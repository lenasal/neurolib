# %%
# change to the root directory of the project
import os
if os.getcwd().split("/")[-1] == "examples":
    os.chdir('..')
    
import matplotlib.pyplot as plt

import numpy as np
from neurolib.models.aln import ALNModel
from neurolib.models.fhn import FHNModel

np.set_printoptions(precision=4)
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = ALNModel()

c_mat = np.array([[0, 0], [0, 0]])
fiber_matrix = np.zeros((len(c_mat), len(c_mat)))
modelNW = ALNModel(Cmat = c_mat, Dmat = fiber_matrix)

init = model.init_vars
output = model.state_vars

model.params.duration = 1.
modelNW.params.duration = 1.

model.run()
modelNW.run()

# %%
# 1 node
for i in range(5):
    print("initial variable = ", init[i])
    print("dim, shape, size, len, value = ", model.params[init[i]].ndim, model.params[init[i]].shape,
          model.params[init[i]].size, len(model.params[init[i]]), model.params[init[i]])
    
for i in range(5):
    print("output variable = ", output[i])
    print("dim, shape, size, len, value = ", model.state[output[i]].ndim, model.state[output[i]].shape,
          model.state[output[i]].size, len(model.state[output[i]]), model.state[output[i]])
# Out:
# initial variable =  rates_exc_init
# dim, shape, size, len, value =  2 (1, 1) 1 1 [[0.0089]]
# initial variable =  rates_inh_init
# dim, shape, size, len, value =  2 (1, 1) 1 1 [[0.007]]
# initial variable =  mufe_init
# dim, shape, size, len, value =  1 (1,) 1 1 [0.7945]
# initial variable =  mufi_init
# dim, shape, size, len, value =  1 (1,) 1 1 [2.4349]
# initial variable =  IA_init
# dim, shape, size, len, value =  2 (1, 1) 1 1 [[97.6594]]
# output variable =  rates_exc
# dim, shape, size, len, value =  2 (1, 10) 10 1 [[1.536  1.4169 1.3022 1.1996 1.1085 1.0206 0.9451 0.8759 0.8089 0.7512]]
# output variable =  rates_inh
# dim, shape, size, len, value =  2 (1, 10) 10 1 [[72.6432 64.6984 58.6584 53.841  49.8776 46.5193 43.624  41.0998 38.8603
#   36.8612]]
# output variable =  mufe
# dim, shape, size, len, value =  1 (1,) 1 1 [0.7121]
# output variable =  mufi
# dim, shape, size, len, value =  1 (1,) 1 1 [1.2846]
# output variable =  IA
# dim, shape, size, len, value =  2 (1, 10) 10 1 [[97.6105 97.5617 97.513  97.4642 97.4155 97.3668 97.3181 97.2694 97.2208
#   97.1722]]

# %%
# 2 nodes
for i in range(5):
    print("initial variable = ", init[i])
    print("dim, shape, size, len, value = ", modelNW.params[init[i]].ndim, modelNW.params[init[i]].shape,
          modelNW.params[init[i]].size, len(modelNW.params[init[i]]), modelNW.params[init[i]])
    
for i in range(5):
    print("output variable = ", output[i])
    print("dim, shape, size, len, value = ", modelNW.state[output[i]].ndim, modelNW.state[output[i]].shape,
          modelNW.state[output[i]].size, len(modelNW.state[output[i]]), modelNW.state[output[i]])
# Out:
# initial variable =  rates_exc_init
# dim, shape, size, len, value =  2 (2, 1) 2 2 [[0.0086]
#  [0.0095]]
# initial variable =  rates_inh_init
# dim, shape, size, len, value =  2 (2, 1) 2 2 [[0.0015]
#  [0.0002]]
# initial variable =  mufe_init
# dim, shape, size, len, value =  1 (2,) 2 2 [1.6316 0.5324]
# initial variable =  mufi_init
# dim, shape, size, len, value =  1 (2,) 2 2 [2.5993 1.5713]
# initial variable =  IA_init
# dim, shape, size, len, value =  2 (2, 1) 2 2 [[162.6257]
#  [113.7022]]
# output variable =  rates_exc
# dim, shape, size, len, value =  2 (2, 10) 20 2 [[17.5423 14.7201 12.4599 10.6233  9.1138  7.8577  6.8103  5.9256  5.1745
#    4.5339]
#  [ 0.0231  0.0225  0.0219  0.0214  0.0209  0.0204  0.0199  0.0194  0.0189
#    0.0185]]
# output variable =  rates_inh
# dim, shape, size, len, value =  2 (2, 10) 20 2 [[77.5134 65.1011 56.5757 50.1901 45.1422 41.0127 37.5641 34.6222 32.0814
#   29.8548]
#  [45.1174 42.7352 40.5851 38.6136 36.8076 35.1306 33.5761 32.1287 30.7761
#   29.5087]]
# output variable =  mufe
# dim, shape, size, len, value =  1 (2,) 2 2 [1.2393 0.5187]
# output variable =  mufi
# dim, shape, size, len, value =  1 (2,) 2 2 [1.089 1.1  ]
# output variable =  IA
# dim, shape, size, len, value =  2 (2, 10) 20 2 [[162.5444 162.4631 162.3819 162.3007 162.2196 162.1384 162.0574 161.9763
#   161.8954 161.8144]
#  [113.6454 113.5886 113.5318 113.475  113.4183 113.3615 113.3049 113.2482
#   113.1916 113.135 ]]

# %%
testarray = np.ones((1))
print(testarray.ndim, testarray.shape)
print(testarray)

test1 = np.array( [testarray] )
print(test1.ndim, test1.shape)
print(test1)
# Out:
# 1 (1,)
# [1.]
# 2 (1, 1)
# [[1.]]
