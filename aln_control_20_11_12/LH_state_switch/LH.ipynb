# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import os
import scipy
import pickle

from neurolib.models.aln import ALNModel
import neurolib.utils.functions as func
from neurolib.utils import costFunctions as cost
from neurolib.utils import plotFunctions as plotFunc

plt.rcParams['image.cmap'] = 'plasma'
cpalette = sns.color_palette('plasma')
np.set_printoptions(precision=4)

font = {
    'family' : 'sans',
    'weight' : 'normal',
    'size'   : 14
       }

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 
matplotlib.rc('grid', c='0.5', ls='-', lw=0.5)  # solid gray grid lines
matplotlib.rc('savefig', dpi=300)       # higher res outputs
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

path = os.getcwd()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def step_control(maxI_ = 1.):
    control_ = aln.getZeroControl()
    for i_time in range(control_.shape[2]):
        if ( float(i_time/control_.shape[2]) < 0.1):
            control_[:,:,i_time] = - maxI_
        elif ( float(i_time/control_.shape[2]) > 0.5 and float(i_time/control_.shape[2]) < 0.6 ):
            control_[:,:,i_time] = maxI_
    return control_

# %%
aln = ALNModel()

aln.params['duration'] = 3000.

control0 = aln.getZeroControl()
target = aln.getZeroTarget()
control0 = step_control(maxI_ = 1.)

aln.params.ext_exc_current = 2.3
aln.params.ext_inh_current = 2.5

# NO ADAPTATION => else no bistability
aln.params.IA_init = np.array([0.])
aln.params.a = 0.
aln.params.b = 0.

# no noise
aln.params.sigma_ou = 0.

state = aln.getZeroState()
aln.run(control = control0)

plt.plot(aln.t, aln.rates_exc[0,:])
plt.plot(aln.t, aln.rates_inh[0,:])
plt.show()

output = aln.output_vars

for i in range(len(output)):
    state[:,i,:] = aln[output[i]][:,:]
    
steady_rates = np.zeros((2, 2))
steady_rates[0,0] = np.mean(state[0,0,3000:15000]) # low state exc
steady_rates[0,1] = np.mean(state[0,1,3000:15000]) # low state inh
steady_rates[1,0] = np.mean(state[0,0,19500:]) # high state exc
steady_rates[1,1] = np.mean(state[0,1,19500:]) #high state inh

print(steady_rates)

state_vars = aln.state_vars
init_vars = aln.init_vars

high_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    #print("final value of state var ", aln.state_vars[i], " : ", aln.state[state_vars[i]])
    if aln.state[state_vars[i]].size == 1:
        high_state_vars[i] = aln.state[state_vars[i]][0] * 1.01
    else:
        high_state_vars[i] = aln.state[state_vars[i]][0,-1] * 1.01
# Out:
# [[1.0281e-02 3.5662e+01]
#  [5.3253e+01 1.0443e+02]]

# %%
aln.params['duration'] = 3000.
control0 = step_control(maxI_ = -1.)
aln.run(control = control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.plot(aln.t, aln.rates_inh[0,:])

low_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    if aln.state[state_vars[i]].size == 1:
        low_state_vars[i] = aln.state[state_vars[i]][0] * 0.99
    else:
        low_state_vars[i] = aln.state[state_vars[i]][0,-2] * 0.99

# %%
dur = 15.
dur_pre = 5.
dur_post = 5.
aln.params.duration = dur

control0 = aln.getZeroControl()

# set high state rates as target
target_lh = aln.getZeroTarget()
target_lh[:,0,:] = steady_rates[1,0]
target_lh[:,1,:] = steady_rates[1,1] 

max_it = 5
tol = 1e-12
incl_step = int(1. + aln.params.duration/aln.params.dt)
start_step = 10.
test_step = 1e-6

c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

alg = "A1"
#alg = "A2"

# %%
def setinitvars(vars):
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                if aln.params[init_vars[iv]].ndim == 2:
                    aln.params[init_vars[iv]][0,:] = vars[sv]
                else:
                    aln.params[init_vars[iv]][0] = vars[sv]

# %% [markdown]
# ## A) State switching from low to high
# - no adaptation (-> bistability)
# - default delay
# - max control current 1 nA
# - w_p = w_e = w_s = 1

# %%
cost.setParams(1.0, 1.0, 1.0)
max_cntrl = 1. * 5.

setinitvars(low_state_vars)
max_it = 100
alg = "A1"
case = "A"

aln.params.duration = dur
control0 = aln.getZeroControl()

bestControlA_A1, bestStateA_A1, costA_A1, runtimeA_A1, grad = aln.A1(control0, target_lh, c_scheme, u_mat, u_scheme,
        max_iteration_ = max_it, tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post)
# Out:
# set cost params
# RUN  0 , total integrated cost =  57082.53849380192
# RUN  1 , total integrated cost =  13299.642948992981
# RUN  2 , total integrated cost =  9049.37049833675
# RUN  3 , total integrated cost =  6909.776256249918
# RUN  4 , total integrated cost =  6312.0678936620625
# RUN  5 , total integrated cost =  5738.703879766123
# RUN  6 , total integrated cost =  5074.061480627613
# RUN  7 , total integrated cost =  4936.2854926076325
# RUN  8 , total integrated cost =  4533.4852493304
# RUN  9 , total integrated cost =  4404.295007422461
# RUN  10 , total integrated cost =  4340.37531478075
# RUN  11 , total integrated cost =  4319.129445276344
# RUN  12 , total integrated cost =  4304.963963133652
# RUN  13 , total integrated cost =  4295.82116705578
# RUN  14 , total integrated cost =  4289.100537109997
# RUN  15 , total integrated cost =  4284.05415687697
# RUN  16 , total integrated cost =  4281.3701407367535
# RUN  17 , total integrated cost =  4279.715063133538
# RUN  18 , total integrated cost =  4277.969758331885
# RUN  19 , total integrated cost =  4276.810603020755
# RUN  20 , total integrated cost =  4276.009117897034
# RUN  21 , total integrated cost =  4275.542997213091
# RUN  22 , total integrated cost =  4275.0943895162145
# RUN  23 , total integrated cost =  4274.736771456413
# RUN  24 , total integrated cost =  4274.387213868899
# RUN  25 , total integrated cost =  4274.0658550897215
# RUN  26 , total integrated cost =  4273.769830566286
# RUN  27 , total integrated cost =  4273.483589454605
# RUN  28 , total integrated cost =  4273.207799949627
# RUN  29 , total integrated cost =  4272.964451435175
# RUN  30 , total integrated cost =  4272.735891715754
# RUN  31 , total integrated cost =  4272.541840961337
# RUN  32 , total integrated cost =  4272.467728564982
# RUN  33 , total integrated cost =  4272.415462046323
# RUN  34 , total integrated cost =  4272.363044450601
# RUN  35 , total integrated cost =  4272.320027861483
# RUN  36 , total integrated cost =  4272.274447456112
# RUN  37 , total integrated cost =  4272.23679882109
# RUN  38 , total integrated cost =  4272.19354593274
# RUN  39 , total integrated cost =  4272.158139447754
# RUN  40 , total integrated cost =  4272.119603665188
# RUN  41 , total integrated cost =  4272.08457564253
# RUN  42 , total integrated cost =  4272.051670074565
# RUN  43 , total integrated cost =  4272.0199746288445
# RUN  44 , total integrated cost =  4271.990240679131
# RUN  45 , total integrated cost =  4271.961864183448
# RUN  46 , total integrated cost =  4271.933577218882
# RUN  47 , total integrated cost =  4271.906532893781
# RUN  48 , total integrated cost =  4271.880830147767
# RUN  49 , total integrated cost =  4271.856236498493
# RUN  50 , total integrated cost =  4271.831640468602
# RUN  51 , total integrated cost =  4271.808113337369
# RUN  52 , total integrated cost =  4271.785649882592
# RUN  53 , total integrated cost =  4271.764189760953
# RUN  54 , total integrated cost =  4271.742605194695
# RUN  55 , total integrated cost =  4271.722002430001
# RUN  56 , total integrated cost =  4271.702173069844
# RUN  57 , total integrated cost =  4271.683209816583
# RUN  58 , total integrated cost =  4271.66402482684
# RUN  59 , total integrated cost =  4271.645796968852
# RUN  60 , total integrated cost =  4271.622188135059
# RUN  61 , total integrated cost =  4271.603253692179
# RUN  62 , total integrated cost =  4271.587212419151
# RUN  63 , total integrated cost =  4271.571192923446
# RUN  64 , total integrated cost =  4271.553150370184
# RUN  65 , total integrated cost =  4271.536805468679
# RUN  66 , total integrated cost =  4271.519868234431
# RUN  67 , total integrated cost =  4271.504198572102
# RUN  68 , total integrated cost =  4271.488842128245
# RUN  69 , total integrated cost =  4271.4736064245735
# RUN  70 , total integrated cost =  4271.4587800908785
# RUN  71 , total integrated cost =  4271.445077813261
# RUN  72 , total integrated cost =  4271.431144740396
# RUN  73 , total integrated cost =  4271.418116406258
# RUN  74 , total integrated cost =  4271.405061662328
# RUN  75 , total integrated cost =  4271.392710613226
# RUN  76 , total integrated cost =  4271.380476383098
# RUN  77 , total integrated cost =  4271.368748528381
# RUN  78 , total integrated cost =  4271.357264057654
# RUN  79 , total integrated cost =  4271.3461109861355
# RUN  80 , total integrated cost =  4271.33544114979
# RUN  81 , total integrated cost =  4271.325052149169
# RUN  82 , total integrated cost =  4271.315013587285
# RUN  83 , total integrated cost =  4271.3051997255725
# RUN  84 , total integrated cost =  4271.295655049654
# RUN  85 , total integrated cost =  4271.286381993285
# RUN  86 , total integrated cost =  4271.277225703452
# RUN  87 , total integrated cost =  4271.268537691055
# RUN  88 , total integrated cost =  4271.259771626012
# RUN  89 , total integrated cost =  4271.251601652418
# RUN  90 , total integrated cost =  4271.243197438335
# RUN  91 , total integrated cost =  4271.235517055364
# RUN  92 , total integrated cost =  4271.227455656837
# RUN  93 , total integrated cost =  4271.220217293899
# RUN  94 , total integrated cost =  4271.2123566225055
# RUN  95 , total integrated cost =  4271.204698504083
# RUN  96 , total integrated cost =  4271.196350544824
# RUN  97 , total integrated cost =  4271.188108474919
# RUN  98 , total integrated cost =  4271.179028713681
# RUN
# ERROR:root:Problem in initial value trasfer
#  99 , total integrated cost =  4271.17064186357
# RUN  100 , total integrated cost =  4271.166370850217
# Improved over  100  iterations by  92.51756056484071  percent.
# Problem in initial value trasfer:  Vmean_exc -56.70421426341613 -56.70421424953248

# %%
plotFunc.plot_runtime(runtimeA_A1, path, str("p1_e1_s1_u1nA_LowHigh_runtime_" + case + "_" + alg) )
plotFunc.plot_convergence(costA_A1, path, str("p1_e1_s1_u1nA_LowHigh_cost_" + case + "_" + alg) )

# %%
plotFunc.plot_control(aln, bestControlA_A1, dur, dur_pre, dur_post, low_state_vars, target_lh,
                      path, filename_ = str('p1_e1_s1_u1nA_LowHigh_' + case + "_" + alg))

# %%
setinitvars(low_state_vars)
max_it = 20
alg = "A2"
case = "A"

aln.params.duration = dur
control0 = aln.getZeroControl()

bestControlA_A2, bestStateA_A2, costA_A2, runtimeA_A2 = aln.A2(control0, target_lh,
        max_iteration_ = max_it,  tolerance_ = tol, include_timestep_ = incl_step,
        start_step_ = start_step, test_step_ = test_step, max_control_ = max_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post)
# Out:
# RUN  0 , total integrated cost:  57082.53849380192
# RUN  1 , total integrated cost:  9113.683122855426
# RUN  2 , total integrated cost:  7329.3721317153495
# RUN  3 , total integrated cost:  5998.301643809373
# RUN  4 , total integrated cost:  4903.08361925198
# RUN  5 , total integrated cost:  4661.651763152516
# RUN  6 , total integrated cost:  4526.458856110947
# RUN  7 , total integrated cost:  4344.984338094069
# RUN  8 , total integrated cost:  4321.045893147665
# RUN  9 , total integrated cost:  4306.277026166069
# RUN  10 , total integrated cost:  4286.337036974125
# RUN  11 , total integrated cost:  4282.09603185366
# RUN  12 , total integrated cost:  4279.342678266308
# RUN  13 , total integrated cost:  4274.847597164297
# RUN  14 , total integrated cost:  4273.737241803494
# RUN  15 , total integrated cost:  4272.807283431023
# RUN  16 , total integrated cost:  4272.261386940426
# RUN  17 , total integrated cost:  4271.872746047677
# RUN  18 , total integrated cost:  4271.656834119364
# RUN  19 , total integrated cost:  4271.519041326765
# RUN  20 , total integrated cost:  4271.2966744564355
# RUN  21 , total integrated cost:  4271.263950961207
# RUN  22 , total integrated cost:  4271.234287926605
# RUN  23 , total integrated cost:  4271.2097659579995
# RUN  24 , total integrated cost:  4271.197254697911
# RUN  25 , total integrated cost:  4271.186301372598
# RUN  26 , total integrated cost:  4271.171919744768
# RUN  27 , total integrated cost:  4271.163482347623
# RUN  28 , total integrated cost:  4271.160586107327
# RUN  29 , total integrated cost:  4271.158528098472
# RUN  30 , total integrated cost:  4271.156922596301
# RUN  31 , total integrated cost:  4271.155225598875
# RUN  32 , total integrated cost:  4271.154305834429
# RUN  33 , total integrated cost:  4271.153147969617
# RUN  34 , total integrated cost:  4271.152625661552
# RUN  35 , total integrated cost:  4271.152216203391
# RUN  36 , total integrated cost:  4271.151915092328
# RUN  37 , total integrated cost:  4271.151633566029
# RUN  38 , total integrated cost:  4271.151410397158
# RUN  39 , total integrated cost:  4271.15128515442
# ERROR:root:Problem in initial value trasfer
# RUN  40 , total integrated cost:  4271.151166846514
# Improved over  40  iterations by  93  percent.
# Problem in initial value trasfer:  Vmean_exc -56.7042148530831 -56.70421477141404

# %%
plotFunc.plot_runtime(runtimeA_A2, path, str("p1_e1_s1_u1nA_LowHigh_runtime_" + case + "_" + alg) )
plotFunc.plot_convergence(costA_A2, path, str("p1_e1_s1_u1nA_LowHigh_cost_" + case + "_" + alg) )

# %%
plotFunc.plot_control(aln, bestControlA_A2, dur, dur_pre, dur_post, low_state_vars, target_lh,
                      path, filename_ = str('p1_e1_s1_u1nA_LowHigh_' + case + "_" + alg))

# %%
diff = bestControlA_A1 - bestControlA_A2

t = np.arange(0,dur + dur_pre + dur_post + aln.params.dt, aln.params.dt)
plt.plot(t, diff[0,0,:], label="difference in exc control")
plt.plot(t, diff[0,1,:], label="difference in inh control")
plt.grid()
plt.legend()
plt.show()
