# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import os
import scipy
import pickle

from neurolib.models.aln import ALNModel
import neurolib.utils.functions as func
from neurolib.utils import costFunctions as cost
from neurolib.utils import plotFunctions as plotFunc

plt.rcParams['image.cmap'] = 'plasma'
cpalette = sns.color_palette('plasma')
np.set_printoptions(precision=4)

font = {
    'family' : 'sans',
    'weight' : 'normal',
    'size'   : 14
       }

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 
matplotlib.rc('grid', c='0.5', ls='-', lw=0.5)  # solid gray grid lines
matplotlib.rc('savefig', dpi=300)       # higher res outputs
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

path = os.getcwd()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def step_control(maxI_ = 1.):
    control_ = aln.getZeroControl()
    for i_time in range(control_.shape[2]):
        if ( float(i_time/control_.shape[2]) < 0.1):
            control_[:,:,i_time] = - maxI_
        elif ( float(i_time/control_.shape[2]) > 0.5 and float(i_time/control_.shape[2]) < 0.6 ):
            control_[:,:,i_time] = maxI_
    return control_

# %%
aln = ALNModel()

aln.params['duration'] = 3000.

control0 = aln.getZeroControl()
target = aln.getZeroTarget()
control0 = step_control(maxI_ = 1.)

aln.params.ext_exc_current = 2.3
aln.params.ext_inh_current = 2.5

# NO ADAPTATION => else no bistability
aln.params.IA_init = np.array([0.])
aln.params.a = 0.
aln.params.b = 0.

# no noise
aln.params.sigma_ou = 0.

state = aln.getZeroState()
aln.run(control = control0)

plt.plot(aln.t, aln.rates_exc[0,:])
plt.plot(aln.t, aln.rates_inh[0,:])
plt.show()

output = aln.output_vars

for i in range(len(output)):
    state[:,i,:] = aln[output[i]][:,:]
    
steady_rates = np.zeros((2, 2))
steady_rates[0,0] = np.mean(state[0,0,3000:15000]) # low state exc
steady_rates[0,1] = np.mean(state[0,1,3000:15000]) # low state inh
steady_rates[1,0] = np.mean(state[0,0,19500:]) # high state exc
steady_rates[1,1] = np.mean(state[0,1,19500:]) #high state inh

print(steady_rates)

state_vars = aln.state_vars
init_vars = aln.init_vars

high_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    #print("final value of state var ", aln.state_vars[i], " : ", aln.state[state_vars[i]])
    if aln.state[state_vars[i]].size == 1:
        high_state_vars[i] = aln.state[state_vars[i]][0] * 1.01
    else:
        high_state_vars[i] = aln.state[state_vars[i]][0,-1] * 1.01
# Out:
# [[1.0281e-02 3.5662e+01]
#  [5.3253e+01 1.0443e+02]]

# %%
aln.params['duration'] = 3000.
control0 = step_control(maxI_ = -1.)
aln.run(control = control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.plot(aln.t, aln.rates_inh[0,:])

low_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    if aln.state[state_vars[i]].size == 1:
        low_state_vars[i] = aln.state[state_vars[i]][0] * 0.99
    else:
        low_state_vars[i] = aln.state[state_vars[i]][0,-2] * 0.99

# %%
dur = 15.
dur_pre = 5.
dur_post = 5.
aln.params.duration = dur

control0 = aln.getZeroControl()

# set high state rates as target
target_lh = aln.getZeroTarget()
target_lh[:,0,:] = steady_rates[1,0]
target_lh[:,1,:] = steady_rates[1,1] 

max_it = 5
tol = 1e-12
incl_step = int(1. + aln.params.duration/aln.params.dt)
start_step = 10.
test_step = 1e-6

c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

alg = "A1"
#alg = "A2"

# %%
def setinitvars(vars):
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                if aln.params[init_vars[iv]].ndim == 2:
                    aln.params[init_vars[iv]][0,:] = vars[sv]
                else:
                    aln.params[init_vars[iv]][0] = vars[sv]

# %% [markdown]
# ## A)
# - no adaptation
# - default delay
# - max control current 1nA
# - w_p = w_e = w_s = 1

# %%
cost.setParams(1.0, 1.0, 1.0)
max_cntrl = 1. * 5.

setinitvars(low_state_vars)
max_it = 100
alg = "A1"
case = "A"

opt_params = {"max_it": max_it,
              "tol": tol,
              "incl_step": incl_step,
              "start_step": start_step,
              "test_step": test_step,
              "dur": dur,
              "dur_pre": dur_pre,
              "dur_post": dur_post,
              "alg": alg,
}

control0 = aln.getZeroControl()

if alg == "A1":
    bestControlA, bestStateA, costA, runtimeA = aln.A1(control0, target_lh, c_scheme, u_mat, u_scheme,
        max_iteration_ = max_it, tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post)
elif alg == "A2":
    bestControlA, bestStateA, costA, runtimeA = aln.A2(control0, target_lh, max_iteration_ = max_it,
                tolerance_ = tol, include_timestep_ = incl_step, start_step_ = start_step, test_step_ = test_step,
                max_control_ = max_cntrl, t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post)

resultA = {"Opt_control": bestControlA,
          "Opt_state": bestStateA,
          "costArray": costA,
          "runtimeArray": runtimeA,    
}

dump_dicts = [opt_params, aln.params, resultA]
filename = str(case + "_" + alg + ".p")
pickle.dump( dump_dicts, open( filename, "wb" ) )
# Out:
# set cost params
# True 40
# RUN  0 , total integrated cost =  57082.53849380191
# RUN  1 , total integrated cost =  13299.642948992963
# RUN  2 , total integrated cost =  9049.37049833675
# RUN  3 , total integrated cost =  6909.77625624992
# RUN  4 , total integrated cost =  6312.067893662069
# RUN  5 , total integrated cost =  5738.703879766123
# RUN  6 , total integrated cost =  5074.061480627612
# RUN  7 , total integrated cost =  4936.285492607637
# RUN  8 , total integrated cost =  4533.485249330401
# RUN  9 , total integrated cost =  4404.295007422463
# RUN  10 , total integrated cost =  4340.375314780755
# RUN  11 , total integrated cost =  4319.1294452763395
# RUN  12 , total integrated cost =  4304.963963133658
# RUN  13 , total integrated cost =  4295.821167055796
# RUN  14 , total integrated cost =  4289.100537109997
# RUN  15 , total integrated cost =  4284.054156876968
# RUN  16 , total integrated cost =  4281.370140736748
# RUN  17 , total integrated cost =  4279.715063133536
# RUN  18 , total integrated cost =  4277.969758331889
# RUN  19 , total integrated cost =  4276.810603020758
# RUN  20 , total integrated cost =  4276.009117897041
# RUN  21 , total integrated cost =  4275.542997213087
# RUN  22 , total integrated cost =  4275.094389516211
# RUN  23 , total integrated cost =  4274.736771456408
# RUN  24 , total integrated cost =  4274.387213868905
# RUN  25 , total integrated cost =  4274.065855089721
# RUN  26 , total integrated cost =  4273.769830566281
# RUN  27 , total integrated cost =  4273.483589454608
# RUN  28 , total integrated cost =  4273.207799949621
# RUN  29 , total integrated cost =  4272.96445143518
# RUN  30 , total integrated cost =  4272.735891715758
# RUN  31 , total integrated cost =  4272.541840961339
# RUN  32 , total integrated cost =  4272.4677285649805
# RUN  33 , total integrated cost =  4272.41546204633
# RUN  34 , total integrated cost =  4272.3630444506025
# RUN  35 , total integrated cost =  4272.320027861493
# RUN  36 , total integrated cost =  4272.274447456106
# RUN  37 , total integrated cost =  4272.236798821086
# RUN  38 , total integrated cost =  4272.193545932733
# RUN  39 , total integrated cost =  4272.15813944776
# RUN  40 , total integrated cost =  4272.119603665187
# RUN  41 , total integrated cost =  4272.08457564252
# RUN  42 , total integrated cost =  4272.051670074563
# RUN  43 , total integrated cost =  4272.019974628843
# RUN  44 , total integrated cost =  4271.990240679135
# RUN  45 , total integrated cost =  4271.961864183448
# RUN  46 , total integrated cost =  4271.933577218878
# RUN  47 , total integrated cost =  4271.906532893784
# RUN  48 , total integrated cost =  4271.880830147761
# RUN  49 , total integrated cost =  4271.856236498506
# RUN  50 , total integrated cost =  4271.831640468608
# RUN  51 , total integrated cost =  4271.808113337376
# RUN  52 , total integrated cost =  4271.785649882591
# RUN  53 , total integrated cost =  4271.764189760949
# RUN  54 , total integrated cost =  4271.742605194698
# RUN  55 , total integrated cost =  4271.722002429998
# RUN  56 , total integrated cost =  4271.70217306985
# RUN  57 , total integrated cost =  4271.683209816585
# RUN  58 , total integrated cost =  4271.664024826841
# RUN  59 , total integrated cost =  4271.645796968841
# RUN  60 , total integrated cost =  4271.622188135064
# RUN  61 , total integrated cost =  4271.60325369218
# RUN  62 , total integrated cost =  4271.587212419149
# RUN  63 , total integrated cost =  4271.571192923452
# RUN  64 , total integrated cost =  4271.5531503701795
# RUN  65 , total integrated cost =  4271.536805468678
# RUN  66 , total integrated cost =  4271.519868234433
# RUN  67 , total integrated cost =  4271.504198572104
# RUN  68 , total integrated cost =  4271.488842128238
# RUN  69 , total integrated cost =  4271.473606424578
# RUN  70 , total integrated cost =  4271.458780090876
# RUN  71 , total integrated cost =  4271.445077813265
# RUN  72 , total integrated cost =  4271.431144740394
# RUN  73 , total integrated cost =  4271.418116406265
# RUN  74 , total integrated cost =  4271.40506166233
# RUN  75 , total integrated cost =  4271.392710613224
# RUN  76 , total integrated cost =  4271.380476383095
# RUN  77 , total integrated cost =  4271.368748528385
# RUN  78 , total integrated cost =  4271.357264057656
# RUN  79 , total integrated cost =  4271.346110986139
# RUN  80 , total integrated cost =  4271.33544114979
# RUN  81 , total integrated cost =  4271.32505214918
# RUN  82 , total integrated cost =  4271.315013587285
# RUN  83 , total integrated cost =  4271.3051997255725
# RUN  84 , total integrated cost =  4271.295655049658
# RUN  85 , total integrated cost =  4271.286381993293
# RUN  86 , total integrated cost =  4271.277225703453
# RUN  87 , total integrated cost =  4271.2685376910495
# RUN  88 , total integrated cost =  4271.2597716260125
# RUN  89 , total integrated cost =  4271.2516016524105
# RUN  90 , total integrated cost =  4271.243197438335
# RUN  91 , total integrated cost =  4271.23551705536
# RUN  92 , total integrated cost =  4271.227455656841
# RUN  93 , total integrated cost =  4271.220217293893
# RUN  94 , total integrated cost =  4271.212356622508
# RUN  95 , total integrated cost =  4271.204698504087
# RUN  96 , total integrated cost =  4271.196350544826
# RUN  97 , total integrated cost =  4271.188108474927
# RUN  98 , total integrated cost =  4271.179028713683
# RUN  99 , total integrated cost =  4271.170641863572
# RUN  100 , total integrated cost =  4271.166370850214
# Improved over  100  iterations by  92.51756056484072  percent.
# max value of final gradient at index =  (array([0], dtype=int64), array([0], dtype=int64), array([31], dtype=int64)) 2.82126339775118
# min value of final gradient at index =  (array([0], dtype=int64), array([1], dtype=int64), array([1], dtype=int64)) -319.79166235875766

# %%
plotFunc.plot_runtime(runtimeA, path, str("p1_e1_s1_u1nA_LowHigh_runtime_" + case + "_" + alg) )
plotFunc.plot_convergence(costA, path, str("p1_e1_s1_u1nA_LowHigh_cost_" + case + "_" + alg) )

# %%
plotFunc.plot_control(aln, bestControlA, dur, dur_pre, dur_post, low_state_vars, target_lh,
                      path, filename_ = str('p1_e1_s1_u1nA_LowHigh_' + case + "_" + alg))
