# %%
import os
import sys
import shutil
import os
from boar.running import run_notebook

# %%
path_data = os.path.join(os.getcwd(), "data")
subfolders = [ f.path for f in os.scandir(path_data) if f.is_dir() ]

# %%
for f in subfolders:
    print(f)
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\00100
# D:\Promotion\neurolib\GUI\current\gui\data\00101
# D:\Promotion\neurolib\GUI\current\gui\data\00110
# D:\Promotion\neurolib\GUI\current\gui\data\00111
# D:\Promotion\neurolib\GUI\current\gui\data\00120
# D:\Promotion\neurolib\GUI\current\gui\data\00121
# D:\Promotion\neurolib\GUI\current\gui\data\00131
# D:\Promotion\neurolib\GUI\current\gui\data\00141
# D:\Promotion\neurolib\GUI\current\gui\data\00151
# D:\Promotion\neurolib\GUI\current\gui\data\00161
# D:\Promotion\neurolib\GUI\current\gui\data\00171
# D:\Promotion\neurolib\GUI\current\gui\data\00181
# D:\Promotion\neurolib\GUI\current\gui\data\01100
# D:\Promotion\neurolib\GUI\current\gui\data\01101
# D:\Promotion\neurolib\GUI\current\gui\data\01110
# D:\Promotion\neurolib\GUI\current\gui\data\01111
# D:\Promotion\neurolib\GUI\current\gui\data\01120
# D:\Promotion\neurolib\GUI\current\gui\data\01121
# D:\Promotion\neurolib\GUI\current\gui\data\01131
# D:\Promotion\neurolib\GUI\current\gui\data\01141
# D:\Promotion\neurolib\GUI\current\gui\data\01151
# D:\Promotion\neurolib\GUI\current\gui\data\01161
# D:\Promotion\neurolib\GUI\current\gui\data\01171
# D:\Promotion\neurolib\GUI\current\gui\data\01181
# D:\Promotion\neurolib\GUI\current\gui\data\10100
# D:\Promotion\neurolib\GUI\current\gui\data\10101
# D:\Promotion\neurolib\GUI\current\gui\data\10110
# D:\Promotion\neurolib\GUI\current\gui\data\10111
# D:\Promotion\neurolib\GUI\current\gui\data\10120
# D:\Promotion\neurolib\GUI\current\gui\data\10121
# D:\Promotion\neurolib\GUI\current\gui\data\10131
# D:\Promotion\neurolib\GUI\current\gui\data\10141
# D:\Promotion\neurolib\GUI\current\gui\data\10151
# D:\Promotion\neurolib\GUI\current\gui\data\10161
# D:\Promotion\neurolib\GUI\current\gui\data\10171
# D:\Promotion\neurolib\GUI\current\gui\data\10181
# D:\Promotion\neurolib\GUI\current\gui\data\11100
# D:\Promotion\neurolib\GUI\current\gui\data\11101
# D:\Promotion\neurolib\GUI\current\gui\data\11110
# D:\Promotion\neurolib\GUI\current\gui\data\11111
# D:\Promotion\neurolib\GUI\current\gui\data\11120
# D:\Promotion\neurolib\GUI\current\gui\data\11121
# D:\Promotion\neurolib\GUI\current\gui\data\11131
# D:\Promotion\neurolib\GUI\current\gui\data\11141
# D:\Promotion\neurolib\GUI\current\gui\data\11151
# D:\Promotion\neurolib\GUI\current\gui\data\11161
# D:\Promotion\neurolib\GUI\current\gui\data\11171
# D:\Promotion\neurolib\GUI\current\gui\data\11181
# D:\Promotion\neurolib\GUI\current\gui\data\shift_init

# %% [markdown]
# ## Delete subfolders in data

# %%
folders = []

for f in subfolders:
    folders.append(f.split(os.sep)[-1])
    
folders.pop(-1)
print(folders)
# Out:
# ['00100', '00101', '00110', '00111', '00120', '00121', '00131', '00141', '00151', '00161', '00171', '00181', '01100', '01101', '01110', '01111', '01120', '01121', '01131', '01141', '01151', '01161', '01171', '01181', '10100', '10101', '10110', '10111', '10120', '10121', '10131', '10141', '10151', '10161', '10171', '10181', '11100', '11101', '11110', '11111', '11120', '11121', '11131', '11141', '11151', '11161', '11171', '11181']

# %%
# delete specific subfolders
delete = ['11111']

for d in delete:
    path_delete = os.path.join(path_data, d)
    shutil.rmtree(path_delete)

# %%
# delete all but particular subfolders
keep = ['.ipynb_checkpoints', '00001']

subfolders = [ f.path for f in os.scandir(path_data) if f.is_dir() ]

for s in subfolders:
    case = s.split(os.sep)[-1]
    if case not in keep:
        print("delete case ", case)
        path_delete = os.path.join(path_data, case)
        shutil.rmtree(path_delete)

# %%
# delete results from specific subfolders
delete = folders

for d in delete:
    if d[4] == '0':
        continue
    file_delete = os.path.join(path_data, d, 'control_init_' + d + '.pickle')
    print(file_delete)
    if os.path.isfile(file_delete):
        os.remove(file_delete)
    file_delete = os.path.join(path_data, d, 'control_' + d + '.pickle')
    if os.path.isfile(file_delete):
        os.remove(file_delete)
    file_delete = os.path.join(path_data, d, 'control_' + d[0] + d[1] + '0' + d[3] + d[4] + '.pickle')
    if os.path.isfile(file_delete):
        os.remove(file_delete)
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\00101\control_init_00101.pickle
# D:\Promotion\neurolib\GUI\current\gui\data\00111\control_init_00111.pickle
# D:\Promotion\neurolib\GUI\current\gui\data\00121\control_init_00121.pickle
# D:\Promotion\neurolib\GUI\current\gui\data\00131\control_init_00131.pickle
# D:\Promotion\neurolib\GUI\current\gui\data\00141\control_init_00141.pickle
# D:\Promotion\neurolib\GUI\current\gui\data\00151\control_init_00151.pickle

# %%
# delete results from all but particular subfolders
keep = ['.ipynb_checkpoints', '00001']

subfolders = [ f.path for f in os.scandir(path_data) if f.is_dir() ]

for s in subfolders:
    case = s.split(os.sep)[-1]
    if case not in keep:
        print("delete case ", case)
        file_delete = os.path.join(path_data, case, 'control_init_' + case + '.pickle')
        if os.path.isfile(file_delete):
            os.remove(file_delete)
        file_delete = os.path.join(path_data, case, 'control_0_' + case + '.pickle')
        if os.path.isfile(file_delete):
            os.remove(file_delete)

# %% [markdown]
# ## Create folders for data and copy data and scripts¶

# %%
# create all
for fol in folders:
    create_path = os.path.join(path_data, fol)
    if not os.path.isdir(create_path):
        print("create directory ", fol)
        os.mkdir(create_path)

# %%
# create particular
create= ['11111']

for c in create:
    create_path = os.path.join(path_data, c)
    if not os.path.isdir(create_path):
        print("create directory ", c)
        os.mkdir(create_path)

# %%
# Copy data and script to all folders

copy_from = '10161'
copy_to = ['10171', '10181', '11161', '11171', '11181']

copy_file = ['bi.pickle', 'data.ipynb', 'plots.ipynb']
#copy_file = ['plots.ipynb']

for c in copy_to:
    if c == copy_from:
        continue
        
    copy_from_path = os.path.join(path_data, copy_from)
    copy_to_path = os.path.join(path_data, c)
    if not os.path.isdir(copy_to_path):
        print("directory does not exist, create")
        os.mkdir(copy_to_path)
            
    for cf in copy_file:
        copy_from_file = os.path.join(copy_from_path, cf)
        copy_to_file = os.path.join(copy_to_path, cf)
        shutil.copyfile(copy_from_file, copy_to_file)

# %%
print(os.getcwd())

run_cases = [
    '00101'
            ] 

if 'data' not in os.getcwd():
    os.chdir('data' + os.sep)
    
#for run_ in folders[-12:]:
    
for run_ in run_cases:
    
    print("------------------------- RUN ", run_)
    os.chdir(run_)
    #outputs = run_notebook('data.ipynb')
    outputs = run_notebook('plots.ipynb')
    os.chdir('..')
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data
# ------------------------- RUN  00111
# --------------------------------------------------
# Cell 0
# --------------------------------------------------
# import matplotlib.pyplot as plt
# import numpy as np
# import os
# import sys
# import pickle
#
# path = os.getcwd().split(os.sep +'GUI')[0]
# if path not in sys.path:
#     sys.path.append(path)
#
# from neurolib.models.aln import ALNModel
# from neurolib.utils import plotFunctions as plotFunc
# from neurolib.utils import costFunctions as cost
# import neurolib.dashboard.functions as functions
# import neurolib.dashboard.data as data
#
# # This will reload all imports as soon as the code changes
#
# path = os.getcwd()
# case = path.split(os.sep)[-1]
# print(path, case)
#
# aln = ALNModel()
# data.set_parameters(aln)
# state_vars = aln.state_vars
#
#
# D:\Promotion\neurolib\GUI\current\gui\data\00111 00111
# --------------------------------------------------
# Cell 1
# --------------------------------------------------
# def set_target_init(exc_, inh_, max_I, model, dur):
#     import neurolib.dashboard.functions as functions
#     import numpy as np
#
#     initVars_ = [None] * len(exc_)
#     target_ = [None] * len(exc_)
#
#     for i in range(len(exc_)):
#         model.params.mue_ext_mean = exc_[i] * 5.
#         model.params.mui_ext_mean = inh_[i] * 5.
#
#         model.params.duration = 3000.
#
#         control0 = model.getZeroControl()
#         control0 = functions.step_control(model, maxI_ = max_I[0])
#         model.run(control=control0)
#
#         target_rates = np.zeros((2))
#         target_rates[0] = model.rates_exc[0,-1]
#         target_rates[1] = model.rates_inh[0,-1]
#
#         control0 = functions.step_control(model, maxI_ = max_I[1])
#         model.run(control=control0)
#
#         state_vars = model.state_vars
#
#         init_state_vars = np.zeros(( len(state_vars) ))
#         for j in range(len(state_vars)):
#             if model.state[state_vars[j]].size == 1:
#                 init_state_vars[j] = model.state[state_vars[j]][0]
#             else:
#                 init_state_vars[j] = model.state[state_vars[j]][0,-1]
#
#         initVars_[i] = init_state_vars
#
#         model.params.duration = dur
#         target_[i] = model.getZeroTarget()
#         target_[i][:,0,:] = target_rates[0]
#         target_[i][:,1,:] = target_rates[1]
#
#     return initVars_, target_
#
#
# --------------------------------------------------
# Cell 2
# --------------------------------------------------
# data_array = data.read_data(aln, path, case)
# exc_, inh_, both_c_, no_c_ = data_array[0:4]
# exc_1, inh_1, lenx_1, leny_1, exc_2, inh_2, lenx_2, leny_2 = data_array[4:12]
# exc_3, inh_3, lenx_3, leny_3, exc_4, inh_4, lenx_4, leny_4, cost1, cost2, cost3, cost4 = data_array[12:]
#
# with open(path + os.sep + 'bi.pickle','rb') as f:
#     load_array= pickle.load(f)
# ext_exc = load_array[0]
# ext_inh = load_array[1]
#
# print(exc_)
# print(inh_)
#
# print(both_c_)
# print(no_c_)
#
# [bestControl_init, costnode_init, bestControl_0, bestState_0, costnode_0] = data.read_control(path, case)
#
# if case[4] == '0':
#     dur = 100
#     trans_time = 0.8
# elif case[4] == '1':
#     dur = 400
#     trans_time = 0.95
#
# dur_pre = 10
# dur_post = 10
#
# if case[0] == '0':    # low to high
#     max_I = [3., -3.]
# elif case[0] == '1':
#     max_I = [-3., 3.]
#
# path_directory = path.split(os.sep + 'data')[0] + os.sep + 'plots_'
# try:
#     os.stat(path_directory)
# except:
#     os.mkdir(path_directory)
#
# path_directory = path_directory + os.sep + case
# try:
#     os.stat(path_directory)
# except:
#     os.mkdir(path_directory)
#
# cases_ = ['1', '2', '3', '4']
# for c_dir in cases_:
#     cases_dir = os.path.join(path_directory, c_dir)
#     try:
#         os.stat(cases_dir)
#     except:
#         os.mkdir(cases_dir)
#
#
# [35, 75, 90, 105, 110, 115, 120, 125, 130, 135, 140, 145]
# [0, 5, 10, 15, 20, 25, 30, 40, 45, 50, 65, 80]
# [55, 60, 70, 85, 95, 100]
# []
# --------------------------------------------------
# Cell 3
# --------------------------------------------------
# initVars_1, target_1 = set_target_init(exc_1, inh_1, max_I, aln, dur)
#
# path1 = path_directory + os.sep + '1'
# print(path1)
#
# try:
#     os.stat(path1)
# except:
#     os.mkdir(path1)
#
# for i in range(len(exc_1)):
#
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_1[i] * 5.
#     aln.params.mui_ext_mean = inh_1[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in exc_:
#             #print(i, j)
#             if exc_1[i] == ext_exc[j] and inh_1[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_1[i], target_1[i], path1, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#     plt.draw(); plt.close('all')
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00111\1
# 35
# 75
# 90
# 105
# 110
# 115
# 120
# 125
# 130
# 135
# 140
# 145
# --------------------------------------------------
# Cell 4
# --------------------------------------------------
# initVars_2, target_2 = set_target_init(exc_2, inh_2, max_I, aln, dur)
#
# path2 = path_directory + os.sep + '2'
# print(path2)
#
# try:
#     os.stat(path2)
# except:
#     os.mkdir(path2)
#
# for i in range(len(exc_2)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_2[i] * 5.
#     aln.params.mui_ext_mean = inh_2[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in inh_:
#             #print(i, j)
#             if exc_2[i] == ext_exc[j] and inh_2[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_2[i], target_2[i], path2, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00111\2
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 40
# 45
# 50
# 65
# 80
# --------------------------------------------------
# Cell 5
# --------------------------------------------------
# initVars_3, target_3 = set_target_init(exc_3, inh_3, max_I, aln, dur)
#
# path3 = path_directory + os.sep + '3'
# print(path3)
#
# try:
#     os.stat(path3)
# except:
#     os.mkdir(path3)
#
# for i in range(len(exc_3)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_3[i] * 5.
#     aln.params.mui_ext_mean = inh_3[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in both_c_:
#             if exc_3[i] == ext_exc[j] and inh_3[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_3[i], target_3[i], path3, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00111\3
# 55
# 60
# 70
# 85
# 95
# 100
# --------------------------------------------------
# Cell 6
# --------------------------------------------------
# initVars_4, target_4 = set_target_init(exc_4, inh_4, max_I, aln, dur)
#
# path4 = path_directory + os.sep + '4'
# print(path4)
#
# try:
#     os.stat(path1)
# except:
#     os.mkdir(path1)
#
# for i in range(len(exc_4)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_4[i] * 5.
#     aln.params.mui_ext_mean = inh_4[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in no_c_:
#             if exc_4[i] == ext_exc[j] and inh_4[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_4[i], target_4[i], path4, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#     plt.draw(); plt.close('all')
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00111\4
# --------------------------------------------------
# Cell 7
# --------------------------------------------------
# path = os.getcwd()
# case = path.split(os.sep)[-1]
# print(path, case)
#
# case1 = case[0] + case[1] + '0' + case[3] + case[4]
#
# data_array = data.read_data(aln, path, case1)
# exc_, inh_, both_c_, no_c_ = data_array[0:4]
# exc_1, inh_1, lenx_1, leny_1, exc_2, inh_2, lenx_2, leny_2 = data_array[4:12]
# exc_3, inh_3, lenx_3, leny_3, exc_4, inh_4, lenx_4, leny_4, cost1, cost2, cost3, cost4 = data_array[12:]
#
# print(exc_)
# print(inh_)
#
# print(both_c_)
# print(no_c_)
#
# [bestControl_init, costnode_init, bestControl_0, bestState_0, costnode_0] = data.read_control(path, case1)
#
# path_directory = path.split(os.sep + 'data')[0] + os.sep + 'plots_'
# path_directory = path_directory + os.sep + case1
# try:
#     os.stat(path_directory)
# except:
#     os.mkdir(path_directory)
#
# cases_ = ['1', '2', '3', '4']
# for c_dir in cases_:
#     cases_dir = os.path.join(path_directory, c_dir)
#     try:
#         os.stat(cases_dir)
#     except:
#         os.mkdir(cases_dir)
#
#
# D:\Promotion\neurolib\GUI\current\gui\data\00111 00111
# []
# [0, 5, 10, 15, 20, 25, 30, 40, 45, 50, 65, 80]
# [35, 55, 60, 70, 75, 85, 90, 95, 100, 105, 110, 115, 120, 125, 130, 135, 140, 145]
# []
# --------------------------------------------------
# Cell 8
# --------------------------------------------------
# initVars_1, target_1 = set_target_init(exc_1, inh_1, max_I, aln, dur)
#
# path1 = path_directory + os.sep + '1'
# print(path1)
#
# try:
#     os.stat(path1)
# except:
#     os.mkdir(path1)
#
# for i in range(len(exc_1)):
#
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_1[i] * 5.
#     aln.params.mui_ext_mean = inh_1[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in exc_:
#             #print(i, j)
#             if exc_1[i] == ext_exc[j] and inh_1[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_1[i], target_1[i], path1, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00011\1
# --------------------------------------------------
# Cell 9
# --------------------------------------------------
# initVars_2, target_2 = set_target_init(exc_2, inh_2, max_I, aln, dur)
#
# path2 = path_directory + os.sep + '2'
# print(path2)
#
# try:
#     os.stat(path2)
# except:
#     os.mkdir(path2)
#
# for i in range(len(exc_2)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_2[i] * 5.
#     aln.params.mui_ext_mean = inh_2[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in inh_:
#             #print(i, j)
#             if exc_2[i] == ext_exc[j] and inh_2[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_2[i], target_2[i], path2, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00011\2
# 0
# 5
# 10
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 15
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 20
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 25
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 30
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 40
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 45
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 50
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 65
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 80
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# --------------------------------------------------
# Cell 10
# --------------------------------------------------
# initVars_3, target_3 = set_target_init(exc_3, inh_3, max_I, aln, dur)
#
# path3 = path_directory + os.sep + '3'
# print(path3)
#
# try:
#     os.stat(path3)
# except:
#     os.mkdir(path3)
#
# for i in range(len(exc_3)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_3[i] * 5.
#     aln.params.mui_ext_mean = inh_3[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in both_c_:
#             if exc_3[i] == ext_exc[j] and inh_3[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_3[i], target_3[i], path3, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00011\3
# 35
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 55
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 60
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 70
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 75
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 85
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 90
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 95
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 100
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 105
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 110
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 115
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 120
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 125
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 130
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 135
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 140
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# 145
# D:\Promotion\neurolib\neurolib\utils\plotFunctions.py:543: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(rows, columns, figsize=(8, 6) )#, linewidth=8, edgecolor='grey')
# --------------------------------------------------
# Cell 11
# --------------------------------------------------
# initVars_4, target_4 = set_target_init(exc_4, inh_4, max_I, aln, dur)
#
# path4 = path_directory + os.sep + '4'
# print(path4)
#
# try:
#     os.stat(path1)
# except:
#     os.mkdir(path1)
#
# for i in range(len(exc_4)):
#     file_ = str(i)
#     aln.params.mue_ext_mean = exc_4[i] * 5.
#     aln.params.mui_ext_mean = inh_4[i] * 5.
#
#     for j in range(len(ext_exc)):
#         if j in no_c_:
#             print(i, j)
#             if exc_4[i] == ext_exc[j] and inh_4[i] ==  ext_inh[j]:
#                 index_ = j
#                 print(j)
#                 break
#
#     print(np.amin(bestControl_0[index_][0,1,:]), np.amax(bestControl_0[index_][0,1,:]))
#
#     plotFunc.plot_control_current(aln, [bestControl_init[index_], bestControl_0[index_]],
#         [costnode_init[index_], costnode_0[index_]], [[1.,0.,1.], [1.,0.,1.]], dur,
#         dur_pre, dur_post, initVars_4[i], target_4[i], path4, filename_ = file_, transition_time_ = trans_time,
#         labels_ = ["initial guess", "sparse control"], print_cost_=False)
#
#
# D:\Promotion\neurolib\GUI\current\gui\plots_\00011\4
# --------------------------------------------------
# Cell 12
# --------------------------------------------------

# %%
os.chdir('..')
