# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import os
import sys
import pickle
from scipy.optimize import curve_fit

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

import neurolib.dashboard.data as data
from neurolib.models.aln import ALNModel
import neurolib.dashboard.layout as layout
import neurolib.dashboard.functions as functions
from neurolib.utils import plotFunctions as plotFunc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# not here
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
readpath = '..' + os.sep

with open(readpath + os.sep + 'bi.pickle','rb') as file:
    load_array= pickle.load(file)
ext_exc = load_array[0]
ext_inh = load_array[1]

with open(readpath + os.sep + 'bi_granular.pickle','rb') as file:
    load_array= pickle.load(file)
ext_exc_granular = load_array[0]
ext_inh_granular = load_array[1]

with open(readpath + os.sep + 'boundary_bi_granular.pickle','rb') as file:
    load_array= pickle.load(file)
boundary_exc_granular = load_array[0]
boundary_inh_granular = load_array[1]

grid_resolution = layout.grid_resolution
grid_resolution_granular = layout.grid_resolution_granular

dist_up_regime = np.zeros((len(ext_exc), 2))
dist_down_regime = np.zeros((len(ext_exc)))

cmap = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors()
exc_red = cmap(3)
inh_blue=cmap(0)
green = cmap(2)

aln = ALNModel()
data.set_parameters(aln)
state_vars = aln.state_vars

# %%
##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
def derivative(f,a,dt):
    return (f[a+1] - f[a])/dt

def fit_func_lin(x, a, b):
    return a * x + b

def readcase(case_):
    
    global ind_, type_, mu_e, mu_i, a_e, a_i, cost_node, w_e, w_i, target_high, target_low 
    global d_e, d_i, d_total
    global cost_p_x, cost_p_y, cost_s_x, cost_e_x, cost_s_y, cost_e_y
    
    readpath = '..' + os.sep + 'data_final' + os.sep
    
    data_array = data.read_data_1(aln, readpath, case_)
    ind_, type_, mu_e, mu_i, a_e, a_i, cost_node, w_e, w_i, target_high, target_low = data_array
    
    opt_control = [None] * len(ind_)
    opt_state = [None] * len(ind_)
    
    control_data = data.read_control(readpath, case_)
    opt_control = control_data[2]
    opt_state = control_data[3]
        
    d_e = [None] * len(ind_)
    d_i = [None] * len(ind_)
    d_total = [None] * len(ind_)
    
    cost_p_x = [None] * len(ext_exc)
    cost_p_y = [None] * len(ext_exc)
    cost_s_x = [None] * len(ext_exc)
    cost_e_x = [None] * len(ext_exc)
    cost_s_y = [None] * len(ext_exc)
    cost_e_y = [None] * len(ext_exc)
    
    for i in ind_:
        
        if type(opt_control[i]) == type(None):
            continue
    
        if case_ in ['1', '2']:
            d_e[i] = data.dist_right(mu_e[i], mu_i[i], ext_exc_granular, ext_inh_granular, grid_resolution)
            d_i[i] = data.dist_low(mu_e[i], mu_i[i], ext_exc_granular, ext_inh_granular, grid_resolution)
            d_total[i] = data.dist_up_regime(mu_e[i], mu_i[i], boundary_exc_granular, boundary_inh_granular,
                                                   grid_resolution_granular)
        else:
            d_e[i] = data.dist_left(mu_e[i], mu_i[i], ext_exc_granular, ext_inh_granular, grid_resolution)
            d_i[i] = data.dist_up(mu_e[i], mu_i[i], ext_exc_granular, ext_inh_granular, grid_resolution)
            d_total[i] = data.dist_down_regime(mu_e[i], mu_i[i], boundary_exc_granular, boundary_inh_granular,
                                               grid_resolution_granular)

        cost_p_x[i] = cost_node[i][0][0][0]
        cost_s_x[i] = cost_node[i][2][0][0]
        cost_e_x[i] = cost_node[i][1][0][0]
        cost_p_y[i] = cost_node[i][0][0][1]
        cost_s_y[i] = cost_node[i][2][0][1]
        cost_e_y[i] = cost_node[i][1][0][1]

# %%
fig5c, axc = plt.subplots(6,7, constrained_layout=True, figsize = (24,24) )

markersize_ = 8

#########################################
readcase('1')

y_axis = [a_e, a_i, cost_s_x, cost_s_y, w_e, w_i]
x_axis = [mu_e, mu_i, d_e, d_i, d_total, target_high[:,0], target_high[:,1]]

fit_data_y = [[], [], [], [], [], []]
fit_data_x = [[], [], [], [], [], [], []]

fit_data = [[[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]],
            [[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]],
            [[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]],
            [[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]],
            [[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]],
            [[None, None], [None, None], [None, None], [None, None], [None, None], [None, None], [None, None]]]

#fit_data[6][7][2]= 1.

for i in range(len(d_e)):
    break
    if type(a_e[i]) == type(None):
        continue

    if np.abs(a_i[i]) > np.abs(a_e[i]):
        marker_ = 'x'
    else:
        marker_ = 'o'
        
    for x_ in range(len(x_axis)):
        x_data = x_axis[x_][i]
        fit_data_x[x_].append(x_data)
                
    for y_ in range(len(y_axis)):
        
        if y_ in [0,2,4]:
            color_ = exc_red
        else:
            color_ = inh_blue
        
        y_data = np.abs(y_axis[y_][i])
        fit_data_y[y_].append(y_data)
        
        for x_ in range(len(x_axis)):
            x_data = x_axis[x_][i]
        
            axc[y_,x_].plot(x_data, y_data, marker=marker_, color=color_, markersize=markersize_)
        
x_max = [np.amax(x_) for x_ in fit_data_x]
print(x_max)
x_ranges = [np.arange(0., x_max[x_] + 0.1, 0.01) for x_ in range(len(x_max))]

for x_ in range(len(x_axis)):
    for y_ in range(len(y_axis)):
        popt, pcov = curve_fit(fit_func_lin, fit_data_x[x_], fit_data_y[y_])
        fit_data[y_][x_][0] = popt
        fit_data[y_][x_][1] = pcov
        axc[y_,x_].plot(x_ranges[x_], fit_func_lin(x_ranges[x_], fit_data[y_][x_][0], fit_data[y_][x_][0]))
    
axc[-1,0].set_xlabel('Ext exc current')
axc[-1,1].set_xlabel('Ext inh current')
axc[-1,2].set_xlabel('Distance horizontal')
axc[-1,3].set_xlabel('Distance vertical')
axc[-1,4].set_xlabel('Shortest distance')
axc[-1,5].set_xlabel('Exc target rate')
axc[-1,6].set_xlabel('Inh target rate')

axc[0,0].set_ylabel('Ext amplitude')
axc[1,0].set_ylabel('Inh amplitude')
       
plt.savefig( os.path.join(os.getcwd(), 'A_all_1.png') )
plt.show()
# Out:
# case =  ..\data_final 1
# Traceback (most recent call last):
#
#   File "<ipython-input-6-f7bdfd0d8413>", line 6, in <module>
#     readcase('1')
#
#   File "<ipython-input-5-b57e403baaa0>", line 28, in readcase
#     data_array = data.read_data_1(aln, readpath, case_)
#
#   File "D:\Promotion\neurolib\neurolib\dashboard\data.py", line 546, in read_data_1
#     [bestControl_init, costnode_init, bestControl_0, bestState_0, costnode_0] = read_control(readpath, case)
#
#   File "D:\Promotion\neurolib\neurolib\dashboard\data.py", line 669, in read_control
#     with open(readfile,'rb') as file:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\data_final\\control_1_init.pickle'

# %%
fig5c, axc = plt.subplots(2,8, constrained_layout=True, figsize = (40,8) )

markersize_ = 8

#########################################
readcase('3')

for i in range(len(d_e)):
    if type(a_e[i]) == type(None):
        continue

    if np.abs(a_i[i]) > np.abs(a_e[i]):
        marker_ = 'x'
    else:
        marker_ = 'o'
        
    axc[0,0].plot(mu_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,1].plot(mu_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,2].plot(d_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,3].plot(d_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,4].plot(d_total[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,5].plot(target_low[i][0], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,6].plot(target_low[i][1], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)

    axc[1,0].plot(mu_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,1].plot(mu_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,2].plot(d_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,3].plot(d_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,4].plot(d_total[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,5].plot(target_low[i][0], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,6].plot(target_low[i][1], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,7].plot(mu_e[i], mu_i[i], marker=marker_, color=green, markersize=markersize_)
    
axc[1,0].set_xlabel('Ext exc current')
axc[1,1].set_xlabel('Ext inh current')
axc[1,2].set_xlabel('Distance horizontal')
axc[1,3].set_xlabel('Distance vertical')
axc[1,4].set_xlabel('Shortest distance')
axc[1,5].set_xlabel('Exc target rate')
axc[1,6].set_xlabel('Inh target rate')
axc[1,7].set_xlabel('Ext exc current')
axc[1,7].set_ylabel('Ext inh current')
       
plt.savefig( os.path.join(os.getcwd(), 'A_all_3.png') )
plt.show()
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-3-5360dfc69272>", line 6, in <module>
#     readcase('3')
#
# NameError: name 'readcase' is not defined

# %%
fig5c, axc = plt.subplots(3,7, constrained_layout=True, figsize = (40,8) )

markersize_ = 8

#########################################
readcase('2')

for i in range(len(d_e)):
    if type(a_e[i]) == type(None):
        continue

    if np.abs(a_i[i]) > np.abs(a_e[i]):
        marker_ = 'x'
    else:
        marker_ = 'o'
        
    axc[0,0].plot(mu_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,1].plot(mu_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,2].plot(d_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,3].plot(d_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,4].plot(d_total[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,5].plot(target_high[i][0], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,6].plot(target_high[i][1], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)

    axc[1,0].plot(mu_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,1].plot(mu_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,2].plot(d_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,3].plot(d_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,4].plot(d_total[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,5].plot(target_high[i][0], np.abs(a_i[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[1,6].plot(target_high[i][1], np.abs(a_i[i]), marker=marker_, color=exc_red, markersize=markersize_)
    
    axc[2,0].plot(d_total[i], np.abs(a_e[i]) + np.abs(a_i[i]), marker=marker_, color=green, markersize=markersize_)
    axc[2,1].plot(d_total[i], np.sqrt(a_e[i]**2 + a_i[i]**2), marker=marker_, color=green, markersize=markersize_)
    axc[2,2].plot(np.abs(a_i[i]), np.abs(a_e[i]), marker=marker_, color=green, markersize=markersize_)
    axc[2,2].plot(np.arange(0., 0.4, 0.01), np.arange(0., 0.4, 0.01), color=green)
    axc[2,6].plot(mu_e[i], mu_i[i], marker=marker_, color=green, markersize=markersize_)
    
axc[1,0].set_xlabel('Ext exc current')
axc[1,1].set_xlabel('Ext inh current')
axc[1,2].set_xlabel('Distance horizontal')
axc[1,3].set_xlabel('Distance vertical')
axc[1,4].set_xlabel('Shortest distance')
axc[1,5].set_xlabel('Exc target rate')
axc[1,6].set_xlabel('Inh target rate')

axc[2,0].set_xlabel('Shortest distance')
axc[2,1].set_xlabel('Shortest distance')
axc[2,2].set_xlabel('Exc amplitude')
axc[2,2].set_ylabel('Inh amplitude')

axc[2,6].set_xlabel('Ext exc current')
axc[2,6].set_ylabel('Ext inh current')

       
plt.savefig( os.path.join(os.getcwd(), 'A_all_2.png') )
plt.show()
# Out:
# case =  ..\data_final 2
# case =  ..\data_final\ 2

# %%
fig5c, axc = plt.subplots(3,7, constrained_layout=True, figsize = (40,8) )

markersize_ = 8

#########################################
readcase('4')

for i in range(len(d_e)):
    if type(a_e[i]) == type(None):
        continue

    if np.abs(a_i[i]) > np.abs(a_e[i]):
        marker_ = 'x'
    else:
        marker_ = 'o'
        
    axc[0,0].plot(mu_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,1].plot(mu_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,2].plot(d_e[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,3].plot(d_i[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,4].plot(d_total[i], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,5].plot(target_high[i][0], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[0,6].plot(target_high[i][1], np.abs(a_e[i]), marker=marker_, color=exc_red, markersize=markersize_)

    axc[1,0].plot(mu_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,1].plot(mu_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,2].plot(d_e[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,3].plot(d_i[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,4].plot(d_total[i], np.abs(a_i[i]), marker=marker_, color=inh_blue, markersize=markersize_)
    axc[1,5].plot(target_high[i][0], np.abs(a_i[i]), marker=marker_, color=exc_red, markersize=markersize_)
    axc[1,6].plot(target_high[i][1], np.abs(a_i[i]), marker=marker_, color=exc_red, markersize=markersize_)
    
    axc[2,0].plot(d_total[i], np.abs(a_e[i]) + np.abs(a_i[i]), marker=marker_, color=green, markersize=markersize_)
    axc[2,1].plot(d_total[i], np.sqrt(a_e[i]**2 + a_i[i]**2), marker=marker_, color=green, markersize=markersize_)
    axc[2,2].plot(np.abs(a_i[i]), np.abs(a_e[i]), marker=marker_, color=green, markersize=markersize_)
    axc[2,2].plot(np.arange(0., 0.4, 0.01), np.arange(0., 0.4, 0.01), color=green)
    axc[2,6].plot(mu_e[i], mu_i[i], marker=marker_, color=green, markersize=markersize_)
    
axc[1,0].set_xlabel('Ext exc current')
axc[1,1].set_xlabel('Ext inh current')
axc[1,2].set_xlabel('Distance horizontal')
axc[1,3].set_xlabel('Distance vertical')
axc[1,4].set_xlabel('Shortest distance')
axc[1,5].set_xlabel('Exc target rate')
axc[1,6].set_xlabel('Inh target rate')

axc[2,0].set_xlabel('Shortest distance')
axc[2,1].set_xlabel('Shortest distance')
axc[2,2].set_xlabel('Exc amplitude')
axc[2,2].set_ylabel('Inh amplitude')

axc[2,6].set_xlabel('Ext exc current')
axc[2,6].set_ylabel('Ext inh current')

       
plt.savefig( os.path.join(os.getcwd(), 'A_all_4.png') )
plt.show()
# Out:
# case =  ..\data_final 4
# case =  ..\data_final\ 4
