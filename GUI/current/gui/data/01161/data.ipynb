# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /mnt/antares_raid/home/salfenmoser/neurolib/GUI/current/gui/data/01161
# 01161

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 5
i_range = range(0, len(exc),i_stepsize)
i_range_0 = range(0, len(exc),i_stepsize)
i_range_1 = range(0, len(exc),i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  65 0.5000000000000002 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  85 0.47500000000000014 0.7250000000000004
# -------  90 0.6000000000000003 0.7250000000000004
# -------  95 0.5250000000000001 0.7500000000000004
# -------  100 0.4500000000000001 0.7750000000000005
# -------  105 0.5750000000000002 0.7750000000000005
# -------  110 0.5000000000000002 0.8000000000000005
# -------  115 0.4250000000000001 0.8250000000000005
# -------  120 0.5500000000000003 0.8250000000000005
# -------  125 0.47500000000000014 0.8500000000000005
# -------  130 0.6000000000000003 0.8500000000000005
# -------  135 0.5250000000000001 0.8750000000000006
# -------  140 0.4500000000000001 0.9000000000000006
# -------  145 0.5750000000000002 0.9000000000000006

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5902.406479238383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5097.289828199723
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5097.289828199723
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9111.456490210901
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9111.456490210901
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13018.074640346456
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13018.074640346456
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8231.907221468136
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8231.907221468136
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7978.317181785681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7978.317181785681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.428984237715
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30546.428984237715
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25531.477705492594
# Gradient descend method:  None
# RUN  0 , total integrated cost =  25531.477705492594
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20627.907894119795
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20627.907894119795
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7112.913357952089
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7112.913357952089
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29795.639845368863
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29795.639845368863
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20071.115113665277
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20071.115113665277
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11109.049056155947
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11109.049056155947
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34495.8289838114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34495.8289838114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24416.866252081658
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24416.866252081658
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15143.755110304457
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15143.755110304457
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39340.86017947994
# Gradient descend method:  None
# RUN  0 , total integrated cost =  39340.86017947994
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24128.44250261018
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24128.44250261018
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10559.709248318897
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10559.709248318897
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33891.050588370264
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33891.050588370264
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19226.098318201533
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19226.098318201533
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5845.286879790712
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5845.286879790712
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28593.126434517075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28593.126434517075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14547.979043359295
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14547.979043359295
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38727.35641379273
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38727.35641379273
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23532.636143093983
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23532.636143093983
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10019.968518582271
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10019.968518582271
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33290.05146687772
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33290.05146687772
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+2000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 6591.536342783782 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5729.320364911385
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5729.320364911385
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 961.1211028133607 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4988.838840366593
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4988.838840366593
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 1701.3094930891546 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8948.369512368488
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8948.369512368488
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 2613.4865658718863 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12785.851766472553
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12785.851766472553
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1607.1244076142086 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12521.692181243114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12521.692181243114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 528.3606449072894 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8183.923222317029
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8183.923222317029
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 430.5315605320516 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7926.951773793789
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7926.951773793789
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 158449.56708756468 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29538.48566521241
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29538.48566521241
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 9248.749627648707 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25237.79652798794
# Gradient descend method:  None
# RUN  0 , total integrated cost =  25237.79652798794
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 2720.222380527557 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20334.697158145376
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20334.697158145376
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1159.0680416820894 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15800.901980415982
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15800.901980415982
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 256.52303251195593 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7069.506822354974
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7069.506822354974
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 11864.872193670615 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29425.45872678436
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29425.45872678436
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 1817.7874728072686 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19849.770373720912
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19849.770373720912
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 471.9047303968287 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11041.800721678674
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11041.800721678674
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 29300.028597081324 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33969.24055797186
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33969.24055797186
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 3017.2976199367495 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24095.691806152732
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24095.691806152732
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 794.4234628488841 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15040.047006719911
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15040.047006719911
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 222673.4804354825 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  37650.71160043695
# Gradient descend method:  None
# RUN  0 , total integrated cost =  37650.71160043695
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 2601.437468327409 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23842.79227869058
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23842.79227869058
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 383.72217855108795 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10493.209177847735
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10493.209177847735
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 14244.413568842774 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33499.654493952716
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33499.654493952716
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 1261.5616234544436 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19074.853965341583
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19074.853965341583
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 158.58673075534693 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5802.921869124248
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5802.921869124248
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 4525.766629042334 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28224.772668902395
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28224.772668902395
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 649.117965889005 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14463.2600633985
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14463.2600633985
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 44734.67336289173 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38062.32234796718
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38062.32234796718
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 2047.6628629145412 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23292.635744377927
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23292.635744377927
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 327.08095613118826 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9962.419647373761
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9962.419647373761
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 9342.556622474913 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32919.123649967594
# Gradient descend method:  None
# RUN  0 , total integrated cost =  32919.123649967594
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 0
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 5
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 10
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 15
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 20
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 25
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 30
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 35
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 40
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 45
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 50
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 55
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 60
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 65
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 70
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 75
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 80
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 85
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 90
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 95
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 100
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 105
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 110
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 115
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 120
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 125
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 130
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 135
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 140
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 145
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    


    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# found solution for  0
# -------  5 0.4000000000000001 0.40000000000000013
# found solution for  5
# -------  10 0.4250000000000001 0.42500000000000016
# found solution for  10
# -------  15 0.4500000000000001 0.4500000000000002
# found solution for  15
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  25 0.4250000000000001 0.5000000000000002
# found solution for  25
# -------  30 0.4250000000000001 0.5250000000000002
# found solution for  30
# -------  35 0.5500000000000003 0.5250000000000002
# found solution for  35
# -------  40 0.5250000000000001 0.5500000000000003
# found solution for  40
# -------  45 0.5000000000000002 0.5750000000000003
# found solution for  45
# -------  50 0.47500000000000014 0.6000000000000003
# found solution for  50
# -------  55 0.4250000000000001 0.6250000000000003
# found solution for  55
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  65 0.5000000000000002 0.6500000000000004
# found solution for  65
# -------  70 0.4500000000000001 0.6750000000000004
# found solution for  70
# -------  75 0.5750000000000002 0.6750000000000004
# found solution for  75
# -------  80 0.5250000000000001 0.7000000000000004
# found solution for  80
# -------  85 0.47500000000000014 0.7250000000000004
# found solution for  85
# -------  90 0.6000000000000003 0.7250000000000004
# found solution for  90
# -------  95 0.5250000000000001 0.7500000000000004
# found solution for  95
# -------  100 0.4500000000000001 0.7750000000000005
# found solution for  100
# -------  105 0.5750000000000002 0.7750000000000005
# found solution for  105
# -------  110 0.5000000000000002 0.8000000000000005
# found solution for  110
# -------  115 0.4250000000000001 0.8250000000000005
# found solution for  115
# -------  120 0.5500000000000003 0.8250000000000005
# found solution for  120
# -------  125 0.47500000000000014 0.8500000000000005
# found solution for  125
# -------  130 0.6000000000000003 0.8500000000000005
# found solution for  130
# -------  135 0.5250000000000001 0.8750000000000006
# found solution for  135
# -------  140 0.4500000000000001 0.9000000000000006
# found solution for  140
# -------  145 0.5750000000000002 0.9000000000000006
# found solution for  145

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 6
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 6:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  20710.006307941545
# set cost params:  1.0 20710.006307941545 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.121490356614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5902.121490319439
# RUN  2 , total integrated cost =  5902.121480839667
# RUN  3 , total integrated cost =  5902.121473667595
# RUN  4 , total integrated cost =  5902.121473640159
# RUN  5 , total integrated cost =  5902.121473639819
# RUN  6 , total integrated cost =  5902.121473617713
# RUN  7 , total integrated cost =  5902.12146332659
# RUN  8 , total integrated cost =  5902.1214545643315
# RUN  9 , total integrated cost =  5902.121454547708
# RUN  10 , total integrated cost =  5902.121454547416
# RUN  11 , total integrated cost =  5902.121454547385
# RUN  12 , total integrated cost =  5902.12145454732
# RUN  13 , total integrated cost =  5902.12145454711
# RUN  14 , total integrated cost =  5902.121454546322
# RUN  15 , total integrated cost =  5902.121454541893
# RUN  16 , total integrated cost =  5902.121454510819
# RUN  17 , total integrated cost =  5902.121454109972
# RUN  18 , total integrated cost =  5902.121211552477
# RUN  19 , total integrated cost =  5902.120960488048
# RUN  20 , total integrated cost =  5902.120960418508
# RUN  30 , total integrated cost =  5902.12094139277
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  32 , total integrated cost =  5902.120941392766
# Improved over  32  iterations in  21.710738968104124  seconds by  9.301127548155819e-06  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62760864118842 -56.62760875252442
# no convergence
# -------  5 0.4000000000000001 0.40000000000000013
# weight =  2948.2195150551615
# set cost params:  1.0 2948.2195150551615 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5095.561476070564
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5095.561476070564
# Control only changes marginally.
# RUN  1 , total integrated cost =  5095.561476070564
# Improved over  1  iterations in  0.8888383395969868  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62446535280191 -56.62446533161298
# converged for  5
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  3545.9049981970516
# set cost params:  1.0 3545.9049981970516 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9108.88764313281
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9108.887284593697
# RUN  2 , total integrated cost =  9108.887119348194
# RUN  3 , total integrated cost =  9108.88689568384
# RUN  4 , total integrated cost =  9108.886682461323
# RUN  5 , total integrated cost =  9108.886276540674
# RUN  6 , total integrated cost =  9108.886054453445
# RUN  7 , total integrated cost =  9108.885651851351
# RUN  8 , total integrated cost =  9108.885427806677
# RUN  9 , total integrated cost =  9108.885019304396
# RUN  10 , total integrated cost =  9108.884812029053
# RUN  11 , total integrated cost =  9108.884450052012
# RUN  12 , total integrated cost =  9108.884286658496
# RUN  13 , total integrated cost =  9108.884064396505
# RUN  14 , total integrated cost =  9108.883847431067
# RUN  15 , total integrated cost =  9108.883441976946
# RUN  16 , total integrated cost =  9108.883221422135
# RUN  17 , total integrated cost =  9108.882816498563
# RUN  18 , total integrated cost =  9108.882597636699
# RUN  19 , total integrated cost =  9108.882190157334
# RUN  20 , total integrated cost =  9108.881978122283
# RUN  30 , total integrated cost =  9108.878858796541
# RUN  40 , total integrated cost =  9108.875757286067
# RUN  50 , total integrated cost =  9108.872940061025
# RUN  60 , total integrated cost =  9108.870119432138
# RUN  70 , total integrated cost =  9108.867302506744
# RUN  80 , total integrated cost =  9108.864459529828
# RUN  90 , total integrated cost =  9108.861328523457
# RUN  100 , total integrated cost =  9108.858701789639
# RUN  110 , total integrated cost =  9108.855581982423
# RUN  120 , total integrated cost =  9108.852937186512
# RUN  130 , total integrated cost =  9108.84981952941
# RUN  140 , total integrated cost =  9108.847187077696
# RUN  150 , total integrated cost =  9108.844059799292
# RUN  160 , total integrated cost =  9108.84143030536
# RUN  170 , total integrated cost =  9108.838329784146
# RUN  180 , total integrated cost =  9108.835480656624
# RUN  190 , total integrated cost =  9108.833129103059
# RUN  200 , total integrated cost =  9108.830027903341
# RUN  300 , total integrated cost =  9108.801627318968
# RUN  400 , total integrated cost =  9108.772400177406
# RUN  500 , total integrated cost =  9108.743943085976
# RUN  600 , total integrated cost =  9108.715150986543
# RUN  700 , total integrated cost =  9108.686154632633
# RUN  800 , total integrated cost =  9108.65724294199
# RUN  900 , total integrated cost =  9108.627324825005
# RUN  1000 , total integrated cost =  9108.597804719677
# RUN  1100 , total integrated cost =  9108.569078915618
# RUN  1200 , total integrated cost =  9108.539791124642
# RUN  1300 , total integrated cost =  9108.511687004286
# RUN  1400 , total integrated cost =  9108.483454620415
# RUN  1500 , total integrated cost =  9108.454768338168
# RUN  1600 , total integrated cost =  9108.42575369998
# RUN  1700 , total integrated cost =  9108.395872725347
# RUN  1800 , total integrated cost =  9108.366839359687
# RUN  1900 , total integrated cost =  9108.337902884763
# RUN  2000 , total integrated cost =  9108.308043963905
# ERROR:root:Problem in initial value trasfer
# RUN  3000 , total integrated cost =  9108.020703122475
# RUN  3000 , total integrated cost =  9108.020703122475
# Improved over  3000  iterations in  512.013764154166  seconds by  0.009517517882542847  percent.
# Problem in initial value trasfer:  Vmean_exc -56.64650865593297 -56.64650867120435
# no convergence
# -------  15 0.4500000000000001 0.4500000000000002
# weight =  5930.319693683298
# set cost params:  1.0 5930.319693683298 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13015.879837956089
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13015.879829151854
# RUN  2 , total integrated cost =  13015.879822471514
# RUN  3 , total integrated cost =  13015.8798136674
# RUN  4 , total integrated cost =  13015.879806987119
# RUN  5 , total integrated cost =  13015.879798182825
# RUN  6 , total integrated cost =  13015.879791502546
# RUN  7 , total integrated cost =  13015.879782698352
# RUN  8 , total integrated cost =  13015.879776018035
# RUN  9 , total integrated cost =  13015.879767213839
# RUN  10 , total integrated cost =  13015.879760533548
# RUN  11 , total integrated cost =  13015.879751729364
# RUN  12 , total integrated cost =  13015.879745049047
# RUN  13 , total integrated cost =  13015.879736244817
# RUN  14 , total integrated cost =  13015.879729564544
# RUN  15 , total integrated cost =  13015.8797207603
# RUN  16 , total integrated cost =  13015.879714080016
# RUN  17 , total integrated cost =  13015.879705275831
# RUN  18 , total integrated cost =  13015.879698595549
# RUN  19 , total integrated cost =  13015.879689791378
# RUN  20 , total integrated cost =  13015.879683111074
# RUN  30 , total integrated cost =  13015.879605688537
# RUN  40 , total integrated cost =  13015.879528266098
# RUN  50 , total integrated cost =  13015.87945084358
# RUN  60 , total integrated cost =  13015.879373421167
# RUN  70 , total integrated cost =  13015.8792959986
# RUN  80 , total integrated cost =  13015.879218576147
# RUN  90 , total integrated cost =  13015.879141153697
# RUN  100 , total integrated cost =  13015.879063731334
# RUN  110 , total integrated cost =  13015.878986308806
# RUN  120 , total integrated cost =  13015.878908886438
# RUN  130 , total integrated cost =  13015.878831463986
# RUN  140 , total integrated cost =  13015.878754041612
# RUN  150 , total integrated cost =  13015.878676619142
# RUN  160 , total integrated cost =  13015.878599196712
# RUN  170 , total integrated cost =  13015.878521774317
# RUN  180 , total integrated cost =  13015.87844435193
# RUN  190 , total integrated cost =  13015.878366929566
# RUN  200 , total integrated cost =  13015.878289507169
# RUN  300 , total integrated cost =  13015.877515283779
# RUN  400 , total integrated cost =  13015.876741060925
# RUN  500 , total integrated cost =  13015.875966838796
# RUN  600 , total integrated cost =  13015.875192617474
# RUN  700 , total integrated cost =  13015.874418396665
# RUN  800 , total integrated cost =  13015.873644176618
# RUN  900 , total integrated cost =  13015.87286995712
# RUN  1000 , total integrated cost =  13015.8720957383
# RUN  1100 , total integrated cost =  13015.871321520153
# RUN  1200 , total integrated cost =  13015.87054730269
# RUN  1300 , total integrated cost =  13015.8697730859
# RUN  1400 , total integrated cost =  13015.868998869706
# RUN  1500 , total integrated cost =  13015.868224654268
# RUN  1600 , total integrated cost =  13015.867450439377
# RUN  1700 , total integrated cost =  13015.866676225189
# RUN  1800 , total integrated cost =  13015.865902011714
# RUN  1900 , total integrated cost =  13015.865127798863
# RUN  2000 , total integrated cost =  13015.864353586709
# RUN  3000 , total integrated cost =  13015.856611501451
# RUN  3000 , total integrated cost =  13015.856611501451
# Improved over  3000  iterations in  737.2794153392315  seconds by  0.00017844705794800575  percent.
# no convergence
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3009.3528090774653
# set cost params:  1.0 3009.3528090774653 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12733.885013871211
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12733.884998783738
# RUN  2 , total integrated cost =  12733.884978602146
# RUN  3 , total integrated cost =  12733.884963515467
# RUN  4 , total integrated cost =  12733.884943330768
# RUN  5 , total integrated cost =  12733.88492824334
# RUN  6 , total integrated cost =  12733.884908061473
# RUN  7 , total integrated cost =  12733.884892974762
# RUN  8 , total integrated cost =  12733.884872790342
# RUN  9 , total integrated cost =  12733.884857702993
# RUN  10 , total integrated cost =  12733.884837520887
# RUN  11 , total integrated cost =  12733.884822434062
# RUN  12 , total integrated cost =  12733.884802249831
# RUN  13 , total integrated cost =  12733.88478716255
# RUN  14 , total integrated cost =  12733.884766980302
# RUN  15 , total integrated cost =  12733.884751893424
# RUN  16 , total integrated cost =  12733.884731709357
# RUN  17 , total integrated cost =  12733.884716622122
# RUN  18 , total integrated cost =  12733.884696439698
# RUN  19 , total integrated cost =  12733.884681352843
# RUN  20 , total integrated cost =  12733.884661168888
# RUN  30 , total integrated cost =  12733.884484817994
# RUN  40 , total integrated cost =  12733.884308466424
# RUN  50 , total integrated cost =  12733.88413211524
# RUN  60 , total integrated cost =  12733.883955763842
# RUN  70 , total integrated cost =  12733.883779412663
# RUN  80 , total integrated cost =  12733.883603061322
# RUN  90 , total integrated cost =  12733.883426710132
# RUN  100 , total integrated cost =  12733.883250358791
# RUN  110 , total integrated cost =  12733.883074007677
# RUN  120 , total integrated cost =  12733.882897656395
# RUN  130 , total integrated cost =  12733.88272130522
# RUN  140 , total integrated cost =  12733.882544954084
# RUN  150 , total integrated cost =  12733.882368602914
# RUN  160 , total integrated cost =  12733.882192251736
# RUN  170 , total integrated cost =  12733.8820159006
# RUN  180 , total integrated cost =  12733.881839549484
# RUN  190 , total integrated cost =  12733.881663198426
# RUN  200 , total integrated cost =  12733.881486847327
# RUN  300 , total integrated cost =  12733.879723337197
# RUN  400 , total integrated cost =  12733.877959828611
# RUN  500 , total integrated cost =  12733.876196321386
# RUN  600 , total integrated cost =  12733.874432815672
# RUN  700 , total integrated cost =  12733.87266931142
# RUN  800 , total integrated cost =  12733.870905808553
# RUN  900 , total integrated cost =  12733.869142307158
# RUN  1000 , total integrated cost =  12733.867378807268
# RUN  1100 , total integrated cost =  12733.865615308774
# RUN  1200 , total integrated cost =  12733.863851811715
# RUN  1300 , total integrated cost =  12733.86208831619
# RUN  1400 , total integrated cost =  12733.8603248221
# RUN  1500 , total integrated cost =  12733.85856132935
# RUN  1600 , total integrated cost =  12733.85679783825
# RUN  1700 , total integrated cost =  12733.855034348395
# RUN  1800 , total integrated cost =  12733.853270860162
# RUN  1900 , total integrated cost =  12733.851507373252
# RUN  2000 , total integrated cost =  12733.849743887902
# ERROR:root:Problem in initial value trasfer
# RUN  3000 , total integrated cost =  12733.83210911372
# RUN  3000 , total integrated cost =  12733.83210911372
# Improved over  3000  iterations in  602.3423859700561  seconds by  0.00041546438839645816  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66906583352294 -56.66906584602297
# no convergence
# -------  25 0.4250000000000001 0.5000000000000002
# weight =  1038.314699556064
# set cost params:  1.0 1038.314699556064 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8223.986705440275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8223.98667949219
# RUN  2 , total integrated cost =  8223.986655066095
# RUN  3 , total integrated cost =  8223.98662935111
# RUN  4 , total integrated cost =  8223.986604929638
# RUN  5 , total integrated cost =  8223.98657911692
# RUN  6 , total integrated cost =  8223.98655469352
# RUN  7 , total integrated cost =  8223.986528922223
# RUN  8 , total integrated cost =  8223.986504499662
# RUN  9 , total integrated cost =  8223.986478710849
# RUN  10 , total integrated cost =  8223.986454287875
# RUN  11 , total integrated cost =  8223.98642850645
# RUN  12 , total integrated cost =  8223.986404083742
# RUN  13 , total integrated cost =  8223.98637829922
# RUN  14 , total integrated cost =  8223.986353876373
# RUN  15 , total integrated cost =  8223.986328093115
# RUN  16 , total integrated cost =  8223.986303670314
# RUN  17 , total integrated cost =  8223.98627788654
# RUN  18 , total integrated cost =  8223.98625346376
# RUN  19 , total integrated cost =  8223.986227680214
# RUN  20 , total integrated cost =  8223.986203257402
# RUN  30 , total integrated cost =  8223.98595222545
# RUN  40 , total integrated cost =  8223.985701193582
# RUN  50 , total integrated cost =  8223.985450161883
# RUN  60 , total integrated cost =  8223.985199130255
# RUN  70 , total integrated cost =  8223.984948098809
# RUN  80 , total integrated cost =  8223.984697067446
# RUN  90 , total integrated cost =  8223.984446036211
# RUN  100 , total integrated cost =  8223.9841950051
# RUN  110 , total integrated cost =  8223.983943974106
# RUN  120 , total integrated cost =  8223.98369294328
# RUN  130 , total integrated cost =  8223.983441912544
# RUN  140 , total integrated cost =  8223.983190881912
# RUN  150 , total integrated cost =  8223.982939851412
# RUN  160 , total integrated cost =  8223.982688821085
# RUN  170 , total integrated cost =  8223.982437790837
# RUN  180 , total integrated cost =  8223.982186760677
# RUN  190 , total integrated cost =  8223.981935730677
# RUN  200 , total integrated cost =  8223.981684700835
# RUN  300 , total integrated cost =  8223.979174408965
# RUN  400 , total integrated cost =  8223.97666412935
# RUN  500 , total integrated cost =  8223.974153862127
# RUN  600 , total integrated cost =  8223.971643607281
# RUN  700 , total integrated cost =  8223.969133364682
# RUN  800 , total integrated cost =  8223.966623134482
# RUN  900 , total integrated cost =  8223.964112916616
# RUN  1000 , total integrated cost =  8223.961602711068
# RUN  1100 , total integrated cost =  8223.959092517875
# RUN  1200 , total integrated cost =  8223.956582337034
# RUN  1300 , total integrated cost =  8223.954072168495
# RUN  1400 , total integrated cost =  8223.951562012417
# RUN  1500 , total integrated cost =  8223.949051869035
# RUN  1600 , total integrated cost =  8223.946541738538
# RUN  1700 , total integrated cost =  8223.944031620875
# RUN  1800 , total integrated cost =  8223.941521516203
# RUN  1900 , total integrated cost =  8223.93901142424
# RUN  2000 , total integrated cost =  8223.936501345095
# ERROR:root:Problem in initial value trasfer
# RUN  3000 , total integrated cost =  8223.911401230174
# RUN  3000 , total integrated cost =  8223.911401230174
# Improved over  3000  iterations in  835.8219632692635  seconds by  0.0009156655135456049  percent.
# Problem in initial value trasfer:  Vmean_exc -56.63979327136379 -56.63979346486221
# no convergence
# -------  30 0.4250000000000001 0.5250000000000002
# weight =  640.1691805638798
# set cost params:  1.0 640.1691805638798 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7965.873793318646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7965.873781043308
# RUN  2 , total integrated cost =  7965.8737734098295
# RUN  3 , total integrated cost =  7965.873767079372
# RUN  4 , total integrated cost =  7965.87375839387
# RUN  5 , total integrated cost =  7965.873749263462
# RUN  6 , total integrated cost =  7965.873739167003
# RUN  7 , total integrated cost =  7965.8737278206
# RUN  8 , total integrated cost =  7965.873715922684
# RUN  9 , total integrated cost =  7965.873701409915
# RUN  10 , total integrated cost =  7965.873693474706
# RUN  11 , total integrated cost =  7965.873686113088
# RUN  12 , total integrated cost =  7965.87367699378
# RUN  13 , total integrated cost =  7965.873667070877
# RUN  14 , total integrated cost =  7965.873656442014
# RUN  15 , total integrated cost =  7965.873642934125
# RUN  16 , total integrated cost =  7965.873635134416
# RUN  17 , total integrated cost =  7965.873627453824
# RUN  18 , total integrated cost =  7965.873618187705
# RUN  19 , total integrated cost =  7965.873608527173
# RUN  20 , total integrated cost =  7965.87359806706
# RUN  30 , total integrated cost =  7965.873498223145
# RUN  40 , total integrated cost =  7965.873402815405
# RUN  50 , total integrated cost =  7965.87330297153
# RUN  60 , total integrated cost =  7965.873207563943
# RUN  70 , total integrated cost =  7965.873107720062
# RUN  80 , total integrated cost =  7965.873012312476
# RUN  90 , total integrated cost =  7965.872912468637
# RUN  100 , total integrated cost =  7965.8728170611
# RUN  110 , total integrated cost =  7965.8727172173085
# RUN  120 , total integrated cost =  7965.87262180975
# RUN  130 , total integrated cost =  7965.872521966023
# RUN  140 , total integrated cost =  7965.872426558543
# RUN  150 , total integrated cost =  7965.872326714831
# RUN  160 , total integrated cost =  7965.872231307357
# RUN  170 , total integrated cost =  7965.872131463719
# RUN  180 , total integrated cost =  7965.872036056188
# RUN  190 , total integrated cost =  7965.871936212659
# RUN  200 , total integrated cost =  7965.87184080524
# RUN  300 , total integrated cost =  7965.870864551082
# RUN  400 , total integrated cost =  7965.869888298654
# RUN  500 , total integrated cost =  7965.868912048014
# RUN  600 , total integrated cost =  7965.867935799126
# RUN  700 , total integrated cost =  7965.866959551917
# RUN  800 , total integrated cost =  7965.865983306552
# RUN  900 , total integrated cost =  7965.865007062858
# RUN  1000 , total integrated cost =  7965.8640308209215
# RUN  1100 , total integrated cost =  7965.8630545807
# RUN  1200 , total integrated cost =  7965.862078342261
# RUN  1300 , total integrated cost =  7965.861102105509
# RUN  1400 , total integrated cost =  7965.860125870545
# RUN  1500 , total integrated cost =  7965.859149637344
# RUN  1600 , total integrated cost =  7965.858173405892
# RUN  1700 , total integrated cost =  7965.857197176077
# RUN  1800 , total integrated cost =  7965.856220948107
# RUN  1900 , total integrated cost =  7965.855244721836
# RUN  2000 , total integrated cost =  7965.854268497306
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  30546.357416505543
# State only changes marginally.
# RUN  2 , total integrated cost =  30546.357416505543
# Control only changes marginally.
# RUN  2 , total integrated cost =  30546.357416505543
# Improved over  2  iterations in  2.087760094553232  seconds by  1.4210854715202004e-14  percent.
# no convergence
# -------  40 0.5250000000000001 0.5500000000000003
# weight =  12578.97163669188
# set cost params:  1.0 12578.97163669188 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25529.44817168732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25529.44817131609
# RUN  2 , total integrated cost =  25529.448170960008
# RUN  3 , total integrated cost =  25529.448170581272
# RUN  4 , total integrated cost =  25529.448170232034
# RUN  5 , total integrated cost =  25529.44816985096
# RUN  6 , total integrated cost =  25529.448169498995
# RUN  7 , total integrated cost =  25529.448169122752
# RUN  8 , total integrated cost =  25529.44816877124
# RUN  9 , total integrated cost =  25529.448168390976
# RUN  10 , total integrated cost =  25529.448168040388
# RUN  11 , total integrated cost =  25529.44816766183
# RUN  12 , total integrated cost =  25529.44816731846
# RUN  13 , total integrated cost =  25529.448166931474
# RUN  14 , total integrated cost =  25529.448166592447
# RUN  15 , total integrated cost =  25529.448166209193
# RUN  16 , total integrated cost =  25529.448165861297
# RUN  17 , total integrated cost =  25529.4481654832
# RUN  18 , total integrated cost =  25529.448165139802
# RUN  19 , total integrated cost =  25529.448164752583
# RUN  20 , total integrated cost =  25529.448164404006
# RUN  30 , total integrated cost =  25529.448160761927
# RUN  40 , total integrated cost =  25529.448157125556
# RUN  50 , total integrated cost =  25529.44815347674
# RUN  60 , total integrated cost =  25529.448149838754
# RUN  70 , total integrated cost =  25529.448146211984
# RUN  80 , total integrated cost =  25529.448142754896
# RUN  90 , total integrated cost =  25529.448139399065
# RUN  100 , total integrated cost =  25529.448135933355
# RUN  110 , total integrated cost =  25529.448132281028
# RUN  120 , total integrated cost =  25529.448128644533
# RUN  130 , total integrated cost =  25529.448124992967
# RUN  140 , total integrated cost =  25529.448121358117
# RUN  150 , total integrated cost =  25529.44811771676
# RUN  160 , total integrated cost =  25529.44811408369
# RUN  170 , total integrated cost =  25529.44811044394
# RUN  180 , total integrated cost =  25529.44810679293
# RUN  190 , total integrated cost =  25529.448103167713
# RUN  200 , total integrated cost =  25529.448099534635
# RUN  300 , total integrated cost =  25529.44806381004
# RUN  400 , total integrated cost =  25529.448027440663
# RUN  500 , total integrated cost =  25529.44799105481
# RUN  600 , total integrated cost =  25529.447954649
# RUN  700 , total integrated cost =  25529.44791823362
# RUN  800 , total integrated cost =  25529.44788194715
# RUN  900 , total integrated cost =  25529.447845573548
# RUN  1000 , total integrated cost =  25529.44780917678
# RUN  1100 , total integrated cost =  25529.447774180917
# RUN  1200 , total integrated cost =  25529.44773880518
# RUN  1300 , total integrated cost =  25529.447702413963
# RUN  1400 , total integrated cost =  25529.447666031356
# RUN  1500 , total integrated cost =  25529.447631064057
# RUN  1600 , total integrated cost =  25529.447594672023
# RUN  1700 , total integrated cost =  25529.44755825424
# RUN  1800 , total integrated cost =  25529.44752186208
# RUN  1900 , total integrated cost =  25529.447485473564
# RUN  2000 , total integrated cost =  25529.447449759336
# RUN  3000 , total integrated cost =  25529.44708818302
# RUN  3000 , total integrated cost =  25529.44708818302
# Improved over  3000  iterations in  886.8573753442615  seconds by  4.244135212161382e-06  percent.
# no convergence
# -------  45 0.5000000000000002 0.5750000000000003
# weight =  3584.118923681099
# set cost params:  1.0 3584.118923681099 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20622.154135783385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20622.154135637305
# RUN  2 , total integrated cost =  20622.15413549232
# RUN  3 , total integrated cost =  20622.154135350767
# RUN  4 , total integrated cost =  20622.15413520944
# RUN  5 , total integrated cost =  20622.154135062072
# RUN  6 , total integrated cost =  20622.15413491738
# RUN  7 , total integrated cost =  20622.154134776174
# RUN  8 , total integrated cost =  20622.15413463241
# RUN  9 , total integrated cost =  20622.154134487366
# RUN  10 , total integrated cost =  20622.154134342058
# RUN  11 , total integrated cost =  20622.154134200253
# RUN  12 , total integrated cost =  20622.154134056163
# RUN  13 , total integrated cost =  20622.15413391172
# RUN  14 , total integrated cost =  20622.15413376585
# RUN  15 , total integrated cost =  20622.154133624394
# RUN  16 , total integrated cost =  20622.154133481938
# RUN  17 , total integrated cost =  20622.154133335636
# RUN  18 , total integrated cost =  20622.15413319073
# RUN  19 , total integrated cost =  20622.15413304919
# RUN  20 , total integrated cost =  20622.154132905755
# RUN  30 , total integrated cost =  20622.154131471092
# RUN  40 , total integrated cost =  20622.154130035193
# RUN  50 , total integrated cost =  20622.15412859287
# RUN  60 , total integrated cost =  20622.154127158232
# RUN  70 , total integrated cost =  20622.154125720484
# RUN  80 , total integrated cost =  20622.15412428479
# RUN  90 , total integrated cost =  20622.154122845757
# RUN  100 , total integrated cost =  20622.15412141196
# RUN  110 , total integrated cost =  20622.154119974526
# RUN  120 , total integrated cost =  20622.154118539125
# RUN  130 , total integrated cost =  20622.154117095
# RUN  140 , total integrated cost =  20622.15411566109
# RUN  150 , total integrated cost =  20622.154114225053
# RUN  160 , total integrated cost =  20622.15411278989
# RUN  170 , total integrated cost =  20622.154111352273
# RUN  180 , total integrated cost =  20622.154109913154
# RUN  190 , total integrated cost =  20622.154108478866
# RUN  200 , total integrated cost =  20622.154107043665
# RUN  300 , total integrated cost =  20622.154092673147
# RUN  400 , total integrated cost =  20622.154078308242
# RUN  500 , total integrated cost =  20622.154063944592
# RUN  600 , total integrated cost =  20622.154049581146
# RUN  700 , total integrated cost =  20622.15403520425
# RUN  800 , total integrated cost =  20622.154020840255
# RUN  900 , total integrated cost =  20622.154006476292
# RUN  1000 , total integrated cost =  20622.15399210873
# RUN  1100 , total integrated cost =  20622.153977742495
# RUN  1200 , total integrated cost =  20622.1539633717
# RUN  1300 , total integrated cost =  20622.153949012325
# RUN  1400 , total integrated cost =  20622.15393465115
# RUN  1500 , total integrated cost =  20622.153920283847
# RUN  1600 , total integrated cost =  20622.153905920575
# RUN  1700 , total integrated cost =  20622.153891554804
# RUN  1800 , total integrated cost =  20622.153877184475
# RUN  1900 , total integrated cost =  20622.153862822477
# RUN  2000 , total integrated cost =  20622.15384845441
# RUN  3000 , total integrated cost =  20622.15370474175
# RUN  3000 , total integrated cost =  20622.15370474175
# Improved over  3000  iterations in  715.2835623081774  seconds by  2.090187237513419e-06  percent.
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  1442.733190978394
# set cost params:  1.0 1442.733190978394 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15931.912567811323
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15931.912567706962
# RUN  2 , total integrated cost =  15931.912567600342
# RUN  3 , total integrated cost =  15931.912567473284
# RUN  4 , total integrated cost =  15931.912567369767
# RUN  5 , total integrated cost =  15931.912567249648
# RUN  6 , total integrated cost =  15931.91256714872
# RUN  7 , total integrated cost =  15931.912567047673
# RUN  8 , total integrated cost =  15931.912566944997
# RUN  9 , total integrated cost =  15931.912566838171
# RUN  10 , total integrated cost =  15931.912566734809
# RUN  11 , total integrated cost =  15931.912566630286
# RUN  12 , total integrated cost =  15931.912566524834
# RUN  13 , total integrated cost =  15931.912566396753
# RUN  14 , total integrated cost =  15931.912566295561
# RUN  15 , total integrated cost =  15931.912566198489
# RUN  16 , total integrated cost =  15931.912566097077
# RUN  17 , total integrated cost =  15931.912565986671
# RUN  18 , total integrated cost =  15931.912565884073
# RUN  19 , total integrated cost =  15931.912565780549
# RUN  20 , total integrated cost =  15931.912565675106
# RUN  30 , total integrated cost =  15931.912564512024
# RUN  40 , total integrated cost =  15931.912563218686
# RUN  50 , total integrated cost =  15931.91256216185
# RUN  60 , total integrated cost =  15931.912560806668
# RUN  70 , total integrated cost =  15931.912559508602
# RUN  80 , total integrated cost =  15931.912558387025
# RUN  90 , total integrated cost =  15931.912557036276
# RUN  100 , total integrated cost =  15931.912555733115
# RUN  110 , total integrated cost =  15931.912554420738
# RUN  120 , total integrated cost =  15931.912553365424
# RUN  130 , total integrated cost =  15931.912552305961
# RUN  140 , total integrated cost =  15931.91255096642
# RUN  150 , total integrated cost =  15931.912549881445
# RUN  160 , total integrated cost =  15931.912548535462
# RUN  170 , total integrated cost =  15931.912547254862
# RUN  180 , total integrated cost =  15931.91254619542
# RUN  190 , total integrated cost =  15931.91254507321
# RUN  200 , total integrated cost =  15931.912543713268
# RUN  300 , total integrated cost =  15931.912531446611
# RUN  400 , total integrated cost =  15931.912519193773
# RUN  500 , total integrated cost =  15931.91250693782
# RUN  600 , total integrated cost =  15931.912494685655
# RUN  700 , total integrated cost =  15931.912482137379
# RUN  800 , total integrated cost =  15931.912469951658
# RUN  900 , total integrated cost =  15931.912457494464
# RUN  1000 , total integrated cost =  15931.912444487378
# RUN  1100 , total integrated cost =  15931.912431712155
# RUN  1200 , total integrated cost =  15931.912419084336
# RUN  1300 , total integrated cost =  15931.912406426183
# RUN  1400 , total integrated cost =  15931.91239432992
# RUN  1500 , total integrated cost =  15931.91238189736
# RUN  1600 , total integrated cost =  15931.912369886342
# RUN  1700 , total integrated cost =  15931.912357110534
# RUN  1800 , total integrated cost =  15931.912344597777
# RUN  1900 , total integrated cost =  15931.912331074096
# RUN  2000 , total integrated cost =  15931.912318385592
# RUN  3000 , total integrated cost =  15931.912192496382
# RUN  3000 , total integrated cost =  15931.912192496382
# Improved over  3000  iterations in  847.8854325525463  seconds by  2.3557431632070802e-06  percent.
# no convergence
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  289.95620381862847
# set cost params:  1.0 289.95620381862847 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7088.466677439375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7088.466677439364
# RUN  2 , total integrated cost =  7088.466677439361
# ERROR:root:Problem in initial value trasfer
# RUN  3 , total integrated cost =  7088.466677439361
# Control only changes marginally.
# RUN  3 , total integrated cost =  7088.466677439361
# Improved over  3  iterations in  2.6061907950788736  seconds by  1.9895196601282805e-13  percent.
# Problem in initial value trasfer:  Vmean_exc -56.63165907893726 -56.63165808116424
# no convergence
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  14693.12333781106
# set cost params:  1.0 14693.12333781106 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29793.612120463396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29793.61212004699
# RUN  2 , total integrated cost =  29793.612117468874
# RUN  3 , total integrated cost =  29793.612116550135
# RUN  4 , total integrated cost =  29793.612116134078
# RUN  5 , total integrated cost =  29793.61211355836
# RUN  6 , total integrated cost =  29793.612112635798
# RUN  7 , total integrated cost =  29793.612112220682
# RUN  8 , total integrated cost =  29793.612109649668
# RUN  9 , total integrated cost =  29793.612108720088
# RUN  10 , total integrated cost =  29793.612108307683
# RUN  11 , total integrated cost =  29793.612105753302
# RUN  12 , total integrated cost =  29793.61210479879
# RUN  13 , total integrated cost =  29793.612104398348
# RUN  14 , total integrated cost =  29793.61210188973
# RUN  15 , total integrated cost =  29793.612100863007
# RUN  16 , total integrated cost =  29793.612100483104
# RUN  17 , total integrated cost =  29793.612097313715
# RUN  18 , total integrated cost =  29793.612095674012
# RUN  19 , total integrated cost =  29793.612095287972
# RUN  20 , total integrated cost =  29793.612092062438
# RUN  30 , total integrated cost =  29793.612077435868
# RUN  40 , total integrated cost =  29793.612066465586
# RUN  50 , total integrated cost =  29793.61205214067
# RUN  60 , total integrated cost =  29793.612040147113
# RUN  70 , total integrated cost =  29793.61202813154
# RUN  80 , total integrated cost =  29793.612011912766
# RUN  90 , total integrated cost =  29793.611999586556
# RUN  100 , total integrated cost =  29793.611987569424
# RUN  110 , total integrated cost =  29793.611973247855
# RUN  120 , total integrated cost =  29793.6119607285
# RUN  130 , total integrated cost =  29793.61194923341
# RUN  140 , total integrated cost =  29793.611933083383
# RUN  150 , total integrated cost =  29793.611912959575
# RUN  160 , total integrated cost =  29793.611899535772
# RUN  170 , total integrated cost =  29793.611872349065
# RUN  180 , total integrated cost =  29793.611858472494
# RUN  190 , total integrated cost =  29793.611846816802
# RUN  200 , total integrated cost =  29793.611833057075
# RUN  300 , total integrated cost =  29793.611691079717
# RUN  400 , total integrated cost =  29793.61156462159
# RUN  500 , total integrated cost =  29793.61143397411
# RUN  600 , total integrated cost =  29793.611306986462
# RUN  700 , total integrated cost =  29793.61117292868
# RUN  800 , total integrated cost =  29793.611040935328
# RUN  900 , total integrated cost =  29793.61091210124
# RUN  1000 , total integrated cost =  29793.61078645004
# RUN  1100 , total integrated cost =  29793.61065722096
# RUN  1200 , total integrated cost =  29793.610518706988
# RUN  1300 , total integrated cost =  29793.610386682914
# RUN  1400 , total integrated cost =  29793.61007644821
# RUN  1500 , total integrated cost =  29793.6099473729
# RUN  1600 , total integrated cost =  29793.6098031499
# RUN  1700 , total integrated cost =  29793.609674852487
# RUN  1800 , total integrated cost =  29793.609539357258
# RUN  1900 , total integrated cost =  29793.60941189572
# RUN  2000 , total integrated cost =  29793.609260964535
# RUN  3000 , total integrated cost =  29793.607935627362
# RUN  3000 , total integrated cost =  29793.607935627362
# Improved over  3000  iterations in  736.5811066105962  seconds by  1.4046084842789242e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  2126.8800901177115
# set cost params:  1.0 2126.8800901177115 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20061.68266716283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20061.68266716283
# Control only changes marginally.
# RUN  1 , total integrated cost =  20061.68266716283
# Improved over  1  iterations in  0.9734699875116348  seconds by  0.0  percent.
# no convergence
# -------  70 0.4500000000000001 0.6750000000000004
# weight =  515.1667746512643
# set cost params:  1.0 515.1667746512643 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11087.526847440187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11087.52684679233
# RUN  2 , total integrated cost =  11087.526846133866
# RUN  3 , total integrated cost =  11087.526845480912
# RUN  4 , total integrated cost =  11087.526844823034
# RUN  5 , total integrated cost =  11087.526844171316
# RUN  6 , total integrated cost =  11087.52684351329
# RUN  7 , total integrated cost =  11087.526842861287
# RUN  8 , total integrated cost =  11087.526842209252
# RUN  9 , total integrated cost =  11087.526841551835
# RUN  10 , total integrated cost =  11087.526840894405
# RUN  11 , total integrated cost =  11087.52684024384
# RUN  12 , total integrated cost =  11087.526839585691
# RUN  13 , total integrated cost =  11087.526838933405
# RUN  14 , total integrated cost =  11087.526838275468
# RUN  15 , total integrated cost =  11087.526837623576
# RUN  16 , total integrated cost =  11087.52683697151
# RUN  17 , total integrated cost =  11087.526836314091
# RUN  18 , total integrated cost =  11087.526835662657
# RUN  19 , total integrated cost =  11087.52683500657
# RUN  20 , total integrated cost =  11087.52683434904
# RUN  30 , total integrated cost =  11087.526827797748
# RUN  40 , total integrated cost =  11087.526821253332
# RUN  50 , total integrated cost =  11087.52681470257
# RUN  60 , total integrated cost =  11087.52680814695
# RUN  70 , total integrated cost =  11087.526801609047
# RUN  80 , total integrated cost =  11087.526795057482
# RUN  90 , total integrated cost =  11087.526788497606
# RUN  100 , total integrated cost =  11087.52678194203
# RUN  110 , total integrated cost =  11087.526775394086
# RUN  120 , total integrated cost =  11087.526768844378
# RUN  130 , total integrated cost =  11087.526762291838
# RUN  140 , total integrated cost =  11087.526755741057
# RUN  150 , total integrated cost =  11087.5267492023
# RUN  160 , total integrated cost =  11087.52674264268
# RUN  170 , total integrated cost =  11087.526736102142
# RUN  180 , total integrated cost =  11087.526729550169
# RUN  190 , total integrated cost =  11087.526723000392
# RUN  200 , total integrated cost =  11087.526716452721
# RUN  300 , total integrated cost =  11087.526650956768
# RUN  400 , total integrated cost =  11087.526585463944
# RUN  500 , total integrated cost =  11087.526519968864
# RUN  600 , total integrated cost =  11087.526454462231

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
