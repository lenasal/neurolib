# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read case
print(os.getcwd())
case = '00131'
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\shift_init\2

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\00100\control_init_00100.pickle

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = [20, 35, 50, 65, 80]
i_range_0 = i_range
i_range_1 = i_range
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.428984237715
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30546.428984237715
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20071.115113665277
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20071.115113665277
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24416.866252081658
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24416.866252081658
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur
shift = 1000

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+shift:n_pre-1+shift+1000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]       
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])
        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 3213.823272271244
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12651.532648493376
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12651.532648493376
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 48505.092678435896
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30102.525587085234
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30102.525587085234
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 2977.1926200199127
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15854.506476970046
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15854.506476970046
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 4351.887908205495
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20034.163780574632
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20034.163780574632
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 6087.151357816494
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24294.61194855922
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24294.61194855922
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 20
# --------- 35
# --------- 50
# --------- 65
# --------- 80

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    

    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  35 0.5500000000000003 0.5250000000000002
# found solution for  35
# -------  50 0.47500000000000014 0.6000000000000003
# found solution for  50
# -------  65 0.5000000000000002 0.6500000000000004
# found solution for  65
# -------  80 0.5250000000000001 0.7000000000000004
# found solution for  80

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False
i_stepsize = 5

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3410.7564192910354
# set cost params:  1.0 0.0 3410.7564192910354
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.38285534689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.38285534689
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.38285534689
# Improved over  1  iterations in  0.5285038000001805  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# weight =  74075.79652354539
# set cost params:  1.0 0.0 74075.79652354539
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.016622601983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30546.016622601983
# Control only changes marginally.
# RUN  1 , total integrated cost =  30546.016622601983
# Improved over  1  iterations in  0.6611890999993193  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0309723467863
# set cost params:  1.0 0.0 3174.0309723467863
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.937912721998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.93791200108
# RUN  2 , total integrated cost =  15937.937911864854
# RUN  3 , total integrated cost =  15937.937911622821
# RUN  4 , total integrated cost =  15937.93791155806
# RUN  5 , total integrated cost =  15937.937910799546
# RUN  6 , total integrated cost =  15937.937910075569
# RUN  7 , total integrated cost =  15937.93790994112
# RUN  8 , total integrated cost =  15937.937909720109
# RUN  9 , total integrated cost =  15937.937909652672
# RUN  10 , total integrated cost =  15937.937908891077
# RUN  11 , total integrated cost =  15937.93790817022
# RUN  12 , total integrated cost =  15937.937908033964
# RUN  13 , total integrated cost =  15937.937907791971
# RUN  14 , total integrated cost =  15937.937907727195
# RUN  15 , total integrated cost =  15937.937906968567
# RUN  16 , total integrated cost =  15937.9379062447
# RUN  17 , total integrated cost =  15937.937906110197
# RUN  18 , total integrated cost =  15937.93790588923
# RUN  19 , total integrated cost =  15937.937905821815
# RUN  20 , total integrated cost =  15937.93790506037
# RUN  30 , total integrated cost =  15937.937901229316
# RUN  40 , total integrated cost =  15937.93789739868
# RUN  50 , total integrated cost =  15937.937893567685
# RUN  60 , total integrated cost =  15937.93788973692
# RUN  70 , total integrated cost =  15937.937885906016
# RUN  80 , total integrated cost =  15937.937882075183
# RUN  90 , total integrated cost =  15937.937878244318
# RUN  100 , total integrated cost =  15937.937874413485
# RUN  110 , total integrated cost =  15937.937870582624
# RUN  120 , total integrated cost =  15937.937866751729
# RUN  130 , total integrated cost =  15937.937862920966
# RUN  140 , total integrated cost =  15937.937859090029
# RUN  150 , total integrated cost =  15937.937855259237
# RUN  160 , total integrated cost =  15937.93785142835
# RUN  170 , total integrated cost =  15937.937847597734
# RUN  180 , total integrated cost =  15937.93784376653
# RUN  190 , total integrated cost =  15937.937839936056
# RUN  200 , total integrated cost =  15937.937836104838
# RUN  300 , total integrated cost =  15937.937797796627
# RUN  400 , total integrated cost =  15937.93775948813
# RUN  500 , total integrated cost =  15937.937721179806
# RUN  600 , total integrated cost =  15937.937682871494
# RUN  700 , total integrated cost =  15937.937644563122
# RUN  800 , total integrated cost =  15937.937606254878
# RUN  900 , total integrated cost =  15937.93756794654
# RUN  1000 , total integrated cost =  15937.937529638339
# RUN  1100 , total integrated cost =  15937.937491330184
# RUN  1200 , total integrated cost =  15937.937453022103
# RUN  1300 , total integrated cost =  15937.937414713917
# RUN  1400 , total integrated cost =  15937.937376405833
# RUN  1500 , total integrated cost =  15937.937338097727
# RUN  1600 , total integrated cost =  15937.93729978975
# RUN  1700 , total integrated cost =  15937.93726148173
# RUN  1800 , total integrated cost =  15937.937223173783
# RUN  1900 , total integrated cost =  15937.937184865901
# RUN  2000 , total integrated cost =  15937.937146557962
# RUN  3000 , total integrated cost =  15937.936763480795
# RUN  4000 , total integrated cost =  15937.936380406929
# RUN  5000 , total integrated cost =  15937.935997336192
# RUN  6000 , total integrated cost =  15937.935614268737
# RUN  7000 , total integrated cost =  15937.93523120449
# RUN  8000 , total integrated cost =  15937.934848143426
# RUN  9000 , total integrated cost =  15937.934465085571
# RUN  10000 , total integrated cost =  15937.934082031006
# RUN  10000 , total integrated cost =  15937.934082031006
# Improved over  10000  iterations in  3822.3510596999986  seconds by  2.4035047772485996e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  4498.272682704817
# set cost params:  1.0 0.0 4498.272682704817
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20066.654144853404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20066.654144853404
# Control only changes marginally.
# RUN  1 , total integrated cost =  20066.654144853404
# Improved over  1  iterations in  0.9409305000008317  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  6453.216552546937
# set cost params:  1.0 0.0 6453.216552546937
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24413.08316453675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24413.08316453675
# Control only changes marginally.
# RUN  1 , total integrated cost =  24413.08316453675
# Improved over  1  iterations in  0.8897184999950696  seconds by  0.0  percent.
# converged for  80
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3410.7564192910354
# set cost params:  1.0 0.0 3410.7564192910354
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.38285534689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.38285534689
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.38285534689
# Improved over  1  iterations in  0.8858382000034908  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# weight =  74075.79652354539
# set cost params:  1.0 0.0 74075.79652354539
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.016622601983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30546.016622601983
# Control only changes marginally.
# RUN  1 , total integrated cost =  30546.016622601983
# Improved over  1  iterations in  0.9538038000027882  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0309722951533
# set cost params:  1.0 0.0 3174.0309722951533
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934081771738
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934081050407
# RUN  2 , total integrated cost =  15937.93408091436
# RUN  3 , total integrated cost =  15937.934080672194
# RUN  4 , total integrated cost =  15937.934080607414
# RUN  5 , total integrated cost =  15937.93407985024
# RUN  6 , total integrated cost =  15937.934079125038
# RUN  7 , total integrated cost =  15937.934078991015
# RUN  8 , total integrated cost =  15937.934078769747
# RUN  9 , total integrated cost =  15937.934078702174
# RUN  10 , total integrated cost =  15937.934077941249
# RUN  11 , total integrated cost =  15937.934077219863
# RUN  12 , total integrated cost =  15937.934077083804
# RUN  13 , total integrated cost =  15937.93407684166
# RUN  14 , total integrated cost =  15937.93407677691
# RUN  15 , total integrated cost =  15937.934076019768
# RUN  16 , total integrated cost =  15937.93407529451
# RUN  17 , total integrated cost =  15937.934075160503
# RUN  18 , total integrated cost =  15937.934074939232
# RUN  19 , total integrated cost =  15937.934074871657
# RUN  20 , total integrated cost =  15937.93407411062
# RUN  30 , total integrated cost =  15937.934070280151
# RUN  40 , total integrated cost =  15937.934066449674
# RUN  50 , total integrated cost =  15937.934062619066
# RUN  60 , total integrated cost =  15937.934058788618
# RUN  70 , total integrated cost =  15937.934054957988
# RUN  80 , total integrated cost =  15937.934051127622
# RUN  90 , total integrated cost =  15937.934047296942
# RUN  100 , total integrated cost =  15937.934043466468
# RUN  110 , total integrated cost =  15937.934039635853
# RUN  120 , total integrated cost =  15937.934035805461
# RUN  130 , total integrated cost =  15937.934031974884
# RUN  140 , total integrated cost =  15937.934028144395
# RUN  150 , total integrated cost =  15937.934024313841
# RUN  160 , total integrated cost =  15937.934020483313
# RUN  170 , total integrated cost =  15937.934016652745
# RUN  180 , total integrated cost =  15937.934012822281
# RUN  190 , total integrated cost =  15937.9340089917
# RUN  200 , total integrated cost =  15937.934005161176
# RUN  300 , total integrated cost =  15937.933966856022
# RUN  400 , total integrated cost =  15937.933928550809
# RUN  500 , total integrated cost =  15937.933890245657
# RUN  600 , total integrated cost =  15937.933851940546
# RUN  700 , total integrated cost =  15937.93381363545
# RUN  800 , total integrated cost =  15937.933775330372
# RUN  900 , total integrated cost =  15937.933737025405
# RUN  1000 , total integrated cost =  15937.933698720353
# RUN  1100 , total integrated cost =  15937.933660415363
# RUN  1200 , total integrated cost =  15937.933622110526
# RUN  1300 , total integrated cost =  15937.933583805652
# RUN  1400 , total integrated cost =  15937.933545500737
# RUN  1500 , total integrated cost =  15937.933507195865
# RUN  1600 , total integrated cost =  15937.933468891071
# RUN  1700 , total integrated cost =  15937.933430586323
# RUN  1800 , total integrated cost =  15937.933392281533
# RUN  1900 , total integrated cost =  15937.933353976898
# RUN  2000 , total integrated cost =  15937.933315672253
# RUN  3000 , total integrated cost =  15937.93293262723
# RUN  4000 , total integrated cost =  15937.932549585617
# RUN  5000 , total integrated cost =  15937.932166547174
# RUN  6000 , total integrated cost =  15937.931783511844
# RUN  7000 , total integrated cost =  15937.931400520098
# RUN  8000 , total integrated cost =  15937.931017591853
# RUN  9000 , total integrated cost =  15937.930634807171
# RUN  10000 , total integrated cost =  15937.930251966525
# RUN  10000 , total integrated cost =  15937.930251966525
# Improved over  10000  iterations in  3395.3811092999968  seconds by  2.402949587576586e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  4498.272682704817
# set cost params:  1.0 0.0 4498.272682704817
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20066.654144853404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20066.654144853404
# Control only changes marginally.
# RUN  1 , total integrated cost =  20066.654144853404
# Improved over  1  iterations in  0.47260730000562035  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  6453.216552546937
# set cost params:  1.0 0.0 6453.216552546937
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24413.08316453675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24413.08316453675
# Control only changes marginally.
# RUN  1 , total integrated cost =  24413.08316453675
# Improved over  1  iterations in  0.4731247000017902  seconds by  0.0  percent.
# converged for  80
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.031735239274
# set cost params:  1.0 0.0 3174.031735239274
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934082978347
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.93408225658
# RUN  2 , total integrated cost =  15937.934082120684
# RUN  3 , total integrated cost =  15937.934081878422
# RUN  4 , total integrated cost =  15937.934081813637
# RUN  5 , total integrated cost =  15937.934081057887
# RUN  6 , total integrated cost =  15937.93408033137
# RUN  7 , total integrated cost =  15937.9340801978
# RUN  8 , total integrated cost =  15937.934079976247
# RUN  9 , total integrated cost =  15937.934079908548
# RUN  10 , total integrated cost =  15937.934079148115
# RUN  11 , total integrated cost =  15937.93407842637
# RUN  12 , total integrated cost =  15937.93407829045
# RUN  13 , total integrated cost =  15937.93407804822
# RUN  14 , total integrated cost =  15937.934077983433
# RUN  15 , total integrated cost =  15937.934077227635
# RUN  16 , total integrated cost =  15937.934076501151
# RUN  17 , total integrated cost =  15937.934076367572
# RUN  18 , total integrated cost =  15937.93407614604
# RUN  19 , total integrated cost =  15937.934076078349
# RUN  20 , total integrated cost =  15937.934075317966
# RUN  30 , total integrated cost =  15937.934071507147
# RUN  40 , total integrated cost =  15937.934067677988
# RUN  50 , total integrated cost =  15937.934063867151
# RUN  60 , total integrated cost =  15937.934060037598
# RUN  70 , total integrated cost =  15937.934056226704
# RUN  80 , total integrated cost =  15937.934052397295
# RUN  90 , total integrated cost =  15937.934048586376
# RUN  100 , total integrated cost =  15937.934044757072
# RUN  110 , total integrated cost =  15937.9340409462
# RUN  120 , total integrated cost =  15937.93403711672
# RUN  130 , total integrated cost =  15937.934033305824
# RUN  140 , total integrated cost =  15937.934029476482
# RUN  150 , total integrated cost =  15937.934025665627
# RUN  160 , total integrated cost =  15937.93402183613
# RUN  170 , total integrated cost =  15937.934018025318
# RUN  180 , total integrated cost =  15937.934014195836
# RUN  190 , total integrated cost =  15937.934010384985
# RUN  200 , total integrated cost =  15937.934006555597
# RUN  300 , total integrated cost =  15937.933968273435
# RUN  400 , total integrated cost =  15937.93392997148
# RUN  500 , total integrated cost =  15937.933891709738
# RUN  600 , total integrated cost =  15937.933853427283
# RUN  700 , total integrated cost =  15937.933815186636
# RUN  800 , total integrated cost =  15937.933776925054
# RUN  900 , total integrated cost =  15937.9337387239
# RUN  1000 , total integrated cost =  15937.933700462123
# RUN  1100 , total integrated cost =  15937.933662160307
# RUN  1200 , total integrated cost =  15937.933623858651
# RUN  1300 , total integrated cost =  15937.93358555698
# RUN  1400 , total integrated cost =  15937.933547255261
# RUN  1500 , total integrated cost =  15937.933508953633
# RUN  1600 , total integrated cost =  15937.933470652062
# RUN  1700 , total integrated cost =  15937.933432430456
# RUN  1800 , total integrated cost =  15937.933394229673
# RUN  1900 , total integrated cost =  15937.933355988918
# RUN  2000 , total integrated cost =  15937.93331768754
# RUN  3000 , total integrated cost =  15937.932935338758
# RUN  4000 , total integrated cost =  15937.932553214667
# RUN  5000 , total integrated cost =  15937.932171053277
# RUN  6000 , total integrated cost =  15937.931789056169
# RUN  7000 , total integrated cost =  15937.931407001302
# RUN  8000 , total integrated cost =  15937.931025010705
# RUN  9000 , total integrated cost =  15937.930643023188
# RUN  10000 , total integrated cost =  15937.930261039468
# RUN  10000 , total integrated cost =  15937.930261039468
# Improved over  10000  iterations in  3196.2372971000004  seconds by  2.3980139829404834e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0324966165063
# set cost params:  1.0 0.0 3174.0324966165063
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934084182472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934083459986
# RUN  2 , total integrated cost =  15937.934083324462
# RUN  3 , total integrated cost =  15937.934083104252
# RUN  4 , total integrated cost =  15937.934083037251
# RUN  5 , total integrated cost =  15937.934082283322
# RUN  6 , total integrated cost =  15937.934081555066
# RUN  7 , total integrated cost =  15937.934081422125
# RUN  8 , total integrated cost =  15937.934081200196
# RUN  9 , total integrated cost =  15937.934081132316
# RUN  10 , total integrated cost =  15937.934080372179
# RUN  11 , total integrated cost =  15937.93407965022
# RUN  12 , total integrated cost =  15937.934079514365
# RUN  13 , total integrated cost =  15937.934079272132
# RUN  14 , total integrated cost =  15937.93407920733
# RUN  15 , total integrated cost =  15937.934078452818
# RUN  16 , total integrated cost =  15937.934077725173
# RUN  17 , total integrated cost =  15937.934077592003
# RUN  18 , total integrated cost =  15937.934077370246
# RUN  19 , total integrated cost =  15937.934077302429
# RUN  20 , total integrated cost =  15937.9340765427
# RUN  30 , total integrated cost =  15937.934072732432
# RUN  40 , total integrated cost =  15937.934068903103
# RUN  50 , total integrated cost =  15937.934065092768
# RUN  60 , total integrated cost =  15937.934061263511
# RUN  70 , total integrated cost =  15937.93405745319
# RUN  80 , total integrated cost =  15937.934053623789
# RUN  90 , total integrated cost =  15937.934049813426
# RUN  100 , total integrated cost =  15937.934045984215
# RUN  110 , total integrated cost =  15937.934042173942
# RUN  120 , total integrated cost =  15937.934038344496
# RUN  130 , total integrated cost =  15937.934034534204
# RUN  140 , total integrated cost =  15937.934030704837
# RUN  150 , total integrated cost =  15937.934026894554
# RUN  160 , total integrated cost =  15937.93402306521
# RUN  170 , total integrated cost =  15937.934019254888
# RUN  180 , total integrated cost =  15937.934015425573
# RUN  190 , total integrated cost =  15937.934011615274
# RUN  200 , total integrated cost =  15937.93400780502
# RUN  300 , total integrated cost =  15937.93396960735
# RUN  400 , total integrated cost =  15937.933931409136
# RUN  500 , total integrated cost =  15937.933893211062
# RUN  600 , total integrated cost =  15937.933855012901
# RUN  700 , total integrated cost =  15937.933816814862
# RUN  800 , total integrated cost =  15937.933778616683
# RUN  900 , total integrated cost =  15937.93374043863
# RUN  1000 , total integrated cost =  15937.933702240918
# RUN  1100 , total integrated cost =  15937.933664043405
# RUN  1200 , total integrated cost =  15937.933625845513
# RUN  1300 , total integrated cost =  15937.933587647616
# RUN  1400 , total integrated cost =  15937.933549449694
# RUN  1500 , total integrated cost =  15937.933511251931
# RUN  1600 , total integrated cost =  15937.93347305418
# RUN  1700 , total integrated cost =  15937.933434876595
# RUN  1800 , total integrated cost =  15937.933396678762
# RUN  1900 , total integrated cost =  15937.933358500984
# RUN  2000 , total integrated cost =  15937.933320343018
# RUN  3000 , total integrated cost =  15937.932938509895
# RUN  4000 , total integrated cost =  15937.932556779655
# RUN  5000 , total integrated cost =  15937.932174992362
# RUN  6000 , total integrated cost =  15937.93179334843
# RUN  7000 , total integrated cost =  15937.931411768694
# RUN  8000 , total integrated cost =  15937.931030212583
# RUN  9000 , total integrated cost =  15937.930648780022
# RUN  10000 , total integrated cost =  15937.930267371152
# RUN  10000 , total integrated cost =  15937.930267371152
# Improved over  10000  iterations in  5924.9940059999935  seconds by  2.394796779014996e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0332569724483
# set cost params:  1.0 0.0 3174.0332569724483
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934085384984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934084662038
# RUN  2 , total integrated cost =  15937.934084526712
# RUN  3 , total integrated cost =  15937.934084306396
# RUN  4 , total integrated cost =  15937.934084239309
# RUN  5 , total integrated cost =  15937.934083486422
# RUN  6 , total integrated cost =  15937.93408275726
# RUN  7 , total integrated cost =  15937.934082624623
# RUN  8 , total integrated cost =  15937.934082402522
# RUN  9 , total integrated cost =  15937.934082334541
# RUN  10 , total integrated cost =  15937.934081575273
# RUN  11 , total integrated cost =  15937.934080852589
# RUN  12 , total integrated cost =  15937.934080717094
# RUN  13 , total integrated cost =  15937.93408049691
# RUN  14 , total integrated cost =  15937.934080429868
# RUN  15 , total integrated cost =  15937.934079677321
# RUN  16 , total integrated cost =  15937.934078947806
# RUN  17 , total integrated cost =  15937.934078815322
# RUN  18 , total integrated cost =  15937.934078593113
# RUN  19 , total integrated cost =  15937.934078525122
# RUN  20 , total integrated cost =  15937.934077765613
# RUN  30 , total integrated cost =  15937.934073956003
# RUN  40 , total integrated cost =  15937.934070146368
# RUN  50 , total integrated cost =  15937.934066317663
# RUN  60 , total integrated cost =  15937.934062507973
# RUN  70 , total integrated cost =  15937.934058698258
# RUN  80 , total integrated cost =  15937.934054888581
# RUN  90 , total integrated cost =  15937.934051078912
# RUN  100 , total integrated cost =  15937.934047250317
# RUN  110 , total integrated cost =  15937.93404344062
# RUN  120 , total integrated cost =  15937.93403963097
# RUN  130 , total integrated cost =  15937.934035821347
# RUN  140 , total integrated cost =  15937.934032011737
# RUN  150 , total integrated cost =  15937.934028182859
# RUN  160 , total integrated cost =  15937.934024373197
# RUN  170 , total integrated cost =  15937.934020563593
# RUN  180 , total integrated cost =  15937.934016753934
# RUN  190 , total integrated cost =  15937.934012944306
# RUN  200 , total integrated cost =  15937.934009115603
# RUN  300 , total integrated cost =  15937.933970980977
# RUN  400 , total integrated cost =  15937.933932865593
# RUN  500 , total integrated cost =  15937.933894731272
# RUN  600 , total integrated cost =  15937.933856596905
# RUN  700 , total integrated cost =  15937.933818462276
# RUN  800 , total integrated cost =  15937.933780327998
# RUN  900 , total integrated cost =  15937.933743529944
# RUN  1000 , total integrated cost =  15937.933705409925
# RUN  1100 , total integrated cost =  15937.933667315638
# RUN  1200 , total integrated cost =  15937.93362922157
# RUN  1300 , total integrated cost =  15937.93359112744
# RUN  1400 , total integrated cost =  15937.933553033463
# RUN  1500 , total integrated cost =  15937.933514939295
# RUN  1600 , total integrated cost =  15937.933476845397
# RUN  1700 , total integrated cost =  15937.933438751426
# RUN  1800 , total integrated cost =  15937.933400657406
# RUN  1900 , total integrated cost =  15937.933362563524
# RUN  2000 , total integrated cost =  15937.933324469734
# RUN  3000 , total integrated cost =  15937.932943532734
# RUN  4000 , total integrated cost =  15937.9325625989
# RUN  5000 , total integrated cost =  15937.932181668191
# RUN  6000 , total integrated cost =  15937.931800740784
# RUN  7000 , total integrated cost =  15937.93141981653
# RUN  8000 , total integrated cost =  15937.93103889546
# RUN  9000 , total integrated cost =  15937.930657977544
# RUN  10000 , total integrated cost =  15937.930277062906
# RUN  10000 , total integrated cost =  15937.930277062906
# Improved over  10000  iterations in  4390.077398299996  seconds by  2.3894703403470885e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0340156374095
# set cost params:  1.0 0.0 3174.0340156374095
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.93408658482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934085858496
# RUN  2 , total integrated cost =  15937.934085724852
# RUN  3 , total integrated cost =  15937.934085503448
# RUN  4 , total integrated cost =  15937.934085435816
# RUN  5 , total integrated cost =  15937.934084680219
# RUN  6 , total integrated cost =  15937.934083953936
# RUN  7 , total integrated cost =  15937.934083820264
# RUN  8 , total integrated cost =  15937.934083598884
# RUN  9 , total integrated cost =  15937.934083531267
# RUN  10 , total integrated cost =  15937.934082775637
# RUN  11 , total integrated cost =  15937.934082049374
# RUN  12 , total integrated cost =  15937.934081915711
# RUN  13 , total integrated cost =  15937.93408169433
# RUN  14 , total integrated cost =  15937.934081626712
# RUN  15 , total integrated cost =  15937.934080871124
# RUN  16 , total integrated cost =  15937.934080144796
# RUN  17 , total integrated cost =  15937.934080011144
# RUN  18 , total integrated cost =  15937.93407978977
# RUN  19 , total integrated cost =  15937.934079722123
# RUN  20 , total integrated cost =  15937.934078966473
# RUN  30 , total integrated cost =  15937.934075157407
# RUN  40 , total integrated cost =  15937.9340713483
# RUN  50 , total integrated cost =  15937.93406753916
# RUN  60 , total integrated cost =  15937.934063730037
# RUN  70 , total integrated cost =  15937.934059920934
# RUN  80 , total integrated cost =  15937.934056111755
# RUN  90 , total integrated cost =  15937.934052302646
# RUN  100 , total integrated cost =  15937.93404849347
# RUN  110 , total integrated cost =  15937.934044684367
# RUN  120 , total integrated cost =  15937.934040875241
# RUN  130 , total integrated cost =  15937.934037066078
# RUN  140 , total integrated cost =  15937.93403325697
# RUN  150 , total integrated cost =  15937.934029447812
# RUN  160 , total integrated cost =  15937.934025638735
# RUN  170 , total integrated cost =  15937.934021829587
# RUN  180 , total integrated cost =  15937.93401802049
# RUN  190 , total integrated cost =  15937.934014211358
# RUN  200 , total integrated cost =  15937.934010402241
# RUN  300 , total integrated cost =  15937.933972311008
# RUN  400 , total integrated cost =  15937.933934219762
# RUN  500 , total integrated cost =  15937.933896128632
# RUN  600 , total integrated cost =  15937.933858037464
# RUN  700 , total integrated cost =  15937.933819946305
# RUN  800 , total integrated cost =  15937.933781855158
# RUN  900 , total integrated cost =  15937.933743764117
# RUN  1000 , total integrated cost =  15937.93370567315
# RUN  1100 , total integrated cost =  15937.933667582141
# RUN  1200 , total integrated cost =  15937.93362949118
# RUN  1300 , total integrated cost =  15937.933591400242
# RUN  1400 , total integrated cost =  15937.933553309309
# RUN  1500 , total integrated cost =  15937.933515218498
# RUN  1600 , total integrated cost =  15937.9334771276
# RUN  1700 , total integrated cost =  15937.933439036788
# RUN  1800 , total integrated cost =  15937.933400946027
# RUN  1900 , total integrated cost =  15937.933362855303
# RUN  2000 , total integrated cost =  15937.933324764595
# RUN  3000 , total integrated cost =  15937.932943859274
# RUN  4000 , total integrated cost =  15937.932562957172
# RUN  5000 , total integrated cost =  15937.932182058252
# RUN  6000 , total integrated cost =  15937.93180116247
# RUN  7000 , total integrated cost =  15937.931420269962
# RUN  8000 , total integrated cost =  15937.93103938055
# RUN  9000 , total integrated cost =  15937.930658494426
# RUN  10000 , total integrated cost =  15937.930277611384
# RUN  10000 , total integrated cost =  15937.930277611384
# Improved over  10000  iterations in  5237.29516970001  seconds by  2.389879024633501e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.034774432311
# set cost params:  1.0 0.0 3174.034774432311
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934087784863
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934087057778
# RUN  2 , total integrated cost =  15937.934086924402
# RUN  3 , total integrated cost =  15937.934086702848
# RUN  4 , total integrated cost =  15937.934086635161
# RUN  5 , total integrated cost =  15937.934085880528
# RUN  6 , total integrated cost =  15937.934085153365
# RUN  7 , total integrated cost =  15937.934085020006
# RUN  8 , total integrated cost =  15937.934084798435
# RUN  9 , total integrated cost =  15937.934084730741
# RUN  10 , total integrated cost =  15937.934083976032
# RUN  11 , total integrated cost =  15937.934083248942
# RUN  12 , total integrated cost =  15937.93408311558
# RUN  13 , total integrated cost =  15937.934082894017
# RUN  14 , total integrated cost =  15937.934082826312
# RUN  15 , total integrated cost =  15937.934082071703
# RUN  16 , total integrated cost =  15937.934081344552
# RUN  17 , total integrated cost =  15937.934081211197
# RUN  18 , total integrated cost =  15937.934080989611
# RUN  19 , total integrated cost =  15937.934080921923
# RUN  20 , total integrated cost =  15937.934080167262
# RUN  30 , total integrated cost =  15937.934076358444
# RUN  40 , total integrated cost =  15937.934072549677
# RUN  50 , total integrated cost =  15937.934068740842
# RUN  60 , total integrated cost =  15937.934064932013
# RUN  70 , total integrated cost =  15937.934061123171
# RUN  80 , total integrated cost =  15937.934057314373
# RUN  90 , total integrated cost =  15937.93405350557
# RUN  100 , total integrated cost =  15937.934049696749
# RUN  110 , total integrated cost =  15937.934045887916
# RUN  120 , total integrated cost =  15937.934042079087
# RUN  130 , total integrated cost =  15937.934038270292
# RUN  140 , total integrated cost =  15937.934034461467
# RUN  150 , total integrated cost =  15937.934030652634
# RUN  160 , total integrated cost =  15937.934026843792
# RUN  170 , total integrated cost =  15937.93402303499
# RUN  180 , total integrated cost =  15937.934019226182
# RUN  190 , total integrated cost =  15937.934015417404
# RUN  200 , total integrated cost =  15937.934011608571
# RUN  300 , total integrated cost =  15937.933973520614
# RUN  400 , total integrated cost =  15937.933935432553
# RUN  500 , total integrated cost =  15937.933897344501
# RUN  600 , total integrated cost =  15937.933859256544
# RUN  700 , total integrated cost =  15937.933821168543
# RUN  800 , total integrated cost =  15937.933783080549
# RUN  900 , total integrated cost =  15937.933744992846
# RUN  1000 , total integrated cost =  15937.933706904922
# RUN  1100 , total integrated cost =  15937.933668817117
# RUN  1200 , total integrated cost =  15937.933630729358
# RUN  1300 , total integrated cost =  15937.933592641566
# RUN  1400 , total integrated cost =  15937.93355455379
# RUN  1500 , total integrated cost =  15937.93351646612
# RUN  1600 , total integrated cost =  15937.933478378494
# RUN  1700 , total integrated cost =  15937.933440290808
# RUN  1800 , total integrated cost =  15937.933402203254
# RUN  1900 , total integrated cost =  15937.933364115646
# RUN  2000 , total integrated cost =  15937.93332602815
# RUN  3000 , total integrated cost =  15937.932945154507
# RUN  4000 , total integrated cost =  15937.932564284021
# RUN  5000 , total integrated cost =  15937.932183416806
# RUN  6000 , total integrated cost =  15937.931802552794
# RUN  7000 , total integrated cost =  15937.931421691892
# RUN  8000 , total integrated cost =  15937.931040834332
# RUN  9000 , total integrated cost =  15937.930659979762
# RUN  10000 , total integrated cost =  15937.9302791284
# RUN  10000 , total integrated cost =  15937.9302791284
# Improved over  10000  iterations in  4240.078727500004  seconds by  2.389680143721762e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0355331642486
# set cost params:  1.0 0.0 3174.0355331642486
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934088984806
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934088256916
# RUN  2 , total integrated cost =  15937.934088123815
# RUN  3 , total integrated cost =  15937.934087902115
# RUN  4 , total integrated cost =  15937.934087834354
# RUN  5 , total integrated cost =  15937.93408708068
# RUN  6 , total integrated cost =  15937.934086352674
# RUN  7 , total integrated cost =  15937.934086219602
# RUN  8 , total integrated cost =  15937.934085997897
# RUN  9 , total integrated cost =  15937.934085930101
# RUN  10 , total integrated cost =  15937.934085176308
# RUN  11 , total integrated cost =  15937.934084448421
# RUN  12 , total integrated cost =  15937.934084315315
# RUN  13 , total integrated cost =  15937.934084093627
# RUN  14 , total integrated cost =  15937.934084025841
# RUN  15 , total integrated cost =  15937.934083272154
# RUN  16 , total integrated cost =  15937.934082544158
# RUN  17 , total integrated cost =  15937.93408241111
# RUN  18 , total integrated cost =  15937.934082189387
# RUN  19 , total integrated cost =  15937.934082121586
# RUN  20 , total integrated cost =  15937.934081367825
# RUN  30 , total integrated cost =  15937.93407755931
# RUN  40 , total integrated cost =  15937.934073750823
# RUN  50 , total integrated cost =  15937.934069942405
# RUN  60 , total integrated cost =  15937.93406613392
# RUN  70 , total integrated cost =  15937.934062325427
# RUN  80 , total integrated cost =  15937.934058516872
# RUN  90 , total integrated cost =  15937.934054708376
# RUN  100 , total integrated cost =  15937.934050899845
# RUN  110 , total integrated cost =  15937.934047091387
# RUN  120 , total integrated cost =  15937.934043282898
# RUN  130 , total integrated cost =  15937.934039474394
# RUN  140 , total integrated cost =  15937.934035665801
# RUN  150 , total integrated cost =  15937.934031857394
# RUN  160 , total integrated cost =  15937.934028048943
# RUN  170 , total integrated cost =  15937.93402424047
# RUN  180 , total integrated cost =  15937.934020431925
# RUN  190 , total integrated cost =  15937.934016623398
# RUN  200 , total integrated cost =  15937.934012814938
# RUN  300 , total integrated cost =  15937.933974730046
# RUN  400 , total integrated cost =  15937.933936645177
# RUN  500 , total integrated cost =  15937.933898560317
# RUN  600 , total integrated cost =  15937.933860475547
# RUN  700 , total integrated cost =  15937.933822390762
# RUN  800 , total integrated cost =  15937.933784305937
# RUN  900 , total integrated cost =  15937.933746221246
# RUN  1000 , total integrated cost =  15937.933708136543
# RUN  1100 , total integrated cost =  15937.933670051903
# RUN  1200 , total integrated cost =  15937.933631967311
# RUN  1300 , total integrated cost =  15937.93359388276
# RUN  1400 , total integrated cost =  15937.933555798161
# RUN  1500 , total integrated cost =  15937.933517713602
# RUN  1600 , total integrated cost =  15937.93347962913
# RUN  1700 , total integrated cost =  15937.933441544677
# RUN  1800 , total integrated cost =  15937.933403460183
# RUN  1900 , total integrated cost =  15937.933365375859
# RUN  2000 , total integrated cost =  15937.933327291432
# RUN  3000 , total integrated cost =  15937.932946449513
# RUN  4000 , total integrated cost =  15937.932565610803
# RUN  5000 , total integrated cost =  15937.932184775334
# RUN  6000 , total integrated cost =  15937.931803942847
# RUN  7000 , total integrated cost =  15937.931423113796
# RUN  8000 , total integrated cost =  15937.931042287693
# RUN  9000 , total integrated cost =  15937.930661465016
# RUN  10000 , total integrated cost =  15937.930280645358
# RUN  10000 , total integrated cost =  15937.930280645358
# Improved over  10000  iterations in  28624.450543  seconds by  2.3894812386515696e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 8
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.036291833214
# set cost params:  1.0 0.0 3174.036291833214
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934090184646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934089455885
# RUN  2 , total integrated cost =  15937.934089323078
# RUN  3 , total integrated cost =  15937.934089101209
# RUN  4 , total integrated cost =  15937.934089033366
# RUN  5 , total integrated cost =  15937.934088280585
# RUN  6 , total integrated cost =  15937.934087551794
# RUN  7 , total integrated cost =  15937.934087419026
# RUN  8 , total integrated cost =  15937.934087197138
# RUN  9 , total integrated cost =  15937.934087129268
# RUN  10 , total integrated cost =  15937.934086376457
# RUN  11 , total integrated cost =  15937.934085647708
# RUN  12 , total integrated cost =  15937.934085514915
# RUN  13 , total integrated cost =  15937.934085293024
# RUN  14 , total integrated cost =  15937.934085225186
# RUN  15 , total integrated cost =  15937.934084472407
# RUN  16 , total integrated cost =  15937.934083743623
# RUN  17 , total integrated cost =  15937.934083610848
# RUN  18 , total integrated cost =  15937.934083388946
# RUN  19 , total integrated cost =  15937.934083321072
# RUN  20 , total integrated cost =  15937.934082568318
# RUN  30 , total integrated cost =  15937.934078760116
# RUN  40 , total integrated cost =  15937.934074951916
# RUN  50 , total integrated cost =  15937.934071143733
# RUN  60 , total integrated cost =  15937.934067335558
# RUN  70 , total integrated cost =  15937.934063527351
# RUN  80 , total integrated cost =  15937.934059719222
# RUN  90 , total integrated cost =  15937.934055911079
# RUN  100 , total integrated cost =  15937.934052102928
# RUN  110 , total integrated cost =  15937.934048294683
# RUN  120 , total integrated cost =  15937.93404448648
# RUN  130 , total integrated cost =  15937.934040678327
# RUN  140 , total integrated cost =  15937.934036870129
# RUN  150 , total integrated cost =  15937.934033061942
# RUN  160 , total integrated cost =  15937.9340292538
# RUN  170 , total integrated cost =  15937.934025445651
# RUN  180 , total integrated cost =  15937.934021637446
# RUN  190 , total integrated cost =  15937.934017829288
# RUN  200 , total integrated cost =  15937.934014021066
# RUN  300 , total integrated cost =  15937.933975939368
# RUN  400 , total integrated cost =  15937.933937857626
# RUN  500 , total integrated cost =  15937.933899775946
# RUN  600 , total integrated cost =  15937.933861694297
# RUN  700 , total integrated cost =  15937.933823612744
# RUN  800 , total integrated cost =  15937.933785531164
# RUN  900 , total integrated cost =  15937.933747449608
# RUN  1000 , total integrated cost =  15937.933709368119
# RUN  1100 , total integrated cost =  15937.933671286593
# RUN  1200 , total integrated cost =  15937.93363320512
# RUN  1300 , total integrated cost =  15937.933595123706
# RUN  1400 , total integrated cost =  15937.933557042292
# RUN  1500 , total integrated cost =  15937.933518960983
# RUN  1600 , total integrated cost =  15937.933480879625
# RUN  1700 , total integrated cost =  15937.933442798316
# RUN  1800 , total integrated cost =  15937.933404717089
# RUN  1900 , total integrated cost =  15937.933366635867
# RUN  2000 , total integrated cost =  15937.933328554733
# RUN  3000 , total integrated cost =  15937.932947744494
# RUN  4000 , total integrated cost =  15937.932566937345
# RUN  5000 , total integrated cost =  15937.932186133565
# RUN  6000 , total integrated cost =  15937.931805332917
# RUN  7000 , total integrated cost =  15937.931424535409
# RUN  8000 , total integrated cost =  15937.931043741142
# RUN  9000 , total integrated cost =  15937.930662949986
# RUN  10000 , total integrated cost =  15937.930282162146
# RUN  10000 , total integrated cost =  15937.930282162146
# Improved over  10000  iterations in  4271.345140599995  seconds by  2.389282374792856e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 9
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0370504392204
# set cost params:  1.0 0.0 3174.0370504392204
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934091384388
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934090654695
# RUN  2 , total integrated cost =  15937.934090522236
# RUN  3 , total integrated cost =  15937.934090300148
# RUN  4 , total integrated cost =  15937.934090232222
# RUN  5 , total integrated cost =  15937.934089480363
# RUN  6 , total integrated cost =  15937.934088750755
# RUN  7 , total integrated cost =  15937.934088618258
# RUN  8 , total integrated cost =  15937.934088396218
# RUN  9 , total integrated cost =  15937.934088328288
# RUN  10 , total integrated cost =  15937.93408757654
# RUN  11 , total integrated cost =  15937.93408684685
# RUN  12 , total integrated cost =  15937.934086714364
# RUN  13 , total integrated cost =  15937.934086492276
# RUN  14 , total integrated cost =  15937.93408642435
# RUN  15 , total integrated cost =  15937.934085672568
# RUN  16 , total integrated cost =  15937.934084942905
# RUN  17 , total integrated cost =  15937.934084810435
# RUN  18 , total integrated cost =  15937.93408458834
# RUN  19 , total integrated cost =  15937.93408452043
# RUN  20 , total integrated cost =  15937.934083768596
# RUN  30 , total integrated cost =  15937.934079960749
# RUN  40 , total integrated cost =  15937.934076152924
# RUN  50 , total integrated cost =  15937.93407234504
# RUN  60 , total integrated cost =  15937.934068537177
# RUN  70 , total integrated cost =  15937.934064729314
# RUN  80 , total integrated cost =  15937.93406092145
# RUN  90 , total integrated cost =  15937.934057113536
# RUN  100 , total integrated cost =  15937.934053305797
# RUN  110 , total integrated cost =  15937.934049497895
# RUN  120 , total integrated cost =  15937.934045690012
# RUN  130 , total integrated cost =  15937.934041882183
# RUN  140 , total integrated cost =  15937.934038074307
# RUN  150 , total integrated cost =  15937.934034266395
# RUN  160 , total integrated cost =  15937.934030458613
# RUN  170 , total integrated cost =  15937.934026650739
# RUN  180 , total integrated cost =  15937.934022842872
# RUN  190 , total integrated cost =  15937.934019035032
# RUN  200 , total integrated cost =  15937.934015227138
# RUN  300 , total integrated cost =  15937.933977148576
# RUN  400 , total integrated cost =  15937.933939069933
# RUN  500 , total integrated cost =  15937.933900991527
# RUN  600 , total integrated cost =  15937.933862912983
# RUN  700 , total integrated cost =  15937.933824834616
# RUN  800 , total integrated cost =  15937.933786756179
# RUN  900 , total integrated cost =  15937.933748677797
# RUN  1000 , total integrated cost =  15937.933710599424
# RUN  1100 , total integrated cost =  15937.933672521045
# RUN  1200 , total integrated cost =  15937.933634442774
# RUN  1300 , total integrated cost =  15937.933596364619
# RUN  1400 , total integrated cost =  15937.933558286411
# RUN  1500 , total integrated cost =  15937.933520208202
# ...
# RUN  3 , total integrated cost =  15937.934098371352
# RUN  4 , total integrated cost =  15937.934098197546
# RUN  5 , total integrated cost =  15937.934097918214
# RUN  6 , total integrated cost =  15937.93409785888
# RUN  7 , total integrated cost =  15937.93409755371
# RUN  8 , total integrated cost =  15937.9340973421
# RUN  9 , total integrated cost =  15937.934096935123
# RUN  10 , total integrated cost =  15937.934096418747
# RUN  11 , total integrated cost =  15937.93409635895
# RUN  12 , total integrated cost =  15937.934095929082
# RUN  13 , total integrated cost =  15937.934095576853
# RUN  14 , total integrated cost =  15937.934095433799
# RUN  15 , total integrated cost =  15937.93409519775
# RUN  16 , total integrated cost =  15937.934095134282
# RUN  17 , total integrated cost =  15937.934094380551
# RUN  18 , total integrated cost =  15937.934093653703
# RUN  19 , total integrated cost =  15937.934093519933
# RUN  20 , total integrated cost =  15937.934093298927
# RUN  30 , total integrated cost =  15937.93409013609
# RUN  40 , total integrated cost =  15937.934087652891
# RUN  50 , total integrated cost =  15937.934083790245
# RUN  60 , total integrated cost =  15937.934081330653
# RUN  70 , total integrated cost =  15937.934078166538
# RUN  80 , total integrated cost =  15937.934074982943
# RUN  90 , total integrated cost =  15937.934072241404
# RUN  100 , total integrated cost =  15937.934068420673
# RUN  110 , total integrated cost =  15937.934065233843
# RUN  120 , total integrated cost =  15937.93406249205
# RUN  130 , total integrated cost =  15937.934058648276
# RUN  140 , total integrated cost =  15937.934055464752
# RUN  150 , total integrated cost =  15937.934052722998
# RUN  160 , total integrated cost =  15937.934048879202
# RUN  170 , total integrated cost =  15937.934045695627
# RUN  180 , total integrated cost =  15937.934042954072
# RUN  190 , total integrated cost =  15937.934039133304
# RUN  200 , total integrated cost =  15937.934035946582
# RUN  300 , total integrated cost =  15937.934003516806
# RUN  400 , total integrated cost =  15937.93397378227
# RUN  500 , total integrated cost =  15937.933943326732
# RUN  600 , total integrated cost =  15937.93390975507
# RUN  700 , total integrated cost =  15937.933877232268
# RUN  800 , total integrated cost =  15937.933846027667
# RUN  900 , total integrated cost =  15937.93381453978
# RUN  1000 , total integrated cost =  15937.933781977792
# RUN  1100 , total integrated cost =  15937.933751195495
# RUN  1200 , total integrated cost =  15937.9337188103
# RUN  1300 , total integrated cost =  15937.93368666824
# RUN  1400 , total integrated cost =  15937.933654505043
# RUN  1500 , total integrated cost =  15937.933623059558
# RUN  1600 , total integrated cost =  15937.933591614761
# RUN  1700 , total integrated cost =  15937.933560589405
# RUN  1800 , total integrated cost =  15937.93353010531
# RUN  1900 , total integrated cost =  15937.933498668235
# RUN  2000 , total integrated cost =  15937.93346680547
# RUN  3000 , total integrated cost =  15937.933150106302
# RUN  4000 , total integrated cost =  15937.932847524798
# RUN  5000 , total integrated cost =  15937.932535615411
# RUN  6000 , total integrated cost =  15937.932227510804
# RUN  7000 , total integrated cost =  15937.931912693333
# RUN  8000 , total integrated cost =  15937.931604070032
# RUN  9000 , total integrated cost =  15937.931291348816
# RUN  10000 , total integrated cost =  15937.93098679595
# RUN  10000 , total integrated cost =  15937.93098679595
# Improved over  10000  iterations in  5470.811746800027  seconds by  1.9528030762216986e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 17
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.042587446141
# set cost params:  1.0 0.0 3174.042587446141
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.93410014119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.9340999691
# RUN  2 , total integrated cost =  15937.934099688222
# RUN  3 , total integrated cost =  15937.934099628885
# RUN  4 , total integrated cost =  15937.934099325525
# RUN  5 , total integrated cost =  15937.934099111937
# RUN  6 , total integrated cost =  15937.934098717642
# RUN  7 , total integrated cost =  15937.93409818947
# RUN  8 , total integrated cost =  15937.93409812919
# RUN  9 , total integrated cost =  15937.934097708583
# RUN  10 , total integrated cost =  15937.934097401077
# RUN  11 , total integrated cost =  15937.934097220324
# RUN  12 , total integrated cost =  15937.934096946978
# RUN  13 , total integrated cost =  15937.93409688418
# RUN  14 , total integrated cost =  15937.934096119248
# RUN  15 , total integrated cost =  15937.934095403885
# RUN  16 , total integrated cost =  15937.93409526369
# RUN  17 , total integrated cost =  15937.93409502532
# RUN  18 , total integrated cost =  15937.934094961443
# RUN  19 , total integrated cost =  15937.934094213111
# RUN  20 , total integrated cost =  15937.934093589332
# RUN  30 , total integrated cost =  15937.934091029523
# RUN  40 , total integrated cost =  15937.934087109334
# RUN  50 , total integrated cost =  15937.9340840011
# RUN  60 , total integrated cost =  15937.934081542287
# RUN  70 , total integrated cost =  15937.934077750557
# RUN  80 , total integrated cost =  15937.934075291734
# RUN  90 , total integrated cost =  15937.93407296884
# RUN  100 , total integrated cost =  15937.934069260817
# RUN  110 , total integrated cost =  15937.93406615273
# RUN  120 , total integrated cost =  15937.93406223253
# RUN  130 , total integrated cost =  15937.934059124294
# RUN  140 , total integrated cost =  15937.93405666548
# RUN  150 , total integrated cost =  15937.934052873754
# RUN  160 , total integrated cost =  15937.93405041497
# RUN  170 , total integrated cost =  15937.934048092184
# RUN  180 , total integrated cost =  15937.934044403995
# RUN  190 , total integrated cost =  15937.934040585147
# RUN  200 , total integrated cost =  15937.934037476922
# RUN  300 , total integrated cost =  15937.934007421269
# RUN  400 , total integrated cost =  15937.933976501126
# RUN  500 , total integrated cost =  15937.933946043408
# RUN  600 , total integrated cost =  15937.933916852011
# RUN  700 , total integrated cost =  15937.933887050338
# RUN  800 , total integrated cost =  15937.933856271098
# RUN  900 , total integrated cost =  15937.93382483571
# RUN  1000 , total integrated cost =  15937.933795785082
# RUN  1100 , total integrated cost =  15937.933762184777
# RUN  1200 , total integrated cost =  15937.933731131869
# RUN  1300 , total integrated cost =  15937.933699716254
# RUN  1400 , total integrated cost =  15937.933669552456
# RUN  1500 , total integrated cost =  15937.933638070324
# RUN  1600 , total integrated cost =  15937.933607304147
# RUN  1700 , total integrated cost =  15937.933575895693
# RUN  1800 , total integrated cost =  15937.933546638089
# RUN  1900 , total integrated cost =  15937.933516474362
# RUN  2000 , total integrated cost =  15937.933486439044
# RUN  3000 , total integrated cost =  15937.933157055479
# RUN  4000 , total integrated cost =  15937.932850321351
# RUN  5000 , total integrated cost =  15937.932543430563
# RUN  6000 , total integrated cost =  15937.932231417411
# RUN  7000 , total integrated cost =  15937.931927165448
# RUN  8000 , total integrated cost =  15937.931622270844
# RUN  9000 , total integrated cost =  15937.931320771042
# RUN  10000 , total integrated cost =  15937.93102308191
# RUN  10000 , total integrated cost =  15937.93102308191
# Improved over  10000  iterations in  4477.394975100004  seconds by  1.930651275472428e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 18
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.043200436262
# set cost params:  1.0 0.0 3174.043200436262
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934101110633
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.93410080676
# RUN  2 , total integrated cost =  15937.934100745804
# RUN  3 , total integrated cost =  15937.934100339871
# RUN  4 , total integrated cost =  15937.93410001711
# RUN  5 , total integrated cost =  15937.934099847482
# RUN  6 , total integrated cost =  15937.934099588067
# RUN  7 , total integrated cost =  15937.93409952686
# RUN  8 , total integrated cost =  15937.934099132975
# RUN  9 , total integrated cost =  15937.934098851969
# RUN  10 , total integrated cost =  15937.934098648468
# RUN  11 , total integrated cost =  15937.934098347669
# RUN  12 , total integrated cost =  15937.934098286962
# RUN  13 , total integrated cost =  15937.934097875992
# RUN  14 , total integrated cost =  15937.934097558467
# RUN  15 , total integrated cost =  15937.93409738566
# RUN  16 , total integrated cost =  15937.934097105453
# RUN  17 , total integrated cost =  15937.934097046109
# RUN  18 , total integrated cost =  15937.934096742287
# RUN  19 , total integrated cost =  15937.934096529281
# RUN  20 , total integrated cost =  15937.93409613091
# RUN  30 , total integrated cost =  15937.93409268009
# RUN  40 , total integrated cost =  15937.934088902168
# RUN  50 , total integrated cost =  15937.934086440098
# RUN  60 , total integrated cost =  15937.934083221724
# RUN  70 , total integrated cost =  15937.93408009893
# RUN  80 , total integrated cost =  15937.934077636854
# RUN  90 , total integrated cost =  15937.934075173634
# RUN  100 , total integrated cost =  15937.934071361413
# RUN  110 , total integrated cost =  15937.934068849923
# RUN  120 , total integrated cost =  15937.934065035513
# RUN  130 , total integrated cost =  15937.934062576092
# RUN  140 , total integrated cost =  15937.934060115223
# RUN  150 , total integrated cost =  15937.934057652816
# RUN  160 , total integrated cost =  15937.934054434363
# RUN  170 , total integrated cost =  15937.934051309065
# RUN  180 , total integrated cost =  15937.934048847397
# RUN  190 , total integrated cost =  15937.934046096583
# RUN  200 , total integrated cost =  15937.934042873689
# RUN  300 , total integrated cost =  15937.934010709367
# RUN  400 , total integrated cost =  15937.933978638617
# RUN  500 , total integrated cost =  15937.933951100353
# RUN  600 , total integrated cost =  15937.933919229996
# RUN  700 , total integrated cost =  15937.93389122819
# RUN  800 , total integrated cost =  15937.933861880785
# RUN  900 , total integrated cost =  15937.933830459797
# RUN  1000 , total integrated cost =  15937.933800390167
# RUN  1100 , total integrated cost =  15937.933771104004
# RUN  1200 , total integrated cost =  15937.93374196279
# RUN  1300 , total integrated cost =  15937.93371117442
# RUN  1400 , total integrated cost =  15937.933681105254
# RUN  1500 , total integrated cost =  15937.933651012394
# RUN  1600 , total integrated cost =  15937.93362126668
# RUN  1700 , total integrated cost =  15937.93358973273
# RUN  1800 , total integrated cost =  15937.933558256362
# RUN  1900 , total integrated cost =  15937.933526056013
# RUN  2000 , total integrated cost =  15937.933494636758
# RUN  3000 , total integrated cost =  15937.933192220053
# RUN  4000 , total integrated cost =  15937.932891668992
# RUN  5000 , total integrated cost =  15937.932588817801
# RUN  6000 , total integrated cost =  15937.9322822604
# RUN  7000 , total integrated cost =  15937.931970417856
# RUN  8000 , total integrated cost =  15937.931669993424
# RUN  9000 , total integrated cost =  15937.931362276699
# RUN  10000 , total integrated cost =  15937.931056273485
# RUN  10000 , total integrated cost =  15937.931056273485
# Improved over  10000  iterations in  4227.392263999995  seconds by  1.9104340182707347e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 19
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0438070074324
# set cost params:  1.0 0.0 3174.0438070074324
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934102069927
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934101811494
# RUN  2 , total integrated cost =  15937.934101750368
# RUN  3 , total integrated cost =  15937.934101354731
# RUN  4 , total integrated cost =  15937.934101075582
# RUN  5 , total integrated cost =  15937.934100871471
# RUN  6 , total integrated cost =  15937.934100571245
# RUN  7 , total integrated cost =  15937.934100510573
# RUN  8 , total integrated cost =  15937.934100099023
# RUN  9 , total integrated cost =  15937.934099782156
# RUN  10 , total integrated cost =  15937.934099608956
# RUN  11 , total integrated cost =  15937.934099329146
# RUN  12 , total integrated cost =  15937.93409926982
# RUN  13 , total integrated cost =  15937.934098965743
# RUN  14 , total integrated cost =  15937.934098753041
# RUN  15 , total integrated cost =  15937.934098352514
# RUN  16 , total integrated cost =  15937.934097830404
# RUN  17 , total integrated cost =  15937.934097770336
# RUN  18 , total integrated cost =  15937.93409734778
# RUN  19 , total integrated cost =  15937.934097042407
# RUN  20 , total integrated cost =  15937.934096860126
# RUN  30 , total integrated cost =  15937.934092990306
# RUN  40 , total integrated cost =  15937.934089865008
# RUN  50 , total integrated cost =  15937.934087403974
# RUN  60 , total integrated cost =  15937.93408465598
# RUN  70 , total integrated cost =  15937.934080816029
# RUN  80 , total integrated cost =  15937.934077595635
# RUN  90 , total integrated cost =  15937.934074447818
# RUN  100 , total integrated cost =  15937.934070614183
# RUN  110 , total integrated cost =  15937.934068152681
# RUN  120 , total integrated cost =  15937.934065628553
# RUN  130 , total integrated cost =  15937.934062243019
# RUN  140 , total integrated cost =  15937.934059021336
# RUN  150 , total integrated cost =  15937.934055252465
# RUN  160 , total integrated cost =  15937.93405274289
# RUN  170 , total integrated cost =  15937.934049994568
# RUN  180 , total integrated cost =  15937.934046152901
# RUN  190 , total integrated cost =  15937.934042931085
# RUN  200 , total integrated cost =  15937.934039159441
# RUN  300 , total integrated cost =  15937.934008602322
# RUN  400 , total integrated cost =  15937.93397575412
# RUN  500 , total integrated cost =  15937.933946051757
# RUN  600 , total integrated cost =  15937.933914532061
# RUN  700 , total integrated cost =  15937.93388514249
# RUN  800 , total integrated cost =  15937.933854364814
# RUN  900 , total integrated cost =  15937.933823320236

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.733611884656419
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733598406036625
# RUN  2 , total integrated cost =  3.733598397842583
# RUN  3 , total integrated cost =  3.733598397842583
# Control only changes marginally.
# RUN  3 , total integrated cost =  3.733598397842583
# Improved over  3  iterations in  0.516009999999369  seconds by  0.0003612269901793752  percent.
# no convergence
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.1106767150717718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4124715277743368
# RUN  2 , total integrated cost =  0.41246712801473756
# RUN  3 , total integrated cost =  0.4124670508739037
# RUN  4 , total integrated cost =  0.412466920082946
# RUN  5 , total integrated cost =  0.4124668687989809
# RUN  6 , total integrated cost =  0.4124662295212646
# RUN  7 , total integrated cost =  0.4124657161425997
# RUN  8 , total integrated cost =  0.4124655643839947
# RUN  9 , total integrated cost =  0.412465355369783
# RUN  10 , total integrated cost =  0.4124653180419388
# RUN  11 , total integrated cost =  0.4124651960454082
# RUN  12 , total integrated cost =  0.41246513125829726
# RUN  13 , total integrated cost =  0.41245805184840195
# RUN  14 , total integrated cost =  0.4124557698062933
# RUN  15 , total integrated cost =  0.41245563899301946
# RUN  16 , total integrated cost =  0.41245547116935455
# RUN  17 , total integrated cost =  0.4124554617204336
# RUN  18 , total integrated cost =  0.4124553874677896
# RUN  19 , total integrated cost =  0.4124553432780999
# RUN  20 , total integrated cost =  0.4124553189462483
# RUN  30 , total integrated cost =  0.41244905445805097
# RUN  40 , total integrated cost =  0.41244893444260555
# RUN  50 , total integrated cost =  0.41244799204630767
# RUN  60 , total integrated cost =  0.4124447223871436
# RUN  70 , total integrated cost =  0.41244355516913794
# RUN  80 , total integrated cost =  0.4124426645599269
# RUN  90 , total integrated cost =  0.4124426080122011
# RUN  100 , total integrated cost =  0.4124375623633028
# RUN  110 , total integrated cost =  0.4124362152482276
# RUN  120 , total integrated cost =  0.4124360478479578
# RUN  130 , total integrated cost =  0.41243599357232075
# RUN  140 , total integrated cost =  0.41243584725432353
# RUN  150 , total integrated cost =  0.41243579373093947
# RUN  160 , total integrated cost =  0.41243505776371125
# RUN  170 , total integrated cost =  0.4124349226728131
# RUN  180 , total integrated cost =  0.4124349099460619
# RUN  190 , total integrated cost =  0.4124348866982093
# RUN  200 , total integrated cost =  0.41243479215443235
# RUN  300 , total integrated cost =  0.4124321557692797
# RUN  400 , total integrated cost =  0.4124272878214357
# RUN  500 , total integrated cost =  0.4124271649725494
# Control only changes marginally.
# RUN  501 , total integrated cost =  0.4124271649725494
# Improved over  501  iterations in  48.54441720000614  seconds by  62.86703778192573  percent.
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.021362535631467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.021355712619119
# RUN  2 , total integrated cost =  5.021355708794576
# RUN  3 , total integrated cost =  5.021355708794575
# RUN  4 , total integrated cost =  5.021355708794575
# Control only changes marginally.
# RUN  4 , total integrated cost =  5.021355708794575
# Improved over  4  iterations in  0.6631678999983706  seconds by  0.0001359558654456805  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.4609702850549064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.460968870194015
# RUN  2 , total integrated cost =  4.460968869891608
# RUN  3 , total integrated cost =  4.460968869891004
# RUN  4 , total integrated cost =  4.460968869891001
# RUN  5 , total integrated cost =  4.460968869891001
# Control only changes marginally.
# RUN  5 , total integrated cost =  4.460968869891001
# Improved over  5  iterations in  0.7985479999988456  seconds by  3.172323093281193e-05  percent.
# no convergence
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7830940013972727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.783087813959923
# RUN  2 , total integrated cost =  3.783087812738599
# RUN  3 , total integrated cost =  3.7830878127383505
# RUN  4 , total integrated cost =  3.7830878127383505
# Control only changes marginally.
# RUN  4 , total integrated cost =  3.7830878127383505
# Improved over  4  iterations in  0.6396470999970916  seconds by  0.00016358723627263316  percent.
# no convergence
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.733598397842583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733598397842583
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.733598397842583
# Improved over  1  iterations in  0.20355830000335118  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.4124271649725494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4124271649725494
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.4124271649725494
# Improved over  1  iterations in  0.20041079999646172  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.021355708794575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.021355708794575
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.021355708794575
# Improved over  1  iterations in  0.21220400000311201  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.460968869891001
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.460968869891001
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.460968869891001
# Improved over  1  iterations in  0.23728449999907752  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7830878127383505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7830878127383505
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7830878127383505
# Improved over  1  iterations in  0.23296560000017053  seconds by  0.0  percent.
# converged for  80
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.733598397842583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733598397842583
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.733598397842583
# Improved over  1  iterations in  0.2332927000024938  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.4124271649725494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4124271649725494
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.4124271649725494
# Improved over  1  iterations in  0.19511600000259932  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.021355708794575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.021355708794575
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.021355708794575
# Improved over  1  iterations in  0.20869539999694098  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.460968869891001
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.460968869891001
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.460968869891001
# Improved over  1  iterations in  0.21050519999698736  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7830878127383505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7830878127383505
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7830878127383505
# Improved over  1  iterations in  0.21291630000632722  seconds by  0.0  percent.
# converged for  80
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence
