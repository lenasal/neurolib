# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# C:\Users\Lena\Promotion\neurolib\GUI\current\gui\data\11120
# 11120

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 4
limit = 40
i_range = range(0, limit,i_stepsize)
i_range_0 = range(0, limit,i_stepsize)
i_range_1 = range(0, limit,i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  8 0.47500000000000014 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  16 0.47500000000000014 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5902.406479238383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13602.2666253313
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13602.2666253313
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17551.147823015366
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17551.147823015366
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17571.20016629342
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17571.20016629342
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17340.897955123706
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17340.897955123706
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.9816241341314
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2980.9816241341314
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21313.092781962267
# Gradient descend method:  None
# RUN  0 , total integrated cost =  21313.092781962267
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16568.218379642258
# Gradient descend method:  None
# RUN  0 , total integrated cost =  16568.218379642258
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7741.667733280556
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7741.667733280556
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55.886170914069865
# RUN  2 , total integrated cost =  42.65570180421014
# RUN  3 , total integrated cost =  28.840267049881813
# RUN  4 , total integrated cost =  24.406095908721905
# RUN  5 , total integrated cost =  20.071541794363235
# RUN  6 , total integrated cost =  17.497077501812623
# RUN  7 , total integrated cost =  14.962898550512925
# RUN  8 , total integrated cost =  12.48803072824853
# RUN  9 , total integrated cost =  10.253848886718844
# RUN  10 , total integrated cost =  8.019764971048419
# RUN  11 , total integrated cost =  7.377795308952696
# RUN  12 , total integrated cost =  5.786539815314411
# RUN  13 , total integrated cost =  5.780689329820276
# RUN  14 , total integrated cost =  5.600426059938204
# RUN  15 , total integrated cost =  5.494742548840481
# RUN  16 , total integrated cost =  5.491787486996326
# RUN  17 , total integrated cost =  4.877299670597409
# RUN  18 , total integrated cost =  4.869937310252979
# RUN  19 , total integrated cost =  4.863229268839997
# RUN  20 , total integrated cost =  4.849961297081692
# RUN  30 , total integrated cost =  4.70288729783421
# RUN  40 , total integrated cost =  4.649439670700624
# RUN  50 , total integrated cost =  4.629484626350216
# RUN  60 , total integrated cost =  4.447417820355914
# ERROR:root:Problem in initial value trasfer
# RUN  70 , total integrated cost =  4.447417820305347
# Control only changes marginally.
# RUN  70 , total integrated cost =  4.447417820305347
# Improved over  70  iterations in  9.508221300000514  seconds by  99.92465077022484  percent.
# Problem in initial value trasfer:  Vmean_exc -64.16262123696094 -64.15379235761353
# weight =  13271.535793848892
# set cost params:  1.0 13271.535793848892 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5548.689928220025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5091.108782491913
# RUN  2 , total integrated cost =  5078.348427359097
# RUN  3 , total integrated cost =  5045.199922119573
# RUN  4 , total integrated cost =  5032.103811287828
# RUN  5 , total integrated cost =  5032.091594644799
# RUN  6 , total integrated cost =  5032.091216718317
# RUN  7 , total integrated cost =  5032.0912052717795
# RUN  8 , total integrated cost =  5032.091202760467
# RUN  9 , total integrated cost =  5032.091201845418
# RUN  10 , total integrated cost =  5032.091201478979
# RUN  11 , total integrated cost =  5032.091201324757
# RUN  12 , total integrated cost =  5032.091201263772
# RUN  13 , total integrated cost =  5032.09120123988
# RUN  14 , total integrated cost =  5032.091201230764
# RUN  15 , total integrated cost =  5032.091201227229
# RUN  16 , total integrated cost =  5032.091201225773
# RUN  17 , total integrated cost =  5032.091201225187
# RUN  18 , total integrated cost =  5032.091201224945
# RUN  19 , total integrated cost =  5032.091201224875
# RUN  20 , total integrated cost =  5032.091201224845
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  24 , total integrated cost =  5032.09120122484
# Improved over  24  iterations in  4.662083899999743  seconds by  9.310282853756533  percent.
# Problem in initial value trasfer:  Vmean_exc -60.58104226392273 -60.609701692552676
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13602.2666253313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  263.45145642566746
# RUN  2 , total integrated cost =  187.2108210027464
# RUN  3 , total integrated cost =  127.26639002054321
# RUN  4 , total integrated cost =  103.3150489634466
# RUN  5 , total integrated cost =  87.01706887564279
# RUN  6 , total integrated cost =  75.91802830345584
# RUN  7 , total integrated cost =  69.09543156035804
# RUN  8 , total integrated cost =  56.98098295994961
# RUN  9 , total integrated cost =  53.45652501721235
# RUN  10 , total integrated cost =  52.882183504206694
# RUN  11 , total integrated cost =  51.848794654252444
# RUN  12 , total integrated cost =  51.59955560206316
# RUN  13 , total integrated cost =  46.6684595819581
# RUN  14 , total integrated cost =  45.843819527386245
# RUN  15 , total integrated cost =  45.80551654330426
# RUN  16 , total integrated cost =  43.75577001777525
# RUN  17 , total integrated cost =  43.16024212706757
# RUN  18 , total integrated cost =  43.128816311533086
# RUN  19 , total integrated cost =  43.03071894564498
# RUN  20 , total integrated cost =  42.78106997965502
# RUN  30 , total integrated cost =  39.487933115293515
# RUN  40 , total integrated cost =  39.29434082908019
# RUN  50 , total integrated cost =  38.961131952743216
# RUN  60 , total integrated cost =  37.713764275637665
# ERROR:root:Problem in initial value trasfer
# RUN  70 , total integrated cost =  37.71114615940619
# Control only changes marginally.
# RUN  70 , total integrated cost =  37.71114615940619
# Improved over  70  iterations in  8.8044002000006  seconds by  99.72275836668885  percent.
# Problem in initial value trasfer:  Vmean_exc -62.34508816415809 -62.34995512047952
# weight =  3606.961869531649
# set cost params:  1.0 3606.961869531649 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13015.121663220054
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11043.829480316641
# RUN  2 , total integrated cost =  10975.30641767864
# RUN  3 , total integrated cost =  10935.509547357626
# RUN  4 , total integrated cost =  10744.59624104103
# RUN  5 , total integrated cost =  10735.854698760839
# RUN  6 , total integrated cost =  10735.720237852325
# RUN  7 , total integrated cost =  10735.673394364887
# RUN  8 , total integrated cost =  10735.566926079271
# RUN  9 , total integrated cost =  10603.082201944195
# RUN  10 , total integrated cost =  10583.368189009856
# RUN  11 , total integrated cost =  10492.756175659602
# RUN  12 , total integrated cost =  10410.357248839638
# RUN  13 , total integrated cost =  10403.405278210845
# RUN  14 , total integrated cost =  10210.288509351609
# RUN  15 , total integrated cost =  10103.577251141374
# RUN  16 , total integrated cost =  9430.301618211959
# RUN  17 , total integrated cost =  9008.197909025468
# RUN  18 , total integrated cost =  8511.087303921304
# RUN  19 , total integrated cost =  8425.483516657974
# RUN  20 , total integrated cost =  8416.055788369249
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  25 , total integrated cost =  8415.126352215066
# Improved over  25  iterations in  3.0789334999999483  seconds by  35.34346762200691  percent.
# Problem in initial value trasfer:  Vmean_exc -56.63544597584617 -56.636355415717986
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17551.147823015366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  371.66531985492736
# RUN  2 , total integrated cost =  261.5525142712681
# RUN  3 , total integrated cost =  173.97859361835341
# RUN  4 , total integrated cost =  142.11811516101196
# RUN  5 , total integrated cost =  119.83386004292565
# RUN  6 , total integrated cost =  104.52508352591892
# RUN  7 , total integrated cost =  95.69406165786106
# RUN  8 , total integrated cost =  79.68055707235408
# RUN  9 , total integrated cost =  77.27095557403035
# RUN  10 , total integrated cost =  76.79080824287851
# RUN  11 , total integrated cost =  75.8576314793369
# RUN  12 , total integrated cost =  75.59732940385595
# RUN  13 , total integrated cost =  69.12269835834441
# RUN  14 , total integrated cost =  68.77179111803471
# RUN  15 , total integrated cost =  68.61077893403731
# RUN  16 , total integrated cost =  68.01440536197823
# RUN  17 , total integrated cost =  67.81470292635153
# RUN  18 , total integrated cost =  67.76597405731077
# RUN  19 , total integrated cost =  66.50376011654087
# RUN  20 , total integrated cost =  65.94904670397105
# RUN  30 , total integrated cost =  62.87809406000054
# RUN  40 , total integrated cost =  59.73814376089469
# RUN  50 , total integrated cost =  59.37192400806923
# RUN  60 , total integrated cost =  58.66839335564876
# RUN  70 , total integrated cost =  58.66590638573967
# RUN  80 , total integrated cost =  58.66590638428541
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  88 , total integrated cost =  58.66590638428488
# Improved over  88  iterations in  17.584468600000037  seconds by  99.66574319254862  percent.
# Problem in initial value trasfer:  Vmean_exc -61.97901545696676 -61.98486347630766
# weight =  2991.711695042843
# set cost params:  1.0 2991.711695042843 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16780.191527607727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14311.024477235214
# RUN  2 , total integrated cost =  12819.091468500228
# RUN  3 , total integrated cost =  10994.136075052073
# RUN  4 , total integrated cost =  10682.577070817366
# RUN  5 , total integrated cost =  10674.019280964014
# RUN  6 , total integrated cost =  10673.962121875287
# RUN  7 , total integrated cost =  10673.96191159514
# RUN  8 , total integrated cost =  10673.961911595132
# RUN  9 , total integrated cost =  10673.96191159513
# ERROR:root:Problem in initial value trasfer
# RUN  10 , total integrated cost =  10673.96191159513
# Control only changes marginally.
# RUN  10 , total integrated cost =  10673.96191159513
# Improved over  10  iterations in  2.7602963999997883  seconds by  36.389510846561436  percent.
# Problem in initial value trasfer:  Vmean_exc -56.647147635023536 -56.64877891875353
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17571.20016629342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  373.38980250045006
# RUN  2 , total integrated cost =  261.4700153750503
# RUN  3 , total integrated cost =  170.38330599801617
# RUN  4 , total integrated cost =  138.53675050916706
# RUN  5 , total integrated cost =  117.50033974232291
# RUN  6 , total integrated cost =  101.70379093062502
# RUN  7 , total integrated cost =  93.78210218316963
# RUN  8 , total integrated cost =  83.12334235615182
# RUN  9 , total integrated cost =  80.05029154110842
# RUN  10 , total integrated cost =  77.78176594067307
# RUN  11 , total integrated cost =  74.72782232208263
# RUN  12 , total integrated cost =  74.52208130816389
# RUN  13 , total integrated cost =  70.74961188184294
# RUN  14 , total integrated cost =  69.59670364936832
# RUN  15 , total integrated cost =  69.50702756953713
# RUN  16 , total integrated cost =  68.60382662953798
# RUN  17 , total integrated cost =  68.20324540967849
# RUN  18 , total integrated cost =  68.13632735592596
# RUN  19 , total integrated cost =  66.88946882427695
# RUN  20 , total integrated cost =  66.3031497681537
# RUN  30 , total integrated cost =  60.24003925017113
# RUN  40 , total integrated cost =  59.49139545856693
# RUN  50 , total integrated cost =  59.19505478706923
# RUN  60 , total integrated cost =  58.791560987376016
# RUN  70 , total integrated cost =  56.109749627366256
# RUN  80 , total integrated cost =  55.669637454753726
# RUN  90 , total integrated cost =  55.66957529959959
# RUN  100 , total integrated cost =  55.669575299299034
# ERROR:root:Problem in initial value trasfer
# State only changes marginally.
# Control only changes marginally.
# RUN  103 , total integrated cost =  55.66957529929893
# Improved over  103  iterations in  23.119268700000248  seconds by  99.68317716051013  percent.
# Problem in initial value trasfer:  Vmean_exc -63.64715270090612 -63.656173492626515
# weight =  3156.338102423911
# set cost params:  1.0 3156.338102423911 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16836.627606250888
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14584.569598052241
# RUN  2 , total integrated cost =  13740.650310145793
# RUN  3 , total integrated cost =  11020.415633312135
# RUN  4 , total integrated cost =  10920.86709652514
# RUN  5 , total integrated cost =  10875.392052036517
# RUN  6 , total integrated cost =  10873.903575988119
# RUN  7 , total integrated cost =  10873.903575988112
# ERROR:root:Problem in initial value trasfer
# RUN  8 , total integrated cost =  10873.903575988112
# Control only changes marginally.
# RUN  8 , total integrated cost =  10873.903575988112
# Improved over  8  iterations in  1.4510512000006202  seconds by  35.41519222085195  percent.
# Problem in initial value trasfer:  Vmean_exc -56.65044526991906 -56.65193644109477
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17340.897955123706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  367.68036068957775
# RUN  2 , total integrated cost =  258.4221883787187
# RUN  3 , total integrated cost =  164.39207096100927
# RUN  4 , total integrated cost =  133.11114555881454
# RUN  5 , total integrated cost =  112.53361002422403
# RUN  6 , total integrated cost =  98.30877823323402
# RUN  7 , total integrated cost =  90.37672664805164
# RUN  8 , total integrated cost =  75.94933330905441
# RUN  9 , total integrated cost =  74.69573248368947
# RUN  10 , total integrated cost =  74.26961972893466
# RUN  11 , total integrated cost =  68.1515288265781
# RUN  12 , total integrated cost =  67.81877331233336
# RUN  13 , total integrated cost =  66.28990614659344
# RUN  14 , total integrated cost =  64.79936581315914
# RUN  15 , total integrated cost =  64.75845005492474
# RUN  16 , total integrated cost =  64.5996512140708
# RUN  17 , total integrated cost =  64.07979420858194
# RUN  18 , total integrated cost =  64.01579325868838
# RUN  19 , total integrated cost =  63.96755287546915
# RUN  20 , total integrated cost =  63.20937755218633
# RUN  30 , total integrated cost =  58.40720625473929
# RUN  40 , total integrated cost =  55.13837426796567
# RUN  50 , total integrated cost =  54.137540524148314
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  59 , total integrated cost =  54.137540521584945
# Improved over  59  iterations in  9.904739200000222  seconds by  99.68780428405907  percent.
# Problem in initial value trasfer:  Vmean_exc -64.57264718242291 -64.58713300656426
# weight =  3203.1189056713415
# set cost params:  1.0 3203.1189056713415 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16531.13449576146
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14103.065317257726
# RUN  2 , total integrated cost =  14087.909996858049
# RUN  3 , total integrated cost =  14082.979570051783
# RUN  4 , total integrated cost =  14066.770196626043
# RUN  5 , total integrated cost =  14055.21484379697
# RUN  6 , total integrated cost =  13992.408100076895
# RUN  7 , total integrated cost =  13959.598437271101
# RUN  8 , total integrated cost =  13959.23902363774
# RUN  9 , total integrated cost =  13957.728042079829
# RUN  10 , total integrated cost =  13953.621402474384
# RUN  11 , total integrated cost =  13953.243265614448
# RUN  12 , total integrated cost =  13952.944113743011
# RUN  13 , total integrated cost =  13946.212319324268
# RUN  14 , total integrated cost =  13942.727732319028
# RUN  15 , total integrated cost =  13942.662153190728
# RUN  16 , total integrated cost =  13942.531613012587
# RUN  17 , total integrated cost =  13931.790803941767
# RUN  18 , total integrated cost =  13926.964319328696
# RUN  19 , total integrated cost =  13926.9607284892
# RUN  20 , total integrated cost =  13926.96050831995
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  24 , total integrated cost =  13926.960487726805
# Improved over  24  iterations in  3.2415869999995266  seconds by  15.753147545332467  percent.
# Problem in initial value trasfer:  Vmean_exc -56.956275693784576 -56.94798897284823
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  238.79594650342023
# RUN  2 , total integrated cost =  168.19300494353385
# RUN  3 , total integrated cost =  105.10259199984124
# RUN  4 , total integrated cost =  85.45812380007646
# RUN  5 , total integrated cost =  71.91429137130612
# RUN  6 , total integrated cost =  63.022430042863135
# RUN  7 , total integrated cost =  57.3305672918744
# RUN  8 , total integrated cost =  49.43717612512729
# RUN  9 , total integrated cost =  47.103570423594164
# RUN  10 , total integrated cost =  46.07458674136454
# RUN  11 , total integrated cost =  44.59302145420148
# RUN  12 , total integrated cost =  44.270668058794804
# RUN  13 , total integrated cost =  41.96533229150236
# RUN  14 , total integrated cost =  40.927994412069886
# RUN  15 , total integrated cost =  40.68924273826107
# RUN  16 , total integrated cost =  40.01977439239287
# RUN  17 , total integrated cost =  39.78342924767334
# RUN  18 , total integrated cost =  39.24105273500338
# RUN  19 , total integrated cost =  38.30620679951606
# RUN  20 , total integrated cost =  38.21146990024051
# RUN  30 , total integrated cost =  31.06617312239456
# RUN  40 , total integrated cost =  28.12877169447552
# RUN  50 , total integrated cost =  27.95279177407239
# RUN  60 , total integrated cost =  27.78341606935341
# RUN  70 , total integrated cost =  27.767850208329524
# RUN  80 , total integrated cost =  27.767849713523255
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  83 , total integrated cost =  27.76784971352321
# Improved over  83  iterations in  9.820608600000014  seconds by  99.78200976712745  percent.
# Problem in initial value trasfer:  Vmean_exc -67.29807370216257 -67.31820069131652
# weight =  4587.3614924052545
# set cost params:  1.0 4587.3614924052545 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12336.080408181311
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10841.367910033992
# RUN  2 , total integrated cost =  10837.313220648864
# RUN  3 , total integrated cost =  10836.053309835741
# RUN  4 , total integrated cost =  10830.394620546522
# RUN  5 , total integrated cost =  10828.708441522502
# RUN  6 , total integrated cost =  10827.903363371472
# RUN  7 , total integrated cost =  10822.51112438053
# RUN  8 , total integrated cost =  10820.90656896984
# RUN  9 , total integrated cost =  10820.353033965726
# RUN  10 , total integrated cost =  10814.409982477058
# RUN  11 , total integrated cost =  10812.21744622862
# RUN  12 , total integrated cost =  10811.900805131296
# RUN  13 , total integrated cost =  10757.296321479262
# RUN  14 , total integrated cost =  10756.53380258818
# RUN  15 , total integrated cost =  10756.52977016438
# RUN  16 , total integrated cost =  10756.529618007797
# RUN  17 , total integrated cost =  10756.529606879214
# RUN  18 , total integrated cost =  10756.529606440432
# RUN  19 , total integrated cost =  10756.529606440406
# RUN  20 , total integrated cost =  10756.529606440397
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  22 , total integrated cost =  10756.529606440396
# Improved over  22  iterations in  2.7933806000000914  seconds by  12.804316683063732  percent.
# Problem in initial value trasfer:  Vmean_exc -58.05215288026265 -58.05407068751046
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.9816241341314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8355504258884979
# RUN  2 , total integrated cost =  0.7732262965421177
# RUN  3 , total integrated cost =  0.7048233664342882
# RUN  4 , total integrated cost =  0.6632400707273635
# RUN  5 , total integrated cost =  0.6071359663026483
# RUN  6 , total integrated cost =  0.5713933210652435
# RUN  7 , total integrated cost =  0.5180222414814448
# RUN  8 , total integrated cost =  0.4729041215356079
# RUN  9 , total integrated cost =  0.37077768782932397
# RUN  10 , total integrated cost =  0.34915457212384354
# RUN  11 , total integrated cost =  0.3171600468904728
# RUN  12 , total integrated cost =  0.28028712252998716
# RUN  13 , total integrated cost =  0.25433528253322923
# RUN  14 , total integrated cost =  0.2540370060940341
# RUN  15 , total integrated cost =  0.2491539480295152
# RUN  16 , total integrated cost =  0.24577625089320396
# RUN  17 , total integrated cost =  0.24574964300274918
# RUN  18 , total integrated cost =  0.24574721753730486
# RUN  19 , total integrated cost =  0.2457459832111784
# RUN  20 , total integrated cost =  0.2457454005191296
# RUN  30 , total integrated cost =  0.24453925753244338
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  33 , total integrated cost =  0.24453925753244024
# Improved over  33  iterations in  3.1676078999998936  seconds by  99.99179668685132  percent.
# Problem in initial value trasfer:  Vmean_exc -72.51893308806706 -72.54309571282366
# weight =  121901.96593439311
# set cost params:  1.0 121901.96593439311 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2876.213729988598
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1690.2902470459035
# RUN  2 , total integrated cost =  1687.9315186615372
# RUN  3 , total integrated cost =  1667.774488756253
# RUN  4 , total integrated cost =  1665.8858718864644
# RUN  5 , total integrated cost =  1665.8843178429283
# RUN  6 , total integrated cost =  1665.8842963501568
# RUN  7 , total integrated cost =  1665.884296327212
# RUN  8 , total integrated cost =  1665.8842963265133
# RUN  9 , total integrated cost =  1665.8842963264856
# RUN  10 , total integrated cost =  1665.8842963264658
# RUN  11 , total integrated cost =  1665.884296326464
# RUN  12 , total integrated cost =  1665.8842963264638
# State only changes marginally.
# RUN  13 , total integrated cost =  1665.8842963264633
# State only changes marginally.
# RUN  14 , total integrated cost =  1665.884296326463
# State only changes marginally.
# RUN  15 , total integrated cost =  1665.8842963264628
# ERROR:root:Problem in initial value trasfer
# State only changes marginally.
# RUN  16 , total integrated cost =  1665.8842963264626
# RUN  17 , total integrated cost =  1665.8842963264626
# Control only changes marginally.
# RUN  17 , total integrated cost =  1665.8842963264626
# Improved over  17  iterations in  1.9410895000000892  seconds by  42.080650024118114  percent.
# Problem in initial value trasfer:  Vmean_exc -60.02757942749234 -60.06511045217133
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21313.092781962267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  472.6121113143062
# RUN  2 , total integrated cost =  316.60388713891314
# RUN  3 , total integrated cost =  212.64551459211856
# RUN  4 , total integrated cost =  173.92520284665588
# RUN  5 , total integrated cost =  149.01226262363096
# RUN  6 , total integrated cost =  130.2339646647312
# RUN  7 , total integrated cost =  120.01228367659799
# RUN  8 , total integrated cost =  105.7857618443104
# RUN  9 , total integrated cost =  103.53996302937756
# RUN  10 , total integrated cost =  102.6129370873273
# RUN  11 , total integrated cost =  101.00449407381397
# RUN  12 , total integrated cost =  100.67018175329466
# RUN  13 , total integrated cost =  92.3419176418606
# RUN  14 , total integrated cost =  92.00029514871731
# RUN  15 , total integrated cost =  91.83824661332889
# RUN  16 , total integrated cost =  91.03335796024223
# RUN  17 , total integrated cost =  90.82528908109121
# RUN  18 , total integrated cost =  90.73398826136498
# RUN  19 , total integrated cost =  89.7563058882051
# RUN  20 , total integrated cost =  89.40300726549607
# RUN  30 , total integrated cost =  81.56337491151632
# RUN  40 , total integrated cost =  78.1865989116233
# RUN  50 , total integrated cost =  77.42918455640361
# RUN  60 , total integrated cost =  76.78934353839365
# ERROR:root:Problem in initial value trasfer
# RUN  70 , total integrated cost =  76.7893435367651
# Control only changes marginally.
# RUN  71 , total integrated cost =  76.7893435367651
# Improved over  71  iterations in  10.84356949999983  seconds by  99.63970811593448  percent.
# Problem in initial value trasfer:  Vmean_exc -64.02646720131635 -64.0451436756575
# weight =  2775.5274104873697
# set cost params:  1.0 2775.5274104873697 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20199.76479208847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17323.96918786431
# RUN  2 , total integrated cost =  14967.001666449187
# RUN  3 , total integrated cost =  13024.059203048571
# RUN  4 , total integrated cost =  13023.435449555363
# RUN  5 , total integrated cost =  13023.435449555353
# ERROR:root:Problem in initial value trasfer
# RUN  6 , total integrated cost =  13023.435449555353
# Control only changes marginally.
# RUN  6 , total integrated cost =  13023.435449555353
# Improved over  6  iterations in  0.8985774000002493  seconds by  35.52679655628381  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66188583118635 -56.66382038759846
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16568.218379642258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  345.330917088433
# RUN  2 , total integrated cost =  229.00935237581575
# RUN  3 , total integrated cost =  156.4162563438501
# RUN  4 , total integrated cost =  127.95517378915527
# RUN  5 , total integrated cost =  110.99595817902754
# RUN  6 , total integrated cost =  99.0159781880837
# RUN  7 , total integrated cost =  92.18290741215365
# RUN  8 , total integrated cost =  83.8080975642205
# RUN  9 , total integrated cost =  79.63857239148196
# RUN  10 , total integrated cost =  67.06417728151303
# RUN  11 , total integrated cost =  65.68369368985422
# RUN  12 , total integrated cost =  64.11507266076313
# RUN  13 , total integrated cost =  63.961215467392606
# RUN  14 , total integrated cost =  58.84388950163382
# RUN  15 , total integrated cost =  58.33548429634316
# RUN  16 , total integrated cost =  58.293058492625335
# RUN  17 , total integrated cost =  55.177434166683064
# RUN  18 , total integrated cost =  54.697098017848774
# RUN  19 , total integrated cost =  54.68192608274368
# RUN  20 , total integrated cost =  53.063111893642635
# RUN  30 , total integrated cost =  49.32635402064523
# ERROR:root:Problem in initial value trasfer
# RUN  40 , total integrated cost =  49.32634353489442
# Control only changes marginally.
# RUN  41 , total integrated cost =  49.32634353489442
# Improved over  41  iterations in  4.247098899999401  seconds by  99.70228335718038  percent.
# Problem in initial value trasfer:  Vmean_exc -66.08429911577124 -66.11247880158339
# weight =  3358.898550410812
# set cost params:  1.0 3358.898550410812 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15740.627654912127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13318.073631738844
# RUN  2 , total integrated cost =  12768.121827758663
# RUN  3 , total integrated cost =  10477.585529824088
# RUN  4 , total integrated cost =  10370.667002873488
# RUN  5 , total integrated cost =  10323.945622632029
# RUN  6 , total integrated cost =  10316.156485021667
# RUN  7 , total integrated cost =  10316.152546743464
# RUN  8 , total integrated cost =  10316.152546457834
# RUN  9 , total integrated cost =  10316.152546457188
# RUN  10 , total integrated cost =  10316.152546457182
# RUN  11 , total integrated cost =  10316.15254645718
# RUN  12 , total integrated cost =  10316.152546457179
# ERROR:root:Problem in initial value trasfer
# RUN  13 , total integrated cost =  10316.152546457179
# Control only changes marginally.
# RUN  13 , total integrated cost =  10316.152546457179
# Improved over  13  iterations in  2.005400899999586  seconds by  34.46161885903038  percent.
# Problem in initial value trasfer:  Vmean_exc -56.644555643706674 -56.64588265414051
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7741.667733280556
# Gradient descend method:  None
# RUN  1 , total integrated cost =  94.13857817916767
# RUN  2 , total integrated cost =  69.65021794166456
# RUN  3 , total integrated cost =  46.47246874573712
# RUN  4 , total integrated cost =  38.248148324878755
# RUN  5 , total integrated cost =  30.85294759131501
# RUN  6 , total integrated cost =  25.221386632517476
# RUN  7 , total integrated cost =  20.95918014309578
# RUN  8 , total integrated cost =  17.424665081325706
# RUN  9 , total integrated cost =  15.419332081941594
# RUN  10 , total integrated cost =  13.041064629316804
# RUN  11 , total integrated cost =  12.106863936031354
# RUN  12 , total integrated cost =  9.690641291248765
# RUN  13 , total integrated cost =  9.648969348050898
# RUN  14 , total integrated cost =  9.61751398980938
# RUN  15 , total integrated cost =  9.54203541043185
# RUN  16 , total integrated cost =  9.524431488220996
# RUN  17 , total integrated cost =  9.464635115331014
# RUN  18 , total integrated cost =  9.368836447042183
# RUN  19 , total integrated cost =  9.358296170369474
# RUN  20 , total integrated cost =  8.26455195431473
# RUN  30 , total integrated cost =  7.945914387316636
# RUN  40 , total integrated cost =  7.795130251849238
# RUN  50 , total integrated cost =  7.121459723598503
# RUN  60 , total integrated cost =  7.03939757981213
# RUN  70 , total integrated cost =  6.942241273587413
# RUN  80 , total integrated cost =  6.942240622256677
# State only changes marginally.
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  86 , total integrated cost =  6.9422406222565085
# Improved over  86  iterations in  9.82645390000016  seconds by  99.9103262906465  percent.
# Problem in initial value trasfer:  Vmean_exc -71.6121244157348 -71.64096106072557
# weight =  11151.540481701426
# set cost params:  1.0 11151.540481701426 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7670.899779855847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7253.970170946718
# RUN  2 , total integrated cost =  7253.237968013487
# RUN  3 , total integrated cost =  7253.033605391974
# RUN  4 , total integrated cost =  7243.72326275413
# RUN  5 , total integrated cost =  7231.4669247179745
# RUN  6 , total integrated cost =  7231.154783283346
# RUN  7 , total integrated cost =  7231.06499271272
# RUN  8 , total integrated cost =  7230.615659636766
# RUN  9 , total integrated cost =  7226.488773833823
# RUN  10 , total integrated cost =  7225.209102965181
# RUN  11 , total integrated cost =  7225.1334588204745
# RUN  12 , total integrated cost =  7224.997844856756
# RUN  13 , total integrated cost =  7176.973430624408
# RUN  14 , total integrated cost =  7160.5350604895675
# RUN  15 , total integrated cost =  7160.535057012808
# RUN  16 , total integrated cost =  7160.53505701259
# RUN  17 , total integrated cost =  7160.535057012574
# RUN  18 , total integrated cost =  7160.535057012572
# RUN  19 , total integrated cost =  7160.535057012562
# ERROR:root:Problem in initial value trasfer
# RUN  20 , total integrated cost =  7160.535057012562
# Control only changes marginally.
# RUN  20 , total integrated cost =  7160.535057012562
# Improved over  20  iterations in  2.640388599999824  seconds by  6.65325760328048  percent.
# Problem in initial value trasfer:  Vmean_exc -62.68154290687797 -62.734192569703055

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
    
    if i != 24:
        continue
    
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 0
# --------- 4
# --------- 8
# --------- 12
# --------- 16
# --------- 20
# --------- 24
# --------- 28
# --------- 32
# --------- 36

# %%
found_solution = []
no_solution = []
factor_iteration = 100.
already_tried = [ [] for _ in range(len(exc)) ]

for k in range(len(i_range)**2):
    print('------------------------------------------------------------')
    print('--------------------', k)
    print('------------------------------------------------------------')
        
    print("found solution: ", found_solution)
    print("no solution: ", no_solution)
    
    if len(i_range) == len(found_solution) + len(no_solution):
        print("found solution for all parameters")
        break


    for i in i_range:
        print("------- ", i, exc[i], inh[i])        

        if np.abs(np.mean(bestState_init[i][0,0,-10:]) - target[i][0,0,-1]) < 0.2 * np.abs(
            np.mean(bestState_init[i][0,0,-10:]) - bestState_init[i][0,0,0]) and np.abs(
            np.mean(bestState_init[i][0,1,-10:]) - target[i][0,1,-1]) < 0.5 * np.abs(
            np.mean(bestState_init[i][0,1,-10:]) - bestState_init[i][0,1,0]) and np.amin(
            bestState_init[i][0,0,:]) > target[i][0,0,-1] - 5. and np.amin(
            bestState_init[i][0,1,:]) > target[i][0,1,-1] - 5.:
            # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
            #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
            if i not in found_solution:
                print("found solution for ", i)
                found_solution.append(i)
            if i in no_solution:
                no_solution.pop(no_solution.index(i))
            continue

            
        closest_ = getclosest(i, found_solution, exc, inh, already_tried[i])
        print("closest index ", closest_)

        weight_ = 100
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
            
        if closest_ != -1:
            control0 = 2. * bestControl_init[closest_][:,:,n_pre-1:-n_post+1]
            if closest_ not in already_tried[i]:
                already_tried[i].append(closest_)
                        
        if closest_ == -1:
            print("all options tried already")
            if i not in no_solution:
                no_solution.append(i)
                continue

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(100 * factor_iteration)

        weights_init[i] = cost.getParams()
        
        print("precision vars = ", prec_vars)

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        j = 1
        while cost_init[i][-j] == 0.:
            j += 1

        weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(10 * factor_iteration)

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
# Out:
# ------------------------------------------------------------
# -------------------- 0
# ------------------------------------------------------------
# found solution:  []
# no solution:  []
# -------  0 0.4000000000000001 0.3500000000000001
# found solution for  0
# -------  4 0.4500000000000001 0.3750000000000001
# found solution for  4
# -------  8 0.47500000000000014 0.40000000000000013
# found solution for  8
# -------  12 0.47500000000000014 0.42500000000000016
# found solution for  12
# -------  16 0.47500000000000014 0.4500000000000002
# found solution for  16
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  24 0.4000000000000001 0.5000000000000002
# [0, 4, 8, 12, 16, 20] []
# closest index  20
# set cost params:  1.0 100.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  920.6320927555195
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.784491460769728
# RUN  2 , total integrated cost =  3.2160773361114363
# RUN  3 , total integrated cost =  3.002987475425794
# RUN  4 , total integrated cost =  2.844409024049785
# RUN  5 , total integrated cost =  2.80851926500741
# RUN  6 , total integrated cost =  2.74942510585643
# RUN  7 , total integrated cost =  2.7154199799989707
# RUN  8 , total integrated cost =  2.509846410905591
# RUN  9 , total integrated cost =  2.384224676506015
# RUN  10 , total integrated cost =  2.37920339017256
# RUN  11 , total integrated cost =  2.3558767643744427
# RUN  12 , total integrated cost =  2.3470081094223643
# RUN  13 , total integrated cost =  2.343841491392593
# RUN  14 , total integrated cost =  2.3236777632309815
# RUN  15 , total integrated cost =  2.3163888188076966
# RUN  16 , total integrated cost =  2.3155872110707776
# RUN  17 , total integrated cost =  2.3040341139970364
# RUN  18 , total integrated cost =  2.2858088875706515
# RUN  19 , total integrated cost =  2.285218915964684
# RUN  20 , total integrated cost =  2.2850593008375526
# ERROR:root:Problem in initial value trasfer
# RUN  30 , total integrated cost =  2.2401522530602875
# Control only changes marginally.
# RUN  30 , total integrated cost =  2.2401522530602875
# Improved over  30  iterations in  5.11115989999962  seconds by  99.75667236991974  percent.
# Problem in initial value trasfer:  Vmean_exc -71.81813128795005 -71.84580805533116
# weight =  13307.04919749
# set cost params:  1.0 13307.04919749 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  286.93349623050386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.23845193116904
# RUN  2 , total integrated cost =  232.23476453721437
# RUN  3 , total integrated cost =  232.23476266011195
# RUN  4 , total integrated cost =  232.23476266011002
# RUN  5 , total integrated cost =  232.2347626601087
# RUN  6 , total integrated cost =  232.23476266010857
# State only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  7 , total integrated cost =  232.23476266010852
# RUN  8 , total integrated cost =  232.23476266010852
# Control only changes marginally.
# RUN  8 , total integrated cost =  232.23476266010852
# Improved over  8  iterations in  2.2912894999990385  seconds by  19.063209520318225  percent.
# Problem in initial value trasfer:  Vmean_exc -67.54175378114704 -67.59639150735028
# -------  28 0.5000000000000002 0.5000000000000002
# found solution for  28
# -------  32 0.47500000000000014 0.5250000000000002
# found solution for  32
# -------  36 0.4250000000000001 0.5500000000000003
# found solution for  36
# ------------------------------------------------------------
# -------------------- 1
# ------------------------------------------------------------
# found solution:  [0, 4, 8, 12, 16, 20, 28, 32, 36]
# no solution:  []
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  8 0.47500000000000014 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  16 0.47500000000000014 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# found solution for  24
# -------  28 0.5000000000000002 0.5000000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# ------------------------------------------------------------
# -------------------- 2
# ------------------------------------------------------------
# found solution:  [0, 4, 8, 12, 16, 20, 28, 32, 36, 24]
# no solution:  []
# found solution for all parameters

# %%
factor_iteration = 20
full_converge = False
conv_init = [[False]*2] * len(exc)

for i in range(len(conv_init)):
    if i not in i_range:
        conv_init[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print("------------------------------------------------")
    print('-------------------------', counter)
    
    if counter > 2:
        break
        
    print(conv_init[::i_stepsize])
    full_converge = True
    
    for conv in conv_init[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range:     
        
        if i != 24:
            continue

        print("------- ", i, exc[i], inh[i])
        
        if conv_init[i] == [True, True]:
            continue
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        j = 1
        while cost_init[i][-j] == 0.:
            j += 1
                       
        weight_ = (factor_we * weights_init[i][1] * cost_uncontrolled[i] / cost_init[i][-j]
                   + factor_ws * weights_init[i][2] * cost_uncontrolled[i] / cost_init[i][-j]) - 1
        
        weight_ = 100000.
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
            
        if j == cost_init[i].shape[0]-1:
            print("converged for ", i)
            if conv_init[i][0]:
                conv_init[i] = [True, True]
            else:
                conv_init[i] = [True, False]
            continue
    
        print("no convergence")
            
    counter += 1
# Out:
# ------------------------------------------------
# ------------------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  100000.0
# set cost params:  1.0 100000.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1664.059425854545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1436.620121188569
# RUN  2 , total integrated cost =  1432.6807753251892
# RUN  3 , total integrated cost =  1418.6670269471358
# RUN  4 , total integrated cost =  1416.2457811787783
# RUN  5 , total integrated cost =  1416.0763271630092
# RUN  6 , total integrated cost =  1415.8667787463223
# RUN  7 , total integrated cost =  1413.4162919407897
# RUN  8 , total integrated cost =  1406.8630685108283
# RUN  9 , total integrated cost =  1406.7262108417729
# RUN  10 , total integrated cost =  1406.7247242991807
# RUN  11 , total integrated cost =  1406.7247220730953
# RUN  12 , total integrated cost =  1406.7247220265895
# RUN  13 , total integrated cost =  1406.7247220249503
# RUN  14 , total integrated cost =  1406.7247220248676
# RUN  15 , total integrated cost =  1406.7247220248644
# RUN  16 , total integrated cost =  1406.7247220248626
# RUN  17 , total integrated cost =  1406.724722024862
# State only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  18 , total integrated cost =  1406.7247220248619
# RUN  19 , total integrated cost =  1406.7247220248619
# Control only changes marginally.
# RUN  19 , total integrated cost =  1406.7247220248619
# Improved over  19  iterations in  3.7102116999994905  seconds by  15.464273681063645  percent.
# Problem in initial value trasfer:  Vmean_exc -60.88075703970318 -60.9258470970278
# converged for  24
# ------------------------------------------------
# ------------------------- 1
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  100000.0
# set cost params:  1.0 100000.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1406.7247220248619
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  1406.7247220248619
# Control only changes marginally.
# RUN  1 , total integrated cost =  1406.7247220248619
# Improved over  1  iterations in  0.4879915000001347  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.88075703970318 -60.9258470970278
# no convergence
# ------------------------------------------------
# ------------------------- 2
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  100000.0
# set cost params:  1.0 100000.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1406.7247220248619
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  1406.7247220248619
# Control only changes marginally.
# RUN  1 , total integrated cost =  1406.7247220248619
# Improved over  1  iterations in  0.5985529999998107  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.88075703970318 -60.9258470970278
# converged for  24
# ------------------------------------------------
# ------------------------- 3

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
