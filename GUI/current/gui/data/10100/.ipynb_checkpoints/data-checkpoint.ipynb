# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\10100
# 10100

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 4
limit = 40
i_range = range(0, limit,i_stepsize)
i_range_0 = range(0, limit,i_stepsize)
i_range_1 = range(0, limit,i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  8 0.47500000000000014 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  16 0.47500000000000014 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5902.406479238383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13602.2666253313
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13602.2666253313
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17551.147823015366
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17551.147823015366
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17571.20016629342
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17571.20016629342
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17340.897955123706
# Gradient descend method:  None
# RUN  0 , total integrated cost =  17340.897955123706
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.9816241341314
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2980.9816241341314
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21313.092781962267
# Gradient descend method:  None
# RUN  0 , total integrated cost =  21313.092781962267
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16568.218379642258
# Gradient descend method:  None
# RUN  0 , total integrated cost =  16568.218379642258
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7741.667733280556
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7741.667733280556
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13602.2666253313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101.76003413797613
# RUN  2 , total integrated cost =  86.51375099376757
# RUN  3 , total integrated cost =  69.12795076359853
# RUN  4 , total integrated cost =  62.40286249302984
# RUN  5 , total integrated cost =  55.291967895886195
# RUN  6 , total integrated cost =  51.04818082069224
# RUN  7 , total integrated cost =  46.9081419495247
# RUN  8 , total integrated cost =  43.631386650266656
# RUN  9 , total integrated cost =  40.85563171635377
# RUN  10 , total integrated cost =  34.00488925922956
# RUN  11 , total integrated cost =  33.09490572147681
# RUN  12 , total integrated cost =  32.87021064467018
# RUN  13 , total integrated cost =  32.61289809888859
# RUN  14 , total integrated cost =  32.582244688277285
# RUN  15 , total integrated cost =  31.457433956574253
# RUN  16 , total integrated cost =  31.218116589837205
# RUN  17 , total integrated cost =  31.206000946913488
# RUN  18 , total integrated cost =  30.20791123501483
# RUN  19 , total integrated cost =  30.106234491185365
# RUN  20 , total integrated cost =  30.097914276962207
# RUN  30 , total integrated cost =  29.709227990599658
# RUN  40 , total integrated cost =  29.335943072013677
# RUN  50 , total integrated cost =  28.21385137691659
# RUN  60 , total integrated cost =  27.783303782431013
# RUN  70 , total integrated cost =  27.78330370625553
# ERROR:root:Problem in initial value trasfer
# RUN  80 , total integrated cost =  27.783303706178142
# Control only changes marginally.
# RUN  84 , total integrated cost =  27.78330370617809
# Improved over  84  iterations in  22.323813900000005  seconds by  99.79574504403232  percent.
# Problem in initial value trasfer:  Vmean_exc -62.35051785674459 -62.35261812227285
# weight =  4895.842038506964
# set cost params:  1.0 0.0 4895.842038506964
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13269.366801951192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12363.141336356133
# RUN  2 , total integrated cost =  12339.41519771009
# RUN  3 , total integrated cost =  12318.77060763873
# RUN  4 , total integrated cost =  12236.904907836331
# RUN  5 , total integrated cost =  12196.785174892026
# RUN  6 , total integrated cost =  12196.576849307185
# RUN  7 , total integrated cost =  12193.543953260547
# RUN  8 , total integrated cost =  12191.827749181864
# RUN  9 , total integrated cost =  12191.760476246423
# RUN  10 , total integrated cost =  12188.934032201285
# RUN  11 , total integrated cost =  12184.544465760071
# RUN  12 , total integrated cost =  12184.44214785606
# RUN  13 , total integrated cost =  12184.422409720422
# RUN  14 , total integrated cost =  12184.406168939715
# RUN  15 , total integrated cost =  12184.346216751823
# RUN  16 , total integrated cost =  12175.30117698633
# RUN  17 , total integrated cost =  12174.91772847162
# RUN  18 , total integrated cost =  12174.917477344487
# RUN  19 , total integrated cost =  12174.917477344481
# ERROR:root:Problem in initial value trasfer
# RUN  20 , total integrated cost =  12174.917477344477
# Control only changes marginally.
# RUN  21 , total integrated cost =  12174.917477344477
# Improved over  21  iterations in  0.9524490999999955  seconds by  8.24793933984688  percent.
# Problem in initial value trasfer:  Vmean_exc -57.5042725963075 -57.49690321304219
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17551.147823015366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126.04961426559234
# RUN  2 , total integrated cost =  107.33059740783882
# RUN  3 , total integrated cost =  83.2431645973395
# RUN  4 , total integrated cost =  74.51736899359668
# RUN  5 , total integrated cost =  65.52982212580403
# RUN  6 , total integrated cost =  60.60019236399125
# RUN  7 , total integrated cost =  55.907283289728895
# RUN  8 , total integrated cost =  51.75180736066079
# RUN  9 , total integrated cost =  48.520585997332105
# RUN  10 , total integrated cost =  41.91455650490177
# RUN  11 , total integrated cost =  40.65248354157291
# RUN  12 , total integrated cost =  40.5716364837716
# RUN  13 , total integrated cost =  40.36666333007438
# RUN  14 , total integrated cost =  40.27108898159989
# RUN  15 , total integrated cost =  40.08473451130352
# RUN  16 , total integrated cost =  39.820307173695724
# RUN  17 , total integrated cost =  39.79100140174436
# RUN  18 , total integrated cost =  38.28553191508468
# RUN  19 , total integrated cost =  38.09119757727279
# RUN  20 , total integrated cost =  38.081201231181204
# RUN  30 , total integrated cost =  37.328209305205164
# RUN  40 , total integrated cost =  37.00719923636872
# RUN  50 , total integrated cost =  36.71072035287478
# RUN  60 , total integrated cost =  35.627315084770544
# RUN  70 , total integrated cost =  34.78911523825963
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  77 , total integrated cost =  34.78911505816675
# Improved over  77  iterations in  3.1006776999999985  seconds by  99.80178438806978  percent.
# Problem in initial value trasfer:  Vmean_exc -61.955454537091036 -61.95810404781841
# weight =  5045.0112897871
# set cost params:  1.0 0.0 5045.0112897871
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17226.538642738215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15995.090825670146
# RUN  2 , total integrated cost =  15784.90293665597
# RUN  3 , total integrated cost =  15708.70123998121
# RUN  4 , total integrated cost =  15707.405496165853
# RUN  5 , total integrated cost =  15700.365335878252
# RUN  6 , total integrated cost =  15696.0412834732
# RUN  7 , total integrated cost =  15694.819506198577
# RUN  8 , total integrated cost =  15691.602488743885
# RUN  9 , total integrated cost =  15690.638956859824
# RUN  10 , total integrated cost =  15688.278973749375
# RUN  11 , total integrated cost =  15683.527783100873
# RUN  12 , total integrated cost =  15683.19813368767
# RUN  13 , total integrated cost =  15681.817213113973
# RUN  14 , total integrated cost =  15677.97888706515
# RUN  15 , total integrated cost =  15677.751127653442
# RUN  16 , total integrated cost =  15677.553403482734
# RUN  17 , total integrated cost =  15671.541925307984
# RUN  18 , total integrated cost =  15668.920654146114
# RUN  19 , total integrated cost =  15668.87466291715
# RUN  20 , total integrated cost =  15668.855225463305
# RUN  30 , total integrated cost =  15663.869698912218
# RUN  40 , total integrated cost =  15660.832748808894
# Control only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  43 , total integrated cost =  15660.83274880872
# Improved over  43  iterations in  1.968376499999998  seconds by  9.088917549838214  percent.
# Problem in initial value trasfer:  Vmean_exc -57.05939016955254 -57.047906367514244
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17571.20016629342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  125.26289955820035
# RUN  2 , total integrated cost =  105.92492925169437
# RUN  3 , total integrated cost =  80.22470706687312
# RUN  4 , total integrated cost =  71.44511409076074
# RUN  5 , total integrated cost =  62.46780298801317
# RUN  6 , total integrated cost =  57.60483108197231
# RUN  7 , total integrated cost =  53.195504903765496
# RUN  8 , total integrated cost =  48.90792142940432
# RUN  9 , total integrated cost =  45.90258293696501
# RUN  10 , total integrated cost =  40.97675562277465
# RUN  11 , total integrated cost =  40.65525293507601
# RUN  12 , total integrated cost =  40.340474756323026
# RUN  13 , total integrated cost =  39.89340326176413
# RUN  14 , total integrated cost =  39.837712217651365
# RUN  15 , total integrated cost =  38.544049653556435
# RUN  16 , total integrated cost =  38.19449820289941
# RUN  17 , total integrated cost =  38.17505753653532
# RUN  18 , total integrated cost =  37.716733363447
# RUN  19 , total integrated cost =  37.478623810292774
# RUN  20 , total integrated cost =  37.46910254526029
# RUN  30 , total integrated cost =  34.99132532127604
# RUN  40 , total integrated cost =  34.883375918627024
# RUN  50 , total integrated cost =  34.62346413174772
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  56 , total integrated cost =  34.623464084171836
# Improved over  56  iterations in  2.382640500000001  seconds by  99.80295333411209  percent.
# Problem in initial value trasfer:  Vmean_exc -64.11962000322453 -64.12345678654788
# weight =  5074.939966600892
# set cost params:  1.0 0.0 5074.939966600892
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17175.01485071173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15584.954764510227
# RUN  2 , total integrated cost =  15578.065625515716
# RUN  3 , total integrated cost =  15513.451006152216
# RUN  4 , total integrated cost =  15486.91155822563
# RUN  5 , total integrated cost =  15486.618374547332
# RUN  6 , total integrated cost =  15467.953156749325
# RUN  7 , total integrated cost =  15463.66607821699
# RUN  8 , total integrated cost =  15463.665557426584
# RUN  9 , total integrated cost =  15463.665546381519
# RUN  10 , total integrated cost =  15463.665545989481
# RUN  11 , total integrated cost =  15463.66554597295
# RUN  12 , total integrated cost =  15463.665545972082
# RUN  13 , total integrated cost =  15463.665545972035
# RUN  14 , total integrated cost =  15463.665545972031
# RUN  15 , total integrated cost =  15463.665545972028
# ERROR:root:Problem in initial value trasfer
# RUN  16 , total integrated cost =  15463.665545972028
# Control only changes marginally.
# RUN  16 , total integrated cost =  15463.665545972028
# Improved over  16  iterations in  0.6646344999999982  seconds by  9.96417947591344  percent.
# Problem in initial value trasfer:  Vmean_exc -57.32845768396951 -57.31849052783209
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17340.897955123706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123.780595847549
# RUN  2 , total integrated cost =  105.44591638926866
# RUN  3 , total integrated cost =  79.61422420249312
# RUN  4 , total integrated cost =  70.87763471481495
# RUN  5 , total integrated cost =  61.644226364637476
# RUN  6 , total integrated cost =  56.7935082280461
# RUN  7 , total integrated cost =  52.65287847342662
# RUN  8 , total integrated cost =  49.52051864195335
# RUN  9 , total integrated cost =  47.157182505851665
# RUN  10 , total integrated cost =  42.97096293017647
# RUN  11 , total integrated cost =  41.62169125369616
# RUN  12 , total integrated cost =  41.29715933157572
# RUN  13 , total integrated cost =  40.77461328811227
# RUN  14 , total integrated cost =  40.64088533717462
# RUN  15 , total integrated cost =  38.702654436738996
# RUN  16 , total integrated cost =  38.32811459973941
# RUN  17 , total integrated cost =  38.2915063082881
# RUN  18 , total integrated cost =  37.996237082602
# RUN  19 , total integrated cost =  37.85689138618997
# RUN  20 , total integrated cost =  37.83400163992749
# RUN  30 , total integrated cost =  35.759058641873565
# RUN  40 , total integrated cost =  34.365645037595506
# RUN  50 , total integrated cost =  33.562058358620185
# RUN  60 , total integrated cost =  33.49515525652624
# RUN  70 , total integrated cost =  33.430439466703405
# ERROR:root:Problem in initial value trasfer
# RUN  80 , total integrated cost =  33.4304226934387
# Control only changes marginally.
# RUN  81 , total integrated cost =  33.4304226934387
# Improved over  81  iterations in  3.147457199999998  seconds by  99.80721631152001  percent.
# Problem in initial value trasfer:  Vmean_exc -65.24092015663322 -65.24957784772056
# weight =  5187.160842727591
# set cost params:  1.0 0.0 5187.160842727591
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16967.694113814963
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15561.791259749769
# RUN  2 , total integrated cost =  15552.818486293821
# RUN  3 , total integrated cost =  15550.86344464697
# RUN  4 , total integrated cost =  15546.90095721894
# RUN  5 , total integrated cost =  15545.662095731748
# RUN  6 , total integrated cost =  15501.667164227994
# RUN  7 , total integrated cost =  15495.239262123474
# RUN  8 , total integrated cost =  15495.224360387985
# RUN  9 , total integrated cost =  15495.224088481009
# RUN  10 , total integrated cost =  15495.224080379849
# RUN  11 , total integrated cost =  15495.22408008285
# RUN  12 , total integrated cost =  15495.224080071574
# RUN  13 , total integrated cost =  15495.224080071246
# ERROR:root:Problem in initial value trasfer
# RUN  14 , total integrated cost =  15495.224080071233
# RUN  15 , total integrated cost =  15495.224080071226
# RUN  16 , total integrated cost =  15495.224080071226
# Control only changes marginally.
# RUN  16 , total integrated cost =  15495.224080071226
# Improved over  16  iterations in  0.6736636999999988  seconds by  8.678079790139918  percent.
# Problem in initial value trasfer:  Vmean_exc -57.678201325902705 -57.670167620784355
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.9816241341314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9666061261806185
# RUN  2 , total integrated cost =  3.5559717665715347
# RUN  3 , total integrated cost =  2.6677045075341037
# RUN  4 , total integrated cost =  2.6128769212558876
# RUN  5 , total integrated cost =  2.5591544355263336
# RUN  6 , total integrated cost =  2.4609212339799615
# RUN  7 , total integrated cost =  2.3381928148770283
# RUN  8 , total integrated cost =  2.3187086319189985
# RUN  9 , total integrated cost =  2.296473718273509
# RUN  10 , total integrated cost =  2.289360556752046
# RUN  11 , total integrated cost =  2.252680578738653
# RUN  12 , total integrated cost =  2.225559554259494
# RUN  13 , total integrated cost =  2.2216261094051255
# RUN  14 , total integrated cost =  2.210972833658833
# RUN  15 , total integrated cost =  2.207653644391518
# RUN  16 , total integrated cost =  2.201694390209207
# RUN  17 , total integrated cost =  2.1917297123706416
# RUN  18 , total integrated cost =  2.1906887625591387
# RUN  19 , total integrated cost =  2.1892782209460706
# RUN  20 , total integrated cost =  2.1823449996874436
# RUN  30 , total integrated cost =  2.164667821910779
# RUN  40 , total integrated cost =  2.1646029692973476
# ERROR:root:Problem in initial value trasfer
# RUN  50 , total integrated cost =  2.1584962518967536
# Control only changes marginally.
# RUN  50 , total integrated cost =  2.1584962518967536
# Improved over  50  iterations in  2.0000445000000013  seconds by  99.92759109165848  percent.
# Problem in initial value trasfer:  Vmean_exc -72.06752931961749 -72.09393341615963
# weight =  13810.455410865914
# set cost params:  1.0 0.0 13810.455410865914
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2923.1599138057586
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2360.5148535850713
# RUN  2 , total integrated cost =  2360.1909536764256
# RUN  3 , total integrated cost =  2358.9558926182735
# RUN  4 , total integrated cost =  2350.826903134218
# RUN  5 , total integrated cost =  2350.058070373863
# RUN  6 , total integrated cost =  2350.0531769920262
# RUN  7 , total integrated cost =  2350.0530770868304
# RUN  8 , total integrated cost =  2350.053075250053
# RUN  9 , total integrated cost =  2350.0530752248806
# ERROR:root:Problem in initial value trasfer
# RUN  10 , total integrated cost =  2350.0530752248765
# RUN  11 , total integrated cost =  2350.053075224873
# RUN  12 , total integrated cost =  2350.0530752248724
# State only changes marginally.
# RUN  13 , total integrated cost =  2350.0530752248724
# Control only changes marginally.
# RUN  13 , total integrated cost =  2350.0530752248724
# Improved over  13  iterations in  0.631235199999999  seconds by  19.605729945671698  percent.
# Problem in initial value trasfer:  Vmean_exc -61.42700759857775 -61.4774382654262
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21313.092781962267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146.58078836357004
# RUN  2 , total integrated cost =  121.09010956488788
# RUN  3 , total integrated cost =  90.27430316582056
# RUN  4 , total integrated cost =  80.50096771611231
# RUN  5 , total integrated cost =  69.8640436836661
# RUN  6 , total integrated cost =  64.19824230490966
# RUN  7 , total integrated cost =  59.36522764028325
# RUN  8 , total integrated cost =  55.62196211513578
# RUN  9 , total integrated cost =  53.010140181832774
# RUN  10 , total integrated cost =  49.140079865694595
# RUN  11 , total integrated cost =  47.98520403425371
# RUN  12 , total integrated cost =  47.847846181379154
# RUN  13 , total integrated cost =  47.41038134372437
# RUN  14 , total integrated cost =  47.23493318630419
# RUN  15 , total integrated cost =  46.894045706639915
# RUN  16 , total integrated cost =  46.32181025321389
# RUN  17 , total integrated cost =  46.260472528393436
# RUN  18 , total integrated cost =  44.20279975051944
# RUN  19 , total integrated cost =  44.102337877623704
# RUN  20 , total integrated cost =  44.086702798831574
# RUN  30 , total integrated cost =  42.411878994397874
# RUN  40 , total integrated cost =  41.31376563621231
# RUN  50 , total integrated cost =  40.35828838949381
# RUN  60 , total integrated cost =  39.93518309811473
# RUN  70 , total integrated cost =  39.765119774573584
# RUN  80 , total integrated cost =  39.76511974529057
# RUN  90 , total integrated cost =  39.76511971800652
# ERROR:root:Problem in initial value trasfer
# RUN  100 , total integrated cost =  39.76511970161086
# Control only changes marginally.
# RUN  101 , total integrated cost =  39.76511970161086
# Improved over  101  iterations in  3.7781689000000043  seconds by  99.81342398258002  percent.
# Problem in initial value trasfer:  Vmean_exc -65.2007702517698 -65.21402093360365
# weight =  5359.745662000079
# set cost params:  1.0 0.0 5359.745662000079
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20832.84052108275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19216.0384007725
# RUN  2 , total integrated cost =  19206.013845965117
# RUN  3 , total integrated cost =  19203.03119786825
# RUN  4 , total integrated cost =  19195.293956518628
# RUN  5 , total integrated cost =  19189.838462612835
# RUN  6 , total integrated cost =  19111.651864072526
# RUN  7 , total integrated cost =  19079.985550104164
# RUN  8 , total integrated cost =  19079.6885887278
# RUN  9 , total integrated cost =  19079.381028924956
# RUN  10 , total integrated cost =  19077.51768538053
# RUN  11 , total integrated cost =  19076.869514962716
# RUN  12 , total integrated cost =  19076.754267432214
# RUN  13 , total integrated cost =  19064.525091969605
# RUN  14 , total integrated cost =  19057.40677814715
# RUN  15 , total integrated cost =  19057.406778147142
# RUN  16 , total integrated cost =  19057.40677814714
# RUN  17 , total integrated cost =  19057.406778147135
# RUN
# ERROR:root:Problem in initial value trasfer
#  18 , total integrated cost =  19057.406778147135
# Control only changes marginally.
# RUN  18 , total integrated cost =  19057.406778147135
# Improved over  18  iterations in  0.7744205999999991  seconds by  8.522283560606553  percent.
# Problem in initial value trasfer:  Vmean_exc -57.33432891401494 -57.32233528746195
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16568.218379642258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.67861970189698
# RUN  2 , total integrated cost =  102.86040294674716
# RUN  3 , total integrated cost =  76.96655979474613
# RUN  4 , total integrated cost =  68.38379454177516
# RUN  5 , total integrated cost =  57.986439188554144
# RUN  6 , total integrated cost =  51.51826417364583
# RUN  7 , total integrated cost =  46.064950499650536
# RUN  8 , total integrated cost =  42.90528865605861
# RUN  9 , total integrated cost =  41.300078804107606
# RUN  10 , total integrated cost =  38.35041409767516
# RUN  11 , total integrated cost =  37.84750597856472
# RUN  12 , total integrated cost =  37.69510650134242
# RUN  13 , total integrated cost =  37.359222263069256
# RUN  14 , total integrated cost =  37.28816166433945
# RUN  15 , total integrated cost =  35.14845961574549
# RUN  16 , total integrated cost =  34.90968376958732
# RUN  17 , total integrated cost =  34.81587673557737
# RUN  18 , total integrated cost =  34.72354161174664
# RUN  19 , total integrated cost =  34.52880930308529
# RUN  20 , total integrated cost =  34.497934779079635
# RUN  30 , total integrated cost =  33.704160998556326
# RUN  40 , total integrated cost =  31.605841707827324
# ERROR:root:Problem in initial value trasfer
# RUN  50 , total integrated cost =  31.197088023815212
# Control only changes marginally.
# RUN  50 , total integrated cost =  31.197088023815212
# Improved over  50  iterations in  1.7540231999999918  seconds by  99.81170523402717  percent.
# Problem in initial value trasfer:  Vmean_exc -67.30670446699733 -67.32821851485932
# weight =  5310.822076404831
# set cost params:  1.0 0.0 5310.822076404831
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16257.269336021194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15042.85336431525
# RUN  2 , total integrated cost =  15037.247590398469
# RUN  3 , total integrated cost =  15036.929997187533
# RUN  4 , total integrated cost =  15016.69037805561
# RUN  5 , total integrated cost =  15004.120107343471
# RUN  6 , total integrated cost =  15003.96892572482
# RUN  7 , total integrated cost =  15003.945317323289
# RUN  8 , total integrated cost =  14983.526490544347
# RUN  9 , total integrated cost =  14980.080052441073
# RUN  10 , total integrated cost =  14980.073840479296
# RUN  11 , total integrated cost =  14980.07380765559
# ERROR:root:Problem in initial value trasfer
# RUN  12 , total integrated cost =  14980.073807262863
# RUN  13 , total integrated cost =  14980.073807255034
# RUN  14 , total integrated cost =  14980.073807255034
# Control only changes marginally.
# RUN  14 , total integrated cost =  14980.073807255034
# Improved over  14  iterations in  0.5374674000000113  seconds by  7.856150392589484  percent.
# Problem in initial value trasfer:  Vmean_exc -58.166830529786424 -58.16572532767258
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7741.667733280556
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.69871744633307
# RUN  2 , total integrated cost =  44.736576440603564
# RUN  3 , total integrated cost =  30.020060572635458
# RUN  4 , total integrated cost =  27.57190034396825
# RUN  5 , total integrated cost =  24.821951672155574
# RUN  6 , total integrated cost =  23.16395713107733
# RUN  7 , total integrated cost =  21.40334478740376
# RUN  8 , total integrated cost =  20.015661875658456
# RUN  9 , total integrated cost =  18.802626314606563
# RUN  10 , total integrated cost =  17.0984979010211
# RUN  11 , total integrated cost =  16.091885856676445
# RUN  12 , total integrated cost =  15.84011793432012
# RUN  13 , total integrated cost =  15.543061181040782
# RUN  14 , total integrated cost =  15.486794635847133
# RUN  15 , total integrated cost =  15.294227290956375
# RUN  16 , total integrated cost =  15.160696813841048
# RUN  17 , total integrated cost =  13.708354030855437
# RUN  18 , total integrated cost =  13.658690544773387
# RUN  19 , total integrated cost =  13.650295092769245
# RUN  20 , total integrated cost =  13.588942027879606
# RUN  30 , total integrated cost =  13.218186220824284
# RUN  40 , total integrated cost =  12.755006044602942
# RUN  50 , total integrated cost =  12.68970436256504
# RUN  60 , total integrated cost =  12.575203532105524
# RUN  70 , total integrated cost =  12.456455755055742
# RUN  80 , total integrated cost =  12.42071593572792
# RUN  90 , total integrated cost =  12.3022447336331
# RUN  100 , total integrated cost =  12.186475179601798
# RUN  110 , total integrated cost =  12.186475147690492
# RUN  120 , total integrated cost =  12.186475145317079
# RUN  130 , total integrated cost =  12.186475145038335
# RUN  140 , total integrated cost =  12.186475144990021
# RUN  150 , total integrated cost =  12.18647514498079
# RUN  160 , total integrated cost =  12.186475144979102
# RUN  170 , total integrated cost =  12.18647514497878
# Control only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  175 , total integrated cost =  12.186475144978742
# Improved over  175  iterations in  5.616691799999998  seconds by  99.84258591863107  percent.
# Problem in initial value trasfer:  Vmean_exc -71.4309575856798 -71.46070039093351
# weight =  6352.671827727311
# set cost params:  1.0 0.0 6352.671827727311
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7676.795878665028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7316.707879421836
# RUN  2 , total integrated cost =  7316.200088622417
# RUN  3 , total integrated cost =  7316.199781637911
# RUN  4 , total integrated cost =  7316.19977471563
# RUN  5 , total integrated cost =  7316.1997744618775
# RUN  6 , total integrated cost =  7316.1997744485025
# RUN  7 , total integrated cost =  7316.1997744481505
# RUN  8 , total integrated cost =  7316.199774448138
# RUN  9 , total integrated cost =  7316.199774448133
# RUN  10 , total integrated cost =  7316.199774448131
# RUN  11 , total integrated cost =  7316.199774448131
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  11 , total integrated cost =  7316.199774448131
# Improved over  11  iterations in  0.4118200999999999  seconds by  4.69722146995008  percent.
# Problem in initial value trasfer:  Vmean_exc -62.89785320956361 -62.95106343963142

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 0
# --------- 4
# --------- 8
# --------- 12
# --------- 16
# --------- 20
# --------- 24
# --------- 28
# --------- 32
# --------- 36

# %%
found_solution = []
no_solution = []
factor_iteration = 0.
already_tried = [ [] for _ in range(len(exc)) ]

for k in range(len(i_range)**2):
    print('------------------------------------------------------------')
    print('--------------------', k)
    print('------------------------------------------------------------')
        
    print("found solution: ", found_solution)
    print("no solution: ", no_solution)
    
    if len(i_range) == len(found_solution) + len(no_solution):
        print("found solution for all parameters")
        break


    for i in i_range:
        print("------- ", i, exc[i], inh[i])   

        if np.abs(np.mean(bestState_init[i][0,0,-50:]) - target[i][0,0,-1]) < 0.2 * np.abs(
            np.mean(bestState_init[i][0,0,-15000:]) - bestState_init[i][0,0,0]) and np.abs(
            np.mean(bestState_init[i][0,1,-50:]) - target[i][0,1,-1]) < 0.2 * np.abs(
            np.mean(bestState_init[i][0,1,-50:]) - bestState_init[i][0,1,0]) and np.amin(
            bestState_init[i][0,0,:]) > target[i][0,0,-1] - 5. and np.amin(
            bestState_init[i][0,1,:]) > target[i][0,1,-1] - 5.:
            # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
            #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
            if i not in found_solution:
                print("found solution for ", i)
                found_solution.append(i)
            if i in no_solution:
                no_solution.pop(no_solution.index(i))
            continue
            
        closest_ = getclosest(i, found_solution, exc, inh, already_tried[i])
        print("closest index ", closest_)

        weight_ = 10
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
            
        if i != 0 and closest_ != -1:
            control0 = 6. * bestControl_init[closest_][:,:,n_pre-1:-n_post+1]
            if closest_ not in already_tried[i]:
                already_tried[i].append(closest_)
                        
        if closest_ == -1:
            print("all options tried already")
            if i not in no_solution:
                no_solution.append(i)
                continue

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(100 * factor_iteration)

        weights_init[i] = cost.getParams()
        
        print("precision vars = ", prec_vars)

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        j = 1
        while cost_init[i][-j] == 0.:
            j += 1

        weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(500 * factor_iteration)

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
            
    break
# Out:
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# ------------------------------------------------------------
# -------------------- 0
# ------------------------------------------------------------
# found solution:  []
# no solution:  []
# -------  0 0.4000000000000001 0.3500000000000001
# found solution for  0
# -------  4 0.4500000000000001 0.3750000000000001
# [0] []
# closest index  0
# set cost params:  1.0 0.0 10.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  53.55840912299588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  53.55840912299588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.35648351826303 -61.34650412108933
# weight =  2539.7069943011097
# set cost params:  1.0 0.0 2539.7069943011097
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13354.168543984932
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13354.168543984932
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.35648351826303 -61.34650412108933
# -------  8 0.47500000000000014 0.40000000000000013
# found solution for  8
# -------  12 0.47500000000000014 0.42500000000000016
# found solution for  12
# -------  16 0.47500000000000014 0.4500000000000002
# found solution for  16
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  24 0.4000000000000001 0.5000000000000002
# found solution for  24
# -------  28 0.5000000000000002 0.5000000000000002
# [0, 8, 12, 16, 20, 24] []
# closest index  16
# set cost params:  1.0 0.0 10.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  210.3108771018558
# Gradient descend method:  None
# RUN  0 , total integrated cost =  210.3108771018558
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -75.0840482419199 -75.04984415736597
# weight =  1013.4089627537481
# set cost params:  1.0 0.0 1013.4089627537481
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21313.07329105634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  21313.07329105634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -75.0840482419199 -75.04984415736597
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# -------  32 0.47500000000000014 0.5250000000000002
# [0, 8, 12, 16, 20, 24] []
# closest index  20
# set cost params:  1.0 0.0 10.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  210.3106829269496
# Gradient descend method:  None
# RUN  0 , total integrated cost =  210.3106829269496
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -78.98140299544919 -78.94751539834166
# weight =  787.797279199419
# set cost params:  1.0 0.0 787.797279199419
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16568.21837404424
# Gradient descend method:  None
# RUN  0 , total integrated cost =  16568.21837404424
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -78.98140299544919 -78.94751539834166
# -------  36 0.4250000000000001 0.5500000000000003
# found solution for  36

# %%
factor_iteration = 20
full_converge = False
conv_init = [[False]*2] * len(exc)

for i in range(len(conv_init)):
    if i not in i_range:
        conv_init[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print("------------------------------------------------")
    print('-------------------------', counter)
    
    if counter > 20:
        break
        
    print(conv_init[::i_stepsize])
    full_converge = True
    
    for conv in conv_init[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_init[i] == [True, True]:
            continue
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        j = 1
        while cost_init[i][-j] == 0.:
            j += 1
                       
        weight_ = (factor_we * weights_init[i][1] * cost_uncontrolled[i] / cost_init[i][-j]
                   + factor_ws * weights_init[i][2] * cost_uncontrolled[i] / cost_init[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
            
        if j == cost_init[i].shape[0]-1:
            print("converged for ", i)
            if conv_init[i][0]:
                conv_init[i] = [True, True]
            else:
                conv_init[i] = [True, False]
            continue
    
        print("no convergence")
            
    counter += 1
# Out:
# ERROR:root:Problem in initial value trasfer
# ------------------------------------------------
# ------------------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  6664.949872655732
# set cost params:  1.0 0.0 6664.949872655732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5901.521023063045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5901.521023063045
# Control only changes marginally.
# RUN  1 , total integrated cost =  5901.521023063045
# Improved over  1  iterations in  0.11109740000028978  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.47599299796212 -61.50901739792505
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# weight =  5481.021055280871
# set cost params:  1.0 0.0 5481.021055280871
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13599.78537498801
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  13599.78537498801
# Control only changes marginally.
# RUN  1 , total integrated cost =  13599.78537498801
# Improved over  1  iterations in  0.06877900000108639  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.32980177138177 -60.34034851979276
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# weight =  5577.578769134116
# set cost params:  1.0 0.0 5577.578769134116
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17548.001654690182
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17548.001654690182
# Control only changes marginally.
# RUN  1 , total integrated cost =  17548.001654690182
# Improved over  1  iterations in  0.07133240000075602  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -59.67944093193857 -59.681442867038044
# converged for
# ERROR:root:Problem in initial value trasfer
#  8
# -------  12 0.47500000000000014 0.42500000000000016
# weight =  5747.292591157646
# set cost params:  1.0 0.0 5747.292591157646
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17568.14339771603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17568.14339771603
# Control only changes marginally.
# RUN  1 , total integrated cost =  17568.14339771603
# Improved over  1  iterations in  0.07341059999998834  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.947211552315764 -60.95994428933848
# converged for  12
# -------  16 0.47500000000000014 0.4500000000000002
# weight =  5814.25420744869
# set cost params:  1.0 0.0 5814.25420744869
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17337.915987812125
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17337.915987812125
# Control only changes marginally.
# RUN  1 , total integrated cost =  17337.915987812125
# Improved over  1  iterations in  0.08043560000078287  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.78737353560361 -61.80807438612132
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  5899.654434313295
# set cost params:  1.0 0.0 5899.654434313295
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12735.957686935424
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12735.957686935424
# Control only changes marginally.
# RUN  1 , total integrated cost =  12735.957686935424
# Improved over  1  iterations in  0.07599590000063472  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -63.74171848766652 -63.77977019851806
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  17883.833410710045
# set cost params:  1.0 0.0 17883.833410710045
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.8149324904934
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  2980.8149324904934
# Control only changes marginally.
# RUN  1 , total integrated cost =  2980.8149324904934
# Improved over  1  iterations in  0.07537210000009509  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.17623329886991 -60.21447020733831
# converged for  24
# -------  28 0.5000000000000002 0.5000000000000002
# weight =  5973.485549546596
# set cost params:  1.0 0.0 5973.485549546596
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21309.525429994428
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21309.525429994428
# Control only changes marginally.
# RUN  1 , total integrated cost =  21309.525429994428
# Improved over  1  iterations in  0.07078829999954905  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.49049266355501 -61.50732081204454
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# weight =  5902.03344385999
# set cost params:  1.0 0.0 5902.03344385999
# interpolate adjoint :  True True True
# RUN
# ERROR:root:Problem in initial value trasfer
# 0 , total integrated cost =  16565.411650095964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16565.411650095964
# Control only changes marginally.
# RUN  1 , total integrated cost =  16565.411650095964
# Improved over  1  iterations in  0.07456220000130998  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -63.30484074458829 -63.33905398899505
# no convergence
# -------  36 0.4250000000000001 0.5500000000000003
# weight =  6724.82782248055
# set cost params:  1.0 0.0 6724.82782248055
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7740.516697610656
# Gradient descend method:  None
# RUN  1 , total integrated cost =
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
#  7740.516697610656
# Control only changes marginally.
# RUN  1 , total integrated cost =  7740.516697610656
# Improved over  1  iterations in  0.08022669999991194  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -62.71672971273203 -62.76947320870609
# converged for  36
# ------------------------------------------------
# ------------------------- 1
# [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  6664.949872655732
# set cost params:  1.0 0.0 6664.949872655732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5901.521023063045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5901.521023063045
# Control only changes marginally.
# RUN  1 , total integrated cost =  5901.521023063045
# Improved over  1  iterations in  0.0714561999993748  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.47599299796212 -61.50901739792505
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# weight =
# ERROR:root:Problem in initial value trasfer
#  5481.021055280871
# set cost params:  1.0 0.0 5481.021055280871
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13599.78537498801
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13599.78537498801
# Control only changes marginally.
# RUN  1 , total integrated cost =  13599.78537498801
# Improved over  1  iterations in  0.07092440000087663  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.32980177138177 -60.34034851979276
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# weight =  5577.578769134115
# set cost params:  1.0 0.0 5577.578769134115
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17548.00165469018
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17548.00165469018
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  17548.00165469018
# Improved over  1  iterations in  0.07083250000141561  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -59.67944093193857 -59.681442867038044
# converged for  8
# -------  12 0.47500000000000014 0.42500000000000016
# weight =  5747.292591157646
# set cost params:  1.0 0.0 5747.292591157646
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17568.14339771603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17568.14339771603
# Control only changes marginally.
# RUN  1 , total integrated cost =  17568.14339771603
# Improved over  1  iterations in  0.07822529999975814  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.947211552315764 -60.95994428933848
# converged for  12
# -------  16
# ERROR:root:Problem in initial value trasfer
#  0.47500000000000014 0.4500000000000002
# weight =  5814.254207448692
# set cost params:  1.0 0.0 5814.254207448692
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17337.91598781213
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17337.91598781213
# Control only changes marginally.
# RUN  1 , total integrated cost =  17337.91598781213
# Improved over  1  iterations in  0.07404869999845687  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.78737353560361 -61.80807438612132
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  5899.654434313294
# set cost params:  1.0 0.0 5899.654434313294
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12735.957686935422
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12735.957686935422
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  12735.957686935422
# Improved over  1  iterations in  0.06927550000000338  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -63.74171848766652 -63.77977019851806
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  17883.833501508467
# set cost params:  1.0 0.0 17883.833501508467
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.8149464020426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2980.8149464020426
# Control only changes marginally.
# RUN  1 , total integrated cost =  2980.8149464020426
# Improved over  1  iterations in  0.07676749999882304  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.17623329886991 -60.21447020733831
# converged for
# ERROR:root:Problem in initial value trasfer
# 24
# -------  28 0.5000000000000002 0.5000000000000002
# weight =  5973.485549546598
# set cost params:  1.0 0.0 5973.485549546598
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21309.525429994435
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21309.525429994435
# Control only changes marginally.
# RUN  1 , total integrated cost =  21309.525429994435
# Improved over  1  iterations in  0.07092899999952351  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.49049266355501 -61.50732081204454
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# weight =  5902.03344385999
# set cost params:  1.0 0.0 5902.03344385999
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16565.411650095964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16565.411650095964
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  16565.411650095964
# Improved over  1  iterations in  0.07020379999994475  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -63.30484074458829 -63.33905398899505
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# weight =  6724.82782248055
# set cost params:  1.0 0.0 6724.82782248055
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7740.516697610656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7740.516697610656
# Control only changes marginally.
# RUN  1 , total integrated cost =  7740.516697610656
# Improved over  1  iterations in  0.0743268000005628  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -62.71672971273203 -62.76947320870609
# converged for  36
# ------------------------------------------------
# ------------------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  8 0.47500000000000014 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  16 0.47500000000000014 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# weight =  5902.03344385999
# set cost params:  1.0 0.0 5902.03344385999
# interpolate adjoint :  True True True
# ERROR:root:Problem in initial value trasfer
# RUN  0 , total integrated cost =  16565.411650095964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16565.411650095964
# Control only changes marginally.
# RUN  1 , total integrated cost =  16565.411650095964
# Improved over  1  iterations in  0.07527540000046429  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -63.30484074458829 -63.33905398899505
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# ------------------------------------------------
# ------------------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  6664.949872655732
# set cost params:  1.0 0.0 6664.949872655732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5901.521023063045
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5901.521023063045
# Control only changes marginally.
# RUN  1 , total integrated cost =  5901.521023063045
# Improved over  1  iterations in  0.2505919999999975  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.47599299796212 -61.50901739792505
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# weight =  5478.994875558886
# set cost params:  1.0 0.0 5478.994875558886
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13599.784457567597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13599.784457567595
# ERROR:root:Problem in initial value trasfer
# RUN  2 , total integrated cost =  13599.784457567595
# Control only changes marginally.
# RUN  2 , total integrated cost =  13599.784457567595
# Improved over  2  iterations in  0.5160988999999887  seconds by  1.4210854715202004e-14  percent.
# Problem in initial value trasfer:  Vmean_exc -57.38062749501374 -57.372872422492414
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# weight =  5679.3914223008815
# set cost params:  1.0 0.0 5679.3914223008815
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17548.058044830133
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17548.058044830133
# Control only changes marginally.
# RUN  1 , total integrated cost =  17548.058044830133
# Improved over  1  iterations in  0.3069392000000022  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.91355724695558 -56.903398145865346
# converged for  8
# -------  12 0.47500000000000014 0.42500000000000016
# weight =  5777.072189778425
# set cost params:  1.0 0.0 5777.072189778425
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17568.15915199112
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17568.15915199112
# Control only changes marginally.
# RUN  1 , total integrated cost =  17568.15915199112
# Improved over  1  iterations in  0.3217181999999923  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.2237960897856 -57.21395180618603
# converged for  12
# -------  16 0.47500000000000014 0.4500000000000002
# weight =  5811.983489400766
# set cost params:  1.0 0.0 5811.983489400766
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17337.914822970182
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17337.914822970182
# Control only changes marginally.
# RUN  1 , total integrated cost =  17337.914822970182
# Improved over  1  iterations in  0.32712649999999144  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.52999617293436 -57.521193582042144
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  5837.032487938744
# set cost params:  1.0 0.0 5837.032487938744
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12735.934530852935
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  12735.934530852935
# Control only changes marginally.
# RUN  1 , total integrated cost =  12735.934530852935
# Improved over  1  iterations in  0.31475460000000055  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -59.48169765170342 -59.497822061111705
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  17853.685712774568
# set cost params:  1.0 0.0 17853.685712774568
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.8146520437144
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  2980.8146520437144
# Control only changes marginally.
# RUN  1 , total integrated cost =  2980.8146520437144
# Improved over  1  iterations in  0.2702598999999992  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.18519505632116 -60.22354995067826
# converged for  24
# -------  28 0.5000000000000002 0.5000000000000002
# weight =  6000.5466148251235
# set cost params:  1.0 0.0 6000.5466148251235
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21309.54151523886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21309.541515238856
# ERROR:root:Problem in initial value trasfer
# RUN  2 , total integrated cost =  21309.541515238856
# Control only changes marginally.
# RUN  2 , total integrated cost =  21309.541515238856
# Improved over  2  iterations in  0.5284456999999918  seconds by  2.842170943040401e-14  percent.
# Problem in initial value trasfer:  Vmean_exc -57.25413879493394 -57.24097557801886
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# weight =  5879.092705123669
# set cost params:  1.0 0.0 5879.092705123669
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16565.400699849757
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  16565.400699849757
# Control only changes marginally.
# RUN  1 , total integrated cost =  16565.400699849757
# Improved over  1  iterations in  0.26700979999999674  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.99529882569189 -57.992426503250044
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# weight =  6724.827822480221
# set cost params:  1.0 0.0 6724.827822480221
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7740.51669761028
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  7740.51669761028
# Control only changes marginally.
# RUN  1 , total integrated cost =  7740.51669761028
# Improved over  1  iterations in  0.29838119999999435  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -62.71672971273203 -62.76947320870609
# converged for  36
# --------------- 1
# [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  6664.949872655732
# set cost params:  1.0 0.0 6664.949872655732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5901.521023063045
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5901.521023063045
# Control only changes marginally.
# RUN  1 , total integrated cost =  5901.521023063045
# Improved over  1  iterations in  0.298406099999994  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.47599299796212 -61.50901739792505
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# weight =  5478.994875558889
# set cost params:  1.0 0.0 5478.994875558889
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13599.784457567604
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  13599.784457567604
# Control only changes marginally.
# RUN  1 , total integrated cost =  13599.784457567604
# Improved over  1  iterations in  0.30928230000000667  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.38062749501374 -57.372872422492414
# no convergence
# -------  8 0.47500000000000014 0.40000000000000013
# weight =  5679.391422396458
# set cost params:  1.0 0.0 5679.391422396458
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17548.058045119367
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17548.058045119367
# Control only changes marginally.
# RUN  1 , total integrated cost =  17548.058045119367
# Improved over  1  iterations in  0.28838700000000017  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.91355724695558 -56.903398145865346
# converged for  8
# -------  12 0.47500000000000014 0.42500000000000016
# weight =  5777.072189778571
# set cost params:  1.0 0.0 5777.072189778571
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17568.159151991556
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  17568.159151991556
# Control only changes marginally.
# RUN  1 , total integrated cost =  17568.159151991556
# Improved over  1  iterations in  0.25158890000000156  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.2237960897856 -57.21395180618603
# converged for  12
# -------  16 0.47500000000000014 0.4500000000000002
# weight =  5811.983489400767
# set cost params:  1.0 0.0 5811.983489400767
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17337.914822970186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17337.914822970182
# ERROR:root:Problem in initial value trasfer
# RUN  2 , total integrated cost =  17337.914822970182
# Control only changes marginally.
# RUN  2 , total integrated cost =  17337.914822970182
# Improved over  2  iterations in  0.5989211999999924  seconds by  2.842170943040401e-14  percent.
# Problem in initial value trasfer:  Vmean_exc -57.529996172934 -57.521193582041775
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  5837.032487938744
# set cost params:  1.0 0.0 5837.032487938744
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12735.934530852935
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  12735.934530852935
# Control only changes marginally.
# RUN  1 , total integrated cost =  12735.934530852935
# Improved over  1  iterations in  0.31688760000000116  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -59.48169765170342 -59.497822061111705
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# weight =  17853.685797507467
# set cost params:  1.0 0.0 17853.685797507467
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2980.814665050399
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  2980.814665050399
# Control only changes marginally.
# RUN  1 , total integrated cost =  2980.814665050399
# Improved over  1  iterations in  0.34469949999999017  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -60.18519505632116 -60.22354995067826
# converged for  24
# -------  28 0.5000000000000002 0.5000000000000002
# weight =  6000.546614825136
# set cost params:  1.0 0.0 6000.546614825136
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21309.541515238903
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  21309.541515238903
# Control only changes marginally.
# RUN  1 , total integrated cost =  21309.541515238903
# Improved over  1  iterations in  0.3555508999999972  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.25413879493394 -57.24097557801886
# no convergence
# -------  32 0.47500000000000014 0.5250000000000002
# weight =  5879.09270512449
# set cost params:  1.0 0.0 5879.09270512449
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16565.40069985205
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  16565.40069985205
# Control only changes marginally.
# RUN  1 , total integrated cost =  16565.40069985205
# Improved over  1  iterations in  0.3259734000000094  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.99529882569189 -57.992426503250044
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# weight =  6724.827822480547
# set cost params:  1.0 0.0 6724.827822480547
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7740.516697610652
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  7740.516697610652
# Control only changes marginally.
# RUN  1 , total integrated cost =  7740.516697610652
# Improved over  1  iterations in  0.3760939999999948  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -62.71672971273203 -62.76947320870609
# converged for  36
# --------------- 2
# [[True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# weight =  5478.994875558889
# set cost params:  1.0 0.0 5478.994875558889
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13599.784457567604
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  13599.784457567604
# Control only changes marginally.
# RUN  1 , total integrated cost =  13599.784457567604
# Improved over  1  iterations in  0.31369920000000207  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.38062749501374 -57.372872422492414
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  16 0.47500000000000014 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# weight =  6000.546614825135
# set cost params:  1.0 0.0 6000.546614825135
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21309.5415152389
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  21309.5415152389
# Control only changes marginally.
# RUN  1 , total integrated cost =  21309.5415152389
# Improved over  1  iterations in  0.35755249999999705  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -57.25413879493394 -57.24097557801886
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""
# Out:
# '\nfor i in i_range_0:\n    \n    aln.params.mue_ext_mean = exc[i] * 5.\n    aln.params.mui_ext_mean = inh[i] * 5.\n\n    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],\n        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,\n        dur_pre, dur_post, initVars[i], target[i], \'\', filename_ = \'\', transition_time_ = trans_time,\n        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)\n'

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.0289577608472507
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.0289577608472507
# Control only changes marginally.
# RUN  1 , total integrated cost =  1.0289577608472507
# Improved over  1  iterations in  0.15593760000000145  seconds by  0.0  percent.
# ERROR:root:Problem in initial value trasfer
# Problem in initial value trasfer:  Vmean_exc -62.91531776284406 -62.914637878677766
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  228.05170806858476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.077925226928128
# RUN  2 , total integrated cost =  4.034663123303606
# RUN  3 , total integrated cost =  3.9675398613615407
# RUN  4 , total integrated cost =  3.943762896355028
# RUN  5 , total integrated cost =  3.8015034676196713
# RUN  6 , total integrated cost =  3.6554882101755712
# RUN  7 , total integrated cost =  3.6139322979487813
# RUN  8 , total integrated cost =  3.5490141118416276
# RUN  9 , total integrated cost =  3.5250135797500515
# RUN  10 , total integrated cost =  3.2765623542363764
# RUN  11 , total integrated cost =  3.0047202136269435
# RUN  12 , total integrated cost =  2.9945235649211925
# RUN  13 , total integrated cost =  2.97579825875234
# RUN  14 , total integrated cost =  2.9698252662344826
# RUN  15 , total integrated cost =  2.871023692410308
# RUN  16 , total integrated cost =  2.857864023190646
# RUN  17 , total integrated cost =  2.8578356228938033
# RUN  18 , total integrated cost =  2.857750846562145
# RUN  19 , total integrated cost =  2.856074554902766
# RUN  20 , total integrated cost =  2.8554931976047175
# RUN  30 , total integrated cost =  2.850034839074453
# RUN  40 , total integrated cost =  2.8463192112690336
# RUN  50 , total integrated cost =  2.840852829771831
# RUN  60 , total integrated cost =  2.8408411544441634
# ERROR:root:Problem in initial value trasfer
# RUN  70 , total integrated cost =  2.820590173173172
# Control only changes marginally.
# RUN  74 , total integrated cost =  2.820590173173168
# Improved over  74  iterations in  3.1040683000000087  seconds by  98.76317954508593  percent.
# Problem in initial value trasfer:  Vmean_exc -61.69658653439048 -61.696000935327774
# no convergence
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  364.3599887953253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.182411263775563
# RUN  2 , total integrated cost =  5.128060000050891
# RUN  3 , total integrated cost =  4.957090784041452
# RUN  4 , total integrated cost =  4.783963994639004
# RUN  5 , total integrated cost =  4.452469344181153
# RUN  6 , total integrated cost =  4.245755522802414
# RUN  7 , total integrated cost =  4.204856988747269
# RUN  8 , total integrated cost =  4.13277714541552
# RUN  9 , total integrated cost =  4.096466949745555
# RUN  10 , total integrated cost =  3.778587733658803
# RUN  11 , total integrated cost =  3.6332196161965116
# RUN  12 , total integrated cost =  3.6330855807290043
# RUN  13 , total integrated cost =  3.632759493865679
# RUN  14 , total integrated cost =  3.6306709518283733
# RUN  15 , total integrated cost =  3.630217549898663
# RUN  16 , total integrated cost =  3.6301424564189304
# RUN  17 , total integrated cost =  3.629526532873623
# RUN  18 , total integrated cost =  3.6277023802183743
# RUN  19 , total integrated cost =  3.627534852061113
# RUN  20 , total integrated cost =  3.6274900100738523
# RUN  30 , total integrated cost =  3.619135944945762
# RUN  40 , total integrated cost =  3.610472305975577
# RUN  50 , total integrated cost =  3.608604713621488
# RUN  60 , total integrated cost =  3.5552143862238976
# RUN  70 , total integrated cost =  3.554288496521586
# RUN  80 , total integrated cost =  3.5529510864983704
# RUN  90 , total integrated cost =  3.55295098138111
# RUN  100 , total integrated cost =  3.5366540859454383
# RUN  110 , total integrated cost =  3.5348339264393243
# RUN  120 , total integrated cost =  3.5331836975066038
# RUN  130 , total integrated cost =  3.53317977948328
# RUN  140 , total integrated cost =  3.53317977763664
# RUN  150 , total integrated cost =  3.5331797776166565
# ERROR:root:Problem in initial value trasfer
# RUN  160 , total integrated cost =  3.533179777616398
# Control only changes marginally.
# RUN  163 , total integrated cost =  3.533179777616395
# Improved over  163  iterations in  5.754711499999999  seconds by  99.0303052238809  percent.
# Problem in initial value trasfer:  Vmean_exc -61.61650044280192 -61.61650465194262
# no convergence
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  271.63528305016547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7010098892146797
# RUN  2 , total integrated cost =  3.6901130771979687
# RUN  3 , total integrated cost =  3.6714626659141545
# RUN  4 , total integrated cost =  3.668652226376767
# RUN  5 , total integrated cost =  3.65951831950722
# RUN  6 , total integrated cost =  3.643365336277777
# RUN  7 , total integrated cost =  3.641185754659778
# RUN  8 , total integrated cost =  3.6377181375546206
# RUN  9 , total integrated cost =  3.62677771584489
# RUN  10 , total integrated cost =  3.6244475474908087
# RUN  11 , total integrated cost =  3.6233277959819925
# RUN  12 , total integrated cost =  3.6086556248975414
# RUN  13 , total integrated cost =  3.603032404006296
# RUN  14 , total integrated cost =  3.6026183380578503
# RUN  15 , total integrated cost =  3.597274449871925
# RUN  16 , total integrated cost =  3.586679979453179
# RUN  17 , total integrated cost =  3.586154201509455
# RUN  18 , total integrated cost =  3.5859377862090227
# RUN  19 , total integrated cost =  3.5836711562101886
# RUN  20 , total integrated cost =  3.576108313175307
# RUN  30 , total integrated cost =  3.524694585619568
# ERROR:root:Problem in initial value trasfer
# RUN  40 , total integrated cost =  3.512001238098557
# Control only changes marginally.
# RUN  41 , total integrated cost =  3.512001238098557
# Improved over  41  iterations in  1.4318775999999929  seconds by  98.70708944778357  percent.
# Problem in initial value trasfer:  Vmean_exc -64.16117815629075 -64.16093081771199
# no convergence
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  212.96616043391498
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.511259026307457
# RUN  2 , total integrated cost =  3.510123045071561
# RUN  3 , total integrated cost =  3.509589974545216
# RUN  4 , total integrated cost =  3.453903366978156
# RUN  5 , total integrated cost =  3.448182984691682
# RUN  6 , total integrated cost =  3.44814695256279
# RUN  7 , total integrated cost =  3.4481231682875935
# RUN  8 , total integrated cost =  3.4481066981092137
# RUN  9 , total integrated cost =  3.448074140163239
# RUN  10 , total integrated cost =  3.4475383915190205
# RUN  11 , total integrated cost =  3.4427535668095777
# RUN  12 , total integrated cost =  3.4421313563171245
# RUN  13 , total integrated cost =  3.4421111572710084
# RUN  14 , total integrated cost =  3.442099447787865
# RUN  15 , total integrated cost =  3.4420904120281786
# RUN  16 , total integrated cost =  3.442082852713693
# RUN  17 , total integrated cost =  3.4420482076455636
# RUN  18 , total integrated cost =  3.4416725158797314
# RUN  19 , total integrated cost =  3.436513759843374
# RUN  20 , total integrated cost =  3.435468850685067
# RUN  30 , total integrated cost =  3.3874390711589633
# RUN  40 , total integrated cost =  3.3874223616957564
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  47 , total integrated cost =  3.3874223616952124
# Improved over  47  iterations in  1.540184999999994  seconds by  98.40940816381655  percent.
# Problem in initial value trasfer:  Vmean_exc -66.01691440045502 -66.01929498321942
# no convergence
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3324404253208426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3324404253208426
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.3324404253208426
# Improved over  1  iterations in  0.08155290000000548  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -68.44593577099218 -68.45829003260653
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  240.3885541535775
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.22723471085201907
# RUN  2 , total integrated cost =  0.227115988045249
# RUN  3 , total integrated cost =  0.22656887815240992
# RUN  4 , total integrated cost =  0.2264352393471869
# RUN  5 , total integrated cost =  0.22641479612704457
# RUN  6 , total integrated cost =  0.22634679469575966
# RUN  7 , total integrated cost =  0.22581161673867586
# RUN  8 , total integrated cost =  0.22570416697511642
# RUN  9 , total integrated cost =  0.22569749505039108
# RUN  10 , total integrated cost =  0.2256935601155403
# RUN  11 , total integrated cost =  0.22565966049925817
# RUN  12 , total integrated cost =  0.22507908856734551
# RUN  13 , total integrated cost =  0.22492239169919634
# RUN  14 , total integrated cost =  0.2249200888365863
# RUN  15 , total integrated cost =  0.22491983408861624
# RUN  16 , total integrated cost =  0.22491983408861582
# RUN  17 , total integrated cost =  0.22491983408861552
# ERROR:root:Problem in initial value trasfer
# RUN  18 , total integrated cost =  0.22491983408861552
# Control only changes marginally.
# RUN  18 , total integrated cost =  0.22491983408861552
# Improved over  18  iterations in  0.6582897999999915  seconds by  99.90643488210969  percent.
# Problem in initial value trasfer:  Vmean_exc -72.69402098704563 -72.71732898450598
# no convergence
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  233.85481785715498
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2005815483169835
# RUN  2 , total integrated cost =  4.197704113697653
# RUN  3 , total integrated cost =  4.196304564175918
# RUN  4 , total integrated cost =  4.178138187646025
# RUN  5 , total integrated cost =  4.17075019599464
# RUN  6 , total integrated cost =  4.170443525964614
# RUN  7 , total integrated cost =  4.169954574446452
# RUN  8 , total integrated cost =  4.137980769579011
# RUN  9 , total integrated cost =  4.128406067530797
# RUN  10 , total integrated cost =  4.128371990252134
# RUN  11 , total integrated cost =  4.1283684168748
# RUN  12 , total integrated cost =  4.128367226149459
# RUN  13 , total integrated cost =  4.128367031308622
# RUN  14 , total integrated cost =  4.128366790929385
# RUN  15 , total integrated cost =  4.12836678409776
# ERROR:root:Problem in initial value trasfer
# RUN  16 , total integrated cost =  4.128366783862234
# RUN  17 , total integrated cost =  4.128366783862231
# RUN  18 , total integrated cost =  4.128366783862231
# Control only changes marginally.
# RUN  18 , total integrated cost =  4.128366783862231
# Improved over  18  iterations in  0.6951904999999954  seconds by  98.23464540021409  percent.
# Problem in initial value trasfer:  Vmean_exc -66.3594427632868 -66.36618152576587
# no convergence
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  178.16709852508654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.2563594144147907
# RUN  2 , total integrated cost =  3.2552053461738524
# RUN  3 , total integrated cost =  3.2549624788630993
# RUN  4 , total integrated cost =  3.2527043451023885
# RUN  5 , total integrated cost =  3.2454751997877405
# RUN  6 , total integrated cost =  3.2446569869447326
# RUN  7 , total integrated cost =  3.24454319945539
# RUN  8 , total integrated cost =  3.2442858646341666
# RUN  9 , total integrated cost =  3.2213480019466543
# RUN  10 , total integrated cost =  3.2122086739206908
# RUN  11 , total integrated cost =  3.2121830694028297
# RUN  12 , total integrated cost =  3.2121710710967726
# RUN  13 , total integrated cost =  3.2121624177369643
# RUN  14 , total integrated cost =  3.212156650201498
# RUN  15 , total integrated cost =  3.212135159229461
# RUN  16 , total integrated cost =  3.211781519232627
# RUN  17 , total integrated cost =  3.207051759816228
# RUN  18 , total integrated cost =  3.205792073290303
# RUN  19 , total integrated cost =  3.2057372180109582
# RUN  20 , total integrated cost =  3.205729137914205
# ERROR:root:Problem in initial value trasfer
# RUN  30 , total integrated cost =  3.156989130383002
# Control only changes marginally.
# RUN  31 , total integrated cost =  3.156989130383002
# Improved over  31  iterations in  1.096164200000004  seconds by  98.22807400663906  percent.
# Problem in initial value trasfer:  Vmean_exc -68.28538825115497 -68.30144047033909
# no convergence
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  76.68358220405186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.2397465325905976
# RUN  2 , total integrated cost =  1.239727926452616
# RUN  3 , total integrated cost =  1.2397169204536158
# RUN  4 , total integrated cost =  1.2397042652174448
# RUN  5 , total integrated cost =  1.2392970749832046
# RUN  6 , total integrated cost =  1.2380339011873125
# RUN  7 , total integrated cost =  1.2379808691466716
# RUN  8 , total integrated cost =  1.2379742662985984
# RUN  9 , total integrated cost =  1.2379625012137938
# RUN  10 , total integrated cost =  1.2379187877032662
# RUN  11 , total integrated cost =  1.2355897110807894
# RUN  12 , total integrated cost =  1.2343765951202559
# RUN  13 , total integrated cost =  1.2343652412333814
# RUN  14 , total integrated cost =  1.2343606374936535
# RUN  15 , total integrated cost =  1.234346449298335
# RUN  16 , total integrated cost =  1.2339258258475385
# RUN  17 , total integrated cost =  1.2326877301166506
# RUN  18 , total integrated cost =  1.2326235002189452
# RUN  19 , total integrated cost =  1.232616643516665
# RUN  20 , total integrated cost =  1.2326131919788215
# RUN  30 , total integrated cost =  1.2269820007733252
# RUN  40 , total integrated cost =  1.1933846259444774
# RUN  50 , total integrated cost =  1.1921057653877465
# ERROR:root:Problem in initial value trasfer
# RUN  60 , total integrated cost =  1.1840681626819032
# Control only changes marginally.
# RUN  62 , total integrated cost =  1.1840681626819027
# Improved over  62  iterations in  2.1439457000000033  seconds by  98.45590395147276  percent.
# Problem in initial value trasfer:  Vmean_exc -72.44949530680516 -72.47425430921497
# no convergence
# --------------- 1
# [[True, False], [False, False], [False, False], [False, False], [False, False], [True, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# ERROR:root:Problem in initial value trasfer
# RUN  0 , total integrated cost =  1.0289577608472507
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.0289577608472507
# Control only changes marginally.
# RUN  1 , total integrated cost =  1.0289577608472507
# Improved over  1  iterations in  0.0757097999999985  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -62.91531776284406 -62.914637878677766
# converged for  0
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.820590173173168
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  2.820590173173168
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.820590173173168
# Improved over  1  iterations in  0.08225950000000637  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.69658653439048 -61.696000935327774
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.533179777616395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.533179777616395
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.533179777616395
# Improved over  1  iterations in  0.0788559999999876  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.61650044280192 -61.61650465194262
# ERROR:root:Problem in initial value trasfer
# converged for  8
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.512001238098557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.512001238098557
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.512001238098557
# Improved over  1  iterations in  0.08420069999999669  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -64.16117815629075 -64.16093081771199
# converged for  12
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3874223616952124
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  3.3874223616952124
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3874223616952124
# Improved over  1  iterations in  0.083653599999991  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -66.01691440045502 -66.01929498321942
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3324404253208426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3324404253208426
# Control only changes marginally.
# RUN
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
#  1 , total integrated cost =  2.3324404253208426
# Improved over  1  iterations in  0.10727800000000798  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -68.44593577099218 -68.45829003260653
# converged for  20
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.22491983408861552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.22491983408861552
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.22491983408861552
# Improved over  1  iterations in  0.08715600000000734  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -72.69402098704563 -72.71732898450598
# ERROR:root:Problem in initial value trasfer
# converged for  24
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.128366783862231
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.128366783862231
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.128366783862231
# Improved over  1  iterations in  0.07746840000000077  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -66.3594427632868 -66.36618152576587
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.156989130383002
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  3.156989130383002
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.156989130383002
# Improved over  1  iterations in  0.09061630000000775  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -68.28538825115497 -68.30144047033909
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.1840681626819027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.1840681626819027
# Control only changes marginally.
# RUN  1 , total integrated cost =  1.1840681626819027
# Improved over  1  iterations in  0.0870965999999953  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -72.44949530680516 -72.47425430921497
# ERROR:root:Problem in initial value trasfer
# converged for  36
# --------------- 2
# [[True, True], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.820590173173168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.820590173173168
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.820590173173168
# Improved over  1  iterations in  0.09571970000000363  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.69658653439048 -61.696000935327774
# converged for  4
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.533179777616395
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  3.533179777616395
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.533179777616395
# Improved over  1  iterations in  0.09656970000000342  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -61.61650044280192 -61.61650465194262
# converged for  8
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.512001238098557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.512001238098557
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.512001238098557
# Improved over  1  iterations in  0.0784357  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -64.16117815629075 -64.16093081771199
# ERROR:root:Problem in initial value trasfer
# converged for  12
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3874223616952124
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3874223616952124
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3874223616952124
# Improved over  1  iterations in  0.08207340000001295  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -66.01691440045502 -66.01929498321942
# converged for  16
# -------  20 0.4500000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.22491983408861552
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  0.22491983408861552
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.22491983408861552
# Improved over  1  iterations in  0.10254030000000114  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -72.69402098704563 -72.71732898450598
# converged for  24
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.128366783862231
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.128366783862231
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.128366783862231
# Improved over  1  iterations in  0.08624689999999191  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -66.3594427632868 -66.36618152576587
# ERROR:root:Problem in initial value trasfer
# converged for  28
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.156989130383002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.156989130383002
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.156989130383002
# Improved over  1  iterations in  0.09407219999999938  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -68.28538825115497 -68.30144047033909
# converged for  32
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.1840681626819027
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  1.1840681626819027
# Control only changes marginally.
# RUN  1 , total integrated cost =  1.1840681626819027
# Improved over  1  iterations in  0.08849309999999377  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -72.44949530680516 -72.47425430921497
# converged for  36
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
for i in i_range_0:
    
    print(i)
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_1[i]],
        [costnode_init[i], costnode_1[i]], [weights_init[i], weights_1[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
