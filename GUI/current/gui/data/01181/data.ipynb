# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /mnt/antares_raid/home/salfenmoser/neurolib/GUI/current/gui/data/01181
# 01181

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 5
i_range = range(0, len(exc),i_stepsize)
i_range_0 = range(0, len(exc),i_stepsize)
i_range_1 = range(0, len(exc),i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  65 0.5000000000000002 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  85 0.47500000000000014 0.7250000000000004
# -------  90 0.6000000000000003 0.7250000000000004
# -------  95 0.5250000000000001 0.7500000000000004
# -------  100 0.4500000000000001 0.7750000000000005
# -------  105 0.5750000000000002 0.7750000000000005
# -------  110 0.5000000000000002 0.8000000000000005
# -------  115 0.4250000000000001 0.8250000000000005
# -------  120 0.5500000000000003 0.8250000000000005
# -------  125 0.47500000000000014 0.8500000000000005
# -------  130 0.6000000000000003 0.8500000000000005
# -------  135 0.5250000000000001 0.8750000000000006
# -------  140 0.4500000000000001 0.9000000000000006
# -------  145 0.5750000000000002 0.9000000000000006

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5902.406479238383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5097.289828199723
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5097.289828199723
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9111.456490210901
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9111.456490210901
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13018.074640346456
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13018.074640346456
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8231.907221468136
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8231.907221468136
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7978.317181785681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7978.317181785681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.428984237715
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30546.428984237715
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25531.477705492594
# Gradient descend method:  None
# RUN  0 , total integrated cost =  25531.477705492594
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20627.907894119795
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20627.907894119795
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7112.913357952089
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7112.913357952089
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29795.639845368863
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29795.639845368863
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20071.115113665277
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20071.115113665277
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11109.049056155947
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11109.049056155947
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34495.8289838114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34495.8289838114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24416.866252081658
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24416.866252081658
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15143.755110304457
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15143.755110304457
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39340.86017947994
# Gradient descend method:  None
# RUN  0 , total integrated cost =  39340.86017947994
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24128.44250261018
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24128.44250261018
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10559.709248318897
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10559.709248318897
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33891.050588370264
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33891.050588370264
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19226.098318201533
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19226.098318201533
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5845.286879790712
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5845.286879790712
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28593.126434517075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28593.126434517075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14547.979043359295
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14547.979043359295
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38727.35641379273
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38727.35641379273
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23532.636143093983
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23532.636143093983
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10019.968518582271
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10019.968518582271
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33290.05146687772
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33290.05146687772
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+2000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 18445.854447083333 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5836.724067309356
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5836.724067309356
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 2656.762314606029 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4987.770441754427
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4987.770441754427
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 4107.207495120388 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8830.290357091597
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8830.290357091597
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 5431.982747810483 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12626.144727584258
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12626.144727584258
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 3076.118322826909 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12398.803020888015
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12398.803020888015
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 1013.1001887079943 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8162.5638870502125
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8162.5638870502125
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 755.5410321090092 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7943.908001501325
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7943.908001501325
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 188050.37064589225 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29532.993876179364
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29532.993876179364
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 11074.036722501161 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25227.973809396615
# Gradient descend method:  None
# RUN  0 , total integrated cost =  25227.973809396615
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 3155.438815405054 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20315.814174582985
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20315.814174582985
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1353.9378458536376 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15843.941482963553
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15843.941482963553
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 320.3025481231734 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7079.386023433475
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7079.386023433475
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 12652.44901488818 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29455.899650839787
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29455.899650839787
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 1949.8225715220053 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19908.035168466165
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19908.035168466165
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 495.497065661354 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11057.441083101432
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11057.441083101432
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 30311.567772426115 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34007.40013403707
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34007.40013403707
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 3155.890584332582 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24155.143492937652
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24155.143492937652
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 817.3134464953282 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15052.982316180725
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15052.982316180725
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 227969.2171906956 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  37933.25666418108
# Gradient descend method:  None
# RUN  0 , total integrated cost =  37933.25666418108
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 2706.1437395009852 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23936.467868401636
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23936.467868401636
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 392.166936837599 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10512.729623241234
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10512.729623241234
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 14400.370591091072 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33485.62150191707
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33485.62150191707
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 1286.152851434381 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19092.150668475388
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19092.150668475388
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 160.44681600766512 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5805.479901834196
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5805.479901834196
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 4590.045224691299 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28253.832283488835
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28253.832283488835
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 657.6556215933103 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14467.124335532164
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14467.124335532164
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 44929.6071837498 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38035.88396734908
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38035.88396734908
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 2104.1680900004885 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23344.376784182015
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23344.376784182015
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 329.66748961643873 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9964.133371007505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9964.133371007505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 9415.699437558038 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32939.828382627675
# Gradient descend method:  None
# RUN  0 , total integrated cost =  32939.828382627675
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 0
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 5
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 10
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 15
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 20
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 25
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 30
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 35
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 40
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 45
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 50
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 55
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 60
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 65
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 70
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 75
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 80
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 85
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 90
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 95
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 100
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 105
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 110
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 115
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 120
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 125
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 130
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 135
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 140
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 145
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    


    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# found solution for  0
# -------  5 0.4000000000000001 0.40000000000000013
# found solution for  5
# -------  10 0.4250000000000001 0.42500000000000016
# found solution for  10
# -------  15 0.4500000000000001 0.4500000000000002
# found solution for  15
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  25 0.4250000000000001 0.5000000000000002
# found solution for  25
# -------  30 0.4250000000000001 0.5250000000000002
# found solution for  30
# -------  35 0.5500000000000003 0.5250000000000002
# found solution for  35
# -------  40 0.5250000000000001 0.5500000000000003
# found solution for  40
# -------  45 0.5000000000000002 0.5750000000000003
# found solution for  45
# -------  50 0.47500000000000014 0.6000000000000003
# found solution for  50
# -------  55 0.4250000000000001 0.6250000000000003
# found solution for  55
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  65 0.5000000000000002 0.6500000000000004
# found solution for  65
# -------  70 0.4500000000000001 0.6750000000000004
# found solution for  70
# -------  75 0.5750000000000002 0.6750000000000004
# found solution for  75
# -------  80 0.5250000000000001 0.7000000000000004
# found solution for  80
# -------  85 0.47500000000000014 0.7250000000000004
# found solution for  85
# -------  90 0.6000000000000003 0.7250000000000004
# found solution for  90
# -------  95 0.5250000000000001 0.7500000000000004
# found solution for  95
# -------  100 0.4500000000000001 0.7750000000000005
# found solution for  100
# -------  105 0.5750000000000002 0.7750000000000005
# found solution for  105
# -------  110 0.5000000000000002 0.8000000000000005
# found solution for  110
# -------  115 0.4250000000000001 0.8250000000000005
# found solution for  115
# -------  120 0.5500000000000003 0.8250000000000005
# found solution for  120
# -------  125 0.47500000000000014 0.8500000000000005
# found solution for  125
# -------  130 0.6000000000000003 0.8500000000000005
# found solution for  130
# -------  135 0.5250000000000001 0.8750000000000006
# found solution for  135
# -------  140 0.4500000000000001 0.9000000000000006
# found solution for  140
# -------  145 0.5750000000000002 0.9000000000000006
# found solution for  145

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  20716.274384383414
# set cost params:  1.0 20716.274384383414 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.12157658325
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5902.12157658325
# Control only changes marginally.
# RUN  1 , total integrated cost =  5902.12157658325
# Improved over  1  iterations in  26.241135066375136  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62761344750302 -56.627613510428986
# no convergence
# -------  5 0.4000000000000001 0.40000000000000013
# weight =  2948.5812307752926
# set cost params:  1.0 2948.5812307752926 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5095.561688023329
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5095.561688023329
# Control only changes marginally.
# RUN  1 , total integrated cost =  5095.561688023329
# Improved over  1  iterations in  0.6618201974779367  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.624466161893835 -56.624466107389274
# no convergence
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  4776.481920269487
# set cost params:  1.0 4776.481920269487 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9109.549323079056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9109.549322681534
# RUN  2 , total integrated cost =  9109.54932226444
# RUN  3 , total integrated cost =  9109.549321841047
# RUN  4 , total integrated cost =  9109.549321431485
# RUN  5 , total integrated cost =  9109.549321021363
# RUN  6 , total integrated cost =  9109.549320608992
# RUN  7 , total integrated cost =  9109.549320184376
# RUN  8 , total integrated cost =  9109.549319762275
# RUN  9 , total integrated cost =  9109.549319370512
# RUN  10 , total integrated cost =  9109.549318960058
# RUN  11 , total integrated cost =  9109.54931858338
# RUN  12 , total integrated cost =  9109.549318177162
# RUN  13 , total integrated cost =  9109.549317794183
# RUN  14 , total integrated cost =  9109.549317388595
# RUN  15 , total integrated cost =  9109.549317034925
# RUN  16 , total integrated cost =  9109.549316605462
# RUN  17 , total integrated cost =  9109.549316112923
# RUN  18 , total integrated cost =  9109.549315691975
# RUN  19 , total integrated cost =  9109.549315269063
# RUN  20 , total integrated cost =  9109.54931485972
# RUN  30 , total integrated cost =  9109.549310706325
# RUN  40 , total integrated cost =  9109.549306615665
# RUN  50 , total integrated cost =  9109.549302552208
# RUN  60 , total integrated cost =  9109.5492986179
# RUN  70 , total integrated cost =  9109.549294512486
# RUN  80 , total integrated cost =  9109.549290441084
# RUN  90 , total integrated cost =  9109.549286324356
# RUN  100 , total integrated cost =  9109.54928222798
# RUN  110 , total integrated cost =  9109.549278129536
# RUN  120 , total integrated cost =  9109.549273896264
# RUN  130 , total integrated cost =  9109.549269749668
# RUN  140 , total integrated cost =  9109.549265434593
# RUN  150 , total integrated cost =  9109.549261458773
# RUN  160 , total integrated cost =  9109.54925722646
# RUN  170 , total integrated cost =  9109.549253046422
# RUN  180 , total integrated cost =  9109.549248866937
# RUN  190 , total integrated cost =  9109.549244789883
# RUN  200 , total integrated cost =  9109.549240593824
# RUN  300 , total integrated cost =  9109.549199291583
# RUN  400 , total integrated cost =  9109.54915854215
# RUN  500 , total integrated cost =  9109.549117290926
# RUN  600 , total integrated cost =  9109.549075897106
# RUN  700 , total integrated cost =  9109.54903487829
# RUN  800 , total integrated cost =  9109.548994133957
# RUN  900 , total integrated cost =  9109.548952797086
# RUN  1000 , total integrated cost =  9109.548911335505
# RUN  1100 , total integrated cost =  9109.548869964756
# RUN  1200 , total integrated cost =  9109.548828802232
# RUN  1300 , total integrated cost =  9109.54878747561
# RUN  1400 , total integrated cost =  9109.548746053171
# RUN  1500 , total integrated cost =  9109.54870522859
# RUN  1600 , total integrated cost =  9109.548663652973
# RUN  1700 , total integrated cost =  9109.54862358995
# RUN  1800 , total integrated cost =  9109.548582389714
# RUN  1900 , total integrated cost =  9109.548541217237
# RUN  2000 , total integrated cost =  9109.548500327353
# RUN  3000 , total integrated cost =  9109.548088858875
# RUN  4000 , total integrated cost =  9109.547678620269
# RUN  5000 , total integrated cost =  9109.547266882175
# RUN  6000 , total integrated cost =  9109.546855909606
# RUN  7000 , total integrated cost =  9109.546444096282
# RUN  8000 , total integrated cost =  9109.54603521054
# RUN  9000 , total integrated cost =  9109.545625030807
# ERROR:root:Problem in initial value trasfer
# RUN  10000 , total integrated cost =  9109.545213269967
# RUN  10000 , total integrated cost =  9109.545213269967
# Improved over  10000  iterations in  6035.5919252075255  seconds by  4.511539422935584e-05  percent.
# Problem in initial value trasfer:  Vmean_exc -56.64650846605813 -56.646508480748544
# no convergence
# -------  15 0.4500000000000001 0.4500000000000002
# weight =  6351.629075330926
# set cost params:  1.0 6351.629075330926 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13016.02539829471
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13016.025398294707
# RUN  2 , total integrated cost =  13016.025398294702
# RUN  3 , total integrated cost =  13016.025398294702
# Control only changes marginally.
# RUN  3 , total integrated cost =  13016.025398294702
# Improved over  3  iterations in  4.611331660300493  seconds by  7.105427357601002e-14  percent.
# no convergence
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3585.125282568358
# set cost params:  1.0 3585.125282568358 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.56439465509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.564394655086
# RUN  2 , total integrated cost =  12734.564394655086
# Control only changes marginally.
# RUN  2 , total integrated cost =  12734.564394655086
# Improved over  2  iterations in  3.1772234439849854  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  25 0.4250000000000001 0.5000000000000002
# weight =  1080.1771142361652
# set cost params:  1.0 1080.1771142361652 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8224.293383630566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8224.293383370263
# RUN  2 , total integrated cost =  8224.293383079917
# RUN  3 , total integrated cost =  8224.293382778475
# RUN  4 , total integrated cost =  8224.29338248566
# RUN  5 , total integrated cost =  8224.293382208347
# RUN  6 , total integrated cost =  8224.293381921085
# RUN  7 , total integrated cost =  8224.293381669715
# RUN  8 , total integrated cost =  8224.293381372398
# RUN  9 , total integrated cost =  8224.293381040052
# RUN  10 , total integrated cost =  8224.293380747067
# RUN  11 , total integrated cost =  8224.29338045467
# RUN  12 , total integrated cost =  8224.293380158393
# RUN  13 , total integrated cost =  8224.293379882281
# RUN  14 , total integrated cost =  8224.29337958908
# RUN  15 , total integrated cost =  8224.293379336112
# RUN  16 , total integrated cost =  8224.293379041177
# RUN  17 , total integrated cost =  8224.293378752262
# RUN  18 , total integrated cost =  8224.293378457282
# RUN  19 , total integrated cost =  8224.293378155671
# RUN  20 , total integrated cost =  8224.293377856156
# RUN  30 , total integrated cost =  8224.293374878405
# RUN  40 , total integrated cost =  8224.293371940008
# RUN  50 , total integrated cost =  8224.293368978957
# RUN  60 , total integrated cost =  8224.293365987105
# RUN  70 , total integrated cost =  8224.293363047404
# RUN  80 , total integrated cost =  8224.293360173846
# RUN  90 , total integrated cost =  8224.293357225271
# RUN  100 , total integrated cost =  8224.293354267667
# RUN  110 , total integrated cost =  8224.293351322181
# RUN  120 , total integrated cost =  8224.293348305126
# RUN  130 , total integrated cost =  8224.293345477023
# RUN  140 , total integrated cost =  8224.293342501742
# RUN  150 , total integrated cost =  8224.293339585818
# RUN  160 , total integrated cost =  8224.293336622586
# RUN  170 , total integrated cost =  8224.293333663678
# RUN  180 , total integrated cost =  8224.293330719582
# RUN  190 , total integrated cost =  8224.293327853897
# RUN  200 , total integrated cost =  8224.293324820566
# RUN  300 , total integrated cost =  8224.293295291962
# RUN  400 , total integrated cost =  8224.293265674547
# RUN  500 , total integrated cost =  8224.29323638385
# RUN  600 , total integrated cost =  8224.293206977376
# RUN  700 , total integrated cost =  8224.293177374066
# RUN  800 , total integrated cost =  8224.29314782109
# RUN  900 , total integrated cost =  8224.29311836247
# RUN  1000 , total integrated cost =  8224.29308880307
# RUN  1100 , total integrated cost =  8224.293059448632
# RUN  1200 , total integrated cost =  8224.293030221568
# RUN  1300 , total integrated cost =  8224.29300059174
# RUN  1400 , total integrated cost =  8224.292971113227
# RUN  1500 , total integrated cost =  8224.292941672773
# RUN  1600 , total integrated cost =  8224.292912120422
# RUN  1700 , total integrated cost =  8224.292882634854
# RUN  1800 , total integrated cost =  8224.292853310812
# RUN  1900 , total integrated cost =  8224.292823985734
# RUN  2000 , total integrated cost =  8224.292794505802
# RUN  3000 , total integrated cost =  8224.29249997238
# RUN  4000 , total integrated cost =  8224.292205759622
# RUN  5000 , total integrated cost =  8224.291910952685
# RUN  6000 , total integrated cost =  8224.291616188595
# RUN  7000 , total integrated cost =  8224.291320864373
# RUN  8000 , total integrated cost =  8224.291026393077
# RUN  9000 , total integrated cost =  8224.290731491992
# RUN  10000 , total integrated cost =  8224.290437152204
# RUN  10000 , total integrated cost =  8224.290437152204
# Improved over  10000  iterations in  6234.048107750714  seconds by  3.582652301759026e-05  percent.
# no convergence
# -------  30 0.4250000000000001 0.5250000000000002
# weight =  787.4531612986225
# set cost params:  1.0 787.4531612986225 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7968.19823297123
# Gradient descend method:  None

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
