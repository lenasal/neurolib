# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /mnt/antares_raid/home/salfenmoser/neurolib/GUI/current/gui/data/01141
# 01141

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])
# Out:
# /mnt/antares_raid/home/salfenmoser/neurolib/GUI/current/gui/data/01110/control_init_01110.pickle

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 5
i_range = range(0, len(exc),i_stepsize)
i_range_0 = range(0, len(exc),i_stepsize)
i_range_1 = range(0, len(exc),i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  65 0.5000000000000002 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  85 0.47500000000000014 0.7250000000000004
# -------  90 0.6000000000000003 0.7250000000000004
# -------  95 0.5250000000000001 0.7500000000000004
# -------  100 0.4500000000000001 0.7750000000000005
# -------  105 0.5750000000000002 0.7750000000000005
# -------  110 0.5000000000000002 0.8000000000000005
# -------  115 0.4250000000000001 0.8250000000000005
# -------  120 0.5500000000000003 0.8250000000000005
# -------  125 0.47500000000000014 0.8500000000000005
# -------  130 0.6000000000000003 0.8500000000000005
# -------  135 0.5250000000000001 0.8750000000000006
# -------  140 0.4500000000000001 0.9000000000000006
# -------  145 0.5750000000000002 0.9000000000000006

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.406479238383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5902.406479238383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5097.289828199723
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5097.289828199723
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9111.456490210901
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9111.456490210901
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13018.074640346456
# Gradient descend method:  None
# RUN  0 , total integrated cost =  13018.074640346456
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8231.907221468136
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8231.907221468136
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7978.317181785681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7978.317181785681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.428984237715
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30546.428984237715
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25531.477705492594
# Gradient descend method:  None
# RUN  0 , total integrated cost =  25531.477705492594
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20627.907894119795
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20627.907894119795
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7112.913357952089
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7112.913357952089
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29795.639845368863
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29795.639845368863
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20071.115113665277
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20071.115113665277
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11109.049056155947
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11109.049056155947
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34495.8289838114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34495.8289838114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24416.866252081658
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24416.866252081658
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15143.755110304457
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15143.755110304457
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39340.86017947994
# Gradient descend method:  None
# RUN  0 , total integrated cost =  39340.86017947994
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24128.44250261018
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24128.44250261018
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10559.709248318897
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10559.709248318897
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33891.050588370264
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33891.050588370264
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19226.098318201533
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19226.098318201533
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5845.286879790712
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5845.286879790712
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28593.126434517075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28593.126434517075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14547.979043359295
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14547.979043359295
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38727.35641379273
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38727.35641379273
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23532.636143093983
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23532.636143093983
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10019.968518582271
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10019.968518582271
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33290.05146687772
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33290.05146687772
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1:n_pre-1+1000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]
                
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])
        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    aln.params.duration = dur
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 11758.778823335755 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5803.061345331574
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5803.061345331574
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 1762.879513839064 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5038.191000241453
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5038.191000241453
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 2825.0554192590494 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8870.886871996832
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8870.886871996832
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 3648.2972607906254 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12712.420104314127
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12712.420104314127
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1999.671961434719 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12335.88657806574
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12335.88657806574
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 621.4975145032569 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8024.5455597660875
# Gradient descend method:  None
# RUN  0 , total integrated cost =  8024.5455597660875
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 429.64601736683187 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7789.540036663817
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7789.540036663817
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 38991.67363578247 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29852.65296538924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  29852.65296538924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 4031.209551734642 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24816.48535319573
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24816.48535319573
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 1538.7369605959577 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20035.672309129528
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20035.672309129528
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 691.0633633507116 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15422.394032228889
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15422.394032228889
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 172.11155998537512 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6963.81678131553
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6963.81678131553
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 2570.2053050286795 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28676.21996052061
# Gradient descend method:  None
# RUN  0 , total integrated cost =  28676.21996052061
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 752.9444551143149 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19429.670967789247
# Gradient descend method:  None
# RUN  0 , total integrated cost =  19429.670967789247
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 235.2495833441169 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10805.96380154473
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10805.96380154473
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 2749.224220103638 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32982.781205317886
# Gradient descend method:  None
# RUN  0 , total integrated cost =  32982.781205317886
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 823.3333979661207 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23587.451124448555
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23587.451124448555
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  85 0.47500000000000014 0.7250000000000004
# set cost params:  1.0 291.0165338256028 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14674.753831269132
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14674.753831269132
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  90 0.6000000000000003 0.7250000000000004
# set cost params:  1.0 6844.527566921928 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38544.9751825312
# Gradient descend method:  None
# RUN  0 , total integrated cost =  38544.9751825312
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  95 0.5250000000000001 0.7500000000000004
# set cost params:  1.0 620.0036685781921 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23413.10221299939
# Gradient descend method:  None
# RUN  0 , total integrated cost =  23413.10221299939
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  100 0.4500000000000001 0.7750000000000005
# set cost params:  1.0 136.07003142521114 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10268.207614504425
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10268.207614504425
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  105 0.5750000000000002 0.7750000000000005
# set cost params:  1.0 1255.477370970074 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32551.94508366154
# Gradient descend method:  None
# RUN  0 , total integrated cost =  32551.94508366154
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  110 0.5000000000000002 0.8000000000000005
# set cost params:  1.0 313.36742217356823 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18689.476919287852
# Gradient descend method:  None
# RUN  0 , total integrated cost =  18689.476919287852
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 53.64304065330639 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5686.557704422067
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5686.557704422067
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  120 0.5500000000000003 0.8250000000000005
# set cost params:  1.0 644.2233280397396 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27794.436367586975
# Gradient descend method:  None
# RUN  0 , total integrated cost =  27794.436367586975
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  125 0.47500000000000014 0.8500000000000005
# set cost params:  1.0 163.25056381702458 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14119.476490800229
# Gradient descend method:  None
# RUN  0 , total integrated cost =  14119.476490800229
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  130 0.6000000000000003 0.8500000000000005
# set cost params:  1.0 1383.551173304307 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  37088.880328408646
# Gradient descend method:  None
# RUN  0 , total integrated cost =  37088.880328408646
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  135 0.5250000000000001 0.8750000000000006
# set cost params:  1.0 348.3534264078073 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22921.172214086262
# Gradient descend method:  None
# RUN  0 , total integrated cost =  22921.172214086262
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  140 0.4500000000000001 0.9000000000000006
# set cost params:  1.0 80.93195568235402 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9702.734124941171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  9702.734124941171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  145 0.5750000000000002 0.9000000000000006
# set cost params:  1.0 706.8844104741327 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32368.60292878895
# Gradient descend method:  None
# RUN  0 , total integrated cost =  32368.60292878895
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# --------- 0
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 5
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 10
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 15
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 20
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 25
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 30
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 35
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 40
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 45
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 50
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 55
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 60
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 65
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 70
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 75
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 80
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 85
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 90
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 95
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 100
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 105
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 110
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 115
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 120
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 125
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 130
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 135
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 140
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)
# --------- 145
# ------- c_ind 0
# (4201,) (4201,)
# (4201,) (4201,)

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    


    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# found solution for  0
# -------  5 0.4000000000000001 0.40000000000000013
# found solution for  5
# -------  10 0.4250000000000001 0.42500000000000016
# found solution for  10
# -------  15 0.4500000000000001 0.4500000000000002
# found solution for  15
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  25 0.4250000000000001 0.5000000000000002
# found solution for  25
# -------  30 0.4250000000000001 0.5250000000000002
# found solution for  30
# -------  35 0.5500000000000003 0.5250000000000002
# found solution for  35
# -------  40 0.5250000000000001 0.5500000000000003
# found solution for  40
# -------  45 0.5000000000000002 0.5750000000000003
# found solution for  45
# -------  50 0.47500000000000014 0.6000000000000003
# found solution for  50
# -------  55 0.4250000000000001 0.6250000000000003
# found solution for  55
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  65 0.5000000000000002 0.6500000000000004
# found solution for  65
# -------  70 0.4500000000000001 0.6750000000000004
# found solution for  70
# -------  75 0.5750000000000002 0.6750000000000004
# found solution for  75
# -------  80 0.5250000000000001 0.7000000000000004
# found solution for  80
# -------  85 0.47500000000000014 0.7250000000000004
# found solution for  85
# -------  90 0.6000000000000003 0.7250000000000004
# found solution for  90
# -------  95 0.5250000000000001 0.7500000000000004
# found solution for  95
# -------  100 0.4500000000000001 0.7750000000000005
# found solution for  100
# -------  105 0.5750000000000002 0.7750000000000005
# found solution for  105
# -------  110 0.5000000000000002 0.8000000000000005
# found solution for  110
# -------  115 0.4250000000000001 0.8250000000000005
# found solution for  115
# -------  120 0.5500000000000003 0.8250000000000005
# found solution for  120
# -------  125 0.47500000000000014 0.8500000000000005
# found solution for  125
# -------  130 0.6000000000000003 0.8500000000000005
# found solution for  130
# -------  135 0.5250000000000001 0.8750000000000006
# found solution for  135
# -------  140 0.4500000000000001 0.9000000000000006
# found solution for  140
# -------  145 0.5750000000000002 0.9000000000000006
# found solution for  145

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  19320.786835681447
# set cost params:  1.0 19320.786835681447 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.1009999093
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5902.1009999093
# Control only changes marginally.
# RUN  1 , total integrated cost =  5902.1009999093
# Improved over  1  iterations in  29.68879407644272  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62780088266443 -56.62779780881823
# converged for  0
# -------  5 0.4000000000000001 0.40000000000000013
# weight =  2285.7985527167834
# set cost params:  1.0 2285.7985527167834 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5095.060821266801
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5095.060821266801
# Control only changes marginally.
# RUN  1 , total integrated cost =  5095.060821266801
# Improved over  1  iterations in  1.2150975745171309  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.624481516892935 -56.62448105818149
# converged for  5
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  4765.965006015698
# set cost params:  1.0 4765.965006015698 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9109.54511547274
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9109.54511547274
# Control only changes marginally.
# RUN  1 , total integrated cost =  9109.54511547274
# Improved over  1  iterations in  0.9767041318118572  seconds by  0.0  percent.
# converged for  10
# -------  15 0.4500000000000001 0.4500000000000002
# weight =  6333.310547084621
# set cost params:  1.0 6333.310547084621 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13016.019471983052
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13016.019471983052
# Control only changes marginally.
# RUN  1 , total integrated cost =  13016.019471983052
# Improved over  1  iterations in  1.299754736945033  seconds by  0.0  percent.
# converged for  15
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3578.11466623365
# set cost params:  1.0 3578.11466623365 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.55743704086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.55743704086
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.55743704086
# Improved over  1  iterations in  1.1008733939379454  seconds by  0.0  percent.
# converged for  20
# -------  25 0.4250000000000001 0.5000000000000002
# weight =  1079.4041902067663
# set cost params:  1.0 1079.4041902067663 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8224.287936670757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8224.287936670757
# Control only changes marginally.
# RUN  1 , total integrated cost =  8224.287936670757
# Improved over  1  iterations in  1.1804409120231867  seconds by  0.0  percent.
# RUN  200 , total integrated cost =  29793.41604946076
# RUN  300 , total integrated cost =  29793.416003000515
# RUN  400 , total integrated cost =  29793.415956540335
# RUN  500 , total integrated cost =  29793.41591007762
# RUN  600 , total integrated cost =  29793.415863617505
# RUN  700 , total integrated cost =  29793.41581715717
# RUN  800 , total integrated cost =  29793.41577069702
# RUN  900 , total integrated cost =  29793.415724234314
# RUN  1000 , total integrated cost =  29793.415677769266
# RUN  1100 , total integrated cost =  29793.415631308955
# RUN  1200 , total integrated cost =  29793.415584848866
# RUN  1300 , total integrated cost =  29793.41553838624
# RUN  1400 , total integrated cost =  29793.415491926036
# RUN  1500 , total integrated cost =  29793.41544546454
# RUN  1600 , total integrated cost =  29793.41539900184
# RUN  1700 , total integrated cost =  29793.415352541688
# RUN  1800 , total integrated cost =  29793.415306081468
# RUN  1900 , total integrated cost =  29793.415259618858
# RUN  2000 , total integrated cost =  29793.415213158685
# RUN  3000 , total integrated cost =  29793.414748546915
# RUN  4000 , total integrated cost =  29793.414283942435
# RUN  5000 , total integrated cost =  29793.413819331006
# RUN  6000 , total integrated cost =  29793.413354712684
# RUN  7000 , total integrated cost =  29793.412890095573
# RUN  8000 , total integrated cost =  29793.412425486807
# RUN  9000 , total integrated cost =  29793.411960875885
# RUN  10000 , total integrated cost =  29793.411496267687
# RUN  10000 , total integrated cost =  29793.411496267687
# Improved over  10000  iterations in  4430.773552138358  seconds by  1.559443036569519e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  2120.9047306498946
# set cost params:  1.0 2120.9047306498946 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20061.656105056773
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20061.656105056773
# Control only changes marginally.
# RUN  1 , total integrated cost =  20061.656105056773
# Improved over  1  iterations in  1.5848312675952911  seconds by  0.0  percent.
# converged for  65
# -------  70 0.4500000000000001 0.6750000000000004
# weight =  505.59345075463995
# set cost params:  1.0 505.59345075463995 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11087.120132598786
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  11087.120132598786
# Control only changes marginally.
# RUN  1 , total integrated cost =  11087.120132598786
# Improved over  1  iterations in  1.5349895674735308  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.659048353247286 -56.65904814981257
# converged for  70
# -------  75 0.5750000000000002 0.6750000000000004
# weight =  38854.115113513835
# set cost params:  1.0 38854.115113513835 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34494.94117717685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34494.94117717685
# Control only changes marginally.
# RUN  1 , total integrated cost =  34494.94117717685
# Improved over  1  iterations in  1.8605294842272997  seconds by  0.0  percent.
# converged for  75
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  3498.9725980231697
# set cost params:  1.0 3498.9725980231697 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24409.889949962646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24409.889949962646
# Control only changes marginally.
# RUN  1 , total integrated cost =  24409.889949962646
# Improved over  1  iterations in  2.0752484519034624  seconds by  0.0  percent.
# converged for  80
# -------  85 0.47500000000000014 0.7250000000000004
# weight =  545.7157131285772
# set cost params:  1.0 545.7157131285772 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15116.05560442481
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  15116.05560442481
# Control only changes marginally.
# RUN  1 , total integrated cost =  15116.05560442481
# Improved over  1  iterations in  1.9936196114867926  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.679958302101944 -56.67995827906179
# converged for  85
# -------  90 0.6000000000000003 0.7250000000000004
# weight =  773361.764116608
# set cost params:  1.0 773361.764116608 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39340.80930961394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39340.80930961394
# Control only changes marginally.
# RUN  1 , total integrated cost =  39340.80930961394
# Improved over  1  iterations in  1.5786974038928747  seconds by  0.0  percent.
# converged for  90
# -------  95 0.5250000000000001 0.7500000000000004
# weight =  2939.722793236261
# set cost params:  1.0 2939.722793236261 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24120.23756654545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24120.23756654545
# Control only changes marginally.
# RUN  1 , total integrated cost =  24120.23756654545
# Improved over  1  iterations in  1.523451540619135  seconds by  0.0  percent.
# converged for  95
# -------  100 0.4500000000000001 0.7750000000000005
# weight =  151.8710918791927
# set cost params:  1.0 151.8710918791927 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10490.633341824661
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  10490.633341824661
# Control only changes marginally.
# RUN  1 , total integrated cost =  10490.633341824661
# Improved over  1  iterations in  1.869165487587452  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.65537911607374 -56.65537900024478
# converged for  100
# -------  105 0.5750000000000002 0.7750000000000005
# weight =  16930.212334844546
# set cost params:  1.0 16930.212334844546 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33889.04889765148
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33889.04889765148
# Control only changes marginally.
# RUN  1 , total integrated cost =  33889.04889765148
# Improved over  1  iterations in  1.686472810804844  seconds by  0.0  percent.
# converged for  105
# -------  110 0.5000000000000002 0.8000000000000005
# weight =  1365.4622797856775
# set cost params:  1.0 1365.4622797856775 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19212.028337198317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19212.028337198317
# Control only changes marginally.
# RUN  1 , total integrated cost =  19212.028337198317
# Improved over  1  iterations in  1.9117636289447546  seconds by  0.0  percent.
# converged for  110
# -------  115 0.4250000000000001 0.8250000000000005
# weight =  72.88000207663333
# set cost params:  1.0 72.88000207663333 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5766.168218238329
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5766.168218238329
# Control only changes marginally.
# RUN  1 , total integrated cost =  5766.168218238329
# Improved over  1  iterations in  1.7992274276912212  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62393652943261 -56.62394109311585
# converged for  115
# -------  120 0.5500000000000003 0.8250000000000005
# weight =  5170.597427752188
# set cost params:  1.0 5170.597427752188 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28587.597557446894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28587.597557446894
# Control only changes marginally.
# RUN  1 , total integrated cost =  28587.597557446894
# Improved over  1  iterations in  1.5550254229456186  seconds by  0.0  percent.
# converged for  120
# -------  125 0.47500000000000014 0.8500000000000005
# weight =  343.3398812986113
# set cost params:  1.0 343.3398812986113 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14505.730149654346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14505.730149654346
# Control only changes marginally.
# RUN  1 , total integrated cost =  14505.730149654346
# Improved over  1  iterations in  1.761537665501237  seconds by  0.0  percent.
# converged for  125
# -------  130 0.6000000000000003 0.8500000000000005
# weight =  62526.72682400372
# set cost params:  1.0 62526.72682400372 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38726.737050857584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38726.737050857584
# Control only changes marginally.
# RUN  1 , total integrated cost =  38726.737050857584
# Improved over  1  iterations in  1.7747413162142038  seconds by  0.0  percent.
# converged for  130
# -------  135 0.5250000000000001 0.8750000000000006
# weight =  2274.275932265575
# set cost params:  1.0 2274.275932265575 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23522.29338166915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23522.29338166915
# Control only changes marginally.
# RUN  1 , total integrated cost =  23522.29338166915
# Improved over  1  iterations in  1.8157132137566805  seconds by  0.0  percent.
# converged for  135
# -------  140 0.4500000000000001 0.9000000000000006
# weight =  94.2426664307726
# set cost params:  1.0 94.2426664307726 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9914.76389869833
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  9914.76389869833
# Control only changes marginally.
# RUN  1 , total integrated cost =  9914.76389869833
# Improved over  1  iterations in  2.119563775137067  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.65161375647954 -56.651614613434994
# converged for  140
# -------  145 0.5750000000000002 0.9000000000000006
# weight =  10734.506242934294
# set cost params:  1.0 10734.506242934294 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33286.95053705515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33286.95053705059
# RUN  2 , total integrated cost =  33286.95053704709
# RUN  3 , total integrated cost =  33286.950537042125
# RUN  4 , total integrated cost =  33286.95053704013
# RUN  5 , total integrated cost =  33286.950537037796
# RUN  6 , total integrated cost =  33286.9505370355
# RUN  7 , total integrated cost =  33286.95053703371
# RUN  8 , total integrated cost =  33286.95053703104
# RUN  9 , total integrated cost =  33286.95053702831
# RUN  10 , total integrated cost =  33286.95053702575
# RUN  11 , total integrated cost =  33286.95053702331
# RUN  12 , total integrated cost =  33286.95053702122
# RUN  13 , total integrated cost =  33286.950537019286
# RUN  14 , total integrated cost =  33286.95053701673
# RUN  15 , total integrated cost =  33286.95053701357
# RUN  16 , total integrated cost =  33286.95053700997
# RUN  17 , total integrated cost =  33286.950537005745
# RUN  18 , total integrated cost =  33286.95053700371
# RUN  19 , total integrated cost =  33286.95053700101
# RUN  20 , total integrated cost =  33286.950536997465
# RUN  30 , total integrated cost =  33286.950536965924
# RUN  40 , total integrated cost =  33286.95053693885
# RUN  50 , total integrated cost =  33286.95053691354
# RUN  60 , total integrated cost =  33286.95053688745
# RUN  70 , total integrated cost =  33286.950536862154
# RUN  80 , total integrated cost =  33286.95053683544
# RUN  90 , total integrated cost =  33286.95053681006
# RUN  100 , total integrated cost =  33286.95053678571
# RUN  110 , total integrated cost =  33286.950536760756
# RUN  120 , total integrated cost =  33286.950536735334
# RUN  130 , total integrated cost =  33286.95053671058
# RUN  140 , total integrated cost =  33286.95053668689
# RUN  150 , total integrated cost =  33286.95053665759
# RUN  160 , total integrated cost =  33286.95053662669
# RUN  170 , total integrated cost =  33286.950536599965
# RUN  180 , total integrated cost =  33286.9505365762
# RUN  190 , total integrated cost =  33286.95053654945
# RUN  200 , total integrated cost =  33286.950536519114
# RUN  300 , total integrated cost =  33286.95053623617
# RUN  400 , total integrated cost =  33286.95053598631
# RUN  500 , total integrated cost =  33286.95053571449
# RUN  600 , total integrated cost =  33286.950535442025
# RUN  700 , total integrated cost =  33286.95053519019
# RUN  800 , total integrated cost =  33286.95053492567
# RUN  900 , total integrated cost =  33286.95053465197
# RUN  1000 , total integrated cost =  33286.95053440284
# RUN  1100 , total integrated cost =  33286.950534134616
# RUN  1200 , total integrated cost =  33286.95053386376
# RUN  1300 , total integrated cost =  33286.95053358687
# RUN  1400 , total integrated cost =  33286.950533320916
# RUN  1500 , total integrated cost =  33286.95053305347
# RUN  1600 , total integrated cost =  33286.95053278293
# RUN  1700 , total integrated cost =  33286.95053250843
# RUN  1800 , total integrated cost =  33286.95053223017
# RUN  1900 , total integrated cost =  33286.95053197441
# RUN  2000 , total integrated cost =  33286.95053170859
# RUN  3000 , total integrated cost =  33286.95052902487
# RUN  4000 , total integrated cost =  33286.950526353336
# RUN  5000 , total integrated cost =  33286.95052365307
# RUN  6000 , total integrated cost =  33286.95052092446
# RUN  7000 , total integrated cost =  33286.9505182796
# RUN  8000 , total integrated cost =  33286.95051557328
# RUN  9000 , total integrated cost =  33286.950512942676
# RUN  10000 , total integrated cost =  33286.950510274204
# RUN  10000 , total integrated cost =  33286.950510274204
# Improved over  10000  iterations in  5950.127806862816  seconds by  8.045478239182557e-08  percent.
# no convergence
# --------------- 1
# [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# weight =  19320.786835681447
# set cost params:  1.0 19320.786835681447 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5902.1009999093
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5902.1009999093
# Control only changes marginally.
# RUN  1 , total integrated cost =  5902.1009999093
# Improved over  1  iterations in  2.0934872273355722  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62780088266443 -56.62779780881823
# converged for  0
# -------  5 0.4000000000000001 0.40000000000000013
# weight =  2285.7985527167834
# set cost params:  1.0 2285.7985527167834 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5095.060821266801
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5095.060821266801
# Control only changes marginally.
# RUN  1 , total integrated cost =  5095.060821266801
# Improved over  1  iterations in  1.8252376522868872  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.624481516892935 -56.62448105818149
# converged for  5
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  4765.965006015697
# set cost params:  1.0 4765.965006015697 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9109.545115472736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9109.545115472736
# Control only changes marginally.
# RUN  1 , total integrated cost =  9109.545115472736
# Improved over  1  iterations in  1.554360730573535  seconds by  0.0  percent.
# converged for  10
# -------  15 0.4500000000000001 0.4500000000000002
# weight =  6333.310547084621
# set cost params:  1.0 6333.310547084621 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13016.019471983052
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13016.019471983052
# Control only changes marginally.
# RUN  1 , total integrated cost =  13016.019471983052
# Improved over  1  iterations in  1.7691669557243586  seconds by  0.0  percent.
# converged for  15
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3578.1146662336496
# set cost params:  1.0 3578.1146662336496 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.557437040858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.557437040858
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.557437040858
# Improved over  1  iterations in  1.8315917048603296  seconds by  0.0  percent.
# converged for  20
# -------  25 0.4250000000000001 0.5000000000000002
# weight =  1079.4041902067663
# set cost params:  1.0 1079.4041902067663 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8224.287936670757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8224.287936670757
# Control only changes marginally.
# RUN  1 , total integrated cost =  8224.287936670757
# Improved over  1  iterations in  1.3547966443002224  seconds by  0.0  percent.
# converged for  25
# -------  30 0.4250000000000001 0.5250000000000002
# weight =  664.9773867853621
# set cost params:  1.0 664.9773867853621 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7966.337319796226
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  7966.337319796226
# Control only changes marginally.
# RUN  1 , total integrated cost =  7966.337319796226
# Improved over  1  iterations in  2.213113931939006  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.63894646260913 -56.63892613705056
# converged for  30
# -------  35 0.5500000000000003 0.5250000000000002
# weight =  422655.7644209001
# set cost params:  1.0 422655.7644209001 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.356711813478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30546.356711813478
# Control only changes marginally.
# RUN  1 , total integrated cost =  30546.356711813478
# Improved over  1  iterations in  1.771849263459444  seconds by  0.0  percent.
# converged for  35
# -------  40 0.5250000000000001 0.5500000000000003
# weight =  12554.782897565203
# set cost params:  1.0 12554.782897565203 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25529.44426178671
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25529.44426178671
# Control only changes marginally.
# RUN  1 , total integrated cost =  25529.44426178671
# Improved over  1  iterations in  1.4855939075350761  seconds by  0.0  percent.
# converged for  40
# -------  45 0.5000000000000002 0.5750000000000003
# weight =  3586.8488142287106
# set cost params:  1.0 3586.8488142287106 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20622.15851365194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20622.15851365194
# Control only changes marginally.
# RUN  1 , total integrated cost =  20622.15851365194
# Improved over  1  iterations in  1.9652083739638329  seconds by  0.0  percent.
# converged for  45
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  1459.1802701963861
# set cost params:  1.0 1459.1802701963861 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15932.036951719801
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15932.036951719801
# Control only changes marginally.
# RUN  1 , total integrated cost =  15932.036951719801
# Improved over  1  iterations in  1.6918826792389154  seconds by  0.0  percent.
# converged for  50
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  257.00841576670626
# set cost params:  1.0 257.00841576670626 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7085.3448255969915
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  7085.3448255969915
# Control only changes marginally.
# RUN  1 , total integrated cost =  7085.3448255969915
# Improved over  1  iterations in  2.188062723726034  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62982938008029 -56.629866786249615
# converged for  55
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  13398.111597785615
# set cost params:  1.0 13398.111597785615 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29793.41614272795
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29793.416142205147
# RUN  2 , total integrated cost =  29793.416141798738
# RUN  3 , total integrated cost =  29793.416141275833
# RUN  4 , total integrated cost =  29793.41614086952
# RUN  5 , total integrated cost =  29793.41614034666
# RUN  6 , total integrated cost =  29793.416139940266
# RUN  7 , total integrated cost =  29793.416139417463
# RUN  8 , total integrated cost =  29793.416139011046
# RUN  9 , total integrated cost =  29793.416138488225
# RUN  10 , total integrated cost =  29793.416138081855
# RUN  11 , total integrated cost =  29793.416137559016
# RUN  12 , total integrated cost =  29793.416137152682
# RUN  13 , total integrated cost =  29793.416136629843
# RUN  14 , total integrated cost =  29793.41613622344
# RUN  15 , total integrated cost =  29793.4161357006
# RUN  16 , total integrated cost =  29793.416135294254
# RUN  17 , total integrated cost =  29793.416134771327
# RUN  18 , total integrated cost =  29793.416134364998
# RUN  19 , total integrated cost =  29793.416133842216
# RUN  20 , total integrated cost =  29793.416133435854
# RUN  30 , total integrated cost =  29793.41612878987
# RUN  40 , total integrated cost =  29793.41612414384
# RUN  50 , total integrated cost =  29793.416119497906
# RUN  60 , total integrated cost =  29793.416114851843
# RUN  70 , total integrated cost =  29793.416110205788
# RUN  80 , total integrated cost =  29793.416105559696
# RUN  90 , total integrated cost =  29793.41610091369
# RUN  100 , total integrated cost =  29793.416096267705
# RUN  110 , total integrated cost =  29793.41609162175
# RUN  120 , total integrated cost =  29793.41608697568
# RUN  130 , total integrated cost =  29793.416082329615
# RUN  140 , total integrated cost =  29793.416077683658
# RUN  150 , total integrated cost =  29793.416073037577
# RUN  160 , total integrated cost =  29793.416068391572
# RUN  170 , total integrated cost =  29793.416063745586
# RUN  180 , total integrated cost =  29793.41605909958
# RUN  190 , total integrated cost =  29793.416054453606
# RUN  200 , total integrated cost =  29793.41604980744
# RUN  300 , total integrated cost =  29793.41600334742
# RUN  400 , total integrated cost =  29793.41595688484
# RUN  500 , total integrated cost =  29793.415910422304
# RUN  600 , total integrated cost =  29793.41586395843
# RUN  700 , total integrated cost =  29793.41581749964
# RUN  800 , total integrated cost =  29793.4157710395
# RUN  900 , total integrated cost =  29793.415724576887
# RUN  1000 , total integrated cost =  29793.41567811674
# RUN  1100 , total integrated cost =  29793.415631656582
# RUN  1200 , total integrated cost =  29793.415585196504
# RUN  1300 , total integrated cost =  29793.415538733883
# RUN  1400 , total integrated cost =  29793.415492273816
# RUN  1500 , total integrated cost =  29793.41544580878
# RUN  1600 , total integrated cost =  29793.4153993486
# RUN  1700 , total integrated cost =  29793.41535288849
# RUN  1800 , total integrated cost =  29793.415306428273
# RUN  1900 , total integrated cost =  29793.41525996831
# RUN  2000 , total integrated cost =  29793.415213508004
# RUN  3000 , total integrated cost =  29793.4147488994
# RUN  4000 , total integrated cost =  29793.414284283892
# RUN  5000 , total integrated cost =  29793.413819675596
# RUN  6000 , total integrated cost =  29793.41335506953
# RUN  7000 , total integrated cost =  29793.41289046604
# RUN  8000 , total integrated cost =  29793.412425862705
# RUN  9000 , total integrated cost =  29793.411961250546
# RUN  10000 , total integrated cost =  29793.411496644963
# RUN  10000 , total integrated cost =  29793.411496644963
# Improved over  10000  iterations in  4520.916486397386  seconds by  1.559432783437842e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  2120.9047306498937
# set cost params:  1.0 2120.9047306498937 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20061.656105056758
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20061.656105056758
# Control only changes marginally.
# RUN  1 , total integrated cost =  20061.656105056758
# Improved over  1  iterations in  1.7857220750302076  seconds by  0.0  percent.
# converged for  65
# -------  70 0.4500000000000001 0.6750000000000004
# weight =  505.59345075464
# set cost params:  1.0 505.59345075464 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11087.120132598786
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  11087.120132598786
# Control only changes marginally.
# RUN  1 , total integrated cost =  11087.120132598786
# Improved over  1  iterations in  1.974113181233406  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.659048353247286 -56.65904814981257
# converged for  70
# -------  75 0.5750000000000002 0.6750000000000004
# weight =  38854.11511351384
# set cost params:  1.0 38854.11511351384 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34494.941177176865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34494.941177176865
# Control only changes marginally.
# RUN  1 , total integrated cost =  34494.941177176865
# Improved over  1  iterations in  1.7610070165246725  seconds by  0.0  percent.
# converged for  75
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  3498.9725980231697
# set cost params:  1.0 3498.9725980231697 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24409.889949962646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24409.889949962646
# Control only changes marginally.
# RUN  1 , total integrated cost =  24409.889949962646
# Improved over  1  iterations in  1.800222508609295  seconds by  0.0  percent.
# converged for  80
# -------  85 0.47500000000000014 0.7250000000000004
# weight =  545.715713128577
# set cost params:  1.0 545.715713128577 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15116.055604424797
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  15116.055604424797
# Control only changes marginally.
# RUN  1 , total integrated cost =  15116.055604424797
# Improved over  1  iterations in  2.3339121080935  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.679958302101944 -56.67995827906179
# converged for  85
# -------  90 0.6000000000000003 0.7250000000000004
# weight =  773361.764116608
# set cost params:  1.0 773361.764116608 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39340.80930961394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39340.80930961394
# Control only changes marginally.
# RUN  1 , total integrated cost =  39340.80930961394
# Improved over  1  iterations in  1.7991932220757008  seconds by  0.0  percent.
# converged for  90
# -------  95 0.5250000000000001 0.7500000000000004
# weight =  2939.722793236261
# set cost params:  1.0 2939.722793236261 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24120.23756654545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24120.23756654545
# Control only changes marginally.
# RUN  1 , total integrated cost =  24120.23756654545
# Improved over  1  iterations in  1.6483207624405622  seconds by  0.0  percent.
# converged for  95
# -------  100 0.4500000000000001 0.7750000000000005
# weight =  151.8710918791927
# set cost params:  1.0 151.8710918791927 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10490.633341824661
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  10490.633341824661
# Control only changes marginally.
# RUN  1 , total integrated cost =  10490.633341824661
# Improved over  1  iterations in  1.9276160709559917  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.65537911607374 -56.65537900024478
# converged for  100
# -------  105 0.5750000000000002 0.7750000000000005
# weight =  16930.212334844546
# set cost params:  1.0 16930.212334844546 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33889.04889765148
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33889.04889765148
# Control only changes marginally.
# RUN  1 , total integrated cost =  33889.04889765148
# Improved over  1  iterations in  1.909663151949644  seconds by  0.0  percent.
# converged for  105
# -------  110 0.5000000000000002 0.8000000000000005
# weight =  1365.4622797856773
# set cost params:  1.0 1365.4622797856773 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19212.02833719831
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19212.02833719831
# Control only changes marginally.
# RUN  1 , total integrated cost =  19212.02833719831
# Improved over  1  iterations in  1.7643421478569508  seconds by  0.0  percent.
# converged for  110
# -------  115 0.4250000000000001 0.8250000000000005
# weight =  72.88000207663329
# set cost params:  1.0 72.88000207663329 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5766.168218238324
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  5766.168218238324
# Control only changes marginally.
# RUN  1 , total integrated cost =  5766.168218238324
# Improved over  1  iterations in  1.7110281009227037  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.62393652943261 -56.62394109311585
# converged for  115
# -------  120 0.5500000000000003 0.8250000000000005
# weight =  5170.597427752188
# set cost params:  1.0 5170.597427752188 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28587.597557446894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28587.597557446894
# Control only changes marginally.
# RUN  1 , total integrated cost =  28587.597557446894
# Improved over  1  iterations in  2.0113986432552338  seconds by  0.0  percent.
# converged for  120
# -------  125 0.47500000000000014 0.8500000000000005
# weight =  343.3398812986113
# set cost params:  1.0 343.3398812986113 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14505.730149654346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14505.730149654346
# Control only changes marginally.
# RUN  1 , total integrated cost =  14505.730149654346
# Improved over  1  iterations in  1.664642272517085  seconds by  0.0  percent.
# converged for  125
# -------  130 0.6000000000000003 0.8500000000000005
# weight =  62526.72682400372
# set cost params:  1.0 62526.72682400372 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  38726.737050857584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38726.737050857584
# Control only changes marginally.
# RUN  1 , total integrated cost =  38726.737050857584
# Improved over  1  iterations in  1.9752400256693363  seconds by  0.0  percent.
# converged for  130
# -------  135 0.5250000000000001 0.8750000000000006
# weight =  2274.2759322655747
# set cost params:  1.0 2274.2759322655747 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23522.293381669144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23522.293381669144
# Control only changes marginally.
# RUN  1 , total integrated cost =  23522.293381669144
# Improved over  1  iterations in  1.8579314425587654  seconds by  0.0  percent.
# converged for  135
# -------  140 0.4500000000000001 0.9000000000000006
# weight =  94.24266643077262
# set cost params:  1.0 94.24266643077262 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9914.763898698333
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  9914.763898698333
# Control only changes marginally.
# RUN  1 , total integrated cost =  9914.763898698333
# Improved over  1  iterations in  1.7812051717191935  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.65161375647954 -56.651614613434994
# converged for  140
# -------  145 0.5750000000000002 0.9000000000000006
# weight =  10734.506251571589
# set cost params:  1.0 10734.506251571589 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33286.95053705789
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33286.950537054945
# RUN  2 , total integrated cost =  33286.95053705227
# RUN  3 , total integrated cost =  33286.95053704984
# RUN  4 , total integrated cost =  33286.95053704781
# RUN  5 , total integrated cost =  33286.95053704528
# RUN  6 , total integrated cost =  33286.95053704269
# RUN  7 , total integrated cost =  33286.95053703994
# RUN  8 , total integrated cost =  33286.950537037366
# RUN  9 , total integrated cost =  33286.95053703446
# RUN  10 , total integrated cost =  33286.95053703189
# RUN  11 , total integrated cost =  33286.95053702955
# RUN  12 , total integrated cost =  33286.95053702721
# RUN  13 , total integrated cost =  33286.95053702492
# RUN  14 , total integrated cost =  33286.95053702234
# RUN  15 , total integrated cost =  33286.95053702014
# RUN  16 , total integrated cost =  33286.950537017845
# RUN  17 , total integrated cost =  33286.95053701596
# RUN  18 , total integrated cost =  33286.95053701351
# RUN  19 , total integrated cost =  33286.95053701134
# RUN  20 , total integrated cost =  33286.95053700857
# RUN  30 , total integrated cost =  33286.95053697989
# RUN  40 , total integrated cost =  33286.95053695015
# RUN  50 , total integrated cost =  33286.95053692369
# RUN  60 , total integrated cost =  33286.95053689682
# RUN  70 , total integrated cost =  33286.950536869655
# RUN  80 , total integrated cost =  33286.95053684044
# RUN  90 , total integrated cost =  33286.95053681357
# RUN  100 , total integrated cost =  33286.950536789074
# RUN  110 , total integrated cost =  33286.95053675675
# RUN  120 , total integrated cost =  33286.950536726734
# RUN  130 , total integrated cost =  33286.950536702585
# RUN  140 , total integrated cost =  33286.95053667862
# RUN  150 , total integrated cost =  33286.950536652475
# RUN  160 , total integrated cost =  33286.95053662163
# RUN  170 , total integrated cost =  33286.95053658884
# RUN  180 , total integrated cost =  33286.95053655504
# RUN  190 , total integrated cost =  33286.95053653019
# RUN  200 , total integrated cost =  33286.95053650545
# RUN  300 , total integrated cost =  33286.95053622316
# RUN  400 , total integrated cost =  33286.950535967546
# RUN  500 , total integrated cost =  33286.95053570789
# RUN  600 , total integrated cost =  33286.95053544024
# RUN  700 , total integrated cost =  33286.9505351586
# RUN  800 , total integrated cost =  33286.95053490068
# RUN  900 , total integrated cost =  33286.95053463163
# RUN  1000 , total integrated cost =  33286.95053435682
# RUN  1100 , total integrated cost =  33286.950534083524
# RUN  1200 , total integrated cost =  33286.95053381704
# RUN  1300 , total integrated cost =  33286.95053354373
# RUN  1400 , total integrated cost =  33286.95053327721
# RUN  1500 , total integrated cost =  33286.95053299239
# RUN  1600 , total integrated cost =  33286.9505327298
# RUN  1700 , total integrated cost =  33286.95053245088
# RUN  1800 , total integrated cost =  33286.9505321823
# RUN  1900 , total integrated cost =  33286.95053190411
# RUN  2000 , total integrated cost =  33286.9505316368
# RUN  3000 , total integrated cost =  33286.95052896861
# RUN  4000 , total integrated cost =  33286.95052629286
# RUN  5000 , total integrated cost =  33286.95052361527
# RUN  6000 , total integrated cost =  33286.9505208926
# RUN  7000 , total integrated cost =  33286.95051818797
# RUN  8000 , total integrated cost =  33286.95051554617
# RUN  9000 , total integrated cost =  33286.95051283627
# RUN  10000 , total integrated cost =  33286.9505101598
# RUN  10000 , total integrated cost =  33286.9505101598
# Improved over  10000  iterations in  5884.886505451053  seconds by  8.080672841970227e-08  percent.
# no convergence
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  13398.113687287349
# set cost params:  1.0 13398.113687287349 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29793.416143074803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29793.41614255198
# RUN  2 , total integrated cost =  29793.41614214566
# RUN  3 , total integrated cost =  29793.41614162282
# RUN  4 , total integrated cost =  29793.416141216385
# RUN  5 , total integrated cost =  29793.416140693553
# RUN  6 , total integrated cost =  29793.41614028716
# RUN  7 , total integrated cost =  29793.416139764387
# RUN  8 , total integrated cost =  29793.416139358073
# RUN  9 , total integrated cost =  29793.416138835204
# RUN  10 , total integrated cost =  29793.416138428838
# RUN  11 , total integrated cost =  29793.41613790594
# RUN  12 , total integrated cost =  29793.4161374996
# RUN  13 , total integrated cost =  29793.416136976706
# RUN  14 , total integrated cost =  29793.41613657038
# RUN  15 , total integrated cost =  29793.41613604759
# RUN  16 , total integrated cost =  29793.416135641215
# RUN  17 , total integrated cost =  29793.41613511841
# RUN  18 , total integrated cost =  29793.416134712053
# RUN  19 , total integrated cost =  29793.416134189214
# RUN  20 , total integrated cost =  29793.416133782757
# RUN  30 , total integrated cost =  29793.416129136713
# RUN  40 , total integrated cost =  29793.416124490675
# RUN  50 , total integrated cost =  29793.416119844744
# RUN  60 , total integrated cost =  29793.41611519873
# RUN  70 , total integrated cost =  29793.416110552764
# RUN  80 , total integrated cost =  29793.416105906635
# RUN  90 , total integrated cost =  29793.416101260693
# RUN  100 , total integrated cost =  29793.41609661474
# RUN  110 , total integrated cost =  29793.41609196862
# RUN  120 , total integrated cost =  29793.41608732269
# RUN  130 , total integrated cost =  29793.41608267663
# RUN  140 , total integrated cost =  29793.416078030667
# RUN  150 , total integrated cost =  29793.41607338471
# RUN  160 , total integrated cost =  29793.4160687386
# RUN  170 , total integrated cost =  29793.416064092533
# RUN  180 , total integrated cost =  29793.416059446514
# RUN  190 , total integrated cost =  29793.41605479851
# RUN  200 , total integrated cost =  29793.41605015217
# RUN  300 , total integrated cost =  29793.41600368966
# RUN  400 , total integrated cost =  29793.41595722756
# RUN  500 , total integrated cost =  29793.41591076729
# RUN  600 , total integrated cost =  29793.415864307233
# RUN  700 , total integrated cost =  29793.41581784712
# RUN  800 , total integrated cost =  29793.415771387125
# RUN  900 , total integrated cost =  29793.415724927167
# RUN  1000 , total integrated cost =  29793.41567846449
# RUN  1100 , total integrated cost =  29793.415632002067
# RUN  1200 , total integrated cost =  29793.4155855419
# RUN  1300 , total integrated cost =  29793.41553908179
# RUN  1400 , total integrated cost =  29793.415492621712
# RUN  1500 , total integrated cost =  29793.415446159564
# RUN  1600 , total integrated cost =  29793.41539969921
# RUN  1700 , total integrated cost =  29793.415353236698
# RUN  1800 , total integrated cost =  29793.415306776624
# RUN  1900 , total integrated cost =  29793.415260316604
# RUN  2000 , total integrated cost =  29793.415213856497
# RUN  3000 , total integrated cost =  29793.414749246174
# RUN  4000 , total integrated cost =  29793.41428464095
# RUN  5000 , total integrated cost =  29793.41382002575
# RUN  6000 , total integrated cost =  29793.41335541356
# RUN  7000 , total integrated cost =  29793.412890808308
# RUN  8000 , total integrated cost =  29793.412426196228
# RUN  9000 , total integrated cost =  29793.411961589056
# RUN  10000 , total integrated cost =  29793.41149698635
# RUN  10000 , total integrated cost =  29793.41149698635
# Improved over  10000  iterations in  4473.7046730183065  seconds by  1.5594346180591856e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  85 0.47500000000000014 0.7250000000000004
# -------  90 0.6000000000000003 0.7250000000000004
# -------  95 0.5250000000000001 0.7500000000000004
# -------  100 0.4500000000000001 0.7750000000000005
# -------  105 0.5750000000000002 0.7750000000000005
# -------  110 0.5000000000000002 0.8000000000000005
# -------  115 0.4250000000000001 0.8250000000000005
# -------  120 0.5500000000000003 0.8250000000000005
# -------  125 0.47500000000000014 0.8500000000000005
# -------  130 0.6000000000000003 0.8500000000000005
# -------  135 0.5250000000000001 0.8750000000000006
# -------  140 0.4500000000000001 0.9000000000000006
# -------  145 0.5750000000000002 0.9000000000000006
# weight =  10734.506260246586
# set cost params:  1.0 10734.506260246586 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33286.95053706029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33286.95053705745
# RUN  2 , total integrated cost =  33286.95053705513
# RUN  3 , total integrated cost =  33286.95053705344
# RUN  4 , total integrated cost =  33286.95053704976
# RUN  5 , total integrated cost =  33286.95053704567
# RUN  6 , total integrated cost =  33286.95053704201
# RUN  7 , total integrated cost =  33286.95053703878
# RUN  8 , total integrated cost =  33286.95053703643
# RUN  9 , total integrated cost =  33286.95053703425
# RUN  10 , total integrated cost =  33286.950537031626
# RUN  11 , total integrated cost =  33286.950537028824
# RUN  12 , total integrated cost =  33286.95053702626
# RUN  13 , total integrated cost =  33286.95053702392
# RUN  14 , total integrated cost =  33286.95053701998
# RUN  15 , total integrated cost =  33286.9505370152
# RUN  16 , total integrated cost =  33286.950537011704
# RUN  17 , total integrated cost =  33286.95053700793
# RUN  18 , total integrated cost =  33286.950537005825
# RUN  19 , total integrated cost =  33286.95053700298
# RUN  20 , total integrated cost =  33286.950537000186
# RUN  30 , total integrated cost =  33286.950536973534
# RUN  40 , total integrated cost =  33286.95053694819
# RUN  50 , total integrated cost =  33286.95053692448
# RUN  60 , total integrated cost =  33286.95053689878
# RUN  70 , total integrated cost =  33286.950536868324
# RUN  80 , total integrated cost =  33286.95053684088
# RUN  90 , total integrated cost =  33286.95053681671
# RUN  100 , total integrated cost =  33286.950536788085
# RUN  110 , total integrated cost =  33286.95053675952
# RUN  120 , total integrated cost =  33286.95053673396
# RUN  130 , total integrated cost =  33286.95053670798
# RUN  140 , total integrated cost =  33286.950536681885
# RUN  150 , total integrated cost =  33286.950536655066
# RUN  160 , total integrated cost =  33286.95053662882
# RUN  170 , total integrated cost =  33286.950536603734
# RUN  180 , total integrated cost =  33286.95053657864
# RUN  190 , total integrated cost =  33286.950536552824
# RUN  200 , total integrated cost =  33286.950536525874
# RUN  300 , total integrated cost =  33286.950536271455
# RUN  400 , total integrated cost =  33286.95053598953
# RUN  500 , total integrated cost =  33286.95053572087
# RUN  600 , total integrated cost =  33286.95053546814
# RUN  700 , total integrated cost =  33286.95053521609
# RUN  800 , total integrated cost =  33286.95053495802
# RUN  900 , total integrated cost =  33286.950534693184
# RUN  1000 , total integrated cost =  33286.950534440904
# RUN  1100 , total integrated cost =  33286.95053418054
# RUN  1200 , total integrated cost =  33286.95053392385
# RUN  1300 , total integrated cost =  33286.950533653944
# RUN  1400 , total integrated cost =  33286.950533384246
# RUN  1500 , total integrated cost =  33286.950533115705
# RUN  1600 , total integrated cost =  33286.950532847455
# RUN  1700 , total integrated cost =  33286.95053258023
# RUN  1800 , total integrated cost =  33286.95053231114
# RUN  1900 , total integrated cost =  33286.9505320426
# RUN  2000 , total integrated cost =  33286.950531765804
# RUN  3000 , total integrated cost =  33286.950529119145
# RUN  4000 , total integrated cost =  33286.95052646021
# RUN  5000 , total integrated cost =  33286.9505237708
# RUN  6000 , total integrated cost =  33286.9505210938
# RUN  7000 , total integrated cost =  33286.950518399426
# RUN  8000 , total integrated cost =  33286.950515700104
# RUN  9000 , total integrated cost =  33286.95051296968
# RUN  10000 , total integrated cost =  33286.95051029581
# RUN  10000 , total integrated cost =  33286.95051029581
# Improved over  10000  iterations in  5990.593467220664  seconds by  8.040534282827139e-08  percent.
# no convergence
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  13398.115776791828
# set cost params:  1.0 13398.115776791828 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29793.416143421524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29793.41614289868
# RUN  2 , total integrated cost =  29793.41614249233
# RUN  3 , total integrated cost =  29793.416141969585
# RUN  4 , total integrated cost =  29793.416141563153
# RUN  5 , total integrated cost =  29793.416141040314
# RUN  6 , total integrated cost =  29793.41614063393
# RUN  7 , total integrated cost =  29793.416140111105
# RUN  8 , total integrated cost =  29793.41613970477
# RUN  9 , total integrated cost =  29793.416139181936
# RUN  10 , total integrated cost =  29793.416138775523
# RUN  11 , total integrated cost =  29793.416138252698
# RUN  12 , total integrated cost =  29793.416137846423
# RUN  13 , total integrated cost =  29793.4161373236
# RUN  14 , total integrated cost =  29793.41613691715
# RUN  15 , total integrated cost =  29793.416136394262
# RUN  16 , total integrated cost =  29793.416135988016
# RUN  17 , total integrated cost =  29793.416135465224
# RUN  18 , total integrated cost =  29793.41613505879
# RUN  19 , total integrated cost =  29793.41613453592
# RUN  20 , total integrated cost =  29793.416134129562
# RUN  30 , total integrated cost =  29793.416129483532
# RUN  40 , total integrated cost =  29793.416124835087
# RUN  50 , total integrated cost =  29793.416120189093
# RUN  60 , total integrated cost =  29793.416115543027
# RUN  70 , total integrated cost =  29793.41611089718
# RUN  80 , total integrated cost =  29793.416106251057
# RUN  90 , total integrated cost =  29793.416101602983
# RUN  100 , total integrated cost =  29793.416096956626
# RUN  110 , total integrated cost =  29793.416092310737
# RUN  120 , total integrated cost =  29793.416087664704
# RUN  130 , total integrated cost =  29793.416083018732
# RUN  140 , total integrated cost =  29793.41607837278
# RUN  150 , total integrated cost =  29793.416073726734
# RUN  160 , total integrated cost =  29793.416069080675
# RUN  170 , total integrated cost =  29793.41606443472
# RUN  180 , total integrated cost =  29793.416059788637
# RUN  190 , total integrated cost =  29793.41605514276
# RUN  200 , total integrated cost =  29793.416050496646
# RUN  300 , total integrated cost =  29793.41600403664
# RUN  400 , total integrated cost =  29793.415957574558
# RUN  500 , total integrated cost =  29793.415911114174
# RUN  600 , total integrated cost =  29793.415864651837
# RUN  700 , total integrated cost =  29793.415818191766
# RUN  1000 , total integrated cost =  29793.415678811616
# RUN  1100 , total integrated cost =  29793.41563234928
# RUN  1200 , total integrated cost =  29793.41558588915
# RUN  1300 , total integrated cost =  29793.415539429177
# RUN  1400 , total integrated cost =  29793.415492966735
# RUN  1500 , total integrated cost =  29793.415446506733
# RUN  1600 , total integrated cost =  29793.415400041784
# RUN  1700 , total integrated cost =  29793.41535358179
# RUN  1800 , total integrated cost =  29793.41530712166
# RUN  1900 , total integrated cost =  29793.415260661717
# RUN  2000 , total integrated cost =  29793.415214199238
# RUN  3000 , total integrated cost =  29793.414749589552
# RUN  4000 , total integrated cost =  29793.41428498573
# RUN  5000 , total integrated cost =  29793.41382037866
# RUN  6000 , total integrated cost =  29793.413355764267
# RUN  7000 , total integrated cost =  29793.412891152588
# RUN  8000 , total integrated cost =  29793.412426541192
# RUN  9000 , total integrated cost =  29793.411961936406
# RUN  10000 , total integrated cost =  29793.411497323676
# RUN  10000 , total integrated cost =  29793.411497323676
# Improved over  10000  iterations in  4491.60791359283  seconds by  1.5594377728689324e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  85 0.47500000000000014 0.7250000000000004
# -------  90 0.6000000000000003 0.7250000000000004
# -------  95 0.5250000000000001 0.7500000000000004
# -------  100 0.4500000000000001 0.7750000000000005
# -------  105 0.5750000000000002 0.7750000000000005
# -------  110 0.5000000000000002 0.8000000000000005
# -------  115 0.4250000000000001 0.8250000000000005
# -------  120 0.5500000000000003 0.8250000000000005
# -------  125 0.47500000000000014 0.8500000000000005
# -------  130 0.6000000000000003 0.8500000000000005
# -------  135 0.5250000000000001 0.8750000000000006
# -------  140 0.4500000000000001 0.9000000000000006
# -------  145 0.5750000000000002 0.9000000000000006
# weight =  10734.506268878526
# set cost params:  1.0 10734.506268878526 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33286.950537062825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33286.95053705981
# RUN  2 , total integrated cost =  33286.95053705723
# RUN  3 , total integrated cost =  33286.950537054465
# RUN  4 , total integrated cost =  33286.95053705219
# RUN  5 , total integrated cost =  33286.950537049524
# RUN  6 , total integrated cost =  33286.95053704667
# RUN  7 , total integrated cost =  33286.95053704391
# RUN  8 , total integrated cost =  33286.95053704193
# RUN  9 , total integrated cost =  33286.95053704003
# RUN  10 , total integrated cost =  33286.95053703603
# RUN  11 , total integrated cost =  33286.95053703165
# RUN  12 , total integrated cost =  33286.95053702804
# RUN  13 , total integrated cost =  33286.95053702475
# RUN  14 , total integrated cost =  33286.950537022356
# RUN  15 , total integrated cost =  33286.95053702035
# RUN  16 , total integrated cost =  33286.95053701804
# RUN  17 , total integrated cost =  33286.95053701509
# RUN  18 , total integrated cost =  33286.9505370114
# RUN  19 , total integrated cost =  33286.95053700724
# RUN  20 , total integrated cost =  33286.95053700475
# RUN  30 , total integrated cost =  33286.95053697954
# RUN  40 , total integrated cost =  33286.95053695727
# RUN  50 , total integrated cost =  33286.95053693075
# RUN  60 , total integrated cost =  33286.95053690322
# RUN  70 , total integrated cost =  33286.950536876844
# RUN  80 , total integrated cost =  33286.95053684996
# RUN  90 , total integrated cost =  33286.95053682412
# RUN  100 , total integrated cost =  33286.95053679737
# RUN  110 , total integrated cost =  33286.9505367689
# RUN  120 , total integrated cost =  33286.95053674229
# RUN  130 , total integrated cost =  33286.95053671729
# RUN  140 , total integrated cost =  33286.95053669232
# RUN  150 , total integrated cost =  33286.95053666629
# RUN  160 , total integrated cost =  33286.95053664165
# RUN  170 , total integrated cost =  33286.950536611446
# RUN  180 , total integrated cost =  33286.95053658525
# RUN  190 , total integrated cost =  33286.95053655825
# RUN  200 , total integrated cost =  33286.95053653157
# RUN  300 , total integrated cost =  33286.95053626171
# RUN  400 , total integrated cost =  33286.950535986995
# RUN  500 , total integrated cost =  33286.95053571952
# RUN  600 , total integrated cost =  33286.95053545335
# RUN  700 , total integrated cost =  33286.95053519219
# RUN  800 , total integrated cost =  33286.95053492379
# RUN  900 , total integrated cost =  33286.95053464485
# RUN  1000 , total integrated cost =  33286.950534370364
# RUN  1100 , total integrated cost =  33286.95053409291
# RUN  1200 , total integrated cost =  33286.950533836105
# RUN  1300 , total integrated cost =  33286.95053357158
# RUN  1400 , total integrated cost =  33286.95053330121
# RUN  1500 , total integrated cost =  33286.95053303736
# RUN  1600 , total integrated cost =  33286.95053278938
# RUN  1700 , total integrated cost =  33286.95053253507
# RUN  1800 , total integrated cost =  33286.95053227703
# RUN  1900 , total integrated cost =  33286.950532014096
# RUN  2000 , total integrated cost =  33286.950531732706
# RUN  3000 , total integrated cost =  33286.95052906438
# RUN  4000 , total integrated cost =  33286.950526378314
# RUN  5000 , total integrated cost =  33286.95052371989
# RUN  6000 , total integrated cost =  33286.95052106008
# RUN  7000 , total integrated cost =  33286.95051837534
# RUN  8000 , total integrated cost =  33286.950515631455
# RUN  9000 , total integrated cost =  33286.95051297962
# RUN  10000 , total integrated cost =  33286.95051030796
# RUN  10000 , total integrated cost =  33286.95051030796
# Improved over  10000  iterations in  5973.4783182721585  seconds by  8.037645216063538e-08  percent.
# no convergence
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False]]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  10 0.4250000000000001 0.42500000000000016
# -------  15 0.4500000000000001 0.4500000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  40 0.5250000000000001 0.5500000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  13398.117866300883
# set cost params:  1.0 13398.117866300883 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29793.41614376835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29793.416143245406
# RUN  2 , total integrated cost =  29793.416142839014
# RUN  3 , total integrated cost =  29793.41614231618
# RUN  4 , total integrated cost =  29793.416141909882
# RUN  5 , total integrated cost =  29793.41614138703
# RUN  6 , total integrated cost =  29793.416140980662
# RUN  7 , total integrated cost =  29793.416140457895
# RUN  8 , total integrated cost =  29793.41614005156
# RUN  9 , total integrated cost =  29793.416139528726
# RUN  10 , total integrated cost =  29793.41613912228
# RUN  11 , total integrated cost =  29793.416138599452
# RUN  12 , total integrated cost =  29793.416138193126
# RUN  13 , total integrated cost =  29793.416137670338
# RUN  14 , total integrated cost =  29793.416137263925
# RUN  15 , total integrated cost =  29793.416136741158
# RUN  16 , total integrated cost =  29793.416136334738
# RUN  17 , total integrated cost =  29793.41613581194
# RUN  18 , total integrated cost =  29793.416135405536
# RUN  19 , total integrated cost =  29793.416134882646
# RUN  20 , total integrated cost =  29793.416134476305
# RUN  30 , total integrated cost =  29793.416129830304
# RUN  40 , total integrated cost =  29793.416125184383
# RUN  50 , total integrated cost =  29793.416120538353
# RUN  60 , total integrated cost =  29793.416115889995
# RUN  70 , total integrated cost =  29793.416111243925
# RUN  80 , total integrated cost =  29793.416106597975
# RUN  90 , total integrated cost =  29793.41610195194
# RUN  100 , total integrated cost =  29793.4160973059
# RUN  110 , total integrated cost =  29793.416092659998
# RUN  120 , total integrated cost =  29793.41608801397
# RUN  130 , total integrated cost =  29793.41608336797
# RUN  140 , total integrated cost =  29793.41607872194
# RUN  150 , total integrated cost =  29793.4160740759
# RUN  160 , total integrated cost =  29793.41606942989
# RUN  170 , total integrated cost =  29793.416064783938
# RUN  180 , total integrated cost =  29793.416060137915
# RUN  190 , total integrated cost =  29793.416055491845
# RUN  200 , total integrated cost =  29793.416050845906
# RUN  300 , total integrated cost =  29793.416004386036
# RUN  400 , total integrated cost =  29793.415957926074
# RUN  500 , total integrated cost =  29793.415911463697
# RUN  600 , total integrated cost =  29793.415865003724
# RUN  700 , total integrated cost =  29793.41581854367
# RUN  800 , total integrated cost =  29793.415772081287
# RUN  900 , total integrated cost =  29793.41572562139
# RUN  1000 , total integrated cost =  29793.415679161433
# RUN  1100 , total integrated cost =  29793.41563270153
# RUN  1200 , total integrated cost =  29793.415586241517
# RUN  1300 , total integrated cost =  29793.415539779166
# RUN  1400 , total integrated cost =  29793.415493319197
# RUN  1500 , total integrated cost =  29793.41544685718
# RUN  1600 , total integrated cost =  29793.415400397203
# RUN  1700 , total integrated cost =  29793.41535393488
# RUN  1800 , total integrated cost =  29793.41530747294
# RUN  1900 , total integrated cost =  29793.415261012913
# RUN  2000 , total integrated cost =  29793.415214550587

# %%
"""
for i in i_range_0:
    
    aln.params.mue_ext_mean = exc[i] * 5.
    aln.params.mui_ext_mean = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.mue_ext_mean = exc[i] * 5.
        aln.params.mui_ext_mean = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
