# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy
import matplotlib.colors as mcolors
import networkx as nx
import pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')
    os.chdir('..')
    os.chdir('..')
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc, cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_nw

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

options = {
    'node_color': 'lightgray',
    'node_size': 1000,
    'width': 2,
    'arrowstyle': '-|>',
    'arrowsize': 20,
    'font_size' : 20,
    'font_weight' : 'bold',
    }
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
comp_points = [[1., 0.5], [3., 0.5], [2., 0.5]]

cmat = np.array( [[0., 0.5, 0.], [1., 0., 0.], [1., 0.5, 0.]] ) # diagonal elements are zero, connection strength is 1 from node 0 to node 1
dmat = np.array( [[0., 12., 0.], [10., 0., 0.], [10., 4., 0.]] ) # delay from 0 to 1

N = cmat.shape[0]

G = nx.DiGraph() 
for n in range(cmat.shape[0]):
        for l in range(cmat.shape[1]):
            if cmat[n,l] != 0:
                G.add_edge(l,n)
nx.draw(G, with_labels=True, arrows=True, **options)
plt.show()


colors = []
n = 0
for col in mcolors.TABLEAU_COLORS:
    colors.append(col)
    n += 1
    if n >= N: break

model = WCModel(Cmat=cmat, Dmat=dmat)

dt = 0.1
model.params['dt'] = dt # Integration time step, ms
model.params['duration'] = 1. * 2000 # Simulation time, ms
model.params.signalV = 1.

zero_input = ZeroInput().generate_input(duration=model.params['duration']+model.params.dt, dt=model.params.dt)
rect_input = np.vstack( (zero_input)*2 )
rect_input[0,:500] = 5.
rect_input[0,5000:5500] = -5.

for p in comp_points:
    model.params["exc_ext"] = p[0] + rect_input[0,:]
    model.params["inh_ext"] = p[1]
    model.run()

    for n in range(N):
        plt.plot(model.t, model.exc[n,:], color=colors[n])
    plt.show()

    if p[0] == 2.:

        peaks = scipy.signal.find_peaks(model.exc[0,2000:5000])[0]
        plist = []
        for pind in range(1, len(peaks)):
            plist.append(model.params.dt * (peaks[pind]-peaks[pind-1]))

        period = np.mean(plist)
        print("period = ", period)

        peaksn = [None]*N

        for n in range(N):
            peaksn[n] = scipy.signal.find_peaks(model.exc[n,4000:5000])[0]

        for n in range(N):
            plt.plot(model.t[12000:14000], model.exc[n,12000:14000], color=colors[n])
        plt.show()
# Out:
# period =  15.43157894736842

# %%
def getperiods(x, prominence):
    timing_list = [None] * N
    periods_list = [None] * N

    for n in range(N):
        timing_list[n] = scipy.signal.find_peaks(x[n, 0, 300:], prominence=prominence)[0]
        periods_list[n] = []
        if len(timing_list[n]) < 3:
            continue
        for pind in range(1, len(timing_list[n])):
            periods_list[n].append(model.params.dt * (timing_list[n][pind]-timing_list[n][pind-1]))

    return timing_list, periods_list

# %%
controlmat = np.zeros((N,2))
controlmat[:,0] = 1.

costmat = np.zeros((N, 2))
costmat[:,0] = 1.

duration = 200.
model.params.duration = duration
zero_input0 = ZeroInput().generate_input(duration=duration+model.params.dt, dt=model.params.dt)
zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
zero_control = np.vstack( ([zero_input]*N))

print(zero_input0.shape, zero_input.shape, zero_control.shape)

w2_array = [1e-3, 1e-5]

results = dict()
results["controls"] = [ [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
]

target_array = [0.5*period, 0.9*period, period, 1.1*period, 1.6*period]
results["periods"] = [ [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
]
results["timings"] = [ [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
                        [ [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ], [ [None, None], [None, None], [None, None], [None, None] ] ], 
]
# Out:
# (1, 2001) (1, 3, 2001) (3, 3, 2001)

# %%
it = 100
pr = np.arange(0,101,10)
maxstr = 10.
nmaxdel = model.getMaxDelay()
proms = [0.01, 0.001]

init_control = zero_control.copy()

# %%
for pind in range(len(comp_points)):

    p = comp_points[pind]
    
    testd = 1000.
    model.params.duration = testd
    test_input = ZeroInput().generate_input(duration=testd+model.params.dt, dt=model.params.dt)
    model.params["exc_ext"] = test_input + p[0]
    model.params["inh_ext"] = test_input + p[1]
    model.run()

    einit = np.zeros((N, nmaxdel+1))
    iinit = np.zeros((N, nmaxdel+1))


    for n in range(N):
        einit[n,:] = model.exc[n,-1]
        iinit[n,:] = model.inh[n,-1]

    model.params.duration = duration

    model.params["exc_ext"] = zero_control[:,0,:] + p[0]
    model.params["inh_ext"] = zero_control[:,0,:] + p[1]

    model.params["exc_init"] = einit
    model.params["inh_init"] = iinit

    model.run()

    for itar in range(len(target_array)):

        target_period = target_array[itar]
        i00 = 0
        int0 = np.around( (duration - i00 * target_period) / model.params.dt, 0).astype(int)     
        while int0 > 200:
            i00 += 1
            int0 = np.around( (duration - i00 * target_period) / model.params.dt, 0).astype(int)

        for imet in range(4):

            for iw in range(len(w2_array)):
                
                w2 = w2_array[iw]

                model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,None), cost_matrix=costmat, control_matrix = controlmat)
                model_controlled.maximum_control_strength = maxstr
                model_controlled.weights["w_p"] = 0.
                model_controlled.weights["w_2"] = w2

                if imet in [2]:
                    init_control = zero_control.copy()
                    tarray = np.arange(int0*dt, int0*dt + 2.*target_period, dt)
                    init_control[0,0,int0:int0+len(tarray)] = np.sin(2.*np.pi *tarray/target_period)
                    init_control[0,1,int0:int0+len(tarray)] = np.sin(2.*np.pi *tarray/target_period)

                    model_controlled.control = init_control.copy()
                    model_controlled.update_input()

                if imet == 0:
                    model_controlled.weights["w_f_sync"] = 1.
                elif imet == 1:
                    model_controlled.weights["w_cc"] = 1.
                elif imet == 2:
                    model_controlled.weights["w_ko"] = 1.
                elif imet == 3:
                    model_controlled.weights["w_var"] = 1.

                if type(results["controls"][pind][itar][imet][iw]) != type(None):
                    model_controlled.control = results["controls"][pind][itar][imet][iw].copy()
                    model_controlled.update_input()

                model_controlled.optimize(it)
                results["controls"][pind][itar][imet][iw] = model_controlled.control.copy()

                timings, periods = getperiods(model_controlled.get_xs(), proms[iw])
                results["timings"][pind][itar][imet][iw] = timings
                results["periods"][pind][itar][imet][iw] = periods

                #plot_oc_nw(N, duration, dt, model_controlled.get_xs(), target_period,  model_controlled.control)
# Out:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.4828832846460584
# Converged in iteration 5 with cost -0.4830741766281152
# Final cost : -0.4830741766281152
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.1023928423877145
# Cost in iteration 10: -1.104074600298183
# Converged in iteration 13 with cost -1.1057205322709394
# Final cost : -1.1057205322709394
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 6.076636888222434e-17
# Cost in iteration 10: 6.076636888222434e-17
# Converged in iteration 11 with cost 6.076636888222434e-17
# Final cost : 6.076636888222434e-17
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -4.75545729281315e-16
# Cost in iteration 10: -4.768739575948084e-16
# Converged in iteration 14 with cost -4.768739575948084e-16
# Final cost : -4.768739575948084e-16
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1263.1362250732986
# Converged in iteration 2 with cost -1263.6202595645286
# Final cost : -1263.6202595645286
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1211.0518813569245
# Converged in iteration 3 with cost -1253.2564102771046
# Final cost : -1253.2564102771046
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 6.22375153301888e-05
# Converged in iteration 3 with cost 6.171117354628126e-05
# Final cost : 6.171117354628126e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 1.7719939796719058e-05
# Converged in iteration 4 with cost 6.032208408874733e-06
# Final cost : 6.032208408874733e-06
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.9778170816132488
# Converged in iteration 8 with cost -0.9785607699622342
# Final cost : -0.9785607699622342
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.8399046694670086e-05
# Converged in iteration 2 with cost 3.8399046694670086e-05
# Final cost : 3.8399046694670086e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.5699696759990903
# Converged in iteration 7 with cost -0.6880872305894841
# Final cost : -0.6880872305894841
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.3081003055184839
# Cost in iteration 10: -1.3084255761289758
# Converged in iteration 16 with cost -1.3088345656782456
# Final cost : -1.3088345656782456
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.410245285514528e-15
# Converged in iteration 2 with cost 3.410245285514528e-15
# Final cost : 3.410245285514528e-15
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.410245285514528e-15
# Converged in iteration 2 with cost 3.410245285514528e-15
# Final cost : 3.410245285514528e-15
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -143.85960370445443
# Converged in iteration 2 with cost -143.90909517870514
# Final cost : -143.90909517870514
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -85.06895945474683
# Converged in iteration 2 with cost -85.96917094908765
# Final cost : -85.96917094908765
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004250785565121947
# Converged in iteration 2 with cost 0.0004250716871678402
# Final cost : 0.0004250716871678402
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.870586176554993e-05
# Converged in iteration 2 with cost 3.870586176554993e-05
# Final cost : 3.870586176554993e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.18232608024603525
# Converged in iteration 5 with cost -0.18584281020408805
# Final cost : -0.18584281020408805
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.8301906434377829
# Cost in iteration 10: -0.8301940103138049
# Cost in iteration 20: -0.8301965924487837
# Converged in iteration 23 with cost -0.8301966518670167
# Final cost : -0.8301966518670167
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.8905775712306134e-15
# Converged in iteration 2 with cost 3.8905775712306134e-15
# Final cost : 3.8905775712306134e-15
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 3.8905775712306134e-15
# Converged in iteration 2 with cost 3.8905775712306134e-15
# Final cost : 3.8905775712306134e-15
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -76.89854480987624
# Converged in iteration 2 with cost -76.89854481437511
# Final cost : -76.89854481437511
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -78.81692687948676
# Converged in iteration 2 with cost -78.81692687948676
# Final cost : -78.81692687948676
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.00044964266619202964
# Converged in iteration 2 with cost 0.00044963541096305123
# Final cost : 0.00044963541096305123
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 4.093598681875274e-05
# Converged in iteration 2 with cost 4.093598681875274e-05
# Final cost : 4.093598681875274e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.5037598392567134
# Converged in iteration 5 with cost -0.5453238940963574
# Final cost : -0.5453238940963574
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.1301960833481088
# Cost in iteration 10: -1.1459297663277397
# Converged in iteration 13 with cost -1.148579169354275
# Final cost : -1.148579169354275
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.041937643534644
# Converged in iteration 2 with cost -1.041937643534644
# Final cost : -1.041937643534644
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.2711069122777887
# Converged in iteration 2 with cost -1.2711069122777887
# Final cost : -1.2711069122777887
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1423.0564241124114
# Converged in iteration 3 with cost -1462.8412415435291
# Final cost : -1462.8412415435291
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1431.5682916107153
# Converged in iteration 3 with cost -1471.1716746029967
# Final cost : -1471.1716746029967
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.8956091199257863
# Converged in iteration 3 with cost 0.617096571854554
# Final cost : 0.617096571854554
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.6347005802944774
# Converged in iteration 3 with cost 0.5457217529461738
# Final cost : 0.5457217529461738
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.7160775380377453
# Converged in iteration 2 with cost -0.7364346480558934
# Final cost : -0.7364346480558934
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.868711669368557
# Cost in iteration 10: -1.2196082985267056
# Converged in iteration 16 with cost -1.2207790945424017
# Final cost : -1.2207790945424017
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -1.0111575375987778
# Converged in iteration 2 with cost -1.0111575375987778
# Final cost : -1.0111575375987778
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.5780095246115357
# Converged in iteration 3 with cost 0.4272395885833665
# Final cost : 0.4272395885833665

# %%
with open('snych_3n.pickle', 'wb') as f:
    pickle.dump(results, f)

# %%
with open('snych_3n.pickle', 'rb') as f:
    res_read = pickle.load(f)
    print(res_read.keys() )
# Out:
# dict_keys(['controls', 'periods', 'timings'])

# %%
xl = [ ["Down F", "Up F", "Osc F"], ["Down CC", "Up CC", "Osc CC"], ["Down KO", "Up KO", "Osc KO"], ["Down Var", "Up Var", "Osc Var"]]

# %%
for iw in range(len(w2_array)):
    ydata = []
    xlabels = []
    fig = plt.figure(figsize =(30, 10))
    ax = fig.add_axes([0, 0, 1, 1])

    for imet in range(4):

        for pind in range(len(comp_points)):

            for itar in range(len(target_array)):

                target_period = target_array[itar]
                xpos = 15*imet + 5*pind + itar

                if itar != 0:
                    xlabels.append("")
                else:
                    xlabels.append(xl[imet][pind])

                data = results["periods"][pind][itar][imet][iw]
                ydata_ = []
                
                if data is None:
                    ydata.append(ydata_)
                    continue

                n_datapoints = 0

                for n in range(N):
                    n_datapoints += len(data[n])
                    
                    if len(data[n]) != 0:
                        for dpoint in data[n]:
                            ax.plot(xpos+1, dpoint, marker="x", color=colors[n])
                            ydata_.append(dpoint)

                ydata.append(ydata_)

                ax.text(xpos+1, 1, str(n_datapoints), horizontalalignment='center', verticalalignment='center')
                ax.hlines(target_period, xpos+0.5, xpos+1.5, linestyle=":", color="red", linewidth =3)


    ax.boxplot(ydata, showfliers=False)
    ax.plot()
    ax.vlines([15.5, 30.5, 45.5], 0., 2.*period, color="grey")
    ax.hlines(period, 1., len(xlabels), linestyle=":", color="grey",linewidth = 1)
    ax.set_xticklabels(xlabels)
    ax.set_ylim(0., 2.*period)
    ax.set_title(r"Period duration, $w_2 = $" + "{}".format(w2_array[iw]))
    plt.show()
    #fig.savefig("wc_xup_" + str(iw) + ".png", bbox_inches='tight')

# %%
for iw in range(len(w2_array)):
    ydata = []
    xlabels = []
    fig = plt.figure(figsize =(20, 8))
    ax = fig.add_axes([0, 0, 1, 1])

    for imet in range(4):

        for pind in range(len(comp_points)):

            for itar in range(len(target_array)):

                xpos = 15*imet + 5*pind + itar

                if itar != 0:
                    xlabels.append("")
                else:
                    xlabels.append(xl[imet][pind])

                data = results["timings"][pind][itar][imet][iw]
                ydata_ = []

                if data is None:
                    ydata.append(ydata_)
                    continue

                n_maxpeaks = 0

                for n in range(1, N):
                    if len(data[n]) > len(data[n_maxpeaks]):
                        n_maxpeaks = n

                n_datapoints = 0

                for n in range(N):
                    n_datapoints += len(data[n])
                    if n == n_maxpeaks:
                        continue
                    for p in data[n]:
                        dpoint = np.amin(np.abs(p - data[n_maxpeaks])) * dt
                        ydata_.append( dpoint )
                        ax.plot(xpos+1, dpoint, marker="x", color=colors[n])
                ax.text(xpos+1, -0.5, str(n_datapoints), horizontalalignment='center', verticalalignment='center')

                ydata.append(ydata_)

    ax.boxplot(ydata, showfliers=False)
    ax.plot()
    ax.hlines(0., 1., len(xlabels), linestyle=":", color="red",linewidth = 1)
    ax.vlines([15.5, 30.5, 45.5], -1.,period, color="grey")
    ax.set_xticklabels(xlabels)
    ax.set_ylim(-1., period)
    ax.set_title(r"Time between peaks of different nodes, $w_2 = $" + "{}".format(w2_array[iw]))
    plt.show()
    #fig.savefig("wc_xup_" + str(iw) + ".png", bbox_inches='tight')
