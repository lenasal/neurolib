# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy
import pickle
import copy

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.control.optimal_control import oc_wc, cost_functions
from neurolib.experiments.WPtwo.onen.plot import plot_1n_osc, plot_1n_osc_noisy

import matplotlib as mpl
label_size= 20
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size
mpl.rcParams['font.size'] = label_size
mpl.rcParams['axes.titlesize'] = label_size

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

while "Promotion/neurolib" in os.getcwd():
    os.chdir('..')

pickledir = os.path.join(os.getcwd(), "neurolib_aln_osc_datastorage/optimal_control/WP2/1n")
dir = os.path.join(pickledir, "images_1n_wc_w1T")

print(dir)
# Out:
# /home/lena/Promotion/neurolib_aln_osc_datastorage/optimal_control/WP2/1n/images_1n_wc_w1T

# %%
w1_array_list = []
w1_array_list.append(np.array([3.*1e-6, 1e-5, 3. * 1e-5, 1e-4, 3. * 1e-4, 1e-3, 3. * 1e-3, 1e-2, 3. * 1e-2, 1e-1]))
w1_array_list.append(np.array([3.*1e-6, 1e-5, 3. * 1e-5, 1e-4, 3. * 1e-4, 1e-3, 3. * 1e-3, 1e-2, 3. * 1e-2, 1e-1]))
w1_array_list.append(np.array([3.*1e-6, 1e-5, 3. * 1e-5, 1e-4, 3. * 1e-4, 1e-3, 3. * 1e-3, 1e-2, 3. * 1e-2, 1e-1]))
w1_array_list.append(np.array([3.*1e-6, 1e-5, 3. * 1e-5, 1e-4, 3. * 1e-4, 1e-3, 3. * 1e-3, 1e-2, 3. * 1e-2, 1e-1]))

# %%
data = dict()

p_names = ["A", "B", "C", "D"]
coords = [[1., 1., "A"], [1.7, 2., "B"], [3., 1., "C"], [4., 2., "D"]]

for i in range(len(p_names)):
    p = p_names[i]
    data[p] = dict()
    data[p]["coordinates"] = coords[i]
    data[p]["target_period"] = 25.
    data[p]["control"] = [None for x in range(len(w1_array_list[i]))]
    data[p]["state"] = [None for x in range(len(w1_array_list[i]))]
    data[p]["w1"] = w1_array_list[i].copy()

N = 1
model = WCModel()
print(data)

dt = model.params['dt']
# Out:
# {'A': {'coordinates': [1.0, 1.0, 'A'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([3.e-06, 1.e-05, 3.e-05, 1.e-04, 3.e-04, 1.e-03, 3.e-03, 1.e-02,
#        3.e-02, 1.e-01])}, 'B': {'coordinates': [1.7, 2.0, 'B'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([3.e-06, 1.e-05, 3.e-05, 1.e-04, 3.e-04, 1.e-03, 3.e-03, 1.e-02,
#        3.e-02, 1.e-01])}, 'C': {'coordinates': [3.0, 1.0, 'C'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([3.e-06, 1.e-05, 3.e-05, 1.e-04, 3.e-04, 1.e-03, 3.e-03, 1.e-02,
#        3.e-02, 1.e-01])}, 'D': {'coordinates': [4.0, 2.0, 'D'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([3.e-06, 1.e-05, 3.e-05, 1.e-04, 3.e-04, 1.e-03, 3.e-03, 1.e-02,
#        3.e-02, 1.e-01])}}

# %%
controlmat = np.zeros((N,2))
controlmat[:,0] = 1.

costmat = np.zeros((N, 2))
costmat[:,0] = 1.

duration = 200.
model.params.duration = duration
zero_input0 = ZeroInput().generate_input(duration=duration+model.params.dt, dt=model.params.dt)
zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
zero_control = np.vstack( ([zero_input]*N))

it = 50
maxstr = 5
pr = np.arange(0,1001,50)
init_control = zero_control.copy()

# %%
for i in range(len(p_names)):
    
    p = data[p_names[i]]["coordinates"]

    print("pind = ", i, p_names[i], p)
    
    testd = 1000.
    model.params.duration = testd
    test_input = ZeroInput().generate_input(duration=testd+model.params.dt, dt=model.params.dt)
    model.params["exc_ext"] = test_input + p[0]
    model.params["inh_ext"] = test_input + p[1]
    model.run()

    einit = np.zeros((N, 1))
    iinit = np.zeros((N, 1))
    for n in range(N):
        einit[n,:] = model.exc[n,-1]
        iinit[n,:] = model.inh[n,-1]

    model.params.duration = duration
    model.params["exc_ext"] = zero_control[:,0,:] + p[0]
    model.params["inh_ext"] = zero_control[:,0,:] + p[1]
    model.params["exc_init"] = einit
    model.params["inh_init"] = iinit

    model.run()

    target_period = data[p_names[i]]["target_period"]
    int0 = 250
    int1 = int0 + int(target_period/dt)*6

    for iw in range(len(data[p_names[i]]["w1"])):

        w1 = data[p_names[i]]["w1"][iw]
        print("iw = ", iw, w1)

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat)
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1T"] = w1
        model_controlled.weights["w_f"] = 1.
        model_controlled.compute_step_per_nv = False

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(data[p_names[i]]["control"][iw]) != type(None):
                model_controlled.control = data[p_names[i]]["control"][iw].copy()
                model_controlled.update_input()

        model_controlled.step = 1e-2
        model_controlled.optimize(it)

        if True:
            for l in range(2):
                for k in range(0,9,1):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10.**(k)
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10.**(-k)
                    model_controlled.optimize(it)

        data[p_names[i]]["control"][iw] = model_controlled.control.copy()
        data[p_names[i]]["state"][iw] = model_controlled.get_xs()

    with open(os.path.join(pickledir, 'osc_1n_wc_w1T.pickle'), 'wb') as f:
        pickle.dump(data, f)
# Out:
# pind =  0 A [1.0, 1.0, 'A']
# iw =  0 3e-06
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Cost in iteration 50: -0.2857223436336126
# Final cost : -0.2857223436336126
# Compute control for a deterministic system
# Cost in iteration 0: -0.2857223436336126
# Converged in iteration 32 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 1 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# Compute control for a deterministic system
# Cost in iteration 0: -0.28602475497914687
# Converged in iteration 2 with cost -0.28602475497914687
# Final cost : -0.28602475497914687
# iw =  1 1e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Cost in iteration 50: -0.2850633837029387
# Final cost : -0.2850633837029387
# Compute control for a deterministic system
# Cost in iteration 0: -0.2850633837029387
# Converged in iteration 4 with cost -0.28506338370293877
# Final cost : -0.28506338370293877
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293877
# Converged in iteration 2 with cost -0.28506338370293877
# Final cost : -0.28506338370293877
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293877
# Converged in iteration 1 with cost -0.28506338370293877
# Final cost : -0.28506338370293877
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293877
# Converged in iteration 2 with cost -0.28506338370293877
# Final cost : -0.28506338370293877
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293877
# Converged in iteration 1 with cost -0.28506338370293877
# Final cost : -0.28506338370293877
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293877
# Converged in iteration 5 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 1 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# Compute control for a deterministic system
# Cost in iteration 0: -0.28506338370293866
# Converged in iteration 2 with cost -0.28506338370293866
# Final cost : -0.28506338370293866
# iw =  2 3.0000000000000004e-05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Cost in iteration 50: -0.28324861088800357
# Final cost : -0.28324861088800357
# Compute control for a deterministic system
# Cost in iteration 0: -0.28324861088800357
# Converged in iteration 29 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 4 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 3 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 1 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# Compute control for a deterministic system
# Cost in iteration 0: -0.28352524969212994
# Converged in iteration 2 with cost -0.28352524969212994
# Final cost : -0.28352524969212994
# iw =  3 0.0001
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 24 with cost -0.2769556146805719
# Final cost : -0.2769556146805719
# Compute control for a deterministic system
# Cost in iteration 0: -0.2769556146805719
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 4 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 3 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 1 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# Compute control for a deterministic system
# Cost in iteration 0: -0.27695561468057195
# Converged in iteration 2 with cost -0.27695561468057195
# Final cost : -0.27695561468057195
# iw =  4 0.00030000000000000003
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 27 with cost -0.2707764664500434
# Final cost : -0.2707764664500434
# Compute control for a deterministic system
# Cost in iteration 0: -0.2707764664500434
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 3 with cost -0.2707764664500434
# Final cost : -0.2707764664500434
# Compute control for a deterministic system
# Cost in iteration 0: -0.2707764664500434
# Converged in iteration 1 with cost -0.2707764664500434
# Final cost : -0.2707764664500434
# Compute control for a deterministic system
# Cost in iteration 0: -0.2707764664500434
# Converged in iteration 4 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 1 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# Compute control for a deterministic system
# Cost in iteration 0: -0.27077646645004344
# Converged in iteration 2 with cost -0.27077646645004344
# Final cost : -0.27077646645004344
# iw =  5 0.001
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 2 with cost -7.282966732422609e-08
# Final cost : -7.282966732422609e-08
# Compute control for a deterministic system
# Cost in iteration 0: -7.282966732422609e-08
# Converged in iteration 2 with cost -3.6288297893436843e-06
# Final cost : -3.6288297893436843e-06
# Compute control for a deterministic system
# Cost in iteration 0: -3.6288297893436843e-06
# Converged in iteration 1 with cost -3.6288297893436843e-06
# Final cost : -3.6288297893436843e-06
# Compute control for a deterministic system
# Cost in iteration 0: -3.6288297893436843e-06
# Converged in iteration 2 with cost -3.336090564875843e-05
# Final cost : -3.336090564875843e-05
# Compute control for a deterministic system
# Cost in iteration 0: -3.336090564875843e-05
# Converged in iteration 1 with cost -3.336090564875843e-05
# Final cost : -3.336090564875843e-05
# Compute control for a deterministic system
# Cost in iteration 0: -3.336090564875843e-05
# Converged in iteration 2 with cost -0.0003363597584478159
# Final cost : -0.0003363597584478159
# Compute control for a deterministic system
# Cost in iteration 0: -0.0003363597584478159
# Converged in iteration 1 with cost -0.0003363597584478159
# Final cost : -0.0003363597584478159
# Compute control for a deterministic system
# Cost in iteration 0: -0.0003363597584478159
# Converged in iteration 2 with cost -0.0033821135104968917
# Final cost : -0.0033821135104968917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0033821135104968917
# Converged in iteration 1 with cost -0.0033821135104968917
# Final cost : -0.0033821135104968917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0033821135104968917
# Converged in iteration 10 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 2 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 2 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 2 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 3 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 2 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 1 with cost -0.23267305552594392
# Final cost : -0.23267305552594392
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594392
# Converged in iteration 2 with cost -0.23267305552594386
# Final cost : -0.23267305552594386
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594386
# Converged in iteration 1 with cost -0.23267305552594386
# Final cost : -0.23267305552594386
# Compute control for a deterministic system
# Cost in iteration 0: -0.23267305552594386
# Converged in iteration 3 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 1 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 2 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 1 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 3 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 1 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 2 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 1 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 2 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 1 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# Compute control for a deterministic system
# Cost in iteration 0: -0.2326730555259439
# Converged in iteration 2 with cost -0.2326730555259439
# Final cost : -0.2326730555259439
# iw =  6 0.003
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 3 with cost -2.8016557063449393e-07
# Final cost : -2.8016557063449393e-07
# Compute control for a deterministic system
# Cost in iteration 0: -2.8016557063449393e-07
# Converged in iteration 2 with cost -1.6040297458736098e-05
# Final cost : -1.6040297458736098e-05
# Compute control for a deterministic system
# Cost in iteration 0: -1.6040297458736098e-05
# Converged in iteration 1 with cost -1.6040297458736098e-05
# Final cost : -1.6040297458736098e-05
# Compute control for a deterministic system
# Cost in iteration 0: -1.6040297458736098e-05
# Converged in iteration 2 with cost -0.0001471737261241965
# Final cost : -0.0001471737261241965
# Compute control for a deterministic system
# Cost in iteration 0: -0.0001471737261241965
# Converged in iteration 1 with cost -0.0001471737261241965
# Final cost : -0.0001471737261241965
# Compute control for a deterministic system
# Cost in iteration 0: -0.0001471737261241965
# Converged in iteration 2 with cost -0.0014887542104203427
# Final cost : -0.0014887542104203427
# Compute control for a deterministic system
# Cost in iteration 0: -0.0014887542104203427
# Converged in iteration 1 with cost -0.0014887542104203427
# Final cost : -0.0014887542104203427
# Compute control for a deterministic system
# Cost in iteration 0: -0.0014887542104203427
# Converged in iteration 2 with cost -0.022363964842165976
# Final cost : -0.022363964842165976
# Compute control for a deterministic system
# Cost in iteration 0: -0.022363964842165976
# Converged in iteration 2 with cost -0.022363964842165976
# Final cost : -0.022363964842165976
# Compute control for a deterministic system
# Cost in iteration 0: -0.022363964842165976
# Converged in iteration 6 with cost -0.21313449540803195
# Final cost : -0.21313449540803195
# Compute control for a deterministic system
# Cost in iteration 0: -0.21313449540803195
# Converged in iteration 3 with cost -0.21313449540803198
# Final cost : -0.21313449540803198
# Compute control for a deterministic system
# Cost in iteration 0: -0.21313449540803198
# Converged in iteration 1 with cost -0.21313449540803198
# Final cost : -0.21313449540803198
# Compute control for a deterministic system
# Cost in iteration 0: -0.21313449540803198
# Converged in iteration 4 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 1 with cost -0.213134495408032
# Final cost : -0.213134495408032
# Compute control for a deterministic system
# Cost in iteration 0: -0.213134495408032
# Converged in iteration 2 with cost -0.213134495408032
# Final cost : -0.213134495408032
# iw =  7 0.01
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 1 with cost -2.6259377254253085e-18
# Final cost : -2.6259377254253085e-18
# Compute control for a deterministic system
# Cost in iteration 0: -2.6259377254253085e-18
# Converged in iteration 3 with cost -0.07658503749953707
# Final cost : -0.07658503749953707
# ...
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Cost in iteration 50: -6.241476986106756e-17
# Final cost : -6.241476986106756e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241476986106756e-17
# Converged in iteration 1 with cost -6.241476986106756e-17
# Final cost : -6.241476986106756e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241476986106756e-17
# Converged in iteration 8 with cost -0.10331107933172215
# Final cost : -0.10331107933172215
# Compute control for a deterministic system
# Cost in iteration 0: -0.10331107933172215
# Converged in iteration 6 with cost -0.1033110793317221
# Final cost : -0.1033110793317221
# Compute control for a deterministic system
# Cost in iteration 0: -0.1033110793317221
# Converged in iteration 1 with cost -0.1033110793317221
# Final cost : -0.1033110793317221
# Compute control for a deterministic system
# Cost in iteration 0: -0.1033110793317221
# Converged in iteration 4 with cost -0.10331107933172197
# Final cost : -0.10331107933172197
# Compute control for a deterministic system
# Cost in iteration 0: -0.10331107933172197
# Converged in iteration 1 with cost -0.10331107933172197
# Final cost : -0.10331107933172197
# Compute control for a deterministic system
# Cost in iteration 0: -0.10331107933172197
# Converged in iteration 5 with cost -0.10331107933172204
# Final cost : -0.10331107933172204
# Compute control for a deterministic system
# Cost in iteration 0: -0.10331107933172204
# Converged in iteration 1 with cost -0.10331107933172204
# Final cost : -0.10331107933172204
# Compute control for a deterministic system
# Cost in iteration 0: -0.10331107933172204
# Converged in iteration 2 with cost -0.10331107933172204
# Final cost : -0.10331107933172204
# iw =  8 0.03
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# iw =  9 0.1
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17
# Compute control for a deterministic system
# Cost in iteration 0: -6.241478011461862e-17
# Converged in iteration 1 with cost -6.241478011461862e-17
# Final cost : -6.241478011461862e-17

# %%
indzoom = np.zeros((len(p_names), len(w1_array_list[0])))
indzoom[0,:] = 6
indzoom[1,:] = 6
indzoom[2,:] = 5
indzoom[3,:] = 6

indzoom[0,5] = 5
indzoom[2,6] = 3
indzoom[2,7] = 4
indzoom[3,1] = 5
indzoom[3,3] = 5
indzoom[3,4] = 5
indzoom[3,7] = 5



plot_1n_osc([ data["A"]["state"], data["B"]["state"], data["C"]["state"], data["D"]["state"] ],
            [ data["A"]["control"], data["B"]["control"], data["C"]["control"], data["D"]["control"] ],
            duration, model.params.dt,
            [ data["A"]["w1"], data["B"]["w1"], data["C"]["w1"], data["D"]["w1"], ],
            indzoom,
            os.path.join(dir, "WC_w1T.pdf")
            )

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1T.pickle'), 'wb') as f:
    pickle.dump(data, f)

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1T.pickle'), 'rb') as f:
    res_read = pickle.load(f)
    print(res_read.keys() )

data = res_read.copy()
# Out:
# dict_keys(['A', 'B', 'C', 'D'])

# %%
data_noisy = dict()
sigma_array = [1e-2, 5*1e-2, 1e-1]
M = 100
w1_n = 4

for i in range(len(p_names)):
    p = p_names[i]
    if p != "D": continue
    data_noisy = dict()
    data_noisy["coordinates"] = coords[i]
    data_noisy["target_period"] = 25.
    data_noisy["control"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["state"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["cost"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["w1"] = np.array([4. * 1e-5, 6. * 1e-5, 8. * 1e-5, 1e-4])


    data_noisy["control_det"] = data[p]["control"][1].copy()
    data_noisy["cost_det"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["state_det"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

    data_noisy["control_det_opt"] = [[data[p]["control"][1].copy() for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["cost_det_opt"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["state_det_opt"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

    data_noisy["state_det_opt_det"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

# %%
it = 100

p = data_noisy["coordinates"]
testd = 1000.
pr = np.arange(0,1001,100)

target_period = data_noisy["target_period"]
int0 = 250
int1 = int0 + int(target_period/dt)*6

wind = 0

for si in range(len(sigma_array)):
    print("SIGMA = ", sigma_array[si])
    w1 = data_noisy["w1"][wind]

    model.params.sigma_ou = sigma_array[si]

    model.params.duration = testd
    model.params["exc_ext"] = p[0]
    model.params["inh_ext"] = p[1]
    model.run()

    einit = np.zeros((N, 1))
    iinit = np.zeros((N, 1))
    for n in range(N):
        einit[n,:] = np.mean(model.exc[n,1000:])
        iinit[n,:] = np.mean(model.inh[n,1000:])

    model.params.duration = duration
    model.params["exc_ext"] = zero_control[:,0,:] + p[0]
    model.params["inh_ext"] = zero_control[:,1,:] + p[1]
    model.params["exc_init"] = einit
    model.params["inh_init"] = iinit
    model.run()

    if False:
        plt.plot(model.exc[0,:])
        plt.show()

    model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                    M=M,
                                    M_validation=M*10,
                                    validate_per_step=False,
    )
    model_controlled.weights["w_p"] = 0.
    model_controlled.weights["w_1T"] = w1
    model_controlled.weights["w_f"] = 1.

    model_controlled.maximum_control_strength = maxstr

    if True:
        if type(data_noisy["control"][wind][si]) != type(None):
            model_controlled.control = data_noisy["control"][wind][si].copy()
            model_controlled.update_input()

    if True:
        for l in range(2):
            for k in range(-8,9,2):
                model_controlled.step = 10.**k
                model_controlled.optimize(it)
                model_controlled.zero_step_encountered = False

        data_noisy["control"][wind][si] = model_controlled.control.copy()
        data_noisy["cost"][wind][si] = model_controlled.cost_validation

        meanstate = model_controlled.get_xs()
        for m in range(M-1):
            model_controlled.model.run()
            meanstate += model_controlled.get_xs()
        data_noisy["state"][wind][si] = meanstate / M
    
    #################################################

    data_noisy["cost_det"][wind][si], data_noisy["state_det"][wind][si] = get_noisy_cost(data_noisy["control_det"], M, sigma_array[si], p, model_controlled.weights["w_f"], model_controlled.weights["w_1T"])
    print("cost det = ", data_noisy["cost_det"][wind][si])

    #################################################

    if True:

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                        M=M,
                                        M_validation=M*10,
                                        validate_per_step=False,
        )

        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1T"] = w1
        model_controlled.weights["w_f"] = 1.
        model_controlled.maximum_control_strength = maxstr

        model_controlled.control = data_noisy["control_det"].copy()

        if True:
            if type(data_noisy["control_det_opt"][wind][si]) != type(None):
                model_controlled.control = data_noisy["control_det_opt"][wind][si].copy()
        
        model_controlled.update_input()
        
        for l in range(2):
            for k in range(-8,9,2):
                model_controlled.step = 10.**k
                model_controlled.optimize(it)
                model_controlled.zero_step_encountered = False


        data_noisy["control_det_opt"][wind][si] = model_controlled.control.copy()
        data_noisy["cost_det_opt"][wind][si] = model_controlled.cost_validation

        model_controlled.update_input()

        meanstate = model_controlled.get_xs()
        for m in range(M-1):
            model_controlled.model.run()
            meanstate += model_controlled.get_xs()
        data_noisy["state_det_opt"][wind][si] = meanstate / M
        plt.show()

    if True:
        model.params.sigma_ou = 0.
        model.params.duration = testd
        model.params["exc_ext"] = p[0]
        model.params["inh_ext"] = p[1]
        model.run()

        einit = np.zeros((N, 1))
        iinit = np.zeros((N, 1))
        for n in range(N):
            einit[n,:] = model.exc[n,-1]
            iinit[n,:] = model.inh[n,-1]

        model.params.duration = duration
   
        model.params["exc_ext"] = data_noisy["control_det_opt"][wind][si][:,0,:] + p[0]
        model.params["inh_ext"] = data_noisy["control_det_opt"][wind][si][:,1,:] + p[1]
        model.params["exc_init"] = einit
        model.params["inh_init"] = iinit

        model.run()
        data_noisy["state_det_opt_det"][wind][si] = get_xs(model)

    with open(os.path.join(pickledir, 'osc_1n_wc_w1T_noisy.pickle'), 'wb') as f:
        pickle.dump(data, f)
# Out:
# SIGMA =  0.01
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023153795677483056
# Mean cost in iteration 100: -0.0025124133858715147
# Minimal cost found at iteration 57
# Final cost validated with 1000 noise realizations : -0.0023711596538073003
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023477796538023434
# Mean cost in iteration 100: -0.0022074861417725592
# Minimal cost found at iteration 148
# Final cost validated with 1000 noise realizations : -0.0023513573759775504
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002285375150598078
# Mean cost in iteration 100: -0.002621990644954909
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0023465623780816514
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023862607902201695
# Mean cost in iteration 100: -0.0025419285346545794
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0023581473391665673
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0022701804317617246
# Mean cost in iteration 100: -0.0022928925060769836
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0024177607280765814
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023581800316813065
# Mean cost in iteration 100: -0.0024230609300667848
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.002401833814586996
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002198653989148918
# Mean cost in iteration 100: -0.0021767442800307182
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0024081952709744344
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0024338455603610445
# Mean cost in iteration 100: -0.27464458107098527
# Minimal cost found at iteration 721
# Final cost validated with 1000 noise realizations : -0.27439383086317076
# Compute control for a noisy system
# Mean cost in iteration 0: -0.274538729713105
# Mean cost in iteration 100: -0.27914793782939284
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.2791810856814739
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27907889529896995
# Mean cost in iteration 100: -0.2790794510161974
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.27899310604002425
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27949476258154693
# Mean cost in iteration 100: -0.27901423263197267
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.27911482770817897
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27913286617793676
# Mean cost in iteration 100: -0.2792648376741073
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.27915975185495795
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2793384845150956
# Mean cost in iteration 100: -0.2794310208165829
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.27917909589651624
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2787380107068758
# Mean cost in iteration 100: -0.2788456079857832
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.2791757645156895
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2789184184036275
# Mean cost in iteration 100: -0.27887507716871085
# Minimal cost found at iteration 855
# Final cost validated with 1000 noise realizations : -0.2791954747164198
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2793843500624
# Mean cost in iteration 100: -0.28169063888976303
# Minimal cost found at iteration 1593
# Final cost validated with 1000 noise realizations : -0.2815866221980994
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2811305602123441
# Mean cost in iteration 100: -0.2816276743951908
# Minimal cost found at iteration 1593
# Final cost validated with 1000 noise realizations : -0.28140317082394134
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28121986694007395
# Mean cost in iteration 100: -0.28121543378184705
# Minimal cost found at iteration 1593
# Final cost validated with 1000 noise realizations : -0.28146313652805965
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'interval' of function 'fourier_cost'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "neurolib/neurolib/control/optimal_control/cost_functions.py", line 194:
# @numba.njit
# def fourier_cost(data, dt, target_period, cost_matrix, interval):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# 0.026060637627699768 -0.28561071812267386
# cost det =  -0.2595500804949741
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2838153246429566
# Mean cost in iteration 100: -0.2837904571292137
# Minimal cost found at iteration 15
# Final cost validated with 1000 noise realizations : -0.28427803484119313
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28398340194285965
# Mean cost in iteration 100: -0.28386543929382874
# Minimal cost found at iteration 138
# Final cost validated with 1000 noise realizations : -0.28420555743241693
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2836247626104741
# Mean cost in iteration 100: -0.28408217701442084
# Minimal cost found at iteration 138
# Final cost validated with 1000 noise realizations : -0.28406575382577703
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2841476702140698
# Mean cost in iteration 100: -0.2841110271592797
# Minimal cost found at iteration 138
# Final cost validated with 1000 noise realizations : -0.28416219293563993
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2841266297154461
# Mean cost in iteration 100: -0.2840902450793085
# Minimal cost found at iteration 441
# Final cost validated with 1000 noise realizations : -0.28407375795902323
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28459352440068075
# Mean cost in iteration 100: -0.28407589383560616
# Minimal cost found at iteration 441
# Final cost validated with 1000 noise realizations : -0.2843001224229488
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28399817117829995

# %%
for wind in range(w1_n):

        plot_1n_osc_noisy(
                data_noisy["state"][wind], data_noisy["control"][wind], data_noisy["cost"][wind],
                data_noisy["state_det"][wind], data_noisy["control_det"], data_noisy["cost_det"][wind],
                data_noisy["state_det_opt"][wind], data_noisy["control_det_opt"][wind], data_noisy["cost_det_opt"][wind],
                data["D"]["state"][1], data_noisy["state_det_opt_det"][wind],
                duration, dt, sigma_array,  M, os.path.join(dir, "WC_w1D_noisy" + str(wind) + ".pdf"))

        tablestring = ""
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost"][wind][si],3)) + " & "
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost_det"][wind][si],3)) + " & "
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost_det_opt"][wind][si],3)) + " & "
        tablestring = tablestring[:-3]
        tablestring = tablestring + " \\" + "\\"

        print(tablestring)
# Out:
# -0.266 & -0.197 & -0.1 & -0.214 & -0.165 & -0.126 & -0.271 & -0.25 & -0.192 \\
# -0.264 & -0.215 & -0.153 & -0.209 & -0.166 & -0.122 & -0.269 & -0.247 & -0.145 \\
# -0.261 & -0.194 & -0.131 & -0.208 & -0.164 & -0.123 & -0.266 & -0.233 & -0.141 \\
# -0.258 & -0.189 & -0.11 & -0.206 & -0.162 & -0.12 & -0.264 & -0.213 & -0.121 \\

# %%
data_noisy["control"][1] = data_noisy["control"][0].copy()
data_noisy["control"][2] = data_noisy["control"][0].copy()
data_noisy["control"][3] = data_noisy["control"][0].copy()

# %%
it = 100

for wind in range(1, w1_n):

    if wind != 3: continue

    for si in range(len(sigma_array)):
        print("SIGMA = ", sigma_array[si])
        w1 = data_noisy["w1"][wind]

        model.params.sigma_ou = sigma_array[si]

        model.params.duration = testd
        model.params["exc_ext"] = p[0]
        model.params["inh_ext"] = p[1]
        model.run()

        einit = np.zeros((N, 1))
        iinit = np.zeros((N, 1))
        for n in range(N):
            einit[n,:] = np.mean(model.exc[n,1000:])
            iinit[n,:] = np.mean(model.inh[n,1000:])

        model.params.duration = duration
        model.params["exc_ext"] = zero_control[:,0,:] + p[0]
        model.params["inh_ext"] = zero_control[:,1,:] + p[1]
        model.params["exc_init"] = einit
        model.params["inh_init"] = iinit
        model.run()

        if False:
            plt.plot(model.exc[0,:])
            plt.show()

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                        M=M,
                                        M_validation=M*10,
                                        validate_per_step=False,
        )
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1T"] = w1
        model_controlled.weights["w_f"] = 1.

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(data_noisy["control"][wind][si]) != type(None):
                model_controlled.control = data_noisy["control"][wind][si].copy()
                model_controlled.update_input()

        if False:
            for l in range(2):
                for k in range(-8,9,2):
                    model_controlled.step = 10.**k
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False

            data_noisy["control"][wind][si] = model_controlled.control.copy()
            data_noisy["cost"][wind][si] = model_controlled.cost_validation

            meanstate = model_controlled.get_xs()
            for m in range(M-1):
                model_controlled.model.run()
                meanstate += model_controlled.get_xs()
            data_noisy["state"][wind][si] = meanstate / M
        
        #################################################

        data_noisy["cost_det"][wind][si], data_noisy["state_det"][wind][si] = get_noisy_cost(data_noisy["control_det"], M, sigma_array[si], p, model_controlled.weights["w_f"], model_controlled.weights["w_1"])
        print("cost det = ", data_noisy["cost_det"][wind][si])

        #################################################

        if False:

            model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                            M=M,
                                            M_validation=M*10,
                                            validate_per_step=False,
            )

            model_controlled.weights["w_p"] = 0.
            model_controlled.weights["w_1T"] = w1
            model_controlled.weights["w_f"] = 1.
            model_controlled.maximum_control_strength = maxstr

            model_controlled.control = data_noisy["control_det"].copy()

            if True:
                if type(data_noisy["control_det_opt"][wind][si]) != type(None):
                    model_controlled.control = data_noisy["control_det_opt"][wind][si].copy()
            
            model_controlled.update_input()
            
            for l in range(2):
                for k in range(-8,9,2):
                    model_controlled.step = 10.**k
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False

            data_noisy["control_det_opt"][wind][si] = model_controlled.control.copy()
            data_noisy["cost_det_opt"][wind][si] = model_controlled.cost_validation

            model_controlled.update_input()

            meanstate = model_controlled.get_xs()
            for m in range(M-1):
                model_controlled.model.run()
                meanstate += model_controlled.get_xs()
            data_noisy["state_det_opt"][wind][si] = meanstate / M
            plt.show()

        if False:
            model.params.sigma_ou = 0.
            model.params.duration = testd
            model.params["exc_ext"] = p[0]
            model.params["inh_ext"] = p[1]
            model.run()

            einit = np.zeros((N, 1))
            iinit = np.zeros((N, 1))
            for n in range(N):
                einit[n,:] = model.exc[n,-1]
                iinit[n,:] = model.inh[n,-1]

            model.params.duration = duration
    
            model.params["exc_ext"] = data_noisy["control_det_opt"][wind][si][:,0,:] + p[0]
            model.params["inh_ext"] = data_noisy["control_det_opt"][wind][si][:,1,:] + p[1]
            model.params["exc_init"] = einit
            model.params["inh_init"] = iinit

            model.run()
            data_noisy["state_det_opt_det"][wind][si] = get_xs(model)

        with open(os.path.join(pickledir, 'osc_1n_wc_noisy.pickle'), 'wb') as f:
            pickle.dump(data, f)
# Out:
# SIGMA =  0.01
# Optimal control with target oscillation period
# 0.008761615056977106 -0.21522718783732828
# cost det =  -0.20646557278035116
# SIGMA =  0.05
# Optimal control with target oscillation period
# 0.008761615056977106 -0.17037651481468621
# cost det =  -0.1616148997577091
# SIGMA =  0.1
# Optimal control with target oscillation period
# 0.008761615056977106 -0.12894829924722098
# cost det =  -0.12018668419024388

# %%
def get_noisy_cost(control, M, sigma, p, wf, w1):

    mod = copy.deepcopy(model)

    mod.params.sigma_ou = sigma
    mod.params["exc_ext"] = control[:,0,:] + p[0]
    mod.params["inh_ext"] = control[:,1,:] + p[1]
    
    mod.run()
    state = get_xs(mod)
    cost_f = wf * np.sum(cost_functions.fourier_cost(state, dt, data_noisy["target_period"], costmat, [int0, int1]))
    cost_2 = w1 * np.sum(cost_functions.L2_cost(control))*dt

    for m in range(1,10*M):
        mod.run()
        state_add = get_xs(mod)
        cost_f_add = wf * np.sum(cost_functions.fourier_cost(state_add, dt, data_noisy["target_period"], costmat, [int0, int1]))

        cost_f += cost_f_add
        state += state_add

    print(cost_2, cost_f/(10*M))

    return cost_2 + cost_f/(10*M), state/(10*M)

def get_xs(m):

    xs_begin = np.concatenate((m.params["exc_init"], m.params["inh_init"]), axis=1)[
        :, :, np.newaxis
    ]
    xs = np.concatenate(
        (
            xs_begin,
            np.stack((m.exc, m.inh), axis=1),
        ),
        axis=2,
    )

    return xs
