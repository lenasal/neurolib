# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy
import pickle
import copy

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.control.optimal_control import oc_wc, cost_functions
from neurolib.experiments.WPtwo.onen.plot import plot_1n_osc, plot_1n_osc_noisy

import matplotlib as mpl
label_size= 20
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size
mpl.rcParams['font.size'] = label_size
mpl.rcParams['axes.titlesize'] = label_size

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

while "Promotion/neurolib" in os.getcwd():
    os.chdir('..')

pickledir = os.path.join(os.getcwd(), "neurolib_aln_osc_datastorage/optimal_control/WP2/1n")
dir = os.path.join(pickledir, "images_1n_wc_w1D")

print(dir)
# Out:
# /home/lena/Promotion/neurolib_aln_osc_datastorage/optimal_control/WP2/1n/images_1n_wc_w1D

# %%
w1_array_list = []

w1_array_list.append(1e-6 * np.arange(1.0, 11., 1.))
w1_array_list.append(1e-6 * np.arange(1.0, 11., 1.))
w1_array_list.append(1e-6 * np.arange(1.0, 11., 1.))
w1_array_list.append(1e-6 * np.arange(1.0, 11., 1.))

# %%
data = dict()

p_names = ["A", "B", "C", "D"]
coords = [[1., 1., "A"], [1.7, 2., "B"], [3., 1., "C"], [4., 2., "D"]]

for i in range(len(p_names)):
    p = p_names[i]
    data[p] = dict()
    data[p]["coordinates"] = coords[i]
    data[p]["target_period"] = 25.
    data[p]["control"] = [None for x in range(len(w1_array_list[i]))]
    data[p]["state"] = [None for x in range(len(w1_array_list[i]))]
    data[p]["w1"] = w1_array_list[i].copy()

N = 1
model = WCModel()
print(data)

dt = model.params['dt']
# Out:
# {'A': {'coordinates': [1.0, 1.0, 'A'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([1.e-06, 2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06,
#        9.e-06, 1.e-05])}, 'B': {'coordinates': [1.7, 2.0, 'B'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([1.e-06, 2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06,
#        9.e-06, 1.e-05])}, 'C': {'coordinates': [3.0, 1.0, 'C'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([1.e-06, 2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06,
#        9.e-06, 1.e-05])}, 'D': {'coordinates': [4.0, 2.0, 'D'], 'target_period': 25.0, 'control': [None, None, None, None, None, None, None, None, None, None], 'state': [None, None, None, None, None, None, None, None, None, None], 'w1': array([1.e-06, 2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06,
#        9.e-06, 1.e-05])}}

# %%
controlmat = np.zeros((N,2))
controlmat[:,0] = 1.

costmat = np.zeros((N, 2))
costmat[:,0] = 1.

duration = 200.
model.params.duration = duration
zero_input0 = ZeroInput().generate_input(duration=duration+model.params.dt, dt=model.params.dt)
zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
zero_control = np.vstack( ([zero_input]*N))

it = 50
maxstr = 5
pr = np.arange(0,1001,50)
init_control = zero_control.copy()

# %%
for i in range(len(p_names)):
    if i not in [2]: continue
    print(i)
    p = p_names[i]
    print(data[p]["w1"][0])
    data[p]["w1"] *= 2
    print(data[p]["w1"][0])
# Out:
# 2
# 0.005
# 0.01

# %%
for i in range(len(p_names)):

    if i not in [2]: continue
    
    p = data[p_names[i]]["coordinates"]

    print("pind = ", i, p_names[i], p)
    
    testd = 1000.
    model.params.duration = testd
    test_input = ZeroInput().generate_input(duration=testd+model.params.dt, dt=model.params.dt)
    model.params["exc_ext"] = test_input + p[0]
    model.params["inh_ext"] = test_input + p[1]
    model.run()

    einit = np.zeros((N, 1))
    iinit = np.zeros((N, 1))
    for n in range(N):
        einit[n,:] = model.exc[n,-1]
        iinit[n,:] = model.inh[n,-1]

    model.params.duration = duration
    model.params["exc_ext"] = zero_control[:,0,:] + p[0]
    model.params["inh_ext"] = zero_control[:,0,:] + p[1]
    model.params["exc_init"] = einit
    model.params["inh_init"] = iinit

    model.run()

    target_period = data[p_names[i]]["target_period"]
    int0 = 250
    int1 = int0 + int(target_period/dt)*6

    for iw in range(len(data[p_names[i]]["w1"])):

        w1 = data[p_names[i]]["w1"][iw]
        print("iw = ", iw, w1)

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat)
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1D"] = w1
        model_controlled.weights["w_f"] = 1.
        model_controlled.compute_step_per_nv = False

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(data[p_names[i]]["control"][iw]) != type(None):
                model_controlled.control = data[p_names[i]]["control"][iw].copy()
                model_controlled.update_input()

        model_controlled.step = 10.**(-2)
        model_controlled.optimize(it)

        model_controlled.step = 1.
        model_controlled.optimize(it)

        if True:
            for l in range(2):
                for k in range(1,9,1):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10.**(k)
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10.**(-k)
                    model_controlled.optimize(it)

        data[p_names[i]]["control"][iw] = model_controlled.control.copy()
        data[p_names[i]]["state"][iw] = model_controlled.get_xs()

    with open(os.path.join(pickledir, 'osc_1n_wc_w1D.pickle'), 'wb') as f:
        pickle.dump(data, f)
# Out:
# pind =  2 C [3.0, 1.0, 'C']
# iw =  0 0.01
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.16479237836907099
# Converged in iteration 15 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 5 with cost -0.1704451681164694
# Final cost : -0.1704451681164694
# Compute control for a deterministic system
# Cost in iteration 0: -0.1704451681164694
# Converged in iteration 1 with cost -0.1704451681164694
# Final cost : -0.1704451681164694
# Compute control for a deterministic system
# Cost in iteration 0: -0.1704451681164694
# Converged in iteration 3 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 4 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 1 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# Compute control for a deterministic system
# Cost in iteration 0: -0.17044516811646943
# Converged in iteration 2 with cost -0.17044516811646943
# Final cost : -0.17044516811646943
# iw =  1 0.02
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.10490346019653007
# Converged in iteration 15 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 1 with cost -0.1120248850281407
# Final cost : -0.1120248850281407
# Compute control for a deterministic system
# Cost in iteration 0: -0.1120248850281407
# Converged in iteration 7 with cost -0.11202488502814079
# Final cost : -0.11202488502814079
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814079
# Converged in iteration 1 with cost -0.11202488502814079
# Final cost : -0.11202488502814079
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814079
# Converged in iteration 10 with cost -0.11202488502814091
# Final cost : -0.11202488502814091
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814091
# Converged in iteration 1 with cost -0.11202488502814091
# Final cost : -0.11202488502814091
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814091
# Converged in iteration 2 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 2 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 2 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 2 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 2 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 1 with cost -0.11202488502814092
# Final cost : -0.11202488502814092
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814092
# Converged in iteration 5 with cost -0.11202488502814098
# Final cost : -0.11202488502814098
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814098
# Converged in iteration 1 with cost -0.11202488502814098
# Final cost : -0.11202488502814098
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814098
# Converged in iteration 2 with cost -0.11202488502814098
# Final cost : -0.11202488502814098
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814098
# Converged in iteration 1 with cost -0.11202488502814098
# Final cost : -0.11202488502814098
# Compute control for a deterministic system
# Cost in iteration 0: -0.11202488502814098
# Converged in iteration 2 with cost -0.11202488502814098
# Final cost : -0.11202488502814098
# iw =  2 0.03
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.06549278143290999
# Converged in iteration 16 with cost -0.07206254089956354
# Final cost : -0.07206254089956354
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956354
# Converged in iteration 1 with cost -0.07206254089956354
# Final cost : -0.07206254089956354
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956354
# Converged in iteration 1 with cost -0.07206254089956354
# Final cost : -0.07206254089956354
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956354
# Converged in iteration 1 with cost -0.07206254089956354
# Final cost : -0.07206254089956354
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956354
# Converged in iteration 1 with cost -0.07206254089956354
# Final cost : -0.07206254089956354
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956354
# Converged in iteration 7 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 4 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 2 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 2 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 2 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 2 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 1 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# Compute control for a deterministic system
# Cost in iteration 0: -0.07206254089956372
# Converged in iteration 2 with cost -0.07206254089956372
# Final cost : -0.07206254089956372
# iw =  3 0.04
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.008251204549007296
# Converged in iteration 12 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 1 with cost -0.026091703980064884
# Final cost : -0.026091703980064884
# Compute control for a deterministic system
# Cost in iteration 0: -0.026091703980064884
# Converged in iteration 5 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 1 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 1 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 1 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 2 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 1 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 2 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 2 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 2 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 1 with cost -0.02609170398006541
# Final cost : -0.02609170398006541
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006541
# Converged in iteration 4 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 1 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# Compute control for a deterministic system
# Cost in iteration 0: -0.02609170398006544
# Converged in iteration 2 with cost -0.02609170398006544
# Final cost : -0.02609170398006544
# iw =  4 0.05
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.004384149828298739
# Converged in iteration 10 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 1 with cost -0.009703881981577178
# Final cost : -0.009703881981577178
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577178
# Converged in iteration 5 with cost -0.009703881981577234
# Final cost : -0.009703881981577234
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577234
# Converged in iteration 1 with cost -0.009703881981577234
# Final cost : -0.009703881981577234
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577234
# Converged in iteration 1 with cost -0.009703881981577234
# Final cost : -0.009703881981577234
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577234
# Converged in iteration 1 with cost -0.009703881981577234
# Final cost : -0.009703881981577234
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577234
# Converged in iteration 3 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 2 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 2 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 2 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 2 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 1 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# Compute control for a deterministic system
# Cost in iteration 0: -0.009703881981577317
# Converged in iteration 2 with cost -0.009703881981577317
# Final cost : -0.009703881981577317
# iw =  5 0.06
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.03925392146028803
# Converged in iteration 12 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Converged in iteration 1 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Converged in iteration 1 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Converged in iteration 1 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Converged in iteration 1 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Converged in iteration 1 with cost 0.03915581698934684
# Final cost : 0.03915581698934684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03915581698934684
# Cost in iteration 50: -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240557800205e-16
# Converged in iteration 1 with cost -1.5198240557800205e-16
# Final cost : -1.5198240557800205e-16
# iw =  6 0.06999999999999999
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.07414068578496824
# Converged in iteration 4 with cost 0.07409046232535374
# Final cost : 0.07409046232535374
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409046232535374
# Converged in iteration 1 with cost 0.07409046232535374
# Final cost : 0.07409046232535374
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409046232535374
# Converged in iteration 1 with cost 0.07409046232535374
# Final cost : 0.07409046232535374
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409046232535374
# Converged in iteration 1 with cost 0.07409046232535374
# Final cost : 0.07409046232535374
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409046232535374
# Cost in iteration 50: -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198224191940702e-16
# Converged in iteration 1 with cost -1.5198224191940702e-16
# Final cost : -1.5198224191940702e-16
# iw =  7 0.08
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.10735361118463682
# Converged in iteration 4 with cost 0.10726733170008279
# Final cost : 0.10726733170008279
# Compute control for a deterministic system
# Cost in iteration 0: 0.10726733170008279
# Converged in iteration 1 with cost 0.10726733170008279
# Final cost : 0.10726733170008279
# Compute control for a deterministic system
# Cost in iteration 0: 0.10726733170008279
# Converged in iteration 1 with cost 0.10726733170008279
# Final cost : 0.10726733170008279
# Compute control for a deterministic system
# Cost in iteration 0: 0.10726733170008279
# Converged in iteration 1 with cost 0.10726733170008279
# Final cost : 0.10726733170008279
# Compute control for a deterministic system
# Cost in iteration 0: 0.10726733170008279
# Cost in iteration 50: -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198240556088434e-16
# Converged in iteration 1 with cost -1.5198240556088434e-16
# Final cost : -1.5198240556088434e-16
# iw =  8 0.09000000000000001
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.14130595053825032
# Converged in iteration 4 with cost 0.1410873032244397
# Final cost : 0.1410873032244397
# Compute control for a deterministic system
# Cost in iteration 0: 0.1410873032244397
# Converged in iteration 1 with cost 0.1410873032244397
# Final cost : 0.1410873032244397
# Compute control for a deterministic system
# Cost in iteration 0: 0.1410873032244397
# Converged in iteration 1 with cost 0.1410873032244397
# Final cost : 0.1410873032244397
# Compute control for a deterministic system
# Cost in iteration 0: 0.1410873032244397
# Converged in iteration 1 with cost 0.1410873032244397
# Final cost : 0.1410873032244397
# Compute control for a deterministic system
# Cost in iteration 0: 0.1410873032244397
# Cost in iteration 50: -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198241075826138e-16
# Converged in iteration 1 with cost -1.5198241075826138e-16
# Final cost : -1.5198241075826138e-16
# iw =  9 0.1
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544638515850222
# Converged in iteration 1 with cost 0.1544638515850222
# Final cost : 0.1544638515850222
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544638515850222
# Converged in iteration 1 with cost 0.1544638515850222
# Final cost : 0.1544638515850222
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544638515850222
# Converged in iteration 1 with cost 0.1544638515850222
# Final cost : 0.1544638515850222
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544638515850222
# Converged in iteration 1 with cost 0.1544638515850222
# Final cost : 0.1544638515850222
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544638515850222
# Cost in iteration 50: -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16
# Compute control for a deterministic system
# Cost in iteration 0: -1.5198067608416365e-16
# Converged in iteration 1 with cost -1.5198067608416365e-16
# Final cost : -1.5198067608416365e-16

# %%
indzoom = np.zeros((len(p_names), len(w1_array_list[0])))
indzoom[0,:] = 6
indzoom[1,:] = 6
indzoom[2,:] = 5
indzoom[3,:] = 6

plot_1n_osc([ data["A"]["state"], data["B"]["state"], data["C"]["state"], data["D"]["state"] ],
            [ data["A"]["control"], data["B"]["control"], data["C"]["control"], data["D"]["control"] ],
            duration, model.params.dt,
            [ data["A"]["w1"], data["B"]["w1"], data["C"]["w1"], data["D"]["w1"], ],
            indzoom,
            os.path.join(dir, "WC_w1D.pdf")
            )
# Out:
# /home/lena/.local/lib/python3.9/site-packages/sigfig/sigfig.py:586: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# /home/lena/.local/lib/python3.9/site-packages/sigfig/sigfig.py:586: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# /home/lena/.local/lib/python3.9/site-packages/sigfig/sigfig.py:586: UserWarning: warning: 3 significant figures requested from number with only 2 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1D.pickle'), 'wb') as f:
    pickle.dump(data, f)

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1D.pickle'), 'rb') as f:
    res_read = pickle.load(f)
    print(res_read.keys() )

data = res_read.copy()
# Out:
# dict_keys(['A', 'B', 'C', 'D'])

# %%
data_noisy = dict()
sigma_array = [1e-2, 5*1e-2, 1e-1]
M = 100
w1_n = 4

for i in range(len(p_names)):
    p = p_names[i]
    if p != "D": continue
    data_noisy = dict()
    data_noisy["coordinates"] = coords[i]
    data_noisy["target_period"] = 25.
    data_noisy["control"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["state"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["cost"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["w1"] = np.array([1e-4, 1e-3, 1e-2, 1e-1])


    data_noisy["control_det"] = data[p]["control"][1].copy()
    data_noisy["cost_det"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["state_det"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

    data_noisy["control_det_opt"] = [[data[p]["control"][1].copy() for x in range(len(sigma_array))] for x1 in range(w1_n)]
    data_noisy["cost_det_opt"] = np.zeros((w1_n, len(sigma_array)))
    data_noisy["state_det_opt"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

    data_noisy["state_det_opt_det"] = [[None for x in range(len(sigma_array))] for x1 in range(w1_n)]

# %%
it = 100

p = data_noisy["coordinates"]
testd = 1000.
pr = np.arange(0,1001,100)

target_period = data_noisy["target_period"]
int0 = 250
int1 = int0 + int(target_period/dt)*6

wind = 0

for si in range(len(sigma_array)):
    print("SIGMA = ", sigma_array[si])
    w1 = data_noisy["w1"][wind]

    model.params.sigma_ou = sigma_array[si]

    model.params.duration = testd
    model.params["exc_ext"] = p[0]
    model.params["inh_ext"] = p[1]
    model.run()

    einit = np.zeros((N, 1))
    iinit = np.zeros((N, 1))
    for n in range(N):
        einit[n,:] = np.mean(model.exc[n,1000:])
        iinit[n,:] = np.mean(model.inh[n,1000:])

    model.params.duration = duration
    model.params["exc_ext"] = zero_control[:,0,:] + p[0]
    model.params["inh_ext"] = zero_control[:,1,:] + p[1]
    model.params["exc_init"] = einit
    model.params["inh_init"] = iinit
    model.run()

    if False:
        plt.plot(model.exc[0,:])
        plt.show()

    model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                    M=M,
                                    M_validation=M*10,
                                    validate_per_step=False,
    )
    model_controlled.weights["w_p"] = 0.
    model_controlled.weights["w_1D"] = w1
    model_controlled.weights["w_f"] = 1.

    model_controlled.maximum_control_strength = maxstr

    if True:
        if type(data_noisy["control"][wind][si]) != type(None):
            model_controlled.control = data_noisy["control"][wind][si].copy()
            model_controlled.update_input()

    if True:
        for l in range(2):
            for k in range(-8,9,2):
                model_controlled.step = 10.**k
                model_controlled.optimize(it)
                model_controlled.zero_step_encountered = False

        data_noisy["control"][wind][si] = model_controlled.control.copy()
        data_noisy["cost"][wind][si] = model_controlled.cost_validation

        meanstate = model_controlled.get_xs()
        for m in range(M-1):
            model_controlled.model.run()
            meanstate += model_controlled.get_xs()
        data_noisy["state"][wind][si] = meanstate / M
    
    #################################################

    data_noisy["cost_det"][wind][si], data_noisy["state_det"][wind][si] = get_noisy_cost(data_noisy["control_det"], M, sigma_array[si], p, model_controlled.weights["w_f"], model_controlled.weights["w_1D"])
    print("cost det = ", data_noisy["cost_det"][wind][si])

    #################################################

    if True:

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                        M=M,
                                        M_validation=M*10,
                                        validate_per_step=False,
        )

        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1D"] = w1
        model_controlled.weights["w_f"] = 1.
        model_controlled.maximum_control_strength = maxstr

        model_controlled.control = data_noisy["control_det"].copy()

        if True:
            if type(data_noisy["control_det_opt"][wind][si]) != type(None):
                model_controlled.control = data_noisy["control_det_opt"][wind][si].copy()
        
        model_controlled.update_input()
        
        for l in range(2):
            for k in range(-8,9,2):
                model_controlled.step = 10.**k
                model_controlled.optimize(it)
                model_controlled.zero_step_encountered = False


        data_noisy["control_det_opt"][wind][si] = model_controlled.control.copy()
        data_noisy["cost_det_opt"][wind][si] = model_controlled.cost_validation

        model_controlled.update_input()

        meanstate = model_controlled.get_xs()
        for m in range(M-1):
            model_controlled.model.run()
            meanstate += model_controlled.get_xs()
        data_noisy["state_det_opt"][wind][si] = meanstate / M
        plt.show()

    if True:
        model.params.sigma_ou = 0.
        model.params.duration = testd
        model.params["exc_ext"] = p[0]
        model.params["inh_ext"] = p[1]
        model.run()

        einit = np.zeros((N, 1))
        iinit = np.zeros((N, 1))
        for n in range(N):
            einit[n,:] = model.exc[n,-1]
            iinit[n,:] = model.inh[n,-1]

        model.params.duration = duration
   
        model.params["exc_ext"] = data_noisy["control_det_opt"][wind][si][:,0,:] + p[0]
        model.params["inh_ext"] = data_noisy["control_det_opt"][wind][si][:,1,:] + p[1]
        model.params["exc_init"] = einit
        model.params["inh_init"] = iinit

        model.run()
        data_noisy["state_det_opt_det"][wind][si] = get_xs(model)

    with open(os.path.join(pickledir, 'osc_1n_wc_w1D_noisy.pickle'), 'wb') as f:
        pickle.dump(data_noisy, f)
# Out:
# SIGMA =  0.01
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023274066697143822
# Mean cost in iteration 100: -0.0023595346343875927
# Minimal cost found at iteration 37
# Final cost validated with 1000 noise realizations : -0.002333902325192912
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023551124642501174
# Mean cost in iteration 100: -0.0024529666312634903
# Minimal cost found at iteration 37
# Final cost validated with 1000 noise realizations : -0.0023774420641478186
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002328209436408142
# Mean cost in iteration 100: -0.0022119452351380174
# Minimal cost found at iteration 243
# Final cost validated with 1000 noise realizations : -0.0023629879936097973
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0025506769756863026
# Mean cost in iteration 100: -0.002247414241135955
# Minimal cost found at iteration 243
# Final cost validated with 1000 noise realizations : -0.002418964072432285
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0025422436937261443
# Mean cost in iteration 100: -0.0024974839416983022
# Minimal cost found at iteration 243
# Final cost validated with 1000 noise realizations : -0.0023203818444589293
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002434670312564312
# Mean cost in iteration 100: -0.0022658489141566245
# Minimal cost found at iteration 243
# Final cost validated with 1000 noise realizations : -0.0023494267791171687
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023896339792210137
# Mean cost in iteration 100: -0.002283928578009424
# Minimal cost found at iteration 243
# Final cost validated with 1000 noise realizations : -0.0023487357149597665
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0026017830696349396
# Mean cost in iteration 100: -0.26283306710522714
# Minimal cost found at iteration 779
# Final cost validated with 1000 noise realizations : -0.2629518992309806
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26292609076443446
# Mean cost in iteration 100: -0.26872134719231083
# Minimal cost found at iteration 823
# Final cost validated with 1000 noise realizations : -0.2688078772854959
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2685181763473331
# Mean cost in iteration 100: -0.2695713691053557
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.26879461314375835
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26862793722352857
# Mean cost in iteration 100: -0.2689600286004223
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.26897627306709676
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26864433268489146
# Mean cost in iteration 100: -0.26851518711877786
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.2688414495545862
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26862820312992386
# Mean cost in iteration 100: -0.26914345602904893
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.26864573249381474
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26828989078464327
# Mean cost in iteration 100: -0.26863040016445344
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.2687825524512392
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2694231079336926
# Mean cost in iteration 100: -0.26910503013301423
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.26874094581556174
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26897133988832467
# Mean cost in iteration 100: -0.2685741158417644
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.2688343877383092
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26846631505965474
# Mean cost in iteration 100: -0.2686748560886395
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.26867405842722575
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2686724438441321
# Mean cost in iteration 100: -0.2688088913435445
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.2687238342621864
# 0.06515159406924942 -0.28551606834122384
# cost det =  -0.22036447427197442
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28207376093492637
# Mean cost in iteration 100: -0.2819707520600515
# Minimal cost found at iteration 21
# Final cost validated with 1000 noise realizations : -0.2820296912254585
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28219221596439176
# Mean cost in iteration 100: -0.2820438256267435
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.28199739213923175
# Compute control for a noisy system
# Mean cost in iteration 0: -0.281885310786379
# Mean cost in iteration 100: -0.2819867979120717
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.2819540663032905
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28183954025567015
# Mean cost in iteration 100: -0.282335060153522
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.2820678891262497
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2824985060246656
# Mean cost in iteration 100: -0.28227549180439854
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.28212806432019744
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2818779877664487
# Mean cost in iteration 100: -0.28207416054604506
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.2819835084182648
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2820452528930433
# Mean cost in iteration 100: -0.28239032453387997
# Minimal cost found at iteration 152
# Final cost validated with 1000 noise realizations : -0.2820345471290344
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28174821254564303
# Mean cost in iteration 100: -0.2822531620995955
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.2821074237186298
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28230138139929045
# Mean cost in iteration 100: -0.28162839471561585
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.2821016512860318
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28211803858519247
# Mean cost in iteration 100: -0.2822009495051466
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.2820569693884869
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28206200288440175
# Mean cost in iteration 100: -0.28251867351591653
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.2820716656367482
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28220467406741173
# Mean cost in iteration 100: -0.2820020379445191
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.28216144927475595
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2818883689484256
# Mean cost in iteration 100: -0.2822373508621558
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.28202572520062524
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28258355785463707
# Mean cost in iteration 100: -0.282228951413513
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.28234644514610807
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2820380447800411
# Mean cost in iteration 100: -0.281573766696805
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.28218283629972274
# Compute control for a noisy system
# Mean cost in iteration 0: -0.282117828081553
# Mean cost in iteration 100: -0.2821468592821274
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.282103312122282
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28206468330976503
# Mean cost in iteration 100: -0.2816065112540754
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.2821610506531495
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28236215129491893
# Mean cost in iteration 100: -0.2822476455702092
# Minimal cost found at iteration 727
# Final cost validated with 1000 noise realizations : -0.28212834238263695
# SIGMA =  0.05
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02229503173752626
# Mean cost in iteration 100: -0.024857737344807656
# Minimal cost found at iteration 60
# Final cost validated with 1000 noise realizations : -0.02588701880453553
# Compute control for a noisy system
# Mean cost in iteration 0: -0.024076275906963027
# Mean cost in iteration 100: -0.0272613246972248
# Minimal cost found at iteration 166
# Final cost validated with 1000 noise realizations : -0.024903623579490056
# Compute control for a noisy system
# Mean cost in iteration 0: -0.025579419241972975
# Mean cost in iteration 100: -0.02430601973599541
# Minimal cost found at iteration 258
# Final cost validated with 1000 noise realizations : -0.026050861156957348
# Compute control for a noisy system
# Mean cost in iteration 0: -0.022516626804308375
# Mean cost in iteration 100: -0.024395996684625845
# Minimal cost found at iteration 258
# Final cost validated with 1000 noise realizations : -0.02511240274013187
# Compute control for a noisy system
# Mean cost in iteration 0: -0.028982857048759386
# Mean cost in iteration 100: -0.026364892225812772
# Minimal cost found at iteration 258
# Final cost validated with 1000 noise realizations : -0.025460117975414448
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02174898477048427
# Mean cost in iteration 100: -0.02302513031164134
# Minimal cost found at iteration 258
# Final cost validated with 1000 noise realizations : -0.024584841950040875
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02368084775059038
# Mean cost in iteration 100: -0.048199666794163036
# Minimal cost found at iteration 626
# Final cost validated with 1000 noise realizations : -0.04791079006270246
# Compute control for a noisy system
# Mean cost in iteration 0: -0.04913497200285896
# Mean cost in iteration 100: -0.14468872264618318
# Minimal cost found at iteration 704
# Final cost validated with 1000 noise realizations : -0.14299593993937454
# Compute control for a noisy system
# Mean cost in iteration 0: -0.14417729516651137
# Mean cost in iteration 100: -0.17078856987919935
# Minimal cost found at iteration 823
# Final cost validated with 1000 noise realizations : -0.17001417280660674
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16968111400511515
# Mean cost in iteration 100: -0.17148164209031677
# Minimal cost found at iteration 823
# Final cost validated with 1000 noise realizations : -0.17073126644376344
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16817391640619456
# Mean cost in iteration 100: -0.16858993298353095
# Minimal cost found at iteration 1040
# Final cost validated with 1000 noise realizations : -0.16997985401403531
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17030725623624504
# Mean cost in iteration 100: -0.16925109456268966
# Minimal cost found at iteration 1040
# Final cost validated with 1000 noise realizations : -0.16983242545893387
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17042534428924083
# Mean cost in iteration 100: -0.16927067535418747
# Minimal cost found at iteration 1040
# Final cost validated with 1000 noise realizations : -0.1701580271098605
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17049585388460536
# Mean cost in iteration 100: -0.16851406424756887
# Minimal cost found at iteration 1040
# Final cost validated with 1000 noise realizations : -0.16923607309614982
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17070832772550384
# Mean cost in iteration 100: -0.1702017878422737
# Minimal cost found at iteration 1040
# Final cost validated with 1000 noise realizations : -0.16982983511195893
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1702586879865771
# Mean cost in iteration 100: -0.21892592351584586
# Minimal cost found at iteration 1567
# Final cost validated with 1000 noise realizations : -0.21685015195071883
# Compute control for a noisy system
# Mean cost in iteration 0: -0.21636643355507426
# Mean cost in iteration 100: -0.23997873891168858
# Minimal cost found at iteration 1685
# Final cost validated with 1000 noise realizations : -0.24394769111769435
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24308817271726846
# Mean cost in iteration 100: -0.25718471530878123
# Minimal cost found at iteration 1763
# Final cost validated with 1000 noise realizations : -0.2572845129238694
# 0.06515159406924942 -0.27621789828414145
# cost det =  -0.21106630421489203
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27140556905379865
# Mean cost in iteration 100: -0.2732278943921705
# Minimal cost found at iteration 58
# Final cost validated with 1000 noise realizations : -0.272122927038849
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2728108774819715
# Mean cost in iteration 100: -0.2713437201729679
# Minimal cost found at iteration 58
# Final cost validated with 1000 noise realizations : -0.2721541642753482
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27164202357702405
# Mean cost in iteration 100: -0.27314547257541877
# Minimal cost found at iteration 223
# Final cost validated with 1000 noise realizations : -0.2717303181970374
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27242438914327655
# Mean cost in iteration 100: -0.2747287323981809
# Minimal cost found at iteration 330
# Final cost validated with 1000 noise realizations : -0.2726485541148611
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2734900470705844
# Mean cost in iteration 100: -0.27286450907427573
# Minimal cost found at iteration 330
# Final cost validated with 1000 noise realizations : -0.27222779886844123
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2715582175808954
# Mean cost in iteration 100: -0.2716843745995002
# Minimal cost found at iteration 330
# Final cost validated with 1000 noise realizations : -0.27259103372830334
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2720987531378752
# Mean cost in iteration 100: -0.27185609128725136
# Minimal cost found at iteration 654
# Final cost validated with 1000 noise realizations : -0.2725421595230507
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27125770911929675
# Mean cost in iteration 100: -0.2727933975981251
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.27242116982200565
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27375016879370745
# Mean cost in iteration 100: -0.2723481441289659
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.27224084875970883
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2720663199626863
# Mean cost in iteration 100: -0.2711422642241726
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2724310497965088
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27157495297076595
# Mean cost in iteration 100: -0.27314998028831533
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2723311283018442
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2741540162899189
# Mean cost in iteration 100: -0.27058194720774315
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2727740054166645
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2747110493008359
# Mean cost in iteration 100: -0.2730872700856106
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2723872983670041
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27179358034000156
# Mean cost in iteration 100: -0.273167040515565
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.272330427307414
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27444432461001994
# Mean cost in iteration 100: -0.2736774536034547
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2725930164602817
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27260588053493806
# Mean cost in iteration 100: -0.2728339987926279
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2722432417354598
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2714453481428352
# Mean cost in iteration 100: -0.2716892580666903
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.2728701930436974
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27158739302835666
# Mean cost in iteration 100: -0.27282393253225107
# Minimal cost found at iteration 767
# Final cost validated with 1000 noise realizations : -0.27232050088811394
# SIGMA =  0.1
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05560371299089709
# Mean cost in iteration 100: -0.058073273039299794
# Minimal cost found at iteration 13
# Final cost validated with 1000 noise realizations : -0.06116922678579555
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06634219369287671
# Mean cost in iteration 100: -0.05827844815274502
# Minimal cost found at iteration 158
# Final cost validated with 1000 noise realizations : -0.060085811048330454
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06015407677799952
# Mean cost in iteration 100: -0.05669617648657308
# Minimal cost found at iteration 205
# Final cost validated with 1000 noise realizations : -0.059407477887519024
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05661373685428625
# Mean cost in iteration 100: -0.05893958499593238
# Minimal cost found at iteration 205
# Final cost validated with 1000 noise realizations : -0.05776219407146264
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06172919720635413
# Mean cost in iteration 100: -0.053780440569140504
# Minimal cost found at iteration 205
# Final cost validated with 1000 noise realizations : -0.057825869512524455
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05560553890019115
# Mean cost in iteration 100: -0.06276554551911356
# Minimal cost found at iteration 205
# Final cost validated with 1000 noise realizations : -0.059656753878197355
# Compute control for a noisy system
# Mean cost in iteration 0: -0.059051018464083144
# Mean cost in iteration 100: -0.1376585378096051
# Minimal cost found at iteration 612
# Final cost validated with 1000 noise realizations : -0.1385830561668628
# Compute control for a noisy system
# Mean cost in iteration 0: -0.14276524698264242
# Mean cost in iteration 100: -0.23209522574556407
# Minimal cost found at iteration 716
# Final cost validated with 1000 noise realizations : -0.23380153111633337
# Compute control for a noisy system
# Mean cost in iteration 0: -0.22824211430850228
# Mean cost in iteration 100: -0.2423773053778885
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24572263961033444
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24245620617159422
# Mean cost in iteration 100: -0.24864965420183263
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24496996076884298
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24345301856076124
# Mean cost in iteration 100: -0.24189257695381955
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24497555781140531
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24750666667651167
# Mean cost in iteration 100: -0.24250077702305564
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.2457855759174068
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24815162159195903
# Mean cost in iteration 100: -0.2476963674576
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24537202564701102
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24587126453153285
# Mean cost in iteration 100: -0.24311245683949115
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24510207740986995
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24644158502256325
# Mean cost in iteration 100: -0.24769188058184688
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24476568926868833
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24571855130302964
# Mean cost in iteration 100: -0.24746172907894443
# Minimal cost found at iteration 838
# Final cost validated with 1000 noise realizations : -0.24482560399905545
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24705720050624838
# Mean cost in iteration 100: -0.24301474760894096
# Minimal cost found at iteration 1602
# Final cost validated with 1000 noise realizations : -0.25352070477038224
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25029935305007633
# Mean cost in iteration 100: -0.253835230820961
# Minimal cost found at iteration 1762
# Final cost validated with 1000 noise realizations : -0.25252474554859067
# 0.06515159406924942 -0.2492428031905803
# cost det =  -0.18409120912133087
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2517644129543255
# Mean cost in iteration 100: -0.24830565332716592
# Minimal cost found at iteration 98
# Final cost validated with 1000 noise realizations : -0.24742947669169196
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24375076950212343
# Mean cost in iteration 100: -0.24741804621885513
# Minimal cost found at iteration 98
# Final cost validated with 1000 noise realizations : -0.24811074756579143
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2470545917915423
# Mean cost in iteration 100: -0.24648105115071295
# Minimal cost found at iteration 265
# Final cost validated with 1000 noise realizations : -0.24675110391544358
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24217962953043098
# Mean cost in iteration 100: -0.24686261576460491
# Minimal cost found at iteration 265
# Final cost validated with 1000 noise realizations : -0.24402823055744988
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24490284459929565
# Mean cost in iteration 100: -0.2523481753733491
# Minimal cost found at iteration 265
# Final cost validated with 1000 noise realizations : -0.24659624553601497
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24370670389689103
# Mean cost in iteration 100: -0.24763356357832586
# Minimal cost found at iteration 265
# Final cost validated with 1000 noise realizations : -0.2449533385372885
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24690498592349894
# Mean cost in iteration 100: -0.2503533662080658
# Minimal cost found at iteration 265
# Final cost validated with 1000 noise realizations : -0.2460480649344751
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2454003672957323
# Mean cost in iteration 100: -0.25445890788208425
# Minimal cost found at iteration 718
# Final cost validated with 1000 noise realizations : -0.250437344939836
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2504908209847805
# Mean cost in iteration 100: -0.24763790930991425
# Minimal cost found at iteration 718
# Final cost validated with 1000 noise realizations : -0.2502643868039057
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25181073884679905
# Mean cost in iteration 100: -0.24984731669147955
# Minimal cost found at iteration 964
# Final cost validated with 1000 noise realizations : -0.2514291178222979
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2487536244729077
# Mean cost in iteration 100: -0.25016401910027164
# Minimal cost found at iteration 964
# Final cost validated with 1000 noise realizations : -0.2510702986793583
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2514538146217077
# Mean cost in iteration 100: -0.24850370321945733
# Minimal cost found at iteration 964
# Final cost validated with 1000 noise realizations : -0.2511055942146995
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25475504750845657
# Mean cost in iteration 100: -0.2511796048405725
# Minimal cost found at iteration 964
# Final cost validated with 1000 noise realizations : -0.25034333864403097
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2524124228963353
# Mean cost in iteration 100: -0.2581961181635168
# Minimal cost found at iteration 1400
# Final cost validated with 1000 noise realizations : -0.2508657645615406
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25430029900778955
# Mean cost in iteration 100: -0.24786790744894888
# Minimal cost found at iteration 1400
# Final cost validated with 1000 noise realizations : -0.24980708807685478
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2466811121180651
# Mean cost in iteration 100: -0.2542692257642509
# Minimal cost found at iteration 1400
# Final cost validated with 1000 noise realizations : -0.2509133367534085
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2517872704664011
# Mean cost in iteration 100: -0.24768012010593768
# Minimal cost found at iteration 1400
# Final cost validated with 1000 noise realizations : -0.2511697832855767
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2470822457612524
# Mean cost in iteration 100: -0.24955469064932922
# Minimal cost found at iteration 1400
# Final cost validated with 1000 noise realizations : -0.2509815372763974

# %%
for wind in range(w1_n):

        plot_1n_osc_noisy(
                data_noisy["state"][wind], data_noisy["control"][wind], data_noisy["cost"][wind],
                data_noisy["state_det"][wind], data_noisy["control_det"], data_noisy["cost_det"][wind],
                data_noisy["state_det_opt"][wind], data_noisy["control_det_opt"][wind], data_noisy["cost_det_opt"][wind],
                data["D"]["state"][1], data_noisy["state_det_opt_det"][wind],
                duration, dt, sigma_array,  M, os.path.join(dir, "WC_w1D_noisy" + str(wind) + ".pdf"))

        tablestring = ""
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost"][wind][si],3)) + " & "
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost_det"][wind][si],3)) + " & "
        for si in range(len(sigma_array)):
                tablestring = tablestring + str(np.around(data_noisy["cost_det_opt"][wind][si],3)) + " & "
        tablestring = tablestring[:-3]
        tablestring = tablestring + " \\" + "\\"

        print(tablestring)
# Out:
# -0.269 & -0.257 & -0.253 & -0.22 & -0.211 & -0.184 & -0.282 & -0.272 & -0.251 \\
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb Zelle 11 in 3
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> for wind in range(w1_n):
# ----> <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>         plot_1n_osc_noisy(
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>                 data_noisy["state"][wind], data_noisy["control"][wind], data_noisy["cost"][wind],
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>                 data_noisy["state_det"][wind], data_noisy["control_det"], data_noisy["cost_det"][wind],
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>                 data_noisy["state_det_opt"][wind], data_noisy["control_det_opt"][wind], data_noisy["cost_det_opt"][wind],
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>                 data["D"]["state"][1], data_noisy["state_det_opt_det"][wind],
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>                 duration, dt, sigma_array,  M, os.path.join(dir, "WC_w1D_noisy" + str(wind) + ".pdf"))
#      <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>         tablestring = ""
#      <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/neurolib/experiments/WPtwo/onen/osc_1n_w1D.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>         for si in range(len(sigma_array)):
#
# File ~/Promotion/neurolib/neurolib/experiments/WPtwo/onen/plot.py:159, in plot_1n_osc_noisy(state, control, cost, state_det, control_det, cost_det, state_det_opt, control_det_opt, cost_det_opt, state_det_det, state_det_opt_det, dur, dt, sigma_array, M, filename)
#     156 index = float(s / (len(sigma_array) - 1))
#     157 col = cmap(index)
# --> 159 ax[0, 0].plot(time, state[s][0, 0, :], color=col, label=r"$F=$" + str(np.around(cost[s], roundint)))
#     160 ax[0, 1].plot(time, state_det[s][0, 0, :], color=col, label=r"$F=$" + str(np.around(cost_det[s], roundint)))
#     161 ax[0, 2].plot(
#     162     time, state_det_opt[s][0, 0, :], color=col, label=r"$F=$" + str(np.around(cost_det_opt[s], roundint))
#     163 )
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data_noisy["control"][1] = data_noisy["control"][0].copy()
data_noisy["control"][2] = data_noisy["control"][0].copy()
data_noisy["control"][3] = data_noisy["control"][0].copy()

# %%
it = 100

for wind in range(1, w1_n):

    for si in range(len(sigma_array)):
        print("SIGMA = ", sigma_array[si])
        w1 = data_noisy["w1"][wind]

        model.params.sigma_ou = sigma_array[si]

        model.params.duration = testd
        model.params["exc_ext"] = p[0]
        model.params["inh_ext"] = p[1]
        model.run()

        einit = np.zeros((N, 1))
        iinit = np.zeros((N, 1))
        for n in range(N):
            einit[n,:] = np.mean(model.exc[n,1000:])
            iinit[n,:] = np.mean(model.inh[n,1000:])

        model.params.duration = duration
        model.params["exc_ext"] = zero_control[:,0,:] + p[0]
        model.params["inh_ext"] = zero_control[:,1,:] + p[1]
        model.params["exc_init"] = einit
        model.params["inh_init"] = iinit
        model.run()

        if False:
            plt.plot(model.exc[0,:])
            plt.show()

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                        M=M,
                                        M_validation=M*10,
                                        validate_per_step=False,
        )
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1D"] = w1
        model_controlled.weights["w_f"] = 1.

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(data_noisy["control"][wind][si]) != type(None):
                model_controlled.control = data_noisy["control"][wind][si].copy()
                model_controlled.update_input()

        if True:
            for l in range(2):
                for k in range(-8,9,2):
                    model_controlled.step = 10.**k
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False

            data_noisy["control"][wind][si] = model_controlled.control.copy()
            data_noisy["cost"][wind][si] = model_controlled.cost_validation

            meanstate = model_controlled.get_xs()
            for m in range(M-1):
                model_controlled.model.run()
                meanstate += model_controlled.get_xs()
            data_noisy["state"][wind][si] = meanstate / M
        
        #################################################

        data_noisy["cost_det"][wind][si], data_noisy["state_det"][wind][si] = get_noisy_cost(data_noisy["control_det"], M, sigma_array[si], p, model_controlled.weights["w_f"], model_controlled.weights["w_1"])
        print("cost det = ", data_noisy["cost_det"][wind][si])

        #################################################

        if True:

            model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), cost_matrix=costmat, control_matrix=controlmat,
                                            M=M,
                                            M_validation=M*10,
                                            validate_per_step=False,
            )

            model_controlled.weights["w_p"] = 0.
            model_controlled.weights["w_1D"] = w1
            model_controlled.weights["w_f"] = 1.
            model_controlled.maximum_control_strength = maxstr

            model_controlled.control = data_noisy["control_det"].copy()

            if True:
                if type(data_noisy["control_det_opt"][wind][si]) != type(None):
                    model_controlled.control = data_noisy["control_det_opt"][wind][si].copy()
            
            model_controlled.update_input()
            
            for l in range(2):
                for k in range(-8,9,2):
                    model_controlled.step = 10.**k
                    model_controlled.optimize(it)
                    model_controlled.zero_step_encountered = False

            data_noisy["control_det_opt"][wind][si] = model_controlled.control.copy()
            data_noisy["cost_det_opt"][wind][si] = model_controlled.cost_validation

            model_controlled.update_input()

            meanstate = model_controlled.get_xs()
            for m in range(M-1):
                model_controlled.model.run()
                meanstate += model_controlled.get_xs()
            data_noisy["state_det_opt"][wind][si] = meanstate / M
            plt.show()

        if True:
            model.params.sigma_ou = 0.
            model.params.duration = testd
            model.params["exc_ext"] = p[0]
            model.params["inh_ext"] = p[1]
            model.run()

            einit = np.zeros((N, 1))
            iinit = np.zeros((N, 1))
            for n in range(N):
                einit[n,:] = model.exc[n,-1]
                iinit[n,:] = model.inh[n,-1]

            model.params.duration = duration
    
            model.params["exc_ext"] = data_noisy["control_det_opt"][wind][si][:,0,:] + p[0]
            model.params["inh_ext"] = data_noisy["control_det_opt"][wind][si][:,1,:] + p[1]
            model.params["exc_init"] = einit
            model.params["inh_init"] = iinit

            model.run()
            data_noisy["state_det_opt_det"][wind][si] = get_xs(model)

        with open(os.path.join(pickledir, 'osc_1n_wc_w1D_noisy.pickle'), 'wb') as f:
            pickle.dump(data_noisy, f)
# Out:
# SIGMA =  0.01
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002465023882074136
# Mean cost in iteration 100: -0.0025934268876579365
# Minimal cost found at iteration 64
# Final cost validated with 1000 noise realizations : -0.0023566242527102124
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002469111682055967
# Mean cost in iteration 100: -0.0025652633525907412
# Minimal cost found at iteration 180
# Final cost validated with 1000 noise realizations : -0.002349462600391214
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0021620271774517408
# Mean cost in iteration 100: -0.002223450207358926
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.002330164461972412
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0024941801382464893
# Mean cost in iteration 100: -0.0024200657790204266
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0023120912892502883
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002535264383359403
# Mean cost in iteration 100: -0.0020599632335149215
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.002249069686842408
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002322493930303463
# Mean cost in iteration 100: -0.002536993020350102
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.0023543398351875706
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002549381575338014
# Mean cost in iteration 100: -0.0023618010693459896
# Minimal cost found at iteration 293
# Final cost validated with 1000 noise realizations : -0.002407274373190768
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002481425763539547
# Mean cost in iteration 100: -0.052402055413491286
# Minimal cost found at iteration 726
# Final cost validated with 1000 noise realizations : -0.05207189316667328
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05193747662686045
# Mean cost in iteration 100: -0.07424328167065307
# Minimal cost found at iteration 877
# Final cost validated with 1000 noise realizations : -0.07437854075670261
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07423939801671241
# Mean cost in iteration 100: -0.07423944459446001
# Minimal cost found at iteration 877
# Final cost validated with 1000 noise realizations : -0.07429926554288262
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07392824553262656
# Mean cost in iteration 100: -0.07433812968703174
# Minimal cost found at iteration 1096
# Final cost validated with 1000 noise realizations : -0.07427169035204718
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07418778865636359
# Mean cost in iteration 100: -0.0741868942327576
# Minimal cost found at iteration 1169
# Final cost validated with 1000 noise realizations : -0.0743533547615346
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07433405455988747
# Mean cost in iteration 100: -0.07461798636907646
# Minimal cost found at iteration 1295
# Final cost validated with 1000 noise realizations : -0.07427603262753096
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07420465595443504
# Mean cost in iteration 100: -0.07442309748611065
# Minimal cost found at iteration 1295
# Final cost validated with 1000 noise realizations : -0.07423245892918338
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07427052778066882
# Mean cost in iteration 100: -0.07443232973488245
# Minimal cost found at iteration 1295
# Final cost validated with 1000 noise realizations : -0.07431590578248347
# Compute control for a noisy system
# Mean cost in iteration 0: -0.07433384138269832
# Mean cost in iteration 100: -0.12815414147746643
# Minimal cost found at iteration 1571
# Final cost validated with 1000 noise realizations : -0.12790988635487865
# Compute control for a noisy system
# Mean cost in iteration 0: -0.12789803359460028
# Mean cost in iteration 100: -0.2267013298190114
# Minimal cost found at iteration 1625
# Final cost validated with 1000 noise realizations : -0.22677766957944737
# Compute control for a noisy system
# Mean cost in iteration 0: -0.226812928066253
# Mean cost in iteration 100: -0.25461912486282307
# Minimal cost found at iteration 1753
# Final cost validated with 1000 noise realizations : -0.254518689571124
# 0.0 -0.28563639034646765
# cost det =  -0.28563639034646765
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2836707183792784
# Mean cost in iteration 100: -0.2834867163334983
# Minimal cost found at iteration 74
# Final cost validated with 1000 noise realizations : -0.2834715524601417
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28340389110277503
# Mean cost in iteration 100: -0.28354367318774715
# Minimal cost found at iteration 103
# Final cost validated with 1000 noise realizations : -0.2834800340611868
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2833114071800573
# Mean cost in iteration 100: -0.28358409003454904
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.28342838081517047
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28353992095711733
# Mean cost in iteration 100: -0.2835212379339886
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.2834933440151057
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2832771355294076
# Mean cost in iteration 100: -0.28348636679155037
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.2833408708285507
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28330466770451784
# Mean cost in iteration 100: -0.28317926015853767
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.28350072309579455
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2836499532647011
# Mean cost in iteration 100: -0.28361831641736834
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.28349548030298255
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28359616495664336
# Mean cost in iteration 100: -0.28351810326699756
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.28342338899971975
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28311684211161603
# Mean cost in iteration 100: -0.28314958615506713
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.2834289295939286
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2832945732542489
# Mean cost in iteration 100: -0.2829212066072552
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.28357955346435215
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28362212313411617
# Mean cost in iteration 100: -0.2835988535234695
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.2835399722762293
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2837129447256179
# Mean cost in iteration 100: -0.2831686570297382
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.283485171415191
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28404980250976564
# Mean cost in iteration 100: -0.2834238775358958
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.2833422356324032
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28333977717831244
# Mean cost in iteration 100: -0.28371812633731475
# Minimal cost found at iteration 275
# Final cost validated with 1000 noise realizations : -0.283398635494293
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2834720929761865
# Mean cost in iteration 100: -0.2831274699346975
# Minimal cost found at iteration 1481
# Final cost validated with 1000 noise realizations : -0.28334826934253904
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2836662233156842
# Mean cost in iteration 100: -0.2834922349156811
# Minimal cost found at iteration 1481
# Final cost validated with 1000 noise realizations : -0.2832721831436842
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2832753284296373
# Mean cost in iteration 100: -0.2834646762646446
# Minimal cost found at iteration 1481
# Final cost validated with 1000 noise realizations : -0.2833907260427942
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2832377864219652
# Mean cost in iteration 100: -0.2837117772057451
# Minimal cost found at iteration 1481
# Final cost validated with 1000 noise realizations : -0.2833885864123913
# SIGMA =  0.05
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02647297743842282
# Mean cost in iteration 100: -0.026198760521941023
# Minimal cost found at iteration 86
# Final cost validated with 1000 noise realizations : -0.02477014739411486
# Compute control for a noisy system
# Mean cost in iteration 0: -0.023893028434653157
# Mean cost in iteration 100: -0.026583730184088213
# Minimal cost found at iteration 103
# Final cost validated with 1000 noise realizations : -0.02562452059357351
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02606853451085989
# Mean cost in iteration 100: -0.029835444017083223
# Minimal cost found at iteration 103
# Final cost validated with 1000 noise realizations : -0.024360002827524267
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0251376763162051
# Mean cost in iteration 100: -0.026433133433262097
# Minimal cost found at iteration 309
# Final cost validated with 1000 noise realizations : -0.024703556317832148
# Compute control for a noisy system
# Mean cost in iteration 0: -0.020593477015108747
# Mean cost in iteration 100: -0.028094207129652958
# Minimal cost found at iteration 309
# Final cost validated with 1000 noise realizations : -0.024718422864469246
# Compute control for a noisy system
# Mean cost in iteration 0: -0.025219861148157125
# Mean cost in iteration 100: -0.024455850351042408
# Minimal cost found at iteration 309
# Final cost validated with 1000 noise realizations : -0.024974296373705403
# Compute control for a noisy system
# Mean cost in iteration 0: -0.026681245768456745
# Mean cost in iteration 100: -0.11219300327771364
# Minimal cost found at iteration 648
# Final cost validated with 1000 noise realizations : -0.11205730533961027
# Compute control for a noisy system
# Mean cost in iteration 0: -0.11327241010915685
# Mean cost in iteration 100: -0.12196775388499612
# Minimal cost found at iteration 733
# Final cost validated with 1000 noise realizations : -0.12114680709743861
# Compute control for a noisy system
# Mean cost in iteration 0: -0.12342607449941399
# Mean cost in iteration 100: -0.1714500553981413
# Minimal cost found at iteration 891
# Final cost validated with 1000 noise realizations : -0.17220328236717347
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1724195245442327
# Mean cost in iteration 100: -0.17052379155395495
# Minimal cost found at iteration 891
# Final cost validated with 1000 noise realizations : -0.17186677384100524
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17078212673025062
# Mean cost in iteration 100: -0.17279542323435834
# Minimal cost found at iteration 1031
# Final cost validated with 1000 noise realizations : -0.17135601071958922
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17129334378524905
# Mean cost in iteration 100: -0.17216211009663354
# Minimal cost found at iteration 1031
# Final cost validated with 1000 noise realizations : -0.171904462609695
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17174685019473707
# Mean cost in iteration 100: -0.17276332717959494
# Minimal cost found at iteration 1208
# Final cost validated with 1000 noise realizations : -0.17188455067329172
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1706435951239996
# Mean cost in iteration 100: -0.1724176766676381
# Minimal cost found at iteration 1208
# Final cost validated with 1000 noise realizations : -0.17207917511707488
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1724832081043061
# Mean cost in iteration 100: -0.17128873020805238
# Minimal cost found at iteration 1425
# Final cost validated with 1000 noise realizations : -0.17362632554284332
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17418799474738034
# Mean cost in iteration 100: -0.19689927001476554
# Minimal cost found at iteration 1543
# Final cost validated with 1000 noise realizations : -0.19591825057015097
# Compute control for a noisy system
# Mean cost in iteration 0: -0.19671111836685617
# Mean cost in iteration 100: -0.221157310987201
# Minimal cost found at iteration 1627
# Final cost validated with 1000 noise realizations : -0.22092064730221211
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2186377249980465
# Mean cost in iteration 100: -0.26263413769701194
# Minimal cost found at iteration 1749
# Final cost validated with 1000 noise realizations : -0.2630927034612584
# 0.0 -0.27605764118714465
# cost det =  -0.27605764118714465
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2726723033310672
# Mean cost in iteration 100: -0.2730363371605476
# Minimal cost found at iteration 55
# Final cost validated with 1000 noise realizations : -0.2739838133511049
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27362091659763693
# Mean cost in iteration 100: -0.2751503703721551
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2746857901783244
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2725563588706467
# Mean cost in iteration 100: -0.27466386310208085
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27399810997632323
# Compute control for a noisy system
# Mean cost in iteration 0: -0.273229665575554
# Mean cost in iteration 100: -0.2734489063839815
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27412962571606636
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2746019528057352
# Mean cost in iteration 100: -0.27595917281399557
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2738567872107292
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27431721951629756
# Mean cost in iteration 100: -0.276427292179013
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2735505392046637
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2738759966254927
# Mean cost in iteration 100: -0.27354365565973393
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27395709079937847
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2757792519140475
# Mean cost in iteration 100: -0.2759842333882759
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2746933714138981
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2728988394967329
# Mean cost in iteration 100: -0.2742764497652287
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2737382327653918
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2756664526376403
# Mean cost in iteration 100: -0.27545327840354294
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27420599409632324
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27370337740749096
# Mean cost in iteration 100: -0.27156521281541623
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27333251178563417
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27507822882462213
# Mean cost in iteration 100: -0.2749151102198265
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27393350981864045
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2742586543959069
# Mean cost in iteration 100: -0.2738798118534487
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2742756039121397
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2726576535056117
# Mean cost in iteration 100: -0.27367577991146674
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2739685798485644
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2726892356976081
# Mean cost in iteration 100: -0.27551894116392983
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27391333043139227
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27389282487714117
# Mean cost in iteration 100: -0.27310048772510526
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.2744350685548511
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2750878006586727
# Mean cost in iteration 100: -0.27484362732171647
# Minimal cost found at iteration 173
# Final cost validated with 1000 noise realizations : -0.27397678271075876
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27272068698516505
# Mean cost in iteration 100: -0.2727390646840524
# Minimal cost found at iteration 1739
# Final cost validated with 1000 noise realizations : -0.27352966053325745
# SIGMA =  0.1
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.056663929645299926
# Mean cost in iteration 100: -0.056090130397399775
# Minimal cost found at iteration 45
# Final cost validated with 1000 noise realizations : -0.05960842236973288
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05826391743340353
# Mean cost in iteration 100: -0.05681904531846541
# Minimal cost found at iteration 134
# Final cost validated with 1000 noise realizations : -0.05912861686260174
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05798670380388663
# Mean cost in iteration 100: -0.05365751860095012
# Minimal cost found at iteration 134
# Final cost validated with 1000 noise realizations : -0.059081629477993954
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05612944833894542
# Mean cost in iteration 100: -0.053983673900293516
# Minimal cost found at iteration 134
# Final cost validated with 1000 noise realizations : -0.060350534843084946
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05710316582139682
# Mean cost in iteration 100: -0.06102643441383246
# Minimal cost found at iteration 134
# Final cost validated with 1000 noise realizations : -0.059184623061369485
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05956667286853559
# Mean cost in iteration 100: -0.059288000600318996
# Minimal cost found at iteration 599
# Final cost validated with 1000 noise realizations : -0.060046380771413985
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06363565635203292
# Mean cost in iteration 100: -0.10514336212198824
# Minimal cost found at iteration 641
# Final cost validated with 1000 noise realizations : -0.09896138995813185
# Compute control for a noisy system
# Mean cost in iteration 0: -0.10162166446548206
# Mean cost in iteration 100: -0.15943974257959492
# Minimal cost found at iteration 761
# Final cost validated with 1000 noise realizations : -0.16150130446150107
# Compute control for a noisy system
# Mean cost in iteration 0: -0.15970647665171647
# Mean cost in iteration 100: -0.19360613802959403
# Minimal cost found at iteration 856
# Final cost validated with 1000 noise realizations : -0.19531553440494714
# Compute control for a noisy system
# Mean cost in iteration 0: -0.19439328176628082
# Mean cost in iteration 100: -0.19411857520254513
# Minimal cost found at iteration 969
# Final cost validated with 1000 noise realizations : -0.1932734206487071
# Compute control for a noisy system
# Mean cost in iteration 0: -0.19065729360837527
# Mean cost in iteration 100: -0.1937251672050984
# Minimal cost found at iteration 1044
# Final cost validated with 1000 noise realizations : -0.19275224604745378
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1908385167185235
# Mean cost in iteration 100: -0.1916369301989957
# Minimal cost found at iteration 1189
# Final cost validated with 1000 noise realizations : -0.19383234459045864
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1981600379774925
# Mean cost in iteration 100: -0.1933870866632444
# Minimal cost found at iteration 1253
# Final cost validated with 1000 noise realizations : -0.19165247198115842
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1931461497697332
# Mean cost in iteration 100: -0.19763007638932323
# Minimal cost found at iteration 1332
# Final cost validated with 1000 noise realizations : -0.19923718767292614
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1984437160949253
# Mean cost in iteration 100: -0.19562452241224929
# Minimal cost found at iteration 1495
# Final cost validated with 1000 noise realizations : -0.19838121536212416
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1918283253994936
# Mean cost in iteration 100: -0.24189975718090165
# Minimal cost found at iteration 1532
# Final cost validated with 1000 noise realizations : -0.2424839516475023
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2413968016289206
# Mean cost in iteration 100: -0.24394527780436426
# Minimal cost found at iteration 1678
# Final cost validated with 1000 noise realizations : -0.24792718080342147
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25237197467877703
# Mean cost in iteration 100: -0.2445825875324276
# Minimal cost found at iteration 1678
# Final cost validated with 1000 noise realizations : -0.2466900194960779
# 0.0 -0.24998412297984152
# cost det =  -0.24998412297984152
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24754688819269247
# Mean cost in iteration 100: -0.24646505216672626
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.24764745486886044
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24673136946819202
# Mean cost in iteration 100: -0.24953343044343906
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.24861895348405313
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24797904056706174
# Mean cost in iteration 100: -0.24760685875432753
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.24785256178010362
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2468331035351443
# Mean cost in iteration 100: -0.24761488146196664
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.2466276710826846
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24844900109104415
# Mean cost in iteration 100: -0.24554300192799364
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.24710160986239368
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24544018590204725
# Mean cost in iteration 100: -0.24760910999865293
# Minimal cost found at iteration 83
# Final cost validated with 1000 noise realizations : -0.24863973382795118
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2462918483920897
# Mean cost in iteration 100: -0.2547564609244262
# Minimal cost found at iteration 602
# Final cost validated with 1000 noise realizations : -0.2560572177751098
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2566901150682512
# Mean cost in iteration 100: -0.25695936550336484
# Minimal cost found at iteration 799
# Final cost validated with 1000 noise realizations : -0.25664863274388816
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2554868563128902
# Mean cost in iteration 100: -0.25381813587021435
# Minimal cost found at iteration 799
# Final cost validated with 1000 noise realizations : -0.2553572386134258
# Compute control for a noisy system
# Mean cost in iteration 0: -0.253471363305779
# Mean cost in iteration 100: -0.2568256839537942
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2564884175141278
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25782944632401406
# Mean cost in iteration 100: -0.25629559010849
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.25613505642654405
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2574404883103236
# Mean cost in iteration 100: -0.2537212677493031
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2551593632858337
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2547736687170178
# Mean cost in iteration 100: -0.25707278087691565
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2556754827239318
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25352503596867704
# Mean cost in iteration 100: -0.26194797147895343
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2554824264408273
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25606598292690036
# Mean cost in iteration 100: -0.2580533993960336
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2566356984394114
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2595299837917736
# Mean cost in iteration 100: -0.2577538551674752
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.25524072526189107
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25582724311488464
# Mean cost in iteration 100: -0.25454600710405345
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.25538618152410764
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2581451055308033
# Mean cost in iteration 100: -0.25082447405737285
# Minimal cost found at iteration 939
# Final cost validated with 1000 noise realizations : -0.2551902413994148
# SIGMA =  0.01
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0023722424234755325
# Mean cost in iteration 100: -0.0024802109381694927
# Minimal cost found at iteration 17
# Final cost validated with 1000 noise realizations : -0.002346799224928283
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002416333254507947
# Mean cost in iteration 100: -0.0022637377341406455
# Minimal cost found at iteration 130
# Final cost validated with 1000 noise realizations : -0.002311724073732199
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0022755319144771406
# Mean cost in iteration 100: -0.0024159783719685827
# Minimal cost found at iteration 130
# Final cost validated with 1000 noise realizations : -0.0023449359837048535
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0022314924825627917
# Mean cost in iteration 100: -0.0022713371105935825
# Minimal cost found at iteration 325
# Final cost validated with 1000 noise realizations : -0.002324772115642272
# Compute control for a noisy system
# Mean cost in iteration 0: -0.00240486219164736
# Mean cost in iteration 100: -0.0022888266215436827
# Minimal cost found at iteration 325
# Final cost validated with 1000 noise realizations : -0.0023226738405746654
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0022501584757426353
# Mean cost in iteration 100: -0.002287160407989834
# Minimal cost found at iteration 519
# Final cost validated with 1000 noise realizations : -0.0023723617595693925
# Compute control for a noisy system
# Mean cost in iteration 0: -0.002408208486906173
# Mean cost in iteration 100: -0.2632114154183381
# Minimal cost found at iteration 605
# Final cost validated with 1000 noise realizations : -0.263588920900908
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2635752478269022
# Mean cost in iteration 100: -0.2751008612697695
# Minimal cost found at iteration 757
# Final cost validated with 1000 noise realizations : -0.27522587674462323
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2750444148658308
# Mean cost in iteration 100: -0.2765040872535587
# Minimal cost found at iteration 848
# Final cost validated with 1000 noise realizations : -0.27646072313275755
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27607992479445537
# Mean cost in iteration 100: -0.2764089296692233
# Minimal cost found at iteration 994
# Final cost validated with 1000 noise realizations : -0.2763695699279127
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27609114887853425
# Mean cost in iteration 100: -0.27664159069330546
# Minimal cost found at iteration 1049
# Final cost validated with 1000 noise realizations : -0.27637417552075627
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27668370682440846
# Mean cost in iteration 100: -0.2758351847190053
# Minimal cost found at iteration 1049
# Final cost validated with 1000 noise realizations : -0.27655281269256843
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27677312860392683
# Mean cost in iteration 100: -0.2764713746749192
# Minimal cost found at iteration 1049
# Final cost validated with 1000 noise realizations : -0.276354337939344
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2762897512098288
# Mean cost in iteration 100: -0.2760951712232568
# Minimal cost found at iteration 1367
# Final cost validated with 1000 noise realizations : -0.2764525586814708
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27669844374991387
# Mean cost in iteration 100: -0.2765040703856668
# Minimal cost found at iteration 1367
# Final cost validated with 1000 noise realizations : -0.27649301591002884
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27629835205766057
# Mean cost in iteration 100: -0.2767548217245405
# Minimal cost found at iteration 1554
# Final cost validated with 1000 noise realizations : -0.27638767327718855
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2759762199599161
# Mean cost in iteration 100: -0.27660931706937036
# Minimal cost found at iteration 1626
# Final cost validated with 1000 noise realizations : -0.27649987657780556
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27669068487468523
# Mean cost in iteration 100: -0.2759459687856911
# Minimal cost found at iteration 1626
# Final cost validated with 1000 noise realizations : -0.2766027046087429
# 0.0 -0.2855151051879048
# cost det =  -0.2855151051879048
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.282731438928844
# Mean cost in iteration 100: -0.28281566983058526
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28285306266849314
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2828978757485716
# Mean cost in iteration 100: -0.2829811837212338
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2826626940950455
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2828198023816259
# Mean cost in iteration 100: -0.28272827924273986
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.282809780164364
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2827463290450433
# Mean cost in iteration 100: -0.2826683892463739
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2827008118950957
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28269754152112836
# Mean cost in iteration 100: -0.28295997133057527
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2827029608389797
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2828201835727435
# Mean cost in iteration 100: -0.2830668112135275
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2825982966658814
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2827144574471436
# Mean cost in iteration 100: -0.28313731361863526
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28274995866019864
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28286343858328966
# Mean cost in iteration 100: -0.2829643220430425
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28288891980660663
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28279845155654304
# Mean cost in iteration 100: -0.2822722057483321
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2827026292326941
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2825240215815443
# Mean cost in iteration 100: -0.2828919034455803
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2826261946307717
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2828591214023594
# Mean cost in iteration 100: -0.28292581767011893
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28273055804221353
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2821669129361107
# Mean cost in iteration 100: -0.28244961983893757
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28266108103554877
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2824921014572704
# Mean cost in iteration 100: -0.2828169025608778
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28270004199834475
# Compute control for a noisy system
# Mean cost in iteration 0: -0.283084747715322
# Mean cost in iteration 100: -0.2823217708490539
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2827053454356455
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2826696453460189
# Mean cost in iteration 100: -0.28274229476518614
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.2827187231363464
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2829459327780385
# Mean cost in iteration 100: -0.2826420228945816
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28281067776430774
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28223878144996034
# Mean cost in iteration 100: -0.2832814311402816
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.282810917590223
# Compute control for a noisy system
# Mean cost in iteration 0: -0.28256232382211005
# Mean cost in iteration 100: -0.28333973492946074
# Minimal cost found at iteration 38
# Final cost validated with 1000 noise realizations : -0.28265246571736985
# SIGMA =  0.05
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02677486254124964
# Mean cost in iteration 100: -0.022743315062952706
# Minimal cost found at iteration 84
# Final cost validated with 1000 noise realizations : -0.026245447947502526
# Compute control for a noisy system
# Mean cost in iteration 0: -0.02552020479428575
# Mean cost in iteration 100: -0.02539254882212202
# Minimal cost found at iteration 84
# Final cost validated with 1000 noise realizations : -0.02617843375724119
# Compute control for a noisy system
# Mean cost in iteration 0: -0.022347781632476707
# Mean cost in iteration 100: -0.027034025613154752
# Minimal cost found at iteration 84
# Final cost validated with 1000 noise realizations : -0.024810623874730625
# Compute control for a noisy system
# Mean cost in iteration 0: -0.025552203691484282
# Mean cost in iteration 100: -0.023831659666427266
# Minimal cost found at iteration 84
# Final cost validated with 1000 noise realizations : -0.02528782679633422
# Compute control for a noisy system
# Mean cost in iteration 0: -0.026266710554056855
# Mean cost in iteration 100: -0.02303565114861748
# Minimal cost found at iteration 462
# Final cost validated with 1000 noise realizations : -0.025283248325644873
# Compute control for a noisy system
# Mean cost in iteration 0: -0.026933500241115717
# Mean cost in iteration 100: -0.026052906299814917
# Minimal cost found at iteration 462
# Final cost validated with 1000 noise realizations : -0.024927867820309202
# Compute control for a noisy system
# Mean cost in iteration 0: -0.023970694833772264
# Mean cost in iteration 100: -0.08123056401955848
# Minimal cost found at iteration 615
# Final cost validated with 1000 noise realizations : -0.07958732652804723
# Compute control for a noisy system
# Mean cost in iteration 0: -0.08306925137890361
# Mean cost in iteration 100: -0.1801364490423796
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.18075352268512673
# Compute control for a noisy system
# Mean cost in iteration 0: -0.18030820755178695
# Mean cost in iteration 100: -0.19046770843664182
# Minimal cost found at iteration 867
# Final cost validated with 1000 noise realizations : -0.18904279361823048
# Compute control for a noisy system
# Mean cost in iteration 0: -0.189896465001267
# Mean cost in iteration 100: -0.19012354108996127
# Minimal cost found at iteration 981
# Final cost validated with 1000 noise realizations : -0.18971744772778507
# Compute control for a noisy system
# Mean cost in iteration 0: -0.18992325023430226
# Mean cost in iteration 100: -0.1913005176578789
# Minimal cost found at iteration 981
# Final cost validated with 1000 noise realizations : -0.18925618960004442
# Compute control for a noisy system
# Mean cost in iteration 0: -0.18796677009678475
# Mean cost in iteration 100: -0.1891210953291768
# Minimal cost found at iteration 981
# Final cost validated with 1000 noise realizations : -0.18959833652652403
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1884755606732975
# Mean cost in iteration 100: -0.1913335066334671
# Minimal cost found at iteration 981
# Final cost validated with 1000 noise realizations : -0.1888135494015811
# Compute control for a noisy system
# Mean cost in iteration 0: -0.19028993418499252
# Mean cost in iteration 100: -0.19031663030299747
# Minimal cost found at iteration 981
# Final cost validated with 1000 noise realizations : -0.18962041594559179
# Compute control for a noisy system
# Mean cost in iteration 0: -0.19162663050367493
# Mean cost in iteration 100: -0.21753457708559926
# Minimal cost found at iteration 1415
# Final cost validated with 1000 noise realizations : -0.22097200781877682
# Compute control for a noisy system
# Mean cost in iteration 0: -0.22384499761657436
# Mean cost in iteration 100: -0.26675497225890854
# Minimal cost found at iteration 1557
# Final cost validated with 1000 noise realizations : -0.2649234662831504
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2645085060760259
# Mean cost in iteration 100: -0.2674571185339535
# Minimal cost found at iteration 1694
# Final cost validated with 1000 noise realizations : -0.26728150918847926
# Compute control for a noisy system
# Mean cost in iteration 0: -0.26723822402802466
# Mean cost in iteration 100: -0.26674890131064755
# Minimal cost found at iteration 1733
# Final cost validated with 1000 noise realizations : -0.2684837047221642
# 0.0 -0.2759751498619942
# cost det =  -0.2759751498619942
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.272785341359689
# Mean cost in iteration 100: -0.2729496570793972
# Minimal cost found at iteration 56
# Final cost validated with 1000 noise realizations : -0.27390242116872016
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2721414844122665
# Mean cost in iteration 100: -0.27342708102031904
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.2730336256664824
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2728635497125734
# Mean cost in iteration 100: -0.2732310046942427
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.27244980504794675
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27241041115395476
# Mean cost in iteration 100: -0.27300346744764
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.2733020430044402
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27401487329176505
# Mean cost in iteration 100: -0.2757188894753161
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.2727646197206048
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2723315785476789
# Mean cost in iteration 100: -0.274874725484214
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.2723971544568813
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2725184588852106
# Mean cost in iteration 100: -0.2731756936523682
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.27328974527866
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2738179499912382
# Mean cost in iteration 100: -0.2731915084495883
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.27305835618591157
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2739396479469075
# Mean cost in iteration 100: -0.2719620832326378
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.27309890985575846
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2738091934097161
# Mean cost in iteration 100: -0.27316259820670025
# Minimal cost found at iteration 125
# Final cost validated with 1000 noise realizations : -0.27351279004598006
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2733287356179237
# Mean cost in iteration 100: -0.27386005178035994
# Minimal cost found at iteration 1092
# Final cost validated with 1000 noise realizations : -0.2732888006679238
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2738425708643292
# Mean cost in iteration 100: -0.2736571184417976
# Minimal cost found at iteration 1092
# Final cost validated with 1000 noise realizations : -0.2735488704962152
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27324510441629885
# Mean cost in iteration 100: -0.27249416361122053
# Minimal cost found at iteration 1092
# Final cost validated with 1000 noise realizations : -0.273333266555153
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27246354904595405
# Mean cost in iteration 100: -0.27257919518102275
# Minimal cost found at iteration 1092
# Final cost validated with 1000 noise realizations : -0.27331258065028285
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2729138783071125
# Mean cost in iteration 100: -0.2733625567425189
# Minimal cost found at iteration 1472
# Final cost validated with 1000 noise realizations : -0.27296257025758036
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27348068723650554
# Mean cost in iteration 100: -0.27378164872389055
# Minimal cost found at iteration 1472
# Final cost validated with 1000 noise realizations : -0.2737004037331341
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2734802876903675
# Mean cost in iteration 100: -0.27349512195132103
# Minimal cost found at iteration 1472
# Final cost validated with 1000 noise realizations : -0.2727123538313953
# Compute control for a noisy system
# Mean cost in iteration 0: -0.272142326701612
# Mean cost in iteration 100: -0.2731639686181114
# Minimal cost found at iteration 1472
# Final cost validated with 1000 noise realizations : -0.2736678944862811
# SIGMA =  0.1
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05732755651095995
# Mean cost in iteration 100: -0.059214920446019434
# Minimal cost found at iteration 92
# Final cost validated with 1000 noise realizations : -0.059407971563693575
# Compute control for a noisy system
# Mean cost in iteration 0: -0.060267840146416604
# Mean cost in iteration 100: -0.05459888232877149
# Minimal cost found at iteration 159
# Final cost validated with 1000 noise realizations : -0.061230924481068025
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06134051071821353
# Mean cost in iteration 100: -0.060754248183104126
# Minimal cost found at iteration 159
# Final cost validated with 1000 noise realizations : -0.05975348636228267
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05857352637121285
# Mean cost in iteration 100: -0.060334671391879785
# Minimal cost found at iteration 159
# Final cost validated with 1000 noise realizations : -0.05998360001074415
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05401519802682216
# Mean cost in iteration 100: -0.056679393835914825
# Minimal cost found at iteration 159
# Final cost validated with 1000 noise realizations : -0.05955589857569125
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06172289040726277
# Mean cost in iteration 100: -0.06567257173779878
# Minimal cost found at iteration 159
# Final cost validated with 1000 noise realizations : -0.057951834014420875
# Compute control for a noisy system
# Mean cost in iteration 0: -0.058533575398814514
# Mean cost in iteration 100: -0.056692809812599575
# Minimal cost found at iteration 657
# Final cost validated with 1000 noise realizations : -0.05888051609173716
# Compute control for a noisy system
# Mean cost in iteration 0: -0.058544661563010206
# Mean cost in iteration 100: -0.11485023033375025
# Minimal cost found at iteration 773
# Final cost validated with 1000 noise realizations : -0.11116158917163468
# Compute control for a noisy system
# Mean cost in iteration 0: -0.11285383083244825
# Mean cost in iteration 100: -0.15826059108502066
# Minimal cost found at iteration 834
# Final cost validated with 1000 noise realizations : -0.16079875289311807
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1552077685585965
# Mean cost in iteration 100: -0.15958469353974059
# Minimal cost found at iteration 929
# Final cost validated with 1000 noise realizations : -0.16033796709739945
# Compute control for a noisy system
# Mean cost in iteration 0: -0.15976922151944126
# Mean cost in iteration 100: -0.16198421889533654
# Minimal cost found at iteration 1008
# Final cost validated with 1000 noise realizations : -0.1589971714473711
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1601277434577255
# Mean cost in iteration 100: -0.16109084075294614
# Minimal cost found at iteration 1008
# Final cost validated with 1000 noise realizations : -0.15922336402750056
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1541136390885762
# Mean cost in iteration 100: -0.1639459881177634
# Minimal cost found at iteration 1008
# Final cost validated with 1000 noise realizations : -0.15854936303387215
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16104405951588063
# Mean cost in iteration 100: -0.15531883031229282
# Minimal cost found at iteration 1008
# Final cost validated with 1000 noise realizations : -0.16108803504489738
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16493003894643402
# Mean cost in iteration 100: -0.1609983019328998
# Minimal cost found at iteration 1008
# Final cost validated with 1000 noise realizations : -0.16149704782096014
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16422367892425796
# Mean cost in iteration 100: -0.23074186351678738
# Minimal cost found at iteration 1534
# Final cost validated with 1000 noise realizations : -0.23195920763269975
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2315242633521041
# Mean cost in iteration 100: -0.23827348965159076
# Minimal cost found at iteration 1640
# ...
# Mean cost in iteration 0: -0.025621210888854398
# Mean cost in iteration 100: -0.08197328108759494
# Minimal cost found at iteration 699
# Final cost validated with 1000 noise realizations : -0.08483251819852893
# Compute control for a noisy system
# Mean cost in iteration 0: -0.08345903146989414
# Mean cost in iteration 100: -0.15351095571701875
# Minimal cost found at iteration 788
# Final cost validated with 1000 noise realizations : -0.15564008989911265
# Compute control for a noisy system
# Mean cost in iteration 0: -0.15470531201201912
# Mean cost in iteration 100: -0.25006530460513116
# Minimal cost found at iteration 878
# Final cost validated with 1000 noise realizations : -0.2509528518870043
# Compute control for a noisy system
# Mean cost in iteration 0: -0.249367866652434
# Mean cost in iteration 100: -0.25009858119372386
# Minimal cost found at iteration 919
# Final cost validated with 1000 noise realizations : -0.25103311752806007
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25018987429566
# Mean cost in iteration 100: -0.2504891500709472
# Minimal cost found at iteration 919
# Final cost validated with 1000 noise realizations : -0.25076048013797847
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2517963720816301
# Mean cost in iteration 100: -0.2510130515821654
# Minimal cost found at iteration 919
# Final cost validated with 1000 noise realizations : -0.2506082230077042
# Compute control for a noisy system
# Mean cost in iteration 0: -0.251564661625053
# Mean cost in iteration 100: -0.2518883057522545
# Minimal cost found at iteration 919
# Final cost validated with 1000 noise realizations : -0.25042647893539177
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2500380612985495
# Mean cost in iteration 100: -0.24949581705229304
# Minimal cost found at iteration 919
# Final cost validated with 1000 noise realizations : -0.2509943612033273
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2521928625011498
# Mean cost in iteration 100: -0.2524765166155867
# Minimal cost found at iteration 1416
# Final cost validated with 1000 noise realizations : -0.2532834313460778
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2534688232752825
# Mean cost in iteration 100: -0.2678167063471357
# Minimal cost found at iteration 1503
# Final cost validated with 1000 noise realizations : -0.2678938434780209
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2692164576900813
# Mean cost in iteration 100: -0.26949957509513656
# Minimal cost found at iteration 1691
# Final cost validated with 1000 noise realizations : -0.2689648449717395
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2679994603013405
# Mean cost in iteration 100: -0.2686468953760214
# Minimal cost found at iteration 1750
# Final cost validated with 1000 noise realizations : -0.2696689559117449
# 0.0 -0.27584647589083344
# cost det =  -0.27584647589083344
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27116332115107555
# Mean cost in iteration 100: -0.27444359526547357
# Minimal cost found at iteration 34
# Final cost validated with 1000 noise realizations : -0.272470586692392
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27295104712680557
# Mean cost in iteration 100: -0.27189677914076765
# Minimal cost found at iteration 104
# Final cost validated with 1000 noise realizations : -0.2724650785757707
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2730711692401413
# Mean cost in iteration 100: -0.2722154678564101
# Minimal cost found at iteration 104
# Final cost validated with 1000 noise realizations : -0.27248157718421434
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27275765582261663
# Mean cost in iteration 100: -0.27201793898757454
# Minimal cost found at iteration 318
# Final cost validated with 1000 noise realizations : -0.27249392230959535
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27110524977791906
# Mean cost in iteration 100: -0.2724162182109981
# Minimal cost found at iteration 318
# Final cost validated with 1000 noise realizations : -0.27238067538020777
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2714555101993948
# Mean cost in iteration 100: -0.2724546702924428
# Minimal cost found at iteration 318
# Final cost validated with 1000 noise realizations : -0.27257642150032
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27194653648368644
# Mean cost in iteration 100: -0.2721918795674497
# Minimal cost found at iteration 318
# Final cost validated with 1000 noise realizations : -0.2722000627118709
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27245965622689083
# Mean cost in iteration 100: -0.2726762160297158
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2725442645067464
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27208175699310955
# Mean cost in iteration 100: -0.27399229607432823
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2725666749400073
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27162327985106893
# Mean cost in iteration 100: -0.2728283012516404
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.27276036281778726
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27278784744449974
# Mean cost in iteration 100: -0.2728604424818878
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2727072714993954
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27275216134345587
# Mean cost in iteration 100: -0.27196571635396477
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2725326550351725
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2730782577811116
# Mean cost in iteration 100: -0.27152567114644394
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.27185064366912026
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27363733470195833
# Mean cost in iteration 100: -0.2747075618084551
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.27249052137107505
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2723938342309698
# Mean cost in iteration 100: -0.272483165036009
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.27287378617501207
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27229189651258007
# Mean cost in iteration 100: -0.2701642643299679
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2722321841618381
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2738126985416385
# Mean cost in iteration 100: -0.27105703229585587
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.27218216755275776
# Compute control for a noisy system
# Mean cost in iteration 0: -0.27168666344938003
# Mean cost in iteration 100: -0.2702291696915476
# Minimal cost found at iteration 784
# Final cost validated with 1000 noise realizations : -0.2723617814180069
# SIGMA =  0.1
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.054740268549670186
# Mean cost in iteration 100: -0.05778861478697784
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.05938993881609878
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06315562445479943
# Mean cost in iteration 100: -0.06107948609253008
# Minimal cost found at iteration 179
# Final cost validated with 1000 noise realizations : -0.059373329493188624
# Compute control for a noisy system
# Mean cost in iteration 0: -0.0581698483946233
# Mean cost in iteration 100: -0.05754615288525214
# Minimal cost found at iteration 179
# Final cost validated with 1000 noise realizations : -0.05977619233668128
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06088894678725088
# Mean cost in iteration 100: -0.06348640145143902
# Minimal cost found at iteration 312
# Final cost validated with 1000 noise realizations : -0.05858458581892407
# Compute control for a noisy system
# Mean cost in iteration 0: -0.060147217949828045
# Mean cost in iteration 100: -0.06316822666721406
# Minimal cost found at iteration 312
# Final cost validated with 1000 noise realizations : -0.059527708619730696
# Compute control for a noisy system
# Mean cost in iteration 0: -0.06196197023543212
# Mean cost in iteration 100: -0.06525588322477113
# Minimal cost found at iteration 312
# Final cost validated with 1000 noise realizations : -0.05851622269083678
# Compute control for a noisy system
# Mean cost in iteration 0: -0.05749180129910008
# Mean cost in iteration 100: -0.08231704860867746
# Minimal cost found at iteration 689
# Final cost validated with 1000 noise realizations : -0.08438662715626613
# Compute control for a noisy system
# Mean cost in iteration 0: -0.08705066366950213
# Mean cost in iteration 100: -0.16847560609574871
# Minimal cost found at iteration 796
# Final cost validated with 1000 noise realizations : -0.167887433287309
# Compute control for a noisy system
# Mean cost in iteration 0: -0.16942586534851717
# Mean cost in iteration 100: -0.17359023785566258
# Minimal cost found at iteration 867
# Final cost validated with 1000 noise realizations : -0.17657189186485975
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17071895437704834
# Mean cost in iteration 100: -0.17321283333970622
# Minimal cost found at iteration 867
# Final cost validated with 1000 noise realizations : -0.1779687851839183
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17890226163334025
# Mean cost in iteration 100: -0.1767413966767888
# Minimal cost found at iteration 867
# Final cost validated with 1000 noise realizations : -0.175803768271787
# Compute control for a noisy system
# Mean cost in iteration 0: -0.1728022813560568
# Mean cost in iteration 100: -0.17451911753502475
# Minimal cost found at iteration 1185
# Final cost validated with 1000 noise realizations : -0.1766850490816282
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17568399770868304
# Mean cost in iteration 100: -0.177099579218831
# Minimal cost found at iteration 1185
# Final cost validated with 1000 noise realizations : -0.17637706106103668
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17305516477875482
# Mean cost in iteration 100: -0.16969451832725257
# Minimal cost found at iteration 1185
# Final cost validated with 1000 noise realizations : -0.176694805887569
# Compute control for a noisy system
# Mean cost in iteration 0: -0.17471161256424522
# Mean cost in iteration 100: -0.17472964567146115
# Minimal cost found at iteration 1185
# Final cost validated with 1000 noise realizations : -0.17608696508486738
# Compute control for a noisy system
# Mean cost in iteration 0: -0.18244260739817278
# Mean cost in iteration 100: -0.23284713456572056
# Minimal cost found at iteration 1541
# Final cost validated with 1000 noise realizations : -0.23313706267299275
# Compute control for a noisy system
# Mean cost in iteration 0: -0.22993849375758113
# Mean cost in iteration 100: -0.24726396887025712
# Minimal cost found at iteration 1669
# Final cost validated with 1000 noise realizations : -0.2462733113039657
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2453935609152977
# Mean cost in iteration 100: -0.25244359224380114
# Minimal cost found at iteration 1707
# Final cost validated with 1000 noise realizations : -0.24879563086366024
# 0.0 -0.24897474741713904
# cost det =  -0.24897474741713904
# Optimal control with target oscillation period
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24572290856007858
# Mean cost in iteration 100: -0.24574173781506561
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.24607747660721213
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25176847963921345
# Mean cost in iteration 100: -0.24822800789898455
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.2468762657015052
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24654195204184287
# Mean cost in iteration 100: -0.24070120571595893
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.24590032792318423
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24923083567053989
# Mean cost in iteration 100: -0.2465221534059933
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.24706766865037044
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2472827852471364
# Mean cost in iteration 100: -0.2468713831985368
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.24585952596485092
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2465942747607749
# Mean cost in iteration 100: -0.2454715005452336
# Minimal cost found at iteration 11
# Final cost validated with 1000 noise realizations : -0.24582510744882688
# Compute control for a noisy system
# Mean cost in iteration 0: -0.24424920695975721
# Mean cost in iteration 100: -0.2531207775816507
# Minimal cost found at iteration 630
# Final cost validated with 1000 noise realizations : -0.2519455081898427
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25432828877788494
# Mean cost in iteration 100: -0.2545571590141193
# Minimal cost found at iteration 710
# Final cost validated with 1000 noise realizations : -0.25365664235306956
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25110978164023856
# Mean cost in iteration 100: -0.25742888931609587
# Minimal cost found at iteration 844
# Final cost validated with 1000 noise realizations : -0.2538262604337541
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2577494592723513
# Mean cost in iteration 100: -0.2526463503060047
# Minimal cost found at iteration 844
# Final cost validated with 1000 noise realizations : -0.2531539535143797
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25350431309888405
# Mean cost in iteration 100: -0.24930582452417166
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2545200207801579
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25308979249522
# Mean cost in iteration 100: -0.25340393238482045
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2540529197859931
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25175488389936285
# Mean cost in iteration 100: -0.25503256957890985
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2527339470151849
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25500932107604163
# Mean cost in iteration 100: -0.25412255936604206
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2538314660870125
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25176543392966144
# Mean cost in iteration 100: -0.2521586934592736
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2539484042357043
# Compute control for a noisy system
# Mean cost in iteration 0: -0.25375795028607123
# Mean cost in iteration 100: -0.2519428256574705
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.25445358814343527
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2513105629339396
# Mean cost in iteration 100: -0.24791656781780033
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.25382185136807145
# Compute control for a noisy system
# Mean cost in iteration 0: -0.2544920271180731
# Mean cost in iteration 100: -0.25281990878465205
# Minimal cost found at iteration 1094
# Final cost validated with 1000 noise realizations : -0.2534164973168935

# %%
def get_noisy_cost(control, M, sigma, p, wf, w1):

    mod = copy.deepcopy(model)

    mod.params.sigma_ou = sigma
    mod.params["exc_ext"] = control[:,0,:] + p[0]
    mod.params["inh_ext"] = control[:,1,:] + p[1]
    
    mod.run()
    state = get_xs(mod)
    cost_f = wf * np.sum(cost_functions.fourier_cost(state, dt, data_noisy["target_period"], costmat, [int0, int1]))
    cost_2 = w1 * np.sum(cost_functions.L2_cost(control))*dt

    for m in range(1,10*M):
        mod.run()
        state_add = get_xs(mod)
        cost_f_add = wf * np.sum(cost_functions.fourier_cost(state_add, dt, data_noisy["target_period"], costmat, [int0, int1]))

        cost_f += cost_f_add
        state += state_add

    print(cost_2, cost_f/(10*M))

    return cost_2 + cost_f/(10*M), state/(10*M)

def get_xs(m):

    xs_begin = np.concatenate((m.params["exc_init"], m.params["inh_init"]), axis=1)[
        :, :, np.newaxis
    ]
    xs = np.concatenate(
        (
            xs_begin,
            np.stack((m.exc, m.inh), axis=1),
        ),
        axis=2,
    )

    return xs

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1D_noisy.pickle'), 'wb') as f:
    pickle.dump(data_noisy, f)

# %%
with open(os.path.join(pickledir, 'osc_1n_wc_w1D_noisy.pickle'), 'rb') as f:
    res_read = pickle.load(f)
    print(res_read.keys() )

data_noisy = res_read.copy()
