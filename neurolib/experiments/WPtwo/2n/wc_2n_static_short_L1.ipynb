# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy
import pickle
import copy

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.control.optimal_control import oc_wc, cost_functions

import matplotlib as mpl
label_size= 20
mpl.rcParams['xtick.labelsize'] = label_size
mpl.rcParams['ytick.labelsize'] = label_size
mpl.rcParams['font.size'] = label_size
mpl.rcParams['axes.titlesize'] = label_size
mpl.rcParams['axes.titlesize'] = label_size
mpl.rcParams['figure.titlesize'] = label_size
mpl.rcParams['lines.linewidth'] = 1

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

while "Promotion/neurolib" in os.getcwd():
    os.chdir('..')

pickledir = os.path.join(os.getcwd(), "neurolib_aln_osc_datastorage/optimal_control/WP2/2n")
dir = os.path.join(pickledir, "images_2n_wc_static_short")

print(dir)

def get_period(timeseries, dt):
    peaks = scipy.signal.find_peaks(timeseries, prominence=0.001)[0]
    periods = []
    for i in range(2, len(peaks)-1):
        periods.append( (peaks[i] - peaks[i-1]) * dt)
    return np.mean(periods)
# Out:
# /home/lena/Promotion/neurolib_aln_osc_datastorage/optimal_control/WP2/2n/images_2n_wc_static_short

# %%
y0lim = [0, 0.6]

def plot_control(data, dur, dt, wi, filename=None, title=None):
    fig, ax = plt.subplots(2,3, figsize=(24,10), sharex="col", sharey="row", gridspec_kw={'width_ratios': [2, 2, 1]})
    time_array = np.arange(0, dur+dt, dt)

    cmax = max( np.amax(np.abs(data["control"][0])), np.amax(np.abs(data["control"][1])) )
    y1lim = [-cmax* 1.1, cmax* 1.1]

    for n in range(N):
        ax[0, n].plot(time_array, data["state"][wi][n,0,:], color="red", label="E")
        ax[0, n].plot(time_array, data["state"][wi][n,1,:], color="blue", label="I")
        ax[1, n].plot(time_array, data["control"][wi][n,0,:], color="red", label="E")
        ax[1, n].plot(time_array, data["control"][wi][n,1,:], color="blue", label="I")

    i0, i1 = int(0.5* dur/dt), int(0.5* dur/dt) + 1000
    time_array = np.arange(i0*dt, i1*dt, dt)
    ax[0, 2].plot(time_array, data["state"][wi][0,0,i0:i1], color="red", label="N0")
    ax[0, 2].plot(time_array, data["state"][wi][1,0,i0:i1], color="red", linestyle=":", label="N1")
    ax[1, 2].plot(time_array, data["control"][wi][0,0,i0:i1], color="red")
    ax[1, 2].plot(time_array, data["control"][wi][1,0,i0:i1], color="red", linestyle=":")
    ax[1, 2].plot(time_array, data["control"][wi][0,1,i0:i1], color="blue")
    ax[1, 2].plot(time_array, data["control"][wi][1,1,i0:i1], color="blue", linestyle=":")

    ax[0,0].legend(loc="lower right")
    ax[1,0].legend(loc="lower right")
    ax[0,2].legend(loc="lower right")

    ax[0,0].set_xlim(0, dur)
    ax[0,1].set_xlim(0, dur)
    ax[0,2].set_xlim(i0*dt, i1*dt)

    ax[0,0].set_ylim(y0lim)
    ax[1,0].set_ylim(y1lim)

    ax[1,0].set_xlabel("Time")
    ax[1,1].set_xlabel("Time")
    ax[1,2].set_xlabel("Time")
    ax[0,0].set_ylabel("Activity")
    ax[1,0].set_ylabel("Control")

    ax[0,0].set_title("n=0")
    ax[0,1].set_title("n=1")
    ax[0,2].set_title("n=0+1")

    plt.subplots_adjust(
                    wspace=0.15,
                    hspace=0.1)
    
    fig.align_ylabels([ax[:,0]])
    
    if title is not None:
        fig.suptitle(title)

    if filename is not None:
        plt.savefig(filename, bbox_inches='tight', dpi=200)

    plt.show()
    return

def plot_control1(c, s, dur, dt, filename=None, title=None):
    fig, ax = plt.subplots(2,2, figsize=(24,10), sharex="col", sharey="row")
    time_array = np.linspace(0,dur,s.shape[2])

    cmax = np.amax(np.abs(c))
    y1lim = [-cmax* 1.1, cmax* 1.1]

    for n in range(N):
        ax[0, n].plot(time_array, s[n,0,:], color="red", label="E")
        ax[0, n].plot(time_array, s[n,1,:], color="blue", label="I")
        ax[1, n].plot(time_array, c[n,0,:], color="red", label="E")
        ax[1, n].plot(time_array, c[n,1,:], color="blue", label="I")


    ax[0,0].legend(loc="lower right")
    ax[1,0].legend(loc="lower right")

    ax[0,0].set_xlim(0, dur)
    ax[0,1].set_xlim(0, dur)

    ax[0,0].set_ylim(y0lim)
    ax[1,0].set_ylim(y1lim)

    ax[1,0].set_xlabel("Time")
    ax[1,1].set_xlabel("Time")
    ax[0,0].set_ylabel("Activity")
    ax[1,0].set_ylabel("Control")

    ax[0,0].set_title("n=0")
    ax[0,1].set_title("n=1")

    plt.subplots_adjust(
                    wspace=0.15,
                    hspace=0.1)
    
    fig.align_ylabels([ax[:,0]])
    
    if title is not None:
        fig.suptitle(title)

    if filename is not None:
        plt.savefig(filename, bbox_inches='tight', dpi=200)

    plt.show()
    return

# %%
p_names = ["D-exp", "D-osc", "U-exp", "U-osc", "Bi-exp", "Bi-osc"]
coords = [[1., 1.5], [1.613, 1.], [3., 1.], [2.2, 0.4], [2.2, 2.1], [2.4, 1.6]]

coupling = 1.8
cmat = np.array( [[0., 1.], [1., 0.]] )
N = cmat.shape[0]

for i in range(len(p_names)):
    p = p_names[i]
    data["D-osc"]["coordinates"] = coords[i]

# %%
if True:
    data = dict()

    for i in range(len(p_names)):
        p = p_names[i]
        data[p] = dict()
        data[p]["coordinates"] = coords[i]
        data[p]["target_period"] = 20.
        data[p]["delay"] = 9.5

        if "Bi" in p:
            data[p]["control"] = [[None, None], [None, None]]
            data[p]["state"] = [[None, None], [None, None]]
            data[p]["init_state"] = [None, None]
            data[p]["weight"] = [[1., 1.], [1., 1.]]
            data[p]["dur/per"] = [[1000., 20], [1000., 20]]
        else:
            data[p]["control"] = [None, None]
            data[p]["state"] = [None, None]
            data[p]["init_state"] = None
            data[p]["weight"] = [5. * 1e-5, 5. * 1e-4]
            data[p]["dur/per"] = [340., 10]


duration = 1e5
dt = 0.1

data["U-osc"]["delay"] = 13.75
data["Bi-osc"]["delay"] = 9.5

test_input_plus = ZeroInput().generate_input(duration=duration+dt, dt=dt)
test_input_plus[:,400:500] = 1.

test_input_minus = ZeroInput().generate_input(duration=duration+dt, dt=dt)
test_input_minus[:,400:500] = -1.

for pi in range(len(p_names)):

    if "Bi" in p_names[pi]:
        continue

    if pi not in [1]: continue

    print(p_names[pi])

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)

    model.params['duration'] = duration
    model.params.exc_ext_baseline = data[p_names[pi]]["coordinates"][0]
    model.params.inh_ext_baseline = data[p_names[pi]]["coordinates"][1]
    model.params["exc_ext"] = test_input_minus

    model.params.K_gl = coupling
    model.run()
    nmaxdelay = model.getMaxDelay()

    einit = np.zeros((N, nmaxdelay+1))
    iinit = np.zeros((N, nmaxdelay+1))

    for n in range(N):
        einit[n,:] = model.exc[n,-nmaxdelay-1:]
        iinit[n,:] = model.inh[n,-nmaxdelay-1:]

    data[p_names[pi]]["init_state"] = [einit, iinit]

    if "osc" in p_names[pi]:
        plt.plot(model.exc[0,0:1500])
        plt.plot(model.exc[1,0:1500])
        plt.show()
        plt.plot(model.exc[0,-3000:])
        plt.plot(model.exc[1,-3000:])
        plt.show()

        per0 = get_period(-model.exc[0,3000:], dt)
        per1 = get_period(-model.exc[1,3000:], dt)
        data[p_names[pi]]["target_period"] = np.mean([per0, per1])

        print(per0, per1)

        model.params.exc_ext_baseline += 0.01
        model.run()
        per0 = get_period(-model.exc[0,3000:], dt)
        per1 = get_period(-model.exc[1,3000:], dt)
        #data[p_names[pi]]["target_period"] = np.mean([per0, per1])

        print(per0, per1)

        plt.plot(model.exc[0,-3000:])
        plt.plot(model.exc[1,-3000:])
        plt.show()

        print("amplitude of oscillation = ", np.amax(model.exc[0,-3000:]))

duration = 2000. 

for pi in range(len(p_names)):

    break

    if "Bi" not in p_names[pi]:
        continue

    print(p_names[pi])

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)

    model.params['duration'] = duration
    model.params.exc_ext_baseline = data[p_names[pi]]["coordinates"][0]
    model.params.inh_ext_baseline = data[p_names[pi]]["coordinates"][1]
    model.params.K_gl = coupling
    nmaxdelay = model.getMaxDelay()

    model.params["exc_ext"] = test_input_plus
    model.params["inh_ext"] = test_input_plus
    model.run()

    plt.plot(model.exc[0,501:1500])
    plt.plot(model.exc[1,501:1500])
    plt.show()

    einit = np.zeros((N, nmaxdelay+1))
    iinit = np.zeros((N, nmaxdelay+1))

    for n in range(N):
        einit[n,:] = model.exc[n,-nmaxdelay-1:]
        iinit[n,:] = model.inh[n,-nmaxdelay-1:]

    data[p_names[pi]]["init_state"][0] = [einit, iinit]

    model.params["exc_ext"] = test_input_minus
    model.params["inh_ext"] = test_input_minus
    model.run()

    einit = np.zeros((N, nmaxdelay+1))
    iinit = np.zeros((N, nmaxdelay+1))

    for n in range(N):
        einit[n,:] = model.exc[n,-nmaxdelay-1:]
        iinit[n,:] = model.inh[n,-nmaxdelay-1:]

    data[p_names[pi]]["init_state"][1] = [einit, iinit]

    if "osc" in p_names[pi]:
        plt.plot(model.exc[0,501:1500])
        plt.plot(model.exc[1,501:1500])
        plt.vlines([177, 348], 0, 0.5)
        plt.show()

        per0 = get_period(-model.exc[0,601:], dt)
        per1 = get_period(-model.exc[1,601:], dt)
        data[p_names[pi]]["target_period"] = np.mean([per0, per1])

        print(data[p]["target_period"])
# Out:
# D-osc
# 11.793633692458375 11.793633692458375
# 11.814046941678523 11.814046941678523
# amplitude of oscillation =  0.12895678701780686

# %%
controlmat = np.ones((N,2))

costmat = np.zeros((N, 2))
costmat[:,0] = 1.

it = 50
maxstr = 5

pr = np.arange(0,1001,20)
testd = 1000.

zero_input0 = ZeroInput().generate_input(duration=duration+model.params.dt, dt=model.params.dt)
zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
zero_control = np.vstack( ([zero_input]*N))

# %%
def optimize_model(model, exprange):
    for l in range(2):
        for k in exprange:
            model.zero_step_encountered = False
            model.step = 10**(k)
            model.optimize(it)
        model.control_matrix = controlmat
    model.zero_step_encountered = False

    return

# %%
data["D-osc"]["weight"] = [1. * 1e-3, 1. * 1e-2]
data["D-osc"]["dur/per"] = [600., 20]

# %%
it = 100

for pi in range(len(p_names)):
    p = p_names[pi]

    if "Bi" in p:
        continue

    if pi not in [1]: continue

    print("Point ", p)
      
    target_period = data[p]["target_period"]

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)
    nmaxdelay = model.getMaxDelay()
    print("target period, max delay = ", target_period, nmaxdelay)

    model.params["exc_ext_baseline"] =  data[p]["coordinates"][0]
    model.params["inh_ext_baseline"] =  data[p]["coordinates"][1]
    model.params.K_gl = coupling
        
    model.params.duration = data[p]["dur/per"][0]
    print("duration = ", model.params.duration)

    zero_input0 = ZeroInput().generate_input(duration=model.params.duration+model.params.dt, dt=model.params.dt)
    zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
    zero_control = np.vstack( ([zero_input]*N))
    zero_control = np.vstack( ([zero_input]*N))
    model.params["exc_ext"] = zero_control[:,0,:]
    model.params["inh_ext"] = zero_control[:,1,:]

    model.params["exc_init"] = data[p]["init_state"][0]
    model.params["inh_init"] = data[p]["init_state"][1]

    model.run()
    
    int0 = 400
    int1 = int0 + int(data[p]["dur/per"][1]*target_period/dt)

    for wi, w2 in enumerate(data[p]["weight"]):

        print("w2 = ",w2)

        #if wi not in [1]: continue

        for factor in [1]:
        #for factor in np.random.rand(10):

            model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,None), control_interval=(int0, int1), 
                                          cost_matrix=costmat, control_matrix=controlmat, )
            model_controlled.channelwise_optimization = True
            model_controlled.weights["w_p"] = 0.
            model_controlled.weights["w_2"] = w2
            model_controlled.weights["w_f_sync"] = 1. 

            model_controlled.maximum_control_strength = maxstr

            if True:
                if type(data[p]["control"][wi]) != type(None):
                    model_controlled.control = data[p]["control"][wi].copy()
                    model_controlled.update_input()

            model_controlled.grad_method = 0
            model_controlled.channelwise_optimization = True

            for l in range(1):
                for k in np.arange(-10., 10., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(it)

            model_controlled.grad_method = 1

            for l in range(0):
                for k in np.arange(-8., 8., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(10)

            data[p]["control"][wi] = model_controlled.control.copy()
            data[p]["state"][wi] = model_controlled.get_xs()

    plot_control(data[p], data[p]["dur/per"][0], dt, 0)
    plot_control(data[p], data[p]["dur/per"][0], dt, 1)

with open(os.path.join(pickledir, '2n_wc_static_short.pickle'), 'wb') as f:
    pickle.dump(data, f)
# Out:
# Point  D-osc
# target period, max delay =  11.814035502958582 95
# duration =  600.0
# w2 =  0.001
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447752
# Converged in iteration 4 with cost -0.0030640909796447752
# Final cost : -0.0030640909796447752
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447752
# Converged in iteration 7 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 2 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 3 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# Compute control for a deterministic system
# Cost in iteration 0: -0.0030640909796447917
# Converged in iteration 1 with cost -0.0030640909796447917
# Final cost : -0.0030640909796447917
# w2 =  0.01
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036523749484444
# Converged in iteration 6 with cost -0.001103652374948457
# Final cost : -0.001103652374948457
# Compute control for a deterministic system
# Cost in iteration 0: -0.001103652374948457
# Cost in iteration 20: -0.001103652548312204
# Converged in iteration 36 with cost -0.0011036828738155214
# Final cost : -0.0011036828738155214
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155214
# Converged in iteration 3 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 2 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225
# Compute control for a deterministic system
# Cost in iteration 0: -0.0011036828738155225
# Converged in iteration 1 with cost -0.0011036828738155225
# Final cost : -0.0011036828738155225

# %%
for pi in range(len(p_names)):
    p = p_names[pi]

    if pi not in [1]:
        continue

    print("Point ", p)   

    for wi in range(len(data[p]["weight"])):

        print(data[p]["weight"][wi])

        filename = os.path.join(dir, str(p) + "_" + str(wi) + ".png")
        title = "WC " + p + r" $\rightarrow$ osc, $w_2 = $ " + "{}".format(data[p]["weight"][wi])
        plot_control(data[p],  data[p]["dur/per"][0], dt, wi, filename=filename, title=title)
# Out:
# Point  D-osc
# 0.001
# 0.01

# %%
from numba.typed import Dict
from numba.core import types

weights = Dict.empty(
        key_type=types.unicode_type,
        value_type=types.float64,
    )

weights["w_2"] = 1.0
weights["w_1"] = 0.0
weights["w_1T"] = 0.0
weights["w_1D"] = 0.0

freq_fac_range = [0.9, 0.95, 1.0, 1.05, 1.1, 1.9, 2.0, 2.1]

c0 = [None] * len(freq_fac_range)
s0 = [None] * len(freq_fac_range)
w0 = np.ones((len(freq_fac_range)))

c1 = [None] * len(freq_fac_range)
s1 = [None] * len(freq_fac_range)
w1 = np.ones((len(freq_fac_range)))

c2 = [None] * len(freq_fac_range)
s2 = [None] * len(freq_fac_range)
w2_ = np.ones((len(freq_fac_range)))

# %%
for fi, freq_factor in enumerate(freq_fac_range):

    if fi not in [0,1,2,3,4]: continue

    target_period = data["D-osc"]["target_period"] * freq_factor

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)
    model.params["exc_ext_baseline"] =  data["D-osc"]["coordinates"][0]
    model.params["inh_ext_baseline"] =  data["D-osc"]["coordinates"][1]
    model.params.K_gl = coupling

    zero_input0 = ZeroInput().generate_input(duration=model.params.duration+model.params.dt, dt=model.params.dt)
    zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
    zero_control = np.vstack( ([zero_input]*N))
    model.params["exc_ext"] = zero_control[:,0,:]
    model.params["inh_ext"] = zero_control[:,1,:]

    model.params["exc_init"] = data["D-osc"]["init_state"][0]
    model.params["inh_init"] = data["D-osc"]["init_state"][1]

    model.run()
    
    int0 = 200
    int1 = int0 + int(data["D-osc"]["dur/per"][1]*target_period/dt)
    model.params.duration = int1 * dt + 10

    weight1 = 1e-4 * 0.4

    for factor in [1]:
    #for factor in np.random.rand(10):

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), 
                                        cost_matrix=costmat, control_matrix=controlmat, )
        model_controlled.channelwise_optimization = True
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1"] = weight1
        model_controlled.weights["w_f_sync"] = 1.

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(c0[fi]) != type(None):
                model_controlled.control = c0[fi].copy()
                model_controlled.update_input()

        model_controlled.grad_method = 0
        model_controlled.channelwise_optimization = True

        for l in range(1):
            for k in np.arange(0, 10., 2.):
                model_controlled.zero_step_encountered = False
                model_controlled.step = 10**(k)
                model_controlled.optimize(it)

        for j in range(1):
            for l in range(1):
                for k in np.arange(-10., 10., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(it)

            model_controlled.grad_method = 1

            for l in range(1):
                for k in np.arange(-8., 8., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(10)

        c0[fi] = model_controlled.control.copy()
        s0[fi] = model_controlled.get_xs()

        print("------------------------------ period factor, energy input = ", freq_factor, cost_functions.control_strength_cost(c0[fi], weights, dt))
        #plot_control1(c0[fi], s0[fi], model_controlled.model.params.duration, dt, filename=os.path.join(dir, "freq_range_time_series_" + str(fi) + ".png"))
# Out:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 2 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 2 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 2 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 2 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 2 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Converged in iteration 1 with cost -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# Compute control for a deterministic system
# Cost in iteration 0: -0.03414765272701055
# Final cost : -0.03414765272701055
# ------------------------------ period factor, energy input =  0.9 212.40741740920367
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.002748627273944787
# Converged in iteration 2 with cost -0.002748842545152794
# Final cost : -0.002748842545152794
# Compute control for a deterministic system
# Cost in iteration 0: -0.002748842545152794
# Converged in iteration 2 with cost -0.002748842545152794
# Final cost : -0.002748842545152794
# Compute control for a deterministic system
# Cost in iteration 0: -0.002748842545152794
# Converged in iteration 2 with cost -0.002748842545152794
# Final cost : -0.002748842545152794
# Compute control for a deterministic system
# Cost in iteration 0: -0.002748842545152794
# Converged in iteration 2 with cost -0.002748842545152794
# Final cost : -0.002748842545152794
# Compute control for a deterministic system
# Cost in iteration 0: -0.002748842545152794
# Converged in iteration 5 with cost -0.0027584407302185514
# Final cost : -0.0027584407302185514
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185514
# Converged in iteration 3 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 2 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 2 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 2 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Converged in iteration 1 with cost -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027584407302185983
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027584407302185983
# Final cost : -0.0027605168830939783
# Compute control for a deterministic system
# Cost in iteration 0: -0.0027605168830939783
# Final cost : -0.0027605168830939783
# ------------------------------ period factor, energy input =  0.95 28.53672570947246
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 2 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Cost in iteration 20: -0.04014545696701717
# Converged in iteration 28 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 2 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 2 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 2 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Converged in iteration 1 with cost -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# Compute control for a deterministic system
# Cost in iteration 0: -0.04014545696701717
# Final cost : -0.04014545696701717
# ------------------------------ period factor, energy input =  1.0 102.91355251950691
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 17 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 2 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 2 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 2 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 2 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Converged in iteration 1 with cost -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# Compute control for a deterministic system
# Cost in iteration 0: -0.04224692319140685
# Final cost : -0.04224692319140685
# ------------------------------ period factor, energy input =  1.05 76.6038904090137
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Cost in iteration 20: -0.04391393687866682
# Converged in iteration 25 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 2 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 2 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 2 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 2 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Converged in iteration 1 with cost -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# Compute control for a deterministic system
# Cost in iteration 0: -0.04391393687866682
# Final cost : -0.04391393687866682
# ------------------------------ period factor, energy input =  1.1 62.66404214041737

# %%
for fi, freq_factor in enumerate(freq_fac_range):

    #if fi not in [0,4,5,6,7]: continue
    if fi not in [0,1,2,3,4]: continue

    target_period = data["D-osc"]["target_period"] * freq_factor

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)
    model.params["exc_ext_baseline"] =  data["D-osc"]["coordinates"][0]
    model.params["inh_ext_baseline"] =  data["D-osc"]["coordinates"][1]
    model.params.K_gl = coupling

    zero_input0 = ZeroInput().generate_input(duration=model.params.duration+model.params.dt, dt=model.params.dt)
    zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
    zero_control = np.vstack( ([zero_input]*N))
    model.params["exc_ext"] = zero_control[:,0,:]
    model.params["inh_ext"] = zero_control[:,1,:]

    model.params["exc_init"] = data["D-osc"]["init_state"][0]
    model.params["inh_init"] = data["D-osc"]["init_state"][1]

    model.run()
    
    int0 = 200
    int1 = int0 + int(data["D-osc"]["dur/per"][1]*target_period/dt)
    model.params.duration = int1 * dt + 10

    weight1 = 1e-4 * 2

    for factor in [1]:
    #for factor in np.random.rand(10):

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), 
                                        cost_matrix=costmat, control_matrix=controlmat, )
        model_controlled.channelwise_optimization = True
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1"] = weight1
        model_controlled.weights["w_f_sync"] = 1.

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(c1[fi]) != type(None):
                model_controlled.control = c1[fi].copy()
                model_controlled.update_input()

        model_controlled.grad_method = 0
        model_controlled.channelwise_optimization = True

        for l in range(1):
            for k in np.arange(0., 10., 2.):
                model_controlled.zero_step_encountered = False
                model_controlled.step = 10**(k)
                model_controlled.optimize(it)

        for j in range(1):
            for l in range(1):
                for k in np.arange(-10., 10., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(it)

            model_controlled.grad_method = 1

            for l in range(1):
                for k in np.arange(-8., 8., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(10)

        c1[fi] = model_controlled.control.copy()
        s1[fi] = model_controlled.get_xs()

        print("------------------------------ period factor, energy input = ", freq_factor, cost_functions.control_strength_cost(c1[fi], weights, dt))
        #plot_control1(c1[fi], s1[fi], model_controlled.model.params.duration, dt)
# Out:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Converged in iteration 1 with cost -0.010691407032965495
# Final cost : -0.010691407032965495
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Converged in iteration 1 with cost -0.010691407032965495
# Final cost : -0.010691407032965495
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Converged in iteration 1 with cost -0.010691407032965495
# Final cost : -0.010691407032965495
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Converged in iteration 1 with cost -0.010691407032965495
# Final cost : -0.010691407032965495
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Converged in iteration 1 with cost -0.010691407032965495
# Final cost : -0.010691407032965495
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032965495
# Cost in iteration 20: -0.010691407032970147
# Cost in iteration 40: -0.010691407032977305
# Final cost : -0.010691407032981042
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032981042
# Cost in iteration 20: -0.010691407032987012
# Cost in iteration 40: -0.010691407032993122
# Final cost : -0.010691407032996019
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407032996019
# Cost in iteration 20: -0.010691407033000904
# Cost in iteration 40: -0.010691407033005425
# Final cost : -0.010691407033007808
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033007808
# Cost in iteration 20: -0.010691407033013807
# Cost in iteration 40: -0.010691407033020132
# Final cost : -0.010691407033023247
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033023247
# Cost in iteration 20: -0.010691407033028993
# Cost in iteration 40: -0.010691407033034506
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Converged in iteration 1 with cost -0.010691407033037524
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Converged in iteration 1 with cost -0.010691407033037524
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Converged in iteration 1 with cost -0.010691407033037524
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Converged in iteration 1 with cost -0.010691407033037524
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Converged in iteration 1 with cost -0.010691407033037524
# Final cost : -0.010691407033037524
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033037524
# Final cost : -0.010691407033038412
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033038412
# Final cost : -0.01069140703303862
# Compute control for a deterministic system
# Cost in iteration 0: -0.01069140703303862
# Final cost : -0.010691407033038797
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033038797
# Final cost : -0.010691407033040497
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033040497
# Final cost : -0.010691407033040497
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033040497
# Final cost : -0.010691407033040497
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033040497
# Final cost : -0.010691407033040497
# Compute control for a deterministic system
# Cost in iteration 0: -0.010691407033040497
# Final cost : -0.010691407033040497
# ------------------------------ period factor, energy input =  0.9 117.82750111501723
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Converged in iteration 1 with cost -0.014694311398867343
# Final cost : -0.014694311398867343
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Converged in iteration 1 with cost -0.014694311398867343
# Final cost : -0.014694311398867343
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Converged in iteration 1 with cost -0.014694311398867343
# Final cost : -0.014694311398867343
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Converged in iteration 1 with cost -0.014694311398867343
# Final cost : -0.014694311398867343
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Converged in iteration 1 with cost -0.014694311398867343
# Final cost : -0.014694311398867343
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398867343
# Cost in iteration 20: -0.014694311398877467
# Cost in iteration 40: -0.01469431139888756
# Final cost : -0.014694311398892566
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398892566
# Cost in iteration 20: -0.01469431139890149
# Cost in iteration 40: -0.014694311398910129
# Final cost : -0.014694311398914375
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398914375
# Cost in iteration 20: -0.01469431139892146
# Cost in iteration 40: -0.01469431139892852
# Final cost : -0.014694311398931893
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398931893
# Cost in iteration 20: -0.01469431139894066
# Cost in iteration 40: -0.014694311398949465
# Final cost : -0.014694311398954593
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398954593
# Cost in iteration 20: -0.014694311398963506
# Cost in iteration 40: -0.014694311398971587
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Converged in iteration 1 with cost -0.014694311398975472
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Converged in iteration 1 with cost -0.014694311398975472
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Converged in iteration 1 with cost -0.014694311398975472
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Converged in iteration 1 with cost -0.014694311398975472
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Converged in iteration 1 with cost -0.014694311398975472
# Final cost : -0.014694311398975472
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398975472
# Final cost : -0.014694311398976614
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398976614
# Final cost : -0.01469431139898316
# Compute control for a deterministic system
# Cost in iteration 0: -0.01469431139898316
# Final cost : -0.014694311398986769
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398986769
# Final cost : -0.014694311398992074
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398992074
# Final cost : -0.014694311398992074
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398992074
# Final cost : -0.014694311398992074
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398992074
# Final cost : -0.014694311398992074
# Compute control for a deterministic system
# Cost in iteration 0: -0.014694311398992074
# Final cost : -0.014694311398992074
# ------------------------------ period factor, energy input =  0.95 106.50220825626621
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 2 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 2 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 2 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 2 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Converged in iteration 1 with cost -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# Compute control for a deterministic system
# Cost in iteration 0: -0.022422115271803586
# Final cost : -0.022422115271803586
# ------------------------------ period factor, energy input =  1.0 29.471026018632315
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 2 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 2 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 2 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 2 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 2 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Converged in iteration 1 with cost -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# Compute control for a deterministic system
# Cost in iteration 0: -0.028707846337225822
# Final cost : -0.028707846337225822
# ------------------------------ period factor, energy input =  1.05 25.72183667609791
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 2 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 2 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 2 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 2 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Converged in iteration 1 with cost -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# Compute control for a deterministic system
# Cost in iteration 0: -0.031849549733980374
# Final cost : -0.031849549733980374
# ------------------------------ period factor, energy input =  1.1 17.53558035906492

# %%
for fi, freq_factor in enumerate(freq_fac_range):

    #if fi not in [0,4,5,6,7]: continue
    if fi not in [0,1,2,3,4]: continue

    target_period = data["D-osc"]["target_period"] * freq_factor

    model = WCModel(Cmat=cmat, Dmat=data[p_names[pi]]["delay"]*20.*cmat)
    model.params["exc_ext_baseline"] =  data["D-osc"]["coordinates"][0]
    model.params["inh_ext_baseline"] =  data["D-osc"]["coordinates"][1]
    model.params.K_gl = coupling

    zero_input0 = ZeroInput().generate_input(duration=model.params.duration+model.params.dt, dt=model.params.dt)
    zero_input = np.vstack( ([zero_input0]*2) )[np.newaxis,:,:]
    zero_control = np.vstack( ([zero_input]*N))
    model.params["exc_ext"] = zero_control[:,0,:]
    model.params["inh_ext"] = zero_control[:,1,:]

    model.params["exc_init"] = data["D-osc"]["init_state"][0]
    model.params["inh_init"] = data["D-osc"]["init_state"][1]

    model.run()
    
    int0 = 200
    int1 = int0 + int(data["D-osc"]["dur/per"][1]*target_period/dt)
    model.params.duration = int1 * dt + 10

    weight1 = 1e-4 * 0.08

    for factor in [1]:
    #for factor in np.random.rand(10):

        model_controlled = oc_wc.OcWc(model, target_period, print_array=pr, cost_interval=(int0,int1), control_interval=(int0, int1), 
                                        cost_matrix=costmat, control_matrix=controlmat, )
        model_controlled.channelwise_optimization = True
        model_controlled.weights["w_p"] = 0.
        model_controlled.weights["w_1"] = weight1
        model_controlled.weights["w_f_sync"] = 1.

        model_controlled.maximum_control_strength = maxstr

        if True:
            if type(c2[fi]) != type(None):
                model_controlled.control = c2[fi].copy()
                model_controlled.update_input()

        model_controlled.grad_method = 0
        model_controlled.channelwise_optimization = True

        for l in range(1):
            for k in np.arange(0., 10., 2.):
                model_controlled.zero_step_encountered = False
                model_controlled.step = 10**(k)
                model_controlled.optimize(it)

        for j in range(1):
            for l in range(1):
                for k in np.arange(-10., 10., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(it)

            model_controlled.grad_method = 1

            for l in range(1):
                for k in np.arange(-8., 8., 2.):
                    model_controlled.zero_step_encountered = False
                    model_controlled.step = 10**(k)
                    model_controlled.optimize(10)

        c2[fi] = model_controlled.control.copy()
        s2[fi] = model_controlled.get_xs()

        print("------------------------------ period factor, energy input = ", freq_factor, cost_functions.control_strength_cost(c2[fi], weights, dt))
        plot_control1(c2[fi], s2[fi], model_controlled.model.params.duration, dt)
# Out:
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 2 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Converged in iteration 1 with cost -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# Compute control for a deterministic system
# Cost in iteration 0: -0.04286836269561217
# Final cost : -0.04286836269561217
# ------------------------------ period factor, energy input =  0.9 372.2247531804841
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Cost in iteration 20: -0.04495085605811647
# Converged in iteration 25 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 2 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Converged in iteration 1 with cost -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# Compute control for a deterministic system
# Cost in iteration 0: -0.04495085605811647
# Final cost : -0.04495085605811647
# ------------------------------ period factor, energy input =  0.95 331.1811281846121
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 2 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 4 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 2 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 2 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 2 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Converged in iteration 1 with cost -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# Compute control for a deterministic system
# Cost in iteration 0: -0.04733803456288552
# Final cost : -0.04733803456288552
# ------------------------------ period factor, energy input =  1.0 301.2876542812862
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 5 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 2 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 2 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Cost in iteration 20: -0.04938002280056024
# Converged in iteration 25 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Converged in iteration 1 with cost -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# Compute control for a deterministic system
# Cost in iteration 0: -0.04938002280056024
# Final cost : -0.04938002280056024
# ------------------------------ period factor, energy input =  1.05 293.0440738438239
# Optimal control with target oscillation period
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Cost in iteration 20: -0.051568018765567644
# Converged in iteration 25 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 2 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 2 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 2 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 2 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 2 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Converged in iteration 1 with cost -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# Compute control for a deterministic system
# Cost in iteration 0: -0.051568018765567644
# Final cost : -0.051568018765567644
# ------------------------------ period factor, energy input =  1.1 298.39741032028337

# %%
fig, ax = plt.subplots(3,6, figsize=(28,12), sharex=True)

for fi, freq_factor in enumerate(freq_fac_range):
    if fi not in [0,1,2,3,4]: continue

    target_period = data["D-osc"]["target_period"] * freq_factor
    int0 = 200
    int1 = int0 + int(data["D-osc"]["dur/per"][1]*target_period/dt)

    control_strength = cost_functions.control_strength_cost(c2[fi], weights, dt)
    av_control_strength = control_strength / freq_factor
    osc_amp = [np.amax(s2[fi][:,0,:]), np.amax(s2[fi][:,1,:])]
    fourier_cost = - sum(cost_functions.fourier_cost_sync(s2[fi], dt, target_period, costmat, [int0,int1]))

    peaks = scipy.signal.find_peaks(s2[fi][0,0,:], prominence=0.001)[0]
    inputdurlist = []
    for p in range(3,len(peaks)-2):
        inputdur = 0.
        for t in range(peaks[p], peaks[p+1]):
            if np.abs(s2[fi][0,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s2[fi][0,1,t]) > 1e-6:
                inputdur +=1
            if np.abs(s2[fi][1,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s2[fi][1,1,t]) > 1e-6:
                inputdur +=1
        inputdurlist.append(inputdur*dt)

    inputdurmean = np.mean(inputdurlist)

    ax[0,0].plot(freq_factor, control_strength, marker="x",color="gray")
    ax[0,1].plot(freq_factor, av_control_strength, marker="x",color="gray")
    ax[0,2].plot(freq_factor, osc_amp[0], marker="x",color="red")
    ax[0,2].plot(freq_factor, osc_amp[1], marker="x",color="blue")
    ax[0,3].plot(freq_factor, fourier_cost, marker="x",color="gray")
    ax[0,4].plot(freq_factor, inputdurmean, marker="x",color="gray")
    ax[0,5].plot(freq_factor, inputdurmean / freq_factor, marker="x",color="gray")

    control_strength = cost_functions.control_strength_cost(c0[fi], weights, dt)
    av_control_strength = control_strength / freq_factor
    osc_amp = [np.amax(s0[fi][:,0,:]), np.amax(s0[fi][:,1,:])]
    fourier_cost = - sum(cost_functions.fourier_cost_sync(s0[fi], dt, target_period, costmat, [int0,int1]))

    peaks = scipy.signal.find_peaks(s0[fi][0,0,:], prominence=0.001)[0]
    inputdurlist = []
    for p in range(3,len(peaks)-2):
        inputdur = 0.
        for t in range(peaks[p], peaks[p+1]):
            if np.abs(s0[fi][0,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s0[fi][0,1,t]) > 1e-6:
                inputdur +=1
            if np.abs(s0[fi][1,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s0[fi][1,1,t]) > 1e-6:
                inputdur +=1
        inputdurlist.append(inputdur*dt)

    inputdurmean = np.mean(inputdurlist)

    ax[1,0].plot(freq_factor, control_strength, marker="x",color="gray")
    ax[1,1].plot(freq_factor, av_control_strength, marker="x",color="gray")
    ax[1,2].plot(freq_factor, osc_amp[0], marker="x",color="red")
    ax[1,2].plot(freq_factor, osc_amp[1], marker="x",color="blue")
    ax[1,3].plot(freq_factor, fourier_cost, marker="x",color="gray")
    ax[1,4].plot(freq_factor, inputdurmean, marker="x",color="gray")
    ax[1,5].plot(freq_factor, inputdurmean / freq_factor, marker="x",color="gray")

    control_strength = cost_functions.control_strength_cost(c1[fi], weights, dt)
    av_control_strength = control_strength / freq_factor
    osc_amp = [np.amax(s1[fi][:,0,:]), np.amax(s1[fi][:,1,:])]
    fourier_cost = - sum(cost_functions.fourier_cost_sync(s1[fi], dt, target_period, costmat, [int0,int1]))

    peaks = scipy.signal.find_peaks(s1[fi][0,0,:], prominence=0.001)[0]
    inputdurlist = []
    for p in range(3,len(peaks)-2):
        inputdur = 0.
        for t in range(peaks[p], peaks[p+1]):
            if np.abs(s1[fi][0,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s1[fi][0,1,t]) > 1e-6:
                inputdur +=1
            if np.abs(s1[fi][1,0,t]) > 1e-6:
                inputdur +=1
            if np.abs(s1[fi][1,1,t]) > 1e-6:
                inputdur +=1
        inputdurlist.append(inputdur*dt)

    inputdurmean = np.mean(inputdurlist)

    ax[2,0].plot(freq_factor, control_strength, marker="x",color="gray")
    ax[2,1].plot(freq_factor, av_control_strength, marker="x",color="gray")
    ax[2,2].plot(freq_factor, osc_amp[0], marker="x",color="red")
    ax[2,2].plot(freq_factor, osc_amp[1], marker="x",color="blue")
    ax[2,3].plot(freq_factor, fourier_cost, marker="x",color="gray")
    ax[2,4].plot(freq_factor, inputdurmean, marker="x",color="gray")
    ax[2,5].plot(freq_factor, inputdurmean / freq_factor, marker="x",color="gray")


ax[0,0].set_title("Control strength (L2 cost)")
ax[0,1].set_title("Normalized control strength")
ax[0,2].set_title("Signal amplitude")
ax[0,3].set_title("Fourier coefficient")
ax[0,4].set_title("Input duration")
ax[0,5].set_title("Normalized input duration")

ax[0,0].set_ylabel("Small w2")
ax[1,0].set_ylabel("Intermediate w2")
ax[2,0].set_ylabel("Large w2")

ax[-1,0].set_xlabel("Multiplication factor")
ax[-1,1].set_xlabel("Multiplication factor")
ax[-1,2].set_xlabel("Multiplication factor")
ax[-1,3].set_xlabel("Multiplication factor")

plt.show()
fig.tight_layout()

fig.savefig(os.path.join(dir, "freq_range_l1.png"))

# %%
with open(os.path.join(pickledir, '2n_wc_static_short.pickle'), 'wb') as f:
    pickle.dump(data, f)

# %%
with open(os.path.join(pickledir, '2n_wc_static_short.pickle'), 'rb') as f:
    res_read = pickle.load(f)
    print(res_read.keys() )

data = res_read.copy()
# Out:
# dict_keys(['D-exp', 'D-osc', 'U-exp', 'U-osc', 'Bi-exp', 'Bi-osc'])
