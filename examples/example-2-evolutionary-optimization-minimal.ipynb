# %% [markdown]
# # Simple example of the evolutionary optimization framework
#
# This notebook provides a simple example for the use of the evolutionary optimization framework builtin to the library. Under the hood, the implementation of the evolutionary algorithm is powered by `deap` and `pypet` cares about the parallelization and storage of the simulation data for us.
#
# Here we demonstrate how to fit parameters of a the evaluation function `optimize_me` which simply computes the distance of the parameters to the unit circle and returns this as the `fitness_tuple` that DEAP expects.

# %%
# change to the root directory of the project
import os
if os.getcwd().split("/")[-1] == "examples":
    os.chdir('..')
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    import sys
    # !{sys.executable} -m pip install matplotlib seaborn
    import matplotlib.pyplot as plt
    
import numpy as np
import logging

from neurolib.utils.parameterSpace import ParameterSpace
from neurolib.optimize.evolution import Evolution

import neurolib.optimize.evolution.evolutionaryUtils as eu
import neurolib.utils.functions as func

def optimize_me(traj):
    ind = evolution.getIndividualFromTraj(traj)
    logging.info("Hello, I am {}".format(ind.id))
    logging.info("You can also call me {}, or simply ({:.2}, {:.2}).".format(ind.params, ind.x, ind.y))
    
    # let's make a circle
    computation_result = abs((ind.x**2 + ind.y**2) - 1)
    # DEAP wants a tuple as fitness, ALWAYS!
    fitness_tuple = (computation_result ,)
    
    # we also require a dictionary with at least a single result for storing the results in the hdf
    result_dict = {}
    
    return fitness_tuple, result_dict

    
pars = ParameterSpace(['x', 'y'], [[-5.0, 5.0], [-5.0, 5.0]])
evolution = Evolution(optimize_me, pars, weightList = [-1.0],
                      POP_INIT_SIZE=2, POP_SIZE = 2, NGEN=8, filename="example-2.0.hdf")
# info: chose POP_INIT_SIZE=100, POP_SIZE = 50, NGEN=10 for real exploration, 
# values here are low for testing: POP_INIT_SIZE=10, POP_SIZE = 6, NGEN=4

evolution.run(verbose = True)
# Out:
# MainProcess root INFO     Assuming parameter kind "bound"
# MainProcess root INFO     Trajectory Name: results-2024-12-03-13H-31M-19S
# MainProcess root INFO     Storing data to: ./data/hdf/example-2.0.hdf
# MainProcess root INFO     Trajectory Name: results-2024-12-03-13H-31M-19S
# MainProcess root INFO     Number of cores: 8
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/example-2.0.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evolution: Using algorithm: adaptive
# /home/lena/.local/lib/python3.10/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/lena/.local/lib/python3.10/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# MainProcess root INFO     Evolution: Individual generation: <function randomParametersAdaptive at 0x77ca9431de10>
# MainProcess root INFO     Evolution: Mating operator: <function cxBlend at 0x77ca961f81f0>
# MainProcess root INFO     Evolution: Mutation operator: <function gaussianAdaptiveMutation_nStepSizes at 0x77ca9431e290>
# MainProcess root INFO     Evolution: Parent selection: <function selRank at 0x77ca9431dfc0>
# MainProcess root INFO     Evolution: Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# MainProcess root INFO     Evaluating initial population of size 2 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 0/2 runs [                    ]  0.0%
# MainProcess pypet INFO     PROGRESS: Finished 1/2 runs [==========          ] 50.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 2/2 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess root INFO     Start of evolution
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# Parameter distribution (Generation 0):
# x: 	 mean: -1.2087,	 std: 2.3454
# y: 	 mean: 0.0401,	 std: 4.0261
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 2/4 runs [==========          ] 50.0%
# MainProcess pypet INFO     PROGRESS: Finished 3/4 runs [===============     ] 75.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 4/4 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 1 -----------
# Best individual is [2.2001188279261266, -1.4266274268810752, 2.5026420353471477, 4.251301275335544]
# Score: -5.875788672124351
# Fitness: (5.875788672124351,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -1.1e+01
# Parameter distribution (Generation 1):
# x: 	 mean: 1.6684,	 std: 0.5317
# y: 	 mean: -2.7063,	 std: 1.2797
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  5.88
# 	Score:  -5.88
# 	Weighted fitness:  -5.88
# 	Stats mean 5.88 std 0.00 min 5.88 max 5.88
# 	model.params["x"] = 2.20
# 	model.params["y"] = -1.43
# Individual 1
# 	Fitness values:  16.18
# 	Score:  -16.18
# 	Weighted fitness:  -16.18
# 	Stats mean 16.18 std 0.00 min 16.18 max 16.18
# 	model.params["x"] = 1.14
# 	model.params["y"] = -3.99
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 4/6 runs [=============       ] 66.7%
# There are 2 valid individuals
# Mean score across population: -1.1e+01
# MainProcess pypet INFO     PROGRESS: Finished 5/6 runs [================    ] 83.3%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 6/6 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 2 -----------
# Best individual is [2.2001188279261266, -1.4266274268810752, 2.5026420353471477, 4.251301275335544]
# Score: -5.875788672124351
# Fitness: (5.875788672124351,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -6.0
# Parameter distribution (Generation 2):
# x: 	 mean: 2.2693,	 std: 0.0692
# y: 	 mean: -0.0834,	 std: 1.3432
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  5.88
# 	Score:  -5.88
# 	Weighted fitness:  -5.88
# 	Stats mean 5.88 std 0.00 min 5.88 max 5.88
# 	model.params["x"] = 2.20
# 	model.params["y"] = -1.43
# Individual 1
# 	Fitness values:  6.06
# 	Score:  -6.06
# 	Weighted fitness:  -6.06
# 	Stats mean 6.06 std 0.00 min 6.06 max 6.06
# 	model.params["x"] = 2.34
# 	model.params["y"] = 1.26
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 6/8 runs [===============     ] 75.0%
# There are 2 valid individuals
# Mean score across population: -6.0
# MainProcess pypet INFO     PROGRESS: Finished 7/8 runs [=================   ] 87.5%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 8/8 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 3 -----------
# Best individual is [2.2001188279261266, -1.4266274268810752, 2.5026420353471477, 4.251301275335544]
# Score: -5.875788672124351
# Fitness: (5.875788672124351,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -6.0
# Parameter distribution (Generation 3):
# x: 	 mean: 2.2693,	 std: 0.0692
# y: 	 mean: -0.0834,	 std: 1.3432
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  5.88
# 	Score:  -5.88
# 	Weighted fitness:  -5.88
# 	Stats mean 5.88 std 0.00 min 5.88 max 5.88
# 	model.params["x"] = 2.20
# 	model.params["y"] = -1.43
# Individual 1
# 	Fitness values:  6.06
# 	Score:  -6.06
# 	Weighted fitness:  -6.06
# 	Stats mean 6.06 std 0.00 min 6.06 max 6.06
# 	model.params["x"] = 2.34
# 	model.params["y"] = 1.26
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 8/10 runs [================    ] 80.0%
# There are 2 valid individuals
# Mean score across population: -6.0
# MainProcess pypet INFO     PROGRESS: Finished 9/10 runs [==================  ] 90.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 10/10 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 4 -----------
# Best individual is [-1.9447358916216624, 1.6786502935376313, 1.845982587034942, 0.954209153568009]
# Score: -5.599864496155478
# Fitness: (5.599864496155478,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -5.7
# Parameter distribution (Generation 4):
# x: 	 mean: 0.1277,	 std: 2.0724
# y: 	 mean: 0.1260,	 std: 1.5526
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  5.6
# 	Score:  -5.6
# 	Weighted fitness:  -5.6
# 	Stats mean 5.60 std 0.00 min 5.60 max 5.60
# 	model.params["x"] = -1.94
# 	model.params["y"] = 1.68
# Individual 1
# 	Fitness values:  5.88
# 	Score:  -5.88
# 	Weighted fitness:  -5.88
# 	Stats mean 5.88 std 0.00 min 5.88 max 5.88
# 	model.params["x"] = 2.20
# 	model.params["y"] = -1.43
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 10/12 runs [================    ] 83.3%
# There are 2 valid individuals
# Mean score across population: -5.7
# MainProcess pypet INFO     PROGRESS: Finished 11/12 runs [==================  ] 91.7%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 12/12 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 5 -----------
# Best individual is [0.37226238908278453, -1.6338520782472274, 1.5960348794609616, 2.929816726327615]
# Score: -1.8080518999184068
# Fitness: (1.8080518999184068,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -3.7
# Parameter distribution (Generation 5):
# x: 	 mean: -0.7862,	 std: 1.1585
# y: 	 mean: 0.0224,	 std: 1.6563
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  1.81
# 	Score:  -1.81
# 	Weighted fitness:  -1.81
# 	Stats mean 1.81 std 0.00 min 1.81 max 1.81
# 	model.params["x"] = 0.37
# 	model.params["y"] = -1.63
# Individual 1
# 	Fitness values:  5.6
# 	Score:  -5.6
# 	Weighted fitness:  -5.6
# 	Stats mean 5.60 std 0.00 min 5.60 max 5.60
# 	model.params["x"] = -1.94
# 	model.params["y"] = 1.68
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 12/14 runs [=================   ] 85.7%
# There are 2 valid individuals
# Mean score across population: -3.7
# MainProcess pypet INFO     PROGRESS: Finished 13/14 runs [==================  ] 92.9%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 14/14 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 6 -----------
# Best individual is [0.37226238908278453, -1.6338520782472274, 1.5960348794609616, 2.929816726327615]
# Score: -1.8080518999184068
# Fitness: (1.8080518999184068,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -3.7
# Parameter distribution (Generation 6):
# x: 	 mean: -0.7862,	 std: 1.1585
# y: 	 mean: 0.0224,	 std: 1.6563
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  1.81
# 	Score:  -1.81
# 	Weighted fitness:  -1.81
# 	Stats mean 1.81 std 0.00 min 1.81 max 1.81
# 	model.params["x"] = 0.37
# 	model.params["y"] = -1.63
# Individual 1
# 	Fitness values:  5.6
# 	Score:  -5.6
# 	Weighted fitness:  -5.6
# 	Stats mean 5.60 std 0.00 min 5.60 max 5.60
# 	model.params["x"] = -1.94
# 	model.params["y"] = 1.68
# --------------------
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 8 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 14/16 runs [=================   ] 87.5%
# There are 2 valid individuals
# Mean score across population: -3.7
# MainProcess pypet INFO     PROGRESS: Finished 15/16 runs [==================  ] 93.8%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 16/16 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2024-12-03-13H-31M-19S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2024-12-03-13H-31M-19S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 7 -----------
# Best individual is [0.23748594877682958, 0.07854656845324959, 1.362602613109863, 3.9429832666566305]
# Score: -0.937430860717788
# Fitness: (0.937430860717788,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -1.4
# Parameter distribution (Generation 7):
# x: 	 mean: 0.3049,	 std: 0.0674
# y: 	 mean: -0.7777,	 std: 0.8562
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  0.94
# 	Score:  -0.94
# 	Weighted fitness:  -0.94
# 	Stats mean 0.94 std 0.00 min 0.94 max 0.94
# 	model.params["x"] = 0.24
# 	model.params["y"] = 0.08
# Individual 1
# 	Fitness values:  1.81
# 	Score:  -1.81
# 	Weighted fitness:  -1.81
# 	Stats mean 1.81 std 0.00 min 1.81 max 1.81
# 	model.params["x"] = 0.37
# 	model.params["y"] = -1.63
# --------------------
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [0.23748594877682958, 0.07854656845324959, 1.362602613109863, 3.9429832666566305], (0.937430860717788,)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2024-12-03-13H-31M-19S`.
# There are 2 valid individuals
# Mean score across population: -1.4

# %%
evolution.loadResults()
# Out:
# MainProcess root INFO     Loading results from ./data/hdf/example-2.0.hdf
# MainProcess root INFO     Analyzing trajectory results-2024-12-03-13H-31M-19S
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/example-2.0.hdf`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading trajectory `results-2024-12-03-13H-31M-19S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `config` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `derived_parameters` in mode `1`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `parameters` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `results` in mode `1`.

# %%
evolution.info(plot=True)
# Out:
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2024-12-03-13H-31M-19S
# Duration of evaluating initial population 0:00:00.756178
# Duration of evolution 0:00:05.639968
# Eval function: <function optimize_me at 0x77cab432a950>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 8
# Initial population size: 2
# Population size: 2
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x77ca961f81f0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x77ca9431e050>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x77ca9431dfc0>
# Comments: no comments
# --- Info summary ---
# Valid: 2
# Mean score (weighted fitness): -1.4
# Parameter distribution (Generation 7):
# x: 	 mean: 0.3049,	 std: 0.0674
# y: 	 mean: -0.7777,	 std: 0.8562
# --------------------
# Best 5 individuals:
# Printing 2 individuals
# Individual 0
# 	Fitness values:  0.94
# 	Score:  -0.94
# 	Weighted fitness:  -0.94
# 	Stats mean 0.94 std 0.00 min 0.94 max 0.94
# 	model.params["x"] = 0.24
# 	model.params["y"] = 0.08
# Individual 1
# 	Fitness values:  1.81
# 	Score:  -1.81
# 	Weighted fitness:  -1.81
# 	Stats mean 1.81 std 0.00 min 1.81 max 1.81
# 	model.params["x"] = 0.37
# 	model.params["y"] = -1.63
# --------------------
# /home/lena/Promotion/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# There are 2 valid individuals
# Mean score across population: -1.4

# %%
gens, all_scores = evolution.getScoresDuringEvolution(reverse=True)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4), dpi=200)   
plt.plot(gens, np.nanmean(all_scores, axis=1), marker="x")
plt.fill_between(gens, np.nanmin(all_scores, axis=1), np.nanmax(all_scores, axis=1), alpha=0.3)
plt.xlabel("Generation #")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
