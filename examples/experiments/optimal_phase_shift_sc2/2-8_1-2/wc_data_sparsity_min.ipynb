# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,19], wc.inh[0,19]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 13.905000000000001
# minima =  [ 107  246  385  524  663  802  941 1080 1219 1358 1497 1636 1775 1914
#  2053 2192 2332 2471 2610 2749 2888 3027 3166 3305 3444 3583 3722 3861
#  4000 4139 4278 4417 4556 4696 4835 4974 5113 5252 5391 5530 5669 5808
#  5947]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 results_min = read()
#
# Cell In [9], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l1_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l1_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
#options = [True, False, False, False, False, False, True, False]
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.024606911254505683
# Converged in iteration 85 with cost 0.008122675151793738 because of step counter
# Final cost : 0.008122675151793738
# Compute control for a deterministic system
# Cost in iteration 0: 0.008122675151793738
# Converged in iteration 3 with cost 0.008122675151792746 because of vanishing difference
# Final cost : 0.008122675151792746
# Compute control for a deterministic system
# Cost in iteration 0: 0.008122675151792746
# Converged in iteration 3 with cost 0.008122675151792309 because of step counter
# Final cost : 0.008122675151792309
# Compute control for a deterministic system
# Cost in iteration 0: 0.008122675151792309
# Converged in iteration 2 with cost 0.008122675151791608 because of step counter
# Final cost : 0.008122675151791608
# Compute control for a deterministic system
# Cost in iteration 0: 0.008122675151791608
# Converged in iteration 1 with cost 0.008122675151791608 because of step counter
# Final cost : 0.008122675151791608
# Compute control for a deterministic system
# Cost in iteration 0: 0.13189845135263195
# Final cost : 0.020333036070286324
# Compute control for a deterministic system
# Cost in iteration 0: 0.020333036070286324
# Converged in iteration 47 with cost 0.01999894147604378 because of vanishing difference
# Final cost : 0.01999894147604378
# Compute control for a deterministic system
# Cost in iteration 0: 0.01999894147604378
# Converged in iteration 31 with cost 0.019998941087863886 because of step counter
# Final cost : 0.019998941087863886
# Compute control for a deterministic system
# Cost in iteration 0: 0.019998941087863886
# Converged in iteration 3 with cost 0.019998941087863552 because of step counter
# Final cost : 0.019998941087863552
# Compute control for a deterministic system
# Cost in iteration 0: 0.019998941087863552
# Converged in iteration 1 with cost 0.019998941087863552 because of step counter
# Final cost : 0.019998941087863552
# Compute control for a deterministic system
# Cost in iteration 0: 0.26400057545371525
# Final cost : 0.029727087708723954
# Compute control for a deterministic system
# Cost in iteration 0: 0.029727087708723954
# Converged in iteration 96 with cost 0.02886705246053006 because of vanishing difference
# Final cost : 0.02886705246053006
# Compute control for a deterministic system
# Cost in iteration 0: 0.02886705246053006
# Converged in iteration 29 with cost 0.02886705160722821 because of step counter
# Final cost : 0.02886705160722821
# Compute control for a deterministic system
# Cost in iteration 0: 0.02886705160722821
# Converged in iteration 1 with cost 0.02886705160722821 because of step counter
# Final cost : 0.02886705160722821
# Compute control for a deterministic system
# Cost in iteration 0: 0.02886705160722821
# Converged in iteration 2 with cost 0.028867051607227988 because of step counter
# Final cost : 0.028867051607227988
# Compute control for a deterministic system
# Cost in iteration 0: 0.49956614466032134
# Final cost : 0.0421994529894137
# Compute control for a deterministic system
# Cost in iteration 0: 0.0421994529894137
# Converged in iteration 155 with cost 0.04062475014434019 because of vanishing difference
# Final cost : 0.04062475014434019
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062475014434019
# Converged in iteration 46 with cost 0.040624748617519385 because of step counter
# Final cost : 0.040624748617519385
# Compute control for a deterministic system
# Cost in iteration 0: 0.040624748617519385
# Converged in iteration 1 with cost 0.040624748617519385 because of step counter
# Final cost : 0.040624748617519385
# Compute control for a deterministic system
# Cost in iteration 0: 0.040624748617519385
# Converged in iteration 2 with cost 0.040624748617518594 because of step counter
# Final cost : 0.040624748617518594
# Compute control for a deterministic system
# Cost in iteration 0: 0.7130561672742703
# Final cost : 0.05151396496768728
# Compute control for a deterministic system
# Cost in iteration 0: 0.05151396496768728
# Converged in iteration 198 with cost 0.049386587419810384 because of vanishing difference
# Final cost : 0.049386587419810384
# Compute control for a deterministic system
# Cost in iteration 0: 0.049386587419810384
# Converged in iteration 78 with cost 0.04938657905224451 because of step counter
# Final cost : 0.04938657905224451
# Compute control for a deterministic system
# Cost in iteration 0: 0.04938657905224451
# Converged in iteration 1 with cost 0.04938657905224451 because of step counter
# Final cost : 0.04938657905224451
# Compute control for a deterministic system
# Cost in iteration 0: 0.04938657905224451
# Converged in iteration 1 with cost 0.04938657905224451 because of step counter
# Final cost : 0.04938657905224451
# Compute control for a deterministic system
# Cost in iteration 0: 1.03455384045837
# Final cost : 0.06390571534651815
# Compute control for a deterministic system
# Cost in iteration 0: 0.06390571534651815
# Cost in iteration 200: 0.06098741530509142
# Final cost : 0.06098741530509142
# Compute control for a deterministic system
# Cost in iteration 0: 0.06098741530509142
# Converged in iteration 164 with cost 0.06098680890568071 because of step counter
# Final cost : 0.06098680890568071
# Compute control for a deterministic system
# Cost in iteration 0: 0.06098680890568071
# Converged in iteration 1 with cost 0.06098680890568071 because of step counter
# Final cost : 0.06098680890568071
# Compute control for a deterministic system
# Cost in iteration 0: 0.06098680890568071
# Converged in iteration 2 with cost 0.06098680890568018 because of step counter
# Final cost : 0.06098680890568018
# Compute control for a deterministic system
# Cost in iteration 0: 1.2947565982956906
# Final cost : 0.07321677832412765
# Compute control for a deterministic system
# Cost in iteration 0: 0.07321677832412765
# Cost in iteration 200: 0.06962655846289609
# Final cost : 0.06962655846289609
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962655846289609
# Converged in iteration 49 with cost 0.0696220803479931 because of vanishing difference
# Final cost : 0.0696220803479931
# Compute control for a deterministic system
# Cost in iteration 0: 0.0696220803479931
# Cost in iteration 200: 0.06962188013489055
# Converged in iteration 288 with cost 0.06962188013342814 because of step counter
# Final cost : 0.06962188013342814
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962188013342814
# Converged in iteration 2 with cost 0.06962188013342763 because of step counter
# Final cost : 0.06962188013342763
# Compute control for a deterministic system
# Cost in iteration 0: 1.654716752786169
# Final cost : 0.08573897348594196
# Compute control for a deterministic system
# Cost in iteration 0: 0.08573897348594196
# Cost in iteration 200: 0.08106286715727548
# Final cost : 0.08106286715727548
# Compute control for a deterministic system
# Cost in iteration 0: 0.08106286715727548
# Converged in iteration 81 with cost 0.0810448828185762 because of vanishing difference
# Final cost : 0.0810448828185762
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810448828185762
# Cost in iteration 200: 0.08104441563738975
# Cost in iteration 400: 0.08104441527237198
# Final cost : 0.08104441527237198
# Compute control for a deterministic system
# Cost in iteration 0: 0.08104441527237198
# Converged in iteration 73 with cost 0.08104441527210658 because of step counter
# Final cost : 0.08104441527210658
# Compute control for a deterministic system
# Cost in iteration 0: 1.9264418617949095
# Final cost : 0.0952841483457698
# Compute control for a deterministic system
# Cost in iteration 0: 0.0952841483457698
# Cost in iteration 200: 0.08960434908457077
# Final cost : 0.08960434908457077
# Compute control for a deterministic system
# Cost in iteration 0: 0.08960434908457077
# Converged in iteration 166 with cost 0.08954037596152623 because of vanishing difference
# Final cost : 0.08954037596152623
# Compute control for a deterministic system
# Cost in iteration 0: 0.08954037596152623
# Cost in iteration 200: 0.08954027077103253
# Cost in iteration 400: 0.08954027044913387
# Final cost : 0.08954027044913387
# Compute control for a deterministic system
# Cost in iteration 0: 0.08954027044913387
# Converged in iteration 123 with cost 0.08954027044815421 because of step counter
# Final cost : 0.08954027044815421
# Compute control for a deterministic system
# Cost in iteration 0: 2.2804987478471075
# Final cost : 0.10833582947691277
# Compute control for a deterministic system
# Cost in iteration 0: 0.10833582947691277
# Cost in iteration 200: 0.10105918685332818
# Final cost : 0.10105918685332818
# Compute control for a deterministic system
# Cost in iteration 0: 0.10105918685332818
# Converged in iteration 164 with cost 0.10076832927585877 because of vanishing difference
# Final cost : 0.10076832927585877
# Compute control for a deterministic system
# Cost in iteration 0: 0.10076832927585877
# Cost in iteration 200: 0.1007671071745945
# Cost in iteration 400: 0.10076709360163257
# Final cost : 0.10076709360163257
# Compute control for a deterministic system
# Cost in iteration 0: 0.10076709360163257
# Cost in iteration 200: 0.10076709344944138
# Cost in iteration 400: 0.10076709344679365
# Converged in iteration 403 with cost 0.10076709344679222 because of vanishing difference
# Final cost : 0.10076709344679222
# Compute control for a deterministic system
# Cost in iteration 0: 2.53354070241355
# Final cost : 0.1184521674822307
# Compute control for a deterministic system
# Cost in iteration 0: 0.1184521674822307
# Cost in iteration 200: 0.1097938531895843
# Final cost : 0.1097938531895843
# Compute control for a deterministic system
# Cost in iteration 0: 0.1097938531895843
# Converged in iteration 184 with cost 0.1091059197538379 because of vanishing difference
# Final cost : 0.1091059197538379
# Compute control for a deterministic system
# Cost in iteration 0: 0.1091059197538379
# Cost in iteration 200: 0.10910388145816965
# Cost in iteration 400: 0.1091038344701946
# Final cost : 0.1091038344701946
# Compute control for a deterministic system
# Cost in iteration 0: 0.1091038344701946
# Cost in iteration 200: 0.10910383335378535
# Cost in iteration 400: 0.10910383331567194
# Converged in iteration 560 with cost 0.10910383331440514 because of vanishing difference
# Final cost : 0.10910383331440514
# Compute control for a deterministic system
# Cost in iteration 0: 2.846126165618865
# Final cost : 0.13249046153495067
# Compute control for a deterministic system
# Cost in iteration 0: 0.13249046153495067
# Cost in iteration 200: 0.12070800328460338
# Final cost : 0.12070800328460338
# Compute control for a deterministic system
# Cost in iteration 0: 0.12070800328460338
# Cost in iteration 200: 0.12009035937347277
# Final cost : 0.12009035937347277
# Compute control for a deterministic system
# Cost in iteration 0: 0.12009035937347277
# Cost in iteration 200: 0.12008782731721926
# Cost in iteration 400: 0.12008770174977391
# Final cost : 0.12008770174977391
# Compute control for a deterministic system
# Cost in iteration 0: 0.12008770174977391
# Converged in iteration 179 with cost 0.12008769495512997 because of step counter
# Final cost : 0.12008769495512997
# Compute control for a deterministic system
# Cost in iteration 0: 3.057120732872539
# Final cost : 0.14349582076799222
# Compute control for a deterministic system
# Cost in iteration 0: 0.14349582076799222
# Cost in iteration 200: 0.12904015033307328
# Final cost : 0.12904015033307328
# Compute control for a deterministic system
# Cost in iteration 0: 0.12904015033307328
# Cost in iteration 200: 0.12821852705324988
# Final cost : 0.12821852705324988
# Compute control for a deterministic system
# Cost in iteration 0: 0.12821852705324988
# Cost in iteration 200: 0.12820795248638178
# Cost in iteration 400: 0.12820716359604192
# Final cost : 0.12820716359604192
# Compute control for a deterministic system
# Cost in iteration 0: 0.12820716359604192
# Converged in iteration 192 with cost 0.128207095555575 because of vanishing difference
# Final cost : 0.128207095555575
# Compute control for a deterministic system
# Cost in iteration 0: 3.3015960611564896
# Final cost : 0.15890221787355957
# Compute control for a deterministic system
# Cost in iteration 0: 0.15890221787355957
# Cost in iteration 200: 0.13937012958696712
# Final cost : 0.13937012958696712
# Compute control for a deterministic system
# Cost in iteration 0: 0.13937012958696712
# Cost in iteration 200: 0.13887728593815718
# Final cost : 0.13887728593815718
# Compute control for a deterministic system
# Cost in iteration 0: 0.13887728593815718
# Converged in iteration 36 with cost 0.1388712087822963 because of vanishing difference
# Final cost : 0.1388712087822963
# Compute control for a deterministic system
# Cost in iteration 0: 0.1388712087822963
# Cost in iteration 200: 0.1388574982687939
# Cost in iteration 400: 0.13885749252625398
# Converged in iteration 473 with cost 0.13885749252538973 because of step counter
# Final cost : 0.13885749252538973
# Compute control for a deterministic system
# Cost in iteration 0: 3.4548111744007457
# Final cost : 0.1711041474672259
# Compute control for a deterministic system
# Cost in iteration 0: 0.1711041474672259
# Cost in iteration 200: 0.1478656949791184
# Final cost : 0.1478656949791184
# Compute control for a deterministic system
# Cost in iteration 0: 0.1478656949791184
# Cost in iteration 200: 0.14677004108058814
# Final cost : 0.14677004108058814
# Compute control for a deterministic system
# Cost in iteration 0: 0.14677004108058814
# Converged in iteration 120 with cost 0.1467380232767586 because of vanishing difference
# Final cost : 0.1467380232767586
# Compute control for a deterministic system
# Cost in iteration 0: 0.1467380232767586
# Cost in iteration 200: 0.1467223577300767
# Cost in iteration 400: 0.1467223156968018
# Cost in iteration 600: 0.14672231550621737
# Converged in iteration 662 with cost 0.14672231550540416 because of step counter
# Final cost : 0.14672231550540416
# Compute control for a deterministic system
# Cost in iteration 0: 3.616928528348779
# Final cost : 0.18844607414837738
# Compute control for a deterministic system
# Cost in iteration 0: 0.18844607414837738
# Cost in iteration 200: 0.15850546376782298
# Final cost : 0.15850546376782298
# Compute control for a deterministic system
# Cost in iteration 0: 0.15850546376782298
# Cost in iteration 200: 0.15718824623615743
# Final cost : 0.15718824623615743
# Compute control for a deterministic system
# Cost in iteration 0: 0.15718824623615743
# Converged in iteration 10 with cost 0.15718057094839455 because of vanishing difference
# Final cost : 0.15718057094839455
# Compute control for a deterministic system
# Cost in iteration 0: 0.15718057094839455
# Cost in iteration 200: 0.15708168669035916
# Cost in iteration 400: 0.15708011466656782
# Cost in iteration 600: 0.1570801025488909
# Cost in iteration 800: 0.15708010240077352
# Converged in iteration 950 with cost 0.1570801023988641 because of vanishing difference
# Final cost : 0.1570801023988641
# Compute control for a deterministic system
# Cost in iteration 0: 3.706448488034272
# Final cost : 0.2024507049144312
# Compute control for a deterministic system
# Cost in iteration 0: 0.2024507049144312
# Cost in iteration 200: 0.1678285788361174
# Final cost : 0.1678285788361174
# Compute control for a deterministic system
# Cost in iteration 0: 0.1678285788361174
# Cost in iteration 200: 0.16499654896395508
# Final cost : 0.16499654896395508
# Compute control for a deterministic system
# Cost in iteration 0: 0.16499654896395508
# Cost in iteration 200: 0.16483329115714404
# Converged in iteration 251 with cost 0.1648174385787085 because of vanishing difference
# Final cost : 0.1648174385787085
# Compute control for a deterministic system
# Cost in iteration 0: 0.1648174385787085
# Cost in iteration 200: 0.16477929673952768
# Cost in iteration 400: 0.16477847514812244
# Cost in iteration 600: 0.16477844834410588
# Cost in iteration 800: 0.1647784475903877
# Converged in iteration 971 with cost 0.1647784475713228 because of vanishing difference
# Final cost : 0.1647784475713228
# Compute control for a deterministic system
# Cost in iteration 0: 3.7834719175814238
# Final cost : 0.22287157224274912
# Compute control for a deterministic system
# Cost in iteration 0: 0.22287157224274912
# Cost in iteration 200: 0.17908960506471092
# Final cost : 0.17908960506471092
# Compute control for a deterministic system
# Cost in iteration 0: 0.17908960506471092
# Cost in iteration 200: 0.17534927996661656
# Final cost : 0.17534927996661656
# Compute control for a deterministic system
# Cost in iteration 0: 0.17534927996661656
# Cost in iteration 200: 0.17509001038458702
# Cost in iteration 400: 0.17501621235399437
# Final cost : 0.17501621235399437
# Compute control for a deterministic system
# Cost in iteration 0: 0.17501621235399437
# Cost in iteration 200: 0.17498286576320654
# Cost in iteration 400: 0.1749812600722941
# Cost in iteration 600: 0.17498111476907827
# Cost in iteration 800: 0.17498109588424524
# Cost in iteration 1000: 0.17498109362062375
# Final cost : 0.17498109362062375
# Compute control for a deterministic system
# Cost in iteration 0: 3.810379111471435
# Final cost : 0.24005710676379716
# Compute control for a deterministic system
# Cost in iteration 0: 0.24005710676379716
# Cost in iteration 200: 0.1879280039748887
# Final cost : 0.1879280039748887
# Compute control for a deterministic system
# Cost in iteration 0: 0.1879280039748887
# Cost in iteration 200: 0.18331312529300164
# Final cost : 0.18331312529300164
# Compute control for a deterministic system
# Cost in iteration 0: 0.18331312529300164
# Cost in iteration 200: 0.18283392474456311
# Converged in iteration 327 with cost 0.18272281780057026 because of vanishing difference
# Final cost : 0.18272281780057026
# Compute control for a deterministic system
# Cost in iteration 0: 0.18272281780057026
# Cost in iteration 200: 0.18260971648824287
# Cost in iteration 400: 0.18260087274504438
# Cost in iteration 600: 0.1825996136447035
# Cost in iteration 800: 0.182599462917231
# Cost in iteration 1000: 0.1825994448115746
# Final cost : 0.1825994448115746
# Compute control for a deterministic system
# Cost in iteration 0: 3.807112882011425
# Final cost : 0.31991009034553564
# Compute control for a deterministic system
# Cost in iteration 0: 0.31991009034553564
# Cost in iteration 200: 0.2327404786961595
# Final cost : 0.2327404786961595
# Compute control for a deterministic system
# Cost in iteration 0: 0.2327404786961595
# Cost in iteration 200: 0.22929265918095584
# Final cost : 0.22929265918095584
# Compute control for a deterministic system
# Cost in iteration 0: 0.22929265918095584
# Cost in iteration 200: 0.22878764146413968
# Cost in iteration 400: 0.22871930583546493
# Final cost : 0.22871930583546493
# Compute control for a deterministic system
# Cost in iteration 0: 0.22871930583546493
# Cost in iteration 200: 0.22870576126980444
# Cost in iteration 400: 0.22870454720045771
# Cost in iteration 600: 0.2287044399372833
# Cost in iteration 800: 0.22870443030306153
# Cost in iteration 1000: 0.2287044294167437
# Final cost : 0.2287044294167437
# Compute control for a deterministic system
# Cost in iteration 0: 3.7768478614431475
# Final cost : 0.28759185378987623
# Compute control for a deterministic system
# Cost in iteration 0: 0.28759185378987623
# Cost in iteration 200: 0.2225104669813327
# Final cost : 0.2225104669813327
# Compute control for a deterministic system
# Cost in iteration 0: 0.2225104669813327
# Cost in iteration 200: 0.21894575542409375
# Final cost : 0.21894575542409375
# Compute control for a deterministic system
# Cost in iteration 0: 0.21894575542409375
# Cost in iteration 200: 0.21778544811950215
# Cost in iteration 400: 0.21775043538644864
# Final cost : 0.21775043538644864
# Compute control for a deterministic system
# Cost in iteration 0: 0.21775043538644864
# Cost in iteration 200: 0.21774977707339352
# Cost in iteration 400: 0.21774974356541504
# Cost in iteration 600: 0.21774974099166086
# Cost in iteration 800: 0.21774974078948256
# Cost in iteration 1000: 0.21774974077376355
# Final cost : 0.21774974077376355
# Compute control for a deterministic system
# Cost in iteration 0: 3.7237800858343735
# Final cost : 0.2634800840687498
# Compute control for a deterministic system
# Cost in iteration 0: 0.2634800840687498
# Cost in iteration 200: 0.21031198200414664
# Final cost : 0.21031198200414664
# Compute control for a deterministic system
# Cost in iteration 0: 0.21031198200414664
# Cost in iteration 200: 0.20707329448032277
# Final cost : 0.20707329448032277
# Compute control for a deterministic system
# Cost in iteration 0: 0.20707329448032277
# Cost in iteration 200: 0.2069029120075141
# Converged in iteration 263 with cost 0.20689431375791834 because of vanishing difference
# Final cost : 0.20689431375791834
# Compute control for a deterministic system
# Cost in iteration 0: 0.20689431375791834
# Cost in iteration 200: 0.20688025400336726
# Cost in iteration 400: 0.206879590519308
# Cost in iteration 600: 0.2068795493114463
# Cost in iteration 800: 0.20687954662798186
# Cost in iteration 1000: 0.2068795464540967
# Final cost : 0.2068795464540967
# Compute control for a deterministic system
# Cost in iteration 0: 3.618452547032667
# Final cost : 0.23537594729352299
# Compute control for a deterministic system
# Cost in iteration 0: 0.23537594729352299
# Cost in iteration 200: 0.19713877329973428
# Final cost : 0.19713877329973428
# Compute control for a deterministic system
# Cost in iteration 0: 0.19713877329973428
# Cost in iteration 200: 0.1930768422018943
# Final cost : 0.1930768422018943
# Compute control for a deterministic system
# Cost in iteration 0: 0.1930768422018943
# Converged in iteration 170 with cost 0.19256012768714817 because of vanishing difference
# Final cost : 0.19256012768714817
# Compute control for a deterministic system
# Cost in iteration 0: 0.19256012768714817
# Cost in iteration 200: 0.1925441237172993
# Cost in iteration 400: 0.19254353514146777
# Cost in iteration 600: 0.19254350638048515
# Cost in iteration 800: 0.19254350496763448
# Cost in iteration 1000: 0.19254350489670116
# Final cost : 0.19254350489670116
# Compute control for a deterministic system
# Cost in iteration 0: 3.5139852361296713
# Final cost : 0.21651460815247764
# Compute control for a deterministic system
# Cost in iteration 0: 0.21651460815247764
# Cost in iteration 200: 0.18717345472046132
# Final cost : 0.18717345472046132
# Compute control for a deterministic system
# Cost in iteration 0: 0.18717345472046132
# Cost in iteration 200: 0.18487120460189646
# Final cost : 0.18487120460189646
# Compute control for a deterministic system
# Cost in iteration 0: 0.18487120460189646
# Cost in iteration 200: 0.18194897587996747
# Converged in iteration 243 with cost 0.18191435714951776 because of vanishing difference
# Final cost : 0.18191435714951776
# Compute control for a deterministic system
# Cost in iteration 0: 0.18191435714951776
# Cost in iteration 200: 0.18190905834529733
# Cost in iteration 400: 0.1819088880934821
# Cost in iteration 600: 0.18190888134309066
# Cost in iteration 800: 0.18190888107830888
# Cost in iteration 1000: 0.1819088810676637
# Final cost : 0.1819088810676637
# Compute control for a deterministic system
# Cost in iteration 0: 3.3414273521007978
# Final cost : 0.19371056302777154
# Compute control for a deterministic system
# Cost in iteration 0: 0.19371056302777154
# Cost in iteration 200: 0.1713782735405164
# Final cost : 0.1713782735405164
# Compute control for a deterministic system
# Cost in iteration 0: 0.1713782735405164
# Cost in iteration 200: 0.16915826210508722
# Final cost : 0.16915826210508722
# Compute control for a deterministic system
# Cost in iteration 0: 0.16915826210508722
# Converged in iteration 107 with cost 0.16787925713604734 because of vanishing difference
# Final cost : 0.16787925713604734
# Compute control for a deterministic system
# Cost in iteration 0: 0.16787925713604734
# Cost in iteration 200: 0.1678751493148959
# Cost in iteration 400: 0.16787505274186196
# Cost in iteration 600: 0.16787505033922354
# Cost in iteration 800: 0.16787505027556462
# Converged in iteration 972 with cost 0.16787505027391236 because of vanishing difference
# Final cost : 0.16787505027391236
# Compute control for a deterministic system
# Cost in iteration 0: 3.1876644794542615
# Final cost : 0.17807896215633004
# Compute control for a deterministic system
# Cost in iteration 0: 0.17807896215633004
# Cost in iteration 200: 0.1599917747108916
# Final cost : 0.1599917747108916
# Compute control for a deterministic system
# Cost in iteration 0: 0.1599917747108916
# Cost in iteration 200: 0.15776657659099919
# Final cost : 0.15776657659099919
# Compute control for a deterministic system
# Cost in iteration 0: 0.15776657659099919
# Converged in iteration 77 with cost 0.1574585149097936 because of vanishing difference
# Final cost : 0.1574585149097936
# Compute control for a deterministic system
# Cost in iteration 0: 0.1574585149097936
# Cost in iteration 200: 0.1574535246987969
# Cost in iteration 400: 0.15745345088806353
# Cost in iteration 600: 0.15745344978360398
# Cost in iteration 800: 0.1574534497659739
# Converged in iteration 889 with cost 0.1574534497657337 because of step counter
# Final cost : 0.1574534497657337
# Compute control for a deterministic system
# Cost in iteration 0: 2.9514390330241427
# Final cost : 0.15886838762155542
# Compute control for a deterministic system
# Cost in iteration 0: 0.15886838762155542
# Cost in iteration 200: 0.14585325218764394
# Final cost : 0.14585325218764394
# Compute control for a deterministic system
# Cost in iteration 0: 0.14585325218764394
# Cost in iteration 200: 0.14370859663145064
# Final cost : 0.14370859663145064
# Compute control for a deterministic system
# Cost in iteration 0: 0.14370859663145064
# Converged in iteration 22 with cost 0.1437019143963519 because of vanishing difference
# Final cost : 0.1437019143963519
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437019143963519
# Cost in iteration 200: 0.14369259699002465
# Cost in iteration 400: 0.14369252289774026
# Cost in iteration 600: 0.14369252199683938
# Converged in iteration 786 with cost 0.14369252198528074 because of vanishing difference
# Final cost : 0.14369252198528074
# Compute control for a deterministic system
# Cost in iteration 0: 2.7521105998583044
# Final cost : 0.1454953040062747
# Compute control for a deterministic system
# Cost in iteration 0: 0.1454953040062747
# Cost in iteration 200: 0.13574512799093702
# Final cost : 0.13574512799093702
# Compute control for a deterministic system
# Cost in iteration 0: 0.13574512799093702
# Cost in iteration 200: 0.13349319653593789
# Final cost : 0.13349319653593789
# Compute control for a deterministic system
# Cost in iteration 0: 0.13349319653593789
# Converged in iteration 42 with cost 0.13347295180268623 because of vanishing difference
# Final cost : 0.13347295180268623
# Compute control for a deterministic system
# Cost in iteration 0: 0.13347295180268623
# Cost in iteration 200: 0.13347159191153155
# Cost in iteration 400: 0.1334715870602857
# Converged in iteration 516 with cost 0.133471587045555 because of vanishing difference
# Final cost : 0.133471587045555
# Compute control for a deterministic system
# Cost in iteration 0: 2.4594946250845995
# Final cost : 0.12880320419723298
# Compute control for a deterministic system
# Cost in iteration 0: 0.12880320419723298
# Cost in iteration 200: 0.12143893309573009
# Final cost : 0.12143893309573009
# Compute control for a deterministic system
# Cost in iteration 0: 0.12143893309573009
# Cost in iteration 200: 0.11997812060660518
# Final cost : 0.11997812060660518
# Compute control for a deterministic system
# Cost in iteration 0: 0.11997812060660518
# Converged in iteration 9 with cost 0.1199777952840807 because of vanishing difference
# Final cost : 0.1199777952840807
# Compute control for a deterministic system
# Cost in iteration 0: 0.1199777952840807
# Cost in iteration 200: 0.11997578617098983
# Cost in iteration 400: 0.1199757837743116
# Converged in iteration 548 with cost 0.11997578377096524 because of step counter
# Final cost : 0.11997578377096524
# Compute control for a deterministic system
# Cost in iteration 0: 2.2225591243420206
# Final cost : 0.11699224498761805
# Compute control for a deterministic system
# Cost in iteration 0: 0.11699224498761805
# Cost in iteration 200: 0.11109498211756132
# Final cost : 0.11109498211756132
# Compute control for a deterministic system
# Cost in iteration 0: 0.11109498211756132
# Cost in iteration 200: 0.10995306854487381
# Final cost : 0.10995306854487381
# Compute control for a deterministic system
# Cost in iteration 0: 0.10995306854487381
# Cost in iteration 200: 0.10995241331211493
# Converged in iteration 255 with cost 0.10995241331135795 because of step counter
# Final cost : 0.10995241331135795
# Compute control for a deterministic system
# Cost in iteration 0: 0.10995241331135795
# Converged in iteration 1 with cost 0.10995241331135795 because of step counter
# Final cost : 0.10995241331135795
# Compute control for a deterministic system
# Cost in iteration 0: 1.8888215480029982
# Final cost : 0.10199653949318145
# Compute control for a deterministic system
# Cost in iteration 0: 0.10199653949318145
# Cost in iteration 200: 0.09710192409316505
# Final cost : 0.09710192409316505
# Compute control for a deterministic system
# Cost in iteration 0: 0.09710192409316505
# Converged in iteration 181 with cost 0.0967188327650362 because of vanishing difference
# Final cost : 0.0967188327650362
# Compute control for a deterministic system
# Cost in iteration 0: 0.0967188327650362
# Converged in iteration 165 with cost 0.09671879370629351 because of vanishing difference
# Final cost : 0.09671879370629351
# Compute control for a deterministic system
# Cost in iteration 0: 0.09671879370629351
# Converged in iteration 9 with cost 0.09671879370628472 because of step counter
# Final cost : 0.09671879370628472
# Compute control for a deterministic system
# Cost in iteration 0: 1.630171472828498
# Final cost : 0.09119680128987691
# Compute control for a deterministic system
# Cost in iteration 0: 0.09119680128987691
# Cost in iteration 200: 0.08689570890072107
# Final cost : 0.08689570890072107
# Compute control for a deterministic system
# Cost in iteration 0: 0.08689570890072107
# Converged in iteration 100 with cost 0.08689141804091301 because of vanishing difference
# Final cost : 0.08689141804091301
# Compute control for a deterministic system
# Cost in iteration 0: 0.08689141804091301
# Converged in iteration 161 with cost 0.0868913710796498 because of step counter
# Final cost : 0.0868913710796498
# Compute control for a deterministic system
# Cost in iteration 0: 0.0868913710796498
# Converged in iteration 1 with cost 0.0868913710796498 because of step counter
# Final cost : 0.0868913710796498
# Compute control for a deterministic system
# Cost in iteration 0: 1.2836037005380547
# Final cost : 0.07724162693815995
# Compute control for a deterministic system
# Cost in iteration 0: 0.07724162693815995
# Cost in iteration 200: 0.07391871050462676
# Final cost : 0.07391871050462676
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391871050462676
# Converged in iteration 21 with cost 0.07391853615526235 because of vanishing difference
# Final cost : 0.07391853615526235
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391853615526235
# Converged in iteration 169 with cost 0.07391843074052755 because of step counter
# Final cost : 0.07391843074052755
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391843074052755
# Converged in iteration 3 with cost 0.07391843074052636 because of step counter
# Final cost : 0.07391843074052636
# Compute control for a deterministic system
# Cost in iteration 0: 1.0301606380511534
# Final cost : 0.06702097530050846
# Compute control for a deterministic system
# Cost in iteration 0: 0.06702097530050846
# Cost in iteration 200: 0.06428676871209957
# Final cost : 0.06428676871209957
# Compute control for a deterministic system
# Cost in iteration 0: 0.06428676871209957
# Converged in iteration 2 with cost 0.0642867669807486 because of vanishing difference
# Final cost : 0.0642867669807486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0642867669807486
# Converged in iteration 123 with cost 0.06428674983842246 because of step counter
# Final cost : 0.06428674983842246
# Compute control for a deterministic system
# Cost in iteration 0: 0.06428674983842246
# Converged in iteration 6 with cost 0.06428674983842049 because of step counter
# Final cost : 0.06428674983842049
# Compute control for a deterministic system
# Cost in iteration 0: 0.7137356759607103
# Final cost : 0.05362099376661945
# Compute control for a deterministic system
# Cost in iteration 0: 0.05362099376661945
# Converged in iteration 182 with cost 0.051576473059109014 because of vanishing difference
# Final cost : 0.051576473059109014
# Compute control for a deterministic system
# Cost in iteration 0: 0.051576473059109014
# Converged in iteration 130 with cost 0.051576472092071446 because of step counter
# Final cost : 0.051576472092071446
# Compute control for a deterministic system
# Cost in iteration 0: 0.051576472092071446
# Converged in iteration 1 with cost 0.051576472092071446 because of step counter
# Final cost : 0.051576472092071446
# Compute control for a deterministic system
# Cost in iteration 0: 0.051576472092071446
# Converged in iteration 2 with cost 0.05157647209207143 because of step counter
# Final cost : 0.05157647209207143
# Compute control for a deterministic system
# Cost in iteration 0: 0.5018222454688425
# Final cost : 0.04369580324866019
# Compute control for a deterministic system
# Cost in iteration 0: 0.04369580324866019
# Converged in iteration 125 with cost 0.04214437807073055 because of vanishing difference
# Final cost : 0.04214437807073055
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214437807073055
# Converged in iteration 112 with cost 0.04214437521400933 because of step counter
# Final cost : 0.04214437521400933
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214437521400933
# Converged in iteration 1 with cost 0.04214437521400933 because of step counter
# Final cost : 0.04214437521400933
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214437521400933
# Converged in iteration 1 with cost 0.04214437521400933 because of step counter
# Final cost : 0.04214437521400933
# Compute control for a deterministic system
# Cost in iteration 0: 0.2665790748397163
# Final cost : 0.03059507391784124
# Compute control for a deterministic system
# Cost in iteration 0: 0.03059507391784124
# Converged in iteration 87 with cost 0.02970645888257571 because of vanishing difference
# Final cost : 0.02970645888257571
# Compute control for a deterministic system
# Cost in iteration 0: 0.02970645888257571
# Converged in iteration 74 with cost 0.0297064573682886 because of step counter
# Final cost : 0.0297064573682886
# Compute control for a deterministic system
# Cost in iteration 0: 0.0297064573682886
# Converged in iteration 2 with cost 0.029706457368287965 because of step counter
# Final cost : 0.029706457368287965
# Compute control for a deterministic system
# Cost in iteration 0: 0.029706457368287965
# Converged in iteration 1 with cost 0.029706457368287965 because of step counter
# Final cost : 0.029706457368287965
# Compute control for a deterministic system
# Cost in iteration 0: 0.1339885067152939
# Final cost : 0.02086551822858599
# Compute control for a deterministic system
# Cost in iteration 0: 0.02086551822858599
# Converged in iteration 57 with cost 0.02048618811145834 because of vanishing difference
# Final cost : 0.02048618811145834
# Compute control for a deterministic system
# Cost in iteration 0: 0.02048618811145834
# Converged in iteration 50 with cost 0.0204861874920823 because of vanishing difference
# Final cost : 0.0204861874920823
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204861874920823
# Converged in iteration 2 with cost 0.020486187492080955 because of step counter
# Final cost : 0.020486187492080955
# Compute control for a deterministic system
# Cost in iteration 0: 0.020486187492080955
# Converged in iteration 1 with cost 0.020486187492080955 because of step counter
# Final cost : 0.020486187492080955
# Compute control for a deterministic system
# Cost in iteration 0: 0.02558980286052459
# Converged in iteration 90 with cost 0.008347572181683886 because of step counter
# Final cost : 0.008347572181683886
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181683886
# Converged in iteration 6 with cost 0.008347572181682078 because of step counter
# Final cost : 0.008347572181682078
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181682078
# Converged in iteration 2 with cost 0.00834757218168203 because of step counter
# Final cost : 0.00834757218168203
# Compute control for a deterministic system
# Cost in iteration 0: 0.00834757218168203
# Converged in iteration 3 with cost 0.008347572181681431 because of step counter
# Final cost : 0.008347572181681431
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181681431
# Converged in iteration 1 with cost 0.008347572181681431 because of step counter
# Final cost : 0.008347572181681431
# Compute control for a deterministic system
# Cost in iteration 0: 9.927079178182924e-06
# Converged in iteration 1 with cost 9.927079178182924e-06 because of step counter
# Final cost : 9.927079178182924e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06477994410688662
# Converged in iteration 187 with cost 0.01999894021496425 because of vanishing difference
# Final cost : 0.01999894021496425
# Compute control for a deterministic system
# Cost in iteration 0: 0.01999894021496425
# Converged in iteration 37 with cost 0.019998939933773083 because of step counter
# Final cost : 0.019998939933773083
# Compute control for a deterministic system
# Cost in iteration 0: 0.019998939933773083
# Converged in iteration 1 with cost 0.019998939933773083 because of step counter
# Final cost : 0.019998939933773083
# Compute control for a deterministic system
# Cost in iteration 0: 0.019998939933773083
# Converged in iteration 1 with cost 0.019998939933773083 because of step counter
# Final cost : 0.019998939933773083
# Compute control for a deterministic system
# Cost in iteration 0: 0.019998939933773083
# Converged in iteration 1 with cost 0.019998939933773083 because of step counter
# Final cost : 0.019998939933773083
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.04890479718748468
# Cost in iteration 200: 0.028867054417097037
# Final cost : 0.028867054417097037
# Compute control for a deterministic system
# Cost in iteration 0: 0.028867054417097037
# Converged in iteration 6 with cost 0.028867052221510422 because of vanishing difference
# Final cost : 0.028867052221510422
# Compute control for a deterministic system
# Cost in iteration 0: 0.028867052221510422
# Converged in iteration 23 with cost 0.028867052019790364 because of step counter
# Final cost : 0.028867052019790364
# Compute control for a deterministic system
# Cost in iteration 0: 0.028867052019790364
# Converged in iteration 1 with cost 0.028867052019790364 because of step counter
# Final cost : 0.028867052019790364
# Compute control for a deterministic system
# Cost in iteration 0: 0.028867052019790364
# Converged in iteration 1 with cost 0.028867052019790364 because of step counter
# Final cost : 0.028867052019790364
# Compute control for a deterministic system
# Cost in iteration 0: 0.08481093092695141
# Cost in iteration 200: 0.040624979289005055
# Final cost : 0.040624979289005055
# Compute control for a deterministic system
# Cost in iteration 0: 0.040624979289005055
# Converged in iteration 56 with cost 0.04062474918314591 because of vanishing difference
# Final cost : 0.04062474918314591
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062474918314591
# Converged in iteration 45 with cost 0.04062474867910783 because of step counter
# Final cost : 0.04062474867910783
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062474867910783
# Converged in iteration 1 with cost 0.04062474867910783 because of step counter
# Final cost : 0.04062474867910783
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062474867910783
# Converged in iteration 1 with cost 0.04062474867910783 because of step counter
# Final cost : 0.04062474867910783
# Compute control for a deterministic system
# Cost in iteration 0: 0.08002426204113623
# Cost in iteration 200: 0.049387288589917255
# Final cost : 0.049387288589917255
# Compute control for a deterministic system
# Cost in iteration 0: 0.049387288589917255
# Converged in iteration 64 with cost 0.049386583126034334 because of vanishing difference
# Final cost : 0.049386583126034334
# Compute control for a deterministic system
# Cost in iteration 0: 0.049386583126034334
# Converged in iteration 76 with cost 0.04938657904103358 because of step counter
# Final cost : 0.04938657904103358
# Compute control for a deterministic system
# Cost in iteration 0: 0.04938657904103358
# Converged in iteration 1 with cost 0.04938657904103358 because of step counter
# Final cost : 0.04938657904103358
# Compute control for a deterministic system
# Cost in iteration 0: 0.04938657904103358
# Converged in iteration 2 with cost 0.049386579041033545 because of step counter
# Final cost : 0.049386579041033545
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.11061658025090464
# Cost in iteration 200: 0.060991687082529014
# Final cost : 0.060991687082529014
# Compute control for a deterministic system
# Cost in iteration 0: 0.060991687082529014
# Converged in iteration 114 with cost 0.060986816108765274 because of vanishing difference
# Final cost : 0.060986816108765274
# Compute control for a deterministic system
# Cost in iteration 0: 0.060986816108765274
# Converged in iteration 133 with cost 0.06098680571550824 because of step counter
# Final cost : 0.06098680571550824
# Compute control for a deterministic system
# Cost in iteration 0: 0.06098680571550824
# Converged in iteration 1 with cost 0.06098680571550824 because of step counter
# Final cost : 0.06098680571550824
# Compute control for a deterministic system
# Cost in iteration 0: 0.06098680571550824
# Converged in iteration 1 with cost 0.06098680571550824 because of step counter
# Final cost : 0.06098680571550824
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.1056487410795878
# Cost in iteration 200: 0.06962894574420977
# Final cost : 0.06962894574420977
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962894574420977
# Converged in iteration 132 with cost 0.06962188864801455 because of vanishing difference
# Final cost : 0.06962188864801455
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962188864801455
# Cost in iteration 200: 0.06962186514903128
# Final cost : 0.06962186514903128
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962186514903128
# Converged in iteration 5 with cost 0.06962186514903053 because of step counter
# Final cost : 0.06962186514903053
# Compute control for a deterministic system
# Cost in iteration 0: 0.06962186514903053
# Converged in iteration 3 with cost 0.06962186514902981 because of step counter
# Final cost : 0.06962186514902981
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.11970304273098797
# Cost in iteration 200: 0.08107097344965172
# Final cost : 0.08107097344965172
# Compute control for a deterministic system
# Cost in iteration 0: 0.08107097344965172
# Cost in iteration 200: 0.08104445260388235
# Final cost : 0.08104445260388235
# Compute control for a deterministic system
# Cost in iteration 0: 0.08104445260388235
# Cost in iteration 200: 0.08104440726148035
# Final cost : 0.08104440726148035
# Compute control for a deterministic system
# Cost in iteration 0: 0.08104440726148035
# Converged in iteration 79 with cost 0.0810444072610862 because of step counter
# Final cost : 0.0810444072610862
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810444072610862
# Converged in iteration 15 with cost 0.08104440726106797 because of step counter
# Final cost : 0.08104440726106797
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.09798394987835815
# Cost in iteration 200: 0.08956393987809891
# Final cost : 0.08956393987809891
# Compute control for a deterministic system
# Cost in iteration 0: 0.08956393987809891
# Cost in iteration 200: 0.08954036951187593
# Final cost : 0.08954036951187593
# Compute control for a deterministic system
# Cost in iteration 0: 0.08954036951187593
# Converged in iteration 5 with cost 0.08954035467142854 because of vanishing difference
# Final cost : 0.08954035467142854
# Compute control for a deterministic system
# Cost in iteration 0: 0.08954035467142854
# Cost in iteration 200: 0.08954027125417906
# Cost in iteration 400: 0.08954027100018204
# Final cost : 0.08954027100018204
# Compute control for a deterministic system
# Cost in iteration 0: 0.08954027100018204
# Converged in iteration 120 with cost 0.08954027099941454 because of step counter
# Final cost : 0.08954027099941454
# Compute control for a deterministic system
# Cost in iteration 0: 0.12875251198268634
# Cost in iteration 200: 0.10083454665216503
# Final cost : 0.10083454665216503
# Compute control for a deterministic system
# Cost in iteration 0: 0.10083454665216503
# Cost in iteration 200: 0.10076794415138611
# Final cost : 0.10076794415138611
# Compute control for a deterministic system
# Cost in iteration 0: 0.10076794415138611
# Cost in iteration 200: 0.1007670868854002
# Final cost : 0.1007670868854002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1007670868854002
# Cost in iteration 200: 0.1007670853088781
# Cost in iteration 400: 0.10076708529087311
# Final cost : 0.10076708529087311
# Compute control for a deterministic system
# Cost in iteration 0: 0.10076708529087311
# Converged in iteration 77 with cost 0.10076708529067219 because of step counter
# Final cost : 0.10076708529067219
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.12102773747943381
# Cost in iteration 200: 0.10915666159474381
# Final cost : 0.10915666159474381
# Compute control for a deterministic system
# Cost in iteration 0: 0.10915666159474381
# Cost in iteration 200: 0.10910529890172624
# Final cost : 0.10910529890172624
# Compute control for a deterministic system
# Cost in iteration 0: 0.10910529890172624
# Converged in iteration 17 with cost 0.10910479059161644 because of vanishing difference
# Final cost : 0.10910479059161644
# Compute control for a deterministic system
# Cost in iteration 0: 0.10910479059161644
# Cost in iteration 200: 0.10910385419393664
# Cost in iteration 400: 0.10910383262452203
# Final cost : 0.10910383262452203
# Compute control for a deterministic system
# Cost in iteration 0: 0.10910383262452203
# Cost in iteration 200: 0.10910383212108368
# Cost in iteration 400: 0.10910383210372278
# Converged in iteration 516 with cost 0.10910383210309911 because of step counter
# Final cost : 0.10910383210309911
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.22064624126944743
# Cost in iteration 200: 0.12021531527220776
# Final cost : 0.12021531527220776
# Compute control for a deterministic system
# Cost in iteration 0: 0.12021531527220776
# Cost in iteration 200: 0.1200930094979129
# Final cost : 0.1200930094979129
# Compute control for a deterministic system
# Cost in iteration 0: 0.1200930094979129
# Converged in iteration 64 with cost 0.12008925913509433 because of vanishing difference
# Final cost : 0.12008925913509433
# Compute control for a deterministic system
# Cost in iteration 0: 0.12008925913509433
# Cost in iteration 200: 0.12008776609079926
# Cost in iteration 400: 0.12008769201578312
# Final cost : 0.12008769201578312
# Compute control for a deterministic system
# Cost in iteration 0: 0.12008769201578312
# Converged in iteration 177 with cost 0.12008768807900728 because of step counter
# Final cost : 0.12008768807900728
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# ...
# Converged in iteration 128 with cost 0.19255634861313614 because of vanishing difference
# Final cost : 0.19255634861313614
# Compute control for a deterministic system
# Cost in iteration 0: 0.19255634861313614
# Cost in iteration 200: 0.1925440798041877
# Cost in iteration 400: 0.19254358912454
# Cost in iteration 600: 0.1925435656383575
# Cost in iteration 800: 0.19254356446206478
# Cost in iteration 1000: 0.19254356440398318
# Final cost : 0.19254356440398318
# Compute control for a deterministic system
# Cost in iteration 0: 3.5139852385933894
# Cost in iteration 200: 0.19808543573307236
# Final cost : 0.19808543573307236
# Compute control for a deterministic system
# Cost in iteration 0: 0.19808543573307236
# Cost in iteration 200: 0.18483288567673636
# Final cost : 0.18483288567673636
# Compute control for a deterministic system
# Cost in iteration 0: 0.18483288567673636
# Cost in iteration 200: 0.18196055515546455
# Final cost : 0.18196055515546455
# Compute control for a deterministic system
# Cost in iteration 0: 0.18196055515546455
# Converged in iteration 88 with cost 0.18191619912369414 because of vanishing difference
# Final cost : 0.18191619912369414
# Compute control for a deterministic system
# Cost in iteration 0: 0.18191619912369414
# Cost in iteration 200: 0.18190911491379005
# Cost in iteration 400: 0.1819088809675743
# Cost in iteration 600: 0.18190887188684346
# Cost in iteration 800: 0.18190887152924276
# Cost in iteration 1000: 0.18190887151503024
# Final cost : 0.18190887151503024
# Compute control for a deterministic system
# Cost in iteration 0: 3.341427353719275
# Cost in iteration 200: 0.18008339933091716
# Final cost : 0.18008339933091716
# Compute control for a deterministic system
# Cost in iteration 0: 0.18008339933091716
# Cost in iteration 200: 0.17083913750091134
# Final cost : 0.17083913750091134
# Compute control for a deterministic system
# Cost in iteration 0: 0.17083913750091134
# Cost in iteration 200: 0.16825983476635217
# Final cost : 0.16825983476635217
# Compute control for a deterministic system
# Cost in iteration 0: 0.16825983476635217
# Converged in iteration 66 with cost 0.16788645138033956 because of vanishing difference
# Final cost : 0.16788645138033956
# Compute control for a deterministic system
# Cost in iteration 0: 0.16788645138033956
# Cost in iteration 200: 0.16787527095897412
# Cost in iteration 400: 0.16787505285188892
# Cost in iteration 600: 0.1678750473589478
# Cost in iteration 800: 0.1678750472158136
# Converged in iteration 990 with cost 0.1678750472119013 because of vanishing difference
# Final cost : 0.1678750472119013
# Compute control for a deterministic system
# Cost in iteration 0: 3.1876644789496043
# Cost in iteration 200: 0.16740723531406382
# Final cost : 0.16740723531406382
# Compute control for a deterministic system
# Cost in iteration 0: 0.16740723531406382
# Cost in iteration 200: 0.1602451837995816
# Final cost : 0.1602451837995816
# Compute control for a deterministic system
# Cost in iteration 0: 0.1602451837995816
# Cost in iteration 200: 0.15750050583667047
# Final cost : 0.15750050583667047
# Compute control for a deterministic system
# Cost in iteration 0: 0.15750050583667047
# Converged in iteration 40 with cost 0.15746120800045288 because of vanishing difference
# Final cost : 0.15746120800045288
# Compute control for a deterministic system
# Cost in iteration 0: 0.15746120800045288
# Cost in iteration 200: 0.15745356659415952
# Cost in iteration 400: 0.1574534690175275
# Cost in iteration 600: 0.15745346751610903
# Cost in iteration 800: 0.15745346749237735
# Converged in iteration 895 with cost 0.15745346749205064 because of step counter
# Final cost : 0.15745346749205064
# Compute control for a deterministic system
# Cost in iteration 0: 2.951439023839309
# Cost in iteration 200: 0.1513973406380385
# Final cost : 0.1513973406380385
# Compute control for a deterministic system
# Cost in iteration 0: 0.1513973406380385
# Cost in iteration 200: 0.14621248966871495
# Final cost : 0.14621248966871495
# Compute control for a deterministic system
# Cost in iteration 0: 0.14621248966871495
# Cost in iteration 200: 0.14390682693593246
# Final cost : 0.14390682693593246
# Compute control for a deterministic system
# Cost in iteration 0: 0.14390682693593246
# Converged in iteration 49 with cost 0.14370293374411544 because of vanishing difference
# Final cost : 0.14370293374411544
# Compute control for a deterministic system
# Cost in iteration 0: 0.14370293374411544
# Cost in iteration 200: 0.14369260645458704
# Cost in iteration 400: 0.1436925287132046
# Cost in iteration 600: 0.14369252770130467
# Converged in iteration 768 with cost 0.1436925276885927 because of vanishing difference
# Final cost : 0.1436925276885927
# Compute control for a deterministic system
# Cost in iteration 0: 2.7521105750796773
# Cost in iteration 200: 0.13990129667580276
# Final cost : 0.13990129667580276
# Compute control for a deterministic system
# Cost in iteration 0: 0.13990129667580276
# Cost in iteration 200: 0.13536286212637638
# Final cost : 0.13536286212637638
# Compute control for a deterministic system
# Cost in iteration 0: 0.13536286212637638
# Cost in iteration 200: 0.13347769426769748
# Final cost : 0.13347769426769748
# Compute control for a deterministic system
# Cost in iteration 0: 0.13347769426769748
# Converged in iteration 35 with cost 0.13347293272177382 because of vanishing difference
# Final cost : 0.13347293272177382
# Compute control for a deterministic system
# Cost in iteration 0: 0.13347293272177382
# Cost in iteration 200: 0.1334716290333885
# Cost in iteration 400: 0.133471623968232
# Cost in iteration 600: 0.1334716239523431
# Converged in iteration 617 with cost 0.133471623952324 because of step counter
# Final cost : 0.133471623952324
# Compute control for a deterministic system
# Cost in iteration 0: 2.459494620234501
# Cost in iteration 200: 0.12512977179903656
# Final cost : 0.12512977179903656
# Compute control for a deterministic system
# Cost in iteration 0: 0.12512977179903656
# Cost in iteration 200: 0.12118386281882103
# Final cost : 0.12118386281882103
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118386281882103
# Cost in iteration 200: 0.11997628453917444
# Final cost : 0.11997628453917444
# Compute control for a deterministic system
# Cost in iteration 0: 0.11997628453917444
# Cost in iteration 200: 0.11997572544152789
# Converged in iteration 244 with cost 0.11997572543897157 because of vanishing difference
# Final cost : 0.11997572543897157
# Compute control for a deterministic system
# Cost in iteration 0: 0.11997572543897157
# Converged in iteration 36 with cost 0.11997572543888275 because of step counter
# Final cost : 0.11997572543888275
# Compute control for a deterministic system
# Cost in iteration 0: 2.222559106255545
# Cost in iteration 200: 0.11437464092815379
# Final cost : 0.11437464092815379
# Compute control for a deterministic system
# Cost in iteration 0: 0.11437464092815379
# Cost in iteration 200: 0.11052545083869482
# Final cost : 0.11052545083869482
# Compute control for a deterministic system
# Cost in iteration 0: 0.11052545083869482
# Cost in iteration 200: 0.10995253845767541
# Final cost : 0.10995253845767541
# Compute control for a deterministic system
# Cost in iteration 0: 0.10995253845767541
# Cost in iteration 200: 0.10995241516374617
# Converged in iteration 224 with cost 0.10995241516359668 because of step counter
# Final cost : 0.10995241516359668
# Compute control for a deterministic system
# Cost in iteration 0: 0.10995241516359668
# Converged in iteration 1 with cost 0.10995241516359668 because of step counter
# Final cost : 0.10995241516359668
# Compute control for a deterministic system
# Cost in iteration 0: 1.888821510893953
# Cost in iteration 200: 0.10033452422655705
# Final cost : 0.10033452422655705
# Compute control for a deterministic system
# Cost in iteration 0: 0.10033452422655705
# Cost in iteration 200: 0.09672483891095504
# Final cost : 0.09672483891095504
# Compute control for a deterministic system
# Cost in iteration 0: 0.09672483891095504
# Converged in iteration 118 with cost 0.09671884632916668 because of vanishing difference
# Final cost : 0.09671884632916668
# Compute control for a deterministic system
# Cost in iteration 0: 0.09671884632916668
# Converged in iteration 169 with cost 0.09671879420338711 because of step counter
# Final cost : 0.09671879420338711
# Compute control for a deterministic system
# Cost in iteration 0: 0.09671879420338711
# Converged in iteration 1 with cost 0.09671879420338711 because of step counter
# Final cost : 0.09671879420338711
# Compute control for a deterministic system
# Cost in iteration 0: 1.6301714658350783
# Cost in iteration 200: 0.08998989403869982
# Final cost : 0.08998989403869982
# Compute control for a deterministic system
# Cost in iteration 0: 0.08998989403869982
# Cost in iteration 200: 0.08689190922499901
# Final cost : 0.08689190922499901
# Compute control for a deterministic system
# Cost in iteration 0: 0.08689190922499901
# Converged in iteration 35 with cost 0.08689150119525425 because of vanishing difference
# Final cost : 0.08689150119525425
# Compute control for a deterministic system
# Cost in iteration 0: 0.08689150119525425
# Converged in iteration 166 with cost 0.0868913730311098 because of step counter
# Final cost : 0.0868913730311098
# Compute control for a deterministic system
# Cost in iteration 0: 0.0868913730311098
# Converged in iteration 3 with cost 0.08689137303110955 because of step counter
# Final cost : 0.08689137303110955
# Compute control for a deterministic system
# Cost in iteration 0: 1.2836036854509967
# Cost in iteration 200: 0.07636466641809808
# Final cost : 0.07636466641809808
# Compute control for a deterministic system
# Cost in iteration 0: 0.07636466641809808
# Cost in iteration 200: 0.07391845070276981
# Final cost : 0.07391845070276981
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391845070276981
# Cost in iteration 200: 0.07391842248503926
# Final cost : 0.07391842248503926
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391842248503926
# Converged in iteration 35 with cost 0.07391842248483729 because of step counter
# Final cost : 0.07391842248483729
# Compute control for a deterministic system
# Cost in iteration 0: 0.07391842248483729
# Converged in iteration 1 with cost 0.07391842248483729 because of step counter
# Final cost : 0.07391842248483729
# Compute control for a deterministic system
# Cost in iteration 0: 1.0301605439514412
# Cost in iteration 200: 0.06625714988866374
# Final cost : 0.06625714988866374
# Compute control for a deterministic system
# Cost in iteration 0: 0.06625714988866374
# Converged in iteration 186 with cost 0.0642867475997618 because of vanishing difference
# Final cost : 0.0642867475997618
# Compute control for a deterministic system
# Cost in iteration 0: 0.0642867475997618
# Converged in iteration 170 with cost 0.06428674334077032 because of step counter
# Final cost : 0.06428674334077032
# Compute control for a deterministic system
# Cost in iteration 0: 0.06428674334077032
# Converged in iteration 19 with cost 0.06428674334074772 because of step counter
# Final cost : 0.06428674334074772
# Compute control for a deterministic system
# Cost in iteration 0: 0.06428674334074772
# Converged in iteration 1 with cost 0.06428674334074772 because of step counter
# Final cost : 0.06428674334074772
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.7137356661125871
# Cost in iteration 200: 0.05289164403993701
# Final cost : 0.05289164403993701
# Compute control for a deterministic system
# Cost in iteration 0: 0.05289164403993701
# Converged in iteration 119 with cost 0.05157647752729378 because of vanishing difference
# Final cost : 0.05157647752729378
# Compute control for a deterministic system
# Cost in iteration 0: 0.05157647752729378
# Converged in iteration 140 with cost 0.0515764723368352 because of step counter
# Final cost : 0.0515764723368352
# Compute control for a deterministic system
# Cost in iteration 0: 0.0515764723368352
# Converged in iteration 2 with cost 0.05157647233683502 because of step counter
# Final cost : 0.05157647233683502
# Compute control for a deterministic system
# Cost in iteration 0: 0.05157647233683502
# Converged in iteration 2 with cost 0.05157647233683479 because of step counter
# Final cost : 0.05157647233683479
# Compute control for a deterministic system
# Cost in iteration 0: 0.5018222335057928
# Cost in iteration 200: 0.0429572842350558
# Final cost : 0.0429572842350558
# Compute control for a deterministic system
# Cost in iteration 0: 0.0429572842350558
# Converged in iteration 88 with cost 0.04214438149720231 because of vanishing difference
# Final cost : 0.04214438149720231
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214438149720231
# Converged in iteration 115 with cost 0.04214437547695463 because of step counter
# Final cost : 0.04214437547695463
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214437547695463
# Converged in iteration 2 with cost 0.04214437547695422 because of step counter
# Final cost : 0.04214437547695422
# Compute control for a deterministic system
# Cost in iteration 0: 0.04214437547695422
# Converged in iteration 2 with cost 0.04214437547695385 because of step counter
# Final cost : 0.04214437547695385
# Compute control for a deterministic system
# Cost in iteration 0: 0.26657906456491975
# Cost in iteration 200: 0.029832637286281573
# Final cost : 0.029832637286281573
# Compute control for a deterministic system
# Cost in iteration 0: 0.029832637286281573
# Converged in iteration 63 with cost 0.02970645740762969 because of vanishing difference
# Final cost : 0.02970645740762969
# Compute control for a deterministic system
# Cost in iteration 0: 0.02970645740762969
# Converged in iteration 64 with cost 0.029706457195509774 because of step counter
# Final cost : 0.029706457195509774
# Compute control for a deterministic system
# Cost in iteration 0: 0.029706457195509774
# Converged in iteration 2 with cost 0.02970645719550968 because of step counter
# Final cost : 0.02970645719550968
# Compute control for a deterministic system
# Cost in iteration 0: 0.02970645719550968
# Converged in iteration 3 with cost 0.029706457195509538 because of step counter
# Final cost : 0.029706457195509538
# Compute control for a deterministic system
# Cost in iteration 0: 0.1339885003962662
# Cost in iteration 200: 0.020486191117606984
# Final cost : 0.020486191117606984
# Compute control for a deterministic system
# Cost in iteration 0: 0.020486191117606984
# Converged in iteration 7 with cost 0.020486187961041742 because of vanishing difference
# Final cost : 0.020486187961041742
# Compute control for a deterministic system
# Cost in iteration 0: 0.020486187961041742
# Converged in iteration 47 with cost 0.0204861875591812 because of step counter
# Final cost : 0.0204861875591812
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204861875591812
# Converged in iteration 1 with cost 0.0204861875591812 because of step counter
# Final cost : 0.0204861875591812
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204861875591812
# Converged in iteration 2 with cost 0.020486187559180705 because of step counter
# Final cost : 0.020486187559180705
# Compute control for a deterministic system
# Cost in iteration 0: 0.02558980286052459
# Converged in iteration 90 with cost 0.008347572181683886 because of step counter
# Final cost : 0.008347572181683886
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181683886
# Converged in iteration 6 with cost 0.008347572181682078 because of step counter
# Final cost : 0.008347572181682078
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181682078
# Converged in iteration 2 with cost 0.00834757218168203 because of step counter
# Final cost : 0.00834757218168203
# Compute control for a deterministic system
# Cost in iteration 0: 0.00834757218168203
# Converged in iteration 3 with cost 0.008347572181681431 because of step counter
# Final cost : 0.008347572181681431
# Compute control for a deterministic system
# Cost in iteration 0: 0.008347572181681431
# Converged in iteration 1 with cost 0.008347572181681431 because of step counter
# Final cost : 0.008347572181681431

# %%
save(results_min)

# %%
ind_list = [5,10,15,20,25,30,35]

fig, ax = plt.subplots(7, 1, figsize=(6,20), sharey=True, sharex=True)
    
for i in range(len(ind_list)):
    i_shift = ind_list[i]
    ax[i].plot(results_min["control"][1][i_shift][0,0,:], color="red")
    ax[i].plot(results_min["control"][1][i_shift][0,1,:], color="blue")

plt.show()
