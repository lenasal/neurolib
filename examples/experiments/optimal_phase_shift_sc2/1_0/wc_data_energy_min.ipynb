# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,164], wc.inh[0,164]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# minima =  [  33  221  410  599  788  977 1166 1355 1544 1733 1922 2111 2300 2489
#  2678 2867 3055 3244 3433 3622 3811 4000 4189 4378 4567 4756 4945 5134
#  5323 5512 5701 5890]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.024351216179019367
# Final cost : 0.00016954645800563425
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016954645800563425
# Final cost : 0.00016791540609124929
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016791540609124929
# Final cost : 0.00016747660984339438
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016747660984339438
# Final cost : 0.00016727249829894705
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016727249829894705
# Final cost : 0.000167239404680999
# Compute control for a deterministic system
# Cost in iteration 0: 0.0391493045160841
# Final cost : 0.0004125866042498963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004125866042498963
# Final cost : 0.00040618434070946555
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040618434070946555
# Final cost : 0.0004046729334820953
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004046729334820953
# Final cost : 0.00040394488979463776
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040394488979463776
# Final cost : 0.00040380874392172253
# Compute control for a deterministic system
# Cost in iteration 0: 0.04578121652316873
# Final cost : 0.0007591432126799578
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007591432126799578
# Final cost : 0.0007463319631504009
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007463319631504009
# Final cost : 0.0007436902613559437
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007436902613559437
# Final cost : 0.0007424426203556677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007424426203556677
# Final cost : 0.0007421620730490408
# Compute control for a deterministic system
# Cost in iteration 0: 0.030640132097404887
# Final cost : 0.0012059912155404906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012059912155404906
# Final cost : 0.0011874877692060627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011874877692060627
# Final cost : 0.0011839418842740953
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011839418842740953
# Final cost : 0.0011821416598353422
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011821416598353422
# Final cost : 0.0011816479038940508
# Compute control for a deterministic system
# Cost in iteration 0: 0.02497678044706876
# Final cost : 0.0016289400735955137
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016289400735955137
# Final cost : 0.001611809920553103
# Compute control for a deterministic system
# Cost in iteration 0: 0.001611809920553103
# Final cost : 0.0016082960268774965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016082960268774965
# Final cost : 0.00160626356188724
# Compute control for a deterministic system
# Cost in iteration 0: 0.00160626356188724
# Final cost : 0.0016056083654157794
# Compute control for a deterministic system
# Cost in iteration 0: 0.030990012379857663
# Final cost : 0.002273142128738517
# Compute control for a deterministic system
# Cost in iteration 0: 0.002273142128738517
# Final cost : 0.002237234889359714
# Compute control for a deterministic system
# Cost in iteration 0: 0.002237234889359714
# Final cost : 0.0022305095442616014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022305095442616014
# Final cost : 0.002226932866613609
# Compute control for a deterministic system
# Cost in iteration 0: 0.002226932866613609
# Final cost : 0.0022255087363029697
# Compute control for a deterministic system
# Cost in iteration 0: 0.05618583855310601
# Final cost : 0.0030122504103208885
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030122504103208885
# Final cost : 0.002961333840748405
# Compute control for a deterministic system
# Cost in iteration 0: 0.002961333840748405
# Final cost : 0.002952333241802958
# Compute control for a deterministic system
# Cost in iteration 0: 0.002952333241802958
# Final cost : 0.0029472173766951267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029472173766951267
# Final cost : 0.0029447397083636785
# Compute control for a deterministic system
# Cost in iteration 0: 0.05448654250670255
# Final cost : 0.0038471359880235534
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038471359880235534
# Final cost : 0.0037837087224659336
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037837087224659336
# Final cost : 0.0037729496567682525
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037729496567682525
# Final cost : 0.0037661893025430423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037661893025430423
# Final cost : 0.0037625800044949528
# Compute control for a deterministic system
# Cost in iteration 0: 0.05015990909370946
# Final cost : 0.004545131331326071
# Compute control for a deterministic system
# Cost in iteration 0: 0.004545131331326071
# Final cost : 0.004500923793592205
# Compute control for a deterministic system
# Cost in iteration 0: 0.004500923793592205
# Final cost : 0.004493745159158874
# Compute control for a deterministic system
# Cost in iteration 0: 0.004493745159158874
# Final cost : 0.004489415976320374
# Compute control for a deterministic system
# Cost in iteration 0: 0.004489415976320374
# Final cost : 0.004486983414304017
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.021334870170668038
# Final cost : 0.005587496279602775
# Compute control for a deterministic system
# Cost in iteration 0: 0.005587496279602775
# Final cost : 0.005510407420745042
# Compute control for a deterministic system
# Cost in iteration 0: 0.005510407420745042
# Final cost : 0.005497941076561744
# Compute control for a deterministic system
# Cost in iteration 0: 0.005497941076561744
# Final cost : 0.005487830154308374
# Compute control for a deterministic system
# Cost in iteration 0: 0.005487830154308374
# Final cost : 0.005481116348158579
# Compute control for a deterministic system
# Cost in iteration 0: 0.025834325320345332
# Final cost : 0.006669842280385021
# Compute control for a deterministic system
# Cost in iteration 0: 0.006669842280385021
# Final cost : 0.00659451369983114
# Compute control for a deterministic system
# Cost in iteration 0: 0.00659451369983114
# Final cost : 0.006583655439183212
# Compute control for a deterministic system
# Cost in iteration 0: 0.006583655439183212
# Final cost : 0.006575815149136371
# Compute control for a deterministic system
# Cost in iteration 0: 0.006575815149136371
# Final cost : 0.0065706007942953155
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.04615064022892322
# Final cost : 0.007611585024426183
# Compute control for a deterministic system
# Cost in iteration 0: 0.007611585024426183
# Final cost : 0.007543430147354545
# Compute control for a deterministic system
# Cost in iteration 0: 0.007543430147354545
# Final cost : 0.00753141965780715
# Compute control for a deterministic system
# Cost in iteration 0: 0.00753141965780715
# Final cost : 0.007520647798255915
# Compute control for a deterministic system
# Cost in iteration 0: 0.007520647798255915
# Final cost : 0.0075123617417502606
# Compute control for a deterministic system
# Cost in iteration 0: 0.06451129662932481
# Final cost : 0.008893948489991959
# Compute control for a deterministic system
# Cost in iteration 0: 0.008893948489991959
# Final cost : 0.008799556833866318
# Compute control for a deterministic system
# Cost in iteration 0: 0.008799556833866318
# Final cost : 0.008787146231415568
# Compute control for a deterministic system
# Cost in iteration 0: 0.008787146231415568
# Final cost : 0.008778782521758271
# Compute control for a deterministic system
# Cost in iteration 0: 0.008778782521758271
# Final cost : 0.008772656675884028
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.07166056673089692
# Final cost : 0.010312640049915134
# Compute control for a deterministic system
# Cost in iteration 0: 0.010312640049915134
# Final cost : 0.010189534920473956
# Compute control for a deterministic system
# Cost in iteration 0: 0.010189534920473956
# Final cost : 0.010168136097574682
# Compute control for a deterministic system
# Cost in iteration 0: 0.010168136097574682
# Final cost : 0.010148636550274932
# Compute control for a deterministic system
# Cost in iteration 0: 0.010148636550274932
# Final cost : 0.010132665836482573
# Compute control for a deterministic system
# Cost in iteration 0: 0.1625173611992579
# Final cost : 0.011830009071426133
# Compute control for a deterministic system
# Cost in iteration 0: 0.011830009071426133
# Final cost : 0.011614925699185964
# Compute control for a deterministic system
# Cost in iteration 0: 0.011614925699185964
# Final cost : 0.011597217560867824
# Compute control for a deterministic system
# Cost in iteration 0: 0.011597217560867824
# Final cost : 0.011584346171011412
# Compute control for a deterministic system
# Cost in iteration 0: 0.011584346171011412
# Final cost : 0.01157624689647816
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.028724544296037557
# Final cost : 0.012930811766996984
# Compute control for a deterministic system
# Cost in iteration 0: 0.012930811766996984
# Final cost : 0.012852103559572357
# Compute control for a deterministic system
# Cost in iteration 0: 0.012852103559572357
# Final cost : 0.012833457767087055
# Compute control for a deterministic system
# Cost in iteration 0: 0.012833457767087055
# Final cost : 0.012818487542157532
# Compute control for a deterministic system
# Cost in iteration 0: 0.012818487542157532
# Final cost : 0.012804041457692032
# Compute control for a deterministic system
# Cost in iteration 0: 0.026617024246431392
# Final cost : 0.014535647498505333
# Compute control for a deterministic system
# Cost in iteration 0: 0.014535647498505333
# Final cost : 0.014436728620502964
# Compute control for a deterministic system
# Cost in iteration 0: 0.014436728620502964
# Final cost : 0.014421936203378815
# Compute control for a deterministic system
# Cost in iteration 0: 0.014421936203378815
# Final cost : 0.014410538407661252
# Compute control for a deterministic system
# Cost in iteration 0: 0.014410538407661252
# Final cost : 0.014403988465538614
# Compute control for a deterministic system
# Cost in iteration 0: 0.09074319903376613
# Final cost : 0.016288364824560527
# Compute control for a deterministic system
# Cost in iteration 0: 0.016288364824560527
# Final cost : 0.016148468184902925
# Compute control for a deterministic system
# Cost in iteration 0: 0.016148468184902925
# Final cost : 0.016127243139375233
# Compute control for a deterministic system
# Cost in iteration 0: 0.016127243139375233
# Final cost : 0.01610953874702588
# Compute control for a deterministic system
# Cost in iteration 0: 0.01610953874702588
# Final cost : 0.01609310401259362
# Compute control for a deterministic system
# Cost in iteration 0: 0.02169865546020903
# Final cost : 0.017599089403092592
# Compute control for a deterministic system
# Cost in iteration 0: 0.017599089403092592
# Final cost : 0.01752243226931734
# Compute control for a deterministic system
# Cost in iteration 0: 0.01752243226931734
# Final cost : 0.017508808711263067
# Compute control for a deterministic system
# Cost in iteration 0: 0.017508808711263067
# Final cost : 0.017496623293218102
# Compute control for a deterministic system
# Cost in iteration 0: 0.017496623293218102
# Final cost : 0.017484887791590277
# Compute control for a deterministic system
# Cost in iteration 0: 0.1409183227246123
# Final cost : 0.019650888240832685
# Compute control for a deterministic system
# Cost in iteration 0: 0.019650888240832685
# Final cost : 0.01942902874099129
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942902874099129
# Final cost : 0.019388062709866954
# Compute control for a deterministic system
# Cost in iteration 0: 0.019388062709866954
# Final cost : 0.019349955680833066
# Compute control for a deterministic system
# Cost in iteration 0: 0.019349955680833066
# Final cost : 0.019308573018087548
# Compute control for a deterministic system
# Cost in iteration 0: 0.03875871940191415
# Final cost : 0.016107969908218667
# Compute control for a deterministic system
# Cost in iteration 0: 0.016107969908218667
# Final cost : 0.01600757764192883
# Compute control for a deterministic system
# Cost in iteration 0: 0.01600757764192883
# Final cost : 0.015973245186285522
# Compute control for a deterministic system
# Cost in iteration 0: 0.015973245186285522
# Final cost : 0.01594782535099969
# Compute control for a deterministic system
# Cost in iteration 0: 0.01594782535099969
# Final cost : 0.015932774030029812
# Compute control for a deterministic system
# Cost in iteration 0: 0.13954101287289572
# Final cost : 0.014196599883090409
# Compute control for a deterministic system
# Cost in iteration 0: 0.014196599883090409
# Final cost : 0.014122218142768822
# Compute control for a deterministic system
# Cost in iteration 0: 0.014122218142768822
# Final cost : 0.014090339856208969
# Compute control for a deterministic system
# Cost in iteration 0: 0.014090339856208969
# Final cost : 0.014063609963325521
# Compute control for a deterministic system
# Cost in iteration 0: 0.014063609963325521
# Final cost : 0.014043520746641787
# Compute control for a deterministic system
# Cost in iteration 0: 0.05296256303358106
# Final cost : 0.012720778925154623
# Compute control for a deterministic system
# Cost in iteration 0: 0.012720778925154623
# Final cost : 0.012667294055780147
# Compute control for a deterministic system
# Cost in iteration 0: 0.012667294055780147
# Final cost : 0.012649395067401542
# Compute control for a deterministic system
# Cost in iteration 0: 0.012649395067401542
# Final cost : 0.012635085024305203
# Compute control for a deterministic system
# Cost in iteration 0: 0.012635085024305203
# Final cost : 0.012625048698240314
# Compute control for a deterministic system
# Cost in iteration 0: 0.016452760342698283
# Final cost : 0.011168624768885945
# Compute control for a deterministic system
# Cost in iteration 0: 0.011168624768885945
# Final cost : 0.01108447578669963
# Compute control for a deterministic system
# Cost in iteration 0: 0.01108447578669963
# Final cost : 0.011048559137866351
# Compute control for a deterministic system
# Cost in iteration 0: 0.011048559137866351
# Final cost : 0.011013387717610545
# Compute control for a deterministic system
# Cost in iteration 0: 0.011013387717610545
# Final cost : 0.010980308492587755
# Compute control for a deterministic system
# Cost in iteration 0: 0.01872659454489064
# Final cost : 0.0095662822308142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0095662822308142
# Final cost : 0.0094933106836952
# Compute control for a deterministic system
# Cost in iteration 0: 0.0094933106836952
# Final cost : 0.009468374551490034
# Compute control for a deterministic system
# Cost in iteration 0: 0.009468374551490034
# Final cost : 0.009450012248380943
# Compute control for a deterministic system
# Cost in iteration 0: 0.009450012248380943
# Final cost : 0.009439411829776643
# Compute control for a deterministic system
# Cost in iteration 0: 0.03595978244831708
# Final cost : 0.008138720697516512
# Compute control for a deterministic system
# Cost in iteration 0: 0.008138720697516512
# Final cost : 0.008074841819702788
# Compute control for a deterministic system
# Cost in iteration 0: 0.008074841819702788
# Final cost : 0.008052288980800714
# Compute control for a deterministic system
# Cost in iteration 0: 0.008052288980800714
# Final cost : 0.008035859631722323
# Compute control for a deterministic system
# Cost in iteration 0: 0.008035859631722323
# Final cost : 0.008026374119635393
# Compute control for a deterministic system
# Cost in iteration 0: 0.0816499156274361
# Final cost : 0.007036804860632949
# Compute control for a deterministic system
# Cost in iteration 0: 0.007036804860632949
# Final cost : 0.007004644206688908
# Compute control for a deterministic system
# Cost in iteration 0: 0.007004644206688908
# Final cost : 0.006994103140478078
# Compute control for a deterministic system
# Cost in iteration 0: 0.006994103140478078
# Final cost : 0.006985360511917828
# Compute control for a deterministic system
# Cost in iteration 0: 0.006985360511917828
# Final cost : 0.006981059384101688
# Compute control for a deterministic system
# Cost in iteration 0: 0.01269501001684863
# Final cost : 0.005876832202069238
# Compute control for a deterministic system
# Cost in iteration 0: 0.005876832202069238
# Final cost : 0.005823010705873141
# Compute control for a deterministic system
# Cost in iteration 0: 0.005823010705873141
# Final cost : 0.005804976756413944
# Compute control for a deterministic system
# Cost in iteration 0: 0.005804976756413944
# Final cost : 0.005790663145469381
# Compute control for a deterministic system
# Cost in iteration 0: 0.005790663145469381
# Final cost : 0.00578333807495923
# Compute control for a deterministic system
# Cost in iteration 0: 0.04988001002982337
# Final cost : 0.004780335385577233
# Compute control for a deterministic system
# Cost in iteration 0: 0.004780335385577233
# Final cost : 0.004735895246511531
# Compute control for a deterministic system
# Cost in iteration 0: 0.004735895246511531
# Final cost : 0.004720835366398079
# Compute control for a deterministic system
# Cost in iteration 0: 0.004720835366398079
# Final cost : 0.004708639471532145
# Compute control for a deterministic system
# Cost in iteration 0: 0.004708639471532145
# Final cost : 0.004702961837099122
# Compute control for a deterministic system
# Cost in iteration 0: 0.008558812994177923
# Final cost : 0.003968245435955365
# Compute control for a deterministic system
# Cost in iteration 0: 0.003968245435955365
# Final cost : 0.003940135415499497
# Compute control for a deterministic system
# Cost in iteration 0: 0.003940135415499497
# Final cost : 0.003931617435072328
# Compute control for a deterministic system
# Cost in iteration 0: 0.003931617435072328
# Final cost : 0.003924849502387159
# Compute control for a deterministic system
# Cost in iteration 0: 0.003924849502387159
# Final cost : 0.003922384615235024
# Compute control for a deterministic system
# Cost in iteration 0: 0.05028685369432738
# Final cost : 0.0031068580715207746
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031068580715207746
# Final cost : 0.0030741965729717794
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030741965729717794
# Final cost : 0.003062813109084955
# Compute control for a deterministic system
# Cost in iteration 0: 0.003062813109084955
# Final cost : 0.0030538349562961153
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030538349562961153
# Final cost : 0.0030507144140003556
# Compute control for a deterministic system
# Cost in iteration 0: 0.04777520273145216
# Final cost : 0.0023367030068563058
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023367030068563058
# Final cost : 0.0023106643162446663
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023106643162446663
# Final cost : 0.0023010276631218775
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023010276631218775
# Final cost : 0.0022942049783533196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022942049783533196
# Final cost : 0.0022918114223242437
# Compute control for a deterministic system
# Cost in iteration 0: 0.02899765376389982
# Final cost : 0.001679232517092732
# Compute control for a deterministic system
# Cost in iteration 0: 0.001679232517092732
# Final cost : 0.0016584959023800338
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016584959023800338
# Final cost : 0.0016508204859316403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016508204859316403
# Final cost : 0.0016454306868153032
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016454306868153032
# Final cost : 0.0016438049897156603
# Compute control for a deterministic system
# Cost in iteration 0: 0.047263844428260815
# Final cost : 0.0012199466731294439
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012199466731294439
# Final cost : 0.0012091098574172955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012091098574172955
# Final cost : 0.0012063001586505044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012063001586505044
# Final cost : 0.001204570914740128
# Compute control for a deterministic system
# Cost in iteration 0: 0.001204570914740128
# Final cost : 0.001204146499774938
# Compute control for a deterministic system
# Cost in iteration 0: 0.05208452411092058
# Final cost : 0.0007691816299526372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007691816299526372
# Final cost : 0.0007580319569266679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007580319569266679
# Final cost : 0.0007544361670498282
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007544361670498282
# Final cost : 0.000752406510613462
# Compute control for a deterministic system
# Cost in iteration 0: 0.000752406510613462
# Final cost : 0.0007518853483551843
# Compute control for a deterministic system
# Cost in iteration 0: 0.0333241609776175
# Final cost : 0.0004172552103292662
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004172552103292662
# Final cost : 0.0004100137964340579
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004100137964340579
# Final cost : 0.0004078956449763491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004078956449763491
# Final cost : 0.000406775111090555
# Compute control for a deterministic system
# Cost in iteration 0: 0.000406775111090555
# Final cost : 0.00040651495251070374
# Compute control for a deterministic system
# Cost in iteration 0: 0.031033594963865072
# Final cost : 0.00017234413111717178
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017234413111717178
# Final cost : 0.00016888543076479205
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016888543076479205
# Final cost : 0.00016770049678111826
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016770049678111826
# Final cost : 0.0001671402418748183
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001671402418748183
# Final cost : 0.00016702413845828842
# Compute control for a deterministic system
# Cost in iteration 0: 0.030143128469429993
# Final cost : 5.2277059210473893e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.2277059210473893e-05
# Final cost : 5.1400882900663226e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1400882900663226e-05
# Final cost : 5.118562582101618e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.118562582101618e-05
# Final cost : 5.108333682644288e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.108333682644288e-05
# Final cost : 5.1066804869355614e-05
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0287481016527346
# Final cost : 0.00017179657723015942
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017179657723015942
# Final cost : 0.00016784156546482905
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016784156546482905
# Final cost : 0.00016707427921185946
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016707427921185946
# Final cost : 0.0001670227363622357
# Compute control for a deterministic system
# Cost in iteration 0: 0.04472879085483099
# Final cost : 0.00041509652626032823
# Compute control for a deterministic system
# Cost in iteration 0: 0.00041509652626032823
# Final cost : 0.0004085913842915963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004085913842915963
# Final cost : 0.000406779660763684
# Compute control for a deterministic system
# Cost in iteration 0: 0.000406779660763684
# Final cost : 0.00040651385883802907
# Compute control for a deterministic system
# Cost in iteration 0: 0.04815140179409104
# Final cost : 0.0007645260979459002
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007645260979459002
# Final cost : 0.0007555723897293001
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007555723897293001
# Final cost : 0.0007524400050354839
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007524400050354839
# Final cost : 0.0007518831021591986
# Compute control for a deterministic system
# Cost in iteration 0: 0.03422990045205847
# Final cost : 0.0012177000505201273
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012177000505201273
# Final cost : 0.0012083256184520056
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012083256184520056
# Final cost : 0.001204956912114756
# Compute control for a deterministic system
# Cost in iteration 0: 0.001204956912114756
# Final cost : 0.0012041581477112478
# Compute control for a deterministic system
# Cost in iteration 0: 0.041705078656596235
# Final cost : 0.0016584754165478832
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016584754165478832
# Final cost : 0.001648407925041783
# Compute control for a deterministic system
# Cost in iteration 0: 0.001648407925041783
# Final cost : 0.0016447116442695048
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016447116442695048
# Final cost : 0.001643761831455572
# Compute control for a deterministic system
# Cost in iteration 0: 0.03249974554293703
# Final cost : 0.0023123437595534303
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023123437595534303
# Final cost : 0.002299748358676811
# Compute control for a deterministic system
# Cost in iteration 0: 0.002299748358676811
# Final cost : 0.002293671630389465
# Compute control for a deterministic system
# Cost in iteration 0: 0.002293671630389465
# Final cost : 0.0022917648649786668
# Compute control for a deterministic system
# Cost in iteration 0: 0.04974429736557953
# Final cost : 0.0030816671887896425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030816671887896425
# Final cost : 0.003063327177193457
# Compute control for a deterministic system
# Cost in iteration 0: 0.003063327177193457
# Final cost : 0.003054030291381797
# Compute control for a deterministic system
# Cost in iteration 0: 0.003054030291381797
# Final cost : 0.003050778246374587
# Compute control for a deterministic system
# Cost in iteration 0: 0.07122548861088905
# Final cost : 0.0039659762559321275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039659762559321275
# Final cost : 0.0039403740768495284
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039403740768495284
# Final cost : 0.003927538642489891
# Compute control for a deterministic system
# Cost in iteration 0: 0.003927538642489891
# Final cost : 0.003922732169372421
# Compute control for a deterministic system
# Cost in iteration 0: 0.025689968328189615
# Final cost : 0.004732972699299415
# Compute control for a deterministic system
# Cost in iteration 0: 0.004732972699299415
# Final cost : 0.004717285457240175
# Compute control for a deterministic system
# Cost in iteration 0: 0.004717285457240175
# Final cost : 0.004707326067242074
# Compute control for a deterministic system
# Cost in iteration 0: 0.004707326067242074
# Final cost : 0.004702808186878896
# Compute control for a deterministic system
# Cost in iteration 0: 0.0642017773732226
# Final cost : 0.005834228423961643
# Compute control for a deterministic system
# Cost in iteration 0: 0.005834228423961643
# Final cost : 0.0058077370988636485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058077370988636485
# Final cost : 0.005791134405803975
# Compute control for a deterministic system
# Cost in iteration 0: 0.005791134405803975
# Final cost : 0.005783382640501583
# Compute control for a deterministic system
# Cost in iteration 0: 0.023706117209609103
# Final cost : 0.007036829384057331
# Compute control for a deterministic system
# Cost in iteration 0: 0.007036829384057331
# Final cost : 0.007011319585287943
# Compute control for a deterministic system
# Cost in iteration 0: 0.007011319585287943
# Final cost : 0.006992362900763205
# Compute control for a deterministic system
# Cost in iteration 0: 0.006992362900763205
# Final cost : 0.006982254373865255
# Compute control for a deterministic system
# Cost in iteration 0: 0.044529965515825914
# Final cost : 0.008080098803333545
# Compute control for a deterministic system
# Cost in iteration 0: 0.008080098803333545
# Final cost : 0.008054938334075069
# Compute control for a deterministic system
# Cost in iteration 0: 0.008054938334075069
# Final cost : 0.00803684037619358
# Compute control for a deterministic system
# Cost in iteration 0: 0.00803684037619358
# Final cost : 0.008026800964011283
# Compute control for a deterministic system
# Cost in iteration 0: 0.027363977327423607
# Final cost : 0.009521810016486458
# Compute control for a deterministic system
# Cost in iteration 0: 0.009521810016486458
# Final cost : 0.009484774345026084
# Compute control for a deterministic system
# Cost in iteration 0: 0.009484774345026084
# Final cost : 0.009457257921095932
# Compute control for a deterministic system
# Cost in iteration 0: 0.009457257921095932
# Final cost : 0.009441466369367586
# Compute control for a deterministic system
# Cost in iteration 0: 0.03116573990497705
# Final cost : 0.011072572733712106
# Compute control for a deterministic system
# Cost in iteration 0: 0.011072572733712106
# Final cost : 0.011029226317787367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011029226317787367
# Final cost : 0.010995821260451288
# Compute control for a deterministic system
# Cost in iteration 0: 0.010995821260451288
# Final cost : 0.010975389754715525
# Compute control for a deterministic system
# Cost in iteration 0: 0.04653727337071726
# Final cost : 0.012744282677705072
# Compute control for a deterministic system
# Cost in iteration 0: 0.012744282677705072
# Final cost : 0.012695811621618827
# Compute control for a deterministic system
# Cost in iteration 0: 0.012695811621618827
# Final cost : 0.01265678301016655
# Compute control for a deterministic system
# Cost in iteration 0: 0.01265678301016655
# Final cost : 0.012631050477704815
# Compute control for a deterministic system
# Cost in iteration 0: 0.12562809722745505
# Final cost : 0.014105080553575402
# Compute control for a deterministic system
# Cost in iteration 0: 0.014105080553575402
# Final cost : 0.014064566662087668
# Compute control for a deterministic system
# Cost in iteration 0: 0.014064566662087668
# Final cost : 0.01404791593281433
# Compute control for a deterministic system
# Cost in iteration 0: 0.01404791593281433
# Final cost : 0.014040007105404779
# Compute control for a deterministic system
# Cost in iteration 0: 0.024502488163530466
# Final cost : 0.01605086889865287
# Compute control for a deterministic system
# Cost in iteration 0: 0.01605086889865287
# Final cost : 0.016004501105839307
# Compute control for a deterministic system
# Cost in iteration 0: 0.016004501105839307
# Final cost : 0.015967006420158178
# Compute control for a deterministic system
# Cost in iteration 0: 0.015967006420158178
# Final cost : 0.01594046117356465
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792098929099056
# Final cost : 0.018298197175675872
# Compute control for a deterministic system
# Cost in iteration 0: 0.018298197175675872
# Final cost : 0.018054570547401182
# Compute control for a deterministic system
# Cost in iteration 0: 0.018054570547401182
# Final cost : 0.018008141618477864
# Compute control for a deterministic system
# Cost in iteration 0: 0.018008141618477864
# Final cost : 0.017976610560784156
# Compute control for a deterministic system
# Cost in iteration 0: 0.026445865007283346
# Final cost : 0.020314449532892184
# Compute control for a deterministic system
# Cost in iteration 0: 0.020314449532892184
# Final cost : 0.020255134778473752
# Compute control for a deterministic system
# Cost in iteration 0: 0.020255134778473752
# Final cost : 0.020201045524517576
# Compute control for a deterministic system
# Cost in iteration 0: 0.020201045524517576
# Final cost : 0.02015230930698934
# Compute control for a deterministic system
# Cost in iteration 0: 0.07573940679527512
# Final cost : 0.01619319608091917
# Compute control for a deterministic system
# Cost in iteration 0: 0.01619319608091917
# Final cost : 0.016126183994549157
# Compute control for a deterministic system
# Cost in iteration 0: 0.016126183994549157
# Final cost : 0.016092111376083185
# Compute control for a deterministic system
# Cost in iteration 0: 0.016092111376083185
# Final cost : 0.016084244138519756
# Compute control for a deterministic system
# Cost in iteration 0: 0.06783766457577499
# Final cost : 0.014595279638271275
# Compute control for a deterministic system
# Cost in iteration 0: 0.014595279638271275
# Final cost : 0.014506601964107024
# Compute control for a deterministic system
# Cost in iteration 0: 0.014506601964107024
# Final cost : 0.01445489294181436
# Compute control for a deterministic system
# Cost in iteration 0: 0.01445489294181436
# Final cost : 0.014419849362468049
# Compute control for a deterministic system
# Cost in iteration 0: 0.111049629176255
# Final cost : 0.013016844789017247
# Compute control for a deterministic system
# Cost in iteration 0: 0.013016844789017247
# Final cost : 0.012908674933989442
# Compute control for a deterministic system
# Cost in iteration 0: 0.012908674933989442
# Final cost : 0.01284631913962101
# Compute control for a deterministic system
# Cost in iteration 0: 0.01284631913962101
# Final cost : 0.012811925213253946
# Compute control for a deterministic system
# Cost in iteration 0: 0.024677160386494843
# Final cost : 0.011717781515250084
# Compute control for a deterministic system
# Cost in iteration 0: 0.011717781515250084
# Final cost : 0.01166674262329506
# Compute control for a deterministic system
# Cost in iteration 0: 0.01166674262329506
# Final cost : 0.011628322636313594
# Compute control for a deterministic system
# Cost in iteration 0: 0.011628322636313594
# Final cost : 0.011593584330731007
# Compute control for a deterministic system
# Cost in iteration 0: 0.06162283971528939
# Final cost : 0.010262322901020866
# Compute control for a deterministic system
# Cost in iteration 0: 0.010262322901020866
# Final cost : 0.010193908653761338
# Compute control for a deterministic system
# Cost in iteration 0: 0.010193908653761338
# Final cost : 0.010153448582316512
# Compute control for a deterministic system
# Cost in iteration 0: 0.010153448582316512
# Final cost : 0.010132391496766596
# Compute control for a deterministic system
# Cost in iteration 0: 0.07261012296626308
# Final cost : 0.008928856867394384
# Compute control for a deterministic system
# Cost in iteration 0: 0.008928856867394384
# Final cost : 0.008865916766203675
# Compute control for a deterministic system
# Cost in iteration 0: 0.008865916766203675
# Final cost : 0.008820044776474432
# Compute control for a deterministic system
# Cost in iteration 0: 0.008820044776474432
# Final cost : 0.00878514274251654
# Compute control for a deterministic system
# Cost in iteration 0: 0.09293159295715687
# Final cost : 0.007593167554189636
# Compute control for a deterministic system
# Cost in iteration 0: 0.007593167554189636
# Final cost : 0.0075542049658677566
# Compute control for a deterministic system
# Cost in iteration 0: 0.0075542049658677566
# Final cost : 0.0075270502400691846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0075270502400691846
# Final cost : 0.007513488235122686
# Compute control for a deterministic system
# Cost in iteration 0: 0.018812228954231406
# Final cost : 0.00665332211411765
# Compute control for a deterministic system
# Cost in iteration 0: 0.00665332211411765
# Final cost : 0.006608817682128152
# Compute control for a deterministic system
# Cost in iteration 0: 0.006608817682128152
# Final cost : 0.006586489470650641
# Compute control for a deterministic system
# Cost in iteration 0: 0.006586489470650641
# Final cost : 0.006573282007280746
# Compute control for a deterministic system
# Cost in iteration 0: 0.05329280583167502
# Final cost : 0.005549671717395104
# Compute control for a deterministic system
# Cost in iteration 0: 0.005549671717395104
# Final cost : 0.005514783009555137
# Compute control for a deterministic system
# Cost in iteration 0: 0.005514783009555137
# Final cost : 0.005492551903912509
# Compute control for a deterministic system
# Cost in iteration 0: 0.005492551903912509
# Final cost : 0.005481500920323509
# Compute control for a deterministic system
# Cost in iteration 0: 0.09454444120386465
# Final cost : 0.00455401497082262
# Compute control for a deterministic system
# Cost in iteration 0: 0.00455401497082262
# Final cost : 0.004526518295674695
# Compute control for a deterministic system
# Cost in iteration 0: 0.004526518295674695
# Final cost : 0.004504053633436718
# Compute control for a deterministic system
# Cost in iteration 0: 0.004504053633436718
# Final cost : 0.004489473982498994
# Compute control for a deterministic system
# Cost in iteration 0: 0.03105512792907801
# Final cost : 0.003795417641302986
# Compute control for a deterministic system
# Cost in iteration 0: 0.003795417641302986
# Final cost : 0.0037737195248014888
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037737195248014888
# Final cost : 0.003765502210510764
# Compute control for a deterministic system
# Cost in iteration 0: 0.003765502210510764
# Final cost : 0.003762347633913311
# Compute control for a deterministic system
# Cost in iteration 0: 0.057218018938750594
# Final cost : 0.002995384306367917
# Compute control for a deterministic system
# Cost in iteration 0: 0.002995384306367917
# Final cost : 0.002968543415343917
# Compute control for a deterministic system
# Cost in iteration 0: 0.002968543415343917
# Final cost : 0.002952678925872866
# Compute control for a deterministic system
# Cost in iteration 0: 0.002952678925872866
# Final cost : 0.002945282509387971
# Compute control for a deterministic system
# Cost in iteration 0: 0.05072140340384986
# Final cost : 0.002254268298199482
# Compute control for a deterministic system
# Cost in iteration 0: 0.002254268298199482
# Final cost : 0.0022386973557701408
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022386973557701408
# Final cost : 0.00222925430472048
# Compute control for a deterministic system
# Cost in iteration 0: 0.00222925430472048
# Final cost : 0.0022256853075756262
# Compute control for a deterministic system
# Cost in iteration 0: 0.03280381211506339
# Final cost : 0.0016278122218848251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016278122218848251
# Final cost : 0.0016157519531595917
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016157519531595917
# Final cost : 0.0016080648763809743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016080648763809743
# Final cost : 0.001605712134203472
# Compute control for a deterministic system
# Cost in iteration 0: 0.03704018358457754
# Final cost : 0.0011907957569334423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011907957569334423
# Final cost : 0.001185535968559469
# Compute control for a deterministic system
# Cost in iteration 0: 0.001185535968559469
# Final cost : 0.001182489542771481
# Compute control for a deterministic system
# Cost in iteration 0: 0.001182489542771481
# Final cost : 0.001181664114731737
# Compute control for a deterministic system
# Cost in iteration 0: 0.031916419294670255
# Final cost : 0.0007527405263609889
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007527405263609889
# Final cost : 0.0007466320654686235
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007466320654686235
# Final cost : 0.0007429521524376858
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007429521524376858
# Final cost : 0.0007421755581596525
# Compute control for a deterministic system
# Cost in iteration 0: 0.03242724545487674
# Final cost : 0.00040939837862758295
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040939837862758295
# Final cost : 0.0004059812860460126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004059812860460126
# Final cost : 0.0004041367443655549
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004041367443655549
# Final cost : 0.0004038128983145811
# Compute control for a deterministic system
# Cost in iteration 0: 0.0476985861216548
# Final cost : 0.00016866972107707496
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016866972107707496
# Final cost : 0.00016761549252798357
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016761549252798357
# Final cost : 0.00016730019780908218
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016730019780908218
# Final cost : 0.00016723980104239153
# Compute control for a deterministic system
# Cost in iteration 0: 0.030259087373170804
# Final cost : 5.2144830107435516e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.2144830107435516e-05
# Final cost : 5.18625777072605e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.18625777072605e-05
# Final cost : 5.1727329306842294e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1727329306842294e-05
# Final cost : 5.170713080163803e-05
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 7.910255851870873e-05
# Final cost : 5.172057878282957e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.172057878282957e-05
# Final cost : 5.1708243515965944e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1708243515965944e-05
# Final cost : 5.17072338525694e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.17072338525694e-05
# Final cost : 5.170698376038167e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.170698376038167e-05
# Final cost : 5.170696903904199e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017160981910331708
# Final cost : 0.00016727374627007905
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016727374627007905
# Final cost : 0.00016724311343608233
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016724311343608233
# Final cost : 0.00016723996221106667
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016723996221106667
# Final cost : 0.0001672391092983246
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001672391092983246
# Final cost : 0.00016723904915472108
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012013562403249164
# Final cost : 0.0004038682240491515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004038682240491515
# Final cost : 0.0004038160550576641
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004038160550576641
# Final cost : 0.0004038088951587888
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004038088951587888
# Final cost : 0.0004038066442498747
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004038066442498747
# Final cost : 0.0004038064001112525
# Compute control for a deterministic system
# Cost in iteration 0: 0.002128705614754805
# Final cost : 0.0007422637661221899
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007422637661221899
# Final cost : 0.0007421719593988528
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007421719593988528
# Final cost : 0.0007421591551916382
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007421591551916382
# Final cost : 0.0007421550128781599
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007421550128781599
# Final cost : 0.000742154559753909
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013043871163164547
# Final cost : 0.001181894649223139
# Compute control for a deterministic system
# Cost in iteration 0: 0.001181894649223139
# Final cost : 0.001181667959894701
# Compute control for a deterministic system
# Cost in iteration 0: 0.001181667959894701
# Final cost : 0.0011816405282799682
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011816405282799682
# Final cost : 0.0011816294720672846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011816294720672846
# Final cost : 0.0011816276799817538
# Compute control for a deterministic system
# Cost in iteration 0: 0.0053845493546785
# Final cost : 0.001605822436131957
# Compute control for a deterministic system
# Cost in iteration 0: 0.001605822436131957
# Final cost : 0.001605630587275975
# Compute control for a deterministic system
# Cost in iteration 0: 0.001605630587275975
# Final cost : 0.0016055917949563217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016055917949563217
# Final cost : 0.0016055753524154808
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016055753524154808
# Final cost : 0.001605570422491372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025481358910448724
# Final cost : 0.0022259066067873
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022259066067873
# Final cost : 0.002225512606090919
# Compute control for a deterministic system
# Cost in iteration 0: 0.002225512606090919
# Final cost : 0.002225438699087017
# Compute control for a deterministic system
# Cost in iteration 0: 0.002225438699087017
# Final cost : 0.0022254027483579347
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022254027483579347
# Final cost : 0.0022253879742700163
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.003123621853875848
# Final cost : 0.0029451232268563224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029451232268563224
# Final cost : 0.00294467586561613
# Compute control for a deterministic system
# Cost in iteration 0: 0.00294467586561613
# Final cost : 0.0029445631280883857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029445631280883857
# Final cost : 0.0029444829177980992
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029444829177980992
# Final cost : 0.002944441735492529
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.0043606443736110756
# Final cost : 0.0037627136118926117
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037627136118926117
# Final cost : 0.003762157828270578
# Compute control for a deterministic system
# Cost in iteration 0: 0.003762157828270578
# Final cost : 0.003762092791416319
# Compute control for a deterministic system
# Cost in iteration 0: 0.003762092791416319
# Final cost : 0.0037620385546748365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037620385546748365
# Final cost : 0.00376201850350936
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.009515992742474562
# Final cost : 0.004487368402130194
# Compute control for a deterministic system
# Cost in iteration 0: 0.004487368402130194
# Final cost : 0.004486927021076488
# Compute control for a deterministic system
# Cost in iteration 0: 0.004486927021076488
# Final cost : 0.0044867661552088186
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044867661552088186
# Final cost : 0.004486629380667236
# Compute control for a deterministic system
# Cost in iteration 0: 0.004486629380667236
# Final cost : 0.004486551802422402
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.009578598277090712
# Final cost : 0.005481297358519219
# Compute control for a deterministic system
# Cost in iteration 0: 0.005481297358519219
# Final cost : 0.005480301096405808
# Compute control for a deterministic system
# Cost in iteration 0: 0.005480301096405808
# Final cost : 0.005480054970829365
# ...
# Cost in iteration 0: 0.007509968906425404
# Final cost : 0.00750978403184627
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.008860456071994288
# Final cost : 0.008772724395277664
# Compute control for a deterministic system
# Cost in iteration 0: 0.008772724395277664
# Final cost : 0.008772167249471432
# Compute control for a deterministic system
# Cost in iteration 0: 0.008772167249471432
# Final cost : 0.00877184163762417
# Compute control for a deterministic system
# Cost in iteration 0: 0.00877184163762417
# Final cost : 0.008771433527493827
# Compute control for a deterministic system
# Cost in iteration 0: 0.008771433527493827
# Final cost : 0.00877099005705499
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.011969602446347103
# Final cost : 0.010128604120549686
# Compute control for a deterministic system
# Cost in iteration 0: 0.010128604120549686
# Final cost : 0.010127892751568305
# Compute control for a deterministic system
# Cost in iteration 0: 0.010127892751568305
# Final cost : 0.01012749113409104
# Compute control for a deterministic system
# Cost in iteration 0: 0.01012749113409104
# Final cost : 0.010126932928461844
# Compute control for a deterministic system
# Cost in iteration 0: 0.010126932928461844
# Final cost : 0.010126208778650355
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.028218139448360473
# Final cost : 0.01158072240819246
# Compute control for a deterministic system
# Cost in iteration 0: 0.01158072240819246
# Final cost : 0.011576017306848813
# Compute control for a deterministic system
# Cost in iteration 0: 0.011576017306848813
# Final cost : 0.011575045548472522
# Compute control for a deterministic system
# Cost in iteration 0: 0.011575045548472522
# Final cost : 0.011574012857942744
# Compute control for a deterministic system
# Cost in iteration 0: 0.011574012857942744
# Final cost : 0.01157354207485964
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.014619209020580254
# Final cost : 0.012804970808034223
# Compute control for a deterministic system
# Cost in iteration 0: 0.012804970808034223
# Final cost : 0.01280316851362099
# Compute control for a deterministic system
# Cost in iteration 0: 0.01280316851362099
# Final cost : 0.012802074299857653
# Compute control for a deterministic system
# Cost in iteration 0: 0.012802074299857653
# Final cost : 0.012800348255457915
# Compute control for a deterministic system
# Cost in iteration 0: 0.012800348255457915
# Final cost : 0.012797943298715251
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.0718361422614729
# Final cost : 0.014423814625395269
# Compute control for a deterministic system
# Cost in iteration 0: 0.014423814625395269
# Final cost : 0.014404888733138716
# Compute control for a deterministic system
# Cost in iteration 0: 0.014404888733138716
# Final cost : 0.01440217345093183
# Compute control for a deterministic system
# Cost in iteration 0: 0.01440217345093183
# Final cost : 0.014401380675579483
# Compute control for a deterministic system
# Cost in iteration 0: 0.014401380675579483
# Final cost : 0.01440135071561197
# Compute control for a deterministic system
# Cost in iteration 0: 0.01619510724479906
# Final cost : 0.0160848048652737
# Compute control for a deterministic system
# Cost in iteration 0: 0.0160848048652737
# Final cost : 0.01608352841673172
# Compute control for a deterministic system
# Cost in iteration 0: 0.01608352841673172
# Final cost : 0.016083426719288467
# Compute control for a deterministic system
# Cost in iteration 0: 0.016083426719288467
# Final cost : 0.016083383090238386
# Compute control for a deterministic system
# Cost in iteration 0: 0.016083383090238386
# Final cost : 0.016083376222727055
# Compute control for a deterministic system
# Cost in iteration 0: 0.02481703541547608
# Final cost : 0.017506070955124197
# Compute control for a deterministic system
# Cost in iteration 0: 0.017506070955124197
# Final cost : 0.01749612316013365
# Compute control for a deterministic system
# Cost in iteration 0: 0.01749612316013365
# Final cost : 0.017492835410383586
# Compute control for a deterministic system
# Cost in iteration 0: 0.017492835410383586
# Final cost : 0.01748880762051254
# Compute control for a deterministic system
# Cost in iteration 0: 0.01748880762051254
# Final cost : 0.017482629965353394
# Compute control for a deterministic system
# Cost in iteration 0: 0.027033092341027326
# Final cost : 0.017985358997118187
# Compute control for a deterministic system
# Cost in iteration 0: 0.017985358997118187
# Final cost : 0.01797646155113005
# Compute control for a deterministic system
# Cost in iteration 0: 0.01797646155113005
# Final cost : 0.017972140852234513
# Compute control for a deterministic system
# Cost in iteration 0: 0.017972140852234513
# Final cost : 0.017967549586317362
# Compute control for a deterministic system
# Cost in iteration 0: 0.017967549586317362
# Final cost : 0.0179626740447168
# Compute control for a deterministic system
# Cost in iteration 0: 0.018132192913616344
# Final cost : 0.015936417592859454
# Compute control for a deterministic system
# Cost in iteration 0: 0.015936417592859454
# Final cost : 0.01593336869390148
# Compute control for a deterministic system
# Cost in iteration 0: 0.01593336869390148
# Final cost : 0.01593200049271548
# Compute control for a deterministic system
# Cost in iteration 0: 0.01593200049271548
# Final cost : 0.01593067410048394
# Compute control for a deterministic system
# Cost in iteration 0: 0.01593067410048394
# Final cost : 0.015929337177458328
# Compute control for a deterministic system
# Cost in iteration 0: 0.017198858157048063
# Final cost : 0.014042268110925956
# Compute control for a deterministic system
# Cost in iteration 0: 0.014042268110925956
# Final cost : 0.014040305917521735
# Compute control for a deterministic system
# Cost in iteration 0: 0.014040305917521735
# Final cost : 0.014039436183634776
# Compute control for a deterministic system
# Cost in iteration 0: 0.014039436183634776
# Final cost : 0.014038627970505145
# Compute control for a deterministic system
# Cost in iteration 0: 0.014038627970505145
# Final cost : 0.014037911868911079
# Compute control for a deterministic system
# Cost in iteration 0: 0.01451278039313783
# Final cost : 0.012626147650743382
# Compute control for a deterministic system
# Cost in iteration 0: 0.012626147650743382
# Final cost : 0.01262447500844379
# Compute control for a deterministic system
# Cost in iteration 0: 0.01262447500844379
# Final cost : 0.01262387478349961
# Compute control for a deterministic system
# Cost in iteration 0: 0.01262387478349961
# Final cost : 0.012623166551440622
# Compute control for a deterministic system
# Cost in iteration 0: 0.012623166551440622
# Final cost : 0.012622460890156761
# Compute control for a deterministic system
# Cost in iteration 0: 0.01099842147570443
# Final cost : 0.010977011035493077
# Compute control for a deterministic system
# Cost in iteration 0: 0.010977011035493077
# Final cost : 0.01097433309768746
# Compute control for a deterministic system
# Cost in iteration 0: 0.01097433309768746
# Final cost : 0.010972735686633334
# Compute control for a deterministic system
# Cost in iteration 0: 0.010972735686633334
# Final cost : 0.010971136673325683
# Compute control for a deterministic system
# Cost in iteration 0: 0.010971136673325683
# Final cost : 0.010969609765679773
# Compute control for a deterministic system
# Cost in iteration 0: 0.009720776426274886
# Final cost : 0.009443079247743834
# Compute control for a deterministic system
# Cost in iteration 0: 0.009443079247743834
# Final cost : 0.009440790997661078
# Compute control for a deterministic system
# Cost in iteration 0: 0.009440790997661078
# Final cost : 0.00943966608198931
# Compute control for a deterministic system
# Cost in iteration 0: 0.00943966608198931
# Final cost : 0.00943850669296781
# Compute control for a deterministic system
# Cost in iteration 0: 0.00943850669296781
# Final cost : 0.009437533501632709
# Compute control for a deterministic system
# Cost in iteration 0: 0.009832010644423623
# Final cost : 0.00802834767754538
# Compute control for a deterministic system
# Cost in iteration 0: 0.00802834767754538
# Final cost : 0.008026571344364955
# Compute control for a deterministic system
# Cost in iteration 0: 0.008026571344364955
# Final cost : 0.008025867077984802
# Compute control for a deterministic system
# Cost in iteration 0: 0.008025867077984802
# Final cost : 0.00802518366093907
# Compute control for a deterministic system
# Cost in iteration 0: 0.00802518366093907
# Final cost : 0.008024647603928053
# Compute control for a deterministic system
# Cost in iteration 0: 0.016598387525601284
# Final cost : 0.006984106274010757
# Compute control for a deterministic system
# Cost in iteration 0: 0.006984106274010757
# Final cost : 0.006982117355373686
# Compute control for a deterministic system
# Cost in iteration 0: 0.006982117355373686
# Final cost : 0.006981463195838991
# Compute control for a deterministic system
# Cost in iteration 0: 0.006981463195838991
# Final cost : 0.006980785363002309
# Compute control for a deterministic system
# Cost in iteration 0: 0.006980785363002309
# Final cost : 0.0069803425794915655
# Compute control for a deterministic system
# Cost in iteration 0: 0.005845847907438806
# Final cost : 0.005784583701462486
# Compute control for a deterministic system
# Cost in iteration 0: 0.005784583701462486
# Final cost : 0.00578328374988254
# Compute control for a deterministic system
# Cost in iteration 0: 0.00578328374988254
# Final cost : 0.005782830008308366
# Compute control for a deterministic system
# Cost in iteration 0: 0.005782830008308366
# Final cost : 0.005782417717141831
# Compute control for a deterministic system
# Cost in iteration 0: 0.005782417717141831
# Final cost : 0.0057821760355183495
# Compute control for a deterministic system
# Cost in iteration 0: 0.007219935832239831
# Final cost : 0.004703839891236811
# Compute control for a deterministic system
# Cost in iteration 0: 0.004703839891236811
# Final cost : 0.004702768869247722
# Compute control for a deterministic system
# Cost in iteration 0: 0.004702768869247722
# Final cost : 0.004702514167910603
# Compute control for a deterministic system
# Cost in iteration 0: 0.004702514167910603
# Final cost : 0.004702310904174929
# Compute control for a deterministic system
# Cost in iteration 0: 0.004702310904174929
# Final cost : 0.004702203872566041
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039453477089379015
# Final cost : 0.003923472675535265
# Compute control for a deterministic system
# Cost in iteration 0: 0.003923472675535265
# Final cost : 0.003922671650314424
# Compute control for a deterministic system
# Cost in iteration 0: 0.003922671650314424
# Final cost : 0.003922457016962214
# Compute control for a deterministic system
# Cost in iteration 0: 0.003922457016962214
# Final cost : 0.003922291797975733
# Compute control for a deterministic system
# Cost in iteration 0: 0.003922291797975733
# Final cost : 0.003922207923019362
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035248729637630824
# Final cost : 0.0030513328711135167
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030513328711135167
# Final cost : 0.0030507630908922835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030507630908922835
# Final cost : 0.0030506253203047237
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030506253203047237
# Final cost : 0.0030505326750482867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030505326750482867
# Final cost : 0.0030504937594624474
# Compute control for a deterministic system
# Cost in iteration 0: 0.00684652349937589
# Final cost : 0.002292160028103372
# Compute control for a deterministic system
# Cost in iteration 0: 0.002292160028103372
# Final cost : 0.0022917911993627564
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022917911993627564
# Final cost : 0.0022917039649335727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022917039649335727
# Final cost : 0.002291650746292971
# Compute control for a deterministic system
# Cost in iteration 0: 0.002291650746292971
# Final cost : 0.0022916332401568644
# Compute control for a deterministic system
# Cost in iteration 0: 0.004075834806646071
# Final cost : 0.0016442412458658679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016442412458658679
# Final cost : 0.0016437904903984718
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016437904903984718
# Final cost : 0.0016437414181078183
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016437414181078183
# Final cost : 0.0016437209467932991
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016437209467932991
# Final cost : 0.001643715392800579
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013366432754815223
# Final cost : 0.0012043830651247945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012043830651247945
# Final cost : 0.0012041702630756891
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012041702630756891
# Final cost : 0.00120414154512553
# Compute control for a deterministic system
# Cost in iteration 0: 0.00120414154512553
# Final cost : 0.0012041298323784166
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012041298323784166
# Final cost : 0.0012041277642861677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007983817863713688
# Final cost : 0.000752047771242267
# Compute control for a deterministic system
# Cost in iteration 0: 0.000752047771242267
# Final cost : 0.0007518913547064226
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007518913547064226
# Final cost : 0.0007518753629149241
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007518753629149241
# Final cost : 0.0007518698286464868
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007518698286464868
# Final cost : 0.0007518692549448391
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009017722931690745
# Final cost : 0.00040657564009932885
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040657564009932885
# Final cost : 0.0004065184669926159
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004065184669926159
# Final cost : 0.00040651130223652414
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040651130223652414
# Final cost : 0.00040650963035478415
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040650963035478415
# Final cost : 0.00040650956094436056
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030260989913455963
# Final cost : 0.00016706931015065575
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016706931015065575
# Final cost : 0.00016702689887284082
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016702689887284082
# Final cost : 0.00016702353438750138
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016702353438750138
# Final cost : 0.00016702264260813954
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016702264260813954
# Final cost : 0.00016702261108274735
# Compute control for a deterministic system
# Cost in iteration 0: 8.554934312263849e-05
# Final cost : 5.1075738126685256e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1075738126685256e-05
# Final cost : 5.1067757069262204e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1067757069262204e-05
# Final cost : 5.1066891516613715e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.1066891516613715e-05
# Final cost : 5.106666401386237e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.106666401386237e-05
# Final cost : 5.106665342803603e-05

# %%
save(results_min)
