# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,164], wc.inh[0,164]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 18.896551724137932
# minima =  [  33  221  410  599  788  977 1166 1355 1544 1733 1922 2111 2300 2489
#  2678 2867 3055 3244 3433 3622 3811 4000 4189 4378 4567 4756 4945 5134
#  5323 5512 5701 5890]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            break

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.048693665900400876
# Converged in iteration 144 with cost 0.01997930694139443 because of vanishing difference
# Final cost : 0.01997930694139443
# Compute control for a deterministic system
# Cost in iteration 0: 0.01997930694139443
# Converged in iteration 35 with cost 0.019979306651068757 because of step counter
# Final cost : 0.019979306651068757
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306651068757
# Converged in iteration 1 with cost 0.019979306651068757 because of step counter
# Final cost : 0.019979306651068757
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306651068757
# Converged in iteration 1 with cost 0.019979306651068757 because of step counter
# Final cost : 0.019979306651068757
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306651068757
# Converged in iteration 1 with cost 0.019979306651068757 because of step counter
# Final cost : 0.019979306651068757
# Compute control for a deterministic system
# Cost in iteration 0: 0.06895302694890731
# Cost in iteration 200: 0.03157322678666097
# Final cost : 0.03157322678666097
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157322678666097
# Converged in iteration 83 with cost 0.03157321782598729 because of step counter
# Final cost : 0.03157321782598729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321782598729
# Converged in iteration 5 with cost 0.03157321782598656 because of step counter
# Final cost : 0.03157321782598656
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321782598656
# Converged in iteration 1 with cost 0.03157321782598656 because of step counter
# Final cost : 0.03157321782598656
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321782598656
# Converged in iteration 1 with cost 0.03157321782598656 because of step counter
# Final cost : 0.03157321782598656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0770796677769289
# Cost in iteration 200: 0.04318968435927238
# Final cost : 0.04318968435927238
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318968435927238
# Converged in iteration 160 with cost 0.04318944730897166 because of step counter
# Final cost : 0.04318944730897166
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944730897166
# Converged in iteration 2 with cost 0.04318944730897122 because of step counter
# Final cost : 0.04318944730897122
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944730897122
# Converged in iteration 1 with cost 0.04318944730897122 because of step counter
# Final cost : 0.04318944730897122
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944730897122
# Converged in iteration 1 with cost 0.04318944730897122 because of step counter
# Final cost : 0.04318944730897122
# Compute control for a deterministic system
# Cost in iteration 0: 0.09091031375078401
# Cost in iteration 200: 0.054821501117426355
# Final cost : 0.054821501117426355
# Compute control for a deterministic system
# Cost in iteration 0: 0.054821501117426355
# Converged in iteration 51 with cost 0.05481958987071454 because of vanishing difference
# Final cost : 0.05481958987071454
# Compute control for a deterministic system
# Cost in iteration 0: 0.05481958987071454
# Converged in iteration 47 with cost 0.05481956856974454 because of vanishing difference
# Final cost : 0.05481956856974454
# Compute control for a deterministic system
# Cost in iteration 0: 0.05481956856974454
# Converged in iteration 9 with cost 0.05481956856973681 because of step counter
# Final cost : 0.05481956856973681
# Compute control for a deterministic system
# Cost in iteration 0: 0.05481956856973681
# Converged in iteration 9 with cost 0.05481956856973427 because of step counter
# Final cost : 0.05481956856973427
# Compute control for a deterministic system
# Cost in iteration 0: 0.09490121905050809
# Cost in iteration 200: 0.06413374402256188
# Final cost : 0.06413374402256188
# Compute control for a deterministic system
# Cost in iteration 0: 0.06413374402256188
# Converged in iteration 47 with cost 0.06412976557699114 because of vanishing difference
# Final cost : 0.06412976557699114
# Compute control for a deterministic system
# Cost in iteration 0: 0.06412976557699114
# Converged in iteration 87 with cost 0.06412963933357951 because of step counter
# Final cost : 0.06412963933357951
# Compute control for a deterministic system
# Cost in iteration 0: 0.06412963933357951
# Converged in iteration 1 with cost 0.06412963933357951 because of step counter
# Final cost : 0.06412963933357951
# Compute control for a deterministic system
# Cost in iteration 0: 0.06412963933357951
# Converged in iteration 1 with cost 0.06412963933357951 because of step counter
# Final cost : 0.06412963933357951
# Compute control for a deterministic system
# Cost in iteration 0: 0.11573508076622784
# Cost in iteration 200: 0.07578645901014425
# Final cost : 0.07578645901014425
# Compute control for a deterministic system
# Cost in iteration 0: 0.07578645901014425
# Converged in iteration 98 with cost 0.07577074374514564 because of vanishing difference
# Final cost : 0.07577074374514564
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577074374514564
# Converged in iteration 138 with cost 0.0757706225102357 because of step counter
# Final cost : 0.0757706225102357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0757706225102357
# Converged in iteration 3 with cost 0.07577062251023556 because of step counter
# Final cost : 0.07577062251023556
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577062251023556
# Converged in iteration 1 with cost 0.07577062251023556 because of step counter
# Final cost : 0.07577062251023556
# Compute control for a deterministic system
# Cost in iteration 0: 0.11241984925615289
# Cost in iteration 200: 0.08744479055588386
# Final cost : 0.08744479055588386
# Compute control for a deterministic system
# Cost in iteration 0: 0.08744479055588386
# Cost in iteration 200: 0.08741183773363796
# Final cost : 0.08741183773363796
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741183773363796
# Cost in iteration 200: 0.08741181787225223
# Final cost : 0.08741181787225223
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741181787225223
# Converged in iteration 1 with cost 0.08741181787225223 because of step counter
# Final cost : 0.08741181787225223
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741181787225223
# Converged in iteration 2 with cost 0.08741181787225187 because of step counter
# Final cost : 0.08741181787225187
# Compute control for a deterministic system
# Cost in iteration 0: 0.12197328748554692
# Cost in iteration 200: 0.09910754509934576
# Final cost : 0.09910754509934576
# Compute control for a deterministic system
# Cost in iteration 0: 0.09910754509934576
# Converged in iteration 123 with cost 0.0990519928076879 because of vanishing difference
# Final cost : 0.0990519928076879
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990519928076879
# Cost in iteration 200: 0.09905072513981839
# Final cost : 0.09905072513981839
# Compute control for a deterministic system
# Cost in iteration 0: 0.09905072513981839
# Cost in iteration 200: 0.09905072512973817
# Converged in iteration 209 with cost 0.09905072512973527 because of step counter
# Final cost : 0.09905072512973527
# Compute control for a deterministic system
# Cost in iteration 0: 0.09905072512973527
# Converged in iteration 17 with cost 0.09905072512972637 because of step counter
# Final cost : 0.09905072512972637
# Compute control for a deterministic system
# Cost in iteration 0: 0.1508635325217812
# Cost in iteration 200: 0.1084136445894498
# Final cost : 0.1084136445894498
# Compute control for a deterministic system
# Cost in iteration 0: 0.1084136445894498
# Cost in iteration 200: 0.10835931328736013
# Final cost : 0.10835931328736013
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835931328736013
# Cost in iteration 200: 0.10835892320868057
# Final cost : 0.10835892320868057
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892320868057
# Cost in iteration 200: 0.10835892311565914
# Converged in iteration 325 with cost 0.10835892311519618 because of step counter
# Final cost : 0.10835892311519618
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892311519618
# Converged in iteration 17 with cost 0.10835892311518829 because of step counter
# Final cost : 0.10835892311518829
# Compute control for a deterministic system
# Cost in iteration 0: 0.1511855782437398
# Cost in iteration 200: 0.12010273961929138
# Final cost : 0.12010273961929138
# Compute control for a deterministic system
# Cost in iteration 0: 0.12010273961929138
# Cost in iteration 200: 0.11999066998274331
# Final cost : 0.11999066998274331
# Compute control for a deterministic system
# Cost in iteration 0: 0.11999066998274331
# Cost in iteration 200: 0.11998897815513328
# Final cost : 0.11998897815513328
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897815513328
# Cost in iteration 200: 0.11998897618824919
# Cost in iteration 400: 0.11998897615969596
# Final cost : 0.11998897615969596
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897615969596
# Converged in iteration 126 with cost 0.11998897615925293 because of step counter
# Final cost : 0.11998897615925293
# Compute control for a deterministic system
# Cost in iteration 0: 0.2086883186384005
# Cost in iteration 200: 0.13176751102701345
# Final cost : 0.13176751102701345
# Compute control for a deterministic system
# Cost in iteration 0: 0.13176751102701345
# Cost in iteration 200: 0.13161545804471536
# Final cost : 0.13161545804471536
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161545804471536
# Cost in iteration 200: 0.13161143039884854
# Final cost : 0.13161143039884854
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161143039884854
# Cost in iteration 200: 0.13161141500870444
# Cost in iteration 400: 0.13161141461527945
# Final cost : 0.13161141461527945
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161141461527945
# Cost in iteration 200: 0.13161141460620726
# Converged in iteration 346 with cost 0.13161141460581663 because of vanishing difference
# Final cost : 0.13161141460581663
# Compute control for a deterministic system
# Cost in iteration 0: 0.1875111327281588
# Cost in iteration 200: 0.14102390158104217
# Final cost : 0.14102390158104217
# Compute control for a deterministic system
# Cost in iteration 0: 0.14102390158104217
# Cost in iteration 200: 0.14090745072985889
# Final cost : 0.14090745072985889
# Compute control for a deterministic system
# Cost in iteration 0: 0.14090745072985889
# Cost in iteration 200: 0.14090241604737572
# Final cost : 0.14090241604737572
# Compute control for a deterministic system
# Cost in iteration 0: 0.14090241604737572
# Cost in iteration 200: 0.14090237433617292
# Cost in iteration 400: 0.14090237226039168
# Final cost : 0.14090237226039168
# Compute control for a deterministic system
# Cost in iteration 0: 0.14090237226039168
# Cost in iteration 200: 0.14090237215239235
# Cost in iteration 400: 0.1409023721448014
# Converged in iteration 480 with cost 0.14090237214442702 because of vanishing difference
# Final cost : 0.14090237214442702
# Compute control for a deterministic system
# Cost in iteration 0: 0.262293911213919
# Cost in iteration 200: 0.15273767443020403
# Final cost : 0.15273767443020403
# Compute control for a deterministic system
# Cost in iteration 0: 0.15273767443020403
# Cost in iteration 200: 0.15251846977360542
# Final cost : 0.15251846977360542
# Compute control for a deterministic system
# Cost in iteration 0: 0.15251846977360542
# Converged in iteration 14 with cost 0.15251565100823847 because of vanishing difference
# Final cost : 0.15251565100823847
# Compute control for a deterministic system
# Cost in iteration 0: 0.15251565100823847
# Cost in iteration 200: 0.15250566606547042
# Cost in iteration 400: 0.15250485411224923
# Final cost : 0.15250485411224923
# Compute control for a deterministic system
# Cost in iteration 0: 0.15250485411224923
# Cost in iteration 200: 0.15250478953268723
# Cost in iteration 400: 0.15250478260792935
# Cost in iteration 600: 0.15250478184844155
# Cost in iteration 800: 0.15250478176498328
# Cost in iteration 1000: 0.15250478175576335
# Final cost : 0.15250478175576335
# Compute control for a deterministic system
# Cost in iteration 0: 0.22276906049349654
# Cost in iteration 200: 0.16435609149797314
# Final cost : 0.16435609149797314
# Compute control for a deterministic system
# Cost in iteration 0: 0.16435609149797314
# Cost in iteration 200: 0.16411270678707338
# Final cost : 0.16411270678707338
# Compute control for a deterministic system
# Cost in iteration 0: 0.16411270678707338
# Cost in iteration 200: 0.1640904660803169
# Final cost : 0.1640904660803169
# Compute control for a deterministic system
# Cost in iteration 0: 0.1640904660803169
# Cost in iteration 200: 0.16408977326850843
# Cost in iteration 400: 0.16408968466446383
# Final cost : 0.16408968466446383
# Compute control for a deterministic system
# Cost in iteration 0: 0.16408968466446383
# Cost in iteration 200: 0.16408967313590495
# Cost in iteration 400: 0.1640896713401423
# Cost in iteration 600: 0.16408967106004999
# Cost in iteration 800: 0.1640896710162912
# Cost in iteration 1000: 0.16408967100941638
# Final cost : 0.16408967100941638
# Compute control for a deterministic system
# Cost in iteration 0: 0.2110983415881133
# Cost in iteration 200: 0.17594178196031127
# Final cost : 0.17594178196031127
# Compute control for a deterministic system
# Cost in iteration 0: 0.17594178196031127
# Cost in iteration 200: 0.17567922500957617
# Final cost : 0.17567922500957617
# Compute control for a deterministic system
# Cost in iteration 0: 0.17567922500957617
# Cost in iteration 200: 0.17564737801408645
# Final cost : 0.17564737801408645
# Compute control for a deterministic system
# Cost in iteration 0: 0.17564737801408645
# Cost in iteration 200: 0.175645866122748
# Cost in iteration 400: 0.17564560508831917
# Final cost : 0.17564560508831917
# Compute control for a deterministic system
# Cost in iteration 0: 0.17564560508831917
# Cost in iteration 200: 0.17564556006490303
# Cost in iteration 400: 0.17564555078430105
# Cost in iteration 600: 0.17564554886252315
# Cost in iteration 800: 0.17564554847050196
# Cost in iteration 1000: 0.17564554838974872
# Final cost : 0.17564554838974872
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.23748177771705442
# Cost in iteration 200: 0.18506428533017805
# Final cost : 0.18506428533017805
# Compute control for a deterministic system
# Cost in iteration 0: 0.18506428533017805
# Cost in iteration 200: 0.18487943719217773
# Final cost : 0.18487943719217773
# Compute control for a deterministic system
# Cost in iteration 0: 0.18487943719217773
# Cost in iteration 200: 0.18485315780975994
# Final cost : 0.18485315780975994
# Compute control for a deterministic system
# Cost in iteration 0: 0.18485315780975994
# Cost in iteration 200: 0.18485130950423212
# Cost in iteration 400: 0.18485091921613997
# Final cost : 0.18485091921613997
# Compute control for a deterministic system
# Cost in iteration 0: 0.18485091921613997
# Cost in iteration 200: 0.1848508370375891
# Cost in iteration 400: 0.1848508168855315
# Cost in iteration 600: 0.18485081192916286
# Cost in iteration 800: 0.1848508106984016
# Cost in iteration 1000: 0.1848508103949001
# Final cost : 0.1848508103949001
# Compute control for a deterministic system
# Cost in iteration 0: 0.3547613390739772
# Cost in iteration 200: 0.1966246490716695
# Final cost : 0.1966246490716695
# Compute control for a deterministic system
# Cost in iteration 0: 0.1966246490716695
# Cost in iteration 200: 0.1963091036288666
# Final cost : 0.1963091036288666
# Compute control for a deterministic system
# Cost in iteration 0: 0.1963091036288666
# Cost in iteration 200: 0.19626170410250318
# Final cost : 0.19626170410250318
# Compute control for a deterministic system
# Cost in iteration 0: 0.19626170410250318
# Cost in iteration 200: 0.1962579230861111
# Cost in iteration 400: 0.19625695771670196
# Final cost : 0.19625695771670196
# Compute control for a deterministic system
# Cost in iteration 0: 0.19625695771670196
# Cost in iteration 200: 0.1962567162924809
# Cost in iteration 400: 0.19625664578921143
# Cost in iteration 600: 0.19625662502204294
# Cost in iteration 800: 0.19625661889585094
# Cost in iteration 1000: 0.19625661707331007
# Final cost : 0.19625661707331007
# Compute control for a deterministic system
# Cost in iteration 0: 0.2317963098304807
# Cost in iteration 200: 0.20782520220248873
# Final cost : 0.20782520220248873
# Compute control for a deterministic system
# Cost in iteration 0: 0.20782520220248873
# Cost in iteration 200: 0.2075353394759467
# Final cost : 0.2075353394759467
# Compute control for a deterministic system
# Cost in iteration 0: 0.2075353394759467
# Converged in iteration 18 with cost 0.20752337563414797 because of vanishing difference
# Final cost : 0.20752337563414797
# Compute control for a deterministic system
# Cost in iteration 0: 0.20752337563414797
# Cost in iteration 200: 0.20748639906635888
# Cost in iteration 400: 0.2074768084544387
# Final cost : 0.2074768084544387
# Compute control for a deterministic system
# Cost in iteration 0: 0.2074768084544387
# Cost in iteration 200: 0.20747433242235108
# Cost in iteration 400: 0.20747350887946514
# Cost in iteration 600: 0.20747323191614672
# Cost in iteration 800: 0.20747313820117386
# Cost in iteration 1000: 0.20747310641656833
# Final cost : 0.20747310641656833
# Compute control for a deterministic system
# Cost in iteration 0: 0.29929105922482657
# Cost in iteration 200: 0.21653647657104533
# Final cost : 0.21653647657104533
# Compute control for a deterministic system
# Cost in iteration 0: 0.21653647657104533
# Cost in iteration 200: 0.21634337008102708
# Final cost : 0.21634337008102708
# Compute control for a deterministic system
# Cost in iteration 0: 0.21634337008102708
# Cost in iteration 200: 0.2163050665778498
# Final cost : 0.2163050665778498
# Compute control for a deterministic system
# Cost in iteration 0: 0.2163050665778498
# Cost in iteration 200: 0.21630077831837397
# Cost in iteration 400: 0.21629944445698585
# Final cost : 0.21629944445698585
# Compute control for a deterministic system
# Cost in iteration 0: 0.21629944445698585
# Cost in iteration 200: 0.21629901543941038
# Cost in iteration 400: 0.21629885488912134
# Cost in iteration 600: 0.21629879551522765
# Cost in iteration 800: 0.21629877340035222
# Cost in iteration 1000: 0.21629876510061305
# Final cost : 0.21629876510061305
# Compute control for a deterministic system
# Cost in iteration 0: 0.2376065766052496
# Cost in iteration 200: 0.22760023860478928
# Final cost : 0.22760023860478928
# Compute control for a deterministic system
# Cost in iteration 0: 0.22760023860478928
# Cost in iteration 200: 0.22731618610479914
# Final cost : 0.22731618610479914
# Compute control for a deterministic system
# Cost in iteration 0: 0.22731618610479914
# Converged in iteration 33 with cost 0.22729333353365358 because of vanishing difference
# Final cost : 0.22729333353365358
# Compute control for a deterministic system
# Cost in iteration 0: 0.22729333353365358
# Cost in iteration 200: 0.2272568260563944
# Cost in iteration 400: 0.22724508722385373
# Final cost : 0.22724508722385373
# Compute control for a deterministic system
# Cost in iteration 0: 0.22724508722385373
# Cost in iteration 200: 0.22724116172935915
# Cost in iteration 400: 0.22723957282308765
# Cost in iteration 600: 0.22723892294117803
# Cost in iteration 800: 0.22723865509036026
# Cost in iteration 1000: 0.22723854426069123
# Final cost : 0.22723854426069123
# Compute control for a deterministic system
# Cost in iteration 0: 0.2470855988646501
# Cost in iteration 200: 0.20192628061968057
# Final cost : 0.20192628061968057
# Compute control for a deterministic system
# Cost in iteration 0: 0.20192628061968057
# Cost in iteration 200: 0.20154699310060087
# Final cost : 0.20154699310060087
# Compute control for a deterministic system
# Cost in iteration 0: 0.20154699310060087
# Cost in iteration 200: 0.20148208206550508
# Final cost : 0.20148208206550508
# Compute control for a deterministic system
# Cost in iteration 0: 0.20148208206550508
# Cost in iteration 200: 0.20147662066533317
# Cost in iteration 400: 0.20147540577312842
# Final cost : 0.20147540577312842
# Compute control for a deterministic system
# Cost in iteration 0: 0.20147540577312842
# Cost in iteration 200: 0.20147516614788644
# Cost in iteration 400: 0.2014751070609891
# Cost in iteration 600: 0.20147509243821088
# Cost in iteration 800: 0.2014750888300601
# Cost in iteration 1000: 0.2014750879320122
# Final cost : 0.2014750879320122
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.23977212366185918
# Cost in iteration 200: 0.18959052113344868
# Final cost : 0.18959052113344868
# Compute control for a deterministic system
# Cost in iteration 0: 0.18959052113344868
# Cost in iteration 200: 0.18924802180451566
# Final cost : 0.18924802180451566
# Compute control for a deterministic system
# Cost in iteration 0: 0.18924802180451566
# Cost in iteration 200: 0.18919497060295798
# Final cost : 0.18919497060295798
# Compute control for a deterministic system
# Cost in iteration 0: 0.18919497060295798
# Cost in iteration 200: 0.18919237154313234
# Cost in iteration 400: 0.1891919412385898
# Final cost : 0.1891919412385898
# Compute control for a deterministic system
# Cost in iteration 0: 0.1891919412385898
# Cost in iteration 200: 0.18919186544864755
# Cost in iteration 400: 0.18919185040260988
# Cost in iteration 600: 0.18919184747345352
# Cost in iteration 800: 0.1891918468997658
# Cost in iteration 1000: 0.1891918467874811
# Final cost : 0.1891918467874811
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.2491097851525274
# Cost in iteration 200: 0.17963796836907797
# Final cost : 0.17963796836907797
# Compute control for a deterministic system
# Cost in iteration 0: 0.17963796836907797
# Cost in iteration 200: 0.17942705075342918
# Final cost : 0.17942705075342918
# Compute control for a deterministic system
# Cost in iteration 0: 0.17942705075342918
# Converged in iteration 86 with cost 0.17940391404717954 because of vanishing difference
# Final cost : 0.17940391404717954
# Compute control for a deterministic system
# Cost in iteration 0: 0.17940391404717954
# Cost in iteration 200: 0.17939721262403824
# Cost in iteration 400: 0.17939638218844461
# Final cost : 0.17939638218844461
# Compute control for a deterministic system
# Cost in iteration 0: 0.17939638218844461
# Cost in iteration 200: 0.17939628344540043
# Cost in iteration 400: 0.17939626788359378
# Cost in iteration 600: 0.17939626542585976
# Cost in iteration 800: 0.17939626503583517
# Cost in iteration 1000: 0.179396264974873
# Final cost : 0.179396264974873
# Compute control for a deterministic system
# Cost in iteration 0: 0.1994512854174455
# Cost in iteration 200: 0.1674954369334344
# Final cost : 0.1674954369334344
# Compute control for a deterministic system
# Cost in iteration 0: 0.1674954369334344
# Cost in iteration 200: 0.16720815063098252
# Final cost : 0.16720815063098252
# Compute control for a deterministic system
# Cost in iteration 0: 0.16720815063098252
# Cost in iteration 200: 0.1671795490768087
# Final cost : 0.1671795490768087
# Compute control for a deterministic system
# Cost in iteration 0: 0.1671795490768087
# Cost in iteration 200: 0.16717926508049974
# Cost in iteration 400: 0.167179241795541
# Final cost : 0.167179241795541
# Compute control for a deterministic system
# Cost in iteration 0: 0.167179241795541
# Cost in iteration 200: 0.1671792398036113
# Cost in iteration 400: 0.16717923957551908
# Cost in iteration 600: 0.16717923954975458
# Cost in iteration 800: 0.1671792395468255
# Converged in iteration 921 with cost 0.16717923954654915 because of vanishing difference
# Final cost : 0.16717923954654915
# Compute control for a deterministic system
# Cost in iteration 0: 0.18389750042281441
# Cost in iteration 200: 0.15526917265198023
# Final cost : 0.15526917265198023
# Compute control for a deterministic system
# Cost in iteration 0: 0.15526917265198023
# Cost in iteration 200: 0.1550162710933422
# Final cost : 0.1550162710933422
# Compute control for a deterministic system
# Cost in iteration 0: 0.1550162710933422
# Cost in iteration 200: 0.1549997839527159
# Final cost : 0.1549997839527159
# Compute control for a deterministic system
# Cost in iteration 0: 0.1549997839527159
# Cost in iteration 200: 0.15499974469429434
# Cost in iteration 400: 0.1549997430283818
# Final cost : 0.1549997430283818
# Compute control for a deterministic system
# Cost in iteration 0: 0.1549997430283818
# Cost in iteration 200: 0.1549997429597626
# Cost in iteration 400: 0.15499974295460153
# Converged in iteration 445 with cost 0.15499974295441807 because of vanishing difference
# Final cost : 0.15499974295441807
# Compute control for a deterministic system
# Cost in iteration 0: 0.20534817431922003
# Cost in iteration 200: 0.14309966958215356
# Final cost : 0.14309966958215356
# Compute control for a deterministic system
# Cost in iteration 0: 0.14309966958215356
# Cost in iteration 200: 0.14288726100518623
# Final cost : 0.14288726100518623
# Compute control for a deterministic system
# Cost in iteration 0: 0.14288726100518623
# Cost in iteration 200: 0.14287900803273104
# Final cost : 0.14287900803273104
# Compute control for a deterministic system
# Cost in iteration 0: 0.14287900803273104
# Cost in iteration 200: 0.1428790056692052
# Cost in iteration 400: 0.14287900557711244
# Final cost : 0.14287900557711244
# Compute control for a deterministic system
# Cost in iteration 0: 0.14287900557711244
# Cost in iteration 200: 0.14287900557314573
# Converged in iteration 299 with cost 0.1428790055729845 because of vanishing difference
# Final cost : 0.1428790055729845
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.142276777188786
# Cost in iteration 200: 0.13334670137873628
# Final cost : 0.13334670137873628
# Compute control for a deterministic system
# Cost in iteration 0: 0.13334670137873628
# Cost in iteration 200: 0.13323438302728038
# Final cost : 0.13323438302728038
# Compute control for a deterministic system
# Cost in iteration 0: 0.13323438302728038
# Cost in iteration 200: 0.1332318433165397
# Final cost : 0.1332318433165397
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332318433165397
# Cost in iteration 200: 0.13323184321484122
# Cost in iteration 400: 0.13323184321291287
# Final cost : 0.13323184321291287
# Compute control for a deterministic system
# Cost in iteration 0: 0.13323184321291287
# Converged in iteration 20 with cost 0.13323184321289838 because of step counter
# Final cost : 0.13323184321289838
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.14883680165174584
# Cost in iteration 200: 0.12137172948127165
# Final cost : 0.12137172948127165
# Compute control for a deterministic system
# Cost in iteration 0: 0.12137172948127165
# Cost in iteration 200: 0.12123494844465127
# Final cost : 0.12123494844465127
# Compute control for a deterministic system
# Cost in iteration 0: 0.12123494844465127
# Cost in iteration 200: 0.12123346207678296
# Final cost : 0.12123346207678296
# Compute control for a deterministic system
# Cost in iteration 0: 0.12123346207678296
# Converged in iteration 34 with cost 0.1212334620767242 because of vanishing difference
# Final cost : 0.1212334620767242
# Compute control for a deterministic system
# Cost in iteration 0: 0.1212334620767242
# Converged in iteration 21 with cost 0.12123346207671183 because of step counter
# Final cost : 0.12123346207671183
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.125047280165882
# Cost in iteration 200: 0.10939301780880116
# Final cost : 0.10939301780880116
# Compute control for a deterministic system
# Cost in iteration 0: 0.10939301780880116
# Cost in iteration 200: 0.10929584742666226
# Final cost : 0.10929584742666226
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929584742666226
# Converged in iteration 194 with cost 0.10929544764730251 because of step counter
# Final cost : 0.10929544764730251
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929544764730251
# Converged in iteration 4 with cost 0.10929544764730134 because of step counter
# Final cost : 0.10929544764730134
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929544764730134
# Converged in iteration 1 with cost 0.10929544764730134 because of step counter
# Final cost : 0.10929544764730134
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.16186564771578796
# Cost in iteration 200: 0.09982962335472347
# Final cost : 0.09982962335472347
# Compute control for a deterministic system
# Cost in iteration 0: 0.09982962335472347
# Cost in iteration 200: 0.09978259830198478
# Final cost : 0.09978259830198478
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978259830198478
# Converged in iteration 188 with cost 0.09978251358926502 because of vanishing difference
# Final cost : 0.09978251358926502
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978251358926502
# Converged in iteration 1 with cost 0.09978251358926502 because of step counter
# Final cost : 0.09978251358926502
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978251358926502
# Converged in iteration 1 with cost 0.09978251358926502 because of step counter
# Final cost : 0.09978251358926502
# Compute control for a deterministic system
# Cost in iteration 0: 0.13450742098482033
# Cost in iteration 200: 0.08797277463811408
# Final cost : 0.08797277463811408
# Compute control for a deterministic system
# Cost in iteration 0: 0.08797277463811408
# Cost in iteration 200: 0.08793140786930556
# Final cost : 0.08793140786930556
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793140786930556
# Converged in iteration 80 with cost 0.08793139529275171 because of step counter
# Final cost : 0.08793139529275171
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793139529275171
# Converged in iteration 1 with cost 0.08793139529275171 because of step counter
# Final cost : 0.08793139529275171
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793139529275171
# Converged in iteration 1 with cost 0.08793139529275171 because of step counter
# Final cost : 0.08793139529275171
# -----------------------------------------------
# 0 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.09548144118774793
# Cost in iteration 200: 0.07613941278057673
# Final cost : 0.07613941278057673
# Compute control for a deterministic system
# Cost in iteration 0: 0.07613941278057673
# Cost in iteration 200: 0.0761189995988154
# Final cost : 0.0761189995988154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0761189995988154
# Converged in iteration 63 with cost 0.07611899892886792 because of step counter
# Final cost : 0.07611899892886792
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611899892886792
# Converged in iteration 2 with cost 0.07611899892886784 because of step counter
# Final cost : 0.07611899892886784
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611899892886784
# Converged in iteration 2 with cost 0.07611899892886755 because of step counter
# Final cost : 0.07611899892886755
# Compute control for a deterministic system
# Cost in iteration 0: 0.09927463258135721
# Cost in iteration 200: 0.06434908532419928
# Final cost : 0.06434908532419928
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434908532419928
# Cost in iteration 200: 0.06434136582375674
# Final cost : 0.06434136582375674
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136582375674
# Converged in iteration 46 with cost 0.06434136581409775 because of step counter
# Final cost : 0.06434136581409775
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136581409775
# Converged in iteration 1 with cost 0.06434136581409775 because of step counter
# Final cost : 0.06434136581409775
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136581409775
# Converged in iteration 2 with cost 0.0643413658140976 because of step counter
# Final cost : 0.0643413658140976
# -----------------------------------------------
# 0 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.10005314140676194
# Cost in iteration 200: 0.0549447251935522
# Final cost : 0.0549447251935522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0549447251935522
# Cost in iteration 200: 0.05494317251088159
# Final cost : 0.05494317251088159
# Compute control for a deterministic system
# Cost in iteration 0: 0.05494317251088159
# Converged in iteration 23 with cost 0.0549431725108328 because of step counter
# Final cost : 0.0549431725108328
# Compute control for a deterministic system
# Cost in iteration 0: 0.0549431725108328
# Converged in iteration 1 with cost 0.0549431725108328 because of step counter
# Final cost : 0.0549431725108328
# Compute control for a deterministic system
# Cost in iteration 0: 0.0549431725108328
# Converged in iteration 1 with cost 0.0549431725108328 because of step counter
# Final cost : 0.0549431725108328
# -----------------------------------------------
# 0 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.07147630368679674
# Cost in iteration 200: 0.043226227448373726
# Final cost : 0.043226227448373726
# Compute control for a deterministic system
# Cost in iteration 0: 0.043226227448373726
# Converged in iteration 151 with cost 0.04322590999556615 because of step counter
# Final cost : 0.04322590999556615
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322590999556615
# Converged in iteration 2 with cost 0.04322590999556592 because of step counter
# Final cost : 0.04322590999556592
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322590999556592
# Converged in iteration 5 with cost 0.04322590999556499 because of step counter
# Final cost : 0.04322590999556499
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322590999556499
# Converged in iteration 1 with cost 0.04322590999556499 because of step counter
# Final cost : 0.04322590999556499
# -----------------------------------------------
# 0 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0795207053469864
# Cost in iteration 200: 0.0315456316910916
# Final cost : 0.0315456316910916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315456316910916
# Converged in iteration 72 with cost 0.0315456240121631 because of step counter
# Final cost : 0.0315456240121631
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315456240121631
# Converged in iteration 1 with cost 0.0315456240121631 because of step counter
# Final cost : 0.0315456240121631
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315456240121631
# Converged in iteration 1 with cost 0.0315456240121631 because of step counter
# Final cost : 0.0315456240121631
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315456240121631
# Converged in iteration 5 with cost 0.03154562401216236 because of step counter
# Final cost : 0.03154562401216236
# Compute control for a deterministic system
# Cost in iteration 0: 0.05934171841272445
# Cost in iteration 200: 0.019909000279238025
# Final cost : 0.019909000279238025
# Compute control for a deterministic system
# Cost in iteration 0: 0.019909000279238025
# Converged in iteration 11 with cost 0.01990900027732321 because of step counter
# Final cost : 0.01990900027732321
# Compute control for a deterministic system
# Cost in iteration 0: 0.01990900027732321
# Converged in iteration 2 with cost 0.019909000277322883 because of step counter
# Final cost : 0.019909000277322883
# Compute control for a deterministic system
# Cost in iteration 0: 0.019909000277322883
# Converged in iteration 1 with cost 0.019909000277322883 because of step counter
# Final cost : 0.019909000277322883
# Compute control for a deterministic system
# Cost in iteration 0: 0.019909000277322883
# Converged in iteration 1 with cost 0.019909000277322883 because of step counter
# Final cost : 0.019909000277322883
# Compute control for a deterministic system
# Cost in iteration 0: 0.042176925879734706
# Converged in iteration 135 with cost 0.010638873304057456 because of step counter
# Final cost : 0.010638873304057456
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304057456
# Converged in iteration 1 with cost 0.010638873304057456 because of step counter
# Final cost : 0.010638873304057456
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304057456
# Converged in iteration 1 with cost 0.010638873304057456 because of step counter
# Final cost : 0.010638873304057456
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304057456
# Converged in iteration 2 with cost 0.01063887330405739 because of step counter
# Final cost : 0.01063887330405739
# Compute control for a deterministic system
# Cost in iteration 0: 0.01063887330405739
# Converged in iteration 2 with cost 0.010638873304057387 because of step counter
# Final cost : 0.010638873304057387
# ----------------------------------------------- 1
# cost =  0.019909000277322286
# Compute control for a deterministic system
# Cost in iteration 0: 0.045401723269405767
# Converged in iteration 46 with cost 0.019909010641293655 because of vanishing difference
# Final cost : 0.019909010641293655
# Compute control for a deterministic system
# Cost in iteration 0: 0.019909010641293655
# Cost in iteration 200: 0.019909003935345507
# Final cost : 0.019909003935345507
# Compute control for a deterministic system
# Cost in iteration 0: 0.019909003935345507
# Converged in iteration 7 with cost 0.01990900363950166 because of step counter
# Final cost : 0.01990900363950166
# Compute control for a deterministic system
# Cost in iteration 0: 0.01990900363950166
# Converged in iteration 1 with cost 0.01990900363950166 because of step counter
# Final cost : 0.01990900363950166
# cost =  0.031545624012161114
# Compute control for a deterministic system
# Cost in iteration 0: 0.07826873581893035
# Converged in iteration 151 with cost 0.03154562401216164 because of step counter
# Final cost : 0.03154562401216164
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154562401216164
# Converged in iteration 1 with cost 0.03154562401216164 because of step counter
# Final cost : 0.03154562401216164
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154562401216164
# Converged in iteration 1 with cost 0.03154562401216164 because of step counter
# Final cost : 0.03154562401216164
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154562401216164
# Converged in iteration 1 with cost 0.03154562401216164 because of step counter
# Final cost : 0.03154562401216164
# cost =  0.04322590999556499
# Compute control for a deterministic system
# Cost in iteration 0: 0.0938262360193413
# Cost in iteration 200: 0.04322590999557977
# Final cost : 0.04322590999557977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322590999557977
# Converged in iteration 14 with cost 0.043225909995565324 because of step counter
# Final cost : 0.043225909995565324
# Compute control for a deterministic system
# Cost in iteration 0: 0.043225909995565324
# Converged in iteration 1 with cost 0.043225909995565324 because of step counter
# Final cost : 0.043225909995565324
# Compute control for a deterministic system
# Cost in iteration 0: 0.043225909995565324
# Converged in iteration 2 with cost 0.04322590999556511 because of step counter
# Final cost : 0.04322590999556511
# cost =  0.0549431725108328
# Compute control for a deterministic system
# Cost in iteration 0: 0.10706925157958166
# Cost in iteration 200: 0.05494317252374331
# Final cost : 0.05494317252374331
# Compute control for a deterministic system
# Cost in iteration 0: 0.05494317252374331
# Converged in iteration 39 with cost 0.05494317251083285 because of step counter
# Final cost : 0.05494317251083285
# Compute control for a deterministic system
# Cost in iteration 0: 0.05494317251083285
# Converged in iteration 1 with cost 0.05494317251083285 because of step counter
# Final cost : 0.05494317251083285
# Compute control for a deterministic system
# Cost in iteration 0: 0.05494317251083285
# Converged in iteration 1 with cost 0.05494317251083285 because of step counter
# Final cost : 0.05494317251083285
# cost =  0.0643413658140976
# Compute control for a deterministic system
# Cost in iteration 0: 0.10728035513220244
# Cost in iteration 200: 0.06434136614018995
# Final cost : 0.06434136614018995
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136614018995
# Converged in iteration 64 with cost 0.06434136581409652 because of step counter
# Final cost : 0.06434136581409652
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136581409652
# Converged in iteration 2 with cost 0.06434136581409579 because of step counter
# Final cost : 0.06434136581409579
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434136581409579
# Converged in iteration 1 with cost 0.06434136581409579 because of step counter
# Final cost : 0.06434136581409579
# -----------------------------------------------
# 1 found better solution,  34
# cost =  0.0761189989288667
# Compute control for a deterministic system
# Cost in iteration 0: 0.13674343198412012
# Cost in iteration 200: 0.07611900793100217
# Final cost : 0.07611900793100217
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611900793100217
# Converged in iteration 81 with cost 0.07611899892886716 because of step counter
# Final cost : 0.07611899892886716
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611899892886716
# Converged in iteration 1 with cost 0.07611899892886716 because of step counter
# Final cost : 0.07611899892886716
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611899892886716
# Converged in iteration 1 with cost 0.07611899892886716 because of step counter
# Final cost : 0.07611899892886716
# cost =  0.08793139529275171
# Compute control for a deterministic system
# Cost in iteration 0: 0.11971905549927006
# Cost in iteration 200: 0.08793147171249756
# Final cost : 0.08793147171249756
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793147171249756
# Converged in iteration 90 with cost 0.08793139529275423 because of step counter
# Final cost : 0.08793139529275423
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793139529275423
# Converged in iteration 3 with cost 0.08793139529275401 because of step counter
# Final cost : 0.08793139529275401
# Compute control for a deterministic system
# Cost in iteration 0: 0.08793139529275401
# Converged in iteration 1 with cost 0.08793139529275401 because of step counter
# Final cost : 0.08793139529275401
# cost =  0.09978251220407044
# Compute control for a deterministic system
# Cost in iteration 0: 0.1645043516084334
# Cost in iteration 200: 0.09978351918101439
# Final cost : 0.09978351918101439
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978351918101439
# Cost in iteration 200: 0.09978252038825176
# Final cost : 0.09978252038825176
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978252038825176
# Converged in iteration 22 with cost 0.0997825203882359 because of step counter
# Final cost : 0.0997825203882359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0997825203882359
# Converged in iteration 2 with cost 0.09978252038823558 because of step counter
# Final cost : 0.09978252038823558
# cost =  0.10929544764730134
# Compute control for a deterministic system
# Cost in iteration 0: 0.15403881960689794
# Cost in iteration 200: 0.10929664454474294
# Final cost : 0.10929664454474294
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929664454474294
# Cost in iteration 200: 0.1092954527096451
# Final cost : 0.1092954527096451
# Compute control for a deterministic system
# Cost in iteration 0: 0.1092954527096451
# Converged in iteration 18 with cost 0.10929545270961621 because of step counter
# Final cost : 0.10929545270961621
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929545270961621
# Converged in iteration 1 with cost 0.10929545270961621 because of step counter
# Final cost : 0.10929545270961621
# cost =  0.12123346207671183
# Compute control for a deterministic system
# Cost in iteration 0: 0.15122063574029843
# Cost in iteration 200: 0.12123627362974025
# Final cost : 0.12123627362974025
# Compute control for a deterministic system
# Cost in iteration 0: 0.12123627362974025
# Cost in iteration 200: 0.12123346204360579
# Final cost : 0.12123346204360579
# Compute control for a deterministic system
# Cost in iteration 0: 0.12123346204360579
# Converged in iteration 65 with cost 0.12123346204346461 because of step counter
# Final cost : 0.12123346204346461
# Compute control for a deterministic system
# Cost in iteration 0: 0.12123346204346461
# Converged in iteration 17 with cost 0.12123346204345531 because of step counter
# Final cost : 0.12123346204345531
# -----------------------------------------------
# 1 found better solution,  29
# cost =  0.13323184321289838
# Compute control for a deterministic system
# Cost in iteration 0: 0.22742611780479038
# Cost in iteration 200: 0.13323886817580705
# Final cost : 0.13323886817580705
# Compute control for a deterministic system
# Cost in iteration 0: 0.13323886817580705
# Cost in iteration 200: 0.1332318432191465
# Final cost : 0.1332318432191465
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332318432191465
# Cost in iteration 200: 0.13323184307647362
# Cost in iteration 400: 0.1332318430740544
# Final cost : 0.1332318430740544
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332318430740544
# Converged in iteration 28 with cost 0.13323184307401875 because of step counter
# Final cost : 0.13323184307401875
# -----------------------------------------------
# 1 found better solution,  28
# cost =  0.1428790055729845
# Compute control for a deterministic system
# Cost in iteration 0: 0.20380578296008434
# Cost in iteration 200: 0.14288989459649387
# Final cost : 0.14288989459649387
# Compute control for a deterministic system
# Cost in iteration 0: 0.14288989459649387
# Cost in iteration 200: 0.14287900922172472
# Final cost : 0.14287900922172472
# Compute control for a deterministic system
# Cost in iteration 0: 0.14287900922172472
# Cost in iteration 200: 0.1428790073619436
# Cost in iteration 400: 0.142879007284723
# Final cost : 0.142879007284723
# Compute control for a deterministic system
# Cost in iteration 0: 0.142879007284723
# Cost in iteration 200: 0.14287900728136282
# Converged in iteration 217 with cost 0.14287900728132585 because of vanishing difference
# Final cost : 0.14287900728132585
# cost =  0.15499974094262028
# Compute control for a deterministic system
# Cost in iteration 0: 0.19040877981188792
# Cost in iteration 200: 0.15502294192508387
# Final cost : 0.15502294192508387
# Compute control for a deterministic system
# Cost in iteration 0: 0.15502294192508387
# Cost in iteration 200: 0.15499976821546602
# Final cost : 0.15499976821546602
# Compute control for a deterministic system
# Cost in iteration 0: 0.15499976821546602
# Cost in iteration 200: 0.15499975649752595
# Cost in iteration 400: 0.15499975605590144
# Final cost : 0.15499975605590144
# Compute control for a deterministic system
# Cost in iteration 0: 0.15499975605590144
# Cost in iteration 200: 0.1549997560386092
# Cost in iteration 400: 0.15499975603728577
# Converged in iteration 457 with cost 0.15499975603722843 because of step counter
# Final cost : 0.15499975603722843
# cost =  0.16717923917862096
# Compute control for a deterministic system
# Cost in iteration 0: 0.2772960263320454
# Cost in iteration 200: 0.16721118609964364
# ...
# Converged in iteration 112 with cost 0.010638873304058945 because of step counter
# Final cost : 0.010638873304058945
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304058945
# Converged in iteration 8 with cost 0.010638873304056927 because of step counter
# Final cost : 0.010638873304056927
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304056927
# Converged in iteration 2 with cost 0.010638873304056563 because of step counter
# Final cost : 0.010638873304056563
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304056563
# Converged in iteration 1 with cost 0.010638873304056563 because of step counter
# Final cost : 0.010638873304056563
# Compute control for a deterministic system
# Cost in iteration 0: 0.010638873304056563
# Converged in iteration 1 with cost 0.010638873304056563 because of step counter
# Final cost : 0.010638873304056563
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.010738090060658602
# Converged in iteration 67 with cost 0.010728754451780571 because of step counter
# Final cost : 0.010728754451780571
# Compute control for a deterministic system
# Cost in iteration 0: 0.010728754451780571
# Converged in iteration 5 with cost 0.010728754451777784 because of step counter
# Final cost : 0.010728754451777784
# Compute control for a deterministic system
# Cost in iteration 0: 0.010728754451777784
# Converged in iteration 1 with cost 0.010728754451777784 because of step counter
# Final cost : 0.010728754451777784
# Compute control for a deterministic system
# Cost in iteration 0: 0.010728754451777784
# Converged in iteration 1 with cost 0.010728754451777784 because of step counter
# Final cost : 0.010728754451777784
# Compute control for a deterministic system
# Cost in iteration 0: 0.010728754451777784
# Converged in iteration 1 with cost 0.010728754451777784 because of step counter
# Final cost : 0.010728754451777784
# Compute control for a deterministic system
# Cost in iteration 0: 0.020218706499948644
# Converged in iteration 148 with cost 0.01997930622924049 because of step counter
# Final cost : 0.01997930622924049
# Compute control for a deterministic system
# Cost in iteration 0: 0.01997930622924049
# Converged in iteration 10 with cost 0.019979306229234925 because of step counter
# Final cost : 0.019979306229234925
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306229234925
# Converged in iteration 1 with cost 0.019979306229234925 because of step counter
# Final cost : 0.019979306229234925
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306229234925
# Converged in iteration 1 with cost 0.019979306229234925 because of step counter
# Final cost : 0.019979306229234925
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979306229234925
# Converged in iteration 1 with cost 0.019979306229234925 because of step counter
# Final cost : 0.019979306229234925
# Compute control for a deterministic system
# Cost in iteration 0: 0.031575261330006765
# Converged in iteration 144 with cost 0.03157321762049484 because of step counter
# Final cost : 0.03157321762049484
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321762049484
# Converged in iteration 8 with cost 0.03157321762047373 because of step counter
# Final cost : 0.03157321762047373
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321762047373
# Converged in iteration 1 with cost 0.03157321762047373 because of step counter
# Final cost : 0.03157321762047373
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321762047373
# Converged in iteration 1 with cost 0.03157321762047373 because of step counter
# Final cost : 0.03157321762047373
# Compute control for a deterministic system
# Cost in iteration 0: 0.03157321762047373
# Converged in iteration 1 with cost 0.03157321762047373 because of step counter
# Final cost : 0.03157321762047373
# Compute control for a deterministic system
# Cost in iteration 0: 0.04353921111330562
# Cost in iteration 200: 0.04318944559079048
# Final cost : 0.04318944559079048
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944559079048
# Converged in iteration 40 with cost 0.04318944558875112 because of step counter
# Final cost : 0.04318944558875112
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944558875112
# Converged in iteration 3 with cost 0.04318944558875075 because of step counter
# Final cost : 0.04318944558875075
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944558875075
# Converged in iteration 2 with cost 0.04318944558874988 because of step counter
# Final cost : 0.04318944558874988
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318944558874988
# Converged in iteration 1 with cost 0.04318944558874988 because of step counter
# Final cost : 0.04318944558874988
# Compute control for a deterministic system
# Cost in iteration 0: 0.05528667192463049
# Cost in iteration 200: 0.054819564864248806
# Final cost : 0.054819564864248806
# Compute control for a deterministic system
# Cost in iteration 0: 0.054819564864248806
# Converged in iteration 89 with cost 0.0548195648504597 because of step counter
# Final cost : 0.0548195648504597
# Compute control for a deterministic system
# Cost in iteration 0: 0.0548195648504597
# Converged in iteration 1 with cost 0.0548195648504597 because of step counter
# Final cost : 0.0548195648504597
# Compute control for a deterministic system
# Cost in iteration 0: 0.0548195648504597
# Converged in iteration 1 with cost 0.0548195648504597 because of step counter
# Final cost : 0.0548195648504597
# Compute control for a deterministic system
# Cost in iteration 0: 0.0548195648504597
# Converged in iteration 1 with cost 0.0548195648504597 because of step counter
# Final cost : 0.0548195648504597
# Compute control for a deterministic system
# Cost in iteration 0: 0.06427314478124671
# Cost in iteration 200: 0.06412963387818686
# Final cost : 0.06412963387818686
# Compute control for a deterministic system
# Cost in iteration 0: 0.06412963387818686
# Converged in iteration 111 with cost 0.0641296338519655 because of step counter
# Final cost : 0.0641296338519655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0641296338519655
# Converged in iteration 1 with cost 0.0641296338519655 because of step counter
# Final cost : 0.0641296338519655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0641296338519655
# Converged in iteration 1 with cost 0.0641296338519655 because of step counter
# Final cost : 0.0641296338519655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0641296338519655
# Converged in iteration 1 with cost 0.0641296338519655 because of step counter
# Final cost : 0.0641296338519655
# Compute control for a deterministic system
# Cost in iteration 0: 0.07581316328778755
# Cost in iteration 200: 0.07577061835377345
# Final cost : 0.07577061835377345
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577061835377345
# Converged in iteration 101 with cost 0.07577061834415662 because of step counter
# Final cost : 0.07577061834415662
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577061834415662
# Converged in iteration 7 with cost 0.07577061834413583 because of vanishing difference
# Final cost : 0.07577061834413583
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577061834413583
# Converged in iteration 2 with cost 0.0757706183441356 because of step counter
# Final cost : 0.0757706183441356
# Compute control for a deterministic system
# Cost in iteration 0: 0.0757706183441356
# Converged in iteration 1 with cost 0.0757706183441356 because of step counter
# Final cost : 0.0757706183441356
# Compute control for a deterministic system
# Cost in iteration 0: 0.09182296719989783
# Cost in iteration 200: 0.08741182092457539
# Final cost : 0.08741182092457539
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741182092457539
# Cost in iteration 200: 0.08741181531272231
# Final cost : 0.08741181531272231
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741181531272231
# Converged in iteration 68 with cost 0.08741181531121385 because of vanishing difference
# Final cost : 0.08741181531121385
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741181531121385
# Converged in iteration 1 with cost 0.08741181531121385 because of step counter
# Final cost : 0.08741181531121385
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741181531121385
# Converged in iteration 2 with cost 0.08741181531121382 because of step counter
# Final cost : 0.08741181531121382
# Compute control for a deterministic system
# Cost in iteration 0: 0.10064197505887476
# Cost in iteration 200: 0.0990507227956847
# Final cost : 0.0990507227956847
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990507227956847
# Cost in iteration 200: 0.09905072097486559
# Final cost : 0.09905072097486559
# Compute control for a deterministic system
# Cost in iteration 0: 0.09905072097486559
# Converged in iteration 91 with cost 0.09905072097271207 because of step counter
# Final cost : 0.09905072097271207
# Compute control for a deterministic system
# Cost in iteration 0: 0.09905072097271207
# Converged in iteration 1 with cost 0.09905072097271207 because of step counter
# Final cost : 0.09905072097271207
# Compute control for a deterministic system
# Cost in iteration 0: 0.09905072097271207
# Converged in iteration 1 with cost 0.09905072097271207 because of step counter
# Final cost : 0.09905072097271207
# Compute control for a deterministic system
# Cost in iteration 0: 0.10910434895602984
# Cost in iteration 200: 0.10835892159611193
# Final cost : 0.10835892159611193
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892159611193
# Cost in iteration 200: 0.10835892076329984
# Final cost : 0.10835892076329984
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892076329984
# Converged in iteration 117 with cost 0.10835892076118123 because of step counter
# Final cost : 0.10835892076118123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892076118123
# Converged in iteration 12 with cost 0.10835892076117823 because of step counter
# Final cost : 0.10835892076117823
# Compute control for a deterministic system
# Cost in iteration 0: 0.10835892076117823
# Converged in iteration 2 with cost 0.10835892076117801 because of step counter
# Final cost : 0.10835892076117801
# Compute control for a deterministic system
# Cost in iteration 0: 0.12014292223978054
# Cost in iteration 200: 0.11998897209926618
# Final cost : 0.11998897209926618
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897209926618
# Cost in iteration 200: 0.11998897199187203
# Final cost : 0.11998897199187203
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897199187203
# Converged in iteration 66 with cost 0.11998897199143517 because of step counter
# Final cost : 0.11998897199143517
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897199143517
# Converged in iteration 1 with cost 0.11998897199143517 because of step counter
# Final cost : 0.11998897199143517
# Compute control for a deterministic system
# Cost in iteration 0: 0.11998897199143517
# Converged in iteration 1 with cost 0.11998897199143517 because of step counter
# Final cost : 0.11998897199143517
# Compute control for a deterministic system
# Cost in iteration 0: 0.13648949578670197
# Cost in iteration 200: 0.13161142318732308
# Final cost : 0.13161142318732308
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161142318732308
# Cost in iteration 200: 0.13161141078275845
# Final cost : 0.13161141078275845
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161141078275845
# Cost in iteration 200: 0.13161141065827417
# Final cost : 0.13161141065827417
# Compute control for a deterministic system
# Cost in iteration 0: 0.13161141065827417
# Converged in iteration 22 with cost 0.1316114106580871 because of vanishing difference
# Final cost : 0.1316114106580871
# Compute control for a deterministic system
# Cost in iteration 0: 0.1316114106580871
# Converged in iteration 106 with cost 0.13161141065780252 because of step counter
# Final cost : 0.13161141065780252
# Compute control for a deterministic system
# Cost in iteration 0: 0.1574829680851841
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 189
#     187 wc_controlled.step = 1e-3
#     188 wc_controlled.zero_step_encountered = False
# --> 189 wc_controlled.optimize(200)
#     191 increase_step_compute()
#     193 if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:556, in OC.optimize(self, n_max_iterations)
#     554 if self.M == 1:
#     555     print("Compute control for a deterministic system")
# --> 556     return self.optimize_deterministic(n_max_iterations)
#     557 else:
#     558     print("Compute control for a noisy system")
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:585, in OC.optimize_deterministic(self, n_max_iterations)
#     582     break
#     584 c0 = self.control.copy()
# --> 585 self.step_size(-self.grad)
#     587 if self.zero_step_encountered:
#     588     print(f"Converged in iteration %s with cost %s because of step counter" % (i, cost))
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:465, in OC.step_size(self, cost_gradient)
#     462 self.control = update_control_with_limit(control0, step, cost_gradient, self.maximum_control_strength)
#     463 self.update_input()
# --> 465 self.simulate_forward()
#     466 cost = self.compute_total_cost()
#     468 if counter == self.count_step:
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:341, in OC.simulate_forward(self)
#     337 def simulate_forward(self):
#     338     """Updates self.xs in accordance to the current self.control.
#     339     Results can be accessed with self.get_xs()
#     340     """
# --> 341     self.model.run()
#
# File ~/Promotion/neurolib/neurolib/models/model.py:247, in Model.run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run)
#     244 chunkwise = chunkwise if chunksize is None else True
#     246 if chunkwise is False:
# --> 247     self.integrate(append_outputs=append, simulate_bold=bold)
#     248     if continue_run:
#     249         self.setInitialValuesToLastState()
#
# File ~/Promotion/neurolib/neurolib/models/model.py:291, in Model.integrate(self, append_outputs, simulate_bold)
#     285 """Calls each models `integration` function and saves the state and the outputs of the model.
#     286
#     287 :param append: append the chunkwise outputs to the outputs attribute, defaults to False, defaults to False
#     288 :type append: bool, optional
#     289 """
#     290 # run integration
# --> 291 t, *variables = self.integration(self.params)
#     292 self.storeOutputsAndStates(t, variables, append=append_outputs)
#     294 # force bold if params['bold'] == True
#
# File ~/Promotion/neurolib/neurolib/models/wc/timeIntegration.py:117, in timeIntegration(params)
#     113 noise_inh = np.zeros((N,))
#     115 # ------------------------------------------------------------------------
# --> 117 return timeIntegration_njit_elementwise(
#     118     startind,
#     119     t,
#     120     dt,
#     121     sqrt_dt,
#     122     N,
#     123     Cmat,
#     124     K_gl,
#     125     Dmat_ndt,
#     126     excs,
#     127     inhs,
#     128     exc_input_d,
#     129     inh_input_d,
#     130     exc_ext,
#     131     inh_ext,
#     132     tau_exc,
#     133     tau_inh,
#     134     a_exc,
#     135     a_inh,
#     136     mu_exc,
#     137     mu_inh,
#     138     c_excexc,
#     139     c_excinh,
#     140     c_inhexc,
#     141     c_inhinh,
#     142     noise_exc,
#     143     noise_inh,
#     144     exc_ou,
#     145     inh_ou,
#     146     exc_ou_mean,
#     147     inh_ou_mean,
#     148     tau_ou,
#     149     sigma_ou,
#     150 )
#
# KeyboardInterrupt:

# %%
save(results_min)
