# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,164], wc.inh[0,164]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 18.896551724137932
# minima =  [  33  221  410  599  788  977 1166 1355 1544 1733 1922 2111 2300 2489
#  2678 2867 3055 3244 3433 3622 3811 4000 4189 4378 4567 4756 4945 5134
#  5323 5512 5701 5890]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True, True, True, True, True]

for k in range(3):

    for i_w in range(len(results_min["w1"])):

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            break

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.1
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03128523569196641
# Converged in iteration 113 with cost 0.018447074871071847 because of step counter
# Final cost : 0.018447074871071847
# Compute control for a deterministic system
# Cost in iteration 0: 0.018447074871071847
# Converged in iteration 1 with cost 0.018447074871071847 because of step counter
# Final cost : 0.018447074871071847
# Compute control for a deterministic system
# Cost in iteration 0: 0.018447074871071847
# Converged in iteration 1 with cost 0.018447074871071847 because of step counter
# Final cost : 0.018447074871071847
# Compute control for a deterministic system
# Cost in iteration 0: 0.018447074871071847
# Converged in iteration 1 with cost 0.018447074871071847 because of step counter
# Final cost : 0.018447074871071847
# Compute control for a deterministic system
# Cost in iteration 0: 0.018447074871071847
# Converged in iteration 1 with cost 0.018447074871071847 because of step counter
# Final cost : 0.018447074871071847
# Compute control for a deterministic system
# Cost in iteration 0: 0.04727505931572689
# Converged in iteration 119 with cost 0.025498417899143942 because of step counter
# Final cost : 0.025498417899143942
# Compute control for a deterministic system
# Cost in iteration 0: 0.025498417899143942
# Converged in iteration 1 with cost 0.025498417899143942 because of step counter
# Final cost : 0.025498417899143942
# Compute control for a deterministic system
# Cost in iteration 0: 0.025498417899143942
# Converged in iteration 1 with cost 0.025498417899143942 because of step counter
# Final cost : 0.025498417899143942
# Compute control for a deterministic system
# Cost in iteration 0: 0.025498417899143942
# Converged in iteration 1 with cost 0.025498417899143942 because of step counter
# Final cost : 0.025498417899143942
# Compute control for a deterministic system
# Cost in iteration 0: 0.025498417899143942
# Converged in iteration 1 with cost 0.025498417899143942 because of step counter
# Final cost : 0.025498417899143942
# Compute control for a deterministic system
# Cost in iteration 0: 0.04796603413147326
# Converged in iteration 111 with cost 0.030475527038020984 because of step counter
# Final cost : 0.030475527038020984
# Compute control for a deterministic system
# Cost in iteration 0: 0.030475527038020984
# Converged in iteration 1 with cost 0.030475527038020984 because of step counter
# Final cost : 0.030475527038020984
# Compute control for a deterministic system
# Cost in iteration 0: 0.030475527038020984
# Converged in iteration 1 with cost 0.030475527038020984 because of step counter
# Final cost : 0.030475527038020984
# Compute control for a deterministic system
# Cost in iteration 0: 0.030475527038020984
# Converged in iteration 1 with cost 0.030475527038020984 because of step counter
# Final cost : 0.030475527038020984
# Compute control for a deterministic system
# Cost in iteration 0: 0.030475527038020984
# Converged in iteration 1 with cost 0.030475527038020984 because of step counter
# Final cost : 0.030475527038020984
# Compute control for a deterministic system
# Cost in iteration 0: 0.05002956999336604
# Converged in iteration 116 with cost 0.03329274542543906 because of step counter
# Final cost : 0.03329274542543906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03329274542543906
# Converged in iteration 1 with cost 0.03329274542543906 because of step counter
# Final cost : 0.03329274542543906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03329274542543906
# Converged in iteration 1 with cost 0.03329274542543906 because of step counter
# Final cost : 0.03329274542543906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03329274542543906
# Converged in iteration 1 with cost 0.03329274542543906 because of step counter
# Final cost : 0.03329274542543906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03329274542543906
# Converged in iteration 1 with cost 0.03329274542543906 because of step counter
# Final cost : 0.03329274542543906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03845913973938571
# Converged in iteration 130 with cost 0.034612052971710904 because of step counter
# Final cost : 0.034612052971710904
# Compute control for a deterministic system
# Cost in iteration 0: 0.034612052971710904
# Converged in iteration 1 with cost 0.034612052971710904 because of step counter
# Final cost : 0.034612052971710904
# Compute control for a deterministic system
# Cost in iteration 0: 0.034612052971710904
# Converged in iteration 1 with cost 0.034612052971710904 because of step counter
# Final cost : 0.034612052971710904
# Compute control for a deterministic system
# Cost in iteration 0: 0.034612052971710904
# Converged in iteration 1 with cost 0.034612052971710904 because of step counter
# Final cost : 0.034612052971710904
# Compute control for a deterministic system
# Cost in iteration 0: 0.034612052971710904
# Converged in iteration 1 with cost 0.034612052971710904 because of step counter
# Final cost : 0.034612052971710904
# Compute control for a deterministic system
# Cost in iteration 0: 0.05382634071081743
# Converged in iteration 105 with cost 0.04390182831732872 because of step counter
# Final cost : 0.04390182831732872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04390182831732872
# Converged in iteration 1 with cost 0.04390182831732872 because of step counter
# Final cost : 0.04390182831732872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04390182831732872
# Converged in iteration 1 with cost 0.04390182831732872 because of step counter
# Final cost : 0.04390182831732872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04390182831732872
# Converged in iteration 1 with cost 0.04390182831732872 because of step counter
# Final cost : 0.04390182831732872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04390182831732872
# Converged in iteration 1 with cost 0.04390182831732872 because of step counter
# Final cost : 0.04390182831732872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669032720816789
# Converged in iteration 174 with cost 0.04263622776106319 because of step counter
# Final cost : 0.04263622776106319
# Compute control for a deterministic system
# Cost in iteration 0: 0.04263622776106319
# Converged in iteration 1 with cost 0.04263622776106319 because of step counter
# Final cost : 0.04263622776106319
# Compute control for a deterministic system
# Cost in iteration 0: 0.04263622776106319
# Converged in iteration 1 with cost 0.04263622776106319 because of step counter
# Final cost : 0.04263622776106319
# Compute control for a deterministic system
# Cost in iteration 0: 0.04263622776106319
# Converged in iteration 1 with cost 0.04263622776106319 because of step counter
# Final cost : 0.04263622776106319
# Compute control for a deterministic system
# Cost in iteration 0: 0.04263622776106319
# Converged in iteration 1 with cost 0.04263622776106319 because of step counter
# Final cost : 0.04263622776106319
# Compute control for a deterministic system
# Cost in iteration 0: 0.048620875606974465
# Converged in iteration 153 with cost 0.04460837333625356 because of step counter
# Final cost : 0.04460837333625356
# Compute control for a deterministic system
# Cost in iteration 0: 0.04460837333625356
# Converged in iteration 1 with cost 0.04460837333625356 because of step counter
# Final cost : 0.04460837333625356
# Compute control for a deterministic system
# Cost in iteration 0: 0.04460837333625356
# Converged in iteration 1 with cost 0.04460837333625356 because of step counter
# Final cost : 0.04460837333625356
# Compute control for a deterministic system
# Cost in iteration 0: 0.04460837333625356
# Converged in iteration 1 with cost 0.04460837333625356 because of step counter
# Final cost : 0.04460837333625356
# Compute control for a deterministic system
# Cost in iteration 0: 0.04460837333625356
# Converged in iteration 1 with cost 0.04460837333625356 because of step counter
# Final cost : 0.04460837333625356
# Compute control for a deterministic system
# Cost in iteration 0: 0.04613739710857862
# Converged in iteration 129 with cost 0.04476814392041758 because of step counter
# Final cost : 0.04476814392041758
# Compute control for a deterministic system
# Cost in iteration 0: 0.04476814392041758
# Converged in iteration 1 with cost 0.04476814392041758 because of step counter
# Final cost : 0.04476814392041758
# Compute control for a deterministic system
# Cost in iteration 0: 0.04476814392041758
# Converged in iteration 1 with cost 0.04476814392041758 because of step counter
# Final cost : 0.04476814392041758
# Compute control for a deterministic system
# Cost in iteration 0: 0.04476814392041758
# Converged in iteration 1 with cost 0.04476814392041758 because of step counter
# Final cost : 0.04476814392041758
# Compute control for a deterministic system
# Cost in iteration 0: 0.04476814392041758
# Converged in iteration 1 with cost 0.04476814392041758 because of step counter
# Final cost : 0.04476814392041758
# Compute control for a deterministic system
# Cost in iteration 0: 0.06042194185066786
# Converged in iteration 97 with cost 0.05095998325677307 because of step counter
# Final cost : 0.05095998325677307
# Compute control for a deterministic system
# Cost in iteration 0: 0.05095998325677307
# Converged in iteration 1 with cost 0.05095998325677307 because of step counter
# Final cost : 0.05095998325677307
# Compute control for a deterministic system
# Cost in iteration 0: 0.05095998325677307
# Converged in iteration 1 with cost 0.05095998325677307 because of step counter
# Final cost : 0.05095998325677307
# Compute control for a deterministic system
# Cost in iteration 0: 0.05095998325677307
# Converged in iteration 1 with cost 0.05095998325677307 because of step counter
# Final cost : 0.05095998325677307
# Compute control for a deterministic system
# Cost in iteration 0: 0.05095998325677307
# Converged in iteration 1 with cost 0.05095998325677307 because of step counter
# Final cost : 0.05095998325677307
# Compute control for a deterministic system
# Cost in iteration 0: 0.05104331802594435
# Cost in iteration 200: 0.04997186194563815
# Final cost : 0.04997186194563815
# Compute control for a deterministic system
# Cost in iteration 0: 0.04997186194563815
# Converged in iteration 8 with cost 0.04996938010284898 because of step counter
# Final cost : 0.04996938010284898
# Compute control for a deterministic system
# Cost in iteration 0: 0.04996938010284898
# Converged in iteration 1 with cost 0.04996938010284898 because of step counter
# Final cost : 0.04996938010284898
# Compute control for a deterministic system
# Cost in iteration 0: 0.04996938010284898
# Converged in iteration 1 with cost 0.04996938010284898 because of step counter
# Final cost : 0.04996938010284898
# Compute control for a deterministic system
# Cost in iteration 0: 0.04996938010284898
# Converged in iteration 1 with cost 0.04996938010284898 because of step counter
# Final cost : 0.04996938010284898
# Compute control for a deterministic system
# Cost in iteration 0: 0.047860870055631326
# Converged in iteration 1 with cost 0.047860870055631326 because of step counter
# Final cost : 0.047860870055631326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047860870055631326
# Converged in iteration 1 with cost 0.047860870055631326 because of step counter
# Final cost : 0.047860870055631326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047860870055631326
# Converged in iteration 1 with cost 0.047860870055631326 because of step counter
# Final cost : 0.047860870055631326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047860870055631326
# Converged in iteration 1 with cost 0.047860870055631326 because of step counter
# Final cost : 0.047860870055631326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047860870055631326
# Converged in iteration 1 with cost 0.047860870055631326 because of step counter
# Final cost : 0.047860870055631326
# Compute control for a deterministic system
# Cost in iteration 0: 0.056847514155974645
# Converged in iteration 134 with cost 0.05496165967384038 because of step counter
# Final cost : 0.05496165967384038
# Compute control for a deterministic system
# Cost in iteration 0: 0.05496165967384038
# Converged in iteration 1 with cost 0.05496165967384038 because of step counter
# Final cost : 0.05496165967384038
# Compute control for a deterministic system
# Cost in iteration 0: 0.05496165967384038
# Converged in iteration 1 with cost 0.05496165967384038 because of step counter
# Final cost : 0.05496165967384038
# Compute control for a deterministic system
# Cost in iteration 0: 0.05496165967384038
# Converged in iteration 1 with cost 0.05496165967384038 because of step counter
# Final cost : 0.05496165967384038
# Compute control for a deterministic system
# Cost in iteration 0: 0.05496165967384038
# Converged in iteration 1 with cost 0.05496165967384038 because of step counter
# Final cost : 0.05496165967384038
# Compute control for a deterministic system
# Cost in iteration 0: 0.059808652436721885
# Converged in iteration 125 with cost 0.05820634132359484 because of step counter
# Final cost : 0.05820634132359484
# Compute control for a deterministic system
# Cost in iteration 0: 0.05820634132359484
# Converged in iteration 1 with cost 0.05820634132359484 because of step counter
# Final cost : 0.05820634132359484
# Compute control for a deterministic system
# Cost in iteration 0: 0.05820634132359484
# Converged in iteration 1 with cost 0.05820634132359484 because of step counter
# Final cost : 0.05820634132359484
# Compute control for a deterministic system
# Cost in iteration 0: 0.05820634132359484
# Converged in iteration 1 with cost 0.05820634132359484 because of step counter
# Final cost : 0.05820634132359484
# Compute control for a deterministic system
# Cost in iteration 0: 0.05820634132359484
# Converged in iteration 1 with cost 0.05820634132359484 because of step counter
# Final cost : 0.05820634132359484
# Compute control for a deterministic system
# Cost in iteration 0: 0.06583027796987487
# Converged in iteration 101 with cost 0.0612806991038078 because of step counter
# Final cost : 0.0612806991038078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0612806991038078
# Converged in iteration 1 with cost 0.0612806991038078 because of step counter
# Final cost : 0.0612806991038078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0612806991038078
# Converged in iteration 1 with cost 0.0612806991038078 because of step counter
# Final cost : 0.0612806991038078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0612806991038078
# Converged in iteration 1 with cost 0.0612806991038078 because of step counter
# Final cost : 0.0612806991038078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0612806991038078
# Converged in iteration 1 with cost 0.0612806991038078 because of step counter
# Final cost : 0.0612806991038078
# Compute control for a deterministic system
# Cost in iteration 0: 0.06250573412909671
# Converged in iteration 72 with cost 0.061413298120958255 because of step counter
# Final cost : 0.061413298120958255
# Compute control for a deterministic system
# Cost in iteration 0: 0.061413298120958255
# Converged in iteration 1 with cost 0.061413298120958255 because of step counter
# Final cost : 0.061413298120958255
# Compute control for a deterministic system
# Cost in iteration 0: 0.061413298120958255
# Converged in iteration 1 with cost 0.061413298120958255 because of step counter
# Final cost : 0.061413298120958255
# Compute control for a deterministic system
# Cost in iteration 0: 0.061413298120958255
# Converged in iteration 1 with cost 0.061413298120958255 because of step counter
# Final cost : 0.061413298120958255
# Compute control for a deterministic system
# Cost in iteration 0: 0.061413298120958255
# Converged in iteration 1 with cost 0.061413298120958255 because of step counter
# Final cost : 0.061413298120958255
# Compute control for a deterministic system
# Cost in iteration 0: 0.06075194782797756
# Converged in iteration 5 with cost 0.06074403136172708 because of step counter
# Final cost : 0.06074403136172708
# Compute control for a deterministic system
# Cost in iteration 0: 0.06074403136172708
# Converged in iteration 1 with cost 0.06074403136172708 because of step counter
# Final cost : 0.06074403136172708
# Compute control for a deterministic system
# Cost in iteration 0: 0.06074403136172708
# Converged in iteration 1 with cost 0.06074403136172708 because of step counter
# Final cost : 0.06074403136172708
# Compute control for a deterministic system
# Cost in iteration 0: 0.06074403136172708
# Converged in iteration 1 with cost 0.06074403136172708 because of step counter
# Final cost : 0.06074403136172708
# Compute control for a deterministic system
# Cost in iteration 0: 0.06074403136172708
# Converged in iteration 1 with cost 0.06074403136172708 because of step counter
# Final cost : 0.06074403136172708
# Compute control for a deterministic system
# Cost in iteration 0: 0.06825319632529825
# Converged in iteration 106 with cost 0.06728498914782596 because of step counter
# Final cost : 0.06728498914782596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06728498914782596
# Converged in iteration 1 with cost 0.06728498914782596 because of step counter
# Final cost : 0.06728498914782596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06728498914782596
# Converged in iteration 1 with cost 0.06728498914782596 because of step counter
# Final cost : 0.06728498914782596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06728498914782596
# Converged in iteration 1 with cost 0.06728498914782596 because of step counter
# Final cost : 0.06728498914782596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06728498914782596
# Converged in iteration 1 with cost 0.06728498914782596 because of step counter
# Final cost : 0.06728498914782596
# Compute control for a deterministic system
# Cost in iteration 0: 0.07323717688456222
# Converged in iteration 98 with cost 0.07088420936122145 because of step counter
# Final cost : 0.07088420936122145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07088420936122145
# Converged in iteration 1 with cost 0.07088420936122145 because of step counter
# Final cost : 0.07088420936122145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07088420936122145
# Converged in iteration 1 with cost 0.07088420936122145 because of step counter
# Final cost : 0.07088420936122145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07088420936122145
# Converged in iteration 1 with cost 0.07088420936122145 because of step counter
# Final cost : 0.07088420936122145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07088420936122145
# Converged in iteration 1 with cost 0.07088420936122145 because of step counter
# Final cost : 0.07088420936122145
# Compute control for a deterministic system
# Cost in iteration 0: 0.10750787542679677
# Cost in iteration 200: 0.06961982857442886
# Final cost : 0.06961982857442886
# Compute control for a deterministic system
# Cost in iteration 0: 0.06961982857442886
# Cost in iteration 200: 0.06809005095421523
# Final cost : 0.06809005095421523
# Compute control for a deterministic system
# Cost in iteration 0: 0.06809005095421523
# Cost in iteration 200: 0.06792913335989934
# Final cost : 0.06792913335989934
# Compute control for a deterministic system
# Cost in iteration 0: 0.06792913335989934
# Converged in iteration 13 with cost 0.0679097567293767 because of step counter
# Final cost : 0.0679097567293767
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679097567293767
# Converged in iteration 1 with cost 0.0679097567293767 because of step counter
# Final cost : 0.0679097567293767
# Compute control for a deterministic system
# Cost in iteration 0: 0.10497587357494417
# Cost in iteration 200: 0.06601170133755412
# Final cost : 0.06601170133755412
# Compute control for a deterministic system
# Cost in iteration 0: 0.06601170133755412
# Cost in iteration 200: 0.06551813743577752
# Final cost : 0.06551813743577752
# Compute control for a deterministic system
# Cost in iteration 0: 0.06551813743577752
# Cost in iteration 200: 0.06532313002978495
# Final cost : 0.06532313002978495
# Compute control for a deterministic system
# Cost in iteration 0: 0.06532313002978495
# Converged in iteration 6 with cost 0.06531902413541452 because of step counter
# Final cost : 0.06531902413541452
# Compute control for a deterministic system
# Cost in iteration 0: 0.06531902413541452
# Converged in iteration 1 with cost 0.06531902413541452 because of step counter
# Final cost : 0.06531902413541452
# Compute control for a deterministic system
# Cost in iteration 0: 0.10313437995339209
# Cost in iteration 200: 0.062314251608666445
# Final cost : 0.062314251608666445
# Compute control for a deterministic system
# Cost in iteration 0: 0.062314251608666445
# Cost in iteration 200: 0.061031475481379556
# Final cost : 0.061031475481379556
# Compute control for a deterministic system
# Cost in iteration 0: 0.061031475481379556
# Converged in iteration 14 with cost 0.06085340815282365 because of step counter
# Final cost : 0.06085340815282365
# Compute control for a deterministic system
# Cost in iteration 0: 0.06085340815282365
# Converged in iteration 1 with cost 0.06085340815282365 because of step counter
# Final cost : 0.06085340815282365
# Compute control for a deterministic system
# Cost in iteration 0: 0.06085340815282365
# Converged in iteration 1 with cost 0.06085340815282365 because of step counter
# Final cost : 0.06085340815282365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0857496806015175
# Cost in iteration 200: 0.058585833892859276
# Final cost : 0.058585833892859276
# Compute control for a deterministic system
# Cost in iteration 0: 0.058585833892859276
# Converged in iteration 25 with cost 0.05852129614283885 because of step counter
# Final cost : 0.05852129614283885
# Compute control for a deterministic system
# Cost in iteration 0: 0.05852129614283885
# Converged in iteration 1 with cost 0.05852129614283885 because of step counter
# Final cost : 0.05852129614283885
# Compute control for a deterministic system
# Cost in iteration 0: 0.05852129614283885
# Converged in iteration 1 with cost 0.05852129614283885 because of step counter
# Final cost : 0.05852129614283885
# Compute control for a deterministic system
# Cost in iteration 0: 0.05852129614283885
# Converged in iteration 1 with cost 0.05852129614283885 because of step counter
# Final cost : 0.05852129614283885
# Compute control for a deterministic system
# Cost in iteration 0: 0.09734184663602101
# Cost in iteration 200: 0.05971155620165432
# Final cost : 0.05971155620165432
# Compute control for a deterministic system
# Cost in iteration 0: 0.05971155620165432
# Cost in iteration 200: 0.058445770532718384
# Final cost : 0.058445770532718384
# Compute control for a deterministic system
# Cost in iteration 0: 0.058445770532718384
# Cost in iteration 200: 0.058224688888557856
# Final cost : 0.058224688888557856
# Compute control for a deterministic system
# Cost in iteration 0: 0.058224688888557856
# Converged in iteration 5 with cost 0.05822389857980102 because of step counter
# Final cost : 0.05822389857980102
# Compute control for a deterministic system
# Cost in iteration 0: 0.05822389857980102
# Converged in iteration 1 with cost 0.05822389857980102 because of step counter
# Final cost : 0.05822389857980102
# Compute control for a deterministic system
# Cost in iteration 0: 0.09539279521991392
# Cost in iteration 200: 0.05698606179759861
# Final cost : 0.05698606179759861
# Compute control for a deterministic system
# Cost in iteration 0: 0.05698606179759861
# Cost in iteration 200: 0.05648559363765359
# Final cost : 0.05648559363765359
# Compute control for a deterministic system
# Cost in iteration 0: 0.05648559363765359
# Cost in iteration 200: 0.056319738183202114
# Final cost : 0.056319738183202114
# Compute control for a deterministic system
# Cost in iteration 0: 0.056319738183202114
# Converged in iteration 27 with cost 0.056214965708266784 because of step counter
# Final cost : 0.056214965708266784
# Compute control for a deterministic system
# Cost in iteration 0: 0.056214965708266784
# Converged in iteration 1 with cost 0.056214965708266784 because of step counter
# Final cost : 0.056214965708266784
# Compute control for a deterministic system
# Cost in iteration 0: 0.0887424205244214
# Cost in iteration 200: 0.05326489745461404
# Final cost : 0.05326489745461404
# Compute control for a deterministic system
# Cost in iteration 0: 0.05326489745461404
# Cost in iteration 200: 0.0514514485454977
# Final cost : 0.0514514485454977
# Compute control for a deterministic system
# Cost in iteration 0: 0.0514514485454977
# Converged in iteration 161 with cost 0.05130942478653922 because of vanishing difference
# Final cost : 0.05130942478653922
# Compute control for a deterministic system
# Cost in iteration 0: 0.05130942478615235
# Converged in iteration 2 with cost 0.05130942478307253 because of vanishing difference
# Final cost : 0.05130942478307253
# Compute control for a deterministic system
# Cost in iteration 0: 0.05130942478307251
# Converged in iteration 1 with cost 0.05130942478307251 because of step counter
# Final cost : 0.05130942478307251
# Compute control for a deterministic system
# Cost in iteration 0: 0.07194346760832017
# Cost in iteration 200: 0.047565377755045414
# Final cost : 0.047565377755045414
# Compute control for a deterministic system
# Cost in iteration 0: 0.047565377755045414
# Converged in iteration 55 with cost 0.046629034849576624 because of step counter
# Final cost : 0.046629034849576624
# Compute control for a deterministic system
# Cost in iteration 0: 0.046629034849576624
# Converged in iteration 1 with cost 0.046629034849576624 because of step counter
# Final cost : 0.046629034849576624
# Compute control for a deterministic system
# Cost in iteration 0: 0.046629034849576624
# Converged in iteration 1 with cost 0.046629034849576624 because of step counter
# Final cost : 0.046629034849576624
# Compute control for a deterministic system
# Cost in iteration 0: 0.046629034849576624
# Converged in iteration 1 with cost 0.046629034849576624 because of step counter
# Final cost : 0.046629034849576624
# Compute control for a deterministic system
# Cost in iteration 0: 0.08455974139543734
# Cost in iteration 200: 0.04730483517742594
# Final cost : 0.04730483517742594
# Compute control for a deterministic system
# Cost in iteration 0: 0.04730483517742594
# Cost in iteration 200: 0.04664842054688823
# Final cost : 0.04664842054688823
# Compute control for a deterministic system
# Cost in iteration 0: 0.04664842054688823
# Cost in iteration 200: 0.04648206950519655
# Final cost : 0.04648206950519655
# Compute control for a deterministic system
# Cost in iteration 0: 0.04648206950519655
# Converged in iteration 11 with cost 0.04630603507144023 because of step counter
# Final cost : 0.04630603507144023
# Compute control for a deterministic system
# Cost in iteration 0: 0.04630603507144023
# Converged in iteration 1 with cost 0.04630603507144023 because of step counter
# Final cost : 0.04630603507144023
# Compute control for a deterministic system
# Cost in iteration 0: 0.08222491978333807
# Cost in iteration 200: 0.04469991844954632
# Final cost : 0.04469991844954632
# Compute control for a deterministic system
# Cost in iteration 0: 0.04469991844954632
# Cost in iteration 200: 0.044227119244690284
# Final cost : 0.044227119244690284
# Compute control for a deterministic system
# Cost in iteration 0: 0.044227119244690284
# Cost in iteration 200: 0.04408901250952317
# Final cost : 0.04408901250952317
# Compute control for a deterministic system
# Cost in iteration 0: 0.04408901250952317
# Converged in iteration 18 with cost 0.04390790056144236 because of step counter
# Final cost : 0.04390790056144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.04390790056144236
# Converged in iteration 1 with cost 0.04390790056144236 because of step counter
# Final cost : 0.04390790056144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.06037197299628068
# Cost in iteration 200: 0.03765656035249384
# Final cost : 0.03765656035249384
# Compute control for a deterministic system
# Cost in iteration 0: 0.03765656035249384
# Converged in iteration 45 with cost 0.03673319989359803 because of step counter
# Final cost : 0.03673319989359803
# Compute control for a deterministic system
# Cost in iteration 0: 0.03673319989359803
# Converged in iteration 1 with cost 0.03673319989359803 because of step counter
# Final cost : 0.03673319989359803
# Compute control for a deterministic system
# Cost in iteration 0: 0.03673319989359803
# Converged in iteration 1 with cost 0.03673319989359803 because of step counter
# Final cost : 0.03673319989359803
# Compute control for a deterministic system
# Cost in iteration 0: 0.03673319989359803
# Converged in iteration 1 with cost 0.03673319989359803 because of step counter
# Final cost : 0.03673319989359803
# Compute control for a deterministic system
# Cost in iteration 0: 0.07245158655190582
# Cost in iteration 200: 0.03702696742248308
# Final cost : 0.03702696742248308
# Compute control for a deterministic system
# Cost in iteration 0: 0.03702696742248308
# Cost in iteration 200: 0.03572993852114516
# Final cost : 0.03572993852114516
# Compute control for a deterministic system
# Cost in iteration 0: 0.03572993852114516
# Cost in iteration 200: 0.03557419698958449
# Final cost : 0.03557419698958449
# Compute control for a deterministic system
# Cost in iteration 0: 0.03557419698958449
# Converged in iteration 2 with cost 0.03557419639618273 because of step counter
# Final cost : 0.03557419639618273
# Compute control for a deterministic system
# Cost in iteration 0: 0.03557419639618273
# Converged in iteration 1 with cost 0.03557419639618273 because of step counter
# Final cost : 0.03557419639618273
# Compute control for a deterministic system
# Cost in iteration 0: 0.06953200284266953
# Cost in iteration 200: 0.03339019555478769
# Final cost : 0.03339019555478769
# Compute control for a deterministic system
# Cost in iteration 0: 0.03339019555478769
# Cost in iteration 200: 0.03230246346825785
# Final cost : 0.03230246346825785
# Compute control for a deterministic system
# Cost in iteration 0: 0.03230246346825785
# Cost in iteration 200: 0.032134711632871724
# Final cost : 0.032134711632871724
# Compute control for a deterministic system
# Cost in iteration 0: 0.032134711632871724
# Converged in iteration 4 with cost 0.032133968875925234 because of step counter
# Final cost : 0.032133968875925234
# Compute control for a deterministic system
# Cost in iteration 0: 0.032133968875925234
# Converged in iteration 1 with cost 0.032133968875925234 because of step counter
# Final cost : 0.032133968875925234
# Compute control for a deterministic system
# Cost in iteration 0: 0.06678140439427768
# Cost in iteration 200: 0.030572385725014663
# Final cost : 0.030572385725014663
# Compute control for a deterministic system
# Cost in iteration 0: 0.030572385725014663
# Cost in iteration 200: 0.02985019721100299
# Final cost : 0.02985019721100299
# Compute control for a deterministic system
# Cost in iteration 0: 0.02985019721100299
# Cost in iteration 200: 0.02966334340679935
# Final cost : 0.02966334340679935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02966334340679935
# Converged in iteration 11 with cost 0.029541439690104365 because of step counter
# Final cost : 0.029541439690104365
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541439690104365
# Converged in iteration 1 with cost 0.029541439690104365 because of step counter
# Final cost : 0.029541439690104365
# Compute control for a deterministic system
# Cost in iteration 0: 0.04977338082554478
# Cost in iteration 200: 0.0259417665884078
# Final cost : 0.0259417665884078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0259417665884078
# Converged in iteration 52 with cost 0.025008219627372142 because of step counter
# Final cost : 0.025008219627372142
# Compute control for a deterministic system
# Cost in iteration 0: 0.025008219627372142
# Converged in iteration 1 with cost 0.025008219627372142 because of step counter
# Final cost : 0.025008219627372142
# Compute control for a deterministic system
# Cost in iteration 0: 0.025008219627372142
# Converged in iteration 1 with cost 0.025008219627372142 because of step counter
# Final cost : 0.025008219627372142
# Compute control for a deterministic system
# Cost in iteration 0: 0.025008219627372142
# Converged in iteration 1 with cost 0.025008219627372142 because of step counter
# Final cost : 0.025008219627372142
# Compute control for a deterministic system
# Cost in iteration 0: 0.06145920044763094
# Cost in iteration 200: 0.02582379840710198
# Final cost : 0.02582379840710198
# Compute control for a deterministic system
# Cost in iteration 0: 0.02582379840710198
# Cost in iteration 200: 0.02509597143668058
# Final cost : 0.02509597143668058
# Compute control for a deterministic system
# Cost in iteration 0: 0.02509597143668058
# Cost in iteration 200: 0.024903573957353608
# Final cost : 0.024903573957353608
# Compute control for a deterministic system
# Cost in iteration 0: 0.024903573957353608
# Converged in iteration 12 with cost 0.024767609471868318 because of step counter
# Final cost : 0.024767609471868318
# Compute control for a deterministic system
# Cost in iteration 0: 0.024767609471868318
# Converged in iteration 1 with cost 0.024767609471868318 because of step counter
# Final cost : 0.024767609471868318
# Compute control for a deterministic system
# Cost in iteration 0: 0.05446522237575832
# Cost in iteration 200: 0.01999371194104045
# Final cost : 0.01999371194104045
# Compute control for a deterministic system
# Cost in iteration 0: 0.01999371194104045
# Cost in iteration 200: 0.017610568504843972
# Final cost : 0.017610568504843972
# Compute control for a deterministic system
# Cost in iteration 0: 0.017610568504843972
# Converged in iteration 21 with cost 0.017574067989615697 because of step counter
# Final cost : 0.017574067989615697
# Compute control for a deterministic system
# Cost in iteration 0: 0.017574067989615697
# Converged in iteration 1 with cost 0.017574067989615697 because of step counter
# Final cost : 0.017574067989615697
# Compute control for a deterministic system
# Cost in iteration 0: 0.017574067989615697
# Converged in iteration 1 with cost 0.017574067989615697 because of step counter
# Final cost : 0.017574067989615697
# Compute control for a deterministic system
# Cost in iteration 0: 0.04697866030160609
# Cost in iteration 200: 0.01227425121845564
# Final cost : 0.01227425121845564
# Compute control for a deterministic system
# Cost in iteration 0: 0.01227425121845564
# Converged in iteration 64 with cost 0.01051623587315351 because of step counter
# Final cost : 0.01051623587315351
# Compute control for a deterministic system
# Cost in iteration 0: 0.01051623587315351
# Converged in iteration 1 with cost 0.01051623587315351 because of step counter
# Final cost : 0.01051623587315351
# Compute control for a deterministic system
# Cost in iteration 0: 0.01051623587315351
# Converged in iteration 1 with cost 0.01051623587315351 because of step counter
# Final cost : 0.01051623587315351
# Compute control for a deterministic system
# Cost in iteration 0: 0.01051623587315351
# Converged in iteration 1 with cost 0.01051623587315351 because of step counter
# Final cost : 0.01051623587315351
# Compute control for a deterministic system
# Cost in iteration 0: 0.03085574875419387
# Cost in iteration 200: 0.005839263622234869
# Final cost : 0.005839263622234869
# Compute control for a deterministic system
# Cost in iteration 0: 0.005839263622234869
# Cost in iteration 200: 0.005534528426539275
# Final cost : 0.005534528426539275
# Compute control for a deterministic system
# Cost in iteration 0: 0.005534528426539275
# Converged in iteration 35 with cost 0.0055344830817516955 because of step counter
# Final cost : 0.0055344830817516955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055344830817516955
# Converged in iteration 1 with cost 0.0055344830817516955 because of step counter
# Final cost : 0.0055344830817516955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055344830817516955
# Converged in iteration 1 with cost 0.0055344830817516955 because of step counter
# Final cost : 0.0055344830817516955
# ----------------------------------------------- 1
# cost =  0.007915854462420834
# Compute control for a deterministic system
# Cost in iteration 0: 0.028462339157251278
# Converged in iteration 11 with cost 0.017815611291794684 because of step counter
# Final cost : 0.017815611291794684
# Compute control for a deterministic system
# Cost in iteration 0: 0.017815611291794684
# Converged in iteration 1 with cost 0.017815611291794684 because of step counter
# Final cost : 0.017815611291794684
# Compute control for a deterministic system
# Cost in iteration 0: 0.017815611291794684
# Converged in iteration 1 with cost 0.017815611291794684 because of step counter
# Final cost : 0.017815611291794684
# Compute control for a deterministic system
# Cost in iteration 0: 0.017815611291794684
# Converged in iteration 1 with cost 0.017815611291794684 because of step counter
# Final cost : 0.017815611291794684
# cost =  0.012665671131638611
# Compute control for a deterministic system
# Cost in iteration 0: 0.04117901105325052
# Converged in iteration 11 with cost 0.024525006885723587 because of step counter
# Final cost : 0.024525006885723587
# Compute control for a deterministic system
# Cost in iteration 0: 0.024525006885723587
# Converged in iteration 1 with cost 0.024525006885723587 because of step counter
# Final cost : 0.024525006885723587
# Compute control for a deterministic system
# Cost in iteration 0: 0.024525006885723587
# Converged in iteration 1 with cost 0.024525006885723587 because of step counter
# Final cost : 0.024525006885723587
# Compute control for a deterministic system
# Cost in iteration 0: 0.024525006885723587
# Converged in iteration 1 with cost 0.024525006885723587 because of step counter
# Final cost : 0.024525006885723587
# cost =  0.0181926066898013
# Compute control for a deterministic system
# Cost in iteration 0: 0.040897903374509915
# Converged in iteration 11 with cost 0.026958359467098524 because of step counter
# Final cost : 0.026958359467098524
# Compute control for a deterministic system
# Cost in iteration 0: 0.026958359467098524
# Converged in iteration 1 with cost 0.026958359467098524 because of step counter
# Final cost : 0.026958359467098524
# Compute control for a deterministic system
# Cost in iteration 0: 0.026958359467098524
# Converged in iteration 1 with cost 0.026958359467098524 because of step counter
# Final cost : 0.026958359467098524
# Compute control for a deterministic system
# Cost in iteration 0: 0.026958359467098524
# Converged in iteration 1 with cost 0.026958359467098524 because of step counter
# Final cost : 0.026958359467098524
# cost =  0.023266132337808502
# Compute control for a deterministic system
# Cost in iteration 0: 0.037757027058120105
# Converged in iteration 11 with cost 0.02908981575713251 because of step counter
# Final cost : 0.02908981575713251
# Compute control for a deterministic system
# Cost in iteration 0: 0.02908981575713251
# Converged in iteration 1 with cost 0.02908981575713251 because of step counter
# Final cost : 0.02908981575713251
# Compute control for a deterministic system
# Cost in iteration 0: 0.02908981575713251
# Converged in iteration 1 with cost 0.02908981575713251 because of step counter
# Final cost : 0.02908981575713251
# Compute control for a deterministic system
# Cost in iteration 0: 0.02908981575713251
# Converged in iteration 1 with cost 0.02908981575713251 because of step counter
# Final cost : 0.02908981575713251
# cost =  0.025543369732441482
# Compute control for a deterministic system
# Cost in iteration 0: 0.025584141659119954
# Converged in iteration 1 with cost 0.025584141659119954 because of step counter
# Final cost : 0.025584141659119954
# Compute control for a deterministic system
# Cost in iteration 0: 0.025584141659119954
# Converged in iteration 1 with cost 0.025584141659119954 because of step counter
# Final cost : 0.025584141659119954
# Compute control for a deterministic system
# Cost in iteration 0: 0.025584141659119954
# Converged in iteration 1 with cost 0.025584141659119954 because of step counter
# Final cost : 0.025584141659119954
# Compute control for a deterministic system
# Cost in iteration 0: 0.025584141659119954
# Converged in iteration 1 with cost 0.025584141659119954 because of step counter
# Final cost : 0.025584141659119954
# cost =  0.028372327752506813
# Compute control for a deterministic system
# Cost in iteration 0: 0.029048140661022317
# Converged in iteration 1 with cost 0.029048140661022317 because of step counter
# Final cost : 0.029048140661022317
# Compute control for a deterministic system
# Cost in iteration 0: 0.029048140661022317
# Converged in iteration 1 with cost 0.029048140661022317 because of step counter
# Final cost : 0.029048140661022317
# Compute control for a deterministic system
# Cost in iteration 0: 0.029048140661022317
# Converged in iteration 1 with cost 0.029048140661022317 because of step counter
# Final cost : 0.029048140661022317
# Compute control for a deterministic system
# Cost in iteration 0: 0.029048140661022317
# Converged in iteration 1 with cost 0.029048140661022317 because of step counter
# Final cost : 0.029048140661022317
# cost =  0.03143586679155748
# Compute control for a deterministic system
# Cost in iteration 0: 0.031792114540549934
# Converged in iteration 1 with cost 0.031792114540549934 because of step counter
# Final cost : 0.031792114540549934
# Compute control for a deterministic system
# Cost in iteration 0: 0.031792114540549934
# Converged in iteration 1 with cost 0.031792114540549934 because of step counter
# Final cost : 0.031792114540549934
# Compute control for a deterministic system
# Cost in iteration 0: 0.031792114540549934
# Converged in iteration 1 with cost 0.031792114540549934 because of step counter
# Final cost : 0.031792114540549934
# Compute control for a deterministic system
# Cost in iteration 0: 0.031792114540549934
# Converged in iteration 1 with cost 0.031792114540549934 because of step counter
# Final cost : 0.031792114540549934
# cost =  0.03484711525496296
# Compute control for a deterministic system
# Cost in iteration 0: 0.035734331014120706
# Converged in iteration 1 with cost 0.035734331014120706 because of step counter
# Final cost : 0.035734331014120706
# Compute control for a deterministic system
# Cost in iteration 0: 0.035734331014120706
# Converged in iteration 1 with cost 0.035734331014120706 because of step counter
# Final cost : 0.035734331014120706
# Compute control for a deterministic system
# Cost in iteration 0: 0.035734331014120706
# Converged in iteration 1 with cost 0.035734331014120706 because of step counter
# Final cost : 0.035734331014120706
# Compute control for a deterministic system
# Cost in iteration 0: 0.035734331014120706
# Converged in iteration 1 with cost 0.035734331014120706 because of step counter
# Final cost : 0.035734331014120706
# cost =  0.03800804304435843
# Compute control for a deterministic system
# Cost in iteration 0: 0.03822797913745177
# Converged in iteration 3 with cost 0.038158396386405426 because of step counter
# Final cost : 0.038158396386405426
# Compute control for a deterministic system
# Cost in iteration 0: 0.038158396386405426
# Converged in iteration 1 with cost 0.038158396386405426 because of step counter
# Final cost : 0.038158396386405426
# Compute control for a deterministic system
# Cost in iteration 0: 0.038158396386405426
# Converged in iteration 1 with cost 0.038158396386405426 because of step counter
# Final cost : 0.038158396386405426
# Compute control for a deterministic system
# Cost in iteration 0: 0.038158396386405426
# Converged in iteration 1 with cost 0.038158396386405426 because of step counter
# Final cost : 0.038158396386405426
# cost =  0.04265251980728912
# Compute control for a deterministic system
# Cost in iteration 0: 0.046522311209752434
# Converged in iteration 20 with cost 0.04453419821854362 because of step counter
# Final cost : 0.04453419821854362
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453419821854362
# Converged in iteration 1 with cost 0.04453419821854362 because of step counter
# Final cost : 0.04453419821854362
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453419821854362
# Converged in iteration 1 with cost 0.04453419821854362 because of step counter
# Final cost : 0.04453419821854362
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453419821854362
# Converged in iteration 1 with cost 0.04453419821854362 because of step counter
# Final cost : 0.04453419821854362
# cost =  0.045156601770342655
# Compute control for a deterministic system
# Cost in iteration 0: 0.05931949896894005
# Converged in iteration 36 with cost 0.046190104001794324 because of step counter
# Final cost : 0.046190104001794324
# Compute control for a deterministic system
# Cost in iteration 0: 0.046190104001794324
# Converged in iteration 1 with cost 0.046190104001794324 because of step counter
# Final cost : 0.046190104001794324
# Compute control for a deterministic system
# Cost in iteration 0: 0.046190104001794324
# Converged in iteration 1 with cost 0.046190104001794324 because of step counter
# Final cost : 0.046190104001794324
# Compute control for a deterministic system
# Cost in iteration 0: 0.046190104001794324
# Converged in iteration 1 with cost 0.046190104001794324 because of step counter
# Final cost : 0.046190104001794324
# cost =  0.04757662821548681
# Compute control for a deterministic system
# Cost in iteration 0: 0.06063892545314669
# Converged in iteration 40 with cost 0.048708948193831175 because of step counter
# Final cost : 0.048708948193831175
# Compute control for a deterministic system
# Cost in iteration 0: 0.048708948193831175
# Converged in iteration 1 with cost 0.048708948193831175 because of step counter
# Final cost : 0.048708948193831175
# Compute control for a deterministic system
# Cost in iteration 0: 0.048708948193831175
# Converged in iteration 1 with cost 0.048708948193831175 because of step counter
# Final cost : 0.048708948193831175
# Compute control for a deterministic system
# Cost in iteration 0: 0.048708948193831175
# Converged in iteration 1 with cost 0.048708948193831175 because of step counter
# Final cost : 0.048708948193831175
# cost =  0.05147487941555894
# Compute control for a deterministic system
# Cost in iteration 0: 0.05260614293528588
# Converged in iteration 6 with cost 0.05170700425197055 because of step counter
# Final cost : 0.05170700425197055
# Compute control for a deterministic system
# Cost in iteration 0: 0.05170700425197055
# Converged in iteration 1 with cost 0.05170700425197055 because of step counter
# Final cost : 0.05170700425197055
# Compute control for a deterministic system
# Cost in iteration 0: 0.05170700425197055
# Converged in iteration 1 with cost 0.05170700425197055 because of step counter
# Final cost : 0.05170700425197055
# Compute control for a deterministic system
# Cost in iteration 0: 0.05170700425197055
# Converged in iteration 1 with cost 0.05170700425197055 because of step counter
# Final cost : 0.05170700425197055
# cost =  0.05462672804919247
# Compute control for a deterministic system
# Cost in iteration 0: 0.05795173177031854
# Converged in iteration 17 with cost 0.057239445599248984 because of step counter
# Final cost : 0.057239445599248984
# Compute control for a deterministic system
# Cost in iteration 0: 0.057239445599248984
# Converged in iteration 1 with cost 0.057239445599248984 because of step counter
# Final cost : 0.057239445599248984
# Compute control for a deterministic system
# Cost in iteration 0: 0.057239445599248984
# Converged in iteration 1 with cost 0.057239445599248984 because of step counter
# Final cost : 0.057239445599248984
# Compute control for a deterministic system
# Cost in iteration 0: 0.057239445599248984
# Converged in iteration 1 with cost 0.057239445599248984 because of step counter
# Final cost : 0.057239445599248984
# cost =  0.05744164254113116
# Compute control for a deterministic system
# Cost in iteration 0: 0.07433177190787615
# Converged in iteration 67 with cost 0.0591112002846423 because of step counter
# Final cost : 0.0591112002846423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0591112002846423
# Converged in iteration 1 with cost 0.0591112002846423 because of step counter
# Final cost : 0.0591112002846423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0591112002846423
# ...
# Converged in iteration 1 with cost 0.11373885396462921 because of step counter
# Final cost : 0.11373885396462921
# Compute control for a deterministic system
# Cost in iteration 0: 0.11373885396462921
# Converged in iteration 1 with cost 0.11373885396462921 because of step counter
# Final cost : 0.11373885396462921
# Compute control for a deterministic system
# Cost in iteration 0: 0.11373885396462921
# Converged in iteration 1 with cost 0.11373885396462921 because of step counter
# Final cost : 0.11373885396462921
# cost =  0.12488303458572285
# Compute control for a deterministic system
# Cost in iteration 0: 0.12535997188092282
# Converged in iteration 1 with cost 0.12535997188092282 because of step counter
# Final cost : 0.12535997188092282
# Compute control for a deterministic system
# Cost in iteration 0: 0.12535997188092282
# Converged in iteration 1 with cost 0.12535997188092282 because of step counter
# Final cost : 0.12535997188092282
# Compute control for a deterministic system
# Cost in iteration 0: 0.12535997188092282
# Converged in iteration 1 with cost 0.12535997188092282 because of step counter
# Final cost : 0.12535997188092282
# Compute control for a deterministic system
# Cost in iteration 0: 0.12535997188092282
# Converged in iteration 1 with cost 0.12535997188092282 because of step counter
# Final cost : 0.12535997188092282
# cost =  0.13798694355193927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1395013810115927
# Converged in iteration 1 with cost 0.1395013810115927 because of step counter
# Final cost : 0.1395013810115927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1395013810115927
# Converged in iteration 1 with cost 0.1395013810115927 because of step counter
# Final cost : 0.1395013810115927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1395013810115927
# Converged in iteration 1 with cost 0.1395013810115927 because of step counter
# Final cost : 0.1395013810115927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1395013810115927
# Converged in iteration 1 with cost 0.1395013810115927 because of step counter
# Final cost : 0.1395013810115927
# cost =  0.15031476733197785
# Compute control for a deterministic system
# Cost in iteration 0: 0.15098459172441492
# Converged in iteration 2 with cost 0.15071465584286275 because of step counter
# Final cost : 0.15071465584286275
# Compute control for a deterministic system
# Cost in iteration 0: 0.15071465584286275
# Converged in iteration 1 with cost 0.15071465584286275 because of step counter
# Final cost : 0.15071465584286275
# Compute control for a deterministic system
# Cost in iteration 0: 0.15071465584286275
# Converged in iteration 1 with cost 0.15071465584286275 because of step counter
# Final cost : 0.15071465584286275
# Compute control for a deterministic system
# Cost in iteration 0: 0.15071465584286275
# Converged in iteration 1 with cost 0.15071465584286275 because of step counter
# Final cost : 0.15071465584286275
# cost =  0.1702262616483808
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723156845312564
# Converged in iteration 1 with cost 0.1723156845312564 because of step counter
# Final cost : 0.1723156845312564
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723156845312564
# Converged in iteration 1 with cost 0.1723156845312564 because of step counter
# Final cost : 0.1723156845312564
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723156845312564
# Converged in iteration 1 with cost 0.1723156845312564 because of step counter
# Final cost : 0.1723156845312564
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723156845312564
# Converged in iteration 1 with cost 0.1723156845312564 because of step counter
# Final cost : 0.1723156845312564
# cost =  0.18007611369235665
# Compute control for a deterministic system
# Cost in iteration 0: 0.19603060711614634
# Converged in iteration 2 with cost 0.18557875613577918 because of step counter
# Final cost : 0.18557875613577918
# Compute control for a deterministic system
# Cost in iteration 0: 0.18557875613577918
# Converged in iteration 1 with cost 0.18557875613577918 because of step counter
# Final cost : 0.18557875613577918
# Compute control for a deterministic system
# Cost in iteration 0: 0.18557875613577918
# Converged in iteration 1 with cost 0.18557875613577918 because of step counter
# Final cost : 0.18557875613577918
# Compute control for a deterministic system
# Cost in iteration 0: 0.18557875613577918
# Converged in iteration 1 with cost 0.18557875613577918 because of step counter
# Final cost : 0.18557875613577918
# cost =  0.18940399146774226
# Compute control for a deterministic system
# Cost in iteration 0: 0.20502654195678108
# Converged in iteration 2 with cost 0.19147785187475777 because of step counter
# Final cost : 0.19147785187475777
# Compute control for a deterministic system
# Cost in iteration 0: 0.19147785187475777
# Converged in iteration 1 with cost 0.19147785187475777 because of step counter
# Final cost : 0.19147785187475777
# Compute control for a deterministic system
# Cost in iteration 0: 0.19147785187475777
# Converged in iteration 1 with cost 0.19147785187475777 because of step counter
# Final cost : 0.19147785187475777
# Compute control for a deterministic system
# Cost in iteration 0: 0.19147785187475777
# Converged in iteration 1 with cost 0.19147785187475777 because of step counter
# Final cost : 0.19147785187475777
# cost =  0.20399607928296473
# Compute control for a deterministic system
# Cost in iteration 0: 0.20709622653918
# Converged in iteration 2 with cost 0.20505031016524064 because of step counter
# Final cost : 0.20505031016524064
# Compute control for a deterministic system
# Cost in iteration 0: 0.20505031016524064
# Converged in iteration 1 with cost 0.20505031016524064 because of step counter
# Final cost : 0.20505031016524064
# Compute control for a deterministic system
# Cost in iteration 0: 0.20505031016524064
# Converged in iteration 1 with cost 0.20505031016524064 because of step counter
# Final cost : 0.20505031016524064
# Compute control for a deterministic system
# Cost in iteration 0: 0.20505031016524064
# Converged in iteration 1 with cost 0.20505031016524064 because of step counter
# Final cost : 0.20505031016524064
# cost =  0.21790597329119732
# Compute control for a deterministic system
# Cost in iteration 0: 0.22586481501415137
# Converged in iteration 2 with cost 0.22582208044332241 because of step counter
# Final cost : 0.22582208044332241
# Compute control for a deterministic system
# Cost in iteration 0: 0.22582208044332241
# Converged in iteration 1 with cost 0.22582208044332241 because of step counter
# Final cost : 0.22582208044332241
# Compute control for a deterministic system
# Cost in iteration 0: 0.22582208044332241
# Converged in iteration 1 with cost 0.22582208044332241 because of step counter
# Final cost : 0.22582208044332241
# Compute control for a deterministic system
# Cost in iteration 0: 0.22582208044332241
# Converged in iteration 1 with cost 0.22582208044332241 because of step counter
# Final cost : 0.22582208044332241
# cost =  0.22874679774989834
# Compute control for a deterministic system
# Cost in iteration 0: 0.25192321737801315
# Converged in iteration 3 with cost 0.23008037141220478 because of step counter
# Final cost : 0.23008037141220478
# Compute control for a deterministic system
# Cost in iteration 0: 0.23008037141220478
# Converged in iteration 1 with cost 0.23008037141220478 because of step counter
# Final cost : 0.23008037141220478
# Compute control for a deterministic system
# Cost in iteration 0: 0.23008037141220478
# Converged in iteration 1 with cost 0.23008037141220478 because of step counter
# Final cost : 0.23008037141220478
# Compute control for a deterministic system
# Cost in iteration 0: 0.23008037141220478
# Converged in iteration 1 with cost 0.23008037141220478 because of step counter
# Final cost : 0.23008037141220478
# cost =  0.23545154657215042
# Compute control for a deterministic system
# Cost in iteration 0: 0.25389208700832355
# Converged in iteration 3 with cost 0.2419111305237211 because of step counter
# Final cost : 0.2419111305237211
# Compute control for a deterministic system
# Cost in iteration 0: 0.2419111305237211
# Converged in iteration 1 with cost 0.2419111305237211 because of step counter
# Final cost : 0.2419111305237211
# Compute control for a deterministic system
# Cost in iteration 0: 0.2419111305237211
# Converged in iteration 1 with cost 0.2419111305237211 because of step counter
# Final cost : 0.2419111305237211
# Compute control for a deterministic system
# Cost in iteration 0: 0.2419111305237211
# Converged in iteration 1 with cost 0.2419111305237211 because of step counter
# Final cost : 0.2419111305237211
# cost =  0.24213519066077527
# Compute control for a deterministic system
# Cost in iteration 0: 0.3638601969575978
# Converged in iteration 17 with cost 0.24514085284160214 because of step counter
# Final cost : 0.24514085284160214
# Compute control for a deterministic system
# Cost in iteration 0: 0.24514085284160214
# Converged in iteration 1 with cost 0.24514085284160214 because of step counter
# Final cost : 0.24514085284160214
# Compute control for a deterministic system
# Cost in iteration 0: 0.24514085284160214
# Converged in iteration 1 with cost 0.24514085284160214 because of step counter
# Final cost : 0.24514085284160214
# Compute control for a deterministic system
# Cost in iteration 0: 0.24514085284160214
# Converged in iteration 1 with cost 0.24514085284160214 because of step counter
# Final cost : 0.24514085284160214
# cost =  0.25142359276967075
# Compute control for a deterministic system
# Cost in iteration 0: 0.3034224433470214
# Converged in iteration 3 with cost 0.25214160296076904 because of step counter
# Final cost : 0.25214160296076904
# Compute control for a deterministic system
# Cost in iteration 0: 0.25214160296076904
# Converged in iteration 1 with cost 0.25214160296076904 because of step counter
# Final cost : 0.25214160296076904
# Compute control for a deterministic system
# Cost in iteration 0: 0.25214160296076904
# Converged in iteration 1 with cost 0.25214160296076904 because of step counter
# Final cost : 0.25214160296076904
# Compute control for a deterministic system
# Cost in iteration 0: 0.25214160296076904
# Converged in iteration 1 with cost 0.25214160296076904 because of step counter
# Final cost : 0.25214160296076904
# cost =  0.26475223101124756
# Compute control for a deterministic system
# Cost in iteration 0: 0.27965032223379244
# Converged in iteration 3 with cost 0.26620698792585307 because of step counter
# Final cost : 0.26620698792585307
# Compute control for a deterministic system
# Cost in iteration 0: 0.26620698792585307
# Converged in iteration 1 with cost 0.26620698792585307 because of step counter
# Final cost : 0.26620698792585307
# Compute control for a deterministic system
# Cost in iteration 0: 0.26620698792585307
# Converged in iteration 1 with cost 0.26620698792585307 because of step counter
# Final cost : 0.26620698792585307
# Compute control for a deterministic system
# Cost in iteration 0: 0.26620698792585307
# Converged in iteration 1 with cost 0.26620698792585307 because of step counter
# Final cost : 0.26620698792585307
# cost =  0.25627583868386494
# Compute control for a deterministic system
# Cost in iteration 0: 0.2940966314863302
# Converged in iteration 3 with cost 0.2806829632960788 because of step counter
# Final cost : 0.2806829632960788
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806829632960788
# Converged in iteration 1 with cost 0.2806829632960788 because of step counter
# Final cost : 0.2806829632960788
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806829632960788
# Converged in iteration 1 with cost 0.2806829632960788 because of step counter
# Final cost : 0.2806829632960788
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806829632960788
# Converged in iteration 1 with cost 0.2806829632960788 because of step counter
# Final cost : 0.2806829632960788
# cost =  0.2405891573381435
# Compute control for a deterministic system
# Cost in iteration 0: 0.4122189967048815
# Converged in iteration 15 with cost 0.24934460324941854 because of step counter
# Final cost : 0.24934460324941854
# Compute control for a deterministic system
# Cost in iteration 0: 0.24934460324941854
# Converged in iteration 1 with cost 0.24934460324941854 because of step counter
# Final cost : 0.24934460324941854
# Compute control for a deterministic system
# Cost in iteration 0: 0.24934460324941854
# Converged in iteration 1 with cost 0.24934460324941854 because of step counter
# Final cost : 0.24934460324941854
# Compute control for a deterministic system
# Cost in iteration 0: 0.24934460324941854
# Converged in iteration 1 with cost 0.24934460324941854 because of step counter
# Final cost : 0.24934460324941854
# cost =  0.22984464607133953
# Compute control for a deterministic system
# Cost in iteration 0: 0.4685904833437526
# Converged in iteration 18 with cost 0.23447702948779464 because of step counter
# Final cost : 0.23447702948779464
# Compute control for a deterministic system
# Cost in iteration 0: 0.23447702948779464
# Converged in iteration 1 with cost 0.23447702948779464 because of step counter
# Final cost : 0.23447702948779464
# Compute control for a deterministic system
# Cost in iteration 0: 0.23447702948779464
# Converged in iteration 1 with cost 0.23447702948779464 because of step counter
# Final cost : 0.23447702948779464
# Compute control for a deterministic system
# Cost in iteration 0: 0.23447702948779464
# Converged in iteration 1 with cost 0.23447702948779464 because of step counter
# Final cost : 0.23447702948779464
# cost =  0.2225361522961308
# Compute control for a deterministic system
# Cost in iteration 0: 0.5176882665440021
# Converged in iteration 15 with cost 0.23454066018963168 because of step counter
# Final cost : 0.23454066018963168
# Compute control for a deterministic system
# Cost in iteration 0: 0.23454066018963168
# Converged in iteration 1 with cost 0.23454066018963168 because of step counter
# Final cost : 0.23454066018963168
# Compute control for a deterministic system
# Cost in iteration 0: 0.23454066018963168
# Converged in iteration 1 with cost 0.23454066018963168 because of step counter
# Final cost : 0.23454066018963168
# Compute control for a deterministic system
# Cost in iteration 0: 0.23454066018963168
# Converged in iteration 1 with cost 0.23454066018963168 because of step counter
# Final cost : 0.23454066018963168
# cost =  0.214475836145378
# Compute control for a deterministic system
# Cost in iteration 0: 0.40764499371822077
# Converged in iteration 5 with cost 0.21489916412778984 because of step counter
# Final cost : 0.21489916412778984
# Compute control for a deterministic system
# Cost in iteration 0: 0.21489916412778984
# Converged in iteration 1 with cost 0.21489916412778984 because of step counter
# Final cost : 0.21489916412778984
# Compute control for a deterministic system
# Cost in iteration 0: 0.21489916412778984
# Converged in iteration 1 with cost 0.21489916412778984 because of step counter
# Final cost : 0.21489916412778984
# Compute control for a deterministic system
# Cost in iteration 0: 0.21489916412778984
# Converged in iteration 1 with cost 0.21489916412778984 because of step counter
# Final cost : 0.21489916412778984
# cost =  0.20451482229378792
# Compute control for a deterministic system
# Cost in iteration 0: 0.4102029658437913
# Converged in iteration 15 with cost 0.20976800407854929 because of step counter
# Final cost : 0.20976800407854929
# Compute control for a deterministic system
# Cost in iteration 0: 0.20976800407854929
# Converged in iteration 1 with cost 0.20976800407854929 because of step counter
# Final cost : 0.20976800407854929
# Compute control for a deterministic system
# Cost in iteration 0: 0.20976800407854929
# Converged in iteration 1 with cost 0.20976800407854929 because of step counter
# Final cost : 0.20976800407854929
# Compute control for a deterministic system
# Cost in iteration 0: 0.20976800407854929
# Converged in iteration 1 with cost 0.20976800407854929 because of step counter
# Final cost : 0.20976800407854929
# cost =  0.19012973463658012
# Compute control for a deterministic system
# Cost in iteration 0: 0.4277355169201951

# %%
save(results_min)
