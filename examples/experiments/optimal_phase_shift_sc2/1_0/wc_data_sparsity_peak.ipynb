# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,75], wc.inh[0,75]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 18.896551724137932
# peaks =  [  33  221  409  598  787  976 1165 1354 1543 1732 1921 2110 2299 2488
#  2677 2866 3055 3244 3433 3622 3811 4000 4189 4378 4567 4755 4944 5133
#  5322 5511 5700 5889]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
empty_dict = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
save(results_peak)

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

initstep = 1e-3
ind_list = range(41)
options = [True, True, True, True, True, True, True, True]
#options = [False, False, False, False, False, False, False, False]

for k in range(3):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            #if type(results_peak["control"][i_w][i_shift]) != type(None):
            #    continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, empty_dict, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]
            continue

            wc_controlled.step = initstep
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            # increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.1
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy() * 1.05
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = initstep
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.02954755633822926
# Converged in iteration 118 with cost 0.018990937511359045 because of step counter
# Final cost : 0.018990937511359045
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990937511359045
# Converged in iteration 1 with cost 0.018990937511359045 because of step counter
# Final cost : 0.018990937511359045
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990937511359045
# Converged in iteration 1 with cost 0.018990937511359045 because of step counter
# Final cost : 0.018990937511359045
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990937511359045
# Converged in iteration 1 with cost 0.018990937511359045 because of step counter
# Final cost : 0.018990937511359045
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990937511359045
# Converged in iteration 1 with cost 0.018990937511359045 because of step counter
# Final cost : 0.018990937511359045
# Compute control for a deterministic system
# Cost in iteration 0: 0.04163798109572796
# Converged in iteration 120 with cost 0.025751406000288912 because of step counter
# Final cost : 0.025751406000288912
# Compute control for a deterministic system
# Cost in iteration 0: 0.025751406000288912
# Converged in iteration 1 with cost 0.025751406000288912 because of step counter
# Final cost : 0.025751406000288912
# Compute control for a deterministic system
# Cost in iteration 0: 0.025751406000288912
# Converged in iteration 1 with cost 0.025751406000288912 because of step counter
# Final cost : 0.025751406000288912
# Compute control for a deterministic system
# Cost in iteration 0: 0.025751406000288912
# Converged in iteration 1 with cost 0.025751406000288912 because of step counter
# Final cost : 0.025751406000288912
# Compute control for a deterministic system
# Cost in iteration 0: 0.025751406000288912
# Converged in iteration 1 with cost 0.025751406000288912 because of step counter
# Final cost : 0.025751406000288912
# Compute control for a deterministic system
# Cost in iteration 0: 0.03856739190743987
# Converged in iteration 124 with cost 0.02786869571945211 because of step counter
# Final cost : 0.02786869571945211
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786869571945211
# Converged in iteration 1 with cost 0.02786869571945211 because of step counter
# Final cost : 0.02786869571945211
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786869571945211
# Converged in iteration 1 with cost 0.02786869571945211 because of step counter
# Final cost : 0.02786869571945211
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786869571945211
# Converged in iteration 1 with cost 0.02786869571945211 because of step counter
# Final cost : 0.02786869571945211
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786869571945211
# Converged in iteration 1 with cost 0.02786869571945211 because of step counter
# Final cost : 0.02786869571945211
# Compute control for a deterministic system
# Cost in iteration 0: 0.037983248057257786
# Converged in iteration 108 with cost 0.03063953449854517 because of step counter
# Final cost : 0.03063953449854517
# Compute control for a deterministic system
# Cost in iteration 0: 0.03063953449854517
# Converged in iteration 1 with cost 0.03063953449854517 because of step counter
# Final cost : 0.03063953449854517
# Compute control for a deterministic system
# Cost in iteration 0: 0.03063953449854517
# Converged in iteration 1 with cost 0.03063953449854517 because of step counter
# Final cost : 0.03063953449854517
# Compute control for a deterministic system
# Cost in iteration 0: 0.03063953449854517
# Converged in iteration 1 with cost 0.03063953449854517 because of step counter
# Final cost : 0.03063953449854517
# Compute control for a deterministic system
# Cost in iteration 0: 0.03063953449854517
# Converged in iteration 1 with cost 0.03063953449854517 because of step counter
# Final cost : 0.03063953449854517
# Compute control for a deterministic system
# Cost in iteration 0: 0.029854882096637524
# Converged in iteration 1 with cost 0.029854882096637524 because of step counter
# Final cost : 0.029854882096637524
# Compute control for a deterministic system
# Cost in iteration 0: 0.029854882096637524
# Converged in iteration 1 with cost 0.029854882096637524 because of step counter
# Final cost : 0.029854882096637524
# Compute control for a deterministic system
# Cost in iteration 0: 0.029854882096637524
# Converged in iteration 1 with cost 0.029854882096637524 because of step counter
# Final cost : 0.029854882096637524
# Compute control for a deterministic system
# Cost in iteration 0: 0.029854882096637524
# Converged in iteration 1 with cost 0.029854882096637524 because of step counter
# Final cost : 0.029854882096637524
# Compute control for a deterministic system
# Cost in iteration 0: 0.029854882096637524
# Converged in iteration 1 with cost 0.029854882096637524 because of step counter
# Final cost : 0.029854882096637524
# Compute control for a deterministic system
# Cost in iteration 0: 0.032521644571271775
# Converged in iteration 1 with cost 0.032521644571271775 because of step counter
# Final cost : 0.032521644571271775
# Compute control for a deterministic system
# Cost in iteration 0: 0.032521644571271775
# Converged in iteration 1 with cost 0.032521644571271775 because of step counter
# Final cost : 0.032521644571271775
# Compute control for a deterministic system
# Cost in iteration 0: 0.032521644571271775
# Converged in iteration 1 with cost 0.032521644571271775 because of step counter
# Final cost : 0.032521644571271775
# Compute control for a deterministic system
# Cost in iteration 0: 0.032521644571271775
# Converged in iteration 1 with cost 0.032521644571271775 because of step counter
# Final cost : 0.032521644571271775
# Compute control for a deterministic system
# Cost in iteration 0: 0.032521644571271775
# Converged in iteration 1 with cost 0.032521644571271775 because of step counter
# Final cost : 0.032521644571271775
# Compute control for a deterministic system
# Cost in iteration 0: 0.03496204618434622
# Converged in iteration 2 with cost 0.034962037974262034 because of step counter
# Final cost : 0.034962037974262034
# Compute control for a deterministic system
# Cost in iteration 0: 0.034962037974262034
# Converged in iteration 1 with cost 0.034962037974262034 because of step counter
# Final cost : 0.034962037974262034
# Compute control for a deterministic system
# Cost in iteration 0: 0.034962037974262034
# Converged in iteration 1 with cost 0.034962037974262034 because of step counter
# Final cost : 0.034962037974262034
# Compute control for a deterministic system
# Cost in iteration 0: 0.034962037974262034
# Converged in iteration 1 with cost 0.034962037974262034 because of step counter
# Final cost : 0.034962037974262034
# Compute control for a deterministic system
# Cost in iteration 0: 0.034962037974262034
# Converged in iteration 1 with cost 0.034962037974262034 because of step counter
# Final cost : 0.034962037974262034
# Compute control for a deterministic system
# Cost in iteration 0: 0.03857559070839344
# Converged in iteration 1 with cost 0.03857559070839344 because of step counter
# Final cost : 0.03857559070839344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03857559070839344
# Converged in iteration 1 with cost 0.03857559070839344 because of step counter
# Final cost : 0.03857559070839344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03857559070839344
# Converged in iteration 1 with cost 0.03857559070839344 because of step counter
# Final cost : 0.03857559070839344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03857559070839344
# Converged in iteration 1 with cost 0.03857559070839344 because of step counter
# Final cost : 0.03857559070839344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03857559070839344
# Converged in iteration 1 with cost 0.03857559070839344 because of step counter
# Final cost : 0.03857559070839344
# Compute control for a deterministic system
# Cost in iteration 0: 0.041696409671216475
# Converged in iteration 29 with cost 0.041516979132426274 because of step counter
# Final cost : 0.041516979132426274
# Compute control for a deterministic system
# Cost in iteration 0: 0.041516979132426274
# Converged in iteration 1 with cost 0.041516979132426274 because of step counter
# Final cost : 0.041516979132426274
# Compute control for a deterministic system
# Cost in iteration 0: 0.041516979132426274
# Converged in iteration 1 with cost 0.041516979132426274 because of step counter
# Final cost : 0.041516979132426274
# Compute control for a deterministic system
# Cost in iteration 0: 0.041516979132426274
# Converged in iteration 1 with cost 0.041516979132426274 because of step counter
# Final cost : 0.041516979132426274
# Compute control for a deterministic system
# Cost in iteration 0: 0.041516979132426274
# Converged in iteration 1 with cost 0.041516979132426274 because of step counter
# Final cost : 0.041516979132426274
# Compute control for a deterministic system
# Cost in iteration 0: 0.05088199737571703
# Converged in iteration 89 with cost 0.042759627226015354 because of step counter
# Final cost : 0.042759627226015354
# Compute control for a deterministic system
# Cost in iteration 0: 0.042759627226015354
# Converged in iteration 1 with cost 0.042759627226015354 because of step counter
# Final cost : 0.042759627226015354
# Compute control for a deterministic system
# Cost in iteration 0: 0.042759627226015354
# Converged in iteration 1 with cost 0.042759627226015354 because of step counter
# Final cost : 0.042759627226015354
# Compute control for a deterministic system
# Cost in iteration 0: 0.042759627226015354
# Converged in iteration 1 with cost 0.042759627226015354 because of step counter
# Final cost : 0.042759627226015354
# Compute control for a deterministic system
# Cost in iteration 0: 0.042759627226015354
# Converged in iteration 1 with cost 0.042759627226015354 because of step counter
# Final cost : 0.042759627226015354
# Compute control for a deterministic system
# Cost in iteration 0: 0.04792594847225062
# Converged in iteration 56 with cost 0.04569511129981485 because of step counter
# Final cost : 0.04569511129981485
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569511129981485
# Converged in iteration 1 with cost 0.04569511129981485 because of step counter
# Final cost : 0.04569511129981485
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569511129981485
# Converged in iteration 1 with cost 0.04569511129981485 because of step counter
# Final cost : 0.04569511129981485
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569511129981485
# Converged in iteration 1 with cost 0.04569511129981485 because of step counter
# Final cost : 0.04569511129981485
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569511129981485
# Converged in iteration 1 with cost 0.04569511129981485 because of step counter
# Final cost : 0.04569511129981485
# Compute control for a deterministic system
# Cost in iteration 0: 0.05701764425113881
# Converged in iteration 122 with cost 0.048225338699349286 because of step counter
# Final cost : 0.048225338699349286
# Compute control for a deterministic system
# Cost in iteration 0: 0.048225338699349286
# Converged in iteration 1 with cost 0.048225338699349286 because of step counter
# Final cost : 0.048225338699349286
# Compute control for a deterministic system
# Cost in iteration 0: 0.048225338699349286
# Converged in iteration 1 with cost 0.048225338699349286 because of step counter
# Final cost : 0.048225338699349286
# Compute control for a deterministic system
# Cost in iteration 0: 0.048225338699349286
# Converged in iteration 1 with cost 0.048225338699349286 because of step counter
# Final cost : 0.048225338699349286
# Compute control for a deterministic system
# Cost in iteration 0: 0.048225338699349286
# Converged in iteration 1 with cost 0.048225338699349286 because of step counter
# Final cost : 0.048225338699349286
# Compute control for a deterministic system
# Cost in iteration 0: 0.05168621363927185
# Converged in iteration 50 with cost 0.051179120007109474 because of step counter
# Final cost : 0.051179120007109474
# Compute control for a deterministic system
# Cost in iteration 0: 0.051179120007109474
# Converged in iteration 1 with cost 0.051179120007109474 because of step counter
# Final cost : 0.051179120007109474
# Compute control for a deterministic system
# Cost in iteration 0: 0.051179120007109474
# Converged in iteration 1 with cost 0.051179120007109474 because of step counter
# Final cost : 0.051179120007109474
# Compute control for a deterministic system
# Cost in iteration 0: 0.051179120007109474
# Converged in iteration 1 with cost 0.051179120007109474 because of step counter
# Final cost : 0.051179120007109474
# Compute control for a deterministic system
# Cost in iteration 0: 0.051179120007109474
# Converged in iteration 1 with cost 0.051179120007109474 because of step counter
# Final cost : 0.051179120007109474
# Compute control for a deterministic system
# Cost in iteration 0: 0.06706570280467591
# Converged in iteration 196 with cost 0.053313606113576384 because of step counter
# Final cost : 0.053313606113576384
# Compute control for a deterministic system
# Cost in iteration 0: 0.053313606113576384
# Converged in iteration 1 with cost 0.053313606113576384 because of step counter
# Final cost : 0.053313606113576384
# Compute control for a deterministic system
# Cost in iteration 0: 0.053313606113576384
# Converged in iteration 1 with cost 0.053313606113576384 because of step counter
# Final cost : 0.053313606113576384
# Compute control for a deterministic system
# Cost in iteration 0: 0.053313606113576384
# Converged in iteration 1 with cost 0.053313606113576384 because of step counter
# Final cost : 0.053313606113576384
# Compute control for a deterministic system
# Cost in iteration 0: 0.053313606113576384
# Converged in iteration 1 with cost 0.053313606113576384 because of step counter
# Final cost : 0.053313606113576384
# Compute control for a deterministic system
# Cost in iteration 0: 0.05839908524176673
# Converged in iteration 84 with cost 0.05619597027405433 because of step counter
# Final cost : 0.05619597027405433
# Compute control for a deterministic system
# Cost in iteration 0: 0.05619597027405433
# Converged in iteration 1 with cost 0.05619597027405433 because of step counter
# Final cost : 0.05619597027405433
# Compute control for a deterministic system
# Cost in iteration 0: 0.05619597027405433
# Converged in iteration 1 with cost 0.05619597027405433 because of step counter
# Final cost : 0.05619597027405433
# Compute control for a deterministic system
# Cost in iteration 0: 0.05619597027405433
# Converged in iteration 1 with cost 0.05619597027405433 because of step counter
# Final cost : 0.05619597027405433
# Compute control for a deterministic system
# Cost in iteration 0: 0.05619597027405433
# Converged in iteration 1 with cost 0.05619597027405433 because of step counter
# Final cost : 0.05619597027405433
# Compute control for a deterministic system
# Cost in iteration 0: 0.07406017683993985
# Cost in iteration 200: 0.059916579913685396
# Final cost : 0.059916579913685396
# Compute control for a deterministic system
# Cost in iteration 0: 0.059916579913685396
# Converged in iteration 24 with cost 0.05984629259258868 because of step counter
# Final cost : 0.05984629259258868
# Compute control for a deterministic system
# Cost in iteration 0: 0.05984629259258868
# Converged in iteration 1 with cost 0.05984629259258868 because of step counter
# Final cost : 0.05984629259258868
# Compute control for a deterministic system
# Cost in iteration 0: 0.05984629259258868
# Converged in iteration 1 with cost 0.05984629259258868 because of step counter
# Final cost : 0.05984629259258868
# Compute control for a deterministic system
# Cost in iteration 0: 0.05984629259258868
# Converged in iteration 1 with cost 0.05984629259258868 because of step counter
# Final cost : 0.05984629259258868
# Compute control for a deterministic system
# Cost in iteration 0: 0.07251613894491336
# Converged in iteration 184 with cost 0.06133281556920751 because of step counter
# Final cost : 0.06133281556920751
# Compute control for a deterministic system
# Cost in iteration 0: 0.06133281556920751
# Converged in iteration 1 with cost 0.06133281556920751 because of step counter
# Final cost : 0.06133281556920751
# Compute control for a deterministic system
# Cost in iteration 0: 0.06133281556920751
# Converged in iteration 1 with cost 0.06133281556920751 because of step counter
# Final cost : 0.06133281556920751
# Compute control for a deterministic system
# Cost in iteration 0: 0.06133281556920751
# Converged in iteration 1 with cost 0.06133281556920751 because of step counter
# Final cost : 0.06133281556920751
# Compute control for a deterministic system
# Cost in iteration 0: 0.06133281556920751
# Converged in iteration 1 with cost 0.06133281556920751 because of step counter
# Final cost : 0.06133281556920751
# Compute control for a deterministic system
# Cost in iteration 0: 0.0732351598523847
# Converged in iteration 145 with cost 0.0635792575805661 because of step counter
# Final cost : 0.0635792575805661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0635792575805661
# Converged in iteration 1 with cost 0.0635792575805661 because of step counter
# Final cost : 0.0635792575805661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0635792575805661
# Converged in iteration 1 with cost 0.0635792575805661 because of step counter
# Final cost : 0.0635792575805661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0635792575805661
# Converged in iteration 1 with cost 0.0635792575805661 because of step counter
# Final cost : 0.0635792575805661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0635792575805661
# Converged in iteration 1 with cost 0.0635792575805661 because of step counter
# Final cost : 0.0635792575805661
# Compute control for a deterministic system
# Cost in iteration 0: 0.07168778107422523
# Cost in iteration 200: 0.06688798119574638
# Final cost : 0.06688798119574638
# Compute control for a deterministic system
# Cost in iteration 0: 0.06688798119574638
# Converged in iteration 23 with cost 0.06688797975109623 because of vanishing difference
# Final cost : 0.06688797975109623
# Compute control for a deterministic system
# Cost in iteration 0: 0.06688797975109623
# Converged in iteration 8 with cost 0.06688797975006068 because of step counter
# Final cost : 0.06688797975006068
# Compute control for a deterministic system
# Cost in iteration 0: 0.06688797975006068
# Converged in iteration 1 with cost 0.06688797975006068 because of step counter
# Final cost : 0.06688797975006068
# Compute control for a deterministic system
# Cost in iteration 0: 0.06688797975006068
# Converged in iteration 1 with cost 0.06688797975006068 because of step counter
# Final cost : 0.06688797975006068
# Compute control for a deterministic system
# Cost in iteration 0: 0.11001893712000295
# Converged in iteration 150 with cost 0.0847275487520351 because of step counter
# Final cost : 0.0847275487520351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847275487520351
# Converged in iteration 1 with cost 0.0847275487520351 because of step counter
# Final cost : 0.0847275487520351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847275487520351
# Converged in iteration 1 with cost 0.0847275487520351 because of step counter
# Final cost : 0.0847275487520351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847275487520351
# Converged in iteration 1 with cost 0.0847275487520351 because of step counter
# Final cost : 0.0847275487520351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847275487520351
# Converged in iteration 1 with cost 0.0847275487520351 because of step counter
# Final cost : 0.0847275487520351
# Compute control for a deterministic system
# Cost in iteration 0: 0.104537479831593
# Cost in iteration 200: 0.06656883480935714
# Final cost : 0.06656883480935714
# Compute control for a deterministic system
# Cost in iteration 0: 0.06656883480935714
# Cost in iteration 200: 0.06534732999692355
# Final cost : 0.06534732999692355
# Compute control for a deterministic system
# Cost in iteration 0: 0.06534732999692355
# Converged in iteration 8 with cost 0.06521241085118132 because of step counter
# Final cost : 0.06521241085118132
# Compute control for a deterministic system
# Cost in iteration 0: 0.06521241085118132
# Converged in iteration 1 with cost 0.06521241085118132 because of step counter
# Final cost : 0.06521241085118132
# Compute control for a deterministic system
# Cost in iteration 0: 0.06521241085118132
# Converged in iteration 1 with cost 0.06521241085118132 because of step counter
# Final cost : 0.06521241085118132
# Compute control for a deterministic system
# Cost in iteration 0: 0.10084227735252776
# Cost in iteration 200: 0.06400048317315249
# Final cost : 0.06400048317315249
# Compute control for a deterministic system
# Cost in iteration 0: 0.06400048317315249
# Cost in iteration 200: 0.06249728901257484
# Final cost : 0.06249728901257484
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249728901257484
# Converged in iteration 16 with cost 0.062359609028909066 because of step counter
# Final cost : 0.062359609028909066
# Compute control for a deterministic system
# Cost in iteration 0: 0.062359609028909066
# Converged in iteration 1 with cost 0.062359609028909066 because of step counter
# Final cost : 0.062359609028909066
# Compute control for a deterministic system
# Cost in iteration 0: 0.062359609028909066
# Converged in iteration 1 with cost 0.062359609028909066 because of step counter
# Final cost : 0.062359609028909066
# Compute control for a deterministic system
# Cost in iteration 0: 0.08501943387087035
# Cost in iteration 200: 0.05978263804424636
# Final cost : 0.05978263804424636
# Compute control for a deterministic system
# Cost in iteration 0: 0.05978263804424636
# Converged in iteration 41 with cost 0.059341562060933536 because of step counter
# Final cost : 0.059341562060933536
# Compute control for a deterministic system
# Cost in iteration 0: 0.059341562060933536
# Converged in iteration 1 with cost 0.059341562060933536 because of step counter
# Final cost : 0.059341562060933536
# Compute control for a deterministic system
# Cost in iteration 0: 0.059341562060933536
# Converged in iteration 1 with cost 0.059341562060933536 because of step counter
# Final cost : 0.059341562060933536
# Compute control for a deterministic system
# Cost in iteration 0: 0.059341562060933536
# Converged in iteration 1 with cost 0.059341562060933536 because of step counter
# Final cost : 0.059341562060933536
# Compute control for a deterministic system
# Cost in iteration 0: 0.09668393541549873
# Cost in iteration 200: 0.059374180549836945
# Final cost : 0.059374180549836945
# Compute control for a deterministic system
# Cost in iteration 0: 0.059374180549836945
# Cost in iteration 200: 0.058268006203862986
# Final cost : 0.058268006203862986
# Compute control for a deterministic system
# Cost in iteration 0: 0.058268006203862986
# Converged in iteration 159 with cost 0.05804122546277527 because of vanishing difference
# Final cost : 0.05804122546277527
# Compute control for a deterministic system
# Cost in iteration 0: 0.05804122546242341
# Converged in iteration 3 with cost 0.05804122545419915 because of step counter
# Final cost : 0.05804122545419915
# Compute control for a deterministic system
# Cost in iteration 0: 0.05804122545419915
# Converged in iteration 1 with cost 0.05804122545419915 because of step counter
# Final cost : 0.05804122545419915
# Compute control for a deterministic system
# Cost in iteration 0: 0.09614262670119714
# Cost in iteration 200: 0.05697534891400726
# Final cost : 0.05697534891400726
# Compute control for a deterministic system
# Cost in iteration 0: 0.05697534891400726
# Cost in iteration 200: 0.05626202433186572
# Final cost : 0.05626202433186572
# Compute control for a deterministic system
# Cost in iteration 0: 0.05626202433186572
# Cost in iteration 200: 0.0560672935551596
# Final cost : 0.0560672935551596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0560672935551596
# Converged in iteration 2 with cost 0.05606728611256821 because of step counter
# Final cost : 0.05606728611256821
# Compute control for a deterministic system
# Cost in iteration 0: 0.05606728611256821
# Converged in iteration 1 with cost 0.05606728611256821 because of step counter
# Final cost : 0.05606728611256821
# Compute control for a deterministic system
# Cost in iteration 0: 0.09091163941784866
# Cost in iteration 200: 0.05321498897790912
# Final cost : 0.05321498897790912
# Compute control for a deterministic system
# Cost in iteration 0: 0.05321498897790912
# Cost in iteration 200: 0.0519234085549435
# Final cost : 0.0519234085549435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0519234085549435
# Cost in iteration 200: 0.051781670685869585
# Final cost : 0.051781670685869585
# Compute control for a deterministic system
# Cost in iteration 0: 0.051781670685869585
# Converged in iteration 6 with cost 0.05178106794978552 because of step counter
# Final cost : 0.05178106794978552
# Compute control for a deterministic system
# Cost in iteration 0: 0.05178106794978552
# Converged in iteration 1 with cost 0.05178106794978552 because of step counter
# Final cost : 0.05178106794978552
# Compute control for a deterministic system
# Cost in iteration 0: 0.07416168666308327
# Cost in iteration 200: 0.04807236176521872
# Final cost : 0.04807236176521872
# Compute control for a deterministic system
# Cost in iteration 0: 0.04807236176521872
# Converged in iteration 77 with cost 0.047044001223168326 because of step counter
# Final cost : 0.047044001223168326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047044001223168326
# Converged in iteration 1 with cost 0.047044001223168326 because of step counter
# Final cost : 0.047044001223168326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047044001223168326
# Converged in iteration 1 with cost 0.047044001223168326 because of step counter
# Final cost : 0.047044001223168326
# Compute control for a deterministic system
# Cost in iteration 0: 0.047044001223168326
# Converged in iteration 1 with cost 0.047044001223168326 because of step counter
# Final cost : 0.047044001223168326
# Compute control for a deterministic system
# Cost in iteration 0: 0.0888849087597511
# Cost in iteration 200: 0.04820803566672777
# Final cost : 0.04820803566672777
# Compute control for a deterministic system
# Cost in iteration 0: 0.04820803566672777
# Converged in iteration 13 with cost 0.04819360472629173 because of step counter
# Final cost : 0.04819360472629173
# Compute control for a deterministic system
# Cost in iteration 0: 0.04819360472629173
# Converged in iteration 1 with cost 0.04819360472629173 because of step counter
# Final cost : 0.04819360472629173
# Compute control for a deterministic system
# Cost in iteration 0: 0.04819360472629173
# Converged in iteration 1 with cost 0.04819360472629173 because of step counter
# Final cost : 0.04819360472629173
# Compute control for a deterministic system
# Cost in iteration 0: 0.04819360472629173
# Converged in iteration 1 with cost 0.04819360472629173 because of step counter
# Final cost : 0.04819360472629173
# Compute control for a deterministic system
# Cost in iteration 0: 0.08747445526912943
# Cost in iteration 200: 0.0461983300391348
# Final cost : 0.0461983300391348
# Compute control for a deterministic system
# Cost in iteration 0: 0.0461983300391348
# Converged in iteration 9 with cost 0.046192476037858934 because of step counter
# Final cost : 0.046192476037858934
# Compute control for a deterministic system
# Cost in iteration 0: 0.046192476037858934
# Converged in iteration 1 with cost 0.046192476037858934 because of step counter
# Final cost : 0.046192476037858934
# Compute control for a deterministic system
# Cost in iteration 0: 0.046192476037858934
# Converged in iteration 1 with cost 0.046192476037858934 because of step counter
# Final cost : 0.046192476037858934
# Compute control for a deterministic system
# Cost in iteration 0: 0.046192476037858934
# Converged in iteration 1 with cost 0.046192476037858934 because of step counter
# Final cost : 0.046192476037858934
# Compute control for a deterministic system
# Cost in iteration 0: 0.06429634902776396
# Cost in iteration 200: 0.03762472040884333
# Final cost : 0.03762472040884333
# Compute control for a deterministic system
# Cost in iteration 0: 0.03762472040884333
# Converged in iteration 108 with cost 0.03643820960796312 because of step counter
# Final cost : 0.03643820960796312
# Compute control for a deterministic system
# Cost in iteration 0: 0.03643820960796312
# Converged in iteration 1 with cost 0.03643820960796312 because of step counter
# Final cost : 0.03643820960796312
# Compute control for a deterministic system
# Cost in iteration 0: 0.03643820960796312
# Converged in iteration 1 with cost 0.03643820960796312 because of step counter
# Final cost : 0.03643820960796312
# Compute control for a deterministic system
# Cost in iteration 0: 0.03643820960796312
# Converged in iteration 1 with cost 0.03643820960796312 because of step counter
# Final cost : 0.03643820960796312
# Compute control for a deterministic system
# Cost in iteration 0: 0.07810390233606185
# Cost in iteration 200: 0.03695422283560589
# Final cost : 0.03695422283560589
# Compute control for a deterministic system
# Cost in iteration 0: 0.03695422283560589
# Cost in iteration 200: 0.03579047774689081
# Final cost : 0.03579047774689081
# Compute control for a deterministic system
# Cost in iteration 0: 0.03579047774689081
# Cost in iteration 200: 0.03562092145581054
# Final cost : 0.03562092145581054
# Compute control for a deterministic system
# Cost in iteration 0: 0.03562092145581054
# Converged in iteration 17 with cost 0.0355418460517958 because of step counter
# Final cost : 0.0355418460517958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0355418460517958
# Converged in iteration 1 with cost 0.0355418460517958 because of step counter
# Final cost : 0.0355418460517958
# Compute control for a deterministic system
# Cost in iteration 0: 0.07587699773708259
# Cost in iteration 200: 0.03411862452796561
# Final cost : 0.03411862452796561
# Compute control for a deterministic system
# Cost in iteration 0: 0.03411862452796561
# Cost in iteration 200: 0.03356518314018131
# Final cost : 0.03356518314018131
# Compute control for a deterministic system
# Cost in iteration 0: 0.03356518314018131
# Cost in iteration 200: 0.03337615993151786
# Final cost : 0.03337615993151786
# Compute control for a deterministic system
# Cost in iteration 0: 0.03337615993151786
# Converged in iteration 7 with cost 0.03336625325381304 because of step counter
# Final cost : 0.03336625325381304
# Compute control for a deterministic system
# Cost in iteration 0: 0.03336625325381304
# Converged in iteration 1 with cost 0.03336625325381304 because of step counter
# Final cost : 0.03336625325381304
# Compute control for a deterministic system
# Cost in iteration 0: 0.07361693649214902
# Cost in iteration 200: 0.031572204149026284
# Final cost : 0.031572204149026284
# Compute control for a deterministic system
# Cost in iteration 0: 0.031572204149026284
# Converged in iteration 22 with cost 0.03154701953249624 because of step counter
# Final cost : 0.03154701953249624
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154701953249624
# Converged in iteration 1 with cost 0.03154701953249624 because of step counter
# Final cost : 0.03154701953249624
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154701953249624
# Converged in iteration 1 with cost 0.03154701953249624 because of step counter
# Final cost : 0.03154701953249624
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154701953249624
# Converged in iteration 1 with cost 0.03154701953249624 because of step counter
# Final cost : 0.03154701953249624
# Compute control for a deterministic system
# Cost in iteration 0: 0.0545206306970432
# Cost in iteration 200: 0.0269991339948949
# Final cost : 0.0269991339948949
# Compute control for a deterministic system
# Cost in iteration 0: 0.0269991339948949
# Converged in iteration 131 with cost 0.025862002218287043 because of step counter
# Final cost : 0.025862002218287043
# Compute control for a deterministic system
# Cost in iteration 0: 0.025862002218287043
# Converged in iteration 1 with cost 0.025862002218287043 because of step counter
# Final cost : 0.025862002218287043
# Compute control for a deterministic system
# Cost in iteration 0: 0.025862002218287043
# Converged in iteration 1 with cost 0.025862002218287043 because of step counter
# Final cost : 0.025862002218287043
# Compute control for a deterministic system
# Cost in iteration 0: 0.025862002218287043
# Converged in iteration 1 with cost 0.025862002218287043 because of step counter
# Final cost : 0.025862002218287043
# Compute control for a deterministic system
# Cost in iteration 0: 0.06888806760495952
# Cost in iteration 200: 0.027455701571961384
# Final cost : 0.027455701571961384
# Compute control for a deterministic system
# Cost in iteration 0: 0.027455701571961384
# Converged in iteration 40 with cost 0.02742072927481847 because of step counter
# Final cost : 0.02742072927481847
# Compute control for a deterministic system
# Cost in iteration 0: 0.02742072927481847
# Converged in iteration 1 with cost 0.02742072927481847 because of step counter
# Final cost : 0.02742072927481847
# Compute control for a deterministic system
# Cost in iteration 0: 0.02742072927481847
# Converged in iteration 1 with cost 0.02742072927481847 because of step counter
# Final cost : 0.02742072927481847
# Compute control for a deterministic system
# Cost in iteration 0: 0.02742072927481847
# Converged in iteration 1 with cost 0.02742072927481847 because of step counter
# Final cost : 0.02742072927481847
# Compute control for a deterministic system
# Cost in iteration 0: 0.06232852120397682
# Cost in iteration 200: 0.019758233617597484
# Final cost : 0.019758233617597484
# Compute control for a deterministic system
# Cost in iteration 0: 0.019758233617597484
# Converged in iteration 198 with cost 0.01745157807874492 because of step counter
# Final cost : 0.01745157807874492
# Compute control for a deterministic system
# Cost in iteration 0: 0.01745157807874492
# Converged in iteration 1 with cost 0.01745157807874492 because of step counter
# Final cost : 0.01745157807874492
# Compute control for a deterministic system
# Cost in iteration 0: 0.01745157807874492
# Converged in iteration 1 with cost 0.01745157807874492 because of step counter
# Final cost : 0.01745157807874492
# Compute control for a deterministic system
# Cost in iteration 0: 0.01745157807874492
# Converged in iteration 1 with cost 0.01745157807874492 because of step counter
# Final cost : 0.01745157807874492
# Compute control for a deterministic system
# Cost in iteration 0: 0.05521255012678164
# Cost in iteration 200: 0.012382106670862581
# Final cost : 0.012382106670862581
# Compute control for a deterministic system
# Cost in iteration 0: 0.012382106670862581
# Converged in iteration 39 with cost 0.010393923983726372 because of step counter
# Final cost : 0.010393923983726372
# Compute control for a deterministic system
# Cost in iteration 0: 0.010393923983726372
# Converged in iteration 1 with cost 0.010393923983726372 because of step counter
# Final cost : 0.010393923983726372
# Compute control for a deterministic system
# Cost in iteration 0: 0.010393923983726372
# Converged in iteration 1 with cost 0.010393923983726372 because of step counter
# Final cost : 0.010393923983726372
# Compute control for a deterministic system
# Cost in iteration 0: 0.010393923983726372
# Converged in iteration 1 with cost 0.010393923983726372 because of step counter
# Final cost : 0.010393923983726372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0340109197420883
# Cost in iteration 200: 0.005932079215087253
# Final cost : 0.005932079215087253
# Compute control for a deterministic system
# Cost in iteration 0: 0.005932079215087253
# Converged in iteration 16 with cost 0.0055892797031303594 because of step counter
# Final cost : 0.0055892797031303594
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055892797031303594
# Converged in iteration 1 with cost 0.0055892797031303594 because of step counter
# Final cost : 0.0055892797031303594
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055892797031303594
# Converged in iteration 1 with cost 0.0055892797031303594 because of step counter
# Final cost : 0.0055892797031303594
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055892797031303594
# Converged in iteration 1 with cost 0.0055892797031303594 because of step counter
# Final cost : 0.0055892797031303594
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.030631261586683216
# Converged in iteration 15 with cost 0.01886331109182382 because of step counter
# Final cost : 0.01886331109182382
# Compute control for a deterministic system
# Cost in iteration 0: 0.01886331109182382
# Converged in iteration 1 with cost 0.01886331109182382 because of step counter
# Final cost : 0.01886331109182382
# Compute control for a deterministic system
# Cost in iteration 0: 0.01886331109182382
# Converged in iteration 1 with cost 0.01886331109182382 because of step counter
# Final cost : 0.01886331109182382
# Compute control for a deterministic system
# Cost in iteration 0: 0.01886331109182382
# Converged in iteration 1 with cost 0.01886331109182382 because of step counter
# Final cost : 0.01886331109182382
# Compute control for a deterministic system
# Cost in iteration 0: 0.04537929973680707
# Converged in iteration 15 with cost 0.026481402381247382 because of step counter
# Final cost : 0.026481402381247382
# Compute control for a deterministic system
# Cost in iteration 0: 0.026481402381247382
# Converged in iteration 1 with cost 0.026481402381247382 because of step counter
# Final cost : 0.026481402381247382
# Compute control for a deterministic system
# Cost in iteration 0: 0.026481402381247382
# Converged in iteration 1 with cost 0.026481402381247382 because of step counter
# Final cost : 0.026481402381247382
# Compute control for a deterministic system
# Cost in iteration 0: 0.026481402381247382
# Converged in iteration 1 with cost 0.026481402381247382 because of step counter
# Final cost : 0.026481402381247382
# Compute control for a deterministic system
# Cost in iteration 0: 0.041827204825648896
# Converged in iteration 12 with cost 0.02796949382284028 because of step counter
# Final cost : 0.02796949382284028
# Compute control for a deterministic system
# Cost in iteration 0: 0.02796949382284028
# Converged in iteration 1 with cost 0.02796949382284028 because of step counter
# Final cost : 0.02796949382284028
# Compute control for a deterministic system
# Cost in iteration 0: 0.02796949382284028
# Converged in iteration 1 with cost 0.02796949382284028 because of step counter
# Final cost : 0.02796949382284028
# Compute control for a deterministic system
# Cost in iteration 0: 0.02796949382284028
# Converged in iteration 1 with cost 0.02796949382284028 because of step counter
# Final cost : 0.02796949382284028
# Compute control for a deterministic system
# Cost in iteration 0: 0.03919627227018693
# Converged in iteration 11 with cost 0.030579471958671264 because of step counter
# Final cost : 0.030579471958671264
# Compute control for a deterministic system
# Cost in iteration 0: 0.030579471958671264
# Converged in iteration 1 with cost 0.030579471958671264 because of step counter
# Final cost : 0.030579471958671264
# Compute control for a deterministic system
# Cost in iteration 0: 0.030579471958671264
# Converged in iteration 1 with cost 0.030579471958671264 because of step counter
# Final cost : 0.030579471958671264
# Compute control for a deterministic system
# Cost in iteration 0: 0.030579471958671264
# Converged in iteration 1 with cost 0.030579471958671264 because of step counter
# Final cost : 0.030579471958671264
# Compute control for a deterministic system
# Cost in iteration 0: 0.026296521643905273
# Converged in iteration 14 with cost 0.026254077386422794 because of step counter
# Final cost : 0.026254077386422794
# Compute control for a deterministic system
# Cost in iteration 0: 0.026254077386422794
# Converged in iteration 1 with cost 0.026254077386422794 because of step counter
# Final cost : 0.026254077386422794
# Compute control for a deterministic system
# Cost in iteration 0: 0.026254077386422794
# Converged in iteration 1 with cost 0.026254077386422794 because of step counter
# Final cost : 0.026254077386422794
# Compute control for a deterministic system
# Cost in iteration 0: 0.026254077386422794
# Converged in iteration 1 with cost 0.026254077386422794 because of step counter
# Final cost : 0.026254077386422794
# Compute control for a deterministic system
# Cost in iteration 0: 0.029332732284938767
# Converged in iteration 1 with cost 0.029332732284938767 because of step counter
# Final cost : 0.029332732284938767
# Compute control for a deterministic system
# Cost in iteration 0: 0.029332732284938767
# Converged in iteration 1 with cost 0.029332732284938767 because of step counter
# Final cost : 0.029332732284938767
# Compute control for a deterministic system
# Cost in iteration 0: 0.029332732284938767
# Converged in iteration 1 with cost 0.029332732284938767 because of step counter
# Final cost : 0.029332732284938767
# Compute control for a deterministic system
# Cost in iteration 0: 0.029332732284938767
# Converged in iteration 1 with cost 0.029332732284938767 because of step counter
# Final cost : 0.029332732284938767
# Compute control for a deterministic system
# Cost in iteration 0: 0.03165232360907273
# Converged in iteration 1 with cost 0.03165232360907273 because of step counter
# Final cost : 0.03165232360907273
# Compute control for a deterministic system
# Cost in iteration 0: 0.03165232360907273
# Converged in iteration 1 with cost 0.03165232360907273 because of step counter
# Final cost : 0.03165232360907273
# Compute control for a deterministic system
# Cost in iteration 0: 0.03165232360907273
# Converged in iteration 1 with cost 0.03165232360907273 because of step counter
# Final cost : 0.03165232360907273
# Compute control for a deterministic system
# Cost in iteration 0: 0.03165232360907273
# Converged in iteration 1 with cost 0.03165232360907273 because of step counter
# Final cost : 0.03165232360907273
# Compute control for a deterministic system
# Cost in iteration 0: 0.034979158676900116
# Converged in iteration 1 with cost 0.034979158676900116 because of step counter
# Final cost : 0.034979158676900116
# Compute control for a deterministic system
# Cost in iteration 0: 0.034979158676900116
# Converged in iteration 1 with cost 0.034979158676900116 because of step counter
# Final cost : 0.034979158676900116
# Compute control for a deterministic system
# Cost in iteration 0: 0.034979158676900116
# Converged in iteration 1 with cost 0.034979158676900116 because of step counter
# Final cost : 0.034979158676900116
# Compute control for a deterministic system
# Cost in iteration 0: 0.034979158676900116
# Converged in iteration 1 with cost 0.034979158676900116 because of step counter
# Final cost : 0.034979158676900116
# Compute control for a deterministic system
# Cost in iteration 0: 0.03826872770818009
# Converged in iteration 4 with cost 0.03805984103883613 because of step counter
# Final cost : 0.03805984103883613
# Compute control for a deterministic system
# Cost in iteration 0: 0.03805984103883613
# Converged in iteration 1 with cost 0.03805984103883613 because of step counter
# Final cost : 0.03805984103883613
# Compute control for a deterministic system
# Cost in iteration 0: 0.03805984103883613
# Converged in iteration 1 with cost 0.03805984103883613 because of step counter
# Final cost : 0.03805984103883613
# Compute control for a deterministic system
# Cost in iteration 0: 0.03805984103883613
# Converged in iteration 1 with cost 0.03805984103883613 because of step counter
# Final cost : 0.03805984103883613
# Compute control for a deterministic system
# Cost in iteration 0: 0.04485617140785789
# Converged in iteration 9 with cost 0.044296587274672304 because of step counter
# Final cost : 0.044296587274672304
# Compute control for a deterministic system
# Cost in iteration 0: 0.044296587274672304
# Converged in iteration 1 with cost 0.044296587274672304 because of step counter
# Final cost : 0.044296587274672304
# Compute control for a deterministic system
# Cost in iteration 0: 0.044296587274672304
# Converged in iteration 1 with cost 0.044296587274672304 because of step counter
# Final cost : 0.044296587274672304
# Compute control for a deterministic system
# Cost in iteration 0: 0.044296587274672304
# Converged in iteration 1 with cost 0.044296587274672304 because of step counter
# Final cost : 0.044296587274672304
# Compute control for a deterministic system
# Cost in iteration 0: 0.06527046056494087
# Converged in iteration 60 with cost 0.047395386303381505 because of step counter
# Final cost : 0.047395386303381505
# Compute control for a deterministic system
# Cost in iteration 0: 0.047395386303381505
# Converged in iteration 1 with cost 0.047395386303381505 because of step counter
# Final cost : 0.047395386303381505
# Compute control for a deterministic system
# Cost in iteration 0: 0.047395386303381505
# Converged in iteration 1 with cost 0.047395386303381505 because of step counter
# Final cost : 0.047395386303381505
# Compute control for a deterministic system
# Cost in iteration 0: 0.047395386303381505
# Converged in iteration 1 with cost 0.047395386303381505 because of step counter
# Final cost : 0.047395386303381505
# Compute control for a deterministic system
# Cost in iteration 0: 0.06765985914521297
# Converged in iteration 52 with cost 0.04944012505159634 because of step counter
# Final cost : 0.04944012505159634
# Compute control for a deterministic system
# Cost in iteration 0: 0.04944012505159634
# Converged in iteration 1 with cost 0.04944012505159634 because of step counter
# Final cost : 0.04944012505159634
# Compute control for a deterministic system
# Cost in iteration 0: 0.04944012505159634
# Converged in iteration 1 with cost 0.04944012505159634 because of step counter
# Final cost : 0.04944012505159634
# Compute control for a deterministic system
# Cost in iteration 0: 0.04944012505159634
# Converged in iteration 1 with cost 0.04944012505159634 because of step counter
# Final cost : 0.04944012505159634
# Compute control for a deterministic system
# Cost in iteration 0: 0.054365654386221804
# Converged in iteration 8 with cost 0.05160295056863156 because of step counter
# Final cost : 0.05160295056863156
# Compute control for a deterministic system
# Cost in iteration 0: 0.05160295056863156
# Converged in iteration 1 with cost 0.05160295056863156 because of step counter
# Final cost : 0.05160295056863156
# Compute control for a deterministic system
# Cost in iteration 0: 0.05160295056863156
# Converged in iteration 1 with cost 0.05160295056863156 because of step counter
# Final cost : 0.05160295056863156
# Compute control for a deterministic system
# Cost in iteration 0: 0.05160295056863156
# Converged in iteration 1 with cost 0.05160295056863156 because of step counter
# Final cost : 0.05160295056863156
# Compute control for a deterministic system
# Cost in iteration 0: 0.05637195718736279
# Converged in iteration 32 with cost 0.056065323304069485 because of step counter
# Final cost : 0.056065323304069485
# Compute control for a deterministic system
# Cost in iteration 0: 0.056065323304069485
# Converged in iteration 1 with cost 0.056065323304069485 because of step counter
# Final cost : 0.056065323304069485
# Compute control for a deterministic system
# Cost in iteration 0: 0.056065323304069485
# Converged in iteration 1 with cost 0.056065323304069485 because of step counter
# Final cost : 0.056065323304069485
# Compute control for a deterministic system
# Cost in iteration 0: 0.056065323304069485
# Converged in iteration 1 with cost 0.056065323304069485 because of step counter
# Final cost : 0.056065323304069485
# Compute control for a deterministic system
# Cost in iteration 0: 0.08253996922940113
# Converged in iteration 122 with cost 0.059825332123662645 because of step counter
# Final cost : 0.059825332123662645
# Compute control for a deterministic system
# Cost in iteration 0: 0.059825332123662645
# Converged in iteration 1 with cost 0.059825332123662645 because of step counter
# Final cost : 0.059825332123662645
# ...
# Converged in iteration 1 with cost 1.2751252379301867 because of step counter
# Final cost : 1.2751252379301867
# Compute control for a deterministic system
# Cost in iteration 0: 1.2751252379301867
# Converged in iteration 1 with cost 1.2751252379301867 because of step counter
# Final cost : 1.2751252379301867
# Compute control for a deterministic system
# Cost in iteration 0: 1.2751252379301867
# Converged in iteration 1 with cost 1.2751252379301867 because of step counter
# Final cost : 1.2751252379301867
# Compute control for a deterministic system
# Cost in iteration 0: 0.9104462910467314
# Converged in iteration 1 with cost 0.9104462910467314 because of step counter
# Final cost : 0.9104462910467314
# Compute control for a deterministic system
# Cost in iteration 0: 0.9104462910467314
# Converged in iteration 1 with cost 0.9104462910467314 because of step counter
# Final cost : 0.9104462910467314
# Compute control for a deterministic system
# Cost in iteration 0: 0.9104462910467314
# Converged in iteration 1 with cost 0.9104462910467314 because of step counter
# Final cost : 0.9104462910467314
# Compute control for a deterministic system
# Cost in iteration 0: 0.9104462910467314
# Converged in iteration 1 with cost 0.9104462910467314 because of step counter
# Final cost : 0.9104462910467314
# Compute control for a deterministic system
# Cost in iteration 0: 0.9104462910467314
# Converged in iteration 1 with cost 0.9104462910467314 because of step counter
# Final cost : 0.9104462910467314
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779436180167934
# Converged in iteration 1 with cost 0.8779436180167934 because of step counter
# Final cost : 0.8779436180167934
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779436180167934
# Converged in iteration 1 with cost 0.8779436180167934 because of step counter
# Final cost : 0.8779436180167934
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779436180167934
# Converged in iteration 1 with cost 0.8779436180167934 because of step counter
# Final cost : 0.8779436180167934
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779436180167934
# Converged in iteration 1 with cost 0.8779436180167934 because of step counter
# Final cost : 0.8779436180167934
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779436180167934
# Converged in iteration 1 with cost 0.8779436180167934 because of step counter
# Final cost : 0.8779436180167934
# Compute control for a deterministic system
# Cost in iteration 0: 0.804502941817596
# Converged in iteration 1 with cost 0.804502941817596 because of step counter
# Final cost : 0.804502941817596
# Compute control for a deterministic system
# Cost in iteration 0: 0.804502941817596
# Converged in iteration 1 with cost 0.804502941817596 because of step counter
# Final cost : 0.804502941817596
# Compute control for a deterministic system
# Cost in iteration 0: 0.804502941817596
# Converged in iteration 1 with cost 0.804502941817596 because of step counter
# Final cost : 0.804502941817596
# Compute control for a deterministic system
# Cost in iteration 0: 0.804502941817596
# Converged in iteration 1 with cost 0.804502941817596 because of step counter
# Final cost : 0.804502941817596
# Compute control for a deterministic system
# Cost in iteration 0: 0.804502941817596
# Converged in iteration 1 with cost 0.804502941817596 because of step counter
# Final cost : 0.804502941817596
# Compute control for a deterministic system
# Cost in iteration 0: 0.7566002915600027
# Converged in iteration 1 with cost 0.7566002915600027 because of step counter
# Final cost : 0.7566002915600027
# Compute control for a deterministic system
# Cost in iteration 0: 0.7566002915600027
# Converged in iteration 1 with cost 0.7566002915600027 because of step counter
# Final cost : 0.7566002915600027
# Compute control for a deterministic system
# Cost in iteration 0: 0.7566002915600027
# Converged in iteration 1 with cost 0.7566002915600027 because of step counter
# Final cost : 0.7566002915600027
# Compute control for a deterministic system
# Cost in iteration 0: 0.7566002915600027
# Converged in iteration 1 with cost 0.7566002915600027 because of step counter
# Final cost : 0.7566002915600027
# Compute control for a deterministic system
# Cost in iteration 0: 0.7566002915600027
# Converged in iteration 1 with cost 0.7566002915600027 because of step counter
# Final cost : 0.7566002915600027
# Compute control for a deterministic system
# Cost in iteration 0: 0.7251386163672741
# Converged in iteration 1 with cost 0.7251386163672741 because of step counter
# Final cost : 0.7251386163672741
# Compute control for a deterministic system
# Cost in iteration 0: 0.7251386163672741
# Converged in iteration 1 with cost 0.7251386163672741 because of step counter
# Final cost : 0.7251386163672741
# Compute control for a deterministic system
# Cost in iteration 0: 0.7251386163672741
# Converged in iteration 1 with cost 0.7251386163672741 because of step counter
# Final cost : 0.7251386163672741
# Compute control for a deterministic system
# Cost in iteration 0: 0.7251386163672741
# Converged in iteration 1 with cost 0.7251386163672741 because of step counter
# Final cost : 0.7251386163672741
# Compute control for a deterministic system
# Cost in iteration 0: 0.7251386163672741
# Converged in iteration 1 with cost 0.7251386163672741 because of step counter
# Final cost : 0.7251386163672741
# Compute control for a deterministic system
# Cost in iteration 0: 0.6962885287647647
# Converged in iteration 1 with cost 0.6962885287647647 because of step counter
# Final cost : 0.6962885287647647
# Compute control for a deterministic system
# Cost in iteration 0: 0.6962885287647647
# Converged in iteration 1 with cost 0.6962885287647647 because of step counter
# Final cost : 0.6962885287647647
# Compute control for a deterministic system
# Cost in iteration 0: 0.6962885287647647
# Converged in iteration 1 with cost 0.6962885287647647 because of step counter
# Final cost : 0.6962885287647647
# Compute control for a deterministic system
# Cost in iteration 0: 0.6962885287647647
# Converged in iteration 1 with cost 0.6962885287647647 because of step counter
# Final cost : 0.6962885287647647
# Compute control for a deterministic system
# Cost in iteration 0: 0.6962885287647647
# Converged in iteration 1 with cost 0.6962885287647647 because of step counter
# Final cost : 0.6962885287647647
# Compute control for a deterministic system
# Cost in iteration 0: 0.5910107792189773
# Converged in iteration 1 with cost 0.5910107792189773 because of step counter
# Final cost : 0.5910107792189773
# Compute control for a deterministic system
# Cost in iteration 0: 0.5910107792189773
# Converged in iteration 1 with cost 0.5910107792189773 because of step counter
# Final cost : 0.5910107792189773
# Compute control for a deterministic system
# Cost in iteration 0: 0.5910107792189773
# Converged in iteration 1 with cost 0.5910107792189773 because of step counter
# Final cost : 0.5910107792189773
# Compute control for a deterministic system
# Cost in iteration 0: 0.5910107792189773
# Converged in iteration 1 with cost 0.5910107792189773 because of step counter
# Final cost : 0.5910107792189773
# Compute control for a deterministic system
# Cost in iteration 0: 0.5910107792189773
# Converged in iteration 1 with cost 0.5910107792189773 because of step counter
# Final cost : 0.5910107792189773
# Compute control for a deterministic system
# Cost in iteration 0: 0.548081951039125
# Converged in iteration 1 with cost 0.548081951039125 because of step counter
# Final cost : 0.548081951039125
# Compute control for a deterministic system
# Cost in iteration 0: 0.548081951039125
# Converged in iteration 1 with cost 0.548081951039125 because of step counter
# Final cost : 0.548081951039125
# Compute control for a deterministic system
# Cost in iteration 0: 0.548081951039125
# Converged in iteration 1 with cost 0.548081951039125 because of step counter
# Final cost : 0.548081951039125
# Compute control for a deterministic system
# Cost in iteration 0: 0.548081951039125
# Converged in iteration 1 with cost 0.548081951039125 because of step counter
# Final cost : 0.548081951039125
# Compute control for a deterministic system
# Cost in iteration 0: 0.548081951039125
# Converged in iteration 1 with cost 0.548081951039125 because of step counter
# Final cost : 0.548081951039125
# Compute control for a deterministic system
# Cost in iteration 0: 0.49877480845588706
# Converged in iteration 1 with cost 0.49877480845588706 because of step counter
# Final cost : 0.49877480845588706
# Compute control for a deterministic system
# Cost in iteration 0: 0.49877480845588706
# Converged in iteration 1 with cost 0.49877480845588706 because of step counter
# Final cost : 0.49877480845588706
# Compute control for a deterministic system
# Cost in iteration 0: 0.49877480845588706
# Converged in iteration 1 with cost 0.49877480845588706 because of step counter
# Final cost : 0.49877480845588706
# Compute control for a deterministic system
# Cost in iteration 0: 0.49877480845588706
# Converged in iteration 1 with cost 0.49877480845588706 because of step counter
# Final cost : 0.49877480845588706
# Compute control for a deterministic system
# Cost in iteration 0: 0.49877480845588706
# Converged in iteration 1 with cost 0.49877480845588706 because of step counter
# Final cost : 0.49877480845588706
# Compute control for a deterministic system
# Cost in iteration 0: 0.4548803364663131
# Converged in iteration 1 with cost 0.4548803364663131 because of step counter
# Final cost : 0.4548803364663131
# Compute control for a deterministic system
# Cost in iteration 0: 0.4548803364663131
# Converged in iteration 1 with cost 0.4548803364663131 because of step counter
# Final cost : 0.4548803364663131
# Compute control for a deterministic system
# Cost in iteration 0: 0.4548803364663131
# Converged in iteration 1 with cost 0.4548803364663131 because of step counter
# Final cost : 0.4548803364663131
# Compute control for a deterministic system
# Cost in iteration 0: 0.4548803364663131
# Converged in iteration 1 with cost 0.4548803364663131 because of step counter
# Final cost : 0.4548803364663131
# Compute control for a deterministic system
# Cost in iteration 0: 0.4548803364663131
# Converged in iteration 1 with cost 0.4548803364663131 because of step counter
# Final cost : 0.4548803364663131
# Compute control for a deterministic system
# Cost in iteration 0: 0.4118465616278751
# Converged in iteration 1 with cost 0.4118465616278751 because of step counter
# Final cost : 0.4118465616278751
# Compute control for a deterministic system
# Cost in iteration 0: 0.4118465616278751
# Converged in iteration 1 with cost 0.4118465616278751 because of step counter
# Final cost : 0.4118465616278751
# Compute control for a deterministic system
# Cost in iteration 0: 0.4118465616278751
# Converged in iteration 1 with cost 0.4118465616278751 because of step counter
# Final cost : 0.4118465616278751
# Compute control for a deterministic system
# Cost in iteration 0: 0.4118465616278751
# Converged in iteration 1 with cost 0.4118465616278751 because of step counter
# Final cost : 0.4118465616278751
# Compute control for a deterministic system
# Cost in iteration 0: 0.4118465616278751
# Converged in iteration 1 with cost 0.4118465616278751 because of step counter
# Final cost : 0.4118465616278751
# Compute control for a deterministic system
# Cost in iteration 0: 0.36615406590909516
# Converged in iteration 1 with cost 0.36615406590909516 because of step counter
# Final cost : 0.36615406590909516
# Compute control for a deterministic system
# Cost in iteration 0: 0.36615406590909516
# Converged in iteration 1 with cost 0.36615406590909516 because of step counter
# Final cost : 0.36615406590909516
# Compute control for a deterministic system
# Cost in iteration 0: 0.36615406590909516
# Converged in iteration 1 with cost 0.36615406590909516 because of step counter
# Final cost : 0.36615406590909516
# Compute control for a deterministic system
# Cost in iteration 0: 0.36615406590909516
# Converged in iteration 1 with cost 0.36615406590909516 because of step counter
# Final cost : 0.36615406590909516
# Compute control for a deterministic system
# Cost in iteration 0: 0.36615406590909516
# Converged in iteration 1 with cost 0.36615406590909516 because of step counter
# Final cost : 0.36615406590909516
# Compute control for a deterministic system
# Cost in iteration 0: 0.27344440868105785
# Converged in iteration 1 with cost 0.27344440868105785 because of step counter
# Final cost : 0.27344440868105785
# Compute control for a deterministic system
# Cost in iteration 0: 0.27344440868105785
# Converged in iteration 1 with cost 0.27344440868105785 because of step counter
# Final cost : 0.27344440868105785
# Compute control for a deterministic system
# Cost in iteration 0: 0.27344440868105785
# Converged in iteration 1 with cost 0.27344440868105785 because of step counter
# Final cost : 0.27344440868105785
# Compute control for a deterministic system
# Cost in iteration 0: 0.27344440868105785
# Converged in iteration 1 with cost 0.27344440868105785 because of step counter
# Final cost : 0.27344440868105785
# Compute control for a deterministic system
# Cost in iteration 0: 0.27344440868105785
# Converged in iteration 1 with cost 0.27344440868105785 because of step counter
# Final cost : 0.27344440868105785
# Compute control for a deterministic system
# Cost in iteration 0: 0.1895156185217097
# Converged in iteration 1 with cost 0.1895156185217097 because of step counter
# Final cost : 0.1895156185217097
# Compute control for a deterministic system
# Cost in iteration 0: 0.1895156185217097
# Converged in iteration 1 with cost 0.1895156185217097 because of step counter
# Final cost : 0.1895156185217097
# Compute control for a deterministic system
# Cost in iteration 0: 0.1895156185217097
# Converged in iteration 1 with cost 0.1895156185217097 because of step counter
# Final cost : 0.1895156185217097
# Compute control for a deterministic system
# Cost in iteration 0: 0.1895156185217097
# Converged in iteration 1 with cost 0.1895156185217097 because of step counter
# Final cost : 0.1895156185217097
# Compute control for a deterministic system
# Cost in iteration 0: 0.1895156185217097
# Converged in iteration 1 with cost 0.1895156185217097 because of step counter
# Final cost : 0.1895156185217097
# Compute control for a deterministic system
# Cost in iteration 0: 0.10409241790339895
# Converged in iteration 1 with cost 0.10409241790339895 because of step counter
# Final cost : 0.10409241790339895
# Compute control for a deterministic system
# Cost in iteration 0: 0.10409241790339895
# Converged in iteration 1 with cost 0.10409241790339895 because of step counter
# Final cost : 0.10409241790339895
# Compute control for a deterministic system
# Cost in iteration 0: 0.10409241790339895
# Converged in iteration 1 with cost 0.10409241790339895 because of step counter
# Final cost : 0.10409241790339895
# Compute control for a deterministic system
# Cost in iteration 0: 0.10409241790339895
# Converged in iteration 1 with cost 0.10409241790339895 because of step counter
# Final cost : 0.10409241790339895
# Compute control for a deterministic system
# Cost in iteration 0: 0.10409241790339895
# Converged in iteration 1 with cost 0.10409241790339895 because of step counter
# Final cost : 0.10409241790339895
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056274072316423
# Converged in iteration 1 with cost 0.04056274072316423 because of step counter
# Final cost : 0.04056274072316423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056274072316423
# Converged in iteration 1 with cost 0.04056274072316423 because of step counter
# Final cost : 0.04056274072316423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056274072316423
# Converged in iteration 1 with cost 0.04056274072316423 because of step counter
# Final cost : 0.04056274072316423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056274072316423
# Converged in iteration 1 with cost 0.04056274072316423 because of step counter
# Final cost : 0.04056274072316423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056274072316423
# Converged in iteration 1 with cost 0.04056274072316423 because of step counter
# Final cost : 0.04056274072316423

# %%
save(results_peak)
