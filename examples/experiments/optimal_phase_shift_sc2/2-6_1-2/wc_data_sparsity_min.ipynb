# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.25426803074613735
y_init = 0.2588983729056897
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,123], wc.inh[0,123]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.05481462579209116 0.18840746023632948
# minima =  [  44  252  460  669  877 1085 1293 1501 1710 1918 2126 2334 2542 2751
#  2959 3167 3375 3583 3792 4000 4208 4416 4624 4833 5041 5249 5457 5665
#  5874]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.1
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05531027690293814
# Final cost : 0.005885144404842307
# Compute control for a deterministic system
# Cost in iteration 0: 0.005885144404842307
# Converged in iteration 100 with cost 0.0033425557479294086 because of vanishing difference
# Final cost : 0.0033425557479294086
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033425557479294086
# Converged in iteration 99 with cost 0.0033425553649701445 because of step counter
# Final cost : 0.0033425553649701445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033425553649701445
# Converged in iteration 3 with cost 0.003342555364969301 because of step counter
# Final cost : 0.003342555364969301
# Compute control for a deterministic system
# Cost in iteration 0: 0.003342555364969301
# Converged in iteration 1 with cost 0.003342555364969301 because of step counter
# Final cost : 0.003342555364969301
# Compute control for a deterministic system
# Cost in iteration 0: 0.003342555364969301
# Converged in iteration 1 with cost 0.003342555364969301 because of step counter
# Final cost : 0.003342555364969301
# Compute control for a deterministic system
# Cost in iteration 0: 0.2186316720661571
# Final cost : 0.07109552453830893
# Compute control for a deterministic system
# Cost in iteration 0: 0.07109552453830893
# Cost in iteration 200: 0.0067383438288768785
# Converged in iteration 254 with cost 0.00673829620029399 because of vanishing difference
# Final cost : 0.00673829620029399
# Compute control for a deterministic system
# Cost in iteration 0: 0.00673829620029399
# Cost in iteration 200: 0.006738293113452306
# Final cost : 0.006738293113452306
# Compute control for a deterministic system
# Cost in iteration 0: 0.006738293113452306
# Converged in iteration 38 with cost 0.00673829311332369 because of step counter
# Final cost : 0.00673829311332369
# Compute control for a deterministic system
# Cost in iteration 0: 0.00673829311332369
# Converged in iteration 1 with cost 0.00673829311332369 because of step counter
# Final cost : 0.00673829311332369
# Compute control for a deterministic system
# Cost in iteration 0: 0.00673829311332369
# Converged in iteration 2 with cost 0.00673829311332324 because of step counter
# Final cost : 0.00673829311332324
# Compute control for a deterministic system
# Cost in iteration 0: 0.5451708787346649
# Final cost : 0.2592984451491106
# Compute control for a deterministic system
# Cost in iteration 0: 0.2592984451491106
# Cost in iteration 200: 0.010783098250006139
# Converged in iteration 378 with cost 0.010781026927718497 because of vanishing difference
# Final cost : 0.010781026927718497
# Compute control for a deterministic system
# Cost in iteration 0: 0.010781026927718497
# Cost in iteration 200: 0.010781010208749399
# Final cost : 0.010781010208749399
# Compute control for a deterministic system
# Cost in iteration 0: 0.010781010208749399
# Converged in iteration 105 with cost 0.010781010103352216 because of step counter
# Final cost : 0.010781010103352216
# Compute control for a deterministic system
# Cost in iteration 0: 0.010781010103352216
# Converged in iteration 1 with cost 0.010781010103352216 because of step counter
# Final cost : 0.010781010103352216
# Compute control for a deterministic system
# Cost in iteration 0: 0.010781010103352216
# Converged in iteration 1 with cost 0.010781010103352216 because of step counter
# Final cost : 0.010781010103352216
# Compute control for a deterministic system
# Cost in iteration 0: 0.9112334009472284
# Final cost : 0.20859737927066374
# Compute control for a deterministic system
# Cost in iteration 0: 0.20859737927066374
# Cost in iteration 200: 0.016897407076967758
# Cost in iteration 400: 0.015258372782016078
# Final cost : 0.015258372782016078
# Compute control for a deterministic system
# Cost in iteration 0: 0.015258372782016078
# Cost in iteration 200: 0.014115282925988263
# Final cost : 0.014115282925988263
# Compute control for a deterministic system
# Cost in iteration 0: 0.014115282925988263
# Cost in iteration 200: 0.014114806331420465
# Final cost : 0.014114806331420465
# Compute control for a deterministic system
# Cost in iteration 0: 0.014114806331420465
# Cost in iteration 200: 0.014114806295565375
# Converged in iteration 321 with cost 0.014114806294445626 because of vanishing difference
# Final cost : 0.014114806294445626
# Compute control for a deterministic system
# Cost in iteration 0: 0.014114806294445626
# Converged in iteration 67 with cost 0.014114806294332632 because of step counter
# Final cost : 0.014114806294332632
# Compute control for a deterministic system
# Cost in iteration 0: 1.3471589634795826
# Final cost : 0.12411571155188614
# Compute control for a deterministic system
# Cost in iteration 0: 0.12411571155188614
# Cost in iteration 200: 0.021344573767087722
# Cost in iteration 400: 0.019594483493986407
# Final cost : 0.019594483493986407
# Compute control for a deterministic system
# Cost in iteration 0: 0.019594483493986407
# Cost in iteration 200: 0.0185173201003397
# Final cost : 0.0185173201003397
# Compute control for a deterministic system
# Cost in iteration 0: 0.0185173201003397
# Cost in iteration 200: 0.01769585438193239
# Final cost : 0.01769585438193239
# Compute control for a deterministic system
# Cost in iteration 0: 0.01769585438193239
# Converged in iteration 54 with cost 0.017415009573058804 because of vanishing difference
# Final cost : 0.017415009573058804
# Compute control for a deterministic system
# Cost in iteration 0: 0.017415009573058804
# Cost in iteration 200: 0.017412277435495397
# Cost in iteration 400: 0.017412220660056342
# Cost in iteration 600: 0.01741221480794762
# Cost in iteration 800: 0.017412214180664347
# Cost in iteration 1000: 0.017412214112300622
# Final cost : 0.017412214112300622
# Compute control for a deterministic system
# Cost in iteration 0: 1.8377905361703997
# Final cost : 0.12748273438991403
# Compute control for a deterministic system
# Cost in iteration 0: 0.12748273438991403
# Cost in iteration 200: 0.025793776721962546
# Cost in iteration 400: 0.0237982433256423
# Final cost : 0.0237982433256423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0237982433256423
# Cost in iteration 200: 0.022609771823755197
# Final cost : 0.022609771823755197
# Compute control for a deterministic system
# Cost in iteration 0: 0.022609771823755197
# Cost in iteration 200: 0.021766805742433084
# Final cost : 0.021766805742433084
# Compute control for a deterministic system
# Cost in iteration 0: 0.021766805742433084
# Converged in iteration 182 with cost 0.020668216847018778 because of vanishing difference
# Final cost : 0.020668216847018778
# Compute control for a deterministic system
# Cost in iteration 0: 0.020668216847018778
# Cost in iteration 200: 0.02066658454000141
# Cost in iteration 400: 0.020666549789504343
# Cost in iteration 600: 0.020666543393036425
# Cost in iteration 800: 0.020666542091745534
# Cost in iteration 1000: 0.020666541826785446
# Final cost : 0.020666541826785446
# Compute control for a deterministic system
# Cost in iteration 0: 2.367733479782278
# Final cost : 0.22988533456633137
# Compute control for a deterministic system
# Cost in iteration 0: 0.22988533456633137
# Cost in iteration 200: 0.030129639320643407
# Cost in iteration 400: 0.02787539759040795
# Final cost : 0.02787539759040795
# Compute control for a deterministic system
# Cost in iteration 0: 0.02787539759040795
# Cost in iteration 200: 0.02697486979046996
# Final cost : 0.02697486979046996
# Compute control for a deterministic system
# Cost in iteration 0: 0.02697486979046996
# Cost in iteration 200: 0.026146513342653766
# Final cost : 0.026146513342653766
# Compute control for a deterministic system
# Cost in iteration 0: 0.026146513342653766
# Cost in iteration 200: 0.024991297056776142
# Cost in iteration 400: 0.02386813003790864
# Final cost : 0.02386813003790864
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386813003790864
# Cost in iteration 200: 0.02386564193200552
# Cost in iteration 400: 0.023865562388634427
# Cost in iteration 600: 0.02386553996182797
# Cost in iteration 800: 0.023865533139619293
# Cost in iteration 1000: 0.023865531043272954
# Final cost : 0.023865531043272954
# Compute control for a deterministic system
# Cost in iteration 0: 3.03372931011425
# Final cost : 0.40362873407166555
# Compute control for a deterministic system
# Cost in iteration 0: 0.40362873407166555
# Cost in iteration 200: 0.0552880979246857
# Cost in iteration 400: 0.028288657704583612
# Final cost : 0.028288657704583612
# Compute control for a deterministic system
# Cost in iteration 0: 0.028288657704583612
# Cost in iteration 200: 0.027665770885810768
# Final cost : 0.027665770885810768
# Compute control for a deterministic system
# Cost in iteration 0: 0.027665770885810768
# Cost in iteration 200: 0.02761673543273693
# Final cost : 0.02761673543273693
# Compute control for a deterministic system
# Cost in iteration 0: 0.02761673543273693
# Cost in iteration 200: 0.027615624908163508
# Cost in iteration 400: 0.02761524357626301
# Final cost : 0.02761524357626301
# Compute control for a deterministic system
# Cost in iteration 0: 0.02761524357626301
# Cost in iteration 200: 0.027615105626236612
# Cost in iteration 400: 0.027615047917418926
# Cost in iteration 600: 0.02761502354777345
# Cost in iteration 800: 0.027615013117515734
# Cost in iteration 1000: 0.02761500870326911
# Final cost : 0.02761500870326911
# Compute control for a deterministic system
# Cost in iteration 0: 3.596907185706732
# Final cost : 0.2479740621401227
# Compute control for a deterministic system
# Cost in iteration 0: 0.2479740621401227
# Cost in iteration 200: 0.09559629274916624
# Cost in iteration 400: 0.04221137085159382
# Final cost : 0.04221137085159382
# Compute control for a deterministic system
# Cost in iteration 0: 0.04221137085159382
# Cost in iteration 200: 0.030772042581125387
# Final cost : 0.030772042581125387
# Compute control for a deterministic system
# Cost in iteration 0: 0.030772042581125387
# Cost in iteration 200: 0.03067430554877538
# Final cost : 0.03067430554877538
# Compute control for a deterministic system
# Cost in iteration 0: 0.03067430554877538
# Cost in iteration 200: 0.0306700018039507
# Cost in iteration 400: 0.030668917904985687
# Final cost : 0.030668917904985687
# Compute control for a deterministic system
# Cost in iteration 0: 0.030668917904985687
# Cost in iteration 200: 0.03066856000588745
# Cost in iteration 400: 0.030668384940254118
# Cost in iteration 600: 0.030668296458532803
# Cost in iteration 800: 0.030668251346883266
# Cost in iteration 1000: 0.030668228237220777
# Final cost : 0.030668228237220777
# Compute control for a deterministic system
# Cost in iteration 0: 4.154511467476518
# Final cost : 0.17011557971125177
# Compute control for a deterministic system
# Cost in iteration 0: 0.17011557971125177
# Cost in iteration 200: 0.09974875603909661
# Cost in iteration 400: 0.04830512016921448
# Final cost : 0.04830512016921448
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830512016921448
# Cost in iteration 200: 0.0340828586745934
# Final cost : 0.0340828586745934
# Compute control for a deterministic system
# Cost in iteration 0: 0.0340828586745934
# Cost in iteration 200: 0.033720814023227255
# Final cost : 0.033720814023227255
# Compute control for a deterministic system
# Cost in iteration 0: 0.033720814023227255
# Cost in iteration 200: 0.033687396011136746
# Cost in iteration 400: 0.033677665006946564
# Final cost : 0.033677665006946564
# Compute control for a deterministic system
# Cost in iteration 0: 0.033677665006946564
# Cost in iteration 200: 0.03367338264011823
# Cost in iteration 400: 0.033670918059461416
# Cost in iteration 600: 0.03366944282623058
# Cost in iteration 800: 0.03366855116970511
# Cost in iteration 1000: 0.03366801561829522
# Final cost : 0.03366801561829522
# Compute control for a deterministic system
# Cost in iteration 0: 4.696182345847609
# Final cost : 0.21674494381755008
# Compute control for a deterministic system
# Cost in iteration 0: 0.21674494381755008
# Cost in iteration 200: 0.10593671914468253
# Cost in iteration 400: 0.05802950578176463
# Final cost : 0.05802950578176463
# Compute control for a deterministic system
# Cost in iteration 0: 0.05802950578176463
# Cost in iteration 200: 0.04078627044501461
# Final cost : 0.04078627044501461
# Compute control for a deterministic system
# Cost in iteration 0: 0.04078627044501461
# Cost in iteration 200: 0.03724602894843231
# Final cost : 0.03724602894843231
# Compute control for a deterministic system
# Cost in iteration 0: 0.03724602894843231
# Cost in iteration 200: 0.03678643417161566
# Converged in iteration 239 with cost 0.03675483753201524 because of vanishing difference
# Final cost : 0.03675483753201524
# Compute control for a deterministic system
# Cost in iteration 0: 0.03675483753201524
# Cost in iteration 200: 0.03668422223333175
# Cost in iteration 400: 0.036658297876410284
# Cost in iteration 600: 0.0366463385223242
# Cost in iteration 800: 0.03663899988136014
# Cost in iteration 1000: 0.036634121698015894
# Final cost : 0.036634121698015894
# Compute control for a deterministic system
# Cost in iteration 0: 5.212478261979664
# Final cost : 0.4279229149678043
# Compute control for a deterministic system
# Cost in iteration 0: 0.4279229149678043
# Cost in iteration 200: 0.06947863258777465
# Cost in iteration 400: 0.04392219228311153
# Final cost : 0.04392219228311153
# Compute control for a deterministic system
# Cost in iteration 0: 0.04392219228311153
# Cost in iteration 200: 0.04052023116637254
# Final cost : 0.04052023116637254
# Compute control for a deterministic system
# Cost in iteration 0: 0.04052023116637254
# Cost in iteration 200: 0.039701967387714435
# Final cost : 0.039701967387714435
# Compute control for a deterministic system
# Cost in iteration 0: 0.039701967387714435
# Converged in iteration 22 with cost 0.03968353524755364 because of vanishing difference
# Final cost : 0.03968353524755364
# Compute control for a deterministic system
# Cost in iteration 0: 0.03968353524755364
# Cost in iteration 200: 0.03960456518189162
# Cost in iteration 400: 0.03958030420738115
# Cost in iteration 600: 0.03956979291877523
# Cost in iteration 800: 0.03956361101754218
# Cost in iteration 1000: 0.03955937036653273
# Final cost : 0.03955937036653273
# Compute control for a deterministic system
# Cost in iteration 0: 5.785579693740778
# Final cost : 0.9271994271289684
# Compute control for a deterministic system
# Cost in iteration 0: 0.9271994271289684
# Cost in iteration 200: 0.07169482987962296
# Cost in iteration 400: 0.04734062803493677
# Final cost : 0.04734062803493677
# Compute control for a deterministic system
# Cost in iteration 0: 0.04734062803493677
# Cost in iteration 200: 0.043727965798471574
# Final cost : 0.043727965798471574
# Compute control for a deterministic system
# Cost in iteration 0: 0.043727965798471574
# Cost in iteration 200: 0.043154508145274294
# Final cost : 0.043154508145274294
# Compute control for a deterministic system
# Cost in iteration 0: 0.043154508145274294
# Cost in iteration 200: 0.04307362519013616
# Cost in iteration 400: 0.04305125956072169
# Final cost : 0.04305125956072169
# Compute control for a deterministic system
# Cost in iteration 0: 0.04305125956072169
# Cost in iteration 200: 0.043037895068174715
# Cost in iteration 400: 0.04303461135827192
# Cost in iteration 600: 0.04303210331609779
# Cost in iteration 800: 0.04303035013294537
# Cost in iteration 1000: 0.04302896571984076
# Final cost : 0.04302896571984076
# Compute control for a deterministic system
# Cost in iteration 0: 6.213532329233548
# Final cost : 1.541124280853751
# Compute control for a deterministic system
# Cost in iteration 0: 1.541124280853751
# Cost in iteration 200: 0.07943149019815991
# Cost in iteration 400: 0.05794863965262116
# Final cost : 0.05794863965262116
# Compute control for a deterministic system
# Cost in iteration 0: 0.05794863965262116
# Cost in iteration 200: 0.050159559500345036
# Final cost : 0.050159559500345036
# Compute control for a deterministic system
# Cost in iteration 0: 0.050159559500345036
# Cost in iteration 200: 0.04611288287008822
# Final cost : 0.04611288287008822
# Compute control for a deterministic system
# Cost in iteration 0: 0.04611288287008822
# Converged in iteration 80 with cost 0.04602499653631194 because of vanishing difference
# Final cost : 0.04602499653631194
# Compute control for a deterministic system
# Cost in iteration 0: 0.04602499653631194
# Cost in iteration 200: 0.04591661151307967
# Cost in iteration 400: 0.04589892470849736
# Cost in iteration 600: 0.04589711435354835
# Cost in iteration 800: 0.045896989709212584
# Cost in iteration 1000: 0.04589692207386371
# Final cost : 0.04589692207386371
# Compute control for a deterministic system
# Cost in iteration 0: 6.587057304974298
# Final cost : 2.3022141453846965
# Compute control for a deterministic system
# Cost in iteration 0: 2.3022141453846965
# Cost in iteration 200: 0.061894589712597356
# Cost in iteration 400: 0.05035583981057586
# Final cost : 0.05035583981057586
# Compute control for a deterministic system
# Cost in iteration 0: 0.05035583981057586
# Cost in iteration 200: 0.04911449407341624
# Final cost : 0.04911449407341624
# Compute control for a deterministic system
# Cost in iteration 0: 0.04911449407341624
# Cost in iteration 200: 0.048817237429708615
# Final cost : 0.048817237429708615
# Compute control for a deterministic system
# Cost in iteration 0: 0.048817237429708615
# Cost in iteration 200: 0.04877661508784582
# Cost in iteration 400: 0.048764949698043986
# Final cost : 0.048764949698043986
# Compute control for a deterministic system
# Cost in iteration 0: 0.048764949698043986
# Cost in iteration 200: 0.04876081278188728
# Cost in iteration 400: 0.04875850667146866
# Cost in iteration 600: 0.048756911237663444
# Cost in iteration 800: 0.04875338137836581
# Cost in iteration 1000: 0.04874991814713322
# Final cost : 0.04874991814713322
# Compute control for a deterministic system
# Cost in iteration 0: 6.899823089250228
# Final cost : 3.162438079916423
# Compute control for a deterministic system
# Cost in iteration 0: 3.162438079916423
# Cost in iteration 200: 0.0726585728892219
# Cost in iteration 400: 0.056409115680212285
# Final cost : 0.056409115680212285
# Compute control for a deterministic system
# Cost in iteration 0: 0.056409115680212285
# Cost in iteration 200: 0.05185906107057869
# Final cost : 0.05185906107057869
# Compute control for a deterministic system
# Cost in iteration 0: 0.05185906107057869
# Cost in iteration 200: 0.051671239027529
# Final cost : 0.051671239027529
# Compute control for a deterministic system
# Cost in iteration 0: 0.051671239027529
# Converged in iteration 144 with cost 0.05162726843534334 because of vanishing difference
# Final cost : 0.05162726843534334
# Compute control for a deterministic system
# Cost in iteration 0: 0.05162726843534334
# Cost in iteration 200: 0.05158932025387132
# Cost in iteration 400: 0.05158429125561494
# Cost in iteration 600: 0.05158191306096171
# Cost in iteration 800: 0.05158050436687701
# Cost in iteration 1000: 0.051579576476075105
# Final cost : 0.051579576476075105
# Compute control for a deterministic system
# Cost in iteration 0: 7.148019377974156
# Final cost : 4.0062095219278895
# Compute control for a deterministic system
# Cost in iteration 0: 4.0062095219278895
# Cost in iteration 200: 0.06786317935340429
# Cost in iteration 400: 0.0565667130049134
# Final cost : 0.0565667130049134
# Compute control for a deterministic system
# Cost in iteration 0: 0.0565667130049134
# Cost in iteration 200: 0.05497873424939133
# Final cost : 0.05497873424939133
# Compute control for a deterministic system
# Cost in iteration 0: 0.05497873424939133
# Cost in iteration 200: 0.05462355087769463
# Final cost : 0.05462355087769463
# Compute control for a deterministic system
# Cost in iteration 0: 0.05462355087769463
# Cost in iteration 200: 0.05457519704860091
# Cost in iteration 400: 0.05454677094017551
# Final cost : 0.05454677094017551
# Compute control for a deterministic system
# Cost in iteration 0: 0.05454677094017551
# Cost in iteration 200: 0.05452709775832708
# Cost in iteration 400: 0.05451086358570235
# Cost in iteration 600: 0.054496840734626184
# Cost in iteration 800: 0.05448470952267137
# Cost in iteration 1000: 0.05447417292520937
# Final cost : 0.05447417292520937
# Compute control for a deterministic system
# Cost in iteration 0: 7.357150733468356
# Final cost : 4.963534047853379
# Compute control for a deterministic system
# Cost in iteration 0: 4.963534047853379
# Cost in iteration 200: 0.07111980645724242
# Cost in iteration 400: 0.0617115543340683
# Final cost : 0.0617115543340683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0617115543340683
# Cost in iteration 200: 0.059218960751482794
# Final cost : 0.059218960751482794
# Compute control for a deterministic system
# Cost in iteration 0: 0.059218960751482794
# Cost in iteration 200: 0.058720174495423494
# Final cost : 0.058720174495423494
# Compute control for a deterministic system
# Cost in iteration 0: 0.058720174495423494
# Converged in iteration 10 with cost 0.05870291226509031 because of vanishing difference
# Final cost : 0.05870291226509031
# Compute control for a deterministic system
# Cost in iteration 0: 0.05870291226509031
# Cost in iteration 200: 0.058504799791613264
# Cost in iteration 400: 0.05839517663755424
# Cost in iteration 600: 0.05831534407509985
# Cost in iteration 800: 0.0582499168052317
# Cost in iteration 1000: 0.058193964344892685
# Final cost : 0.058193964344892685
# Compute control for a deterministic system
# Cost in iteration 0: 7.455508296460477
# Final cost : 5.8248875419365165
# Compute control for a deterministic system
# Cost in iteration 0: 5.8248875419365165
# Cost in iteration 200: 0.07402527503353776
# Cost in iteration 400: 0.06648685502052772
# Final cost : 0.06648685502052772
# Compute control for a deterministic system
# Cost in iteration 0: 0.06648685502052772
# Cost in iteration 200: 0.06388550835368131
# Final cost : 0.06388550835368131
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388550835368131
# Cost in iteration 200: 0.06266057528243792
# Final cost : 0.06266057528243792
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266057528243792
# Cost in iteration 200: 0.06219553237788723
# Cost in iteration 400: 0.0619187548033546
# Final cost : 0.0619187548033546
# Compute control for a deterministic system
# Cost in iteration 0: 0.0619187548033546
# Cost in iteration 200: 0.06176929071565149
# Cost in iteration 400: 0.061638043415787123
# Cost in iteration 600: 0.0615221725933129
# Cost in iteration 800: 0.061419620230438454
# Cost in iteration 1000: 0.061328744939474246
# Final cost : 0.061328744939474246
# Compute control for a deterministic system
# Cost in iteration 0: 7.483663428509586
# Final cost : 6.9149905622236645
# Compute control for a deterministic system
# Cost in iteration 0: 6.9149905622236645
# Cost in iteration 200: 0.07986480002062879
# Cost in iteration 400: 0.07066047115218356
# Final cost : 0.07066047115218356
# Compute control for a deterministic system
# Cost in iteration 0: 0.07066047115218356
# Cost in iteration 200: 0.06826683398151015
# Final cost : 0.06826683398151015
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826683398151015
# Cost in iteration 200: 0.06764993308732933
# Final cost : 0.06764993308732933
# Compute control for a deterministic system
# Cost in iteration 0: 0.06764993308732933
# Converged in iteration 7 with cost 0.06763551106070731 because of vanishing difference
# Final cost : 0.06763551106070731
# Compute control for a deterministic system
# Cost in iteration 0: 0.06763551106070731
# Cost in iteration 200: 0.06685023171726111
# Cost in iteration 400: 0.06631108119203045
# Cost in iteration 600: 0.06589505315905393
# Cost in iteration 800: 0.06557493684755682
# Cost in iteration 1000: 0.06530652893934269
# Final cost : 0.06530652893934269
# Compute control for a deterministic system
# Cost in iteration 0: 7.440917911687052
# Final cost : 6.872987750888987
# Compute control for a deterministic system
# Cost in iteration 0: 6.872987750888987
# Cost in iteration 200: 0.08528741725986788
# Cost in iteration 400: 0.08054835302664214
# Final cost : 0.08054835302664214
# Compute control for a deterministic system
# Cost in iteration 0: 0.08054835302664214
# Cost in iteration 200: 0.07900315649943468
# Final cost : 0.07900315649943468
# Compute control for a deterministic system
# Cost in iteration 0: 0.07900315649943468
# Cost in iteration 200: 0.07844748583331053
# Final cost : 0.07844748583331053
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844748583331053
# Cost in iteration 200: 0.07802876712583781
# Cost in iteration 400: 0.07783042399929818
# Final cost : 0.07783042399929818
# Compute control for a deterministic system
# Cost in iteration 0: 0.07783042399929818
# Cost in iteration 200: 0.07771828354321574
# Cost in iteration 400: 0.07764280752496754
# Cost in iteration 600: 0.07759081159904606
# Cost in iteration 800: 0.07755403124221157
# Cost in iteration 1000: 0.07752777878347125
# Final cost : 0.07752777878347125
# Compute control for a deterministic system
# Cost in iteration 0: 7.295629070970098
# Final cost : 5.507272675686701
# Compute control for a deterministic system
# Cost in iteration 0: 5.507272675686701
# Cost in iteration 200: 0.07905543300383669
# Cost in iteration 400: 0.07453648214919727
# Final cost : 0.07453648214919727
# Compute control for a deterministic system
# Cost in iteration 0: 0.07453648214919727
# Cost in iteration 200: 0.07345180999198662
# Final cost : 0.07345180999198662
# Compute control for a deterministic system
# Cost in iteration 0: 0.07345180999198662
# Cost in iteration 200: 0.07302667637542869
# Final cost : 0.07302667637542869
# Compute control for a deterministic system
# Cost in iteration 0: 0.07302667637542869
# Cost in iteration 200: 0.07272437105730302
# Cost in iteration 400: 0.07255970139498212
# Final cost : 0.07255970139498212
# Compute control for a deterministic system
# Cost in iteration 0: 0.07255970139498212
# Cost in iteration 200: 0.07246953867546731
# Cost in iteration 400: 0.07241036688029666
# Cost in iteration 600: 0.07237041744812611
# Cost in iteration 800: 0.0723427674873333
# Cost in iteration 1000: 0.07231991135982266
# Final cost : 0.07231991135982266
# Compute control for a deterministic system
# Cost in iteration 0: 7.0967944367630595
# Final cost : 4.6138474994598955
# Compute control for a deterministic system
# Cost in iteration 0: 4.6138474994598955
# Cost in iteration 200: 0.07349044136974044
# Cost in iteration 400: 0.06931969795202614
# Final cost : 0.06931969795202614
# Compute control for a deterministic system
# Cost in iteration 0: 0.06931969795202614
# Cost in iteration 200: 0.06868631160895469
# Final cost : 0.06868631160895469
# Compute control for a deterministic system
# Cost in iteration 0: 0.06868631160895469
# Cost in iteration 200: 0.06826710718236156
# Final cost : 0.06826710718236156
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826710718236156
# Cost in iteration 200: 0.06817239989626432
# Cost in iteration 400: 0.06811431419891231
# Final cost : 0.06811431419891231
# Compute control for a deterministic system
# Cost in iteration 0: 0.06811431419891231
# Cost in iteration 200: 0.06808031852460697
# Cost in iteration 400: 0.06802624797711321
# Cost in iteration 600: 0.06801089791906716
# Cost in iteration 800: 0.06800620443466726
# Cost in iteration 1000: 0.06800475173291703
# Final cost : 0.06800475173291703
# Compute control for a deterministic system
# Cost in iteration 0: 6.829243632948826
# Final cost : 3.805500516461882
# Compute control for a deterministic system
# Cost in iteration 0: 3.805500516461882
# Cost in iteration 200: 0.07027764426746093
# Cost in iteration 400: 0.06458519305453166
# Final cost : 0.06458519305453166
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458519305453166
# Cost in iteration 200: 0.06415469064677812
# Final cost : 0.06415469064677812
# Compute control for a deterministic system
# Cost in iteration 0: 0.06415469064677812
# Cost in iteration 200: 0.06395056497190281
# Final cost : 0.06395056497190281
# Compute control for a deterministic system
# Cost in iteration 0: 0.06395056497190281
# Cost in iteration 200: 0.06388533679116058
# Cost in iteration 400: 0.06384638588261939
# Final cost : 0.06384638588261939
# Compute control for a deterministic system
# Cost in iteration 0: 0.06384638588261939
# Cost in iteration 200: 0.06379595825763444
# Cost in iteration 400: 0.0637841704844854
# Cost in iteration 600: 0.06378090781848399
# Cost in iteration 800: 0.06377945343144206
# Cost in iteration 1000: 0.06377883713986533
# Final cost : 0.06377883713986533
# Compute control for a deterministic system
# Cost in iteration 0: 6.496727431960348
# Final cost : 2.994398985966255
# Compute control for a deterministic system
# Cost in iteration 0: 2.994398985966255
# Cost in iteration 200: 0.06914529532364636
# Cost in iteration 400: 0.06076758309201619
# Final cost : 0.06076758309201619
# Compute control for a deterministic system
# Cost in iteration 0: 0.06076758309201619
# Cost in iteration 200: 0.05991809521191899
# Final cost : 0.05991809521191899
# Compute control for a deterministic system
# Cost in iteration 0: 0.05991809521191899
# Cost in iteration 200: 0.0597124801857664
# Final cost : 0.0597124801857664
# Compute control for a deterministic system
# Cost in iteration 0: 0.0597124801857664
# Converged in iteration 3 with cost 0.059711755365318385 because of vanishing difference
# Final cost : 0.059711755365318385
# Compute control for a deterministic system
# Cost in iteration 0: 0.059711755365318385
# Cost in iteration 200: 0.05962249671007771
# Cost in iteration 400: 0.05960535193248767
# Cost in iteration 600: 0.059599728230257006
# Cost in iteration 800: 0.05959788216759046
# Cost in iteration 1000: 0.05959720017272915
# Final cost : 0.05959720017272915
# Compute control for a deterministic system
# Cost in iteration 0: 6.105031828911294
# Final cost : 2.180920582156193
# Compute control for a deterministic system
# Cost in iteration 0: 2.180920582156193
# Cost in iteration 200: 0.06154591102130894
# Cost in iteration 400: 0.05611781505606822
# Final cost : 0.05611781505606822
# Compute control for a deterministic system
# Cost in iteration 0: 0.05611781505606822
# Converged in iteration 180 with cost 0.05555142463499592 because of vanishing difference
# Final cost : 0.05555142463499592
# Compute control for a deterministic system
# Cost in iteration 0: 0.05555142463499592
# Cost in iteration 200: 0.05550335361629976
# Final cost : 0.05550335361629976
# Compute control for a deterministic system
# Cost in iteration 0: 0.05550335361629976
# Cost in iteration 200: 0.0554840628241685
# Cost in iteration 400: 0.055473271157198425
# Final cost : 0.055473271157198425
# Compute control for a deterministic system
# Cost in iteration 0: 0.055473271157198425
# Cost in iteration 200: 0.05546304997132524
# Cost in iteration 400: 0.05545990356313209
# Cost in iteration 600: 0.05545867085994079
# Cost in iteration 800: 0.05545817518410279
# Cost in iteration 1000: 0.05545797240269301
# Final cost : 0.05545797240269301
# Compute control for a deterministic system
# Cost in iteration 0: 5.567902191016901
# Final cost : 1.3481195307853289
# Compute control for a deterministic system
# Cost in iteration 0: 1.3481195307853289
# Cost in iteration 200: 0.07044976488786178
# Cost in iteration 400: 0.0527506206244009
# Final cost : 0.0527506206244009
# Compute control for a deterministic system
# Cost in iteration 0: 0.0527506206244009
# Cost in iteration 200: 0.050585284959034575
# Final cost : 0.050585284959034575
# Compute control for a deterministic system
# Cost in iteration 0: 0.050585284959034575
# Converged in iteration 188 with cost 0.05055264947008897 because of vanishing difference
# Final cost : 0.05055264947008897
# Compute control for a deterministic system
# Cost in iteration 0: 0.05055264947008897
# Cost in iteration 200: 0.050548319126905175
# Cost in iteration 400: 0.05054763318977138
# Final cost : 0.05054763318977138
# Compute control for a deterministic system
# Cost in iteration 0: 0.05054763318977138
# Cost in iteration 200: 0.050547480017443795
# Cost in iteration 400: 0.050547456836558396
# Cost in iteration 600: 0.050547452234041765
# Cost in iteration 800: 0.05054745121719105
# Cost in iteration 1000: 0.05054745096387051
# Final cost : 0.05054745096387051
# Compute control for a deterministic system
# Cost in iteration 0: 5.0755989064429805
# Final cost : 0.8109223775080479
# Compute control for a deterministic system
# Cost in iteration 0: 0.8109223775080479
# Cost in iteration 200: 0.06659389811588043
# Cost in iteration 400: 0.048519079968468146
# Final cost : 0.048519079968468146
# Compute control for a deterministic system
# Cost in iteration 0: 0.048519079968468146
# Cost in iteration 200: 0.04658045591588234
# Final cost : 0.04658045591588234
# Compute control for a deterministic system
# Cost in iteration 0: 0.04658045591588234
# Converged in iteration 96 with cost 0.04652681122784642 because of vanishing difference
# Final cost : 0.04652681122784642
# Compute control for a deterministic system
# Cost in iteration 0: 0.04652681122784642
# Cost in iteration 200: 0.04650400670247472
# Cost in iteration 400: 0.04650109905043546
# Final cost : 0.04650109905043546
# Compute control for a deterministic system
# Cost in iteration 0: 0.04650109905043546
# Cost in iteration 200: 0.046500573420864215
# Cost in iteration 400: 0.046500508919199275
# Cost in iteration 600: 0.04650049419437556
# Cost in iteration 800: 0.04650048972342668
# Cost in iteration 1000: 0.04650048831872957
# Final cost : 0.04650048831872957
# Compute control for a deterministic system
# Cost in iteration 0: 4.554047585919947
# Final cost : 0.4371799320485975
# Compute control for a deterministic system
# Cost in iteration 0: 0.4371799320485975
# Cost in iteration 200: 0.06745268719978499
# Cost in iteration 400: 0.044468806576497426
# Final cost : 0.044468806576497426
# Compute control for a deterministic system
# Cost in iteration 0: 0.044468806576497426
# Cost in iteration 200: 0.042571729454898254
# Final cost : 0.042571729454898254
# Compute control for a deterministic system
# Cost in iteration 0: 0.042571729454898254
# Converged in iteration 96 with cost 0.04251843666917949 because of vanishing difference
# Final cost : 0.04251843666917949
# Compute control for a deterministic system
# Cost in iteration 0: 0.04251843666917949
# Cost in iteration 200: 0.04249645064060997
# Cost in iteration 400: 0.042493701811955685
# Final cost : 0.042493701811955685
# Compute control for a deterministic system
# Cost in iteration 0: 0.042493701811955685
# Cost in iteration 200: 0.04249311945592844
# Cost in iteration 400: 0.042493022604532055
# Cost in iteration 600: 0.04249299688405145
# Cost in iteration 800: 0.0424929894350908
# Cost in iteration 1000: 0.04249298707715325
# Final cost : 0.04249298707715325
# Compute control for a deterministic system
# Cost in iteration 0: 4.013970200791728
# Final cost : 0.22766612679022658
# Compute control for a deterministic system
# Cost in iteration 0: 0.22766612679022658
# Cost in iteration 200: 0.09024934735407214
# Cost in iteration 400: 0.04655451866568781
# Final cost : 0.04655451866568781
# Compute control for a deterministic system
# Cost in iteration 0: 0.04655451866568781
# Cost in iteration 200: 0.03868602340258735
# Final cost : 0.03868602340258735
# Compute control for a deterministic system
# Cost in iteration 0: 0.03868602340258735
# Converged in iteration 149 with cost 0.03855208288326383 because of vanishing difference
# Final cost : 0.03855208288326383
# Compute control for a deterministic system
# Cost in iteration 0: 0.03855208288326383
# Cost in iteration 200: 0.038529566668858234
# Cost in iteration 400: 0.03852737254630192
# Final cost : 0.03852737254630192
# Compute control for a deterministic system
# Cost in iteration 0: 0.03852737254630192
# Cost in iteration 200: 0.03852699626905277
# Cost in iteration 400: 0.038526923500352736
# Cost in iteration 600: 0.03852690572843138
# Cost in iteration 800: 0.03852690144111442
# Cost in iteration 1000: 0.03852690038794414
# Final cost : 0.03852690038794414
# Compute control for a deterministic system
# Cost in iteration 0: 3.4657675249544653
# Final cost : 0.16427332354268612
# Compute control for a deterministic system
# Cost in iteration 0: 0.16427332354268612
# Cost in iteration 200: 0.09126537042175364
# Cost in iteration 400: 0.04131917634905395
# Final cost : 0.04131917634905395
# Compute control for a deterministic system
# Cost in iteration 0: 0.04131917634905395
# Cost in iteration 200: 0.03467898960264153
# Final cost : 0.03467898960264153
# Compute control for a deterministic system
# Cost in iteration 0: 0.03467898960264153
# Cost in iteration 200: 0.034609419442738786
# Final cost : 0.034609419442738786
# Compute control for a deterministic system
# Cost in iteration 0: 0.034609419442738786
# Cost in iteration 200: 0.03460555599926021
# Cost in iteration 400: 0.034605080811080276
# Final cost : 0.034605080811080276
# Compute control for a deterministic system
# Cost in iteration 0: 0.034605080811080276
# Cost in iteration 200: 0.03460499733873342
# Cost in iteration 400: 0.03460499144433321
# Cost in iteration 600: 0.03460499060578247
# Cost in iteration 800: 0.03460499046216187
# Cost in iteration 1000: 0.034604990436094656
# Final cost : 0.034604990436094656
# Compute control for a deterministic system
# Cost in iteration 0: 2.8119927122184745
# Final cost : 0.23520429093221207
# Compute control for a deterministic system
# Cost in iteration 0: 0.23520429093221207
# Cost in iteration 200: 0.06076012767810976
# Cost in iteration 400: 0.031025677860605796
# Final cost : 0.031025677860605796
# Compute control for a deterministic system
# Cost in iteration 0: 0.031025677860605796
# Cost in iteration 200: 0.029965727089117208
# Final cost : 0.029965727089117208
# Compute control for a deterministic system
# Cost in iteration 0: 0.029965727089117208
# Cost in iteration 200: 0.029958280095200088
# Final cost : 0.029958280095200088
# Compute control for a deterministic system
# Cost in iteration 0: 0.029958280095200088
# Cost in iteration 200: 0.029957833951256455
# Cost in iteration 400: 0.029957716867801656
# Final cost : 0.029957716867801656
# Compute control for a deterministic system
# Cost in iteration 0: 0.029957716867801656
# Cost in iteration 200: 0.02995771671938853
# Cost in iteration 400: 0.029957716698824095
# Cost in iteration 600: 0.029957716695580647
# Converged in iteration 728 with cost 0.029957716695185647 because of step counter
# Final cost : 0.029957716695185647
# Compute control for a deterministic system
# Cost in iteration 0: 2.2829909806034827
# Final cost : 0.23434041998998056
# Compute control for a deterministic system
# Cost in iteration 0: 0.23434041998998056
# Cost in iteration 200: 0.03352807859893842
# Cost in iteration 400: 0.03159766039611125
# Final cost : 0.03159766039611125
# Compute control for a deterministic system
# Cost in iteration 0: 0.03159766039611125
# Cost in iteration 200: 0.0294882360818186
# Final cost : 0.0294882360818186
# Compute control for a deterministic system
# Cost in iteration 0: 0.0294882360818186
# Cost in iteration 200: 0.027775201521258328
# Final cost : 0.027775201521258328
# Compute control for a deterministic system
# Cost in iteration 0: 0.027775201521258328
# Cost in iteration 200: 0.02651817295402945
# Converged in iteration 271 with cost 0.02613691011467671 because of vanishing difference
# Final cost : 0.02613691011467671
# Compute control for a deterministic system
# Cost in iteration 0: 0.02613691011467671
# Cost in iteration 200: 0.026135141979353148
# Cost in iteration 400: 0.026135124807754567
# Cost in iteration 600: 0.026135123400149445
# Cost in iteration 800: 0.02613512327784067
# Cost in iteration 1000: 0.02613512326690326
# Final cost : 0.02613512326690326
# Compute control for a deterministic system
# Cost in iteration 0: 1.7798604919514478
# Final cost : 0.12853985097525686
# Compute control for a deterministic system
# Cost in iteration 0: 0.12853985097525686
# Cost in iteration 200: 0.028207231057610232
# Cost in iteration 400: 0.026674005486231313
# Final cost : 0.026674005486231313
# Compute control for a deterministic system
# Cost in iteration 0: 0.026674005486231313
# Cost in iteration 200: 0.024501815426402215
# Final cost : 0.024501815426402215
# Compute control for a deterministic system
# Cost in iteration 0: 0.024501815426402215
# Converged in iteration 123 with cost 0.022359069991428473 because of vanishing difference
# Final cost : 0.022359069991428473
# Compute control for a deterministic system
# Cost in iteration 0: 0.022359069991428473
# Cost in iteration 200: 0.02235890494956809
# Converged in iteration 205 with cost 0.022358904949558594 because of step counter
# Final cost : 0.022358904949558594
# Compute control for a deterministic system
# Cost in iteration 0: 0.022358904949558594
# Converged in iteration 1 with cost 0.022358904949558594 because of step counter
# Final cost : 0.022358904949558594
# Compute control for a deterministic system
# Cost in iteration 0: 1.313976288716248
# Final cost : 0.11643839112411669
# Compute control for a deterministic system
# Cost in iteration 0: 0.11643839112411669
# Cost in iteration 200: 0.02313891404538058
# Cost in iteration 400: 0.021824879203432446
# Final cost : 0.021824879203432446
# Compute control for a deterministic system
# Cost in iteration 0: 0.021824879203432446
# Cost in iteration 200: 0.01958221907769532
# Final cost : 0.01958221907769532
# Compute control for a deterministic system
# Cost in iteration 0: 0.01958221907769532
# Converged in iteration 153 with cost 0.018630689706784446 because of vanishing difference
# Final cost : 0.018630689706784446
# Compute control for a deterministic system
# Cost in iteration 0: 0.018630689706784446
# Cost in iteration 200: 0.01863042839028408
# Converged in iteration 298 with cost 0.018630428382193736 because of step counter
# Final cost : 0.018630428382193736
# Compute control for a deterministic system
# Cost in iteration 0: 0.018630428382193736
# Converged in iteration 4 with cost 0.01863042838219158 because of step counter
# Final cost : 0.01863042838219158
# Compute control for a deterministic system
# Cost in iteration 0: 0.8975908781188906
# Final cost : 0.1854561501753898
# Compute control for a deterministic system
# Cost in iteration 0: 0.1854561501753898
# Cost in iteration 200: 0.01850320839186179
# Cost in iteration 400: 0.017236397119050787
# Final cost : 0.017236397119050787
# Compute control for a deterministic system
# Cost in iteration 0: 0.017236397119050787
# Cost in iteration 200: 0.014971343391267919
# Final cost : 0.014971343391267919
# Compute control for a deterministic system
# Cost in iteration 0: 0.014971343391267919
# Cost in iteration 200: 0.01495020186301908
# Final cost : 0.01495020186301908
# Compute control for a deterministic system
# Cost in iteration 0: 0.01495020186301908
# Cost in iteration 200: 0.014950194919813144
# Converged in iteration 201 with cost 0.014950194919813144 because of step counter
# Final cost : 0.014950194919813144
# Compute control for a deterministic system
# Cost in iteration 0: 0.014950194919813144
# Converged in iteration 2 with cost 0.014950194919811895 because of step counter
# Final cost : 0.014950194919811895
# Compute control for a deterministic system
# Cost in iteration 0: 0.48224406580869444
# Final cost : 0.2395686567885697
# Compute control for a deterministic system
# Cost in iteration 0: 0.2395686567885697
# Cost in iteration 200: 0.010598777141929425
# Converged in iteration 225 with cost 0.010598701967497211 because of vanishing difference
# Final cost : 0.010598701967497211
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598701967497211
# Cost in iteration 200: 0.010598679855048448
# Final cost : 0.010598679855048448
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679855048448
# Converged in iteration 173 with cost 0.010598679838365033 because of step counter
# Final cost : 0.010598679838365033
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679838365033
# Converged in iteration 5 with cost 0.010598679838317682 because of step counter
# Final cost : 0.010598679838317682
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679838317682
# Converged in iteration 6 with cost 0.010598679838310154 because of step counter
# Final cost : 0.010598679838310154
# Compute control for a deterministic system
# Cost in iteration 0: 0.22352713519279852
# Final cost : 0.05953941374277467
# Compute control for a deterministic system
# Cost in iteration 0: 0.05953941374277467
# Cost in iteration 200: 0.007028854823307397
# Converged in iteration 238 with cost 0.007028656216914265 because of vanishing difference
# Final cost : 0.007028656216914265
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028656216914265
# Cost in iteration 200: 0.007028646257189302
# Final cost : 0.007028646257189302
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646257189302
# Converged in iteration 14 with cost 0.007028646257134455 because of step counter
# Final cost : 0.007028646257134455
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646257134455
# Converged in iteration 1 with cost 0.007028646257134455 because of step counter
# Final cost : 0.007028646257134455
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646257134455
# Converged in iteration 2 with cost 0.007028646257134407 because of step counter
# Final cost : 0.007028646257134407
# Compute control for a deterministic system
# Cost in iteration 0: 0.05924937536857409
# Final cost : 0.005681693605577037
# Compute control for a deterministic system
# Cost in iteration 0: 0.005681693605577037
# Converged in iteration 72 with cost 0.003515625404795603 because of vanishing difference
# Final cost : 0.003515625404795603
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515625404795603
# Converged in iteration 99 with cost 0.0035156207671563507 because of step counter
# Final cost : 0.0035156207671563507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035156207671563507
# Converged in iteration 7 with cost 0.00351562076714211 because of step counter
# Final cost : 0.00351562076714211
# Compute control for a deterministic system
# Cost in iteration 0: 0.00351562076714211
# Converged in iteration 1 with cost 0.00351562076714211 because of step counter
# Final cost : 0.00351562076714211
# Compute control for a deterministic system
# Cost in iteration 0: 0.00351562076714211
# Converged in iteration 1 with cost 0.00351562076714211 because of step counter
# Final cost : 0.00351562076714211
# Compute control for a deterministic system
# Cost in iteration 0: 8.638950980750527e-05
# Final cost : 8.2326932647294e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.2326932647294e-05
# Converged in iteration 20 with cost 8.183379207900483e-05 because of step counter
# Final cost : 8.183379207900483e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.183379207900483e-05
# Converged in iteration 1 with cost 8.183379207900483e-05 because of step counter
# Final cost : 8.183379207900483e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.183379207900483e-05
# Converged in iteration 1 with cost 8.183379207900483e-05 because of step counter
# Final cost : 8.183379207900483e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.183379207900483e-05
# Converged in iteration 1 with cost 8.183379207900483e-05 because of step counter
# Final cost : 8.183379207900483e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.183379207900483e-05
# Converged in iteration 2 with cost 8.183379207876686e-05 because of step counter
# Final cost : 8.183379207876686e-05
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05717763657214973
# Cost in iteration 200: 0.006738294137746431
# Final cost : 0.006738294137746431
# Compute control for a deterministic system
# Cost in iteration 0: 0.006738294137746431
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.06377852758877575
# Cost in iteration 200: 0.06377842363261459
# Cost in iteration 400: 0.06377840039321306
# Final cost : 0.06377840039321306
# Compute control for a deterministic system
# Cost in iteration 0: 0.06377840039321306
# Cost in iteration 200: 0.06377839047505701
# Cost in iteration 400: 0.06377838835049736
# Cost in iteration 600: 0.06377838761070265
# Cost in iteration 800: 0.06377838731132539
# Cost in iteration 1000: 0.06377838718368706
# Final cost : 0.06377838718368706
# Compute control for a deterministic system
# Cost in iteration 0: 0.1180160382628489
# Cost in iteration 200: 0.059597771680918836
# Final cost : 0.059597771680918836
# Compute control for a deterministic system
# Cost in iteration 0: 0.059597771680918836
# Converged in iteration 24 with cost 0.05959737135194988 because of vanishing difference
# Final cost : 0.05959737135194988
# Compute control for a deterministic system
# Cost in iteration 0: 0.05959737135194988
# Cost in iteration 200: 0.05959664518150752
# Final cost : 0.05959664518150752
# Compute control for a deterministic system
# Cost in iteration 0: 0.05959664518150752
# Cost in iteration 200: 0.05959656057427291
# Cost in iteration 400: 0.05959654201495724
# Final cost : 0.05959654201495724
# Compute control for a deterministic system
# Cost in iteration 0: 0.05959654201495724
# Cost in iteration 200: 0.059596534079795295
# Cost in iteration 400: 0.05959653211212974
# Cost in iteration 600: 0.05959653139166318
# Cost in iteration 800: 0.05959653108889799
# Cost in iteration 1000: 0.05959653095497062
# Final cost : 0.05959653095497062
# Compute control for a deterministic system
# Cost in iteration 0: 0.11027065674715109
# Cost in iteration 200: 0.05545896609431664
# Final cost : 0.05545896609431664
# Compute control for a deterministic system
# Cost in iteration 0: 0.05545896609431664
# Cost in iteration 200: 0.05545788619736467
# Final cost : 0.05545788619736467
# Compute control for a deterministic system
# Cost in iteration 0: 0.05545788619736467
# Cost in iteration 200: 0.055457836497284384
# Final cost : 0.055457836497284384
# Compute control for a deterministic system
# Cost in iteration 0: 0.055457836497284384
# Cost in iteration 200: 0.055457826010836785
# Cost in iteration 400: 0.05545782230652569
# Final cost : 0.05545782230652569
# Compute control for a deterministic system
# Cost in iteration 0: 0.05545782230652569
# Cost in iteration 200: 0.05545781986876538
# Cost in iteration 400: 0.05545781904815339
# Cost in iteration 600: 0.05545781873229578
# Cost in iteration 800: 0.05545781860546727
# Cost in iteration 1000: 0.05545781855500377
# Final cost : 0.05545781855500377
# Compute control for a deterministic system
# Cost in iteration 0: 0.10070365720905633
# Converged in iteration 182 with cost 0.0505474973344717 because of vanishing difference
# Final cost : 0.0505474973344717
# Compute control for a deterministic system
# Cost in iteration 0: 0.0505474973344717
# Cost in iteration 200: 0.050547439762725944
# Final cost : 0.050547439762725944
# Compute control for a deterministic system
# Cost in iteration 0: 0.050547439762725944
# Cost in iteration 200: 0.050547438756087845
# Final cost : 0.050547438756087845
# Compute control for a deterministic system
# Cost in iteration 0: 0.050547438756087845
# Cost in iteration 200: 0.05054743862746704
# Cost in iteration 400: 0.05054743860017382
# Final cost : 0.05054743860017382
# Compute control for a deterministic system
# Cost in iteration 0: 0.05054743860017382
# Cost in iteration 200: 0.05054743859035029
# Cost in iteration 400: 0.050547438587398276
# Cost in iteration 600: 0.05054743858628651
# Converged in iteration 662 with cost 0.05054743858611957 because of step counter
# Final cost : 0.05054743858611957
# Compute control for a deterministic system
# Cost in iteration 0: 0.09245074664227879
# Cost in iteration 200: 0.04650111000582841
# Final cost : 0.04650111000582841
# Compute control for a deterministic system
# Cost in iteration 0: 0.04650111000582841
# Cost in iteration 200: 0.04650050479508477
# Final cost : 0.04650050479508477
# Compute control for a deterministic system
# Cost in iteration 0: 0.04650050479508477
# Cost in iteration 200: 0.04650047788712136
# Final cost : 0.04650047788712136
# Compute control for a deterministic system
# Cost in iteration 0: 0.04650047788712136
# Cost in iteration 200: 0.04650047209543527
# Cost in iteration 400: 0.04650046996577576
# Final cost : 0.04650046996577576
# Compute control for a deterministic system
# Cost in iteration 0: 0.04650046996577576
# Cost in iteration 200: 0.04650046874319517
# Cost in iteration 400: 0.04650046833367002
# Cost in iteration 600: 0.04650046818849922
# Cost in iteration 800: 0.0465004681331924
# Cost in iteration 1000: 0.04650046811285269
# Final cost : 0.04650046811285269
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.08391443418959288
# Cost in iteration 200: 0.04249345897121972
# Final cost : 0.04249345897121972
# Compute control for a deterministic system
# Cost in iteration 0: 0.04249345897121972
# Cost in iteration 200: 0.04249298010445284
# Final cost : 0.04249298010445284
# Compute control for a deterministic system
# Cost in iteration 0: 0.04249298010445284
# Cost in iteration 200: 0.04249295969155415
# Final cost : 0.04249295969155415
# Compute control for a deterministic system
# Cost in iteration 0: 0.04249295969155415
# Cost in iteration 200: 0.042492955270889435
# Cost in iteration 400: 0.04249295367075574
# Final cost : 0.04249295367075574
# Compute control for a deterministic system
# Cost in iteration 0: 0.04249295367075574
# Cost in iteration 200: 0.042492952816089766
# Cost in iteration 400: 0.04249295255809397
# Cost in iteration 600: 0.04249295247722168
# Cost in iteration 800: 0.042492952452008605
# Cost in iteration 1000: 0.04249295244395797
# Final cost : 0.04249295244395797
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.07518160630235314
# Cost in iteration 200: 0.038527276884159405
# Final cost : 0.038527276884159405
# Compute control for a deterministic system
# Cost in iteration 0: 0.038527276884159405
# Cost in iteration 200: 0.0385268878363101
# Final cost : 0.0385268878363101
# Compute control for a deterministic system
# Cost in iteration 0: 0.0385268878363101
# Cost in iteration 200: 0.03852687038015758
# Final cost : 0.03852687038015758
# Compute control for a deterministic system
# Cost in iteration 0: 0.03852687038015758
# Cost in iteration 200: 0.03852686676692144
# Cost in iteration 400: 0.03852686554263036
# Final cost : 0.03852686554263036
# Compute control for a deterministic system
# Cost in iteration 0: 0.03852686554263036
# Cost in iteration 200: 0.038526864956016774
# Cost in iteration 400: 0.0385268648154641
# Cost in iteration 600: 0.038526864780028834
# Cost in iteration 800: 0.03852686477095417
# Cost in iteration 1000: 0.03852686476857799
# Final cost : 0.03852686476857799
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.06639672256625989
# Cost in iteration 200: 0.03460535285956612
# Final cost : 0.03460535285956612
# Compute control for a deterministic system
# Cost in iteration 0: 0.03460535285956612
# Cost in iteration 200: 0.034604993246069804
# Final cost : 0.034604993246069804
# Compute control for a deterministic system
# Cost in iteration 0: 0.034604993246069804
# Cost in iteration 200: 0.034604978792680686
# Final cost : 0.034604978792680686
# Compute control for a deterministic system
# Cost in iteration 0: 0.034604978792680686
# Cost in iteration 200: 0.034604976151033806
# Cost in iteration 400: 0.03460497536265335
# Final cost : 0.03460497536265335
# Compute control for a deterministic system
# Cost in iteration 0: 0.03460497536265335
# Cost in iteration 200: 0.03460497504531749
# Cost in iteration 400: 0.03460497498618841
# Cost in iteration 600: 0.03460497497486387
# Cost in iteration 800: 0.03460497497270585
# Converged in iteration 829 with cost 0.03460497497260669 because of step counter
# Final cost : 0.03460497497260669
# Compute control for a deterministic system
# Cost in iteration 0: 0.055895945055356826
# Cost in iteration 200: 0.02995775173943642
# Final cost : 0.02995775173943642
# Compute control for a deterministic system
# Cost in iteration 0: 0.02995775173943642
# Cost in iteration 200: 0.029957702595354345
# Final cost : 0.029957702595354345
# Compute control for a deterministic system
# Cost in iteration 0: 0.029957702595354345
# Cost in iteration 200: 0.029957700892086766
# Final cost : 0.029957700892086766
# Compute control for a deterministic system
# Cost in iteration 0: 0.029957700892086766
# Cost in iteration 200: 0.0299577005576244
# Converged in iteration 207 with cost 0.029957700557600987 because of step counter
# Final cost : 0.029957700557600987
# Compute control for a deterministic system
# Cost in iteration 0: 0.029957700557600987
# Converged in iteration 1 with cost 0.029957700557600987 because of step counter
# Final cost : 0.029957700557600987
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.04727714321023043
# Cost in iteration 200: 0.026134967761264186
# Final cost : 0.026134967761264186
# Compute control for a deterministic system
# Cost in iteration 0: 0.026134967761264186
# Cost in iteration 200: 0.02613494267772008
# Final cost : 0.02613494267772008
# Compute control for a deterministic system
# Cost in iteration 0: 0.02613494267772008
# Cost in iteration 200: 0.026134941880858544
# Final cost : 0.026134941880858544
# Compute control for a deterministic system
# Cost in iteration 0: 0.026134941880858544
# Converged in iteration 159 with cost 0.026134941766628974 because of step counter
# Final cost : 0.026134941766628974
# Compute control for a deterministic system
# Cost in iteration 0: 0.026134941766628974
# Converged in iteration 6 with cost 0.02613494176662737 because of step counter
# Final cost : 0.02613494176662737
# Compute control for a deterministic system
# Cost in iteration 0: 0.03889585142268533
# Converged in iteration 157 with cost 0.022358905420408904 because of vanishing difference
# Final cost : 0.022358905420408904
# Compute control for a deterministic system
# Cost in iteration 0: 0.022358905420408904
# Cost in iteration 200: 0.022358879363354102
# Final cost : 0.022358879363354102
# Compute control for a deterministic system
# Cost in iteration 0: 0.022358879363354102
# Cost in iteration 200: 0.022358878834450237
# Final cost : 0.022358878834450237
# Compute control for a deterministic system
# Cost in iteration 0: 0.022358878834450237
# Converged in iteration 122 with cost 0.022358878790961663 because of step counter
# Final cost : 0.022358878790961663
# Compute control for a deterministic system
# Cost in iteration 0: 0.022358878790961663
# Converged in iteration 8 with cost 0.02235887879095983 because of step counter
# Final cost : 0.02235887879095983
# Compute control for a deterministic system
# Cost in iteration 0: 0.03087441229204306
# Converged in iteration 136 with cost 0.018630428586425062 because of vanishing difference
# Final cost : 0.018630428586425062
# Compute control for a deterministic system
# Cost in iteration 0: 0.018630428586425062
# Cost in iteration 200: 0.018630416743319767
# Final cost : 0.018630416743319767
# Compute control for a deterministic system
# Cost in iteration 0: 0.018630416743319767
# Cost in iteration 200: 0.01863041657153758
# Final cost : 0.01863041657153758
# Compute control for a deterministic system
# Cost in iteration 0: 0.01863041657153758
# Converged in iteration 112 with cost 0.018630416564550452 because of step counter
# Final cost : 0.018630416564550452
# Compute control for a deterministic system
# Cost in iteration 0: 0.018630416564550452
# Converged in iteration 1 with cost 0.018630416564550452 because of step counter
# Final cost : 0.018630416564550452
# Compute control for a deterministic system
# Cost in iteration 0: 0.02334439258517175
# Cost in iteration 200: 0.014950177989097535
# Final cost : 0.014950177989097535
# Compute control for a deterministic system
# Cost in iteration 0: 0.014950177989097535
# Converged in iteration 77 with cost 0.014950177988774353 because of step counter
# Final cost : 0.014950177988774353
# Compute control for a deterministic system
# Cost in iteration 0: 0.014950177988774353
# Converged in iteration 1 with cost 0.014950177988774353 because of step counter
# Final cost : 0.014950177988774353
# Compute control for a deterministic system
# Cost in iteration 0: 0.014950177988774353
# Converged in iteration 1 with cost 0.014950177988774353 because of step counter
# Final cost : 0.014950177988774353
# Compute control for a deterministic system
# Cost in iteration 0: 0.014950177988774353
# Converged in iteration 1 with cost 0.014950177988774353 because of step counter
# Final cost : 0.014950177988774353
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.015137551342954634
# Cost in iteration 200: 0.010598679584337651
# Final cost : 0.010598679584337651
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679584337651
# Converged in iteration 7 with cost 0.010598679584320182 because of step counter
# Final cost : 0.010598679584320182
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679584320182
# Converged in iteration 13 with cost 0.010598679584289183 because of step counter
# Final cost : 0.010598679584289183
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679584289183
# Converged in iteration 1 with cost 0.010598679584289183 because of step counter
# Final cost : 0.010598679584289183
# Compute control for a deterministic system
# Cost in iteration 0: 0.010598679584289183
# Converged in iteration 1 with cost 0.010598679584289183 because of step counter
# Final cost : 0.010598679584289183
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.009137524167995618
# Converged in iteration 137 with cost 0.007028646110447021 because of step counter
# Final cost : 0.007028646110447021
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646110447021
# Converged in iteration 1 with cost 0.007028646110447021 because of step counter
# Final cost : 0.007028646110447021
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646110447021
# Converged in iteration 1 with cost 0.007028646110447021 because of step counter
# Final cost : 0.007028646110447021
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646110447021
# Converged in iteration 1 with cost 0.007028646110447021 because of step counter
# Final cost : 0.007028646110447021
# Compute control for a deterministic system
# Cost in iteration 0: 0.007028646110447021
# Converged in iteration 17 with cost 0.00702864611043295 because of step counter
# Final cost : 0.00702864611043295
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.004065382146402916
# Converged in iteration 80 with cost 0.003515620593181182 because of step counter
# Final cost : 0.003515620593181182
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515620593181182
# Converged in iteration 2 with cost 0.003515620593180561 because of step counter
# Final cost : 0.003515620593180561
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515620593180561
# Converged in iteration 1 with cost 0.003515620593180561 because of step counter
# Final cost : 0.003515620593180561
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515620593180561
# Converged in iteration 1 with cost 0.003515620593180561 because of step counter
# Final cost : 0.003515620593180561
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515620593180561
# Converged in iteration 1 with cost 0.003515620593180561 because of step counter
# Final cost : 0.003515620593180561
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
