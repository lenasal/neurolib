# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.25426803074613735
y_init = 0.2588983729056897
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,123], wc.inh[0,123]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.05481462579209116 0.18840746023632948
# minima =  [  44  252  460  669  877 1085 1293 1501 1710 1918 2126 2334 2542 2751
#  2959 3167 3375 3583 3792 4000 4208 4416 4624 4833 5041 5249 5457 5665
#  5874]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 2
#       1 results_min = read()
# ----> 2 results_peak = readfile("results_peak_w2.pickle")
#
# Cell In [7], line 14, in readfile(file)
#      13 def readfile(file):
# ---> 14     filehandler = open(file,"rb")
#      15     results_dict = pickle.load(filehandler)
#      16     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results_peak_w2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                #wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05626712878172736
# Final cost : 1.7922237153969215e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7922237153969215e-05
# Final cost : 1.7663763846398988e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7663763846398988e-05
# Final cost : 1.7418863805751447e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7418863805751447e-05
# Final cost : 1.7074367710978914e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7074367710978914e-05
# Final cost : 1.638208398195422e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.08290301784437215
# Final cost : 6.184732645594158e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.184732645594158e-05
# Final cost : 5.959668798647262e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.959668798647262e-05
# Final cost : 5.609553884148143e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.609553884148143e-05
# Final cost : 4.99627923971497e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.99627923971497e-05
# Final cost : 4.427555883302824e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.06359267633508274
# Final cost : 8.221247882868611e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.221247882868611e-05
# Final cost : 8.020499493024634e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.020499493024634e-05
# Final cost : 7.772837433023854e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.772837433023854e-05
# Final cost : 6.906758338731495e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.906758338731495e-05
# Final cost : 6.627306681859472e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.07453315044304391
# Final cost : 0.00012067840230467471
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012067840230467471
# Final cost : 0.00011439057780704553
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011439057780704553
# Final cost : 0.00011184102076553191
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011184102076553191
# Final cost : 0.00010669344318694648
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010669344318694648
# Final cost : 0.0001022262913767844
# Compute control for a deterministic system
# Cost in iteration 0: 0.0694446780065198
# Final cost : 0.00016804684633626407
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016804684633626407
# Final cost : 0.00016038043584247957
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016038043584247957
# Final cost : 0.00015703390765470023
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015703390765470023
# Final cost : 0.00014465125315955862
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014465125315955862
# Final cost : 0.00013994304750510517
# Compute control for a deterministic system
# Cost in iteration 0: 0.06575330096832263
# Final cost : 0.00021302489271099063
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021302489271099063
# Final cost : 0.00020627887843322108
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020627887843322108
# Final cost : 0.00020195573461716197
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020195573461716197
# Final cost : 0.00019098167422470914
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019098167422470914
# Final cost : 0.0001858386252983361
# Compute control for a deterministic system
# Cost in iteration 0: 0.12540353020133788
# Final cost : 0.000333585570613378
# Compute control for a deterministic system
# Cost in iteration 0: 0.000333585570613378
# Final cost : 0.0002972021881324574
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002972021881324574
# Final cost : 0.0002786175187030733
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002786175187030733
# Final cost : 0.0002611767199538315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002611767199538315
# Final cost : 0.00024796494982390213
# Compute control for a deterministic system
# Cost in iteration 0: 0.02934818352083593
# Final cost : 0.00031438836685607685
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031438836685607685
# Final cost : 0.00030984897195988534
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030984897195988534
# Final cost : 0.00030674604992245364
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030674604992245364
# Final cost : 0.0003010714920499997
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003010714920499997
# Final cost : 0.0002980585400252474
# Compute control for a deterministic system
# Cost in iteration 0: 0.03183554026237135
# Final cost : 0.00037724346888319093
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037724346888319093
# Final cost : 0.0003709779256666505
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003709779256666505
# Final cost : 0.00036802247022971375
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036802247022971375
# Final cost : 0.00036391875924907596
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036391875924907596
# Final cost : 0.0003607183373854964
# Compute control for a deterministic system
# Cost in iteration 0: 0.037999688772005234
# Final cost : 0.0004671766373013996
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004671766373013996
# Final cost : 0.0004559847181757149
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004559847181757149
# Final cost : 0.0004474183563680076
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004474183563680076
# Final cost : 0.0004411798939676082
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004411798939676082
# Final cost : 0.00043348308899162366
# Compute control for a deterministic system
# Cost in iteration 0: 0.06240736927676535
# Final cost : 0.0005315138847785185
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005315138847785185
# Final cost : 0.0005154770353494656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005154770353494656
# Final cost : 0.0005070445233916622
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005070445233916622
# Final cost : 0.0005006109852683818
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005006109852683818
# Final cost : 0.0004960544266303811
# Compute control for a deterministic system
# Cost in iteration 0: 0.109789272879621
# Final cost : 0.000791912599321341
# Compute control for a deterministic system
# Cost in iteration 0: 0.000791912599321341
# Final cost : 0.000665199076462362
# Compute control for a deterministic system
# Cost in iteration 0: 0.000665199076462362
# Final cost : 0.0006303795367725586
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006303795367725586
# Final cost : 0.0006120058043710599
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006120058043710599
# Final cost : 0.0006016565293644301
# Compute control for a deterministic system
# Cost in iteration 0: 0.07425906516705492
# Final cost : 0.0007250169791412453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007250169791412453
# Final cost : 0.0006860610339849344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006860610339849344
# Final cost : 0.0006710963204271883
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006710963204271883
# Final cost : 0.0006612433590961627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006612433590961627
# Final cost : 0.0006576318340961629
# Compute control for a deterministic system
# Cost in iteration 0: 0.08001164970587264
# Final cost : 0.0008551754977483777
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008551754977483777
# Final cost : 0.0007876414596802066
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007876414596802066
# Final cost : 0.0007643790666189343
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007643790666189343
# Final cost : 0.0007535012587436923
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007535012587436923
# Final cost : 0.0007477887697941198
# Compute control for a deterministic system
# Cost in iteration 0: 0.1114015531460751
# Final cost : 0.0012083806173006865
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012083806173006865
# Final cost : 0.0009285179014298018
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009285179014298018
# Final cost : 0.0008739948407687554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008739948407687554
# Final cost : 0.0008604698042692444
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008604698042692444
# Final cost : 0.0008512305262638865
# Compute control for a deterministic system
# Cost in iteration 0: 0.06334875927334434
# Final cost : 0.0010476648108470922
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010476648108470922
# Final cost : 0.0009874761872406882
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009874761872406882
# Final cost : 0.0009739076025277226
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009739076025277226
# Final cost : 0.000943962370535604
# Compute control for a deterministic system
# Cost in iteration 0: 0.000943962370535604
# Final cost : 0.000931494967157145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07867681021524359
# Final cost : 0.0011691863786166437
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011691863786166437
# Final cost : 0.0010868849226133126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010868849226133126
# Final cost : 0.0010730385478839588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010730385478839588
# Final cost : 0.0010674420957425559
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010674420957425559
# Final cost : 0.0010618946411232245
# Compute control for a deterministic system
# Cost in iteration 0: 0.1274678964626161
# Final cost : 0.0018659276031285587
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018659276031285587
# Final cost : 0.0014467098157716573
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014467098157716573
# Final cost : 0.0012566515437870934
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012566515437870934
# Final cost : 0.0011576578220642906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011576578220642906
# Final cost : 0.0011471084371288923
# Compute control for a deterministic system
# Cost in iteration 0: 0.04385049670998477
# Final cost : 0.0013062271899300399
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013062271899300399
# Final cost : 0.0012793574955079863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012793574955079863
# Final cost : 0.0012738083853018518
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012738083853018518
# Final cost : 0.0012694492368835425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012694492368835425
# Final cost : 0.0012644824773835963
# Compute control for a deterministic system
# Cost in iteration 0: 0.09065177790784124
# Final cost : 0.0016881667482367478
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016881667482367478
# Final cost : 0.0014617406079534857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014617406079534857
# Final cost : 0.0014015966287627404
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014015966287627404
# Final cost : 0.0013913973628748154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013913973628748154
# Final cost : 0.0013866353591440474
# Compute control for a deterministic system
# Cost in iteration 0: 0.11311634358168816
# Final cost : 0.0020902706415807937
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020902706415807937
# Final cost : 0.0017359607104019625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017359607104019625
# Final cost : 0.0016345743348525129
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016345743348525129
# Final cost : 0.0016046939431587544
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016046939431587544
# Final cost : 0.001581434332778286
# Compute control for a deterministic system
# Cost in iteration 0: 0.059507133058442865
# Final cost : 0.001787136584966958
# Compute control for a deterministic system
# Cost in iteration 0: 0.001787136584966958
# Final cost : 0.0017346612079276555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017346612079276555
# Final cost : 0.0017304254862632888
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017304254862632888
# Final cost : 0.0017267773160422337
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017267773160422337
# Final cost : 0.0017220092932053652
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014928139138157455
# Final cost : 0.0013623731669082234
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013623731669082234
# Final cost : 0.0013595370559627083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013595370559627083
# Final cost : 0.001356821603046788
# Compute control for a deterministic system
# Cost in iteration 0: 0.001356821603046788
# Final cost : 0.0013519411549028717
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013519411549028717
# Final cost : 0.0013423475017570398
# Compute control for a deterministic system
# Cost in iteration 0: 0.06676506382746838
# Final cost : 0.0011919038661531598
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011919038661531598
# Final cost : 0.0011890616447700463
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011890616447700463
# Final cost : 0.0011867228814275376
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011867228814275376
# Final cost : 0.001182436279819442
# Compute control for a deterministic system
# Cost in iteration 0: 0.001182436279819442
# Final cost : 0.001174414442243614
# Compute control for a deterministic system
# Cost in iteration 0: 0.06819726295216641
# Final cost : 0.0010367160672554966
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010367160672554966
# Final cost : 0.0010334049810553157
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010334049810553157
# Final cost : 0.0010255508568536215
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010255508568536215
# Final cost : 0.0010163449509770336
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010163449509770336
# Final cost : 0.0010078995532438533
# Compute control for a deterministic system
# Cost in iteration 0: 0.05555635949357446
# Final cost : 0.0008677634898221342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008677634898221342
# Final cost : 0.0008653003755990657
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008653003755990657
# Final cost : 0.0008635106678688241
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008635106678688241
# Final cost : 0.0008601265484821611
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008601265484821611
# Final cost : 0.0008530647041290138
# Compute control for a deterministic system
# Cost in iteration 0: 0.10794403854028226
# Final cost : 0.0007461829620576677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007461829620576677
# Final cost : 0.0007435035509921624
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007435035509921624
# Final cost : 0.0007375383339329357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007375383339329357
# Final cost : 0.0007340249691537363
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007340249691537363
# Final cost : 0.0007270915828904072
# Compute control for a deterministic system
# Cost in iteration 0: 0.07723733706523057
# Final cost : 0.0006063120942689862
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006063120942689862
# Final cost : 0.0006043510307290811
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006043510307290811
# Final cost : 0.0006012645397957063
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006012645397957063
# Final cost : 0.0005960597453984009
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005960597453984009
# Final cost : 0.000591960568244538
# Compute control for a deterministic system
# Cost in iteration 0: 0.022565437980459884
# Final cost : 0.0004957060144229219
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004957060144229219
# Final cost : 0.0004946113595487955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004946113595487955
# Final cost : 0.0004936740994335914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004936740994335914
# Final cost : 0.0004920007860437858
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004920007860437858
# Final cost : 0.000488606951363737
# Compute control for a deterministic system
# Cost in iteration 0: 0.0987365984009056
# Final cost : 0.0004078116611289909
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004078116611289909
# Final cost : 0.0004065538230428927
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004065538230428927
# Final cost : 0.00040540134111263906
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040540134111263906
# Final cost : 0.0004004854741462079
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004004854741462079
# Final cost : 0.0003957502906430454
# Compute control for a deterministic system
# Cost in iteration 0: 0.06884695919184075
# Final cost : 0.00030730524828437175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030730524828437175
# Final cost : 0.0003062209273083971
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003062209273083971
# Final cost : 0.0003054146651984455
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003054146651984455
# Final cost : 0.0003041246851872402
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003041246851872402
# Final cost : 0.0003013906610047378
# Compute control for a deterministic system
# Cost in iteration 0: 0.02928015257130646
# Final cost : 0.00022764422350227042
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022764422350227042
# Final cost : 0.00022675596546293844
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022675596546293844
# Final cost : 0.00022631655900167118
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022631655900167118
# Final cost : 0.0002255120716702367
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002255120716702367
# Final cost : 0.0002238385675403734
# Compute control for a deterministic system
# Cost in iteration 0: 0.05172516367997019
# Final cost : 0.00016896547926240304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016896547926240304
# Final cost : 0.00016795179042820537
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016795179042820537
# Final cost : 0.00016756341418917988
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016756341418917988
# Final cost : 0.00016656362657963456
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016656362657963456
# Final cost : 0.0001628592531545149
# Compute control for a deterministic system
# Cost in iteration 0: 0.06969561201331953
# Final cost : 0.00011753816080507296
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011753816080507296
# Final cost : 0.00011636570124546073
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011636570124546073
# Final cost : 0.00011607885331708543
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011607885331708543
# Final cost : 0.00011546166818153393
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011546166818153393
# Final cost : 0.00011313644347082579
# Compute control for a deterministic system
# Cost in iteration 0: 0.043668828989030684
# Final cost : 7.603744811643298e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.603744811643298e-05
# Final cost : 7.56892168215944e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.56892168215944e-05
# Final cost : 7.551389782084177e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.551389782084177e-05
# Final cost : 7.519779593553782e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.519779593553782e-05
# Final cost : 7.448583273823826e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.07142343594009236
# Final cost : 4.167137927742598e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.167137927742598e-05
# Final cost : 4.0740757945159475e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.0740757945159475e-05
# Final cost : 4.049455936077888e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.049455936077888e-05
# Final cost : 3.9767378178014777e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.9767378178014777e-05
# Final cost : 3.828045181554756e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.05511126578529997
# Final cost : 1.914422752233827e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.914422752233827e-05
# Final cost : 1.8596929132323877e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8596929132323877e-05
# Final cost : 1.8448728975425627e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8448728975425627e-05
# Final cost : 1.8047674500462196e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8047674500462196e-05
# Final cost : 1.7406763256696184e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.05317209976278572
# Final cost : 6.451846857427159e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.451846857427159e-06
# Final cost : 6.096440746442714e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.096440746442714e-06
# Final cost : 5.979033177325864e-06
# Compute control for a deterministic system
# Cost in iteration 0: 5.979033177325864e-06
# Final cost : 5.653651963529342e-06
# Compute control for a deterministic system
# Cost in iteration 0: 5.653651963529342e-06
# Final cost : 5.1989044910465815e-06
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.05346799066974277
# Final cost : 1.9894648218227243e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.9894648218227243e-05
# Final cost : 1.9333036310283596e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.9333036310283596e-05
# Final cost : 1.8749156303710405e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8749156303710405e-05
# Final cost : 1.784902066912057e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.049749883822271905
# Final cost : 4.660554854904794e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.660554854904794e-05
# Final cost : 4.5060764183667265e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.5060764183667265e-05
# Final cost : 4.270821738417044e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.270821738417044e-05
# Final cost : 4.031067907987986e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.08835221980280901
# Final cost : 0.00010249148902654793
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010249148902654793
# Final cost : 9.646858227687591e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.646858227687591e-05
# Final cost : 8.882499347427172e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.882499347427172e-05
# Final cost : 7.775531882909047e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.06293679244295484
# Final cost : 0.00013248088076233113
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013248088076233113
# Final cost : 0.0001277151987777156
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001277151987777156
# Final cost : 0.000122783888374675
# Compute control for a deterministic system
# Cost in iteration 0: 0.000122783888374675
# Final cost : 0.00011240576060077489
# Compute control for a deterministic system
# Cost in iteration 0: 0.06738422906547555
# Final cost : 0.00018667388473946167
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018667388473946167
# Final cost : 0.0001766860987765846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001766860987765846
# Final cost : 0.00017137058462103835
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017137058462103835
# Final cost : 0.00016445172919128618
# Compute control for a deterministic system
# Cost in iteration 0: 0.07217260153982999
# Final cost : 0.00025077536891866977
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025077536891866977
# Final cost : 0.00024245462143536188
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024245462143536188
# Final cost : 0.00023134149003401687
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023134149003401687
# Final cost : 0.00022433045702721527
# Compute control for a deterministic system
# Cost in iteration 0: 0.08889351442209786
# Final cost : 0.00032293846195443975
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032293846195443975
# Final cost : 0.00031409523202336473
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031409523202336473
# Final cost : 0.00030248406308600647
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030248406308600647
# Final cost : 0.0002941175484248408
# Compute control for a deterministic system
# Cost in iteration 0: 0.053474383326369966
# Final cost : 0.0004150325630799834
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004150325630799834
# Final cost : 0.0004059889614346741
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004059889614346741
# Final cost : 0.00039878966012692354
# Compute control for a deterministic system
# Cost in iteration 0: 0.00039878966012692354
# Final cost : 0.0003915558913552825
# Compute control for a deterministic system
# Cost in iteration 0: 0.06832335456744348
# Final cost : 0.0005095734069456605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005095734069456605
# Final cost : 0.0004997826223533483
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004997826223533483
# Final cost : 0.0004890644661682189
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004890644661682189
# Final cost : 0.00048155605909882713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0328662188313929
# Final cost : 0.0006205141185246581
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006205141185246581
# Final cost : 0.0006102015927574045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006102015927574045
# Final cost : 0.000598212022828124
# Compute control for a deterministic system
# Cost in iteration 0: 0.000598212022828124
# Final cost : 0.0005896049669931097
# Compute control for a deterministic system
# Cost in iteration 0: 0.0308468255665675
# Final cost : 0.0007322863910011245
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007322863910011245
# Final cost : 0.0007226624154310798
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007226624154310798
# Final cost : 0.000712382612319737
# Compute control for a deterministic system
# Cost in iteration 0: 0.000712382612319737
# Final cost : 0.000704580653535534
# Compute control for a deterministic system
# Cost in iteration 0: 0.026976292702855894
# Final cost : 0.0008610363497637624
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008610363497637624
# Final cost : 0.0008516165680224673
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008516165680224673
# Final cost : 0.000842594091777088
# Compute control for a deterministic system
# Cost in iteration 0: 0.000842594091777088
# Final cost : 0.000835941911190367
# Compute control for a deterministic system
# Cost in iteration 0: 0.03349318817093878
# Final cost : 0.001034100869312055
# Compute control for a deterministic system
# Cost in iteration 0: 0.001034100869312055
# Final cost : 0.0010190031682574202
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010190031682574202
# Final cost : 0.0010081371205226965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010081371205226965
# Final cost : 0.0010011683373588678
# Compute control for a deterministic system
# Cost in iteration 0: 0.060915187952278675
# Final cost : 0.001210628553702087
# Compute control for a deterministic system
# Cost in iteration 0: 0.001210628553702087
# Final cost : 0.0011854212822224616
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011854212822224616
# Final cost : 0.0011712436492327405
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011712436492327405
# Final cost : 0.0011639331608885538
# Compute control for a deterministic system
# Cost in iteration 0: 0.046020210114628354
# Final cost : 0.0013987759036043267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013987759036043267
# Final cost : 0.0013737398931246744
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013737398931246744
# Final cost : 0.0013519123901055397
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013519123901055397
# Final cost : 0.0013419005069783792
# Compute control for a deterministic system
# Cost in iteration 0: 0.016851325485111396
# Final cost : 0.0015519918597376148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015519918597376148
# Final cost : 0.0015378236405560529
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015378236405560529
# Final cost : 0.0015286199954153768
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015286199954153768
# Final cost : 0.0015222779086094776
# Compute control for a deterministic system
# Cost in iteration 0: 0.06103539539581763
# Final cost : 0.0018011349969497843
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018011349969497843
# Final cost : 0.0017635414238222262
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017635414238222262
# Final cost : 0.001747486508816479
# Compute control for a deterministic system
# Cost in iteration 0: 0.001747486508816479
# Final cost : 0.0017357130577944572
# Compute control for a deterministic system
# Cost in iteration 0: 0.061518531391546526
# Final cost : 0.0014839431415344744
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014839431415344744
# Final cost : 0.0014820862155988034
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014820862155988034
# Final cost : 0.0014786963818305234
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014786963818305234
# Converged in iteration 2 with cost 0.0014786899976742226 because of vanishing difference
# Final cost : 0.0014786899976742226
# Compute control for a deterministic system
# Cost in iteration 0: 0.01917923896346973
# Final cost : 0.0013122871413463275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013122871413463275
# Final cost : 0.001309742266181454
# Compute control for a deterministic system
# Cost in iteration 0: 0.001309742266181454
# Final cost : 0.001305497408408062
# Compute control for a deterministic system
# Cost in iteration 0: 0.001305497408408062
# Final cost : 0.0012962190221138133
# Compute control for a deterministic system
# Cost in iteration 0: 0.028449657007789102
# Final cost : 0.0011726975124473455
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011726975124473455
# Final cost : 0.0011702245234319016
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011702245234319016
# Final cost : 0.0011663190475799158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011663190475799158
# Final cost : 0.001157928639310106
# Compute control for a deterministic system
# Cost in iteration 0: 0.09920662698317702
# Final cost : 0.0010554968635600346
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010554968635600346
# Final cost : 0.0010523363660385227
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010523363660385227
# Final cost : 0.001048325101654143
# Compute control for a deterministic system
# Cost in iteration 0: 0.001048325101654143
# Final cost : 0.0010395626726183535
# Compute control for a deterministic system
# Cost in iteration 0: 0.08776513017470386
# Final cost : 0.0009559828172982748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009559828172982748
# Final cost : 0.0009532624388619099
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009532624388619099
# Final cost : 0.0009509447302483777
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009509447302483777
# Final cost : 0.0009454923706658123
# Compute control for a deterministic system
# Cost in iteration 0: 0.07157976355064913
# Final cost : 0.000856153251498064
# Compute control for a deterministic system
# Cost in iteration 0: 0.000856153251498064
# Final cost : 0.0008539371184448233
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008539371184448233
# Final cost : 0.0008502525885383001
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008502525885383001
# Final cost : 0.0008423940502525028
# Compute control for a deterministic system
# Cost in iteration 0: 0.10669562748657321
# Final cost : 0.0007559607053864066
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007559607053864066
# Final cost : 0.0007531796787077752
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007531796787077752
# Final cost : 0.0007504537204068102
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007504537204068102
# Final cost : 0.0007453608626176746
# Compute control for a deterministic system
# Cost in iteration 0: 0.08906509739889491
# Final cost : 0.0006701642104379095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006701642104379095
# Final cost : 0.000668502738098388
# Compute control for a deterministic system
# Cost in iteration 0: 0.000668502738098388
# Final cost : 0.0006665728093677145
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006665728093677145
# Final cost : 0.0006628030067242303
# Compute control for a deterministic system
# Cost in iteration 0: 0.023518107396625704
# Final cost : 0.0005989691430489959
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005989691430489959
# Final cost : 0.0005979592761156197
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005979592761156197
# Final cost : 0.0005961082852064012
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005961082852064012
# Final cost : 0.000591535257741005
# Compute control for a deterministic system
# Cost in iteration 0: 0.03814370029175279
# Final cost : 0.0005178833400944842
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005178833400944842
# Final cost : 0.0005169728010811339
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005169728010811339
# Final cost : 0.0005156004586209623
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005156004586209623
# Final cost : 0.0005121045419849516
# Compute control for a deterministic system
# Cost in iteration 0: 0.058665000386390456
# Final cost : 0.00043491319133454363
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043491319133454363
# Final cost : 0.00043373914720218343
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043373914720218343
# Final cost : 0.0004315635604899369
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004315635604899369
# Final cost : 0.0004278197234068295
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042949122743394215
# Final cost : 0.0003681101700357897
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003681101700357897
# Final cost : 0.0003674187242163951
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003674187242163951
# Final cost : 0.0003662397507761351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003662397507761351
# Final cost : 0.0003638801692079612
# Compute control for a deterministic system
# Cost in iteration 0: 0.09806521335033712
# Final cost : 0.00030149116380258454
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030149116380258454
# Final cost : 0.00030021831267965066
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030021831267965066
# Final cost : 0.00029911435142687323
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029911435142687323
# Final cost : 0.0002973535841252868
# Compute control for a deterministic system
# Cost in iteration 0: 0.10133311731385418
# Final cost : 0.0002443184668273142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002443184668273142
# Final cost : 0.00024301071436412975
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024301071436412975
# Final cost : 0.0002421898568865809
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002421898568865809
# Final cost : 0.00024113857389399164
# Compute control for a deterministic system
# Cost in iteration 0: 0.07982666704671103
# Final cost : 0.00019130769861787938
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019130769861787938
# Final cost : 0.0001906667782564269
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001906667782564269
# Final cost : 0.00018978860982761444
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018978860982761444
# Final cost : 0.00018266514092199303
# Compute control for a deterministic system
# Cost in iteration 0: 0.02903962815944178
# Final cost : 0.00013984690879071624
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013984690879071624
# Final cost : 0.00013937562758863307
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013937562758863307
# Final cost : 0.00013883052872054892
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013883052872054892
# Final cost : 0.00013757711335633512
# Compute control for a deterministic system
# Cost in iteration 0: 0.08048060503627459
# Final cost : 0.00010450377296041971
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010450377296041971
# Final cost : 0.00010383204877092448
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010383204877092448
# Final cost : 0.00010316987151863475
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010316987151863475
# Final cost : 0.00010073204450570912
# Compute control for a deterministic system
# Cost in iteration 0: 0.06711535951298231
# Final cost : 7.189643319791813e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.189643319791813e-05
# Final cost : 7.054085916258886e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.054085916258886e-05
# Final cost : 6.75512150195759e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.75512150195759e-05
# Final cost : 6.59010272483869e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.047575147332508345
# Final cost : 4.413540573681408e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.413540573681408e-05
# Final cost : 4.3488158051799914e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.3488158051799914e-05
# Final cost : 4.2673127019136036e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.2673127019136036e-05
# Final cost : 4.146452324894555e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.07104638473605807
# Final cost : 2.1145151233207938e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.1145151233207938e-05
# Final cost : 2.0633205733588704e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.0633205733588704e-05
# Final cost : 1.8355410167133696e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8355410167133696e-05
# Final cost : 1.686309952934543e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.06644768874954896
# Final cost : 4.420840841951845e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.420840841951845e-06
# Final cost : 4.2345750953799375e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.2345750953799375e-06
# Final cost : 4.146055299461487e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.146055299461487e-06
# Final cost : 3.939239578455809e-06
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 3.7152459335672348e-06
# Final cost : 3.7119792703904396e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.7119792703904396e-06
# Final cost : 3.7119759792948073e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.7119759792948073e-06
# Final cost : 3.711972996297814e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.711972996297814e-06
# Final cost : 3.7119681277709303e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.7119681277709303e-06
# Final cost : 3.711953641536905e-06
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019741493479705376
# Final cost : 1.4656030514109565e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4656030514109565e-05
# Final cost : 1.4655002831729676e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4655002831729676e-05
# Final cost : 1.4654298507025471e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4654298507025471e-05
# Final cost : 1.4653171384377978e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4653171384377978e-05
# Final cost : 1.4650801994918383e-05
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008697002968527345
# Final cost : 3.6926845167445705e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6926845167445705e-05
# Final cost : 3.692229692508275e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.692229692508275e-05
# Final cost : 3.692005716695164e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.692005716695164e-05
# Final cost : 3.691614675378195e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.691614675378195e-05
# Final cost : 3.690746161594106e-05
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023088672376098264
# Final cost : 6.275433288814361e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.275433288814361e-05
# Final cost : 6.274487444274318e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.274487444274318e-05
# Final cost : 6.274166770996161e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.274166770996161e-05
# Final cost : 6.273558732970119e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.273558732970119e-05
# Final cost : 6.272317595875339e-05
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.001336984247794388
# Final cost : 9.479381961910415e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.479381961910415e-05
# Final cost : 9.47879236123783e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.47879236123783e-05
# Final cost : 9.478643855160527e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.478643855160527e-05
# Final cost : 9.478390555540684e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.478390555540684e-05
# Final cost : 9.477857897656476e-05
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.004546002785173778
# Final cost : 0.00013301139136619096
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013301139136619096
# Final cost : 0.0001329865313691814
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001329865313691814
# Final cost : 0.0001329810187435381
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001329810187435381
# Final cost : 0.00013297276289722247
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013297276289722247
# Final cost : 0.00013295627673825134
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.005653454416152419
# Final cost : 0.0001779314584599396
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001779314584599396
# Final cost : 0.00017785326537272307
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017785326537272307
# Final cost : 0.00017780992861511435
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017780992861511435
# Final cost : 0.00017773835958264321
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017773835958264321
# Final cost : 0.00017757670662742919
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033288994810495723
# Final cost : 0.00023695658255627362
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023695658255627362
# Final cost : 0.0002369417335277374
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002369417335277374
# Final cost : 0.00023692872005612304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023692872005612304
# Final cost : 0.00023686775962861433
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023686775962861433
# Final cost : 0.0002368316451824411
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.00782804311043823
# Final cost : 0.0002935265689115545
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002935265689115545
# Final cost : 0.00029333274804556304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029333274804556304
# Final cost : 0.00029327137652332674
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029327137652332674
# Final cost : 0.00029322794320218965
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029322794320218965
# Final cost : 0.0002931195276480998
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013302513651027763
# Final cost : 0.00035604625805937
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035604625805937
# Final cost : 0.0003559842851085046
# Compute control for a deterministic system
# ...
# Cost in iteration 0: 0.0008253809036516777
# Final cost : 0.0008252879155379901
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008252879155379901
# Final cost : 0.0008251992999989775
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008251992999989775
# Final cost : 0.0008250546932400024
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008250546932400024
# Final cost : 0.000824658562983624
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015752727606092175
# Final cost : 0.0009247255303794118
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009247255303794118
# Final cost : 0.0009244753545029532
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009244753545029532
# Final cost : 0.0009242298772803853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009242298772803853
# Final cost : 0.0009238736038908915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009238736038908915
# Final cost : 0.0009226915456557821
# -----------------------------------------------
# 5 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.05736626100698284
# Final cost : 0.0010952874257572933
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010952874257572933
# Final cost : 0.001057396690169978
# Compute control for a deterministic system
# Cost in iteration 0: 0.001057396690169978
# Final cost : 0.0010414697555468989
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010414697555468989
# Final cost : 0.0010328923629216757
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010328923629216757
# Final cost : 0.0010304045264048314
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.0043711378872311815
# Final cost : 0.001137545778976779
# Compute control for a deterministic system
# Cost in iteration 0: 0.001137545778976779
# Final cost : 0.0011373155815756334
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011373155815756334
# Final cost : 0.0011371013980915657
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011371013980915657
# Final cost : 0.0011365613815309142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011365613815309142
# Final cost : 0.0011355687627566235
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023041503509754497
# Final cost : 0.0012520747632215592
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012520747632215592
# Final cost : 0.0012517217694697949
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012517217694697949
# Final cost : 0.0012514440955022662
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012514440955022662
# Final cost : 0.0012509581930228067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012509581930228067
# Final cost : 0.0012495812131178609
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.015076732490301583
# Final cost : 0.0013891442490641729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891442490641729
# Final cost : 0.0013846173732527185
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013846173732527185
# Final cost : 0.0013812324291065895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013812324291065895
# Final cost : 0.0013798897641805485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013798897641805485
# Final cost : 0.0013769517719948198
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.01631436093932682
# Final cost : 0.0015689321889474528
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015689321889474528
# Final cost : 0.0015654482012511393
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015654482012511393
# Final cost : 0.001564041866814166
# Compute control for a deterministic system
# Cost in iteration 0: 0.001564041866814166
# Final cost : 0.001561058074545806
# Compute control for a deterministic system
# Cost in iteration 0: 0.001561058074545806
# Final cost : 0.0015578740189372924
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.00909493235956714
# Final cost : 0.001511136067318387
# Compute control for a deterministic system
# Cost in iteration 0: 0.001511136067318387
# Final cost : 0.0015107712376531655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015107712376531655
# Final cost : 0.001510605325601543
# Compute control for a deterministic system
# Cost in iteration 0: 0.001510605325601543
# Final cost : 0.0015102233871259825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015102233871259825
# Final cost : 0.0015093497565334536
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013463162222681188
# Final cost : 0.0013217819146400516
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013217819146400516
# Final cost : 0.0013217693515949237
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013217693515949237
# Final cost : 0.001321757747158381
# Compute control for a deterministic system
# Cost in iteration 0: 0.001321757747158381
# Final cost : 0.0013217342692097964
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013217342692097964
# Final cost : 0.0013216840410263686
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014957504330106917
# Final cost : 0.001151663047405331
# Compute control for a deterministic system
# Cost in iteration 0: 0.001151663047405331
# Final cost : 0.001151632671912304
# Compute control for a deterministic system
# Cost in iteration 0: 0.001151632671912304
# Final cost : 0.0011516075216680484
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011516075216680484
# Final cost : 0.0011515417817591495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011515417817591495
# Final cost : 0.0011514411486432323
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.016453025971530148
# Final cost : 0.0009947075849889258
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009947075849889258
# Final cost : 0.0009945805613259676
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009945805613259676
# Final cost : 0.000994441031099256
# Compute control for a deterministic system
# Cost in iteration 0: 0.000994441031099256
# Final cost : 0.0009937681850781738
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009937681850781738
# Final cost : 0.000993740699814754
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438358616015296
# Final cost : 0.000824703214366831
# Compute control for a deterministic system
# Cost in iteration 0: 0.000824703214366831
# Final cost : 0.0008245517626290922
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008245517626290922
# Final cost : 0.000824400587408504
# Compute control for a deterministic system
# Cost in iteration 0: 0.000824400587408504
# Final cost : 0.0008242628587647444
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008242628587647444
# Final cost : 0.0008240213908857878
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.010840521235064883
# Final cost : 0.0006957881274631995
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006957881274631995
# Final cost : 0.0006957392926472811
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006957392926472811
# Final cost : 0.0006957059419518625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006957059419518625
# Final cost : 0.0006956421140065402
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006956421140065402
# Final cost : 0.000695542523732557
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.011889751109138456
# Final cost : 0.0005804521520635759
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005804521520635759
# Final cost : 0.0005803465890739956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005803465890739956
# Final cost : 0.0005801736795809355
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005801736795809355
# Final cost : 0.0005800080764969988
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005800080764969988
# Final cost : 0.0005797922013067473
# Compute control for a deterministic system
# Cost in iteration 0: 0.00229340737881404
# Final cost : 0.0004759106409350962
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004759106409350962
# Final cost : 0.0004758974543335224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004758974543335224
# Final cost : 0.00047587719963651824
# Compute control for a deterministic system
# Cost in iteration 0: 0.00047587719963651824
# Final cost : 0.00047585249306842905
# Compute control for a deterministic system
# Cost in iteration 0: 0.00047585249306842905
# Final cost : 0.0004758179719461037
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030274299647003403
# Final cost : 0.0003850255183038223
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003850255183038223
# Final cost : 0.0003848301463922617
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003848301463922617
# Final cost : 0.00038470107667272393
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038470107667272393
# Final cost : 0.00038453280611387377
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038453280611387377
# Final cost : 0.0003840482746175281
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008327475735538341
# Final cost : 0.0002874180897411109
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002874180897411109
# Final cost : 0.0002873985311797914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002873985311797914
# Final cost : 0.00028733515410290286
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028733515410290286
# Final cost : 0.00028731220960726906
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028731220960726906
# Final cost : 0.0002872572144970768
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040959977532853235
# Final cost : 0.0002186725615791314
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002186725615791314
# Final cost : 0.0002186545800739936
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002186545800739936
# Final cost : 0.00021864106731169135
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021864106731169135
# Final cost : 0.0002186237860569553
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002186237860569553
# Final cost : 0.00021857635786830894
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004956954656617531
# Final cost : 0.00016019503383651312
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016019503383651312
# Final cost : 0.00016017466788292246
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016017466788292246
# Final cost : 0.00016015631053818642
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016015631053818642
# Final cost : 0.00016013848181821712
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016013848181821712
# Final cost : 0.00016008762842268894
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.000401744574639276
# Final cost : 0.00011130856438471351
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011130856438471351
# Final cost : 0.00011129911844709734
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011129911844709734
# Final cost : 0.00011127522988942749
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011127522988942749
# Final cost : 0.00011126952778358746
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011126952778358746
# Final cost : 0.00011125343813320478
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010557385475946136
# Final cost : 7.234885625203541e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.234885625203541e-05
# Final cost : 7.228553652936219e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.228553652936219e-05
# Final cost : 7.223365520232322e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.223365520232322e-05
# Final cost : 7.217807382331034e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.217807382331034e-05
# Final cost : 7.202243725891616e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035863671168322577
# Final cost : 3.636392516853153e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.636392516853153e-05
# Final cost : 3.6352405030894424e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6352405030894424e-05
# Final cost : 3.634631023683037e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.634631023683037e-05
# Final cost : 3.633796496113589e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.633796496113589e-05
# Final cost : 3.631346247866704e-05
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001855440029247212
# Final cost : 1.6111460686860268e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6111460686860268e-05
# Final cost : 1.611081712183673e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.611081712183673e-05
# Final cost : 1.6110596387507003e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6110596387507003e-05
# Final cost : 1.611032530289258e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.611032530289258e-05
# Final cost : 1.6109519802164105e-05
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 1.9114664835747694e-05
# Final cost : 4.129802592039529e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.129802592039529e-06
# Final cost : 4.129504970058746e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.129504970058746e-06
# Final cost : 4.129275470916156e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.129275470916156e-06
# Final cost : 4.128927337493919e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.128927337493919e-06
# Final cost : 4.128141325457255e-06
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
