# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4659462713939012 
y_init = 0.4876131671862581
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,104], wc.inh[0,104]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.14719457520602167 0.2941562640388582
# 19.071428571428573
# minima =  [ 186  377  568  758  949 1140 1330 1521 1712 1902 2093 2284 2475 2665
#  2856 3047 3237 3428 3619 3809 4000 4191 4381 4572 4763 4954 5144 5335
#  5526 5716 5907]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 2
#       1 results_min = read()
# ----> 2 results_peak = readfile("results_peak_w1.pickle")
#
# Cell In [6], line 14, in readfile(file)
#      13 def readfile(file):
# ---> 14     filehandler = open(file,"rb")
#      15     results_dict = pickle.load(filehandler)
#      16     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results_peak_w1.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(14,21)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.1
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.13610793161336093
# Cost in iteration 200: 0.1258954147863699
# Final cost : 0.1258954147863699
# Compute control for a deterministic system
# Cost in iteration 0: 0.1258954147863699
# Cost in iteration 200: 0.12585780458590515
# Final cost : 0.12585780458590515
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585780458590515
# Cost in iteration 200: 0.12585630600718042
# Final cost : 0.12585630600718042
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630600718042
# Cost in iteration 200: 0.1258563059455688
# Converged in iteration 315 with cost 0.1258563059435224 because of vanishing difference
# Final cost : 0.1258563059435224
# Compute control for a deterministic system
# Cost in iteration 0: 0.1258563059435224
# Converged in iteration 30 with cost 0.12585630594332844 because of step counter
# Final cost : 0.12585630594332844
# Compute control for a deterministic system
# Cost in iteration 0: 0.1438736907220434
# Cost in iteration 200: 0.135540837328879
# Final cost : 0.135540837328879
# Compute control for a deterministic system
# Cost in iteration 0: 0.135540837328879
# Cost in iteration 200: 0.135492947052934
# Final cost : 0.135492947052934
# Compute control for a deterministic system
# Cost in iteration 0: 0.135492947052934
# Cost in iteration 200: 0.13549030962561204
# Final cost : 0.13549030962561204
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030962561204
# Cost in iteration 200: 0.13549030958756653
# Cost in iteration 400: 0.13549030958534045
# Final cost : 0.13549030958534045
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030958534045
# Converged in iteration 10 with cost 0.13549030958531796 because of step counter
# Final cost : 0.13549030958531796
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.1445936551273359
# Cost in iteration 200: 0.14325828908231325
# Final cost : 0.14325828908231325
# Compute control for a deterministic system
# Cost in iteration 0: 0.14325828908231325
# Cost in iteration 200: 0.1432215675964601
# Final cost : 0.1432215675964601
# Compute control for a deterministic system
# Cost in iteration 0: 0.1432215675964601
# Cost in iteration 200: 0.14321898415649034
# Final cost : 0.14321898415649034
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321898415649034
# Cost in iteration 200: 0.14321898408294453
# Cost in iteration 400: 0.14321898407798997
# Final cost : 0.14321898407798997
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321898407798997
# Converged in iteration 67 with cost 0.14321898407776498 because of step counter
# Final cost : 0.14321898407776498
# Compute control for a deterministic system
# Cost in iteration 0: 0.15854664672175145
# Cost in iteration 200: 0.15297921062997924
# Final cost : 0.15297921062997924
# Compute control for a deterministic system
# Cost in iteration 0: 0.15297921062997924
# Cost in iteration 200: 0.15291150228020503
# Final cost : 0.15291150228020503
# Compute control for a deterministic system
# Cost in iteration 0: 0.15291150228020503
# Cost in iteration 200: 0.15290549468266193
# Final cost : 0.15290549468266193
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290549468266193
# Cost in iteration 200: 0.1529054890623176
# Cost in iteration 400: 0.15290548858267852
# Final cost : 0.15290548858267852
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290548858267852
# Cost in iteration 200: 0.15290548854172134
# Cost in iteration 400: 0.15290548853561042
# Converged in iteration 589 with cost 0.15290548853471905 because of step counter
# Final cost : 0.15290548853471905
# Compute control for a deterministic system
# Cost in iteration 0: 0.16706128736612888
# Cost in iteration 200: 0.16270735679863252
# Final cost : 0.16270735679863252
# Compute control for a deterministic system
# Cost in iteration 0: 0.16270735679863252
# Cost in iteration 200: 0.16262831522180174
# Final cost : 0.16262831522180174
# Compute control for a deterministic system
# Cost in iteration 0: 0.16262831522180174
# Cost in iteration 200: 0.16261962388143428
# Final cost : 0.16261962388143428
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261962388143428
# Cost in iteration 200: 0.16261960323264243
# Cost in iteration 400: 0.16261960124981997
# Final cost : 0.16261960124981997
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261960124981997
# Cost in iteration 200: 0.16261960104392473
# Cost in iteration 400: 0.16261960100704156
# Cost in iteration 600: 0.16261960100042136
# Converged in iteration 791 with cost 0.1626196009992333 because of step counter
# Final cost : 0.1626196009992333
# Compute control for a deterministic system
# Cost in iteration 0: 0.1758186392200439
# Cost in iteration 200: 0.1724630603104769
# Final cost : 0.1724630603104769
# Compute control for a deterministic system
# Cost in iteration 0: 0.1724630603104769
# Cost in iteration 200: 0.17237274939914315
# Final cost : 0.17237274939914315
# Compute control for a deterministic system
# Cost in iteration 0: 0.17237274939914315
# Cost in iteration 200: 0.17236390377028074
# Final cost : 0.17236390377028074
# Compute control for a deterministic system
# Cost in iteration 0: 0.17236390377028074
# Cost in iteration 200: 0.17236102726552993
# Cost in iteration 400: 0.1723607141093677
# Final cost : 0.1723607141093677
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723607141093677
# Cost in iteration 200: 0.17236067634484104
# Cost in iteration 400: 0.172360668397238
# Cost in iteration 600: 0.17236066668719463
# Cost in iteration 800: 0.17236066632569189
# Cost in iteration 1000: 0.1723606662488514
# Final cost : 0.1723606662488514
# Compute control for a deterministic system
# Cost in iteration 0: 0.18084992849902917
# Cost in iteration 200: 0.1802470069119979
# Final cost : 0.1802470069119979
# Compute control for a deterministic system
# Cost in iteration 0: 0.1802470069119979
# Cost in iteration 200: 0.1801827098750012
# Final cost : 0.1801827098750012
# Compute control for a deterministic system
# Cost in iteration 0: 0.1801827098750012
# Cost in iteration 200: 0.1801752420604506
# Final cost : 0.1801752420604506
# Compute control for a deterministic system
# Cost in iteration 0: 0.1801752420604506
# Cost in iteration 200: 0.18017302280005837
# Cost in iteration 400: 0.18017269599196134
# Final cost : 0.18017269599196134
# Compute control for a deterministic system
# Cost in iteration 0: 0.18017269599196134
# Cost in iteration 200: 0.1801726509589901
# Cost in iteration 400: 0.18017264013444478
# Cost in iteration 600: 0.18017263753931873
# Cost in iteration 800: 0.18017263691570842
# Cost in iteration 1000: 0.1801726367656746
# Final cost : 0.1801726367656746
# ----------------------------------------------- 1
# cost =  0.1767381338577556
# Compute control for a deterministic system
# Cost in iteration 0: 0.19873200993616083
# Cost in iteration 200: 0.17678262332435601
# Final cost : 0.17678262332435601
# Compute control for a deterministic system
# Cost in iteration 0: 0.17678262332435601
# Cost in iteration 200: 0.1767422442563411
# Final cost : 0.1767422442563411
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767422442563411
# Cost in iteration 200: 0.17673922395679204
# Cost in iteration 400: 0.17673843821296004
# Final cost : 0.17673843821296004
# Compute control for a deterministic system
# Cost in iteration 0: 0.17673843821296004
# Cost in iteration 200: 0.17673823014953113
# Cost in iteration 400: 0.17673816445871265
# Cost in iteration 600: 0.17673814361290008
# Cost in iteration 800: 0.17673813696355728
# Cost in iteration 1000: 0.17673813484783416
# Final cost : 0.17673813484783416
# cost =  0.17236066622812676
# Compute control for a deterministic system
# Cost in iteration 0: 0.22793375417255987
# Cost in iteration 200: 0.18401515868788143
# Final cost : 0.18401515868788143
# Compute control for a deterministic system
# Cost in iteration 0: 0.18401515868788143
# Cost in iteration 200: 0.1839834077462538
# Final cost : 0.1839834077462538
# Compute control for a deterministic system
# Cost in iteration 0: 0.1839834077462538
# Cost in iteration 200: 0.1839806935018661
# Cost in iteration 400: 0.1839798606470483
# Final cost : 0.1839798606470483
# Compute control for a deterministic system
# Cost in iteration 0: 0.1839798606470483
# Cost in iteration 200: 0.1839796365746271
# Cost in iteration 400: 0.1839795591189705
# Cost in iteration 600: 0.18397953216631388
# Cost in iteration 800: 0.18397952272425008
# Cost in iteration 1000: 0.18397951943236768
# Final cost : 0.18397951943236768
# cost =  0.16261960099912134
# Compute control for a deterministic system
# Cost in iteration 0: 0.5087985018254505
# Cost in iteration 200: 0.16265983621322633
# Final cost : 0.16265983621322633
# Compute control for a deterministic system
# Cost in iteration 0: 0.16265983621322633
# Converged in iteration 28 with cost 0.16264079991887323 because of vanishing difference
# Final cost : 0.16264079991887323
# Compute control for a deterministic system
# Cost in iteration 0: 0.16264079991887323
# Cost in iteration 200: 0.16262219007338347
# Cost in iteration 400: 0.16261995745466773
# Final cost : 0.16261995745466773
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261995745466773
# Cost in iteration 200: 0.16261971574996023
# Cost in iteration 400: 0.16261967198633584
# Cost in iteration 600: 0.16261966416973533
# Cost in iteration 800: 0.16261966276533785
# Cost in iteration 1000: 0.16261966251077925
# Final cost : 0.16261966251077925
# cost =  0.15290548853466648
# Compute control for a deterministic system
# Cost in iteration 0: 0.4830775074952029
# Cost in iteration 200: 0.1529371571629653
# Final cost : 0.1529371571629653
# Compute control for a deterministic system
# Cost in iteration 0: 0.1529371571629653
# Cost in iteration 200: 0.15290549116229518
# Final cost : 0.15290549116229518
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290549116229518
# Cost in iteration 200: 0.15290548876095938
# Cost in iteration 400: 0.15290548855520114
# Final cost : 0.15290548855520114
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290548855520114
# Cost in iteration 200: 0.15290548853761288
# Cost in iteration 400: 0.15290548853501204
# Converged in iteration 445 with cost 0.152905488534857 because of vanishing difference
# Final cost : 0.152905488534857
# cost =  0.14321898407765601
# Compute control for a deterministic system
# Cost in iteration 0: 0.4571943133963504
# Cost in iteration 200: 0.1432449920794809
# Final cost : 0.1432449920794809
# Compute control for a deterministic system
# Cost in iteration 0: 0.1432449920794809
# Cost in iteration 200: 0.1432190043192889
# Final cost : 0.1432190043192889
# Compute control for a deterministic system
# Cost in iteration 0: 0.1432190043192889
# Cost in iteration 200: 0.14321900399401827
# Cost in iteration 400: 0.14321900397195098
# Final cost : 0.14321900397195098
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321900397195098
# Converged in iteration 157 with cost 0.14321900397054885 because of step counter
# Final cost : 0.14321900397054885
# cost =  0.13549030958531796
# Compute control for a deterministic system
# Cost in iteration 0: 0.3860694608195675
# Cost in iteration 200: 0.1355010285664433
# Final cost : 0.1355010285664433
# Compute control for a deterministic system
# Cost in iteration 0: 0.1355010285664433
# Cost in iteration 200: 0.13549031167637302
# Final cost : 0.13549031167637302
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549031167637302
# Cost in iteration 200: 0.13549031129757713
# Cost in iteration 400: 0.13549031127791078
# Final cost : 0.13549031127791078
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549031127791078
# Converged in iteration 159 with cost 0.13549031127685718 because of step counter
# Final cost : 0.13549031127685718
# cost =  0.12585630594316582
# Compute control for a deterministic system
# Cost in iteration 0: 0.40996997144858266
# Cost in iteration 200: 0.1258690164790282
# Final cost : 0.1258690164790282
# Compute control for a deterministic system
# Cost in iteration 0: 0.1258690164790282
# Cost in iteration 200: 0.125856331454419
# Final cost : 0.125856331454419
# Compute control for a deterministic system
# Cost in iteration 0: 0.125856331454419
# Cost in iteration 200: 0.12585633098108184
# Cost in iteration 400: 0.12585633096187973
# Final cost : 0.12585633096187973
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585633096187973
# Converged in iteration 98 with cost 0.1258563309612449 because of step counter
# Final cost : 0.1258563309612449
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.12698854609732949
# Cost in iteration 200: 0.12585788464308478
# Final cost : 0.12585788464308478
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585788464308478
# Cost in iteration 200: 0.12585630939646159
# Final cost : 0.12585630939646159
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630939646159
# Cost in iteration 200: 0.12585630594321606
# Final cost : 0.12585630594321606
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630594321606
# Converged in iteration 9 with cost 0.12585630594318692 because of vanishing difference
# Final cost : 0.12585630594318692
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630594318692
# Converged in iteration 15 with cost 0.12585630594317404 because of vanishing difference
# Final cost : 0.12585630594317404
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366045513782976
# Cost in iteration 200: 0.1354924654697553
# Final cost : 0.1354924654697553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1354924654697553
# Cost in iteration 200: 0.13549031599066216
# Final cost : 0.13549031599066216
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549031599066216
# Converged in iteration 199 with cost 0.13549030958528405 because of step counter
# Final cost : 0.13549030958528405
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030958528405
# Converged in iteration 2 with cost 0.13549030958528388 because of step counter
# Final cost : 0.13549030958528388
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030958528388
# Converged in iteration 1 with cost 0.13549030958528388 because of step counter
# Final cost : 0.13549030958528388
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.14430504918200132
# Cost in iteration 200: 0.14322172279488993
# Final cost : 0.14322172279488993
# Compute control for a deterministic system
# Cost in iteration 0: 0.14322172279488993
# Cost in iteration 200: 0.14321899415674988
# Final cost : 0.14321899415674988
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321899415674988
# Cost in iteration 200: 0.14321898407791786
# Final cost : 0.14321898407791786
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321898407791786
# Converged in iteration 34 with cost 0.14321898407777417 because of step counter
# Final cost : 0.14321898407777417
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321898407777417
# Converged in iteration 1 with cost 0.14321898407777417 because of step counter
# Final cost : 0.14321898407777417
# Compute control for a deterministic system
# Cost in iteration 0: 0.15393688433311375
# Cost in iteration 200: 0.15290915903364752
# Final cost : 0.15290915903364752
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290915903364752
# Cost in iteration 200: 0.1529055063613167
# Final cost : 0.1529055063613167
# Compute control for a deterministic system
# Cost in iteration 0: 0.1529055063613167
# Cost in iteration 200: 0.152905488535261
# Final cost : 0.152905488535261
# Compute control for a deterministic system
# Cost in iteration 0: 0.152905488535261
# Converged in iteration 104 with cost 0.15290548853473743 because of step counter
# Final cost : 0.15290548853473743
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290548853473743
# Converged in iteration 29 with cost 0.1529054885346824 because of step counter
# Final cost : 0.1529054885346824
# Compute control for a deterministic system
# Cost in iteration 0: 0.16357454920568426
# Cost in iteration 200: 0.1626244823178023
# Final cost : 0.1626244823178023
# Compute control for a deterministic system
# Cost in iteration 0: 0.1626244823178023
# Cost in iteration 200: 0.1626196325738409
# Final cost : 0.1626196325738409
# Compute control for a deterministic system
# Cost in iteration 0: 0.1626196325738409
# Cost in iteration 200: 0.16261960099968684
# Final cost : 0.16261960099968684
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261960099968684
# Converged in iteration 107 with cost 0.16261960099918132 because of step counter
# Final cost : 0.16261960099918132
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261960099918132
# Converged in iteration 1 with cost 0.16261960099918132 because of step counter
# Final cost : 0.16261960099918132
# Compute control for a deterministic system
# Cost in iteration 0: 0.17322384259874113
# Cost in iteration 200: 0.17236704712970569
# Final cost : 0.17236704712970569
# Compute control for a deterministic system
# Cost in iteration 0: 0.17236704712970569
# Cost in iteration 200: 0.1723607217023275
# Final cost : 0.1723607217023275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723607217023275
# Converged in iteration 191 with cost 0.1723606662280806 because of step counter
# Final cost : 0.1723606662280806
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723606662280806
# Converged in iteration 1 with cost 0.1723606662280806 because of step counter
# Final cost : 0.1723606662280806
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723606662280806
# Converged in iteration 1 with cost 0.1723606662280806 because of step counter
# Final cost : 0.1723606662280806
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.17743719882084674
# Cost in iteration 200: 0.1767444172969437
# Final cost : 0.1767444172969437
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767444172969437
# Cost in iteration 200: 0.17673825696852016
# Final cost : 0.17673825696852016
# Compute control for a deterministic system
# Cost in iteration 0: 0.17673825696852016
# Cost in iteration 200: 0.1767381350339962
# Final cost : 0.1767381350339962
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767381350339962
# Cost in iteration 200: 0.17673813408518904
# Cost in iteration 400: 0.17673813391656235
# Final cost : 0.17673813391656235
# Compute control for a deterministic system
# Cost in iteration 0: 0.17673813391656235
# Cost in iteration 200: 0.1767381338756229
# Cost in iteration 400: 0.1767381338627868
# Cost in iteration 600: 0.17673813385871953
# Converged in iteration 713 with cost 0.1767381338578165 because of step counter
# Final cost : 0.1767381338578165
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810818677470583
# Cost in iteration 200: 0.12585655256342926
# Final cost : 0.12585655256342926
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585655256342926
# Cost in iteration 200: 0.12585630984922178
# Final cost : 0.12585630984922178
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630984922178
# Cost in iteration 200: 0.12585630594321867
# Final cost : 0.12585630594321867
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630594321867
# Converged in iteration 4 with cost 0.12585630594319364 because of step counter
# Final cost : 0.12585630594319364
# Compute control for a deterministic system
# Cost in iteration 0: 0.12585630594319364
# Converged in iteration 2 with cost 0.1258563059431925 because of step counter
# Final cost : 0.1258563059431925
# Compute control for a deterministic system
# Cost in iteration 0: 0.22778528248288527
# Cost in iteration 200: 0.13549065501798893
# Final cost : 0.13549065501798893
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549065501798893
# Cost in iteration 200: 0.13549031648224888
# Final cost : 0.13549031648224888
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549031648224888
# Cost in iteration 200: 0.13549030958538538
# Final cost : 0.13549030958538538
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030958538538
# Converged in iteration 7 with cost 0.13549030958537367 because of step counter
# Final cost : 0.13549030958537367
# Compute control for a deterministic system
# Cost in iteration 0: 0.13549030958537367
# Converged in iteration 1 with cost 0.13549030958537367 because of step counter
# Final cost : 0.13549030958537367
# Compute control for a deterministic system
# Cost in iteration 0: 0.24363392561910752
# Cost in iteration 200: 0.14321942623992484
# Final cost : 0.14321942623992484
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321942623992484
# Cost in iteration 200: 0.14321899431458102
# Final cost : 0.14321899431458102
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321899431458102
# Cost in iteration 200: 0.14321898407781863
# Final cost : 0.14321898407781863
# Compute control for a deterministic system
# Cost in iteration 0: 0.14321898407781863
# Converged in iteration 10 with cost 0.143218984077784 because of step counter
# Final cost : 0.143218984077784
# Compute control for a deterministic system
# Cost in iteration 0: 0.143218984077784
# Converged in iteration 12 with cost 0.14321898407775205 because of step counter
# Final cost : 0.14321898407775205
# Compute control for a deterministic system
# Cost in iteration 0: 0.2635255855311487
# Cost in iteration 200: 0.15290607729641076
# Final cost : 0.15290607729641076
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290607729641076
# Cost in iteration 200: 0.15290550438930542
# Final cost : 0.15290550438930542
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290550438930542
# Converged in iteration 166 with cost 0.15290548857757555 because of vanishing difference
# Final cost : 0.15290548857757555
# Compute control for a deterministic system
# Cost in iteration 0: 0.15290548857757555
# Cost in iteration 200: 0.152905488538236
# Cost in iteration 400: 0.1529054885348963
# Final cost : 0.1529054885348963
# Compute control for a deterministic system
# Cost in iteration 0: 0.1529054885348963
# Converged in iteration 38 with cost 0.15290548853478975 because of step counter
# Final cost : 0.15290548853478975
# Compute control for a deterministic system
# Cost in iteration 0: 0.28347417685543097
# Cost in iteration 200: 0.16262036871972527
# Final cost : 0.16262036871972527
# Compute control for a deterministic system
# Cost in iteration 0: 0.16262036871972527
# Cost in iteration 200: 0.16261962504882388
# Final cost : 0.16261962504882388
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261962504882388
# Cost in iteration 200: 0.16261960099911174
# Final cost : 0.16261960099911174
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261960099911174
# Converged in iteration 14 with cost 0.16261960099907424 because of step counter
# Final cost : 0.16261960099907424
# Compute control for a deterministic system
# Cost in iteration 0: 0.16261960099907424
# Converged in iteration 3 with cost 0.16261960099907338 because of step counter
# Final cost : 0.16261960099907338
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.30349354158168923
# Cost in iteration 200: 0.1723616506988886
# Final cost : 0.1723616506988886
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723616506988886
# Cost in iteration 200: 0.17236070024920253
# Final cost : 0.17236070024920253
# Compute control for a deterministic system
# Cost in iteration 0: 0.17236070024920253
# Cost in iteration 200: 0.17236066622840712
# Final cost : 0.17236066622840712
# Compute control for a deterministic system
# Cost in iteration 0: 0.17236066622840712
# Converged in iteration 43 with cost 0.1723606662282532 because of step counter
# Final cost : 0.1723606662282532
# Compute control for a deterministic system
# Cost in iteration 0: 0.1723606662282532
# Converged in iteration 21 with cost 0.17236066622822105 because of step counter
# Final cost : 0.17236066622822105
# Compute control for a deterministic system
# Cost in iteration 0: 0.3326824224520717
# Cost in iteration 200: 0.1767395631934391
# Final cost : 0.1767395631934391
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767395631934391
# Cost in iteration 200: 0.1767382071786065
# Final cost : 0.1767382071786065
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767382071786065
# Cost in iteration 200: 0.17673813787408343
# Final cost : 0.17673813787408343
# Compute control for a deterministic system
# Cost in iteration 0: 0.17673813787408343
# Cost in iteration 200: 0.17673813493077073
# Cost in iteration 400: 0.1767381341482905
# Final cost : 0.1767381341482905
# Compute control for a deterministic system
# Cost in iteration 0: 0.1767381341482905
# Cost in iteration 200: 0.1767381339493301
# Cost in iteration 400: 0.1767381338861194
# Cost in iteration 600: 0.17673813386618548
# Cost in iteration 800: 0.17673813385979262
# Cost in iteration 1000: 0.1767381338577699
# Final cost : 0.1767381338577699

# %%
save(results_min)
