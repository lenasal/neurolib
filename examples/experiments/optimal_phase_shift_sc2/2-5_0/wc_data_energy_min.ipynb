# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4659462713939012 
y_init = 0.4876131671862581
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,104], wc.inh[0,104]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# minima =  [ 186  377  568  758  949 1140 1330 1521 1712 1902 2093 2284 2475 2665
#  2856 3047 3237 3428 3619 3809 4000 4191 4381 4572 4763 4954 5144 5335
#  5526 5716 5907]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95*np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06418081547537782
# Final cost : 0.015709016620599123
# Compute control for a deterministic system
# Cost in iteration 0: 0.015709016620599123
# Final cost : 4.623326373297712e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.623326373297712e-05
# Final cost : 4.419859941882422e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.419859941882422e-05
# Final cost : 4.376130349290379e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.376130349290379e-05
# Final cost : 4.370869955135313e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.370869955135313e-05
# Final cost : 4.368376836713666e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.24852957300085682
# Final cost : 0.034359621618743
# Compute control for a deterministic system
# Cost in iteration 0: 0.034359621618743
# Final cost : 0.00019335922552940555
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019335922552940555
# Final cost : 0.00017909385938495425
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017909385938495425
# Final cost : 0.00017682365882458294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017682365882458294
# Final cost : 0.0001756542473744311
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001756542473744311
# Final cost : 0.0001751605314254661
# Compute control for a deterministic system
# Cost in iteration 0: 0.4691500918716056
# Final cost : 0.029949176282546234
# Compute control for a deterministic system
# Cost in iteration 0: 0.029949176282546234
# Final cost : 0.0003903783474580511
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003903783474580511
# Final cost : 0.0003543171290611347
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003543171290611347
# Final cost : 0.00034785369784613794
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034785369784613794
# Final cost : 0.00034497948746775825
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034497948746775825
# Final cost : 0.00034393010259060446
# Compute control for a deterministic system
# Cost in iteration 0: 0.8151920053586257
# Final cost : 0.008747266308081836
# Compute control for a deterministic system
# Cost in iteration 0: 0.008747266308081836
# Final cost : 0.0007392713915574011
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007392713915574011
# Final cost : 0.000656898874964775
# Compute control for a deterministic system
# Cost in iteration 0: 0.000656898874964775
# Final cost : 0.000646800942080137
# Compute control for a deterministic system
# Cost in iteration 0: 0.000646800942080137
# Final cost : 0.0006375110215986025
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006375110215986025
# Final cost : 0.0006344474580515073
# Compute control for a deterministic system
# Cost in iteration 0: 1.2145533345474417
# Final cost : 0.0034516611521562737
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034516611521562737
# Final cost : 0.0011934579717963712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011934579717963712
# Final cost : 0.00107690935003159
# Compute control for a deterministic system
# Cost in iteration 0: 0.00107690935003159
# Final cost : 0.0010390560940855315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010390560940855315
# Final cost : 0.001017457584528571
# Compute control for a deterministic system
# Cost in iteration 0: 0.001017457584528571
# Final cost : 0.0010121924001402268
# Compute control for a deterministic system
# Cost in iteration 0: 1.6428062792383415
# Final cost : 0.053593971300569886
# Compute control for a deterministic system
# Cost in iteration 0: 0.053593971300569886
# Final cost : 0.0017614430263539883
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017614430263539883
# Final cost : 0.0015552152105608981
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015552152105608981
# Final cost : 0.001493704697412424
# Compute control for a deterministic system
# Cost in iteration 0: 0.001493704697412424
# Final cost : 0.001478699298034356
# Compute control for a deterministic system
# Cost in iteration 0: 0.001478699298034356
# Final cost : 0.0014747041129935983
# Compute control for a deterministic system
# Cost in iteration 0: 1.992225848802756
# Final cost : 0.16473006309174523
# Compute control for a deterministic system
# Cost in iteration 0: 0.16473006309174523
# Final cost : 0.0022952947277081037
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022952947277081037
# Final cost : 0.002034882393655967
# Compute control for a deterministic system
# Cost in iteration 0: 0.002034882393655967
# Final cost : 0.0019506464924160716
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019506464924160716
# Final cost : 0.0019044634980661238
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019044634980661238
# Final cost : 0.0019039618879649722
# Compute control for a deterministic system
# Cost in iteration 0: 2.422907353351034
# Final cost : 0.4150019816410444
# Compute control for a deterministic system
# Cost in iteration 0: 0.4150019816410444
# Final cost : 0.003069798906208594
# Compute control for a deterministic system
# Cost in iteration 0: 0.003069798906208594
# Final cost : 0.0027386549901890034
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027386549901890034
# Final cost : 0.00261033052502868
# Compute control for a deterministic system
# Cost in iteration 0: 0.00261033052502868
# Final cost : 0.0025233971457218384
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025233971457218384
# Final cost : 0.0025134699108984343
# Compute control for a deterministic system
# Cost in iteration 0: 2.833080546483485
# Final cost : 0.7970687136938206
# Compute control for a deterministic system
# Cost in iteration 0: 0.7970687136938206
# Final cost : 0.003976716428938465
# Compute control for a deterministic system
# Cost in iteration 0: 0.003976716428938465
# Final cost : 0.003482254325341886
# Compute control for a deterministic system
# Cost in iteration 0: 0.003482254325341886
# Final cost : 0.0032968510728743567
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032968510728743567
# Final cost : 0.003215802849517424
# Compute control for a deterministic system
# Cost in iteration 0: 0.003215802849517424
# Final cost : 0.003205163024359183
# Compute control for a deterministic system
# Cost in iteration 0: 3.2104005519765297
# Final cost : 1.299575849675834
# Compute control for a deterministic system
# Cost in iteration 0: 1.299575849675834
# Final cost : 0.005028704352740956
# Compute control for a deterministic system
# Cost in iteration 0: 0.005028704352740956
# Final cost : 0.00431353269699555
# Compute control for a deterministic system
# Cost in iteration 0: 0.00431353269699555
# Final cost : 0.004119364292028714
# Compute control for a deterministic system
# Cost in iteration 0: 0.004119364292028714
# Final cost : 0.004012953974242584
# Compute control for a deterministic system
# Cost in iteration 0: 0.004012953974242584
# Final cost : 0.003982324111903012
# Compute control for a deterministic system
# Cost in iteration 0: 3.482099094061679
# Final cost : 1.7663164367961108
# Compute control for a deterministic system
# Cost in iteration 0: 1.7663164367961108
# Final cost : 0.005980463716808688
# Compute control for a deterministic system
# Cost in iteration 0: 0.005980463716808688
# Final cost : 0.005057682535347936
# Compute control for a deterministic system
# Cost in iteration 0: 0.005057682535347936
# Final cost : 0.004757520004131815
# Compute control for a deterministic system
# Cost in iteration 0: 0.004757520004131815
# Final cost : 0.004687898225692387
# Compute control for a deterministic system
# Cost in iteration 0: 0.004687898225692387
# Final cost : 0.004670021138454775
# Compute control for a deterministic system
# Cost in iteration 0: 3.7787460480385064
# Final cost : 2.385491801119907
# Compute control for a deterministic system
# Cost in iteration 0: 2.385491801119907
# Final cost : 0.007314017552327719
# Compute control for a deterministic system
# Cost in iteration 0: 0.007314017552327719
# Final cost : 0.006069372884490606
# Compute control for a deterministic system
# Cost in iteration 0: 0.006069372884490606
# Final cost : 0.005785523858475726
# Compute control for a deterministic system
# Cost in iteration 0: 0.005785523858475726
# Final cost : 0.005640893733039129
# Compute control for a deterministic system
# Cost in iteration 0: 0.005640893733039129
# Final cost : 0.005607057130337877
# Compute control for a deterministic system
# Cost in iteration 0: 4.025516129922814
# Final cost : 2.98258822501585
# Compute control for a deterministic system
# Cost in iteration 0: 2.98258822501585
# Final cost : 0.00881861291025159
# Compute control for a deterministic system
# Cost in iteration 0: 0.00881861291025159
# Final cost : 0.007183220037043322
# Compute control for a deterministic system
# Cost in iteration 0: 0.007183220037043322
# Final cost : 0.0068051804533122194
# Compute control for a deterministic system
# Cost in iteration 0: 0.0068051804533122194
# Final cost : 0.006645621338304564
# Compute control for a deterministic system
# Cost in iteration 0: 0.006645621338304564
# Final cost : 0.006638858241853332
# Compute control for a deterministic system
# Cost in iteration 0: 4.22392311844762
# Final cost : 3.4986701615205327
# Compute control for a deterministic system
# Cost in iteration 0: 3.4986701615205327
# Final cost : 0.010509722585350172
# Compute control for a deterministic system
# Cost in iteration 0: 0.010509722585350172
# Final cost : 0.008390920186020723
# Compute control for a deterministic system
# Cost in iteration 0: 0.008390920186020723
# Final cost : 0.008016139972606674
# Compute control for a deterministic system
# Cost in iteration 0: 0.008016139972606674
# Final cost : 0.007808200339151459
# Compute control for a deterministic system
# Cost in iteration 0: 0.007808200339151459
# Final cost : 0.007770453355264441
# Compute control for a deterministic system
# Cost in iteration 0: 4.378216475856057
# Final cost : 3.9029882856515177
# Compute control for a deterministic system
# Cost in iteration 0: 3.9029882856515177
# Final cost : 0.012400471337239139
# Compute control for a deterministic system
# Cost in iteration 0: 0.012400471337239139
# Final cost : 0.009736531263099403
# Compute control for a deterministic system
# Cost in iteration 0: 0.009736531263099403
# Final cost : 0.009240055618155964
# Compute control for a deterministic system
# Cost in iteration 0: 0.009240055618155964
# Final cost : 0.009079788496394101
# Compute control for a deterministic system
# Cost in iteration 0: 0.009079788496394101
# Final cost : 0.008995047025556667
# Compute control for a deterministic system
# Cost in iteration 0: 4.473467033896257
# Final cost : 4.14616896450911
# Compute control for a deterministic system
# Cost in iteration 0: 4.14616896450911
# Final cost : 0.014066229822313765
# Compute control for a deterministic system
# Cost in iteration 0: 0.014066229822313765
# Final cost : 0.010888205640046444
# Compute control for a deterministic system
# Cost in iteration 0: 0.010888205640046444
# Final cost : 0.010350598944841086
# Compute control for a deterministic system
# Cost in iteration 0: 0.010350598944841086
# Final cost : 0.01011055408370446
# Compute control for a deterministic system
# Cost in iteration 0: 0.01011055408370446
# Final cost : 0.010037557105209125
# Compute control for a deterministic system
# Cost in iteration 0: 4.561662225898966
# Final cost : 4.3652977180473735
# Compute control for a deterministic system
# Cost in iteration 0: 4.3652977180473735
# Final cost : 0.016356563768426754
# Compute control for a deterministic system
# Cost in iteration 0: 0.016356563768426754
# Final cost : 0.012428106246321177
# Compute control for a deterministic system
# Cost in iteration 0: 0.012428106246321177
# Final cost : 0.011783330126805918
# Compute control for a deterministic system
# Cost in iteration 0: 0.011783330126805918
# Final cost : 0.011521127950483207
# Compute control for a deterministic system
# Cost in iteration 0: 0.011521127950483207
# Final cost : 0.01142901515725352
# Compute control for a deterministic system
# Cost in iteration 0: 4.619640296735433
# Final cost : 4.510140026246512
# Compute control for a deterministic system
# Cost in iteration 0: 4.510140026246512
# Final cost : 0.01889870371804868
# Compute control for a deterministic system
# Cost in iteration 0: 0.01889870371804868
# Final cost : 0.014075658700334115
# Compute control for a deterministic system
# Cost in iteration 0: 0.014075658700334115
# Final cost : 0.013309250649389778
# Compute control for a deterministic system
# Cost in iteration 0: 0.013309250649389778
# Final cost : 0.013011383517588538
# Compute control for a deterministic system
# Cost in iteration 0: 0.013011383517588538
# Final cost : 0.01291327668300078
# Compute control for a deterministic system
# Cost in iteration 0: 4.6506520261900794
# Final cost : 4.597617869685914
# Compute control for a deterministic system
# Cost in iteration 0: 4.597617869685914
# Final cost : 0.021720688566587328
# Compute control for a deterministic system
# Cost in iteration 0: 0.021720688566587328
# Final cost : 0.015850924746226028
# Compute control for a deterministic system
# Cost in iteration 0: 0.015850924746226028
# Final cost : 0.01500685619798411
# Compute control for a deterministic system
# Cost in iteration 0: 0.01500685619798411
# Final cost : 0.014655197142545586
# Compute control for a deterministic system
# Cost in iteration 0: 0.014655197142545586
# Final cost : 0.014499707216740005
# Compute control for a deterministic system
# Cost in iteration 0: 4.657424221472922
# Final cost : 4.633510338305412
# Compute control for a deterministic system
# Cost in iteration 0: 4.633510338305412
# Final cost : 0.024205399207730367
# Compute control for a deterministic system
# Cost in iteration 0: 0.024205399207730367
# Final cost : 0.01732058147151216
# Compute control for a deterministic system
# Cost in iteration 0: 0.01732058147151216
# Final cost : 0.01612884026726462
# Compute control for a deterministic system
# Cost in iteration 0: 0.01612884026726462
# Final cost : 0.015936935329844346
# Compute control for a deterministic system
# Cost in iteration 0: 0.015936935329844346
# Final cost : 0.015824704559808986
# Compute control for a deterministic system
# Cost in iteration 0: 4.644082107970136
# Final cost : 4.639668740611367
# Compute control for a deterministic system
# Cost in iteration 0: 4.639668740611367
# Final cost : 0.02766157314347253
# Compute control for a deterministic system
# Cost in iteration 0: 0.02766157314347253
# Final cost : 0.01934603020087982
# Compute control for a deterministic system
# Cost in iteration 0: 0.01934603020087982
# Final cost : 0.01823766340446208
# Compute control for a deterministic system
# Cost in iteration 0: 0.01823766340446208
# Final cost : 0.017607633715626417
# Compute control for a deterministic system
# Cost in iteration 0: 0.017607633715626417
# Final cost : 0.017562696686279
# Compute control for a deterministic system
# Cost in iteration 0: 4.606262966869659
# Final cost : 4.60142709584653
# Compute control for a deterministic system
# Cost in iteration 0: 4.60142709584653
# Final cost : 0.018190597901126863
# Compute control for a deterministic system
# Cost in iteration 0: 0.018190597901126863
# Final cost : 0.013627616267199074
# Compute control for a deterministic system
# Cost in iteration 0: 0.013627616267199074
# Final cost : 0.012839821408924501
# Compute control for a deterministic system
# Cost in iteration 0: 0.012839821408924501
# Final cost : 0.012366379367370941
# Compute control for a deterministic system
# Cost in iteration 0: 0.012366379367370941
# Final cost : 0.012318949996561262
# Compute control for a deterministic system
# Cost in iteration 0: 4.542428746950768
# Final cost : 4.510032591821062
# Compute control for a deterministic system
# Cost in iteration 0: 4.510032591821062
# Final cost : 0.015721323470295354
# Compute control for a deterministic system
# Cost in iteration 0: 0.015721323470295354
# Final cost : 0.01203151925103624
# Compute control for a deterministic system
# Cost in iteration 0: 0.01203151925103624
# Final cost : 0.011397854233162148
# Compute control for a deterministic system
# Cost in iteration 0: 0.011397854233162148
# Final cost : 0.011040300099780463
# Compute control for a deterministic system
# Cost in iteration 0: 0.011040300099780463
# Final cost : 0.010957740699055139
# Compute control for a deterministic system
# Cost in iteration 0: 4.4706045426997445
# Final cost : 4.386602356182962
# Compute control for a deterministic system
# Cost in iteration 0: 4.386602356182962
# Final cost : 0.013978820332025016
# Compute control for a deterministic system
# Cost in iteration 0: 0.013978820332025016
# Final cost : 0.010876272798602355
# Compute control for a deterministic system
# Cost in iteration 0: 0.010876272798602355
# Final cost : 0.010256952005071858
# Compute control for a deterministic system
# Cost in iteration 0: 0.010256952005071858
# Final cost : 0.009980897642255822
# Compute control for a deterministic system
# Cost in iteration 0: 0.009980897642255822
# Final cost : 0.009914399975260947
# Compute control for a deterministic system
# Cost in iteration 0: 4.35112072020636
# Final cost : 4.1458383382674695
# Compute control for a deterministic system
# Cost in iteration 0: 4.1458383382674695
# Final cost : 0.011999719169462929
# Compute control for a deterministic system
# Cost in iteration 0: 0.011999719169462929
# Final cost : 0.00951842078952965
# Compute control for a deterministic system
# Cost in iteration 0: 0.00951842078952965
# Final cost : 0.009002249942556193
# Compute control for a deterministic system
# Cost in iteration 0: 0.009002249942556193
# Final cost : 0.008740235578167721
# Compute control for a deterministic system
# Cost in iteration 0: 0.008740235578167721
# Final cost : 0.008683236211722853
# Compute control for a deterministic system
# Cost in iteration 0: 4.193418862939608
# Final cost : 3.7782442212840515
# Compute control for a deterministic system
# Cost in iteration 0: 3.7782442212840515
# Final cost : 0.010211291893329302
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211291893329302
# Final cost : 0.00825805946974784
# Compute control for a deterministic system
# Cost in iteration 0: 0.00825805946974784
# Final cost : 0.007841586846953996
# Compute control for a deterministic system
# Cost in iteration 0: 0.007841586846953996
# Final cost : 0.007574123123547606
# Compute control for a deterministic system
# Cost in iteration 0: 0.007574123123547606
# Final cost : 0.007528390372832382
# Compute control for a deterministic system
# Cost in iteration 0: 3.9916110253614416
# Final cost : 3.2655017179035495
# Compute control for a deterministic system
# Cost in iteration 0: 3.2655017179035495
# Final cost : 0.008597411865282702
# Compute control for a deterministic system
# Cost in iteration 0: 0.008597411865282702
# Final cost : 0.007081661937842508
# Compute control for a deterministic system
# Cost in iteration 0: 0.007081661937842508
# Final cost : 0.006731416395690229
# Compute control for a deterministic system
# Cost in iteration 0: 0.006731416395690229
# Final cost : 0.0065068501003272715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0065068501003272715
# Final cost : 0.006451068146536598
# Compute control for a deterministic system
# Cost in iteration 0: 3.741049569859334
# Final cost : 2.63259905868573
# Compute control for a deterministic system
# Cost in iteration 0: 2.63259905868573
# Final cost : 0.007146043564476241
# Compute control for a deterministic system
# Cost in iteration 0: 0.007146043564476241
# Final cost : 0.005993749608370329
# Compute control for a deterministic system
# Cost in iteration 0: 0.005993749608370329
# Final cost : 0.00569786711158763
# Compute control for a deterministic system
# Cost in iteration 0: 0.00569786711158763
# Final cost : 0.005494428959735811
# Compute control for a deterministic system
# Cost in iteration 0: 0.005494428959735811
# Final cost : 0.005461459404212222
# Compute control for a deterministic system
# Cost in iteration 0: 3.5044376717313455
# Final cost : 2.0870682674862957
# Compute control for a deterministic system
# Cost in iteration 0: 2.0870682674862957
# Final cost : 0.0060970262007202895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060970262007202895
# Final cost : 0.00519132058639084
# Compute control for a deterministic system
# Cost in iteration 0: 0.00519132058639084
# Final cost : 0.004931726608242468
# Compute control for a deterministic system
# Cost in iteration 0: 0.004931726608242468
# Final cost : 0.004753893727019216
# Compute control for a deterministic system
# Cost in iteration 0: 0.004753893727019216
# Final cost : 0.004727438851838393
# Compute control for a deterministic system
# Cost in iteration 0: 3.1659488142670575
# Final cost : 1.4299170091703963
# Compute control for a deterministic system
# Cost in iteration 0: 1.4299170091703963
# Final cost : 0.004916343346527264
# Compute control for a deterministic system
# Cost in iteration 0: 0.004916343346527264
# Final cost : 0.0042666965081710135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042666965081710135
# Final cost : 0.00405225760846035
# Compute control for a deterministic system
# Cost in iteration 0: 0.00405225760846035
# Final cost : 0.0039126642307562645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039126642307562645
# Final cost : 0.003882508238965846
# Compute control for a deterministic system
# Cost in iteration 0: 2.787100226704374
# Final cost : 0.8682023221155262
# Compute control for a deterministic system
# Cost in iteration 0: 0.8682023221155262
# Final cost : 0.003875505221388138
# Compute control for a deterministic system
# Cost in iteration 0: 0.003875505221388138
# Final cost : 0.0033956389212789415
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033956389212789415
# Final cost : 0.0031825519662053202
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031825519662053202
# Final cost : 0.0031343752868212725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031343752868212725
# Final cost : 0.0031187029784375676
# Compute control for a deterministic system
# Cost in iteration 0: 2.378943159058334
# Final cost : 0.44502542791460187
# Compute control for a deterministic system
# Cost in iteration 0: 0.44502542791460187
# Final cost : 0.00297347958297652
# Compute control for a deterministic system
# Cost in iteration 0: 0.00297347958297652
# Final cost : 0.002627408686052784
# Compute control for a deterministic system
# Cost in iteration 0: 0.002627408686052784
# Final cost : 0.0024953218299206712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024953218299206712
# Final cost : 0.0024499403903484305
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024499403903484305
# Final cost : 0.002436744888021412
# Compute control for a deterministic system
# Cost in iteration 0: 2.0397205757223102
# Final cost : 0.21525317422716622
# Compute control for a deterministic system
# Cost in iteration 0: 0.21525317422716622
# Final cost : 0.002349774273808329
# Compute control for a deterministic system
# Cost in iteration 0: 0.002349774273808329
# Final cost : 0.0020858630483923503
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020858630483923503
# Final cost : 0.0019879652369813087
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019879652369813087
# Final cost : 0.001959364239765425
# Compute control for a deterministic system
# Cost in iteration 0: 0.001959364239765425
# Converged in iteration 761 with cost 0.0019505712745745243 because of step counter
# Final cost : 0.0019505712745745243
# Compute control for a deterministic system
# Cost in iteration 0: 1.6099663975634053
# Final cost : 0.054080276529636484
# Compute control for a deterministic system
# Cost in iteration 0: 0.054080276529636484
# Final cost : 0.0016853960336646967
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016853960336646967
# Final cost : 0.0015090720380573357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015090720380573357
# Final cost : 0.0014342570922158111
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014342570922158111
# Final cost : 0.0014220996190649567
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014220996190649567
# Converged in iteration 869 with cost 0.0014177315341141806 because of step counter
# Final cost : 0.0014177315341141806
# Compute control for a deterministic system
# Cost in iteration 0: 1.186849988372671
# Final cost : 0.0032848762296864126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032848762296864126
# Final cost : 0.0011379674649611739
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011379674649611739
# Final cost : 0.0010336528463908941
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010336528463908941
# Final cost : 0.0009733990657758955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009733990657758955
# Final cost : 0.0009701102822465674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009701102822465674
# Final cost : 0.000968768361916804
# Compute control for a deterministic system
# Cost in iteration 0: 0.7915080297081456
# Final cost : 0.010607726535568665
# Compute control for a deterministic system
# Cost in iteration 0: 0.010607726535568665
# Final cost : 0.0007022487870395033
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007022487870395033
# Final cost : 0.0006253868953791965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006253868953791965
# Final cost : 0.0006106554421255854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006106554421255854
# Final cost : 0.0006061696105847432
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006061696105847432
# Final cost : 0.0006043334946111315
# Compute control for a deterministic system
# Cost in iteration 0: 0.5128543975553773
# Final cost : 0.028773318836681196
# Compute control for a deterministic system
# Cost in iteration 0: 0.028773318836681196
# Final cost : 0.0004263993398086976
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004263993398086976
# Final cost : 0.0003859842050109237
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003859842050109237
# Final cost : 0.0003782806140802986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003782806140802986
# Final cost : 0.0003752907903792988
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003752907903792988
# Final cost : 0.00037403249628596415
# Compute control for a deterministic system
# Cost in iteration 0: 0.2342034701617024
# Final cost : 0.034937735792425255
# Compute control for a deterministic system
# Cost in iteration 0: 0.034937735792425255
# Final cost : 0.0001798105928386238
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001798105928386238
# Final cost : 0.00016664649125042505
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016664649125042505
# Final cost : 0.00016443737706891255
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016443737706891255
# Final cost : 0.0001635595882736921
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001635595882736921
# Final cost : 0.00016316831857088294
# Compute control for a deterministic system
# Cost in iteration 0: 0.0566879588437638
# Final cost : 0.01441694052338119
# Compute control for a deterministic system
# Cost in iteration 0: 0.01441694052338119
# Final cost : 4.047985172977718e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.047985172977718e-05
# Final cost : 3.87551479300699e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.87551479300699e-05
# Final cost : 3.841763795938516e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.841763795938516e-05
# Final cost : 3.8375764146286494e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.8375764146286494e-05
# Final cost : 3.835651505069983e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024044058732010062
# Final cost : 7.178475742620921e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.178475742620921e-05
# Final cost : 1.6645049431320986e-07
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0916670378604408
# Final cost : 0.0001806974034428293
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001806974034428293
# Final cost : 0.00017621162831559496
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017621162831559496
# Final cost : 0.0001755604786434083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001755604786434083
# Final cost : 0.0001752793574600671
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001752793574600671
# Final cost : 0.0001751546188686681
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.011600468242293539
# Final cost : 0.00034588352088176194
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034588352088176194
# Final cost : 0.00034439483922619877
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034439483922619877
# Final cost : 0.00034407873921833454
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034407873921833454
# Final cost : 0.00034397368468698817
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034397368468698817
# Final cost : 0.00034392335592977604
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.008346464362043051
# Final cost : 0.0006389644583708705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006389644583708705
# Final cost : 0.0006357653131927
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006357653131927
# Final cost : 0.0006348781211619713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006348781211619713
# Final cost : 0.000634583375334733
# Compute control for a deterministic system
# Cost in iteration 0: 0.000634583375334733
# Final cost : 0.0006344472592432176
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010359469427699323
# Final cost : 0.0010198414596690867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010198414596690867
# Final cost : 0.0010152261587208333
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010152261587208333
# Final cost : 0.0010133829132200063
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010133829132200063
# Final cost : 0.0010125490468276713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010125490468276713
# Converged in iteration 713 with cost 0.0010121922122012204 because of step counter
# Final cost : 0.0010121922122012204
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.19702925000924987
# Final cost : 0.0015035731340947154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015035731340947154
# Final cost : 0.0014806669729186504
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014806669729186504
# Final cost : 0.0014780025784325525
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014780025784325525
# Final cost : 0.0014755796079752833
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014755796079752833
# Final cost : 0.0014747068766312371
# Compute control for a deterministic system
# Cost in iteration 0: 0.010621560720227408
# Final cost : 0.0019125361848580163
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019125361848580163
# Final cost : 0.0019066371198731133
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019066371198731133
# Final cost : 0.00190467631948128
# Compute control for a deterministic system
# Cost in iteration 0: 0.00190467631948128
# Final cost : 0.001904184395689702
# Compute control for a deterministic system
# Cost in iteration 0: 0.001904184395689702
# Final cost : 0.0019039611521368782
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.10383364726695772
# Final cost : 0.0025384740851818253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025384740851818253
# Final cost : 0.0025190277808198893
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025190277808198893
# Final cost : 0.002514027104088476
# Compute control for a deterministic system
# Cost in iteration 0: 0.002514027104088476
# Final cost : 0.0025136548942139353
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025136548942139353
# Final cost : 0.0025134695539869405
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.22304027651318725
# Final cost : 0.00325403795975533
# Compute control for a deterministic system
# Cost in iteration 0: 0.00325403795975533
# Final cost : 0.003220958607613072
# Compute control for a deterministic system
# Cost in iteration 0: 0.003220958607613072
# Final cost : 0.0032115129225686583
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032115129225686583
# Final cost : 0.003206594379313492
# Compute control for a deterministic system
# Cost in iteration 0: 0.003206594379313492
# Final cost : 0.0032051510483979383
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.020353525966331165
# Final cost : 0.004009807179844799
# Compute control for a deterministic system
# Cost in iteration 0: 0.004009807179844799
# Final cost : 0.003991544818155526
# Compute control for a deterministic system
# Cost in iteration 0: 0.003991544818155526
# Final cost : 0.0039874064975763115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039874064975763115
# Final cost : 0.003983539625491864
# Compute control for a deterministic system
# Cost in iteration 0: 0.003983539625491864
# Final cost : 0.003982249268360694
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.18235385231130663
# Final cost : 0.004716121256964482
# Compute control for a deterministic system
# Cost in iteration 0: 0.004716121256964482
# Final cost : 0.004675194355454193
# Compute control for a deterministic system
# Cost in iteration 0: 0.004675194355454193
# Final cost : 0.0046692199315288094
# Compute control for a deterministic system
# Cost in iteration 0: 0.0046692199315288094
# Final cost : 0.004668334673555235
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668334673555235
# Final cost : 0.004667869392076968
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.439556253173473
# Final cost : 0.005747456995917933
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747456995917933
# Final cost : 0.005633089823076971
# Compute control for a deterministic system
# Cost in iteration 0: 0.005633089823076971
# Final cost : 0.005618103153712722
# Compute control for a deterministic system
# Cost in iteration 0: 0.005618103153712722
# Final cost : 0.005609656319846919
# Compute control for a deterministic system
# Cost in iteration 0: 0.005609656319846919
# Final cost : 0.005607163901288405
# Compute control for a deterministic system
# Cost in iteration 0: 0.441094595802777
# Final cost : 0.006797516167771278
# Compute control for a deterministic system
# Cost in iteration 0: 0.006797516167771278
# Final cost : 0.006665243579354682
# Compute control for a deterministic system
# Cost in iteration 0: 0.006665243579354682
# Final cost : 0.006649066413387773
# Compute control for a deterministic system
# Cost in iteration 0: 0.006649066413387773
# Final cost : 0.006641587729218258
# Compute control for a deterministic system
# Cost in iteration 0: 0.006641587729218258
# Final cost : 0.006638857131935129
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.6697448011020855
# Final cost : 0.00803740485083844
# Compute control for a deterministic system
# Cost in iteration 0: 0.00803740485083844
# Final cost : 0.007810305387182877
# Compute control for a deterministic system
# Cost in iteration 0: 0.007810305387182877
# Final cost : 0.007774433633998828
# Compute control for a deterministic system
# Cost in iteration 0: 0.007774433633998828
# Final cost : 0.00776705885921537
# Compute control for a deterministic system
# Cost in iteration 0: 0.00776705885921537
# Final cost : 0.007764433421719018
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.12740726517389023
# Final cost : 0.009119472210652936
# Compute control for a deterministic system
# Cost in iteration 0: 0.009119472210652936
# Final cost : 0.009024068847283608
# Compute control for a deterministic system
# Cost in iteration 0: 0.009024068847283608
# Final cost : 0.009001189108366761
# Compute control for a deterministic system
# Cost in iteration 0: 0.009001189108366761
# Final cost : 0.008987105504932352
# Compute control for a deterministic system
# Cost in iteration 0: 0.008987105504932352
# Final cost : 0.008982484099676736
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.3122245316491934
# Final cost : 0.010157499397004532
# Compute control for a deterministic system
# Cost in iteration 0: 0.010157499397004532
# Final cost : 0.010047994617441134
# Compute control for a deterministic system
# Cost in iteration 0: 0.010047994617441134
# Final cost : 0.010033285695115838
# Compute control for a deterministic system
# Cost in iteration 0: 0.010033285695115838
# Final cost : 0.010027650812413084
# Compute control for a deterministic system
# Cost in iteration 0: 0.010027650812413084
# Final cost : 0.010024702988600951
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.9433411784880426
# Final cost : 0.01196087087257761
# Compute control for a deterministic system
# Cost in iteration 0: 0.01196087087257761
# Final cost : 0.011502626557005898
# Compute control for a deterministic system
# Cost in iteration 0: 0.011502626557005898
# Final cost : 0.01144411771435847
# Compute control for a deterministic system
# Cost in iteration 0: 0.01144411771435847
# Final cost : 0.01141785044524616
# Compute control for a deterministic system
# Cost in iteration 0: 0.01141785044524616
# Final cost : 0.011412020487709748
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.28630250255712847
# Final cost : 0.013224764885430345
# Compute control for a deterministic system
# Cost in iteration 0: 0.013224764885430345
# Final cost : 0.01298268257979638
# Compute control for a deterministic system
# Cost in iteration 0: 0.01298268257979638
# Final cost : 0.012930160615900896
# Compute control for a deterministic system
# Cost in iteration 0: 0.012930160615900896
# Final cost : 0.012906025076186682
# Compute control for a deterministic system
# Cost in iteration 0: 0.012906025076186682
# Final cost : 0.01289586975462944
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 1.3088306650424644
# Final cost : 0.015460972040555507
# Compute control for a deterministic system
# Cost in iteration 0: 0.015460972040555507
# Final cost : 0.014612496979453039
# Compute control for a deterministic system
# Cost in iteration 0: 0.014612496979453039
# Final cost : 0.014517145964643803
# Compute control for a deterministic system
# Cost in iteration 0: 0.014517145964643803
# Final cost : 0.014485645424904539
# Compute control for a deterministic system
# Cost in iteration 0: 0.014485645424904539
# Final cost : 0.01447299891578836
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.07276818771749194
# Final cost : 0.01591933101369678
# Compute control for a deterministic system
# Cost in iteration 0: 0.01591933101369678
# Final cost : 0.015843235433832665
# Compute control for a deterministic system
# Cost in iteration 0: 0.015843235433832665
# Final cost : 0.01582506922897119
# Compute control for a deterministic system
# Cost in iteration 0: 0.01582506922897119
# Final cost : 0.015808118756135896
# Compute control for a deterministic system
# Cost in iteration 0: 0.015808118756135896
# Final cost : 0.015801241613192483
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.055570373176513636
# Final cost : 0.01767852767842849
# Compute control for a deterministic system
# Cost in iteration 0: 0.01767852767842849
# Final cost : 0.017598614003937946
# Compute control for a deterministic system
# Cost in iteration 0: 0.017598614003937946
# Final cost : 0.017577225576796467
# Compute control for a deterministic system
# Cost in iteration 0: 0.017577225576796467
# Final cost : 0.01755515543752382
# Compute control for a deterministic system
# Cost in iteration 0: 0.01755515543752382
# Final cost : 0.017548995188592348
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.6092832158577318
# Final cost : 0.01993216576694171
# Compute control for a deterministic system
# Cost in iteration 0: 0.01993216576694171
# Final cost : 0.01948080700370156
# Compute control for a deterministic system
# Cost in iteration 0: 0.01948080700370156
# Final cost : 0.019422245474493838
# Compute control for a deterministic system
# Cost in iteration 0: 0.019422245474493838
# Final cost : 0.019404263280817926
# Compute control for a deterministic system
# Cost in iteration 0: 0.019404263280817926
# Final cost : 0.01939445294565829
# Compute control for a deterministic system
# Cost in iteration 0: 0.9376965980792555
# Final cost : 0.011039084811831775
# Compute control for a deterministic system
# Cost in iteration 0: 0.011039084811831775
# Final cost : 0.01096630949591972
# Compute control for a deterministic system
# Cost in iteration 0: 0.01096630949591972
# Final cost : 0.010938966886951045
# Compute control for a deterministic system
# Cost in iteration 0: 0.010938966886951045
# Final cost : 0.010934246734310166
# Compute control for a deterministic system
# Cost in iteration 0: 0.010934246734310166
# Final cost : 0.010932244743820402
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.70240121828571
# Final cost : 0.009940851803090912
# Compute control for a deterministic system
# Cost in iteration 0: 0.009940851803090912
# Final cost : 0.009909063047520423
# Compute control for a deterministic system
# Cost in iteration 0: 0.009909063047520423
# Final cost : 0.009900097740744912
# Compute control for a deterministic system
# Cost in iteration 0: 0.009900097740744912
# Final cost : 0.009897236218512009
# Compute control for a deterministic system
# Cost in iteration 0: 0.009897236218512009
# Final cost : 0.00989491209948045
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.6474671137037041
# Final cost : 0.008702276339081702
# Compute control for a deterministic system
# Cost in iteration 0: 0.008702276339081702
# Final cost : 0.008679099293482668
# Compute control for a deterministic system
# Cost in iteration 0: 0.008679099293482668
# Final cost : 0.00867297302485148
# Compute control for a deterministic system
# Cost in iteration 0: 0.00867297302485148
# Final cost : 0.008670780699381915
# Compute control for a deterministic system
# Cost in iteration 0: 0.008670780699381915
# Converged in iteration 882 with cost 0.008668357209222153 because of step counter
# Final cost : 0.008668357209222153
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.7648616402094501
# Final cost : 0.0075611229462851344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0075611229462851344
# Final cost : 0.007535000455244265
# Compute control for a deterministic system
# Cost in iteration 0: 0.007535000455244265
# Final cost : 0.007527136460220483
# Compute control for a deterministic system
# Cost in iteration 0: 0.007527136460220483
# Final cost : 0.007523240190521098
# Compute control for a deterministic system
# Cost in iteration 0: 0.007523240190521098
# Final cost : 0.007520220900547086
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.022584635311247474
# Final cost : 0.006487327068158993
# Compute control for a deterministic system
# Cost in iteration 0: 0.006487327068158993
# Final cost : 0.006461179497437596
# Compute control for a deterministic system
# Cost in iteration 0: 0.006461179497437596
# Final cost : 0.0064571447280470685
# Compute control for a deterministic system
# Cost in iteration 0: 0.0064571447280470685
# Final cost : 0.006454167533457144
# Compute control for a deterministic system
# Cost in iteration 0: 0.006454167533457144
# Final cost : 0.006451065007808658
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.007593400257821646
# Final cost : 0.00549687013552719
# Compute control for a deterministic system
# Cost in iteration 0: 0.00549687013552719
# Final cost : 0.0054720030727329946
# Compute control for a deterministic system
# Cost in iteration 0: 0.0054720030727329946
# Final cost : 0.005467766388445065
# Compute control for a deterministic system
# Cost in iteration 0: 0.005467766388445065
# Final cost : 0.005464512213616691
# Compute control for a deterministic system
# Cost in iteration 0: 0.005464512213616691
# Final cost : 0.005461459472231582
# Compute control for a deterministic system
# Cost in iteration 0: 0.1909000745834679
# Final cost : 0.004740260756480404
# Compute control for a deterministic system
# Cost in iteration 0: 0.004740260756480404
# Final cost : 0.004730016859091609
# Compute control for a deterministic system
# Cost in iteration 0: 0.004730016859091609
# Final cost : 0.004728282678315709
# Compute control for a deterministic system
# Cost in iteration 0: 0.004728282678315709
# Final cost : 0.004727777806703538
# Compute control for a deterministic system
# Cost in iteration 0: 0.004727777806703538
# Converged in iteration 834 with cost 0.0047274388144815035 because of step counter
# Final cost : 0.0047274388144815035
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.07312254671454482
# Final cost : 0.003893328262160968
# Compute control for a deterministic system
# Cost in iteration 0: 0.003893328262160968
# Final cost : 0.0038862966564413093
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038862966564413093
# Final cost : 0.003884402590920961
# Compute control for a deterministic system
# Cost in iteration 0: 0.003884402590920961
# Final cost : 0.0038833856803687883
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038833856803687883
# Final cost : 0.0038824803214971616
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.5359494827665534
# ...
# Cost in iteration 0: 4.121283378851416
# Final cost : 0.010009983356215646
# Compute control for a deterministic system
# Cost in iteration 0: 0.010009983356215646
# Final cost : 0.008299731026249459
# Compute control for a deterministic system
# Cost in iteration 0: 0.008299731026249459
# Final cost : 0.007863994166865092
# Compute control for a deterministic system
# Cost in iteration 0: 0.007863994166865092
# Final cost : 0.007796249422977603
# Compute control for a deterministic system
# Cost in iteration 0: 0.007796249422977603
# Final cost : 0.00776870093485315
# Compute control for a deterministic system
# Cost in iteration 0: 4.344934960967608
# Final cost : 0.012107957777553094
# Compute control for a deterministic system
# Cost in iteration 0: 0.012107957777553094
# Final cost : 0.009662380182545042
# Compute control for a deterministic system
# Cost in iteration 0: 0.009662380182545042
# Final cost : 0.009192491900931393
# Compute control for a deterministic system
# Cost in iteration 0: 0.009192491900931393
# Final cost : 0.009047585925508372
# Compute control for a deterministic system
# Cost in iteration 0: 0.009047585925508372
# Final cost : 0.008992149936280888
# Compute control for a deterministic system
# Cost in iteration 0: 4.433712747652687
# Final cost : 0.013561427690860333
# Compute control for a deterministic system
# Cost in iteration 0: 0.013561427690860333
# Final cost : 0.010774148181768313
# Compute control for a deterministic system
# Cost in iteration 0: 0.010774148181768313
# Final cost : 0.010282577076113358
# Compute control for a deterministic system
# Cost in iteration 0: 0.010282577076113358
# Final cost : 0.01012029925820041
# Compute control for a deterministic system
# Cost in iteration 0: 0.01012029925820041
# Final cost : 0.010037636509949197
# Compute control for a deterministic system
# Cost in iteration 0: 4.551387602013744
# Final cost : 0.016121452023492192
# Compute control for a deterministic system
# Cost in iteration 0: 0.016121452023492192
# Final cost : 0.012387299844614891
# Compute control for a deterministic system
# Cost in iteration 0: 0.012387299844614891
# Final cost : 0.011780914686884074
# Compute control for a deterministic system
# Cost in iteration 0: 0.011780914686884074
# Final cost : 0.011506283195401907
# Compute control for a deterministic system
# Cost in iteration 0: 0.011506283195401907
# Final cost : 0.011427986879775413
# Compute control for a deterministic system
# Cost in iteration 0: 4.596495957652278
# Final cost : 0.018036711818969077
# Compute control for a deterministic system
# Cost in iteration 0: 0.018036711818969077
# Final cost : 0.013924961262888938
# Compute control for a deterministic system
# Cost in iteration 0: 0.013924961262888938
# Final cost : 0.013174542082189267
# Compute control for a deterministic system
# Cost in iteration 0: 0.013174542082189267
# Final cost : 0.013015807576894405
# Compute control for a deterministic system
# Cost in iteration 0: 0.013015807576894405
# Final cost : 0.012913161830514957
# Compute control for a deterministic system
# Cost in iteration 0: 4.616695471208391
# Final cost : 0.019768442576095974
# Compute control for a deterministic system
# Cost in iteration 0: 0.019768442576095974
# Final cost : 0.015507704287984312
# Compute control for a deterministic system
# Cost in iteration 0: 0.015507704287984312
# Final cost : 0.0148269337388488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0148269337388488
# Final cost : 0.014490034340214656
# Compute control for a deterministic system
# Cost in iteration 0: 0.014490034340214656
# Final cost : 0.014475045094698446
# Compute control for a deterministic system
# Cost in iteration 0: 4.665719036988841
# Final cost : 0.024466942371831602
# Compute control for a deterministic system
# Cost in iteration 0: 0.024466942371831602
# Final cost : 0.017334724142839757
# Compute control for a deterministic system
# Cost in iteration 0: 0.017334724142839757
# Final cost : 0.016192109863800284
# Compute control for a deterministic system
# Cost in iteration 0: 0.016192109863800284
# Final cost : 0.01596983873849471
# Compute control for a deterministic system
# Cost in iteration 0: 0.01596983873849471
# Final cost : 0.015826805884849127
# Compute control for a deterministic system
# Cost in iteration 0: 4.648076447866622
# Final cost : 0.019050567469358303
# Compute control for a deterministic system
# Cost in iteration 0: 0.019050567469358303
# Final cost : 0.014902616546350306
# Compute control for a deterministic system
# Cost in iteration 0: 0.014902616546350306
# Final cost : 0.014277797474335338
# Compute control for a deterministic system
# Cost in iteration 0: 0.014277797474335338
# Final cost : 0.013865937762208267
# Compute control for a deterministic system
# Cost in iteration 0: 0.013865937762208267
# Final cost : 0.013774164603993373
# Compute control for a deterministic system
# Cost in iteration 0: 4.602689577915058
# Final cost : 0.017398176288048267
# Compute control for a deterministic system
# Cost in iteration 0: 0.017398176288048267
# Final cost : 0.013444929731262701
# Compute control for a deterministic system
# Cost in iteration 0: 0.013444929731262701
# Final cost : 0.01280346018386473
# Compute control for a deterministic system
# Cost in iteration 0: 0.01280346018386473
# Final cost : 0.012412988748328035
# Compute control for a deterministic system
# Cost in iteration 0: 0.012412988748328035
# Final cost : 0.012327066392561927
# Compute control for a deterministic system
# Cost in iteration 0: 4.539768963153486
# Final cost : 0.015566299336733197
# Compute control for a deterministic system
# Cost in iteration 0: 0.015566299336733197
# Final cost : 0.01201096398758392
# Compute control for a deterministic system
# Cost in iteration 0: 0.01201096398758392
# Final cost : 0.011415231923884299
# Compute control for a deterministic system
# Cost in iteration 0: 0.011415231923884299
# Final cost : 0.011043140179888715
# Compute control for a deterministic system
# Cost in iteration 0: 0.011043140179888715
# Final cost : 0.010957553908205209
# Compute control for a deterministic system
# Cost in iteration 0: 4.465704382476034
# Final cost : 0.0138412009265388
# Compute control for a deterministic system
# Cost in iteration 0: 0.0138412009265388
# Final cost : 0.010835426697394259
# Compute control for a deterministic system
# Cost in iteration 0: 0.010835426697394259
# Final cost : 0.010233381512467105
# Compute control for a deterministic system
# Cost in iteration 0: 0.010233381512467105
# Final cost : 0.009916960640623725
# Compute control for a deterministic system
# Cost in iteration 0: 0.009916960640623725
# Final cost : 0.009894912963309811
# Compute control for a deterministic system
# Cost in iteration 0: 4.2907554277370545
# Final cost : 0.011315715275002317
# Compute control for a deterministic system
# Cost in iteration 0: 0.011315715275002317
# Final cost : 0.009359494859495948
# Compute control for a deterministic system
# Cost in iteration 0: 0.009359494859495948
# Final cost : 0.008975131827170208
# Compute control for a deterministic system
# Cost in iteration 0: 0.008975131827170208
# Final cost : 0.008733873507421483
# Compute control for a deterministic system
# Cost in iteration 0: 0.008733873507421483
# Final cost : 0.00868005832721272
# Compute control for a deterministic system
# Cost in iteration 0: 4.188695557310764
# Final cost : 0.010180505622258045
# Compute control for a deterministic system
# Cost in iteration 0: 0.010180505622258045
# Final cost : 0.008247564620155422
# Compute control for a deterministic system
# Cost in iteration 0: 0.008247564620155422
# Final cost : 0.007819294897453095
# Compute control for a deterministic system
# Cost in iteration 0: 0.007819294897453095
# Final cost : 0.007574621736889106
# Compute control for a deterministic system
# Cost in iteration 0: 0.007574621736889106
# Final cost : 0.0075226854582903235
# Compute control for a deterministic system
# Cost in iteration 0: 3.9406511848088543
# Final cost : 0.008392857715579079
# Compute control for a deterministic system
# Cost in iteration 0: 0.008392857715579079
# Final cost : 0.007024239318746984
# Compute control for a deterministic system
# Cost in iteration 0: 0.007024239318746984
# Final cost : 0.00670767673550395
# Compute control for a deterministic system
# Cost in iteration 0: 0.00670767673550395
# Final cost : 0.00649364211209815
# Compute control for a deterministic system
# Cost in iteration 0: 0.00649364211209815
# Final cost : 0.00645111743370293
# Compute control for a deterministic system
# Cost in iteration 0: 3.583021320513572
# Final cost : 0.006806280018587241
# Compute control for a deterministic system
# Cost in iteration 0: 0.006806280018587241
# Final cost : 0.005909989776675741
# Compute control for a deterministic system
# Cost in iteration 0: 0.005909989776675741
# Final cost : 0.0056570912489290765
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056570912489290765
# Final cost : 0.005500000462267107
# Compute control for a deterministic system
# Cost in iteration 0: 0.005500000462267107
# Final cost : 0.005461469261990434
# Compute control for a deterministic system
# Cost in iteration 0: 3.359475209769888
# Final cost : 0.0058716548327971095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058716548327971095
# Final cost : 0.005131280699189202
# Compute control for a deterministic system
# Cost in iteration 0: 0.005131280699189202
# Final cost : 0.004904244125032309
# Compute control for a deterministic system
# Cost in iteration 0: 0.004904244125032309
# Final cost : 0.004759811216852503
# Compute control for a deterministic system
# Cost in iteration 0: 0.004759811216852503
# Final cost : 0.004727955094751211
# Compute control for a deterministic system
# Cost in iteration 0: 3.1169454633437383
# Final cost : 0.004862342112024542
# Compute control for a deterministic system
# Cost in iteration 0: 0.004862342112024542
# Final cost : 0.004236754152403559
# Compute control for a deterministic system
# Cost in iteration 0: 0.004236754152403559
# Final cost : 0.003968621085964475
# Compute control for a deterministic system
# Cost in iteration 0: 0.003968621085964475
# Final cost : 0.0039010563172403576
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039010563172403576
# Final cost : 0.0038824807348791543
# Compute control for a deterministic system
# Cost in iteration 0: 2.744117344435115
# Final cost : 0.003843857291630141
# Compute control for a deterministic system
# Cost in iteration 0: 0.003843857291630141
# Final cost : 0.00337499476819354
# Compute control for a deterministic system
# Cost in iteration 0: 0.00337499476819354
# Final cost : 0.0031714960862673836
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031714960862673836
# Final cost : 0.003132469970980991
# Compute control for a deterministic system
# Cost in iteration 0: 0.003132469970980991
# Converged in iteration 927 with cost 0.0031187029602774263 because of step counter
# Final cost : 0.0031187029602774263
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 2.237153798293065
# Final cost : 0.002906645518625441
# Compute control for a deterministic system
# Cost in iteration 0: 0.002906645518625441
# Final cost : 0.0026040544300609167
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026040544300609167
# Final cost : 0.00245060406971748
# Compute control for a deterministic system
# Cost in iteration 0: 0.00245060406971748
# Final cost : 0.0024409332703757246
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024409332703757246
# Converged in iteration 928 with cost 0.0024367448855300736 because of step counter
# Final cost : 0.0024367448855300736
# Compute control for a deterministic system
# Cost in iteration 0: 1.876646636727327
# Final cost : 0.00229599706418818
# Compute control for a deterministic system
# Cost in iteration 0: 0.00229599706418818
# Final cost : 0.002059328074300569
# Compute control for a deterministic system
# Cost in iteration 0: 0.002059328074300569
# Final cost : 0.0019789412245287217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019789412245287217
# Final cost : 0.0019574519486028298
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019574519486028298
# Converged in iteration 925 with cost 0.0019505712745556058 because of vanishing difference
# Final cost : 0.0019505712745556058
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 1.474471258341488
# Final cost : 0.001654923375407469
# Compute control for a deterministic system
# Cost in iteration 0: 0.001654923375407469
# Final cost : 0.0015018620946274435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015018620946274435
# Final cost : 0.0014509679227701826
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014509679227701826
# Final cost : 0.0014250206911972615
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014250206911972615
# Converged in iteration 965 with cost 0.001417731534134501 because of step counter
# Final cost : 0.001417731534134501
# Compute control for a deterministic system
# Cost in iteration 0: 1.1705407921360473
# Final cost : 0.001135409000236187
# Compute control for a deterministic system
# Cost in iteration 0: 0.001135409000236187
# Final cost : 0.0010302531249244719
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010302531249244719
# Final cost : 0.001000725125404803
# Compute control for a deterministic system
# Cost in iteration 0: 0.001000725125404803
# Final cost : 0.000976201952538673
# Compute control for a deterministic system
# Cost in iteration 0: 0.000976201952538673
# Final cost : 0.00096876836222006
# Compute control for a deterministic system
# Cost in iteration 0: 0.7647619010939246
# Final cost : 0.0006991729289892869
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006991729289892869
# Final cost : 0.0006256444769384142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006256444769384142
# Final cost : 0.0006128179082319085
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006128179082319085
# Final cost : 0.000606649852366619
# Compute control for a deterministic system
# Cost in iteration 0: 0.000606649852366619
# Final cost : 0.0006043385549752517
# Compute control for a deterministic system
# Cost in iteration 0: 0.5065710694837477
# Final cost : 0.0004257661929662138
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004257661929662138
# Final cost : 0.00038788921270112926
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038788921270112926
# Final cost : 0.0003783792761092456
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003783792761092456
# Final cost : 0.0003753169984313766
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003753169984313766
# Final cost : 0.0003740446670544302
# Compute control for a deterministic system
# Cost in iteration 0: 0.21499229536070916
# Final cost : 0.00017820131141784077
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017820131141784077
# Final cost : 0.0001660463895787051
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001660463895787051
# Final cost : 0.00016411053007746036
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016411053007746036
# Final cost : 0.00016345574232129917
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016345574232129917
# Final cost : 0.00016316793718885048
# Compute control for a deterministic system
# Cost in iteration 0: 0.05526730013244256
# Final cost : 4.0437821029220636e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.0437821029220636e-05
# Final cost : 3.874669072955177e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.874669072955177e-05
# Final cost : 3.842681277394071e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.842681277394071e-05
# Final cost : 3.837159770644926e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.837159770644926e-05
# Final cost : 3.8356493266049144e-05
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
