# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.16789760468071255 
y_init = 0.34689637900179876
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,18], wc.inh[0,18]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.05766218995978744 0.14797540509015372
# minima =  [  24  177  330  483  635  788  941 1094 1247 1400 1553 1706 1859 2012
#  2165 2318 2471 2624 2777 2929 3082 3235 3388 3541 3694 3847 4000 4153
#  4306 4459 4612 4765 4918 5071 5223 5376 5529 5682 5835 5988]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95*np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06640800319730386
# Final cost : 0.021858488995585183
# Compute control for a deterministic system
# Cost in iteration 0: 0.021858488995585183
# Final cost : 0.00016544847685204977
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016544847685204977
# Final cost : 0.00016240408012578825
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016240408012578825
# Final cost : 0.00016221869458593786
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016221869458593786
# Final cost : 0.00016220707728539538
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016220707728539538
# Final cost : 0.00016220686329986494
# Compute control for a deterministic system
# Cost in iteration 0: 0.26117585950497485
# Final cost : 0.09239580568185926
# Compute control for a deterministic system
# Cost in iteration 0: 0.09239580568185926
# Final cost : 0.0006740000339381742
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006740000339381742
# Final cost : 0.0006508825695629584
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006508825695629584
# Final cost : 0.0006484816016855385
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006484816016855385
# Final cost : 0.0006483146237192125
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006483146237192125
# Final cost : 0.0006483107776522023
# Compute control for a deterministic system
# Cost in iteration 0: 0.48454227583310455
# Final cost : 0.18420907914672457
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420907914672457
# Final cost : 0.0012985656783551344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012985656783551344
# Final cost : 0.0012326630282084776
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012326630282084776
# Final cost : 0.0012255351379018061
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012255351379018061
# Final cost : 0.0012250119989069838
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012250119989069838
# Final cost : 0.001224997219590406
# Compute control for a deterministic system
# Cost in iteration 0: 0.8728619977317525
# Final cost : 0.36872372805022396
# Compute control for a deterministic system
# Cost in iteration 0: 0.36872372805022396
# Final cost : 0.0024856492502483485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024856492502483485
# Final cost : 0.002296772805662034
# Compute control for a deterministic system
# Cost in iteration 0: 0.002296772805662034
# Final cost : 0.0022776732943057426
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022776732943057426
# Final cost : 0.002276195735220048
# Compute control for a deterministic system
# Cost in iteration 0: 0.002276195735220048
# Converged in iteration 996 with cost 0.0022761376053489777 because of step counter
# Final cost : 0.0022761376053489777
# Compute control for a deterministic system
# Cost in iteration 0: 1.3487834736854054
# Final cost : 0.633253201345316
# Compute control for a deterministic system
# Cost in iteration 0: 0.633253201345316
# Final cost : 0.004113803216165159
# Compute control for a deterministic system
# Cost in iteration 0: 0.004113803216165159
# Final cost : 0.0036915971362709503
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036915971362709503
# Final cost : 0.0036527816577867802
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036527816577867802
# Final cost : 0.003649308348896706
# Compute control for a deterministic system
# Cost in iteration 0: 0.003649308348896706
# Converged in iteration 557 with cost 0.0036491277277506118 because of step counter
# Final cost : 0.0036491277277506118
# Compute control for a deterministic system
# Cost in iteration 0: 1.8948299078088437
# Final cost : 0.9831082279712057
# Compute control for a deterministic system
# Cost in iteration 0: 0.9831082279712057
# Final cost : 0.006222623097284469
# Compute control for a deterministic system
# Cost in iteration 0: 0.006222623097284469
# Final cost : 0.0054163257015535805
# Compute control for a deterministic system
# Cost in iteration 0: 0.0054163257015535805
# Final cost : 0.005350301416534314
# Compute control for a deterministic system
# Cost in iteration 0: 0.005350301416534314
# Final cost : 0.005343547287076008
# Compute control for a deterministic system
# Cost in iteration 0: 0.005343547287076008
# Final cost : 0.005343089151686959
# Compute control for a deterministic system
# Cost in iteration 0: 2.4938192869796123
# Final cost : 1.418518885261255
# Compute control for a deterministic system
# Cost in iteration 0: 1.418518885261255
# Final cost : 0.008852087267512965
# Compute control for a deterministic system
# Cost in iteration 0: 0.008852087267512965
# Final cost : 0.007470362201036718
# Compute control for a deterministic system
# Cost in iteration 0: 0.007470362201036718
# Final cost : 0.007367882041688503
# Compute control for a deterministic system
# Cost in iteration 0: 0.007367882041688503
# Final cost : 0.007357553722222341
# Compute control for a deterministic system
# Cost in iteration 0: 0.007357553722222341
# Final cost : 0.007356618491014098
# Compute control for a deterministic system
# Cost in iteration 0: 3.128758213716116
# Final cost : 1.9350377435282196
# Compute control for a deterministic system
# Cost in iteration 0: 1.9350377435282196
# Final cost : 0.012041315874015572
# Compute control for a deterministic system
# Cost in iteration 0: 0.012041315874015572
# Final cost : 0.009855345026991699
# Compute control for a deterministic system
# Cost in iteration 0: 0.009855345026991699
# Final cost : 0.00970873939645083
# Compute control for a deterministic system
# Cost in iteration 0: 0.00970873939645083
# Final cost : 0.009688251549942925
# Compute control for a deterministic system
# Cost in iteration 0: 0.009688251549942925
# Final cost : 0.009686037783138235
# Compute control for a deterministic system
# Cost in iteration 0: 3.6181267930823697
# Final cost : 2.370473602175007
# Compute control for a deterministic system
# Cost in iteration 0: 2.370473602175007
# Final cost : 0.014820135266692618
# Compute control for a deterministic system
# Cost in iteration 0: 0.014820135266692618
# Final cost : 0.011851897541107449
# Compute control for a deterministic system
# Cost in iteration 0: 0.011851897541107449
# Final cost : 0.011660740003580732
# Compute control for a deterministic system
# Cost in iteration 0: 0.011660740003580732
# Final cost : 0.011637491283754613
# Compute control for a deterministic system
# Cost in iteration 0: 0.011637491283754613
# Final cost : 0.011634458870633113
# Compute control for a deterministic system
# Cost in iteration 0: 4.273808349108581
# Final cost : 3.00509329811666
# Compute control for a deterministic system
# Cost in iteration 0: 3.00509329811666
# Final cost : 0.01906425600093107
# Compute control for a deterministic system
# Cost in iteration 0: 0.01906425600093107
# Final cost : 0.01478498338527263
# Compute control for a deterministic system
# Cost in iteration 0: 0.01478498338527263
# Final cost : 0.014526696199240416
# Compute control for a deterministic system
# Cost in iteration 0: 0.014526696199240416
# Final cost : 0.014493986055891576
# Compute control for a deterministic system
# Cost in iteration 0: 0.014493986055891576
# Final cost : 0.014488948744452506
# Compute control for a deterministic system
# Cost in iteration 0: 4.9169177454514195
# Final cost : 3.68747641741765
# Compute control for a deterministic system
# Cost in iteration 0: 3.68747641741765
# Final cost : 0.023968413492677622
# Compute control for a deterministic system
# Cost in iteration 0: 0.023968413492677622
# Final cost : 0.018011957764399674
# Compute control for a deterministic system
# Cost in iteration 0: 0.018011957764399674
# Final cost : 0.017691536479262304
# Compute control for a deterministic system
# Cost in iteration 0: 0.017691536479262304
# Final cost : 0.017638192976737938
# Compute control for a deterministic system
# Cost in iteration 0: 0.017638192976737938
# Final cost : 0.01762902206515797
# Compute control for a deterministic system
# Cost in iteration 0: 5.530544162137875
# Final cost : 4.399969740946727
# Compute control for a deterministic system
# Cost in iteration 0: 4.399969740946727
# Final cost : 0.029617710344244926
# Compute control for a deterministic system
# Cost in iteration 0: 0.029617710344244926
# Final cost : 0.0215682869688339
# Compute control for a deterministic system
# Cost in iteration 0: 0.0215682869688339
# Final cost : 0.021148083508577303
# Compute control for a deterministic system
# Cost in iteration 0: 0.021148083508577303
# Final cost : 0.021072626527303198
# Compute control for a deterministic system
# Cost in iteration 0: 0.021072626527303198
# Final cost : 0.021058798406124322
# Compute control for a deterministic system
# Cost in iteration 0: 6.098886406613899
# Final cost : 5.12116485901148
# Compute control for a deterministic system
# Cost in iteration 0: 5.12116485901148
# Final cost : 0.03612730471552
# Compute control for a deterministic system
# Cost in iteration 0: 0.03612730471552
# Final cost : 0.025489302149722528
# Compute control for a deterministic system
# Cost in iteration 0: 0.025489302149722528
# Final cost : 0.02496060089499997
# Compute control for a deterministic system
# Cost in iteration 0: 0.02496060089499997
# Final cost : 0.024816250050079633
# Compute control for a deterministic system
# Cost in iteration 0: 0.024816250050079633
# Final cost : 0.02478812472639552
# Compute control for a deterministic system
# Cost in iteration 0: 6.607510205292968
# Final cost : 5.823874507656071
# Compute control for a deterministic system
# Cost in iteration 0: 5.823874507656071
# Final cost : 0.0436343292164552
# Compute control for a deterministic system
# Cost in iteration 0: 0.0436343292164552
# Final cost : 0.029773016376060227
# Compute control for a deterministic system
# Cost in iteration 0: 0.029773016376060227
# Final cost : 0.02914260063988356
# Compute control for a deterministic system
# Cost in iteration 0: 0.02914260063988356
# Final cost : 0.02887657638152163
# Compute control for a deterministic system
# Cost in iteration 0: 0.02887657638152163
# Final cost : 0.028825266047025355
# Compute control for a deterministic system
# Cost in iteration 0: 6.942204399295588
# Final cost : 6.318732426545727
# Compute control for a deterministic system
# Cost in iteration 0: 6.318732426545727
# Final cost : 0.05001538486412518
# Compute control for a deterministic system
# Cost in iteration 0: 0.05001538486412518
# Final cost : 0.033237350705167076
# Compute control for a deterministic system
# Cost in iteration 0: 0.033237350705167076
# Final cost : 0.03246678362900845
# Compute control for a deterministic system
# Cost in iteration 0: 0.03246678362900845
# Final cost : 0.03212835723924348
# Compute control for a deterministic system
# Cost in iteration 0: 0.03212835723924348
# Final cost : 0.032058071066020856
# Compute control for a deterministic system
# Cost in iteration 0: 7.318097040080531
# Final cost : 6.906096767188414
# Compute control for a deterministic system
# Cost in iteration 0: 6.906096767188414
# Final cost : 0.059677941813754395
# Compute control for a deterministic system
# Cost in iteration 0: 0.059677941813754395
# Final cost : 0.038244849346019245
# Compute control for a deterministic system
# Cost in iteration 0: 0.038244849346019245
# Final cost : 0.0372164422842469
# Compute control for a deterministic system
# Cost in iteration 0: 0.0372164422842469
# Final cost : 0.03674404407805533
# Compute control for a deterministic system
# Cost in iteration 0: 0.03674404407805533
# Final cost : 0.03664344151057933
# Compute control for a deterministic system
# Cost in iteration 0: 7.607318418943938
# Final cost : 7.379515524192546
# Compute control for a deterministic system
# Cost in iteration 0: 7.379515524192546
# Final cost : 0.07087850602695724
# Compute control for a deterministic system
# Cost in iteration 0: 0.07087850602695724
# Final cost : 0.04372874708480958
# Compute control for a deterministic system
# Cost in iteration 0: 0.04372874708480958
# Final cost : 0.04223321467406721
# Compute control for a deterministic system
# Cost in iteration 0: 0.04223321467406721
# Final cost : 0.041627639588641234
# Compute control for a deterministic system
# Cost in iteration 0: 0.041627639588641234
# Final cost : 0.04154130470175692
# Compute control for a deterministic system
# Cost in iteration 0: 7.806041632638515
# Final cost : 7.7142317297594625
# Compute control for a deterministic system
# Cost in iteration 0: 7.7142317297594625
# Final cost : 0.08393684348653213
# Compute control for a deterministic system
# Cost in iteration 0: 0.08393684348653213
# Final cost : 0.04975274509166488
# Compute control for a deterministic system
# Cost in iteration 0: 0.04975274509166488
# Final cost : 0.04775041106931652
# Compute control for a deterministic system
# Cost in iteration 0: 0.04775041106931652
# Final cost : 0.046946119785159474
# Compute control for a deterministic system
# Cost in iteration 0: 0.046946119785159474
# Final cost : 0.046759797780432814
# Compute control for a deterministic system
# Cost in iteration 0: 7.912894710145015
# Final cost : 7.897268856464465
# Compute control for a deterministic system
# Cost in iteration 0: 7.897268856464465
# Final cost : 0.09940684421026538
# Compute control for a deterministic system
# Cost in iteration 0: 0.09940684421026538
# Final cost : 0.056339045696620065
# Compute control for a deterministic system
# Cost in iteration 0: 0.056339045696620065
# Final cost : 0.0536317090079166
# Compute control for a deterministic system
# Cost in iteration 0: 0.0536317090079166
# Final cost : 0.05251718325622069
# Compute control for a deterministic system
# Cost in iteration 0: 0.05251718325622069
# Final cost : 0.05228627494057896
# Compute control for a deterministic system
# Cost in iteration 0: 7.932838334768423
# Final cost : 7.932483996040473
# Compute control for a deterministic system
# Cost in iteration 0: 7.932483996040473
# Final cost : 0.12556158307667367
# Compute control for a deterministic system
# Cost in iteration 0: 0.12556158307667367
# Final cost : 0.06703235898029253
# Compute control for a deterministic system
# Cost in iteration 0: 0.06703235898029253
# Final cost : 0.06330303662922554
# Compute control for a deterministic system
# Cost in iteration 0: 0.06330303662922554
# Final cost : 0.06194341670533434
# Compute control for a deterministic system
# Cost in iteration 0: 0.06194341670533434
# Final cost : 0.061725453315060116
# Compute control for a deterministic system
# Cost in iteration 0: 7.880095716700625
# Final cost : 7.844580380901113
# Compute control for a deterministic system
# Cost in iteration 0: 7.844580380901113
# Final cost : 0.10495370942666817
# Compute control for a deterministic system
# Cost in iteration 0: 0.10495370942666817
# Final cost : 0.05938441232431592
# Compute control for a deterministic system
# Cost in iteration 0: 0.05938441232431592
# Final cost : 0.056631654320780954
# Compute control for a deterministic system
# Cost in iteration 0: 0.056631654320780954
# Final cost : 0.05560102243707728
# Compute control for a deterministic system
# Cost in iteration 0: 0.05560102243707728
# Final cost : 0.05542815799985353
# Compute control for a deterministic system
# Cost in iteration 0: 7.738506439100568
# Final cost : 7.607869981913894
# Compute control for a deterministic system
# Cost in iteration 0: 7.607869981913894
# Final cost : 0.08883014163548829
# Compute control for a deterministic system
# Cost in iteration 0: 0.08883014163548829
# Final cost : 0.05240472641272535
# Compute control for a deterministic system
# Cost in iteration 0: 0.05240472641272535
# Final cost : 0.050363431595863345
# Compute control for a deterministic system
# Cost in iteration 0: 0.050363431595863345
# Final cost : 0.04959205362861629
# Compute control for a deterministic system
# Cost in iteration 0: 0.04959205362861629
# Final cost : 0.049468955398155406
# Compute control for a deterministic system
# Cost in iteration 0: 7.510990640715474
# Final cost : 7.232984262162393
# Compute control for a deterministic system
# Cost in iteration 0: 7.232984262162393
# Final cost : 0.0750013484592786
# Compute control for a deterministic system
# Cost in iteration 0: 0.0750013484592786
# Final cost : 0.045992580210457226
# Compute control for a deterministic system
# Cost in iteration 0: 0.045992580210457226
# Final cost : 0.04448254141946005
# Compute control for a deterministic system
# Cost in iteration 0: 0.04448254141946005
# Final cost : 0.0439333334894607
# Compute control for a deterministic system
# Cost in iteration 0: 0.0439333334894607
# Final cost : 0.04384285015612141
# Compute control for a deterministic system
# Cost in iteration 0: 7.201613925627095
# Final cost : 6.737544940660621
# Compute control for a deterministic system
# Cost in iteration 0: 6.737544940660621
# Final cost : 0.06302668036753736
# Compute control for a deterministic system
# Cost in iteration 0: 0.06302668036753736
# Final cost : 0.04009931019389906
# Compute control for a deterministic system
# Cost in iteration 0: 0.04009931019389906
# Final cost : 0.03902903339749603
# Compute control for a deterministic system
# Cost in iteration 0: 0.03902903339749603
# Final cost : 0.03860971346542214
# Compute control for a deterministic system
# Cost in iteration 0: 0.03860971346542214
# Final cost : 0.0385492418981705
# Compute control for a deterministic system
# Cost in iteration 0: 6.815722759789974
# Final cost : 6.1471172986090945
# Compute control for a deterministic system
# Cost in iteration 0: 6.1471172986090945
# Final cost : 0.05264421029843628
# Compute control for a deterministic system
# Cost in iteration 0: 0.05264421029843628
# Final cost : 0.034729834388507214
# Compute control for a deterministic system
# Cost in iteration 0: 0.034729834388507214
# Final cost : 0.03395294139576344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03395294139576344
# Final cost : 0.03363941126500346
# Compute control for a deterministic system
# Cost in iteration 0: 0.03363941126500346
# Final cost : 0.033595613048717644
# Compute control for a deterministic system
# Cost in iteration 0: 6.480127969075941
# Final cost : 5.6604356144438785
# Compute control for a deterministic system
# Cost in iteration 0: 5.6604356144438785
# Final cost : 0.04576946544150191
# Compute control for a deterministic system
# Cost in iteration 0: 0.04576946544150191
# Final cost : 0.031007727412192054
# Compute control for a deterministic system
# Cost in iteration 0: 0.031007727412192054
# Final cost : 0.030379958056788267
# Compute control for a deterministic system
# Cost in iteration 0: 0.030379958056788267
# Final cost : 0.03013870254205397
# Compute control for a deterministic system
# Cost in iteration 0: 0.03013870254205397
# Final cost : 0.030105628541704975
# Compute control for a deterministic system
# Cost in iteration 0: 5.977326606102922
# Final cost : 4.977397968021694
# Compute control for a deterministic system
# Cost in iteration 0: 4.977397968021694
# Final cost : 0.03767054005686376
# Compute control for a deterministic system
# Cost in iteration 0: 0.03767054005686376
# Final cost : 0.02641617991634581
# Compute control for a deterministic system
# Cost in iteration 0: 0.02641617991634581
# Final cost : 0.025947890681696433
# Compute control for a deterministic system
# Cost in iteration 0: 0.025947890681696433
# Final cost : 0.025776524857366763
# Compute control for a deterministic system
# Cost in iteration 0: 0.025776524857366763
# Final cost : 0.025753953842754685
# Compute control for a deterministic system
# Cost in iteration 0: 5.419364823534784
# Final cost : 4.279278057270959
# Compute control for a deterministic system
# Cost in iteration 0: 4.279278057270959
# Final cost : 0.03065601076149431
# Compute control for a deterministic system
# Cost in iteration 0: 0.03065601076149431
# Final cost : 0.02221923732190967
# Compute control for a deterministic system
# Cost in iteration 0: 0.02221923732190967
# Final cost : 0.02188485834482076
# Compute control for a deterministic system
# Cost in iteration 0: 0.02188485834482076
# Final cost : 0.021764409841678954
# Compute control for a deterministic system
# Cost in iteration 0: 0.021764409841678954
# Final cost : 0.02174831514402299
# Compute control for a deterministic system
# Cost in iteration 0: 4.81796820956996
# Final cost : 3.589071054996291
# Compute control for a deterministic system
# Cost in iteration 0: 3.589071054996291
# Final cost : 0.02460779790222075
# Compute control for a deterministic system
# Cost in iteration 0: 0.02460779790222075
# Final cost : 0.018435588154781305
# Compute control for a deterministic system
# Cost in iteration 0: 0.018435588154781305
# Final cost : 0.018176069592102377
# Compute control for a deterministic system
# Cost in iteration 0: 0.018176069592102377
# Final cost : 0.01809875579299493
# Compute control for a deterministic system
# Cost in iteration 0: 0.01809875579299493
# Final cost : 0.018088846089223735
# Compute control for a deterministic system
# Cost in iteration 0: 4.188669629364228
# Final cost : 2.927774745736226
# Compute control for a deterministic system
# Cost in iteration 0: 2.927774745736226
# Final cost : 0.01942278637138415
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942278637138415
# Final cost : 0.01504241017714608
# Compute control for a deterministic system
# Cost in iteration 0: 0.01504241017714608
# Final cost : 0.014823512392170652
# Compute control for a deterministic system
# Cost in iteration 0: 0.014823512392170652
# Final cost : 0.014779158743624028
# Compute control for a deterministic system
# Cost in iteration 0: 0.014779158743624028
# Final cost : 0.014774092625603651
# Compute control for a deterministic system
# Cost in iteration 0: 3.5482825157682907
# Final cost : 2.3130839794471556
# Compute control for a deterministic system
# Cost in iteration 0: 2.3130839794471556
# Final cost : 0.01500841150610032
# Compute control for a deterministic system
# Cost in iteration 0: 0.01500841150610032
# Final cost : 0.01200013830126905
# Compute control for a deterministic system
# Cost in iteration 0: 0.01200013830126905
# Final cost : 0.011828564316863008
# Compute control for a deterministic system
# Cost in iteration 0: 0.011828564316863008
# Final cost : 0.011803727042697791
# Compute control for a deterministic system
# Cost in iteration 0: 0.011803727042697791
# Final cost : 0.011801524135038438
# Compute control for a deterministic system
# Cost in iteration 0: 3.070672659264437
# Final cost : 1.8911939988102708
# Compute control for a deterministic system
# Cost in iteration 0: 1.8911939988102708
# Final cost : 0.012155517263310312
# Compute control for a deterministic system
# Cost in iteration 0: 0.012155517263310312
# Final cost : 0.009947158176724348
# Compute control for a deterministic system
# Cost in iteration 0: 0.009947158176724348
# Final cost : 0.00980555935576504
# Compute control for a deterministic system
# Cost in iteration 0: 0.00980555935576504
# Final cost : 0.009795913973878308
# Compute control for a deterministic system
# Cost in iteration 0: 0.009795913973878308
# Final cost : 0.009794950739785873
# Compute control for a deterministic system
# Cost in iteration 0: 2.450442271837314
# Final cost : 1.3897281882938837
# Compute control for a deterministic system
# Cost in iteration 0: 1.3897281882938837
# Final cost : 0.008908428705972382
# Compute control for a deterministic system
# Cost in iteration 0: 0.008908428705972382
# Final cost : 0.007517884108479514
# Compute control for a deterministic system
# Cost in iteration 0: 0.007517884108479514
# Final cost : 0.0074224598448831905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0074224598448831905
# Final cost : 0.007414882603850914
# Compute control for a deterministic system
# Cost in iteration 0: 0.007414882603850914
# Converged in iteration 725 with cost 0.00741431476094485 because of step counter
# Final cost : 0.00741431476094485
# Compute control for a deterministic system
# Cost in iteration 0: 1.8640351935083146
# Final cost : 0.9654446254793201
# Compute control for a deterministic system
# Cost in iteration 0: 0.9654446254793201
# Final cost : 0.006245526547962914
# Compute control for a deterministic system
# Cost in iteration 0: 0.006245526547962914
# Final cost : 0.005434837264724993
# Compute control for a deterministic system
# Cost in iteration 0: 0.005434837264724993
# Final cost : 0.005371288547928471
# Compute control for a deterministic system
# Cost in iteration 0: 0.005371288547928471
# Final cost : 0.005368390236800203
# Compute control for a deterministic system
# Cost in iteration 0: 0.005368390236800203
# Converged in iteration 946 with cost 0.0053682003370227075 because of step counter
# Final cost : 0.0053682003370227075
# Compute control for a deterministic system
# Cost in iteration 0: 1.328033136025491
# Final cost : 0.6230975243559962
# Compute control for a deterministic system
# Cost in iteration 0: 0.6230975243559962
# Final cost : 0.0041173389572570175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0041173389572570175
# Final cost : 0.0036939838935080905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036939838935080905
# Final cost : 0.003656053939907952
# Compute control for a deterministic system
# Cost in iteration 0: 0.003656053939907952
# Final cost : 0.003654404897620927
# Compute control for a deterministic system
# Cost in iteration 0: 0.003654404897620927
# Final cost : 0.003654328709090142
# Compute control for a deterministic system
# Cost in iteration 0: 0.8596397962083568
# Final cost : 0.36319791865534445
# Compute control for a deterministic system
# Cost in iteration 0: 0.36319791865534445
# Final cost : 0.0024792885795048066
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024792885795048066
# Final cost : 0.0022904198659003715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022904198659003715
# Final cost : 0.0022721151489472078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022721151489472078
# Final cost : 0.002270813159468038
# Compute control for a deterministic system
# Cost in iteration 0: 0.002270813159468038
# Converged in iteration 814 with cost 0.0022707788294052847 because of step counter
# Final cost : 0.0022707788294052847
# Compute control for a deterministic system
# Cost in iteration 0: 0.5633987951457037
# Final cost : 0.2199074012141875
# Compute control for a deterministic system
# Cost in iteration 0: 0.2199074012141875
# Final cost : 0.0015468785142666213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015468785142666213
# Final cost : 0.0014585009165972802
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014585009165972802
# Final cost : 0.0014494282948109768
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014494282948109768
# Final cost : 0.001448932153697928
# Compute control for a deterministic system
# Cost in iteration 0: 0.001448932153697928
# Converged in iteration 637 with cost 0.0014489181972893294 because of step counter
# Final cost : 0.0014489181972893294
# Compute control for a deterministic system
# Cost in iteration 0: 0.2561038639198099
# Final cost : 0.09066691461658945
# Compute control for a deterministic system
# Cost in iteration 0: 0.09066691461658945
# Final cost : 0.0006651579926282815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006651579926282815
# Final cost : 0.0006421709917638359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006421709917638359
# Final cost : 0.0006399050885746342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006399050885746342
# Final cost : 0.0006397539806699636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006397539806699636
# Converged in iteration 807 with cost 0.0006397508143495806 because of step counter
# Final cost : 0.0006397508143495806
# Compute control for a deterministic system
# Cost in iteration 0: 0.06413472522011136
# Final cost : 0.021120560299843685
# Compute control for a deterministic system
# Cost in iteration 0: 0.021120560299843685
# Final cost : 0.0001602758766851855
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001602758766851855
# Final cost : 0.00015730876070946598
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015730876070946598
# Final cost : 0.0001571358132347106
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001571358132347106
# Final cost : 0.0001571245486053924
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001571245486053924
# Converged in iteration 666 with cost 0.00015712435198420407 because of step counter
# Final cost : 0.00015712435198420407
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Final cost : 5.909485323198924e-06
# Compute control for a deterministic system
# Cost in iteration 0: 5.909485323198924e-06
# Final cost : 4.5404427808481514e-08
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0908938542174645
# Final cost : 0.0006589932542294017
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006589932542294017
# Final cost : 0.0006494917119998522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006494917119998522
# Final cost : 0.0006483983681928975
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006483983681928975
# Final cost : 0.0006483128495735705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006483128495735705
# Final cost : 0.0006483107771494217
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.04530500763866869
# Final cost : 0.0012358001925615663
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012358001925615663
# Final cost : 0.001226409861622889
# Compute control for a deterministic system
# Cost in iteration 0: 0.001226409861622889
# Final cost : 0.0012251095201991245
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012251095201991245
# Final cost : 0.0012250007111793714
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012250007111793714
# Final cost : 0.0012249972135252368
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.06543054614895068
# Final cost : 0.0023082973325202947
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023082973325202947
# Final cost : 0.0022804284638901244
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022804284638901244
# Final cost : 0.0022765483224035416
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022765483224035416
# Final cost : 0.002276155284793953
# Compute control for a deterministic system
# Cost in iteration 0: 0.002276155284793953
# Final cost : 0.0022761376278330747
# Compute control for a deterministic system
# Cost in iteration 0: 0.10507715839977691
# Final cost : 0.0037049016269314885
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037049016269314885
# Final cost : 0.0036564805344585583
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036564805344585583
# Final cost : 0.0036499063243663698
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036499063243663698
# Final cost : 0.0036491725779557653
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036491725779557653
# Final cost : 0.003649127833737359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060291342653360945
# Final cost : 0.0054340079371961135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0054340079371961135
# Final cost : 0.005354925250975802
# Compute control for a deterministic system
# Cost in iteration 0: 0.005354925250975802
# Final cost : 0.005344658222360188
# Compute control for a deterministic system
# Cost in iteration 0: 0.005344658222360188
# Final cost : 0.005343204869873604
# Compute control for a deterministic system
# Cost in iteration 0: 0.005343204869873604
# Final cost : 0.005343087819385551
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.17282775786462104
# Final cost : 0.007477022997956105
# Compute control for a deterministic system
# Cost in iteration 0: 0.007477022997956105
# Final cost : 0.007372715510423902
# Compute control for a deterministic system
# Cost in iteration 0: 0.007372715510423902
# Final cost : 0.007359031540584119
# Compute control for a deterministic system
# Cost in iteration 0: 0.007359031540584119
# Final cost : 0.007356837610738829
# Compute control for a deterministic system
# Cost in iteration 0: 0.007356837610738829
# Final cost : 0.007356613831385154
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.2011791144335392
# Final cost : 0.009844858780855045
# Compute control for a deterministic system
# Cost in iteration 0: 0.009844858780855045
# Final cost : 0.009707655069603123
# Compute control for a deterministic system
# Cost in iteration 0: 0.009707655069603123
# Final cost : 0.009689600792741783
# Compute control for a deterministic system
# Cost in iteration 0: 0.009689600792741783
# Final cost : 0.00968642467884872
# Compute control for a deterministic system
# Cost in iteration 0: 0.00968642467884872
# Final cost : 0.009686019857939794
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.11720164827925494
# Final cost : 0.011737740278014367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011737740278014367
# Final cost : 0.011650216067144914
# Compute control for a deterministic system
# Cost in iteration 0: 0.011650216067144914
# Final cost : 0.011637439419492137
# Compute control for a deterministic system
# Cost in iteration 0: 0.011637439419492137
# Final cost : 0.01163481272364012
# Compute control for a deterministic system
# Cost in iteration 0: 0.01163481272364012
# Final cost : 0.01163442399039844
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.046666322868719516
# Final cost : 0.014678556435469597
# Compute control for a deterministic system
# Cost in iteration 0: 0.014678556435469597
# Final cost : 0.014518232377971103
# Compute control for a deterministic system
# Cost in iteration 0: 0.014518232377971103
# Final cost : 0.014494887128078313
# Compute control for a deterministic system
# Cost in iteration 0: 0.014494887128078313
# Final cost : 0.01448974658258508
# Compute control for a deterministic system
# Cost in iteration 0: 0.01448974658258508
# Final cost : 0.014488874247154561
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.3373227969279364
# Final cost : 0.01792011088704274
# Compute control for a deterministic system
# Cost in iteration 0: 0.01792011088704274
# Final cost : 0.017668337579942763
# Compute control for a deterministic system
# Cost in iteration 0: 0.017668337579942763
# Final cost : 0.01763829398284263
# Compute control for a deterministic system
# Cost in iteration 0: 0.01763829398284263
# Final cost : 0.017630489837915143
# Compute control for a deterministic system
# Cost in iteration 0: 0.017630489837915143
# Final cost : 0.0176290017993714
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.022371956802890353
# Final cost : 0.02134069654487704
# Compute control for a deterministic system
# Cost in iteration 0: 0.02134069654487704
# Final cost : 0.021101452134129846
# Compute control for a deterministic system
# Cost in iteration 0: 0.021101452134129846
# Final cost : 0.021070361306616242
# Compute control for a deterministic system
# Cost in iteration 0: 0.021070361306616242
# Final cost : 0.021060792680326425
# Compute control for a deterministic system
# Cost in iteration 0: 0.021060792680326425
# Final cost : 0.0210586535251631
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.6350056640771293
# Final cost : 0.025273006601335635
# Compute control for a deterministic system
# Cost in iteration 0: 0.025273006601335635
# Final cost : 0.02484433013883304
# Compute control for a deterministic system
# Cost in iteration 0: 0.02484433013883304
# Final cost : 0.024802121739997147
# Compute control for a deterministic system
# Cost in iteration 0: 0.024802121739997147
# Final cost : 0.024790313401696493
# Compute control for a deterministic system
# Cost in iteration 0: 0.024790313401696493
# Final cost : 0.024787332385625294
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.7601745890503104
# Final cost : 0.02942676247267403
# Compute control for a deterministic system
# Cost in iteration 0: 0.02942676247267403
# Final cost : 0.028892401179530465
# Compute control for a deterministic system
# Cost in iteration 0: 0.028892401179530465
# Final cost : 0.02884318684608965
# Compute control for a deterministic system
# Cost in iteration 0: 0.02884318684608965
# Final cost : 0.028827534658960232
# Compute control for a deterministic system
# Cost in iteration 0: 0.028827534658960232
# Final cost : 0.02882316611529657
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.3052207814670623
# Final cost : 0.03234684632230833
# Compute control for a deterministic system
# Cost in iteration 0: 0.03234684632230833
# Final cost : 0.0321012061725438
# Compute control for a deterministic system
# Cost in iteration 0: 0.0321012061725438
# Final cost : 0.03206990305805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.03206990305805875
# Final cost : 0.03205824285129905
# Compute control for a deterministic system
# Cost in iteration 0: 0.03205824285129905
# Final cost : 0.03205450137509841
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.4504731031070642
# Final cost : 0.03719833786761311
# Compute control for a deterministic system
# Cost in iteration 0: 0.03719833786761311
# Final cost : 0.036724007186003875
# Compute control for a deterministic system
# Cost in iteration 0: 0.036724007186003875
# Final cost : 0.036663776766854936
# Compute control for a deterministic system
# Cost in iteration 0: 0.036663776766854936
# Final cost : 0.036644647299065726
# Compute control for a deterministic system
# Cost in iteration 0: 0.036644647299065726
# Final cost : 0.036637928614021695
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 1.3761158583754889
# Final cost : 0.04276539870185592
# Compute control for a deterministic system
# Cost in iteration 0: 0.04276539870185592
# Final cost : 0.04164765056549035
# Compute control for a deterministic system
# Cost in iteration 0: 0.04164765056549035
# Final cost : 0.041571696830230646
# Compute control for a deterministic system
# Cost in iteration 0: 0.041571696830230646
# Final cost : 0.04154523538055325
# Compute control for a deterministic system
# Cost in iteration 0: 0.04154523538055325
# Final cost : 0.04153492845154811
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.5187572792710358
# Final cost : 0.04745768174914865
# Compute control for a deterministic system
# Cost in iteration 0: 0.04745768174914865
# Final cost : 0.04686195234661093
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686195234661093
# Final cost : 0.04678835769223626
# Compute control for a deterministic system
# Cost in iteration 0: 0.04678835769223626
# Final cost : 0.046757465082461085
# Compute control for a deterministic system
# Cost in iteration 0: 0.046757465082461085
# Final cost : 0.04674421814036981
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.0754555893083192
# Final cost : 0.05303484315618351
# Compute control for a deterministic system
# Cost in iteration 0: 0.05303484315618351
# Final cost : 0.05239741756253633
# Compute control for a deterministic system
# Cost in iteration 0: 0.05239741756253633
# Final cost : 0.05231574231256895
# Compute control for a deterministic system
# Cost in iteration 0: 0.05231574231256895
# Final cost : 0.05228026688036057
# Compute control for a deterministic system
# Cost in iteration 0: 0.05228026688036057
# Final cost : 0.05226416466452474
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.057577592271304365
# Final cost : 0.056961781483190546
# Compute control for a deterministic system
# Cost in iteration 0: 0.056961781483190546
# Final cost : 0.05669631445890921
# Compute control for a deterministic system
# Cost in iteration 0: 0.05669631445890921
# Final cost : 0.05664196902891976
# Compute control for a deterministic system
# Cost in iteration 0: 0.05664196902891976
# Final cost : 0.05661728839617022
# Compute control for a deterministic system
# Cost in iteration 0: 0.05661728839617022
# Final cost : 0.05660489291316022
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.12338298698951992
# Final cost : 0.06329550614386843
# Compute control for a deterministic system
# Cost in iteration 0: 0.06329550614386843
# Final cost : 0.06281991537834362
# Compute control for a deterministic system
# Cost in iteration 0: 0.06281991537834362
# Final cost : 0.06270733837022727
# Compute control for a deterministic system
# Cost in iteration 0: 0.06270733837022727
# Final cost : 0.06267686490721466
# Compute control for a deterministic system
# Cost in iteration 0: 0.06267686490721466
# Final cost : 0.06265869264633685
# Compute control for a deterministic system
# Cost in iteration 0: 0.1830953585904648
# Final cost : 0.049919626023200346
# Compute control for a deterministic system
# Cost in iteration 0: 0.049919626023200346
# Final cost : 0.04955705764504549
# Compute control for a deterministic system
# Cost in iteration 0: 0.04955705764504549
# Final cost : 0.04949523654245375
# Compute control for a deterministic system
# Cost in iteration 0: 0.04949523654245375
# Final cost : 0.04947073871638867
# Compute control for a deterministic system
# Cost in iteration 0: 0.04947073871638867
# Final cost : 0.049462473519052585
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.27532615584929626
# Final cost : 0.044286835085212625
# Compute control for a deterministic system
# Cost in iteration 0: 0.044286835085212625
# Final cost : 0.04396353884816058
# Compute control for a deterministic system
# Cost in iteration 0: 0.04396353884816058
# Final cost : 0.0438909618882013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0438909618882013
# Final cost : 0.04385319959534715
# Compute control for a deterministic system
# Cost in iteration 0: 0.04385319959534715
# Final cost : 0.04383943084009599
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.6512312318686124
# Final cost : 0.03905115180370224
# Compute control for a deterministic system
# Cost in iteration 0: 0.03905115180370224
# Final cost : 0.038663407495661814
# Compute control for a deterministic system
# Cost in iteration 0: 0.038663407495661814
# Final cost : 0.03858745082996348
# Compute control for a deterministic system
# Cost in iteration 0: 0.03858745082996348
# Final cost : 0.03855729062670601
# Compute control for a deterministic system
# Cost in iteration 0: 0.03855729062670601
# Final cost : 0.038547381791808985
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.7234010335084878
# Final cost : 0.034253921812378345
# Compute control for a deterministic system
# Cost in iteration 0: 0.034253921812378345
# Final cost : 0.0336967290339699
# Compute control for a deterministic system
# Cost in iteration 0: 0.0336967290339699
# Final cost : 0.03362527669763405
# Compute control for a deterministic system
# Cost in iteration 0: 0.03362527669763405
# Final cost : 0.03360127468346805
# Compute control for a deterministic system
# Cost in iteration 0: 0.03360127468346805
# Final cost : 0.033594527571158175
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.21600440194188666
# Final cost : 0.030237820877399256
# Compute control for a deterministic system
# Cost in iteration 0: 0.030237820877399256
# Final cost : 0.0301488114993142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0301488114993142
# Final cost : 0.03011890868384696
# Compute control for a deterministic system
# Cost in iteration 0: 0.03011890868384696
# Final cost : 0.030107669302830268
# Compute control for a deterministic system
# Cost in iteration 0: 0.030107669302830268
# Final cost : 0.03010487469480709
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.10386504528889387
# Final cost : 0.02610234431068048
# Compute control for a deterministic system
# Cost in iteration 0: 0.02610234431068048
# Final cost : 0.025828831598533893
# Compute control for a deterministic system
# Cost in iteration 0: 0.025828831598533893
# Final cost : 0.02577601890582953
# Compute control for a deterministic system
# Cost in iteration 0: 0.02577601890582953
# Final cost : 0.025757675425428284
# Compute control for a deterministic system
# Cost in iteration 0: 0.025757675425428284
# Final cost : 0.025753584372816465
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.0845826759813838
# Final cost : 0.022056024198604047
# Compute control for a deterministic system
# Cost in iteration 0: 0.022056024198604047
# Final cost : 0.021812732540819092
# Compute control for a deterministic system
# Cost in iteration 0: 0.021812732540819092
# Final cost : 0.021766771005645384
# Compute control for a deterministic system
# Cost in iteration 0: 0.021766771005645384
# Final cost : 0.02175121722011028
# Compute control for a deterministic system
# Cost in iteration 0: 0.02175121722011028
# Final cost : 0.02174809376696625
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.650224770676001
# Final cost : 0.0183757054503736
# Compute control for a deterministic system
# Cost in iteration 0: 0.0183757054503736
# Final cost : 0.018140026541258243
# Compute control for a deterministic system
# Cost in iteration 0: 0.018140026541258243
# Final cost : 0.018100946315705017
# Compute control for a deterministic system
# Cost in iteration 0: 0.018100946315705017
# Final cost : 0.018090550399973197
# Compute control for a deterministic system
# Cost in iteration 0: 0.018090550399973197
# Final cost : 0.01808873047745506
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.6028154988926827
# Final cost : 0.014975670720142978
# Compute control for a deterministic system
# Cost in iteration 0: 0.014975670720142978
# Final cost : 0.014813474667815447
# Compute control for a deterministic system
# Cost in iteration 0: 0.014813474667815447
# Final cost : 0.014782683467549015
# Compute control for a deterministic system
# Cost in iteration 0: 0.014782683467549015
# Final cost : 0.014775197919202138
# Compute control for a deterministic system
# Cost in iteration 0: 0.014775197919202138
# Final cost : 0.014774044551013036
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.036029748587773226
# Final cost : 0.011943225741536676
# ...
# -----------------------------------------------
# 5 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 6.527259313146852
# Final cost : 0.041202513701355324
# Compute control for a deterministic system
# Cost in iteration 0: 0.041202513701355324
# Final cost : 0.029590076995589406
# Compute control for a deterministic system
# Cost in iteration 0: 0.029590076995589406
# Final cost : 0.029086440953258585
# Compute control for a deterministic system
# Cost in iteration 0: 0.029086440953258585
# Final cost : 0.02885656087386056
# Compute control for a deterministic system
# Cost in iteration 0: 0.02885656087386056
# Final cost : 0.028824494936267722
# Compute control for a deterministic system
# Cost in iteration 0: 6.849797610409366
# Final cost : 0.04590264119909211
# Compute control for a deterministic system
# Cost in iteration 0: 0.04590264119909211
# Final cost : 0.03293080468212464
# Compute control for a deterministic system
# Cost in iteration 0: 0.03293080468212464
# Final cost : 0.032364330278680783
# Compute control for a deterministic system
# Cost in iteration 0: 0.032364330278680783
# Final cost : 0.03211334902675171
# Compute control for a deterministic system
# Cost in iteration 0: 0.03211334902675171
# Final cost : 0.032057375065375024
# Compute control for a deterministic system
# Cost in iteration 0: 7.2902008163819785
# Final cost : 0.05684827855856128
# Compute control for a deterministic system
# Cost in iteration 0: 0.05684827855856128
# Final cost : 0.03800629552048896
# Compute control for a deterministic system
# Cost in iteration 0: 0.03800629552048896
# Final cost : 0.03713467236147437
# Compute control for a deterministic system
# Cost in iteration 0: 0.03713467236147437
# Final cost : 0.03673423309453384
# Compute control for a deterministic system
# Cost in iteration 0: 0.03673423309453384
# Final cost : 0.036643214429395395
# Compute control for a deterministic system
# Cost in iteration 0: 7.570556338179372
# Final cost : 0.06348303600420133
# Compute control for a deterministic system
# Cost in iteration 0: 0.06348303600420133
# Final cost : 0.0430154722487472
# Compute control for a deterministic system
# Cost in iteration 0: 0.0430154722487472
# Final cost : 0.04202287474389149
# Compute control for a deterministic system
# Cost in iteration 0: 0.04202287474389149
# Final cost : 0.04164317042623343
# Compute control for a deterministic system
# Cost in iteration 0: 0.04164317042623343
# Final cost : 0.04154220031031892
# Compute control for a deterministic system
# Cost in iteration 0: 7.801226762594663
# Final cost : 0.0802441257262491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802441257262491
# Final cost : 0.04931568131594814
# Compute control for a deterministic system
# Cost in iteration 0: 0.04931568131594814
# Final cost : 0.04763582520000882
# Compute control for a deterministic system
# Cost in iteration 0: 0.04763582520000882
# Final cost : 0.046927508898058364
# Compute control for a deterministic system
# Cost in iteration 0: 0.046927508898058364
# Final cost : 0.046758617632192113
# Compute control for a deterministic system
# Cost in iteration 0: 7.909812205788185
# Final cost : 0.08781365675923813
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781365675923813
# Final cost : 0.05494378277742425
# Compute control for a deterministic system
# Cost in iteration 0: 0.05494378277742425
# Final cost : 0.05323046206224168
# Compute control for a deterministic system
# Cost in iteration 0: 0.05323046206224168
# Final cost : 0.05247679730419798
# Compute control for a deterministic system
# Cost in iteration 0: 0.05247679730419798
# Final cost : 0.05228313923069914
# Compute control for a deterministic system
# Cost in iteration 0: 7.934024197497786
# Final cost : 0.12721674290558183
# Compute control for a deterministic system
# Cost in iteration 0: 0.12721674290558183
# Final cost : 0.06696046287251382
# Compute control for a deterministic system
# Cost in iteration 0: 0.06696046287251382
# Final cost : 0.06328347553414611
# Compute control for a deterministic system
# Cost in iteration 0: 0.06328347553414611
# Final cost : 0.06194405920399508
# Compute control for a deterministic system
# Cost in iteration 0: 0.06194405920399508
# Final cost : 0.06172550166263282
# Compute control for a deterministic system
# Cost in iteration 0: 7.875726423156955
# Final cost : 0.0957055948650434
# Compute control for a deterministic system
# Cost in iteration 0: 0.0957055948650434
# Final cost : 0.058382130657417645
# Compute control for a deterministic system
# Cost in iteration 0: 0.058382130657417645
# Final cost : 0.05637420000897352
# Compute control for a deterministic system
# Cost in iteration 0: 0.05637420000897352
# Final cost : 0.055567868037456426
# Compute control for a deterministic system
# Cost in iteration 0: 0.055567868037456426
# Final cost : 0.055426276300967234
# Compute control for a deterministic system
# Cost in iteration 0: 7.722478769619937
# Final cost : 0.08064322225319377
# Compute control for a deterministic system
# Cost in iteration 0: 0.08064322225319377
# Final cost : 0.051571474516763305
# Compute control for a deterministic system
# Cost in iteration 0: 0.051571474516763305
# Final cost : 0.05013865084498871
# Compute control for a deterministic system
# Cost in iteration 0: 0.05013865084498871
# Final cost : 0.049571305215700745
# Compute control for a deterministic system
# Cost in iteration 0: 0.049571305215700745
# Final cost : 0.049467975402208694
# Compute control for a deterministic system
# Cost in iteration 0: 7.466857429379221
# Final cost : 0.06703832665515574
# Compute control for a deterministic system
# Cost in iteration 0: 0.06703832665515574
# Final cost : 0.04528669007133604
# Compute control for a deterministic system
# Cost in iteration 0: 0.04528669007133604
# Final cost : 0.04434202673693979
# Compute control for a deterministic system
# Cost in iteration 0: 0.04434202673693979
# Final cost : 0.0439113980237769
# Compute control for a deterministic system
# Cost in iteration 0: 0.0439113980237769
# Final cost : 0.043841972560549156
# Compute control for a deterministic system
# Cost in iteration 0: 7.18638365508571
# Final cost : 0.061467962854459546
# Compute control for a deterministic system
# Cost in iteration 0: 0.061467962854459546
# Final cost : 0.039958348195386476
# Compute control for a deterministic system
# Cost in iteration 0: 0.039958348195386476
# Final cost : 0.039012268287412846
# Compute control for a deterministic system
# Cost in iteration 0: 0.039012268287412846
# Final cost : 0.03861225853955223
# Compute control for a deterministic system
# Cost in iteration 0: 0.03861225853955223
# Final cost : 0.03854931486960478
# Compute control for a deterministic system
# Cost in iteration 0: 6.69651946080357
# Final cost : 0.04757929988731302
# Compute control for a deterministic system
# Cost in iteration 0: 0.04757929988731302
# Final cost : 0.03438638164288378
# Compute control for a deterministic system
# Cost in iteration 0: 0.03438638164288378
# Final cost : 0.03385057317263937
# Compute control for a deterministic system
# Cost in iteration 0: 0.03385057317263937
# Final cost : 0.033629111925286045
# Compute control for a deterministic system
# Cost in iteration 0: 0.033629111925286045
# Final cost : 0.03359531455375281
# Compute control for a deterministic system
# Cost in iteration 0: 6.315191910096762
# Final cost : 0.0413451373074074
# Compute control for a deterministic system
# Cost in iteration 0: 0.0413451373074074
# Final cost : 0.03072999692227427
# Compute control for a deterministic system
# Cost in iteration 0: 0.03072999692227427
# Final cost : 0.030294091529407825
# Compute control for a deterministic system
# Cost in iteration 0: 0.030294091529407825
# Final cost : 0.03013066990794701
# Compute control for a deterministic system
# Cost in iteration 0: 0.03013066990794701
# Final cost : 0.03010543641001379
# Compute control for a deterministic system
# Cost in iteration 0: 5.926691400111367
# Final cost : 0.036705769698793626
# Compute control for a deterministic system
# Cost in iteration 0: 0.036705769698793626
# Final cost : 0.026351793565726367
# Compute control for a deterministic system
# Cost in iteration 0: 0.026351793565726367
# Final cost : 0.02593254656573669
# Compute control for a deterministic system
# Cost in iteration 0: 0.02593254656573669
# Final cost : 0.025774799524915445
# Compute control for a deterministic system
# Cost in iteration 0: 0.025774799524915445
# Final cost : 0.025753915835405164
# Compute control for a deterministic system
# Cost in iteration 0: 5.383711370521132
# Final cost : 0.030238736081193367
# Compute control for a deterministic system
# Cost in iteration 0: 0.030238736081193367
# Final cost : 0.022204945979381517
# Compute control for a deterministic system
# Cost in iteration 0: 0.022204945979381517
# Final cost : 0.02183818504856113
# Compute control for a deterministic system
# Cost in iteration 0: 0.02183818504856113
# Final cost : 0.0217591900596369
# Compute control for a deterministic system
# Cost in iteration 0: 0.0217591900596369
# Final cost : 0.02174823285079829
# Compute control for a deterministic system
# Cost in iteration 0: 4.8002024775226015
# Final cost : 0.0244831659130898
# Compute control for a deterministic system
# Cost in iteration 0: 0.0244831659130898
# Final cost : 0.01843438321344957
# Compute control for a deterministic system
# Cost in iteration 0: 0.01843438321344957
# Final cost : 0.018158874660809957
# Compute control for a deterministic system
# Cost in iteration 0: 0.018158874660809957
# Final cost : 0.01809672671722135
# Compute control for a deterministic system
# Cost in iteration 0: 0.01809672671722135
# Final cost : 0.018088816381113634
# Compute control for a deterministic system
# Cost in iteration 0: 4.094830104637284
# Final cost : 0.018971466805525253
# Compute control for a deterministic system
# Cost in iteration 0: 0.018971466805525253
# Final cost : 0.01502102539443888
# Compute control for a deterministic system
# Cost in iteration 0: 0.01502102539443888
# Final cost : 0.014814439786004193
# Compute control for a deterministic system
# Cost in iteration 0: 0.014814439786004193
# Final cost : 0.014778099887113079
# Compute control for a deterministic system
# Cost in iteration 0: 0.014778099887113079
# Final cost : 0.014774080579935503
# Compute control for a deterministic system
# Cost in iteration 0: 3.3974726554797687
# Final cost : 0.014535940017981273
# Compute control for a deterministic system
# Cost in iteration 0: 0.014535940017981273
# Final cost : 0.01197604390476557
# Compute control for a deterministic system
# Cost in iteration 0: 0.01197604390476557
# Final cost : 0.011817077450341596
# Compute control for a deterministic system
# Cost in iteration 0: 0.011817077450341596
# Final cost : 0.01180303497338082
# Compute control for a deterministic system
# Cost in iteration 0: 0.01180303497338082
# Final cost : 0.011801529020818843
# Compute control for a deterministic system
# Cost in iteration 0: 2.8359080498282574
# Final cost : 0.011631237431855797
# Compute control for a deterministic system
# Cost in iteration 0: 0.011631237431855797
# Final cost : 0.00991700275032774
# Compute control for a deterministic system
# Cost in iteration 0: 0.00991700275032774
# Final cost : 0.009803499779947687
# Compute control for a deterministic system
# Cost in iteration 0: 0.009803499779947687
# Final cost : 0.0097957036363638
# Compute control for a deterministic system
# Cost in iteration 0: 0.0097957036363638
# Final cost : 0.009794955041504868
# Compute control for a deterministic system
# Cost in iteration 0: 2.4179105556921185
# Final cost : 0.008856195490511486
# Compute control for a deterministic system
# Cost in iteration 0: 0.008856195490511486
# Final cost : 0.007513020292120115
# Compute control for a deterministic system
# Cost in iteration 0: 0.007513020292120115
# Final cost : 0.00742222609226323
# Compute control for a deterministic system
# Cost in iteration 0: 0.00742222609226323
# Final cost : 0.007414875592992156
# Compute control for a deterministic system
# Cost in iteration 0: 0.007414875592992156
# Final cost : 0.007414314812065529
# Compute control for a deterministic system
# Cost in iteration 0: 1.8235242414273247
# Final cost : 0.006201255739047915
# Compute control for a deterministic system
# Cost in iteration 0: 0.006201255739047915
# Final cost : 0.005431960771276693
# Compute control for a deterministic system
# Cost in iteration 0: 0.005431960771276693
# Final cost : 0.005372242363531663
# Compute control for a deterministic system
# Cost in iteration 0: 0.005372242363531663
# Final cost : 0.005368433192432058
# Compute control for a deterministic system
# Cost in iteration 0: 0.005368433192432058
# Converged in iteration 676 with cost 0.0053682003370224525 because of step counter
# Final cost : 0.0053682003370224525
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 1.3006994472096776
# Final cost : 0.004097912885923736
# Compute control for a deterministic system
# Cost in iteration 0: 0.004097912885923736
# Final cost : 0.003691865491458898
# Compute control for a deterministic system
# Cost in iteration 0: 0.003691865491458898
# Final cost : 0.0036555408396487733
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036555408396487733
# Final cost : 0.0036543894283591685
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036543894283591685
# Converged in iteration 589 with cost 0.003654328707151371 because of step counter
# Final cost : 0.003654328707151371
# Compute control for a deterministic system
# Cost in iteration 0: 0.745769627062109
# Final cost : 0.002430307009544672
# Compute control for a deterministic system
# Cost in iteration 0: 0.002430307009544672
# Final cost : 0.002285607984056052
# Compute control for a deterministic system
# Cost in iteration 0: 0.002285607984056052
# Final cost : 0.0022712643149635516
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022712643149635516
# Final cost : 0.002270796368778699
# Compute control for a deterministic system
# Cost in iteration 0: 0.002270796368778699
# Converged in iteration 704 with cost 0.002270778829403549 because of step counter
# Final cost : 0.002270778829403549
# Compute control for a deterministic system
# Cost in iteration 0: 0.5203645105819299
# Final cost : 0.0015340538936087348
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015340538936087348
# Final cost : 0.0014571772932139228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014571772932139228
# Final cost : 0.0014494642453855035
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014494642453855035
# Final cost : 0.0014489328038355337
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014489328038355337
# Converged in iteration 792 with cost 0.001448918197289428 because of step counter
# Final cost : 0.001448918197289428
# Compute control for a deterministic system
# Cost in iteration 0: 0.22011392748286268
# Final cost : 0.0006599549751817379
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006599549751817379
# Final cost : 0.0006415629738481686
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006415629738481686
# Final cost : 0.0006398723498138076
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006398723498138076
# Final cost : 0.0006397533405977307
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006397533405977307
# Converged in iteration 421 with cost 0.0006397508143514146 because of step counter
# Final cost : 0.0006397508143514146
# Compute control for a deterministic system
# Cost in iteration 0: 0.057325086198576035
# Final cost : 0.0001599002744096236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001599002744096236
# Final cost : 0.00015727073975189718
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015727073975189718
# Final cost : 0.00015713395077048358
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015713395077048358
# Final cost : 0.00015712451702207988
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015712451702207988
# Converged in iteration 659 with cost 0.00015712435198350896 because of step counter
# Final cost : 0.00015712435198350896

# %%
save(results_min)
