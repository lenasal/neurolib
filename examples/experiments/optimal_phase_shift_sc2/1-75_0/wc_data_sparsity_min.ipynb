# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.16789760468071255 
y_init = 0.34689637900179876
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,18], wc.inh[0,18]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.05766218995978744 0.14797540509015372
# minima =  [  24  177  330  483  635  788  941 1094 1247 1400 1553 1706 1859 2012
#  2165 2318 2471 2624 2777 2929 3082 3235 3388 3541 3694 3847 4000 4153
#  4306 4459 4612 4765 4918 5071 5223 5376 5529 5682 5835 5988]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.1
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06640800319730386
# Final cost : 0.03140463539022609
# Compute control for a deterministic system
# Cost in iteration 0: 0.03140463539022609
# Converged in iteration 90 with cost 0.01731923519450294 because of vanishing difference
# Final cost : 0.01731923519450294
# Compute control for a deterministic system
# Cost in iteration 0: 0.01731923519450294
# Converged in iteration 36 with cost 0.017319232461146084 because of step counter
# Final cost : 0.017319232461146084
# Compute control for a deterministic system
# Cost in iteration 0: 0.017319232461146084
# Converged in iteration 1 with cost 0.017319232461146084 because of step counter
# Final cost : 0.017319232461146084
# Compute control for a deterministic system
# Cost in iteration 0: 0.017319232461146084
# Converged in iteration 1 with cost 0.017319232461146084 because of step counter
# Final cost : 0.017319232461146084
# Compute control for a deterministic system
# Cost in iteration 0: 0.017319232461146084
# Converged in iteration 1 with cost 0.017319232461146084 because of step counter
# Final cost : 0.017319232461146084
# Compute control for a deterministic system
# Cost in iteration 0: 0.26117585950497485
# Final cost : 0.1107740004720948
# Compute control for a deterministic system
# Cost in iteration 0: 0.1107740004720948
# Cost in iteration 200: 0.03603142659805284
# Converged in iteration 267 with cost 0.036031416039962565 because of vanishing difference
# Final cost : 0.036031416039962565
# Compute control for a deterministic system
# Cost in iteration 0: 0.036031416039962565
# Converged in iteration 58 with cost 0.03603141569169885 because of step counter
# Final cost : 0.03603141569169885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03603141569169885
# Converged in iteration 1 with cost 0.03603141569169885 because of step counter
# Final cost : 0.03603141569169885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03603141569169885
# Converged in iteration 1 with cost 0.03603141569169885 because of step counter
# Final cost : 0.03603141569169885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03603141569169885
# Converged in iteration 2 with cost 0.03603141569169744 because of step counter
# Final cost : 0.03603141569169744
# Compute control for a deterministic system
# Cost in iteration 0: 0.48454227583310455
# Final cost : 0.20848240650860894
# Compute control for a deterministic system
# Cost in iteration 0: 0.20848240650860894
# Cost in iteration 200: 0.050113092340589166
# Converged in iteration 320 with cost 0.05011246560411442 because of vanishing difference
# Final cost : 0.05011246560411442
# Compute control for a deterministic system
# Cost in iteration 0: 0.05011246560411442
# Converged in iteration 186 with cost 0.05011245554701077 because of step counter
# Final cost : 0.05011245554701077
# Compute control for a deterministic system
# Cost in iteration 0: 0.05011245554701077
# Converged in iteration 2 with cost 0.05011245554701057 because of step counter
# Final cost : 0.05011245554701057
# Compute control for a deterministic system
# Cost in iteration 0: 0.05011245554701057
# Converged in iteration 1 with cost 0.05011245554701057 because of step counter
# Final cost : 0.05011245554701057
# Compute control for a deterministic system
# Cost in iteration 0: 0.05011245554701057
# Converged in iteration 1 with cost 0.05011245554701057 because of step counter
# Final cost : 0.05011245554701057
# Compute control for a deterministic system
# Cost in iteration 0: 0.8728619977317525
# Final cost : 0.3997368730212643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3997368730212643
# Cost in iteration 200: 0.06894443166005271
# Cost in iteration 400: 0.06893172651309959
# Final cost : 0.06893172651309959
# Compute control for a deterministic system
# Cost in iteration 0: 0.06893172651309959
# Cost in iteration 200: 0.0689316183360563
# Final cost : 0.0689316183360563
# Compute control for a deterministic system
# Cost in iteration 0: 0.0689316183360563
# Converged in iteration 13 with cost 0.06893161813864976 because of step counter
# Final cost : 0.06893161813864976
# Compute control for a deterministic system
# Cost in iteration 0: 0.06893161813864976
# Converged in iteration 1 with cost 0.06893161813864976 because of step counter
# Final cost : 0.06893161813864976
# Compute control for a deterministic system
# Cost in iteration 0: 0.06893161813864976
# Converged in iteration 1 with cost 0.06893161813864976 because of step counter
# Final cost : 0.06893161813864976
# Compute control for a deterministic system
# Cost in iteration 0: 1.3487834736854054
# Final cost : 0.6696951154053741
# Compute control for a deterministic system
# Cost in iteration 0: 0.6696951154053741
# Cost in iteration 200: 0.08787075738938094
# Cost in iteration 400: 0.08779003649840204
# Final cost : 0.08779003649840204
# Compute control for a deterministic system
# Cost in iteration 0: 0.08779003649840204
# Converged in iteration 40 with cost 0.08778760810293539 because of vanishing difference
# Final cost : 0.08778760810293539
# Compute control for a deterministic system
# Cost in iteration 0: 0.08778760810293539
# Converged in iteration 133 with cost 0.08778752440260262 because of step counter
# Final cost : 0.08778752440260262
# Compute control for a deterministic system
# Cost in iteration 0: 0.08778752440260262
# Converged in iteration 1 with cost 0.08778752440260262 because of step counter
# Final cost : 0.08778752440260262
# Compute control for a deterministic system
# Cost in iteration 0: 0.08778752440260262
# Converged in iteration 2 with cost 0.08778752440259992 because of step counter
# Final cost : 0.08778752440259992
# Compute control for a deterministic system
# Cost in iteration 0: 1.8948299078088437
# Final cost : 1.0237028127710361
# Compute control for a deterministic system
# Cost in iteration 0: 1.0237028127710361
# Cost in iteration 200: 0.10694263510698661
# Cost in iteration 400: 0.10668388194435434
# Final cost : 0.10668388194435434
# Compute control for a deterministic system
# Cost in iteration 0: 0.10668388194435434
# Converged in iteration 71 with cost 0.1066679394043326 because of vanishing difference
# Final cost : 0.1066679394043326
# Compute control for a deterministic system
# Cost in iteration 0: 0.1066679394043326
# Cost in iteration 200: 0.10666774917943814
# Final cost : 0.10666774917943814
# Compute control for a deterministic system
# Cost in iteration 0: 0.10666774917943814
# Converged in iteration 3 with cost 0.10666774917943454 because of step counter
# Final cost : 0.10666774917943454
# Compute control for a deterministic system
# Cost in iteration 0: 0.10666774917943454
# Converged in iteration 2 with cost 0.10666774917943293 because of step counter
# Final cost : 0.10666774917943293
# Compute control for a deterministic system
# Cost in iteration 0: 2.4938192869796123
# Final cost : 1.4620464790634362
# Compute control for a deterministic system
# Cost in iteration 0: 1.4620464790634362
# Cost in iteration 200: 0.1262926217199211
# Cost in iteration 400: 0.1256275323285913
# Final cost : 0.1256275323285913
# Compute control for a deterministic system
# Cost in iteration 0: 0.1256275323285913
# Converged in iteration 104 with cost 0.1255580352066306 because of vanishing difference
# Final cost : 0.1255580352066306
# Compute control for a deterministic system
# Cost in iteration 0: 0.1255580352066306
# Cost in iteration 200: 0.1255576155444066
# Final cost : 0.1255576155444066
# Compute control for a deterministic system
# Cost in iteration 0: 0.1255576155444066
# Converged in iteration 78 with cost 0.1255576155433885 because of step counter
# Final cost : 0.1255576155433885
# Compute control for a deterministic system
# Cost in iteration 0: 0.1255576155433885
# Converged in iteration 2 with cost 0.1255576155433873 because of step counter
# Final cost : 0.1255576155433873
# Compute control for a deterministic system
# Cost in iteration 0: 3.128758213716116
# Final cost : 1.9803299038937838
# Compute control for a deterministic system
# Cost in iteration 0: 1.9803299038937838
# Cost in iteration 200: 0.14594225210507217
# Cost in iteration 400: 0.14463304860900253
# Final cost : 0.14463304860900253
# Compute control for a deterministic system
# Cost in iteration 0: 0.14463304860900253
# Converged in iteration 95 with cost 0.14442977922463773 because of vanishing difference
# Final cost : 0.14442977922463773
# Compute control for a deterministic system
# Cost in iteration 0: 0.14442977922463773
# Cost in iteration 200: 0.14442517529882554
# Final cost : 0.14442517529882554
# Compute control for a deterministic system
# Cost in iteration 0: 0.14442517529882554
# Cost in iteration 200: 0.14442517514791273
# Converged in iteration 203 with cost 0.14442517514790493 because of step counter
# Final cost : 0.14442517514790493
# Compute control for a deterministic system
# Cost in iteration 0: 0.14442517514790493
# Converged in iteration 1 with cost 0.14442517514790493 because of step counter
# Final cost : 0.14442517514790493
# Compute control for a deterministic system
# Cost in iteration 0: 3.6181267930823697
# Final cost : 2.416344911035969
# Compute control for a deterministic system
# Cost in iteration 0: 2.416344911035969
# Cost in iteration 200: 0.16092531754926015
# Cost in iteration 400: 0.15892305776010426
# Final cost : 0.15892305776010426
# Compute control for a deterministic system
# Cost in iteration 0: 0.15892305776010426
# Cost in iteration 200: 0.15851774325920356
# Final cost : 0.15851774325920356
# Compute control for a deterministic system
# Cost in iteration 0: 0.15851774325920356
# Cost in iteration 200: 0.15851738362399742
# Final cost : 0.15851738362399742
# Compute control for a deterministic system
# Cost in iteration 0: 0.15851738362399742
# Cost in iteration 200: 0.15851738355879247
# Converged in iteration 220 with cost 0.15851738355876455 because of vanishing difference
# Final cost : 0.15851738355876455
# Compute control for a deterministic system
# Cost in iteration 0: 0.15851738355876455
# Converged in iteration 4 with cost 0.15851738355876266 because of vanishing difference
# Final cost : 0.15851738355876266
# Compute control for a deterministic system
# Cost in iteration 0: 4.273808349108581
# Final cost : 3.0507633361086066
# Compute control for a deterministic system
# Cost in iteration 0: 3.0507633361086066
# Cost in iteration 200: 0.1812428978552465
# Cost in iteration 400: 0.17802551358631882
# Final cost : 0.17802551358631882
# Compute control for a deterministic system
# Cost in iteration 0: 0.17802551358631882
# Cost in iteration 200: 0.17717246010688448
# Final cost : 0.17717246010688448
# Compute control for a deterministic system
# Cost in iteration 0: 0.17717246010688448
# Cost in iteration 200: 0.177170575591111
# Final cost : 0.177170575591111
# Compute control for a deterministic system
# Cost in iteration 0: 0.177170575591111
# Cost in iteration 200: 0.1771705743275258
# Converged in iteration 357 with cost 0.17717057432405456 because of step counter
# Final cost : 0.17717057432405456
# Compute control for a deterministic system
# Cost in iteration 0: 0.17717057432405456
# Converged in iteration 1 with cost 0.17717057432405456 because of step counter
# Final cost : 0.17717057432405456
# Compute control for a deterministic system
# Cost in iteration 0: 4.9169177454514195
# Final cost : 3.7318423258222047
# Compute control for a deterministic system
# Cost in iteration 0: 3.7318423258222047
# Cost in iteration 200: 0.20203067884251438
# Cost in iteration 400: 0.19728272194828753
# Final cost : 0.19728272194828753
# Compute control for a deterministic system
# Cost in iteration 0: 0.19728272194828753
# Cost in iteration 200: 0.19569778861199463
# Final cost : 0.19569778861199463
# Compute control for a deterministic system
# Cost in iteration 0: 0.19569778861199463
# Cost in iteration 200: 0.1956900404736708
# Final cost : 0.1956900404736708
# Compute control for a deterministic system
# Cost in iteration 0: 0.1956900404736708
# Cost in iteration 200: 0.1956900289385348
# Cost in iteration 400: 0.19569002886056552
# Final cost : 0.19569002886056552
# Compute control for a deterministic system
# Cost in iteration 0: 0.19569002886056552
# Converged in iteration 74 with cost 0.1956900288601326 because of vanishing difference
# Final cost : 0.1956900288601326
# Compute control for a deterministic system
# Cost in iteration 0: 5.530544162137875
# Final cost : 4.441932050714356
# Compute control for a deterministic system
# Cost in iteration 0: 4.441932050714356
# Cost in iteration 200: 0.2236640253003742
# Cost in iteration 400: 0.21691447146314352
# Final cost : 0.21691447146314352
# Compute control for a deterministic system
# Cost in iteration 0: 0.21691447146314352
# Cost in iteration 200: 0.2141904800208597
# Final cost : 0.2141904800208597
# Compute control for a deterministic system
# Cost in iteration 0: 0.2141904800208597
# Converged in iteration 64 with cost 0.2141724081973075 because of vanishing difference
# Final cost : 0.2141724081973075
# Compute control for a deterministic system
# Cost in iteration 0: 0.2141724081973075
# Cost in iteration 200: 0.21416929164143503
# Cost in iteration 400: 0.21416924905890963
# Final cost : 0.21416924905890963
# Compute control for a deterministic system
# Cost in iteration 0: 0.21416924905890963
# Cost in iteration 200: 0.2141692484690575
# Cost in iteration 400: 0.21416924845633437
# Converged in iteration 459 with cost 0.21416924845605873 because of step counter
# Final cost : 0.21416924845605873
# Compute control for a deterministic system
# Cost in iteration 0: 6.098886406613899
# Final cost : 5.159643680251965
# Compute control for a deterministic system
# Cost in iteration 0: 5.159643680251965
# Cost in iteration 200: 0.24619955139786392
# Cost in iteration 400: 0.23710299620033157
# Final cost : 0.23710299620033157
# Compute control for a deterministic system
# Cost in iteration 0: 0.23710299620033157
# Cost in iteration 200: 0.23272532835105875
# Final cost : 0.23272532835105875
# Compute control for a deterministic system
# Cost in iteration 0: 0.23272532835105875
# Cost in iteration 200: 0.23267655433920764
# Final cost : 0.23267655433920764
# Compute control for a deterministic system
# Cost in iteration 0: 0.23267655433920764
# Cost in iteration 200: 0.23267623598545834
# Cost in iteration 400: 0.2326762280121234
# Final cost : 0.2326762280121234
# Compute control for a deterministic system
# Cost in iteration 0: 0.2326762280121234
# Cost in iteration 200: 0.232676227810237
# Cost in iteration 400: 0.2326762278029751
# Converged in iteration 484 with cost 0.23267622780270306 because of step counter
# Final cost : 0.23267622780270306
# Compute control for a deterministic system
# Cost in iteration 0: 6.607510205292968
# Final cost : 5.857861358901264
# Compute control for a deterministic system
# Cost in iteration 0: 5.857861358901264
# Cost in iteration 200: 0.26988236569356583
# Cost in iteration 400: 0.2580222940869775
# Final cost : 0.2580222940869775
# Compute control for a deterministic system
# Cost in iteration 0: 0.2580222940869775
# Cost in iteration 200: 0.25134442336955687
# Final cost : 0.25134442336955687
# Compute control for a deterministic system
# Cost in iteration 0: 0.25134442336955687
# Converged in iteration 54 with cost 0.2512663545494684 because of vanishing difference
# Final cost : 0.2512663545494684
# Compute control for a deterministic system
# Cost in iteration 0: 0.2512663545494684
# Cost in iteration 200: 0.25123527595823386
# Cost in iteration 400: 0.2512340418462336
# Final cost : 0.2512340418462336
# Compute control for a deterministic system
# Cost in iteration 0: 0.2512340418462336
# Cost in iteration 200: 0.251233990531115
# Cost in iteration 400: 0.2512339876274251
# Cost in iteration 600: 0.2512339874619835
# Cost in iteration 800: 0.25123398745252484
# Converged in iteration 893 with cost 0.25123398745195735 because of step counter
# Final cost : 0.25123398745195735
# Compute control for a deterministic system
# Cost in iteration 0: 6.942204399295588
# Final cost : 6.348776324844785
# Compute control for a deterministic system
# Cost in iteration 0: 6.348776324844785
# Cost in iteration 200: 0.28839169212733257
# Cost in iteration 400: 0.27422876556063985
# Final cost : 0.27422876556063985
# Compute control for a deterministic system
# Cost in iteration 0: 0.27422876556063985
# Cost in iteration 200: 0.2653619706887173
# Final cost : 0.2653619706887173
# Compute control for a deterministic system
# Cost in iteration 0: 0.2653619706887173
# Cost in iteration 200: 0.2651889027216211
# Final cost : 0.2651889027216211
# Compute control for a deterministic system
# Cost in iteration 0: 0.2651889027216211
# Cost in iteration 200: 0.26518618723274723
# Cost in iteration 400: 0.2651860313347832
# Final cost : 0.2651860313347832
# Compute control for a deterministic system
# Cost in iteration 0: 0.2651860313347832
# Cost in iteration 200: 0.26518602247219014
# Cost in iteration 400: 0.26518602179140743
# Cost in iteration 600: 0.2651860217396911
# Cost in iteration 800: 0.26518602173574946
# Converged in iteration 859 with cost 0.2651860217354305 because of step counter
# Final cost : 0.2651860217354305
# Compute control for a deterministic system
# Cost in iteration 0: 7.318097040080531
# Final cost : 6.930291142882556
# Compute control for a deterministic system
# Cost in iteration 0: 6.930291142882556
# Cost in iteration 200: 0.31470323236369735
# Cost in iteration 400: 0.29687079414382794
# Final cost : 0.29687079414382794
# Compute control for a deterministic system
# Cost in iteration 0: 0.29687079414382794
# Cost in iteration 200: 0.2841398494283095
# Final cost : 0.2841398494283095
# Compute control for a deterministic system
# Cost in iteration 0: 0.2841398494283095
# Cost in iteration 200: 0.28383485807340664
# Final cost : 0.28383485807340664
# Compute control for a deterministic system
# Cost in iteration 0: 0.28383485807340664
# Cost in iteration 200: 0.28382780809906977
# Cost in iteration 400: 0.2838272245114925
# Final cost : 0.2838272245114925
# Compute control for a deterministic system
# Cost in iteration 0: 0.2838272245114925
# Cost in iteration 200: 0.283827176161075
# Cost in iteration 400: 0.28382717098832644
# Cost in iteration 600: 0.2838271704298088
# Cost in iteration 800: 0.28382717037009
# Cost in iteration 1000: 0.28382717036369637
# Final cost : 0.28382717036369637
# Compute control for a deterministic system
# Cost in iteration 0: 7.607318418943938
# Final cost : 7.39740323993469
# Compute control for a deterministic system
# Cost in iteration 0: 7.39740323993469
# Cost in iteration 200: 0.34281078575082624
# Cost in iteration 400: 0.3207180894685631
# Final cost : 0.3207180894685631
# Compute control for a deterministic system
# Cost in iteration 0: 0.3207180894685631
# Cost in iteration 200: 0.3030444069403281
# Final cost : 0.3030444069403281
# Compute control for a deterministic system
# Cost in iteration 0: 0.3030444069403281
# Converged in iteration 110 with cost 0.3025765644024978 because of vanishing difference
# Final cost : 0.3025765644024978
# Compute control for a deterministic system
# Cost in iteration 0: 0.3025765644024978
# Cost in iteration 200: 0.30251072524756734
# Cost in iteration 400: 0.30250361717361435
# Final cost : 0.30250361717361435
# Compute control for a deterministic system
# Cost in iteration 0: 0.30250361717361435
# Cost in iteration 200: 0.3025028275052464
# Cost in iteration 400: 0.30250271572825566
# Cost in iteration 600: 0.3025026997955195
# Cost in iteration 800: 0.30250269750582726
# Cost in iteration 1000: 0.30250269718018585
# Final cost : 0.30250269718018585
# Compute control for a deterministic system
# Cost in iteration 0: 7.806041632638515
# Final cost : 7.725564878481821
# Compute control for a deterministic system
# Cost in iteration 0: 7.725564878481821
# Cost in iteration 200: 0.37326035861722623
# Cost in iteration 400: 0.3461607992158457
# Final cost : 0.3461607992158457
# Compute control for a deterministic system
# Cost in iteration 0: 0.3461607992158457
# Cost in iteration 200: 0.3220536038955222
# Final cost : 0.3220536038955222
# Compute control for a deterministic system
# Cost in iteration 0: 0.3220536038955222
# Converged in iteration 62 with cost 0.3214752216089721 because of vanishing difference
# Final cost : 0.3214752216089721
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214752216089721
# Cost in iteration 200: 0.32123779536176456
# Cost in iteration 400: 0.3212072530978099
# Final cost : 0.3212072530978099
# Compute control for a deterministic system
# Cost in iteration 0: 0.3212072530978099
# Cost in iteration 200: 0.32120293217030566
# Cost in iteration 400: 0.32120216288871634
# Cost in iteration 600: 0.3212020234087613
# Cost in iteration 800: 0.3212019980645568
# Cost in iteration 1000: 0.32120199344035116
# Final cost : 0.32120199344035116
# Compute control for a deterministic system
# Cost in iteration 0: 7.912894710145015
# Final cost : 7.901960908371765
# Compute control for a deterministic system
# Cost in iteration 0: 7.901960908371765
# Cost in iteration 200: 0.4095621424555286
# Cost in iteration 400: 0.3735719013333998
# Final cost : 0.3735719013333998
# Compute control for a deterministic system
# Cost in iteration 0: 0.3735719013333998
# Cost in iteration 200: 0.341241700759785
# Final cost : 0.341241700759785
# Compute control for a deterministic system
# Cost in iteration 0: 0.341241700759785
# Cost in iteration 200: 0.3399800134185855
# Final cost : 0.3399800134185855
# Compute control for a deterministic system
# Cost in iteration 0: 0.3399800134185855
# Cost in iteration 200: 0.3399273550698576
# Cost in iteration 400: 0.3399179286332531
# Final cost : 0.3399179286332531
# Compute control for a deterministic system
# Cost in iteration 0: 0.3399179286332531
# Cost in iteration 200: 0.3399162320618024
# Cost in iteration 400: 0.3399158565687164
# Cost in iteration 600: 0.3399157721977891
# Cost in iteration 800: 0.3399157533262168
# Cost in iteration 1000: 0.33991574908653066
# Final cost : 0.33991574908653066
# Compute control for a deterministic system
# Cost in iteration 0: 7.932838334768423
# Converged in iteration 1 with cost 7.932838334768423 because of step counter
# Final cost : 7.932838334768423
# Compute control for a deterministic system
# Cost in iteration 0: 7.932838334768423
# Converged in iteration 1 with cost 7.932838334768423 because of step counter
# Final cost : 7.932838334768423
# Compute control for a deterministic system
# Cost in iteration 0: 7.932838334768423
# Converged in iteration 1 with cost 7.932838334768423 because of step counter
# Final cost : 7.932838334768423
# Compute control for a deterministic system
# Cost in iteration 0: 7.932838334768423
# Cost in iteration 200: 0.3695225410425251
# Final cost : 0.3695225410425251
# Compute control for a deterministic system
# Cost in iteration 0: 0.3695225410425251
# Cost in iteration 200: 0.36759249701356617
# Cost in iteration 400: 0.36739940252297076
# Final cost : 0.36739940252297076
# Compute control for a deterministic system
# Cost in iteration 0: 0.36739940252297076
# Cost in iteration 200: 0.3673701875766612
# Cost in iteration 400: 0.36736402782790323
# Cost in iteration 600: 0.36736267152788776
# Cost in iteration 800: 0.36736237474779804
# Cost in iteration 1000: 0.36736230883259113
# Final cost : 0.36736230883259113
# Compute control for a deterministic system
# Cost in iteration 0: 7.880095716700625
# Final cost : 7.8516290527432275
# Compute control for a deterministic system
# Cost in iteration 0: 7.8516290527432275
# Cost in iteration 200: 0.4162110534347268
# Cost in iteration 400: 0.3814762187377516
# Final cost : 0.3814762187377516
# Compute control for a deterministic system
# Cost in iteration 0: 0.3814762187377516
# Cost in iteration 200: 0.3491626808756457
# Final cost : 0.3491626808756457
# Compute control for a deterministic system
# Cost in iteration 0: 0.3491626808756457
# Cost in iteration 200: 0.34800409679693917
# Final cost : 0.34800409679693917
# Compute control for a deterministic system
# Cost in iteration 0: 0.34800409679693917
# Cost in iteration 200: 0.34797557288582665
# Cost in iteration 400: 0.34797154253717927
# Final cost : 0.34797154253717927
# Compute control for a deterministic system
# Cost in iteration 0: 0.34797154253717927
# Cost in iteration 200: 0.34797092940162044
# Cost in iteration 400: 0.3479708181498038
# Cost in iteration 600: 0.347970797733426
# Cost in iteration 800: 0.3479707939927706
# Cost in iteration 1000: 0.34797079330559577
# Final cost : 0.34797079330559577
# Compute control for a deterministic system
# Cost in iteration 0: 7.738506439100568
# Final cost : 7.621407125258262
# Compute control for a deterministic system
# Cost in iteration 0: 7.621407125258262
# Cost in iteration 200: 0.3822115946745229
# Cost in iteration 400: 0.3537241445515912
# Final cost : 0.3537241445515912
# Compute control for a deterministic system
# Cost in iteration 0: 0.3537241445515912
# Cost in iteration 200: 0.3292865071713725
# Final cost : 0.3292865071713725
# Compute control for a deterministic system
# Cost in iteration 0: 0.3292865071713725
# Cost in iteration 200: 0.32857814579162575
# Final cost : 0.32857814579162575
# Compute control for a deterministic system
# Cost in iteration 0: 0.32857814579162575
# Cost in iteration 200: 0.3285672032028434
# Cost in iteration 400: 0.3285659495920386
# Final cost : 0.3285659495920386
# Compute control for a deterministic system
# Cost in iteration 0: 0.3285659495920386
# Cost in iteration 200: 0.3285658024617539
# Cost in iteration 400: 0.328565781193036
# Cost in iteration 600: 0.32856577809915727
# Cost in iteration 800: 0.3285657776485999
# Cost in iteration 1000: 0.32856577758296435
# Final cost : 0.32856577758296435
# Compute control for a deterministic system
# Cost in iteration 0: 7.510990640715474
# Final cost : 7.252813717645405
# Compute control for a deterministic system
# Cost in iteration 0: 7.252813717645405
# Cost in iteration 200: 0.3509311958689995
# Cost in iteration 400: 0.32759103854521815
# Final cost : 0.32759103854521815
# Compute control for a deterministic system
# Cost in iteration 0: 0.32759103854521815
# Cost in iteration 200: 0.3095728006887675
# Final cost : 0.3095728006887675
# Compute control for a deterministic system
# Cost in iteration 0: 0.3095728006887675
# Converged in iteration 130 with cost 0.3091463715936258 because of vanishing difference
# Final cost : 0.3091463715936258
# Compute control for a deterministic system
# Cost in iteration 0: 0.3091463715936258
# Cost in iteration 200: 0.3091278720769723
# Cost in iteration 400: 0.3091263200028157
# Final cost : 0.3091263200028157
# Compute control for a deterministic system
# Cost in iteration 0: 0.3091263200028157
# Cost in iteration 200: 0.3091261855209738
# Cost in iteration 400: 0.30912617063772607
# Cost in iteration 600: 0.30912616900757794
# Cost in iteration 800: 0.30912616882837957
# Cost in iteration 1000: 0.3091261688086616
# Final cost : 0.3091261688086616
# Compute control for a deterministic system
# Cost in iteration 0: 7.201613925627095
# Final cost : 6.763344220961247
# Compute control for a deterministic system
# Cost in iteration 0: 6.763344220961247
# Cost in iteration 200: 0.32176444499918483
# Cost in iteration 400: 0.30292408643325464
# Final cost : 0.30292408643325464
# Compute control for a deterministic system
# Cost in iteration 0: 0.30292408643325464
# Cost in iteration 200: 0.2899129366976783
# Final cost : 0.2899129366976783
# Compute control for a deterministic system
# Cost in iteration 0: 0.2899129366976783
# Converged in iteration 21 with cost 0.2898147907299314 because of vanishing difference
# Final cost : 0.2898147907299314
# Compute control for a deterministic system
# Cost in iteration 0: 0.2898147907299314
# Cost in iteration 200: 0.2896666961273887
# Cost in iteration 400: 0.2896604878248466
# Final cost : 0.2896604878248466
# Compute control for a deterministic system
# Cost in iteration 0: 0.2896604878248466
# Cost in iteration 200: 0.2896601280881074
# Cost in iteration 400: 0.28966009964511263
# Cost in iteration 600: 0.2896600974377748
# Cost in iteration 800: 0.28966009726456105
# Cost in iteration 1000: 0.28966009725093167
# Final cost : 0.28966009725093167
# Compute control for a deterministic system
# Cost in iteration 0: 6.815722759789974
# Final cost : 6.178392720775107
# Compute control for a deterministic system
# Cost in iteration 0: 6.178392720775107
# Cost in iteration 200: 0.29433688572669187
# Cost in iteration 400: 0.2794317925204017
# Final cost : 0.2794317925204017
# Compute control for a deterministic system
# Cost in iteration 0: 0.2794317925204017
# Cost in iteration 200: 0.27032429620322146
# Final cost : 0.27032429620322146
# Compute control for a deterministic system
# Cost in iteration 0: 0.27032429620322146
# Converged in iteration 60 with cost 0.2702210157199457 because of vanishing difference
# Final cost : 0.2702210157199457
# Compute control for a deterministic system
# Cost in iteration 0: 0.2702210157199457
# Cost in iteration 200: 0.27020020280352103
# Cost in iteration 400: 0.2701995563810313
# Final cost : 0.2701995563810313
# Compute control for a deterministic system
# Cost in iteration 0: 0.2701995563810313
# Cost in iteration 200: 0.2701995308868481
# Cost in iteration 400: 0.27019952954845544
# Cost in iteration 600: 0.2701995294768848
# Cost in iteration 800: 0.27019952947314047
# Converged in iteration 876 with cost 0.2701995294729535 because of vanishing difference
# Final cost : 0.2701995294729535
# Compute control for a deterministic system
# Cost in iteration 0: 6.480127969075941
# Final cost : 5.695376967156266
# Compute control for a deterministic system
# Cost in iteration 0: 5.695376967156266
# Cost in iteration 200: 0.27482151715154773
# Cost in iteration 400: 0.2624804918923171
# Final cost : 0.2624804918923171
# Compute control for a deterministic system
# Cost in iteration 0: 0.2624804918923171
# Cost in iteration 200: 0.25569221019924926
# Final cost : 0.25569221019924926
# Compute control for a deterministic system
# Cost in iteration 0: 0.25569221019924926
# Cost in iteration 200: 0.2556195346904344
# Final cost : 0.2556195346904344
# Compute control for a deterministic system
# Cost in iteration 0: 0.2556195346904344
# Cost in iteration 200: 0.25561935166496963
# Cost in iteration 400: 0.2556193469058116
# Final cost : 0.2556193469058116
# Compute control for a deterministic system
# Cost in iteration 0: 0.2556193469058116
# Cost in iteration 200: 0.25561934676888526
# Cost in iteration 400: 0.2556193467637774
# Converged in iteration 433 with cost 0.25561934676369474 because of step counter
# Final cost : 0.25561934676369474
# Compute control for a deterministic system
# Cost in iteration 0: 5.977326606102922
# Final cost : 5.01650036242374
# Compute control for a deterministic system
# Cost in iteration 0: 5.01650036242374
# Cost in iteration 200: 0.24999039765033462
# Cost in iteration 400: 0.24063598054260626
# Final cost : 0.24063598054260626
# Compute control for a deterministic system
# Cost in iteration 0: 0.24063598054260626
# Cost in iteration 200: 0.23624525513972025
# Final cost : 0.23624525513972025
# Compute control for a deterministic system
# Cost in iteration 0: 0.23624525513972025
# Cost in iteration 200: 0.236211197539146
# Final cost : 0.236211197539146
# Compute control for a deterministic system
# Cost in iteration 0: 0.236211197539146
# Cost in iteration 200: 0.2362111568840114
# Cost in iteration 400: 0.23621115632982537
# Final cost : 0.23621115632982537
# Compute control for a deterministic system
# Cost in iteration 0: 0.23621115632982537
# Cost in iteration 200: 0.23621115632313017
# Converged in iteration 265 with cost 0.23621115632298706 because of step counter
# Final cost : 0.23621115632298706
# Compute control for a deterministic system
# Cost in iteration 0: 5.419364823534784
# Final cost : 4.321600225040396
# Compute control for a deterministic system
# Cost in iteration 0: 4.321600225040396
# Cost in iteration 200: 0.22640582518161345
# Cost in iteration 400: 0.21956809784729617
# Final cost : 0.21956809784729617
# Compute control for a deterministic system
# Cost in iteration 0: 0.21956809784729617
# Cost in iteration 200: 0.21686664773872485
# Final cost : 0.21686664773872485
# Compute control for a deterministic system
# Cost in iteration 0: 0.21686664773872485
# Cost in iteration 200: 0.21685331260482932
# Final cost : 0.21685331260482932
# Compute control for a deterministic system
# Cost in iteration 0: 0.21685331260482932
# Cost in iteration 200: 0.21685329581126903
# Cost in iteration 400: 0.2168532956706478
# Final cost : 0.2168532956706478
# Compute control for a deterministic system
# Cost in iteration 0: 0.2168532956706478
# Converged in iteration 132 with cost 0.21685329566954417 because of vanishing difference
# Final cost : 0.21685329566954417
# Compute control for a deterministic system
# Cost in iteration 0: 4.81796820956996
# Final cost : 3.6335984600631215
# Compute control for a deterministic system
# Cost in iteration 0: 3.6335984600631215
# Cost in iteration 200: 0.20395666535901302
# Cost in iteration 400: 0.19913092319244916
# Final cost : 0.19913092319244916
# Compute control for a deterministic system
# Cost in iteration 0: 0.19913092319244916
# Cost in iteration 200: 0.19755907278843757
# Final cost : 0.19755907278843757
# Compute control for a deterministic system
# Cost in iteration 0: 0.19755907278843757
# Converged in iteration 4 with cost 0.1975582873869113 because of vanishing difference
# Final cost : 0.1975582873869113
# Compute control for a deterministic system
# Cost in iteration 0: 0.1975582873869113
# Cost in iteration 200: 0.19755433659598845
# Cost in iteration 400: 0.1975543196812355
# Final cost : 0.1975543196812355
# Compute control for a deterministic system
# Cost in iteration 0: 0.1975543196812355
# Cost in iteration 200: 0.19755431960607475
# Converged in iteration 292 with cost 0.19755431960558115 because of step counter
# Final cost : 0.19755431960558115
# Compute control for a deterministic system
# Cost in iteration 0: 4.188669629364228
# Final cost : 2.973458393812587
# Compute control for a deterministic system
# Cost in iteration 0: 2.973458393812587
# Cost in iteration 200: 0.18228521604457015
# Cost in iteration 400: 0.17913523993845296
# Final cost : 0.17913523993845296
# Compute control for a deterministic system
# Cost in iteration 0: 0.17913523993845296
# Cost in iteration 200: 0.1783166154711711
# Final cost : 0.1783166154711711
# Compute control for a deterministic system
# Cost in iteration 0: 0.1783166154711711
# Cost in iteration 200: 0.17831537047503557
# Final cost : 0.17831537047503557
# Compute control for a deterministic system
# Cost in iteration 0: 0.17831537047503557
# Cost in iteration 200: 0.17831537030789155
# Converged in iteration 274 with cost 0.1783153703076591 because of step counter
# Final cost : 0.1783153703076591
# Compute control for a deterministic system
# Cost in iteration 0: 0.1783153703076591
# Converged in iteration 1 with cost 0.1783153703076591 because of step counter
# Final cost : 0.1783153703076591
# Compute control for a deterministic system
# Cost in iteration 0: 3.5482825157682907
# Final cost : 2.358860407122653
# Compute control for a deterministic system
# Cost in iteration 0: 2.358860407122653
# Cost in iteration 200: 0.16147366897539606
# Cost in iteration 400: 0.1595151052073582
# Final cost : 0.1595151052073582
# Compute control for a deterministic system
# Cost in iteration 0: 0.1595151052073582
# Converged in iteration 92 with cost 0.1591442087253255 because of vanishing difference
# Final cost : 0.1591442087253255
# Compute control for a deterministic system
# Cost in iteration 0: 0.1591442087253255
# Cost in iteration 200: 0.15913407734078996
# Final cost : 0.15913407734078996
# Compute control for a deterministic system
# Cost in iteration 0: 0.15913407734078996
# Cost in iteration 200: 0.15913407716775305
# Converged in iteration 222 with cost 0.15913407716769862 because of vanishing difference
# Final cost : 0.15913407716769862
# Compute control for a deterministic system
# Cost in iteration 0: 0.15913407716769862
# Converged in iteration 3 with cost 0.15913407716769498 because of step counter
# Final cost : 0.15913407716769498
# Compute control for a deterministic system
# Cost in iteration 0: 3.070672659264437
# Final cost : 1.936333472264554
# Compute control for a deterministic system
# Cost in iteration 0: 1.936333472264554
# Cost in iteration 200: 0.1462323393160343
# Cost in iteration 400: 0.14497898918250787
# Final cost : 0.14497898918250787
# Compute control for a deterministic system
# Cost in iteration 0: 0.14497898918250787
# Cost in iteration 200: 0.14478370478748068
# Final cost : 0.14478370478748068
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478370478748068
# Cost in iteration 200: 0.14478366451096297
# Final cost : 0.14478366451096297
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478366451096297
# Converged in iteration 28 with cost 0.14478366451086638 because of step counter
# Final cost : 0.14478366451086638
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478366451086638
# Converged in iteration 1 with cost 0.14478366451086638 because of step counter
# Final cost : 0.14478366451086638
# Compute control for a deterministic system
# Cost in iteration 0: 2.450442271837314
# Final cost : 1.4330553267469477
# Compute control for a deterministic system
# Cost in iteration 0: 1.4330553267469477
# Cost in iteration 200: 0.12637677301080452
# Cost in iteration 400: 0.12575763448127616
# Final cost : 0.12575763448127616
# Compute control for a deterministic system
# Cost in iteration 0: 0.12575763448127616
# Cost in iteration 200: 0.12569462192133715
# Final cost : 0.12569462192133715
# Compute control for a deterministic system
# Cost in iteration 0: 0.12569462192133715
# Converged in iteration 139 with cost 0.1256946195800135 because of vanishing difference
# Final cost : 0.1256946195800135
# Compute control for a deterministic system
# Cost in iteration 0: 0.1256946195800135
# Converged in iteration 10 with cost 0.12569461957999864 because of vanishing difference
# Final cost : 0.12569461957999864
# Compute control for a deterministic system
# Cost in iteration 0: 0.12569461957999864
# Converged in iteration 10 with cost 0.12569461957999012 because of step counter
# Final cost : 0.12569461957999012
# Compute control for a deterministic system
# Cost in iteration 0: 1.8640351935083146
# Final cost : 1.0058193573696075
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058193573696075
# Cost in iteration 200: 0.10692045549163616
# Cost in iteration 400: 0.10667057360849877
# Final cost : 0.10667057360849877
# Compute control for a deterministic system
# Cost in iteration 0: 0.10667057360849877
# Converged in iteration 91 with cost 0.10665527603179886 because of vanishing difference
# Final cost : 0.10665527603179886
# Compute control for a deterministic system
# Cost in iteration 0: 0.10665527603179886
# Converged in iteration 147 with cost 0.1066552443639981 because of step counter
# Final cost : 0.1066552443639981
# Compute control for a deterministic system
# Cost in iteration 0: 0.1066552443639981
# Converged in iteration 1 with cost 0.1066552443639981 because of step counter
# Final cost : 0.1066552443639981
# Compute control for a deterministic system
# Cost in iteration 0: 0.1066552443639981
# Converged in iteration 1 with cost 0.1066552443639981 because of step counter
# Final cost : 0.1066552443639981
# Compute control for a deterministic system
# Cost in iteration 0: 1.328033136025491
# Final cost : 0.6593213338819568
# Compute control for a deterministic system
# Cost in iteration 0: 0.6593213338819568
# Cost in iteration 200: 0.08774191223876421
# Cost in iteration 400: 0.08766795486225022
# Final cost : 0.08766795486225022
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766795486225022
# Cost in iteration 200: 0.08766590170995428
# Final cost : 0.08766590170995428
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766590170995428
# Converged in iteration 16 with cost 0.08766590170989495 because of step counter
# Final cost : 0.08766590170989495
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766590170989495
# Converged in iteration 1 with cost 0.08766590170989495 because of step counter
# Final cost : 0.08766590170989495
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766590170989495
# Converged in iteration 2 with cost 0.08766590170989488 because of step counter
# Final cost : 0.08766590170989488
# Compute control for a deterministic system
# Cost in iteration 0: 0.8596397962083568
# Final cost : 0.39400771464642864
# Compute control for a deterministic system
# Cost in iteration 0: 0.39400771464642864
# Cost in iteration 200: 0.06874187443418556
# Cost in iteration 400: 0.06872998057862223
# Final cost : 0.06872998057862223
# Compute control for a deterministic system
# Cost in iteration 0: 0.06872998057862223
# Converged in iteration 143 with cost 0.06872988591891034 because of step counter
# Final cost : 0.06872988591891034
# Compute control for a deterministic system
# Cost in iteration 0: 0.06872988591891034
# Converged in iteration 1 with cost 0.06872988591891034 because of step counter
# Final cost : 0.06872988591891034
# Compute control for a deterministic system
# Cost in iteration 0: 0.06872988591891034
# Converged in iteration 2 with cost 0.06872988591891004 because of vanishing difference
# Final cost : 0.06872988591891004
# Compute control for a deterministic system
# Cost in iteration 0: 0.06872988591891004
# Converged in iteration 2 with cost 0.06872988591890995 because of step counter
# Final cost : 0.06872988591890995
# Compute control for a deterministic system
# Cost in iteration 0: 0.5633987951457037
# Final cost : 0.24579933202644932
# Compute control for a deterministic system
# Cost in iteration 0: 0.24579933202644932
# Cost in iteration 200: 0.05456848385509186
# Cost in iteration 400: 0.054567041392706225
# Final cost : 0.054567041392706225
# Compute control for a deterministic system
# Cost in iteration 0: 0.054567041392706225
# Converged in iteration 89 with cost 0.05456703865863044 because of step counter
# Final cost : 0.05456703865863044
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703865863044
# Converged in iteration 2 with cost 0.05456703865863009 because of step counter
# Final cost : 0.05456703865863009
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703865863009
# Converged in iteration 4 with cost 0.054567038658628525 because of step counter
# Final cost : 0.054567038658628525
# Compute control for a deterministic system
# Cost in iteration 0: 0.054567038658628525
# Converged in iteration 1 with cost 0.054567038658628525 because of step counter
# Final cost : 0.054567038658628525
# Compute control for a deterministic system
# Cost in iteration 0: 0.2561038639198099
# Final cost : 0.10887280847416086
# Compute control for a deterministic system
# Cost in iteration 0: 0.10887280847416086
# Cost in iteration 200: 0.0357451892297908
# Converged in iteration 205 with cost 0.035745187364809236 because of vanishing difference
# Final cost : 0.035745187364809236
# Compute control for a deterministic system
# Cost in iteration 0: 0.035745187364809236
# Converged in iteration 77 with cost 0.0357451796142725 because of step counter
# Final cost : 0.0357451796142725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0357451796142725
# Converged in iteration 1 with cost 0.0357451796142725 because of step counter
# Final cost : 0.0357451796142725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0357451796142725
# Converged in iteration 1 with cost 0.0357451796142725 because of step counter
# Final cost : 0.0357451796142725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0357451796142725
# Converged in iteration 1 with cost 0.0357451796142725 because of step counter
# Final cost : 0.0357451796142725
# Compute control for a deterministic system
# Cost in iteration 0: 0.06413472522011136
# Final cost : 0.030503695613260592
# Compute control for a deterministic system
# Cost in iteration 0: 0.030503695613260592
# Converged in iteration 82 with cost 0.017012696799611798 because of vanishing difference
# Final cost : 0.017012696799611798
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012696799611798
# Converged in iteration 27 with cost 0.017012692764950946 because of step counter
# Final cost : 0.017012692764950946
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692764950946
# Converged in iteration 1 with cost 0.017012692764950946 because of step counter
# Final cost : 0.017012692764950946
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692764950946
# Converged in iteration 1 with cost 0.017012692764950946 because of step counter
# Final cost : 0.017012692764950946
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692764950946
# Converged in iteration 1 with cost 0.017012692764950946 because of step counter
# Final cost : 0.017012692764950946
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8439292041399223e-05
# Converged in iteration 1 with cost 1.8439292041399223e-05 because of step counter
# Final cost : 1.8439292041399223e-05
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09679298558807098
# Cost in iteration 200: 0.036031422712577456
# Final cost : 0.036031422712577456
# Compute control for a deterministic system
# Cost in iteration 0: 0.036031422712577456
# Converged in iteration 100 with cost 0.036031415559805414 because of step counter
# Final cost : 0.036031415559805414
# Compute control for a deterministic system
# Cost in iteration 0: 0.036031415559805414
# Converged in iteration 1 with cost 0.036031415559805414 because of step counter
# Final cost : 0.036031415559805414
# Compute control for a deterministic system
# Cost in iteration 0: 0.036031415559805414
# Converged in iteration 1 with cost 0.036031415559805414 because of step counter
# Final cost : 0.036031415559805414
# Compute control for a deterministic system
# Cost in iteration 0: 0.036031415559805414
# Converged in iteration 1 with cost 0.036031415559805414 because of step counter
# Final cost : 0.036031415559805414
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.07901210615821462
# Cost in iteration 200: 0.050112614406049714
# Final cost : 0.050112614406049714
# Compute control for a deterministic system
# Cost in iteration 0: 0.050112614406049714
# Converged in iteration 7 with cost 0.050112476842732095 because of vanishing difference
# Final cost : 0.050112476842732095
# Compute control for a deterministic system
# Cost in iteration 0: 0.050112476842732095
# Converged in iteration 65 with cost 0.050112462182040116 because of step counter
# Final cost : 0.050112462182040116
# Compute control for a deterministic system
# Cost in iteration 0: 0.050112462182040116
# Converged in iteration 1 with cost 0.050112462182040116 because of step counter
# Final cost : 0.050112462182040116
# Compute control for a deterministic system
# ...
# Final cost : 0.3091261221592418
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.3875940910985329
# Cost in iteration 200: 0.28966382427043874
# Final cost : 0.28966382427043874
# Compute control for a deterministic system
# Cost in iteration 0: 0.28966382427043874
# Cost in iteration 200: 0.28966001637576033
# Final cost : 0.28966001637576033
# Compute control for a deterministic system
# Cost in iteration 0: 0.28966001637576033
# Cost in iteration 200: 0.2896600133389043
# Final cost : 0.2896600133389043
# Compute control for a deterministic system
# Cost in iteration 0: 0.2896600133389043
# Cost in iteration 200: 0.28966001331984437
# Converged in iteration 316 with cost 0.2896600133188267 because of vanishing difference
# Final cost : 0.2896600133188267
# Compute control for a deterministic system
# Cost in iteration 0: 0.2896600133188267
# Converged in iteration 10 with cost 0.2896600133187978 because of step counter
# Final cost : 0.2896600133187978
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.358962700705131
# Cost in iteration 200: 0.2702022803642339
# Final cost : 0.2702022803642339
# Compute control for a deterministic system
# Cost in iteration 0: 0.2702022803642339
# Cost in iteration 200: 0.27019948881600203
# Final cost : 0.27019948881600203
# Compute control for a deterministic system
# Cost in iteration 0: 0.27019948881600203
# Cost in iteration 200: 0.27019948715940106
# Final cost : 0.27019948715940106
# Compute control for a deterministic system
# Cost in iteration 0: 0.27019948715940106
# Cost in iteration 200: 0.2701994871523362
# Converged in iteration 202 with cost 0.27019948715233266 because of vanishing difference
# Final cost : 0.27019948715233266
# Compute control for a deterministic system
# Cost in iteration 0: 0.27019948715233266
# Converged in iteration 68 with cost 0.270199487152099 because of vanishing difference
# Final cost : 0.270199487152099
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.3375343471652147
# Cost in iteration 200: 0.2556214900639818
# Final cost : 0.2556214900639818
# Compute control for a deterministic system
# Cost in iteration 0: 0.2556214900639818
# Cost in iteration 200: 0.2556193173091518
# Final cost : 0.2556193173091518
# Compute control for a deterministic system
# Cost in iteration 0: 0.2556193173091518
# Converged in iteration 142 with cost 0.25561931629446627 because of vanishing difference
# Final cost : 0.25561931629446627
# Compute control for a deterministic system
# Cost in iteration 0: 0.25561931629446627
# Converged in iteration 156 with cost 0.25561931628053197 because of vanishing difference
# Final cost : 0.25561931628053197
# Compute control for a deterministic system
# Cost in iteration 0: 0.25561931628053197
# Converged in iteration 124 with cost 0.25561931627969364 because of step counter
# Final cost : 0.25561931627969364
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.30927731482835363
# Cost in iteration 200: 0.2362126282713248
# Final cost : 0.2362126282713248
# Compute control for a deterministic system
# Cost in iteration 0: 0.2362126282713248
# Converged in iteration 37 with cost 0.23621121444154175 because of vanishing difference
# Final cost : 0.23621121444154175
# Compute control for a deterministic system
# Cost in iteration 0: 0.23621121444154175
# Cost in iteration 200: 0.23621113111910377
# Final cost : 0.23621113111910377
# Compute control for a deterministic system
# Cost in iteration 0: 0.23621113111910377
# Cost in iteration 200: 0.23621113111114894
# Converged in iteration 240 with cost 0.23621113111106712 because of step counter
# Final cost : 0.23621113111106712
# Compute control for a deterministic system
# Cost in iteration 0: 0.23621113111106712
# Converged in iteration 1 with cost 0.23621113111106712 because of step counter
# Final cost : 0.23621113111106712
# Compute control for a deterministic system
# Cost in iteration 0: 0.2816216753956022
# Cost in iteration 200: 0.21685436896453633
# Final cost : 0.21685436896453633
# Compute control for a deterministic system
# Cost in iteration 0: 0.21685436896453633
# Converged in iteration 20 with cost 0.21685339166305062 because of vanishing difference
# Final cost : 0.21685339166305062
# Compute control for a deterministic system
# Cost in iteration 0: 0.21685339166305062
# Cost in iteration 200: 0.21685325960111637
# Final cost : 0.21685325960111637
# Compute control for a deterministic system
# Cost in iteration 0: 0.21685325960111637
# Cost in iteration 200: 0.2168532595832729
# Converged in iteration 240 with cost 0.21685325958317928 because of step counter
# Final cost : 0.21685325958317928
# Compute control for a deterministic system
# Cost in iteration 0: 0.21685325958317928
# Converged in iteration 35 with cost 0.21685325958312676 because of step counter
# Final cost : 0.21685325958312676
# Compute control for a deterministic system
# Cost in iteration 0: 0.25432089321642665
# Cost in iteration 200: 0.19755487864862922
# Final cost : 0.19755487864862922
# Compute control for a deterministic system
# Cost in iteration 0: 0.19755487864862922
# Cost in iteration 200: 0.1975542332919909
# Final cost : 0.1975542332919909
# Compute control for a deterministic system
# Cost in iteration 0: 0.1975542332919909
# Cost in iteration 200: 0.19755423321245072
# Final cost : 0.19755423321245072
# Compute control for a deterministic system
# Cost in iteration 0: 0.19755423321245072
# Converged in iteration 15 with cost 0.19755423321243643 because of step counter
# Final cost : 0.19755423321243643
# Compute control for a deterministic system
# Cost in iteration 0: 0.19755423321243643
# Converged in iteration 1 with cost 0.19755423321243643 because of step counter
# Final cost : 0.19755423321243643
# Compute control for a deterministic system
# Cost in iteration 0: 0.22696616587089824
# Cost in iteration 200: 0.17831567685652844
# Final cost : 0.17831567685652844
# Compute control for a deterministic system
# Cost in iteration 0: 0.17831567685652844
# Cost in iteration 200: 0.17831536720338675
# Final cost : 0.17831536720338675
# Compute control for a deterministic system
# Cost in iteration 0: 0.17831536720338675
# Converged in iteration 142 with cost 0.17831536718131463 because of step counter
# Final cost : 0.17831536718131463
# Compute control for a deterministic system
# Cost in iteration 0: 0.17831536718131463
# Converged in iteration 1 with cost 0.17831536718131463 because of step counter
# Final cost : 0.17831536718131463
# Compute control for a deterministic system
# Cost in iteration 0: 0.17831536718131463
# Converged in iteration 1 with cost 0.17831536718131463 because of step counter
# Final cost : 0.17831536718131463
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.19958357661268983
# Cost in iteration 200: 0.15913423642767438
# Final cost : 0.15913423642767438
# Compute control for a deterministic system
# Cost in iteration 0: 0.15913423642767438
# Cost in iteration 200: 0.1591340723004243
# Final cost : 0.1591340723004243
# Compute control for a deterministic system
# Cost in iteration 0: 0.1591340723004243
# Converged in iteration 99 with cost 0.1591340722965405 because of step counter
# Final cost : 0.1591340722965405
# Compute control for a deterministic system
# Cost in iteration 0: 0.1591340722965405
# Converged in iteration 1 with cost 0.1591340722965405 because of step counter
# Final cost : 0.1591340722965405
# Compute control for a deterministic system
# Cost in iteration 0: 0.1591340722965405
# Converged in iteration 1 with cost 0.1591340722965405 because of step counter
# Final cost : 0.1591340722965405
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.17919607596582687
# Cost in iteration 200: 0.14478375115056624
# Final cost : 0.14478375115056624
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478375115056624
# Cost in iteration 200: 0.14478365665527618
# Final cost : 0.14478365665527618
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478365665527618
# Converged in iteration 59 with cost 0.14478365665459408 because of step counter
# Final cost : 0.14478365665459408
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478365665459408
# Converged in iteration 1 with cost 0.14478365665459408 because of step counter
# Final cost : 0.14478365665459408
# Compute control for a deterministic system
# Cost in iteration 0: 0.14478365665459408
# Converged in iteration 1 with cost 0.14478365665459408 because of step counter
# Final cost : 0.14478365665459408
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.15244073737108735
# Cost in iteration 200: 0.1256946559062443
# Final cost : 0.1256946559062443
# Compute control for a deterministic system
# Cost in iteration 0: 0.1256946559062443
# Cost in iteration 200: 0.12569461643243215
# Final cost : 0.12569461643243215
# Compute control for a deterministic system
# Cost in iteration 0: 0.12569461643243215
# Converged in iteration 24 with cost 0.12569461643240376 because of step counter
# Final cost : 0.12569461643240376
# Compute control for a deterministic system
# Cost in iteration 0: 0.12569461643240376
# Converged in iteration 1 with cost 0.12569461643240376 because of step counter
# Final cost : 0.12569461643240376
# Compute control for a deterministic system
# Cost in iteration 0: 0.12569461643240376
# Converged in iteration 1 with cost 0.12569461643240376 because of step counter
# Final cost : 0.12569461643240376
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.12639296977506598
# Cost in iteration 200: 0.10665525357243405
# Final cost : 0.10665525357243405
# Compute control for a deterministic system
# Cost in iteration 0: 0.10665525357243405
# Converged in iteration 150 with cost 0.10665524032113748 because of step counter
# Final cost : 0.10665524032113748
# Compute control for a deterministic system
# Cost in iteration 0: 0.10665524032113748
# Converged in iteration 6 with cost 0.10665524032113118 because of step counter
# Final cost : 0.10665524032113118
# Compute control for a deterministic system
# Cost in iteration 0: 0.10665524032113118
# Converged in iteration 2 with cost 0.10665524032113112 because of step counter
# Final cost : 0.10665524032113112
# Compute control for a deterministic system
# Cost in iteration 0: 0.10665524032113112
# Converged in iteration 1 with cost 0.10665524032113112 because of step counter
# Final cost : 0.10665524032113112
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.10124975259035679
# Cost in iteration 200: 0.0876659015558679
# Final cost : 0.0876659015558679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0876659015558679
# Converged in iteration 91 with cost 0.08766589834496069 because of step counter
# Final cost : 0.08766589834496069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766589834496069
# Converged in iteration 1 with cost 0.08766589834496069 because of step counter
# Final cost : 0.08766589834496069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766589834496069
# Converged in iteration 1 with cost 0.08766589834496069 because of step counter
# Final cost : 0.08766589834496069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08766589834496069
# Converged in iteration 1 with cost 0.08766589834496069 because of step counter
# Final cost : 0.08766589834496069
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.07717442681298955
# Cost in iteration 200: 0.0687298847954211
# Final cost : 0.0687298847954211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0687298847954211
# Converged in iteration 63 with cost 0.06872988432825425 because of step counter
# Final cost : 0.06872988432825425
# Compute control for a deterministic system
# Cost in iteration 0: 0.06872988432825425
# Converged in iteration 2 with cost 0.0687298843282531 because of step counter
# Final cost : 0.0687298843282531
# Compute control for a deterministic system
# Cost in iteration 0: 0.0687298843282531
# Converged in iteration 1 with cost 0.0687298843282531 because of step counter
# Final cost : 0.0687298843282531
# Compute control for a deterministic system
# Cost in iteration 0: 0.0687298843282531
# Converged in iteration 1 with cost 0.0687298843282531 because of step counter
# Final cost : 0.0687298843282531
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.05990122737042361
# Cost in iteration 200: 0.05456703836971486
# Final cost : 0.05456703836971486
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703836971486
# Converged in iteration 43 with cost 0.05456703830698772 because of step counter
# Final cost : 0.05456703830698772
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703830698772
# Converged in iteration 1 with cost 0.05456703830698772 because of step counter
# Final cost : 0.05456703830698772
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703830698772
# Converged in iteration 1 with cost 0.05456703830698772 because of step counter
# Final cost : 0.05456703830698772
# Compute control for a deterministic system
# Cost in iteration 0: 0.05456703830698772
# Converged in iteration 1 with cost 0.05456703830698772 because of step counter
# Final cost : 0.05456703830698772
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0380050850344035
# Cost in iteration 200: 0.035745179061396355
# Final cost : 0.035745179061396355
# Compute control for a deterministic system
# Cost in iteration 0: 0.035745179061396355
# Converged in iteration 11 with cost 0.03574517906071875 because of step counter
# Final cost : 0.03574517906071875
# Compute control for a deterministic system
# Cost in iteration 0: 0.03574517906071875
# Converged in iteration 4 with cost 0.03574517906071727 because of step counter
# Final cost : 0.03574517906071727
# Compute control for a deterministic system
# Cost in iteration 0: 0.03574517906071727
# Converged in iteration 1 with cost 0.03574517906071727 because of step counter
# Final cost : 0.03574517906071727
# Compute control for a deterministic system
# Cost in iteration 0: 0.03574517906071727
# Converged in iteration 1 with cost 0.03574517906071727 because of step counter
# Final cost : 0.03574517906071727
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.017487862028249607
# Converged in iteration 129 with cost 0.017012692032629177 because of step counter
# Final cost : 0.017012692032629177
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692032629177
# Converged in iteration 3 with cost 0.017012692032625135 because of step counter
# Final cost : 0.017012692032625135
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692032625135
# Converged in iteration 1 with cost 0.017012692032625135 because of step counter
# Final cost : 0.017012692032625135
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692032625135
# Converged in iteration 1 with cost 0.017012692032625135 because of step counter
# Final cost : 0.017012692032625135
# Compute control for a deterministic system
# Cost in iteration 0: 0.017012692032625135
# Converged in iteration 1 with cost 0.017012692032625135 because of step counter
# Final cost : 0.017012692032625135
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
