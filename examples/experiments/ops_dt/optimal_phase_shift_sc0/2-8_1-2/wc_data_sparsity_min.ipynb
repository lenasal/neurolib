# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 200.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,1259], wc.inh[0,1259]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# 13.399166666666668
# minima =  [ 1320  2660  4000  5340  6680  8020  9359 10699 12039 13379 14719 16059
#  17399 18739]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s1_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s1_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [False, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.06426099921918445
# Converged in iteration 86 with cost 0.038461139073238886 because of vanishing difference
# Final cost : 0.038461139073238886
# Compute control for a deterministic system
# Cost in iteration 0: 0.038461139073238886
# Converged in iteration 30 with cost 0.03846113904624361 because of step counter
# Final cost : 0.03846113904624361
# Compute control for a deterministic system
# Cost in iteration 0: 0.03846113904624361
# Converged in iteration 1 with cost 0.03846113904624361 because of step counter
# Final cost : 0.03846113904624361
# Compute control for a deterministic system
# Cost in iteration 0: 0.03846113904624361
# Converged in iteration 1 with cost 0.03846113904624361 because of vanishing difference
# Final cost : 0.03846113904624361
# Compute control for a deterministic system
# Cost in iteration 0: 0.09246382328902807
# Converged in iteration 79 with cost 0.06309207681720037 because of step counter
# Final cost : 0.06309207681720037
# Compute control for a deterministic system
# Cost in iteration 0: 0.06309207681720037
# Converged in iteration 2 with cost 0.06309207681719983 because of step counter
# Final cost : 0.06309207681719983
# Compute control for a deterministic system
# Cost in iteration 0: 0.06309207681719983
# Converged in iteration 2 with cost 0.06309207681719914 because of step counter
# Final cost : 0.06309207681719914
# Compute control for a deterministic system
# Cost in iteration 0: 0.06309207681719914
# Converged in iteration 1 with cost 0.06309207681719914 because of step counter
# Final cost : 0.06309207681719914
# Compute control for a deterministic system
# Cost in iteration 0: 0.11718514388314075
# Converged in iteration 117 with cost 0.0888541912100377 because of vanishing difference
# Final cost : 0.0888541912100377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0888541912100377
# Converged in iteration 21 with cost 0.08885419085642732 because of step counter
# Final cost : 0.08885419085642732
# Compute control for a deterministic system
# Cost in iteration 0: 0.08885419085642732
# Converged in iteration 1 with cost 0.08885419085642732 because of step counter
# Final cost : 0.08885419085642732
# Compute control for a deterministic system
# Cost in iteration 0: 0.08885419085642732
# Converged in iteration 1 with cost 0.08885419085642732 because of step counter
# Final cost : 0.08885419085642732
# Compute control for a deterministic system
# Cost in iteration 0: 0.13607472743358306
# Converged in iteration 85 with cost 0.1172092853963968 because of vanishing difference
# Final cost : 0.1172092853963968
# Compute control for a deterministic system
# Cost in iteration 0: 0.1172092853963968
# Converged in iteration 17 with cost 0.11720928396869776 because of vanishing difference
# Final cost : 0.11720928396869776
# Compute control for a deterministic system
# Cost in iteration 0: 0.11720928396869776
# Converged in iteration 10 with cost 0.1172092839686774 because of step counter
# Final cost : 0.1172092839686774
# Compute control for a deterministic system
# Cost in iteration 0: 0.1172092839686774
# Converged in iteration 1 with cost 0.1172092839686774 because of step counter
# Final cost : 0.1172092839686774
# -----------------------------------------------
# 1 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.16514777789231783
# Converged in iteration 106 with cost 0.14644457906900396 because of vanishing difference
# Final cost : 0.14644457906900396
# Compute control for a deterministic system
# Cost in iteration 0: 0.14644457906900396
# Converged in iteration 45 with cost 0.14644457475583594 because of step counter
# Final cost : 0.14644457475583594
# Compute control for a deterministic system
# Cost in iteration 0: 0.14644457475583594
# Converged in iteration 1 with cost 0.14644457475583594 because of step counter
# Final cost : 0.14644457475583594
# Compute control for a deterministic system
# Cost in iteration 0: 0.14644457475583594
# Converged in iteration 1 with cost 0.14644457475583594 because of step counter
# Final cost : 0.14644457475583594
# Compute control for a deterministic system
# Cost in iteration 0: 0.1992083691532549
# Converged in iteration 143 with cost 0.17830278583134854 because of vanishing difference
# Final cost : 0.17830278583134854
# Compute control for a deterministic system
# Cost in iteration 0: 0.17830278583134854
# Converged in iteration 50 with cost 0.17830278194047416 because of step counter
# Final cost : 0.17830278194047416
# Compute control for a deterministic system
# Cost in iteration 0: 0.17830278194047416
# Converged in iteration 3 with cost 0.17830278194046656 because of step counter
# Final cost : 0.17830278194046656
# Compute control for a deterministic system
# Cost in iteration 0: 0.17830278194046656
# Converged in iteration 1 with cost 0.17830278194046656 because of step counter
# Final cost : 0.17830278194046656
# Compute control for a deterministic system
# Cost in iteration 0: 0.22948445732539768
# Converged in iteration 176 with cost 0.21088269561846099 because of vanishing difference
# Final cost : 0.21088269561846099
# Compute control for a deterministic system
# Cost in iteration 0: 0.21088269561846099
# Converged in iteration 69 with cost 0.21088268926080256 because of step counter
# Final cost : 0.21088268926080256
# Compute control for a deterministic system
# Cost in iteration 0: 0.21088268926080256
# Converged in iteration 3 with cost 0.21088268926079579 because of step counter
# Final cost : 0.21088268926079579
# Compute control for a deterministic system
# Cost in iteration 0: 0.21088268926079579
# Converged in iteration 5 with cost 0.21088268926079237 because of step counter
# Final cost : 0.21088268926079237
# Compute control for a deterministic system
# Cost in iteration 0: 0.26085824790924245
# Cost in iteration 200: 0.24612304344035885
# Final cost : 0.24612304344035885
# Compute control for a deterministic system
# Cost in iteration 0: 0.24612304344035885
# Converged in iteration 100 with cost 0.2461230210418056 because of step counter
# Final cost : 0.2461230210418056
# Compute control for a deterministic system
# Cost in iteration 0: 0.2461230210418056
# Converged in iteration 9 with cost 0.24612302104178946 because of step counter
# Final cost : 0.24612302104178946
# Compute control for a deterministic system
# Cost in iteration 0: 0.24612302104178946
# Converged in iteration 1 with cost 0.24612302104178946 because of step counter
# Final cost : 0.24612302104178946
# Compute control for a deterministic system
# Cost in iteration 0: 0.31988906524154115
# Cost in iteration 200: 0.28190564828185516
# Final cost : 0.28190564828185516
# Compute control for a deterministic system
# Cost in iteration 0: 0.28190564828185516
# Converged in iteration 133 with cost 0.2819054408641797 because of vanishing difference
# Final cost : 0.2819054408641797
# Compute control for a deterministic system
# Cost in iteration 0: 0.2819054408641797
# Converged in iteration 7 with cost 0.28190544086413155 because of step counter
# Final cost : 0.28190544086413155
# Compute control for a deterministic system
# Cost in iteration 0: 0.28190544086413155
# Converged in iteration 1 with cost 0.28190544086413155 because of step counter
# Final cost : 0.28190544086413155
# Compute control for a deterministic system
# Cost in iteration 0: 0.34000066528118594
# Cost in iteration 200: 0.32033956371123284
# Final cost : 0.32033956371123284
# Compute control for a deterministic system
# Cost in iteration 0: 0.32033956371123284
# Converged in iteration 186 with cost 0.3203384569747083 because of vanishing difference
# Final cost : 0.3203384569747083
# Compute control for a deterministic system
# Cost in iteration 0: 0.3203384569747083
# Converged in iteration 9 with cost 0.3203384569746804 because of step counter
# Final cost : 0.3203384569746804
# Compute control for a deterministic system
# Cost in iteration 0: 0.3203384569746804
# Converged in iteration 1 with cost 0.3203384569746804 because of step counter
# Final cost : 0.3203384569746804
# Compute control for a deterministic system
# Cost in iteration 0: 0.3735835314658821
# Cost in iteration 200: 0.35838941583202777
# Final cost : 0.35838941583202777
# Compute control for a deterministic system
# Cost in iteration 0: 0.35838941583202777
# Cost in iteration 200: 0.35829622491274
# Final cost : 0.35829622491274
# Compute control for a deterministic system
# Cost in iteration 0: 0.35829622491274
# Cost in iteration 200: 0.3582322030653054
# Cost in iteration 400: 0.35819352665217674
# Final cost : 0.35819352665217674
# Compute control for a deterministic system
# Cost in iteration 0: 0.35819352665217674
# Cost in iteration 200: 0.35817466040118123
# Cost in iteration 400: 0.35816044387331586
# Cost in iteration 600: 0.3581519376037009
# Cost in iteration 800: 0.3581451248235269
# Cost in iteration 1000: 0.3581413860987855
# Final cost : 0.3581413860987855
# Compute control for a deterministic system
# Cost in iteration 0: 0.452035069636793
# Converged in iteration 143 with cost 0.3499500794575934 because of vanishing difference
# Final cost : 0.3499500794575934
# Compute control for a deterministic system
# Cost in iteration 0: 0.3499500794575934
# Cost in iteration 200: 0.34991859847281487
# Final cost : 0.34991859847281487
# Compute control for a deterministic system
# Cost in iteration 0: 0.34991859847281487
# Cost in iteration 200: 0.34990971125432857
# Cost in iteration 400: 0.3499060703120261
# Final cost : 0.3499060703120261
# Compute control for a deterministic system
# Cost in iteration 0: 0.3499060703120261
# Cost in iteration 200: 0.3499035341573073
# Cost in iteration 400: 0.34990349047091696
# Converged in iteration 492 with cost 0.3499034903174872 because of vanishing difference
# Final cost : 0.3499034903174872
# Compute control for a deterministic system
# Cost in iteration 0: 0.3861921018947211
# Cost in iteration 200: 0.34248103682790954
# Final cost : 0.34248103682790954
# Compute control for a deterministic system
# Cost in iteration 0: 0.34248103682790954
# Converged in iteration 112 with cost 0.34245733843519205 because of vanishing difference
# Final cost : 0.34245733843519205
# Compute control for a deterministic system
# Cost in iteration 0: 0.34245733843519205
# Cost in iteration 200: 0.3424440129962493
# Cost in iteration 400: 0.34243905734804103
# Final cost : 0.34243905734804103
# Compute control for a deterministic system
# Cost in iteration 0: 0.34243905734804103
# Cost in iteration 200: 0.34243723673606674
# Cost in iteration 400: 0.3424364808418531
# Cost in iteration 600: 0.34243616413368183
# Cost in iteration 800: 0.34243603247305127
# Cost in iteration 1000: 0.3424359780351976
# Final cost : 0.3424359780351976
# Compute control for a deterministic system
# Cost in iteration 0: 0.388996619654413
# Cost in iteration 200: 0.3347048399526136
# Final cost : 0.3347048399526136
# Compute control for a deterministic system
# Cost in iteration 0: 0.3347048399526136
# Converged in iteration 26 with cost 0.33469592187243613 because of vanishing difference
# Final cost : 0.33469592187243613
# Compute control for a deterministic system
# Cost in iteration 0: 0.33469592187243613
# Cost in iteration 200: 0.3346681943921476
# Cost in iteration 400: 0.33465914019070386
# Final cost : 0.33465914019070386
# Compute control for a deterministic system
# Cost in iteration 0: 0.33465914019070386
# Cost in iteration 200: 0.3346563809273223
# Cost in iteration 400: 0.33465535625499365
# Cost in iteration 600: 0.33465497305846015
# Cost in iteration 800: 0.3346548299869592
# Cost in iteration 1000: 0.3346547766502156
# Final cost : 0.3346547766502156
# Compute control for a deterministic system
# Cost in iteration 0: 0.3722775678403087
# Cost in iteration 200: 0.32705830288088433
# Final cost : 0.32705830288088433
# Compute control for a deterministic system
# Cost in iteration 0: 0.32705830288088433
# Cost in iteration 200: 0.3270195834593673
# Final cost : 0.3270195834593673
# Compute control for a deterministic system
# Cost in iteration 0: 0.3270195834593673
# Cost in iteration 200: 0.32701732624906205
# Cost in iteration 400: 0.3270167233432529
# Final cost : 0.3270167233432529
# Compute control for a deterministic system
# Cost in iteration 0: 0.3270167233432529
# Cost in iteration 200: 0.3270165334289414
# Cost in iteration 400: 0.3270164707359558
# Cost in iteration 600: 0.3270164498860344
# Cost in iteration 800: 0.32701644296982096
# Cost in iteration 1000: 0.32701644067889707
# Final cost : 0.32701644067889707
# Compute control for a deterministic system
# Cost in iteration 0: 0.33959519817389594
# Cost in iteration 200: 0.3190747158740834
# Final cost : 0.3190747158740834
# Compute control for a deterministic system
# Cost in iteration 0: 0.3190747158740834
# Converged in iteration 25 with cost 0.319068072227321 because of vanishing difference
# Final cost : 0.319068072227321
# Compute control for a deterministic system
# Cost in iteration 0: 0.319068072227321
# Cost in iteration 200: 0.31904737837341196
# Cost in iteration 400: 0.3190430720016447
# Final cost : 0.3190430720016447
# Compute control for a deterministic system
# Cost in iteration 0: 0.3190430720016447
# Cost in iteration 200: 0.31904229982978305
# Cost in iteration 400: 0.3190420756201003
# Cost in iteration 600: 0.31904201061389525
# Cost in iteration 800: 0.31904199158458396
# Cost in iteration 1000: 0.31904198610150286
# Final cost : 0.31904198610150286
# Compute control for a deterministic system
# Cost in iteration 0: 0.31563698225174036
# Cost in iteration 200: 0.31119835257385436
# Final cost : 0.31119835257385436
# Compute control for a deterministic system
# Cost in iteration 0: 0.31119835257385436
# Cost in iteration 200: 0.31118161600459415
# Final cost : 0.31118161600459415
# Compute control for a deterministic system
# Cost in iteration 0: 0.31118161600459415
# Cost in iteration 200: 0.31117641479268443
# Cost in iteration 400: 0.3111756038394223
# Final cost : 0.3111756038394223
# Compute control for a deterministic system
# Cost in iteration 0: 0.3111756038394223
# Cost in iteration 200: 0.31117553588183894
# Cost in iteration 400: 0.3111755202050929
# Cost in iteration 600: 0.3111755163887831
# Cost in iteration 800: 0.31117551550227274
# Cost in iteration 1000: 0.31117551530843196
# Final cost : 0.31117551530843196
# -----------------------------------------------
# 1 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.3516527102729028
# Cost in iteration 200: 0.30295401470696776
# Final cost : 0.30295401470696776
# Compute control for a deterministic system
# Cost in iteration 0: 0.30295401470696776
# Cost in iteration 200: 0.3029374958363675
# Final cost : 0.3029374958363675
# Compute control for a deterministic system
# Cost in iteration 0: 0.3029374958363675
# Cost in iteration 200: 0.3029332688809672
# Cost in iteration 400: 0.3029330874175329
# Final cost : 0.3029330874175329
# Compute control for a deterministic system
# Cost in iteration 0: 0.3029330874175329
# Cost in iteration 200: 0.30293307928937147
# Cost in iteration 400: 0.3029330779205784
# Cost in iteration 600: 0.3029330776945333
# Cost in iteration 800: 0.3029330776555088
# Cost in iteration 1000: 0.3029330776487735
# Final cost : 0.3029330776487735
# Compute control for a deterministic system
# Cost in iteration 0: 0.30770115092094014
# Cost in iteration 200: 0.2948472515316055
# Final cost : 0.2948472515316055
# Compute control for a deterministic system
# Cost in iteration 0: 0.2948472515316055
# Cost in iteration 200: 0.29483601578702556
# Final cost : 0.29483601578702556
# Compute control for a deterministic system
# Cost in iteration 0: 0.29483601578702556
# Cost in iteration 200: 0.2948338336132019
# Cost in iteration 400: 0.29483383287180803
# Final cost : 0.29483383287180803
# Compute control for a deterministic system
# Cost in iteration 0: 0.29483383287180803
# Converged in iteration 10 with cost 0.29483383287178816 because of step counter
# Final cost : 0.29483383287178816
# Compute control for a deterministic system
# Cost in iteration 0: 0.2886918896489895
# Cost in iteration 200: 0.28641386502156946
# Final cost : 0.28641386502156946
# Compute control for a deterministic system
# Cost in iteration 0: 0.28641386502156946
# Cost in iteration 200: 0.2864094031515291
# Final cost : 0.2864094031515291
# Compute control for a deterministic system
# Cost in iteration 0: 0.2864094031515291
# Cost in iteration 200: 0.2864088651929882
# Cost in iteration 400: 0.2864087827338689
# Final cost : 0.2864087827338689
# Compute control for a deterministic system
# Cost in iteration 0: 0.2864087827338689
# Cost in iteration 200: 0.2864087686300787
# Cost in iteration 400: 0.28640876776915
# Cost in iteration 600: 0.2864087677184575
# Converged in iteration 721 with cost 0.2864087677158234 because of vanishing difference
# Final cost : 0.2864087677158234
# Compute control for a deterministic system
# Cost in iteration 0: 0.38214320938891594
# Cost in iteration 200: 0.27804346862161733
# Final cost : 0.27804346862161733
# Compute control for a deterministic system
# Cost in iteration 0: 0.27804346862161733
# Cost in iteration 200: 0.27803940595362014
# Final cost : 0.27803940595362014
# Compute control for a deterministic system
# Cost in iteration 0: 0.27803940595362014
# Cost in iteration 200: 0.278039082040674
# Cost in iteration 400: 0.27803904696467546
# Final cost : 0.27803904696467546
# Compute control for a deterministic system
# Cost in iteration 0: 0.27803904696467546
# Cost in iteration 200: 0.2780390427888977
# Cost in iteration 400: 0.2780390426807437
# Converged in iteration 507 with cost 0.2780390426782937 because of step counter
# Final cost : 0.2780390426782937
# Compute control for a deterministic system
# Cost in iteration 0: 0.3271013339249733
# Converged in iteration 178 with cost 0.26897254550817346 because of vanishing difference
# Final cost : 0.26897254550817346
# Compute control for a deterministic system
# Cost in iteration 0: 0.26897254550817346
# Cost in iteration 200: 0.26896808366126157
# Final cost : 0.26896808366126157
# Compute control for a deterministic system
# Cost in iteration 0: 0.26896808366126157
# Cost in iteration 200: 0.2689678508694521
# Cost in iteration 400: 0.26896783375709776
# Final cost : 0.26896783375709776
# Compute control for a deterministic system
# Cost in iteration 0: 0.26896783375709776
# Cost in iteration 200: 0.2689678323867923
# Converged in iteration 283 with cost 0.2689678323851889 because of step counter
# Final cost : 0.2689678323851889
# -----------------------------------------------
# 1 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.27571197161818367
# Converged in iteration 63 with cost 0.25952758730684383 because of vanishing difference
# Final cost : 0.25952758730684383
# Compute control for a deterministic system
# Cost in iteration 0: 0.25952758730684383
# Cost in iteration 200: 0.25949061277618984
# Final cost : 0.25949061277618984
# Compute control for a deterministic system
# Cost in iteration 0: 0.25949061277618984
# Cost in iteration 200: 0.2594896127218513
# Cost in iteration 400: 0.2594895623545216
# Final cost : 0.2594895623545216
# Compute control for a deterministic system
# Cost in iteration 0: 0.2594895623545216
# Converged in iteration 171 with cost 0.2594895596650899 because of step counter
# Final cost : 0.2594895596650899
# Compute control for a deterministic system
# Cost in iteration 0: 0.26313266505522753
# Cost in iteration 200: 0.24884645642826897
# Final cost : 0.24884645642826897
# Compute control for a deterministic system
# Cost in iteration 0: 0.24884645642826897
# Cost in iteration 200: 0.2488423796726331
# Final cost : 0.2488423796726331
# Compute control for a deterministic system
# Cost in iteration 0: 0.2488423796726331
# Cost in iteration 200: 0.24884233937199976
# Cost in iteration 400: 0.2488423380629223
# Final cost : 0.2488423380629223
# Compute control for a deterministic system
# Cost in iteration 0: 0.2488423380629223
# Cost in iteration 200: 0.2488423380208379
# Converged in iteration 341 with cost 0.24884233801888367 because of step counter
# Final cost : 0.24884233801888367
# -----------------------------------------------
# 1 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.23856701279595255
# Cost in iteration 200: 0.2375380119902586
# Final cost : 0.2375380119902586
# Compute control for a deterministic system
# Cost in iteration 0: 0.2375380119902586
# Cost in iteration 200: 0.23753425417256127
# Final cost : 0.23753425417256127
# Compute control for a deterministic system
# Cost in iteration 0: 0.23753425417256127
# Cost in iteration 200: 0.2375342379134551
# Cost in iteration 400: 0.23753423760302186
# Final cost : 0.23753423760302186
# Compute control for a deterministic system
# Cost in iteration 0: 0.23753423760302186
# Cost in iteration 200: 0.2375342375973813
# Converged in iteration 222 with cost 0.23753423759731032 because of step counter
# Final cost : 0.23753423759731032
# -----------------------------------------------
# 1 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.2460327544983459
# Cost in iteration 200: 0.22483628430753536
# Final cost : 0.22483628430753536
# Compute control for a deterministic system
# Cost in iteration 0: 0.22483628430753536
# Cost in iteration 200: 0.2248329592814381
# Final cost : 0.2248329592814381
# Compute control for a deterministic system
# Cost in iteration 0: 0.2248329592814381
# Cost in iteration 200: 0.22483295816659868
# Cost in iteration 400: 0.22483295815710852
# Final cost : 0.22483295815710852
# Compute control for a deterministic system
# Cost in iteration 0: 0.22483295815710852
# Converged in iteration 3 with cost 0.2248329581571078 because of step counter
# Final cost : 0.2248329581571078
# -----------------------------------------------
# 1 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.24199815483368328
# Cost in iteration 200: 0.21153710389166241
# Final cost : 0.21153710389166241
# Compute control for a deterministic system
# Cost in iteration 0: 0.21153710389166241
# Converged in iteration 39 with cost 0.21153341909083012 because of vanishing difference
# Final cost : 0.21153341909083012
# Compute control for a deterministic system
# Cost in iteration 0: 0.21153341909083012
# Cost in iteration 200: 0.21153318794603748
# Cost in iteration 400: 0.21153318712982402
# Final cost : 0.21153318712982402
# Compute control for a deterministic system
# Cost in iteration 0: 0.21153318712982402
# Converged in iteration 135 with cost 0.21153318712642818 because of step counter
# Final cost : 0.21153318712642818
# Compute control for a deterministic system
# Cost in iteration 0: 0.21816379588384088
# Cost in iteration 200: 0.19695274403228466
# Final cost : 0.19695274403228466
# Compute control for a deterministic system
# Cost in iteration 0: 0.19695274403228466
# Converged in iteration 188 with cost 0.19695064568620715 because of vanishing difference
# Final cost : 0.19695064568620715
# Compute control for a deterministic system
# Cost in iteration 0: 0.19695064568620715
# Converged in iteration 60 with cost 0.19695064568578882 because of vanishing difference
# Final cost : 0.19695064568578882
# Compute control for a deterministic system
# Cost in iteration 0: 0.19695064568578882
# Converged in iteration 9 with cost 0.19695064568577653 because of step counter
# Final cost : 0.19695064568577653
# Compute control for a deterministic system
# Cost in iteration 0: 0.1881440704720825
# Cost in iteration 200: 0.1820558746940522
# Final cost : 0.1820558746940522
# Compute control for a deterministic system
# Cost in iteration 0: 0.1820558746940522
# Cost in iteration 200: 0.1820552228987095
# Final cost : 0.1820552228987095
# Compute control for a deterministic system
# Cost in iteration 0: 0.1820552228987095
# Converged in iteration 190 with cost 0.1820552222104535 because of step counter
# Final cost : 0.1820552222104535
# Compute control for a deterministic system
# Cost in iteration 0: 0.1820552222104535
# Converged in iteration 1 with cost 0.1820552222104535 because of step counter
# Final cost : 0.1820552222104535
# Compute control for a deterministic system
# Cost in iteration 0: 0.21379363032491866
# Converged in iteration 186 with cost 0.16600374532878281 because of vanishing difference
# Final cost : 0.16600374532878281
# Compute control for a deterministic system
# Cost in iteration 0: 0.16600374532878281
# Cost in iteration 200: 0.1660035217501428
# Final cost : 0.1660035217501428
# Compute control for a deterministic system
# Cost in iteration 0: 0.1660035217501428
# Converged in iteration 86 with cost 0.1660035217202389 because of step counter
# Final cost : 0.1660035217202389
# Compute control for a deterministic system
# Cost in iteration 0: 0.1660035217202389
# Converged in iteration 12 with cost 0.16600352172022576 because of step counter
# Final cost : 0.16600352172022576
# Compute control for a deterministic system
# Cost in iteration 0: 0.18497789186276858
# Cost in iteration 200: 0.14974744653073252
# Final cost : 0.14974744653073252
# Compute control for a deterministic system
# Cost in iteration 0: 0.14974744653073252
# Converged in iteration 170 with cost 0.14974744458955047 because of vanishing difference
# Final cost : 0.14974744458955047
# Compute control for a deterministic system
# Cost in iteration 0: 0.14974744458955047
# Converged in iteration 20 with cost 0.14974744458946168 because of step counter
# Final cost : 0.14974744458946168
# Compute control for a deterministic system
# Cost in iteration 0: 0.14974744458946168
# Converged in iteration 7 with cost 0.14974744458944997 because of step counter
# Final cost : 0.14974744458944997
# -----------------------------------------------
# 1 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.17667981133169325
# Cost in iteration 200: 0.13228428381676546
# Final cost : 0.13228428381676546
# Compute control for a deterministic system
# Cost in iteration 0: 0.13228428381676546
# Converged in iteration 93 with cost 0.13228428376876641 because of vanishing difference
# Final cost : 0.13228428376876641
# Compute control for a deterministic system
# Cost in iteration 0: 0.13228428376876641
# Converged in iteration 3 with cost 0.1322842837687625 because of step counter
# Final cost : 0.1322842837687625
# Compute control for a deterministic system
# Cost in iteration 0: 0.1322842837687625
# Converged in iteration 18 with cost 0.1322842837687433 because of step counter
# Final cost : 0.1322842837687433
# -----------------------------------------------
# 1 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.1321370691179071
# Cost in iteration 200: 0.11462122654598371
# Final cost : 0.11462122654598371
# Compute control for a deterministic system
# Cost in iteration 0: 0.11462122654598371
# Converged in iteration 27 with cost 0.11462122654576776 because of step counter
# Final cost : 0.11462122654576776
# Compute control for a deterministic system
# Cost in iteration 0: 0.11462122654576776
# Converged in iteration 1 with cost 0.11462122654576776 because of step counter
# Final cost : 0.11462122654576776
# Compute control for a deterministic system
# Cost in iteration 0: 0.11462122654576776
# Converged in iteration 1 with cost 0.11462122654576776 because of step counter
# Final cost : 0.11462122654576776
# -----------------------------------------------
# 1 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.1274754973134719
# Converged in iteration 174 with cost 0.09568235017232267 because of step counter
# Final cost : 0.09568235017232267
# Compute control for a deterministic system
# Cost in iteration 0: 0.09568235017232267
# Converged in iteration 3 with cost 0.09568235017232044 because of step counter
# Final cost : 0.09568235017232044
# Compute control for a deterministic system
# Cost in iteration 0: 0.09568235017232044
# Converged in iteration 1 with cost 0.09568235017232044 because of step counter
# Final cost : 0.09568235017232044
# Compute control for a deterministic system
# Cost in iteration 0: 0.09568235017232044
# Converged in iteration 1 with cost 0.09568235017232044 because of step counter
# Final cost : 0.09568235017232044
# -----------------------------------------------
# 1 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.09537063681796369
# Converged in iteration 122 with cost 0.07661198800118554 because of step counter
# Final cost : 0.07661198800118554
# Compute control for a deterministic system
# Cost in iteration 0: 0.07661198800118554
# Converged in iteration 4 with cost 0.07661198800118381 because of step counter
# Final cost : 0.07661198800118381
# Compute control for a deterministic system
# Cost in iteration 0: 0.07661198800118381
# Converged in iteration 1 with cost 0.07661198800118381 because of step counter
# Final cost : 0.07661198800118381
# Compute control for a deterministic system
# Cost in iteration 0: 0.07661198800118381
# Converged in iteration 2 with cost 0.07661198800118295 because of step counter
# Final cost : 0.07661198800118295
# -----------------------------------------------
# 1 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0808120650207477
# Cost in iteration 200: 0.056355433936801445
# Final cost : 0.056355433936801445
# Compute control for a deterministic system
# Cost in iteration 0: 0.056355433936801445
# Converged in iteration 7 with cost 0.05635543197198619 because of step counter
# Final cost : 0.05635543197198619
# Compute control for a deterministic system
# Cost in iteration 0: 0.05635543197198619
# Converged in iteration 1 with cost 0.05635543197198619 because of step counter
# Final cost : 0.05635543197198619
# Compute control for a deterministic system
# Cost in iteration 0: 0.05635543197198619
# Converged in iteration 1 with cost 0.05635543197198619 because of step counter
# Final cost : 0.05635543197198619
# Compute control for a deterministic system
# Cost in iteration 0: 0.06725599079230912
# Converged in iteration 80 with cost 0.03632405686261533 because of vanishing difference
# Final cost : 0.03632405686261533
# Compute control for a deterministic system
# Cost in iteration 0: 0.03632405686261533
# Converged in iteration 9 with cost 0.03632405626544204 because of vanishing difference
# Final cost : 0.03632405626544204
# Compute control for a deterministic system
# Cost in iteration 0: 0.03632405626544204
# Converged in iteration 4 with cost 0.03632405626543998 because of step counter
# Final cost : 0.03632405626543998
# Compute control for a deterministic system
# Cost in iteration 0: 0.03632405626543998
# Converged in iteration 2 with cost 0.03632405626543965 because of step counter
# Final cost : 0.03632405626543965
# Compute control for a deterministic system
# Cost in iteration 0: 0.04283381473267836
# Converged in iteration 51 with cost 0.015780996176535035 because of vanishing difference
# Final cost : 0.015780996176535035
# Compute control for a deterministic system
# Cost in iteration 0: 0.015780996176535035
# Converged in iteration 13 with cost 0.015780995590331595 because of step counter
# Final cost : 0.015780995590331595
# Compute control for a deterministic system
# Cost in iteration 0: 0.015780995590331595
# Converged in iteration 1 with cost 0.015780995590331595 because of step counter
# Final cost : 0.015780995590331595
# Compute control for a deterministic system
# Cost in iteration 0: 0.015780995590331595
# Converged in iteration 1 with cost 0.015780995590331595 because of step counter
# Final cost : 0.015780995590331595

# %%
save(results_min)

# %%
ind_list = [5,10,15,20,25,30,35]

fig, ax = plt.subplots(7, 1, figsize=(6,20), sharey=True, sharex=True)
    
for i in range(len(ind_list)):
    i_shift = ind_list[i]
    ax[i].plot(results_min["control"][1][i_shift][0,0,:], color="red")
    ax[i].plot(results_min["control"][1][i_shift][0,1,:], color="blue")

plt.show()
