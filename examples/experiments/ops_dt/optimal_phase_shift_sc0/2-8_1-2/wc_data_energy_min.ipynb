# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 200.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,1259], wc.inh[0,1259]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# 13.399166666666668
# minima =  [ 1320  2660  4000  5340  6680  8020  9359 10699 12039 13379 14719 16059
#  17399 18739]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w1, w_1D=0., print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s1_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s1_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(10,30)
options = [True, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)


        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in [18,19,20]:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = - results_min["control"][i_w][21].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)


        if options[4]:
            print("----------------------------------------------- 3")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in [21,22,23]:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = - results_min["control"][i_w][20].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.021886116874535892
# Cost in iteration 200: 0.011542374686076513
# Final cost : 0.011542374686076513
# Compute control for a deterministic system
# Cost in iteration 0: 0.011542374686076513
# Cost in iteration 200: 0.011493900064826283
# Final cost : 0.011493900064826283
# Compute control for a deterministic system
# Cost in iteration 0: 0.011493900064826283
# Cost in iteration 200: 0.011486373368044594
# Final cost : 0.011486373368044594
# Compute control for a deterministic system
# Cost in iteration 0: 0.011486373368044594
# Cost in iteration 200: 0.01148410512254428
# Cost in iteration 400: 0.011483229447034385
# Final cost : 0.011483229447034385
# Compute control for a deterministic system
# Cost in iteration 0: 0.011483229447034385
# Cost in iteration 200: 0.011482853954703087
# Cost in iteration 400: 0.011482709322512833
# Cost in iteration 600: 0.011482654566380602
# Cost in iteration 800: 0.011482633675609331
# Cost in iteration 1000: 0.011482625956060257
# Final cost : 0.011482625956060257
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.03940078995465323
# Cost in iteration 200: 0.013406018164724925
# Final cost : 0.013406018164724925
# Compute control for a deterministic system
# Cost in iteration 0: 0.013406018164724925
# Cost in iteration 200: 0.0133589809145049
# Final cost : 0.0133589809145049
# Compute control for a deterministic system
# Cost in iteration 0: 0.0133589809145049
# Cost in iteration 200: 0.013351066571216257
# Final cost : 0.013351066571216257
# Compute control for a deterministic system
# Cost in iteration 0: 0.013351066571216257
# Cost in iteration 200: 0.013348471994928
# Cost in iteration 400: 0.013347443658569042
# Final cost : 0.013347443658569042
# Compute control for a deterministic system
# Cost in iteration 0: 0.013347443658569042
# Cost in iteration 200: 0.013347051751958893
# Cost in iteration 400: 0.013346885051848452
# Cost in iteration 600: 0.013346816193291651
# Cost in iteration 800: 0.013346788763817582
# Cost in iteration 1000: 0.013346777913666683
# Final cost : 0.013346777913666683
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.021942237696946042
# Cost in iteration 200: 0.015392636327109388
# Final cost : 0.015392636327109388
# Compute control for a deterministic system
# Cost in iteration 0: 0.015392636327109388
# Cost in iteration 200: 0.015343918314874472
# Final cost : 0.015343918314874472
# Compute control for a deterministic system
# Cost in iteration 0: 0.015343918314874472
# Cost in iteration 200: 0.015335316571763253
# Final cost : 0.015335316571763253
# Compute control for a deterministic system
# Cost in iteration 0: 0.015335316571763253
# Cost in iteration 200: 0.015333089089865524
# Cost in iteration 400: 0.015332138286684005
# Final cost : 0.015332138286684005
# Compute control for a deterministic system
# Cost in iteration 0: 0.015332138286684005
# Cost in iteration 200: 0.015331652251499472
# Cost in iteration 400: 0.015331461410769177
# Cost in iteration 600: 0.015331398734383654
# Cost in iteration 800: 0.01533137648954325
# Cost in iteration 1000: 0.015331367669639306
# Final cost : 0.015331367669639306
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.07676330342217483
# Cost in iteration 200: 0.017357685424029067
# Final cost : 0.017357685424029067
# Compute control for a deterministic system
# Cost in iteration 0: 0.017357685424029067
# Cost in iteration 200: 0.017308399534288258
# Final cost : 0.017308399534288258
# Compute control for a deterministic system
# Cost in iteration 0: 0.017308399534288258
# Cost in iteration 200: 0.017298673538631997
# Final cost : 0.017298673538631997
# Compute control for a deterministic system
# Cost in iteration 0: 0.017298673538631997
# Cost in iteration 200: 0.017295676248957555
# Cost in iteration 400: 0.017294505276714472
# Final cost : 0.017294505276714472
# Compute control for a deterministic system
# Cost in iteration 0: 0.017294505276714472
# Cost in iteration 200: 0.017294195474150717
# Cost in iteration 400: 0.017294073390763363
# Cost in iteration 600: 0.017294027334145763
# Cost in iteration 800: 0.017294007487959423
# Cost in iteration 1000: 0.01729400015558028
# Final cost : 0.01729400015558028
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.07482150207510216
# Cost in iteration 200: 0.019379176888062837
# Final cost : 0.019379176888062837
# Compute control for a deterministic system
# Cost in iteration 0: 0.019379176888062837
# Cost in iteration 200: 0.019334143409795303
# Final cost : 0.019334143409795303
# Compute control for a deterministic system
# Cost in iteration 0: 0.019334143409795303
# Cost in iteration 200: 0.019325596154749783
# Final cost : 0.019325596154749783
# Compute control for a deterministic system
# Cost in iteration 0: 0.019325596154749783
# Cost in iteration 200: 0.0193220516024559
# Cost in iteration 400: 0.019320899092602394
# Final cost : 0.019320899092602394
# Compute control for a deterministic system
# Cost in iteration 0: 0.019320899092602394
# Cost in iteration 200: 0.019320459511823512
# Cost in iteration 400: 0.01932031367609664
# Cost in iteration 600: 0.01932026956230012
# Cost in iteration 800: 0.01932025409316458
# Cost in iteration 1000: 0.019320248661245883
# Final cost : 0.019320248661245883
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.032399765788204214
# Cost in iteration 200: 0.021300171627311987
# Final cost : 0.021300171627311987
# Compute control for a deterministic system
# Cost in iteration 0: 0.021300171627311987
# Cost in iteration 200: 0.0212669005820023
# Final cost : 0.0212669005820023
# Compute control for a deterministic system
# Cost in iteration 0: 0.0212669005820023
# Cost in iteration 200: 0.021260747300505794
# Final cost : 0.021260747300505794
# Compute control for a deterministic system
# Cost in iteration 0: 0.021260747300505794
# Cost in iteration 200: 0.021258432311289314
# Cost in iteration 400: 0.02125738353638541
# Final cost : 0.02125738353638541
# Compute control for a deterministic system
# Cost in iteration 0: 0.02125738353638541
# Cost in iteration 200: 0.021256805432618753
# Cost in iteration 400: 0.02125654709392128
# Cost in iteration 600: 0.021256442325075953
# Cost in iteration 800: 0.021256403616033336
# Cost in iteration 1000: 0.02125638784846744
# Final cost : 0.02125638784846744
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.06399888394718954
# Cost in iteration 200: 0.0232256602849001
# Final cost : 0.0232256602849001
# Compute control for a deterministic system
# Cost in iteration 0: 0.0232256602849001
# Cost in iteration 200: 0.023195835622045323
# Final cost : 0.023195835622045323
# Compute control for a deterministic system
# Cost in iteration 0: 0.023195835622045323
# Cost in iteration 200: 0.023189727546898915
# Final cost : 0.023189727546898915
# Compute control for a deterministic system
# Cost in iteration 0: 0.023189727546898915
# Cost in iteration 200: 0.023186960949131745
# Cost in iteration 400: 0.023185826239231086
# Final cost : 0.023185826239231086
# Compute control for a deterministic system
# Cost in iteration 0: 0.023185826239231086
# Cost in iteration 200: 0.02318524315420911
# Cost in iteration 400: 0.02318494791388408
# Cost in iteration 600: 0.02318479821899811
# Cost in iteration 800: 0.023184722679685806
# Cost in iteration 1000: 0.023184682786202775
# Final cost : 0.023184682786202775
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.03071551752987893
# Cost in iteration 200: 0.025004024308706584
# Final cost : 0.025004024308706584
# Compute control for a deterministic system
# Cost in iteration 0: 0.025004024308706584
# Cost in iteration 200: 0.024973400245097806
# Final cost : 0.024973400245097806
# Compute control for a deterministic system
# Cost in iteration 0: 0.024973400245097806
# Cost in iteration 200: 0.02496829911510441
# Final cost : 0.02496829911510441
# Compute control for a deterministic system
# Cost in iteration 0: 0.02496829911510441
# Cost in iteration 200: 0.02496637430798572
# Cost in iteration 400: 0.02496540931345059
# Final cost : 0.02496540931345059
# Compute control for a deterministic system
# Cost in iteration 0: 0.02496540931345059
# Cost in iteration 200: 0.0249648817898746
# Cost in iteration 400: 0.024964627049392583
# Cost in iteration 600: 0.02496449128797914
# Cost in iteration 800: 0.02496442279883788
# Cost in iteration 1000: 0.024964386076835515
# Final cost : 0.024964386076835515
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.043321933500262075
# Cost in iteration 200: 0.02673059811503818
# Final cost : 0.02673059811503818
# Compute control for a deterministic system
# Cost in iteration 0: 0.02673059811503818
# Cost in iteration 200: 0.026702693381696705
# Final cost : 0.026702693381696705
# Compute control for a deterministic system
# Cost in iteration 0: 0.026702693381696705
# Cost in iteration 200: 0.026698163795264383
# Final cost : 0.026698163795264383
# Compute control for a deterministic system
# Cost in iteration 0: 0.026698163795264383
# Cost in iteration 200: 0.026696187993838147
# Cost in iteration 400: 0.026695266884510207
# Final cost : 0.026695266884510207
# Compute control for a deterministic system
# Cost in iteration 0: 0.026695266884510207
# Cost in iteration 200: 0.026694848844298978
# Cost in iteration 400: 0.026694632638686922
# Cost in iteration 600: 0.02669451906018186
# Cost in iteration 800: 0.026694454111928542
# Cost in iteration 1000: 0.026694422449020642
# Final cost : 0.026694422449020642
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.03941868148797237
# Cost in iteration 200: 0.028332083518639122
# Final cost : 0.028332083518639122
# Compute control for a deterministic system
# Cost in iteration 0: 0.028332083518639122
# Cost in iteration 200: 0.028303045872971968
# Final cost : 0.028303045872971968
# Compute control for a deterministic system
# Cost in iteration 0: 0.028303045872971968
# Cost in iteration 200: 0.028299071526016826
# Final cost : 0.028299071526016826
# Compute control for a deterministic system
# Cost in iteration 0: 0.028299071526016826
# Cost in iteration 200: 0.028297458733874223
# Cost in iteration 400: 0.028296848291346738
# Final cost : 0.028296848291346738
# Compute control for a deterministic system
# Cost in iteration 0: 0.028296848291346738
# Cost in iteration 200: 0.02829653032668413
# Cost in iteration 400: 0.02829641826638734
# Cost in iteration 600: 0.02829637181108222
# Cost in iteration 800: 0.028296345585945556
# Cost in iteration 1000: 0.02829633642289939
# Final cost : 0.02829633642289939
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.035539952076962304
# Cost in iteration 200: 0.02995130349163662
# Final cost : 0.02995130349163662
# Compute control for a deterministic system
# Cost in iteration 0: 0.02995130349163662
# Cost in iteration 200: 0.029916963439199237
# Final cost : 0.029916963439199237
# Compute control for a deterministic system
# Cost in iteration 0: 0.029916963439199237
# Cost in iteration 200: 0.029912986197113137
# Final cost : 0.029912986197113137
# Compute control for a deterministic system
# Cost in iteration 0: 0.029912986197113137
# Cost in iteration 200: 0.029911472240963567
# Cost in iteration 400: 0.029910971975051496
# Final cost : 0.029910971975051496
# Compute control for a deterministic system
# Cost in iteration 0: 0.029910971975051496
# Cost in iteration 200: 0.029910747237462853
# Cost in iteration 400: 0.029910620981574525
# Cost in iteration 600: 0.029910550335868997
# Cost in iteration 800: 0.0299105099087769
# Cost in iteration 1000: 0.029910486481299996
# Final cost : 0.029910486481299996
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.05570828225055008
# Cost in iteration 200: 0.03148749671326148
# Final cost : 0.03148749671326148
# Compute control for a deterministic system
# Cost in iteration 0: 0.03148749671326148
# Cost in iteration 200: 0.03146267858195084
# Final cost : 0.03146267858195084
# Compute control for a deterministic system
# Cost in iteration 0: 0.03146267858195084
# Cost in iteration 200: 0.03145879228532902
# Final cost : 0.03145879228532902
# Compute control for a deterministic system
# Cost in iteration 0: 0.03145879228532902
# Cost in iteration 200: 0.03145725794972737
# Cost in iteration 400: 0.03145642114758017
# Final cost : 0.03145642114758017
# Compute control for a deterministic system
# Cost in iteration 0: 0.03145642114758017
# Cost in iteration 200: 0.03145593741984188
# Cost in iteration 400: 0.031455618422971
# Cost in iteration 600: 0.03145543723455015
# Cost in iteration 800: 0.031455330730988246
# Cost in iteration 1000: 0.031455261162861875
# Final cost : 0.031455261162861875
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.07907725636140231
# Cost in iteration 200: 0.033049457140993346
# Final cost : 0.033049457140993346
# Compute control for a deterministic system
# Cost in iteration 0: 0.033049457140993346
# Cost in iteration 200: 0.03302290229527248
# Final cost : 0.03302290229527248
# Compute control for a deterministic system
# Cost in iteration 0: 0.03302290229527248
# Cost in iteration 200: 0.03301854179066524
# Final cost : 0.03301854179066524
# Compute control for a deterministic system
# Cost in iteration 0: 0.03301854179066524
# Cost in iteration 200: 0.03301660097508377
# Cost in iteration 400: 0.0330155740158575
# Final cost : 0.0330155740158575
# Compute control for a deterministic system
# Cost in iteration 0: 0.0330155740158575
# Cost in iteration 200: 0.033014937358295256
# Cost in iteration 400: 0.03301457003397869
# Cost in iteration 600: 0.03301434025044219
# Cost in iteration 800: 0.03301419169512092
# Cost in iteration 1000: 0.033014105154513904
# Final cost : 0.033014105154513904
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.06203443024232533
# Cost in iteration 200: 0.034541757738446
# Final cost : 0.034541757738446
# Compute control for a deterministic system
# Cost in iteration 0: 0.034541757738446
# Cost in iteration 200: 0.03451633682499805
# Final cost : 0.03451633682499805
# Compute control for a deterministic system
# Cost in iteration 0: 0.03451633682499805
# Cost in iteration 200: 0.034511461810955046
# Final cost : 0.034511461810955046
# Compute control for a deterministic system
# Cost in iteration 0: 0.034511461810955046
# Cost in iteration 200: 0.03450858315634434
# Cost in iteration 400: 0.03450773789728225
# Final cost : 0.03450773789728225
# Compute control for a deterministic system
# Cost in iteration 0: 0.03450773789728225
# Cost in iteration 200: 0.03450714115515602
# Cost in iteration 400: 0.03450683688768735
# Cost in iteration 600: 0.034506658378913625
# Cost in iteration 800: 0.03450654590726748
# Cost in iteration 1000: 0.034506480660777446
# Final cost : 0.034506480660777446
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.054368805243652965
# Cost in iteration 200: 0.03609337254993073
# Final cost : 0.03609337254993073
# Compute control for a deterministic system
# Cost in iteration 0: 0.03609337254993073
# Cost in iteration 200: 0.036065740776049404
# Final cost : 0.036065740776049404
# Compute control for a deterministic system
# Cost in iteration 0: 0.036065740776049404
# Cost in iteration 200: 0.03605886525784493
# Final cost : 0.03605886525784493
# Compute control for a deterministic system
# Cost in iteration 0: 0.03605886525784493
# Cost in iteration 200: 0.0360569950518485
# Cost in iteration 400: 0.036055943394219206
# Final cost : 0.036055943394219206
# Compute control for a deterministic system
# Cost in iteration 0: 0.036055943394219206
# Cost in iteration 200: 0.03605519998185602
# Cost in iteration 400: 0.03605480051543732
# Cost in iteration 600: 0.03605456558885668
# Cost in iteration 800: 0.03605440425922847
# Cost in iteration 1000: 0.03605429264794953
# Final cost : 0.03605429264794953
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.05507434012994257
# Cost in iteration 200: 0.03763350269631783
# Final cost : 0.03763350269631783
# Compute control for a deterministic system
# Cost in iteration 0: 0.03763350269631783
# Cost in iteration 200: 0.03760696204711227
# Final cost : 0.03760696204711227
# Compute control for a deterministic system
# Cost in iteration 0: 0.03760696204711227
# Cost in iteration 200: 0.0376001579128301
# Final cost : 0.0376001579128301
# Compute control for a deterministic system
# Cost in iteration 0: 0.0376001579128301
# Cost in iteration 200: 0.03759713711828083
# Cost in iteration 400: 0.03759546857642711
# Final cost : 0.03759546857642711
# Compute control for a deterministic system
# Cost in iteration 0: 0.03759546857642711
# Cost in iteration 200: 0.03759458070469439
# Cost in iteration 400: 0.037593973347851965
# Cost in iteration 600: 0.03759355621753617
# Cost in iteration 800: 0.03759325202678797
# Cost in iteration 1000: 0.037593039117022505
# Final cost : 0.037593039117022505
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.0880502113429469
# Cost in iteration 200: 0.03927987266199144
# Final cost : 0.03927987266199144
# Compute control for a deterministic system
# Cost in iteration 0: 0.03927987266199144
# Cost in iteration 200: 0.03924855745612521
# Final cost : 0.03924855745612521
# Compute control for a deterministic system
# Cost in iteration 0: 0.03924855745612521
# Cost in iteration 200: 0.039240482165660936
# Final cost : 0.039240482165660936
# Compute control for a deterministic system
# Cost in iteration 0: 0.039240482165660936
# Cost in iteration 200: 0.03923667315745903
# Cost in iteration 400: 0.039234470109738066
# Final cost : 0.039234470109738066
# Compute control for a deterministic system
# Cost in iteration 0: 0.039234470109738066
# Cost in iteration 200: 0.0392329363174841
# Cost in iteration 400: 0.03923201749187829
# Cost in iteration 600: 0.03923140046457471
# Cost in iteration 800: 0.03923093059724759
# Cost in iteration 1000: 0.03923060417486344
# Final cost : 0.03923060417486344
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.058840321319720515
# Cost in iteration 200: 0.040923895770634995
# Final cost : 0.040923895770634995
# Compute control for a deterministic system
# Cost in iteration 0: 0.040923895770634995
# Cost in iteration 200: 0.04089410020131116
# Final cost : 0.04089410020131116
# Compute control for a deterministic system
# Cost in iteration 0: 0.04089410020131116
# Cost in iteration 200: 0.04088357472443736
# Final cost : 0.04088357472443736
# Compute control for a deterministic system
# Cost in iteration 0: 0.04088357472443736
# Cost in iteration 200: 0.04087967425701265
# Cost in iteration 400: 0.040877228379201505
# Final cost : 0.040877228379201505
# Compute control for a deterministic system
# Cost in iteration 0: 0.040877228379201505
# Cost in iteration 200: 0.04087549745720778
# Cost in iteration 400: 0.04087446697022166
# Cost in iteration 600: 0.040873753805893275
# Cost in iteration 800: 0.04087329927300484
# Cost in iteration 1000: 0.040873027718398396
# Final cost : 0.040873027718398396
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.12926932718767695
# Cost in iteration 200: 0.0426785748517319
# Final cost : 0.0426785748517319
# Compute control for a deterministic system
# Cost in iteration 0: 0.0426785748517319
# Cost in iteration 200: 0.04264400382646547
# Final cost : 0.04264400382646547
# Compute control for a deterministic system
# Cost in iteration 0: 0.04264400382646547
# Cost in iteration 200: 0.042632407334783025
# Final cost : 0.042632407334783025
# Compute control for a deterministic system
# Cost in iteration 0: 0.042632407334783025
# Cost in iteration 200: 0.04262655554754198
# Cost in iteration 400: 0.04262339173881339
# Final cost : 0.04262339173881339
# Compute control for a deterministic system
# Cost in iteration 0: 0.04262339173881339
# Cost in iteration 200: 0.0426209198698049
# Cost in iteration 400: 0.0426193810290873
# Cost in iteration 600: 0.04261844506921117
# Cost in iteration 800: 0.04261780478967543
# Cost in iteration 1000: 0.042617367075124146
# Final cost : 0.042617367075124146
# Compute control for a deterministic system
# Cost in iteration 0: 0.03976561717700495
# Cost in iteration 200: 0.034325796982997064
# Final cost : 0.034325796982997064
# Compute control for a deterministic system
# Cost in iteration 0: 0.034325796982997064
# Cost in iteration 200: 0.033928030567223794
# Final cost : 0.033928030567223794
# Compute control for a deterministic system
# Cost in iteration 0: 0.033928030567223794
# Cost in iteration 200: 0.033897113728031454
# Final cost : 0.033897113728031454
# Compute control for a deterministic system
# Cost in iteration 0: 0.033897113728031454
# Cost in iteration 200: 0.033893555730796956
# Cost in iteration 400: 0.03389292992311648
# Final cost : 0.03389292992311648
# Compute control for a deterministic system
# Cost in iteration 0: 0.03389292992311648
# Cost in iteration 200: 0.03389279750856387
# Cost in iteration 400: 0.033892794107450636
# Cost in iteration 600: 0.033892793981072
# Cost in iteration 800: 0.03389279397766791
# Converged in iteration 824 with cost 0.03389279397759878 because of step counter
# Final cost : 0.03389279397759878
# -----------------------------------------------
# 0 found better solution,  29

# %%
save(results_min)
