# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period) # 19.069230769230767

wc.run()
init_min = [wc.exc[0,1301], wc.inh[0,1301]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t[:500], wc.exc[0,:500])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  17.457307692307694
# minima =  [  485  2252  4000  5746  7492  9237 10983 12729 14474 16220 17966 19711
#  21457 23203 24948 26694 28440 30185 31931 33677 35422 37168 38914 40659
#  42405 44151 45896 47642 49388]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("c_s1_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("c_s1_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031953703076419418
# Converged in iteration 34 with cost 0.003143111451665587 because of vanishing difference
# Final cost : 0.003143111451665587
# Compute control for a deterministic system
# Cost in iteration 0: 0.003143111451665587
# Converged in iteration 92 with cost 0.0031431109549237613 because of step counter
# Final cost : 0.0031431109549237613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031431109549237613
# Converged in iteration 1 with cost 0.0031431109549237613 because of step counter
# Final cost : 0.0031431109549237613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031431109549237613
# Converged in iteration 1 with cost 0.0031431109549237613 because of step counter
# Final cost : 0.0031431109549237613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031431109549237613
# Converged in iteration 1 with cost 0.0031431109549237613 because of step counter
# Final cost : 0.0031431109549237613
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.006663714853206933
# Converged in iteration 42 with cost 0.006505169082752963 because of vanishing difference
# Final cost : 0.006505169082752963
# Compute control for a deterministic system
# Cost in iteration 0: 0.006505169082752963
# Final cost : 0.0065051652609560695
# Compute control for a deterministic system
# Cost in iteration 0: 0.0065051652609560695
# Converged in iteration 16 with cost 0.006505165260838074 because of step counter
# Final cost : 0.006505165260838074
# Compute control for a deterministic system
# Cost in iteration 0: 0.006505165260838074
# Converged in iteration 1 with cost 0.006505165260838074 because of step counter
# Final cost : 0.006505165260838074
# Compute control for a deterministic system
# Cost in iteration 0: 0.006505165260838074
# Converged in iteration 26 with cost 0.0065051652607344 because of step counter
# Final cost : 0.0065051652607344
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.009968091135572505
# Converged in iteration 35 with cost 0.009963856972955371 because of vanishing difference
# Final cost : 0.009963856972955371
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963856972955371
# Final cost : 0.009963846960548155
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963846960548155
# Converged in iteration 199 with cost 0.009963846942927698 because of step counter
# Final cost : 0.009963846942927698
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963846942927698
# Converged in iteration 9 with cost 0.009963846942841444 because of step counter
# Final cost : 0.009963846942841444
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963846942841444
# Converged in iteration 1 with cost 0.009963846942841444 because of step counter
# Final cost : 0.009963846942841444
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.01354097056767927
# Converged in iteration 77 with cost 0.013417175260871413 because of vanishing difference
# Final cost : 0.013417175260871413
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417175260871413
# Final cost : 0.013417166923060064
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166923060064
# Final cost : 0.013417166812467279
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166812467279
# Converged in iteration 91 with cost 0.01341716680930389 because of step counter
# Final cost : 0.01341716680930389
# Compute control for a deterministic system
# Cost in iteration 0: 0.01341716680930389
# Converged in iteration 9 with cost 0.013417166809291666 because of step counter
# Final cost : 0.013417166809291666
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.017412786303154203
# Converged in iteration 169 with cost 0.0167869145335465 because of vanishing difference
# Final cost : 0.0167869145335465
# Compute control for a deterministic system
# Cost in iteration 0: 0.0167869145335465
# Final cost : 0.016786912801565124
# Compute control for a deterministic system
# Cost in iteration 0: 0.016786912801565124
# Final cost : 0.016786912734279742
# Compute control for a deterministic system
# Cost in iteration 0: 0.016786912734279742
# Converged in iteration 139 with cost 0.016786912729576168 because of step counter
# Final cost : 0.016786912729576168
# Compute control for a deterministic system
# Cost in iteration 0: 0.016786912729576168
# Converged in iteration 6 with cost 0.016786912729568115 because of step counter
# Final cost : 0.016786912729568115
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.020687302972546142
# Converged in iteration 182 with cost 0.020231427062153452 because of vanishing difference
# Final cost : 0.020231427062153452
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231427062153452
# Final cost : 0.020231422275177116
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231422275177116
# Final cost : 0.020231421899089566
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231421899089566
# Converged in iteration 200 with cost 0.020231421858940814 because of step counter
# Final cost : 0.020231421858940814
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231421858940814
# Converged in iteration 4 with cost 0.020231421858929698 because of step counter
# Final cost : 0.020231421858929698
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.024576706502352153
# Converged in iteration 98 with cost 0.02366238854834606 because of vanishing difference
# Final cost : 0.02366238854834606
# Compute control for a deterministic system
# Cost in iteration 0: 0.02366238854834606
# Final cost : 0.023662317498841054
# Compute control for a deterministic system
# Cost in iteration 0: 0.023662317498841054
# Final cost : 0.02366231117167907
# Compute control for a deterministic system
# Cost in iteration 0: 0.02366231117167907
# Final cost : 0.023662310171683906
# Compute control for a deterministic system
# Cost in iteration 0: 0.023662310171683906
# Converged in iteration 6 with cost 0.023662310171653135 because of step counter
# Final cost : 0.023662310171653135
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.02945636186661498
# Converged in iteration 199 with cost 0.026972239818153207 because of vanishing difference
# Final cost : 0.026972239818153207
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972239818153207
# Final cost : 0.026972201064245548
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972201064245548
# Final cost : 0.02697219650731841
# Compute control for a deterministic system
# Cost in iteration 0: 0.02697219650731841
# Final cost : 0.026972195553990153
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972195553990153
# Converged in iteration 108 with cost 0.026972195553064356 because of step counter
# Final cost : 0.026972195553064356
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.030564949867206995
# Final cost : 0.030273800889976138
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273800889976138
# Final cost : 0.03027377376743997
# Compute control for a deterministic system
# Cost in iteration 0: 0.03027377376743997
# Final cost : 0.030273769487260637
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273769487260637
# Final cost : 0.03027376838280083
# Compute control for a deterministic system
# Cost in iteration 0: 0.03027376838280083
# Converged in iteration 173 with cost 0.03027376838145473 because of vanishing difference
# Final cost : 0.03027376838145473
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.03745477817806428
# Final cost : 0.033384093128522176
# Compute control for a deterministic system
# Cost in iteration 0: 0.033384093128522176
# Final cost : 0.03338403023553291
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338403023553291
# Final cost : 0.03338401892722095
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338401892722095
# Final cost : 0.033384013868729724
# Compute control for a deterministic system
# Cost in iteration 0: 0.033384013868729724
# Converged in iteration 805 with cost 0.033384013755036676 because of vanishing difference
# Final cost : 0.033384013755036676
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.036427490229553924
# Converged in iteration 161 with cost 0.036421358980375344 because of vanishing difference
# Final cost : 0.036421358980375344
# Compute control for a deterministic system
# Cost in iteration 0: 0.036421358980375344
# Final cost : 0.036421297342919594
# Compute control for a deterministic system
# Cost in iteration 0: 0.036421297342919594
# Final cost : 0.03642128472293944
# Compute control for a deterministic system
# Cost in iteration 0: 0.03642128472293944
# Final cost : 0.03642127968482485
# Compute control for a deterministic system
# Cost in iteration 0: 0.03642127968482485
# Final cost : 0.03642127962060905
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.04054262595751522
# Final cost : 0.03929172535387731
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929172535387731
# Final cost : 0.039291673431170814
# Compute control for a deterministic system
# Cost in iteration 0: 0.039291673431170814
# Final cost : 0.03929166278625368
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929166278625368
# Final cost : 0.03929165842815961
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929165842815961
# Converged in iteration 933 with cost 0.03929165839147328 because of step counter
# Final cost : 0.03929165839147328
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.04869600169385394
# Final cost : 0.04192862022554014
# Compute control for a deterministic system
# Cost in iteration 0: 0.04192862022554014
# Converged in iteration 27 with cost 0.041928522131092216 because of vanishing difference
# Final cost : 0.041928522131092216
# Compute control for a deterministic system
# Cost in iteration 0: 0.041928522131092216
# Final cost : 0.041928289120927484
# Compute control for a deterministic system
# Cost in iteration 0: 0.041928289120927484
# Final cost : 0.04192823403287355
# Compute control for a deterministic system
# Cost in iteration 0: 0.04192823403287355
# Converged in iteration 908 with cost 0.04192823382104658 because of step counter
# Final cost : 0.04192823382104658
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.053573245179020616
# Final cost : 0.04446361514392614
# Compute control for a deterministic system
# Cost in iteration 0: 0.04446361514392614
# Final cost : 0.044463446301082656
# Compute control for a deterministic system
# Cost in iteration 0: 0.044463446301082656
# Final cost : 0.04446341113813904
# Compute control for a deterministic system
# Cost in iteration 0: 0.04446341113813904
# Final cost : 0.044463396098079644
# Compute control for a deterministic system
# Cost in iteration 0: 0.044463396098079644
# Converged in iteration 995 with cost 0.0444633959945613 because of step counter
# Final cost : 0.0444633959945613
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.05348193933020034
# Final cost : 0.04686207989752778
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686207989752778
# Final cost : 0.04686178851198823
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686178851198823
# Final cost : 0.046861724915366706
# Compute control for a deterministic system
# Cost in iteration 0: 0.046861724915366706
# Final cost : 0.04686169417661857
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686169417661857
# Final cost : 0.04686169372819552
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.052394783786961
# Final cost : 0.04911401946301156
# Compute control for a deterministic system
# Cost in iteration 0: 0.04911401946301156
# Final cost : 0.04911375104245571
# Compute control for a deterministic system
# Cost in iteration 0: 0.04911375104245571
# Final cost : 0.0491136694545201
# Compute control for a deterministic system
# Cost in iteration 0: 0.0491136694545201
# Final cost : 0.049113604287955956
# Compute control for a deterministic system
# Cost in iteration 0: 0.049113604287955956
# Final cost : 0.04911359929794113
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.052426936803935925
# Converged in iteration 185 with cost 0.05137380603557816 because of vanishing difference
# Final cost : 0.05137380603557816
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137380603557816
# Final cost : 0.05137358897770805
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137358897770805
# Final cost : 0.05137350730024591
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137350730024591
# Final cost : 0.05137342819145652
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137342819145652
# Final cost : 0.051373419671645486
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.07527153346728438
# Final cost : 0.05364159583215057
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364159583215057
# Final cost : 0.05364119869496494
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364119869496494
# Final cost : 0.05364107710790572
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364107710790572
# Final cost : 0.0536409519661776
# Compute control for a deterministic system
# Cost in iteration 0: 0.0536409519661776
# Final cost : 0.05364093051945065
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.08063899705275834
# Final cost : 0.05591682608201642
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591682608201642
# Converged in iteration 166 with cost 0.05591390083852673 because of vanishing difference
# Final cost : 0.05591390083852673
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591390083852673
# Final cost : 0.05591348883395101
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591348883395101
# Final cost : 0.05591308558849748
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591308558849748
# Final cost : 0.055913005647254224
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.05863310859885467
# Final cost : 0.058340462614871115
# Compute control for a deterministic system
# Cost in iteration 0: 0.058340462614871115
# Final cost : 0.05834009058943594
# Compute control for a deterministic system
# Cost in iteration 0: 0.05834009058943594
# Final cost : 0.05833989571870278
# Compute control for a deterministic system
# Cost in iteration 0: 0.05833989571870278
# Final cost : 0.05833961276026469
# Compute control for a deterministic system
# Cost in iteration 0: 0.05833961276026469
# Final cost : 0.05833950713368311
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.08026577310603607
# Final cost : 0.06090725647327917
# Compute control for a deterministic system
# Cost in iteration 0: 0.06090725647327917
# Converged in iteration 12 with cost 0.06090721869102625 because of vanishing difference
# Final cost : 0.06090721869102625
# Compute control for a deterministic system
# Cost in iteration 0: 0.06090721869102625
# Final cost : 0.060906794091862865
# Compute control for a deterministic system
# Cost in iteration 0: 0.060906794091862865
# Final cost : 0.0609062578200959
# Compute control for a deterministic system
# Cost in iteration 0: 0.0609062578200959
# Final cost : 0.060906058620289284
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.07434216656173002
# Final cost : 0.063580341835735
# Compute control for a deterministic system
# Cost in iteration 0: 0.063580341835735
# Converged in iteration 35 with cost 0.06358021628754044 because of vanishing difference
# Final cost : 0.06358021628754044
# Compute control for a deterministic system
# Cost in iteration 0: 0.06358021628754044
# Final cost : 0.06357968122332176
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357968122332176
# Final cost : 0.06357879230366556
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357879230366556
# Final cost : 0.0635783757606566
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.10476318392208223
# Final cost : 0.06661716457629246
# Compute control for a deterministic system
# Cost in iteration 0: 0.06661716457629246
# Final cost : 0.06650754818848917
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650754818848917
# Final cost : 0.06650652455202892
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650652455202892
# Final cost : 0.06650468363595999
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650468363595999
# Final cost : 0.06650380101950468
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.10231487238890916
# Final cost : 0.06963207386608865
# Compute control for a deterministic system
# Cost in iteration 0: 0.06963207386608865
# Converged in iteration 185 with cost 0.06956798882242798 because of vanishing difference
# Final cost : 0.06956798882242798
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956798882242798
# Final cost : 0.0695675376883276
# Compute control for a deterministic system
# Cost in iteration 0: 0.0695675376883276
# Final cost : 0.06956678993082437
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956678993082437
# Final cost : 0.0695664120491982
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.1019111731833573
# Converged in iteration 180 with cost 0.07293200462212192 because of vanishing difference
# Final cost : 0.07293200462212192
# Compute control for a deterministic system
# Cost in iteration 0: 0.07293200462212192
# Final cost : 0.07292865225949942
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292865225949942
# Final cost : 0.07292679166191504
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292679166191504
# Final cost : 0.07292249187108121
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292249187108121
# Final cost : 0.0729206902643798
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.07545771649866172
# Converged in iteration 195 with cost 0.06981275545204403 because of vanishing difference
# Final cost : 0.06981275545204403
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981275545204403
# Final cost : 0.06981253649578997
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981253649578997
# Final cost : 0.06981244540081906
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981244540081906
# Final cost : 0.06981235593064118
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981235593064118
# Final cost : 0.06981233656396577
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.07119866443793424
# Final cost : 0.0624980524728523
# Compute control for a deterministic system
# Cost in iteration 0: 0.0624980524728523
# Final cost : 0.06249795389876696
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249795389876696
# Final cost : 0.062497919298085625
# Compute control for a deterministic system
# Cost in iteration 0: 0.062497919298085625
# Final cost : 0.06249789079520197
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249789079520197
# Final cost : 0.06249788621456547
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.05963980280313227
# Final cost : 0.055562706374044986
# Compute control for a deterministic system
# Cost in iteration 0: 0.055562706374044986
# Final cost : 0.05556267495294416
# Compute control for a deterministic system
# Cost in iteration 0: 0.05556267495294416
# Final cost : 0.0555626656447691
# Compute control for a deterministic system
# Cost in iteration 0: 0.0555626656447691
# Final cost : 0.05556266510151298
# Compute control for a deterministic system
# Cost in iteration 0: 0.05556266510151298
# Final cost : 0.05556266501410782
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.05616089046509859
# Converged in iteration 139 with cost 0.04913836260410108 because of vanishing difference
# Final cost : 0.04913836260410108
# Compute control for a deterministic system
# Cost in iteration 0: 0.04913836260410108
# Final cost : 0.04913826233575426
# Compute control for a deterministic system
# Cost in iteration 0: 0.04913826233575426
# Final cost : 0.04913824324278893
# Compute control for a deterministic system
# Cost in iteration 0: 0.04913824324278893
# Final cost : 0.04913824314397502
# Compute control for a deterministic system
# Cost in iteration 0: 0.04913824314397502
# Converged in iteration 604 with cost 0.0491382431312786 because of step counter
# Final cost : 0.0491382431312786
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.04749064512029069
# Final cost : 0.04329992695949874
# Compute control for a deterministic system
# Cost in iteration 0: 0.04329992695949874
# Final cost : 0.043299903742161895
# Compute control for a deterministic system
# Cost in iteration 0: 0.043299903742161895
# Final cost : 0.04329990055131804
# Compute control for a deterministic system
# Cost in iteration 0: 0.04329990055131804
# Final cost : 0.043299900476674535
# Compute control for a deterministic system
# Cost in iteration 0: 0.043299900476674535
# Converged in iteration 478 with cost 0.04329990046744642 because of step counter
# Final cost : 0.04329990046744642
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.04081107403352179
# Converged in iteration 180 with cost 0.03772536842932715 because of vanishing difference
# Final cost : 0.03772536842932715
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772536842932715
# Final cost : 0.03772534563470241
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772534563470241
# Final cost : 0.03772534001544011
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772534001544011
# Final cost : 0.03772533955660923
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772533955660923
# Converged in iteration 796 with cost 0.037725339513440564 because of step counter
# Final cost : 0.037725339513440564
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.03649939319282582
# Converged in iteration 172 with cost 0.03250878824375538 because of vanishing difference
# Final cost : 0.03250878824375538
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250878824375538
# Final cost : 0.032508757195755945
# Compute control for a deterministic system
# Cost in iteration 0: 0.032508757195755945
# Final cost : 0.032508753681852846
# Compute control for a deterministic system
# Cost in iteration 0: 0.032508753681852846
# Final cost : 0.03250875354780715
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250875354780715
# Converged in iteration 314 with cost 0.03250875354304096 because of step counter
# Final cost : 0.03250875354304096
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.027846274069595292
# Converged in iteration 147 with cost 0.02771523559571935 because of vanishing difference
# Final cost : 0.02771523559571935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02771523559571935
# Final cost : 0.027715232389410763
# Compute control for a deterministic system
# Cost in iteration 0: 0.027715232389410763
# Final cost : 0.02771523215849381
# Compute control for a deterministic system
# Cost in iteration 0: 0.02771523215849381
# Converged in iteration 283 with cost 0.027715232152993555 because of step counter
# Final cost : 0.027715232152993555
# Compute control for a deterministic system
# Cost in iteration 0: 0.027715232152993555
# Converged in iteration 1 with cost 0.027715232152993555 because of step counter
# Final cost : 0.027715232152993555
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.02309157813079252
# Converged in iteration 134 with cost 0.02308270989576975 because of vanishing difference
# Final cost : 0.02308270989576975
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270989576975
# Final cost : 0.023082707502888922
# Compute control for a deterministic system
# Cost in iteration 0: 0.023082707502888922
# Final cost : 0.023082707365213225
# Compute control for a deterministic system
# Cost in iteration 0: 0.023082707365213225
# Converged in iteration 159 with cost 0.02308270736367109 because of step counter
# Final cost : 0.02308270736367109
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270736367109
# Converged in iteration 10 with cost 0.023082707363558663 because of step counter
# Final cost : 0.023082707363558663
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.018702946108684018
# Converged in iteration 74 with cost 0.018690083642493395 because of vanishing difference
# Final cost : 0.018690083642493395
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690083642493395
# Converged in iteration 166 with cost 0.018690076419473386 because of step counter
# Final cost : 0.018690076419473386
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076419473386
# Converged in iteration 1 with cost 0.018690076419473386 because of step counter
# Final cost : 0.018690076419473386
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076419473386
# Converged in iteration 1 with cost 0.018690076419473386 because of step counter
# Final cost : 0.018690076419473386
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076419473386
# Converged in iteration 1 with cost 0.018690076419473386 because of step counter
# Final cost : 0.018690076419473386
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.014601002702899664
# Converged in iteration 138 with cost 0.014599034032248995 because of vanishing difference
# Final cost : 0.014599034032248995
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599034032248995
# Converged in iteration 148 with cost 0.014599032801740823 because of step counter
# Final cost : 0.014599032801740823
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032801740823
# Converged in iteration 1 with cost 0.014599032801740823 because of step counter
# Final cost : 0.014599032801740823
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032801740823
# Converged in iteration 1 with cost 0.014599032801740823 because of step counter
# Final cost : 0.014599032801740823
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032801740823
# Converged in iteration 1 with cost 0.014599032801740823 because of step counter
# Final cost : 0.014599032801740823
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.010635314051961884
# Converged in iteration 101 with cost 0.010594670815239625 because of vanishing difference
# Final cost : 0.010594670815239625
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594670815239625
# Converged in iteration 184 with cost 0.010594666701144954 because of step counter
# Final cost : 0.010594666701144954
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666701144954
# Converged in iteration 1 with cost 0.010594666701144954 because of step counter
# Final cost : 0.010594666701144954
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666701144954
# Converged in iteration 2 with cost 0.010594666701144105 because of step counter
# Final cost : 0.010594666701144105
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666701144105
# Converged in iteration 1 with cost 0.010594666701144105 because of step counter
# Final cost : 0.010594666701144105
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070122825306787985
# Converged in iteration 168 with cost 0.006845125743498571 because of vanishing difference
# Final cost : 0.006845125743498571
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125743498571
# Converged in iteration 123 with cost 0.006845125521859312 because of step counter
# Final cost : 0.006845125521859312
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125521859312
# Converged in iteration 2 with cost 0.006845125521858896 because of step counter
# Final cost : 0.006845125521858896
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125521858896
# Converged in iteration 1 with cost 0.006845125521858896 because of step counter
# Final cost : 0.006845125521858896
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125521858896
# Converged in iteration 1 with cost 0.006845125521858896 because of step counter
# Final cost : 0.006845125521858896
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.003295657105020905
# Converged in iteration 93 with cost 0.003189572369718566 because of vanishing difference
# Final cost : 0.003189572369718566
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189572369718566
# Converged in iteration 84 with cost 0.003189571581095349 because of step counter
# Final cost : 0.003189571581095349
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189571581095349
# Converged in iteration 2 with cost 0.0031895715810946815 because of step counter
# Final cost : 0.0031895715810946815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031895715810946815
# Converged in iteration 2 with cost 0.003189571581092421 because of step counter
# Final cost : 0.003189571581092421
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189571581092421
# Converged in iteration 1 with cost 0.003189571581092421 because of step counter
# Final cost : 0.003189571581092421
# -----------------------------------------------
# 4 found better solution,  39
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.003203079025968541
# Converged in iteration 49 with cost 0.003143110822178487 because of step counter
# Final cost : 0.003143110822178487
# Compute control for a deterministic system
# Cost in iteration 0: 0.003143110822178487
# Converged in iteration 1 with cost 0.003143110822178487 because of step counter
# Final cost : 0.003143110822178487
# Compute control for a deterministic system
# Cost in iteration 0: 0.003143110822178487
# Converged in iteration 1 with cost 0.003143110822178487 because of step counter
# Final cost : 0.003143110822178487
# Compute control for a deterministic system
# Cost in iteration 0: 0.003143110822178487
# Converged in iteration 1 with cost 0.003143110822178487 because of step counter
# Final cost : 0.003143110822178487
# Compute control for a deterministic system
# Cost in iteration 0: 0.003143110822178487
# Converged in iteration 1 with cost 0.003143110822178487 because of step counter
# Final cost : 0.003143110822178487
# -----------------------------------------------
# 5 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.006693344615781813
# Converged in iteration 74 with cost 0.0065051655054733535 because of vanishing difference
# Final cost : 0.0065051655054733535
# Compute control for a deterministic system
# Cost in iteration 0: 0.0065051655054733535
# Final cost : 0.00650516525489911
# Compute control for a deterministic system
# Cost in iteration 0: 0.00650516525489911
# Converged in iteration 3 with cost 0.006505165254892284 because of step counter
# Final cost : 0.006505165254892284
# Compute control for a deterministic system
# Cost in iteration 0: 0.006505165254892284
# Converged in iteration 1 with cost 0.006505165254892284 because of step counter
# Final cost : 0.006505165254892284
# Compute control for a deterministic system
# Cost in iteration 0: 0.006505165254892284
# Converged in iteration 1 with cost 0.006505165254892284 because of step counter
# Final cost : 0.006505165254892284
# -----------------------------------------------
# 5 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.010104737340913838
# Converged in iteration 76 with cost 0.009963849799385714 because of vanishing difference
# Final cost : 0.009963849799385714
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963849799385714
# Final cost : 0.009963846885269164
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963846885269164
# Converged in iteration 165 with cost 0.009963846883026827 because of step counter
# Final cost : 0.009963846883026827
# Compute control for a deterministic system
# Cost in iteration 0: 0.009963846883026827
# Converged in iteration 5 with cost 0.00996384688297175 because of step counter
# Final cost : 0.00996384688297175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00996384688297175
# Converged in iteration 2 with cost 0.009963846882970313 because of step counter
# Final cost : 0.009963846882970313
# -----------------------------------------------
# 5 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.013452104092881034
# Final cost : 0.013417166703394507
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166703394507
# Converged in iteration 70 with cost 0.013417166702997942 because of step counter
# Final cost : 0.013417166702997942
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166702997942
# Converged in iteration 13 with cost 0.013417166702923379 because of step counter
# Final cost : 0.013417166702923379
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166702923379
# Converged in iteration 1 with cost 0.013417166702923379 because of step counter
# Final cost : 0.013417166702923379
# Compute control for a deterministic system
# Cost in iteration 0: 0.013417166702923379
# Converged in iteration 1 with cost 0.013417166702923379 because of step counter
# Final cost : 0.013417166702923379
# -----------------------------------------------
# 5 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.01799067258107448
# Final cost : 0.01678691272892017
# Compute control for a deterministic system
# Cost in iteration 0: 0.01678691272892017
# Final cost : 0.01678691261875945
# Compute control for a deterministic system
# Cost in iteration 0: 0.01678691261875945
# Final cost : 0.01678691260864821
# Compute control for a deterministic system
# Cost in iteration 0: 0.01678691260864821
# Converged in iteration 84 with cost 0.016786912607206383 because of step counter
# Final cost : 0.016786912607206383
# Compute control for a deterministic system
# Cost in iteration 0: 0.016786912607206383
# Converged in iteration 24 with cost 0.016786912607111834 because of step counter
# Final cost : 0.016786912607111834
# -----------------------------------------------
# 5 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.02110140734698847
# Converged in iteration 129 with cost 0.020231424199909996 because of vanishing difference
# Final cost : 0.020231424199909996
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231424199909996
# Final cost : 0.0202314219720635
# Compute control for a deterministic system
# Cost in iteration 0: 0.0202314219720635
# Final cost : 0.020231421864776226
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231421864776226
# Converged in iteration 283 with cost 0.020231421839504073 because of step counter
# Final cost : 0.020231421839504073
# Compute control for a deterministic system
# Cost in iteration 0: 0.020231421839504073
# Converged in iteration 1 with cost 0.020231421839504073 because of step counter
# Final cost : 0.020231421839504073
# -----------------------------------------------
# 5 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.028806967090165093
# Converged in iteration 185 with cost 0.02366231840542446 because of vanishing difference
# Final cost : 0.02366231840542446
# Compute control for a deterministic system
# Cost in iteration 0: 0.02366231840542446
# Final cost : 0.02366231094970403
# Compute control for a deterministic system
# Cost in iteration 0: 0.02366231094970403
# Final cost : 0.023662310264638775
# Compute control for a deterministic system
# Cost in iteration 0: 0.023662310264638775
# Final cost : 0.02366231012406456
# Compute control for a deterministic system
# Cost in iteration 0: 0.02366231012406456
# Converged in iteration 6 with cost 0.0236623101240437 because of step counter
# Final cost : 0.0236623101240437
# -----------------------------------------------
# 5 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.03235830747493608
# Converged in iteration 165 with cost 0.02697221196012489 because of vanishing difference
# Final cost : 0.02697221196012489
# Compute control for a deterministic system
# Cost in iteration 0: 0.02697221196012489
# Final cost : 0.026972197402764596
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972197402764596
# Final cost : 0.026972195900541302
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972195900541302
# Final cost : 0.026972195502946876
# Compute control for a deterministic system
# Cost in iteration 0: 0.026972195502946876
# Converged in iteration 242 with cost 0.02697219550077389 because of step counter
# Final cost : 0.02697219550077389
# -----------------------------------------------
# 5 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.031603954621139324
# Final cost : 0.030273770313032432
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273770313032432
# Final cost : 0.030273768742196883
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273768742196883
# Final cost : 0.030273768441826516
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273768441826516
# Final cost : 0.030273768243744663
# Compute control for a deterministic system
# Cost in iteration 0: 0.030273768243744663
# Converged in iteration 499 with cost 0.03027376823836884 because of step counter
# Final cost : 0.03027376823836884
# -----------------------------------------------
# 5 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.04392344673393174
# Final cost : 0.03338415356299405
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338415356299405
# Converged in iteration 100 with cost 0.03338405178234627 because of vanishing difference
# Final cost : 0.03338405178234627
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338405178234627
# Final cost : 0.03338402417346264
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338402417346264
# Final cost : 0.03338401533352469
# Compute control for a deterministic system
# Cost in iteration 0: 0.03338401533352469
# Final cost : 0.033384015050806286
# Compute control for a deterministic system
# Cost in iteration 0: 0.04284718533885912
# Converged in iteration 164 with cost 0.0364213410346301 because of vanishing difference
# Final cost : 0.0364213410346301
# Compute control for a deterministic system
# Cost in iteration 0: 0.0364213410346301
# Final cost : 0.036421287068825685
# Compute control for a deterministic system
# Cost in iteration 0: 0.036421287068825685
# Final cost : 0.03642128192687091
# Compute control for a deterministic system
# Cost in iteration 0: 0.03642128192687091
# Final cost : 0.03642127967929141
# Compute control for a deterministic system
# Cost in iteration 0: 0.03642127967929141
# Final cost : 0.03642127960779205
# -----------------------------------------------
# 5 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.041343115814949434
# Converged in iteration 197 with cost 0.03929167682520804 because of vanishing difference
# Final cost : 0.03929167682520804
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929167682520804
# Final cost : 0.03929166071582147
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929166071582147
# Final cost : 0.03929165919648795
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929165919648795
# Final cost : 0.03929165836117948
# Compute control for a deterministic system
# Cost in iteration 0: 0.03929165836117948
# Final cost : 0.03929165830926531
# -----------------------------------------------
# 5 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.04345921865390211
# Final cost : 0.041928244649595034
# Compute control for a deterministic system
# Cost in iteration 0: 0.041928244649595034
# Final cost : 0.04192823486441789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04192823486441789
# Final cost : 0.041928233501319495
# Compute control for a deterministic system
# Cost in iteration 0: 0.041928233501319495
# Final cost : 0.041928232519325113
# Compute control for a deterministic system
# Cost in iteration 0: 0.041928232519325113
# Final cost : 0.04192823244576889
# -----------------------------------------------
# 5 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.04455781402385753
# Final cost : 0.044463396252415244
# Compute control for a deterministic system
# Cost in iteration 0: 0.044463396252415244
# Final cost : 0.044463395676420145
# Compute control for a deterministic system
# Cost in iteration 0: 0.044463395676420145
# Final cost : 0.04446339559822703
# Compute control for a deterministic system
# Cost in iteration 0: 0.04446339559822703
# Final cost : 0.04446339554565111
# Compute control for a deterministic system
# Cost in iteration 0: 0.04446339554565111
# Converged in iteration 545 with cost 0.044463395541630965 because of step counter
# Final cost : 0.044463395541630965
# -----------------------------------------------
# 5 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.0483923126655474
# Converged in iteration 178 with cost 0.04686172930351584 because of vanishing difference
# Final cost : 0.04686172930351584
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686172930351584
# Final cost : 0.046861698265987024
# Compute control for a deterministic system
# Cost in iteration 0: 0.046861698265987024
# Final cost : 0.04686169495605231
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686169495605231
# Final cost : 0.04686169330405582
# Compute control for a deterministic system
# Cost in iteration 0: 0.04686169330405582
# Final cost : 0.04686169316881053
# -----------------------------------------------
# 5 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.04914010525065835
# Final cost : 0.04911359899261666
# Compute control for a deterministic system
# Cost in iteration 0: 0.04911359899261666
# Final cost : 0.049113598827773136
# Compute control for a deterministic system
# Cost in iteration 0: 0.049113598827773136
# Final cost : 0.049113598793856225
# Compute control for a deterministic system
# Cost in iteration 0: 0.049113598793856225
# Final cost : 0.049113598764875616
# Compute control for a deterministic system
# Cost in iteration 0: 0.049113598764875616
# Converged in iteration 322 with cost 0.04911359876288565 because of step counter
# Final cost : 0.04911359876288565
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.05612248344018062
# Final cost : 0.051373480223643714
# Compute control for a deterministic system
# Cost in iteration 0: 0.051373480223643714
# Final cost : 0.05137343913628376
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137343913628376
# Final cost : 0.051373428720116694
# Compute control for a deterministic system
# Cost in iteration 0: 0.051373428720116694
# Final cost : 0.05137341979196753
# Compute control for a deterministic system
# Cost in iteration 0: 0.05137341979196753
# Final cost : 0.05137341882817106
# -----------------------------------------------
# 5 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.0740338004472732
# Final cost : 0.05364119019039581
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364119019039581
# Final cost : 0.0536409833889316
# Compute control for a deterministic system
# Cost in iteration 0: 0.0536409833889316
# Final cost : 0.05364095219005762
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364095219005762
# Final cost : 0.05364093101767638
# Compute control for a deterministic system
# Cost in iteration 0: 0.05364093101767638
# Final cost : 0.0536409276391416
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.06881303811832813
# Converged in iteration 154 with cost 0.05591318021739671 because of vanishing difference
# Final cost : 0.05591318021739671
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591318021739671
# Final cost : 0.05591306622283866
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591306622283866
# Final cost : 0.055913034948735195
# Compute control for a deterministic system
# Cost in iteration 0: 0.055913034948735195
# Final cost : 0.05591300034257682
# Compute control for a deterministic system
# Cost in iteration 0: 0.05591300034257682
# Final cost : 0.05591299189717797
# -----------------------------------------------
# ...
# Final cost : 0.05833957627439447
# Compute control for a deterministic system
# Cost in iteration 0: 0.05833957627439447
# Final cost : 0.05833952007728153
# Compute control for a deterministic system
# Cost in iteration 0: 0.05833952007728153
# Final cost : 0.058339487010653626
# Compute control for a deterministic system
# Cost in iteration 0: 0.058339487010653626
# Final cost : 0.05833948403692681
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.06106320281307237
# Final cost : 0.06090604607868215
# Compute control for a deterministic system
# Cost in iteration 0: 0.06090604607868215
# Final cost : 0.0609060371871331
# Compute control for a deterministic system
# Cost in iteration 0: 0.0609060371871331
# Final cost : 0.06090603100736611
# Compute control for a deterministic system
# Cost in iteration 0: 0.06090603100736611
# Final cost : 0.06090601855287406
# Compute control for a deterministic system
# Cost in iteration 0: 0.06090601855287406
# Final cost : 0.060906012315052944
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.1130068891153411
# Final cost : 0.06366381836270281
# Compute control for a deterministic system
# Cost in iteration 0: 0.06366381836270281
# Converged in iteration 192 with cost 0.06357848121234634 because of vanishing difference
# Final cost : 0.06357848121234634
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357848121234634
# Final cost : 0.06357835607495163
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357835607495163
# Final cost : 0.06357825061360613
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357825061360613
# Final cost : 0.06357823611962725
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.07153745027576451
# Final cost : 0.06650377382062042
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650377382062042
# Final cost : 0.06650370541227775
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650370541227775
# Final cost : 0.06650365918634948
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650365918634948
# Final cost : 0.06650356139357352
# Compute control for a deterministic system
# Cost in iteration 0: 0.06650356139357352
# Final cost : 0.06650350348279234
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.09845714918310444
# Final cost : 0.06956848797389843
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956848797389843
# Converged in iteration 82 with cost 0.06956660053100093 because of vanishing difference
# Final cost : 0.06956660053100093
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956660053100093
# Final cost : 0.06956637495267824
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956637495267824
# Final cost : 0.06956629305105773
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956629305105773
# Final cost : 0.0695662739404391
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.07842939814438564
# Converged in iteration 157 with cost 0.07292052590712571 because of vanishing difference
# Final cost : 0.07292052590712571
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292052590712571
# Final cost : 0.07292039989382726
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292039989382726
# Final cost : 0.07292030944047909
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292030944047909
# Final cost : 0.07292008600984659
# Compute control for a deterministic system
# Cost in iteration 0: 0.07292008600984659
# Final cost : 0.0729199863331281
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.07001397986514016
# Final cost : 0.06981233707093348
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981233707093348
# Final cost : 0.06981233621385192
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981233621385192
# Final cost : 0.06981233589677374
# Compute control for a deterministic system
# Cost in iteration 0: 0.06981233589677374
# Final cost : 0.0698123355836814
# Compute control for a deterministic system
# Cost in iteration 0: 0.0698123355836814
# Final cost : 0.06981233552251061
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.06308165288023261
# Final cost : 0.06249788706095302
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249788706095302
# Final cost : 0.062497885887553256
# Compute control for a deterministic system
# Cost in iteration 0: 0.062497885887553256
# Final cost : 0.06249788559946499
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249788559946499
# Final cost : 0.06249788537252184
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249788537252184
# Converged in iteration 862 with cost 0.06249788533718962 because of step counter
# Final cost : 0.06249788533718962
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.057525515817468974
# Final cost : 0.055562672417453225
# Compute control for a deterministic system
# Cost in iteration 0: 0.055562672417453225
# Converged in iteration 1 with cost 0.055562672417453225 because of vanishing difference
# Final cost : 0.055562672417453225
# Compute control for a deterministic system
# Cost in iteration 0: 0.055562672417453225
# Final cost : 0.05556266607854285
# Compute control for a deterministic system
# Cost in iteration 0: 0.05556266607854285
# Final cost : 0.05556266600421085
# Compute control for a deterministic system
# Cost in iteration 0: 0.05556266600421085
# Converged in iteration 509 with cost 0.05556266599454796 because of step counter
# Final cost : 0.05556266599454796
# Compute control for a deterministic system
# Cost in iteration 0: 0.05667641483539912
# Final cost : 0.04913829067735864
# Compute control for a deterministic system
# Cost in iteration 0: 0.04913829067735864
# Final cost : 0.049138251347893125
# Compute control for a deterministic system
# Cost in iteration 0: 0.049138251347893125
# Final cost : 0.049138243014982444
# Compute control for a deterministic system
# Cost in iteration 0: 0.049138243014982444
# Final cost : 0.049138242983683536
# Compute control for a deterministic system
# Cost in iteration 0: 0.049138242983683536
# Converged in iteration 305 with cost 0.049138242980893344 because of step counter
# Final cost : 0.049138242980893344
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.04760863798014245
# Converged in iteration 153 with cost 0.0432999788060494 because of vanishing difference
# Final cost : 0.0432999788060494
# Compute control for a deterministic system
# Cost in iteration 0: 0.0432999788060494
# Final cost : 0.043299906500470914
# Compute control for a deterministic system
# Cost in iteration 0: 0.043299906500470914
# Final cost : 0.04329990056345992
# Compute control for a deterministic system
# Cost in iteration 0: 0.04329990056345992
# Final cost : 0.04329990032873076
# Compute control for a deterministic system
# Cost in iteration 0: 0.04329990032873076
# Converged in iteration 742 with cost 0.04329990029748544 because of step counter
# Final cost : 0.04329990029748544
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0395427090706924
# Converged in iteration 166 with cost 0.03772535342941737 because of vanishing difference
# Final cost : 0.03772535342941737
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772535342941737
# Final cost : 0.03772534095952391
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772534095952391
# Final cost : 0.03772533967493505
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772533967493505
# Final cost : 0.037725339584807976
# Compute control for a deterministic system
# Cost in iteration 0: 0.037725339584807976
# Converged in iteration 479 with cost 0.037725339577206515 because of step counter
# Final cost : 0.037725339577206515
# Compute control for a deterministic system
# Cost in iteration 0: 0.036059878197130565
# Final cost : 0.03250876507729787
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250876507729787
# Final cost : 0.03250875469961454
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250875469961454
# Final cost : 0.03250875344473265
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250875344473265
# Final cost : 0.03250875339845624
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250875339845624
# Converged in iteration 203 with cost 0.03250875339681518 because of step counter
# Final cost : 0.03250875339681518
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.02967491000978108
# Final cost : 0.02771523623523087
# Compute control for a deterministic system
# Cost in iteration 0: 0.02771523623523087
# Final cost : 0.02771523239433271
# Compute control for a deterministic system
# Cost in iteration 0: 0.02771523239433271
# Final cost : 0.027715232014174106
# Compute control for a deterministic system
# Cost in iteration 0: 0.027715232014174106
# Final cost : 0.027715231994359355
# Compute control for a deterministic system
# Cost in iteration 0: 0.027715231994359355
# Converged in iteration 40 with cost 0.027715231994176682 because of step counter
# Final cost : 0.027715231994176682
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.024326562374811404
# Final cost : 0.02308270899393828
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270899393828
# Final cost : 0.02308270738418748
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270738418748
# Final cost : 0.02308270725539676
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270725539676
# Converged in iteration 300 with cost 0.02308270725060203 because of step counter
# Final cost : 0.02308270725060203
# Compute control for a deterministic system
# Cost in iteration 0: 0.02308270725060203
# Converged in iteration 22 with cost 0.0230827072503695 because of step counter
# Final cost : 0.0230827072503695
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.019443445146265535
# Final cost : 0.018690076908034377
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076908034377
# Converged in iteration 132 with cost 0.018690076276767484 because of step counter
# Final cost : 0.018690076276767484
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076276767484
# Converged in iteration 5 with cost 0.018690076276763494 because of step counter
# Final cost : 0.018690076276763494
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076276763494
# Converged in iteration 2 with cost 0.018690076276763418 because of step counter
# Final cost : 0.018690076276763418
# Compute control for a deterministic system
# Cost in iteration 0: 0.018690076276763418
# Converged in iteration 1 with cost 0.018690076276763418 because of step counter
# Final cost : 0.018690076276763418
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.015180325939710013
# Converged in iteration 111 with cost 0.01459904490532782 because of vanishing difference
# Final cost : 0.01459904490532782
# Compute control for a deterministic system
# Cost in iteration 0: 0.01459904490532782
# Final cost : 0.014599032809885162
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032809885162
# Converged in iteration 6 with cost 0.014599032809870714 because of step counter
# Final cost : 0.014599032809870714
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032809870714
# Converged in iteration 1 with cost 0.014599032809870714 because of step counter
# Final cost : 0.014599032809870714
# Compute control for a deterministic system
# Cost in iteration 0: 0.014599032809870714
# Converged in iteration 1 with cost 0.014599032809870714 because of step counter
# Final cost : 0.014599032809870714
# Compute control for a deterministic system
# Cost in iteration 0: 0.010606075397690613
# Final cost : 0.010594666576636148
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666576636148
# Converged in iteration 77 with cost 0.010594666574954583 because of step counter
# Final cost : 0.010594666574954583
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666574954583
# Converged in iteration 1 with cost 0.010594666574954583 because of step counter
# Final cost : 0.010594666574954583
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666574954583
# Converged in iteration 1 with cost 0.010594666574954583 because of step counter
# Final cost : 0.010594666574954583
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594666574954583
# Converged in iteration 3 with cost 0.010594666574953513 because of step counter
# Final cost : 0.010594666574953513
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.007040682331824218
# Converged in iteration 100 with cost 0.006845127626413212 because of vanishing difference
# Final cost : 0.006845127626413212
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845127626413212
# Converged in iteration 127 with cost 0.006845125483089769 because of step counter
# Final cost : 0.006845125483089769
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125483089769
# Converged in iteration 12 with cost 0.006845125483073312 because of step counter
# Final cost : 0.006845125483073312
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125483073312
# Converged in iteration 6 with cost 0.006845125483070061 because of step counter
# Final cost : 0.006845125483070061
# Compute control for a deterministic system
# Cost in iteration 0: 0.006845125483070061
# Converged in iteration 3 with cost 0.006845125483067527 because of step counter
# Final cost : 0.006845125483067527
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032236101588965288
# Converged in iteration 86 with cost 0.0031895716844141248 because of vanishing difference
# Final cost : 0.0031895716844141248
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031895716844141248
# Converged in iteration 56 with cost 0.003189571574645262 because of step counter
# Final cost : 0.003189571574645262
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189571574645262
# Converged in iteration 1 with cost 0.003189571574645262 because of step counter
# Final cost : 0.003189571574645262
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189571574645262
# Converged in iteration 1 with cost 0.003189571574645262 because of step counter
# Final cost : 0.003189571574645262
# Compute control for a deterministic system
# Cost in iteration 0: 0.003189571574645262
# Converged in iteration 1 with cost 0.003189571574645262 because of step counter
# Final cost : 0.003189571574645262
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
