# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period)

wc.run()
init_min = [wc.exc[0,1301], wc.inh[0,1301]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  17.457857142857144
# minima =  [  485  2252  4000  5746  7492  9237 10983 12729 14474 16220 17966 19711
#  21457 23203 24948 26694 28440]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("c_s1_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("c_s1_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)


        save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011258047285431419
# Final cost : 4.455690304869107e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.455690304869107e-06
# Final cost : 4.408522951841034e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.408522951841034e-06
# Final cost : 4.312639765804837e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.312639765804837e-06
# Final cost : 4.231332103737663e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.231332103737663e-06
# Final cost : 4.0979357302610445e-06
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022586030096311097
# Final cost : 1.6284631887389583e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6284631887389583e-05
# Final cost : 1.6168303150077535e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6168303150077535e-05
# Final cost : 1.5999387312633114e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.5999387312633114e-05
# Final cost : 1.5783344140097666e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.5783344140097666e-05
# Final cost : 1.539146713392644e-05
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.000425172235980286
# Final cost : 3.415676283424361e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.415676283424361e-05
# Final cost : 3.404573356518072e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.404573356518072e-05
# Final cost : 3.38814716080325e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.38814716080325e-05
# Final cost : 3.3656408666594364e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3656408666594364e-05
# Final cost : 3.328797534743334e-05
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 5.9961664743365175e-05
# Final cost : 5.9232341129917965e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.9232341129917965e-05
# Final cost : 5.900570284809513e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.900570284809513e-05
# Final cost : 5.88181224442528e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.88181224442528e-05
# Final cost : 5.858189368186878e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.858189368186878e-05
# Final cost : 5.818796477076486e-05
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022837426333863604
# Final cost : 9.330491710287445e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.330491710287445e-05
# Final cost : 9.298179129428611e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.298179129428611e-05
# Final cost : 9.219990991023242e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.219990991023242e-05
# Final cost : 9.165764947872234e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.165764947872234e-05
# Final cost : 9.071864079646531e-05
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005395650541662434
# Final cost : 0.00013132851718064754
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013132851718064754
# Final cost : 0.00013105690997031004
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013105690997031004
# Final cost : 0.00013068983277192452
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013068983277192452
# Final cost : 0.00013020150597321546
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013020150597321546
# Final cost : 0.0001294581015249486
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010738917448649696
# Final cost : 0.00017600231037883765
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017600231037883765
# Final cost : 0.00017580073608543224
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017580073608543224
# Final cost : 0.0001755265893403715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001755265893403715
# Final cost : 0.00017517604075255265
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017517604075255265
# Final cost : 0.0001745948870584258
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.00269139214721565
# Final cost : 0.00022924417043506198
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022924417043506198
# Final cost : 0.00022903664568383673
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022903664568383673
# Final cost : 0.00022874494278255162
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022874494278255162
# Final cost : 0.000228332601910033
# Compute control for a deterministic system
# Cost in iteration 0: 0.000228332601910033
# Final cost : 0.0002277566331674851
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006581585939609813
# Final cost : 0.00029857184142260745
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029857184142260745
# Final cost : 0.0002980375353427591
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002980375353427591
# Final cost : 0.00029719736606067474
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029719736606067474
# Final cost : 0.00029618471169629896
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029618471169629896
# Final cost : 0.0002943901164931624
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007132463964748613
# Final cost : 0.0003819807308200445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003819807308200445
# Final cost : 0.00038078646548396304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038078646548396304
# Final cost : 0.0003792373407419702
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003792373407419702
# Final cost : 0.00037716812676161346
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037716812676161346
# Final cost : 0.00037373137991027157
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.003901878716749327
# Final cost : 0.0004681515458360663
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004681515458360663
# Final cost : 0.0004667373247128921
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004667373247128921
# Final cost : 0.0004648221603033309
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004648221603033309
# Final cost : 0.00046220181387130816
# Compute control for a deterministic system
# Cost in iteration 0: 0.00046220181387130816
# Final cost : 0.0004582142867890812
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005718107402579665
# Final cost : 0.0005578823083269219
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005578823083269219
# Final cost : 0.000556988478708341
# Compute control for a deterministic system
# Cost in iteration 0: 0.000556988478708341
# Final cost : 0.0005551821167704085
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005551821167704085
# Final cost : 0.0005527441116743276
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005527441116743276
# Final cost : 0.000549414367533917
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.00113585213202326
# Final cost : 0.0006558602765784927
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006558602765784927
# Final cost : 0.0006546675620337724
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006546675620337724
# Final cost : 0.0006530440732106247
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006530440732106247
# Final cost : 0.0006506893530460224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006506893530460224
# Final cost : 0.0006473522444409614
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.006512296497170641
# Final cost : 0.0007679463001019466
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007679463001019466
# Final cost : 0.0007639305900323748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007639305900323748
# Final cost : 0.0007620718755847658
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007620718755847658
# Final cost : 0.0007601756709627143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007601756709627143
# Final cost : 0.0007573890903525925
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.010015858363294659
# Final cost : 0.0008910090294669047
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008910090294669047
# Final cost : 0.0008856235342376819
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008856235342376819
# Final cost : 0.0008833309983950054
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008833309983950054
# Final cost : 0.0008815726543882827
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008815726543882827
# Final cost : 0.0008792367595655969
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029110500567645584
# Final cost : 0.0010099508422126181
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010099508422126181
# Final cost : 0.001008703564586271
# Compute control for a deterministic system
# Cost in iteration 0: 0.001008703564586271
# Final cost : 0.0010074972624634071
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010074972624634071
# Final cost : 0.0010062171128439612
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010062171128439612
# Final cost : 0.0010045321390421893
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.013918187995350592
# Final cost : 0.0011468153518380078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011468153518380078
# Final cost : 0.0011424825306357396
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011424825306357396
# Final cost : 0.001139267754598077
# Compute control for a deterministic system
# Cost in iteration 0: 0.001139267754598077
# Final cost : 0.0011378408795373648
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011378408795373648
# Final cost : 0.0011361973546675918
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032172311789988566
# Final cost : 0.001270304993872878
# Compute control for a deterministic system
# Cost in iteration 0: 0.001270304993872878
# Final cost : 0.0012693554992444318
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012693554992444318
# Final cost : 0.0012677476985788172
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012677476985788172
# Final cost : 0.001266900383956643
# Compute control for a deterministic system
# Cost in iteration 0: 0.001266900383956643
# Final cost : 0.001265594219360207
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.0164024494333785
# Final cost : 0.0013898264507423825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013898264507423825
# Final cost : 0.00138775048807623
# Compute control for a deterministic system
# Cost in iteration 0: 0.00138775048807623
# Final cost : 0.0013858791936616588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013858791936616588
# Final cost : 0.0013844456712662303
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013844456712662303
# Final cost : 0.0013834535245938046
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.009451319044142587
# Final cost : 0.0014987290997127822
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014987290997127822
# Final cost : 0.0014976660164158636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014976660164158636
# Final cost : 0.001496457613545112
# Compute control for a deterministic system
# Cost in iteration 0: 0.001496457613545112
# Final cost : 0.0014954083362601683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014954083362601683
# Final cost : 0.0014944015627184188
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.018346848560883314
# Final cost : 0.0016091455590730695
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016091455590730695
# Final cost : 0.001606119531751989
# Compute control for a deterministic system
# Cost in iteration 0: 0.001606119531751989
# Final cost : 0.001602191884569126
# Compute control for a deterministic system
# Cost in iteration 0: 0.001602191884569126
# Final cost : 0.0015986490465956997
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015986490465956997
# Final cost : 0.0015947338872975036
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.017838002977275946
# Final cost : 0.001680847305377537
# Compute control for a deterministic system
# Cost in iteration 0: 0.001680847305377537
# Final cost : 0.0016795131237268665
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016795131237268665
# Final cost : 0.001677992256047945
# Compute control for a deterministic system
# Cost in iteration 0: 0.001677992256047945
# Final cost : 0.0016762440714645284
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016762440714645284
# Final cost : 0.0016744517904653138
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.00852608785183905
# Final cost : 0.001756777310441298
# Compute control for a deterministic system
# Cost in iteration 0: 0.001756777310441298
# Final cost : 0.0017552931216374829
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017552931216374829
# Final cost : 0.0017526707038146715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017526707038146715
# Final cost : 0.001751018930606501
# Compute control for a deterministic system
# Cost in iteration 0: 0.001751018930606501
# Final cost : 0.0017483799082403252
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.0236624373093552
# Final cost : 0.001823634057032175
# Compute control for a deterministic system
# Cost in iteration 0: 0.001823634057032175
# Final cost : 0.0018225151305249002
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018225151305249002
# Final cost : 0.0018207783222793114
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018207783222793114
# Final cost : 0.0018193427473088253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018193427473088253
# Final cost : 0.001817498402474087
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.036882007527799666
# Final cost : 0.0019103582081785178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019103582081785178
# Final cost : 0.0019092324798691536
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019092324798691536
# Final cost : 0.0019077228589143534
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019077228589143534
# Final cost : 0.0019056407552348427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019056407552348427
# Final cost : 0.0019021939156822567
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016435097010734652
# Final cost : 0.0016060949299552655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016060949299552655
# Final cost : 0.0016039565622595678
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016039565622595678
# Final cost : 0.0016011608371751128
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016011608371751128
# Final cost : 0.0015977116438235075
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015977116438235075
# Final cost : 0.0015907029821580305
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.008045292079113755
# Final cost : 0.0012621646909252164
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012621646909252164
# Final cost : 0.0012607505132726105
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012607505132726105
# Final cost : 0.0012594937088525413
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012594937088525413
# Final cost : 0.0012578477668935672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012578477668935672
# Final cost : 0.0012553692239076085
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.000982776552118675
# Final cost : 0.0009807054477222667
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009807054477222667
# Final cost : 0.0009803868603780357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009803868603780357
# Final cost : 0.0009800041281525541
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009800041281525541
# Final cost : 0.0009795477059843514
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009795477059843514
# Final cost : 0.000978821239897369
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.0064591754404590765
# Final cost : 0.0007606844896406375
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007606844896406375
# Final cost : 0.0007605435564784897
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007605435564784897
# Final cost : 0.0007604030551988534
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007604030551988534
# Final cost : 0.0007601561508675554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007601561508675554
# Final cost : 0.0007598761542473984
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011166699264554055
# Final cost : 0.0005999719531274428
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005999719531274428
# Final cost : 0.0005991742685847064
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005991742685847064
# Final cost : 0.0005981813636163488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005981813636163488
# Final cost : 0.0005968096606085595
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005968096606085595
# Final cost : 0.0005942542313820589
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018072394286060122
# Final cost : 0.0004562191145538403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004562191145538403
# Final cost : 0.0004554680583960863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004554680583960863
# Final cost : 0.00045450644925147383
# Compute control for a deterministic system
# Cost in iteration 0: 0.00045450644925147383
# Final cost : 0.0004529398916883492
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004529398916883492
# Final cost : 0.0004505393428088437
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006038521633707076
# Final cost : 0.00033816609513650527
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033816609513650527
# Final cost : 0.0003376471957363282
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003376471957363282
# Final cost : 0.0003369751885140366
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003369751885140366
# Final cost : 0.00033601132084122614
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033601132084122614
# Final cost : 0.000334432294460739
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.003292440794588556
# Final cost : 0.00024677584055781174
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024677584055781174
# Final cost : 0.0002463199410210562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002463199410210562
# Final cost : 0.0002457563965287217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002457563965287217
# Final cost : 0.00024476118426923596
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024476118426923596
# Final cost : 0.0002436181804190018
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024883702315304152
# Final cost : 0.00017433470535762162
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017433470535762162
# Final cost : 0.00017385598205205648
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017385598205205648
# Final cost : 0.000173076400647552
# Compute control for a deterministic system
# Cost in iteration 0: 0.000173076400647552
# Final cost : 0.00017212501529602933
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017212501529602933
# Final cost : 0.00017080976883708052
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008545135847151102
# Final cost : 0.00011570779122442739
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011570779122442739
# Final cost : 0.0001153640906157638
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001153640906157638
# Final cost : 0.00011485196053995734
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011485196053995734
# Final cost : 0.00011394007416707524
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011394007416707524
# Final cost : 0.0001130805857600448
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002668997709971846
# Final cost : 7.171970098775353e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.171970098775353e-05
# Final cost : 7.149059184946769e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.149059184946769e-05
# Final cost : 7.118187982457665e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.118187982457665e-05
# Final cost : 7.052214321420056e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.052214321420056e-05
# Final cost : 7.00102856641542e-05
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024913711778560784
# Final cost : 3.840694023701637e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.840694023701637e-05
# Final cost : 3.8320881565764655e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.8320881565764655e-05
# Final cost : 3.819476483456972e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.819476483456972e-05
# Final cost : 3.796456911704988e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.796456911704988e-05
# Final cost : 3.7723177783638855e-05
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004113339007708101
# Final cost : 1.6995217484366236e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6995217484366236e-05
# Final cost : 1.6944803591804985e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6944803591804985e-05
# Final cost : 1.6885774294095822e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6885774294095822e-05
# Final cost : 1.6776283537681266e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6776283537681266e-05
# Final cost : 1.662714369233708e-05
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 5.2240263067175446e-05
# Final cost : 4.4256180381512284e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.4256180381512284e-06
# Final cost : 4.385895280605304e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.385895280605304e-06
# Final cost : 4.074575724569194e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.074575724569194e-06
# Final cost : 4.053062871685916e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.053062871685916e-06
# Final cost : 4.018632584712968e-06
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
