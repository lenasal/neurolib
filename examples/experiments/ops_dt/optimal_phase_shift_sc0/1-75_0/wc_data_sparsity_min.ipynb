# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1361], wc.inh[0,1361]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [ 1000  2500  4000  5500  6999  8499  9999 11499 12999 14499 15998 17498
#  18998 20498 21998 23498 24997 26497 27997 29497]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s1_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s1_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor =  (0.95*np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor =  (0.95*np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05597273702356491
# Final cost : 0.04820790764902335
# Compute control for a deterministic system
# Cost in iteration 0: 0.04820790764902335
# Final cost : 0.011448546345162843
# Compute control for a deterministic system
# Cost in iteration 0: 0.011448546345162843
# Final cost : 0.011320047955278863
# Compute control for a deterministic system
# Cost in iteration 0: 0.011320047955278863
# Converged in iteration 30 with cost 0.011320043310387972 because of vanishing difference
# Final cost : 0.011320043310387972
# Compute control for a deterministic system
# Cost in iteration 0: 0.011320043310387972
# Converged in iteration 1 with cost 0.011320043310387972 because of vanishing difference
# Final cost : 0.011320043310387972
# Compute control for a deterministic system
# Cost in iteration 0: 0.011320043310387972
# Converged in iteration 1 with cost 0.011320043310387972 because of vanishing difference
# Final cost : 0.011320043310387972
# Compute control for a deterministic system
# Cost in iteration 0: 0.22680888172368577
# Final cost : 0.1947890811236736
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947890811236736
# Final cost : 0.025901645735890405
# Compute control for a deterministic system
# Cost in iteration 0: 0.025901645735890405
# Converged in iteration 20 with cost 0.02570012035463764 because of step counter
# Final cost : 0.02570012035463764
# Compute control for a deterministic system
# Cost in iteration 0: 0.02570012035463764
# Converged in iteration 1 with cost 0.02570012035463764 because of step counter
# Final cost : 0.02570012035463764
# Compute control for a deterministic system
# Cost in iteration 0: 0.02570012035463764
# Converged in iteration 1 with cost 0.02570012035463764 because of step counter
# Final cost : 0.02570012035463764
# Compute control for a deterministic system
# Cost in iteration 0: 0.02570012035463764
# Converged in iteration 1 with cost 0.02570012035463764 because of step counter
# Final cost : 0.02570012035463764
# Compute control for a deterministic system
# Cost in iteration 0: 0.4946226234451564
# Final cost : 0.4278706110968972
# Compute control for a deterministic system
# Cost in iteration 0: 0.4278706110968972
# Final cost : 0.04119664668750757
# Compute control for a deterministic system
# Cost in iteration 0: 0.04119664668750757
# Converged in iteration 36 with cost 0.04062868030520242 because of step counter
# Final cost : 0.04062868030520242
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062868030520242
# Converged in iteration 1 with cost 0.04062868030520242 because of step counter
# Final cost : 0.04062868030520242
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062868030520242
# Converged in iteration 1 with cost 0.04062868030520242 because of step counter
# Final cost : 0.04062868030520242
# Compute control for a deterministic system
# Cost in iteration 0: 0.04062868030520242
# Converged in iteration 1 with cost 0.04062868030520242 because of step counter
# Final cost : 0.04062868030520242
# Compute control for a deterministic system
# Cost in iteration 0: 0.8608850625133276
# Final cost : 0.7528898989268321
# Compute control for a deterministic system
# Cost in iteration 0: 0.7528898989268321
# Final cost : 0.05787503647307163
# Compute control for a deterministic system
# Cost in iteration 0: 0.05787503647307163
# Converged in iteration 107 with cost 0.056162741048205324 because of step counter
# Final cost : 0.056162741048205324
# Compute control for a deterministic system
# Cost in iteration 0: 0.056162741048205324
# Converged in iteration 1 with cost 0.056162741048205324 because of step counter
# Final cost : 0.056162741048205324
# Compute control for a deterministic system
# Cost in iteration 0: 0.056162741048205324
# Converged in iteration 1 with cost 0.056162741048205324 because of step counter
# Final cost : 0.056162741048205324
# Compute control for a deterministic system
# Cost in iteration 0: 0.056162741048205324
# Converged in iteration 1 with cost 0.056162741048205324 because of step counter
# Final cost : 0.056162741048205324
# Compute control for a deterministic system
# Cost in iteration 0: 1.2921995600586604
# Final cost : 1.143738297172998
# Compute control for a deterministic system
# Cost in iteration 0: 1.143738297172998
# Final cost : 0.07536016490598706
# Compute control for a deterministic system
# Cost in iteration 0: 0.07536016490598706
# Final cost : 0.07149007025123508
# Compute control for a deterministic system
# Cost in iteration 0: 0.07149007025123508
# Converged in iteration 5 with cost 0.07148204768184498 because of step counter
# Final cost : 0.07148204768184498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07148204768184498
# Converged in iteration 1 with cost 0.07148204768184498 because of step counter
# Final cost : 0.07148204768184498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07148204768184498
# Converged in iteration 1 with cost 0.07148204768184498 because of step counter
# Final cost : 0.07148204768184498
# Compute control for a deterministic system
# Cost in iteration 0: 1.7968562100882712
# Final cost : 1.6107381913014227
# Compute control for a deterministic system
# Cost in iteration 0: 1.6107381913014227
# Final cost : 0.09474472826099362
# Compute control for a deterministic system
# Cost in iteration 0: 0.09474472826099362
# Final cost : 0.08642434333291889
# Compute control for a deterministic system
# Cost in iteration 0: 0.08642434333291889
# Final cost : 0.08595558499195338
# Compute control for a deterministic system
# Cost in iteration 0: 0.08595558499195338
# Converged in iteration 5 with cost 0.08595558499004483 because of step counter
# Final cost : 0.08595558499004483
# Compute control for a deterministic system
# Cost in iteration 0: 0.08595558499004483
# Converged in iteration 1 with cost 0.08595558499004483 because of step counter
# Final cost : 0.08595558499004483
# Compute control for a deterministic system
# Cost in iteration 0: 2.333864505213055
# Final cost : 2.1178847158150442
# Compute control for a deterministic system
# Cost in iteration 0: 2.1178847158150442
# Final cost : 0.11517831728127113
# Compute control for a deterministic system
# Cost in iteration 0: 0.11517831728127113
# Final cost : 0.097963557783518
# Compute control for a deterministic system
# Cost in iteration 0: 0.097963557783518
# Converged in iteration 200 with cost 0.09605359611390933 because of vanishing difference
# Final cost : 0.09605359611390933
# Compute control for a deterministic system
# Cost in iteration 0: 0.09605359611390933
# Converged in iteration 1 with cost 0.09605359611390933 because of vanishing difference
# Final cost : 0.09605359611390933
# Compute control for a deterministic system
# Cost in iteration 0: 0.09605359611390933
# Converged in iteration 1 with cost 0.09605359611390933 because of vanishing difference
# Final cost : 0.09605359611390933
# Compute control for a deterministic system
# Cost in iteration 0: 2.9172758280698567
# Final cost : 2.679769570167619
# Compute control for a deterministic system
# Cost in iteration 0: 2.679769570167619
# Final cost : 0.13786074917440871
# Compute control for a deterministic system
# Cost in iteration 0: 0.13786074917440871
# Final cost : 0.11364848620959506
# Compute control for a deterministic system
# Cost in iteration 0: 0.11364848620959506
# Converged in iteration 116 with cost 0.1060370442590061 because of vanishing difference
# Final cost : 0.1060370442590061
# Compute control for a deterministic system
# Cost in iteration 0: 0.1060370442590061
# Converged in iteration 3 with cost 0.10603704425900085 because of vanishing difference
# Final cost : 0.10603704425900085
# Compute control for a deterministic system
# Cost in iteration 0: 0.10603704425900085
# Converged in iteration 1 with cost 0.10603704425900085 because of vanishing difference
# Final cost : 0.10603704425900085
# Compute control for a deterministic system
# Cost in iteration 0: 3.501595888759896
# Final cost : 3.2533310272675364
# Compute control for a deterministic system
# Cost in iteration 0: 3.2533310272675364
# Final cost : 0.16142684396951304
# Compute control for a deterministic system
# Cost in iteration 0: 0.16142684396951304
# Final cost : 0.13183141309509466
# Compute control for a deterministic system
# Cost in iteration 0: 0.13183141309509466
# Converged in iteration 150 with cost 0.12101085260900452 because of vanishing difference
# Final cost : 0.12101085260900452
# Compute control for a deterministic system
# Cost in iteration 0: 0.12101085260900452
# Converged in iteration 1 with cost 0.12101085260900452 because of vanishing difference
# Final cost : 0.12101085260900452
# Compute control for a deterministic system
# Cost in iteration 0: 0.12101085260900452
# Converged in iteration 1 with cost 0.12101085260900452 because of vanishing difference
# Final cost : 0.12101085260900452
# Compute control for a deterministic system
# Cost in iteration 0: 4.103072317626299
# Final cost : 3.854873112579128
# Compute control for a deterministic system
# Cost in iteration 0: 3.854873112579128
# Final cost : 0.18693898107172777
# Compute control for a deterministic system
# Cost in iteration 0: 0.18693898107172777
# Final cost : 0.15076772577134365
# Compute control for a deterministic system
# Cost in iteration 0: 0.15076772577134365
# Converged in iteration 184 with cost 0.1363554288435374 because of vanishing difference
# Final cost : 0.1363554288435374
# Compute control for a deterministic system
# Cost in iteration 0: 0.1363554288435374
# Converged in iteration 3 with cost 0.13635542884353272 because of vanishing difference
# Final cost : 0.13635542884353272
# Compute control for a deterministic system
# Cost in iteration 0: 0.13635542884353272
# Converged in iteration 1 with cost 0.13635542884353272 because of vanishing difference
# Final cost : 0.13635542884353272
# Compute control for a deterministic system
# Cost in iteration 0: 4.675799545057614
# Final cost : 4.4384541803615205
# Compute control for a deterministic system
# Cost in iteration 0: 4.4384541803615205
# Final cost : 0.21337459303656403
# Compute control for a deterministic system
# Cost in iteration 0: 0.21337459303656403
# Final cost : 0.16946513173054917
# Compute control for a deterministic system
# Cost in iteration 0: 0.16946513173054917
# Final cost : 0.15107907889919236
# Compute control for a deterministic system
# Cost in iteration 0: 0.15107907889919236
# Converged in iteration 2 with cost 0.15107907889909675 because of vanishing difference
# Final cost : 0.15107907889909675
# Compute control for a deterministic system
# Cost in iteration 0: 0.15107907889909675
# Converged in iteration 1 with cost 0.15107907889909675 because of vanishing difference
# Final cost : 0.15107907889909675
# Compute control for a deterministic system
# Cost in iteration 0: 5.2368046405293045
# Final cost : 5.020899115673885
# Compute control for a deterministic system
# Cost in iteration 0: 5.020899115673885
# Final cost : 0.24325377202326048
# Compute control for a deterministic system
# Cost in iteration 0: 0.24325377202326048
# Final cost : 0.18915030952564915
# Compute control for a deterministic system
# Cost in iteration 0: 0.18915030952564915
# Final cost : 0.1651950638906177
# Compute control for a deterministic system
# Cost in iteration 0: 0.1651950638906177
# Converged in iteration 2 with cost 0.16519506388933003 because of vanishing difference
# Final cost : 0.16519506388933003
# Compute control for a deterministic system
# Cost in iteration 0: 0.16519506388933003
# Converged in iteration 2 with cost 0.16519506388933 because of vanishing difference
# Final cost : 0.16519506388933
# Compute control for a deterministic system
# Cost in iteration 0: 5.744016854691112
# Final cost : 5.55735083936425
# Compute control for a deterministic system
# Cost in iteration 0: 5.55735083936425
# Final cost : 0.2766645618255285
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766645618255285
# Final cost : 0.20908279699842652
# Compute control for a deterministic system
# Cost in iteration 0: 0.20908279699842652
# Final cost : 0.17673655922173348
# Compute control for a deterministic system
# Cost in iteration 0: 0.17673655922173348
# Converged in iteration 13 with cost 0.17527378102219252 because of step counter
# Final cost : 0.17527378102219252
# Compute control for a deterministic system
# Cost in iteration 0: 0.17527378102219252
# Converged in iteration 1 with cost 0.17527378102219252 because of step counter
# Final cost : 0.17527378102219252
# Compute control for a deterministic system
# Cost in iteration 0: 6.212984474227305
# Final cost : 6.062169991580116
# Compute control for a deterministic system
# Cost in iteration 0: 6.062169991580116
# Final cost : 0.3177051964121451
# Compute control for a deterministic system
# Cost in iteration 0: 0.3177051964121451
# Final cost : 0.23065284620205528
# Compute control for a deterministic system
# Cost in iteration 0: 0.23065284620205528
# Final cost : 0.18444601700974156
# Compute control for a deterministic system
# Cost in iteration 0: 0.18444601700974156
# Converged in iteration 16 with cost 0.18232564820141794 because of step counter
# Final cost : 0.18232564820141794
# Compute control for a deterministic system
# Cost in iteration 0: 0.18232564820141794
# Converged in iteration 1 with cost 0.18232564820141794 because of step counter
# Final cost : 0.18232564820141794
# Compute control for a deterministic system
# Cost in iteration 0: 6.609150233571892
# Final cost : 6.495389653074685
# Compute control for a deterministic system
# Cost in iteration 0: 6.495389653074685
# Final cost : 0.3671607354156827
# Compute control for a deterministic system
# Cost in iteration 0: 0.3671607354156827
# Final cost : 0.2530077328589237
# Compute control for a deterministic system
# Cost in iteration 0: 0.2530077328589237
# Converged in iteration 84 with cost 0.19186356697239926 because of step counter
# Final cost : 0.19186356697239926
# Compute control for a deterministic system
# Cost in iteration 0: 0.19186356697239926
# Converged in iteration 1 with cost 0.19186356697239926 because of step counter
# Final cost : 0.19186356697239926
# Compute control for a deterministic system
# Cost in iteration 0: 0.19186356697239926
# Converged in iteration 1 with cost 0.19186356697239926 because of step counter
# Final cost : 0.19186356697239926
# Compute control for a deterministic system
# Cost in iteration 0: 6.945963974929948
# Final cost : 6.868557816769462
# Compute control for a deterministic system
# Cost in iteration 0: 6.868557816769462
# Final cost : 0.4319675011448116
# Compute control for a deterministic system
# Cost in iteration 0: 0.4319675011448116
# Final cost : 0.2776307074539889
# Compute control for a deterministic system
# Cost in iteration 0: 0.2776307074539889
# Converged in iteration 144 with cost 0.19551290125121273 because of vanishing difference
# Final cost : 0.19551290125121273
# Compute control for a deterministic system
# Cost in iteration 0: 0.19551290125121273
# Converged in iteration 13 with cost 0.1955128997770408 because of step counter
# Final cost : 0.1955128997770408
# Compute control for a deterministic system
# Cost in iteration 0: 0.1955128997770408
# Converged in iteration 1 with cost 0.1955128997770408 because of step counter
# Final cost : 0.1955128997770408
# Compute control for a deterministic system
# Cost in iteration 0: 7.2005080618811075
# Final cost : 7.153634592354847
# Compute control for a deterministic system
# Cost in iteration 0: 7.153634592354847
# Final cost : 0.5148685637643753
# Compute control for a deterministic system
# Cost in iteration 0: 0.5148685637643753
# Final cost : 0.30350340181401686
# Compute control for a deterministic system
# Cost in iteration 0: 0.30350340181401686
# Converged in iteration 165 with cost 0.20533330445027181 because of vanishing difference
# Final cost : 0.20533330445027181
# Compute control for a deterministic system
# Cost in iteration 0: 0.20533330445027181
# Converged in iteration 5 with cost 0.20533330429269336 because of step counter
# Final cost : 0.20533330429269336
# Compute control for a deterministic system
# Cost in iteration 0: 0.20533330429269336
# Converged in iteration 1 with cost 0.20533330429269336 because of step counter
# Final cost : 0.20533330429269336
# Compute control for a deterministic system
# Cost in iteration 0: 7.383516292671991
# Final cost : 7.360761951833119
# Compute control for a deterministic system
# Cost in iteration 0: 7.360761951833119
# Final cost : 0.6311463954380037
# Compute control for a deterministic system
# Cost in iteration 0: 0.6311463954380037
# Final cost : 0.33239815020541447
# Compute control for a deterministic system
# Cost in iteration 0: 0.33239815020541447
# Converged in iteration 186 with cost 0.21532568122428167 because of step counter
# Final cost : 0.21532568122428167
# Compute control for a deterministic system
# Cost in iteration 0: 0.21532568122428167
# Converged in iteration 1 with cost 0.21532568122428167 because of step counter
# Final cost : 0.21532568122428167
# Compute control for a deterministic system
# Cost in iteration 0: 0.21532568122428167
# Converged in iteration 1 with cost 0.21532568122428167 because of step counter
# Final cost : 0.21532568122428167
# Compute control for a deterministic system
# Cost in iteration 0: 7.48411356353738
# Final cost : 7.476637641517127
# Compute control for a deterministic system
# Cost in iteration 0: 7.476637641517127
# Final cost : 0.7977534315664638
# Compute control for a deterministic system
# Cost in iteration 0: 0.7977534315664638
# Final cost : 0.3634256066505956
# Compute control for a deterministic system
# Cost in iteration 0: 0.3634256066505956
# Final cost : 0.22639146112580066
# Compute control for a deterministic system
# Cost in iteration 0: 0.22639146112580066
# Converged in iteration 1 with cost 0.22639146112580066 because of step counter
# Final cost : 0.22639146112580066
# Compute control for a deterministic system
# Cost in iteration 0: 0.22639146112580066
# Converged in iteration 1 with cost 0.22639146112580066 because of step counter
# Final cost : 0.22639146112580066
# Compute control for a deterministic system
# Cost in iteration 0: 7.507508543593407
# Final cost : 7.5068490502779675
# Compute control for a deterministic system
# Cost in iteration 0: 7.5068490502779675
# Final cost : 1.1474188789866635
# Compute control for a deterministic system
# Cost in iteration 0: 1.1474188789866635
# Final cost : 0.4005840489446039
# Compute control for a deterministic system
# Cost in iteration 0: 0.4005840489446039
# Final cost : 0.2391935309592539
# Compute control for a deterministic system
# Cost in iteration 0: 0.2391935309592539
# Converged in iteration 20 with cost 0.23697729321640024 because of step counter
# Final cost : 0.23697729321640024
# Compute control for a deterministic system
# Cost in iteration 0: 0.23697729321640024
# Converged in iteration 1 with cost 0.23697729321640024 because of step counter
# Final cost : 0.23697729321640024
# Compute control for a deterministic system
# Cost in iteration 0: 7.452760382517055
# Final cost : 7.450667084474245
# Compute control for a deterministic system
# Cost in iteration 0: 7.450667084474245
# Final cost : 1.1971254502431161
# Compute control for a deterministic system
# Cost in iteration 0: 1.1971254502431161
# Final cost : 0.44021745032510545
# Compute control for a deterministic system
# Cost in iteration 0: 0.44021745032510545
# Final cost : 0.2873767815803032
# Compute control for a deterministic system
# Cost in iteration 0: 0.2873767815803032
# Converged in iteration 15 with cost 0.28328882125409055 because of step counter
# Final cost : 0.28328882125409055
# Compute control for a deterministic system
# Cost in iteration 0: 0.28328882125409055
# Converged in iteration 1 with cost 0.28328882125409055 because of step counter
# Final cost : 0.28328882125409055
# Compute control for a deterministic system
# Cost in iteration 0: 7.317473343292279
# Final cost : 7.305324065495076
# Compute control for a deterministic system
# Cost in iteration 0: 7.305324065495076
# Final cost : 0.9402231574374049
# Compute control for a deterministic system
# Cost in iteration 0: 0.9402231574374049
# Final cost : 0.40130408851385263
# Compute control for a deterministic system
# Cost in iteration 0: 0.40130408851385263
# Final cost : 0.26756756340619003
# Compute control for a deterministic system
# Cost in iteration 0: 0.26756756340619003
# Converged in iteration 11 with cost 0.2662927121454526 because of step counter
# Final cost : 0.2662927121454526
# Compute control for a deterministic system
# Cost in iteration 0: 0.2662927121454526
# Converged in iteration 1 with cost 0.2662927121454526 because of step counter
# Final cost : 0.2662927121454526
# Compute control for a deterministic system
# Cost in iteration 0: 7.109866438965277
# Final cost : 7.0793843322877255
# Compute control for a deterministic system
# Cost in iteration 0: 7.0793843322877255
# Final cost : 0.7649619949832742
# Compute control for a deterministic system
# Cost in iteration 0: 0.7649619949832742
# Final cost : 0.36543042154050165
# Compute control for a deterministic system
# Cost in iteration 0: 0.36543042154050165
# Converged in iteration 190 with cost 0.25339593579067576 because of vanishing difference
# Final cost : 0.25339593579067576
# Compute control for a deterministic system
# Cost in iteration 0: 0.25339593579067576
# Converged in iteration 26 with cost 0.2533959353706448 because of step counter
# Final cost : 0.2533959353706448
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533959353706448
# Converged in iteration 1 with cost 0.2533959353706448 because of step counter
# Final cost : 0.2533959353706448
# Compute control for a deterministic system
# Cost in iteration 0: 6.821612554536581
# Final cost : 6.764322990345727
# Compute control for a deterministic system
# Cost in iteration 0: 6.764322990345727
# Final cost : 0.6259701106788838
# Compute control for a deterministic system
# Cost in iteration 0: 0.6259701106788838
# Final cost : 0.3304392784240399
# Compute control for a deterministic system
# Cost in iteration 0: 0.3304392784240399
# Converged in iteration 183 with cost 0.23596414545745772 because of step counter
# Final cost : 0.23596414545745772
# Compute control for a deterministic system
# Cost in iteration 0: 0.23596414545745772
# Converged in iteration 1 with cost 0.23596414545745772 because of step counter
# Final cost : 0.23596414545745772
# Compute control for a deterministic system
# Cost in iteration 0: 0.23596414545745772
# Converged in iteration 1 with cost 0.23596414545745772 because of step counter
# Final cost : 0.23596414545745772
# Compute control for a deterministic system
# Cost in iteration 0: 6.472827206686714
# Final cost : 6.383489414681735
# Compute control for a deterministic system
# Cost in iteration 0: 6.383489414681735
# Final cost : 0.5183714663590406
# Compute control for a deterministic system
# Cost in iteration 0: 0.5183714663590406
# Final cost : 0.2980469579850004
# Compute control for a deterministic system
# Cost in iteration 0: 0.2980469579850004
# Converged in iteration 172 with cost 0.21942699293189627 because of step counter
# Final cost : 0.21942699293189627
# Compute control for a deterministic system
# Cost in iteration 0: 0.21942699293189627
# Converged in iteration 1 with cost 0.21942699293189627 because of step counter
# Final cost : 0.21942699293189627
# Compute control for a deterministic system
# Cost in iteration 0: 0.21942699293189627
# Converged in iteration 1 with cost 0.21942699293189627 because of step counter
# Final cost : 0.21942699293189627
# Compute control for a deterministic system
# Cost in iteration 0: 6.051687503750652
# Final cost : 5.926439878739959
# Compute control for a deterministic system
# Cost in iteration 0: 5.926439878739959
# Final cost : 0.4293041591170591
# Compute control for a deterministic system
# Cost in iteration 0: 0.4293041591170591
# Final cost : 0.266495935420911
# Compute control for a deterministic system
# Cost in iteration 0: 0.266495935420911
# Converged in iteration 152 with cost 0.2030632943226305 because of step counter
# Final cost : 0.2030632943226305
# Compute control for a deterministic system
# Cost in iteration 0: 0.2030632943226305
# Converged in iteration 1 with cost 0.2030632943226305 because of step counter
# Final cost : 0.2030632943226305
# Compute control for a deterministic system
# Cost in iteration 0: 0.2030632943226305
# Converged in iteration 1 with cost 0.2030632943226305 because of step counter
# Final cost : 0.2030632943226305
# Compute control for a deterministic system
# Cost in iteration 0: 5.588849047200861
# Final cost : 5.4294545925179545
# Compute control for a deterministic system
# Cost in iteration 0: 5.4294545925179545
# Final cost : 0.35887219952386884
# Compute control for a deterministic system
# Cost in iteration 0: 0.35887219952386884
# Final cost : 0.23750888761365055
# Compute control for a deterministic system
# Cost in iteration 0: 0.23750888761365055
# Converged in iteration 139 with cost 0.18651199600569607 because of step counter
# Final cost : 0.18651199600569607
# Compute control for a deterministic system
# Cost in iteration 0: 0.18651199600569607
# Converged in iteration 1 with cost 0.18651199600569607 because of step counter
# Final cost : 0.18651199600569607
# Compute control for a deterministic system
# Cost in iteration 0: 0.18651199600569607
# Converged in iteration 1 with cost 0.18651199600569607 because of step counter
# Final cost : 0.18651199600569607
# Compute control for a deterministic system
# Cost in iteration 0: 5.069652515149256
# Final cost : 4.879793619336066
# Compute control for a deterministic system
# Cost in iteration 0: 4.879793619336066
# Final cost : 0.2996519025952329
# Compute control for a deterministic system
# Cost in iteration 0: 0.2996519025952329
# Final cost : 0.20956813168300054
# Compute control for a deterministic system
# Cost in iteration 0: 0.20956813168300054
# Converged in iteration 54 with cost 0.17893196340087872 because of step counter
# Final cost : 0.17893196340087872
# Compute control for a deterministic system
# Cost in iteration 0: 0.17893196340087872
# Converged in iteration 1 with cost 0.17893196340087872 because of step counter
# Final cost : 0.17893196340087872
# Compute control for a deterministic system
# Cost in iteration 0: 0.17893196340087872
# Converged in iteration 1 with cost 0.17893196340087872 because of step counter
# Final cost : 0.17893196340087872
# Compute control for a deterministic system
# Cost in iteration 0: 4.532489468876998
# Final cost : 4.320317225714571
# Compute control for a deterministic system
# Cost in iteration 0: 4.320317225714571
# Final cost : 0.2519842567478036
# Compute control for a deterministic system
# Cost in iteration 0: 0.2519842567478036
# Final cost : 0.18414182412270388
# Compute control for a deterministic system
# Cost in iteration 0: 0.18414182412270388
# Converged in iteration 62 with cost 0.1601520058174899 because of step counter
# Final cost : 0.1601520058174899
# Compute control for a deterministic system
# Cost in iteration 0: 0.1601520058174899
# Converged in iteration 1 with cost 0.1601520058174899 because of step counter
# Final cost : 0.1601520058174899
# Compute control for a deterministic system
# Cost in iteration 0: 0.1601520058174899
# Converged in iteration 1 with cost 0.1601520058174899 because of step counter
# Final cost : 0.1601520058174899
# Compute control for a deterministic system
# Cost in iteration 0: 3.960389422668421
# Final cost : 3.7347890460955964
# Compute control for a deterministic system
# Cost in iteration 0: 3.7347890460955964
# Final cost : 0.21100463920365953
# Compute control for a deterministic system
# Cost in iteration 0: 0.21100463920365953
# Final cost : 0.15979880791724166
# Compute control for a deterministic system
# Cost in iteration 0: 0.15979880791724166
# Converged in iteration 63 with cost 0.1415024723096924 because of step counter
# Final cost : 0.1415024723096924
# Compute control for a deterministic system
# Cost in iteration 0: 0.1415024723096924
# Converged in iteration 1 with cost 0.1415024723096924 because of step counter
# Final cost : 0.1415024723096924
# Compute control for a deterministic system
# Cost in iteration 0: 0.1415024723096924
# Converged in iteration 1 with cost 0.1415024723096924 because of step counter
# Final cost : 0.1415024723096924
# Compute control for a deterministic system
# Cost in iteration 0: 3.3953637689179157
# Final cost : 3.166888009870129
# Compute control for a deterministic system
# Cost in iteration 0: 3.166888009870129
# Final cost : 0.17713487865756625
# Compute control for a deterministic system
# Cost in iteration 0: 0.17713487865756625
# Final cost : 0.137724677036391
# Compute control for a deterministic system
# Cost in iteration 0: 0.137724677036391
# Converged in iteration 61 with cost 0.12441307303682475 because of step counter
# Final cost : 0.12441307303682475
# Compute control for a deterministic system
# Cost in iteration 0: 0.12441307303682475
# Converged in iteration 1 with cost 0.12441307303682475 because of step counter
# Final cost : 0.12441307303682475
# Compute control for a deterministic system
# Cost in iteration 0: 0.12441307303682475
# Converged in iteration 1 with cost 0.12441307303682475 because of step counter
# Final cost : 0.12441307303682475
# Compute control for a deterministic system
# Cost in iteration 0: 2.8193485927756106
# Final cost : 2.598608219624207
# Compute control for a deterministic system
# Cost in iteration 0: 2.598608219624207
# Final cost : 0.14714926289734623
# Compute control for a deterministic system
# Cost in iteration 0: 0.14714926289734623
# Final cost : 0.11660150284275522
# Compute control for a deterministic system
# Cost in iteration 0: 0.11660150284275522
# Converged in iteration 42 with cost 0.10783750245519332 because of step counter
# Final cost : 0.10783750245519332
# Compute control for a deterministic system
# Cost in iteration 0: 0.10783750245519332
# Converged in iteration 1 with cost 0.10783750245519332 because of step counter
# Final cost : 0.10783750245519332
# Compute control for a deterministic system
# Cost in iteration 0: 0.10783750245519332
# Converged in iteration 1 with cost 0.10783750245519332 because of step counter
# Final cost : 0.10783750245519332
# Compute control for a deterministic system
# Cost in iteration 0: 2.2748749294001773
# Final cost : 2.071628678615064
# Compute control for a deterministic system
# Cost in iteration 0: 2.071628678615064
# Final cost : 0.12159586610086356
# Compute control for a deterministic system
# Cost in iteration 0: 0.12159586610086356
# Final cost : 0.09925243065190514
# Compute control for a deterministic system
# Cost in iteration 0: 0.09925243065190514
# Converged in iteration 138 with cost 0.09681373089090924 because of vanishing difference
# Final cost : 0.09681373089090924
# Compute control for a deterministic system
# Cost in iteration 0: 0.09681373089090924
# Converged in iteration 4 with cost 0.09681373089090792 because of vanishing difference
# Final cost : 0.09681373089090792
# Compute control for a deterministic system
# Cost in iteration 0: 0.09681373089090792
# Converged in iteration 1 with cost 0.09681373089090792 because of vanishing difference
# Final cost : 0.09681373089090792
# Compute control for a deterministic system
# Cost in iteration 0: 1.7454578349418406
# Final cost : 1.5692854108622947
# Compute control for a deterministic system
# Cost in iteration 0: 1.5692854108622947
# Final cost : 0.09829214730698092
# Compute control for a deterministic system
# Cost in iteration 0: 0.09829214730698092
# Final cost : 0.08675731627825181
# Compute control for a deterministic system
# Cost in iteration 0: 0.08675731627825181
# Final cost : 0.08590710103187343
# Compute control for a deterministic system
# Cost in iteration 0: 0.08590710103187343
# Converged in iteration 2 with cost 0.08590710103170784 because of vanishing difference
# Final cost : 0.08590710103170784
# Compute control for a deterministic system
# Cost in iteration 0: 0.08590710103170784
# Converged in iteration 1 with cost 0.08590710103170784 because of vanishing difference
# Final cost : 0.08590710103170784
# Compute control for a deterministic system
# Cost in iteration 0: 1.2718764853580509
# Final cost : 1.1291186088816205
# Compute control for a deterministic system
# Cost in iteration 0: 1.1291186088816205
# Final cost : 0.07790077458292852
# Compute control for a deterministic system
# Cost in iteration 0: 0.07790077458292852
# Final cost : 0.07208830603196631
# Compute control for a deterministic system
# Cost in iteration 0: 0.07208830603196631
# Final cost : 0.07189439329858383
# Compute control for a deterministic system
# Cost in iteration 0: 0.07189439329858383
# Converged in iteration 3 with cost 0.07189439329832924 because of vanishing difference
# Final cost : 0.07189439329832924
# Compute control for a deterministic system
# Cost in iteration 0: 0.07189439329832924
# Converged in iteration 1 with cost 0.07189439329832924 because of step counter
# Final cost : 0.07189439329832924
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425447098209606
# Final cost : 0.7385293170537915
# Compute control for a deterministic system
# Cost in iteration 0: 0.7385293170537915
# Final cost : 0.05890886666854811
# Compute control for a deterministic system
# Cost in iteration 0: 0.05890886666854811
# Final cost : 0.05630008095711993
# Compute control for a deterministic system
# Cost in iteration 0: 0.05630008095711993
# Converged in iteration 4 with cost 0.05629898840751328 because of step counter
# Final cost : 0.05629898840751328
# Compute control for a deterministic system
# Cost in iteration 0: 0.05629898840751328
# Converged in iteration 1 with cost 0.05629898840751328 because of step counter
# Final cost : 0.05629898840751328
# Compute control for a deterministic system
# Cost in iteration 0: 0.05629898840751328
# Converged in iteration 1 with cost 0.05629898840751328 because of step counter
# Final cost : 0.05629898840751328
# Compute control for a deterministic system
# Cost in iteration 0: 0.49433437122888985
# Final cost : 0.4285105626268097
# Compute control for a deterministic system
# Cost in iteration 0: 0.4285105626268097
# Final cost : 0.042041727527078625
# Compute control for a deterministic system
# Cost in iteration 0: 0.042041727527078625
# Converged in iteration 76 with cost 0.041022670997329085 because of step counter
# Final cost : 0.041022670997329085
# Compute control for a deterministic system
# Cost in iteration 0: 0.041022670997329085
# Converged in iteration 1 with cost 0.041022670997329085 because of step counter
# Final cost : 0.041022670997329085
# Compute control for a deterministic system
# Cost in iteration 0: 0.041022670997329085
# Converged in iteration 1 with cost 0.041022670997329085 because of step counter
# Final cost : 0.041022670997329085
# Compute control for a deterministic system
# Cost in iteration 0: 0.041022670997329085
# Converged in iteration 1 with cost 0.041022670997329085 because of step counter
# Final cost : 0.041022670997329085
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359083445271974
# Final cost : 0.19227110844971199
# Compute control for a deterministic system
# Cost in iteration 0: 0.19227110844971199
# Final cost : 0.025964781809194863
# Compute control for a deterministic system
# Cost in iteration 0: 0.025964781809194863
# Converged in iteration 30 with cost 0.0256630928915507 because of step counter
# Final cost : 0.0256630928915507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0256630928915507
# Converged in iteration 1 with cost 0.0256630928915507 because of step counter
# Final cost : 0.0256630928915507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0256630928915507
# Converged in iteration 1 with cost 0.0256630928915507 because of step counter
# Final cost : 0.0256630928915507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0256630928915507
# Converged in iteration 1 with cost 0.0256630928915507 because of step counter
# Final cost : 0.0256630928915507
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Final cost : 0.05015269384292837
# Compute control for a deterministic system
# Cost in iteration 0: 0.05015269384292837
# Final cost : 0.011775403772775013
# Compute control for a deterministic system
# Cost in iteration 0: 0.011775403772775013
# Final cost : 0.011611867106160703
# Compute control for a deterministic system
# Cost in iteration 0: 0.011611867106160703
# Converged in iteration 23 with cost 0.011611859435439183 because of vanishing difference
# Final cost : 0.011611859435439183
# Compute control for a deterministic system
# Cost in iteration 0: 0.011611859435439183
# Converged in iteration 1 with cost 0.011611859435439183 because of vanishing difference
# Final cost : 0.011611859435439183
# Compute control for a deterministic system
# Cost in iteration 0: 0.011611859435439183
# Converged in iteration 1 with cost 0.011611859435439183 because of vanishing difference
# Final cost : 0.011611859435439183
# Compute control for a deterministic system
# Cost in iteration 0: 1.1834255416428287e-06
# Converged in iteration 1 with cost 1.1834255416428287e-06 because of step counter
# Final cost : 1.1834255416428287e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.1834255416428287e-06
# Converged in iteration 1 with cost 1.1834255416428287e-06 because of step counter
# Final cost : 1.1834255416428287e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.21812819381557316
# Final cost : 0.02582428596965021
# Compute control for a deterministic system
# Cost in iteration 0: 0.02582428596965021
# Converged in iteration 20 with cost 0.025625910212298094 because of step counter
# Final cost : 0.025625910212298094
# Compute control for a deterministic system
# Cost in iteration 0: 0.025625910212298094
# Converged in iteration 1 with cost 0.025625910212298094 because of step counter
# Final cost : 0.025625910212298094
# Compute control for a deterministic system
# Cost in iteration 0: 0.025625910212298094
# Converged in iteration 1 with cost 0.025625910212298094 because of step counter
# Final cost : 0.025625910212298094
# Compute control for a deterministic system
# Cost in iteration 0: 0.025625910212298094
# Converged in iteration 1 with cost 0.025625910212298094 because of step counter
# Final cost : 0.025625910212298094
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.48649350587597995
# Final cost : 0.041161249649900235
# Compute control for a deterministic system
# Cost in iteration 0: 0.041161249649900235
# Converged in iteration 36 with cost 0.040600050558959884 because of step counter
# Final cost : 0.040600050558959884
# Compute control for a deterministic system
# Cost in iteration 0: 0.040600050558959884
# Converged in iteration 1 with cost 0.040600050558959884 because of step counter
# Final cost : 0.040600050558959884
# Compute control for a deterministic system
# Cost in iteration 0: 0.040600050558959884
# Converged in iteration 1 with cost 0.040600050558959884 because of step counter
# Final cost : 0.040600050558959884
# Compute control for a deterministic system
# Cost in iteration 0: 0.040600050558959884
# Converged in iteration 1 with cost 0.040600050558959884 because of step counter
# Final cost : 0.040600050558959884
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.8453507196834792
# Final cost : 0.057807383932004505
# Compute control for a deterministic system
# Cost in iteration 0: 0.057807383932004505
# Converged in iteration 106 with cost 0.056115893771162044 because of step counter
# Final cost : 0.056115893771162044
# Compute control for a deterministic system
# Cost in iteration 0: 0.056115893771162044
# Converged in iteration 1 with cost 0.056115893771162044 because of step counter
# Final cost : 0.056115893771162044
# Compute control for a deterministic system
# Cost in iteration 0: 0.056115893771162044
# Converged in iteration 1 with cost 0.056115893771162044 because of step counter
# Final cost : 0.056115893771162044
# Compute control for a deterministic system
# Cost in iteration 0: 0.056115893771162044
# Converged in iteration 1 with cost 0.056115893771162044 because of step counter
# Final cost : 0.056115893771162044
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 1.1240618025264346
# Final cost : 0.07429689497450381
# Compute control for a deterministic system
# Cost in iteration 0: 0.07429689497450381
# Converged in iteration 191 with cost 0.07123200252595316 because of step counter
# Final cost : 0.07123200252595316
# Compute control for a deterministic system
# Cost in iteration 0: 0.07123200252595316
# Converged in iteration 1 with cost 0.07123200252595316 because of step counter
# Final cost : 0.07123200252595316
# Compute control for a deterministic system
# Cost in iteration 0: 0.07123200252595316
# Converged in iteration 1 with cost 0.07123200252595316 because of step counter
# Final cost : 0.07123200252595316
# Compute control for a deterministic system
# Cost in iteration 0: 0.07123200252595316
# Converged in iteration 1 with cost 0.07123200252595316 because of step counter
# Final cost : 0.07123200252595316
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 1.5625967909455707
# Final cost : 0.09277231839624465
# Compute control for a deterministic system
# Cost in iteration 0: 0.09277231839624465
# Final cost : 0.08656112963968145
# Compute control for a deterministic system
# Cost in iteration 0: 0.08656112963968145
# Converged in iteration 76 with cost 0.08633965621668134 because of step counter
# Final cost : 0.08633965621668134
# Compute control for a deterministic system
# Cost in iteration 0: 0.08633965621668134
# Converged in iteration 1 with cost 0.08633965621668134 because of step counter
# Final cost : 0.08633965621668134
# Compute control for a deterministic system
# Cost in iteration 0: 0.08633965621668134
# Converged in iteration 1 with cost 0.08633965621668134 because of step counter
# Final cost : 0.08633965621668134
# Compute control for a deterministic system
# Cost in iteration 0: 2.1831417866399954
# Final cost : 0.11344789422625881
# Compute control for a deterministic system
# Cost in iteration 0: 0.11344789422625881
# Final cost : 0.1002463201359817
# Compute control for a deterministic system
# Cost in iteration 0: 0.1002463201359817
# Final cost : 0.09893636009942454
# Compute control for a deterministic system
# Cost in iteration 0: 0.09893636009942454
# Converged in iteration 3 with cost 0.09893636009855968 because of vanishing difference
# Final cost : 0.09893636009855968
# Compute control for a deterministic system
# Cost in iteration 0: 0.09893636009855968
# Converged in iteration 1 with cost 0.09893636009855968 because of vanishing difference
# Final cost : 0.09893636009855968
# Compute control for a deterministic system
# Cost in iteration 0: 2.7153949456371613
# Final cost : 0.13439046736119453
# Compute control for a deterministic system
# Cost in iteration 0: 0.13439046736119453
# Final cost : 0.11223447883794598
# Compute control for a deterministic system
# Cost in iteration 0: 0.11223447883794598
# Converged in iteration 143 with cost 0.107275767790289 because of vanishing difference
# Final cost : 0.107275767790289
# Compute control for a deterministic system
# Cost in iteration 0: 0.107275767790289
# Converged in iteration 1 with cost 0.107275767790289 because of vanishing difference
# Final cost : 0.107275767790289
# Compute control for a deterministic system
# Cost in iteration 0: 0.107275767790289
# Converged in iteration 1 with cost 0.107275767790289 because of vanishing difference
# Final cost : 0.107275767790289
# Compute control for a deterministic system
# Cost in iteration 0: 3.2934897422609017
# Final cost : 0.15622869594802122
# Compute control for a deterministic system
# Cost in iteration 0: 0.15622869594802122
# Final cost : 0.12965502120843242
# Compute control for a deterministic system
# Cost in iteration 0: 0.12965502120843242
# Converged in iteration 131 with cost 0.11966627090169406 because of vanishing difference
# Final cost : 0.11966627090169406
# Compute control for a deterministic system
# Cost in iteration 0: 0.11966627090169406
# Converged in iteration 1 with cost 0.11966627090169406 because of vanishing difference
# Final cost : 0.11966627090169406
# Compute control for a deterministic system
# Cost in iteration 0: 0.11966627090169406
# Converged in iteration 1 with cost 0.11966627090169406 because of vanishing difference
# Final cost : 0.11966627090169406
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 3.8749651265243457
# Final cost : 0.17943289767522852
# Compute control for a deterministic system
# Cost in iteration 0: 0.17943289767522852
# Final cost : 0.1477390313329375
# Compute control for a deterministic system
# Cost in iteration 0: 0.1477390313329375
# Converged in iteration 187 with cost 0.13460397785863693 because of vanishing difference
# Final cost : 0.13460397785863693
# Compute control for a deterministic system
# Cost in iteration 0: 0.13460397785863693
# Converged in iteration 1 with cost 0.13460397785863693 because of vanishing difference
# Final cost : 0.13460397785863693
# Compute control for a deterministic system
# Cost in iteration 0: 0.13460397785863693
# Converged in iteration 1 with cost 0.13460397785863693 because of vanishing difference
# Final cost : 0.13460397785863693
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 4.437422166662506
# Final cost : 0.20315745484560593
# Compute control for a deterministic system
# Cost in iteration 0: 0.20315745484560593
# Final cost : 0.1655240095520181
# Compute control for a deterministic system
# Cost in iteration 0: 0.1655240095520181
# Final cost : 0.14901546690009437
# Compute control for a deterministic system
# Cost in iteration 0: 0.14901546690009437
# Converged in iteration 3 with cost 0.14901546690008421 because of vanishing difference
# Final cost : 0.14901546690008421
# Compute control for a deterministic system
# Cost in iteration 0: 0.14901546690008421
# Converged in iteration 1 with cost 0.14901546690008421 because of vanishing difference
# Final cost : 0.14901546690008421
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 4.80314293676203
# Final cost : 0.22062850947633336
# Compute control for a deterministic system
# Cost in iteration 0: 0.22062850947633336
# Final cost : 0.18077773314087625
# Compute control for a deterministic system
# Cost in iteration 0: 0.18077773314087625
# Final cost : 0.16189388510112523
# Compute control for a deterministic system
# Cost in iteration 0: 0.16189388510112523
# Converged in iteration 2 with cost 0.16189388510095543 because of vanishing difference
# Final cost : 0.16189388510095543
# Compute control for a deterministic system
# Cost in iteration 0: 0.16189388510095543
# Converged in iteration 1 with cost 0.16189388510095543 because of vanishing difference
# Final cost : 0.16189388510095543
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 5.481738857036912
# Final cost : 0.25467774943475097
# Compute control for a deterministic system
# Cost in iteration 0: 0.25467774943475097
# Final cost : 0.20156555027489356
# Compute control for a deterministic system
# Cost in iteration 0: 0.20156555027489356
# Final cost : 0.1758077970852593
# Compute control for a deterministic system
# Cost in iteration 0: 0.1758077970852593
# Converged in iteration 3 with cost 0.17580779708216643 because of vanishing difference
# Final cost : 0.17580779708216643
# Compute control for a deterministic system
# Cost in iteration 0: 0.17580779708216643
# Converged in iteration 1 with cost 0.17580779708216643 because of vanishing difference
# Final cost : 0.17580779708216643
# Compute control for a deterministic system
# Cost in iteration 0: 5.961395114750568
# Final cost : 0.2875222464788373
# Compute control for a deterministic system
# Cost in iteration 0: 0.2875222464788373
# Final cost : 0.22122858261390482
# Compute control for a deterministic system
# Cost in iteration 0: 0.22122858261390482
# Final cost : 0.18650480885324625
# Compute control for a deterministic system
# ...
# Final cost : 7.109462675843945
# Compute control for a deterministic system
# Cost in iteration 0: 7.109462675843945
# Converged in iteration 1 with cost 7.109462675843945 because of step counter
# Final cost : 7.109462675843945
# Compute control for a deterministic system
# Cost in iteration 0: 7.109462675843945
# Converged in iteration 1 with cost 7.109462675843945 because of step counter
# Final cost : 7.109462675843945
# Compute control for a deterministic system
# Cost in iteration 0: 7.109462675843945
# Converged in iteration 1 with cost 7.109462675843945 because of step counter
# Final cost : 7.109462675843945
# Compute control for a deterministic system
# Cost in iteration 0: 6.821543959351403
# Converged in iteration 1 with cost 6.821543959351403 because of step counter
# Final cost : 6.821543959351403
# Compute control for a deterministic system
# Cost in iteration 0: 6.821543959351403
# Converged in iteration 1 with cost 6.821543959351403 because of step counter
# Final cost : 6.821543959351403
# Compute control for a deterministic system
# Cost in iteration 0: 6.821543959351403
# Converged in iteration 1 with cost 6.821543959351403 because of step counter
# Final cost : 6.821543959351403
# Compute control for a deterministic system
# Cost in iteration 0: 6.821543959351403
# Converged in iteration 1 with cost 6.821543959351403 because of step counter
# Final cost : 6.821543959351403
# Compute control for a deterministic system
# Cost in iteration 0: 6.821543959351403
# Converged in iteration 1 with cost 6.821543959351403 because of step counter
# Final cost : 6.821543959351403
# Compute control for a deterministic system
# Cost in iteration 0: 6.470448939651684
# Converged in iteration 1 with cost 6.470448939651684 because of step counter
# Final cost : 6.470448939651684
# Compute control for a deterministic system
# Cost in iteration 0: 6.470448939651684
# Converged in iteration 1 with cost 6.470448939651684 because of step counter
# Final cost : 6.470448939651684
# Compute control for a deterministic system
# Cost in iteration 0: 6.470448939651684
# Converged in iteration 1 with cost 6.470448939651684 because of step counter
# Final cost : 6.470448939651684
# Compute control for a deterministic system
# Cost in iteration 0: 6.470448939651684
# Converged in iteration 1 with cost 6.470448939651684 because of step counter
# Final cost : 6.470448939651684
# Compute control for a deterministic system
# Cost in iteration 0: 6.470448939651684
# Converged in iteration 1 with cost 6.470448939651684 because of step counter
# Final cost : 6.470448939651684
# Compute control for a deterministic system
# Cost in iteration 0: 6.048677083482049
# Converged in iteration 1 with cost 6.048677083482049 because of step counter
# Final cost : 6.048677083482049
# Compute control for a deterministic system
# Cost in iteration 0: 6.048677083482049
# Converged in iteration 1 with cost 6.048677083482049 because of step counter
# Final cost : 6.048677083482049
# Compute control for a deterministic system
# Cost in iteration 0: 6.048677083482049
# Converged in iteration 1 with cost 6.048677083482049 because of step counter
# Final cost : 6.048677083482049
# Compute control for a deterministic system
# Cost in iteration 0: 6.048677083482049
# Converged in iteration 1 with cost 6.048677083482049 because of step counter
# Final cost : 6.048677083482049
# Compute control for a deterministic system
# Cost in iteration 0: 6.048677083482049
# Converged in iteration 1 with cost 6.048677083482049 because of step counter
# Final cost : 6.048677083482049
# Compute control for a deterministic system
# Cost in iteration 0: 5.5835803928955885
# Converged in iteration 2 with cost 5.582736344691782 because of step counter
# Final cost : 5.582736344691782
# Compute control for a deterministic system
# Cost in iteration 0: 5.582736344691782
# Converged in iteration 1 with cost 5.582736344691782 because of step counter
# Final cost : 5.582736344691782
# Compute control for a deterministic system
# Cost in iteration 0: 5.582736344691782
# Converged in iteration 1 with cost 5.582736344691782 because of step counter
# Final cost : 5.582736344691782
# Compute control for a deterministic system
# Cost in iteration 0: 5.582736344691782
# Converged in iteration 1 with cost 5.582736344691782 because of step counter
# Final cost : 5.582736344691782
# Compute control for a deterministic system
# Cost in iteration 0: 5.582736344691782
# Converged in iteration 1 with cost 5.582736344691782 because of step counter
# Final cost : 5.582736344691782
# Compute control for a deterministic system
# Cost in iteration 0: 5.058806829151972
# Converged in iteration 2 with cost 5.056070252607488 because of step counter
# Final cost : 5.056070252607488
# Compute control for a deterministic system
# Cost in iteration 0: 5.056070252607488
# Converged in iteration 1 with cost 5.056070252607488 because of step counter
# Final cost : 5.056070252607488
# Compute control for a deterministic system
# Cost in iteration 0: 5.056070252607488
# Converged in iteration 1 with cost 5.056070252607488 because of step counter
# Final cost : 5.056070252607488
# Compute control for a deterministic system
# Cost in iteration 0: 5.056070252607488
# Converged in iteration 1 with cost 5.056070252607488 because of step counter
# Final cost : 5.056070252607488
# Compute control for a deterministic system
# Cost in iteration 0: 5.056070252607488
# Converged in iteration 1 with cost 5.056070252607488 because of step counter
# Final cost : 5.056070252607488
# Compute control for a deterministic system
# Cost in iteration 0: 4.527634578230316
# Converged in iteration 2 with cost 4.523441391951622 because of step counter
# Final cost : 4.523441391951622
# Compute control for a deterministic system
# Cost in iteration 0: 4.523441391951622
# Converged in iteration 1 with cost 4.523441391951622 because of step counter
# Final cost : 4.523441391951622
# Compute control for a deterministic system
# Cost in iteration 0: 4.523441391951622
# Converged in iteration 1 with cost 4.523441391951622 because of step counter
# Final cost : 4.523441391951622
# Compute control for a deterministic system
# Cost in iteration 0: 4.523441391951622
# Converged in iteration 1 with cost 4.523441391951622 because of step counter
# Final cost : 4.523441391951622
# Compute control for a deterministic system
# Cost in iteration 0: 4.523441391951622
# Converged in iteration 1 with cost 4.523441391951622 because of step counter
# Final cost : 4.523441391951622
# Compute control for a deterministic system
# Cost in iteration 0: 3.9501783188698756
# Converged in iteration 2 with cost 3.945025871475926 because of step counter
# Final cost : 3.945025871475926
# Compute control for a deterministic system
# Cost in iteration 0: 3.945025871475926
# Converged in iteration 1 with cost 3.945025871475926 because of step counter
# Final cost : 3.945025871475926
# Compute control for a deterministic system
# Cost in iteration 0: 3.945025871475926
# Converged in iteration 1 with cost 3.945025871475926 because of step counter
# Final cost : 3.945025871475926
# Compute control for a deterministic system
# Cost in iteration 0: 3.945025871475926
# Converged in iteration 1 with cost 3.945025871475926 because of step counter
# Final cost : 3.945025871475926
# Compute control for a deterministic system
# Cost in iteration 0: 3.945025871475926
# Converged in iteration 1 with cost 3.945025871475926 because of step counter
# Final cost : 3.945025871475926
# Compute control for a deterministic system
# Cost in iteration 0: 3.381554116978941
# Converged in iteration 2 with cost 3.3761517457201586 because of step counter
# Final cost : 3.3761517457201586
# Compute control for a deterministic system
# Cost in iteration 0: 3.3761517457201586
# Converged in iteration 1 with cost 3.3761517457201586 because of step counter
# Final cost : 3.3761517457201586
# Compute control for a deterministic system
# Cost in iteration 0: 3.3761517457201586
# Converged in iteration 1 with cost 3.3761517457201586 because of step counter
# Final cost : 3.3761517457201586
# Compute control for a deterministic system
# Cost in iteration 0: 3.3761517457201586
# Converged in iteration 1 with cost 3.3761517457201586 because of step counter
# Final cost : 3.3761517457201586
# Compute control for a deterministic system
# Cost in iteration 0: 3.3761517457201586
# Converged in iteration 1 with cost 3.3761517457201586 because of step counter
# Final cost : 3.3761517457201586
# Compute control for a deterministic system
# Cost in iteration 0: 2.815078069842779
# Converged in iteration 2 with cost 2.810110903358493 because of step counter
# Final cost : 2.810110903358493
# Compute control for a deterministic system
# Cost in iteration 0: 2.810110903358493
# Converged in iteration 1 with cost 2.810110903358493 because of step counter
# Final cost : 2.810110903358493
# Compute control for a deterministic system
# Cost in iteration 0: 2.810110903358493
# Converged in iteration 1 with cost 2.810110903358493 because of step counter
# Final cost : 2.810110903358493
# Compute control for a deterministic system
# Cost in iteration 0: 2.810110903358493
# Converged in iteration 1 with cost 2.810110903358493 because of step counter
# Final cost : 2.810110903358493
# Compute control for a deterministic system
# Cost in iteration 0: 2.810110903358493
# Converged in iteration 1 with cost 2.810110903358493 because of step counter
# Final cost : 2.810110903358493
# Compute control for a deterministic system
# Cost in iteration 0: 2.2735571258715206
# Converged in iteration 2 with cost 2.269675994380631 because of step counter
# Final cost : 2.269675994380631
# Compute control for a deterministic system
# Cost in iteration 0: 2.269675994380631
# Converged in iteration 1 with cost 2.269675994380631 because of step counter
# Final cost : 2.269675994380631
# Compute control for a deterministic system
# Cost in iteration 0: 2.269675994380631
# Converged in iteration 1 with cost 2.269675994380631 because of step counter
# Final cost : 2.269675994380631
# Compute control for a deterministic system
# Cost in iteration 0: 2.269675994380631
# Converged in iteration 1 with cost 2.269675994380631 because of step counter
# Final cost : 2.269675994380631
# Compute control for a deterministic system
# Cost in iteration 0: 2.269675994380631
# Converged in iteration 1 with cost 2.269675994380631 because of step counter
# Final cost : 2.269675994380631
# Compute control for a deterministic system
# Cost in iteration 0: 1.7376364963083648
# Converged in iteration 2 with cost 1.735483295516377 because of step counter
# Final cost : 1.735483295516377
# Compute control for a deterministic system
# Cost in iteration 0: 1.735483295516377
# Converged in iteration 1 with cost 1.735483295516377 because of step counter
# Final cost : 1.735483295516377
# Compute control for a deterministic system
# Cost in iteration 0: 1.735483295516377
# Converged in iteration 1 with cost 1.735483295516377 because of step counter
# Final cost : 1.735483295516377
# Compute control for a deterministic system
# Cost in iteration 0: 1.735483295516377
# Converged in iteration 1 with cost 1.735483295516377 because of step counter
# Final cost : 1.735483295516377
# Compute control for a deterministic system
# Cost in iteration 0: 1.735483295516377
# Converged in iteration 1 with cost 1.735483295516377 because of step counter
# Final cost : 1.735483295516377
# Compute control for a deterministic system
# Cost in iteration 0: 1.2673178841572483
# Converged in iteration 2 with cost 1.2671238627407702 because of step counter
# Final cost : 1.2671238627407702
# Compute control for a deterministic system
# Cost in iteration 0: 1.2671238627407702
# Converged in iteration 1 with cost 1.2671238627407702 because of step counter
# Final cost : 1.2671238627407702
# Compute control for a deterministic system
# Cost in iteration 0: 1.2671238627407702
# Converged in iteration 1 with cost 1.2671238627407702 because of step counter
# Final cost : 1.2671238627407702
# Compute control for a deterministic system
# Cost in iteration 0: 1.2671238627407702
# Converged in iteration 1 with cost 1.2671238627407702 because of step counter
# Final cost : 1.2671238627407702
# Compute control for a deterministic system
# Cost in iteration 0: 1.2671238627407702
# Converged in iteration 1 with cost 1.2671238627407702 because of step counter
# Final cost : 1.2671238627407702
# Compute control for a deterministic system
# Cost in iteration 0: 0.8395809700260829
# Converged in iteration 1 with cost 0.8395809700260829 because of step counter
# Final cost : 0.8395809700260829
# Compute control for a deterministic system
# Cost in iteration 0: 0.8395809700260829
# Converged in iteration 1 with cost 0.8395809700260829 because of step counter
# Final cost : 0.8395809700260829
# Compute control for a deterministic system
# Cost in iteration 0: 0.8395809700260829
# Converged in iteration 1 with cost 0.8395809700260829 because of step counter
# Final cost : 0.8395809700260829
# Compute control for a deterministic system
# Cost in iteration 0: 0.8395809700260829
# Converged in iteration 1 with cost 0.8395809700260829 because of step counter
# Final cost : 0.8395809700260829
# Compute control for a deterministic system
# Cost in iteration 0: 0.8395809700260829
# Converged in iteration 1 with cost 0.8395809700260829 because of step counter
# Final cost : 0.8395809700260829
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933805075887603
# Converged in iteration 1 with cost 0.4933805075887603 because of step counter
# Final cost : 0.4933805075887603
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933805075887603
# Converged in iteration 1 with cost 0.4933805075887603 because of step counter
# Final cost : 0.4933805075887603
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933805075887603
# Converged in iteration 1 with cost 0.4933805075887603 because of step counter
# Final cost : 0.4933805075887603
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933805075887603
# Converged in iteration 1 with cost 0.4933805075887603 because of step counter
# Final cost : 0.4933805075887603
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933805075887603
# Converged in iteration 1 with cost 0.4933805075887603 because of step counter
# Final cost : 0.4933805075887603
# Compute control for a deterministic system
# Cost in iteration 0: 0.22099523906043345
# Converged in iteration 1 with cost 0.22099523906043345 because of step counter
# Final cost : 0.22099523906043345
# Compute control for a deterministic system
# Cost in iteration 0: 0.22099523906043345
# Converged in iteration 1 with cost 0.22099523906043345 because of step counter
# Final cost : 0.22099523906043345
# Compute control for a deterministic system
# Cost in iteration 0: 0.22099523906043345
# Converged in iteration 1 with cost 0.22099523906043345 because of step counter
# Final cost : 0.22099523906043345
# Compute control for a deterministic system
# Cost in iteration 0: 0.22099523906043345
# Converged in iteration 1 with cost 0.22099523906043345 because of step counter
# Final cost : 0.22099523906043345
# Compute control for a deterministic system
# Cost in iteration 0: 0.22099523906043345
# Converged in iteration 1 with cost 0.22099523906043345 because of step counter
# Final cost : 0.22099523906043345
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Converged in iteration 1 with cost 0.05821055614597352 because of step counter
# Final cost : 0.05821055614597352
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Converged in iteration 1 with cost 0.05821055614597352 because of step counter
# Final cost : 0.05821055614597352
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Converged in iteration 1 with cost 0.05821055614597352 because of step counter
# Final cost : 0.05821055614597352
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Converged in iteration 1 with cost 0.05821055614597352 because of step counter
# Final cost : 0.05821055614597352
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Converged in iteration 1 with cost 0.05821055614597352 because of step counter
# Final cost : 0.05821055614597352

# %%
save(results_min)
