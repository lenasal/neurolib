# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1361], wc.inh[0,1361]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# 0.44221551344266974 0.4080479660494597
# minima =  [ 1000  2500  4000  5500  6999  8499  9999 11499 12999 14499 15998 17498
#  18998 20498 21998 23498 24997 26497 27997 29497]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s1_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s1_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [True, True, True]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05597273702356491
# Final cost : 0.04725015332714257
# Compute control for a deterministic system
# Cost in iteration 0: 0.04725015332714257
# Final cost : 0.0011471303056850156
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011471303056850156
# Final cost : 0.001013152080109743
# Compute control for a deterministic system
# Cost in iteration 0: 0.001013152080109743
# Converged in iteration 148 with cost 0.0010131492847395701 because of step counter
# Final cost : 0.0010131492847395701
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010131492847395701
# Converged in iteration 3 with cost 0.0010131492847394704 because of step counter
# Final cost : 0.0010131492847394704
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010131492847394704
# Converged in iteration 1 with cost 0.0010131492847394704 because of step counter
# Final cost : 0.0010131492847394704
# Compute control for a deterministic system
# Cost in iteration 0: 0.22680888172368577
# Final cost : 0.19291314844879462
# Compute control for a deterministic system
# Cost in iteration 0: 0.19291314844879462
# Final cost : 0.0047409872420988595
# Compute control for a deterministic system
# Cost in iteration 0: 0.0047409872420988595
# Final cost : 0.004133290837483931
# Compute control for a deterministic system
# Cost in iteration 0: 0.004133290837483931
# Converged in iteration 188 with cost 0.004133238118556104 because of step counter
# Final cost : 0.004133238118556104
# Compute control for a deterministic system
# Cost in iteration 0: 0.004133238118556104
# Converged in iteration 1 with cost 0.004133238118556104 because of step counter
# Final cost : 0.004133238118556104
# Compute control for a deterministic system
# Cost in iteration 0: 0.004133238118556104
# Converged in iteration 1 with cost 0.004133238118556104 because of step counter
# Final cost : 0.004133238118556104
# Compute control for a deterministic system
# Cost in iteration 0: 0.4946226234451564
# Final cost : 0.425203054036329
# Compute control for a deterministic system
# Cost in iteration 0: 0.425203054036329
# Final cost : 0.010720949248368047
# Compute control for a deterministic system
# Cost in iteration 0: 0.010720949248368047
# Final cost : 0.00915093483666074
# Compute control for a deterministic system
# Cost in iteration 0: 0.00915093483666074
# Converged in iteration 219 with cost 0.009150624571467083 because of step counter
# Final cost : 0.009150624571467083
# Compute control for a deterministic system
# Cost in iteration 0: 0.009150624571467083
# Converged in iteration 1 with cost 0.009150624571467083 because of step counter
# Final cost : 0.009150624571467083
# Compute control for a deterministic system
# Cost in iteration 0: 0.009150624571467083
# Converged in iteration 1 with cost 0.009150624571467083 because of step counter
# Final cost : 0.009150624571467083
# Compute control for a deterministic system
# Cost in iteration 0: 0.8608850625133276
# Final cost : 0.7495322840638295
# Compute control for a deterministic system
# Cost in iteration 0: 0.7495322840638295
# Final cost : 0.01964109355231892
# Compute control for a deterministic system
# Cost in iteration 0: 0.01964109355231892
# Final cost : 0.016285873857670115
# Compute control for a deterministic system
# Cost in iteration 0: 0.016285873857670115
# Converged in iteration 256 with cost 0.016284631134513203 because of vanishing difference
# Final cost : 0.016284631134513203
# Compute control for a deterministic system
# Cost in iteration 0: 0.016284631134513203
# Converged in iteration 3 with cost 0.016284631134512725 because of step counter
# Final cost : 0.016284631134512725
# Compute control for a deterministic system
# Cost in iteration 0: 0.016284631134512725
# Converged in iteration 1 with cost 0.016284631134512725 because of step counter
# Final cost : 0.016284631134512725
# Compute control for a deterministic system
# Cost in iteration 0: 1.2921995600586604
# Final cost : 1.1398320469323378
# Compute control for a deterministic system
# Cost in iteration 0: 1.1398320469323378
# Final cost : 0.03132355224636699
# Compute control for a deterministic system
# Cost in iteration 0: 0.03132355224636699
# Final cost : 0.025106191552511238
# Compute control for a deterministic system
# Cost in iteration 0: 0.025106191552511238
# Converged in iteration 310 with cost 0.025102357877754805 because of step counter
# Final cost : 0.025102357877754805
# Compute control for a deterministic system
# Cost in iteration 0: 0.025102357877754805
# Converged in iteration 1 with cost 0.025102357877754805 because of step counter
# Final cost : 0.025102357877754805
# Compute control for a deterministic system
# Cost in iteration 0: 0.025102357877754805
# Converged in iteration 1 with cost 0.025102357877754805 because of step counter
# Final cost : 0.025102357877754805
# Compute control for a deterministic system
# Cost in iteration 0: 1.7968562100882712
# Final cost : 1.6063921878345226
# Compute control for a deterministic system
# Cost in iteration 0: 1.6063921878345226
# Final cost : 0.04675336811866625
# Compute control for a deterministic system
# Cost in iteration 0: 0.04675336811866625
# Final cost : 0.03601750258278711
# Compute control for a deterministic system
# Cost in iteration 0: 0.03601750258278711
# Converged in iteration 371 with cost 0.03600697097278239 because of step counter
# Final cost : 0.03600697097278239
# Compute control for a deterministic system
# Cost in iteration 0: 0.03600697097278239
# Converged in iteration 1 with cost 0.03600697097278239 because of step counter
# Final cost : 0.03600697097278239
# Compute control for a deterministic system
# Cost in iteration 0: 0.03600697097278239
# Converged in iteration 1 with cost 0.03600697097278239 because of step counter
# Final cost : 0.03600697097278239
# Compute control for a deterministic system
# Cost in iteration 0: 2.333864505213055
# Final cost : 2.113226242613801
# Compute control for a deterministic system
# Cost in iteration 0: 2.113226242613801
# Final cost : 0.06547137009615087
# Compute control for a deterministic system
# Cost in iteration 0: 0.06547137009615087
# Final cost : 0.04834561492087913
# Compute control for a deterministic system
# Cost in iteration 0: 0.04834561492087913
# Converged in iteration 449 with cost 0.048320228468823424 because of step counter
# Final cost : 0.048320228468823424
# Compute control for a deterministic system
# Cost in iteration 0: 0.048320228468823424
# Converged in iteration 4 with cost 0.04832022846882292 because of step counter
# Final cost : 0.04832022846882292
# Compute control for a deterministic system
# Cost in iteration 0: 0.04832022846882292
# Converged in iteration 12 with cost 0.04832022846880584 because of step counter
# Final cost : 0.04832022846880584
# Compute control for a deterministic system
# Cost in iteration 0: 2.9172758280698567
# Final cost : 2.674904342115625
# Compute control for a deterministic system
# Cost in iteration 0: 2.674904342115625
# Final cost : 0.08872412475869919
# Compute control for a deterministic system
# Cost in iteration 0: 0.08872412475869919
# Final cost : 0.0625525863067067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0625525863067067
# Converged in iteration 559 with cost 0.06249536419302424 because of step counter
# Final cost : 0.06249536419302424
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249536419302424
# Converged in iteration 1 with cost 0.06249536419302424 because of step counter
# Final cost : 0.06249536419302424
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249536419302424
# Converged in iteration 1 with cost 0.06249536419302424 because of step counter
# Final cost : 0.06249536419302424
# Compute control for a deterministic system
# Cost in iteration 0: 3.501595888759896
# Final cost : 3.248372218060757
# Compute control for a deterministic system
# Cost in iteration 0: 3.248372218060757
# Final cost : 0.11515872158956601
# Compute control for a deterministic system
# Cost in iteration 0: 0.11515872158956601
# Final cost : 0.07751292072244985
# Compute control for a deterministic system
# Cost in iteration 0: 0.07751292072244985
# Final cost : 0.07739731522976025
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739731522976025
# Converged in iteration 12 with cost 0.07739731522971406 because of step counter
# Final cost : 0.07739731522971406
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739731522971406
# Converged in iteration 17 with cost 0.07739731522960336 because of step counter
# Final cost : 0.07739731522960336
# Compute control for a deterministic system
# Cost in iteration 0: 4.103072317626299
# Final cost : 3.8499266378539536
# Compute control for a deterministic system
# Cost in iteration 0: 3.8499266378539536
# Final cost : 0.14592279130172464
# Compute control for a deterministic system
# Cost in iteration 0: 0.14592279130172464
# Final cost : 0.0936194082671017
# Compute control for a deterministic system
# Cost in iteration 0: 0.0936194082671017
# Final cost : 0.0934010296919528
# Compute control for a deterministic system
# Cost in iteration 0: 0.0934010296919528
# Converged in iteration 171 with cost 0.09340102968424413 because of step counter
# Final cost : 0.09340102968424413
# Compute control for a deterministic system
# Cost in iteration 0: 0.09340102968424413
# Converged in iteration 1 with cost 0.09340102968424413 because of step counter
# Final cost : 0.09340102968424413
# Compute control for a deterministic system
# Cost in iteration 0: 4.675799545057614
# Final cost : 4.433624343223815
# Compute control for a deterministic system
# Cost in iteration 0: 4.433624343223815
# Final cost : 0.1796033436940275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1796033436940275
# Final cost : 0.10983959651505405
# Compute control for a deterministic system
# Cost in iteration 0: 0.10983959651505405
# Final cost : 0.10945974173326538
# Compute control for a deterministic system
# Cost in iteration 0: 0.10945974173326538
# Converged in iteration 430 with cost 0.10945974154868957 because of step counter
# Final cost : 0.10945974154868957
# Compute control for a deterministic system
# Cost in iteration 0: 0.10945974154868957
# Converged in iteration 6 with cost 0.10945974154858643 because of step counter
# Final cost : 0.10945974154858643
# Compute control for a deterministic system
# Cost in iteration 0: 5.2368046405293045
# Final cost : 5.016295685047056
# Compute control for a deterministic system
# Cost in iteration 0: 5.016295685047056
# Final cost : 0.21903305070749113
# Compute control for a deterministic system
# Cost in iteration 0: 0.21903305070749113
# Final cost : 0.1271051738163612
# Compute control for a deterministic system
# Cost in iteration 0: 0.1271051738163612
# Final cost : 0.12646303775274445
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646303775274445
# Converged in iteration 487 with cost 0.12646303618671334 because of step counter
# Final cost : 0.12646303618671334
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646303618671334
# Converged in iteration 1 with cost 0.12646303618671334 because of step counter
# Final cost : 0.12646303618671334
# Compute control for a deterministic system
# Cost in iteration 0: 5.744016854691112
# Final cost : 5.5530690108565635
# Compute control for a deterministic system
# Cost in iteration 0: 5.5530690108565635
# Final cost : 0.26375890169711713
# Compute control for a deterministic system
# Cost in iteration 0: 0.26375890169711713
# Final cost : 0.14465728191717792
# Compute control for a deterministic system
# Cost in iteration 0: 0.14465728191717792
# Final cost : 0.143614942448883
# Compute control for a deterministic system
# Cost in iteration 0: 0.143614942448883
# Converged in iteration 390 with cost 0.14361490076947214 because of step counter
# Final cost : 0.14361490076947214
# Compute control for a deterministic system
# Cost in iteration 0: 0.14361490076947214
# Converged in iteration 1 with cost 0.14361490076947214 because of step counter
# Final cost : 0.14361490076947214
# Compute control for a deterministic system
# Cost in iteration 0: 6.212984474227305
# Final cost : 6.058314990360964
# Compute control for a deterministic system
# Cost in iteration 0: 6.058314990360964
# Final cost : 0.31841931508706717
# Compute control for a deterministic system
# Cost in iteration 0: 0.31841931508706717
# Final cost : 0.16360502423639772
# Compute control for a deterministic system
# Cost in iteration 0: 0.16360502423639772
# Final cost : 0.16192298600542046
# Compute control for a deterministic system
# Cost in iteration 0: 0.16192298600542046
# Converged in iteration 957 with cost 0.1619227701591685 because of vanishing difference
# Final cost : 0.1619227701591685
# Compute control for a deterministic system
# Cost in iteration 0: 0.1619227701591685
# Converged in iteration 5 with cost 0.16192277015916404 because of step counter
# Final cost : 0.16192277015916404
# Compute control for a deterministic system
# Cost in iteration 0: 6.609150233571892
# Final cost : 6.492030853406164
# Compute control for a deterministic system
# Cost in iteration 0: 6.492030853406164
# Final cost : 0.38290703868246023
# Compute control for a deterministic system
# Cost in iteration 0: 0.38290703868246023
# Final cost : 0.183088689794241
# Compute control for a deterministic system
# Cost in iteration 0: 0.183088689794241
# Final cost : 0.18044870144703867
# Compute control for a deterministic system
# Cost in iteration 0: 0.18044870144703867
# Final cost : 0.18044410135664138
# Compute control for a deterministic system
# Cost in iteration 0: 0.18044410135664138
# Converged in iteration 1071 with cost 0.180444100433177 because of step counter
# Final cost : 0.180444100433177
# Compute control for a deterministic system
# Cost in iteration 0: 6.945963974929948
# Final cost : 6.865772002526214
# Compute control for a deterministic system
# Cost in iteration 0: 6.865772002526214
# Final cost : 0.4646200184052526
# Compute control for a deterministic system
# Cost in iteration 0: 0.4646200184052526
# Final cost : 0.20429238109575473
# Compute control for a deterministic system
# Cost in iteration 0: 0.20429238109575473
# Final cost : 0.20016676958252777
# Compute control for a deterministic system
# Cost in iteration 0: 0.20016676958252777
# Final cost : 0.20012498751143915
# Compute control for a deterministic system
# Cost in iteration 0: 0.20012498751143915
# Final cost : 0.20012462839703565
# Compute control for a deterministic system
# Cost in iteration 0: 7.2005080618811075
# Final cost : 7.1514482094499785
# Compute control for a deterministic system
# Cost in iteration 0: 7.1514482094499785
# Final cost : 0.5648623944467035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5648623944467035
# Final cost : 0.2262448938295378
# Compute control for a deterministic system
# Cost in iteration 0: 0.2262448938295378
# Final cost : 0.21994911457402555
# Compute control for a deterministic system
# Cost in iteration 0: 0.21994911457402555
# Final cost : 0.21979626047528025
# Compute control for a deterministic system
# Cost in iteration 0: 0.21979626047528025
# Final cost : 0.21977719554416825
# Compute control for a deterministic system
# Cost in iteration 0: 7.383516292671991
# Final cost : 7.359215276882318
# Compute control for a deterministic system
# Cost in iteration 0: 7.359215276882318
# Final cost : 0.6989437490097128
# Compute control for a deterministic system
# Cost in iteration 0: 0.6989437490097128
# Final cost : 0.25035029586588525
# Compute control for a deterministic system
# Cost in iteration 0: 0.25035029586588525
# Final cost : 0.239282425603583
# Compute control for a deterministic system
# Cost in iteration 0: 0.239282425603583
# Final cost : 0.23781454685205214
# Compute control for a deterministic system
# Cost in iteration 0: 0.23781454685205214
# Final cost : 0.23701836635706044
# Compute control for a deterministic system
# Cost in iteration 0: 7.48411356353738
# Final cost : 7.475720223373793
# Compute control for a deterministic system
# Cost in iteration 0: 7.475720223373793
# Final cost : 0.8811041790006613
# Compute control for a deterministic system
# Cost in iteration 0: 0.8811041790006613
# Final cost : 0.2754292076633512
# Compute control for a deterministic system
# Cost in iteration 0: 0.2754292076633512
# Final cost : 0.2537689066067427
# Compute control for a deterministic system
# Cost in iteration 0: 0.2537689066067427
# Final cost : 0.2509642167130899
# Compute control for a deterministic system
# Cost in iteration 0: 0.2509642167130899
# Final cost : 0.25010271688380975
# Compute control for a deterministic system
# Cost in iteration 0: 7.507508543593407
# Final cost : 7.506521624573391
# Compute control for a deterministic system
# Cost in iteration 0: 7.506521624573391
# Final cost : 1.2338153560817624
# Compute control for a deterministic system
# Cost in iteration 0: 1.2338153560817624
# Final cost : 0.30132831851650377
# Compute control for a deterministic system
# Cost in iteration 0: 0.30132831851650377
# Final cost : 0.2708212465913075
# Compute control for a deterministic system
# Cost in iteration 0: 0.2708212465913075
# Final cost : 0.26347735520166393
# Compute control for a deterministic system
# Cost in iteration 0: 0.26347735520166393
# Final cost : 0.2621699201924324
# Compute control for a deterministic system
# Cost in iteration 0: 7.452760382517055
# Final cost : 7.450159545023799
# Compute control for a deterministic system
# Cost in iteration 0: 7.450159545023799
# Final cost : 1.3109455596780606
# Compute control for a deterministic system
# Cost in iteration 0: 1.3109455596780606
# Final cost : 0.46215120475938654
# Compute control for a deterministic system
# Cost in iteration 0: 0.46215120475938654
# Final cost : 0.4521765469791735
# Compute control for a deterministic system
# Cost in iteration 0: 0.4521765469791735
# Converged in iteration 351 with cost 0.45217651309000173 because of step counter
# Final cost : 0.45217651309000173
# Compute control for a deterministic system
# Cost in iteration 0: 0.45217651309000173
# Converged in iteration 1 with cost 0.45217651309000173 because of step counter
# Final cost : 0.45217651309000173
# Compute control for a deterministic system
# Cost in iteration 0: 7.317473343292279
# Final cost : 7.304188556294373
# Compute control for a deterministic system
# Cost in iteration 0: 7.304188556294373
# Final cost : 1.0402682271681278
# Compute control for a deterministic system
# Cost in iteration 0: 1.0402682271681278
# Final cost : 0.40885605424017873
# Compute control for a deterministic system
# Cost in iteration 0: 0.40885605424017873
# Final cost : 0.4019587602536458
# Compute control for a deterministic system
# Cost in iteration 0: 0.4019587602536458
# Converged in iteration 279 with cost 0.4019587539581612 because of step counter
# Final cost : 0.4019587539581612
# Compute control for a deterministic system
# Cost in iteration 0: 0.4019587539581612
# Converged in iteration 1 with cost 0.4019587539581612 because of step counter
# Final cost : 0.4019587539581612
# Compute control for a deterministic system
# Cost in iteration 0: 7.109866438965277
# Final cost : 7.077619179265396
# Compute control for a deterministic system
# Cost in iteration 0: 7.077619179265396
# Final cost : 0.8456037040869342
# Compute control for a deterministic system
# Cost in iteration 0: 0.8456037040869342
# Final cost : 0.3602570671425378
# Compute control for a deterministic system
# Cost in iteration 0: 0.3602570671425378
# Final cost : 0.35555451609826516
# Compute control for a deterministic system
# Cost in iteration 0: 0.35555451609826516
# Converged in iteration 265 with cost 0.35555451441894836 because of step counter
# Final cost : 0.35555451441894836
# Compute control for a deterministic system
# Cost in iteration 0: 0.35555451441894836
# Converged in iteration 1 with cost 0.35555451441894836 because of step counter
# Final cost : 0.35555451441894836
# Compute control for a deterministic system
# Cost in iteration 0: 6.821612554536581
# Final cost : 6.761925601131516
# Compute control for a deterministic system
# Cost in iteration 0: 6.761925601131516
# Final cost : 0.6854445551671088
# Compute control for a deterministic system
# Cost in iteration 0: 0.6854445551671088
# Final cost : 0.31389658466972775
# Compute control for a deterministic system
# Cost in iteration 0: 0.31389658466972775
# Final cost : 0.3108132706948319
# Compute control for a deterministic system
# Cost in iteration 0: 0.3108132706948319
# Converged in iteration 286 with cost 0.3108132682900377 because of step counter
# Final cost : 0.3108132682900377
# Compute control for a deterministic system
# Cost in iteration 0: 0.3108132682900377
# Converged in iteration 2 with cost 0.31081326829003664 because of step counter
# Final cost : 0.31081326829003664
# Compute control for a deterministic system
# Cost in iteration 0: 6.472827206686714
# Final cost : 6.380511288238765
# Compute control for a deterministic system
# Cost in iteration 0: 6.380511288238765
# Final cost : 0.5575931246809018
# Compute control for a deterministic system
# Cost in iteration 0: 0.5575931246809018
# Final cost : 0.27229319718809275
# Compute control for a deterministic system
# Cost in iteration 0: 0.27229319718809275
# Final cost : 0.270307638434969
# Compute control for a deterministic system
# Cost in iteration 0: 0.270307638434969
# Converged in iteration 215 with cost 0.27030763809741143 because of step counter
# Final cost : 0.27030763809741143
# Compute control for a deterministic system
# Cost in iteration 0: 0.27030763809741143
# Converged in iteration 1 with cost 0.27030763809741143 because of step counter
# Final cost : 0.27030763809741143
# Compute control for a deterministic system
# Cost in iteration 0: 6.051687503750652
# Final cost : 5.922924344680521
# Compute control for a deterministic system
# Cost in iteration 0: 5.922924344680521
# Final cost : 0.44901101085445483
# Compute control for a deterministic system
# Cost in iteration 0: 0.44901101085445483
# Final cost : 0.2332181276531848
# Compute control for a deterministic system
# Cost in iteration 0: 0.2332181276531848
# Final cost : 0.23199184969511916
# Compute control for a deterministic system
# Cost in iteration 0: 0.23199184969511916
# Converged in iteration 186 with cost 0.23199184958325406 because of step counter
# Final cost : 0.23199184958325406
# Compute control for a deterministic system
# Cost in iteration 0: 0.23199184958325406
# Converged in iteration 2 with cost 0.23199184958325192 because of step counter
# Final cost : 0.23199184958325192
# Compute control for a deterministic system
# Cost in iteration 0: 5.588849047200861
# Final cost : 5.425493966623695
# Compute control for a deterministic system
# Cost in iteration 0: 5.425493966623695
# Final cost : 0.36140643377723247
# Compute control for a deterministic system
# Cost in iteration 0: 0.36140643377723247
# Final cost : 0.19867645558546423
# Compute control for a deterministic system
# Cost in iteration 0: 0.19867645558546423
# Final cost : 0.1979315974942521
# Compute control for a deterministic system
# Cost in iteration 0: 0.1979315974942521
# Converged in iteration 151 with cost 0.19793159747823824 because of step counter
# Final cost : 0.19793159747823824
# Compute control for a deterministic system
# Cost in iteration 0: 0.19793159747823824
# Converged in iteration 13 with cost 0.197931597478214 because of step counter
# Final cost : 0.197931597478214
# Compute control for a deterministic system
# Cost in iteration 0: 5.069652515149256
# Final cost : 4.875471575195498
# Compute control for a deterministic system
# Cost in iteration 0: 4.875471575195498
# Final cost : 0.2868487746534839
# Compute control for a deterministic system
# Cost in iteration 0: 0.2868487746534839
# Final cost : 0.1666650324905612
# Compute control for a deterministic system
# Cost in iteration 0: 0.1666650324905612
# Final cost : 0.16623243403269014
# Compute control for a deterministic system
# Cost in iteration 0: 0.16623243403269014
# Converged in iteration 66 with cost 0.1662324340316815 because of step counter
# Final cost : 0.1662324340316815
# Compute control for a deterministic system
# Cost in iteration 0: 0.1662324340316815
# Converged in iteration 1 with cost 0.1662324340316815 because of step counter
# Final cost : 0.1662324340316815
# Compute control for a deterministic system
# Cost in iteration 0: 4.532489468876998
# Final cost : 4.315744484061401
# Compute control for a deterministic system
# Cost in iteration 0: 4.315744484061401
# Final cost : 0.22676670877094504
# Compute control for a deterministic system
# Cost in iteration 0: 0.22676670877094504
# Final cost : 0.13869132044716848
# Compute control for a deterministic system
# Cost in iteration 0: 0.13869132044716848
# Converged in iteration 560 with cost 0.13844473589458703 because of step counter
# Final cost : 0.13844473589458703
# Compute control for a deterministic system
# Cost in iteration 0: 0.13844473589458703
# Converged in iteration 1 with cost 0.13844473589458703 because of step counter
# Final cost : 0.13844473589458703
# Compute control for a deterministic system
# Cost in iteration 0: 0.13844473589458703
# Converged in iteration 1 with cost 0.13844473589458703 because of step counter
# Final cost : 0.13844473589458703
# Compute control for a deterministic system
# Cost in iteration 0: 3.960389422668421
# Final cost : 3.7300659823062974
# Compute control for a deterministic system
# Cost in iteration 0: 3.7300659823062974
# Final cost : 0.17579972464535576
# Compute control for a deterministic system
# Cost in iteration 0: 0.17579972464535576
# Final cost : 0.11305057168114287
# Compute control for a deterministic system
# Cost in iteration 0: 0.11305057168114287
# Converged in iteration 496 with cost 0.11291727326587525 because of step counter
# Final cost : 0.11291727326587525
# Compute control for a deterministic system
# Cost in iteration 0: 0.11291727326587525
# Converged in iteration 4 with cost 0.11291727326587254 because of step counter
# Final cost : 0.11291727326587254
# Compute control for a deterministic system
# Cost in iteration 0: 0.11291727326587254
# Converged in iteration 2 with cost 0.11291727326587214 because of step counter
# Final cost : 0.11291727326587214
# Compute control for a deterministic system
# Cost in iteration 0: 3.3953637689179157
# Final cost : 3.1621237620400158
# Compute control for a deterministic system
# Cost in iteration 0: 3.1621237620400158
# Final cost : 0.13496645999014373
# Compute control for a deterministic system
# Cost in iteration 0: 0.13496645999014373
# Final cost : 0.09092012857084243
# Compute control for a deterministic system
# Cost in iteration 0: 0.09092012857084243
# Converged in iteration 559 with cost 0.09084990692609332 because of step counter
# Final cost : 0.09084990692609332
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084990692609332
# Converged in iteration 1 with cost 0.09084990692609332 because of step counter
# Final cost : 0.09084990692609332
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084990692609332
# Converged in iteration 1 with cost 0.09084990692609332 because of step counter
# Final cost : 0.09084990692609332
# Compute control for a deterministic system
# Cost in iteration 0: 2.8193485927756106
# Final cost : 2.593910421676721
# Compute control for a deterministic system
# Cost in iteration 0: 2.593910421676721
# Final cost : 0.1006545202392237
# Compute control for a deterministic system
# Cost in iteration 0: 0.1006545202392237
# Final cost : 0.0709491950026901
# Compute control for a deterministic system
# Cost in iteration 0: 0.0709491950026901
# Converged in iteration 511 with cost 0.07091462447433342 because of step counter
# Final cost : 0.07091462447433342
# Compute control for a deterministic system
# Cost in iteration 0: 0.07091462447433342
# Converged in iteration 1 with cost 0.07091462447433342 because of step counter
# Final cost : 0.07091462447433342
# Compute control for a deterministic system
# Cost in iteration 0: 0.07091462447433342
# Converged in iteration 1 with cost 0.07091462447433342 because of step counter
# Final cost : 0.07091462447433342
# Compute control for a deterministic system
# Cost in iteration 0: 2.2748749294001773
# Final cost : 2.06710324491504
# Compute control for a deterministic system
# Cost in iteration 0: 2.06710324491504
# Final cost : 0.07356374382591492
# Compute control for a deterministic system
# Cost in iteration 0: 0.07356374382591492
# Final cost : 0.05406426494653168
# Compute control for a deterministic system
# Cost in iteration 0: 0.05406426494653168
# Converged in iteration 468 with cost 0.05404791521245632 because of step counter
# Final cost : 0.05404791521245632
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404791521245632
# Converged in iteration 1 with cost 0.05404791521245632 because of step counter
# Final cost : 0.05404791521245632
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404791521245632
# Converged in iteration 2 with cost 0.05404791521245579 because of step counter
# Final cost : 0.05404791521245579
# Compute control for a deterministic system
# Cost in iteration 0: 1.7454578349418406
# Final cost : 1.565051124794272
# Compute control for a deterministic system
# Cost in iteration 0: 1.565051124794272
# Final cost : 0.05129176515821275
# Compute control for a deterministic system
# Cost in iteration 0: 0.05129176515821275
# Final cost : 0.03924669552583226
# Compute control for a deterministic system
# Cost in iteration 0: 0.03924669552583226
# Converged in iteration 410 with cost 0.03923966680293799 because of step counter
# Final cost : 0.03923966680293799
# Compute control for a deterministic system
# Cost in iteration 0: 0.03923966680293799
# Converged in iteration 7 with cost 0.0392396668029281 because of step counter
# Final cost : 0.0392396668029281
# Compute control for a deterministic system
# Cost in iteration 0: 0.0392396668029281
# Converged in iteration 1 with cost 0.0392396668029281 because of step counter
# Final cost : 0.0392396668029281
# Compute control for a deterministic system
# Cost in iteration 0: 1.2718764853580509
# Final cost : 1.125283998477372
# Compute control for a deterministic system
# Cost in iteration 0: 1.125283998477372
# Final cost : 0.03426534981878073
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426534981878073
# Final cost : 0.0271928502416644
# Compute control for a deterministic system
# Cost in iteration 0: 0.0271928502416644
# Converged in iteration 364 with cost 0.027190043753662806 because of step counter
# Final cost : 0.027190043753662806
# Compute control for a deterministic system
# Cost in iteration 0: 0.027190043753662806
# Converged in iteration 5 with cost 0.027190043753661783 because of step counter
# Final cost : 0.027190043753661783
# Compute control for a deterministic system
# Cost in iteration 0: 0.027190043753661783
# Converged in iteration 1 with cost 0.027190043753661783 because of step counter
# Final cost : 0.027190043753661783
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425447098209606
# Final cost : 0.7352306087750001
# Compute control for a deterministic system
# Cost in iteration 0: 0.7352306087750001
# Final cost : 0.02092295739946006
# Compute control for a deterministic system
# Cost in iteration 0: 0.02092295739946006
# Final cost : 0.017179955515404244
# Compute control for a deterministic system
# Cost in iteration 0: 0.017179955515404244
# Converged in iteration 282 with cost 0.01717900605274192 because of step counter
# Final cost : 0.01717900605274192
# Compute control for a deterministic system
# Cost in iteration 0: 0.01717900605274192
# Converged in iteration 1 with cost 0.01717900605274192 because of step counter
# Final cost : 0.01717900605274192
# Compute control for a deterministic system
# Cost in iteration 0: 0.01717900605274192
# Converged in iteration 1 with cost 0.01717900605274192 because of step counter
# Final cost : 0.01717900605274192
# Compute control for a deterministic system
# Cost in iteration 0: 0.49433437122888985
# Final cost : 0.425860140905737
# Compute control for a deterministic system
# Cost in iteration 0: 0.425860140905737
# Final cost : 0.011449555849599207
# Compute control for a deterministic system
# Cost in iteration 0: 0.011449555849599207
# Final cost : 0.009677361465869639
# Compute control for a deterministic system
# Cost in iteration 0: 0.009677361465869639
# Converged in iteration 235 with cost 0.009677096071959206 because of step counter
# Final cost : 0.009677096071959206
# Compute control for a deterministic system
# Cost in iteration 0: 0.009677096071959206
# Converged in iteration 1 with cost 0.009677096071959206 because of step counter
# Final cost : 0.009677096071959206
# Compute control for a deterministic system
# Cost in iteration 0: 0.009677096071959206
# Converged in iteration 1 with cost 0.009677096071959206 because of step counter
# Final cost : 0.009677096071959206
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359083445271974
# Final cost : 0.1904144848995215
# Compute control for a deterministic system
# Cost in iteration 0: 0.1904144848995215
# Final cost : 0.004883950640944993
# Compute control for a deterministic system
# Cost in iteration 0: 0.004883950640944993
# Final cost : 0.004227877690057877
# Compute control for a deterministic system
# Cost in iteration 0: 0.004227877690057877
# Converged in iteration 218 with cost 0.0042278310476670964 because of step counter
# Final cost : 0.0042278310476670964
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042278310476670964
# Converged in iteration 8 with cost 0.004227831047665213 because of step counter
# Final cost : 0.004227831047665213
# Compute control for a deterministic system
# Cost in iteration 0: 0.004227831047665213
# Converged in iteration 1 with cost 0.004227831047665213 because of step counter
# Final cost : 0.004227831047665213
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821055614597352
# Final cost : 0.049178042701272365
# Compute control for a deterministic system
# Cost in iteration 0: 0.049178042701272365
# Final cost : 0.0012205079077839292
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012205079077839292
# Final cost : 0.0010734974096235936
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010734974096235936
# Converged in iteration 167 with cost 0.001073494448365767 because of step counter
# Final cost : 0.001073494448365767
# Compute control for a deterministic system
# Cost in iteration 0: 0.001073494448365767
# Converged in iteration 1 with cost 0.001073494448365767 because of step counter
# Final cost : 0.001073494448365767
# Compute control for a deterministic system
# Cost in iteration 0: 0.001073494448365767
# Converged in iteration 1 with cost 0.001073494448365767 because of step counter
# Final cost : 0.001073494448365767
# Compute control for a deterministic system
# Cost in iteration 0: 1.1834255416428287e-06
# Final cost : 9.965650483318749e-07
# Compute control for a deterministic system
# Cost in iteration 0: 9.965650483318749e-07
# Final cost : 2.4269676205646826e-08
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05795376133981112
# Final cost : 0.004292303784123748
# Compute control for a deterministic system
# Cost in iteration 0: 0.004292303784123748
# Final cost : 0.004133258564204727
# Compute control for a deterministic system
# Cost in iteration 0: 0.004133258564204727
# Converged in iteration 168 with cost 0.00413323811855777 because of step counter
# Final cost : 0.00413323811855777
# Compute control for a deterministic system
# Cost in iteration 0: 0.00413323811855777
# Converged in iteration 5 with cost 0.004133238118553295 because of step counter
# Final cost : 0.004133238118553295
# Compute control for a deterministic system
# Cost in iteration 0: 0.004133238118553295
# Converged in iteration 2 with cost 0.004133238118552962 because of step counter
# Final cost : 0.004133238118552962
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.054909653155094475
# Final cost : 0.009337842486032491
# Compute control for a deterministic system
# Cost in iteration 0: 0.009337842486032491
# Final cost : 0.009150694677582368
# Compute control for a deterministic system
# Cost in iteration 0: 0.009150694677582368
# Converged in iteration 205 with cost 0.009150624571466301 because of step counter
# Final cost : 0.009150624571466301
# Compute control for a deterministic system
# Cost in iteration 0: 0.009150624571466301
# Converged in iteration 1 with cost 0.009150624571466301 because of step counter
# Final cost : 0.009150624571466301
# Compute control for a deterministic system
# Cost in iteration 0: 0.009150624571466301
# Converged in iteration 1 with cost 0.009150624571466301 because of step counter
# Final cost : 0.009150624571466301
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.059156729243753314
# Final cost : 0.016546911860386707
# Compute control for a deterministic system
# Cost in iteration 0: 0.016546911860386707
# Final cost : 0.0162848438038636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0162848438038636
# Converged in iteration 241 with cost 0.01628463113450756 because of step counter
# Final cost : 0.01628463113450756
# Compute control for a deterministic system
# Cost in iteration 0: 0.01628463113450756
# Converged in iteration 1 with cost 0.01628463113450756 because of step counter
# Final cost : 0.01628463113450756
# Compute control for a deterministic system
# Cost in iteration 0: 0.01628463113450756
# Converged in iteration 6 with cost 0.016284631134506913 because of step counter
# Final cost : 0.016284631134506913
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0826426583868156
# Final cost : 0.025483819935159795
# Compute control for a deterministic system
# Cost in iteration 0: 0.025483819935159795
# Final cost : 0.025102876482982574
# Compute control for a deterministic system
# Cost in iteration 0: 0.025102876482982574
# Converged in iteration 288 with cost 0.025102357877744386 because of step counter
# Final cost : 0.025102357877744386
# Compute control for a deterministic system
# Cost in iteration 0: 0.025102357877744386
# Converged in iteration 1 with cost 0.025102357877744386 because of step counter
# Final cost : 0.025102357877744386
# Compute control for a deterministic system
# Cost in iteration 0: 0.025102357877744386
# Converged in iteration 1 with cost 0.025102357877744386 because of step counter
# Final cost : 0.025102357877744386
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.08111356655225263
# Final cost : 0.036493107527735
# Compute control for a deterministic system
# Cost in iteration 0: 0.036493107527735
# Final cost : 0.0360081766153183
# Compute control for a deterministic system
# Cost in iteration 0: 0.0360081766153183
# Converged in iteration 334 with cost 0.036006970972788065 because of vanishing difference
# Final cost : 0.036006970972788065
# Compute control for a deterministic system
# Cost in iteration 0: 0.036006970972788065
# Converged in iteration 2 with cost 0.03600697097278692 because of step counter
# Final cost : 0.03600697097278692
# Compute control for a deterministic system
# Cost in iteration 0: 0.03600697097278692
# Converged in iteration 2 with cost 0.03600697097278609 because of step counter
# Final cost : 0.03600697097278609
# Compute control for a deterministic system
# Cost in iteration 0: 0.09771906194951394
# Final cost : 0.04891805811056781
# Compute control for a deterministic system
# Cost in iteration 0: 0.04891805811056781
# Final cost : 0.04832258999812965
# Compute control for a deterministic system
# Cost in iteration 0: 0.04832258999812965
# Converged in iteration 406 with cost 0.04832022846883174 because of step counter
# Final cost : 0.04832022846883174
# Compute control for a deterministic system
# Cost in iteration 0: 0.04832022846883174
# Converged in iteration 1 with cost 0.04832022846883174 because of step counter
# Final cost : 0.04832022846883174
# Compute control for a deterministic system
# Cost in iteration 0: 0.04832022846883174
# Converged in iteration 1 with cost 0.04832022846883174 because of step counter
# Final cost : 0.04832022846883174
# Compute control for a deterministic system
# Cost in iteration 0: 0.16471912629057833
# Final cost : 0.06335741759686182
# Compute control for a deterministic system
# Cost in iteration 0: 0.06335741759686182
# Final cost : 0.06250025552267718
# Compute control for a deterministic system
# Cost in iteration 0: 0.06250025552267718
# Converged in iteration 502 with cost 0.06249536419301892 because of step counter
# Final cost : 0.06249536419301892
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249536419301892
# Converged in iteration 17 with cost 0.06249536419299153 because of step counter
# Final cost : 0.06249536419299153
# Compute control for a deterministic system
# Cost in iteration 0: 0.06249536419299153
# Converged in iteration 1 with cost 0.06249536419299153 because of step counter
# Final cost : 0.06249536419299153
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.10626719129697487
# Final cost : 0.07816351622312234
# Compute control for a deterministic system
# Cost in iteration 0: 0.07816351622312234
# Final cost : 0.07740431884156898
# Compute control for a deterministic system
# Cost in iteration 0: 0.07740431884156898
# Converged in iteration 570 with cost 0.07739731522963918 because of step counter
# Final cost : 0.07739731522963918
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739731522963918
# Converged in iteration 1 with cost 0.07739731522963918 because of step counter
# Final cost : 0.07739731522963918
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739731522963918
# Converged in iteration 3 with cost 0.07739731522963811 because of step counter
# Final cost : 0.07739731522963811
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916779148706061
# Final cost : 0.09437768803465342
# Compute control for a deterministic system
# Cost in iteration 0: 0.09437768803465342
# Final cost : 0.09341234965988417
# Compute control for a deterministic system
# Cost in iteration 0: 0.09341234965988417
# Final cost : 0.09340102968471757
# Compute control for a deterministic system
# Cost in iteration 0: 0.09340102968471757
# Converged in iteration 84 with cost 0.09340102968426917 because of step counter
# Final cost : 0.09340102968426917
# Compute control for a deterministic system
# Cost in iteration 0: 0.09340102968426917
# Converged in iteration 1 with cost 0.09340102968426917 because of step counter
# Final cost : 0.09340102968426917
# Compute control for a deterministic system
# Cost in iteration 0: 0.1348203797264689
# Final cost : 0.11034100579736739
# Compute control for a deterministic system
# Cost in iteration 0: 0.11034100579736739
# Final cost : 0.10947305414048658
# Compute control for a deterministic system
# Cost in iteration 0: 0.10947305414048658
# Final cost : 0.10945974156393677
# Compute control for a deterministic system
# Cost in iteration 0: 0.10945974156393677
# Converged in iteration 273 with cost 0.10945974154864424 because of step counter
# Final cost : 0.10945974154864424
# Compute control for a deterministic system
# Cost in iteration 0: 0.10945974154864424
# Converged in iteration 3 with cost 0.10945974154864349 because of step counter
# Final cost : 0.10945974154864349
# Compute control for a deterministic system
# Cost in iteration 0: 0.22330577301458904
# Final cost : 0.12755600953088586
# Compute control for a deterministic system
# Cost in iteration 0: 0.12755600953088586
# Final cost : 0.12648280096637685
# Compute control for a deterministic system
# Cost in iteration 0: 0.12648280096637685
# Final cost : 0.12646303621917354
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646303621917354
# Converged in iteration 308 with cost 0.12646303618675098 because of step counter
# Final cost : 0.12646303618675098
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646303618675098
# Converged in iteration 1 with cost 0.12646303618675098 because of step counter
# Final cost : 0.12646303618675098
# Compute control for a deterministic system
# Cost in iteration 0: 0.16403260523199065
# Final cost : 0.1446631107837178
# Compute control for a deterministic system
# Cost in iteration 0: 0.1446631107837178
# Final cost : 0.14363858111830194
# Compute control for a deterministic system
# Cost in iteration 0: 0.14363858111830194
# Final cost : 0.14361490157377899
# Compute control for a deterministic system
# Cost in iteration 0: 0.14361490157377899
# Converged in iteration 401 with cost 0.143614900769482 because of step counter
# Final cost : 0.143614900769482
# Compute control for a deterministic system
# Cost in iteration 0: 0.143614900769482
# Converged in iteration 2 with cost 0.14361490076948025 because of step counter
# Final cost : 0.14361490076948025
# Compute control for a deterministic system
# Cost in iteration 0: 0.24982635607778236
# Final cost : 0.16323357050452036
# Compute control for a deterministic system
# Cost in iteration 0: 0.16323357050452036
# Final cost : 0.1619593950079838
# Compute control for a deterministic system
# Cost in iteration 0: 0.1619593950079838
# Final cost : 0.16192278817888492
# Compute control for a deterministic system
# Cost in iteration 0: 0.16192278817888492
# Converged in iteration 810 with cost 0.16192277015912868 because of step counter
# Final cost : 0.16192277015912868
# Compute control for a deterministic system
# Cost in iteration 0: 0.16192277015912868
# Converged in iteration 1 with cost 0.16192277015912868 because of step counter
# Final cost : 0.16192277015912868
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.20765925855875947
# Final cost : 0.18173160210365624
# Compute control for a deterministic system
# Cost in iteration 0: 0.18173160210365624
# Final cost : 0.18049072820198717
# Compute control for a deterministic system
# Cost in iteration 0: 0.18049072820198717
# Final cost : 0.18044426007133652
# Compute control for a deterministic system
# Cost in iteration 0: 0.18044426007133652
# Final cost : 0.18044410047441986
# Compute control for a deterministic system
# Cost in iteration 0: 0.18044410047441986
# Converged in iteration 640 with cost 0.18044410043295442 because of step counter
# Final cost : 0.18044410043295442
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.23431779895594945
# Final cost : 0.2016352506878467
# Compute control for a deterministic system
# Cost in iteration 0: 0.2016352506878467
# Final cost : 0.20019330938288668
# Compute control for a deterministic system
# Cost in iteration 0: 0.20019330938288668
# Final cost : 0.20012616830213834
# Compute control for a deterministic system
# Cost in iteration 0: 0.20012616830213834
# Final cost : 0.20012464293618004
# Compute control for a deterministic system
# Cost in iteration 0: 0.20012464293618004
# Converged in iteration 1944 with cost 0.20012462836376346 because of step counter
# Final cost : 0.20012462836376346
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.2835210078724745
# Final cost : 0.22141884403206583
# Compute control for a deterministic system
# Cost in iteration 0: 0.22141884403206583
# Final cost : 0.21986479171817513
# Compute control for a deterministic system
# Cost in iteration 0: 0.21986479171817513
# Final cost : 0.2197823753075556
# Compute control for a deterministic system
# Cost in iteration 0: 0.2197823753075556
# Final cost : 0.219777745980166
# Compute control for a deterministic system
# Cost in iteration 0: 0.219777745980166
# Final cost : 0.21977717951595938
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.3720132309108344
# Final cost : 0.24217071458033526
# Compute control for a deterministic system
# Cost in iteration 0: 0.24217071458033526
# Final cost : 0.2402199212855132
# Compute control for a deterministic system
# Cost in iteration 0: 0.2402199212855132
# Final cost : 0.23992178960175684
# ...
# Final cost : 0.2614978430773578
# Compute control for a deterministic system
# Cost in iteration 0: 0.2614978430773578
# Final cost : 0.26144125046320293
# Compute control for a deterministic system
# Cost in iteration 0: 0.26144125046320293
# Final cost : 0.2614223670802891
# Compute control for a deterministic system
# Cost in iteration 0: 0.2614223670802891
# Final cost : 0.2613991057725216
# Compute control for a deterministic system
# Cost in iteration 0: 0.2613991057725216
# Final cost : 0.26137303820386837
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 1.0626952625698738
# Final cost : 0.27140530287354875
# Compute control for a deterministic system
# Cost in iteration 0: 0.27140530287354875
# Final cost : 0.27117488407571655
# Compute control for a deterministic system
# Cost in iteration 0: 0.27117488407571655
# Final cost : 0.2711563873511663
# Compute control for a deterministic system
# Cost in iteration 0: 0.2711563873511663
# Final cost : 0.2711445181903703
# Compute control for a deterministic system
# Cost in iteration 0: 0.2711445181903703
# Final cost : 0.27112641094070544
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.4933780224957893
# Final cost : 0.2795257280888627
# Compute control for a deterministic system
# Cost in iteration 0: 0.2795257280888627
# Final cost : 0.27951941166902616
# Compute control for a deterministic system
# Cost in iteration 0: 0.27951941166902616
# Final cost : 0.2795187801647051
# Compute control for a deterministic system
# Cost in iteration 0: 0.2795187801647051
# Final cost : 0.27951872421669716
# Compute control for a deterministic system
# Cost in iteration 0: 0.27951872421669716
# Final cost : 0.27951871652650223
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.38779122403650484
# Final cost : 0.2865093612098807
# Compute control for a deterministic system
# Cost in iteration 0: 0.2865093612098807
# Final cost : 0.286485395540536
# Compute control for a deterministic system
# Cost in iteration 0: 0.286485395540536
# Final cost : 0.2864722509480396
# Compute control for a deterministic system
# Cost in iteration 0: 0.2864722509480396
# Final cost : 0.286460096724562
# Compute control for a deterministic system
# Cost in iteration 0: 0.286460096724562
# Final cost : 0.2864431590365913
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232758353631907
# Final cost : 0.29291315301174004
# Compute control for a deterministic system
# Cost in iteration 0: 0.29291315301174004
# Final cost : 0.29288812639158157
# Compute control for a deterministic system
# Cost in iteration 0: 0.29288812639158157
# Final cost : 0.2928596575901309
# Compute control for a deterministic system
# Cost in iteration 0: 0.2928596575901309
# Final cost : 0.29281983922564697
# Compute control for a deterministic system
# Cost in iteration 0: 0.29281983922564697
# Final cost : 0.292733847013547
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.3136459797768378
# Final cost : 0.27095672031230855
# Compute control for a deterministic system
# Cost in iteration 0: 0.27095672031230855
# Final cost : 0.27030769487992407
# Compute control for a deterministic system
# Cost in iteration 0: 0.27030769487992407
# Converged in iteration 352 with cost 0.27030763809742253 because of step counter
# Final cost : 0.27030763809742253
# Compute control for a deterministic system
# Cost in iteration 0: 0.27030763809742253
# Converged in iteration 2 with cost 0.27030763809742236 because of step counter
# Final cost : 0.27030763809742236
# Compute control for a deterministic system
# Cost in iteration 0: 0.27030763809742236
# Converged in iteration 1 with cost 0.27030763809742236 because of step counter
# Final cost : 0.27030763809742236
# Compute control for a deterministic system
# Cost in iteration 0: 0.2501860700030748
# Final cost : 0.232686787272049
# Compute control for a deterministic system
# Cost in iteration 0: 0.232686787272049
# Final cost : 0.2319919278166088
# Compute control for a deterministic system
# Cost in iteration 0: 0.2319919278166088
# Converged in iteration 426 with cost 0.23199184958328306 because of step counter
# Final cost : 0.23199184958328306
# Compute control for a deterministic system
# Cost in iteration 0: 0.23199184958328306
# Converged in iteration 2 with cost 0.2319918495832826 because of step counter
# Final cost : 0.2319918495832826
# Compute control for a deterministic system
# Cost in iteration 0: 0.2319918495832826
# Converged in iteration 1 with cost 0.2319918495832826 because of step counter
# Final cost : 0.2319918495832826
# Compute control for a deterministic system
# Cost in iteration 0: 0.20589675873775715
# Final cost : 0.19865681177125033
# Compute control for a deterministic system
# Cost in iteration 0: 0.19865681177125033
# Final cost : 0.19793168919207996
# Compute control for a deterministic system
# Cost in iteration 0: 0.19793168919207996
# Converged in iteration 430 with cost 0.19793159747824732 because of step counter
# Final cost : 0.19793159747824732
# Compute control for a deterministic system
# Cost in iteration 0: 0.19793159747824732
# Converged in iteration 9 with cost 0.19793159747822736 because of step counter
# Final cost : 0.19793159747822736
# Compute control for a deterministic system
# Cost in iteration 0: 0.19793159747822736
# Converged in iteration 1 with cost 0.19793159747822736 because of step counter
# Final cost : 0.19793159747822736
# Compute control for a deterministic system
# Cost in iteration 0: 0.23028091143326693
# Final cost : 0.16665895427198535
# Compute control for a deterministic system
# Cost in iteration 0: 0.16665895427198535
# Final cost : 0.16623247409385755
# Compute control for a deterministic system
# Cost in iteration 0: 0.16623247409385755
# Converged in iteration 263 with cost 0.16623243403186555 because of step counter
# Final cost : 0.16623243403186555
# Compute control for a deterministic system
# Cost in iteration 0: 0.16623243403186555
# Converged in iteration 13 with cost 0.16623243403175325 because of step counter
# Final cost : 0.16623243403175325
# Compute control for a deterministic system
# Cost in iteration 0: 0.16623243403175325
# Converged in iteration 30 with cost 0.1662324340316771 because of step counter
# Final cost : 0.1662324340316771
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.1422913429103731
# Final cost : 0.13921230505395044
# Compute control for a deterministic system
# Cost in iteration 0: 0.13921230505395044
# Final cost : 0.13844482213240605
# Compute control for a deterministic system
# Cost in iteration 0: 0.13844482213240605
# Converged in iteration 325 with cost 0.13844473589449902 because of step counter
# Final cost : 0.13844473589449902
# Compute control for a deterministic system
# Cost in iteration 0: 0.13844473589449902
# Converged in iteration 1 with cost 0.13844473589449902 because of step counter
# Final cost : 0.13844473589449902
# Compute control for a deterministic system
# Cost in iteration 0: 0.13844473589449902
# Converged in iteration 1 with cost 0.13844473589449902 because of step counter
# Final cost : 0.13844473589449902
# Compute control for a deterministic system
# Cost in iteration 0: 0.11551653708320946
# Final cost : 0.11349433097916319
# Compute control for a deterministic system
# Cost in iteration 0: 0.11349433097916319
# Final cost : 0.1129173270304072
# Compute control for a deterministic system
# Cost in iteration 0: 0.1129173270304072
# Converged in iteration 251 with cost 0.11291727326588732 because of step counter
# Final cost : 0.11291727326588732
# Compute control for a deterministic system
# Cost in iteration 0: 0.11291727326588732
# Converged in iteration 1 with cost 0.11291727326588732 because of step counter
# Final cost : 0.11291727326588732
# Compute control for a deterministic system
# Cost in iteration 0: 0.11291727326588732
# Converged in iteration 1 with cost 0.11291727326588732 because of step counter
# Final cost : 0.11291727326588732
# Compute control for a deterministic system
# Cost in iteration 0: 0.11272692103223526
# Final cost : 0.09114316905803885
# Compute control for a deterministic system
# Cost in iteration 0: 0.09114316905803885
# Final cost : 0.09084993007112592
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084993007112592
# Converged in iteration 197 with cost 0.09084990692609812 because of step counter
# Final cost : 0.09084990692609812
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084990692609812
# Converged in iteration 1 with cost 0.09084990692609812 because of step counter
# Final cost : 0.09084990692609812
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084990692609812
# Converged in iteration 1 with cost 0.09084990692609812 because of step counter
# Final cost : 0.09084990692609812
# Compute control for a deterministic system
# Cost in iteration 0: 0.07272241348775635
# Final cost : 0.07134110150724085
# Compute control for a deterministic system
# Cost in iteration 0: 0.07134110150724085
# Final cost : 0.07091465387046694
# Compute control for a deterministic system
# Cost in iteration 0: 0.07091465387046694
# Converged in iteration 286 with cost 0.0709146244743058 because of step counter
# Final cost : 0.0709146244743058
# Compute control for a deterministic system
# Cost in iteration 0: 0.0709146244743058
# Converged in iteration 7 with cost 0.07091462447429761 because of step counter
# Final cost : 0.07091462447429761
# Compute control for a deterministic system
# Cost in iteration 0: 0.07091462447429761
# Converged in iteration 2 with cost 0.07091462447429674 because of step counter
# Final cost : 0.07091462447429674
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.05858718150029017
# Final cost : 0.054279016963358115
# Compute control for a deterministic system
# Cost in iteration 0: 0.054279016963358115
# Final cost : 0.05404793128067043
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404793128067043
# Converged in iteration 226 with cost 0.05404791521246214 because of step counter
# Final cost : 0.05404791521246214
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404791521246214
# Converged in iteration 3 with cost 0.05404791521246155 because of step counter
# Final cost : 0.05404791521246155
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404791521246155
# Converged in iteration 1 with cost 0.05404791521246155 because of step counter
# Final cost : 0.05404791521246155
# Compute control for a deterministic system
# Cost in iteration 0: 0.04739914158994559
# Final cost : 0.03937843724622
# Compute control for a deterministic system
# Cost in iteration 0: 0.03937843724622
# Final cost : 0.039239677230113006
# Compute control for a deterministic system
# Cost in iteration 0: 0.039239677230113006
# Converged in iteration 166 with cost 0.03923966680293984 because of step counter
# Final cost : 0.03923966680293984
# Compute control for a deterministic system
# Cost in iteration 0: 0.03923966680293984
# Converged in iteration 5 with cost 0.03923966680292851 because of step counter
# Final cost : 0.03923966680292851
# Compute control for a deterministic system
# Cost in iteration 0: 0.03923966680292851
# Converged in iteration 1 with cost 0.03923966680292851 because of step counter
# Final cost : 0.03923966680292851
# Compute control for a deterministic system
# Cost in iteration 0: 0.029667512439519695
# Final cost : 0.027306648286790677
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306648286790677
# Final cost : 0.027190051510150696
# Compute control for a deterministic system
# Cost in iteration 0: 0.027190051510150696
# Converged in iteration 160 with cost 0.027190043753664277 because of step counter
# Final cost : 0.027190043753664277
# Compute control for a deterministic system
# Cost in iteration 0: 0.027190043753664277
# Converged in iteration 1 with cost 0.027190043753664277 because of step counter
# Final cost : 0.027190043753664277
# Compute control for a deterministic system
# Cost in iteration 0: 0.027190043753664277
# Converged in iteration 3 with cost 0.02719004375366347 because of step counter
# Final cost : 0.02719004375366347
# Compute control for a deterministic system
# Cost in iteration 0: 0.01756207277701511
# Final cost : 0.017281463718444558
# Compute control for a deterministic system
# Cost in iteration 0: 0.017281463718444558
# Final cost : 0.0171790114673577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0171790114673577
# Converged in iteration 137 with cost 0.017179006052738952 because of step counter
# Final cost : 0.017179006052738952
# Compute control for a deterministic system
# Cost in iteration 0: 0.017179006052738952
# Converged in iteration 5 with cost 0.017179006052736534 because of step counter
# Final cost : 0.017179006052736534
# Compute control for a deterministic system
# Cost in iteration 0: 0.017179006052736534
# Converged in iteration 5 with cost 0.01717900605273601 because of step counter
# Final cost : 0.01717900605273601
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.010651461917332457
# Final cost : 0.009716975018306961
# Compute control for a deterministic system
# Cost in iteration 0: 0.009716975018306961
# Final cost : 0.009677098895277313
# Compute control for a deterministic system
# Cost in iteration 0: 0.009677098895277313
# Converged in iteration 111 with cost 0.00967709607195479 because of step counter
# Final cost : 0.00967709607195479
# Compute control for a deterministic system
# Cost in iteration 0: 0.00967709607195479
# Converged in iteration 11 with cost 0.009677096071949163 because of step counter
# Final cost : 0.009677096071949163
# Compute control for a deterministic system
# Cost in iteration 0: 0.009677096071949163
# Converged in iteration 1 with cost 0.009677096071949163 because of step counter
# Final cost : 0.009677096071949163
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.005022690886338313
# Final cost : 0.0042424411576564396
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042424411576564396
# Final cost : 0.004227832290659973
# Compute control for a deterministic system
# Cost in iteration 0: 0.004227832290659973
# Converged in iteration 137 with cost 0.004227831047665334 because of step counter
# Final cost : 0.004227831047665334
# Compute control for a deterministic system
# Cost in iteration 0: 0.004227831047665334
# Converged in iteration 1 with cost 0.004227831047665334 because of step counter
# Final cost : 0.004227831047665334
# Compute control for a deterministic system
# Cost in iteration 0: 0.004227831047665334
# Converged in iteration 1 with cost 0.004227831047665334 because of step counter
# Final cost : 0.004227831047665334
# Compute control for a deterministic system
# Cost in iteration 0: 0.001098707019297412
# Final cost : 0.0010788492187034393
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010788492187034393
# Final cost : 0.0010734948113275617
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010734948113275617
# Converged in iteration 123 with cost 0.001073494448364621 because of step counter
# Final cost : 0.001073494448364621
# Compute control for a deterministic system
# Cost in iteration 0: 0.001073494448364621
# Converged in iteration 1 with cost 0.001073494448364621 because of step counter
# Final cost : 0.001073494448364621
# Compute control for a deterministic system
# Cost in iteration 0: 0.001073494448364621
# Converged in iteration 1 with cost 0.001073494448364621 because of step counter
# Final cost : 0.001073494448364621
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
