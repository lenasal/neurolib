# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period) # 19.069230769230767

wc.run()
init_min = [wc.exc[0,1234], wc.inh[0,1234]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  18.83291666666667
# minima =  [  234  2117  4000  5884  7767  9650 11534 13417 15300 17184 19067 20950
#  22833 24717 26600 28483 30367 32250 34133 36017 37900 39783 41667 43550
#  45433 47317 49200]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s1_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s1_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 0.95 + 0.1*np.random.random()
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy()
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09416688795393842
# Final cost : 0.04512693052989184
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512693052989184
# Converged in iteration 37 with cost 0.04512691596979147 because of step counter
# Final cost : 0.04512691596979147
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596979147
# Converged in iteration 1 with cost 0.04512691596979147 because of step counter
# Final cost : 0.04512691596979147
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596979147
# Converged in iteration 1 with cost 0.04512691596979147 because of step counter
# Final cost : 0.04512691596979147
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596979147
# Converged in iteration 2 with cost 0.04512691596978729 because of step counter
# Final cost : 0.04512691596978729
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.1287999743943419
# Final cost : 0.07135648105927032
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135648105927032
# Converged in iteration 74 with cost 0.07135479101662894 because of step counter
# Final cost : 0.07135479101662894
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135479101662894
# Converged in iteration 5 with cost 0.07135479101661876 because of step counter
# Final cost : 0.07135479101661876
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135479101661876
# Converged in iteration 1 with cost 0.07135479101661876 because of step counter
# Final cost : 0.07135479101661876
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135479101661876
# Converged in iteration 1 with cost 0.07135479101661876 because of step counter
# Final cost : 0.07135479101661876
# Compute control for a deterministic system
# Cost in iteration 0: 0.1601976048014878
# Final cost : 0.09786989314790157
# Compute control for a deterministic system
# Cost in iteration 0: 0.09786989314790157
# Converged in iteration 29 with cost 0.09785906324225566 because of vanishing difference
# Final cost : 0.09785906324225566
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785906324225566
# Converged in iteration 89 with cost 0.09785900825281017 because of step counter
# Final cost : 0.09785900825281017
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785900825281017
# Converged in iteration 3 with cost 0.09785900825280902 because of step counter
# Final cost : 0.09785900825280902
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785900825280902
# Converged in iteration 2 with cost 0.09785900825280701 because of step counter
# Final cost : 0.09785900825280701
# Compute control for a deterministic system
# Cost in iteration 0: 0.16892267005862643
# Final cost : 0.12364559883826255
# Compute control for a deterministic system
# Cost in iteration 0: 0.12364559883826255
# Converged in iteration 150 with cost 0.12362283864011384 because of step counter
# Final cost : 0.12362283864011384
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864011384
# Converged in iteration 1 with cost 0.12362283864011384 because of step counter
# Final cost : 0.12362283864011384
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864011384
# Converged in iteration 2 with cost 0.12362283864011063 because of step counter
# Final cost : 0.12362283864011063
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864011063
# Converged in iteration 5 with cost 0.12362283864010234 because of step counter
# Final cost : 0.12362283864010234
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.21183381089896208
# Final cost : 0.14850632244219222
# Compute control for a deterministic system
# Cost in iteration 0: 0.14850632244219222
# Converged in iteration 191 with cost 0.1484577776912506 because of step counter
# Final cost : 0.1484577776912506
# Compute control for a deterministic system
# Cost in iteration 0: 0.1484577776912506
# Converged in iteration 10 with cost 0.14845777769121044 because of step counter
# Final cost : 0.14845777769121044
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845777769121044
# Converged in iteration 1 with cost 0.14845777769121044 because of step counter
# Final cost : 0.14845777769121044
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845777769121044
# Converged in iteration 2 with cost 0.14845777769120772 because of step counter
# Final cost : 0.14845777769120772
# Compute control for a deterministic system
# Cost in iteration 0: 0.21556751924025314
# Final cost : 0.17332927898038983
# Compute control for a deterministic system
# Cost in iteration 0: 0.17332927898038983
# Final cost : 0.17326250004612095
# Compute control for a deterministic system
# Cost in iteration 0: 0.17326250004612095
# Converged in iteration 29 with cost 0.17326250004563754 because of step counter
# Final cost : 0.17326250004563754
# Compute control for a deterministic system
# Cost in iteration 0: 0.17326250004563754
# Converged in iteration 2 with cost 0.17326250004563748 because of step counter
# Final cost : 0.17326250004563748
# Compute control for a deterministic system
# Cost in iteration 0: 0.17326250004563748
# Converged in iteration 1 with cost 0.17326250004563748 because of step counter
# Final cost : 0.17326250004563748
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.2561006843122969
# Final cost : 0.1975658834914389
# Compute control for a deterministic system
# Cost in iteration 0: 0.1975658834914389
# Converged in iteration 73 with cost 0.19745438044432936 because of vanishing difference
# Final cost : 0.19745438044432936
# Compute control for a deterministic system
# Cost in iteration 0: 0.19745438044432936
# Converged in iteration 192 with cost 0.19745398208452772 because of step counter
# Final cost : 0.19745398208452772
# Compute control for a deterministic system
# Cost in iteration 0: 0.19745398208452772
# Converged in iteration 3 with cost 0.19745398208452128 because of step counter
# Final cost : 0.19745398208452128
# Compute control for a deterministic system
# Cost in iteration 0: 0.19745398208452128
# Converged in iteration 2 with cost 0.19745398208451864 because of step counter
# Final cost : 0.19745398208451864
# Compute control for a deterministic system
# Cost in iteration 0: 0.2535212697954643
# Final cost : 0.22202528467471044
# Compute control for a deterministic system
# Cost in iteration 0: 0.22202528467471044
# Final cost : 0.22188487754413616
# Compute control for a deterministic system
# Cost in iteration 0: 0.22188487754413616
# Converged in iteration 104 with cost 0.22188487738275153 because of step counter
# Final cost : 0.22188487738275153
# Compute control for a deterministic system
# Cost in iteration 0: 0.22188487738275153
# Converged in iteration 1 with cost 0.22188487738275153 because of step counter
# Final cost : 0.22188487738275153
# Compute control for a deterministic system
# Cost in iteration 0: 0.22188487738275153
# Converged in iteration 1 with cost 0.22188487738275153 because of step counter
# Final cost : 0.22188487738275153
# Compute control for a deterministic system
# Cost in iteration 0: 0.2991941844409678
# Final cost : 0.24698933418467128
# Compute control for a deterministic system
# Cost in iteration 0: 0.24698933418467128
# Final cost : 0.24677550603200155
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677550603200155
# Converged in iteration 160 with cost 0.24677550447508223 because of step counter
# Final cost : 0.24677550447508223
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677550447508223
# Converged in iteration 1 with cost 0.24677550447508223 because of step counter
# Final cost : 0.24677550447508223
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677550447508223
# Converged in iteration 1 with cost 0.24677550447508223 because of step counter
# Final cost : 0.24677550447508223
# Compute control for a deterministic system
# Cost in iteration 0: 0.33182713921978474
# Final cost : 0.2725665687925054
# Compute control for a deterministic system
# Cost in iteration 0: 0.2725665687925054
# Final cost : 0.27225660394781437
# Compute control for a deterministic system
# Cost in iteration 0: 0.27225660394781437
# Final cost : 0.27225659098251126
# Compute control for a deterministic system
# Cost in iteration 0: 0.27225659098251126
# Converged in iteration 1 with cost 0.27225659098251126 because of step counter
# Final cost : 0.27225659098251126
# Compute control for a deterministic system
# Cost in iteration 0: 0.27225659098251126
# Converged in iteration 1 with cost 0.27225659098251126 because of step counter
# Final cost : 0.27225659098251126
# Compute control for a deterministic system
# Cost in iteration 0: 0.36494054551217525
# Final cost : 0.2987972944805699
# Compute control for a deterministic system
# Cost in iteration 0: 0.2987972944805699
# Final cost : 0.2983914350015042
# Compute control for a deterministic system
# Cost in iteration 0: 0.2983914350015042
# Final cost : 0.29839135296162234
# Compute control for a deterministic system
# Cost in iteration 0: 0.29839135296162234
# Converged in iteration 59 with cost 0.29839135296029035 because of step counter
# Final cost : 0.29839135296029035
# Compute control for a deterministic system
# Cost in iteration 0: 0.29839135296029035
# Converged in iteration 1 with cost 0.29839135296029035 because of step counter
# Final cost : 0.29839135296029035
# Compute control for a deterministic system
# Cost in iteration 0: 0.35442492592874625
# Final cost : 0.32566437629234735
# Compute control for a deterministic system
# Cost in iteration 0: 0.32566437629234735
# Final cost : 0.325195747590555
# Compute control for a deterministic system
# Cost in iteration 0: 0.325195747590555
# Final cost : 0.3251955505490984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3251955505490984
# Converged in iteration 88 with cost 0.32519555054570376 because of step counter
# Final cost : 0.32519555054570376
# Compute control for a deterministic system
# Cost in iteration 0: 0.32519555054570376
# Converged in iteration 2 with cost 0.3251955505456994 because of step counter
# Final cost : 0.3251955505456994
# Compute control for a deterministic system
# Cost in iteration 0: 0.4345484412527002
# Final cost : 0.3533120627321435
# Compute control for a deterministic system
# Cost in iteration 0: 0.3533120627321435
# Final cost : 0.3526554928341861
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526554928341861
# Converged in iteration 2 with cost 0.3526552590528455 because of vanishing difference
# Final cost : 0.3526552590528455
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526552590528455
# Final cost : 0.3526546563768231
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526546563768231
# Converged in iteration 62 with cost 0.352654656376135 because of step counter
# Final cost : 0.352654656376135
# Compute control for a deterministic system
# Cost in iteration 0: 0.39753432344738415
# Final cost : 0.3814224924333649
# Compute control for a deterministic system
# Cost in iteration 0: 0.3814224924333649
# Final cost : 0.380738567148791
# Compute control for a deterministic system
# Cost in iteration 0: 0.380738567148791
# Final cost : 0.38073686103777354
# Compute control for a deterministic system
# Cost in iteration 0: 0.38073686103777354
# Converged in iteration 203 with cost 0.3807368607925521 because of step counter
# Final cost : 0.3807368607925521
# Compute control for a deterministic system
# Cost in iteration 0: 0.3807368607925521
# Converged in iteration 28 with cost 0.38073686079199803 because of step counter
# Final cost : 0.38073686079199803
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.5057099753519649
# Final cost : 0.4103455814876807
# Compute control for a deterministic system
# Cost in iteration 0: 0.4103455814876807
# Final cost : 0.40940815155959803
# Compute control for a deterministic system
# Cost in iteration 0: 0.40940815155959803
# Converged in iteration 9 with cost 0.4094054201461923 because of vanishing difference
# Final cost : 0.4094054201461923
# Compute control for a deterministic system
# Cost in iteration 0: 0.4094054201461923
# Final cost : 0.4094031948302125
# Compute control for a deterministic system
# Cost in iteration 0: 0.4094031948302125
# Converged in iteration 217 with cost 0.4094031947778005 because of step counter
# Final cost : 0.4094031947778005
# Compute control for a deterministic system
# Cost in iteration 0: 0.4721829457138487
# Final cost : 0.43958088279162927
# Compute control for a deterministic system
# Cost in iteration 0: 0.43958088279162927
# Final cost : 0.4386208221249359
# Compute control for a deterministic system
# Cost in iteration 0: 0.4386208221249359
# Final cost : 0.43861253279381335
# Compute control for a deterministic system
# Cost in iteration 0: 0.43861253279381335
# Converged in iteration 380 with cost 0.43861252989219823 because of step counter
# Final cost : 0.43861252989219823
# Compute control for a deterministic system
# Cost in iteration 0: 0.43861252989219823
# Converged in iteration 17 with cost 0.4386125298920027 because of step counter
# Final cost : 0.4386125298920027
# Compute control for a deterministic system
# Cost in iteration 0: 0.4839123767334532
# Final cost : 0.46938821842370965
# Compute control for a deterministic system
# Cost in iteration 0: 0.46938821842370965
# Final cost : 0.4683407053417436
# Compute control for a deterministic system
# Cost in iteration 0: 0.4683407053417436
# Final cost : 0.46832572083674423
# Compute control for a deterministic system
# Cost in iteration 0: 0.46832572083674423
# Final cost : 0.46832571223342745
# Compute control for a deterministic system
# Cost in iteration 0: 0.46832571223342745
# Converged in iteration 70 with cost 0.46832571223245956 because of vanishing difference
# Final cost : 0.46832571223245956
# Compute control for a deterministic system
# Cost in iteration 0: 0.6529799005138422
# Final cost : 0.5006444493137776
# Compute control for a deterministic system
# Cost in iteration 0: 0.5006444493137776
# Final cost : 0.4991838500545946
# Compute control for a deterministic system
# Cost in iteration 0: 0.4991838500545946
# Final cost : 0.4991531608326338
# Compute control for a deterministic system
# Cost in iteration 0: 0.4991531608326338
# Final cost : 0.4991531191353204
# Compute control for a deterministic system
# Cost in iteration 0: 0.4991531191353204
# Converged in iteration 205 with cost 0.4991531191130843 because of step counter
# Final cost : 0.4991531191130843
# Compute control for a deterministic system
# Cost in iteration 0: 0.6510303851828012
# Final cost : 0.5313145292611879
# Compute control for a deterministic system
# Cost in iteration 0: 0.5313145292611879
# Final cost : 0.5298214223265563
# Compute control for a deterministic system
# Cost in iteration 0: 0.5298214223265563
# Converged in iteration 62 with cost 0.5297820862342881 because of vanishing difference
# Final cost : 0.5297820862342881
# Compute control for a deterministic system
# Cost in iteration 0: 0.5297820862342881
# Final cost : 0.5297759228230963
# Compute control for a deterministic system
# Cost in iteration 0: 0.5297759228230963
# Converged in iteration 470 with cost 0.5297759190565801 because of vanishing difference
# Final cost : 0.5297759190565801
# Compute control for a deterministic system
# Cost in iteration 0: 0.6195667993249979
# Final cost : 0.5623605371947831
# Compute control for a deterministic system
# Cost in iteration 0: 0.5623605371947831
# Final cost : 0.5608647568468138
# Compute control for a deterministic system
# Cost in iteration 0: 0.5608647568468138
# Converged in iteration 57 with cost 0.5608118117542901 because of vanishing difference
# Final cost : 0.5608118117542901
# Compute control for a deterministic system
# Cost in iteration 0: 0.5608118117542901
# Final cost : 0.560800163103657
# Compute control for a deterministic system
# Cost in iteration 0: 0.560800163103657
# Converged in iteration 820 with cost 0.5608001414549982 because of step counter
# Final cost : 0.5608001414549982
# Compute control for a deterministic system
# Cost in iteration 0: 0.41094304875591253
# Final cost : 0.40830238999179963
# Compute control for a deterministic system
# Cost in iteration 0: 0.40830238999179963
# Final cost : 0.4079707042341314
# Compute control for a deterministic system
# Cost in iteration 0: 0.4079707042341314
# Final cost : 0.4079585731318818
# Compute control for a deterministic system
# Cost in iteration 0: 0.4079585731318818
# Final cost : 0.40795795664832896
# Compute control for a deterministic system
# Cost in iteration 0: 0.40795795664832896
# Final cost : 0.4079579424431958
# Compute control for a deterministic system
# Cost in iteration 0: 0.42979796591397534
# Final cost : 0.38917479491915763
# Compute control for a deterministic system
# Cost in iteration 0: 0.38917479491915763
# Final cost : 0.38882829836107613
# Compute control for a deterministic system
# Cost in iteration 0: 0.38882829836107613
# Final cost : 0.3888189645042812
# Compute control for a deterministic system
# Cost in iteration 0: 0.3888189645042812
# Final cost : 0.3888186620898364
# Compute control for a deterministic system
# Cost in iteration 0: 0.3888186620898364
# Converged in iteration 857 with cost 0.3888186588442388 because of step counter
# Final cost : 0.3888186588442388
# Compute control for a deterministic system
# Cost in iteration 0: 0.37849137736247246
# Final cost : 0.36959005102976394
# Compute control for a deterministic system
# Cost in iteration 0: 0.36959005102976394
# Final cost : 0.36927312124200257
# Compute control for a deterministic system
# Cost in iteration 0: 0.36927312124200257
# Final cost : 0.3692666434773971
# Compute control for a deterministic system
# Cost in iteration 0: 0.3692666434773971
# Final cost : 0.3692665951577167
# Compute control for a deterministic system
# Cost in iteration 0: 0.3692665951577167
# Converged in iteration 566 with cost 0.3692665948374196 because of step counter
# Final cost : 0.3692665948374196
# Compute control for a deterministic system
# Cost in iteration 0: 0.44018349379828725
# Final cost : 0.349615555063118
# Compute control for a deterministic system
# Cost in iteration 0: 0.349615555063118
# Final cost : 0.34928839070699186
# Compute control for a deterministic system
# Cost in iteration 0: 0.34928839070699186
# Final cost : 0.3492841797329585
# Compute control for a deterministic system
# Cost in iteration 0: 0.3492841797329585
# Final cost : 0.3492841613330956
# Compute control for a deterministic system
# Cost in iteration 0: 0.3492841613330956
# Converged in iteration 371 with cost 0.34928416129706136 because of step counter
# Final cost : 0.34928416129706136
# Compute control for a deterministic system
# Cost in iteration 0: 0.3892063403187587
# Final cost : 0.3291599600115623
# Compute control for a deterministic system
# Cost in iteration 0: 0.3291599600115623
# Final cost : 0.3288553891421449
# Compute control for a deterministic system
# Cost in iteration 0: 0.3288553891421449
# Final cost : 0.3288529812495052
# Compute control for a deterministic system
# Cost in iteration 0: 0.3288529812495052
# Converged in iteration 355 with cost 0.3288529809860758 because of step counter
# Final cost : 0.3288529809860758
# Compute control for a deterministic system
# Cost in iteration 0: 0.3288529809860758
# Converged in iteration 1 with cost 0.3288529809860758 because of step counter
# Final cost : 0.3288529809860758
# Compute control for a deterministic system
# Cost in iteration 0: 0.33390385680123646
# Final cost : 0.3082261553720231
# Compute control for a deterministic system
# Cost in iteration 0: 0.3082261553720231
# Final cost : 0.30795414236431606
# Compute control for a deterministic system
# Cost in iteration 0: 0.30795414236431606
# Converged in iteration 190 with cost 0.3079529616401395 because of step counter
# Final cost : 0.3079529616401395
# Compute control for a deterministic system
# Cost in iteration 0: 0.3079529616401395
# Converged in iteration 1 with cost 0.3079529616401395 because of step counter
# Final cost : 0.3079529616401395
# Compute control for a deterministic system
# Cost in iteration 0: 0.3079529616401395
# Converged in iteration 1 with cost 0.3079529616401395 because of step counter
# Final cost : 0.3079529616401395
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.32725163773871224
# Final cost : 0.286814029190945
# Compute control for a deterministic system
# Cost in iteration 0: 0.286814029190945
# Final cost : 0.2865603381467164
# Compute control for a deterministic system
# Cost in iteration 0: 0.2865603381467164
# Final cost : 0.2865598403742864
# Compute control for a deterministic system
# Cost in iteration 0: 0.2865598403742864
# Converged in iteration 328 with cost 0.28655983544686686 because of step counter
# Final cost : 0.28655983544686686
# Compute control for a deterministic system
# Cost in iteration 0: 0.28655983544686686
# Converged in iteration 9 with cost 0.28655983544682584 because of step counter
# Final cost : 0.28655983544682584
# Compute control for a deterministic system
# Cost in iteration 0: 0.2837603010034735
# Final cost : 0.2648577620389196
# Compute control for a deterministic system
# Cost in iteration 0: 0.2648577620389196
# Final cost : 0.2646397727227105
# Compute control for a deterministic system
# Cost in iteration 0: 0.2646397727227105
# Final cost : 0.26463960865385716
# Compute control for a deterministic system
# Cost in iteration 0: 0.26463960865385716
# Converged in iteration 113 with cost 0.2646396076906041 because of vanishing difference
# Final cost : 0.2646396076906041
# Compute control for a deterministic system
# Cost in iteration 0: 0.2646396076906041
# Converged in iteration 159 with cost 0.2646396076789293 because of step counter
# Final cost : 0.2646396076789293
# Compute control for a deterministic system
# Cost in iteration 0: 0.2953686917443479
# Final cost : 0.24234672338128713
# Compute control for a deterministic system
# Cost in iteration 0: 0.24234672338128713
# Final cost : 0.24214164265741583
# Compute control for a deterministic system
# Cost in iteration 0: 0.24214164265741583
# Final cost : 0.24214159693643098
# Compute control for a deterministic system
# Cost in iteration 0: 0.24214159693643098
# Converged in iteration 154 with cost 0.2421415968593475 because of step counter
# Final cost : 0.2421415968593475
# Compute control for a deterministic system
# Cost in iteration 0: 0.2421415968593475
# Converged in iteration 1 with cost 0.2421415968593475 because of step counter
# Final cost : 0.2421415968593475
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.29836567429452404
# Final cost : 0.21870007748902562
# Compute control for a deterministic system
# Cost in iteration 0: 0.21870007748902562
# Final cost : 0.2185095753965882
# Compute control for a deterministic system
# Cost in iteration 0: 0.2185095753965882
# Final cost : 0.21850956638368085
# Compute control for a deterministic system
# Cost in iteration 0: 0.21850956638368085
# Converged in iteration 43 with cost 0.21850956638002214 because of step counter
# Final cost : 0.21850956638002214
# Compute control for a deterministic system
# Cost in iteration 0: 0.21850956638002214
# Converged in iteration 18 with cost 0.2185095663799377 because of step counter
# Final cost : 0.2185095663799377
# Compute control for a deterministic system
# Cost in iteration 0: 0.287978144516889
# Final cost : 0.19486500160476095
# Compute control for a deterministic system
# Cost in iteration 0: 0.19486500160476095
# Final cost : 0.1947099915486577
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947099915486577
# Final cost : 0.1947099903069316
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947099903069316
# Converged in iteration 10 with cost 0.1947099903069114 because of step counter
# Final cost : 0.1947099903069114
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947099903069114
# Converged in iteration 1 with cost 0.1947099903069114 because of step counter
# Final cost : 0.1947099903069114
# -----------------------------------------------
# 0 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.22996558138726952
# Final cost : 0.17042321399103702
# Compute control for a deterministic system
# Cost in iteration 0: 0.17042321399103702
# Final cost : 0.17031005411228003
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005411228003
# Converged in iteration 125 with cost 0.17031005402908328 because of step counter
# Final cost : 0.17031005402908328
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005402908328
# Converged in iteration 1 with cost 0.17031005402908328 because of step counter
# Final cost : 0.17031005402908328
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005402908328
# Converged in iteration 1 with cost 0.17031005402908328 because of step counter
# Final cost : 0.17031005402908328
# Compute control for a deterministic system
# Cost in iteration 0: 0.18056335603713256
# Final cost : 0.14549977278557655
# Compute control for a deterministic system
# Cost in iteration 0: 0.14549977278557655
# Final cost : 0.1454303836750034
# Compute control for a deterministic system
# Cost in iteration 0: 0.1454303836750034
# Converged in iteration 39 with cost 0.14543038367359473 because of step counter
# Final cost : 0.14543038367359473
# Compute control for a deterministic system
# Cost in iteration 0: 0.14543038367359473
# Converged in iteration 18 with cost 0.14543038367351213 because of step counter
# Final cost : 0.14543038367351213
# Compute control for a deterministic system
# Cost in iteration 0: 0.14543038367351213
# Converged in iteration 2 with cost 0.14543038367351027 because of step counter
# Final cost : 0.14543038367351027
# Compute control for a deterministic system
# Cost in iteration 0: 0.17623037825978263
# Final cost : 0.12027073866695964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12027073866695964
# Converged in iteration 194 with cost 0.12023202945311419 because of step counter
# Final cost : 0.12023202945311419
# Compute control for a deterministic system
# Cost in iteration 0: 0.12023202945311419
# Converged in iteration 3 with cost 0.12023202945310713 because of step counter
# Final cost : 0.12023202945310713
# Compute control for a deterministic system
# Cost in iteration 0: 0.12023202945310713
# Converged in iteration 1 with cost 0.12023202945310713 because of step counter
# Final cost : 0.12023202945310713
# Compute control for a deterministic system
# Cost in iteration 0: 0.12023202945310713
# Converged in iteration 2 with cost 0.12023202945310164 because of step counter
# Final cost : 0.12023202945310164
# -----------------------------------------------
# 0 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.14188341408527216
# Final cost : 0.09489587146411929
# Compute control for a deterministic system
# Cost in iteration 0: 0.09489587146411929
# Converged in iteration 125 with cost 0.09488268623970654 because of step counter
# Final cost : 0.09488268623970654
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623970654
# Converged in iteration 1 with cost 0.09488268623970654 because of step counter
# Final cost : 0.09488268623970654
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623970654
# Converged in iteration 1 with cost 0.09488268623970654 because of step counter
# Final cost : 0.09488268623970654
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623970654
# Converged in iteration 1 with cost 0.09488268623970654 because of step counter
# Final cost : 0.09488268623970654
# Compute control for a deterministic system
# Cost in iteration 0: 0.10668875865925591
# Final cost : 0.06956394531545693
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956394531545693
# Converged in iteration 84 with cost 0.06956196841341188 because of step counter
# Final cost : 0.06956196841341188
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956196841341188
# Converged in iteration 1 with cost 0.06956196841341188 because of step counter
# Final cost : 0.06956196841341188
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956196841341188
# Converged in iteration 1 with cost 0.06956196841341188 because of step counter
# Final cost : 0.06956196841341188
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956196841341188
# Converged in iteration 1 with cost 0.06956196841341188 because of step counter
# Final cost : 0.06956196841341188
# -----------------------------------------------
# 0 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.10891818657648163
# Final cost : 0.04452317891543207
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452317891543207
# Converged in iteration 32 with cost 0.04452313214319101 because of step counter
# Final cost : 0.04452313214319101
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214319101
# Converged in iteration 1 with cost 0.04452313214319101 because of step counter
# Final cost : 0.04452313214319101
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214319101
# Converged in iteration 1 with cost 0.04452313214319101 because of step counter
# Final cost : 0.04452313214319101
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214319101
# Converged in iteration 1 with cost 0.04452313214319101 because of step counter
# Final cost : 0.04452313214319101
# Compute control for a deterministic system
# Cost in iteration 0: 0.07162767077087834
# Final cost : 0.02027228486698982
# Compute control for a deterministic system
# Cost in iteration 0: 0.02027228486698982
# Converged in iteration 6 with cost 0.02027228486693381 because of step counter
# Final cost : 0.02027228486693381
# Compute control for a deterministic system
# Cost in iteration 0: 0.02027228486693381
# Converged in iteration 1 with cost 0.02027228486693381 because of step counter
# Final cost : 0.02027228486693381
# Compute control for a deterministic system
# Cost in iteration 0: 0.02027228486693381
# Converged in iteration 1 with cost 0.02027228486693381 because of step counter
# Final cost : 0.02027228486693381
# Compute control for a deterministic system
# Cost in iteration 0: 0.02027228486693381
# Converged in iteration 1 with cost 0.02027228486693381 because of step counter
# Final cost : 0.02027228486693381
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.09557770203069915
# Converged in iteration 65 with cost 0.04452313214318622 because of step counter
# Final cost : 0.04452313214318622
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214318622
# Converged in iteration 2 with cost 0.04452313214318529 because of step counter
# Final cost : 0.04452313214318529
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214318529
# Converged in iteration 1 with cost 0.04452313214318529 because of step counter
# Final cost : 0.04452313214318529
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452313214318529
# Converged in iteration 2 with cost 0.04452313214318481 because of step counter
# Final cost : 0.04452313214318481
# Compute control for a deterministic system
# Cost in iteration 0: 0.11977771114159894
# Converged in iteration 51 with cost 0.06956201637256505 because of vanishing difference
# Final cost : 0.06956201637256505
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956201637256505
# Converged in iteration 66 with cost 0.06956197918253049 because of step counter
# Final cost : 0.06956197918253049
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956197918253049
# Converged in iteration 1 with cost 0.06956197918253049 because of step counter
# Final cost : 0.06956197918253049
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956197918253049
# Converged in iteration 2 with cost 0.06956197918252516 because of step counter
# Final cost : 0.06956197918252516
# Compute control for a deterministic system
# Cost in iteration 0: 0.15073891374077927
# Converged in iteration 154 with cost 0.09488268623970585 because of step counter
# Final cost : 0.09488268623970585
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623970585
# Converged in iteration 3 with cost 0.09488268623969512 because of step counter
# Final cost : 0.09488268623969512
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623969512
# Converged in iteration 2 with cost 0.09488268623968985 because of step counter
# Final cost : 0.09488268623968985
# Compute control for a deterministic system
# Cost in iteration 0: 0.09488268623968985
# Converged in iteration 1 with cost 0.09488268623968985 because of step counter
# Final cost : 0.09488268623968985
# -----------------------------------------------
# 1 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.16316886979735104
# Final cost : 0.12023202945317747
# Compute control for a deterministic system
# Cost in iteration 0: 0.12023202945317747
# Converged in iteration 18 with cost 0.1202320294531042 because of step counter
# Final cost : 0.1202320294531042
# Compute control for a deterministic system
# Cost in iteration 0: 0.1202320294531042
# Converged in iteration 1 with cost 0.1202320294531042 because of step counter
# Final cost : 0.1202320294531042
# Compute control for a deterministic system
# Cost in iteration 0: 0.1202320294531042
# Converged in iteration 1 with cost 0.1202320294531042 because of step counter
# Final cost : 0.1202320294531042
# Compute control for a deterministic system
# Cost in iteration 0: 0.20914907276144085
# Final cost : 0.14543038368652797
# Compute control for a deterministic system
# Cost in iteration 0: 0.14543038368652797
# Converged in iteration 77 with cost 0.14543038367350786 because of step counter
# Final cost : 0.14543038367350786
# Compute control for a deterministic system
# Cost in iteration 0: 0.14543038367350786
# Converged in iteration 3 with cost 0.14543038367350317 because of step counter
# Final cost : 0.14543038367350317
# Compute control for a deterministic system
# Cost in iteration 0: 0.14543038367350317
# Converged in iteration 1 with cost 0.14543038367350317 because of step counter
# Final cost : 0.14543038367350317
# Compute control for a deterministic system
# Cost in iteration 0: 0.22150358903119244
# Final cost : 0.17031005441590777
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005441590777
# Converged in iteration 167 with cost 0.17031005402907107 because of step counter
# Final cost : 0.17031005402907107
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005402907107
# Converged in iteration 1 with cost 0.17031005402907107 because of step counter
# Final cost : 0.17031005402907107
# Compute control for a deterministic system
# Cost in iteration 0: 0.17031005402907107
# Converged in iteration 1 with cost 0.17031005402907107 because of step counter
# Final cost : 0.17031005402907107
# -----------------------------------------------
# 1 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.29183138613030335
# Final cost : 0.1947099947633217
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947099947633217
# Final cost : 0.19470999030728176
# Compute control for a deterministic system
# Cost in iteration 0: 0.19470999030728176
# Converged in iteration 41 with cost 0.19470999030691954 because of step counter
# Final cost : 0.19470999030691954
# Compute control for a deterministic system
# Cost in iteration 0: 0.19470999030691954
# Converged in iteration 1 with cost 0.19470999030691954 because of step counter
# Final cost : 0.19470999030691954
# Compute control for a deterministic system
# Cost in iteration 0: 0.24267032540757716
# Final cost : 0.21850958807905468
# Compute control for a deterministic system
# Cost in iteration 0: 0.21850958807905468
# Final cost : 0.2185095663888781
# Compute control for a deterministic system
# Cost in iteration 0: 0.2185095663888781
# Converged in iteration 52 with cost 0.21850956638003843 because of vanishing difference
# Final cost : 0.21850956638003843
# Compute control for a deterministic system
# Cost in iteration 0: 0.21850956638003843
# Converged in iteration 12 with cost 0.21850956637997773 because of step counter
# Final cost : 0.21850956637997773
# Compute control for a deterministic system
# Cost in iteration 0: 0.2593635741545375
# Final cost : 0.24214169380677056
# Compute control for a deterministic system
# Cost in iteration 0: 0.24214169380677056
# Final cost : 0.24214159702701799
# Compute control for a deterministic system
# Cost in iteration 0: 0.24214159702701799
# Converged in iteration 162 with cost 0.2421415968593973 because of step counter
# Final cost : 0.2421415968593973
# Compute control for a deterministic system
# Cost in iteration 0: 0.2421415968593973
# Converged in iteration 1 with cost 0.2421415968593973 because of step counter
# Final cost : 0.2421415968593973
# Compute control for a deterministic system
# Cost in iteration 0: 0.3400926091368983
# Final cost : 0.2646399420629912
# Compute control for a deterministic system
# Cost in iteration 0: 0.2646399420629912
# Final cost : 0.2646396096131142
# Compute control for a deterministic system
# Cost in iteration 0: 0.2646396096131142
# Converged in iteration 232 with cost 0.26463960767903827 because of step counter
# Final cost : 0.26463960767903827
# Compute control for a deterministic system
# Cost in iteration 0: 0.26463960767903827
# Converged in iteration 13 with cost 0.2646396076789794 because of step counter
# Final cost : 0.2646396076789794
# Compute control for a deterministic system
# Cost in iteration 0: 0.32112787158853195
# Final cost : 0.28656067743833213
# Compute control for a deterministic system
# Cost in iteration 0: 0.28656067743833213
# Final cost : 0.286559844551773
# Compute control for a deterministic system
# Cost in iteration 0: 0.286559844551773
# Converged in iteration 202 with cost 0.2865598354613316 because of vanishing difference
# Final cost : 0.2865598354613316
# Compute control for a deterministic system
# Cost in iteration 0: 0.2865598354613316
# Converged in iteration 148 with cost 0.2865598354471194 because of step counter
# Final cost : 0.2865598354471194
# Compute control for a deterministic system
# Cost in iteration 0: 0.4182723409600783
# Final cost : 0.3079548658161701
# Compute control for a deterministic system
# Cost in iteration 0: 0.3079548658161701
# Converged in iteration 199 with cost 0.30795296164016395 because of step counter
# Final cost : 0.30795296164016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.30795296164016395
# Converged in iteration 1 with cost 0.30795296164016395 because of step counter
# Final cost : 0.30795296164016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.30795296164016395
# Converged in iteration 1 with cost 0.30795296164016395 because of step counter
# Final cost : 0.30795296164016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.4696009215848873
# Final cost : 0.328856543741749
# Compute control for a deterministic system
# Cost in iteration 0: 0.328856543741749
# Final cost : 0.32885298139868296
# Compute control for a deterministic system
# Cost in iteration 0: 0.32885298139868296
# Converged in iteration 368 with cost 0.32885298098625626 because of step counter
# Final cost : 0.32885298098625626
# Compute control for a deterministic system
# Cost in iteration 0: 0.32885298098625626
# Converged in iteration 1 with cost 0.32885298098625626 because of step counter
# Final cost : 0.32885298098625626
# Compute control for a deterministic system
# Cost in iteration 0: 0.4380153818470067
# Final cost : 0.3492897492746423
# Compute control for a deterministic system
# Cost in iteration 0: 0.3492897492746423
# Final cost : 0.3492841688371031
# Compute control for a deterministic system
# Cost in iteration 0: 0.3492841688371031
# Final cost : 0.34928416131109613
# Compute control for a deterministic system
# Cost in iteration 0: 0.34928416131109613
# Converged in iteration 255 with cost 0.3492841612973475 because of step counter
# Final cost : 0.3492841612973475
# Compute control for a deterministic system
# Cost in iteration 0: 0.37239650388187256
# Final cost : 0.36927437733782265
# Compute control for a deterministic system
# Cost in iteration 0: 0.36927437733782265
# Final cost : 0.36926663575988966
# Compute control for a deterministic system
# Cost in iteration 0: 0.36926663575988966
# Final cost : 0.36926659512379284
# Compute control for a deterministic system
# Cost in iteration 0: 0.36926659512379284
# Converged in iteration 561 with cost 0.3692665948373616 because of vanishing difference
# Final cost : 0.3692665948373616
# Compute control for a deterministic system
# Cost in iteration 0: 0.4055683164070993
# Final cost : 0.3888295473628161
# Compute control for a deterministic system
# Cost in iteration 0: 0.3888295473628161
# Final cost : 0.3888189628885786
# Compute control for a deterministic system
# Cost in iteration 0: 0.3888189628885786
# Final cost : 0.3888186621670366
# Compute control for a deterministic system
# Cost in iteration 0: 0.3888186621670366
# Converged in iteration 838 with cost 0.3888186588442637 because of step counter
# Final cost : 0.3888186588442637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5426645925631
# Final cost : 0.40797306698474234
# Compute control for a deterministic system
# Cost in iteration 0: 0.40797306698474234
# Final cost : 0.40795862375176234
# Compute control for a deterministic system
# Cost in iteration 0: 0.40795862375176234
# Final cost : 0.40795795599321305
# Compute control for a deterministic system
# Cost in iteration 0: 0.40795795599321305
# Final cost : 0.40795794244300715
# Compute control for a deterministic system
# Cost in iteration 0: 0.4986850295427379
# Final cost : 0.42671964591924694
# Compute control for a deterministic system
# Cost in iteration 0: 0.42671964591924694
# Final cost : 0.42670343643691233
# Compute control for a deterministic system
# Cost in iteration 0: 0.42670343643691233
# Final cost : 0.4267016517100493
# Compute control for a deterministic system
# Cost in iteration 0: 0.4267016517100493
# Final cost : 0.42670156688762156
# Compute control for a deterministic system
# Cost in iteration 0: 0.4618810924082624
# Final cost : 0.4450872849392855
# Compute control for a deterministic system
# Cost in iteration 0: 0.4450872849392855
# Final cost : 0.44506924590373714
# Compute control for a deterministic system
# Cost in iteration 0: 0.44506924590373714
# Final cost : 0.44506650232576694
# Compute control for a deterministic system
# Cost in iteration 0: 0.44506650232576694
# Final cost : 0.44506629634083733
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.46470865762782515
# Final cost : 0.46309286934929295
# Compute control for a deterministic system
# Cost in iteration 0: 0.46309286934929295
# Final cost : 0.4630728403943001
# Compute control for a deterministic system
# Cost in iteration 0: 0.4630728403943001
# Final cost : 0.4630690408903236
# Compute control for a deterministic system
# Cost in iteration 0: 0.4630690408903236
# Final cost : 0.4630686190610917
# -----------------------------------------------
# 1 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.5480973422746674
# Final cost : 0.4811275023292926
# Compute control for a deterministic system
# Cost in iteration 0: 0.4811275023292926
# Final cost : 0.48110391904713123
# Compute control for a deterministic system
# Cost in iteration 0: 0.48110391904713123
# Final cost : 0.48109790702467875
# Compute control for a deterministic system
# Cost in iteration 0: 0.48109790702467875
# Final cost : 0.4810969326256692
# Compute control for a deterministic system
# Cost in iteration 0: 0.4476397714834446
# Final cost : 0.4386285328187581
# Compute control for a deterministic system
# Cost in iteration 0: 0.4386285328187581
# Final cost : 0.43861254258402665
# Compute control for a deterministic system
# Cost in iteration 0: 0.43861254258402665
# Final cost : 0.4386125298928421
# Compute control for a deterministic system
# Cost in iteration 0: 0.4386125298928421
# Converged in iteration 38 with cost 0.43861252989230753 because of vanishing difference
# Final cost : 0.43861252989230753
# Compute control for a deterministic system
# Cost in iteration 0: 0.4395797689400704
# Final cost : 0.40941198607251916
# Compute control for a deterministic system
# Cost in iteration 0: 0.40941198607251916
# Final cost : 0.4094031313273755
# Compute control for a deterministic system
# Cost in iteration 0: 0.4094031313273755
# Converged in iteration 346 with cost 0.40940312955706437 because of step counter
# Final cost : 0.40940312955706437
# Compute control for a deterministic system
# Cost in iteration 0: 0.40940312955706437
# Converged in iteration 1 with cost 0.40940312955706437 because of step counter
# Final cost : 0.40940312955706437
# Compute control for a deterministic system
# Cost in iteration 0: 0.3858364450942247
# Final cost : 0.38074090740573985
# Compute control for a deterministic system
# Cost in iteration 0: 0.38074090740573985
# Final cost : 0.38073686169363996
# Compute control for a deterministic system
# Cost in iteration 0: 0.38073686169363996
# Converged in iteration 265 with cost 0.3807368607923095 because of step counter
# Final cost : 0.3807368607923095
# Compute control for a deterministic system
# Cost in iteration 0: 0.3807368607923095
# Converged in iteration 3 with cost 0.38073686079229246 because of vanishing difference
# Final cost : 0.38073686079229246
# Compute control for a deterministic system
# Cost in iteration 0: 0.38991942899998183
# Final cost : 0.3526563898043349
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526563898043349
# Final cost : 0.3526545963889162
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526545963889162
# Converged in iteration 182 with cost 0.352654596243903 because of step counter
# Final cost : 0.352654596243903
# Compute control for a deterministic system
# Cost in iteration 0: 0.352654596243903
# Converged in iteration 31 with cost 0.3526545962436059 because of step counter
# Final cost : 0.3526545962436059
# -----------------------------------------------
# 1 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.3338073566536978
# Final cost : 0.3251963325175975
# Compute control for a deterministic system
# Cost in iteration 0: 0.3251963325175975
# Final cost : 0.3251955505684622
# Compute control for a deterministic system
# Cost in iteration 0: 0.3251955505684622
# Converged in iteration 131 with cost 0.325195550545705 because of step counter
# Final cost : 0.325195550545705
# Compute control for a deterministic system
# Cost in iteration 0: 0.325195550545705
# Converged in iteration 1 with cost 0.325195550545705 because of step counter
# Final cost : 0.325195550545705
# Compute control for a deterministic system
# Cost in iteration 0: 0.3833193428508191
# Final cost : 0.2983917039841224
# Compute control for a deterministic system
# Cost in iteration 0: 0.2983917039841224
# Final cost : 0.2983913608898455
# Compute control for a deterministic system
# Cost in iteration 0: 0.2983913608898455
# Converged in iteration 90 with cost 0.2983913608838986 because of vanishing difference
# Final cost : 0.2983913608838986
# Compute control for a deterministic system
# Cost in iteration 0: 0.2983913608838986
# Converged in iteration 3 with cost 0.29839136088388146 because of step counter
# Final cost : 0.29839136088388146
# Compute control for a deterministic system
# Cost in iteration 0: 0.3462153802616099
# Converged in iteration 170 with cost 0.27225703787131295 because of vanishing difference
# Final cost : 0.27225703787131295
# Compute control for a deterministic system
# Cost in iteration 0: 0.27225703787131295
# Final cost : 0.27225659706906996
# Compute control for a deterministic system
# Cost in iteration 0: 0.27225659706906996
# Converged in iteration 78 with cost 0.2722565970649331 because of step counter
# Final cost : 0.2722565970649331
# Compute control for a deterministic system
# Cost in iteration 0: 0.2722565970649331
# Converged in iteration 3 with cost 0.27225659706492766 because of step counter
# Final cost : 0.27225659706492766
# Compute control for a deterministic system
# Cost in iteration 0: 0.2726309507017235
# Final cost : 0.24677551281995141
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677551281995141
# Converged in iteration 199 with cost 0.24677550447507451 because of step counter
# Final cost : 0.24677550447507451
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677550447507451
# Converged in iteration 1 with cost 0.24677550447507451 because of step counter
# Final cost : 0.24677550447507451
# Compute control for a deterministic system
# Cost in iteration 0: 0.24677550447507451
# Converged in iteration 2 with cost 0.24677550447507407 because of step counter
# Final cost : 0.24677550447507407
# Compute control for a deterministic system
# Cost in iteration 0: 0.24231334684158823
# Final cost : 0.2218848785005793
# Compute control for a deterministic system
# Cost in iteration 0: 0.2218848785005793
# Converged in iteration 134 with cost 0.2218848773827464 because of step counter
# Final cost : 0.2218848773827464
# Compute control for a deterministic system
# Cost in iteration 0: 0.2218848773827464
# Converged in iteration 1 with cost 0.2218848773827464 because of step counter
# Final cost : 0.2218848773827464
# Compute control for a deterministic system
# Cost in iteration 0: 0.2218848773827464
# Converged in iteration 11 with cost 0.22188487738269044 because of step counter
# Final cost : 0.22188487738269044
# -----------------------------------------------
# 1 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.22464534191935462
# Final cost : 0.19745397639253498
# Compute control for a deterministic system
# Cost in iteration 0: 0.19745397639253498
# Converged in iteration 96 with cost 0.1974539762906235 because of step counter
# Final cost : 0.1974539762906235
# Compute control for a deterministic system
# Cost in iteration 0: 0.1974539762906235
# Converged in iteration 1 with cost 0.1974539762906235 because of step counter
# Final cost : 0.1974539762906235
# Compute control for a deterministic system
# Cost in iteration 0: 0.1974539762906235
# Converged in iteration 2 with cost 0.19745397629062256 because of step counter
# Final cost : 0.19745397629062256
# Compute control for a deterministic system
# Cost in iteration 0: 0.23359486163328597
# Final cost : 0.1732625000514503
# Compute control for a deterministic system
# Cost in iteration 0: 0.1732625000514503
# Converged in iteration 62 with cost 0.17326250004562951 because of step counter
# Final cost : 0.17326250004562951
# Compute control for a deterministic system
# Cost in iteration 0: 0.17326250004562951
# Converged in iteration 1 with cost 0.17326250004562951 because of step counter
# Final cost : 0.17326250004562951
# Compute control for a deterministic system
# Cost in iteration 0: 0.17326250004562951
# Converged in iteration 1 with cost 0.17326250004562951 because of step counter
# Final cost : 0.17326250004562951
# -----------------------------------------------
# 1 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.23456367354433288
# Final cost : 0.14845777383400993
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845777383400993
# Converged in iteration 19 with cost 0.14845777383387218 because of step counter
# Final cost : 0.14845777383387218
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845777383387218
# Converged in iteration 1 with cost 0.14845777383387218 because of step counter
# Final cost : 0.14845777383387218
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845777383387218
# Converged in iteration 1 with cost 0.14845777383387218 because of step counter
# Final cost : 0.14845777383387218
# Compute control for a deterministic system
# Cost in iteration 0: 0.15836375485576765
# Converged in iteration 171 with cost 0.12362283864013593 because of step counter
# Final cost : 0.12362283864013593
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864013593
# Converged in iteration 10 with cost 0.12362283864009524 because of step counter
# Final cost : 0.12362283864009524
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864009524
# Converged in iteration 1 with cost 0.12362283864009524 because of step counter
# Final cost : 0.12362283864009524
# Compute control for a deterministic system
# Cost in iteration 0: 0.12362283864009524
# Converged in iteration 1 with cost 0.12362283864009524 because of step counter
# Final cost : 0.12362283864009524
# -----------------------------------------------
# 1 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.15100802600160243
# Converged in iteration 141 with cost 0.09785899946859619 because of step counter
# Final cost : 0.09785899946859619
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785899946859619
# Converged in iteration 1 with cost 0.09785899946859619 because of step counter
# Final cost : 0.09785899946859619
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785899946859619
# Converged in iteration 2 with cost 0.09785899946859611 because of step counter
# Final cost : 0.09785899946859611
# Compute control for a deterministic system
# Cost in iteration 0: 0.09785899946859611
# Converged in iteration 2 with cost 0.09785899946859566 because of step counter
# Final cost : 0.09785899946859566
# Compute control for a deterministic system
# Cost in iteration 0: 0.14087459106094705
# Converged in iteration 105 with cost 0.07135478655340179 because of step counter
# Final cost : 0.07135478655340179
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135478655340179
# Converged in iteration 3 with cost 0.07135478655339707 because of step counter
# Final cost : 0.07135478655339707
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135478655339707
# Converged in iteration 1 with cost 0.07135478655339707 because of step counter
# Final cost : 0.07135478655339707
# Compute control for a deterministic system
# Cost in iteration 0: 0.07135478655339707
# Converged in iteration 1 with cost 0.07135478655339707 because of step counter
# Final cost : 0.07135478655339707
# -----------------------------------------------
# 1 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.08695238254472355
# Converged in iteration 62 with cost 0.04512691596980008 because of step counter
# Final cost : 0.04512691596980008
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596980008
# Converged in iteration 4 with cost 0.04512691596979695 because of step counter
# Final cost : 0.04512691596979695
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596979695
# Converged in iteration 1 with cost 0.04512691596979695 because of step counter
# Final cost : 0.04512691596979695
# Compute control for a deterministic system
# Cost in iteration 0: 0.04512691596979695
# Converged in iteration 1 with cost 0.04512691596979695 because of step counter
# Final cost : 0.04512691596979695
# Compute control for a deterministic system
# Cost in iteration 0: 0.08217772520499125
# Converged in iteration 31 with cost 0.0202351890241067 because of step counter
# Final cost : 0.0202351890241067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0202351890241067
# Converged in iteration 1 with cost 0.0202351890241067 because of step counter
# Final cost : 0.0202351890241067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0202351890241067
# Converged in iteration 1 with cost 0.0202351890241067 because of step counter
# Final cost : 0.0202351890241067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0202351890241067
# Converged in iteration 1 with cost 0.0202351890241067 because of step counter
# Final cost : 0.0202351890241067
# -----------------------------------------------
# 1 found better solution,  1

# %%
save(results_min)
