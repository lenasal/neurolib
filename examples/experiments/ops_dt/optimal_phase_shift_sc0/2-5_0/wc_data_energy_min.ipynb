# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1234], wc.inh[0,1234]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  234  2117  4000  5884  7767  9650 11534 13417 15300 17184 19067 20950
#  22833 24717 26600 28483]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s1_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s1_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)


            save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037413936027206506
# Final cost : 0.0003715081000573049
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003715081000573049
# Converged in iteration 796 with cost 0.00037149949156166763 because of step counter
# Final cost : 0.00037149949156166763
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037149949156166763
# Converged in iteration 32 with cost 0.000371499491552427 because of step counter
# Final cost : 0.000371499491552427
# Compute control for a deterministic system
# Cost in iteration 0: 0.000371499491552427
# Converged in iteration 1 with cost 0.000371499491552427 because of step counter
# Final cost : 0.000371499491552427
# Compute control for a deterministic system
# Cost in iteration 0: 0.000371499491552427
# Converged in iteration 1 with cost 0.000371499491552427 because of step counter
# Final cost : 0.000371499491552427
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.001741604560339349
# Final cost : 0.0015137528309109606
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015137528309109606
# Final cost : 0.0015135419955996294
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015135419955996294
# Converged in iteration 37 with cost 0.001513541995572395 because of step counter
# Final cost : 0.001513541995572395
# Compute control for a deterministic system
# Cost in iteration 0: 0.001513541995572395
# Converged in iteration 1 with cost 0.001513541995572395 because of step counter
# Final cost : 0.001513541995572395
# Compute control for a deterministic system
# Cost in iteration 0: 0.001513541995572395
# Converged in iteration 1 with cost 0.001513541995572395 because of step counter
# Final cost : 0.001513541995572395
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035428926091867047
# Final cost : 0.003459268091644483
# Compute control for a deterministic system
# Cost in iteration 0: 0.003459268091644483
# Converged in iteration 759 with cost 0.0034591408214996277 because of step counter
# Final cost : 0.0034591408214996277
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034591408214996277
# Converged in iteration 11 with cost 0.003459140821491706 because of step counter
# Final cost : 0.003459140821491706
# Compute control for a deterministic system
# Cost in iteration 0: 0.003459140821491706
# Converged in iteration 6 with cost 0.0034591408214693503 because of step counter
# Final cost : 0.0034591408214693503
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034591408214693503
# Converged in iteration 2 with cost 0.0034591408214692046 because of step counter
# Final cost : 0.0034591408214692046
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.0072049380211659676
# Final cost : 0.006185913001820783
# Compute control for a deterministic system
# Cost in iteration 0: 0.006185913001820783
# Converged in iteration 751 with cost 0.006184619489612802 because of step counter
# Final cost : 0.006184619489612802
# Compute control for a deterministic system
# Cost in iteration 0: 0.006184619489612802
# Converged in iteration 19 with cost 0.006184619489568588 because of step counter
# Final cost : 0.006184619489568588
# Compute control for a deterministic system
# Cost in iteration 0: 0.006184619489568588
# Converged in iteration 3 with cost 0.006184619489567729 because of step counter
# Final cost : 0.006184619489567729
# Compute control for a deterministic system
# Cost in iteration 0: 0.006184619489567729
# Converged in iteration 8 with cost 0.006184619489560951 because of step counter
# Final cost : 0.006184619489560951
# Compute control for a deterministic system
# Cost in iteration 0: 0.009750752728828216
# Final cost : 0.00957540984467903
# Compute control for a deterministic system
# Cost in iteration 0: 0.00957540984467903
# Converged in iteration 717 with cost 0.00957479015860849 because of vanishing difference
# Final cost : 0.00957479015860849
# Compute control for a deterministic system
# Cost in iteration 0: 0.00957479015860849
# Converged in iteration 12 with cost 0.009574790158568026 because of step counter
# Final cost : 0.009574790158568026
# Compute control for a deterministic system
# Cost in iteration 0: 0.009574790158568026
# Converged in iteration 14 with cost 0.00957479015852642 because of step counter
# Final cost : 0.00957479015852642
# Compute control for a deterministic system
# Cost in iteration 0: 0.00957479015852642
# Converged in iteration 2 with cost 0.009574790158526336 because of step counter
# Final cost : 0.009574790158526336
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.01549505581814055
# Final cost : 0.013482433577370173
# Compute control for a deterministic system
# Cost in iteration 0: 0.013482433577370173
# Final cost : 0.01347827801471864
# Compute control for a deterministic system
# Cost in iteration 0: 0.01347827801471864
# Converged in iteration 79 with cost 0.013478278014143422 because of vanishing difference
# Final cost : 0.013478278014143422
# Compute control for a deterministic system
# Cost in iteration 0: 0.013478278014143422
# Converged in iteration 2 with cost 0.013478278014143235 because of step counter
# Final cost : 0.013478278014143235
# Compute control for a deterministic system
# Cost in iteration 0: 0.013478278014143235
# Converged in iteration 17 with cost 0.013478278014130707 because of step counter
# Final cost : 0.013478278014130707
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.019733706728283774
# Final cost : 0.017882795602088497
# Compute control for a deterministic system
# Cost in iteration 0: 0.017882795602088497
# Final cost : 0.017881338627208095
# Compute control for a deterministic system
# Cost in iteration 0: 0.017881338627208095
# Converged in iteration 80 with cost 0.017881338626449406 because of step counter
# Final cost : 0.017881338626449406
# Compute control for a deterministic system
# Cost in iteration 0: 0.017881338626449406
# Converged in iteration 2 with cost 0.01788133862644896 because of step counter
# Final cost : 0.01788133862644896
# Compute control for a deterministic system
# Cost in iteration 0: 0.01788133862644896
# Converged in iteration 1 with cost 0.01788133862644896 because of step counter
# Final cost : 0.01788133862644896
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.022722184804398922
# Final cost : 0.022576309449117416
# Compute control for a deterministic system
# Cost in iteration 0: 0.022576309449117416
# Converged in iteration 748 with cost 0.022573157711955144 because of step counter
# Final cost : 0.022573157711955144
# Compute control for a deterministic system
# Cost in iteration 0: 0.022573157711955144
# Converged in iteration 36 with cost 0.022573157711841815 because of step counter
# Final cost : 0.022573157711841815
# Compute control for a deterministic system
# Cost in iteration 0: 0.022573157711841815
# Converged in iteration 1 with cost 0.022573157711841815 because of step counter
# Final cost : 0.022573157711841815
# Compute control for a deterministic system
# Cost in iteration 0: 0.022573157711841815
# Converged in iteration 1 with cost 0.022573157711841815 because of step counter
# Final cost : 0.022573157711841815
# Compute control for a deterministic system
# Cost in iteration 0: 0.03214919455423554
# Final cost : 0.02770973715188362
# Compute control for a deterministic system
# Cost in iteration 0: 0.02770973715188362
# Final cost : 0.027694496768944622
# Compute control for a deterministic system
# Cost in iteration 0: 0.027694496768944622
# Converged in iteration 196 with cost 0.027694496708951646 because of step counter
# Final cost : 0.027694496708951646
# Compute control for a deterministic system
# Cost in iteration 0: 0.027694496708951646
# Converged in iteration 1 with cost 0.027694496708951646 because of step counter
# Final cost : 0.027694496708951646
# Compute control for a deterministic system
# Cost in iteration 0: 0.027694496708951646
# Converged in iteration 1 with cost 0.027694496708951646 because of step counter
# Final cost : 0.027694496708951646
# Compute control for a deterministic system
# Cost in iteration 0: 0.03860465418278888
# Final cost : 0.033353341288943524
# Compute control for a deterministic system
# Cost in iteration 0: 0.033353341288943524
# Final cost : 0.03334789676325134
# Compute control for a deterministic system
# Cost in iteration 0: 0.03334789676325134
# Converged in iteration 192 with cost 0.0333478966424244 because of step counter
# Final cost : 0.0333478966424244
# Compute control for a deterministic system
# Cost in iteration 0: 0.0333478966424244
# Converged in iteration 1 with cost 0.0333478966424244 because of step counter
# Final cost : 0.0333478966424244
# Compute control for a deterministic system
# Cost in iteration 0: 0.0333478966424244
# Converged in iteration 1 with cost 0.0333478966424244 because of step counter
# Final cost : 0.0333478966424244
# Compute control for a deterministic system
# Cost in iteration 0: 0.04157952899370536
# Final cost : 0.03967366503547915
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967366503547915
# Final cost : 0.03965093738254917
# Compute control for a deterministic system
# Cost in iteration 0: 0.03965093738254917
# Converged in iteration 215 with cost 0.03965093717103749 because of step counter
# Final cost : 0.03965093717103749
# Compute control for a deterministic system
# Cost in iteration 0: 0.03965093717103749
# Converged in iteration 1 with cost 0.03965093717103749 because of step counter
# Final cost : 0.03965093717103749
# Compute control for a deterministic system
# Cost in iteration 0: 0.03965093717103749
# Converged in iteration 1 with cost 0.03965093717103749 because of step counter
# Final cost : 0.03965093717103749
# Compute control for a deterministic system
# Cost in iteration 0: 0.05418500693275837
# Final cost : 0.04672304631049974
# Compute control for a deterministic system
# Cost in iteration 0: 0.04672304631049974
# Final cost : 0.046710711491523275
# Compute control for a deterministic system
# Cost in iteration 0: 0.046710711491523275
# Converged in iteration 163 with cost 0.046710711455188264 because of step counter
# Final cost : 0.046710711455188264
# Compute control for a deterministic system
# Cost in iteration 0: 0.046710711455188264
# Converged in iteration 1 with cost 0.046710711455188264 because of step counter
# Final cost : 0.046710711455188264
# Compute control for a deterministic system
# Cost in iteration 0: 0.046710711455188264
# Converged in iteration 1 with cost 0.046710711455188264 because of step counter
# Final cost : 0.046710711455188264
# Compute control for a deterministic system
# Cost in iteration 0: 0.0741685754815088
# Final cost : 0.05462298333469117
# Compute control for a deterministic system
# Cost in iteration 0: 0.05462298333469117
# Final cost : 0.054610707441289555
# Compute control for a deterministic system
# Cost in iteration 0: 0.054610707441289555
# Converged in iteration 206 with cost 0.054610707327601406 because of step counter
# Final cost : 0.054610707327601406
# Compute control for a deterministic system
# Cost in iteration 0: 0.054610707327601406
# Converged in iteration 21 with cost 0.054610707327559085 because of step counter
# Final cost : 0.054610707327559085
# Compute control for a deterministic system
# Cost in iteration 0: 0.054610707327559085
# Converged in iteration 1 with cost 0.054610707327559085 because of step counter
# Final cost : 0.054610707327559085
# Compute control for a deterministic system
# Cost in iteration 0: 0.06505915314480001
# Final cost : 0.06344249512012741
# Compute control for a deterministic system
# Cost in iteration 0: 0.06344249512012741
# Final cost : 0.0634080704274514
# Compute control for a deterministic system
# Cost in iteration 0: 0.0634080704274514
# Converged in iteration 212 with cost 0.06340807037963941 because of step counter
# Final cost : 0.06340807037963941
# Compute control for a deterministic system
# Cost in iteration 0: 0.06340807037963941
# Converged in iteration 1 with cost 0.06340807037963941 because of step counter
# Final cost : 0.06340807037963941
# Compute control for a deterministic system
# Cost in iteration 0: 0.06340807037963941
# Converged in iteration 1 with cost 0.06340807037963941 because of step counter
# Final cost : 0.06340807037963941
# Compute control for a deterministic system
# Cost in iteration 0: 0.07711732804716508
# Final cost : 0.0731747470421752
# Compute control for a deterministic system
# Cost in iteration 0: 0.0731747470421752
# Final cost : 0.07313731185277504
# Compute control for a deterministic system
# Cost in iteration 0: 0.07313731185277504
# Converged in iteration 209 with cost 0.07313731183121733 because of step counter
# Final cost : 0.07313731183121733
# Compute control for a deterministic system
# Cost in iteration 0: 0.07313731183121733
# Converged in iteration 2 with cost 0.07313731183121618 because of step counter
# Final cost : 0.07313731183121618
# Compute control for a deterministic system
# Cost in iteration 0: 0.07313731183121618
# Converged in iteration 1 with cost 0.07313731183121618 because of step counter
# Final cost : 0.07313731183121618
# Compute control for a deterministic system
# Cost in iteration 0: 0.08857675050149026
# Final cost : 0.0838977958169653
# Compute control for a deterministic system
# Cost in iteration 0: 0.0838977958169653
# Final cost : 0.08381656521473964
# Compute control for a deterministic system
# Cost in iteration 0: 0.08381656521473964
# Converged in iteration 287 with cost 0.0838165651033653 because of step counter
# Final cost : 0.0838165651033653
# Compute control for a deterministic system
# Cost in iteration 0: 0.0838165651033653
# Converged in iteration 1 with cost 0.0838165651033653 because of step counter
# Final cost : 0.0838165651033653
# Compute control for a deterministic system
# Cost in iteration 0: 0.0838165651033653
# Converged in iteration 5 with cost 0.08381656510336108 because of step counter
# Final cost : 0.08381656510336108
# Compute control for a deterministic system
# Cost in iteration 0: 0.09784420143941773
# Final cost : 0.0955150797881737
# Compute control for a deterministic system
# Cost in iteration 0: 0.0955150797881737
# Final cost : 0.09545359131040201
# Compute control for a deterministic system
# Cost in iteration 0: 0.09545359131040201
# Converged in iteration 256 with cost 0.09545359124813657 because of step counter
# Final cost : 0.09545359124813657
# Compute control for a deterministic system
# Cost in iteration 0: 0.09545359124813657
# Converged in iteration 3 with cost 0.0954535912481342 because of step counter
# Final cost : 0.0954535912481342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954535912481342
# Converged in iteration 1 with cost 0.0954535912481342 because of step counter
# Final cost : 0.0954535912481342
# Compute control for a deterministic system
# Cost in iteration 0: 0.11236300894075342
# Final cost : 0.1081140582876634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1081140582876634
# Final cost : 0.10805015359452268
# Compute control for a deterministic system
# Cost in iteration 0: 0.10805015359452268
# Converged in iteration 290 with cost 0.10805015352701593 because of step counter
# Final cost : 0.10805015352701593
# Compute control for a deterministic system
# Cost in iteration 0: 0.10805015352701593
# Converged in iteration 1 with cost 0.10805015352701593 because of step counter
# Final cost : 0.10805015352701593
# Compute control for a deterministic system
# Cost in iteration 0: 0.10805015352701593
# Converged in iteration 1 with cost 0.10805015352701593 because of step counter
# Final cost : 0.10805015352701593
# Compute control for a deterministic system
# Cost in iteration 0: 0.11363012320052213
# Final cost : 0.10658784087554365
# Compute control for a deterministic system
# Cost in iteration 0: 0.10658784087554365
# Final cost : 0.10655649616863992
# Compute control for a deterministic system
# Cost in iteration 0: 0.10655649616863992
# Converged in iteration 769 with cost 0.106556489966322 because of step counter
# Final cost : 0.106556489966322
# Compute control for a deterministic system
# Cost in iteration 0: 0.106556489966322
# Converged in iteration 1 with cost 0.106556489966322 because of step counter
# Final cost : 0.106556489966322
# Compute control for a deterministic system
# Cost in iteration 0: 0.106556489966322
# Converged in iteration 1 with cost 0.106556489966322 because of step counter
# Final cost : 0.106556489966322
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.1089954654316988
# Final cost : 0.09857995422957275
# Compute control for a deterministic system
# Cost in iteration 0: 0.09857995422957275
# Final cost : 0.09856132668107884
# Compute control for a deterministic system
# Cost in iteration 0: 0.09856132668107884
# Converged in iteration 389 with cost 0.09856132422228295 because of step counter
# Final cost : 0.09856132422228295
# Compute control for a deterministic system
# Cost in iteration 0: 0.09856132422228295
# Converged in iteration 1 with cost 0.09856132422228295 because of step counter
# Final cost : 0.09856132422228295
# Compute control for a deterministic system
# Cost in iteration 0: 0.09856132422228295
# Converged in iteration 1 with cost 0.09856132422228295 because of step counter
# Final cost : 0.09856132422228295
# Compute control for a deterministic system
# Cost in iteration 0: 0.09938688336199222
# Final cost : 0.09076295589174943
# Compute control for a deterministic system
# Cost in iteration 0: 0.09076295589174943
# Final cost : 0.090736658431617
# Compute control for a deterministic system
# Cost in iteration 0: 0.090736658431617
# Converged in iteration 490 with cost 0.09073665590220954 because of step counter
# Final cost : 0.09073665590220954
# Compute control for a deterministic system
# Cost in iteration 0: 0.09073665590220954
# Converged in iteration 13 with cost 0.09073665590194573 because of step counter
# Final cost : 0.09073665590194573
# Compute control for a deterministic system
# Cost in iteration 0: 0.09073665590194573
# Converged in iteration 1 with cost 0.09073665590194573 because of step counter
# Final cost : 0.09073665590194573
# Compute control for a deterministic system
# Cost in iteration 0: 0.08882147164112263
# Final cost : 0.08310898634644506
# Compute control for a deterministic system
# Cost in iteration 0: 0.08310898634644506
# Final cost : 0.08309423181636885
# Compute control for a deterministic system
# Cost in iteration 0: 0.08309423181636885
# Converged in iteration 370 with cost 0.08309422977841195 because of vanishing difference
# Final cost : 0.08309422977841195
# Compute control for a deterministic system
# Cost in iteration 0: 0.08309422977841195
# Converged in iteration 2 with cost 0.08309422977841098 because of step counter
# Final cost : 0.08309422977841098
# Compute control for a deterministic system
# Cost in iteration 0: 0.08309422977841098
# Converged in iteration 5 with cost 0.08309422977840306 because of step counter
# Final cost : 0.08309422977840306
# Compute control for a deterministic system
# Cost in iteration 0: 0.12244081405396909
# Final cost : 0.07565814209243675
# Compute control for a deterministic system
# Cost in iteration 0: 0.07565814209243675
# Final cost : 0.0756471101278521
# Compute control for a deterministic system
# Cost in iteration 0: 0.0756471101278521
# Converged in iteration 589 with cost 0.07564710826146023 because of step counter
# Final cost : 0.07564710826146023
# Compute control for a deterministic system
# Cost in iteration 0: 0.07564710826146023
# Converged in iteration 1 with cost 0.07564710826146023 because of step counter
# Final cost : 0.07564710826146023
# Compute control for a deterministic system
# Cost in iteration 0: 0.07564710826146023
# Converged in iteration 1 with cost 0.07564710826146023 because of step counter
# Final cost : 0.07564710826146023
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757373853393114
# Final cost : 0.06842441444068999
# Compute control for a deterministic system
# Cost in iteration 0: 0.06842441444068999
# Final cost : 0.06840970039394813
# Compute control for a deterministic system
# Cost in iteration 0: 0.06840970039394813
# Converged in iteration 274 with cost 0.06840969909627587 because of step counter
# Final cost : 0.06840969909627587
# Compute control for a deterministic system
# Cost in iteration 0: 0.06840969909627587
# Converged in iteration 1 with cost 0.06840969909627587 because of step counter
# Final cost : 0.06840969909627587
# Compute control for a deterministic system
# Cost in iteration 0: 0.06840969909627587
# Converged in iteration 41 with cost 0.06840969909606764 because of step counter
# Final cost : 0.06840969909606764
# Compute control for a deterministic system
# Cost in iteration 0: 0.0685739003103746
# Final cost : 0.061408250029540944
# Compute control for a deterministic system
# Cost in iteration 0: 0.061408250029540944
# Final cost : 0.0613978384184293
# Compute control for a deterministic system
# Cost in iteration 0: 0.0613978384184293
# Converged in iteration 266 with cost 0.061397837459025 because of vanishing difference
# Final cost : 0.061397837459025
# Compute control for a deterministic system
# Cost in iteration 0: 0.061397837459025
# Converged in iteration 23 with cost 0.061397837458992174 because of step counter
# Final cost : 0.061397837458992174
# Compute control for a deterministic system
# Cost in iteration 0: 0.061397837458992174
# Converged in iteration 1 with cost 0.061397837458992174 because of step counter
# Final cost : 0.061397837458992174
# Compute control for a deterministic system
# Cost in iteration 0: 0.07238613555706844
# Final cost : 0.05463815821114493
# Compute control for a deterministic system
# Cost in iteration 0: 0.05463815821114493
# Final cost : 0.05462888200128597
# Compute control for a deterministic system
# Cost in iteration 0: 0.05462888200128597
# Converged in iteration 201 with cost 0.054628881483992954 because of step counter
# Final cost : 0.054628881483992954
# Compute control for a deterministic system
# Cost in iteration 0: 0.054628881483992954
# Converged in iteration 8 with cost 0.0546288814839741 because of step counter
# Final cost : 0.0546288814839741
# Compute control for a deterministic system
# Cost in iteration 0: 0.0546288814839741
# Converged in iteration 1 with cost 0.0546288814839741 because of step counter
# Final cost : 0.0546288814839741
# Compute control for a deterministic system
# Cost in iteration 0: 0.05420967553425044
# Final cost : 0.04812636653062552
# Compute control for a deterministic system
# Cost in iteration 0: 0.04812636653062552
# Final cost : 0.04812178402268397
# Compute control for a deterministic system
# Cost in iteration 0: 0.04812178402268397
# Converged in iteration 178 with cost 0.048121783813405594 because of step counter
# Final cost : 0.048121783813405594
# Compute control for a deterministic system
# Cost in iteration 0: 0.048121783813405594
# Converged in iteration 23 with cost 0.048121783813373196 because of step counter
# Final cost : 0.048121783813373196
# Compute control for a deterministic system
# Cost in iteration 0: 0.048121783813373196
# Converged in iteration 1 with cost 0.048121783813373196 because of step counter
# Final cost : 0.048121783813373196
# Compute control for a deterministic system
# Cost in iteration 0: 0.05024899416022879
# Final cost : 0.04190037566301729
# Compute control for a deterministic system
# Cost in iteration 0: 0.04190037566301729
# Final cost : 0.0418970895054021
# Compute control for a deterministic system
# Cost in iteration 0: 0.0418970895054021
# Converged in iteration 151 with cost 0.04189708943214423 because of step counter
# Final cost : 0.04189708943214423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04189708943214423
# Converged in iteration 1 with cost 0.04189708943214423 because of step counter
# Final cost : 0.04189708943214423
# Compute control for a deterministic system
# Cost in iteration 0: 0.04189708943214423
# Converged in iteration 1 with cost 0.04189708943214423 because of step counter
# Final cost : 0.04189708943214423
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.05620508131929548
# Final cost : 0.03597966004525094
# Compute control for a deterministic system
# Cost in iteration 0: 0.03597966004525094
# Final cost : 0.035976805454274036
# Compute control for a deterministic system
# Cost in iteration 0: 0.035976805454274036
# Converged in iteration 298 with cost 0.03597680539148207 because of step counter
# Final cost : 0.03597680539148207
# Compute control for a deterministic system
# Cost in iteration 0: 0.03597680539148207
# Converged in iteration 2 with cost 0.03597680539148147 because of step counter
# Final cost : 0.03597680539148147
# Compute control for a deterministic system
# Cost in iteration 0: 0.03597680539148147
# Converged in iteration 1 with cost 0.03597680539148147 because of step counter
# Final cost : 0.03597680539148147
# Compute control for a deterministic system
# Cost in iteration 0: 0.03040619337110212
# Final cost : 0.030384914635423626
# Compute control for a deterministic system
# Cost in iteration 0: 0.030384914635423626
# Final cost : 0.030384281552053288
# Compute control for a deterministic system
# Cost in iteration 0: 0.030384281552053288
# Converged in iteration 83 with cost 0.030384281547572126 because of step counter
# Final cost : 0.030384281547572126
# Compute control for a deterministic system
# Cost in iteration 0: 0.030384281547572126
# Converged in iteration 12 with cost 0.030384281547558657 because of step counter
# Final cost : 0.030384281547558657
# Compute control for a deterministic system
# Cost in iteration 0: 0.030384281547558657
# Converged in iteration 2 with cost 0.030384281547558064 because of step counter
# Final cost : 0.030384281547558064
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.03313790042827554
# Final cost : 0.02503919801793442
# Compute control for a deterministic system
# Cost in iteration 0: 0.02503919801793442
# Final cost : 0.025037724792117473
# Compute control for a deterministic system
# Cost in iteration 0: 0.025037724792117473
# Converged in iteration 180 with cost 0.02503772477752154 because of step counter
# Final cost : 0.02503772477752154
# Compute control for a deterministic system
# Cost in iteration 0: 0.02503772477752154
# Converged in iteration 1 with cost 0.02503772477752154 because of step counter
# Final cost : 0.02503772477752154
# Compute control for a deterministic system
# Cost in iteration 0: 0.02503772477752154
# Converged in iteration 1 with cost 0.02503772477752154 because of step counter
# Final cost : 0.02503772477752154
# Compute control for a deterministic system
# Cost in iteration 0: 0.020509983962284827
# Final cost : 0.0201919618108789
# Compute control for a deterministic system
# Cost in iteration 0: 0.0201919618108789
# Final cost : 0.0201914682390227
# Compute control for a deterministic system
# Cost in iteration 0: 0.0201914682390227
# Converged in iteration 88 with cost 0.020191468237409648 because of vanishing difference
# Final cost : 0.020191468237409648
# Compute control for a deterministic system
# Cost in iteration 0: 0.020191468237409648
# Converged in iteration 1 with cost 0.020191468237409648 because of step counter
# Final cost : 0.020191468237409648
# Compute control for a deterministic system
# Cost in iteration 0: 0.020191468237409648
# Converged in iteration 1 with cost 0.020191468237409648 because of step counter
# Final cost : 0.020191468237409648
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.01628835359736189
# Final cost : 0.015768319752577517
# Compute control for a deterministic system
# Cost in iteration 0: 0.015768319752577517
# Final cost : 0.01576790568497687
# Compute control for a deterministic system
# Cost in iteration 0: 0.01576790568497687
# Converged in iteration 71 with cost 0.015767905683647228 because of step counter
# Final cost : 0.015767905683647228
# Compute control for a deterministic system
# Cost in iteration 0: 0.015767905683647228
# Converged in iteration 1 with cost 0.015767905683647228 because of step counter
# Final cost : 0.015767905683647228
# Compute control for a deterministic system
# Cost in iteration 0: 0.015767905683647228
# Converged in iteration 1 with cost 0.015767905683647228 because of step counter
# Final cost : 0.015767905683647228
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.01237189979767868
# Final cost : 0.01180890656843743
# Compute control for a deterministic system
# Cost in iteration 0: 0.01180890656843743
# Final cost : 0.011808526652033247
# Compute control for a deterministic system
# Cost in iteration 0: 0.011808526652033247
# Converged in iteration 91 with cost 0.011808526650592413 because of step counter
# Final cost : 0.011808526650592413
# Compute control for a deterministic system
# Cost in iteration 0: 0.011808526650592413
# Converged in iteration 1 with cost 0.011808526650592413 because of step counter
# Final cost : 0.011808526650592413
# Compute control for a deterministic system
# Cost in iteration 0: 0.011808526650592413
# Converged in iteration 1 with cost 0.011808526650592413 because of step counter
# Final cost : 0.011808526650592413
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.009563197994622198
# Final cost : 0.008355956320662444
# Compute control for a deterministic system
# Cost in iteration 0: 0.008355956320662444
# Final cost : 0.008355276596469442
# Compute control for a deterministic system
# Cost in iteration 0: 0.008355276596469442
# Converged in iteration 126 with cost 0.008355276592963808 because of step counter
# Final cost : 0.008355276592963808
# Compute control for a deterministic system
# Cost in iteration 0: 0.008355276592963808
# Converged in iteration 7 with cost 0.008355276592959576 because of step counter
# Final cost : 0.008355276592959576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008355276592959576
# Converged in iteration 1 with cost 0.008355276592959576 because of step counter
# Final cost : 0.008355276592959576
# Compute control for a deterministic system
# Cost in iteration 0: 0.006724817426491258
# Final cost : 0.005448336980018927
# Compute control for a deterministic system
# Cost in iteration 0: 0.005448336980018927
# Final cost : 0.005447812630835985
# Compute control for a deterministic system
# Cost in iteration 0: 0.005447812630835985
# Converged in iteration 92 with cost 0.005447812629609489 because of step counter
# Final cost : 0.005447812629609489
# Compute control for a deterministic system
# Cost in iteration 0: 0.005447812629609489
# Converged in iteration 1 with cost 0.005447812629609489 because of step counter
# Final cost : 0.005447812629609489
# Compute control for a deterministic system
# Cost in iteration 0: 0.005447812629609489
# Converged in iteration 1 with cost 0.005447812629609489 because of step counter
# Final cost : 0.005447812629609489
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032062358614036624
# Final cost : 0.0031231594172902713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031231594172902713
# Final cost : 0.003123040105599659
# Compute control for a deterministic system
# Cost in iteration 0: 0.003123040105599659
# Converged in iteration 46 with cost 0.0031230401053674007 because of step counter
# Final cost : 0.0031230401053674007
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031230401053674007
# Converged in iteration 8 with cost 0.0031230401053519504 because of step counter
# Final cost : 0.0031230401053519504
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031230401053519504
# Converged in iteration 3 with cost 0.0031230401053514126 because of step counter
# Final cost : 0.0031230401053514126
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014647952867051723
# Final cost : 0.0014164075988354944
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014164075988354944
# Final cost : 0.00141632128801279
# Compute control for a deterministic system
# Cost in iteration 0: 0.00141632128801279
# Converged in iteration 56 with cost 0.0014163212878543165 because of step counter
# Final cost : 0.0014163212878543165
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014163212878543165
# Converged in iteration 2 with cost 0.001416321287854291 because of step counter
# Final cost : 0.001416321287854291
# Compute control for a deterministic system
# Cost in iteration 0: 0.001416321287854291
# Converged in iteration 1 with cost 0.001416321287854291 because of step counter
# Final cost : 0.001416321287854291
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004142595515916639
# Final cost : 0.00036308745953773084
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036308745953773084
# Final cost : 0.0003630550961883754
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003630550961883754
# Converged in iteration 28 with cost 0.00036305509617050313 because of step counter
# Final cost : 0.00036305509617050313
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036305509617050313
# Converged in iteration 1 with cost 0.00036305509617050313 because of step counter
# Final cost : 0.00036305509617050313
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036305509617050313
# Converged in iteration 2 with cost 0.0003630550961704822 because of step counter
# Final cost : 0.0003630550961704822

# %%
save(results_min)
