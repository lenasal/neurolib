# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1650], wc.inh[0,1650]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  314  2155  4000  5845  7691  9536 11381 13227 15072 16918 18763 20608
#  22454 24299 26144 27990 29835]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s0_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s0_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("a_s0_l1.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s0_l1.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, False, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor =  (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor =  (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.02011141545082858
# Converged in iteration 134 with cost 0.02010177968069852 because of step counter
# Final cost : 0.02010177968069852
# Compute control for a deterministic system
# Cost in iteration 0: 0.02010177968069852
# Converged in iteration 10 with cost 0.020101779680692076 because of step counter
# Final cost : 0.020101779680692076
# Compute control for a deterministic system
# Cost in iteration 0: 0.020101779680692076
# Converged in iteration 1 with cost 0.020101779680692076 because of step counter
# Final cost : 0.020101779680692076
# Compute control for a deterministic system
# Cost in iteration 0: 0.020101779680692076
# Converged in iteration 1 with cost 0.020101779680692076 because of step counter
# Final cost : 0.020101779680692076
# Compute control for a deterministic system
# Cost in iteration 0: 0.020101779680692076
# Converged in iteration 1 with cost 0.020101779680692076 because of step counter
# Final cost : 0.020101779680692076
# -----------------------------------------------
# 5 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.04634451735321182
# Cost in iteration 200: 0.04629799071020735
# Final cost : 0.04629799071020735
# Compute control for a deterministic system
# Cost in iteration 0: 0.04629799071020735
# Converged in iteration 18 with cost 0.046297990696715696 because of step counter
# Final cost : 0.046297990696715696
# Compute control for a deterministic system
# Cost in iteration 0: 0.046297990696715696
# Converged in iteration 2 with cost 0.04629799069671521 because of step counter
# Final cost : 0.04629799069671521
# Compute control for a deterministic system
# Cost in iteration 0: 0.04629799069671521
# Converged in iteration 2 with cost 0.04629799069671401 because of step counter
# Final cost : 0.04629799069671401
# Compute control for a deterministic system
# Cost in iteration 0: 0.04629799069671401
# Converged in iteration 1 with cost 0.04629799069671401 because of step counter
# Final cost : 0.04629799069671401
# -----------------------------------------------
# 5 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.07357892917719853
# Cost in iteration 200: 0.07329331839962548
# Final cost : 0.07329331839962548
# Compute control for a deterministic system
# Cost in iteration 0: 0.07329331839962548
# Converged in iteration 50 with cost 0.07329331526294135 because of vanishing difference
# Final cost : 0.07329331526294135
# Compute control for a deterministic system
# Cost in iteration 0: 0.07329331526294135
# Converged in iteration 8 with cost 0.07329331526293521 because of step counter
# Final cost : 0.07329331526293521
# Compute control for a deterministic system
# Cost in iteration 0: 0.07329331526293521
# Converged in iteration 1 with cost 0.07329331526293521 because of step counter
# Final cost : 0.07329331526293521
# Compute control for a deterministic system
# Cost in iteration 0: 0.07329331526293521
# Converged in iteration 1 with cost 0.07329331526293521 because of step counter
# Final cost : 0.07329331526293521
# -----------------------------------------------
# 5 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.10217614127867514
# Cost in iteration 200: 0.10135275981126615
# Final cost : 0.10135275981126615
# Compute control for a deterministic system
# Cost in iteration 0: 0.10135275981126615
# Converged in iteration 87 with cost 0.10135271785623662 because of step counter
# Final cost : 0.10135271785623662
# Compute control for a deterministic system
# Cost in iteration 0: 0.10135271785623662
# Converged in iteration 6 with cost 0.10135271785622789 because of step counter
# Final cost : 0.10135271785622789
# Compute control for a deterministic system
# Cost in iteration 0: 0.10135271785622789
# Converged in iteration 1 with cost 0.10135271785622789 because of step counter
# Final cost : 0.10135271785622789
# Compute control for a deterministic system
# Cost in iteration 0: 0.10135271785622789
# Converged in iteration 1 with cost 0.10135271785622789 because of step counter
# Final cost : 0.10135271785622789
# -----------------------------------------------
# 5 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.13072247815785737
# Cost in iteration 200: 0.12907008817862642
# Final cost : 0.12907008817862642
# Compute control for a deterministic system
# Cost in iteration 0: 0.12907008817862642
# Converged in iteration 140 with cost 0.12906990253638062 because of step counter
# Final cost : 0.12906990253638062
# Compute control for a deterministic system
# Cost in iteration 0: 0.12906990253638062
# Converged in iteration 5 with cost 0.12906990253637743 because of step counter
# Final cost : 0.12906990253637743
# Compute control for a deterministic system
# Cost in iteration 0: 0.12906990253637743
# Converged in iteration 1 with cost 0.12906990253637743 because of step counter
# Final cost : 0.12906990253637743
# Compute control for a deterministic system
# Cost in iteration 0: 0.12906990253637743
# Converged in iteration 1 with cost 0.12906990253637743 because of step counter
# Final cost : 0.12906990253637743
# -----------------------------------------------
# 5 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.15741077667580736
# Cost in iteration 200: 0.1568935906374911
# Final cost : 0.1568935906374911
# Compute control for a deterministic system
# Cost in iteration 0: 0.1568935906374911
# Converged in iteration 146 with cost 0.15689351775850535 because of step counter
# Final cost : 0.15689351775850535
# Compute control for a deterministic system
# Cost in iteration 0: 0.15689351775850535
# Converged in iteration 7 with cost 0.15689351775846208 because of step counter
# Final cost : 0.15689351775846208
# Compute control for a deterministic system
# Cost in iteration 0: 0.15689351775846208
# Converged in iteration 2 with cost 0.1568935177584619 because of step counter
# Final cost : 0.1568935177584619
# Compute control for a deterministic system
# Cost in iteration 0: 0.1568935177584619
# Converged in iteration 1 with cost 0.1568935177584619 because of step counter
# Final cost : 0.1568935177584619
# -----------------------------------------------
# 5 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.18795222303786357
# Cost in iteration 200: 0.18471513712809018
# Final cost : 0.18471513712809018
# Compute control for a deterministic system
# Cost in iteration 0: 0.18471513712809018
# Cost in iteration 200: 0.1847142943595578
# Final cost : 0.1847142943595578
# Compute control for a deterministic system
# Cost in iteration 0: 0.1847142943595578
# Converged in iteration 11 with cost 0.18471429435928793 because of step counter
# Final cost : 0.18471429435928793
# Compute control for a deterministic system
# Cost in iteration 0: 0.18471429435928793
# Converged in iteration 2 with cost 0.18471429435928663 because of step counter
# Final cost : 0.18471429435928663
# Compute control for a deterministic system
# Cost in iteration 0: 0.18471429435928663
# Converged in iteration 1 with cost 0.18471429435928663 because of step counter
# Final cost : 0.18471429435928663
# -----------------------------------------------
# 5 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.21342365973659683
# Cost in iteration 200: 0.21244180138817828
# Final cost : 0.21244180138817828
# Compute control for a deterministic system
# Cost in iteration 0: 0.21244180138817828
# Cost in iteration 200: 0.21244157709840114
# Final cost : 0.21244157709840114
# Compute control for a deterministic system
# Cost in iteration 0: 0.21244157709840114
# Converged in iteration 15 with cost 0.2124415770975297 because of step counter
# Final cost : 0.2124415770975297
# Compute control for a deterministic system
# Cost in iteration 0: 0.2124415770975297
# Converged in iteration 2 with cost 0.21244157709752967 because of step counter
# Final cost : 0.21244157709752967
# Compute control for a deterministic system
# Cost in iteration 0: 0.21244157709752967
# Converged in iteration 1 with cost 0.21244157709752967 because of step counter
# Final cost : 0.21244157709752967
# -----------------------------------------------
# 5 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.24345269599667108
# Cost in iteration 200: 0.23999400864906073
# Final cost : 0.23999400864906073
# Compute control for a deterministic system
# Cost in iteration 0: 0.23999400864906073
# Converged in iteration 48 with cost 0.23999288832068896 because of vanishing difference
# Final cost : 0.23999288832068896
# Compute control for a deterministic system
# Cost in iteration 0: 0.23999288832068896
# Converged in iteration 165 with cost 0.23999284034477653 because of vanishing difference
# Final cost : 0.23999284034477653
# Compute control for a deterministic system
# Cost in iteration 0: 0.23999284034477653
# Converged in iteration 6 with cost 0.23999284034475707 because of step counter
# Final cost : 0.23999284034475707
# Compute control for a deterministic system
# Cost in iteration 0: 0.23999284034475707
# Converged in iteration 2 with cost 0.2399928403447562 because of step counter
# Final cost : 0.2399928403447562
# Compute control for a deterministic system
# Cost in iteration 0: 0.2734960634406345
# Cost in iteration 200: 0.267288179154142
# Final cost : 0.267288179154142
# Compute control for a deterministic system
# Cost in iteration 0: 0.267288179154142
# Cost in iteration 200: 0.2672863825369327
# Final cost : 0.2672863825369327
# Compute control for a deterministic system
# Cost in iteration 0: 0.2672863825369327
# Converged in iteration 126 with cost 0.2672863823510495 because of step counter
# Final cost : 0.2672863823510495
# Compute control for a deterministic system
# Cost in iteration 0: 0.2672863823510495
# Converged in iteration 8 with cost 0.26728638235104263 because of step counter
# Final cost : 0.26728638235104263
# Compute control for a deterministic system
# Cost in iteration 0: 0.26728638235104263
# Converged in iteration 1 with cost 0.26728638235104263 because of step counter
# Final cost : 0.26728638235104263
# -----------------------------------------------
# 5 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.296279571750975
# Cost in iteration 200: 0.29423577444371546
# Final cost : 0.29423577444371546
# Compute control for a deterministic system
# Cost in iteration 0: 0.29423577444371546
# Cost in iteration 200: 0.294235107803377
# Final cost : 0.294235107803377
# Compute control for a deterministic system
# Cost in iteration 0: 0.294235107803377
# Converged in iteration 146 with cost 0.2942351075916322 because of step counter
# Final cost : 0.2942351075916322
# Compute control for a deterministic system
# Cost in iteration 0: 0.2942351075916322
# Converged in iteration 1 with cost 0.2942351075916322 because of step counter
# Final cost : 0.2942351075916322
# Compute control for a deterministic system
# Cost in iteration 0: 0.2942351075916322
# Converged in iteration 1 with cost 0.2942351075916322 because of step counter
# Final cost : 0.2942351075916322
# -----------------------------------------------
# 5 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.32397748112683145
# Cost in iteration 200: 0.3213108226507814
# Final cost : 0.3213108226507814
# Compute control for a deterministic system
# Cost in iteration 0: 0.3213108226507814
# Cost in iteration 200: 0.3213097538425297
# Final cost : 0.3213097538425297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3213097538425297
# Cost in iteration 200: 0.32130975300851605
# Final cost : 0.32130975300851605
# Compute control for a deterministic system
# Cost in iteration 0: 0.32130975300851605
# Converged in iteration 8 with cost 0.3213097530084539 because of step counter
# Final cost : 0.3213097530084539
# Compute control for a deterministic system
# Cost in iteration 0: 0.3213097530084539
# Converged in iteration 3 with cost 0.3213097530084514 because of step counter
# Final cost : 0.3213097530084514
# -----------------------------------------------
# 5 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.35039544541548434
# Cost in iteration 200: 0.3472343128151756
# Final cost : 0.3472343128151756
# Compute control for a deterministic system
# Cost in iteration 0: 0.3472343128151756
# Cost in iteration 200: 0.3472331363322751
# Final cost : 0.3472331363322751
# Compute control for a deterministic system
# Cost in iteration 0: 0.3472331363322751
# Cost in iteration 200: 0.347233135006196
# Final cost : 0.347233135006196
# Compute control for a deterministic system
# Cost in iteration 0: 0.347233135006196
# Converged in iteration 50 with cost 0.3472331350056199 because of step counter
# Final cost : 0.3472331350056199
# Compute control for a deterministic system
# Cost in iteration 0: 0.3472331350056199
# Converged in iteration 2 with cost 0.34723313500561925 because of step counter
# Final cost : 0.34723313500561925
# -----------------------------------------------
# 5 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.3737492895158291
# Cost in iteration 200: 0.37242247707669607
# Final cost : 0.37242247707669607
# Compute control for a deterministic system
# Cost in iteration 0: 0.37242247707669607
# Cost in iteration 200: 0.37242198767723017
# Final cost : 0.37242198767723017
# Compute control for a deterministic system
# Cost in iteration 0: 0.37242198767723017
# Cost in iteration 200: 0.37242198678058186
# Final cost : 0.37242198678058186
# Compute control for a deterministic system
# Cost in iteration 0: 0.37242198678058186
# Converged in iteration 42 with cost 0.3724219867789614 because of vanishing difference
# Final cost : 0.3724219867789614
# Compute control for a deterministic system
# Cost in iteration 0: 0.3724219867789614
# Converged in iteration 2 with cost 0.37242198677895744 because of step counter
# Final cost : 0.37242198677895744
# -----------------------------------------------
# 5 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.3966321920252415
# Cost in iteration 200: 0.3966320609086098
# Final cost : 0.3966320609086098
# Compute control for a deterministic system
# Cost in iteration 0: 0.3966320609086098
# Converged in iteration 178 with cost 0.39663206086473723 because of step counter
# Final cost : 0.39663206086473723
# Compute control for a deterministic system
# Cost in iteration 0: 0.39663206086473723
# Converged in iteration 9 with cost 0.3966320608646143 because of step counter
# Final cost : 0.3966320608646143
# Compute control for a deterministic system
# Cost in iteration 0: 0.3966320608646143
# Converged in iteration 6 with cost 0.3966320608646064 because of step counter
# Final cost : 0.3966320608646064
# Compute control for a deterministic system
# Cost in iteration 0: 0.3966320608646064
# Converged in iteration 7 with cost 0.39663206086459485 because of step counter
# Final cost : 0.39663206086459485
# -----------------------------------------------
# 5 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.43087778011420397
# Cost in iteration 200: 0.4194500463797363
# Final cost : 0.4194500463797363
# Compute control for a deterministic system
# Cost in iteration 0: 0.4194500463797363
# Cost in iteration 200: 0.41944591052389885
# Final cost : 0.41944591052389885
# Compute control for a deterministic system
# Cost in iteration 0: 0.41944591052389885
# Cost in iteration 200: 0.4194458991857124
# Final cost : 0.4194458991857124
# Compute control for a deterministic system
# Cost in iteration 0: 0.4194458991857124
# Cost in iteration 200: 0.41944589891806716
# Converged in iteration 216 with cost 0.4194458989180111 because of step counter
# Final cost : 0.4194458989180111
# Compute control for a deterministic system
# Cost in iteration 0: 0.4194458989180111
# Converged in iteration 1 with cost 0.4194458989180111 because of step counter
# Final cost : 0.4194458989180111
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.45586171669906445
# Cost in iteration 200: 0.4399945614522854
# Final cost : 0.4399945614522854
# Compute control for a deterministic system
# Cost in iteration 0: 0.4399945614522854
# Cost in iteration 200: 0.4399918241477433
# Final cost : 0.4399918241477433
# Compute control for a deterministic system
# Cost in iteration 0: 0.4399918241477433
# Cost in iteration 200: 0.439991800146858
# Final cost : 0.439991800146858
# Compute control for a deterministic system
# Cost in iteration 0: 0.439991800146858
# Cost in iteration 200: 0.4399917994413389
# Cost in iteration 400: 0.43999179937568644
# Final cost : 0.43999179937568644
# Compute control for a deterministic system
# Cost in iteration 0: 0.43999179937568644
# Cost in iteration 200: 0.4399917993697
# Converged in iteration 279 with cost 0.4399917993691771 because of step counter
# Final cost : 0.4399917993691771
# Compute control for a deterministic system
# Cost in iteration 0: 0.4695643796470649
# Cost in iteration 200: 0.4559690055301578
# Final cost : 0.4559690055301578
# Compute control for a deterministic system
# Cost in iteration 0: 0.4559690055301578
# Converged in iteration 55 with cost 0.4559680599831544 because of vanishing difference
# Final cost : 0.4559680599831544
# Compute control for a deterministic system
# Cost in iteration 0: 0.4559680599831544
# Cost in iteration 200: 0.45596798216575585
# Final cost : 0.45596798216575585
# Compute control for a deterministic system
# Cost in iteration 0: 0.45596798216575585
# Cost in iteration 200: 0.4559679743515434
# Cost in iteration 400: 0.45596797328282396
# Final cost : 0.45596797328282396
# Compute control for a deterministic system
# Cost in iteration 0: 0.45596797328282396
# Cost in iteration 200: 0.4559679731318787
# Cost in iteration 400: 0.45596797308253334
# Cost in iteration 600: 0.4559679730659646
# Cost in iteration 800: 0.45596797306063663
# Cost in iteration 1000: 0.4559679730587677
# Final cost : 0.4559679730587677
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.4837988501489837
# Cost in iteration 200: 0.46672137128873875
# Final cost : 0.46672137128873875
# Compute control for a deterministic system
# Cost in iteration 0: 0.46672137128873875
# Converged in iteration 42 with cost 0.4667208616967255 because of vanishing difference
# Final cost : 0.4667208616967255
# Compute control for a deterministic system
# Cost in iteration 0: 0.4667208616967255
# Cost in iteration 200: 0.46672070770360524
# Final cost : 0.46672070770360524
# Compute control for a deterministic system
# Cost in iteration 0: 0.46672070770360524
# Cost in iteration 200: 0.4667206980418687
# Cost in iteration 400: 0.46672069715444997
# Final cost : 0.46672069715444997
# Compute control for a deterministic system
# Cost in iteration 0: 0.46672069715444997
# Cost in iteration 200: 0.46672069704054703
# Cost in iteration 400: 0.46672069700155566
# Cost in iteration 600: 0.4667206969873601
# Converged in iteration 618 with cost 0.4667206969866148 because of vanishing difference
# Final cost : 0.4667206969866148
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.5196192299929452
# Cost in iteration 200: 0.4741579419110441
# Final cost : 0.4741579419110441
# Compute control for a deterministic system
# Cost in iteration 0: 0.4741579419110441
# Cost in iteration 200: 0.4741572491551342
# Final cost : 0.4741572491551342
# Compute control for a deterministic system
# Cost in iteration 0: 0.4741572491551342
# Cost in iteration 200: 0.4741572136199709
# Final cost : 0.4741572136199709
# Compute control for a deterministic system
# Cost in iteration 0: 0.4741572136199709
# Cost in iteration 200: 0.4741572031862662
# Cost in iteration 400: 0.4741572026063943
# Final cost : 0.4741572026063943
# Compute control for a deterministic system
# Cost in iteration 0: 0.4741572026063943
# Cost in iteration 200: 0.47415720257182903
# Cost in iteration 400: 0.4741572025531863
# Cost in iteration 600: 0.47415720254280236
# Cost in iteration 800: 0.4741572025370382
# Cost in iteration 1000: 0.47415720253390603
# Final cost : 0.47415720253390603
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.6971209513794443
# Cost in iteration 200: 0.4795591007897601
# Final cost : 0.4795591007897601
# Compute control for a deterministic system
# Cost in iteration 0: 0.4795591007897601
# Cost in iteration 200: 0.4795529093889613
# Final cost : 0.4795529093889613
# Compute control for a deterministic system
# Cost in iteration 0: 0.4795529093889613
# Cost in iteration 200: 0.47955258883318835
# Final cost : 0.47955258883318835
# Compute control for a deterministic system
# Cost in iteration 0: 0.47955258883318835
# Cost in iteration 200: 0.4795524831277786
# Cost in iteration 400: 0.4795524369668901
# Final cost : 0.4795524369668901
# Compute control for a deterministic system
# Cost in iteration 0: 0.4795524369668901
# Cost in iteration 200: 0.4795524002939681
# Cost in iteration 400: 0.4795523933443116
# Cost in iteration 600: 0.47955239159971064
# Cost in iteration 800: 0.4795523910155965
# Cost in iteration 1000: 0.479552390805804
# Final cost : 0.479552390805804
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.48356160263576575
# Cost in iteration 200: 0.48355271631795993
# Final cost : 0.48355271631795993
# Compute control for a deterministic system
# Cost in iteration 0: 0.48355271631795993
# Cost in iteration 200: 0.48355270065929157
# Final cost : 0.48355270065929157
# Compute control for a deterministic system
# Cost in iteration 0: 0.48355270065929157
# Cost in iteration 200: 0.48355268263205
# Final cost : 0.48355268263205
# Compute control for a deterministic system
# Cost in iteration 0: 0.48355268263205
# Cost in iteration 200: 0.4835526742373219
# Cost in iteration 400: 0.4835526680267232
# Final cost : 0.4835526680267232
# Compute control for a deterministic system
# Cost in iteration 0: 0.4835526680267232
# Cost in iteration 200: 0.48355266392548507
# Cost in iteration 400: 0.48355266059040664
# Cost in iteration 600: 0.48355265785777746
# Cost in iteration 800: 0.48355265560384986
# Cost in iteration 1000: 0.48355265373546175
# Final cost : 0.48355265373546175
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.7810631234620786
# Cost in iteration 200: 0.4893139344360636
# Final cost : 0.4893139344360636
# Compute control for a deterministic system
# Cost in iteration 0: 0.4893139344360636
# Cost in iteration 200: 0.48676894812942423
# Final cost : 0.48676894812942423
# Compute control for a deterministic system
# Cost in iteration 0: 0.48676894812942423
# Converged in iteration 21 with cost 0.4867684541040997 because of vanishing difference
# Final cost : 0.4867684541040997
# Compute control for a deterministic system
# Cost in iteration 0: 0.4867684541040997
# Cost in iteration 200: 0.4867655968979814
# Cost in iteration 400: 0.4867648041698025
# Final cost : 0.4867648041698025
# Compute control for a deterministic system
# Cost in iteration 0: 0.4867648041698025
# Cost in iteration 200: 0.48676449599407123
# Cost in iteration 400: 0.48676425806404494
# Cost in iteration 600: 0.4867640731482431
# Cost in iteration 800: 0.48676392147739267
# Cost in iteration 1000: 0.48676379195038444
# Final cost : 0.48676379195038444
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.4951493725448763
# Cost in iteration 200: 0.4742654968434994
# Final cost : 0.4742654968434994
# Compute control for a deterministic system
# Cost in iteration 0: 0.4742654968434994
# Converged in iteration 79 with cost 0.4742591845296391 because of vanishing difference
# Final cost : 0.4742591845296391
# Compute control for a deterministic system
# Cost in iteration 0: 0.4742591845296391
# Cost in iteration 200: 0.4742588283154875
# Final cost : 0.4742588283154875
# Compute control for a deterministic system
# Cost in iteration 0: 0.4742588283154875
# Cost in iteration 200: 0.47425881523613794
# Converged in iteration 357 with cost 0.4742588150276403 because of vanishing difference
# Final cost : 0.4742588150276403
# Compute control for a deterministic system
# Cost in iteration 0: 0.4742588150276403
# Cost in iteration 200: 0.474258815019054
# Converged in iteration 260 with cost 0.4742588150187532 because of vanishing difference
# Final cost : 0.4742588150187532
# Compute control for a deterministic system
# Cost in iteration 0: 0.4462506299177345
# Cost in iteration 200: 0.4391785313048357
# Final cost : 0.4391785313048357
# Compute control for a deterministic system
# Cost in iteration 0: 0.4391785313048357
# Cost in iteration 200: 0.43917594281011024
# Final cost : 0.43917594281011024
# Compute control for a deterministic system
# Cost in iteration 0: 0.43917594281011024
# Cost in iteration 200: 0.43917592909139813
# Final cost : 0.43917592909139813
# Compute control for a deterministic system
# Cost in iteration 0: 0.43917592909139813
# Cost in iteration 200: 0.43917592878776573
# Converged in iteration 301 with cost 0.4391759287858289 because of step counter
# Final cost : 0.4391759287858289
# Compute control for a deterministic system
# Cost in iteration 0: 0.4391759287858289
# Converged in iteration 1 with cost 0.4391759287858289 because of step counter
# Final cost : 0.4391759287858289
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.4144121715975568
# Cost in iteration 200: 0.40443781125037276
# Final cost : 0.40443781125037276
# Compute control for a deterministic system
# Cost in iteration 0: 0.40443781125037276
# Cost in iteration 200: 0.4044340616611555
# Final cost : 0.4044340616611555
# Compute control for a deterministic system
# Cost in iteration 0: 0.4044340616611555
# Cost in iteration 200: 0.40443405019958295
# Final cost : 0.40443405019958295
# Compute control for a deterministic system
# Cost in iteration 0: 0.40443405019958295
# Cost in iteration 200: 0.4044340501007548
# Converged in iteration 204 with cost 0.40443405010075234 because of step counter
# Final cost : 0.40443405010075234
# Compute control for a deterministic system
# Cost in iteration 0: 0.40443405010075234
# Converged in iteration 1 with cost 0.40443405010075234 because of step counter
# Final cost : 0.40443405010075234
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.37581784648715655
# Cost in iteration 200: 0.3715558648748809
# Final cost : 0.3715558648748809
# Compute control for a deterministic system
# Cost in iteration 0: 0.3715558648748809
# Cost in iteration 200: 0.371554326153897
# Final cost : 0.371554326153897
# Compute control for a deterministic system
# Cost in iteration 0: 0.371554326153897
# Cost in iteration 200: 0.37155432334101574
# Final cost : 0.37155432334101574
# Compute control for a deterministic system
# Cost in iteration 0: 0.37155432334101574
# Converged in iteration 109 with cost 0.371554323334132 because of step counter
# Final cost : 0.371554323334132
# Compute control for a deterministic system
# Cost in iteration 0: 0.371554323334132
# Converged in iteration 1 with cost 0.371554323334132 because of vanishing difference
# Final cost : 0.371554323334132
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.3403949623839093
# Cost in iteration 200: 0.33965418615387694
# Final cost : 0.33965418615387694
# Compute control for a deterministic system
# Cost in iteration 0: 0.33965418615387694
# Cost in iteration 200: 0.33965392235593134
# Final cost : 0.33965392235593134
# Compute control for a deterministic system
# Cost in iteration 0: 0.33965392235593134
# Cost in iteration 200: 0.3396539220953893
# Final cost : 0.3396539220953893
# Compute control for a deterministic system
# Cost in iteration 0: 0.3396539220953893
# Converged in iteration 26 with cost 0.3396539220952792 because of vanishing difference
# Final cost : 0.3396539220952792
# Compute control for a deterministic system
# Cost in iteration 0: 0.3396539220952792
# Converged in iteration 5 with cost 0.33965392209527323 because of step counter
# Final cost : 0.33965392209527323
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.3085590299241148
# Cost in iteration 200: 0.3085487591376944
# Final cost : 0.3085487591376944
# Compute control for a deterministic system
# Cost in iteration 0: 0.3085487591376944
# Cost in iteration 200: 0.30854875545899707
# Final cost : 0.30854875545899707
# Compute control for a deterministic system
# Cost in iteration 0: 0.30854875545899707
# Converged in iteration 58 with cost 0.3085487554573265 because of step counter
# Final cost : 0.3085487554573265
# Compute control for a deterministic system
# Cost in iteration 0: 0.3085487554573265
# Converged in iteration 1 with cost 0.3085487554573265 because of step counter
# Final cost : 0.3085487554573265
# Compute control for a deterministic system
# Cost in iteration 0: 0.3085487554573265
# Converged in iteration 1 with cost 0.3085487554573265 because of step counter
# Final cost : 0.3085487554573265
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.28143957908033546
# Cost in iteration 200: 0.27806328633140953
# Final cost : 0.27806328633140953
# Compute control for a deterministic system
# Cost in iteration 0: 0.27806328633140953
# Cost in iteration 200: 0.278062034634314
# Final cost : 0.278062034634314
# Compute control for a deterministic system
# Cost in iteration 0: 0.278062034634314
# Converged in iteration 160 with cost 0.2780620344161772 because of step counter
# Final cost : 0.2780620344161772
# Compute control for a deterministic system
# Cost in iteration 0: 0.2780620344161772
# Converged in iteration 6 with cost 0.27806203441617516 because of step counter
# Final cost : 0.27806203441617516
# Compute control for a deterministic system
# Cost in iteration 0: 0.27806203441617516
# Converged in iteration 1 with cost 0.27806203441617516 because of step counter
# Final cost : 0.27806203441617516
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.24894562664670566
# Cost in iteration 200: 0.24804919043397747
# Final cost : 0.24804919043397747
# Compute control for a deterministic system
# Cost in iteration 0: 0.24804919043397747
# Cost in iteration 200: 0.24804890044465727
# Final cost : 0.24804890044465727
# Compute control for a deterministic system
# Cost in iteration 0: 0.24804890044465727
# Converged in iteration 63 with cost 0.24804890043256517 because of vanishing difference
# Final cost : 0.24804890043256517
# Compute control for a deterministic system
# Cost in iteration 0: 0.24804890043256517
# Converged in iteration 7 with cost 0.24804890043253497 because of step counter
# Final cost : 0.24804890043253497
# Compute control for a deterministic system
# Cost in iteration 0: 0.24804890043253497
# Converged in iteration 3 with cost 0.2480489004325328 because of step counter
# Final cost : 0.2480489004325328
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.2231190885486955
# Cost in iteration 200: 0.21840520461994545
# Final cost : 0.21840520461994545
# Compute control for a deterministic system
# Cost in iteration 0: 0.21840520461994545
# Cost in iteration 200: 0.21840358589027642
# Final cost : 0.21840358589027642
# Compute control for a deterministic system
# Cost in iteration 0: 0.21840358589027642
# Converged in iteration 45 with cost 0.21840358587789832 because of step counter
# Final cost : 0.21840358587789832
# Compute control for a deterministic system
# Cost in iteration 0: 0.21840358587789832
# Converged in iteration 1 with cost 0.21840358587789832 because of step counter
# Final cost : 0.21840358587789832
# Compute control for a deterministic system
# Cost in iteration 0: 0.21840358587789832
# Converged in iteration 1 with cost 0.21840358587789832 because of step counter
# Final cost : 0.21840358587789832
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.1903190907642103
# Cost in iteration 200: 0.1890596986558056
# Final cost : 0.1890596986558056
# Compute control for a deterministic system
# Cost in iteration 0: 0.1890596986558056
# Cost in iteration 200: 0.18905938849031795
# Final cost : 0.18905938849031795
# Compute control for a deterministic system
# Cost in iteration 0: 0.18905938849031795
# Converged in iteration 15 with cost 0.18905938849015008 because of step counter
# Final cost : 0.18905938849015008
# Compute control for a deterministic system
# Cost in iteration 0: 0.18905938849015008
# Converged in iteration 1 with cost 0.18905938849015008 because of step counter
# Final cost : 0.18905938849015008
# Compute control for a deterministic system
# Cost in iteration 0: 0.18905938849015008
# Converged in iteration 1 with cost 0.18905938849015008 because of step counter
# Final cost : 0.18905938849015008
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.15974793187147113
# Cost in iteration 200: 0.1593580105427674
# Final cost : 0.1593580105427674
# Compute control for a deterministic system
# Cost in iteration 0: 0.1593580105427674
# Converged in iteration 168 with cost 0.1593579266440362 because of vanishing difference
# Final cost : 0.1593579266440362
# Compute control for a deterministic system
# Cost in iteration 0: 0.1593579266440362
# Converged in iteration 7 with cost 0.15935792664401596 because of step counter
# Final cost : 0.15935792664401596
# Compute control for a deterministic system
# Cost in iteration 0: 0.15935792664401596
# Converged in iteration 1 with cost 0.15935792664401596 because of step counter
# Final cost : 0.15935792664401596
# Compute control for a deterministic system
# Cost in iteration 0: 0.15935792664401596
# Converged in iteration 1 with cost 0.15935792664401596 because of step counter
# Final cost : 0.15935792664401596
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.13100103108844724
# Cost in iteration 200: 0.13057142214633244
# Final cost : 0.13057142214633244
# Compute control for a deterministic system
# Cost in iteration 0: 0.13057142214633244
# Converged in iteration 128 with cost 0.1305713601517966 because of step counter
# Final cost : 0.1305713601517966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1305713601517966
# Converged in iteration 4 with cost 0.1305713601517881 because of step counter
# Final cost : 0.1305713601517881
# Compute control for a deterministic system
# Cost in iteration 0: 0.1305713601517881
# Converged in iteration 3 with cost 0.13057136015178666 because of step counter
# Final cost : 0.13057136015178666
# Compute control for a deterministic system
# Cost in iteration 0: 0.13057136015178666
# Converged in iteration 2 with cost 0.13057136015178641 because of step counter
# Final cost : 0.13057136015178641
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.10278837404608841
# Cost in iteration 200: 0.10211466219938445
# Final cost : 0.10211466219938445
# Compute control for a deterministic system
# Cost in iteration 0: 0.10211466219938445
# Converged in iteration 99 with cost 0.10211461388075305 because of step counter
# Final cost : 0.10211461388075305
# Compute control for a deterministic system
# Cost in iteration 0: 0.10211461388075305
# Converged in iteration 9 with cost 0.1021146138807474 because of step counter
# Final cost : 0.1021146138807474
# Compute control for a deterministic system
# Cost in iteration 0: 0.1021146138807474
# Converged in iteration 1 with cost 0.1021146138807474 because of step counter
# Final cost : 0.1021146138807474
# Compute control for a deterministic system
# Cost in iteration 0: 0.1021146138807474
# Converged in iteration 1 with cost 0.1021146138807474 because of step counter
# Final cost : 0.1021146138807474
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.07414538092138363
# Cost in iteration 200: 0.07409160610717855
# Final cost : 0.07409160610717855
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409160610717855
# Converged in iteration 52 with cost 0.07409160524501121 because of step counter
# Final cost : 0.07409160524501121
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409160524501121
# Converged in iteration 1 with cost 0.07409160524501121 because of step counter
# Final cost : 0.07409160524501121
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409160524501121
# Converged in iteration 4 with cost 0.07409160524500955 because of vanishing difference
# Final cost : 0.07409160524500955
# Compute control for a deterministic system
# Cost in iteration 0: 0.07409160524500955
# Converged in iteration 1 with cost 0.07409160524500955 because of step counter
# Final cost : 0.07409160524500955
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.04688782976638707
# Cost in iteration 200: 0.04669201774670197
# Final cost : 0.04669201774670197
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669201774670197
# Converged in iteration 26 with cost 0.046692017648506313 because of step counter
# Final cost : 0.046692017648506313
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692017648506313
# Converged in iteration 2 with cost 0.046692017648506015 because of step counter
# Final cost : 0.046692017648506015
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692017648506015
# Converged in iteration 1 with cost 0.046692017648506015 because of step counter
# Final cost : 0.046692017648506015
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692017648506015
# Converged in iteration 2 with cost 0.04669201764850555 because of step counter
# Final cost : 0.04669201764850555
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.020271097378827402
# Converged in iteration 117 with cost 0.020270683388183018 because of step counter
# Final cost : 0.020270683388183018
# Compute control for a deterministic system
# Cost in iteration 0: 0.020270683388183018
# Converged in iteration 5 with cost 0.020270683388176856 because of step counter
# Final cost : 0.020270683388176856
# Compute control for a deterministic system
# Cost in iteration 0: 0.020270683388176856
# Converged in iteration 1 with cost 0.020270683388176856 because of step counter
# Final cost : 0.020270683388176856
# Compute control for a deterministic system
# Cost in iteration 0: 0.020270683388176856
# Converged in iteration 1 with cost 0.020270683388176856 because of step counter
# Final cost : 0.020270683388176856
# Compute control for a deterministic system
# Cost in iteration 0: 0.020270683388176856
# Converged in iteration 1 with cost 0.020270683388176856 because of step counter
# Final cost : 0.020270683388176856
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
