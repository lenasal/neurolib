# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,84], wc.inh[0,84]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [  24  212  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
results_min = readfile("results_min_w1.pickle")

ind_list = range(41)
options = [True, True, True, True, True, True, False, False]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03539520828206978
# Converged in iteration 57 with cost 0.01498611248121494 because of step counter
# Final cost : 0.01498611248121494
# Compute control for a deterministic system
# Cost in iteration 0: 0.01498611248121494
# Converged in iteration 1 with cost 0.01498611248121494 because of step counter
# Final cost : 0.01498611248121494
# Compute control for a deterministic system
# Cost in iteration 0: 0.01498611248121494
# Converged in iteration 1 with cost 0.01498611248121494 because of step counter
# Final cost : 0.01498611248121494
# Compute control for a deterministic system
# Cost in iteration 0: 0.01498611248121494
# Converged in iteration 1 with cost 0.01498611248121494 because of step counter
# Final cost : 0.01498611248121494
# Compute control for a deterministic system
# Cost in iteration 0: 0.01498611248121494
# Converged in iteration 1 with cost 0.01498611248121494 because of step counter
# Final cost : 0.01498611248121494
# Compute control for a deterministic system
# Cost in iteration 0: 0.054513090780780114
# Converged in iteration 60 with cost 0.023684502784593626 because of step counter
# Final cost : 0.023684502784593626
# Compute control for a deterministic system
# Cost in iteration 0: 0.023684502784593626
# Converged in iteration 1 with cost 0.023684502784593626 because of step counter
# Final cost : 0.023684502784593626
# Compute control for a deterministic system
# Cost in iteration 0: 0.023684502784593626
# Converged in iteration 1 with cost 0.023684502784593626 because of step counter
# Final cost : 0.023684502784593626
# Compute control for a deterministic system
# Cost in iteration 0: 0.023684502784593626
# Converged in iteration 1 with cost 0.023684502784593626 because of step counter
# Final cost : 0.023684502784593626
# Compute control for a deterministic system
# Cost in iteration 0: 0.023684502784593626
# Converged in iteration 1 with cost 0.023684502784593626 because of step counter
# Final cost : 0.023684502784593626
# Compute control for a deterministic system
# Cost in iteration 0: 0.05966067873771709
# Converged in iteration 35 with cost 0.032111453135145344 because of step counter
# Final cost : 0.032111453135145344
# Compute control for a deterministic system
# Cost in iteration 0: 0.032111453135145344
# Converged in iteration 1 with cost 0.032111453135145344 because of step counter
# Final cost : 0.032111453135145344
# Compute control for a deterministic system
# Cost in iteration 0: 0.032111453135145344
# Converged in iteration 1 with cost 0.032111453135145344 because of step counter
# Final cost : 0.032111453135145344
# Compute control for a deterministic system
# Cost in iteration 0: 0.032111453135145344
# Converged in iteration 1 with cost 0.032111453135145344 because of step counter
# Final cost : 0.032111453135145344
# Compute control for a deterministic system
# Cost in iteration 0: 0.032111453135145344
# Converged in iteration 1 with cost 0.032111453135145344 because of step counter
# Final cost : 0.032111453135145344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0656968317034965
# Converged in iteration 63 with cost 0.04063789633214554 because of step counter
# Final cost : 0.04063789633214554
# Compute control for a deterministic system
# Cost in iteration 0: 0.04063789633214554
# Converged in iteration 1 with cost 0.04063789633214554 because of step counter
# Final cost : 0.04063789633214554
# Compute control for a deterministic system
# Cost in iteration 0: 0.04063789633214554
# Converged in iteration 1 with cost 0.04063789633214554 because of step counter
# Final cost : 0.04063789633214554
# Compute control for a deterministic system
# Cost in iteration 0: 0.04063789633214554
# Converged in iteration 1 with cost 0.04063789633214554 because of step counter
# Final cost : 0.04063789633214554
# Compute control for a deterministic system
# Cost in iteration 0: 0.04063789633214554
# Converged in iteration 1 with cost 0.04063789633214554 because of step counter
# Final cost : 0.04063789633214554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0586693715497609
# Converged in iteration 27 with cost 0.04665036115936148 because of step counter
# Final cost : 0.04665036115936148
# Compute control for a deterministic system
# Cost in iteration 0: 0.04665036115936148
# Converged in iteration 1 with cost 0.04665036115936148 because of step counter
# Final cost : 0.04665036115936148
# Compute control for a deterministic system
# Cost in iteration 0: 0.04665036115936148
# Converged in iteration 1 with cost 0.04665036115936148 because of step counter
# Final cost : 0.04665036115936148
# Compute control for a deterministic system
# Cost in iteration 0: 0.04665036115936148
# Converged in iteration 1 with cost 0.04665036115936148 because of step counter
# Final cost : 0.04665036115936148
# Compute control for a deterministic system
# Cost in iteration 0: 0.04665036115936148
# Converged in iteration 1 with cost 0.04665036115936148 because of step counter
# Final cost : 0.04665036115936148
# Compute control for a deterministic system
# Cost in iteration 0: 0.07607786040878048
# Converged in iteration 51 with cost 0.05513710277981053 because of step counter
# Final cost : 0.05513710277981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.05513710277981053
# Converged in iteration 1 with cost 0.05513710277981053 because of step counter
# Final cost : 0.05513710277981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.05513710277981053
# Converged in iteration 1 with cost 0.05513710277981053 because of step counter
# Final cost : 0.05513710277981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.05513710277981053
# Converged in iteration 1 with cost 0.05513710277981053 because of step counter
# Final cost : 0.05513710277981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.05513710277981053
# Converged in iteration 1 with cost 0.05513710277981053 because of step counter
# Final cost : 0.05513710277981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.08219162385389484
# Converged in iteration 64 with cost 0.06291987862625337 because of vanishing difference
# Final cost : 0.06291987862625337
# Compute control for a deterministic system
# Cost in iteration 0: 0.06291987862625337
# Converged in iteration 1 with cost 0.06291987862625337 because of step counter
# Final cost : 0.06291987862625337
# Compute control for a deterministic system
# Cost in iteration 0: 0.06291987862625337
# Converged in iteration 1 with cost 0.06291987862625337 because of step counter
# Final cost : 0.06291987862625337
# Compute control for a deterministic system
# Cost in iteration 0: 0.06291987862625337
# Converged in iteration 1 with cost 0.06291987862625337 because of step counter
# Final cost : 0.06291987862625337
# Compute control for a deterministic system
# Cost in iteration 0: 0.06291987862625337
# Converged in iteration 1 with cost 0.06291987862625337 because of step counter
# Final cost : 0.06291987862625337
# Compute control for a deterministic system
# Cost in iteration 0: 0.08848597789529765
# Converged in iteration 55 with cost 0.07052977295525517 because of step counter
# Final cost : 0.07052977295525517
# Compute control for a deterministic system
# Cost in iteration 0: 0.07052977295525517
# Converged in iteration 1 with cost 0.07052977295525517 because of step counter
# Final cost : 0.07052977295525517
# Compute control for a deterministic system
# Cost in iteration 0: 0.07052977295525517
# Converged in iteration 1 with cost 0.07052977295525517 because of step counter
# Final cost : 0.07052977295525517
# Compute control for a deterministic system
# Cost in iteration 0: 0.07052977295525517
# Converged in iteration 1 with cost 0.07052977295525517 because of step counter
# Final cost : 0.07052977295525517
# Compute control for a deterministic system
# Cost in iteration 0: 0.07052977295525517
# Converged in iteration 1 with cost 0.07052977295525517 because of step counter
# Final cost : 0.07052977295525517
# Compute control for a deterministic system
# Cost in iteration 0: 0.08390045277165217
# Converged in iteration 29 with cost 0.07572025706703639 because of step counter
# Final cost : 0.07572025706703639
# Compute control for a deterministic system
# Cost in iteration 0: 0.07572025706703639
# Converged in iteration 1 with cost 0.07572025706703639 because of step counter
# Final cost : 0.07572025706703639
# Compute control for a deterministic system
# Cost in iteration 0: 0.07572025706703639
# Converged in iteration 1 with cost 0.07572025706703639 because of step counter
# Final cost : 0.07572025706703639
# Compute control for a deterministic system
# Cost in iteration 0: 0.07572025706703639
# Converged in iteration 1 with cost 0.07572025706703639 because of step counter
# Final cost : 0.07572025706703639
# Compute control for a deterministic system
# Cost in iteration 0: 0.07572025706703639
# Converged in iteration 1 with cost 0.07572025706703639 because of step counter
# Final cost : 0.07572025706703639
# Compute control for a deterministic system
# Cost in iteration 0: 0.10009887826811284
# Converged in iteration 64 with cost 0.08373295341629938 because of step counter
# Final cost : 0.08373295341629938
# Compute control for a deterministic system
# Cost in iteration 0: 0.08373295341629938
# Converged in iteration 2 with cost 0.08373295341629933 because of step counter
# Final cost : 0.08373295341629933
# Compute control for a deterministic system
# Cost in iteration 0: 0.08373295341629933
# Converged in iteration 1 with cost 0.08373295341629933 because of step counter
# Final cost : 0.08373295341629933
# Compute control for a deterministic system
# Cost in iteration 0: 0.08373295341629933
# Converged in iteration 1 with cost 0.08373295341629933 because of step counter
# Final cost : 0.08373295341629933
# Compute control for a deterministic system
# Cost in iteration 0: 0.08373295341629933
# Converged in iteration 1 with cost 0.08373295341629933 because of step counter
# Final cost : 0.08373295341629933
# Compute control for a deterministic system
# Cost in iteration 0: 0.10738159728897317
# Converged in iteration 85 with cost 0.09059582313557772 because of step counter
# Final cost : 0.09059582313557772
# Compute control for a deterministic system
# Cost in iteration 0: 0.09059582313557772
# Converged in iteration 1 with cost 0.09059582313557772 because of step counter
# Final cost : 0.09059582313557772
# Compute control for a deterministic system
# Cost in iteration 0: 0.09059582313557772
# Converged in iteration 1 with cost 0.09059582313557772 because of step counter
# Final cost : 0.09059582313557772
# Compute control for a deterministic system
# Cost in iteration 0: 0.09059582313557772
# Converged in iteration 1 with cost 0.09059582313557772 because of step counter
# Final cost : 0.09059582313557772
# Compute control for a deterministic system
# Cost in iteration 0: 0.09059582313557772
# Converged in iteration 1 with cost 0.09059582313557772 because of step counter
# Final cost : 0.09059582313557772
# Compute control for a deterministic system
# Cost in iteration 0: 0.10188238399551106
# Converged in iteration 42 with cost 0.09493799792923652 because of vanishing difference
# Final cost : 0.09493799792923652
# Compute control for a deterministic system
# Cost in iteration 0: 0.09493799792923652
# Converged in iteration 1 with cost 0.09493799792923652 because of step counter
# Final cost : 0.09493799792923652
# Compute control for a deterministic system
# Cost in iteration 0: 0.09493799792923652
# Converged in iteration 1 with cost 0.09493799792923652 because of step counter
# Final cost : 0.09493799792923652
# Compute control for a deterministic system
# Cost in iteration 0: 0.09493799792923652
# Converged in iteration 1 with cost 0.09493799792923652 because of step counter
# Final cost : 0.09493799792923652
# Compute control for a deterministic system
# Cost in iteration 0: 0.09493799792923652
# Converged in iteration 1 with cost 0.09493799792923652 because of step counter
# Final cost : 0.09493799792923652
# Compute control for a deterministic system
# Cost in iteration 0: 0.11718937596022579
# Cost in iteration 200: 0.10156270387648933
# Final cost : 0.10156270387648933
# Compute control for a deterministic system
# Cost in iteration 0: 0.10156270387648933
# Converged in iteration 65 with cost 0.09966227619491186 because of step counter
# Final cost : 0.09966227619491186
# Compute control for a deterministic system
# Cost in iteration 0: 0.09966227619491186
# Converged in iteration 1 with cost 0.09966227619491186 because of step counter
# Final cost : 0.09966227619491186
# Compute control for a deterministic system
# Cost in iteration 0: 0.09966227619491186
# Converged in iteration 1 with cost 0.09966227619491186 because of step counter
# Final cost : 0.09966227619491186
# Compute control for a deterministic system
# Cost in iteration 0: 0.09966227619491186
# Converged in iteration 1 with cost 0.09966227619491186 because of step counter
# Final cost : 0.09966227619491186
# Compute control for a deterministic system
# Cost in iteration 0: 0.12376598020837848
# Cost in iteration 200: 0.1076719363248622
# Final cost : 0.1076719363248622
# Compute control for a deterministic system
# Cost in iteration 0: 0.1076719363248622
# Cost in iteration 200: 0.10505197978973917
# Final cost : 0.10505197978973917
# Compute control for a deterministic system
# Cost in iteration 0: 0.10505197978973917
# Converged in iteration 21 with cost 0.10496694134399108 because of step counter
# Final cost : 0.10496694134399108
# Compute control for a deterministic system
# Cost in iteration 0: 0.10496694134399108
# Converged in iteration 1 with cost 0.10496694134399108 because of step counter
# Final cost : 0.10496694134399108
# Compute control for a deterministic system
# Cost in iteration 0: 0.10496694134399108
# Converged in iteration 1 with cost 0.10496694134399108 because of step counter
# Final cost : 0.10496694134399108
# Compute control for a deterministic system
# Cost in iteration 0: 0.13029280557554812
# Cost in iteration 200: 0.11348883092581624
# Final cost : 0.11348883092581624
# Compute control for a deterministic system
# Cost in iteration 0: 0.11348883092581624
# Converged in iteration 71 with cost 0.11141723900085503 because of step counter
# Final cost : 0.11141723900085503
# Compute control for a deterministic system
# Cost in iteration 0: 0.11141723900085503
# Converged in iteration 1 with cost 0.11141723900085503 because of step counter
# Final cost : 0.11141723900085503
# Compute control for a deterministic system
# Cost in iteration 0: 0.11141723900085503
# Converged in iteration 1 with cost 0.11141723900085503 because of step counter
# Final cost : 0.11141723900085503
# Compute control for a deterministic system
# Cost in iteration 0: 0.11141723900085503
# Converged in iteration 1 with cost 0.11141723900085503 because of step counter
# Final cost : 0.11141723900085503
# Compute control for a deterministic system
# Cost in iteration 0: 0.1265016818089703
# Cost in iteration 200: 0.11705030013067765
# Final cost : 0.11705030013067765
# Compute control for a deterministic system
# Cost in iteration 0: 0.11705030013067765
# Cost in iteration 200: 0.11512750192686143
# Final cost : 0.11512750192686143
# Compute control for a deterministic system
# Cost in iteration 0: 0.11512750192686143
# Converged in iteration 28 with cost 0.11505345342702195 because of step counter
# Final cost : 0.11505345342702195
# Compute control for a deterministic system
# Cost in iteration 0: 0.11505345342702195
# Converged in iteration 1 with cost 0.11505345342702195 because of step counter
# Final cost : 0.11505345342702195
# Compute control for a deterministic system
# Cost in iteration 0: 0.11505345342702195
# Converged in iteration 1 with cost 0.11505345342702195 because of step counter
# Final cost : 0.11505345342702195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14163542792674713
# Cost in iteration 200: 0.12283693381635463
# Final cost : 0.12283693381635463
# Compute control for a deterministic system
# Cost in iteration 0: 0.12283693381635463
# Cost in iteration 200: 0.12093135567872343
# Final cost : 0.12093135567872343
# Compute control for a deterministic system
# Cost in iteration 0: 0.12093135567872343
# Converged in iteration 85 with cost 0.12093131592690702 because of vanishing difference
# Final cost : 0.12093131592690702
# Compute control for a deterministic system
# Cost in iteration 0: 0.12093131592690702
# Converged in iteration 22 with cost 0.12093131541419794 because of step counter
# Final cost : 0.12093131541419794
# Compute control for a deterministic system
# Cost in iteration 0: 0.12093131541419794
# Converged in iteration 1 with cost 0.12093131541419794 because of step counter
# Final cost : 0.12093131541419794
# Compute control for a deterministic system
# Cost in iteration 0: 0.14753198159537478
# Cost in iteration 200: 0.1271651998069627
# Final cost : 0.1271651998069627
# Compute control for a deterministic system
# Cost in iteration 0: 0.1271651998069627
# Converged in iteration 62 with cost 0.12560679702332458 because of step counter
# Final cost : 0.12560679702332458
# Compute control for a deterministic system
# Cost in iteration 0: 0.12560679702332458
# Converged in iteration 1 with cost 0.12560679702332458 because of step counter
# Final cost : 0.12560679702332458
# Compute control for a deterministic system
# Cost in iteration 0: 0.12560679702332458
# Converged in iteration 1 with cost 0.12560679702332458 because of step counter
# Final cost : 0.12560679702332458
# Compute control for a deterministic system
# Cost in iteration 0: 0.12560679702332458
# Converged in iteration 1 with cost 0.12560679702332458 because of step counter
# Final cost : 0.12560679702332458
# Compute control for a deterministic system
# Cost in iteration 0: 0.13919450166472003
# Cost in iteration 200: 0.1281432073454935
# Final cost : 0.1281432073454935
# Compute control for a deterministic system
# Cost in iteration 0: 0.1281432073454935
# Converged in iteration 56 with cost 0.127552375407984 because of step counter
# Final cost : 0.127552375407984
# Compute control for a deterministic system
# Cost in iteration 0: 0.127552375407984
# Converged in iteration 1 with cost 0.127552375407984 because of step counter
# Final cost : 0.127552375407984
# Compute control for a deterministic system
# Cost in iteration 0: 0.127552375407984
# Converged in iteration 1 with cost 0.127552375407984 because of step counter
# Final cost : 0.127552375407984
# Compute control for a deterministic system
# Cost in iteration 0: 0.127552375407984
# Converged in iteration 1 with cost 0.127552375407984 because of step counter
# Final cost : 0.127552375407984
# Compute control for a deterministic system
# Cost in iteration 0: 0.1694210338303453
# Converged in iteration 18 with cost 0.1299876863266998 because of step counter
# Final cost : 0.1299876863266998
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299876863266998
# Converged in iteration 1 with cost 0.1299876863266998 because of step counter
# Final cost : 0.1299876863266998
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299876863266998
# Converged in iteration 1 with cost 0.1299876863266998 because of step counter
# Final cost : 0.1299876863266998
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299876863266998
# Converged in iteration 1 with cost 0.1299876863266998 because of step counter
# Final cost : 0.1299876863266998
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299876863266998
# Converged in iteration 1 with cost 0.1299876863266998 because of step counter
# Final cost : 0.1299876863266998
# Compute control for a deterministic system
# Cost in iteration 0: 0.17247130285856216
# Converged in iteration 38 with cost 0.13213873250142116 because of step counter
# Final cost : 0.13213873250142116
# Compute control for a deterministic system
# Cost in iteration 0: 0.13213873250142116
# Converged in iteration 1 with cost 0.13213873250142116 because of step counter
# Final cost : 0.13213873250142116
# Compute control for a deterministic system
# Cost in iteration 0: 0.13213873250142116
# Converged in iteration 1 with cost 0.13213873250142116 because of step counter
# Final cost : 0.13213873250142116
# Compute control for a deterministic system
# Cost in iteration 0: 0.13213873250142116
# Converged in iteration 1 with cost 0.13213873250142116 because of step counter
# Final cost : 0.13213873250142116
# Compute control for a deterministic system
# Cost in iteration 0: 0.13213873250142116
# Converged in iteration 1 with cost 0.13213873250142116 because of step counter
# Final cost : 0.13213873250142116
# Compute control for a deterministic system
# Cost in iteration 0: 0.17515512429588853
# Converged in iteration 55 with cost 0.13440415569772737 because of step counter
# Final cost : 0.13440415569772737
# Compute control for a deterministic system
# Cost in iteration 0: 0.13440415569772737
# Converged in iteration 1 with cost 0.13440415569772737 because of step counter
# Final cost : 0.13440415569772737
# Compute control for a deterministic system
# Cost in iteration 0: 0.13440415569772737
# Converged in iteration 1 with cost 0.13440415569772737 because of step counter
# Final cost : 0.13440415569772737
# Compute control for a deterministic system
# Cost in iteration 0: 0.13440415569772737
# Converged in iteration 1 with cost 0.13440415569772737 because of step counter
# Final cost : 0.13440415569772737
# Compute control for a deterministic system
# Cost in iteration 0: 0.13440415569772737
# Converged in iteration 1 with cost 0.13440415569772737 because of step counter
# Final cost : 0.13440415569772737
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.16252810292442857
# Converged in iteration 82 with cost 0.13626529682730112 because of step counter
# Final cost : 0.13626529682730112
# Compute control for a deterministic system
# Cost in iteration 0: 0.13626529682730112
# Converged in iteration 1 with cost 0.13626529682730112 because of step counter
# Final cost : 0.13626529682730112
# Compute control for a deterministic system
# Cost in iteration 0: 0.13626529682730112
# Converged in iteration 1 with cost 0.13626529682730112 because of step counter
# Final cost : 0.13626529682730112
# Compute control for a deterministic system
# Cost in iteration 0: 0.13626529682730112
# Converged in iteration 1 with cost 0.13626529682730112 because of step counter
# Final cost : 0.13626529682730112
# Compute control for a deterministic system
# Cost in iteration 0: 0.13626529682730112
# Converged in iteration 1 with cost 0.13626529682730112 because of step counter
# Final cost : 0.13626529682730112
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.17984642890617153
# Converged in iteration 164 with cost 0.13853963299245506 because of step counter
# Final cost : 0.13853963299245506
# Compute control for a deterministic system
# Cost in iteration 0: 0.13853963299245506
# Converged in iteration 1 with cost 0.13853963299245506 because of step counter
# Final cost : 0.13853963299245506
# Compute control for a deterministic system
# Cost in iteration 0: 0.13853963299245506
# Converged in iteration 1 with cost 0.13853963299245506 because of step counter
# Final cost : 0.13853963299245506
# Compute control for a deterministic system
# Cost in iteration 0: 0.13853963299245506
# Converged in iteration 1 with cost 0.13853963299245506 because of step counter
# Final cost : 0.13853963299245506
# Compute control for a deterministic system
# Cost in iteration 0: 0.13853963299245506
# Converged in iteration 1 with cost 0.13853963299245506 because of step counter
# Final cost : 0.13853963299245506
# Compute control for a deterministic system
# Cost in iteration 0: 0.16962390054047288
# Cost in iteration 200: 0.12275865029293385
# Final cost : 0.12275865029293385
# Compute control for a deterministic system
# Cost in iteration 0: 0.12275865029293385
# Converged in iteration 115 with cost 0.12229528569181672 because of step counter
# Final cost : 0.12229528569181672
# Compute control for a deterministic system
# Cost in iteration 0: 0.12229528569181672
# Converged in iteration 1 with cost 0.12229528569181672 because of step counter
# Final cost : 0.12229528569181672
# Compute control for a deterministic system
# Cost in iteration 0: 0.12229528569181672
# Converged in iteration 1 with cost 0.12229528569181672 because of step counter
# Final cost : 0.12229528569181672
# Compute control for a deterministic system
# Cost in iteration 0: 0.12229528569181672
# Converged in iteration 1 with cost 0.12229528569181672 because of step counter
# Final cost : 0.12229528569181672
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.16439098519069476
# Cost in iteration 200: 0.11569473535148155
# Final cost : 0.11569473535148155
# Compute control for a deterministic system
# Cost in iteration 0: 0.11569473535148155
# Cost in iteration 200: 0.1134901721118846
# Final cost : 0.1134901721118846
# Compute control for a deterministic system
# Cost in iteration 0: 0.1134901721118846
# Converged in iteration 9 with cost 0.11346937639503453 because of step counter
# Final cost : 0.11346937639503453
# Compute control for a deterministic system
# Cost in iteration 0: 0.11346937639503453
# Converged in iteration 1 with cost 0.11346937639503453 because of step counter
# Final cost : 0.11346937639503453
# Compute control for a deterministic system
# Cost in iteration 0: 0.11346937639503453
# Converged in iteration 1 with cost 0.11346937639503453 because of step counter
# Final cost : 0.11346937639503453
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.14079555286040682
# Cost in iteration 200: 0.1082494399382452
# Final cost : 0.1082494399382452
# Compute control for a deterministic system
# Cost in iteration 0: 0.1082494399382452
# Cost in iteration 200: 0.10656110683087254
# Final cost : 0.10656110683087254
# Compute control for a deterministic system
# Cost in iteration 0: 0.10656110683087254
# Converged in iteration 13 with cost 0.10652659637817946 because of step counter
# Final cost : 0.10652659637817946
# Compute control for a deterministic system
# Cost in iteration 0: 0.10652659637817946
# Converged in iteration 1 with cost 0.10652659637817946 because of step counter
# Final cost : 0.10652659637817946
# Compute control for a deterministic system
# Cost in iteration 0: 0.10652659637817946
# Converged in iteration 1 with cost 0.10652659637817946 because of step counter
# Final cost : 0.10652659637817946
# Compute control for a deterministic system
# Cost in iteration 0: 0.14690292547867892
# Cost in iteration 200: 0.09746066525111632
# Final cost : 0.09746066525111632
# Compute control for a deterministic system
# Cost in iteration 0: 0.09746066525111632
# Converged in iteration 70 with cost 0.09714895838635546 because of step counter
# Final cost : 0.09714895838635546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09714895838635546
# Converged in iteration 1 with cost 0.09714895838635546 because of step counter
# Final cost : 0.09714895838635546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09714895838635546
# Converged in iteration 1 with cost 0.09714895838635546 because of step counter
# Final cost : 0.09714895838635546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09714895838635546
# Converged in iteration 1 with cost 0.09714895838635546 because of step counter
# Final cost : 0.09714895838635546
# Compute control for a deterministic system
# Cost in iteration 0: 0.13784793779450905
# Cost in iteration 200: 0.08826283716314968
# Final cost : 0.08826283716314968
# Compute control for a deterministic system
# Cost in iteration 0: 0.08826283716314968
# Converged in iteration 61 with cost 0.08797015739021735 because of step counter
# Final cost : 0.08797015739021735
# Compute control for a deterministic system
# Cost in iteration 0: 0.08797015739021735
# Converged in iteration 1 with cost 0.08797015739021735 because of step counter
# Final cost : 0.08797015739021735
# Compute control for a deterministic system
# Cost in iteration 0: 0.08797015739021735
# Converged in iteration 1 with cost 0.08797015739021735 because of step counter
# Final cost : 0.08797015739021735
# Compute control for a deterministic system
# Cost in iteration 0: 0.08797015739021735
# Converged in iteration 1 with cost 0.08797015739021735 because of step counter
# Final cost : 0.08797015739021735
# Compute control for a deterministic system
# Cost in iteration 0: 0.11336252348887074
# Cost in iteration 200: 0.08060840101832097
# Final cost : 0.08060840101832097
# Compute control for a deterministic system
# Cost in iteration 0: 0.08060840101832097
# Converged in iteration 35 with cost 0.08050199163471597 because of step counter
# Final cost : 0.08050199163471597
# Compute control for a deterministic system
# Cost in iteration 0: 0.08050199163471597
# Converged in iteration 1 with cost 0.08050199163471597 because of step counter
# Final cost : 0.08050199163471597
# Compute control for a deterministic system
# Cost in iteration 0: 0.08050199163471597
# Converged in iteration 1 with cost 0.08050199163471597 because of step counter
# Final cost : 0.08050199163471597
# Compute control for a deterministic system
# Cost in iteration 0: 0.08050199163471597
# Converged in iteration 1 with cost 0.08050199163471597 because of step counter
# Final cost : 0.08050199163471597
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.12493955765049403
# Cost in iteration 200: 0.07283693005949354
# Final cost : 0.07283693005949354
# Compute control for a deterministic system
# Cost in iteration 0: 0.07283693005949354
# Converged in iteration 171 with cost 0.0713223919019887 because of step counter
# Final cost : 0.0713223919019887
# Compute control for a deterministic system
# Cost in iteration 0: 0.0713223919019887
# Converged in iteration 1 with cost 0.0713223919019887 because of step counter
# Final cost : 0.0713223919019887
# Compute control for a deterministic system
# Cost in iteration 0: 0.0713223919019887
# Converged in iteration 1 with cost 0.0713223919019887 because of step counter
# Final cost : 0.0713223919019887
# Compute control for a deterministic system
# Cost in iteration 0: 0.0713223919019887
# Converged in iteration 1 with cost 0.0713223919019887 because of step counter
# Final cost : 0.0713223919019887
# Compute control for a deterministic system
# Cost in iteration 0: 0.10987524686008487
# Cost in iteration 200: 0.06247127882197816
# Final cost : 0.06247127882197816
# Compute control for a deterministic system
# Cost in iteration 0: 0.06247127882197816
# Cost in iteration 200: 0.06207171158745614
# Final cost : 0.06207171158745614
# Compute control for a deterministic system
# Cost in iteration 0: 0.06207171158745614
# Converged in iteration 16 with cost 0.06202298848127322 because of step counter
# Final cost : 0.06202298848127322
# Compute control for a deterministic system
# Cost in iteration 0: 0.06202298848127322
# Converged in iteration 1 with cost 0.06202298848127322 because of step counter
# Final cost : 0.06202298848127322
# Compute control for a deterministic system
# Cost in iteration 0: 0.06202298848127322
# Converged in iteration 1 with cost 0.06202298848127322 because of step counter
# Final cost : 0.06202298848127322
# Compute control for a deterministic system
# Cost in iteration 0: 0.10458980436939506
# Cost in iteration 200: 0.0524128961874683
# Final cost : 0.0524128961874683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0524128961874683
# Converged in iteration 35 with cost 0.052259465338257295 because of step counter
# Final cost : 0.052259465338257295
# Compute control for a deterministic system
# Cost in iteration 0: 0.052259465338257295
# Converged in iteration 1 with cost 0.052259465338257295 because of step counter
# Final cost : 0.052259465338257295
# Compute control for a deterministic system
# Cost in iteration 0: 0.052259465338257295
# Converged in iteration 1 with cost 0.052259465338257295 because of step counter
# Final cost : 0.052259465338257295
# Compute control for a deterministic system
# Cost in iteration 0: 0.052259465338257295
# Converged in iteration 1 with cost 0.052259465338257295 because of step counter
# Final cost : 0.052259465338257295
# Compute control for a deterministic system
# Cost in iteration 0: 0.07823053522009876
# Cost in iteration 200: 0.04483412841459222
# Final cost : 0.04483412841459222
# Compute control for a deterministic system
# Cost in iteration 0: 0.04483412841459222
# Converged in iteration 26 with cost 0.04478629392041688 because of step counter
# Final cost : 0.04478629392041688
# Compute control for a deterministic system
# Cost in iteration 0: 0.04478629392041688
# Converged in iteration 1 with cost 0.04478629392041688 because of step counter
# Final cost : 0.04478629392041688
# Compute control for a deterministic system
# Cost in iteration 0: 0.04478629392041688
# Converged in iteration 1 with cost 0.04478629392041688 because of step counter
# Final cost : 0.04478629392041688
# Compute control for a deterministic system
# Cost in iteration 0: 0.04478629392041688
# Converged in iteration 1 with cost 0.04478629392041688 because of step counter
# Final cost : 0.04478629392041688
# Compute control for a deterministic system
# Cost in iteration 0: 0.08663753850350302
# Cost in iteration 200: 0.03562345296779644
# Final cost : 0.03562345296779644
# Compute control for a deterministic system
# Cost in iteration 0: 0.03562345296779644
# Cost in iteration 200: 0.035176011273244635
# Final cost : 0.035176011273244635
# Compute control for a deterministic system
# Cost in iteration 0: 0.035176011273244635
# Converged in iteration 12 with cost 0.03515111652605214 because of step counter
# Final cost : 0.03515111652605214
# Compute control for a deterministic system
# Cost in iteration 0: 0.03515111652605214
# Converged in iteration 1 with cost 0.03515111652605214 because of step counter
# Final cost : 0.03515111652605214
# Compute control for a deterministic system
# Cost in iteration 0: 0.03515111652605214
# Converged in iteration 1 with cost 0.03515111652605214 because of step counter
# Final cost : 0.03515111652605214
# Compute control for a deterministic system
# Cost in iteration 0: 0.07859857108434265
# Cost in iteration 200: 0.026099969027371224
# Final cost : 0.026099969027371224
# Compute control for a deterministic system
# Cost in iteration 0: 0.026099969027371224
# Converged in iteration 95 with cost 0.025458560484112443 because of step counter
# Final cost : 0.025458560484112443
# Compute control for a deterministic system
# Cost in iteration 0: 0.025458560484112443
# Converged in iteration 1 with cost 0.025458560484112443 because of step counter
# Final cost : 0.025458560484112443
# Compute control for a deterministic system
# Cost in iteration 0: 0.025458560484112443
# Converged in iteration 1 with cost 0.025458560484112443 because of step counter
# Final cost : 0.025458560484112443
# Compute control for a deterministic system
# Cost in iteration 0: 0.025458560484112443
# Converged in iteration 1 with cost 0.025458560484112443 because of step counter
# Final cost : 0.025458560484112443
# Compute control for a deterministic system
# Cost in iteration 0: 0.06768595619404366
# Cost in iteration 200: 0.016328933563713302
# Final cost : 0.016328933563713302
# Compute control for a deterministic system
# Cost in iteration 0: 0.016328933563713302
# Converged in iteration 159 with cost 0.015726564560648325 because of step counter
# Final cost : 0.015726564560648325
# Compute control for a deterministic system
# Cost in iteration 0: 0.015726564560648325
# Converged in iteration 1 with cost 0.015726564560648325 because of step counter
# Final cost : 0.015726564560648325
# Compute control for a deterministic system
# Cost in iteration 0: 0.015726564560648325
# Converged in iteration 1 with cost 0.015726564560648325 because of step counter
# Final cost : 0.015726564560648325
# Compute control for a deterministic system
# Cost in iteration 0: 0.015726564560648325
# Converged in iteration 1 with cost 0.015726564560648325 because of step counter
# Final cost : 0.015726564560648325
# Compute control for a deterministic system
# Cost in iteration 0: 0.040791409744601166
# Cost in iteration 200: 0.008364003398001972
# Final cost : 0.008364003398001972
# Compute control for a deterministic system
# Cost in iteration 0: 0.008364003398001972
# Converged in iteration 107 with cost 0.008149738096339875 because of step counter
# Final cost : 0.008149738096339875
# Compute control for a deterministic system
# Cost in iteration 0: 0.008149738096339875
# Converged in iteration 1 with cost 0.008149738096339875 because of step counter
# Final cost : 0.008149738096339875
# Compute control for a deterministic system
# Cost in iteration 0: 0.008149738096339875
# Converged in iteration 1 with cost 0.008149738096339875 because of step counter
# Final cost : 0.008149738096339875
# Compute control for a deterministic system
# Cost in iteration 0: 0.008149738096339875
# Converged in iteration 1 with cost 0.008149738096339875 because of step counter
# Final cost : 0.008149738096339875
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.03963224720858639
# Converged in iteration 12 with cost 0.015129681970307625 because of step counter
# Final cost : 0.015129681970307625
# Compute control for a deterministic system
# Cost in iteration 0: 0.015129681970307625
# Converged in iteration 1 with cost 0.015129681970307625 because of step counter
# Final cost : 0.015129681970307625
# Compute control for a deterministic system
# Cost in iteration 0: 0.015129681970307625
# Converged in iteration 1 with cost 0.015129681970307625 because of step counter
# Final cost : 0.015129681970307625
# Compute control for a deterministic system
# Cost in iteration 0: 0.015129681970307625
# Converged in iteration 1 with cost 0.015129681970307625 because of step counter
# Final cost : 0.015129681970307625
# Compute control for a deterministic system
# Cost in iteration 0: 0.06590324364048585
# Converged in iteration 19 with cost 0.025164183656432252 because of vanishing difference
# Final cost : 0.025164183656432252
# Compute control for a deterministic system
# Cost in iteration 0: 0.025164183656432252
# Converged in iteration 5 with cost 0.025164183655308203 because of step counter
# Final cost : 0.025164183655308203
# Compute control for a deterministic system
# Cost in iteration 0: 0.025164183655308203
# Converged in iteration 1 with cost 0.025164183655308203 because of step counter
# Final cost : 0.025164183655308203
# Compute control for a deterministic system
# Cost in iteration 0: 0.025164183655308203
# Converged in iteration 1 with cost 0.025164183655308203 because of step counter
# Final cost : 0.025164183655308203
# Compute control for a deterministic system
# Cost in iteration 0: 0.07513005542305982
# Converged in iteration 18 with cost 0.03510379008139182 because of vanishing difference
# Final cost : 0.03510379008139182
# Compute control for a deterministic system
# Cost in iteration 0: 0.03510379008139182
# Converged in iteration 7 with cost 0.03510379005566685 because of step counter
# Final cost : 0.03510379005566685
# Compute control for a deterministic system
# Cost in iteration 0: 0.03510379005566685
# Converged in iteration 1 with cost 0.03510379005566685 because of step counter
# Final cost : 0.03510379005566685
# Compute control for a deterministic system
# Cost in iteration 0: 0.03510379005566685
# Converged in iteration 1 with cost 0.03510379005566685 because of step counter
# Final cost : 0.03510379005566685
# Compute control for a deterministic system
# Cost in iteration 0: 0.08390293476897964
# Converged in iteration 15 with cost 0.04490994002667795 because of step counter
# Final cost : 0.04490994002667795
# Compute control for a deterministic system
# Cost in iteration 0: 0.04490994002667795
# Converged in iteration 1 with cost 0.04490994002667795 because of step counter
# Final cost : 0.04490994002667795
# Compute control for a deterministic system
# Cost in iteration 0: 0.04490994002667795
# Converged in iteration 1 with cost 0.04490994002667795 because of step counter
# Final cost : 0.04490994002667795
# Compute control for a deterministic system
# Cost in iteration 0: 0.04490994002667795
# Converged in iteration 1 with cost 0.04490994002667795 because of step counter
# Final cost : 0.04490994002667795
# Compute control for a deterministic system
# Cost in iteration 0: 0.07601565487441059
# Converged in iteration 14 with cost 0.05213166830829866 because of step counter
# Final cost : 0.05213166830829866
# Compute control for a deterministic system
# Cost in iteration 0: 0.05213166830829866
# Converged in iteration 1 with cost 0.05213166830829866 because of step counter
# Final cost : 0.05213166830829866
# Compute control for a deterministic system
# Cost in iteration 0: 0.05213166830829866
# Converged in iteration 1 with cost 0.05213166830829866 because of step counter
# Final cost : 0.05213166830829866
# Compute control for a deterministic system
# Cost in iteration 0: 0.05213166830829866
# Converged in iteration 1 with cost 0.05213166830829866 because of step counter
# Final cost : 0.05213166830829866
# Compute control for a deterministic system
# Cost in iteration 0: 0.10186561248157894
# Cost in iteration 200: 0.06314067113268387
# Final cost : 0.06314067113268387
# Compute control for a deterministic system
# Cost in iteration 0: 0.06314067113268387
# Converged in iteration 1 with cost 0.06314067113268387 because of step counter
# Final cost : 0.06314067113268387
# Compute control for a deterministic system
# Cost in iteration 0: 0.06314067113268387
# Converged in iteration 1 with cost 0.06314067113268387 because of step counter
# Final cost : 0.06314067113268387
# Compute control for a deterministic system
# Cost in iteration 0: 0.06314067113268387
# Converged in iteration 1 with cost 0.06314067113268387 because of step counter
# Final cost : 0.06314067113268387
# Compute control for a deterministic system
# Cost in iteration 0: 0.10901134372865812
# Converged in iteration 23 with cost 0.07274500869177848 because of step counter
# Final cost : 0.07274500869177848
# Compute control for a deterministic system
# Cost in iteration 0: 0.07274500869177848
# Converged in iteration 1 with cost 0.07274500869177848 because of step counter
# Final cost : 0.07274500869177848
# Compute control for a deterministic system
# Cost in iteration 0: 0.07274500869177848
# Converged in iteration 1 with cost 0.07274500869177848 because of step counter
# Final cost : 0.07274500869177848
# Compute control for a deterministic system
# Cost in iteration 0: 0.07274500869177848
# Converged in iteration 1 with cost 0.07274500869177848 because of step counter
# Final cost : 0.07274500869177848
# Compute control for a deterministic system
# Cost in iteration 0: 0.118949199895083
# Converged in iteration 20 with cost 0.08111819433697853 because of step counter
# Final cost : 0.08111819433697853
# Compute control for a deterministic system
# Cost in iteration 0: 0.08111819433697853
# Converged in iteration 1 with cost 0.08111819433697853 because of step counter
# Final cost : 0.08111819433697853
# Compute control for a deterministic system
# Cost in iteration 0: 0.08111819433697853
# Converged in iteration 1 with cost 0.08111819433697853 because of step counter
# Final cost : 0.08111819433697853
# Compute control for a deterministic system
# Cost in iteration 0: 0.08111819433697853
# Converged in iteration 1 with cost 0.08111819433697853 because of step counter
# Final cost : 0.08111819433697853
# Compute control for a deterministic system
# Cost in iteration 0: 0.10641863800349181
# Converged in iteration 3 with cost 0.08755591838921137 because of step counter
# Final cost : 0.08755591838921137
# Compute control for a deterministic system
# Cost in iteration 0: 0.08755591838921137
# Converged in iteration 1 with cost 0.08755591838921137 because of step counter
# Final cost : 0.08755591838921137
# Compute control for a deterministic system
# Cost in iteration 0: 0.08755591838921137
# Converged in iteration 1 with cost 0.08755591838921137 because of step counter
# Final cost : 0.08755591838921137
# Compute control for a deterministic system
# Cost in iteration 0: 0.08755591838921137
# Converged in iteration 1 with cost 0.08755591838921137 because of step counter
# Final cost : 0.08755591838921137
# -----------------------------------------------
# 1 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.13434493850648682
# Converged in iteration 25 with cost 0.09893971905672976 because of step counter
# Final cost : 0.09893971905672976
# Compute control for a deterministic system
# Cost in iteration 0: 0.09893971905672976
# Converged in iteration 1 with cost 0.09893971905672976 because of step counter
# Final cost : 0.09893971905672976
# Compute control for a deterministic system
# Cost in iteration 0: 0.09893971905672976
# Converged in iteration 1 with cost 0.09893971905672976 because of step counter
# Final cost : 0.09893971905672976
# Compute control for a deterministic system
# Cost in iteration 0: 0.09893971905672976
# Converged in iteration 1 with cost 0.09893971905672976 because of step counter
# Final cost : 0.09893971905672976
# Compute control for a deterministic system
# Cost in iteration 0: 0.140384277927332
# Converged in iteration 45 with cost 0.1083478228587886 because of vanishing difference
# Final cost : 0.1083478228587886
# Compute control for a deterministic system
# Cost in iteration 0: 0.1083478228587886
# Converged in iteration 26 with cost 0.10834782272832266 because of step counter
# Final cost : 0.10834782272832266
# Compute control for a deterministic system
# Cost in iteration 0: 0.10834782272832266
# Converged in iteration 1 with cost 0.10834782272832266 because of step counter
# Final cost : 0.10834782272832266
# Compute control for a deterministic system
# Cost in iteration 0: 0.10834782272832266
# Converged in iteration 1 with cost 0.10834782272832266 because of step counter
# Final cost : 0.10834782272832266
# Compute control for a deterministic system
# Cost in iteration 0: 0.13274457433825781
# Converged in iteration 46 with cost 0.1151534859400834 because of step counter
# Final cost : 0.1151534859400834
# Compute control for a deterministic system
# Cost in iteration 0: 0.1151534859400834
# Converged in iteration 1 with cost 0.1151534859400834 because of step counter
# Final cost : 0.1151534859400834
# Compute control for a deterministic system
# Cost in iteration 0: 0.1151534859400834
# Converged in iteration 1 with cost 0.1151534859400834 because of step counter
# Final cost : 0.1151534859400834
# Compute control for a deterministic system
# Cost in iteration 0: 0.1151534859400834
# Converged in iteration 1 with cost 0.1151534859400834 because of step counter
# Final cost : 0.1151534859400834
# Compute control for a deterministic system
# Cost in iteration 0: 0.14780681384813743
# Converged in iteration 4 with cost 0.12192072739744116 because of step counter
# Final cost : 0.12192072739744116
# Compute control for a deterministic system
# Cost in iteration 0: 0.12192072739744116
# Converged in iteration 1 with cost 0.12192072739744116 because of step counter
# Final cost : 0.12192072739744116
# Compute control for a deterministic system
# Cost in iteration 0: 0.12192072739744116
# Converged in iteration 1 with cost 0.12192072739744116 because of step counter
# Final cost : 0.12192072739744116
# Compute control for a deterministic system
# Cost in iteration 0: 0.12192072739744116
# Converged in iteration 1 with cost 0.12192072739744116 because of step counter
# Final cost : 0.12192072739744116
# -----------------------------------------------
# 1 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.16301179996094284
# Cost in iteration 200: 0.13252316730362795
# Final cost : 0.13252316730362795
# Compute control for a deterministic system
# Cost in iteration 0: 0.13252316730362795
# Converged in iteration 4 with cost 0.13236866127255642 because of step counter
# Final cost : 0.13236866127255642
# Compute control for a deterministic system
# Cost in iteration 0: 0.13236866127255642
# Converged in iteration 1 with cost 0.13236866127255642 because of step counter
# Final cost : 0.13236866127255642
# Compute control for a deterministic system
# Cost in iteration 0: 0.13236866127255642
# Converged in iteration 1 with cost 0.13236866127255642 because of step counter
# Final cost : 0.13236866127255642
# Compute control for a deterministic system
# Cost in iteration 0: 0.168051616270453
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 2.016317063033557
# Converged in iteration 1 with cost 2.016317063033557 because of step counter
# Final cost : 2.016317063033557
# Compute control for a deterministic system
# Cost in iteration 0: 2.016317063033557
# Converged in iteration 1 with cost 2.016317063033557 because of step counter
# Final cost : 2.016317063033557
# Compute control for a deterministic system
# Cost in iteration 0: 2.016317063033557
# Converged in iteration 1 with cost 2.016317063033557 because of step counter
# Final cost : 2.016317063033557
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 2.0536803457399384
# Converged in iteration 4 with cost 1.902818541059946 because of step counter
# Final cost : 1.902818541059946
# Compute control for a deterministic system
# Cost in iteration 0: 1.902818541059946
# Converged in iteration 1 with cost 1.902818541059946 because of step counter
# Final cost : 1.902818541059946
# Compute control for a deterministic system
# Cost in iteration 0: 1.902818541059946
# Converged in iteration 1 with cost 1.902818541059946 because of step counter
# Final cost : 1.902818541059946
# Compute control for a deterministic system
# Cost in iteration 0: 1.902818541059946
# Converged in iteration 1 with cost 1.902818541059946 because of step counter
# Final cost : 1.902818541059946
# Compute control for a deterministic system
# Cost in iteration 0: 1.902818541059946
# Converged in iteration 1 with cost 1.902818541059946 because of step counter
# Final cost : 1.902818541059946
# Compute control for a deterministic system
# Cost in iteration 0: 1.8171681621360316
# Converged in iteration 4 with cost 1.7396315442466541 because of step counter
# Final cost : 1.7396315442466541
# Compute control for a deterministic system
# Cost in iteration 0: 1.7396315442466541
# Converged in iteration 1 with cost 1.7396315442466541 because of step counter
# Final cost : 1.7396315442466541
# Compute control for a deterministic system
# Cost in iteration 0: 1.7396315442466541
# Converged in iteration 1 with cost 1.7396315442466541 because of step counter
# Final cost : 1.7396315442466541
# Compute control for a deterministic system
# Cost in iteration 0: 1.7396315442466541
# Converged in iteration 1 with cost 1.7396315442466541 because of step counter
# Final cost : 1.7396315442466541
# Compute control for a deterministic system
# Cost in iteration 0: 1.7396315442466541
# Converged in iteration 1 with cost 1.7396315442466541 because of step counter
# Final cost : 1.7396315442466541
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 1.718781631887331
# Converged in iteration 4 with cost 1.6177783136551087 because of step counter
# Final cost : 1.6177783136551087
# Compute control for a deterministic system
# Cost in iteration 0: 1.6177783136551087
# Converged in iteration 1 with cost 1.6177783136551087 because of step counter
# Final cost : 1.6177783136551087
# Compute control for a deterministic system
# Cost in iteration 0: 1.6177783136551087
# Converged in iteration 1 with cost 1.6177783136551087 because of step counter
# Final cost : 1.6177783136551087
# Compute control for a deterministic system
# Cost in iteration 0: 1.6177783136551087
# Converged in iteration 1 with cost 1.6177783136551087 because of step counter
# Final cost : 1.6177783136551087
# Compute control for a deterministic system
# Cost in iteration 0: 1.6177783136551087
# Converged in iteration 1 with cost 1.6177783136551087 because of step counter
# Final cost : 1.6177783136551087
# Compute control for a deterministic system
# Cost in iteration 0: 1.529991662118466
# Converged in iteration 5 with cost 1.484277928054085 because of step counter
# Final cost : 1.484277928054085
# Compute control for a deterministic system
# Cost in iteration 0: 1.484277928054085
# Converged in iteration 1 with cost 1.484277928054085 because of step counter
# Final cost : 1.484277928054085
# Compute control for a deterministic system
# Cost in iteration 0: 1.484277928054085
# Converged in iteration 1 with cost 1.484277928054085 because of step counter
# Final cost : 1.484277928054085
# Compute control for a deterministic system
# Cost in iteration 0: 1.484277928054085
# Converged in iteration 1 with cost 1.484277928054085 because of step counter
# Final cost : 1.484277928054085
# Compute control for a deterministic system
# Cost in iteration 0: 1.484277928054085
# Converged in iteration 1 with cost 1.484277928054085 because of step counter
# Final cost : 1.484277928054085
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 1.420311394642958
# Converged in iteration 4 with cost 1.3562537430366757 because of step counter
# Final cost : 1.3562537430366757
# Compute control for a deterministic system
# Cost in iteration 0: 1.3562537430366757
# Converged in iteration 1 with cost 1.3562537430366757 because of step counter
# Final cost : 1.3562537430366757
# Compute control for a deterministic system
# Cost in iteration 0: 1.3562537430366757
# Converged in iteration 1 with cost 1.3562537430366757 because of step counter
# Final cost : 1.3562537430366757
# Compute control for a deterministic system
# Cost in iteration 0: 1.3562537430366757
# Converged in iteration 1 with cost 1.3562537430366757 because of step counter
# Final cost : 1.3562537430366757
# Compute control for a deterministic system
# Cost in iteration 0: 1.3562537430366757
# Converged in iteration 1 with cost 1.3562537430366757 because of step counter
# Final cost : 1.3562537430366757
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 1.2327640475544015
# Converged in iteration 3 with cost 1.2026287343956568 because of step counter
# Final cost : 1.2026287343956568
# Compute control for a deterministic system
# Cost in iteration 0: 1.2026287343956568
# Converged in iteration 1 with cost 1.2026287343956568 because of step counter
# Final cost : 1.2026287343956568
# Compute control for a deterministic system
# Cost in iteration 0: 1.2026287343956568
# Converged in iteration 1 with cost 1.2026287343956568 because of step counter
# Final cost : 1.2026287343956568
# Compute control for a deterministic system
# Cost in iteration 0: 1.2026287343956568
# Converged in iteration 1 with cost 1.2026287343956568 because of step counter
# Final cost : 1.2026287343956568
# Compute control for a deterministic system
# Cost in iteration 0: 1.2026287343956568
# Converged in iteration 1 with cost 1.2026287343956568 because of step counter
# Final cost : 1.2026287343956568
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 1.1268654016775328
# Converged in iteration 3 with cost 1.0945754048370033 because of step counter
# Final cost : 1.0945754048370033
# Compute control for a deterministic system
# Cost in iteration 0: 1.0945754048370033
# Converged in iteration 1 with cost 1.0945754048370033 because of step counter
# Final cost : 1.0945754048370033
# Compute control for a deterministic system
# Cost in iteration 0: 1.0945754048370033
# Converged in iteration 1 with cost 1.0945754048370033 because of step counter
# Final cost : 1.0945754048370033
# Compute control for a deterministic system
# Cost in iteration 0: 1.0945754048370033
# Converged in iteration 1 with cost 1.0945754048370033 because of step counter
# Final cost : 1.0945754048370033
# Compute control for a deterministic system
# Cost in iteration 0: 1.0945754048370033
# Converged in iteration 1 with cost 1.0945754048370033 because of step counter
# Final cost : 1.0945754048370033
# Compute control for a deterministic system
# Cost in iteration 0: 0.9727896549375419
# Converged in iteration 10 with cost 0.9449176937043167 because of step counter
# Final cost : 0.9449176937043167
# Compute control for a deterministic system
# Cost in iteration 0: 0.9449176937043167
# Converged in iteration 1 with cost 0.9449176937043167 because of step counter
# Final cost : 0.9449176937043167
# Compute control for a deterministic system
# Cost in iteration 0: 0.9449176937043167
# Converged in iteration 1 with cost 0.9449176937043167 because of step counter
# Final cost : 0.9449176937043167
# Compute control for a deterministic system
# Cost in iteration 0: 0.9449176937043167
# Converged in iteration 1 with cost 0.9449176937043167 because of step counter
# Final cost : 0.9449176937043167
# Compute control for a deterministic system
# Cost in iteration 0: 0.9449176937043167
# Converged in iteration 1 with cost 0.9449176937043167 because of step counter
# Final cost : 0.9449176937043167
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.8119987886141689
# Converged in iteration 3 with cost 0.798399810077058 because of step counter
# Final cost : 0.798399810077058
# Compute control for a deterministic system
# Cost in iteration 0: 0.798399810077058
# Converged in iteration 1 with cost 0.798399810077058 because of step counter
# Final cost : 0.798399810077058
# Compute control for a deterministic system
# Cost in iteration 0: 0.798399810077058
# Converged in iteration 1 with cost 0.798399810077058 because of step counter
# Final cost : 0.798399810077058
# Compute control for a deterministic system
# Cost in iteration 0: 0.798399810077058
# Converged in iteration 1 with cost 0.798399810077058 because of step counter
# Final cost : 0.798399810077058
# Compute control for a deterministic system
# Cost in iteration 0: 0.798399810077058
# Converged in iteration 1 with cost 0.798399810077058 because of step counter
# Final cost : 0.798399810077058
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.66265377358731
# Converged in iteration 3 with cost 0.653012192977757 because of step counter
# Final cost : 0.653012192977757
# Compute control for a deterministic system
# Cost in iteration 0: 0.653012192977757
# Converged in iteration 1 with cost 0.653012192977757 because of step counter
# Final cost : 0.653012192977757
# Compute control for a deterministic system
# Cost in iteration 0: 0.653012192977757
# Converged in iteration 1 with cost 0.653012192977757 because of step counter
# Final cost : 0.653012192977757
# Compute control for a deterministic system
# Cost in iteration 0: 0.653012192977757
# Converged in iteration 1 with cost 0.653012192977757 because of step counter
# Final cost : 0.653012192977757
# Compute control for a deterministic system
# Cost in iteration 0: 0.653012192977757
# Converged in iteration 1 with cost 0.653012192977757 because of step counter
# Final cost : 0.653012192977757
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.5338992265347478
# Converged in iteration 2 with cost 0.5334741627911532 because of step counter
# Final cost : 0.5334741627911532
# Compute control for a deterministic system
# Cost in iteration 0: 0.5334741627911532
# Converged in iteration 1 with cost 0.5334741627911532 because of step counter
# Final cost : 0.5334741627911532
# Compute control for a deterministic system
# Cost in iteration 0: 0.5334741627911532
# Converged in iteration 1 with cost 0.5334741627911532 because of step counter
# Final cost : 0.5334741627911532
# Compute control for a deterministic system
# Cost in iteration 0: 0.5334741627911532
# Converged in iteration 1 with cost 0.5334741627911532 because of step counter
# Final cost : 0.5334741627911532
# Compute control for a deterministic system
# Cost in iteration 0: 0.5334741627911532
# Converged in iteration 1 with cost 0.5334741627911532 because of step counter
# Final cost : 0.5334741627911532
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.39052369642870477
# Converged in iteration 12 with cost 0.3884574013455643 because of step counter
# Final cost : 0.3884574013455643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3884574013455643
# Converged in iteration 1 with cost 0.3884574013455643 because of step counter
# Final cost : 0.3884574013455643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3884574013455643
# Converged in iteration 1 with cost 0.3884574013455643 because of step counter
# Final cost : 0.3884574013455643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3884574013455643
# Converged in iteration 1 with cost 0.3884574013455643 because of step counter
# Final cost : 0.3884574013455643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3884574013455643
# Converged in iteration 1 with cost 0.3884574013455643 because of step counter
# Final cost : 0.3884574013455643
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.25801602233000964
# Converged in iteration 2 with cost 0.25789011924849237 because of step counter
# Final cost : 0.25789011924849237
# Compute control for a deterministic system
# Cost in iteration 0: 0.25789011924849237
# Converged in iteration 1 with cost 0.25789011924849237 because of step counter
# Final cost : 0.25789011924849237
# Compute control for a deterministic system
# Cost in iteration 0: 0.25789011924849237
# Converged in iteration 1 with cost 0.25789011924849237 because of step counter
# Final cost : 0.25789011924849237
# Compute control for a deterministic system
# Cost in iteration 0: 0.25789011924849237
# Converged in iteration 1 with cost 0.25789011924849237 because of step counter
# Final cost : 0.25789011924849237
# Compute control for a deterministic system
# Cost in iteration 0: 0.25789011924849237
# Converged in iteration 1 with cost 0.25789011924849237 because of step counter
# Final cost : 0.25789011924849237
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.13247861603312586
# Converged in iteration 2 with cost 0.13243344442825747 because of step counter
# Final cost : 0.13243344442825747
# Compute control for a deterministic system
# Cost in iteration 0: 0.13243344442825747
# Converged in iteration 1 with cost 0.13243344442825747 because of step counter
# Final cost : 0.13243344442825747
# Compute control for a deterministic system
# Cost in iteration 0: 0.13243344442825747
# Converged in iteration 1 with cost 0.13243344442825747 because of step counter
# Final cost : 0.13243344442825747
# Compute control for a deterministic system
# Cost in iteration 0: 0.13243344442825747
# Converged in iteration 1 with cost 0.13243344442825747 because of step counter
# Final cost : 0.13243344442825747
# Compute control for a deterministic system
# Cost in iteration 0: 0.13243344442825747
# Converged in iteration 1 with cost 0.13243344442825747 because of step counter
# Final cost : 0.13243344442825747
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.044464468894700085
# Converged in iteration 1 with cost 0.044464468894700085 because of step counter
# Final cost : 0.044464468894700085
# Compute control for a deterministic system
# Cost in iteration 0: 0.044464468894700085
# Converged in iteration 1 with cost 0.044464468894700085 because of step counter
# Final cost : 0.044464468894700085
# Compute control for a deterministic system
# Cost in iteration 0: 0.044464468894700085
# Converged in iteration 1 with cost 0.044464468894700085 because of step counter
# Final cost : 0.044464468894700085
# Compute control for a deterministic system
# Cost in iteration 0: 0.044464468894700085
# Converged in iteration 1 with cost 0.044464468894700085 because of step counter
# Final cost : 0.044464468894700085
# Compute control for a deterministic system
# Cost in iteration 0: 0.044464468894700085
# Converged in iteration 1 with cost 0.044464468894700085 because of step counter
# Final cost : 0.044464468894700085

# %%
save(results_peak)
