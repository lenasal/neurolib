# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode, ops_plotall
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,174], wc.inh[0,174]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  23  211  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 80.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [1., 2.2, 2.3, 2.4]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
for i_w in [0, 2, 3, 4, 5]:
    for i_shift in range(41):
        results_min["control"][i_w][i_shift] = None

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, True, False, False, False]
#options = [False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w == 0:
            continue


        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-4
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.017424099752564662
# Converged in iteration 14 with cost 0.016576399004861894 because of step counter
# Final cost : 0.016576399004861894
# Compute control for a deterministic system
# Cost in iteration 0: 0.016576399004861894
# Converged in iteration 1 with cost 0.016576399004861894 because of step counter
# Final cost : 0.016576399004861894
# Compute control for a deterministic system
# Cost in iteration 0: 0.016576399004861894
# Converged in iteration 1 with cost 0.016576399004861894 because of step counter
# Final cost : 0.016576399004861894
# Compute control for a deterministic system
# Cost in iteration 0: 0.016576399004861894
# Converged in iteration 1 with cost 0.016576399004861894 because of step counter
# Final cost : 0.016576399004861894
# Compute control for a deterministic system
# Cost in iteration 0: 0.016576399004861894
# Converged in iteration 1 with cost 0.016576399004861894 because of step counter
# Final cost : 0.016576399004861894
# Compute control for a deterministic system
# Cost in iteration 0: 0.07270581679646401
# Converged in iteration 16 with cost 0.05238743854099646 because of step counter
# Final cost : 0.05238743854099646
# Compute control for a deterministic system
# Cost in iteration 0: 0.05238743854099646
# Converged in iteration 1 with cost 0.05238743854099646 because of step counter
# Final cost : 0.05238743854099646
# Compute control for a deterministic system
# Cost in iteration 0: 0.05238743854099646
# Converged in iteration 1 with cost 0.05238743854099646 because of step counter
# Final cost : 0.05238743854099646
# Compute control for a deterministic system
# Cost in iteration 0: 0.05238743854099646
# Converged in iteration 1 with cost 0.05238743854099646 because of step counter
# Final cost : 0.05238743854099646
# Compute control for a deterministic system
# Cost in iteration 0: 0.05238743854099646
# Converged in iteration 1 with cost 0.05238743854099646 because of step counter
# Final cost : 0.05238743854099646
# Compute control for a deterministic system
# Cost in iteration 0: 0.14314203523216112
# Converged in iteration 16 with cost 0.11901364370046369 because of step counter
# Final cost : 0.11901364370046369
# Compute control for a deterministic system
# Cost in iteration 0: 0.11901364370046369
# Converged in iteration 1 with cost 0.11901364370046369 because of step counter
# Final cost : 0.11901364370046369
# Compute control for a deterministic system
# Cost in iteration 0: 0.11901364370046369
# Converged in iteration 1 with cost 0.11901364370046369 because of step counter
# Final cost : 0.11901364370046369
# Compute control for a deterministic system
# Cost in iteration 0: 0.11901364370046369
# Converged in iteration 1 with cost 0.11901364370046369 because of step counter
# Final cost : 0.11901364370046369
# Compute control for a deterministic system
# Cost in iteration 0: 0.11901364370046369
# Converged in iteration 1 with cost 0.11901364370046369 because of step counter
# Final cost : 0.11901364370046369
# -----------------------------------------------
# 2 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.2106207843093203
# Converged in iteration 15 with cost 0.19082826719567333 because of step counter
# Final cost : 0.19082826719567333
# Compute control for a deterministic system
# Cost in iteration 0: 0.19082826719567333
# Converged in iteration 1 with cost 0.19082826719567333 because of step counter
# Final cost : 0.19082826719567333
# Compute control for a deterministic system
# Cost in iteration 0: 0.19082826719567333
# Converged in iteration 1 with cost 0.19082826719567333 because of step counter
# Final cost : 0.19082826719567333
# Compute control for a deterministic system
# Cost in iteration 0: 0.19082826719567333
# Converged in iteration 1 with cost 0.19082826719567333 because of step counter
# Final cost : 0.19082826719567333
# Compute control for a deterministic system
# Cost in iteration 0: 0.19082826719567333
# Converged in iteration 1 with cost 0.19082826719567333 because of step counter
# Final cost : 0.19082826719567333
# -----------------------------------------------
# 2 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.28909710638169583
# Converged in iteration 15 with cost 0.2627567026534625 because of step counter
# Final cost : 0.2627567026534625
# Compute control for a deterministic system
# Cost in iteration 0: 0.2627567026534625
# Converged in iteration 1 with cost 0.2627567026534625 because of step counter
# Final cost : 0.2627567026534625
# Compute control for a deterministic system
# Cost in iteration 0: 0.2627567026534625
# Converged in iteration 1 with cost 0.2627567026534625 because of step counter
# Final cost : 0.2627567026534625
# Compute control for a deterministic system
# Cost in iteration 0: 0.2627567026534625
# Converged in iteration 1 with cost 0.2627567026534625 because of step counter
# Final cost : 0.2627567026534625
# Compute control for a deterministic system
# Cost in iteration 0: 0.2627567026534625
# Converged in iteration 1 with cost 0.2627567026534625 because of step counter
# Final cost : 0.2627567026534625
# -----------------------------------------------
# 2 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.3341438380597878
# Converged in iteration 12 with cost 0.3200684569707375 because of step counter
# Final cost : 0.3200684569707375
# Compute control for a deterministic system
# Cost in iteration 0: 0.3200684569707375
# Converged in iteration 1 with cost 0.3200684569707375 because of step counter
# Final cost : 0.3200684569707375
# Compute control for a deterministic system
# Cost in iteration 0: 0.3200684569707375
# Converged in iteration 1 with cost 0.3200684569707375 because of step counter
# Final cost : 0.3200684569707375
# Compute control for a deterministic system
# Cost in iteration 0: 0.3200684569707375
# Converged in iteration 1 with cost 0.3200684569707375 because of step counter
# Final cost : 0.3200684569707375
# Compute control for a deterministic system
# Cost in iteration 0: 0.3200684569707375
# Converged in iteration 1 with cost 0.3200684569707375 because of step counter
# Final cost : 0.3200684569707375
# -----------------------------------------------
# 2 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.41150563046814576
# Converged in iteration 12 with cost 0.39133726498997695 because of step counter
# Final cost : 0.39133726498997695
# Compute control for a deterministic system
# Cost in iteration 0: 0.39133726498997695
# Converged in iteration 1 with cost 0.39133726498997695 because of step counter
# Final cost : 0.39133726498997695
# Compute control for a deterministic system
# Cost in iteration 0: 0.39133726498997695
# Converged in iteration 1 with cost 0.39133726498997695 because of step counter
# Final cost : 0.39133726498997695
# Compute control for a deterministic system
# Cost in iteration 0: 0.39133726498997695
# Converged in iteration 1 with cost 0.39133726498997695 because of step counter
# Final cost : 0.39133726498997695
# Compute control for a deterministic system
# Cost in iteration 0: 0.39133726498997695
# Converged in iteration 1 with cost 0.39133726498997695 because of step counter
# Final cost : 0.39133726498997695
# -----------------------------------------------
# 2 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.4900016238205014
# Converged in iteration 14 with cost 0.4620851023317947 because of step counter
# Final cost : 0.4620851023317947
# Compute control for a deterministic system
# Cost in iteration 0: 0.4620851023317947
# Converged in iteration 1 with cost 0.4620851023317947 because of step counter
# Final cost : 0.4620851023317947
# Compute control for a deterministic system
# Cost in iteration 0: 0.4620851023317947
# Converged in iteration 1 with cost 0.4620851023317947 because of step counter
# Final cost : 0.4620851023317947
# Compute control for a deterministic system
# Cost in iteration 0: 0.4620851023317947
# Converged in iteration 1 with cost 0.4620851023317947 because of step counter
# Final cost : 0.4620851023317947
# Compute control for a deterministic system
# Cost in iteration 0: 0.4620851023317947
# Converged in iteration 1 with cost 0.4620851023317947 because of step counter
# Final cost : 0.4620851023317947
# -----------------------------------------------
# 2 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.5440902831183432
# Converged in iteration 9 with cost 0.5322040927975675 because of step counter
# Final cost : 0.5322040927975675
# Compute control for a deterministic system
# Cost in iteration 0: 0.5322040927975675
# Converged in iteration 1 with cost 0.5322040927975675 because of step counter
# Final cost : 0.5322040927975675
# Compute control for a deterministic system
# Cost in iteration 0: 0.5322040927975675
# Converged in iteration 1 with cost 0.5322040927975675 because of step counter
# Final cost : 0.5322040927975675
# Compute control for a deterministic system
# Cost in iteration 0: 0.5322040927975675
# Converged in iteration 1 with cost 0.5322040927975675 because of step counter
# Final cost : 0.5322040927975675
# Compute control for a deterministic system
# Cost in iteration 0: 0.5322040927975675
# Converged in iteration 1 with cost 0.5322040927975675 because of step counter
# Final cost : 0.5322040927975675
# -----------------------------------------------
# 2 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.6220750615664034
# Converged in iteration 15 with cost 0.5877720372929399 because of step counter
# Final cost : 0.5877720372929399
# Compute control for a deterministic system
# Cost in iteration 0: 0.5877720372929399
# Converged in iteration 1 with cost 0.5877720372929399 because of step counter
# Final cost : 0.5877720372929399
# Compute control for a deterministic system
# Cost in iteration 0: 0.5877720372929399
# Converged in iteration 1 with cost 0.5877720372929399 because of step counter
# Final cost : 0.5877720372929399
# Compute control for a deterministic system
# Cost in iteration 0: 0.5877720372929399
# Converged in iteration 1 with cost 0.5877720372929399 because of step counter
# Final cost : 0.5877720372929399
# Compute control for a deterministic system
# Cost in iteration 0: 0.5877720372929399
# Converged in iteration 1 with cost 0.5877720372929399 because of step counter
# Final cost : 0.5877720372929399
# -----------------------------------------------
# 2 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.6640917728322456
# Converged in iteration 8 with cost 0.6564301953507058 because of step counter
# Final cost : 0.6564301953507058
# Compute control for a deterministic system
# Cost in iteration 0: 0.6564301953507058
# Converged in iteration 1 with cost 0.6564301953507058 because of step counter
# Final cost : 0.6564301953507058
# Compute control for a deterministic system
# Cost in iteration 0: 0.6564301953507058
# Converged in iteration 1 with cost 0.6564301953507058 because of step counter
# Final cost : 0.6564301953507058
# Compute control for a deterministic system
# Cost in iteration 0: 0.6564301953507058
# Converged in iteration 1 with cost 0.6564301953507058 because of step counter
# Final cost : 0.6564301953507058
# Compute control for a deterministic system
# Cost in iteration 0: 0.6564301953507058
# Converged in iteration 1 with cost 0.6564301953507058 because of step counter
# Final cost : 0.6564301953507058
# -----------------------------------------------
# 2 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.7298193469245208
# Converged in iteration 9 with cost 0.7241443090267551 because of step counter
# Final cost : 0.7241443090267551
# Compute control for a deterministic system
# Cost in iteration 0: 0.7241443090267551
# Converged in iteration 1 with cost 0.7241443090267551 because of step counter
# Final cost : 0.7241443090267551
# Compute control for a deterministic system
# Cost in iteration 0: 0.7241443090267551
# Converged in iteration 1 with cost 0.7241443090267551 because of step counter
# Final cost : 0.7241443090267551
# Compute control for a deterministic system
# Cost in iteration 0: 0.7241443090267551
# Converged in iteration 1 with cost 0.7241443090267551 because of step counter
# Final cost : 0.7241443090267551
# Compute control for a deterministic system
# Cost in iteration 0: 0.7241443090267551
# Converged in iteration 1 with cost 0.7241443090267551 because of step counter
# Final cost : 0.7241443090267551
# -----------------------------------------------
# 2 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.7853165531926223
# Converged in iteration 9 with cost 0.7774687003309938 because of step counter
# Final cost : 0.7774687003309938
# Compute control for a deterministic system
# Cost in iteration 0: 0.7774687003309938
# Converged in iteration 1 with cost 0.7774687003309938 because of step counter
# Final cost : 0.7774687003309938
# Compute control for a deterministic system
# Cost in iteration 0: 0.7774687003309938
# Converged in iteration 1 with cost 0.7774687003309938 because of step counter
# Final cost : 0.7774687003309938
# Compute control for a deterministic system
# Cost in iteration 0: 0.7774687003309938
# Converged in iteration 1 with cost 0.7774687003309938 because of step counter
# Final cost : 0.7774687003309938
# Compute control for a deterministic system
# Cost in iteration 0: 0.7774687003309938
# Converged in iteration 1 with cost 0.7774687003309938 because of step counter
# Final cost : 0.7774687003309938
# -----------------------------------------------
# 2 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.8555602982951546
# Converged in iteration 9 with cost 0.8428591938349811 because of step counter
# Final cost : 0.8428591938349811
# Compute control for a deterministic system
# Cost in iteration 0: 0.8428591938349811
# Converged in iteration 1 with cost 0.8428591938349811 because of step counter
# Final cost : 0.8428591938349811
# Compute control for a deterministic system
# Cost in iteration 0: 0.8428591938349811
# Converged in iteration 1 with cost 0.8428591938349811 because of step counter
# Final cost : 0.8428591938349811
# Compute control for a deterministic system
# Cost in iteration 0: 0.8428591938349811
# Converged in iteration 1 with cost 0.8428591938349811 because of step counter
# Final cost : 0.8428591938349811
# Compute control for a deterministic system
# Cost in iteration 0: 0.8428591938349811
# Converged in iteration 1 with cost 0.8428591938349811 because of step counter
# Final cost : 0.8428591938349811
# -----------------------------------------------
# 2 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.9074546711281074
# Converged in iteration 3 with cost 0.9074546528632994 because of step counter
# Final cost : 0.9074546528632994
# Compute control for a deterministic system
# Cost in iteration 0: 0.9074546528632994
# Converged in iteration 1 with cost 0.9074546528632994 because of step counter
# Final cost : 0.9074546528632994
# Compute control for a deterministic system
# Cost in iteration 0: 0.9074546528632994
# Converged in iteration 1 with cost 0.9074546528632994 because of step counter
# Final cost : 0.9074546528632994
# Compute control for a deterministic system
# Cost in iteration 0: 0.9074546528632994
# Converged in iteration 1 with cost 0.9074546528632994 because of step counter
# Final cost : 0.9074546528632994
# Compute control for a deterministic system
# Cost in iteration 0: 0.9074546528632994
# Converged in iteration 1 with cost 0.9074546528632994 because of step counter
# Final cost : 0.9074546528632994
# -----------------------------------------------
# 2 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 1.009124141733978
# Converged in iteration 13 with cost 0.966375272617269 because of step counter
# Final cost : 0.966375272617269
# Compute control for a deterministic system
# Cost in iteration 0: 0.966375272617269
# Converged in iteration 1 with cost 0.966375272617269 because of step counter
# Final cost : 0.966375272617269
# Compute control for a deterministic system
# Cost in iteration 0: 0.966375272617269
# Converged in iteration 1 with cost 0.966375272617269 because of step counter
# Final cost : 0.966375272617269
# Compute control for a deterministic system
# Cost in iteration 0: 0.966375272617269
# Converged in iteration 1 with cost 0.966375272617269 because of step counter
# Final cost : 0.966375272617269
# Compute control for a deterministic system
# Cost in iteration 0: 0.966375272617269
# Converged in iteration 1 with cost 0.966375272617269 because of step counter
# Final cost : 0.966375272617269
# -----------------------------------------------
# 2 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180430393632847
# Converged in iteration 2 with cost 1.0180430348634055 because of step counter
# Final cost : 1.0180430348634055
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180430348634055
# Converged in iteration 1 with cost 1.0180430348634055 because of step counter
# Final cost : 1.0180430348634055
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180430348634055
# Converged in iteration 1 with cost 1.0180430348634055 because of step counter
# Final cost : 1.0180430348634055
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180430348634055
# Converged in iteration 1 with cost 1.0180430348634055 because of step counter
# Final cost : 1.0180430348634055
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180430348634055
# Converged in iteration 1 with cost 1.0180430348634055 because of step counter
# Final cost : 1.0180430348634055
# -----------------------------------------------
# 2 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 1.0905901162745657
# Converged in iteration 11 with cost 1.0714417081817909 because of step counter
# Final cost : 1.0714417081817909
# Compute control for a deterministic system
# Cost in iteration 0: 1.0714417081817909
# Converged in iteration 1 with cost 1.0714417081817909 because of step counter
# Final cost : 1.0714417081817909
# Compute control for a deterministic system
# Cost in iteration 0: 1.0714417081817909
# Converged in iteration 1 with cost 1.0714417081817909 because of step counter
# Final cost : 1.0714417081817909
# Compute control for a deterministic system
# Cost in iteration 0: 1.0714417081817909
# Converged in iteration 1 with cost 1.0714417081817909 because of step counter
# Final cost : 1.0714417081817909
# Compute control for a deterministic system
# Cost in iteration 0: 1.0714417081817909
# Converged in iteration 1 with cost 1.0714417081817909 because of step counter
# Final cost : 1.0714417081817909
# -----------------------------------------------
# 2 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 1.0958248318216475
# Converged in iteration 5 with cost 1.0837189750219585 because of step counter
# Final cost : 1.0837189750219585
# Compute control for a deterministic system
# Cost in iteration 0: 1.0837189750219585
# Converged in iteration 1 with cost 1.0837189750219585 because of step counter
# Final cost : 1.0837189750219585
# Compute control for a deterministic system
# Cost in iteration 0: 1.0837189750219585
# Converged in iteration 1 with cost 1.0837189750219585 because of step counter
# Final cost : 1.0837189750219585
# Compute control for a deterministic system
# Cost in iteration 0: 1.0837189750219585
# Converged in iteration 1 with cost 1.0837189750219585 because of step counter
# Final cost : 1.0837189750219585
# Compute control for a deterministic system
# Cost in iteration 0: 1.0837189750219585
# Converged in iteration 1 with cost 1.0837189750219585 because of step counter
# Final cost : 1.0837189750219585
# -----------------------------------------------
# 2 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 1.1051588487272948
# Converged in iteration 5 with cost 1.0973668871061042 because of step counter
# Final cost : 1.0973668871061042
# Compute control for a deterministic system
# Cost in iteration 0: 1.0973668871061042
# Converged in iteration 1 with cost 1.0973668871061042 because of step counter
# Final cost : 1.0973668871061042
# Compute control for a deterministic system
# Cost in iteration 0: 1.0973668871061042
# Converged in iteration 1 with cost 1.0973668871061042 because of step counter
# Final cost : 1.0973668871061042
# Compute control for a deterministic system
# Cost in iteration 0: 1.0973668871061042
# Converged in iteration 1 with cost 1.0973668871061042 because of step counter
# Final cost : 1.0973668871061042
# Compute control for a deterministic system
# Cost in iteration 0: 1.0973668871061042
# Converged in iteration 1 with cost 1.0973668871061042 because of step counter
# Final cost : 1.0973668871061042
# -----------------------------------------------
# 2 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 1.2800797133589588
# Converged in iteration 52 with cost 1.115917053467021 because of step counter
# Final cost : 1.115917053467021
# Compute control for a deterministic system
# Cost in iteration 0: 1.115917053467021
# Converged in iteration 1 with cost 1.115917053467021 because of step counter
# Final cost : 1.115917053467021
# Compute control for a deterministic system
# Cost in iteration 0: 1.115917053467021
# Converged in iteration 1 with cost 1.115917053467021 because of step counter
# Final cost : 1.115917053467021
# Compute control for a deterministic system
# Cost in iteration 0: 1.115917053467021
# Converged in iteration 1 with cost 1.115917053467021 because of step counter
# Final cost : 1.115917053467021
# Compute control for a deterministic system
# Cost in iteration 0: 1.115917053467021
# Converged in iteration 1 with cost 1.115917053467021 because of step counter
# Final cost : 1.115917053467021
# -----------------------------------------------
# 2 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 1.185515417992494
# Converged in iteration 7 with cost 1.117614331443445 because of step counter
# Final cost : 1.117614331443445
# Compute control for a deterministic system
# Cost in iteration 0: 1.117614331443445
# Converged in iteration 1 with cost 1.117614331443445 because of step counter
# Final cost : 1.117614331443445
# Compute control for a deterministic system
# Cost in iteration 0: 1.117614331443445
# Converged in iteration 1 with cost 1.117614331443445 because of step counter
# Final cost : 1.117614331443445
# Compute control for a deterministic system
# Cost in iteration 0: 1.117614331443445
# Converged in iteration 1 with cost 1.117614331443445 because of step counter
# Final cost : 1.117614331443445
# Compute control for a deterministic system
# Cost in iteration 0: 1.117614331443445
# Converged in iteration 1 with cost 1.117614331443445 because of step counter
# Final cost : 1.117614331443445
# -----------------------------------------------
# 2 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 1.2495250192364926
# Converged in iteration 5 with cost 1.122691197590763 because of step counter
# Final cost : 1.122691197590763
# Compute control for a deterministic system
# Cost in iteration 0: 1.122691197590763
# Converged in iteration 1 with cost 1.122691197590763 because of step counter
# Final cost : 1.122691197590763
# Compute control for a deterministic system
# Cost in iteration 0: 1.122691197590763
# Converged in iteration 1 with cost 1.122691197590763 because of step counter
# Final cost : 1.122691197590763
# Compute control for a deterministic system
# Cost in iteration 0: 1.122691197590763
# Converged in iteration 1 with cost 1.122691197590763 because of step counter
# Final cost : 1.122691197590763
# Compute control for a deterministic system
# Cost in iteration 0: 1.122691197590763
# Converged in iteration 1 with cost 1.122691197590763 because of step counter
# Final cost : 1.122691197590763
# -----------------------------------------------
# 2 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 1.094925964355394
# Converged in iteration 11 with cost 1.0636019152946936 because of step counter
# Final cost : 1.0636019152946936
# Compute control for a deterministic system
# Cost in iteration 0: 1.0636019152946936
# Converged in iteration 1 with cost 1.0636019152946936 because of step counter
# Final cost : 1.0636019152946936
# Compute control for a deterministic system
# Cost in iteration 0: 1.0636019152946936
# Converged in iteration 1 with cost 1.0636019152946936 because of step counter
# Final cost : 1.0636019152946936
# Compute control for a deterministic system
# Cost in iteration 0: 1.0636019152946936
# Converged in iteration 1 with cost 1.0636019152946936 because of step counter
# Final cost : 1.0636019152946936
# Compute control for a deterministic system
# Cost in iteration 0: 1.0636019152946936
# Converged in iteration 1 with cost 1.0636019152946936 because of step counter
# Final cost : 1.0636019152946936
# -----------------------------------------------
# 2 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 1.0212157260143835
# Converged in iteration 12 with cost 0.978789802230312 because of step counter
# Final cost : 0.978789802230312
# Compute control for a deterministic system
# Cost in iteration 0: 0.978789802230312
# Converged in iteration 1 with cost 0.978789802230312 because of step counter
# Final cost : 0.978789802230312
# Compute control for a deterministic system
# Cost in iteration 0: 0.978789802230312
# Converged in iteration 1 with cost 0.978789802230312 because of step counter
# Final cost : 0.978789802230312
# Compute control for a deterministic system
# Cost in iteration 0: 0.978789802230312
# Converged in iteration 1 with cost 0.978789802230312 because of step counter
# Final cost : 0.978789802230312
# Compute control for a deterministic system
# Cost in iteration 0: 0.978789802230312
# Converged in iteration 1 with cost 0.978789802230312 because of step counter
# Final cost : 0.978789802230312
# -----------------------------------------------
# 2 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.8991295513044338
# Converged in iteration 5 with cost 0.8968880484635042 because of step counter
# Final cost : 0.8968880484635042
# Compute control for a deterministic system
# Cost in iteration 0: 0.8968880484635042
# Converged in iteration 1 with cost 0.8968880484635042 because of step counter
# Final cost : 0.8968880484635042
# Compute control for a deterministic system
# Cost in iteration 0: 0.8968880484635042
# Converged in iteration 1 with cost 0.8968880484635042 because of step counter
# Final cost : 0.8968880484635042
# Compute control for a deterministic system
# Cost in iteration 0: 0.8968880484635042
# Converged in iteration 1 with cost 0.8968880484635042 because of step counter
# Final cost : 0.8968880484635042
# Compute control for a deterministic system
# Cost in iteration 0: 0.8968880484635042
# Converged in iteration 1 with cost 0.8968880484635042 because of step counter
# Final cost : 0.8968880484635042
# -----------------------------------------------
# 2 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.8509817550851445
# Converged in iteration 12 with cost 0.8176351553208364 because of step counter
# Final cost : 0.8176351553208364
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176351553208364
# Converged in iteration 1 with cost 0.8176351553208364 because of step counter
# Final cost : 0.8176351553208364
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176351553208364
# Converged in iteration 1 with cost 0.8176351553208364 because of step counter
# Final cost : 0.8176351553208364
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176351553208364
# Converged in iteration 1 with cost 0.8176351553208364 because of step counter
# Final cost : 0.8176351553208364
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176351553208364
# Converged in iteration 1 with cost 0.8176351553208364 because of step counter
# Final cost : 0.8176351553208364
# -----------------------------------------------
# 2 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.7629719112012282
# Converged in iteration 7 with cost 0.7557480182304533 because of step counter
# Final cost : 0.7557480182304533
# Compute control for a deterministic system
# Cost in iteration 0: 0.7557480182304533
# Converged in iteration 1 with cost 0.7557480182304533 because of step counter
# Final cost : 0.7557480182304533
# Compute control for a deterministic system
# Cost in iteration 0: 0.7557480182304533
# Converged in iteration 1 with cost 0.7557480182304533 because of step counter
# Final cost : 0.7557480182304533
# Compute control for a deterministic system
# Cost in iteration 0: 0.7557480182304533
# Converged in iteration 1 with cost 0.7557480182304533 because of step counter
# Final cost : 0.7557480182304533
# Compute control for a deterministic system
# Cost in iteration 0: 0.7557480182304533
# Converged in iteration 1 with cost 0.7557480182304533 because of step counter
# Final cost : 0.7557480182304533
# -----------------------------------------------
# 2 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.7081060209474866
# Converged in iteration 12 with cost 0.6796992960108538 because of step counter
# Final cost : 0.6796992960108538
# Compute control for a deterministic system
# Cost in iteration 0: 0.6796992960108538
# Converged in iteration 1 with cost 0.6796992960108538 because of step counter
# Final cost : 0.6796992960108538
# Compute control for a deterministic system
# Cost in iteration 0: 0.6796992960108538
# Converged in iteration 1 with cost 0.6796992960108538 because of step counter
# Final cost : 0.6796992960108538
# Compute control for a deterministic system
# Cost in iteration 0: 0.6796992960108538
# Converged in iteration 1 with cost 0.6796992960108538 because of step counter
# Final cost : 0.6796992960108538
# Compute control for a deterministic system
# Cost in iteration 0: 0.6796992960108538
# Converged in iteration 1 with cost 0.6796992960108538 because of step counter
# Final cost : 0.6796992960108538
# -----------------------------------------------
# 2 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.635893355670242
# Converged in iteration 13 with cost 0.6047093153174359 because of step counter
# Final cost : 0.6047093153174359
# Compute control for a deterministic system
# Cost in iteration 0: 0.6047093153174359
# Converged in iteration 1 with cost 0.6047093153174359 because of step counter
# Final cost : 0.6047093153174359
# Compute control for a deterministic system
# Cost in iteration 0: 0.6047093153174359
# Converged in iteration 1 with cost 0.6047093153174359 because of step counter
# Final cost : 0.6047093153174359
# Compute control for a deterministic system
# Cost in iteration 0: 0.6047093153174359
# Converged in iteration 1 with cost 0.6047093153174359 because of step counter
# Final cost : 0.6047093153174359
# Compute control for a deterministic system
# Cost in iteration 0: 0.6047093153174359
# Converged in iteration 1 with cost 0.6047093153174359 because of step counter
# Final cost : 0.6047093153174359
# -----------------------------------------------
# 2 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.5713747097962011
# Converged in iteration 12 with cost 0.5451810682564094 because of step counter
# Final cost : 0.5451810682564094
# Compute control for a deterministic system
# Cost in iteration 0: 0.5451810682564094
# Converged in iteration 1 with cost 0.5451810682564094 because of step counter
# Final cost : 0.5451810682564094
# Compute control for a deterministic system
# Cost in iteration 0: 0.5451810682564094
# Converged in iteration 1 with cost 0.5451810682564094 because of step counter
# Final cost : 0.5451810682564094
# Compute control for a deterministic system
# Cost in iteration 0: 0.5451810682564094
# Converged in iteration 1 with cost 0.5451810682564094 because of step counter
# Final cost : 0.5451810682564094
# Compute control for a deterministic system
# Cost in iteration 0: 0.5451810682564094
# Converged in iteration 1 with cost 0.5451810682564094 because of step counter
# Final cost : 0.5451810682564094
# -----------------------------------------------
# 2 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.49405024456636965
# Converged in iteration 12 with cost 0.4711679705187142 because of step counter
# Final cost : 0.4711679705187142
# Compute control for a deterministic system
# Cost in iteration 0: 0.4711679705187142
# Converged in iteration 1 with cost 0.4711679705187142 because of step counter
# Final cost : 0.4711679705187142
# Compute control for a deterministic system
# Cost in iteration 0: 0.4711679705187142
# Converged in iteration 1 with cost 0.4711679705187142 because of step counter
# Final cost : 0.4711679705187142
# Compute control for a deterministic system
# Cost in iteration 0: 0.4711679705187142
# Converged in iteration 1 with cost 0.4711679705187142 because of step counter
# Final cost : 0.4711679705187142
# Compute control for a deterministic system
# Cost in iteration 0: 0.4711679705187142
# Converged in iteration 1 with cost 0.4711679705187142 because of step counter
# Final cost : 0.4711679705187142
# -----------------------------------------------
# 2 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.41504441492356037
# Converged in iteration 13 with cost 0.39741602873805054 because of step counter
# Final cost : 0.39741602873805054
# Compute control for a deterministic system
# Cost in iteration 0: 0.39741602873805054
# Converged in iteration 1 with cost 0.39741602873805054 because of step counter
# Final cost : 0.39741602873805054
# Compute control for a deterministic system
# Cost in iteration 0: 0.39741602873805054
# Converged in iteration 1 with cost 0.39741602873805054 because of step counter
# Final cost : 0.39741602873805054
# Compute control for a deterministic system
# Cost in iteration 0: 0.39741602873805054
# Converged in iteration 1 with cost 0.39741602873805054 because of step counter
# Final cost : 0.39741602873805054
# Compute control for a deterministic system
# Cost in iteration 0: 0.39741602873805054
# Converged in iteration 1 with cost 0.39741602873805054 because of step counter
# Final cost : 0.39741602873805054
# -----------------------------------------------
# 2 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.34060751867850186
# Converged in iteration 13 with cost 0.32382321934182345 because of step counter
# Final cost : 0.32382321934182345
# Compute control for a deterministic system
# Cost in iteration 0: 0.32382321934182345
# Converged in iteration 1 with cost 0.32382321934182345 because of step counter
# Final cost : 0.32382321934182345
# Compute control for a deterministic system
# Cost in iteration 0: 0.32382321934182345
# Converged in iteration 1 with cost 0.32382321934182345 because of step counter
# Final cost : 0.32382321934182345
# Compute control for a deterministic system
# Cost in iteration 0: 0.32382321934182345
# Converged in iteration 1 with cost 0.32382321934182345 because of step counter
# Final cost : 0.32382321934182345
# Compute control for a deterministic system
# Cost in iteration 0: 0.32382321934182345
# Converged in iteration 1 with cost 0.32382321934182345 because of step counter
# Final cost : 0.32382321934182345
# -----------------------------------------------
# 2 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.287291049578704
# Converged in iteration 15 with cost 0.2650146048659299 because of step counter
# Final cost : 0.2650146048659299
# Compute control for a deterministic system
# Cost in iteration 0: 0.2650146048659299
# Converged in iteration 1 with cost 0.2650146048659299 because of step counter
# Final cost : 0.2650146048659299
# Compute control for a deterministic system
# Cost in iteration 0: 0.2650146048659299
# Converged in iteration 1 with cost 0.2650146048659299 because of step counter
# Final cost : 0.2650146048659299
# Compute control for a deterministic system
# Cost in iteration 0: 0.2650146048659299
# Converged in iteration 1 with cost 0.2650146048659299 because of step counter
# Final cost : 0.2650146048659299
# Compute control for a deterministic system
# Cost in iteration 0: 0.2650146048659299
# Converged in iteration 1 with cost 0.2650146048659299 because of step counter
# Final cost : 0.2650146048659299
# -----------------------------------------------
# 2 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.21314636392029246
# Converged in iteration 15 with cost 0.1916245312934422 because of step counter
# Final cost : 0.1916245312934422
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916245312934422
# Converged in iteration 1 with cost 0.1916245312934422 because of step counter
# Final cost : 0.1916245312934422
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916245312934422
# Converged in iteration 1 with cost 0.1916245312934422 because of step counter
# Final cost : 0.1916245312934422
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916245312934422
# Converged in iteration 1 with cost 0.1916245312934422 because of step counter
# Final cost : 0.1916245312934422
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916245312934422
# Converged in iteration 1 with cost 0.1916245312934422 because of step counter
# Final cost : 0.1916245312934422
# -----------------------------------------------
# 2 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.14394209530284655
# Converged in iteration 16 with cost 0.11877988492739912 because of step counter
# Final cost : 0.11877988492739912
# Compute control for a deterministic system
# Cost in iteration 0: 0.11877988492739912
# Converged in iteration 1 with cost 0.11877988492739912 because of step counter
# Final cost : 0.11877988492739912
# Compute control for a deterministic system
# Cost in iteration 0: 0.11877988492739912
# Converged in iteration 1 with cost 0.11877988492739912 because of step counter
# Final cost : 0.11877988492739912
# Compute control for a deterministic system
# Cost in iteration 0: 0.11877988492739912
# Converged in iteration 1 with cost 0.11877988492739912 because of step counter
# Final cost : 0.11877988492739912
# Compute control for a deterministic system
# Cost in iteration 0: 0.11877988492739912
# Converged in iteration 1 with cost 0.11877988492739912 because of step counter
# Final cost : 0.11877988492739912
# -----------------------------------------------
# 2 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0742457627902684
# Converged in iteration 23 with cost 0.05195651472420428 because of step counter
# Final cost : 0.05195651472420428
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651472420428
# Converged in iteration 1 with cost 0.05195651472420428 because of step counter
# Final cost : 0.05195651472420428
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651472420428
# Converged in iteration 1 with cost 0.05195651472420428 because of step counter
# Final cost : 0.05195651472420428
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651472420428
# Converged in iteration 1 with cost 0.05195651472420428 because of step counter
# Final cost : 0.05195651472420428
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651472420428
# Converged in iteration 1 with cost 0.05195651472420428 because of step counter
# Final cost : 0.05195651472420428
# Compute control for a deterministic system
# Cost in iteration 0: 0.01670557725888172
# Converged in iteration 13 with cost 0.016307809070283643 because of vanishing difference
# Final cost : 0.016307809070283643
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307809070283643
# Converged in iteration 1 with cost 0.016307809070283643 because of step counter
# Final cost : 0.016307809070283643
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307809070283643
# Converged in iteration 1 with cost 0.016307809070283643 because of step counter
# Final cost : 0.016307809070283643
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307809070283643
# Converged in iteration 1 with cost 0.016307809070283643 because of step counter
# Final cost : 0.016307809070283643
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307809070283643
# Converged in iteration 1 with cost 0.016307809070283643 because of step counter
# Final cost : 0.016307809070283643
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.01657639035208299
# Converged in iteration 1 with cost 0.01657639035208299 because of step counter
# Final cost : 0.01657639035208299
# Compute control for a deterministic system
# Cost in iteration 0: 0.01657639035208299
# Converged in iteration 1 with cost 0.01657639035208299 because of step counter
# Final cost : 0.01657639035208299
# Compute control for a deterministic system
# Cost in iteration 0: 0.01657639035208299
# Converged in iteration 1 with cost 0.01657639035208299 because of step counter
# Final cost : 0.01657639035208299
# Compute control for a deterministic system
# Cost in iteration 0: 0.01657639035208299
# Converged in iteration 1 with cost 0.01657639035208299 because of step counter
# Final cost : 0.01657639035208299
# Compute control for a deterministic system
# Cost in iteration 0: 0.01657639035208299
# Converged in iteration 1 with cost 0.01657639035208299 because of step counter
# Final cost : 0.01657639035208299
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.12025708519536964
# Converged in iteration 3 with cost 0.12001830923156896 because of step counter
# Final cost : 0.12001830923156896
# Compute control for a deterministic system
# Cost in iteration 0: 0.12001830923156896
# Converged in iteration 1 with cost 0.12001830923156896 because of step counter
# Final cost : 0.12001830923156896
# Compute control for a deterministic system
# Cost in iteration 0: 0.12001830923156896
# Converged in iteration 1 with cost 0.12001830923156896 because of step counter
# Final cost : 0.12001830923156896
# Compute control for a deterministic system
# Cost in iteration 0: 0.12001830923156896
# Converged in iteration 1 with cost 0.12001830923156896 because of step counter
# Final cost : 0.12001830923156896
# Compute control for a deterministic system
# Cost in iteration 0: 0.12001830923156896
# Converged in iteration 1 with cost 0.12001830923156896 because of step counter
# Final cost : 0.12001830923156896
# -----------------------------------------------
# 2 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.19534635287125734
# Converged in iteration 3 with cost 0.19512725449384205 because of step counter
# Final cost : 0.19512725449384205
# Compute control for a deterministic system
# Cost in iteration 0: 0.19512725449384205
# Converged in iteration 1 with cost 0.19512725449384205 because of step counter
# Final cost : 0.19512725449384205
# Compute control for a deterministic system
# Cost in iteration 0: 0.19512725449384205
# Converged in iteration 1 with cost 0.19512725449384205 because of step counter
# Final cost : 0.19512725449384205
# Compute control for a deterministic system
# Cost in iteration 0: 0.19512725449384205
# Converged in iteration 1 with cost 0.19512725449384205 because of step counter
# Final cost : 0.19512725449384205
# Compute control for a deterministic system
# Cost in iteration 0: 0.19512725449384205
# Converged in iteration 1 with cost 0.19512725449384205 because of step counter
# Final cost : 0.19512725449384205
# -----------------------------------------------
# 2 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.27091316808233473
# Converged in iteration 3 with cost 0.27091315185293496 because of step counter
# Final cost : 0.27091315185293496
# Compute control for a deterministic system
# Cost in iteration 0: 0.27091315185293496
# Converged in iteration 1 with cost 0.27091315185293496 because of step counter
# Final cost : 0.27091315185293496
# Compute control for a deterministic system
# Cost in iteration 0: 0.27091315185293496
# Converged in iteration 1 with cost 0.27091315185293496 because of step counter
# Final cost : 0.27091315185293496
# Compute control for a deterministic system
# Cost in iteration 0: 0.27091315185293496
# Converged in iteration 1 with cost 0.27091315185293496 because of step counter
# Final cost : 0.27091315185293496
# Compute control for a deterministic system
# Cost in iteration 0: 0.27091315185293496
# Converged in iteration 1 with cost 0.27091315185293496 because of step counter
# Final cost : 0.27091315185293496
# -----------------------------------------------
# 2 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.3309831388010669
# Converged in iteration 3 with cost 0.33082429414435405 because of step counter
# Final cost : 0.33082429414435405
# Compute control for a deterministic system
# Cost in iteration 0: 0.33082429414435405
# Converged in iteration 1 with cost 0.33082429414435405 because of step counter
# Final cost : 0.33082429414435405
# Compute control for a deterministic system
# Cost in iteration 0: 0.33082429414435405
# Converged in iteration 1 with cost 0.33082429414435405 because of step counter
# Final cost : 0.33082429414435405
# Compute control for a deterministic system
# Cost in iteration 0: 0.33082429414435405
# Converged in iteration 1 with cost 0.33082429414435405 because of step counter
# Final cost : 0.33082429414435405
# Compute control for a deterministic system
# Cost in iteration 0: 0.33082429414435405
# Converged in iteration 1 with cost 0.33082429414435405 because of step counter
# Final cost : 0.33082429414435405
# -----------------------------------------------
# 2 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.40603354847667694
# Converged in iteration 1 with cost 0.40603354847667694 because of step counter
# Final cost : 0.40603354847667694
# Compute control for a deterministic system
# Cost in iteration 0: 0.40603354847667694
# Converged in iteration 1 with cost 0.40603354847667694 because of step counter
# Final cost : 0.40603354847667694
# Compute control for a deterministic system
# Cost in iteration 0: 0.40603354847667694
# Converged in iteration 1 with cost 0.40603354847667694 because of step counter
# Final cost : 0.40603354847667694
# Compute control for a deterministic system
# Cost in iteration 0: 0.40603354847667694
# Converged in iteration 1 with cost 0.40603354847667694 because of step counter
# Final cost : 0.40603354847667694
# Compute control for a deterministic system
# Cost in iteration 0: 0.40603354847667694
# Converged in iteration 1 with cost 0.40603354847667694 because of step counter
# Final cost : 0.40603354847667694
# -----------------------------------------------
# 2 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.4805374078867226
# Converged in iteration 4 with cost 0.479579213603971 because of step counter
# ...
# Final cost : 1.153066756076697
# Compute control for a deterministic system
# Cost in iteration 0: 1.153066756076697
# Converged in iteration 1 with cost 1.153066756076697 because of step counter
# Final cost : 1.153066756076697
# Compute control for a deterministic system
# Cost in iteration 0: 1.153066756076697
# Converged in iteration 1 with cost 1.153066756076697 because of step counter
# Final cost : 1.153066756076697
# Compute control for a deterministic system
# Cost in iteration 0: 1.153066756076697
# Converged in iteration 1 with cost 1.153066756076697 because of step counter
# Final cost : 1.153066756076697
# Compute control for a deterministic system
# Cost in iteration 0: 1.070814646844259
# Converged in iteration 6 with cost 1.0607319761863454 because of step counter
# Final cost : 1.0607319761863454
# Compute control for a deterministic system
# Cost in iteration 0: 1.0607319761863454
# Converged in iteration 1 with cost 1.0607319761863454 because of step counter
# Final cost : 1.0607319761863454
# Compute control for a deterministic system
# Cost in iteration 0: 1.0607319761863454
# Converged in iteration 1 with cost 1.0607319761863454 because of step counter
# Final cost : 1.0607319761863454
# Compute control for a deterministic system
# Cost in iteration 0: 1.0607319761863454
# Converged in iteration 1 with cost 1.0607319761863454 because of step counter
# Final cost : 1.0607319761863454
# Compute control for a deterministic system
# Cost in iteration 0: 1.0607319761863454
# Converged in iteration 1 with cost 1.0607319761863454 because of step counter
# Final cost : 1.0607319761863454
# Compute control for a deterministic system
# Cost in iteration 0: 0.9847863274161017
# Converged in iteration 1 with cost 0.9847863274161017 because of step counter
# Final cost : 0.9847863274161017
# Compute control for a deterministic system
# Cost in iteration 0: 0.9847863274161017
# Converged in iteration 1 with cost 0.9847863274161017 because of step counter
# Final cost : 0.9847863274161017
# Compute control for a deterministic system
# Cost in iteration 0: 0.9847863274161017
# Converged in iteration 1 with cost 0.9847863274161017 because of step counter
# Final cost : 0.9847863274161017
# Compute control for a deterministic system
# Cost in iteration 0: 0.9847863274161017
# Converged in iteration 1 with cost 0.9847863274161017 because of step counter
# Final cost : 0.9847863274161017
# Compute control for a deterministic system
# Cost in iteration 0: 0.9847863274161017
# Converged in iteration 1 with cost 0.9847863274161017 because of step counter
# Final cost : 0.9847863274161017
# -----------------------------------------------
# 2 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.8910642371007199
# Converged in iteration 1 with cost 0.8910642371007199 because of step counter
# Final cost : 0.8910642371007199
# Compute control for a deterministic system
# Cost in iteration 0: 0.8910642371007199
# Converged in iteration 1 with cost 0.8910642371007199 because of step counter
# Final cost : 0.8910642371007199
# Compute control for a deterministic system
# Cost in iteration 0: 0.8910642371007199
# Converged in iteration 1 with cost 0.8910642371007199 because of step counter
# Final cost : 0.8910642371007199
# Compute control for a deterministic system
# Cost in iteration 0: 0.8910642371007199
# Converged in iteration 1 with cost 0.8910642371007199 because of step counter
# Final cost : 0.8910642371007199
# Compute control for a deterministic system
# Cost in iteration 0: 0.8910642371007199
# Converged in iteration 1 with cost 0.8910642371007199 because of step counter
# Final cost : 0.8910642371007199
# -----------------------------------------------
# 2 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176487497669255
# Converged in iteration 2 with cost 0.8176163621198688 because of step counter
# Final cost : 0.8176163621198688
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176163621198688
# Converged in iteration 1 with cost 0.8176163621198688 because of step counter
# Final cost : 0.8176163621198688
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176163621198688
# Converged in iteration 1 with cost 0.8176163621198688 because of step counter
# Final cost : 0.8176163621198688
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176163621198688
# Converged in iteration 1 with cost 0.8176163621198688 because of step counter
# Final cost : 0.8176163621198688
# Compute control for a deterministic system
# Cost in iteration 0: 0.8176163621198688
# Converged in iteration 1 with cost 0.8176163621198688 because of step counter
# Final cost : 0.8176163621198688
# -----------------------------------------------
# 2 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.7364543255742164
# Converged in iteration 4 with cost 0.7348231711241179 because of step counter
# Final cost : 0.7348231711241179
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348231711241179
# Converged in iteration 1 with cost 0.7348231711241179 because of step counter
# Final cost : 0.7348231711241179
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348231711241179
# Converged in iteration 1 with cost 0.7348231711241179 because of step counter
# Final cost : 0.7348231711241179
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348231711241179
# Converged in iteration 1 with cost 0.7348231711241179 because of step counter
# Final cost : 0.7348231711241179
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348231711241179
# Converged in iteration 1 with cost 0.7348231711241179 because of step counter
# Final cost : 0.7348231711241179
# -----------------------------------------------
# 2 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.6544905267798378
# Converged in iteration 4 with cost 0.6528736509455073 because of step counter
# Final cost : 0.6528736509455073
# Compute control for a deterministic system
# Cost in iteration 0: 0.6528736509455073
# Converged in iteration 1 with cost 0.6528736509455073 because of step counter
# Final cost : 0.6528736509455073
# Compute control for a deterministic system
# Cost in iteration 0: 0.6528736509455073
# Converged in iteration 1 with cost 0.6528736509455073 because of step counter
# Final cost : 0.6528736509455073
# Compute control for a deterministic system
# Cost in iteration 0: 0.6528736509455073
# Converged in iteration 1 with cost 0.6528736509455073 because of step counter
# Final cost : 0.6528736509455073
# Compute control for a deterministic system
# Cost in iteration 0: 0.6528736509455073
# Converged in iteration 1 with cost 0.6528736509455073 because of step counter
# Final cost : 0.6528736509455073
# -----------------------------------------------
# 2 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.5889061095431283
# Converged in iteration 1 with cost 0.5889061095431283 because of step counter
# Final cost : 0.5889061095431283
# Compute control for a deterministic system
# Cost in iteration 0: 0.5889061095431283
# Converged in iteration 1 with cost 0.5889061095431283 because of step counter
# Final cost : 0.5889061095431283
# Compute control for a deterministic system
# Cost in iteration 0: 0.5889061095431283
# Converged in iteration 1 with cost 0.5889061095431283 because of step counter
# Final cost : 0.5889061095431283
# Compute control for a deterministic system
# Cost in iteration 0: 0.5889061095431283
# Converged in iteration 1 with cost 0.5889061095431283 because of step counter
# Final cost : 0.5889061095431283
# Compute control for a deterministic system
# Cost in iteration 0: 0.5889061095431283
# Converged in iteration 1 with cost 0.5889061095431283 because of step counter
# Final cost : 0.5889061095431283
# -----------------------------------------------
# 2 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.507470698216899
# Converged in iteration 1 with cost 0.507470698216899 because of step counter
# Final cost : 0.507470698216899
# Compute control for a deterministic system
# Cost in iteration 0: 0.507470698216899
# Converged in iteration 1 with cost 0.507470698216899 because of step counter
# Final cost : 0.507470698216899
# Compute control for a deterministic system
# Cost in iteration 0: 0.507470698216899
# Converged in iteration 1 with cost 0.507470698216899 because of step counter
# Final cost : 0.507470698216899
# Compute control for a deterministic system
# Cost in iteration 0: 0.507470698216899
# Converged in iteration 1 with cost 0.507470698216899 because of step counter
# Final cost : 0.507470698216899
# Compute control for a deterministic system
# Cost in iteration 0: 0.507470698216899
# Converged in iteration 1 with cost 0.507470698216899 because of step counter
# Final cost : 0.507470698216899
# -----------------------------------------------
# 2 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.42590836044629127
# Converged in iteration 3 with cost 0.42538329831222177 because of step counter
# Final cost : 0.42538329831222177
# Compute control for a deterministic system
# Cost in iteration 0: 0.42538329831222177
# Converged in iteration 1 with cost 0.42538329831222177 because of step counter
# Final cost : 0.42538329831222177
# Compute control for a deterministic system
# Cost in iteration 0: 0.42538329831222177
# Converged in iteration 1 with cost 0.42538329831222177 because of step counter
# Final cost : 0.42538329831222177
# Compute control for a deterministic system
# Cost in iteration 0: 0.42538329831222177
# Converged in iteration 1 with cost 0.42538329831222177 because of step counter
# Final cost : 0.42538329831222177
# Compute control for a deterministic system
# Cost in iteration 0: 0.42538329831222177
# Converged in iteration 1 with cost 0.42538329831222177 because of step counter
# Final cost : 0.42538329831222177
# -----------------------------------------------
# 2 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.34492716731519785
# Converged in iteration 2 with cost 0.3449155239481851 because of step counter
# Final cost : 0.3449155239481851
# Compute control for a deterministic system
# Cost in iteration 0: 0.3449155239481851
# Converged in iteration 1 with cost 0.3449155239481851 because of step counter
# Final cost : 0.3449155239481851
# Compute control for a deterministic system
# Cost in iteration 0: 0.3449155239481851
# Converged in iteration 1 with cost 0.3449155239481851 because of step counter
# Final cost : 0.3449155239481851
# Compute control for a deterministic system
# Cost in iteration 0: 0.3449155239481851
# Converged in iteration 1 with cost 0.3449155239481851 because of step counter
# Final cost : 0.3449155239481851
# Compute control for a deterministic system
# Cost in iteration 0: 0.3449155239481851
# Converged in iteration 1 with cost 0.3449155239481851 because of step counter
# Final cost : 0.3449155239481851
# -----------------------------------------------
# 2 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806896495973564
# Converged in iteration 2 with cost 0.2806887474093731 because of step counter
# Final cost : 0.2806887474093731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806887474093731
# Converged in iteration 1 with cost 0.2806887474093731 because of step counter
# Final cost : 0.2806887474093731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806887474093731
# Converged in iteration 1 with cost 0.2806887474093731 because of step counter
# Final cost : 0.2806887474093731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806887474093731
# Converged in iteration 1 with cost 0.2806887474093731 because of step counter
# Final cost : 0.2806887474093731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2806887474093731
# Converged in iteration 1 with cost 0.2806887474093731 because of step counter
# Final cost : 0.2806887474093731
# -----------------------------------------------
# 2 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.1996506758410398
# Converged in iteration 3 with cost 0.19947450273452322 because of step counter
# Final cost : 0.19947450273452322
# Compute control for a deterministic system
# Cost in iteration 0: 0.19947450273452322
# Converged in iteration 1 with cost 0.19947450273452322 because of step counter
# Final cost : 0.19947450273452322
# Compute control for a deterministic system
# Cost in iteration 0: 0.19947450273452322
# Converged in iteration 1 with cost 0.19947450273452322 because of step counter
# Final cost : 0.19947450273452322
# Compute control for a deterministic system
# Cost in iteration 0: 0.19947450273452322
# Converged in iteration 1 with cost 0.19947450273452322 because of step counter
# Final cost : 0.19947450273452322
# Compute control for a deterministic system
# Cost in iteration 0: 0.19947450273452322
# Converged in iteration 1 with cost 0.19947450273452322 because of step counter
# Final cost : 0.19947450273452322
# -----------------------------------------------
# 2 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.12036294455979596
# Converged in iteration 3 with cost 0.12013031556192241 because of step counter
# Final cost : 0.12013031556192241
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013031556192241
# Converged in iteration 1 with cost 0.12013031556192241 because of step counter
# Final cost : 0.12013031556192241
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013031556192241
# Converged in iteration 1 with cost 0.12013031556192241 because of step counter
# Final cost : 0.12013031556192241
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013031556192241
# Converged in iteration 1 with cost 0.12013031556192241 because of step counter
# Final cost : 0.12013031556192241
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013031556192241
# Converged in iteration 1 with cost 0.12013031556192241 because of step counter
# Final cost : 0.12013031556192241
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307791916236554
# Converged in iteration 1 with cost 0.016307791916236554 because of step counter
# Final cost : 0.016307791916236554
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307791916236554
# Converged in iteration 1 with cost 0.016307791916236554 because of step counter
# Final cost : 0.016307791916236554
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307791916236554
# Converged in iteration 1 with cost 0.016307791916236554 because of step counter
# Final cost : 0.016307791916236554
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307791916236554
# Converged in iteration 1 with cost 0.016307791916236554 because of step counter
# Final cost : 0.016307791916236554
# Compute control for a deterministic system
# Cost in iteration 0: 0.016307791916236554
# Converged in iteration 1 with cost 0.016307791916236554 because of step counter
# Final cost : 0.016307791916236554

# %%
save(results_min)

# %%
duration = 80.
dt=0.1

percent = [0.1, 0.1, 0.1]
lim = [80., 250., 450.]
dist = [20., 100, 200]

activity_lim = [0.4, 0.55, 0.55, 0.55]
control_lim = 0.2


for ind_w in range(4):
    ops_plotall(results_min["control"][ind_w], control_lim, duration, dt, duration-40., str(ind_w), './')
