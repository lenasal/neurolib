# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,84], wc.inh[0,84]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [  24  212  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
#results_min = readfile("results_min_w2.pickle")

ind_list = range(41)
#options = [True, True, True, True, True, True, True, True]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w2"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.02546154994679433
# Final cost : 0.0004297025138470438
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004297025138470438
# Final cost : 0.0003915657089859114
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003915657089859114
# Final cost : 0.0003904963264806055
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003904963264806055
# Final cost : 0.0003902420473134405
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003902420473134405
# Final cost : 0.00039022429140366373
# Compute control for a deterministic system
# Cost in iteration 0: 0.037558041998528
# Final cost : 0.0009669156582867973
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009669156582867973
# Final cost : 0.0009109053477016701
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009109053477016701
# Final cost : 0.0009068938765362685
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009068938765362685
# Final cost : 0.0009059918490282102
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009059918490282102
# Final cost : 0.0009059139308234685
# Compute control for a deterministic system
# Cost in iteration 0: 0.03427681407091641
# Final cost : 0.0016712312813323728
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016712312813323728
# Final cost : 0.001615350340778048
# Compute control for a deterministic system
# Cost in iteration 0: 0.001615350340778048
# Final cost : 0.0016077522469022032
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016077522469022032
# Final cost : 0.0016060574528606211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016060574528606211
# Final cost : 0.001605874044974213
# Compute control for a deterministic system
# Cost in iteration 0: 0.031452813616467436
# Final cost : 0.0025455942702191773
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025455942702191773
# Final cost : 0.0024871262955367965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024871262955367965
# Final cost : 0.0024758774427517446
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024758774427517446
# Final cost : 0.0024729588265199956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024729588265199956
# Final cost : 0.002472521932453236
# Compute control for a deterministic system
# Cost in iteration 0: 0.01740738785892871
# Final cost : 0.0033220116505870458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033220116505870458
# Final cost : 0.003282934618142884
# Compute control for a deterministic system
# Cost in iteration 0: 0.003282934618142884
# Final cost : 0.0032740774022728416
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032740774022728416
# Final cost : 0.0032716351890755614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032716351890755614
# Final cost : 0.003271188795520359
# Compute control for a deterministic system
# Cost in iteration 0: 0.027648200929737757
# Final cost : 0.004478259783322863
# Compute control for a deterministic system
# Cost in iteration 0: 0.004478259783322863
# Final cost : 0.004403916492704098
# Compute control for a deterministic system
# Cost in iteration 0: 0.004403916492704098
# Final cost : 0.004388185191867369
# Compute control for a deterministic system
# Cost in iteration 0: 0.004388185191867369
# Final cost : 0.004382775470179874
# Compute control for a deterministic system
# Cost in iteration 0: 0.004382775470179874
# Final cost : 0.004381564975917404
# Compute control for a deterministic system
# Cost in iteration 0: 0.026259724908746205
# Final cost : 0.005712080797893872
# Compute control for a deterministic system
# Cost in iteration 0: 0.005712080797893872
# Final cost : 0.005621110690191225
# Compute control for a deterministic system
# Cost in iteration 0: 0.005621110690191225
# Final cost : 0.005603475934177245
# Compute control for a deterministic system
# Cost in iteration 0: 0.005603475934177245
# Final cost : 0.005597372773344325
# Compute control for a deterministic system
# Cost in iteration 0: 0.005597372773344325
# Final cost : 0.005595542499202651
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.02532782632035255
# Final cost : 0.007032088261181715
# Compute control for a deterministic system
# Cost in iteration 0: 0.007032088261181715
# Final cost : 0.006920998830977375
# Compute control for a deterministic system
# Cost in iteration 0: 0.006920998830977375
# Final cost : 0.0069024183262239875
# Compute control for a deterministic system
# Cost in iteration 0: 0.0069024183262239875
# Final cost : 0.006895490479044656
# Compute control for a deterministic system
# Cost in iteration 0: 0.006895490479044656
# Final cost : 0.006892958675010141
# Compute control for a deterministic system
# Cost in iteration 0: 0.015551955625914948
# Final cost : 0.008082433260975443
# Compute control for a deterministic system
# Cost in iteration 0: 0.008082433260975443
# Final cost : 0.007993803589752204
# Compute control for a deterministic system
# Cost in iteration 0: 0.007993803589752204
# Final cost : 0.007984656481235365
# Compute control for a deterministic system
# Cost in iteration 0: 0.007984656481235365
# Final cost : 0.007980357031878695
# Compute control for a deterministic system
# Cost in iteration 0: 0.007980357031878695
# Final cost : 0.00797893539720149
# Compute control for a deterministic system
# Cost in iteration 0: 0.024638711849702774
# Final cost : 0.009563528101832286
# Compute control for a deterministic system
# Cost in iteration 0: 0.009563528101832286
# Final cost : 0.009415127581367389
# Compute control for a deterministic system
# Cost in iteration 0: 0.009415127581367389
# Final cost : 0.009396929766198778
# Compute control for a deterministic system
# Cost in iteration 0: 0.009396929766198778
# Final cost : 0.009388274647280793
# Compute control for a deterministic system
# Cost in iteration 0: 0.009388274647280793
# Final cost : 0.009384633183746438
# Compute control for a deterministic system
# Cost in iteration 0: 0.02482298716734764
# Final cost : 0.011031852432495307
# Compute control for a deterministic system
# Cost in iteration 0: 0.011031852432495307
# Final cost : 0.010865298550607102
# Compute control for a deterministic system
# Cost in iteration 0: 0.010865298550607102
# Final cost : 0.010846413195260843
# Compute control for a deterministic system
# Cost in iteration 0: 0.010846413195260843
# Final cost : 0.010836056168789614
# Compute control for a deterministic system
# Cost in iteration 0: 0.010836056168789614
# Final cost : 0.010831143340482673
# Compute control for a deterministic system
# Cost in iteration 0: 0.01710396453517591
# Final cost : 0.012152401511596344
# Compute control for a deterministic system
# Cost in iteration 0: 0.012152401511596344
# Final cost : 0.01202383071369927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01202383071369927
# Final cost : 0.01201516000701033
# Compute control for a deterministic system
# Cost in iteration 0: 0.01201516000701033
# Final cost : 0.012010477763690273
# Compute control for a deterministic system
# Cost in iteration 0: 0.012010477763690273
# Final cost : 0.012008287550687557
# Compute control for a deterministic system
# Cost in iteration 0: 0.025659799235493788
# Final cost : 0.013714524706205636
# Compute control for a deterministic system
# Cost in iteration 0: 0.013714524706205636
# Final cost : 0.013532562594084153
# Compute control for a deterministic system
# Cost in iteration 0: 0.013532562594084153
# Final cost : 0.013514232522242412
# Compute control for a deterministic system
# Cost in iteration 0: 0.013514232522242412
# Final cost : 0.013502738883184106
# Compute control for a deterministic system
# Cost in iteration 0: 0.013502738883184106
# Final cost : 0.01349695234199451
# Compute control for a deterministic system
# Cost in iteration 0: 0.025722827722974434
# Final cost : 0.015181383700280937
# Compute control for a deterministic system
# Cost in iteration 0: 0.015181383700280937
# Final cost : 0.015008009300505437
# Compute control for a deterministic system
# Cost in iteration 0: 0.015008009300505437
# Final cost : 0.01499497552618552
# Compute control for a deterministic system
# Cost in iteration 0: 0.01499497552618552
# Final cost : 0.014987485131109292
# Compute control for a deterministic system
# Cost in iteration 0: 0.014987485131109292
# Final cost : 0.014983767321151744
# Compute control for a deterministic system
# Cost in iteration 0: 0.026808128441602
# Final cost : 0.016633159554325642
# Compute control for a deterministic system
# Cost in iteration 0: 0.016633159554325642
# Final cost : 0.01647806893412119
# Compute control for a deterministic system
# Cost in iteration 0: 0.01647806893412119
# Final cost : 0.01646292139011198
# Compute control for a deterministic system
# Cost in iteration 0: 0.01646292139011198
# Final cost : 0.016453096905304394
# Compute control for a deterministic system
# Cost in iteration 0: 0.016453096905304394
# Final cost : 0.01644725934731322
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.021642381528366835
# Final cost : 0.017714237557794072
# Compute control for a deterministic system
# Cost in iteration 0: 0.017714237557794072
# Final cost : 0.017605312321400855
# Compute control for a deterministic system
# Cost in iteration 0: 0.017605312321400855
# Final cost : 0.01759032832800226
# Compute control for a deterministic system
# Cost in iteration 0: 0.01759032832800226
# Final cost : 0.01757966881918296
# Compute control for a deterministic system
# Cost in iteration 0: 0.01757966881918296
# Final cost : 0.017572028670272
# Compute control for a deterministic system
# Cost in iteration 0: 0.028971621506698485
# Final cost : 0.019034906339911215
# Compute control for a deterministic system
# Cost in iteration 0: 0.019034906339911215
# Final cost : 0.018928491192594578
# Compute control for a deterministic system
# Cost in iteration 0: 0.018928491192594578
# Final cost : 0.018906510242693922
# Compute control for a deterministic system
# Cost in iteration 0: 0.018906510242693922
# Final cost : 0.01888526355408603
# Compute control for a deterministic system
# Cost in iteration 0: 0.01888526355408603
# Final cost : 0.018867775088828788
# Compute control for a deterministic system
# Cost in iteration 0: 0.025769892549489297
# Final cost : 0.02001462809425695
# Compute control for a deterministic system
# Cost in iteration 0: 0.02001462809425695
# Final cost : 0.019979311674799702
# Compute control for a deterministic system
# Cost in iteration 0: 0.019979311674799702
# Final cost : 0.019969144491568107
# Compute control for a deterministic system
# Cost in iteration 0: 0.019969144491568107
# Final cost : 0.01996285649403211
# Compute control for a deterministic system
# Cost in iteration 0: 0.01996285649403211
# Final cost : 0.01995819615698061
# Compute control for a deterministic system
# Cost in iteration 0: 0.022425035189044533
# Final cost : 0.020779558827134892
# Compute control for a deterministic system
# Cost in iteration 0: 0.020779558827134892
# Final cost : 0.020760793248369578
# Compute control for a deterministic system
# Cost in iteration 0: 0.020760793248369578
# Final cost : 0.020755888331307475
# Compute control for a deterministic system
# Cost in iteration 0: 0.020755888331307475
# Final cost : 0.020751792652057902
# Compute control for a deterministic system
# Cost in iteration 0: 0.020751792652057902
# Final cost : 0.02074872453946421
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.06301562146184758
# Final cost : 0.021708672968423857
# Compute control for a deterministic system
# Cost in iteration 0: 0.021708672968423857
# Final cost : 0.021694488953394864
# Compute control for a deterministic system
# Cost in iteration 0: 0.021694488953394864
# Final cost : 0.021687031044832578
# Compute control for a deterministic system
# Cost in iteration 0: 0.021687031044832578
# Final cost : 0.021677976100678117
# Compute control for a deterministic system
# Cost in iteration 0: 0.021677976100678117
# Final cost : 0.021667092981460943
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388975730644755
# Final cost : 0.022562428773509884
# Compute control for a deterministic system
# Cost in iteration 0: 0.022562428773509884
# Final cost : 0.022551731076763074
# Compute control for a deterministic system
# Cost in iteration 0: 0.022551731076763074
# Final cost : 0.02254492029342973
# Compute control for a deterministic system
# Cost in iteration 0: 0.02254492029342973
# Final cost : 0.02253464222506833
# Compute control for a deterministic system
# Cost in iteration 0: 0.02253464222506833
# Final cost : 0.0225201652463847
# Compute control for a deterministic system
# Cost in iteration 0: 0.06463536880050715
# Final cost : 0.023271091139737993
# Compute control for a deterministic system
# Cost in iteration 0: 0.023271091139737993
# Final cost : 0.023268896554132546
# Compute control for a deterministic system
# Cost in iteration 0: 0.023268896554132546
# Final cost : 0.023267280946964917
# Compute control for a deterministic system
# Cost in iteration 0: 0.023267280946964917
# Final cost : 0.023265071371587627
# Compute control for a deterministic system
# Cost in iteration 0: 0.023265071371587627
# Final cost : 0.023263112790294107
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.05059016888784173
# Final cost : 0.0238720737011233
# Compute control for a deterministic system
# Cost in iteration 0: 0.0238720737011233
# Final cost : 0.023868964334728893
# Compute control for a deterministic system
# Cost in iteration 0: 0.023868964334728893
# Final cost : 0.023866732180673627
# Compute control for a deterministic system
# Cost in iteration 0: 0.023866732180673627
# Final cost : 0.02386331708548284
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386331708548284
# Final cost : 0.023856824236729107
# Compute control for a deterministic system
# Cost in iteration 0: 0.06657096107010187
# Final cost : 0.02460812882643534
# Compute control for a deterministic system
# Cost in iteration 0: 0.02460812882643534
# Final cost : 0.024589815514787956
# Compute control for a deterministic system
# Cost in iteration 0: 0.024589815514787956
# Final cost : 0.024586188488020924
# Compute control for a deterministic system
# Cost in iteration 0: 0.024586188488020924
# Final cost : 0.024581656355905687
# Compute control for a deterministic system
# Cost in iteration 0: 0.024581656355905687
# Final cost : 0.024572153601790114
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808157727366387
# Final cost : 0.025344983954694908
# Compute control for a deterministic system
# Cost in iteration 0: 0.025344983954694908
# Final cost : 0.025285896053140387
# Compute control for a deterministic system
# Cost in iteration 0: 0.025285896053140387
# Final cost : 0.02527915544735709
# Compute control for a deterministic system
# Cost in iteration 0: 0.02527915544735709
# Final cost : 0.025272778880539772
# Compute control for a deterministic system
# Cost in iteration 0: 0.025272778880539772
# Final cost : 0.02526019614961077
# Compute control for a deterministic system
# Cost in iteration 0: 0.06527679855475674
# Final cost : 0.021912591787555846
# Compute control for a deterministic system
# Cost in iteration 0: 0.021912591787555846
# Final cost : 0.021207044985076442
# Compute control for a deterministic system
# Cost in iteration 0: 0.021207044985076442
# Final cost : 0.021155480559706636
# Compute control for a deterministic system
# Cost in iteration 0: 0.021155480559706636
# Final cost : 0.02114088350860261
# Compute control for a deterministic system
# Cost in iteration 0: 0.02114088350860261
# Final cost : 0.021134130075548797
# Compute control for a deterministic system
# Cost in iteration 0: 0.04748539391750171
# Final cost : 0.018954822812405434
# Compute control for a deterministic system
# Cost in iteration 0: 0.018954822812405434
# Final cost : 0.018543629813506567
# Compute control for a deterministic system
# Cost in iteration 0: 0.018543629813506567
# Final cost : 0.018514731616335368
# Compute control for a deterministic system
# Cost in iteration 0: 0.018514731616335368
# Final cost : 0.018503572830271136
# Compute control for a deterministic system
# Cost in iteration 0: 0.018503572830271136
# Final cost : 0.018498994195428182
# Compute control for a deterministic system
# Cost in iteration 0: 0.06112723681508585
# Final cost : 0.016068287421604453
# Compute control for a deterministic system
# Cost in iteration 0: 0.016068287421604453
# Final cost : 0.01548852923165865
# Compute control for a deterministic system
# Cost in iteration 0: 0.01548852923165865
# Final cost : 0.015445393345888788
# Compute control for a deterministic system
# Cost in iteration 0: 0.015445393345888788
# Final cost : 0.015431812821508128
# Compute control for a deterministic system
# Cost in iteration 0: 0.015431812821508128
# Final cost : 0.015425976255281342
# Compute control for a deterministic system
# Cost in iteration 0: 0.05872148234334181
# Final cost : 0.013176731016191896
# Compute control for a deterministic system
# Cost in iteration 0: 0.013176731016191896
# Final cost : 0.01266372450838382
# Compute control for a deterministic system
# Cost in iteration 0: 0.01266372450838382
# Final cost : 0.012626624270112078
# Compute control for a deterministic system
# Cost in iteration 0: 0.012626624270112078
# Final cost : 0.012613652253486858
# Compute control for a deterministic system
# Cost in iteration 0: 0.012613652253486858
# Final cost : 0.01260848555475905
# Compute control for a deterministic system
# Cost in iteration 0: 0.04039913918169194
# Final cost : 0.010868494778005043
# Compute control for a deterministic system
# Cost in iteration 0: 0.010868494778005043
# Final cost : 0.010576504294813214
# Compute control for a deterministic system
# Cost in iteration 0: 0.010576504294813214
# Final cost : 0.010557340954069691
# Compute control for a deterministic system
# Cost in iteration 0: 0.010557340954069691
# Final cost : 0.010549235881903438
# Compute control for a deterministic system
# Cost in iteration 0: 0.010549235881903438
# Final cost : 0.010546414875435537
# Compute control for a deterministic system
# Cost in iteration 0: 0.055055070506255986
# Final cost : 0.008658225283224756
# Compute control for a deterministic system
# Cost in iteration 0: 0.008658225283224756
# Final cost : 0.008258467283427854
# Compute control for a deterministic system
# Cost in iteration 0: 0.008258467283427854
# Final cost : 0.008229340812623923
# Compute control for a deterministic system
# Cost in iteration 0: 0.008229340812623923
# Final cost : 0.008220321759714587
# Compute control for a deterministic system
# Cost in iteration 0: 0.008220321759714587
# Final cost : 0.008217335745349705
# Compute control for a deterministic system
# Cost in iteration 0: 0.05343537212531074
# Final cost : 0.0065470563241222185
# Compute control for a deterministic system
# Cost in iteration 0: 0.0065470563241222185
# Final cost : 0.006204988903039903
# Compute control for a deterministic system
# Cost in iteration 0: 0.006204988903039903
# Final cost : 0.006182857680392202
# Compute control for a deterministic system
# Cost in iteration 0: 0.006182857680392202
# Final cost : 0.0061738040050343035
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061738040050343035
# Final cost : 0.006172134756657721
# Compute control for a deterministic system
# Cost in iteration 0: 0.052061021988966436
# Final cost : 0.004730991127077859
# Compute control for a deterministic system
# Cost in iteration 0: 0.004730991127077859
# Final cost : 0.004441993529893699
# Compute control for a deterministic system
# Cost in iteration 0: 0.004441993529893699
# Final cost : 0.004426690494999078
# Compute control for a deterministic system
# Cost in iteration 0: 0.004426690494999078
# Final cost : 0.004418755410552358
# Compute control for a deterministic system
# Cost in iteration 0: 0.004418755410552358
# Final cost : 0.004416857718206835
# Compute control for a deterministic system
# Cost in iteration 0: 0.03399839775455422
# Final cost : 0.0033947350940636777
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033947350940636777
# Final cost : 0.0032366400382005845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032366400382005845
# Final cost : 0.00322800152006275
# Compute control for a deterministic system
# Cost in iteration 0: 0.00322800152006275
# Final cost : 0.0032248385937101508
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032248385937101508
# Final cost : 0.0032242231837849456
# Compute control for a deterministic system
# Cost in iteration 0: 0.04995324825858645
# Final cost : 0.002222906697261799
# Compute control for a deterministic system
# Cost in iteration 0: 0.002222906697261799
# Final cost : 0.0020128785148068565
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020128785148068565
# Final cost : 0.00200342197333131
# Compute control for a deterministic system
# Cost in iteration 0: 0.00200342197333131
# Final cost : 0.0020000783691575866
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020000783691575866
# Final cost : 0.0019995496585995926
# Compute control for a deterministic system
# Cost in iteration 0: 0.04874653086916228
# Final cost : 0.001257861169198412
# Compute control for a deterministic system
# Cost in iteration 0: 0.001257861169198412
# Final cost : 0.0010781230424232343
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010781230424232343
# Final cost : 0.0010724489055835317
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010724489055835317
# Final cost : 0.00107039074029691
# Compute control for a deterministic system
# Cost in iteration 0: 0.00107039074029691
# Final cost : 0.0010701387260752511
# Compute control for a deterministic system
# Cost in iteration 0: 0.047324584344539726
# Final cost : 0.0005952991010207236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005952991010207236
# Final cost : 0.0004371595164007366
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004371595164007366
# Final cost : 0.0004342556667346792
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004342556667346792
# Final cost : 0.0004333341795101731
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004333341795101731
# Final cost : 0.00043324107178373933
# Compute control for a deterministic system
# Cost in iteration 0: 0.029646347535921786
# Final cost : 0.0002207090078379793
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002207090078379793
# Final cost : 0.00013130889529092615
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013130889529092615
# Final cost : 0.0001305257774168159
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001305257774168159
# Final cost : 0.00013032274872226427
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013032274872226427
# Final cost : 0.00013030029970224376
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.029200723973504285
# Final cost : 0.00044075421135586176
# Compute control for a deterministic system
# Cost in iteration 0: 0.00044075421135586176
# Final cost : 0.0004341862987903522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004341862987903522
# Final cost : 0.00043326372934794155
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043326372934794155
# Final cost : 0.00043324066955138454
# Compute control for a deterministic system
# Cost in iteration 0: 0.046235505544809964
# Final cost : 0.0010867560515211688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010867560515211688
# Final cost : 0.001074025323860564
# Compute control for a deterministic system
# Cost in iteration 0: 0.001074025323860564
# Final cost : 0.001070333654077298
# Compute control for a deterministic system
# Cost in iteration 0: 0.001070333654077298
# Final cost : 0.0010701364857242657
# Compute control for a deterministic system
# Cost in iteration 0: 0.04690716433688686
# Final cost : 0.002021992794311313
# Compute control for a deterministic system
# Cost in iteration 0: 0.002021992794311313
# Final cost : 0.0020051186515084494
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020051186515084494
# Final cost : 0.0019999426251779795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019999426251779795
# Final cost : 0.0019995464529200344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0473393511511623
# Final cost : 0.00325398628483697
# Compute control for a deterministic system
# Cost in iteration 0: 0.00325398628483697
# Final cost : 0.003231279959014201
# Compute control for a deterministic system
# Cost in iteration 0: 0.003231279959014201
# Final cost : 0.0032245409970957637
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032245409970957637
# Final cost : 0.0032242089757250334
# Compute control for a deterministic system
# Cost in iteration 0: 0.031268944998023865
# Final cost : 0.004439481162275007
# Compute control for a deterministic system
# Cost in iteration 0: 0.004439481162275007
# Final cost : 0.0044211444790092855
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044211444790092855
# Final cost : 0.004417423360687295
# Compute control for a deterministic system
# Cost in iteration 0: 0.004417423360687295
# Final cost : 0.004416820574908638
# Compute control for a deterministic system
# Cost in iteration 0: 0.048066335356613914
# Final cost : 0.006217520989875374
# Compute control for a deterministic system
# Cost in iteration 0: 0.006217520989875374
# Final cost : 0.0061810310430658695
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061810310430658695
# Final cost : 0.006173656895630567
# Compute control for a deterministic system
# Cost in iteration 0: 0.006173656895630567
# Final cost : 0.006172113743190529
# Compute control for a deterministic system
# Cost in iteration 0: 0.04868604921307688
# Final cost : 0.008272284461144114
# Compute control for a deterministic system
# Cost in iteration 0: 0.008272284461144114
# Final cost : 0.008227007795612161
# Compute control for a deterministic system
# Cost in iteration 0: 0.008227007795612161
# Final cost : 0.008219348018912371
# Compute control for a deterministic system
# Cost in iteration 0: 0.008219348018912371
# Final cost : 0.008217412399512349
# Compute control for a deterministic system
# Cost in iteration 0: 0.049554862014556035
# Final cost : 0.010611049755053056
# Compute control for a deterministic system
# Cost in iteration 0: 0.010611049755053056
# Final cost : 0.010564873758116274
# Compute control for a deterministic system
# Cost in iteration 0: 0.010564873758116274
# Final cost : 0.010550722927900005
# Compute control for a deterministic system
# Cost in iteration 0: 0.010550722927900005
# Final cost : 0.010546531022019006
# Compute control for a deterministic system
# Cost in iteration 0: 0.035424810707122875
# Final cost : 0.012654109644071522
# Compute control for a deterministic system
# Cost in iteration 0: 0.012654109644071522
# Final cost : 0.01262219060875468
# Compute control for a deterministic system
# Cost in iteration 0: 0.01262219060875468
# Final cost : 0.012611929636241555
# Compute control for a deterministic system
# Cost in iteration 0: 0.012611929636241555
# Final cost : 0.012608315699034103
# Compute control for a deterministic system
# Cost in iteration 0: 0.051869286587796236
# Final cost : 0.015508211596637367
# Compute control for a deterministic system
# Cost in iteration 0: 0.015508211596637367
# Final cost : 0.015451273407192882
# Compute control for a deterministic system
# Cost in iteration 0: 0.015451273407192882
# Final cost : 0.015432920454702966
# Compute control for a deterministic system
# Cost in iteration 0: 0.015432920454702966
# Final cost : 0.015426072238965229
# Compute control for a deterministic system
# Cost in iteration 0: 0.053522590791678294
# Final cost : 0.018592022502872233
# Compute control for a deterministic system
# Cost in iteration 0: 0.018592022502872233
# Final cost : 0.01852918835729211
# Compute control for a deterministic system
# Cost in iteration 0: 0.01852918835729211
# Final cost : 0.01850706249357198
# Compute control for a deterministic system
# Cost in iteration 0: 0.01850706249357198
# Final cost : 0.018499613235358262
# Compute control for a deterministic system
# Cost in iteration 0: 0.04093299779669286
# Final cost : 0.021198952646019217
# Compute control for a deterministic system
# Cost in iteration 0: 0.021198952646019217
# Final cost : 0.02115712645838451
# Compute control for a deterministic system
# Cost in iteration 0: 0.02115712645838451
# Final cost : 0.021141690148264287
# Compute control for a deterministic system
# Cost in iteration 0: 0.021141690148264287
# Final cost : 0.02113425377595259
# Compute control for a deterministic system
# Cost in iteration 0: 0.05652096454669578
# Final cost : 0.02474214041035985
# Compute control for a deterministic system
# Cost in iteration 0: 0.02474214041035985
# Final cost : 0.024671577653791042
# Compute control for a deterministic system
# Cost in iteration 0: 0.024671577653791042
# Final cost : 0.02464903385322513
# Compute control for a deterministic system
# Cost in iteration 0: 0.02464903385322513
# Final cost : 0.024637507103678742
# Compute control for a deterministic system
# Cost in iteration 0: 0.05840669157725858
# Final cost : 0.02848120293176085
# Compute control for a deterministic system
# Cost in iteration 0: 0.02848120293176085
# Final cost : 0.028403610293003465
# Compute control for a deterministic system
# Cost in iteration 0: 0.028403610293003465
# Final cost : 0.028376494253205747
# Compute control for a deterministic system
# Cost in iteration 0: 0.028376494253205747
# Final cost : 0.028360692242910806
# Compute control for a deterministic system
# Cost in iteration 0: 0.0685530769210124
# Final cost : 0.023939964407199997
# Compute control for a deterministic system
# Cost in iteration 0: 0.023939964407199997
# Final cost : 0.023893651428412353
# Compute control for a deterministic system
# Cost in iteration 0: 0.023893651428412353
# Final cost : 0.023879994153900973
# Compute control for a deterministic system
# Cost in iteration 0: 0.023879994153900973
# Final cost : 0.023864334627912643
# Compute control for a deterministic system
# Cost in iteration 0: 0.05733757610560073
# Final cost : 0.023293157372004075
# Compute control for a deterministic system
# Cost in iteration 0: 0.023293157372004075
# Final cost : 0.02328183384649877
# Compute control for a deterministic system
# Cost in iteration 0: 0.02328183384649877
# Final cost : 0.02327517655283109
# Compute control for a deterministic system
# Cost in iteration 0: 0.02327517655283109
# Final cost : 0.023268447851489366
# Compute control for a deterministic system
# Cost in iteration 0: 0.07723634732540051
# Final cost : 0.022529061087029883
# Compute control for a deterministic system
# Cost in iteration 0: 0.022529061087029883
# Final cost : 0.02251617802999021
# Compute control for a deterministic system
# Cost in iteration 0: 0.02251617802999021
# Final cost : 0.022508982429415608
# Compute control for a deterministic system
# Cost in iteration 0: 0.022508982429415608
# Final cost : 0.02249944402501151
# -----------------------------------------------
# 1 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.08056424700499845
# Final cost : 0.021738723186453684
# Compute control for a deterministic system
# Cost in iteration 0: 0.021738723186453684
# Final cost : 0.021719421525127132
# Compute control for a deterministic system
# Cost in iteration 0: 0.021719421525127132
# Final cost : 0.021700991408799605
# Compute control for a deterministic system
# Cost in iteration 0: 0.021700991408799605
# Final cost : 0.02168204307675601
# Compute control for a deterministic system
# Cost in iteration 0: 0.04440781070308923
# Final cost : 0.02075778282844123
# Compute control for a deterministic system
# Cost in iteration 0: 0.02075778282844123
# Final cost : 0.020752809656855338
# Compute control for a deterministic system
# Cost in iteration 0: 0.020752809656855338
# Final cost : 0.020748599720689608
# Compute control for a deterministic system
# Cost in iteration 0: 0.020748599720689608
# Final cost : 0.020746140658472304
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.032010572351760996
# Final cost : 0.019978999742996034
# Compute control for a deterministic system
# Cost in iteration 0: 0.019978999742996034
# Final cost : 0.019969557273496384
# Compute control for a deterministic system
# Cost in iteration 0: 0.019969557273496384
# Final cost : 0.019962509274273843
# Compute control for a deterministic system
# Cost in iteration 0: 0.019962509274273843
# Final cost : 0.01995648048216341
# Compute control for a deterministic system
# Cost in iteration 0: 0.04198936775420328
# Final cost : 0.018921958947113952
# Compute control for a deterministic system
# Cost in iteration 0: 0.018921958947113952
# Final cost : 0.01889807139102141
# Compute control for a deterministic system
# Cost in iteration 0: 0.01889807139102141
# Final cost : 0.018880099389378083
# Compute control for a deterministic system
# Cost in iteration 0: 0.018880099389378083
# Final cost : 0.018865114456219953
# Compute control for a deterministic system
# Cost in iteration 0: 0.04236655841375631
# Final cost : 0.017695468056033573
# Compute control for a deterministic system
# Cost in iteration 0: 0.017695468056033573
# Final cost : 0.017670026855189477
# Compute control for a deterministic system
# Cost in iteration 0: 0.017670026855189477
# Final cost : 0.01764238759786265
# Compute control for a deterministic system
# Cost in iteration 0: 0.01764238759786265
# Final cost : 0.017612469550793677
# Compute control for a deterministic system
# Cost in iteration 0: 0.032379873227236004
# Final cost : 0.016476340723468194
# Compute control for a deterministic system
# Cost in iteration 0: 0.016476340723468194
# Final cost : 0.016464260655205395
# Compute control for a deterministic system
# Cost in iteration 0: 0.016464260655205395
# Final cost : 0.016454742838001604
# Compute control for a deterministic system
# Cost in iteration 0: 0.016454742838001604
# Final cost : 0.016448112620048905
# Compute control for a deterministic system
# Cost in iteration 0: 0.04398393479641292
# Final cost : 0.015038277198074063
# Compute control for a deterministic system
# Cost in iteration 0: 0.015038277198074063
# Final cost : 0.015008943117432031
# Compute control for a deterministic system
# Cost in iteration 0: 0.015008943117432031
# Final cost : 0.014989536533810388
# Compute control for a deterministic system
# Cost in iteration 0: 0.014989536533810388
# Final cost : 0.014983650289933472
# Compute control for a deterministic system
# Cost in iteration 0: 0.04344120368855428
# Final cost : 0.013551310872142855
# Compute control for a deterministic system
# Cost in iteration 0: 0.013551310872142855
# Final cost : 0.013525926061241155
# Compute control for a deterministic system
# Cost in iteration 0: 0.013525926061241155
# Final cost : 0.01350752784308004
# Compute control for a deterministic system
# Cost in iteration 0: 0.01350752784308004
# Final cost : 0.013496760462259028
# Compute control for a deterministic system
# Cost in iteration 0: 0.04294360559086979
# Final cost : 0.012079383105323818
# Compute control for a deterministic system
# Cost in iteration 0: 0.012079383105323818
# Final cost : 0.012038703985324346
# Compute control for a deterministic system
# Cost in iteration 0: 0.012038703985324346
# Final cost : 0.012019101176161652
# Compute control for a deterministic system
# Cost in iteration 0: 0.012019101176161652
# Final cost : 0.012009887483158682
# Compute control for a deterministic system
# Cost in iteration 0: 0.030056499449936366
# Final cost : 0.01085315696380072
# Compute control for a deterministic system
# Cost in iteration 0: 0.01085315696380072
# Final cost : 0.01084123429425447
# Compute control for a deterministic system
# Cost in iteration 0: 0.01084123429425447
# Final cost : 0.010833826224000215
# Compute control for a deterministic system
# Cost in iteration 0: 0.010833826224000215
# Final cost : 0.010830453837453785
# Compute control for a deterministic system
# Cost in iteration 0: 0.04206262612388904
# Final cost : 0.009431255878888786
# Compute control for a deterministic system
# Cost in iteration 0: 0.009431255878888786
# Final cost : 0.009407406203948119
# Compute control for a deterministic system
# Cost in iteration 0: 0.009407406203948119
# Final cost : 0.00939267249439554
# Compute control for a deterministic system
# Cost in iteration 0: 0.00939267249439554
# Final cost : 0.009385198517465224
# Compute control for a deterministic system
# Cost in iteration 0: 0.04165208326137024
# Final cost : 0.00801389064446347
# Compute control for a deterministic system
# Cost in iteration 0: 0.00801389064446347
# Final cost : 0.00799399722936181
# Compute control for a deterministic system
# Cost in iteration 0: 0.00799399722936181
# Final cost : 0.0079832323006881
# Compute control for a deterministic system
# Cost in iteration 0: 0.0079832323006881
# Final cost : 0.007979179925086491
# Compute control for a deterministic system
# Cost in iteration 0: 0.02795277379085291
# Final cost : 0.0069130745662928554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0069130745662928554
# Final cost : 0.006901651781280712
# Compute control for a deterministic system
# Cost in iteration 0: 0.006901651781280712
# Final cost : 0.006895043324319977
# Compute control for a deterministic system
# Cost in iteration 0: 0.006895043324319977
# Final cost : 0.006892897809735394
# Compute control for a deterministic system
# Cost in iteration 0: 0.04078593886595294
# Final cost : 0.005642035655790384
# Compute control for a deterministic system
# Cost in iteration 0: 0.005642035655790384
# Final cost : 0.005605787809788124
# Compute control for a deterministic system
# Cost in iteration 0: 0.005605787809788124
# Final cost : 0.005597200701528421
# Compute control for a deterministic system
# Cost in iteration 0: 0.005597200701528421
# Final cost : 0.005595546240347857
# Compute control for a deterministic system
# Cost in iteration 0: 0.04058280519377041
# Final cost : 0.004419181160048503
# Compute control for a deterministic system
# Cost in iteration 0: 0.004419181160048503
# Final cost : 0.004392599708432702
# Compute control for a deterministic system
# Cost in iteration 0: 0.004392599708432702
# Final cost : 0.0043837314036525785
# Compute control for a deterministic system
# Cost in iteration 0: 0.0043837314036525785
# Final cost : 0.004381600381638544
# Compute control for a deterministic system
# Cost in iteration 0: 0.04047995436673916
# Final cost : 0.0033021539021945915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033021539021945915
# Final cost : 0.003278345648133059
# Compute control for a deterministic system
# Cost in iteration 0: 0.003278345648133059
# Final cost : 0.003271681108392059
# Compute control for a deterministic system
# Cost in iteration 0: 0.003271681108392059
# Final cost : 0.0032711781831715504
# -----------------------------------------------
# 1 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.026343255385226458
# Final cost : 0.002490945441779573
# Compute control for a deterministic system
# Cost in iteration 0: 0.002490945441779573
# Final cost : 0.002476860608151896
# Compute control for a deterministic system
# Cost in iteration 0: 0.002476860608151896
# Final cost : 0.0024730790957793016
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024730790957793016
# Final cost : 0.0024725228019717863
# Compute control for a deterministic system
# Cost in iteration 0: 0.040831983054792007
# Final cost : 0.0016302494143092259
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016302494143092259
# Final cost : 0.0016108684457592304
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016108684457592304
# Final cost : 0.0016063800438414363
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016063800438414363
# Final cost : 0.0016058776714669752
# Compute control for a deterministic system
# Cost in iteration 0: 0.04132210506632815
# Final cost : 0.0009233191270366453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009233191270366453
# Final cost : 0.0009077621444978767
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009077621444978767
# Final cost : 0.0009059602749492959
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009059602749492959
# Final cost : 0.0009059135177347844
# -----------------------------------------------
# 1 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.041985507396553004
# Final cost : 0.0004032446419875672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004032446419875672
# Final cost : 0.00039119102576698814
# Compute control for a deterministic system
# Cost in iteration 0: 0.00039119102576698814
# Final cost : 0.0003902623047505121
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003902623047505121
# Final cost : 0.0003902243511603859
# Compute control for a deterministic system
# Cost in iteration 0: 0.027324685554519116
# Final cost : 0.0001307256024649169
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001307256024649169
# Final cost : 0.00012494636398799414
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012494636398799414
# Final cost : 0.0001243938523444819
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001243938523444819
# Final cost : 0.00012437884990862194
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002718762722664119
# Final cost : 0.00015783636031738786
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015783636031738786
# Final cost : 0.00012472517472004294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012472517472004294
# Final cost : 0.0001243973374104827
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001243973374104827
# Final cost : 0.00012437990430132
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012437990430132
# Final cost : 0.0001243788435395971
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008258291935966102
# Final cost : 0.00048449112273026744
# Compute control for a deterministic system
# Cost in iteration 0: 0.00048449112273026744
# Final cost : 0.00039188000184941206
# Compute control for a deterministic system
# Cost in iteration 0: 0.00039188000184941206
# Final cost : 0.0003904134105617265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003904134105617265
# Final cost : 0.0003902351279861797
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003902351279861797
# Final cost : 0.00039022426789524266
# Compute control for a deterministic system
# Cost in iteration 0: 0.001858200153219824
# Final cost : 0.0011018477311752122
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011018477311752122
# Final cost : 0.0009114671388207352
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009114671388207352
# Final cost : 0.0009069348710243284
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009069348710243284
# Final cost : 0.0009059669654675143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009059669654675143
# Final cost : 0.0009059137811099041
# Compute control for a deterministic system
# Cost in iteration 0: 0.003212792077895022
# Final cost : 0.0019278415110088884
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019278415110088884
# Final cost : 0.0016204217409826738
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016204217409826738
# Final cost : 0.0016089743559491616
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016089743559491616
# Final cost : 0.0016061497974117532
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016061497974117532
# Final cost : 0.0016058747232152704
# Compute control for a deterministic system
# Cost in iteration 0: 0.004827344264253192
# Final cost : 0.002934118384922048
# Compute control for a deterministic system
# Cost in iteration 0: 0.002934118384922048
# Final cost : 0.002505378565126587
# Compute control for a deterministic system
# Cost in iteration 0: 0.002505378565126587
# Final cost : 0.002480339131860928
# Compute control for a deterministic system
# Cost in iteration 0: 0.002480339131860928
# Final cost : 0.0024734455449075894
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024734455449075894
# Final cost : 0.0024725296158866965
# Compute control for a deterministic system
# Cost in iteration 0: 0.006257213487608377
# Final cost : 0.0038416798058562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038416798058562
# Final cost : 0.0033277403122514114
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033277403122514114
# Final cost : 0.00328516845796024
# Compute control for a deterministic system
# Cost in iteration 0: 0.00328516845796024
# Final cost : 0.0032730181401797753
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032730181401797753
# Final cost : 0.0032712223207517436
# Compute control for a deterministic system
# Cost in iteration 0: 0.008165684980571547
# Final cost : 0.0050713539811198735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050713539811198735
# Final cost : 0.0044796996988988496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044796996988988496
# Final cost : 0.004407552076153344
# Compute control for a deterministic system
# Cost in iteration 0: 0.004407552076153344
# Final cost : 0.004385591255518024
# Compute control for a deterministic system
# Cost in iteration 0: 0.004385591255518024
# Final cost : 0.0043816645392637495
# Compute control for a deterministic system
# Cost in iteration 0: 0.010166902207134912
# Final cost : 0.006378389299265348
# Compute control for a deterministic system
# Cost in iteration 0: 0.006378389299265348
# Final cost : 0.005746206432812774
# Compute control for a deterministic system
# Cost in iteration 0: 0.005746206432812774
# Final cost : 0.005638546108819808
# Compute control for a deterministic system
# Cost in iteration 0: 0.005638546108819808
# Final cost : 0.005603342695565915
# Compute control for a deterministic system
# Cost in iteration 0: 0.005603342695565915
# Final cost : 0.005595856010222062
# Compute control for a deterministic system
# Cost in iteration 0: 0.012228988198679453
# Final cost : 0.007742525032245175
# Compute control for a deterministic system
# Cost in iteration 0: 0.007742525032245175
# Final cost : 0.007102012848496009
# Compute control for a deterministic system
# Cost in iteration 0: 0.007102012848496009
# Final cost : 0.006959195180402131
# Compute control for a deterministic system
# Cost in iteration 0: 0.006959195180402131
# Final cost : 0.00690705742808678
# Compute control for a deterministic system
# Cost in iteration 0: 0.00690705742808678
# Final cost : 0.006893763838419538
# Compute control for a deterministic system
# Cost in iteration 0: 0.0139060661663334
# Final cost : 0.008867046579342626
# Compute control for a deterministic system
# Cost in iteration 0: 0.008867046579342626
# Final cost : 0.008235165155837295
# Compute control for a deterministic system
# Cost in iteration 0: 0.008235165155837295
# Final cost : 0.008065982586278908
# Compute control for a deterministic system
# Cost in iteration 0: 0.008065982586278908
# Final cost : 0.00799756234012476
# Compute control for a deterministic system
# Cost in iteration 0: 0.00799756234012476
# Final cost : 0.007980583239861004
# Compute control for a deterministic system
# Cost in iteration 0: 0.016017336053757155
# Final cost : 0.010308498441219205
# Compute control for a deterministic system
# Cost in iteration 0: 0.010308498441219205
# Final cost : 0.009695247159441586
# Compute control for a deterministic system
# Cost in iteration 0: 0.009695247159441586
# Final cost : 0.009499582574869112
# Compute control for a deterministic system
# Cost in iteration 0: 0.009499582574869112
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.25646520573876347
# Final cost : 0.2564652038960673
# Compute control for a deterministic system
# Cost in iteration 0: 2.491208855949267
# Final cost : 0.29533971447669777
# Compute control for a deterministic system
# Cost in iteration 0: 0.29533971447669777
# Final cost : 0.2796514919192518
# Compute control for a deterministic system
# Cost in iteration 0: 0.2796514919192518
# Final cost : 0.27963464017889844
# Compute control for a deterministic system
# Cost in iteration 0: 0.27963464017889844
# Final cost : 0.27962966394966166
# Compute control for a deterministic system
# Cost in iteration 0: 0.27962966394966166
# Final cost : 0.2796283555609574
# Compute control for a deterministic system
# Cost in iteration 0: 2.645847218152125
# Final cost : 0.3155761373069425
# Compute control for a deterministic system
# Cost in iteration 0: 0.3155761373069425
# Final cost : 0.29794821685080325
# Compute control for a deterministic system
# Cost in iteration 0: 0.29794821685080325
# Final cost : 0.2979210705211815
# Compute control for a deterministic system
# Cost in iteration 0: 0.2979210705211815
# Final cost : 0.2979127545910102
# Compute control for a deterministic system
# Cost in iteration 0: 0.2979127545910102
# Final cost : 0.297908159254403
# Compute control for a deterministic system
# Cost in iteration 0: 2.7292329251345935
# Final cost : 0.3272548109691813
# Compute control for a deterministic system
# Cost in iteration 0: 0.3272548109691813
# Final cost : 0.30895503394427776
# Compute control for a deterministic system
# Cost in iteration 0: 0.30895503394427776
# Final cost : 0.3088467442675489
# Compute control for a deterministic system
# Cost in iteration 0: 0.3088467442675489
# Final cost : 0.30883199071610157
# Compute control for a deterministic system
# Cost in iteration 0: 0.30883199071610157
# Final cost : 0.3088272738743697
# Compute control for a deterministic system
# Cost in iteration 0: 2.8130068899585225
# Final cost : 0.33950085431366817
# Compute control for a deterministic system
# Cost in iteration 0: 0.33950085431366817
# Final cost : 0.3215186006149549
# Compute control for a deterministic system
# Cost in iteration 0: 0.3215186006149549
# Final cost : 0.32051758889391524
# Compute control for a deterministic system
# Cost in iteration 0: 0.32051758889391524
# Final cost : 0.32044057806981807
# Compute control for a deterministic system
# Cost in iteration 0: 0.32044057806981807
# Final cost : 0.3204352501037304
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 2.882582420573233
# Final cost : 0.3534577574911128
# Compute control for a deterministic system
# Cost in iteration 0: 0.3534577574911128
# Final cost : 0.33552165835908654
# Compute control for a deterministic system
# Cost in iteration 0: 0.33552165835908654
# Final cost : 0.3323224339042475
# Compute control for a deterministic system
# Cost in iteration 0: 0.3323224339042475
# Final cost : 0.3309455227999925
# Compute control for a deterministic system
# Cost in iteration 0: 0.3309455227999925
# Final cost : 0.3307957015914357
# Compute control for a deterministic system
# Cost in iteration 0: 2.9351618608315637
# Final cost : 0.381631041945192
# Compute control for a deterministic system
# Cost in iteration 0: 0.381631041945192
# Final cost : 0.3574228923909601
# Compute control for a deterministic system
# Cost in iteration 0: 0.3574228923909601
# Final cost : 0.3492448596659568
# Compute control for a deterministic system
# Cost in iteration 0: 0.3492448596659568
# Final cost : 0.342812896955325
# Compute control for a deterministic system
# Cost in iteration 0: 0.342812896955325
# Final cost : 0.3405084500636374
# Compute control for a deterministic system
# Cost in iteration 0: 2.9689885398630427
# Final cost : 0.41314537330804807
# Compute control for a deterministic system
# Cost in iteration 0: 0.41314537330804807
# Final cost : 0.3886845532589203
# Compute control for a deterministic system
# Cost in iteration 0: 0.3886845532589203
# Final cost : 0.3713340801726347
# Compute control for a deterministic system
# Cost in iteration 0: 0.3713340801726347
# Final cost : 0.35798761132232243
# Compute control for a deterministic system
# Cost in iteration 0: 0.35798761132232243
# Final cost : 0.34899126439302824
# Compute control for a deterministic system
# Cost in iteration 0: 2.9969047930523764
# Final cost : 0.42473791360831004
# Compute control for a deterministic system
# Cost in iteration 0: 0.42473791360831004
# Final cost : 0.4097552595877446
# Compute control for a deterministic system
# Cost in iteration 0: 0.4097552595877446
# Final cost : 0.398388416823336
# Compute control for a deterministic system
# Cost in iteration 0: 0.398388416823336
# Final cost : 0.3795039521563429
# Compute control for a deterministic system
# Cost in iteration 0: 0.3795039521563429
# Final cost : 0.36185998092569355
# Compute control for a deterministic system
# Cost in iteration 0: 0.6589478283737877
# Final cost : 0.3451376259829029
# Compute control for a deterministic system
# Cost in iteration 0: 0.3451376259829029
# Final cost : 0.3345440014145435
# Compute control for a deterministic system
# Cost in iteration 0: 0.3345440014145435
# Final cost : 0.3345438625965033
# Compute control for a deterministic system
# Cost in iteration 0: 0.3345438625965033
# Converged in iteration 339 with cost 0.3345438623145416 because of step counter
# Final cost : 0.3345438623145416
# Compute control for a deterministic system
# Cost in iteration 0: 0.3345438623145416
# Converged in iteration 3 with cost 0.3345438623145404 because of step counter
# Final cost : 0.3345438623145404
# Compute control for a deterministic system
# Cost in iteration 0: 0.5565133986478239
# Final cost : 0.2958161212392029
# Compute control for a deterministic system
# Cost in iteration 0: 0.2958161212392029
# Final cost : 0.28665318582909277
# Compute control for a deterministic system
# Cost in iteration 0: 0.28665318582909277
# Final cost : 0.2866530911144598
# Compute control for a deterministic system
# Cost in iteration 0: 0.2866530911144598
# Converged in iteration 291 with cost 0.2866530909562976 because of step counter
# Final cost : 0.2866530909562976
# Compute control for a deterministic system
# Cost in iteration 0: 0.2866530909562976
# Converged in iteration 2 with cost 0.28665309095629726 because of step counter
# Final cost : 0.28665309095629726
# Compute control for a deterministic system
# Cost in iteration 0: 0.48177759163836464
# Final cost : 0.2587888625171757
# Compute control for a deterministic system
# Cost in iteration 0: 0.2587888625171757
# Final cost : 0.250701133591786
# Compute control for a deterministic system
# Cost in iteration 0: 0.250701133591786
# Final cost : 0.2507010699442307
# Compute control for a deterministic system
# Cost in iteration 0: 0.2507010699442307
# Converged in iteration 239 with cost 0.2507010698784554 because of vanishing difference
# Final cost : 0.2507010698784554
# Compute control for a deterministic system
# Cost in iteration 0: 0.2507010698784546
# Converged in iteration 7 with cost 0.2507010698784506 because of step counter
# Final cost : 0.2507010698784506
# Compute control for a deterministic system
# Cost in iteration 0: 0.3974681092101906
# Final cost : 0.2156776069169373
# Compute control for a deterministic system
# Cost in iteration 0: 0.2156776069169373
# Final cost : 0.2088489207362455
# Compute control for a deterministic system
# Cost in iteration 0: 0.2088489207362455
# Final cost : 0.20884888680637098
# Compute control for a deterministic system
# Cost in iteration 0: 0.20884888680637098
# Converged in iteration 184 with cost 0.20884888679048952 because of vanishing difference
# Final cost : 0.20884888679048952
# Compute control for a deterministic system
# Cost in iteration 0: 0.20884888679048952
# Converged in iteration 3 with cost 0.20884888679048877 because of step counter
# Final cost : 0.20884888679048877
# Compute control for a deterministic system
# Cost in iteration 0: 0.32283194464800646
# Final cost : 0.1762275086043848
# Compute control for a deterministic system
# Cost in iteration 0: 0.1762275086043848
# Final cost : 0.17056392141813806
# Compute control for a deterministic system
# Cost in iteration 0: 0.17056392141813806
# Final cost : 0.17056390355950635
# Compute control for a deterministic system
# Cost in iteration 0: 0.17056390355950635
# Converged in iteration 95 with cost 0.17056390355874398 because of step counter
# Final cost : 0.17056390355874398
# Compute control for a deterministic system
# Cost in iteration 0: 0.17056390355874398
# Converged in iteration 1 with cost 0.17056390355874398 because of step counter
# Final cost : 0.17056390355874398
# Compute control for a deterministic system
# Cost in iteration 0: 0.2694853832909705
# Final cost : 0.14739013384304114
# Compute control for a deterministic system
# Cost in iteration 0: 0.14739013384304114
# Final cost : 0.14259039642665458
# Compute control for a deterministic system
# Cost in iteration 0: 0.14259039642665458
# Final cost : 0.14259038619499195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14259038619499195
# Converged in iteration 22 with cost 0.14259038619496503 because of step counter
# Final cost : 0.14259038619496503
# Compute control for a deterministic system
# Cost in iteration 0: 0.14259038619496503
# Converged in iteration 3 with cost 0.14259038619496472 because of step counter
# Final cost : 0.14259038619496472
# Compute control for a deterministic system
# Cost in iteration 0: 0.21012576640230501
# Final cost : 0.11483873739459104
# Compute control for a deterministic system
# Cost in iteration 0: 0.11483873739459104
# Final cost : 0.11103164527229661
# Compute control for a deterministic system
# Cost in iteration 0: 0.11103164527229661
# Converged in iteration 193 with cost 0.11103164062661645 because of step counter
# Final cost : 0.11103164062661645
# Compute control for a deterministic system
# Cost in iteration 0: 0.11103164062661645
# Converged in iteration 1 with cost 0.11103164062661645 because of step counter
# Final cost : 0.11103164062661645
# Compute control for a deterministic system
# Cost in iteration 0: 0.11103164062661645
# Converged in iteration 3 with cost 0.11103164062661579 because of step counter
# Final cost : 0.11103164062661579
# Compute control for a deterministic system
# Cost in iteration 0: 0.15842437811948207
# Final cost : 0.08625255047842922
# Compute control for a deterministic system
# Cost in iteration 0: 0.08625255047842922
# Final cost : 0.08333801617027933
# Compute control for a deterministic system
# Cost in iteration 0: 0.08333801617027933
# Converged in iteration 115 with cost 0.08333801427167069 because of vanishing difference
# Final cost : 0.08333801427167069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08333801427167045
# Converged in iteration 3 with cost 0.08333801427167 because of vanishing difference
# Final cost : 0.08333801427167
# Compute control for a deterministic system
# Cost in iteration 0: 0.08333801427166977
# Converged in iteration 7 with cost 0.08333801427166795 because of step counter
# Final cost : 0.08333801427166795
# Compute control for a deterministic system
# Cost in iteration 0: 0.11406408576532198
# Final cost : 0.06169401820145264
# Compute control for a deterministic system
# Cost in iteration 0: 0.06169401820145264
# Final cost : 0.05956743615356471
# Compute control for a deterministic system
# Cost in iteration 0: 0.05956743615356471
# Converged in iteration 122 with cost 0.059567435444315114 because of vanishing difference
# Final cost : 0.059567435444315114
# Compute control for a deterministic system
# Cost in iteration 0: 0.059567435444314885
# Converged in iteration 1 with cost 0.059567435444314885 because of step counter
# Final cost : 0.059567435444314885
# Compute control for a deterministic system
# Cost in iteration 0: 0.059567435444314885
# Converged in iteration 1 with cost 0.059567435444314885 because of step counter
# Final cost : 0.059567435444314885
# Compute control for a deterministic system
# Cost in iteration 0: 0.08374780129744375
# Final cost : 0.04497191701892726
# Compute control for a deterministic system
# Cost in iteration 0: 0.04497191701892726
# Final cost : 0.04339669461894034
# Compute control for a deterministic system
# Cost in iteration 0: 0.04339669461894034
# Converged in iteration 107 with cost 0.04339669430579952 because of vanishing difference
# Final cost : 0.04339669430579952
# Compute control for a deterministic system
# Cost in iteration 0: 0.043396694305799365
# Converged in iteration 16 with cost 0.043396694305793126 because of vanishing difference
# Final cost : 0.043396694305793126
# Compute control for a deterministic system
# Cost in iteration 0: 0.04339669430579311
# Converged in iteration 1 with cost 0.04339669430579311 because of step counter
# Final cost : 0.04339669430579311
# Compute control for a deterministic system
# Cost in iteration 0: 0.05228622546977915
# Final cost : 0.027745434435899302
# Compute control for a deterministic system
# Cost in iteration 0: 0.027745434435899302
# Final cost : 0.026754693813556486
# Compute control for a deterministic system
# Cost in iteration 0: 0.026754693813556486
# Converged in iteration 64 with cost 0.026754693696554893 because of vanishing difference
# Final cost : 0.026754693696554893
# Compute control for a deterministic system
# Cost in iteration 0: 0.026754693696554803
# Converged in iteration 2 with cost 0.02675469369655449 because of step counter
# Final cost : 0.02675469369655449
# Compute control for a deterministic system
# Cost in iteration 0: 0.02675469369655449
# Converged in iteration 1 with cost 0.02675469369655449 because of step counter
# Final cost : 0.02675469369655449
# Compute control for a deterministic system
# Cost in iteration 0: 0.028107679053804943
# Final cost : 0.014656977032128093
# Compute control for a deterministic system
# Cost in iteration 0: 0.014656977032128093
# Final cost : 0.014124162213205156
# Compute control for a deterministic system
# Cost in iteration 0: 0.014124162213205156
# Converged in iteration 45 with cost 0.014124162166335177 because of vanishing difference
# Final cost : 0.014124162166335177
# Compute control for a deterministic system
# Cost in iteration 0: 0.014124162166335037
# Converged in iteration 1 with cost 0.014124162166335037 because of step counter
# Final cost : 0.014124162166335037
# Compute control for a deterministic system
# Cost in iteration 0: 0.014124162166335037
# Converged in iteration 1 with cost 0.014124162166335037 because of step counter
# Final cost : 0.014124162166335037
# Compute control for a deterministic system
# Cost in iteration 0: 0.011435787543422324
# Final cost : 0.0058002022362822194
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058002022362822194
# Final cost : 0.005585212798443187
# Compute control for a deterministic system
# Cost in iteration 0: 0.005585212798443187
# Converged in iteration 30 with cost 0.0055852127814010255 because of step counter
# Final cost : 0.0055852127814010255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055852127814010255
# Converged in iteration 1 with cost 0.0055852127814010255 because of vanishing difference
# Final cost : 0.0055852127814010255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055852127814009864
# Converged in iteration 1 with cost 0.0055852127814009864 because of step counter
# Final cost : 0.0055852127814009864
# Compute control for a deterministic system
# Cost in iteration 0: 0.003476025861256582
# Final cost : 0.0017091714430696719
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017091714430696719
# Final cost : 0.0016445058072520808
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016445058072520808
# Converged in iteration 30 with cost 0.0016445058022009572 because of step counter
# Final cost : 0.0016445058022009572
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016445058022009572
# Converged in iteration 5 with cost 0.0016445058022007204 because of step counter
# Final cost : 0.0016445058022007204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016445058022007204
# Converged in iteration 2 with cost 0.001644505802200706 because of step counter
# Final cost : 0.001644505802200706

# %%
save(results_peak)
