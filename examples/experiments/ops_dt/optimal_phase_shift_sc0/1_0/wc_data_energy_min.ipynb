# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1650], wc.inh[0,1650]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  314  2155  4000  5845  7691  9536 11381 13227 15072 16918 18763 20608
#  22454 24299 26144 27990 29835]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 4000, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s0_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s0_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 results_min = read()
#       2 results_peak = readfile("results_peak_w2.pickle")
#
# Cell In [13], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("a_s0_l2.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s0_l2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03126865614810596
# Final cost : 0.02347687024281557
# Compute control for a deterministic system
# Cost in iteration 0: 0.02347687024281557
# Final cost : 0.000351762990509492
# Compute control for a deterministic system
# Cost in iteration 0: 0.000351762990509492
# Final cost : 0.00032941679491309294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032941679491309294
# Final cost : 0.00032937114331435053
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032937114331435053
# Converged in iteration 220 with cost 0.0003293711356201919 because of step counter
# Final cost : 0.0003293711356201919
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003293711356201919
# Converged in iteration 1 with cost 0.0003293711356201919 because of step counter
# Final cost : 0.0003293711356201919
# Compute control for a deterministic system
# Cost in iteration 0: 0.12302646406868373
# Final cost : 0.09436649631691577
# Compute control for a deterministic system
# Cost in iteration 0: 0.09436649631691577
# Final cost : 0.001415991171230785
# Compute control for a deterministic system
# Cost in iteration 0: 0.001415991171230785
# Final cost : 0.0013047513387994623
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013047513387994623
# Final cost : 0.001304085516287272
# Compute control for a deterministic system
# Cost in iteration 0: 0.001304085516287272
# Final cost : 0.0013040846859015932
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013040846859015932
# Converged in iteration 34 with cost 0.0013040846858951717 because of step counter
# Final cost : 0.0013040846858951717
# Compute control for a deterministic system
# Cost in iteration 0: 0.26784772200669704
# Final cost : 0.2121800068652826
# Compute control for a deterministic system
# Cost in iteration 0: 0.2121800068652826
# Final cost : 0.0032422265644752495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032422265644752495
# Final cost : 0.0029055669377195874
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029055669377195874
# Final cost : 0.0029023804739349984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029023804739349984
# Final cost : 0.002902372204216908
# Compute control for a deterministic system
# Cost in iteration 0: 0.002902372204216908
# Converged in iteration 189 with cost 0.0029023722037762 because of vanishing difference
# Final cost : 0.0029023722037762
# Compute control for a deterministic system
# Cost in iteration 0: 0.4578531463623979
# Final cost : 0.37680189945815434
# Compute control for a deterministic system
# Cost in iteration 0: 0.37680189945815434
# Final cost : 0.005979916105523707
# Compute control for a deterministic system
# Cost in iteration 0: 0.005979916105523707
# Final cost : 0.005164132700113013
# Compute control for a deterministic system
# Cost in iteration 0: 0.005164132700113013
# Final cost : 0.0051541289831793045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0051541289831793045
# Final cost : 0.005154093004230854
# Compute control for a deterministic system
# Cost in iteration 0: 0.005154093004230854
# Converged in iteration 350 with cost 0.0051540929965687345 because of step counter
# Final cost : 0.0051540929965687345
# Compute control for a deterministic system
# Cost in iteration 0: 0.6697418248917717
# Final cost : 0.5721425326303758
# Compute control for a deterministic system
# Cost in iteration 0: 0.5721425326303758
# Final cost : 0.009610507822076862
# Compute control for a deterministic system
# Cost in iteration 0: 0.009610507822076862
# Final cost : 0.00795993722646011
# Compute control for a deterministic system
# Cost in iteration 0: 0.00795993722646011
# Final cost : 0.00793578340830777
# Compute control for a deterministic system
# Cost in iteration 0: 0.00793578340830777
# Final cost : 0.007935485492216763
# Compute control for a deterministic system
# Cost in iteration 0: 0.007935485492216763
# Converged in iteration 523 with cost 0.007935485350258764 because of step counter
# Final cost : 0.007935485350258764
# Compute control for a deterministic system
# Cost in iteration 0: 0.8923107726170936
# Final cost : 0.7885036201125282
# Compute control for a deterministic system
# Cost in iteration 0: 0.7885036201125282
# Final cost : 0.014286713855790065
# Compute control for a deterministic system
# Cost in iteration 0: 0.014286713855790065
# Final cost : 0.011309134643289523
# Compute control for a deterministic system
# Cost in iteration 0: 0.011309134643289523
# Final cost : 0.011257902631604335
# Compute control for a deterministic system
# Cost in iteration 0: 0.011257902631604335
# Final cost : 0.011257018213519756
# Compute control for a deterministic system
# Cost in iteration 0: 0.011257018213519756
# Converged in iteration 635 with cost 0.011257017862298418 because of step counter
# Final cost : 0.011257017862298418
# Compute control for a deterministic system
# Cost in iteration 0: 1.1132551550817364
# Final cost : 1.012249698501971
# Compute control for a deterministic system
# Cost in iteration 0: 1.012249698501971
# Final cost : 0.020127764535854742
# Compute control for a deterministic system
# Cost in iteration 0: 0.020127764535854742
# Final cost : 0.01518567017038431
# Compute control for a deterministic system
# Cost in iteration 0: 0.01518567017038431
# Final cost : 0.015086345425506652
# Compute control for a deterministic system
# Cost in iteration 0: 0.015086345425506652
# Final cost : 0.015083460446005512
# Compute control for a deterministic system
# Cost in iteration 0: 0.015083460446005512
# Converged in iteration 856 with cost 0.015083456968049127 because of step counter
# Final cost : 0.015083456968049127
# Compute control for a deterministic system
# Cost in iteration 0: 1.3239898932497274
# Final cost : 1.2318149080665324
# Compute control for a deterministic system
# Cost in iteration 0: 1.2318149080665324
# Final cost : 0.02729138349832792
# Compute control for a deterministic system
# Cost in iteration 0: 0.02729138349832792
# Final cost : 0.01956454743821424
# Compute control for a deterministic system
# Cost in iteration 0: 0.01956454743821424
# Final cost : 0.01937994886407312
# Compute control for a deterministic system
# Cost in iteration 0: 0.01937994886407312
# Final cost : 0.01937441776624509
# Compute control for a deterministic system
# Cost in iteration 0: 0.01937441776624509
# Final cost : 0.019374398878819
# Compute control for a deterministic system
# Cost in iteration 0: 1.5194297410056663
# Final cost : 1.4391575312165756
# Compute control for a deterministic system
# Cost in iteration 0: 1.4391575312165756
# Final cost : 0.03601414663011211
# Compute control for a deterministic system
# Cost in iteration 0: 0.03601414663011211
# Final cost : 0.024425020392532627
# Compute control for a deterministic system
# Cost in iteration 0: 0.024425020392532627
# Final cost : 0.0241036033272523
# Compute control for a deterministic system
# Cost in iteration 0: 0.0241036033272523
# Final cost : 0.024082941041795126
# Compute control for a deterministic system
# Cost in iteration 0: 0.024082941041795126
# Final cost : 0.024082823528138453
# Compute control for a deterministic system
# Cost in iteration 0: 1.6970170944858902
# Final cost : 1.629549497278871
# Compute control for a deterministic system
# Cost in iteration 0: 1.629549497278871
# Final cost : 0.046682919624160164
# Compute control for a deterministic system
# Cost in iteration 0: 0.046682919624160164
# Final cost : 0.02975610790571724
# Compute control for a deterministic system
# Cost in iteration 0: 0.02975610790571724
# Final cost : 0.02920262854376113
# Compute control for a deterministic system
# Cost in iteration 0: 0.02920262854376113
# Final cost : 0.029153637278001566
# Compute control for a deterministic system
# Cost in iteration 0: 0.029153637278001566
# Final cost : 0.029152849752471722
# Compute control for a deterministic system
# Cost in iteration 0: 1.8557444091196806
# Final cost : 1.8006525687681196
# Compute control for a deterministic system
# Cost in iteration 0: 1.8006525687681196
# Final cost : 0.05997948374378531
# Compute control for a deterministic system
# Cost in iteration 0: 0.05997948374378531
# Final cost : 0.03556441409181588
# Compute control for a deterministic system
# Cost in iteration 0: 0.03556441409181588
# Final cost : 0.03464653192399014
# Compute control for a deterministic system
# Cost in iteration 0: 0.03464653192399014
# Final cost : 0.03451924483483274
# Compute control for a deterministic system
# Cost in iteration 0: 0.03451924483483274
# Final cost : 0.03451605839446605
# Compute control for a deterministic system
# Cost in iteration 0: 1.9982957834019026
# Final cost : 1.9546780200405456
# Compute control for a deterministic system
# Cost in iteration 0: 1.9546780200405456
# Final cost : 0.07764759773402109
# Compute control for a deterministic system
# Cost in iteration 0: 0.07764759773402109
# Final cost : 0.04202329640846119
# Compute control for a deterministic system
# Cost in iteration 0: 0.04202329640846119
# Final cost : 0.04052126764265131
# Compute control for a deterministic system
# Cost in iteration 0: 0.04052126764265131
# Final cost : 0.04022104182057864
# Compute control for a deterministic system
# Cost in iteration 0: 0.04022104182057864
# Final cost : 0.04020746824902846
# Compute control for a deterministic system
# Cost in iteration 0: 2.118902133569074
# Final cost : 2.08506488174164
# Compute control for a deterministic system
# Cost in iteration 0: 2.08506488174164
# Final cost : 0.10175867687772006
# Compute control for a deterministic system
# Cost in iteration 0: 0.10175867687772006
# Final cost : 0.048902742792126884
# Compute control for a deterministic system
# Cost in iteration 0: 0.048902742792126884
# Final cost : 0.04651534476026379
# Compute control for a deterministic system
# Cost in iteration 0: 0.04651534476026379
# Final cost : 0.04590757721320588
# Compute control for a deterministic system
# Cost in iteration 0: 0.04590757721320588
# Final cost : 0.04586251289558755
# Compute control for a deterministic system
# Cost in iteration 0: 2.2212548647990578
# Final cost : 2.195695467162056
# Compute control for a deterministic system
# Cost in iteration 0: 2.195695467162056
# Final cost : 0.13855313925381627
# Compute control for a deterministic system
# Cost in iteration 0: 0.13855313925381627
# Final cost : 0.05635448908382528
# Compute control for a deterministic system
# Cost in iteration 0: 0.05635448908382528
# Final cost : 0.052972329646809584
# Compute control for a deterministic system
# Cost in iteration 0: 0.052972329646809584
# Final cost : 0.05160751345405421
# Compute control for a deterministic system
# Cost in iteration 0: 0.05160751345405421
# Final cost : 0.05141981928507952
# Compute control for a deterministic system
# Cost in iteration 0: 2.305769409106584
# Final cost : 2.287035329902376
# Compute control for a deterministic system
# Cost in iteration 0: 2.287035329902376
# Final cost : 0.19688500167532175
# Compute control for a deterministic system
# Cost in iteration 0: 0.19688500167532175
# Final cost : 0.06436336914484304
# Compute control for a deterministic system
# Cost in iteration 0: 0.06436336914484304
# Final cost : 0.05984460626073046
# Compute control for a deterministic system
# Cost in iteration 0: 0.05984460626073046
# Final cost : 0.057208449850130634
# Compute control for a deterministic system
# Cost in iteration 0: 0.057208449850130634
# Final cost : 0.05660462985075603
# Compute control for a deterministic system
# Cost in iteration 0: 2.3726319941561687
# Final cost : 2.3593714721552836
# Compute control for a deterministic system
# Cost in iteration 0: 2.3593714721552836
# Final cost : 0.27500717636604843
# Compute control for a deterministic system
# Cost in iteration 0: 0.27500717636604843
# Final cost : 0.073087141946994
# Compute control for a deterministic system
# Cost in iteration 0: 0.073087141946994
# Final cost : 0.0684800052897146
# Compute control for a deterministic system
# Cost in iteration 0: 0.0684800052897146
# Final cost : 0.06359699174212101
# Compute control for a deterministic system
# Cost in iteration 0: 0.06359699174212101
# Final cost : 0.06115980024132392
# Compute control for a deterministic system
# Cost in iteration 0: 2.4215576115068562
# Final cost : 2.412531906426648
# Compute control for a deterministic system
# Cost in iteration 0: 2.412531906426648
# Final cost : 0.35430164391571667
# Compute control for a deterministic system
# Cost in iteration 0: 0.35430164391571667
# Final cost : 0.08467799866968492
# Compute control for a deterministic system
# Cost in iteration 0: 0.08467799866968492
# Final cost : 0.07952031743998007
# Compute control for a deterministic system
# Cost in iteration 0: 0.07952031743998007
# Final cost : 0.07457962803829499
# Compute control for a deterministic system
# Cost in iteration 0: 0.07457962803829499
# Final cost : 0.0653066973269827
# Compute control for a deterministic system
# Cost in iteration 0: 2.4516253565273725
# Final cost : 2.4457008615394393
# Compute control for a deterministic system
# Cost in iteration 0: 2.4457008615394393
# Final cost : 0.4463758829447623
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463758829447623
# Final cost : 0.11051125617689658
# Compute control for a deterministic system
# Cost in iteration 0: 0.11051125617689658
# Final cost : 0.09661424816633458
# Compute control for a deterministic system
# Cost in iteration 0: 0.09661424816633458
# Final cost : 0.08943746049957915
# Compute control for a deterministic system
# Cost in iteration 0: 0.08943746049957915
# Final cost : 0.08104045569574683
# Compute control for a deterministic system
# Cost in iteration 0: 2.4616320092492883
# Final cost : 2.4577976584094237
# Compute control for a deterministic system
# Cost in iteration 0: 2.4577976584094237
# Final cost : 0.6147077572716831
# Compute control for a deterministic system
# Cost in iteration 0: 0.6147077572716831
# Final cost : 0.3418874086840609
# Compute control for a deterministic system
# Cost in iteration 0: 0.3418874086840609
# Final cost : 0.3177267841232161
# Compute control for a deterministic system
# Cost in iteration 0: 0.3177267841232161
# Final cost : 0.27438571384459615
# Compute control for a deterministic system
# Cost in iteration 0: 0.27438571384459615
# Final cost : 0.10257743910966843
# Compute control for a deterministic system
# Cost in iteration 0: 2.4506725182192164
# Final cost : 2.4478975728703456
# Compute control for a deterministic system
# Cost in iteration 0: 2.4478975728703456
# Final cost : 1.2263087682924705
# Compute control for a deterministic system
# Cost in iteration 0: 1.2263087682924705
# Final cost : 0.6072674129156519
# Compute control for a deterministic system
# Cost in iteration 0: 0.6072674129156519
# Final cost : 0.47062818689399044
# Compute control for a deterministic system
# Cost in iteration 0: 0.47062818689399044
# Final cost : 0.3943833693264347
# Compute control for a deterministic system
# Cost in iteration 0: 0.3943833693264347
# Final cost : 0.34782146425287064
# Compute control for a deterministic system
# Cost in iteration 0: 2.420258866736131
# Final cost : 2.4176100272628473
# Compute control for a deterministic system
# Cost in iteration 0: 2.4176100272628473
# Final cost : 0.6483386906287629
# Compute control for a deterministic system
# Cost in iteration 0: 0.6483386906287629
# Final cost : 0.20339208126549618
# Compute control for a deterministic system
# Cost in iteration 0: 0.20339208126549618
# Final cost : 0.16430072366232443
# Compute control for a deterministic system
# Cost in iteration 0: 0.16430072366232443
# Final cost : 0.15388720721911303
# Compute control for a deterministic system
# Cost in iteration 0: 0.15388720721911303
# Final cost : 0.1530444537291533
# Compute control for a deterministic system
# Cost in iteration 0: 2.3730526638755856
# Final cost : 2.3696084623663913
# Compute control for a deterministic system
# Cost in iteration 0: 2.3696084623663913
# Final cost : 0.5056656063669013
# Compute control for a deterministic system
# Cost in iteration 0: 0.5056656063669013
# Final cost : 0.17350214391381039
# Compute control for a deterministic system
# Cost in iteration 0: 0.17350214391381039
# Final cost : 0.14487829088831672
# Compute control for a deterministic system
# Cost in iteration 0: 0.14487829088831672
# Final cost : 0.13719487902500838
# Compute control for a deterministic system
# Cost in iteration 0: 0.13719487902500838
# Final cost : 0.13672487503555078
# Compute control for a deterministic system
# Cost in iteration 0: 2.3122602870527453
# Final cost : 2.3070782890442914
# Compute control for a deterministic system
# Cost in iteration 0: 2.3070782890442914
# Final cost : 0.4002501385802848
# Compute control for a deterministic system
# Cost in iteration 0: 0.4002501385802848
# Final cost : 0.14674960573309248
# Compute control for a deterministic system
# Cost in iteration 0: 0.14674960573309248
# Final cost : 0.12665140535436548
# Compute control for a deterministic system
# Cost in iteration 0: 0.12665140535436548
# Final cost : 0.12133890610466438
# Compute control for a deterministic system
# Cost in iteration 0: 0.12133890610466438
# Final cost : 0.12098977720199897
# Compute control for a deterministic system
# Cost in iteration 0: 2.2400725097360388
# Final cost : 2.2321556025702702
# Compute control for a deterministic system
# Cost in iteration 0: 2.2321556025702702
# Final cost : 0.3143224148745618
# Compute control for a deterministic system
# Cost in iteration 0: 0.3143224148745618
# Final cost : 0.12322473613724559
# Compute control for a deterministic system
# Cost in iteration 0: 0.12322473613724559
# Final cost : 0.10950951530864447
# Compute control for a deterministic system
# Cost in iteration 0: 0.10950951530864447
# Final cost : 0.10597968480986494
# Compute control for a deterministic system
# Cost in iteration 0: 0.10597968480986494
# Final cost : 0.10583037691393465
# Compute control for a deterministic system
# Cost in iteration 0: 2.1571673220260585
# Final cost : 2.145434147553925
# Compute control for a deterministic system
# Cost in iteration 0: 2.145434147553925
# Final cost : 0.244702288390713
# Compute control for a deterministic system
# Cost in iteration 0: 0.244702288390713
# Final cost : 0.10291739196564133
# Compute control for a deterministic system
# Cost in iteration 0: 0.10291739196564133
# Final cost : 0.09378324314900599
# Compute control for a deterministic system
# Cost in iteration 0: 0.09378324314900599
# Final cost : 0.09154500972149215
# Compute control for a deterministic system
# Cost in iteration 0: 0.09154500972149215
# Final cost : 0.09147628098313967
# Compute control for a deterministic system
# Cost in iteration 0: 2.060939464522631
# Final cost : 2.0440822076177656
# Compute control for a deterministic system
# Cost in iteration 0: 2.0440822076177656
# Final cost : 0.1880591657064004
# Compute control for a deterministic system
# Cost in iteration 0: 0.1880591657064004
# Final cost : 0.0852271949237391
# Compute control for a deterministic system
# Cost in iteration 0: 0.0852271949237391
# Final cost : 0.07927055139954163
# Compute control for a deterministic system
# Cost in iteration 0: 0.07927055139954163
# Final cost : 0.07795587280688412
# Compute control for a deterministic system
# Cost in iteration 0: 0.07795587280688412
# Final cost : 0.07791332273411244
# Compute control for a deterministic system
# Cost in iteration 0: 1.954497841038536
# Final cost : 1.931318250824556
# Compute control for a deterministic system
# Cost in iteration 0: 1.931318250824556
# Final cost : 0.14449252919415573
# Compute control for a deterministic system
# Cost in iteration 0: 0.14449252919415573
# Final cost : 0.07051760767416014
# Compute control for a deterministic system
# Cost in iteration 0: 0.07051760767416014
# Final cost : 0.06661847733114198
# Compute control for a deterministic system
# Cost in iteration 0: 0.06661847733114198
# Final cost : 0.06588925083013024
# Compute control for a deterministic system
# Cost in iteration 0: 0.06588925083013024
# Final cost : 0.06587233704734786
# Compute control for a deterministic system
# Cost in iteration 0: 1.8348314364982121
# Final cost : 1.8039552760113455
# Compute control for a deterministic system
# Cost in iteration 0: 1.8039552760113455
# Final cost : 0.11044171452017225
# Compute control for a deterministic system
# Cost in iteration 0: 0.11044171452017225
# Final cost : 0.057983114781445536
# Compute control for a deterministic system
# Cost in iteration 0: 0.057983114781445536
# Final cost : 0.05547749293686206
# Compute control for a deterministic system
# Cost in iteration 0: 0.05547749293686206
# Final cost : 0.05508896808858765
# Compute control for a deterministic system
# Cost in iteration 0: 0.05508896808858765
# Final cost : 0.05508158283285505
# Compute control for a deterministic system
# Cost in iteration 0: 1.7009841691732615
# Final cost : 1.661033455902184
# Compute control for a deterministic system
# Cost in iteration 0: 1.661033455902184
# Final cost : 0.08391498632301328
# Compute control for a deterministic system
# Cost in iteration 0: 0.08391498632301328
# Final cost : 0.04726939527329293
# Compute control for a deterministic system
# Cost in iteration 0: 0.04726939527329293
# Final cost : 0.04568854725856969
# Compute control for a deterministic system
# Cost in iteration 0: 0.04568854725856969
# Final cost : 0.04549526214342876
# Compute control for a deterministic system
# Cost in iteration 0: 0.04549526214342876
# Final cost : 0.04549324463090336
# Compute control for a deterministic system
# Cost in iteration 0: 1.5523189938210227
# Final cost : 1.5020739957293792
# Compute control for a deterministic system
# Cost in iteration 0: 1.5020739957293792
# Final cost : 0.0632408856493555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0632408856493555
# Final cost : 0.03808542064532998
# Compute control for a deterministic system
# Cost in iteration 0: 0.03808542064532998
# Final cost : 0.03711568433127922
# Compute control for a deterministic system
# Cost in iteration 0: 0.03711568433127922
# Final cost : 0.03702624753090957
# Compute control for a deterministic system
# Cost in iteration 0: 0.03702624753090957
# Final cost : 0.037025595274097066
# Compute control for a deterministic system
# Cost in iteration 0: 1.388731906159371
# Final cost : 1.3274305606177834
# Compute control for a deterministic system
# Cost in iteration 0: 1.3274305606177834
# Final cost : 0.04709270269846652
# Compute control for a deterministic system
# Cost in iteration 0: 0.04709270269846652
# Final cost : 0.030203068659047375
# Compute control for a deterministic system
# Cost in iteration 0: 0.030203068659047375
# Final cost : 0.02963596625793224
# Compute control for a deterministic system
# Cost in iteration 0: 0.02963596625793224
# Final cost : 0.02959105926915933
# Compute control for a deterministic system
# Cost in iteration 0: 0.02959105926915933
# Final cost : 0.029590928815566662
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109590812511593
# Final cost : 1.1387951398822767
# Compute control for a deterministic system
# Cost in iteration 0: 1.1387951398822767
# Final cost : 0.03445903359692632
# Compute control for a deterministic system
# Cost in iteration 0: 0.03445903359692632
# Final cost : 0.02344894474041675
# Compute control for a deterministic system
# Cost in iteration 0: 0.02344894474041675
# Final cost : 0.023127107483581637
# Compute control for a deterministic system
# Cost in iteration 0: 0.023127107483581637
# Final cost : 0.023109809565042112
# Compute control for a deterministic system
# Cost in iteration 0: 0.023109809565042112
# Final cost : 0.023109752694066895
# Compute control for a deterministic system
# Cost in iteration 0: 1.0210308291654024
# Final cost : 0.9398767713502519
# Compute control for a deterministic system
# Cost in iteration 0: 0.9398767713502519
# Final cost : 0.024588484910129334
# Compute control for a deterministic system
# Cost in iteration 0: 0.024588484910129334
# Final cost : 0.017694198203194993
# Compute control for a deterministic system
# Cost in iteration 0: 0.017694198203194993
# Final cost : 0.017521500238297617
# Compute control for a deterministic system
# Cost in iteration 0: 0.017521500238297617
# Final cost : 0.017516051099949505
# Compute control for a deterministic system
# Cost in iteration 0: 0.017516051099949505
# Converged in iteration 857 with cost 0.017516039797264554 because of step counter
# Final cost : 0.017516039797264554
# Compute control for a deterministic system
# Cost in iteration 0: 0.8185357032092722
# Final cost : 0.7327215927855807
# Compute control for a deterministic system
# Cost in iteration 0: 0.7327215927855807
# Final cost : 0.016783844528338403
# Compute control for a deterministic system
# Cost in iteration 0: 0.016783844528338403
# Final cost : 0.012748844036364677
# Compute control for a deterministic system
# Cost in iteration 0: 0.012748844036364677
# Final cost : 0.01266503836544797
# Compute control for a deterministic system
# Cost in iteration 0: 0.01266503836544797
# Final cost : 0.012663116725159487
# Compute control for a deterministic system
# Cost in iteration 0: 0.012663116725159487
# Converged in iteration 730 with cost 0.012663113380585098 because of step counter
# Final cost : 0.012663113380585098
# Compute control for a deterministic system
# Cost in iteration 0: 0.6187908724052963
# Final cost : 0.5357661380300587
# Compute control for a deterministic system
# Cost in iteration 0: 0.5357661380300587
# Final cost : 0.010963326606655744
# Compute control for a deterministic system
# Cost in iteration 0: 0.010963326606655744
# Final cost : 0.008754501417292717
# Compute control for a deterministic system
# Cost in iteration 0: 0.008754501417292717
# Final cost : 0.008716871516115221
# Compute control for a deterministic system
# Cost in iteration 0: 0.008716871516115221
# Final cost : 0.008716619583029977
# Compute control for a deterministic system
# Cost in iteration 0: 0.008716619583029977
# Converged in iteration 437 with cost 0.008716619350590565 because of step counter
# Final cost : 0.008716619350590565
# Compute control for a deterministic system
# Cost in iteration 0: 0.42723223558539636
# Final cost : 0.3561980336605183
# Compute control for a deterministic system
# Cost in iteration 0: 0.3561980336605183
# Final cost : 0.0066316565147801
# Compute control for a deterministic system
# Cost in iteration 0: 0.0066316565147801
# Final cost : 0.005548006914034772
# Compute control for a deterministic system
# Cost in iteration 0: 0.005548006914034772
# Final cost : 0.005533657002509485
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533657002509485
# Final cost : 0.005533595111258781
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533595111258781
# Converged in iteration 288 with cost 0.0055335951040316285 because of step counter
# Final cost : 0.0055335951040316285
# Compute control for a deterministic system
# Cost in iteration 0: 0.2563145066063064
# Final cost : 0.20554251085445185
# Compute control for a deterministic system
# Cost in iteration 0: 0.20554251085445185
# Final cost : 0.0035467887036040135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035467887036040135
# Final cost : 0.003094024503499794
# Compute control for a deterministic system
# Cost in iteration 0: 0.003094024503499794
# Final cost : 0.0030897512540190224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030897512540190224
# Final cost : 0.003089735658231598
# Compute control for a deterministic system
# Cost in iteration 0: 0.003089735658231598
# Converged in iteration 189 with cost 0.0030897356575618398 because of step counter
# Final cost : 0.0030897356575618398
# Compute control for a deterministic system
# Cost in iteration 0: 0.11994004860634938
# Final cost : 0.09286342716764362
# Compute control for a deterministic system
# Cost in iteration 0: 0.09286342716764362
# Final cost : 0.0015116762849787726
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015116762849787726
# Final cost : 0.0013656322519213025
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013656322519213025
# Final cost : 0.0013648294629456403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013648294629456403
# Converged in iteration 386 with cost 0.0013648286697349936 because of step counter
# Final cost : 0.0013648286697349936
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013648286697349936
# Converged in iteration 1 with cost 0.0013648286697349936 because of step counter
# Final cost : 0.0013648286697349936
# Compute control for a deterministic system
# Cost in iteration 0: 0.031231537495432997
# Final cost : 0.02357006950844064
# Compute control for a deterministic system
# Cost in iteration 0: 0.02357006950844064
# Final cost : 0.00036784822455786573
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036784822455786573
# Final cost : 0.000340819780267355
# Compute control for a deterministic system
# Cost in iteration 0: 0.000340819780267355
# Final cost : 0.00034077207749680827
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034077207749680827
# Converged in iteration 384 with cost 0.00034077203175169685 because of step counter
# Final cost : 0.00034077203175169685
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034077203175169685
# Converged in iteration 5 with cost 0.0003407720317511137 because of step counter
# Final cost : 0.0003407720317511137
# Compute control for a deterministic system
# Cost in iteration 0: 1.8316014599625827e-06
# Final cost : 1.3665549614462476e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.3665549614462476e-06
# Final cost : 2.0426347591383745e-08
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03210292593052147
# Final cost : 0.0013325526544539458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013325526544539458
# Final cost : 0.0013042951931861284
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013042951931861284
# Final cost : 0.0013040849092304213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013040849092304213
# Converged in iteration 374 with cost 0.0013040846858937331 because of vanishing difference
# Final cost : 0.0013040846858937331
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013040846858937331
# Converged in iteration 6 with cost 0.001304084685893356 because of step counter
# Final cost : 0.001304084685893356
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.03527766327205019
# Final cost : 0.002946960274457628
# Compute control for a deterministic system
# Cost in iteration 0: 0.002946960274457628
# Final cost : 0.0029029290883563555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029029290883563555
# Final cost : 0.002902374633053597
# Compute control for a deterministic system
# Cost in iteration 0: 0.002902374633053597
# Final cost : 0.0029023722039390257
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029023722039390257
# Converged in iteration 145 with cost 0.002902372203775243 because of step counter
# Final cost : 0.002902372203775243
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.031304502304237265
# Final cost : 0.005220341404825053
# Compute control for a deterministic system
# Cost in iteration 0: 0.005220341404825053
# Final cost : 0.0051552884850680596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0051552884850680596
# Final cost : 0.005154106198790641
# Compute control for a deterministic system
# Cost in iteration 0: 0.005154106198790641
# Final cost : 0.005154093000930391
# Compute control for a deterministic system
# Cost in iteration 0: 0.005154093000930391
# Converged in iteration 330 with cost 0.005154092996567903 because of step counter
# Final cost : 0.005154092996567903
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.04065475583245363
# Final cost : 0.008033786502267281
# Compute control for a deterministic system
# Cost in iteration 0: 0.008033786502267281
# Final cost : 0.007937713473422743
# Compute control for a deterministic system
# Cost in iteration 0: 0.007937713473422743
# Final cost : 0.007935519690958737
# Compute control for a deterministic system
# Cost in iteration 0: 0.007935519690958737
# Final cost : 0.007935485370784173
# Compute control for a deterministic system
# Cost in iteration 0: 0.007935485370784173
# Converged in iteration 404 with cost 0.007935485350250246 because of step counter
# Final cost : 0.007935485350250246
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.04870426954077676
# Final cost : 0.01139273452289145
# Compute control for a deterministic system
# Cost in iteration 0: 0.01139273452289145
# Final cost : 0.011260900256690022
# Compute control for a deterministic system
# Cost in iteration 0: 0.011260900256690022
# Final cost : 0.011257129374007926
# Compute control for a deterministic system
# Cost in iteration 0: 0.011257129374007926
# Final cost : 0.011257017894879437
# Compute control for a deterministic system
# Cost in iteration 0: 0.011257017894879437
# Converged in iteration 474 with cost 0.011257017862299963 because of step counter
# Final cost : 0.011257017862299963
# Compute control for a deterministic system
# Cost in iteration 0: 0.06515936407860018
# Final cost : 0.015265955849722986
# Compute control for a deterministic system
# Cost in iteration 0: 0.015265955849722986
# Final cost : 0.015089859176261216
# Compute control for a deterministic system
# Cost in iteration 0: 0.015089859176261216
# Final cost : 0.01508373809436986
# Compute control for a deterministic system
# Cost in iteration 0: 0.01508373809436986
# Final cost : 0.015083457423259264
# Compute control for a deterministic system
# Cost in iteration 0: 0.015083457423259264
# Converged in iteration 717 with cost 0.015083456968051016 because of step counter
# Final cost : 0.015083456968051016
# Compute control for a deterministic system
# Cost in iteration 0: 0.06497442217874277
# Final cost : 0.019587277299195363
# Compute control for a deterministic system
# Cost in iteration 0: 0.019587277299195363
# Final cost : 0.019383939243421928
# Compute control for a deterministic system
# Cost in iteration 0: 0.019383939243421928
# Final cost : 0.019374905601549662
# Compute control for a deterministic system
# Cost in iteration 0: 0.019374905601549662
# Final cost : 0.01937440047653232
# Compute control for a deterministic system
# Cost in iteration 0: 0.01937440047653232
# Converged in iteration 862 with cost 0.019374398878739 because of step counter
# Final cost : 0.019374398878739
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.07296689843223805
# Final cost : 0.024329721038234376
# Compute control for a deterministic system
# Cost in iteration 0: 0.024329721038234376
# Final cost : 0.02409661581330657
# Compute control for a deterministic system
# Cost in iteration 0: 0.02409661581330657
# Final cost : 0.02408363711728367
# Compute control for a deterministic system
# Cost in iteration 0: 0.02408363711728367
# Final cost : 0.024082830067185028
# Compute control for a deterministic system
# Cost in iteration 0: 0.024082830067185028
# Final cost : 0.02408282352580803
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.044041831029565985
# Final cost : 0.02939123467326449
# Compute control for a deterministic system
# Cost in iteration 0: 0.02939123467326449
# Final cost : 0.02917113405397818
# Compute control for a deterministic system
# Cost in iteration 0: 0.02917113405397818
# Final cost : 0.029154345230412465
# Compute control for a deterministic system
# Cost in iteration 0: 0.029154345230412465
# Final cost : 0.029152872316805748
# Compute control for a deterministic system
# Cost in iteration 0: 0.029152872316805748
# Final cost : 0.029152849687995364
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.10940801597408618
# Final cost : 0.034836585616492916
# Compute control for a deterministic system
# Cost in iteration 0: 0.034836585616492916
# Final cost : 0.03454285368059538
# Compute control for a deterministic system
# Cost in iteration 0: 0.03454285368059538
# Final cost : 0.03451969962634518
# Compute control for a deterministic system
# Cost in iteration 0: 0.03451969962634518
# Final cost : 0.03451614549912487
# Compute control for a deterministic system
# Cost in iteration 0: 0.03451614549912487
# Final cost : 0.03451605747660286
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.09511846582155406
# Final cost : 0.040531008186101586
# Compute control for a deterministic system
# Cost in iteration 0: 0.040531008186101586
# Final cost : 0.040245001034775664
# Compute control for a deterministic system
# Cost in iteration 0: 0.040245001034775664
# Final cost : 0.040214112341893815
# Compute control for a deterministic system
# Cost in iteration 0: 0.040214112341893815
# Final cost : 0.040207766636903106
# Compute control for a deterministic system
# Cost in iteration 0: 0.040207766636903106
# Final cost : 0.04020745463571731
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.05774767100153235
# Final cost : 0.04614664363456078
# Compute control for a deterministic system
# Cost in iteration 0: 0.04614664363456078
# Final cost : 0.04591204302082152
# Compute control for a deterministic system
# Cost in iteration 0: 0.04591204302082152
# Final cost : 0.04587462300101547
# Compute control for a deterministic system
# Cost in iteration 0: 0.04587462300101547
# Final cost : 0.04586358666037456
# Compute control for a deterministic system
# Cost in iteration 0: 0.04586358666037456
# Final cost : 0.04586244553201111
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.07664253236787864
# Final cost : 0.05175530774490782
# Compute control for a deterministic system
# Cost in iteration 0: 0.05175530774490782
# Final cost : 0.051496882846521104
# Compute control for a deterministic system
# Cost in iteration 0: 0.051496882846521104
# Final cost : 0.05144378755740194
# Compute control for a deterministic system
# Cost in iteration 0: 0.05144378755740194
# Final cost : 0.05142261013677208
# Compute control for a deterministic system
# Cost in iteration 0: 0.05142261013677208
# Final cost : 0.05141884901429703
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.07123399904290997
# Final cost : 0.056992963614051574
# Compute control for a deterministic system
# Cost in iteration 0: 0.056992963614051574
# Final cost : 0.056721097218261386
# Compute control for a deterministic system
# Cost in iteration 0: 0.056721097218261386
# Final cost : 0.05665143571584911
# Compute control for a deterministic system
# Cost in iteration 0: 0.05665143571584911
# Final cost : 0.05660549817241584
# Compute control for a deterministic system
# Cost in iteration 0: 0.05660549817241584
# Final cost : 0.05659390239622351
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.06850047142211944
# Final cost : 0.06150574971057713
# Compute control for a deterministic system
# Cost in iteration 0: 0.06150574971057713
# Final cost : 0.0612328333010204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0612328333010204
# Final cost : 0.06115939009979067
# Compute control for a deterministic system
# Cost in iteration 0: 0.06115939009979067
# Final cost : 0.0611115773813842
# Compute control for a deterministic system
# Cost in iteration 0: 0.0611115773813842
# Final cost : 0.061095355767023
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.130002219583498
# Final cost : 0.06518739042191422
# Compute control for a deterministic system
# Cost in iteration 0: 0.06518739042191422
# Final cost : 0.06501276922417074
# Compute control for a deterministic system
# Cost in iteration 0: 0.06501276922417074
# Final cost : 0.06496332374476839
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496332374476839
# Final cost : 0.06492063621025669
# Compute control for a deterministic system
# Cost in iteration 0: 0.06492063621025669
# Final cost : 0.06490375626858477
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.07911215418471323
# Final cost : 0.06830609021288764
# Compute control for a deterministic system
# Cost in iteration 0: 0.06830609021288764
# Final cost : 0.06822529311952692
# Compute control for a deterministic system
# Cost in iteration 0: 0.06822529311952692
# Final cost : 0.06819717685669184
# Compute control for a deterministic system
# Cost in iteration 0: 0.06819717685669184
# Final cost : 0.06817356190649101
# Compute control for a deterministic system
# Cost in iteration 0: 0.06817356190649101
# Final cost : 0.06815891061999055
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.09852805879369819
# Final cost : 0.07107553938685
# Compute control for a deterministic system
# Cost in iteration 0: 0.07107553938685
# Final cost : 0.07102791334699132
# Compute control for a deterministic system
# Cost in iteration 0: 0.07102791334699132
# Final cost : 0.07100922654169423
# Compute control for a deterministic system
# Cost in iteration 0: 0.07100922654169423
# Final cost : 0.07099104989621728
# Compute control for a deterministic system
# Cost in iteration 0: 0.07099104989621728
# Final cost : 0.0709807019515294
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.21033860746663074
# Final cost : 0.07330755383798075
# Compute control for a deterministic system
# Cost in iteration 0: 0.07330755383798075
# Final cost : 0.07327600124488302
# Compute control for a deterministic system
# Cost in iteration 0: 0.07327600124488302
# Final cost : 0.07326218507790405
# Compute control for a deterministic system
# Cost in iteration 0: 0.07326218507790405
# Final cost : 0.07324893796527328
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324893796527328
# Final cost : 0.07323714614980587
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897803883704858
# Final cost : 0.07508395254520522
# Compute control for a deterministic system
# Cost in iteration 0: 0.07508395254520522
# Final cost : 0.07504102564908609
# Compute control for a deterministic system
# Cost in iteration 0: 0.07504102564908609
# Final cost : 0.07502097427860763
# Compute control for a deterministic system
# Cost in iteration 0: 0.07502097427860763
# Final cost : 0.0750012859576199
# Compute control for a deterministic system
# Cost in iteration 0: 0.0750012859576199
# Final cost : 0.07498567026654426
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.17272605185069223
# Final cost : 0.07638956840152711
# Compute control for a deterministic system
# Cost in iteration 0: 0.07638956840152711
# Final cost : 0.0763642132202726
# Compute control for a deterministic system
# Cost in iteration 0: 0.0763642132202726
# Final cost : 0.07634806658865137
# Compute control for a deterministic system
# Cost in iteration 0: 0.07634806658865137
# Final cost : 0.07632842353012648
# Compute control for a deterministic system
# Cost in iteration 0: 0.07632842353012648
# Final cost : 0.07630455925500677
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.07837765232450376
# Final cost : 0.07747830417196852
# Compute control for a deterministic system
# Cost in iteration 0: 0.07747830417196852
# Final cost : 0.07745198403458478
# Compute control for a deterministic system
# Cost in iteration 0: 0.07745198403458478
# Final cost : 0.07743241094175835
# Compute control for a deterministic system
# Cost in iteration 0: 0.07743241094175835
# Final cost : 0.07740174113232463
# Compute control for a deterministic system
# Cost in iteration 0: 0.07740174113232463
# Final cost : 0.07736958278155025
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.08778905325543786
# Final cost : 0.07846061150578787
# Compute control for a deterministic system
# Cost in iteration 0: 0.07846061150578787
# Final cost : 0.07843828217322993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07843828217322993
# Final cost : 0.07842064726139954
# Compute control for a deterministic system
# Cost in iteration 0: 0.07842064726139954
# Final cost : 0.07839748052440283
# Compute control for a deterministic system
# Cost in iteration 0: 0.07839748052440283
# Final cost : 0.07835395230289366
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.111986816683448
# Final cost : 0.07947638355834934
# Compute control for a deterministic system
# Cost in iteration 0: 0.07947638355834934
# Final cost : 0.07945665515852333
# Compute control for a deterministic system
# Cost in iteration 0: 0.07945665515852333
# Final cost : 0.07944233436860461
# Compute control for a deterministic system
# Cost in iteration 0: 0.07944233436860461
# Final cost : 0.07939837510538103
# Compute control for a deterministic system
# Cost in iteration 0: 0.07939837510538103
# Final cost : 0.07936674964746505
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.13591741740363136
# Final cost : 0.08057618347478908
# Compute control for a deterministic system
# Cost in iteration 0: 0.08057618347478908
# Final cost : 0.0805470468412775
# Compute control for a deterministic system
# Cost in iteration 0: 0.0805470468412775
# Final cost : 0.08053332145921145
# Compute control for a deterministic system
# Cost in iteration 0: 0.08053332145921145
# Final cost : 0.08051027235858284
# Compute control for a deterministic system
# Cost in iteration 0: 0.08051027235858284
# Final cost : 0.08043547123131613
# Compute control for a deterministic system
# Cost in iteration 0: 0.13010527460839244
# Final cost : 0.06677627491256662
# Compute control for a deterministic system
# Cost in iteration 0: 0.06677627491256662
# Final cost : 0.06605673309997138
# Compute control for a deterministic system
# Cost in iteration 0: 0.06605673309997138
# Final cost : 0.06592024226837989
# Compute control for a deterministic system
# Cost in iteration 0: 0.06592024226837989
# Final cost : 0.06587399042870418
# Compute control for a deterministic system
# Cost in iteration 0: 0.06587399042870418
# Final cost : 0.06587232390502512
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.07935341418903302
# Final cost : 0.055819532344361135
# Compute control for a deterministic system
# Cost in iteration 0: 0.055819532344361135
# Final cost : 0.05520780626156009
# Compute control for a deterministic system
# Cost in iteration 0: 0.05520780626156009
# Final cost : 0.05510740105996849
# Compute control for a deterministic system
# Cost in iteration 0: 0.05510740105996849
# Final cost : 0.055082062903406566
# Compute control for a deterministic system
# Cost in iteration 0: 0.055082062903406566
# Final cost : 0.055081580990076894
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.09543279620827405
# Final cost : 0.0461369470381591
# Compute control for a deterministic system
# Cost in iteration 0: 0.0461369470381591
# ...
# Final cost : 0.0649030731411616
# Compute control for a deterministic system
# Cost in iteration 0: 0.0649030731411616
# Final cost : 0.06490282610845267
# Compute control for a deterministic system
# Cost in iteration 0: 0.06490282610845267
# Final cost : 0.06490268934094004
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.0768885752495819
# Final cost : 0.06815957257015597
# Compute control for a deterministic system
# Cost in iteration 0: 0.06815957257015597
# Final cost : 0.06815827089265544
# Compute control for a deterministic system
# Cost in iteration 0: 0.06815827089265544
# Final cost : 0.06815780388671677
# Compute control for a deterministic system
# Cost in iteration 0: 0.06815780388671677
# Final cost : 0.06815738831429201
# Compute control for a deterministic system
# Cost in iteration 0: 0.06815738831429201
# Final cost : 0.06815704203340897
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.09876199529245056
# Final cost : 0.07098662215800418
# Compute control for a deterministic system
# Cost in iteration 0: 0.07098662215800418
# Final cost : 0.07098254953726221
# Compute control for a deterministic system
# Cost in iteration 0: 0.07098254953726221
# Final cost : 0.0709806520914687
# Compute control for a deterministic system
# Cost in iteration 0: 0.0709806520914687
# Final cost : 0.07097889208959254
# Compute control for a deterministic system
# Cost in iteration 0: 0.07097889208959254
# Final cost : 0.07097792080634818
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.21910887807155321
# Final cost : 0.07328322612871985
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328322612871985
# Final cost : 0.07325632443678776
# Compute control for a deterministic system
# Cost in iteration 0: 0.07325632443678776
# Final cost : 0.07324509374354873
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324509374354873
# Final cost : 0.07323599761746932
# Compute control for a deterministic system
# Cost in iteration 0: 0.07323599761746932
# Final cost : 0.07323320795213338
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.1969766434418284
# Final cost : 0.07500989392715615
# Compute control for a deterministic system
# Cost in iteration 0: 0.07500989392715615
# Final cost : 0.07499853607738459
# Compute control for a deterministic system
# Cost in iteration 0: 0.07499853607738459
# Final cost : 0.07499132095615596
# Compute control for a deterministic system
# Cost in iteration 0: 0.07499132095615596
# Final cost : 0.07498468719795101
# Compute control for a deterministic system
# Cost in iteration 0: 0.07498468719795101
# Final cost : 0.07498010341088863
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.09188493966592491
# Final cost : 0.07631139331504476
# Compute control for a deterministic system
# Cost in iteration 0: 0.07631139331504476
# Final cost : 0.07630671707990139
# Compute control for a deterministic system
# Cost in iteration 0: 0.07630671707990139
# Final cost : 0.07630389551707835
# Compute control for a deterministic system
# Cost in iteration 0: 0.07630389551707835
# Final cost : 0.07629926730312488
# Compute control for a deterministic system
# Cost in iteration 0: 0.07629926730312488
# Final cost : 0.0762952095457689
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.4083193975253875
# Final cost : 0.07754587315241944
# Compute control for a deterministic system
# Cost in iteration 0: 0.07754587315241944
# Final cost : 0.07749987041069088
# Compute control for a deterministic system
# Cost in iteration 0: 0.07749987041069088
# Final cost : 0.07742638410575398
# Compute control for a deterministic system
# Cost in iteration 0: 0.07742638410575398
# Final cost : 0.07739091731635177
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739091731635177
# Final cost : 0.0773585019666156
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.07956529786205639
# Final cost : 0.07835799552444385
# Compute control for a deterministic system
# Cost in iteration 0: 0.07835799552444385
# Final cost : 0.07834984988849408
# Compute control for a deterministic system
# Cost in iteration 0: 0.07834984988849408
# Final cost : 0.0783438386588371
# Compute control for a deterministic system
# Cost in iteration 0: 0.0783438386588371
# Final cost : 0.07833662549635972
# Compute control for a deterministic system
# Cost in iteration 0: 0.07833662549635972
# Final cost : 0.07832552706905421
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.08619680492978339
# Final cost : 0.079387559255964
# Compute control for a deterministic system
# Cost in iteration 0: 0.079387559255964
# Final cost : 0.07937323709078076
# Compute control for a deterministic system
# Cost in iteration 0: 0.07937323709078076
# Final cost : 0.079365412676035
# Compute control for a deterministic system
# Cost in iteration 0: 0.079365412676035
# Final cost : 0.07934765921039014
# Compute control for a deterministic system
# Cost in iteration 0: 0.07934765921039014
# Final cost : 0.079327677228919
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.11319616953742676
# Final cost : 0.0779829855499439
# Compute control for a deterministic system
# Cost in iteration 0: 0.0779829855499439
# Final cost : 0.07791349060673854
# Compute control for a deterministic system
# Cost in iteration 0: 0.07791349060673854
# Final cost : 0.07791327648723964
# Compute control for a deterministic system
# Cost in iteration 0: 0.07791327648723964
# Final cost : 0.0779132398971272
# Compute control for a deterministic system
# Cost in iteration 0: 0.0779132398971272
# Final cost : 0.0779132379064687
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.08737072321475131
# Final cost : 0.06594623155658191
# Compute control for a deterministic system
# Cost in iteration 0: 0.06594623155658191
# Final cost : 0.0658724296838168
# Compute control for a deterministic system
# Cost in iteration 0: 0.0658724296838168
# Final cost : 0.06587232409541394
# Compute control for a deterministic system
# Cost in iteration 0: 0.06587232409541394
# Final cost : 0.06587232232627949
# Compute control for a deterministic system
# Cost in iteration 0: 0.06587232232627949
# Converged in iteration 809 with cost 0.06587232227680238 because of step counter
# Final cost : 0.06587232227680238
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.056935862221796835
# Final cost : 0.0552073275549527
# Compute control for a deterministic system
# Cost in iteration 0: 0.0552073275549527
# Final cost : 0.055081746398494946
# Compute control for a deterministic system
# Cost in iteration 0: 0.055081746398494946
# Final cost : 0.05508158922829236
# Compute control for a deterministic system
# Cost in iteration 0: 0.05508158922829236
# Final cost : 0.05508158101200252
# Compute control for a deterministic system
# Cost in iteration 0: 0.05508158101200252
# Converged in iteration 867 with cost 0.055081580845216124 because of step counter
# Final cost : 0.055081580845216124
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.04772173468854005
# Final cost : 0.045578633327085165
# Compute control for a deterministic system
# Cost in iteration 0: 0.045578633327085165
# Final cost : 0.04549334516133022
# Compute control for a deterministic system
# Cost in iteration 0: 0.04549334516133022
# Final cost : 0.04549324571657669
# Compute control for a deterministic system
# Cost in iteration 0: 0.04549324571657669
# Final cost : 0.04549324449185052
# Compute control for a deterministic system
# Cost in iteration 0: 0.04549324449185052
# Converged in iteration 562 with cost 0.04549324448086024 because of step counter
# Final cost : 0.04549324448086024
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.0386552109840608
# Final cost : 0.03710243458303558
# Compute control for a deterministic system
# Cost in iteration 0: 0.03710243458303558
# Final cost : 0.0370256851590299
# Compute control for a deterministic system
# Cost in iteration 0: 0.0370256851590299
# Final cost : 0.03702559614363756
# Compute control for a deterministic system
# Cost in iteration 0: 0.03702559614363756
# Final cost : 0.03702559526127416
# Compute control for a deterministic system
# Cost in iteration 0: 0.03702559526127416
# Converged in iteration 443 with cost 0.03702559525564492 because of step counter
# Final cost : 0.03702559525564492
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.04372137639821391
# Final cost : 0.029637868716675897
# Compute control for a deterministic system
# Cost in iteration 0: 0.029637868716675897
# Final cost : 0.029590992233496746
# Compute control for a deterministic system
# Cost in iteration 0: 0.029590992233496746
# Final cost : 0.029590928997268246
# Compute control for a deterministic system
# Cost in iteration 0: 0.029590928997268246
# Final cost : 0.029590928814049934
# Compute control for a deterministic system
# Cost in iteration 0: 0.029590928814049934
# Converged in iteration 247 with cost 0.029590928813374787 because of step counter
# Final cost : 0.029590928813374787
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.02347277977667894
# Final cost : 0.023173431396595227
# Compute control for a deterministic system
# Cost in iteration 0: 0.023173431396595227
# Final cost : 0.023109821869211098
# Compute control for a deterministic system
# Cost in iteration 0: 0.023109821869211098
# Final cost : 0.023109753279965724
# Compute control for a deterministic system
# Cost in iteration 0: 0.023109753279965724
# Final cost : 0.023109752695018016
# Compute control for a deterministic system
# Cost in iteration 0: 0.023109752695018016
# Converged in iteration 281 with cost 0.02310975269390042 because of step counter
# Final cost : 0.02310975269390042
# Compute control for a deterministic system
# Cost in iteration 0: 0.018789421982108118
# Final cost : 0.01757489087352217
# Compute control for a deterministic system
# Cost in iteration 0: 0.01757489087352217
# Final cost : 0.0175160968165126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0175160968165126
# Final cost : 0.01751604021168099
# Compute control for a deterministic system
# Cost in iteration 0: 0.01751604021168099
# Final cost : 0.01751603979828063
# Compute control for a deterministic system
# Cost in iteration 0: 0.01751603979828063
# Converged in iteration 252 with cost 0.01751603979726175 because of step counter
# Final cost : 0.01751603979726175
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.012961692641720514
# Final cost : 0.012695263573984471
# Compute control for a deterministic system
# Cost in iteration 0: 0.012695263573984471
# Final cost : 0.012663148692298383
# Compute control for a deterministic system
# Cost in iteration 0: 0.012663148692298383
# Final cost : 0.012663113418271785
# Compute control for a deterministic system
# Cost in iteration 0: 0.012663113418271785
# Final cost : 0.01266311338065606
# Compute control for a deterministic system
# Cost in iteration 0: 0.01266311338065606
# Converged in iteration 60 with cost 0.012663113380591005 because of step counter
# Final cost : 0.012663113380591005
# Compute control for a deterministic system
# Cost in iteration 0: 0.013037000255250928
# Final cost : 0.00873071334876507
# Compute control for a deterministic system
# Cost in iteration 0: 0.00873071334876507
# Final cost : 0.008716639178525873
# Compute control for a deterministic system
# Cost in iteration 0: 0.008716639178525873
# Final cost : 0.008716619356816762
# Compute control for a deterministic system
# Cost in iteration 0: 0.008716619356816762
# Converged in iteration 299 with cost 0.008716619350587014 because of step counter
# Final cost : 0.008716619350587014
# Compute control for a deterministic system
# Cost in iteration 0: 0.008716619350587014
# Converged in iteration 4 with cost 0.008716619350586857 because of step counter
# Final cost : 0.008716619350586857
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.006000948513325593
# Final cost : 0.0055455277078584895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055455277078584895
# Final cost : 0.005533609499616448
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533609499616448
# Final cost : 0.00553359510437034
# Compute control for a deterministic system
# Cost in iteration 0: 0.00553359510437034
# Converged in iteration 133 with cost 0.005533595104030121 because of step counter
# Final cost : 0.005533595104030121
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533595104030121
# Converged in iteration 7 with cost 0.005533595104029293 because of step counter
# Final cost : 0.005533595104029293
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037339826905988713
# Final cost : 0.0030953503035649004
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030953503035649004
# Final cost : 0.003089743319336897
# Compute control for a deterministic system
# Cost in iteration 0: 0.003089743319336897
# Final cost : 0.003089735658755824
# Compute control for a deterministic system
# Cost in iteration 0: 0.003089735658755824
# Converged in iteration 131 with cost 0.003089735657565537 because of step counter
# Final cost : 0.003089735657565537
# Compute control for a deterministic system
# Cost in iteration 0: 0.003089735657565537
# Converged in iteration 26 with cost 0.0030897356575618658 because of step counter
# Final cost : 0.0030897356575618658
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014306496209059362
# Final cost : 0.0013677859311437138
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013677859311437138
# Final cost : 0.0013648323601498672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013648323601498672
# Final cost : 0.0013648286702057522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013648286702057522
# Converged in iteration 127 with cost 0.001364828669735732 because of step counter
# Final cost : 0.001364828669735732
# Compute control for a deterministic system
# Cost in iteration 0: 0.001364828669735732
# Converged in iteration 1 with cost 0.001364828669735732 because of step counter
# Final cost : 0.001364828669735732
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003465711107045993
# Final cost : 0.00034163973624457206
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034163973624457206
# Final cost : 0.0003407730315159435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003407730315159435
# Final cost : 0.00034077203179303124
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034077203179303124
# Converged in iteration 63 with cost 0.0003407720317513768 because of step counter
# Final cost : 0.0003407720317513768
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003407720317513768
# Converged in iteration 1 with cost 0.0003407720317513768 because of step counter
# Final cost : 0.0003407720317513768

# %%
save(results_min)
