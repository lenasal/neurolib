# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print("period = ", period)

init_min = [wc.exc[0,301], wc.inh[0,301]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# period =  18.83291666666667
# minima =  [ 1167  3050  4933  6817  8700 10583 12467 14350 16233 18117 20000 21883
#  23766 25650 27533 29416 31300 33183 35066 36950 38833 40716 42600 44483
#  46366 48250]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s2_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s2_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 0.99 + 0.02*np.random.random()
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 0.99 + 0.02*np.random.random()
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05362569514949328
# Final cost : 0.011342629183774558
# Compute control for a deterministic system
# Cost in iteration 0: 0.011342629183774558
# Converged in iteration 112 with cost 0.01096000483083978 because of step counter
# Final cost : 0.01096000483083978
# Compute control for a deterministic system
# Cost in iteration 0: 0.01096000483083978
# Converged in iteration 4 with cost 0.010960004830828792 because of step counter
# Final cost : 0.010960004830828792
# Compute control for a deterministic system
# Cost in iteration 0: 0.010960004830828792
# Converged in iteration 7 with cost 0.010960004830824429 because of step counter
# Final cost : 0.010960004830824429
# Compute control for a deterministic system
# Cost in iteration 0: 0.010960004830824429
# Converged in iteration 1 with cost 0.010960004830824429 because of step counter
# Final cost : 0.010960004830824429
# Compute control for a deterministic system
# Cost in iteration 0: 0.010960004830824429
# Converged in iteration 1 with cost 0.010960004830824429 because of step counter
# Final cost : 0.010960004830824429
# Compute control for a deterministic system
# Cost in iteration 0: 0.20845171416090186
# Final cost : 0.030134786272708124
# Compute control for a deterministic system
# Cost in iteration 0: 0.030134786272708124
# Cost in iteration 200: 0.022791880868395075
# Final cost : 0.022791880868395075
# Compute control for a deterministic system
# Cost in iteration 0: 0.022791880868395075
# Converged in iteration 13 with cost 0.02279188086433155 because of step counter
# Final cost : 0.02279188086433155
# Compute control for a deterministic system
# Cost in iteration 0: 0.02279188086433155
# Converged in iteration 1 with cost 0.02279188086433155 because of step counter
# Final cost : 0.02279188086433155
# Compute control for a deterministic system
# Cost in iteration 0: 0.02279188086433155
# Converged in iteration 1 with cost 0.02279188086433155 because of step counter
# Final cost : 0.02279188086433155
# Compute control for a deterministic system
# Cost in iteration 0: 0.02279188086433155
# Converged in iteration 1 with cost 0.02279188086433155 because of step counter
# Final cost : 0.02279188086433155
# Compute control for a deterministic system
# Cost in iteration 0: 0.44920777293251674
# Final cost : 0.06674788634983633
# Compute control for a deterministic system
# Cost in iteration 0: 0.06674788634983633
# Cost in iteration 200: 0.03475419657767963
# Final cost : 0.03475419657767963
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475419657767963
# Converged in iteration 73 with cost 0.03475418326164801 because of vanishing difference
# Final cost : 0.03475418326164801
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418326164801
# Converged in iteration 4 with cost 0.03475418326164075 because of step counter
# Final cost : 0.03475418326164075
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418326164075
# Converged in iteration 1 with cost 0.03475418326164075 because of step counter
# Final cost : 0.03475418326164075
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418326164075
# Converged in iteration 1 with cost 0.03475418326164075 because of step counter
# Final cost : 0.03475418326164075
# Compute control for a deterministic system
# Cost in iteration 0: 0.7559165359876917
# Final cost : 0.1386789379681612
# Compute control for a deterministic system
# Cost in iteration 0: 0.1386789379681612
# Cost in iteration 200: 0.04669350537188719
# Final cost : 0.04669350537188719
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669350537188719
# Converged in iteration 145 with cost 0.04669282158139454 because of step counter
# Final cost : 0.04669282158139454
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669282158139454
# Converged in iteration 1 with cost 0.04669282158139454 because of step counter
# Final cost : 0.04669282158139454
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669282158139454
# Converged in iteration 1 with cost 0.04669282158139454 because of step counter
# Final cost : 0.04669282158139454
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669282158139454
# Converged in iteration 1 with cost 0.04669282158139454 because of step counter
# Final cost : 0.04669282158139454
# Compute control for a deterministic system
# Cost in iteration 0: 1.1075250045568614
# Final cost : 0.2652252892657512
# Compute control for a deterministic system
# Cost in iteration 0: 0.2652252892657512
# Cost in iteration 200: 0.058521157741990563
# Final cost : 0.058521157741990563
# Compute control for a deterministic system
# Cost in iteration 0: 0.058521157741990563
# Converged in iteration 62 with cost 0.05851560618800115 because of vanishing difference
# Final cost : 0.05851560618800115
# Compute control for a deterministic system
# Cost in iteration 0: 0.05851560618800115
# Converged in iteration 131 with cost 0.05851558324110182 because of step counter
# Final cost : 0.05851558324110182
# Compute control for a deterministic system
# Cost in iteration 0: 0.05851558324110182
# Converged in iteration 1 with cost 0.05851558324110182 because of step counter
# Final cost : 0.05851558324110182
# Compute control for a deterministic system
# Cost in iteration 0: 0.05851558324110182
# Converged in iteration 1 with cost 0.05851558324110182 because of step counter
# Final cost : 0.05851558324110182
# Compute control for a deterministic system
# Cost in iteration 0: 1.484807511247943
# Final cost : 0.4601817177448607
# Compute control for a deterministic system
# Cost in iteration 0: 0.4601817177448607
# Cost in iteration 200: 0.07029216350602356
# Final cost : 0.07029216350602356
# Compute control for a deterministic system
# Cost in iteration 0: 0.07029216350602356
# Cost in iteration 200: 0.07026842748434993
# Final cost : 0.07026842748434993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026842748434993
# Converged in iteration 78 with cost 0.07026842742215984 because of step counter
# Final cost : 0.07026842742215984
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026842742215984
# Converged in iteration 1 with cost 0.07026842742215984 because of step counter
# Final cost : 0.07026842742215984
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026842742215984
# Converged in iteration 1 with cost 0.07026842742215984 because of step counter
# Final cost : 0.07026842742215984
# Compute control for a deterministic system
# Cost in iteration 0: 1.8795185672780235
# Final cost : 0.7368397265401923
# Compute control for a deterministic system
# Cost in iteration 0: 0.7368397265401923
# Cost in iteration 200: 0.08237588272566738
# Final cost : 0.08237588272566738
# Compute control for a deterministic system
# Cost in iteration 0: 0.08237588272566738
# Converged in iteration 148 with cost 0.0822827124186086 because of vanishing difference
# Final cost : 0.0822827124186086
# Compute control for a deterministic system
# Cost in iteration 0: 0.0822827124186086
# Converged in iteration 178 with cost 0.0822826800595534 because of step counter
# Final cost : 0.0822826800595534
# Compute control for a deterministic system
# Cost in iteration 0: 0.0822826800595534
# Converged in iteration 5 with cost 0.08228268005953064 because of step counter
# Final cost : 0.08228268005953064
# Compute control for a deterministic system
# Cost in iteration 0: 0.08228268005953064
# Converged in iteration 5 with cost 0.08228268005951303 because of step counter
# Final cost : 0.08228268005951303
# Compute control for a deterministic system
# Cost in iteration 0: 2.2609979996995078
# Final cost : 1.0818839362319606
# Compute control for a deterministic system
# Cost in iteration 0: 1.0818839362319606
# Cost in iteration 200: 0.09429824857705725
# Final cost : 0.09429824857705725
# Compute control for a deterministic system
# Cost in iteration 0: 0.09429824857705725
# Converged in iteration 95 with cost 0.09411278940425785 because of vanishing difference
# Final cost : 0.09411278940425785
# Compute control for a deterministic system
# Cost in iteration 0: 0.09411278940425785
# Cost in iteration 200: 0.09411123189352157
# Final cost : 0.09411123189352157
# Compute control for a deterministic system
# Cost in iteration 0: 0.09411123189352157
# Converged in iteration 38 with cost 0.09411123189286748 because of step counter
# Final cost : 0.09411123189286748
# Compute control for a deterministic system
# Cost in iteration 0: 0.09411123189286748
# Converged in iteration 14 with cost 0.09411123189276138 because of step counter
# Final cost : 0.09411123189276138
# Compute control for a deterministic system
# Cost in iteration 0: 2.6254925893797605
# Final cost : 1.489565324940271
# Compute control for a deterministic system
# Cost in iteration 0: 1.489565324940271
# Cost in iteration 200: 0.10641032876084075
# Final cost : 0.10641032876084075
# Compute control for a deterministic system
# Cost in iteration 0: 0.10641032876084075
# Converged in iteration 176 with cost 0.10602894080896605 because of vanishing difference
# Final cost : 0.10602894080896605
# Compute control for a deterministic system
# Cost in iteration 0: 0.10602894080896605
# Cost in iteration 200: 0.10602864903354162
# Final cost : 0.10602864903354162
# Compute control for a deterministic system
# Cost in iteration 0: 0.10602864903354162
# Converged in iteration 54 with cost 0.10602864903283746 because of step counter
# Final cost : 0.10602864903283746
# Compute control for a deterministic system
# Cost in iteration 0: 0.10602864903283746
# Converged in iteration 1 with cost 0.10602864903283746 because of step counter
# Final cost : 0.10602864903283746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9629748865519456
# Final cost : 1.9402829194389222
# Compute control for a deterministic system
# Cost in iteration 0: 1.9402829194389222
# Cost in iteration 200: 0.1187724144551878
# Final cost : 0.1187724144551878
# Compute control for a deterministic system
# Cost in iteration 0: 0.1187724144551878
# Cost in iteration 200: 0.11804252119139763
# Final cost : 0.11804252119139763
# Compute control for a deterministic system
# Cost in iteration 0: 0.11804252119139763
# Cost in iteration 200: 0.11804201385756825
# Final cost : 0.11804201385756825
# Compute control for a deterministic system
# Cost in iteration 0: 0.11804201385756825
# Converged in iteration 120 with cost 0.11804201384862119 because of step counter
# Final cost : 0.11804201384862119
# Compute control for a deterministic system
# Cost in iteration 0: 0.11804201384862119
# Converged in iteration 1 with cost 0.11804201384862119 because of step counter
# Final cost : 0.11804201384862119
# Compute control for a deterministic system
# Cost in iteration 0: 3.2656377443446325
# Final cost : 2.4062267152013344
# Compute control for a deterministic system
# Cost in iteration 0: 2.4062267152013344
# Cost in iteration 200: 0.13139257409853614
# Final cost : 0.13139257409853614
# Compute control for a deterministic system
# Cost in iteration 0: 0.13139257409853614
# Converged in iteration 198 with cost 0.1301509763681141 because of vanishing difference
# Final cost : 0.1301509763681141
# Compute control for a deterministic system
# Cost in iteration 0: 0.1301509763681141
# Cost in iteration 200: 0.1301489617412985
# Final cost : 0.1301489617412985
# Compute control for a deterministic system
# Cost in iteration 0: 0.1301489617412985
# Converged in iteration 132 with cost 0.13014896172726825 because of step counter
# Final cost : 0.13014896172726825
# Compute control for a deterministic system
# Cost in iteration 0: 0.13014896172726825
# Converged in iteration 1 with cost 0.13014896172726825 because of step counter
# Final cost : 0.13014896172726825
# Compute control for a deterministic system
# Cost in iteration 0: 3.528460693678295
# Final cost : 2.854525815953291
# Compute control for a deterministic system
# Cost in iteration 0: 2.854525815953291
# Cost in iteration 200: 0.14441671316158405
# Final cost : 0.14441671316158405
# Compute control for a deterministic system
# Cost in iteration 0: 0.14441671316158405
# Cost in iteration 200: 0.1423479669173451
# Final cost : 0.1423479669173451
# Compute control for a deterministic system
# Cost in iteration 0: 0.1423479669173451
# Cost in iteration 200: 0.14234315900167793
# Final cost : 0.14234315900167793
# Compute control for a deterministic system
# Cost in iteration 0: 0.14234315900167793
# Cost in iteration 200: 0.14234315893175015
# Converged in iteration 225 with cost 0.14234315893161426 because of step counter
# Final cost : 0.14234315893161426
# Compute control for a deterministic system
# Cost in iteration 0: 0.14234315893161426
# Converged in iteration 6 with cost 0.14234315893160018 because of step counter
# Final cost : 0.14234315893160018
# Compute control for a deterministic system
# Cost in iteration 0: 3.749620826389356
# Final cost : 3.254448969726713
# Compute control for a deterministic system
# Cost in iteration 0: 3.254448969726713
# Cost in iteration 200: 0.15762490904107912
# Final cost : 0.15762490904107912
# Compute control for a deterministic system
# Cost in iteration 0: 0.15762490904107912
# Cost in iteration 200: 0.15462740142640663
# Final cost : 0.15462740142640663
# Compute control for a deterministic system
# Cost in iteration 0: 0.15462740142640663
# Converged in iteration 7 with cost 0.15462658603549576 because of vanishing difference
# Final cost : 0.15462658603549576
# Compute control for a deterministic system
# Cost in iteration 0: 0.15462658603549576
# Cost in iteration 200: 0.15461758721289373
# Cost in iteration 400: 0.15461751887829578
# Final cost : 0.15461751887829578
# Compute control for a deterministic system
# Cost in iteration 0: 0.15461751887829578
# Cost in iteration 200: 0.1546175182989934
# Converged in iteration 376 with cost 0.15461751829022058 because of step counter
# Final cost : 0.15461751829022058
# Compute control for a deterministic system
# Cost in iteration 0: 3.9302639987817187
# Final cost : 3.586297025896526
# Compute control for a deterministic system
# Cost in iteration 0: 3.586297025896526
# Cost in iteration 200: 0.17119235672776423
# Final cost : 0.17119235672776423
# Compute control for a deterministic system
# Cost in iteration 0: 0.17119235672776423
# Cost in iteration 200: 0.16698650826354883
# Final cost : 0.16698650826354883
# Compute control for a deterministic system
# Cost in iteration 0: 0.16698650826354883
# Cost in iteration 200: 0.1669654035870927
# Final cost : 0.1669654035870927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1669654035870927
# Cost in iteration 200: 0.16696539851896883
# Cost in iteration 400: 0.16696539844213074
# Final cost : 0.16696539844213074
# Compute control for a deterministic system
# Cost in iteration 0: 0.16696539844213074
# Converged in iteration 78 with cost 0.16696539844123762 because of step counter
# Final cost : 0.16696539844123762
# Compute control for a deterministic system
# Cost in iteration 0: 4.073578979468256
# Final cost : 3.845490639503999
# Compute control for a deterministic system
# Cost in iteration 0: 3.845490639503999
# Cost in iteration 200: 0.18530132079673317
# Final cost : 0.18530132079673317
# Compute control for a deterministic system
# Cost in iteration 0: 0.18530132079673317
# Cost in iteration 200: 0.17942046584207086
# Final cost : 0.17942046584207086
# Compute control for a deterministic system
# Cost in iteration 0: 0.17942046584207086
# Cost in iteration 200: 0.1793817023033029
# Final cost : 0.1793817023033029
# Compute control for a deterministic system
# Cost in iteration 0: 0.1793817023033029
# Cost in iteration 200: 0.1793816992064344
# Cost in iteration 400: 0.17938169914287416
# Final cost : 0.17938169914287416
# Compute control for a deterministic system
# Cost in iteration 0: 0.17938169914287416
# Converged in iteration 67 with cost 0.17938169914186702 because of step counter
# Final cost : 0.17938169914186702
# Compute control for a deterministic system
# Cost in iteration 0: 4.18365225427835
# Final cost : 4.038796011100214
# Compute control for a deterministic system
# Cost in iteration 0: 4.038796011100214
# Cost in iteration 200: 0.19998214861356314
# Final cost : 0.19998214861356314
# Compute control for a deterministic system
# Cost in iteration 0: 0.19998214861356314
# Cost in iteration 200: 0.19192700797340836
# Final cost : 0.19192700797340836
# Compute control for a deterministic system
# Cost in iteration 0: 0.19192700797340836
# Cost in iteration 200: 0.1918622238051115
# Final cost : 0.1918622238051115
# Compute control for a deterministic system
# Cost in iteration 0: 0.1918622238051115
# Cost in iteration 200: 0.19186221500113096
# Cost in iteration 400: 0.1918622147657816
# Final cost : 0.1918622147657816
# Compute control for a deterministic system
# Cost in iteration 0: 0.1918622147657816
# Converged in iteration 180 with cost 0.19186221475963416 because of step counter
# Final cost : 0.19186221475963416
# Compute control for a deterministic system
# Cost in iteration 0: 4.264585437562494
# Final cost : 4.177327399210936
# Compute control for a deterministic system
# Cost in iteration 0: 4.177327399210936
# Cost in iteration 200: 0.21526081216270385
# Final cost : 0.21526081216270385
# Compute control for a deterministic system
# Cost in iteration 0: 0.21526081216270385
# Cost in iteration 200: 0.2045223604344757
# Final cost : 0.2045223604344757
# Compute control for a deterministic system
# Cost in iteration 0: 0.2045223604344757
# Converged in iteration 36 with cost 0.20446329480242248 because of vanishing difference
# Final cost : 0.20446329480242248
# Compute control for a deterministic system
# Cost in iteration 0: 0.20446329480242248
# Cost in iteration 200: 0.20440646755106948
# Cost in iteration 400: 0.20440419789894615
# Final cost : 0.20440419789894615
# Compute control for a deterministic system
# Cost in iteration 0: 0.20440419789894615
# Cost in iteration 200: 0.20440406962044289
# Cost in iteration 400: 0.2044040609250358
# Cost in iteration 600: 0.20440406033734407
# Cost in iteration 800: 0.2044040602975314
# Converged in iteration 917 with cost 0.20440406029521882 because of step counter
# Final cost : 0.20440406029521882
# Compute control for a deterministic system
# Cost in iteration 0: 4.320016195575196
# Final cost : 4.271705411534332
# Compute control for a deterministic system
# Cost in iteration 0: 4.271705411534332
# Cost in iteration 200: 0.2311215803280731
# Final cost : 0.2311215803280731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2311215803280731
# Cost in iteration 200: 0.2171787918968609
# Final cost : 0.2171787918968609
# Compute control for a deterministic system
# Cost in iteration 0: 0.2171787918968609
# Converged in iteration 91 with cost 0.2170164506510221 because of vanishing difference
# Final cost : 0.2170164506510221
# Compute control for a deterministic system
# Cost in iteration 0: 0.2170164506510221
# Cost in iteration 200: 0.21700559905599306
# Cost in iteration 400: 0.2170049415781249
# Final cost : 0.2170049415781249
# Compute control for a deterministic system
# Cost in iteration 0: 0.2170049415781249
# Cost in iteration 200: 0.21700489564270803
# Cost in iteration 400: 0.21700489158730124
# Cost in iteration 600: 0.21700489122966457
# Cost in iteration 800: 0.21700489119781896
# Converged in iteration 909 with cost 0.21700489119556718 because of step counter
# Final cost : 0.21700489119556718
# Compute control for a deterministic system
# Cost in iteration 0: 4.353399705032631
# Final cost : 4.3310679240361285
# Compute control for a deterministic system
# Cost in iteration 0: 4.3310679240361285
# Cost in iteration 200: 0.24832961977453835
# Final cost : 0.24832961977453835
# Compute control for a deterministic system
# Cost in iteration 0: 0.24832961977453835
# Cost in iteration 200: 0.23018948949508386
# Final cost : 0.23018948949508386
# Compute control for a deterministic system
# Cost in iteration 0: 0.23018948949508386
# Cost in iteration 200: 0.22993387231109544
# Final cost : 0.22993387231109544
# Compute control for a deterministic system
# Cost in iteration 0: 0.22993387231109544
# Cost in iteration 200: 0.22993327599826865
# Cost in iteration 400: 0.22993322140314926
# Final cost : 0.22993322140314926
# Compute control for a deterministic system
# Cost in iteration 0: 0.22993322140314926
# Cost in iteration 200: 0.22993321617655488
# Cost in iteration 400: 0.2299332155914283
# Cost in iteration 600: 0.22993321552547552
# Cost in iteration 800: 0.2299332155178908
# Converged in iteration 843 with cost 0.2299332155172649 because of step counter
# Final cost : 0.2299332155172649
# Compute control for a deterministic system
# Cost in iteration 0: 4.365551187284114
# Final cost : 4.358344517339255
# Compute control for a deterministic system
# Cost in iteration 0: 4.358344517339255
# Cost in iteration 200: 0.26629131694525326
# Final cost : 0.26629131694525326
# Compute control for a deterministic system
# Cost in iteration 0: 0.26629131694525326
# Cost in iteration 200: 0.24302226820253653
# Final cost : 0.24302226820253653
# Compute control for a deterministic system
# Cost in iteration 0: 0.24302226820253653
# Cost in iteration 200: 0.24265355353195486
# Final cost : 0.24265355353195486
# Compute control for a deterministic system
# Cost in iteration 0: 0.24265355353195486
# Cost in iteration 200: 0.24264983712257251
# Cost in iteration 400: 0.24264942511808335
# Final cost : 0.24264942511808335
# Compute control for a deterministic system
# Cost in iteration 0: 0.24264942511808335
# Cost in iteration 200: 0.2426493764486134
# Cost in iteration 400: 0.24264936965880435
# Cost in iteration 600: 0.24264936870947235
# Cost in iteration 800: 0.24264936857667135
# Cost in iteration 1000: 0.2426493685580948
# Final cost : 0.2426493685580948
# Compute control for a deterministic system
# Cost in iteration 0: 4.358501690754904
# Final cost : 4.357713820744478
# Compute control for a deterministic system
# Cost in iteration 0: 4.357713820744478
# Cost in iteration 200: 0.2869501780191849
# Final cost : 0.2869501780191849
# Compute control for a deterministic system
# Cost in iteration 0: 0.2869501780191849
# Cost in iteration 200: 0.25596608995401493
# Final cost : 0.25596608995401493
# Compute control for a deterministic system
# Cost in iteration 0: 0.25596608995401493
# Converged in iteration 72 with cost 0.2556941870438254 because of vanishing difference
# Final cost : 0.2556941870438254
# Compute control for a deterministic system
# Cost in iteration 0: 0.2556941870438254
# Cost in iteration 200: 0.2554479746478633
# Cost in iteration 400: 0.2554248825013427
# Final cost : 0.2554248825013427
# Compute control for a deterministic system
# Cost in iteration 0: 0.2554248825013427
# Cost in iteration 200: 0.25542201502749123
# Cost in iteration 400: 0.2554215323253781
# Cost in iteration 600: 0.255421451640525
# Cost in iteration 800: 0.25542143798958195
# Cost in iteration 1000: 0.2554214356753158
# Final cost : 0.2554214356753158
# Compute control for a deterministic system
# Cost in iteration 0: 4.332114107609619
# Final cost : 4.330369935965287
# Compute control for a deterministic system
# Cost in iteration 0: 4.330369935965287
# Cost in iteration 200: 0.22323714784097753
# Final cost : 0.22323714784097753
# Compute control for a deterministic system
# Cost in iteration 0: 0.22323714784097753
# Cost in iteration 200: 0.20993985326523232
# Final cost : 0.20993985326523232
# Compute control for a deterministic system
# Cost in iteration 0: 0.20993985326523232
# Converged in iteration 141 with cost 0.20960333507561754 because of vanishing difference
# Final cost : 0.20960333507561754
# Compute control for a deterministic system
# Cost in iteration 0: 0.20960333507561754
# Cost in iteration 200: 0.20954174537139764
# Cost in iteration 400: 0.20953293372774703
# Final cost : 0.20953293372774703
# Compute control for a deterministic system
# Cost in iteration 0: 0.20953293372774703
# Cost in iteration 200: 0.20953135731259623
# Cost in iteration 400: 0.20953134520608566
# Cost in iteration 600: 0.20953134511681015
# Converged in iteration 635 with cost 0.2095313451164432 because of step counter
# Final cost : 0.2095313451164432
# Compute control for a deterministic system
# Cost in iteration 0: 4.284922324665414
# Final cost : 4.27165546533127
# Compute control for a deterministic system
# Cost in iteration 0: 4.27165546533127
# Cost in iteration 200: 0.20842684190387073
# Final cost : 0.20842684190387073
# Compute control for a deterministic system
# Cost in iteration 0: 0.20842684190387073
# Cost in iteration 200: 0.19850988000711797
# Final cost : 0.19850988000711797
# Compute control for a deterministic system
# Cost in iteration 0: 0.19850988000711797
# Converged in iteration 90 with cost 0.19831554691726144 because of vanishing difference
# Final cost : 0.19831554691726144
# Compute control for a deterministic system
# Cost in iteration 0: 0.19831554691726144
# Cost in iteration 200: 0.19824125404042128
# Cost in iteration 400: 0.1982327667759275
# Final cost : 0.1982327667759275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1982327667759275
# Cost in iteration 200: 0.1982315766461652
# Cost in iteration 400: 0.19823157112559905
# Converged in iteration 540 with cost 0.1982315711051464 because of step counter
# Final cost : 0.1982315711051464
# Compute control for a deterministic system
# Cost in iteration 0: 4.214109832952824
# Final cost : 4.171123512219971
# Compute control for a deterministic system
# Cost in iteration 0: 4.171123512219971
# Cost in iteration 200: 0.19431163468223936
# Final cost : 0.19431163468223936
# Compute control for a deterministic system
# Cost in iteration 0: 0.19431163468223936
# Cost in iteration 200: 0.1870409514388686
# Final cost : 0.1870409514388686
# Compute control for a deterministic system
# Cost in iteration 0: 0.1870409514388686
# Converged in iteration 36 with cost 0.1869778688658073 because of vanishing difference
# Final cost : 0.1869778688658073
# Compute control for a deterministic system
# Cost in iteration 0: 0.1869778688658073
# Cost in iteration 200: 0.18689042761608604
# Cost in iteration 400: 0.18688282987174715
# Final cost : 0.18688282987174715
# Compute control for a deterministic system
# Cost in iteration 0: 0.18688282987174715
# Cost in iteration 200: 0.18688201619082984
# Cost in iteration 400: 0.18688201376703664
# Converged in iteration 470 with cost 0.18688201376229122 because of step counter
# Final cost : 0.18688201376229122
# Compute control for a deterministic system
# Cost in iteration 0: 4.115617003107827
# Final cost : 4.015522187282939
# Compute control for a deterministic system
# Cost in iteration 0: 4.015522187282939
# Cost in iteration 200: 0.18109724225546642
# Final cost : 0.18109724225546642
# Compute control for a deterministic system
# Cost in iteration 0: 0.18109724225546642
# Cost in iteration 200: 0.17558643917157912
# Final cost : 0.17558643917157912
# Compute control for a deterministic system
# Cost in iteration 0: 0.17558643917157912
# Converged in iteration 12 with cost 0.17556909568248283 because of vanishing difference
# Final cost : 0.17556909568248283
# Compute control for a deterministic system
# Cost in iteration 0: 0.17556909568248283
# Cost in iteration 200: 0.17548806853234727
# Cost in iteration 400: 0.17548284027924954
# Final cost : 0.17548284027924954
# Compute control for a deterministic system
# Cost in iteration 0: 0.17548284027924954
# Cost in iteration 200: 0.17548243263235958
# Cost in iteration 400: 0.1754824320108385
# Converged in iteration 411 with cost 0.17548243201056715 because of step counter
# Final cost : 0.17548243201056715
# Compute control for a deterministic system
# Cost in iteration 0: 3.9844728139638135
# Final cost : 3.788894478974915
# Compute control for a deterministic system
# Cost in iteration 0: 3.788894478974915
# Cost in iteration 200: 0.1680112724502009
# Final cost : 0.1680112724502009
# Compute control for a deterministic system
# Cost in iteration 0: 0.1680112724502009
# Cost in iteration 200: 0.16408482503774027
# Final cost : 0.16408482503774027
# Compute control for a deterministic system
# Cost in iteration 0: 0.16408482503774027
# Converged in iteration 30 with cost 0.16406307438344725 because of vanishing difference
# Final cost : 0.16406307438344725
# Compute control for a deterministic system
# Cost in iteration 0: 0.16406307438344725
# Cost in iteration 200: 0.164034034298229
# Cost in iteration 400: 0.16403263361875609
# Final cost : 0.16403263361875609
# Compute control for a deterministic system
# Cost in iteration 0: 0.16403263361875609
# Cost in iteration 200: 0.16403255657438967
# Converged in iteration 319 with cost 0.1640325565442167 because of step counter
# Final cost : 0.1640325565442167
# Compute control for a deterministic system
# Cost in iteration 0: 3.815467012222417
# Final cost : 3.4776649917125333
# Compute control for a deterministic system
# Cost in iteration 0: 3.4776649917125333
# Cost in iteration 200: 0.15529855102524995
# Final cost : 0.15529855102524995
# Compute control for a deterministic system
# Cost in iteration 0: 0.15529855102524995
# Converged in iteration 159 with cost 0.1525918529695415 because of vanishing difference
# Final cost : 0.1525918529695415
# Compute control for a deterministic system
# Cost in iteration 0: 0.1525918529695415
# Cost in iteration 200: 0.15253281213646672
# Final cost : 0.15253281213646672
# Compute control for a deterministic system
# Cost in iteration 0: 0.15253281213646672
# Cost in iteration 200: 0.15253180255734128
# Cost in iteration 400: 0.15253176770282986
# Final cost : 0.15253176770282986
# Compute control for a deterministic system
# Cost in iteration 0: 0.15253176770282986
# Converged in iteration 162 with cost 0.15253176645720884 because of step counter
# Final cost : 0.15253176645720884
# Compute control for a deterministic system
# Cost in iteration 0: 3.6042315945477483
# Final cost : 3.080529031634114
# Compute control for a deterministic system
# Cost in iteration 0: 3.080529031634114
# Cost in iteration 200: 0.14283432363566312
# Final cost : 0.14283432363566312
# Compute control for a deterministic system
# Cost in iteration 0: 0.14283432363566312
# Cost in iteration 200: 0.1409866415865606
# Final cost : 0.1409866415865606
# Compute control for a deterministic system
# Cost in iteration 0: 0.1409866415865606
# Cost in iteration 200: 0.14097928635309007
# Final cost : 0.14097928635309007
# Compute control for a deterministic system
# Cost in iteration 0: 0.14097928635309007
# Cost in iteration 200: 0.14097918988061922
# Cost in iteration 400: 0.14097918785283542
# Final cost : 0.14097918785283542
# Compute control for a deterministic system
# Cost in iteration 0: 0.14097918785283542
# Converged in iteration 93 with cost 0.14097918781032043 because of step counter
# Final cost : 0.14097918781032043
# Compute control for a deterministic system
# Cost in iteration 0: 3.3485022125185386
# Final cost : 2.6160775603783466
# Compute control for a deterministic system
# Cost in iteration 0: 2.6160775603783466
# Cost in iteration 200: 0.13055782114768005
# Final cost : 0.13055782114768005
# Compute control for a deterministic system
# Cost in iteration 0: 0.13055782114768005
# Converged in iteration 160 with cost 0.12938184079373455 because of vanishing difference
# Final cost : 0.12938184079373455
# Compute control for a deterministic system
# Cost in iteration 0: 0.12938184079373455
# Cost in iteration 200: 0.12937255787947335
# Final cost : 0.12937255787947335
# Compute control for a deterministic system
# Cost in iteration 0: 0.12937255787947335
# Cost in iteration 200: 0.12937250247840745
# Cost in iteration 400: 0.12937250185994156
# Final cost : 0.12937250185994156
# Compute control for a deterministic system
# Cost in iteration 0: 0.12937250185994156
# Converged in iteration 54 with cost 0.12937250185305796 because of step counter
# Final cost : 0.12937250185305796
# Compute control for a deterministic system
# Cost in iteration 0: 3.048804876671416
# Final cost : 2.119152541844332
# Compute control for a deterministic system
# Cost in iteration 0: 2.119152541844332
# Cost in iteration 200: 0.11841463036486766
# Final cost : 0.11841463036486766
# Compute control for a deterministic system
# Cost in iteration 0: 0.11841463036486766
# Converged in iteration 140 with cost 0.11771335475853975 because of vanishing difference
# Final cost : 0.11771335475853975
# Compute control for a deterministic system
# Cost in iteration 0: 0.11771335475853975
# Cost in iteration 200: 0.11770730151368458
# Final cost : 0.11770730151368458
# Compute control for a deterministic system
# Cost in iteration 0: 0.11770730151368458
# Cost in iteration 200: 0.11770728882578804
# Cost in iteration 400: 0.11770728876113455
# Final cost : 0.11770728876113455
# Compute control for a deterministic system
# Cost in iteration 0: 0.11770728876113455
# Converged in iteration 32 with cost 0.11770728876077985 because of step counter
# Final cost : 0.11770728876077985
# Compute control for a deterministic system
# Cost in iteration 0: 2.7002715407926474
# Final cost : 1.6182697771302497
# Compute control for a deterministic system
# Cost in iteration 0: 1.6182697771302497
# Cost in iteration 200: 0.1061244554113479
# Final cost : 0.1061244554113479
# Compute control for a deterministic system
# Cost in iteration 0: 0.1061244554113479
# Converged in iteration 96 with cost 0.10573428596830677 because of vanishing difference
# Final cost : 0.10573428596830677
# Compute control for a deterministic system
# Cost in iteration 0: 0.10573428596830677
# Cost in iteration 200: 0.10572803371697188
# Final cost : 0.10572803371697188
# Compute control for a deterministic system
# Cost in iteration 0: 0.10572803371697188
# Cost in iteration 200: 0.10572802788418932
# Converged in iteration 342 with cost 0.10572802787261348 because of step counter
# Final cost : 0.10572802787261348
# Compute control for a deterministic system
# Cost in iteration 0: 0.10572802787261348
# Converged in iteration 8 with cost 0.10572802787252536 because of step counter
# Final cost : 0.10572802787252536
# Compute control for a deterministic system
# Cost in iteration 0: 2.323455184303653
# Final cost : 1.1682794615278842
# Compute control for a deterministic system
# Cost in iteration 0: 1.1682794615278842
# Cost in iteration 200: 0.0941172431575404
# Final cost : 0.0941172431575404
# Compute control for a deterministic system
# Cost in iteration 0: 0.0941172431575404
# Cost in iteration 200: 0.0939346232540143
# Final cost : 0.0939346232540143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0939346232540143
# Cost in iteration 200: 0.09393462175084062
# Final cost : 0.09393462175084062
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393462175084062
# Converged in iteration 13 with cost 0.09393462175059866 because of step counter
# Final cost : 0.09393462175059866
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393462175059866
# Converged in iteration 1 with cost 0.09393462175059866 because of step counter
# Final cost : 0.09393462175059866
# Compute control for a deterministic system
# Cost in iteration 0: 1.9240609579006853
# Final cost : 0.7851883560749012
# Compute control for a deterministic system
# Cost in iteration 0: 0.7851883560749012
# Cost in iteration 200: 0.08216844493837724
# Final cost : 0.08216844493837724
# Compute control for a deterministic system
# Cost in iteration 0: 0.08216844493837724
# Cost in iteration 200: 0.08208930154073027
# Final cost : 0.08208930154073027
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208930154073027
# Converged in iteration 59 with cost 0.08208930153670946 because of vanishing difference
# Final cost : 0.08208930153670946
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208930153670946
# Converged in iteration 6 with cost 0.08208930153665972 because of step counter
# Final cost : 0.08208930153665972
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208930153665972
# Converged in iteration 16 with cost 0.08208930153650026 because of step counter
# Final cost : 0.08208930153650026
# Compute control for a deterministic system
# Cost in iteration 0: 1.5192718620109835
# Final cost : 0.4856228302628498
# Compute control for a deterministic system
# Cost in iteration 0: 0.4856228302628498
# Cost in iteration 200: 0.07023439902258598
# Final cost : 0.07023439902258598
# Compute control for a deterministic system
# Cost in iteration 0: 0.07023439902258598
# Converged in iteration 33 with cost 0.07021117660035957 because of vanishing difference
# Final cost : 0.07021117660035957
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021117660035957
# Cost in iteration 200: 0.07021039628503627
# Final cost : 0.07021039628503627
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021039628503627
# Converged in iteration 79 with cost 0.07021039628132311 because of step counter
# Final cost : 0.07021039628132311
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021039628132311
# Converged in iteration 1 with cost 0.07021039628132311 because of step counter
# Final cost : 0.07021039628132311
# Compute control for a deterministic system
# Cost in iteration 0: 1.1271216519752087
# Final cost : 0.2733173748144105
# Compute control for a deterministic system
# Cost in iteration 0: 0.2733173748144105
# Cost in iteration 200: 0.058323527166715725
# Final cost : 0.058323527166715725
# Compute control for a deterministic system
# Cost in iteration 0: 0.058323527166715725
# Converged in iteration 27 with cost 0.058318672592329306 because of vanishing difference
# Final cost : 0.058318672592329306
# Compute control for a deterministic system
# Cost in iteration 0: 0.058318672592329306
# Converged in iteration 196 with cost 0.05831852914892086 because of step counter
# Final cost : 0.05831852914892086
# Compute control for a deterministic system
# Cost in iteration 0: 0.05831852914892086
# Converged in iteration 7 with cost 0.058318529148907984 because of step counter
# Final cost : 0.058318529148907984
# Compute control for a deterministic system
# Cost in iteration 0: 0.058318529148907984
# Converged in iteration 2 with cost 0.058318529148906804 because of step counter
# Final cost : 0.058318529148906804
# Compute control for a deterministic system
# Cost in iteration 0: 0.7657623053231586
# Final cost : 0.13963798960781926
# Compute control for a deterministic system
# Cost in iteration 0: 0.13963798960781926
# Cost in iteration 200: 0.04643250688315231
# Final cost : 0.04643250688315231
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643250688315231
# Converged in iteration 11 with cost 0.04643202672699767 because of vanishing difference
# Final cost : 0.04643202672699767
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643202672699767
# Converged in iteration 142 with cost 0.04643195693309835 because of step counter
# Final cost : 0.04643195693309835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643195693309835
# Converged in iteration 1 with cost 0.04643195693309835 because of step counter
# Final cost : 0.04643195693309835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643195693309835
# Converged in iteration 1 with cost 0.04643195693309835 because of step counter
# Final cost : 0.04643195693309835
# Compute control for a deterministic system
# Cost in iteration 0: 0.45386413331666164
# Final cost : 0.06636456381033219
# Compute control for a deterministic system
# Cost in iteration 0: 0.06636456381033219
# Cost in iteration 200: 0.03456733199219614
# Final cost : 0.03456733199219614
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456733199219614
# Converged in iteration 48 with cost 0.0345673171301574 because of step counter
# Final cost : 0.0345673171301574
# Compute control for a deterministic system
# Cost in iteration 0: 0.0345673171301574
# Converged in iteration 1 with cost 0.0345673171301574 because of step counter
# Final cost : 0.0345673171301574
# Compute control for a deterministic system
# Cost in iteration 0: 0.0345673171301574
# Converged in iteration 1 with cost 0.0345673171301574 because of step counter
# Final cost : 0.0345673171301574
# Compute control for a deterministic system
# Cost in iteration 0: 0.0345673171301574
# Converged in iteration 5 with cost 0.034567317130143826 because of step counter
# Final cost : 0.034567317130143826
# Compute control for a deterministic system
# Cost in iteration 0: 0.2106044341345741
# Final cost : 0.029987530259729327
# Compute control for a deterministic system
# Cost in iteration 0: 0.029987530259729327
# Cost in iteration 200: 0.022746763553405734
# Final cost : 0.022746763553405734
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763553405734
# Converged in iteration 14 with cost 0.02274676354965011 because of step counter
# Final cost : 0.02274676354965011
# Compute control for a deterministic system
# Cost in iteration 0: 0.02274676354965011
# Converged in iteration 3 with cost 0.022746763549643754 because of step counter
# Final cost : 0.022746763549643754
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763549643754
# Converged in iteration 1 with cost 0.022746763549643754 because of step counter
# Final cost : 0.022746763549643754
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763549643754
# Converged in iteration 1 with cost 0.022746763549643754 because of step counter
# Final cost : 0.022746763549643754
# Compute control for a deterministic system
# Cost in iteration 0: 0.054464761854799544
# Final cost : 0.01140076054442837
# Compute control for a deterministic system
# Cost in iteration 0: 0.01140076054442837
# Converged in iteration 118 with cost 0.011014199736921167 because of step counter
# Final cost : 0.011014199736921167
# Compute control for a deterministic system
# Cost in iteration 0: 0.011014199736921167
# Converged in iteration 1 with cost 0.011014199736921167 because of step counter
# Final cost : 0.011014199736921167
# Compute control for a deterministic system
# Cost in iteration 0: 0.011014199736921167
# Converged in iteration 1 with cost 0.011014199736921167 because of step counter
# Final cost : 0.011014199736921167
# Compute control for a deterministic system
# Cost in iteration 0: 0.011014199736921167
# Converged in iteration 6 with cost 0.011014199736912367 because of step counter
# Final cost : 0.011014199736912367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011014199736912367
# Converged in iteration 1 with cost 0.011014199736912367 because of step counter
# Final cost : 0.011014199736912367
# Compute control for a deterministic system
# Cost in iteration 0: 2.6732693669051974e-06
# Converged in iteration 1 with cost 2.6732693669051974e-06 because of step counter
# Final cost : 2.6732693669051974e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.6732693669051974e-06
# Converged in iteration 1 with cost 2.6732693669051974e-06 because of step counter
# Final cost : 2.6732693669051974e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.07622340161645919
# Cost in iteration 200: 0.02279188086602174
# Final cost : 0.02279188086602174
# Compute control for a deterministic system
# Cost in iteration 0: 0.02279188086602174
# Converged in iteration 7 with cost 0.022791880864334323 because of step counter
# Final cost : 0.022791880864334323
# Compute control for a deterministic system
# Cost in iteration 0: 0.022791880864334323
# Converged in iteration 2 with cost 0.022791880864332415 because of step counter
# Final cost : 0.022791880864332415
# Compute control for a deterministic system
# Cost in iteration 0: 0.022791880864332415
# Converged in iteration 1 with cost 0.022791880864332415 because of step counter
# Final cost : 0.022791880864332415
# Compute control for a deterministic system
# Cost in iteration 0: 0.022791880864332415
# Converged in iteration 1 with cost 0.022791880864332415 because of step counter
# Final cost : 0.022791880864332415
# Compute control for a deterministic system
# Cost in iteration 0: 0.08964301635038154
# Cost in iteration 200: 0.0347541840860122
# Final cost : 0.0347541840860122
# Compute control for a deterministic system
# Cost in iteration 0: 0.0347541840860122
# Converged in iteration 56 with cost 0.03475418214911199 because of step counter
# Final cost : 0.03475418214911199
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418214911199
# Converged in iteration 3 with cost 0.03475418214910705 because of step counter
# Final cost : 0.03475418214910705
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418214910705
# Converged in iteration 1 with cost 0.03475418214910705 because of step counter
# Final cost : 0.03475418214910705
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475418214910705
# Converged in iteration 1 with cost 0.03475418214910705 because of step counter
# Final cost : 0.03475418214910705
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.10126252273709589
# Cost in iteration 200: 0.04669287548730477
# Final cost : 0.04669287548730477
# Compute control for a deterministic system
# Cost in iteration 0: 0.04669287548730477
# Converged in iteration 125 with cost 0.046692819670158474 because of step counter
# Final cost : 0.046692819670158474
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692819670158474
# Converged in iteration 1 with cost 0.046692819670158474 because of step counter
# Final cost : 0.046692819670158474
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692819670158474
# Converged in iteration 1 with cost 0.046692819670158474 because of step counter
# Final cost : 0.046692819670158474
# Compute control for a deterministic system
# Cost in iteration 0: 0.046692819670158474
# Converged in iteration 1 with cost 0.046692819670158474 because of step counter
# Final cost : 0.046692819670158474
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.11173908225758838
# Cost in iteration 200: 0.058515962197836856
# Final cost : 0.058515962197836856
# Compute control for a deterministic system
# Cost in iteration 0: 0.058515962197836856
# Cost in iteration 200: 0.0585155767803134
# Final cost : 0.0585155767803134
# Compute control for a deterministic system
# Cost in iteration 0: 0.0585155767803134
# Converged in iteration 12 with cost 0.05851557678025618 because of step counter
# Final cost : 0.05851557678025618
# Compute control for a deterministic system
# Cost in iteration 0: 0.05851557678025618
# Converged in iteration 1 with cost 0.05851557678025618 because of step counter
# Final cost : 0.05851557678025618
# Compute control for a deterministic system
# Cost in iteration 0: 0.05851557678025618
# Converged in iteration 7 with cost 0.058515576780233544 because of step counter
# Final cost : 0.058515576780233544
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.12058112324002904
# Cost in iteration 200: 0.07026981446238272
# Final cost : 0.07026981446238272
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026981446238272
# Cost in iteration 200: 0.070268422453431
# Final cost : 0.070268422453431
# Compute control for a deterministic system
# Cost in iteration 0: 0.070268422453431
# Converged in iteration 57 with cost 0.07026842244960232 because of step counter
# Final cost : 0.07026842244960232
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026842244960232
# Converged in iteration 1 with cost 0.07026842244960232 because of step counter
# Final cost : 0.07026842244960232
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026842244960232
# Converged in iteration 1 with cost 0.07026842244960232 because of step counter
# Final cost : 0.07026842244960232
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.1273468213294563
# Cost in iteration 200: 0.08228647268162229
# Final cost : 0.08228647268162229
# Compute control for a deterministic system
# Cost in iteration 0: 0.08228647268162229
# Cost in iteration 200: 0.08228267641989699
# Final cost : 0.08228267641989699
# Compute control for a deterministic system
# Cost in iteration 0: 0.08228267641989699
# Converged in iteration 90 with cost 0.08228267633940695 because of step counter
# Final cost : 0.08228267633940695
# Compute control for a deterministic system
# Cost in iteration 0: 0.08228267633940695
# ...
# Cost in iteration 0: 0.20953170833765708
# Cost in iteration 200: 0.2095313479934449
# Cost in iteration 400: 0.2095313449409079
# Converged in iteration 539 with cost 0.20953134491815534 because of step counter
# Final cost : 0.20953134491815534
# Compute control for a deterministic system
# Cost in iteration 0: 3.3235646692646412
# Cost in iteration 200: 0.24409473040380716
# Final cost : 0.24409473040380716
# Compute control for a deterministic system
# Cost in iteration 0: 0.24409473040380716
# Cost in iteration 200: 0.19837187024080544
# Final cost : 0.19837187024080544
# Compute control for a deterministic system
# Cost in iteration 0: 0.19837187024080544
# Cost in iteration 200: 0.19823407062476567
# Final cost : 0.19823407062476567
# Compute control for a deterministic system
# Cost in iteration 0: 0.19823407062476567
# Cost in iteration 200: 0.19823180723312667
# Cost in iteration 400: 0.19823155579255292
# Final cost : 0.19823155579255292
# Compute control for a deterministic system
# Cost in iteration 0: 0.19823155579255292
# Cost in iteration 200: 0.19823151996677457
# Cost in iteration 400: 0.19823151982290702
# Converged in iteration 430 with cost 0.19823151982265172 because of vanishing difference
# Final cost : 0.19823151982265172
# Compute control for a deterministic system
# Cost in iteration 0: 1.8144593339176582
# Cost in iteration 200: 0.19660612538561864
# Final cost : 0.19660612538561864
# Compute control for a deterministic system
# Cost in iteration 0: 0.19660612538561864
# Cost in iteration 200: 0.1868897317963739
# Final cost : 0.1868897317963739
# Compute control for a deterministic system
# Cost in iteration 0: 0.1868897317963739
# Cost in iteration 200: 0.18688208779994586
# Final cost : 0.18688208779994586
# Compute control for a deterministic system
# Cost in iteration 0: 0.18688208779994586
# Cost in iteration 200: 0.18688197750436805
# Cost in iteration 400: 0.18688196795710665
# Final cost : 0.18688196795710665
# Compute control for a deterministic system
# Cost in iteration 0: 0.18688196795710665
# Cost in iteration 200: 0.18688196690902065
# Converged in iteration 252 with cost 0.18688196690725042 because of step counter
# Final cost : 0.18688196690725042
# Compute control for a deterministic system
# Cost in iteration 0: 1.4481275026266396
# Cost in iteration 200: 0.1812552338943739
# Final cost : 0.1812552338943739
# Compute control for a deterministic system
# Cost in iteration 0: 0.1812552338943739
# Cost in iteration 200: 0.17548361495642018
# Final cost : 0.17548361495642018
# Compute control for a deterministic system
# Cost in iteration 0: 0.17548361495642018
# Cost in iteration 200: 0.17548239750480674
# Final cost : 0.17548239750480674
# Compute control for a deterministic system
# Cost in iteration 0: 0.17548239750480674
# Cost in iteration 200: 0.17548237988776938
# Cost in iteration 400: 0.1754823786783063
# Final cost : 0.1754823786783063
# Compute control for a deterministic system
# Cost in iteration 0: 0.1754823786783063
# Converged in iteration 161 with cost 0.17548237858115068 because of step counter
# Final cost : 0.17548237858115068
# Compute control for a deterministic system
# Cost in iteration 0: 2.6583077559060753
# Cost in iteration 200: 0.18385000294009157
# Final cost : 0.18385000294009157
# Compute control for a deterministic system
# Cost in iteration 0: 0.18385000294009157
# Cost in iteration 200: 0.16404573668542488
# Final cost : 0.16404573668542488
# Compute control for a deterministic system
# Cost in iteration 0: 0.16404573668542488
# Cost in iteration 200: 0.16403262161081303
# Final cost : 0.16403262161081303
# Compute control for a deterministic system
# Cost in iteration 0: 0.16403262161081303
# Cost in iteration 200: 0.16403249336248044
# Cost in iteration 400: 0.16403248707032023
# Final cost : 0.16403248707032023
# Compute control for a deterministic system
# Cost in iteration 0: 0.16403248707032023
# Converged in iteration 180 with cost 0.16403248672067883 because of step counter
# Final cost : 0.16403248672067883
# Compute control for a deterministic system
# Cost in iteration 0: 3.444577246779657
# Cost in iteration 200: 0.19247011859883667
# Final cost : 0.19247011859883667
# Compute control for a deterministic system
# Cost in iteration 0: 0.19247011859883667
# Cost in iteration 200: 0.1525568286798461
# Final cost : 0.1525568286798461
# Compute control for a deterministic system
# Cost in iteration 0: 0.1525568286798461
# Cost in iteration 200: 0.15253198057550518
# Final cost : 0.15253198057550518
# Compute control for a deterministic system
# Cost in iteration 0: 0.15253198057550518
# Cost in iteration 200: 0.15253181175441602
# Cost in iteration 400: 0.15253180615092282
# Final cost : 0.15253180615092282
# Compute control for a deterministic system
# Cost in iteration 0: 0.15253180615092282
# Converged in iteration 127 with cost 0.15253180594965055 because of step counter
# Final cost : 0.15253180594965055
# Compute control for a deterministic system
# Cost in iteration 0: 3.039344883221685
# Cost in iteration 200: 0.16548248637061125
# Final cost : 0.16548248637061125
# Compute control for a deterministic system
# Cost in iteration 0: 0.16548248637061125
# Cost in iteration 200: 0.14098547218348143
# Final cost : 0.14098547218348143
# Compute control for a deterministic system
# Cost in iteration 0: 0.14098547218348143
# Cost in iteration 200: 0.14097922410924998
# Final cost : 0.14097922410924998
# Compute control for a deterministic system
# Cost in iteration 0: 0.14097922410924998
# Cost in iteration 200: 0.1409791965025263
# Cost in iteration 400: 0.14097919594703096
# Final cost : 0.14097919594703096
# Compute control for a deterministic system
# Cost in iteration 0: 0.14097919594703096
# Converged in iteration 71 with cost 0.1409791959352494 because of step counter
# Final cost : 0.1409791959352494
# Compute control for a deterministic system
# Cost in iteration 0: 1.6402697202573657
# Cost in iteration 200: 0.1341348523743377
# Final cost : 0.1341348523743377
# Compute control for a deterministic system
# Cost in iteration 0: 0.1341348523743377
# Cost in iteration 200: 0.12937274999405254
# Final cost : 0.12937274999405254
# Compute control for a deterministic system
# Cost in iteration 0: 0.12937274999405254
# Cost in iteration 200: 0.1293724963096116
# Final cost : 0.1293724963096116
# Compute control for a deterministic system
# Cost in iteration 0: 0.1293724963096116
# Cost in iteration 200: 0.12937249536007675
# Converged in iteration 341 with cost 0.1293724953503624 because of step counter
# Final cost : 0.1293724953503624
# Compute control for a deterministic system
# Cost in iteration 0: 0.1293724953503624
# Converged in iteration 8 with cost 0.12937249534997408 because of step counter
# Final cost : 0.12937249534997408
# Compute control for a deterministic system
# Cost in iteration 0: 3.7666128848071514
# Cost in iteration 200: 0.16132081942960283
# Final cost : 0.16132081942960283
# Compute control for a deterministic system
# Cost in iteration 0: 0.16132081942960283
# Cost in iteration 200: 0.11771177506742467
# Final cost : 0.11771177506742467
# Compute control for a deterministic system
# Cost in iteration 0: 0.11771177506742467
# Cost in iteration 200: 0.1177072872735523
# Final cost : 0.1177072872735523
# Compute control for a deterministic system
# Cost in iteration 0: 0.1177072872735523
# Cost in iteration 200: 0.11770728146413567
# Converged in iteration 396 with cost 0.11770728143491513 because of step counter
# Final cost : 0.11770728143491513
# Compute control for a deterministic system
# Cost in iteration 0: 0.11770728143491513
# Converged in iteration 1 with cost 0.11770728143491513 because of step counter
# Final cost : 0.11770728143491513
# Compute control for a deterministic system
# Cost in iteration 0: 0.7724077630526007
# Cost in iteration 200: 0.10657726446405266
# Final cost : 0.10657726446405266
# Compute control for a deterministic system
# Cost in iteration 0: 0.10657726446405266
# Converged in iteration 89 with cost 0.10573020687154012 because of vanishing difference
# Final cost : 0.10573020687154012
# Compute control for a deterministic system
# Cost in iteration 0: 0.10573020687154012
# Cost in iteration 200: 0.10572802820236135
# Final cost : 0.10572802820236135
# Compute control for a deterministic system
# Cost in iteration 0: 0.10572802820236135
# Converged in iteration 186 with cost 0.10572802803529506 because of step counter
# Final cost : 0.10572802803529506
# Compute control for a deterministic system
# Cost in iteration 0: 0.10572802803529506
# Converged in iteration 1 with cost 0.10572802803529506 because of step counter
# Final cost : 0.10572802803529506
# Compute control for a deterministic system
# Cost in iteration 0: 3.388370756120374
# Cost in iteration 200: 0.11802527356227488
# Final cost : 0.11802527356227488
# Compute control for a deterministic system
# Cost in iteration 0: 0.11802527356227488
# Cost in iteration 200: 0.09393465668852263
# Final cost : 0.09393465668852263
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393465668852263
# Cost in iteration 200: 0.09393461908398287
# Final cost : 0.09393461908398287
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393461908398287
# Converged in iteration 87 with cost 0.09393461907797693 because of step counter
# Final cost : 0.09393461907797693
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393461907797693
# Converged in iteration 5 with cost 0.09393461907770317 because of step counter
# Final cost : 0.09393461907770317
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 1.5104335007057563
# Cost in iteration 200: 0.0837982273546857
# Final cost : 0.0837982273546857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837982273546857
# Converged in iteration 91 with cost 0.08208942791672377 because of vanishing difference
# Final cost : 0.08208942791672377
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208942791672377
# Cost in iteration 200: 0.08208930311347432
# Final cost : 0.08208930311347432
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208930311347432
# Converged in iteration 41 with cost 0.08208930311242954 because of step counter
# Final cost : 0.08208930311242954
# Compute control for a deterministic system
# Cost in iteration 0: 0.08208930311242954
# Converged in iteration 13 with cost 0.08208930311224324 because of step counter
# Final cost : 0.08208930311224324
# Compute control for a deterministic system
# Cost in iteration 0: 2.5508295645119343
# Cost in iteration 200: 0.07608189300883232
# Final cost : 0.07608189300883232
# Compute control for a deterministic system
# Cost in iteration 0: 0.07608189300883232
# Converged in iteration 87 with cost 0.07021058721069155 because of vanishing difference
# Final cost : 0.07021058721069155
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021058721069155
# Cost in iteration 200: 0.07021039083714974
# Final cost : 0.07021039083714974
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021039083714974
# Converged in iteration 25 with cost 0.07021039083692436 because of step counter
# Final cost : 0.07021039083692436
# Compute control for a deterministic system
# Cost in iteration 0: 0.07021039083692436
# Converged in iteration 3 with cost 0.07021039083692146 because of step counter
# Final cost : 0.07021039083692146
# Compute control for a deterministic system
# Cost in iteration 0: 0.8786541579410176
# Cost in iteration 200: 0.05847154670933529
# Final cost : 0.05847154670933529
# Compute control for a deterministic system
# Cost in iteration 0: 0.05847154670933529
# Converged in iteration 31 with cost 0.05831918232192557 because of vanishing difference
# Final cost : 0.05831918232192557
# Compute control for a deterministic system
# Cost in iteration 0: 0.05831918232192557
# Converged in iteration 178 with cost 0.05831852874123707 because of step counter
# Final cost : 0.05831852874123707
# Compute control for a deterministic system
# Cost in iteration 0: 0.05831852874123707
# Converged in iteration 2 with cost 0.05831852874123571 because of step counter
# Final cost : 0.05831852874123571
# Compute control for a deterministic system
# Cost in iteration 0: 0.05831852874123571
# Converged in iteration 1 with cost 0.05831852874123571 because of step counter
# Final cost : 0.05831852874123571
# Compute control for a deterministic system
# Cost in iteration 0: 0.14597014686473797
# Cost in iteration 200: 0.04643313662315703
# Final cost : 0.04643313662315703
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643313662315703
# Converged in iteration 77 with cost 0.046431950886808286 because of step counter
# Final cost : 0.046431950886808286
# Compute control for a deterministic system
# Cost in iteration 0: 0.046431950886808286
# Converged in iteration 3 with cost 0.04643195088680508 because of step counter
# Final cost : 0.04643195088680508
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643195088680508
# Converged in iteration 2 with cost 0.04643195088680451 because of step counter
# Final cost : 0.04643195088680451
# Compute control for a deterministic system
# Cost in iteration 0: 0.04643195088680451
# Converged in iteration 1 with cost 0.04643195088680451 because of step counter
# Final cost : 0.04643195088680451
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 4.053251809488118
# Cost in iteration 200: 0.0797471114496458
# Final cost : 0.0797471114496458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0797471114496458
# Converged in iteration 77 with cost 0.03456742819633199 because of vanishing difference
# Final cost : 0.03456742819633199
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456742819633199
# Converged in iteration 99 with cost 0.034567321270259875 because of step counter
# Final cost : 0.034567321270259875
# Compute control for a deterministic system
# Cost in iteration 0: 0.034567321270259875
# Converged in iteration 1 with cost 0.034567321270259875 because of step counter
# Final cost : 0.034567321270259875
# Compute control for a deterministic system
# Cost in iteration 0: 0.034567321270259875
# Converged in iteration 1 with cost 0.034567321270259875 because of step counter
# Final cost : 0.034567321270259875
# Compute control for a deterministic system
# Cost in iteration 0: 0.3405214638900338
# Cost in iteration 200: 0.02274676588339105
# Final cost : 0.02274676588339105
# Compute control for a deterministic system
# Cost in iteration 0: 0.02274676588339105
# Converged in iteration 22 with cost 0.022746763549646075 because of step counter
# Final cost : 0.022746763549646075
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763549646075
# Converged in iteration 1 with cost 0.022746763549646075 because of step counter
# Final cost : 0.022746763549646075
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763549646075
# Converged in iteration 1 with cost 0.022746763549646075 because of step counter
# Final cost : 0.022746763549646075
# Compute control for a deterministic system
# Cost in iteration 0: 0.022746763549646075
# Converged in iteration 1 with cost 0.022746763549646075 because of step counter
# Final cost : 0.022746763549646075
# Compute control for a deterministic system
# Cost in iteration 0: 4.140059516156505
# Cost in iteration 200: 0.06724686219664847
# Final cost : 0.06724686219664847
# Compute control for a deterministic system
# Cost in iteration 0: 0.06724686219664847
# Converged in iteration 56 with cost 0.011014202725202246 because of step counter
# Final cost : 0.011014202725202246
# Compute control for a deterministic system
# Cost in iteration 0: 0.011014202725202246
# Converged in iteration 2 with cost 0.01101420272520168 because of step counter
# Final cost : 0.01101420272520168
# Compute control for a deterministic system
# Cost in iteration 0: 0.01101420272520168
# Converged in iteration 1 with cost 0.01101420272520168 because of step counter
# Final cost : 0.01101420272520168
# Compute control for a deterministic system
# Cost in iteration 0: 0.01101420272520168
# Converged in iteration 1 with cost 0.01101420272520168 because of step counter
# Final cost : 0.01101420272520168

# %%
save(results_min)
