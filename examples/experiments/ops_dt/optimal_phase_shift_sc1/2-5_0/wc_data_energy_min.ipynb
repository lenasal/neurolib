# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,301], wc.inh[0,301]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# minima =  [ 1167  3050  4933  6817  8700 10583 12467 14350 16233 18117 20000 21883
#  23766 25650 27533 29416 31300 33183 35066 36950 38833]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s2_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s2_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05362569514949328
# Final cost : 0.0014691296961812231
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014691296961812231
# Final cost : 7.300806181965733e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.300806181965733e-05
# Final cost : 7.16717456769602e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.16717456769602e-05
# Final cost : 7.165826242331521e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.165826242331521e-05
# Converged in iteration 136 with cost 7.16582290188647e-05 because of step counter
# Final cost : 7.16582290188647e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.16582290188647e-05
# Converged in iteration 1 with cost 7.16582290188647e-05 because of step counter
# Final cost : 7.16582290188647e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.20845171416090186
# Final cost : 0.009824408311687731
# Compute control for a deterministic system
# Cost in iteration 0: 0.009824408311687731
# Final cost : 0.00029770506389875
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029770506389875
# Final cost : 0.0002879355241815727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002879355241815727
# Final cost : 0.00028777687970334034
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028777687970334034
# Converged in iteration 269 with cost 0.00028777672291062064 because of step counter
# Final cost : 0.00028777672291062064
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028777672291062064
# Converged in iteration 1 with cost 0.00028777672291062064 because of step counter
# Final cost : 0.00028777672291062064
# Compute control for a deterministic system
# Cost in iteration 0: 0.44920777293251674
# Final cost : 0.03760494186340716
# Compute control for a deterministic system
# Cost in iteration 0: 0.03760494186340716
# Final cost : 0.0006860916869777762
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006860916869777762
# Final cost : 0.0006502722388182755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006502722388182755
# Final cost : 0.0006497409840757564
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006497409840757564
# Converged in iteration 620 with cost 0.0006497401940626067 because of step counter
# Final cost : 0.0006497401940626067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006497401940626067
# Converged in iteration 11 with cost 0.00064974019403534 because of step counter
# Final cost : 0.00064974019403534
# Compute control for a deterministic system
# Cost in iteration 0: 0.7559165359876917
# Final cost : 0.10351174312506621
# Compute control for a deterministic system
# Cost in iteration 0: 0.10351174312506621
# Final cost : 0.0012505654969762667
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012505654969762667
# Final cost : 0.0011578629415581782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011578629415581782
# Final cost : 0.0011567724058695198
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011567724058695198
# Converged in iteration 515 with cost 0.0011567711170421204 because of step counter
# Final cost : 0.0011567711170421204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011567711170421204
# Converged in iteration 1 with cost 0.0011567711170421204 because of step counter
# Final cost : 0.0011567711170421204
# Compute control for a deterministic system
# Cost in iteration 0: 1.1075250045568614
# Final cost : 0.2259465446664136
# Compute control for a deterministic system
# Cost in iteration 0: 0.2259465446664136
# Final cost : 0.0019975453765462216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019975453765462216
# Final cost : 0.0018063651504210863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018063651504210863
# Final cost : 0.0018044687555623825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018044687555623825
# Final cost : 0.0018044668249278537
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018044668249278537
# Converged in iteration 569 with cost 0.0018044668227903697 because of step counter
# Final cost : 0.0018044668227903697
# Compute control for a deterministic system
# Cost in iteration 0: 1.484807511247943
# Final cost : 0.4185327239015215
# Compute control for a deterministic system
# Cost in iteration 0: 0.4185327239015215
# Final cost : 0.002922415490902781
# Compute control for a deterministic system
# Cost in iteration 0: 0.002922415490902781
# Final cost : 0.002588806880658108
# Compute control for a deterministic system
# Cost in iteration 0: 0.002588806880658108
# Final cost : 0.002585977955759931
# Compute control for a deterministic system
# Cost in iteration 0: 0.002585977955759931
# Converged in iteration 667 with cost 0.0025859779224933458 because of step counter
# Final cost : 0.0025859779224933458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025859779224933458
# Converged in iteration 3 with cost 0.0025859779224929502 because of step counter
# Final cost : 0.0025859779224929502
# Compute control for a deterministic system
# Cost in iteration 0: 1.8795185672780235
# Final cost : 0.6943914014266301
# Compute control for a deterministic system
# Cost in iteration 0: 0.6943914014266301
# Final cost : 0.004046310077958621
# Compute control for a deterministic system
# Cost in iteration 0: 0.004046310077958621
# Final cost : 0.0035200287368574463
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035200287368574463
# Final cost : 0.003515725429657425
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515725429657425
# Converged in iteration 160 with cost 0.003515725427002803 because of step counter
# Final cost : 0.003515725427002803
# Compute control for a deterministic system
# Cost in iteration 0: 0.003515725427002803
# Converged in iteration 1 with cost 0.003515725427002803 because of step counter
# Final cost : 0.003515725427002803
# Compute control for a deterministic system
# Cost in iteration 0: 2.2609979996995078
# Final cost : 1.0400751510260535
# Compute control for a deterministic system
# Cost in iteration 0: 1.0400751510260535
# Final cost : 0.005334020857490464
# Compute control for a deterministic system
# Cost in iteration 0: 0.005334020857490464
# Final cost : 0.00455839789562899
# Compute control for a deterministic system
# Cost in iteration 0: 0.00455839789562899
# Final cost : 0.004552969474830424
# Compute control for a deterministic system
# Cost in iteration 0: 0.004552969474830424
# Converged in iteration 559 with cost 0.004552968644799483 because of step counter
# Final cost : 0.004552968644799483
# Compute control for a deterministic system
# Cost in iteration 0: 0.004552968644799483
# Converged in iteration 20 with cost 0.004552968644786381 because of step counter
# Final cost : 0.004552968644786381
# Compute control for a deterministic system
# Cost in iteration 0: 2.6254925893797605
# Final cost : 1.4496319352746438
# Compute control for a deterministic system
# Cost in iteration 0: 1.4496319352746438
# Final cost : 0.006831989474689203
# Compute control for a deterministic system
# Cost in iteration 0: 0.006831989474689203
# Final cost : 0.005728687439414892
# Compute control for a deterministic system
# Cost in iteration 0: 0.005728687439414892
# Final cost : 0.005719985120980305
# Compute control for a deterministic system
# Cost in iteration 0: 0.005719985120980305
# Converged in iteration 781 with cost 0.005719916514560364 because of step counter
# Final cost : 0.005719916514560364
# Compute control for a deterministic system
# Cost in iteration 0: 0.005719916514560364
# Converged in iteration 1 with cost 0.005719916514560364 because of step counter
# Final cost : 0.005719916514560364
# Compute control for a deterministic system
# Cost in iteration 0: 2.9629748865519456
# Final cost : 1.903257426017981
# Compute control for a deterministic system
# Cost in iteration 0: 1.903257426017981
# Final cost : 0.008568571853335375
# Compute control for a deterministic system
# Cost in iteration 0: 0.008568571853335375
# Final cost : 0.007036822582313246
# Compute control for a deterministic system
# Cost in iteration 0: 0.007036822582313246
# Final cost : 0.007024993146199566
# Compute control for a deterministic system
# Cost in iteration 0: 0.007024993146199566
# Converged in iteration 522 with cost 0.007024815740684588 because of step counter
# Final cost : 0.007024815740684588
# Compute control for a deterministic system
# Cost in iteration 0: 0.007024815740684588
# Converged in iteration 1 with cost 0.007024815740684588 because of step counter
# Final cost : 0.007024815740684588
# Compute control for a deterministic system
# Cost in iteration 0: 3.2656377443446325
# Final cost : 2.3728781778875003
# Compute control for a deterministic system
# Cost in iteration 0: 2.3728781778875003
# Final cost : 0.010570211397301419
# Compute control for a deterministic system
# Cost in iteration 0: 0.010570211397301419
# Final cost : 0.008492547105182144
# Compute control for a deterministic system
# Cost in iteration 0: 0.008492547105182144
# Final cost : 0.008476848622520692
# Compute control for a deterministic system
# Cost in iteration 0: 0.008476848622520692
# Converged in iteration 773 with cost 0.008476203578851246 because of step counter
# Final cost : 0.008476203578851246
# Compute control for a deterministic system
# Cost in iteration 0: 0.008476203578851246
# Converged in iteration 1 with cost 0.008476203578851246 because of step counter
# Final cost : 0.008476203578851246
# Compute control for a deterministic system
# Cost in iteration 0: 3.528460693678295
# Final cost : 2.825294994597148
# Compute control for a deterministic system
# Cost in iteration 0: 2.825294994597148
# Final cost : 0.01286104409353203
# Compute control for a deterministic system
# Cost in iteration 0: 0.01286104409353203
# Final cost : 0.010102092852741412
# Compute control for a deterministic system
# Cost in iteration 0: 0.010102092852741412
# Final cost : 0.010081445540840743
# Compute control for a deterministic system
# Cost in iteration 0: 0.010081445540840743
# Final cost : 0.010080397551296687
# Compute control for a deterministic system
# Cost in iteration 0: 0.010080397551296687
# Converged in iteration 1069 with cost 0.010080397522195809 because of step counter
# Final cost : 0.010080397522195809
# Compute control for a deterministic system
# Cost in iteration 0: 3.749620826389356
# Final cost : 3.229429262786736
# Compute control for a deterministic system
# Cost in iteration 0: 3.229429262786736
# Final cost : 0.01546461816437837
# Compute control for a deterministic system
# Cost in iteration 0: 0.01546461816437837
# Final cost : 0.011869866848367834
# Compute control for a deterministic system
# Cost in iteration 0: 0.011869866848367834
# Final cost : 0.01184198016420107
# Compute control for a deterministic system
# Cost in iteration 0: 0.01184198016420107
# Final cost : 0.0118410939772628
# Compute control for a deterministic system
# Cost in iteration 0: 0.0118410939772628
# Final cost : 0.01184109204565282
# Compute control for a deterministic system
# Cost in iteration 0: 3.9302639987817187
# Final cost : 3.5652982585962505
# Compute control for a deterministic system
# Cost in iteration 0: 3.5652982585962505
# Final cost : 0.01840644032983955
# Compute control for a deterministic system
# Cost in iteration 0: 0.01840644032983955
# Final cost : 0.013797875003322139
# Compute control for a deterministic system
# Cost in iteration 0: 0.013797875003322139
# Final cost : 0.013762315410804702
# Compute control for a deterministic system
# Cost in iteration 0: 0.013762315410804702
# Final cost : 0.013760144579235252
# Compute control for a deterministic system
# Cost in iteration 0: 0.013760144579235252
# Final cost : 0.013760135041791063
# Compute control for a deterministic system
# Cost in iteration 0: 4.073578979468256
# Final cost : 3.828159302137108
# Compute control for a deterministic system
# Cost in iteration 0: 3.828159302137108
# Final cost : 0.021715744768019327
# Compute control for a deterministic system
# Cost in iteration 0: 0.021715744768019327
# Final cost : 0.015887174152813516
# Compute control for a deterministic system
# Cost in iteration 0: 0.015887174152813516
# Final cost : 0.015841538319235852
# Compute control for a deterministic system
# Cost in iteration 0: 0.015841538319235852
# Final cost : 0.01583845965541931
# Compute control for a deterministic system
# Cost in iteration 0: 0.01583845965541931
# Final cost : 0.01583845712955043
# Compute control for a deterministic system
# Cost in iteration 0: 4.18365225427835
# Final cost : 4.024731517787437
# Compute control for a deterministic system
# Cost in iteration 0: 4.024731517787437
# Final cost : 0.025427042417625587
# Compute control for a deterministic system
# Cost in iteration 0: 0.025427042417625587
# Final cost : 0.018141161200164783
# Compute control for a deterministic system
# Cost in iteration 0: 0.018141161200164783
# Final cost : 0.01808117474387037
# Compute control for a deterministic system
# Cost in iteration 0: 0.01808117474387037
# Final cost : 0.018076767179783893
# Compute control for a deterministic system
# Cost in iteration 0: 0.018076767179783893
# Final cost : 0.018076713215062434
# Compute control for a deterministic system
# Cost in iteration 0: 4.264585437562494
# Final cost : 4.166160723630309
# Compute control for a deterministic system
# Cost in iteration 0: 4.166160723630309
# Final cost : 0.029582936218839055
# Compute control for a deterministic system
# Cost in iteration 0: 0.029582936218839055
# Final cost : 0.02055631966258954
# Compute control for a deterministic system
# Cost in iteration 0: 0.02055631966258954
# Final cost : 0.020481803268985556
# Compute control for a deterministic system
# Cost in iteration 0: 0.020481803268985556
# Final cost : 0.02047572442143343
# Compute control for a deterministic system
# Cost in iteration 0: 0.02047572442143343
# Final cost : 0.02047561421445237
# Compute control for a deterministic system
# Cost in iteration 0: 4.320016195575196
# Final cost : 4.263140341816223
# Compute control for a deterministic system
# Cost in iteration 0: 4.263140341816223
# Final cost : 0.034236971302003205
# Compute control for a deterministic system
# Cost in iteration 0: 0.034236971302003205
# Final cost : 0.02313661644826178
# Compute control for a deterministic system
# Cost in iteration 0: 0.02313661644826178
# Final cost : 0.02304443599105764
# Compute control for a deterministic system
# Cost in iteration 0: 0.02304443599105764
# Final cost : 0.023036057902954665
# Compute control for a deterministic system
# Cost in iteration 0: 0.023036057902954665
# Converged in iteration 1675 with cost 0.02303605779886169 because of step counter
# Final cost : 0.02303605779886169
# Compute control for a deterministic system
# Cost in iteration 0: 4.353399705032631
# Final cost : 4.324943770700093
# Compute control for a deterministic system
# Cost in iteration 0: 4.324943770700093
# Final cost : 0.039577881472062836
# Compute control for a deterministic system
# Cost in iteration 0: 0.039577881472062836
# Final cost : 0.02595149174401873
# Compute control for a deterministic system
# Cost in iteration 0: 0.02595149174401873
# Final cost : 0.02583085486803462
# Compute control for a deterministic system
# Cost in iteration 0: 0.02583085486803462
# Final cost : 0.025819031706504503
# Compute control for a deterministic system
# Cost in iteration 0: 0.025819031706504503
# Final cost : 0.025818877822579855
# Compute control for a deterministic system
# Cost in iteration 0: 4.365551187284114
# Final cost : 4.354549965636984
# Compute control for a deterministic system
# Cost in iteration 0: 4.354549965636984
# Final cost : 0.04549003277699282
# Compute control for a deterministic system
# Cost in iteration 0: 0.04549003277699282
# Final cost : 0.028876096481379978
# Compute control for a deterministic system
# Cost in iteration 0: 0.028876096481379978
# Final cost : 0.028724321981502963
# Compute control for a deterministic system
# Cost in iteration 0: 0.028724321981502963
# Final cost : 0.028709495482595687
# Compute control for a deterministic system
# Cost in iteration 0: 0.028709495482595687
# Final cost : 0.028709465588109953
# Compute control for a deterministic system
# Cost in iteration 0: 4.358501690754904
# Final cost : 4.355986578970677
# Compute control for a deterministic system
# Cost in iteration 0: 4.355986578970677
# Final cost : 0.052336516822376
# Compute control for a deterministic system
# Cost in iteration 0: 0.052336516822376
# Final cost : 0.031985008215998575
# Compute control for a deterministic system
# Cost in iteration 0: 0.031985008215998575
# Final cost : 0.03178660131821521
# Compute control for a deterministic system
# Cost in iteration 0: 0.03178660131821521
# Final cost : 0.031766716382023455
# Compute control for a deterministic system
# Cost in iteration 0: 0.031766716382023455
# Final cost : 0.031765579727532724
# Compute control for a deterministic system
# Cost in iteration 0: 4.332114107609619
# Final cost : 4.328342488623764
# Compute control for a deterministic system
# Cost in iteration 0: 4.328342488623764
# Final cost : 0.032377786038835364
# Compute control for a deterministic system
# Cost in iteration 0: 0.032377786038835364
# Final cost : 0.021788434855457773
# Compute control for a deterministic system
# Cost in iteration 0: 0.021788434855457773
# Final cost : 0.021605028080154364
# Compute control for a deterministic system
# Cost in iteration 0: 0.021605028080154364
# Final cost : 0.02159675052392127
# Compute control for a deterministic system
# Cost in iteration 0: 0.02159675052392127
# Converged in iteration 608 with cost 0.02159634093081174 because of step counter
# Final cost : 0.02159634093081174
# Compute control for a deterministic system
# Cost in iteration 0: 4.284922324665414
# Final cost : 4.2670373424642065
# Compute control for a deterministic system
# Cost in iteration 0: 4.2670373424642065
# Final cost : 0.02800190490606228
# Compute control for a deterministic system
# Cost in iteration 0: 0.02800190490606228
# Final cost : 0.019502169687468048
# Compute control for a deterministic system
# Cost in iteration 0: 0.019502169687468048
# Final cost : 0.019356226666666684
# Compute control for a deterministic system
# Cost in iteration 0: 0.019356226666666684
# Final cost : 0.019348959321061704
# Compute control for a deterministic system
# Cost in iteration 0: 0.019348959321061704
# Converged in iteration 570 with cost 0.01934894937579012 because of step counter
# Final cost : 0.01934894937579012
# Compute control for a deterministic system
# Cost in iteration 0: 4.214109832952824
# Final cost : 4.163312883519529
# Compute control for a deterministic system
# Cost in iteration 0: 4.163312883519529
# Final cost : 0.024257117507639387
# Compute control for a deterministic system
# Cost in iteration 0: 0.024257117507639387
# Final cost : 0.01733528872647909
# Compute control for a deterministic system
# Cost in iteration 0: 0.01733528872647909
# Final cost : 0.017222803812376473
# Compute control for a deterministic system
# Cost in iteration 0: 0.017222803812376473
# Final cost : 0.017217186946955423
# Compute control for a deterministic system
# Cost in iteration 0: 0.017217186946955423
# Converged in iteration 1300 with cost 0.017216366054335654 because of step counter
# Final cost : 0.017216366054335654
# Compute control for a deterministic system
# Cost in iteration 0: 4.115617003107827
# Final cost : 4.004048853890894
# Compute control for a deterministic system
# Cost in iteration 0: 4.004048853890894
# Final cost : 0.02090581020844808
# Compute control for a deterministic system
# Cost in iteration 0: 0.02090581020844808
# Final cost : 0.015292761587726663
# Compute control for a deterministic system
# Cost in iteration 0: 0.015292761587726663
# Final cost : 0.01520501000525233
# Compute control for a deterministic system
# Cost in iteration 0: 0.01520501000525233
# Final cost : 0.01520003819881958
# Compute control for a deterministic system
# Cost in iteration 0: 0.01520003819881958
# Converged in iteration 57 with cost 0.01520003819448349 because of step counter
# Final cost : 0.01520003819448349
# Compute control for a deterministic system
# Cost in iteration 0: 3.9844728139638135
# Final cost : 3.773223538872196
# Compute control for a deterministic system
# Cost in iteration 0: 3.773223538872196
# Final cost : 0.01788107355188416
# Compute control for a deterministic system
# Cost in iteration 0: 0.01788107355188416
# Final cost : 0.013372066069057996
# Compute control for a deterministic system
# Cost in iteration 0: 0.013372066069057996
# Final cost : 0.013304476371530849
# Compute control for a deterministic system
# Cost in iteration 0: 0.013304476371530849
# Final cost : 0.013301436986473814
# Compute control for a deterministic system
# Cost in iteration 0: 0.013301436986473814
# Converged in iteration 243 with cost 0.013301436960228662 because of step counter
# Final cost : 0.013301436960228662
# Compute control for a deterministic system
# Cost in iteration 0: 3.815467012222417
# Final cost : 3.4573276551071794
# Compute control for a deterministic system
# Cost in iteration 0: 3.4573276551071794
# Final cost : 0.01514901997090505
# Compute control for a deterministic system
# Cost in iteration 0: 0.01514901997090505
# Final cost : 0.011575081142386595
# Compute control for a deterministic system
# Cost in iteration 0: 0.011575081142386595
# Final cost : 0.011524004032781332
# Compute control for a deterministic system
# Cost in iteration 0: 0.011524004032781332
# Converged in iteration 817 with cost 0.01152205867287953 because of step counter
# Final cost : 0.01152205867287953
# Compute control for a deterministic system
# Cost in iteration 0: 0.01152205867287953
# Converged in iteration 28 with cost 0.011522058672640915 because of step counter
# Final cost : 0.011522058672640915
# Compute control for a deterministic system
# Cost in iteration 0: 3.6042315945477483
# Final cost : 3.0552489782158228
# Compute control for a deterministic system
# Cost in iteration 0: 3.0552489782158228
# Final cost : 0.012687674865185359
# Compute control for a deterministic system
# Cost in iteration 0: 0.012687674865185359
# Final cost : 0.00990209676256781
# Compute control for a deterministic system
# Cost in iteration 0: 0.00990209676256781
# Final cost : 0.009864674244635526
# Compute control for a deterministic system
# Cost in iteration 0: 0.009864674244635526
# Final cost : 0.009863423110928839
# Compute control for a deterministic system
# Cost in iteration 0: 0.009863423110928839
# Converged in iteration 402 with cost 0.009863423099591146 because of vanishing difference
# Final cost : 0.009863423099591146
# Compute control for a deterministic system
# Cost in iteration 0: 3.3485022125185386
# Final cost : 2.5859070347185633
# Compute control for a deterministic system
# Cost in iteration 0: 2.5859070347185633
# Final cost : 0.010480860668880336
# Compute control for a deterministic system
# Cost in iteration 0: 0.010480860668880336
# Final cost : 0.008354683189625029
# Compute control for a deterministic system
# Cost in iteration 0: 0.008354683189625029
# Final cost : 0.00832775512426363
# Compute control for a deterministic system
# Cost in iteration 0: 0.00832775512426363
# Converged in iteration 897 with cost 0.008327064617006932 because of step counter
# Final cost : 0.008327064617006932
# Compute control for a deterministic system
# Cost in iteration 0: 0.008327064617006932
# Converged in iteration 1 with cost 0.008327064617006932 because of step counter
# Final cost : 0.008327064617006932
# Compute control for a deterministic system
# Cost in iteration 0: 3.048804876671416
# Final cost : 2.084543982469024
# Compute control for a deterministic system
# Cost in iteration 0: 2.084543982469024
# Final cost : 0.0085153787486705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0085153787486705
# Final cost : 0.00693409094603676
# Compute control for a deterministic system
# Cost in iteration 0: 0.00693409094603676
# Final cost : 0.006914924295847015
# Compute control for a deterministic system
# Cost in iteration 0: 0.006914924295847015
# Final cost : 0.006914545590390598
# Compute control for a deterministic system
# Cost in iteration 0: 0.006914545590390598
# Converged in iteration 508 with cost 0.00691452410711977 because of step counter
# Final cost : 0.00691452410711977
# Compute control for a deterministic system
# Cost in iteration 0: 2.7002715407926474
# Final cost : 1.5799873462401994
# Compute control for a deterministic system
# Cost in iteration 0: 1.5799873462401994
# Final cost : 0.006745070538224165
# Compute control for a deterministic system
# Cost in iteration 0: 0.006745070538224165
# Final cost : 0.005615310777841899
# Compute control for a deterministic system
# Cost in iteration 0: 0.005615310777841899
# Final cost : 0.00560160309960355
# Compute control for a deterministic system
# Cost in iteration 0: 0.00560160309960355
# Converged in iteration 533 with cost 0.005601386962120824 because of step counter
# Final cost : 0.005601386962120824
# Compute control for a deterministic system
# Cost in iteration 0: 0.005601386962120824
# Converged in iteration 3 with cost 0.005601386962119602 because of step counter
# Final cost : 0.005601386962119602
# Compute control for a deterministic system
# Cost in iteration 0: 2.323455184303653
# Final cost : 1.1275490583329866
# Compute control for a deterministic system
# Cost in iteration 0: 1.1275490583329866
# Final cost : 0.0052334694613537375
# Compute control for a deterministic system
# Cost in iteration 0: 0.0052334694613537375
# Final cost : 0.004455527414149624
# Compute control for a deterministic system
# Cost in iteration 0: 0.004455527414149624
# Final cost : 0.004444374397883545
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444374397883545
# Converged in iteration 542 with cost 0.004444210897573759 because of step counter
# Final cost : 0.004444210897573759
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444210897573759
# Converged in iteration 11 with cost 0.004444210897568055 because of step counter
# Final cost : 0.004444210897568055
# Compute control for a deterministic system
# Cost in iteration 0: 1.9240609579006853
# Final cost : 0.7433761538982452
# Compute control for a deterministic system
# Cost in iteration 0: 0.7433761538982452
# Final cost : 0.003933133702260845
# Compute control for a deterministic system
# Cost in iteration 0: 0.003933133702260845
# Final cost : 0.0034250140457020408
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034250140457020408
# Final cost : 0.0034164564603045315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034164564603045315
# Converged in iteration 642 with cost 0.003416362461058359 because of step counter
# Final cost : 0.003416362461058359
# Compute control for a deterministic system
# Cost in iteration 0: 0.003416362461058359
# Converged in iteration 3 with cost 0.0034163624610582277 because of step counter
# Final cost : 0.0034163624610582277
# Compute control for a deterministic system
# Cost in iteration 0: 1.5192718620109835
# Final cost : 0.4442685029054956
# Compute control for a deterministic system
# Cost in iteration 0: 0.4442685029054956
# Final cost : 0.002835985175502925
# Compute control for a deterministic system
# Cost in iteration 0: 0.002835985175502925
# Final cost : 0.002525770361679302
# Compute control for a deterministic system
# Cost in iteration 0: 0.002525770361679302
# Final cost : 0.002520011225118831
# Compute control for a deterministic system
# Cost in iteration 0: 0.002520011225118831
# Converged in iteration 743 with cost 0.002519959993784245 because of step counter
# Final cost : 0.002519959993784245
# Compute control for a deterministic system
# Cost in iteration 0: 0.002519959993784245
# Converged in iteration 2 with cost 0.0025199599937840837 because of step counter
# Final cost : 0.0025199599937840837
# Compute control for a deterministic system
# Cost in iteration 0: 1.1271216519752087
# Final cost : 0.23411548191758108
# Compute control for a deterministic system
# Cost in iteration 0: 0.23411548191758108
# Final cost : 0.0019332038787375815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019332038787375815
# Final cost : 0.0017605327351299428
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017605327351299428
# Final cost : 0.001757016428050886
# Compute control for a deterministic system
# Cost in iteration 0: 0.001757016428050886
# Converged in iteration 436 with cost 0.0017569931766315877 because of step counter
# Final cost : 0.0017569931766315877
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017569931766315877
# Converged in iteration 37 with cost 0.0017569931765680006 because of step counter
# Final cost : 0.0017569931765680006
# Compute control for a deterministic system
# Cost in iteration 0: 0.7657623053231586
# Final cost : 0.10443642653361895
# Compute control for a deterministic system
# Cost in iteration 0: 0.10443642653361895
# Final cost : 0.0012152729138854078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012152729138854078
# Final cost : 0.0011311306255329767
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011311306255329767
# Final cost : 0.0011292209378804816
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011292209378804816
# Converged in iteration 423 with cost 0.0011292177495781427 because of step counter
# Final cost : 0.0011292177495781427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011292177495781427
# Converged in iteration 1 with cost 0.0011292177495781427 because of step counter
# Final cost : 0.0011292177495781427
# Compute control for a deterministic system
# Cost in iteration 0: 0.45386413331666164
# Final cost : 0.03714984060337362
# Compute control for a deterministic system
# Cost in iteration 0: 0.03714984060337362
# Final cost : 0.000672368117036055
# Compute control for a deterministic system
# Cost in iteration 0: 0.000672368117036055
# Final cost : 0.0006389797496174841
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006389797496174841
# Final cost : 0.0006381845639431876
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006381845639431876
# Converged in iteration 437 with cost 0.0006381821065842387 because of step counter
# Final cost : 0.0006381821065842387
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006381821065842387
# Converged in iteration 1 with cost 0.0006381821065842387 because of step counter
# Final cost : 0.0006381821065842387
# Compute control for a deterministic system
# Cost in iteration 0: 0.2106044341345741
# Final cost : 0.009631203025907045
# Compute control for a deterministic system
# Cost in iteration 0: 0.009631203025907045
# Final cost : 0.0002948626467835024
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002948626467835024
# Final cost : 0.0002855377526097552
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002855377526097552
# Final cost : 0.00028533071103661455
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028533071103661455
# Converged in iteration 227 with cost 0.00028532976343513896 because of step counter
# Final cost : 0.00028532976343513896
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028532976343513896
# Converged in iteration 2 with cost 0.00028532976343512086 because of step counter
# Final cost : 0.00028532976343512086
# Compute control for a deterministic system
# Cost in iteration 0: 0.054464761854799544
# Final cost : 0.0014590385699481557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014590385699481557
# Final cost : 7.342656062546585e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.342656062546585e-05
# Final cost : 7.211665540453503e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.211665540453503e-05
# Final cost : 7.210074035267336e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.210074035267336e-05
# Converged in iteration 305 with cost 7.21007285103396e-05 because of step counter
# Final cost : 7.21007285103396e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.21007285103396e-05
# Converged in iteration 10 with cost 7.210072850849733e-05 because of step counter
# Final cost : 7.210072850849733e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.6732693669051974e-06
# Final cost : 5.714137987727708e-08
# Compute control for a deterministic system
# Cost in iteration 0: 5.714137987727708e-08
# Final cost : 3.5649576479369637e-09
# ----------------------------------------------- 0
# cost =  0.00028777672291062064
# Compute control for a deterministic system
# Cost in iteration 0: 0.05378853020790701
# Final cost : 0.0002904805396752489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002904805396752489
# Final cost : 0.0002878272553320613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002878272553320613
# Final cost : 0.00028777682941682803
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028777682941682803
# Converged in iteration 308 with cost 0.0002877767229091673 because of step counter
# Final cost : 0.0002877767229091673
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002877767229091673
# Converged in iteration 1 with cost 0.0002877767229091673 because of step counter
# Final cost : 0.0002877767229091673
# -----------------------------------------------
# 0 found better solution,  2
# cost =  0.00064974019403534
# Compute control for a deterministic system
# Cost in iteration 0: 0.05539443796723306
# Final cost : 0.000654855631207654
# Compute control for a deterministic system
# Cost in iteration 0: 0.000654855631207654
# Final cost : 0.0006498465174848867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006498465174848867
# Final cost : 0.000649740372827649
# Compute control for a deterministic system
# Cost in iteration 0: 0.000649740372827649
# Converged in iteration 903 with cost 0.0006497401940956372 because of vanishing difference
# Final cost : 0.0006497401940956372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006497401940956372
# Converged in iteration 15 with cost 0.0006497401940071162 because of step counter
# Final cost : 0.0006497401940071162
# -----------------------------------------------
# 0 found better solution,  3
# cost =  0.0011567711170421204
# Compute control for a deterministic system
# Cost in iteration 0: 0.05311390172138655
# Final cost : 0.0011649547428467587
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011649547428467587
# Final cost : 0.0011569300278268025
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011569300278268025
# Final cost : 0.0011567713543925188
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011567713543925188
# Converged in iteration 391 with cost 0.0011567711170827615 because of step counter
# Final cost : 0.0011567711170827615
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011567711170827615
# Converged in iteration 10 with cost 0.001156771116992511 because of step counter
# Final cost : 0.001156771116992511
# -----------------------------------------------
# 0 found better solution,  4
# cost =  0.0018044668227903697
# Compute control for a deterministic system
# Cost in iteration 0: 0.04886335894195515
# Final cost : 0.0018158968657498325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018158968657498325
# Final cost : 0.0018046877230744373
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018046877230744373
# Final cost : 0.0018044673783421169
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018044673783421169
# Final cost : 0.0018044668240495207
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018044668240495207
# Converged in iteration 147 with cost 0.0018044668227761176 because of step counter
# Final cost : 0.0018044668227761176
# -----------------------------------------------
# 0 found better solution,  5
# cost =  0.0025859779224929502
# Compute control for a deterministic system
# Cost in iteration 0: 0.05368297317241201
# Final cost : 0.0026013697600372697
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026013697600372697
# Final cost : 0.0025863002307432107
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025863002307432107
# Final cost : 0.0025859779864400427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025859779864400427
# Converged in iteration 251 with cost 0.0025859779226104357 because of step counter
# Final cost : 0.0025859779226104357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025859779226104357
# Converged in iteration 21 with cost 0.0025859779225409774 because of step counter
# Final cost : 0.0025859779225409774
# cost =  0.003515725427002803
# Compute control for a deterministic system
# Cost in iteration 0: 0.051294625995416634
# Final cost : 0.0035367601093189436
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035367601093189436
# Final cost : 0.0035161378031417084
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035161378031417084
# Final cost : 0.0035157265196571206
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035157265196571206
# Converged in iteration 243 with cost 0.00351572542717394 because of step counter
# Final cost : 0.00351572542717394
# Compute control for a deterministic system
# Cost in iteration 0: 0.00351572542717394
# Converged in iteration 4 with cost 0.0035157254271724063 because of step counter
# Final cost : 0.0035157254271724063
# cost =  0.004552968644786381
# Compute control for a deterministic system
# Cost in iteration 0: 0.05144267465800844
# Final cost : 0.004579568222309451
# Compute control for a deterministic system
# Cost in iteration 0: 0.004579568222309451
# Final cost : 0.004553479033155087
# Compute control for a deterministic system
# Cost in iteration 0: 0.004553479033155087
# Final cost : 0.004552971195920571
# Compute control for a deterministic system
# Cost in iteration 0: 0.004552971195920571
# Converged in iteration 320 with cost 0.004552968644745356 because of step counter
# Final cost : 0.004552968644745356
# Compute control for a deterministic system
# Cost in iteration 0: 0.004552968644745356
# Converged in iteration 5 with cost 0.0045529686447431765 because of step counter
# Final cost : 0.0045529686447431765
# -----------------------------------------------
# 0 found better solution,  8
# cost =  0.005719916514560364
# Compute control for a deterministic system
# Cost in iteration 0: 0.05713709050637359
# Final cost : 0.00575404651789898
# Compute control for a deterministic system
# Cost in iteration 0: 0.00575404651789898
# Final cost : 0.0057205856435462365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0057205856435462365
# Final cost : 0.005719921689370603
# Compute control for a deterministic system
# Cost in iteration 0: 0.005719921689370603
# Converged in iteration 451 with cost 0.005719916514684888 because of step counter
# Final cost : 0.005719916514684888
# Compute control for a deterministic system
# Cost in iteration 0: 0.005719916514684888
# Converged in iteration 5 with cost 0.0057199165146825165 because of step counter
# Final cost : 0.0057199165146825165
# cost =  0.007024815740684588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0598544127176288
# Final cost : 0.007067245513221668
# Compute control for a deterministic system
# Cost in iteration 0: 0.007067245513221668
# Final cost : 0.007025617649723802
# Compute control for a deterministic system
# Cost in iteration 0: 0.007025617649723802
# Final cost : 0.007024816688684525
# Compute control for a deterministic system
# Cost in iteration 0: 0.007024816688684525
# Converged in iteration 343 with cost 0.007024815740670232 because of step counter
# Final cost : 0.007024815740670232
# Compute control for a deterministic system
# Cost in iteration 0: 0.007024815740670232
# Converged in iteration 3 with cost 0.007024815740668909 because of step counter
# Final cost : 0.007024815740668909
# -----------------------------------------------
# 0 found better solution,  10
# cost =  0.008476203578851246
# Compute control for a deterministic system
# Cost in iteration 0: 0.057928038534134946
# Final cost : 0.008527635799224324
# Compute control for a deterministic system
# Cost in iteration 0: 0.008527635799224324
# Final cost : 0.008477320566179496
# Compute control for a deterministic system
# Cost in iteration 0: 0.008477320566179496
# Final cost : 0.008476203833795737
# Compute control for a deterministic system
# Cost in iteration 0: 0.008476203833795737
# Converged in iteration 718 with cost 0.008476203578755098 because of step counter
# Final cost : 0.008476203578755098
# Compute control for a deterministic system
# Cost in iteration 0: 0.008476203578755098
# Converged in iteration 1 with cost 0.008476203578755098 because of step counter
# Final cost : 0.008476203578755098
# -----------------------------------------------
# 0 found better solution,  11
# cost =  0.010080397522195809
# Compute control for a deterministic system
# Cost in iteration 0: 0.05176954931470742
# Final cost : 0.010141578994685591
# Compute control for a deterministic system
# Cost in iteration 0: 0.010141578994685591
# Final cost : 0.010081971229413655
# Compute control for a deterministic system
# Cost in iteration 0: 0.010081971229413655
# Final cost : 0.010080397936749497
# Compute control for a deterministic system
# Cost in iteration 0: 0.010080397936749497
# Converged in iteration 547 with cost 0.010080397522131508 because of step counter
# Final cost : 0.010080397522131508
# Compute control for a deterministic system
# Cost in iteration 0: 0.010080397522131508
# Converged in iteration 1 with cost 0.010080397522131508 because of step counter
# Final cost : 0.010080397522131508
# -----------------------------------------------
# 0 found better solution,  12
# cost =  0.01184109204565282
# Compute control for a deterministic system
# Cost in iteration 0: 0.06836109063512912
# Final cost : 0.011914907639671964
# Compute control for a deterministic system
# Cost in iteration 0: 0.011914907639671964
# Final cost : 0.011843170643867649
# Compute control for a deterministic system
# Cost in iteration 0: 0.011843170643867649
# Final cost : 0.011841232962545332
# Compute control for a deterministic system
# Cost in iteration 0: 0.011841232962545332
# Final cost : 0.011841092054387754
# Compute control for a deterministic system
# Cost in iteration 0: 0.011841092054387754
# Converged in iteration 849 with cost 0.011841092043819626 because of step counter
# Final cost : 0.011841092043819626
# -----------------------------------------------
# 0 found better solution,  13
# cost =  0.013760135041791063
# Compute control for a deterministic system
# Cost in iteration 0: 0.07367745891826619
# Final cost : 0.013846659811664698
# Compute control for a deterministic system
# Cost in iteration 0: 0.013846659811664698
# Final cost : 0.013762828900761127
# Compute control for a deterministic system
# Cost in iteration 0: 0.013762828900761127
# Final cost : 0.013760332551056654
# Compute control for a deterministic system
# Cost in iteration 0: 0.013760332551056654
# Final cost : 0.013760135612194089
# Compute control for a deterministic system
# Cost in iteration 0: 0.013760135612194089
# Final cost : 0.013760135034191299
# -----------------------------------------------
# 0 found better solution,  14
# cost =  0.01583845712955043
# Compute control for a deterministic system
# Cost in iteration 0: 0.05485936316576514
# Final cost : 0.015935645401956477
# Compute control for a deterministic system
# Cost in iteration 0: 0.015935645401956477
# Final cost : 0.01584174334669783
# Compute control for a deterministic system
# Cost in iteration 0: 0.01584174334669783
# Final cost : 0.015838717153829025
# Compute control for a deterministic system
# Cost in iteration 0: 0.015838717153829025
# Final cost : 0.015838457176453588
# Compute control for a deterministic system
# Cost in iteration 0: 0.015838457176453588
# Converged in iteration 1349 with cost 0.015838457124479337 because of step counter
# Final cost : 0.015838457124479337
# -----------------------------------------------
# 0 found better solution,  15
# cost =  0.018076713215062434
# Compute control for a deterministic system
# Cost in iteration 0: 0.06888994940077307
# Final cost : 0.018188550437921523
# Compute control for a deterministic system
# Cost in iteration 0: 0.018188550437921523
# Final cost : 0.018080868722892787
# Compute control for a deterministic system
# Cost in iteration 0: 0.018080868722892787
# Final cost : 0.01807706649827231
# Compute control for a deterministic system
# Cost in iteration 0: 0.01807706649827231
# Final cost : 0.018076716078392237
# Compute control for a deterministic system
# Cost in iteration 0: 0.018076716078392237
# Final cost : 0.01807671306072997
# -----------------------------------------------
# 0 found better solution,  16
# cost =  0.02047561421445237
# Compute control for a deterministic system
# Cost in iteration 0: 0.07902547164949694
# Final cost : 0.02060241903395557
# Compute control for a deterministic system
# Cost in iteration 0: 0.02060241903395557
# Final cost : 0.02048070635263056
# Compute control for a deterministic system
# Cost in iteration 0: 0.02048070635263056
# Final cost : 0.020476081929925356
# Compute control for a deterministic system
# Cost in iteration 0: 0.020476081929925356
# Final cost : 0.0204756172660141
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204756172660141
# Final cost : 0.020475613723945227
# -----------------------------------------------
# 0 found better solution,  17
# cost =  0.02303605779886169
# Compute control for a deterministic system
# Cost in iteration 0: 0.06360966115600905
# Final cost : 0.023174634775683867
# Compute control for a deterministic system
# Cost in iteration 0: 0.023174634775683867
# Final cost : 0.023042453072191372
# Compute control for a deterministic system
# Cost in iteration 0: 0.023042453072191372
# Final cost : 0.023036692663810903
# Compute control for a deterministic system
# Cost in iteration 0: 0.023036692663810903
# Final cost : 0.02303605786947696
# Compute control for a deterministic system
# Cost in iteration 0: 0.02303605786947696
# Converged in iteration 1486 with cost 0.02303605779852367 because of step counter
# Final cost : 0.02303605779852367
# -----------------------------------------------
# 0 found better solution,  18
# cost =  0.025818877822579855
# Compute control for a deterministic system
# Cost in iteration 0: 0.0855781198987087
# Final cost : 0.025981345217254485
# Compute control for a deterministic system
# Cost in iteration 0: 0.025981345217254485
# Final cost : 0.025826456544492424
# Compute control for a deterministic system
# Cost in iteration 0: 0.025826456544492424
# Final cost : 0.02581970972606078
# Compute control for a deterministic system
# Cost in iteration 0: 0.02581970972606078
# Final cost : 0.02581888477008098
# Compute control for a deterministic system
# Cost in iteration 0: 0.02581888477008098
# Final cost : 0.025818876637273953
# -----------------------------------------------
# 0 found better solution,  19
# cost =  0.028709465588109953
# Compute control for a deterministic system
# Cost in iteration 0: 0.06622220743134788
# Final cost : 0.02887728674347765
# Compute control for a deterministic system
# Cost in iteration 0: 0.02887728674347765
# Final cost : 0.028718438014671655
# Compute control for a deterministic system
# Cost in iteration 0: 0.028718438014671655
# Final cost : 0.028710564966118433
# Compute control for a deterministic system
# Cost in iteration 0: 0.028710564966118433
# Final cost : 0.0287094698694843
# Compute control for a deterministic system
# Cost in iteration 0: 0.0287094698694843
# Final cost : 0.02870946531038374
# -----------------------------------------------
# 0 found better solution,  20
# cost =  0.031765579727532724
# Compute control for a deterministic system
# Cost in iteration 0: 0.06701200374285364
# Final cost : 0.031948138638603886
# Compute control for a deterministic system
# Cost in iteration 0: 0.031948138638603886
# Final cost : 0.03177583999759246
# Compute control for a deterministic system
# Cost in iteration 0: 0.03177583999759246
# Final cost : 0.03176697796036641
# Compute control for a deterministic system
# Cost in iteration 0: 0.03176697796036641
# ...
# Cost in iteration 0: 0.026429944531541225
# Final cost : 0.026429904093958807
# Compute control for a deterministic system
# Cost in iteration 0: 0.026429904093958807
# Converged in iteration 770 with cost 0.02642990400749453 because of step counter
# Final cost : 0.02642990400749453
# Compute control for a deterministic system
# Cost in iteration 0: 0.02642990400749453
# Converged in iteration 1 with cost 0.02642990400749453 because of step counter
# Final cost : 0.02642990400749453
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.024046405456441163
# Final cost : 0.023958921441331348
# Compute control for a deterministic system
# Cost in iteration 0: 0.023958921441331348
# Final cost : 0.023957164227819287
# Compute control for a deterministic system
# Cost in iteration 0: 0.023957164227819287
# Final cost : 0.023957119681774015
# Compute control for a deterministic system
# Cost in iteration 0: 0.023957119681774015
# Converged in iteration 131 with cost 0.023957119538910977 because of step counter
# Final cost : 0.023957119538910977
# Compute control for a deterministic system
# Cost in iteration 0: 0.023957119538910977
# Converged in iteration 20 with cost 0.023957119538785994 because of step counter
# Final cost : 0.023957119538785994
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.021619879448977544
# Final cost : 0.02159784859499121
# Compute control for a deterministic system
# Cost in iteration 0: 0.02159784859499121
# Final cost : 0.021596386210123022
# Compute control for a deterministic system
# Cost in iteration 0: 0.021596386210123022
# Final cost : 0.021596341092947134
# Compute control for a deterministic system
# Cost in iteration 0: 0.021596341092947134
# Converged in iteration 141 with cost 0.021596340930241292 because of step counter
# Final cost : 0.021596340930241292
# Compute control for a deterministic system
# Cost in iteration 0: 0.021596340930241292
# Converged in iteration 1 with cost 0.021596340930241292 because of step counter
# Final cost : 0.021596340930241292
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.019965551635647543
# Final cost : 0.01935021546808557
# Compute control for a deterministic system
# Cost in iteration 0: 0.01935021546808557
# Final cost : 0.019348991645133217
# Compute control for a deterministic system
# Cost in iteration 0: 0.019348991645133217
# Final cost : 0.01934894951583813
# Compute control for a deterministic system
# Cost in iteration 0: 0.01934894951583813
# Converged in iteration 99 with cost 0.019348949375933386 because of step counter
# Final cost : 0.019348949375933386
# Compute control for a deterministic system
# Cost in iteration 0: 0.019348949375933386
# Converged in iteration 1 with cost 0.019348949375933386 because of step counter
# Final cost : 0.019348949375933386
# Compute control for a deterministic system
# Cost in iteration 0: 0.017352793392051705
# Final cost : 0.01721726068067516
# Compute control for a deterministic system
# Cost in iteration 0: 0.01721726068067516
# Final cost : 0.01721640081969223
# Compute control for a deterministic system
# Cost in iteration 0: 0.01721640081969223
# Final cost : 0.017216366156961965
# Compute control for a deterministic system
# Cost in iteration 0: 0.017216366156961965
# Converged in iteration 186 with cost 0.01721636605434315 because of step counter
# Final cost : 0.01721636605434315
# Compute control for a deterministic system
# Cost in iteration 0: 0.01721636605434315
# Converged in iteration 1 with cost 0.01721636605434315 because of step counter
# Final cost : 0.01721636605434315
# Compute control for a deterministic system
# Cost in iteration 0: 0.015351139385243615
# Final cost : 0.01520061355835344
# Compute control for a deterministic system
# Cost in iteration 0: 0.01520061355835344
# Final cost : 0.015200063471281475
# Compute control for a deterministic system
# Cost in iteration 0: 0.015200063471281475
# Final cost : 0.015200038274899533
# Compute control for a deterministic system
# Cost in iteration 0: 0.015200038274899533
# Converged in iteration 74 with cost 0.015200038193772317 because of step counter
# Final cost : 0.015200038193772317
# Compute control for a deterministic system
# Cost in iteration 0: 0.015200038193772317
# Converged in iteration 6 with cost 0.015200038193770245 because of step counter
# Final cost : 0.015200038193770245
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.013312892567313134
# Final cost : 0.01330181279644463
# Compute control for a deterministic system
# Cost in iteration 0: 0.01330181279644463
# Final cost : 0.01330144461721884
# Compute control for a deterministic system
# Cost in iteration 0: 0.01330144461721884
# Final cost : 0.01330143697978981
# Compute control for a deterministic system
# Cost in iteration 0: 0.01330143697978981
# Converged in iteration 63 with cost 0.013301436960128626 because of step counter
# Final cost : 0.013301436960128626
# Compute control for a deterministic system
# Cost in iteration 0: 0.013301436960128626
# Converged in iteration 1 with cost 0.013301436960128626 because of step counter
# Final cost : 0.013301436960128626
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.011816935372660754
# Final cost : 0.011522273155520653
# Compute control for a deterministic system
# Cost in iteration 0: 0.011522273155520653
# Final cost : 0.01152206573870214
# Compute control for a deterministic system
# Cost in iteration 0: 0.01152206573870214
# Final cost : 0.011522058688239106
# Compute control for a deterministic system
# Cost in iteration 0: 0.011522058688239106
# Converged in iteration 81 with cost 0.011522058672444359 because of step counter
# Final cost : 0.011522058672444359
# Compute control for a deterministic system
# Cost in iteration 0: 0.011522058672444359
# Converged in iteration 2 with cost 0.011522058672444178 because of step counter
# Final cost : 0.011522058672444178
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.009900615439983216
# Final cost : 0.00986354778565738
# Compute control for a deterministic system
# Cost in iteration 0: 0.00986354778565738
# Final cost : 0.009863427751361476
# Compute control for a deterministic system
# Cost in iteration 0: 0.009863427751361476
# Final cost : 0.009863423101137032
# Compute control for a deterministic system
# Cost in iteration 0: 0.009863423101137032
# Converged in iteration 33 with cost 0.00986342309928756 because of step counter
# Final cost : 0.00986342309928756
# Compute control for a deterministic system
# Cost in iteration 0: 0.00986342309928756
# Converged in iteration 1 with cost 0.00986342309928756 because of step counter
# Final cost : 0.00986342309928756
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.008980203860665767
# Final cost : 0.008327131902859893
# Compute control for a deterministic system
# Cost in iteration 0: 0.008327131902859893
# Final cost : 0.008327066672870344
# Compute control for a deterministic system
# Cost in iteration 0: 0.008327066672870344
# Final cost : 0.008327064626033725
# Compute control for a deterministic system
# Cost in iteration 0: 0.008327064626033725
# Converged in iteration 63 with cost 0.008327064616927516 because of step counter
# Final cost : 0.008327064616927516
# Compute control for a deterministic system
# Cost in iteration 0: 0.008327064616927516
# Converged in iteration 1 with cost 0.008327064616927516 because of step counter
# Final cost : 0.008327064616927516
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.00718651055085505
# Final cost : 0.006914564045775896
# Compute control for a deterministic system
# Cost in iteration 0: 0.006914564045775896
# Final cost : 0.00691452494110938
# Compute control for a deterministic system
# Cost in iteration 0: 0.00691452494110938
# Final cost : 0.0069145241090161225
# Compute control for a deterministic system
# Cost in iteration 0: 0.0069145241090161225
# Converged in iteration 47 with cost 0.006914524107026465 because of step counter
# Final cost : 0.006914524107026465
# Compute control for a deterministic system
# Cost in iteration 0: 0.006914524107026465
# Converged in iteration 1 with cost 0.006914524107026465 because of step counter
# Final cost : 0.006914524107026465
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.005718678221543361
# Final cost : 0.005601414934868824
# Compute control for a deterministic system
# Cost in iteration 0: 0.005601414934868824
# Final cost : 0.005601387373405471
# Compute control for a deterministic system
# Cost in iteration 0: 0.005601387373405471
# Final cost : 0.005601386962784701
# Compute control for a deterministic system
# Cost in iteration 0: 0.005601386962784701
# Converged in iteration 73 with cost 0.005601386962037987 because of step counter
# Final cost : 0.005601386962037987
# Compute control for a deterministic system
# Cost in iteration 0: 0.005601386962037987
# Converged in iteration 6 with cost 0.005601386961996809 because of step counter
# Final cost : 0.005601386961996809
# Compute control for a deterministic system
# Cost in iteration 0: 0.004502649902315082
# Final cost : 0.004444233793677811
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444233793677811
# Final cost : 0.004444211144273484
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444211144273484
# Final cost : 0.004444210897882065
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444210897882065
# Converged in iteration 63 with cost 0.004444210897526696 because of step counter
# Final cost : 0.004444210897526696
# Compute control for a deterministic system
# Cost in iteration 0: 0.004444210897526696
# Converged in iteration 4 with cost 0.004444210897526419 because of step counter
# Final cost : 0.004444210897526419
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035794445376440167
# Final cost : 0.003416382625020503
# Compute control for a deterministic system
# Cost in iteration 0: 0.003416382625020503
# Final cost : 0.003416362778594134
# Compute control for a deterministic system
# Cost in iteration 0: 0.003416362778594134
# Final cost : 0.0034163624619656134
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034163624619656134
# Converged in iteration 24 with cost 0.0034163624610470244 because of vanishing difference
# Final cost : 0.0034163624610470244
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034163624610470244
# Converged in iteration 1 with cost 0.0034163624610470244 because of step counter
# Final cost : 0.0034163624610470244
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026172895840846904
# Final cost : 0.002519975326107053
# Compute control for a deterministic system
# Cost in iteration 0: 0.002519975326107053
# Final cost : 0.0025199603255888488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025199603255888488
# Final cost : 0.0025199599946999322
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025199599946999322
# Converged in iteration 44 with cost 0.0025199599937688667 because of step counter
# Final cost : 0.0025199599937688667
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025199599937688667
# Converged in iteration 1 with cost 0.0025199599937688667 because of step counter
# Final cost : 0.0025199599937688667
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018150323111652037
# Final cost : 0.0017570046488688358
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017570046488688358
# Final cost : 0.0017569934590441496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017569934590441496
# Final cost : 0.001756993177308828
# Compute control for a deterministic system
# Cost in iteration 0: 0.001756993177308828
# Converged in iteration 190 with cost 0.0017569931765541939 because of step counter
# Final cost : 0.0017569931765541939
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017569931765541939
# Converged in iteration 1 with cost 0.0017569931765541939 because of step counter
# Final cost : 0.0017569931765541939
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011883318057195234
# Final cost : 0.0011292259361927665
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011292259361927665
# Final cost : 0.001129217944435852
# Compute control for a deterministic system
# Cost in iteration 0: 0.001129217944435852
# Final cost : 0.0011292177500699903
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011292177500699903
# Converged in iteration 198 with cost 0.0011292177495706424 because of step counter
# Final cost : 0.0011292177495706424
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011292177495706424
# Converged in iteration 8 with cost 0.0011292177495344615 because of step counter
# Final cost : 0.0011292177495344615
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006667107905470692
# Final cost : 0.0006381869374799654
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006381869374799654
# Final cost : 0.000638182220741753
# Compute control for a deterministic system
# Cost in iteration 0: 0.000638182220741753
# Converged in iteration 888 with cost 0.0006381821065602818 because of step counter
# Final cost : 0.0006381821065602818
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006381821065602818
# Converged in iteration 1 with cost 0.0006381821065602818 because of step counter
# Final cost : 0.0006381821065602818
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006381821065602818
# Converged in iteration 1 with cost 0.0006381821065602818 because of step counter
# Final cost : 0.0006381821065602818
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028727469539196804
# Final cost : 0.0002853318730702808
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002853318730702808
# Final cost : 0.00028532981481375034
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028532981481375034
# Final cost : 0.00028532976355998804
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028532976355998804
# Converged in iteration 51 with cost 0.00028532976343982993 because of step counter
# Final cost : 0.00028532976343982993
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028532976343982993
# Converged in iteration 1 with cost 0.00028532976343982993 because of step counter
# Final cost : 0.00028532976343982993
# Compute control for a deterministic system
# Cost in iteration 0: 7.366227945440448e-05
# Final cost : 7.210125093619877e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.210125093619877e-05
# Final cost : 7.210074041207638e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.210074041207638e-05
# Converged in iteration 751 with cost 7.210072853256226e-05 because of step counter
# Final cost : 7.210072853256226e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.210072853256226e-05
# Converged in iteration 1 with cost 7.210072853256226e-05 because of step counter
# Final cost : 7.210072853256226e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.210072853256226e-05
# Converged in iteration 1 with cost 7.210072853256226e-05 because of step counter
# Final cost : 7.210072853256226e-05

# %%
save(results_min)
