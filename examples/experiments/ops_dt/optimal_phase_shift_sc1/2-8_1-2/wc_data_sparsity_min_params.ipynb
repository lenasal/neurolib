# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,1337], wc.inh[0,1337]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 13.399117647058825
# minima =  [ 1242  2582  3922  5262  6602  7942  9281 10621 11961 13301 14641 15981
#  17321 18661 20000 21340 22680 24020 25360 26700 28040 29380 30719 32059
#  33399 34739 36079 37419 38759 40099 41438 42778 44118 45458 46798 48138
#  49478]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s2_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s2_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 results_min = read()
#
# Cell In [9], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l1_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l1_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
#options = [True, False, False, False, False, False, True, False]
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0503415091485185
# Converged in iteration 156 with cost 0.019766029637544643 because of vanishing difference
# Final cost : 0.019766029637544643
# Compute control for a deterministic system
# Cost in iteration 0: 0.019766029637544643
# Converged in iteration 22 with cost 0.01976602917929283 because of step counter
# Final cost : 0.01976602917929283
# Compute control for a deterministic system
# Cost in iteration 0: 0.01976602917929283
# Converged in iteration 2 with cost 0.019766029179292294 because of step counter
# Final cost : 0.019766029179292294
# Compute control for a deterministic system
# Cost in iteration 0: 0.019766029179292294
# Converged in iteration 1 with cost 0.019766029179292294 because of step counter
# Final cost : 0.019766029179292294
# Compute control for a deterministic system
# Cost in iteration 0: 0.019766029179292294
# Converged in iteration 4 with cost 0.01976602917928685 because of step counter
# Final cost : 0.01976602917928685
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.0547495809142527
# Cost in iteration 200: 0.02995160460762775
# Final cost : 0.02995160460762775
# Compute control for a deterministic system
# Cost in iteration 0: 0.02995160460762775
# Converged in iteration 56 with cost 0.02995160161473844 because of step counter
# Final cost : 0.02995160161473844
# Compute control for a deterministic system
# Cost in iteration 0: 0.02995160161473844
# Converged in iteration 2 with cost 0.029951601614736114 because of step counter
# Final cost : 0.029951601614736114
# Compute control for a deterministic system
# Cost in iteration 0: 0.029951601614736114
# Converged in iteration 1 with cost 0.029951601614736114 because of step counter
# Final cost : 0.029951601614736114
# Compute control for a deterministic system
# Cost in iteration 0: 0.029951601614736114
# Converged in iteration 1 with cost 0.029951601614736114 because of step counter
# Final cost : 0.029951601614736114
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.07488526992713898
# Cost in iteration 200: 0.040371249338412594
# Final cost : 0.040371249338412594
# Compute control for a deterministic system
# Cost in iteration 0: 0.040371249338412594
# Converged in iteration 31 with cost 0.04037112879341633 because of vanishing difference
# Final cost : 0.04037112879341633
# Compute control for a deterministic system
# Cost in iteration 0: 0.04037112879341633
# Converged in iteration 87 with cost 0.040371127988805086 because of step counter
# Final cost : 0.040371127988805086
# Compute control for a deterministic system
# Cost in iteration 0: 0.040371127988805086
# Converged in iteration 2 with cost 0.040371127988803844 because of step counter
# Final cost : 0.040371127988803844
# Compute control for a deterministic system
# Cost in iteration 0: 0.040371127988803844
# Converged in iteration 1 with cost 0.040371127988803844 because of step counter
# Final cost : 0.040371127988803844
# Compute control for a deterministic system
# Cost in iteration 0: 0.083503823862035
# Cost in iteration 200: 0.05039287671349441
# Final cost : 0.05039287671349441
# Compute control for a deterministic system
# Cost in iteration 0: 0.05039287671349441
# Converged in iteration 195 with cost 0.05039140347235438 because of step counter
# Final cost : 0.05039140347235438
# Compute control for a deterministic system
# Cost in iteration 0: 0.05039140347235438
# Converged in iteration 7 with cost 0.050391403472350826 because of step counter
# Final cost : 0.050391403472350826
# Compute control for a deterministic system
# Cost in iteration 0: 0.050391403472350826
# Converged in iteration 1 with cost 0.050391403472350826 because of step counter
# Final cost : 0.050391403472350826
# Compute control for a deterministic system
# Cost in iteration 0: 0.050391403472350826
# Converged in iteration 1 with cost 0.050391403472350826 because of step counter
# Final cost : 0.050391403472350826
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.08865030869959573
# Cost in iteration 200: 0.0606093858026792
# Final cost : 0.0606093858026792
# Compute control for a deterministic system
# Cost in iteration 0: 0.0606093858026792
# Converged in iteration 78 with cost 0.06060661123423337 because of vanishing difference
# Final cost : 0.06060661123423337
# Compute control for a deterministic system
# Cost in iteration 0: 0.06060661123423337
# Converged in iteration 187 with cost 0.06060660107156829 because of vanishing difference
# Final cost : 0.06060660107156829
# Compute control for a deterministic system
# Cost in iteration 0: 0.06060660107156829
# Converged in iteration 20 with cost 0.06060660107152354 because of step counter
# Final cost : 0.06060660107152354
# Compute control for a deterministic system
# Cost in iteration 0: 0.06060660107152354
# Converged in iteration 2 with cost 0.06060660107152219 because of step counter
# Final cost : 0.06060660107152219
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.09035441498728435
# Cost in iteration 200: 0.07041542952715632
# Final cost : 0.07041542952715632
# Compute control for a deterministic system
# Cost in iteration 0: 0.07041542952715632
# Converged in iteration 135 with cost 0.07040735944676432 because of vanishing difference
# Final cost : 0.07040735944676432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07040735944676432
# Cost in iteration 200: 0.07040735359742187
# Final cost : 0.07040735359742187
# Compute control for a deterministic system
# Cost in iteration 0: 0.07040735359742187
# Converged in iteration 35 with cost 0.07040735356865489 because of step counter
# Final cost : 0.07040735356865489
# Compute control for a deterministic system
# Cost in iteration 0: 0.07040735356865489
# Converged in iteration 14 with cost 0.07040735356862689 because of step counter
# Final cost : 0.07040735356862689
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.10749415219798553
# Cost in iteration 200: 0.08039758110296737
# Final cost : 0.08039758110296737
# Compute control for a deterministic system
# Cost in iteration 0: 0.08039758110296737
# Converged in iteration 161 with cost 0.08038088113776405 because of vanishing difference
# Final cost : 0.08038088113776405
# Compute control for a deterministic system
# Cost in iteration 0: 0.08038088113776405
# Converged in iteration 83 with cost 0.0803808607409507 because of vanishing difference
# Final cost : 0.0803808607409507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0803808607409507
# Converged in iteration 2 with cost 0.08038086074094798 because of step counter
# Final cost : 0.08038086074094798
# Compute control for a deterministic system
# Cost in iteration 0: 0.08038086074094798
# Converged in iteration 1 with cost 0.08038086074094798 because of step counter
# Final cost : 0.08038086074094798
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.10141360620530446
# Cost in iteration 200: 0.0899599210454377
# Final cost : 0.0899599210454377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0899599210454377
# Converged in iteration 65 with cost 0.0899360427302945 because of vanishing difference
# Final cost : 0.0899360427302945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0899360427302945
# Converged in iteration 155 with cost 0.08993398001295017 because of step counter
# Final cost : 0.08993398001295017
# Compute control for a deterministic system
# Cost in iteration 0: 0.08993398001295017
# Converged in iteration 2 with cost 0.0899339800129484 because of step counter
# Final cost : 0.0899339800129484
# Compute control for a deterministic system
# Cost in iteration 0: 0.0899339800129484
# Converged in iteration 2 with cost 0.08993398001294739 because of step counter
# Final cost : 0.08993398001294739
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.15935348180327336
# Cost in iteration 200: 0.09968246571867526
# Final cost : 0.09968246571867526
# Compute control for a deterministic system
# Cost in iteration 0: 0.09968246571867526
# Converged in iteration 178 with cost 0.09963680073795031 because of vanishing difference
# Final cost : 0.09963680073795031
# Compute control for a deterministic system
# Cost in iteration 0: 0.09963680073795031
# Cost in iteration 200: 0.09963637438556214
# Final cost : 0.09963637438556214
# Compute control for a deterministic system
# Cost in iteration 0: 0.09963637438556214
# Converged in iteration 10 with cost 0.09963637438553159 because of step counter
# Final cost : 0.09963637438553159
# Compute control for a deterministic system
# Cost in iteration 0: 0.09963637438553159
# Converged in iteration 13 with cost 0.09963637438548135 because of step counter
# Final cost : 0.09963637438548135
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.13144553024826677
# Cost in iteration 200: 0.1089590563802785
# Final cost : 0.1089590563802785
# Compute control for a deterministic system
# Cost in iteration 0: 0.1089590563802785
# Cost in iteration 200: 0.10890259119909002
# Final cost : 0.10890259119909002
# Compute control for a deterministic system
# Cost in iteration 0: 0.10890259119909002
# Converged in iteration 7 with cost 0.1089025369157771 because of vanishing difference
# Final cost : 0.1089025369157771
# Compute control for a deterministic system
# Cost in iteration 0: 0.1089025369157771
# Cost in iteration 200: 0.10890196580293796
# Cost in iteration 400: 0.10890196121573843
# Final cost : 0.10890196121573843
# Compute control for a deterministic system
# Cost in iteration 0: 0.10890196121573843
# Cost in iteration 200: 0.10890196117610976
# Converged in iteration 254 with cost 0.10890196117569959 because of step counter
# Final cost : 0.10890196117569959
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.14696449600649916
# Cost in iteration 200: 0.11834446594730116
# Final cost : 0.11834446594730116
# Compute control for a deterministic system
# Cost in iteration 0: 0.11834446594730116
# Cost in iteration 200: 0.11826744200983412
# Final cost : 0.11826744200983412
# Compute control for a deterministic system
# Cost in iteration 0: 0.11826744200983412
# Converged in iteration 48 with cost 0.11826580577553374 because of vanishing difference
# Final cost : 0.11826580577553374
# Compute control for a deterministic system
# Cost in iteration 0: 0.11826580577553374
# Cost in iteration 200: 0.11826548181768944
# Cost in iteration 400: 0.11826547421509961
# Final cost : 0.11826547421509961
# Compute control for a deterministic system
# Cost in iteration 0: 0.11826547421509961
# Cost in iteration 200: 0.11826547403926463
# Converged in iteration 398 with cost 0.11826547403323616 because of step counter
# Final cost : 0.11826547403323616
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.13396180836878402
# Cost in iteration 200: 0.1272290768909382
# Final cost : 0.1272290768909382
# Compute control for a deterministic system
# Cost in iteration 0: 0.1272290768909382
# Cost in iteration 200: 0.12714773866947093
# Final cost : 0.12714773866947093
# Compute control for a deterministic system
# Cost in iteration 0: 0.12714773866947093
# Converged in iteration 27 with cost 0.1271462087459839 because of vanishing difference
# Final cost : 0.1271462087459839
# Compute control for a deterministic system
# Cost in iteration 0: 0.1271462087459839
# Cost in iteration 200: 0.12714448064196032
# Cost in iteration 400: 0.1271444090905917
# Final cost : 0.1271444090905917
# Compute control for a deterministic system
# Cost in iteration 0: 0.1271444090905917
# Cost in iteration 200: 0.12714440638706306
# Cost in iteration 400: 0.1271444062212647
# Cost in iteration 600: 0.1271444062109547
# Converged in iteration 694 with cost 0.12714440621034226 because of step counter
# Final cost : 0.12714440621034226
# Compute control for a deterministic system
# Cost in iteration 0: 0.1493303382923675
# Cost in iteration 200: 0.13615740933357118
# Final cost : 0.13615740933357118
# Compute control for a deterministic system
# Cost in iteration 0: 0.13615740933357118
# Cost in iteration 200: 0.136064535970279
# Final cost : 0.136064535970279
# Compute control for a deterministic system
# Cost in iteration 0: 0.136064535970279
# Converged in iteration 43 with cost 0.13606078883906556 because of vanishing difference
# Final cost : 0.13606078883906556
# Compute control for a deterministic system
# Cost in iteration 0: 0.13606078883906556
# Cost in iteration 200: 0.13605816015220462
# Cost in iteration 400: 0.136057957047124
# Final cost : 0.136057957047124
# Compute control for a deterministic system
# Cost in iteration 0: 0.136057957047124
# Cost in iteration 200: 0.13605794292263418
# Cost in iteration 400: 0.1360579414959402
# Cost in iteration 600: 0.1360579413517233
# Cost in iteration 800: 0.13605794133729934
# Converged in iteration 945 with cost 0.1360579413357132 because of step counter
# Final cost : 0.1360579413357132
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.16534985290402582
# Cost in iteration 200: 0.14459786364870986
# Final cost : 0.14459786364870986
# Compute control for a deterministic system
# Cost in iteration 0: 0.14459786364870986
# Cost in iteration 200: 0.1445027523953023
# Final cost : 0.1445027523953023
# Compute control for a deterministic system
# Cost in iteration 0: 0.1445027523953023
# Converged in iteration 98 with cost 0.1444950391072831 because of vanishing difference
# Final cost : 0.1444950391072831
# Compute control for a deterministic system
# Cost in iteration 0: 0.1444950391072831
# Cost in iteration 200: 0.1444932359791333
# Cost in iteration 400: 0.14449302367535294
# Final cost : 0.14449302367535294
# Compute control for a deterministic system
# Cost in iteration 0: 0.14449302367535294
# Cost in iteration 200: 0.1444929972289909
# Cost in iteration 400: 0.14449299333324733
# Cost in iteration 600: 0.1444929927579381
# Cost in iteration 800: 0.14449299267281546
# Cost in iteration 1000: 0.14449299266015656
# Final cost : 0.14449299266015656
# Compute control for a deterministic system
# Cost in iteration 0: 0.16340518256818043
# Cost in iteration 200: 0.1531134858165286
# Final cost : 0.1531134858165286
# Compute control for a deterministic system
# Cost in iteration 0: 0.1531134858165286
# Cost in iteration 200: 0.15301243562279218
# Final cost : 0.15301243562279218
# Compute control for a deterministic system
# Cost in iteration 0: 0.15301243562279218
# Converged in iteration 30 with cost 0.15300825842798235 because of vanishing difference
# Final cost : 0.15300825842798235
# Compute control for a deterministic system
# Cost in iteration 0: 0.15300825842798235
# Cost in iteration 200: 0.15299975535075855
# Cost in iteration 400: 0.15299833926319706
# Final cost : 0.15299833926319706
# Compute control for a deterministic system
# Cost in iteration 0: 0.15299833926319706
# Cost in iteration 200: 0.15299809609391457
# Cost in iteration 400: 0.15299804682545137
# Cost in iteration 600: 0.15299803690625915
# Cost in iteration 800: 0.15299803486607985
# Cost in iteration 1000: 0.15299803445283186
# Final cost : 0.15299803445283186
# Compute control for a deterministic system
# Cost in iteration 0: 0.22344878788486655
# Cost in iteration 200: 0.1612436392341975
# Final cost : 0.1612436392341975
# Compute control for a deterministic system
# Cost in iteration 0: 0.1612436392341975
# Cost in iteration 200: 0.16113838766669275
# Final cost : 0.16113838766669275
# Compute control for a deterministic system
# Cost in iteration 0: 0.16113838766669275
# Converged in iteration 109 with cost 0.16112618498630335 because of vanishing difference
# Final cost : 0.16112618498630335
# Compute control for a deterministic system
# Cost in iteration 0: 0.16112618498630335
# Cost in iteration 200: 0.16112167187030013
# Cost in iteration 400: 0.16112066247794662
# Final cost : 0.16112066247794662
# Compute control for a deterministic system
# Cost in iteration 0: 0.16112066247794662
# Cost in iteration 200: 0.16112043926323613
# Cost in iteration 400: 0.16112038061773906
# Cost in iteration 600: 0.1611203650663627
# Cost in iteration 800: 0.1611203609759152
# Cost in iteration 1000: 0.16112035988373016
# Final cost : 0.16112035988373016
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.19022925226200177
# Cost in iteration 200: 0.1695408727758683
# Final cost : 0.1695408727758683
# Compute control for a deterministic system
# Cost in iteration 0: 0.1695408727758683
# Cost in iteration 200: 0.16943065374043736
# Final cost : 0.16943065374043736
# Compute control for a deterministic system
# Cost in iteration 0: 0.16943065374043736
# Converged in iteration 39 with cost 0.16942243331521176 because of vanishing difference
# Final cost : 0.16942243331521176
# Compute control for a deterministic system
# Cost in iteration 0: 0.16942243331521176
# Cost in iteration 200: 0.16940839901051435
# Cost in iteration 400: 0.1694046344654948
# Final cost : 0.1694046344654948
# Compute control for a deterministic system
# Cost in iteration 0: 0.1694046344654948
# Cost in iteration 200: 0.16940360743567454
# Cost in iteration 400: 0.16940327274281483
# Cost in iteration 600: 0.16940316241788111
# Cost in iteration 800: 0.16940312590048193
# Cost in iteration 1000: 0.1694031138095044
# Final cost : 0.1694031138095044
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.24956105049803023
# Cost in iteration 200: 0.17754486819807916
# Final cost : 0.17754486819807916
# Compute control for a deterministic system
# Cost in iteration 0: 0.17754486819807916
# Cost in iteration 200: 0.1774270343234823
# Final cost : 0.1774270343234823
# Compute control for a deterministic system
# Cost in iteration 0: 0.1774270343234823
# Converged in iteration 52 with cost 0.17741637516076186 because of vanishing difference
# Final cost : 0.17741637516076186
# Compute control for a deterministic system
# Cost in iteration 0: 0.17741637516076186
# Cost in iteration 200: 0.17740169894415178
# Cost in iteration 400: 0.1773969150506241
# Final cost : 0.1773969150506241
# Compute control for a deterministic system
# Cost in iteration 0: 0.1773969150506241
# Cost in iteration 200: 0.17739444989735534
# Cost in iteration 400: 0.17739438213759592
# Cost in iteration 600: 0.17739438177057748
# Converged in iteration 678 with cost 0.17739438176940772 because of step counter
# Final cost : 0.17739438176940772
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.19465787684134375
# Cost in iteration 200: 0.18573892140429898
# Final cost : 0.18573892140429898
# Compute control for a deterministic system
# Cost in iteration 0: 0.18573892140429898
# Cost in iteration 200: 0.18562239210156006
# Final cost : 0.18562239210156006
# Compute control for a deterministic system
# Cost in iteration 0: 0.18562239210156006
# Converged in iteration 183 with cost 0.18558997921571208 because of vanishing difference
# Final cost : 0.18558997921571208
# Compute control for a deterministic system
# Cost in iteration 0: 0.18558997921571208
# Cost in iteration 200: 0.1855806790438806
# Cost in iteration 400: 0.18557699040042766
# Final cost : 0.18557699040042766
# Compute control for a deterministic system
# Cost in iteration 0: 0.18557699040042766
# Cost in iteration 200: 0.18557446147157514
# Cost in iteration 400: 0.18557439968115091
# Cost in iteration 600: 0.18557439812135024
# Cost in iteration 800: 0.18557439808848114
# Converged in iteration 882 with cost 0.1855743980879751 because of step counter
# Final cost : 0.1855743980879751
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.32989781670044244
# Cost in iteration 200: 0.19361045257371173
# Final cost : 0.19361045257371173
# Compute control for a deterministic system
# Cost in iteration 0: 0.19361045257371173
# Cost in iteration 200: 0.19347448170215123
# Final cost : 0.19347448170215123
# Compute control for a deterministic system
# Cost in iteration 0: 0.19347448170215123
# Cost in iteration 200: 0.193441791842846
# Final cost : 0.193441791842846
# Compute control for a deterministic system
# Cost in iteration 0: 0.193441791842846
# Cost in iteration 200: 0.1934314941776943
# Cost in iteration 400: 0.19342687817967535
# Final cost : 0.19342687817967535
# Compute control for a deterministic system
# Cost in iteration 0: 0.19342687817967535
# Cost in iteration 200: 0.19342308293434698
# Cost in iteration 400: 0.1934228053228796
# Cost in iteration 600: 0.19342278650137792
# Cost in iteration 800: 0.1934227850483808
# Cost in iteration 1000: 0.19342278492366324
# Final cost : 0.19342278492366324
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.2758649294926276
# Cost in iteration 200: 0.20159248845590674
# Final cost : 0.20159248845590674
# Compute control for a deterministic system
# Cost in iteration 0: 0.20159248845590674
# Cost in iteration 200: 0.2014546608749209
# Final cost : 0.2014546608749209
# Compute control for a deterministic system
# Cost in iteration 0: 0.2014546608749209
# Cost in iteration 200: 0.20142356430959657
# Final cost : 0.20142356430959657
# Compute control for a deterministic system
# Cost in iteration 0: 0.20142356430959657
# Cost in iteration 200: 0.2014117789597625
# Cost in iteration 400: 0.2014058575132775
# Final cost : 0.2014058575132775
# Compute control for a deterministic system
# Cost in iteration 0: 0.2014058575132775
# Cost in iteration 200: 0.201400570940335
# Cost in iteration 400: 0.20139955037859164
# Cost in iteration 600: 0.2013993870115977
# Cost in iteration 800: 0.20139936547598034
# Cost in iteration 1000: 0.2013993621634459
# Final cost : 0.2013993621634459
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.3256497499274838
# Cost in iteration 200: 0.2092481158410579
# Final cost : 0.2092481158410579
# Compute control for a deterministic system
# Cost in iteration 0: 0.2092481158410579
# Cost in iteration 200: 0.2091050356505389
# Final cost : 0.2091050356505389
# Compute control for a deterministic system
# Cost in iteration 0: 0.2091050356505389
# Cost in iteration 200: 0.20907640620171003
# Final cost : 0.20907640620171003
# Compute control for a deterministic system
# Cost in iteration 0: 0.20907640620171003
# Cost in iteration 200: 0.20906508543873564
# Cost in iteration 400: 0.20905892099659976
# Final cost : 0.20905892099659976
# Compute control for a deterministic system
# Cost in iteration 0: 0.20905892099659976
# Cost in iteration 200: 0.20905317081581526
# Cost in iteration 400: 0.20905155243155188
# Cost in iteration 600: 0.2090509392973978
# Cost in iteration 800: 0.2090507478657844
# Cost in iteration 1000: 0.20905068646012703
# Final cost : 0.20905068646012703
# Compute control for a deterministic system
# Cost in iteration 0: 0.19562621411798362
# Cost in iteration 200: 0.1937301968989674
# Final cost : 0.1937301968989674
# Compute control for a deterministic system
# Cost in iteration 0: 0.1937301968989674
# Cost in iteration 200: 0.19338927848648924
# Final cost : 0.19338927848648924
# Compute control for a deterministic system
# Cost in iteration 0: 0.19338927848648924
# Converged in iteration 85 with cost 0.19338507793393322 because of vanishing difference
# Final cost : 0.19338507793393322
# Compute control for a deterministic system
# Cost in iteration 0: 0.19338507793393322
# Cost in iteration 200: 0.19338477387033529
# Cost in iteration 400: 0.19338477064958742
# Final cost : 0.19338477064958742
# Compute control for a deterministic system
# Cost in iteration 0: 0.19338477064958742
# Cost in iteration 200: 0.19338477061511106
# Converged in iteration 241 with cost 0.19338477061480822 because of step counter
# Final cost : 0.19338477061480822
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.2475135379852419
# Cost in iteration 200: 0.18014398931399941
# Final cost : 0.18014398931399941
# Compute control for a deterministic system
# Cost in iteration 0: 0.18014398931399941
# Cost in iteration 200: 0.1798328725282436
# Final cost : 0.1798328725282436
# Compute control for a deterministic system
# Cost in iteration 0: 0.1798328725282436
# Converged in iteration 76 with cost 0.17982935243046735 because of vanishing difference
# Final cost : 0.17982935243046735
# Compute control for a deterministic system
# Cost in iteration 0: 0.17982935243046735
# Cost in iteration 200: 0.17982900318970338
# Cost in iteration 400: 0.17982900091138523
# Final cost : 0.17982900091138523
# Compute control for a deterministic system
# Cost in iteration 0: 0.17982900091138523
# Converged in iteration 189 with cost 0.17982900089640327 because of vanishing difference
# Final cost : 0.17982900089640327
# Compute control for a deterministic system
# Cost in iteration 0: 0.20135032365697406
# Cost in iteration 200: 0.16636919526469982
# Final cost : 0.16636919526469982
# Compute control for a deterministic system
# Cost in iteration 0: 0.16636919526469982
# Cost in iteration 200: 0.16609538483646763
# Final cost : 0.16609538483646763
# Compute control for a deterministic system
# Cost in iteration 0: 0.16609538483646763
# Converged in iteration 61 with cost 0.16609329112023372 because of vanishing difference
# Final cost : 0.16609329112023372
# Compute control for a deterministic system
# Cost in iteration 0: 0.16609329112023372
# Cost in iteration 200: 0.16609287492590927
# Cost in iteration 400: 0.1660928734291424
# Final cost : 0.1660928734291424
# Compute control for a deterministic system
# Cost in iteration 0: 0.1660928734291424
# Converged in iteration 158 with cost 0.16609287342363258 because of step counter
# Final cost : 0.16609287342363258
# Compute control for a deterministic system
# Cost in iteration 0: 0.16020754569966753
# Cost in iteration 200: 0.15317051218783995
# Final cost : 0.15317051218783995
# Compute control for a deterministic system
# Cost in iteration 0: 0.15317051218783995
# Cost in iteration 200: 0.15297872794270004
# Final cost : 0.15297872794270004
# Compute control for a deterministic system
# Cost in iteration 0: 0.15297872794270004
# Cost in iteration 200: 0.15297830271992197
# Final cost : 0.15297830271992197
# Compute control for a deterministic system
# Cost in iteration 0: 0.15297830271992197
# Converged in iteration 197 with cost 0.15297830268891635 because of step counter
# Final cost : 0.15297830268891635
# Compute control for a deterministic system
# Cost in iteration 0: 0.15297830268891635
# Converged in iteration 14 with cost 0.1529783026888865 because of step counter
# Final cost : 0.1529783026888865
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.16498447726973922
# Cost in iteration 200: 0.1398503572980663
# Final cost : 0.1398503572980663
# Compute control for a deterministic system
# Cost in iteration 0: 0.1398503572980663
# Cost in iteration 200: 0.13968641440864543
# Final cost : 0.13968641440864543
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968641440864543
# Cost in iteration 200: 0.13968614701745938
# Final cost : 0.13968614701745938
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968614701745938
# Converged in iteration 125 with cost 0.13968614701215532 because of step counter
# Final cost : 0.13968614701215532
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968614701215532
# Converged in iteration 10 with cost 0.13968614701211718 because of step counter
# Final cost : 0.13968614701211718
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.16659759195503235
# Cost in iteration 200: 0.12712487948630521
# Final cost : 0.12712487948630521
# Compute control for a deterministic system
# Cost in iteration 0: 0.12712487948630521
# Cost in iteration 200: 0.12699497479709124
# Final cost : 0.12699497479709124
# Compute control for a deterministic system
# Cost in iteration 0: 0.12699497479709124
# Converged in iteration 2 with cost 0.12699494556579147 because of vanishing difference
# Final cost : 0.12699494556579147
# Compute control for a deterministic system
# Cost in iteration 0: 0.12699494556579147
# Cost in iteration 200: 0.12699488835117476
# Converged in iteration 336 with cost 0.12699488833805792 because of step counter
# Final cost : 0.12699488833805792
# Compute control for a deterministic system
# Cost in iteration 0: 0.12699488833805792
# Converged in iteration 1 with cost 0.12699488833805792 because of step counter
# Final cost : 0.12699488833805792
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.1435962101982326
# Cost in iteration 200: 0.11422737105531365
# Final cost : 0.11422737105531365
# Compute control for a deterministic system
# Cost in iteration 0: 0.11422737105531365
# Converged in iteration 174 with cost 0.11413224875773213 because of vanishing difference
# Final cost : 0.11413224875773213
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413224875773213
# Cost in iteration 200: 0.11413213058005924
# Final cost : 0.11413213058005924
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413213058005924
# Converged in iteration 66 with cost 0.11413213057960667 because of step counter
# Final cost : 0.11413213057960667
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413213057960667
# Converged in iteration 2 with cost 0.1141321305796046 because of step counter
# Final cost : 0.1141321305796046
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.15328468051416444
# Cost in iteration 200: 0.10191341395458607
# Final cost : 0.10191341395458607
# Compute control for a deterministic system
# Cost in iteration 0: 0.10191341395458607
# Converged in iteration 140 with cost 0.10185181717790431 because of vanishing difference
# Final cost : 0.10185181717790431
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185181717790431
# Cost in iteration 200: 0.10185177172381035
# Final cost : 0.10185177172381035
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185177172381035
# Converged in iteration 30 with cost 0.1018517717237361 because of step counter
# Final cost : 0.1018517717237361
# Compute control for a deterministic system
# Cost in iteration 0: 0.1018517717237361
# Converged in iteration 2 with cost 0.10185177172373495 because of step counter
# Final cost : 0.10185177172373495
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.10192363791952608
# Cost in iteration 200: 0.08943830553550236
# Final cost : 0.08943830553550236
# Compute control for a deterministic system
# Cost in iteration 0: 0.08943830553550236
# Converged in iteration 72 with cost 0.08940729853269232 because of vanishing difference
# Final cost : 0.08940729853269232
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940729853269232
# Cost in iteration 200: 0.08940717543057956
# Final cost : 0.08940717543057956
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717543057956
# Converged in iteration 19 with cost 0.08940717543054441 because of step counter
# Final cost : 0.08940717543054441
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717543054441
# Converged in iteration 1 with cost 0.08940717543054441 because of step counter
# Final cost : 0.08940717543054441
# -----------------------------------------------
# 0 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.08811004023269375
# Cost in iteration 200: 0.0775430166981914
# Final cost : 0.0775430166981914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0775430166981914
# Converged in iteration 57 with cost 0.07752892730419218 because of vanishing difference
# Final cost : 0.07752892730419218
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752892730419218
# Converged in iteration 157 with cost 0.07752886350336925 because of vanishing difference
# Final cost : 0.07752886350336925
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886350336925
# Converged in iteration 10 with cost 0.07752886350335436 because of step counter
# Final cost : 0.07752886350335436
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886350335436
# Converged in iteration 3 with cost 0.07752886350335239 because of step counter
# Final cost : 0.07752886350335239
# Compute control for a deterministic system
# Cost in iteration 0: 0.10899904233204759
# Cost in iteration 200: 0.06550535942904438
# Final cost : 0.06550535942904438
# Compute control for a deterministic system
# Cost in iteration 0: 0.06550535942904438
# Converged in iteration 69 with cost 0.06549655195704693 because of vanishing difference
# Final cost : 0.06549655195704693
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549655195704693
# Converged in iteration 130 with cost 0.06549652425579383 because of step counter
# Final cost : 0.06549652425579383
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652425579383
# Converged in iteration 1 with cost 0.06549652425579383 because of step counter
# Final cost : 0.06549652425579383
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652425579383
# Converged in iteration 1 with cost 0.06549652425579383 because of step counter
# Final cost : 0.06549652425579383
# -----------------------------------------------
# 0 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300070612424567
# Cost in iteration 200: 0.05402142996446084
# Final cost : 0.05402142996446084
# Compute control for a deterministic system
# Cost in iteration 0: 0.05402142996446084
# Converged in iteration 51 with cost 0.05401912345576216 because of vanishing difference
# Final cost : 0.05401912345576216
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401912345576216
# Converged in iteration 101 with cost 0.05401911661333924 because of step counter
# Final cost : 0.05401911661333924
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911661333924
# Converged in iteration 1 with cost 0.05401911661333924 because of step counter
# Final cost : 0.05401911661333924
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911661333924
# Converged in iteration 2 with cost 0.05401911661333709 because of step counter
# Final cost : 0.05401911661333709
# Compute control for a deterministic system
# Cost in iteration 0: 0.07333490261509103
# Cost in iteration 200: 0.042404813269004984
# Final cost : 0.042404813269004984
# Compute control for a deterministic system
# Cost in iteration 0: 0.042404813269004984
# Converged in iteration 14 with cost 0.042404659543627446 because of vanishing difference
# Final cost : 0.042404659543627446
# Compute control for a deterministic system
# Cost in iteration 0: 0.042404659543627446
# Converged in iteration 68 with cost 0.0424046574592788 because of step counter
# Final cost : 0.0424046574592788
# Compute control for a deterministic system
# Cost in iteration 0: 0.0424046574592788
# Converged in iteration 1 with cost 0.0424046574592788 because of step counter
# Final cost : 0.0424046574592788
# Compute control for a deterministic system
# Cost in iteration 0: 0.0424046574592788
# Converged in iteration 1 with cost 0.0424046574592788 because of step counter
# Final cost : 0.0424046574592788
# Compute control for a deterministic system
# Cost in iteration 0: 0.06704370847368382
# Cost in iteration 200: 0.03134356708016428
# Final cost : 0.03134356708016428
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356708016428
# Converged in iteration 5 with cost 0.03134356356483989 because of vanishing difference
# Final cost : 0.03134356356483989
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356356483989
# Converged in iteration 38 with cost 0.03134356327925529 because of step counter
# Final cost : 0.03134356327925529
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356327925529
# Converged in iteration 1 with cost 0.03134356327925529 because of step counter
# Final cost : 0.03134356327925529
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356327925529
# Converged in iteration 1 with cost 0.03134356327925529 because of step counter
# Final cost : 0.03134356327925529
# -----------------------------------------------
# 0 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.05030622940934291
# Converged in iteration 166 with cost 0.020179793981714312 because of vanishing difference
# Final cost : 0.020179793981714312
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179793981714312
# Converged in iteration 19 with cost 0.020179793922959103 because of step counter
# Final cost : 0.020179793922959103
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179793922959103
# Converged in iteration 1 with cost 0.020179793922959103 because of step counter
# Final cost : 0.020179793922959103
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179793922959103
# Converged in iteration 2 with cost 0.02017979392295761 because of step counter
# Final cost : 0.02017979392295761
# Compute control for a deterministic system
# Cost in iteration 0: 0.02017979392295761
# Converged in iteration 1 with cost 0.02017979392295761 because of step counter
# Final cost : 0.02017979392295761
# -----------------------------------------------
# 0 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.03366757515774091
# Converged in iteration 67 with cost 0.009596320949531388 because of vanishing difference
# Final cost : 0.009596320949531388
# Compute control for a deterministic system
# Cost in iteration 0: 0.009596320949531388
# Converged in iteration 9 with cost 0.00959632090077943 because of step counter
# Final cost : 0.00959632090077943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00959632090077943
# Converged in iteration 1 with cost 0.00959632090077943 because of step counter
# Final cost : 0.00959632090077943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00959632090077943
# Converged in iteration 1 with cost 0.00959632090077943 because of step counter
# Final cost : 0.00959632090077943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00959632090077943
# Converged in iteration 1 with cost 0.00959632090077943 because of step counter
# Final cost : 0.00959632090077943
# -----------------------------------------------
# 0 found better solution,  39
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.04765503921054874
# Converged in iteration 73 with cost 0.020179795282719605 because of vanishing difference
# Final cost : 0.020179795282719605
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179795282719605
# Converged in iteration 33 with cost 0.020179795131280657 because of step counter
# Final cost : 0.020179795131280657
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179795131280657
# Converged in iteration 3 with cost 0.02017979513127949 because of step counter
# Final cost : 0.02017979513127949
# Compute control for a deterministic system
# Cost in iteration 0: 0.02017979513127949
# Converged in iteration 1 with cost 0.02017979513127949 because of step counter
# Final cost : 0.02017979513127949
# Compute control for a deterministic system
# Cost in iteration 0: 0.05877792627546273
# Converged in iteration 85 with cost 0.03134356264574316 because of step counter
# Final cost : 0.03134356264574316
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356264574316
# Converged in iteration 1 with cost 0.03134356264574316 because of step counter
# Final cost : 0.03134356264574316
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356264574316
# Converged in iteration 1 with cost 0.03134356264574316 because of step counter
# Final cost : 0.03134356264574316
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356264574316
# Converged in iteration 1 with cost 0.03134356264574316 because of step counter
# Final cost : 0.03134356264574316
# -----------------------------------------------
# 1 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.06372834876666524
# Converged in iteration 108 with cost 0.04240465625978918 because of step counter
# Final cost : 0.04240465625978918
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240465625978918
# Converged in iteration 2 with cost 0.04240465625978812 because of step counter
# Final cost : 0.04240465625978812
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240465625978812
# Converged in iteration 1 with cost 0.04240465625978812 because of step counter
# Final cost : 0.04240465625978812
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240465625978812
# Converged in iteration 1 with cost 0.04240465625978812 because of step counter
# Final cost : 0.04240465625978812
# -----------------------------------------------
# 1 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.08654065121856888
# Converged in iteration 150 with cost 0.05401911541070435 because of vanishing difference
# Final cost : 0.05401911541070435
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911541070435
# Converged in iteration 8 with cost 0.05401911541069487 because of step counter
# Final cost : 0.05401911541069487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911541069487
# Converged in iteration 1 with cost 0.05401911541069487 because of step counter
# Final cost : 0.05401911541069487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911541069487
# Converged in iteration 1 with cost 0.05401911541069487 because of step counter
# Final cost : 0.05401911541069487
# -----------------------------------------------
# 1 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.08231142013619729
# Converged in iteration 143 with cost 0.06549653017188091 because of vanishing difference
# Final cost : 0.06549653017188091
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549653017188091
# Converged in iteration 118 with cost 0.06549652426658338 because of step counter
# Final cost : 0.06549652426658338
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652426658338
# Converged in iteration 2 with cost 0.06549652426657998 because of step counter
# Final cost : 0.06549652426657998
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652426657998
# Converged in iteration 1 with cost 0.06549652426657998 because of step counter
# Final cost : 0.06549652426657998
# Compute control for a deterministic system
# Cost in iteration 0: 0.09241467591692193
# Converged in iteration 177 with cost 0.07752886463052899 because of vanishing difference
# Final cost : 0.07752886463052899
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886463052899
# Converged in iteration 117 with cost 0.07752886346813459 because of step counter
# Final cost : 0.07752886346813459
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886346813459
# Converged in iteration 2 with cost 0.07752886346813298 because of step counter
# Final cost : 0.07752886346813298
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886346813298
# Converged in iteration 1 with cost 0.07752886346813298 because of step counter
# Final cost : 0.07752886346813298
# Compute control for a deterministic system
# Cost in iteration 0: 0.10686693536664388
# Converged in iteration 183 with cost 0.08940718574995997 because of vanishing difference
# Final cost : 0.08940718574995997
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940718574995997
# Converged in iteration 184 with cost 0.08940717526490434 because of step counter
# Final cost : 0.08940717526490434
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717526490434
# Converged in iteration 1 with cost 0.08940717526490434 because of step counter
# Final cost : 0.08940717526490434
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717526490434
# Converged in iteration 1 with cost 0.08940717526490434 because of step counter
# Final cost : 0.08940717526490434
# -----------------------------------------------
# 1 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.14548945744987543
# Cost in iteration 200: 0.10185180179863516
# Final cost : 0.10185180179863516
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185180179863516
# Cost in iteration 200: 0.10185177272655832
# Final cost : 0.10185177272655832
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185177272655832
# Converged in iteration 18 with cost 0.10185177272650857 because of step counter
# Final cost : 0.10185177272650857
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185177272650857
# Converged in iteration 1 with cost 0.10185177272650857 because of step counter
# Final cost : 0.10185177272650857
# Compute control for a deterministic system
# Cost in iteration 0: 0.15088894057088542
# Cost in iteration 200: 0.11413241972207089
# Final cost : 0.11413241972207089
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413241972207089
# Cost in iteration 200: 0.11413213505305436
# Final cost : 0.11413213505305436
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413213505305436
# Converged in iteration 75 with cost 0.114132135051542 because of step counter
# Final cost : 0.114132135051542
# Compute control for a deterministic system
# Cost in iteration 0: 0.114132135051542
# Converged in iteration 2 with cost 0.1141321350515404 because of step counter
# Final cost : 0.1141321350515404
# Compute control for a deterministic system
# Cost in iteration 0: 0.1410482524398866
# Cost in iteration 200: 0.1269952969962735
# Final cost : 0.1269952969962735
# Compute control for a deterministic system
# Cost in iteration 0: 0.1269952969962735
# Converged in iteration 26 with cost 0.12699500677634265 because of vanishing difference
# Final cost : 0.12699500677634265
# Compute control for a deterministic system
# Cost in iteration 0: 0.12699500677634265
# Cost in iteration 200: 0.12699488812724055
# Converged in iteration 355 with cost 0.1269948881008797 because of step counter
# Final cost : 0.1269948881008797
# Compute control for a deterministic system
# Cost in iteration 0: 0.1269948881008797
# Converged in iteration 2 with cost 0.12699488810087933 because of vanishing difference
# Final cost : 0.12699488810087933
# -----------------------------------------------
# 1 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.16852653082580007
# Cost in iteration 200: 0.13968714468234952
# Final cost : 0.13968714468234952
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968714468234952
# Converged in iteration 68 with cost 0.13968620284811678 because of vanishing difference
# Final cost : 0.13968620284811678
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968620284811678
# Cost in iteration 200: 0.13968615397450018
# ...
# Cost in iteration 200: 0.23028133239164095
# Final cost : 0.23028133239164095
# Compute control for a deterministic system
# Cost in iteration 0: 0.23028133239164095
# Cost in iteration 200: 0.2080060884838739
# Final cost : 0.2080060884838739
# Compute control for a deterministic system
# Cost in iteration 0: 0.2080060884838739
# Cost in iteration 200: 0.20759301558740686
# Final cost : 0.20759301558740686
# Compute control for a deterministic system
# Cost in iteration 0: 0.20759301558740686
# Cost in iteration 200: 0.20759258991775648
# Cost in iteration 400: 0.20759258550927495
# Final cost : 0.20759258550927495
# Compute control for a deterministic system
# Cost in iteration 0: 0.20759258550927495
# Cost in iteration 200: 0.2075925854762996
# Converged in iteration 255 with cost 0.20759258547578108 because of step counter
# Final cost : 0.20759258547578108
# Compute control for a deterministic system
# Cost in iteration 0: 2.783165367097849
# Cost in iteration 200: 0.21105932953101178
# Final cost : 0.21105932953101178
# Compute control for a deterministic system
# Cost in iteration 0: 0.21105932953101178
# Cost in iteration 200: 0.1943081221386058
# Final cost : 0.1943081221386058
# Compute control for a deterministic system
# Cost in iteration 0: 0.1943081221386058
# Converged in iteration 196 with cost 0.1933853461991174 because of vanishing difference
# Final cost : 0.1933853461991174
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933853461991174
# Cost in iteration 200: 0.19338477715826452
# Cost in iteration 400: 0.19338477220746206
# Final cost : 0.19338477220746206
# Compute control for a deterministic system
# Cost in iteration 0: 0.19338477220746206
# Cost in iteration 200: 0.19338477215174568
# Converged in iteration 291 with cost 0.19338477215087124 because of step counter
# Final cost : 0.19338477215087124
# Compute control for a deterministic system
# Cost in iteration 0: 2.6677564038985477
# Cost in iteration 200: 0.19376838556146184
# Final cost : 0.19376838556146184
# Compute control for a deterministic system
# Cost in iteration 0: 0.19376838556146184
# Cost in iteration 200: 0.18006871325412982
# Final cost : 0.18006871325412982
# Compute control for a deterministic system
# Cost in iteration 0: 0.18006871325412982
# Converged in iteration 166 with cost 0.17982967324652022 because of vanishing difference
# Final cost : 0.17982967324652022
# Compute control for a deterministic system
# Cost in iteration 0: 0.17982967324652022
# Cost in iteration 200: 0.1798290060345373
# Cost in iteration 400: 0.17982900182024136
# Final cost : 0.17982900182024136
# Compute control for a deterministic system
# Cost in iteration 0: 0.17982900182024136
# Cost in iteration 200: 0.1798290017921178
# Converged in iteration 243 with cost 0.1798290017918642 because of step counter
# Final cost : 0.1798290017918642
# Compute control for a deterministic system
# Cost in iteration 0: 2.5265631673121716
# Cost in iteration 200: 0.1771349942900591
# Final cost : 0.1771349942900591
# Compute control for a deterministic system
# Cost in iteration 0: 0.1771349942900591
# Cost in iteration 200: 0.16624014035385415
# Final cost : 0.16624014035385415
# Compute control for a deterministic system
# Cost in iteration 0: 0.16624014035385415
# Converged in iteration 149 with cost 0.16609340884742968 because of vanishing difference
# Final cost : 0.16609340884742968
# Compute control for a deterministic system
# Cost in iteration 0: 0.16609340884742968
# Cost in iteration 200: 0.16609287793927055
# Cost in iteration 400: 0.16609287604519993
# Final cost : 0.16609287604519993
# Compute control for a deterministic system
# Cost in iteration 0: 0.16609287604519993
# Converged in iteration 158 with cost 0.16609287603838832 because of vanishing difference
# Final cost : 0.16609287603838832
# Compute control for a deterministic system
# Cost in iteration 0: 2.3686338771454265
# Cost in iteration 200: 0.16190120388649443
# Final cost : 0.16190120388649443
# Compute control for a deterministic system
# Cost in iteration 0: 0.16190120388649443
# Cost in iteration 200: 0.15303724723228562
# Final cost : 0.15303724723228562
# Compute control for a deterministic system
# Cost in iteration 0: 0.15303724723228562
# Converged in iteration 124 with cost 0.15297888401235765 because of vanishing difference
# Final cost : 0.15297888401235765
# Compute control for a deterministic system
# Cost in iteration 0: 0.15297888401235765
# Cost in iteration 200: 0.15297831148860666
# Cost in iteration 400: 0.152978310539886
# Final cost : 0.152978310539886
# Compute control for a deterministic system
# Cost in iteration 0: 0.152978310539886
# Converged in iteration 117 with cost 0.1529783105382679 because of step counter
# Final cost : 0.1529783105382679
# Compute control for a deterministic system
# Cost in iteration 0: 2.185541900965189
# Cost in iteration 200: 0.14693990183539513
# Final cost : 0.14693990183539513
# Compute control for a deterministic system
# Cost in iteration 0: 0.14693990183539513
# Cost in iteration 200: 0.13971419729315085
# Final cost : 0.13971419729315085
# Compute control for a deterministic system
# Cost in iteration 0: 0.13971419729315085
# Converged in iteration 94 with cost 0.13968668601674478 because of vanishing difference
# Final cost : 0.13968668601674478
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968668601674478
# Cost in iteration 200: 0.13968615482556135
# Cost in iteration 400: 0.13968615447717328
# Final cost : 0.13968615447717328
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968615447717328
# Converged in iteration 30 with cost 0.13968615447693597 because of step counter
# Final cost : 0.13968615447693597
# Compute control for a deterministic system
# Cost in iteration 0: 1.9896624403616578
# Cost in iteration 200: 0.1330228154212506
# Final cost : 0.1330228154212506
# Compute control for a deterministic system
# Cost in iteration 0: 0.1330228154212506
# Cost in iteration 200: 0.12700140945463467
# Final cost : 0.12700140945463467
# Compute control for a deterministic system
# Cost in iteration 0: 0.12700140945463467
# Converged in iteration 51 with cost 0.12699558302711134 because of vanishing difference
# Final cost : 0.12699558302711134
# Compute control for a deterministic system
# Cost in iteration 0: 0.12699558302711134
# Cost in iteration 200: 0.1269948876534575
# Converged in iteration 397 with cost 0.126994887502358 because of step counter
# Final cost : 0.126994887502358
# Compute control for a deterministic system
# Cost in iteration 0: 0.126994887502358
# Converged in iteration 1 with cost 0.126994887502358 because of step counter
# Final cost : 0.126994887502358
# Compute control for a deterministic system
# Cost in iteration 0: 1.771497926140848
# Cost in iteration 200: 0.11914304308263612
# Final cost : 0.11914304308263612
# Compute control for a deterministic system
# Cost in iteration 0: 0.11914304308263612
# Cost in iteration 200: 0.11413439728889715
# Final cost : 0.11413439728889715
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413439728889715
# Converged in iteration 62 with cost 0.11413221624549655 because of vanishing difference
# Final cost : 0.11413221624549655
# Compute control for a deterministic system
# Cost in iteration 0: 0.11413221624549655
# Cost in iteration 200: 0.11413214020006739
# Converged in iteration 310 with cost 0.1141321401957455 because of step counter
# Final cost : 0.1141321401957455
# Compute control for a deterministic system
# Cost in iteration 0: 0.1141321401957455
# Converged in iteration 2 with cost 0.11413214019574465 because of step counter
# Final cost : 0.11413214019574465
# Compute control for a deterministic system
# Cost in iteration 0: 1.5470265262244225
# Cost in iteration 200: 0.10604141025517626
# Final cost : 0.10604141025517626
# Compute control for a deterministic system
# Cost in iteration 0: 0.10604141025517626
# Cost in iteration 200: 0.10185197104757689
# Final cost : 0.10185197104757689
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185197104757689
# Cost in iteration 200: 0.10185177266083992
# Final cost : 0.10185177266083992
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185177266083992
# Converged in iteration 51 with cost 0.10185177266051929 because of step counter
# Final cost : 0.10185177266051929
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185177266051929
# Converged in iteration 1 with cost 0.10185177266051929 because of step counter
# Final cost : 0.10185177266051929
# Compute control for a deterministic system
# Cost in iteration 0: 1.3070132646214845
# Cost in iteration 200: 0.09283105935580481
# Final cost : 0.09283105935580481
# Compute control for a deterministic system
# Cost in iteration 0: 0.09283105935580481
# Converged in iteration 167 with cost 0.08940724746995529 because of vanishing difference
# Final cost : 0.08940724746995529
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940724746995529
# Cost in iteration 200: 0.08940717495763724
# Final cost : 0.08940717495763724
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717495763724
# Converged in iteration 8 with cost 0.08940717495761616 because of step counter
# Final cost : 0.08940717495761616
# Compute control for a deterministic system
# Cost in iteration 0: 0.08940717495761616
# Converged in iteration 1 with cost 0.08940717495761616 because of step counter
# Final cost : 0.08940717495761616
# Compute control for a deterministic system
# Cost in iteration 0: 1.0710029229241544
# Cost in iteration 200: 0.0802497971022019
# Final cost : 0.0802497971022019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802497971022019
# Converged in iteration 186 with cost 0.07752886955447483 because of vanishing difference
# Final cost : 0.07752886955447483
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886955447483
# Converged in iteration 138 with cost 0.07752886313367696 because of step counter
# Final cost : 0.07752886313367696
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886313367696
# Converged in iteration 1 with cost 0.07752886313367696 because of step counter
# Final cost : 0.07752886313367696
# Compute control for a deterministic system
# Cost in iteration 0: 0.07752886313367696
# Converged in iteration 1 with cost 0.07752886313367696 because of step counter
# Final cost : 0.07752886313367696
# Compute control for a deterministic system
# Cost in iteration 0: 0.8317669912343415
# Cost in iteration 200: 0.0675022356707104
# Final cost : 0.0675022356707104
# Compute control for a deterministic system
# Cost in iteration 0: 0.0675022356707104
# Converged in iteration 129 with cost 0.06549654129716141 because of vanishing difference
# Final cost : 0.06549654129716141
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549654129716141
# Converged in iteration 124 with cost 0.06549652484370692 because of step counter
# Final cost : 0.06549652484370692
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652484370692
# Converged in iteration 2 with cost 0.06549652484370648 because of step counter
# Final cost : 0.06549652484370648
# Compute control for a deterministic system
# Cost in iteration 0: 0.06549652484370648
# Converged in iteration 1 with cost 0.06549652484370648 because of step counter
# Final cost : 0.06549652484370648
# Compute control for a deterministic system
# Cost in iteration 0: 0.6115895638181063
# Cost in iteration 200: 0.055312145196834375
# Final cost : 0.055312145196834375
# Compute control for a deterministic system
# Cost in iteration 0: 0.055312145196834375
# Converged in iteration 92 with cost 0.05401911925503954 because of vanishing difference
# Final cost : 0.05401911925503954
# Compute control for a deterministic system
# Cost in iteration 0: 0.05401911925503954
# Converged in iteration 93 with cost 0.054019116323895666 because of step counter
# Final cost : 0.054019116323895666
# Compute control for a deterministic system
# Cost in iteration 0: 0.054019116323895666
# Converged in iteration 1 with cost 0.054019116323895666 because of step counter
# Final cost : 0.054019116323895666
# Compute control for a deterministic system
# Cost in iteration 0: 0.054019116323895666
# Converged in iteration 1 with cost 0.054019116323895666 because of step counter
# Final cost : 0.054019116323895666
# Compute control for a deterministic system
# Cost in iteration 0: 0.406832446660535
# Cost in iteration 200: 0.04295394987443793
# Final cost : 0.04295394987443793
# Compute control for a deterministic system
# Cost in iteration 0: 0.04295394987443793
# Converged in iteration 64 with cost 0.04240465891318008 because of vanishing difference
# Final cost : 0.04240465891318008
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240465891318008
# Converged in iteration 67 with cost 0.042404657514889976 because of step counter
# Final cost : 0.042404657514889976
# Compute control for a deterministic system
# Cost in iteration 0: 0.042404657514889976
# Converged in iteration 1 with cost 0.042404657514889976 because of step counter
# Final cost : 0.042404657514889976
# Compute control for a deterministic system
# Cost in iteration 0: 0.042404657514889976
# Converged in iteration 2 with cost 0.04240465751488904 because of step counter
# Final cost : 0.04240465751488904
# Compute control for a deterministic system
# Cost in iteration 0: 0.23921944308692641
# Cost in iteration 200: 0.031344015806047475
# Final cost : 0.031344015806047475
# Compute control for a deterministic system
# Cost in iteration 0: 0.031344015806047475
# Converged in iteration 25 with cost 0.0313435653414242 because of vanishing difference
# Final cost : 0.0313435653414242
# Compute control for a deterministic system
# Cost in iteration 0: 0.0313435653414242
# Converged in iteration 55 with cost 0.03134356417629579 because of step counter
# Final cost : 0.03134356417629579
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356417629579
# Converged in iteration 2 with cost 0.03134356417629535 because of step counter
# Final cost : 0.03134356417629535
# Compute control for a deterministic system
# Cost in iteration 0: 0.03134356417629535
# Converged in iteration 1 with cost 0.03134356417629535 because of step counter
# Final cost : 0.03134356417629535
# Compute control for a deterministic system
# Cost in iteration 0: 0.10796847593614224
# Cost in iteration 200: 0.020179794705421996
# Final cost : 0.020179794705421996
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179794705421996
# Converged in iteration 2 with cost 0.020179794570954996 because of vanishing difference
# Final cost : 0.020179794570954996
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179794570954996
# Converged in iteration 19 with cost 0.020179794528081496 because of step counter
# Final cost : 0.020179794528081496
# Compute control for a deterministic system
# Cost in iteration 0: 0.020179794528081496
# Converged in iteration 2 with cost 0.02017979452808128 because of step counter
# Final cost : 0.02017979452808128
# Compute control for a deterministic system
# Cost in iteration 0: 0.02017979452808128
# Converged in iteration 1 with cost 0.02017979452808128 because of step counter
# Final cost : 0.02017979452808128
# Compute control for a deterministic system
# Cost in iteration 0: 0.028153551398382496
# Converged in iteration 105 with cost 0.009596320937386132 because of vanishing difference
# Final cost : 0.009596320937386132
# Compute control for a deterministic system
# Cost in iteration 0: 0.009596320937386132
# Converged in iteration 10 with cost 0.009596320901685773 because of step counter
# Final cost : 0.009596320901685773
# Compute control for a deterministic system
# Cost in iteration 0: 0.009596320901685773
# Converged in iteration 2 with cost 0.0095963209016852 because of step counter
# Final cost : 0.0095963209016852
# Compute control for a deterministic system
# Cost in iteration 0: 0.0095963209016852
# Converged in iteration 1 with cost 0.0095963209016852 because of step counter
# Final cost : 0.0095963209016852
# Compute control for a deterministic system
# Cost in iteration 0: 0.0095963209016852
# Converged in iteration 2 with cost 0.009596320901683997 because of step counter
# Final cost : 0.009596320901683997

# %%
save(results_min)

# %%
ind_list = [5,10,15,20,25,30,35]

fig, ax = plt.subplots(7, 1, figsize=(6,20), sharey=True, sharex=True)
    
for i in range(len(ind_list)):
    i_shift = ind_list[i]
    ax[i].plot(results_min["control"][1][i_shift][0,0,:], color="red")
    ax[i].plot(results_min["control"][1][i_shift][0,1,:], color="blue")

plt.show()
