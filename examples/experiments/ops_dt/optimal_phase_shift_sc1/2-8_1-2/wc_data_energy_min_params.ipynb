# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,1337], wc.inh[0,1337]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 13.399117647058825
# minima =  [ 1242  2582  3922  5262  6602  7942  9281 10621 11961 13301 14641 15981
#  17321 18661 20000 21340 22680 24020 25360 26700 28040 29380 30719 32059
#  33399 34739 36079 37419 38759 40099 41438 42778 44118 45458 46798 48138
#  49478]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w1, w_1D=0., print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s2_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s2_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l2_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l2_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.026340246458761155
# Cost in iteration 200: 0.00013924921241976416
# Final cost : 0.00013924921241976416
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013924921241976416
# Cost in iteration 200: 0.00013778326477320417
# Final cost : 0.00013778326477320417
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013778326477320417
# Cost in iteration 200: 0.000137324087045841
# Final cost : 0.000137324087045841
# Compute control for a deterministic system
# Cost in iteration 0: 0.000137324087045841
# Cost in iteration 200: 0.00013719398228952988
# Cost in iteration 400: 0.00013714104923222989
# Final cost : 0.00013714104923222989
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013714104923222989
# Cost in iteration 200: 0.00013711871422917888
# Cost in iteration 400: 0.00013710865442206058
# Cost in iteration 600: 0.00013710468866608757
# Cost in iteration 800: 0.00013710317206512231
# Cost in iteration 1000: 0.0001371025571421204
# Final cost : 0.0001371025571421204
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.027911799625672907
# Cost in iteration 200: 0.000306033715263738
# Final cost : 0.000306033715263738
# Compute control for a deterministic system
# Cost in iteration 0: 0.000306033715263738
# Cost in iteration 200: 0.0003031411201433739
# Final cost : 0.0003031411201433739
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003031411201433739
# Cost in iteration 200: 0.0003021779452835467
# Final cost : 0.0003021779452835467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003021779452835467
# Cost in iteration 200: 0.0003018771499398291
# Cost in iteration 400: 0.00030175321956707853
# Final cost : 0.00030175321956707853
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030175321956707853
# Cost in iteration 200: 0.00030169753685420835
# Cost in iteration 400: 0.0003016720382319552
# Cost in iteration 600: 0.0003016606661532962
# Cost in iteration 800: 0.0003016560060665476
# Cost in iteration 1000: 0.0003016538772175147
# Final cost : 0.0003016538772175147
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.02320451407750765
# Cost in iteration 200: 0.0005423828683012191
# Final cost : 0.0005423828683012191
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005423828683012191
# Cost in iteration 200: 0.0005373981368960238
# Final cost : 0.0005373981368960238
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005373981368960238
# Cost in iteration 200: 0.0005357765216911198
# Final cost : 0.0005357765216911198
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005357765216911198
# Cost in iteration 200: 0.0005352278031182287
# Cost in iteration 400: 0.0005349910736602395
# Final cost : 0.0005349910736602395
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005349910736602395
# Cost in iteration 200: 0.0005348713537325031
# Cost in iteration 400: 0.000534809902787475
# Cost in iteration 600: 0.0005347874356408388
# Cost in iteration 800: 0.0005347783886351702
# Cost in iteration 1000: 0.0005347742246863276
# Final cost : 0.0005347742246863276
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.023194276250625336
# Cost in iteration 200: 0.0008314747255168375
# Final cost : 0.0008314747255168375
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008314747255168375
# Cost in iteration 200: 0.0008241944327490724
# Final cost : 0.0008241944327490724
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008241944327490724
# Cost in iteration 200: 0.0008218215422537686
# Final cost : 0.0008218215422537686
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008218215422537686
# Cost in iteration 200: 0.0008210739541897752
# Cost in iteration 400: 0.000820732932973583
# Final cost : 0.000820732932973583
# Compute control for a deterministic system
# Cost in iteration 0: 0.000820732932973583
# Cost in iteration 200: 0.0008205704403622288
# Cost in iteration 400: 0.0008204564037720875
# Cost in iteration 600: 0.0008204013024850809
# Cost in iteration 800: 0.0008203802473726443
# Cost in iteration 1000: 0.0008203708204277795
# Final cost : 0.0008203708204277795
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.024131742194012346
# Cost in iteration 200: 0.0011899727343175758
# Final cost : 0.0011899727343175758
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011899727343175758
# Cost in iteration 200: 0.001178950399847347
# Final cost : 0.001178950399847347
# Compute control for a deterministic system
# Cost in iteration 0: 0.001178950399847347
# Cost in iteration 200: 0.0011756229415959523
# Final cost : 0.0011756229415959523
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011756229415959523
# Cost in iteration 200: 0.001174513609293805
# Cost in iteration 400: 0.0011739840803747835
# Final cost : 0.0011739840803747835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011739840803747835
# Cost in iteration 200: 0.0011736340699504664
# Cost in iteration 400: 0.0011734758152165588
# Cost in iteration 600: 0.0011733995613967974
# Cost in iteration 800: 0.001173360458093889
# Cost in iteration 1000: 0.001173340340115216
# Final cost : 0.001173340340115216
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.023637483331663618
# Cost in iteration 200: 0.0015916201165397307
# Final cost : 0.0015916201165397307
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015916201165397307
# Cost in iteration 200: 0.001578068863439772
# Final cost : 0.001578068863439772
# Compute control for a deterministic system
# Cost in iteration 0: 0.001578068863439772
# Cost in iteration 200: 0.0015737098057902435
# Final cost : 0.0015737098057902435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015737098057902435
# Cost in iteration 200: 0.001572351016461831
# Cost in iteration 400: 0.0015716376692470084
# Final cost : 0.0015716376692470084
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015716376692470084
# Cost in iteration 200: 0.001571128039525216
# Cost in iteration 400: 0.0015708864864596207
# Cost in iteration 600: 0.0015707518111650726
# Cost in iteration 800: 0.0015706813947172526
# Cost in iteration 1000: 0.0015706459596490964
# Final cost : 0.0015706459596490964
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.03605501040504525
# Cost in iteration 200: 0.002064133739382638
# Final cost : 0.002064133739382638
# Compute control for a deterministic system
# Cost in iteration 0: 0.002064133739382638
# Cost in iteration 200: 0.0020435679109876673
# Final cost : 0.0020435679109876673
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020435679109876673
# Cost in iteration 200: 0.0020384291092801726
# Final cost : 0.0020384291092801726
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020384291092801726
# Cost in iteration 200: 0.002036576906121486
# Cost in iteration 400: 0.00203560104333145
# Final cost : 0.00203560104333145
# Compute control for a deterministic system
# Cost in iteration 0: 0.00203560104333145
# Cost in iteration 200: 0.0020348218293189282
# Cost in iteration 400: 0.002034431576906544
# Cost in iteration 600: 0.002034237387355912
# Cost in iteration 800: 0.002034132710390132
# Cost in iteration 1000: 0.002034061681175163
# Final cost : 0.002034061681175163
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.04862267342682558
# Cost in iteration 200: 0.002572129690752423
# Final cost : 0.002572129690752423
# Compute control for a deterministic system
# Cost in iteration 0: 0.002572129690752423
# Cost in iteration 200: 0.0025463853454598916
# Final cost : 0.0025463853454598916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025463853454598916
# Cost in iteration 200: 0.00254006886760218
# Final cost : 0.00254006886760218
# Compute control for a deterministic system
# Cost in iteration 0: 0.00254006886760218
# Cost in iteration 200: 0.002537680160494435
# Cost in iteration 400: 0.0025363663972379205
# Final cost : 0.0025363663972379205
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025363663972379205
# Cost in iteration 200: 0.0025353536462220205
# Cost in iteration 400: 0.0025347882374513572
# Cost in iteration 600: 0.0025344673622083543
# Cost in iteration 800: 0.00253426877341465
# Cost in iteration 1000: 0.00253414537010176
# Final cost : 0.00253414537010176
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.019074110017501568
# Cost in iteration 200: 0.003140013613448355
# Final cost : 0.003140013613448355
# Compute control for a deterministic system
# Cost in iteration 0: 0.003140013613448355
# Cost in iteration 200: 0.0031136610653131553
# Final cost : 0.0031136610653131553
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031136610653131553
# Cost in iteration 200: 0.0031064640431585164
# Final cost : 0.0031064640431585164
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031064640431585164
# Cost in iteration 200: 0.0031036337342132078
# Cost in iteration 400: 0.0031019774003262688
# Final cost : 0.0031019774003262688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031019774003262688
# Cost in iteration 200: 0.003100666603376761
# Cost in iteration 400: 0.003099867645561314
# Cost in iteration 600: 0.003099398140711731
# Cost in iteration 800: 0.0030990701919148948
# Cost in iteration 1000: 0.003098845127157769
# Final cost : 0.003098845127157769
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.06336401277081789
# Cost in iteration 200: 0.003750762732507826
# Final cost : 0.003750762732507826
# Compute control for a deterministic system
# Cost in iteration 0: 0.003750762732507826
# Cost in iteration 200: 0.00371006580269032
# Final cost : 0.00371006580269032
# Compute control for a deterministic system
# Cost in iteration 0: 0.00371006580269032
# Cost in iteration 200: 0.0037020415125198144
# Final cost : 0.0037020415125198144
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037020415125198144
# Cost in iteration 200: 0.003698624173977952
# Cost in iteration 400: 0.0036965608985137727
# Final cost : 0.0036965608985137727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036965608985137727
# Cost in iteration 200: 0.00369485638352525
# Cost in iteration 400: 0.0036938821006331493
# Cost in iteration 600: 0.0036932163867544345
# Cost in iteration 800: 0.0036927607562539373
# Cost in iteration 1000: 0.0036924296487003383
# Final cost : 0.0036924296487003383
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.047159733438274704
# Cost in iteration 200: 0.004410054620752999
# Final cost : 0.004410054620752999
# Compute control for a deterministic system
# Cost in iteration 0: 0.004410054620752999
# Cost in iteration 200: 0.004368868379207599
# Final cost : 0.004368868379207599
# Compute control for a deterministic system
# Cost in iteration 0: 0.004368868379207599
# Cost in iteration 200: 0.0043596433139311
# Final cost : 0.0043596433139311
# Compute control for a deterministic system
# Cost in iteration 0: 0.0043596433139311
# Cost in iteration 200: 0.004355717339683407
# Cost in iteration 400: 0.004353252648594397
# Final cost : 0.004353252648594397
# Compute control for a deterministic system
# Cost in iteration 0: 0.004353252648594397
# Cost in iteration 200: 0.004351186761135731
# Cost in iteration 400: 0.004349947700294369
# Cost in iteration 600: 0.004349029961668205
# Cost in iteration 800: 0.004348357980148271
# Cost in iteration 1000: 0.004347852225045345
# Final cost : 0.004347852225045345
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.03683740617127958
# Cost in iteration 200: 0.005084812141427396
# Final cost : 0.005084812141427396
# Compute control for a deterministic system
# Cost in iteration 0: 0.005084812141427396
# Cost in iteration 200: 0.005046491519246748
# Final cost : 0.005046491519246748
# Compute control for a deterministic system
# Cost in iteration 0: 0.005046491519246748
# Cost in iteration 200: 0.005036835042824715
# Final cost : 0.005036835042824715
# Compute control for a deterministic system
# Cost in iteration 0: 0.005036835042824715
# Cost in iteration 200: 0.005032450119064034
# Cost in iteration 400: 0.005029570311262462
# Final cost : 0.005029570311262462
# Compute control for a deterministic system
# Cost in iteration 0: 0.005029570311262462
# Cost in iteration 200: 0.005027160582165112
# Cost in iteration 400: 0.005025612671770536
# Cost in iteration 600: 0.005024447660736888
# Cost in iteration 800: 0.005023625057496179
# Cost in iteration 1000: 0.005022947930282369
# Final cost : 0.005022947930282369
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.08589879473177252
# Cost in iteration 200: 0.005850465284449388
# Final cost : 0.005850465284449388
# Compute control for a deterministic system
# Cost in iteration 0: 0.005850465284449388
# Cost in iteration 200: 0.005783989184060622
# Final cost : 0.005783989184060622
# Compute control for a deterministic system
# Cost in iteration 0: 0.005783989184060622
# Cost in iteration 200: 0.005772219566345765
# Final cost : 0.005772219566345765
# Compute control for a deterministic system
# Cost in iteration 0: 0.005772219566345765
# Cost in iteration 200: 0.005766764905418074
# Cost in iteration 400: 0.005763155368847234
# Final cost : 0.005763155368847234
# Compute control for a deterministic system
# Cost in iteration 0: 0.005763155368847234
# Cost in iteration 200: 0.0057600155145991145
# Cost in iteration 400: 0.005757983485265987
# Cost in iteration 600: 0.00575643245380079
# Cost in iteration 800: 0.005755333505104847
# Cost in iteration 1000: 0.00575442020617122
# Final cost : 0.00575442020617122
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.09012117338216691
# Cost in iteration 200: 0.00659768442218584
# Final cost : 0.00659768442218584
# Compute control for a deterministic system
# Cost in iteration 0: 0.00659768442218584
# Cost in iteration 200: 0.006526189244016154
# Final cost : 0.006526189244016154
# Compute control for a deterministic system
# Cost in iteration 0: 0.006526189244016154
# Cost in iteration 200: 0.006513860381494866
# Final cost : 0.006513860381494866
# Compute control for a deterministic system
# Cost in iteration 0: 0.006513860381494866
# Cost in iteration 200: 0.0065075424138307265
# Cost in iteration 400: 0.006503848418137833
# Final cost : 0.006503848418137833
# Compute control for a deterministic system
# Cost in iteration 0: 0.006503848418137833
# Cost in iteration 200: 0.006500614879625438
# Cost in iteration 400: 0.006498439658079496
# Cost in iteration 600: 0.006496792456002709
# Cost in iteration 800: 0.0064955344225203345
# Cost in iteration 1000: 0.006494559615270926
# Final cost : 0.006494559615270926
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.014452060639184335
# Cost in iteration 200: 0.007357538396441575
# Final cost : 0.007357538396441575
# Compute control for a deterministic system
# Cost in iteration 0: 0.007357538396441575
# Cost in iteration 200: 0.007315635232683863
# Final cost : 0.007315635232683863
# Compute control for a deterministic system
# Cost in iteration 0: 0.007315635232683863
# Cost in iteration 200: 0.00730529791474225
# Final cost : 0.00730529791474225
# Compute control for a deterministic system
# Cost in iteration 0: 0.00730529791474225
# Cost in iteration 200: 0.007299359049146606
# Cost in iteration 400: 0.007295382408585797
# Final cost : 0.007295382408585797
# Compute control for a deterministic system
# Cost in iteration 0: 0.007295382408585797
# Cost in iteration 200: 0.007291974457959212
# Cost in iteration 400: 0.00728937591819745
# Cost in iteration 600: 0.007287413112547975
# Cost in iteration 800: 0.00728573163746932
# Cost in iteration 1000: 0.007284413801740478
# Final cost : 0.007284413801740478
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.021671850641523063
# Cost in iteration 200: 0.008146952275750049
# Final cost : 0.008146952275750049
# Compute control for a deterministic system
# Cost in iteration 0: 0.008146952275750049
# Cost in iteration 200: 0.008105985412389466
# Final cost : 0.008105985412389466
# Compute control for a deterministic system
# Cost in iteration 0: 0.008105985412389466
# Cost in iteration 200: 0.00809615011299532
# Final cost : 0.00809615011299532
# Compute control for a deterministic system
# Cost in iteration 0: 0.00809615011299532
# Cost in iteration 200: 0.008090009287241172
# Cost in iteration 400: 0.008085907713591805
# Final cost : 0.008085907713591805
# Compute control for a deterministic system
# Cost in iteration 0: 0.008085907713591805
# Cost in iteration 200: 0.008082363105132453
# Cost in iteration 400: 0.008079659191479955
# Cost in iteration 600: 0.008077438675029202
# Cost in iteration 800: 0.008075661453241205
# Cost in iteration 1000: 0.008074152439152604
# Final cost : 0.008074152439152604
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.012170034637059447
# Cost in iteration 200: 0.008994138020574562
# Final cost : 0.008994138020574562
# Compute control for a deterministic system
# Cost in iteration 0: 0.008994138020574562
# Cost in iteration 200: 0.008946708012781154
# Final cost : 0.008946708012781154
# Compute control for a deterministic system
# Cost in iteration 0: 0.008946708012781154
# Cost in iteration 200: 0.008936221206457802
# Final cost : 0.008936221206457802
# Compute control for a deterministic system
# Cost in iteration 0: 0.008936221206457802
# Cost in iteration 200: 0.00892995085419612
# Cost in iteration 400: 0.00892554827495334
# Final cost : 0.00892554827495334
# Compute control for a deterministic system
# Cost in iteration 0: 0.00892554827495334
# Cost in iteration 200: 0.008921857621955633
# Cost in iteration 400: 0.00891880157925437
# Cost in iteration 600: 0.008916323609994411
# Cost in iteration 800: 0.008914102996216339
# Cost in iteration 1000: 0.008912281222102945
# Final cost : 0.008912281222102945
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.027745395339499226
# Cost in iteration 200: 0.009834174152943609
# Final cost : 0.009834174152943609
# Compute control for a deterministic system
# Cost in iteration 0: 0.009834174152943609
# Cost in iteration 200: 0.0097894595303558
# Final cost : 0.0097894595303558
# Compute control for a deterministic system
# Cost in iteration 0: 0.0097894595303558
# Cost in iteration 200: 0.00977902504055968
# Final cost : 0.00977902504055968
# Compute control for a deterministic system
# Cost in iteration 0: 0.00977902504055968
# Cost in iteration 200: 0.009772475914598231
# Cost in iteration 400: 0.009767718208591573
# Final cost : 0.009767718208591573
# Compute control for a deterministic system
# Cost in iteration 0: 0.009767718208591573
# Cost in iteration 200: 0.009763659716235218
# Cost in iteration 400: 0.009760393567947234
# Cost in iteration 600: 0.009757455791089316
# Cost in iteration 800: 0.009754806947472492
# Cost in iteration 1000: 0.00975199400357085
# Final cost : 0.00975199400357085
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.12498476813292916
# Cost in iteration 200: 0.010810377703333198
# Final cost : 0.010810377703333198
# Compute control for a deterministic system
# Cost in iteration 0: 0.010810377703333198
# Cost in iteration 200: 0.010701003677567338
# Final cost : 0.010701003677567338
# Compute control for a deterministic system
# Cost in iteration 0: 0.010701003677567338
# Cost in iteration 200: 0.010683879247676302
# Final cost : 0.010683879247676302
# Compute control for a deterministic system
# Cost in iteration 0: 0.010683879247676302
# Cost in iteration 200: 0.010674655479798177
# Cost in iteration 400: 0.010668598295337402
# Final cost : 0.010668598295337402
# Compute control for a deterministic system
# Cost in iteration 0: 0.010668598295337402
# Cost in iteration 200: 0.010663049768909704
# Cost in iteration 400: 0.01065896202295981
# Cost in iteration 600: 0.010655706755130537
# Cost in iteration 800: 0.010652892742194036
# Cost in iteration 1000: 0.010650569240896763
# Final cost : 0.010650569240896763
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.040800874414883295
# Cost in iteration 200: 0.011643656881477999
# Final cost : 0.011643656881477999
# Compute control for a deterministic system
# Cost in iteration 0: 0.011643656881477999
# Cost in iteration 200: 0.01159401978360931
# Final cost : 0.01159401978360931
# Compute control for a deterministic system
# Cost in iteration 0: 0.01159401978360931
# Cost in iteration 200: 0.011582077951021905
# Final cost : 0.011582077951021905
# Compute control for a deterministic system
# Cost in iteration 0: 0.011582077951021905
# Cost in iteration 200: 0.011574204400603434
# Cost in iteration 400: 0.011568290674216955
# Final cost : 0.011568290674216955
# Compute control for a deterministic system
# Cost in iteration 0: 0.011568290674216955
# Cost in iteration 200: 0.0115616910013967
# Cost in iteration 400: 0.011557512897518869
# Cost in iteration 600: 0.011553930115391709
# Cost in iteration 800: 0.011550443902540446
# Cost in iteration 1000: 0.011546785291427917
# Final cost : 0.011546785291427917
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.018362434953794478
# Cost in iteration 200: 0.012596404423410767
# Final cost : 0.012596404423410767
# Compute control for a deterministic system
# Cost in iteration 0: 0.012596404423410767
# Cost in iteration 200: 0.012548185504968288
# Final cost : 0.012548185504968288
# Compute control for a deterministic system
# Cost in iteration 0: 0.012548185504968288
# Cost in iteration 200: 0.01253550881861974
# Final cost : 0.01253550881861974
# Compute control for a deterministic system
# Cost in iteration 0: 0.01253550881861974
# Cost in iteration 200: 0.012527489011472688
# Cost in iteration 400: 0.012521283105656188
# Final cost : 0.012521283105656188
# Compute control for a deterministic system
# Cost in iteration 0: 0.012521283105656188
# Cost in iteration 200: 0.012515341442556073
# Cost in iteration 400: 0.01251052914001101
# Cost in iteration 600: 0.012505991112358512
# Cost in iteration 800: 0.012501974511316205
# Cost in iteration 1000: 0.012498753993025654
# Final cost : 0.012498753993025654
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.11547568809739668
# Cost in iteration 200: 0.013626977840520972
# Final cost : 0.013626977840520972
# Compute control for a deterministic system
# Cost in iteration 0: 0.013626977840520972
# Cost in iteration 200: 0.013514899147884287
# Final cost : 0.013514899147884287
# Compute control for a deterministic system
# Cost in iteration 0: 0.013514899147884287
# Cost in iteration 200: 0.013494811222933679
# Final cost : 0.013494811222933679
# Compute control for a deterministic system
# Cost in iteration 0: 0.013494811222933679
# Cost in iteration 200: 0.01348452365572658
# Cost in iteration 400: 0.013476913714841138
# Final cost : 0.013476913714841138
# Compute control for a deterministic system
# Cost in iteration 0: 0.013476913714841138
# Cost in iteration 200: 0.013469283400074774
# Cost in iteration 400: 0.01346387358131958
# Cost in iteration 600: 0.01345906276464152
# Cost in iteration 800: 0.013454863586733458
# Cost in iteration 1000: 0.01345089570600535
# Final cost : 0.01345089570600535
# Compute control for a deterministic system
# Cost in iteration 0: 0.02324976890866021
# Cost in iteration 200: 0.011167559444346331
# Final cost : 0.011167559444346331
# Compute control for a deterministic system
# Cost in iteration 0: 0.011167559444346331
# Cost in iteration 200: 0.011098075047707906
# Final cost : 0.011098075047707906
# Compute control for a deterministic system
# Cost in iteration 0: 0.011098075047707906
# Cost in iteration 200: 0.01107437503332162
# Final cost : 0.01107437503332162
# Compute control for a deterministic system
# Cost in iteration 0: 0.01107437503332162
# Cost in iteration 200: 0.011069169543944659
# Cost in iteration 400: 0.011066437783731575
# Final cost : 0.011066437783731575
# Compute control for a deterministic system
# Cost in iteration 0: 0.011066437783731575
# Cost in iteration 200: 0.011065263881913513
# Cost in iteration 400: 0.011064568314046813
# Cost in iteration 600: 0.01106414985849447
# Cost in iteration 800: 0.011063896841000242
# Cost in iteration 1000: 0.011063739064935537
# Final cost : 0.011063739064935537
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.06887666360721606
# Cost in iteration 200: 0.009728448529755762
# Final cost : 0.009728448529755762
# Compute control for a deterministic system
# Cost in iteration 0: 0.009728448529755762
# Cost in iteration 200: 0.00966462377600601
# Final cost : 0.00966462377600601
# Compute control for a deterministic system
# Cost in iteration 0: 0.00966462377600601
# Cost in iteration 200: 0.009637967841472684
# Final cost : 0.009637967841472684
# Compute control for a deterministic system
# Cost in iteration 0: 0.009637967841472684
# Cost in iteration 200: 0.009627784472292246
# Cost in iteration 400: 0.00962178391465117
# Final cost : 0.00962178391465117
# Compute control for a deterministic system
# Cost in iteration 0: 0.00962178391465117
# Cost in iteration 200: 0.009618551589186336
# Cost in iteration 400: 0.009616491511711404
# Cost in iteration 600: 0.009615178072329566
# Cost in iteration 800: 0.009614322026719824
# Cost in iteration 1000: 0.00961376271387664
# Final cost : 0.00961376271387664
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.01635338156573773
# Cost in iteration 200: 0.008360463828969685
# Final cost : 0.008360463828969685
# Compute control for a deterministic system
# Cost in iteration 0: 0.008360463828969685
# Cost in iteration 200: 0.00829469778569671
# Final cost : 0.00829469778569671
# Compute control for a deterministic system
# Cost in iteration 0: 0.00829469778569671
# Cost in iteration 200: 0.008270977129841211
# Final cost : 0.008270977129841211
# Compute control for a deterministic system
# Cost in iteration 0: 0.008270977129841211
# Cost in iteration 200: 0.00825914235893607
# Cost in iteration 400: 0.008253040255246825
# Final cost : 0.008253040255246825
# Compute control for a deterministic system
# Cost in iteration 0: 0.008253040255246825
# Cost in iteration 200: 0.008249765841497201
# Cost in iteration 400: 0.008247760833490282
# Cost in iteration 600: 0.008246465618351517
# Cost in iteration 800: 0.008245639856630465
# Cost in iteration 1000: 0.008245108695496647
# Final cost : 0.008245108695496647
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.03025011180351414
# Cost in iteration 200: 0.007129743470791595
# Final cost : 0.007129743470791595
# Compute control for a deterministic system
# Cost in iteration 0: 0.007129743470791595
# Cost in iteration 200: 0.007075421387216717
# Final cost : 0.007075421387216717
# Compute control for a deterministic system
# Cost in iteration 0: 0.007075421387216717
# Cost in iteration 200: 0.007054813080474404
# Final cost : 0.007054813080474404
# Compute control for a deterministic system
# Cost in iteration 0: 0.007054813080474404
# Cost in iteration 200: 0.0070452776124660605
# Cost in iteration 400: 0.007039923541049496
# Final cost : 0.007039923541049496
# Compute control for a deterministic system
# Cost in iteration 0: 0.007039923541049496
# Cost in iteration 200: 0.007037063576354039
# Cost in iteration 400: 0.007035312514527568
# Cost in iteration 600: 0.007034244360767664
# Cost in iteration 800: 0.007033555717408852
# Cost in iteration 1000: 0.007033134556097121
# Final cost : 0.007033134556097121
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.04697455219329314
# Cost in iteration 200: 0.005986396519660021
# Final cost : 0.005986396519660021
# Compute control for a deterministic system
# Cost in iteration 0: 0.005986396519660021
# Cost in iteration 200: 0.005935781330143476
# Final cost : 0.005935781330143476
# Compute control for a deterministic system
# Cost in iteration 0: 0.005935781330143476
# Cost in iteration 200: 0.005917800197627331
# Final cost : 0.005917800197627331
# Compute control for a deterministic system
# Cost in iteration 0: 0.005917800197627331
# Cost in iteration 200: 0.005909751611286827
# Cost in iteration 400: 0.0059051479290394785
# Final cost : 0.0059051479290394785
# Compute control for a deterministic system
# Cost in iteration 0: 0.0059051479290394785
# Cost in iteration 200: 0.00590273623041824
# Cost in iteration 400: 0.005901294727519982
# Cost in iteration 600: 0.005900422998507109
# Cost in iteration 800: 0.005899899095288474
# Cost in iteration 1000: 0.005899576301305423
# Final cost : 0.005899576301305423
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.02084928625312619
# Cost in iteration 200: 0.004977481702764789
# Final cost : 0.004977481702764789
# Compute control for a deterministic system
# Cost in iteration 0: 0.004977481702764789
# Cost in iteration 200: 0.0049365670106192895
# Final cost : 0.0049365670106192895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0049365670106192895
# Cost in iteration 200: 0.0049208205038992195
# Final cost : 0.0049208205038992195
# Compute control for a deterministic system
# Cost in iteration 0: 0.0049208205038992195
# Cost in iteration 200: 0.004914412690636392
# Cost in iteration 400: 0.004910924869488755
# Final cost : 0.004910924869488755
# Compute control for a deterministic system
# Cost in iteration 0: 0.004910924869488755
# Cost in iteration 200: 0.004909132785558594
# Cost in iteration 400: 0.004908091014975359
# Cost in iteration 600: 0.0049074748147208865
# Cost in iteration 800: 0.0049071113556824735
# Cost in iteration 1000: 0.004906894668863715
# Final cost : 0.004906894668863715
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.024503521728412872
# Cost in iteration 200: 0.004052997322457027
# Final cost : 0.004052997322457027
# Compute control for a deterministic system
# Cost in iteration 0: 0.004052997322457027
# Cost in iteration 200: 0.004015915984050569
# Final cost : 0.004015915984050569
# Compute control for a deterministic system
# Cost in iteration 0: 0.004015915984050569
# Cost in iteration 200: 0.004002332514256105
# Final cost : 0.004002332514256105
# Compute control for a deterministic system
# Cost in iteration 0: 0.004002332514256105
# Cost in iteration 200: 0.003996930303485722
# Cost in iteration 400: 0.00399403746508734
# Final cost : 0.00399403746508734
# Compute control for a deterministic system
# Cost in iteration 0: 0.00399403746508734
# Cost in iteration 200: 0.0039926638434701215
# Cost in iteration 400: 0.003991869818058989
# Cost in iteration 600: 0.003991416118341804
# Cost in iteration 800: 0.003991154803535481
# Cost in iteration 1000: 0.00399100296857215
# Final cost : 0.00399100296857215
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0334123140216255
# Cost in iteration 200: 0.003249842984360232
# Final cost : 0.003249842984360232
# Compute control for a deterministic system
# Cost in iteration 0: 0.003249842984360232
# Cost in iteration 200: 0.003220875672524118
# Final cost : 0.003220875672524118
# Compute control for a deterministic system
# Cost in iteration 0: 0.003220875672524118
# Cost in iteration 200: 0.0032104105926914726
# Final cost : 0.0032104105926914726
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032104105926914726
# Cost in iteration 200: 0.003206167732044149
# Cost in iteration 400: 0.003204131768505461
# Final cost : 0.003204131768505461
# Compute control for a deterministic system
# Cost in iteration 0: 0.003204131768505461
# Cost in iteration 200: 0.003203146446214784
# Cost in iteration 400: 0.0032026080307675907
# Cost in iteration 600: 0.0032023096676124397
# Cost in iteration 800: 0.003202140311822579
# Cost in iteration 1000: 0.003202045666236135
# Final cost : 0.003202045666236135
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.03021003524456247
# Cost in iteration 200: 0.0025289912084054556
# Final cost : 0.0025289912084054556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025289912084054556
# Cost in iteration 200: 0.0025019663613498992
# Final cost : 0.0025019663613498992
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025019663613498992
# Cost in iteration 200: 0.002494223104011296
# Final cost : 0.002494223104011296
# Compute control for a deterministic system
# Cost in iteration 0: 0.002494223104011296
# Cost in iteration 200: 0.002491306252932747
# Cost in iteration 400: 0.0024899062703017095
# Final cost : 0.0024899062703017095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024899062703017095
# Cost in iteration 200: 0.0024892484449552396
# Cost in iteration 400: 0.0024889001679861485
# Cost in iteration 600: 0.0024887124540933225
# Cost in iteration 800: 0.0024886121929391736
# Cost in iteration 1000: 0.002488556750188454
# Final cost : 0.002488556750188454
# -----------------------------------------------
# 0 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.016628754678080553
# Cost in iteration 200: 0.001918814263016238
# Final cost : 0.001918814263016238
# Compute control for a deterministic system
# Cost in iteration 0: 0.001918814263016238
# Cost in iteration 200: 0.0018992654718745963
# Final cost : 0.0018992654718745963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018992654718745963
# Cost in iteration 200: 0.0018933840909585845
# Final cost : 0.0018933840909585845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018933840909585845
# Cost in iteration 200: 0.0018911101800875392
# Cost in iteration 400: 0.0018900277899373172
# Final cost : 0.0018900277899373172
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018900277899373172
# Cost in iteration 200: 0.001889560631780077
# Cost in iteration 400: 0.0018893237830815853
# Cost in iteration 600: 0.0018891981290320918
# Cost in iteration 800: 0.001889132354801908
# Cost in iteration 1000: 0.0018890977237405683
# Final cost : 0.0018890977237405683
# -----------------------------------------------
# 0 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.03131359658219785
# Cost in iteration 200: 0.001387380350671099
# Final cost : 0.001387380350671099
# Compute control for a deterministic system
# Cost in iteration 0: 0.001387380350671099
# Cost in iteration 200: 0.00137247929665672
# Final cost : 0.00137247929665672
# Compute control for a deterministic system
# Cost in iteration 0: 0.00137247929665672
# Cost in iteration 200: 0.001367325754421584
# Final cost : 0.001367325754421584
# Compute control for a deterministic system
# Cost in iteration 0: 0.001367325754421584
# Cost in iteration 200: 0.0013654022602427613
# Cost in iteration 400: 0.0013645796762928517
# Final cost : 0.0013645796762928517
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013645796762928517
# Cost in iteration 200: 0.0013642306754218976
# Cost in iteration 400: 0.0013640161811867273
# Cost in iteration 600: 0.0013639407845259582
# Cost in iteration 800: 0.0013639087149200247
# Cost in iteration 1000: 0.001363893881605089
# Final cost : 0.001363893881605089
# -----------------------------------------------
# 0 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.01879650989618128
# Cost in iteration 200: 0.0009565031366469459
# Final cost : 0.0009565031366469459
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009565031366469459
# Cost in iteration 200: 0.0009465665956079757
# Final cost : 0.0009465665956079757
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009465665956079757
# Cost in iteration 200: 0.0009429733416135709
# Final cost : 0.0009429733416135709
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009429733416135709
# Cost in iteration 200: 0.0009416686416122257
# Cost in iteration 400: 0.0009410966156441759
# Final cost : 0.0009410966156441759
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009410966156441759
# Cost in iteration 200: 0.0009408670045517573
# Cost in iteration 400: 0.0009407598360855496
# Cost in iteration 600: 0.0009407073545758188
# Cost in iteration 800: 0.0009406812832951131
# Cost in iteration 1000: 0.0009406681447508822
# Final cost : 0.0009406681447508822
# -----------------------------------------------
# 0 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.030423651615580777
# Cost in iteration 200: 0.0006017945453462083
# Final cost : 0.0006017945453462083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006017945453462083
# Cost in iteration 200: 0.0005942928663870451
# Final cost : 0.0005942928663870451
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005942928663870451
# Cost in iteration 200: 0.0005917868773274999
# Final cost : 0.0005917868773274999
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005917868773274999
# Cost in iteration 200: 0.0005910587342339926
# Cost in iteration 400: 0.0005907608241861812
# Final cost : 0.0005907608241861812
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005907608241861812
# Cost in iteration 200: 0.0005906162788515374
# Cost in iteration 400: 0.0005905621237128047
# Cost in iteration 600: 0.0005905420936416979
# Cost in iteration 800: 0.0005905349929771298
# Cost in iteration 1000: 0.0005905316873529505
# Final cost : 0.0005905316873529505
# -----------------------------------------------
# 0 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.01748599656800331
# Cost in iteration 200: 0.00033744890529870656
# Final cost : 0.00033744890529870656
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033744890529870656
# Cost in iteration 200: 0.00033322521759465934
# Final cost : 0.00033322521759465934
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033322521759465934
# Cost in iteration 200: 0.00033188550631566715
# Final cost : 0.00033188550631566715
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033188550631566715
# Cost in iteration 200: 0.0003314330325683916
# Cost in iteration 400: 0.000331244280420081
# Final cost : 0.000331244280420081
# Compute control for a deterministic system
# Cost in iteration 0: 0.000331244280420081
# Cost in iteration 200: 0.0003311609962921365
# Cost in iteration 400: 0.00033111600093133027
# Cost in iteration 600: 0.0003311121269663404
# Cost in iteration 800: 0.0003311113840805141
# Cost in iteration 1000: 0.00033111117661166007
# Final cost : 0.00033111117661166007
# -----------------------------------------------
# 0 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.03048083494389225
# Cost in iteration 200: 0.00014720376192854906
# Final cost : 0.00014720376192854906
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014720376192854906
# Cost in iteration 200: 0.00014465672183820168
# Final cost : 0.00014465672183820168
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014465672183820168
# Cost in iteration 200: 0.00014397512316073935
# Final cost : 0.00014397512316073935
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014397512316073935
# Cost in iteration 200: 0.00014379127598338802
# Cost in iteration 400: 0.00014371542994940362
# Final cost : 0.00014371542994940362
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014371542994940362
# Cost in iteration 200: 0.00014368374783037458
# Cost in iteration 400: 0.00014366684066701392
# Cost in iteration 600: 0.00014366452564483465
# Cost in iteration 800: 0.00014366391722306457
# Cost in iteration 1000: 0.00014366370798343662
# Final cost : 0.00014366370798343662
# -----------------------------------------------
# 0 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.0287021592225015
# Cost in iteration 200: 3.788386630234812e-05
# Final cost : 3.788386630234812e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.788386630234812e-05
# Cost in iteration 200: 3.6726286395502474e-05
# Final cost : 3.6726286395502474e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6726286395502474e-05
# Cost in iteration 200: 3.6505841069164026e-05
# Final cost : 3.6505841069164026e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6505841069164026e-05
# Cost in iteration 200: 3.644570785922345e-05
# Cost in iteration 400: 3.6421758827143715e-05
# Final cost : 3.6421758827143715e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6421758827143715e-05
# Cost in iteration 200: 3.64120440373865e-05
# Cost in iteration 400: 3.640678157845924e-05
# Cost in iteration 600: 3.6406052306154135e-05
# Cost in iteration 800: 3.640580425895978e-05
# Cost in iteration 1000: 3.6405697258758924e-05
# Final cost : 3.6405697258758924e-05
# -----------------------------------------------
# 0 found better solution,  39
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.025373169717422147
# Cost in iteration 200: 0.00014529395234686075
# Final cost : 0.00014529395234686075
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014529395234686075
# Cost in iteration 200: 0.0001441679905355229
# Final cost : 0.0001441679905355229
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001441679905355229
# Cost in iteration 200: 0.0001438394816829511
# Cost in iteration 400: 0.00014372755709586568
# Final cost : 0.00014372755709586568
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014372755709586568
# Cost in iteration 200: 0.00014368875285975126
# Cost in iteration 400: 0.00014367103237300432
# Cost in iteration 600: 0.0001436654598625848
# Cost in iteration 800: 0.00014366440702771887
# Cost in iteration 1000: 0.0001436639662728603
# Final cost : 0.0001436639662728603
# Compute control for a deterministic system
# Cost in iteration 0: 0.0338233736551652
# Cost in iteration 200: 0.00033782560135055755
# Final cost : 0.00033782560135055755
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033782560135055755
# Cost in iteration 200: 0.0003333412401804188
# Final cost : 0.0003333412401804188
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003333412401804188
# Cost in iteration 200: 0.00033173768448108235
# Cost in iteration 400: 0.0003313200488348192
# Final cost : 0.0003313200488348192
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003313200488348192
# Cost in iteration 200: 0.00033120316437573554
# Cost in iteration 400: 0.00033115332296074484
# Cost in iteration 600: 0.000331130985096477
# Cost in iteration 800: 0.0003311197852217064
# Cost in iteration 1000: 0.000331113630413581
# Final cost : 0.000331113630413581
# Compute control for a deterministic system
# Cost in iteration 0: 0.027895415791839125
# Cost in iteration 200: 0.0006032358532595756
# Final cost : 0.0006032358532595756
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006032358532595756
# Cost in iteration 200: 0.000593252624577807
# Final cost : 0.000593252624577807
# Compute control for a deterministic system
# Cost in iteration 0: 0.000593252624577807
# Cost in iteration 200: 0.0005913418823278444
# Cost in iteration 400: 0.0005908138526035372
# Final cost : 0.0005908138526035372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005908138526035372
# Cost in iteration 200: 0.0005906526036074114
# Cost in iteration 400: 0.000590584518133961
# Cost in iteration 600: 0.0005905544580277148
# Cost in iteration 800: 0.0005905411199001495
# Cost in iteration 1000: 0.0005905350987829858
# Final cost : 0.0005905350987829858
# Compute control for a deterministic system
# Cost in iteration 0: 0.02458891188684649
# Cost in iteration 200: 0.00095388161955801
# Final cost : 0.00095388161955801
# Compute control for a deterministic system
# Cost in iteration 0: 0.00095388161955801
# Cost in iteration 200: 0.000943555940100927
# Final cost : 0.000943555940100927
# Compute control for a deterministic system
# Cost in iteration 0: 0.000943555940100927
# Cost in iteration 200: 0.0009416229348533653
# Cost in iteration 400: 0.0009410187530244915
# Final cost : 0.0009410187530244915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009410187530244915
# Cost in iteration 200: 0.0009407952794433628
# Cost in iteration 400: 0.0009407070243118651
# Cost in iteration 600: 0.0009406804399437114
# Cost in iteration 800: 0.0009406674811429014
# Cost in iteration 1000: 0.0009406611907087106
# Final cost : 0.0009406611907087106
# -----------------------------------------------
# 1 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.03217589464424019
# Cost in iteration 200: 0.00139016126192243
# Final cost : 0.00139016126192243
# Compute control for a deterministic system
# Cost in iteration 0: 0.00139016126192243
# Cost in iteration 200: 0.0013693142898574093
# Final cost : 0.0013693142898574093
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013693142898574093
# Cost in iteration 200: 0.0013657753299718463
# Cost in iteration 400: 0.0013646123656767927
# Final cost : 0.0013646123656767927
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013646123656767927
# Cost in iteration 200: 0.0013642213742558428
# Cost in iteration 400: 0.0013640443333921037
# Cost in iteration 600: 0.0013639604120610728
# Cost in iteration 800: 0.0013639194399456833
# Cost in iteration 1000: 0.0013638990330496162
# Final cost : 0.0013638990330496162
# Compute control for a deterministic system
# Cost in iteration 0: 0.015699647447413256
# Cost in iteration 200: 0.0019056585961208013
# Final cost : 0.0019056585961208013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019056585961208013
# Cost in iteration 200: 0.0018943798700267126
# Final cost : 0.0018943798700267126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018943798700267126
# Cost in iteration 200: 0.001890905297889105
# Cost in iteration 400: 0.0018898304201284014
# Final cost : 0.0018898304201284014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018898304201284014
# Cost in iteration 200: 0.0018894323854320386
# Cost in iteration 400: 0.0018892478485960616
# Cost in iteration 600: 0.0018891561157447052
# Cost in iteration 800: 0.001889109219380991
# Cost in iteration 1000: 0.0018890852168556812
# Final cost : 0.0018890852168556812
# -----------------------------------------------
# ...
# Cost in iteration 800: 0.009612740019095328
# Cost in iteration 1000: 0.00961273622352896
# Final cost : 0.00961273622352896
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.00840928462135104
# Cost in iteration 200: 0.008245711399038388
# Final cost : 0.008245711399038388
# Compute control for a deterministic system
# Cost in iteration 0: 0.008245711399038388
# Cost in iteration 200: 0.008244550804013411
# Final cost : 0.008244550804013411
# Compute control for a deterministic system
# Cost in iteration 0: 0.008244550804013411
# Cost in iteration 200: 0.00824431550476847
# Final cost : 0.00824431550476847
# Compute control for a deterministic system
# Cost in iteration 0: 0.00824431550476847
# Cost in iteration 200: 0.008244235912266749
# Cost in iteration 400: 0.008244202020198441
# Final cost : 0.008244202020198441
# Compute control for a deterministic system
# Cost in iteration 0: 0.008244202020198441
# Cost in iteration 200: 0.008244190728464431
# Cost in iteration 400: 0.008244183980255773
# Cost in iteration 600: 0.008244179739580124
# Cost in iteration 800: 0.008244177076194181
# Cost in iteration 1000: 0.008244175414701356
# Final cost : 0.008244175414701356
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.013570363115440427
# Cost in iteration 200: 0.007033744473591517
# Final cost : 0.007033744473591517
# Compute control for a deterministic system
# Cost in iteration 0: 0.007033744473591517
# Cost in iteration 200: 0.0070327545692132004
# Final cost : 0.0070327545692132004
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070327545692132004
# Cost in iteration 200: 0.0070325640124500755
# Final cost : 0.0070325640124500755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070325640124500755
# Cost in iteration 200: 0.007032486002574617
# Cost in iteration 400: 0.007032456712931923
# Final cost : 0.007032456712931923
# Compute control for a deterministic system
# Cost in iteration 0: 0.007032456712931923
# Cost in iteration 200: 0.007032443106766628
# Cost in iteration 400: 0.007032434617863944
# Cost in iteration 600: 0.007032429488456758
# Cost in iteration 800: 0.007032426310663403
# Cost in iteration 1000: 0.007032424379231278
# Final cost : 0.007032424379231278
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.006041438554198683
# Cost in iteration 200: 0.005900153566345807
# Final cost : 0.005900153566345807
# Compute control for a deterministic system
# Cost in iteration 0: 0.005900153566345807
# Cost in iteration 200: 0.005899292288997184
# Final cost : 0.005899292288997184
# Compute control for a deterministic system
# Cost in iteration 0: 0.005899292288997184
# Cost in iteration 200: 0.005899133640641542
# Final cost : 0.005899133640641542
# Compute control for a deterministic system
# Cost in iteration 0: 0.005899133640641542
# Cost in iteration 200: 0.005899090761969721
# Cost in iteration 400: 0.005899074956509867
# Final cost : 0.005899074956509867
# Compute control for a deterministic system
# Cost in iteration 0: 0.005899074956509867
# Cost in iteration 200: 0.0058990695726104745
# Cost in iteration 400: 0.005899066623649632
# Cost in iteration 600: 0.005899064841886716
# Cost in iteration 800: 0.0058990637560704644
# Cost in iteration 1000: 0.005899063093160108
# Final cost : 0.005899063093160108
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.008691071488496818
# Cost in iteration 200: 0.004907855114052125
# Final cost : 0.004907855114052125
# Compute control for a deterministic system
# Cost in iteration 0: 0.004907855114052125
# Cost in iteration 200: 0.004906783231760101
# Final cost : 0.004906783231760101
# Compute control for a deterministic system
# Cost in iteration 0: 0.004906783231760101
# Cost in iteration 200: 0.004906633479646569
# Final cost : 0.004906633479646569
# Compute control for a deterministic system
# Cost in iteration 0: 0.004906633479646569
# Cost in iteration 200: 0.0049065976236766
# Cost in iteration 400: 0.004906586324373597
# Final cost : 0.004906586324373597
# Compute control for a deterministic system
# Cost in iteration 0: 0.004906586324373597
# Cost in iteration 200: 0.0049065818984348345
# Cost in iteration 400: 0.004906579480378616
# Cost in iteration 600: 0.004906578078705259
# Cost in iteration 800: 0.004906577261903805
# Cost in iteration 1000: 0.0049065767734269555
# Final cost : 0.0049065767734269555
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.005300712288290848
# Cost in iteration 200: 0.003991480422396357
# Final cost : 0.003991480422396357
# Compute control for a deterministic system
# Cost in iteration 0: 0.003991480422396357
# Cost in iteration 200: 0.003990943952361174
# Final cost : 0.003990943952361174
# Compute control for a deterministic system
# Cost in iteration 0: 0.003990943952361174
# Cost in iteration 200: 0.0039908410157473585
# Final cost : 0.0039908410157473585
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039908410157473585
# Cost in iteration 200: 0.003990810515341285
# Cost in iteration 400: 0.00399080161516919
# Final cost : 0.00399080161516919
# Compute control for a deterministic system
# Cost in iteration 0: 0.00399080161516919
# Cost in iteration 200: 0.003990798256826181
# Cost in iteration 400: 0.0039907965122956725
# Cost in iteration 600: 0.003990795542034848
# Cost in iteration 800: 0.003990794989247916
# Cost in iteration 1000: 0.00399079467092627
# Final cost : 0.00399079467092627
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032136840169104328
# Cost in iteration 200: 0.003202510280088447
# Final cost : 0.003202510280088447
# Compute control for a deterministic system
# Cost in iteration 0: 0.003202510280088447
# Cost in iteration 200: 0.0032020365421443556
# Final cost : 0.0032020365421443556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032020365421443556
# Cost in iteration 200: 0.003201949406681111
# Final cost : 0.003201949406681111
# Compute control for a deterministic system
# Cost in iteration 0: 0.003201949406681111
# Cost in iteration 200: 0.0032019306090368084
# Cost in iteration 400: 0.0032019260302172028
# Final cost : 0.0032019260302172028
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032019260302172028
# Cost in iteration 200: 0.003201924617439854
# Cost in iteration 400: 0.0032019239624846863
# Cost in iteration 600: 0.003201923623163417
# Cost in iteration 800: 0.0032019234386222776
# Cost in iteration 1000: 0.0032019233359691333
# Final cost : 0.0032019233359691333
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.002566954937569054
# Cost in iteration 200: 0.002488931909945868
# Final cost : 0.002488931909945868
# Compute control for a deterministic system
# Cost in iteration 0: 0.002488931909945868
# Cost in iteration 200: 0.0024885789632000934
# Final cost : 0.0024885789632000934
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024885789632000934
# Cost in iteration 200: 0.0024885080106786367
# Final cost : 0.0024885080106786367
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024885080106786367
# Cost in iteration 200: 0.0024884950564949986
# Cost in iteration 400: 0.0024884915742685067
# Final cost : 0.0024884915742685067
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024884915742685067
# Cost in iteration 200: 0.0024884904342132694
# Cost in iteration 400: 0.0024884899172048715
# Cost in iteration 600: 0.002488489658111572
# Cost in iteration 800: 0.002488489521924941
# Cost in iteration 1000: 0.0024884894487990222
# Final cost : 0.0024884894487990222
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.005219378911796733
# Cost in iteration 200: 0.001889410556867707
# Final cost : 0.001889410556867707
# Compute control for a deterministic system
# Cost in iteration 0: 0.001889410556867707
# Cost in iteration 200: 0.0018891324163400258
# Final cost : 0.0018891324163400258
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018891324163400258
# Cost in iteration 200: 0.0018890712497413996
# Final cost : 0.0018890712497413996
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018890712497413996
# Cost in iteration 200: 0.0018890629698526842
# Cost in iteration 400: 0.001889060429370216
# Final cost : 0.001889060429370216
# Compute control for a deterministic system
# Cost in iteration 0: 0.001889060429370216
# Cost in iteration 200: 0.0018890595523052016
# Cost in iteration 400: 0.0018890591553685629
# Cost in iteration 600: 0.0018890589612693082
# Cost in iteration 800: 0.0018890588621940122
# Cost in iteration 1000: 0.0018890588106629737
# Final cost : 0.0018890588106629737
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015010028312041081
# Cost in iteration 200: 0.0013641510285385852
# Final cost : 0.0013641510285385852
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013641510285385852
# Cost in iteration 200: 0.001363933313150942
# Final cost : 0.001363933313150942
# Compute control for a deterministic system
# Cost in iteration 0: 0.001363933313150942
# Cost in iteration 200: 0.0013638872296135387
# Final cost : 0.0013638872296135387
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013638872296135387
# Cost in iteration 200: 0.0013638808295521946
# Cost in iteration 400: 0.0013638790206920077
# Final cost : 0.0013638790206920077
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013638790206920077
# Cost in iteration 200: 0.0013638784763907658
# Cost in iteration 400: 0.0013638782589866008
# Cost in iteration 600: 0.0013638781630371714
# Cost in iteration 800: 0.0013638781176222676
# Cost in iteration 1000: 0.001363878095074192
# Final cost : 0.001363878095074192
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.001137842518254813
# Cost in iteration 200: 0.0009408098645894377
# Final cost : 0.0009408098645894377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009408098645894377
# Cost in iteration 200: 0.0009406889629152661
# Final cost : 0.0009406889629152661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009406889629152661
# Cost in iteration 200: 0.0009406626415752589
# Final cost : 0.0009406626415752589
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009406626415752589
# Cost in iteration 200: 0.0009406569674643899
# Cost in iteration 400: 0.0009406554884966557
# Final cost : 0.0009406554884966557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009406554884966557
# Cost in iteration 200: 0.0009406551089492622
# Cost in iteration 400: 0.0009406549778267689
# Cost in iteration 600: 0.0009406549283492057
# Cost in iteration 800: 0.0009406549055598234
# Cost in iteration 1000: 0.0009406548971803941
# Final cost : 0.0009406548971803941
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007922003095778305
# Cost in iteration 200: 0.0005906507287198072
# Final cost : 0.0005906507287198072
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005906507287198072
# Cost in iteration 200: 0.0005905528277939625
# Final cost : 0.0005905528277939625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005905528277939625
# Cost in iteration 200: 0.0005905337135804257
# Final cost : 0.0005905337135804257
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005905337135804257
# Cost in iteration 200: 0.0005905308489148083
# Cost in iteration 400: 0.0005905300969898567
# Final cost : 0.0005905300969898567
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005905300969898567
# Cost in iteration 200: 0.0005905299163896232
# Cost in iteration 400: 0.0005905298565439754
# Cost in iteration 600: 0.0005905298353825602
# Cost in iteration 800: 0.0005905298272777466
# Cost in iteration 1000: 0.0005905298240319779
# Final cost : 0.0005905298240319779
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006502854841155862
# Cost in iteration 200: 0.000331186105802862
# Final cost : 0.000331186105802862
# Compute control for a deterministic system
# Cost in iteration 0: 0.000331186105802862
# Cost in iteration 200: 0.0003311247445970426
# Final cost : 0.0003311247445970426
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003311247445970426
# Cost in iteration 200: 0.0003311139409341324
# Final cost : 0.0003311139409341324
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003311139409341324
# Cost in iteration 200: 0.00033111185672825966
# Cost in iteration 400: 0.0003311113048485061
# Final cost : 0.0003311113048485061
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003311113048485061
# Cost in iteration 200: 0.0003311111654906241
# Cost in iteration 400: 0.000331111119211629
# Cost in iteration 600: 0.00033111110197350243
# Cost in iteration 800: 0.0003311110943251482
# Cost in iteration 1000: 0.00033111109079974303
# Final cost : 0.00033111109079974303
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002114163018178696
# Cost in iteration 200: 0.0001436843995232623
# Final cost : 0.0001436843995232623
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001436843995232623
# Cost in iteration 200: 0.00014366771694888933
# Final cost : 0.00014366771694888933
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014366771694888933
# Cost in iteration 200: 0.00014366438654932139
# Final cost : 0.00014366438654932139
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014366438654932139
# Cost in iteration 200: 0.00014366379934159003
# Cost in iteration 400: 0.00014366364647148584
# Final cost : 0.00014366364647148584
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014366364647148584
# Cost in iteration 200: 0.00014366360096996648
# Cost in iteration 400: 0.00014366358961763164
# Cost in iteration 600: 0.00014366358684928362
# Cost in iteration 800: 0.0001436635864023325
# Cost in iteration 1000: 0.00014366358632482003
# Final cost : 0.00014366358632482003
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 6.25623066136785e-05
# Cost in iteration 200: 3.6410675051872696e-05
# Final cost : 3.6410675051872696e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.6410675051872696e-05
# Cost in iteration 200: 3.640699940116211e-05
# Final cost : 3.640699940116211e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.640699940116211e-05
# Cost in iteration 200: 3.640599903387621e-05
# Final cost : 3.640599903387621e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.640599903387621e-05
# Cost in iteration 200: 3.6405765819899704e-05
# Cost in iteration 400: 3.640569784415932e-05
# Final cost : 3.640569784415932e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.640569784415932e-05
# Cost in iteration 200: 3.640567597054601e-05
# Cost in iteration 400: 3.6405670308666125e-05
# Cost in iteration 600: 3.64056686582244e-05
# Cost in iteration 800: 3.640566821264219e-05
# Cost in iteration 1000: 3.6405668071207934e-05
# Final cost : 3.6405668071207934e-05
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
