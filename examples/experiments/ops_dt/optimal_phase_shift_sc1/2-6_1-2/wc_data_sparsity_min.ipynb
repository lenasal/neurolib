# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4353161677504697 
y_init = 0.4948614151973427
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,121], wc.inh[0,121]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.40318543532890344 0.43957823341190944
# minima =  [  776  2541  4289  6034  7780  9526 11271 13017 14763 16508 18254 20000
#  21745 23491 25237 26982 28728 30474 32219 33965 35711 37456 39202]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("c_s2_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("c_s2_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [False, False, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

                
        save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014796480075708694
# Converged in iteration 78 with cost 0.0013928778193005808 because of vanishing difference
# Final cost : 0.0013928778193005808
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928778193005808
# Converged in iteration 77 with cost 0.0013928710265597491 because of step counter
# Final cost : 0.0013928710265597491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928710265597491
# Converged in iteration 1 with cost 0.0013928710265597491 because of step counter
# Final cost : 0.0013928710265597491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928710265597491
# Converged in iteration 1 with cost 0.0013928710265597491 because of step counter
# Final cost : 0.0013928710265597491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928710265597491
# Converged in iteration 1 with cost 0.0013928710265597491 because of step counter
# Final cost : 0.0013928710265597491
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031393083140906167
# Converged in iteration 114 with cost 0.0027865796575469656 because of vanishing difference
# Final cost : 0.0027865796575469656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027865796575469656
# Converged in iteration 114 with cost 0.0027865686744815653 because of step counter
# Final cost : 0.0027865686744815653
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027865686744815653
# Converged in iteration 2 with cost 0.0027865686744793787 because of step counter
# Final cost : 0.0027865686744793787
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027865686744793787
# Converged in iteration 1 with cost 0.0027865686744793787 because of step counter
# Final cost : 0.0027865686744793787
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027865686744793787
# Converged in iteration 2 with cost 0.0027865686744792425 because of step counter
# Final cost : 0.0027865686744792425
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.005066829207943123
# Converged in iteration 135 with cost 0.0042129683398778595 because of vanishing difference
# Final cost : 0.0042129683398778595
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129683398778595
# Cost in iteration 200: 0.0042129571912731265
# Final cost : 0.0042129571912731265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129571912731265
# Converged in iteration 18 with cost 0.0042129571911746115 because of step counter
# Final cost : 0.0042129571911746115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129571911746115
# Converged in iteration 1 with cost 0.0042129571911746115 because of step counter
# Final cost : 0.0042129571911746115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129571911746115
# Converged in iteration 2 with cost 0.004212957191171863 because of step counter
# Final cost : 0.004212957191171863
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.0072106504995642995
# Converged in iteration 184 with cost 0.005635778225219746 because of vanishing difference
# Final cost : 0.005635778225219746
# Compute control for a deterministic system
# Cost in iteration 0: 0.005635778225219746
# Cost in iteration 200: 0.005635776091348527
# Final cost : 0.005635776091348527
# Compute control for a deterministic system
# Cost in iteration 0: 0.005635776091348527
# Converged in iteration 51 with cost 0.0056357760910825064 because of step counter
# Final cost : 0.0056357760910825064
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056357760910825064
# Converged in iteration 34 with cost 0.005635776090978954 because of step counter
# Final cost : 0.005635776090978954
# Compute control for a deterministic system
# Cost in iteration 0: 0.005635776090978954
# Converged in iteration 7 with cost 0.005635776090910328 because of step counter
# Final cost : 0.005635776090910328
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00819445711780408
# Converged in iteration 156 with cost 0.007021103895438387 because of vanishing difference
# Final cost : 0.007021103895438387
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021103895438387
# Cost in iteration 200: 0.007021099189994931
# Final cost : 0.007021099189994931
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021099189994931
# Cost in iteration 200: 0.007021099181484961
# Final cost : 0.007021099181484961
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021099181484961
# Converged in iteration 73 with cost 0.007021099181065217 because of step counter
# Final cost : 0.007021099181065217
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021099181065217
# Converged in iteration 4 with cost 0.0070210991809160316 because of step counter
# Final cost : 0.0070210991809160316
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.011710194935040477
# Converged in iteration 143 with cost 0.00843160236325992 because of vanishing difference
# Final cost : 0.00843160236325992
# Compute control for a deterministic system
# Cost in iteration 0: 0.00843160236325992
# Cost in iteration 200: 0.008431583533528903
# Final cost : 0.008431583533528903
# Compute control for a deterministic system
# Cost in iteration 0: 0.008431583533528903
# Cost in iteration 200: 0.008431583483111928
# Final cost : 0.008431583483111928
# Compute control for a deterministic system
# Cost in iteration 0: 0.008431583483111928
# Cost in iteration 200: 0.00843158347636801
# Cost in iteration 400: 0.00843158347480837
# Final cost : 0.00843158347480837
# Compute control for a deterministic system
# Cost in iteration 0: 0.00843158347480837
# Converged in iteration 40 with cost 0.008431583474610392 because of step counter
# Final cost : 0.008431583474610392
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.015359345977580069
# Cost in iteration 200: 0.009817593353723111
# Final cost : 0.009817593353723111
# Compute control for a deterministic system
# Cost in iteration 0: 0.009817593353723111
# Converged in iteration 95 with cost 0.009800045601816632 because of vanishing difference
# Final cost : 0.009800045601816632
# Compute control for a deterministic system
# Cost in iteration 0: 0.009800045601816632
# Cost in iteration 200: 0.00980002509701893
# Final cost : 0.00980002509701893
# Compute control for a deterministic system
# Cost in iteration 0: 0.00980002509701893
# Cost in iteration 200: 0.009800024590219215
# Cost in iteration 400: 0.009800024524934127
# Final cost : 0.009800024524934127
# Compute control for a deterministic system
# Cost in iteration 0: 0.009800024524934127
# Cost in iteration 200: 0.00980002450196859
# Converged in iteration 311 with cost 0.009800024500688441 because of step counter
# Final cost : 0.009800024500688441
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.017728705681764496
# Cost in iteration 200: 0.011184910494150149
# Final cost : 0.011184910494150149
# Compute control for a deterministic system
# Cost in iteration 0: 0.011184910494150149
# Cost in iteration 200: 0.01118487569671397
# Final cost : 0.01118487569671397
# Compute control for a deterministic system
# Cost in iteration 0: 0.01118487569671397
# Cost in iteration 200: 0.011184875174097985
# Final cost : 0.011184875174097985
# Compute control for a deterministic system
# Cost in iteration 0: 0.011184875174097985
# Cost in iteration 200: 0.011184875032196631
# Cost in iteration 400: 0.011184874971746368
# Final cost : 0.011184874971746368
# Compute control for a deterministic system
# Cost in iteration 0: 0.011184874971746368
# Cost in iteration 200: 0.01118487492121061
# Cost in iteration 400: 0.011184874909309271
# Cost in iteration 600: 0.011184874906257672
# Converged in iteration 610 with cost 0.011184874906184217 because of step counter
# Final cost : 0.011184874906184217
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.012713749348489648
# Converged in iteration 98 with cost 0.01254908862147618 because of vanishing difference
# Final cost : 0.01254908862147618
# Compute control for a deterministic system
# Cost in iteration 0: 0.01254908862147618
# Cost in iteration 200: 0.012549079769270909
# Final cost : 0.012549079769270909
# Compute control for a deterministic system
# Cost in iteration 0: 0.012549079769270909
# Cost in iteration 200: 0.01254907886609766
# Final cost : 0.01254907886609766
# Compute control for a deterministic system
# Cost in iteration 0: 0.01254907886609766
# Cost in iteration 200: 0.012549078380098014
# Cost in iteration 400: 0.012549078070639345
# Final cost : 0.012549078070639345
# Compute control for a deterministic system
# Cost in iteration 0: 0.012549078070639345
# Cost in iteration 200: 0.012549077668039688
# Cost in iteration 400: 0.012549077541662394
# Cost in iteration 600: 0.012549077505504797
# Cost in iteration 800: 0.012549077495147776
# Cost in iteration 1000: 0.012549077491930244
# Final cost : 0.012549077491930244
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.014802543810125305
# Cost in iteration 200: 0.013859993985443079
# Final cost : 0.013859993985443079
# Compute control for a deterministic system
# Cost in iteration 0: 0.013859993985443079
# Cost in iteration 200: 0.0138599516807007
# Final cost : 0.0138599516807007
# Compute control for a deterministic system
# Cost in iteration 0: 0.0138599516807007
# Cost in iteration 200: 0.013859947686232454
# Final cost : 0.013859947686232454
# Compute control for a deterministic system
# Cost in iteration 0: 0.013859947686232454
# Cost in iteration 200: 0.013859945381080162
# Cost in iteration 400: 0.013859943771160637
# Final cost : 0.013859943771160637
# Compute control for a deterministic system
# Cost in iteration 0: 0.013859943771160637
# Cost in iteration 200: 0.013859941255031405
# Cost in iteration 400: 0.013859940358380278
# Cost in iteration 600: 0.013859940044632365
# Cost in iteration 800: 0.013859939937856497
# Cost in iteration 1000: 0.013859939900865585
# Final cost : 0.013859939900865585
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.015337451366332263
# Cost in iteration 200: 0.01517827755788575
# Final cost : 0.01517827755788575
# Compute control for a deterministic system
# Cost in iteration 0: 0.01517827755788575
# Cost in iteration 200: 0.01517823809710626
# Final cost : 0.01517823809710626
# Compute control for a deterministic system
# Cost in iteration 0: 0.01517823809710626
# Cost in iteration 200: 0.015178226611920411
# Final cost : 0.015178226611920411
# Compute control for a deterministic system
# Cost in iteration 0: 0.015178226611920411
# Cost in iteration 200: 0.015178219217096991
# Cost in iteration 400: 0.015178213668135286
# Final cost : 0.015178213668135286
# Compute control for a deterministic system
# Cost in iteration 0: 0.015178213668135286
# Cost in iteration 200: 0.015178204358855266
# Cost in iteration 400: 0.015178200032748048
# Cost in iteration 600: 0.0151781981710011
# Cost in iteration 800: 0.01517819736538203
# Cost in iteration 1000: 0.015178197020526833
# Final cost : 0.015178197020526833
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.02667228894443177
# Cost in iteration 200: 0.016474963604623936
# Final cost : 0.016474963604623936
# Compute control for a deterministic system
# Cost in iteration 0: 0.016474963604623936
# Converged in iteration 23 with cost 0.01647490883485615 because of vanishing difference
# Final cost : 0.01647490883485615
# Compute control for a deterministic system
# Cost in iteration 0: 0.01647490883485615
# Cost in iteration 200: 0.01647480859646262
# Final cost : 0.01647480859646262
# Compute control for a deterministic system
# Cost in iteration 0: 0.01647480859646262
# Cost in iteration 200: 0.016474769605843185
# Cost in iteration 400: 0.01647474420344524
# Final cost : 0.01647474420344524
# Compute control for a deterministic system
# Cost in iteration 0: 0.01647474420344524
# Cost in iteration 200: 0.016474703571300542
# Cost in iteration 400: 0.01647468247961233
# Cost in iteration 600: 0.016474671636269245
# Cost in iteration 800: 0.01647466620133893
# Cost in iteration 1000: 0.016474663538651093
# Final cost : 0.016474663538651093
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.04344354257937324
# Cost in iteration 200: 0.017725586586743686
# Final cost : 0.017725586586743686
# Compute control for a deterministic system
# Cost in iteration 0: 0.017725586586743686
# Converged in iteration 20 with cost 0.017725458710291905 because of vanishing difference
# Final cost : 0.017725458710291905
# Compute control for a deterministic system
# Cost in iteration 0: 0.017725458710291905
# Cost in iteration 200: 0.0177250391962459
# Final cost : 0.0177250391962459
# Compute control for a deterministic system
# Cost in iteration 0: 0.0177250391962459
# Cost in iteration 200: 0.017724810741707456
# Cost in iteration 400: 0.017724643915638206
# Final cost : 0.017724643915638206
# Compute control for a deterministic system
# Cost in iteration 0: 0.017724643915638206
# Cost in iteration 200: 0.017724345270455112
# Cost in iteration 400: 0.017724190637331563
# Cost in iteration 600: 0.01772409774355425
# Cost in iteration 800: 0.017724042111653657
# Cost in iteration 1000: 0.017724010514175378
# Final cost : 0.017724010514175378
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.021209445910597605
# Cost in iteration 200: 0.018990964803971427
# Final cost : 0.018990964803971427
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990964803971427
# Converged in iteration 2 with cost 0.018990964101057654 because of vanishing difference
# Final cost : 0.018990964101057654
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990964101057654
# Cost in iteration 200: 0.018990636966467717
# Final cost : 0.018990636966467717
# Compute control for a deterministic system
# Cost in iteration 0: 0.018990636966467717
# Cost in iteration 200: 0.018990423841679385
# Cost in iteration 400: 0.01899024673634272
# Final cost : 0.01899024673634272
# Compute control for a deterministic system
# Cost in iteration 0: 0.01899024673634272
# Cost in iteration 200: 0.018989915862310275
# Cost in iteration 400: 0.018989686470697074
# Cost in iteration 600: 0.01898953360654836
# Cost in iteration 800: 0.018989436161974117
# Cost in iteration 1000: 0.01898938154110687
# Final cost : 0.01898938154110687
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.030116323720808576
# Cost in iteration 200: 0.020251587781220826
# Final cost : 0.020251587781220826
# Compute control for a deterministic system
# Cost in iteration 0: 0.020251587781220826
# Converged in iteration 6 with cost 0.02025155882892233 because of vanishing difference
# Final cost : 0.02025155882892233
# Compute control for a deterministic system
# Cost in iteration 0: 0.02025155882892233
# Cost in iteration 200: 0.020250914540591927
# Final cost : 0.020250914540591927
# Compute control for a deterministic system
# Cost in iteration 0: 0.020250914540591927
# Cost in iteration 200: 0.020250431732196154
# Cost in iteration 400: 0.020250015336184528
# Final cost : 0.020250015336184528
# Compute control for a deterministic system
# Cost in iteration 0: 0.020250015336184528
# Cost in iteration 200: 0.020249369554314646
# Cost in iteration 400: 0.02024883627535726
# Cost in iteration 600: 0.020248399212598103
# Cost in iteration 800: 0.02024806553791443
# Cost in iteration 1000: 0.020247823929671487
# Final cost : 0.020247823929671487
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.022487014864783234
# Cost in iteration 200: 0.021474613942708855
# Final cost : 0.021474613942708855
# Compute control for a deterministic system
# Cost in iteration 0: 0.021474613942708855
# Cost in iteration 200: 0.021474494648126827
# Final cost : 0.021474494648126827
# Compute control for a deterministic system
# Cost in iteration 0: 0.021474494648126827
# Cost in iteration 200: 0.02147445064001558
# Final cost : 0.02147445064001558
# Compute control for a deterministic system
# Cost in iteration 0: 0.02147445064001558
# Cost in iteration 200: 0.021474423174515575
# Cost in iteration 400: 0.021474402951513285
# Final cost : 0.021474402951513285
# Compute control for a deterministic system
# Cost in iteration 0: 0.021474402951513285
# Cost in iteration 200: 0.021474375092854284
# Cost in iteration 400: 0.021474360567501436
# Cost in iteration 600: 0.021474352552449595
# Cost in iteration 800: 0.021474348227239124
# Cost in iteration 1000: 0.021474345788391854
# Final cost : 0.021474345788391854
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.06472505850379269
# Cost in iteration 200: 0.022766969335621782
# Final cost : 0.022766969335621782
# Compute control for a deterministic system
# Cost in iteration 0: 0.022766969335621782
# Cost in iteration 200: 0.022762721105178244
# Final cost : 0.022762721105178244
# Compute control for a deterministic system
# Cost in iteration 0: 0.022762721105178244
# Cost in iteration 200: 0.022758054572580476
# Final cost : 0.022758054572580476
# Compute control for a deterministic system
# Cost in iteration 0: 0.022758054572580476
# Cost in iteration 200: 0.02275499978058023
# Cost in iteration 400: 0.022752362221783357
# Final cost : 0.022752362221783357
# Compute control for a deterministic system
# Cost in iteration 0: 0.022752362221783357
# Cost in iteration 200: 0.022744118263442824
# Cost in iteration 400: 0.02274031048245999
# Cost in iteration 600: 0.022737628874469035
# Cost in iteration 800: 0.022736089834981963
# Cost in iteration 1000: 0.02273497607241692
# Final cost : 0.02273497607241692
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.02478954203834507
# Cost in iteration 200: 0.02403331261578373
# Final cost : 0.02403331261578373
# Compute control for a deterministic system
# Cost in iteration 0: 0.02403331261578373
# Cost in iteration 200: 0.02402832259216092
# Final cost : 0.02402832259216092
# Compute control for a deterministic system
# Cost in iteration 0: 0.02402832259216092
# Cost in iteration 200: 0.024024774788848183
# Final cost : 0.024024774788848183
# Compute control for a deterministic system
# Cost in iteration 0: 0.024024774788848183
# Cost in iteration 200: 0.024009880713794063
# Cost in iteration 400: 0.024008238195073424
# Final cost : 0.024008238195073424
# Compute control for a deterministic system
# Cost in iteration 0: 0.024008238195073424
# Cost in iteration 200: 0.02400631033045937
# Cost in iteration 400: 0.024004638062969107
# Cost in iteration 600: 0.02400322182289956
# Cost in iteration 800: 0.02400198232435247
# Cost in iteration 1000: 0.024000896659713084
# Final cost : 0.024000896659713084
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.026153775008775786
# Cost in iteration 200: 0.02529919379918823
# Final cost : 0.02529919379918823
# Compute control for a deterministic system
# Cost in iteration 0: 0.02529919379918823
# Cost in iteration 200: 0.02524190204260134
# Final cost : 0.02524190204260134
# Compute control for a deterministic system
# Cost in iteration 0: 0.02524190204260134
# Converged in iteration 28 with cost 0.02524157511735681 because of vanishing difference
# Final cost : 0.02524157511735681
# Compute control for a deterministic system
# Cost in iteration 0: 0.02524157511735681
# Cost in iteration 200: 0.025236707690994314
# Cost in iteration 400: 0.025235394094604763
# Final cost : 0.025235394094604763
# Compute control for a deterministic system
# Cost in iteration 0: 0.025235394094604763
# Cost in iteration 200: 0.025234167111456502
# Cost in iteration 400: 0.025233221074466308
# Cost in iteration 600: 0.02523250428953112
# Cost in iteration 800: 0.025231932408300854
# Cost in iteration 1000: 0.025231474011703354
# Final cost : 0.025231474011703354
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.04156048769021978
# Cost in iteration 200: 0.026507953377240344
# Final cost : 0.026507953377240344
# Compute control for a deterministic system
# Cost in iteration 0: 0.026507953377240344
# Converged in iteration 3 with cost 0.026507952419228275 because of vanishing difference
# Final cost : 0.026507952419228275
# Compute control for a deterministic system
# Cost in iteration 0: 0.026507952419228275
# Cost in iteration 200: 0.02650706517838417
# Final cost : 0.02650706517838417
# Compute control for a deterministic system
# Cost in iteration 0: 0.02650706517838417
# Cost in iteration 200: 0.026506411534289145
# Cost in iteration 400: 0.026505813729020986
# Final cost : 0.026505813729020986
# Compute control for a deterministic system
# Cost in iteration 0: 0.026505813729020986
# Cost in iteration 200: 0.0265048163881163
# Cost in iteration 400: 0.026503988454226343
# Cost in iteration 600: 0.026503262360822188
# Cost in iteration 800: 0.02650261997656492
# Cost in iteration 1000: 0.026502057067949343
# Final cost : 0.026502057067949343
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.04845527783598995
# Cost in iteration 200: 0.027856661213646182
# Final cost : 0.027856661213646182
# Compute control for a deterministic system
# Cost in iteration 0: 0.027856661213646182
# Cost in iteration 200: 0.027848661875218332
# Final cost : 0.027848661875218332
# Compute control for a deterministic system
# Cost in iteration 0: 0.027848661875218332
# Cost in iteration 200: 0.027838288048980656
# Final cost : 0.027838288048980656
# Compute control for a deterministic system
# Cost in iteration 0: 0.027838288048980656
# Cost in iteration 200: 0.027831389477943176
# Cost in iteration 400: 0.0278251163710567
# Final cost : 0.0278251163710567
# Compute control for a deterministic system
# Cost in iteration 0: 0.0278251163710567
# Cost in iteration 200: 0.027806124497585603
# Cost in iteration 400: 0.027792047421172993
# Cost in iteration 600: 0.02778289653385323
# Cost in iteration 800: 0.02777588051444148
# Cost in iteration 1000: 0.02777074813736357
# Final cost : 0.02777074813736357
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.05899218145953736
# Cost in iteration 200: 0.02753841602566872
# Final cost : 0.02753841602566872
# Compute control for a deterministic system
# Cost in iteration 0: 0.02753841602566872
# Cost in iteration 200: 0.027427118057729946
# Final cost : 0.027427118057729946
# Compute control for a deterministic system
# Cost in iteration 0: 0.027427118057729946
# Cost in iteration 200: 0.02742118909969233
# Final cost : 0.02742118909969233
# Compute control for a deterministic system
# Cost in iteration 0: 0.02742118909969233
# Cost in iteration 200: 0.02741368879008279
# Cost in iteration 400: 0.027408033906406587
# Final cost : 0.027408033906406587
# Compute control for a deterministic system
# Cost in iteration 0: 0.027408033906406587
# Cost in iteration 200: 0.02740467543500554
# Cost in iteration 400: 0.02740184278448005
# Cost in iteration 600: 0.02739943643026458
# Cost in iteration 800: 0.02739737902534021
# Cost in iteration 1000: 0.027395623254549743
# Final cost : 0.027395623254549743
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.04178464967152419
# Cost in iteration 200: 0.02578484339416259
# Final cost : 0.02578484339416259
# Compute control for a deterministic system
# Cost in iteration 0: 0.02578484339416259
# Cost in iteration 200: 0.02577959225625428
# Final cost : 0.02577959225625428
# Compute control for a deterministic system
# Cost in iteration 0: 0.02577959225625428
# Cost in iteration 200: 0.02577566084867755
# Final cost : 0.02577566084867755
# Compute control for a deterministic system
# Cost in iteration 0: 0.02577566084867755
# Cost in iteration 200: 0.025770895490799146
# Cost in iteration 400: 0.025767423209734595
# Final cost : 0.025767423209734595
# Compute control for a deterministic system
# Cost in iteration 0: 0.025767423209734595
# Cost in iteration 200: 0.025765160218933044
# Cost in iteration 400: 0.025763262604166066
# Cost in iteration 600: 0.02576166831665248
# Cost in iteration 800: 0.02576032570558477
# Cost in iteration 1000: 0.025759194399561577
# Final cost : 0.025759194399561577
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.04376584075860031
# Cost in iteration 200: 0.024289158494269648
# Final cost : 0.024289158494269648
# Compute control for a deterministic system
# Cost in iteration 0: 0.024289158494269648
# Cost in iteration 200: 0.024194870563448285
# Final cost : 0.024194870563448285
# Compute control for a deterministic system
# Cost in iteration 0: 0.024194870563448285
# Converged in iteration 92 with cost 0.024193417810605036 because of vanishing difference
# Final cost : 0.024193417810605036
# Compute control for a deterministic system
# Cost in iteration 0: 0.024193417810605036
# Cost in iteration 200: 0.024188369380338706
# Cost in iteration 400: 0.024184871166037233
# Final cost : 0.024184871166037233
# Compute control for a deterministic system
# Cost in iteration 0: 0.024184871166037233
# Cost in iteration 200: 0.02418265564057147
# Cost in iteration 400: 0.024180844443051693
# Cost in iteration 600: 0.024179350408136364
# Cost in iteration 800: 0.02417812418630835
# Cost in iteration 1000: 0.024177101699178433
# Final cost : 0.024177101699178433
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.05333928935518045
# Cost in iteration 200: 0.022657227782549753
# Final cost : 0.022657227782549753
# Compute control for a deterministic system
# Cost in iteration 0: 0.022657227782549753
# Cost in iteration 200: 0.022575664013276903
# Final cost : 0.022575664013276903
# Compute control for a deterministic system
# Cost in iteration 0: 0.022575664013276903
# Cost in iteration 200: 0.02257153445395345
# Final cost : 0.02257153445395345
# Compute control for a deterministic system
# Cost in iteration 0: 0.02257153445395345
# Cost in iteration 200: 0.022570627132621868
# Cost in iteration 400: 0.02256989616102164
# Final cost : 0.02256989616102164
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256989616102164
# Cost in iteration 200: 0.02256935043234189
# Cost in iteration 400: 0.02256890884353192
# Cost in iteration 600: 0.022568549519778373
# Cost in iteration 800: 0.022568253548062214
# Cost in iteration 1000: 0.022568013788263726
# Final cost : 0.022568013788263726
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.02472235317565865
# Cost in iteration 200: 0.02097846841829693
# Final cost : 0.02097846841829693
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097846841829693
# Cost in iteration 200: 0.02097727411244403
# Final cost : 0.02097727411244403
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097727411244403
# Cost in iteration 200: 0.02097521540657327
# Final cost : 0.02097521540657327
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097521540657327
# Cost in iteration 200: 0.02097465353843795
# Cost in iteration 400: 0.02097423018325056
# Final cost : 0.02097423018325056
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097423018325056
# Cost in iteration 200: 0.020973939589497004
# Cost in iteration 400: 0.02097371001977784
# Cost in iteration 600: 0.02097352743079181
# Cost in iteration 800: 0.020973382111694062
# Cost in iteration 1000: 0.020973265914502635
# Final cost : 0.020973265914502635
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.02764227804634954
# Cost in iteration 200: 0.01942832866988991
# Final cost : 0.01942832866988991
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942832866988991
# Converged in iteration 28 with cost 0.01942820929544719 because of vanishing difference
# Final cost : 0.01942820929544719
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942820929544719
# Cost in iteration 200: 0.01942673193076951
# Final cost : 0.01942673193076951
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942673193076951
# Cost in iteration 200: 0.0194262126995237
# Cost in iteration 400: 0.019425828206358645
# Final cost : 0.019425828206358645
# Compute control for a deterministic system
# Cost in iteration 0: 0.019425828206358645
# Cost in iteration 200: 0.01942557754811174
# Cost in iteration 400: 0.019425385769639633
# Cost in iteration 600: 0.019425237926105166
# Cost in iteration 800: 0.019425123794487482
# Cost in iteration 1000: 0.019425036304787306
# Final cost : 0.019425036304787306
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.027707227289088445
# Cost in iteration 200: 0.017853549456426938
# Final cost : 0.017853549456426938
# Compute control for a deterministic system
# Cost in iteration 0: 0.017853549456426938
# Converged in iteration 15 with cost 0.017853498485723582 because of vanishing difference
# Final cost : 0.017853498485723582
# Compute control for a deterministic system
# Cost in iteration 0: 0.017853498485723582
# Cost in iteration 200: 0.017852348226525185
# Final cost : 0.017852348226525185
# Compute control for a deterministic system
# Cost in iteration 0: 0.017852348226525185
# Cost in iteration 200: 0.017851995873082012
# Cost in iteration 400: 0.017851768086487783
# Final cost : 0.017851768086487783
# Compute control for a deterministic system
# Cost in iteration 0: 0.017851768086487783
# Cost in iteration 200: 0.01785161327960426
# Cost in iteration 400: 0.017851499593485518
# Cost in iteration 600: 0.0178514158140733
# Cost in iteration 800: 0.017851354135939947
# Cost in iteration 1000: 0.017851308586648743
# Final cost : 0.017851308586648743
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.0288481603622983
# Cost in iteration 200: 0.016341169636207787
# Final cost : 0.016341169636207787
# Compute control for a deterministic system
# Cost in iteration 0: 0.016341169636207787
# Cost in iteration 200: 0.01628959192476772
# Final cost : 0.01628959192476772
# Compute control for a deterministic system
# Cost in iteration 0: 0.01628959192476772
# Cost in iteration 200: 0.016289039662182127
# Final cost : 0.016289039662182127
# Compute control for a deterministic system
# Cost in iteration 0: 0.016289039662182127
# Cost in iteration 200: 0.016288867716997977
# Cost in iteration 400: 0.016288753782183942
# Final cost : 0.016288753782183942
# Compute control for a deterministic system
# Cost in iteration 0: 0.016288753782183942
# Cost in iteration 200: 0.01628868581471532
# Cost in iteration 400: 0.016288638553131368
# Cost in iteration 600: 0.016288605385732097
# Cost in iteration 800: 0.01628858225512673
# Cost in iteration 1000: 0.016288566057849348
# Final cost : 0.016288566057849348
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.01487015852329118
# Cost in iteration 200: 0.014772152302444148
# Final cost : 0.014772152302444148
# Compute control for a deterministic system
# Cost in iteration 0: 0.014772152302444148
# Cost in iteration 200: 0.014771969356256172
# Final cost : 0.014771969356256172
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771969356256172
# Cost in iteration 200: 0.014771785630758217
# Final cost : 0.014771785630758217
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771785630758217
# Cost in iteration 200: 0.014771726620554699
# Cost in iteration 400: 0.014771689268597536
# Final cost : 0.014771689268597536
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771689268597536
# Cost in iteration 200: 0.014771668435113483
# Cost in iteration 400: 0.014771654845829143
# Cost in iteration 600: 0.014771645962126163
# Cost in iteration 800: 0.01477164015261802
# Cost in iteration 1000: 0.014771636356525845
# Final cost : 0.014771636356525845
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.01579902519758591
# Cost in iteration 200: 0.013229958054968561
# Final cost : 0.013229958054968561
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229958054968561
# Cost in iteration 200: 0.013229864711833858
# Final cost : 0.013229864711833858
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229864711833858
# Cost in iteration 200: 0.013229787420571714
# Final cost : 0.013229787420571714
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229787420571714
# Cost in iteration 200: 0.013229764544958061
# Cost in iteration 400: 0.013229751475978416
# Final cost : 0.013229751475978416
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229751475978416
# Cost in iteration 200: 0.0132297450757012
# Cost in iteration 400: 0.013229741233734216
# Cost in iteration 600: 0.013229738955966215
# Cost in iteration 800: 0.013229737592447922
# Cost in iteration 1000: 0.013229736781089383
# Final cost : 0.013229736781089383
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.013642568630182374
# Converged in iteration 198 with cost 0.011698335386647083 because of vanishing difference
# Final cost : 0.011698335386647083
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698335386647083
# Cost in iteration 200: 0.011698313923626054
# Final cost : 0.011698313923626054
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698313923626054
# Cost in iteration 200: 0.011698305606928174
# Final cost : 0.011698305606928174
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698305606928174
# Cost in iteration 200: 0.01169830361929701
# Cost in iteration 400: 0.01169830261947686
# Final cost : 0.01169830261947686
# Compute control for a deterministic system
# Cost in iteration 0: 0.01169830261947686
# Cost in iteration 200: 0.011698302144456208
# Cost in iteration 400: 0.011698301893105292
# Cost in iteration 600: 0.011698301760096426
# Cost in iteration 800: 0.011698301689860911
# Cost in iteration 1000: 0.011698301652467312
# Final cost : 0.011698301652467312
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.011809749788330805
# Converged in iteration 174 with cost 0.010211911150551069 because of vanishing difference
# Final cost : 0.010211911150551069
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211911150551069
# Cost in iteration 200: 0.010211905794350554
# Final cost : 0.010211905794350554
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211905794350554
# Cost in iteration 200: 0.010211904644219555
# Final cost : 0.010211904644219555
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211904644219555
# Cost in iteration 200: 0.010211904469124528
# Cost in iteration 400: 0.010211904405694179
# Final cost : 0.010211904405694179
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211904405694179
# Cost in iteration 200: 0.01021190438392818
# Cost in iteration 400: 0.010211904374119651
# Cost in iteration 600: 0.010211904369720514
# Cost in iteration 800: 0.010211904367746764
# Converged in iteration 882 with cost 0.010211904367061053 because of step counter
# Final cost : 0.010211904367061053
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.011129062504371373
# Converged in iteration 163 with cost 0.008701526195493072 because of vanishing difference
# Final cost : 0.008701526195493072
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701526195493072
# Cost in iteration 200: 0.008701515518134622
# Final cost : 0.008701515518134622
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701515518134622
# Cost in iteration 200: 0.008701514633192384
# Final cost : 0.008701514633192384
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514633192384
# Cost in iteration 200: 0.008701514586023319
# Cost in iteration 400: 0.008701514576654369
# Final cost : 0.008701514576654369
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514576654369
# Cost in iteration 200: 0.008701514574388251
# Converged in iteration 321 with cost 0.00870151457377939 because of step counter
# Final cost : 0.00870151457377939
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.008902936269207037
# Cost in iteration 200: 0.007235887677069817
# Final cost : 0.007235887677069817
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235887677069817
# Cost in iteration 200: 0.007235884796037651
# Final cost : 0.007235884796037651
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235884796037651
# Cost in iteration 200: 0.00723588457593163
# Final cost : 0.00723588457593163
# Compute control for a deterministic system
# Cost in iteration 0: 0.00723588457593163
# Cost in iteration 200: 0.007235884569520125
# Converged in iteration 232 with cost 0.007235884569295597 because of step counter
# Final cost : 0.007235884569295597
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235884569295597
# Converged in iteration 1 with cost 0.007235884569295597 because of step counter
# Final cost : 0.007235884569295597
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.007063877169762983
# Cost in iteration 200: 0.005747036249123852
# Final cost : 0.005747036249123852
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747036249123852
# Cost in iteration 200: 0.005747032417494616
# Final cost : 0.005747032417494616
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747032417494616
# Cost in iteration 200: 0.005747032353963179
# Final cost : 0.005747032353963179
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747032353963179
# Converged in iteration 161 with cost 0.005747032352903338 because of step counter
# Final cost : 0.005747032352903338
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747032352903338
# Converged in iteration 17 with cost 0.005747032352803119 because of step counter
# Final cost : 0.005747032352803119
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.004410823240413258
# Converged in iteration 177 with cost 0.004269631915947419 because of vanishing difference
# Final cost : 0.004269631915947419
# Compute control for a deterministic system
# Cost in iteration 0: 0.004269631915947419
# Cost in iteration 200: 0.0042696310184142
# Final cost : 0.0042696310184142
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042696310184142
# Converged in iteration 146 with cost 0.00426963101071655 because of step counter
# Final cost : 0.00426963101071655
# Compute control for a deterministic system
# Cost in iteration 0: 0.00426963101071655
# Converged in iteration 6 with cost 0.004269631010706175 because of step counter
# Final cost : 0.004269631010706175
# Compute control for a deterministic system
# Cost in iteration 0: 0.004269631010706175
# Converged in iteration 1 with cost 0.004269631010706175 because of step counter
# Final cost : 0.004269631010706175
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029554719001665414
# Converged in iteration 122 with cost 0.0028380299998444084 because of vanishing difference
# Final cost : 0.0028380299998444084
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380299998444084
# Cost in iteration 200: 0.0028380249576335213
# Final cost : 0.0028380249576335213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380249576335213
# Converged in iteration 112 with cost 0.0028380249532909524 because of step counter
# Final cost : 0.0028380249532909524
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380249532909524
# Converged in iteration 2 with cost 0.0028380249532901445 because of step counter
# Final cost : 0.0028380249532901445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380249532901445
# Converged in iteration 1 with cost 0.0028380249532901445 because of step counter
# Final cost : 0.0028380249532901445
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.001402363693326122
# Converged in iteration 81 with cost 0.0013891655494701147 because of vanishing difference
# Final cost : 0.0013891655494701147
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891655494701147
# Converged in iteration 79 with cost 0.0013891634496033575 because of step counter
# Final cost : 0.0013891634496033575
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634496033575
# Converged in iteration 1 with cost 0.0013891634496033575 because of step counter
# Final cost : 0.0013891634496033575
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634496033575
# Converged in iteration 1 with cost 0.0013891634496033575 because of step counter
# Final cost : 0.0013891634496033575
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634496033575
# Converged in iteration 1 with cost 0.0013891634496033575 because of step counter
# Final cost : 0.0013891634496033575
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013957836648864404
# Converged in iteration 119 with cost 0.001392870679635211 because of step counter
# Final cost : 0.001392870679635211
# Compute control for a deterministic system
# Cost in iteration 0: 0.001392870679635211
# Converged in iteration 2 with cost 0.0013928706796325853 because of step counter
# Final cost : 0.0013928706796325853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928706796325853
# Converged in iteration 1 with cost 0.0013928706796325853 because of step counter
# Final cost : 0.0013928706796325853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928706796325853
# Converged in iteration 1 with cost 0.0013928706796325853 because of step counter
# Final cost : 0.0013928706796325853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013928706796325853
# Converged in iteration 1 with cost 0.0013928706796325853 because of step counter
# Final cost : 0.0013928706796325853
# -----------------------------------------------
# 5 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028041554843620956
# Converged in iteration 51 with cost 0.0027865700538698863 because of vanishing difference
# Final cost : 0.0027865700538698863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027865700538698863
# Converged in iteration 99 with cost 0.00278656857668288 because of step counter
# Final cost : 0.00278656857668288
# Compute control for a deterministic system
# Cost in iteration 0: 0.00278656857668288
# Converged in iteration 1 with cost 0.00278656857668288 because of step counter
# Final cost : 0.00278656857668288
# Compute control for a deterministic system
# Cost in iteration 0: 0.00278656857668288
# Converged in iteration 1 with cost 0.00278656857668288 because of step counter
# Final cost : 0.00278656857668288
# Compute control for a deterministic system
# Cost in iteration 0: 0.00278656857668288
# Converged in iteration 1 with cost 0.00278656857668288 because of step counter
# Final cost : 0.00278656857668288
# -----------------------------------------------
# 5 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.004212958101421871
# Converged in iteration 77 with cost 0.004212957059773818 because of step counter
# Final cost : 0.004212957059773818
# Compute control for a deterministic system
# Cost in iteration 0: 0.004212957059773818
# Converged in iteration 2 with cost 0.004212957059772016 because of step counter
# Final cost : 0.004212957059772016
# Compute control for a deterministic system
# Cost in iteration 0: 0.004212957059772016
# Converged in iteration 2 with cost 0.0042129570597713275 because of step counter
# Final cost : 0.0042129570597713275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129570597713275
# Converged in iteration 1 with cost 0.0042129570597713275 because of step counter
# Final cost : 0.0042129570597713275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042129570597713275
# Converged in iteration 1 with cost 0.0042129570597713275 because of step counter
# Final cost : 0.0042129570597713275
# -----------------------------------------------
# 5 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.006602054238893148
# Converged in iteration 79 with cost 0.005635796458509249 because of vanishing difference
# Final cost : 0.005635796458509249
# Compute control for a deterministic system
# Cost in iteration 0: 0.005635796458509249
# Cost in iteration 200: 0.005635776193206228
# Final cost : 0.005635776193206228
# Compute control for a deterministic system
# Cost in iteration 0: 0.005635776193206228
# Converged in iteration 43 with cost 0.00563577619294175 because of step counter
# Final cost : 0.00563577619294175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00563577619294175
# Converged in iteration 2 with cost 0.0056357761929378735 because of step counter
# Final cost : 0.0056357761929378735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056357761929378735
# Converged in iteration 4 with cost 0.005635776192880174 because of step counter
# Final cost : 0.005635776192880174
# Compute control for a deterministic system
# Cost in iteration 0: 0.00966916140267448
# Converged in iteration 137 with cost 0.007021108127581376 because of vanishing difference
# Final cost : 0.007021108127581376
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021108127581376
# Cost in iteration 200: 0.00702109918407281
# Final cost : 0.00702109918407281
# Compute control for a deterministic system
# Cost in iteration 0: 0.00702109918407281
# Cost in iteration 200: 0.0070210991630519385
# Final cost : 0.0070210991630519385
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070210991630519385
# Cost in iteration 200: 0.007021099160885709
# Converged in iteration 203 with cost 0.007021099160877326 because of step counter
# Final cost : 0.007021099160877326
# Compute control for a deterministic system
# ...
# Cost in iteration 800: 0.024172781087757746
# Cost in iteration 1000: 0.024172649957220117
# Final cost : 0.024172649957220117
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.03206735313487183
# Cost in iteration 200: 0.02256785702008904
# Final cost : 0.02256785702008904
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256785702008904
# Converged in iteration 23 with cost 0.022567823038038465 because of vanishing difference
# Final cost : 0.022567823038038465
# Compute control for a deterministic system
# Cost in iteration 0: 0.022567823038038465
# Cost in iteration 200: 0.02256749370947702
# Final cost : 0.02256749370947702
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256749370947702
# Cost in iteration 200: 0.022567376534708545
# Cost in iteration 400: 0.022567281851652424
# Final cost : 0.022567281851652424
# Compute control for a deterministic system
# Cost in iteration 0: 0.022567281851652424
# Cost in iteration 200: 0.022567215559273185
# Cost in iteration 400: 0.022567161046979718
# Cost in iteration 600: 0.022567116202786956
# Cost in iteration 800: 0.022567079295160254
# Cost in iteration 1000: 0.02256704889729081
# Final cost : 0.02256704889729081
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.021181635434480244
# Cost in iteration 200: 0.02097316676604929
# Final cost : 0.02097316676604929
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097316676604929
# Cost in iteration 200: 0.020973094678540777
# Final cost : 0.020973094678540777
# Compute control for a deterministic system
# Cost in iteration 0: 0.020973094678540777
# Cost in iteration 200: 0.020972980165058778
# Final cost : 0.020972980165058778
# Compute control for a deterministic system
# Cost in iteration 0: 0.020972980165058778
# Cost in iteration 200: 0.02097293952172623
# Cost in iteration 400: 0.02097290841340468
# Final cost : 0.02097290841340468
# Compute control for a deterministic system
# Cost in iteration 0: 0.02097290841340468
# Cost in iteration 200: 0.020972887518687297
# Cost in iteration 400: 0.020972870647584567
# Cost in iteration 600: 0.020972857199204956
# Cost in iteration 800: 0.020972846434366244
# Cost in iteration 1000: 0.020972837779211828
# Final cost : 0.020972837779211828
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.024605792915569975
# Cost in iteration 200: 0.019425003746505447
# Final cost : 0.019425003746505447
# Compute control for a deterministic system
# Cost in iteration 0: 0.019425003746505447
# Cost in iteration 200: 0.019424933585979146
# Final cost : 0.019424933585979146
# Compute control for a deterministic system
# Cost in iteration 0: 0.019424933585979146
# Cost in iteration 200: 0.019424848095705216
# Final cost : 0.019424848095705216
# Compute control for a deterministic system
# Cost in iteration 0: 0.019424848095705216
# Cost in iteration 200: 0.01942482046432904
# Cost in iteration 400: 0.019424799710231637
# Final cost : 0.019424799710231637
# Compute control for a deterministic system
# Cost in iteration 0: 0.019424799710231637
# Cost in iteration 200: 0.01942478550061953
# Cost in iteration 400: 0.019424774630442388
# Cost in iteration 600: 0.019424766197290846
# Cost in iteration 800: 0.019424759700836864
# Cost in iteration 1000: 0.019424754633693215
# Final cost : 0.019424754633693215
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.022681960192233733
# Converged in iteration 162 with cost 0.0178513199651824 because of vanishing difference
# Final cost : 0.0178513199651824
# Compute control for a deterministic system
# Cost in iteration 0: 0.0178513199651824
# Cost in iteration 200: 0.017851266924003958
# Final cost : 0.017851266924003958
# Compute control for a deterministic system
# Cost in iteration 0: 0.017851266924003958
# Cost in iteration 200: 0.01785122735698434
# Final cost : 0.01785122735698434
# Compute control for a deterministic system
# Cost in iteration 0: 0.01785122735698434
# Cost in iteration 200: 0.01785121261539417
# Cost in iteration 400: 0.01785120242647565
# Final cost : 0.01785120242647565
# Compute control for a deterministic system
# Cost in iteration 0: 0.01785120242647565
# Cost in iteration 200: 0.01785119595865161
# Cost in iteration 400: 0.017851191180327648
# Cost in iteration 600: 0.017851187644403715
# Cost in iteration 800: 0.017851185028090702
# Cost in iteration 1000: 0.017851183080162418
# Final cost : 0.017851183080162418
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.017347000405424525
# Cost in iteration 200: 0.01628855718284327
# Final cost : 0.01628855718284327
# Compute control for a deterministic system
# Cost in iteration 0: 0.01628855718284327
# Cost in iteration 200: 0.016288546996953163
# Final cost : 0.016288546996953163
# Compute control for a deterministic system
# Cost in iteration 0: 0.016288546996953163
# Cost in iteration 200: 0.016288537568395642
# Final cost : 0.016288537568395642
# Compute control for a deterministic system
# Cost in iteration 0: 0.016288537568395642
# Cost in iteration 200: 0.016288534101249495
# Cost in iteration 400: 0.016288531758854526
# Final cost : 0.016288531758854526
# Compute control for a deterministic system
# Cost in iteration 0: 0.016288531758854526
# Cost in iteration 200: 0.016288530278728026
# Cost in iteration 400: 0.01628852924416436
# Cost in iteration 600: 0.01628852851221483
# Cost in iteration 800: 0.016288527999419235
# Cost in iteration 1000: 0.016288527639546878
# Final cost : 0.016288527639546878
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.01491016050746798
# Cost in iteration 200: 0.014771634394207428
# Final cost : 0.014771634394207428
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771634394207428
# Cost in iteration 200: 0.014771632460841138
# Final cost : 0.014771632460841138
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771632460841138
# Cost in iteration 200: 0.014771630663479623
# Final cost : 0.014771630663479623
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771630663479623
# Cost in iteration 200: 0.014771630055450827
# Cost in iteration 400: 0.014771629674145985
# Final cost : 0.014771629674145985
# Compute control for a deterministic system
# Cost in iteration 0: 0.014771629674145985
# Cost in iteration 200: 0.014771629462559867
# Cost in iteration 400: 0.014771629324232162
# Cost in iteration 600: 0.014771629233050022
# Cost in iteration 800: 0.014771629173356811
# Cost in iteration 1000: 0.014771629134244069
# Final cost : 0.014771629134244069
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.01347262102298274
# Converged in iteration 159 with cost 0.013229737782256655 because of vanishing difference
# Final cost : 0.013229737782256655
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229737782256655
# Cost in iteration 200: 0.01322973620145266
# Final cost : 0.01322973620145266
# Compute control for a deterministic system
# Cost in iteration 0: 0.01322973620145266
# Cost in iteration 200: 0.0132297358175777
# Final cost : 0.0132297358175777
# Compute control for a deterministic system
# Cost in iteration 0: 0.0132297358175777
# Cost in iteration 200: 0.013229735690777747
# Cost in iteration 400: 0.013229735625989416
# Final cost : 0.013229735625989416
# Compute control for a deterministic system
# Cost in iteration 0: 0.013229735625989416
# Cost in iteration 200: 0.013229735596947508
# Cost in iteration 400: 0.013229735579606617
# Cost in iteration 600: 0.013229735569257555
# Cost in iteration 800: 0.013229735563042438
# Cost in iteration 1000: 0.013229735559331088
# Final cost : 0.013229735559331088
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.013706388795892593
# Cost in iteration 200: 0.01169831089193485
# Final cost : 0.01169831089193485
# Compute control for a deterministic system
# Cost in iteration 0: 0.01169831089193485
# Cost in iteration 200: 0.011698301990720595
# Final cost : 0.011698301990720595
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698301990720595
# Cost in iteration 200: 0.011698301808495444
# Final cost : 0.011698301808495444
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698301808495444
# Cost in iteration 200: 0.011698301802227303
# Cost in iteration 400: 0.011698301800242398
# Final cost : 0.011698301800242398
# Compute control for a deterministic system
# Cost in iteration 0: 0.011698301800242398
# Converged in iteration 78 with cost 0.011698301799940004 because of step counter
# Final cost : 0.011698301799940004
# Compute control for a deterministic system
# Cost in iteration 0: 0.01294938173700556
# Converged in iteration 185 with cost 0.010211911816949477 because of vanishing difference
# Final cost : 0.010211911816949477
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211911816949477
# Cost in iteration 200: 0.010211905252871419
# Final cost : 0.010211905252871419
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211905252871419
# Cost in iteration 200: 0.010211904502330222
# Final cost : 0.010211904502330222
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211904502330222
# Cost in iteration 200: 0.01021190446941051
# Cost in iteration 400: 0.010211904462052094
# Final cost : 0.010211904462052094
# Compute control for a deterministic system
# Cost in iteration 0: 0.010211904462052094
# Cost in iteration 200: 0.010211904459864687
# Converged in iteration 257 with cost 0.010211904459546766 because of step counter
# Final cost : 0.010211904459546766
# Compute control for a deterministic system
# Cost in iteration 0: 0.009315060696104736
# Cost in iteration 200: 0.008701514797567693
# Final cost : 0.008701514797567693
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514797567693
# Cost in iteration 200: 0.008701514491529777
# Final cost : 0.008701514491529777
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514491529777
# Cost in iteration 200: 0.008701514468354998
# Final cost : 0.008701514468354998
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514468354998
# Converged in iteration 124 with cost 0.008701514467551462 because of step counter
# Final cost : 0.008701514467551462
# Compute control for a deterministic system
# Cost in iteration 0: 0.008701514467551462
# Converged in iteration 15 with cost 0.008701514467515135 because of step counter
# Final cost : 0.008701514467515135
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.007351624130962595
# Converged in iteration 82 with cost 0.007235887339835048 because of vanishing difference
# Final cost : 0.007235887339835048
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235887339835048
# Cost in iteration 200: 0.007235884605577082
# Final cost : 0.007235884605577082
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235884605577082
# Cost in iteration 200: 0.007235884572577495
# Final cost : 0.007235884572577495
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235884572577495
# Converged in iteration 148 with cost 0.007235884571308655 because of step counter
# Final cost : 0.007235884571308655
# Compute control for a deterministic system
# Cost in iteration 0: 0.007235884571308655
# Converged in iteration 1 with cost 0.007235884571308655 because of step counter
# Final cost : 0.007235884571308655
# Compute control for a deterministic system
# Cost in iteration 0: 0.00619795714843387
# Converged in iteration 129 with cost 0.0057470362075964345 because of vanishing difference
# Final cost : 0.0057470362075964345
# Compute control for a deterministic system
# Cost in iteration 0: 0.0057470362075964345
# Cost in iteration 200: 0.005747032176924149
# Final cost : 0.005747032176924149
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747032176924149
# Cost in iteration 200: 0.00574703215113833
# Final cost : 0.00574703215113833
# Compute control for a deterministic system
# Cost in iteration 0: 0.00574703215113833
# Converged in iteration 44 with cost 0.005747032150834887 because of step counter
# Final cost : 0.005747032150834887
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747032150834887
# Converged in iteration 37 with cost 0.005747032150554978 because of step counter
# Final cost : 0.005747032150554978
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.004394100760907421
# Cost in iteration 200: 0.004269630909598073
# Final cost : 0.004269630909598073
# Compute control for a deterministic system
# Cost in iteration 0: 0.004269630909598073
# Converged in iteration 121 with cost 0.004269630903913554 because of step counter
# Final cost : 0.004269630903913554
# Compute control for a deterministic system
# Cost in iteration 0: 0.004269630903913554
# Converged in iteration 24 with cost 0.00426963090371442 because of step counter
# Final cost : 0.00426963090371442
# Compute control for a deterministic system
# Cost in iteration 0: 0.00426963090371442
# Converged in iteration 14 with cost 0.004269630903684405 because of step counter
# Final cost : 0.004269630903684405
# Compute control for a deterministic system
# Cost in iteration 0: 0.004269630903684405
# Converged in iteration 9 with cost 0.004269630903658037 because of step counter
# Final cost : 0.004269630903658037
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031579629553524745
# Converged in iteration 58 with cost 0.002838029597574879 because of vanishing difference
# Final cost : 0.002838029597574879
# Compute control for a deterministic system
# Cost in iteration 0: 0.002838029597574879
# Cost in iteration 200: 0.0028380248865569778
# Final cost : 0.0028380248865569778
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380248865569778
# Converged in iteration 91 with cost 0.0028380248847551426 because of step counter
# Final cost : 0.0028380248847551426
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380248847551426
# Converged in iteration 2 with cost 0.0028380248847549566 because of step counter
# Final cost : 0.0028380248847549566
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028380248847549566
# Converged in iteration 1 with cost 0.0028380248847549566 because of step counter
# Final cost : 0.0028380248847549566
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014906897693460152
# Converged in iteration 53 with cost 0.0013891640605516783 because of vanishing difference
# Final cost : 0.0013891640605516783
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891640605516783
# Converged in iteration 53 with cost 0.0013891634490995845 because of step counter
# Final cost : 0.0013891634490995845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634490995845
# Converged in iteration 2 with cost 0.0013891634490977491 because of step counter
# Final cost : 0.0013891634490977491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634490977491
# Converged in iteration 1 with cost 0.0013891634490977491 because of step counter
# Final cost : 0.0013891634490977491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013891634490977491
# Converged in iteration 1 with cost 0.0013891634490977491 because of step counter
# Final cost : 0.0013891634490977491

# %%
save(results_min)
