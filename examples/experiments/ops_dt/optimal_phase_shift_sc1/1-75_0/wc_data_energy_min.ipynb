# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.390687755422495 
y_init = 0.46070476656497017
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,183], wc.inh[0,183]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.20823994240047755 0.10333216754118275
# minima =  [  500  2002  3501  5001  6501  8001  9501 11001 12500 14000 15500 17000
#  18500 20000 21499 22999 24499 25999 27499 28999 30498 31998 33498 34998
#  36498 37997 39497]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s2_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s2_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [True, True, True]
#options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05597484015996037
# Final cost : 0.03061353280747869
# Compute control for a deterministic system
# Cost in iteration 0: 0.03061353280747869
# Final cost : 0.0002434073218947377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002434073218947377
# Final cost : 0.0002364018762161537
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002364018762161537
# Converged in iteration 353 with cost 0.0002364018692243441 because of step counter
# Final cost : 0.0002364018692243441
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002364018692243441
# Converged in iteration 1 with cost 0.0002364018692243441 because of step counter
# Final cost : 0.0002364018692243441
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002364018692243441
# Converged in iteration 15 with cost 0.00023640186921842008 because of step counter
# Final cost : 0.00023640186921842008
# Compute control for a deterministic system
# Cost in iteration 0: 0.2268169979617528
# Final cost : 0.12778307965239705
# Compute control for a deterministic system
# Cost in iteration 0: 0.12778307965239705
# Final cost : 0.0010142031287424956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010142031287424956
# Final cost : 0.000969336232920603
# Compute control for a deterministic system
# Cost in iteration 0: 0.000969336232920603
# Converged in iteration 669 with cost 0.0009693358393931835 because of step counter
# Final cost : 0.0009693358393931835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009693358393931835
# Converged in iteration 1 with cost 0.0009693358393931835 because of step counter
# Final cost : 0.0009693358393931835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009693358393931835
# Converged in iteration 1 with cost 0.0009693358393931835 because of step counter
# Final cost : 0.0009693358393931835
# Compute control for a deterministic system
# Cost in iteration 0: 0.49463945206848964
# Final cost : 0.290432377684749
# Compute control for a deterministic system
# Cost in iteration 0: 0.290432377684749
# Final cost : 0.002309723048531506
# Compute control for a deterministic system
# Cost in iteration 0: 0.002309723048531506
# Final cost : 0.002157359694726357
# Compute control for a deterministic system
# Cost in iteration 0: 0.002157359694726357
# Converged in iteration 895 with cost 0.0021573551563235684 because of step counter
# Final cost : 0.0021573551563235684
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021573551563235684
# Converged in iteration 1 with cost 0.0021573551563235684 because of step counter
# Final cost : 0.0021573551563235684
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021573551563235684
# Converged in iteration 1 with cost 0.0021573551563235684 because of step counter
# Final cost : 0.0021573551563235684
# Compute control for a deterministic system
# Cost in iteration 0: 0.8609128013808958
# Final cost : 0.5307856056014822
# Compute control for a deterministic system
# Cost in iteration 0: 0.5307856056014822
# Final cost : 0.004253493331860204
# Compute control for a deterministic system
# Cost in iteration 0: 0.004253493331860204
# Final cost : 0.0038616996022139615
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038616996022139615
# Final cost : 0.0038616809622498732
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038616809622498732
# Converged in iteration 58 with cost 0.003861680962127715 because of step counter
# Final cost : 0.003861680962127715
# Compute control for a deterministic system
# Cost in iteration 0: 0.003861680962127715
# Converged in iteration 1 with cost 0.003861680962127715 because of step counter
# Final cost : 0.003861680962127715
# Compute control for a deterministic system
# Cost in iteration 0: 1.292238864168766
# Final cost : 0.83701363254698
# Compute control for a deterministic system
# Cost in iteration 0: 0.83701363254698
# Final cost : 0.006800980104078216
# Compute control for a deterministic system
# Cost in iteration 0: 0.006800980104078216
# Final cost : 0.0059896134987076285
# Compute control for a deterministic system
# Cost in iteration 0: 0.0059896134987076285
# Final cost : 0.005989551424865242
# Compute control for a deterministic system
# Cost in iteration 0: 0.005989551424865242
# Converged in iteration 237 with cost 0.005989551423830953 because of step counter
# Final cost : 0.005989551423830953
# Compute control for a deterministic system
# Cost in iteration 0: 0.005989551423830953
# Converged in iteration 1 with cost 0.005989551423830953 because of step counter
# Final cost : 0.005989551423830953
# Compute control for a deterministic system
# Cost in iteration 0: 1.796907085101933
# Final cost : 1.223421938765264
# Compute control for a deterministic system
# Cost in iteration 0: 1.223421938765264
# Final cost : 0.01015272684049876
# Compute control for a deterministic system
# Cost in iteration 0: 0.01015272684049876
# Final cost : 0.008652315097093287
# Compute control for a deterministic system
# Cost in iteration 0: 0.008652315097093287
# Final cost : 0.00865217814508959
# Compute control for a deterministic system
# Cost in iteration 0: 0.00865217814508959
# Converged in iteration 392 with cost 0.008652178138097379 because of step counter
# Final cost : 0.008652178138097379
# Compute control for a deterministic system
# Cost in iteration 0: 0.008652178138097379
# Converged in iteration 1 with cost 0.008652178138097379 because of step counter
# Final cost : 0.008652178138097379
# Compute control for a deterministic system
# Cost in iteration 0: 2.333924033036714
# Final cost : 1.6646635596622406
# Compute control for a deterministic system
# Cost in iteration 0: 1.6646635596622406
# Final cost : 0.014192878807942354
# Compute control for a deterministic system
# Cost in iteration 0: 0.014192878807942354
# Final cost : 0.011703658136334616
# Compute control for a deterministic system
# Cost in iteration 0: 0.011703658136334616
# Final cost : 0.01170330878737765
# Compute control for a deterministic system
# Cost in iteration 0: 0.01170330878737765
# Converged in iteration 598 with cost 0.011703308749090337 because of step counter
# Final cost : 0.011703308749090337
# Compute control for a deterministic system
# Cost in iteration 0: 0.011703308749090337
# Converged in iteration 6 with cost 0.011703308749084727 because of step counter
# Final cost : 0.011703308749084727
# Compute control for a deterministic system
# Cost in iteration 0: 2.9173363031335406
# Final cost : 2.17663813254734
# Compute control for a deterministic system
# Cost in iteration 0: 2.17663813254734
# Final cost : 0.019190784158642185
# Compute control for a deterministic system
# Cost in iteration 0: 0.019190784158642185
# Final cost : 0.015293019510546828
# Compute control for a deterministic system
# Cost in iteration 0: 0.015293019510546828
# Final cost : 0.015292077156472192
# Compute control for a deterministic system
# Cost in iteration 0: 0.015292077156472192
# Converged in iteration 510 with cost 0.015292076914012033 because of step counter
# Final cost : 0.015292076914012033
# Compute control for a deterministic system
# Cost in iteration 0: 0.015292076914012033
# Converged in iteration 1 with cost 0.015292076914012033 because of step counter
# Final cost : 0.015292076914012033
# Compute control for a deterministic system
# Cost in iteration 0: 3.5016441074519524
# Final cost : 2.7221041929310146
# Compute control for a deterministic system
# Cost in iteration 0: 2.7221041929310146
# Final cost : 0.024911733989056436
# Compute control for a deterministic system
# Cost in iteration 0: 0.024911733989056436
# Final cost : 0.0192012953146311
# Compute control for a deterministic system
# Cost in iteration 0: 0.0192012953146311
# Final cost : 0.01919914132103918
# Compute control for a deterministic system
# Cost in iteration 0: 0.01919914132103918
# Converged in iteration 965 with cost 0.01919914024823031 because of step counter
# Final cost : 0.01919914024823031
# Compute control for a deterministic system
# Cost in iteration 0: 0.01919914024823031
# Converged in iteration 11 with cost 0.019199140248218585 because of step counter
# Final cost : 0.019199140248218585
# Compute control for a deterministic system
# Cost in iteration 0: 4.103094916391872
# Final cost : 3.317795621926818
# Compute control for a deterministic system
# Cost in iteration 0: 3.317795621926818
# Final cost : 0.03170872650202108
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170872650202108
# Final cost : 0.023610433181943183
# Compute control for a deterministic system
# Cost in iteration 0: 0.023610433181943183
# Final cost : 0.023605731198637656
# Compute control for a deterministic system
# Cost in iteration 0: 0.023605731198637656
# Final cost : 0.02360572735300164
# Compute control for a deterministic system
# Cost in iteration 0: 0.02360572735300164
# Converged in iteration 200 with cost 0.023605727352015236 because of step counter
# Final cost : 0.023605727352015236
# Compute control for a deterministic system
# Cost in iteration 0: 4.675788932785525
# Final cost : 3.9187883457056936
# Compute control for a deterministic system
# Cost in iteration 0: 3.9187883457056936
# Final cost : 0.03932265098444638
# Compute control for a deterministic system
# Cost in iteration 0: 0.03932265098444638
# Final cost : 0.028281256966119467
# Compute control for a deterministic system
# Cost in iteration 0: 0.028281256966119467
# Final cost : 0.028271224614293378
# Compute control for a deterministic system
# Cost in iteration 0: 0.028271224614293378
# Final cost : 0.028271211405883564
# Compute control for a deterministic system
# Cost in iteration 0: 0.028271211405883564
# Converged in iteration 209 with cost 0.028271211404578955 because of step counter
# Final cost : 0.028271211404578955
# Compute control for a deterministic system
# Cost in iteration 0: 5.236757252545923
# Final cost : 4.542189906000411
# Compute control for a deterministic system
# Cost in iteration 0: 4.542189906000411
# Final cost : 0.048334587033804166
# Compute control for a deterministic system
# Cost in iteration 0: 0.048334587033804166
# Final cost : 0.033477644800560744
# Compute control for a deterministic system
# Cost in iteration 0: 0.033477644800560744
# Final cost : 0.033458474966596596
# Compute control for a deterministic system
# Cost in iteration 0: 0.033458474966596596
# Final cost : 0.03345843515520572
# Compute control for a deterministic system
# Cost in iteration 0: 0.03345843515520572
# Converged in iteration 136 with cost 0.03345843515384476 because of step counter
# Final cost : 0.03345843515384476
# Compute control for a deterministic system
# Cost in iteration 0: 5.7439352757160025
# Final cost : 5.138494804639459
# Compute control for a deterministic system
# Cost in iteration 0: 5.138494804639459
# Final cost : 0.05848154075691957
# Compute control for a deterministic system
# Cost in iteration 0: 0.05848154075691957
# Final cost : 0.03894463318230294
# Compute control for a deterministic system
# Cost in iteration 0: 0.03894463318230294
# Final cost : 0.038910747095736484
# Compute control for a deterministic system
# Cost in iteration 0: 0.038910747095736484
# Final cost : 0.03891065394200213
# Compute control for a deterministic system
# Cost in iteration 0: 0.03891065394200213
# Converged in iteration 667 with cost 0.038910653886137354 because of step counter
# Final cost : 0.038910653886137354
# Compute control for a deterministic system
# Cost in iteration 0: 6.212871819162207
# Final cost : 5.7201882907130965
# Compute control for a deterministic system
# Cost in iteration 0: 5.7201882907130965
# Final cost : 0.07057816950065432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07057816950065432
# Final cost : 0.04499831323345608
# Compute control for a deterministic system
# Cost in iteration 0: 0.04499831323345608
# Final cost : 0.044937902208129064
# Compute control for a deterministic system
# Cost in iteration 0: 0.044937902208129064
# Final cost : 0.044937620133341544
# Compute control for a deterministic system
# Cost in iteration 0: 0.044937620133341544
# Converged in iteration 823 with cost 0.04493761996751278 because of step counter
# Final cost : 0.04493761996751278
# Compute control for a deterministic system
# Cost in iteration 0: 6.609012181946943
# Final cost : 6.235772950991037
# Compute control for a deterministic system
# Cost in iteration 0: 6.235772950991037
# Final cost : 0.08430050455070909
# Compute control for a deterministic system
# Cost in iteration 0: 0.08430050455070909
# Final cost : 0.05132800386695954
# Compute control for a deterministic system
# Cost in iteration 0: 0.05132800386695954
# Final cost : 0.0512322437358392
# Compute control for a deterministic system
# Cost in iteration 0: 0.0512322437358392
# Final cost : 0.05123163151726423
# Compute control for a deterministic system
# Cost in iteration 0: 0.05123163151726423
# Converged in iteration 1088 with cost 0.05123163126643299 because of step counter
# Final cost : 0.05123163126643299
# Compute control for a deterministic system
# Cost in iteration 0: 6.9458049731357585
# Final cost : 6.691922559119724
# Compute control for a deterministic system
# Cost in iteration 0: 6.691922559119724
# Final cost : 0.10079576818412644
# Compute control for a deterministic system
# Cost in iteration 0: 0.10079576818412644
# Final cost : 0.05828728778780098
# Compute control for a deterministic system
# Cost in iteration 0: 0.05828728778780098
# Final cost : 0.05813852731409098
# Compute control for a deterministic system
# Cost in iteration 0: 0.05813852731409098
# Final cost : 0.058136934262618845
# Compute control for a deterministic system
# Cost in iteration 0: 0.058136934262618845
# Converged in iteration 1045 with cost 0.0581369261100456 because of vanishing difference
# Final cost : 0.0581369261100456
# Compute control for a deterministic system
# Cost in iteration 0: 7.20033338104308
# Final cost : 7.047781320689426
# Compute control for a deterministic system
# Cost in iteration 0: 7.047781320689426
# Final cost : 0.1197077016479232
# Compute control for a deterministic system
# Cost in iteration 0: 0.1197077016479232
# Final cost : 0.06551421124244562
# Compute control for a deterministic system
# Cost in iteration 0: 0.06551421124244562
# Final cost : 0.06529221379976954
# Compute control for a deterministic system
# Cost in iteration 0: 0.06529221379976954
# Final cost : 0.06528928160992273
# Compute control for a deterministic system
# Cost in iteration 0: 0.06528928160992273
# Converged in iteration 1876 with cost 0.06528925257897163 because of step counter
# Final cost : 0.06528925257897163
# Compute control for a deterministic system
# Cost in iteration 0: 7.383329864284528
# Final cost : 7.310968711728228
# Compute control for a deterministic system
# Cost in iteration 0: 7.310968711728228
# Final cost : 0.1428069769254327
# Compute control for a deterministic system
# Cost in iteration 0: 0.1428069769254327
# Final cost : 0.07340599048907732
# Compute control for a deterministic system
# Cost in iteration 0: 0.07340599048907732
# Final cost : 0.07307696191583549
# Compute control for a deterministic system
# Cost in iteration 0: 0.07307696191583549
# Final cost : 0.07307108345124393
# Compute control for a deterministic system
# Cost in iteration 0: 0.07307108345124393
# Final cost : 0.0730709538008718
# Compute control for a deterministic system
# Cost in iteration 0: 7.483919342422571
# Final cost : 7.461789618612798
# Compute control for a deterministic system
# Cost in iteration 0: 7.461789618612798
# Final cost : 0.17009396428309964
# Compute control for a deterministic system
# Cost in iteration 0: 0.17009396428309964
# Final cost : 0.08155071884298308
# Compute control for a deterministic system
# Cost in iteration 0: 0.08155071884298308
# Final cost : 0.08107755477069684
# Compute control for a deterministic system
# Cost in iteration 0: 0.08107755477069684
# Final cost : 0.08106641255308013
# Compute control for a deterministic system
# Cost in iteration 0: 0.08106641255308013
# Final cost : 0.0810660673526944
# Compute control for a deterministic system
# Cost in iteration 0: 7.507309270666101
# Final cost : 7.506183636660087
# Compute control for a deterministic system
# Cost in iteration 0: 7.506183636660087
# Final cost : 0.20789396546515437
# Compute control for a deterministic system
# Cost in iteration 0: 0.20789396546515437
# Final cost : 0.09039969456872415
# Compute control for a deterministic system
# Cost in iteration 0: 0.09039969456872415
# Final cost : 0.0897166844313113
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897166844313113
# Final cost : 0.08969822617327758
# Compute control for a deterministic system
# Cost in iteration 0: 0.08969822617327758
# Final cost : 0.08969774764245479
# Compute control for a deterministic system
# Cost in iteration 0: 7.452558177126701
# Final cost : 7.441725957324227
# Compute control for a deterministic system
# Cost in iteration 0: 7.441725957324227
# Final cost : 0.19824325469169907
# Compute control for a deterministic system
# Cost in iteration 0: 0.19824325469169907
# Final cost : 0.0934951124018196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0934951124018196
# Final cost : 0.09326306093726633
# Compute control for a deterministic system
# Cost in iteration 0: 0.09326306093726633
# Final cost : 0.09326198138433082
# Compute control for a deterministic system
# Cost in iteration 0: 0.09326198138433082
# Converged in iteration 783 with cost 0.09326197439293275 because of step counter
# Final cost : 0.09326197439293275
# Compute control for a deterministic system
# Cost in iteration 0: 7.317270048243203
# Final cost : 7.265976574379595
# Compute control for a deterministic system
# Cost in iteration 0: 7.265976574379595
# Final cost : 0.16507397710024416
# Compute control for a deterministic system
# Cost in iteration 0: 0.16507397710024416
# Final cost : 0.0835556757890693
# Compute control for a deterministic system
# Cost in iteration 0: 0.0835556757890693
# Final cost : 0.0833876707541959
# Compute control for a deterministic system
# Cost in iteration 0: 0.0833876707541959
# Final cost : 0.08338680691442521
# Compute control for a deterministic system
# Cost in iteration 0: 0.08338680691442521
# Converged in iteration 771 with cost 0.08338680245037595 because of step counter
# Final cost : 0.08338680245037595
# Compute control for a deterministic system
# Cost in iteration 0: 7.1096682294529305
# Final cost : 6.990751762579715
# Compute control for a deterministic system
# Cost in iteration 0: 6.990751762579715
# Final cost : 0.13826227726821952
# Compute control for a deterministic system
# Cost in iteration 0: 0.13826227726821952
# Final cost : 0.07440199599616118
# Compute control for a deterministic system
# Cost in iteration 0: 0.07440199599616118
# Final cost : 0.07427890994018797
# Compute control for a deterministic system
# Cost in iteration 0: 0.07427890994018797
# Final cost : 0.07427839617125963
# Compute control for a deterministic system
# Cost in iteration 0: 0.07427839617125963
# Converged in iteration 804 with cost 0.07427839498290482 because of step counter
# Final cost : 0.07427839498290482
# Compute control for a deterministic system
# Cost in iteration 0: 6.821433590527662
# Final cost : 6.607982470641458
# Compute control for a deterministic system
# Cost in iteration 0: 6.607982470641458
# Final cost : 0.11498146024525818
# Compute control for a deterministic system
# Cost in iteration 0: 0.11498146024525818
# Final cost : 0.06555423479373079
# Compute control for a deterministic system
# Cost in iteration 0: 0.06555423479373079
# Final cost : 0.06546645175255666
# Compute control for a deterministic system
# Cost in iteration 0: 0.06546645175255666
# Final cost : 0.06546614253362382
# Compute control for a deterministic system
# Cost in iteration 0: 0.06546614253362382
# Converged in iteration 792 with cost 0.0654661419051985 because of step counter
# Final cost : 0.0654661419051985
# Compute control for a deterministic system
# Cost in iteration 0: 6.472680154265202
# Final cost : 6.150261594651888
# Compute control for a deterministic system
# Cost in iteration 0: 6.150261594651888
# Final cost : 0.09573565711960581
# Compute control for a deterministic system
# Cost in iteration 0: 0.09573565711960581
# Final cost : 0.05749050657839349
# Compute control for a deterministic system
# Cost in iteration 0: 0.05749050657839349
# Final cost : 0.057428648446290906
# Compute control for a deterministic system
# Cost in iteration 0: 0.057428648446290906
# Final cost : 0.057428493180265
# Compute control for a deterministic system
# Cost in iteration 0: 0.057428493180265
# Converged in iteration 797 with cost 0.057428492455361545 because of step counter
# Final cost : 0.057428492455361545
# Compute control for a deterministic system
# Cost in iteration 0: 6.051580188673024
# Final cost : 5.611429150432727
# Compute control for a deterministic system
# Cost in iteration 0: 5.611429150432727
# Final cost : 0.07890168850716386
# Compute control for a deterministic system
# Cost in iteration 0: 0.07890168850716386
# Final cost : 0.04977633325019156
# Compute control for a deterministic system
# Cost in iteration 0: 0.04977633325019156
# Final cost : 0.04973611947122784
# Compute control for a deterministic system
# Cost in iteration 0: 0.04973611947122784
# Final cost : 0.04973604907761773
# Compute control for a deterministic system
# Cost in iteration 0: 0.04973604907761773
# Converged in iteration 743 with cost 0.049736048826563455 because of step counter
# Final cost : 0.049736048826563455
# Compute control for a deterministic system
# Cost in iteration 0: 5.588780711097274
# Final cost : 5.040971766236929
# Compute control for a deterministic system
# Cost in iteration 0: 5.040971766236929
# Final cost : 0.06492029599385082
# Compute control for a deterministic system
# Cost in iteration 0: 0.06492029599385082
# Final cost : 0.04282382821844344
# Compute control for a deterministic system
# Cost in iteration 0: 0.04282382821844344
# Final cost : 0.04279791547126195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279791547126195
# Final cost : 0.042797885945116694
# Compute control for a deterministic system
# Cost in iteration 0: 0.042797885945116694
# Converged in iteration 552 with cost 0.04279788587572072 because of vanishing difference
# Final cost : 0.04279788587572072
# Compute control for a deterministic system
# Cost in iteration 0: 5.069620239168994
# Final cost : 4.4299961583231475
# Compute control for a deterministic system
# Cost in iteration 0: 4.4299961583231475
# Final cost : 0.05266387708498258
# Compute control for a deterministic system
# Cost in iteration 0: 0.05266387708498258
# Final cost : 0.036255799084788695
# Compute control for a deterministic system
# Cost in iteration 0: 0.036255799084788695
# Final cost : 0.036240347024383446
# Compute control for a deterministic system
# Cost in iteration 0: 0.036240347024383446
# Final cost : 0.036240336734871585
# Compute control for a deterministic system
# Cost in iteration 0: 0.036240336734871585
# Converged in iteration 419 with cost 0.03624033671907361 because of step counter
# Final cost : 0.03624033671907361
# Compute control for a deterministic system
# Cost in iteration 0: 4.532486543312421
# Final cost : 3.8296702875915205
# Compute control for a deterministic system
# Cost in iteration 0: 3.8296702875915205
# Final cost : 0.04248472792458725
# Compute control for a deterministic system
# Cost in iteration 0: 0.04248472792458725
# Final cost : 0.030414295780616947
# Compute control for a deterministic system
# Cost in iteration 0: 0.030414295780616947
# Final cost : 0.030405284959359784
# Compute control for a deterministic system
# Cost in iteration 0: 0.030405284959359784
# Final cost : 0.030405281425926516
# Compute control for a deterministic system
# Cost in iteration 0: 0.030405281425926516
# Converged in iteration 246 with cost 0.030405281422679932 because of step counter
# Final cost : 0.030405281422679932
# Compute control for a deterministic system
# Cost in iteration 0: 3.9604101418819124
# Final cost : 3.2243119200675334
# Compute control for a deterministic system
# Cost in iteration 0: 3.2243119200675334
# Final cost : 0.033585510987316006
# Compute control for a deterministic system
# Cost in iteration 0: 0.033585510987316006
# Final cost : 0.02497512880177431
# Compute control for a deterministic system
# Cost in iteration 0: 0.02497512880177431
# Final cost : 0.0249704792013098
# Compute control for a deterministic system
# Cost in iteration 0: 0.0249704792013098
# Final cost : 0.024970478168840356
# Compute control for a deterministic system
# Cost in iteration 0: 0.024970478168840356
# Converged in iteration 123 with cost 0.02497047816833999 because of step counter
# Final cost : 0.02497047816833999
# Compute control for a deterministic system
# Cost in iteration 0: 3.3954012365711557
# Final cost : 2.6594276297808075
# Compute control for a deterministic system
# Cost in iteration 0: 2.6594276297808075
# Final cost : 0.02624102691693477
# Compute control for a deterministic system
# Cost in iteration 0: 0.02624102691693477
# Final cost : 0.020216110709530586
# Compute control for a deterministic system
# Cost in iteration 0: 0.020216110709530586
# Final cost : 0.020213786840962342
# Compute control for a deterministic system
# Cost in iteration 0: 0.020213786840962342
# Converged in iteration 892 with cost 0.020213786564375454 because of step counter
# Final cost : 0.020213786564375454
# Compute control for a deterministic system
# Cost in iteration 0: 0.020213786564375454
# Converged in iteration 1 with cost 0.020213786564375454 because of step counter
# Final cost : 0.020213786564375454
# Compute control for a deterministic system
# Cost in iteration 0: 2.819397045152489
# Final cost : 2.116536859949103
# Compute control for a deterministic system
# Cost in iteration 0: 2.116536859949103
# Final cost : 0.019891420052225717
# Compute control for a deterministic system
# Cost in iteration 0: 0.019891420052225717
# Final cost : 0.01587026389210173
# Compute control for a deterministic system
# Cost in iteration 0: 0.01587026389210173
# Final cost : 0.015869299475114975
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869299475114975
# Converged in iteration 676 with cost 0.015869299407826293 because of step counter
# Final cost : 0.015869299407826293
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869299407826293
# Converged in iteration 2 with cost 0.015869299407825985 because of step counter
# Final cost : 0.015869299407825985
# Compute control for a deterministic system
# Cost in iteration 0: 2.2749281397562306
# Final cost : 1.634208787584382
# Compute control for a deterministic system
# Cost in iteration 0: 1.634208787584382
# Final cost : 0.014742591847681211
# Compute control for a deterministic system
# Cost in iteration 0: 0.014742591847681211
# Final cost : 0.012158080113802325
# Compute control for a deterministic system
# Cost in iteration 0: 0.012158080113802325
# Final cost : 0.012157634515963165
# Compute control for a deterministic system
# Cost in iteration 0: 0.012157634515963165
# Converged in iteration 522 with cost 0.012157634501328396 because of step counter
# Final cost : 0.012157634501328396
# Compute control for a deterministic system
# Cost in iteration 0: 0.012157634501328396
# Converged in iteration 1 with cost 0.012157634501328396 because of step counter
# Final cost : 0.012157634501328396
# Compute control for a deterministic system
# Cost in iteration 0: 1.7455097418959467
# Final cost : 1.1951544541301342
# Compute control for a deterministic system
# Cost in iteration 0: 1.1951544541301342
# Final cost : 0.010406242385644807
# Compute control for a deterministic system
# Cost in iteration 0: 0.010406242385644807
# Final cost : 0.008870831067992961
# Compute control for a deterministic system
# Cost in iteration 0: 0.008870831067992961
# Final cost : 0.00887065121673943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00887065121673943
# Converged in iteration 329 with cost 0.008870651214017413 because of step counter
# Final cost : 0.008870651214017413
# Compute control for a deterministic system
# Cost in iteration 0: 0.008870651214017413
# Converged in iteration 1 with cost 0.008870651214017413 because of step counter
# Final cost : 0.008870651214017413
# Compute control for a deterministic system
# Cost in iteration 0: 1.2719211643645472
# Final cost : 0.8293008365198357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8293008365198357
# Final cost : 0.007020669448553511
# Compute control for a deterministic system
# Cost in iteration 0: 0.007020669448553511
# Final cost : 0.006175069372397332
# Compute control for a deterministic system
# Cost in iteration 0: 0.006175069372397332
# Final cost : 0.006174992671657362
# Compute control for a deterministic system
# Cost in iteration 0: 0.006174992671657362
# Converged in iteration 199 with cost 0.006174992671197361 because of step counter
# Final cost : 0.006174992671197361
# Compute control for a deterministic system
# Cost in iteration 0: 0.006174992671197361
# Converged in iteration 1 with cost 0.006174992671197361 because of step counter
# Final cost : 0.006174992671197361
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425773925152386
# Final cost : 0.5219120180121762
# Compute control for a deterministic system
# Cost in iteration 0: 0.5219120180121762
# Final cost : 0.004321239328015114
# Compute control for a deterministic system
# Cost in iteration 0: 0.004321239328015114
# Final cost : 0.003919270794605061
# Compute control for a deterministic system
# Cost in iteration 0: 0.003919270794605061
# Final cost : 0.003919244321835451
# Compute control for a deterministic system
# Cost in iteration 0: 0.003919244321835451
# Converged in iteration 8 with cost 0.00391924432178706 because of step counter
# Final cost : 0.00391924432178706
# Compute control for a deterministic system
# Cost in iteration 0: 0.00391924432178706
# Converged in iteration 1 with cost 0.00391924432178706 because of step counter
# Final cost : 0.00391924432178706
# Compute control for a deterministic system
# Cost in iteration 0: 0.49435436624176343
# Final cost : 0.291740347350741
# Compute control for a deterministic system
# Cost in iteration 0: 0.291740347350741
# Final cost : 0.002378584548238712
# Compute control for a deterministic system
# Cost in iteration 0: 0.002378584548238712
# Final cost : 0.0022173747073993676
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022173747073993676
# Converged in iteration 851 with cost 0.002217369059856106 because of step counter
# Final cost : 0.002217369059856106
# Compute control for a deterministic system
# Cost in iteration 0: 0.002217369059856106
# Converged in iteration 1 with cost 0.002217369059856106 because of step counter
# Final cost : 0.002217369059856106
# Compute control for a deterministic system
# Cost in iteration 0: 0.002217369059856106
# Converged in iteration 1 with cost 0.002217369059856106 because of step counter
# Final cost : 0.002217369059856106
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359997766842216
# Final cost : 0.12631470001750308
# Compute control for a deterministic system
# Cost in iteration 0: 0.12631470001750308
# Final cost : 0.0010192654649302034
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010192654649302034
# Final cost : 0.0009730718384306492
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730718384306492
# Converged in iteration 707 with cost 0.0009730711532751958 because of step counter
# Final cost : 0.0009730711532751958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730711532751958
# Converged in iteration 1 with cost 0.0009730711532751958 because of step counter
# Final cost : 0.0009730711532751958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730711532751958
# Converged in iteration 1 with cost 0.0009730711532751958 because of step counter
# Final cost : 0.0009730711532751958
# Compute control for a deterministic system
# Cost in iteration 0: 0.058212907945238375
# Final cost : 0.031900942952887604
# Compute control for a deterministic system
# Cost in iteration 0: 0.031900942952887604
# Final cost : 0.0002557668325012292
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002557668325012292
# Final cost : 0.0002481612770998727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002481612770998727
# Converged in iteration 500 with cost 0.00024816125492712693 because of step counter
# Final cost : 0.00024816125492712693
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024816125492712693
# Converged in iteration 1 with cost 0.00024816125492712693 because of step counter
# Final cost : 0.00024816125492712693
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024816125492712693
# Converged in iteration 1 with cost 0.00024816125492712693 because of step counter
# Final cost : 0.00024816125492712693
# Compute control for a deterministic system
# Cost in iteration 0: 1.183472436512719e-06
# Final cost : 6.408285807491519e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.408285807491519e-07
# Final cost : 5.113490578486877e-09
# ----------------------------------------------- 0
# cost =  0.0009693358393931835
# Compute control for a deterministic system
# Cost in iteration 0: 0.05893574310720122
# Final cost : 0.0009846288816963524
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009846288816963524
# Final cost : 0.0009693359912233571
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009693359912233571
# Converged in iteration 626 with cost 0.0009693358393903362 because of step counter
# Final cost : 0.0009693358393903362
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009693358393903362
# Converged in iteration 10 with cost 0.0009693358393836871 because of step counter
# Final cost : 0.0009693358393836871
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009693358393836871
# Converged in iteration 1 with cost 0.0009693358393836871 because of step counter
# Final cost : 0.0009693358393836871
# -----------------------------------------------
# 0 found better solution,  2
# cost =  0.0021573551563235684
# Compute control for a deterministic system
# Cost in iteration 0: 0.058319416127503756
# Final cost : 0.00218638002812453
# Compute control for a deterministic system
# Cost in iteration 0: 0.00218638002812453
# Final cost : 0.0021573562582972486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021573562582972486
# Converged in iteration 751 with cost 0.0021573551563234834 because of step counter
# Final cost : 0.0021573551563234834
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021573551563234834
# Converged in iteration 15 with cost 0.0021573551563113026 because of step counter
# Final cost : 0.0021573551563113026
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021573551563113026
# Converged in iteration 1 with cost 0.0021573551563113026 because of step counter
# Final cost : 0.0021573551563113026
# -----------------------------------------------
# 0 found better solution,  3
# cost =  0.003861680962127715
# Compute control for a deterministic system
# Cost in iteration 0: 0.06334910559345784
# Final cost : 0.00391462110142127
# Compute control for a deterministic system
# Cost in iteration 0: 0.00391462110142127
# Final cost : 0.0038616842968882026
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038616842968882026
# Converged in iteration 956 with cost 0.0038616809621554848 because of step counter
# Final cost : 0.0038616809621554848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038616809621554848
# Converged in iteration 1 with cost 0.0038616809621554848 because of step counter
# Final cost : 0.0038616809621554848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038616809621554848
# Converged in iteration 1 with cost 0.0038616809621554848 because of step counter
# Final cost : 0.0038616809621554848
# cost =  0.005989551423830953
# Compute control for a deterministic system
# Cost in iteration 0: 0.06033998797437792
# Final cost : 0.006066727100594699
# Compute control for a deterministic system
# Cost in iteration 0: 0.006066727100594699
# Final cost : 0.005989564399377739
# Compute control for a deterministic system
# Cost in iteration 0: 0.005989564399377739
# Final cost : 0.005989551424106458
# Compute control for a deterministic system
# Cost in iteration 0: 0.005989551424106458
# Converged in iteration 79 with cost 0.005989551423828889 because of step counter
# Final cost : 0.005989551423828889
# Compute control for a deterministic system
# Cost in iteration 0: 0.005989551423828889
# Converged in iteration 1 with cost 0.005989551423828889 because of step counter
# Final cost : 0.005989551423828889
# -----------------------------------------------
# 0 found better solution,  5
# cost =  0.008652178138097379
# Compute control for a deterministic system
# Cost in iteration 0: 0.06716860492198715
# Final cost : 0.008768567165394125
# Compute control for a deterministic system
# Cost in iteration 0: 0.008768567165394125
# Final cost : 0.008652208735178003
# Compute control for a deterministic system
# Cost in iteration 0: 0.008652208735178003
# Final cost : 0.008652178139710772
# Compute control for a deterministic system
# Cost in iteration 0: 0.008652178139710772
# Converged in iteration 314 with cost 0.008652178138086105 because of step counter
# Final cost : 0.008652178138086105
# Compute control for a deterministic system
# Cost in iteration 0: 0.008652178138086105
# Converged in iteration 5 with cost 0.008652178138079109 because of step counter
# Final cost : 0.008652178138079109
# -----------------------------------------------
# 0 found better solution,  6
# cost =  0.011703308749084727
# Compute control for a deterministic system
# Cost in iteration 0: 0.06391700207882987
# Final cost : 0.011850402758693236
# Compute control for a deterministic system
# Cost in iteration 0: 0.011850402758693236
# Final cost : 0.01170338086680084
# Compute control for a deterministic system
# Cost in iteration 0: 0.01170338086680084
# Final cost : 0.011703308757759665
# Compute control for a deterministic system
# Cost in iteration 0: 0.011703308757759665
# Converged in iteration 481 with cost 0.011703308749109567 because of step counter
# Final cost : 0.011703308749109567
# Compute control for a deterministic system
# Cost in iteration 0: 0.011703308749109567
# Converged in iteration 1 with cost 0.011703308749109567 because of step counter
# Final cost : 0.011703308749109567
# cost =  0.015292076914012033
# Compute control for a deterministic system
# Cost in iteration 0: 0.07818808422812591
# Final cost : 0.015490104265192331
# Compute control for a deterministic system
# Cost in iteration 0: 0.015490104265192331
# Final cost : 0.01529223480356159
# Compute control for a deterministic system
# Cost in iteration 0: 0.01529223480356159
# Final cost : 0.015292076955813756
# Compute control for a deterministic system
# Cost in iteration 0: 0.015292076955813756
# Converged in iteration 440 with cost 0.015292076913925094 because of step counter
# Final cost : 0.015292076913925094
# Compute control for a deterministic system
# Cost in iteration 0: 0.015292076913925094
# Converged in iteration 2 with cost 0.015292076913924722 because of step counter
# Final cost : 0.015292076913924722
# -----------------------------------------------
# 0 found better solution,  8
# cost =  0.019199140248218585
# Compute control for a deterministic system
# Cost in iteration 0: 0.07773178037268137
# Final cost : 0.01942455896414418
# Compute control for a deterministic system
# Cost in iteration 0: 0.01942455896414418
# Final cost : 0.019199443103556032
# Compute control for a deterministic system
# Cost in iteration 0: 0.019199443103556032
# Final cost : 0.019199140395542335
# Compute control for a deterministic system
# Cost in iteration 0: 0.019199140395542335
# Converged in iteration 850 with cost 0.019199140248151583 because of step counter
# Final cost : 0.019199140248151583
# Compute control for a deterministic system
# Cost in iteration 0: 0.019199140248151583
# Converged in iteration 3 with cost 0.01919914024815116 because of step counter
# Final cost : 0.01919914024815116
# -----------------------------------------------
# 0 found better solution,  9
# cost =  0.023605727352015236
# Compute control for a deterministic system
# Cost in iteration 0: 0.08314610549058576
# Final cost : 0.023882264979482964
# Compute control for a deterministic system
# Cost in iteration 0: 0.023882264979482964
# Final cost : 0.02360634782965003
# Compute control for a deterministic system
# Cost in iteration 0: 0.02360634782965003
# Final cost : 0.02360572785262391
# Compute control for a deterministic system
# Cost in iteration 0: 0.02360572785262391
# Converged in iteration 952 with cost 0.023605727351997712 because of step counter
# Final cost : 0.023605727351997712
# Compute control for a deterministic system
# Cost in iteration 0: 0.023605727351997712
# Converged in iteration 1 with cost 0.023605727351997712 because of step counter
# Final cost : 0.023605727351997712
# -----------------------------------------------
# 0 found better solution,  10
# cost =  0.028271211404578955
# Compute control for a deterministic system
# Cost in iteration 0: 0.08682796667560524
# Final cost : 0.028573860940643667
# Compute control for a deterministic system
# Cost in iteration 0: 0.028573860940643667
# Final cost : 0.028272125500571732
# Compute control for a deterministic system
# Cost in iteration 0: 0.028272125500571732
# Final cost : 0.028271212700350913
# Compute control for a deterministic system
# Cost in iteration 0: 0.028271212700350913
# Converged in iteration 800 with cost 0.02827121140447227 because of step counter
# Final cost : 0.02827121140447227
# Compute control for a deterministic system
# Cost in iteration 0: 0.02827121140447227
# Converged in iteration 1 with cost 0.02827121140447227 because of step counter
# Final cost : 0.02827121140447227
# -----------------------------------------------
# 0 found better solution,  11
# cost =  0.03345843515384476
# Compute control for a deterministic system
# Cost in iteration 0: 0.07985056138628854
# Final cost : 0.03382160692966711
# Compute control for a deterministic system
# Cost in iteration 0: 0.03382160692966711
# Final cost : 0.03346003656816033
# Compute control for a deterministic system
# Cost in iteration 0: 0.03346003656816033
# Final cost : 0.03345843862682764
# Compute control for a deterministic system
# Cost in iteration 0: 0.03345843862682764
# Final cost : 0.03345843515510974
# Compute control for a deterministic system
# Cost in iteration 0: 0.03345843515510974
# Converged in iteration 225 with cost 0.03345843515369914 because of step counter
# Final cost : 0.03345843515369914
# -----------------------------------------------
# 0 found better solution,  12
# cost =  0.038910653886137354
# Compute control for a deterministic system
# Cost in iteration 0: 0.08785586687757858
# Final cost : 0.03930509784289763
# Compute control for a deterministic system
# Cost in iteration 0: 0.03930509784289763
# Final cost : 0.03891315777472733
# Compute control for a deterministic system
# Cost in iteration 0: 0.03891315777472733
# Final cost : 0.038910663268084206
# Compute control for a deterministic system
# Cost in iteration 0: 0.038910663268084206
# Final cost : 0.03891065388876356
# Compute control for a deterministic system
# Cost in iteration 0: 0.03891065388876356
# Converged in iteration 332 with cost 0.03891065388632843 because of step counter
# Final cost : 0.03891065388632843
# cost =  0.04493761996751278
# Compute control for a deterministic system
# Cost in iteration 0: 0.10983983967672126
# Final cost : 0.04541359006979516
# Compute control for a deterministic system
# Cost in iteration 0: 0.04541359006979516
# Final cost : 0.04494159896083632
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494159896083632
# Final cost : 0.04493764295296741
# Compute control for a deterministic system
# Cost in iteration 0: 0.04493764295296741
# Final cost : 0.04493761997685907
# Compute control for a deterministic system
# Cost in iteration 0: 0.04493761997685907
# Converged in iteration 457 with cost 0.04493761996725296 because of vanishing difference
# Final cost : 0.04493761996725296
# -----------------------------------------------
# 0 found better solution,  14
# cost =  0.05123163126643299
# Compute control for a deterministic system
# Cost in iteration 0: 0.09066386365216583
# Final cost : 0.0517314935071578
# Compute control for a deterministic system
# Cost in iteration 0: 0.0517314935071578
# Final cost : 0.05123693505490231
# Compute control for a deterministic system
# Cost in iteration 0: 0.05123693505490231
# Final cost : 0.0512316706572817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0512316706572817
# Final cost : 0.05123163131221141
# Compute control for a deterministic system
# Cost in iteration 0: 0.05123163131221141
# Converged in iteration 639 with cost 0.05123163126631968 because of step counter
# Final cost : 0.05123163126631968
# -----------------------------------------------
# 0 found better solution,  15
# cost =  0.0581369261100456
# Compute control for a deterministic system
# Cost in iteration 0: 0.10957909370536924
# Final cost : 0.05872625074696991
# Compute control for a deterministic system
# Cost in iteration 0: 0.05872625074696991
# Final cost : 0.05814500420307223
# Compute control for a deterministic system
# Cost in iteration 0: 0.05814500420307223
# Final cost : 0.058137022143146366
# Compute control for a deterministic system
# Cost in iteration 0: 0.058137022143146366
# Final cost : 0.05813692614370055
# Compute control for a deterministic system
# Cost in iteration 0: 0.05813692614370055
# Converged in iteration 648 with cost 0.058136926109875545 because of vanishing difference
# Final cost : 0.058136926109875545
# -----------------------------------------------
# 0 found better solution,  16
# cost =  0.06528925257897163
# Compute control for a deterministic system
# Cost in iteration 0: 0.12635773571116515
# Final cost : 0.06590910054887879
# Compute control for a deterministic system
# Cost in iteration 0: 0.06590910054887879
# Final cost : 0.06529978260658
# Compute control for a deterministic system
# Cost in iteration 0: 0.06529978260658
# Final cost : 0.06528943383418055
# Compute control for a deterministic system
# Cost in iteration 0: 0.06528943383418055
# Final cost : 0.06528925305024542
# Compute control for a deterministic system
# Cost in iteration 0: 0.06528925305024542
# Converged in iteration 1330 with cost 0.06528925257883578 because of step counter
# Final cost : 0.06528925257883578
# -----------------------------------------------
# 0 found better solution,  17
# cost =  0.0730709538008718
# Compute control for a deterministic system
# Cost in iteration 0: 0.11563063922591174
# Final cost : 0.07377216290959566
# Compute control for a deterministic system
# Cost in iteration 0: 0.07377216290959566
# Final cost : 0.07308437735605981
# Compute control for a deterministic system
# Cost in iteration 0: 0.07308437735605981
# Final cost : 0.07307126825102003
# Compute control for a deterministic system
# Cost in iteration 0: 0.07307126825102003
# Final cost : 0.0730709611641852
# Compute control for a deterministic system
# Cost in iteration 0: 0.0730709611641852
# Final cost : 0.07307095379468384
# -----------------------------------------------
# 0 found better solution,  18
# cost =  0.0810660673526944
# Compute control for a deterministic system
# Cost in iteration 0: 0.13816409324962767
# Final cost : 0.08178987516134119
# Compute control for a deterministic system
# Cost in iteration 0: 0.08178987516134119
# Final cost : 0.08108380890756875
# Compute control for a deterministic system
# Cost in iteration 0: 0.08108380890756875
# Final cost : 0.08106653204966895
# Compute control for a deterministic system
# Cost in iteration 0: 0.08106653204966895
# Final cost : 0.08106607972341655
# Compute control for a deterministic system
# Cost in iteration 0: 0.08106607972341655
# Final cost : 0.08106606729186287
# -----------------------------------------------
# 0 found better solution,  19
# cost =  0.08969774764245479
# Compute control for a deterministic system
# Cost in iteration 0: 0.1282644071134672
# Final cost : 0.0905010356673291
# Compute control for a deterministic system
# Cost in iteration 0: 0.0905010356673291
# Final cost : 0.08972079504588949
# Compute control for a deterministic system
# Cost in iteration 0: 0.08972079504588949
# Final cost : 0.08969877284894703
# Compute control for a deterministic system
# ...
# Final cost : 0.09329656671293733
# Compute control for a deterministic system
# Cost in iteration 0: 0.09329656671293733
# Final cost : 0.09326197496483726
# Compute control for a deterministic system
# Cost in iteration 0: 0.09326197496483726
# Final cost : 0.09326197439361245
# Compute control for a deterministic system
# Cost in iteration 0: 0.09326197439361245
# Converged in iteration 72 with cost 0.09326197439288944 because of vanishing difference
# Final cost : 0.09326197439288944
# Compute control for a deterministic system
# Cost in iteration 0: 0.09326197439288944
# Converged in iteration 1 with cost 0.09326197439288944 because of vanishing difference
# Final cost : 0.09326197439288944
# Compute control for a deterministic system
# Cost in iteration 0: 0.08446911592362898
# Final cost : 0.08341571432363137
# Compute control for a deterministic system
# Cost in iteration 0: 0.08341571432363137
# Final cost : 0.08338680289298513
# Compute control for a deterministic system
# Cost in iteration 0: 0.08338680289298513
# Final cost : 0.08338680245091086
# Compute control for a deterministic system
# Cost in iteration 0: 0.08338680245091086
# Converged in iteration 41 with cost 0.08338680245059052 because of step counter
# Final cost : 0.08338680245059052
# Compute control for a deterministic system
# Cost in iteration 0: 0.08338680245059052
# Converged in iteration 23 with cost 0.08338680245030052 because of step counter
# Final cost : 0.08338680245030052
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.07492650731962841
# Final cost : 0.07430576179494358
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430576179494358
# Final cost : 0.07427839526978013
# Compute control for a deterministic system
# Cost in iteration 0: 0.07427839526978013
# Converged in iteration 936 with cost 0.07427839498346168 because of step counter
# Final cost : 0.07427839498346168
# Compute control for a deterministic system
# Cost in iteration 0: 0.07427839498346168
# Converged in iteration 48 with cost 0.07427839498304228 because of step counter
# Final cost : 0.07427839498304228
# Compute control for a deterministic system
# Cost in iteration 0: 0.07427839498304228
# Converged in iteration 1 with cost 0.07427839498304228 because of step counter
# Final cost : 0.07427839498304228
# Compute control for a deterministic system
# Cost in iteration 0: 0.06586390961482004
# Final cost : 0.065495649903606
# Compute control for a deterministic system
# Cost in iteration 0: 0.065495649903606
# Final cost : 0.06546614213463577
# Compute control for a deterministic system
# Cost in iteration 0: 0.06546614213463577
# Converged in iteration 963 with cost 0.06546614190575471 because of step counter
# Final cost : 0.06546614190575471
# Compute control for a deterministic system
# Cost in iteration 0: 0.06546614190575471
# Converged in iteration 43 with cost 0.06546614190526354 because of step counter
# Final cost : 0.06546614190526354
# Compute control for a deterministic system
# Cost in iteration 0: 0.06546614190526354
# Converged in iteration 2 with cost 0.06546614190526254 because of step counter
# Final cost : 0.06546614190526254
# Compute control for a deterministic system
# Cost in iteration 0: 0.057585456914494716
# Final cost : 0.05745627826807538
# Compute control for a deterministic system
# Cost in iteration 0: 0.05745627826807538
# Final cost : 0.05742849253745455
# Compute control for a deterministic system
# Cost in iteration 0: 0.05742849253745455
# Converged in iteration 883 with cost 0.05742849245562094 because of step counter
# Final cost : 0.05742849245562094
# Compute control for a deterministic system
# Cost in iteration 0: 0.05742849245562094
# Converged in iteration 22 with cost 0.05742849245544981 because of step counter
# Final cost : 0.05742849245544981
# Compute control for a deterministic system
# Cost in iteration 0: 0.05742849245544981
# Converged in iteration 1 with cost 0.05742849245544981 because of step counter
# Final cost : 0.05742849245544981
# Compute control for a deterministic system
# Cost in iteration 0: 0.050066157795874165
# Final cost : 0.04976197156776664
# Compute control for a deterministic system
# Cost in iteration 0: 0.04976197156776664
# Final cost : 0.049736048893700625
# Compute control for a deterministic system
# Cost in iteration 0: 0.049736048893700625
# Converged in iteration 752 with cost 0.04973604882684085 because of step counter
# Final cost : 0.04973604882684085
# Compute control for a deterministic system
# Cost in iteration 0: 0.04973604882684085
# Converged in iteration 49 with cost 0.04973604882649449 because of step counter
# Final cost : 0.04973604882649449
# Compute control for a deterministic system
# Cost in iteration 0: 0.04973604882649449
# Converged in iteration 1 with cost 0.04973604882649449 because of step counter
# Final cost : 0.04973604882649449
# Compute control for a deterministic system
# Cost in iteration 0: 0.04366680765031668
# Final cost : 0.04282183671154204
# Compute control for a deterministic system
# Cost in iteration 0: 0.04282183671154204
# Final cost : 0.04279788590531047
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279788590531047
# Converged in iteration 648 with cost 0.04279788587571547 because of step counter
# Final cost : 0.04279788587571547
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279788587571547
# Converged in iteration 24 with cost 0.04279788587550075 because of step counter
# Final cost : 0.04279788587550075
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279788587550075
# Converged in iteration 3 with cost 0.04279788587549962 because of step counter
# Final cost : 0.04279788587549962
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.03638068881421676
# Final cost : 0.03626527051510369
# Compute control for a deterministic system
# Cost in iteration 0: 0.03626527051510369
# Final cost : 0.03624033677626459
# Compute control for a deterministic system
# Cost in iteration 0: 0.03624033677626459
# Converged in iteration 757 with cost 0.03624033671916125 because of step counter
# Final cost : 0.03624033671916125
# Compute control for a deterministic system
# Cost in iteration 0: 0.03624033671916125
# Converged in iteration 1 with cost 0.03624033671916125 because of step counter
# Final cost : 0.03624033671916125
# Compute control for a deterministic system
# Cost in iteration 0: 0.03624033671916125
# Converged in iteration 1 with cost 0.03624033671916125 because of step counter
# Final cost : 0.03624033671916125
# Compute control for a deterministic system
# Cost in iteration 0: 0.03140026787198734
# Final cost : 0.03042573322026145
# Compute control for a deterministic system
# Cost in iteration 0: 0.03042573322026145
# Final cost : 0.030405281441828382
# Compute control for a deterministic system
# Cost in iteration 0: 0.030405281441828382
# Converged in iteration 478 with cost 0.030405281422850025 because of step counter
# Final cost : 0.030405281422850025
# Compute control for a deterministic system
# Cost in iteration 0: 0.030405281422850025
# Converged in iteration 1 with cost 0.030405281422850025 because of step counter
# Final cost : 0.030405281422850025
# Compute control for a deterministic system
# Cost in iteration 0: 0.030405281422850025
# Converged in iteration 59 with cost 0.030405281422639353 because of step counter
# Final cost : 0.030405281422639353
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.02544154910510717
# Final cost : 0.024989302714617165
# Compute control for a deterministic system
# Cost in iteration 0: 0.024989302714617165
# Final cost : 0.024970478185301834
# Compute control for a deterministic system
# Cost in iteration 0: 0.024970478185301834
# Converged in iteration 519 with cost 0.02497047816836914 because of step counter
# Final cost : 0.02497047816836914
# Compute control for a deterministic system
# Cost in iteration 0: 0.02497047816836914
# Converged in iteration 1 with cost 0.02497047816836914 because of step counter
# Final cost : 0.02497047816836914
# Compute control for a deterministic system
# Cost in iteration 0: 0.02497047816836914
# Converged in iteration 1 with cost 0.02497047816836914 because of step counter
# Final cost : 0.02497047816836914
# Compute control for a deterministic system
# Cost in iteration 0: 0.020392002250588948
# Final cost : 0.02023065405831207
# Compute control for a deterministic system
# Cost in iteration 0: 0.02023065405831207
# Final cost : 0.020213786585303522
# Compute control for a deterministic system
# Cost in iteration 0: 0.020213786585303522
# Converged in iteration 456 with cost 0.020213786564470582 because of vanishing difference
# Final cost : 0.020213786564470582
# Compute control for a deterministic system
# Cost in iteration 0: 0.020213786564470582
# Converged in iteration 2 with cost 0.020213786564470027 because of step counter
# Final cost : 0.020213786564470027
# Compute control for a deterministic system
# Cost in iteration 0: 0.020213786564470027
# Converged in iteration 1 with cost 0.020213786564470027 because of step counter
# Final cost : 0.020213786564470027
# Compute control for a deterministic system
# Cost in iteration 0: 0.015940165489133018
# Final cost : 0.015883830387061985
# Compute control for a deterministic system
# Cost in iteration 0: 0.015883830387061985
# Final cost : 0.015869299416430106
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869299416430106
# Converged in iteration 342 with cost 0.015869299407927865 because of step counter
# Final cost : 0.015869299407927865
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869299407927865
# Converged in iteration 1 with cost 0.015869299407927865 because of step counter
# Final cost : 0.015869299407927865
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869299407927865
# Converged in iteration 1 with cost 0.015869299407927865 because of step counter
# Final cost : 0.015869299407927865
# Compute control for a deterministic system
# Cost in iteration 0: 0.012642624661699542
# Final cost : 0.012168157555415914
# Compute control for a deterministic system
# Cost in iteration 0: 0.012168157555415914
# Final cost : 0.012157634507076838
# Compute control for a deterministic system
# Cost in iteration 0: 0.012157634507076838
# Converged in iteration 260 with cost 0.012157634501396971 because of step counter
# Final cost : 0.012157634501396971
# Compute control for a deterministic system
# Cost in iteration 0: 0.012157634501396971
# Converged in iteration 2 with cost 0.012157634501396062 because of step counter
# Final cost : 0.012157634501396062
# Compute control for a deterministic system
# Cost in iteration 0: 0.012157634501396062
# Converged in iteration 21 with cost 0.012157634501324488 because of step counter
# Final cost : 0.012157634501324488
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.008917067395800865
# Final cost : 0.00887938843055984
# Compute control for a deterministic system
# Cost in iteration 0: 0.00887938843055984
# Final cost : 0.008870651218617343
# Compute control for a deterministic system
# Cost in iteration 0: 0.008870651218617343
# Converged in iteration 294 with cost 0.008870651214040603 because of step counter
# Final cost : 0.008870651214040603
# Compute control for a deterministic system
# Cost in iteration 0: 0.008870651214040603
# Converged in iteration 1 with cost 0.008870651214040603 because of step counter
# Final cost : 0.008870651214040603
# Compute control for a deterministic system
# Cost in iteration 0: 0.008870651214040603
# Converged in iteration 1 with cost 0.008870651214040603 because of step counter
# Final cost : 0.008870651214040603
# Compute control for a deterministic system
# Cost in iteration 0: 0.006289606147923206
# Final cost : 0.006180913858679483
# Compute control for a deterministic system
# Cost in iteration 0: 0.006180913858679483
# Final cost : 0.006174992677064911
# Compute control for a deterministic system
# Cost in iteration 0: 0.006174992677064911
# Converged in iteration 277 with cost 0.006174992671216736 because of vanishing difference
# Final cost : 0.006174992671216736
# Compute control for a deterministic system
# Cost in iteration 0: 0.006174992671216736
# Converged in iteration 1 with cost 0.006174992671216736 because of step counter
# Final cost : 0.006174992671216736
# Compute control for a deterministic system
# Cost in iteration 0: 0.006174992671216736
# Converged in iteration 1 with cost 0.006174992671216736 because of step counter
# Final cost : 0.006174992671216736
# Compute control for a deterministic system
# Cost in iteration 0: 0.004176267228012483
# Final cost : 0.003922800685795376
# Compute control for a deterministic system
# Cost in iteration 0: 0.003922800685795376
# Final cost : 0.003919244324922822
# Compute control for a deterministic system
# Cost in iteration 0: 0.003919244324922822
# Converged in iteration 302 with cost 0.003919244321794401 because of step counter
# Final cost : 0.003919244321794401
# Compute control for a deterministic system
# Cost in iteration 0: 0.003919244321794401
# Converged in iteration 21 with cost 0.003919244321785711 because of step counter
# Final cost : 0.003919244321785711
# Compute control for a deterministic system
# Cost in iteration 0: 0.003919244321785711
# Converged in iteration 2 with cost 0.00391924432178571 because of step counter
# Final cost : 0.00391924432178571
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.002346420746802424
# Final cost : 0.002219407717068687
# Compute control for a deterministic system
# Cost in iteration 0: 0.002219407717068687
# Final cost : 0.00221736906132286
# Compute control for a deterministic system
# Cost in iteration 0: 0.00221736906132286
# Converged in iteration 232 with cost 0.002217369059828141 because of step counter
# Final cost : 0.002217369059828141
# Compute control for a deterministic system
# Cost in iteration 0: 0.002217369059828141
# Converged in iteration 1 with cost 0.002217369059828141 because of step counter
# Final cost : 0.002217369059828141
# Compute control for a deterministic system
# Cost in iteration 0: 0.002217369059828141
# Converged in iteration 1 with cost 0.002217369059828141 because of step counter
# Final cost : 0.002217369059828141
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010242704885786494
# Final cost : 0.0009739635619218426
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009739635619218426
# Final cost : 0.0009730711541227442
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730711541227442
# Converged in iteration 228 with cost 0.0009730711532765108 because of step counter
# Final cost : 0.0009730711532765108
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730711532765108
# Converged in iteration 1 with cost 0.0009730711532765108 because of step counter
# Final cost : 0.0009730711532765108
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009730711532765108
# Converged in iteration 1 with cost 0.0009730711532765108 because of step counter
# Final cost : 0.0009730711532765108
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025284327952809126
# Final cost : 0.00024839534850092294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024839534850092294
# Final cost : 0.00024816125526915927
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024816125526915927
# Converged in iteration 242 with cost 0.00024816125492794843 because of step counter
# Final cost : 0.00024816125492794843
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024816125492794843
# Converged in iteration 6 with cost 0.0002481612549277285 because of step counter
# Final cost : 0.0002481612549277285
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002481612549277285
# Converged in iteration 1 with cost 0.0002481612549277285 because of step counter
# Final cost : 0.0002481612549277285

# %%
save(results_min)
