# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.390687755422495 
y_init = 0.46070476656497017
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,183], wc.inh[0,183]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.20823994240047755 0.10333216754118275
# minima =  [  500  2002  3501  5001  6501  8001  9501 11001 12500 14000 15500 17000
#  18500 20000 21499 22999 24499 25999 27499 28999 30498 31998 33498 34998
#  36498 37997 39497]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s2_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s2_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * ( 0.95 + 0.1*np.random.random() )
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * ( 0.95 + 0.1*np.random.random() )
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05597484015996037
# Final cost : 0.03752387872313381
# Compute control for a deterministic system
# Cost in iteration 0: 0.03752387872313381
# Cost in iteration 200: 0.019925089844015885
# Final cost : 0.019925089844015885
# Compute control for a deterministic system
# Cost in iteration 0: 0.019925089844015885
# Converged in iteration 8 with cost 0.019925089843979817 because of step counter
# Final cost : 0.019925089843979817
# Compute control for a deterministic system
# Cost in iteration 0: 0.019925089843979817
# Converged in iteration 1 with cost 0.019925089843979817 because of step counter
# Final cost : 0.019925089843979817
# Compute control for a deterministic system
# Cost in iteration 0: 0.019925089843979817
# Converged in iteration 1 with cost 0.019925089843979817 because of step counter
# Final cost : 0.019925089843979817
# Compute control for a deterministic system
# Cost in iteration 0: 0.019925089843979817
# Converged in iteration 1 with cost 0.019925089843979817 because of step counter
# Final cost : 0.019925089843979817
# Compute control for a deterministic system
# Cost in iteration 0: 0.2268169979617528
# Final cost : 0.14134409600596748
# Compute control for a deterministic system
# Cost in iteration 0: 0.14134409600596748
# Cost in iteration 200: 0.042881841626004454
# Final cost : 0.042881841626004454
# Compute control for a deterministic system
# Cost in iteration 0: 0.042881841626004454
# Converged in iteration 38 with cost 0.04288178791486261 because of step counter
# Final cost : 0.04288178791486261
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178791486261
# Converged in iteration 1 with cost 0.04288178791486261 because of step counter
# Final cost : 0.04288178791486261
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178791486261
# Converged in iteration 1 with cost 0.04288178791486261 because of step counter
# Final cost : 0.04288178791486261
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178791486261
# Converged in iteration 1 with cost 0.04288178791486261 because of step counter
# Final cost : 0.04288178791486261
# Compute control for a deterministic system
# Cost in iteration 0: 0.49463945206848964
# Final cost : 0.30974600104748656
# Compute control for a deterministic system
# Cost in iteration 0: 0.30974600104748656
# Cost in iteration 200: 0.06541592499451254
# Final cost : 0.06541592499451254
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541592499451254
# Converged in iteration 29 with cost 0.06541154519027992 because of vanishing difference
# Final cost : 0.06541154519027992
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541154519027992
# Converged in iteration 61 with cost 0.06541153941388352 because of step counter
# Final cost : 0.06541153941388352
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541153941388352
# Converged in iteration 1 with cost 0.06541153941388352 because of step counter
# Final cost : 0.06541153941388352
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541153941388352
# Converged in iteration 2 with cost 0.06541153941387949 because of step counter
# Final cost : 0.06541153941387949
# Compute control for a deterministic system
# Cost in iteration 0: 0.8609128013808958
# Final cost : 0.5551249419667166
# Compute control for a deterministic system
# Cost in iteration 0: 0.5551249419667166
# Cost in iteration 200: 0.08871362442935048
# Final cost : 0.08871362442935048
# Compute control for a deterministic system
# Cost in iteration 0: 0.08871362442935048
# Converged in iteration 141 with cost 0.08866466448841215 because of step counter
# Final cost : 0.08866466448841215
# Compute control for a deterministic system
# Cost in iteration 0: 0.08866466448841215
# Converged in iteration 4 with cost 0.08866466448840726 because of step counter
# Final cost : 0.08866466448840726
# Compute control for a deterministic system
# Cost in iteration 0: 0.08866466448840726
# Converged in iteration 3 with cost 0.0886646644884062 because of step counter
# Final cost : 0.0886646644884062
# Compute control for a deterministic system
# Cost in iteration 0: 0.0886646644884062
# Converged in iteration 1 with cost 0.0886646644884062 because of step counter
# Final cost : 0.0886646644884062
# Compute control for a deterministic system
# Cost in iteration 0: 1.292238864168766
# Final cost : 0.8653520459840924
# Compute control for a deterministic system
# Cost in iteration 0: 0.8653520459840924
# Cost in iteration 200: 0.11159797296922377
# Final cost : 0.11159797296922377
# Compute control for a deterministic system
# Cost in iteration 0: 0.11159797296922377
# Converged in iteration 76 with cost 0.11137587746513196 because of vanishing difference
# Final cost : 0.11137587746513196
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137587746513196
# Converged in iteration 123 with cost 0.11137584914445292 because of step counter
# Final cost : 0.11137584914445292
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137584914445292
# Converged in iteration 2 with cost 0.11137584914445278 because of step counter
# Final cost : 0.11137584914445278
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137584914445278
# Converged in iteration 1 with cost 0.11137584914445278 because of step counter
# Final cost : 0.11137584914445278
# Compute control for a deterministic system
# Cost in iteration 0: 1.796907085101933
# Final cost : 1.2549618852100901
# Compute control for a deterministic system
# Cost in iteration 0: 1.2549618852100901
# Cost in iteration 200: 0.13540541316558388
# Final cost : 0.13540541316558388
# Compute control for a deterministic system
# Cost in iteration 0: 0.13540541316558388
# Converged in iteration 101 with cost 0.13473908973121473 because of vanishing difference
# Final cost : 0.13473908973121473
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473908973121473
# Converged in iteration 158 with cost 0.13473902471788388 because of step counter
# Final cost : 0.13473902471788388
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473902471788388
# Converged in iteration 5 with cost 0.13473902471785332 because of vanishing difference
# Final cost : 0.13473902471785332
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473902471785332
# Converged in iteration 4 with cost 0.13473902471784097 because of step counter
# Final cost : 0.13473902471784097
# Compute control for a deterministic system
# Cost in iteration 0: 2.333924033036714
# Final cost : 1.698467754045632
# Compute control for a deterministic system
# Cost in iteration 0: 1.698467754045632
# Cost in iteration 200: 0.1590136578292301
# Final cost : 0.1590136578292301
# Compute control for a deterministic system
# Cost in iteration 0: 0.1590136578292301
# Converged in iteration 116 with cost 0.15748375001404916 because of vanishing difference
# Final cost : 0.15748375001404916
# Compute control for a deterministic system
# Cost in iteration 0: 0.15748375001404916
# Cost in iteration 200: 0.1574834964978586
# Final cost : 0.1574834964978586
# Compute control for a deterministic system
# Cost in iteration 0: 0.1574834964978586
# Converged in iteration 31 with cost 0.15748349649765456 because of step counter
# Final cost : 0.15748349649765456
# Compute control for a deterministic system
# Cost in iteration 0: 0.15748349649765456
# Converged in iteration 2 with cost 0.15748349649765203 because of step counter
# Final cost : 0.15748349649765203
# Compute control for a deterministic system
# Cost in iteration 0: 2.9173363031335406
# Final cost : 2.2119219564109076
# Compute control for a deterministic system
# Cost in iteration 0: 2.2119219564109076
# Cost in iteration 200: 0.1837027821407539
# Final cost : 0.1837027821407539
# Compute control for a deterministic system
# Cost in iteration 0: 0.1837027821407539
# Converged in iteration 177 with cost 0.1807465109889002 because of vanishing difference
# Final cost : 0.1807465109889002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1807465109889002
# Cost in iteration 200: 0.1807464420486923
# Final cost : 0.1807464420486923
# Compute control for a deterministic system
# Cost in iteration 0: 0.1807464420486923
# Converged in iteration 33 with cost 0.18074644204795737 because of vanishing difference
# Final cost : 0.18074644204795737
# Compute control for a deterministic system
# Cost in iteration 0: 0.18074644204795737
# Converged in iteration 22 with cost 0.18074644204781168 because of step counter
# Final cost : 0.18074644204781168
# Compute control for a deterministic system
# Cost in iteration 0: 3.5016441074519524
# Final cost : 2.758028850244562
# Compute control for a deterministic system
# Cost in iteration 0: 2.758028850244562
# Cost in iteration 200: 0.20831518216123546
# Final cost : 0.20831518216123546
# Compute control for a deterministic system
# Cost in iteration 0: 0.20831518216123546
# Cost in iteration 200: 0.2031542509423655
# Final cost : 0.2031542509423655
# Compute control for a deterministic system
# Cost in iteration 0: 0.2031542509423655
# Cost in iteration 200: 0.203154064285358
# Final cost : 0.203154064285358
# Compute control for a deterministic system
# Cost in iteration 0: 0.203154064285358
# Converged in iteration 142 with cost 0.20315406426668683 because of step counter
# Final cost : 0.20315406426668683
# Compute control for a deterministic system
# Cost in iteration 0: 0.20315406426668683
# Converged in iteration 1 with cost 0.20315406426668683 because of step counter
# Final cost : 0.20315406426668683
# Compute control for a deterministic system
# Cost in iteration 0: 4.103094916391872
# Final cost : 3.3535739030713536
# Compute control for a deterministic system
# Cost in iteration 0: 3.3535739030713536
# Cost in iteration 200: 0.23391248504959827
# Final cost : 0.23391248504959827
# Compute control for a deterministic system
# Cost in iteration 0: 0.23391248504959827
# Converged in iteration 184 with cost 0.22585586651676728 because of vanishing difference
# Final cost : 0.22585586651676728
# Compute control for a deterministic system
# Cost in iteration 0: 0.22585586651676728
# Cost in iteration 200: 0.22585369061732122
# Final cost : 0.22585369061732122
# Compute control for a deterministic system
# Cost in iteration 0: 0.22585369061732122
# Cost in iteration 200: 0.22585368965786973
# Converged in iteration 252 with cost 0.2258536896571214 because of step counter
# Final cost : 0.2258536896571214
# Compute control for a deterministic system
# Cost in iteration 0: 0.2258536896571214
# Converged in iteration 4 with cost 0.22585368965708874 because of step counter
# Final cost : 0.22585368965708874
# Compute control for a deterministic system
# Cost in iteration 0: 4.675788932785525
# Final cost : 3.9536493464114026
# Compute control for a deterministic system
# Cost in iteration 0: 3.9536493464114026
# Cost in iteration 200: 0.2595802019388782
# Final cost : 0.2595802019388782
# Compute control for a deterministic system
# Cost in iteration 0: 0.2595802019388782
# Cost in iteration 200: 0.24774980252255907
# Final cost : 0.24774980252255907
# Compute control for a deterministic system
# Cost in iteration 0: 0.24774980252255907
# Cost in iteration 200: 0.2477444137587047
# Final cost : 0.2477444137587047
# Compute control for a deterministic system
# Cost in iteration 0: 0.2477444137587047
# Cost in iteration 200: 0.2477444062121157
# Converged in iteration 391 with cost 0.24774440619269852 because of step counter
# Final cost : 0.24774440619269852
# Compute control for a deterministic system
# Cost in iteration 0: 0.24774440619269852
# Converged in iteration 2 with cost 0.2477444061926979 because of step counter
# Final cost : 0.2477444061926979
# Compute control for a deterministic system
# Cost in iteration 0: 5.236757252545923
# Final cost : 4.575321433685547
# Compute control for a deterministic system
# Cost in iteration 0: 4.575321433685547
# Cost in iteration 200: 0.2872116814395792
# Final cost : 0.2872116814395792
# Compute control for a deterministic system
# Cost in iteration 0: 0.2872116814395792
# Cost in iteration 200: 0.27017461573900686
# Final cost : 0.27017461573900686
# Compute control for a deterministic system
# Cost in iteration 0: 0.27017461573900686
# Converged in iteration 4 with cost 0.2701730809286346 because of vanishing difference
# Final cost : 0.2701730809286346
# Compute control for a deterministic system
# Cost in iteration 0: 0.2701730809286346
# Cost in iteration 200: 0.2701579620646302
# Cost in iteration 400: 0.27015787505052485
# Final cost : 0.27015787505052485
# Compute control for a deterministic system
# Cost in iteration 0: 0.27015787505052485
# Cost in iteration 200: 0.27015787451847834
# Converged in iteration 217 with cost 0.270157874518401 because of step counter
# Final cost : 0.270157874518401
# Compute control for a deterministic system
# Cost in iteration 0: 5.7439352757160025
# Final cost : 5.169198453522424
# Compute control for a deterministic system
# Cost in iteration 0: 5.169198453522424
# Cost in iteration 200: 0.31524843997581364
# Final cost : 0.31524843997581364
# Compute control for a deterministic system
# Cost in iteration 0: 0.31524843997581364
# Cost in iteration 200: 0.2920486973056661
# Final cost : 0.2920486973056661
# Compute control for a deterministic system
# Cost in iteration 0: 0.2920486973056661
# Cost in iteration 200: 0.29200707220502914
# Final cost : 0.29200707220502914
# Compute control for a deterministic system
# Cost in iteration 0: 0.29200707220502914
# Cost in iteration 200: 0.2920067538804519
# Cost in iteration 400: 0.29200674998530685
# Final cost : 0.29200674998530685
# Compute control for a deterministic system
# Cost in iteration 0: 0.29200674998530685
# Converged in iteration 175 with cost 0.29200674993678016 because of vanishing difference
# Final cost : 0.29200674993678016
# Compute control for a deterministic system
# Cost in iteration 0: 6.212871819162207
# Final cost : 5.747693231350028
# Compute control for a deterministic system
# Cost in iteration 0: 5.747693231350028
# Cost in iteration 200: 0.3460454911265301
# Final cost : 0.3460454911265301
# Compute control for a deterministic system
# Cost in iteration 0: 0.3460454911265301
# Cost in iteration 200: 0.31463082088417405
# Final cost : 0.31463082088417405
# Compute control for a deterministic system
# Cost in iteration 0: 0.31463082088417405
# Converged in iteration 119 with cost 0.3145222565046643 because of vanishing difference
# Final cost : 0.3145222565046643
# Compute control for a deterministic system
# Cost in iteration 0: 0.3145222565046643
# Cost in iteration 200: 0.3145122633916886
# Cost in iteration 400: 0.3145120450255499
# Final cost : 0.3145120450255499
# Compute control for a deterministic system
# Cost in iteration 0: 0.3145120450255499
# Cost in iteration 200: 0.31451203997640104
# Converged in iteration 348 with cost 0.31451203996699345 because of step counter
# Final cost : 0.31451203996699345
# Compute control for a deterministic system
# Cost in iteration 0: 6.609012181946943
# Final cost : 6.259580411548599
# Compute control for a deterministic system
# Cost in iteration 0: 6.259580411548599
# Cost in iteration 200: 0.37942938646637475
# Final cost : 0.37942938646637475
# Compute control for a deterministic system
# Cost in iteration 0: 0.37942938646637475
# Cost in iteration 200: 0.33676220073483315
# Final cost : 0.33676220073483315
# Compute control for a deterministic system
# Cost in iteration 0: 0.33676220073483315
# Converged in iteration 43 with cost 0.3366014309905682 because of vanishing difference
# Final cost : 0.3366014309905682
# Compute control for a deterministic system
# Cost in iteration 0: 0.3366014309905682
# Cost in iteration 200: 0.3364997582053101
# Cost in iteration 400: 0.33649634329762207
# Final cost : 0.33649634329762207
# Compute control for a deterministic system
# Cost in iteration 0: 0.33649634329762207
# Cost in iteration 200: 0.3364962124036279
# Cost in iteration 400: 0.3364962117699867
# Converged in iteration 488 with cost 0.3364962117666583 because of step counter
# Final cost : 0.3364962117666583
# Compute control for a deterministic system
# Cost in iteration 0: 6.9458049731357585
# Final cost : 6.7114813383005325
# Compute control for a deterministic system
# Cost in iteration 0: 6.7114813383005325
# Cost in iteration 200: 0.4211551632844866
# Final cost : 0.4211551632844866
# Compute control for a deterministic system
# Cost in iteration 0: 0.4211551632844866
# Cost in iteration 200: 0.359674492711148
# Final cost : 0.359674492711148
# Compute control for a deterministic system
# Cost in iteration 0: 0.359674492711148
# Converged in iteration 72 with cost 0.35929898698366775 because of vanishing difference
# Final cost : 0.35929898698366775
# Compute control for a deterministic system
# Cost in iteration 0: 0.35929898698366775
# Cost in iteration 200: 0.35914671139390936
# Cost in iteration 400: 0.3591390274413575
# Final cost : 0.3591390274413575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3591390274413575
# Cost in iteration 200: 0.359138567981498
# Cost in iteration 400: 0.35913856249186277
# Cost in iteration 600: 0.35913856243310505
# Converged in iteration 647 with cost 0.3591385624327088 because of step counter
# Final cost : 0.3591385624327088
# Compute control for a deterministic system
# Cost in iteration 0: 7.20033338104308
# Final cost : 7.06291417217926
# Compute control for a deterministic system
# Cost in iteration 0: 7.06291417217926
# Cost in iteration 200: 0.46540992452244395
# Final cost : 0.46540992452244395
# Compute control for a deterministic system
# Cost in iteration 0: 0.46540992452244395
# Cost in iteration 200: 0.38221062119340576
# Final cost : 0.38221062119340576
# Compute control for a deterministic system
# Cost in iteration 0: 0.38221062119340576
# Converged in iteration 193 with cost 0.38128576391382335 because of vanishing difference
# Final cost : 0.38128576391382335
# Compute control for a deterministic system
# Cost in iteration 0: 0.38128576391382335
# Cost in iteration 200: 0.381236608552292
# Cost in iteration 400: 0.38123276611263596
# Final cost : 0.38123276611263596
# Compute control for a deterministic system
# Cost in iteration 0: 0.38123276611263596
# Cost in iteration 200: 0.3812324230986048
# Cost in iteration 400: 0.3812324149278769
# Cost in iteration 600: 0.3812324147258777
# Converged in iteration 774 with cost 0.38123241472074776 because of step counter
# Final cost : 0.38123241472074776
# Compute control for a deterministic system
# Cost in iteration 0: 7.383329864284528
# Final cost : 7.321392184011403
# Compute control for a deterministic system
# Cost in iteration 0: 7.321392184011403
# Cost in iteration 200: 0.5155758855193471
# Final cost : 0.5155758855193471
# Compute control for a deterministic system
# Cost in iteration 0: 0.5155758855193471
# Cost in iteration 200: 0.40570146571216636
# Final cost : 0.40570146571216636
# Compute control for a deterministic system
# Cost in iteration 0: 0.40570146571216636
# Cost in iteration 200: 0.4040444219973359
# Final cost : 0.4040444219973359
# Compute control for a deterministic system
# Cost in iteration 0: 0.4040444219973359
# Cost in iteration 200: 0.4039639228911142
# Cost in iteration 400: 0.4039553844123038
# Final cost : 0.4039553844123038
# Compute control for a deterministic system
# Cost in iteration 0: 0.4039553844123038
# Cost in iteration 200: 0.40395433854910034
# Cost in iteration 400: 0.4039542970907592
# Cost in iteration 600: 0.40395429557729967
# Converged in iteration 694 with cost 0.40395429552829604 because of vanishing difference
# Final cost : 0.40395429552829604
# Compute control for a deterministic system
# Cost in iteration 0: 7.483919342422571
# Final cost : 7.467574192706426
# Compute control for a deterministic system
# Cost in iteration 0: 7.467574192706426
# Cost in iteration 200: 0.5709137084497602
# Final cost : 0.5709137084497602
# Compute control for a deterministic system
# Cost in iteration 0: 0.5709137084497602
# Cost in iteration 200: 0.4290088210873541
# Final cost : 0.4290088210873541
# Compute control for a deterministic system
# Cost in iteration 0: 0.4290088210873541
# Cost in iteration 200: 0.42626622998851726
# Final cost : 0.42626622998851726
# Compute control for a deterministic system
# Cost in iteration 0: 0.42626622998851726
# Cost in iteration 200: 0.4261147209969332
# Cost in iteration 400: 0.4260943947566861
# Final cost : 0.4260943947566861
# Compute control for a deterministic system
# Cost in iteration 0: 0.4260943947566861
# Cost in iteration 200: 0.42609112453521775
# Cost in iteration 400: 0.42609093423637
# Cost in iteration 600: 0.4260909239957814
# Cost in iteration 800: 0.4260909234268649
# Cost in iteration 1000: 0.426090923396349
# Final cost : 0.426090923396349
# Compute control for a deterministic system
# Cost in iteration 0: 7.507309270666101
# Converged in iteration 1 with cost 7.507309270666101 because of step counter
# Final cost : 7.507309270666101
# Compute control for a deterministic system
# Cost in iteration 0: 7.507309270666101
# Converged in iteration 1 with cost 7.507309270666101 because of step counter
# Final cost : 7.507309270666101
# Compute control for a deterministic system
# Cost in iteration 0: 7.507309270666101
# Cost in iteration 200: 0.4557133931113436
# Final cost : 0.4557133931113436
# Compute control for a deterministic system
# Cost in iteration 0: 0.4557133931113436
# Cost in iteration 200: 0.4492244589049112
# Final cost : 0.4492244589049112
# Compute control for a deterministic system
# Cost in iteration 0: 0.4492244589049112
# Cost in iteration 200: 0.44888583498393414
# Cost in iteration 400: 0.4488311468215073
# Final cost : 0.4488311468215073
# Compute control for a deterministic system
# Cost in iteration 0: 0.4488311468215073
# Cost in iteration 200: 0.4488201062521508
# Cost in iteration 400: 0.4488192214885225
# Cost in iteration 600: 0.44881916374554887
# Cost in iteration 800: 0.44881915945497736
# Cost in iteration 1000: 0.4488191591050345
# Final cost : 0.4488191591050345
# Compute control for a deterministic system
# Cost in iteration 0: 7.452558177126701
# Final cost : 7.44577135980203
# Compute control for a deterministic system
# Cost in iteration 0: 7.44577135980203
# Cost in iteration 200: 0.6070870036187695
# Final cost : 0.6070870036187695
# Compute control for a deterministic system
# Cost in iteration 0: 0.6070870036187695
# Cost in iteration 200: 0.45335842871259496
# Final cost : 0.45335842871259496
# Compute control for a deterministic system
# Cost in iteration 0: 0.45335842871259496
# Cost in iteration 200: 0.45085229891738515
# Final cost : 0.45085229891738515
# Compute control for a deterministic system
# Cost in iteration 0: 0.45085229891738515
# Cost in iteration 200: 0.4507818257206321
# Cost in iteration 400: 0.45077609535985075
# Final cost : 0.45077609535985075
# Compute control for a deterministic system
# Cost in iteration 0: 0.45077609535985075
# Cost in iteration 200: 0.4507755511977086
# Converged in iteration 381 with cost 0.45077555086255344 because of vanishing difference
# Final cost : 0.45077555086255344
# Compute control for a deterministic system
# Cost in iteration 0: 7.317270048243203
# Final cost : 7.27474582283501
# Compute control for a deterministic system
# Cost in iteration 0: 7.27474582283501
# Cost in iteration 200: 0.5447519827875719
# Final cost : 0.5447519827875719
# Compute control for a deterministic system
# Cost in iteration 0: 0.5447519827875719
# Cost in iteration 200: 0.4274291995471107
# Final cost : 0.4274291995471107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4274291995471107
# Cost in iteration 200: 0.4258830936845617
# Final cost : 0.4258830936845617
# Compute control for a deterministic system
# Cost in iteration 0: 0.4258830936845617
# Cost in iteration 200: 0.4258464297236813
# Cost in iteration 400: 0.42584409261761724
# Final cost : 0.42584409261761724
# Compute control for a deterministic system
# Cost in iteration 0: 0.42584409261761724
# Cost in iteration 200: 0.4258439279142195
# Cost in iteration 400: 0.42584392731173215
# Converged in iteration 466 with cost 0.4258439273096988 because of step counter
# Final cost : 0.4258439273096988
# Compute control for a deterministic system
# Cost in iteration 0: 7.1096682294529305
# Final cost : 7.004113044980081
# Compute control for a deterministic system
# Cost in iteration 0: 7.004113044980081
# Cost in iteration 200: 0.4914160794845862
# Final cost : 0.4914160794845862
# Compute control for a deterministic system
# Cost in iteration 0: 0.4914160794845862
# Cost in iteration 200: 0.4024113793050305
# Final cost : 0.4024113793050305
# Compute control for a deterministic system
# Cost in iteration 0: 0.4024113793050305
# Cost in iteration 200: 0.4015251293169513
# Final cost : 0.4015251293169513
# Compute control for a deterministic system
# Cost in iteration 0: 0.4015251293169513
# Cost in iteration 200: 0.401506095582564
# Cost in iteration 400: 0.40150517327969615
# Final cost : 0.40150517327969615
# Compute control for a deterministic system
# Cost in iteration 0: 0.40150517327969615
# Cost in iteration 200: 0.40150512457041865
# Converged in iteration 366 with cost 0.4015051245249679 because of step counter
# Final cost : 0.4015051245249679
# Compute control for a deterministic system
# Cost in iteration 0: 6.821433590527662
# Final cost : 6.625928211028121
# Compute control for a deterministic system
# Cost in iteration 0: 6.625928211028121
# Cost in iteration 200: 0.4416012852956954
# Final cost : 0.4416012852956954
# Compute control for a deterministic system
# Cost in iteration 0: 0.4416012852956954
# Cost in iteration 200: 0.37702328932310936
# Final cost : 0.37702328932310936
# Compute control for a deterministic system
# Cost in iteration 0: 0.37702328932310936
# Converged in iteration 128 with cost 0.37654140216955306 because of vanishing difference
# Final cost : 0.37654140216955306
# Compute control for a deterministic system
# Cost in iteration 0: 0.37654140216955306
# Cost in iteration 200: 0.3765131400685989
# Cost in iteration 400: 0.37651218128673786
# Final cost : 0.37651218128673786
# Compute control for a deterministic system
# Cost in iteration 0: 0.37651218128673786
# Cost in iteration 200: 0.376512145837411
# Converged in iteration 357 with cost 0.37651214580668224 because of step counter
# Final cost : 0.37651214580668224
# Compute control for a deterministic system
# Cost in iteration 0: 6.472680154265202
# Final cost : 6.172410617287783
# Compute control for a deterministic system
# Cost in iteration 0: 6.172410617287783
# Cost in iteration 200: 0.39875893998691875
# Final cost : 0.39875893998691875
# Compute control for a deterministic system
# Cost in iteration 0: 0.39875893998691875
# Cost in iteration 200: 0.3524640287926695
# Final cost : 0.3524640287926695
# Compute control for a deterministic system
# Cost in iteration 0: 0.3524640287926695
# Converged in iteration 72 with cost 0.35227436892222047 because of vanishing difference
# Final cost : 0.35227436892222047
# Compute control for a deterministic system
# Cost in iteration 0: 0.35227436892222047
# Cost in iteration 200: 0.35222616587270805
# Cost in iteration 400: 0.35222511161672465
# Final cost : 0.35222511161672465
# Compute control for a deterministic system
# Cost in iteration 0: 0.35222511161672465
# Cost in iteration 200: 0.3522250861957897
# Converged in iteration 365 with cost 0.35222508616891074 because of step counter
# Final cost : 0.35222508616891074
# Compute control for a deterministic system
# Cost in iteration 0: 6.051580188673024
# Final cost : 5.637465192739372
# Compute control for a deterministic system
# Cost in iteration 0: 5.637465192739372
# Cost in iteration 200: 0.36204623991938645
# Final cost : 0.36204623991938645
# Compute control for a deterministic system
# Cost in iteration 0: 0.36204623991938645
# Cost in iteration 200: 0.3274684748252006
# Final cost : 0.3274684748252006
# Compute control for a deterministic system
# Cost in iteration 0: 0.3274684748252006
# Converged in iteration 24 with cost 0.3274293019367193 because of vanishing difference
# Final cost : 0.3274293019367193
# Compute control for a deterministic system
# Cost in iteration 0: 0.3274293019367193
# Cost in iteration 200: 0.3273640256885599
# Cost in iteration 400: 0.3273631981784919
# Final cost : 0.3273631981784919
# Compute control for a deterministic system
# Cost in iteration 0: 0.3273631981784919
# Cost in iteration 200: 0.327363186621419
# Converged in iteration 289 with cost 0.3273631866137911 because of step counter
# Final cost : 0.3273631866137911
# Compute control for a deterministic system
# Cost in iteration 0: 5.588780711097274
# Final cost : 5.070224892945542
# Compute control for a deterministic system
# Cost in iteration 0: 5.070224892945542
# Cost in iteration 200: 0.3287013221907887
# Final cost : 0.3287013221907887
# Compute control for a deterministic system
# Cost in iteration 0: 0.3287013221907887
# Cost in iteration 200: 0.30330866856744887
# Final cost : 0.30330866856744887
# Compute control for a deterministic system
# Cost in iteration 0: 0.30330866856744887
# Converged in iteration 36 with cost 0.30328192395619447 because of vanishing difference
# Final cost : 0.30328192395619447
# Compute control for a deterministic system
# Cost in iteration 0: 0.30328192395619447
# Cost in iteration 200: 0.3032667780867825
# Cost in iteration 400: 0.3032666717307335
# Final cost : 0.3032666717307335
# Compute control for a deterministic system
# Cost in iteration 0: 0.3032666717307335
# Converged in iteration 178 with cost 0.3032666709505041 because of vanishing difference
# Final cost : 0.3032666709505041
# Compute control for a deterministic system
# Cost in iteration 0: 5.069620239168994
# Final cost : 4.461856784391627
# Compute control for a deterministic system
# Cost in iteration 0: 4.461856784391627
# Cost in iteration 200: 0.296820973901436
# Final cost : 0.296820973901436
# Compute control for a deterministic system
# Cost in iteration 0: 0.296820973901436
# Cost in iteration 200: 0.2786692199511874
# Final cost : 0.2786692199511874
# Compute control for a deterministic system
# Cost in iteration 0: 0.2786692199511874
# Cost in iteration 200: 0.27865459816403076
# Final cost : 0.27865459816403076
# Compute control for a deterministic system
# Cost in iteration 0: 0.27865459816403076
# Cost in iteration 200: 0.27865457440739816
# Cost in iteration 400: 0.27865457433412233
# Final cost : 0.27865457433412233
# Compute control for a deterministic system
# Cost in iteration 0: 0.27865457433412233
# Converged in iteration 18 with cost 0.27865457433398794 because of step counter
# Final cost : 0.27865457433398794
# Compute control for a deterministic system
# Cost in iteration 0: 4.532486543312421
# Final cost : 3.8633305604951667
# Compute control for a deterministic system
# Cost in iteration 0: 3.8633305604951667
# Cost in iteration 200: 0.26730163651452976
# Final cost : 0.26730163651452976
# Compute control for a deterministic system
# Cost in iteration 0: 0.26730163651452976
# Cost in iteration 200: 0.25483265226060475
# Final cost : 0.25483265226060475
# Compute control for a deterministic system
# Cost in iteration 0: 0.25483265226060475
# Cost in iteration 200: 0.25482878900711375
# Final cost : 0.25482878900711375
# Compute control for a deterministic system
# Cost in iteration 0: 0.25482878900711375
# Cost in iteration 200: 0.2548287868758087
# Converged in iteration 300 with cost 0.25482878687323574 because of step counter
# Final cost : 0.25482878687323574
# Compute control for a deterministic system
# Cost in iteration 0: 0.25482878687323574
# Converged in iteration 2 with cost 0.2548287868732342 because of step counter
# Final cost : 0.2548287868732342
# Compute control for a deterministic system
# Cost in iteration 0: 3.9604101418819124
# Final cost : 3.2590351069450776
# Compute control for a deterministic system
# Cost in iteration 0: 3.2590351069450776
# Cost in iteration 200: 0.2386610778376743
# Final cost : 0.2386610778376743
# Compute control for a deterministic system
# Cost in iteration 0: 0.2386610778376743
# Cost in iteration 200: 0.23049862685457054
# Final cost : 0.23049862685457054
# Compute control for a deterministic system
# Cost in iteration 0: 0.23049862685457054
# Cost in iteration 200: 0.230497869423561
# Final cost : 0.230497869423561
# Compute control for a deterministic system
# Cost in iteration 0: 0.230497869423561
# Converged in iteration 174 with cost 0.2304978693245534 because of vanishing difference
# Final cost : 0.2304978693245534
# Compute control for a deterministic system
# Cost in iteration 0: 0.2304978693245534
# Converged in iteration 1 with cost 0.2304978693245534 because of step counter
# Final cost : 0.2304978693245534
# Compute control for a deterministic system
# Cost in iteration 0: 3.3954012365711557
# Final cost : 2.694412760671872
# Compute control for a deterministic system
# Cost in iteration 0: 2.694412760671872
# Cost in iteration 200: 0.21207530992988513
# Final cost : 0.21207530992988513
# Compute control for a deterministic system
# Cost in iteration 0: 0.21207530992988513
# Cost in iteration 200: 0.20693496888119153
# Final cost : 0.20693496888119153
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693496888119153
# Cost in iteration 200: 0.20693485099817316
# Final cost : 0.20693485099817316
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693485099817316
# Converged in iteration 72 with cost 0.20693485099500866 because of step counter
# Final cost : 0.20693485099500866
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693485099500866
# Converged in iteration 1 with cost 0.20693485099500866 because of step counter
# Final cost : 0.20693485099500866
# Compute control for a deterministic system
# Cost in iteration 0: 2.819397045152489
# Final cost : 2.150990732859096
# Compute control for a deterministic system
# Cost in iteration 0: 2.150990732859096
# Cost in iteration 200: 0.1857643465492878
# Final cost : 0.1857643465492878
# Compute control for a deterministic system
# Cost in iteration 0: 0.1857643465492878
# Converged in iteration 122 with cost 0.18285900799717 because of vanishing difference
# Final cost : 0.18285900799717
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285900799717
# Cost in iteration 200: 0.18285776931602352
# Final cost : 0.18285776931602352
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285776931602352
# Converged in iteration 62 with cost 0.18285776931300138 because of step counter
# Final cost : 0.18285776931300138
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285776931300138
# Converged in iteration 1 with cost 0.18285776931300138 because of step counter
# Final cost : 0.18285776931300138
# Compute control for a deterministic system
# Cost in iteration 0: 2.2749281397562306
# Final cost : 1.6673533725831733
# Compute control for a deterministic system
# Cost in iteration 0: 1.6673533725831733
# Cost in iteration 200: 0.16101865572050575
# Final cost : 0.16101865572050575
# Compute control for a deterministic system
# Cost in iteration 0: 0.16101865572050575
# Cost in iteration 200: 0.15952785285815438
# Final cost : 0.15952785285815438
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952785285815438
# Converged in iteration 108 with cost 0.15952785256867805 because of step counter
# Final cost : 0.15952785256867805
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952785256867805
# Converged in iteration 1 with cost 0.15952785256867805 because of step counter
# Final cost : 0.15952785256867805
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952785256867805
# Converged in iteration 1 with cost 0.15952785256867805 because of step counter
# Final cost : 0.15952785256867805
# Compute control for a deterministic system
# Cost in iteration 0: 1.7455097418959467
# Final cost : 1.2261168403930085
# Compute control for a deterministic system
# Cost in iteration 0: 1.2261168403930085
# Cost in iteration 200: 0.13633310050209207
# Final cost : 0.13633310050209207
# Compute control for a deterministic system
# Cost in iteration 0: 0.13633310050209207
# Converged in iteration 86 with cost 0.13568163392666005 because of vanishing difference
# Final cost : 0.13568163392666005
# Compute control for a deterministic system
# Cost in iteration 0: 0.13568163392666005
# Converged in iteration 149 with cost 0.13568152146196308 because of step counter
# Final cost : 0.13568152146196308
# Compute control for a deterministic system
# Cost in iteration 0: 0.13568152146196308
# Converged in iteration 2 with cost 0.13568152146195986 because of step counter
# Final cost : 0.13568152146195986
# Compute control for a deterministic system
# Cost in iteration 0: 0.13568152146195986
# Converged in iteration 1 with cost 0.13568152146195986 because of step counter
# Final cost : 0.13568152146195986
# Compute control for a deterministic system
# Cost in iteration 0: 1.2719211643645472
# Final cost : 0.8572897071443265
# Compute control for a deterministic system
# Cost in iteration 0: 0.8572897071443265
# Cost in iteration 200: 0.1127986343712072
# Final cost : 0.1127986343712072
# Compute control for a deterministic system
# Cost in iteration 0: 0.1127986343712072
# Converged in iteration 67 with cost 0.1125764357111318 because of vanishing difference
# Final cost : 0.1125764357111318
# Compute control for a deterministic system
# Cost in iteration 0: 0.1125764357111318
# Converged in iteration 122 with cost 0.11257634609538231 because of step counter
# Final cost : 0.11257634609538231
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257634609538231
# Converged in iteration 1 with cost 0.11257634609538231 because of step counter
# Final cost : 0.11257634609538231
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257634609538231
# Converged in iteration 1 with cost 0.11257634609538231 because of step counter
# Final cost : 0.11257634609538231
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425773925152386
# Final cost : 0.5459372468270205
# Compute control for a deterministic system
# Cost in iteration 0: 0.5459372468270205
# Cost in iteration 200: 0.08902061028233522
# Final cost : 0.08902061028233522
# Compute control for a deterministic system
# Cost in iteration 0: 0.08902061028233522
# Converged in iteration 130 with cost 0.08897300302261038 because of step counter
# Final cost : 0.08897300302261038
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300302261038
# Converged in iteration 1 with cost 0.08897300302261038 because of step counter
# Final cost : 0.08897300302261038
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300302261038
# Converged in iteration 2 with cost 0.08897300302260767 because of step counter
# Final cost : 0.08897300302260767
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300302260767
# Converged in iteration 1 with cost 0.08897300302260767 because of step counter
# Final cost : 0.08897300302260767
# Compute control for a deterministic system
# Cost in iteration 0: 0.49435436624176343
# Final cost : 0.3109973896063208
# Compute control for a deterministic system
# Cost in iteration 0: 0.3109973896063208
# Cost in iteration 200: 0.06613744574759653
# Final cost : 0.06613744574759653
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613744574759653
# Converged in iteration 27 with cost 0.06613273058983407 because of vanishing difference
# Final cost : 0.06613273058983407
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613273058983407
# Converged in iteration 61 with cost 0.0661327199576543 because of step counter
# Final cost : 0.0661327199576543
# Compute control for a deterministic system
# Cost in iteration 0: 0.0661327199576543
# Converged in iteration 2 with cost 0.06613271995765203 because of step counter
# Final cost : 0.06613271995765203
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613271995765203
# Converged in iteration 1 with cost 0.06613271995765203 because of step counter
# Final cost : 0.06613271995765203
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359997766842216
# Final cost : 0.139766655005219
# Compute control for a deterministic system
# Cost in iteration 0: 0.139766655005219
# Cost in iteration 200: 0.04285642842238577
# Final cost : 0.04285642842238577
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285642842238577
# Converged in iteration 4 with cost 0.042856389905602574 because of vanishing difference
# Final cost : 0.042856389905602574
# Compute control for a deterministic system
# Cost in iteration 0: 0.042856389905602574
# Converged in iteration 17 with cost 0.04285637997980327 because of step counter
# Final cost : 0.04285637997980327
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637997980327
# Converged in iteration 2 with cost 0.04285637997980308 because of step counter
# Final cost : 0.04285637997980308
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637997980308
# Converged in iteration 1 with cost 0.04285637997980308 because of step counter
# Final cost : 0.04285637997980308
# Compute control for a deterministic system
# Cost in iteration 0: 0.058212907945238375
# Final cost : 0.038941596876350085
# Compute control for a deterministic system
# Cost in iteration 0: 0.038941596876350085
# Converged in iteration 109 with cost 0.020431077387620233 because of vanishing difference
# Final cost : 0.020431077387620233
# Compute control for a deterministic system
# Cost in iteration 0: 0.020431077387620233
# Converged in iteration 12 with cost 0.0204310751957723 because of step counter
# Final cost : 0.0204310751957723
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204310751957723
# Converged in iteration 1 with cost 0.0204310751957723 because of step counter
# Final cost : 0.0204310751957723
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204310751957723
# Converged in iteration 1 with cost 0.0204310751957723 because of step counter
# Final cost : 0.0204310751957723
# Compute control for a deterministic system
# Cost in iteration 0: 0.0204310751957723
# Converged in iteration 1 with cost 0.0204310751957723 because of step counter
# Final cost : 0.0204310751957723
# Compute control for a deterministic system
# Cost in iteration 0: 1.183472436512719e-06
# Converged in iteration 1 with cost 1.183472436512719e-06 because of step counter
# Final cost : 1.183472436512719e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183472436512719e-06
# Converged in iteration 1 with cost 1.183472436512719e-06 because of step counter
# Final cost : 1.183472436512719e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09928638119854288
# Cost in iteration 200: 0.042881827500508875
# Final cost : 0.042881827500508875
# Compute control for a deterministic system
# Cost in iteration 0: 0.042881827500508875
# Converged in iteration 33 with cost 0.04288178974266067 because of step counter
# Final cost : 0.04288178974266067
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178974266067
# Converged in iteration 1 with cost 0.04288178974266067 because of step counter
# Final cost : 0.04288178974266067
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178974266067
# Converged in iteration 1 with cost 0.04288178974266067 because of step counter
# Final cost : 0.04288178974266067
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288178974266067
# Converged in iteration 1 with cost 0.04288178974266067 because of step counter
# Final cost : 0.04288178974266067
# Compute control for a deterministic system
# Cost in iteration 0: 0.11431676173400718
# Cost in iteration 200: 0.06541307645822647
# Final cost : 0.06541307645822647
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541307645822647
# Converged in iteration 78 with cost 0.0654115357720247 because of step counter
# Final cost : 0.0654115357720247
# Compute control for a deterministic system
# Cost in iteration 0: 0.0654115357720247
# Converged in iteration 1 with cost 0.0654115357720247 because of step counter
# Final cost : 0.0654115357720247
# Compute control for a deterministic system
# Cost in iteration 0: 0.0654115357720247
# Converged in iteration 6 with cost 0.06541153577201647 because of step counter
# Final cost : 0.06541153577201647
# Compute control for a deterministic system
# Cost in iteration 0: 0.06541153577201647
# Converged in iteration 3 with cost 0.06541153577201443 because of step counter
# Final cost : 0.06541153577201443
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.14630903584498012
# Cost in iteration 200: 0.08867657304163856
# Final cost : 0.08867657304163856
# Compute control for a deterministic system
# Cost in iteration 0: 0.08867657304163856
# Converged in iteration 44 with cost 0.08866467612506393 because of vanishing difference
# Final cost : 0.08866467612506393
# Compute control for a deterministic system
# Cost in iteration 0: 0.08866467612506393
# Converged in iteration 90 with cost 0.08866466702730358 because of step counter
# Final cost : 0.08866466702730358
# Compute control for a deterministic system
# Cost in iteration 0: 0.08866466702730358
# Converged in iteration 1 with cost 0.08866466702730358 because of step counter
# Final cost : 0.08866466702730358
# Compute control for a deterministic system
# Cost in iteration 0: 0.08866466702730358
# Converged in iteration 1 with cost 0.08866466702730358 because of step counter
# Final cost : 0.08866466702730358
# Compute control for a deterministic system
# Cost in iteration 0: 0.15428395459489952
# Cost in iteration 200: 0.11141045073879324
# Final cost : 0.11141045073879324
# Compute control for a deterministic system
# Cost in iteration 0: 0.11141045073879324
# Converged in iteration 54 with cost 0.11137590186422926 because of vanishing difference
# Final cost : 0.11137590186422926
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137590186422926
# Converged in iteration 121 with cost 0.11137584883053332 because of step counter
# Final cost : 0.11137584883053332
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137584883053332
# Converged in iteration 9 with cost 0.11137584883050564 because of step counter
# Final cost : 0.11137584883050564
# Compute control for a deterministic system
# Cost in iteration 0: 0.11137584883050564
# Converged in iteration 1 with cost 0.11137584883050564 because of step counter
# Final cost : 0.11137584883050564
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.22366688833995862
# Cost in iteration 200: 0.1348257584267256
# Final cost : 0.1348257584267256
# Compute control for a deterministic system
# Cost in iteration 0: 0.1348257584267256
# Converged in iteration 83 with cost 0.13473907057144668 because of vanishing difference
# Final cost : 0.13473907057144668
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473907057144668
# Converged in iteration 163 with cost 0.13473902474397914 because of step counter
# Final cost : 0.13473902474397914
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473902474397914
# Converged in iteration 1 with cost 0.13473902474397914 because of step counter
# Final cost : 0.13473902474397914
# Compute control for a deterministic system
# Cost in iteration 0: 0.13473902474397914
# Converged in iteration 1 with cost 0.13473902474397914 because of step counter
# Final cost : 0.13473902474397914
# Compute control for a deterministic system
# Cost in iteration 0: 0.2504644429917802
# Cost in iteration 200: 0.15762248289562503
# Final cost : 0.15762248289562503
# Compute control for a deterministic system
# Cost in iteration 0: 0.15762248289562503
# Cost in iteration 200: 0.1574834939848739
# Final cost : 0.1574834939848739
# Compute control for a deterministic system
# Cost in iteration 0: 0.1574834939848739
# Converged in iteration 109 with cost 0.15748349390392685 because of step counter
# Final cost : 0.15748349390392685
# Compute control for a deterministic system
# Cost in iteration 0: 0.15748349390392685
# Converged in iteration 11 with cost 0.15748349390389543 because of step counter
# Final cost : 0.15748349390389543
# Compute control for a deterministic system
# Cost in iteration 0: 0.15748349390389543
# Converged in iteration 1 with cost 0.15748349390389543 because of step counter
# Final cost : 0.15748349390389543
# -----------------------------------------------
# ...
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.3967447491897437
# Cost in iteration 200: 0.3765135694610909
# Final cost : 0.3765135694610909
# Compute control for a deterministic system
# Cost in iteration 0: 0.3765135694610909
# Converged in iteration 37 with cost 0.3765122376394429 because of vanishing difference
# Final cost : 0.3765122376394429
# Compute control for a deterministic system
# Cost in iteration 0: 0.3765122376394429
# Cost in iteration 200: 0.3765121020539906
# Final cost : 0.3765121020539906
# Compute control for a deterministic system
# Cost in iteration 0: 0.3765121020539906
# Cost in iteration 200: 0.3765121015077049
# Cost in iteration 400: 0.37651210148874237
# Final cost : 0.37651210148874237
# Compute control for a deterministic system
# Cost in iteration 0: 0.37651210148874237
# Converged in iteration 28 with cost 0.3765121014883131 because of step counter
# Final cost : 0.3765121014883131
# Compute control for a deterministic system
# Cost in iteration 0: 0.37675956987090026
# Cost in iteration 200: 0.35222675942837384
# Final cost : 0.35222675942837384
# Compute control for a deterministic system
# Cost in iteration 0: 0.35222675942837384
# Converged in iteration 52 with cost 0.35222514489980167 because of vanishing difference
# Final cost : 0.35222514489980167
# Compute control for a deterministic system
# Cost in iteration 0: 0.35222514489980167
# Cost in iteration 200: 0.3522250594932388
# Final cost : 0.3522250594932388
# Compute control for a deterministic system
# Cost in iteration 0: 0.3522250594932388
# Cost in iteration 200: 0.35222505900175655
# Converged in iteration 374 with cost 0.35222505899063383 because of step counter
# Final cost : 0.35222505899063383
# Compute control for a deterministic system
# Cost in iteration 0: 0.35222505899063383
# Converged in iteration 27 with cost 0.3522250589902108 because of step counter
# Final cost : 0.3522250589902108
# Compute control for a deterministic system
# Cost in iteration 0: 0.3290913904956899
# Cost in iteration 200: 0.32736322865636447
# Final cost : 0.32736322865636447
# Compute control for a deterministic system
# Cost in iteration 0: 0.32736322865636447
# Cost in iteration 200: 0.3273631472933836
# Final cost : 0.3273631472933836
# Compute control for a deterministic system
# Cost in iteration 0: 0.3273631472933836
# Converged in iteration 199 with cost 0.32736314725738974 because of step counter
# Final cost : 0.32736314725738974
# Compute control for a deterministic system
# Cost in iteration 0: 0.32736314725738974
# Converged in iteration 1 with cost 0.32736314725738974 because of step counter
# Final cost : 0.32736314725738974
# Compute control for a deterministic system
# Cost in iteration 0: 0.32736314725738974
# Converged in iteration 1 with cost 0.32736314725738974 because of step counter
# Final cost : 0.32736314725738974
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.30595270176939937
# Cost in iteration 200: 0.3032667505514771
# Final cost : 0.3032667505514771
# Compute control for a deterministic system
# Cost in iteration 0: 0.3032667505514771
# Cost in iteration 200: 0.3032666197020309
# Final cost : 0.3032666197020309
# Compute control for a deterministic system
# Cost in iteration 0: 0.3032666197020309
# Converged in iteration 131 with cost 0.3032666196513628 because of vanishing difference
# Final cost : 0.3032666196513628
# Compute control for a deterministic system
# Cost in iteration 0: 0.3032666196513628
# Converged in iteration 47 with cost 0.30326661965041973 because of step counter
# Final cost : 0.30326661965041973
# Compute control for a deterministic system
# Cost in iteration 0: 0.30326661965041973
# Converged in iteration 49 with cost 0.30326661965000373 because of step counter
# Final cost : 0.30326661965000373
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.2902050577257332
# Cost in iteration 200: 0.27865498747787715
# Final cost : 0.27865498747787715
# Compute control for a deterministic system
# Cost in iteration 0: 0.27865498747787715
# Cost in iteration 200: 0.2786545727135711
# Final cost : 0.2786545727135711
# Compute control for a deterministic system
# Cost in iteration 0: 0.2786545727135711
# Converged in iteration 192 with cost 0.27865457267724575 because of step counter
# Final cost : 0.27865457267724575
# Compute control for a deterministic system
# Cost in iteration 0: 0.27865457267724575
# Converged in iteration 2 with cost 0.2786545726772444 because of step counter
# Final cost : 0.2786545726772444
# Compute control for a deterministic system
# Cost in iteration 0: 0.2786545726772444
# Converged in iteration 18 with cost 0.2786545726771924 because of step counter
# Final cost : 0.2786545726771924
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.25909405343887265
# Cost in iteration 200: 0.25482890342026765
# Final cost : 0.25482890342026765
# Compute control for a deterministic system
# Cost in iteration 0: 0.25482890342026765
# Cost in iteration 200: 0.25482876795543186
# Final cost : 0.25482876795543186
# Compute control for a deterministic system
# Cost in iteration 0: 0.25482876795543186
# Converged in iteration 113 with cost 0.254828767948112 because of step counter
# Final cost : 0.254828767948112
# Compute control for a deterministic system
# Cost in iteration 0: 0.254828767948112
# Converged in iteration 3 with cost 0.2548287679481077 because of step counter
# Final cost : 0.2548287679481077
# Compute control for a deterministic system
# Cost in iteration 0: 0.2548287679481077
# Converged in iteration 1 with cost 0.2548287679481077 because of step counter
# Final cost : 0.2548287679481077
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.23093131350879584
# Cost in iteration 200: 0.23049788007233923
# Final cost : 0.23049788007233923
# Compute control for a deterministic system
# Cost in iteration 0: 0.23049788007233923
# Cost in iteration 200: 0.230497865900327
# Final cost : 0.230497865900327
# Compute control for a deterministic system
# Cost in iteration 0: 0.230497865900327
# Converged in iteration 39 with cost 0.23049786590001292 because of step counter
# Final cost : 0.23049786590001292
# Compute control for a deterministic system
# Cost in iteration 0: 0.23049786590001292
# Converged in iteration 1 with cost 0.23049786590001292 because of step counter
# Final cost : 0.23049786590001292
# Compute control for a deterministic system
# Cost in iteration 0: 0.23049786590001292
# Converged in iteration 1 with cost 0.23049786590001292 because of step counter
# Final cost : 0.23049786590001292
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.20811511578295602
# Cost in iteration 200: 0.20693488039086877
# Final cost : 0.20693488039086877
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693488039086877
# Cost in iteration 200: 0.20693484614317365
# Final cost : 0.20693484614317365
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693484614317365
# Converged in iteration 32 with cost 0.20693484614298477 because of step counter
# Final cost : 0.20693484614298477
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693484614298477
# Converged in iteration 1 with cost 0.20693484614298477 because of step counter
# Final cost : 0.20693484614298477
# Compute control for a deterministic system
# Cost in iteration 0: 0.20693484614298477
# Converged in iteration 1 with cost 0.20693484614298477 because of step counter
# Final cost : 0.20693484614298477
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.1871323287347815
# Cost in iteration 200: 0.18285783499348543
# Final cost : 0.18285783499348543
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285783499348543
# Cost in iteration 200: 0.18285776362107242
# Final cost : 0.18285776362107242
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285776362107242
# Converged in iteration 6 with cost 0.18285776362105838 because of step counter
# Final cost : 0.18285776362105838
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285776362105838
# Converged in iteration 1 with cost 0.18285776362105838 because of step counter
# Final cost : 0.18285776362105838
# Compute control for a deterministic system
# Cost in iteration 0: 0.18285776362105838
# Converged in iteration 6 with cost 0.1828577636210352 because of step counter
# Final cost : 0.1828577636210352
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.16501017560654466
# Cost in iteration 200: 0.15952791295728716
# Final cost : 0.15952791295728716
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952791295728716
# Converged in iteration 161 with cost 0.15952784913990825 because of step counter
# Final cost : 0.15952784913990825
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952784913990825
# Converged in iteration 5 with cost 0.15952784913989543 because of step counter
# Final cost : 0.15952784913989543
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952784913989543
# Converged in iteration 3 with cost 0.15952784913989423 because of step counter
# Final cost : 0.15952784913989423
# Compute control for a deterministic system
# Cost in iteration 0: 0.15952784913989423
# Converged in iteration 1 with cost 0.15952784913989423 because of step counter
# Final cost : 0.15952784913989423
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.13937370294542378
# Cost in iteration 200: 0.13568156779155133
# Final cost : 0.13568156779155133
# Compute control for a deterministic system
# Cost in iteration 0: 0.13568156779155133
# Converged in iteration 142 with cost 0.1356815141392842 because of step counter
# Final cost : 0.1356815141392842
# Compute control for a deterministic system
# Cost in iteration 0: 0.1356815141392842
# Converged in iteration 4 with cost 0.1356815141392595 because of step counter
# Final cost : 0.1356815141392595
# Compute control for a deterministic system
# Cost in iteration 0: 0.1356815141392595
# Converged in iteration 1 with cost 0.1356815141392595 because of step counter
# Final cost : 0.1356815141392595
# Compute control for a deterministic system
# Cost in iteration 0: 0.1356815141392595
# Converged in iteration 1 with cost 0.1356815141392595 because of step counter
# Final cost : 0.1356815141392595
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.11515460936227356
# Cost in iteration 200: 0.11257636053747776
# Final cost : 0.11257636053747776
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257636053747776
# Converged in iteration 104 with cost 0.11257633908368608 because of step counter
# Final cost : 0.11257633908368608
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257633908368608
# Converged in iteration 1 with cost 0.11257633908368608 because of step counter
# Final cost : 0.11257633908368608
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257633908368608
# Converged in iteration 1 with cost 0.11257633908368608 because of step counter
# Final cost : 0.11257633908368608
# Compute control for a deterministic system
# Cost in iteration 0: 0.11257633908368608
# Converged in iteration 1 with cost 0.11257633908368608 because of step counter
# Final cost : 0.11257633908368608
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0896809878201581
# Cost in iteration 200: 0.08897300376314334
# Final cost : 0.08897300376314334
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300376314334
# Converged in iteration 61 with cost 0.0889730015995509 because of step counter
# Final cost : 0.0889730015995509
# Compute control for a deterministic system
# Cost in iteration 0: 0.0889730015995509
# Converged in iteration 4 with cost 0.08897300159953513 because of step counter
# Final cost : 0.08897300159953513
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300159953513
# Converged in iteration 1 with cost 0.08897300159953513 because of step counter
# Final cost : 0.08897300159953513
# Compute control for a deterministic system
# Cost in iteration 0: 0.08897300159953513
# Converged in iteration 1 with cost 0.08897300159953513 because of step counter
# Final cost : 0.08897300159953513
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.06651080504516696
# Cost in iteration 200: 0.06613271394793384
# Final cost : 0.06613271394793384
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613271394793384
# Converged in iteration 34 with cost 0.06613271377599739 because of step counter
# Final cost : 0.06613271377599739
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613271377599739
# Converged in iteration 7 with cost 0.0661327137759858 because of step counter
# Final cost : 0.0661327137759858
# Compute control for a deterministic system
# Cost in iteration 0: 0.0661327137759858
# Converged in iteration 2 with cost 0.06613271377598295 because of step counter
# Final cost : 0.06613271377598295
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613271377598295
# Converged in iteration 1 with cost 0.06613271377598295 because of step counter
# Final cost : 0.06613271377598295
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285697190428176
# Converged in iteration 152 with cost 0.04285637107411603 because of step counter
# Final cost : 0.04285637107411603
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637107411603
# Converged in iteration 14 with cost 0.04285637107398455 because of step counter
# Final cost : 0.04285637107398455
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637107398455
# Converged in iteration 1 with cost 0.04285637107398455 because of step counter
# Final cost : 0.04285637107398455
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637107398455
# Converged in iteration 1 with cost 0.04285637107398455 because of step counter
# Final cost : 0.04285637107398455
# Compute control for a deterministic system
# Cost in iteration 0: 0.04285637107398455
# Converged in iteration 1 with cost 0.04285637107398455 because of step counter
# Final cost : 0.04285637107398455
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.02050726827455001
# Converged in iteration 134 with cost 0.02043107477577957 because of step counter
# Final cost : 0.02043107477577957
# Compute control for a deterministic system
# Cost in iteration 0: 0.02043107477577957
# Converged in iteration 2 with cost 0.020431074775758614 because of step counter
# Final cost : 0.020431074775758614
# Compute control for a deterministic system
# Cost in iteration 0: 0.020431074775758614
# Converged in iteration 1 with cost 0.020431074775758614 because of step counter
# Final cost : 0.020431074775758614
# Compute control for a deterministic system
# Cost in iteration 0: 0.020431074775758614
# Converged in iteration 1 with cost 0.020431074775758614 because of step counter
# Final cost : 0.020431074775758614
# Compute control for a deterministic system
# Cost in iteration 0: 0.020431074775758614
# Converged in iteration 4 with cost 0.020431074775754534 because of step counter
# Final cost : 0.020431074775754534
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
