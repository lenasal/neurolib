# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,413], wc.inh[0,413]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.453333333333333
# minima =  [ 1551  3392  5237  7082  8928 10773 12618 14464 16309 18155 20000 21845
#  23691 25536 27381 29227 31072 32917 34763 36608 38453 40299 42144 43989
#  45835 47680 49525]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s2_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s2_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [False, False, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.012721090530955229
# Converged in iteration 60 with cost 0.012143940276540853 because of vanishing difference
# Final cost : 0.012143940276540853
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143940276540853
# Converged in iteration 8 with cost 0.012143939236350732 because of step counter
# Final cost : 0.012143939236350732
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143939236350732
# Converged in iteration 5 with cost 0.012143939236349946 because of step counter
# Final cost : 0.012143939236349946
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143939236349946
# Converged in iteration 1 with cost 0.012143939236349946 because of step counter
# Final cost : 0.012143939236349946
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143939236349946
# Converged in iteration 1 with cost 0.012143939236349946 because of step counter
# Final cost : 0.012143939236349946
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.02691997867404452
# Converged in iteration 131 with cost 0.02587220777382719 because of vanishing difference
# Final cost : 0.02587220777382719
# Compute control for a deterministic system
# Cost in iteration 0: 0.02587220777382719
# Converged in iteration 24 with cost 0.025872203999632915 because of step counter
# Final cost : 0.025872203999632915
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203999632915
# Converged in iteration 2 with cost 0.025872203999632665 because of step counter
# Final cost : 0.025872203999632665
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203999632665
# Converged in iteration 1 with cost 0.025872203999632665 because of step counter
# Final cost : 0.025872203999632665
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203999632665
# Converged in iteration 1 with cost 0.025872203999632665 because of step counter
# Final cost : 0.025872203999632665
# Compute control for a deterministic system
# Cost in iteration 0: 0.043138202261852
# Cost in iteration 200: 0.03967189766908983
# Final cost : 0.03967189766908983
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967189766908983
# Converged in iteration 55 with cost 0.039671891549620336 because of step counter
# Final cost : 0.039671891549620336
# Compute control for a deterministic system
# Cost in iteration 0: 0.039671891549620336
# Converged in iteration 1 with cost 0.039671891549620336 because of step counter
# Final cost : 0.039671891549620336
# Compute control for a deterministic system
# Cost in iteration 0: 0.039671891549620336
# Converged in iteration 1 with cost 0.039671891549620336 because of step counter
# Final cost : 0.039671891549620336
# Compute control for a deterministic system
# Cost in iteration 0: 0.039671891549620336
# Converged in iteration 1 with cost 0.039671891549620336 because of step counter
# Final cost : 0.039671891549620336
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.05597415665443965
# Cost in iteration 200: 0.05381974488731433
# Final cost : 0.05381974488731433
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381974488731433
# Converged in iteration 97 with cost 0.053819608371170634 because of step counter
# Final cost : 0.053819608371170634
# Compute control for a deterministic system
# Cost in iteration 0: 0.053819608371170634
# Converged in iteration 2 with cost 0.05381960837116921 because of step counter
# Final cost : 0.05381960837116921
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381960837116921
# Converged in iteration 2 with cost 0.05381960837116848 because of step counter
# Final cost : 0.05381960837116848
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381960837116848
# Converged in iteration 2 with cost 0.05381960837116804 because of step counter
# Final cost : 0.05381960837116804
# Compute control for a deterministic system
# Cost in iteration 0: 0.07530125689182371
# Cost in iteration 200: 0.0676973363818032
# Final cost : 0.0676973363818032
# Compute control for a deterministic system
# Cost in iteration 0: 0.0676973363818032
# Converged in iteration 19 with cost 0.06769654872287978 because of vanishing difference
# Final cost : 0.06769654872287978
# Compute control for a deterministic system
# Cost in iteration 0: 0.06769654872287978
# Converged in iteration 88 with cost 0.06769652998756907 because of step counter
# Final cost : 0.06769652998756907
# Compute control for a deterministic system
# Cost in iteration 0: 0.06769652998756907
# Converged in iteration 2 with cost 0.06769652998756893 because of step counter
# Final cost : 0.06769652998756893
# Compute control for a deterministic system
# Cost in iteration 0: 0.06769652998756893
# Converged in iteration 2 with cost 0.06769652998756757 because of step counter
# Final cost : 0.06769652998756757
# Compute control for a deterministic system
# Cost in iteration 0: 0.08328239346962209
# Cost in iteration 200: 0.08159263321301702
# Final cost : 0.08159263321301702
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159263321301702
# Cost in iteration 200: 0.08159021188059487
# Final cost : 0.08159021188059487
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021188059487
# Converged in iteration 4 with cost 0.08159021188058166 because of step counter
# Final cost : 0.08159021188058166
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021188058166
# Converged in iteration 1 with cost 0.08159021188058166 because of step counter
# Final cost : 0.08159021188058166
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021188058166
# Converged in iteration 1 with cost 0.08159021188058166 because of step counter
# Final cost : 0.08159021188058166
# Compute control for a deterministic system
# Cost in iteration 0: 0.10014637970791156
# Cost in iteration 200: 0.09549587554210111
# Final cost : 0.09549587554210111
# Compute control for a deterministic system
# Cost in iteration 0: 0.09549587554210111
# Converged in iteration 83 with cost 0.09549032906665435 because of vanishing difference
# Final cost : 0.09549032906665435
# Compute control for a deterministic system
# Cost in iteration 0: 0.09549032906665435
# Converged in iteration 128 with cost 0.0954903267293916 because of step counter
# Final cost : 0.0954903267293916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954903267293916
# Converged in iteration 1 with cost 0.0954903267293916 because of step counter
# Final cost : 0.0954903267293916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954903267293916
# Converged in iteration 1 with cost 0.0954903267293916 because of step counter
# Final cost : 0.0954903267293916
# Compute control for a deterministic system
# Cost in iteration 0: 0.11106941913043678
# Cost in iteration 200: 0.10939824598138001
# Final cost : 0.10939824598138001
# Compute control for a deterministic system
# Cost in iteration 0: 0.10939824598138001
# Cost in iteration 200: 0.10938890316540219
# Final cost : 0.10938890316540219
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890316540219
# Converged in iteration 96 with cost 0.10938890314151015 because of step counter
# Final cost : 0.10938890314151015
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890314151015
# Converged in iteration 1 with cost 0.10938890314151015 because of step counter
# Final cost : 0.10938890314151015
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890314151015
# Converged in iteration 20 with cost 0.10938890314149002 because of step counter
# Final cost : 0.10938890314149002
# Compute control for a deterministic system
# Cost in iteration 0: 0.12592353932263461
# Cost in iteration 200: 0.12329212006910764
# Final cost : 0.12329212006910764
# Compute control for a deterministic system
# Cost in iteration 0: 0.12329212006910764
# Cost in iteration 200: 0.12327963329643277
# Final cost : 0.12327963329643277
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327963329643277
# Converged in iteration 162 with cost 0.12327961991318279 because of step counter
# Final cost : 0.12327961991318279
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327961991318279
# Converged in iteration 1 with cost 0.12327961991318279 because of step counter
# Final cost : 0.12327961991318279
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327961991318279
# Converged in iteration 1 with cost 0.12327961991318279 because of step counter
# Final cost : 0.12327961991318279
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.14475623046207303
# Cost in iteration 200: 0.13717386068646478
# Final cost : 0.13717386068646478
# Compute control for a deterministic system
# Cost in iteration 0: 0.13717386068646478
# Converged in iteration 79 with cost 0.13715721169852899 because of vanishing difference
# Final cost : 0.13715721169852899
# Compute control for a deterministic system
# Cost in iteration 0: 0.13715721169852899
# Cost in iteration 200: 0.13715713767996085
# Final cost : 0.13715713767996085
# Compute control for a deterministic system
# Cost in iteration 0: 0.13715713767996085
# Converged in iteration 114 with cost 0.13715713767810397 because of step counter
# Final cost : 0.13715713767810397
# Compute control for a deterministic system
# Cost in iteration 0: 0.13715713767810397
# Converged in iteration 1 with cost 0.13715713767810397 because of step counter
# Final cost : 0.13715713767810397
# Compute control for a deterministic system
# Cost in iteration 0: 0.15373475653652677
# Cost in iteration 200: 0.15103728136910144
# Final cost : 0.15103728136910144
# Compute control for a deterministic system
# Cost in iteration 0: 0.15103728136910144
# Converged in iteration 84 with cost 0.1510166860420106 because of vanishing difference
# Final cost : 0.1510166860420106
# Compute control for a deterministic system
# Cost in iteration 0: 0.1510166860420106
# Cost in iteration 200: 0.15101661788354864
# Final cost : 0.15101661788354864
# Compute control for a deterministic system
# Cost in iteration 0: 0.15101661788354864
# Cost in iteration 200: 0.1510166178695064
# Converged in iteration 209 with cost 0.15101661786947168 because of step counter
# Final cost : 0.15101661786947168
# Compute control for a deterministic system
# Cost in iteration 0: 0.15101661786947168
# Converged in iteration 1 with cost 0.15101661786947168 because of step counter
# Final cost : 0.15101661786947168
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.17012294863101787
# Cost in iteration 200: 0.1651761563946113
# Final cost : 0.1651761563946113
# Compute control for a deterministic system
# Cost in iteration 0: 0.1651761563946113
# Converged in iteration 42 with cost 0.16515627585921078 because of vanishing difference
# Final cost : 0.16515627585921078
# Compute control for a deterministic system
# Cost in iteration 0: 0.16515627585921078
# Cost in iteration 200: 0.16515369997562918
# Final cost : 0.16515369997562918
# Compute control for a deterministic system
# Cost in iteration 0: 0.16515369997562918
# Cost in iteration 200: 0.16515369986041506
# Converged in iteration 316 with cost 0.16515369985944356 because of step counter
# Final cost : 0.16515369985944356
# Compute control for a deterministic system
# Cost in iteration 0: 0.16515369985944356
# Converged in iteration 1 with cost 0.16515369985944356 because of step counter
# Final cost : 0.16515369985944356
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.1799729403854856
# Cost in iteration 200: 0.17897976542842556
# Final cost : 0.17897976542842556
# Compute control for a deterministic system
# Cost in iteration 0: 0.17897976542842556
# Converged in iteration 57 with cost 0.17896156724347964 because of vanishing difference
# Final cost : 0.17896156724347964
# Compute control for a deterministic system
# Cost in iteration 0: 0.17896156724347964
# Cost in iteration 200: 0.17896101539444373
# Final cost : 0.17896101539444373
# Compute control for a deterministic system
# Cost in iteration 0: 0.17896101539444373
# Cost in iteration 200: 0.17896101520868088
# Converged in iteration 367 with cost 0.17896101520506538 because of step counter
# Final cost : 0.17896101520506538
# Compute control for a deterministic system
# Cost in iteration 0: 0.17896101520506538
# Converged in iteration 11 with cost 0.17896101520495217 because of step counter
# Final cost : 0.17896101520495217
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.21207263164384632
# Cost in iteration 200: 0.19274604287706879
# Final cost : 0.19274604287706879
# Compute control for a deterministic system
# Cost in iteration 0: 0.19274604287706879
# Converged in iteration 52 with cost 0.19273214249583603 because of vanishing difference
# Final cost : 0.19273214249583603
# Compute control for a deterministic system
# Cost in iteration 0: 0.19273214249583603
# Cost in iteration 200: 0.1927313913625392
# Final cost : 0.1927313913625392
# Compute control for a deterministic system
# Cost in iteration 0: 0.1927313913625392
# Cost in iteration 200: 0.19273139134649966
# Converged in iteration 334 with cost 0.1927313913459844 because of step counter
# Final cost : 0.1927313913459844
# Compute control for a deterministic system
# Cost in iteration 0: 0.1927313913459844
# Converged in iteration 1 with cost 0.1927313913459844 because of step counter
# Final cost : 0.1927313913459844
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.20966042906693563
# Cost in iteration 200: 0.2064643866461254
# Final cost : 0.2064643866461254
# Compute control for a deterministic system
# Cost in iteration 0: 0.2064643866461254
# Converged in iteration 65 with cost 0.20645011760272222 because of vanishing difference
# Final cost : 0.20645011760272222
# Compute control for a deterministic system
# Cost in iteration 0: 0.20645011760272222
# Cost in iteration 200: 0.20644982787777058
# Final cost : 0.20644982787777058
# Compute control for a deterministic system
# Cost in iteration 0: 0.20644982787777058
# Cost in iteration 200: 0.20644982739439022
# Cost in iteration 400: 0.2064498273672031
# Final cost : 0.2064498273672031
# Compute control for a deterministic system
# Cost in iteration 0: 0.2064498273672031
# Converged in iteration 104 with cost 0.20644982736555464 because of step counter
# Final cost : 0.20644982736555464
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.22516755560888038
# Cost in iteration 200: 0.220097212171598
# Final cost : 0.220097212171598
# Compute control for a deterministic system
# Cost in iteration 0: 0.220097212171598
# Converged in iteration 69 with cost 0.22008375709331046 because of vanishing difference
# Final cost : 0.22008375709331046
# Compute control for a deterministic system
# Cost in iteration 0: 0.22008375709331046
# Cost in iteration 200: 0.2200835435093275
# Final cost : 0.2200835435093275
# Compute control for a deterministic system
# Cost in iteration 0: 0.2200835435093275
# Cost in iteration 200: 0.220083542863606
# Cost in iteration 400: 0.22008354280871403
# Final cost : 0.22008354280871403
# Compute control for a deterministic system
# Cost in iteration 0: 0.22008354280871403
# Converged in iteration 96 with cost 0.22008354280354434 because of step counter
# Final cost : 0.22008354280354434
# Compute control for a deterministic system
# Cost in iteration 0: 0.23941264889342093
# Cost in iteration 200: 0.2335746687031026
# Final cost : 0.2335746687031026
# Compute control for a deterministic system
# Cost in iteration 0: 0.2335746687031026
# Converged in iteration 102 with cost 0.23355916567155355 because of vanishing difference
# Final cost : 0.23355916567155355
# Compute control for a deterministic system
# Cost in iteration 0: 0.23355916567155355
# Cost in iteration 200: 0.23355910185403816
# Final cost : 0.23355910185403816
# Compute control for a deterministic system
# Cost in iteration 0: 0.23355910185403816
# Cost in iteration 200: 0.23355910123246112
# Cost in iteration 400: 0.23355910115967507
# Final cost : 0.23355910115967507
# Compute control for a deterministic system
# Cost in iteration 0: 0.23355910115967507
# Converged in iteration 158 with cost 0.2335591011498857 because of step counter
# Final cost : 0.2335591011498857
# Compute control for a deterministic system
# Cost in iteration 0: 0.27563048832777837
# Cost in iteration 200: 0.2467660490077165
# Final cost : 0.2467660490077165
# Compute control for a deterministic system
# Cost in iteration 0: 0.2467660490077165
# Cost in iteration 200: 0.24675007892809991
# Final cost : 0.24675007892809991
# Compute control for a deterministic system
# Cost in iteration 0: 0.24675007892809991
# Cost in iteration 200: 0.24675007781728728
# Final cost : 0.24675007781728728
# Compute control for a deterministic system
# Cost in iteration 0: 0.24675007781728728
# Cost in iteration 200: 0.24675007781207034
# Converged in iteration 333 with cost 0.24675007781130337 because of step counter
# Final cost : 0.24675007781130337
# Compute control for a deterministic system
# Cost in iteration 0: 0.24675007781130337
# Converged in iteration 1 with cost 0.24675007781130337 because of step counter
# Final cost : 0.24675007781130337
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.30254232994149916
# Cost in iteration 200: 0.25984664560104537
# Final cost : 0.25984664560104537
# Compute control for a deterministic system
# Cost in iteration 0: 0.25984664560104537
# Converged in iteration 136 with cost 0.25982827516415596 because of vanishing difference
# Final cost : 0.25982827516415596
# Compute control for a deterministic system
# Cost in iteration 0: 0.25982827516415596
# Cost in iteration 200: 0.2598282395921144
# Final cost : 0.2598282395921144
# Compute control for a deterministic system
# Cost in iteration 0: 0.2598282395921144
# Cost in iteration 200: 0.25982823946679334
# Cost in iteration 400: 0.2598282394430138
# Final cost : 0.2598282394430138
# Compute control for a deterministic system
# Cost in iteration 0: 0.2598282394430138
# Cost in iteration 200: 0.2598282394386854
# Converged in iteration 288 with cost 0.2598282394372956 because of step counter
# Final cost : 0.2598282394372956
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.2775511448936186
# Cost in iteration 200: 0.2723228193040848
# Final cost : 0.2723228193040848
# Compute control for a deterministic system
# Cost in iteration 0: 0.2723228193040848
# Converged in iteration 54 with cost 0.2722955614852911 because of vanishing difference
# Final cost : 0.2722955614852911
# Compute control for a deterministic system
# Cost in iteration 0: 0.2722955614852911
# Cost in iteration 200: 0.2722935381827453
# Final cost : 0.2722935381827453
# Compute control for a deterministic system
# Cost in iteration 0: 0.2722935381827453
# Cost in iteration 200: 0.27229353637874903
# Cost in iteration 400: 0.27229353603595263
# Final cost : 0.27229353603595263
# Compute control for a deterministic system
# Cost in iteration 0: 0.27229353603595263
# Cost in iteration 200: 0.27229353596221445
# Cost in iteration 400: 0.27229353594219585
# Cost in iteration 600: 0.27229353593673833
# Converged in iteration 773 with cost 0.2722935359337941 because of step counter
# Final cost : 0.2722935359337941
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.2810474602459311
# Cost in iteration 200: 0.27485027718398836
# Final cost : 0.27485027718398836
# Compute control for a deterministic system
# Cost in iteration 0: 0.27485027718398836
# Converged in iteration 125 with cost 0.27479994995024304 because of vanishing difference
# Final cost : 0.27479994995024304
# Compute control for a deterministic system
# Cost in iteration 0: 0.27479994995024304
# Cost in iteration 200: 0.2747997543760434
# Final cost : 0.2747997543760434
# Compute control for a deterministic system
# Cost in iteration 0: 0.2747997543760434
# Cost in iteration 200: 0.27479975186798333
# Cost in iteration 400: 0.274799751475906
# Final cost : 0.274799751475906
# Compute control for a deterministic system
# Cost in iteration 0: 0.274799751475906
# Cost in iteration 200: 0.2747997514144555
# Cost in iteration 400: 0.2747997514025495
# Cost in iteration 600: 0.27479975140023977
# Converged in iteration 647 with cost 0.27479975139968243 because of step counter
# Final cost : 0.27479975139968243
# Compute control for a deterministic system
# Cost in iteration 0: 0.30599760716380053
# Cost in iteration 200: 0.2594868330979726
# Final cost : 0.2594868330979726
# Compute control for a deterministic system
# Cost in iteration 0: 0.2594868330979726
# Converged in iteration 138 with cost 0.25944709664073207 because of vanishing difference
# Final cost : 0.25944709664073207
# Compute control for a deterministic system
# Cost in iteration 0: 0.25944709664073207
# Cost in iteration 200: 0.25944704277060004
# Final cost : 0.25944704277060004
# Compute control for a deterministic system
# Cost in iteration 0: 0.25944704277060004
# Cost in iteration 200: 0.2594470427623265
# Converged in iteration 321 with cost 0.25944704276152175 because of step counter
# Final cost : 0.25944704276152175
# Compute control for a deterministic system
# Cost in iteration 0: 0.25944704276152175
# Converged in iteration 40 with cost 0.25944704276127095 because of vanishing difference
# Final cost : 0.25944704276127095
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.2509569578009731
# Cost in iteration 200: 0.24423324529985746
# Final cost : 0.24423324529985746
# Compute control for a deterministic system
# Cost in iteration 0: 0.24423324529985746
# Converged in iteration 105 with cost 0.24418840957086702 because of vanishing difference
# Final cost : 0.24418840957086702
# Compute control for a deterministic system
# Cost in iteration 0: 0.24418840957086702
# Cost in iteration 200: 0.2441881783771705
# Final cost : 0.2441881783771705
# Compute control for a deterministic system
# Cost in iteration 0: 0.2441881783771705
# Cost in iteration 200: 0.24418817752585367
# Cost in iteration 400: 0.24418817745167182
# Final cost : 0.24418817745167182
# Compute control for a deterministic system
# Cost in iteration 0: 0.24418817745167182
# Cost in iteration 200: 0.24418817744519722
# Converged in iteration 287 with cost 0.24418817744471372 because of vanishing difference
# Final cost : 0.24418817744471372
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.24032098682491193
# Cost in iteration 200: 0.22901777750748625
# Final cost : 0.22901777750748625
# Compute control for a deterministic system
# Cost in iteration 0: 0.22901777750748625
# Converged in iteration 56 with cost 0.2289753935826587 because of vanishing difference
# Final cost : 0.2289753935826587
# Compute control for a deterministic system
# Cost in iteration 0: 0.2289753935826587
# Cost in iteration 200: 0.2289734207533612
# Final cost : 0.2289734207533612
# Compute control for a deterministic system
# Cost in iteration 0: 0.2289734207533612
# Cost in iteration 200: 0.22897341963018425
# Cost in iteration 400: 0.2289734195652687
# Final cost : 0.2289734195652687
# Compute control for a deterministic system
# Cost in iteration 0: 0.2289734195652687
# Cost in iteration 200: 0.2289734195614214
# Converged in iteration 223 with cost 0.22897341956112346 because of step counter
# Final cost : 0.22897341956112346
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.2467677552449159
# Cost in iteration 200: 0.2138634447903201
# Final cost : 0.2138634447903201
# Compute control for a deterministic system
# Cost in iteration 0: 0.2138634447903201
# Converged in iteration 78 with cost 0.21382350443815074 because of vanishing difference
# Final cost : 0.21382350443815074
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382350443815074
# Cost in iteration 200: 0.21382314970877503
# Final cost : 0.21382314970877503
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314970877503
# Cost in iteration 200: 0.21382314955884713
# Converged in iteration 384 with cost 0.21382314955335563 because of vanishing difference
# Final cost : 0.21382314955335563
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314955335563
# Converged in iteration 67 with cost 0.21382314955307535 because of step counter
# Final cost : 0.21382314955307535
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.2136762975727855
# Cost in iteration 200: 0.1988249047719689
# Final cost : 0.1988249047719689
# Compute control for a deterministic system
# Cost in iteration 0: 0.1988249047719689
# Converged in iteration 74 with cost 0.19878435298199196 because of vanishing difference
# Final cost : 0.19878435298199196
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878435298199196
# Cost in iteration 200: 0.19878395437799748
# Final cost : 0.19878395437799748
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878395437799748
# Cost in iteration 200: 0.19878395418061567
# Converged in iteration 289 with cost 0.19878395417767478 because of vanishing difference
# Final cost : 0.19878395417767478
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878395417767478
# Converged in iteration 79 with cost 0.19878395417721 because of step counter
# Final cost : 0.19878395417721
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.20659680036048284
# Cost in iteration 200: 0.1835961537503393
# Final cost : 0.1835961537503393
# Compute control for a deterministic system
# Cost in iteration 0: 0.1835961537503393
# Cost in iteration 200: 0.1835607025781785
# Final cost : 0.1835607025781785
# Compute control for a deterministic system
# Cost in iteration 0: 0.1835607025781785
# Cost in iteration 200: 0.18356069929954527
# Final cost : 0.18356069929954527
# Compute control for a deterministic system
# Cost in iteration 0: 0.18356069929954527
# Converged in iteration 110 with cost 0.1835606992980112 because of vanishing difference
# Final cost : 0.1835606992980112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1835606992980112
# Converged in iteration 20 with cost 0.18356069929793287 because of step counter
# Final cost : 0.18356069929793287
# Compute control for a deterministic system
# Cost in iteration 0: 0.1708082398704813
# Cost in iteration 200: 0.1688382066254754
# Final cost : 0.1688382066254754
# Compute control for a deterministic system
# Cost in iteration 0: 0.1688382066254754
# Cost in iteration 200: 0.16880372825919232
# Final cost : 0.16880372825919232
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372825919232
# Cost in iteration 200: 0.16880372488981016
# Final cost : 0.16880372488981016
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372488981016
# Converged in iteration 68 with cost 0.16880372488944145 because of vanishing difference
# Final cost : 0.16880372488944145
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372488944145
# Converged in iteration 17 with cost 0.16880372488939238 because of step counter
# Final cost : 0.16880372488939238
# Compute control for a deterministic system
# Cost in iteration 0: 0.15737069968926756
# Cost in iteration 200: 0.1542050306871187
# Final cost : 0.1542050306871187
# Compute control for a deterministic system
# Cost in iteration 0: 0.1542050306871187
# Cost in iteration 200: 0.1541756117365039
# Final cost : 0.1541756117365039
# Compute control for a deterministic system
# Cost in iteration 0: 0.1541756117365039
# Converged in iteration 198 with cost 0.1541756103529112 because of step counter
# Final cost : 0.1541756103529112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1541756103529112
# Converged in iteration 1 with cost 0.1541756103529112 because of step counter
# Final cost : 0.1541756103529112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1541756103529112
# Converged in iteration 1 with cost 0.1541756103529112 because of step counter
# Final cost : 0.1541756103529112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1423292720182717
# Cost in iteration 200: 0.13967961735106865
# Final cost : 0.13967961735106865
# Compute control for a deterministic system
# Cost in iteration 0: 0.13967961735106865
# Cost in iteration 200: 0.139659260475183
# Final cost : 0.139659260475183
# Compute control for a deterministic system
# Cost in iteration 0: 0.139659260475183
# Converged in iteration 134 with cost 0.13965926015177854 because of step counter
# Final cost : 0.13965926015177854
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965926015177854
# Converged in iteration 1 with cost 0.13965926015177854 because of step counter
# Final cost : 0.13965926015177854
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965926015177854
# Converged in iteration 1 with cost 0.13965926015177854 because of step counter
# Final cost : 0.13965926015177854
# Compute control for a deterministic system
# Cost in iteration 0: 0.12718749972046106
# Cost in iteration 200: 0.1252528024070793
# Final cost : 0.1252528024070793
# Compute control for a deterministic system
# Cost in iteration 0: 0.1252528024070793
# Cost in iteration 200: 0.1252378887141002
# Final cost : 0.1252378887141002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1252378887141002
# Converged in iteration 82 with cost 0.1252378886536677 because of step counter
# Final cost : 0.1252378886536677
# Compute control for a deterministic system
# Cost in iteration 0: 0.1252378886536677
# Converged in iteration 10 with cost 0.12523788865365115 because of step counter
# Final cost : 0.12523788865365115
# Compute control for a deterministic system
# Cost in iteration 0: 0.12523788865365115
# Converged in iteration 3 with cost 0.12523788865364985 because of step counter
# Final cost : 0.12523788865364985
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013360584190029
# Cost in iteration 200: 0.11090681935852206
# Final cost : 0.11090681935852206
# Compute control for a deterministic system
# Cost in iteration 0: 0.11090681935852206
# Cost in iteration 200: 0.11089764500301078
# Final cost : 0.11089764500301078
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764500301078
# Converged in iteration 53 with cost 0.11089764499830602 because of vanishing difference
# Final cost : 0.11089764499830602
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764499830602
# Converged in iteration 1 with cost 0.11089764499830602 because of step counter
# Final cost : 0.11089764499830602
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764499830602
# Converged in iteration 2 with cost 0.11089764499830425 because of step counter
# Final cost : 0.11089764499830425
# Compute control for a deterministic system
# Cost in iteration 0: 0.10514025005605726
# Cost in iteration 200: 0.09663370403716019
# Final cost : 0.09663370403716019
# Compute control for a deterministic system
# Cost in iteration 0: 0.09663370403716019
# Converged in iteration 31 with cost 0.09662869482904228 because of vanishing difference
# Final cost : 0.09662869482904228
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662869482904228
# Converged in iteration 96 with cost 0.09662861281404342 because of step counter
# Final cost : 0.09662861281404342
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662861281404342
# Converged in iteration 2 with cost 0.09662861281404268 because of step counter
# Final cost : 0.09662861281404268
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662861281404268
# Converged in iteration 1 with cost 0.09662861281404268 because of step counter
# Final cost : 0.09662861281404268
# Compute control for a deterministic system
# Cost in iteration 0: 0.08528128125986197
# Cost in iteration 200: 0.08211911956982364
# Final cost : 0.08211911956982364
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211911956982364
# Converged in iteration 177 with cost 0.08211700711984188 because of step counter
# Final cost : 0.08211700711984188
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700711984188
# Converged in iteration 1 with cost 0.08211700711984188 because of step counter
# Final cost : 0.08211700711984188
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700711984188
# Converged in iteration 1 with cost 0.08211700711984188 because of step counter
# Final cost : 0.08211700711984188
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700711984188
# Converged in iteration 1 with cost 0.08211700711984188 because of step counter
# Final cost : 0.08211700711984188
# Compute control for a deterministic system
# Cost in iteration 0: 0.07039208503266921
# Cost in iteration 200: 0.06797962558015051
# Final cost : 0.06797962558015051
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797962558015051
# Converged in iteration 22 with cost 0.06797894586684636 because of vanishing difference
# Final cost : 0.06797894586684636
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797894586684636
# Converged in iteration 49 with cost 0.06797894103618443 because of step counter
# Final cost : 0.06797894103618443
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797894103618443
# Converged in iteration 3 with cost 0.06797894103618253 because of step counter
# Final cost : 0.06797894103618253
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797894103618253
# Converged in iteration 1 with cost 0.06797894103618253 because of step counter
# Final cost : 0.06797894103618253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0583901290227563
# Cost in iteration 200: 0.05390832345392249
# Final cost : 0.05390832345392249
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390832345392249
# Converged in iteration 8 with cost 0.05390822712429398 because of vanishing difference
# Final cost : 0.05390822712429398
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390822712429398
# Converged in iteration 29 with cost 0.053908221293794426 because of step counter
# Final cost : 0.053908221293794426
# Compute control for a deterministic system
# Cost in iteration 0: 0.053908221293794426
# Converged in iteration 1 with cost 0.053908221293794426 because of step counter
# Final cost : 0.053908221293794426
# Compute control for a deterministic system
# Cost in iteration 0: 0.053908221293794426
# Converged in iteration 1 with cost 0.053908221293794426 because of step counter
# Final cost : 0.053908221293794426
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.042405004157362945
# Cost in iteration 200: 0.03991369231159176
# Final cost : 0.03991369231159176
# Compute control for a deterministic system
# Cost in iteration 0: 0.03991369231159176
# Converged in iteration 53 with cost 0.039913686408824915 because of step counter
# Final cost : 0.039913686408824915
# Compute control for a deterministic system
# Cost in iteration 0: 0.039913686408824915
# Converged in iteration 1 with cost 0.039913686408824915 because of step counter
# Final cost : 0.039913686408824915
# Compute control for a deterministic system
# Cost in iteration 0: 0.039913686408824915
# Converged in iteration 1 with cost 0.039913686408824915 because of step counter
# Final cost : 0.039913686408824915
# Compute control for a deterministic system
# Cost in iteration 0: 0.039913686408824915
# Converged in iteration 1 with cost 0.039913686408824915 because of step counter
# Final cost : 0.039913686408824915
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.02689721715523352
# Converged in iteration 132 with cost 0.026012254975744102 because of vanishing difference
# Final cost : 0.026012254975744102
# Compute control for a deterministic system
# Cost in iteration 0: 0.026012254975744102
# Converged in iteration 31 with cost 0.026012251689099056 because of step counter
# Final cost : 0.026012251689099056
# Compute control for a deterministic system
# Cost in iteration 0: 0.026012251689099056
# Converged in iteration 2 with cost 0.02601225168909898 because of step counter
# Final cost : 0.02601225168909898
# Compute control for a deterministic system
# Cost in iteration 0: 0.02601225168909898
# Converged in iteration 1 with cost 0.02601225168909898 because of step counter
# Final cost : 0.02601225168909898
# Compute control for a deterministic system
# Cost in iteration 0: 0.02601225168909898
# Converged in iteration 1 with cost 0.02601225168909898 because of step counter
# Final cost : 0.02601225168909898
# Compute control for a deterministic system
# Cost in iteration 0: 0.012657752778241495
# Converged in iteration 62 with cost 0.012235180980309132 because of vanishing difference
# Final cost : 0.012235180980309132
# Compute control for a deterministic system
# Cost in iteration 0: 0.012235180980309132
# Converged in iteration 9 with cost 0.01223518014830004 because of step counter
# Final cost : 0.01223518014830004
# Compute control for a deterministic system
# Cost in iteration 0: 0.01223518014830004
# Converged in iteration 1 with cost 0.01223518014830004 because of step counter
# Final cost : 0.01223518014830004
# Compute control for a deterministic system
# Cost in iteration 0: 0.01223518014830004
# Converged in iteration 1 with cost 0.01223518014830004 because of step counter
# Final cost : 0.01223518014830004
# Compute control for a deterministic system
# Cost in iteration 0: 0.01223518014830004
# Converged in iteration 2 with cost 0.012235180148299968 because of step counter
# Final cost : 0.012235180148299968
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.012187170390582078
# Converged in iteration 84 with cost 0.012143938796993924 because of step counter
# Final cost : 0.012143938796993924
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143938796993924
# Converged in iteration 4 with cost 0.012143938796985054 because of step counter
# Final cost : 0.012143938796985054
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143938796985054
# Converged in iteration 1 with cost 0.012143938796985054 because of step counter
# Final cost : 0.012143938796985054
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143938796985054
# Converged in iteration 1 with cost 0.012143938796985054 because of step counter
# Final cost : 0.012143938796985054
# Compute control for a deterministic system
# Cost in iteration 0: 0.012143938796985054
# Converged in iteration 2 with cost 0.0121439387969848 because of step counter
# Final cost : 0.0121439387969848
# -----------------------------------------------
# 5 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872738573695143
# Converged in iteration 124 with cost 0.025872203472310746 because of step counter
# Final cost : 0.025872203472310746
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203472310746
# Converged in iteration 8 with cost 0.025872203472297864 because of step counter
# Final cost : 0.025872203472297864
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203472297864
# Converged in iteration 1 with cost 0.025872203472297864 because of step counter
# Final cost : 0.025872203472297864
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203472297864
# Converged in iteration 2 with cost 0.025872203472296934 because of step counter
# Final cost : 0.025872203472296934
# Compute control for a deterministic system
# Cost in iteration 0: 0.025872203472296934
# Converged in iteration 2 with cost 0.025872203472296483 because of step counter
# Final cost : 0.025872203472296483
# -----------------------------------------------
# 5 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.03982627178283088
# Cost in iteration 200: 0.03967189111267934
# Final cost : 0.03967189111267934
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967189111267934
# Converged in iteration 24 with cost 0.03967189110988477 because of step counter
# Final cost : 0.03967189110988477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967189110988477
# Converged in iteration 1 with cost 0.03967189110988477 because of step counter
# Final cost : 0.03967189110988477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967189110988477
# Converged in iteration 2 with cost 0.03967189110988464 because of step counter
# Final cost : 0.03967189110988464
# Compute control for a deterministic system
# Cost in iteration 0: 0.03967189110988464
# Converged in iteration 1 with cost 0.03967189110988464 because of step counter
# Final cost : 0.03967189110988464
# -----------------------------------------------
# 5 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.05484287031369007
# Cost in iteration 200: 0.053819607443901914
# Final cost : 0.053819607443901914
# Compute control for a deterministic system
# Cost in iteration 0: 0.053819607443901914
# Converged in iteration 60 with cost 0.05381960715974073 because of step counter
# Final cost : 0.05381960715974073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381960715974073
# Converged in iteration 1 with cost 0.05381960715974073 because of step counter
# Final cost : 0.05381960715974073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381960715974073
# Converged in iteration 1 with cost 0.05381960715974073 because of step counter
# Final cost : 0.05381960715974073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381960715974073
# Converged in iteration 1 with cost 0.05381960715974073 because of step counter
# Final cost : 0.05381960715974073
# -----------------------------------------------
# 5 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.06792059787723567
# Cost in iteration 200: 0.06769652553992926
# Final cost : 0.06769652553992926
# Compute control for a deterministic system
# Cost in iteration 0: 0.06769652553992926
# Converged in iteration 81 with cost 0.0676965253609377 because of step counter
# Final cost : 0.0676965253609377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0676965253609377
# Converged in iteration 1 with cost 0.0676965253609377 because of step counter
# Final cost : 0.0676965253609377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0676965253609377
# Converged in iteration 2 with cost 0.06769652536093745 because of step counter
# Final cost : 0.06769652536093745
# Compute control for a deterministic system
# Cost in iteration 0: 0.06769652536093745
# Converged in iteration 6 with cost 0.06769652536093114 because of step counter
# Final cost : 0.06769652536093114
# -----------------------------------------------
# 5 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.08246735592866208
# Cost in iteration 200: 0.08159021205090497
# Final cost : 0.08159021205090497
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021205090497
# Converged in iteration 124 with cost 0.08159021025774159 because of step counter
# Final cost : 0.08159021025774159
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021025774159
# Converged in iteration 2 with cost 0.0815902102577412 because of step counter
# Final cost : 0.0815902102577412
# Compute control for a deterministic system
# Cost in iteration 0: 0.0815902102577412
# Converged in iteration 8 with cost 0.08159021025773192 because of step counter
# Final cost : 0.08159021025773192
# Compute control for a deterministic system
# Cost in iteration 0: 0.08159021025773192
# Converged in iteration 11 with cost 0.08159021025771739 because of step counter
# Final cost : 0.08159021025771739
# -----------------------------------------------
# 5 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.09791057474565845
# Cost in iteration 200: 0.09549033111907089
# Final cost : 0.09549033111907089
# Compute control for a deterministic system
# Cost in iteration 0: 0.09549033111907089
# Cost in iteration 200: 0.09549032143243996
# Final cost : 0.09549032143243996
# Compute control for a deterministic system
# Cost in iteration 0: 0.09549032143243996
# Converged in iteration 6 with cost 0.0954903214324354 because of step counter
# Final cost : 0.0954903214324354
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954903214324354
# Converged in iteration 1 with cost 0.0954903214324354 because of step counter
# Final cost : 0.0954903214324354
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954903214324354
# Converged in iteration 10 with cost 0.09549032143242314 because of step counter
# Final cost : 0.09549032143242314
# -----------------------------------------------
# 5 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.11220623899586986
# Cost in iteration 200: 0.10938890597966083
# Final cost : 0.10938890597966083
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890597966083
# Cost in iteration 200: 0.10938890100980221
# Final cost : 0.10938890100980221
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890100980221
# Converged in iteration 18 with cost 0.10938890100972994 because of step counter
# Final cost : 0.10938890100972994
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890100972994
# Converged in iteration 1 with cost 0.10938890100972994 because of step counter
# Final cost : 0.10938890100972994
# Compute control for a deterministic system
# Cost in iteration 0: 0.10938890100972994
# Converged in iteration 1 with cost 0.10938890100972994 because of step counter
# Final cost : 0.10938890100972994
# -----------------------------------------------
# 5 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.1259718846237688
# Cost in iteration 200: 0.12327963517192082
# Final cost : 0.12327963517192082
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327963517192082
# Cost in iteration 200: 0.12327961664186178
# Final cost : 0.12327961664186178
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327961664186178
# Converged in iteration 75 with cost 0.12327961662768781 because of step counter
# Final cost : 0.12327961662768781
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327961662768781
# Converged in iteration 1 with cost 0.12327961662768781 because of step counter
# Final cost : 0.12327961662768781
# Compute control for a deterministic system
# Cost in iteration 0: 0.12327961662768781
# Converged in iteration 1 with cost 0.12327961662768781 because of step counter
# Final cost : 0.12327961662768781
# -----------------------------------------------
# 5 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.14472962221330413
# Cost in iteration 200: 0.1371572174863323
# Final cost : 0.1371572174863323
# Compute control for a deterministic system
# Cost in iteration 0: 0.1371572174863323
# Converged in iteration 11 with cost 0.13715716104177786 because of vanishing difference
# Final cost : 0.13715716104177786
# ...
# Converged in iteration 23 with cost 0.22897346819673883 because of vanishing difference
# Final cost : 0.22897346819673883
# Compute control for a deterministic system
# Cost in iteration 0: 0.22897346819673883
# Cost in iteration 200: 0.22897341585480965
# Final cost : 0.22897341585480965
# Compute control for a deterministic system
# Cost in iteration 0: 0.22897341585480965
# Cost in iteration 200: 0.22897341563400947
# Cost in iteration 400: 0.22897341562117854
# Final cost : 0.22897341562117854
# Compute control for a deterministic system
# Cost in iteration 0: 0.22897341562117854
# Converged in iteration 104 with cost 0.2289734156203417 because of step counter
# Final cost : 0.2289734156203417
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.21384122441511644
# Cost in iteration 200: 0.21382314665743013
# Final cost : 0.21382314665743013
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314665743013
# Cost in iteration 200: 0.21382314637207392
# Final cost : 0.21382314637207392
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314637207392
# Converged in iteration 76 with cost 0.21382314637104938 because of vanishing difference
# Final cost : 0.21382314637104938
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314637104938
# Converged in iteration 29 with cost 0.21382314637096872 because of step counter
# Final cost : 0.21382314637096872
# Compute control for a deterministic system
# Cost in iteration 0: 0.21382314637096872
# Converged in iteration 14 with cost 0.21382314637092187 because of step counter
# Final cost : 0.21382314637092187
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.1999063613451532
# Cost in iteration 200: 0.19878396840622592
# Final cost : 0.19878396840622592
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878396840622592
# Cost in iteration 200: 0.19878395045759475
# Final cost : 0.19878395045759475
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878395045759475
# Converged in iteration 164 with cost 0.1987839504025222 because of vanishing difference
# Final cost : 0.1987839504025222
# Compute control for a deterministic system
# Cost in iteration 0: 0.1987839504025222
# Converged in iteration 35 with cost 0.19878395040230912 because of vanishing difference
# Final cost : 0.19878395040230912
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878395040230912
# Converged in iteration 20 with cost 0.19878395040225255 because of step counter
# Final cost : 0.19878395040225255
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.18877988301625998
# Cost in iteration 200: 0.1835607441328883
# Final cost : 0.1835607441328883
# Compute control for a deterministic system
# Cost in iteration 0: 0.1835607441328883
# Cost in iteration 200: 0.18356069583863943
# Final cost : 0.18356069583863943
# Compute control for a deterministic system
# Cost in iteration 0: 0.18356069583863943
# Converged in iteration 179 with cost 0.18356069578079082 because of step counter
# Final cost : 0.18356069578079082
# Compute control for a deterministic system
# Cost in iteration 0: 0.18356069578079082
# Converged in iteration 1 with cost 0.18356069578079082 because of step counter
# Final cost : 0.18356069578079082
# Compute control for a deterministic system
# Cost in iteration 0: 0.18356069578079082
# Converged in iteration 2 with cost 0.18356069578079012 because of step counter
# Final cost : 0.18356069578079012
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.17231605647280154
# Cost in iteration 200: 0.16880375234277148
# Final cost : 0.16880375234277148
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880375234277148
# Cost in iteration 200: 0.16880372406442176
# Final cost : 0.16880372406442176
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372406442176
# Converged in iteration 127 with cost 0.16880372404574057 because of step counter
# Final cost : 0.16880372404574057
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372404574057
# Converged in iteration 11 with cost 0.16880372404572572 because of step counter
# Final cost : 0.16880372404572572
# Compute control for a deterministic system
# Cost in iteration 0: 0.16880372404572572
# Converged in iteration 1 with cost 0.16880372404572572 because of step counter
# Final cost : 0.16880372404572572
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.15636702262261165
# Cost in iteration 200: 0.15417562492412673
# Final cost : 0.15417562492412673
# Compute control for a deterministic system
# Cost in iteration 0: 0.15417562492412673
# Cost in iteration 200: 0.15417560950067996
# Final cost : 0.15417560950067996
# Compute control for a deterministic system
# Cost in iteration 0: 0.15417560950067996
# Converged in iteration 79 with cost 0.1541756094961451 because of step counter
# Final cost : 0.1541756094961451
# Compute control for a deterministic system
# Cost in iteration 0: 0.1541756094961451
# Converged in iteration 1 with cost 0.1541756094961451 because of step counter
# Final cost : 0.1541756094961451
# Compute control for a deterministic system
# Cost in iteration 0: 0.1541756094961451
# Converged in iteration 1 with cost 0.1541756094961451 because of step counter
# Final cost : 0.1541756094961451
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.13970756756674751
# Cost in iteration 200: 0.13965925888814332
# Final cost : 0.13965925888814332
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965925888814332
# Converged in iteration 178 with cost 0.13965925853012623 because of step counter
# Final cost : 0.13965925853012623
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965925853012623
# Converged in iteration 19 with cost 0.13965925853005676 because of step counter
# Final cost : 0.13965925853005676
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965925853005676
# Converged in iteration 1 with cost 0.13965925853005676 because of step counter
# Final cost : 0.13965925853005676
# Compute control for a deterministic system
# Cost in iteration 0: 0.13965925853005676
# Converged in iteration 1 with cost 0.13965925853005676 because of step counter
# Final cost : 0.13965925853005676
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.12625970641767584
# Cost in iteration 200: 0.12523789198266655
# Final cost : 0.12523789198266655
# Compute control for a deterministic system
# Cost in iteration 0: 0.12523789198266655
# Cost in iteration 200: 0.12523788706351235
# Final cost : 0.12523788706351235
# Compute control for a deterministic system
# Cost in iteration 0: 0.12523788706351235
# Converged in iteration 23 with cost 0.12523788706341404 because of step counter
# Final cost : 0.12523788706341404
# Compute control for a deterministic system
# Cost in iteration 0: 0.12523788706341404
# Converged in iteration 2 with cost 0.1252378870634125 because of step counter
# Final cost : 0.1252378870634125
# Compute control for a deterministic system
# Cost in iteration 0: 0.1252378870634125
# Converged in iteration 1 with cost 0.1252378870634125 because of step counter
# Final cost : 0.1252378870634125
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.11200093339955847
# Cost in iteration 200: 0.11089764583345518
# Final cost : 0.11089764583345518
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764583345518
# Converged in iteration 192 with cost 0.11089764203970096 because of step counter
# Final cost : 0.11089764203970096
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764203970096
# Converged in iteration 1 with cost 0.11089764203970096 because of step counter
# Final cost : 0.11089764203970096
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764203970096
# Converged in iteration 1 with cost 0.11089764203970096 because of step counter
# Final cost : 0.11089764203970096
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089764203970096
# Converged in iteration 1 with cost 0.11089764203970096 because of step counter
# Final cost : 0.11089764203970096
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.09700405318172838
# Cost in iteration 200: 0.09662860935987144
# Final cost : 0.09662860935987144
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662860935987144
# Converged in iteration 134 with cost 0.09662860789665204 because of step counter
# Final cost : 0.09662860789665204
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662860789665204
# Converged in iteration 1 with cost 0.09662860789665204 because of step counter
# Final cost : 0.09662860789665204
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662860789665204
# Converged in iteration 1 with cost 0.09662860789665204 because of vanishing difference
# Final cost : 0.09662860789665204
# Compute control for a deterministic system
# Cost in iteration 0: 0.09662860789665204
# Converged in iteration 9 with cost 0.09662860789663055 because of step counter
# Final cost : 0.09662860789663055
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.08298529309783369
# Cost in iteration 200: 0.08211700619441711
# Final cost : 0.08211700619441711
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700619441711
# Converged in iteration 114 with cost 0.08211700507275567 because of step counter
# Final cost : 0.08211700507275567
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700507275567
# Converged in iteration 1 with cost 0.08211700507275567 because of vanishing difference
# Final cost : 0.08211700507275567
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700507275567
# Converged in iteration 1 with cost 0.08211700507275567 because of step counter
# Final cost : 0.08211700507275567
# Compute control for a deterministic system
# Cost in iteration 0: 0.08211700507275567
# Converged in iteration 1 with cost 0.08211700507275567 because of step counter
# Final cost : 0.08211700507275567
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.06969697893820476
# Cost in iteration 200: 0.06797893971173713
# Final cost : 0.06797893971173713
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797893971173713
# Converged in iteration 84 with cost 0.06797893894065248 because of step counter
# Final cost : 0.06797893894065248
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797893894065248
# Converged in iteration 2 with cost 0.0679789389406519 because of step counter
# Final cost : 0.0679789389406519
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679789389406519
# Converged in iteration 1 with cost 0.0679789389406519 because of step counter
# Final cost : 0.0679789389406519
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679789389406519
# Converged in iteration 3 with cost 0.06797893894065092 because of step counter
# Final cost : 0.06797893894065092
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.05467263171529175
# Cost in iteration 200: 0.05390821756812046
# Final cost : 0.05390821756812046
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390821756812046
# Converged in iteration 52 with cost 0.05390821732453089 because of step counter
# Final cost : 0.05390821732453089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390821732453089
# Converged in iteration 1 with cost 0.05390821732453089 because of step counter
# Final cost : 0.05390821732453089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390821732453089
# Converged in iteration 1 with cost 0.05390821732453089 because of step counter
# Final cost : 0.05390821732453089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05390821732453089
# Converged in iteration 1 with cost 0.05390821732453089 because of step counter
# Final cost : 0.05390821732453089
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.03997122173643361
# Cost in iteration 200: 0.039913686072776955
# Final cost : 0.039913686072776955
# Compute control for a deterministic system
# Cost in iteration 0: 0.039913686072776955
# Converged in iteration 19 with cost 0.039913686071813614 because of step counter
# Final cost : 0.039913686071813614
# Compute control for a deterministic system
# Cost in iteration 0: 0.039913686071813614
# Converged in iteration 2 with cost 0.0399136860718126 because of step counter
# Final cost : 0.0399136860718126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0399136860718126
# Converged in iteration 1 with cost 0.0399136860718126 because of step counter
# Final cost : 0.0399136860718126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0399136860718126
# Converged in iteration 1 with cost 0.0399136860718126 because of step counter
# Final cost : 0.0399136860718126
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.026014312996636008
# Converged in iteration 136 with cost 0.02601225119016368 because of step counter
# Final cost : 0.02601225119016368
# Compute control for a deterministic system
# Cost in iteration 0: 0.02601225119016368
# Converged in iteration 8 with cost 0.026012251190138832 because of step counter
# Final cost : 0.026012251190138832
# Compute control for a deterministic system
# Cost in iteration 0: 0.026012251190138832
# Converged in iteration 1 with cost 0.026012251190138832 because of step counter
# Final cost : 0.026012251190138832
# Compute control for a deterministic system
# Cost in iteration 0: 0.026012251190138832
# Converged in iteration 1 with cost 0.026012251190138832 because of step counter
# Final cost : 0.026012251190138832
# Compute control for a deterministic system
# Cost in iteration 0: 0.026012251190138832
# Converged in iteration 1 with cost 0.026012251190138832 because of step counter
# Final cost : 0.026012251190138832
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.01227998191741025
# Converged in iteration 83 with cost 0.012235179857905622 because of step counter
# Final cost : 0.012235179857905622
# Compute control for a deterministic system
# Cost in iteration 0: 0.012235179857905622
# Converged in iteration 5 with cost 0.012235179857896227 because of step counter
# Final cost : 0.012235179857896227
# Compute control for a deterministic system
# Cost in iteration 0: 0.012235179857896227
# Converged in iteration 1 with cost 0.012235179857896227 because of step counter
# Final cost : 0.012235179857896227
# Compute control for a deterministic system
# Cost in iteration 0: 0.012235179857896227
# Converged in iteration 1 with cost 0.012235179857896227 because of step counter
# Final cost : 0.012235179857896227
# Compute control for a deterministic system
# Cost in iteration 0: 0.012235179857896227
# Converged in iteration 1 with cost 0.012235179857896227 because of step counter
# Final cost : 0.012235179857896227
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
