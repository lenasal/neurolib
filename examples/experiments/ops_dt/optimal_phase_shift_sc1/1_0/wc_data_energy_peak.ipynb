# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,1368], wc.inh[0,1368]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.453333333333333
# peaks =  [ 1547  3392  5237  7083  8928 10773 12619 14464 16309 18155 20000 21845
#  23691 25536 27382 29227 31072 32918 34763 36608 38454 40299 42144 43990
#  45835 47680 49526]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L2_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L2_cost_unweighted"][iw][ish] = results_dict["L2_cost_weighted"][iw][ish] / w2
    wc_controlled.w_1D = w2

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s2_l2_max.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s2_l2_max.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

ind_list = [9,10,11]
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        if i_w != 1:
            continue

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            if i_shift not in ind_list:
                continue

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                if type(results_peak["control"][i_w][i_shift-1]) == type(None):
                    continue 

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)

                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                if type(results_peak["control"][i_w][i_shift+1]) == type(None):
                    continue 

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        save(results_peak)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 1.4686896727130658
# Final cost : 1.1976163229971357
# Compute control for a deterministic system
# Cost in iteration 0: 1.1976163229971357
# Cost in iteration 200: 0.008426271801034349
# Final cost : 0.008426271801034349
# Compute control for a deterministic system
# Cost in iteration 0: 0.008426271801034349
# Cost in iteration 200: 0.006133191904578407
# Final cost : 0.006133191904578407
# Compute control for a deterministic system
# Cost in iteration 0: 0.006133191904578407
# Cost in iteration 200: 0.006031612768027137
# Final cost : 0.006031612768027137
# Compute control for a deterministic system
# Cost in iteration 0: 0.006031612768027137
# Cost in iteration 200: 0.006009361687617617
# Cost in iteration 400: 0.0060011521241969965
# Final cost : 0.0060011521241969965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060011521241969965
# Cost in iteration 200: 0.005997868585840987
# Cost in iteration 400: 0.005996436181208988
# Cost in iteration 600: 0.005995823457652686
# Cost in iteration 800: 0.0059955531682128966
# Cost in iteration 1000: 0.0059954268868469135
# Final cost : 0.0059954268868469135
# Compute control for a deterministic system
# Cost in iteration 0: 1.6399212789140323
# Final cost : 1.4065293445229232
# Compute control for a deterministic system
# Cost in iteration 0: 1.4065293445229232
# Cost in iteration 200: 0.010766858010140087
# Final cost : 0.010766858010140087
# Compute control for a deterministic system
# Cost in iteration 0: 0.010766858010140087
# Cost in iteration 200: 0.007548693675605994
# Final cost : 0.007548693675605994
# Compute control for a deterministic system
# Cost in iteration 0: 0.007548693675605994
# Cost in iteration 200: 0.0074028245259747955
# Final cost : 0.0074028245259747955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0074028245259747955
# Cost in iteration 200: 0.007367029977905793
# Cost in iteration 400: 0.00735298895513422
# Final cost : 0.00735298895513422
# Compute control for a deterministic system
# Cost in iteration 0: 0.00735298895513422
# Cost in iteration 200: 0.007346684563618492
# Cost in iteration 400: 0.007343815801026635
# Cost in iteration 600: 0.007342482872900986
# Cost in iteration 800: 0.007341819045887841
# Cost in iteration 1000: 0.007341497270607157
# Final cost : 0.007341497270607157
# Compute control for a deterministic system
# Cost in iteration 0: 1.7939593926618786
# Final cost : 1.5984364014940071
# Compute control for a deterministic system
# Cost in iteration 0: 1.5984364014940071
# Cost in iteration 200: 0.013525834771037137
# Final cost : 0.013525834771037137
# Compute control for a deterministic system
# Cost in iteration 0: 0.013525834771037137
# Cost in iteration 200: 0.009122337944513777
# Final cost : 0.009122337944513777
# Compute control for a deterministic system
# Cost in iteration 0: 0.009122337944513777
# Cost in iteration 200: 0.008911255809852142
# Final cost : 0.008911255809852142
# Compute control for a deterministic system
# Cost in iteration 0: 0.008911255809852142
# Cost in iteration 200: 0.008856871475594653
# Cost in iteration 400: 0.008835128143572422
# Final cost : 0.008835128143572422
# Compute control for a deterministic system
# Cost in iteration 0: 0.008835128143572422
# Cost in iteration 200: 0.008824386849255891
# Cost in iteration 400: 0.008819526351704732
# Cost in iteration 600: 0.008817103431755189
# Cost in iteration 800: 0.008815861636143714
# Cost in iteration 1000: 0.008815244509445245
# Final cost : 0.008815244509445245
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.02442834119240017
# Cost in iteration 200: 0.007449758622747997
# Final cost : 0.007449758622747997
# Compute control for a deterministic system
# Cost in iteration 0: 0.007449758622747997
# Cost in iteration 200: 0.007353168288809466
# Final cost : 0.007353168288809466
# Compute control for a deterministic system
# Cost in iteration 0: 0.007353168288809466
# Cost in iteration 200: 0.0073460414247387374
# Final cost : 0.0073460414247387374
# Compute control for a deterministic system
# Cost in iteration 0: 0.0073460414247387374
# Cost in iteration 200: 0.007343313604844538
# Cost in iteration 400: 0.007342238651634086
# Final cost : 0.007342238651634086
# Compute control for a deterministic system
# Cost in iteration 0: 0.007342238651634086
# Cost in iteration 200: 0.007341702256909091
# Cost in iteration 400: 0.007341436474075756
# Cost in iteration 600: 0.007341316118967613
# Cost in iteration 800: 0.007341258049440824
# Cost in iteration 1000: 0.007341230974122716
# Final cost : 0.007341230974122716
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.06470499891185469
# Cost in iteration 200: 0.008945450928210747
# Final cost : 0.008945450928210747
# Compute control for a deterministic system
# Cost in iteration 0: 0.008945450928210747
# Cost in iteration 200: 0.008831987663253061
# Final cost : 0.008831987663253061
# Compute control for a deterministic system
# Cost in iteration 0: 0.008831987663253061
# Cost in iteration 200: 0.008821725605284643
# Final cost : 0.008821725605284643
# Compute control for a deterministic system
# Cost in iteration 0: 0.008821725605284643
# Cost in iteration 200: 0.008817886361980058
# Cost in iteration 400: 0.008816264805965023
# Final cost : 0.008816264805965023
# Compute control for a deterministic system
# Cost in iteration 0: 0.008816264805965023
# Cost in iteration 200: 0.00881546628330792
# Cost in iteration 400: 0.00881504916831708
# Cost in iteration 600: 0.008814833526193413
# Cost in iteration 800: 0.008814724940652333
# Cost in iteration 1000: 0.008814670302752617
# Final cost : 0.008814670302752617
# -----------------------------------------------
# 0 found better solution,  11
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.034810063914004034
# Cost in iteration 200: 0.007384402536466924
# Final cost : 0.007384402536466924
# Compute control for a deterministic system
# Cost in iteration 0: 0.007384402536466924
# Cost in iteration 200: 0.007357829592535372
# Final cost : 0.007357829592535372
# Compute control for a deterministic system
# Cost in iteration 0: 0.007357829592535372
# Cost in iteration 200: 0.007348770032777337
# Cost in iteration 400: 0.00734447193928846
# Final cost : 0.00734447193928846
# Compute control for a deterministic system
# Cost in iteration 0: 0.00734447193928846
# Cost in iteration 200: 0.007342591726866185
# Cost in iteration 400: 0.00734189457004684
# Cost in iteration 600: 0.007341552722520333
# Cost in iteration 800: 0.007341380731179667
# Cost in iteration 1000: 0.007341294569351426
# Final cost : 0.007341294569351426
# Compute control for a deterministic system
# Cost in iteration 0: 0.036227220892124865
# Cost in iteration 200: 0.006027481021307978
# Final cost : 0.006027481021307978
# Compute control for a deterministic system
# Cost in iteration 0: 0.006027481021307978
# Cost in iteration 200: 0.006007217123462722
# Final cost : 0.006007217123462722
# Compute control for a deterministic system
# Cost in iteration 0: 0.006007217123462722
# Cost in iteration 200: 0.006000314213427767
# Cost in iteration 400: 0.005997061050701341
# Final cost : 0.005997061050701341
# Compute control for a deterministic system
# Cost in iteration 0: 0.005997061050701341
# Cost in iteration 200: 0.005995915323060719
# Cost in iteration 400: 0.005995591142985679
# Cost in iteration 600: 0.00599544471599452
# Cost in iteration 800: 0.005995376049136479
# Cost in iteration 1000: 0.0059953444153745825
# Final cost : 0.0059953444153745825
# -----------------------------------------------
# 1 found better solution,  9
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0068037319384210045
# Cost in iteration 200: 0.005996211420044622
# Final cost : 0.005996211420044622
# Compute control for a deterministic system
# Cost in iteration 0: 0.005996211420044622
# Cost in iteration 200: 0.005995348553855704
# Final cost : 0.005995348553855704
# Compute control for a deterministic system
# Cost in iteration 0: 0.005995348553855704
# Cost in iteration 200: 0.00599532121183054
# Final cost : 0.00599532121183054
# Compute control for a deterministic system
# Cost in iteration 0: 0.00599532121183054
# Cost in iteration 200: 0.00599531815353135
# Cost in iteration 400: 0.005995317092059519
# Final cost : 0.005995317092059519
# Compute control for a deterministic system
# Cost in iteration 0: 0.005995317092059519
# Cost in iteration 200: 0.005995316604181037
# Cost in iteration 400: 0.005995316379145305
# Cost in iteration 600: 0.00599531627353283
# Cost in iteration 800: 0.005995316222992542
# Cost in iteration 1000: 0.0059953161987825136
# Final cost : 0.0059953161987825136
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.013102680396845721
# Cost in iteration 200: 0.007342301035930787
# Final cost : 0.007342301035930787
# Compute control for a deterministic system
# Cost in iteration 0: 0.007342301035930787
# Cost in iteration 200: 0.007341249708941093
# Final cost : 0.007341249708941093
# Compute control for a deterministic system
# Cost in iteration 0: 0.007341249708941093
# Cost in iteration 200: 0.0073412148538106224
# Final cost : 0.0073412148538106224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0073412148538106224
# Cost in iteration 200: 0.007341209986188465
# Cost in iteration 400: 0.0073412080984611066
# Final cost : 0.0073412080984611066
# Compute control for a deterministic system
# Cost in iteration 0: 0.0073412080984611066
# Cost in iteration 200: 0.007341207182779511
# Cost in iteration 400: 0.007341206727633577
# Cost in iteration 600: 0.007341206503550608
# Cost in iteration 800: 0.0073412063902712705
# Cost in iteration 1000: 0.007341206333065823
# Final cost : 0.007341206333065823
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.011302776019054063
# Cost in iteration 200: 0.008816287192463846
# Final cost : 0.008816287192463846
# Compute control for a deterministic system
# Cost in iteration 0: 0.008816287192463846
# Cost in iteration 200: 0.008814679610917586
# Final cost : 0.008814679610917586
# Compute control for a deterministic system
# Cost in iteration 0: 0.008814679610917586
# Cost in iteration 200: 0.008814628725677433
# Final cost : 0.008814628725677433
# Compute control for a deterministic system
# Cost in iteration 0: 0.008814628725677433
# Cost in iteration 200: 0.008814620877356696
# Cost in iteration 400: 0.008814617425596357
# Final cost : 0.008814617425596357
# Compute control for a deterministic system
# Cost in iteration 0: 0.008814617425596357
# Cost in iteration 200: 0.00881461557762166
# Cost in iteration 400: 0.008814614597576603
# Cost in iteration 600: 0.008814614073564986
# Cost in iteration 800: 0.008814613784809836
# Cost in iteration 1000: 0.008814613629859261
# Final cost : 0.008814613629859261
# -----------------------------------------------
# 4 found better solution,  11

# %%
save(results_peak)

# %%
0.4*59
# Out:
# 23.6
