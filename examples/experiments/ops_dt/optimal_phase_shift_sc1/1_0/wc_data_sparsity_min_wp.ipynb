# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,413], wc.inh[0,413]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.453333333333333
# minima =  [ 1551  3392  5237  7082  8928 10773 12618 14464 16309 18155 20000 21845
#  23691 25536 27381 29227 31072 32917 34763 36608 38453 40299 42144 43989
#  45835 47680 49525]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-3
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [1., 1e-1, 1e-2, 1e-3, 1e-4]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ])

# %%
def save(results_dict):
    filehandler = open("a_s2_l1_wp.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s2_l1_wp.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = [10]
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w"])):

        w1 = results_min['w'][i_w]

        if i_w not in [1,2,3,4]:
            continue

        for i_shift in range(n_points):

            if i_shift not in ind_list:
                continue

            print(i_w, i_shift)

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[0]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.99+np.random.random()*0.02)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_w == 0:
                    break

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.99+np.random.random()*0.02)
                
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# 1 10
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.017825719631301924
# Converged in iteration 149 with cost 0.014221763977529583 because of step counter
# Final cost : 0.014221763977529583
# Compute control for a deterministic system
# Cost in iteration 0: 0.014221763977529583
# Converged in iteration 1 with cost 0.014221763977529583 because of step counter
# Final cost : 0.014221763977529583
# Compute control for a deterministic system
# Cost in iteration 0: 0.014221763977529583
# Converged in iteration 1 with cost 0.014221763977529583 because of step counter
# Final cost : 0.014221763977529583
# Compute control for a deterministic system
# Cost in iteration 0: 0.014221763977529583
# Converged in iteration 1 with cost 0.014221763977529583 because of step counter
# Final cost : 0.014221763977529583
# Compute control for a deterministic system
# Cost in iteration 0: 0.014221763977529583
# Converged in iteration 1 with cost 0.014221763977529583 because of step counter
# Final cost : 0.014221763977529583
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.01417613339002799
# Converged in iteration 9 with cost 0.014172170599974065 because of step counter
# Final cost : 0.014172170599974065
# Compute control for a deterministic system
# Cost in iteration 0: 0.014172170599974065
# Converged in iteration 1 with cost 0.014172170599974065 because of step counter
# Final cost : 0.014172170599974065
# Compute control for a deterministic system
# Cost in iteration 0: 0.014172170599974065
# Converged in iteration 1 with cost 0.014172170599974065 because of step counter
# Final cost : 0.014172170599974065
# Compute control for a deterministic system
# Cost in iteration 0: 0.014172170599974065
# Converged in iteration 1 with cost 0.014172170599974065 because of step counter
# Final cost : 0.014172170599974065
# Compute control for a deterministic system
# Cost in iteration 0: 0.014172170599974065
# Converged in iteration 1 with cost 0.014172170599974065 because of step counter
# Final cost : 0.014172170599974065
# -----------------------------------------------
# 5 found better solution,  10
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0179199112937801
# Final cost : 0.014360154434991458
# Compute control for a deterministic system
# Cost in iteration 0: 0.014360154434991458
# Converged in iteration 5 with cost 0.014337182233266696 because of step counter
# Final cost : 0.014337182233266696
# Compute control for a deterministic system
# Cost in iteration 0: 0.014337182233266696
# Converged in iteration 1 with cost 0.014337182233266696 because of step counter
# Final cost : 0.014337182233266696
# Compute control for a deterministic system
# Cost in iteration 0: 0.014337182233266696
# Converged in iteration 1 with cost 0.014337182233266696 because of step counter
# Final cost : 0.014337182233266696
# 2 10
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.001594121393118191
# Converged in iteration 135 with cost 0.001431681130696997 because of step counter
# Final cost : 0.001431681130696997
# Compute control for a deterministic system
# Cost in iteration 0: 0.001431681130696997
# Converged in iteration 1 with cost 0.001431681130696997 because of step counter
# Final cost : 0.001431681130696997
# Compute control for a deterministic system
# Cost in iteration 0: 0.001431681130696997
# Converged in iteration 1 with cost 0.001431681130696997 because of step counter
# Final cost : 0.001431681130696997
# Compute control for a deterministic system
# Cost in iteration 0: 0.001431681130696997
# Converged in iteration 1 with cost 0.001431681130696997 because of step counter
# Final cost : 0.001431681130696997
# Compute control for a deterministic system
# Cost in iteration 0: 0.001431681130696997
# Converged in iteration 1 with cost 0.001431681130696997 because of step counter
# Final cost : 0.001431681130696997
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015767909347075757
# Final cost : 0.0014347565777381908
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014347565777381908
# Final cost : 0.0014346123204496389
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014346123204496389
# Converged in iteration 12 with cost 0.0014300996993115928 because of step counter
# Final cost : 0.0014300996993115928
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014300996993115928
# Converged in iteration 1 with cost 0.0014300996993115928 because of step counter
# Final cost : 0.0014300996993115928
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014300996993115928
# Converged in iteration 1 with cost 0.0014300996993115928 because of step counter
# Final cost : 0.0014300996993115928
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016640589586520101
# Final cost : 0.0014390383746015526
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014390383746015526
# Converged in iteration 13 with cost 0.0014319265226750014 because of step counter
# Final cost : 0.0014319265226750014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014319265226750014
# Converged in iteration 1 with cost 0.0014319265226750014 because of step counter
# Final cost : 0.0014319265226750014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014319265226750014
# Converged in iteration 1 with cost 0.0014319265226750014 because of step counter
# Final cost : 0.0014319265226750014
# 3 10
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.004047937958363226
# Final cost : 0.0001498749774909228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001498749774909228
# Final cost : 0.00014950079777027115
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014950079777027115
# Final cost : 0.0001467258742992552
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001467258742992552
# Converged in iteration 118 with cost 0.00014622047230273427 because of step counter
# Final cost : 0.00014622047230273427
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014622047230273427
# Converged in iteration 1 with cost 0.00014622047230273427 because of step counter
# Final cost : 0.00014622047230273427
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001617905295733736
# Final cost : 0.00014508192746199517
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014508192746199517
# Final cost : 0.00014506206691128557
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014506206691128557
# Converged in iteration 28 with cost 0.0001448334782931211 because of step counter
# Final cost : 0.0001448334782931211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001448334782931211
# Converged in iteration 1 with cost 0.0001448334782931211 because of step counter
# Final cost : 0.0001448334782931211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001448334782931211
# Converged in iteration 1 with cost 0.0001448334782931211 because of step counter
# Final cost : 0.0001448334782931211
# -----------------------------------------------
# 5 found better solution,  10
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014961630976482882
# Final cost : 0.00014538458428839602
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014538458428839602
# Converged in iteration 44 with cost 0.00014517827394599947 because of step counter
# Final cost : 0.00014517827394599947
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014517827394599947
# Converged in iteration 1 with cost 0.00014517827394599947 because of step counter
# Final cost : 0.00014517827394599947
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014517827394599947
# Converged in iteration 1 with cost 0.00014517827394599947 because of step counter
# Final cost : 0.00014517827394599947
# 4 10
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018982488553056945
# Final cost : 1.4689913973183441e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4689913973183441e-05
# Final cost : 1.4679712428749471e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4679712428749471e-05
# Converged in iteration 85 with cost 1.4676502842249393e-05 because of step counter
# Final cost : 1.4676502842249393e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4676502842249393e-05
# Converged in iteration 1 with cost 1.4676502842249393e-05 because of step counter
# Final cost : 1.4676502842249393e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4676502842249393e-05
# Converged in iteration 1 with cost 1.4676502842249393e-05 because of step counter
# Final cost : 1.4676502842249393e-05
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 9.400013663462281e-05
# Final cost : 1.4676947008664502e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4676947008664502e-05
# Final cost : 1.4667193839255699e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4667193839255699e-05
# Converged in iteration 82 with cost 1.4662934093102363e-05 because of step counter
# Final cost : 1.4662934093102363e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4662934093102363e-05
# Converged in iteration 1 with cost 1.4662934093102363e-05 because of step counter
# Final cost : 1.4662934093102363e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.4662934093102363e-05
# Converged in iteration 1 with cost 1.4662934093102363e-05 because of step counter
# Final cost : 1.4662934093102363e-05
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 2.751692340204328e-05
# Final cost : 1.6009691742753948e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6009691742753948e-05
# Final cost : 1.5757766837537847e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.5757766837537847e-05
# Final cost : 1.5435467491414467e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.5435467491414467e-05
# Final cost : 1.4782558909913913e-05

# %%
save(results_min)
