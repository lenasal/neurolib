# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,413], wc.inh[0,413]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.453333333333333
# minima =  [ 1551  3392  5237  7082  8928 10773 12618 14464 16309 18155 20000 21845
#  23691 25536 27381 29227 31072 32917 34763 36608 38453 40299 42144 43989
#  45835 47680 49525]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 20000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L2_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L2_cost_unweighted"][iw][ish] = results_dict["L2_cost_weighted"][iw][ish] / w2
    wc_controlled.w_1D = w2

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s2_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s2_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("a_s2_l2.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s2_l2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)
                
            save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 7.57966229343957e-05
# Cost in iteration 200: 7.478150757517331e-05
# Final cost : 7.478150757517331e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.478150757517331e-05
# Cost in iteration 200: 7.474828188956849e-05
# Final cost : 7.474828188956849e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.474828188956849e-05
# Cost in iteration 200: 7.474741432101374e-05
# Final cost : 7.474741432101374e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.474741432101374e-05
# Cost in iteration 200: 7.474735871210781e-05
# Cost in iteration 400: 7.474735508037737e-05
# Final cost : 7.474735508037737e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.474735508037737e-05
# Cost in iteration 200: 7.47473546884091e-05
# Cost in iteration 400: 7.474735463792316e-05
# Converged in iteration 506 with cost 7.474735463138615e-05 because of step counter
# Final cost : 7.474735463138615e-05
# -----------------------------------------------
# 4 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003022394578687027
# Cost in iteration 200: 0.000298050811077306
# Final cost : 0.000298050811077306
# Compute control for a deterministic system
# Cost in iteration 0: 0.000298050811077306
# Cost in iteration 200: 0.0002979220978725111
# Final cost : 0.0002979220978725111
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002979220978725111
# Cost in iteration 200: 0.0002979183458666952
# Final cost : 0.0002979183458666952
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002979183458666952
# Cost in iteration 200: 0.0002979180479540015
# Cost in iteration 400: 0.00029791801708703967
# Final cost : 0.00029791801708703967
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029791801708703967
# Cost in iteration 200: 0.00029791801288739806
# Cost in iteration 400: 0.00029791801247788026
# Cost in iteration 600: 0.0002979180124210328
# Converged in iteration 602 with cost 0.0002979180124209855 because of step counter
# Final cost : 0.0002979180124209855
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006780048772970194
# Cost in iteration 200: 0.0006682081618764588
# Final cost : 0.0006682081618764588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006682081618764588
# Cost in iteration 200: 0.0006679289004732806
# Final cost : 0.0006679289004732806
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006679289004732806
# Cost in iteration 200: 0.000667921257769281
# Final cost : 0.000667921257769281
# Compute control for a deterministic system
# Cost in iteration 0: 0.000667921257769281
# Cost in iteration 200: 0.0006679205764577715
# Cost in iteration 400: 0.000667920485539413
# Final cost : 0.000667920485539413
# Compute control for a deterministic system
# Cost in iteration 0: 0.000667920485539413
# Cost in iteration 200: 0.0006679204707926294
# Cost in iteration 400: 0.0006679204685488988
# Cost in iteration 600: 0.0006679204681684311
# Cost in iteration 800: 0.000667920468099715
# Converged in iteration 838 with cost 0.0006679204680942483 because of step counter
# Final cost : 0.0006679204680942483
# -----------------------------------------------
# 4 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.00121490897089233
# Cost in iteration 200: 0.0011964546451198126
# Final cost : 0.0011964546451198126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011964546451198126
# Cost in iteration 200: 0.0011959787524889929
# Final cost : 0.0011959787524889929
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011959787524889929
# Cost in iteration 200: 0.0011959647620595607
# Final cost : 0.0011959647620595607
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011959647620595607
# Cost in iteration 200: 0.0011959632752832898
# Cost in iteration 400: 0.001195963055068823
# Final cost : 0.001195963055068823
# Compute control for a deterministic system
# Cost in iteration 0: 0.001195963055068823
# Cost in iteration 200: 0.0011959630200454132
# Cost in iteration 400: 0.001195963013821971
# Cost in iteration 600: 0.0011959630128508118
# Cost in iteration 800: 0.0011959630126881316
# Converged in iteration 893 with cost 0.0011959630126679626 because of vanishing difference
# Final cost : 0.0011959630126679626
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018890672164421694
# Cost in iteration 200: 0.0018586489626698265
# Final cost : 0.0018586489626698265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018586489626698265
# Cost in iteration 200: 0.0018579581596261563
# Final cost : 0.0018579581596261563
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018579581596261563
# Cost in iteration 200: 0.0018579326948886213
# Final cost : 0.0018579326948886213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018579326948886213
# Cost in iteration 200: 0.0018579298150842734
# Cost in iteration 400: 0.001857929384117532
# Final cost : 0.001857929384117532
# Compute control for a deterministic system
# Cost in iteration 0: 0.001857929384117532
# Cost in iteration 200: 0.0018579293184135949
# Cost in iteration 400: 0.0018579293058568393
# Cost in iteration 600: 0.0018579293033093099
# Cost in iteration 800: 0.0018579293029171952
# Cost in iteration 1000: 0.001857929302835809
# Final cost : 0.001857929302835809
# -----------------------------------------------
# 4 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027096037058779872
# Cost in iteration 200: 0.0026627821724580537
# Final cost : 0.0026627821724580537
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026627821724580537
# Cost in iteration 200: 0.0026618695413484833
# Final cost : 0.0026618695413484833
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026618695413484833
# Cost in iteration 200: 0.0026618325857437545
# Final cost : 0.0026618325857437545
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026618325857437545
# Cost in iteration 200: 0.002661827822101336
# Cost in iteration 400: 0.002661827000531055
# Final cost : 0.002661827000531055
# Compute control for a deterministic system
# Cost in iteration 0: 0.002661827000531055
# Cost in iteration 200: 0.0026618268403791803
# Cost in iteration 400: 0.0026618268046993527
# Cost in iteration 600: 0.0026618268009311564
# Cost in iteration 800: 0.0026618268001673815
# Cost in iteration 1000: 0.002661826799979684
# Final cost : 0.002661826799979684
# -----------------------------------------------
# 4 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036761218764421737
# Cost in iteration 200: 0.0036071301101735093
# Final cost : 0.0036071301101735093
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036071301101735093
# Cost in iteration 200: 0.003606015973064221
# Final cost : 0.003606015973064221
# Compute control for a deterministic system
# Cost in iteration 0: 0.003606015973064221
# Cost in iteration 200: 0.00360596316059232
# Final cost : 0.00360596316059232
# Compute control for a deterministic system
# Cost in iteration 0: 0.00360596316059232
# Cost in iteration 200: 0.0036059555488278383
# Cost in iteration 400: 0.0036059541860065636
# Final cost : 0.0036059541860065636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036059541860065636
# Cost in iteration 200: 0.0036059538833020923
# Cost in iteration 400: 0.003605953824640524
# Cost in iteration 600: 0.0036059538089644096
# Cost in iteration 800: 0.0036059538039385683
# Cost in iteration 1000: 0.0036059538020748864
# Final cost : 0.0036059538020748864
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.004788461914793512
# Cost in iteration 200: 0.004689913209402353
# Final cost : 0.004689913209402353
# Compute control for a deterministic system
# Cost in iteration 0: 0.004689913209402353
# Cost in iteration 200: 0.004688637179881162
# Final cost : 0.004688637179881162
# Compute control for a deterministic system
# Cost in iteration 0: 0.004688637179881162
# Cost in iteration 200: 0.004688569463562958
# Final cost : 0.004688569463562958
# Compute control for a deterministic system
# Cost in iteration 0: 0.004688569463562958
# Cost in iteration 200: 0.00468855841291543
# Cost in iteration 400: 0.004688556220388397
# Final cost : 0.004688556220388397
# Compute control for a deterministic system
# Cost in iteration 0: 0.004688556220388397
# Cost in iteration 200: 0.004688555649893058
# Cost in iteration 400: 0.004688555498484968
# Cost in iteration 600: 0.004688555438607462
# Cost in iteration 800: 0.004688555412872111
# Cost in iteration 1000: 0.00468855540046775
# Final cost : 0.00468855540046775
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.006047043603223165
# Cost in iteration 200: 0.005909297074438786
# Final cost : 0.005909297074438786
# Compute control for a deterministic system
# Cost in iteration 0: 0.005909297074438786
# Cost in iteration 200: 0.005907930460960441
# Final cost : 0.005907930460960441
# Compute control for a deterministic system
# Cost in iteration 0: 0.005907930460960441
# Cost in iteration 200: 0.005907841029937873
# Final cost : 0.005907841029937873
# Compute control for a deterministic system
# Cost in iteration 0: 0.005907841029937873
# Cost in iteration 200: 0.005907822949829465
# Cost in iteration 400: 0.005907819658942955
# Final cost : 0.005907819658942955
# Compute control for a deterministic system
# Cost in iteration 0: 0.005907819658942955
# Cost in iteration 200: 0.005907818831582521
# Cost in iteration 400: 0.005907818499604664
# Cost in iteration 600: 0.0059078183525493235
# Cost in iteration 800: 0.005907818279900986
# Cost in iteration 1000: 0.0059078182458173695
# Final cost : 0.0059078182458173695
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.007451156759123589
# Cost in iteration 200: 0.007263398681897752
# Final cost : 0.007263398681897752
# Compute control for a deterministic system
# Cost in iteration 0: 0.007263398681897752
# Cost in iteration 200: 0.007262003960783559
# Final cost : 0.007262003960783559
# Compute control for a deterministic system
# Cost in iteration 0: 0.007262003960783559
# Cost in iteration 200: 0.007261902134760523
# Final cost : 0.007261902134760523
# Compute control for a deterministic system
# Cost in iteration 0: 0.007261902134760523
# Cost in iteration 200: 0.007261877912975512
# Cost in iteration 400: 0.007261870422703492
# Final cost : 0.007261870422703492
# Compute control for a deterministic system
# Cost in iteration 0: 0.007261870422703492
# Cost in iteration 200: 0.007261867195640686
# Cost in iteration 400: 0.007261865648347412
# Cost in iteration 600: 0.007261864905365651
# Cost in iteration 800: 0.007261864505825838
# Cost in iteration 1000: 0.007261864319898028
# Final cost : 0.007261864319898028
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.008999883670952164
# Cost in iteration 200: 0.008750228561704019
# Final cost : 0.008750228561704019
# Compute control for a deterministic system
# Cost in iteration 0: 0.008750228561704019
# Cost in iteration 200: 0.008748914364181874
# Final cost : 0.008748914364181874
# Compute control for a deterministic system
# Cost in iteration 0: 0.008748914364181874
# Cost in iteration 200: 0.008748796165856687
# Final cost : 0.008748796165856687
# Compute control for a deterministic system
# Cost in iteration 0: 0.008748796165856687
# Cost in iteration 200: 0.008748763584921366
# Cost in iteration 400: 0.00874875166740727
# Final cost : 0.00874875166740727
# Compute control for a deterministic system
# Cost in iteration 0: 0.00874875166740727
# Cost in iteration 200: 0.008748745540392741
# Cost in iteration 400: 0.008748742510770237
# Cost in iteration 600: 0.008748740929173318
# Cost in iteration 800: 0.00874874005457766
# Cost in iteration 1000: 0.00874873959255716
# Final cost : 0.00874873959255716
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.010725110725444974
# Cost in iteration 200: 0.010404502371382116
# Final cost : 0.010404502371382116
# Compute control for a deterministic system
# Cost in iteration 0: 0.010404502371382116
# Cost in iteration 200: 0.010403287349842895
# Final cost : 0.010403287349842895
# Compute control for a deterministic system
# Cost in iteration 0: 0.010403287349842895
# Cost in iteration 200: 0.010403126417890027
# Final cost : 0.010403126417890027
# Compute control for a deterministic system
# Cost in iteration 0: 0.010403126417890027
# Cost in iteration 200: 0.010403063562054496
# Cost in iteration 400: 0.010403033916211887
# Final cost : 0.010403033916211887
# Compute control for a deterministic system
# Cost in iteration 0: 0.010403033916211887
# Cost in iteration 200: 0.010403016229757282
# Cost in iteration 400: 0.01040300630366618
# Cost in iteration 600: 0.010403000353730985
# Cost in iteration 800: 0.010402996811795486
# Cost in iteration 1000: 0.01040299479167071
# Final cost : 0.01040299479167071
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.012552726371598011
# Cost in iteration 200: 0.01215340134606276
# Final cost : 0.01215340134606276
# Compute control for a deterministic system
# Cost in iteration 0: 0.01215340134606276
# Cost in iteration 200: 0.012152363009445168
# Final cost : 0.012152363009445168
# Compute control for a deterministic system
# Cost in iteration 0: 0.012152363009445168
# Cost in iteration 200: 0.012152184157872538
# Final cost : 0.012152184157872538
# Compute control for a deterministic system
# Cost in iteration 0: 0.012152184157872538
# Cost in iteration 200: 0.012152100694806729
# Cost in iteration 400: 0.012152054121560708
# Final cost : 0.012152054121560708
# Compute control for a deterministic system
# Cost in iteration 0: 0.012152054121560708
# Cost in iteration 200: 0.012152025244886887
# Cost in iteration 400: 0.01215200717599509
# Cost in iteration 600: 0.012151996104889236
# Cost in iteration 800: 0.012151989267061743
# Cost in iteration 1000: 0.012151985380271693
# Final cost : 0.012151985380271693
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.01450384268416013
# Cost in iteration 200: 0.014028484038560794
# Final cost : 0.014028484038560794
# Compute control for a deterministic system
# Cost in iteration 0: 0.014028484038560794
# Cost in iteration 200: 0.014027555336586301
# Final cost : 0.014027555336586301
# Compute control for a deterministic system
# Cost in iteration 0: 0.014027555336586301
# Cost in iteration 200: 0.014027332388459336
# Final cost : 0.014027332388459336
# Compute control for a deterministic system
# Cost in iteration 0: 0.014027332388459336
# Cost in iteration 200: 0.014027203960650537
# Cost in iteration 400: 0.014027126414555302
# Final cost : 0.014027126414555302
# Compute control for a deterministic system
# Cost in iteration 0: 0.014027126414555302
# Cost in iteration 200: 0.01402707068053377
# Cost in iteration 400: 0.014027037033771984
# Cost in iteration 600: 0.014027015370618885
# Cost in iteration 800: 0.014027001403841404
# Cost in iteration 1000: 0.01402699231455516
# Final cost : 0.01402699231455516
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.016569209317155796
# Cost in iteration 200: 0.016026445655073752
# Final cost : 0.016026445655073752
# Compute control for a deterministic system
# Cost in iteration 0: 0.016026445655073752
# Cost in iteration 200: 0.01602558040809457
# Final cost : 0.01602558040809457
# Compute control for a deterministic system
# Cost in iteration 0: 0.01602558040809457
# Cost in iteration 200: 0.0160253255365883
# Final cost : 0.0160253255365883
# Compute control for a deterministic system
# Cost in iteration 0: 0.0160253255365883
# Cost in iteration 200: 0.016025149570545426
# Cost in iteration 400: 0.01602503523674913
# Final cost : 0.01602503523674913
# Compute control for a deterministic system
# Cost in iteration 0: 0.01602503523674913
# Cost in iteration 200: 0.016024956890201187
# Cost in iteration 400: 0.01602490555302935
# Cost in iteration 600: 0.01602487116599864
# Cost in iteration 800: 0.016024848739677754
# Cost in iteration 1000: 0.016024834276348807
# Final cost : 0.016024834276348807
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.018738530537674908
# Cost in iteration 200: 0.018142672876421483
# Final cost : 0.018142672876421483
# Compute control for a deterministic system
# Cost in iteration 0: 0.018142672876421483
# Cost in iteration 200: 0.018141705288200687
# Final cost : 0.018141705288200687
# Compute control for a deterministic system
# Cost in iteration 0: 0.018141705288200687
# Cost in iteration 200: 0.018141365650696677
# Final cost : 0.018141365650696677
# Compute control for a deterministic system
# Cost in iteration 0: 0.018141365650696677
# Cost in iteration 200: 0.018141102541314062
# Cost in iteration 400: 0.018140946699725727
# Final cost : 0.018140946699725727
# Compute control for a deterministic system
# Cost in iteration 0: 0.018140946699725727
# Cost in iteration 200: 0.018140821770185365
# Cost in iteration 400: 0.01814073930892287
# Cost in iteration 600: 0.018140681577841863
# Cost in iteration 800: 0.01814064295191365
# Cost in iteration 1000: 0.018140615245513636
# Final cost : 0.018140615245513636
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.021009444418038363
# Cost in iteration 200: 0.020368039084833183
# Final cost : 0.020368039084833183
# Compute control for a deterministic system
# Cost in iteration 0: 0.020368039084833183
# Cost in iteration 200: 0.020366797207292762
# Final cost : 0.020366797207292762
# Compute control for a deterministic system
# Cost in iteration 0: 0.020366797207292762
# Cost in iteration 200: 0.020366325938642724
# Final cost : 0.020366325938642724
# Compute control for a deterministic system
# Cost in iteration 0: 0.020366325938642724
# Cost in iteration 200: 0.0203659706016777
# Cost in iteration 400: 0.020365714060207814
# Final cost : 0.020365714060207814
# Compute control for a deterministic system
# Cost in iteration 0: 0.020365714060207814
# Cost in iteration 200: 0.02036553171461279
# Cost in iteration 400: 0.02036539695947216
# Cost in iteration 600: 0.02036530255223311
# Cost in iteration 800: 0.0203652369897902
# Cost in iteration 1000: 0.020365191541508475
# Final cost : 0.020365191541508475
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.0234314820237429
# Cost in iteration 200: 0.02268501973097702
# Final cost : 0.02268501973097702
# Compute control for a deterministic system
# Cost in iteration 0: 0.02268501973097702
# Cost in iteration 200: 0.022683758867993765
# Final cost : 0.022683758867993765
# Compute control for a deterministic system
# Cost in iteration 0: 0.022683758867993765
# Cost in iteration 200: 0.022683279110740934
# Final cost : 0.022683279110740934
# Compute control for a deterministic system
# Cost in iteration 0: 0.022683279110740934
# Cost in iteration 200: 0.02268283341167374
# Cost in iteration 400: 0.022682551978461744
# Final cost : 0.022682551978461744
# Compute control for a deterministic system
# Cost in iteration 0: 0.022682551978461744
# Cost in iteration 200: 0.022682364573048508
# Cost in iteration 400: 0.02268222183512937
# Cost in iteration 600: 0.02268212040238571
# Cost in iteration 800: 0.022682043778465902
# Cost in iteration 1000: 0.02268198746323846
# Final cost : 0.02268198746323846
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.02587047318617017
# Cost in iteration 200: 0.025127469147134675
# Final cost : 0.025127469147134675
# Compute control for a deterministic system
# Cost in iteration 0: 0.025127469147134675
# Cost in iteration 200: 0.025125387563040724
# Final cost : 0.025125387563040724
# Compute control for a deterministic system
# Cost in iteration 0: 0.025125387563040724
# Cost in iteration 200: 0.025124480601667738
# Final cost : 0.025124480601667738
# Compute control for a deterministic system
# Cost in iteration 0: 0.025124480601667738
# Cost in iteration 200: 0.025123831826965416
# Cost in iteration 400: 0.025123337449653296
# Final cost : 0.025123337449653296
# Compute control for a deterministic system
# Cost in iteration 0: 0.025123337449653296
# Cost in iteration 200: 0.025122868280454562
# Cost in iteration 400: 0.025122514716631825
# Cost in iteration 600: 0.025122252672255273
# Cost in iteration 800: 0.025122057247390025
# Cost in iteration 1000: 0.025121936502327524
# Final cost : 0.025121936502327524
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.02843553734689577
# Cost in iteration 200: 0.027566403345659903
# Final cost : 0.027566403345659903
# Compute control for a deterministic system
# Cost in iteration 0: 0.027566403345659903
# Cost in iteration 200: 0.0275652015518462
# Final cost : 0.0275652015518462
# Compute control for a deterministic system
# Cost in iteration 0: 0.0275652015518462
# Cost in iteration 200: 0.02756477638477602
# Final cost : 0.02756477638477602
# Compute control for a deterministic system
# Cost in iteration 0: 0.02756477638477602
# Cost in iteration 200: 0.027564488168212577
# Cost in iteration 400: 0.027564265311026355
# Final cost : 0.027564265311026355
# Compute control for a deterministic system
# Cost in iteration 0: 0.027564265311026355
# Cost in iteration 200: 0.027564081506279224
# Cost in iteration 400: 0.027563933365374455
# Cost in iteration 600: 0.027563823690703815
# Cost in iteration 800: 0.027563735903336807
# Cost in iteration 1000: 0.027563670826432244
# Final cost : 0.027563670826432244
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.030944975208008707
# Cost in iteration 200: 0.030070866364997822
# Final cost : 0.030070866364997822
# Compute control for a deterministic system
# Cost in iteration 0: 0.030070866364997822
# Cost in iteration 200: 0.030068035454008296
# Final cost : 0.030068035454008296
# Compute control for a deterministic system
# Cost in iteration 0: 0.030068035454008296
# Cost in iteration 200: 0.030066647457393132
# Final cost : 0.030066647457393132
# Compute control for a deterministic system
# Cost in iteration 0: 0.030066647457393132
# Cost in iteration 200: 0.030065474794628854
# Cost in iteration 400: 0.030064505357910117
# Final cost : 0.030064505357910117
# Compute control for a deterministic system
# Cost in iteration 0: 0.030064505357910117
# Cost in iteration 200: 0.030063737569433303
# Cost in iteration 400: 0.030063211181271234
# Cost in iteration 600: 0.030062778616741302
# Cost in iteration 800: 0.03006245423067879
# Cost in iteration 1000: 0.03006218867014008
# Final cost : 0.03006218867014008
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.02793478229909647
# Cost in iteration 200: 0.02716976659185228
# Final cost : 0.02716976659185228
# Compute control for a deterministic system
# Cost in iteration 0: 0.02716976659185228
# Cost in iteration 200: 0.027167867815145953
# Final cost : 0.027167867815145953
# Compute control for a deterministic system
# Cost in iteration 0: 0.027167867815145953
# Cost in iteration 200: 0.027167575541271975
# Final cost : 0.027167575541271975
# Compute control for a deterministic system
# Cost in iteration 0: 0.027167575541271975
# Cost in iteration 200: 0.027167415016076023
# Cost in iteration 400: 0.027167309006614515
# Final cost : 0.027167309006614515
# Compute control for a deterministic system
# Cost in iteration 0: 0.027167309006614515
# Cost in iteration 200: 0.02716723356073921
# Cost in iteration 400: 0.027167185065558052
# Cost in iteration 600: 0.027167151495756856
# Cost in iteration 800: 0.027167127637920875
# Cost in iteration 1000: 0.027167111549397115
# Final cost : 0.027167111549397115
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.024734129296295496
# Cost in iteration 200: 0.02406663234776901
# Final cost : 0.02406663234776901
# Compute control for a deterministic system
# Cost in iteration 0: 0.02406663234776901
# Cost in iteration 200: 0.02406504711299991
# Final cost : 0.02406504711299991
# Compute control for a deterministic system
# Cost in iteration 0: 0.02406504711299991
# Cost in iteration 200: 0.024064957539177912
# Final cost : 0.024064957539177912
# Compute control for a deterministic system
# Cost in iteration 0: 0.024064957539177912
# Cost in iteration 200: 0.024064915472056508
# Cost in iteration 400: 0.024064888753518
# Final cost : 0.024064888753518
# Compute control for a deterministic system
# Cost in iteration 0: 0.024064888753518
# Cost in iteration 200: 0.024064870212829305
# Cost in iteration 400: 0.024064860057303912
# Cost in iteration 600: 0.024064853172000324
# Cost in iteration 800: 0.024064848486908694
# Cost in iteration 1000: 0.02406484530063745
# Final cost : 0.02406484530063745
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.02172342537407967
# Cost in iteration 200: 0.021185124868213168
# Final cost : 0.021185124868213168
# Compute control for a deterministic system
# Cost in iteration 0: 0.021185124868213168
# Cost in iteration 200: 0.021183057650092152
# Final cost : 0.021183057650092152
# Compute control for a deterministic system
# Cost in iteration 0: 0.021183057650092152
# Cost in iteration 200: 0.021182809899271446
# Final cost : 0.021182809899271446
# Compute control for a deterministic system
# Cost in iteration 0: 0.021182809899271446
# Cost in iteration 200: 0.021182671420813204
# Cost in iteration 400: 0.021182589082289927
# Final cost : 0.021182589082289927
# Compute control for a deterministic system
# Cost in iteration 0: 0.021182589082289927
# Cost in iteration 200: 0.021182537646035934
# Cost in iteration 400: 0.02118250379918052
# Cost in iteration 600: 0.02118248156907444
# Cost in iteration 800: 0.021182466962116463
# Cost in iteration 1000: 0.02118245734097897
# Final cost : 0.02118245734097897
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.018936986431933686
# Cost in iteration 200: 0.018499754136599184
# Final cost : 0.018499754136599184
# Compute control for a deterministic system
# Cost in iteration 0: 0.018499754136599184
# Cost in iteration 200: 0.018497646538134706
# Final cost : 0.018497646538134706
# Compute control for a deterministic system
# Cost in iteration 0: 0.018497646538134706
# Cost in iteration 200: 0.018497487390875512
# Final cost : 0.018497487390875512
# Compute control for a deterministic system
# Cost in iteration 0: 0.018497487390875512
# Cost in iteration 200: 0.01849741156620776
# Cost in iteration 400: 0.018497365859008734
# Final cost : 0.018497365859008734
# Compute control for a deterministic system
# Cost in iteration 0: 0.018497365859008734
# Cost in iteration 200: 0.018497339593689335
# Cost in iteration 400: 0.018497322998085357
# Cost in iteration 600: 0.018497312530798293
# Cost in iteration 800: 0.018497305494979698
# Cost in iteration 1000: 0.0184973007415199
# Final cost : 0.0184973007415199
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.016355329484666347
# Cost in iteration 200: 0.016006097121706683
# Final cost : 0.016006097121706683
# Compute control for a deterministic system
# Cost in iteration 0: 0.016006097121706683
# Cost in iteration 200: 0.016003804878328337
# Final cost : 0.016003804878328337
# Compute control for a deterministic system
# Cost in iteration 0: 0.016003804878328337
# Cost in iteration 200: 0.016003673775914825
# Final cost : 0.016003673775914825
# Compute control for a deterministic system
# Cost in iteration 0: 0.016003673775914825
# Cost in iteration 200: 0.01600362524361473
# Cost in iteration 400: 0.016003597696084414
# Final cost : 0.016003597696084414
# Compute control for a deterministic system
# Cost in iteration 0: 0.016003597696084414
# Cost in iteration 200: 0.016003580776628272
# Cost in iteration 400: 0.01600357088687217
# Cost in iteration 600: 0.016003565425489984
# Cost in iteration 800: 0.016003562374435194
# Cost in iteration 1000: 0.016003560622187583
# Final cost : 0.016003560622187583
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.013931477656612302
# Cost in iteration 200: 0.013657336146622278
# Final cost : 0.013657336146622278
# Compute control for a deterministic system
# Cost in iteration 0: 0.013657336146622278
# Cost in iteration 200: 0.01365487034423254
# Final cost : 0.01365487034423254
# Compute control for a deterministic system
# Cost in iteration 0: 0.01365487034423254
# Cost in iteration 200: 0.013654766359698848
# Final cost : 0.013654766359698848
# Compute control for a deterministic system
# Cost in iteration 0: 0.013654766359698848
# Cost in iteration 200: 0.013654730341594767
# Cost in iteration 400: 0.013654708739215867
# Final cost : 0.013654708739215867
# Compute control for a deterministic system
# Cost in iteration 0: 0.013654708739215867
# Cost in iteration 200: 0.013654699788309925
# Cost in iteration 400: 0.01365469566199455
# Cost in iteration 600: 0.013654693252019498
# Cost in iteration 800: 0.013654691839867198
# Cost in iteration 1000: 0.01365469101670003
# Final cost : 0.01365469101670003
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.01176702602841073
# Cost in iteration 200: 0.011553918221144053
# Final cost : 0.011553918221144053
# Compute control for a deterministic system
# Cost in iteration 0: 0.011553918221144053
# Cost in iteration 200: 0.01155139921883389
# Final cost : 0.01155139921883389
# Compute control for a deterministic system
# Cost in iteration 0: 0.01155139921883389
# Cost in iteration 200: 0.01155132994155226
# Final cost : 0.01155132994155226
# Compute control for a deterministic system
# Cost in iteration 0: 0.01155132994155226
# Cost in iteration 200: 0.011551313923557849
# Cost in iteration 400: 0.011551305960993739
# Final cost : 0.011551305960993739
# Compute control for a deterministic system
# Cost in iteration 0: 0.011551305960993739
# Cost in iteration 200: 0.011551302842011637
# Cost in iteration 400: 0.01155130184739298
# Cost in iteration 600: 0.011551301293641595
# Cost in iteration 800: 0.01155130098992548
# Cost in iteration 1000: 0.011551300821023356
# Final cost : 0.011551300821023356
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.009806671454221936
# Cost in iteration 200: 0.009642076090511122
# Final cost : 0.009642076090511122
# Compute control for a deterministic system
# Cost in iteration 0: 0.009642076090511122
# Cost in iteration 200: 0.009639561093125942
# Final cost : 0.009639561093125942
# Compute control for a deterministic system
# Cost in iteration 0: 0.009639561093125942
# Cost in iteration 200: 0.00963950796071593
# Final cost : 0.00963950796071593
# Compute control for a deterministic system
# Cost in iteration 0: 0.00963950796071593
# Cost in iteration 200: 0.009639499040862837
# Cost in iteration 400: 0.00963949523222654
# Final cost : 0.00963949523222654
# Compute control for a deterministic system
# Cost in iteration 0: 0.00963949523222654
# Cost in iteration 200: 0.00963949412198286
# Cost in iteration 400: 0.009639493767568206
# Cost in iteration 600: 0.009639493582306232
# Cost in iteration 800: 0.009639493484848834
# Cost in iteration 1000: 0.009639493432958371
# Final cost : 0.009639493432958371
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.008044450297071693
# Cost in iteration 200: 0.007917867162837334
# Final cost : 0.007917867162837334
# Compute control for a deterministic system
# Cost in iteration 0: 0.007917867162837334
# Cost in iteration 200: 0.007915483582792197
# Final cost : 0.007915483582792197
# Compute control for a deterministic system
# Cost in iteration 0: 0.007915483582792197
# Cost in iteration 200: 0.007915436601386166
# Final cost : 0.007915436601386166
# Compute control for a deterministic system
# Cost in iteration 0: 0.007915436601386166
# Cost in iteration 200: 0.00791543237426542
# Cost in iteration 400: 0.007915431206847278
# Final cost : 0.007915431206847278
# Compute control for a deterministic system
# Cost in iteration 0: 0.007915431206847278
# Cost in iteration 200: 0.007915430768192021
# Cost in iteration 400: 0.007915430550921969
# Cost in iteration 600: 0.00791543044286998
# Cost in iteration 800: 0.007915430388883045
# Cost in iteration 1000: 0.007915430361921903
# Final cost : 0.007915430361921903
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.006472476829000568
# Cost in iteration 200: 0.006376351018598642
# Final cost : 0.006376351018598642
# Compute control for a deterministic system
# Cost in iteration 0: 0.006376351018598642
# Cost in iteration 200: 0.006374188647438623
# Final cost : 0.006374188647438623
# Compute control for a deterministic system
# Cost in iteration 0: 0.006374188647438623
# Cost in iteration 200: 0.006374147147908826
# Final cost : 0.006374147147908826
# Compute control for a deterministic system
# Cost in iteration 0: 0.006374147147908826
# Cost in iteration 200: 0.006374144151422146
# Cost in iteration 400: 0.006374143613806161
# Final cost : 0.006374143613806161
# Compute control for a deterministic system
# Cost in iteration 0: 0.006374143613806161
# Cost in iteration 200: 0.006374143446485909
# Cost in iteration 400: 0.00637414337039414
# Cost in iteration 600: 0.006374143334843999
# Cost in iteration 800: 0.006374143318326011
# Cost in iteration 1000: 0.006374143310604263
# Final cost : 0.006374143310604263
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.00508425067887021
# Cost in iteration 200: 0.005012239652391644
# Final cost : 0.005012239652391644
# Compute control for a deterministic system
# Cost in iteration 0: 0.005012239652391644
# Cost in iteration 200: 0.005010374590574525
# Final cost : 0.005010374590574525
# Compute control for a deterministic system
# Cost in iteration 0: 0.005010374590574525
# Cost in iteration 200: 0.005010340308077442
# Final cost : 0.005010340308077442
# Compute control for a deterministic system
# Cost in iteration 0: 0.005010340308077442
# Cost in iteration 200: 0.0050103385070768905
# Cost in iteration 400: 0.0050103383501814095
# Final cost : 0.0050103383501814095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050103383501814095
# Cost in iteration 200: 0.005010338317511717
# Cost in iteration 400: 0.005010338304826693
# Cost in iteration 600: 0.005010338299522233
# Cost in iteration 800: 0.005010338297250475
# Cost in iteration 1000: 0.005010338296270704
# Final cost : 0.005010338296270704
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038736441419826707
# Cost in iteration 200: 0.003820511569079411
# Final cost : 0.003820511569079411
# Compute control for a deterministic system
# Cost in iteration 0: 0.003820511569079411
# Cost in iteration 200: 0.0038189857200672138
# Final cost : 0.0038189857200672138
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038189857200672138
# Cost in iteration 200: 0.0038189556203535504
# Final cost : 0.0038189556203535504
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038189556203535504
# Cost in iteration 200: 0.003818953847955422
# Cost in iteration 400: 0.003818953673752854
# Final cost : 0.003818953673752854
# Compute control for a deterministic system
# Cost in iteration 0: 0.003818953673752854
# Cost in iteration 200: 0.003818953652537034
# Cost in iteration 400: 0.0038189536471059933
# Cost in iteration 600: 0.0038189536450001418
# Cost in iteration 800: 0.0038189536441770814
# Cost in iteration 1000: 0.003818953643858087
# Final cost : 0.003818953643858087
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.002813596747972772
# Cost in iteration 200: 0.0027762426290616083
# Final cost : 0.0027762426290616083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027762426290616083
# Cost in iteration 200: 0.0027750703808766715
# Final cost : 0.0027750703808766715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027750703808766715
# Cost in iteration 200: 0.0027750481711334178
# Final cost : 0.0027750481711334178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027750481711334178
# Cost in iteration 200: 0.00277504710470233
# Cost in iteration 400: 0.002775047047812182
# Final cost : 0.002775047047812182
# Compute control for a deterministic system
# Cost in iteration 0: 0.002775047047812182
# Cost in iteration 200: 0.002775047043234019
# Cost in iteration 400: 0.002775047042527957
# Cost in iteration 600: 0.0027750470423633885
# Converged in iteration 729 with cost 0.002775047042314856 because of step counter
# Final cost : 0.002775047042314856
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.001945304598791972
# Cost in iteration 200: 0.0019199467174361325
# Final cost : 0.0019199467174361325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019199467174361325
# Cost in iteration 200: 0.0019191025319678218
# Final cost : 0.0019191025319678218
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019191025319678218
# Cost in iteration 200: 0.0019190883707254805
# Final cost : 0.0019190883707254805
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019190883707254805
# Cost in iteration 200: 0.0019190877356854781
# Cost in iteration 400: 0.0019190876986560172
# Final cost : 0.0019190876986560172
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019190876986560172
# Cost in iteration 200: 0.001919087695100298
# Cost in iteration 400: 0.001919087694426289
# Cost in iteration 600: 0.0019190876942486864
# Converged in iteration 688 with cost 0.0019190876942034554 because of step counter
# Final cost : 0.0019190876942034554
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012403162821759321
# Cost in iteration 200: 0.001224356130066288
# Final cost : 0.001224356130066288
# Compute control for a deterministic system
# Cost in iteration 0: 0.001224356130066288
# Cost in iteration 200: 0.001223804737369003
# Final cost : 0.001223804737369003
# Compute control for a deterministic system
# Cost in iteration 0: 0.001223804737369003
# Cost in iteration 200: 0.0012237944994559309
# Final cost : 0.0012237944994559309
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012237944994559309
# Cost in iteration 200: 0.0012237940059219542
# Cost in iteration 400: 0.0012237939795439867
# Final cost : 0.0012237939795439867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012237939795439867
# Cost in iteration 200: 0.001223793977624946
# Cost in iteration 400: 0.0012237939773980311
# Converged in iteration 499 with cost 0.001223793977365149 because of step counter
# Final cost : 0.001223793977365149
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006956460928725497
# Cost in iteration 200: 0.0006867468642778639
# Final cost : 0.0006867468642778639
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006867468642778639
# Cost in iteration 200: 0.0006864325945863302
# Final cost : 0.0006864325945863302
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006864325945863302
# Cost in iteration 200: 0.0006864269297412736
# Final cost : 0.0006864269297412736
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006864269297412736
# Cost in iteration 200: 0.0006864267032529515
# Cost in iteration 400: 0.0006864266896576057
# Final cost : 0.0006864266896576057
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006864266896576057
# Cost in iteration 200: 0.0006864266885442113
# Cost in iteration 400: 0.0006864266884118286
# Converged in iteration 477 with cost 0.0006864266883937637 because of step counter
# Final cost : 0.0006864266883937637
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003087501128241122
# Cost in iteration 200: 0.00030479996201165525
# Final cost : 0.00030479996201165525
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030479996201165525
# Cost in iteration 200: 0.0003046599571872505
# Final cost : 0.0003046599571872505
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003046599571872505
# Cost in iteration 200: 0.00030465709593639946
# Final cost : 0.00030465709593639946
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030465709593639946
# Cost in iteration 200: 0.0003046569639217515
# Cost in iteration 400: 0.0003046569563737628
# Final cost : 0.0003046569563737628
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003046569563737628
# Cost in iteration 200: 0.00030465695576605863
# Converged in iteration 385 with cost 0.00030465695570958015 because of step counter
# Final cost : 0.00030465695570958015
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 7.749064977040144e-05
# Cost in iteration 200: 7.649263485497176e-05
# Final cost : 7.649263485497176e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.649263485497176e-05
# Cost in iteration 200: 7.645757646514182e-05
# Final cost : 7.645757646514182e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.645757646514182e-05
# Cost in iteration 200: 7.64568359154719e-05
# Final cost : 7.64568359154719e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.64568359154719e-05
# Cost in iteration 200: 7.645680429273032e-05
# Cost in iteration 400: 7.64568019867033e-05
# Final cost : 7.64568019867033e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.64568019867033e-05
# Cost in iteration 200: 7.645680176595602e-05
# Cost in iteration 400: 7.645680173640024e-05
# Converged in iteration 457 with cost 7.645680173207977e-05 because of step counter
# Final cost : 7.645680173207977e-05
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
