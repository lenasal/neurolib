# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, ish, w1):
    results_dict["control"][ish] = wc_controlled.control.copy()
    results_dict["state"][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1T = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][ish] = ( results_dict["total_cost"][ish] - results_dict["precision_cost"][ish]) 
    results_dict["L1_cost_unweighted"][ish] = results_dict["L1_cost_weighted"][ish] / w1
    wc_controlled.w_1T = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1T=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][ish]) != type(None):
        wc_controlled.control = results_dict["control"][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [1.]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L1_cost_unweighted", [None] * n_points),
    ("L1_cost_weighted", [None] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ])

# %%
import IPython
filename = IPython.extract_module_locals()[1]['__vsc_ipynb_file__'].split("/")[-1][:-6]
print(filename)

def save(results_dict):
    filehandler = open((filename + ".pickle"),"wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open((filename + ".pickle"),"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict
# Out:
# a_s2_l1t

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 results_min = read()
#
# Cell In [23], line 11, in read()
#      10 def read():
# ---> 11     filehandler = open((filename + ".pickle"),"rb")
#      12     results_dict = pickle.load(filehandler)
#      13     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s2_l1t.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [False, False, False, False]

for k in range(1):

    w1 = results_min['w1'][0]

    for i_shift in range(n_points):
        
        if type(results_min["control"][i_shift]) != type(None):
            continue

        period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

        wc_controlled = getmodel(target_shift, w1, results_min, i_shift)

        wc_controlled.step = 1e-3
        wc_controlled.optimize(100)

        if i_shift in [0, n_points-1]:
            get_values(results_min, i_shift, w1)
            continue

        increase_step_compute()
        get_values(results_min, i_shift, w1)

    save(results_min)

    if options[0]:
        print("----------------------------------------------- 0")
        for i_shift in range(2, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_shift)
            
            factor = (0.95+np.random.random()*0.1)
            
            wc_controlled.control = results_min["control"][i_shift-1].copy() * factor
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("0 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    if options[1]:
        print("----------------------------------------------- 1")
        for i_shift in range(n_points-3, 0, -1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_shift)

            factor = (0.95+np.random.random()*0.1)
            
            wc_controlled.control = results_min["control"][i_shift+1].copy() * factor
            wc_controlled.update_input()
            wc_controlled.simulate_forward()

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("1 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    if options[2]:
        print("----------------------------------------------- 4")
        for i_shift in range(1, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
            
            wc_controlled.control = results_min["control"][i_shift].copy() * (0.95+np.random.random()*0.1)
            wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("4 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    if options[3]:
        print("----------------------------------------------- 5")
        for i_shift in range(1, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
            
            wc_controlled.control = results_min["control"][i_shift].copy() * (0.95+np.random.random()*0.1)
            wc_controlled.control[0,1,:] = 0.
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("5 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)
                
        save(results_min)

    save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.04146970119814645
# Final cost : 0.013756410533438101
# Compute control for a deterministic system
# Cost in iteration 0: 0.013756410533438101
# Converged in iteration 1 with cost 0.013756410533438101 because of step counter
# Final cost : 0.013756410533438101
# Compute control for a deterministic system
# Cost in iteration 0: 0.013756410533438101
# Converged in iteration 1 with cost 0.013756410533438101 because of step counter
# Final cost : 0.013756410533438101
# Compute control for a deterministic system
# Cost in iteration 0: 0.013756410533438101
# Converged in iteration 1 with cost 0.013756410533438101 because of step counter
# Final cost : 0.013756410533438101
# Compute control for a deterministic system
# Cost in iteration 0: 0.013756410533438101
# Converged in iteration 1 with cost 0.013756410533438101 because of step counter
# Final cost : 0.013756410533438101
# Compute control for a deterministic system
# Cost in iteration 0: 0.13111330368504498
# Final cost : 0.025967474932644726
# Compute control for a deterministic system
# Cost in iteration 0: 0.025967474932644726
# Converged in iteration 15 with cost 0.025967431142267267 because of vanishing difference
# Final cost : 0.025967431142267267
# Compute control for a deterministic system
# Cost in iteration 0: 0.025967431142267267
# Converged in iteration 1 with cost 0.025967431142267267 because of step counter
# Final cost : 0.025967431142267267
# Compute control for a deterministic system
# Cost in iteration 0: 0.025967431142267267
# Converged in iteration 1 with cost 0.025967431142267267 because of step counter
# Final cost : 0.025967431142267267
# Compute control for a deterministic system
# Cost in iteration 0: 0.025967431142267267
# Converged in iteration 1 with cost 0.025967431142267267 because of step counter
# Final cost : 0.025967431142267267
# Compute control for a deterministic system
# Cost in iteration 0: 0.30228811979969555
# Final cost : 0.041287440070115915
# Compute control for a deterministic system
# Cost in iteration 0: 0.041287440070115915
# Converged in iteration 19 with cost 0.0412872292657236 because of vanishing difference
# Final cost : 0.0412872292657236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412872292657236
# Converged in iteration 1 with cost 0.0412872292657236 because of step counter
# Final cost : 0.0412872292657236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412872292657236
# Converged in iteration 1 with cost 0.0412872292657236 because of step counter
# Final cost : 0.0412872292657236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412872292657236
# Converged in iteration 1 with cost 0.0412872292657236 because of step counter
# Final cost : 0.0412872292657236
# Compute control for a deterministic system
# Cost in iteration 0: 0.5215525460753447
# Final cost : 0.05688638608903122
# Compute control for a deterministic system
# Cost in iteration 0: 0.05688638608903122
# Converged in iteration 57 with cost 0.056879788375002495 because of vanishing difference
# Final cost : 0.056879788375002495
# Compute control for a deterministic system
# Cost in iteration 0: 0.056879788375002495
# Converged in iteration 1 with cost 0.056879788375002495 because of step counter
# Final cost : 0.056879788375002495
# Compute control for a deterministic system
# Cost in iteration 0: 0.056879788375002495
# Converged in iteration 1 with cost 0.056879788375002495 because of step counter
# Final cost : 0.056879788375002495
# Compute control for a deterministic system
# Cost in iteration 0: 0.056879788375002495
# Converged in iteration 1 with cost 0.056879788375002495 because of step counter
# Final cost : 0.056879788375002495
# Compute control for a deterministic system
# Cost in iteration 0: 0.7691267485404539
# Final cost : 0.07289659231939208
# Compute control for a deterministic system
# Cost in iteration 0: 0.07289659231939208
# Converged in iteration 59 with cost 0.07286446758370546 because of vanishing difference
# Final cost : 0.07286446758370546
# Compute control for a deterministic system
# Cost in iteration 0: 0.07286446758370546
# Converged in iteration 1 with cost 0.07286446758370546 because of step counter
# Final cost : 0.07286446758370546
# Compute control for a deterministic system
# Cost in iteration 0: 0.07286446758370546
# Converged in iteration 1 with cost 0.07286446758370546 because of step counter
# Final cost : 0.07286446758370546
# Compute control for a deterministic system
# Cost in iteration 0: 0.07286446758370546
# Converged in iteration 1 with cost 0.07286446758370546 because of step counter
# Final cost : 0.07286446758370546
# Compute control for a deterministic system
# Cost in iteration 0: 0.9761558110765247
# Final cost : 0.08608929592576237
# Compute control for a deterministic system
# Cost in iteration 0: 0.08608929592576237
# Converged in iteration 117 with cost 0.08555336403205999 because of vanishing difference
# Final cost : 0.08555336403205999
# Compute control for a deterministic system
# Cost in iteration 0: 0.08555336403205999
# Converged in iteration 1 with cost 0.08555336403205999 because of step counter
# Final cost : 0.08555336403205999
# Compute control for a deterministic system
# Cost in iteration 0: 0.08555336403205999
# Converged in iteration 1 with cost 0.08555336403205999 because of step counter
# Final cost : 0.08555336403205999
# Compute control for a deterministic system
# Cost in iteration 0: 0.08555336403205999
# Converged in iteration 1 with cost 0.08555336403205999 because of step counter
# Final cost : 0.08555336403205999
# Compute control for a deterministic system
# Cost in iteration 0: 1.2362276008726105
# Final cost : 0.10305609290711486
# Compute control for a deterministic system
# Cost in iteration 0: 0.10305609290711486
# Converged in iteration 197 with cost 0.1013877461540158 because of vanishing difference
# Final cost : 0.1013877461540158
# Compute control for a deterministic system
# Cost in iteration 0: 0.1013877461540158
# Converged in iteration 1 with cost 0.1013877461540158 because of step counter
# Final cost : 0.1013877461540158
# Compute control for a deterministic system
# Cost in iteration 0: 0.1013877461540158
# Converged in iteration 1 with cost 0.1013877461540158 because of step counter
# Final cost : 0.1013877461540158
# Compute control for a deterministic system
# Cost in iteration 0: 0.1013877461540158
# Converged in iteration 1 with cost 0.1013877461540158 because of step counter
# Final cost : 0.1013877461540158
# Compute control for a deterministic system
# Cost in iteration 0: 1.4910319774227965
# Final cost : 0.1208643413002288
# Compute control for a deterministic system
# Cost in iteration 0: 0.1208643413002288
# Cost in iteration 200: 0.11684790931180503
# Final cost : 0.11684790931180503
# Compute control for a deterministic system
# Cost in iteration 0: 0.11684790931180503
# Converged in iteration 37 with cost 0.11684665998832518 because of vanishing difference
# Final cost : 0.11684665998832518
# Compute control for a deterministic system
# Cost in iteration 0: 0.11684665998832518
# Converged in iteration 1 with cost 0.11684665998832518 because of step counter
# Final cost : 0.11684665998832518
# Compute control for a deterministic system
# Cost in iteration 0: 0.11684665998832518
# Converged in iteration 1 with cost 0.11684665998832518 because of step counter
# Final cost : 0.11684665998832518
# Compute control for a deterministic system
# Cost in iteration 0: 1.7355221749515761
# Final cost : 0.13975426788041714
# Compute control for a deterministic system
# Cost in iteration 0: 0.13975426788041714
# Cost in iteration 200: 0.13274676208391714
# Final cost : 0.13274676208391714
# Compute control for a deterministic system
# Cost in iteration 0: 0.13274676208391714
# Converged in iteration 74 with cost 0.13259394017613188 because of vanishing difference
# Final cost : 0.13259394017613188
# Compute control for a deterministic system
# Cost in iteration 0: 0.13259394017613188
# Converged in iteration 1 with cost 0.13259394017613188 because of step counter
# Final cost : 0.13259394017613188
# Compute control for a deterministic system
# Cost in iteration 0: 0.13259394017613188
# Converged in iteration 1 with cost 0.13259394017613188 because of step counter
# Final cost : 0.13259394017613188
# Compute control for a deterministic system
# Cost in iteration 0: 1.920463700763563
# Final cost : 0.1558775476231357
# Compute control for a deterministic system
# Cost in iteration 0: 0.1558775476231357
# Cost in iteration 200: 0.1460142931670579
# Final cost : 0.1460142931670579
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460142931670579
# Converged in iteration 18 with cost 0.1460122552163154 because of vanishing difference
# Final cost : 0.1460122552163154
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460122552163154
# Converged in iteration 1 with cost 0.1460122552163154 because of step counter
# Final cost : 0.1460122552163154
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460122552163154
# Converged in iteration 1 with cost 0.1460122552163154 because of step counter
# Final cost : 0.1460122552163154
# Compute control for a deterministic system
# Cost in iteration 0: 2.1339901967980874
# Final cost : 0.17756755055531337
# Compute control for a deterministic system
# Cost in iteration 0: 0.17756755055531337
# Cost in iteration 200: 0.1624724941638451
# Final cost : 0.1624724941638451
# Compute control for a deterministic system
# Cost in iteration 0: 0.1624724941638451
# Cost in iteration 200: 0.16235998631298712
# Final cost : 0.16235998631298712
# Compute control for a deterministic system
# Cost in iteration 0: 0.16235998631298712
# Cost in iteration 200: 0.1618474776128667
# Converged in iteration 280 with cost 0.16184462521109266 because of step counter
# Final cost : 0.16184462521109266
# Compute control for a deterministic system
# Cost in iteration 0: 0.16184462521109266
# Converged in iteration 1 with cost 0.16184462521109266 because of step counter
# Final cost : 0.16184462521109266
# Compute control for a deterministic system
# Cost in iteration 0: 2.3236263507684765
# Final cost : 0.20143404850821747
# Compute control for a deterministic system
# Cost in iteration 0: 0.20143404850821747
# Cost in iteration 200: 0.18011799089261452
# Final cost : 0.18011799089261452
# Compute control for a deterministic system
# Cost in iteration 0: 0.18011799089261452
# Cost in iteration 200: 0.1799806100381608
# Final cost : 0.1799806100381608
# Compute control for a deterministic system
# Cost in iteration 0: 0.1799806100381608
# Converged in iteration 2 with cost 0.1799800652570179 because of vanishing difference
# Final cost : 0.1799800652570179
# Compute control for a deterministic system
# Cost in iteration 0: 0.1799800652570179
# Converged in iteration 1 with cost 0.1799800652570179 because of step counter
# Final cost : 0.1799800652570179
# Compute control for a deterministic system
# Cost in iteration 0: 2.4562383366284295
# Final cost : 0.2225119809198802
# Compute control for a deterministic system
# Cost in iteration 0: 0.2225119809198802
# Cost in iteration 200: 0.19269719518761041
# Final cost : 0.19269719518761041
# Compute control for a deterministic system
# Cost in iteration 0: 0.19269719518761041
# Cost in iteration 200: 0.19202999570614285
# Final cost : 0.19202999570614285
# Compute control for a deterministic system
# Cost in iteration 0: 0.19202999570614285
# Converged in iteration 137 with cost 0.19110618205918842 because of step counter
# Final cost : 0.19110618205918842
# Compute control for a deterministic system
# Cost in iteration 0: 0.19110618205918842
# Converged in iteration 1 with cost 0.19110618205918842 because of step counter
# Final cost : 0.19110618205918842
# Compute control for a deterministic system
# Cost in iteration 0: 2.597506123617889
# Final cost : 0.2522160528736218
# Compute control for a deterministic system
# Cost in iteration 0: 0.2522160528736218
# Cost in iteration 200: 0.20692323389618178
# Final cost : 0.20692323389618178
# Compute control for a deterministic system
# Cost in iteration 0: 0.20692323389618178
# Converged in iteration 9 with cost 0.20692281639740906 because of vanishing difference
# Final cost : 0.20692281639740906
# Compute control for a deterministic system
# Cost in iteration 0: 0.20692281639740906
# Converged in iteration 1 with cost 0.20692281639740906 because of step counter
# Final cost : 0.20692281639740906
# Compute control for a deterministic system
# Cost in iteration 0: 0.20692281639740906
# Converged in iteration 1 with cost 0.20692281639740906 because of step counter
# Final cost : 0.20692281639740906
# Compute control for a deterministic system
# Cost in iteration 0: 2.7121413917345705
# Final cost : 0.2870151181170973
# Compute control for a deterministic system
# Cost in iteration 0: 0.2870151181170973
# Cost in iteration 200: 0.22205211219396553
# Final cost : 0.22205211219396553
# Compute control for a deterministic system
# Cost in iteration 0: 0.22205211219396553
# Converged in iteration 131 with cost 0.2220422525488204 because of vanishing difference
# Final cost : 0.2220422525488204
# Compute control for a deterministic system
# Cost in iteration 0: 0.2220422525488204
# Converged in iteration 1 with cost 0.2220422525488204 because of step counter
# Final cost : 0.2220422525488204
# Compute control for a deterministic system
# Cost in iteration 0: 0.2220422525488204
# Converged in iteration 1 with cost 0.2220422525488204 because of step counter
# Final cost : 0.2220422525488204
# Compute control for a deterministic system
# Cost in iteration 0: 2.8011534914450498
# Final cost : 0.3296022260236724
# Compute control for a deterministic system
# Cost in iteration 0: 0.3296022260236724
# Converged in iteration 171 with cost 0.2413306541133307 because of vanishing difference
# Final cost : 0.2413306541133307
# Compute control for a deterministic system
# Cost in iteration 0: 0.2413306541133307
# Cost in iteration 200: 0.2403432229675591
# Final cost : 0.2403432229675591
# Compute control for a deterministic system
# Cost in iteration 0: 0.2403432229675591
# Converged in iteration 34 with cost 0.24034273171577064 because of step counter
# Final cost : 0.24034273171577064
# Compute control for a deterministic system
# Cost in iteration 0: 0.24034273171577064
# Converged in iteration 1 with cost 0.24034273171577064 because of step counter
# Final cost : 0.24034273171577064
# Compute control for a deterministic system
# Cost in iteration 0: 2.854347316887494
# Final cost : 0.37292727701052214
# Compute control for a deterministic system
# Cost in iteration 0: 0.37292727701052214
# Cost in iteration 200: 0.25300793409223143
# Final cost : 0.25300793409223143
# Compute control for a deterministic system
# Cost in iteration 0: 0.25300793409223143
# Converged in iteration 98 with cost 0.25283187930691303 because of vanishing difference
# Final cost : 0.25283187930691303
# Compute control for a deterministic system
# Cost in iteration 0: 0.25283187930691303
# Converged in iteration 64 with cost 0.25283001316981585 because of step counter
# Final cost : 0.25283001316981585
# Compute control for a deterministic system
# Cost in iteration 0: 0.25283001316981585
# Converged in iteration 1 with cost 0.25283001316981585 because of step counter
# Final cost : 0.25283001316981585
# Compute control for a deterministic system
# Cost in iteration 0: 2.8980783559901653
# Final cost : 0.4507662631630427
# Compute control for a deterministic system
# Cost in iteration 0: 0.4507662631630427
# Cost in iteration 200: 0.2721630208095618
# Final cost : 0.2721630208095618
# Compute control for a deterministic system
# Cost in iteration 0: 0.2721630208095618
# Converged in iteration 90 with cost 0.27209410999341993 because of vanishing difference
# Final cost : 0.27209410999341993
# Compute control for a deterministic system
# Cost in iteration 0: 0.27209410999341993
# Converged in iteration 1 with cost 0.27209410999341993 because of step counter
# Final cost : 0.27209410999341993
# Compute control for a deterministic system
# Cost in iteration 0: 0.27209410999341993
# Converged in iteration 1 with cost 0.27209410999341993 because of step counter
# Final cost : 0.27209410999341993
# Compute control for a deterministic system
# Cost in iteration 0: 2.9153616406011444
# Final cost : 0.6168430848914708
# Compute control for a deterministic system
# Cost in iteration 0: 0.6168430848914708
# Cost in iteration 200: 0.29044292141015404
# Final cost : 0.29044292141015404
# Compute control for a deterministic system
# Cost in iteration 0: 0.29044292141015404
# Cost in iteration 200: 0.2900536645056586
# Final cost : 0.2900536645056586
# Compute control for a deterministic system
# Cost in iteration 0: 0.2900536645056586
# Converged in iteration 1 with cost 0.2900536645056586 because of step counter
# Final cost : 0.2900536645056586
# Compute control for a deterministic system
# Cost in iteration 0: 0.2900536645056586
# Converged in iteration 1 with cost 0.2900536645056586 because of step counter
# Final cost : 0.2900536645056586
# Compute control for a deterministic system
# Cost in iteration 0: 2.9093868837696237
# Final cost : 1.5109387576356337
# Compute control for a deterministic system
# Cost in iteration 0: 1.5109387576356337
# Cost in iteration 200: 0.3107710959171743
# Final cost : 0.3107710959171743
# Compute control for a deterministic system
# Cost in iteration 0: 0.3107710959171743
# Converged in iteration 153 with cost 0.31069450509013585 because of vanishing difference
# Final cost : 0.31069450509013585
# Compute control for a deterministic system
# Cost in iteration 0: 0.31069450509013585
# Converged in iteration 1 with cost 0.31069450509013585 because of step counter
# Final cost : 0.31069450509013585
# Compute control for a deterministic system
# Cost in iteration 0: 0.31069450509013585
# Converged in iteration 1 with cost 0.31069450509013585 because of step counter
# Final cost : 0.31069450509013585
# Compute control for a deterministic system
# Cost in iteration 0: 2.8775650508437414
# Final cost : 0.578189050129447
# Compute control for a deterministic system
# Cost in iteration 0: 0.578189050129447
# Cost in iteration 200: 0.3127800021508791
# Final cost : 0.3127800021508791
# Compute control for a deterministic system
# Cost in iteration 0: 0.3127800021508791
# Converged in iteration 34 with cost 0.31277475262618565 because of vanishing difference
# Final cost : 0.31277475262618565
# Compute control for a deterministic system
# Cost in iteration 0: 0.31277475262618565
# Converged in iteration 1 with cost 0.31277475262618565 because of step counter
# Final cost : 0.31277475262618565
# Compute control for a deterministic system
# Cost in iteration 0: 0.31277475262618565
# Converged in iteration 1 with cost 0.31277475262618565 because of step counter
# Final cost : 0.31277475262618565
# Compute control for a deterministic system
# Cost in iteration 0: 2.82121240099908
# Final cost : 0.4575598487105518
# Compute control for a deterministic system
# Cost in iteration 0: 0.4575598487105518
# Cost in iteration 200: 0.29072014429186144
# Final cost : 0.29072014429186144
# Compute control for a deterministic system
# Cost in iteration 0: 0.29072014429186144
# Cost in iteration 200: 0.2872975761070234
# Final cost : 0.2872975761070234
# Compute control for a deterministic system
# Cost in iteration 0: 0.2872975761070234
# Converged in iteration 1 with cost 0.2872975761070234 because of step counter
# Final cost : 0.2872975761070234
# Compute control for a deterministic system
# Cost in iteration 0: 0.2872975761070234
# Converged in iteration 1 with cost 0.2872975761070234 because of step counter
# Final cost : 0.2872975761070234
# Compute control for a deterministic system
# Cost in iteration 0: 2.7446997408715683
# Final cost : 0.3881560183915339
# Compute control for a deterministic system
# Cost in iteration 0: 0.3881560183915339
# Cost in iteration 200: 0.27402984591734997
# Final cost : 0.27402984591734997
# Compute control for a deterministic system
# Cost in iteration 0: 0.27402984591734997
# Converged in iteration 60 with cost 0.2740281137577481 because of vanishing difference
# Final cost : 0.2740281137577481
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740281137577481
# Converged in iteration 1 with cost 0.2740281137577481 because of step counter
# Final cost : 0.2740281137577481
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740281137577481
# Converged in iteration 1 with cost 0.2740281137577481 because of step counter
# Final cost : 0.2740281137577481
# Compute control for a deterministic system
# Cost in iteration 0: 2.67177083723948
# Final cost : 0.3453076483692583
# Compute control for a deterministic system
# Cost in iteration 0: 0.3453076483692583
# Cost in iteration 200: 0.25680668850300165
# Final cost : 0.25680668850300165
# Compute control for a deterministic system
# Cost in iteration 0: 0.25680668850300165
# Converged in iteration 45 with cost 0.2568037188341867 because of vanishing difference
# Final cost : 0.2568037188341867
# Compute control for a deterministic system
# Cost in iteration 0: 0.2568037188341867
# Converged in iteration 1 with cost 0.2568037188341867 because of step counter
# Final cost : 0.2568037188341867
# Compute control for a deterministic system
# Cost in iteration 0: 0.2568037188341867
# Converged in iteration 1 with cost 0.2568037188341867 because of step counter
# Final cost : 0.2568037188341867
# Compute control for a deterministic system
# Cost in iteration 0: 2.5677691099138036
# Final cost : 0.30106796954418485
# Compute control for a deterministic system
# Cost in iteration 0: 0.30106796954418485
# Converged in iteration 199 with cost 0.2356975810907404 because of vanishing difference
# Final cost : 0.2356975810907404
# Compute control for a deterministic system
# Cost in iteration 0: 0.2356975810907404
# Converged in iteration 1 with cost 0.2356975810907404 because of step counter
# Final cost : 0.2356975810907404
# Compute control for a deterministic system
# Cost in iteration 0: 0.2356975810907404
# Converged in iteration 1 with cost 0.2356975810907404 because of step counter
# Final cost : 0.2356975810907404
# Compute control for a deterministic system
# Cost in iteration 0: 0.2356975810907404
# Converged in iteration 1 with cost 0.2356975810907404 because of step counter
# Final cost : 0.2356975810907404
# Compute control for a deterministic system
# Cost in iteration 0: 2.449545957652314
# Final cost : 0.26388862326204215
# Compute control for a deterministic system
# Cost in iteration 0: 0.26388862326204215
# Cost in iteration 200: 0.21695511716471141
# Final cost : 0.21695511716471141
# Compute control for a deterministic system
# Cost in iteration 0: 0.21695511716471141
# Converged in iteration 9 with cost 0.2169546298073821 because of vanishing difference
# Final cost : 0.2169546298073821
# Compute control for a deterministic system
# Cost in iteration 0: 0.2169546298073821
# Converged in iteration 1 with cost 0.2169546298073821 because of step counter
# Final cost : 0.2169546298073821
# Compute control for a deterministic system
# Cost in iteration 0: 0.2169546298073821
# Converged in iteration 1 with cost 0.2169546298073821 because of step counter
# Final cost : 0.2169546298073821
# Compute control for a deterministic system
# Cost in iteration 0: 2.3158404686855465
# Final cost : 0.23190681236266564
# Compute control for a deterministic system
# Cost in iteration 0: 0.23190681236266564
# Cost in iteration 200: 0.19741580628163702
# Final cost : 0.19741580628163702
# Compute control for a deterministic system
# Cost in iteration 0: 0.19741580628163702
# Converged in iteration 15 with cost 0.19741470308472978 because of vanishing difference
# Final cost : 0.19741470308472978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19741470308472978
# Converged in iteration 1 with cost 0.19741470308472978 because of step counter
# Final cost : 0.19741470308472978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19741470308472978
# Converged in iteration 1 with cost 0.19741470308472978 because of step counter
# Final cost : 0.19741470308472978
# Compute control for a deterministic system
# Cost in iteration 0: 2.1965494245299824
# Final cost : 0.20919209040153727
# Compute control for a deterministic system
# Cost in iteration 0: 0.20919209040153727
# Cost in iteration 200: 0.1836490287833133
# Final cost : 0.1836490287833133
# Compute control for a deterministic system
# Cost in iteration 0: 0.1836490287833133
# Converged in iteration 32 with cost 0.18364767332894705 because of vanishing difference
# Final cost : 0.18364767332894705
# Compute control for a deterministic system
# Cost in iteration 0: 0.18364767332894705
# Converged in iteration 1 with cost 0.18364767332894705 because of step counter
# Final cost : 0.18364767332894705
# Compute control for a deterministic system
# Cost in iteration 0: 0.18364767332894705
# Converged in iteration 1 with cost 0.18364767332894705 because of step counter
# Final cost : 0.18364767332894705
# Compute control for a deterministic system
# Cost in iteration 0: 2.030600260182703
# Final cost : 0.18357844390119774
# Compute control for a deterministic system
# Cost in iteration 0: 0.18357844390119774
# Cost in iteration 200: 0.16502243201718889
# Final cost : 0.16502243201718889
# Compute control for a deterministic system
# Cost in iteration 0: 0.16502243201718889
# Converged in iteration 1 with cost 0.16502243201718889 because of vanishing difference
# Final cost : 0.16502243201718889
# Compute control for a deterministic system
# Cost in iteration 0: 0.16502243201718889
# Converged in iteration 1 with cost 0.16502243201718889 because of step counter
# Final cost : 0.16502243201718889
# Compute control for a deterministic system
# Cost in iteration 0: 0.16502243201718889
# Converged in iteration 1 with cost 0.16502243201718889 because of step counter
# Final cost : 0.16502243201718889
# Compute control for a deterministic system
# Cost in iteration 0: 1.8447402758209792
# Final cost : 0.16045318407355852
# Compute control for a deterministic system
# Cost in iteration 0: 0.16045318407355852
# Cost in iteration 200: 0.14865966379079626
# Final cost : 0.14865966379079626
# Compute control for a deterministic system
# Cost in iteration 0: 0.14865966379079626
# Converged in iteration 15 with cost 0.14865912851833343 because of vanishing difference
# Final cost : 0.14865912851833343
# Compute control for a deterministic system
# Cost in iteration 0: 0.14865912851833343
# Converged in iteration 1 with cost 0.14865912851833343 because of step counter
# Final cost : 0.14865912851833343
# Compute control for a deterministic system
# Cost in iteration 0: 0.14865912851833343
# Converged in iteration 1 with cost 0.14865912851833343 because of step counter
# Final cost : 0.14865912851833343
# Compute control for a deterministic system
# Cost in iteration 0: 1.6813199013484696
# Final cost : 0.1433845026990328
# Compute control for a deterministic system
# Cost in iteration 0: 0.1433845026990328
# Cost in iteration 200: 0.13539754600910459
# Final cost : 0.13539754600910459
# Compute control for a deterministic system
# Cost in iteration 0: 0.13539754600910459
# Converged in iteration 3 with cost 0.13539749146517988 because of vanishing difference
# Final cost : 0.13539749146517988
# Compute control for a deterministic system
# Cost in iteration 0: 0.13539749146517988
# Converged in iteration 1 with cost 0.13539749146517988 because of step counter
# Final cost : 0.13539749146517988
# Compute control for a deterministic system
# Cost in iteration 0: 0.13539749146517988
# Converged in iteration 1 with cost 0.13539749146517988 because of step counter
# Final cost : 0.13539749146517988
# Compute control for a deterministic system
# Cost in iteration 0: 1.4591419376192478
# Final cost : 0.12347427112425129
# Compute control for a deterministic system
# Cost in iteration 0: 0.12347427112425129
# Cost in iteration 200: 0.11899653779025722
# Final cost : 0.11899653779025722
# Compute control for a deterministic system
# Cost in iteration 0: 0.11899653779025722
# Cost in iteration 200: 0.11897581009809784
# Final cost : 0.11897581009809784
# Compute control for a deterministic system
# Cost in iteration 0: 0.11897581009809784
# Converged in iteration 1 with cost 0.11897581009809784 because of vanishing difference
# Final cost : 0.11897581009809784
# Compute control for a deterministic system
# Cost in iteration 0: 0.11897581009809784
# Converged in iteration 1 with cost 0.11897581009809784 because of step counter
# Final cost : 0.11897581009809784
# Compute control for a deterministic system
# Cost in iteration 0: 1.2194382788455362
# Final cost : 0.10489713524853539
# Compute control for a deterministic system
# Cost in iteration 0: 0.10489713524853539
# Cost in iteration 200: 0.10233263100946152
# Final cost : 0.10233263100946152
# Compute control for a deterministic system
# Cost in iteration 0: 0.10233263100946152
# Converged in iteration 95 with cost 0.10232665470229407 because of vanishing difference
# Final cost : 0.10232665470229407
# Compute control for a deterministic system
# Cost in iteration 0: 0.10232665470229407
# Converged in iteration 1 with cost 0.10232665470229407 because of step counter
# Final cost : 0.10232665470229407
# Compute control for a deterministic system
# Cost in iteration 0: 0.10232665470229407
# Converged in iteration 1 with cost 0.10232665470229407 because of step counter
# Final cost : 0.10232665470229407
# Compute control for a deterministic system
# Cost in iteration 0: 0.9676832426299331
# Final cost : 0.08726056681420387
# Compute control for a deterministic system
# Cost in iteration 0: 0.08726056681420387
# Converged in iteration 151 with cost 0.08696213691445395 because of vanishing difference
# Final cost : 0.08696213691445395
# Compute control for a deterministic system
# Cost in iteration 0: 0.08696213691445395
# Converged in iteration 1 with cost 0.08696213691445395 because of step counter
# Final cost : 0.08696213691445395
# Compute control for a deterministic system
# Cost in iteration 0: 0.08696213691445395
# Converged in iteration 1 with cost 0.08696213691445395 because of step counter
# Final cost : 0.08696213691445395
# Compute control for a deterministic system
# Cost in iteration 0: 0.08696213691445395
# Converged in iteration 1 with cost 0.08696213691445395 because of step counter
# Final cost : 0.08696213691445395
# Compute control for a deterministic system
# Cost in iteration 0: 0.7639871135529253
# Final cost : 0.07405444062899465
# Compute control for a deterministic system
# Cost in iteration 0: 0.07405444062899465
# Converged in iteration 128 with cost 0.07369441289199943 because of vanishing difference
# Final cost : 0.07369441289199943
# Compute control for a deterministic system
# Cost in iteration 0: 0.07369441289199943
# Converged in iteration 1 with cost 0.07369441289199943 because of step counter
# Final cost : 0.07369441289199943
# Compute control for a deterministic system
# Cost in iteration 0: 0.07369441289199943
# Converged in iteration 1 with cost 0.07369441289199943 because of step counter
# Final cost : 0.07369441289199943
# Compute control for a deterministic system
# Cost in iteration 0: 0.07369441289199943
# Converged in iteration 1 with cost 0.07369441289199943 because of step counter
# Final cost : 0.07369441289199943
# Compute control for a deterministic system
# Cost in iteration 0: 0.5184642453943644
# Final cost : 0.05781883545475652
# Compute control for a deterministic system
# Cost in iteration 0: 0.05781883545475652
# Converged in iteration 58 with cost 0.05781095864892321 because of vanishing difference
# Final cost : 0.05781095864892321
# Compute control for a deterministic system
# Cost in iteration 0: 0.05781095864892321
# Converged in iteration 1 with cost 0.05781095864892321 because of step counter
# Final cost : 0.05781095864892321
# Compute control for a deterministic system
# Cost in iteration 0: 0.05781095864892321
# Converged in iteration 1 with cost 0.05781095864892321 because of step counter
# Final cost : 0.05781095864892321
# Compute control for a deterministic system
# Cost in iteration 0: 0.05781095864892321
# Converged in iteration 1 with cost 0.05781095864892321 because of step counter
# Final cost : 0.05781095864892321
# Compute control for a deterministic system
# Cost in iteration 0: 0.30026735202923
# Final cost : 0.04168274154880279
# Compute control for a deterministic system
# Cost in iteration 0: 0.04168274154880279
# Converged in iteration 26 with cost 0.04168251615976722 because of vanishing difference
# Final cost : 0.04168251615976722
# Compute control for a deterministic system
# Cost in iteration 0: 0.04168251615976722
# Converged in iteration 1 with cost 0.04168251615976722 because of step counter
# Final cost : 0.04168251615976722
# Compute control for a deterministic system
# Cost in iteration 0: 0.04168251615976722
# Converged in iteration 1 with cost 0.04168251615976722 because of step counter
# Final cost : 0.04168251615976722
# Compute control for a deterministic system
# Cost in iteration 0: 0.04168251615976722
# Converged in iteration 1 with cost 0.04168251615976722 because of step counter
# Final cost : 0.04168251615976722
# Compute control for a deterministic system
# Cost in iteration 0: 0.12985143183249284
# Final cost : 0.02601610936118643
# Compute control for a deterministic system
# Cost in iteration 0: 0.02601610936118643
# Converged in iteration 10 with cost 0.026016067235796938 because of vanishing difference
# Final cost : 0.026016067235796938
# Compute control for a deterministic system
# Cost in iteration 0: 0.026016067235796938
# Converged in iteration 1 with cost 0.026016067235796938 because of step counter
# Final cost : 0.026016067235796938
# Compute control for a deterministic system
# Cost in iteration 0: 0.026016067235796938
# Converged in iteration 1 with cost 0.026016067235796938 because of step counter
# Final cost : 0.026016067235796938
# Compute control for a deterministic system
# Cost in iteration 0: 0.026016067235796938
# Converged in iteration 1 with cost 0.026016067235796938 because of step counter
# Final cost : 0.026016067235796938
# Compute control for a deterministic system
# Cost in iteration 0: 0.040768574037098215
# Final cost : 0.013686195336313612
# Compute control for a deterministic system
# Cost in iteration 0: 0.013686195336313612
# Converged in iteration 1 with cost 0.013686195336313612 because of step counter
# Final cost : 0.013686195336313612
# Compute control for a deterministic system
# Cost in iteration 0: 0.013686195336313612
# Converged in iteration 1 with cost 0.013686195336313612 because of step counter
# Final cost : 0.013686195336313612
# Compute control for a deterministic system
# Cost in iteration 0: 0.013686195336313612
# Converged in iteration 1 with cost 0.013686195336313612 because of step counter
# Final cost : 0.013686195336313612
# Compute control for a deterministic system
# Cost in iteration 0: 0.013686195336313612
# Converged in iteration 1 with cost 0.013686195336313612 because of step counter
# Final cost : 0.013686195336313612
# Compute control for a deterministic system
# Cost in iteration 0: 2.979802797262418e-06
# Converged in iteration 1 with cost 2.979802797262418e-06 because of step counter
# Final cost : 2.979802797262418e-06

# %%
save(results_min)

# %%
from neurolib.optimal_control.oc_utils.plot_oc import ops_plotall

ops_plotall(results_min["control"], 0.05, 300, dt, 200, "")
