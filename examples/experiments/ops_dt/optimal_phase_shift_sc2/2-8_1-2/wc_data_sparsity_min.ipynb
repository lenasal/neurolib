# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,96], wc.inh[0,96]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 13.39904761904762
# minima =  [ 1140  2483  3823  5163  6503  7843  9183 10522 11862 13202 14542 15882
#  17222 18562 19902 21241 22581 23921 25261 26601 27941 29281 30621 31960
#  33300 34640 35980 37320 38660 40000 41340 42679 44019 45359 46699 48039
#  49379 50719 52059 53398 54738 56078 57418 58758]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 results_min = read()
#
# Cell In [9], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l1_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l1_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [True, True, True, True]
options = [ False, False, False, False ]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.026799696086287378
# Converged in iteration 79 with cost 0.006923455997767933 because of step counter
# Final cost : 0.006923455997767933
# Compute control for a deterministic system
# Cost in iteration 0: 0.006923455997767933
# Converged in iteration 1 with cost 0.006923455997767933 because of step counter
# Final cost : 0.006923455997767933
# Compute control for a deterministic system
# Cost in iteration 0: 0.006923455997767933
# Converged in iteration 2 with cost 0.006923455997766473 because of step counter
# Final cost : 0.006923455997766473
# Compute control for a deterministic system
# Cost in iteration 0: 0.006923455997766473
# Converged in iteration 2 with cost 0.006923455997766158 because of step counter
# Final cost : 0.006923455997766158
# Compute control for a deterministic system
# Cost in iteration 0: 0.006923455997766158
# Converged in iteration 1 with cost 0.006923455997766158 because of step counter
# Final cost : 0.006923455997766158
# Compute control for a deterministic system
# Cost in iteration 0: 0.1090219230016524
# Final cost : 0.014582868533895605
# Compute control for a deterministic system
# Cost in iteration 0: 0.014582868533895605
# Converged in iteration 25 with cost 0.014582867956966544 because of step counter
# Final cost : 0.014582867956966544
# Compute control for a deterministic system
# Cost in iteration 0: 0.014582867956966544
# Converged in iteration 1 with cost 0.014582867956966544 because of step counter
# Final cost : 0.014582867956966544
# Compute control for a deterministic system
# Cost in iteration 0: 0.014582867956966544
# Converged in iteration 1 with cost 0.014582867956966544 because of step counter
# Final cost : 0.014582867956966544
# Compute control for a deterministic system
# Cost in iteration 0: 0.014582867956966544
# Converged in iteration 1 with cost 0.014582867956966544 because of step counter
# Final cost : 0.014582867956966544
# Compute control for a deterministic system
# Cost in iteration 0: 0.23759974534476652
# Final cost : 0.021997841384373593
# Compute control for a deterministic system
# Cost in iteration 0: 0.021997841384373593
# Converged in iteration 72 with cost 0.021997596683724523 because of step counter
# Final cost : 0.021997596683724523
# Compute control for a deterministic system
# Cost in iteration 0: 0.021997596683724523
# Converged in iteration 5 with cost 0.021997596683713525 because of step counter
# Final cost : 0.021997596683713525
# Compute control for a deterministic system
# Cost in iteration 0: 0.021997596683713525
# Converged in iteration 7 with cost 0.02199759668369961 because of step counter
# Final cost : 0.02199759668369961
# Compute control for a deterministic system
# Cost in iteration 0: 0.02199759668369961
# Converged in iteration 2 with cost 0.021997596683698196 because of step counter
# Final cost : 0.021997596683698196
# Compute control for a deterministic system
# Cost in iteration 0: 0.41337336495907656
# Final cost : 0.0296121652738489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0296121652738489
# Converged in iteration 173 with cost 0.029606755876968486 because of step counter
# Final cost : 0.029606755876968486
# Compute control for a deterministic system
# Cost in iteration 0: 0.029606755876968486
# Converged in iteration 1 with cost 0.029606755876968486 because of step counter
# Final cost : 0.029606755876968486
# Compute control for a deterministic system
# Cost in iteration 0: 0.029606755876968486
# Converged in iteration 1 with cost 0.029606755876968486 because of step counter
# Final cost : 0.029606755876968486
# Compute control for a deterministic system
# Cost in iteration 0: 0.029606755876968486
# Converged in iteration 1 with cost 0.029606755876968486 because of step counter
# Final cost : 0.029606755876968486
# Compute control for a deterministic system
# Cost in iteration 0: 0.6175738251388867
# Final cost : 0.038330140654473675
# Compute control for a deterministic system
# Cost in iteration 0: 0.038330140654473675
# Converged in iteration 87 with cost 0.03695657171374729 because of vanishing difference
# Final cost : 0.03695657171374729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03695657171374729
# Converged in iteration 175 with cost 0.03695655304686012 because of step counter
# Final cost : 0.03695655304686012
# Compute control for a deterministic system
# Cost in iteration 0: 0.03695655304686012
# Converged in iteration 4 with cost 0.03695655304685882 because of step counter
# Final cost : 0.03695655304685882
# Compute control for a deterministic system
# Cost in iteration 0: 0.03695655304685882
# Converged in iteration 1 with cost 0.03695655304685882 because of step counter
# Final cost : 0.03695655304685882
# Compute control for a deterministic system
# Cost in iteration 0: 0.852857032624333
# Final cost : 0.04640222439898466
# Compute control for a deterministic system
# Cost in iteration 0: 0.04640222439898466
# Converged in iteration 162 with cost 0.044488016700508 because of vanishing difference
# Final cost : 0.044488016700508
# Compute control for a deterministic system
# Cost in iteration 0: 0.044488016700508
# Cost in iteration 200: 0.04448801016907203
# Final cost : 0.04448801016907203
# Compute control for a deterministic system
# Cost in iteration 0: 0.04448801016907203
# Converged in iteration 6 with cost 0.04448801016899384 because of step counter
# Final cost : 0.04448801016899384
# Compute control for a deterministic system
# Cost in iteration 0: 0.04448801016899384
# Converged in iteration 1 with cost 0.04448801016899384 because of step counter
# Final cost : 0.04448801016899384
# Compute control for a deterministic system
# Cost in iteration 0: 1.0959324356757536
# Final cost : 0.05422210024444815
# Compute control for a deterministic system
# Cost in iteration 0: 0.05422210024444815
# Converged in iteration 170 with cost 0.05175493135842637 because of vanishing difference
# Final cost : 0.05175493135842637
# Compute control for a deterministic system
# Cost in iteration 0: 0.05175493135842637
# Cost in iteration 200: 0.051754910334270814
# Final cost : 0.051754910334270814
# Compute control for a deterministic system
# Cost in iteration 0: 0.051754910334270814
# Converged in iteration 54 with cost 0.05175491033009279 because of step counter
# Final cost : 0.05175491033009279
# Compute control for a deterministic system
# Cost in iteration 0: 0.05175491033009279
# Converged in iteration 2 with cost 0.051754910330090685 because of step counter
# Final cost : 0.051754910330090685
# Compute control for a deterministic system
# Cost in iteration 0: 1.3522906620231454
# Final cost : 0.062295894371272795
# Compute control for a deterministic system
# Cost in iteration 0: 0.062295894371272795
# Cost in iteration 200: 0.05919487565822407
# Final cost : 0.05919487565822407
# Compute control for a deterministic system
# Cost in iteration 0: 0.05919487565822407
# Cost in iteration 200: 0.05919478602470144
# Final cost : 0.05919478602470144
# Compute control for a deterministic system
# Cost in iteration 0: 0.05919478602470144
# Converged in iteration 105 with cost 0.05919478590462422 because of step counter
# Final cost : 0.05919478590462422
# Compute control for a deterministic system
# Cost in iteration 0: 0.05919478590462422
# Converged in iteration 2 with cost 0.05919478590462396 because of step counter
# Final cost : 0.05919478590462396
# Compute control for a deterministic system
# Cost in iteration 0: 1.5990194357608654
# Final cost : 0.07019212743599039
# Compute control for a deterministic system
# Cost in iteration 0: 0.07019212743599039
# Cost in iteration 200: 0.0663684625876675
# Final cost : 0.0663684625876675
# Compute control for a deterministic system
# Cost in iteration 0: 0.0663684625876675
# Converged in iteration 31 with cost 0.06636760944408425 because of vanishing difference
# Final cost : 0.06636760944408425
# Compute control for a deterministic system
# Cost in iteration 0: 0.06636760944408425
# Cost in iteration 200: 0.06636691567583276
# Converged in iteration 278 with cost 0.06636691567259699 because of step counter
# Final cost : 0.06636691567259699
# Compute control for a deterministic system
# Cost in iteration 0: 0.06636691567259699
# Converged in iteration 1 with cost 0.06636691567259699 because of step counter
# Final cost : 0.06636691567259699
# Compute control for a deterministic system
# Cost in iteration 0: 1.8442491287073832
# Final cost : 0.07844514833878213
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844514833878213
# Cost in iteration 200: 0.07370657312927063
# Final cost : 0.07370657312927063
# Compute control for a deterministic system
# Cost in iteration 0: 0.07370657312927063
# Converged in iteration 79 with cost 0.07370228465683068 because of vanishing difference
# Final cost : 0.07370228465683068
# Compute control for a deterministic system
# Cost in iteration 0: 0.07370228465683068
# Cost in iteration 200: 0.07370121852927601
# Cost in iteration 400: 0.07370121827738367
# Final cost : 0.07370121827738367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07370121827738367
# Converged in iteration 14 with cost 0.07370121827735016 because of step counter
# Final cost : 0.07370121827735016
# Compute control for a deterministic system
# Cost in iteration 0: 2.068248482451078
# Final cost : 0.08662783301185384
# Compute control for a deterministic system
# Cost in iteration 0: 0.08662783301185384
# Cost in iteration 200: 0.08077975947624276
# Final cost : 0.08077975947624276
# Compute control for a deterministic system
# Cost in iteration 0: 0.08077975947624276
# Converged in iteration 177 with cost 0.08075938767129832 because of vanishing difference
# Final cost : 0.08075938767129832
# Compute control for a deterministic system
# Cost in iteration 0: 0.08075938767129832
# Cost in iteration 200: 0.08075838485139779
# Cost in iteration 400: 0.08075838292491902
# Final cost : 0.08075838292491902
# Compute control for a deterministic system
# Cost in iteration 0: 0.08075838292491902
# Converged in iteration 141 with cost 0.08075838292119335 because of step counter
# Final cost : 0.08075838292119335
# Compute control for a deterministic system
# Cost in iteration 0: 2.2801645067759755
# Final cost : 0.09529595666050716
# Compute control for a deterministic system
# Cost in iteration 0: 0.09529595666050716
# Cost in iteration 200: 0.08799158865617618
# Final cost : 0.08799158865617618
# Compute control for a deterministic system
# Cost in iteration 0: 0.08799158865617618
# Cost in iteration 200: 0.08795475998382674
# Final cost : 0.08795475998382674
# Compute control for a deterministic system
# Cost in iteration 0: 0.08795475998382674
# Cost in iteration 200: 0.08795265560550582
# Cost in iteration 400: 0.08795264345843902
# Final cost : 0.08795264345843902
# Compute control for a deterministic system
# Cost in iteration 0: 0.08795264345843902
# Cost in iteration 200: 0.08795264337369357
# Converged in iteration 328 with cost 0.0879526433710338 because of step counter
# Final cost : 0.0879526433710338
# Compute control for a deterministic system
# Cost in iteration 0: 2.4641012721448257
# Final cost : 0.10399592411829509
# Compute control for a deterministic system
# Cost in iteration 0: 0.10399592411829509
# Cost in iteration 200: 0.0949407963524292
# Final cost : 0.0949407963524292
# Compute control for a deterministic system
# Cost in iteration 0: 0.0949407963524292
# Cost in iteration 200: 0.09485321365982366
# Final cost : 0.09485321365982366
# Compute control for a deterministic system
# Cost in iteration 0: 0.09485321365982366
# Cost in iteration 200: 0.09484588087430601
# Cost in iteration 400: 0.09484578795150056
# Final cost : 0.09484578795150056
# Compute control for a deterministic system
# Cost in iteration 0: 0.09484578795150056
# Cost in iteration 200: 0.09484578718399961
# Cost in iteration 400: 0.09484578713229777
# Cost in iteration 600: 0.09484578712879659
# Converged in iteration 619 with cost 0.09484578712874263 because of step counter
# Final cost : 0.09484578712874263
# Compute control for a deterministic system
# Cost in iteration 0: 2.628408041955669
# Final cost : 0.11332351902808807
# Compute control for a deterministic system
# Cost in iteration 0: 0.11332351902808807
# Cost in iteration 200: 0.1027900567655701
# Final cost : 0.1027900567655701
# Compute control for a deterministic system
# Cost in iteration 0: 0.1027900567655701
# Cost in iteration 200: 0.10185883074897976
# Final cost : 0.10185883074897976
# Compute control for a deterministic system
# Cost in iteration 0: 0.10185883074897976
# Cost in iteration 200: 0.10184868767530325
# Cost in iteration 400: 0.10184847300807458
# Final cost : 0.10184847300807458
# Compute control for a deterministic system
# Cost in iteration 0: 0.10184847300807458
# Cost in iteration 200: 0.10184846645378683
# Cost in iteration 400: 0.10184846575234996
# Cost in iteration 600: 0.10184846567761367
# Cost in iteration 800: 0.10184846566955819
# Converged in iteration 902 with cost 0.10184846566889932 because of step counter
# Final cost : 0.10184846566889932
# Compute control for a deterministic system
# Cost in iteration 0: 2.7615264846264638
# Final cost : 0.12282037094915838
# Compute control for a deterministic system
# Cost in iteration 0: 0.12282037094915838
# Cost in iteration 200: 0.10942377661879217
# Final cost : 0.10942377661879217
# Compute control for a deterministic system
# Cost in iteration 0: 0.10942377661879217
# Cost in iteration 200: 0.10857770694681804
# Final cost : 0.10857770694681804
# Compute control for a deterministic system
# Cost in iteration 0: 0.10857770694681804
# Converged in iteration 34 with cost 0.10856939938872759 because of vanishing difference
# Final cost : 0.10856939938872759
# Compute control for a deterministic system
# Cost in iteration 0: 0.10856939938872759
# Cost in iteration 200: 0.10855859073890514
# Cost in iteration 400: 0.10855711331086598
# Cost in iteration 600: 0.108556907506837
# Cost in iteration 800: 0.10855687895807288
# Cost in iteration 1000: 0.10855687490463746
# Final cost : 0.10855687490463746
# Compute control for a deterministic system
# Cost in iteration 0: 2.8704180241103887
# Final cost : 0.13319020905248707
# Compute control for a deterministic system
# Cost in iteration 0: 0.13319020905248707
# Cost in iteration 200: 0.1161112045068994
# Final cost : 0.1161112045068994
# Compute control for a deterministic system
# Cost in iteration 0: 0.1161112045068994
# Cost in iteration 200: 0.11550169802980378
# Final cost : 0.11550169802980378
# Compute control for a deterministic system
# Cost in iteration 0: 0.11550169802980378
# Cost in iteration 200: 0.11540280909069892
# Cost in iteration 400: 0.11539763951146956
# Final cost : 0.11539763951146956
# Compute control for a deterministic system
# Cost in iteration 0: 0.11539763951146956
# Cost in iteration 200: 0.11539716802814286
# Cost in iteration 400: 0.11539707570614581
# Cost in iteration 600: 0.11539705772568017
# Cost in iteration 800: 0.11539705419683013
# Cost in iteration 1000: 0.1153970535004536
# Final cost : 0.1153970535004536
# Compute control for a deterministic system
# Cost in iteration 0: 2.9483885763600903
# Final cost : 0.14398304116683694
# Compute control for a deterministic system
# Cost in iteration 0: 0.14398304116683694
# Cost in iteration 200: 0.1228555251384511
# Final cost : 0.1228555251384511
# Compute control for a deterministic system
# Cost in iteration 0: 0.1228555251384511
# Cost in iteration 200: 0.12215000789599409
# Final cost : 0.12215000789599409
# Compute control for a deterministic system
# Cost in iteration 0: 0.12215000789599409
# Converged in iteration 70 with cost 0.12204762713916549 because of vanishing difference
# Final cost : 0.12204762713916549
# Compute control for a deterministic system
# Cost in iteration 0: 0.12204762713916549
# Cost in iteration 200: 0.12200133374829009
# Cost in iteration 400: 0.12199216589237566
# Cost in iteration 600: 0.12199012050261436
# Cost in iteration 800: 0.12198962404728794
# Cost in iteration 1000: 0.1219895037801047
# Final cost : 0.1219895037801047
# Compute control for a deterministic system
# Cost in iteration 0: 3.0005699908705576
# Final cost : 0.15609087337275085
# Compute control for a deterministic system
# Cost in iteration 0: 0.15609087337275085
# Cost in iteration 200: 0.13034335189162544
# Final cost : 0.13034335189162544
# Compute control for a deterministic system
# Cost in iteration 0: 0.13034335189162544
# Cost in iteration 200: 0.1290779151374617
# Final cost : 0.1290779151374617
# Compute control for a deterministic system
# Cost in iteration 0: 0.1290779151374617
# Converged in iteration 20 with cost 0.1290113721198892 because of vanishing difference
# Final cost : 0.1290113721198892
# Compute control for a deterministic system
# Cost in iteration 0: 0.1290113721198892
# Cost in iteration 200: 0.12881238323682836
# Cost in iteration 400: 0.12876928625176526
# Cost in iteration 600: 0.12875856180442283
# Cost in iteration 800: 0.12875550187606694
# Cost in iteration 1000: 0.1287546076193504
# Final cost : 0.1287546076193504
# Compute control for a deterministic system
# Cost in iteration 0: 3.0248573018505365
# Final cost : 0.16931741050479715
# Compute control for a deterministic system
# Cost in iteration 0: 0.16931741050479715
# Cost in iteration 200: 0.13763852381212857
# Final cost : 0.13763852381212857
# Compute control for a deterministic system
# Cost in iteration 0: 0.13763852381212857
# Cost in iteration 200: 0.13576007499756917
# Final cost : 0.13576007499756917
# Compute control for a deterministic system
# Cost in iteration 0: 0.13576007499756917
# Converged in iteration 23 with cost 0.13565831393463187 because of vanishing difference
# Final cost : 0.13565831393463187
# Compute control for a deterministic system
# Cost in iteration 0: 0.13565831393463187
# Cost in iteration 200: 0.13539683837233774
# Cost in iteration 400: 0.13533173280161878
# Cost in iteration 600: 0.13531248937972842
# Cost in iteration 800: 0.1353060338092229
# Cost in iteration 1000: 0.1353038353879576
# Final cost : 0.1353038353879576
# Compute control for a deterministic system
# Cost in iteration 0: 3.0240758593341357
# Final cost : 0.2164878101555712
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164878101555712
# Cost in iteration 200: 0.16801728210749808
# Final cost : 0.16801728210749808
# Compute control for a deterministic system
# Cost in iteration 0: 0.16801728210749808
# Cost in iteration 200: 0.16662320823495935
# Final cost : 0.16662320823495935
# Compute control for a deterministic system
# Cost in iteration 0: 0.16662320823495935
# Converged in iteration 40 with cost 0.16660432023487157 because of vanishing difference
# Final cost : 0.16660432023487157
# Compute control for a deterministic system
# Cost in iteration 0: 0.16660432023487157
# Cost in iteration 200: 0.1665711881438208
# Cost in iteration 400: 0.1665652969279527
# Cost in iteration 600: 0.1665642076818457
# Cost in iteration 800: 0.16656399794480722
# Cost in iteration 1000: 0.16656395784448946
# Final cost : 0.16656395784448946
# Compute control for a deterministic system
# Cost in iteration 0: 2.9994209327267
# Final cost : 0.1970420666610195
# Compute control for a deterministic system
# Cost in iteration 0: 0.1970420666610195
# Cost in iteration 200: 0.15944375837250452
# Final cost : 0.15944375837250452
# Compute control for a deterministic system
# Cost in iteration 0: 0.15944375837250452
# Cost in iteration 200: 0.15762245114473158
# Final cost : 0.15762245114473158
# Compute control for a deterministic system
# Cost in iteration 0: 0.15762245114473158
# Cost in iteration 200: 0.15758668457021408
# Cost in iteration 400: 0.15758225755063668
# Final cost : 0.15758225755063668
# Compute control for a deterministic system
# Cost in iteration 0: 0.15758225755063668
# Cost in iteration 200: 0.15758167555270036
# Cost in iteration 400: 0.15758158232333463
# Cost in iteration 600: 0.15758156729791478
# Cost in iteration 800: 0.15758156486294791
# Cost in iteration 1000: 0.15758156446779636
# Final cost : 0.15758156446779636
# Compute control for a deterministic system
# Cost in iteration 0: 2.9501054718319146
# Final cost : 0.1796804924630883
# Compute control for a deterministic system
# Cost in iteration 0: 0.1796804924630883
# Cost in iteration 200: 0.15029966568079497
# Final cost : 0.15029966568079497
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029966568079497
# Cost in iteration 200: 0.14845043706905484
# Final cost : 0.14845043706905484
# Compute control for a deterministic system
# Cost in iteration 0: 0.14845043706905484
# Converged in iteration 12 with cost 0.14844716165449096 because of vanishing difference
# Final cost : 0.14844716165449096
# Compute control for a deterministic system
# Cost in iteration 0: 0.14844716165449096
# Cost in iteration 200: 0.14842485127924462
# Cost in iteration 400: 0.14842212766980784
# Cost in iteration 600: 0.14842178225207478
# Cost in iteration 800: 0.14842173717123963
# Cost in iteration 1000: 0.1484217312577625
# Final cost : 0.1484217312577625
# Compute control for a deterministic system
# Cost in iteration 0: 2.8794058642523623
# Final cost : 0.1644961750771107
# Compute control for a deterministic system
# Cost in iteration 0: 0.1644961750771107
# Cost in iteration 200: 0.14074251780097294
# Final cost : 0.14074251780097294
# Compute control for a deterministic system
# Cost in iteration 0: 0.14074251780097294
# Cost in iteration 200: 0.1396343764231942
# Final cost : 0.1396343764231942
# Compute control for a deterministic system
# Cost in iteration 0: 0.1396343764231942
# Cost in iteration 200: 0.13962418170890753
# Cost in iteration 400: 0.13962337730743704
# Final cost : 0.13962337730743704
# Compute control for a deterministic system
# Cost in iteration 0: 0.13962337730743704
# Cost in iteration 200: 0.13962331231347033
# Cost in iteration 400: 0.13962330551642213
# Cost in iteration 600: 0.13962330481138502
# Cost in iteration 800: 0.13962330473800108
# Cost in iteration 1000: 0.13962330473035908
# Final cost : 0.13962330473035908
# Compute control for a deterministic system
# Cost in iteration 0: 2.7833621725511355
# Final cost : 0.15022483377282597
# Compute control for a deterministic system
# Cost in iteration 0: 0.15022483377282597
# Cost in iteration 200: 0.13106838232336615
# Final cost : 0.13106838232336615
# Compute control for a deterministic system
# Cost in iteration 0: 0.13106838232336615
# Cost in iteration 200: 0.1306507452418643
# Final cost : 0.1306507452418643
# Compute control for a deterministic system
# Cost in iteration 0: 0.1306507452418643
# Cost in iteration 200: 0.13064657995985576
# Cost in iteration 400: 0.13064633396000713
# Final cost : 0.13064633396000713
# Compute control for a deterministic system
# Cost in iteration 0: 0.13064633396000713
# Cost in iteration 200: 0.1306463193319321
# Cost in iteration 400: 0.13064631818418887
# Cost in iteration 600: 0.13064631809390376
# Cost in iteration 800: 0.13064631808679172
# Converged in iteration 817 with cost 0.13064631808667582 because of vanishing difference
# Final cost : 0.13064631808667582
# Compute control for a deterministic system
# Cost in iteration 0: 2.6679927074507637
# Final cost : 0.1374818480568942
# Compute control for a deterministic system
# Cost in iteration 0: 0.1374818480568942
# Cost in iteration 200: 0.12252285569986364
# Final cost : 0.12252285569986364
# Compute control for a deterministic system
# Cost in iteration 0: 0.12252285569986364
# Cost in iteration 200: 0.12201652848442722
# Final cost : 0.12201652848442722
# Compute control for a deterministic system
# Cost in iteration 0: 0.12201652848442722
# Cost in iteration 200: 0.1220131635618061
# Cost in iteration 400: 0.12201302737002341
# Final cost : 0.12201302737002341
# Compute control for a deterministic system
# Cost in iteration 0: 0.12201302737002341
# Cost in iteration 200: 0.12201302173369345
# Cost in iteration 400: 0.12201302141248195
# Cost in iteration 600: 0.12201302139413878
# Converged in iteration 688 with cost 0.12201302139302636 because of step counter
# Final cost : 0.12201302139302636
# Compute control for a deterministic system
# Cost in iteration 0: 2.5268327843714578
# Final cost : 0.1253097161126018
# Compute control for a deterministic system
# Cost in iteration 0: 0.1253097161126018
# Cost in iteration 200: 0.11447557373386351
# Final cost : 0.11447557373386351
# Compute control for a deterministic system
# Cost in iteration 0: 0.11447557373386351
# Cost in iteration 200: 0.11319974337980553
# Final cost : 0.11319974337980553
# Compute control for a deterministic system
# Cost in iteration 0: 0.11319974337980553
# Cost in iteration 200: 0.11319669406634421
# Cost in iteration 400: 0.11319661468119983
# Final cost : 0.11319661468119983
# Compute control for a deterministic system
# Cost in iteration 0: 0.11319661468119983
# Cost in iteration 200: 0.11319661256419797
# Cost in iteration 400: 0.11319661248243396
# Converged in iteration 565 with cost 0.11319661247914505 because of step counter
# Final cost : 0.11319661247914505
# Compute control for a deterministic system
# Cost in iteration 0: 2.3689275285448437
# Final cost : 0.11427489728613051
# Compute control for a deterministic system
# Cost in iteration 0: 0.11427489728613051
# Cost in iteration 200: 0.10503841447083151
# Final cost : 0.10503841447083151
# Compute control for a deterministic system
# Cost in iteration 0: 0.10503841447083151
# Converged in iteration 168 with cost 0.10471577385218012 because of vanishing difference
# Final cost : 0.10471577385218012
# Compute control for a deterministic system
# Cost in iteration 0: 0.10471577385218012
# Cost in iteration 200: 0.10471390013530528
# Cost in iteration 400: 0.1047138704333282
# Final cost : 0.1047138704333282
# Compute control for a deterministic system
# Cost in iteration 0: 0.1047138704333282
# Cost in iteration 200: 0.10471386996486792
# Cost in iteration 400: 0.10471386995322687
# Converged in iteration 427 with cost 0.10471386995293229 because of step counter
# Final cost : 0.10471386995293229
# Compute control for a deterministic system
# Cost in iteration 0: 2.1858508132752035
# Final cost : 0.10357264341736393
# Compute control for a deterministic system
# Cost in iteration 0: 0.10357264341736393
# Cost in iteration 200: 0.09613829281522326
# Final cost : 0.09613829281522326
# Compute control for a deterministic system
# Cost in iteration 0: 0.09613829281522326
# Converged in iteration 179 with cost 0.09605006661250177 because of vanishing difference
# Final cost : 0.09605006661250177
# Compute control for a deterministic system
# Cost in iteration 0: 0.09605006661250177
# Cost in iteration 200: 0.09604968334242879
# Cost in iteration 400: 0.096049680141175
# Final cost : 0.096049680141175
# Compute control for a deterministic system
# Cost in iteration 0: 0.096049680141175
# Cost in iteration 200: 0.09604968011432728
# Converged in iteration 234 with cost 0.09604968011387728 because of step counter
# Final cost : 0.09604968011387728
# Compute control for a deterministic system
# Cost in iteration 0: 1.9899759321198134
# Final cost : 0.093715629603038
# Compute control for a deterministic system
# Cost in iteration 0: 0.093715629603038
# Cost in iteration 200: 0.08776523740834462
# Final cost : 0.08776523740834462
# Compute control for a deterministic system
# Cost in iteration 0: 0.08776523740834462
# Converged in iteration 143 with cost 0.08771345867583273 because of vanishing difference
# Final cost : 0.08771345867583273
# Compute control for a deterministic system
# Cost in iteration 0: 0.08771345867583273
# Cost in iteration 200: 0.08771301375024876
# Cost in iteration 400: 0.08771301202895757
# Final cost : 0.08771301202895757
# Compute control for a deterministic system
# Cost in iteration 0: 0.08771301202895757
# Converged in iteration 88 with cost 0.08771301202218708 because of step counter
# Final cost : 0.08771301202218708
# Compute control for a deterministic system
# Cost in iteration 0: 1.771804493159195
# Final cost : 0.08399756652565514
# Compute control for a deterministic system
# Cost in iteration 0: 0.08399756652565514
# Cost in iteration 200: 0.07921528606030141
# Final cost : 0.07921528606030141
# Compute control for a deterministic system
# Cost in iteration 0: 0.07921528606030141
# Converged in iteration 126 with cost 0.07919821351425485 because of vanishing difference
# Final cost : 0.07919821351425485
# Compute control for a deterministic system
# Cost in iteration 0: 0.07919821351425485
# Cost in iteration 200: 0.07919802848780694
# Cost in iteration 400: 0.07919802821818815
# Final cost : 0.07919802821818815
# Compute control for a deterministic system
# Cost in iteration 0: 0.07919802821818815
# Converged in iteration 25 with cost 0.07919802821777874 because of step counter
# Final cost : 0.07919802821777874
# Compute control for a deterministic system
# Cost in iteration 0: 1.5473136603133997
# Final cost : 0.07489784969631562
# Compute control for a deterministic system
# Cost in iteration 0: 0.07489784969631562
# Cost in iteration 200: 0.07100790737579496
# Final cost : 0.07100790737579496
# Compute control for a deterministic system
# Cost in iteration 0: 0.07100790737579496
# Converged in iteration 56 with cost 0.07100548417926451 because of vanishing difference
# Final cost : 0.07100548417926451
# Compute control for a deterministic system
# Cost in iteration 0: 0.07100548417926451
# Cost in iteration 200: 0.07100518721647862
# Cost in iteration 400: 0.07100518708332057
# Final cost : 0.07100518708332057
# Compute control for a deterministic system
# Cost in iteration 0: 0.07100518708332057
# Converged in iteration 6 with cost 0.07100518708328302 because of step counter
# Final cost : 0.07100518708328302
# Compute control for a deterministic system
# Cost in iteration 0: 1.3072660389339377
# Final cost : 0.06578228555863465
# Compute control for a deterministic system
# Cost in iteration 0: 0.06578228555863465
# Cost in iteration 200: 0.06263782603382861
# Final cost : 0.06263782603382861
# Compute control for a deterministic system
# Cost in iteration 0: 0.06263782603382861
# Converged in iteration 2 with cost 0.06263780350681196 because of vanishing difference
# Final cost : 0.06263780350681196
# Compute control for a deterministic system
# Cost in iteration 0: 0.06263780350681196
# Cost in iteration 200: 0.06263769620874982
# Converged in iteration 316 with cost 0.06263769619886651 because of step counter
# Final cost : 0.06263769619886651
# Compute control for a deterministic system
# Cost in iteration 0: 0.06263769619886651
# Converged in iteration 2 with cost 0.06263769619886525 because of step counter
# Final cost : 0.06263769619886525
# Compute control for a deterministic system
# Cost in iteration 0: 1.0712089426654303
# Final cost : 0.057121324865334624
# Compute control for a deterministic system
# Cost in iteration 0: 0.057121324865334624
# Converged in iteration 173 with cost 0.0545878496225609 because of vanishing difference
# Final cost : 0.0545878496225609
# Compute control for a deterministic system
# Cost in iteration 0: 0.0545878496225609
# Cost in iteration 200: 0.05458779874877472
# Final cost : 0.05458779874877472
# Compute control for a deterministic system
# Cost in iteration 0: 0.05458779874877472
# Converged in iteration 8 with cost 0.05458779874874954 because of step counter
# Final cost : 0.05458779874874954
# Compute control for a deterministic system
# Cost in iteration 0: 0.05458779874874954
# Converged in iteration 2 with cost 0.05458779874874779 because of step counter
# Final cost : 0.05458779874874779
# Compute control for a deterministic system
# Cost in iteration 0: 0.8319162188838928
# Final cost : 0.048337304069977494
# Compute control for a deterministic system
# Cost in iteration 0: 0.048337304069977494
# Converged in iteration 135 with cost 0.04636831205050413 because of vanishing difference
# Final cost : 0.04636831205050413
# Compute control for a deterministic system
# Cost in iteration 0: 0.04636831205050413
# Cost in iteration 200: 0.046368143196917934
# Final cost : 0.046368143196917934
# Compute control for a deterministic system
# Cost in iteration 0: 0.046368143196917934
# Converged in iteration 5 with cost 0.04636814319691396 because of step counter
# Final cost : 0.04636814319691396
# Compute control for a deterministic system
# Cost in iteration 0: 0.04636814319691396
# Converged in iteration 2 with cost 0.04636814319691319 because of step counter
# Final cost : 0.04636814319691319
# Compute control for a deterministic system
# Cost in iteration 0: 0.611685238217272
# Final cost : 0.039911255020003075
# Compute control for a deterministic system
# Cost in iteration 0: 0.039911255020003075
# Converged in iteration 112 with cost 0.03846323397620436 because of vanishing difference
# Final cost : 0.03846323397620436
# Compute control for a deterministic system
# Cost in iteration 0: 0.03846323397620436
# Converged in iteration 125 with cost 0.038463230098610565 because of step counter
# Final cost : 0.038463230098610565
# Compute control for a deterministic system
# Cost in iteration 0: 0.038463230098610565
# Converged in iteration 7 with cost 0.03846323009859469 because of step counter
# Final cost : 0.03846323009859469
# Compute control for a deterministic system
# Cost in iteration 0: 0.03846323009859469
# Converged in iteration 1 with cost 0.03846323009859469 because of step counter
# Final cost : 0.03846323009859469
# Compute control for a deterministic system
# Cost in iteration 0: 0.4068842859200585
# Final cost : 0.031309480867948575
# Compute control for a deterministic system
# Cost in iteration 0: 0.031309480867948575
# Converged in iteration 83 with cost 0.030395765870397076 because of vanishing difference
# Final cost : 0.030395765870397076
# Compute control for a deterministic system
# Cost in iteration 0: 0.030395765870397076
# Converged in iteration 106 with cost 0.03039576213265926 because of step counter
# Final cost : 0.03039576213265926
# Compute control for a deterministic system
# Cost in iteration 0: 0.03039576213265926
# Converged in iteration 1 with cost 0.03039576213265926 because of step counter
# Final cost : 0.03039576213265926
# Compute control for a deterministic system
# Cost in iteration 0: 0.03039576213265926
# Converged in iteration 1 with cost 0.03039576213265926 because of step counter
# Final cost : 0.03039576213265926
# Compute control for a deterministic system
# Cost in iteration 0: 0.23924335310846714
# Final cost : 0.0226434536415556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0226434536415556
# Converged in iteration 60 with cost 0.02264315316378099 because of step counter
# Final cost : 0.02264315316378099
# Compute control for a deterministic system
# Cost in iteration 0: 0.02264315316378099
# Converged in iteration 1 with cost 0.02264315316378099 because of step counter
# Final cost : 0.02264315316378099
# Compute control for a deterministic system
# Cost in iteration 0: 0.02264315316378099
# Converged in iteration 1 with cost 0.02264315316378099 because of step counter
# Final cost : 0.02264315316378099
# Compute control for a deterministic system
# Cost in iteration 0: 0.02264315316378099
# Converged in iteration 1 with cost 0.02264315316378099 because of step counter
# Final cost : 0.02264315316378099
# Compute control for a deterministic system
# Cost in iteration 0: 0.1079767721310192
# Final cost : 0.014740507428415418
# Compute control for a deterministic system
# Cost in iteration 0: 0.014740507428415418
# Converged in iteration 20 with cost 0.01474050682146927 because of step counter
# Final cost : 0.01474050682146927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01474050682146927
# Converged in iteration 1 with cost 0.01474050682146927 because of step counter
# Final cost : 0.01474050682146927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01474050682146927
# Converged in iteration 1 with cost 0.01474050682146927 because of step counter
# Final cost : 0.01474050682146927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01474050682146927
# Converged in iteration 1 with cost 0.01474050682146927 because of step counter
# Final cost : 0.01474050682146927
# Compute control for a deterministic system
# Cost in iteration 0: 0.028155314435467017
# Converged in iteration 76 with cost 0.007160763288660828 because of step counter
# Final cost : 0.007160763288660828
# Compute control for a deterministic system
# Cost in iteration 0: 0.007160763288660828
# Converged in iteration 7 with cost 0.00716076328865319 because of step counter
# Final cost : 0.00716076328865319
# Compute control for a deterministic system
# Cost in iteration 0: 0.00716076328865319
# Converged in iteration 1 with cost 0.00716076328865319 because of step counter
# Final cost : 0.00716076328865319
# Compute control for a deterministic system
# Cost in iteration 0: 0.00716076328865319
# Converged in iteration 1 with cost 0.00716076328865319 because of step counter
# Final cost : 0.00716076328865319
# Compute control for a deterministic system
# Cost in iteration 0: 0.00716076328865319
# Converged in iteration 1 with cost 0.00716076328865319 because of step counter
# Final cost : 0.00716076328865319
# Compute control for a deterministic system
# Cost in iteration 0: 3.829259811741126e-07
# Converged in iteration 1 with cost 3.829259811741126e-07 because of step counter
# Final cost : 3.829259811741126e-07

# %%
save(results_min)

# %%
ind_list = [5,10,15,20,25,30,35]

fig, ax = plt.subplots(7, 1, figsize=(6,20), sharey=True, sharex=True)
    
for i in range(len(ind_list)):
    i_shift = ind_list[i]
    ax[i].plot(results_min["control"][1][i_shift][0,0,:], color="red")
    ax[i].plot(results_min["control"][1][i_shift][0,1,:], color="blue")

plt.show()
