# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,96], wc.inh[0,96]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 13.39904761904762
# minima =  [ 1140  2483  3823  5163  6503  7843  9183 10522 11862 13202 14542 15882
#  17222 18562 19902 21241 22581 23921 25261 26601 27941 29281 30621 31960
#  33300 34640 35980 37320 38660 40000 41340 42679 44019 45359 46699 48039
#  49379 50719 52059 53398 54738 56078 57418 58758]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w1, w_1D=0., print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s3_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s3_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("e_s3_l2.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'e_s3_l2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [True, True, True]
options = [False, False, False]


for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.026799696086287378
# Final cost : 2.737586223948419e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.737586223948419e-05
# Final cost : 2.2525112965286792e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.2525112965286792e-05
# Final cost : 1.9454640886659135e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.9454640886659135e-05
# Final cost : 1.7732869258528285e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7732869258528285e-05
# Final cost : 1.707584813762175e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.1090219230016524
# Final cost : 0.00011657867873035772
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011657867873035772
# Final cost : 8.885239130627095e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.885239130627095e-05
# Final cost : 7.94242779740581e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.94242779740581e-05
# Final cost : 7.265480195234493e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.265480195234493e-05
# Final cost : 6.9933145882174e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.23759974534476652
# Final cost : 0.00026910488800553953
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026910488800553953
# Final cost : 0.00020303475548487848
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020303475548487848
# Final cost : 0.00016765768926710673
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016765768926710673
# Final cost : 0.00015760514475851716
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015760514475851716
# Final cost : 0.0001544516097258156
# Compute control for a deterministic system
# Cost in iteration 0: 0.41337336495907656
# Final cost : 0.0004474857369030562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004474857369030562
# Final cost : 0.00033166400566034634
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033166400566034634
# Final cost : 0.0003015820193646702
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003015820193646702
# Final cost : 0.00028160928449941144
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028160928449941144
# Final cost : 0.0002757712081053288
# Compute control for a deterministic system
# Cost in iteration 0: 0.6175738251388867
# Final cost : 0.0007199812103109878
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007199812103109878
# Final cost : 0.0005155814098034825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005155814098034825
# Final cost : 0.0004653504903646479
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004653504903646479
# Final cost : 0.00043413595179961025
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043413595179961025
# Final cost : 0.0004256913927481576
# Compute control for a deterministic system
# Cost in iteration 0: 0.852857032624333
# Final cost : 0.0010490566987587677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010490566987587677
# Final cost : 0.000731966767481448
# Compute control for a deterministic system
# Cost in iteration 0: 0.000731966767481448
# Final cost : 0.0006645030691063051
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006645030691063051
# Final cost : 0.0006246654302696458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006246654302696458
# Final cost : 0.0006128688213848457
# Compute control for a deterministic system
# Cost in iteration 0: 1.0959324356757536
# Final cost : 0.0014116312604508328
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014116312604508328
# Final cost : 0.000981211007799772
# Compute control for a deterministic system
# Cost in iteration 0: 0.000981211007799772
# Final cost : 0.000892018140568215
# Compute control for a deterministic system
# Cost in iteration 0: 0.000892018140568215
# Final cost : 0.0008421197343343374
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008421197343343374
# Final cost : 0.000825875878068963
# Compute control for a deterministic system
# Cost in iteration 0: 1.3522906620231454
# Final cost : 0.0018395139259782076
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018395139259782076
# Final cost : 0.0012543468938982104
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012543468938982104
# Final cost : 0.0011550476729807033
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011550476729807033
# Final cost : 0.0010993750799474249
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010993750799474249
# Final cost : 0.0010771602373343947
# Compute control for a deterministic system
# Cost in iteration 0: 1.5990194357608654
# Final cost : 0.002324928940473894
# Compute control for a deterministic system
# Cost in iteration 0: 0.002324928940473894
# Final cost : 0.0015702820818842755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015702820818842755
# Final cost : 0.0014472469747028567
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014472469747028567
# Final cost : 0.0013786774012059652
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013786774012059652
# Final cost : 0.0013513495087594271
# Compute control for a deterministic system
# Cost in iteration 0: 1.8442491287073832
# Final cost : 0.002916100647791603
# Compute control for a deterministic system
# Cost in iteration 0: 0.002916100647791603
# Final cost : 0.0019271323644508656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019271323644508656
# Final cost : 0.0017810083049679605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017810083049679605
# Final cost : 0.0017002868864432863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017002868864432863
# Final cost : 0.0016648886284445874
# Compute control for a deterministic system
# Cost in iteration 0: 2.068248482451078
# Final cost : 0.003592750779234687
# Compute control for a deterministic system
# Cost in iteration 0: 0.003592750779234687
# Final cost : 0.0023031824390678706
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023031824390678706
# Final cost : 0.002135498310050316
# Compute control for a deterministic system
# Cost in iteration 0: 0.002135498310050316
# Final cost : 0.0020457893607329636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020457893607329636
# Final cost : 0.0019991510166859714
# Compute control for a deterministic system
# Cost in iteration 0: 2.2801645067759755
# Final cost : 0.004407076285450303
# Compute control for a deterministic system
# Cost in iteration 0: 0.004407076285450303
# Final cost : 0.0027465028095595622
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027465028095595622
# Final cost : 0.0025552301275895864
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025552301275895864
# Final cost : 0.002438671796187462
# Compute control for a deterministic system
# Cost in iteration 0: 0.002438671796187462
# Final cost : 0.002373959785422142
# Compute control for a deterministic system
# Cost in iteration 0: 2.4641012721448257
# Final cost : 0.005320013096636172
# Compute control for a deterministic system
# Cost in iteration 0: 0.005320013096636172
# Final cost : 0.003216172753257813
# Compute control for a deterministic system
# Cost in iteration 0: 0.003216172753257813
# Final cost : 0.0029799344683615458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029799344683615458
# Final cost : 0.0028466698955337652
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028466698955337652
# Final cost : 0.0027669926221344336
# Compute control for a deterministic system
# Cost in iteration 0: 2.628408041955669
# Final cost : 0.0063965497414080995
# Compute control for a deterministic system
# Cost in iteration 0: 0.0063965497414080995
# Final cost : 0.0037284437619418413
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037284437619418413
# Final cost : 0.0034595660554747267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034595660554747267
# Final cost : 0.0033050370340245465
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033050370340245465
# Final cost : 0.003199253105663056
# Compute control for a deterministic system
# Cost in iteration 0: 2.7615264846264638
# Final cost : 0.0075860307843924795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0075860307843924795
# Final cost : 0.004272440679460086
# Compute control for a deterministic system
# Cost in iteration 0: 0.004272440679460086
# Final cost : 0.003956799481112183
# Compute control for a deterministic system
# Cost in iteration 0: 0.003956799481112183
# Final cost : 0.0037797694447422037
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037797694447422037
# Final cost : 0.003647295294216796
# Compute control for a deterministic system
# Cost in iteration 0: 2.8704180241103887
# Final cost : 0.00898189807727507
# Compute control for a deterministic system
# Cost in iteration 0: 0.00898189807727507
# Final cost : 0.004901890738739826
# Compute control for a deterministic system
# Cost in iteration 0: 0.004901890738739826
# Final cost : 0.004510104805106181
# Compute control for a deterministic system
# Cost in iteration 0: 0.004510104805106181
# Final cost : 0.0042945938533219515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042945938533219515
# Final cost : 0.004132083697084452
# Compute control for a deterministic system
# Cost in iteration 0: 2.9483885763600903
# Final cost : 0.010535663489210636
# Compute control for a deterministic system
# Cost in iteration 0: 0.010535663489210636
# Final cost : 0.005538617283047013
# Compute control for a deterministic system
# Cost in iteration 0: 0.005538617283047013
# Final cost : 0.005101169142576642
# Compute control for a deterministic system
# Cost in iteration 0: 0.005101169142576642
# Final cost : 0.004839875595274848
# Compute control for a deterministic system
# Cost in iteration 0: 0.004839875595274848
# Final cost : 0.004635501918047783
# Compute control for a deterministic system
# Cost in iteration 0: 3.0005699908705576
# Final cost : 0.012401603697251523
# Compute control for a deterministic system
# Cost in iteration 0: 0.012401603697251523
# Final cost : 0.006237811495261269
# Compute control for a deterministic system
# Cost in iteration 0: 0.006237811495261269
# Final cost : 0.005682394701456725
# Compute control for a deterministic system
# Cost in iteration 0: 0.005682394701456725
# Final cost : 0.005384645278383024
# Compute control for a deterministic system
# Cost in iteration 0: 0.005384645278383024
# Final cost : 0.005165750512365553
# Compute control for a deterministic system
# Cost in iteration 0: 3.0248573018505365
# Final cost : 0.014609672919458576
# Compute control for a deterministic system
# Cost in iteration 0: 0.014609672919458576
# Final cost : 0.007004160083568923
# Compute control for a deterministic system
# Cost in iteration 0: 0.007004160083568923
# Final cost : 0.0064346365231532626
# Compute control for a deterministic system
# Cost in iteration 0: 0.0064346365231532626
# Final cost : 0.006047970298610817
# Compute control for a deterministic system
# Cost in iteration 0: 0.006047970298610817
# Final cost : 0.005730925347920262
# Compute control for a deterministic system
# Cost in iteration 0: 3.0240758593341357
# Final cost : 0.026307109992946564
# Compute control for a deterministic system
# Cost in iteration 0: 0.026307109992946564
# Final cost : 0.009918985946769569
# Compute control for a deterministic system
# Cost in iteration 0: 0.009918985946769569
# Final cost : 0.009090363206619134
# Compute control for a deterministic system
# Cost in iteration 0: 0.009090363206619134
# Final cost : 0.008550938294015493
# Compute control for a deterministic system
# Cost in iteration 0: 0.008550938294015493
# Final cost : 0.008235352839875892
# Compute control for a deterministic system
# Cost in iteration 0: 2.9994209327267
# Final cost : 0.021238420924139478
# Compute control for a deterministic system
# Cost in iteration 0: 0.021238420924139478
# Final cost : 0.008763401143091171
# Compute control for a deterministic system
# Cost in iteration 0: 0.008763401143091171
# Final cost : 0.008088464676995767
# Compute control for a deterministic system
# Cost in iteration 0: 0.008088464676995767
# Final cost : 0.007626605737787157
# Compute control for a deterministic system
# Cost in iteration 0: 0.007626605737787157
# Final cost : 0.007366572461858634
# Compute control for a deterministic system
# Cost in iteration 0: 2.9501054718319146
# Final cost : 0.017285813551310546
# Compute control for a deterministic system
# Cost in iteration 0: 0.017285813551310546
# Final cost : 0.007679113260370189
# Compute control for a deterministic system
# Cost in iteration 0: 0.007679113260370189
# Final cost : 0.007129670235554206
# Compute control for a deterministic system
# Cost in iteration 0: 0.007129670235554206
# Final cost : 0.006755746841863647
# Compute control for a deterministic system
# Cost in iteration 0: 0.006755746841863647
# Final cost : 0.00653225202930915
# Compute control for a deterministic system
# Cost in iteration 0: 2.8794058642523623
# Final cost : 0.014233220190370127
# Compute control for a deterministic system
# Cost in iteration 0: 0.014233220190370127
# Final cost : 0.006732982539682601
# Compute control for a deterministic system
# Cost in iteration 0: 0.006732982539682601
# Final cost : 0.006282377994149548
# Compute control for a deterministic system
# Cost in iteration 0: 0.006282377994149548
# Final cost : 0.005972982832726039
# Compute control for a deterministic system
# Cost in iteration 0: 0.005972982832726039
# Final cost : 0.005791514770238206
# Compute control for a deterministic system
# Cost in iteration 0: 2.7833621725511355
# Final cost : 0.011675027716647154
# Compute control for a deterministic system
# Cost in iteration 0: 0.011675027716647154
# Final cost : 0.005860790125433485
# Compute control for a deterministic system
# Cost in iteration 0: 0.005860790125433485
# Final cost : 0.005487255582128499
# Compute control for a deterministic system
# Cost in iteration 0: 0.005487255582128499
# Final cost : 0.005224108386411624
# Compute control for a deterministic system
# Cost in iteration 0: 0.005224108386411624
# Final cost : 0.005069971505873422
# Compute control for a deterministic system
# Cost in iteration 0: 2.6679927074507637
# Final cost : 0.009625677878648773
# Compute control for a deterministic system
# Cost in iteration 0: 0.009625677878648773
# Final cost : 0.005078872516297451
# Compute control for a deterministic system
# Cost in iteration 0: 0.005078872516297451
# Final cost : 0.004741132453093503
# Compute control for a deterministic system
# Cost in iteration 0: 0.004741132453093503
# Final cost : 0.004546274706211188
# Compute control for a deterministic system
# Cost in iteration 0: 0.004546274706211188
# Final cost : 0.004427469703765032
# Compute control for a deterministic system
# Cost in iteration 0: 2.5268327843714578
# Final cost : 0.007864644646348763
# Compute control for a deterministic system
# Cost in iteration 0: 0.007864644646348763
# Final cost : 0.004348794399458983
# Compute control for a deterministic system
# Cost in iteration 0: 0.004348794399458983
# Final cost : 0.004080273823030063
# Compute control for a deterministic system
# Cost in iteration 0: 0.004080273823030063
# Final cost : 0.0039147980047197495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039147980047197495
# Final cost : 0.003819071567698599
# Compute control for a deterministic system
# Cost in iteration 0: 2.3689275285448437
# Final cost : 0.006431374461818625
# Compute control for a deterministic system
# Cost in iteration 0: 0.006431374461818625
# Final cost : 0.003708537997501602
# Compute control for a deterministic system
# Cost in iteration 0: 0.003708537997501602
# Final cost : 0.003477265889303673
# Compute control for a deterministic system
# Cost in iteration 0: 0.003477265889303673
# Final cost : 0.0033483211867230355
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033483211867230355
# Final cost : 0.0032752306052655925
# Compute control for a deterministic system
# Cost in iteration 0: 2.1858508132752035
# Final cost : 0.005191343188175249
# Compute control for a deterministic system
# Cost in iteration 0: 0.005191343188175249
# Final cost : 0.0031118709052432355
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031118709052432355
# Final cost : 0.002919926210377466
# Compute control for a deterministic system
# Cost in iteration 0: 0.002919926210377466
# Final cost : 0.0028190764142034495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028190764142034495
# Final cost : 0.002763361080033515
# Compute control for a deterministic system
# Cost in iteration 0: 1.9899759321198134
# Final cost : 0.00418314800150197
# Compute control for a deterministic system
# Cost in iteration 0: 0.00418314800150197
# Final cost : 0.0026009002591586387
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026009002591586387
# Final cost : 0.0024408042343658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024408042343658266
# Final cost : 0.0023560277729130687
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023560277729130687
# Final cost : 0.002311128484518229
# Compute control for a deterministic system
# Cost in iteration 0: 1.771804493159195
# Final cost : 0.0033169553132021815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033169553132021815
# Final cost : 0.0021247184531684444
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021247184531684444
# Final cost : 0.001985382697932265
# Compute control for a deterministic system
# Cost in iteration 0: 0.001985382697932265
# Final cost : 0.001921047112570063
# Compute control for a deterministic system
# Cost in iteration 0: 0.001921047112570063
# Final cost : 0.0018902194665400235
# Compute control for a deterministic system
# Cost in iteration 0: 1.5473136603133997
# Final cost : 0.0026193427038379486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026193427038379486
# Final cost : 0.001722060104307481
# Compute control for a deterministic system
# Cost in iteration 0: 0.001722060104307481
# Final cost : 0.001603842764692983
# Compute control for a deterministic system
# Cost in iteration 0: 0.001603842764692983
# Final cost : 0.001548373421035404
# Compute control for a deterministic system
# Cost in iteration 0: 0.001548373421035404
# Final cost : 0.0015249687824828845
# Compute control for a deterministic system
# Cost in iteration 0: 1.3072660389339377
# Final cost : 0.002023160137682869
# Compute control for a deterministic system
# Cost in iteration 0: 0.002023160137682869
# Final cost : 0.00135375297600683
# Compute control for a deterministic system
# Cost in iteration 0: 0.00135375297600683
# Final cost : 0.0012572282798755058
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012572282798755058
# Final cost : 0.0012082426267715056
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012082426267715056
# Final cost : 0.001192113364175665
# Compute control for a deterministic system
# Cost in iteration 0: 1.0712089426654303
# Final cost : 0.0015392642411739418
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015392642411739418
# Final cost : 0.0010486870731505845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010486870731505845
# Final cost : 0.0009642271516119872
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009642271516119872
# Final cost : 0.0009231900074130195
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009231900074130195
# Final cost : 0.0009102492798855428
# Compute control for a deterministic system
# Cost in iteration 0: 0.8319162188838928
# Final cost : 0.0011158204521178627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011158204521178627
# Final cost : 0.0007756783620914723
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007756783620914723
# Final cost : 0.0007033468644970102
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007033468644970102
# Final cost : 0.00066903344629202
# Compute control for a deterministic system
# Cost in iteration 0: 0.00066903344629202
# Final cost : 0.0006611004930520938
# Compute control for a deterministic system
# Cost in iteration 0: 0.611685238217272
# Final cost : 0.000764464390931571
# Compute control for a deterministic system
# Cost in iteration 0: 0.000764464390931571
# Final cost : 0.0005451538110449517
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005451538110449517
# Final cost : 0.000491707040168972
# Compute control for a deterministic system
# Cost in iteration 0: 0.000491707040168972
# Final cost : 0.00046482466719105834
# Compute control for a deterministic system
# Cost in iteration 0: 0.00046482466719105834
# Final cost : 0.0004587055894514281
# Compute control for a deterministic system
# Cost in iteration 0: 0.4068842859200585
# Final cost : 0.00046358089642594536
# Compute control for a deterministic system
# Cost in iteration 0: 0.00046358089642594536
# Final cost : 0.0003419785408971046
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003419785408971046
# Final cost : 0.00031183887244252777
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031183887244252777
# Final cost : 0.00029400932677898486
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029400932677898486
# Final cost : 0.00028976368690132153
# Compute control for a deterministic system
# Cost in iteration 0: 0.23924335310846714
# Final cost : 0.0002606661613810349
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002606661613810349
# Final cost : 0.00020319398811362513
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020319398811362513
# Final cost : 0.00018342809618298716
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018342809618298716
# Final cost : 0.00016738223349964788
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016738223349964788
# Final cost : 0.00016344360453372008
# Compute control for a deterministic system
# Cost in iteration 0: 0.1079767721310192
# Final cost : 0.0001193074235033065
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001193074235033065
# Final cost : 8.689755667552319e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.689755667552319e-05
# Final cost : 7.894593492272257e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.894593492272257e-05
# Final cost : 7.314481352701778e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.314481352701778e-05
# Final cost : 7.14210703376253e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.028155314435467017
# Final cost : 2.9324679684615684e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9324679684615684e-05
# Final cost : 2.4160509880526258e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.4160509880526258e-05
# Final cost : 2.089273005517345e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.089273005517345e-05
# Final cost : 1.900182828190979e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.900182828190979e-05
# Final cost : 1.8240242087673623e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.829259811741126e-07
# Final cost : 3.866618021898505e-10

# %%
save(results_min)
