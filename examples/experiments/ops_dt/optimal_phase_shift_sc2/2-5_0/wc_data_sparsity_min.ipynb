# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1017], wc.inh[0,1017]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# minima =  [  451  2334  4217  6101  7984  9867 11751 13634 15517 17401 19284 21167
#  23050 24934 26817 28700 30584 32467 34350 36234 38117 40000 41884 43767
#  45650 47534 49417 51300 53184 55067 56950 58834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 0.99 + 0.02*np.random.random()
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 0.99 + 0.02*np.random.random()
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05362677462567759
# Final cost : 0.023820448125482514
# Compute control for a deterministic system
# Cost in iteration 0: 0.023820448125482514
# Converged in iteration 92 with cost 0.008223821719324573 because of step counter
# Final cost : 0.008223821719324573
# Compute control for a deterministic system
# Cost in iteration 0: 0.008223821719324573
# Converged in iteration 1 with cost 0.008223821719324573 because of step counter
# Final cost : 0.008223821719324573
# Compute control for a deterministic system
# Cost in iteration 0: 0.008223821719324573
# Converged in iteration 2 with cost 0.008223821719323916 because of step counter
# Final cost : 0.008223821719323916
# Compute control for a deterministic system
# Cost in iteration 0: 0.008223821719323916
# Converged in iteration 1 with cost 0.008223821719323916 because of step counter
# Final cost : 0.008223821719323916
# Compute control for a deterministic system
# Cost in iteration 0: 0.008223821719323916
# Converged in iteration 1 with cost 0.008223821719323916 because of step counter
# Final cost : 0.008223821719323916
# Compute control for a deterministic system
# Cost in iteration 0: 0.208456458857865
# Final cost : 0.0495750517831605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0495750517831605
# Converged in iteration 199 with cost 0.016877721331013437 because of step counter
# Final cost : 0.016877721331013437
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721331013437
# Converged in iteration 6 with cost 0.016877721330978868 because of step counter
# Final cost : 0.016877721330978868
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330978868
# Converged in iteration 2 with cost 0.016877721330975926 because of step counter
# Final cost : 0.016877721330975926
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330975926
# Converged in iteration 1 with cost 0.016877721330975926 because of step counter
# Final cost : 0.016877721330975926
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330975926
# Converged in iteration 1 with cost 0.016877721330975926 because of step counter
# Final cost : 0.016877721330975926
# Compute control for a deterministic system
# Cost in iteration 0: 0.4492251857960263
# Final cost : 0.05414750981224542
# Compute control for a deterministic system
# Cost in iteration 0: 0.05414750981224542
# Cost in iteration 200: 0.02557966927594005
# Final cost : 0.02557966927594005
# Compute control for a deterministic system
# Cost in iteration 0: 0.02557966927594005
# Converged in iteration 64 with cost 0.025579668892321727 because of step counter
# Final cost : 0.025579668892321727
# Compute control for a deterministic system
# Cost in iteration 0: 0.025579668892321727
# Converged in iteration 2 with cost 0.025579668892320516 because of step counter
# Final cost : 0.025579668892320516
# Compute control for a deterministic system
# Cost in iteration 0: 0.025579668892320516
# Converged in iteration 2 with cost 0.02557966889231907 because of step counter
# Final cost : 0.02557966889231907
# Compute control for a deterministic system
# Cost in iteration 0: 0.02557966889231907
# Converged in iteration 1 with cost 0.02557966889231907 because of step counter
# Final cost : 0.02557966889231907
# Compute control for a deterministic system
# Cost in iteration 0: 0.7559722325801564
# Final cost : 0.04463738616255843
# Compute control for a deterministic system
# Cost in iteration 0: 0.04463738616255843
# Cost in iteration 200: 0.034267726564269234
# Final cost : 0.034267726564269234
# Compute control for a deterministic system
# Cost in iteration 0: 0.034267726564269234
# Converged in iteration 154 with cost 0.03426768800927994 because of step counter
# Final cost : 0.03426768800927994
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426768800927994
# Converged in iteration 1 with cost 0.03426768800927994 because of step counter
# Final cost : 0.03426768800927994
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426768800927994
# Converged in iteration 1 with cost 0.03426768800927994 because of step counter
# Final cost : 0.03426768800927994
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426768800927994
# Converged in iteration 2 with cost 0.034267688009279276 because of step counter
# Final cost : 0.034267688009279276
# Compute control for a deterministic system
# Cost in iteration 0: 1.1076473431570795
# Final cost : 0.04972513225123638
# Compute control for a deterministic system
# Cost in iteration 0: 0.04972513225123638
# Cost in iteration 200: 0.042910482442774046
# Final cost : 0.042910482442774046
# Compute control for a deterministic system
# Cost in iteration 0: 0.042910482442774046
# Cost in iteration 200: 0.042909880688893835
# Final cost : 0.042909880688893835
# Compute control for a deterministic system
# Cost in iteration 0: 0.042909880688893835
# Converged in iteration 32 with cost 0.04290988068748493 because of step counter
# Final cost : 0.04290988068748493
# Compute control for a deterministic system
# Cost in iteration 0: 0.04290988068748493
# Converged in iteration 1 with cost 0.04290988068748493 because of step counter
# Final cost : 0.04290988068748493
# Compute control for a deterministic system
# Cost in iteration 0: 0.04290988068748493
# Converged in iteration 7 with cost 0.042909880687467185 because of step counter
# Final cost : 0.042909880687467185
# Compute control for a deterministic system
# Cost in iteration 0: 1.4850110202516826
# Final cost : 0.10031363129148121
# Compute control for a deterministic system
# Cost in iteration 0: 0.10031363129148121
# Cost in iteration 200: 0.051536398991129405
# Final cost : 0.051536398991129405
# Compute control for a deterministic system
# Cost in iteration 0: 0.051536398991129405
# Converged in iteration 55 with cost 0.051531864275738415 because of vanishing difference
# Final cost : 0.051531864275738415
# Compute control for a deterministic system
# Cost in iteration 0: 0.051531864275738415
# Converged in iteration 140 with cost 0.05153165271931968 because of step counter
# Final cost : 0.05153165271931968
# Compute control for a deterministic system
# Cost in iteration 0: 0.05153165271931968
# Converged in iteration 2 with cost 0.05153165271931833 because of step counter
# Final cost : 0.05153165271931833
# Compute control for a deterministic system
# Cost in iteration 0: 0.05153165271931833
# Converged in iteration 2 with cost 0.05153165271931229 because of step counter
# Final cost : 0.05153165271931229
# Compute control for a deterministic system
# Cost in iteration 0: 1.8798040700027128
# Final cost : 0.2268247025681699
# Compute control for a deterministic system
# Cost in iteration 0: 0.2268247025681699
# Cost in iteration 200: 0.06037420522243079
# Final cost : 0.06037420522243079
# Compute control for a deterministic system
# Cost in iteration 0: 0.06037420522243079
# Cost in iteration 200: 0.06035078363900307
# Final cost : 0.06035078363900307
# Compute control for a deterministic system
# Cost in iteration 0: 0.06035078363900307
# Converged in iteration 108 with cost 0.060350777787453666 because of step counter
# Final cost : 0.060350777787453666
# Compute control for a deterministic system
# Cost in iteration 0: 0.060350777787453666
# Converged in iteration 1 with cost 0.060350777787453666 because of step counter
# Final cost : 0.060350777787453666
# Compute control for a deterministic system
# Cost in iteration 0: 0.060350777787453666
# Converged in iteration 1 with cost 0.060350777787453666 because of step counter
# Final cost : 0.060350777787453666
# Compute control for a deterministic system
# Cost in iteration 0: 2.2613541315895733
# Final cost : 0.45251544268230676
# Compute control for a deterministic system
# Cost in iteration 0: 0.45251544268230676
# Cost in iteration 200: 0.0690679249812012
# Final cost : 0.0690679249812012
# Compute control for a deterministic system
# Cost in iteration 0: 0.0690679249812012
# Cost in iteration 200: 0.0690188119807601
# Final cost : 0.0690188119807601
# Compute control for a deterministic system
# Cost in iteration 0: 0.0690188119807601
# Converged in iteration 115 with cost 0.06901877484161485 because of step counter
# Final cost : 0.06901877484161485
# Compute control for a deterministic system
# Cost in iteration 0: 0.06901877484161485
# Converged in iteration 1 with cost 0.06901877484161485 because of step counter
# Final cost : 0.06901877484161485
# Compute control for a deterministic system
# Cost in iteration 0: 0.06901877484161485
# Converged in iteration 1 with cost 0.06901877484161485 because of step counter
# Final cost : 0.06901877484161485
# Compute control for a deterministic system
# Cost in iteration 0: 2.6259068586367484
# Final cost : 0.7866746670170266
# Compute control for a deterministic system
# Cost in iteration 0: 0.7866746670170266
# Cost in iteration 200: 0.07784320538611542
# Final cost : 0.07784320538611542
# Compute control for a deterministic system
# Cost in iteration 0: 0.07784320538611542
# Converged in iteration 137 with cost 0.07772709158896889 because of vanishing difference
# Final cost : 0.07772709158896889
# Compute control for a deterministic system
# Cost in iteration 0: 0.07772709158896889
# Converged in iteration 155 with cost 0.07772581328779107 because of step counter
# Final cost : 0.07772581328779107
# Compute control for a deterministic system
# Cost in iteration 0: 0.07772581328779107
# Converged in iteration 1 with cost 0.07772581328779107 because of step counter
# Final cost : 0.07772581328779107
# Compute control for a deterministic system
# Cost in iteration 0: 0.07772581328779107
# Converged in iteration 1 with cost 0.07772581328779107 because of step counter
# Final cost : 0.07772581328779107
# Compute control for a deterministic system
# Cost in iteration 0: 2.963434887481866
# Final cost : 1.2207216287849896
# Compute control for a deterministic system
# Cost in iteration 0: 1.2207216287849896
# Cost in iteration 200: 0.08670953854849554
# Final cost : 0.08670953854849554
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670953854849554
# Converged in iteration 192 with cost 0.08647330687552111 because of vanishing difference
# Final cost : 0.08647330687552111
# Compute control for a deterministic system
# Cost in iteration 0: 0.08647330687552111
# Converged in iteration 158 with cost 0.08647217793571636 because of step counter
# Final cost : 0.08647217793571636
# Compute control for a deterministic system
# Cost in iteration 0: 0.08647217793571636
# Converged in iteration 2 with cost 0.08647217793571543 because of step counter
# Final cost : 0.08647217793571543
# Compute control for a deterministic system
# Cost in iteration 0: 0.08647217793571543
# Converged in iteration 2 with cost 0.0864721779357124 because of step counter
# Final cost : 0.0864721779357124
# Compute control for a deterministic system
# Cost in iteration 0: 3.2661323952682837
# Final cost : 1.728843911111766
# Compute control for a deterministic system
# Cost in iteration 0: 1.728843911111766
# Cost in iteration 200: 0.09568356326227409
# Final cost : 0.09568356326227409
# Compute control for a deterministic system
# Cost in iteration 0: 0.09568356326227409
# Converged in iteration 165 with cost 0.09526156239093982 because of vanishing difference
# Final cost : 0.09526156239093982
# Compute control for a deterministic system
# Cost in iteration 0: 0.09526156239093982
# Cost in iteration 200: 0.09525536428610086
# Final cost : 0.09525536428610086
# Compute control for a deterministic system
# Cost in iteration 0: 0.09525536428610086
# Converged in iteration 57 with cost 0.09525536428449599 because of step counter
# Final cost : 0.09525536428449599
# Compute control for a deterministic system
# Cost in iteration 0: 0.09525536428449599
# Converged in iteration 1 with cost 0.09525536428449599 because of step counter
# Final cost : 0.09525536428449599
# Compute control for a deterministic system
# Cost in iteration 0: 3.5289805713308553
# Final cost : 2.2689409413222976
# Compute control for a deterministic system
# Cost in iteration 0: 2.2689409413222976
# Cost in iteration 200: 0.10477271395018538
# Final cost : 0.10477271395018538
# Compute control for a deterministic system
# Cost in iteration 0: 0.10477271395018538
# Cost in iteration 200: 0.10408008631721055
# Final cost : 0.10408008631721055
# Compute control for a deterministic system
# Cost in iteration 0: 0.10408008631721055
# Cost in iteration 200: 0.1040721359421927
# Final cost : 0.1040721359421927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1040721359421927
# Converged in iteration 193 with cost 0.10407213589130897 because of step counter
# Final cost : 0.10407213589130897
# Compute control for a deterministic system
# Cost in iteration 0: 0.10407213589130897
# Converged in iteration 28 with cost 0.10407213589102694 because of step counter
# Final cost : 0.10407213589102694
# Compute control for a deterministic system
# Cost in iteration 0: 3.7501580681946662
# Final cost : 2.7898881175223913
# Compute control for a deterministic system
# Cost in iteration 0: 2.7898881175223913
# Cost in iteration 200: 0.11417304361491103
# Final cost : 0.11417304361491103
# Compute control for a deterministic system
# Cost in iteration 0: 0.11417304361491103
# Cost in iteration 200: 0.11293738808896428
# Final cost : 0.11293738808896428
# Compute control for a deterministic system
# Cost in iteration 0: 0.11293738808896428
# Converged in iteration 99 with cost 0.11292376375490988 because of vanishing difference
# Final cost : 0.11292376375490988
# Compute control for a deterministic system
# Cost in iteration 0: 0.11292376375490988
# Cost in iteration 200: 0.11291957272786293
# Cost in iteration 400: 0.11291950463460883
# Final cost : 0.11291950463460883
# Compute control for a deterministic system
# Cost in iteration 0: 0.11291950463460883
# Cost in iteration 200: 0.11291950350641046
# Cost in iteration 400: 0.11291950345894418
# Converged in iteration 521 with cost 0.11291950345704134 because of step counter
# Final cost : 0.11291950345704134
# Compute control for a deterministic system
# Cost in iteration 0: 3.9308119961270354
# Final cost : 3.2462854797019043
# Compute control for a deterministic system
# Cost in iteration 0: 3.2462854797019043
# Cost in iteration 200: 0.12350097792078144
# Final cost : 0.12350097792078144
# Compute control for a deterministic system
# Cost in iteration 0: 0.12350097792078144
# Cost in iteration 200: 0.12182606292608188
# Final cost : 0.12182606292608188
# Compute control for a deterministic system
# Cost in iteration 0: 0.12182606292608188
# Converged in iteration 84 with cost 0.12180508821251529 because of vanishing difference
# Final cost : 0.12180508821251529
# Compute control for a deterministic system
# Cost in iteration 0: 0.12180508821251529
# Cost in iteration 200: 0.12179499482553968
# Cost in iteration 400: 0.12179474669241795
# Final cost : 0.12179474669241795
# Compute control for a deterministic system
# Cost in iteration 0: 0.12179474669241795
# Cost in iteration 200: 0.12179474043249602
# Cost in iteration 400: 0.12179474005069153
# Cost in iteration 600: 0.1217947400271567
# Converged in iteration 675 with cost 0.12179474002615938 because of step counter
# Final cost : 0.12179474002615938
# Compute control for a deterministic system
# Cost in iteration 0: 4.0741319299451435
# Final cost : 3.6129188570823128
# Compute control for a deterministic system
# Cost in iteration 0: 3.6129188570823128
# Cost in iteration 200: 0.13307007343884295
# Final cost : 0.13307007343884295
# Compute control for a deterministic system
# Cost in iteration 0: 0.13307007343884295
# Cost in iteration 200: 0.13074845389161083
# Final cost : 0.13074845389161083
# Compute control for a deterministic system
# Cost in iteration 0: 0.13074845389161083
# Converged in iteration 42 with cost 0.13072775467575526 because of vanishing difference
# Final cost : 0.13072775467575526
# Compute control for a deterministic system
# Cost in iteration 0: 0.13072775467575526
# Cost in iteration 200: 0.13069698681440692
# Cost in iteration 400: 0.13069604162909246
# Final cost : 0.13069604162909246
# Compute control for a deterministic system
# Cost in iteration 0: 0.13069604162909246
# Cost in iteration 200: 0.13069599816967356
# Cost in iteration 400: 0.1306959946095847
# Cost in iteration 600: 0.13069599431561493
# Cost in iteration 800: 0.13069599429112047
# Converged in iteration 917 with cost 0.13069599428928505 because of step counter
# Final cost : 0.13069599428928505
# Compute control for a deterministic system
# Cost in iteration 0: 4.184204520809734
# Final cost : 3.8881184639222908
# Compute control for a deterministic system
# Cost in iteration 0: 3.8881184639222908
# Cost in iteration 200: 0.14293500083536875
# Final cost : 0.14293500083536875
# Compute control for a deterministic system
# Cost in iteration 0: 0.14293500083536875
# Cost in iteration 200: 0.13970538795665055
# Final cost : 0.13970538795665055
# Compute control for a deterministic system
# Cost in iteration 0: 0.13970538795665055
# Converged in iteration 53 with cost 0.1396689469130125 because of vanishing difference
# Final cost : 0.1396689469130125
# Compute control for a deterministic system
# Cost in iteration 0: 0.1396689469130125
# Cost in iteration 200: 0.13962375516338538
# Cost in iteration 400: 0.1396219328479768
# Final cost : 0.1396219328479768
# Compute control for a deterministic system
# Cost in iteration 0: 0.1396219328479768
# Cost in iteration 200: 0.13962183292515876
# Cost in iteration 400: 0.13962182218064983
# Cost in iteration 600: 0.13962182102199935
# Cost in iteration 800: 0.13962182089607147
# Cost in iteration 1000: 0.139621820882547
# Final cost : 0.139621820882547
# Compute control for a deterministic system
# Cost in iteration 0: 4.2651305527325825
# Final cost : 4.08474012891251
# Compute control for a deterministic system
# Cost in iteration 0: 4.08474012891251
# Cost in iteration 200: 0.15309079259074004
# Final cost : 0.15309079259074004
# Compute control for a deterministic system
# Cost in iteration 0: 0.15309079259074004
# Cost in iteration 200: 0.14869439799171946
# Final cost : 0.14869439799171946
# Compute control for a deterministic system
# Cost in iteration 0: 0.14869439799171946
# Cost in iteration 200: 0.14858838280596692
# Final cost : 0.14858838280596692
# Compute control for a deterministic system
# Cost in iteration 0: 0.14858838280596692
# Cost in iteration 200: 0.1485720770415574
# Cost in iteration 400: 0.14857113486569612
# Final cost : 0.14857113486569612
# Compute control for a deterministic system
# Cost in iteration 0: 0.14857113486569612
# Cost in iteration 200: 0.14857107147048956
# Cost in iteration 400: 0.14857106285038618
# Cost in iteration 600: 0.14857106168687179
# Cost in iteration 800: 0.14857106152731875
# Cost in iteration 1000: 0.14857106150581295
# Final cost : 0.14857106150581295
# Compute control for a deterministic system
# Cost in iteration 0: 4.320545433780196
# Final cost : 4.218921890724507
# Compute control for a deterministic system
# Cost in iteration 0: 4.218921890724507
# Cost in iteration 200: 0.163561865680019
# Final cost : 0.163561865680019
# Compute control for a deterministic system
# Cost in iteration 0: 0.163561865680019
# Cost in iteration 200: 0.15772991999697808
# Final cost : 0.15772991999697808
# Compute control for a deterministic system
# Cost in iteration 0: 0.15772991999697808
# Cost in iteration 200: 0.1575735360850688
# Final cost : 0.1575735360850688
# Compute control for a deterministic system
# Cost in iteration 0: 0.1575735360850688
# Cost in iteration 200: 0.1575454013317211
# Cost in iteration 400: 0.15754328784579943
# Final cost : 0.15754328784579943
# Compute control for a deterministic system
# Cost in iteration 0: 0.15754328784579943
# Cost in iteration 200: 0.1575431238821634
# Cost in iteration 400: 0.15754309680700743
# Cost in iteration 600: 0.15754309236124084
# Cost in iteration 800: 0.15754309162357022
# Cost in iteration 1000: 0.15754309149991033
# Final cost : 0.15754309149991033
# Compute control for a deterministic system
# Cost in iteration 0: 4.3539003652087755
# Final cost : 4.3053921593368365
# Compute control for a deterministic system
# Cost in iteration 0: 4.3053921593368365
# Cost in iteration 200: 0.17460885791366376
# Final cost : 0.17460885791366376
# Compute control for a deterministic system
# Cost in iteration 0: 0.17460885791366376
# Cost in iteration 200: 0.16702304800424234
# Final cost : 0.16702304800424234
# Compute control for a deterministic system
# Cost in iteration 0: 0.16702304800424234
# Cost in iteration 200: 0.16678486144215995
# Final cost : 0.16678486144215995
# Compute control for a deterministic system
# Cost in iteration 0: 0.16678486144215995
# Cost in iteration 200: 0.1667342814081211
# Cost in iteration 400: 0.166729514069017
# Final cost : 0.166729514069017
# Compute control for a deterministic system
# Cost in iteration 0: 0.166729514069017
# Cost in iteration 200: 0.1667290510685601
# Cost in iteration 400: 0.16672896068488777
# Cost in iteration 600: 0.1667289425783903
# Cost in iteration 800: 0.1667289389796974
# Cost in iteration 1000: 0.16672893826227192
# Final cost : 0.16672893826227192
# Compute control for a deterministic system
# Cost in iteration 0: 4.366009911157753
# Final cost : 4.349468284836485
# Compute control for a deterministic system
# Cost in iteration 0: 4.349468284836485
# Cost in iteration 200: 0.18593955196592238
# Final cost : 0.18593955196592238
# Compute control for a deterministic system
# Cost in iteration 0: 0.18593955196592238
# Cost in iteration 200: 0.17615077871778376
# Final cost : 0.17615077871778376
# Compute control for a deterministic system
# Cost in iteration 0: 0.17615077871778376
# Cost in iteration 200: 0.17583055360390643
# Final cost : 0.17583055360390643
# Compute control for a deterministic system
# Cost in iteration 0: 0.17583055360390643
# Cost in iteration 200: 0.1757554331887106
# Cost in iteration 400: 0.1757468516353461
# Final cost : 0.1757468516353461
# Compute control for a deterministic system
# Cost in iteration 0: 0.1757468516353461
# Cost in iteration 200: 0.17574577688119655
# Cost in iteration 400: 0.17574553084961295
# Cost in iteration 600: 0.1757454734315899
# Cost in iteration 800: 0.17574546001256658
# Cost in iteration 1000: 0.17574545686500043
# Final cost : 0.17574545686500043
# Compute control for a deterministic system
# Cost in iteration 0: 4.358905530043869
# Final cost : 4.357104853630852
# Compute control for a deterministic system
# Cost in iteration 0: 4.357104853630852
# Cost in iteration 200: 0.1980531169670271
# Final cost : 0.1980531169670271
# Compute control for a deterministic system
# Cost in iteration 0: 0.1980531169670271
# Cost in iteration 200: 0.18537758022698847
# Final cost : 0.18537758022698847
# Compute control for a deterministic system
# Cost in iteration 0: 0.18537758022698847
# Cost in iteration 200: 0.18492145641108632
# Final cost : 0.18492145641108632
# Compute control for a deterministic system
# Cost in iteration 0: 0.18492145641108632
# Cost in iteration 200: 0.18480246820317806
# Cost in iteration 400: 0.1847868869192511
# Final cost : 0.1847868869192511
# Compute control for a deterministic system
# Cost in iteration 0: 0.1847868869192511
# Cost in iteration 200: 0.18478445733621612
# Cost in iteration 400: 0.1847838177678944
# Cost in iteration 600: 0.1847836455985726
# Cost in iteration 800: 0.18478359916404588
# Cost in iteration 1000: 0.18478358664397457
# Final cost : 0.18478358664397457
# Compute control for a deterministic system
# Cost in iteration 0: 4.332452409601872
# Final cost : 4.329833763933392
# Compute control for a deterministic system
# Cost in iteration 0: 4.329833763933392
# Cost in iteration 200: 0.1607162354268646
# Final cost : 0.1607162354268646
# Compute control for a deterministic system
# Cost in iteration 0: 0.1607162354268646
# Cost in iteration 200: 0.15500254998419116
# Final cost : 0.15500254998419116
# Compute control for a deterministic system
# Cost in iteration 0: 0.15500254998419116
# Cost in iteration 200: 0.15467928897952585
# Final cost : 0.15467928897952585
# Compute control for a deterministic system
# Cost in iteration 0: 0.15467928897952585
# Cost in iteration 200: 0.15466942398058342
# Cost in iteration 400: 0.15466769929063998
# Final cost : 0.15466769929063998
# Compute control for a deterministic system
# Cost in iteration 0: 0.15466769929063998
# Cost in iteration 200: 0.1546674034014745
# Cost in iteration 400: 0.1546673346997311
# Cost in iteration 600: 0.15466731870406944
# Cost in iteration 800: 0.15466731494964797
# Cost in iteration 1000: 0.15466731407845158
# Final cost : 0.15466731407845158
# Compute control for a deterministic system
# Cost in iteration 0: 4.2851876418112775
# Final cost : 4.260030833979472
# Compute control for a deterministic system
# Cost in iteration 0: 4.260030833979472
# Cost in iteration 200: 0.15065502700204236
# Final cost : 0.15065502700204236
# Compute control for a deterministic system
# Cost in iteration 0: 0.15065502700204236
# Cost in iteration 200: 0.14644406767248386
# Final cost : 0.14644406767248386
# Compute control for a deterministic system
# Cost in iteration 0: 0.14644406767248386
# Converged in iteration 36 with cost 0.1463061964604197 because of vanishing difference
# Final cost : 0.1463061964604197
# Compute control for a deterministic system
# Cost in iteration 0: 0.1463061964604197
# Cost in iteration 200: 0.14621525105102148
# Cost in iteration 400: 0.146202391800237
# Final cost : 0.146202391800237
# Compute control for a deterministic system
# Cost in iteration 0: 0.146202391800237
# Cost in iteration 200: 0.14620057875342812
# Cost in iteration 400: 0.14620022205590397
# Cost in iteration 600: 0.1462001511612942
# Cost in iteration 800: 0.14620013684829392
# Cost in iteration 1000: 0.14620013399040746
# Final cost : 0.14620013399040746
# Compute control for a deterministic system
# Cost in iteration 0: 4.2142984357605435
# Final cost : 4.129436825962314
# Compute control for a deterministic system
# Cost in iteration 0: 4.129436825962314
# Cost in iteration 200: 0.14090177886129568
# Final cost : 0.14090177886129568
# Compute control for a deterministic system
# Cost in iteration 0: 0.14090177886129568
# Cost in iteration 200: 0.1378853273693214
# Final cost : 0.1378853273693214
# Compute control for a deterministic system
# Cost in iteration 0: 0.1378853273693214
# Cost in iteration 200: 0.13771840149273148
# Final cost : 0.13771840149273148
# Compute control for a deterministic system
# Cost in iteration 0: 0.13771840149273148
# Cost in iteration 200: 0.13771438749169565
# Cost in iteration 400: 0.13771383961216105
# Final cost : 0.13771383961216105
# Compute control for a deterministic system
# Cost in iteration 0: 0.13771383961216105
# Cost in iteration 200: 0.13771377055202147
# Cost in iteration 400: 0.13771375900458124
# Cost in iteration 600: 0.13771375706941386
# Cost in iteration 800: 0.1377137567446228
# Cost in iteration 1000: 0.13771375669007638
# Final cost : 0.13771375669007638
# Compute control for a deterministic system
# Cost in iteration 0: 4.115728773825471
# Final cost : 3.9151707018077184
# Compute control for a deterministic system
# Cost in iteration 0: 3.9151707018077184
# Cost in iteration 200: 0.13149985062097846
# Final cost : 0.13149985062097846
# Compute control for a deterministic system
# Cost in iteration 0: 0.13149985062097846
# Cost in iteration 200: 0.1293085110838784
# Final cost : 0.1293085110838784
# Compute control for a deterministic system
# Cost in iteration 0: 0.1293085110838784
# Converged in iteration 6 with cost 0.12930558704971143 because of vanishing difference
# Final cost : 0.12930558704971143
# Compute control for a deterministic system
# Cost in iteration 0: 0.12930558704971143
# Cost in iteration 200: 0.12921688266886627
# Cost in iteration 400: 0.12920937496113644
# Final cost : 0.12920937496113644
# Compute control for a deterministic system
# Cost in iteration 0: 0.12920937496113644
# Cost in iteration 200: 0.12920864267744098
# Cost in iteration 400: 0.12920854640018364
# Cost in iteration 600: 0.12920853337661287
# Cost in iteration 800: 0.12920853161581755
# Cost in iteration 1000: 0.1292085313771835
# Final cost : 0.1292085313771835
# Compute control for a deterministic system
# Cost in iteration 0: 3.9845108758414565
# Final cost : 3.591466030028081
# Compute control for a deterministic system
# Cost in iteration 0: 3.591466030028081
# Cost in iteration 200: 0.12228695792691857
# Final cost : 0.12228695792691857
# Compute control for a deterministic system
# Cost in iteration 0: 0.12228695792691857
# Cost in iteration 200: 0.12074285035816636
# Final cost : 0.12074285035816636
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074285035816636
# Cost in iteration 200: 0.12068502508138211
# Final cost : 0.12068502508138211
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068502508138211
# Cost in iteration 200: 0.12068426301728048
# Cost in iteration 400: 0.12068420099697041
# Final cost : 0.12068420099697041
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068420099697041
# Cost in iteration 200: 0.12068419580195991
# Cost in iteration 400: 0.12068419525376448
# Cost in iteration 600: 0.12068419519635663
# Cost in iteration 800: 0.12068419519013415
# Converged in iteration 812 with cost 0.1206841951900574 because of step counter
# Final cost : 0.1206841951900574
# Compute control for a deterministic system
# Cost in iteration 0: 3.8154375867401336
# Final cost : 3.144904635630231
# Compute control for a deterministic system
# Cost in iteration 0: 3.144904635630231
# Cost in iteration 200: 0.11322070692932745
# Final cost : 0.11322070692932745
# Compute control for a deterministic system
# Cost in iteration 0: 0.11322070692932745
# Cost in iteration 200: 0.11217032038650214
# Final cost : 0.11217032038650214
# Compute control for a deterministic system
# Cost in iteration 0: 0.11217032038650214
# Cost in iteration 200: 0.1121410021744825
# Final cost : 0.1121410021744825
# Compute control for a deterministic system
# Cost in iteration 0: 0.1121410021744825
# Cost in iteration 200: 0.1121407610761693
# Cost in iteration 400: 0.11214074760091669
# Final cost : 0.11214074760091669
# Compute control for a deterministic system
# Cost in iteration 0: 0.11214074760091669
# Cost in iteration 200: 0.11214074683865019
# Cost in iteration 400: 0.11214074678017172
# Converged in iteration 590 with cost 0.11214074677539117 because of step counter
# Final cost : 0.11214074677539117
# Compute control for a deterministic system
# Cost in iteration 0: 3.604144735944816
# Final cost : 2.5944537536439123
# Compute control for a deterministic system
# Cost in iteration 0: 2.5944537536439123
# Cost in iteration 200: 0.10426237295406827
# Final cost : 0.10426237295406827
# Compute control for a deterministic system
# Cost in iteration 0: 0.10426237295406827
# Cost in iteration 200: 0.10359137044272025
# Final cost : 0.10359137044272025
# Compute control for a deterministic system
# Cost in iteration 0: 0.10359137044272025
# Converged in iteration 6 with cost 0.10358976066268312 because of vanishing difference
# Final cost : 0.10358976066268312
# Compute control for a deterministic system
# Cost in iteration 0: 0.10358976066268312
# Cost in iteration 200: 0.1035783734857033
# Cost in iteration 400: 0.1035779778776324
# Final cost : 0.1035779778776324
# Compute control for a deterministic system
# Cost in iteration 0: 0.1035779778776324
# Cost in iteration 200: 0.10357796298576416
# Cost in iteration 400: 0.1035779621980812
# Cost in iteration 600: 0.10357796215557499
# Converged in iteration 706 with cost 0.10357796215330936 because of step counter
# Final cost : 0.10357796215330936
# Compute control for a deterministic system
# Cost in iteration 0: 3.3483749497864523
# Final cost : 1.9944538224750232
# Compute control for a deterministic system
# Cost in iteration 0: 1.9944538224750232
# Cost in iteration 200: 0.09540716687849377
# Final cost : 0.09540716687849377
# Compute control for a deterministic system
# Cost in iteration 0: 0.09540716687849377
# Cost in iteration 200: 0.09500016751138093
# Final cost : 0.09500016751138093
# Compute control for a deterministic system
# Cost in iteration 0: 0.09500016751138093
# Cost in iteration 200: 0.09499473098488471
# Final cost : 0.09499473098488471
# Compute control for a deterministic system
# Cost in iteration 0: 0.09499473098488471
# Cost in iteration 200: 0.0949947152388879
# Cost in iteration 400: 0.09499471483362736
# Final cost : 0.09499471483362736
# Compute control for a deterministic system
# Cost in iteration 0: 0.09499471483362736
# Converged in iteration 185 with cost 0.09499471482308149 because of step counter
# Final cost : 0.09499471482308149
# Compute control for a deterministic system
# Cost in iteration 0: 3.0486702897165356
# Final cost : 1.4136246063018223
# Compute control for a deterministic system
# Cost in iteration 0: 1.4136246063018223
# Cost in iteration 200: 0.08670792442448087
# Final cost : 0.08670792442448087
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670792442448087
# Cost in iteration 200: 0.08639194608666778
# Final cost : 0.08639194608666778
# Compute control for a deterministic system
# Cost in iteration 0: 0.08639194608666778
# Cost in iteration 200: 0.08638952961721268
# Final cost : 0.08638952961721268
# Compute control for a deterministic system
# Cost in iteration 0: 0.08638952961721268
# Cost in iteration 200: 0.08638952765921695
# Cost in iteration 400: 0.08638952763800353
# Final cost : 0.08638952763800353
# Compute control for a deterministic system
# Cost in iteration 0: 0.08638952763800353
# Converged in iteration 8 with cost 0.08638952763796634 because of step counter
# Final cost : 0.08638952763796634
# Compute control for a deterministic system
# Cost in iteration 0: 2.7001876837649705
# Final cost : 0.8999869438670625
# Compute control for a deterministic system
# Cost in iteration 0: 0.8999869438670625
# Cost in iteration 200: 0.07769617399294454
# Final cost : 0.07769617399294454
# Compute control for a deterministic system
# Cost in iteration 0: 0.07769617399294454
# Converged in iteration 198 with cost 0.0775768240528979 because of vanishing difference
# Final cost : 0.0775768240528979
# Compute control for a deterministic system
# Cost in iteration 0: 0.0775768240528979
# Cost in iteration 200: 0.07757628839117751
# Final cost : 0.07757628839117751
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757628839117751
# Cost in iteration 200: 0.07757628827702778
# Converged in iteration 220 with cost 0.07757628827674713 because of step counter
# Final cost : 0.07757628827674713
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757628827674713
# Converged in iteration 3 with cost 0.07757628827673291 because of step counter
# Final cost : 0.07757628827673291
# Compute control for a deterministic system
# Cost in iteration 0: 2.323451285711982
# Final cost : 0.5107754148162746
# Compute control for a deterministic system
# Cost in iteration 0: 0.5107754148162746
# Cost in iteration 200: 0.06897129291579637
# Final cost : 0.06897129291579637
# Compute control for a deterministic system
# Cost in iteration 0: 0.06897129291579637
# Converged in iteration 35 with cost 0.0689322293067521 because of vanishing difference
# Final cost : 0.0689322293067521
# Compute control for a deterministic system
# Cost in iteration 0: 0.0689322293067521
# Cost in iteration 200: 0.06892264248145574
# Final cost : 0.06892264248145574
# Compute control for a deterministic system
# Cost in iteration 0: 0.06892264248145574
# Cost in iteration 200: 0.068922640471041
# Converged in iteration 309 with cost 0.0689226404650239 because of vanishing difference
# Final cost : 0.0689226404650239
# Compute control for a deterministic system
# Cost in iteration 0: 0.0689226404650239
# Converged in iteration 24 with cost 0.06892264046481138 because of step counter
# Final cost : 0.06892264046481138
# Compute control for a deterministic system
# Cost in iteration 0: 1.9241059402832839
# Final cost : 0.24840936434560001
# Compute control for a deterministic system
# Cost in iteration 0: 0.24840936434560001
# Cost in iteration 200: 0.060268521400999316
# Final cost : 0.060268521400999316
# Compute control for a deterministic system
# Cost in iteration 0: 0.060268521400999316
# Converged in iteration 89 with cost 0.06025071758330107 because of vanishing difference
# Final cost : 0.06025071758330107
# Compute control for a deterministic system
# Cost in iteration 0: 0.06025071758330107
# Cost in iteration 200: 0.060250224922099804
# Final cost : 0.060250224922099804
# Compute control for a deterministic system
# Cost in iteration 0: 0.060250224922099804
# Converged in iteration 171 with cost 0.06025022488739776 because of step counter
# Final cost : 0.06025022488739776
# Compute control for a deterministic system
# Cost in iteration 0: 0.06025022488739776
# Converged in iteration 1 with cost 0.06025022488739776 because of step counter
# Final cost : 0.06025022488739776
# Compute control for a deterministic system
# Cost in iteration 0: 1.519326786374221
# Final cost : 0.10588170173062834
# Compute control for a deterministic system
# Cost in iteration 0: 0.10588170173062834
# Cost in iteration 200: 0.0515723159752371
# Final cost : 0.0515723159752371
# Compute control for a deterministic system
# Cost in iteration 0: 0.0515723159752371
# Converged in iteration 24 with cost 0.05156783275672743 because of vanishing difference
# Final cost : 0.05156783275672743
# Compute control for a deterministic system
# Cost in iteration 0: 0.05156783275672743
# Cost in iteration 200: 0.05156703400881507
# Final cost : 0.05156703400881507
# Compute control for a deterministic system
# Cost in iteration 0: 0.05156703400881507
# Converged in iteration 99 with cost 0.05156703400442195 because of step counter
# Final cost : 0.05156703400442195
# Compute control for a deterministic system
# Cost in iteration 0: 0.05156703400442195
# Converged in iteration 2 with cost 0.05156703400441894 because of step counter
# Final cost : 0.05156703400441894
# Compute control for a deterministic system
# Cost in iteration 0: 1.1271663711067634
# Final cost : 0.05015803209110639
# Compute control for a deterministic system
# Cost in iteration 0: 0.05015803209110639
# Cost in iteration 200: 0.042882409698269404
# Final cost : 0.042882409698269404
# Compute control for a deterministic system
# Cost in iteration 0: 0.042882409698269404
# Cost in iteration 200: 0.042881824179458114
# Final cost : 0.042881824179458114
# Compute control for a deterministic system
# Cost in iteration 0: 0.042881824179458114
# Converged in iteration 74 with cost 0.04288182417115573 because of step counter
# Final cost : 0.04288182417115573
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288182417115573
# Converged in iteration 2 with cost 0.042881824171155464 because of step counter
# Final cost : 0.042881824171155464
# Compute control for a deterministic system
# Cost in iteration 0: 0.042881824171155464
# Converged in iteration 1 with cost 0.042881824171155464 because of step counter
# Final cost : 0.042881824171155464
# Compute control for a deterministic system
# Cost in iteration 0: 0.7657914944624007
# Final cost : 0.045824338362084396
# Compute control for a deterministic system
# Cost in iteration 0: 0.045824338362084396
# Cost in iteration 200: 0.03420209675452538
# Final cost : 0.03420209675452538
# Compute control for a deterministic system
# Cost in iteration 0: 0.03420209675452538
# Converged in iteration 180 with cost 0.03420205962128356 because of step counter
# Final cost : 0.03420205962128356
# Compute control for a deterministic system
# Cost in iteration 0: 0.03420205962128356
# Converged in iteration 1 with cost 0.03420205962128356 because of step counter
# Final cost : 0.03420205962128356
# Compute control for a deterministic system
# Cost in iteration 0: 0.03420205962128356
# Converged in iteration 1 with cost 0.03420205962128356 because of step counter
# Final cost : 0.03420205962128356
# Compute control for a deterministic system
# Cost in iteration 0: 0.03420205962128356
# Converged in iteration 2 with cost 0.034202059621280256 because of step counter
# Final cost : 0.034202059621280256
# Compute control for a deterministic system
# Cost in iteration 0: 0.45387969386113847
# Final cost : 0.056429652297991184
# Compute control for a deterministic system
# Cost in iteration 0: 0.056429652297991184
# Cost in iteration 200: 0.025534118463705777
# Final cost : 0.025534118463705777
# Compute control for a deterministic system
# Cost in iteration 0: 0.025534118463705777
# Converged in iteration 65 with cost 0.025534118091451008 because of step counter
# Final cost : 0.025534118091451008
# Compute control for a deterministic system
# Cost in iteration 0: 0.025534118091451008
# Converged in iteration 1 with cost 0.025534118091451008 because of step counter
# Final cost : 0.025534118091451008
# Compute control for a deterministic system
# Cost in iteration 0: 0.025534118091451008
# Converged in iteration 1 with cost 0.025534118091451008 because of step counter
# Final cost : 0.025534118091451008
# Compute control for a deterministic system
# Cost in iteration 0: 0.025534118091451008
# Converged in iteration 1 with cost 0.025534118091451008 because of step counter
# Final cost : 0.025534118091451008
# Compute control for a deterministic system
# Cost in iteration 0: 0.21061070491315015
# Final cost : 0.05120727824778362
# Compute control for a deterministic system
# Cost in iteration 0: 0.05120727824778362
# Converged in iteration 195 with cost 0.016885942312046435 because of step counter
# Final cost : 0.016885942312046435
# Compute control for a deterministic system
# Cost in iteration 0: 0.016885942312046435
# Converged in iteration 4 with cost 0.016885942311977986 because of step counter
# Final cost : 0.016885942311977986
# Compute control for a deterministic system
# Cost in iteration 0: 0.016885942311977986
# Converged in iteration 5 with cost 0.01688594231197362 because of step counter
# Final cost : 0.01688594231197362
# Compute control for a deterministic system
# Cost in iteration 0: 0.01688594231197362
# Converged in iteration 1 with cost 0.01688594231197362 because of step counter
# Final cost : 0.01688594231197362
# Compute control for a deterministic system
# Cost in iteration 0: 0.01688594231197362
# Converged in iteration 1 with cost 0.01688594231197362 because of step counter
# Final cost : 0.01688594231197362
# Compute control for a deterministic system
# Cost in iteration 0: 0.054466149286279276
# Final cost : 0.024342462646107413
# Compute control for a deterministic system
# Cost in iteration 0: 0.024342462646107413
# Converged in iteration 95 with cost 0.00827222751350696 because of step counter
# Final cost : 0.00827222751350696
# Compute control for a deterministic system
# Cost in iteration 0: 0.00827222751350696
# Converged in iteration 1 with cost 0.00827222751350696 because of step counter
# Final cost : 0.00827222751350696
# Compute control for a deterministic system
# Cost in iteration 0: 0.00827222751350696
# Converged in iteration 2 with cost 0.008272227513506475 because of step counter
# Final cost : 0.008272227513506475
# Compute control for a deterministic system
# Cost in iteration 0: 0.008272227513506475
# Converged in iteration 1 with cost 0.008272227513506475 because of step counter
# Final cost : 0.008272227513506475
# Compute control for a deterministic system
# Cost in iteration 0: 0.008272227513506475
# Converged in iteration 1 with cost 0.008272227513506475 because of step counter
# Final cost : 0.008272227513506475
# Compute control for a deterministic system
# Cost in iteration 0: 2.673328107109998e-06
# Converged in iteration 1 with cost 2.673328107109998e-06 because of step counter
# Final cost : 2.673328107109998e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.673328107109998e-06
# Converged in iteration 1 with cost 2.673328107109998e-06 because of step counter
# Final cost : 2.673328107109998e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.07036030655164366
# Converged in iteration 194 with cost 0.01687772133100098 because of step counter
# Final cost : 0.01687772133100098
# Compute control for a deterministic system
# Cost in iteration 0: 0.01687772133100098
# Converged in iteration 5 with cost 0.016877721330974888 because of step counter
# Final cost : 0.016877721330974888
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330974888
# Converged in iteration 1 with cost 0.016877721330974888 because of step counter
# Final cost : 0.016877721330974888
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330974888
# Converged in iteration 1 with cost 0.016877721330974888 because of step counter
# Final cost : 0.016877721330974888
# Compute control for a deterministic system
# Cost in iteration 0: 0.016877721330974888
# Converged in iteration 1 with cost 0.016877721330974888 because of step counter
# Final cost : 0.016877721330974888
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.07743136875973647
# Cost in iteration 200: 0.02557966894230557
# Final cost : 0.02557966894230557
# Compute control for a deterministic system
# Cost in iteration 0: 0.02557966894230557
# Converged in iteration 44 with cost 0.025579668892316425 because of step counter
# Final cost : 0.025579668892316425
# Compute control for a deterministic system
# Cost in iteration 0: 0.025579668892316425
# Converged in iteration 2 with cost 0.0255796688923157 because of step counter
# Final cost : 0.0255796688923157
# Compute control for a deterministic system
# Cost in iteration 0: 0.0255796688923157
# Converged in iteration 1 with cost 0.0255796688923157 because of step counter
# Final cost : 0.0255796688923157
# Compute control for a deterministic system
# Cost in iteration 0: 0.0255796688923157
# Converged in iteration 1 with cost 0.0255796688923157 because of step counter
# Final cost : 0.0255796688923157
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.08436011181638872
# Cost in iteration 200: 0.0342676915810606
# Final cost : 0.0342676915810606
# Compute control for a deterministic system
# Cost in iteration 0: 0.0342676915810606
# Converged in iteration 119 with cost 0.034267688009292495 because of step counter
# Final cost : 0.034267688009292495
# Compute control for a deterministic system
# Cost in iteration 0: 0.034267688009292495
# Converged in iteration 6 with cost 0.03426768800923559 because of step counter
# Final cost : 0.03426768800923559
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426768800923559
# Converged in iteration 2 with cost 0.03426768800923527 because of step counter
# Final cost : 0.03426768800923527
# Compute control for a deterministic system
# Cost in iteration 0: 0.03426768800923527
# Converged in iteration 8 with cost 0.03426768800920557 because of step counter
# Final cost : 0.03426768800920557
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.09659236191034648
# Cost in iteration 200: 0.042909925734568435
# Final cost : 0.042909925734568435
# Compute control for a deterministic system
# Cost in iteration 0: 0.042909925734568435
# Converged in iteration 197 with cost 0.04290988068760593 because of step counter
# Final cost : 0.04290988068760593
# Compute control for a deterministic system
# Cost in iteration 0: 0.04290988068760593
# Converged in iteration 7 with cost 0.04290988068748835 because of step counter
# Final cost : 0.04290988068748835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04290988068748835
# Converged in iteration 2 with cost 0.042909880687487585 because of step counter
# Final cost : 0.042909880687487585
# Compute control for a deterministic system
# Cost in iteration 0: 0.042909880687487585
# Converged in iteration 7 with cost 0.04290988068746718 because of step counter
# Final cost : 0.04290988068746718
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.10466851788029977
# Cost in iteration 200: 0.05153188193036029
# Final cost : 0.05153188193036029
# Compute control for a deterministic system
# Cost in iteration 0: 0.05153188193036029
# Cost in iteration 200: 0.05153164386761639
# Final cost : 0.05153164386761639
# Compute control for a deterministic system
# Cost in iteration 0: 0.05153164386761639
# Converged in iteration 47 with cost 0.05153164386050699 because of step counter
# Final cost : 0.05153164386050699
# Compute control for a deterministic system
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.14620017039008845
# Cost in iteration 200: 0.14620008877081642
# Cost in iteration 400: 0.14620007961938444
# Final cost : 0.14620007961938444
# Compute control for a deterministic system
# Cost in iteration 0: 0.14620007961938444
# Cost in iteration 200: 0.14620007833528123
# Cost in iteration 400: 0.14620007807770313
# Cost in iteration 600: 0.14620007802607407
# Cost in iteration 800: 0.14620007801572427
# Converged in iteration 874 with cost 0.14620007801401577 because of vanishing difference
# Final cost : 0.14620007801401577
# Compute control for a deterministic system
# Cost in iteration 0: 3.078711598197722
# Cost in iteration 200: 0.1581693923549456
# Final cost : 0.1581693923549456
# Compute control for a deterministic system
# Cost in iteration 0: 0.1581693923549456
# Cost in iteration 200: 0.13788189563545616
# Final cost : 0.13788189563545616
# Compute control for a deterministic system
# Cost in iteration 0: 0.13788189563545616
# Converged in iteration 25 with cost 0.1377886115127877 because of vanishing difference
# Final cost : 0.1377886115127877
# Compute control for a deterministic system
# Cost in iteration 0: 0.1377886115127877
# Cost in iteration 200: 0.13771728061140767
# Cost in iteration 400: 0.13771421731526606
# Final cost : 0.13771421731526606
# Compute control for a deterministic system
# Cost in iteration 0: 0.13771421731526606
# Cost in iteration 200: 0.1377138779286483
# Cost in iteration 400: 0.1377138233595479
# Cost in iteration 600: 0.1377138142604815
# Cost in iteration 800: 0.13771381273547903
# Cost in iteration 1000: 0.13771381247995454
# Final cost : 0.13771381247995454
# Compute control for a deterministic system
# Cost in iteration 0: 0.9205742866212381
# Cost in iteration 200: 0.13039934049560076
# Final cost : 0.13039934049560076
# Compute control for a deterministic system
# Cost in iteration 0: 0.13039934049560076
# Cost in iteration 200: 0.12921854597107846
# Final cost : 0.12921854597107846
# Compute control for a deterministic system
# Cost in iteration 0: 0.12921854597107846
# Cost in iteration 200: 0.12920849803418824
# Final cost : 0.12920849803418824
# Compute control for a deterministic system
# Cost in iteration 0: 0.12920849803418824
# Cost in iteration 200: 0.12920847201059546
# Cost in iteration 400: 0.1292084694861731
# Final cost : 0.1292084694861731
# Compute control for a deterministic system
# Cost in iteration 0: 0.1292084694861731
# Cost in iteration 200: 0.12920846920311796
# Cost in iteration 400: 0.12920846916487838
# Converged in iteration 517 with cost 0.12920846916074316 because of vanishing difference
# Final cost : 0.12920846916074316
# Compute control for a deterministic system
# Cost in iteration 0: 0.32182836074367877
# Cost in iteration 200: 0.12085372709802973
# Final cost : 0.12085372709802973
# Compute control for a deterministic system
# Cost in iteration 0: 0.12085372709802973
# Cost in iteration 200: 0.12068507573363765
# Final cost : 0.12068507573363765
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068507573363765
# Cost in iteration 200: 0.12068416815877749
# Final cost : 0.12068416815877749
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068416815877749
# Cost in iteration 200: 0.12068416688237782
# Cost in iteration 400: 0.1206841668027532
# Final cost : 0.1206841668027532
# Compute control for a deterministic system
# Cost in iteration 0: 0.1206841668027532
# Cost in iteration 200: 0.12068416679654002
# Converged in iteration 241 with cost 0.1206841667959334 because of step counter
# Final cost : 0.1206841667959334
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 4.231747755742026
# Cost in iteration 200: 0.17009826638758518
# Final cost : 0.17009826638758518
# Compute control for a deterministic system
# Cost in iteration 0: 0.17009826638758518
# Cost in iteration 200: 0.11225447990072752
# Final cost : 0.11225447990072752
# Compute control for a deterministic system
# Cost in iteration 0: 0.11225447990072752
# Converged in iteration 27 with cost 0.11218440300633427 because of vanishing difference
# Final cost : 0.11218440300633427
# Compute control for a deterministic system
# Cost in iteration 0: 0.11218440300633427
# Cost in iteration 200: 0.11214222390111207
# Cost in iteration 400: 0.11214090380267287
# Final cost : 0.11214090380267287
# Compute control for a deterministic system
# Cost in iteration 0: 0.11214090380267287
# Cost in iteration 200: 0.1121408402188519
# Cost in iteration 400: 0.11214083534445242
# Cost in iteration 600: 0.11214083496818723
# Cost in iteration 800: 0.11214083493901074
# Converged in iteration 905 with cost 0.11214083493720457 because of step counter
# Final cost : 0.11214083493720457
# Compute control for a deterministic system
# Cost in iteration 0: 3.6453125259441963
# Cost in iteration 200: 0.12744918581099707
# Final cost : 0.12744918581099707
# Compute control for a deterministic system
# Cost in iteration 0: 0.12744918581099707
# Cost in iteration 200: 0.10363122987529312
# Final cost : 0.10363122987529312
# Compute control for a deterministic system
# Cost in iteration 0: 0.10363122987529312
# Converged in iteration 9 with cost 0.10361638494012548 because of vanishing difference
# Final cost : 0.10361638494012548
# Compute control for a deterministic system
# Cost in iteration 0: 0.10361638494012548
# Cost in iteration 200: 0.10357852042753182
# Cost in iteration 400: 0.10357797559295756
# Final cost : 0.10357797559295756
# Compute control for a deterministic system
# Cost in iteration 0: 0.10357797559295756
# Cost in iteration 200: 0.10357795660152391
# Cost in iteration 400: 0.10357795558617637
# Cost in iteration 600: 0.10357795553300266
# Converged in iteration 692 with cost 0.10357795553079545 because of step counter
# Final cost : 0.10357795553079545
# Compute control for a deterministic system
# Cost in iteration 0: 4.385890361856823
# Cost in iteration 200: 0.1517174940320097
# Final cost : 0.1517174940320097
# Compute control for a deterministic system
# Cost in iteration 0: 0.1517174940320097
# Cost in iteration 200: 0.09505054213472035
# Final cost : 0.09505054213472035
# Compute control for a deterministic system
# Cost in iteration 0: 0.09505054213472035
# Cost in iteration 200: 0.09499482296980553
# Final cost : 0.09499482296980553
# Compute control for a deterministic system
# Cost in iteration 0: 0.09499482296980553
# Cost in iteration 200: 0.09499476004278752
# Cost in iteration 400: 0.09499475851223328
# Final cost : 0.09499475851223328
# Compute control for a deterministic system
# Cost in iteration 0: 0.09499475851223328
# Cost in iteration 200: 0.09499475847255041
# Converged in iteration 277 with cost 0.09499475847136062 because of step counter
# Final cost : 0.09499475847136062
# Compute control for a deterministic system
# Cost in iteration 0: 4.827553302226667
# Cost in iteration 200: 0.20907688716807843
# Final cost : 0.20907688716807843
# Compute control for a deterministic system
# Cost in iteration 0: 0.20907688716807843
# Cost in iteration 200: 0.08643779482270368
# Final cost : 0.08643779482270368
# Compute control for a deterministic system
# Cost in iteration 0: 0.08643779482270368
# Converged in iteration 34 with cost 0.08640180198401183 because of vanishing difference
# Final cost : 0.08640180198401183
# Compute control for a deterministic system
# Cost in iteration 0: 0.08640180198401183
# Cost in iteration 200: 0.08638968279243753
# Cost in iteration 400: 0.08638959639866704
# Final cost : 0.08638959639866704
# Compute control for a deterministic system
# Cost in iteration 0: 0.08638959639866704
# Cost in iteration 200: 0.08638959535204352
# Converged in iteration 397 with cost 0.08638959533180195 because of step counter
# Final cost : 0.08638959533180195
# Compute control for a deterministic system
# Cost in iteration 0: 4.38483749622701
# Cost in iteration 200: 0.1210042279422445
# Final cost : 0.1210042279422445
# Compute control for a deterministic system
# Cost in iteration 0: 0.1210042279422445
# Cost in iteration 200: 0.07759193689928139
# Final cost : 0.07759193689928139
# Compute control for a deterministic system
# Cost in iteration 0: 0.07759193689928139
# Cost in iteration 200: 0.07757631181709426
# Final cost : 0.07757631181709426
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757631181709426
# Cost in iteration 200: 0.07757630995394925
# Converged in iteration 294 with cost 0.07757630994641376 because of vanishing difference
# Final cost : 0.07757630994641376
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757630994641376
# Converged in iteration 64 with cost 0.07757630994576262 because of step counter
# Final cost : 0.07757630994576262
# Compute control for a deterministic system
# Cost in iteration 0: 4.680012502383884
# Cost in iteration 200: 0.13553221317799816
# Final cost : 0.13553221317799816
# Compute control for a deterministic system
# Cost in iteration 0: 0.13553221317799816
# Cost in iteration 200: 0.06893478097799617
# Final cost : 0.06893478097799617
# Compute control for a deterministic system
# Cost in iteration 0: 0.06893478097799617
# Cost in iteration 200: 0.06892266243848723
# Final cost : 0.06892266243848723
# Compute control for a deterministic system
# Cost in iteration 0: 0.06892266243848723
# Cost in iteration 200: 0.06892266063965434
# Converged in iteration 327 with cost 0.06892266063423268 because of step counter
# Final cost : 0.06892266063423268
# Compute control for a deterministic system
# Cost in iteration 0: 0.06892266063423268
# Converged in iteration 1 with cost 0.06892266063423268 because of step counter
# Final cost : 0.06892266063423268
# Compute control for a deterministic system
# Cost in iteration 0: 4.333587879772306
# Cost in iteration 200: 0.09166893540625488
# Final cost : 0.09166893540625488
# Compute control for a deterministic system
# Cost in iteration 0: 0.09166893540625488
# Cost in iteration 200: 0.060254172073727956
# Final cost : 0.060254172073727956
# Compute control for a deterministic system
# Cost in iteration 0: 0.060254172073727956
# Cost in iteration 200: 0.060250265114753905
# Final cost : 0.060250265114753905
# Compute control for a deterministic system
# Cost in iteration 0: 0.060250265114753905
# Cost in iteration 200: 0.06025026498154098
# Converged in iteration 203 with cost 0.060250264981518996 because of step counter
# Final cost : 0.060250264981518996
# Compute control for a deterministic system
# Cost in iteration 0: 0.060250264981518996
# Converged in iteration 1 with cost 0.060250264981518996 because of step counter
# Final cost : 0.060250264981518996
# Compute control for a deterministic system
# Cost in iteration 0: 4.228285498527902
# Cost in iteration 200: 0.07447154399223035
# Final cost : 0.07447154399223035
# Compute control for a deterministic system
# Cost in iteration 0: 0.07447154399223035
# Converged in iteration 196 with cost 0.051568106820893155 because of vanishing difference
# Final cost : 0.051568106820893155
# Compute control for a deterministic system
# Cost in iteration 0: 0.051568106820893155
# Cost in iteration 200: 0.05156703700405856
# Final cost : 0.05156703700405856
# Compute control for a deterministic system
# Cost in iteration 0: 0.05156703700405856
# Converged in iteration 42 with cost 0.05156703700111266 because of vanishing difference
# Final cost : 0.05156703700111266
# Compute control for a deterministic system
# Cost in iteration 0: 0.05156703700111266
# Converged in iteration 54 with cost 0.051567037000468136 because of step counter
# Final cost : 0.051567037000468136
# Compute control for a deterministic system
# Cost in iteration 0: 0.043178766598757155
# Cost in iteration 200: 0.042881826645654514
# Final cost : 0.042881826645654514
# Compute control for a deterministic system
# Cost in iteration 0: 0.042881826645654514
# Converged in iteration 132 with cost 0.04288182417114023 because of step counter
# Final cost : 0.04288182417114023
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288182417114023
# Converged in iteration 3 with cost 0.04288182417112949 because of step counter
# Final cost : 0.04288182417112949
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288182417112949
# Converged in iteration 2 with cost 0.04288182417112669 because of step counter
# Final cost : 0.04288182417112669
# Compute control for a deterministic system
# Cost in iteration 0: 0.04288182417112669
# Converged in iteration 1 with cost 0.04288182417112669 because of step counter
# Final cost : 0.04288182417112669
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 4.7928028573873185
# Cost in iteration 200: 0.4777015431563782
# Final cost : 0.4777015431563782
# Compute control for a deterministic system
# Cost in iteration 0: 0.4777015431563782
# Cost in iteration 200: 0.38540657391074196
# Final cost : 0.38540657391074196
# Compute control for a deterministic system
# Cost in iteration 0: 0.38540657391074196
# Cost in iteration 200: 0.37861563921489233
# Final cost : 0.37861563921489233
# Compute control for a deterministic system
# Cost in iteration 0: 0.37861563921489233
# Cost in iteration 200: 0.37762836758652435
# Cost in iteration 400: 0.3771890049134291
# Final cost : 0.3771890049134291
# Compute control for a deterministic system
# Cost in iteration 0: 0.3771890049134291
# Converged in iteration 113 with cost 0.03421108188145983 because of vanishing difference
# Final cost : 0.03421108188145983
# Compute control for a deterministic system
# Cost in iteration 0: 4.651178869832049
# Cost in iteration 200: 0.07996232492401945
# Final cost : 0.07996232492401945
# Compute control for a deterministic system
# Cost in iteration 0: 0.07996232492401945
# Cost in iteration 200: 0.025534119373785743
# Final cost : 0.025534119373785743
# Compute control for a deterministic system
# Cost in iteration 0: 0.025534119373785743
# Converged in iteration 60 with cost 0.02553411924015384 because of step counter
# Final cost : 0.02553411924015384
# Compute control for a deterministic system
# Cost in iteration 0: 0.02553411924015384
# Converged in iteration 1 with cost 0.02553411924015384 because of step counter
# Final cost : 0.02553411924015384
# Compute control for a deterministic system
# Cost in iteration 0: 0.02553411924015384
# Converged in iteration 4 with cost 0.025534119240147767 because of step counter
# Final cost : 0.025534119240147767
# Compute control for a deterministic system
# Cost in iteration 0: 4.562766279988279
# Cost in iteration 200: 0.4565668362521472
# Final cost : 0.4565668362521472
# Compute control for a deterministic system
# Cost in iteration 0: 0.4565668362521472
# Cost in iteration 200: 0.3699481441055462
# Final cost : 0.3699481441055462
# Compute control for a deterministic system
# Cost in iteration 0: 0.3699481441055462
# Cost in iteration 200: 0.3612824794242213
# Final cost : 0.3612824794242213
# Compute control for a deterministic system
# Cost in iteration 0: 0.3612824794242213
# Cost in iteration 200: 0.36052817910898977
# Cost in iteration 400: 0.36022105544787275
# Final cost : 0.36022105544787275
# Compute control for a deterministic system
# Cost in iteration 0: 0.36022105544787275
# Converged in iteration 109 with cost 0.016930721503135612 because of vanishing difference
# Final cost : 0.016930721503135612
# Compute control for a deterministic system
# Cost in iteration 0: 4.424996619407922
# Cost in iteration 200: 0.035906764871325166
# Final cost : 0.035906764871325166
# Compute control for a deterministic system
# Cost in iteration 0: 0.035906764871325166
# Converged in iteration 67 with cost 0.008272237470913196 because of vanishing difference
# Final cost : 0.008272237470913196
# Compute control for a deterministic system
# Cost in iteration 0: 0.008272237470913196
# Converged in iteration 13 with cost 0.00827223509399923 because of step counter
# Final cost : 0.00827223509399923
# Compute control for a deterministic system
# Cost in iteration 0: 0.00827223509399923
# Converged in iteration 1 with cost 0.00827223509399923 because of step counter
# Final cost : 0.00827223509399923
# Compute control for a deterministic system
# Cost in iteration 0: 0.00827223509399923
# Converged in iteration 1 with cost 0.00827223509399923 because of step counter
# Final cost : 0.00827223509399923

# %%
save(results_min)
