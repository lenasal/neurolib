# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,1017], wc.inh[0,1017]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# minima =  [  451  2334  4217  6101  7984  9867 11751 13634 15517 17401 19284 21167
#  23050 24934 26817 28700 30584 32467 34350 36234 38117 40000 41884 43767
#  45650 47534 49417 51300 53184 55067 56950 58834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("b_s3_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("b_s3_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05362677462567759
# Final cost : 0.01139501674027176
# Compute control for a deterministic system
# Cost in iteration 0: 0.01139501674027176
# Final cost : 3.941695788653498e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.941695788653498e-05
# Final cost : 3.738086818373671e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.738086818373671e-05
# Final cost : 3.73233391851571e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.73233391851571e-05
# Converged in iteration 377 with cost 3.732246984081814e-05 because of step counter
# Final cost : 3.732246984081814e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.732246984081814e-05
# Converged in iteration 2 with cost 3.732246984081533e-05 because of step counter
# Final cost : 3.732246984081533e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.208456458857865
# Final cost : 0.026172343688657375
# Compute control for a deterministic system
# Cost in iteration 0: 0.026172343688657375
# Final cost : 0.00016415661317568513
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016415661317568513
# Final cost : 0.0001500689284809596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001500689284809596
# Final cost : 0.00014961286279554899
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014961286279554899
# Final cost : 0.0001495992544222976
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001495992544222976
# Converged in iteration 1251 with cost 0.00014959843213840313 because of step counter
# Final cost : 0.00014959843213840313
# Compute control for a deterministic system
# Cost in iteration 0: 0.4492251857960263
# Final cost : 0.02188705189731772
# Compute control for a deterministic system
# Cost in iteration 0: 0.02188705189731772
# Final cost : 0.0003828537175368688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003828537175368688
# Final cost : 0.0003385029705753756
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003385029705753756
# Final cost : 0.0003372302152655381
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003372302152655381
# Converged in iteration 265 with cost 0.0003372020833650497 because of step counter
# Final cost : 0.0003372020833650497
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003372020833650497
# Converged in iteration 43 with cost 0.0003372020833357662 because of step counter
# Final cost : 0.0003372020833357662
# Compute control for a deterministic system
# Cost in iteration 0: 0.7559722325801564
# Final cost : 0.005767962561991857
# Compute control for a deterministic system
# Cost in iteration 0: 0.005767962561991857
# Final cost : 0.0006987437235828865
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006987437235828865
# Final cost : 0.0006022780515788491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006022780515788491
# Final cost : 0.0005999308704592585
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005999308704592585
# Final cost : 0.0005999269456294866
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005999269456294866
# Final cost : 0.0005999267209420347
# Compute control for a deterministic system
# Cost in iteration 0: 1.1076473431570795
# Final cost : 0.003293650032462261
# Compute control for a deterministic system
# Cost in iteration 0: 0.003293650032462261
# Final cost : 0.001101484462525224
# Compute control for a deterministic system
# Cost in iteration 0: 0.001101484462525224
# Final cost : 0.0009418839550997736
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009418839550997736
# Final cost : 0.0009369843321211267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009369843321211267
# Final cost : 0.0009365822634885382
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009365822634885382
# Final cost : 0.0009365766291111336
# Compute control for a deterministic system
# Cost in iteration 0: 1.4850110202516826
# Final cost : 0.04463033451608726
# Compute control for a deterministic system
# Cost in iteration 0: 0.04463033451608726
# Final cost : 0.001601998485452011
# Compute control for a deterministic system
# Cost in iteration 0: 0.001601998485452011
# Final cost : 0.0013526869617201764
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013526869617201764
# Final cost : 0.001345786795365158
# Compute control for a deterministic system
# Cost in iteration 0: 0.001345786795365158
# Final cost : 0.001345271510763183
# Compute control for a deterministic system
# Cost in iteration 0: 0.001345271510763183
# Final cost : 0.001345243432983197
# Compute control for a deterministic system
# Cost in iteration 0: 1.8798040700027128
# Final cost : 0.17007573088158556
# Compute control for a deterministic system
# Cost in iteration 0: 0.17007573088158556
# Final cost : 0.0022101292620744298
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022101292620744298
# Final cost : 0.0018448437816651815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018448437816651815
# Final cost : 0.0018356474507322913
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018356474507322913
# Final cost : 0.0018350875139881621
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018350875139881621
# Final cost : 0.0018350519432500424
# Compute control for a deterministic system
# Cost in iteration 0: 2.2613541315895733
# Final cost : 0.3966074748545786
# Compute control for a deterministic system
# Cost in iteration 0: 0.3966074748545786
# Final cost : 0.002909671465789272
# Compute control for a deterministic system
# Cost in iteration 0: 0.002909671465789272
# Final cost : 0.00240016874109171
# Compute control for a deterministic system
# Cost in iteration 0: 0.00240016874109171
# Final cost : 0.0023861091907533727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023861091907533727
# Final cost : 0.0023849827935661745
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023849827935661745
# Final cost : 0.0023849774312703366
# Compute control for a deterministic system
# Cost in iteration 0: 2.6259068586367484
# Final cost : 0.7332455950520251
# Compute control for a deterministic system
# Cost in iteration 0: 0.7332455950520251
# Final cost : 0.0037239704579398315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037239704579398315
# Final cost : 0.0030263130989728795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030263130989728795
# Final cost : 0.0030069578936311103
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030069578936311103
# Final cost : 0.0030057873990667755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030057873990667755
# Final cost : 0.003005729209901567
# Compute control for a deterministic system
# Cost in iteration 0: 2.963434887481866
# Final cost : 1.1711420850909258
# Compute control for a deterministic system
# Cost in iteration 0: 1.1711420850909258
# Final cost : 0.004662740593914192
# Compute control for a deterministic system
# Cost in iteration 0: 0.004662740593914192
# Final cost : 0.003727199835484062
# Compute control for a deterministic system
# Cost in iteration 0: 0.003727199835484062
# Final cost : 0.0037017839086001055
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037017839086001055
# Final cost : 0.003699916445129558
# Compute control for a deterministic system
# Cost in iteration 0: 0.003699916445129558
# Final cost : 0.0036997827786763725
# Compute control for a deterministic system
# Cost in iteration 0: 3.2661323952682837
# Final cost : 1.6841384352071038
# Compute control for a deterministic system
# Cost in iteration 0: 1.6841384352071038
# Final cost : 0.005732668549490185
# Compute control for a deterministic system
# Cost in iteration 0: 0.005732668549490185
# Final cost : 0.004503775208772452
# Compute control for a deterministic system
# Cost in iteration 0: 0.004503775208772452
# Final cost : 0.004471803388969602
# Compute control for a deterministic system
# Cost in iteration 0: 0.004471803388969602
# Final cost : 0.004469795409494688
# Compute control for a deterministic system
# Cost in iteration 0: 0.004469795409494688
# Final cost : 0.004469633949085361
# Compute control for a deterministic system
# Cost in iteration 0: 3.5289805713308553
# Final cost : 2.2297016112568246
# Compute control for a deterministic system
# Cost in iteration 0: 2.2297016112568246
# Final cost : 0.0069398376393995514
# Compute control for a deterministic system
# Cost in iteration 0: 0.0069398376393995514
# Final cost : 0.005365072609089997
# Compute control for a deterministic system
# Cost in iteration 0: 0.005365072609089997
# Final cost : 0.00532000414570518
# Compute control for a deterministic system
# Cost in iteration 0: 0.00532000414570518
# Final cost : 0.005317262700361915
# Compute control for a deterministic system
# Cost in iteration 0: 0.005317262700361915
# Final cost : 0.00531703778519154
# Compute control for a deterministic system
# Cost in iteration 0: 3.7501580681946662
# Final cost : 2.756247858278054
# Compute control for a deterministic system
# Cost in iteration 0: 2.756247858278054
# Final cost : 0.008293454431975517
# Compute control for a deterministic system
# Cost in iteration 0: 0.008293454431975517
# Final cost : 0.006303440597850871
# Compute control for a deterministic system
# Cost in iteration 0: 0.006303440597850871
# Final cost : 0.006246668033447503
# Compute control for a deterministic system
# Cost in iteration 0: 0.006246668033447503
# Final cost : 0.006243284249947589
# Compute control for a deterministic system
# Cost in iteration 0: 0.006243284249947589
# Final cost : 0.006242957043186984
# Compute control for a deterministic system
# Cost in iteration 0: 3.9308119961270354
# Final cost : 3.218001044258531
# Compute control for a deterministic system
# Cost in iteration 0: 3.218001044258531
# Final cost : 0.009805406438334278
# Compute control for a deterministic system
# Cost in iteration 0: 0.009805406438334278
# Final cost : 0.007324240015645635
# Compute control for a deterministic system
# Cost in iteration 0: 0.007324240015645635
# Final cost : 0.007253127785011651
# Compute control for a deterministic system
# Cost in iteration 0: 0.007253127785011651
# Final cost : 0.007248307376152374
# Compute control for a deterministic system
# Cost in iteration 0: 0.007248307376152374
# Final cost : 0.007247820612421207
# Compute control for a deterministic system
# Cost in iteration 0: 4.0741319299451435
# Final cost : 3.589529465712352
# Compute control for a deterministic system
# Cost in iteration 0: 3.589529465712352
# Final cost : 0.011487075260425769
# Compute control for a deterministic system
# Cost in iteration 0: 0.011487075260425769
# Final cost : 0.00843028323596201
# Compute control for a deterministic system
# Cost in iteration 0: 0.00843028323596201
# Final cost : 0.008342894650626922
# Compute control for a deterministic system
# Cost in iteration 0: 0.008342894650626922
# Final cost : 0.008332994809448187
# Compute control for a deterministic system
# Cost in iteration 0: 0.008332994809448187
# Final cost : 0.008331862576655299
# Compute control for a deterministic system
# Cost in iteration 0: 4.184204520809734
# Final cost : 3.869100256030288
# Compute control for a deterministic system
# Cost in iteration 0: 3.869100256030288
# Final cost : 0.01335038350744985
# Compute control for a deterministic system
# Cost in iteration 0: 0.01335038350744985
# Final cost : 0.009622202997914464
# Compute control for a deterministic system
# Cost in iteration 0: 0.009622202997914464
# Final cost : 0.009510130988813845
# Compute control for a deterministic system
# Cost in iteration 0: 0.009510130988813845
# Final cost : 0.009496878334766692
# Compute control for a deterministic system
# Cost in iteration 0: 0.009496878334766692
# Final cost : 0.009495224722985333
# Compute control for a deterministic system
# Cost in iteration 0: 4.2651305527325825
# Final cost : 4.069611618873328
# Compute control for a deterministic system
# Cost in iteration 0: 4.069611618873328
# Final cost : 0.015410454794848547
# Compute control for a deterministic system
# Cost in iteration 0: 0.015410454794848547
# Final cost : 0.01090057331110367
# Compute control for a deterministic system
# Cost in iteration 0: 0.01090057331110367
# Final cost : 0.010759018400970276
# Compute control for a deterministic system
# Cost in iteration 0: 0.010759018400970276
# Final cost : 0.010740805798927553
# Compute control for a deterministic system
# Cost in iteration 0: 0.010740805798927553
# Final cost : 0.010738126883673402
# Compute control for a deterministic system
# Cost in iteration 0: 4.320545433780196
# Final cost : 4.207300942502433
# Compute control for a deterministic system
# Cost in iteration 0: 4.207300942502433
# Final cost : 0.017686217511708468
# Compute control for a deterministic system
# Cost in iteration 0: 0.017686217511708468
# Final cost : 0.012276404900490092
# Compute control for a deterministic system
# Cost in iteration 0: 0.012276404900490092
# Final cost : 0.012088412664600512
# Compute control for a deterministic system
# Cost in iteration 0: 0.012088412664600512
# Final cost : 0.012064576406780506
# Compute control for a deterministic system
# Cost in iteration 0: 0.012064576406780506
# Final cost : 0.012060794452574497
# Compute control for a deterministic system
# Cost in iteration 0: 4.3539003652087755
# Final cost : 4.297086432746504
# Compute control for a deterministic system
# Cost in iteration 0: 4.297086432746504
# Final cost : 0.020256556703699555
# Compute control for a deterministic system
# Cost in iteration 0: 0.020256556703699555
# Final cost : 0.013763165925400583
# Compute control for a deterministic system
# Cost in iteration 0: 0.013763165925400583
# Final cost : 0.013539604922656042
# Compute control for a deterministic system
# Cost in iteration 0: 0.013539604922656042
# Final cost : 0.013501066515353712
# Compute control for a deterministic system
# Cost in iteration 0: 0.013501066515353712
# Final cost : 0.013494486648558082
# Compute control for a deterministic system
# Cost in iteration 0: 4.366009911157753
# Final cost : 4.344260835094972
# Compute control for a deterministic system
# Cost in iteration 0: 4.344260835094972
# Final cost : 0.02304681867198761
# Compute control for a deterministic system
# Cost in iteration 0: 0.02304681867198761
# Final cost : 0.015312073082835857
# Compute control for a deterministic system
# Cost in iteration 0: 0.015312073082835857
# Final cost : 0.015039059061292864
# Compute control for a deterministic system
# Cost in iteration 0: 0.015039059061292864
# Final cost : 0.014989023971178864
# Compute control for a deterministic system
# Cost in iteration 0: 0.014989023971178864
# Final cost : 0.014979658014945635
# Compute control for a deterministic system
# Cost in iteration 0: 4.358905530043869
# Final cost : 4.3549677765045605
# Compute control for a deterministic system
# Cost in iteration 0: 4.3549677765045605
# Final cost : 0.026175122515317388
# Compute control for a deterministic system
# Cost in iteration 0: 0.026175122515317388
# Final cost : 0.016936467408606055
# Compute control for a deterministic system
# Cost in iteration 0: 0.016936467408606055
# Final cost : 0.016620574583488663
# Compute control for a deterministic system
# Cost in iteration 0: 0.016620574583488663
# Final cost : 0.01655882211191626
# Compute control for a deterministic system
# Cost in iteration 0: 0.01655882211191626
# Final cost : 0.016545893371921343
# Compute control for a deterministic system
# Cost in iteration 0: 4.332452409601872
# Final cost : 4.327547175300972
# Compute control for a deterministic system
# Cost in iteration 0: 4.327547175300972
# Final cost : 0.017289361828219954
# Compute control for a deterministic system
# Cost in iteration 0: 0.017289361828219954
# Final cost : 0.01194027144903694
# Compute control for a deterministic system
# Cost in iteration 0: 0.01194027144903694
# Final cost : 0.011685846339450016
# Compute control for a deterministic system
# Cost in iteration 0: 0.011685846339450016
# Final cost : 0.011669232077271897
# Compute control for a deterministic system
# Cost in iteration 0: 0.011669232077271897
# Final cost : 0.011668410416087828
# Compute control for a deterministic system
# Cost in iteration 0: 4.2851876418112775
# Final cost : 4.25407481728599
# Compute control for a deterministic system
# Cost in iteration 0: 4.25407481728599
# Final cost : 0.015049163392041836
# Compute control for a deterministic system
# Cost in iteration 0: 0.015049163392041836
# Final cost : 0.010656524854579963
# Compute control for a deterministic system
# Cost in iteration 0: 0.010656524854579963
# Final cost : 0.010459958201836383
# Compute control for a deterministic system
# Cost in iteration 0: 0.010459958201836383
# Final cost : 0.010439015574420653
# Compute control for a deterministic system
# Cost in iteration 0: 0.010439015574420653
# Final cost : 0.010432653542559374
# Compute control for a deterministic system
# Cost in iteration 0: 4.2142984357605435
# Final cost : 4.119202328918159
# Compute control for a deterministic system
# Cost in iteration 0: 4.119202328918159
# Final cost : 0.01308592744712327
# Compute control for a deterministic system
# Cost in iteration 0: 0.01308592744712327
# Final cost : 0.009446092961077183
# Compute control for a deterministic system
# Cost in iteration 0: 0.009446092961077183
# Final cost : 0.009274785480304727
# Compute control for a deterministic system
# Cost in iteration 0: 0.009274785480304727
# Final cost : 0.009266109883088125
# Compute control for a deterministic system
# Cost in iteration 0: 0.009266109883088125
# Final cost : 0.009263637642076654
# Compute control for a deterministic system
# Cost in iteration 0: 4.115728773825471
# Final cost : 3.899968601042163
# Compute control for a deterministic system
# Cost in iteration 0: 3.899968601042163
# Final cost : 0.011311949804248768
# Compute control for a deterministic system
# Cost in iteration 0: 0.011311949804248768
# Final cost : 0.008309116404771576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008309116404771576
# Final cost : 0.008179544859761158
# Compute control for a deterministic system
# Cost in iteration 0: 0.008179544859761158
# Final cost : 0.00816518637846297
# Compute control for a deterministic system
# Cost in iteration 0: 0.00816518637846297
# Final cost : 0.008161789994470607
# Compute control for a deterministic system
# Cost in iteration 0: 3.9845108758414565
# Final cost : 3.5705962180244946
# Compute control for a deterministic system
# Cost in iteration 0: 3.5705962180244946
# Final cost : 0.009701589532114202
# Compute control for a deterministic system
# Cost in iteration 0: 0.009701589532114202
# Final cost : 0.0072407836854154715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0072407836854154715
# Final cost : 0.0071304535944747525
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071304535944747525
# Final cost : 0.0071281354363036545
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071281354363036545
# Final cost : 0.007127462800786555
# Compute control for a deterministic system
# Cost in iteration 0: 3.8154375867401336
# Final cost : 3.117751175574
# Compute control for a deterministic system
# Cost in iteration 0: 3.117751175574
# Final cost : 0.008241198353641916
# Compute control for a deterministic system
# Cost in iteration 0: 0.008241198353641916
# Final cost : 0.0062550102792613286
# Compute control for a deterministic system
# Cost in iteration 0: 0.0062550102792613286
# Final cost : 0.006170502113134348
# Compute control for a deterministic system
# Cost in iteration 0: 0.006170502113134348
# Final cost : 0.006162770756100397
# Compute control for a deterministic system
# Cost in iteration 0: 0.006162770756100397
# Final cost : 0.006161137817919613
# Compute control for a deterministic system
# Cost in iteration 0: 3.604144735944816
# Final cost : 2.5606584309973814
# Compute control for a deterministic system
# Cost in iteration 0: 2.5606584309973814
# Final cost : 0.006920208225449906
# Compute control for a deterministic system
# Cost in iteration 0: 0.006920208225449906
# Final cost : 0.005329353050521102
# Compute control for a deterministic system
# Cost in iteration 0: 0.005329353050521102
# Final cost : 0.005269777356129209
# Compute control for a deterministic system
# Cost in iteration 0: 0.005269777356129209
# Final cost : 0.005264319941382495
# Compute control for a deterministic system
# Cost in iteration 0: 0.005264319941382495
# Final cost : 0.005263244875962257
# Compute control for a deterministic system
# Cost in iteration 0: 3.3483749497864523
# Final cost : 1.954098659291037
# Compute control for a deterministic system
# Cost in iteration 0: 1.954098659291037
# Final cost : 0.005734147409054389
# Compute control for a deterministic system
# Cost in iteration 0: 0.005734147409054389
# Final cost : 0.004493224970253109
# Compute control for a deterministic system
# Cost in iteration 0: 0.004493224970253109
# Final cost : 0.004439261760850867
# Compute control for a deterministic system
# Cost in iteration 0: 0.004439261760850867
# Final cost : 0.004434937029324366
# Compute control for a deterministic system
# Cost in iteration 0: 0.004434937029324366
# Final cost : 0.004434219138700103
# Compute control for a deterministic system
# Cost in iteration 0: 3.0486702897165356
# Final cost : 1.3673258171610534
# Compute control for a deterministic system
# Cost in iteration 0: 1.3673258171610534
# Final cost : 0.004672601364696115
# Compute control for a deterministic system
# Cost in iteration 0: 0.004672601364696115
# Final cost : 0.003719122070341671
# Compute control for a deterministic system
# Cost in iteration 0: 0.003719122070341671
# Final cost : 0.0036768761638759353
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036768761638759353
# Final cost : 0.0036748019250944135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036748019250944135
# Final cost : 0.0036744922471520967
# Compute control for a deterministic system
# Cost in iteration 0: 2.7001876837649705
# Final cost : 0.8487739884078315
# Compute control for a deterministic system
# Cost in iteration 0: 0.8487739884078315
# Final cost : 0.0037098723165483907
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037098723165483907
# Final cost : 0.003001197274794281
# Compute control for a deterministic system
# Cost in iteration 0: 0.003001197274794281
# Final cost : 0.002971645677178388
# Compute control for a deterministic system
# Cost in iteration 0: 0.002971645677178388
# Final cost : 0.0029707364468048877
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029707364468048877
# Final cost : 0.0029705930693716695
# Compute control for a deterministic system
# Cost in iteration 0: 2.323451285711982
# Final cost : 0.456289551872127
# Compute control for a deterministic system
# Cost in iteration 0: 0.456289551872127
# Final cost : 0.0028853845599729326
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028853845599729326
# Final cost : 0.0023754462599487555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023754462599487555
# Final cost : 0.0023528950717754543
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023528950717754543
# Final cost : 0.002352435167081579
# Compute control for a deterministic system
# Cost in iteration 0: 0.002352435167081579
# Final cost : 0.0023523660348770325
# Compute control for a deterministic system
# Cost in iteration 0: 1.9241059402832839
# Final cost : 0.19247381907807876
# Compute control for a deterministic system
# Cost in iteration 0: 0.19247381907807876
# Final cost : 0.002177559370664016
# Compute control for a deterministic system
# Cost in iteration 0: 0.002177559370664016
# Final cost : 0.0018196732879288977
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018196732879288977
# Final cost : 0.0018050178472725211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018050178472725211
# Final cost : 0.001804983967042579
# Compute control for a deterministic system
# Cost in iteration 0: 0.001804983967042579
# Final cost : 0.0018049785592200791
# Compute control for a deterministic system
# Cost in iteration 0: 1.519326786374221
# Final cost : 0.050548076671534284
# Compute control for a deterministic system
# Cost in iteration 0: 0.050548076671534284
# Final cost : 0.0015811487046315947
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015811487046315947
# Final cost : 0.001339355486752397
# Compute control for a deterministic system
# Cost in iteration 0: 0.001339355486752397
# Final cost : 0.0013290734691364318
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290734691364318
# Final cost : 0.0013290184168521842
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290184168521842
# Converged in iteration 808 with cost 0.0013290183954459815 because of step counter
# Final cost : 0.0013290183954459815
# Compute control for a deterministic system
# Cost in iteration 0: 1.1271663711067634
# Final cost : 0.003717289565531314
# Compute control for a deterministic system
# Cost in iteration 0: 0.003717289565531314
# Final cost : 0.0010868985125666478
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010868985125666478
# Final cost : 0.0009319428370007046
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009319428370007046
# Final cost : 0.0009251590574968447
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009251590574968447
# Final cost : 0.000925033022425326
# Compute control for a deterministic system
# Cost in iteration 0: 0.000925033022425326
# Converged in iteration 764 with cost 0.0009250330040301405 because of step counter
# Final cost : 0.0009250330040301405
# Compute control for a deterministic system
# Cost in iteration 0: 0.7657914944624007
# Final cost : 0.0068709613481064725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0068709613481064725
# Final cost : 0.0006905670812180318
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006905670812180318
# Final cost : 0.0005966044200342932
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005966044200342932
# Final cost : 0.0005935705735150438
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005935705735150438
# Final cost : 0.0005935066050012684
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005935066050012684
# Final cost : 0.0005935013195137882
# Compute control for a deterministic system
# Cost in iteration 0: 0.45387969386113847
# Final cost : 0.02406110131528848
# Compute control for a deterministic system
# Cost in iteration 0: 0.02406110131528848
# Final cost : 0.00038034001530677945
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038034001530677945
# Final cost : 0.00033654779053500625
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033654779053500625
# Final cost : 0.0003348731931066854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003348731931066854
# Final cost : 0.0003348442245633073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003348442245633073
# Final cost : 0.0003348422074060263
# Compute control for a deterministic system
# Cost in iteration 0: 0.21061070491315015
# Final cost : 0.027703739103814202
# Compute control for a deterministic system
# Cost in iteration 0: 0.027703739103814202
# Final cost : 0.0001641919917395433
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001641919917395433
# Final cost : 0.00014997716514523495
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014997716514523495
# Final cost : 0.0001494534161969622
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001494534161969622
# Final cost : 0.0001494444045323906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001494444045323906
# Final cost : 0.00014944436258723
# Compute control for a deterministic system
# Cost in iteration 0: 0.054466149286279276
# Final cost : 0.011825057100390545
# Compute control for a deterministic system
# Cost in iteration 0: 0.011825057100390545
# Final cost : 3.982658137788896e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.982658137788896e-05
# Final cost : 3.774380549415469e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.774380549415469e-05
# Final cost : 3.769635799134025e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.769635799134025e-05
# Final cost : 3.7695430484542785e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.7695430484542785e-05
# Final cost : 3.7695377736821996e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.673328107109998e-06
# Final cost : 6.83149773052943e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.83149773052943e-07
# Final cost : 1.898593720717717e-09
# ----------------------------------------------- 0
# cost =  0.00014959843213840313
# Compute control for a deterministic system
# Cost in iteration 0: 0.053580057165318974
# Final cost : 0.00015271123267060897
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015271123267060897
# Final cost : 0.00014968739124759684
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014968739124759684
# Final cost : 0.0001495996413272792
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001495996413272792
# Final cost : 0.00014959843225369069
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014959843225369069
# Converged in iteration 26 with cost 0.0001495984321335233 because of step counter
# Final cost : 0.0001495984321335233
# -----------------------------------------------
# 0 found better solution,  2
# cost =  0.0003372020833357662
# Compute control for a deterministic system
# Cost in iteration 0: 0.05542799356513547
# Final cost : 0.0003419539046485674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003419539046485674
# Final cost : 0.0003373614222315276
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003373614222315276
# Final cost : 0.00033720666992331907
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033720666992331907
# Converged in iteration 361 with cost 0.0003372020833388637 because of step counter
# Final cost : 0.0003372020833388637
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003372020833388637
# Converged in iteration 3 with cost 0.00033720208333869173 because of step counter
# Final cost : 0.00033720208333869173
# cost =  0.0005999267209420347
# Compute control for a deterministic system
# Cost in iteration 0: 0.05127033292283455
# Final cost : 0.000606341864259635
# Compute control for a deterministic system
# Cost in iteration 0: 0.000606341864259635
# Final cost : 0.0006001258077443071
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006001258077443071
# Final cost : 0.0005999294913512012
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005999294913512012
# Final cost : 0.0005999268791587276
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005999268791587276
# Final cost : 0.0005999267207206585
# -----------------------------------------------
# 0 found better solution,  4
# cost =  0.0009365766291111336
# Compute control for a deterministic system
# Cost in iteration 0: 0.04908211296601345
# Final cost : 0.000944971474850396
# Compute control for a deterministic system
# Cost in iteration 0: 0.000944971474850396
# Final cost : 0.0009368183951329796
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009368183951329796
# Final cost : 0.0009365772519644243
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009365772519644243
# Final cost : 0.0009365766659322835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009365766659322835
# Converged in iteration 1048 with cost 0.0009365766284458571 because of step counter
# Final cost : 0.0009365766284458571
# -----------------------------------------------
# 0 found better solution,  5
# cost =  0.001345243432983197
# Compute control for a deterministic system
# Cost in iteration 0: 0.04731612543435775
# Final cost : 0.0013559355135119488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013559355135119488
# Final cost : 0.0013455410296591716
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013455410296591716
# Final cost : 0.0013452755010542107
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013452755010542107
# Final cost : 0.0013452456214711086
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013452456214711086
# Final cost : 0.0013452434393594122
# cost =  0.0018350519432500424
# Compute control for a deterministic system
# Cost in iteration 0: 0.05603682957817767
# Final cost : 0.0018499711325217641
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018499711325217641
# Final cost : 0.0018355212471961387
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018355212471961387
# Final cost : 0.0018351017430735504
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018351017430735504
# Final cost : 0.0018350553930886267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018350553930886267
# Final cost : 0.0018350517365910391
# -----------------------------------------------
# 0 found better solution,  7
# cost =  0.0023849774312703366
# Compute control for a deterministic system
# Cost in iteration 0: 0.048908448876088306
# Final cost : 0.00240246819853197
# Compute control for a deterministic system
# Cost in iteration 0: 0.00240246819853197
# Final cost : 0.0023855602215398395
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023855602215398395
# Final cost : 0.002385040530937172
# Compute control for a deterministic system
# Cost in iteration 0: 0.002385040530937172
# Final cost : 0.0023849821034381147
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023849821034381147
# Final cost : 0.0023849774487086375
# cost =  0.003005729209901567
# Compute control for a deterministic system
# Cost in iteration 0: 0.04544003341929335
# Final cost : 0.003026945647393518
# Compute control for a deterministic system
# Cost in iteration 0: 0.003026945647393518
# Final cost : 0.0030064879453019083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030064879453019083
# Final cost : 0.0030058234933687204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030058234933687204
# Final cost : 0.003005736501178311
# Compute control for a deterministic system
# Cost in iteration 0: 0.003005736501178311
# Final cost : 0.0030057290774237046
# -----------------------------------------------
# 0 found better solution,  9
# cost =  0.0036997827786763725
# Compute control for a deterministic system
# Cost in iteration 0: 0.06042846174052431
# Final cost : 0.0037270461220717493
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037270461220717493
# Final cost : 0.003700770641444708
# Compute control for a deterministic system
# Cost in iteration 0: 0.003700770641444708
# Final cost : 0.0036999182322676742
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036999182322676742
# Final cost : 0.0036997921400851786
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036997921400851786
# Final cost : 0.003699781628627985
# -----------------------------------------------
# 0 found better solution,  10
# cost =  0.004469633949085361
# Compute control for a deterministic system
# Cost in iteration 0: 0.05018860779145837
# Final cost : 0.004500611609544997
# Compute control for a deterministic system
# Cost in iteration 0: 0.004500611609544997
# Final cost : 0.004470980827260328
# Compute control for a deterministic system
# Cost in iteration 0: 0.004470980827260328
# Final cost : 0.00446983841418104
# Compute control for a deterministic system
# Cost in iteration 0: 0.00446983841418104
# Final cost : 0.00446964392269595
# Compute control for a deterministic system
# Cost in iteration 0: 0.00446964392269595
# Final cost : 0.004469631652073953
# -----------------------------------------------
# 0 found better solution,  11
# cost =  0.00531703778519154
# Compute control for a deterministic system
# Cost in iteration 0: 0.04593300544330864
# Final cost : 0.0053528090544913
# Compute control for a deterministic system
# Cost in iteration 0: 0.0053528090544913
# Final cost : 0.005318796780564451
# Compute control for a deterministic system
# Cost in iteration 0: 0.005318796780564451
# Final cost : 0.005317330732245736
# Compute control for a deterministic system
# Cost in iteration 0: 0.005317330732245736
# Final cost : 0.0053170591607392854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0053170591607392854
# Final cost : 0.0053170348546183795
# -----------------------------------------------
# 0 found better solution,  12
# cost =  0.006242957043186984
# Compute control for a deterministic system
# Cost in iteration 0: 0.05470029535799253
# Final cost : 0.006285619549427664
# Compute control for a deterministic system
# Cost in iteration 0: 0.006285619549427664
# Final cost : 0.006245273486476042
# Compute control for a deterministic system
# Cost in iteration 0: 0.006245273486476042
# Final cost : 0.006243368129136572
# Compute control for a deterministic system
# Cost in iteration 0: 0.006243368129136572
# Final cost : 0.006242981912266787
# Compute control for a deterministic system
# Cost in iteration 0: 0.006242981912266787
# Final cost : 0.0062429473727810495
# -----------------------------------------------
# 0 found better solution,  13
# cost =  0.007247820612421207
# Compute control for a deterministic system
# Cost in iteration 0: 0.057674501029714685
# Final cost : 0.007297660854984701
# Compute control for a deterministic system
# Cost in iteration 0: 0.007297660854984701
# Final cost : 0.0072506926063562625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0072506926063562625
# Final cost : 0.007248362931114132
# Compute control for a deterministic system
# Cost in iteration 0: 0.007248362931114132
# Final cost : 0.007247858025976734
# Compute control for a deterministic system
# Cost in iteration 0: 0.007247858025976734
# Final cost : 0.007247807776582077
# -----------------------------------------------
# 0 found better solution,  14
# cost =  0.008331862576655299
# Compute control for a deterministic system
# Cost in iteration 0: 0.05926637974901146
# Final cost : 0.008388416611196322
# Compute control for a deterministic system
# Cost in iteration 0: 0.008388416611196322
# Final cost : 0.008335463052788534
# Compute control for a deterministic system
# Cost in iteration 0: 0.008335463052788534
# Final cost : 0.008332574762620575
# Compute control for a deterministic system
# Cost in iteration 0: 0.008332574762620575
# Final cost : 0.008331907442355522
# Compute control for a deterministic system
# Cost in iteration 0: 0.008331907442355522
# Final cost : 0.008331825790969095
# -----------------------------------------------
# 0 found better solution,  15
# cost =  0.009495224722985333
# Compute control for a deterministic system
# Cost in iteration 0: 0.06095541517016314
# Final cost : 0.0095588611425954
# Compute control for a deterministic system
# Cost in iteration 0: 0.0095588611425954
# Final cost : 0.009499452833466322
# Compute control for a deterministic system
# Cost in iteration 0: 0.009499452833466322
# Final cost : 0.00949605144377494
# Compute control for a deterministic system
# Cost in iteration 0: 0.00949605144377494
# Final cost : 0.009495258307308666
# Compute control for a deterministic system
# Cost in iteration 0: 0.009495258307308666
# Final cost : 0.00949515574931764
# -----------------------------------------------
# 0 found better solution,  16
# cost =  0.010738126883673402
# Compute control for a deterministic system
# Cost in iteration 0: 0.058971523139547385
# Final cost : 0.01080804340669131
# Compute control for a deterministic system
# Cost in iteration 0: 0.01080804340669131
# Final cost : 0.010743133668670277
# Compute control for a deterministic system
# Cost in iteration 0: 0.010743133668670277
# Final cost : 0.010739087998295446
# Compute control for a deterministic system
# Cost in iteration 0: 0.010739087998295446
# Final cost : 0.01073813173658085
# Compute control for a deterministic system
# Cost in iteration 0: 0.01073813173658085
# Final cost : 0.010737992298948985
# -----------------------------------------------
# 0 found better solution,  17
# cost =  0.012060794452574497
# Compute control for a deterministic system
# Cost in iteration 0: 0.049414947488776687
# Final cost : 0.01213561161231823
# Compute control for a deterministic system
# Cost in iteration 0: 0.01213561161231823
# Final cost : 0.012066922483835108
# Compute control for a deterministic system
# Cost in iteration 0: 0.012066922483835108
# Final cost : 0.012062015593790212
# Compute control for a deterministic system
# Cost in iteration 0: 0.012062015593790212
# Final cost : 0.012060784893495644
# Compute control for a deterministic system
# Cost in iteration 0: 0.012060784893495644
# Final cost : 0.012060586039357212
# -----------------------------------------------
# 0 found better solution,  18
# cost =  0.013494486648558082
# Compute control for a deterministic system
# Cost in iteration 0: 0.052044132889259076
# Final cost : 0.013579697195879014
# Compute control for a deterministic system
# Cost in iteration 0: 0.013579697195879014
# Final cost : 0.013501629477047168
# Compute control for a deterministic system
# Cost in iteration 0: 0.013501629477047168
# Final cost : 0.013495832625306209
# Compute control for a deterministic system
# Cost in iteration 0: 0.013495832625306209
# Final cost : 0.013494273812939725
# Compute control for a deterministic system
# Cost in iteration 0: 0.013494273812939725
# Final cost : 0.01349398992397187
# -----------------------------------------------
# 0 found better solution,  19
# cost =  0.014979658014945635
# Compute control for a deterministic system
# Cost in iteration 0: 0.07321151736195819
# Final cost : 0.015073962569909647
# Compute control for a deterministic system
# Cost in iteration 0: 0.015073962569909647
# Final cost : 0.014987388487756055
# Compute control for a deterministic system
# Cost in iteration 0: 0.014987388487756055
# Final cost : 0.014981067055901572
# Compute control for a deterministic system
# Cost in iteration 0: 0.014981067055901572
# Final cost : 0.01497922449886437
# Compute control for a deterministic system
# Cost in iteration 0: 0.01497922449886437
# Final cost : 0.014978854747318573
# -----------------------------------------------
# 0 found better solution,  20
# cost =  0.016545893371921343
# Compute control for a deterministic system
# Cost in iteration 0: 0.05546240389090679
# Final cost : 0.0166427356073661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0166427356073661
# Final cost : 0.016554811802732498
# Compute control for a deterministic system
# Cost in iteration 0: 0.016554811802732498
# Final cost : 0.016547405386724688
# Compute control for a deterministic system
# Cost in iteration 0: 0.016547405386724688
# Final cost : 0.01654513323038701
# Compute control for a deterministic system
# Cost in iteration 0: 0.01654513323038701
# Final cost : 0.01654462546780102
# -----------------------------------------------
# 0 found better solution,  21
# cost =  0.011668410416087828
# Compute control for a deterministic system
# Cost in iteration 0: 0.06311451293365074
# Final cost : 0.01829927749537628
# Compute control for a deterministic system
# Cost in iteration 0: 0.01829927749537628
# Final cost : 0.01820313326048081
# Compute control for a deterministic system
# Cost in iteration 0: 0.01820313326048081
# Final cost : 0.018195231911877725
# Compute control for a deterministic system
# Cost in iteration 0: 0.018195231911877725
# Final cost : 0.018192440970633474
# Compute control for a deterministic system
# Cost in iteration 0: 0.018192440970633474
# Final cost : 0.0181917682460852
# cost =  0.010432653542559374
# Compute control for a deterministic system
# Cost in iteration 0: 0.050799981596884425
# Final cost : 0.010483746340710151
# Compute control for a deterministic system
# Cost in iteration 0: 0.010483746340710151
# Final cost : 0.010436867095833992
# Compute control for a deterministic system
# Cost in iteration 0: 0.010436867095833992
# Final cost : 0.010433521996433562
# Compute control for a deterministic system
# Cost in iteration 0: 0.010433521996433562
# Final cost : 0.010432912767759641
# Compute control for a deterministic system
# Cost in iteration 0: 0.010432912767759641
# Final cost : 0.010432653815297623
# cost =  0.009263637642076654
# Compute control for a deterministic system
# Cost in iteration 0: 0.0631966470028205
# Final cost : 0.009309374366733117
# Compute control for a deterministic system
# Cost in iteration 0: 0.009309374366733117
# Final cost : 0.009266976188643932
# Compute control for a deterministic system
# Cost in iteration 0: 0.009266976188643932
# Final cost : 0.009264249541197
# Compute control for a deterministic system
# Cost in iteration 0: 0.009264249541197
# Final cost : 0.00926381056563427
# Compute control for a deterministic system
# Cost in iteration 0: 0.00926381056563427
# Final cost : 0.009263640747369885
# cost =  0.008161789994470607
# Compute control for a deterministic system
# Cost in iteration 0: 0.06612518159993433
# Final cost : 0.008202993790385799
# Compute control for a deterministic system
# Cost in iteration 0: 0.008202993790385799
# Final cost : 0.008163905092569902
# Compute control for a deterministic system
# Cost in iteration 0: 0.008163905092569902
# Final cost : 0.008162069212644157
# Compute control for a deterministic system
# Cost in iteration 0: 0.008162069212644157
# Final cost : 0.008161844653357172
# Compute control for a deterministic system
# Cost in iteration 0: 0.008161844653357172
# Final cost : 0.008161761615995274
# -----------------------------------------------
# 0 found better solution,  25
# cost =  0.007127462800786555
# Compute control for a deterministic system
# Cost in iteration 0: 0.050925384205501696
# Final cost : 0.007165140388664117
# Compute control for a deterministic system
# Cost in iteration 0: 0.007165140388664117
# Final cost : 0.007129331576325881
# Compute control for a deterministic system
# Cost in iteration 0: 0.007129331576325881
# Final cost : 0.007127706962625528
# Compute control for a deterministic system
# Cost in iteration 0: 0.007127706962625528
# Final cost : 0.007127514809478879
# Compute control for a deterministic system
# Cost in iteration 0: 0.007127514809478879
# Final cost : 0.007127450538292097
# -----------------------------------------------
# 0 found better solution,  26
# cost =  0.006161137817919613
# Compute control for a deterministic system
# Cost in iteration 0: 0.06182447822650638
# Final cost : 0.006194579297625788
# Compute control for a deterministic system
# Cost in iteration 0: 0.006194579297625788
# Final cost : 0.0061628882342261975
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061628882342261975
# Final cost : 0.006161355401758745
# Compute control for a deterministic system
# Cost in iteration 0: 0.006161355401758745
# Final cost : 0.00616118525983878
# Compute control for a deterministic system
# Cost in iteration 0: 0.00616118525983878
# Final cost : 0.006161133742739852
# -----------------------------------------------
# 0 found better solution,  27
# cost =  0.005263244875962257
# Compute control for a deterministic system
# Cost in iteration 0: 0.0663645516476008
# Final cost : 0.005286653649072193
# Compute control for a deterministic system
# Cost in iteration 0: 0.005286653649072193
# Final cost : 0.005264667479666796
# Compute control for a deterministic system
# Cost in iteration 0: 0.005264667479666796
# Final cost : 0.005263409541671494
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263409541671494
# Final cost : 0.005263279641274921
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263279641274921
# Final cost : 0.0052632447727151204
# -----------------------------------------------
# 0 found better solution,  28
# cost =  0.004434219138700103
# Compute control for a deterministic system
# Cost in iteration 0: 0.06626967527408685
# Final cost : 0.004454774957626677
# Compute control for a deterministic system
# Cost in iteration 0: 0.004454774957626677
# Final cost : 0.004435913907986927
# ...
# Final cost : 0.014338371858627135
# Compute control for a deterministic system
# Cost in iteration 0: 0.014338371858627135
# Final cost : 0.014338360037795116
# Compute control for a deterministic system
# Cost in iteration 0: 0.014338360037795116
# Final cost : 0.014338359870472633
# Compute control for a deterministic system
# Cost in iteration 0: 0.014338359870472633
# Converged in iteration 168 with cost 0.01433835986368583 because of step counter
# Final cost : 0.01433835986368583
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.01362548001061149
# Final cost : 0.012971037393885394
# Compute control for a deterministic system
# Cost in iteration 0: 0.012971037393885394
# Final cost : 0.012970446565694148
# Compute control for a deterministic system
# Cost in iteration 0: 0.012970446565694148
# Final cost : 0.012970425337451295
# Compute control for a deterministic system
# Cost in iteration 0: 0.012970425337451295
# Final cost : 0.012970425069979362
# Compute control for a deterministic system
# Cost in iteration 0: 0.012970425069979362
# Converged in iteration 525 with cost 0.01297042505813069 because of step counter
# Final cost : 0.01297042505813069
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.011692955712044229
# Final cost : 0.011668844631967558
# Compute control for a deterministic system
# Cost in iteration 0: 0.011668844631967558
# Final cost : 0.011668405095884887
# Compute control for a deterministic system
# Cost in iteration 0: 0.011668405095884887
# Final cost : 0.011668388060829572
# Compute control for a deterministic system
# Cost in iteration 0: 0.011668388060829572
# Final cost : 0.011668387890518741
# Compute control for a deterministic system
# Cost in iteration 0: 0.011668387890518741
# Converged in iteration 347 with cost 0.011668387881700843 because of step counter
# Final cost : 0.011668387881700843
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.010473644928568622
# Final cost : 0.010433011305759658
# Compute control for a deterministic system
# Cost in iteration 0: 0.010433011305759658
# Final cost : 0.01043266784286619
# Compute control for a deterministic system
# Cost in iteration 0: 0.01043266784286619
# Final cost : 0.01043265353973341
# Compute control for a deterministic system
# Cost in iteration 0: 0.01043265353973341
# Final cost : 0.010432653379860784
# Compute control for a deterministic system
# Cost in iteration 0: 0.010432653379860784
# Converged in iteration 499 with cost 0.010432653373059753 because of step counter
# Final cost : 0.010432653373059753
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.010165847878067544
# Final cost : 0.009263939291596645
# Compute control for a deterministic system
# Cost in iteration 0: 0.009263939291596645
# Final cost : 0.009263647450649615
# Compute control for a deterministic system
# Cost in iteration 0: 0.009263647450649615
# Final cost : 0.009263637596978153
# Compute control for a deterministic system
# Cost in iteration 0: 0.009263637596978153
# Converged in iteration 874 with cost 0.009263637572544912 because of step counter
# Final cost : 0.009263637572544912
# Compute control for a deterministic system
# Cost in iteration 0: 0.009263637572544912
# Converged in iteration 3 with cost 0.009263637572544673 because of step counter
# Final cost : 0.009263637572544673
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.008225751083960977
# Final cost : 0.008161943725100044
# Compute control for a deterministic system
# Cost in iteration 0: 0.008161943725100044
# Final cost : 0.008161769540159642
# Compute control for a deterministic system
# Cost in iteration 0: 0.008161769540159642
# Final cost : 0.008161761641731106
# Compute control for a deterministic system
# Cost in iteration 0: 0.008161761641731106
# Final cost : 0.008161761610783412
# Compute control for a deterministic system
# Cost in iteration 0: 0.008161761610783412
# Converged in iteration 345 with cost 0.008161761609675987 because of step counter
# Final cost : 0.008161761609675987
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.007129592255946541
# Final cost : 0.007127563080083302
# Compute control for a deterministic system
# Cost in iteration 0: 0.007127563080083302
# Final cost : 0.007127456557956772
# Compute control for a deterministic system
# Cost in iteration 0: 0.007127456557956772
# Final cost : 0.0071274505331352985
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071274505331352985
# Converged in iteration 176 with cost 0.00712745053276383 because of step counter
# Final cost : 0.00712745053276383
# Compute control for a deterministic system
# Cost in iteration 0: 0.00712745053276383
# Converged in iteration 1 with cost 0.00712745053276383 because of step counter
# Final cost : 0.00712745053276383
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.006807585690691785
# Final cost : 0.006161217753756336
# Compute control for a deterministic system
# Cost in iteration 0: 0.006161217753756336
# Final cost : 0.006161135713188462
# Compute control for a deterministic system
# Cost in iteration 0: 0.006161135713188462
# Final cost : 0.00616113374726979
# Compute control for a deterministic system
# Cost in iteration 0: 0.00616113374726979
# Final cost : 0.0061611337344262196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061611337344262196
# Converged in iteration 48 with cost 0.006161133734042785 because of step counter
# Final cost : 0.006161133734042785
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.005668194677612383
# Final cost : 0.005263288225684067
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263288225684067
# Final cost : 0.005263245742991266
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263245742991266
# Final cost : 0.005263244773528711
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263244773528711
# Converged in iteration 818 with cost 0.005263244764721439 because of step counter
# Final cost : 0.005263244764721439
# Compute control for a deterministic system
# Cost in iteration 0: 0.005263244764721439
# Converged in iteration 26 with cost 0.005263244764667363 because of step counter
# Final cost : 0.005263244764667363
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.00443698190922987
# Final cost : 0.004434238500348047
# Compute control for a deterministic system
# Cost in iteration 0: 0.004434238500348047
# Final cost : 0.004434219587679717
# Compute control for a deterministic system
# Cost in iteration 0: 0.004434219587679717
# Final cost : 0.00443421912136423
# Compute control for a deterministic system
# Cost in iteration 0: 0.00443421912136423
# Converged in iteration 121 with cost 0.004434219118850065 because of vanishing difference
# Final cost : 0.004434219118850065
# Compute control for a deterministic system
# Cost in iteration 0: 0.004434219118850065
# Converged in iteration 1 with cost 0.004434219118850065 because of step counter
# Final cost : 0.004434219118850065
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.00390701252980754
# Final cost : 0.003674507780610182
# Compute control for a deterministic system
# Cost in iteration 0: 0.003674507780610182
# Final cost : 0.0036744922159893303
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036744922159893303
# Final cost : 0.003674492053071678
# Compute control for a deterministic system
# Cost in iteration 0: 0.003674492053071678
# Converged in iteration 42 with cost 0.0036744920518587713 because of step counter
# Final cost : 0.0036744920518587713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036744920518587713
# Converged in iteration 1 with cost 0.0036744920518587713 because of step counter
# Final cost : 0.0036744920518587713
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.003128067816653317
# Final cost : 0.0029706043482227618
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029706043482227618
# Final cost : 0.0029705928458544912
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029705928458544912
# Converged in iteration 945 with cost 0.0029705927632471627 because of vanishing difference
# Final cost : 0.0029705927632471627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029705927632471627
# Converged in iteration 43 with cost 0.002970592763185755 because of step counter
# Final cost : 0.002970592763185755
# Compute control for a deterministic system
# Cost in iteration 0: 0.002970592763185755
# Converged in iteration 1 with cost 0.002970592763185755 because of step counter
# Final cost : 0.002970592763185755
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023664039441641796
# Final cost : 0.002352372656752928
# Compute control for a deterministic system
# Cost in iteration 0: 0.002352372656752928
# Final cost : 0.0023523659196841855
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023523659196841855
# Final cost : 0.0023523658549947984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023523658549947984
# Converged in iteration 169 with cost 0.002352365854160773 because of step counter
# Final cost : 0.002352365854160773
# Compute control for a deterministic system
# Cost in iteration 0: 0.002352365854160773
# Converged in iteration 8 with cost 0.0023523658540813863 because of step counter
# Final cost : 0.0023523658540813863
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020352255551751765
# Final cost : 0.0018049888129124019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018049888129124019
# Final cost : 0.0018049786896804458
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018049786896804458
# Converged in iteration 911 with cost 0.0018049785531984613 because of step counter
# Final cost : 0.0018049785531984613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018049785531984613
# Converged in iteration 1 with cost 0.0018049785531984613 because of step counter
# Final cost : 0.0018049785531984613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018049785531984613
# Converged in iteration 1 with cost 0.0018049785531984613 because of step counter
# Final cost : 0.0018049785531984613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013479187536929666
# Final cost : 0.0013290228454921724
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290228454921724
# Final cost : 0.0013290184891154332
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290184891154332
# Final cost : 0.0013290183957555188
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290183957555188
# Converged in iteration 143 with cost 0.0013290183955421812 because of step counter
# Final cost : 0.0013290183955421812
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013290183955421812
# Converged in iteration 1 with cost 0.0013290183955421812 because of step counter
# Final cost : 0.0013290183955421812
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010556557283813294
# Final cost : 0.0009250388139572146
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009250388139572146
# Final cost : 0.0009250330550370289
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009250330550370289
# Final cost : 0.0009250330041375472
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009250330041375472
# Converged in iteration 31 with cost 0.0009250330041245118 because of step counter
# Final cost : 0.0009250330041245118
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009250330041245118
# Converged in iteration 13 with cost 0.0009250330040323497 because of step counter
# Final cost : 0.0009250330040323497
# Compute control for a deterministic system
# Cost in iteration 0: 0.000593533127803113
# Final cost : 0.0005935034391933648
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005935034391933648
# Final cost : 0.0005935014584565748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005935014584565748
# Final cost : 0.00059350131608826
# Compute control for a deterministic system
# Cost in iteration 0: 0.00059350131608826
# Converged in iteration 153 with cost 0.0005935013152076839 because of step counter
# Final cost : 0.0005935013152076839
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005935013152076839
# Converged in iteration 1 with cost 0.0005935013152076839 because of step counter
# Final cost : 0.0005935013152076839
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003511689666945895
# Final cost : 0.0003348438122259233
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003348438122259233
# Final cost : 0.0003348422099801871
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003348422099801871
# Converged in iteration 962 with cost 0.00033484219913327483 because of step counter
# Final cost : 0.00033484219913327483
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033484219913327483
# Converged in iteration 1 with cost 0.00033484219913327483 because of step counter
# Final cost : 0.00033484219913327483
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033484219913327483
# Converged in iteration 1 with cost 0.00033484219913327483 because of step counter
# Final cost : 0.00033484219913327483
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001511374038734679
# Final cost : 0.00014944497024902304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014944497024902304
# Final cost : 0.00014944436913449032
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014944436913449032
# Final cost : 0.00014944436258891732
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014944436258891732
# Converged in iteration 48 with cost 0.0001494443624907906 because of step counter
# Final cost : 0.0001494443624907906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001494443624907906
# Converged in iteration 1 with cost 0.0001494443624907906 because of step counter
# Final cost : 0.0001494443624907906
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 4.154035509304367e-05
# Final cost : 3.76955981151774e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.76955981151774e-05
# Final cost : 3.7695379151619725e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.7695379151619725e-05
# Final cost : 3.7695377575374216e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.7695377575374216e-05
# Converged in iteration 6 with cost 3.7695377574983836e-05 because of step counter
# Final cost : 3.7695377574983836e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.7695377574983836e-05
# Converged in iteration 1 with cost 3.7695377574983836e-05 because of step counter
# Final cost : 3.7695377574983836e-05

# %%
save(results_min)
