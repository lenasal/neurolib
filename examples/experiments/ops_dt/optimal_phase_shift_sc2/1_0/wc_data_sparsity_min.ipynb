# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,712], wc.inh[0,712]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 18.45344827586207
# minima =  [ 1252  3093  4938  6783  8629 10474 12319 14165 16010 17856 19701 21546
#  23392 25237 27082 28928 30773 32618 34464 36309 38154 40000 41845 43690
#  45536 47381 49226 51072 52917 54763 56608 58453]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 results_min = read()
#
# Cell In [6], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("a_s3_l1.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s3_l1.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03127304557649737
# Final cost : 0.010818742052030345
# Compute control for a deterministic system
# Cost in iteration 0: 0.010818742052030345
# Converged in iteration 106 with cost 0.00923937184403999 because of step counter
# Final cost : 0.00923937184403999
# Compute control for a deterministic system
# Cost in iteration 0: 0.00923937184403999
# Converged in iteration 13 with cost 0.009239371844031563 because of step counter
# Final cost : 0.009239371844031563
# Compute control for a deterministic system
# Cost in iteration 0: 0.009239371844031563
# Converged in iteration 1 with cost 0.009239371844031563 because of step counter
# Final cost : 0.009239371844031563
# Compute control for a deterministic system
# Cost in iteration 0: 0.009239371844031563
# Converged in iteration 1 with cost 0.009239371844031563 because of step counter
# Final cost : 0.009239371844031563
# Compute control for a deterministic system
# Cost in iteration 0: 0.009239371844031563
# Converged in iteration 1 with cost 0.009239371844031563 because of step counter
# Final cost : 0.009239371844031563
# Compute control for a deterministic system
# Cost in iteration 0: 0.12304618880469587
# Final cost : 0.025937429780193047
# Compute control for a deterministic system
# Cost in iteration 0: 0.025937429780193047
# Cost in iteration 200: 0.019314239262626088
# Converged in iteration 255 with cost 0.0193142392605549 because of step counter
# Final cost : 0.0193142392605549
# Compute control for a deterministic system
# Cost in iteration 0: 0.0193142392605549
# Converged in iteration 3 with cost 0.019314239260541342 because of step counter
# Final cost : 0.019314239260541342
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239260541342
# Converged in iteration 1 with cost 0.019314239260541342 because of step counter
# Final cost : 0.019314239260541342
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239260541342
# Converged in iteration 1 with cost 0.019314239260541342 because of step counter
# Final cost : 0.019314239260541342
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239260541342
# Converged in iteration 1 with cost 0.019314239260541342 because of step counter
# Final cost : 0.019314239260541342
# Compute control for a deterministic system
# Cost in iteration 0: 0.2678910958547081
# Final cost : 0.05583748224956053
# Compute control for a deterministic system
# Cost in iteration 0: 0.05583748224956053
# Cost in iteration 200: 0.02940900362517062
# Converged in iteration 217 with cost 0.029408998916754275 because of vanishing difference
# Final cost : 0.029408998916754275
# Compute control for a deterministic system
# Cost in iteration 0: 0.029408998916754275
# Converged in iteration 62 with cost 0.029408995490855915 because of step counter
# Final cost : 0.029408995490855915
# Compute control for a deterministic system
# Cost in iteration 0: 0.029408995490855915
# Converged in iteration 5 with cost 0.029408995490854788 because of step counter
# Final cost : 0.029408995490854788
# Compute control for a deterministic system
# Cost in iteration 0: 0.029408995490854788
# Converged in iteration 1 with cost 0.029408995490854788 because of step counter
# Final cost : 0.029408995490854788
# Compute control for a deterministic system
# Cost in iteration 0: 0.029408995490854788
# Converged in iteration 1 with cost 0.029408995490854788 because of step counter
# Final cost : 0.029408995490854788
# Compute control for a deterministic system
# Cost in iteration 0: 0.45792043825945333
# Final cost : 0.11938868299470132
# Compute control for a deterministic system
# Cost in iteration 0: 0.11938868299470132
# Cost in iteration 200: 0.03973809216907281
# Cost in iteration 400: 0.03973770782343341
# Final cost : 0.03973770782343341
# Compute control for a deterministic system
# Cost in iteration 0: 0.03973770782343341
# Converged in iteration 77 with cost 0.039737707559534936 because of step counter
# Final cost : 0.039737707559534936
# Compute control for a deterministic system
# Cost in iteration 0: 0.039737707559534936
# Converged in iteration 4 with cost 0.039737707559534034 because of step counter
# Final cost : 0.039737707559534034
# Compute control for a deterministic system
# Cost in iteration 0: 0.039737707559534034
# Converged in iteration 2 with cost 0.039737707559534 because of step counter
# Final cost : 0.039737707559534
# Compute control for a deterministic system
# Cost in iteration 0: 0.039737707559534
# Converged in iteration 2 with cost 0.03973770755953138 because of step counter
# Final cost : 0.03973770755953138
# Compute control for a deterministic system
# Cost in iteration 0: 0.6698235317517994
# Final cost : 0.22990773325237956
# Compute control for a deterministic system
# Cost in iteration 0: 0.22990773325237956
# Cost in iteration 200: 0.04986158997455947
# Cost in iteration 400: 0.04985716909853094
# Final cost : 0.04985716909853094
# Compute control for a deterministic system
# Cost in iteration 0: 0.04985716909853094
# Converged in iteration 165 with cost 0.04985714780867723 because of step counter
# Final cost : 0.04985714780867723
# Compute control for a deterministic system
# Cost in iteration 0: 0.04985714780867723
# Converged in iteration 1 with cost 0.04985714780867723 because of step counter
# Final cost : 0.04985714780867723
# Compute control for a deterministic system
# Cost in iteration 0: 0.04985714780867723
# Converged in iteration 3 with cost 0.04985714780867647 because of step counter
# Final cost : 0.04985714780867647
# Compute control for a deterministic system
# Cost in iteration 0: 0.04985714780867647
# Converged in iteration 3 with cost 0.04985714780867521 because of step counter
# Final cost : 0.04985714780867521
# Compute control for a deterministic system
# Cost in iteration 0: 0.892394714692296
# Final cost : 0.39442571156021994
# Compute control for a deterministic system
# Cost in iteration 0: 0.39442571156021994
# Cost in iteration 200: 0.06000523311892993
# Cost in iteration 400: 0.05998376067011886
# Final cost : 0.05998376067011886
# Compute control for a deterministic system
# Cost in iteration 0: 0.05998376067011886
# Converged in iteration 29 with cost 0.05998337951591114 because of vanishing difference
# Final cost : 0.05998337951591114
# Compute control for a deterministic system
# Cost in iteration 0: 0.05998337951591114
# Converged in iteration 109 with cost 0.05998333477494375 because of step counter
# Final cost : 0.05998333477494375
# Compute control for a deterministic system
# Cost in iteration 0: 0.05998333477494375
# Converged in iteration 2 with cost 0.05998333477494298 because of step counter
# Final cost : 0.05998333477494298
# Compute control for a deterministic system
# Cost in iteration 0: 0.05998333477494298
# Converged in iteration 1 with cost 0.05998333477494298 because of step counter
# Final cost : 0.05998333477494298
# Compute control for a deterministic system
# Cost in iteration 0: 1.1133320054805924
# Final cost : 0.6060186034143494
# Compute control for a deterministic system
# Cost in iteration 0: 0.6060186034143494
# Cost in iteration 200: 0.070189221725748
# Cost in iteration 400: 0.0701160158190109
# Final cost : 0.0701160158190109
# Compute control for a deterministic system
# Cost in iteration 0: 0.0701160158190109
# Converged in iteration 44 with cost 0.07011311285706541 because of vanishing difference
# Final cost : 0.07011311285706541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07011311285706541
# Converged in iteration 153 with cost 0.07011282751380425 because of step counter
# Final cost : 0.07011282751380425
# Compute control for a deterministic system
# Cost in iteration 0: 0.07011282751380425
# Converged in iteration 1 with cost 0.07011282751380425 because of step counter
# Final cost : 0.07011282751380425
# Compute control for a deterministic system
# Cost in iteration 0: 0.07011282751380425
# Converged in iteration 1 with cost 0.07011282751380425 because of step counter
# Final cost : 0.07011282751380425
# Compute control for a deterministic system
# Cost in iteration 0: 1.3240556037094873
# Final cost : 0.847773987120171
# Compute control for a deterministic system
# Cost in iteration 0: 0.847773987120171
# Cost in iteration 200: 0.08045257819045477
# Cost in iteration 400: 0.08025703166766215
# Final cost : 0.08025703166766215
# Compute control for a deterministic system
# Cost in iteration 0: 0.08025703166766215
# Converged in iteration 76 with cost 0.08024351848681216 because of vanishing difference
# Final cost : 0.08024351848681216
# Compute control for a deterministic system
# Cost in iteration 0: 0.08024351848681216
# Cost in iteration 200: 0.08024283484016857
# Final cost : 0.08024283484016857
# Compute control for a deterministic system
# Cost in iteration 0: 0.08024283484016857
# Converged in iteration 25 with cost 0.0802428348400428 because of step counter
# Final cost : 0.0802428348400428
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802428348400428
# Converged in iteration 13 with cost 0.08024283484001735 because of step counter
# Final cost : 0.08024283484001735
# Compute control for a deterministic system
# Cost in iteration 0: 1.5194844574362227
# Final cost : 1.099873680606363
# Compute control for a deterministic system
# Cost in iteration 0: 1.099873680606363
# Cost in iteration 200: 0.09083464315611046
# Cost in iteration 400: 0.0904200465165575
# Final cost : 0.0904200465165575
# Compute control for a deterministic system
# Cost in iteration 0: 0.0904200465165575
# Cost in iteration 200: 0.09037121389126597
# Final cost : 0.09037121389126597
# Compute control for a deterministic system
# Cost in iteration 0: 0.09037121389126597
# Cost in iteration 200: 0.09037111057298049
# Final cost : 0.09037111057298049
# Compute control for a deterministic system
# Cost in iteration 0: 0.09037111057298049
# Converged in iteration 85 with cost 0.0903711105715507 because of step counter
# Final cost : 0.0903711105715507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0903711105715507
# Converged in iteration 12 with cost 0.09037111057149688 because of step counter
# Final cost : 0.09037111057149688
# Compute control for a deterministic system
# Cost in iteration 0: 1.6970628307830333
# Final cost : 1.3456342463352382
# Compute control for a deterministic system
# Cost in iteration 0: 1.3456342463352382
# Cost in iteration 200: 0.10140490802262914
# Cost in iteration 400: 0.10062941692990308
# Final cost : 0.10062941692990308
# Compute control for a deterministic system
# Cost in iteration 0: 0.10062941692990308
# Cost in iteration 200: 0.10049661958270525
# Final cost : 0.10049661958270525
# Compute control for a deterministic system
# Cost in iteration 0: 0.10049661958270525
# Cost in iteration 200: 0.1004957708437181
# Final cost : 0.1004957708437181
# Compute control for a deterministic system
# Cost in iteration 0: 0.1004957708437181
# Cost in iteration 200: 0.10049577070894022
# Converged in iteration 281 with cost 0.10049577070845685 because of step counter
# Final cost : 0.10049577070845685
# Compute control for a deterministic system
# Cost in iteration 0: 0.10049577070845685
# Converged in iteration 1 with cost 0.10049577070845685 because of step counter
# Final cost : 0.10049577070845685
# Compute control for a deterministic system
# Cost in iteration 0: 1.8557834856769568
# Final cost : 1.5738428108006512
# Compute control for a deterministic system
# Cost in iteration 0: 1.5738428108006512
# Cost in iteration 200: 0.11223888712958163
# Cost in iteration 400: 0.11092372799463912
# Final cost : 0.11092372799463912
# Compute control for a deterministic system
# Cost in iteration 0: 0.11092372799463912
# Cost in iteration 200: 0.11061879532346078
# Final cost : 0.11061879532346078
# Compute control for a deterministic system
# Cost in iteration 0: 0.11061879532346078
# Converged in iteration 4 with cost 0.11061861842016704 because of vanishing difference
# Final cost : 0.11061861842016704
# Compute control for a deterministic system
# Cost in iteration 0: 0.11061861842016704
# Cost in iteration 200: 0.1106151712531943
# Cost in iteration 400: 0.1106151366767268
# Final cost : 0.1106151366767268
# Compute control for a deterministic system
# Cost in iteration 0: 0.1106151366767268
# Cost in iteration 200: 0.11061513624785921
# Cost in iteration 400: 0.11061513624034278
# Converged in iteration 429 with cost 0.11061513624023604 because of step counter
# Final cost : 0.11061513624023604
# Compute control for a deterministic system
# Cost in iteration 0: 1.998330025119673
# Final cost : 1.7823966753118305
# Compute control for a deterministic system
# Cost in iteration 0: 1.7823966753118305
# Cost in iteration 200: 0.12368906026234248
# Cost in iteration 400: 0.12159055582943853
# Final cost : 0.12159055582943853
# Compute control for a deterministic system
# Cost in iteration 0: 0.12159055582943853
# Cost in iteration 200: 0.12096034251722408
# Final cost : 0.12096034251722408
# Compute control for a deterministic system
# Cost in iteration 0: 0.12096034251722408
# Converged in iteration 59 with cost 0.12094923501117869 because of vanishing difference
# Final cost : 0.12094923501117869
# Compute control for a deterministic system
# Cost in iteration 0: 0.12094923501117869
# Cost in iteration 200: 0.12094710223349617
# Cost in iteration 400: 0.1209470661024193
# Final cost : 0.1209470661024193
# Compute control for a deterministic system
# Cost in iteration 0: 0.1209470661024193
# Cost in iteration 200: 0.12094706551524895
# Cost in iteration 400: 0.1209470654946916
# Converged in iteration 522 with cost 0.12094706549396492 because of step counter
# Final cost : 0.12094706549396492
# Compute control for a deterministic system
# Cost in iteration 0: 2.1189328451240157
# Final cost : 1.9595988289716073
# Compute control for a deterministic system
# Cost in iteration 0: 1.9595988289716073
# Cost in iteration 200: 0.1353112376010702
# Cost in iteration 400: 0.1322271291824917
# Final cost : 0.1322271291824917
# Compute control for a deterministic system
# Cost in iteration 0: 0.1322271291824917
# Cost in iteration 200: 0.13108850211863793
# Final cost : 0.13108850211863793
# Compute control for a deterministic system
# Cost in iteration 0: 0.13108850211863793
# Converged in iteration 71 with cost 0.13105470996590504 because of vanishing difference
# Final cost : 0.13105470996590504
# Compute control for a deterministic system
# Cost in iteration 0: 0.13105470996590504
# Cost in iteration 200: 0.13104982284841554
# Cost in iteration 400: 0.1310496515498934
# Final cost : 0.1310496515498934
# Compute control for a deterministic system
# Cost in iteration 0: 0.1310496515498934
# Cost in iteration 200: 0.1310496444008002
# Cost in iteration 400: 0.13104964397599658
# Cost in iteration 600: 0.1310496439507173
# Converged in iteration 765 with cost 0.13104964394916907 because of step counter
# Final cost : 0.13104964394916907
# Compute control for a deterministic system
# Cost in iteration 0: 2.221282287502974
# Final cost : 2.109451808059838
# Compute control for a deterministic system
# Cost in iteration 0: 2.109451808059838
# Cost in iteration 200: 0.14948835622991283
# Cost in iteration 400: 0.1431688637983407
# Final cost : 0.1431688637983407
# Compute control for a deterministic system
# Cost in iteration 0: 0.1431688637983407
# Cost in iteration 200: 0.14122823985993851
# Final cost : 0.14122823985993851
# Compute control for a deterministic system
# Cost in iteration 0: 0.14122823985993851
# Converged in iteration 54 with cost 0.1411601578883856 because of vanishing difference
# Final cost : 0.1411601578883856
# Compute control for a deterministic system
# Cost in iteration 0: 0.1411601578883856
# Cost in iteration 200: 0.14114058710097296
# Cost in iteration 400: 0.14113947231513305
# Final cost : 0.14113947231513305
# Compute control for a deterministic system
# Cost in iteration 0: 0.14113947231513305
# Cost in iteration 200: 0.14113939552415447
# Cost in iteration 400: 0.14113938854285593
# Cost in iteration 600: 0.14113938791153863
# Cost in iteration 800: 0.14113938785427685
# Cost in iteration 1000: 0.14113938784907873
# Final cost : 0.14113938784907873
# Compute control for a deterministic system
# Cost in iteration 0: 2.305792408274015
# Final cost : 2.232254784095724
# Compute control for a deterministic system
# Cost in iteration 0: 2.232254784095724
# Cost in iteration 200: 0.16472214709218927
# Cost in iteration 400: 0.1544553624960348
# Final cost : 0.1544553624960348
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544553624960348
# Cost in iteration 200: 0.15137627768959186
# Final cost : 0.15137627768959186
# Compute control for a deterministic system
# Cost in iteration 0: 0.15137627768959186
# Converged in iteration 36 with cost 0.15127683499028569 because of vanishing difference
# Final cost : 0.15127683499028569
# Compute control for a deterministic system
# Cost in iteration 0: 0.15127683499028569
# Cost in iteration 200: 0.15121507418463304
# Cost in iteration 400: 0.15120988969057264
# Final cost : 0.15120988969057264
# Compute control for a deterministic system
# Cost in iteration 0: 0.15120988969057264
# Cost in iteration 200: 0.15120942324180986
# Cost in iteration 400: 0.15120936465699636
# Cost in iteration 600: 0.15120935718578077
# Cost in iteration 800: 0.15120935623453582
# Cost in iteration 1000: 0.15120935611279723
# Final cost : 0.15120935611279723
# Compute control for a deterministic system
# Cost in iteration 0: 2.372647091625591
# Final cost : 2.328590934399219
# Compute control for a deterministic system
# Cost in iteration 0: 2.328590934399219
# Cost in iteration 200: 0.18109202222598014
# Cost in iteration 400: 0.16624438340484587
# Final cost : 0.16624438340484587
# Compute control for a deterministic system
# Cost in iteration 0: 0.16624438340484587
# Cost in iteration 200: 0.16153195571853252
# Final cost : 0.16153195571853252
# Compute control for a deterministic system
# Cost in iteration 0: 0.16153195571853252
# Cost in iteration 200: 0.16124939808803337
# Final cost : 0.16124939808803337
# Compute control for a deterministic system
# Cost in iteration 0: 0.16124939808803337
# Cost in iteration 200: 0.16124447852260662
# Cost in iteration 400: 0.16124387992438272
# Final cost : 0.16124387992438272
# Compute control for a deterministic system
# Cost in iteration 0: 0.16124387992438272
# Cost in iteration 200: 0.16124379927066806
# Cost in iteration 400: 0.16124378566762598
# Cost in iteration 600: 0.16124378339746243
# Cost in iteration 800: 0.1612437830136924
# Cost in iteration 1000: 0.16124378294940933
# Final cost : 0.16124378294940933
# Compute control for a deterministic system
# Cost in iteration 0: 2.42155751651184
# Final cost : 2.398774142232758
# Compute control for a deterministic system
# Cost in iteration 0: 2.398774142232758
# Cost in iteration 200: 0.19891472264302887
# Cost in iteration 400: 0.17856293920589097
# Final cost : 0.17856293920589097
# Compute control for a deterministic system
# Cost in iteration 0: 0.17856293920589097
# Cost in iteration 200: 0.17167343734847
# Final cost : 0.17167343734847
# Compute control for a deterministic system
# Cost in iteration 0: 0.17167343734847
# Converged in iteration 185 with cost 0.171226874829079 because of vanishing difference
# Final cost : 0.171226874829079
# Compute control for a deterministic system
# Cost in iteration 0: 0.171226874829079
# Cost in iteration 200: 0.1712101897373371
# Cost in iteration 400: 0.17120739650548497
# Final cost : 0.17120739650548497
# Compute control for a deterministic system
# Cost in iteration 0: 0.17120739650548497
# Cost in iteration 200: 0.17120697306419058
# Cost in iteration 400: 0.17120688450789714
# Cost in iteration 600: 0.17120686594661502
# Cost in iteration 800: 0.17120686205984698
# Cost in iteration 1000: 0.1712068612442019
# Final cost : 0.1712068612442019
# Compute control for a deterministic system
# Cost in iteration 0: 2.451599121719409
# Final cost : 2.4425450130239925
# Compute control for a deterministic system
# Cost in iteration 0: 2.4425450130239925
# Cost in iteration 200: 0.2187393351249299
# Cost in iteration 400: 0.19157608114875263
# Final cost : 0.19157608114875263
# Compute control for a deterministic system
# Cost in iteration 0: 0.19157608114875263
# Cost in iteration 200: 0.18177256661182015
# Final cost : 0.18177256661182015
# Compute control for a deterministic system
# Cost in iteration 0: 0.18177256661182015
# Cost in iteration 200: 0.18109406773018086
# Final cost : 0.18109406773018086
# Compute control for a deterministic system
# Cost in iteration 0: 0.18109406773018086
# Cost in iteration 200: 0.18105042325658918
# Cost in iteration 400: 0.181041899849313
# Final cost : 0.181041899849313
# Compute control for a deterministic system
# Cost in iteration 0: 0.181041899849313
# Cost in iteration 200: 0.18104019715490546
# Cost in iteration 400: 0.18103977823450676
# Cost in iteration 600: 0.18103967272572083
# Cost in iteration 800: 0.181039646551763
# Cost in iteration 1000: 0.18103963998896672
# Final cost : 0.18103963998896672
# Compute control for a deterministic system
# Cost in iteration 0: 2.461569201463839
# Final cost : 2.4595607483615134
# Compute control for a deterministic system
# Cost in iteration 0: 2.4595607483615134
# Cost in iteration 200: 0.2432900107158177
# Cost in iteration 400: 0.20594404897063312
# Final cost : 0.20594404897063312
# Compute control for a deterministic system
# Cost in iteration 0: 0.20594404897063312
# Cost in iteration 200: 0.19195851121727955
# Final cost : 0.19195851121727955
# Compute control for a deterministic system
# Cost in iteration 0: 0.19195851121727955
# Cost in iteration 200: 0.19111115297077508
# Final cost : 0.19111115297077508
# Compute control for a deterministic system
# Cost in iteration 0: 0.19111115297077508
# Cost in iteration 200: 0.1909555990170381
# Cost in iteration 400: 0.19092368014496328
# Final cost : 0.19092368014496328
# Compute control for a deterministic system
# Cost in iteration 0: 0.19092368014496328
# Cost in iteration 200: 0.19091659839940997
# Cost in iteration 400: 0.1909146051626451
# Cost in iteration 600: 0.19091403730312995
# Cost in iteration 800: 0.19091387215403535
# Cost in iteration 1000: 0.19091382461830514
# Final cost : 0.19091382461830514
# Compute control for a deterministic system
# Cost in iteration 0: 2.4505729626579504
# Final cost : 2.4499844740861527
# Compute control for a deterministic system
# Cost in iteration 0: 2.4499844740861527
# Cost in iteration 200: 0.28479378899639224
# Cost in iteration 400: 0.23240696494288535
# Final cost : 0.23240696494288535
# Compute control for a deterministic system
# Cost in iteration 0: 0.23240696494288535
# Cost in iteration 200: 0.20956138302605287
# Final cost : 0.20956138302605287
# Compute control for a deterministic system
# Cost in iteration 0: 0.20956138302605287
# Cost in iteration 200: 0.20834771590274034
# Final cost : 0.20834771590274034
# Compute control for a deterministic system
# Cost in iteration 0: 0.20834771590274034
# Cost in iteration 200: 0.20804232896452077
# Cost in iteration 400: 0.20798695388490637
# Final cost : 0.20798695388490637
# Compute control for a deterministic system
# Cost in iteration 0: 0.20798695388490637
# Cost in iteration 200: 0.2079743764058309
# Cost in iteration 400: 0.20797070052954766
# Cost in iteration 600: 0.2079696209771926
# Cost in iteration 800: 0.20796929782354798
# Cost in iteration 1000: 0.2079692010484216
# Final cost : 0.2079692010484216
# Compute control for a deterministic system
# Cost in iteration 0: 2.4201336805228677
# Final cost : 2.4165934872015513
# Compute control for a deterministic system
# Cost in iteration 0: 2.4165934872015513
# Cost in iteration 200: 0.24722286561371054
# Cost in iteration 400: 0.21335088727574247
# Final cost : 0.21335088727574247
# Compute control for a deterministic system
# Cost in iteration 0: 0.21335088727574247
# Cost in iteration 200: 0.19805147549108384
# Final cost : 0.19805147549108384
# Compute control for a deterministic system
# Cost in iteration 0: 0.19805147549108384
# Cost in iteration 200: 0.19729973355978753
# Final cost : 0.19729973355978753
# Compute control for a deterministic system
# Cost in iteration 0: 0.19729973355978753
# Cost in iteration 200: 0.19712274411846525
# Cost in iteration 400: 0.19709363317993522
# Final cost : 0.19709363317993522
# Compute control for a deterministic system
# Cost in iteration 0: 0.19709363317993522
# Cost in iteration 200: 0.1970880968063141
# Cost in iteration 400: 0.19708673161965598
# Cost in iteration 600: 0.19708639291064642
# Cost in iteration 800: 0.19708630799972235
# Cost in iteration 1000: 0.19708628665838687
# Final cost : 0.19708628665838687
# Compute control for a deterministic system
# Cost in iteration 0: 2.3729221862963197
# Final cost : 2.3611442046724043
# Compute control for a deterministic system
# Cost in iteration 0: 2.3611442046724043
# Cost in iteration 200: 0.2230118018209367
# Cost in iteration 400: 0.19785226229720235
# Final cost : 0.19785226229720235
# Compute control for a deterministic system
# Cost in iteration 0: 0.19785226229720235
# Cost in iteration 200: 0.18700987263266725
# Final cost : 0.18700987263266725
# Compute control for a deterministic system
# Cost in iteration 0: 0.18700987263266725
# Cost in iteration 200: 0.18646799858945043
# Final cost : 0.18646799858945043
# Compute control for a deterministic system
# Cost in iteration 0: 0.18646799858945043
# Cost in iteration 200: 0.186356009299425
# Cost in iteration 400: 0.18634150581573103
# Final cost : 0.18634150581573103
# Compute control for a deterministic system
# Cost in iteration 0: 0.18634150581573103
# Cost in iteration 200: 0.18633911322842453
# Cost in iteration 400: 0.18633863177723273
# Cost in iteration 600: 0.18633853452106391
# Cost in iteration 800: 0.18633851464044368
# Cost in iteration 1000: 0.18633851057166848
# Final cost : 0.18633851057166848
# Compute control for a deterministic system
# Cost in iteration 0: 2.3121437845323864
# Final cost : 2.2862875109718295
# Compute control for a deterministic system
# Cost in iteration 0: 2.2862875109718295
# Cost in iteration 200: 0.20212219855456381
# Cost in iteration 400: 0.18361769750985793
# Final cost : 0.18361769750985793
# Compute control for a deterministic system
# Cost in iteration 0: 0.18361769750985793
# Cost in iteration 200: 0.17603503249995228
# Final cost : 0.17603503249995228
# Compute control for a deterministic system
# Cost in iteration 0: 0.17603503249995228
# Cost in iteration 200: 0.17567343120212933
# Final cost : 0.17567343120212933
# Compute control for a deterministic system
# Cost in iteration 0: 0.17567343120212933
# Cost in iteration 200: 0.17564564898468035
# Cost in iteration 400: 0.1756428755672323
# Final cost : 0.1756428755672323
# Compute control for a deterministic system
# Cost in iteration 0: 0.1756428755672323
# Cost in iteration 200: 0.175642521378534
# Cost in iteration 400: 0.17564246482940843
# Cost in iteration 600: 0.17564245577670934
# Cost in iteration 800: 0.17564245431909134
# Cost in iteration 1000: 0.1756424540859594
# Final cost : 0.1756424540859594
# Compute control for a deterministic system
# Cost in iteration 0: 2.2399804106186556
# Final cost : 2.1938546104133434
# Compute control for a deterministic system
# Cost in iteration 0: 2.1938546104133434
# Cost in iteration 200: 0.18331975905784328
# Cost in iteration 400: 0.17037023898256423
# Final cost : 0.17037023898256423
# Compute control for a deterministic system
# Cost in iteration 0: 0.17037023898256423
# Cost in iteration 200: 0.16518458769081387
# Final cost : 0.16518458769081387
# Compute control for a deterministic system
# Cost in iteration 0: 0.16518458769081387
# Cost in iteration 200: 0.16497606034147588
# Final cost : 0.16497606034147588
# Compute control for a deterministic system
# Cost in iteration 0: 0.16497606034147588
# Cost in iteration 200: 0.1649732945176252
# Cost in iteration 400: 0.16497305761864822
# Final cost : 0.16497305761864822
# Compute control for a deterministic system
# Cost in iteration 0: 0.16497305761864822
# Cost in iteration 200: 0.16497303758175377
# Cost in iteration 400: 0.16497303518211937
# Cost in iteration 600: 0.1649730348929321
# Cost in iteration 800: 0.1649730348584145
# Cost in iteration 1000: 0.16497303485426945
# Final cost : 0.16497303485426945
# Compute control for a deterministic system
# Cost in iteration 0: 2.157101776921312
# Final cost : 2.0840956678574125
# Compute control for a deterministic system
# Cost in iteration 0: 2.0840956678574125
# Cost in iteration 200: 0.1661130510259835
# Cost in iteration 400: 0.15782831390223417
# Final cost : 0.15782831390223417
# Compute control for a deterministic system
# Cost in iteration 0: 0.15782831390223417
# Cost in iteration 200: 0.15443872937379283
# Final cost : 0.15443872937379283
# Compute control for a deterministic system
# Cost in iteration 0: 0.15443872937379283
# Converged in iteration 121 with cost 0.15434897454306562 because of vanishing difference
# Final cost : 0.15434897454306562
# Compute control for a deterministic system
# Cost in iteration 0: 0.15434897454306562
# Cost in iteration 200: 0.15433098986047172
# Cost in iteration 400: 0.1543301436452351
# Final cost : 0.1543301436452351
# Compute control for a deterministic system
# Cost in iteration 0: 0.1543301436452351
# Cost in iteration 200: 0.15433009416270235
# Cost in iteration 400: 0.15433008995234873
# Cost in iteration 600: 0.15433008959984099
# Cost in iteration 800: 0.15433008957008718
# Converged in iteration 974 with cost 0.15433008956760766 because of vanishing difference
# Final cost : 0.15433008956760766
# Compute control for a deterministic system
# Cost in iteration 0: 2.063073075638606
# Final cost : 1.956134296497984
# Compute control for a deterministic system
# Cost in iteration 0: 1.956134296497984
# Cost in iteration 200: 0.15076967731810187
# Cost in iteration 400: 0.14588455617140536
# Final cost : 0.14588455617140536
# Compute control for a deterministic system
# Cost in iteration 0: 0.14588455617140536
# Cost in iteration 200: 0.1437810134193981
# Final cost : 0.1437810134193981
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437810134193981
# Cost in iteration 200: 0.14372881149143693
# Final cost : 0.14372881149143693
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372881149143693
# Cost in iteration 200: 0.14372881021701195
# Cost in iteration 400: 0.14372881017655686
# Final cost : 0.14372881017655686
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372881017655686
# Converged in iteration 159 with cost 0.14372881017522268 because of step counter
# Final cost : 0.14372881017522268
# Compute control for a deterministic system
# Cost in iteration 0: 1.9544762463657586
# Final cost : 1.8052612669565884
# Compute control for a deterministic system
# Cost in iteration 0: 1.8052612669565884
# Cost in iteration 200: 0.13757464150553406
# Cost in iteration 400: 0.1341984219712164
# Final cost : 0.1341984219712164
# Compute control for a deterministic system
# Cost in iteration 0: 0.1341984219712164
# Cost in iteration 200: 0.13297383222306175
# Final cost : 0.13297383222306175
# Compute control for a deterministic system
# Cost in iteration 0: 0.13297383222306175
# Cost in iteration 200: 0.13295152777465893
# Final cost : 0.13295152777465893
# Compute control for a deterministic system
# Cost in iteration 0: 0.13295152777465893
# Cost in iteration 200: 0.13295152774298633
# Converged in iteration 255 with cost 0.13295152774269972 because of step counter
# Final cost : 0.13295152774269972
# Compute control for a deterministic system
# Cost in iteration 0: 0.13295152774269972
# Converged in iteration 1 with cost 0.13295152774269972 because of step counter
# Final cost : 0.13295152774269972
# Compute control for a deterministic system
# Cost in iteration 0: 1.8348249270895876
# Final cost : 1.6368729147869499
# Compute control for a deterministic system
# Cost in iteration 0: 1.6368729147869499
# Cost in iteration 200: 0.12540911177687677
# Cost in iteration 400: 0.12313896829352275
# Final cost : 0.12313896829352275
# Compute control for a deterministic system
# Cost in iteration 0: 0.12313896829352275
# Cost in iteration 200: 0.12246598440394063
# Final cost : 0.12246598440394063
# Compute control for a deterministic system
# Cost in iteration 0: 0.12246598440394063
# Cost in iteration 200: 0.12245891396311775
# Final cost : 0.12245891396311775
# Compute control for a deterministic system
# Cost in iteration 0: 0.12245891396311775
# Converged in iteration 124 with cost 0.12245891396119477 because of step counter
# Final cost : 0.12245891396119477
# Compute control for a deterministic system
# Cost in iteration 0: 0.12245891396119477
# Converged in iteration 1 with cost 0.12245891396119477 because of step counter
# Final cost : 0.12245891396119477
# Compute control for a deterministic system
# Cost in iteration 0: 1.7009888106987157
# Final cost : 1.447922493693129
# Compute control for a deterministic system
# Cost in iteration 0: 1.447922493693129
# Cost in iteration 200: 0.11377824302908504
# Cost in iteration 400: 0.11234756162231913
# Final cost : 0.11234756162231913
# Compute control for a deterministic system
# Cost in iteration 0: 0.11234756162231913
# Cost in iteration 200: 0.11201929157145885
# Final cost : 0.11201929157145885
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201929157145885
# Converged in iteration 163 with cost 0.11201742833480975 because of step counter
# Final cost : 0.11201742833480975
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742833480975
# Converged in iteration 2 with cost 0.11201742833480959 because of step counter
# Final cost : 0.11201742833480959
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742833480959
# Converged in iteration 1 with cost 0.11201742833480959 because of step counter
# Final cost : 0.11201742833480959
# Compute control for a deterministic system
# Cost in iteration 0: 1.5523315023457602
# Final cost : 1.2401469857601553
# Compute control for a deterministic system
# Cost in iteration 0: 1.2401469857601553
# Cost in iteration 200: 0.10261911794711497
# Cost in iteration 400: 0.1017674906790928
# Final cost : 0.1017674906790928
# Compute control for a deterministic system
# Cost in iteration 0: 0.1017674906790928
# Cost in iteration 200: 0.10162150786173792
# Final cost : 0.10162150786173792
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162150786173792
# Cost in iteration 200: 0.10162115685268377
# Final cost : 0.10162115685268377
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162115685268377
# Converged in iteration 116 with cost 0.1016211568475409 because of step counter
# Final cost : 0.1016211568475409
# Compute control for a deterministic system
# Cost in iteration 0: 0.1016211568475409
# Converged in iteration 1 with cost 0.1016211568475409 because of step counter
# Final cost : 0.1016211568475409
# Compute control for a deterministic system
# Cost in iteration 0: 1.3887496072900851
# Final cost : 1.0182024052896994
# Compute control for a deterministic system
# Cost in iteration 0: 1.0182024052896994
# Cost in iteration 200: 0.09178005498050443
# Cost in iteration 400: 0.09132524207058908
# Final cost : 0.09132524207058908
# Compute control for a deterministic system
# Cost in iteration 0: 0.09132524207058908
# Converged in iteration 182 with cost 0.09126418585413189 because of vanishing difference
# Final cost : 0.09126418585413189
# Compute control for a deterministic system
# Cost in iteration 0: 0.09126418585413189
# Cost in iteration 200: 0.09126409370281648
# Final cost : 0.09126409370281648
# Compute control for a deterministic system
# Cost in iteration 0: 0.09126409370281648
# Converged in iteration 187 with cost 0.0912640933107487 because of step counter
# Final cost : 0.0912640933107487
# Compute control for a deterministic system
# Cost in iteration 0: 0.0912640933107487
# Converged in iteration 4 with cost 0.09126409331074596 because of step counter
# Final cost : 0.09126409331074596
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109798060388104
# Final cost : 0.790925779283365
# Compute control for a deterministic system
# Cost in iteration 0: 0.790925779283365
# Cost in iteration 200: 0.08116920713053878
# Cost in iteration 400: 0.0809569950029253
# Final cost : 0.0809569950029253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0809569950029253
# Converged in iteration 102 with cost 0.08094132286977515 because of vanishing difference
# Final cost : 0.08094132286977515
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094132286977515
# Cost in iteration 200: 0.08094116605401053
# Final cost : 0.08094116605401053
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116605401053
# Converged in iteration 79 with cost 0.08094116599469159 because of vanishing difference
# Final cost : 0.08094116599469159
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116599469159
# Converged in iteration 61 with cost 0.08094116599419712 because of step counter
# Final cost : 0.08094116599419712
# Compute control for a deterministic system
# Cost in iteration 0: 1.0210527966865819
# Final cost : 0.5719433888248502
# Compute control for a deterministic system
# Cost in iteration 0: 0.5719433888248502
# Cost in iteration 200: 0.07073352557768503
# Cost in iteration 400: 0.07065194140862883
# Final cost : 0.07065194140862883
# Compute control for a deterministic system
# Cost in iteration 0: 0.07065194140862883
# Cost in iteration 200: 0.07064867538533864
# Final cost : 0.07064867538533864
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064867538533864
# Converged in iteration 153 with cost 0.07064867534809068 because of step counter
# Final cost : 0.07064867534809068
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064867534809068
# Converged in iteration 2 with cost 0.07064867534808941 because of step counter
# Final cost : 0.07064867534808941
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064867534808941
# Converged in iteration 1 with cost 0.07064867534808941 because of step counter
# Final cost : 0.07064867534808941
# Compute control for a deterministic system
# Cost in iteration 0: 0.8185573881107101
# Final cost : 0.37428532257872027
# Compute control for a deterministic system
# Cost in iteration 0: 0.37428532257872027
# Cost in iteration 200: 0.060185481516065606
# Cost in iteration 400: 0.06016197083972611
# Final cost : 0.06016197083972611
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016197083972611
# Converged in iteration 41 with cost 0.06016158836014549 because of vanishing difference
# Final cost : 0.06016158836014549
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016158836014549
# Converged in iteration 197 with cost 0.06016157722997289 because of step counter
# Final cost : 0.06016157722997289
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016157722997289
# Converged in iteration 3 with cost 0.060161577229971494 because of step counter
# Final cost : 0.060161577229971494
# Compute control for a deterministic system
# Cost in iteration 0: 0.060161577229971494
# Converged in iteration 1 with cost 0.060161577229971494 because of step counter
# Final cost : 0.060161577229971494
# Compute control for a deterministic system
# Cost in iteration 0: 0.618810943238059
# Final cost : 0.22186504379362437
# Compute control for a deterministic system
# Cost in iteration 0: 0.22186504379362437
# Cost in iteration 200: 0.04992987352604259
# Cost in iteration 400: 0.04992544517523915
# Final cost : 0.04992544517523915
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992544517523915
# Converged in iteration 147 with cost 0.04992542381239707 because of step counter
# Final cost : 0.04992542381239707
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542381239707
# Converged in iteration 1 with cost 0.04992542381239707 because of step counter
# Final cost : 0.04992542381239707
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542381239707
# Converged in iteration 1 with cost 0.04992542381239707 because of step counter
# Final cost : 0.04992542381239707
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542381239707
# Converged in iteration 1 with cost 0.04992542381239707 because of step counter
# Final cost : 0.04992542381239707
# Compute control for a deterministic system
# Cost in iteration 0: 0.4272494763271503
# Final cost : 0.11738608971892121
# Compute control for a deterministic system
# Cost in iteration 0: 0.11738608971892121
# Cost in iteration 200: 0.03971799909560594
# Cost in iteration 400: 0.0397176784550689
# Final cost : 0.0397176784550689
# Compute control for a deterministic system
# Cost in iteration 0: 0.0397176784550689
# Converged in iteration 69 with cost 0.03971767824023302 because of step counter
# Final cost : 0.03971767824023302
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767824023302
# Converged in iteration 1 with cost 0.03971767824023302 because of step counter
# Final cost : 0.03971767824023302
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767824023302
# Converged in iteration 1 with cost 0.03971767824023302 because of step counter
# Final cost : 0.03971767824023302
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767824023302
# Converged in iteration 1 with cost 0.03971767824023302 because of step counter
# Final cost : 0.03971767824023302
# Compute control for a deterministic system
# Cost in iteration 0: 0.25632778459833644
# Final cost : 0.056652645246152024
# Compute control for a deterministic system
# Cost in iteration 0: 0.056652645246152024
# Cost in iteration 200: 0.029541068198812814
# Converged in iteration 217 with cost 0.029541063808620243 because of vanishing difference
# Final cost : 0.029541063808620243
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541063808620243
# Converged in iteration 57 with cost 0.029541060702216026 because of step counter
# Final cost : 0.029541060702216026
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060702216026
# Converged in iteration 1 with cost 0.029541060702216026 because of step counter
# Final cost : 0.029541060702216026
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060702216026
# Converged in iteration 1 with cost 0.029541060702216026 because of step counter
# Final cost : 0.029541060702216026
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060702216026
# Converged in iteration 1 with cost 0.029541060702216026 because of step counter
# Final cost : 0.029541060702216026
# Compute control for a deterministic system
# Cost in iteration 0: 0.11994841961844178
# Final cost : 0.026313582626443288
# Compute control for a deterministic system
# Cost in iteration 0: 0.026313582626443288
# Cost in iteration 200: 0.01940081090009982
# Converged in iteration 251 with cost 0.019400810896223485 because of step counter
# Final cost : 0.019400810896223485
# Compute control for a deterministic system
# Cost in iteration 0: 0.019400810896223485
# Converged in iteration 6 with cost 0.019400810896186515 because of step counter
# Final cost : 0.019400810896186515
# Compute control for a deterministic system
# Cost in iteration 0: 0.019400810896186515
# Converged in iteration 1 with cost 0.019400810896186515 because of step counter
# Final cost : 0.019400810896186515
# Compute control for a deterministic system
# Cost in iteration 0: 0.019400810896186515
# Converged in iteration 2 with cost 0.019400810896186296 because of step counter
# Final cost : 0.019400810896186296
# Compute control for a deterministic system
# Cost in iteration 0: 0.019400810896186296
# Converged in iteration 1 with cost 0.019400810896186296 because of step counter
# Final cost : 0.019400810896186296
# Compute control for a deterministic system
# Cost in iteration 0: 0.031234744306238318
# Final cost : 0.010897399598007264
# Compute control for a deterministic system
# Cost in iteration 0: 0.010897399598007264
# Converged in iteration 66 with cost 0.009306535261722357 because of vanishing difference
# Final cost : 0.009306535261722357
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306535261722357
# Converged in iteration 11 with cost 0.009306535073759756 because of step counter
# Final cost : 0.009306535073759756
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306535073759756
# Converged in iteration 1 with cost 0.009306535073759756 because of step counter
# Final cost : 0.009306535073759756
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306535073759756
# Converged in iteration 2 with cost 0.00930653507375966 because of step counter
# Final cost : 0.00930653507375966
# Compute control for a deterministic system
# Cost in iteration 0: 0.00930653507375966
# Converged in iteration 1 with cost 0.00930653507375966 because of step counter
# Final cost : 0.00930653507375966
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Converged in iteration 1 with cost 1.8375344496151055e-06 because of step counter
# Final cost : 1.8375344496151055e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05047171213512077
# Converged in iteration 123 with cost 0.019314241303629187 because of vanishing difference
# Final cost : 0.019314241303629187
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314241303629187
# Converged in iteration 32 with cost 0.019314239420691277 because of step counter
# Final cost : 0.019314239420691277
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239420691277
# Converged in iteration 1 with cost 0.019314239420691277 because of step counter
# Final cost : 0.019314239420691277
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239420691277
# Converged in iteration 2 with cost 0.019314239420691128 because of step counter
# Final cost : 0.019314239420691128
# Compute control for a deterministic system
# Cost in iteration 0: 0.019314239420691128
# Converged in iteration 1 with cost 0.019314239420691128 because of step counter
# Final cost : 0.019314239420691128
# Compute control for a deterministic system
# Cost in iteration 0: 0.06003042333829513
# Converged in iteration 198 with cost 0.02940899901563989 because of vanishing difference
# Final cost : 0.02940899901563989
# Compute control for a deterministic system
# Cost in iteration 0: 0.02940899901563989
# Converged in iteration 64 with cost 0.02940899550179809 because of step counter
# Final cost : 0.02940899550179809
# Compute control for a deterministic system
# Cost in iteration 0: 0.02940899550179809
# Converged in iteration 1 with cost 0.02940899550179809 because of step counter
# Final cost : 0.02940899550179809
# Compute control for a deterministic system
# Cost in iteration 0: 0.02940899550179809
# Converged in iteration 1 with cost 0.02940899550179809 because of step counter
# Final cost : 0.02940899550179809
# ...
# Final cost : 0.1649730262876232
# Compute control for a deterministic system
# Cost in iteration 0: 0.1649730262876232
# Cost in iteration 200: 0.16497300976896495
# Final cost : 0.16497300976896495
# Compute control for a deterministic system
# Cost in iteration 0: 0.16497300976896495
# Cost in iteration 200: 0.1649730095133214
# Final cost : 0.1649730095133214
# Compute control for a deterministic system
# Cost in iteration 0: 0.1649730095133214
# Converged in iteration 42 with cost 0.16497300951316773 because of step counter
# Final cost : 0.16497300951316773
# Compute control for a deterministic system
# Cost in iteration 0: 0.16497300951316773
# Converged in iteration 1 with cost 0.16497300951316773 because of step counter
# Final cost : 0.16497300951316773
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.15884821565467222
# Cost in iteration 200: 0.15433008132590026
# Final cost : 0.15433008132590026
# Compute control for a deterministic system
# Cost in iteration 0: 0.15433008132590026
# Cost in iteration 200: 0.1543300624768459
# Final cost : 0.1543300624768459
# Compute control for a deterministic system
# Cost in iteration 0: 0.1543300624768459
# Converged in iteration 189 with cost 0.15433006224056678 because of step counter
# Final cost : 0.15433006224056678
# Compute control for a deterministic system
# Cost in iteration 0: 0.15433006224056678
# Converged in iteration 2 with cost 0.1543300622405658 because of step counter
# Final cost : 0.1543300622405658
# Compute control for a deterministic system
# Cost in iteration 0: 0.1543300622405658
# Converged in iteration 1 with cost 0.1543300622405658 because of step counter
# Final cost : 0.1543300622405658
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.15215167884660985
# Cost in iteration 200: 0.14372881070680524
# Final cost : 0.14372881070680524
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372881070680524
# Cost in iteration 200: 0.14372880142020594
# Final cost : 0.14372880142020594
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372880142020594
# Converged in iteration 83 with cost 0.14372880141267344 because of step counter
# Final cost : 0.14372880141267344
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372880141267344
# Converged in iteration 3 with cost 0.14372880141267247 because of step counter
# Final cost : 0.14372880141267247
# Compute control for a deterministic system
# Cost in iteration 0: 0.14372880141267247
# Converged in iteration 4 with cost 0.14372880141266955 because of step counter
# Final cost : 0.14372880141266955
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.13703794427950394
# Cost in iteration 200: 0.1329515271211208
# Final cost : 0.1329515271211208
# Compute control for a deterministic system
# Cost in iteration 0: 0.1329515271211208
# Cost in iteration 200: 0.13295151331956107
# Final cost : 0.13295151331956107
# Compute control for a deterministic system
# Cost in iteration 0: 0.13295151331956107
# Converged in iteration 95 with cost 0.13295151323077195 because of step counter
# Final cost : 0.13295151323077195
# Compute control for a deterministic system
# Cost in iteration 0: 0.13295151323077195
# Converged in iteration 1 with cost 0.13295151323077195 because of step counter
# Final cost : 0.13295151323077195
# Compute control for a deterministic system
# Cost in iteration 0: 0.13295151323077195
# Converged in iteration 1 with cost 0.13295151323077195 because of step counter
# Final cost : 0.13295151323077195
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.12493214435654393
# Cost in iteration 200: 0.12245891103915676
# Final cost : 0.12245891103915676
# Compute control for a deterministic system
# Cost in iteration 0: 0.12245891103915676
# Cost in iteration 200: 0.1224589091640905
# Final cost : 0.1224589091640905
# Compute control for a deterministic system
# Cost in iteration 0: 0.1224589091640905
# Converged in iteration 56 with cost 0.12245890916080036 because of step counter
# Final cost : 0.12245890916080036
# Compute control for a deterministic system
# Cost in iteration 0: 0.12245890916080036
# Converged in iteration 2 with cost 0.12245890916079993 because of step counter
# Final cost : 0.12245890916079993
# Compute control for a deterministic system
# Cost in iteration 0: 0.12245890916079993
# Converged in iteration 2 with cost 0.12245890916079988 because of step counter
# Final cost : 0.12245890916079988
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.11435314141874399
# Cost in iteration 200: 0.11201742457470663
# Final cost : 0.11201742457470663
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742457470663
# Cost in iteration 200: 0.11201742325865857
# Final cost : 0.11201742325865857
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742325865857
# Converged in iteration 79 with cost 0.11201742325745782 because of vanishing difference
# Final cost : 0.11201742325745782
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742325745782
# Converged in iteration 1 with cost 0.11201742325745782 because of step counter
# Final cost : 0.11201742325745782
# Compute control for a deterministic system
# Cost in iteration 0: 0.11201742325745782
# Converged in iteration 4 with cost 0.1120174232574566 because of step counter
# Final cost : 0.1120174232574566
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.10939824108708796
# Cost in iteration 200: 0.10162117673105582
# Final cost : 0.10162117673105582
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162117673105582
# Cost in iteration 200: 0.10162115459321086
# Final cost : 0.10162115459321086
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162115459321086
# Converged in iteration 109 with cost 0.10162115457433853 because of step counter
# Final cost : 0.10162115457433853
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162115457433853
# Converged in iteration 1 with cost 0.10162115457433853 because of step counter
# Final cost : 0.10162115457433853
# Compute control for a deterministic system
# Cost in iteration 0: 0.10162115457433853
# Converged in iteration 2 with cost 0.10162115457433807 because of step counter
# Final cost : 0.10162115457433807
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.09170579701077408
# Cost in iteration 200: 0.09126409032559232
# Final cost : 0.09126409032559232
# Compute control for a deterministic system
# Cost in iteration 0: 0.09126409032559232
# Cost in iteration 200: 0.0912640901217656
# Final cost : 0.0912640901217656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0912640901217656
# Converged in iteration 10 with cost 0.09126409012173103 because of step counter
# Final cost : 0.09126409012173103
# Compute control for a deterministic system
# Cost in iteration 0: 0.09126409012173103
# Converged in iteration 2 with cost 0.09126409012173003 because of step counter
# Final cost : 0.09126409012173003
# Compute control for a deterministic system
# Cost in iteration 0: 0.09126409012173003
# Converged in iteration 1 with cost 0.09126409012173003 because of step counter
# Final cost : 0.09126409012173003
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.08294429772474099
# Cost in iteration 200: 0.08094116444199707
# Final cost : 0.08094116444199707
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116444199707
# Cost in iteration 200: 0.08094116239667187
# Final cost : 0.08094116239667187
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116239667187
# Converged in iteration 15 with cost 0.08094116239657899 because of step counter
# Final cost : 0.08094116239657899
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116239657899
# Converged in iteration 1 with cost 0.08094116239657899 because of step counter
# Final cost : 0.08094116239657899
# Compute control for a deterministic system
# Cost in iteration 0: 0.08094116239657899
# Converged in iteration 1 with cost 0.08094116239657899 because of step counter
# Final cost : 0.08094116239657899
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.07239318605119739
# Cost in iteration 200: 0.07064867361000213
# Final cost : 0.07064867361000213
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064867361000213
# Converged in iteration 159 with cost 0.0706486725092445 because of step counter
# Final cost : 0.0706486725092445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0706486725092445
# Converged in iteration 1 with cost 0.0706486725092445 because of step counter
# Final cost : 0.0706486725092445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0706486725092445
# Converged in iteration 24 with cost 0.07064867250920202 because of step counter
# Final cost : 0.07064867250920202
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064867250920202
# Converged in iteration 2 with cost 0.07064867250920007 because of step counter
# Final cost : 0.07064867250920007
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.060998848089507264
# Cost in iteration 200: 0.06016157511759693
# Final cost : 0.06016157511759693
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016157511759693
# Converged in iteration 74 with cost 0.060161575067556684 because of step counter
# Final cost : 0.060161575067556684
# Compute control for a deterministic system
# Cost in iteration 0: 0.060161575067556684
# Converged in iteration 19 with cost 0.06016157506752182 because of step counter
# Final cost : 0.06016157506752182
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016157506752182
# Converged in iteration 10 with cost 0.06016157506750875 because of step counter
# Final cost : 0.06016157506750875
# Compute control for a deterministic system
# Cost in iteration 0: 0.06016157506750875
# Converged in iteration 1 with cost 0.06016157506750875 because of step counter
# Final cost : 0.06016157506750875
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0499254365038528
# Converged in iteration 103 with cost 0.049925422729467525 because of step counter
# Final cost : 0.049925422729467525
# Compute control for a deterministic system
# Cost in iteration 0: 0.049925422729467525
# Converged in iteration 5 with cost 0.04992542272945103 because of step counter
# Final cost : 0.04992542272945103
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542272945103
# Converged in iteration 2 with cost 0.04992542272944848 because of step counter
# Final cost : 0.04992542272944848
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542272944848
# Converged in iteration 3 with cost 0.04992542272944697 because of step counter
# Final cost : 0.04992542272944697
# Compute control for a deterministic system
# Cost in iteration 0: 0.04992542272944697
# Converged in iteration 1 with cost 0.04992542272944697 because of step counter
# Final cost : 0.04992542272944697
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0397895221333393
# Cost in iteration 200: 0.03971767812716476
# Final cost : 0.03971767812716476
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767812716476
# Converged in iteration 29 with cost 0.03971767812642973 because of step counter
# Final cost : 0.03971767812642973
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767812642973
# Converged in iteration 1 with cost 0.03971767812642973 because of step counter
# Final cost : 0.03971767812642973
# Compute control for a deterministic system
# Cost in iteration 0: 0.03971767812642973
# Converged in iteration 3 with cost 0.039717678126429616 because of step counter
# Final cost : 0.039717678126429616
# Compute control for a deterministic system
# Cost in iteration 0: 0.039717678126429616
# Converged in iteration 1 with cost 0.039717678126429616 because of step counter
# Final cost : 0.039717678126429616
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.029803523623856232
# Cost in iteration 200: 0.02954106036204089
# Final cost : 0.02954106036204089
# Compute control for a deterministic system
# Cost in iteration 0: 0.02954106036204089
# Converged in iteration 10 with cost 0.029541060361994956 because of step counter
# Final cost : 0.029541060361994956
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060361994956
# Converged in iteration 2 with cost 0.029541060361994657 because of step counter
# Final cost : 0.029541060361994657
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060361994657
# Converged in iteration 1 with cost 0.029541060361994657 because of step counter
# Final cost : 0.029541060361994657
# Compute control for a deterministic system
# Cost in iteration 0: 0.029541060361994657
# Converged in iteration 3 with cost 0.029541060361994526 because of step counter
# Final cost : 0.029541060361994526
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.019638879110616292
# Converged in iteration 142 with cost 0.01940081062754856 because of step counter
# Final cost : 0.01940081062754856
# Compute control for a deterministic system
# Cost in iteration 0: 0.01940081062754856
# Converged in iteration 8 with cost 0.01940081062753847 because of step counter
# Final cost : 0.01940081062753847
# Compute control for a deterministic system
# Cost in iteration 0: 0.01940081062753847
# Converged in iteration 1 with cost 0.01940081062753847 because of step counter
# Final cost : 0.01940081062753847
# Compute control for a deterministic system
# Cost in iteration 0: 0.01940081062753847
# Converged in iteration 1 with cost 0.01940081062753847 because of step counter
# Final cost : 0.01940081062753847
# Compute control for a deterministic system
# Cost in iteration 0: 0.01940081062753847
# Converged in iteration 1 with cost 0.01940081062753847 because of step counter
# Final cost : 0.01940081062753847
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.009351660391849384
# Converged in iteration 67 with cost 0.009306534787796429 because of step counter
# Final cost : 0.009306534787796429
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306534787796429
# Converged in iteration 5 with cost 0.009306534787793497 because of step counter
# Final cost : 0.009306534787793497
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306534787793497
# Converged in iteration 1 with cost 0.009306534787793497 because of step counter
# Final cost : 0.009306534787793497
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306534787793497
# Converged in iteration 1 with cost 0.009306534787793497 because of step counter
# Final cost : 0.009306534787793497
# Compute control for a deterministic system
# Cost in iteration 0: 0.009306534787793497
# Converged in iteration 1 with cost 0.009306534787793497 because of step counter
# Final cost : 0.009306534787793497
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
