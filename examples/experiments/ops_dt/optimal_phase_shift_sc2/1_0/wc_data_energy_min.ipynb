# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,712], wc.inh[0,712]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# minima =  [ 1252  3093  4938  6783  8629 10474 12319 14165 16010 17856 19701 21546
#  23392 25237 27082 28928 30773 32618 34464 36309 38154 40000 41845 43690
#  45536 47381 49226 51072 52917 54763 56608 58453]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("a_s3_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("a_s3_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("a_s3_l2.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s3_l2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)


        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.03127304557649737
# Final cost : 0.0010052062204094934
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010052062204094934
# Final cost : 3.966839610623224e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.966839610623224e-05
# Final cost : 3.903579402238856e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.903579402238856e-05
# Final cost : 3.889233532524315e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.889233532524315e-05
# Final cost : 3.8830176337181245e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.8830176337181245e-05
# Final cost : 3.882016766941282e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.12304618880469587
# Final cost : 0.007329104329036449
# Compute control for a deterministic system
# Cost in iteration 0: 0.007329104329036449
# Final cost : 0.0001649354229517813
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001649354229517813
# Final cost : 0.00015772550105622204
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015772550105622204
# Final cost : 0.00015589843143368106
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015589843143368106
# Final cost : 0.00015510200920906982
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015510200920906982
# Final cost : 0.00015497263702653386
# Compute control for a deterministic system
# Cost in iteration 0: 0.2678910958547081
# Final cost : 0.030251383577122454
# Compute control for a deterministic system
# Cost in iteration 0: 0.030251383577122454
# Final cost : 0.0003887875734080128
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003887875734080128
# Final cost : 0.00035714922655357274
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035714922655357274
# Final cost : 0.0003511073752611876
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003511073752611876
# Final cost : 0.00034844978256955026
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034844978256955026
# Final cost : 0.00034800565635709484
# Compute control for a deterministic system
# Cost in iteration 0: 0.45792043825945333
# Final cost : 0.08895796595679947
# Compute control for a deterministic system
# Cost in iteration 0: 0.08895796595679947
# Final cost : 0.0007311182878668287
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007311182878668287
# Final cost : 0.0006469555921707006
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006469555921707006
# Final cost : 0.0006302359843534386
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006302359843534386
# Final cost : 0.0006250676659241981
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006250676659241981
# Final cost : 0.0006241847680770035
# Compute control for a deterministic system
# Cost in iteration 0: 0.6698235317517994
# Final cost : 0.1969603795132377
# Compute control for a deterministic system
# Cost in iteration 0: 0.1969603795132377
# Final cost : 0.001187030343731658
# Compute control for a deterministic system
# Cost in iteration 0: 0.001187030343731658
# Final cost : 0.001007183582473819
# Compute control for a deterministic system
# Cost in iteration 0: 0.001007183582473819
# Final cost : 0.0009817144906741522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009817144906741522
# Final cost : 0.0009731810696660354
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009731810696660354
# Final cost : 0.0009713159195986097
# Compute control for a deterministic system
# Cost in iteration 0: 0.892394714692296
# Final cost : 0.36084995991856805
# Compute control for a deterministic system
# Cost in iteration 0: 0.36084995991856805
# Final cost : 0.0017726013691551261
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017726013691551261
# Final cost : 0.0014530583934738944
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014530583934738944
# Final cost : 0.0014160653913400495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014160653913400495
# Final cost : 0.0013988867530022452
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013988867530022452
# Final cost : 0.0013940973240963053
# Compute control for a deterministic system
# Cost in iteration 0: 1.1133320054805924
# Final cost : 0.5732401436564359
# Compute control for a deterministic system
# Cost in iteration 0: 0.5732401436564359
# Final cost : 0.0024987517165929976
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024987517165929976
# Final cost : 0.001978210479084641
# Compute control for a deterministic system
# Cost in iteration 0: 0.001978210479084641
# Final cost : 0.001926149963649926
# Compute control for a deterministic system
# Cost in iteration 0: 0.001926149963649926
# Final cost : 0.0019003350579636427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019003350579636427
# Final cost : 0.0018921097035940033
# Compute control for a deterministic system
# Cost in iteration 0: 1.3240556037094873
# Final cost : 0.8167515610234671
# Compute control for a deterministic system
# Cost in iteration 0: 0.8167515610234671
# Final cost : 0.0033785080827371536
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033785080827371536
# Final cost : 0.0025891555379484762
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025891555379484762
# Final cost : 0.002516291639276787
# Compute control for a deterministic system
# Cost in iteration 0: 0.002516291639276787
# Final cost : 0.0024785136779995926
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024785136779995926
# Final cost : 0.0024650387747517702
# Compute control for a deterministic system
# Cost in iteration 0: 1.5194844574362227
# Final cost : 1.0711875673803153
# Compute control for a deterministic system
# Cost in iteration 0: 1.0711875673803153
# Final cost : 0.004428821512493699
# Compute control for a deterministic system
# Cost in iteration 0: 0.004428821512493699
# Final cost : 0.003283367890904771
# Compute control for a deterministic system
# Cost in iteration 0: 0.003283367890904771
# Final cost : 0.00318732633235486
# Compute control for a deterministic system
# Cost in iteration 0: 0.00318732633235486
# Final cost : 0.0031337346472843043
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031337346472843043
# Final cost : 0.003112722373104366
# Compute control for a deterministic system
# Cost in iteration 0: 1.6970628307830333
# Final cost : 1.3195967571900802
# Compute control for a deterministic system
# Cost in iteration 0: 1.3195967571900802
# Final cost : 0.005671605010530643
# Compute control for a deterministic system
# Cost in iteration 0: 0.005671605010530643
# Final cost : 0.004054306258699781
# Compute control for a deterministic system
# Cost in iteration 0: 0.004054306258699781
# Final cost : 0.003934987074532264
# Compute control for a deterministic system
# Cost in iteration 0: 0.003934987074532264
# Final cost : 0.0038656411024596475
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038656411024596475
# Final cost : 0.0038348989439475835
# Compute control for a deterministic system
# Cost in iteration 0: 1.8557834856769568
# Final cost : 1.5505915353607926
# Compute control for a deterministic system
# Cost in iteration 0: 1.5505915353607926
# Final cost : 0.007134657920111759
# Compute control for a deterministic system
# Cost in iteration 0: 0.007134657920111759
# Final cost : 0.004929105084709424
# Compute control for a deterministic system
# Cost in iteration 0: 0.004929105084709424
# Final cost : 0.004770272689589207
# Compute control for a deterministic system
# Cost in iteration 0: 0.004770272689589207
# Final cost : 0.004676765606785328
# Compute control for a deterministic system
# Cost in iteration 0: 0.004676765606785328
# Final cost : 0.0046317469118399525
# Compute control for a deterministic system
# Cost in iteration 0: 1.998330025119673
# Final cost : 1.7620225287195712
# Compute control for a deterministic system
# Cost in iteration 0: 1.7620225287195712
# Final cost : 0.008893602580514104
# Compute control for a deterministic system
# Cost in iteration 0: 0.008893602580514104
# Final cost : 0.005916644066688031
# Compute control for a deterministic system
# Cost in iteration 0: 0.005916644066688031
# Final cost : 0.00571103983379244
# Compute control for a deterministic system
# Cost in iteration 0: 0.00571103983379244
# Final cost : 0.005584781623067517
# Compute control for a deterministic system
# Cost in iteration 0: 0.005584781623067517
# Final cost : 0.005522539603973489
# Compute control for a deterministic system
# Cost in iteration 0: 2.1189328451240157
# Final cost : 1.942006460923763
# Compute control for a deterministic system
# Cost in iteration 0: 1.942006460923763
# Final cost : 0.010919029566728083
# Compute control for a deterministic system
# Cost in iteration 0: 0.010919029566728083
# Final cost : 0.0069820471543326525
# Compute control for a deterministic system
# Cost in iteration 0: 0.0069820471543326525
# Final cost : 0.006733337714360404
# Compute control for a deterministic system
# Cost in iteration 0: 0.006733337714360404
# Final cost : 0.006564344590760942
# Compute control for a deterministic system
# Cost in iteration 0: 0.006564344590760942
# Final cost : 0.0064707745130059
# Compute control for a deterministic system
# Cost in iteration 0: 2.221282287502974
# Final cost : 2.0945728295473676
# Compute control for a deterministic system
# Cost in iteration 0: 2.0945728295473676
# Final cost : 0.013302670940349067
# Compute control for a deterministic system
# Cost in iteration 0: 0.013302670940349067
# Final cost : 0.008139033672372516
# Compute control for a deterministic system
# Cost in iteration 0: 0.008139033672372516
# Final cost : 0.007834125090160462
# Compute control for a deterministic system
# Cost in iteration 0: 0.007834125090160462
# Final cost : 0.007616498985535188
# Compute control for a deterministic system
# Cost in iteration 0: 0.007616498985535188
# Final cost : 0.007493987483466918
# Compute control for a deterministic system
# Cost in iteration 0: 2.305792408274015
# Final cost : 2.2200029735238553
# Compute control for a deterministic system
# Cost in iteration 0: 2.2200029735238553
# Final cost : 0.016118979819029846
# Compute control for a deterministic system
# Cost in iteration 0: 0.016118979819029846
# Final cost : 0.00942642683140523
# Compute control for a deterministic system
# Cost in iteration 0: 0.00942642683140523
# Final cost : 0.009037541304171635
# Compute control for a deterministic system
# Cost in iteration 0: 0.009037541304171635
# Final cost : 0.00874516055721698
# Compute control for a deterministic system
# Cost in iteration 0: 0.00874516055721698
# Final cost : 0.008586695294788812
# Compute control for a deterministic system
# Cost in iteration 0: 2.372647091625591
# Final cost : 2.3188689539264247
# Compute control for a deterministic system
# Cost in iteration 0: 2.3188689539264247
# Final cost : 0.019467575904185318
# Compute control for a deterministic system
# Cost in iteration 0: 0.019467575904185318
# Final cost : 0.010821581644934929
# Compute control for a deterministic system
# Cost in iteration 0: 0.010821581644934929
# Final cost : 0.010333413505361055
# Compute control for a deterministic system
# Cost in iteration 0: 0.010333413505361055
# Final cost : 0.009990620126224498
# Compute control for a deterministic system
# Cost in iteration 0: 0.009990620126224498
# Final cost : 0.009766177547316332
# Compute control for a deterministic system
# Cost in iteration 0: 2.42155751651184
# Final cost : 2.39146811211392
# Compute control for a deterministic system
# Cost in iteration 0: 2.39146811211392
# Final cost : 0.023489502393691342
# Compute control for a deterministic system
# Cost in iteration 0: 0.023489502393691342
# Final cost : 0.012401430811596927
# Compute control for a deterministic system
# Cost in iteration 0: 0.012401430811596927
# Final cost : 0.011714306407114506
# Compute control for a deterministic system
# Cost in iteration 0: 0.011714306407114506
# Final cost : 0.011266898315475718
# Compute control for a deterministic system
# Cost in iteration 0: 0.011266898315475718
# Final cost : 0.01100094409684996
# Compute control for a deterministic system
# Cost in iteration 0: 2.451599121719409
# Final cost : 2.4374915620263504
# Compute control for a deterministic system
# Cost in iteration 0: 2.4374915620263504
# Final cost : 0.028417269433967652
# Compute control for a deterministic system
# Cost in iteration 0: 0.028417269433967652
# Final cost : 0.014151573406781758
# Compute control for a deterministic system
# Cost in iteration 0: 0.014151573406781758
# Final cost : 0.013260087635230107
# Compute control for a deterministic system
# Cost in iteration 0: 0.013260087635230107
# Final cost : 0.012696585723239664
# Compute control for a deterministic system
# Cost in iteration 0: 0.012696585723239664
# Final cost : 0.012322937546398096
# Compute control for a deterministic system
# Cost in iteration 0: 2.461569201463839
# Final cost : 2.4564364025463696
# Compute control for a deterministic system
# Cost in iteration 0: 2.4564364025463696
# Final cost : 0.03500576980055055
# Compute control for a deterministic system
# Cost in iteration 0: 0.03500576980055055
# Final cost : 0.01606521253008649
# Compute control for a deterministic system
# Cost in iteration 0: 0.01606521253008649
# Final cost : 0.014934938430991066
# Compute control for a deterministic system
# Cost in iteration 0: 0.014934938430991066
# Final cost : 0.014169319920309372
# Compute control for a deterministic system
# Cost in iteration 0: 0.014169319920309372
# Final cost : 0.01372247927744168
# Compute control for a deterministic system
# Cost in iteration 0: 2.4505729626579504
# Final cost : 2.4475454330590996
# Compute control for a deterministic system
# Cost in iteration 0: 2.4475454330590996
# Final cost : 0.052668930767325935
# Compute control for a deterministic system
# Cost in iteration 0: 0.052668930767325935
# Final cost : 0.020510396945449913
# Compute control for a deterministic system
# Cost in iteration 0: 0.020510396945449913
# Final cost : 0.018780867264352154
# Compute control for a deterministic system
# Cost in iteration 0: 0.018780867264352154
# Final cost : 0.01768742673646154
# Compute control for a deterministic system
# Cost in iteration 0: 0.01768742673646154
# Final cost : 0.016994034959132633
# Compute control for a deterministic system
# Cost in iteration 0: 2.4201336805228677
# Final cost : 2.4129852906890643
# Compute control for a deterministic system
# Cost in iteration 0: 2.4129852906890643
# Final cost : 0.04042402661811175
# Compute control for a deterministic system
# Cost in iteration 0: 0.04042402661811175
# Final cost : 0.017945377679069965
# Compute control for a deterministic system
# Cost in iteration 0: 0.017945377679069965
# Final cost : 0.016502649362952274
# Compute control for a deterministic system
# Cost in iteration 0: 0.016502649362952274
# Final cost : 0.015712507133480377
# Compute control for a deterministic system
# Cost in iteration 0: 0.015712507133480377
# Final cost : 0.015216047795729598
# Compute control for a deterministic system
# Cost in iteration 0: 2.3729221862963197
# Final cost : 2.355620487384914
# Compute control for a deterministic system
# Cost in iteration 0: 2.355620487384914
# Final cost : 0.03253334006505573
# Compute control for a deterministic system
# Cost in iteration 0: 0.03253334006505573
# Final cost : 0.015683428975902976
# Compute control for a deterministic system
# Cost in iteration 0: 0.015683428975902976
# Final cost : 0.014611963847184018
# Compute control for a deterministic system
# Cost in iteration 0: 0.014611963847184018
# Final cost : 0.013959362714452422
# Compute control for a deterministic system
# Cost in iteration 0: 0.013959362714452422
# Final cost : 0.013557666287536883
# Compute control for a deterministic system
# Cost in iteration 0: 2.3121437845323864
# Final cost : 2.2786351420748674
# Compute control for a deterministic system
# Cost in iteration 0: 2.2786351420748674
# Final cost : 0.026506682045277032
# Compute control for a deterministic system
# Cost in iteration 0: 0.026506682045277032
# Final cost : 0.013649735011585146
# Compute control for a deterministic system
# Cost in iteration 0: 0.013649735011585146
# Final cost : 0.012782351442371663
# Compute control for a deterministic system
# Cost in iteration 0: 0.012782351442371663
# Final cost : 0.012323020023986851
# Compute control for a deterministic system
# Cost in iteration 0: 0.012323020023986851
# Final cost : 0.012033843278511754
# Compute control for a deterministic system
# Cost in iteration 0: 2.2399804106186556
# Final cost : 2.1839720005415852
# Compute control for a deterministic system
# Cost in iteration 0: 2.1839720005415852
# Final cost : 0.021677165529727073
# Compute control for a deterministic system
# Cost in iteration 0: 0.021677165529727073
# Final cost : 0.011815200780274272
# Compute control for a deterministic system
# Cost in iteration 0: 0.011815200780274272
# Final cost : 0.011187946573097393
# Compute control for a deterministic system
# Cost in iteration 0: 0.011187946573097393
# Final cost : 0.010826784153863863
# Compute control for a deterministic system
# Cost in iteration 0: 0.010826784153863863
# Final cost : 0.01060791345072643
# Compute control for a deterministic system
# Cost in iteration 0: 2.157101776921312
# Final cost : 2.071902556403303
# Compute control for a deterministic system
# Cost in iteration 0: 2.071902556403303
# Final cost : 0.017715553643749986
# Compute control for a deterministic system
# Cost in iteration 0: 0.017715553643749986
# Final cost : 0.010174182154511165
# Compute control for a deterministic system
# Cost in iteration 0: 0.010174182154511165
# Final cost : 0.00969349566663633
# Compute control for a deterministic system
# Cost in iteration 0: 0.00969349566663633
# Final cost : 0.009432573598114316
# Compute control for a deterministic system
# Cost in iteration 0: 0.009432573598114316
# Final cost : 0.009277917300527103
# Compute control for a deterministic system
# Cost in iteration 0: 2.063073075638606
# Final cost : 1.9415530037207605
# Compute control for a deterministic system
# Cost in iteration 0: 1.9415530037207605
# Final cost : 0.01443686715266874
# Compute control for a deterministic system
# Cost in iteration 0: 0.01443686715266874
# Final cost : 0.008745305679661107
# Compute control for a deterministic system
# Cost in iteration 0: 0.008745305679661107
# Final cost : 0.00838044351947781
# Compute control for a deterministic system
# Cost in iteration 0: 0.00838044351947781
# Final cost : 0.008164455321928209
# Compute control for a deterministic system
# Cost in iteration 0: 0.008164455321928209
# Final cost : 0.008046604622309297
# Compute control for a deterministic system
# Cost in iteration 0: 1.9544762463657586
# Final cost : 1.7881620863254948
# Compute control for a deterministic system
# Cost in iteration 0: 1.7881620863254948
# Final cost : 0.011658152863898142
# Compute control for a deterministic system
# Cost in iteration 0: 0.011658152863898142
# Final cost : 0.0073988813353118126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0073988813353118126
# Final cost : 0.007127904371286842
# Compute control for a deterministic system
# Cost in iteration 0: 0.007127904371286842
# Final cost : 0.006967864480203194
# Compute control for a deterministic system
# Cost in iteration 0: 0.006967864480203194
# Final cost : 0.006879646290483155
# Compute control for a deterministic system
# Cost in iteration 0: 1.8348249270895876
# Final cost : 1.617243788335152
# Compute control for a deterministic system
# Cost in iteration 0: 1.617243788335152
# Final cost : 0.009394802141189977
# Compute control for a deterministic system
# Cost in iteration 0: 0.009394802141189977
# Final cost : 0.006238332695523989
# Compute control for a deterministic system
# Cost in iteration 0: 0.006238332695523989
# Final cost : 0.006019798256068275
# Compute control for a deterministic system
# Cost in iteration 0: 0.006019798256068275
# Final cost : 0.005895070568689945
# Compute control for a deterministic system
# Cost in iteration 0: 0.005895070568689945
# Final cost : 0.005838230401219736
# Compute control for a deterministic system
# Cost in iteration 0: 1.7009888106987157
# Final cost : 1.4257243732719609
# Compute control for a deterministic system
# Cost in iteration 0: 1.4257243732719609
# Final cost : 0.007501768074508339
# Compute control for a deterministic system
# Cost in iteration 0: 0.007501768074508339
# Final cost : 0.005174046442963313
# Compute control for a deterministic system
# Cost in iteration 0: 0.005174046442963313
# Final cost : 0.005014194436161832
# Compute control for a deterministic system
# Cost in iteration 0: 0.005014194436161832
# Final cost : 0.004926584856156537
# Compute control for a deterministic system
# Cost in iteration 0: 0.004926584856156537
# Final cost : 0.004886953394609353
# Compute control for a deterministic system
# Cost in iteration 0: 1.5523315023457602
# Final cost : 1.2153917634584392
# Compute control for a deterministic system
# Cost in iteration 0: 1.2153917634584392
# Final cost : 0.005915710030663762
# Compute control for a deterministic system
# Cost in iteration 0: 0.005915710030663762
# Final cost : 0.004233603979428243
# Compute control for a deterministic system
# Cost in iteration 0: 0.004233603979428243
# Final cost : 0.0041145719509574005
# Compute control for a deterministic system
# Cost in iteration 0: 0.0041145719509574005
# Final cost : 0.004049905316712398
# Compute control for a deterministic system
# Cost in iteration 0: 0.004049905316712398
# Final cost : 0.004023353276123299
# Compute control for a deterministic system
# Cost in iteration 0: 1.3887496072900851
# Final cost : 0.9909924837573917
# Compute control for a deterministic system
# Cost in iteration 0: 0.9909924837573917
# Final cost : 0.004587274728028412
# Compute control for a deterministic system
# Cost in iteration 0: 0.004587274728028412
# Final cost : 0.0033994891624358594
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033994891624358594
# Final cost : 0.00331172050663949
# Compute control for a deterministic system
# Cost in iteration 0: 0.00331172050663949
# Final cost : 0.003265400497466444
# Compute control for a deterministic system
# Cost in iteration 0: 0.003265400497466444
# Final cost : 0.00324859414105807
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109798060388104
# Final cost : 0.7615143550984148
# Compute control for a deterministic system
# Cost in iteration 0: 0.7615143550984148
# Final cost : 0.0034783217694928583
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034783217694928583
# Final cost : 0.002663953683414622
# Compute control for a deterministic system
# Cost in iteration 0: 0.002663953683414622
# Final cost : 0.002601436056114224
# Compute control for a deterministic system
# Cost in iteration 0: 0.002601436056114224
# Final cost : 0.0025693745847821096
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025693745847821096
# Final cost : 0.002559791939305438
# Compute control for a deterministic system
# Cost in iteration 0: 1.0210527966865819
# Final cost : 0.540821040823462
# Compute control for a deterministic system
# Cost in iteration 0: 0.540821040823462
# Final cost : 0.002559523210239392
# Compute control for a deterministic system
# Cost in iteration 0: 0.002559523210239392
# Final cost : 0.0020277979603392044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020277979603392044
# Final cost : 0.0019834274239255018
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019834274239255018
# Final cost : 0.001961164193469573
# Compute control for a deterministic system
# Cost in iteration 0: 0.001961164193469573
# Final cost : 0.0019554847009535204
# Compute control for a deterministic system
# Cost in iteration 0: 0.8185573881107101
# Final cost : 0.342283145871482
# Compute control for a deterministic system
# Cost in iteration 0: 0.342283145871482
# Final cost : 0.0017937771344124136
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017937771344124136
# Final cost : 0.0014724375010614903
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014724375010614903
# Final cost : 0.0014414122324296706
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014414122324296706
# Final cost : 0.0014271308125196648
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014271308125196648
# Final cost : 0.0014239724039137116
# Compute control for a deterministic system
# Cost in iteration 0: 0.618810943238059
# Final cost : 0.19031147316709274
# Compute control for a deterministic system
# Cost in iteration 0: 0.19031147316709274
# Final cost : 0.0011959169113679828
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011959169113679828
# Final cost : 0.0010182157562315022
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010182157562315022
# Final cost : 0.000997451917534289
# Compute control for a deterministic system
# Cost in iteration 0: 0.000997451917534289
# Final cost : 0.0009884118748347914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009884118748347914
# Final cost : 0.00098666609720478
# Compute control for a deterministic system
# Cost in iteration 0: 0.4272494763271503
# Final cost : 0.0880635103634807
# Compute control for a deterministic system
# Cost in iteration 0: 0.0880635103634807
# Final cost : 0.0007335887303313532
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007335887303313532
# Final cost : 0.0006473601492281077
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006473601492281077
# Final cost : 0.0006360634553305491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006360634553305491
# Final cost : 0.0006311980458869815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006311980458869815
# Final cost : 0.0006303459057818517
# Compute control for a deterministic system
# Cost in iteration 0: 0.25632778459833644
# Final cost : 0.031710775373040546
# Compute control for a deterministic system
# Cost in iteration 0: 0.031710775373040546
# Final cost : 0.0003944179479638969
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003944179479638969
# Final cost : 0.0003618849846029287
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003618849846029287
# Final cost : 0.0003566354955002043
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003566354955002043
# Final cost : 0.0003545181607992668
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003545181607992668
# Final cost : 0.00035417763476132196
# Compute control for a deterministic system
# Cost in iteration 0: 0.11994841961844178
# Final cost : 0.007986435281702087
# Compute control for a deterministic system
# Cost in iteration 0: 0.007986435281702087
# Final cost : 0.00016741060571146525
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016741060571146525
# Final cost : 0.00015999240633256476
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015999240633256476
# Final cost : 0.00015835096355128038
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015835096355128038
# Final cost : 0.00015757092964543444
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015757092964543444
# Final cost : 0.00015745895959666073
# Compute control for a deterministic system
# Cost in iteration 0: 0.031234744306238318
# Final cost : 0.001103593715554337
# Compute control for a deterministic system
# Cost in iteration 0: 0.001103593715554337
# Final cost : 4.0450855179123534e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.0450855179123534e-05
# Final cost : 3.979001176448884e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.979001176448884e-05
# Final cost : 3.965548549080138e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.965548549080138e-05
# Final cost : 3.9590246543806806e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.9590246543806806e-05
# Final cost : 3.9580497628480744e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8375344496151055e-06
# Final cost : 4.620387843490966e-08
# Compute control for a deterministic system
# Cost in iteration 0: 4.620387843490966e-08
# Final cost : 2.2975564379416433e-09
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.030143796382120818
# Final cost : 0.0001579475743640288
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001579475743640288
# Final cost : 0.00015586416710220677
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015586416710220677
# Final cost : 0.00015529748147857894
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015529748147857894
# Final cost : 0.00015501584723392678
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015501584723392678
# Final cost : 0.00015497165743852732
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.031455530756923505
# Final cost : 0.0003548681101036373
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003548681101036373
# Final cost : 0.0003501040420878232
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003501040420878232
# Final cost : 0.0003487860179603457
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003487860179603457
# Final cost : 0.000348135299772119
# Compute control for a deterministic system
# Cost in iteration 0: 0.000348135299772119
# Final cost : 0.00034800105450308045
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.028668559721285854
# Final cost : 0.0006367926905838233
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006367926905838233
# Final cost : 0.0006279929265202987
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006279929265202987
# Final cost : 0.0006256016475814805
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006256016475814805
# Final cost : 0.000624438097502641
# Compute control for a deterministic system
# Cost in iteration 0: 0.000624438097502641
# Final cost : 0.0006241659506517909
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.03471214316292018
# Final cost : 0.0009910502910926325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009910502910926325
# Final cost : 0.0009770306176102644
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009770306176102644
# Final cost : 0.0009735067936165426
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009735067936165426
# Final cost : 0.0009717564130115963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009717564130115963
# Final cost : 0.0009712617050690102
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.048742302145724774
# Final cost : 0.0014242917007148115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014242917007148115
# Final cost : 0.0014023272619006042
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014023272619006042
# Final cost : 0.0013970862869177973
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013970862869177973
# Final cost : 0.0013946606750645664
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013946606750645664
# Final cost : 0.001393888101423178
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.04025289152490873
# Final cost : 0.0019303210551333075
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019303210551333075
# Final cost : 0.0019024000976211963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019024000976211963
# Final cost : 0.0018963648873276187
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018963648873276187
# Final cost : 0.0018929416077137326
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018929416077137326
# Final cost : 0.0018916104799796608
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.056158330641963135
# Final cost : 0.0025174316333434013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025174316333434013
# Final cost : 0.002478346605726922
# Compute control for a deterministic system
# Cost in iteration 0: 0.002478346605726922
# Final cost : 0.0024701702677589993
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024701702677589993
# Final cost : 0.0024659338297907314
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024659338297907314
# Final cost : 0.002463968940396677
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.0279462981960374
# Final cost : 0.0031691908807520435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031691908807520435
# Final cost : 0.0031272341095922953
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031272341095922953
# Final cost : 0.003118986362426362
# Compute control for a deterministic system
# Cost in iteration 0: 0.003118986362426362
# Final cost : 0.0031134078080914183
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031134078080914183
# Final cost : 0.0031104724476474963
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.018352513248964104
# Final cost : 0.003899905048627702
# Compute control for a deterministic system
# Cost in iteration 0: 0.003899905048627702
# Final cost : 0.0038508860730026126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038508860730026126
# Final cost : 0.003840869997938342
# Compute control for a deterministic system
# Cost in iteration 0: 0.003840869997938342
# Final cost : 0.0038344619553769715
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038344619553769715
# Final cost : 0.003830693429694825
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.01968486677316119
# Final cost : 0.0047056233386711605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0047056233386711605
# Final cost : 0.004648980783238533
# Compute control for a deterministic system
# Cost in iteration 0: 0.004648980783238533
# Final cost : 0.004638325800935996
# Compute control for a deterministic system
# Cost in iteration 0: 0.004638325800935996
# Final cost : 0.004629750137344673
# Compute control for a deterministic system
# Cost in iteration 0: 0.004629750137344673
# Final cost : 0.004624137436993759
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.017387954448509723
# Final cost : 0.005607895772963098
# Compute control for a deterministic system
# Cost in iteration 0: 0.005607895772963098
# Final cost : 0.005541625695941559
# Compute control for a deterministic system
# Cost in iteration 0: 0.005541625695941559
# Final cost : 0.005527256565775206
# Compute control for a deterministic system
# Cost in iteration 0: 0.005527256565775206
# Final cost : 0.005517140318858266
# Compute control for a deterministic system
# Cost in iteration 0: 0.005517140318858266
# Final cost : 0.005510052823361953
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.04871216912554698
# Final cost : 0.006564761105788402
# Compute control for a deterministic system
# Cost in iteration 0: 0.006564761105788402
# Final cost : 0.006485876202412511
# Compute control for a deterministic system
# Cost in iteration 0: 0.006485876202412511
# Final cost : 0.006470755835927179
# Compute control for a deterministic system
# Cost in iteration 0: 0.006470755835927179
# Final cost : 0.006459661354246818
# Compute control for a deterministic system
# Cost in iteration 0: 0.006459661354246818
# Final cost : 0.0064502530298278
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.02188581224542696
# Final cost : 0.007582781728647225
# Compute control for a deterministic system
# Cost in iteration 0: 0.007582781728647225
# Final cost : 0.007504812964950441
# Compute control for a deterministic system
# Cost in iteration 0: 0.007504812964950441
# Final cost : 0.007487520559330792
# Compute control for a deterministic system
# Cost in iteration 0: 0.007487520559330792
# Final cost : 0.007473585436558918
# Compute control for a deterministic system
# Cost in iteration 0: 0.007473585436558918
# Final cost : 0.007462161562799026
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.045145923770388056
# Final cost : 0.008684693665983012
# Compute control for a deterministic system
# Cost in iteration 0: 0.008684693665983012
# Final cost : 0.00859515934098286
# Compute control for a deterministic system
# Cost in iteration 0: 0.00859515934098286
# Final cost : 0.008576413979770395
# Compute control for a deterministic system
# Cost in iteration 0: 0.008576413979770395
# Final cost : 0.008560117677019929
# Compute control for a deterministic system
# Cost in iteration 0: 0.008560117677019929
# Final cost : 0.008544852131917564
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.022770128658915735
# Final cost : 0.00984405970077723
# Compute control for a deterministic system
# Cost in iteration 0: 0.00984405970077723
# Final cost : 0.009754160214528407
# Compute control for a deterministic system
# Cost in iteration 0: 0.009754160214528407
# Final cost : 0.009734850363859803
# Compute control for a deterministic system
# Cost in iteration 0: 0.009734850363859803
# Final cost : 0.00971577234247158
# Compute control for a deterministic system
# Cost in iteration 0: 0.00971577234247158
# Final cost : 0.009697748851806538
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.06620868988906639
# Final cost : 0.011092909845851746
# Compute control for a deterministic system
# Cost in iteration 0: 0.011092909845851746
# Final cost : 0.010982299269845598
# Compute control for a deterministic system
# Cost in iteration 0: 0.010982299269845598
# Final cost : 0.010960485604348692
# Compute control for a deterministic system
# Cost in iteration 0: 0.010960485604348692
# Final cost : 0.010938551169820433
# Compute control for a deterministic system
# Cost in iteration 0: 0.010938551169820433
# Final cost : 0.010917132763829645
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.10642795794878002
# Final cost : 0.012420355705852312
# Compute control for a deterministic system
# Cost in iteration 0: 0.012420355705852312
# Final cost : 0.012271241962461646
# Compute control for a deterministic system
# Cost in iteration 0: 0.012271241962461646
# Final cost : 0.01224539055554469
# Compute control for a deterministic system
# Cost in iteration 0: 0.01224539055554469
# Final cost : 0.012222085301869162
# Compute control for a deterministic system
# Cost in iteration 0: 0.012222085301869162
# Final cost : 0.012197648798939283
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.03478220154702227
# Final cost : 0.013747792455074011
# Compute control for a deterministic system
# Cost in iteration 0: 0.013747792455074011
# Final cost : 0.01364320646832982
# Compute control for a deterministic system
# Cost in iteration 0: 0.01364320646832982
# Final cost : 0.013617054758571981
# Compute control for a deterministic system
# Cost in iteration 0: 0.013617054758571981
# Final cost : 0.013590776149419408
# Compute control for a deterministic system
# Cost in iteration 0: 0.013590776149419408
# Final cost : 0.01356413428280195
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.057577862941769184
# Final cost : 0.015144529867237551
# Compute control for a deterministic system
# Cost in iteration 0: 0.015144529867237551
# Final cost : 0.015033702585033412
# Compute control for a deterministic system
# Cost in iteration 0: 0.015033702585033412
# Final cost : 0.015002042701675248
# Compute control for a deterministic system
# Cost in iteration 0: 0.015002042701675248
# Final cost : 0.014977202011674857
# Compute control for a deterministic system
# Cost in iteration 0: 0.014977202011674857
# Final cost : 0.014950474736694728
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.025569065671406287
# Final cost : 0.016584571517507682
# Compute control for a deterministic system
# Cost in iteration 0: 0.016584571517507682
# Final cost : 0.01647571795744896
# Compute control for a deterministic system
# Cost in iteration 0: 0.01647571795744896
# Final cost : 0.016449703612733138
# Compute control for a deterministic system
# Cost in iteration 0: 0.016449703612733138
# Final cost : 0.016420807887488384
# Compute control for a deterministic system
# Cost in iteration 0: 0.016420807887488384
# Final cost : 0.016390217116655323
# Compute control for a deterministic system
# Cost in iteration 0: 0.0877554066699069
# Final cost : 0.013601307159289443
# Compute control for a deterministic system
# Cost in iteration 0: 0.013601307159289443
# Final cost : 0.013519543778322308
# Compute control for a deterministic system
# Cost in iteration 0: 0.013519543778322308
# Final cost : 0.013491052104794034
# Compute control for a deterministic system
# Cost in iteration 0: 0.013491052104794034
# Final cost : 0.013470202154678595
# Compute control for a deterministic system
# Cost in iteration 0: 0.013470202154678595
# Final cost : 0.013460569296536837
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.0835479253997434
# Final cost : 0.01209686615523148
# Compute control for a deterministic system
# Cost in iteration 0: 0.01209686615523148
# Final cost : 0.012028736161059662
# Compute control for a deterministic system
# Cost in iteration 0: 0.012028736161059662
# Final cost : 0.012001228597227444
# Compute control for a deterministic system
# Cost in iteration 0: 0.012001228597227444
# Final cost : 0.011977346940602958
# Compute control for a deterministic system
# Cost in iteration 0: 0.011977346940602958
# Final cost : 0.011961115432284657
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.017474772820157157
# Final cost : 0.010732346879994803
# Compute control for a deterministic system
# Cost in iteration 0: 0.010732346879994803
# Final cost : 0.010657752680461837
# Compute control for a deterministic system
# Cost in iteration 0: 0.010657752680461837
# Final cost : 0.010625720081833141
# Compute control for a deterministic system
# Cost in iteration 0: 0.010625720081833141
# Final cost : 0.010594158752709089
# Compute control for a deterministic system
# Cost in iteration 0: 0.010594158752709089
# Final cost : 0.010565330840948394
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.051413516590582936
# Final cost : 0.009419248892762857
# Compute control for a deterministic system
# Cost in iteration 0: 0.009419248892762857
# Final cost : 0.009351815171376914
# Compute control for a deterministic system
# Cost in iteration 0: 0.009351815171376914
# Final cost : 0.00932051030573905
# Compute control for a deterministic system
# Cost in iteration 0: 0.00932051030573905
# Final cost : 0.009287886574687437
# Compute control for a deterministic system
# Cost in iteration 0: 0.009287886574687437
# Final cost : 0.009255937176486848
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.05996928690796576
# Final cost : 0.008184286962989189
# Compute control for a deterministic system
# Cost in iteration 0: 0.008184286962989189
# Final cost : 0.008122869248790094
# Compute control for a deterministic system
# Cost in iteration 0: 0.008122869248790094
# Final cost : 0.008093926038966899
# Compute control for a deterministic system
# Cost in iteration 0: 0.008093926038966899
# Final cost : 0.008062578417880453
# Compute control for a deterministic system
# Cost in iteration 0: 0.008062578417880453
# Final cost : 0.008033720614004104
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.013876203474067551
# Final cost : 0.007021644881830819
# Compute control for a deterministic system
# Cost in iteration 0: 0.007021644881830819
# Final cost : 0.006960696206952915
# Compute control for a deterministic system
# Cost in iteration 0: 0.006960696206952915
# Final cost : 0.006931871844548752
# Compute control for a deterministic system
# Cost in iteration 0: 0.006931871844548752
# Final cost : 0.00690240064966921
# Compute control for a deterministic system
# Cost in iteration 0: 0.00690240064966921
# Final cost : 0.0068771502697923745
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.06648519721434705
# Final cost : 0.00595052595788547
# Compute control for a deterministic system
# Cost in iteration 0: 0.00595052595788547
# Final cost : 0.005900798731392362
# Compute control for a deterministic system
# Cost in iteration 0: 0.005900798731392362
# Final cost : 0.005878794515983344
# Compute control for a deterministic system
# Cost in iteration 0: 0.005878794515983344
# Final cost : 0.005854702921978152
# Compute control for a deterministic system
# Cost in iteration 0: 0.005854702921978152
# Final cost : 0.005835839080084909
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.02885389216918972
# Final cost : 0.004984645075751502
# Compute control for a deterministic system
# Cost in iteration 0: 0.004984645075751502
# Final cost : 0.004938501394470591
# Compute control for a deterministic system
# Cost in iteration 0: 0.004938501394470591
# Final cost : 0.004919217940176482
# Compute control for a deterministic system
# Cost in iteration 0: 0.004919217940176482
# Final cost : 0.00489882453641425
# Compute control for a deterministic system
# Cost in iteration 0: 0.00489882453641425
# Final cost : 0.004884818782684148
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.0627478007488608
# Final cost : 0.0041021717232547095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0041021717232547095
# Final cost : 0.004063413550996045
# Compute control for a deterministic system
# Cost in iteration 0: 0.004063413550996045
# Final cost : 0.004048072159997932
# Compute control for a deterministic system
# Cost in iteration 0: 0.004048072159997932
# Final cost : 0.004031026340670555
# Compute control for a deterministic system
# Cost in iteration 0: 0.004031026340670555
# Final cost : 0.004022124569209128
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0199133312286868
# Final cost : 0.0033137857068414518
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033137857068414518
# ...
# Final cost : 0.009695625879021001
# Compute control for a deterministic system
# Cost in iteration 0: 0.009695625879021001
# Final cost : 0.009694467109244298
# Compute control for a deterministic system
# Cost in iteration 0: 0.009694467109244298
# Final cost : 0.009692929841955992
# Compute control for a deterministic system
# Cost in iteration 0: 0.009692929841955992
# Final cost : 0.009690845350389665
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.03495379528506238
# Final cost : 0.010917444484276942
# Compute control for a deterministic system
# Cost in iteration 0: 0.010917444484276942
# Final cost : 0.010909580278790996
# Compute control for a deterministic system
# Cost in iteration 0: 0.010909580278790996
# Final cost : 0.010908000417301464
# Compute control for a deterministic system
# Cost in iteration 0: 0.010908000417301464
# Final cost : 0.010907108223746834
# Compute control for a deterministic system
# Cost in iteration 0: 0.010907108223746834
# Final cost : 0.010906723513656283
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.01962568041238629
# Final cost : 0.012197327274197062
# Compute control for a deterministic system
# Cost in iteration 0: 0.012197327274197062
# Final cost : 0.012194792809628192
# Compute control for a deterministic system
# Cost in iteration 0: 0.012194792809628192
# Final cost : 0.012193092057511831
# Compute control for a deterministic system
# Cost in iteration 0: 0.012193092057511831
# Final cost : 0.012190645995705542
# Compute control for a deterministic system
# Cost in iteration 0: 0.012190645995705542
# Final cost : 0.01218706606265175
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.050374403798599324
# Final cost : 0.013561406366336747
# Compute control for a deterministic system
# Cost in iteration 0: 0.013561406366336747
# Final cost : 0.013550727790337195
# Compute control for a deterministic system
# Cost in iteration 0: 0.013550727790337195
# Final cost : 0.013548995599865476
# Compute control for a deterministic system
# Cost in iteration 0: 0.013548995599865476
# Final cost : 0.013547959600859014
# Compute control for a deterministic system
# Cost in iteration 0: 0.013547959600859014
# Final cost : 0.013547645190889473
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.01732545434118778
# Final cost : 0.014949452321330685
# Compute control for a deterministic system
# Cost in iteration 0: 0.014949452321330685
# Final cost : 0.014946387943989272
# Compute control for a deterministic system
# Cost in iteration 0: 0.014946387943989272
# Final cost : 0.014944099116649427
# Compute control for a deterministic system
# Cost in iteration 0: 0.014944099116649427
# Final cost : 0.014940718706745404
# Compute control for a deterministic system
# Cost in iteration 0: 0.014940718706745404
# Final cost : 0.014935399215551499
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.01803463660238583
# Final cost : 0.015073821292636473
# Compute control for a deterministic system
# Cost in iteration 0: 0.015073821292636473
# Final cost : 0.01507132748133997
# Compute control for a deterministic system
# Cost in iteration 0: 0.01507132748133997
# Final cost : 0.015069530527763586
# Compute control for a deterministic system
# Cost in iteration 0: 0.015069530527763586
# Final cost : 0.015067146810728347
# Compute control for a deterministic system
# Cost in iteration 0: 0.015067146810728347
# Final cost : 0.015064333528498662
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.029288716703340704
# Final cost : 0.013461790202507979
# Compute control for a deterministic system
# Cost in iteration 0: 0.013461790202507979
# Final cost : 0.013459700119188218
# Compute control for a deterministic system
# Cost in iteration 0: 0.013459700119188218
# Final cost : 0.013459066001085611
# Compute control for a deterministic system
# Cost in iteration 0: 0.013459066001085611
# Final cost : 0.013458223575164225
# Compute control for a deterministic system
# Cost in iteration 0: 0.013458223575164225
# Final cost : 0.01345751808981713
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.019672344675588427
# Final cost : 0.011962077488196035
# Compute control for a deterministic system
# Cost in iteration 0: 0.011962077488196035
# Final cost : 0.011959830995942684
# Compute control for a deterministic system
# Cost in iteration 0: 0.011959830995942684
# Final cost : 0.01195890894464256
# Compute control for a deterministic system
# Cost in iteration 0: 0.01195890894464256
# Final cost : 0.011957866351575856
# Compute control for a deterministic system
# Cost in iteration 0: 0.011957866351575856
# Final cost : 0.01195675242933959
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.010752346454418728
# Final cost : 0.010559255996899199
# Compute control for a deterministic system
# Cost in iteration 0: 0.010559255996899199
# Final cost : 0.010557808291279556
# Compute control for a deterministic system
# Cost in iteration 0: 0.010557808291279556
# Final cost : 0.01055695150080998
# Compute control for a deterministic system
# Cost in iteration 0: 0.01055695150080998
# Final cost : 0.010555796538282095
# Compute control for a deterministic system
# Cost in iteration 0: 0.010555796538282095
# Final cost : 0.010554539454480264
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.011425491936868823
# Final cost : 0.009248209315418303
# Compute control for a deterministic system
# Cost in iteration 0: 0.009248209315418303
# Final cost : 0.00924680792821741
# Compute control for a deterministic system
# Cost in iteration 0: 0.00924680792821741
# Final cost : 0.009246131513996598
# Compute control for a deterministic system
# Cost in iteration 0: 0.009246131513996598
# Final cost : 0.009245270199672842
# Compute control for a deterministic system
# Cost in iteration 0: 0.009245270199672842
# Final cost : 0.009244395876036943
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.008150684367213768
# Final cost : 0.008026852163831555
# Compute control for a deterministic system
# Cost in iteration 0: 0.008026852163831555
# Final cost : 0.00802582642723958
# Compute control for a deterministic system
# Cost in iteration 0: 0.00802582642723958
# Final cost : 0.008025309145106924
# Compute control for a deterministic system
# Cost in iteration 0: 0.008025309145106924
# Final cost : 0.00802470573005487
# Compute control for a deterministic system
# Cost in iteration 0: 0.00802470573005487
# Final cost : 0.008024121642982142
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.010746050832576287
# Final cost : 0.0068724055623493605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0068724055623493605
# Final cost : 0.006871218463520044
# Compute control for a deterministic system
# Cost in iteration 0: 0.006871218463520044
# Final cost : 0.006870843799682568
# Compute control for a deterministic system
# Cost in iteration 0: 0.006870843799682568
# Final cost : 0.006870421880092026
# Compute control for a deterministic system
# Cost in iteration 0: 0.006870421880092026
# Final cost : 0.0068700505222690994
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.006570830308193543
# Final cost : 0.0058328533411730315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058328533411730315
# Final cost : 0.0058321104900436365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058321104900436365
# Final cost : 0.00583184518409643
# Compute control for a deterministic system
# Cost in iteration 0: 0.00583184518409643
# Final cost : 0.00583156866640787
# Compute control for a deterministic system
# Cost in iteration 0: 0.00583156866640787
# Final cost : 0.005831344663564413
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.009346272856904658
# Final cost : 0.004883171620831088
# Compute control for a deterministic system
# Cost in iteration 0: 0.004883171620831088
# Final cost : 0.004882536999240109
# Compute control for a deterministic system
# Cost in iteration 0: 0.004882536999240109
# Final cost : 0.004882330624714101
# Compute control for a deterministic system
# Cost in iteration 0: 0.004882330624714101
# Final cost : 0.004882143411339009
# Compute control for a deterministic system
# Cost in iteration 0: 0.004882143411339009
# Final cost : 0.004882006185741403
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.013331869025476418
# Final cost : 0.004022083714030191
# Compute control for a deterministic system
# Cost in iteration 0: 0.004022083714030191
# Final cost : 0.004021469269004233
# Compute control for a deterministic system
# Cost in iteration 0: 0.004021469269004233
# Final cost : 0.004021294883368527
# Compute control for a deterministic system
# Cost in iteration 0: 0.004021294883368527
# Final cost : 0.004021148760675238
# Compute control for a deterministic system
# Cost in iteration 0: 0.004021148760675238
# Final cost : 0.004021055531914106
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056736747069766015
# Final cost : 0.0032478887805787128
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032478887805787128
# Final cost : 0.0032474259669045603
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032474259669045603
# Final cost : 0.0032473176935338727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032473176935338727
# Final cost : 0.003247238743872201
# Compute control for a deterministic system
# Cost in iteration 0: 0.003247238743872201
# Final cost : 0.0032471944055730423
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.004919735604550849
# Final cost : 0.002559799733282518
# Compute control for a deterministic system
# Cost in iteration 0: 0.002559799733282518
# Final cost : 0.002559165239481609
# Compute control for a deterministic system
# Cost in iteration 0: 0.002559165239481609
# Final cost : 0.002559081193151856
# Compute control for a deterministic system
# Cost in iteration 0: 0.002559081193151856
# Final cost : 0.002559032809915962
# Compute control for a deterministic system
# Cost in iteration 0: 0.002559032809915962
# Final cost : 0.002559010653988276
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.005231474883194782
# Final cost : 0.001955464382380535
# Compute control for a deterministic system
# Cost in iteration 0: 0.001955464382380535
# Final cost : 0.0019551923446960856
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019551923446960856
# Final cost : 0.001955143892692812
# Compute control for a deterministic system
# Cost in iteration 0: 0.001955143892692812
# Final cost : 0.001955120512363406
# Compute control for a deterministic system
# Cost in iteration 0: 0.001955120512363406
# Final cost : 0.001955112096327789
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036286320912293857
# Final cost : 0.0014242878852279625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014242878852279625
# Final cost : 0.0014238772114641453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014238772114641453
# Final cost : 0.0014238375218106445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014238375218106445
# Final cost : 0.001423822336901875
# Compute control for a deterministic system
# Cost in iteration 0: 0.001423822336901875
# Final cost : 0.0014238183211753282
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024153204633918157
# Final cost : 0.0009869237373950613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009869237373950613
# Final cost : 0.0009866411164715337
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009866411164715337
# Final cost : 0.0009866157179026782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009866157179026782
# Final cost : 0.0009866075938427964
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009866075938427964
# Final cost : 0.0009866061256018081
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016187916908859247
# Final cost : 0.0006305326252420843
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006305326252420843
# Final cost : 0.0006303467892210643
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006303467892210643
# Final cost : 0.0006303310718289577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006303310718289577
# Final cost : 0.0006303264995944867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006303264995944867
# Final cost : 0.0006303259111325051
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006938495871483712
# Final cost : 0.0003542370578186274
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003542370578186274
# Final cost : 0.00035418174302551553
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035418174302551553
# Final cost : 0.0003541749090055331
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003541749090055331
# Final cost : 0.0003541729890811209
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003541729890811209
# Final cost : 0.00035417281300313685
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016957560025839926
# Final cost : 0.00015749133849158746
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015749133849158746
# Final cost : 0.00015746166745969089
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015746166745969089
# Final cost : 0.00015745866904876306
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015745866904876306
# Final cost : 0.00015745799277336648
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015745799277336648
# Final cost : 0.00015745795490987178
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 4.1826504161898565e-05
# Final cost : 3.958893158763344e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.958893158763344e-05
# Final cost : 3.958137646867617e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.958137646867617e-05
# Final cost : 3.958062763319762e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.958062763319762e-05
# Final cost : 3.9580449261909904e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.9580449261909904e-05
# Final cost : 3.958043967352472e-05
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
