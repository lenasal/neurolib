# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.25426803074613735
y_init = 0.2588983729056897
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,98], wc.inh[0,98]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.4075060938514842 0.4461657054316379
# minima =  [ 1575  3339  5086  6832  8578 10324 12069 13815 15561 17306 19052 20798
#  22543 24289 26035 27780 29526 31272 33017 34763 36509 38254 40000 41746
#  43491 45237 46983 48728 50474 52220 53965 55711 57457 59202]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("c_s3_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("c_s3_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)


        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)


        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.04663828213652848
# Final cost : 0.0004723893575295823
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004723893575295823
# Final cost : 8.450324666296694e-07
# Compute control for a deterministic system
# Cost in iteration 0: 8.450324666296694e-07
# Final cost : 7.325937369328487e-07
# Compute control for a deterministic system
# Cost in iteration 0: 7.325937369328487e-07
# Final cost : 7.134425842762048e-07
# Compute control for a deterministic system
# Cost in iteration 0: 7.134425842762048e-07
# Final cost : 6.872264358272883e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.872264358272883e-07
# Final cost : 6.632670205437688e-07
# Compute control for a deterministic system
# Cost in iteration 0: 0.18078165598509696
# Final cost : 0.08739059226130372
# Compute control for a deterministic system
# Cost in iteration 0: 0.08739059226130372
# Final cost : 1.0184498145454971e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0184498145454971e-05
# Final cost : 9.732749267004212e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.732749267004212e-06
# Final cost : 9.590304921540355e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.590304921540355e-06
# Final cost : 9.215255379050915e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.215255379050915e-06
# Final cost : 8.321883997945517e-06
# Compute control for a deterministic system
# Cost in iteration 0: 0.40333464892077187
# Final cost : 0.29954944322995347
# Compute control for a deterministic system
# Cost in iteration 0: 0.29954944322995347
# Final cost : 0.00030150472167927045
# Compute control for a deterministic system
# Cost in iteration 0: 0.00030150472167927045
# Final cost : 0.00021878834275728922
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021878834275728922
# Final cost : 0.00015253651099012523
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015253651099012523
# Final cost : 0.00010883687207904784
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010883687207904784
# Final cost : 6.15564646956693e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.7036507514154297
# Final cost : 0.22265304500697067
# Compute control for a deterministic system
# Cost in iteration 0: 0.22265304500697067
# Final cost : 0.04155510418229126
# Compute control for a deterministic system
# Cost in iteration 0: 0.04155510418229126
# Final cost : 0.019004548155117484
# Compute control for a deterministic system
# Cost in iteration 0: 0.019004548155117484
# Final cost : 0.013113140788169457
# Compute control for a deterministic system
# Cost in iteration 0: 0.013113140788169457
# Final cost : 0.005741398165890601
# Compute control for a deterministic system
# Cost in iteration 0: 0.005741398165890601
# Final cost : 0.0012403827636694854
# Compute control for a deterministic system
# Cost in iteration 0: 1.0621596075856976
# Final cost : 0.11865658365603868
# Compute control for a deterministic system
# Cost in iteration 0: 0.11865658365603868
# Final cost : 0.053355868963228435
# Compute control for a deterministic system
# Cost in iteration 0: 0.053355868963228435
# Final cost : 0.031545587454134306
# Compute control for a deterministic system
# Cost in iteration 0: 0.031545587454134306
# Final cost : 0.015425139760823386
# Compute control for a deterministic system
# Cost in iteration 0: 0.015425139760823386
# Final cost : 0.0023655286067634012
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023655286067634012
# Final cost : 0.0014888042285041733
# Compute control for a deterministic system
# Cost in iteration 0: 1.484130914920475
# Final cost : 0.10150225062079891
# Compute control for a deterministic system
# Cost in iteration 0: 0.10150225062079891
# Final cost : 0.06732717731009386
# Compute control for a deterministic system
# Cost in iteration 0: 0.06732717731009386
# Final cost : 0.03798641287717643
# Compute control for a deterministic system
# Cost in iteration 0: 0.03798641287717643
# Final cost : 0.028997083616789907
# Compute control for a deterministic system
# Cost in iteration 0: 0.028997083616789907
# Final cost : 0.00565968340165118
# Compute control for a deterministic system
# Cost in iteration 0: 0.00565968340165118
# Final cost : 0.0004853219359108006
# Compute control for a deterministic system
# Cost in iteration 0: 1.9387830164598812
# Final cost : 0.08733100261250872
# Compute control for a deterministic system
# Cost in iteration 0: 0.08733100261250872
# Final cost : 0.06262272217441149
# Compute control for a deterministic system
# Cost in iteration 0: 0.06262272217441149
# Final cost : 0.04577643663982264
# Compute control for a deterministic system
# Cost in iteration 0: 0.04577643663982264
# Final cost : 0.030641637244951506
# Compute control for a deterministic system
# Cost in iteration 0: 0.030641637244951506
# Final cost : 0.01952558468199076
# Compute control for a deterministic system
# Cost in iteration 0: 0.01952558468199076
# Final cost : 0.00758937884420454
# Compute control for a deterministic system
# Cost in iteration 0: 2.4348983844357095
# Final cost : 0.1341610729899838
# Compute control for a deterministic system
# Cost in iteration 0: 0.1341610729899838
# Final cost : 0.07156870995321163
# Compute control for a deterministic system
# Cost in iteration 0: 0.07156870995321163
# Final cost : 0.04583362334507114
# Compute control for a deterministic system
# Cost in iteration 0: 0.04583362334507114
# Final cost : 0.0363449844446149
# Compute control for a deterministic system
# Cost in iteration 0: 0.0363449844446149
# Final cost : 0.02173959400444944
# Compute control for a deterministic system
# Cost in iteration 0: 0.02173959400444944
# Final cost : 0.004848175433765907
# Compute control for a deterministic system
# Cost in iteration 0: 2.9495601363967943
# Final cost : 0.2690505204814458
# Compute control for a deterministic system
# Cost in iteration 0: 0.2690505204814458
# Final cost : 0.06845974744946835
# Compute control for a deterministic system
# Cost in iteration 0: 0.06845974744946835
# Final cost : 0.036044717658252956
# Compute control for a deterministic system
# Cost in iteration 0: 0.036044717658252956
# Final cost : 0.024108782245795518
# Compute control for a deterministic system
# Cost in iteration 0: 0.024108782245795518
# Final cost : 0.012622573616110383
# Compute control for a deterministic system
# Cost in iteration 0: 0.012622573616110383
# Final cost : 0.004636974426943499
# Compute control for a deterministic system
# Cost in iteration 0: 3.4585500407553575
# Final cost : 0.47812653717240683
# Compute control for a deterministic system
# Cost in iteration 0: 0.47812653717240683
# Final cost : 0.0697960373363522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0697960373363522
# Final cost : 0.033773488200542705
# Compute control for a deterministic system
# Cost in iteration 0: 0.033773488200542705
# Final cost : 0.02130176107557373
# Compute control for a deterministic system
# Cost in iteration 0: 0.02130176107557373
# Final cost : 0.010663198009437371
# Compute control for a deterministic system
# Cost in iteration 0: 0.010663198009437371
# Final cost : 0.003890807084846871
# Compute control for a deterministic system
# Cost in iteration 0: 3.97421764950854
# Final cost : 0.7609140131949628
# Compute control for a deterministic system
# Cost in iteration 0: 0.7609140131949628
# Final cost : 0.06870465265780314
# Compute control for a deterministic system
# Cost in iteration 0: 0.06870465265780314
# Final cost : 0.021151929404927956
# Compute control for a deterministic system
# Cost in iteration 0: 0.021151929404927956
# Final cost : 0.008530023389997967
# Compute control for a deterministic system
# Cost in iteration 0: 0.008530023389997967
# Final cost : 0.0018039374097454635
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018039374097454635
# Final cost : 0.0005068218639844974
# Compute control for a deterministic system
# Cost in iteration 0: 4.4740246566093465
# Final cost : 1.1021949500288266
# Compute control for a deterministic system
# Cost in iteration 0: 1.1021949500288266
# Final cost : 0.06474338988406704
# Compute control for a deterministic system
# Cost in iteration 0: 0.06474338988406704
# Final cost : 0.0286491066345959
# Compute control for a deterministic system
# Cost in iteration 0: 0.0286491066345959
# Final cost : 0.013049312607515547
# Compute control for a deterministic system
# Cost in iteration 0: 0.013049312607515547
# Final cost : 0.0028233413819041707
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028233413819041707
# Final cost : 0.0009224895143761219
# Compute control for a deterministic system
# Cost in iteration 0: 4.937348463061636
# Final cost : 1.4814215486549345
# Compute control for a deterministic system
# Cost in iteration 0: 1.4814215486549345
# Final cost : 0.05978175602797157
# Compute control for a deterministic system
# Cost in iteration 0: 0.05978175602797157
# Final cost : 0.02099260240547309
# Compute control for a deterministic system
# Cost in iteration 0: 0.02099260240547309
# Final cost : 0.010318234034697376
# Compute control for a deterministic system
# Cost in iteration 0: 0.010318234034697376
# Final cost : 0.004462488556364073
# Compute control for a deterministic system
# Cost in iteration 0: 0.004462488556364073
# Final cost : 0.0014374744555289444
# Compute control for a deterministic system
# Cost in iteration 0: 5.375907084496923
# Final cost : 1.9055203787044879
# Compute control for a deterministic system
# Cost in iteration 0: 1.9055203787044879
# Final cost : 0.05223266351899335
# Compute control for a deterministic system
# Cost in iteration 0: 0.05223266351899335
# Final cost : 0.02424552729146459
# Compute control for a deterministic system
# Cost in iteration 0: 0.02424552729146459
# Final cost : 0.011587634918682643
# Compute control for a deterministic system
# Cost in iteration 0: 0.011587634918682643
# Final cost : 0.006192917278032504
# Compute control for a deterministic system
# Cost in iteration 0: 0.006192917278032504
# Final cost : 0.0025916248316368855
# Compute control for a deterministic system
# Cost in iteration 0: 5.768576362457562
# Final cost : 2.3557809334448567
# Compute control for a deterministic system
# Cost in iteration 0: 2.3557809334448567
# Final cost : 0.04356139222828504
# Compute control for a deterministic system
# Cost in iteration 0: 0.04356139222828504
# Final cost : 0.025295757618031055
# Compute control for a deterministic system
# Cost in iteration 0: 0.025295757618031055
# Final cost : 0.014911089246373419
# Compute control for a deterministic system
# Cost in iteration 0: 0.014911089246373419
# Final cost : 0.007086319544272295
# Compute control for a deterministic system
# Cost in iteration 0: 0.007086319544272295
# Final cost : 0.003602340468785963
# Compute control for a deterministic system
# Cost in iteration 0: 6.098332770826194
# Final cost : 2.8116728269515234
# Compute control for a deterministic system
# Cost in iteration 0: 2.8116728269515234
# Final cost : 0.0349466310818238
# Compute control for a deterministic system
# Cost in iteration 0: 0.0349466310818238
# Final cost : 0.019787754306604455
# Compute control for a deterministic system
# Cost in iteration 0: 0.019787754306604455
# Final cost : 0.013378463087958804
# Compute control for a deterministic system
# Cost in iteration 0: 0.013378463087958804
# Final cost : 0.0075286875253695274
# Compute control for a deterministic system
# Cost in iteration 0: 0.0075286875253695274
# Final cost : 0.003943438104774636
# Compute control for a deterministic system
# Cost in iteration 0: 6.37071080032635
# Final cost : 3.2853014178061515
# Compute control for a deterministic system
# Cost in iteration 0: 3.2853014178061515
# Final cost : 0.02205403166254594
# Compute control for a deterministic system
# Cost in iteration 0: 0.02205403166254594
# Final cost : 0.009736968666522216
# Compute control for a deterministic system
# Cost in iteration 0: 0.009736968666522216
# Final cost : 0.0048065153658069255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0048065153658069255
# Final cost : 0.0016881799958853186
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016881799958853186
# Final cost : 0.0006611906637916333
# Compute control for a deterministic system
# Cost in iteration 0: 6.567910145333144
# Final cost : 3.7574537183170884
# Compute control for a deterministic system
# Cost in iteration 0: 3.7574537183170884
# Final cost : 0.014673330287957252
# Compute control for a deterministic system
# Cost in iteration 0: 0.014673330287957252
# Final cost : 0.007701111385195588
# Compute control for a deterministic system
# Cost in iteration 0: 0.007701111385195588
# Final cost : 0.0031287968422138465
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031287968422138465
# Final cost : 0.0016216190154876562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016216190154876562
# Final cost : 0.0007490668235250447
# Compute control for a deterministic system
# Cost in iteration 0: 6.680520010621298
# Final cost : 4.211986734871422
# Compute control for a deterministic system
# Cost in iteration 0: 4.211986734871422
# Final cost : 0.011405873573569522
# Compute control for a deterministic system
# Cost in iteration 0: 0.011405873573569522
# Final cost : 0.006775629013462959
# Compute control for a deterministic system
# Cost in iteration 0: 0.006775629013462959
# Final cost : 0.0038987262245409556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038987262245409556
# Final cost : 0.002150015770981053
# Compute control for a deterministic system
# Cost in iteration 0: 0.002150015770981053
# Final cost : 0.0009744793392660041
# Compute control for a deterministic system
# Cost in iteration 0: 6.709330239499748
# Final cost : 5.059987014687522
# Compute control for a deterministic system
# Cost in iteration 0: 5.059987014687522
# Final cost : 0.009892680800096351
# Compute control for a deterministic system
# Cost in iteration 0: 0.009892680800096351
# Final cost : 0.006365646136946902
# Compute control for a deterministic system
# Cost in iteration 0: 0.006365646136946902
# Final cost : 0.004469908414430128
# Compute control for a deterministic system
# Cost in iteration 0: 0.004469908414430128
# Final cost : 0.003076546094779514
# Compute control for a deterministic system
# Cost in iteration 0: 0.003076546094779514
# Final cost : 0.0016947642224554875
# Compute control for a deterministic system
# Cost in iteration 0: 6.65243759608336
# Final cost : 4.469039924764758
# Compute control for a deterministic system
# Cost in iteration 0: 4.469039924764758
# Final cost : 0.015365197071341066
# Compute control for a deterministic system
# Cost in iteration 0: 0.015365197071341066
# Final cost : 0.005400634406951165
# Compute control for a deterministic system
# Cost in iteration 0: 0.005400634406951165
# Final cost : 0.0030191243924036658
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030191243924036658
# Final cost : 0.0015664288805205143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015664288805205143
# Final cost : 0.0007922195856883931
# Compute control for a deterministic system
# Cost in iteration 0: 6.509954798968891
# Final cost : 3.888302191146617
# Compute control for a deterministic system
# Cost in iteration 0: 3.888302191146617
# Final cost : 0.012411732215152363
# Compute control for a deterministic system
# Cost in iteration 0: 0.012411732215152363
# Final cost : 0.006227917048176722
# Compute control for a deterministic system
# Cost in iteration 0: 0.006227917048176722
# Final cost : 0.0033060328201131627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033060328201131627
# Final cost : 0.0017122663636023265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017122663636023265
# Final cost : 0.000790170489321638
# Compute control for a deterministic system
# Cost in iteration 0: 6.287814638507996
# Final cost : 3.363465570394324
# Compute control for a deterministic system
# Cost in iteration 0: 3.363465570394324
# Final cost : 0.017395140438791742
# Compute control for a deterministic system
# Cost in iteration 0: 0.017395140438791742
# Final cost : 0.007237764985885403
# Compute control for a deterministic system
# Cost in iteration 0: 0.007237764985885403
# Final cost : 0.00400874968333841
# Compute control for a deterministic system
# Cost in iteration 0: 0.00400874968333841
# Final cost : 0.0018115604715484126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018115604715484126
# Final cost : 0.0006559710412544617
# Compute control for a deterministic system
# Cost in iteration 0: 6.0013098152436
# Final cost : 2.8551422939584046
# Compute control for a deterministic system
# Cost in iteration 0: 2.8551422939584046
# Final cost : 0.02908148437229629
# Compute control for a deterministic system
# Cost in iteration 0: 0.02908148437229629
# Final cost : 0.016190523530242185
# Compute control for a deterministic system
# Cost in iteration 0: 0.016190523530242185
# Final cost : 0.0106676944489019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0106676944489019
# Final cost : 0.0064136148425369705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0064136148425369705
# Final cost : 0.0034149275516426963
# Compute control for a deterministic system
# Cost in iteration 0: 5.646537810702565
# Final cost : 2.349806852053255
# Compute control for a deterministic system
# Cost in iteration 0: 2.349806852053255
# Final cost : 0.03739351545211824
# Compute control for a deterministic system
# Cost in iteration 0: 0.03739351545211824
# Final cost : 0.020673942078028015
# Compute control for a deterministic system
# Cost in iteration 0: 0.020673942078028015
# Final cost : 0.012523043111760215
# Compute control for a deterministic system
# Cost in iteration 0: 0.012523043111760215
# Final cost : 0.006206357346792984
# Compute control for a deterministic system
# Cost in iteration 0: 0.006206357346792984
# Final cost : 0.003240848872551994
# Compute control for a deterministic system
# Cost in iteration 0: 5.240104643202825
# Final cost : 1.870109992262296
# Compute control for a deterministic system
# Cost in iteration 0: 1.870109992262296
# Final cost : 0.046130269324605504
# Compute control for a deterministic system
# Cost in iteration 0: 0.046130269324605504
# Final cost : 0.02510783836640384
# Compute control for a deterministic system
# Cost in iteration 0: 0.02510783836640384
# Final cost : 0.013386194975035452
# Compute control for a deterministic system
# Cost in iteration 0: 0.013386194975035452
# Final cost : 0.0066726766326008265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0066726766326008265
# Final cost : 0.002938683365468917
# Compute control for a deterministic system
# Cost in iteration 0: 4.803603711304705
# Final cost : 1.4364192514032448
# Compute control for a deterministic system
# Cost in iteration 0: 1.4364192514032448
# Final cost : 0.05360329368228261
# Compute control for a deterministic system
# Cost in iteration 0: 0.05360329368228261
# Final cost : 0.02304223401667066
# Compute control for a deterministic system
# Cost in iteration 0: 0.02304223401667066
# Final cost : 0.011858553658217674
# Compute control for a deterministic system
# Cost in iteration 0: 0.011858553658217674
# Final cost : 0.005118271334419086
# Compute control for a deterministic system
# Cost in iteration 0: 0.005118271334419086
# Final cost : 0.0017277219267263413
# Compute control for a deterministic system
# Cost in iteration 0: 4.327262928732099
# Final cost : 1.0389108116426498
# Compute control for a deterministic system
# Cost in iteration 0: 1.0389108116426498
# Final cost : 0.05918670959196457
# Compute control for a deterministic system
# Cost in iteration 0: 0.05918670959196457
# Final cost : 0.025400065029167657
# Compute control for a deterministic system
# Cost in iteration 0: 0.025400065029167657
# Final cost : 0.012874759621755813
# Compute control for a deterministic system
# Cost in iteration 0: 0.012874759621755813
# Final cost : 0.0033523818781527135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033523818781527135
# Final cost : 0.0009656864964690606
# Compute control for a deterministic system
# Cost in iteration 0: 3.831237770329163
# Final cost : 0.6984722678840543
# Compute control for a deterministic system
# Cost in iteration 0: 0.6984722678840543
# Final cost : 0.06355039306452472
# Compute control for a deterministic system
# Cost in iteration 0: 0.06355039306452472
# Final cost : 0.017562886341577717
# Compute control for a deterministic system
# Cost in iteration 0: 0.017562886341577717
# Final cost : 0.00765634646094649
# Compute control for a deterministic system
# Cost in iteration 0: 0.00765634646094649
# Final cost : 0.0019958941674316504
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019958941674316504
# Final cost : 0.000649635029328108
# Compute control for a deterministic system
# Cost in iteration 0: 3.3373228009268208
# Final cost : 0.4305178489080431
# Compute control for a deterministic system
# Cost in iteration 0: 0.4305178489080431
# Final cost : 0.06523087434955674
# Compute control for a deterministic system
# Cost in iteration 0: 0.06523087434955674
# Final cost : 0.03404349063034955
# Compute control for a deterministic system
# Cost in iteration 0: 0.03404349063034955
# Final cost : 0.02341229697186942
# Compute control for a deterministic system
# Cost in iteration 0: 0.02341229697186942
# Final cost : 0.012605271572022528
# Compute control for a deterministic system
# Cost in iteration 0: 0.012605271572022528
# Final cost : 0.005123969437951266
# Compute control for a deterministic system
# Cost in iteration 0: 2.83243215263194
# Final cost : 0.2314527194994403
# Compute control for a deterministic system
# Cost in iteration 0: 0.2314527194994403
# Final cost : 0.06455730179266071
# Compute control for a deterministic system
# Cost in iteration 0: 0.06455730179266071
# Final cost : 0.034445784746486484
# Compute control for a deterministic system
# Cost in iteration 0: 0.034445784746486484
# Final cost : 0.0195971513728947
# Compute control for a deterministic system
# Cost in iteration 0: 0.0195971513728947
# Final cost : 0.012463743210352292
# Compute control for a deterministic system
# Cost in iteration 0: 0.012463743210352292
# Final cost : 0.005465642149018865
# Compute control for a deterministic system
# Cost in iteration 0: 2.3379306842630636
# Final cost : 0.11542853539645433
# Compute control for a deterministic system
# Cost in iteration 0: 0.11542853539645433
# Final cost : 0.06774243582504723
# Compute control for a deterministic system
# Cost in iteration 0: 0.06774243582504723
# Final cost : 0.043472386885125516
# Compute control for a deterministic system
# Cost in iteration 0: 0.043472386885125516
# Final cost : 0.034340253018756955
# Compute control for a deterministic system
# Cost in iteration 0: 0.034340253018756955
# Final cost : 0.019401909417930144
# Compute control for a deterministic system
# Cost in iteration 0: 0.019401909417930144
# Final cost : 0.004666346916235156
# Compute control for a deterministic system
# Cost in iteration 0: 1.8743250554387667
# Final cost : 0.08627623733182502
# Compute control for a deterministic system
# Cost in iteration 0: 0.08627623733182502
# Final cost : 0.05762009611250781
# Compute control for a deterministic system
# Cost in iteration 0: 0.05762009611250781
# Final cost : 0.041115328114084554
# Compute control for a deterministic system
# Cost in iteration 0: 0.041115328114084554
# Final cost : 0.027280601867652125
# Compute control for a deterministic system
# Cost in iteration 0: 0.027280601867652125
# Final cost : 0.01633453118826821
# Compute control for a deterministic system
# Cost in iteration 0: 0.01633453118826821
# Final cost : 0.006946494889884027
# Compute control for a deterministic system
# Cost in iteration 0: 1.4301537194849934
# Final cost : 0.09712727603226719
# Compute control for a deterministic system
# Cost in iteration 0: 0.09712727603226719
# Final cost : 0.06465176453148062
# Compute control for a deterministic system
# Cost in iteration 0: 0.06465176453148062
# Final cost : 0.038180162662773555
# Compute control for a deterministic system
# Cost in iteration 0: 0.038180162662773555
# Final cost : 0.029468924981260844
# Compute control for a deterministic system
# Cost in iteration 0: 0.029468924981260844
# Final cost : 0.014457814262412928
# Compute control for a deterministic system
# Cost in iteration 0: 0.014457814262412928
# Final cost : 0.0040786628216861595
# Compute control for a deterministic system
# Cost in iteration 0: 1.0357060437643792
# Final cost : 0.11635071913921495
# Compute control for a deterministic system
# Cost in iteration 0: 0.11635071913921495
# Final cost : 0.051885499182975366
# Compute control for a deterministic system
# Cost in iteration 0: 0.051885499182975366
# Final cost : 0.028602765835192865
# Compute control for a deterministic system
# Cost in iteration 0: 0.028602765835192865
# Final cost : 0.01464681154654979
# Compute control for a deterministic system
# Cost in iteration 0: 0.01464681154654979
# Final cost : 0.00647093344390337
# Compute control for a deterministic system
# Cost in iteration 0: 0.00647093344390337
# Final cost : 0.0006145651988727368
# Compute control for a deterministic system
# Cost in iteration 0: 0.6832875923499309
# Final cost : 0.22194966815208575
# Compute control for a deterministic system
# Cost in iteration 0: 0.22194966815208575
# Final cost : 0.04801781290609877
# Compute control for a deterministic system
# Cost in iteration 0: 0.04801781290609877
# Final cost : 0.03373447784210747
# Compute control for a deterministic system
# Cost in iteration 0: 0.03373447784210747
# Final cost : 0.018016971779647693
# Compute control for a deterministic system
# Cost in iteration 0: 0.018016971779647693
# Final cost : 0.006140282859453771
# Compute control for a deterministic system
# Cost in iteration 0: 0.006140282859453771
# Final cost : 0.0007296512636329255
# Compute control for a deterministic system
# Cost in iteration 0: 0.39350654824230447
# Final cost : 0.2821805106467073
# Compute control for a deterministic system
# Cost in iteration 0: 0.2821805106467073
# Final cost : 0.00026862138163119786
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026862138163119786
# Final cost : 0.00020103270424356943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020103270424356943
# Final cost : 0.00014792463823489282
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014792463823489282
# Final cost : 0.00010234982003160011
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010234982003160011
# Final cost : 5.865988272141995e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.18109401834263353
# Final cost : 0.07982410156639148
# Compute control for a deterministic system
# Cost in iteration 0: 0.07982410156639148
# Final cost : 1.0280313379475805e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0280313379475805e-05
# Final cost : 9.690052079908373e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.690052079908373e-06
# Final cost : 9.547097240106684e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.547097240106684e-06
# Final cost : 9.168385308680157e-06
# Compute control for a deterministic system
# Cost in iteration 0: 9.168385308680157e-06
# Final cost : 8.306754123035477e-06
# Compute control for a deterministic system
# Cost in iteration 0: 0.045628926885835724
# Final cost : 0.0004014275004592112
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004014275004592112
# Final cost : 8.15737484360004e-07
# Compute control for a deterministic system
# Cost in iteration 0: 8.15737484360004e-07
# Final cost : 7.17649865934079e-07
# Compute control for a deterministic system
# Cost in iteration 0: 7.17649865934079e-07
# Final cost : 7.034128937959394e-07
# Compute control for a deterministic system
# Cost in iteration 0: 7.034128937959394e-07
# Final cost : 6.936950540288418e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.936950540288418e-07
# Final cost : 6.712496596913445e-07
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Final cost : 4.921458936124902e-08
# Compute control for a deterministic system
# Cost in iteration 0: 4.921458936124902e-08
# Final cost : 5.392084542770376e-11
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.043181242088711345
# Final cost : 1.8480140610122028e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.8480140610122028e-06
# Final cost : 1.7051651516647969e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.7051651516647969e-06
# Final cost : 1.683644585314707e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.683644585314707e-06
# Final cost : 1.6697039254051626e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.6697039254051626e-06
# Final cost : 1.4981204232384173e-06
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.045831024384661266
# Final cost : 3.2274004017778395e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.2274004017778395e-06
# Final cost : 3.1070167621054028e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.1070167621054028e-06
# Final cost : 3.088477373404814e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.088477373404814e-06
# Final cost : 3.0764961266998252e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.0764961266998252e-06
# Final cost : 3.055073387404126e-06
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.04835227735094826
# Final cost : 6.720797422755325e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.720797422755325e-06
# Final cost : 6.609555232250022e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.609555232250022e-06
# Final cost : 6.581822160830357e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.581822160830357e-06
# Final cost : 6.521755339302612e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.521755339302612e-06
# Final cost : 6.343947244801043e-06
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.036348487740976126
# Final cost : 1.1992833166207934e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.1992833166207934e-05
# Final cost : 1.1751167416246253e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.1751167416246253e-05
# Final cost : 1.1685754375425827e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.1685754375425827e-05
# Final cost : 1.1456584292114636e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.1456584292114636e-05
# Final cost : 1.0908070193598322e-05
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.04712005681921114
# Final cost : 1.6302726191321815e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6302726191321815e-05
# Final cost : 1.611312598745192e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.611312598745192e-05
# Final cost : 1.5962742996225316e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.5962742996225316e-05
# Final cost : 1.546109704587317e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.546109704587317e-05
# Final cost : 1.4988958123590992e-05
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.0580737263223128
# Final cost : 2.0606788840429873e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.0606788840429873e-05
# Final cost : 2.0365260459706685e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.0365260459706685e-05
# Final cost : 2.0164648385471936e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.0164648385471936e-05
# Final cost : 1.9866183170245874e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.9866183170245874e-05
# Final cost : 1.9281908476136384e-05
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.05834397042627585
# Final cost : 3.0078280579070803e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.0078280579070803e-05
# Final cost : 2.9633261121212562e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9633261121212562e-05
# Final cost : 2.9192182466133322e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9192182466133322e-05
# Final cost : 2.8551144901127428e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.8551144901127428e-05
# Final cost : 2.6673593701213832e-05
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.03927447796072978
# Final cost : 4.0032509087528364e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.0032509087528364e-05
# Final cost : 3.8994667049470306e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.8994667049470306e-05
# Final cost : 3.846924437539981e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.846924437539981e-05
# Final cost : 3.7539649231675555e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.7539649231675555e-05
# Final cost : 3.306052497810966e-05
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.04723905462885752
# Final cost : 4.96558361930344e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.96558361930344e-05
# Final cost : 4.872511678180401e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.872511678180401e-05
# Final cost : 4.8057635832637136e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.8057635832637136e-05
# Final cost : 4.6767548414373384e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.6767548414373384e-05
# Final cost : 4.391736762904044e-05
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.054358414830205704
# Final cost : 6.820794223401773e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.820794223401773e-05
# Final cost : 6.600267004679779e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.600267004679779e-05
# Final cost : 6.489003667648711e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.489003667648711e-05
# Final cost : 6.22742413355477e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.22742413355477e-05
# Final cost : 5.721332063255574e-05
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.042976170757947484
# Final cost : 7.544146227251256e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.544146227251256e-05
# Final cost : 7.326938325335789e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.326938325335789e-05
# Final cost : 7.138544183819524e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.138544183819524e-05
# Final cost : 6.940088789010213e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.940088789010213e-05
# Final cost : 6.244417173887972e-05
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.05995740540532424
# Final cost : 8.469246713600363e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.469246713600363e-05
# Final cost : 8.141875283904128e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.141875283904128e-05
# Final cost : 7.883915763465337e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.883915763465337e-05
# Final cost : 7.588411167761793e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.588411167761793e-05
# Final cost : 7.189476865356536e-05
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.03899660505173521
# Final cost : 9.458223637034921e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.458223637034921e-05
# Final cost : 9.14129530233091e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.14129530233091e-05
# Final cost : 8.955382427971072e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.955382427971072e-05
# Final cost : 8.72649965600975e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.72649965600975e-05
# Final cost : 8.219029365828462e-05
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.05441970277591283
# Final cost : 0.00011122355100295534
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011122355100295534
# Final cost : 0.00010733915934285682
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010733915934285682
# Final cost : 0.00010527278373460199
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010527278373460199
# Final cost : 0.0001024151655766491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001024151655766491
# Final cost : 9.743431107777262e-05
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.06494553729475379
# Final cost : 0.00013151157009824702
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013151157009824702
# Final cost : 0.0001277634344652236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001277634344652236
# Final cost : 0.0001250272939999113
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001250272939999113
# Final cost : 0.0001204608272041578
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001204608272041578
# Final cost : 0.00011360874427410512
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.03499410385944979
# Final cost : 0.00014893315618727778
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014893315618727778
# Final cost : 0.0001460985426632269
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001460985426632269
# Final cost : 0.00014373079793787084
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014373079793787084
# Final cost : 0.0001394187564426661
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001394187564426661
# Final cost : 0.00013301169374191975
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.04183897944908634
# Final cost : 0.0001730865856058427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001730865856058427
# Final cost : 0.00017027813768512174
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017027813768512174
# Final cost : 0.00016783540031927553
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016783540031927553
# Final cost : 0.0001631093978075463
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001631093978075463
# Final cost : 0.00015577354919003067
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.06463897192372027
# Final cost : 0.00020702909720297683
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020702909720297683
# Final cost : 0.00020164347593220187
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020164347593220187
# Final cost : 0.0001978137655723688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001978137655723688
# Final cost : 0.00018933598159364402
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018933598159364402
# Final cost : 0.00017990396634470941
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.04613627034339095
# Final cost : 0.00022783069527427903
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022783069527427903
# Final cost : 0.0002237462235870389
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002237462235870389
# Final cost : 0.0002205747508952915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002205747508952915
# Final cost : 0.00021413669100023094
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021413669100023094
# Final cost : 0.00020505859735551823
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.042077805954688824
# Final cost : 0.00025223554372726857
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025223554372726857
# Final cost : 0.00024817542909199886
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024817542909199886
# Final cost : 0.00024485920789235215
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024485920789235215
# Final cost : 0.0002379860801076881
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002379860801076881
# Final cost : 0.00022956714493058936
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.05306186555717433
# Final cost : 0.00028363960242831164
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028363960242831164
# Final cost : 0.0002777472925620315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002777472925620315
# Final cost : 0.0002742214341835924
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002742214341835924
# Final cost : 0.0002666097032385937
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002666097032385937
# Final cost : 0.0002576682649545042
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.05281192000545529
# Final cost : 0.0003103064903139947
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003103064903139947
# Final cost : 0.0003042905809471797
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003042905809471797
# Final cost : 0.0003002986710063794
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003002986710063794
# Final cost : 0.00029271585907752443
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029271585907752443
# Final cost : 0.0002838546866323021
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.0860957292503556
# Final cost : 0.0003780946084462427
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003780946084462427
# Final cost : 0.00036246557813417147
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036246557813417147
# Final cost : 0.00035059417109505536
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035059417109505536
# Final cost : 0.0003332226764699783
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003332226764699783
# Final cost : 0.0003186210686167845
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.053838602793045524
# Final cost : 0.0003828412197847298
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003828412197847298
# Final cost : 0.0003745178633255306
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003745178633255306
# Final cost : 0.0003703271261884825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003703271261884825
# Final cost : 0.00036236864447782415
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036236864447782415
# Final cost : 0.0003507075427468085
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.08070817728356733
# Final cost : 0.00044732950904249034
# Compute control for a deterministic system
# Cost in iteration 0: 0.00044732950904249034
# Final cost : 0.00043052163278488
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043052163278488
# Final cost : 0.00041846352215849396
# Compute control for a deterministic system
# Cost in iteration 0: 0.00041846352215849396
# Final cost : 0.000404011244798348
# Compute control for a deterministic system
# Cost in iteration 0: 0.000404011244798348
# Final cost : 0.00039116769207235
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.029982180663295145
# Final cost : 0.00046291033044343414
# Compute control for a deterministic system
# Cost in iteration 0: 0.00046291033044343414
# Final cost : 0.0004562625634592248
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004562625634592248
# Final cost : 0.000452430525858039
# Compute control for a deterministic system
# Cost in iteration 0: 0.000452430525858039
# Final cost : 0.0004452195751243481
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004452195751243481
# Final cost : 0.00043213955993857766
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.04842769865150121
# Final cost : 0.0005242745537270462
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005242745537270462
# Final cost : 0.0005171234206594397
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005171234206594397
# Final cost : 0.0005125148547002429
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005125148547002429
# Final cost : 0.000502201874956427
# Compute control for a deterministic system
# Cost in iteration 0: 0.000502201874956427
# Final cost : 0.0004886208201428174
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.09297413793670313
# Final cost : 0.0006170645126774637
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006170645126774637
# Final cost : 0.0005985784480461211
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005985784480461211
# Final cost : 0.0005822982469891804
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005822982469891804
# Final cost : 0.0005568120548885019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005568120548885019
# Final cost : 0.0005308667362697832
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.02367636477523736
# Final cost : 0.0006335928688056506
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006335928688056506
# Final cost : 0.0006262843582439804
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006262843582439804
# Final cost : 0.0006211811635837585
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006211811635837585
# Final cost : 0.0006140694835706343
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006140694835706343
# Final cost : 0.0006009597563518808
# ...
# Final cost : 0.00010665952290100266
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.006270731298171279
# Final cost : 0.00012722681790951342
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012722681790951342
# Final cost : 0.0001266765356397882
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001266765356397882
# Final cost : 0.00012601267354360213
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012601267354360213
# Final cost : 0.00012497479156910277
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012497479156910277
# Converged in iteration 1 with cost 0.00012497479156910277 because of vanishing difference
# Final cost : 0.00012497479156910277
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.01712188461305682
# Final cost : 0.0001387712243484048
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001387712243484048
# Final cost : 0.00013819436509470654
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013819436509470654
# Final cost : 0.00013775638987045387
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013775638987045387
# Final cost : 0.00013686055425854476
# Compute control for a deterministic system
# Cost in iteration 0: 0.00013686055425854476
# Final cost : 0.0001349373692615964
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.002629782775084054
# Final cost : 0.0001621395812823325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001621395812823325
# Final cost : 0.00016098938007165275
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016098938007165275
# Final cost : 0.00016055733131504975
# Compute control for a deterministic system
# Cost in iteration 0: 0.00016055733131504975
# Final cost : 0.00015954605944612304
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015954605944612304
# Final cost : 0.0001565344906584451
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.007733594693968817
# Final cost : 0.0002047140256737536
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002047140256737536
# Final cost : 0.00020060864549362365
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020060864549362365
# Final cost : 0.00019959462164714865
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019959462164714865
# Final cost : 0.0001974815482658886
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001974815482658886
# Final cost : 0.0001901763148945389
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007031996651675291
# Final cost : 0.00021733075927500356
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021733075927500356
# Final cost : 0.00021573943394819276
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021573943394819276
# Final cost : 0.00021430822809726823
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021430822809726823
# Final cost : 0.00021105450197695137
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021105450197695137
# Final cost : 0.00020464294032183968
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006130236764825363
# Final cost : 0.00017817591206207745
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017817591206207745
# Final cost : 0.00017702729502038552
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017702729502038552
# Final cost : 0.00017580794590721325
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017580794590721325
# Final cost : 0.00017363228015382587
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017363228015382587
# Final cost : 0.0001685692992191101
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006470068502075012
# Final cost : 0.00014799451538957586
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014799451538957586
# Final cost : 0.00014706384303137245
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014706384303137245
# Final cost : 0.0001460156565812701
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001460156565812701
# Final cost : 0.00014436227100217845
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014436227100217845
# Final cost : 0.00014131508958762897
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007851692469176848
# Final cost : 0.0001227938880224779
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001227938880224779
# Final cost : 0.00012200738531468745
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012200738531468745
# Final cost : 0.0001211623826882673
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001211623826882673
# Final cost : 0.00011997675624970185
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011997675624970185
# Final cost : 0.00011715272273776508
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010388682126756818
# Final cost : 0.00010630312471992761
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010630312471992761
# Final cost : 0.00010551953724487842
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010551953724487842
# Final cost : 0.00010470263505168012
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010470263505168012
# Final cost : 0.0001034512789991971
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001034512789991971
# Final cost : 0.00010033332758717522
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.00047080250351572394
# Final cost : 9.341640392848688e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.341640392848688e-05
# Final cost : 9.21071740894241e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.21071740894241e-05
# Final cost : 9.144697561210333e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.144697561210333e-05
# Final cost : 8.996220292895728e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.996220292895728e-05
# Final cost : 8.68174459529811e-05
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024679023092891482
# Final cost : 8.784582538365377e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.784582538365377e-05
# Final cost : 8.624316582658152e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.624316582658152e-05
# Final cost : 8.522672299454874e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.522672299454874e-05
# Final cost : 8.316892913737675e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.316892913737675e-05
# Final cost : 7.902092603390471e-05
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.001986715710472427
# Final cost : 6.917067774599568e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.917067774599568e-05
# Final cost : 6.844581113485084e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.844581113485084e-05
# Final cost : 6.784849882450476e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.784849882450476e-05
# Final cost : 6.651107293867254e-05
# Compute control for a deterministic system
# Cost in iteration 0: 6.651107293867254e-05
# Final cost : 6.436127662098651e-05
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011240034345844893
# Final cost : 5.6508072053621365e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.6508072053621365e-05
# Final cost : 5.6046216177362014e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.6046216177362014e-05
# Final cost : 5.560521568646707e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.560521568646707e-05
# Final cost : 5.408202942010894e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.408202942010894e-05
# Final cost : 5.2499692242084564e-05
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010724535298734742
# Final cost : 4.3962824603948116e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.3962824603948116e-05
# Final cost : 4.367451966934177e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.367451966934177e-05
# Final cost : 4.337662870165897e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.337662870165897e-05
# Final cost : 4.2879102545250503e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.2879102545250503e-05
# Final cost : 4.124200123503367e-05
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 3.698005974848952e-05
# Final cost : 3.512436044012183e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.512436044012183e-05
# Final cost : 3.4887001189896854e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4887001189896854e-05
# Final cost : 3.464263705161641e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.464263705161641e-05
# Final cost : 3.4063710144741354e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4063710144741354e-05
# Final cost : 3.30291774256679e-05
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004031297487327861
# Final cost : 2.680723156055962e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.680723156055962e-05
# Final cost : 2.6641142221567285e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.6641142221567285e-05
# Final cost : 2.6402985692583272e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.6402985692583272e-05
# Final cost : 2.6067918224176063e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.6067918224176063e-05
# Final cost : 2.544202957737971e-05
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 3.213440010873797e-05
# Final cost : 2.1702397051162053e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.1702397051162053e-05
# Final cost : 2.1534557433847055e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.1534557433847055e-05
# Final cost : 2.0527466060216927e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.0527466060216927e-05
# Final cost : 2.031740129326385e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.031740129326385e-05
# Final cost : 1.9818884308807735e-05
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 3.771462882583972e-05
# Final cost : 1.6564361954274193e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6564361954274193e-05
# Final cost : 1.644682061311858e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.644682061311858e-05
# Final cost : 1.628120270886289e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.628120270886289e-05
# Final cost : 1.6083764859391468e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.6083764859391468e-05
# Final cost : 1.5577175232908374e-05
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003423957425430342
# Final cost : 1.0812969032339094e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0812969032339094e-05
# Final cost : 1.0626980312137527e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0626980312137527e-05
# Final cost : 1.0555042723470598e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0555042723470598e-05
# Final cost : 1.044466291972829e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.044466291972829e-05
# Final cost : 9.892142037166963e-06
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 3.0402834388117326e-05
# Final cost : 6.209764832981257e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.209764832981257e-06
# Final cost : 6.184635223869216e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.184635223869216e-06
# Final cost : 6.162236080530302e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.162236080530302e-06
# Final cost : 6.101720827887207e-06
# Compute control for a deterministic system
# Cost in iteration 0: 6.101720827887207e-06
# Final cost : 5.927758901540113e-06
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 5.234463852202765e-05
# Final cost : 4.1615795179065e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.1615795179065e-06
# Final cost : 4.1400829491178395e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.1400829491178395e-06
# Final cost : 4.0675113653755135e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.0675113653755135e-06
# Final cost : 4.038169770193224e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.038169770193224e-06
# Final cost : 3.948034981683428e-06
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 8.43736475125673e-05
# Final cost : 2.5148633473051686e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.5148633473051686e-06
# Final cost : 2.5011368151548985e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.5011368151548985e-06
# Final cost : 2.490763184488912e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.490763184488912e-06
# Final cost : 2.460764836945986e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.460764836945986e-06
# Final cost : 2.3979723931984266e-06
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 9.020166374036192e-05
# Final cost : 6.591678312969076e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.591678312969076e-07
# Final cost : 6.569761961939096e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.569761961939096e-07
# Final cost : 6.537674066504738e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.537674066504738e-07
# Final cost : 6.448230321504745e-07
# Compute control for a deterministic system
# Cost in iteration 0: 6.448230321504745e-07
# Final cost : 6.241608969812507e-07
# -----------------------------------------------
# 4 found better solution,  39

# %%
save(results_min)
