# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.25426803074613735
y_init = 0.2588983729056897
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,98], wc.inh[0,98]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.4075060938514842 0.4461657054316379
# minima =  [ 1575  3339  5086  6832  8578 10324 12069 13815 15561 17306 19052 20798
#  22543 24289 26035 27780 29526 31272 33017 34763 36509 38254 40000 41746
#  43491 45237 46983 48728 50474 52220 53965 55711 57457 59202]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("c_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("c_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 results_min = read()
#
# Cell In [6], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("c_s3_l1.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c_s3_l1.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.04663828213652848
# Final cost : 0.0017460271459185973
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017460271459185973
# Cost in iteration 200: 0.0011018757541362957
# Cost in iteration 400: 0.0010533736923639902
# Final cost : 0.0010533736923639902
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010533736923639902
# Cost in iteration 200: 0.0010139998178927308
# Final cost : 0.0010139998178927308
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010139998178927308
# Converged in iteration 138 with cost 0.0009942544189563056 because of vanishing difference
# Final cost : 0.0009942544189563056
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009942544189563056
# Cost in iteration 200: 0.000994224426035669
# Converged in iteration 227 with cost 0.0009942244259653265 because of step counter
# Final cost : 0.0009942244259653265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009942244259653265
# Converged in iteration 1 with cost 0.0009942244259653265 because of step counter
# Final cost : 0.0009942244259653265
# Compute control for a deterministic system
# Cost in iteration 0: 0.18078165598509696
# Final cost : 0.09230981094384912
# Compute control for a deterministic system
# Cost in iteration 0: 0.09230981094384912
# Cost in iteration 200: 0.002247830919598841
# Cost in iteration 400: 0.002199615850004841
# Final cost : 0.002199615850004841
# Compute control for a deterministic system
# Cost in iteration 0: 0.002199615850004841
# Cost in iteration 200: 0.0021598386446194796
# Final cost : 0.0021598386446194796
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021598386446194796
# Cost in iteration 200: 0.0021302419389731377
# Final cost : 0.0021302419389731377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021302419389731377
# Cost in iteration 200: 0.0020848495861536323
# Cost in iteration 400: 0.002039876176183298
# Final cost : 0.002039876176183298
# Compute control for a deterministic system
# Cost in iteration 0: 0.002039876176183298
# Converged in iteration 39 with cost 0.0019873968641019447 because of vanishing difference
# Final cost : 0.0019873968641019447
# Compute control for a deterministic system
# Cost in iteration 0: 0.40333464892077187
# Final cost : 0.31497233592832524
# Compute control for a deterministic system
# Cost in iteration 0: 0.31497233592832524
# Cost in iteration 200: 0.003191556387950397
# Cost in iteration 400: 0.0029934949208944464
# Final cost : 0.0029934949208944464
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029934949208944464
# Cost in iteration 200: 0.0029890214918643467
# Final cost : 0.0029890214918643467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029890214918643467
# Cost in iteration 200: 0.0029885330563034712
# Final cost : 0.0029885330563034712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029885330563034712
# Cost in iteration 200: 0.0029885149231490063
# Cost in iteration 400: 0.002988512888598408
# Final cost : 0.002988512888598408
# Compute control for a deterministic system
# Cost in iteration 0: 0.002988512888598408
# Cost in iteration 200: 0.00298851265242296
# Cost in iteration 400: 0.0029885126180183475
# Cost in iteration 600: 0.0029885126130134703
# Converged in iteration 636 with cost 0.0029885126127653793 because of step counter
# Final cost : 0.0029885126127653793
# Compute control for a deterministic system
# Cost in iteration 0: 0.7036507514154297
# Final cost : 0.5041344774006205
# Compute control for a deterministic system
# Cost in iteration 0: 0.5041344774006205
# Cost in iteration 200: 0.1399560486298279
# Cost in iteration 400: 0.0180147882892659
# Final cost : 0.0180147882892659
# Compute control for a deterministic system
# Cost in iteration 0: 0.0180147882892659
# Cost in iteration 200: 0.004024241115294306
# Final cost : 0.004024241115294306
# Compute control for a deterministic system
# Cost in iteration 0: 0.004024241115294306
# Converged in iteration 78 with cost 0.004002963939011943 because of vanishing difference
# Final cost : 0.004002963939011943
# Compute control for a deterministic system
# Cost in iteration 0: 0.004002963939011943
# Cost in iteration 200: 0.003997338284141426
# Cost in iteration 400: 0.003996450600633993
# Final cost : 0.003996450600633993
# Compute control for a deterministic system
# Cost in iteration 0: 0.003996450600633993
# Cost in iteration 200: 0.003996279874751396
# Cost in iteration 400: 0.003996236085924228
# Cost in iteration 600: 0.003996224167194307
# Cost in iteration 800: 0.003996220846180522
# Cost in iteration 1000: 0.003996219902737586
# Final cost : 0.003996219902737586
# Compute control for a deterministic system
# Cost in iteration 0: 1.0621596075856976
# Final cost : 0.4378134409010615
# Compute control for a deterministic system
# Cost in iteration 0: 0.4378134409010615
# Cost in iteration 200: 0.1986316778816755
# Cost in iteration 400: 0.05524419537329229
# Final cost : 0.05524419537329229
# Compute control for a deterministic system
# Cost in iteration 0: 0.05524419537329229
# Cost in iteration 200: 0.007412529493767414
# Final cost : 0.007412529493767414
# Compute control for a deterministic system
# Cost in iteration 0: 0.007412529493767414
# Converged in iteration 172 with cost 0.004982009740269535 because of vanishing difference
# Final cost : 0.004982009740269535
# Compute control for a deterministic system
# Cost in iteration 0: 0.004982009740269535
# Cost in iteration 200: 0.004979995371268271
# Cost in iteration 400: 0.004979463938461661
# Final cost : 0.004979463938461661
# Compute control for a deterministic system
# Cost in iteration 0: 0.004979463938461661
# Cost in iteration 200: 0.004979283353457222
# Cost in iteration 400: 0.004979209475319464
# Cost in iteration 600: 0.004979179270074168
# Cost in iteration 800: 0.004979166774188414
# Cost in iteration 1000: 0.004979161570162124
# Final cost : 0.004979161570162124
# Compute control for a deterministic system
# Cost in iteration 0: 1.484130914920475
# Final cost : 0.44161530086595013
# Compute control for a deterministic system
# Cost in iteration 0: 0.44161530086595013
# Cost in iteration 200: 0.19629918744757474
# Cost in iteration 400: 0.06998811470608057
# Final cost : 0.06998811470608057
# Compute control for a deterministic system
# Cost in iteration 0: 0.06998811470608057
# Cost in iteration 200: 0.008184677107073799
# Final cost : 0.008184677107073799
# Compute control for a deterministic system
# Cost in iteration 0: 0.008184677107073799
# Cost in iteration 200: 0.0070194754146632125
# Final cost : 0.0070194754146632125
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070194754146632125
# Cost in iteration 200: 0.006851921750090919
# Cost in iteration 400: 0.006804074210321605
# Final cost : 0.006804074210321605
# Compute control for a deterministic system
# Cost in iteration 0: 0.006804074210321605
# Cost in iteration 200: 0.00649453576236139
# Cost in iteration 400: 0.006140616104317322
# Cost in iteration 600: 0.005983754329809226
# Cost in iteration 800: 0.005983629559288783
# Cost in iteration 1000: 0.0059836276032985075
# Final cost : 0.0059836276032985075
# Compute control for a deterministic system
# Cost in iteration 0: 1.9387830164598812
# Final cost : 0.4170858259444127
# Compute control for a deterministic system
# Cost in iteration 0: 0.4170858259444127
# Cost in iteration 200: 0.24119507904032342
# Cost in iteration 400: 0.11339185828458678
# Final cost : 0.11339185828458678
# Compute control for a deterministic system
# Cost in iteration 0: 0.11339185828458678
# Cost in iteration 200: 0.014959576320239861
# Final cost : 0.014959576320239861
# Compute control for a deterministic system
# Cost in iteration 0: 0.014959576320239861
# Cost in iteration 200: 0.008268245400701134
# Final cost : 0.008268245400701134
# Compute control for a deterministic system
# Cost in iteration 0: 0.008268245400701134
# Cost in iteration 200: 0.007852783776324462
# Cost in iteration 400: 0.00779282050442896
# Final cost : 0.00779282050442896
# Compute control for a deterministic system
# Cost in iteration 0: 0.00779282050442896
# Converged in iteration 16 with cost 0.0077805667733063565 because of vanishing difference
# Final cost : 0.0077805667733063565
# Compute control for a deterministic system
# Cost in iteration 0: 2.4348983844357095
# Final cost : 0.4765958828713396
# Compute control for a deterministic system
# Cost in iteration 0: 0.4765958828713396
# Cost in iteration 200: 0.2651650992670278
# Cost in iteration 400: 0.13599953488530026
# Final cost : 0.13599953488530026
# Compute control for a deterministic system
# Cost in iteration 0: 0.13599953488530026
# Cost in iteration 200: 0.013864125788890704
# Final cost : 0.013864125788890704
# Compute control for a deterministic system
# Cost in iteration 0: 0.013864125788890704
# Cost in iteration 200: 0.009653866889037207
# Final cost : 0.009653866889037207
# Compute control for a deterministic system
# Cost in iteration 0: 0.009653866889037207
# Cost in iteration 200: 0.00924466431705688
# Cost in iteration 400: 0.009161065683013043
# Final cost : 0.009161065683013043
# Compute control for a deterministic system
# Cost in iteration 0: 0.009161065683013043
# Cost in iteration 200: 0.009064242552895209
# Cost in iteration 400: 0.008974121967010248
# Cost in iteration 600: 0.008884358521905987
# Cost in iteration 800: 0.00856573797227744
# Converged in iteration 813 with cost 0.008553237424229847 because of vanishing difference
# Final cost : 0.008553237424229847
# Compute control for a deterministic system
# Cost in iteration 0: 2.9495601363967943
# Final cost : 0.6184231662851747
# Compute control for a deterministic system
# Cost in iteration 0: 0.6184231662851747
# Cost in iteration 200: 0.2521077479065762
# Cost in iteration 400: 0.10873754214679862
# Final cost : 0.10873754214679862
# Compute control for a deterministic system
# Cost in iteration 0: 0.10873754214679862
# Cost in iteration 200: 0.026733877201253895
# Final cost : 0.026733877201253895
# Compute control for a deterministic system
# Cost in iteration 0: 0.026733877201253895
# Cost in iteration 200: 0.011401896922452278
# Final cost : 0.011401896922452278
# Compute control for a deterministic system
# Cost in iteration 0: 0.011401896922452278
# Cost in iteration 200: 0.010476600858640465
# Cost in iteration 400: 0.010228191227664002
# Final cost : 0.010228191227664002
# Compute control for a deterministic system
# Cost in iteration 0: 0.010228191227664002
# Cost in iteration 200: 0.010139988468364914
# Cost in iteration 400: 0.01005546602712001
# Cost in iteration 600: 0.009911240607927372
# Cost in iteration 800: 0.00967168256023819
# Cost in iteration 1000: 0.009534735067687145
# Final cost : 0.009534735067687145
# Compute control for a deterministic system
# Cost in iteration 0: 3.4585500407553575
# Final cost : 0.8292459522013012
# Compute control for a deterministic system
# Cost in iteration 0: 0.8292459522013012
# Cost in iteration 200: 0.25627014047483043
# Cost in iteration 400: 0.10326116748866951
# Final cost : 0.10326116748866951
# Compute control for a deterministic system
# Cost in iteration 0: 0.10326116748866951
# Cost in iteration 200: 0.014429436590554616
# Final cost : 0.014429436590554616
# Compute control for a deterministic system
# Cost in iteration 0: 0.014429436590554616
# Cost in iteration 200: 0.012189187849768971
# Final cost : 0.012189187849768971
# Compute control for a deterministic system
# Cost in iteration 0: 0.012189187849768971
# Cost in iteration 200: 0.011611078728642003
# Cost in iteration 400: 0.011354152000939942
# Final cost : 0.011354152000939942
# Compute control for a deterministic system
# Cost in iteration 0: 0.011354152000939942
# Cost in iteration 200: 0.011154505180557718
# Cost in iteration 400: 0.011074971859342446
# Cost in iteration 600: 0.010997303556622684
# Cost in iteration 800: 0.010919651538944914
# Cost in iteration 1000: 0.01084140499769481
# Final cost : 0.01084140499769481
# Compute control for a deterministic system
# Cost in iteration 0: 3.97421764950854
# Final cost : 1.1088762529623803
# Compute control for a deterministic system
# Cost in iteration 0: 1.1088762529623803
# Cost in iteration 200: 0.2521255964726428
# Cost in iteration 400: 0.10453876121475261
# Final cost : 0.10453876121475261
# Compute control for a deterministic system
# Cost in iteration 0: 0.10453876121475261
# Cost in iteration 200: 0.01658215222569659
# Final cost : 0.01658215222569659
# Compute control for a deterministic system
# Cost in iteration 0: 0.01658215222569659
# Cost in iteration 200: 0.01332959778350352
# Final cost : 0.01332959778350352
# Compute control for a deterministic system
# Cost in iteration 0: 0.01332959778350352
# Cost in iteration 200: 0.012653749266998046
# Cost in iteration 400: 0.012288374771231729
# Final cost : 0.012288374771231729
# Compute control for a deterministic system
# Cost in iteration 0: 0.012288374771231729
# Cost in iteration 200: 0.01221288851613685
# Cost in iteration 400: 0.012141683726957625
# Cost in iteration 600: 0.01207081936373306
# Cost in iteration 800: 0.01199935823376935
# Cost in iteration 1000: 0.011926965911071593
# Final cost : 0.011926965911071593
# Compute control for a deterministic system
# Cost in iteration 0: 4.4740246566093465
# Final cost : 1.4419053989713917
# Compute control for a deterministic system
# Cost in iteration 0: 1.4419053989713917
# Cost in iteration 200: 0.23926935310857977
# Cost in iteration 400: 0.11023212128238905
# Final cost : 0.11023212128238905
# Compute control for a deterministic system
# Cost in iteration 0: 0.11023212128238905
# Cost in iteration 200: 0.01648016903188473
# Final cost : 0.01648016903188473
# Compute control for a deterministic system
# Cost in iteration 0: 0.01648016903188473
# Cost in iteration 200: 0.014454679230178477
# Final cost : 0.014454679230178477
# Compute control for a deterministic system
# Cost in iteration 0: 0.014454679230178477
# Cost in iteration 200: 0.01390942097026975
# Cost in iteration 400: 0.01370775485345314
# Final cost : 0.01370775485345314
# Compute control for a deterministic system
# Cost in iteration 0: 0.01370775485345314
# Cost in iteration 200: 0.013518221807172277
# Cost in iteration 400: 0.013350714622651347
# Cost in iteration 600: 0.0132850293726734
# Cost in iteration 800: 0.013219078181439262
# Cost in iteration 1000: 0.013152433750682794
# Final cost : 0.013152433750682794
# Compute control for a deterministic system
# Cost in iteration 0: 4.937348463061636
# Final cost : 1.8077878416177926
# Compute control for a deterministic system
# Cost in iteration 0: 1.8077878416177926
# Cost in iteration 200: 0.226988137083322
# Cost in iteration 400: 0.1023220401977314
# Final cost : 0.1023220401977314
# Compute control for a deterministic system
# Cost in iteration 0: 0.1023220401977314
# Cost in iteration 200: 0.017776855991264624
# Final cost : 0.017776855991264624
# Compute control for a deterministic system
# Cost in iteration 0: 0.017776855991264624
# Cost in iteration 200: 0.015095397630592571
# Final cost : 0.015095397630592571
# Compute control for a deterministic system
# Cost in iteration 0: 0.015095397630592571
# Cost in iteration 200: 0.014886233898313301
# Cost in iteration 400: 0.014777204258431728
# Final cost : 0.014777204258431728
# Compute control for a deterministic system
# Cost in iteration 0: 0.014777204258431728
# Cost in iteration 200: 0.014619686031201118
# Cost in iteration 400: 0.014373007103145272
# Cost in iteration 600: 0.01430463430976306
# Cost in iteration 800: 0.0142384553791154
# Cost in iteration 1000: 0.014172926811046574
# Final cost : 0.014172926811046574
# Compute control for a deterministic system
# Cost in iteration 0: 5.375907084496923
# Final cost : 2.2122153331036265
# Compute control for a deterministic system
# Cost in iteration 0: 2.2122153331036265
# Cost in iteration 200: 0.19684281413036442
# Cost in iteration 400: 0.08187850215076399
# Final cost : 0.08187850215076399
# Compute control for a deterministic system
# Cost in iteration 0: 0.08187850215076399
# Cost in iteration 200: 0.016768575254531622
# Final cost : 0.016768575254531622
# Compute control for a deterministic system
# Cost in iteration 0: 0.016768575254531622
# Cost in iteration 200: 0.016240032325646445
# Final cost : 0.016240032325646445
# Compute control for a deterministic system
# Cost in iteration 0: 0.016240032325646445
# Cost in iteration 200: 0.01598902635963125
# Cost in iteration 400: 0.015869612824573658
# Final cost : 0.015869612824573658
# Compute control for a deterministic system
# Cost in iteration 0: 0.015869612824573658
# Cost in iteration 200: 0.01572598645868607
# Cost in iteration 400: 0.015577518761035292
# Cost in iteration 600: 0.015283320132940944
# Cost in iteration 800: 0.015198680613316733
# Cost in iteration 1000: 0.015131657184830373
# Final cost : 0.015131657184830373
# Compute control for a deterministic system
# Cost in iteration 0: 5.768576362457562
# Final cost : 2.635893511308006
# Compute control for a deterministic system
# Cost in iteration 0: 2.635893511308006
# Cost in iteration 200: 0.16022476785407572
# Cost in iteration 400: 0.054639861145200266
# Final cost : 0.054639861145200266
# Compute control for a deterministic system
# Cost in iteration 0: 0.054639861145200266
# Cost in iteration 200: 0.01831006306801973
# Final cost : 0.01831006306801973
# Compute control for a deterministic system
# Cost in iteration 0: 0.01831006306801973
# Cost in iteration 200: 0.01754475134109654
# Final cost : 0.01754475134109654
# Compute control for a deterministic system
# Cost in iteration 0: 0.01754475134109654
# Cost in iteration 200: 0.017196192260702813
# Cost in iteration 400: 0.016886378237456836
# Final cost : 0.016886378237456836
# Compute control for a deterministic system
# Cost in iteration 0: 0.016886378237456836
# Cost in iteration 200: 0.016749695549000475
# Cost in iteration 400: 0.016611375607633018
# Cost in iteration 600: 0.016467668159013644
# Cost in iteration 800: 0.016315889796120486
# Cost in iteration 1000: 0.01597631931208705
# Final cost : 0.01597631931208705
# Compute control for a deterministic system
# Cost in iteration 0: 6.098332770826194
# Final cost : 3.0582218759687327
# Compute control for a deterministic system
# Cost in iteration 0: 3.0582218759687327
# Cost in iteration 200: 0.12395610210879543
# Cost in iteration 400: 0.040462239502832
# Final cost : 0.040462239502832
# Compute control for a deterministic system
# Cost in iteration 0: 0.040462239502832
# Cost in iteration 200: 0.020840386185322617
# Final cost : 0.020840386185322617
# Compute control for a deterministic system
# Cost in iteration 0: 0.020840386185322617
# Cost in iteration 200: 0.019218211882646635
# Final cost : 0.019218211882646635
# Compute control for a deterministic system
# Cost in iteration 0: 0.019218211882646635
# Cost in iteration 200: 0.018257937354544326
# Cost in iteration 400: 0.01816142476761894
# Final cost : 0.01816142476761894
# Compute control for a deterministic system
# Cost in iteration 0: 0.01816142476761894
# Cost in iteration 200: 0.018036888580415203
# Cost in iteration 400: 0.017908205384640122
# Cost in iteration 600: 0.01777375808878054
# Cost in iteration 800: 0.017632371728910905
# Cost in iteration 1000: 0.017425300718164928
# Final cost : 0.017425300718164928
# Compute control for a deterministic system
# Cost in iteration 0: 6.37071080032635
# Final cost : 3.4888551019032645
# Compute control for a deterministic system
# Cost in iteration 0: 3.4888551019032645
# Cost in iteration 200: 0.08783164026904453
# Cost in iteration 400: 0.030241104574840846
# Final cost : 0.030241104574840846
# Compute control for a deterministic system
# Cost in iteration 0: 0.030241104574840846
# Cost in iteration 200: 0.02225215036882037
# Final cost : 0.02225215036882037
# Compute control for a deterministic system
# Cost in iteration 0: 0.02225215036882037
# Cost in iteration 200: 0.020518414834430218
# Final cost : 0.020518414834430218
# Compute control for a deterministic system
# Cost in iteration 0: 0.020518414834430218
# Cost in iteration 200: 0.019796357011376515
# Cost in iteration 400: 0.0194084651615901
# Final cost : 0.0194084651615901
# Compute control for a deterministic system
# Cost in iteration 0: 0.0194084651615901
# Cost in iteration 200: 0.019123066359527673
# Cost in iteration 400: 0.01895520138540098
# Cost in iteration 600: 0.01880872781328151
# Cost in iteration 800: 0.018674698222118275
# Cost in iteration 1000: 0.01854187420926613
# Final cost : 0.01854187420926613
# Compute control for a deterministic system
# Cost in iteration 0: 6.567910145333144
# Final cost : 3.908652150582548
# Compute control for a deterministic system
# Cost in iteration 0: 3.908652150582548
# Cost in iteration 200: 0.05933156079738677
# Cost in iteration 400: 0.027574331110944175
# Final cost : 0.027574331110944175
# Compute control for a deterministic system
# Cost in iteration 0: 0.027574331110944175
# Cost in iteration 200: 0.023411976115844845
# Final cost : 0.023411976115844845
# Compute control for a deterministic system
# Cost in iteration 0: 0.023411976115844845
# Cost in iteration 200: 0.02195280329488958
# Final cost : 0.02195280329488958
# Compute control for a deterministic system
# Cost in iteration 0: 0.02195280329488958
# Cost in iteration 200: 0.020968344381319313
# Cost in iteration 400: 0.020582198475297426
# Final cost : 0.020582198475297426
# Compute control for a deterministic system
# Cost in iteration 0: 0.020582198475297426
# Cost in iteration 200: 0.02015420893924274
# Cost in iteration 400: 0.019980896547922983
# Cost in iteration 600: 0.019805122817424355
# Cost in iteration 800: 0.01967605012127033
# Cost in iteration 1000: 0.01954890230671487
# Final cost : 0.01954890230671487
# Compute control for a deterministic system
# Cost in iteration 0: 6.680520010621298
# Final cost : 4.303029390046544
# Compute control for a deterministic system
# Cost in iteration 0: 4.303029390046544
# Cost in iteration 200: 0.044679428911828904
# Cost in iteration 400: 0.02699255707550783
# Final cost : 0.02699255707550783
# Compute control for a deterministic system
# Cost in iteration 0: 0.02699255707550783
# Cost in iteration 200: 0.0242637613591484
# Final cost : 0.0242637613591484
# Compute control for a deterministic system
# Cost in iteration 0: 0.0242637613591484
# Cost in iteration 200: 0.023211031764328354
# Final cost : 0.023211031764328354
# Compute control for a deterministic system
# Cost in iteration 0: 0.023211031764328354
# Cost in iteration 200: 0.022421829641783263
# Cost in iteration 400: 0.021998754825516362
# Final cost : 0.021998754825516362
# Compute control for a deterministic system
# Cost in iteration 0: 0.021998754825516362
# Cost in iteration 200: 0.02155559313672067
# Cost in iteration 400: 0.021371472551507904
# Cost in iteration 600: 0.02120427267674566
# Cost in iteration 800: 0.021064175893939822
# Cost in iteration 1000: 0.02092331465864412
# Final cost : 0.02092331465864412
# Compute control for a deterministic system
# Cost in iteration 0: 6.709330239499748
# Final cost : 5.10758484091466
# Compute control for a deterministic system
# Cost in iteration 0: 5.10758484091466
# Cost in iteration 200: 0.03754165133221136
# Cost in iteration 400: 0.027615181955743605
# Final cost : 0.027615181955743605
# Compute control for a deterministic system
# Cost in iteration 0: 0.027615181955743605
# Cost in iteration 200: 0.02541147027515882
# Final cost : 0.02541147027515882
# Compute control for a deterministic system
# Cost in iteration 0: 0.02541147027515882
# Cost in iteration 200: 0.024511012096870653
# Final cost : 0.024511012096870653
# Compute control for a deterministic system
# Cost in iteration 0: 0.024511012096870653
# Cost in iteration 200: 0.02382404798969229
# Cost in iteration 400: 0.023114863082125747
# Final cost : 0.023114863082125747
# Compute control for a deterministic system
# Cost in iteration 0: 0.023114863082125747
# Cost in iteration 200: 0.02265155839380394
# Cost in iteration 400: 0.022448652772830244
# Cost in iteration 600: 0.022274790752675827
# Cost in iteration 800: 0.0221085803092653
# Cost in iteration 1000: 0.021939883535156694
# Final cost : 0.021939883535156694
# Compute control for a deterministic system
# Cost in iteration 0: 6.65243759608336
# Final cost : 4.520379544692871
# Compute control for a deterministic system
# Cost in iteration 0: 4.520379544692871
# Cost in iteration 200: 0.05088755280491321
# Cost in iteration 400: 0.028458246711571093
# Final cost : 0.028458246711571093
# Compute control for a deterministic system
# Cost in iteration 0: 0.028458246711571093
# Cost in iteration 200: 0.025230939027034813
# Final cost : 0.025230939027034813
# Compute control for a deterministic system
# Cost in iteration 0: 0.025230939027034813
# Cost in iteration 200: 0.02416145983140281
# Final cost : 0.02416145983140281
# Compute control for a deterministic system
# Cost in iteration 0: 0.02416145983140281
# Cost in iteration 200: 0.023492051948923738
# Cost in iteration 400: 0.0232225659827505
# Final cost : 0.0232225659827505
# Compute control for a deterministic system
# Cost in iteration 0: 0.0232225659827505
# Cost in iteration 200: 0.022922334332398042
# Cost in iteration 400: 0.02277592517322868
# Cost in iteration 600: 0.022638688647987827
# Cost in iteration 800: 0.022500748450308878
# Cost in iteration 1000: 0.02235939728502448
# Final cost : 0.02235939728502448
# Compute control for a deterministic system
# Cost in iteration 0: 6.509954798968891
# Final cost : 4.005731118438616
# Compute control for a deterministic system
# Cost in iteration 0: 4.005731118438616
# Cost in iteration 200: 0.045282207715241635
# Cost in iteration 400: 0.02669871727037157
# Final cost : 0.02669871727037157
# Compute control for a deterministic system
# Cost in iteration 0: 0.02669871727037157
# Cost in iteration 200: 0.023835453235248324
# Final cost : 0.023835453235248324
# Compute control for a deterministic system
# Cost in iteration 0: 0.023835453235248324
# Cost in iteration 200: 0.02283684083598605
# Final cost : 0.02283684083598605
# Compute control for a deterministic system
# Cost in iteration 0: 0.02283684083598605
# Cost in iteration 200: 0.021870718700021073
# Cost in iteration 400: 0.02154943860874786
# Final cost : 0.02154943860874786
# Compute control for a deterministic system
# Cost in iteration 0: 0.02154943860874786
# Cost in iteration 200: 0.021436661557820643
# Cost in iteration 400: 0.021327398975889533
# Cost in iteration 600: 0.021218610523977825
# Cost in iteration 800: 0.021109181230963375
# Cost in iteration 1000: 0.020998578571333137
# Final cost : 0.020998578571333137
# Compute control for a deterministic system
# Cost in iteration 0: 6.287814638507996
# Final cost : 3.5381127982654443
# Compute control for a deterministic system
# Cost in iteration 0: 3.5381127982654443
# Cost in iteration 200: 0.06469164590347594
# Cost in iteration 400: 0.025778851495759533
# Final cost : 0.025778851495759533
# Compute control for a deterministic system
# Cost in iteration 0: 0.025778851495759533
# Cost in iteration 200: 0.02223253936972967
# Final cost : 0.02223253936972967
# Compute control for a deterministic system
# Cost in iteration 0: 0.02223253936972967
# Cost in iteration 200: 0.02131449379442111
# Final cost : 0.02131449379442111
# Compute control for a deterministic system
# Cost in iteration 0: 0.02131449379442111
# Cost in iteration 200: 0.020546944681508257
# Cost in iteration 400: 0.020457642670181922
# Final cost : 0.020457642670181922
# Compute control for a deterministic system
# Cost in iteration 0: 0.020457642670181922
# Cost in iteration 200: 0.02034825955447782
# Cost in iteration 400: 0.020239006752814984
# Cost in iteration 600: 0.02012774341403603
# Cost in iteration 800: 0.020013832684755258
# Cost in iteration 1000: 0.019896904659438122
# Final cost : 0.019896904659438122
# Compute control for a deterministic system
# Cost in iteration 0: 6.0013098152436
# Final cost : 3.076471611639913
# Compute control for a deterministic system
# Cost in iteration 0: 3.076471611639913
# Cost in iteration 200: 0.0969252403120171
# Cost in iteration 400: 0.030311745954423118
# Final cost : 0.030311745954423118
# Compute control for a deterministic system
# Cost in iteration 0: 0.030311745954423118
# Cost in iteration 200: 0.020919904307847306
# Final cost : 0.020919904307847306
# Compute control for a deterministic system
# Cost in iteration 0: 0.020919904307847306
# Cost in iteration 200: 0.019969749012897837
# Final cost : 0.019969749012897837
# Compute control for a deterministic system
# Cost in iteration 0: 0.019969749012897837
# Cost in iteration 200: 0.01961121726406551
# Cost in iteration 400: 0.019382672579129418
# Final cost : 0.019382672579129418
# Compute control for a deterministic system
# Cost in iteration 0: 0.019382672579129418
# Cost in iteration 200: 0.019182905769832524
# Cost in iteration 400: 0.01905552795045858
# Cost in iteration 600: 0.01893762043513416
# Cost in iteration 800: 0.018820239678173072
# Cost in iteration 1000: 0.018701738602130636
# Final cost : 0.018701738602130636
# Compute control for a deterministic system
# Cost in iteration 0: 5.646537810702565
# Final cost : 2.609733965809542
# Compute control for a deterministic system
# Cost in iteration 0: 2.609733965809542
# Cost in iteration 200: 0.13749477321230008
# Cost in iteration 400: 0.04370610701246977
# Final cost : 0.04370610701246977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04370610701246977
# Cost in iteration 200: 0.0203014357991204
# Final cost : 0.0203014357991204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0203014357991204
# Cost in iteration 200: 0.018779198712229436
# Final cost : 0.018779198712229436
# Compute control for a deterministic system
# Cost in iteration 0: 0.018779198712229436
# Cost in iteration 200: 0.01826012962904164
# Cost in iteration 400: 0.018015006170229695
# Final cost : 0.018015006170229695
# Compute control for a deterministic system
# Cost in iteration 0: 0.018015006170229695
# Cost in iteration 200: 0.017887715041214947
# Cost in iteration 400: 0.0177672091215758
# Cost in iteration 600: 0.017645805333180303
# Cost in iteration 800: 0.017521968912719305
# Cost in iteration 1000: 0.01739438357319051
# Final cost : 0.01739438357319051
# Compute control for a deterministic system
# Cost in iteration 0: 5.240104643202825
# Final cost : 2.1601309221866027
# Compute control for a deterministic system
# Cost in iteration 0: 2.1601309221866027
# Cost in iteration 200: 0.18369951951533442
# Cost in iteration 400: 0.06396822301784763
# Final cost : 0.06396822301784763
# Compute control for a deterministic system
# Cost in iteration 0: 0.06396822301784763
# Cost in iteration 200: 0.01813863330490949
# Final cost : 0.01813863330490949
# Compute control for a deterministic system
# Cost in iteration 0: 0.01813863330490949
# Cost in iteration 200: 0.01731264632730247
# Final cost : 0.01731264632730247
# Compute control for a deterministic system
# Cost in iteration 0: 0.01731264632730247
# Cost in iteration 200: 0.016816639742814547
# Cost in iteration 400: 0.01671581778784346
# Final cost : 0.01671581778784346
# Compute control for a deterministic system
# Cost in iteration 0: 0.01671581778784346
# Cost in iteration 200: 0.016589853542730713
# Cost in iteration 400: 0.016459806017397226
# Cost in iteration 600: 0.0163235714454053
# Cost in iteration 800: 0.015945641304247915
# Cost in iteration 1000: 0.015882922648427045
# Final cost : 0.015882922648427045
# Compute control for a deterministic system
# Cost in iteration 0: 4.803603711304705
# Final cost : 1.7485394812920165
# Compute control for a deterministic system
# Cost in iteration 0: 1.7485394812920165
# Cost in iteration 200: 0.1973653013302483
# Cost in iteration 400: 0.07161962082281648
# Final cost : 0.07161962082281648
# Compute control for a deterministic system
# Cost in iteration 0: 0.07161962082281648
# Cost in iteration 200: 0.01727508820785686
# Final cost : 0.01727508820785686
# Compute control for a deterministic system
# Cost in iteration 0: 0.01727508820785686
# Cost in iteration 200: 0.016050365504200356
# Final cost : 0.016050365504200356
# Compute control for a deterministic system
# Cost in iteration 0: 0.016050365504200356
# Cost in iteration 200: 0.015617537295066198
# Cost in iteration 400: 0.015486335156219317
# Final cost : 0.015486335156219317
# Compute control for a deterministic system
# Cost in iteration 0: 0.015486335156219317
# Cost in iteration 200: 0.01534593012253062
# Cost in iteration 400: 0.015203046306366893
# Cost in iteration 600: 0.014612695437022979
# Cost in iteration 800: 0.014399129601747737
# Cost in iteration 1000: 0.014294908078985931
# Final cost : 0.014294908078985931
# Compute control for a deterministic system
# Cost in iteration 0: 4.327262928732099
# Final cost : 1.3670442912892455
# Compute control for a deterministic system
# Cost in iteration 0: 1.3670442912892455
# Cost in iteration 200: 0.21895583238975497
# Cost in iteration 400: 0.0883000498040517
# Final cost : 0.0883000498040517
# Compute control for a deterministic system
# Cost in iteration 0: 0.0883000498040517
# Cost in iteration 200: 0.014930991414245722
# Final cost : 0.014930991414245722
# Compute control for a deterministic system
# Cost in iteration 0: 0.014930991414245722
# Cost in iteration 200: 0.014512463441630818
# Final cost : 0.014512463441630818
# Compute control for a deterministic system
# Cost in iteration 0: 0.014512463441630818
# Cost in iteration 200: 0.014330983717506157
# Cost in iteration 400: 0.014245855360871555
# Final cost : 0.014245855360871555
# Compute control for a deterministic system
# Cost in iteration 0: 0.014245855360871555
# Cost in iteration 200: 0.014019190284992877
# Cost in iteration 400: 0.013958424236159462
# Cost in iteration 600: 0.013898473901385435
# Cost in iteration 800: 0.013838589122793279
# Cost in iteration 1000: 0.013778670171957335
# Final cost : 0.013778670171957335
# Compute control for a deterministic system
# Cost in iteration 0: 3.831237770329163
# Final cost : 1.036660074412052
# Compute control for a deterministic system
# Cost in iteration 0: 1.036660074412052
# Cost in iteration 200: 0.23454409063102755
# Cost in iteration 400: 0.09019276380349985
# Final cost : 0.09019276380349985
# Compute control for a deterministic system
# Cost in iteration 0: 0.09019276380349985
# Cost in iteration 200: 0.01564796167969281
# Final cost : 0.01564796167969281
# Compute control for a deterministic system
# Cost in iteration 0: 0.01564796167969281
# Cost in iteration 200: 0.013455475848946725
# Final cost : 0.013455475848946725
# Compute control for a deterministic system
# Cost in iteration 0: 0.013455475848946725
# Cost in iteration 200: 0.013104430502559295
# Cost in iteration 400: 0.012970598479952421
# Final cost : 0.012970598479952421
# Compute control for a deterministic system
# Cost in iteration 0: 0.012970598479952421
# Cost in iteration 200: 0.012798748569919664
# Cost in iteration 400: 0.01273655503116515
# Cost in iteration 600: 0.01267492819666884
# Cost in iteration 800: 0.012611593873447518
# Cost in iteration 1000: 0.012549092910697448
# Final cost : 0.012549092910697448
# Compute control for a deterministic system
# Cost in iteration 0: 3.3373228009268208
# Final cost : 0.7732308306513603
# Compute control for a deterministic system
# Cost in iteration 0: 0.7732308306513603
# Cost in iteration 200: 0.24086630649155158
# Cost in iteration 400: 0.09494360403951646
# Final cost : 0.09494360403951646
# Compute control for a deterministic system
# Cost in iteration 0: 0.09494360403951646
# Cost in iteration 200: 0.014404961900002681
# Final cost : 0.014404961900002681
# Compute control for a deterministic system
# Cost in iteration 0: 0.014404961900002681
# Cost in iteration 200: 0.012121621834460524
# Final cost : 0.012121621834460524
# Compute control for a deterministic system
# Cost in iteration 0: 0.012121621834460524
# Cost in iteration 200: 0.011826849573463544
# Cost in iteration 400: 0.011721357316955158
# Final cost : 0.011721357316955158
# Compute control for a deterministic system
# Cost in iteration 0: 0.011721357316955158
# Cost in iteration 200: 0.011553269434541633
# Cost in iteration 400: 0.011485236901605446
# Cost in iteration 600: 0.01141920635445746
# Cost in iteration 800: 0.01135353278878884
# Cost in iteration 1000: 0.011287702710344294
# Final cost : 0.011287702710344294
# Compute control for a deterministic system
# Cost in iteration 0: 2.83243215263194
# Final cost : 0.5735566267526789
# Compute control for a deterministic system
# Cost in iteration 0: 0.5735566267526789
# Cost in iteration 200: 0.3121647557230238
# Cost in iteration 400: 0.20233945673761244
# Final cost : 0.20233945673761244
# Compute control for a deterministic system
# Cost in iteration 0: 0.20233945673761244
# Cost in iteration 200: 0.06972546977435304
# Final cost : 0.06972546977435304
# Compute control for a deterministic system
# Cost in iteration 0: 0.06972546977435304
# Cost in iteration 200: 0.012821208007492538
# Final cost : 0.012821208007492538
# Compute control for a deterministic system
# Cost in iteration 0: 0.012821208007492538
# Cost in iteration 200: 0.011203658900725512
# Cost in iteration 400: 0.010574400860346193
# Final cost : 0.010574400860346193
# Compute control for a deterministic system
# Cost in iteration 0: 0.010574400860346193
# Cost in iteration 200: 0.010506468739712059
# Cost in iteration 400: 0.010440057705979432
# Cost in iteration 600: 0.010373582314679242
# Cost in iteration 800: 0.010306841023405816
# Cost in iteration 1000: 0.010239737194308493
# Final cost : 0.010239737194308493
# Compute control for a deterministic system
# Cost in iteration 0: 2.3379306842630636
# Final cost : 0.45150214183148846
# Compute control for a deterministic system
# Cost in iteration 0: 0.45150214183148846
# Cost in iteration 200: 0.25673282443799184
# Cost in iteration 400: 0.12803068513652985
# Final cost : 0.12803068513652985
# Compute control for a deterministic system
# Cost in iteration 0: 0.12803068513652985
# Cost in iteration 200: 0.029900009772259994
# Final cost : 0.029900009772259994
# Compute control for a deterministic system
# Cost in iteration 0: 0.029900009772259994
# Cost in iteration 200: 0.011106783202663242
# Final cost : 0.011106783202663242
# Compute control for a deterministic system
# Cost in iteration 0: 0.011106783202663242
# Cost in iteration 200: 0.009697487809164462
# Cost in iteration 400: 0.009433024996318972
# Final cost : 0.009433024996318972
# Compute control for a deterministic system
# Cost in iteration 0: 0.009433024996318972
# Cost in iteration 200: 0.00930872934886263
# Cost in iteration 400: 0.00923698940607105
# Cost in iteration 600: 0.009166844893042678
# Cost in iteration 800: 0.009097237005105667
# Cost in iteration 1000: 0.009027780677480234
# Final cost : 0.009027780677480234
# Compute control for a deterministic system
# Cost in iteration 0: 1.8743250554387667
# Final cost : 0.4107931664849096
# Compute control for a deterministic system
# Cost in iteration 0: 0.4107931664849096
# Cost in iteration 200: 0.21446681049182856
# Cost in iteration 400: 0.07726027822405618
# Final cost : 0.07726027822405618
# Compute control for a deterministic system
# Cost in iteration 0: 0.07726027822405618
# Cost in iteration 200: 0.010198138499645489
# Final cost : 0.010198138499645489
# Compute control for a deterministic system
# Cost in iteration 0: 0.010198138499645489
# Cost in iteration 200: 0.008440493290656463
# Final cost : 0.008440493290656463
# Compute control for a deterministic system
# Cost in iteration 0: 0.008440493290656463
# Cost in iteration 200: 0.008201275005360484
# Cost in iteration 400: 0.008081886050913565
# Final cost : 0.008081886050913565
# Compute control for a deterministic system
# Cost in iteration 0: 0.008081886050913565
# Cost in iteration 200: 0.008009000159592846
# Cost in iteration 400: 0.007935951655258186
# Cost in iteration 600: 0.007864818701498407
# Cost in iteration 800: 0.007793856134274906
# Cost in iteration 1000: 0.007722892333888721
# Final cost : 0.007722892333888721
# Compute control for a deterministic system
# Cost in iteration 0: 1.4301537194849934
# Final cost : 0.439558655228821
# Compute control for a deterministic system
# Cost in iteration 0: 0.439558655228821
# Cost in iteration 200: 0.23970227698476676
# Cost in iteration 400: 0.10898677227845166
# Final cost : 0.10898677227845166
# Compute control for a deterministic system
# Cost in iteration 0: 0.10898677227845166
# Cost in iteration 200: 0.015214272420977738
# Final cost : 0.015214272420977738
# Compute control for a deterministic system
# Cost in iteration 0: 0.015214272420977738
# Cost in iteration 200: 0.0062944720883338755
# Final cost : 0.0062944720883338755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0062944720883338755
# Converged in iteration 51 with cost 0.0061832399821403075 because of vanishing difference
# Final cost : 0.0061832399821403075
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061832399821403075
# Cost in iteration 200: 0.0061015205089341405
# Cost in iteration 400: 0.006084628374884181
# Cost in iteration 600: 0.006080017227533245
# Cost in iteration 800: 0.00607848090208569
# Cost in iteration 1000: 0.006077884827849039
# Final cost : 0.006077884827849039
# Compute control for a deterministic system
# Cost in iteration 0: 1.0357060437643792
# Final cost : 0.4319327331849264
# Compute control for a deterministic system
# Cost in iteration 0: 0.4319327331849264
# Cost in iteration 200: 0.19270055535811348
# Cost in iteration 400: 0.048232658694117664
# Final cost : 0.048232658694117664
# Compute control for a deterministic system
# Cost in iteration 0: 0.048232658694117664
# Cost in iteration 200: 0.005122567956020015
# Final cost : 0.005122567956020015
# Compute control for a deterministic system
# Cost in iteration 0: 0.005122567956020015
# Converged in iteration 112 with cost 0.005080717109176797 because of vanishing difference
# Final cost : 0.005080717109176797
# Compute control for a deterministic system
# Cost in iteration 0: 0.005080717109176797
# Cost in iteration 200: 0.005067968224440556
# Cost in iteration 400: 0.005065814973526567
# Final cost : 0.005065814973526567
# Compute control for a deterministic system
# Cost in iteration 0: 0.005065814973526567
# Cost in iteration 200: 0.005065343262086989
# Cost in iteration 400: 0.005065195370769387
# Cost in iteration 600: 0.005065145811416594
# Cost in iteration 800: 0.005065128599986456
# Cost in iteration 1000: 0.005065122538372363
# Final cost : 0.005065122538372363
# Compute control for a deterministic system
# Cost in iteration 0: 0.6832875923499309
# Final cost : 0.49997162233499803
# Compute control for a deterministic system
# Cost in iteration 0: 0.49997162233499803
# Cost in iteration 200: 0.16450827022542305
# Cost in iteration 400: 0.022137445686012704
# Final cost : 0.022137445686012704
# Compute control for a deterministic system
# Cost in iteration 0: 0.022137445686012704
# Cost in iteration 200: 0.004370764379215961
# Final cost : 0.004370764379215961
# Compute control for a deterministic system
# Cost in iteration 0: 0.004370764379215961
# Cost in iteration 200: 0.0040501665544873154
# Final cost : 0.0040501665544873154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0040501665544873154
# Cost in iteration 200: 0.004034883833265911
# Cost in iteration 400: 0.004033571378539125
# Final cost : 0.004033571378539125
# Compute control for a deterministic system
# Cost in iteration 0: 0.004033571378539125
# Cost in iteration 200: 0.0040334018503909354
# Cost in iteration 400: 0.0040333672474556865
# Cost in iteration 600: 0.004033359609235565
# Cost in iteration 800: 0.004033357853240564
# Cost in iteration 1000: 0.004033357442555506
# Final cost : 0.004033357442555506
# Compute control for a deterministic system
# Cost in iteration 0: 0.39350654824230447
# Final cost : 0.2968961328563827
# Compute control for a deterministic system
# Cost in iteration 0: 0.2968961328563827
# Cost in iteration 200: 0.0034714571376150416
# Cost in iteration 400: 0.003378690575429025
# Final cost : 0.003378690575429025
# Compute control for a deterministic system
# Cost in iteration 0: 0.003378690575429025
# Cost in iteration 200: 0.003343059370756525
# Final cost : 0.003343059370756525
# Compute control for a deterministic system
# Cost in iteration 0: 0.003343059370756525
# Cost in iteration 200: 0.003314160681150771
# Final cost : 0.003314160681150771
# Compute control for a deterministic system
# Cost in iteration 0: 0.003314160681150771
# Cost in iteration 200: 0.0032723228064794256
# Cost in iteration 400: 0.0032309936776192846
# Final cost : 0.0032309936776192846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032309936776192846
# Cost in iteration 200: 0.003152006132252846
# Cost in iteration 400: 0.003074798867244145
# Converged in iteration 579 with cost 0.0030075117107510457 because of vanishing difference
# Final cost : 0.0030075117107510457
# Compute control for a deterministic system
# Cost in iteration 0: 0.18109401834263353
# Final cost : 0.08474292925631265
# Compute control for a deterministic system
# Cost in iteration 0: 0.08474292925631265
# Cost in iteration 200: 0.0022994589613551195
# Cost in iteration 400: 0.002254379492286177
# Final cost : 0.002254379492286177
# Compute control for a deterministic system
# Cost in iteration 0: 0.002254379492286177
# Cost in iteration 200: 0.0022043928934168166
# Final cost : 0.0022043928934168166
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022043928934168166
# Cost in iteration 200: 0.0021766344162872167
# Final cost : 0.0021766344162872167
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021766344162872167
# Cost in iteration 200: 0.0021340998176255133
# Cost in iteration 400: 0.002091919025729105
# Final cost : 0.002091919025729105
# Compute control for a deterministic system
# Cost in iteration 0: 0.002091919025729105
# Cost in iteration 200: 0.0020112769942583282
# Cost in iteration 400: 0.002006092396842793
# Cost in iteration 600: 0.002006092126007773
# Converged in iteration 737 with cost 0.0020060921232736366 because of step counter
# Final cost : 0.0020060921232736366
# Compute control for a deterministic system
# Cost in iteration 0: 0.045628926885835724
# Final cost : 0.0016609393418402958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016609393418402958
# Cost in iteration 200: 0.0011029196922266737
# Cost in iteration 400: 0.0010562117760400712
# Final cost : 0.0010562117760400712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010562117760400712
# Cost in iteration 200: 0.0010187366453735234
# Final cost : 0.0010187366453735234
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010187366453735234
# Cost in iteration 200: 0.0009905130710751078
# Final cost : 0.0009905130710751078
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009905130710751078
# Converged in iteration 7 with cost 0.0009894161512101723 because of vanishing difference
# Final cost : 0.0009894161512101723
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009894161512101723
# Cost in iteration 200: 0.00098938232193737
# Converged in iteration 209 with cost 0.0009893823219101262 because of step counter
# Final cost : 0.0009893823219101262
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Converged in iteration 1 with cost 2.7017031116754726e-06 because of step counter
# Final cost : 2.7017031116754726e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Converged in iteration 1 with cost 2.7017031116754726e-06 because of step counter
# Final cost : 2.7017031116754726e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Converged in iteration 1 with cost 2.7017031116754726e-06 because of step counter
# Final cost : 2.7017031116754726e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Converged in iteration 1 with cost 2.7017031116754726e-06 because of step counter
# Final cost : 2.7017031116754726e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.7017031116754726e-06
# Converged in iteration 1 with cost 2.7017031116754726e-06 because of step counter
# Final cost : 2.7017031116754726e-06
# Compute control for a deterministic system
# ...
# Converged in iteration 18 with cost 0.015488968831393219 because of vanishing difference
# Final cost : 0.015488968831393219
# Compute control for a deterministic system
# Cost in iteration 0: 0.015488968831393219
# Cost in iteration 200: 0.015486861738499268
# Final cost : 0.015486861738499268
# Compute control for a deterministic system
# Cost in iteration 0: 0.015486861738499268
# Cost in iteration 200: 0.015486183104468539
# Cost in iteration 400: 0.015485562484939246
# Final cost : 0.015485562484939246
# Compute control for a deterministic system
# Cost in iteration 0: 0.015485562484939246
# Cost in iteration 200: 0.015485128484379683
# Cost in iteration 400: 0.015484751072593535
# Cost in iteration 600: 0.015484422784759611
# Cost in iteration 800: 0.015484136514210803
# Cost in iteration 1000: 0.015483885820742945
# Final cost : 0.015483885820742945
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.017125995788080856
# Cost in iteration 200: 0.014419291282572456
# Final cost : 0.014419291282572456
# Compute control for a deterministic system
# Cost in iteration 0: 0.014419291282572456
# Cost in iteration 200: 0.014418889643120734
# Final cost : 0.014418889643120734
# Compute control for a deterministic system
# Cost in iteration 0: 0.014418889643120734
# Cost in iteration 200: 0.01441828034659194
# Final cost : 0.01441828034659194
# Compute control for a deterministic system
# Cost in iteration 0: 0.01441828034659194
# Cost in iteration 200: 0.014417997725518371
# Cost in iteration 400: 0.014417765404162654
# Final cost : 0.014417765404162654
# Compute control for a deterministic system
# Cost in iteration 0: 0.014417765404162654
# Cost in iteration 200: 0.014417591139302176
# Cost in iteration 400: 0.01441744190002316
# Cost in iteration 600: 0.014417313802149587
# Cost in iteration 800: 0.014417204161292175
# Cost in iteration 1000: 0.01441710990707155
# Final cost : 0.01441710990707155
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.01778383958954915
# Cost in iteration 200: 0.013382492344426315
# Final cost : 0.013382492344426315
# Compute control for a deterministic system
# Cost in iteration 0: 0.013382492344426315
# Cost in iteration 200: 0.013381697577635744
# Final cost : 0.013381697577635744
# Compute control for a deterministic system
# Cost in iteration 0: 0.013381697577635744
# Cost in iteration 200: 0.013380270696157525
# Final cost : 0.013380270696157525
# Compute control for a deterministic system
# Cost in iteration 0: 0.013380270696157525
# Cost in iteration 200: 0.013379821541894191
# Cost in iteration 400: 0.013379460326653091
# Final cost : 0.013379460326653091
# Compute control for a deterministic system
# Cost in iteration 0: 0.013379460326653091
# Cost in iteration 200: 0.01337920021235553
# Cost in iteration 400: 0.013378984133634298
# Cost in iteration 600: 0.013378803025145077
# Cost in iteration 800: 0.013378652968394593
# Cost in iteration 1000: 0.013378527354762472
# Final cost : 0.013378527354762472
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.013178643491257386
# Cost in iteration 200: 0.012318867792635023
# Final cost : 0.012318867792635023
# Compute control for a deterministic system
# Cost in iteration 0: 0.012318867792635023
# Cost in iteration 200: 0.012318729912441014
# Final cost : 0.012318729912441014
# Compute control for a deterministic system
# Cost in iteration 0: 0.012318729912441014
# Cost in iteration 200: 0.012318506806425461
# Final cost : 0.012318506806425461
# Compute control for a deterministic system
# Cost in iteration 0: 0.012318506806425461
# Cost in iteration 200: 0.012318434065457651
# Cost in iteration 400: 0.012318374718410258
# Final cost : 0.012318374718410258
# Compute control for a deterministic system
# Cost in iteration 0: 0.012318374718410258
# Cost in iteration 200: 0.012318330967522878
# Cost in iteration 400: 0.012318295486758078
# Cost in iteration 600: 0.012318266713413566
# Cost in iteration 800: 0.01231824336754949
# Cost in iteration 1000: 0.012318224406036823
# Final cost : 0.012318224406036823
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.011378918615244055
# Cost in iteration 200: 0.011262146862553456
# Final cost : 0.011262146862553456
# Compute control for a deterministic system
# Cost in iteration 0: 0.011262146862553456
# Cost in iteration 200: 0.01126205070451844
# Final cost : 0.01126205070451844
# Compute control for a deterministic system
# Cost in iteration 0: 0.01126205070451844
# Cost in iteration 200: 0.011261906094970481
# Final cost : 0.011261906094970481
# Compute control for a deterministic system
# Cost in iteration 0: 0.011261906094970481
# Cost in iteration 200: 0.011261859494877811
# Cost in iteration 400: 0.01126182432012486
# Final cost : 0.01126182432012486
# Compute control for a deterministic system
# Cost in iteration 0: 0.01126182432012486
# Cost in iteration 200: 0.01126180002858759
# Cost in iteration 400: 0.011261781018479128
# Cost in iteration 600: 0.01126176629210408
# Cost in iteration 800: 0.011261754822506947
# Cost in iteration 1000: 0.01126174588218936
# Final cost : 0.01126174588218936
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.017345346989021994
# Cost in iteration 200: 0.010246137703301426
# Final cost : 0.010246137703301426
# Compute control for a deterministic system
# Cost in iteration 0: 0.010246137703301426
# Cost in iteration 200: 0.0102325121422945
# Final cost : 0.0102325121422945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0102325121422945
# Cost in iteration 200: 0.010232486961454693
# Final cost : 0.010232486961454693
# Compute control for a deterministic system
# Cost in iteration 0: 0.010232486961454693
# Cost in iteration 200: 0.010232480551977946
# Cost in iteration 400: 0.010232476067710116
# Final cost : 0.010232476067710116
# Compute control for a deterministic system
# Cost in iteration 0: 0.010232476067710116
# Cost in iteration 200: 0.010232473138614057
# Cost in iteration 400: 0.010232470986562587
# Cost in iteration 600: 0.010232469384664766
# Cost in iteration 800: 0.010232468202028734
# Cost in iteration 1000: 0.010232467326707984
# Final cost : 0.010232467326707984
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.009206267781226709
# Cost in iteration 200: 0.00918253564924602
# Final cost : 0.00918253564924602
# Compute control for a deterministic system
# Cost in iteration 0: 0.00918253564924602
# Cost in iteration 200: 0.009182532879306546
# Final cost : 0.009182532879306546
# Compute control for a deterministic system
# Cost in iteration 0: 0.009182532879306546
# Cost in iteration 200: 0.00918252978173404
# Final cost : 0.00918252978173404
# Compute control for a deterministic system
# Cost in iteration 0: 0.00918252978173404
# Cost in iteration 200: 0.009182528700346998
# Cost in iteration 400: 0.009182527993502906
# Final cost : 0.009182527993502906
# Compute control for a deterministic system
# Cost in iteration 0: 0.009182527993502906
# Cost in iteration 200: 0.009182527570966964
# Cost in iteration 400: 0.00918252727810357
# Cost in iteration 600: 0.009182527076998705
# Cost in iteration 800: 0.009182526936796933
# Cost in iteration 1000: 0.009182526840282026
# Final cost : 0.009182526840282026
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.00938634203141262
# Cost in iteration 200: 0.008136002228647285
# Final cost : 0.008136002228647285
# Compute control for a deterministic system
# Cost in iteration 0: 0.008136002228647285
# Cost in iteration 200: 0.008135992096474982
# Final cost : 0.008135992096474982
# Compute control for a deterministic system
# Cost in iteration 0: 0.008135992096474982
# Cost in iteration 200: 0.008135991094439908
# Final cost : 0.008135991094439908
# Compute control for a deterministic system
# Cost in iteration 0: 0.008135991094439908
# Cost in iteration 200: 0.008135990870083657
# Cost in iteration 400: 0.008135990739028648
# Final cost : 0.008135990739028648
# Compute control for a deterministic system
# Cost in iteration 0: 0.008135990739028648
# Cost in iteration 200: 0.008135990667737387
# Cost in iteration 400: 0.008135990623186009
# Cost in iteration 600: 0.008135990595070152
# Cost in iteration 800: 0.008135990577472961
# Cost in iteration 1000: 0.008135990566358178
# Final cost : 0.008135990566358178
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.00905861460585953
# Converged in iteration 156 with cost 0.007116670599975367 because of vanishing difference
# Final cost : 0.007116670599975367
# Compute control for a deterministic system
# Cost in iteration 0: 0.007116670599975367
# Cost in iteration 200: 0.007116658616837983
# Final cost : 0.007116658616837983
# Compute control for a deterministic system
# Cost in iteration 0: 0.007116658616837983
# Cost in iteration 200: 0.007116657728735808
# Final cost : 0.007116657728735808
# Compute control for a deterministic system
# Cost in iteration 0: 0.007116657728735808
# Cost in iteration 200: 0.007116657641373318
# Cost in iteration 400: 0.007116657606577002
# Final cost : 0.007116657606577002
# Compute control for a deterministic system
# Cost in iteration 0: 0.007116657606577002
# Cost in iteration 200: 0.00711665759213779
# Cost in iteration 400: 0.007116657584630162
# Cost in iteration 600: 0.007116657580633868
# Cost in iteration 800: 0.00711665757845632
# Converged in iteration 939 with cost 0.007116657577558249 because of step counter
# Final cost : 0.007116657577558249
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.007257583302375298
# Converged in iteration 150 with cost 0.006077245811598502 because of vanishing difference
# Final cost : 0.006077245811598502
# Compute control for a deterministic system
# Cost in iteration 0: 0.006077245811598502
# Cost in iteration 200: 0.006077239811658449
# Final cost : 0.006077239811658449
# Compute control for a deterministic system
# Cost in iteration 0: 0.006077239811658449
# Cost in iteration 200: 0.0060772395424306645
# Final cost : 0.0060772395424306645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060772395424306645
# Cost in iteration 200: 0.006077239528436223
# Cost in iteration 400: 0.006077239524343933
# Final cost : 0.006077239524343933
# Compute control for a deterministic system
# Cost in iteration 0: 0.006077239524343933
# Converged in iteration 92 with cost 0.0060772395236091585 because of step counter
# Final cost : 0.0060772395236091585
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050869264045071685
# Cost in iteration 200: 0.005065095611763647
# Final cost : 0.005065095611763647
# Compute control for a deterministic system
# Cost in iteration 0: 0.005065095611763647
# Cost in iteration 200: 0.005065095603606413
# Final cost : 0.005065095603606413
# Compute control for a deterministic system
# Cost in iteration 0: 0.005065095603606413
# Converged in iteration 33 with cost 0.00506509560336508 because of step counter
# Final cost : 0.00506509560336508
# Compute control for a deterministic system
# Cost in iteration 0: 0.00506509560336508
# Converged in iteration 11 with cost 0.005065095603335616 because of step counter
# Final cost : 0.005065095603335616
# Compute control for a deterministic system
# Cost in iteration 0: 0.005065095603335616
# Converged in iteration 1 with cost 0.005065095603335616 because of step counter
# Final cost : 0.005065095603335616
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.00427992308608948
# Converged in iteration 100 with cost 0.004033305085491803 because of vanishing difference
# Final cost : 0.004033305085491803
# Compute control for a deterministic system
# Cost in iteration 0: 0.004033305085491803
# Cost in iteration 200: 0.004033298744736625
# Final cost : 0.004033298744736625
# Compute control for a deterministic system
# Cost in iteration 0: 0.004033298744736625
# Cost in iteration 200: 0.004033298710582165
# Final cost : 0.004033298710582165
# Compute control for a deterministic system
# Cost in iteration 0: 0.004033298710582165
# Converged in iteration 17 with cost 0.004033298710537144 because of step counter
# Final cost : 0.004033298710537144
# Compute control for a deterministic system
# Cost in iteration 0: 0.004033298710537144
# Converged in iteration 1 with cost 0.004033298710537144 because of step counter
# Final cost : 0.004033298710537144
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031967921158133988
# Cost in iteration 200: 0.0030056904425845242
# Final cost : 0.0030056904425845242
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030056904425845242
# Cost in iteration 200: 0.003005690421382934
# Final cost : 0.003005690421382934
# Compute control for a deterministic system
# Cost in iteration 0: 0.003005690421382934
# Converged in iteration 39 with cost 0.0030056904211002416 because of step counter
# Final cost : 0.0030056904211002416
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030056904211002416
# Converged in iteration 16 with cost 0.0030056904210612073 because of step counter
# Final cost : 0.0030056904210612073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030056904210612073
# Converged in iteration 1 with cost 0.0030056904210612073 because of step counter
# Final cost : 0.0030056904210612073
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.002071131831136568
# Cost in iteration 200: 0.0020060136775791482
# Final cost : 0.0020060136775791482
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020060136775791482
# Converged in iteration 82 with cost 0.002006013676419033 because of step counter
# Final cost : 0.002006013676419033
# Compute control for a deterministic system
# Cost in iteration 0: 0.002006013676419033
# Converged in iteration 1 with cost 0.002006013676419033 because of step counter
# Final cost : 0.002006013676419033
# Compute control for a deterministic system
# Cost in iteration 0: 0.002006013676419033
# Converged in iteration 22 with cost 0.0020060136763617085 because of step counter
# Final cost : 0.0020060136763617085
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020060136763617085
# Converged in iteration 1 with cost 0.0020060136763617085 because of step counter
# Final cost : 0.0020060136763617085
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009960028545208401
# Converged in iteration 154 with cost 0.0009892396687279357 because of step counter
# Final cost : 0.0009892396687279357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009892396687279357
# Converged in iteration 1 with cost 0.0009892396687279357 because of step counter
# Final cost : 0.0009892396687279357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009892396687279357
# Converged in iteration 1 with cost 0.0009892396687279357 because of step counter
# Final cost : 0.0009892396687279357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009892396687279357
# Converged in iteration 5 with cost 0.0009892396687093213 because of step counter
# Final cost : 0.0009892396687093213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009892396687093213
# Converged in iteration 1 with cost 0.0009892396687093213 because of step counter
# Final cost : 0.0009892396687093213
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
