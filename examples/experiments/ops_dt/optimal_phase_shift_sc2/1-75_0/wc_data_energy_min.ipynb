# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.16789760468071255 
y_init = 0.34689637900179876
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,936], wc.inh[0,936]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.17015079995392576 0.3442890159451902
# minima =  [ 1004  2504  4004  5504  7004  8503 10003 11503 13003 14503 16003 17502
#  19002 20502 22002 23502 25001 26501 28001 29501 31001 32501 34000 35500
#  37000 38500 40000 41500 42999 44499 45999 47499 48999 50499 51998 53498
#  54998 56498 57998 59498]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s3_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s3_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.055973002971348364
# Final cost : 0.01476479036375828
# Compute control for a deterministic system
# Cost in iteration 0: 0.01476479036375828
# Final cost : 0.0001223683846898793
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001223683846898793
# Final cost : 0.000120251767227084
# Compute control for a deterministic system
# Cost in iteration 0: 0.000120251767227084
# Final cost : 0.00012016229288764124
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012016229288764124
# Final cost : 0.000120145216222966
# Compute control for a deterministic system
# Cost in iteration 0: 0.000120145216222966
# Converged in iteration 738 with cost 0.00012014461400829716 because of vanishing difference
# Final cost : 0.00012014461400829716
# Compute control for a deterministic system
# Cost in iteration 0: 0.22680990812380114
# Final cost : 0.06491253107444772
# Compute control for a deterministic system
# Cost in iteration 0: 0.06491253107444772
# Final cost : 0.0005120466441715834
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005120466441715834
# Final cost : 0.000495292501945192
# Compute control for a deterministic system
# Cost in iteration 0: 0.000495292501945192
# Final cost : 0.000493468422901294
# Compute control for a deterministic system
# Cost in iteration 0: 0.000493468422901294
# Final cost : 0.0004931439853624139
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004931439853624139
# Converged in iteration 810 with cost 0.0004931310853527922 because of step counter
# Final cost : 0.0004931310853527922
# Compute control for a deterministic system
# Cost in iteration 0: 0.4946247517641807
# Final cost : 0.15798686142972462
# Compute control for a deterministic system
# Cost in iteration 0: 0.15798686142972462
# Final cost : 0.0011709887445896547
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011709887445896547
# Final cost : 0.0011078441094766324
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011078441094766324
# Final cost : 0.0011000353461535052
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011000353461535052
# Final cost : 0.0010986482421651608
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010986482421651608
# Converged in iteration 836 with cost 0.0010985840334280816 because of vanishing difference
# Final cost : 0.0010985840334280816
# Compute control for a deterministic system
# Cost in iteration 0: 0.8608885708602931
# Final cost : 0.3113138092769641
# Compute control for a deterministic system
# Cost in iteration 0: 0.3113138092769641
# Final cost : 0.00216337752375766
# Compute control for a deterministic system
# Cost in iteration 0: 0.00216337752375766
# Final cost : 0.001992914773211961
# Compute control for a deterministic system
# Cost in iteration 0: 0.001992914773211961
# Final cost : 0.001971938127477715
# Compute control for a deterministic system
# Cost in iteration 0: 0.001971938127477715
# Final cost : 0.0019686548318343204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019686548318343204
# Final cost : 0.0019684631703645087
# Compute control for a deterministic system
# Cost in iteration 0: 1.2922045315072759
# Final cost : 0.5268068179322446
# Compute control for a deterministic system
# Cost in iteration 0: 0.5268068179322446
# Final cost : 0.0034651721068218095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034651721068218095
# Final cost : 0.0031031410620967165
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031031410620967165
# Final cost : 0.003062327368643418
# Compute control for a deterministic system
# Cost in iteration 0: 0.003062327368643418
# Final cost : 0.0030566391884256547
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030566391884256547
# Final cost : 0.003056208607094328
# Compute control for a deterministic system
# Cost in iteration 0: 1.7968626459394517
# Final cost : 0.8226272601511275
# Compute control for a deterministic system
# Cost in iteration 0: 0.8226272601511275
# Final cost : 0.0051756043955671965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0051756043955671965
# Final cost : 0.004498794394632276
# Compute control for a deterministic system
# Cost in iteration 0: 0.004498794394632276
# Final cost : 0.004431128283080897
# Compute control for a deterministic system
# Cost in iteration 0: 0.004431128283080897
# Final cost : 0.004420615319951228
# Compute control for a deterministic system
# Cost in iteration 0: 0.004420615319951228
# Final cost : 0.004419647953221348
# Compute control for a deterministic system
# Cost in iteration 0: 2.3338720379256297
# Final cost : 1.1853005208582337
# Compute control for a deterministic system
# Cost in iteration 0: 1.1853005208582337
# Final cost : 0.007232188089702616
# Compute control for a deterministic system
# Cost in iteration 0: 0.007232188089702616
# Final cost : 0.006102799574379209
# Compute control for a deterministic system
# Cost in iteration 0: 0.006102799574379209
# Final cost : 0.006002404929132743
# Compute control for a deterministic system
# Cost in iteration 0: 0.006002404929132743
# Final cost : 0.005987149151294756
# Compute control for a deterministic system
# Cost in iteration 0: 0.005987149151294756
# Final cost : 0.005985413888046939
# Compute control for a deterministic system
# Cost in iteration 0: 2.9172834865437682
# Final cost : 1.6323172639664836
# Compute control for a deterministic system
# Cost in iteration 0: 1.6323172639664836
# Final cost : 0.009772215387538164
# Compute control for a deterministic system
# Cost in iteration 0: 0.009772215387538164
# Final cost : 0.008002826415976601
# Compute control for a deterministic system
# Cost in iteration 0: 0.008002826415976601
# Final cost : 0.00786191498012064
# Compute control for a deterministic system
# Cost in iteration 0: 0.00786191498012064
# Final cost : 0.00783718172418878
# Compute control for a deterministic system
# Cost in iteration 0: 0.00783718172418878
# Final cost : 0.007833819597481063
# Compute control for a deterministic system
# Cost in iteration 0: 3.5016020050709815
# Final cost : 2.1341454814388388
# Compute control for a deterministic system
# Cost in iteration 0: 2.1341454814388388
# Final cost : 0.012683065475311273
# Compute control for a deterministic system
# Cost in iteration 0: 0.012683065475311273
# Final cost : 0.010090668205760748
# Compute control for a deterministic system
# Cost in iteration 0: 0.010090668205760748
# Final cost : 0.009897264745705455
# Compute control for a deterministic system
# Cost in iteration 0: 0.009897264745705455
# Final cost : 0.009864599686004233
# Compute control for a deterministic system
# Cost in iteration 0: 0.009864599686004233
# Final cost : 0.009859221380048543
# Compute control for a deterministic system
# Cost in iteration 0: 4.10307520141059
# Final cost : 2.7084322962989567
# Compute control for a deterministic system
# Cost in iteration 0: 2.7084322962989567
# Final cost : 0.016148515136843167
# Compute control for a deterministic system
# Cost in iteration 0: 0.016148515136843167
# Final cost : 0.01246947254064717
# Compute control for a deterministic system
# Cost in iteration 0: 0.01246947254064717
# Final cost : 0.012213359165136545
# Compute control for a deterministic system
# Cost in iteration 0: 0.012213359165136545
# Final cost : 0.012171193453830421
# Compute control for a deterministic system
# Cost in iteration 0: 0.012171193453830421
# Final cost : 0.012162997425052837
# Compute control for a deterministic system
# Cost in iteration 0: 4.675798234049624
# Final cost : 3.3136410268714243
# Compute control for a deterministic system
# Cost in iteration 0: 3.3136410268714243
# Final cost : 0.02002852745833284
# Compute control for a deterministic system
# Cost in iteration 0: 0.02002852745833284
# Final cost : 0.015008778054122618
# Compute control for a deterministic system
# Cost in iteration 0: 0.015008778054122618
# Final cost : 0.014691330342377209
# Compute control for a deterministic system
# Cost in iteration 0: 0.014691330342377209
# Final cost : 0.014634462858288781
# Compute control for a deterministic system
# Cost in iteration 0: 0.014634462858288781
# Final cost : 0.014621801253648542
# Compute control for a deterministic system
# Cost in iteration 0: 5.23679868170237
# Final cost : 3.9684232464757616
# Compute control for a deterministic system
# Cost in iteration 0: 3.9684232464757616
# Final cost : 0.02459774390649969
# Compute control for a deterministic system
# Cost in iteration 0: 0.02459774390649969
# Final cost : 0.017861763932370715
# Compute control for a deterministic system
# Cost in iteration 0: 0.017861763932370715
# Final cost : 0.017473238700952482
# Compute control for a deterministic system
# Cost in iteration 0: 0.017473238700952482
# Final cost : 0.017392246443549857
# Compute control for a deterministic system
# Cost in iteration 0: 0.017392246443549857
# Final cost : 0.017371968994183123
# Compute control for a deterministic system
# Cost in iteration 0: 5.7440065731754
# Final cost : 4.621278232515673
# Compute control for a deterministic system
# Cost in iteration 0: 4.621278232515673
# Final cost : 0.02969419578107105
# Compute control for a deterministic system
# Cost in iteration 0: 0.02969419578107105
# Final cost : 0.02091041730879263
# Compute control for a deterministic system
# Cost in iteration 0: 0.02091041730879263
# Final cost : 0.020409176865167043
# Compute control for a deterministic system
# Cost in iteration 0: 0.020409176865167043
# Final cost : 0.02030368460124386
# Compute control for a deterministic system
# Cost in iteration 0: 0.02030368460124386
# Final cost : 0.02027364568567765
# Compute control for a deterministic system
# Cost in iteration 0: 6.212970262918845
# Final cost : 5.284576503435804
# Compute control for a deterministic system
# Cost in iteration 0: 5.284576503435804
# Final cost : 0.035689738603813956
# Compute control for a deterministic system
# Cost in iteration 0: 0.035689738603813956
# Final cost : 0.02434675227051027
# Compute control for a deterministic system
# Cost in iteration 0: 0.02434675227051027
# Final cost : 0.023758258426430968
# Compute control for a deterministic system
# Cost in iteration 0: 0.023758258426430968
# Final cost : 0.023547358344829118
# Compute control for a deterministic system
# Cost in iteration 0: 0.023547358344829118
# Final cost : 0.02348858992841557
# Compute control for a deterministic system
# Cost in iteration 0: 6.609132810110073
# Final cost : 5.89560713070809
# Compute control for a deterministic system
# Cost in iteration 0: 5.89560713070809
# Final cost : 0.042378637562608026
# Compute control for a deterministic system
# Cost in iteration 0: 0.042378637562608026
# Final cost : 0.027967353704222136
# Compute control for a deterministic system
# Cost in iteration 0: 0.027967353704222136
# Final cost : 0.027235879985578096
# Compute control for a deterministic system
# Cost in iteration 0: 0.027235879985578096
# Final cost : 0.02693871411098763
# Compute control for a deterministic system
# Cost in iteration 0: 0.02693871411098763
# Final cost : 0.026849473021201678
# Compute control for a deterministic system
# Cost in iteration 0: 6.945943901240291
# Final cost : 6.45498207166904
# Compute control for a deterministic system
# Cost in iteration 0: 6.45498207166904
# Final cost : 0.050259521088637536
# Compute control for a deterministic system
# Cost in iteration 0: 0.050259521088637536
# Final cost : 0.03202668662790833
# Compute control for a deterministic system
# Cost in iteration 0: 0.03202668662790833
# Final cost : 0.031114395787827143
# Compute control for a deterministic system
# Cost in iteration 0: 0.031114395787827143
# Final cost : 0.03067641115791129
# Compute control for a deterministic system
# Cost in iteration 0: 0.03067641115791129
# Final cost : 0.030542913681745294
# Compute control for a deterministic system
# Cost in iteration 0: 7.200486004356526
# Final cost : 6.903785282901196
# Compute control for a deterministic system
# Cost in iteration 0: 6.903785282901196
# Final cost : 0.059081923352967046
# Compute control for a deterministic system
# Cost in iteration 0: 0.059081923352967046
# Final cost : 0.03628111855481715
# Compute control for a deterministic system
# Cost in iteration 0: 0.03628111855481715
# Final cost : 0.03512969553180174
# Compute control for a deterministic system
# Cost in iteration 0: 0.03512969553180174
# Final cost : 0.03454703541467858
# Compute control for a deterministic system
# Cost in iteration 0: 0.03454703541467858
# Final cost : 0.03436743267197062
# Compute control for a deterministic system
# Cost in iteration 0: 7.38349274828695
# Final cost : 7.2432572892674525
# Compute control for a deterministic system
# Cost in iteration 0: 7.2432572892674525
# Final cost : 0.06954502016980478
# Compute control for a deterministic system
# Cost in iteration 0: 0.06954502016980478
# Final cost : 0.04106765056411194
# Compute control for a deterministic system
# Cost in iteration 0: 0.04106765056411194
# Final cost : 0.0395059593302494
# Compute control for a deterministic system
# Cost in iteration 0: 0.0395059593302494
# Final cost : 0.038780444558079025
# Compute control for a deterministic system
# Cost in iteration 0: 0.038780444558079025
# Final cost : 0.0385458091131892
# Compute control for a deterministic system
# Cost in iteration 0: 7.484089032280225
# Final cost : 7.442435367420288
# Compute control for a deterministic system
# Cost in iteration 0: 7.442435367420288
# Final cost : 0.08141516452096945
# Compute control for a deterministic system
# Cost in iteration 0: 0.08141516452096945
# Final cost : 0.04619295487260401
# Compute control for a deterministic system
# Cost in iteration 0: 0.04619295487260401
# Final cost : 0.04407774851320695
# Compute control for a deterministic system
# Cost in iteration 0: 0.04407774851320695
# Final cost : 0.043131207221659786
# Compute control for a deterministic system
# Cost in iteration 0: 0.043131207221659786
# Final cost : 0.04283822401715045
# Compute control for a deterministic system
# Cost in iteration 0: 7.507483371795184
# Final cost : 7.506169495731556
# Compute control for a deterministic system
# Cost in iteration 0: 7.506169495731556
# Final cost : 0.09638069769750587
# Compute control for a deterministic system
# Cost in iteration 0: 0.09638069769750587
# Final cost : 0.05194255337109861
# Compute control for a deterministic system
# Cost in iteration 0: 0.05194255337109861
# Final cost : 0.049112853892711986
# Compute control for a deterministic system
# Cost in iteration 0: 0.049112853892711986
# Final cost : 0.04787043625080386
# Compute control for a deterministic system
# Cost in iteration 0: 0.04787043625080386
# Final cost : 0.047485317345996356
# Compute control for a deterministic system
# Cost in iteration 0: 7.452734837594315
# Final cost : 7.430112835740463
# Compute control for a deterministic system
# Cost in iteration 0: 7.430112835740463
# Final cost : 0.08788679129008461
# Compute control for a deterministic system
# Cost in iteration 0: 0.08788679129008461
# Final cost : 0.04940355685445221
# Compute control for a deterministic system
# Cost in iteration 0: 0.04940355685445221
# Final cost : 0.047186843871372716
# Compute control for a deterministic system
# Cost in iteration 0: 0.047186843871372716
# Final cost : 0.04629294003471906
# Compute control for a deterministic system
# Cost in iteration 0: 0.04629294003471906
# Final cost : 0.046074363026530014
# Compute control for a deterministic system
# Cost in iteration 0: 7.317447656389243
# Final cost : 7.212263467221506
# Compute control for a deterministic system
# Cost in iteration 0: 7.212263467221506
# Final cost : 0.07464385734904441
# Compute control for a deterministic system
# Cost in iteration 0: 0.07464385734904441
# Final cost : 0.04372890119312479
# Compute control for a deterministic system
# Cost in iteration 0: 0.04372890119312479
# Final cost : 0.042085667184515264
# Compute control for a deterministic system
# Cost in iteration 0: 0.042085667184515264
# Final cost : 0.04141019128332956
# Compute control for a deterministic system
# Cost in iteration 0: 0.04141019128332956
# Final cost : 0.041230179949115105
# Compute control for a deterministic system
# Cost in iteration 0: 7.109841386629864
# Final cost : 6.869793731432214
# Compute control for a deterministic system
# Cost in iteration 0: 6.869793731432214
# Final cost : 0.06352786005088434
# Compute control for a deterministic system
# Cost in iteration 0: 0.06352786005088434
# Final cost : 0.038681107635093574
# Compute control for a deterministic system
# Cost in iteration 0: 0.038681107635093574
# Final cost : 0.03748569155381161
# Compute control for a deterministic system
# Cost in iteration 0: 0.03748569155381161
# Final cost : 0.0369233784067126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0369233784067126
# Final cost : 0.03677769567455363
# Compute control for a deterministic system
# Cost in iteration 0: 6.821589924630023
# Final cost : 6.39770667307233
# Compute control for a deterministic system
# Cost in iteration 0: 6.39770667307233
# Final cost : 0.053612300785480065
# Compute control for a deterministic system
# Cost in iteration 0: 0.053612300785480065
# Final cost : 0.033934092380274
# Compute control for a deterministic system
# Cost in iteration 0: 0.033934092380274
# Final cost : 0.03300923379287669
# Compute control for a deterministic system
# Cost in iteration 0: 0.03300923379287669
# Final cost : 0.03258038897742142
# Compute control for a deterministic system
# Cost in iteration 0: 0.03258038897742142
# Final cost : 0.03246915751377744
# Compute control for a deterministic system
# Cost in iteration 0: 6.472808603067905
# Final cost : 5.843701252423985
# Compute control for a deterministic system
# Cost in iteration 0: 5.843701252423985
# Final cost : 0.04521474104431165
# Compute control for a deterministic system
# Cost in iteration 0: 0.04521474104431165
# Final cost : 0.02965694393564189
# Compute control for a deterministic system
# Cost in iteration 0: 0.02965694393564189
# Final cost : 0.02893246598127246
# Compute control for a deterministic system
# Cost in iteration 0: 0.02893246598127246
# Final cost : 0.028611735970682395
# Compute control for a deterministic system
# Cost in iteration 0: 0.028611735970682395
# Final cost : 0.028527968906991035
# Compute control for a deterministic system
# Cost in iteration 0: 6.051673919230707
# Final cost : 5.209303387803394
# Compute control for a deterministic system
# Cost in iteration 0: 5.209303387803394
# Final cost : 0.037702570233613654
# Compute control for a deterministic system
# Cost in iteration 0: 0.037702570233613654
# Final cost : 0.025601294025431886
# Compute control for a deterministic system
# Cost in iteration 0: 0.025601294025431886
# Final cost : 0.02498267468954239
# Compute control for a deterministic system
# Cost in iteration 0: 0.02498267468954239
# Final cost : 0.024800877150920785
# Compute control for a deterministic system
# Cost in iteration 0: 0.024800877150920785
# Final cost : 0.024752927073729565
# Compute control for a deterministic system
# Cost in iteration 0: 5.588840388888546
# Final cost : 4.560025245959
# Compute control for a deterministic system
# Cost in iteration 0: 4.560025245959
# Final cost : 0.03133364882910729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03133364882910729
# Final cost : 0.021979248807807494
# Compute control for a deterministic system
# Cost in iteration 0: 0.021979248807807494
# Final cost : 0.0214681350642669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0214681350642669
# Final cost : 0.021365957557524844
# Compute control for a deterministic system
# Cost in iteration 0: 0.021365957557524844
# Final cost : 0.021340310391831728
# Compute control for a deterministic system
# Cost in iteration 0: 5.06964841575295
# Final cost : 3.8901933642092312
# Compute control for a deterministic system
# Cost in iteration 0: 3.8901933642092312
# Final cost : 0.025647162593413302
# Compute control for a deterministic system
# Cost in iteration 0: 0.025647162593413302
# Final cost : 0.018594661710481405
# Compute control for a deterministic system
# Cost in iteration 0: 0.018594661710481405
# Final cost : 0.018197680287037245
# Compute control for a deterministic system
# Cost in iteration 0: 0.018197680287037245
# Final cost : 0.018122847023952133
# Compute control for a deterministic system
# Cost in iteration 0: 0.018122847023952133
# Final cost : 0.018105693469510527
# Compute control for a deterministic system
# Cost in iteration 0: 4.5324890810339
# Final cost : 3.257424513569068
# Compute control for a deterministic system
# Cost in iteration 0: 3.257424513569068
# Final cost : 0.020847562896046147
# Compute control for a deterministic system
# Cost in iteration 0: 0.020847562896046147
# Final cost : 0.01559327085743931
# Compute control for a deterministic system
# Cost in iteration 0: 0.01559327085743931
# Final cost : 0.015281753497258995
# Compute control for a deterministic system
# Cost in iteration 0: 0.015281753497258995
# Final cost : 0.01522885456560228
# Compute control for a deterministic system
# Cost in iteration 0: 0.01522885456560228
# Final cost : 0.015218210072451152
# Compute control for a deterministic system
# Cost in iteration 0: 3.960392025547704
# Final cost : 2.6448817483040714
# Compute control for a deterministic system
# Cost in iteration 0: 2.6448817483040714
# Final cost : 0.016592148333589254
# Compute control for a deterministic system
# Cost in iteration 0: 0.016592148333589254
# Final cost : 0.012814449442051347
# Compute control for a deterministic system
# Cost in iteration 0: 0.012814449442051347
# Final cost : 0.012567230321531809
# Compute control for a deterministic system
# Cost in iteration 0: 0.012567230321531809
# Final cost : 0.012527062671953764
# Compute control for a deterministic system
# Cost in iteration 0: 0.012527062671953764
# Final cost : 0.012520209368547171
# Compute control for a deterministic system
# Cost in iteration 0: 3.395368490893563
# Final cost : 2.097342277232508
# Compute control for a deterministic system
# Cost in iteration 0: 2.097342277232508
# Final cost : 0.013037030468687198
# Compute control for a deterministic system
# Cost in iteration 0: 0.013037030468687198
# Final cost : 0.010364017018703545
# Compute control for a deterministic system
# Cost in iteration 0: 0.010364017018703545
# Final cost : 0.010182147875598522
# Compute control for a deterministic system
# Cost in iteration 0: 0.010182147875598522
# Final cost : 0.010155215506304945
# Compute control for a deterministic system
# Cost in iteration 0: 0.010155215506304945
# Final cost : 0.010151580969201263
# Compute control for a deterministic system
# Cost in iteration 0: 2.8193547054855475
# Final cost : 1.595027085743576
# Compute control for a deterministic system
# Cost in iteration 0: 1.595027085743576
# Final cost : 0.009930797696464481
# Compute control for a deterministic system
# Cost in iteration 0: 0.009930797696464481
# Final cost : 0.008132957104607794
# Compute control for a deterministic system
# Cost in iteration 0: 0.008132957104607794
# Final cost : 0.008002958403158556
# Compute control for a deterministic system
# Cost in iteration 0: 0.008002958403158556
# Final cost : 0.007984179555158363
# Compute control for a deterministic system
# Cost in iteration 0: 0.007984179555158363
# Final cost : 0.007982050837879909
# Compute control for a deterministic system
# Cost in iteration 0: 2.2748816459352805
# Final cost : 1.1713543046291413
# Compute control for a deterministic system
# Cost in iteration 0: 1.1713543046291413
# Final cost : 0.007388713609590865
# Compute control for a deterministic system
# Cost in iteration 0: 0.007388713609590865
# Final cost : 0.006227783148121227
# Compute control for a deterministic system
# Cost in iteration 0: 0.006227783148121227
# Final cost : 0.006136497183483133
# Compute control for a deterministic system
# Cost in iteration 0: 0.006136497183483133
# Final cost : 0.006124821805331227
# Compute control for a deterministic system
# Cost in iteration 0: 0.006124821805331227
# Final cost : 0.0061236938982792005
# Compute control for a deterministic system
# Cost in iteration 0: 1.7454643895416961
# Final cost : 0.8080861896192783
# Compute control for a deterministic system
# Cost in iteration 0: 0.8080861896192783
# Final cost : 0.005230881228769503
# Compute control for a deterministic system
# Cost in iteration 0: 0.005230881228769503
# Final cost : 0.004542250182026493
# Compute control for a deterministic system
# Cost in iteration 0: 0.004542250182026493
# Final cost : 0.004481217597649092
# Compute control for a deterministic system
# Cost in iteration 0: 0.004481217597649092
# Final cost : 0.0044745271474837854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044745271474837854
# Final cost : 0.004474062403563759
# Compute control for a deterministic system
# Cost in iteration 0: 1.2718821292136762
# Final cost : 0.5259762726497493
# Compute control for a deterministic system
# Cost in iteration 0: 0.5259762726497493
# Final cost : 0.003535289583867686
# Compute control for a deterministic system
# Cost in iteration 0: 0.003535289583867686
# Final cost : 0.003160983365890586
# Compute control for a deterministic system
# Cost in iteration 0: 0.003160983365890586
# Final cost : 0.0031227079282928945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031227079282928945
# Final cost : 0.0031185321750863957
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031185321750863957
# Final cost : 0.0031182748262408915
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425488395436342
# Final cost : 0.30793657610995906
# Compute control for a deterministic system
# Cost in iteration 0: 0.30793657610995906
# Final cost : 0.0021770712916130636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021770712916130636
# Final cost : 0.002003847353768941
# Compute control for a deterministic system
# Cost in iteration 0: 0.002003847353768941
# Final cost : 0.0019838455001409674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019838455001409674
# Final cost : 0.001981616321254896
# Compute control for a deterministic system
# Cost in iteration 0: 0.001981616321254896
# Final cost : 0.0019815062900526213
# Compute control for a deterministic system
# Cost in iteration 0: 0.4943368981781017
# Final cost : 0.1599037411832413
# Compute control for a deterministic system
# Cost in iteration 0: 0.1599037411832413
# Final cost : 0.0011973548533131429
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011973548533131429
# Final cost : 0.0011314763684347347
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011314763684347347
# Final cost : 0.0011233496849468436
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011233496849468436
# Final cost : 0.0011223393550576486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011223393550576486
# Final cost : 0.0011222984656006412
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359199005515515
# Final cost : 0.06445677483033777
# Compute control for a deterministic system
# Cost in iteration 0: 0.06445677483033777
# Final cost : 0.0005121275147890539
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005121275147890539
# Final cost : 0.0004951970344913318
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004951970344913318
# Final cost : 0.0004933518262778344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004933518262778344
# Final cost : 0.0004930540068471045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004930540068471045
# Converged in iteration 982 with cost 0.0004930436788400169 because of step counter
# Final cost : 0.0004930436788400169
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821085337444422
# Final cost : 0.015441065120804471
# Compute control for a deterministic system
# Cost in iteration 0: 0.015441065120804471
# Final cost : 0.00012827950798586919
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012827950798586919
# Final cost : 0.00012599709131816544
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012599709131816544
# Final cost : 0.00012588847405202918
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012588847405202918
# Final cost : 0.00012586945394308256
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012586945394308256
# Converged in iteration 710 with cost 0.0001258688308970907 because of step counter
# Final cost : 0.0001258688308970907
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Final cost : 3.0355205269178877e-07
# Compute control for a deterministic system
# Cost in iteration 0: 3.0355205269178877e-07
# Final cost : 2.5643741345766633e-09
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0442102444561223
# Final cost : 0.000499311849542974
# Compute control for a deterministic system
# Cost in iteration 0: 0.000499311849542974
# Final cost : 0.0004938992048595292
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004938992048595292
# Final cost : 0.0004932564216513486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004932564216513486
# Final cost : 0.0004931363164939143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004931363164939143
# Converged in iteration 847 with cost 0.0004931310853583265 because of step counter
# Final cost : 0.0004931310853583265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0820500721823372
# Final cost : 0.0011143235282756712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011143235282756712
# Final cost : 0.0011007128563276525
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011007128563276525
# Final cost : 0.001098943123956616
# Compute control for a deterministic system
# Cost in iteration 0: 0.001098943123956616
# Final cost : 0.001098602336949958
# Compute control for a deterministic system
# Cost in iteration 0: 0.001098602336949958
# Converged in iteration 883 with cost 0.001098584033417759 because of step counter
# Final cost : 0.001098584033417759
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.08842667923047536
# Final cost : 0.0019974362879652337
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019974362879652337
# Final cost : 0.00197272553226003
# Compute control for a deterministic system
# Cost in iteration 0: 0.00197272553226003
# Final cost : 0.0019692759344718297
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019692759344718297
# Final cost : 0.0019685160604663776
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019685160604663776
# Final cost : 0.001968463167839189
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.010547928241724291
# Final cost : 0.00309597920024715
# Compute control for a deterministic system
# Cost in iteration 0: 0.00309597920024715
# Final cost : 0.003062433302628431
# Compute control for a deterministic system
# Cost in iteration 0: 0.003062433302628431
# Final cost : 0.0030574837119436466
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030574837119436466
# Final cost : 0.00305631416704953
# Compute control for a deterministic system
# Cost in iteration 0: 0.00305631416704953
# Final cost : 0.003056208606250981
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.021042709447383325
# Final cost : 0.0044789741383710014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044789741383710014
# Final cost : 0.0044291187755042885
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044291187755042885
# Final cost : 0.004421896327458957
# Compute control for a deterministic system
# Cost in iteration 0: 0.004421896327458957
# Final cost : 0.004419878424514749
# Compute control for a deterministic system
# Cost in iteration 0: 0.004419878424514749
# Final cost : 0.004419647921602136
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.041847264893854
# Final cost : 0.006061403174900758
# Compute control for a deterministic system
# Cost in iteration 0: 0.006061403174900758
# Final cost : 0.005997926506490248
# Compute control for a deterministic system
# Cost in iteration 0: 0.005997926506490248
# Final cost : 0.005988581170935753
# Compute control for a deterministic system
# Cost in iteration 0: 0.005988581170935753
# Final cost : 0.005985798205773745
# Compute control for a deterministic system
# Cost in iteration 0: 0.005985798205773745
# Final cost : 0.005985413548667216
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.05837270364245941
# Final cost : 0.00793761698408612
# Compute control for a deterministic system
# Cost in iteration 0: 0.00793761698408612
# Final cost : 0.007851295623103152
# Compute control for a deterministic system
# Cost in iteration 0: 0.007851295623103152
# Final cost : 0.007838463708601475
# Compute control for a deterministic system
# Cost in iteration 0: 0.007838463708601475
# Final cost : 0.007834492126755402
# Compute control for a deterministic system
# Cost in iteration 0: 0.007834492126755402
# Final cost : 0.00783381857840147
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.012761839276653216
# Final cost : 0.010006636436725358
# Compute control for a deterministic system
# Cost in iteration 0: 0.010006636436725358
# Final cost : 0.009881714967159663
# Compute control for a deterministic system
# Cost in iteration 0: 0.009881714967159663
# Final cost : 0.009865364479323666
# Compute control for a deterministic system
# Cost in iteration 0: 0.009865364479323666
# Final cost : 0.009860216032385348
# Compute control for a deterministic system
# Cost in iteration 0: 0.009860216032385348
# Final cost : 0.009859219053366279
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.34306997244029386
# Final cost : 0.01237988457854069
# Compute control for a deterministic system
# Cost in iteration 0: 0.01237988457854069
# Final cost : 0.012193881550321254
# Compute control for a deterministic system
# Cost in iteration 0: 0.012193881550321254
# Final cost : 0.012171111328899798
# Compute control for a deterministic system
# Cost in iteration 0: 0.012171111328899798
# Final cost : 0.012164314377287476
# Compute control for a deterministic system
# Cost in iteration 0: 0.012164314377287476
# Final cost : 0.012162983763077128
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.0766916068723644
# Final cost : 0.014791253075865703
# Compute control for a deterministic system
# Cost in iteration 0: 0.014791253075865703
# Final cost : 0.014651597277658955
# Compute control for a deterministic system
# Cost in iteration 0: 0.014651597277658955
# Final cost : 0.014630422235865005
# Compute control for a deterministic system
# Cost in iteration 0: 0.014630422235865005
# Final cost : 0.014623500332799709
# Compute control for a deterministic system
# Cost in iteration 0: 0.014623500332799709
# Final cost : 0.014621768070990363
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.028170083455437832
# Final cost : 0.01757773138974292
# Compute control for a deterministic system
# Cost in iteration 0: 0.01757773138974292
# Final cost : 0.017408544806838504
# Compute control for a deterministic system
# Cost in iteration 0: 0.017408544806838504
# Final cost : 0.017383413059511518
# Compute control for a deterministic system
# Cost in iteration 0: 0.017383413059511518
# Final cost : 0.017374396901422805
# Compute control for a deterministic system
# Cost in iteration 0: 0.017374396901422805
# Final cost : 0.017371844204499144
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.13395999133864855
# Final cost : 0.02051092963255966
# Compute control for a deterministic system
# Cost in iteration 0: 0.02051092963255966
# Final cost : 0.02031636768800655
# Compute control for a deterministic system
# Cost in iteration 0: 0.02031636768800655
# Final cost : 0.020286665200214125
# Compute control for a deterministic system
# Cost in iteration 0: 0.020286665200214125
# Final cost : 0.020276580937875217
# Compute control for a deterministic system
# Cost in iteration 0: 0.020276580937875217
# Final cost : 0.020273320653565866
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.048763371353532994
# Final cost : 0.023750544686807033
# Compute control for a deterministic system
# Cost in iteration 0: 0.023750544686807033
# Final cost : 0.02353931708751905
# Compute control for a deterministic system
# Cost in iteration 0: 0.02353931708751905
# Final cost : 0.023505323772259046
# Compute control for a deterministic system
# Cost in iteration 0: 0.023505323772259046
# Final cost : 0.023492186279152255
# Compute control for a deterministic system
# Cost in iteration 0: 0.023492186279152255
# Final cost : 0.023487412231023252
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.7826417146253958
# Final cost : 0.027465460311765836
# Compute control for a deterministic system
# Cost in iteration 0: 0.027465460311765836
# Final cost : 0.02691704519351489
# Compute control for a deterministic system
# Cost in iteration 0: 0.02691704519351489
# Final cost : 0.026871421777210247
# Compute control for a deterministic system
# Cost in iteration 0: 0.026871421777210247
# Final cost : 0.02685436233285973
# Compute control for a deterministic system
# Cost in iteration 0: 0.02685436233285973
# Final cost : 0.026847580007851
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.03144525506463491
# Final cost : 0.030891239682753317
# Compute control for a deterministic system
# Cost in iteration 0: 0.030891239682753317
# Final cost : 0.03060891238276521
# Compute control for a deterministic system
# Cost in iteration 0: 0.03060891238276521
# Final cost : 0.03056399092099554
# Compute control for a deterministic system
# Cost in iteration 0: 0.03056399092099554
# Final cost : 0.03054503139408172
# Compute control for a deterministic system
# Cost in iteration 0: 0.03054503139408172
# Final cost : 0.030536453831518817
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.08729092145890821
# Final cost : 0.03470712503660733
# Compute control for a deterministic system
# Cost in iteration 0: 0.03470712503660733
# Final cost : 0.03443902701395088
# Compute control for a deterministic system
# Cost in iteration 0: 0.03443902701395088
# Final cost : 0.03439310937424778
# Compute control for a deterministic system
# Cost in iteration 0: 0.03439310937424778
# Final cost : 0.03437061058617169
# Compute control for a deterministic system
# Cost in iteration 0: 0.03437061058617169
# Final cost : 0.03435962503763801
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.08898496525858546
# Final cost : 0.03926961533767531
# Compute control for a deterministic system
# Cost in iteration 0: 0.03926961533767531
# Final cost : 0.038626590890231995
# Compute control for a deterministic system
# Cost in iteration 0: 0.038626590890231995
# Final cost : 0.03856509676899121
# Compute control for a deterministic system
# Cost in iteration 0: 0.03856509676899121
# Final cost : 0.0385373864594507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0385373864594507
# Final cost : 0.038522561472742474
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.12169959015757396
# Final cost : 0.04379492722680514
# Compute control for a deterministic system
# Cost in iteration 0: 0.04379492722680514
# Final cost : 0.042920222728000085
# Compute control for a deterministic system
# Cost in iteration 0: 0.042920222728000085
# Final cost : 0.042853510566358895
# Compute control for a deterministic system
# Cost in iteration 0: 0.042853510566358895
# Final cost : 0.042822439986985754
# Compute control for a deterministic system
# Cost in iteration 0: 0.042822439986985754
# Final cost : 0.04280438175311702
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.14254559789471744
# Final cost : 0.04873232352665567
# Compute control for a deterministic system
# Cost in iteration 0: 0.04873232352665567
# Final cost : 0.04757201267193818
# Compute control for a deterministic system
# Cost in iteration 0: 0.04757201267193818
# Final cost : 0.0474932802502565
# Compute control for a deterministic system
# Cost in iteration 0: 0.0474932802502565
# Final cost : 0.04745710318554968
# Compute control for a deterministic system
# Cost in iteration 0: 0.04745710318554968
# Final cost : 0.04743428305226772
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.20761635322203614
# Final cost : 0.05441784115358883
# Compute control for a deterministic system
# Cost in iteration 0: 0.05441784115358883
# Final cost : 0.05232011054905628
# Compute control for a deterministic system
# Cost in iteration 0: 0.05232011054905628
# Final cost : 0.05223254528257686
# Compute control for a deterministic system
# Cost in iteration 0: 0.05223254528257686
# Final cost : 0.05219189267069912
# Compute control for a deterministic system
# Cost in iteration 0: 0.05219189267069912
# Final cost : 0.05216414954912584
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214794546269104
# Final cost : 0.0414861185537217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0414861185537217
# Final cost : 0.04128048373537655
# Compute control for a deterministic system
# Cost in iteration 0: 0.04128048373537655
# Final cost : 0.04124750673389561
# Compute control for a deterministic system
# Cost in iteration 0: 0.04124750673389561
# Final cost : 0.041230443139435975
# Compute control for a deterministic system
# Cost in iteration 0: 0.041230443139435975
# Final cost : 0.041223628590575594
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.23594285840615042
# Final cost : 0.0371028444260668
# Compute control for a deterministic system
# Cost in iteration 0: 0.0371028444260668
# Final cost : 0.0368656643153771
# Compute control for a deterministic system
# Cost in iteration 0: 0.0368656643153771
# Final cost : 0.03681868234073696
# Compute control for a deterministic system
# Cost in iteration 0: 0.03681868234073696
# Final cost : 0.03678742777472548
# Compute control for a deterministic system
# Cost in iteration 0: 0.03678742777472548
# Final cost : 0.03677160136419743
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.34108638948736825
# Final cost : 0.03272669584609218
# Compute control for a deterministic system
# Cost in iteration 0: 0.03272669584609218
# Final cost : 0.03254374637068836
# Compute control for a deterministic system
# Cost in iteration 0: 0.03254374637068836
# Final cost : 0.03249961829197135
# Compute control for a deterministic system
# Cost in iteration 0: 0.03249961829197135
# Final cost : 0.032466837039223574
# Compute control for a deterministic system
# Cost in iteration 0: 0.032466837039223574
# Final cost : 0.032462053375216446
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.6151464448145623
# Final cost : 0.028926102006034383
# Compute control for a deterministic system
# Cost in iteration 0: 0.028926102006034383
# Final cost : 0.028587297475154472
# Compute control for a deterministic system
# Cost in iteration 0: 0.028587297475154472
# Final cost : 0.02855333171777806
# Compute control for a deterministic system
# Cost in iteration 0: 0.02855333171777806
# Final cost : 0.028534371916134244
# Compute control for a deterministic system
# Cost in iteration 0: 0.028534371916134244
# Final cost : 0.02852622581071536
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.2801897052254228
# Final cost : 0.024960432384257207
# Compute control for a deterministic system
# Cost in iteration 0: 0.024960432384257207
# Final cost : 0.024815493693438936
# Compute control for a deterministic system
# Cost in iteration 0: 0.024815493693438936
# Final cost : 0.02478091977793111
# Compute control for a deterministic system
# Cost in iteration 0: 0.02478091977793111
# Final cost : 0.024760444378314858
# Compute control for a deterministic system
# Cost in iteration 0: 0.024760444378314858
# Final cost : 0.02475244698301533
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.6169855671278512
# Final cost : 0.021651592349604447
# Compute control for a deterministic system
# Cost in iteration 0: 0.021651592349604447
# Final cost : 0.021385608012783875
# Compute control for a deterministic system
# Cost in iteration 0: 0.021385608012783875
# Final cost : 0.021358199473011825
# Compute control for a deterministic system
# Cost in iteration 0: 0.021358199473011825
# Final cost : 0.021344754627835087
# Compute control for a deterministic system
# Cost in iteration 0: 0.021344754627835087
# Final cost : 0.021340247661226497
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.19812725901283265
# Final cost : 0.018265576708450287
# Compute control for a deterministic system
# Cost in iteration 0: 0.018265576708450287
# Final cost : 0.018137050475867236
# Compute control for a deterministic system
# Cost in iteration 0: 0.018137050475867236
# Final cost : 0.01811907717508329
# Compute control for a deterministic system
# Cost in iteration 0: 0.01811907717508329
# Final cost : 0.018108845626631537
# Compute control for a deterministic system
# Cost in iteration 0: 0.018108845626631537
# Final cost : 0.018105651422636405
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.5666951549710604
# Final cost : 0.015407470804013362
# Compute control for a deterministic system
# Cost in iteration 0: 0.015407470804013362
# Final cost : 0.015246037773356449
# Compute control for a deterministic system
# Cost in iteration 0: 0.015246037773356449
# Final cost : 0.015228141026433146
# Compute control for a deterministic system
# Cost in iteration 0: 0.015228141026433146
# Final cost : 0.015218698942818448
# Compute control for a deterministic system
# Cost in iteration 0: 0.015218698942818448
# Final cost : 0.015218206936410227
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.10800972096725986
# Final cost : 0.012628923750397085
# Compute control for a deterministic system
# Cost in iteration 0: 0.012628923750397085
# Final cost : 0.012543628947372461
# Compute control for a deterministic system
# Cost in iteration 0: 0.012543628947372461
# Final cost : 0.0125287749259815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0125287749259815
# Final cost : 0.01252156748567959
# Compute control for a deterministic system
# Cost in iteration 0: 0.01252156748567959
# Final cost : 0.012520200143432721
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# ...
# Final cost : 0.020820482907238612
# Compute control for a deterministic system
# Cost in iteration 0: 0.020820482907238612
# Final cost : 0.020417333853419584
# Compute control for a deterministic system
# Cost in iteration 0: 0.020417333853419584
# Final cost : 0.02029875136164893
# Compute control for a deterministic system
# Cost in iteration 0: 0.02029875136164893
# Final cost : 0.020273527887908416
# Compute control for a deterministic system
# Cost in iteration 0: 6.18326080316554
# Final cost : 0.034882108791545886
# Compute control for a deterministic system
# Cost in iteration 0: 0.034882108791545886
# Final cost : 0.024271961597854014
# Compute control for a deterministic system
# Cost in iteration 0: 0.024271961597854014
# Final cost : 0.023706036076064474
# Compute control for a deterministic system
# Cost in iteration 0: 0.023706036076064474
# Final cost : 0.02353700489875582
# Compute control for a deterministic system
# Cost in iteration 0: 0.02353700489875582
# Final cost : 0.023488450284901454
# Compute control for a deterministic system
# Cost in iteration 0: 6.499433831055251
# Final cost : 0.03810930359919958
# Compute control for a deterministic system
# Cost in iteration 0: 0.03810930359919958
# Final cost : 0.027607251614412208
# Compute control for a deterministic system
# Cost in iteration 0: 0.027607251614412208
# Final cost : 0.027086088452544777
# Compute control for a deterministic system
# Cost in iteration 0: 0.027086088452544777
# Final cost : 0.026900457905776106
# Compute control for a deterministic system
# Cost in iteration 0: 0.026900457905776106
# Final cost : 0.0268490544576251
# Compute control for a deterministic system
# Cost in iteration 0: 6.9357137189003115
# Final cost : 0.04928478040173835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04928478040173835
# Final cost : 0.03192887497014763
# Compute control for a deterministic system
# Cost in iteration 0: 0.03192887497014763
# Final cost : 0.031088538073454516
# Compute control for a deterministic system
# Cost in iteration 0: 0.031088538073454516
# Final cost : 0.030664750259638662
# Compute control for a deterministic system
# Cost in iteration 0: 0.030664750259638662
# Final cost : 0.03054108850298477
# Compute control for a deterministic system
# Cost in iteration 0: 7.174954625397919
# Final cost : 0.05448327737544608
# Compute control for a deterministic system
# Cost in iteration 0: 0.05448327737544608
# Final cost : 0.03584046494651525
# Compute control for a deterministic system
# Cost in iteration 0: 0.03584046494651525
# Final cost : 0.03496745410465837
# Compute control for a deterministic system
# Cost in iteration 0: 0.03496745410465837
# Final cost : 0.03451631367710541
# Compute control for a deterministic system
# Cost in iteration 0: 0.03451631367710541
# Final cost : 0.03436909391433441
# Compute control for a deterministic system
# Cost in iteration 0: 7.372252407533531
# Final cost : 0.06398210397202782
# Compute control for a deterministic system
# Cost in iteration 0: 0.06398210397202782
# Final cost : 0.04045965672241421
# Compute control for a deterministic system
# Cost in iteration 0: 0.04045965672241421
# Final cost : 0.03933670403624738
# Compute control for a deterministic system
# Cost in iteration 0: 0.03933670403624738
# Final cost : 0.03873648514208112
# Compute control for a deterministic system
# Cost in iteration 0: 0.03873648514208112
# Final cost : 0.0385404473053435
# Compute control for a deterministic system
# Cost in iteration 0: 7.4830901964630225
# Final cost : 0.0787647155214719
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787647155214719
# Final cost : 0.04583947995065359
# Compute control for a deterministic system
# Cost in iteration 0: 0.04583947995065359
# Final cost : 0.043964507355019694
# Compute control for a deterministic system
# Cost in iteration 0: 0.043964507355019694
# Final cost : 0.043125607542096975
# Compute control for a deterministic system
# Cost in iteration 0: 0.043125607542096975
# Final cost : 0.042837309006087204
# Compute control for a deterministic system
# Cost in iteration 0: 7.507822302639194
# Final cost : 0.08042922842546069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08042922842546069
# Final cost : 0.04994918415465566
# Compute control for a deterministic system
# Cost in iteration 0: 0.04994918415465566
# Final cost : 0.04853773598695908
# Compute control for a deterministic system
# Cost in iteration 0: 0.04853773598695908
# Final cost : 0.04775740811450592
# Compute control for a deterministic system
# Cost in iteration 0: 0.04775740811450592
# Final cost : 0.047471191968787727
# Compute control for a deterministic system
# Cost in iteration 0: 7.452156419089798
# Final cost : 0.08622091755633558
# Compute control for a deterministic system
# Cost in iteration 0: 0.08622091755633558
# Final cost : 0.04920598515496759
# Compute control for a deterministic system
# Cost in iteration 0: 0.04920598515496759
# Final cost : 0.04706370119921042
# Compute control for a deterministic system
# Cost in iteration 0: 0.04706370119921042
# Final cost : 0.046276398447357855
# Compute control for a deterministic system
# Cost in iteration 0: 0.046276398447357855
# Final cost : 0.046074242427800664
# Compute control for a deterministic system
# Cost in iteration 0: 7.309349179030767
# Final cost : 0.06992738627724368
# Compute control for a deterministic system
# Cost in iteration 0: 0.06992738627724368
# Final cost : 0.04324711839030917
# Compute control for a deterministic system
# Cost in iteration 0: 0.04324711839030917
# Final cost : 0.04200121822554224
# Compute control for a deterministic system
# Cost in iteration 0: 0.04200121822554224
# Final cost : 0.041391470543580465
# Compute control for a deterministic system
# Cost in iteration 0: 0.041391470543580465
# Final cost : 0.041229823916686024
# Compute control for a deterministic system
# Cost in iteration 0: 7.087428415714092
# Final cost : 0.05884970338200483
# Compute control for a deterministic system
# Cost in iteration 0: 0.05884970338200483
# Final cost : 0.03827664681204101
# Compute control for a deterministic system
# Cost in iteration 0: 0.03827664681204101
# Final cost : 0.037349517788010864
# Compute control for a deterministic system
# Cost in iteration 0: 0.037349517788010864
# Final cost : 0.03689726761279736
# Compute control for a deterministic system
# Cost in iteration 0: 0.03689726761279736
# Final cost : 0.03677695605593966
# Compute control for a deterministic system
# Cost in iteration 0: 6.79030150759046
# Final cost : 0.05055878325752444
# Compute control for a deterministic system
# Cost in iteration 0: 0.05055878325752444
# Final cost : 0.033674708689879256
# Compute control for a deterministic system
# Cost in iteration 0: 0.033674708689879256
# Final cost : 0.032921769083478436
# Compute control for a deterministic system
# Cost in iteration 0: 0.032921769083478436
# Final cost : 0.032562287358205724
# Compute control for a deterministic system
# Cost in iteration 0: 0.032562287358205724
# Final cost : 0.032465261063271626
# Compute control for a deterministic system
# Cost in iteration 0: 6.466453323736584
# Final cost : 0.04488933768088835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04488933768088835
# Final cost : 0.02962419999767565
# Compute control for a deterministic system
# Cost in iteration 0: 0.02962419999767565
# Final cost : 0.028908984032582862
# Compute control for a deterministic system
# Cost in iteration 0: 0.028908984032582862
# Final cost : 0.02860794942276017
# Compute control for a deterministic system
# Cost in iteration 0: 0.02860794942276017
# Final cost : 0.028527840846893377
# Compute control for a deterministic system
# Cost in iteration 0: 5.953792855039892
# Final cost : 0.03511503809980906
# Compute control for a deterministic system
# Cost in iteration 0: 0.03511503809980906
# Final cost : 0.02541094706944031
# Compute control for a deterministic system
# Cost in iteration 0: 0.02541094706944031
# Final cost : 0.024919632197313444
# Compute control for a deterministic system
# Cost in iteration 0: 0.024919632197313444
# Final cost : 0.024789122461799765
# Compute control for a deterministic system
# Cost in iteration 0: 0.024789122461799765
# Final cost : 0.024752905538982198
# Compute control for a deterministic system
# Cost in iteration 0: 5.390356317698066
# Final cost : 0.028451614455114592
# Compute control for a deterministic system
# Cost in iteration 0: 0.028451614455114592
# Final cost : 0.021795228984270904
# Compute control for a deterministic system
# Cost in iteration 0: 0.021795228984270904
# Final cost : 0.021435733865107564
# Compute control for a deterministic system
# Cost in iteration 0: 0.021435733865107564
# Final cost : 0.021359978030707504
# Compute control for a deterministic system
# Cost in iteration 0: 0.021359978030707504
# Final cost : 0.02134027776554394
# Compute control for a deterministic system
# Cost in iteration 0: 4.9560187837562815
# Final cost : 0.02447523014221329
# Compute control for a deterministic system
# Cost in iteration 0: 0.02447523014221329
# Final cost : 0.018525810353258995
# Compute control for a deterministic system
# Cost in iteration 0: 0.018525810353258995
# Final cost : 0.018188798624037293
# Compute control for a deterministic system
# Cost in iteration 0: 0.018188798624037293
# Final cost : 0.018121006978994558
# Compute control for a deterministic system
# Cost in iteration 0: 0.018121006978994558
# Final cost : 0.01810567042387701
# Compute control for a deterministic system
# Cost in iteration 0: 4.271239810532722
# Final cost : 0.019259777626945643
# Compute control for a deterministic system
# Cost in iteration 0: 0.019259777626945643
# Final cost : 0.01550061831277585
# Compute control for a deterministic system
# Cost in iteration 0: 0.01550061831277585
# Final cost : 0.015267725772168648
# Compute control for a deterministic system
# Cost in iteration 0: 0.015267725772168648
# Final cost : 0.015226328502854459
# Compute control for a deterministic system
# Cost in iteration 0: 0.015226328502854459
# Final cost : 0.015218219659202148
# Compute control for a deterministic system
# Cost in iteration 0: 3.706094140016227
# Final cost : 0.015532674991768755
# Compute control for a deterministic system
# Cost in iteration 0: 0.015532674991768755
# Final cost : 0.01274339473486468
# Compute control for a deterministic system
# Cost in iteration 0: 0.01274339473486468
# Final cost : 0.012559395435008622
# Compute control for a deterministic system
# Cost in iteration 0: 0.012559395435008622
# Final cost : 0.012525677869706684
# Compute control for a deterministic system
# Cost in iteration 0: 0.012525677869706684
# Final cost : 0.012520203366428236
# Compute control for a deterministic system
# Cost in iteration 0: 3.1548932112704207
# Final cost : 0.012334320812963383
# Compute control for a deterministic system
# Cost in iteration 0: 0.012334320812963383
# Final cost : 0.010320437463423465
# Compute control for a deterministic system
# Cost in iteration 0: 0.010320437463423465
# Final cost : 0.010176824130960197
# Compute control for a deterministic system
# Cost in iteration 0: 0.010176824130960197
# Final cost : 0.010154409280691518
# Compute control for a deterministic system
# Cost in iteration 0: 0.010154409280691518
# Final cost : 0.01015158125564161
# Compute control for a deterministic system
# Cost in iteration 0: 2.6280630942293155
# Final cost : 0.00953330615911713
# Compute control for a deterministic system
# Cost in iteration 0: 0.00953330615911713
# Final cost : 0.008107320483766608
# Compute control for a deterministic system
# Cost in iteration 0: 0.008107320483766608
# Final cost : 0.00799896031735366
# Compute control for a deterministic system
# Cost in iteration 0: 0.00799896031735366
# Final cost : 0.007983830413633852
# Compute control for a deterministic system
# Cost in iteration 0: 0.007983830413633852
# Final cost : 0.007982051766347526
# Compute control for a deterministic system
# Cost in iteration 0: 2.130390546139899
# Final cost : 0.007174336175410075
# Compute control for a deterministic system
# Cost in iteration 0: 0.007174336175410075
# Final cost : 0.006214731695386208
# Compute control for a deterministic system
# Cost in iteration 0: 0.006214731695386208
# Final cost : 0.006134271797764819
# Compute control for a deterministic system
# Cost in iteration 0: 0.006134271797764819
# Final cost : 0.006124624098121004
# Compute control for a deterministic system
# Cost in iteration 0: 0.006124624098121004
# Final cost : 0.0061236940261955915
# Compute control for a deterministic system
# Cost in iteration 0: 1.643367653211037
# Final cost : 0.005125207044477835
# Compute control for a deterministic system
# Cost in iteration 0: 0.005125207044477835
# Final cost : 0.004535421164724178
# Compute control for a deterministic system
# Cost in iteration 0: 0.004535421164724178
# Final cost : 0.004480729853795039
# Compute control for a deterministic system
# Cost in iteration 0: 0.004480729853795039
# Final cost : 0.004474507106977693
# Compute control for a deterministic system
# Cost in iteration 0: 0.004474507106977693
# Final cost : 0.0044740624068085955
# Compute control for a deterministic system
# Cost in iteration 0: 1.2052190381752377
# Final cost : 0.0034879079469750623
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034879079469750623
# Final cost : 0.003156787581427729
# Compute control for a deterministic system
# Cost in iteration 0: 0.003156787581427729
# Final cost : 0.0031222066132447985
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031222066132447985
# Final cost : 0.003118503753870814
# Compute control for a deterministic system
# Cost in iteration 0: 0.003118503753870814
# Final cost : 0.0031182748104600718
# Compute control for a deterministic system
# Cost in iteration 0: 0.810306514449254
# Final cost : 0.0021622440047445635
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021622440047445635
# Final cost : 0.00200225617339691
# Compute control for a deterministic system
# Cost in iteration 0: 0.00200225617339691
# Final cost : 0.0019835159213068498
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019835159213068498
# Final cost : 0.001981597604197917
# Compute control for a deterministic system
# Cost in iteration 0: 0.001981597604197917
# Final cost : 0.001981506294100921
# Compute control for a deterministic system
# Cost in iteration 0: 0.4273444422065731
# Final cost : 0.0011791545024776558
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011791545024776558
# Final cost : 0.001129249677776233
# Compute control for a deterministic system
# Cost in iteration 0: 0.001129249677776233
# Final cost : 0.0011230596072356795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011230596072356795
# Final cost : 0.0011223278228566706
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011223278228566706
# Final cost : 0.0011222984655195544
# Compute control for a deterministic system
# Cost in iteration 0: 0.18576958638070817
# Final cost : 0.0005068619268004825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005068619268004825
# Final cost : 0.0004945556810871843
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004945556810871843
# Final cost : 0.000493264930427146
# Compute control for a deterministic system
# Cost in iteration 0: 0.000493264930427146
# Final cost : 0.0004930510560429126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004930510560429126
# Converged in iteration 979 with cost 0.0004930436788286445 because of step counter
# Final cost : 0.0004930436788286445
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.04852107111277974
# Final cost : 0.00012772477360457554
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012772477360457554
# Final cost : 0.0001259725682144167
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001259725682144167
# Final cost : 0.00012588482185373455
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012588482185373455
# Final cost : 0.00012586933578811766
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012586933578811766
# Converged in iteration 655 with cost 0.00012586883089717318 because of step counter
# Final cost : 0.00012586883089717318

# %%
save(results_min)
