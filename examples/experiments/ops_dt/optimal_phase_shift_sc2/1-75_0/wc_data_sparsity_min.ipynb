# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.01
wc.params.dt = dt

duration = 600.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.16789760468071255 
y_init = 0.34689637900179876
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,936], wc.inh[0,936]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(400,-1,1)
plt.show()
# Out:
# 0.17015079995392576 0.3442890159451902
# minima =  [ 1004  2504  4004  5504  7004  8503 10003 11503 13003 14503 16003 17502
#  19002 20502 22002 23502 25001 26501 28001 29501 31001 32501 34000 35500
#  37000 38500 40000 41500 42999 44499 45999 47499 48999 50499 51998 53498
#  54998 56498 57998 59498]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 40000, None

duration = 500.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1., w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("d_s3_l1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("d_s3_l1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 results_min = read()
#
# Cell In [6], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("d_s3_l1.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd_s3_l1.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]#*np.random.random()

        for i_shift in range(n_points):

            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(400)

            increase_step_compute()

            get_values(results_min, i_w, i_shift, w1)
            save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[3]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.055973002971348364
# Final cost : 0.02420153505517031
# Compute control for a deterministic system
# Cost in iteration 0: 0.02420153505517031
# Converged in iteration 100 with cost 0.014943701487359344 because of vanishing difference
# Final cost : 0.014943701487359344
# Compute control for a deterministic system
# Cost in iteration 0: 0.014943701487359344
# Converged in iteration 8 with cost 0.014943701391421479 because of step counter
# Final cost : 0.014943701391421479
# Compute control for a deterministic system
# Cost in iteration 0: 0.014943701391421479
# Converged in iteration 3 with cost 0.014943701391418568 because of step counter
# Final cost : 0.014943701391418568
# Compute control for a deterministic system
# Cost in iteration 0: 0.014943701391418568
# Converged in iteration 2 with cost 0.014943701391415341 because of step counter
# Final cost : 0.014943701391415341
# Compute control for a deterministic system
# Cost in iteration 0: 0.014943701391415341
# Converged in iteration 1 with cost 0.014943701391415341 because of step counter
# Final cost : 0.014943701391415341
# Compute control for a deterministic system
# Cost in iteration 0: 0.22680990812380114
# Final cost : 0.08341497175831028
# Compute control for a deterministic system
# Cost in iteration 0: 0.08341497175831028
# Cost in iteration 200: 0.03155613936778882
# Converged in iteration 383 with cost 0.03155613704109992 because of step counter
# Final cost : 0.03155613704109992
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155613704109992
# Converged in iteration 6 with cost 0.0315561370410512 because of step counter
# Final cost : 0.0315561370410512
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315561370410512
# Converged in iteration 3 with cost 0.03155613704104904 because of step counter
# Final cost : 0.03155613704104904
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155613704104904
# Converged in iteration 1 with cost 0.03155613704104904 because of step counter
# Final cost : 0.03155613704104904
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155613704104904
# Converged in iteration 1 with cost 0.03155613704104904 because of step counter
# Final cost : 0.03155613704104904
# Compute control for a deterministic system
# Cost in iteration 0: 0.4946247517641807
# Final cost : 0.1843170136289793
# Compute control for a deterministic system
# Cost in iteration 0: 0.1843170136289793
# Cost in iteration 200: 0.04778944563613139
# Converged in iteration 325 with cost 0.04778877290087493 because of vanishing difference
# Final cost : 0.04778877290087493
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778877290087493
# Converged in iteration 57 with cost 0.04778876665722179 because of step counter
# Final cost : 0.04778876665722179
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778876665722179
# Converged in iteration 1 with cost 0.04778876665722179 because of step counter
# Final cost : 0.04778876665722179
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778876665722179
# Converged in iteration 1 with cost 0.04778876665722179 because of step counter
# Final cost : 0.04778876665722179
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778876665722179
# Converged in iteration 1 with cost 0.04778876665722179 because of step counter
# Final cost : 0.04778876665722179
# Compute control for a deterministic system
# Cost in iteration 0: 0.8608885708602931
# Final cost : 0.3444710448441233
# Compute control for a deterministic system
# Cost in iteration 0: 0.3444710448441233
# Cost in iteration 200: 0.06450936850666215
# Cost in iteration 400: 0.06450021857673931
# Final cost : 0.06450021857673931
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450021857673931
# Converged in iteration 110 with cost 0.06450015607119859 because of step counter
# Final cost : 0.06450015607119859
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450015607119859
# Converged in iteration 5 with cost 0.06450015607119615 because of vanishing difference
# Final cost : 0.06450015607119615
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450015607119615
# Converged in iteration 3 with cost 0.06450015607119228 because of step counter
# Final cost : 0.06450015607119228
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450015607119228
# Converged in iteration 1 with cost 0.06450015607119228 because of step counter
# Final cost : 0.06450015607119228
# Compute control for a deterministic system
# Cost in iteration 0: 1.2922045315072759
# Final cost : 0.5653875539712759
# Compute control for a deterministic system
# Cost in iteration 0: 0.5653875539712759
# Cost in iteration 200: 0.08084972869854413
# Cost in iteration 400: 0.08079903418968212
# Final cost : 0.08079903418968212
# Compute control for a deterministic system
# Cost in iteration 0: 0.08079903418968212
# Converged in iteration 177 with cost 0.08079787195123866 because of step counter
# Final cost : 0.08079787195123866
# Compute control for a deterministic system
# Cost in iteration 0: 0.08079787195123866
# Converged in iteration 3 with cost 0.08079787195123678 because of step counter
# Final cost : 0.08079787195123678
# Compute control for a deterministic system
# Cost in iteration 0: 0.08079787195123678
# Converged in iteration 2 with cost 0.08079787195123525 because of step counter
# Final cost : 0.08079787195123525
# Compute control for a deterministic system
# Cost in iteration 0: 0.08079787195123525
# Converged in iteration 1 with cost 0.08079787195123525 because of step counter
# Final cost : 0.08079787195123525
# Compute control for a deterministic system
# Cost in iteration 0: 1.7968626459394517
# Final cost : 0.8655423479599261
# Compute control for a deterministic system
# Cost in iteration 0: 0.8655423479599261
# Cost in iteration 200: 0.09774442168540354
# Cost in iteration 400: 0.09756012816548738
# Final cost : 0.09756012816548738
# Compute control for a deterministic system
# Cost in iteration 0: 0.09756012816548738
# Cost in iteration 200: 0.09755106592477238
# Final cost : 0.09755106592477238
# Compute control for a deterministic system
# Cost in iteration 0: 0.09755106592477238
# Converged in iteration 32 with cost 0.09755106592327342 because of vanishing difference
# Final cost : 0.09755106592327342
# Compute control for a deterministic system
# Cost in iteration 0: 0.09755106592327342
# Converged in iteration 30 with cost 0.0975510659230895 because of step counter
# Final cost : 0.0975510659230895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0975510659230895
# Converged in iteration 1 with cost 0.0975510659230895 because of step counter
# Final cost : 0.0975510659230895
# Compute control for a deterministic system
# Cost in iteration 0: 2.3338720379256297
# Final cost : 1.2312744829971045
# Compute control for a deterministic system
# Cost in iteration 0: 1.2312744829971045
# Cost in iteration 200: 0.114358404903397
# Cost in iteration 400: 0.11390051790097766
# Final cost : 0.11390051790097766
# Compute control for a deterministic system
# Cost in iteration 0: 0.11390051790097766
# Cost in iteration 200: 0.11386132258959807
# Final cost : 0.11386132258959807
# Compute control for a deterministic system
# Cost in iteration 0: 0.11386132258959807
# Converged in iteration 124 with cost 0.1138613224177208 because of step counter
# Final cost : 0.1138613224177208
# Compute control for a deterministic system
# Cost in iteration 0: 0.1138613224177208
# Converged in iteration 1 with cost 0.1138613224177208 because of step counter
# Final cost : 0.1138613224177208
# Compute control for a deterministic system
# Cost in iteration 0: 0.1138613224177208
# Converged in iteration 1 with cost 0.1138613224177208 because of step counter
# Final cost : 0.1138613224177208
# Compute control for a deterministic system
# Cost in iteration 0: 2.9172834865437682
# Final cost : 1.6802831310606243
# Compute control for a deterministic system
# Cost in iteration 0: 1.6802831310606243
# Cost in iteration 200: 0.13160998033021193
# Cost in iteration 400: 0.13069241533507378
# Final cost : 0.13069241533507378
# Compute control for a deterministic system
# Cost in iteration 0: 0.13069241533507378
# Converged in iteration 126 with cost 0.13057024056888178 because of vanishing difference
# Final cost : 0.13057024056888178
# Compute control for a deterministic system
# Cost in iteration 0: 0.13057024056888178
# Cost in iteration 200: 0.13056995557025414
# Final cost : 0.13056995557025414
# Compute control for a deterministic system
# Cost in iteration 0: 0.13056995557025414
# Converged in iteration 153 with cost 0.13056995553682282 because of step counter
# Final cost : 0.13056995553682282
# Compute control for a deterministic system
# Cost in iteration 0: 0.13056995553682282
# Converged in iteration 1 with cost 0.13056995553682282 because of step counter
# Final cost : 0.13056995553682282
# Compute control for a deterministic system
# Cost in iteration 0: 3.5016020050709815
# Final cost : 2.1829650857313854
# Compute control for a deterministic system
# Cost in iteration 0: 2.1829650857313854
# Cost in iteration 200: 0.14867313794519632
# Cost in iteration 400: 0.14703829941646013
# Final cost : 0.14703829941646013
# Compute control for a deterministic system
# Cost in iteration 0: 0.14703829941646013
# Cost in iteration 200: 0.146737216284002
# Final cost : 0.146737216284002
# Compute control for a deterministic system
# Cost in iteration 0: 0.146737216284002
# Cost in iteration 200: 0.1467371201909093
# Final cost : 0.1467371201909093
# Compute control for a deterministic system
# Cost in iteration 0: 0.1467371201909093
# Cost in iteration 200: 0.1467371201162927
# Converged in iteration 201 with cost 0.1467371201162927 because of vanishing difference
# Final cost : 0.1467371201162927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1467371201162927
# Converged in iteration 19 with cost 0.14673712011621792 because of step counter
# Final cost : 0.14673712011621792
# Compute control for a deterministic system
# Cost in iteration 0: 4.10307520141059
# Final cost : 2.757037682468657
# Compute control for a deterministic system
# Cost in iteration 0: 2.757037682468657
# Cost in iteration 200: 0.16646617803858307
# Cost in iteration 400: 0.16384788658401409
# Final cost : 0.16384788658401409
# Compute control for a deterministic system
# Cost in iteration 0: 0.16384788658401409
# Converged in iteration 183 with cost 0.16322376952084686 because of vanishing difference
# Final cost : 0.16322376952084686
# Compute control for a deterministic system
# Cost in iteration 0: 0.16322376952084686
# Cost in iteration 200: 0.16322238379004259
# Final cost : 0.16322238379004259
# Compute control for a deterministic system
# Cost in iteration 0: 0.16322238379004259
# Cost in iteration 200: 0.16322238108940268
# Converged in iteration 365 with cost 0.1632223810796424 because of step counter
# Final cost : 0.1632223810796424
# Compute control for a deterministic system
# Cost in iteration 0: 0.1632223810796424
# Converged in iteration 10 with cost 0.163222381079623 because of step counter
# Final cost : 0.163222381079623
# Compute control for a deterministic system
# Cost in iteration 0: 4.675798234049624
# Final cost : 3.3609874362862406
# Compute control for a deterministic system
# Cost in iteration 0: 3.3609874362862406
# Cost in iteration 200: 0.18432251783692688
# Cost in iteration 400: 0.18038708601291614
# Final cost : 0.18038708601291614
# Compute control for a deterministic system
# Cost in iteration 0: 0.18038708601291614
# Cost in iteration 200: 0.17921103746610442
# Final cost : 0.17921103746610442
# Compute control for a deterministic system
# Cost in iteration 0: 0.17921103746610442
# Cost in iteration 200: 0.17920706993492289
# Final cost : 0.17920706993492289
# Compute control for a deterministic system
# Cost in iteration 0: 0.17920706993492289
# Cost in iteration 200: 0.17920705617288638
# Cost in iteration 400: 0.1792070560599635
# Final cost : 0.1792070560599635
# Compute control for a deterministic system
# Cost in iteration 0: 0.1792070560599635
# Converged in iteration 43 with cost 0.1792070560591144 because of step counter
# Final cost : 0.1792070560591144
# Compute control for a deterministic system
# Cost in iteration 0: 5.23679868170237
# Final cost : 4.01340847606977
# Compute control for a deterministic system
# Cost in iteration 0: 4.01340847606977
# Cost in iteration 200: 0.2031862841163159
# Cost in iteration 400: 0.19771363990377394
# Final cost : 0.19771363990377394
# Compute control for a deterministic system
# Cost in iteration 0: 0.19771363990377394
# Cost in iteration 200: 0.19562987816785035
# Final cost : 0.19562987816785035
# Compute control for a deterministic system
# Cost in iteration 0: 0.19562987816785035
# Cost in iteration 200: 0.1956151813550105
# Final cost : 0.1956151813550105
# Compute control for a deterministic system
# Cost in iteration 0: 0.1956151813550105
# Cost in iteration 200: 0.19561505894011533
# Cost in iteration 400: 0.19561505696443687
# Final cost : 0.19561505696443687
# Compute control for a deterministic system
# Cost in iteration 0: 0.19561505696443687
# Converged in iteration 94 with cost 0.19561505693220538 because of step counter
# Final cost : 0.19561505693220538
# Compute control for a deterministic system
# Cost in iteration 0: 5.7440065731754
# Final cost : 4.662953946967395
# Compute control for a deterministic system
# Cost in iteration 0: 4.662953946967395
# Cost in iteration 200: 0.22229445167412729
# Cost in iteration 400: 0.21487897065567244
# Final cost : 0.21487897065567244
# Compute control for a deterministic system
# Cost in iteration 0: 0.21487897065567244
# Cost in iteration 200: 0.2116494982049005
# Final cost : 0.2116494982049005
# Compute control for a deterministic system
# Cost in iteration 0: 0.2116494982049005
# Cost in iteration 200: 0.21161419096507808
# Final cost : 0.21161419096507808
# Compute control for a deterministic system
# Cost in iteration 0: 0.21161419096507808
# Cost in iteration 200: 0.2116137311742332
# Cost in iteration 400: 0.21161371826555553
# Final cost : 0.21161371826555553
# Compute control for a deterministic system
# Cost in iteration 0: 0.21161371826555553
# Converged in iteration 126 with cost 0.21161371789328273 because of vanishing difference
# Final cost : 0.21161371789328273
# Compute control for a deterministic system
# Cost in iteration 0: 6.212970262918845
# Final cost : 5.3218935128410525
# Compute control for a deterministic system
# Cost in iteration 0: 5.3218935128410525
# Cost in iteration 200: 0.2429798766013184
# Cost in iteration 400: 0.23316785734087958
# Final cost : 0.23316785734087958
# Compute control for a deterministic system
# Cost in iteration 0: 0.23316785734087958
# Cost in iteration 200: 0.22816879754096822
# Final cost : 0.22816879754096822
# Compute control for a deterministic system
# Cost in iteration 0: 0.22816879754096822
# Converged in iteration 76 with cost 0.22810039820468653 because of vanishing difference
# Final cost : 0.22810039820468653
# Compute control for a deterministic system
# Cost in iteration 0: 0.22810039820468653
# Cost in iteration 200: 0.22807872772081728
# Cost in iteration 400: 0.2280777910634305
# Final cost : 0.2280777910634305
# Compute control for a deterministic system
# Cost in iteration 0: 0.2280777910634305
# Cost in iteration 200: 0.22807774742450446
# Converged in iteration 300 with cost 0.22807774741207482 because of step counter
# Final cost : 0.22807774741207482
# Compute control for a deterministic system
# Cost in iteration 0: 6.609132810110073
# Final cost : 5.9278845650316745
# Compute control for a deterministic system
# Cost in iteration 0: 5.9278845650316745
# Cost in iteration 200: 0.26414491371866466
# Cost in iteration 400: 0.25164516710120455
# Final cost : 0.25164516710120455
# Compute control for a deterministic system
# Cost in iteration 0: 0.25164516710120455
# Cost in iteration 200: 0.2443249082442934
# Final cost : 0.2443249082442934
# Compute control for a deterministic system
# Cost in iteration 0: 0.2443249082442934
# Cost in iteration 200: 0.244146418538005
# Final cost : 0.244146418538005
# Compute control for a deterministic system
# Cost in iteration 0: 0.244146418538005
# Cost in iteration 200: 0.24413996230114698
# Cost in iteration 400: 0.24413953953476908
# Final cost : 0.24413953953476908
# Compute control for a deterministic system
# Cost in iteration 0: 0.24413953953476908
# Cost in iteration 200: 0.24413950895594774
# Converged in iteration 329 with cost 0.24413950892820982 because of vanishing difference
# Final cost : 0.24413950892820982
# Compute control for a deterministic system
# Cost in iteration 0: 6.945943901240291
# Final cost : 6.4814650201515605
# Compute control for a deterministic system
# Cost in iteration 0: 6.4814650201515605
# Cost in iteration 200: 0.2870362230555489
# Cost in iteration 400: 0.27139714861790837
# Final cost : 0.27139714861790837
# Compute control for a deterministic system
# Cost in iteration 0: 0.27139714861790837
# Cost in iteration 200: 0.2609906774264584
# Final cost : 0.2609906774264584
# Compute control for a deterministic system
# Cost in iteration 0: 0.2609906774264584
# Converged in iteration 95 with cost 0.2607393886866783 because of vanishing difference
# Final cost : 0.2607393886866783
# Compute control for a deterministic system
# Cost in iteration 0: 0.2607393886866783
# Cost in iteration 200: 0.26066832319265487
# Cost in iteration 400: 0.2606621724993072
# Final cost : 0.2606621724993072
# Compute control for a deterministic system
# Cost in iteration 0: 0.2606621724993072
# Cost in iteration 200: 0.26066154093507726
# Cost in iteration 400: 0.26066153945526055
# Converged in iteration 462 with cost 0.2606615394528084 because of step counter
# Final cost : 0.2606615394528084
# Compute control for a deterministic system
# Cost in iteration 0: 7.200486004356526
# Final cost : 6.924226232013234
# Compute control for a deterministic system
# Cost in iteration 0: 6.924226232013234
# Cost in iteration 200: 0.31094195253700735
# Cost in iteration 400: 0.29165922280596734
# Final cost : 0.29165922280596734
# Compute control for a deterministic system
# Cost in iteration 0: 0.29165922280596734
# Cost in iteration 200: 0.27730155136732837
# Final cost : 0.27730155136732837
# Compute control for a deterministic system
# Cost in iteration 0: 0.27730155136732837
# Cost in iteration 200: 0.27680447122366103
# Final cost : 0.27680447122366103
# Compute control for a deterministic system
# Cost in iteration 0: 0.27680447122366103
# Cost in iteration 200: 0.2767717824634273
# Cost in iteration 400: 0.2767678851364459
# Final cost : 0.2767678851364459
# Compute control for a deterministic system
# Cost in iteration 0: 0.2767678851364459
# Cost in iteration 200: 0.2767673301660131
# Cost in iteration 400: 0.27676732809551796
# Converged in iteration 506 with cost 0.27676732808952903 because of step counter
# Final cost : 0.27676732808952903
# Compute control for a deterministic system
# Cost in iteration 0: 7.38349274828695
# Final cost : 7.257259719026068
# Compute control for a deterministic system
# Cost in iteration 0: 7.257259719026068
# Cost in iteration 200: 0.3370696821434356
# Cost in iteration 400: 0.3135302261661952
# Final cost : 0.3135302261661952
# Compute control for a deterministic system
# Cost in iteration 0: 0.3135302261661952
# Cost in iteration 200: 0.29414453289407866
# Final cost : 0.29414453289407866
# Compute control for a deterministic system
# Cost in iteration 0: 0.29414453289407866
# Converged in iteration 175 with cost 0.29340880078928533 because of vanishing difference
# Final cost : 0.29340880078928533
# Compute control for a deterministic system
# Cost in iteration 0: 0.29340880078928533
# Cost in iteration 200: 0.29333391586021235
# Cost in iteration 400: 0.2933226540338829
# Final cost : 0.2933226540338829
# Compute control for a deterministic system
# Cost in iteration 0: 0.2933226540338829
# Cost in iteration 200: 0.2933205341304526
# Cost in iteration 400: 0.293320521503891
# Converged in iteration 577 with cost 0.2933205214526979 because of step counter
# Final cost : 0.2933205214526979
# Compute control for a deterministic system
# Cost in iteration 0: 7.484089032280225
# Final cost : 7.450074324687699
# Compute control for a deterministic system
# Cost in iteration 0: 7.450074324687699
# Cost in iteration 200: 0.3654882721616029
# Cost in iteration 400: 0.33645594588399946
# Final cost : 0.33645594588399946
# Compute control for a deterministic system
# Cost in iteration 0: 0.33645594588399946
# Cost in iteration 200: 0.3106379061524163
# Final cost : 0.3106379061524163
# Compute control for a deterministic system
# Cost in iteration 0: 0.3106379061524163
# Cost in iteration 200: 0.30955638672508556
# Final cost : 0.30955638672508556
# Compute control for a deterministic system
# Cost in iteration 0: 0.30955638672508556
# Cost in iteration 200: 0.30946418621016564
# Cost in iteration 400: 0.3094473847773614
# Final cost : 0.3094473847773614
# Compute control for a deterministic system
# Cost in iteration 0: 0.3094473847773614
# Cost in iteration 200: 0.3094433271610837
# Cost in iteration 400: 0.30944329226951645
# Cost in iteration 600: 0.30944329190850534
# Converged in iteration 695 with cost 0.3094432919042012 because of step counter
# Final cost : 0.3094432919042012
# Compute control for a deterministic system
# Cost in iteration 0: 7.507483371795184
# Final cost : 7.507403630358294
# Compute control for a deterministic system
# Cost in iteration 0: 7.507403630358294
# Cost in iteration 200: 0.4106147879931019
# Cost in iteration 400: 0.3628906108293931
# Final cost : 0.3628906108293931
# Compute control for a deterministic system
# Cost in iteration 0: 0.3628906108293931
# Cost in iteration 200: 0.327714036449928
# Final cost : 0.327714036449928
# Compute control for a deterministic system
# Cost in iteration 0: 0.327714036449928
# Cost in iteration 200: 0.3261657665966714
# Final cost : 0.3261657665966714
# Compute control for a deterministic system
# Cost in iteration 0: 0.3261657665966714
# Cost in iteration 200: 0.32603607444460725
# Cost in iteration 400: 0.3260075929383013
# Final cost : 0.3260075929383013
# Compute control for a deterministic system
# Cost in iteration 0: 0.3260075929383013
# Cost in iteration 200: 0.325999053193422
# Cost in iteration 400: 0.32599889472654503
# Cost in iteration 600: 0.32599888923919484
# Cost in iteration 800: 0.3259988890210942
# Converged in iteration 969 with cost 0.32599888901357854 because of step counter
# Final cost : 0.32599888901357854
# Compute control for a deterministic system
# Cost in iteration 0: 7.452734837594315
# Final cost : 7.435746335091701
# Compute control for a deterministic system
# Cost in iteration 0: 7.435746335091701
# Cost in iteration 200: 0.3769757813419507
# Cost in iteration 400: 0.34625020451649124
# Final cost : 0.34625020451649124
# Compute control for a deterministic system
# Cost in iteration 0: 0.34625020451649124
# Cost in iteration 200: 0.319697430612605
# Final cost : 0.319697430612605
# Compute control for a deterministic system
# Cost in iteration 0: 0.319697430612605
# Converged in iteration 189 with cost 0.3187912888248731 because of vanishing difference
# Final cost : 0.3187912888248731
# Compute control for a deterministic system
# Cost in iteration 0: 0.3187912888248731
# Cost in iteration 200: 0.3187369801480191
# Cost in iteration 400: 0.3187285822300059
# Final cost : 0.3187285822300059
# Compute control for a deterministic system
# Cost in iteration 0: 0.3187285822300059
# Cost in iteration 200: 0.3187269384431418
# Converged in iteration 366 with cost 0.3187269379807098 because of step counter
# Final cost : 0.3187269379807098
# Compute control for a deterministic system
# Cost in iteration 0: 7.317447656389243
# Final cost : 7.224394885129327
# Compute control for a deterministic system
# Cost in iteration 0: 7.224394885129327
# Cost in iteration 200: 0.3472510785718099
# Cost in iteration 400: 0.32202481822103235
# Final cost : 0.32202481822103235
# Compute control for a deterministic system
# Cost in iteration 0: 0.32202481822103235
# Cost in iteration 200: 0.3020579878359093
# Final cost : 0.3020579878359093
# Compute control for a deterministic system
# Cost in iteration 0: 0.3020579878359093
# Cost in iteration 200: 0.30142488734275613
# Final cost : 0.30142488734275613
# Compute control for a deterministic system
# Cost in iteration 0: 0.30142488734275613
# Cost in iteration 200: 0.30139175696710124
# Cost in iteration 400: 0.301387458644935
# Final cost : 0.301387458644935
# Compute control for a deterministic system
# Cost in iteration 0: 0.301387458644935
# Cost in iteration 200: 0.3013868007038092
# Converged in iteration 299 with cost 0.30138680060074796 because of step counter
# Final cost : 0.30138680060074796
# Compute control for a deterministic system
# Cost in iteration 0: 7.109841386629864
# Final cost : 6.888193104989593
# Compute control for a deterministic system
# Cost in iteration 0: 6.888193104989593
# Cost in iteration 200: 0.32052153081929974
# Cost in iteration 400: 0.29985511806800413
# Final cost : 0.29985511806800413
# Compute control for a deterministic system
# Cost in iteration 0: 0.29985511806800413
# Cost in iteration 200: 0.2849487945454285
# Final cost : 0.2849487945454285
# Compute control for a deterministic system
# Cost in iteration 0: 0.2849487945454285
# Converged in iteration 158 with cost 0.2845191778371462 because of vanishing difference
# Final cost : 0.2845191778371462
# Compute control for a deterministic system
# Cost in iteration 0: 0.2845191778371462
# Cost in iteration 200: 0.2844824401031941
# Cost in iteration 400: 0.2844786704794415
# Final cost : 0.2844786704794415
# Compute control for a deterministic system
# Cost in iteration 0: 0.2844786704794415
# Cost in iteration 200: 0.28447821764463066
# Cost in iteration 400: 0.28447821652476296
# Converged in iteration 465 with cost 0.28447821652252825 because of step counter
# Final cost : 0.28447821652252825
# Compute control for a deterministic system
# Cost in iteration 0: 6.821589924630023
# Final cost : 6.422344558530876
# Compute control for a deterministic system
# Cost in iteration 0: 6.422344558530876
# Cost in iteration 200: 0.294741416159201
# Cost in iteration 400: 0.2781008263927291
# Final cost : 0.2781008263927291
# Compute control for a deterministic system
# Cost in iteration 0: 0.2781008263927291
# Cost in iteration 200: 0.2674096465268831
# Final cost : 0.2674096465268831
# Compute control for a deterministic system
# Cost in iteration 0: 0.2674096465268831
# Converged in iteration 55 with cost 0.26722688627582303 because of vanishing difference
# Final cost : 0.26722688627582303
# Compute control for a deterministic system
# Cost in iteration 0: 0.26722688627582303
# Cost in iteration 200: 0.26712002253905814
# Cost in iteration 400: 0.26711207420588745
# Final cost : 0.26711207420588745
# Compute control for a deterministic system
# Cost in iteration 0: 0.26711207420588745
# Cost in iteration 200: 0.2671113655584447
# Converged in iteration 319 with cost 0.2671113655257733 because of step counter
# Final cost : 0.2671113655257733
# Compute control for a deterministic system
# Cost in iteration 0: 6.472808603067905
# Final cost : 5.874046506057012
# Compute control for a deterministic system
# Cost in iteration 0: 5.874046506057012
# Cost in iteration 200: 0.2712455578468346
# Cost in iteration 400: 0.25792256757063303
# Final cost : 0.25792256757063303
# Compute control for a deterministic system
# Cost in iteration 0: 0.25792256757063303
# Cost in iteration 200: 0.25038586170195953
# Final cost : 0.25038586170195953
# Compute control for a deterministic system
# Cost in iteration 0: 0.25038586170195953
# Cost in iteration 200: 0.25022569565787184
# Final cost : 0.25022569565787184
# Compute control for a deterministic system
# Cost in iteration 0: 0.25022569565787184
# Cost in iteration 200: 0.2502197085222155
# Cost in iteration 400: 0.2502193519332877
# Final cost : 0.2502193519332877
# Compute control for a deterministic system
# Cost in iteration 0: 0.2502193519332877
# Cost in iteration 200: 0.2502193289649946
# Converged in iteration 275 with cost 0.2502193289596384 because of step counter
# Final cost : 0.2502193289596384
# Compute control for a deterministic system
# Cost in iteration 0: 6.051673919230707
# Final cost : 5.244917074779554
# Compute control for a deterministic system
# Cost in iteration 0: 5.244917074779554
# Cost in iteration 200: 0.24833019342949514
# Cost in iteration 400: 0.23808859490265644
# Final cost : 0.23808859490265644
# Compute control for a deterministic system
# Cost in iteration 0: 0.23808859490265644
# Cost in iteration 200: 0.23298740985882027
# Final cost : 0.23298740985882027
# Compute control for a deterministic system
# Cost in iteration 0: 0.23298740985882027
# Converged in iteration 26 with cost 0.23295290019040812 because of vanishing difference
# Final cost : 0.23295290019040812
# Compute control for a deterministic system
# Cost in iteration 0: 0.23295290019040812
# Cost in iteration 200: 0.23290228373393423
# Cost in iteration 400: 0.23290040100943118
# Final cost : 0.23290040100943118
# Compute control for a deterministic system
# Cost in iteration 0: 0.23290040100943118
# Cost in iteration 200: 0.2329003218737786
# Converged in iteration 281 with cost 0.23290032186483056 because of step counter
# Final cost : 0.23290032186483056
# Compute control for a deterministic system
# Cost in iteration 0: 5.588840388888546
# Final cost : 4.599992308501219
# Compute control for a deterministic system
# Cost in iteration 0: 4.599992308501219
# Cost in iteration 200: 0.22724309037645332
# Cost in iteration 400: 0.21944185453807502
# Final cost : 0.21944185453807502
# Compute control for a deterministic system
# Cost in iteration 0: 0.21944185453807502
# Cost in iteration 200: 0.21611255945187124
# Final cost : 0.21611255945187124
# Compute control for a deterministic system
# Cost in iteration 0: 0.21611255945187124
# Cost in iteration 200: 0.21607734623157884
# Final cost : 0.21607734623157884
# Compute control for a deterministic system
# Cost in iteration 0: 0.21607734623157884
# Cost in iteration 200: 0.21607691331255394
# Cost in iteration 400: 0.21607690254785974
# Final cost : 0.21607690254785974
# Compute control for a deterministic system
# Cost in iteration 0: 0.21607690254785974
# Converged in iteration 141 with cost 0.21607690227314255 because of vanishing difference
# Final cost : 0.21607690227314255
# Compute control for a deterministic system
# Cost in iteration 0: 5.06964841575295
# Final cost : 3.933683248476641
# Compute control for a deterministic system
# Cost in iteration 0: 3.933683248476641
# Cost in iteration 200: 0.20663609107120923
# Cost in iteration 400: 0.20091281883325599
# Final cost : 0.20091281883325599
# Compute control for a deterministic system
# Cost in iteration 0: 0.20091281883325599
# Cost in iteration 200: 0.19885979392080047
# Final cost : 0.19885979392080047
# Compute control for a deterministic system
# Cost in iteration 0: 0.19885979392080047
# Converged in iteration 13 with cost 0.19885712400238792 because of vanishing difference
# Final cost : 0.19885712400238792
# Compute control for a deterministic system
# Cost in iteration 0: 0.19885712400238792
# Cost in iteration 200: 0.198848625998617
# Cost in iteration 400: 0.1988485146261169
# Final cost : 0.1988485146261169
# Compute control for a deterministic system
# Cost in iteration 0: 0.1988485146261169
# Converged in iteration 172 with cost 0.1988485131073932 because of step counter
# Final cost : 0.1988485131073932
# Compute control for a deterministic system
# Cost in iteration 0: 4.5324890810339
# Final cost : 3.3033409237574936
# Compute control for a deterministic system
# Cost in iteration 0: 3.3033409237574936
# Cost in iteration 200: 0.1873743239511472
# Cost in iteration 400: 0.18332708896833327
# Final cost : 0.18332708896833327
# Compute control for a deterministic system
# Cost in iteration 0: 0.18332708896833327
# Cost in iteration 200: 0.1821283991776304
# Final cost : 0.1821283991776304
# Compute control for a deterministic system
# Cost in iteration 0: 0.1821283991776304
# Cost in iteration 200: 0.18212489592956
# Final cost : 0.18212489592956
# Compute control for a deterministic system
# Cost in iteration 0: 0.18212489592956
# Cost in iteration 200: 0.18212488717379136
# Cost in iteration 400: 0.18212488711890193
# Final cost : 0.18212488711890193
# Compute control for a deterministic system
# Cost in iteration 0: 0.18212488711890193
# Converged in iteration 35 with cost 0.18212488711855773 because of step counter
# Final cost : 0.18212488711855773
# Compute control for a deterministic system
# Cost in iteration 0: 3.960392025547704
# Final cost : 2.692225757857224
# Compute control for a deterministic system
# Cost in iteration 0: 2.692225757857224
# Cost in iteration 200: 0.16829246210049723
# Cost in iteration 400: 0.16563024376922472
# Final cost : 0.16563024376922472
# Compute control for a deterministic system
# Cost in iteration 0: 0.16563024376922472
# Converged in iteration 99 with cost 0.1650207650528707 because of vanishing difference
# Final cost : 0.1650207650528707
# Compute control for a deterministic system
# Cost in iteration 0: 0.1650207650528707
# Cost in iteration 200: 0.16500142203719628
# Final cost : 0.16500142203719628
# Compute control for a deterministic system
# Cost in iteration 0: 0.16500142203719628
# Cost in iteration 200: 0.16500140481488723
# Converged in iteration 396 with cost 0.16500140477154698 because of step counter
# Final cost : 0.16500140477154698
# Compute control for a deterministic system
# Cost in iteration 0: 0.16500140477154698
# Converged in iteration 1 with cost 0.16500140477154698 because of step counter
# Final cost : 0.16500140477154698
# Compute control for a deterministic system
# Cost in iteration 0: 3.395368490893563
# Final cost : 2.1450293848589954
# Compute control for a deterministic system
# Cost in iteration 0: 2.1450293848589954
# Cost in iteration 200: 0.15029714971066088
# Cost in iteration 400: 0.14867019818037525
# Final cost : 0.14867019818037525
# Compute control for a deterministic system
# Cost in iteration 0: 0.14867019818037525
# Converged in iteration 161 with cost 0.14837745107217215 because of vanishing difference
# Final cost : 0.14837745107217215
# Compute control for a deterministic system
# Cost in iteration 0: 0.14837745107217215
# Cost in iteration 200: 0.14837694260707257
# Final cost : 0.14837694260707257
# Compute control for a deterministic system
# Cost in iteration 0: 0.14837694260707257
# Converged in iteration 190 with cost 0.14837694251175904 because of step counter
# Final cost : 0.14837694251175904
# Compute control for a deterministic system
# Cost in iteration 0: 0.14837694251175904
# Converged in iteration 4 with cost 0.14837694251165184 because of step counter
# Final cost : 0.14837694251165184
# Compute control for a deterministic system
# Cost in iteration 0: 2.8193547054855475
# Final cost : 1.6419827561174782
# Compute control for a deterministic system
# Cost in iteration 0: 1.6419827561174782
# Cost in iteration 200: 0.1323949075336992
# Cost in iteration 400: 0.13146770157418627
# Final cost : 0.13146770157418627
# Compute control for a deterministic system
# Cost in iteration 0: 0.13146770157418627
# Converged in iteration 134 with cost 0.13135024603223353 because of vanishing difference
# Final cost : 0.13135024603223353
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135024603223353
# Cost in iteration 200: 0.13135007798014955
# Final cost : 0.13135007798014955
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135007798014955
# Converged in iteration 79 with cost 0.13135007797614354 because of step counter
# Final cost : 0.13135007797614354
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135007797614354
# Converged in iteration 1 with cost 0.13135007797614354 because of step counter
# Final cost : 0.13135007797614354
# Compute control for a deterministic system
# Cost in iteration 0: 2.2748816459352805
# Final cost : 1.2165245921795547
# Compute control for a deterministic system
# Cost in iteration 0: 1.2165245921795547
# Cost in iteration 200: 0.11530382729275539
# Cost in iteration 400: 0.11485285623163262
# Final cost : 0.11485285623163262
# Compute control for a deterministic system
# Cost in iteration 0: 0.11485285623163262
# Converged in iteration 115 with cost 0.11481498416364294 because of vanishing difference
# Final cost : 0.11481498416364294
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481498416364294
# Cost in iteration 200: 0.11481493007574745
# Final cost : 0.11481493007574745
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481493007574745
# Converged in iteration 31 with cost 0.11481493007563306 because of step counter
# Final cost : 0.11481493007563306
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481493007563306
# Converged in iteration 1 with cost 0.11481493007563306 because of step counter
# Final cost : 0.11481493007563306
# Compute control for a deterministic system
# Cost in iteration 0: 1.7454643895416961
# Final cost : 0.8502867290162834
# Compute control for a deterministic system
# Cost in iteration 0: 0.8502867290162834
# Cost in iteration 200: 0.09806408833061851
# Cost in iteration 400: 0.09788547794148081
# Final cost : 0.09788547794148081
# Compute control for a deterministic system
# Cost in iteration 0: 0.09788547794148081
# Converged in iteration 40 with cost 0.09787731744207394 because of vanishing difference
# Final cost : 0.09787731744207394
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787731744207394
# Cost in iteration 200: 0.09787686175205809
# Final cost : 0.09787686175205809
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787686175205809
# Converged in iteration 7 with cost 0.09787686175203553 because of step counter
# Final cost : 0.09787686175203553
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787686175203553
# Converged in iteration 1 with cost 0.09787686175203553 because of step counter
# Final cost : 0.09787686175203553
# Compute control for a deterministic system
# Cost in iteration 0: 1.2718821292136762
# Final cost : 0.5641320992847213
# Compute control for a deterministic system
# Cost in iteration 0: 0.5641320992847213
# Cost in iteration 200: 0.08148283319927657
# Cost in iteration 400: 0.08142947326589718
# Final cost : 0.08142947326589718
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142947326589718
# Converged in iteration 187 with cost 0.08142825336555874 because of step counter
# Final cost : 0.08142825336555874
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142825336555874
# Converged in iteration 9 with cost 0.08142825336554646 because of step counter
# Final cost : 0.08142825336554646
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142825336554646
# Converged in iteration 2 with cost 0.08142825336554574 because of step counter
# Final cost : 0.08142825336554574
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142825336554574
# Converged in iteration 1 with cost 0.08142825336554574 because of step counter
# Final cost : 0.08142825336554574
# Compute control for a deterministic system
# Cost in iteration 0: 0.8425488395436342
# Final cost : 0.3406998824318906
# Compute control for a deterministic system
# Cost in iteration 0: 0.3406998824318906
# Cost in iteration 200: 0.06459202892246765
# Cost in iteration 400: 0.0645833650185121
# Final cost : 0.0645833650185121
# Compute control for a deterministic system
# Cost in iteration 0: 0.0645833650185121
# Converged in iteration 105 with cost 0.06458331085214199 because of step counter
# Final cost : 0.06458331085214199
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458331085214199
# Converged in iteration 2 with cost 0.06458331085213974 because of step counter
# Final cost : 0.06458331085213974
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458331085213974
# Converged in iteration 1 with cost 0.06458331085213974 because of step counter
# Final cost : 0.06458331085213974
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458331085213974
# Converged in iteration 1 with cost 0.06458331085213974 because of step counter
# Final cost : 0.06458331085213974
# Compute control for a deterministic system
# Cost in iteration 0: 0.4943368981781017
# Final cost : 0.18617608244351608
# Compute control for a deterministic system
# Cost in iteration 0: 0.18617608244351608
# Cost in iteration 200: 0.04823539003899079
# Converged in iteration 309 with cost 0.04823483917432859 because of vanishing difference
# Final cost : 0.04823483917432859
# Compute control for a deterministic system
# Cost in iteration 0: 0.04823483917432859
# Converged in iteration 65 with cost 0.04823482845941224 because of step counter
# Final cost : 0.04823482845941224
# Compute control for a deterministic system
# Cost in iteration 0: 0.04823482845941224
# Converged in iteration 7 with cost 0.04823482845940654 because of step counter
# Final cost : 0.04823482845940654
# Compute control for a deterministic system
# Cost in iteration 0: 0.04823482845940654
# Converged in iteration 3 with cost 0.048234828459404015 because of step counter
# Final cost : 0.048234828459404015
# Compute control for a deterministic system
# Cost in iteration 0: 0.048234828459404015
# Converged in iteration 1 with cost 0.048234828459404015 because of step counter
# Final cost : 0.048234828459404015
# Compute control for a deterministic system
# Cost in iteration 0: 0.22359199005515515
# Final cost : 0.08281938746637987
# Compute control for a deterministic system
# Cost in iteration 0: 0.08281938746637987
# Converged in iteration 186 with cost 0.0315100550755721 because of vanishing difference
# Final cost : 0.0315100550755721
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315100550755721
# Converged in iteration 29 with cost 0.0315100489673659 because of step counter
# Final cost : 0.0315100489673659
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315100489673659
# Converged in iteration 9 with cost 0.03151004896734975 because of step counter
# Final cost : 0.03151004896734975
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004896734975
# Converged in iteration 1 with cost 0.03151004896734975 because of step counter
# Final cost : 0.03151004896734975
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004896734975
# Converged in iteration 1 with cost 0.03151004896734975 because of step counter
# Final cost : 0.03151004896734975
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821085337444422
# Final cost : 0.025057874526362954
# Compute control for a deterministic system
# Cost in iteration 0: 0.025057874526362954
# Converged in iteration 99 with cost 0.015307043482000765 because of vanishing difference
# Final cost : 0.015307043482000765
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307043482000765
# Converged in iteration 9 with cost 0.015307043268788054 because of step counter
# Final cost : 0.015307043268788054
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307043268788054
# Converged in iteration 1 with cost 0.015307043268788054 because of step counter
# Final cost : 0.015307043268788054
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307043268788054
# Converged in iteration 1 with cost 0.015307043268788054 because of step counter
# Final cost : 0.015307043268788054
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307043268788054
# Converged in iteration 1 with cost 0.015307043268788054 because of step counter
# Final cost : 0.015307043268788054
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# Compute control for a deterministic system
# Cost in iteration 0: 1.183431945692681e-06
# Converged in iteration 1 with cost 1.183431945692681e-06 because of step counter
# Final cost : 1.183431945692681e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09367091318117181
# Cost in iteration 200: 0.03155613860770726
# Final cost : 0.03155613860770726
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155613860770726
# Converged in iteration 28 with cost 0.031556137026823285 because of step counter
# Final cost : 0.031556137026823285
# Compute control for a deterministic system
# Cost in iteration 0: 0.031556137026823285
# Converged in iteration 1 with cost 0.031556137026823285 because of step counter
# Final cost : 0.031556137026823285
# Compute control for a deterministic system
# Cost in iteration 0: 0.031556137026823285
# Converged in iteration 1 with cost 0.031556137026823285 because of step counter
# Final cost : 0.031556137026823285
# Compute control for a deterministic system
# Cost in iteration 0: 0.031556137026823285
# Converged in iteration 1 with cost 0.031556137026823285 because of step counter
# Final cost : 0.031556137026823285
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.12241990057208837
# Cost in iteration 200: 0.04778894539950512
# Final cost : 0.04778894539950512
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778894539950512
# Converged in iteration 8 with cost 0.04778878234625044 because of vanishing difference
# Final cost : 0.04778878234625044
# Compute control for a deterministic system
# Cost in iteration 0: 0.04778878234625044
# Converged in iteration 79 with cost 0.047788771195193196 because of step counter
# Final cost : 0.047788771195193196
# Compute control for a deterministic system
# Cost in iteration 0: 0.047788771195193196
# Converged in iteration 2 with cost 0.047788771195191766 because of step counter
# Final cost : 0.047788771195191766
# Compute control for a deterministic system
# Cost in iteration 0: 0.047788771195191766
# Converged in iteration 1 with cost 0.047788771195191766 because of step counter
# Final cost : 0.047788771195191766
# Compute control for a deterministic system
# Cost in iteration 0: 0.2023370363576957
# Cost in iteration 200: 0.06450259216574167
# Final cost : 0.06450259216574167
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450259216574167
# Converged in iteration 21 with cost 0.06450024698619983 because of vanishing difference
# Final cost : 0.06450024698619983
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450024698619983
# Converged in iteration 122 with cost 0.06450015897423901 because of step counter
# Final cost : 0.06450015897423901
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450015897423901
# Converged in iteration 2 with cost 0.06450015897423565 because of step counter
# Final cost : 0.06450015897423565
# Compute control for a deterministic system
# Cost in iteration 0: 0.06450015897423565
# Converged in iteration 1 with cost 0.06450015897423565 because of step counter
# Final cost : 0.06450015897423565
# Compute control for a deterministic system
# ...
# Final cost : 0.2844781840400974
# Compute control for a deterministic system
# Cost in iteration 0: 0.2844781840400974
# Cost in iteration 200: 0.28447818321209883
# Converged in iteration 248 with cost 0.2844781832110205 because of step counter
# Final cost : 0.2844781832110205
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.4084973282002219
# Cost in iteration 200: 0.2671185820763465
# Final cost : 0.2671185820763465
# Compute control for a deterministic system
# Cost in iteration 0: 0.2671185820763465
# Cost in iteration 200: 0.26711131482347206
# Final cost : 0.26711131482347206
# Compute control for a deterministic system
# Cost in iteration 0: 0.26711131482347206
# Cost in iteration 200: 0.26711130513845077
# Final cost : 0.26711130513845077
# Compute control for a deterministic system
# Cost in iteration 0: 0.26711130513845077
# Cost in iteration 200: 0.26711130479824247
# Cost in iteration 400: 0.2671113047702853
# Final cost : 0.2671113047702853
# Compute control for a deterministic system
# Cost in iteration 0: 0.2671113047702853
# Converged in iteration 77 with cost 0.26711130476780803 because of step counter
# Final cost : 0.26711130476780803
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.7060236983631774
# Cost in iteration 200: 0.25024492352900934
# Final cost : 0.25024492352900934
# Compute control for a deterministic system
# Cost in iteration 0: 0.25024492352900934
# Cost in iteration 200: 0.2502194453285027
# Final cost : 0.2502194453285027
# Compute control for a deterministic system
# Cost in iteration 0: 0.2502194453285027
# Cost in iteration 200: 0.2502193076881777
# Final cost : 0.2502193076881777
# Compute control for a deterministic system
# Cost in iteration 0: 0.2502193076881777
# Cost in iteration 200: 0.250219302880693
# Cost in iteration 400: 0.25021930258862835
# Final cost : 0.25021930258862835
# Compute control for a deterministic system
# Cost in iteration 0: 0.25021930258862835
# Converged in iteration 118 with cost 0.2502193025697797 because of step counter
# Final cost : 0.2502193025697797
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.34714245583508874
# Cost in iteration 200: 0.23290317264298344
# Final cost : 0.23290317264298344
# Compute control for a deterministic system
# Cost in iteration 0: 0.23290317264298344
# Converged in iteration 21 with cost 0.23290107971223592 because of vanishing difference
# Final cost : 0.23290107971223592
# Compute control for a deterministic system
# Cost in iteration 0: 0.23290107971223592
# Cost in iteration 200: 0.23290025451610497
# Final cost : 0.23290025451610497
# Compute control for a deterministic system
# Cost in iteration 0: 0.23290025451610497
# Cost in iteration 200: 0.23290024886158847
# Cost in iteration 400: 0.23290024864604977
# Final cost : 0.23290024864604977
# Compute control for a deterministic system
# Cost in iteration 0: 0.23290024864604977
# Converged in iteration 94 with cost 0.2329002486369925 because of step counter
# Final cost : 0.2329002486369925
# Compute control for a deterministic system
# Cost in iteration 0: 0.22131462516568282
# Cost in iteration 200: 0.2160769438205562
# Final cost : 0.2160769438205562
# Compute control for a deterministic system
# Cost in iteration 0: 0.2160769438205562
# Cost in iteration 200: 0.21607689495919466
# Final cost : 0.21607689495919466
# Compute control for a deterministic system
# Cost in iteration 0: 0.21607689495919466
# Cost in iteration 200: 0.21607689487871776
# Final cost : 0.21607689487871776
# Compute control for a deterministic system
# Cost in iteration 0: 0.21607689487871776
# Converged in iteration 108 with cost 0.216076894877725 because of step counter
# Final cost : 0.216076894877725
# Compute control for a deterministic system
# Cost in iteration 0: 0.216076894877725
# Converged in iteration 5 with cost 0.21607689487764514 because of step counter
# Final cost : 0.21607689487764514
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.21386254792899462
# Cost in iteration 200: 0.19884863275006318
# Final cost : 0.19884863275006318
# Compute control for a deterministic system
# Cost in iteration 0: 0.19884863275006318
# Cost in iteration 200: 0.1988484732924765
# Final cost : 0.1988484732924765
# Compute control for a deterministic system
# Cost in iteration 0: 0.1988484732924765
# Cost in iteration 200: 0.1988484731025245
# Final cost : 0.1988484731025245
# Compute control for a deterministic system
# Cost in iteration 0: 0.1988484731025245
# Converged in iteration 65 with cost 0.19884847310154527 because of step counter
# Final cost : 0.19884847310154527
# Compute control for a deterministic system
# Cost in iteration 0: 0.19884847310154527
# Converged in iteration 18 with cost 0.19884847310125597 because of step counter
# Final cost : 0.19884847310125597
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.23218113559183773
# Cost in iteration 200: 0.1821256485396137
# Final cost : 0.1821256485396137
# Compute control for a deterministic system
# Cost in iteration 0: 0.1821256485396137
# Cost in iteration 200: 0.18212486167115183
# Final cost : 0.18212486167115183
# Compute control for a deterministic system
# Cost in iteration 0: 0.18212486167115183
# Cost in iteration 200: 0.18212486112050172
# Final cost : 0.18212486112050172
# Compute control for a deterministic system
# Cost in iteration 0: 0.18212486112050172
# Converged in iteration 97 with cost 0.18212486111909043 because of vanishing difference
# Final cost : 0.18212486111909043
# Compute control for a deterministic system
# Cost in iteration 0: 0.18212486111909043
# Converged in iteration 8 with cost 0.18212486111903367 because of step counter
# Final cost : 0.18212486111903367
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.16547525743175454
# Cost in iteration 200: 0.16500140182454126
# Final cost : 0.16500140182454126
# Compute control for a deterministic system
# Cost in iteration 0: 0.16500140182454126
# Converged in iteration 195 with cost 0.1650014001654725 because of vanishing difference
# Final cost : 0.1650014001654725
# Compute control for a deterministic system
# Cost in iteration 0: 0.1650014001654725
# Converged in iteration 1 with cost 0.1650014001654725 because of vanishing difference
# Final cost : 0.1650014001654725
# Compute control for a deterministic system
# Cost in iteration 0: 0.1650014001654725
# Converged in iteration 36 with cost 0.1650014001652231 because of step counter
# Final cost : 0.1650014001652231
# Compute control for a deterministic system
# Cost in iteration 0: 0.1650014001652231
# Converged in iteration 2 with cost 0.1650014001652208 because of step counter
# Final cost : 0.1650014001652208
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.31357412614851793
# Cost in iteration 200: 0.14838199943787367
# Final cost : 0.14838199943787367
# Compute control for a deterministic system
# Cost in iteration 0: 0.14838199943787367
# Converged in iteration 61 with cost 0.14837703991165463 because of vanishing difference
# Final cost : 0.14837703991165463
# Compute control for a deterministic system
# Cost in iteration 0: 0.14837703991165463
# Cost in iteration 200: 0.148376940774074
# Final cost : 0.148376940774074
# Compute control for a deterministic system
# Cost in iteration 0: 0.148376940774074
# Converged in iteration 130 with cost 0.14837694076322575 because of step counter
# Final cost : 0.14837694076322575
# Compute control for a deterministic system
# Cost in iteration 0: 0.14837694076322575
# Converged in iteration 2 with cost 0.14837694076322497 because of step counter
# Final cost : 0.14837694076322497
# Compute control for a deterministic system
# Cost in iteration 0: 0.17186107944033804
# Cost in iteration 200: 0.131350477579123
# Final cost : 0.131350477579123
# Compute control for a deterministic system
# Cost in iteration 0: 0.131350477579123
# Converged in iteration 27 with cost 0.13135013088204878 because of vanishing difference
# Final cost : 0.13135013088204878
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135013088204878
# Converged in iteration 182 with cost 0.13135008158862377 because of vanishing difference
# Final cost : 0.13135008158862377
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135008158862377
# Converged in iteration 93 with cost 0.13135008158631706 because of step counter
# Final cost : 0.13135008158631706
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135008158631706
# Converged in iteration 2 with cost 0.13135008158631276 because of step counter
# Final cost : 0.13135008158631276
# Compute control for a deterministic system
# Cost in iteration 0: 0.2552905208342663
# Cost in iteration 200: 0.11481618691452382
# Final cost : 0.11481618691452382
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481618691452382
# Converged in iteration 15 with cost 0.11481515894092519 because of vanishing difference
# Final cost : 0.11481515894092519
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481515894092519
# Cost in iteration 200: 0.11481493464066414
# Final cost : 0.11481493464066414
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481493464066414
# Converged in iteration 36 with cost 0.11481493464044973 because of step counter
# Final cost : 0.11481493464044973
# Compute control for a deterministic system
# Cost in iteration 0: 0.11481493464044973
# Converged in iteration 2 with cost 0.11481493464044874 because of step counter
# Final cost : 0.11481493464044874
# Compute control for a deterministic system
# Cost in iteration 0: 0.09932983649698598
# Cost in iteration 200: 0.0978768592897402
# Final cost : 0.0978768592897402
# Compute control for a deterministic system
# Cost in iteration 0: 0.0978768592897402
# Converged in iteration 124 with cost 0.09787685722409302 because of step counter
# Final cost : 0.09787685722409302
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787685722409302
# Converged in iteration 7 with cost 0.09787685722406546 because of step counter
# Final cost : 0.09787685722406546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787685722406546
# Converged in iteration 1 with cost 0.09787685722406546 because of step counter
# Final cost : 0.09787685722406546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09787685722406546
# Converged in iteration 1 with cost 0.09787685722406546 because of step counter
# Final cost : 0.09787685722406546
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.11707371515307764
# Cost in iteration 200: 0.08142826358870088
# Final cost : 0.08142826358870088
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142826358870088
# Converged in iteration 118 with cost 0.08142824961548376 because of step counter
# Final cost : 0.08142824961548376
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142824961548376
# Converged in iteration 1 with cost 0.08142824961548376 because of step counter
# Final cost : 0.08142824961548376
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142824961548376
# Converged in iteration 1 with cost 0.08142824961548376 because of step counter
# Final cost : 0.08142824961548376
# Compute control for a deterministic system
# Cost in iteration 0: 0.08142824961548376
# Converged in iteration 1 with cost 0.08142824961548376 because of step counter
# Final cost : 0.08142824961548376
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.09182668279059467
# Cost in iteration 200: 0.06458331188634128
# Final cost : 0.06458331188634128
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458331188634128
# Converged in iteration 74 with cost 0.06458330948260606 because of step counter
# Final cost : 0.06458330948260606
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458330948260606
# Converged in iteration 9 with cost 0.06458330948259046 because of step counter
# Final cost : 0.06458330948259046
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458330948259046
# Converged in iteration 1 with cost 0.06458330948259046 because of step counter
# Final cost : 0.06458330948259046
# Compute control for a deterministic system
# Cost in iteration 0: 0.06458330948259046
# Converged in iteration 1 with cost 0.06458330948259046 because of step counter
# Final cost : 0.06458330948259046
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0482665021372499
# Cost in iteration 200: 0.04823482792140062
# Final cost : 0.04823482792140062
# Compute control for a deterministic system
# Cost in iteration 0: 0.04823482792140062
# Converged in iteration 18 with cost 0.0482348279207524 because of step counter
# Final cost : 0.0482348279207524
# Compute control for a deterministic system
# Cost in iteration 0: 0.0482348279207524
# Converged in iteration 1 with cost 0.0482348279207524 because of step counter
# Final cost : 0.0482348279207524
# Compute control for a deterministic system
# Cost in iteration 0: 0.0482348279207524
# Converged in iteration 2 with cost 0.04823482792075023 because of step counter
# Final cost : 0.04823482792075023
# Compute control for a deterministic system
# Cost in iteration 0: 0.04823482792075023
# Converged in iteration 1 with cost 0.04823482792075023 because of step counter
# Final cost : 0.04823482792075023
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.04663404289136923
# Cost in iteration 200: 0.03151004839365225
# Final cost : 0.03151004839365225
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004839365225
# Converged in iteration 9 with cost 0.03151004839260544 because of step counter
# Final cost : 0.03151004839260544
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004839260544
# Converged in iteration 5 with cost 0.03151004839259789 because of step counter
# Final cost : 0.03151004839259789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004839259789
# Converged in iteration 1 with cost 0.03151004839259789 because of step counter
# Final cost : 0.03151004839259789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03151004839259789
# Converged in iteration 1 with cost 0.03151004839259789 because of step counter
# Final cost : 0.03151004839259789
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.015711018728363293
# Converged in iteration 113 with cost 0.01530704276182779 because of step counter
# Final cost : 0.01530704276182779
# Compute control for a deterministic system
# Cost in iteration 0: 0.01530704276182779
# Converged in iteration 6 with cost 0.015307042761815581 because of step counter
# Final cost : 0.015307042761815581
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307042761815581
# Converged in iteration 3 with cost 0.015307042761811534 because of step counter
# Final cost : 0.015307042761811534
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307042761811534
# Converged in iteration 1 with cost 0.015307042761811534 because of step counter
# Final cost : 0.015307042761811534
# Compute control for a deterministic system
# Cost in iteration 0: 0.015307042761811534
# Converged in iteration 1 with cost 0.015307042761811534 because of step counter
# Final cost : 0.015307042761811534
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
