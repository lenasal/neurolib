# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,117], wc.inh[0,117]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 19.070833333333336
# peaks =  [  93  284  475  665  856 1047 1238 1428 1619 1810 2000 2191 2382 2572
#  2763 2954 3144 3335 3526 3717 3907 4098 4289 4479 4670 4861]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
for i in [18,19,20,21,22]:
    results_peak["total_cost"][0][i] = 10.

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
results_min = readfile("results_min_w1.pickle")

ind_list = range(16,22,1)
options = [True, True, True, True, True, True, True, True]
options = [True, False, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
            
            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.2687615354964316
# Cost in iteration 200: 0.05301473730126416
# Final cost : 0.05301473730126416
# Compute control for a deterministic system
# Cost in iteration 0: 0.05301473730126416
# Converged in iteration 43 with cost 0.05280992071555291 because of step counter
# Final cost : 0.05280992071555291
# Compute control for a deterministic system
# Cost in iteration 0: 0.05280992071555291
# Converged in iteration 1 with cost 0.05280992071555291 because of step counter
# Final cost : 0.05280992071555291
# Compute control for a deterministic system
# Cost in iteration 0: 0.05280992071555291
# Converged in iteration 1 with cost 0.05280992071555291 because of step counter
# Final cost : 0.05280992071555291
# Compute control for a deterministic system
# Cost in iteration 0: 0.05280992071555291
# Converged in iteration 1 with cost 0.05280992071555291 because of step counter
# Final cost : 0.05280992071555291
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.5236508574290432
# Cost in iteration 200: 0.05783311955336988
# Final cost : 0.05783311955336988
# Compute control for a deterministic system
# Cost in iteration 0: 0.05783311955336988
# Converged in iteration 79 with cost 0.057187988015741806 because of step counter
# Final cost : 0.057187988015741806
# Compute control for a deterministic system
# Cost in iteration 0: 0.057187988015741806
# Converged in iteration 1 with cost 0.057187988015741806 because of step counter
# Final cost : 0.057187988015741806
# Compute control for a deterministic system
# Cost in iteration 0: 0.057187988015741806
# Converged in iteration 1 with cost 0.057187988015741806 because of step counter
# Final cost : 0.057187988015741806
# Compute control for a deterministic system
# Cost in iteration 0: 0.057187988015741806
# Converged in iteration 1 with cost 0.057187988015741806 because of step counter
# Final cost : 0.057187988015741806
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.11870694369943385
# Converged in iteration 116 with cost 0.06218034276885605 because of step counter
# Final cost : 0.06218034276885605
# Compute control for a deterministic system
# Cost in iteration 0: 0.06218034276885605
# Converged in iteration 1 with cost 0.06218034276885605 because of step counter
# Final cost : 0.06218034276885605
# Compute control for a deterministic system
# Cost in iteration 0: 0.06218034276885605
# Converged in iteration 1 with cost 0.06218034276885605 because of step counter
# Final cost : 0.06218034276885605
# Compute control for a deterministic system
# Cost in iteration 0: 0.06218034276885605
# Converged in iteration 1 with cost 0.06218034276885605 because of step counter
# Final cost : 0.06218034276885605
# Compute control for a deterministic system
# Cost in iteration 0: 0.06218034276885605
# Converged in iteration 1 with cost 0.06218034276885605 because of step counter
# Final cost : 0.06218034276885605
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.07603049433985214
# Cost in iteration 200: 0.06811907640884424
# Final cost : 0.06811907640884424
# Compute control for a deterministic system
# Cost in iteration 0: 0.06811907640884424
# Converged in iteration 34 with cost 0.06751362693831832 because of step counter
# Final cost : 0.06751362693831832
# Compute control for a deterministic system
# Cost in iteration 0: 0.06751362693831832
# Converged in iteration 1 with cost 0.06751362693831832 because of step counter
# Final cost : 0.06751362693831832
# Compute control for a deterministic system
# Cost in iteration 0: 0.06751362693831832
# Converged in iteration 1 with cost 0.06751362693831832 because of step counter
# Final cost : 0.06751362693831832
# Compute control for a deterministic system
# Cost in iteration 0: 0.06751362693831832
# Converged in iteration 1 with cost 0.06751362693831832 because of step counter
# Final cost : 0.06751362693831832
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.07530644826713576
# Cost in iteration 200: 0.07334544585876329
# Final cost : 0.07334544585876329
# Compute control for a deterministic system
# Cost in iteration 0: 0.07334544585876329
# Converged in iteration 39 with cost 0.07185705254938993 because of step counter
# Final cost : 0.07185705254938993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07185705254938993
# Converged in iteration 1 with cost 0.07185705254938993 because of step counter
# Final cost : 0.07185705254938993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07185705254938993
# Converged in iteration 1 with cost 0.07185705254938993 because of step counter
# Final cost : 0.07185705254938993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07185705254938993
# Converged in iteration 1 with cost 0.07185705254938993 because of step counter
# Final cost : 0.07185705254938993
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.13497014201048585
# Cost in iteration 200: 0.07719717336270683
# Final cost : 0.07719717336270683
# Compute control for a deterministic system
# Cost in iteration 0: 0.07719717336270683
# Converged in iteration 63 with cost 0.07559719119578619 because of step counter
# Final cost : 0.07559719119578619
# Compute control for a deterministic system
# Cost in iteration 0: 0.07559719119578619
# Converged in iteration 1 with cost 0.07559719119578619 because of step counter
# Final cost : 0.07559719119578619
# Compute control for a deterministic system
# Cost in iteration 0: 0.07559719119578619
# Converged in iteration 1 with cost 0.07559719119578619 because of step counter
# Final cost : 0.07559719119578619
# Compute control for a deterministic system
# Cost in iteration 0: 0.07559719119578619
# Converged in iteration 1 with cost 0.07559719119578619 because of step counter
# Final cost : 0.07559719119578619
# -----------------------------------------------
# 0 found better solution,  21
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.05336733649349773
# Converged in iteration 11 with cost 0.05289661448842252 because of step counter
# Final cost : 0.05289661448842252
# Compute control for a deterministic system
# Cost in iteration 0: 0.05289661448842252
# Converged in iteration 1 with cost 0.05289661448842252 because of step counter
# Final cost : 0.05289661448842252
# Compute control for a deterministic system
# Cost in iteration 0: 0.05289661448842252
# Converged in iteration 1 with cost 0.05289661448842252 because of step counter
# Final cost : 0.05289661448842252
# Compute control for a deterministic system
# Cost in iteration 0: 0.05289661448842252
# Converged in iteration 1 with cost 0.05289661448842252 because of step counter
# Final cost : 0.05289661448842252
# Compute control for a deterministic system
# Cost in iteration 0: 0.05289661448842252
# Converged in iteration 1 with cost 0.05289661448842252 because of step counter
# Final cost : 0.05289661448842252
# Compute control for a deterministic system
# Cost in iteration 0: 0.057630854979793054
# Converged in iteration 18 with cost 0.057272944784732785 because of step counter
# Final cost : 0.057272944784732785
# Compute control for a deterministic system
# Cost in iteration 0: 0.057272944784732785
# Converged in iteration 1 with cost 0.057272944784732785 because of step counter
# Final cost : 0.057272944784732785
# Compute control for a deterministic system
# Cost in iteration 0: 0.057272944784732785
# Converged in iteration 1 with cost 0.057272944784732785 because of step counter
# Final cost : 0.057272944784732785
# Compute control for a deterministic system
# Cost in iteration 0: 0.057272944784732785
# Converged in iteration 1 with cost 0.057272944784732785 because of step counter
# Final cost : 0.057272944784732785
# Compute control for a deterministic system
# Cost in iteration 0: 0.057272944784732785
# Converged in iteration 1 with cost 0.057272944784732785 because of step counter
# Final cost : 0.057272944784732785
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266102796406382
# Cost in iteration 200: 0.062135749976317683
# Final cost : 0.062135749976317683
# Compute control for a deterministic system
# Cost in iteration 0: 0.062135749976317683
# Converged in iteration 14 with cost 0.06194436923370076 because of step counter
# Final cost : 0.06194436923370076
# Compute control for a deterministic system
# Cost in iteration 0: 0.06194436923370076
# Converged in iteration 1 with cost 0.06194436923370076 because of step counter
# Final cost : 0.06194436923370076
# Compute control for a deterministic system
# Cost in iteration 0: 0.06194436923370076
# Converged in iteration 1 with cost 0.06194436923370076 because of step counter
# Final cost : 0.06194436923370076
# Compute control for a deterministic system
# Cost in iteration 0: 0.06194436923370076
# Converged in iteration 1 with cost 0.06194436923370076 because of step counter
# Final cost : 0.06194436923370076
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.0684807348130814
# Cost in iteration 200: 0.06715324855564105
# Final cost : 0.06715324855564105
# Compute control for a deterministic system
# Cost in iteration 0: 0.06715324855564105
# Converged in iteration 16 with cost 0.06680610736829164 because of step counter
# Final cost : 0.06680610736829164
# Compute control for a deterministic system
# Cost in iteration 0: 0.06680610736829164
# Converged in iteration 1 with cost 0.06680610736829164 because of step counter
# Final cost : 0.06680610736829164
# Compute control for a deterministic system
# Cost in iteration 0: 0.06680610736829164
# Converged in iteration 1 with cost 0.06680610736829164 because of step counter
# Final cost : 0.06680610736829164
# Compute control for a deterministic system
# Cost in iteration 0: 0.06680610736829164
# Converged in iteration 1 with cost 0.06680610736829164 because of step counter
# Final cost : 0.06680610736829164
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.07276598922653915
# Cost in iteration 200: 0.07139110001954725
# Final cost : 0.07139110001954725
# Compute control for a deterministic system
# Cost in iteration 0: 0.07139110001954725
# Converged in iteration 20 with cost 0.07083785132034837 because of step counter
# Final cost : 0.07083785132034837
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083785132034837
# Converged in iteration 1 with cost 0.07083785132034837 because of step counter
# Final cost : 0.07083785132034837
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083785132034837
# Converged in iteration 1 with cost 0.07083785132034837 because of step counter
# Final cost : 0.07083785132034837
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083785132034837
# Converged in iteration 1 with cost 0.07083785132034837 because of step counter
# Final cost : 0.07083785132034837
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.07662048689335842
# Cost in iteration 200: 0.07520471951986991
# Final cost : 0.07520471951986991
# Compute control for a deterministic system
# Cost in iteration 0: 0.07520471951986991
# Converged in iteration 22 with cost 0.07467173145226089 because of step counter
# Final cost : 0.07467173145226089
# Compute control for a deterministic system
# Cost in iteration 0: 0.07467173145226089
# Converged in iteration 1 with cost 0.07467173145226089 because of step counter
# Final cost : 0.07467173145226089
# Compute control for a deterministic system
# Cost in iteration 0: 0.07467173145226089
# Converged in iteration 1 with cost 0.07467173145226089 because of step counter
# Final cost : 0.07467173145226089
# Compute control for a deterministic system
# Cost in iteration 0: 0.07467173145226089
# Converged in iteration 1 with cost 0.07467173145226089 because of step counter
# Final cost : 0.07467173145226089
# -----------------------------------------------
# 4 found better solution,  21
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.05380757613081712
# Converged in iteration 9 with cost 0.05285791995583491 because of step counter
# Final cost : 0.05285791995583491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05285791995583491
# Converged in iteration 1 with cost 0.05285791995583491 because of step counter
# Final cost : 0.05285791995583491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05285791995583491
# Converged in iteration 1 with cost 0.05285791995583491 because of step counter
# Final cost : 0.05285791995583491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05285791995583491
# Converged in iteration 1 with cost 0.05285791995583491 because of step counter
# Final cost : 0.05285791995583491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05285791995583491
# Converged in iteration 1 with cost 0.05285791995583491 because of step counter
# Final cost : 0.05285791995583491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05795009824674325
# Converged in iteration 13 with cost 0.05726596602458981 because of step counter
# Final cost : 0.05726596602458981
# Compute control for a deterministic system
# Cost in iteration 0: 0.05726596602458981
# Converged in iteration 1 with cost 0.05726596602458981 because of step counter
# Final cost : 0.05726596602458981
# Compute control for a deterministic system
# Cost in iteration 0: 0.05726596602458981
# Converged in iteration 1 with cost 0.05726596602458981 because of step counter
# Final cost : 0.05726596602458981
# Compute control for a deterministic system
# Cost in iteration 0: 0.05726596602458981
# Converged in iteration 1 with cost 0.05726596602458981 because of step counter
# Final cost : 0.05726596602458981
# Compute control for a deterministic system
# Cost in iteration 0: 0.05726596602458981
# Converged in iteration 1 with cost 0.05726596602458981 because of step counter
# Final cost : 0.05726596602458981
# Compute control for a deterministic system
# Cost in iteration 0: 0.06296403668700362
# Cost in iteration 200: 0.06175908415021978
# Final cost : 0.06175908415021978
# Compute control for a deterministic system
# Cost in iteration 0: 0.06175908415021978
# Converged in iteration 12 with cost 0.061607099544605075 because of step counter
# Final cost : 0.061607099544605075
# Compute control for a deterministic system
# Cost in iteration 0: 0.061607099544605075
# Converged in iteration 1 with cost 0.061607099544605075 because of step counter
# Final cost : 0.061607099544605075
# Compute control for a deterministic system
# Cost in iteration 0: 0.061607099544605075
# Converged in iteration 1 with cost 0.061607099544605075 because of step counter
# Final cost : 0.061607099544605075
# Compute control for a deterministic system
# Cost in iteration 0: 0.061607099544605075
# Converged in iteration 1 with cost 0.061607099544605075 because of step counter
# Final cost : 0.061607099544605075
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.06784111532965213
# Cost in iteration 200: 0.06651772238889847
# Final cost : 0.06651772238889847
# Compute control for a deterministic system
# Cost in iteration 0: 0.06651772238889847
# Converged in iteration 14 with cost 0.0662704001129083 because of step counter
# Final cost : 0.0662704001129083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0662704001129083
# Converged in iteration 1 with cost 0.0662704001129083 because of step counter
# Final cost : 0.0662704001129083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0662704001129083
# Converged in iteration 1 with cost 0.0662704001129083 because of step counter
# Final cost : 0.0662704001129083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0662704001129083
# Converged in iteration 1 with cost 0.0662704001129083 because of step counter
# Final cost : 0.0662704001129083
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.0718758351874463
# Cost in iteration 200: 0.07048173220922938
# Final cost : 0.07048173220922938
# Compute control for a deterministic system
# Cost in iteration 0: 0.07048173220922938
# Converged in iteration 20 with cost 0.07005346151653478 because of step counter
# Final cost : 0.07005346151653478
# Compute control for a deterministic system
# Cost in iteration 0: 0.07005346151653478
# Converged in iteration 1 with cost 0.07005346151653478 because of step counter
# Final cost : 0.07005346151653478
# Compute control for a deterministic system
# Cost in iteration 0: 0.07005346151653478
# Converged in iteration 1 with cost 0.07005346151653478 because of step counter
# Final cost : 0.07005346151653478
# Compute control for a deterministic system
# Cost in iteration 0: 0.07005346151653478
# Converged in iteration 1 with cost 0.07005346151653478 because of step counter
# Final cost : 0.07005346151653478
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.07581157013911552
# Cost in iteration 200: 0.07436086491961935
# Final cost : 0.07436086491961935
# Compute control for a deterministic system
# Cost in iteration 0: 0.07436086491961935
# Converged in iteration 16 with cost 0.07403757329815028 because of step counter
# Final cost : 0.07403757329815028
# Compute control for a deterministic system
# Cost in iteration 0: 0.07403757329815028
# Converged in iteration 1 with cost 0.07403757329815028 because of step counter
# Final cost : 0.07403757329815028
# Compute control for a deterministic system
# Cost in iteration 0: 0.07403757329815028
# Converged in iteration 1 with cost 0.07403757329815028 because of step counter
# Final cost : 0.07403757329815028
# Compute control for a deterministic system
# Cost in iteration 0: 0.07403757329815028
# Converged in iteration 1 with cost 0.07403757329815028 because of step counter
# Final cost : 0.07403757329815028
# -----------------------------------------------
# 5 found better solution,  21
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.5458282620470327
# Cost in iteration 200: 0.2050745793663487
# Final cost : 0.2050745793663487
# Compute control for a deterministic system
# Cost in iteration 0: 0.2050745793663487
# Cost in iteration 200: 0.2049282683598599
# Final cost : 0.2049282683598599
# Compute control for a deterministic system
# Cost in iteration 0: 0.2049282683598599
# Cost in iteration 200: 0.2049244663635138
# Final cost : 0.2049244663635138
# Compute control for a deterministic system
# Cost in iteration 0: 0.2049244663635138
# Cost in iteration 200: 0.20492445424239727
# Cost in iteration 400: 0.20492445377693103
# Final cost : 0.20492445377693103
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445377693103
# Cost in iteration 200: 0.20492445375823326
# Converged in iteration 380 with cost 0.20492445375704066 because of step counter
# Final cost : 0.20492445375704066
# Compute control for a deterministic system
# Cost in iteration 0: 0.2832060403268072
# Cost in iteration 200: 0.2193162756571296
# Final cost : 0.2193162756571296
# Compute control for a deterministic system
# Cost in iteration 0: 0.2193162756571296
# Cost in iteration 200: 0.21910256042540582
# Final cost : 0.21910256042540582
# Compute control for a deterministic system
# Cost in iteration 0: 0.21910256042540582
# Cost in iteration 200: 0.2190946821386153
# Final cost : 0.2190946821386153
# Compute control for a deterministic system
# Cost in iteration 0: 0.2190946821386153
# Cost in iteration 200: 0.21909467223172135
# Cost in iteration 400: 0.21909467170134625
# Final cost : 0.21909467170134625
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467170134625
# Cost in iteration 200: 0.2190946716732207
# Cost in iteration 400: 0.21909467167085736
# Converged in iteration 408 with cost 0.2190946716708329 because of step counter
# Final cost : 0.2190946716708329
# Compute control for a deterministic system
# Cost in iteration 0: 0.9542151229260388
# Cost in iteration 200: 0.23365548132855102
# Final cost : 0.23365548132855102
# Compute control for a deterministic system
# Cost in iteration 0: 0.23365548132855102
# Cost in iteration 200: 0.23331823480316166
# Final cost : 0.23331823480316166
# Compute control for a deterministic system
# Cost in iteration 0: 0.23331823480316166
# Cost in iteration 200: 0.23330509015385925
# Final cost : 0.23330509015385925
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330509015385925
# Cost in iteration 200: 0.23330506760309072
# Cost in iteration 400: 0.2333050660739235
# Final cost : 0.2333050660739235
# Compute control for a deterministic system
# Cost in iteration 0: 0.2333050660739235
# Cost in iteration 200: 0.23330506597320647
# Cost in iteration 400: 0.2333050659624864
# Converged in iteration 536 with cost 0.23330506596150036 because of step counter
# Final cost : 0.23330506596150036
# Compute control for a deterministic system
# Cost in iteration 0: 0.30899617023541165
# Cost in iteration 200: 0.24781438858462868
# Final cost : 0.24781438858462868
# Compute control for a deterministic system
# Cost in iteration 0: 0.24781438858462868
# Cost in iteration 200: 0.2475510332798687
# Final cost : 0.2475510332798687
# Compute control for a deterministic system
# Cost in iteration 0: 0.2475510332798687
# Cost in iteration 200: 0.24753598536749194
# Final cost : 0.24753598536749194
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753598536749194
# Cost in iteration 200: 0.24753596114128396
# Cost in iteration 400: 0.24753595851441065
# Final cost : 0.24753595851441065
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753595851441065
# Cost in iteration 200: 0.24753595821752303
# Cost in iteration 400: 0.24753595817872576
# Cost in iteration 600: 0.24753595817368484
# Converged in iteration 749 with cost 0.2475359581730013 because of step counter
# Final cost : 0.2475359581730013
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.30395120062807973
# Cost in iteration 200: 0.2591163906790811
# Final cost : 0.2591163906790811
# Compute control for a deterministic system
# Cost in iteration 0: 0.2591163906790811
# Cost in iteration 200: 0.2589416999692455
# Final cost : 0.2589416999692455
# Compute control for a deterministic system
# Cost in iteration 0: 0.2589416999692455
# Cost in iteration 200: 0.25892932328346024
# Final cost : 0.25892932328346024
# Compute control for a deterministic system
# Cost in iteration 0: 0.25892932328346024
# Cost in iteration 200: 0.25892928471638427
# Cost in iteration 400: 0.25892927964276935
# Final cost : 0.25892927964276935
# Compute control for a deterministic system
# Cost in iteration 0: 0.25892927964276935
# Cost in iteration 200: 0.258929278981229
# Cost in iteration 400: 0.25892927888006073
# Cost in iteration 600: 0.2589292788645839
# Cost in iteration 800: 0.25892927886222034
# Converged in iteration 807 with cost 0.2589292788621961 because of step counter
# Final cost : 0.2589292788621961
# Compute control for a deterministic system
# Cost in iteration 0: 0.6280047304750287
# Cost in iteration 200: 0.23497022264706374
# Final cost : 0.23497022264706374
# Compute control for a deterministic system
# Cost in iteration 0: 0.23497022264706374
# Cost in iteration 200: 0.23487228792228484
# Final cost : 0.23487228792228484
# Compute control for a deterministic system
# Cost in iteration 0: 0.23487228792228484
# Cost in iteration 200: 0.23486864091550622
# Final cost : 0.23486864091550622
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486864091550622
# Cost in iteration 200: 0.23486802305312937
# Cost in iteration 400: 0.23486788605007258
# Final cost : 0.23486788605007258
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486788605007258
# Cost in iteration 200: 0.23486784860121196
# Cost in iteration 400: 0.23486784716801867
# Cost in iteration 600: 0.23486784711343026
# Converged in iteration 701 with cost 0.23486784711166916 because of step counter
# Final cost : 0.23486784711166916
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.20545433080865805
# Cost in iteration 200: 0.20492809556072705
# Final cost : 0.20492809556072705
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492809556072705
# Cost in iteration 200: 0.20492445789479938
# Final cost : 0.20492445789479938
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445789479938
# Cost in iteration 200: 0.20492445375749868
# Final cost : 0.20492445375749868
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445375749868
# Converged in iteration 5 with cost 0.2049244537574574 because of vanishing difference
# Final cost : 0.2049244537574574
# Compute control for a deterministic system
# Cost in iteration 0: 0.2049244537574574
# Converged in iteration 39 with cost 0.20492445375725954 because of vanishing difference
# Final cost : 0.20492445375725954
# Compute control for a deterministic system
# Cost in iteration 0: 0.21972207947988043
# Cost in iteration 200: 0.21909762116497775
# Final cost : 0.21909762116497775
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909762116497775
# Cost in iteration 200: 0.21909467587435444
# Final cost : 0.21909467587435444
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467587435444
# Cost in iteration 200: 0.2190946716712383
# Final cost : 0.2190946716712383
# Compute control for a deterministic system
# Cost in iteration 0: 0.2190946716712383
# Converged in iteration 81 with cost 0.21909467167081698 because of step counter
# Final cost : 0.21909467167081698
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467167081698
# Converged in iteration 1 with cost 0.21909467167081698 because of step counter
# Final cost : 0.21909467167081698
# Compute control for a deterministic system
# Cost in iteration 0: 0.23402746548658757
# Cost in iteration 200: 0.2333079216421626
# Final cost : 0.2333079216421626
# Compute control for a deterministic system
# Cost in iteration 0: 0.2333079216421626
# Cost in iteration 200: 0.23330507096114744
# Final cost : 0.23330507096114744
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330507096114744
# Cost in iteration 200: 0.23330506596150208
# Final cost : 0.23330506596150208
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330506596150208
# Converged in iteration 56 with cost 0.23330506596132958 because of vanishing difference
# Final cost : 0.23330506596132958
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330506596132958
# Converged in iteration 1 with cost 0.23330506596132958 because of step counter
# Final cost : 0.23330506596132958
# Compute control for a deterministic system
# Cost in iteration 0: 0.24834631625478465
# Cost in iteration 200: 0.24753911445828666
# Final cost : 0.24753911445828666
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753911445828666
# Cost in iteration 200: 0.24753596523555985
# Final cost : 0.24753596523555985
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753596523555985
# Cost in iteration 200: 0.24753595817408905
# Final cost : 0.24753595817408905
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753595817408905
# Converged in iteration 149 with cost 0.2475359581730746 because of step counter
# Final cost : 0.2475359581730746
# Compute control for a deterministic system
# Cost in iteration 0: 0.2475359581730746
# Converged in iteration 1 with cost 0.2475359581730746 because of step counter
# Final cost : 0.2475359581730746
# Compute control for a deterministic system
# Cost in iteration 0: 0.24870223004389239
# Cost in iteration 200: 0.24747505459638958
# Final cost : 0.24747505459638958
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747505459638958
# Cost in iteration 200: 0.24747259171769817
# Final cost : 0.24747259171769817
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259171769817
# Cost in iteration 200: 0.24747259142165137
# Final cost : 0.24747259142165137
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259142165137
# Cost in iteration 200: 0.24747259141153938
# Cost in iteration 400: 0.2474725914096941
# Final cost : 0.2474725914096941
# Compute control for a deterministic system
# Cost in iteration 0: 0.2474725914096941
# Converged in iteration 48 with cost 0.24747259140934777 because of step counter
# Final cost : 0.24747259140934777
# Compute control for a deterministic system
# Cost in iteration 0: 0.23587058045617257
# Cost in iteration 200: 0.2348704348597779
# Final cost : 0.2348704348597779
# Compute control for a deterministic system
# Cost in iteration 0: 0.2348704348597779
# Cost in iteration 200: 0.23486784762579138
# Final cost : 0.23486784762579138
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486784762579138
# Cost in iteration 200: 0.23486784712657324
# Final cost : 0.23486784712657324
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486784712657324
# Cost in iteration 200: 0.2348678471138278
# Cost in iteration 400: 0.23486784711158024
# Final cost : 0.23486784711158024
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486784711158024
# Converged in iteration 23 with cost 0.2348678471114196 because of step counter
# Final cost : 0.2348678471114196
# -----------------------------------------------
# 4 found better solution,  21
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.20621168108019405
# Cost in iteration 200: 0.20492445681453947
# Final cost : 0.20492445681453947
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445681453947
# Cost in iteration 200: 0.20492445376944002
# Final cost : 0.20492445376944002
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445376944002
# Converged in iteration 185 with cost 0.20492445375700172 because of vanishing difference
# Final cost : 0.20492445375700172
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445375700089
# Converged in iteration 1 with cost 0.20492445375700089 because of step counter
# Final cost : 0.20492445375700089
# Compute control for a deterministic system
# Cost in iteration 0: 0.20492445375700089
# Converged in iteration 1 with cost 0.20492445375700089 because of step counter
# Final cost : 0.20492445375700089
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.22054846329800898
# Cost in iteration 200: 0.2190946756694363
# Final cost : 0.2190946756694363
# Compute control for a deterministic system
# Cost in iteration 0: 0.2190946756694363
# Cost in iteration 200: 0.21909467169005833
# Final cost : 0.21909467169005833
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467169005833
# Converged in iteration 180 with cost 0.21909467167072905 because of step counter
# Final cost : 0.21909467167072905
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467167072905
# Converged in iteration 1 with cost 0.21909467167072905 because of step counter
# Final cost : 0.21909467167072905
# Compute control for a deterministic system
# Cost in iteration 0: 0.21909467167072905
# Converged in iteration 1 with cost 0.21909467167072905 because of step counter
# Final cost : 0.21909467167072905
# Compute control for a deterministic system
# Cost in iteration 0: 0.23493080618544712
# Cost in iteration 200: 0.2333050711382271
# Final cost : 0.2333050711382271
# Compute control for a deterministic system
# Cost in iteration 0: 0.2333050711382271
# Cost in iteration 200: 0.23330506598987963
# Final cost : 0.23330506598987963
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330506598987963
# Converged in iteration 170 with cost 0.23330506596129427 because of vanishing difference
# Final cost : 0.23330506596129427
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330506596129427
# Converged in iteration 3 with cost 0.23330506596128964 because of step counter
# Final cost : 0.23330506596128964
# Compute control for a deterministic system
# Cost in iteration 0: 0.23330506596128964
# Converged in iteration 1 with cost 0.23330506596128964 because of step counter
# Final cost : 0.23330506596128964
# Compute control for a deterministic system
# Cost in iteration 0: 0.24934007332420313
# Cost in iteration 200: 0.24753596487332297
# Final cost : 0.24753596487332297
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753596487332297
# Cost in iteration 200: 0.24753595821150065
# Final cost : 0.24753595821150065
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753595821150065
# Cost in iteration 200: 0.24753595817306226
# Final cost : 0.24753595817306226
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753595817306226
# Converged in iteration 30 with cost 0.24753595817301008 because of step counter
# Final cost : 0.24753595817301008
# Compute control for a deterministic system
# Cost in iteration 0: 0.24753595817301008
# Converged in iteration 3 with cost 0.24753595817300608 because of step counter
# Final cost : 0.24753595817300608
# Compute control for a deterministic system
# Cost in iteration 0: 0.24988201349467112
# Cost in iteration 200: 0.24747259750378822
# Final cost : 0.24747259750378822
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259750378822
# Cost in iteration 200: 0.24747259141440692
# Final cost : 0.24747259141440692
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259141440692
# Cost in iteration 200: 0.24747259141012992
# Final cost : 0.24747259141012992
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259141012992
# Converged in iteration 35 with cost 0.24747259140990718 because of vanishing difference
# Final cost : 0.24747259140990718
# Compute control for a deterministic system
# Cost in iteration 0: 0.24747259140990718
# Converged in iteration 74 with cost 0.2474725914092378 because of step counter
# Final cost : 0.2474725914092378
# Compute control for a deterministic system
# Cost in iteration 0: 0.23705202033970565
# Cost in iteration 200: 0.23486785280934513
# Final cost : 0.23486785280934513
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486785280934513
# Cost in iteration 200: 0.2348678471189912
# Final cost : 0.2348678471189912
# Compute control for a deterministic system
# Cost in iteration 0: 0.2348678471189912
# Cost in iteration 200: 0.23486784711257885
# Final cost : 0.23486784711257885
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486784711257885
# Converged in iteration 159 with cost 0.23486784711148195 because of step counter
# Final cost : 0.23486784711148195
# Compute control for a deterministic system
# Cost in iteration 0: 0.23486784711148195
# Converged in iteration 3 with cost 0.2348678471114782 because of vanishing difference
# Final cost : 0.2348678471114782
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.4648569555688444
# Converged in iteration 20 with cost 0.9229295795566227 because of step counter
# Final cost : 0.9229295795566227
# Compute control for a deterministic system
# Cost in iteration 0: 0.9229295795566227
# Converged in iteration 1 with cost 0.9229295795566227 because of step counter
# Final cost : 0.9229295795566227
# Compute control for a deterministic system
# Cost in iteration 0: 0.9229295795566227
# Converged in iteration 2 with cost 0.9221515440584681 because of step counter
# Final cost : 0.9221515440584681
# Compute control for a deterministic system
# Cost in iteration 0: 0.9221515440584681
# Converged in iteration 1 with cost 0.9221515440584681 because of step counter
# Final cost : 0.9221515440584681
# Compute control for a deterministic system
# Cost in iteration 0: 0.9221515440584681
# Converged in iteration 1 with cost 0.9221515440584681 because of step counter
# Final cost : 0.9221515440584681
# Compute control for a deterministic system
# Cost in iteration 0: 1.270029884069119
# Converged in iteration 6 with cost 0.9457836675042656 because of step counter
# Final cost : 0.9457836675042656
# Compute control for a deterministic system
# Cost in iteration 0: 0.9457836675042656
# Converged in iteration 1 with cost 0.9457836675042656 because of step counter
# Final cost : 0.9457836675042656
# Compute control for a deterministic system
# Cost in iteration 0: 0.9457836675042656
# Converged in iteration 1 with cost 0.9457836675042656 because of step counter
# Final cost : 0.9457836675042656
# Compute control for a deterministic system
# Cost in iteration 0: 0.9457836675042656
# Converged in iteration 1 with cost 0.9457836675042656 because of step counter
# Final cost : 0.9457836675042656
# Compute control for a deterministic system
# Cost in iteration 0: 0.9457836675042656
# Converged in iteration 1 with cost 0.9457836675042656 because of step counter
# Final cost : 0.9457836675042656
# Compute control for a deterministic system
# Cost in iteration 0: 1.4567616702055055
# Converged in iteration 2 with cost 1.0052881188142588 because of step counter
# Final cost : 1.0052881188142588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052881188142588
# Converged in iteration 1 with cost 1.0052881188142588 because of step counter
# Final cost : 1.0052881188142588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052881188142588
# Converged in iteration 1 with cost 1.0052881188142588 because of step counter
# Final cost : 1.0052881188142588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052881188142588
# Converged in iteration 1 with cost 1.0052881188142588 because of step counter
# Final cost : 1.0052881188142588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052881188142588
# Converged in iteration 1 with cost 1.0052881188142588 because of step counter
# Final cost : 1.0052881188142588
# Compute control for a deterministic system
# Cost in iteration 0: 1.975150556758213
# Converged in iteration 2 with cost 1.0741521704290857 because of step counter
# Final cost : 1.0741521704290857
# Compute control for a deterministic system
# Cost in iteration 0: 1.0741521704290857
# Converged in iteration 1 with cost 1.0741521704290857 because of step counter
# Final cost : 1.0741521704290857
# Compute control for a deterministic system
# Cost in iteration 0: 1.0741521704290857
# Converged in iteration 1 with cost 1.0741521704290857 because of step counter
# Final cost : 1.0741521704290857
# Compute control for a deterministic system
# Cost in iteration 0: 1.0741521704290857
# Converged in iteration 1 with cost 1.0741521704290857 because of step counter
# Final cost : 1.0741521704290857
# Compute control for a deterministic system
# Cost in iteration 0: 1.0741521704290857
# Converged in iteration 1 with cost 1.0741521704290857 because of step counter
# Final cost : 1.0741521704290857
# Compute control for a deterministic system
# Cost in iteration 0: 1.0259888838124116
# Converged in iteration 1 with cost 1.0259888838124116 because of step counter
# Final cost : 1.0259888838124116
# Compute control for a deterministic system
# Cost in iteration 0: 1.0259888838124116
# Converged in iteration 1 with cost 1.0259888838124116 because of step counter
# Final cost : 1.0259888838124116
# Compute control for a deterministic system
# Cost in iteration 0: 1.0259888838124116
# Converged in iteration 1 with cost 1.0259888838124116 because of step counter
# Final cost : 1.0259888838124116
# Compute control for a deterministic system
# Cost in iteration 0: 1.0259888838124116
# Converged in iteration 1 with cost 1.0259888838124116 because of step counter
# Final cost : 1.0259888838124116
# Compute control for a deterministic system
# Cost in iteration 0: 1.0259888838124116
# Converged in iteration 1 with cost 1.0259888838124116 because of step counter
# Final cost : 1.0259888838124116
# Compute control for a deterministic system
# Cost in iteration 0: 2.21175343507164
# Converged in iteration 4 with cost 0.9719406301154484 because of step counter
# Final cost : 0.9719406301154484
# Compute control for a deterministic system
# Cost in iteration 0: 0.9719406301154484
# Converged in iteration 1 with cost 0.9719406301154484 because of step counter
# Final cost : 0.9719406301154484
# Compute control for a deterministic system
# Cost in iteration 0: 0.9719406301154484
# Converged in iteration 1 with cost 0.9719406301154484 because of step counter
# Final cost : 0.9719406301154484
# Compute control for a deterministic system
# Cost in iteration 0: 0.9719406301154484
# Converged in iteration 1 with cost 0.9719406301154484 because of step counter
# Final cost : 0.9719406301154484
# Compute control for a deterministic system
# Cost in iteration 0: 0.9719406301154484
# Converged in iteration 1 with cost 0.9719406301154484 because of step counter
# Final cost : 0.9719406301154484
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.8082688776237462
# Converged in iteration 2 with cost 0.8080976028112034 because of step counter
# Final cost : 0.8080976028112034
# Compute control for a deterministic system
# Cost in iteration 0: 0.8080976028112034
# Converged in iteration 1 with cost 0.8080976028112034 because of step counter
# Final cost : 0.8080976028112034
# Compute control for a deterministic system
# Cost in iteration 0: 0.8080976028112034
# Converged in iteration 1 with cost 0.8080976028112034 because of step counter
# Final cost : 0.8080976028112034
# Compute control for a deterministic system
# Cost in iteration 0: 0.8080976028112034
# Converged in iteration 1 with cost 0.8080976028112034 because of step counter
# Final cost : 0.8080976028112034
# Compute control for a deterministic system
# Cost in iteration 0: 0.8080976028112034
# Converged in iteration 1 with cost 0.8080976028112034 because of step counter
# Final cost : 0.8080976028112034
# Compute control for a deterministic system
# Cost in iteration 0: 0.8644986000511639
# Converged in iteration 2 with cost 0.8642508773415825 because of step counter
# Final cost : 0.8642508773415825
# Compute control for a deterministic system
# Cost in iteration 0: 0.8642508773415825
# Converged in iteration 1 with cost 0.8642508773415825 because of step counter
# Final cost : 0.8642508773415825
# Compute control for a deterministic system
# Cost in iteration 0: 0.8642508773415825
# Converged in iteration 1 with cost 0.8642508773415825 because of step counter
# Final cost : 0.8642508773415825
# Compute control for a deterministic system
# Cost in iteration 0: 0.8642508773415825
# Converged in iteration 1 with cost 0.8642508773415825 because of step counter
# Final cost : 0.8642508773415825
# Compute control for a deterministic system
# Cost in iteration 0: 0.8642508773415825
# Converged in iteration 1 with cost 0.8642508773415825 because of step counter
# Final cost : 0.8642508773415825
# Compute control for a deterministic system
# Cost in iteration 0: 0.9212554699540887
# Converged in iteration 2 with cost 0.9205621116741768 because of step counter
# Final cost : 0.9205621116741768
# Compute control for a deterministic system
# Cost in iteration 0: 0.9205621116741768
# Converged in iteration 1 with cost 0.9205621116741768 because of step counter
# Final cost : 0.9205621116741768
# Compute control for a deterministic system
# Cost in iteration 0: 0.9205621116741768
# Converged in iteration 1 with cost 0.9205621116741768 because of step counter
# Final cost : 0.9205621116741768
# Compute control for a deterministic system
# Cost in iteration 0: 0.9205621116741768
# Converged in iteration 1 with cost 0.9205621116741768 because of step counter
# Final cost : 0.9205621116741768
# Compute control for a deterministic system
# Cost in iteration 0: 0.9205621116741768
# Converged in iteration 1 with cost 0.9205621116741768 because of step counter
# Final cost : 0.9205621116741768
# Compute control for a deterministic system
# Cost in iteration 0: 0.9774438460969026
# Converged in iteration 2 with cost 0.9771749425357044 because of step counter
# Final cost : 0.9771749425357044
# Compute control for a deterministic system
# Cost in iteration 0: 0.9771749425357044
# Converged in iteration 1 with cost 0.9771749425357044 because of step counter
# Final cost : 0.9771749425357044
# Compute control for a deterministic system
# Cost in iteration 0: 0.9771749425357044
# Converged in iteration 1 with cost 0.9771749425357044 because of step counter
# Final cost : 0.9771749425357044
# Compute control for a deterministic system
# Cost in iteration 0: 0.9771749425357044
# Converged in iteration 1 with cost 0.9771749425357044 because of step counter
# Final cost : 0.9771749425357044
# Compute control for a deterministic system
# Cost in iteration 0: 0.9771749425357044
# Converged in iteration 1 with cost 0.9771749425357044 because of step counter
# Final cost : 0.9771749425357044
# Compute control for a deterministic system
# Cost in iteration 0: 0.981884633825085
# Converged in iteration 2 with cost 0.9804492524302068 because of step counter
# Final cost : 0.9804492524302068
# Compute control for a deterministic system
# Cost in iteration 0: 0.9804492524302068
# Converged in iteration 1 with cost 0.9804492524302068 because of step counter
# Final cost : 0.9804492524302068
# Compute control for a deterministic system
# Cost in iteration 0: 0.9804492524302068
# Converged in iteration 1 with cost 0.9804492524302068 because of step counter
# Final cost : 0.9804492524302068
# Compute control for a deterministic system
# Cost in iteration 0: 0.9804492524302068
# Converged in iteration 1 with cost 0.9804492524302068 because of step counter
# Final cost : 0.9804492524302068
# Compute control for a deterministic system
# Cost in iteration 0: 0.9804492524302068
# Converged in iteration 1 with cost 0.9804492524302068 because of step counter
# Final cost : 0.9804492524302068
# Compute control for a deterministic system
# Cost in iteration 0: 0.9306471680727795
# Converged in iteration 6 with cost 0.9293357203476105 because of vanishing difference
# Final cost : 0.9293357203476105
# Compute control for a deterministic system
# Cost in iteration 0: 0.9293357203476105
# Converged in iteration 2 with cost 0.9293354756016395 because of step counter
# Final cost : 0.9293354756016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.9293354756016395
# Converged in iteration 1 with cost 0.9293354756016395 because of step counter
# Final cost : 0.9293354756016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.9293354756016395
# Converged in iteration 1 with cost 0.9293354756016395 because of step counter
# Final cost : 0.9293354756016395
# Compute control for a deterministic system
# Cost in iteration 0: 0.9293354756016395
# Converged in iteration 1 with cost 0.9293354756016395 because of step counter
# Final cost : 0.9293354756016395
# -----------------------------------------------
# 4 found better solution,  21
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.8061494255970818
# Converged in iteration 10 with cost 0.8049838887299329 because of step counter
# Final cost : 0.8049838887299329
# Compute control for a deterministic system
# Cost in iteration 0: 0.8049838887299329
# Converged in iteration 1 with cost 0.8049838887299329 because of step counter
# Final cost : 0.8049838887299329
# Compute control for a deterministic system
# Cost in iteration 0: 0.8049838887299329
# Converged in iteration 1 with cost 0.8049838887299329 because of step counter
# Final cost : 0.8049838887299329
# Compute control for a deterministic system
# Cost in iteration 0: 0.8049838887299329
# Converged in iteration 1 with cost 0.8049838887299329 because of step counter
# Final cost : 0.8049838887299329
# Compute control for a deterministic system
# Cost in iteration 0: 0.8049838887299329
# Converged in iteration 1 with cost 0.8049838887299329 because of step counter
# Final cost : 0.8049838887299329
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.8625022947050265
# Converged in iteration 13 with cost 0.8613139512681423 because of step counter
# Final cost : 0.8613139512681423
# Compute control for a deterministic system
# Cost in iteration 0: 0.8613139512681423
# Converged in iteration 1 with cost 0.8613139512681423 because of step counter
# Final cost : 0.8613139512681423
# Compute control for a deterministic system
# Cost in iteration 0: 0.8613139512681423
# Converged in iteration 1 with cost 0.8613139512681423 because of step counter
# Final cost : 0.8613139512681423
# Compute control for a deterministic system
# Cost in iteration 0: 0.8613139512681423
# Converged in iteration 1 with cost 0.8613139512681423 because of step counter
# Final cost : 0.8613139512681423
# Compute control for a deterministic system
# Cost in iteration 0: 0.8613139512681423
# Converged in iteration 1 with cost 0.8613139512681423 because of step counter
# Final cost : 0.8613139512681423
# -----------------------------------------------
# 5 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.9195283170542027
# Converged in iteration 2 with cost 0.9182874354725918 because of step counter
# Final cost : 0.9182874354725918
# Compute control for a deterministic system
# Cost in iteration 0: 0.9182874354725918
# Converged in iteration 1 with cost 0.9182874354725918 because of step counter
# Final cost : 0.9182874354725918
# Compute control for a deterministic system
# Cost in iteration 0: 0.9182874354725918
# Converged in iteration 1 with cost 0.9182874354725918 because of step counter
# Final cost : 0.9182874354725918
# Compute control for a deterministic system
# Cost in iteration 0: 0.9182874354725918
# Converged in iteration 1 with cost 0.9182874354725918 because of step counter
# Final cost : 0.9182874354725918
# Compute control for a deterministic system
# Cost in iteration 0: 0.9182874354725918
# Converged in iteration 1 with cost 0.9182874354725918 because of step counter
# Final cost : 0.9182874354725918
# Compute control for a deterministic system
# Cost in iteration 0: 0.9754209802780863
# Converged in iteration 13 with cost 0.9742132157056042 because of step counter
# Final cost : 0.9742132157056042
# Compute control for a deterministic system
# Cost in iteration 0: 0.9742132157056042
# Converged in iteration 1 with cost 0.9742132157056042 because of step counter
# Final cost : 0.9742132157056042
# Compute control for a deterministic system
# Cost in iteration 0: 0.9742132157056042
# Converged in iteration 1 with cost 0.9742132157056042 because of step counter
# Final cost : 0.9742132157056042
# Compute control for a deterministic system
# Cost in iteration 0: 0.9742132157056042
# Converged in iteration 1 with cost 0.9742132157056042 because of step counter
# Final cost : 0.9742132157056042
# Compute control for a deterministic system
# Cost in iteration 0: 0.9742132157056042
# Converged in iteration 1 with cost 0.9742132157056042 because of step counter
# Final cost : 0.9742132157056042
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.9818622503171884
# Converged in iteration 2 with cost 0.9803884876265753 because of step counter
# Final cost : 0.9803884876265753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9803884876265753
# Converged in iteration 1 with cost 0.9803884876265753 because of step counter
# Final cost : 0.9803884876265753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9803884876265753
# Converged in iteration 1 with cost 0.9803884876265753 because of step counter
# Final cost : 0.9803884876265753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9803884876265753
# Converged in iteration 1 with cost 0.9803884876265753 because of step counter
# Final cost : 0.9803884876265753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9803884876265753
# Converged in iteration 1 with cost 0.9803884876265753 because of step counter
# Final cost : 0.9803884876265753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9315338483538278
# Converged in iteration 2 with cost 0.9299877971211574 because of step counter
# Final cost : 0.9299877971211574
# Compute control for a deterministic system
# Cost in iteration 0: 0.9299877971211574
# Converged in iteration 1 with cost 0.9299877971211574 because of step counter
# Final cost : 0.9299877971211574
# Compute control for a deterministic system
# Cost in iteration 0: 0.9299877971211574
# Converged in iteration 1 with cost 0.9299877971211574 because of step counter
# Final cost : 0.9299877971211574
# Compute control for a deterministic system
# Cost in iteration 0: 0.9299877971211574
# Converged in iteration 1 with cost 0.9299877971211574 because of step counter
# Final cost : 0.9299877971211574
# Compute control for a deterministic system
# Cost in iteration 0: 0.9299877971211574
# Converged in iteration 1 with cost 0.9299877971211574 because of step counter
# Final cost : 0.9299877971211574

# %%
save(results_peak)
