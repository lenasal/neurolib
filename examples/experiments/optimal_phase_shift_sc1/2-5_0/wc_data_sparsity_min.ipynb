# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print("period = ", period)

init_min = [wc.exc[0,53], wc.inh[0,53]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# period =  19.070833333333336
# minima =  [  93  284  474  665  856 1046 1237 1428 1619 1809 2000 2191 2381 2572
#  2763 2953 3144 3335 3526 3716 3907 4098 4288 4479 4670 4860]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
results_peak = readfile("results_peak_w1.pickle")

ind_list = range(14,21)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.19962817522668325
# Cost in iteration 200: 0.17436989391698687
# Final cost : 0.17436989391698687
# Compute control for a deterministic system
# Cost in iteration 0: 0.17436989391698687
# Cost in iteration 200: 0.17425822267067573
# Final cost : 0.17425822267067573
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425822267067573
# Cost in iteration 200: 0.1742567775790876
# Final cost : 0.1742567775790876
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742567775790876
# Cost in iteration 200: 0.17425677670668557
# Cost in iteration 400: 0.17425677669219958
# Final cost : 0.17425677669219958
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425677669219958
# Converged in iteration 58 with cost 0.174256776692025 because of step counter
# Final cost : 0.174256776692025
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.8394085233629063
# Cost in iteration 200: 0.18808354423542686
# Final cost : 0.18808354423542686
# Compute control for a deterministic system
# Cost in iteration 0: 0.18808354423542686
# Cost in iteration 200: 0.18785750598278725
# Final cost : 0.18785750598278725
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785750598278725
# Cost in iteration 200: 0.18785382125905029
# Final cost : 0.18785382125905029
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785382125905029
# Cost in iteration 200: 0.18785382061699607
# Cost in iteration 400: 0.18785382060215033
# Final cost : 0.18785382060215033
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785382060215033
# Converged in iteration 81 with cost 0.18785382060179112 because of step counter
# Final cost : 0.18785382060179112
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.20469803984349985
# Cost in iteration 200: 0.19888678230963558
# Final cost : 0.19888678230963558
# Compute control for a deterministic system
# Cost in iteration 0: 0.19888678230963558
# Cost in iteration 200: 0.19879252367010206
# Final cost : 0.19879252367010206
# Compute control for a deterministic system
# Cost in iteration 0: 0.19879252367010206
# Cost in iteration 200: 0.19878997634577203
# Final cost : 0.19878997634577203
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878997634577203
# Cost in iteration 200: 0.1987899759966618
# Cost in iteration 400: 0.19878997598736955
# Final cost : 0.19878997598736955
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878997598736955
# Converged in iteration 47 with cost 0.1987899759872151 because of step counter
# Final cost : 0.1987899759872151
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.7422554386283828
# Cost in iteration 200: 0.2127975562858834
# Final cost : 0.2127975562858834
# Compute control for a deterministic system
# Cost in iteration 0: 0.2127975562858834
# Converged in iteration 179 with cost 0.21254030506596758 because of vanishing difference
# Final cost : 0.21254030506596758
# Compute control for a deterministic system
# Cost in iteration 0: 0.21254030506596758
# Cost in iteration 200: 0.2125298928651264
# Final cost : 0.2125298928651264
# Compute control for a deterministic system
# Cost in iteration 0: 0.2125298928651264
# Cost in iteration 200: 0.21252988583121177
# Cost in iteration 400: 0.21252988536425169
# Final cost : 0.21252988536425169
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988536425169
# Converged in iteration 191 with cost 0.21252988533357461 because of vanishing difference
# Final cost : 0.21252988533357461
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.5721356175763456
# Cost in iteration 200: 0.22660494577460702
# Final cost : 0.22660494577460702
# Compute control for a deterministic system
# Cost in iteration 0: 0.22660494577460702
# Cost in iteration 200: 0.2263545217427526
# Final cost : 0.2263545217427526
# Compute control for a deterministic system
# Cost in iteration 0: 0.2263545217427526
# Cost in iteration 200: 0.22634458432739787
# Final cost : 0.22634458432739787
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634458432739787
# Cost in iteration 200: 0.22634457862815405
# Cost in iteration 400: 0.22634457823585122
# Final cost : 0.22634457823585122
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634457823585122
# Cost in iteration 200: 0.22634457820824064
# Cost in iteration 400: 0.22634457820569295
# Converged in iteration 438 with cost 0.22634457820558884 because of step counter
# Final cost : 0.22634457820558884
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.7098981185096397
# Cost in iteration 200: 0.24054977913644
# Final cost : 0.24054977913644
# Compute control for a deterministic system
# Cost in iteration 0: 0.24054977913644
# Cost in iteration 200: 0.24024637550441927
# Final cost : 0.24024637550441927
# Compute control for a deterministic system
# Cost in iteration 0: 0.24024637550441927
# Cost in iteration 200: 0.24023209527523373
# Final cost : 0.24023209527523373
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023209527523373
# Cost in iteration 200: 0.24023209125948267
# Cost in iteration 400: 0.24023209096280368
# Final cost : 0.24023209096280368
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023209096280368
# Cost in iteration 200: 0.24023209093961845
# Cost in iteration 400: 0.24023209093688896
# Converged in iteration 461 with cost 0.24023209093669676 because of vanishing difference
# Final cost : 0.24023209093669676
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.2596972679265606
# Cost in iteration 200: 0.2515645172049168
# Final cost : 0.2515645172049168
# Compute control for a deterministic system
# Cost in iteration 0: 0.2515645172049168
# Cost in iteration 200: 0.25140467961356977
# Final cost : 0.25140467961356977
# Compute control for a deterministic system
# Cost in iteration 0: 0.25140467961356977
# Cost in iteration 200: 0.251393706534681
# Final cost : 0.251393706534681
# Compute control for a deterministic system
# Cost in iteration 0: 0.251393706534681
# Cost in iteration 200: 0.25139369594637007
# Cost in iteration 400: 0.2513936948337123
# Final cost : 0.2513936948337123
# Compute control for a deterministic system
# Cost in iteration 0: 0.2513936948337123
# Cost in iteration 200: 0.25139369471302947
# Cost in iteration 400: 0.25139369469657813
# Converged in iteration 536 with cost 0.2513936946946111 because of vanishing difference
# Final cost : 0.2513936946946111
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.24639453462249128
# Cost in iteration 200: 0.24055480277750332
# Final cost : 0.24055480277750332
# Compute control for a deterministic system
# Cost in iteration 0: 0.24055480277750332
# Cost in iteration 200: 0.24052624305603024
# Final cost : 0.24052624305603024
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052624305603024
# Cost in iteration 200: 0.24052209958887877
# Cost in iteration 400: 0.24052117009643226
# Final cost : 0.24052117009643226
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052117009643226
# Cost in iteration 200: 0.2405208916107738
# Cost in iteration 400: 0.24052088731770754
# Cost in iteration 600: 0.24052088726044651
# Converged in iteration 688 with cost 0.24052088725979381 because of step counter
# Final cost : 0.24052088725979381
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.7560642260094723
# Cost in iteration 200: 0.25020040449681674
# Final cost : 0.25020040449681674
# Compute control for a deterministic system
# Cost in iteration 0: 0.25020040449681674
# Cost in iteration 200: 0.2501667114924734
# Final cost : 0.2501667114924734
# Compute control for a deterministic system
# Cost in iteration 0: 0.2501667114924734
# Cost in iteration 200: 0.25016172378017837
# Cost in iteration 400: 0.250160457271684
# Final cost : 0.250160457271684
# Compute control for a deterministic system
# Cost in iteration 0: 0.250160457271684
# Cost in iteration 200: 0.2501600193045089
# Cost in iteration 400: 0.25016000902391927
# Cost in iteration 600: 0.2501600087881209
# Cost in iteration 800: 0.2501600087820621
# Converged in iteration 813 with cost 0.2501600087819732 because of step counter
# Final cost : 0.2501600087819732
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540102700069066
# Converged in iteration 32 with cost 0.22673034862719807 because of vanishing difference
# Final cost : 0.22673034862719807
# Compute control for a deterministic system
# Cost in iteration 0: 0.22673034862719807
# Cost in iteration 200: 0.22634529847043816
# Final cost : 0.22634529847043816
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634529847043816
# Cost in iteration 200: 0.22634463164196134
# Cost in iteration 400: 0.22634458193566312
# Final cost : 0.22634458193566312
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634458193566312
# Cost in iteration 200: 0.22634457847065842
# Cost in iteration 400: 0.22634457814557055
# Cost in iteration 600: 0.22634457811499234
# Cost in iteration 800: 0.22634457811212702
# Converged in iteration 842 with cost 0.22634457811194914 because of vanishing difference
# Final cost : 0.22634457811194914
# -----------------------------------------------
# 1 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.9342926787115553
# Cost in iteration 200: 0.21253913917132644
# Final cost : 0.21253913917132644
# Compute control for a deterministic system
# Cost in iteration 0: 0.21253913917132644
# Cost in iteration 200: 0.21252988924337332
# Final cost : 0.21252988924337332
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988924337332
# Cost in iteration 200: 0.21252988400389367
# Cost in iteration 400: 0.21252988365888423
# Final cost : 0.21252988365888423
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988365888423
# Cost in iteration 200: 0.21252988363555392
# Cost in iteration 400: 0.21252988363381023
# Converged in iteration 411 with cost 0.2125298836337941 because of step counter
# Final cost : 0.2125298836337941
# -----------------------------------------------
# 1 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.8079696058043693
# Cost in iteration 200: 0.19879332480482315
# Final cost : 0.19879332480482315
# Compute control for a deterministic system
# Cost in iteration 0: 0.19879332480482315
# Cost in iteration 200: 0.19878995931295068
# Final cost : 0.19878995931295068
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878995931295068
# Cost in iteration 200: 0.19878995916359962
# Cost in iteration 400: 0.1987899591593709
# Final cost : 0.1987899591593709
# Compute control for a deterministic system
# Cost in iteration 0: 0.1987899591593709
# Converged in iteration 10 with cost 0.1987899591593478 because of vanishing difference
# Final cost : 0.1987899591593478
# -----------------------------------------------
# 1 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.45683680530229276
# Cost in iteration 200: 0.18785879262701846
# Final cost : 0.18785879262701846
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785879262701846
# Cost in iteration 200: 0.1878537949219558
# Final cost : 0.1878537949219558
# Compute control for a deterministic system
# Cost in iteration 0: 0.1878537949219558
# Cost in iteration 200: 0.18785379029666083
# Cost in iteration 400: 0.18785379018559423
# Final cost : 0.18785379018559423
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785379018559423
# Converged in iteration 173 with cost 0.18785379018301707 because of step counter
# Final cost : 0.18785379018301707
# -----------------------------------------------
# 1 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.7418070761651689
# Cost in iteration 200: 0.17425807186158604
# Final cost : 0.17425807186158604
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425807186158604
# Converged in iteration 2 with cost 0.17425786532539356 because of vanishing difference
# Final cost : 0.17425786532539356
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425786532539356
# Cost in iteration 200: 0.1742568555184249
# Cost in iteration 400: 0.1742568542978902
# Final cost : 0.1742568542978902
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742568542978902
# Cost in iteration 200: 0.17425685428427928
# Converged in iteration 229 with cost 0.17425685428413043 because of vanishing difference
# Final cost : 0.17425685428413043
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.17784532687399676
# Cost in iteration 200: 0.1742654500642929
# Final cost : 0.1742654500642929
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742654500642929
# Cost in iteration 200: 0.17425678200905714
# Final cost : 0.17425678200905714
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425678200905714
# Cost in iteration 200: 0.1742567767034714
# Final cost : 0.1742567767034714
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742567767034714
# Converged in iteration 190 with cost 0.1742567767002634 because of step counter
# Final cost : 0.1742567767002634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742567767002634
# Converged in iteration 18 with cost 0.1742567767002444 because of step counter
# Final cost : 0.1742567767002444
# Compute control for a deterministic system
# Cost in iteration 0: 0.1914304227157601
# Cost in iteration 200: 0.18786486651779202
# Final cost : 0.18786486651779202
# Compute control for a deterministic system
# Cost in iteration 0: 0.18786486651779202
# Cost in iteration 200: 0.18785379934686935
# Final cost : 0.18785379934686935
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785379934686935
# Cost in iteration 200: 0.18785379021136925
# Final cost : 0.18785379021136925
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785379021136925
# Cost in iteration 200: 0.18785379020562915
# Converged in iteration 218 with cost 0.18785379020559684 because of step counter
# Final cost : 0.18785379020559684
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785379020559684
# Converged in iteration 3 with cost 0.1878537902055919 because of step counter
# Final cost : 0.1878537902055919
# Compute control for a deterministic system
# Cost in iteration 0: 0.20230108902324
# Cost in iteration 200: 0.19880330634455814
# Final cost : 0.19880330634455814
# Compute control for a deterministic system
# Cost in iteration 0: 0.19880330634455814
# Cost in iteration 200: 0.19878997289812458
# Final cost : 0.19878997289812458
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878997289812458
# Cost in iteration 200: 0.1987899592127567
# Final cost : 0.1987899592127567
# Compute control for a deterministic system
# Cost in iteration 0: 0.1987899592127567
# Converged in iteration 98 with cost 0.19878995921189277 because of step counter
# Final cost : 0.19878995921189277
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878995921189277
# Converged in iteration 1 with cost 0.19878995921189277 because of step counter
# Final cost : 0.19878995921189277
# Compute control for a deterministic system
# Cost in iteration 0: 0.21587369068760626
# Cost in iteration 200: 0.21254663519595285
# Final cost : 0.21254663519595285
# Compute control for a deterministic system
# Cost in iteration 0: 0.21254663519595285
# Cost in iteration 200: 0.2125299064007125
# Final cost : 0.2125299064007125
# Compute control for a deterministic system
# Cost in iteration 0: 0.2125299064007125
# Cost in iteration 200: 0.21252988368990627
# Final cost : 0.21252988368990627
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988368990627
# Cost in iteration 200: 0.21252988367759149
# Converged in iteration 205 with cost 0.21252988367754566 because of vanishing difference
# Final cost : 0.21252988367754566
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988367754566
# Converged in iteration 79 with cost 0.21252988367702216 because of step counter
# Final cost : 0.21252988367702216
# Compute control for a deterministic system
# Cost in iteration 0: 0.22941028054510285
# Cost in iteration 200: 0.22636545891740334
# Final cost : 0.22636545891740334
# Compute control for a deterministic system
# Cost in iteration 0: 0.22636545891740334
# Converged in iteration 92 with cost 0.22634517583020602 because of vanishing difference
# Final cost : 0.22634517583020602
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634517583020602
# Cost in iteration 200: 0.22634457822975612
# Final cost : 0.22634457822975612
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634457822975612
# Cost in iteration 200: 0.22634457817092352
# Cost in iteration 400: 0.22634457816676476
# Final cost : 0.22634457816676476
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634457816676476
# Converged in iteration 67 with cost 0.22634457816658143 because of step counter
# Final cost : 0.22634457816658143
# Compute control for a deterministic system
# Cost in iteration 0: 0.24290523764021216
# Cost in iteration 200: 0.24025774616562703
# Final cost : 0.24025774616562703
# Compute control for a deterministic system
# Cost in iteration 0: 0.24025774616562703
# Converged in iteration 77 with cost 0.24023356974547164 because of vanishing difference
# Final cost : 0.24023356974547164
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023356974547164
# Cost in iteration 200: 0.24023209102479284
# Final cost : 0.24023209102479284
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023209102479284
# Cost in iteration 200: 0.24023209099012865
# Cost in iteration 400: 0.24023209098748044
# Final cost : 0.24023209098748044
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023209098748044
# Converged in iteration 2 with cost 0.24023209098747578 because of step counter
# Final cost : 0.24023209098747578
# Compute control for a deterministic system
# Cost in iteration 0: 0.24179803350961887
# Cost in iteration 200: 0.2405411540579825
# Final cost : 0.2405411540579825
# Compute control for a deterministic system
# Cost in iteration 0: 0.2405411540579825
# Cost in iteration 200: 0.2405208911060594
# Final cost : 0.2405208911060594
# Compute control for a deterministic system
# Cost in iteration 0: 0.2405208911060594
# Cost in iteration 200: 0.24052088764724847
# Final cost : 0.24052088764724847
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052088764724847
# Cost in iteration 200: 0.2405208873464869
# Cost in iteration 400: 0.24052088727998824
# Final cost : 0.24052088727998824
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052088727998824
# Cost in iteration 200: 0.2405208872599799
# Converged in iteration 224 with cost 0.24052088725983775 because of step counter
# Final cost : 0.24052088725983775
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.1752091643985187
# Cost in iteration 200: 0.17425677732392675
# Final cost : 0.17425677732392675
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425677732392675
# Cost in iteration 200: 0.1742567758745346
# Final cost : 0.1742567758745346
# Compute control for a deterministic system
# Cost in iteration 0: 0.1742567758745346
# Converged in iteration 34 with cost 0.17425677587183458 because of vanishing difference
# Final cost : 0.17425677587183458
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425677587183458
# Converged in iteration 118 with cost 0.17425677587084779 because of step counter
# Final cost : 0.17425677587084779
# Compute control for a deterministic system
# Cost in iteration 0: 0.17425677587084779
# Converged in iteration 1 with cost 0.17425677587084779 because of step counter
# Final cost : 0.17425677587084779
# -----------------------------------------------
# 5 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.18894730110403093
# Cost in iteration 200: 0.18785378990225732
# Final cost : 0.18785378990225732
# Compute control for a deterministic system
# Cost in iteration 0: 0.18785378990225732
# Cost in iteration 200: 0.187853787929846
# Final cost : 0.187853787929846
# Compute control for a deterministic system
# Cost in iteration 0: 0.187853787929846
# Converged in iteration 124 with cost 0.1878537879232761 because of step counter
# Final cost : 0.1878537879232761
# Compute control for a deterministic system
# Cost in iteration 0: 0.1878537879232761
# Converged in iteration 1 with cost 0.1878537879232761 because of step counter
# Final cost : 0.1878537879232761
# Compute control for a deterministic system
# Cost in iteration 0: 0.1878537879232761
# Converged in iteration 1 with cost 0.1878537879232761 because of step counter
# Final cost : 0.1878537879232761
# -----------------------------------------------
# 5 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.20000268357331763
# Cost in iteration 200: 0.19878995639263733
# Final cost : 0.19878995639263733
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878995639263733
# Cost in iteration 200: 0.1987899539234763
# Final cost : 0.1987899539234763
# Compute control for a deterministic system
# Cost in iteration 0: 0.1987899539234763
# Converged in iteration 125 with cost 0.19878995391417784 because of step counter
# Final cost : 0.19878995391417784
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878995391417784
# Converged in iteration 1 with cost 0.19878995391417784 because of step counter
# Final cost : 0.19878995391417784
# Compute control for a deterministic system
# Cost in iteration 0: 0.19878995391417784
# Converged in iteration 1 with cost 0.19878995391417784 because of step counter
# Final cost : 0.19878995391417784
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.21389938388269375
# Cost in iteration 200: 0.21252988255237734
# Final cost : 0.21252988255237734
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252988255237734
# Converged in iteration 192 with cost 0.2125298793511507 because of vanishing difference
# Final cost : 0.2125298793511507
# Compute control for a deterministic system
# Cost in iteration 0: 0.2125298793511507
# Converged in iteration 146 with cost 0.2125298793350374 because of step counter
# Final cost : 0.2125298793350374
# Compute control for a deterministic system
# Cost in iteration 0: 0.2125298793350374
# Converged in iteration 12 with cost 0.21252987933501263 because of vanishing difference
# Final cost : 0.21252987933501263
# Compute control for a deterministic system
# Cost in iteration 0: 0.21252987933501263
# Converged in iteration 1 with cost 0.21252987933501263 because of step counter
# Final cost : 0.21252987933501263
# -----------------------------------------------
# 5 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.22787941435981263
# Cost in iteration 200: 0.2263445767498911
# Final cost : 0.2263445767498911
# Compute control for a deterministic system
# Cost in iteration 0: 0.2263445767498911
# Cost in iteration 200: 0.2263445726686098
# Final cost : 0.2263445726686098
# Compute control for a deterministic system
# Cost in iteration 0: 0.2263445726686098
# Converged in iteration 146 with cost 0.2263445726483029 because of step counter
# Final cost : 0.2263445726483029
# Compute control for a deterministic system
# Cost in iteration 0: 0.2263445726483029
# Converged in iteration 2 with cost 0.22634457264830174 because of step counter
# Final cost : 0.22634457264830174
# Compute control for a deterministic system
# Cost in iteration 0: 0.22634457264830174
# Converged in iteration 1 with cost 0.22634457264830174 because of step counter
# Final cost : 0.22634457264830174
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.2419411016560263
# Cost in iteration 200: 0.24023209098728457
# Final cost : 0.24023209098728457
# Compute control for a deterministic system
# Cost in iteration 0: 0.24023209098728457
# Cost in iteration 200: 0.2402320858914775
# Final cost : 0.2402320858914775
# Compute control for a deterministic system
# Cost in iteration 0: 0.2402320858914775
# Converged in iteration 148 with cost 0.240232085865315 because of step counter
# Final cost : 0.240232085865315
# Compute control for a deterministic system
# Cost in iteration 0: 0.240232085865315
# Converged in iteration 1 with cost 0.240232085865315 because of step counter
# Final cost : 0.240232085865315
# Compute control for a deterministic system
# Cost in iteration 0: 0.240232085865315
# Converged in iteration 9 with cost 0.24023208586530706 because of step counter
# Final cost : 0.24023208586530706
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.24280619770310682
# Cost in iteration 200: 0.24052089081337275
# Final cost : 0.24052089081337275
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052089081337275
# Cost in iteration 200: 0.240520887262351
# Final cost : 0.240520887262351
# Compute control for a deterministic system
# Cost in iteration 0: 0.240520887262351
# Cost in iteration 200: 0.24052088726012424
# Final cost : 0.24052088726012424
# Compute control for a deterministic system
# Cost in iteration 0: 0.24052088726012424
# Converged in iteration 35 with cost 0.2405208872600232 because of step counter
# Final cost : 0.2405208872600232
# Compute control for a deterministic system
# Cost in iteration 0: 0.2405208872600232
# Converged in iteration 1 with cost 0.2405208872600232 because of step counter
# Final cost : 0.2405208872600232

# %%
save(results_min)
