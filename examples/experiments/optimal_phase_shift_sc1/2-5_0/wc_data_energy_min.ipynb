# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,53], wc.inh[0,53]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# minima =  [  93  284  474  665  856 1046 1237 1428 1619 1809 2000 2191 2381 2572
#  2763 2953 3144 3335 3526 3716 3907]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [True, True, False, False, True, True, False, False]
#options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * factor
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06418027096300696
# Final cost : 0.001670745997380794
# Compute control for a deterministic system
# Cost in iteration 0: 0.001670745997380794
# Final cost : 8.685517135681523e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.685517135681523e-05
# Final cost : 8.526634530891283e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.526634530891283e-05
# Final cost : 8.524692055318388e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.524692055318388e-05
# Converged in iteration 224 with cost 8.524688819716561e-05 because of step counter
# Final cost : 8.524688819716561e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.524688819716561e-05
# Converged in iteration 1 with cost 8.524688819716561e-05 because of step counter
# Final cost : 8.524688819716561e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.24852550056353864
# Final cost : 0.012023174969924654
# Compute control for a deterministic system
# Cost in iteration 0: 0.012023174969924654
# Final cost : 0.00035484552006284
# Compute control for a deterministic system
# Cost in iteration 0: 0.00035484552006284
# Final cost : 0.00034281519784605606
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034281519784605606
# Final cost : 0.0003425934680707604
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003425934680707604
# Converged in iteration 243 with cost 0.0003425929097025927 because of step counter
# Final cost : 0.0003425929097025927
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003425929097025927
# Converged in iteration 2 with cost 0.0003425929097025757 because of step counter
# Final cost : 0.0003425929097025757
# Compute control for a deterministic system
# Cost in iteration 0: 0.4691341853309771
# Final cost : 0.03772140714478413
# Compute control for a deterministic system
# Cost in iteration 0: 0.03772140714478413
# Final cost : 0.000709983196463562
# Compute control for a deterministic system
# Cost in iteration 0: 0.000709983196463562
# Final cost : 0.0006744881256873549
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006744881256873549
# Final cost : 0.0006738850895725258
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006738850895725258
# Final cost : 0.0006738836976089241
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006738836976089241
# Converged in iteration 1192 with cost 0.0006738836845547368 because of step counter
# Final cost : 0.0006738836845547368
# Compute control for a deterministic system
# Cost in iteration 0: 0.8151174669388772
# Final cost : 0.11248643551886493
# Compute control for a deterministic system
# Cost in iteration 0: 0.11248643551886493
# Final cost : 0.0013438068575916684
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013438068575916684
# Final cost : 0.0012462657592104411
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012462657592104411
# Final cost : 0.001244974147509486
# Compute control for a deterministic system
# Cost in iteration 0: 0.001244974147509486
# Converged in iteration 236 with cost 0.0012449732512125006 because of step counter
# Final cost : 0.0012449732512125006
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012449732512125006
# Converged in iteration 1 with cost 0.0012449732512125006 because of step counter
# Final cost : 0.0012449732512125006
# Compute control for a deterministic system
# Cost in iteration 0: 1.2143457887266047
# Final cost : 0.256594882056283
# Compute control for a deterministic system
# Cost in iteration 0: 0.256594882056283
# Final cost : 0.002199313834792258
# Compute control for a deterministic system
# Cost in iteration 0: 0.002199313834792258
# Final cost : 0.0019883881889407188
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019883881889407188
# Final cost : 0.001985932266429154
# Compute control for a deterministic system
# Cost in iteration 0: 0.001985932266429154
# Final cost : 0.001985929014703594
# Compute control for a deterministic system
# Cost in iteration 0: 0.001985929014703594
# Converged in iteration 266 with cost 0.0019859290140000676 because of step counter
# Final cost : 0.0019859290140000676
# Compute control for a deterministic system
# Cost in iteration 0: 1.642417935762891
# Final cost : 0.4858021059844985
# Compute control for a deterministic system
# Cost in iteration 0: 0.4858021059844985
# Final cost : 0.003272214664116321
# Compute control for a deterministic system
# Cost in iteration 0: 0.003272214664116321
# Final cost : 0.0028911829075665228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028911829075665228
# Final cost : 0.0028875512816546674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028875512816546674
# Final cost : 0.0028875440523632025
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028875440523632025
# Converged in iteration 1309 with cost 0.0028875439468260848 because of step counter
# Final cost : 0.0028875439468260848
# Compute control for a deterministic system
# Cost in iteration 0: 1.9916874105899045
# Final cost : 0.7347400874464591
# Compute control for a deterministic system
# Cost in iteration 0: 0.7347400874464591
# Final cost : 0.004279149103304077
# Compute control for a deterministic system
# Cost in iteration 0: 0.004279149103304077
# Final cost : 0.003722966467545285
# Compute control for a deterministic system
# Cost in iteration 0: 0.003722966467545285
# Final cost : 0.003718122382859354
# Compute control for a deterministic system
# Cost in iteration 0: 0.003718122382859354
# Final cost : 0.003718118693744062
# Compute control for a deterministic system
# Cost in iteration 0: 0.003718118693744062
# Converged in iteration 1095 with cost 0.0037181186331589934 because of step counter
# Final cost : 0.0037181186331589934
# Compute control for a deterministic system
# Cost in iteration 0: 2.422198951402198
# Final cost : 1.1247756966692128
# Compute control for a deterministic system
# Cost in iteration 0: 1.1247756966692128
# Final cost : 0.005730044392448435
# Compute control for a deterministic system
# Cost in iteration 0: 0.005730044392448435
# Final cost : 0.004895775631811569
# Compute control for a deterministic system
# Cost in iteration 0: 0.004895775631811569
# Final cost : 0.004889218986310013
# Compute control for a deterministic system
# Cost in iteration 0: 0.004889218986310013
# Final cost : 0.004889212798301864
# Compute control for a deterministic system
# Cost in iteration 0: 0.004889212798301864
# Converged in iteration 391 with cost 0.004889212702986178 because of step counter
# Final cost : 0.004889212702986178
# Compute control for a deterministic system
# Cost in iteration 0: 2.832232164870778
# Final cost : 1.5892299202220088
# Compute control for a deterministic system
# Cost in iteration 0: 1.5892299202220088
# Final cost : 0.007423706979575353
# Compute control for a deterministic system
# Cost in iteration 0: 0.007423706979575353
# Final cost : 0.0062214886802420735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0062214886802420735
# Final cost : 0.006212006919591639
# Compute control for a deterministic system
# Cost in iteration 0: 0.006212006919591639
# Final cost : 0.0062119957475571235
# Compute control for a deterministic system
# Cost in iteration 0: 0.0062119957475571235
# Converged in iteration 550 with cost 0.006211995585617666 because of step counter
# Final cost : 0.006211995585617666
# Compute control for a deterministic system
# Cost in iteration 0: 3.2094432249455096
# Final cost : 2.1033720518259944
# Compute control for a deterministic system
# Cost in iteration 0: 2.1033720518259944
# Final cost : 0.009399419724362718
# Compute control for a deterministic system
# Cost in iteration 0: 0.009399419724362718
# Final cost : 0.007711119494181521
# Compute control for a deterministic system
# Cost in iteration 0: 0.007711119494181521
# Final cost : 0.0076976775891161925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0076976775891161925
# Final cost : 0.007697677463243957
# Compute control for a deterministic system
# Cost in iteration 0: 0.007697677463243957
# Converged in iteration 193 with cost 0.007697677462956513 because of step counter
# Final cost : 0.007697677462956513
# Compute control for a deterministic system
# Cost in iteration 0: 3.4810747048614687
# Final cost : 2.5270828824270812
# Compute control for a deterministic system
# Cost in iteration 0: 2.5270828824270812
# Final cost : 0.01120772790372536
# Compute control for a deterministic system
# Cost in iteration 0: 0.01120772790372536
# Final cost : 0.009029239320367513
# Compute control for a deterministic system
# Cost in iteration 0: 0.009029239320367513
# Final cost : 0.00901210516945154
# Compute control for a deterministic system
# Cost in iteration 0: 0.00901210516945154
# Final cost : 0.009012032965831385
# Compute control for a deterministic system
# Cost in iteration 0: 0.009012032965831385
# Converged in iteration 1218 with cost 0.009012032873890442 because of step counter
# Final cost : 0.009012032873890442
# Compute control for a deterministic system
# Cost in iteration 0: 3.7776590348045462
# Final cost : 3.037436126518656
# Compute control for a deterministic system
# Cost in iteration 0: 3.037436126518656
# Final cost : 0.013779823594656465
# Compute control for a deterministic system
# Cost in iteration 0: 0.013779823594656465
# Final cost : 0.010843790630320732
# Compute control for a deterministic system
# Cost in iteration 0: 0.010843790630320732
# Final cost : 0.010820442121148988
# Compute control for a deterministic system
# Cost in iteration 0: 0.010820442121148988
# Final cost : 0.010820395302964211
# Compute control for a deterministic system
# Cost in iteration 0: 0.010820395302964211
# Converged in iteration 1506 with cost 0.010820394730366447 because of step counter
# Final cost : 0.010820394730366447
# Compute control for a deterministic system
# Cost in iteration 0: 4.024385763814507
# Final cost : 3.4898823853269882
# Compute control for a deterministic system
# Cost in iteration 0: 3.4898823853269882
# Final cost : 0.016726690468379365
# Compute control for a deterministic system
# Cost in iteration 0: 0.016726690468379365
# Final cost : 0.012849115355750368
# Compute control for a deterministic system
# Cost in iteration 0: 0.012849115355750368
# Final cost : 0.012817872012091594
# Compute control for a deterministic system
# Cost in iteration 0: 0.012817872012091594
# Final cost : 0.012817851421669803
# Compute control for a deterministic system
# Cost in iteration 0: 0.012817851421669803
# Converged in iteration 1734 with cost 0.012817850745002746 because of step counter
# Final cost : 0.012817850745002746
# Compute control for a deterministic system
# Cost in iteration 0: 4.222764679623928
# Final cost : 3.859368004891278
# Compute control for a deterministic system
# Cost in iteration 0: 3.859368004891278
# Final cost : 0.020080638821336146
# Compute control for a deterministic system
# Cost in iteration 0: 0.020080638821336146
# Final cost : 0.01504819634377127
# Compute control for a deterministic system
# Cost in iteration 0: 0.01504819634377127
# Final cost : 0.015007167503401508
# Compute control for a deterministic system
# Cost in iteration 0: 0.015007167503401508
# Final cost : 0.01500715396273011
# Compute control for a deterministic system
# Cost in iteration 0: 0.01500715396273011
# Converged in iteration 769 with cost 0.015007153567130924 because of step counter
# Final cost : 0.015007153567130924
# Compute control for a deterministic system
# Cost in iteration 0: 4.377042068012568
# Final cost : 4.141271911468256
# Compute control for a deterministic system
# Cost in iteration 0: 4.141271911468256
# Final cost : 0.023878183544897354
# Compute control for a deterministic system
# Cost in iteration 0: 0.023878183544897354
# Final cost : 0.017444176054889134
# Compute control for a deterministic system
# Cost in iteration 0: 0.017444176054889134
# Final cost : 0.01739216064271149
# Compute control for a deterministic system
# Cost in iteration 0: 0.01739216064271149
# Final cost : 0.017389625787072913
# Compute control for a deterministic system
# Cost in iteration 0: 0.017389625787072913
# Final cost : 0.017389535221711463
# Compute control for a deterministic system
# Cost in iteration 0: 4.472286977649341
# Final cost : 4.310304453772829
# Compute control for a deterministic system
# Cost in iteration 0: 4.310304453772829
# Final cost : 0.027265183077933262
# Compute control for a deterministic system
# Cost in iteration 0: 0.027265183077933262
# Final cost : 0.019500791451362378
# Compute control for a deterministic system
# Cost in iteration 0: 0.019500791451362378
# Final cost : 0.01943893320592889
# Compute control for a deterministic system
# Cost in iteration 0: 0.01943893320592889
# Final cost : 0.019435170135992403
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435170135992403
# Converged in iteration 1450 with cost 0.019435013010448227 because of step counter
# Final cost : 0.019435013010448227
# Compute control for a deterministic system
# Cost in iteration 0: 4.560482750669695
# Final cost : 4.463387782718732
# Compute control for a deterministic system
# Cost in iteration 0: 4.463387782718732
# Final cost : 0.03198013450094809
# Compute control for a deterministic system
# Cost in iteration 0: 0.03198013450094809
# Final cost : 0.022250765603759243
# Compute control for a deterministic system
# Cost in iteration 0: 0.022250765603759243
# Final cost : 0.02217313122827957
# Compute control for a deterministic system
# Cost in iteration 0: 0.02217313122827957
# Final cost : 0.02216735343546318
# Compute control for a deterministic system
# Cost in iteration 0: 0.02216735343546318
# Final cost : 0.02216711861192854
# Compute control for a deterministic system
# Cost in iteration 0: 4.6184694358424725
# Final cost : 4.564400276166686
# Compute control for a deterministic system
# Cost in iteration 0: 4.564400276166686
# Final cost : 0.037292909875646194
# Compute control for a deterministic system
# Cost in iteration 0: 0.037292909875646194
# Final cost : 0.025202870232190745
# Compute control for a deterministic system
# Cost in iteration 0: 0.025202870232190745
# Final cost : 0.02510261213688375
# Compute control for a deterministic system
# Cost in iteration 0: 0.02510261213688375
# Final cost : 0.025095539602825106
# Compute control for a deterministic system
# Cost in iteration 0: 0.025095539602825106
# Final cost : 0.02509512265972155
# Compute control for a deterministic system
# Cost in iteration 0: 4.649498792273404
# Final cost : 4.62334056630998
# Compute control for a deterministic system
# Cost in iteration 0: 4.62334056630998
# Final cost : 0.04329294114722028
# Compute control for a deterministic system
# Cost in iteration 0: 0.04329294114722028
# Final cost : 0.028357582958945634
# Compute control for a deterministic system
# Cost in iteration 0: 0.028357582958945634
# Final cost : 0.028230165383485592
# Compute control for a deterministic system
# Cost in iteration 0: 0.028230165383485592
# Final cost : 0.028220775057188407
# Compute control for a deterministic system
# Cost in iteration 0: 0.028220775057188407
# Final cost : 0.028220610951574406
# Compute control for a deterministic system
# Cost in iteration 0: 4.656293785637355
# Final cost : 4.644377285475559
# Compute control for a deterministic system
# Cost in iteration 0: 4.644377285475559
# Final cost : 0.048676611342832056
# Compute control for a deterministic system
# Cost in iteration 0: 0.048676611342832056
# Final cost : 0.03103005620438737
# Compute control for a deterministic system
# Cost in iteration 0: 0.03103005620438737
# Final cost : 0.0308775672656874
# Compute control for a deterministic system
# Cost in iteration 0: 0.0308775672656874
# Final cost : 0.030864541095920784
# Compute control for a deterministic system
# Cost in iteration 0: 0.030864541095920784
# Final cost : 0.030864465146892693
# Compute control for a deterministic system
# Cost in iteration 0: 4.6429963757233885
# Final cost : 4.640256921575637
# Compute control for a deterministic system
# Cost in iteration 0: 4.640256921575637
# Final cost : 0.056399636374664136
# Compute control for a deterministic system
# Cost in iteration 0: 0.056399636374664136
# Final cost : 0.034566593144653046
# Compute control for a deterministic system
# Cost in iteration 0: 0.034566593144653046
# Final cost : 0.03436870641838478
# Compute control for a deterministic system
# Cost in iteration 0: 0.03436870641838478
# Final cost : 0.0343513970871965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0343513970871965
# Final cost : 0.03435043062209519
# Compute control for a deterministic system
# Cost in iteration 0: 4.605246730927961
# Final cost : 4.601515205264208
# Compute control for a deterministic system
# Cost in iteration 0: 4.601515205264208
# Final cost : 0.03446292946563959
# Compute control for a deterministic system
# Cost in iteration 0: 0.03446292946563959
# Final cost : 0.0232263415501261
# Compute control for a deterministic system
# Cost in iteration 0: 0.0232263415501261
# Final cost : 0.02303455239630437
# Compute control for a deterministic system
# Cost in iteration 0: 0.02303455239630437
# Final cost : 0.023025213291396562
# Compute control for a deterministic system
# Cost in iteration 0: 0.023025213291396562
# Converged in iteration 1131 with cost 0.023023505707439357 because of step counter
# Final cost : 0.023023505707439357
# Compute control for a deterministic system
# Cost in iteration 0: 4.54150952932075
# Final cost : 4.523179385865063
# Compute control for a deterministic system
# Cost in iteration 0: 4.523179385865063
# Final cost : 0.02958422175324017
# Compute control for a deterministic system
# Cost in iteration 0: 0.02958422175324017
# Final cost : 0.020674526939470788
# Compute control for a deterministic system
# Cost in iteration 0: 0.020674526939470788
# Final cost : 0.020523967551397806
# Compute control for a deterministic system
# Cost in iteration 0: 0.020523967551397806
# Final cost : 0.020516016406085635
# Compute control for a deterministic system
# Cost in iteration 0: 0.020516016406085635
# Converged in iteration 723 with cost 0.020514732013344847 because of step counter
# Final cost : 0.020514732013344847
# Compute control for a deterministic system
# Cost in iteration 0: 4.469781581583304
# Final cost : 4.42528672680261
# Compute control for a deterministic system
# Cost in iteration 0: 4.42528672680261
# Final cost : 0.02622266466113482
# Compute control for a deterministic system
# Cost in iteration 0: 0.02622266466113482
# Final cost : 0.01873659688648253
# Compute control for a deterministic system
# Cost in iteration 0: 0.01873659688648253
# Final cost : 0.018611272935301928
# Compute control for a deterministic system
# Cost in iteration 0: 0.018611272935301928
# Final cost : 0.01860482931346257
# Compute control for a deterministic system
# Cost in iteration 0: 0.01860482931346257
# Converged in iteration 724 with cost 0.018603911626194198 because of step counter
# Final cost : 0.018603911626194198
# Compute control for a deterministic system
# Cost in iteration 0: 4.350438615351134
# Final cost : 4.245804436023311
# Compute control for a deterministic system
# Cost in iteration 0: 4.245804436023311
# Final cost : 0.02244139372615356
# Compute control for a deterministic system
# Cost in iteration 0: 0.02244139372615356
# Final cost : 0.016435166637196318
# Compute control for a deterministic system
# Cost in iteration 0: 0.016435166637196318
# Final cost : 0.016341483817622002
# Compute control for a deterministic system
# Cost in iteration 0: 0.016341483817622002
# Final cost : 0.016337739460061066
# Compute control for a deterministic system
# Cost in iteration 0: 0.016337739460061066
# Converged in iteration 866 with cost 0.01633724612610622 because of vanishing difference
# Final cost : 0.01633724612610622
# Compute control for a deterministic system
# Cost in iteration 0: 4.192895296075554
# Final cost : 3.984512735475003
# Compute control for a deterministic system
# Cost in iteration 0: 3.984512735475003
# Final cost : 0.019047647793677614
# Compute control for a deterministic system
# Cost in iteration 0: 0.019047647793677614
# Final cost : 0.014283562892243085
# Compute control for a deterministic system
# Cost in iteration 0: 0.014283562892243085
# Final cost : 0.014211249950808408
# Compute control for a deterministic system
# Cost in iteration 0: 0.014211249950808408
# Final cost : 0.014208119201029388
# Compute control for a deterministic system
# Cost in iteration 0: 0.014208119201029388
# Converged in iteration 910 with cost 0.014207806624112761 because of step counter
# Final cost : 0.014207806624112761
# Compute control for a deterministic system
# Cost in iteration 0: 3.9912569582276642
# Final cost : 3.6243788742973746
# Compute control for a deterministic system
# Cost in iteration 0: 3.6243788742973746
# Final cost : 0.01599793200029814
# Compute control for a deterministic system
# Cost in iteration 0: 0.01599793200029814
# Final cost : 0.012272934690414915
# Compute control for a deterministic system
# Cost in iteration 0: 0.012272934690414915
# Final cost : 0.012219714730748578
# Compute control for a deterministic system
# Cost in iteration 0: 0.012219714730748578
# Final cost : 0.01221775559392511
# Compute control for a deterministic system
# Cost in iteration 0: 0.01221775559392511
# Converged in iteration 1046 with cost 0.012217590996202716 because of step counter
# Final cost : 0.012217590996202716
# Compute control for a deterministic system
# Cost in iteration 0: 3.740870126000062
# Final cost : 3.1646154483977695
# Compute control for a deterministic system
# Cost in iteration 0: 3.1646154483977695
# Final cost : 0.013264981548131547
# Compute control for a deterministic system
# Cost in iteration 0: 0.013264981548131547
# Final cost : 0.010409924513787118
# Compute control for a deterministic system
# Cost in iteration 0: 0.010409924513787118
# Final cost : 0.010369931424338109
# Compute control for a deterministic system
# Cost in iteration 0: 0.010369931424338109
# Final cost : 0.010368732095497274
# Compute control for a deterministic system
# Cost in iteration 0: 0.010368732095497274
# Converged in iteration 895 with cost 0.010368641824033345 because of step counter
# Final cost : 0.010368641824033345
# Compute control for a deterministic system
# Cost in iteration 0: 3.504398919028858
# Final cost : 2.7416937465494584
# Compute control for a deterministic system
# Cost in iteration 0: 2.7416937465494584
# Final cost : 0.011293565580258048
# Compute control for a deterministic system
# Cost in iteration 0: 0.011293565580258048
# Final cost : 0.009023332256475084
# Compute control for a deterministic system
# Cost in iteration 0: 0.009023332256475084
# Final cost : 0.008993475660466738
# Compute control for a deterministic system
# Cost in iteration 0: 0.008993475660466738
# Final cost : 0.008992591685094455
# Compute control for a deterministic system
# Cost in iteration 0: 0.008992591685094455
# Converged in iteration 639 with cost 0.008992591130639676 because of step counter
# Final cost : 0.008992591130639676
# Compute control for a deterministic system
# Cost in iteration 0: 3.166084511930819
# Final cost : 2.182387948163271
# Compute control for a deterministic system
# Cost in iteration 0: 2.182387948163271
# Final cost : 0.00908481294922439
# Compute control for a deterministic system
# Cost in iteration 0: 0.00908481294922439
# Final cost : 0.007424813912827426
# Compute control for a deterministic system
# Cost in iteration 0: 0.007424813912827426
# Final cost : 0.007403636385350737
# Compute control for a deterministic system
# Cost in iteration 0: 0.007403636385350737
# Final cost : 0.007403205718384717
# Compute control for a deterministic system
# Cost in iteration 0: 0.007403205718384717
# Converged in iteration 459 with cost 0.007403180294419539 because of step counter
# Final cost : 0.007403180294419539
# Compute control for a deterministic system
# Cost in iteration 0: 2.78740166521945
# Final cost : 1.6361722737081956
# Compute control for a deterministic system
# Cost in iteration 0: 1.6361722737081956
# Final cost : 0.007147486859987805
# Compute control for a deterministic system
# Cost in iteration 0: 0.007147486859987805
# Final cost : 0.005975654076683703
# Compute control for a deterministic system
# Cost in iteration 0: 0.005975654076683703
# Final cost : 0.005961162162304638
# Compute control for a deterministic system
# Cost in iteration 0: 0.005961162162304638
# Final cost : 0.005960957806250732
# Compute control for a deterministic system
# Cost in iteration 0: 0.005960957806250732
# Converged in iteration 530 with cost 0.005960948347525191 because of step counter
# Final cost : 0.005960948347525191
# Compute control for a deterministic system
# Cost in iteration 0: 2.3793757814022096
# Final cost : 1.1454029649510067
# Compute control for a deterministic system
# Cost in iteration 0: 1.1454029649510067
# Final cost : 0.005469207948589034
# Compute control for a deterministic system
# Cost in iteration 0: 0.005469207948589034
# Final cost : 0.0046780447056082915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0046780447056082915
# Final cost : 0.004668335859440581
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668335859440581
# Final cost : 0.004668243483479718
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668243483479718
# Converged in iteration 486 with cost 0.0046682400229006 because of vanishing difference
# Final cost : 0.0046682400229006
# Compute control for a deterministic system
# Cost in iteration 0: 2.0401914197456916
# Final cost : 0.8119574017576691
# Compute control for a deterministic system
# Cost in iteration 0: 0.8119574017576691
# Final cost : 0.004305240099963541
# Compute control for a deterministic system
# Cost in iteration 0: 0.004305240099963541
# Final cost : 0.003750571702888095
# Compute control for a deterministic system
# Cost in iteration 0: 0.003750571702888095
# Final cost : 0.003743541994030662
# Compute control for a deterministic system
# Cost in iteration 0: 0.003743541994030662
# Final cost : 0.0037435139542907237
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037435139542907237
# Converged in iteration 422 with cost 0.003743513093421407 because of vanishing difference
# Final cost : 0.003743513093421407
# Compute control for a deterministic system
# Cost in iteration 0: 1.610341146338599
# Final cost : 0.4809890300952349
# Compute control for a deterministic system
# Cost in iteration 0: 0.4809890300952349
# Final cost : 0.0030640085517826808
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030640085517826808
# Final cost : 0.002731445862183443
# Compute control for a deterministic system
# Cost in iteration 0: 0.002731445862183443
# Final cost : 0.002726788277610609
# Compute control for a deterministic system
# Cost in iteration 0: 0.002726788277610609
# Converged in iteration 818 with cost 0.0027267631159580796 because of step counter
# Final cost : 0.0027267631159580796
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027267631159580796
# Converged in iteration 2 with cost 0.0027267631159580362 because of step counter
# Final cost : 0.0027267631159580362
# Compute control for a deterministic system
# Cost in iteration 0: 1.18704417491227
# Final cost : 0.24780222738130375
# Compute control for a deterministic system
# Cost in iteration 0: 0.24780222738130375
# Final cost : 0.002050018831923559
# Compute control for a deterministic system
# Cost in iteration 0: 0.002050018831923559
# Final cost : 0.001870206415491314
# Compute control for a deterministic system
# Cost in iteration 0: 0.001870206415491314
# Final cost : 0.0018671893641509284
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018671893641509284
# Converged in iteration 764 with cost 0.0018671716917505743 because of step counter
# Final cost : 0.0018671716917505743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018671716917505743
# Converged in iteration 1 with cost 0.0018671716917505743 because of step counter
# Final cost : 0.0018671716917505743
# Compute control for a deterministic system
# Cost in iteration 0: 0.7915802919645731
# Final cost : 0.10524945818817029
# Compute control for a deterministic system
# Cost in iteration 0: 0.10524945818817029
# Final cost : 0.0012525368715055267
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012525368715055267
# Final cost : 0.001168972138798994
# Compute control for a deterministic system
# Cost in iteration 0: 0.001168972138798994
# Final cost : 0.0011672028246027056
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011672028246027056
# Converged in iteration 308 with cost 0.0011671938032876677 because of vanishing difference
# Final cost : 0.0011671938032876677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011671938032876677
# Converged in iteration 33 with cost 0.0011671938032699375 because of step counter
# Final cost : 0.0011671938032699375
# Compute control for a deterministic system
# Cost in iteration 0: 0.5128808471624567
# Final cost : 0.04391175791629759
# Compute control for a deterministic system
# Cost in iteration 0: 0.04391175791629759
# Final cost : 0.0007629188346270374
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007629188346270374
# Final cost : 0.0007245267592502417
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007245267592502417
# Final cost : 0.00072360829591711
# Compute control for a deterministic system
# Cost in iteration 0: 0.00072360829591711
# Converged in iteration 424 with cost 0.0007236041918692778 because of step counter
# Final cost : 0.0007236041918692778
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007236041918692778
# Converged in iteration 1 with cost 0.0007236041918692778 because of vanishing difference
# Final cost : 0.0007236041918692778
# Compute control for a deterministic system
# Cost in iteration 0: 0.23420847317933566
# Final cost : 0.010597525307104042
# Compute control for a deterministic system
# Cost in iteration 0: 0.010597525307104042
# Final cost : 0.00032683342363217264
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032683342363217264
# Final cost : 0.00031657777167984704
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031657777167984704
# Final cost : 0.0003163290866005769
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003163290866005769
# Converged in iteration 344 with cost 0.00031632795752124294 because of step counter
# Final cost : 0.00031632795752124294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031632795752124294
# Converged in iteration 2 with cost 0.0003163279575212276 because of step counter
# Final cost : 0.0003163279575212276
# Compute control for a deterministic system
# Cost in iteration 0: 0.05668824981903782
# Final cost : 0.0014016660182722199
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014016660182722199
# Final cost : 7.583047780030918e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.583047780030918e-05
# Final cost : 7.454046242672858e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.454046242672858e-05
# Final cost : 7.452310863142985e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.452310863142985e-05
# Converged in iteration 203 with cost 7.452307432207012e-05 because of step counter
# Final cost : 7.452307432207012e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.452307432207012e-05
# Converged in iteration 1 with cost 7.452307432207012e-05 because of step counter
# Final cost : 7.452307432207012e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024043977611434297
# Final cost : 4.686333635821084e-06
# Compute control for a deterministic system
# Cost in iteration 0: 4.686333635821084e-06
# Final cost : 3.1811350611079974e-07
# ----------------------------------------------- 0
# cost =  0.0003425929097025757
# Compute control for a deterministic system
# Cost in iteration 0: 0.06514947332030938
# Final cost : 0.00034598083957416645
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034598083957416645
# Final cost : 0.00034266555762705426
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034266555762705426
# Final cost : 0.00034259314216955833
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034259314216955833
# Converged in iteration 564 with cost 0.0003425929096983259 because of step counter
# Final cost : 0.0003425929096983259
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003425929096983259
# Converged in iteration 6 with cost 0.0003425929096979377 because of step counter
# Final cost : 0.0003425929096979377
# -----------------------------------------------
# 0 found better solution,  2
# cost =  0.0006738836845547368
# Compute control for a deterministic system
# Cost in iteration 0: 0.03991493344853719
# Final cost : 0.0006775501766250312
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006775501766250312
# Final cost : 0.0006739741616731758
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006739741616731758
# Final cost : 0.0006738839434925557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006738839434925557
# Converged in iteration 559 with cost 0.0006738836845579196 because of step counter
# Final cost : 0.0006738836845579196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006738836845579196
# Converged in iteration 20 with cost 0.0006738836845552867 because of step counter
# Final cost : 0.0006738836845552867
# cost =  0.0012449732512125006
# Compute control for a deterministic system
# Cost in iteration 0: 0.06476677235712872
# Final cost : 0.0012546978777298124
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012546978777298124
# Final cost : 0.0012451859430355602
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012451859430355602
# Final cost : 0.0012449735725123825
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012449735725123825
# Converged in iteration 221 with cost 0.0012449732512166021 because of vanishing difference
# Final cost : 0.0012449732512166021
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012449732512166021
# Converged in iteration 13 with cost 0.0012449732512111462 because of step counter
# Final cost : 0.0012449732512111462
# -----------------------------------------------
# 0 found better solution,  4
# cost =  0.0019859290140000676
# Compute control for a deterministic system
# Cost in iteration 0: 0.06419232112215699
# Final cost : 0.002000164252536866
# Compute control for a deterministic system
# Cost in iteration 0: 0.002000164252536866
# Final cost : 0.001986211837166638
# Compute control for a deterministic system
# Cost in iteration 0: 0.001986211837166638
# Final cost : 0.0019859293935023097
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019859293935023097
# Converged in iteration 504 with cost 0.0019859290140139462 because of step counter
# Final cost : 0.0019859290140139462
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019859290140139462
# Converged in iteration 6 with cost 0.001985929013998622 because of step counter
# Final cost : 0.001985929013998622
# -----------------------------------------------
# 0 found better solution,  5
# cost =  0.0028875439468260848
# Compute control for a deterministic system
# Cost in iteration 0: 0.06303950819210197
# Final cost : 0.0029063057200823957
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029063057200823957
# Final cost : 0.002887942767705412
# Compute control for a deterministic system
# Cost in iteration 0: 0.002887942767705412
# Final cost : 0.0028875452876187856
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028875452876187856
# Final cost : 0.0028875439668957677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028875439668957677
# Converged in iteration 208 with cost 0.0028875439468162723 because of step counter
# Final cost : 0.0028875439468162723
# -----------------------------------------------
# 0 found better solution,  6
# cost =  0.0037181186331589934
# Compute control for a deterministic system
# Cost in iteration 0: 0.03629589063305577
# Final cost : 0.003733081217080722
# Compute control for a deterministic system
# Cost in iteration 0: 0.003733081217080722
# Final cost : 0.003718454780460434
# Compute control for a deterministic system
# Cost in iteration 0: 0.003718454780460434
# Final cost : 0.003718119297670364
# Compute control for a deterministic system
# Cost in iteration 0: 0.003718119297670364
# Final cost : 0.0037181186441313466
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037181186441313466
# Converged in iteration 616 with cost 0.0037181186331250236 because of vanishing difference
# Final cost : 0.0037181186331250236
# -----------------------------------------------
# 0 found better solution,  7
# cost =  0.004889212702986178
# Compute control for a deterministic system
# Cost in iteration 0: 0.061309890294503254
# Final cost : 0.004919912395551497
# Compute control for a deterministic system
# Cost in iteration 0: 0.004919912395551497
# Final cost : 0.004889831380738493
# Compute control for a deterministic system
# Cost in iteration 0: 0.004889831380738493
# Final cost : 0.004889212741061694
# Compute control for a deterministic system
# Cost in iteration 0: 0.004889212741061694
# Final cost : 0.004889212703050149
# Compute control for a deterministic system
# Cost in iteration 0: 0.004889212703050149
# Converged in iteration 27 with cost 0.00488921270301844 because of step counter
# Final cost : 0.00488921270301844
# cost =  0.006211995585617666
# Compute control for a deterministic system
# Cost in iteration 0: 0.06553602629651263
# Final cost : 0.0062519082619176556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0062519082619176556
# Final cost : 0.006212731113261236
# Compute control for a deterministic system
# Cost in iteration 0: 0.006212731113261236
# Final cost : 0.006211997695573335
# Compute control for a deterministic system
# Cost in iteration 0: 0.006211997695573335
# Final cost : 0.006211995618245128
# Compute control for a deterministic system
# Cost in iteration 0: 0.006211995618245128
# Converged in iteration 271 with cost 0.00621199558551202 because of step counter
# Final cost : 0.00621199558551202
# -----------------------------------------------
# 0 found better solution,  9
# cost =  0.007697677462956513
# Compute control for a deterministic system
# Cost in iteration 0: 0.0683514662722919
# Final cost : 0.007747804520882345
# Compute control for a deterministic system
# Cost in iteration 0: 0.007747804520882345
# Final cost : 0.0076986945059801986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0076986945059801986
# Final cost : 0.007697677662481117
# Compute control for a deterministic system
# Cost in iteration 0: 0.007697677662481117
# Final cost : 0.007697677466882263
# Compute control for a deterministic system
# Cost in iteration 0: 0.007697677466882263
# Converged in iteration 525 with cost 0.007697677462832148 because of step counter
# Final cost : 0.007697677462832148
# -----------------------------------------------
# 0 found better solution,  10
# cost =  0.009012032873890442
# Compute control for a deterministic system
# Cost in iteration 0: 0.05227000196006794
# Final cost : 0.009050580120120657
# Compute control for a deterministic system
# Cost in iteration 0: 0.009050580120120657
# Final cost : 0.009012924574573903
# Compute control for a deterministic system
# Cost in iteration 0: 0.009012924574573903
# Final cost : 0.009012033592806832
# Compute control for a deterministic system
# Cost in iteration 0: 0.009012033592806832
# Final cost : 0.009012032876510931
# Compute control for a deterministic system
# Cost in iteration 0: 0.009012032876510931
# Converged in iteration 459 with cost 0.009012032873915747 because of step counter
# Final cost : 0.009012032873915747
# cost =  0.010820394730366447
# Compute control for a deterministic system
# Cost in iteration 0: 0.07692830041261896
# Final cost : 0.010892616403066645
# Compute control for a deterministic system
# Cost in iteration 0: 0.010892616403066645
# Final cost : 0.010822237563206367
# Compute control for a deterministic system
# Cost in iteration 0: 0.010822237563206367
# Final cost : 0.010820496865865272
# Compute control for a deterministic system
# Cost in iteration 0: 0.010820496865865272
# Final cost : 0.010820396883243672
# Compute control for a deterministic system
# Cost in iteration 0: 0.010820396883243672
# Converged in iteration 1616 with cost 0.010820394730388816 because of step counter
# Final cost : 0.010820394730388816
# cost =  0.012817850745002746
# Compute control for a deterministic system
# Cost in iteration 0: 0.0747129283241371
# Final cost : 0.012903903204492386
# Compute control for a deterministic system
# Cost in iteration 0: 0.012903903204492386
# Final cost : 0.012820280872971244
# Compute control for a deterministic system
# Cost in iteration 0: 0.012820280872971244
# Final cost : 0.01281785313913058
# Compute control for a deterministic system
# Cost in iteration 0: 0.01281785313913058
# Final cost : 0.012817850795703736
# Compute control for a deterministic system
# Cost in iteration 0: 0.012817850795703736
# Converged in iteration 739 with cost 0.012817850745040979 because of step counter
# Final cost : 0.012817850745040979
# cost =  0.015007153567130924
# Compute control for a deterministic system
# Cost in iteration 0: 0.062044815619092246
# Final cost : 0.015107164978815448
# Compute control for a deterministic system
# Cost in iteration 0: 0.015107164978815448
# Final cost : 0.015010293290962273
# Compute control for a deterministic system
# Cost in iteration 0: 0.015010293290962273
# Final cost : 0.01500716923762081
# Compute control for a deterministic system
# Cost in iteration 0: 0.01500716923762081
# Final cost : 0.015007153687326111
# Compute control for a deterministic system
# Cost in iteration 0: 0.015007153687326111
# Converged in iteration 445 with cost 0.015007153567088847 because of step counter
# Final cost : 0.015007153567088847
# -----------------------------------------------
# 0 found better solution,  14
# cost =  0.017389535221711463
# Compute control for a deterministic system
# Cost in iteration 0: 0.07173000451336316
# Final cost : 0.0175064439166639
# Compute control for a deterministic system
# Cost in iteration 0: 0.0175064439166639
# Final cost : 0.017393506409424338
# Compute control for a deterministic system
# Cost in iteration 0: 0.017393506409424338
# Final cost : 0.017389757103247902
# Compute control for a deterministic system
# Cost in iteration 0: 0.017389757103247902
# Final cost : 0.01738954287607039
# Compute control for a deterministic system
# Cost in iteration 0: 0.01738954287607039
# Final cost : 0.017389535223641634
# cost =  0.019435013010448227
# Compute control for a deterministic system
# Cost in iteration 0: 0.06464631413402755
# Final cost : 0.019520258186953694
# Compute control for a deterministic system
# Cost in iteration 0: 0.019520258186953694
# Final cost : 0.01943823313734028
# Compute control for a deterministic system
# Cost in iteration 0: 0.01943823313734028
# Final cost : 0.01943526573492641
# Compute control for a deterministic system
# Cost in iteration 0: 0.01943526573492641
# Final cost : 0.019435019611594023
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435019611594023
# Final cost : 0.019435013016056223
# cost =  0.02216711861192854
# Compute control for a deterministic system
# Cost in iteration 0: 0.08278074963088983
# Final cost : 0.022315729010946354
# Compute control for a deterministic system
# Cost in iteration 0: 0.022315729010946354
# Final cost : 0.022173029735233066
# Compute control for a deterministic system
# Cost in iteration 0: 0.022173029735233066
# Final cost : 0.022167598351730423
# Compute control for a deterministic system
# Cost in iteration 0: 0.022167598351730423
# Final cost : 0.022167138890811414
# Compute control for a deterministic system
# Cost in iteration 0: 0.022167138890811414
# Final cost : 0.022167118278242783
# -----------------------------------------------
# 0 found better solution,  17
# cost =  0.02509512265972155
# Compute control for a deterministic system
# Cost in iteration 0: 0.09607136206577796
# Final cost : 0.02526335924323623
# Compute control for a deterministic system
# Cost in iteration 0: 0.02526335924323623
# Final cost : 0.025101904965157823
# Compute control for a deterministic system
# Cost in iteration 0: 0.025101904965157823
# Final cost : 0.025095737475708813
# Compute control for a deterministic system
# Cost in iteration 0: 0.025095737475708813
# Final cost : 0.0250951501551478
# Compute control for a deterministic system
# Cost in iteration 0: 0.0250951501551478
# Final cost : 0.025095121537714874
# -----------------------------------------------
# 0 found better solution,  18
# cost =  0.028220610951574406
# Compute control for a deterministic system
# Cost in iteration 0: 0.09156989518778909
# Final cost : 0.02840623154610513
# Compute control for a deterministic system
# Cost in iteration 0: 0.02840623154610513
# Final cost : 0.02822942443848087
# Compute control for a deterministic system
# Cost in iteration 0: 0.02822942443848087
# Final cost : 0.02822146709887369
# Compute control for a deterministic system
# Cost in iteration 0: 0.02822146709887369
# Final cost : 0.028220665722701557
# Compute control for a deterministic system
# Cost in iteration 0: 0.028220665722701557
# Final cost : 0.028220610469832253
# -----------------------------------------------
# 0 found better solution,  19
# cost =  0.030864465146892693
# Compute control for a deterministic system
# Cost in iteration 0: 0.0717136625715776
# Final cost : 0.030993650376161783
# Compute control for a deterministic system
# Cost in iteration 0: 0.030993650376161783
# Final cost : 0.030870956076537257
# Compute control for a deterministic system
# Cost in iteration 0: 0.030870956076537257
# Final cost : 0.030865125079712476
# Compute control for a deterministic system
# Cost in iteration 0: 0.030865125079712476
# Final cost : 0.03086451112901961
# Compute control for a deterministic system
# Cost in iteration 0: 0.03086451112901961
# Final cost : 0.030864465296000516
# cost =  0.03435043062209519
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496133698010963
# Final cost : 0.03457002965056281
# Compute control for a deterministic system
# Cost in iteration 0: 0.03457002965056281
# Final cost : 0.03436182775846023
# Compute control for a deterministic system
# Cost in iteration 0: 0.03436182775846023
# Final cost : 0.03435168702158245
# Compute control for a deterministic system
# Cost in iteration 0: 0.03435168702158245
# Final cost : 0.034350430640950495
# Compute control for a deterministic system
# Cost in iteration 0: 0.034350430640950495
# Final cost : 0.03435042481682995
# -----------------------------------------------
# 0 found better solution,  21
# cost =  0.023023505707439357
# Compute control for a deterministic system
# Cost in iteration 0: 0.11540789353642798
# Final cost : 0.038282419594043215
# Compute control for a deterministic system
# Cost in iteration 0: 0.038282419594043215
# Final cost : 0.0380527536003792
# Compute control for a deterministic system
# Cost in iteration 0: 0.0380527536003792
# Final cost : 0.0380414890403582
# Compute control for a deterministic system
# Cost in iteration 0: 0.0380414890403582
# Final cost : 0.038039973373546955
# Compute control for a deterministic system
# Cost in iteration 0: 0.038039973373546955
# Final cost : 0.03803985969925339
# cost =  0.020514732013344847
# Compute control for a deterministic system
# Cost in iteration 0: 0.07575756974268737
# Final cost : 0.020627673669217996
# Compute control for a deterministic system
# Cost in iteration 0: 0.020627673669217996
# Final cost : 0.020523420756969703
# Compute control for a deterministic system
# Cost in iteration 0: 0.020523420756969703
# Final cost : 0.02051556531509509
# Compute control for a deterministic system
# Cost in iteration 0: 0.02051556531509509
# Final cost : 0.020514855182905946
# Compute control for a deterministic system
# Cost in iteration 0: 0.020514855182905946
# Converged in iteration 1309 with cost 0.020514732013397655 because of step counter
# Final cost : 0.020514732013397655
# cost =  0.018603911626194198
# Compute control for a deterministic system
# Cost in iteration 0: 0.06191508884147667
# Final cost : 0.018670882287516462
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.025095121456554348
# Converged in iteration 24 with cost 0.025095121456534447 because of step counter
# Final cost : 0.025095121456534447
# Compute control for a deterministic system
# Cost in iteration 0: 0.053606407501087805
# Final cost : 0.02899727906243394
# Compute control for a deterministic system
# Cost in iteration 0: 0.02899727906243394
# Final cost : 0.028220611391719597
# Compute control for a deterministic system
# Cost in iteration 0: 0.028220611391719597
# Final cost : 0.028220610168695242
# Compute control for a deterministic system
# Cost in iteration 0: 0.028220610168695242
# Converged in iteration 927 with cost 0.02822061016307874 because of step counter
# Final cost : 0.02822061016307874
# Compute control for a deterministic system
# Cost in iteration 0: 0.02822061016307874
# Converged in iteration 1 with cost 0.02822061016307874 because of step counter
# Final cost : 0.02822061016307874
# Compute control for a deterministic system
# Cost in iteration 0: 0.061244018626533
# Final cost : 0.029069330814129185
# Compute control for a deterministic system
# Cost in iteration 0: 0.029069330814129185
# Final cost : 0.028434840414739034
# Compute control for a deterministic system
# Cost in iteration 0: 0.028434840414739034
# Final cost : 0.028434793086471205
# Compute control for a deterministic system
# Cost in iteration 0: 0.028434793086471205
# Final cost : 0.028434792830196995
# Compute control for a deterministic system
# Cost in iteration 0: 0.028434792830196995
# Converged in iteration 200 with cost 0.028434792788062997 because of step counter
# Final cost : 0.028434792788062997
# Compute control for a deterministic system
# Cost in iteration 0: 0.04733312236535289
# Final cost : 0.026206366540513733
# Compute control for a deterministic system
# Cost in iteration 0: 0.026206366540513733
# Final cost : 0.0256641689087143
# Compute control for a deterministic system
# Cost in iteration 0: 0.0256641689087143
# Final cost : 0.0256641340484491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0256641340484491
# Final cost : 0.02566413389698326
# Compute control for a deterministic system
# Cost in iteration 0: 0.02566413389698326
# Converged in iteration 109 with cost 0.02566413387831273 because of step counter
# Final cost : 0.02566413387831273
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.03599047512423649
# Final cost : 0.02351844346859905
# Compute control for a deterministic system
# Cost in iteration 0: 0.02351844346859905
# Final cost : 0.023023534083863498
# Compute control for a deterministic system
# Cost in iteration 0: 0.023023534083863498
# Final cost : 0.023023505756489433
# Compute control for a deterministic system
# Cost in iteration 0: 0.023023505756489433
# Final cost : 0.023023505711901836
# Compute control for a deterministic system
# Cost in iteration 0: 0.023023505711901836
# Converged in iteration 280 with cost 0.023023505707586808 because of step counter
# Final cost : 0.023023505707586808
# Compute control for a deterministic system
# Cost in iteration 0: 0.03774314450791374
# Final cost : 0.02095354425491869
# Compute control for a deterministic system
# Cost in iteration 0: 0.02095354425491869
# Final cost : 0.02051475994469856
# Compute control for a deterministic system
# Cost in iteration 0: 0.02051475994469856
# Final cost : 0.020514732027591076
# Compute control for a deterministic system
# Cost in iteration 0: 0.020514732027591076
# Final cost : 0.02051473201526073
# Compute control for a deterministic system
# Cost in iteration 0: 0.02051473201526073
# Converged in iteration 234 with cost 0.02051473201355334 because of step counter
# Final cost : 0.02051473201355334
# Compute control for a deterministic system
# Cost in iteration 0: 0.04713471171291857
# Final cost : 0.01899540148060097
# Compute control for a deterministic system
# Cost in iteration 0: 0.01899540148060097
# Final cost : 0.01860394314534848
# Compute control for a deterministic system
# Cost in iteration 0: 0.01860394314534848
# Final cost : 0.01860391163463915
# Compute control for a deterministic system
# Cost in iteration 0: 0.01860391163463915
# Final cost : 0.018603911627175975
# Compute control for a deterministic system
# Cost in iteration 0: 0.018603911627175975
# Converged in iteration 171 with cost 0.018603911626106924 because of step counter
# Final cost : 0.018603911626106924
# Compute control for a deterministic system
# Cost in iteration 0: 0.026564335054666016
# Final cost : 0.01669379629928687
# Compute control for a deterministic system
# Cost in iteration 0: 0.01669379629928687
# Final cost : 0.01633726619966174
# Compute control for a deterministic system
# Cost in iteration 0: 0.01633726619966174
# Final cost : 0.01633724615699587
# Compute control for a deterministic system
# Cost in iteration 0: 0.01633724615699587
# Final cost : 0.016337246128413477
# Compute control for a deterministic system
# Cost in iteration 0: 0.016337246128413477
# Converged in iteration 368 with cost 0.016337246126167528 because of step counter
# Final cost : 0.016337246126167528
# Compute control for a deterministic system
# Cost in iteration 0: 0.034414276975005306
# Final cost : 0.014511422011134048
# Compute control for a deterministic system
# Cost in iteration 0: 0.014511422011134048
# Final cost : 0.014207830133331023
# Compute control for a deterministic system
# Cost in iteration 0: 0.014207830133331023
# Final cost : 0.014207806730463672
# Compute control for a deterministic system
# Cost in iteration 0: 0.014207806730463672
# Final cost : 0.014207806631981465
# Compute control for a deterministic system
# Cost in iteration 0: 0.014207806631981465
# Converged in iteration 294 with cost 0.01420780662408978 because of step counter
# Final cost : 0.01420780662408978
# Compute control for a deterministic system
# Cost in iteration 0: 0.019857015471755946
# Final cost : 0.012487791916439468
# Compute control for a deterministic system
# Cost in iteration 0: 0.012487791916439468
# Final cost : 0.012217605743157549
# Compute control for a deterministic system
# Cost in iteration 0: 0.012217605743157549
# Final cost : 0.012217591001509577
# Compute control for a deterministic system
# Cost in iteration 0: 0.012217591001509577
# Converged in iteration 753 with cost 0.01221759099617031 because of step counter
# Final cost : 0.01221759099617031
# Compute control for a deterministic system
# Cost in iteration 0: 0.01221759099617031
# Converged in iteration 1 with cost 0.01221759099617031 because of step counter
# Final cost : 0.01221759099617031
# Compute control for a deterministic system
# Cost in iteration 0: 0.02703026936077922
# Final cost : 0.010591884387312518
# Compute control for a deterministic system
# Cost in iteration 0: 0.010591884387312518
# Final cost : 0.010368659292346809
# Compute control for a deterministic system
# Cost in iteration 0: 0.010368659292346809
# Final cost : 0.010368641828711084
# Compute control for a deterministic system
# Cost in iteration 0: 0.010368641828711084
# Converged in iteration 854 with cost 0.010368641823969914 because of step counter
# Final cost : 0.010368641823969914
# Compute control for a deterministic system
# Cost in iteration 0: 0.010368641823969914
# Converged in iteration 2 with cost 0.010368641823969843 because of step counter
# Final cost : 0.010368641823969843
# Compute control for a deterministic system
# Cost in iteration 0: 0.02183048517272471
# Final cost : 0.009188205824963394
# Compute control for a deterministic system
# Cost in iteration 0: 0.009188205824963394
# Final cost : 0.008992605721021507
# Compute control for a deterministic system
# Cost in iteration 0: 0.008992605721021507
# Final cost : 0.008992591142945015
# Compute control for a deterministic system
# Cost in iteration 0: 0.008992591142945015
# Converged in iteration 381 with cost 0.00899259113056241 because of step counter
# Final cost : 0.00899259113056241
# Compute control for a deterministic system
# Cost in iteration 0: 0.00899259113056241
# Converged in iteration 1 with cost 0.00899259113056241 because of step counter
# Final cost : 0.00899259113056241
# Compute control for a deterministic system
# Cost in iteration 0: 0.013620129684941062
# Final cost : 0.007568581886648714
# Compute control for a deterministic system
# Cost in iteration 0: 0.007568581886648714
# Final cost : 0.0074031944150536435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0074031944150536435
# Final cost : 0.007403180295751626
# Compute control for a deterministic system
# Cost in iteration 0: 0.007403180295751626
# Converged in iteration 339 with cost 0.007403180294416196 because of step counter
# Final cost : 0.007403180294416196
# Compute control for a deterministic system
# Cost in iteration 0: 0.007403180294416196
# Converged in iteration 1 with cost 0.007403180294416196 because of step counter
# Final cost : 0.007403180294416196
# Compute control for a deterministic system
# Cost in iteration 0: 0.012771573316694766
# Final cost : 0.006093618150803158
# Compute control for a deterministic system
# Cost in iteration 0: 0.006093618150803158
# Final cost : 0.005960960427064745
# Compute control for a deterministic system
# Cost in iteration 0: 0.005960960427064745
# Final cost : 0.005960948356814678
# Compute control for a deterministic system
# Cost in iteration 0: 0.005960948356814678
# Final cost : 0.005960948347779796
# Compute control for a deterministic system
# Cost in iteration 0: 0.005960948347779796
# Converged in iteration 81 with cost 0.005960948347544704 because of step counter
# Final cost : 0.005960948347544704
# Compute control for a deterministic system
# Cost in iteration 0: 0.009087333646025025
# Final cost : 0.004773690010714799
# Compute control for a deterministic system
# Cost in iteration 0: 0.004773690010714799
# Final cost : 0.004668249118592386
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668249118592386
# Final cost : 0.004668240024807041
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668240024807041
# Converged in iteration 695 with cost 0.004668240022943722 because of step counter
# Final cost : 0.004668240022943722
# Compute control for a deterministic system
# Cost in iteration 0: 0.004668240022943722
# Converged in iteration 1 with cost 0.004668240022943722 because of step counter
# Final cost : 0.004668240022943722
# Compute control for a deterministic system
# Cost in iteration 0: 0.006881472935582828
# Final cost : 0.0038290212851235686
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038290212851235686
# Final cost : 0.0037435204084532857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037435204084532857
# Final cost : 0.003743513094829103
# Compute control for a deterministic system
# Cost in iteration 0: 0.003743513094829103
# Converged in iteration 575 with cost 0.0037435130934192814 because of vanishing difference
# Final cost : 0.0037435130934192814
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037435130934192814
# Converged in iteration 1 with cost 0.0037435130934192814 because of step counter
# Final cost : 0.0037435130934192814
# Compute control for a deterministic system
# Cost in iteration 0: 0.004381342890798291
# Final cost : 0.0027902970705773137
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027902970705773137
# Final cost : 0.0027267685062426516
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027267685062426516
# Final cost : 0.0027267631161432214
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027267631161432214
# Converged in iteration 132 with cost 0.002726763115939579 because of step counter
# Final cost : 0.002726763115939579
# Compute control for a deterministic system
# Cost in iteration 0: 0.002726763115939579
# Converged in iteration 5 with cost 0.0027267631159394352 because of step counter
# Final cost : 0.0027267631159394352
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032147480936194537
# Final cost : 0.0019109015231523372
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019109015231523372
# Final cost : 0.0018671748378666425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018671748378666425
# Final cost : 0.001867171691818466
# Compute control for a deterministic system
# Cost in iteration 0: 0.001867171691818466
# Converged in iteration 33 with cost 0.001867171691736174 because of step counter
# Final cost : 0.001867171691736174
# Compute control for a deterministic system
# Cost in iteration 0: 0.001867171691736174
# Converged in iteration 1 with cost 0.001867171691736174 because of step counter
# Final cost : 0.001867171691736174
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019089104274285277
# Final cost : 0.0011949328078479328
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011949328078479328
# Final cost : 0.0011671958116842838
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011671958116842838
# Converged in iteration 804 with cost 0.0011671938032776835 because of step counter
# Final cost : 0.0011671938032776835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011671938032776835
# Converged in iteration 1 with cost 0.0011671938032776835 because of step counter
# Final cost : 0.0011671938032776835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011671938032776835
# Converged in iteration 1 with cost 0.0011671938032776835 because of step counter
# Final cost : 0.0011671938032776835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011931602055216379
# Final cost : 0.0007409376508478799
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007409376508478799
# Final cost : 0.0007236054272065308
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007236054272065308
# Converged in iteration 819 with cost 0.0007236041918763656 because of step counter
# Final cost : 0.0007236041918763656
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007236041918763656
# Converged in iteration 25 with cost 0.0007236041918680779 because of step counter
# Final cost : 0.0007236041918680779
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007236041918680779
# Converged in iteration 1 with cost 0.0007236041918680779 because of step counter
# Final cost : 0.0007236041918680779
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008172287773657114
# Final cost : 0.00032373067582850724
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032373067582850724
# Final cost : 0.00031632852503549994
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031632852503549994
# Converged in iteration 803 with cost 0.0003163279575342377 because of step counter
# Final cost : 0.0003163279575342377
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003163279575342377
# Converged in iteration 8 with cost 0.0003163279575338693 because of step counter
# Final cost : 0.0003163279575338693
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003163279575338693
# Converged in iteration 14 with cost 0.00031632795752355874 because of step counter
# Final cost : 0.00031632795752355874
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017836180323530505
# Final cost : 7.629514255386376e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.629514255386376e-05
# Final cost : 7.452321678253652e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.452321678253652e-05
# Converged in iteration 893 with cost 7.452307432169412e-05 because of vanishing difference
# Final cost : 7.452307432169412e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.452307432169412e-05
# Converged in iteration 21 with cost 7.452307431973107e-05 because of step counter
# Final cost : 7.452307431973107e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.452307431973107e-05
# Converged in iteration 1 with cost 7.452307431973107e-05 because of step counter
# Final cost : 7.452307431973107e-05

# %%
save(results_min)
