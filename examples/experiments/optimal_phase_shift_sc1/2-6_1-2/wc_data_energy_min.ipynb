# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4353161677504697 
y_init = 0.4948614151973427
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,171], wc.inh[0,171]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.20256788383864668 0.45501490253970783
# minima =  [ 126  334  542  750  959 1167 1375 1583 1791 2000 2208 2416 2624 2832
#  3041 3249 3457 3665 3873]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 2
#       1 results_min = read()
# ----> 2 results_peak = readfile("results_peak_w2.pickle")
#
# Cell In [6], line 14, in readfile(file)
#      13 def readfile(file):
# ---> 14     filehandler = open(file,"rb")
#      15     results_dict = pickle.load(filehandler)
#      16     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results_peak_w2.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [False, False, False, False, True, True, False, False]
#options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * factor
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                #wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010989815311913622
# Final cost : 7.640106054984796e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.640106054984796e-06
# Final cost : 7.639632741427988e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639632741427988e-06
# Final cost : 7.63944429596686e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.63944429596686e-06
# Final cost : 7.639327884017416e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639327884017416e-06
# Final cost : 7.639230522136776e-06
# Compute control for a deterministic system
# Cost in iteration 0: 2.973516245217994e-05
# Final cost : 2.9702298273362438e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702298273362438e-05
# Final cost : 2.9702294996350594e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702294996350594e-05
# Final cost : 2.9702292830636392e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702292830636392e-05
# Final cost : 2.9702291625497325e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702291625497325e-05
# Final cost : 2.9702290634518867e-05
# -----------------------------------------------
# 4 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011392152786253431
# Final cost : 7.352149763053102e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.352149763053102e-05
# Final cost : 7.351929675646489e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351929675646489e-05
# Final cost : 7.351839176616584e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351839176616584e-05
# Final cost : 7.351788500267437e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351788500267437e-05
# Final cost : 7.351730895411465e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012381394654836022
# Final cost : 0.00012317071557985953
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012317071557985953
# Final cost : 0.00012317070186287208
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012317070186287208
# Final cost : 0.0001231706926195551
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001231706926195551
# Final cost : 0.00012317068592008145
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012317068592008145
# Final cost : 0.00012317067895046193
# -----------------------------------------------
# 4 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.00388823848466047
# Final cost : 0.00018370416985552724
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018370416985552724
# Final cost : 0.0001836877427848688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001836877427848688
# Final cost : 0.00018368246912826378
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018368246912826378
# Final cost : 0.0001836782080383383
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001836782080383383
# Final cost : 0.00018367584782455498
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028674025110525282
# Final cost : 0.00025432837612899227
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025432837612899227
# Final cost : 0.0002542377828876535
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002542377828876535
# Final cost : 0.0002541312414210123
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002541312414210123
# Final cost : 0.0002541043873784596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002541043873784596
# Final cost : 0.00025408682165466184
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005577418973814524
# Final cost : 0.00033350385970487724
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033350385970487724
# Final cost : 0.0003334951636531434
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003334951636531434
# Final cost : 0.00033348521363650054
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033348521363650054
# Final cost : 0.00033348282685400347
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033348282685400347
# Final cost : 0.00033348095048744893
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.009230851904839068
# Final cost : 0.00043965699870999466
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043965699870999466
# Final cost : 0.00043948362356702257
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043948362356702257
# Final cost : 0.0004394574075946252
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004394574075946252
# Final cost : 0.00043944661726890073
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043944661726890073
# Final cost : 0.0004394382239187624
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.004706353243069855
# Final cost : 0.00053636045781861
# Compute control for a deterministic system
# Cost in iteration 0: 0.00053636045781861
# Final cost : 0.0005360449397135437
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005360449397135437
# Final cost : 0.0005358610595777313
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005358610595777313
# Final cost : 0.000535782228960491
# Compute control for a deterministic system
# Cost in iteration 0: 0.000535782228960491
# Final cost : 0.0005356814496459002
# Compute control for a deterministic system
# Cost in iteration 0: 0.00483712464949697
# Final cost : 0.0006389177037166132
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006389177037166132
# Final cost : 0.0006385439260397313
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006385439260397313
# Final cost : 0.0006383633910377877
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006383633910377877
# Final cost : 0.0006382941055438746
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006382941055438746
# Final cost : 0.0006381873341165175
# Compute control for a deterministic system
# Cost in iteration 0: 0.010173122051950765
# Final cost : 0.0007470658139493315
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007470658139493315
# Final cost : 0.0007464255263720158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007464255263720158
# Final cost : 0.0007463636360516365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007463636360516365
# Final cost : 0.0007463409535657807
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007463409535657807
# Final cost : 0.0007463085210356928
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.006884191920955265
# Final cost : 0.0008598820507781157
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008598820507781157
# Final cost : 0.0008591646505752293
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008591646505752293
# Final cost : 0.0008588747663847598
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008588747663847598
# Final cost : 0.0008587478729220876
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008587478729220876
# Final cost : 0.0008585769373675649
# -----------------------------------------------
# 4 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.00411940526041663
# Final cost : 0.000998090180830534
# Compute control for a deterministic system
# Cost in iteration 0: 0.000998090180830534
# Final cost : 0.0009978163180334929
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009978163180334929
# Final cost : 0.000997676111053618
# Compute control for a deterministic system
# Cost in iteration 0: 0.000997676111053618
# Final cost : 0.0009976423871710888
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009976423871710888
# Final cost : 0.0009975888633199294
# -----------------------------------------------
# 4 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013611680137733627
# Final cost : 0.001116477660344881
# Compute control for a deterministic system
# Cost in iteration 0: 0.001116477660344881
# Final cost : 0.0011164649180161687
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011164649180161687
# Final cost : 0.0011164493916016917
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011164493916016917
# Final cost : 0.0011164370933796897
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011164370933796897
# Final cost : 0.0011164128161913114
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.005598680548309592
# Final cost : 0.0012375992175125555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012375992175125555
# Final cost : 0.0012370531586338768
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012370531586338768
# Final cost : 0.0012369060321263683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012369060321263683
# Final cost : 0.0012368055615589845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012368055615589845
# Final cost : 0.0012366445223228942
# Compute control for a deterministic system
# Cost in iteration 0: 0.10437759942056632
# Final cost : 0.0016643770069476526
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016643770069476526
# Final cost : 0.001386915982686843
# Compute control for a deterministic system
# Cost in iteration 0: 0.001386915982686843
# Final cost : 0.001375715107331018
# Compute control for a deterministic system
# Cost in iteration 0: 0.001375715107331018
# Final cost : 0.0013708515995983076
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013708515995983076
# Final cost : 0.0013640864671836438
# Compute control for a deterministic system
# Cost in iteration 0: 0.022275252633045587
# Final cost : 0.0015234423537071014
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015234423537071014
# Final cost : 0.0015157998544680148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015157998544680148
# Final cost : 0.001514280278723691
# Compute control for a deterministic system
# Cost in iteration 0: 0.001514280278723691
# Final cost : 0.0015133629400333943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015133629400333943
# Final cost : 0.0015119113577755565
# Compute control for a deterministic system
# Cost in iteration 0: 0.027824257971947458
# Final cost : 0.0016534716653125272
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016534716653125272
# Final cost : 0.0016456234635853278
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016456234635853278
# Final cost : 0.0016451606325437304
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016451606325437304
# Final cost : 0.0016447530318127893
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016447530318127893
# Final cost : 0.0016442688756245455
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.008185831441534883
# Final cost : 0.0017853921628247936
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017853921628247936
# Final cost : 0.001784607080028753
# Compute control for a deterministic system
# Cost in iteration 0: 0.001784607080028753
# Final cost : 0.0017843464742532302
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017843464742532302
# Final cost : 0.0017841660659866602
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017841660659866602
# Final cost : 0.001783561992588213
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.001985673742162915
# Final cost : 0.0019230984868406208
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019230984868406208
# Final cost : 0.001922717345028305
# Compute control for a deterministic system
# Cost in iteration 0: 0.001922717345028305
# Final cost : 0.0019223406147880029
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019223406147880029
# Final cost : 0.0019220479701082046
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019220479701082046
# Final cost : 0.0019214920539046855
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021895700602837073
# Final cost : 0.00208479933165512
# Compute control for a deterministic system
# Cost in iteration 0: 0.00208479933165512
# Final cost : 0.002084248066446179
# Compute control for a deterministic system
# Cost in iteration 0: 0.002084248066446179
# Final cost : 0.002083715552495919
# Compute control for a deterministic system
# Cost in iteration 0: 0.002083715552495919
# Final cost : 0.0020832400785716024
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020832400785716024
# Final cost : 0.002082140107887787
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.011077358652987195
# Final cost : 0.0022753552654738956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022753552654738956
# Final cost : 0.002273587092594622
# Compute control for a deterministic system
# Cost in iteration 0: 0.002273587092594622
# Final cost : 0.002273091775465033
# Compute control for a deterministic system
# Cost in iteration 0: 0.002273091775465033
# Final cost : 0.002272683073065767
# Compute control for a deterministic system
# Cost in iteration 0: 0.002272683073065767
# Final cost : 0.0022717570976429798
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.19600945992004828
# Final cost : 0.012225348856037134
# Compute control for a deterministic system
# Cost in iteration 0: 0.012225348856037134
# Final cost : 0.0032363081056528058
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032363081056528058
# Final cost : 0.0025587545533282425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025587545533282425
# Final cost : 0.0024676019894689836
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024676019894689836
# Final cost : 0.0024458181385943606
# Compute control for a deterministic system
# Cost in iteration 0: 0.04658362498505891
# Final cost : 0.0029344508510658306
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029344508510658306
# Final cost : 0.0026163547661312058
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026163547661312058
# Final cost : 0.0026131739551434135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026131739551434135
# Final cost : 0.002610918786519548
# Compute control for a deterministic system
# Cost in iteration 0: 0.002610918786519548
# Final cost : 0.002607964251439713
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.45779494773933194
# Final cost : 0.06657354742280565
# Compute control for a deterministic system
# Cost in iteration 0: 0.06657354742280565
# Final cost : 0.018294530573973
# Compute control for a deterministic system
# Cost in iteration 0: 0.018294530573973
# Final cost : 0.006868320502691705
# Compute control for a deterministic system
# Cost in iteration 0: 0.006868320502691705
# Final cost : 0.003071124874315937
# Compute control for a deterministic system
# Cost in iteration 0: 0.003071124874315937
# Final cost : 0.002895717007539021
# Compute control for a deterministic system
# Cost in iteration 0: 0.012783950942261573
# Final cost : 0.002580559643262901
# Compute control for a deterministic system
# Cost in iteration 0: 0.002580559643262901
# Final cost : 0.0025795107939513384
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025795107939513384
# Final cost : 0.0025792144190998952
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025792144190998952
# Final cost : 0.002579106235574711
# Compute control for a deterministic system
# Cost in iteration 0: 0.002579106235574711
# Final cost : 0.002579069544885979
# Compute control for a deterministic system
# Cost in iteration 0: 0.016189290739916724
# Final cost : 0.002103240919177378
# Compute control for a deterministic system
# Cost in iteration 0: 0.002103240919177378
# Final cost : 0.0021018275282277104
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021018275282277104
# Final cost : 0.0021014582635102263
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021014582635102263
# Final cost : 0.0021013322970446597
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021013322970446597
# Final cost : 0.0021012921219535708
# Compute control for a deterministic system
# Cost in iteration 0: 0.0054988869708266505
# Final cost : 0.0017496297928616923
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017496297928616923
# Final cost : 0.0017495991542352486
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017495991542352486
# Final cost : 0.0017495866098199949
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017495866098199949
# Final cost : 0.001749582701087267
# Compute control for a deterministic system
# Cost in iteration 0: 0.001749582701087267
# Final cost : 0.001749580815076952
# Compute control for a deterministic system
# Cost in iteration 0: 0.00244449922537666
# Final cost : 0.001437561062870714
# Compute control for a deterministic system
# Cost in iteration 0: 0.001437561062870714
# Final cost : 0.0014375538095177584
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375538095177584
# Final cost : 0.0014375500570253251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375500570253251
# Final cost : 0.0014375489072885035
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375489072885035
# Final cost : 0.0014375483342419198
# Compute control for a deterministic system
# Cost in iteration 0: 0.008753647373054008
# Final cost : 0.0011630170883393956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011630170883393956
# Final cost : 0.0011629454665522591
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011629454665522591
# Final cost : 0.001162918425068984
# Compute control for a deterministic system
# Cost in iteration 0: 0.001162918425068984
# Final cost : 0.0011629079356713066
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011629079356713066
# Final cost : 0.0011629022949510071
# Compute control for a deterministic system
# Cost in iteration 0: 0.002376526233602204
# Final cost : 0.0009234280022589694
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009234280022589694
# Final cost : 0.0009234047069554624
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009234047069554624
# Final cost : 0.0009233904878176329
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009233904878176329
# Final cost : 0.0009233861552294154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009233861552294154
# Final cost : 0.0009233835728181494
# Compute control for a deterministic system
# Cost in iteration 0: 0.00683427748068599
# Final cost : 0.0006807681107648511
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006807681107648511
# Final cost : 0.0006798488358354495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006798488358354495
# Final cost : 0.0006792695403863926
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006792695403863926
# Final cost : 0.0006791971536895032
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006791971536895032
# Final cost : 0.0006791699120369491
# Compute control for a deterministic system
# Cost in iteration 0: 0.004798664315490874
# Final cost : 0.0005092121588157151
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005092121588157151
# Final cost : 0.0005091488898154896
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005091488898154896
# Final cost : 0.000509109917396136
# Compute control for a deterministic system
# Cost in iteration 0: 0.000509109917396136
# Final cost : 0.0005090954738774555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005090954738774555
# Final cost : 0.0005090884752724135
# Compute control for a deterministic system
# Cost in iteration 0: 0.001347983777066802
# Final cost : 0.0003674737160114148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003674737160114148
# Final cost : 0.00036728097252262395
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036728097252262395
# Final cost : 0.00036719450305316666
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036719450305316666
# Final cost : 0.0003671771166934052
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003671771166934052
# Final cost : 0.00036716923994334404
# Compute control for a deterministic system
# Cost in iteration 0: 0.00163611297477967
# Final cost : 0.00025164140214721373
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025164140214721373
# Final cost : 0.0002514826400418703
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002514826400418703
# Final cost : 0.0002514157856099255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002514157856099255
# Final cost : 0.00025140078413255076
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025140078413255076
# Final cost : 0.0002513896061257895
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020342516314517426
# Final cost : 0.0001598209138541226
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001598209138541226
# Final cost : 0.00015981725679517782
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015981725679517782
# Final cost : 0.000159816068312663
# Compute control for a deterministic system
# Cost in iteration 0: 0.000159816068312663
# Final cost : 0.00015981580017703382
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015981580017703382
# Final cost : 0.00015981558833495408
# Compute control for a deterministic system
# Cost in iteration 0: 0.000518418604807916
# Final cost : 7.933713947938147e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.933713947938147e-05
# Final cost : 7.931594052459201e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.931594052459201e-05
# Final cost : 7.931144528291265e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.931144528291265e-05
# Final cost : 7.931010731875768e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.931010731875768e-05
# Final cost : 7.930911935292154e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00041686905371247636
# Final cost : 3.4711025905306526e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4711025905306526e-05
# Final cost : 3.46928887855636e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.46928887855636e-05
# Final cost : 3.468658493981166e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.468658493981166e-05
# Final cost : 3.468381367447797e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.468381367447797e-05
# Final cost : 3.46820063090312e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.138370438502909e-05
# Final cost : 8.754885695491376e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.754885695491376e-06
# Final cost : 8.75344149695462e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.75344149695462e-06
# Final cost : 8.752851126390924e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.752851126390924e-06
# Final cost : 8.752397969941251e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.752397969941251e-06
# Final cost : 8.752141326933036e-06
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 8.218428079925083e-05
# Final cost : 7.639626243038081e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639626243038081e-06
# Final cost : 7.639411288712771e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639411288712771e-06
# Final cost : 7.639320076122629e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639320076122629e-06
# Final cost : 7.639268929176241e-06
# Compute control for a deterministic system
# Cost in iteration 0: 7.639268929176241e-06
# Final cost : 7.639220832382582e-06
# Compute control for a deterministic system
# Cost in iteration 0: 3.4920832598049456e-05
# Final cost : 2.97023059883007e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.97023059883007e-05
# Final cost : 2.970229677999136e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.970229677999136e-05
# Final cost : 2.9702294143312024e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702294143312024e-05
# Final cost : 2.9702292608535923e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.9702292608535923e-05
# Final cost : 2.970229104370396e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.399999712934336e-05
# Final cost : 7.351711032170711e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351711032170711e-05
# Final cost : 7.351707353179622e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351707353179622e-05
# Final cost : 7.351706347293526e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351706347293526e-05
# Final cost : 7.351705555400525e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.351705555400525e-05
# Final cost : 7.351704875192815e-05
# -----------------------------------------------
# 5 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026800259987432807
# Final cost : 0.0001234515685504887
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001234515685504887
# Final cost : 0.00012335687758477783
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012335687758477783
# Final cost : 0.00012324882203983172
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012324882203983172
# Final cost : 0.00012321135362077038
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012321135362077038
# Final cost : 0.00012318640303462432
# Compute control for a deterministic system
# Cost in iteration 0: 0.00034254701634772733
# Final cost : 0.00018368869221739524
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018368869221739524
# Final cost : 0.00018368392512782685
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018368392512782685
# Final cost : 0.00018367831816186803
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018367831816186803
# Final cost : 0.00018367670266542007
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018367670266542007
# Final cost : 0.00018367550193653512
# -----------------------------------------------
# 5 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005533081997652104
# Final cost : 0.00025412438921890894
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025412438921890894
# Final cost : 0.00025410722514858483
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025410722514858483
# Final cost : 0.00025408710061862217
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025408710061862217
# Final cost : 0.00025408209912331517
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025408209912331517
# Final cost : 0.0002540788230254313
# -----------------------------------------------
# 5 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.004263115145977634
# Final cost : 0.00033381942189784035
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033381942189784035
# Final cost : 0.00033369236579213065
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033369236579213065
# Final cost : 0.0003335457475942868
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003335457475942868
# Final cost : 0.0003335165505307702
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003335165505307702
# Final cost : 0.0003334923273466884
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024562845543616187
# Final cost : 0.00043965086107598393
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043965086107598393
# Final cost : 0.00043956445264051267
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043956445264051267
# Final cost : 0.0004394887824028973
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004394887824028973
# Final cost : 0.00043947145811931205
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043947145811931205
# Final cost : 0.0004394439095289958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0063723233262328975
# Final cost : 0.0005358770313469304
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005358770313469304
# Final cost : 0.0005357059105349028
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005357059105349028
# Final cost : 0.0005356535302031919
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005356535302031919
# Final cost : 0.00053564377143922
# Compute control for a deterministic system
# Cost in iteration 0: 0.00053564377143922
# Final cost : 0.0005356378378385142
# -----------------------------------------------
# 5 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.004932217451473532
# Final cost : 0.0006386542468542847
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006386542468542847
# Final cost : 0.0006384161412461935
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006384161412461935
# Final cost : 0.0006382930678313414
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006382930678313414
# Final cost : 0.0006382465778642161
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006382465778642161
# Final cost : 0.0006381738764771062
# Compute control for a deterministic system
# Cost in iteration 0: 0.022743687557798344
# Final cost : 0.000748861726513151
# Compute control for a deterministic system
# Cost in iteration 0: 0.000748861726513151
# Final cost : 0.0007477339923829424
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007477339923829424
# Final cost : 0.0007465977103928148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007465977103928148
# Final cost : 0.000746474998864029
# Compute control for a deterministic system
# Cost in iteration 0: 0.000746474998864029
# Final cost : 0.0007463059156347181
# -----------------------------------------------
# 5 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.02804201074495409
# Final cost : 0.0008597142064015703
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008597142064015703
# Final cost : 0.0008588232631920288
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008588232631920288
# Final cost : 0.0008585637800297218
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008585637800297218
# Final cost : 0.0008585193156390738
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008585193156390738
# Final cost : 0.0008584885575085371
# -----------------------------------------------
# 5 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.025117104105884133
# Final cost : 0.0009990436642517
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009990436642517
# Final cost : 0.0009978452174291335
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009978452174291335
# Final cost : 0.0009976383968082051
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009976383968082051
# Final cost : 0.0009975980509099609
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009975980509099609
# Final cost : 0.0009975752995874086
# -----------------------------------------------
# 5 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.034958063876402844
# Final cost : 0.0011221743593311899
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011221743593311899
# Final cost : 0.0011173600757403831
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011173600757403831
# Final cost : 0.0011167519790603617
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011167519790603617
# Final cost : 0.0011166189210795197
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011166189210795197
# Final cost : 0.0011164854039860338
# Compute control for a deterministic system
# Cost in iteration 0: 0.02201257251655544
# Final cost : 0.0012470550674746948
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012470550674746948
# Final cost : 0.0012404828005391345
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012404828005391345
# Final cost : 0.0012387763931919205
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012387763931919205
# Final cost : 0.001237962977725968
# Compute control for a deterministic system
# Cost in iteration 0: 0.001237962977725968
# Final cost : 0.0012366384207234515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024925535471817563
# Final cost : 0.00135956160773587
# Compute control for a deterministic system
# Cost in iteration 0: 0.00135956160773587
# Final cost : 0.0013595444896744558
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013595444896744558
# Final cost : 0.0013595261458772287
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013595261458772287
# Final cost : 0.001359509869062273
# Compute control for a deterministic system
# Cost in iteration 0: 0.001359509869062273
# Final cost : 0.0013594749375779131
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.06282478397459669
# Final cost : 0.0015955998090136341
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015955998090136341
# Final cost : 0.001521930692391626
# Compute control for a deterministic system
# Cost in iteration 0: 0.001521930692391626
# Final cost : 0.0015177132652774545
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015177132652774545
# Final cost : 0.001515614210734051
# Compute control for a deterministic system
# Cost in iteration 0: 0.001515614210734051
# Final cost : 0.0015127153634087525
# Compute control for a deterministic system
# Cost in iteration 0: 0.007426363509734514
# Final cost : 0.0016453539297669863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016453539297669863
# Final cost : 0.0016446168179069477
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016446168179069477
# Final cost : 0.0016443112123881215
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016443112123881215
# Final cost : 0.0016440485867524773
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016440485867524773
# Final cost : 0.0016435024425112117
# -----------------------------------------------
# 5 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.017278314230553034
# Final cost : 0.0017934895358153239
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017934895358153239
# Final cost : 0.0017867969906773958
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017867969906773958
# Final cost : 0.0017856233813999622
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017856233813999622
# Final cost : 0.0017847840501764823
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017847840501764823
# Final cost : 0.0017829248961997103
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022646157572414937
# Final cost : 0.0019214461930919641
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019214461930919641
# Final cost : 0.0019212324064168047
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019212324064168047
# Final cost : 0.0019210088875944473
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019210088875944473
# Final cost : 0.0019207660882463546
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019207660882463546
# Final cost : 0.0019203179387658714
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.022462592612511857
# Final cost : 0.002096015156717363
# Compute control for a deterministic system
# Cost in iteration 0: 0.002096015156717363
# Final cost : 0.0020863085765988817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020863085765988817
# Final cost : 0.00208456126510965
# Compute control for a deterministic system
# Cost in iteration 0: 0.00208456126510965
# Final cost : 0.002083276147137989
# Compute control for a deterministic system
# Cost in iteration 0: 0.002083276147137989
# Final cost : 0.002081205002502984
# -----------------------------------------------
# 5 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.014695700781024529
# Final cost : 0.002277528184243878
# Compute control for a deterministic system
# Cost in iteration 0: 0.002277528184243878
# Final cost : 0.002272656584857911
# Compute control for a deterministic system
# Cost in iteration 0: 0.002272656584857911
# Final cost : 0.0022718123129531207
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022718123129531207
# Final cost : 0.0022710788388124866
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022710788388124866
# Final cost : 0.002269717780747305
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.07792386440920802
# Final cost : 0.0034124005383198
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034124005383198
# Final cost : 0.0024863473175059307
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024863473175059307
# Final cost : 0.0024380669559084262
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024380669559084262
# Final cost : 0.00243359776647361
# Compute control for a deterministic system
# Cost in iteration 0: 0.00243359776647361
# Final cost : 0.0024299679840835493
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.013922707291087365
# Final cost : 0.0026112452106237614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026112452106237614
# Final cost : 0.0026078479548708503
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026078479548708503
# Final cost : 0.0026066662176723113
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026066662176723113
# Final cost : 0.0026058240272267994
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026058240272267994
# Final cost : 0.0026040683693860753
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.02240307730157018
# Final cost : 0.002803733201143872
# Compute control for a deterministic system
# Cost in iteration 0: 0.002803733201143872
# Final cost : 0.0027960082240908748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027960082240908748
# Final cost : 0.002794201815210425
# Compute control for a deterministic system
# Cost in iteration 0: 0.002794201815210425
# Final cost : 0.002792808665514249
# Compute control for a deterministic system
# Cost in iteration 0: 0.002792808665514249
# Final cost : 0.002790562216794309
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.002894945305159365
# Final cost : 0.00257907295392931
# Compute control for a deterministic system
# Cost in iteration 0: 0.00257907295392931
# Final cost : 0.0025790694886555364
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025790694886555364
# Final cost : 0.0025790679796512677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025790679796512677
# Final cost : 0.0025790674195674507
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025790674195674507
# Final cost : 0.002579067201871284
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.004963851564833826
# Final cost : 0.0021013237919429747
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021013237919429747
# Final cost : 0.0021012989204286002
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021012989204286002
# Final cost : 0.0021012916973510306
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021012916973510306
# Final cost : 0.002101290490537267
# Compute control for a deterministic system
# Cost in iteration 0: 0.002101290490537267
# Final cost : 0.0021012899368327747
# Compute control for a deterministic system
# Cost in iteration 0: 0.01994801387390032
# Final cost : 0.00175001947686873
# Compute control for a deterministic system
# Cost in iteration 0: 0.00175001947686873
# Final cost : 0.0017496488315158875
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017496488315158875
# Final cost : 0.0017495998686119995
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017495998686119995
# Final cost : 0.0017495878168426557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017495878168426557
# Final cost : 0.0017495819811715963
# Compute control for a deterministic system
# Cost in iteration 0: 0.004886103495591411
# Final cost : 0.0014376072331291165
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014376072331291165
# Final cost : 0.0014375710969508834
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375710969508834
# Final cost : 0.0014375568436769195
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375568436769195
# Final cost : 0.0014375515290465577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014375515290465577
# Final cost : 0.0014375487474290627
# Compute control for a deterministic system
# Cost in iteration 0: 0.002824210991650455
# Final cost : 0.0011629400777330692
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011629400777330692
# Final cost : 0.001162918437824391
# Compute control for a deterministic system
# Cost in iteration 0: 0.001162918437824391
# Final cost : 0.0011629071496648132
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011629071496648132
# Final cost : 0.0011629036176799272
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011629036176799272
# Final cost : 0.0011629015120513423
# Compute control for a deterministic system
# Cost in iteration 0: 0.009512831223392337
# Final cost : 0.0009255919820635745
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009255919820635745
# Final cost : 0.0009243555164252817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009243555164252817
# Final cost : 0.0009235423169726181
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009235423169726181
# Final cost : 0.0009234348622260411
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009234348622260411
# Final cost : 0.0009233915286607508
# Compute control for a deterministic system
# Cost in iteration 0: 0.004056444003176488
# Final cost : 0.0006792911905361627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006792911905361627
# Final cost : 0.000679223105209711
# Compute control for a deterministic system
# Cost in iteration 0: 0.000679223105209711
# Final cost : 0.0006791869282289309
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006791869282289309
# Final cost : 0.0006791720055296539
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006791720055296539
# Final cost : 0.0006791653667991348
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017733781127488458
# Final cost : 0.0005091176178407009
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005091176178407009
# Final cost : 0.0005091004035578991
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005091004035578991
# Final cost : 0.000509089990535735
# Compute control for a deterministic system
# Cost in iteration 0: 0.000509089990535735
# Final cost : 0.0005090881899158461
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005090881899158461
# Final cost : 0.0005090875792615568
# Compute control for a deterministic system
# Cost in iteration 0: 0.0040186619128017315
# Final cost : 0.0003674742181442713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003674742181442713
# Final cost : 0.0003672889128861654
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003672889128861654
# Final cost : 0.0003671999128811584
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003671999128811584
# Final cost : 0.00036717702906359143
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036717702906359143
# Final cost : 0.00036716976285782425
# Compute control for a deterministic system
# Cost in iteration 0: 0.00027297035687274016
# Final cost : 0.00025139263397073335
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025139263397073335
# Final cost : 0.0002513893754517088
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002513893754517088
# Final cost : 0.0002513881538229674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002513881538229674
# Final cost : 0.00025138784717603884
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025138784717603884
# Final cost : 0.0002513876013441664
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003877272939919292
# Final cost : 0.00015983900360579795
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015983900360579795
# Final cost : 0.00015982271150525207
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015982271150525207
# Final cost : 0.00015981851629682947
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015981851629682947
# Final cost : 0.00015981691812069044
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015981691812069044
# Final cost : 0.00015981567848107043
# Compute control for a deterministic system
# Cost in iteration 0: 0.000439371347425584
# Final cost : 7.933793054533687e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.933793054533687e-05
# Final cost : 7.931611069598253e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.931611069598253e-05
# Final cost : 7.931149329962837e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.931149329962837e-05
# Final cost : 7.93101182789631e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.93101182789631e-05
# Final cost : 7.930911188688945e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022726637893876774
# Final cost : 3.4696782585362956e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4696782585362956e-05
# Final cost : 3.4688109580250355e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4688109580250355e-05
# Final cost : 3.4684553716962935e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4684553716962935e-05
# Final cost : 3.4682992011667734e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4682992011667734e-05
# Final cost : 3.4681976877432105e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.458247185598136e-05
# Final cost : 8.754117840630389e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.754117840630389e-06
# Final cost : 8.753077484247655e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.753077484247655e-06
# Final cost : 8.752648568484614e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.752648568484614e-06
# Final cost : 8.752319550815825e-06
# Compute control for a deterministic system
# Cost in iteration 0: 8.752319550815825e-06
# Final cost : 8.752135406954199e-06

# %%
save(results_min)
