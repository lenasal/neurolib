# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4353161677504697 
y_init = 0.4948614151973427
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,171], wc.inh[0,171]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.20256788383864668 0.45501490253970783
# minima =  [ 126  334  542  750  959 1167 1375 1583 1791 2000 2208 2416 2624 2832
#  3041 3249 3457 3665 3873]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06960096309137134
# Cost in iteration 200: 0.009441765636657542
# Final cost : 0.009441765636657542
# Compute control for a deterministic system
# Cost in iteration 0: 0.009441765636657542
# Converged in iteration 133 with cost 0.009441765531443066 because of step counter
# Final cost : 0.009441765531443066
# Compute control for a deterministic system
# Cost in iteration 0: 0.009441765531443066
# Converged in iteration 6 with cost 0.009441765531425818 because of step counter
# Final cost : 0.009441765531425818
# Compute control for a deterministic system
# Cost in iteration 0: 0.009441765531425818
# Converged in iteration 1 with cost 0.009441765531425818 because of step counter
# Final cost : 0.009441765531425818
# Compute control for a deterministic system
# Cost in iteration 0: 0.009441765531425818
# Converged in iteration 1 with cost 0.009441765531425818 because of step counter
# Final cost : 0.009441765531425818
# Compute control for a deterministic system
# Cost in iteration 0: 0.09219010624539149
# Cost in iteration 200: 0.015076011021200958
# Final cost : 0.015076011021200958
# Compute control for a deterministic system
# Cost in iteration 0: 0.015076011021200958
# Cost in iteration 200: 0.015075851049886336
# Final cost : 0.015075851049886336
# Compute control for a deterministic system
# Cost in iteration 0: 0.015075851049886336
# Converged in iteration 159 with cost 0.015075850721969328 because of step counter
# Final cost : 0.015075850721969328
# Compute control for a deterministic system
# Cost in iteration 0: 0.015075850721969328
# Converged in iteration 1 with cost 0.015075850721969328 because of step counter
# Final cost : 0.015075850721969328
# Compute control for a deterministic system
# Cost in iteration 0: 0.015075850721969328
# Converged in iteration 1 with cost 0.015075850721969328 because of step counter
# Final cost : 0.015075850721969328
# Compute control for a deterministic system
# Cost in iteration 0: 0.07776410711123025
# Cost in iteration 200: 0.01966914418506549
# Final cost : 0.01966914418506549
# Compute control for a deterministic system
# Cost in iteration 0: 0.01966914418506549
# Converged in iteration 119 with cost 0.019667919504315692 because of vanishing difference
# Final cost : 0.019667919504315692
# Compute control for a deterministic system
# Cost in iteration 0: 0.019667919504315692
# Cost in iteration 200: 0.019667760073850835
# Final cost : 0.019667760073850835
# Compute control for a deterministic system
# Cost in iteration 0: 0.019667760073850835
# Cost in iteration 200: 0.019667759443100917
# Cost in iteration 400: 0.019667759432389426
# Final cost : 0.019667759432389426
# Compute control for a deterministic system
# Cost in iteration 0: 0.019667759432389426
# Converged in iteration 82 with cost 0.01966775943221047 because of step counter
# Final cost : 0.01966775943221047
# Compute control for a deterministic system
# Cost in iteration 0: 0.09242487192027656
# Cost in iteration 200: 0.024162225597499976
# Final cost : 0.024162225597499976
# Compute control for a deterministic system
# Cost in iteration 0: 0.024162225597499976
# Cost in iteration 200: 0.024156356582056122
# Final cost : 0.024156356582056122
# Compute control for a deterministic system
# Cost in iteration 0: 0.024156356582056122
# Cost in iteration 200: 0.024155829978394525
# Final cost : 0.024155829978394525
# Compute control for a deterministic system
# Cost in iteration 0: 0.024155829978394525
# Cost in iteration 200: 0.024155815069003193
# Cost in iteration 400: 0.02415581406270638
# Final cost : 0.02415581406270638
# Compute control for a deterministic system
# Cost in iteration 0: 0.02415581406270638
# Cost in iteration 200: 0.024155813994351533
# Cost in iteration 400: 0.024155813988194313
# Converged in iteration 569 with cost 0.024155813987572657 because of step counter
# Final cost : 0.024155813987572657
# Compute control for a deterministic system
# Cost in iteration 0: 0.07938552770911708
# Cost in iteration 200: 0.028543368633558205
# Final cost : 0.028543368633558205
# Compute control for a deterministic system
# Cost in iteration 0: 0.028543368633558205
# Converged in iteration 124 with cost 0.028528294185373015 because of vanishing difference
# Final cost : 0.028528294185373015
# Compute control for a deterministic system
# Cost in iteration 0: 0.028528294185373015
# Cost in iteration 200: 0.028527405515834714
# Final cost : 0.028527405515834714
# Compute control for a deterministic system
# Cost in iteration 0: 0.028527405515834714
# Cost in iteration 200: 0.028527308271714652
# Cost in iteration 400: 0.02852729276625216
# Final cost : 0.02852729276625216
# Compute control for a deterministic system
# Cost in iteration 0: 0.02852729276625216
# Cost in iteration 200: 0.028527289780037178
# Converged in iteration 220 with cost 0.028527289779998553 because of step counter
# Final cost : 0.028527289779998553
# Compute control for a deterministic system
# Cost in iteration 0: 0.12879438727374645
# Cost in iteration 200: 0.03279006808756105
# Final cost : 0.03279006808756105
# Compute control for a deterministic system
# Cost in iteration 0: 0.03279006808756105
# Converged in iteration 175 with cost 0.032759936541025984 because of vanishing difference
# Final cost : 0.032759936541025984
# Compute control for a deterministic system
# Cost in iteration 0: 0.032759936541025984
# Cost in iteration 200: 0.03275883375947512
# Final cost : 0.03275883375947512
# Compute control for a deterministic system
# Cost in iteration 0: 0.03275883375947512
# Cost in iteration 200: 0.03275857418204719
# Cost in iteration 400: 0.03275850315294426
# Final cost : 0.03275850315294426
# Compute control for a deterministic system
# Cost in iteration 0: 0.03275850315294426
# Cost in iteration 200: 0.03275847643604492
# Cost in iteration 400: 0.032758476259887766
# Converged in iteration 422 with cost 0.032758476259527075 because of vanishing difference
# Final cost : 0.032758476259527075
# Compute control for a deterministic system
# Cost in iteration 0: 0.08634258701085087
# Cost in iteration 200: 0.03770626955916604
# Final cost : 0.03770626955916604
# Compute control for a deterministic system
# Cost in iteration 0: 0.03770626955916604
# Cost in iteration 200: 0.037633189411431844
# Final cost : 0.037633189411431844
# Compute control for a deterministic system
# Cost in iteration 0: 0.037633189411431844
# Cost in iteration 200: 0.037626290347634
# Final cost : 0.037626290347634
# Compute control for a deterministic system
# Cost in iteration 0: 0.037626290347634
# Cost in iteration 200: 0.03762422446853958
# Cost in iteration 400: 0.037623400482819765
# Final cost : 0.037623400482819765
# Compute control for a deterministic system
# Cost in iteration 0: 0.037623400482819765
# Cost in iteration 200: 0.03762287621742927
# Cost in iteration 400: 0.037622835964739414
# Cost in iteration 600: 0.037622831987543355
# Cost in iteration 800: 0.03762283142875122
# Cost in iteration 1000: 0.03762283135750271
# Final cost : 0.03762283135750271
# Compute control for a deterministic system
# Cost in iteration 0: 0.10929760901970717
# Cost in iteration 200: 0.04155868703757146
# Final cost : 0.04155868703757146
# Compute control for a deterministic system
# Cost in iteration 0: 0.04155868703757146
# Cost in iteration 200: 0.041513211621927566
# Final cost : 0.041513211621927566
# Compute control for a deterministic system
# Cost in iteration 0: 0.041513211621927566
# Cost in iteration 200: 0.04150923372669044
# Final cost : 0.04150923372669044
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150923372669044
# Cost in iteration 200: 0.041507593809830226
# Cost in iteration 400: 0.04150676636814424
# Final cost : 0.04150676636814424
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150676636814424
# Cost in iteration 200: 0.0415060964120252
# Cost in iteration 400: 0.04150593866418159
# Cost in iteration 600: 0.04150590416612473
# Cost in iteration 800: 0.04150589671562255
# Cost in iteration 1000: 0.04150589511471033
# Final cost : 0.04150589511471033
# Compute control for a deterministic system
# Cost in iteration 0: 0.08737225439783815
# Cost in iteration 200: 0.045319300391778485
# Final cost : 0.045319300391778485
# Compute control for a deterministic system
# Cost in iteration 0: 0.045319300391778485
# Cost in iteration 200: 0.045269933492438935
# Final cost : 0.045269933492438935
# Compute control for a deterministic system
# Cost in iteration 0: 0.045269933492438935
# Cost in iteration 200: 0.045263298389961064
# Final cost : 0.045263298389961064
# Compute control for a deterministic system
# Cost in iteration 0: 0.045263298389961064
# Cost in iteration 200: 0.04526005216176715
# Cost in iteration 400: 0.0452581611289212
# Final cost : 0.0452581611289212
# Compute control for a deterministic system
# Cost in iteration 0: 0.0452581611289212
# Cost in iteration 200: 0.045256451818827384
# Cost in iteration 400: 0.04525576701628035
# Cost in iteration 600: 0.045255499797794044
# Cost in iteration 800: 0.04525538827923643
# Cost in iteration 1000: 0.04525534206551204
# Final cost : 0.04525534206551204
# Compute control for a deterministic system
# Cost in iteration 0: 0.13021281176449281
# Cost in iteration 200: 0.04911546189562547
# Final cost : 0.04911546189562547
# Compute control for a deterministic system
# Cost in iteration 0: 0.04911546189562547
# Cost in iteration 200: 0.04892687668639511
# Final cost : 0.04892687668639511
# Compute control for a deterministic system
# Cost in iteration 0: 0.04892687668639511
# Cost in iteration 200: 0.048913794712208976
# Final cost : 0.048913794712208976
# Compute control for a deterministic system
# Cost in iteration 0: 0.048913794712208976
# Cost in iteration 200: 0.048907088892689805
# Cost in iteration 400: 0.04890281287592258
# Final cost : 0.04890281287592258
# Compute control for a deterministic system
# Cost in iteration 0: 0.04890281287592258
# Cost in iteration 200: 0.04889856293303593
# Cost in iteration 400: 0.04889633831458278
# Cost in iteration 600: 0.048895322607400336
# Cost in iteration 800: 0.0488948344445978
# Cost in iteration 1000: 0.0488945774032042
# Final cost : 0.0488945774032042
# Compute control for a deterministic system
# Cost in iteration 0: 0.06606979627151122
# Cost in iteration 200: 0.052528691495583486
# Final cost : 0.052528691495583486
# Compute control for a deterministic system
# Cost in iteration 0: 0.052528691495583486
# Cost in iteration 200: 0.05248003802907081
# Final cost : 0.05248003802907081
# Compute control for a deterministic system
# Cost in iteration 0: 0.05248003802907081
# Cost in iteration 200: 0.05246892924215024
# Final cost : 0.05246892924215024
# Compute control for a deterministic system
# Cost in iteration 0: 0.05246892924215024
# Cost in iteration 200: 0.05246229284693629
# Cost in iteration 400: 0.05245769705692967
# Final cost : 0.05245769705692967
# Compute control for a deterministic system
# Cost in iteration 0: 0.05245769705692967
# Cost in iteration 200: 0.052452798824239026
# Cost in iteration 400: 0.05245008001203567
# Cost in iteration 600: 0.05244833294281912
# Cost in iteration 800: 0.052447197885469955
# Cost in iteration 1000: 0.052446455919738545
# Final cost : 0.052446455919738545
# Compute control for a deterministic system
# Cost in iteration 0: 0.10385493393845324
# Cost in iteration 200: 0.056834808808794816
# Final cost : 0.056834808808794816
# Compute control for a deterministic system
# Cost in iteration 0: 0.056834808808794816
# Cost in iteration 200: 0.0566871432719914
# Final cost : 0.0566871432719914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0566871432719914
# Converged in iteration 118 with cost 0.056674435290740656 because of vanishing difference
# Final cost : 0.056674435290740656
# Compute control for a deterministic system
# Cost in iteration 0: 0.056674435290740656
# Cost in iteration 200: 0.05666041259967011
# Cost in iteration 400: 0.0566505688337909
# Final cost : 0.0566505688337909
# Compute control for a deterministic system
# Cost in iteration 0: 0.0566505688337909
# Cost in iteration 200: 0.056640063587978025
# Cost in iteration 400: 0.05663303035381567
# Cost in iteration 600: 0.056628554156152214
# Cost in iteration 800: 0.05662526874542772
# Cost in iteration 1000: 0.05662288223795866
# Final cost : 0.05662288223795866
# Compute control for a deterministic system
# Cost in iteration 0: 0.11160403735861966
# Cost in iteration 200: 0.060146099974942774
# Final cost : 0.060146099974942774
# Compute control for a deterministic system
# Cost in iteration 0: 0.060146099974942774
# Cost in iteration 200: 0.06009199545214455
# Final cost : 0.06009199545214455
# Compute control for a deterministic system
# Cost in iteration 0: 0.06009199545214455
# Cost in iteration 200: 0.06007699085454339
# Final cost : 0.06007699085454339
# Compute control for a deterministic system
# Cost in iteration 0: 0.06007699085454339
# Cost in iteration 200: 0.0600527631877024
# Cost in iteration 400: 0.06004221357922596
# Final cost : 0.06004221357922596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06004221357922596
# Cost in iteration 200: 0.06004016088993206
# Cost in iteration 400: 0.060038581235032695
# Cost in iteration 600: 0.060037313366990225
# Cost in iteration 800: 0.06003630158810001
# Cost in iteration 1000: 0.06003542372866183
# Final cost : 0.06003542372866183
# Compute control for a deterministic system
# Cost in iteration 0: 0.09304489760790374
# Cost in iteration 200: 0.06352143038649924
# Final cost : 0.06352143038649924
# Compute control for a deterministic system
# Cost in iteration 0: 0.06352143038649924
# Cost in iteration 200: 0.0634701975341141
# Final cost : 0.0634701975341141
# Compute control for a deterministic system
# Cost in iteration 0: 0.0634701975341141
# Cost in iteration 200: 0.06345399439824988
# Final cost : 0.06345399439824988
# Compute control for a deterministic system
# Cost in iteration 0: 0.06345399439824988
# Cost in iteration 200: 0.06343057550892173
# Cost in iteration 400: 0.06342147391251282
# Final cost : 0.06342147391251282
# Compute control for a deterministic system
# Cost in iteration 0: 0.06342147391251282
# Cost in iteration 200: 0.06341772197973994
# Cost in iteration 400: 0.06341466216878437
# Cost in iteration 600: 0.06341229323211958
# Cost in iteration 800: 0.0634102585699805
# Cost in iteration 1000: 0.06340851282604652
# Final cost : 0.06340851282604652
# Compute control for a deterministic system
# Cost in iteration 0: 0.09399585925806966
# Cost in iteration 200: 0.06690706652034133
# Final cost : 0.06690706652034133
# Compute control for a deterministic system
# Cost in iteration 0: 0.06690706652034133
# Cost in iteration 200: 0.0668039584189068
# Final cost : 0.0668039584189068
# Compute control for a deterministic system
# Cost in iteration 0: 0.0668039584189068
# Cost in iteration 200: 0.06678673322174296
# Final cost : 0.06678673322174296
# Compute control for a deterministic system
# Cost in iteration 0: 0.06678673322174296
# Cost in iteration 200: 0.06676691596426061
# Cost in iteration 400: 0.06675597400529985
# Final cost : 0.06675597400529985
# Compute control for a deterministic system
# Cost in iteration 0: 0.06675597400529985
# Cost in iteration 200: 0.06675072801449962
# Cost in iteration 400: 0.06674663388720146
# Cost in iteration 600: 0.06674320982335358
# Cost in iteration 800: 0.06674025872782587
# Cost in iteration 1000: 0.06673775209894538
# Final cost : 0.06673775209894538
# Compute control for a deterministic system
# Cost in iteration 0: 0.10496725720685895
# Cost in iteration 200: 0.07083503721787068
# Final cost : 0.07083503721787068
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083503721787068
# Cost in iteration 200: 0.0707686265383906
# Final cost : 0.0707686265383906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0707686265383906
# Cost in iteration 200: 0.07074652143973079
# Final cost : 0.07074652143973079
# Compute control for a deterministic system
# Cost in iteration 0: 0.07074652143973079
# Cost in iteration 200: 0.07072233667387728
# Cost in iteration 400: 0.07070826274609128
# Final cost : 0.07070826274609128
# Compute control for a deterministic system
# Cost in iteration 0: 0.07070826274609128
# Cost in iteration 200: 0.07070043329750039
# Cost in iteration 400: 0.0706938752827436
# Cost in iteration 600: 0.07068833288658406
# Cost in iteration 800: 0.07068354344693802
# Cost in iteration 1000: 0.07067938914095556
# Final cost : 0.07067938914095556
# Compute control for a deterministic system
# Cost in iteration 0: 0.10308440619174195
# Cost in iteration 200: 0.07412421620985746
# Final cost : 0.07412421620985746
# Compute control for a deterministic system
# Cost in iteration 0: 0.07412421620985746
# Cost in iteration 200: 0.07396765794160076
# Final cost : 0.07396765794160076
# Compute control for a deterministic system
# Cost in iteration 0: 0.07396765794160076
# Cost in iteration 200: 0.07395267682322057
# Final cost : 0.07395267682322057
# Compute control for a deterministic system
# Cost in iteration 0: 0.07395267682322057
# Cost in iteration 200: 0.07393674815199998
# Cost in iteration 400: 0.07392603104746003
# Final cost : 0.07392603104746003
# Compute control for a deterministic system
# Cost in iteration 0: 0.07392603104746003
# Cost in iteration 200: 0.07391909000170388
# Cost in iteration 400: 0.0739131867201388
# Cost in iteration 600: 0.0739080675766344
# Cost in iteration 800: 0.07390357898744876
# Cost in iteration 1000: 0.07389960550129528
# Final cost : 0.07389960550129528
# Compute control for a deterministic system
# Cost in iteration 0: 0.11484049156867362
# Cost in iteration 200: 0.07749599967308461
# Final cost : 0.07749599967308461
# Compute control for a deterministic system
# Cost in iteration 0: 0.07749599967308461
# Cost in iteration 200: 0.07707117711380966
# Final cost : 0.07707117711380966
# Compute control for a deterministic system
# Cost in iteration 0: 0.07707117711380966
# Converged in iteration 62 with cost 0.07706095249839198 because of vanishing difference
# Final cost : 0.07706095249839198
# Compute control for a deterministic system
# Cost in iteration 0: 0.07706095249839198
# Cost in iteration 200: 0.07704965246552088
# Cost in iteration 400: 0.07704196335229756
# Final cost : 0.07704196335229756
# Compute control for a deterministic system
# Cost in iteration 0: 0.07704196335229756
# Cost in iteration 200: 0.07703708281983886
# Cost in iteration 400: 0.07703320373443664
# Cost in iteration 600: 0.07703002805051334
# Cost in iteration 800: 0.07702742305941426
# Cost in iteration 1000: 0.07702526113452234
# Final cost : 0.07702526113452234
# Compute control for a deterministic system
# Cost in iteration 0: 0.08894189859645588
# Cost in iteration 200: 0.08019298408483581
# Final cost : 0.08019298408483581
# Compute control for a deterministic system
# Cost in iteration 0: 0.08019298408483581
# Cost in iteration 200: 0.08017556736608612
# Final cost : 0.08017556736608612
# Compute control for a deterministic system
# Cost in iteration 0: 0.08017556736608612
# Converged in iteration 7 with cost 0.08017534926378969 because of vanishing difference
# Final cost : 0.08017534926378969
# Compute control for a deterministic system
# Cost in iteration 0: 0.08017534926378969
# Cost in iteration 200: 0.08016561027524477
# Cost in iteration 400: 0.08015894565242415
# Final cost : 0.08015894565242415
# Compute control for a deterministic system
# Cost in iteration 0: 0.08015894565242415
# Cost in iteration 200: 0.08015427656157649
# Cost in iteration 400: 0.08015040813907062
# Cost in iteration 600: 0.08014714659102337
# Cost in iteration 800: 0.08014436641289117
# Cost in iteration 1000: 0.08014196674903695
# Final cost : 0.08014196674903695
# Compute control for a deterministic system
# Cost in iteration 0: 0.1280902609171123
# Cost in iteration 200: 0.08341693071667114
# Final cost : 0.08341693071667114
# Compute control for a deterministic system
# Cost in iteration 0: 0.08341693071667114
# Cost in iteration 200: 0.0832643539748557
# Final cost : 0.0832643539748557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0832643539748557
# Converged in iteration 32 with cost 0.08325911915233124 because of vanishing difference
# Final cost : 0.08325911915233124
# Compute control for a deterministic system
# Cost in iteration 0: 0.08325911915233124
# Cost in iteration 200: 0.0832484759747501
# Cost in iteration 400: 0.08324148741142863
# Final cost : 0.08324148741142863
# Compute control for a deterministic system
# Cost in iteration 0: 0.08324148741142863
# Cost in iteration 200: 0.08323644104080091
# Cost in iteration 400: 0.08323210209699441
# Cost in iteration 600: 0.08322833311770043
# Cost in iteration 800: 0.08322498951761634
# Cost in iteration 1000: 0.08322199202798615
# Final cost : 0.08322199202798615
# Compute control for a deterministic system
# Cost in iteration 0: 0.14928997601249547
# Cost in iteration 200: 0.08715187593806194
# Final cost : 0.08715187593806194
# Compute control for a deterministic system
# Cost in iteration 0: 0.08715187593806194
# Cost in iteration 200: 0.08697909677777776
# Final cost : 0.08697909677777776
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697909677777776
# Converged in iteration 3 with cost 0.08697899830969542 because of vanishing difference
# Final cost : 0.08697899830969542
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697899830969542
# Cost in iteration 200: 0.08696264594798289
# Cost in iteration 400: 0.08695216005370428
# Final cost : 0.08695216005370428
# Compute control for a deterministic system
# Cost in iteration 0: 0.08695216005370428
# Cost in iteration 200: 0.08694427833025486
# Cost in iteration 400: 0.08693732748765169
# Cost in iteration 600: 0.08693096307531381
# Cost in iteration 800: 0.08692511737237578
# Cost in iteration 1000: 0.08691965251617151
# Final cost : 0.08691965251617151
# Compute control for a deterministic system
# Cost in iteration 0: 0.5825477024248471
# Cost in iteration 200: 0.11340442562898183
# Final cost : 0.11340442562898183
# Compute control for a deterministic system
# Cost in iteration 0: 0.11340442562898183
# Cost in iteration 200: 0.10204352911126208
# Final cost : 0.10204352911126208
# Compute control for a deterministic system
# Cost in iteration 0: 0.10204352911126208
# Cost in iteration 200: 0.10096822351736655
# Final cost : 0.10096822351736655
# Compute control for a deterministic system
# Cost in iteration 0: 0.10096822351736655
# Cost in iteration 200: 0.10038761555311022
# Cost in iteration 400: 0.0999054646253323
# Final cost : 0.0999054646253323
# Compute control for a deterministic system
# Cost in iteration 0: 0.0999054646253323
# Cost in iteration 200: 0.09950636371361272
# Cost in iteration 400: 0.09911909117315494
# Cost in iteration 600: 0.09873759353633439
# Cost in iteration 800: 0.09836032748805155
# Cost in iteration 1000: 0.09798647037073764
# Final cost : 0.09798647037073764
# Compute control for a deterministic system
# Cost in iteration 0: 0.2984261697992238
# Cost in iteration 200: 0.09750875030130086
# Final cost : 0.09750875030130086
# Compute control for a deterministic system
# Cost in iteration 0: 0.09750875030130086
# Cost in iteration 200: 0.09708563212188767
# Final cost : 0.09708563212188767
# Compute control for a deterministic system
# Cost in iteration 0: 0.09708563212188767
# Cost in iteration 200: 0.09664070174408906
# Final cost : 0.09664070174408906
# Compute control for a deterministic system
# Cost in iteration 0: 0.09664070174408906
# Cost in iteration 200: 0.09624557870993505
# Cost in iteration 400: 0.09585915760260402
# Final cost : 0.09585915760260402
# Compute control for a deterministic system
# Cost in iteration 0: 0.09585915760260402
# Cost in iteration 200: 0.09554959525596744
# Cost in iteration 400: 0.09523025743713345
# Cost in iteration 600: 0.09492586587951464
# Cost in iteration 800: 0.09462078505320587
# Cost in iteration 1000: 0.09431671302360371
# Final cost : 0.09431671302360371
# Compute control for a deterministic system
# Cost in iteration 0: 0.46948277471184013
# Cost in iteration 200: 0.10567724772570507
# Final cost : 0.10567724772570507
# Compute control for a deterministic system
# Cost in iteration 0: 0.10567724772570507
# Cost in iteration 200: 0.10351460328728428
# Final cost : 0.10351460328728428
# Compute control for a deterministic system
# Cost in iteration 0: 0.10351460328728428
# Cost in iteration 200: 0.10306108954352707
# Final cost : 0.10306108954352707
# Compute control for a deterministic system
# Cost in iteration 0: 0.10306108954352707
# Cost in iteration 200: 0.10264777497740031
# Cost in iteration 400: 0.1022487927362123
# Final cost : 0.1022487927362123
# Compute control for a deterministic system
# Cost in iteration 0: 0.1022487927362123
# Cost in iteration 200: 0.10193014896281138
# Cost in iteration 400: 0.10161976921089814
# Cost in iteration 600: 0.10131309934431264
# Cost in iteration 800: 0.10100904003412525
# Cost in iteration 1000: 0.10070699385205417
# Final cost : 0.10070699385205417
# Compute control for a deterministic system
# Cost in iteration 0: 0.19476896430792276
# Cost in iteration 200: 0.08636738048485515
# Final cost : 0.08636738048485515
# Compute control for a deterministic system
# Cost in iteration 0: 0.08636738048485515
# Cost in iteration 200: 0.08618513638637823
# Final cost : 0.08618513638637823
# Compute control for a deterministic system
# Cost in iteration 0: 0.08618513638637823
# Converged in iteration 199 with cost 0.0861650373949676 because of vanishing difference
# Final cost : 0.0861650373949676
# Compute control for a deterministic system
# Cost in iteration 0: 0.0861650373949676
# Cost in iteration 200: 0.086158352930008
# Cost in iteration 400: 0.0861556213993328
# Final cost : 0.0861556213993328
# Compute control for a deterministic system
# Cost in iteration 0: 0.0861556213993328
# Cost in iteration 200: 0.08615382302373058
# Cost in iteration 400: 0.0861537443990226
# Cost in iteration 600: 0.08615374387319436
# Converged in iteration 720 with cost 0.08615374387100262 because of vanishing difference
# Final cost : 0.08615374387100262
# Compute control for a deterministic system
# Cost in iteration 0: 0.16637511280963194
# Cost in iteration 200: 0.07834695933972707
# Final cost : 0.07834695933972707
# Compute control for a deterministic system
# Cost in iteration 0: 0.07834695933972707
# Cost in iteration 200: 0.07812663825721465
# Final cost : 0.07812663825721465
# Compute control for a deterministic system
# Cost in iteration 0: 0.07812663825721465
# Cost in iteration 200: 0.07809381116013737
# Final cost : 0.07809381116013737
# Compute control for a deterministic system
# Cost in iteration 0: 0.07809381116013737
# Cost in iteration 200: 0.0780846275217345
# Cost in iteration 400: 0.07808133729183467
# Final cost : 0.07808133729183467
# Compute control for a deterministic system
# Cost in iteration 0: 0.07808133729183467
# Cost in iteration 200: 0.0780795172827311
# Cost in iteration 400: 0.0780795075371649
# Converged in iteration 547 with cost 0.07807950752725071 because of step counter
# Final cost : 0.07807950752725071
# Compute control for a deterministic system
# Cost in iteration 0: 0.13138062611372348
# Cost in iteration 200: 0.07162779557600907
# Final cost : 0.07162779557600907
# Compute control for a deterministic system
# Cost in iteration 0: 0.07162779557600907
# Cost in iteration 200: 0.07148856692918945
# Final cost : 0.07148856692918945
# Compute control for a deterministic system
# Cost in iteration 0: 0.07148856692918945
# Cost in iteration 200: 0.07147288129192965
# Final cost : 0.07147288129192965
# Compute control for a deterministic system
# Cost in iteration 0: 0.07147288129192965
# Cost in iteration 200: 0.07146908743007102
# Cost in iteration 400: 0.07146790485361985
# Final cost : 0.07146790485361985
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146790485361985
# Cost in iteration 200: 0.07146739517432092
# Cost in iteration 400: 0.07146738365227592
# Cost in iteration 600: 0.07146738336306659
# Converged in iteration 732 with cost 0.07146738335577671 because of vanishing difference
# Final cost : 0.07146738335577671
# Compute control for a deterministic system
# Cost in iteration 0: 0.07424385527471918
# Cost in iteration 200: 0.06510236077630902
# Final cost : 0.06510236077630902
# Compute control for a deterministic system
# Cost in iteration 0: 0.06510236077630902
# Cost in iteration 200: 0.06497461385938413
# Final cost : 0.06497461385938413
# Compute control for a deterministic system
# Cost in iteration 0: 0.06497461385938413
# Converged in iteration 7 with cost 0.06497387341322389 because of vanishing difference
# Final cost : 0.06497387341322389
# Compute control for a deterministic system
# Cost in iteration 0: 0.06497387341322389
# Cost in iteration 200: 0.06496387089497253
# Cost in iteration 400: 0.06496123609657305
# Final cost : 0.06496123609657305
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496123609657305
# Cost in iteration 200: 0.06496034781170038
# Cost in iteration 400: 0.06496032248936831
# Cost in iteration 600: 0.06496032200737759
# Converged in iteration 799 with cost 0.0649603219956488 because of step counter
# Final cost : 0.0649603219956488
# Compute control for a deterministic system
# Cost in iteration 0: 0.11806928536562863
# Cost in iteration 200: 0.058659584969663996
# Final cost : 0.058659584969663996
# Compute control for a deterministic system
# Cost in iteration 0: 0.058659584969663996
# Cost in iteration 200: 0.05857425007373549
# Final cost : 0.05857425007373549
# Compute control for a deterministic system
# Cost in iteration 0: 0.05857425007373549
# Cost in iteration 200: 0.05856872405429045
# Final cost : 0.05856872405429045
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856872405429045
# Cost in iteration 200: 0.058567789836730035
# Cost in iteration 400: 0.05856759487876181
# Final cost : 0.05856759487876181
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856759487876181
# Cost in iteration 200: 0.05856754520943408
# Cost in iteration 400: 0.058567543980922954
# Cost in iteration 600: 0.05856754393840898
# Converged in iteration 717 with cost 0.05856754393737688 because of step counter
# Final cost : 0.05856754393737688
# Compute control for a deterministic system
# Cost in iteration 0: 0.13251184238029337
# Cost in iteration 200: 0.05238629185283213
# Final cost : 0.05238629185283213
# Compute control for a deterministic system
# Cost in iteration 0: 0.05238629185283213
# Cost in iteration 200: 0.05230381439513927
# Final cost : 0.05230381439513927
# Compute control for a deterministic system
# Cost in iteration 0: 0.05230381439513927
# Cost in iteration 200: 0.05229928263574646
# Final cost : 0.05229928263574646
# Compute control for a deterministic system
# Cost in iteration 0: 0.05229928263574646
# Cost in iteration 200: 0.05229876207424378
# Cost in iteration 400: 0.052298679180651286
# Final cost : 0.052298679180651286
# Compute control for a deterministic system
# Cost in iteration 0: 0.052298679180651286
# Cost in iteration 200: 0.0522986637829696
# Converged in iteration 395 with cost 0.05229866356053619 because of vanishing difference
# Final cost : 0.05229866356053619
# Compute control for a deterministic system
# Cost in iteration 0: 0.07571333867482716
# Cost in iteration 200: 0.04501584347654107
# Final cost : 0.04501584347654107
# Compute control for a deterministic system
# Cost in iteration 0: 0.04501584347654107
# Cost in iteration 200: 0.044946167697499005
# Final cost : 0.044946167697499005
# Compute control for a deterministic system
# Cost in iteration 0: 0.044946167697499005
# Cost in iteration 200: 0.04494359576789768
# Final cost : 0.04494359576789768
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494359576789768
# Cost in iteration 200: 0.044943378980431256
# Cost in iteration 400: 0.04494335678099158
# Final cost : 0.04494335678099158
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494335678099158
# Cost in iteration 200: 0.04494335424486623
# Cost in iteration 400: 0.044943354197445835
# Converged in iteration 504 with cost 0.04494335419678153 because of step counter
# Final cost : 0.04494335419678153
# Compute control for a deterministic system
# Cost in iteration 0: 0.060980565711964724
# Cost in iteration 200: 0.03898276571881322
# Final cost : 0.03898276571881322
# Compute control for a deterministic system
# Cost in iteration 0: 0.03898276571881322
# Converged in iteration 190 with cost 0.038957977375321015 because of vanishing difference
# Final cost : 0.038957977375321015
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957977375321015
# Cost in iteration 200: 0.038957450268427694
# Final cost : 0.038957450268427694
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957450268427694
# Cost in iteration 200: 0.03895742330136611
# Cost in iteration 400: 0.038957421518715785
# Final cost : 0.038957421518715785
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957421518715785
# Cost in iteration 200: 0.038957421396504495
# Converged in iteration 309 with cost 0.03895742139528057 because of step counter
# Final cost : 0.03895742139528057
# Compute control for a deterministic system
# Cost in iteration 0: 0.11523692249934861
# Cost in iteration 200: 0.033122373173281545
# Final cost : 0.033122373173281545
# Compute control for a deterministic system
# Cost in iteration 0: 0.033122373173281545
# Converged in iteration 128 with cost 0.033107263537686574 because of vanishing difference
# Final cost : 0.033107263537686574
# Compute control for a deterministic system
# Cost in iteration 0: 0.033107263537686574
# Cost in iteration 200: 0.033106406191205875
# Final cost : 0.033106406191205875
# Compute control for a deterministic system
# Cost in iteration 0: 0.033106406191205875
# Cost in iteration 200: 0.03310638471590479
# Cost in iteration 400: 0.0331063839685589
# Final cost : 0.0331063839685589
# Compute control for a deterministic system
# Cost in iteration 0: 0.0331063839685589
# Cost in iteration 200: 0.03310638394157979
# Converged in iteration 246 with cost 0.03310638394144167 because of step counter
# Final cost : 0.03310638394144167
# Compute control for a deterministic system
# Cost in iteration 0: 0.09719422511113504
# Cost in iteration 200: 0.027395010335881924
# Final cost : 0.027395010335881924
# Compute control for a deterministic system
# Cost in iteration 0: 0.027395010335881924
# Cost in iteration 200: 0.0273930010976969
# Final cost : 0.0273930010976969
# Compute control for a deterministic system
# Cost in iteration 0: 0.0273930010976969
# Cost in iteration 200: 0.027392995452256298
# Final cost : 0.027392995452256298
# Compute control for a deterministic system
# Cost in iteration 0: 0.027392995452256298
# Cost in iteration 200: 0.027392995402906024
# Converged in iteration 303 with cost 0.027392995400441607 because of step counter
# Final cost : 0.027392995400441607
# Compute control for a deterministic system
# Cost in iteration 0: 0.027392995400441607
# Converged in iteration 1 with cost 0.027392995400441607 because of step counter
# Final cost : 0.027392995400441607
# Compute control for a deterministic system
# Cost in iteration 0: 0.06452046661531845
# Cost in iteration 200: 0.021819397752460338
# Final cost : 0.021819397752460338
# Compute control for a deterministic system
# Cost in iteration 0: 0.021819397752460338
# Converged in iteration 53 with cost 0.02181890415624855 because of vanishing difference
# Final cost : 0.02181890415624855
# Compute control for a deterministic system
# Cost in iteration 0: 0.02181890415624855
# Cost in iteration 200: 0.021818810988998332
# Final cost : 0.021818810988998332
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818810988998332
# Converged in iteration 71 with cost 0.021818810807192553 because of step counter
# Final cost : 0.021818810807192553
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818810807192553
# Converged in iteration 1 with cost 0.021818810807192553 because of step counter
# Final cost : 0.021818810807192553
# Compute control for a deterministic system
# Cost in iteration 0: 0.07302039271928613
# Converged in iteration 160 with cost 0.015315978183692704 because of vanishing difference
# Final cost : 0.015315978183692704
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315978183692704
# Cost in iteration 200: 0.015315818275987337
# Final cost : 0.015315818275987337
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818275987337
# Converged in iteration 125 with cost 0.015315818268887093 because of step counter
# Final cost : 0.015315818268887093
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818268887093
# Converged in iteration 7 with cost 0.015315818268882272 because of step counter
# Final cost : 0.015315818268882272
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818268882272
# Converged in iteration 2 with cost 0.015315818268881917 because of step counter
# Final cost : 0.015315818268881917
# Compute control for a deterministic system
# Cost in iteration 0: 0.05234994364574813
# Cost in iteration 200: 0.010056562468151106
# Final cost : 0.010056562468151106
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562468151106
# Converged in iteration 43 with cost 0.010056562467748966 because of vanishing difference
# Final cost : 0.010056562467748966
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467748966
# Converged in iteration 10 with cost 0.010056562467737057 because of step counter
# Final cost : 0.010056562467737057
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467737057
# Converged in iteration 1 with cost 0.010056562467737057 because of step counter
# Final cost : 0.010056562467737057
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467737057
# Converged in iteration 1 with cost 0.010056562467737057 because of step counter
# Final cost : 0.010056562467737057
# -----------------------------------------------
# 0 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.05086128191589084
# Converged in iteration 74 with cost 0.004957414680584657 because of vanishing difference
# Final cost : 0.004957414680584657
# Compute control for a deterministic system
# Cost in iteration 0: 0.004957414680584657
# Converged in iteration 73 with cost 0.0049574127721770216 because of step counter
# Final cost : 0.0049574127721770216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0049574127721770216
# Converged in iteration 1 with cost 0.0049574127721770216 because of step counter
# Final cost : 0.0049574127721770216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0049574127721770216
# Converged in iteration 1 with cost 0.0049574127721770216 because of step counter
# Final cost : 0.0049574127721770216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0049574127721770216
# Converged in iteration 1 with cost 0.0049574127721770216 because of step counter
# Final cost : 0.0049574127721770216
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.062236308582190904
# Converged in iteration 123 with cost 0.010056588227995298 because of vanishing difference
# Final cost : 0.010056588227995298
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056588227995298
# Converged in iteration 196 with cost 0.010056564494464505 because of step counter
# Final cost : 0.010056564494464505
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056564494464505
# Converged in iteration 1 with cost 0.010056564494464505 because of step counter
# Final cost : 0.010056564494464505
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056564494464505
# Converged in iteration 2 with cost 0.010056564494463372 because of step counter
# Final cost : 0.010056564494463372
# Compute control for a deterministic system
# Cost in iteration 0: 0.07572555626049503
# Cost in iteration 200: 0.01531581928593393
# Final cost : 0.01531581928593393
# Compute control for a deterministic system
# Cost in iteration 0: 0.01531581928593393
# Cost in iteration 200: 0.015315818151135866
# Final cost : 0.015315818151135866
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151135866
# Converged in iteration 32 with cost 0.015315818151045484 because of step counter
# Final cost : 0.015315818151045484
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151045484
# Converged in iteration 1 with cost 0.015315818151045484 because of step counter
# Final cost : 0.015315818151045484
# -----------------------------------------------
# 1 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.09323390044207755
# Converged in iteration 182 with cost 0.02181897771751415 because of vanishing difference
# Final cost : 0.02181897771751415
# Compute control for a deterministic system
# Cost in iteration 0: 0.02181897771751415
# Cost in iteration 200: 0.021818810385119656
# Final cost : 0.021818810385119656
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818810385119656
# Converged in iteration 79 with cost 0.021818810079079706 because of step counter
# Final cost : 0.021818810079079706
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818810079079706
# Converged in iteration 4 with cost 0.021818810079078464 because of step counter
# Final cost : 0.021818810079078464
# Compute control for a deterministic system
# Cost in iteration 0: 0.06987300818865919
# Cost in iteration 200: 0.027393263047761147
# Final cost : 0.027393263047761147
# Compute control for a deterministic system
# Cost in iteration 0: 0.027393263047761147
# Cost in iteration 200: 0.027393002806478314
# Final cost : 0.027393002806478314
# Compute control for a deterministic system
# Cost in iteration 0: 0.027393002806478314
# Cost in iteration 200: 0.027393000614305232
# Cost in iteration 400: 0.027393000581598416
# Final cost : 0.027393000581598416
# Compute control for a deterministic system
# Cost in iteration 0: 0.027393000581598416
# Converged in iteration 73 with cost 0.02739300057019105 because of step counter
# Final cost : 0.02739300057019105
# Compute control for a deterministic system
# Cost in iteration 0: 0.10137186816700275
# Cost in iteration 200: 0.033112399712169734
# Final cost : 0.033112399712169734
# Compute control for a deterministic system
# Cost in iteration 0: 0.033112399712169734
# Converged in iteration 8 with cost 0.03311157309352443 because of vanishing difference
# Final cost : 0.03311157309352443
# Compute control for a deterministic system
# Cost in iteration 0: 0.03311157309352443
# Cost in iteration 200: 0.03310657039785998
# Cost in iteration 400: 0.03310642047646304
# Final cost : 0.03310642047646304
# Compute control for a deterministic system
# Cost in iteration 0: 0.03310642047646304
# Cost in iteration 200: 0.03310641520685009
# Cost in iteration 400: 0.033106415172400844
# Converged in iteration 430 with cost 0.0331064151722728 because of vanishing difference
# Final cost : 0.0331064151722728
# Compute control for a deterministic system
# Cost in iteration 0: 0.0714646365612541
# Cost in iteration 200: 0.03896267945181751
# Final cost : 0.03896267945181751
# Compute control for a deterministic system
# Cost in iteration 0: 0.03896267945181751
# Cost in iteration 200: 0.038957659965696216
# Final cost : 0.038957659965696216
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957659965696216
# Cost in iteration 200: 0.03895743780914812
# Cost in iteration 400: 0.038957423771174116
# Final cost : 0.038957423771174116
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957423771174116
# Cost in iteration 200: 0.03895742279751057
# Cost in iteration 400: 0.038957422788133245
# Converged in iteration 420 with cost 0.038957422788096045 because of step counter
# Final cost : 0.038957422788096045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0841877786896198
# Converged in iteration 166 with cost 0.04494983913907187 because of vanishing difference
# Final cost : 0.04494983913907187
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494983913907187
# Cost in iteration 200: 0.04494378926304462
# Final cost : 0.04494378926304462
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494378926304462
# Cost in iteration 200: 0.0449433991220523
# Cost in iteration 400: 0.04494335937949964
# Final cost : 0.04494335937949964
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494335937949964
# Cost in iteration 200: 0.04494335487733236
# Cost in iteration 400: 0.044943354799642725
# Converged in iteration 524 with cost 0.044943354798328825 because of step counter
# Final cost : 0.044943354798328825
# Compute control for a deterministic system
# Cost in iteration 0: 0.12325803174571545
# Cost in iteration 200: 0.052316331540972864
# Final cost : 0.052316331540972864
# Compute control for a deterministic system
# Cost in iteration 0: 0.052316331540972864
# Cost in iteration 200: 0.052300644273621605
# Final cost : 0.052300644273621605
# Compute control for a deterministic system
# Cost in iteration 0: 0.052300644273621605
# Cost in iteration 200: 0.05229897479340994
# Cost in iteration 400: 0.052298722012699396
# Final cost : 0.052298722012699396
# Compute control for a deterministic system
# Cost in iteration 0: 0.052298722012699396
# Cost in iteration 200: 0.052298675932538764
# Cost in iteration 400: 0.05229867528873824
# Converged in iteration 600 with cost 0.05229867528089743 because of step counter
# Final cost : 0.05229867528089743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0811680191930472
# Cost in iteration 200: 0.058591676546007575
# Final cost : 0.058591676546007575
# Compute control for a deterministic system
# Cost in iteration 0: 0.058591676546007575
# Cost in iteration 200: 0.05857110096399248
# Final cost : 0.05857110096399248
# Compute control for a deterministic system
# Cost in iteration 0: 0.05857110096399248
# Cost in iteration 200: 0.05856825082495731
# Cost in iteration 400: 0.05856769813250796
# Final cost : 0.05856769813250796
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856769813250796
# Cost in iteration 200: 0.058567561481951164
# Cost in iteration 400: 0.05856755771946082
# Cost in iteration 600: 0.058567557635004874
# Converged in iteration 775 with cost 0.05856755763297385 because of step counter
# Final cost : 0.05856755763297385
# Compute control for a deterministic system
# Cost in iteration 0: 0.17573459217856413
# Cost in iteration 200: 0.06502497649115256
# Final cost : 0.06502497649115256
# Compute control for a deterministic system
# Cost in iteration 0: 0.06502497649115256
# Converged in iteration 22 with cost 0.06501515769270559 because of vanishing difference
# Final cost : 0.06501515769270559
# Compute control for a deterministic system
# Cost in iteration 0: 0.06501515769270559
# Cost in iteration 200: 0.06497161643008993
# Cost in iteration 400: 0.06496299155296335
# Final cost : 0.06496299155296335
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496299155296335
# Cost in iteration 200: 0.06496035848253921
# Cost in iteration 400: 0.06496031750880861
# Cost in iteration 600: 0.06496031646680113
# Cost in iteration 800: 0.06496031644164985
# Converged in iteration 859 with cost 0.06496031644120252 because of step counter
# Final cost : 0.06496031644120252
# Compute control for a deterministic system
# Cost in iteration 0: 0.12204918941348378
# Cost in iteration 200: 0.07154694680174381
# Final cost : 0.07154694680174381
# Compute control for a deterministic system
# Cost in iteration 0: 0.07154694680174381
# Converged in iteration 112 with cost 0.07149561357009966 because of vanishing difference
# Final cost : 0.07149561357009966
# Compute control for a deterministic system
# Cost in iteration 0: 0.07149561357009966
# Cost in iteration 200: 0.07147504971171104
# Cost in iteration 400: 0.07146961153137753
# Final cost : 0.07146961153137753
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146961153137753
# Cost in iteration 200: 0.07146743342912637
# Cost in iteration 400: 0.07146739547329177
# Cost in iteration 600: 0.07146739429055972
# Cost in iteration 800: 0.07146739426012752
# Converged in iteration 857 with cost 0.07146739425963043 because of vanishing difference
# Final cost : 0.07146739425963043
# Compute control for a deterministic system
# Cost in iteration 0: 0.12369102332730937
# Cost in iteration 200: 0.0781701752092573
# Final cost : 0.0781701752092573
# Compute control for a deterministic system
# Cost in iteration 0: 0.0781701752092573
# Converged in iteration 95 with cost 0.07811933001373593 because of vanishing difference
# Final cost : 0.07811933001373593
# Compute control for a deterministic system
# Cost in iteration 0: 0.07811933001373593
# Cost in iteration 200: 0.0780918275414875
# Cost in iteration 400: 0.07808360583139284
# ...
# Cost in iteration 0: 0.08996612363724933
# Cost in iteration 200: 0.08995905757080074
# Final cost : 0.08995905757080074
# Compute control for a deterministic system
# Cost in iteration 0: 0.08995905757080074
# Cost in iteration 200: 0.08995413186424325
# Cost in iteration 400: 0.08994933265933648
# Final cost : 0.08994933265933648
# Compute control for a deterministic system
# Cost in iteration 0: 0.08994933265933648
# Cost in iteration 200: 0.08994501617405253
# Cost in iteration 400: 0.08994078507831942
# Cost in iteration 600: 0.08993663391258122
# Cost in iteration 800: 0.08993256510534818
# Cost in iteration 1000: 0.0899285878856078
# Final cost : 0.0899285878856078
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.1175229267779019
# Cost in iteration 200: 0.0931362830310592
# Final cost : 0.0931362830310592
# Compute control for a deterministic system
# Cost in iteration 0: 0.0931362830310592
# Cost in iteration 200: 0.09312529595807507
# Final cost : 0.09312529595807507
# Compute control for a deterministic system
# Cost in iteration 0: 0.09312529595807507
# Cost in iteration 200: 0.09310820511965702
# Final cost : 0.09310820511965702
# Compute control for a deterministic system
# Cost in iteration 0: 0.09310820511965702
# Cost in iteration 200: 0.09309852989065236
# Cost in iteration 400: 0.09308917076268697
# Final cost : 0.09308917076268697
# Compute control for a deterministic system
# Cost in iteration 0: 0.09308917076268697
# Cost in iteration 200: 0.09308083847545678
# Cost in iteration 400: 0.09307271041038015
# Cost in iteration 600: 0.09306475421134774
# Cost in iteration 800: 0.09305695341679059
# Cost in iteration 1000: 0.09304931879910713
# Final cost : 0.09304931879910713
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.09767465146347162
# Cost in iteration 200: 0.09300058915958147
# Final cost : 0.09300058915958147
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300058915958147
# Cost in iteration 200: 0.09300058774158142
# Final cost : 0.09300058774158142
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300058774158142
# Cost in iteration 200: 0.09300058754227308
# Final cost : 0.09300058754227308
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300058754227308
# Cost in iteration 200: 0.09300058750262173
# Cost in iteration 400: 0.09300058748706948
# Final cost : 0.09300058748706948
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300058748706948
# Converged in iteration 94 with cost 0.09300058748362892 because of vanishing difference
# Final cost : 0.09300058748362892
# Compute control for a deterministic system
# Cost in iteration 0: 0.08995375639471581
# Converged in iteration 77 with cost 0.08615385163034953 because of vanishing difference
# Final cost : 0.08615385163034953
# Compute control for a deterministic system
# Cost in iteration 0: 0.08615385163034953
# Cost in iteration 200: 0.08615372938373211
# Final cost : 0.08615372938373211
# Compute control for a deterministic system
# Cost in iteration 0: 0.08615372938373211
# Cost in iteration 200: 0.08615372937850785
# Final cost : 0.08615372937850785
# Compute control for a deterministic system
# Cost in iteration 0: 0.08615372937850785
# Cost in iteration 200: 0.08615372937714676
# Cost in iteration 400: 0.08615372937657648
# Final cost : 0.08615372937657648
# Compute control for a deterministic system
# Cost in iteration 0: 0.08615372937657648
# Converged in iteration 9 with cost 0.086153729376238 because of step counter
# Final cost : 0.086153729376238
# Compute control for a deterministic system
# Cost in iteration 0: 0.07960508357071246
# Cost in iteration 200: 0.07807950389804107
# Final cost : 0.07807950389804107
# Compute control for a deterministic system
# Cost in iteration 0: 0.07807950389804107
# Converged in iteration 184 with cost 0.07807950308020441 because of vanishing difference
# Final cost : 0.07807950308020441
# Compute control for a deterministic system
# Cost in iteration 0: 0.07807950308020441
# Converged in iteration 1 with cost 0.07807950308020441 because of step counter
# Final cost : 0.07807950308020441
# Compute control for a deterministic system
# Cost in iteration 0: 0.07807950308020441
# Converged in iteration 2 with cost 0.07807950308020342 because of step counter
# Final cost : 0.07807950308020342
# Compute control for a deterministic system
# Cost in iteration 0: 0.07807950308020342
# Converged in iteration 1 with cost 0.07807950308020342 because of step counter
# Final cost : 0.07807950308020342
# Compute control for a deterministic system
# Cost in iteration 0: 0.08229082178567457
# Cost in iteration 200: 0.07146739740263446
# Final cost : 0.07146739740263446
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146739740263446
# Cost in iteration 200: 0.07146737148928671
# Final cost : 0.07146737148928671
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146737148928671
# Cost in iteration 200: 0.07146737145002892
# Final cost : 0.07146737145002892
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146737145002892
# Cost in iteration 200: 0.07146737143981335
# Cost in iteration 400: 0.07146737143678825
# Final cost : 0.07146737143678825
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146737143678825
# Converged in iteration 34 with cost 0.07146737143617589 because of vanishing difference
# Final cost : 0.07146737143617589
# Compute control for a deterministic system
# Cost in iteration 0: 0.08106286492051856
# Cost in iteration 200: 0.06496033462759622
# Final cost : 0.06496033462759622
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496033462759622
# Cost in iteration 200: 0.06496030119002534
# Final cost : 0.06496030119002534
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496030119002534
# Cost in iteration 200: 0.06496030079819676
# Final cost : 0.06496030079819676
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496030079819676
# Cost in iteration 200: 0.06496030072568032
# Cost in iteration 400: 0.06496030070734857
# Final cost : 0.06496030070734857
# Compute control for a deterministic system
# Cost in iteration 0: 0.06496030070734857
# Converged in iteration 184 with cost 0.06496030070115018 because of step counter
# Final cost : 0.06496030070115018
# Compute control for a deterministic system
# Cost in iteration 0: 0.05950891022925431
# Converged in iteration 88 with cost 0.05856755415888334 because of vanishing difference
# Final cost : 0.05856755415888334
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856755415888334
# Cost in iteration 200: 0.058567544028342126
# Final cost : 0.058567544028342126
# Compute control for a deterministic system
# Cost in iteration 0: 0.058567544028342126
# Converged in iteration 163 with cost 0.05856754402750326 because of step counter
# Final cost : 0.05856754402750326
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856754402750326
# Converged in iteration 1 with cost 0.05856754402750326 because of step counter
# Final cost : 0.05856754402750326
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856754402750326
# Converged in iteration 1 with cost 0.05856754402750326 because of step counter
# Final cost : 0.05856754402750326
# Compute control for a deterministic system
# Cost in iteration 0: 0.054767940811830285
# Converged in iteration 101 with cost 0.05229866813967562 because of vanishing difference
# Final cost : 0.05229866813967562
# Compute control for a deterministic system
# Cost in iteration 0: 0.05229866813967562
# Cost in iteration 200: 0.05229866038349964
# Final cost : 0.05229866038349964
# Compute control for a deterministic system
# Cost in iteration 0: 0.05229866038349964
# Cost in iteration 200: 0.052298660380222343
# Final cost : 0.052298660380222343
# Compute control for a deterministic system
# Cost in iteration 0: 0.052298660380222343
# Converged in iteration 86 with cost 0.052298660379908324 because of step counter
# Final cost : 0.052298660379908324
# Compute control for a deterministic system
# Cost in iteration 0: 0.052298660379908324
# Converged in iteration 1 with cost 0.052298660379908324 because of step counter
# Final cost : 0.052298660379908324
# Compute control for a deterministic system
# Cost in iteration 0: 0.04612807642108493
# Cost in iteration 200: 0.04494335222080783
# Final cost : 0.04494335222080783
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494335222080783
# Cost in iteration 200: 0.044943351826603264
# Final cost : 0.044943351826603264
# Compute control for a deterministic system
# Cost in iteration 0: 0.044943351826603264
# Cost in iteration 200: 0.044943351822369804
# Final cost : 0.044943351822369804
# Compute control for a deterministic system
# Cost in iteration 0: 0.044943351822369804
# Converged in iteration 50 with cost 0.04494335182222676 because of step counter
# Final cost : 0.04494335182222676
# Compute control for a deterministic system
# Cost in iteration 0: 0.04494335182222676
# Converged in iteration 6 with cost 0.04494335182220296 because of vanishing difference
# Final cost : 0.04494335182220296
# Compute control for a deterministic system
# Cost in iteration 0: 0.039550756682979187
# Cost in iteration 200: 0.038957419670304125
# Final cost : 0.038957419670304125
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957419670304125
# Cost in iteration 200: 0.038957419349623365
# Final cost : 0.038957419349623365
# Compute control for a deterministic system
# Cost in iteration 0: 0.038957419349623365
# Cost in iteration 200: 0.03895741934645756
# Final cost : 0.03895741934645756
# Compute control for a deterministic system
# Cost in iteration 0: 0.03895741934645756
# Converged in iteration 41 with cost 0.03895741934631642 because of step counter
# Final cost : 0.03895741934631642
# Compute control for a deterministic system
# Cost in iteration 0: 0.03895741934631642
# Converged in iteration 1 with cost 0.03895741934631642 because of step counter
# Final cost : 0.03895741934631642
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.03342286366753963
# Cost in iteration 200: 0.03310638740674337
# Final cost : 0.03310638740674337
# Compute control for a deterministic system
# Cost in iteration 0: 0.03310638740674337
# Cost in iteration 200: 0.033106382006969796
# Final cost : 0.033106382006969796
# Compute control for a deterministic system
# Cost in iteration 0: 0.033106382006969796
# Converged in iteration 1 with cost 0.033106382006969796 because of step counter
# Final cost : 0.033106382006969796
# Compute control for a deterministic system
# Cost in iteration 0: 0.033106382006969796
# Converged in iteration 1 with cost 0.033106382006969796 because of step counter
# Final cost : 0.033106382006969796
# Compute control for a deterministic system
# Cost in iteration 0: 0.033106382006969796
# Converged in iteration 19 with cost 0.033106382006941416 because of step counter
# Final cost : 0.033106382006941416
# Compute control for a deterministic system
# Cost in iteration 0: 0.02754027095883668
# Cost in iteration 200: 0.02739299526074983
# Final cost : 0.02739299526074983
# Compute control for a deterministic system
# Cost in iteration 0: 0.02739299526074983
# Converged in iteration 138 with cost 0.027392995258601834 because of step counter
# Final cost : 0.027392995258601834
# Compute control for a deterministic system
# Cost in iteration 0: 0.027392995258601834
# Converged in iteration 2 with cost 0.02739299525860099 because of step counter
# Final cost : 0.02739299525860099
# Compute control for a deterministic system
# Cost in iteration 0: 0.02739299525860099
# Converged in iteration 1 with cost 0.02739299525860099 because of step counter
# Final cost : 0.02739299525860099
# Compute control for a deterministic system
# Cost in iteration 0: 0.02739299525860099
# Converged in iteration 1 with cost 0.02739299525860099 because of step counter
# Final cost : 0.02739299525860099
# Compute control for a deterministic system
# Cost in iteration 0: 0.022698458356294138
# Cost in iteration 200: 0.02181880886110504
# Final cost : 0.02181880886110504
# Compute control for a deterministic system
# Cost in iteration 0: 0.02181880886110504
# Converged in iteration 150 with cost 0.021818808855246254 because of step counter
# Final cost : 0.021818808855246254
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818808855246254
# Converged in iteration 1 with cost 0.021818808855246254 because of step counter
# Final cost : 0.021818808855246254
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818808855246254
# Converged in iteration 2 with cost 0.021818808855245456 because of step counter
# Final cost : 0.021818808855245456
# Compute control for a deterministic system
# Cost in iteration 0: 0.021818808855245456
# Converged in iteration 1 with cost 0.021818808855245456 because of step counter
# Final cost : 0.021818808855245456
# Compute control for a deterministic system
# Cost in iteration 0: 0.015370693817650823
# Converged in iteration 183 with cost 0.015315818151051418 because of step counter
# Final cost : 0.015315818151051418
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151051418
# Converged in iteration 2 with cost 0.015315818151051324 because of step counter
# Final cost : 0.015315818151051324
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151051324
# Converged in iteration 5 with cost 0.015315818151048755 because of step counter
# Final cost : 0.015315818151048755
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151048755
# Converged in iteration 1 with cost 0.015315818151048755 because of step counter
# Final cost : 0.015315818151048755
# Compute control for a deterministic system
# Cost in iteration 0: 0.015315818151048755
# Converged in iteration 1 with cost 0.015315818151048755 because of step counter
# Final cost : 0.015315818151048755
# Compute control for a deterministic system
# Cost in iteration 0: 0.010247037926721325
# Converged in iteration 136 with cost 0.010056562467741755 because of step counter
# Final cost : 0.010056562467741755
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467741755
# Converged in iteration 3 with cost 0.010056562467739895 because of step counter
# Final cost : 0.010056562467739895
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467739895
# Converged in iteration 2 with cost 0.010056562467739562 because of step counter
# Final cost : 0.010056562467739562
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467739562
# Converged in iteration 1 with cost 0.010056562467739562 because of step counter
# Final cost : 0.010056562467739562
# Compute control for a deterministic system
# Cost in iteration 0: 0.010056562467739562
# Converged in iteration 1 with cost 0.010056562467739562 because of step counter
# Final cost : 0.010056562467739562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050829650563891954
# Converged in iteration 66 with cost 0.004957412463714836 because of step counter
# Final cost : 0.004957412463714836
# Compute control for a deterministic system
# Cost in iteration 0: 0.004957412463714836
# Converged in iteration 1 with cost 0.004957412463714836 because of step counter
# Final cost : 0.004957412463714836
# Compute control for a deterministic system
# Cost in iteration 0: 0.004957412463714836
# Converged in iteration 1 with cost 0.004957412463714836 because of step counter
# Final cost : 0.004957412463714836
# Compute control for a deterministic system
# Cost in iteration 0: 0.004957412463714836
# Converged in iteration 1 with cost 0.004957412463714836 because of step counter
# Final cost : 0.004957412463714836
# Compute control for a deterministic system
# Cost in iteration 0: 0.004957412463714836
# Converged in iteration 2 with cost 0.004957412463713425 because of step counter
# Final cost : 0.004957412463713425
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
