# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,72], wc.inh[0,72]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 13.906060606060606
# minima =  [  54  193  332  471  610  749  888 1027 1166 1305 1444 1583 1722 1861
#  2000 2139 2279 2418 2557 2696 2835 2974 3113 3252 3391 3530 3669 3808
#  3947 4086 4225 4364 4503 4643 4782 4921]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("s1_l2_otherparams.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("s1_l2_otherparams.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l2_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l2_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.024606133097083836
# Final cost : 0.010829188165190403
# Compute control for a deterministic system
# Cost in iteration 0: 0.010829188165190403
# Converged in iteration 12 with cost 0.010829175911793835 because of vanishing difference
# Final cost : 0.010829175911793835
# Compute control for a deterministic system
# Cost in iteration 0: 0.010829175911793835
# Converged in iteration 10 with cost 0.010829175830346142 because of step counter
# Final cost : 0.010829175830346142
# Compute control for a deterministic system
# Cost in iteration 0: 0.010829175830346142
# Converged in iteration 1 with cost 0.010829175830346142 because of step counter
# Final cost : 0.010829175830346142
# Compute control for a deterministic system
# Cost in iteration 0: 0.010829175830346142
# Converged in iteration 1 with cost 0.010829175830346142 because of step counter
# Final cost : 0.010829175830346142
# Compute control for a deterministic system
# Cost in iteration 0: 0.13189103097022428
# Final cost : 0.028026340672587823
# Compute control for a deterministic system
# Cost in iteration 0: 0.028026340672587823
# Converged in iteration 76 with cost 0.02730671653591188 because of vanishing difference
# Final cost : 0.02730671653591188
# Compute control for a deterministic system
# Cost in iteration 0: 0.02730671653591188
# Converged in iteration 20 with cost 0.027306716487868282 because of step counter
# Final cost : 0.027306716487868282
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306716487868282
# Converged in iteration 1 with cost 0.027306716487868282 because of step counter
# Final cost : 0.027306716487868282
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306716487868282
# Converged in iteration 1 with cost 0.027306716487868282 because of step counter
# Final cost : 0.027306716487868282
# Compute control for a deterministic system
# Cost in iteration 0: 0.26397830408578044
# Final cost : 0.04101902014336291
# Compute control for a deterministic system
# Cost in iteration 0: 0.04101902014336291
# Converged in iteration 99 with cost 0.03957806871297639 because of vanishing difference
# Final cost : 0.03957806871297639
# Compute control for a deterministic system
# Cost in iteration 0: 0.03957806871297639
# Converged in iteration 34 with cost 0.039578068046849456 because of step counter
# Final cost : 0.039578068046849456
# Compute control for a deterministic system
# Cost in iteration 0: 0.039578068046849456
# Converged in iteration 2 with cost 0.03957806804684938 because of step counter
# Final cost : 0.03957806804684938
# Compute control for a deterministic system
# Cost in iteration 0: 0.03957806804684938
# Converged in iteration 1 with cost 0.03957806804684938 because of step counter
# Final cost : 0.03957806804684938
# Compute control for a deterministic system
# Cost in iteration 0: 0.49949585032886373
# Final cost : 0.05821931161404136
# Compute control for a deterministic system
# Cost in iteration 0: 0.05821931161404136
# Converged in iteration 148 with cost 0.05576718840672347 because of vanishing difference
# Final cost : 0.05576718840672347
# Compute control for a deterministic system
# Cost in iteration 0: 0.05576718840672347
# Converged in iteration 64 with cost 0.0557671867027253 because of step counter
# Final cost : 0.0557671867027253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0557671867027253
# Converged in iteration 1 with cost 0.0557671867027253 because of step counter
# Final cost : 0.0557671867027253
# Compute control for a deterministic system
# Cost in iteration 0: 0.0557671867027253
# Converged in iteration 1 with cost 0.0557671867027253 because of step counter
# Final cost : 0.0557671867027253
# Compute control for a deterministic system
# Cost in iteration 0: 0.7129152971247614
# Final cost : 0.07103095422648319
# Compute control for a deterministic system
# Cost in iteration 0: 0.07103095422648319
# Converged in iteration 182 with cost 0.0677561220013701 because of vanishing difference
# Final cost : 0.0677561220013701
# Compute control for a deterministic system
# Cost in iteration 0: 0.0677561220013701
# Converged in iteration 79 with cost 0.06775611996312846 because of step counter
# Final cost : 0.06775611996312846
# Compute control for a deterministic system
# Cost in iteration 0: 0.06775611996312846
# Converged in iteration 1 with cost 0.06775611996312846 because of step counter
# Final cost : 0.06775611996312846
# Compute control for a deterministic system
# Cost in iteration 0: 0.06775611996312846
# Converged in iteration 1 with cost 0.06775611996312846 because of step counter
# Final cost : 0.06775611996312846
# Compute control for a deterministic system
# Cost in iteration 0: 1.0342637552034966
# Final cost : 0.08806476056928177
# Compute control for a deterministic system
# Cost in iteration 0: 0.08806476056928177
# Converged in iteration 199 with cost 0.08351578381206766 because of vanishing difference
# Final cost : 0.08351578381206766
# Compute control for a deterministic system
# Cost in iteration 0: 0.08351578381206766
# Converged in iteration 187 with cost 0.08351565561152031 because of step counter
# Final cost : 0.08351565561152031
# Compute control for a deterministic system
# Cost in iteration 0: 0.08351565561152031
# Converged in iteration 2 with cost 0.08351565561151997 because of step counter
# Final cost : 0.08351565561151997
# Compute control for a deterministic system
# Cost in iteration 0: 0.08351565561151997
# Converged in iteration 1 with cost 0.08351565561151997 because of step counter
# Final cost : 0.08351565561151997
# Compute control for a deterministic system
# Cost in iteration 0: 1.294323126007163
# Final cost : 0.10088724458328552
# Compute control for a deterministic system
# Cost in iteration 0: 0.10088724458328552
# Cost in iteration 200: 0.0951566200499435
# Final cost : 0.0951566200499435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0951566200499435
# Converged in iteration 4 with cost 0.09515653465748115 because of vanishing difference
# Final cost : 0.09515653465748115
# Compute control for a deterministic system
# Cost in iteration 0: 0.09515653465748115
# Cost in iteration 200: 0.09515633015522833
# Converged in iteration 281 with cost 0.09515633015341567 because of step counter
# Final cost : 0.09515633015341567
# Compute control for a deterministic system
# Cost in iteration 0: 0.09515633015341567
# Converged in iteration 10 with cost 0.09515633015339851 because of step counter
# Final cost : 0.09515633015339851
# Compute control for a deterministic system
# Cost in iteration 0: 1.654080380594206
# Final cost : 0.11820289183106199
# Compute control for a deterministic system
# Cost in iteration 0: 0.11820289183106199
# Cost in iteration 200: 0.1104307902942341
# Final cost : 0.1104307902942341
# Compute control for a deterministic system
# Cost in iteration 0: 0.1104307902942341
# Converged in iteration 16 with cost 0.11042978206103914 because of vanishing difference
# Final cost : 0.11042978206103914
# Compute control for a deterministic system
# Cost in iteration 0: 0.11042978206103914
# Cost in iteration 200: 0.11042847860951706
# Cost in iteration 400: 0.11042847826150194
# Final cost : 0.11042847826150194
# Compute control for a deterministic system
# Cost in iteration 0: 0.11042847826150194
# Converged in iteration 15 with cost 0.11042847826142307 because of vanishing difference
# Final cost : 0.11042847826142307
# Compute control for a deterministic system
# Cost in iteration 0: 1.9256669276533431
# Final cost : 0.13147399228299467
# Compute control for a deterministic system
# Cost in iteration 0: 0.13147399228299467
# Cost in iteration 200: 0.1216974721409209
# Final cost : 0.1216974721409209
# Compute control for a deterministic system
# Cost in iteration 0: 0.1216974721409209
# Cost in iteration 200: 0.12168992245586037
# Final cost : 0.12168992245586037
# Compute control for a deterministic system
# Cost in iteration 0: 0.12168992245586037
# Cost in iteration 200: 0.12168991609358995
# Cost in iteration 400: 0.12168991608395455
# Final cost : 0.12168991608395455
# Compute control for a deterministic system
# Cost in iteration 0: 0.12168991608395455
# Converged in iteration 5 with cost 0.12168991608395174 because of step counter
# Final cost : 0.12168991608395174
# Compute control for a deterministic system
# Cost in iteration 0: 2.279588234839666
# Final cost : 0.14973281265704702
# Compute control for a deterministic system
# Cost in iteration 0: 0.14973281265704702
# Cost in iteration 200: 0.13646511749648726
# Final cost : 0.13646511749648726
# Compute control for a deterministic system
# Cost in iteration 0: 0.13646511749648726
# Cost in iteration 200: 0.136436998488041
# Final cost : 0.136436998488041
# Compute control for a deterministic system
# Cost in iteration 0: 0.136436998488041
# Cost in iteration 200: 0.1364368034355556
# Cost in iteration 400: 0.13643680172909528
# Final cost : 0.13643680172909528
# Compute control for a deterministic system
# Cost in iteration 0: 0.13643680172909528
# Converged in iteration 121 with cost 0.13643680171414677 because of vanishing difference
# Final cost : 0.13643680171414677
# Compute control for a deterministic system
# Cost in iteration 0: 2.532587218603636
# Final cost : 0.1639725856377107
# Compute control for a deterministic system
# Cost in iteration 0: 0.1639725856377107
# Cost in iteration 200: 0.14734647847266305
# Final cost : 0.14734647847266305
# Compute control for a deterministic system
# Cost in iteration 0: 0.14734647847266305
# Converged in iteration 151 with cost 0.14728544617270095 because of vanishing difference
# Final cost : 0.14728544617270095
# Compute control for a deterministic system
# Cost in iteration 0: 0.14728544617270095
# Cost in iteration 200: 0.14728215135336398
# Cost in iteration 400: 0.14728207947596486
# Final cost : 0.14728207947596486
# Compute control for a deterministic system
# Cost in iteration 0: 0.14728207947596486
# Cost in iteration 200: 0.14728207782652084
# Converged in iteration 336 with cost 0.1472820778211448 because of vanishing difference
# Final cost : 0.1472820778211448
# Compute control for a deterministic system
# Cost in iteration 0: 2.845225729537918
# Final cost : 0.18383656893946082
# Compute control for a deterministic system
# Cost in iteration 0: 0.18383656893946082
# Cost in iteration 200: 0.1616314238449659
# Final cost : 0.1616314238449659
# Compute control for a deterministic system
# Cost in iteration 0: 0.1616314238449659
# Cost in iteration 200: 0.16142604032796082
# Final cost : 0.16142604032796082
# Compute control for a deterministic system
# Cost in iteration 0: 0.16142604032796082
# Cost in iteration 200: 0.16141893881886935
# Cost in iteration 400: 0.16141854265695113
# Final cost : 0.16141854265695113
# Compute control for a deterministic system
# Cost in iteration 0: 0.16141854265695113
# Cost in iteration 200: 0.16141851473710578
# Cost in iteration 400: 0.16141851435951787
# Converged in iteration 508 with cost 0.16141851435394672 because of vanishing difference
# Final cost : 0.16141851435394672
# Compute control for a deterministic system
# Cost in iteration 0: 3.0563504114160627
# Final cost : 0.19946029452893282
# Compute control for a deterministic system
# Cost in iteration 0: 0.19946029452893282
# Cost in iteration 200: 0.17209061342793522
# Final cost : 0.17209061342793522
# Compute control for a deterministic system
# Cost in iteration 0: 0.17209061342793522
# Cost in iteration 200: 0.17176168015461457
# Final cost : 0.17176168015461457
# Compute control for a deterministic system
# Cost in iteration 0: 0.17176168015461457
# Cost in iteration 200: 0.17174029615983555
# Converged in iteration 294 with cost 0.17174029056628362 because of vanishing difference
# Final cost : 0.17174029056628362
# Compute control for a deterministic system
# Cost in iteration 0: 0.17174029056628362
# Converged in iteration 23 with cost 0.17174029056617512 because of vanishing difference
# Final cost : 0.17174029056617512
# Compute control for a deterministic system
# Cost in iteration 0: 3.301088631712384
# Final cost : 0.22134803344002613
# Compute control for a deterministic system
# Cost in iteration 0: 0.22134803344002613
# Cost in iteration 200: 0.18581260855244422
# Final cost : 0.18581260855244422
# Compute control for a deterministic system
# Cost in iteration 0: 0.18581260855244422
# Cost in iteration 200: 0.18516097386872324
# Final cost : 0.18516097386872324
# Compute control for a deterministic system
# Cost in iteration 0: 0.18516097386872324
# Converged in iteration 63 with cost 0.18510501266537382 because of vanishing difference
# Final cost : 0.18510501266537382
# Compute control for a deterministic system
# Cost in iteration 0: 0.18510501266537382
# Cost in iteration 200: 0.18509004327552864
# Cost in iteration 400: 0.18508866755959835
# Cost in iteration 600: 0.1850885403436873
# Cost in iteration 800: 0.18508852843686535
# Cost in iteration 1000: 0.18508852728378813
# Final cost : 0.18508852728378813
# Compute control for a deterministic system
# Cost in iteration 0: 3.4545361862200203
# Final cost : 0.23868435867608753
# Compute control for a deterministic system
# Cost in iteration 0: 0.23868435867608753
# Cost in iteration 200: 0.19596844535648913
# Final cost : 0.19596844535648913
# Compute control for a deterministic system
# Cost in iteration 0: 0.19596844535648913
# Cost in iteration 200: 0.1949545834685558
# Final cost : 0.1949545834685558
# Compute control for a deterministic system
# Cost in iteration 0: 0.1949545834685558
# Converged in iteration 43 with cost 0.19485319908786217 because of vanishing difference
# Final cost : 0.19485319908786217
# Compute control for a deterministic system
# Cost in iteration 0: 0.19485319908786217
# Cost in iteration 200: 0.19480804458008957
# Cost in iteration 400: 0.19480156485500766
# Cost in iteration 600: 0.19480076020347603
# Cost in iteration 800: 0.1948006494670172
# Cost in iteration 1000: 0.19480063450375318
# Final cost : 0.19480063450375318
# Compute control for a deterministic system
# Cost in iteration 0: 3.6169715022997546
# Final cost : 0.2634025427880926
# Compute control for a deterministic system
# Cost in iteration 0: 0.2634025427880926
# Cost in iteration 200: 0.20925646266393133
# Final cost : 0.20925646266393133
# Compute control for a deterministic system
# Cost in iteration 0: 0.20925646266393133
# Cost in iteration 200: 0.20774040210718075
# Final cost : 0.20774040210718075
# Compute control for a deterministic system
# Cost in iteration 0: 0.20774040210718075
# Converged in iteration 130 with cost 0.2074514074026062 because of vanishing difference
# Final cost : 0.2074514074026062
# Compute control for a deterministic system
# Cost in iteration 0: 0.2074514074026062
# Cost in iteration 200: 0.20742365932938034
# Cost in iteration 400: 0.20741800221533518
# Cost in iteration 600: 0.20741679193169438
# Cost in iteration 800: 0.20741651451957113
# Cost in iteration 1000: 0.20741645177640636
# Final cost : 0.20741645177640636
# Compute control for a deterministic system
# Cost in iteration 0: 3.706713284005952
# Final cost : 0.2835653910041561
# Compute control for a deterministic system
# Cost in iteration 0: 0.2835653910041561
# Cost in iteration 200: 0.21932103248855342
# Final cost : 0.21932103248855342
# Compute control for a deterministic system
# Cost in iteration 0: 0.21932103248855342
# Cost in iteration 200: 0.21722207357805728
# Final cost : 0.21722207357805728
# Compute control for a deterministic system
# Cost in iteration 0: 0.21722207357805728
# Converged in iteration 94 with cost 0.2168383783755762 because of vanishing difference
# Final cost : 0.2168383783755762
# Compute control for a deterministic system
# Cost in iteration 0: 0.2168383783755762
# Cost in iteration 200: 0.21672195273734082
# Cost in iteration 400: 0.21669382801406387
# Cost in iteration 600: 0.21668634647583954
# Cost in iteration 800: 0.21668425713443348
# Cost in iteration 1000: 0.21668366739542938
# Final cost : 0.21668366739542938
# Compute control for a deterministic system
# Cost in iteration 0: 3.7839804227491096
# Final cost : 0.3136999340378472
# Compute control for a deterministic system
# Cost in iteration 0: 0.3136999340378472
# Cost in iteration 200: 0.23263586033494585
# Final cost : 0.23263586033494585
# Compute control for a deterministic system
# Cost in iteration 0: 0.23263586033494585
# Cost in iteration 200: 0.22983055494195054
# Final cost : 0.22983055494195054
# Compute control for a deterministic system
# Cost in iteration 0: 0.22983055494195054
# Converged in iteration 132 with cost 0.22908471703669278 because of vanishing difference
# Final cost : 0.22908471703669278
# Compute control for a deterministic system
# Cost in iteration 0: 0.22908471703669278
# Cost in iteration 200: 0.22893307670936974
# Cost in iteration 400: 0.22888137031646316
# Cost in iteration 600: 0.22886460587320837
# Cost in iteration 800: 0.22885848276605875
# Cost in iteration 1000: 0.22885618337240757
# Final cost : 0.22885618337240757
# Compute control for a deterministic system
# Cost in iteration 0: 3.811012863758817
# Final cost : 0.34048618814741494
# Compute control for a deterministic system
# Cost in iteration 0: 0.34048618814741494
# Cost in iteration 200: 0.243183614225137
# Final cost : 0.243183614225137
# Compute control for a deterministic system
# Cost in iteration 0: 0.243183614225137
# Cost in iteration 200: 0.2394964092117527
# Final cost : 0.2394964092117527
# Compute control for a deterministic system
# Cost in iteration 0: 0.2394964092117527
# Cost in iteration 200: 0.23815675439249412
# Converged in iteration 319 with cost 0.2379981532396605 because of vanishing difference
# Final cost : 0.2379981532396605
# Compute control for a deterministic system
# Cost in iteration 0: 0.2379981532396605
# Cost in iteration 200: 0.23793310120903532
# Cost in iteration 400: 0.23790619851869477
# Cost in iteration 600: 0.23789457405612574
# Cost in iteration 800: 0.23788944615044377
# Cost in iteration 1000: 0.23788719806399583
# Final cost : 0.23788719806399583
# Compute control for a deterministic system
# Cost in iteration 0: 3.8078182232287023
# Final cost : 0.4155601779112291
# Compute control for a deterministic system
# Cost in iteration 0: 0.4155601779112291
# Cost in iteration 200: 0.25730189570317197
# Final cost : 0.25730189570317197
# Compute control for a deterministic system
# Cost in iteration 0: 0.25730189570317197
# Cost in iteration 200: 0.2524250978088425
# Final cost : 0.2524250978088425
# Compute control for a deterministic system
# Cost in iteration 0: 0.2524250978088425
# Cost in iteration 200: 0.2505285654564252
# Converged in iteration 328 with cost 0.25013834945150965 because of vanishing difference
# Final cost : 0.25013834945150965
# Compute control for a deterministic system
# Cost in iteration 0: 0.25013834945150965
# Cost in iteration 200: 0.2499763076631285
# Cost in iteration 400: 0.2498984724957749
# Cost in iteration 600: 0.24985939272026347
# Cost in iteration 800: 0.2498396776588662
# Cost in iteration 1000: 0.24982953398229052
# Final cost : 0.24982953398229052
# Compute control for a deterministic system
# Cost in iteration 0: 3.7775421962164675
# Final cost : 0.4857684313244838
# Compute control for a deterministic system
# Cost in iteration 0: 0.4857684313244838
# Cost in iteration 200: 0.3370199052992936
# Final cost : 0.3370199052992936
# Compute control for a deterministic system
# Cost in iteration 0: 0.3370199052992936
# Cost in iteration 200: 0.3351585452810975
# Final cost : 0.3351585452810975
# Compute control for a deterministic system
# Cost in iteration 0: 0.3351585452810975
# Cost in iteration 200: 0.33351243098503636
# Cost in iteration 400: 0.33255235504987446
# Final cost : 0.33255235504987446
# Compute control for a deterministic system
# Cost in iteration 0: 0.33255235504987446
# Cost in iteration 200: 0.3321830917282718
# Cost in iteration 400: 0.33218300094578823
# Cost in iteration 600: 0.33218300056159766
# Converged in iteration 660 with cost 0.332183000560176 because of vanishing difference
# Final cost : 0.332183000560176
# Compute control for a deterministic system
# Cost in iteration 0: 3.7244317765464503
# Final cost : 0.43540873384857365
# Compute control for a deterministic system
# Cost in iteration 0: 0.43540873384857365
# Cost in iteration 200: 0.3193125681204971
# Final cost : 0.3193125681204971
# Compute control for a deterministic system
# Cost in iteration 0: 0.3193125681204971
# Cost in iteration 200: 0.31722394313799984
# Final cost : 0.31722394313799984
# Compute control for a deterministic system
# Cost in iteration 0: 0.31722394313799984
# Cost in iteration 200: 0.3158673204686939
# Cost in iteration 400: 0.3146576779500606
# Final cost : 0.3146576779500606
# Compute control for a deterministic system
# Cost in iteration 0: 0.3146576779500606
# Converged in iteration 95 with cost 0.31440472254129126 because of vanishing difference
# Final cost : 0.31440472254129126
# Compute control for a deterministic system
# Cost in iteration 0: 3.6190282472665682
# Final cost : 0.3805931512244632
# Compute control for a deterministic system
# Cost in iteration 0: 0.3805931512244632
# Cost in iteration 200: 0.2955444363637308
# Final cost : 0.2955444363637308
# Compute control for a deterministic system
# Cost in iteration 0: 0.2955444363637308
# Cost in iteration 200: 0.293185783695348
# Final cost : 0.293185783695348
# Compute control for a deterministic system
# Cost in iteration 0: 0.293185783695348
# Cost in iteration 200: 0.29150041153430956
# Cost in iteration 400: 0.29113685615579643
# Final cost : 0.29113685615579643
# Compute control for a deterministic system
# Cost in iteration 0: 0.29113685615579643
# Cost in iteration 200: 0.2911359611965388
# Cost in iteration 400: 0.2911359592016188
# Converged in iteration 534 with cost 0.29113595919829677 because of vanishing difference
# Final cost : 0.29113595919829677
# Compute control for a deterministic system
# Cost in iteration 0: 3.514498369990701
# Final cost : 0.345193652576847
# Compute control for a deterministic system
# Cost in iteration 0: 0.345193652576847
# Cost in iteration 200: 0.2783430963300911
# Final cost : 0.2783430963300911
# Compute control for a deterministic system
# Cost in iteration 0: 0.2783430963300911
# Cost in iteration 200: 0.2756051340140415
# Final cost : 0.2756051340140415
# Compute control for a deterministic system
# Cost in iteration 0: 0.2756051340140415
# Cost in iteration 200: 0.27401519343027136
# Converged in iteration 300 with cost 0.27400789604854925 because of vanishing difference
# Final cost : 0.27400789604854925
# Compute control for a deterministic system
# Cost in iteration 0: 0.27400789604854925
# Cost in iteration 200: 0.27400759621075005
# Cost in iteration 400: 0.27400759552766724
# Converged in iteration 455 with cost 0.27400759552648146 because of vanishing difference
# Final cost : 0.27400759552648146
# Compute control for a deterministic system
# Cost in iteration 0: 3.3418549172629124
# Final cost : 0.3036069707534186
# Compute control for a deterministic system
# Cost in iteration 0: 0.3036069707534186
# Cost in iteration 200: 0.2552505504732483
# Final cost : 0.2552505504732483
# Compute control for a deterministic system
# Cost in iteration 0: 0.2552505504732483
# Cost in iteration 200: 0.2522127579412751
# Final cost : 0.2522127579412751
# Compute control for a deterministic system
# Cost in iteration 0: 0.2522127579412751
# Cost in iteration 200: 0.2515680953856285
# Converged in iteration 265 with cost 0.25156773620526746 because of vanishing difference
# Final cost : 0.25156773620526746
# Compute control for a deterministic system
# Cost in iteration 0: 0.25156773620526746
# Cost in iteration 200: 0.25156762662314464
# Cost in iteration 400: 0.25156762655994164
# Converged in iteration 417 with cost 0.25156762655992454 because of step counter
# Final cost : 0.25156762655992454
# Compute control for a deterministic system
# Cost in iteration 0: 3.188029290351415
# Final cost : 0.27581891594427776
# Compute control for a deterministic system
# Cost in iteration 0: 0.27581891594427776
# Cost in iteration 200: 0.238146778204404
# Final cost : 0.238146778204404
# Compute control for a deterministic system
# Cost in iteration 0: 0.238146778204404
# Cost in iteration 200: 0.2350342088267202
# Final cost : 0.2350342088267202
# Compute control for a deterministic system
# Cost in iteration 0: 0.2350342088267202
# Converged in iteration 143 with cost 0.23502339503966244 because of vanishing difference
# Final cost : 0.23502339503966244
# Compute control for a deterministic system
# Cost in iteration 0: 0.23502339503966244
# Cost in iteration 200: 0.23502311190444936
# Cost in iteration 400: 0.23502311181632357
# Converged in iteration 408 with cost 0.23502311181631377 because of step counter
# Final cost : 0.23502311181631377
# Compute control for a deterministic system
# Cost in iteration 0: 2.9517258870468828
# Final cost : 0.24246115388797188
# Compute control for a deterministic system
# Cost in iteration 0: 0.24246115388797188
# Cost in iteration 200: 0.2161508311925297
# Final cost : 0.2161508311925297
# Compute control for a deterministic system
# Cost in iteration 0: 0.2161508311925297
# Cost in iteration 200: 0.21405391323040657
# Final cost : 0.21405391323040657
# Compute control for a deterministic system
# Cost in iteration 0: 0.21405391323040657
# Cost in iteration 200: 0.21333656228731773
# Converged in iteration 209 with cost 0.21333652363249014 because of vanishing difference
# Final cost : 0.21333652363249014
# Compute control for a deterministic system
# Cost in iteration 0: 0.21333652363249014
# Cost in iteration 200: 0.2133362928301704
# Converged in iteration 358 with cost 0.21333629280090038 because of step counter
# Final cost : 0.21333629280090038
# Compute control for a deterministic system
# Cost in iteration 0: 2.7523450213963887
# Final cost : 0.21976656026646674
# Compute control for a deterministic system
# Cost in iteration 0: 0.21976656026646674
# Cost in iteration 200: 0.19978318971588796
# Final cost : 0.19978318971588796
# Compute control for a deterministic system
# Cost in iteration 0: 0.19978318971588796
# Cost in iteration 200: 0.19764221992737493
# Final cost : 0.19764221992737493
# Compute control for a deterministic system
# Cost in iteration 0: 0.19764221992737493
# Converged in iteration 93 with cost 0.19734899382563162 because of vanishing difference
# Final cost : 0.19734899382563162
# Compute control for a deterministic system
# Cost in iteration 0: 0.19734899382563162
# Cost in iteration 200: 0.19734874549141795
# Converged in iteration 344 with cost 0.19734874547705086 because of step counter
# Final cost : 0.19734874547705086
# Compute control for a deterministic system
# Cost in iteration 0: 2.459668439157128
# Final cost : 0.19206768974690078
# Compute control for a deterministic system
# Cost in iteration 0: 0.19206768974690078
# Cost in iteration 200: 0.178409669648476
# Final cost : 0.178409669648476
# Compute control for a deterministic system
# Cost in iteration 0: 0.178409669648476
# Cost in iteration 200: 0.17640200811702772
# Final cost : 0.17640200811702772
# Compute control for a deterministic system
# Cost in iteration 0: 0.17640200811702772
# Converged in iteration 21 with cost 0.17640089175541204 because of vanishing difference
# Final cost : 0.17640089175541204
# Compute control for a deterministic system
# Cost in iteration 0: 0.17640089175541204
# Cost in iteration 200: 0.17640050946339927
# Converged in iteration 334 with cost 0.17640050945171387 because of step counter
# Final cost : 0.17640050945171387
# Compute control for a deterministic system
# Cost in iteration 0: 2.2226946244095087
# Final cost : 0.17290295883891588
# Compute control for a deterministic system
# Cost in iteration 0: 0.17290295883891588
# Cost in iteration 200: 0.16239103891446743
# Final cost : 0.16239103891446743
# Compute control for a deterministic system
# Cost in iteration 0: 0.16239103891446743
# Cost in iteration 200: 0.16096479222787605
# Final cost : 0.16096479222787605
# Compute control for a deterministic system
# Cost in iteration 0: 0.16096479222787605
# Converged in iteration 112 with cost 0.16096467649398163 because of step counter
# Final cost : 0.16096467649398163
# Compute control for a deterministic system
# Cost in iteration 0: 0.16096467649398163
# Converged in iteration 2 with cost 0.16096467649398122 because of step counter
# Final cost : 0.16096467649398122
# Compute control for a deterministic system
# Cost in iteration 0: 1.8889150792608895
# Final cost : 0.14910015908334068
# Compute control for a deterministic system
# Cost in iteration 0: 0.14910015908334068
# Cost in iteration 200: 0.14140291201021007
# Final cost : 0.14140291201021007
# Compute control for a deterministic system
# Cost in iteration 0: 0.14140291201021007
# Converged in iteration 143 with cost 0.1407492772129133 because of vanishing difference
# Final cost : 0.1407492772129133
# Compute control for a deterministic system
# Cost in iteration 0: 0.1407492772129133
# Converged in iteration 94 with cost 0.1407492602423102 because of step counter
# Final cost : 0.1407492602423102
# Compute control for a deterministic system
# Cost in iteration 0: 0.1407492602423102
# Converged in iteration 2 with cost 0.14074926024231005 because of step counter
# Final cost : 0.14074926024231005
# Compute control for a deterministic system
# Cost in iteration 0: 1.630239837850748
# Final cost : 0.13232383428184802
# Compute control for a deterministic system
# Cost in iteration 0: 0.13232383428184802
# Cost in iteration 200: 0.1258686625061316
# Final cost : 0.1258686625061316
# Compute control for a deterministic system
# Cost in iteration 0: 0.1258686625061316
# Converged in iteration 88 with cost 0.12586118422669404 because of vanishing difference
# Final cost : 0.12586118422669404
# Compute control for a deterministic system
# Cost in iteration 0: 0.12586118422669404
# Converged in iteration 86 with cost 0.12586115573168752 because of vanishing difference
# Final cost : 0.12586115573168752
# Compute control for a deterministic system
# Cost in iteration 0: 0.12586115573168752
# Converged in iteration 31 with cost 0.12586115573159237 because of step counter
# Final cost : 0.12586115573159237
# Compute control for a deterministic system
# Cost in iteration 0: 1.283645986710447
# Final cost : 0.11108313720991851
# Compute control for a deterministic system
# Cost in iteration 0: 0.11108313720991851
# Cost in iteration 200: 0.10637475671245555
# Final cost : 0.10637475671245555
# Compute control for a deterministic system
# Cost in iteration 0: 0.10637475671245555
# Converged in iteration 32 with cost 0.1063746324612525 because of vanishing difference
# Final cost : 0.1063746324612525
# Compute control for a deterministic system
# Cost in iteration 0: 0.1063746324612525
# Converged in iteration 81 with cost 0.10637461877069682 because of step counter
# Final cost : 0.10637461877069682
# Compute control for a deterministic system
# Cost in iteration 0: 0.10637461877069682
# Converged in iteration 1 with cost 0.10637461877069682 because of step counter
# Final cost : 0.10637461877069682
# Compute control for a deterministic system
# Cost in iteration 0: 1.0301883002751728
# Final cost : 0.09581535843773027
# Compute control for a deterministic system
# Cost in iteration 0: 0.09581535843773027
# Cost in iteration 200: 0.09203368727821316
# Final cost : 0.09203368727821316
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368727821316
# Converged in iteration 129 with cost 0.09203368078402532 because of vanishing difference
# Final cost : 0.09203368078402532
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368078402532
# Converged in iteration 5 with cost 0.09203368078401745 because of step counter
# Final cost : 0.09203368078401745
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368078401745
# Converged in iteration 1 with cost 0.09203368078401745 because of step counter
# Final cost : 0.09203368078401745
# Compute control for a deterministic system
# Cost in iteration 0: 0.7137494525822982
# Final cost : 0.07611509143223863
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611509143223863
# Converged in iteration 163 with cost 0.07328109939307743 because of vanishing difference
# Final cost : 0.07328109939307743
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328109939307743
# Converged in iteration 92 with cost 0.0732810983900577 because of step counter
# Final cost : 0.0732810983900577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0732810983900577
# Converged in iteration 1 with cost 0.0732810983900577 because of step counter
# Final cost : 0.0732810983900577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0732810983900577
# Converged in iteration 2 with cost 0.07328109839005734 because of step counter
# Final cost : 0.07328109839005734
# Compute control for a deterministic system
# Cost in iteration 0: 0.5018291854143839
# Final cost : 0.061713435672466246
# Compute control for a deterministic system
# Cost in iteration 0: 0.061713435672466246
# Converged in iteration 138 with cost 0.05949775998543625 because of vanishing difference
# Final cost : 0.05949775998543625
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775998543625
# Converged in iteration 85 with cost 0.05949775750868283 because of step counter
# Final cost : 0.05949775750868283
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775750868283
# Converged in iteration 2 with cost 0.05949775750868258 because of step counter
# Final cost : 0.05949775750868258
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775750868258
# Converged in iteration 1 with cost 0.05949775750868258 because of step counter
# Final cost : 0.05949775750868258
# Compute control for a deterministic system
# Cost in iteration 0: 0.2665807685532065
# Final cost : 0.04290413664586859
# Compute control for a deterministic system
# Cost in iteration 0: 0.04290413664586859
# Converged in iteration 159 with cost 0.04150697325472869 because of step counter
# Final cost : 0.04150697325472869
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150697325472869
# Converged in iteration 2 with cost 0.041506973254728574 because of step counter
# Final cost : 0.041506973254728574
# Compute control for a deterministic system
# Cost in iteration 0: 0.041506973254728574
# Converged in iteration 1 with cost 0.041506973254728574 because of vanishing difference
# Final cost : 0.041506973254728574
# Compute control for a deterministic system
# Cost in iteration 0: 0.041506973254728574
# Converged in iteration 1 with cost 0.041506973254728574 because of step counter
# Final cost : 0.041506973254728574
# Compute control for a deterministic system
# Cost in iteration 0: 0.1339885357152664
# Final cost : 0.029072881801930416
# Compute control for a deterministic system
# Cost in iteration 0: 0.029072881801930416
# Converged in iteration 78 with cost 0.028318676224011376 because of vanishing difference
# Final cost : 0.028318676224011376
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318676224011376
# Converged in iteration 77 with cost 0.028318676152434417 because of step counter
# Final cost : 0.028318676152434417
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318676152434417
# Converged in iteration 1 with cost 0.028318676152434417 because of step counter
# Final cost : 0.028318676152434417
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318676152434417
# Converged in iteration 1 with cost 0.028318676152434417 because of step counter
# Final cost : 0.028318676152434417
# Compute control for a deterministic system
# Cost in iteration 0: 0.02558955906431585
# Final cost : 0.011179127418067288
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179127418067288
# Converged in iteration 11 with cost 0.011179114289304888 because of vanishing difference
# Final cost : 0.011179114289304888
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179114289304888
# Converged in iteration 11 with cost 0.01117911394069433 because of step counter
# Final cost : 0.01117911394069433
# Compute control for a deterministic system
# Cost in iteration 0: 0.01117911394069433
# Converged in iteration 1 with cost 0.01117911394069433 because of step counter
# Final cost : 0.01117911394069433
# Compute control for a deterministic system
# Cost in iteration 0: 0.01117911394069433
# Converged in iteration 1 with cost 0.01117911394069433 because of step counter
# Final cost : 0.01117911394069433
# Compute control for a deterministic system
# Cost in iteration 0: 9.926891380816366e-06
# Converged in iteration 1 with cost 9.926891380816366e-06 because of step counter
# Final cost : 9.926891380816366e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06994582965812483
# Cost in iteration 200: 0.027306720457181844
# Final cost : 0.027306720457181844
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306720457181844
# Converged in iteration 8 with cost 0.027306716498271613 because of vanishing difference
# Final cost : 0.027306716498271613
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306716498271613
# Converged in iteration 16 with cost 0.02730671641999391 because of step counter
# Final cost : 0.02730671641999391
# Compute control for a deterministic system
# Cost in iteration 0: 0.02730671641999391
# Converged in iteration 4 with cost 0.027306716419993486 because of step counter
# Final cost : 0.027306716419993486
# Compute control for a deterministic system
# Cost in iteration 0: 0.027306716419993486
# Converged in iteration 1 with cost 0.027306716419993486 because of step counter
# Final cost : 0.027306716419993486
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.06018208421872821
# Cost in iteration 200: 0.039578176285758916
# Final cost : 0.039578176285758916
# Compute control for a deterministic system
# Cost in iteration 0: 0.039578176285758916
# Converged in iteration 35 with cost 0.03957806823406543 because of vanishing difference
# Final cost : 0.03957806823406543
# Compute control for a deterministic system
# Cost in iteration 0: 0.03957806823406543
# Converged in iteration 36 with cost 0.03957806793082314 because of step counter
# Final cost : 0.03957806793082314
# Compute control for a deterministic system
# Cost in iteration 0: 0.03957806793082314
# Converged in iteration 1 with cost 0.03957806793082314 because of step counter
# Final cost : 0.03957806793082314
# Compute control for a deterministic system
# Cost in iteration 0: 0.03957806793082314
# Converged in iteration 1 with cost 0.03957806793082314 because of step counter
# Final cost : 0.03957806793082314
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.09230044447278386
# Cost in iteration 200: 0.055768598434426477
# Final cost : 0.055768598434426477
# Compute control for a deterministic system
# Cost in iteration 0: 0.055768598434426477
# Converged in iteration 66 with cost 0.055767187959428526 because of vanishing difference
# Final cost : 0.055767187959428526
# Compute control for a deterministic system
# Cost in iteration 0: 0.055767187959428526
# Converged in iteration 61 with cost 0.05576718704854831 because of step counter
# Final cost : 0.05576718704854831
# Compute control for a deterministic system
# Cost in iteration 0: 0.05576718704854831
# Converged in iteration 1 with cost 0.05576718704854831 because of step counter
# Final cost : 0.05576718704854831
# Compute control for a deterministic system
# Cost in iteration 0: 0.05576718704854831
# Converged in iteration 1 with cost 0.05576718704854831 because of step counter
# Final cost : 0.05576718704854831
# Compute control for a deterministic system
# Cost in iteration 0: 0.08562126448163793
# Cost in iteration 200: 0.06775991169123569
# Final cost : 0.06775991169123569
# Compute control for a deterministic system
# Cost in iteration 0: 0.06775991169123569
# Converged in iteration 82 with cost 0.06775612219035365 because of vanishing difference
# Final cost : 0.06775612219035365
# Compute control for a deterministic system
# Cost in iteration 0: 0.06775612219035365
# Converged in iteration 80 with cost 0.0677561194759872 because of step counter
# Final cost : 0.0677561194759872
# Compute control for a deterministic system
# Cost in iteration 0: 0.0677561194759872
# Converged in iteration 1 with cost 0.0677561194759872 because of step counter
# Final cost : 0.0677561194759872
# Compute control for a deterministic system
# Cost in iteration 0: 0.0677561194759872
# Converged in iteration 1 with cost 0.0677561194759872 because of step counter
# Final cost : 0.0677561194759872
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.1216402300148212
# Cost in iteration 200: 0.08353518982248681
# Final cost : 0.08353518982248681
# Compute control for a deterministic system
# Cost in iteration 0: 0.08353518982248681
# Converged in iteration 96 with cost 0.08351573006135148 because of vanishing difference
# Final cost : 0.08351573006135148
# Compute control for a deterministic system
# Cost in iteration 0: 0.08351573006135148
# Converged in iteration 157 with cost 0.0835156553664827 because of vanishing difference
# Final cost : 0.0835156553664827
# Compute control for a deterministic system
# Cost in iteration 0: 0.0835156553664827
# Converged in iteration 9 with cost 0.08351565536647378 because of step counter
# Final cost : 0.08351565536647378
# Compute control for a deterministic system
# Cost in iteration 0: 0.08351565536647378
# Converged in iteration 1 with cost 0.08351565536647378 because of step counter
# Final cost : 0.08351565536647378
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.13074037524015564
# Cost in iteration 200: 0.0951797279326918
# Final cost : 0.0951797279326918
# Compute control for a deterministic system
# Cost in iteration 0: 0.0951797279326918
# Converged in iteration 112 with cost 0.095156350369838 because of vanishing difference
# Final cost : 0.095156350369838
# Compute control for a deterministic system
# Cost in iteration 0: 0.095156350369838
# Cost in iteration 200: 0.09515632810788989
# Final cost : 0.09515632810788989
# Compute control for a deterministic system
# Cost in iteration 0: 0.09515632810788989
# Converged in iteration 32 with cost 0.09515632810784515 because of vanishing difference
# Final cost : 0.09515632810784515
# Compute control for a deterministic system
# Cost in iteration 0: 0.09515632810784515
# Converged in iteration 4 with cost 0.09515632810784444 because of step counter
# Final cost : 0.09515632810784444
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.17029779813301296
# Cost in iteration 200: 0.110501454842718
# Final cost : 0.110501454842718
# Compute control for a deterministic system
# Cost in iteration 0: 0.110501454842718
# Converged in iteration 157 with cost 0.11042851918609227 because of vanishing difference
# Final cost : 0.11042851918609227
# Compute control for a deterministic system
# Cost in iteration 0: 0.11042851918609227
# Cost in iteration 200: 0.11042846774193789
# Final cost : 0.11042846774193789
# Compute control for a deterministic system
# Cost in iteration 0: 0.11042846774193789
# Converged in iteration 125 with cost 0.11042846773846828 because of step counter
# Final cost : 0.11042846773846828
# Compute control for a deterministic system
# Cost in iteration 0: 0.11042846773846828
# Converged in iteration 11 with cost 0.11042846773845579 because of step counter
# Final cost : 0.11042846773845579
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.17426623464955626
# Cost in iteration 200: 0.12175428524274151
# Final cost : 0.12175428524274151
# Compute control for a deterministic system
# Cost in iteration 0: 0.12175428524274151
# Converged in iteration 156 with cost 0.12169009370578293 because of vanishing difference
# Final cost : 0.12169009370578293
# Compute control for a deterministic system
# Cost in iteration 0: 0.12169009370578293
# Cost in iteration 200: 0.12168991201444009
# Final cost : 0.12168991201444009
# Compute control for a deterministic system
# Cost in iteration 0: 0.12168991201444009
# Cost in iteration 200: 0.12168991188155315
# Converged in iteration 237 with cost 0.1216899118814085 because of vanishing difference
# Final cost : 0.1216899118814085
# Compute control for a deterministic system
# Cost in iteration 0: 0.1216899118814085
# Converged in iteration 4 with cost 0.12168991188140159 because of step counter
# Final cost : 0.12168991188140159
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.16805778992561782
# Cost in iteration 200: 0.13659058158877596
# Final cost : 0.13659058158877596
# Compute control for a deterministic system
# Cost in iteration 0: 0.13659058158877596
# Converged in iteration 180 with cost 0.13643748250320087 because of vanishing difference
# Final cost : 0.13643748250320087
# Compute control for a deterministic system
# Cost in iteration 0: 0.13643748250320087
# Cost in iteration 200: 0.1364367924810284
# Final cost : 0.1364367924810284
# Compute control for a deterministic system
# Cost in iteration 0: 0.1364367924810284
# Cost in iteration 200: 0.13643678836511827
# Cost in iteration 400: 0.13643678832940295
# Final cost : 0.13643678832940295
# Compute control for a deterministic system
# Cost in iteration 0: 0.13643678832940295
# Converged in iteration 66 with cost 0.136436788329106 because of step counter
# Final cost : 0.136436788329106
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.17930509196622915
# Cost in iteration 200: 0.1473926450833879
# Final cost : 0.1473926450833879
# Compute control for a deterministic system
# Cost in iteration 0: 0.1473926450833879
# Converged in iteration 186 with cost 0.1472827277551266 because of vanishing difference
# Final cost : 0.1472827277551266
# Compute control for a deterministic system
# Cost in iteration 0: 0.1472827277551266
# Cost in iteration 200: 0.14728207400704524
# Final cost : 0.14728207400704524
# Compute control for a deterministic system
# Cost in iteration 0: 0.14728207400704524
# Cost in iteration 200: 0.14728206387972897
# Cost in iteration 400: 0.14728206365400956
# Final cost : 0.14728206365400956
# Compute control for a deterministic system
# Cost in iteration 0: 0.14728206365400956
# Converged in iteration 163 with cost 0.14728206364881152 because of step counter
# Final cost : 0.14728206364881152
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.201044409940159
# Cost in iteration 200: 0.16164751907623648
# Final cost : 0.16164751907623648
# Compute control for a deterministic system
# Cost in iteration 0: 0.16164751907623648
# Cost in iteration 200: 0.1614210595354712
# Final cost : 0.1614210595354712
# Compute control for a deterministic system
# Cost in iteration 0: 0.1614210595354712
# Converged in iteration 53 with cost 0.16141960088930377 because of vanishing difference
# Final cost : 0.16141960088930377
# Compute control for a deterministic system
# Cost in iteration 0: 0.16141960088930377
# Cost in iteration 200: 0.1614185564159491
# Cost in iteration 400: 0.16141849743907843
# Final cost : 0.16141849743907843
# Compute control for a deterministic system
# Cost in iteration 0: 0.16141849743907843
# Cost in iteration 200: 0.16141849307275244
# Cost in iteration 400: 0.16141849301852004
# Converged in iteration 513 with cost 0.16141849301770456 because of step counter
# Final cost : 0.16141849301770456
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.17845224143229202
# Cost in iteration 200: 0.17188581879169856
# Final cost : 0.17188581879169856
# Compute control for a deterministic system
# Cost in iteration 0: 0.17188581879169856
# Cost in iteration 200: 0.17174374647129306
# Final cost : 0.17174374647129306
# Compute control for a deterministic system
# Cost in iteration 0: 0.17174374647129306
# Converged in iteration 117 with cost 0.171741002762974 because of vanishing difference
# Final cost : 0.171741002762974
# Compute control for a deterministic system
# Cost in iteration 0: 0.171741002762974
# Cost in iteration 200: 0.17174017186964707
# ...
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.2784381036550797
# Cost in iteration 200: 0.27413261090963065
# Final cost : 0.27413261090963065
# Compute control for a deterministic system
# Cost in iteration 0: 0.27413261090963065
# Cost in iteration 200: 0.2740075679969605
# Final cost : 0.2740075679969605
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740075679969605
# Cost in iteration 200: 0.27400755119701015
# Final cost : 0.27400755119701015
# Compute control for a deterministic system
# Cost in iteration 0: 0.27400755119701015
# Cost in iteration 200: 0.27400755101925084
# Converged in iteration 273 with cost 0.27400755101689184 because of vanishing difference
# Final cost : 0.27400755101689184
# Compute control for a deterministic system
# Cost in iteration 0: 0.27400755101689184
# Converged in iteration 86 with cost 0.2740075510162371 because of vanishing difference
# Final cost : 0.2740075510162371
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.2549918324428253
# Cost in iteration 200: 0.2516826664058911
# Final cost : 0.2516826664058911
# Compute control for a deterministic system
# Cost in iteration 0: 0.2516826664058911
# Converged in iteration 166 with cost 0.251567603451584 because of vanishing difference
# Final cost : 0.251567603451584
# Compute control for a deterministic system
# Cost in iteration 0: 0.251567603451584
# Cost in iteration 200: 0.25156758345636093
# Final cost : 0.25156758345636093
# Compute control for a deterministic system
# Cost in iteration 0: 0.25156758345636093
# Cost in iteration 200: 0.2515675833477544
# Converged in iteration 280 with cost 0.251567583346867 because of vanishing difference
# Final cost : 0.251567583346867
# Compute control for a deterministic system
# Cost in iteration 0: 0.251567583346867
# Converged in iteration 51 with cost 0.25156758334672563 because of step counter
# Final cost : 0.25156758334672563
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.2459506539150271
# Cost in iteration 200: 0.23510956983402176
# Final cost : 0.23510956983402176
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510956983402176
# Cost in iteration 200: 0.2350230387252689
# Final cost : 0.2350230387252689
# Compute control for a deterministic system
# Cost in iteration 0: 0.2350230387252689
# Converged in iteration 1 with cost 0.2350230387252689 because of vanishing difference
# Final cost : 0.2350230387252689
# Compute control for a deterministic system
# Cost in iteration 0: 0.2350230387252689
# Cost in iteration 200: 0.2350230324682704
# Cost in iteration 400: 0.23502303243309164
# Final cost : 0.23502303243309164
# Compute control for a deterministic system
# Cost in iteration 0: 0.23502303243309164
# Converged in iteration 58 with cost 0.23502303243290407 because of step counter
# Final cost : 0.23502303243290407
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.22440392769083195
# Cost in iteration 200: 0.2134059978844736
# Final cost : 0.2134059978844736
# Compute control for a deterministic system
# Cost in iteration 0: 0.2134059978844736
# Cost in iteration 200: 0.21333624422961664
# Final cost : 0.21333624422961664
# Compute control for a deterministic system
# Cost in iteration 0: 0.21333624422961664
# Cost in iteration 200: 0.2133362401378052
# Final cost : 0.2133362401378052
# Compute control for a deterministic system
# Cost in iteration 0: 0.2133362401378052
# Converged in iteration 72 with cost 0.21333624013265823 because of step counter
# Final cost : 0.21333624013265823
# Compute control for a deterministic system
# Cost in iteration 0: 0.21333624013265823
# Converged in iteration 1 with cost 0.21333624013265823 because of step counter
# Final cost : 0.21333624013265823
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.20039569278318606
# Cost in iteration 200: 0.19741150609640423
# Final cost : 0.19741150609640423
# Compute control for a deterministic system
# Cost in iteration 0: 0.19741150609640423
# Converged in iteration 155 with cost 0.19734868408480497 because of vanishing difference
# Final cost : 0.19734868408480497
# Compute control for a deterministic system
# Cost in iteration 0: 0.19734868408480497
# Cost in iteration 200: 0.19734867938864276
# Final cost : 0.19734867938864276
# Compute control for a deterministic system
# Cost in iteration 0: 0.19734867938864276
# Converged in iteration 66 with cost 0.1973486793860883 because of step counter
# Final cost : 0.1973486793860883
# Compute control for a deterministic system
# Cost in iteration 0: 0.1973486793860883
# Converged in iteration 1 with cost 0.1973486793860883 because of step counter
# Final cost : 0.1973486793860883
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.18095566751873807
# Cost in iteration 200: 0.17644582083541727
# Final cost : 0.17644582083541727
# Compute control for a deterministic system
# Cost in iteration 0: 0.17644582083541727
# Converged in iteration 163 with cost 0.17640044914674174 because of vanishing difference
# Final cost : 0.17640044914674174
# Compute control for a deterministic system
# Cost in iteration 0: 0.17640044914674174
# Cost in iteration 200: 0.17640044610278519
# Final cost : 0.17640044610278519
# Compute control for a deterministic system
# Cost in iteration 0: 0.17640044610278519
# Converged in iteration 31 with cost 0.1764004461023895 because of vanishing difference
# Final cost : 0.1764004461023895
# Compute control for a deterministic system
# Cost in iteration 0: 0.1764004461023895
# Converged in iteration 12 with cost 0.17640044610238073 because of step counter
# Final cost : 0.17640044610238073
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.1739114038133242
# Cost in iteration 200: 0.16099563580287254
# Final cost : 0.16099563580287254
# Compute control for a deterministic system
# Cost in iteration 0: 0.16099563580287254
# Converged in iteration 131 with cost 0.1609646580919897 because of vanishing difference
# Final cost : 0.1609646580919897
# Compute control for a deterministic system
# Cost in iteration 0: 0.1609646580919897
# Cost in iteration 200: 0.1609646502926913
# Final cost : 0.1609646502926913
# Compute control for a deterministic system
# Cost in iteration 0: 0.1609646502926913
# Converged in iteration 29 with cost 0.16096465029243212 because of vanishing difference
# Final cost : 0.16096465029243212
# Compute control for a deterministic system
# Cost in iteration 0: 0.16096465029243212
# Converged in iteration 1 with cost 0.16096465029243212 because of step counter
# Final cost : 0.16096465029243212
# Compute control for a deterministic system
# Cost in iteration 0: 0.15904715586378448
# Cost in iteration 200: 0.14076728531942348
# Final cost : 0.14076728531942348
# Compute control for a deterministic system
# Cost in iteration 0: 0.14076728531942348
# Converged in iteration 106 with cost 0.140749259256878 because of vanishing difference
# Final cost : 0.140749259256878
# Compute control for a deterministic system
# Cost in iteration 0: 0.140749259256878
# Cost in iteration 200: 0.14074925176048686
# Final cost : 0.14074925176048686
# Compute control for a deterministic system
# Cost in iteration 0: 0.14074925176048686
# Converged in iteration 10 with cost 0.14074925176045994 because of step counter
# Final cost : 0.14074925176045994
# Compute control for a deterministic system
# Cost in iteration 0: 0.14074925176045994
# Converged in iteration 1 with cost 0.14074925176045994 because of step counter
# Final cost : 0.14074925176045994
# Compute control for a deterministic system
# Cost in iteration 0: 0.13957885722681163
# Cost in iteration 200: 0.125873811695083
# Final cost : 0.125873811695083
# Compute control for a deterministic system
# Cost in iteration 0: 0.125873811695083
# Converged in iteration 119 with cost 0.1258611474939048 because of vanishing difference
# Final cost : 0.1258611474939048
# Compute control for a deterministic system
# Cost in iteration 0: 0.1258611474939048
# Converged in iteration 154 with cost 0.12586114688578437 because of step counter
# Final cost : 0.12586114688578437
# Compute control for a deterministic system
# Cost in iteration 0: 0.12586114688578437
# Converged in iteration 1 with cost 0.12586114688578437 because of step counter
# Final cost : 0.12586114688578437
# Compute control for a deterministic system
# Cost in iteration 0: 0.12586114688578437
# Converged in iteration 1 with cost 0.12586114688578437 because of step counter
# Final cost : 0.12586114688578437
# Compute control for a deterministic system
# Cost in iteration 0: 0.1083802907089726
# Cost in iteration 200: 0.10638192392614418
# Final cost : 0.10638192392614418
# Compute control for a deterministic system
# Cost in iteration 0: 0.10638192392614418
# Converged in iteration 22 with cost 0.10637475455650085 because of vanishing difference
# Final cost : 0.10637475455650085
# Compute control for a deterministic system
# Cost in iteration 0: 0.10637475455650085
# Converged in iteration 175 with cost 0.10637461199886598 because of step counter
# Final cost : 0.10637461199886598
# Compute control for a deterministic system
# Cost in iteration 0: 0.10637461199886598
# Converged in iteration 2 with cost 0.10637461199886585 because of step counter
# Final cost : 0.10637461199886585
# Compute control for a deterministic system
# Cost in iteration 0: 0.10637461199886585
# Converged in iteration 2 with cost 0.106374611998865 because of step counter
# Final cost : 0.106374611998865
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.09456132143009126
# Cost in iteration 200: 0.0920379036141588
# Final cost : 0.0920379036141588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0920379036141588
# Converged in iteration 86 with cost 0.09203368172120185 because of vanishing difference
# Final cost : 0.09203368172120185
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368172120185
# Converged in iteration 113 with cost 0.09203368107693959 because of step counter
# Final cost : 0.09203368107693959
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368107693959
# Converged in iteration 1 with cost 0.09203368107693959 because of step counter
# Final cost : 0.09203368107693959
# Compute control for a deterministic system
# Cost in iteration 0: 0.09203368107693959
# Converged in iteration 2 with cost 0.0920336810769395 because of step counter
# Final cost : 0.0920336810769395
# Compute control for a deterministic system
# Cost in iteration 0: 0.07533614294905644
# Cost in iteration 200: 0.07328198369006285
# Final cost : 0.07328198369006285
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328198369006285
# Converged in iteration 18 with cost 0.07328110610053823 because of vanishing difference
# Final cost : 0.07328110610053823
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328110610053823
# Converged in iteration 103 with cost 0.07328109833282472 because of step counter
# Final cost : 0.07328109833282472
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328109833282472
# Converged in iteration 1 with cost 0.07328109833282472 because of step counter
# Final cost : 0.07328109833282472
# Compute control for a deterministic system
# Cost in iteration 0: 0.07328109833282472
# Converged in iteration 1 with cost 0.07328109833282472 because of step counter
# Final cost : 0.07328109833282472
# -----------------------------------------------
# 4 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.06284105670083655
# Cost in iteration 200: 0.059498325365395364
# Final cost : 0.059498325365395364
# Compute control for a deterministic system
# Cost in iteration 0: 0.059498325365395364
# Converged in iteration 52 with cost 0.05949775903439187 because of vanishing difference
# Final cost : 0.05949775903439187
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775903439187
# Converged in iteration 77 with cost 0.05949775733473373 because of step counter
# Final cost : 0.05949775733473373
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775733473373
# Converged in iteration 1 with cost 0.05949775733473373 because of step counter
# Final cost : 0.05949775733473373
# Compute control for a deterministic system
# Cost in iteration 0: 0.05949775733473373
# Converged in iteration 1 with cost 0.05949775733473373 because of step counter
# Final cost : 0.05949775733473373
# -----------------------------------------------
# 4 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.042675865822659295
# Cost in iteration 200: 0.041506979174609646
# Final cost : 0.041506979174609646
# Compute control for a deterministic system
# Cost in iteration 0: 0.041506979174609646
# Converged in iteration 46 with cost 0.04150697273016281 because of step counter
# Final cost : 0.04150697273016281
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150697273016281
# Converged in iteration 2 with cost 0.04150697273016268 because of step counter
# Final cost : 0.04150697273016268
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150697273016268
# Converged in iteration 1 with cost 0.04150697273016268 because of step counter
# Final cost : 0.04150697273016268
# Compute control for a deterministic system
# Cost in iteration 0: 0.04150697273016268
# Converged in iteration 1 with cost 0.04150697273016268 because of step counter
# Final cost : 0.04150697273016268
# -----------------------------------------------
# 4 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.02945664342821528
# Converged in iteration 175 with cost 0.028318675478652362 because of vanishing difference
# Final cost : 0.028318675478652362
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318675478652362
# Converged in iteration 21 with cost 0.028318675259584716 because of step counter
# Final cost : 0.028318675259584716
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318675259584716
# Converged in iteration 1 with cost 0.028318675259584716 because of step counter
# Final cost : 0.028318675259584716
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318675259584716
# Converged in iteration 1 with cost 0.028318675259584716 because of step counter
# Final cost : 0.028318675259584716
# Compute control for a deterministic system
# Cost in iteration 0: 0.028318675259584716
# Converged in iteration 1 with cost 0.028318675259584716 because of step counter
# Final cost : 0.028318675259584716
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.011535108380197806
# Converged in iteration 64 with cost 0.011179113142884934 because of vanishing difference
# Final cost : 0.011179113142884934
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179113142884934
# Converged in iteration 7 with cost 0.011179113057121343 because of step counter
# Final cost : 0.011179113057121343
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179113057121343
# Converged in iteration 2 with cost 0.011179113057121227 because of step counter
# Final cost : 0.011179113057121227
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179113057121227
# Converged in iteration 1 with cost 0.011179113057121227 because of step counter
# Final cost : 0.011179113057121227
# Compute control for a deterministic system
# Cost in iteration 0: 0.011179113057121227
# Converged in iteration 1 with cost 0.011179113057121227 because of step counter
# Final cost : 0.011179113057121227

# %%
save(results_min)
