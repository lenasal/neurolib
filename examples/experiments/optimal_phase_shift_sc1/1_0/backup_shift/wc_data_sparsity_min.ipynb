# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history.copy()

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish][-1] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ('models', [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
#options = [True, True, False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, True, True, True, True]

ilist = [20, 21,22,23,24, 25]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w not in [0]:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["models"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)
            results_min["models"][i_w][i_shift] = wc_controlled

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                factor = 1.1
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,1500:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[8]:
            print("----------------------------------------------- 8")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,100:] = results_peak["control"][i_w][i_shift].copy()[:,:,:-100]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("8 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[9]:
            print("----------------------------------------------- 9")
            for i_shift in range(1, n_points-1):

                if i_shift not in ilist:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = results_min["models"][i_w][i_shift]
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,np.around(period/dt).astype(int):] = results_min["control"][i_w][i_shift].copy()[:,:,:-np.around(period/dt).astype(int)]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("9 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.11473309612682175
# Cost in iteration 200: 0.10366468978609956
# Final cost : 0.10366468978609956
# Compute control for a deterministic system
# Cost in iteration 0: 0.10366468978609956
# Converged in iteration 43 with cost 0.10098415957550358 because of step counter
# Final cost : 0.10098415957550358
# Compute control for a deterministic system
# Cost in iteration 0: 0.10098415957550358
# Converged in iteration 1 with cost 0.10098415957550358 because of step counter
# Final cost : 0.10098415957550358
# Compute control for a deterministic system
# Cost in iteration 0: 0.10098415957550358
# Converged in iteration 1 with cost 0.10098415957550358 because of step counter
# Final cost : 0.10098415957550358
# Compute control for a deterministic system
# Cost in iteration 0: 0.10098415957550358
# Converged in iteration 1 with cost 0.10098415957550358 because of step counter
# Final cost : 0.10098415957550358
# Compute control for a deterministic system
# Cost in iteration 0: 0.1512790993488823
# Converged in iteration 123 with cost 0.11674921222337568 because of step counter
# Final cost : 0.11674921222337568
# Compute control for a deterministic system
# Cost in iteration 0: 0.11674921222337568
# Converged in iteration 1 with cost 0.11674921222337568 because of step counter
# Final cost : 0.11674921222337568
# Compute control for a deterministic system
# Cost in iteration 0: 0.11674921222337568
# Converged in iteration 1 with cost 0.11674921222337568 because of step counter
# Final cost : 0.11674921222337568
# Compute control for a deterministic system
# Cost in iteration 0: 0.11674921222337568
# Converged in iteration 1 with cost 0.11674921222337568 because of step counter
# Final cost : 0.11674921222337568
# Compute control for a deterministic system
# Cost in iteration 0: 0.11674921222337568
# Converged in iteration 1 with cost 0.11674921222337568 because of step counter
# Final cost : 0.11674921222337568
# Compute control for a deterministic system
# Cost in iteration 0: 0.12595858798075193
# Cost in iteration 200: 0.0883060926008595
# Final cost : 0.0883060926008595
# Compute control for a deterministic system
# Cost in iteration 0: 0.0883060926008595
# Converged in iteration 36 with cost 0.08572213157664108 because of step counter
# Final cost : 0.08572213157664108
# Compute control for a deterministic system
# Cost in iteration 0: 0.08572213157664108
# Converged in iteration 1 with cost 0.08572213157664108 because of step counter
# Final cost : 0.08572213157664108
# Compute control for a deterministic system
# Cost in iteration 0: 0.08572213157664108
# Converged in iteration 1 with cost 0.08572213157664108 because of step counter
# Final cost : 0.08572213157664108
# Compute control for a deterministic system
# Cost in iteration 0: 0.08572213157664108
# Converged in iteration 1 with cost 0.08572213157664108 because of step counter
# Final cost : 0.08572213157664108
# Compute control for a deterministic system
# Cost in iteration 0: 0.12186939406062672
# Cost in iteration 200: 0.0852091397332587
# Final cost : 0.0852091397332587
# Compute control for a deterministic system
# Cost in iteration 0: 0.0852091397332587
# Cost in iteration 200: 0.08284625476121187
# Final cost : 0.08284625476121187
# Compute control for a deterministic system
# Cost in iteration 0: 0.08284625476121187
# Converged in iteration 21 with cost 0.08283523854860186 because of step counter
# Final cost : 0.08283523854860186
# Compute control for a deterministic system
# Cost in iteration 0: 0.08283523854860186
# Converged in iteration 1 with cost 0.08283523854860186 because of step counter
# Final cost : 0.08283523854860186
# Compute control for a deterministic system
# Cost in iteration 0: 0.08283523854860186
# Converged in iteration 1 with cost 0.08283523854860186 because of step counter
# Final cost : 0.08283523854860186
# Compute control for a deterministic system
# Cost in iteration 0: 0.10306382074593157
# Cost in iteration 200: 0.08038907752537498
# Final cost : 0.08038907752537498
# Compute control for a deterministic system
# Cost in iteration 0: 0.08038907752537498
# Converged in iteration 57 with cost 0.0802734330171228 because of step counter
# Final cost : 0.0802734330171228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802734330171228
# Converged in iteration 1 with cost 0.0802734330171228 because of step counter
# Final cost : 0.0802734330171228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802734330171228
# Converged in iteration 1 with cost 0.0802734330171228 because of step counter
# Final cost : 0.0802734330171228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0802734330171228
# Converged in iteration 1 with cost 0.0802734330171228 because of step counter
# Final cost : 0.0802734330171228
# Compute control for a deterministic system
# Cost in iteration 0: 0.11057724855331327
# Cost in iteration 200: 0.07350917972401143
# Final cost : 0.07350917972401143
# Compute control for a deterministic system
# Cost in iteration 0: 0.07350917972401143
# Converged in iteration 50 with cost 0.07126354109976485 because of vanishing difference
# Final cost : 0.07126354109976485
# Compute control for a deterministic system
# Cost in iteration 0: 0.07126354109976485
# Converged in iteration 3 with cost 0.0712635410893011 because of step counter
# Final cost : 0.0712635410893011
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712635410893011
# Converged in iteration 1 with cost 0.0712635410893011 because of step counter
# Final cost : 0.0712635410893011
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712635410893011
# Converged in iteration 1 with cost 0.0712635410893011 because of step counter
# Final cost : 0.0712635410893011
# -----------------------------------------------
# 0 found better solution,  25
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.07517966631479228
# Converged in iteration 47 with cost 0.07250216238730464 because of step counter
# Final cost : 0.07250216238730464
# Compute control for a deterministic system
# Cost in iteration 0: 0.07250216238730464
# Converged in iteration 1 with cost 0.07250216238730464 because of step counter
# Final cost : 0.07250216238730464
# Compute control for a deterministic system
# Cost in iteration 0: 0.07250216238730464
# Converged in iteration 1 with cost 0.07250216238730464 because of step counter
# Final cost : 0.07250216238730464
# Compute control for a deterministic system
# Cost in iteration 0: 0.07250216238730464
# Converged in iteration 1 with cost 0.07250216238730464 because of step counter
# Final cost : 0.07250216238730464
# Compute control for a deterministic system
# Cost in iteration 0: 0.07832894371306434
# Converged in iteration 29 with cost 0.07713936512259566 because of step counter
# Final cost : 0.07713936512259566
# Compute control for a deterministic system
# Cost in iteration 0: 0.07713936512259566
# Converged in iteration 1 with cost 0.07713936512259566 because of step counter
# Final cost : 0.07713936512259566
# Compute control for a deterministic system
# Cost in iteration 0: 0.07713936512259566
# Converged in iteration 1 with cost 0.07713936512259566 because of step counter
# Final cost : 0.07713936512259566
# Compute control for a deterministic system
# Cost in iteration 0: 0.07713936512259566
# Converged in iteration 1 with cost 0.07713936512259566 because of step counter
# Final cost : 0.07713936512259566
# -----------------------------------------------
# 1 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.08393492958970908
# Converged in iteration 28 with cost 0.0830660525079013 because of step counter
# Final cost : 0.0830660525079013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0830660525079013
# Converged in iteration 1 with cost 0.0830660525079013 because of step counter
# Final cost : 0.0830660525079013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0830660525079013
# Converged in iteration 1 with cost 0.0830660525079013 because of step counter
# Final cost : 0.0830660525079013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0830660525079013
# Converged in iteration 1 with cost 0.0830660525079013 because of step counter
# Final cost : 0.0830660525079013
# Compute control for a deterministic system
# Cost in iteration 0: 0.09120021628457164
# Converged in iteration 42 with cost 0.08735027869584809 because of step counter
# Final cost : 0.08735027869584809
# Compute control for a deterministic system
# Cost in iteration 0: 0.08735027869584809
# Converged in iteration 1 with cost 0.08735027869584809 because of step counter
# Final cost : 0.08735027869584809
# Compute control for a deterministic system
# Cost in iteration 0: 0.08735027869584809
# Converged in iteration 1 with cost 0.08735027869584809 because of step counter
# Final cost : 0.08735027869584809
# Compute control for a deterministic system
# Cost in iteration 0: 0.08735027869584809
# Converged in iteration 1 with cost 0.08735027869584809 because of step counter
# Final cost : 0.08735027869584809
# Compute control for a deterministic system
# Cost in iteration 0: 0.09497332782330477
# Converged in iteration 37 with cost 0.0925569796027712 because of step counter
# Final cost : 0.0925569796027712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0925569796027712
# Converged in iteration 1 with cost 0.0925569796027712 because of step counter
# Final cost : 0.0925569796027712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0925569796027712
# Converged in iteration 1 with cost 0.0925569796027712 because of step counter
# Final cost : 0.0925569796027712
# Compute control for a deterministic system
# Cost in iteration 0: 0.0925569796027712
# Converged in iteration 1 with cost 0.0925569796027712 because of step counter
# Final cost : 0.0925569796027712
# Compute control for a deterministic system
# Cost in iteration 0: 0.15046411163154924
# Converged in iteration 37 with cost 0.11668552999594396 because of step counter
# Final cost : 0.11668552999594396
# Compute control for a deterministic system
# Cost in iteration 0: 0.11668552999594396
# Converged in iteration 1 with cost 0.11668552999594396 because of step counter
# Final cost : 0.11668552999594396
# Compute control for a deterministic system
# Cost in iteration 0: 0.11668552999594396
# Converged in iteration 1 with cost 0.11668552999594396 because of step counter
# Final cost : 0.11668552999594396
# Compute control for a deterministic system
# Cost in iteration 0: 0.11668552999594396
# Converged in iteration 1 with cost 0.11668552999594396 because of step counter
# Final cost : 0.11668552999594396
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.10744717469764702
# Converged in iteration 171 with cost 0.10389491590915272 because of step counter
# Final cost : 0.10389491590915272
# Compute control for a deterministic system
# Cost in iteration 0: 0.10389491590915272
# Converged in iteration 1 with cost 0.10389491590915272 because of step counter
# Final cost : 0.10389491590915272
# Compute control for a deterministic system
# Cost in iteration 0: 0.10389491590915272
# Converged in iteration 1 with cost 0.10389491590915272 because of step counter
# Final cost : 0.10389491590915272
# Compute control for a deterministic system
# Cost in iteration 0: 0.10389491590915272
# Converged in iteration 1 with cost 0.10389491590915272 because of step counter
# Final cost : 0.10389491590915272
# Compute control for a deterministic system
# Cost in iteration 0: 0.10389491590915272
# Converged in iteration 1 with cost 0.10389491590915272 because of step counter
# Final cost : 0.10389491590915272
# Compute control for a deterministic system
# Cost in iteration 0: 0.11918049920707979
# Converged in iteration 100 with cost 0.10962505743934876 because of step counter
# Final cost : 0.10962505743934876
# Compute control for a deterministic system
# Cost in iteration 0: 0.10962505743934876
# Converged in iteration 1 with cost 0.10962505743934876 because of step counter
# Final cost : 0.10962505743934876
# Compute control for a deterministic system
# Cost in iteration 0: 0.10962505743934876
# Converged in iteration 1 with cost 0.10962505743934876 because of step counter
# Final cost : 0.10962505743934876
# Compute control for a deterministic system
# Cost in iteration 0: 0.10962505743934876
# Converged in iteration 1 with cost 0.10962505743934876 because of step counter
# Final cost : 0.10962505743934876
# Compute control for a deterministic system
# Cost in iteration 0: 0.10962505743934876
# Converged in iteration 1 with cost 0.10962505743934876 because of step counter
# Final cost : 0.10962505743934876
# Compute control for a deterministic system
# Cost in iteration 0: 0.10407371769045126
# Converged in iteration 183 with cost 0.10281581705182435 because of step counter
# Final cost : 0.10281581705182435
# Compute control for a deterministic system
# Cost in iteration 0: 0.10281581705182435
# Converged in iteration 1 with cost 0.10281581705182435 because of step counter
# Final cost : 0.10281581705182435
# Compute control for a deterministic system
# Cost in iteration 0: 0.10281581705182435
# Converged in iteration 1 with cost 0.10281581705182435 because of step counter
# Final cost : 0.10281581705182435
# Compute control for a deterministic system
# Cost in iteration 0: 0.10281581705182435
# Converged in iteration 1 with cost 0.10281581705182435 because of step counter
# Final cost : 0.10281581705182435
# Compute control for a deterministic system
# Cost in iteration 0: 0.10281581705182435
# Converged in iteration 1 with cost 0.10281581705182435 because of step counter
# Final cost : 0.10281581705182435
# Compute control for a deterministic system
# Cost in iteration 0: 0.21375262236075918
# Cost in iteration 200: 0.11077365584041397
# Final cost : 0.11077365584041397
# Compute control for a deterministic system
# Cost in iteration 0: 0.11077365584041397
# Converged in iteration 32 with cost 0.10672334686685761 because of step counter
# Final cost : 0.10672334686685761
# Compute control for a deterministic system
# Cost in iteration 0: 0.10672334686685761
# Converged in iteration 1 with cost 0.10672334686685761 because of step counter
# Final cost : 0.10672334686685761
# Compute control for a deterministic system
# Cost in iteration 0: 0.10672334686685761
# Converged in iteration 1 with cost 0.10672334686685761 because of step counter
# Final cost : 0.10672334686685761
# Compute control for a deterministic system
# Cost in iteration 0: 0.10672334686685761
# Converged in iteration 1 with cost 0.10672334686685761 because of step counter
# Final cost : 0.10672334686685761
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888602691058665
# Converged in iteration 97 with cost 0.08727985635386808 because of step counter
# Final cost : 0.08727985635386808
# Compute control for a deterministic system
# Cost in iteration 0: 0.08727985635386808
# Converged in iteration 1 with cost 0.08727985635386808 because of step counter
# Final cost : 0.08727985635386808
# Compute control for a deterministic system
# Cost in iteration 0: 0.08727985635386808
# Converged in iteration 1 with cost 0.08727985635386808 because of step counter
# Final cost : 0.08727985635386808
# Compute control for a deterministic system
# Cost in iteration 0: 0.08727985635386808
# Converged in iteration 1 with cost 0.08727985635386808 because of step counter
# Final cost : 0.08727985635386808
# Compute control for a deterministic system
# Cost in iteration 0: 0.08727985635386808
# Converged in iteration 1 with cost 0.08727985635386808 because of step counter
# Final cost : 0.08727985635386808
# Compute control for a deterministic system
# Cost in iteration 0: 0.08712117444164795
# Converged in iteration 128 with cost 0.0810542892316593 because of step counter
# Final cost : 0.0810542892316593
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810542892316593
# Converged in iteration 1 with cost 0.0810542892316593 because of step counter
# Final cost : 0.0810542892316593
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810542892316593
# Converged in iteration 1 with cost 0.0810542892316593 because of step counter
# Final cost : 0.0810542892316593
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810542892316593
# Converged in iteration 1 with cost 0.0810542892316593 because of step counter
# Final cost : 0.0810542892316593
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810542892316593
# Converged in iteration 1 with cost 0.0810542892316593 because of step counter
# Final cost : 0.0810542892316593
# ----------------------------------------------- 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.09898210620033203
# Converged in iteration 35 with cost 0.09888720928164743 because of step counter
# Final cost : 0.09888720928164743
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888720928164743
# Converged in iteration 1 with cost 0.09888720928164743 because of step counter
# Final cost : 0.09888720928164743
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888720928164743
# Converged in iteration 1 with cost 0.09888720928164743 because of step counter
# Final cost : 0.09888720928164743
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888720928164743
# Converged in iteration 1 with cost 0.09888720928164743 because of step counter
# Final cost : 0.09888720928164743
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888720928164743
# Converged in iteration 1 with cost 0.09888720928164743 because of step counter
# Final cost : 0.09888720928164743
# Compute control for a deterministic system
# Cost in iteration 0: 0.10535276513547631
# Converged in iteration 143 with cost 0.10524920879690688 because of step counter
# Final cost : 0.10524920879690688
# Compute control for a deterministic system
# Cost in iteration 0: 0.10524920879690688
# Converged in iteration 1 with cost 0.10524920879690688 because of vanishing difference
# Final cost : 0.10524920879690688
# Compute control for a deterministic system
# Cost in iteration 0: 0.10524920879690688
# Converged in iteration 1 with cost 0.10524920879690688 because of step counter
# Final cost : 0.10524920879690688
# Compute control for a deterministic system
# Cost in iteration 0: 0.10524920879690688
# Converged in iteration 1 with cost 0.10524920879690688 because of step counter
# Final cost : 0.10524920879690688
# Compute control for a deterministic system
# Cost in iteration 0: 0.10524920879690688
# Converged in iteration 1 with cost 0.10524920879690688 because of step counter
# Final cost : 0.10524920879690688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0992467749011446
# Converged in iteration 33 with cost 0.09860682260988221 because of step counter
# Final cost : 0.09860682260988221
# Compute control for a deterministic system
# Cost in iteration 0: 0.09860682260988221
# Converged in iteration 1 with cost 0.09860682260988221 because of step counter
# Final cost : 0.09860682260988221
# Compute control for a deterministic system
# Cost in iteration 0: 0.09860682260988221
# Converged in iteration 1 with cost 0.09860682260988221 because of step counter
# Final cost : 0.09860682260988221
# Compute control for a deterministic system
# Cost in iteration 0: 0.09860682260988221
# Converged in iteration 1 with cost 0.09860682260988221 because of step counter
# Final cost : 0.09860682260988221
# Compute control for a deterministic system
# Cost in iteration 0: 0.09860682260988221
# Converged in iteration 1 with cost 0.09860682260988221 because of step counter
# Final cost : 0.09860682260988221
# Compute control for a deterministic system
# Cost in iteration 0: 0.09421022087545586
# Converged in iteration 32 with cost 0.09389447939395384 because of step counter
# Final cost : 0.09389447939395384
# Compute control for a deterministic system
# Cost in iteration 0: 0.09389447939395384
# Converged in iteration 1 with cost 0.09389447939395384 because of step counter
# Final cost : 0.09389447939395384
# Compute control for a deterministic system
# Cost in iteration 0: 0.09389447939395384
# Converged in iteration 1 with cost 0.09389447939395384 because of step counter
# Final cost : 0.09389447939395384
# Compute control for a deterministic system
# Cost in iteration 0: 0.09389447939395384
# Converged in iteration 1 with cost 0.09389447939395384 because of step counter
# Final cost : 0.09389447939395384
# Compute control for a deterministic system
# Cost in iteration 0: 0.09389447939395384
# Converged in iteration 1 with cost 0.09389447939395384 because of step counter
# Final cost : 0.09389447939395384
# Compute control for a deterministic system
# Cost in iteration 0: 0.08137256569114372
# Converged in iteration 156 with cost 0.0810654339755296 because of step counter
# Final cost : 0.0810654339755296
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810654339755296
# Converged in iteration 1 with cost 0.0810654339755296 because of step counter
# Final cost : 0.0810654339755296
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810654339755296
# Converged in iteration 1 with cost 0.0810654339755296 because of step counter
# Final cost : 0.0810654339755296
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810654339755296
# Converged in iteration 1 with cost 0.0810654339755296 because of step counter
# Final cost : 0.0810654339755296
# Compute control for a deterministic system
# Cost in iteration 0: 0.0810654339755296
# Converged in iteration 1 with cost 0.0810654339755296 because of step counter
# Final cost : 0.0810654339755296
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454591504938232
# Converged in iteration 7 with cost 0.07454074925736122 because of step counter
# Final cost : 0.07454074925736122
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454074925736122
# Converged in iteration 1 with cost 0.07454074925736122 because of step counter
# Final cost : 0.07454074925736122
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454074925736122
# Converged in iteration 1 with cost 0.07454074925736122 because of step counter
# Final cost : 0.07454074925736122
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454074925736122
# Converged in iteration 1 with cost 0.07454074925736122 because of step counter
# Final cost : 0.07454074925736122
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454074925736122
# Converged in iteration 1 with cost 0.07454074925736122 because of step counter
# Final cost : 0.07454074925736122
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.11078808417856478
# Converged in iteration 105 with cost 0.10461408637704846 because of step counter
# Final cost : 0.10461408637704846
# Compute control for a deterministic system
# Cost in iteration 0: 0.10461408637704846
# Converged in iteration 1 with cost 0.10461408637704846 because of step counter
# Final cost : 0.10461408637704846
# Compute control for a deterministic system
# Cost in iteration 0: 0.10461408637704846
# Converged in iteration 1 with cost 0.10461408637704846 because of step counter
# Final cost : 0.10461408637704846
# Compute control for a deterministic system
# Cost in iteration 0: 0.10461408637704846
# Converged in iteration 1 with cost 0.10461408637704846 because of step counter
# Final cost : 0.10461408637704846
# Compute control for a deterministic system
# Cost in iteration 0: 0.10461408637704846
# Converged in iteration 1 with cost 0.10461408637704846 because of step counter
# Final cost : 0.10461408637704846
# Compute control for a deterministic system
# Cost in iteration 0: 0.8274352988671579
# Cost in iteration 200: 0.21964018138171681
# Final cost : 0.21964018138171681
# Compute control for a deterministic system
# Cost in iteration 0: 0.21964018138171681
# Converged in iteration 66 with cost 0.18582263885783587 because of step counter
# Final cost : 0.18582263885783587
# Compute control for a deterministic system
# Cost in iteration 0: 0.18582263885783587
# Converged in iteration 1 with cost 0.18582263885783587 because of step counter
# Final cost : 0.18582263885783587
# Compute control for a deterministic system
# Cost in iteration 0: 0.18582263885783587
# Converged in iteration 1 with cost 0.18582263885783587 because of step counter
# Final cost : 0.18582263885783587
# Compute control for a deterministic system
# Cost in iteration 0: 0.18582263885783587
# Converged in iteration 1 with cost 0.18582263885783587 because of step counter
# Final cost : 0.18582263885783587
# Compute control for a deterministic system
# Cost in iteration 0: 0.6688515738107477
# Cost in iteration 200: 0.18996005767475937
# Final cost : 0.18996005767475937
# Compute control for a deterministic system
# Cost in iteration 0: 0.18996005767475937
# Converged in iteration 55 with cost 0.16873579256204085 because of step counter
# Final cost : 0.16873579256204085
# Compute control for a deterministic system
# Cost in iteration 0: 0.16873579256204085
# Converged in iteration 1 with cost 0.16873579256204085 because of step counter
# Final cost : 0.16873579256204085
# Compute control for a deterministic system
# Cost in iteration 0: 0.16873579256204085
# Converged in iteration 1 with cost 0.16873579256204085 because of step counter
# Final cost : 0.16873579256204085
# Compute control for a deterministic system
# Cost in iteration 0: 0.16873579256204085
# Converged in iteration 1 with cost 0.16873579256204085 because of step counter
# Final cost : 0.16873579256204085
# Compute control for a deterministic system
# Cost in iteration 0: 0.495441795878501
# Cost in iteration 200: 0.15936051806363993
# Final cost : 0.15936051806363993
# Compute control for a deterministic system
# Cost in iteration 0: 0.15936051806363993
# Converged in iteration 39 with cost 0.14827410442638478 because of step counter
# Final cost : 0.14827410442638478
# Compute control for a deterministic system
# Cost in iteration 0: 0.14827410442638478
# Converged in iteration 1 with cost 0.14827410442638478 because of step counter
# Final cost : 0.14827410442638478
# Compute control for a deterministic system
# Cost in iteration 0: 0.14827410442638478
# Converged in iteration 1 with cost 0.14827410442638478 because of step counter
# Final cost : 0.14827410442638478
# Compute control for a deterministic system
# Cost in iteration 0: 0.14827410442638478
# Converged in iteration 1 with cost 0.14827410442638478 because of step counter
# Final cost : 0.14827410442638478
# Compute control for a deterministic system
# Cost in iteration 0: 0.8015647718304041
# Cost in iteration 200: 0.19702302987518183
# Final cost : 0.19702302987518183
# Compute control for a deterministic system
# Cost in iteration 0: 0.19702302987518183

# %%
100 0.06821236541225148
