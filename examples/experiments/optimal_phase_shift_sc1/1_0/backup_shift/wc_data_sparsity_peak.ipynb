# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot_single(time, state, control, target, filename=None):

    fig, ax = plt.subplots(2,1)

    ax[0].plot(time, state[0,0,1:], color="red")
    ax[0].plot(time, state[0,1,1:], color="blue")
    ax[0].plot(time, target[0,0,1:], color="red", linestyle=':')
    ax[0].plot(time, target[0,1,1:], color="blue", linestyle=':')
    #ax[0].set_xlim(0,300)

    ax[1].plot(time, control[0,0,1:], color="red")
    ax[1].plot(time, control[0,1,1:], color="blue")
    #ax[1].set_xlim(0,300)

    if type(filename) != type(None):
        plt.savefig(filename)
    plt.show()

savepath =  '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + 'writing' + os.sep + 'paper2_chaos' + os.sep + 'exploration' + os.sep + 'images_ops' + os.sep

def plot(c_array, filename):

    fig, ax = plt.subplots(len(c_array),1, figsize=(10,2.*len(c_array)))

    for i in range(len(c_array)):
        ax[i].plot(wc_controlled.model.t, c_array[i][0,0,1:], color="red")
        ax[i].plot(wc_controlled.model.t, c_array[i][0,1,1:], color="blue")
        ax[i].set_ylim([-0.4,0.4])
        ax[i].set_title(str(np.round(i*2./(len(c_array)-1), 2))+ " * pi")
        if i != len(c_array)-1:
            ax[i].set_xticklabels([])

    plt.savefig(os.path.join(savepath, filename))
    plt.show()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,185], wc.inh[0,185]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# peaks =  [ 111  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2945 3134 3323 3512 3701 3890 4079 4268 4457 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history.copy()

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish][-1] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]
    return p, index, target

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ('models', [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

ind_list = []
options = [True, True, True, True, True, True, True, False, False]
#options = [False, False, False, False, False, False, True, False]

for k in range(5):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["models"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)
            results_peak["models"][i_w][i_shift] = wc_controlled

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                
                factor = 1.1
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,1500:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = results_peak["models"][i_w][i_shift]
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.039234340785853375
# Converged in iteration 82 with cost 0.02426663264057935 because of step counter
# Final cost : 0.02426663264057935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02426663264057935
# Converged in iteration 1 with cost 0.02426663264057935 because of step counter
# Final cost : 0.02426663264057935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02426663264057935
# Converged in iteration 1 with cost 0.02426663264057935 because of step counter
# Final cost : 0.02426663264057935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02426663264057935
# Converged in iteration 1 with cost 0.02426663264057935 because of step counter
# Final cost : 0.02426663264057935
# Compute control for a deterministic system
# Cost in iteration 0: 0.02426663264057935
# Converged in iteration 1 with cost 0.02426663264057935 because of step counter
# Final cost : 0.02426663264057935
# Compute control for a deterministic system
# Cost in iteration 0: 0.0555770218651763
# Converged in iteration 87 with cost 0.036413750998838805 because of step counter
# Final cost : 0.036413750998838805
# Compute control for a deterministic system
# Cost in iteration 0: 0.036413750998838805
# Converged in iteration 1 with cost 0.036413750998838805 because of step counter
# Final cost : 0.036413750998838805
# Compute control for a deterministic system
# Cost in iteration 0: 0.036413750998838805
# Converged in iteration 1 with cost 0.036413750998838805 because of step counter
# Final cost : 0.036413750998838805
# Compute control for a deterministic system
# Cost in iteration 0: 0.036413750998838805
# Converged in iteration 1 with cost 0.036413750998838805 because of step counter
# Final cost : 0.036413750998838805
# Compute control for a deterministic system
# Cost in iteration 0: 0.036413750998838805
# Converged in iteration 1 with cost 0.036413750998838805 because of step counter
# Final cost : 0.036413750998838805
# Compute control for a deterministic system
# Cost in iteration 0: 0.05876191829975569
# Converged in iteration 95 with cost 0.04563442022132208 because of step counter
# Final cost : 0.04563442022132208
# Compute control for a deterministic system
# Cost in iteration 0: 0.04563442022132208
# Converged in iteration 1 with cost 0.04563442022132208 because of step counter
# Final cost : 0.04563442022132208
# Compute control for a deterministic system
# Cost in iteration 0: 0.04563442022132208
# Converged in iteration 1 with cost 0.04563442022132208 because of step counter
# Final cost : 0.04563442022132208
# Compute control for a deterministic system
# Cost in iteration 0: 0.04563442022132208
# Converged in iteration 1 with cost 0.04563442022132208 because of step counter
# Final cost : 0.04563442022132208
# Compute control for a deterministic system
# Cost in iteration 0: 0.04563442022132208
# Converged in iteration 1 with cost 0.04563442022132208 because of step counter
# Final cost : 0.04563442022132208
# Compute control for a deterministic system
# Cost in iteration 0: 0.06238377407232581
# Converged in iteration 98 with cost 0.054378760314388284 because of step counter
# Final cost : 0.054378760314388284
# Compute control for a deterministic system
# Cost in iteration 0: 0.054378760314388284
# Converged in iteration 1 with cost 0.054378760314388284 because of step counter
# Final cost : 0.054378760314388284
# Compute control for a deterministic system
# Cost in iteration 0: 0.054378760314388284
# Converged in iteration 1 with cost 0.054378760314388284 because of step counter
# Final cost : 0.054378760314388284
# Compute control for a deterministic system
# Cost in iteration 0: 0.054378760314388284
# Converged in iteration 1 with cost 0.054378760314388284 because of step counter
# Final cost : 0.054378760314388284
# Compute control for a deterministic system
# Cost in iteration 0: 0.054378760314388284
# Converged in iteration 1 with cost 0.054378760314388284 because of step counter
# Final cost : 0.054378760314388284
# Compute control for a deterministic system
# Cost in iteration 0: 0.05945107982113217
# Converged in iteration 96 with cost 0.05835488692625633 because of step counter
# Final cost : 0.05835488692625633
# Compute control for a deterministic system
# Cost in iteration 0: 0.05835488692625633
# Converged in iteration 2 with cost 0.05835488692625616 because of step counter
# Final cost : 0.05835488692625616
# Compute control for a deterministic system
# Cost in iteration 0: 0.05835488692625616
# Converged in iteration 1 with cost 0.05835488692625616 because of step counter
# Final cost : 0.05835488692625616
# Compute control for a deterministic system
# Cost in iteration 0: 0.05835488692625616
# Converged in iteration 1 with cost 0.05835488692625616 because of step counter
# Final cost : 0.05835488692625616
# Compute control for a deterministic system
# Cost in iteration 0: 0.05835488692625616
# Converged in iteration 1 with cost 0.05835488692625616 because of step counter
# Final cost : 0.05835488692625616
# Compute control for a deterministic system
# Cost in iteration 0: 0.06967739751401136
# Converged in iteration 105 with cost 0.06743922364630907 because of step counter
# Final cost : 0.06743922364630907
# Compute control for a deterministic system
# Cost in iteration 0: 0.06743922364630907
# Converged in iteration 1 with cost 0.06743922364630907 because of step counter
# Final cost : 0.06743922364630907
# Compute control for a deterministic system
# Cost in iteration 0: 0.06743922364630907
# Converged in iteration 1 with cost 0.06743922364630907 because of step counter
# Final cost : 0.06743922364630907
# Compute control for a deterministic system
# Cost in iteration 0: 0.06743922364630907
# Converged in iteration 1 with cost 0.06743922364630907 because of step counter
# Final cost : 0.06743922364630907
# Compute control for a deterministic system
# Cost in iteration 0: 0.06743922364630907
# Converged in iteration 1 with cost 0.06743922364630907 because of step counter
# Final cost : 0.06743922364630907
# Compute control for a deterministic system
# Cost in iteration 0: 0.07473588192198163
# Converged in iteration 109 with cost 0.07358232784784541 because of step counter
# Final cost : 0.07358232784784541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07358232784784541
# Converged in iteration 1 with cost 0.07358232784784541 because of step counter
# Final cost : 0.07358232784784541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07358232784784541
# Converged in iteration 1 with cost 0.07358232784784541 because of step counter
# Final cost : 0.07358232784784541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07358232784784541
# Converged in iteration 1 with cost 0.07358232784784541 because of step counter
# Final cost : 0.07358232784784541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07358232784784541
# Converged in iteration 1 with cost 0.07358232784784541 because of step counter
# Final cost : 0.07358232784784541
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.08330361009102091
# Converged in iteration 104 with cost 0.08156472047262422 because of step counter
# Final cost : 0.08156472047262422
# Compute control for a deterministic system
# Cost in iteration 0: 0.08156472047262422
# Converged in iteration 1 with cost 0.08156472047262422 because of step counter
# Final cost : 0.08156472047262422
# Compute control for a deterministic system
# Cost in iteration 0: 0.08156472047262422
# Converged in iteration 1 with cost 0.08156472047262422 because of step counter
# Final cost : 0.08156472047262422
# Compute control for a deterministic system
# Cost in iteration 0: 0.08156472047262422
# Converged in iteration 1 with cost 0.08156472047262422 because of step counter
# Final cost : 0.08156472047262422
# Compute control for a deterministic system
# Cost in iteration 0: 0.08156472047262422
# Converged in iteration 1 with cost 0.08156472047262422 because of step counter
# Final cost : 0.08156472047262422
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.08707457495024827
# Converged in iteration 86 with cost 0.08666457201391241 because of step counter
# Final cost : 0.08666457201391241
# Compute control for a deterministic system
# Cost in iteration 0: 0.08666457201391241
# Converged in iteration 1 with cost 0.08666457201391241 because of step counter
# Final cost : 0.08666457201391241
# Compute control for a deterministic system
# Cost in iteration 0: 0.08666457201391241
# Converged in iteration 1 with cost 0.08666457201391241 because of step counter
# Final cost : 0.08666457201391241
# Compute control for a deterministic system
# Cost in iteration 0: 0.08666457201391241
# Converged in iteration 1 with cost 0.08666457201391241 because of step counter
# Final cost : 0.08666457201391241
# Compute control for a deterministic system
# Cost in iteration 0: 0.08666457201391241
# Converged in iteration 1 with cost 0.08666457201391241 because of step counter
# Final cost : 0.08666457201391241
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.10180544811880578
# Converged in iteration 183 with cost 0.09670070586850629 because of vanishing difference
# Final cost : 0.09670070586850629
# Compute control for a deterministic system
# Cost in iteration 0: 0.09670070586850629
# Converged in iteration 2 with cost 0.09670070586850617 because of step counter
# Final cost : 0.09670070586850617
# Compute control for a deterministic system
# Cost in iteration 0: 0.09670070586850617
# Converged in iteration 1 with cost 0.09670070586850617 because of step counter
# Final cost : 0.09670070586850617
# Compute control for a deterministic system
# Cost in iteration 0: 0.09670070586850617
# Converged in iteration 1 with cost 0.09670070586850617 because of step counter
# Final cost : 0.09670070586850617
# Compute control for a deterministic system
# Cost in iteration 0: 0.09670070586850617
# Converged in iteration 1 with cost 0.09670070586850617 because of step counter
# Final cost : 0.09670070586850617
# Compute control for a deterministic system
# Cost in iteration 0: 0.10082252128278328
# Cost in iteration 200: 0.0990952086889943
# Final cost : 0.0990952086889943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990952086889943
# Converged in iteration 1 with cost 0.0990952086889943 because of step counter
# Final cost : 0.0990952086889943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990952086889943
# Converged in iteration 1 with cost 0.0990952086889943 because of step counter
# Final cost : 0.0990952086889943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990952086889943
# Converged in iteration 1 with cost 0.0990952086889943 because of step counter
# Final cost : 0.0990952086889943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0990952086889943
# Converged in iteration 1 with cost 0.0990952086889943 because of step counter
# Final cost : 0.0990952086889943
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.10624650221741433
# Cost in iteration 200: 0.10394296593475226
# Final cost : 0.10394296593475226
# Compute control for a deterministic system
# Cost in iteration 0: 0.10394296593475226
# Converged in iteration 22 with cost 0.10354747199498728 because of step counter
# Final cost : 0.10354747199498728
# Compute control for a deterministic system
# Cost in iteration 0: 0.10354747199498728
# Converged in iteration 1 with cost 0.10354747199498728 because of step counter
# Final cost : 0.10354747199498728
# Compute control for a deterministic system
# Cost in iteration 0: 0.10354747199498728
# Converged in iteration 1 with cost 0.10354747199498728 because of step counter
# Final cost : 0.10354747199498728
# Compute control for a deterministic system
# Cost in iteration 0: 0.10354747199498728
# Converged in iteration 1 with cost 0.10354747199498728 because of step counter
# Final cost : 0.10354747199498728
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.11326990679594379
# Cost in iteration 200: 0.11104301082093623
# Final cost : 0.11104301082093623
# Compute control for a deterministic system
# Cost in iteration 0: 0.11104301082093623
# Converged in iteration 38 with cost 0.11071747266002817 because of step counter
# Final cost : 0.11071747266002817
# Compute control for a deterministic system
# Cost in iteration 0: 0.11071747266002817
# Converged in iteration 1 with cost 0.11071747266002817 because of step counter
# Final cost : 0.11071747266002817
# Compute control for a deterministic system
# Cost in iteration 0: 0.11071747266002817
# Converged in iteration 1 with cost 0.11071747266002817 because of step counter
# Final cost : 0.11071747266002817
# Compute control for a deterministic system
# Cost in iteration 0: 0.11071747266002817
# Converged in iteration 1 with cost 0.11071747266002817 because of step counter
# Final cost : 0.11071747266002817
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.11979820669952668
# Cost in iteration 200: 0.11859926316918686
# Final cost : 0.11859926316918686
# Compute control for a deterministic system
# Cost in iteration 0: 0.11859926316918686
# Converged in iteration 60 with cost 0.11806938753351855 because of step counter
# Final cost : 0.11806938753351855
# Compute control for a deterministic system
# Cost in iteration 0: 0.11806938753351855
# Converged in iteration 1 with cost 0.11806938753351855 because of step counter
# Final cost : 0.11806938753351855
# Compute control for a deterministic system
# Cost in iteration 0: 0.11806938753351855
# Converged in iteration 1 with cost 0.11806938753351855 because of step counter
# Final cost : 0.11806938753351855
# Compute control for a deterministic system
# Cost in iteration 0: 0.11806938753351855
# Converged in iteration 1 with cost 0.11806938753351855 because of step counter
# Final cost : 0.11806938753351855
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.1264932968208063
# Cost in iteration 200: 0.12421072677617251
# Final cost : 0.12421072677617251
# Compute control for a deterministic system
# Cost in iteration 0: 0.12421072677617251
# Converged in iteration 20 with cost 0.12386762660223899 because of step counter
# Final cost : 0.12386762660223899
# Compute control for a deterministic system
# Cost in iteration 0: 0.12386762660223899
# Converged in iteration 1 with cost 0.12386762660223899 because of step counter
# Final cost : 0.12386762660223899
# Compute control for a deterministic system
# Cost in iteration 0: 0.12386762660223899
# Converged in iteration 1 with cost 0.12386762660223899 because of step counter
# Final cost : 0.12386762660223899
# Compute control for a deterministic system
# Cost in iteration 0: 0.12386762660223899
# Converged in iteration 1 with cost 0.12386762660223899 because of step counter
# Final cost : 0.12386762660223899
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.13560490330966796
# Cost in iteration 200: 0.1320740384969769
# Final cost : 0.1320740384969769
# Compute control for a deterministic system
# Cost in iteration 0: 0.1320740384969769
# Converged in iteration 72 with cost 0.1313272594104768 because of step counter
# Final cost : 0.1313272594104768
# Compute control for a deterministic system
# Cost in iteration 0: 0.1313272594104768
# Converged in iteration 1 with cost 0.1313272594104768 because of step counter
# Final cost : 0.1313272594104768
# Compute control for a deterministic system
# Cost in iteration 0: 0.1313272594104768
# Converged in iteration 1 with cost 0.1313272594104768 because of step counter
# Final cost : 0.1313272594104768
# Compute control for a deterministic system
# Cost in iteration 0: 0.1313272594104768
# Converged in iteration 1 with cost 0.1313272594104768 because of step counter
# Final cost : 0.1313272594104768
# Compute control for a deterministic system
# Cost in iteration 0: 1.5052061910786674
# Converged in iteration 2 with cost 0.14163284495154335 because of step counter
# Final cost : 0.14163284495154335
# Compute control for a deterministic system
# Cost in iteration 0: 0.14163284495154335
# Converged in iteration 1 with cost 0.14163284495154335 because of step counter
# Final cost : 0.14163284495154335
# Compute control for a deterministic system
# Cost in iteration 0: 0.14163284495154335
# Converged in iteration 1 with cost 0.14163284495154335 because of step counter
# Final cost : 0.14163284495154335
# Compute control for a deterministic system
# Cost in iteration 0: 0.14163284495154335
# Converged in iteration 1 with cost 0.14163284495154335 because of step counter
# Final cost : 0.14163284495154335
# Compute control for a deterministic system
# Cost in iteration 0: 0.14163284495154335
# Converged in iteration 1 with cost 0.14163284495154335 because of step counter
# Final cost : 0.14163284495154335
# Compute control for a deterministic system
# Cost in iteration 0: 1.9788455361687411
# Converged in iteration 23 with cost 0.15662996996666975 because of step counter
# Final cost : 0.15662996996666975
# Compute control for a deterministic system
# Cost in iteration 0: 0.15662996996666975
# Converged in iteration 1 with cost 0.15662996996666975 because of step counter
# Final cost : 0.15662996996666975
# Compute control for a deterministic system
# Cost in iteration 0: 0.15662996996666975
# Converged in iteration 1 with cost 0.15662996996666975 because of step counter
# Final cost : 0.15662996996666975
# Compute control for a deterministic system
# Cost in iteration 0: 0.15662996996666975
# Converged in iteration 1 with cost 0.15662996996666975 because of step counter
# Final cost : 0.15662996996666975
# Compute control for a deterministic system
# Cost in iteration 0: 0.15662996996666975
# Converged in iteration 1 with cost 0.15662996996666975 because of step counter
# Final cost : 0.15662996996666975
# Compute control for a deterministic system
# Cost in iteration 0: 2.1318164951951384
# Cost in iteration 200: 0.18245324636321766
# Final cost : 0.18245324636321766
# Compute control for a deterministic system
# Cost in iteration 0: 0.18245324636321766
# Converged in iteration 49 with cost 0.18230650827102204 because of step counter
# Final cost : 0.18230650827102204
# Compute control for a deterministic system
# Cost in iteration 0: 0.18230650827102204
# Converged in iteration 1 with cost 0.18230650827102204 because of step counter
# Final cost : 0.18230650827102204
# Compute control for a deterministic system
# Cost in iteration 0: 0.18230650827102204
# Converged in iteration 1 with cost 0.18230650827102204 because of step counter
# Final cost : 0.18230650827102204
# Compute control for a deterministic system
# Cost in iteration 0: 0.18230650827102204
# Converged in iteration 1 with cost 0.18230650827102204 because of step counter
# Final cost : 0.18230650827102204
# Compute control for a deterministic system
# Cost in iteration 0: 0.1806889089629548
# Cost in iteration 200: 0.13804607761923685
# Final cost : 0.13804607761923685
# Compute control for a deterministic system
# Cost in iteration 0: 0.13804607761923685
# Converged in iteration 23 with cost 0.1374656884327002 because of step counter
# Final cost : 0.1374656884327002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1374656884327002
# Converged in iteration 1 with cost 0.1374656884327002 because of step counter
# Final cost : 0.1374656884327002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1374656884327002
# Converged in iteration 1 with cost 0.1374656884327002 because of step counter
# Final cost : 0.1374656884327002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1374656884327002
# Converged in iteration 1 with cost 0.1374656884327002 because of step counter
# Final cost : 0.1374656884327002
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.17841513499106865
# Converged in iteration 3 with cost 0.1375930229515508 because of step counter
# Final cost : 0.1375930229515508
# Compute control for a deterministic system
# Cost in iteration 0: 0.1375930229515508
# Converged in iteration 1 with cost 0.1375930229515508 because of step counter
# Final cost : 0.1375930229515508
# Compute control for a deterministic system
# Cost in iteration 0: 0.1375930229515508
# Converged in iteration 1 with cost 0.1375930229515508 because of step counter
# Final cost : 0.1375930229515508
# Compute control for a deterministic system
# Cost in iteration 0: 0.1375930229515508
# Converged in iteration 1 with cost 0.1375930229515508 because of step counter
# Final cost : 0.1375930229515508
# Compute control for a deterministic system
# Cost in iteration 0: 0.1375930229515508
# Converged in iteration 1 with cost 0.1375930229515508 because of step counter
# Final cost : 0.1375930229515508
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.17850880731872926
# Converged in iteration 2 with cost 0.1380830348069228 because of step counter
# Final cost : 0.1380830348069228
# Compute control for a deterministic system
# Cost in iteration 0: 0.1380830348069228
# Converged in iteration 1 with cost 0.1380830348069228 because of step counter
# Final cost : 0.1380830348069228
# Compute control for a deterministic system
# Cost in iteration 0: 0.1380830348069228
# Converged in iteration 1 with cost 0.1380830348069228 because of step counter
# Final cost : 0.1380830348069228
# Compute control for a deterministic system
# Cost in iteration 0: 0.1380830348069228
# Converged in iteration 1 with cost 0.1380830348069228 because of step counter
# Final cost : 0.1380830348069228
# Compute control for a deterministic system
# Cost in iteration 0: 0.1380830348069228
# Converged in iteration 1 with cost 0.1380830348069228 because of step counter
# Final cost : 0.1380830348069228
# Compute control for a deterministic system
# Cost in iteration 0: 0.15960108337897244
# Cost in iteration 200: 0.13267084244142568
# Final cost : 0.13267084244142568
# Compute control for a deterministic system
# Cost in iteration 0: 0.13267084244142568
# Converged in iteration 62 with cost 0.13250407681373005 because of step counter
# Final cost : 0.13250407681373005
# Compute control for a deterministic system
# Cost in iteration 0: 0.13250407681373005
# Converged in iteration 1 with cost 0.13250407681373005 because of step counter
# Final cost : 0.13250407681373005
# Compute control for a deterministic system
# Cost in iteration 0: 0.13250407681373005
# Converged in iteration 1 with cost 0.13250407681373005 because of step counter
# Final cost : 0.13250407681373005
# Compute control for a deterministic system
# Cost in iteration 0: 0.13250407681373005
# Converged in iteration 1 with cost 0.13250407681373005 because of step counter
# Final cost : 0.13250407681373005
# Compute control for a deterministic system
# Cost in iteration 0: 0.16807651188882214
# Cost in iteration 200: 0.12802967397764836
# Final cost : 0.12802967397764836
# Compute control for a deterministic system
# Cost in iteration 0: 0.12802967397764836
# Cost in iteration 200: 0.12659332419400462
# Final cost : 0.12659332419400462
# Compute control for a deterministic system
# Cost in iteration 0: 0.12659332419400462
# Converged in iteration 10 with cost 0.12646379571209942 because of step counter
# Final cost : 0.12646379571209942
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646379571209942
# Converged in iteration 1 with cost 0.12646379571209942 because of step counter
# Final cost : 0.12646379571209942
# Compute control for a deterministic system
# Cost in iteration 0: 0.12646379571209942
# Converged in iteration 1 with cost 0.12646379571209942 because of step counter
# Final cost : 0.12646379571209942
# Compute control for a deterministic system
# Cost in iteration 0: 0.1612144618956996
# Cost in iteration 200: 0.12045070681370014
# Final cost : 0.12045070681370014
# Compute control for a deterministic system
# Cost in iteration 0: 0.12045070681370014
# Cost in iteration 200: 0.1190543969409691
# Final cost : 0.1190543969409691
# Compute control for a deterministic system
# Cost in iteration 0: 0.1190543969409691
# Converged in iteration 10 with cost 0.1189162202051685 because of step counter
# Final cost : 0.1189162202051685
# Compute control for a deterministic system
# Cost in iteration 0: 0.1189162202051685
# Converged in iteration 1 with cost 0.1189162202051685 because of step counter
# Final cost : 0.1189162202051685
# Compute control for a deterministic system
# Cost in iteration 0: 0.1189162202051685
# Converged in iteration 1 with cost 0.1189162202051685 because of step counter
# Final cost : 0.1189162202051685
# Compute control for a deterministic system
# Cost in iteration 0: 0.15425012885232903
# Cost in iteration 200: 0.11255318081331873
# Final cost : 0.11255318081331873
# Compute control for a deterministic system
# Cost in iteration 0: 0.11255318081331873
# Cost in iteration 200: 0.1111863701880107
# Final cost : 0.1111863701880107
# Compute control for a deterministic system
# Cost in iteration 0: 0.1111863701880107
# Converged in iteration 12 with cost 0.11105799447494122 because of step counter
# Final cost : 0.11105799447494122
# Compute control for a deterministic system
# Cost in iteration 0: 0.11105799447494122
# Converged in iteration 1 with cost 0.11105799447494122 because of step counter
# Final cost : 0.11105799447494122
# Compute control for a deterministic system
# Cost in iteration 0: 0.11105799447494122
# Converged in iteration 1 with cost 0.11105799447494122 because of step counter
# Final cost : 0.11105799447494122
# Compute control for a deterministic system
# Cost in iteration 0: 0.13159238044813
# Cost in iteration 200: 0.10298888160365656
# Final cost : 0.10298888160365656
# Compute control for a deterministic system
# Cost in iteration 0: 0.10298888160365656
# Converged in iteration 13 with cost 0.10252643240429118 because of step counter
# Final cost : 0.10252643240429118
# Compute control for a deterministic system
# Cost in iteration 0: 0.10252643240429118
# Converged in iteration 1 with cost 0.10252643240429118 because of step counter
# Final cost : 0.10252643240429118
# Compute control for a deterministic system
# Cost in iteration 0: 0.10252643240429118
# Converged in iteration 1 with cost 0.10252643240429118 because of step counter
# Final cost : 0.10252643240429118
# Compute control for a deterministic system
# Cost in iteration 0: 0.10252643240429118
# Converged in iteration 1 with cost 0.10252643240429118 because of step counter
# Final cost : 0.10252643240429118
# Compute control for a deterministic system
# Cost in iteration 0: 0.14106929912518815
# Cost in iteration 200: 0.09824630651937234
# Final cost : 0.09824630651937234
# Compute control for a deterministic system
# Cost in iteration 0: 0.09824630651937234
# Cost in iteration 200: 0.09669654328592198
# Final cost : 0.09669654328592198
# Compute control for a deterministic system
# Cost in iteration 0: 0.09669654328592198
# Converged in iteration 29 with cost 0.09659462248860208 because of step counter
# Final cost : 0.09659462248860208
# Compute control for a deterministic system
# Cost in iteration 0: 0.09659462248860208
# Converged in iteration 1 with cost 0.09659462248860208 because of step counter
# Final cost : 0.09659462248860208
# Compute control for a deterministic system
# Cost in iteration 0: 0.09659462248860208
# Converged in iteration 1 with cost 0.09659462248860208 because of step counter
# Final cost : 0.09659462248860208
# Compute control for a deterministic system
# Cost in iteration 0: 0.13302376261167764
# Cost in iteration 200: 0.08995629015859197
# Final cost : 0.08995629015859197
# Compute control for a deterministic system
# Cost in iteration 0: 0.08995629015859197
# Cost in iteration 200: 0.08817122913090568
# Final cost : 0.08817122913090568
# Compute control for a deterministic system
# Cost in iteration 0: 0.08817122913090568
# Converged in iteration 16 with cost 0.08808042326163523 because of step counter
# Final cost : 0.08808042326163523
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808042326163523
# Converged in iteration 1 with cost 0.08808042326163523 because of step counter
# Final cost : 0.08808042326163523
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808042326163523
# Converged in iteration 1 with cost 0.08808042326163523 because of step counter
# Final cost : 0.08808042326163523
# Compute control for a deterministic system
# Cost in iteration 0: 0.10894038951441834
# Cost in iteration 200: 0.07974427918235551
# Final cost : 0.07974427918235551
# Compute control for a deterministic system
# Cost in iteration 0: 0.07974427918235551
# Converged in iteration 32 with cost 0.07914231107589655 because of step counter
# Final cost : 0.07914231107589655
# Compute control for a deterministic system
# Cost in iteration 0: 0.07914231107589655
# Converged in iteration 1 with cost 0.07914231107589655 because of step counter
# Final cost : 0.07914231107589655
# Compute control for a deterministic system
# Cost in iteration 0: 0.07914231107589655
# Converged in iteration 1 with cost 0.07914231107589655 because of step counter
# Final cost : 0.07914231107589655
# Compute control for a deterministic system
# Cost in iteration 0: 0.07914231107589655
# Converged in iteration 1 with cost 0.07914231107589655 because of step counter
# Final cost : 0.07914231107589655
# Compute control for a deterministic system
# Cost in iteration 0: 0.11836906306336065
# Cost in iteration 200: 0.07467180785065018
# Final cost : 0.07467180785065018
# Compute control for a deterministic system
# Cost in iteration 0: 0.07467180785065018
# Cost in iteration 200: 0.07243957261493442
# Final cost : 0.07243957261493442
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243957261493442
# Converged in iteration 18 with cost 0.07238382706146307 because of step counter
# Final cost : 0.07238382706146307
# Compute control for a deterministic system
# Cost in iteration 0: 0.07238382706146307
# Converged in iteration 1 with cost 0.07238382706146307 because of step counter
# Final cost : 0.07238382706146307
# Compute control for a deterministic system
# Cost in iteration 0: 0.07238382706146307
# Converged in iteration 1 with cost 0.07238382706146307 because of step counter
# Final cost : 0.07238382706146307
# Compute control for a deterministic system
# Cost in iteration 0: 0.10996134889009296
# Cost in iteration 200: 0.06459294085856887
# Final cost : 0.06459294085856887
# Compute control for a deterministic system
# Cost in iteration 0: 0.06459294085856887
# Cost in iteration 200: 0.06020532882759833
# Final cost : 0.06020532882759833
# Compute control for a deterministic system
# Cost in iteration 0: 0.06020532882759833
# Converged in iteration 25 with cost 0.06019809930817562 because of step counter
# Final cost : 0.06019809930817562
# Compute control for a deterministic system
# Cost in iteration 0: 0.06019809930817562
# Converged in iteration 1 with cost 0.06019809930817562 because of step counter
# Final cost : 0.06019809930817562
# Compute control for a deterministic system
# Cost in iteration 0: 0.06019809930817562
# Converged in iteration 1 with cost 0.06019809930817562 because of step counter
# Final cost : 0.06019809930817562
# Compute control for a deterministic system
# Cost in iteration 0: 0.10126754038239472
# Cost in iteration 200: 0.05500707724213295
# Final cost : 0.05500707724213295
# Compute control for a deterministic system
# Cost in iteration 0: 0.05500707724213295
# Cost in iteration 200: 0.051382354989245364
# Final cost : 0.051382354989245364
# Compute control for a deterministic system
# Cost in iteration 0: 0.051382354989245364
# Converged in iteration 50 with cost 0.05138179811065508 because of vanishing difference
# Final cost : 0.05138179811065508
# Compute control for a deterministic system
# Cost in iteration 0: 0.05138179811065501
# Converged in iteration 1 with cost 0.05138179811065501 because of vanishing difference
# Final cost : 0.05138179811065501
# Compute control for a deterministic system
# Cost in iteration 0: 0.05138179811065501
# Converged in iteration 1 with cost 0.05138179811065501 because of step counter
# Final cost : 0.05138179811065501
# Compute control for a deterministic system
# Cost in iteration 0: 0.07637189557287297
# Cost in iteration 200: 0.046106533565847825
# Final cost : 0.046106533565847825
# Compute control for a deterministic system
# Cost in iteration 0: 0.046106533565847825
# Converged in iteration 52 with cost 0.04376329940270262 because of step counter
# Final cost : 0.04376329940270262
# Compute control for a deterministic system
# Cost in iteration 0: 0.04376329940270262
# Converged in iteration 1 with cost 0.04376329940270262 because of step counter
# Final cost : 0.04376329940270262
# Compute control for a deterministic system
# Cost in iteration 0: 0.04376329940270262
# Converged in iteration 1 with cost 0.04376329940270262 because of step counter
# Final cost : 0.04376329940270262
# Compute control for a deterministic system
# Cost in iteration 0: 0.04376329940270262
# Converged in iteration 1 with cost 0.04376329940270262 because of step counter
# Final cost : 0.04376329940270262
# Compute control for a deterministic system
# Cost in iteration 0: 0.08507664666375298
# Cost in iteration 200: 0.03951435446527546
# Final cost : 0.03951435446527546
# Compute control for a deterministic system
# Cost in iteration 0: 0.03951435446527546
# Converged in iteration 59 with cost 0.03472895563817414 because of step counter
# Final cost : 0.03472895563817414
# Compute control for a deterministic system
# Cost in iteration 0: 0.03472895563817414
# Converged in iteration 1 with cost 0.03472895563817414 because of step counter
# Final cost : 0.03472895563817414
# Compute control for a deterministic system
# Cost in iteration 0: 0.03472895563817414
# Converged in iteration 1 with cost 0.03472895563817414 because of step counter
# Final cost : 0.03472895563817414
# Compute control for a deterministic system
# Cost in iteration 0: 0.03472895563817414
# Converged in iteration 1 with cost 0.03472895563817414 because of step counter
# Final cost : 0.03472895563817414
# Compute control for a deterministic system
# Cost in iteration 0: 0.07512302279581505
# Cost in iteration 200: 0.03073323447648245
# Final cost : 0.03073323447648245
# Compute control for a deterministic system
# Cost in iteration 0: 0.03073323447648245
# Converged in iteration 54 with cost 0.02517091962200041 because of step counter
# Final cost : 0.02517091962200041
# Compute control for a deterministic system
# Cost in iteration 0: 0.02517091962200041
# Converged in iteration 1 with cost 0.02517091962200041 because of step counter
# Final cost : 0.02517091962200041
# Compute control for a deterministic system
# Cost in iteration 0: 0.02517091962200041
# Converged in iteration 1 with cost 0.02517091962200041 because of step counter
# Final cost : 0.02517091962200041
# Compute control for a deterministic system
# Cost in iteration 0: 0.02517091962200041
# Converged in iteration 1 with cost 0.02517091962200041 because of step counter
# Final cost : 0.02517091962200041
# Compute control for a deterministic system
# Cost in iteration 0: 0.0639641905481568
# Cost in iteration 200: 0.0220721197251269
# Final cost : 0.0220721197251269
# Compute control for a deterministic system
# Cost in iteration 0: 0.0220721197251269
# Converged in iteration 47 with cost 0.015535090032432638 because of step counter
# Final cost : 0.015535090032432638
# Compute control for a deterministic system
# Cost in iteration 0: 0.015535090032432638
# Converged in iteration 1 with cost 0.015535090032432638 because of step counter
# Final cost : 0.015535090032432638
# Compute control for a deterministic system
# Cost in iteration 0: 0.015535090032432638
# Converged in iteration 1 with cost 0.015535090032432638 because of step counter
# Final cost : 0.015535090032432638
# Compute control for a deterministic system
# Cost in iteration 0: 0.015535090032432638
# Converged in iteration 1 with cost 0.015535090032432638 because of step counter
# Final cost : 0.015535090032432638
# Compute control for a deterministic system
# Cost in iteration 0: 0.038127364337285294
# Cost in iteration 200: 0.010907326080273061
# Final cost : 0.010907326080273061
# Compute control for a deterministic system
# Cost in iteration 0: 0.010907326080273061
# Converged in iteration 29 with cost 0.00797210794124463 because of step counter
# Final cost : 0.00797210794124463
# Compute control for a deterministic system
# Cost in iteration 0: 0.00797210794124463
# Converged in iteration 1 with cost 0.00797210794124463 because of step counter
# Final cost : 0.00797210794124463
# Compute control for a deterministic system
# Cost in iteration 0: 0.00797210794124463
# Converged in iteration 1 with cost 0.00797210794124463 because of step counter
# Final cost : 0.00797210794124463
# Compute control for a deterministic system
# Cost in iteration 0: 0.00797210794124463
# Converged in iteration 1 with cost 0.00797210794124463 because of step counter
# Final cost : 0.00797210794124463
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.03995553642961317
# Converged in iteration 23 with cost 0.023192868961859296 because of step counter
# Final cost : 0.023192868961859296
# Compute control for a deterministic system
# Cost in iteration 0: 0.023192868961859296
# Converged in iteration 1 with cost 0.023192868961859296 because of step counter
# Final cost : 0.023192868961859296
# Compute control for a deterministic system
# Cost in iteration 0: 0.023192868961859296
# Converged in iteration 1 with cost 0.023192868961859296 because of step counter
# Final cost : 0.023192868961859296
# Compute control for a deterministic system
# Cost in iteration 0: 0.023192868961859296
# Converged in iteration 1 with cost 0.023192868961859296 because of step counter
# Final cost : 0.023192868961859296
# Compute control for a deterministic system
# Cost in iteration 0: 0.05695528749966451
# Converged in iteration 74 with cost 0.03467194940528909 because of step counter
# Final cost : 0.03467194940528909
# Compute control for a deterministic system
# Cost in iteration 0: 0.03467194940528909
# Converged in iteration 1 with cost 0.03467194940528909 because of step counter
# Final cost : 0.03467194940528909
# Compute control for a deterministic system
# Cost in iteration 0: 0.03467194940528909
# Converged in iteration 1 with cost 0.03467194940528909 because of step counter
# Final cost : 0.03467194940528909
# Compute control for a deterministic system
# Cost in iteration 0: 0.03467194940528909
# Converged in iteration 1 with cost 0.03467194940528909 because of step counter
# Final cost : 0.03467194940528909
# Compute control for a deterministic system
# Cost in iteration 0: 0.057722854078039273
# Converged in iteration 12 with cost 0.03993257334943255 because of step counter
# Final cost : 0.03993257334943255
# Compute control for a deterministic system
# Cost in iteration 0: 0.03993257334943255
# Converged in iteration 1 with cost 0.03993257334943255 because of step counter
# Final cost : 0.03993257334943255
# Compute control for a deterministic system
# Cost in iteration 0: 0.03993257334943255
# Converged in iteration 1 with cost 0.03993257334943255 because of step counter
# Final cost : 0.03993257334943255
# Compute control for a deterministic system
# Cost in iteration 0: 0.03993257334943255
# Converged in iteration 1 with cost 0.03993257334943255 because of step counter
# Final cost : 0.03993257334943255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0582014314599226
# Converged in iteration 10 with cost 0.046360875194957074 because of step counter
# Final cost : 0.046360875194957074
# Compute control for a deterministic system
# Cost in iteration 0: 0.046360875194957074
# Converged in iteration 1 with cost 0.046360875194957074 because of step counter
# Final cost : 0.046360875194957074
# Compute control for a deterministic system
# Cost in iteration 0: 0.046360875194957074
# Converged in iteration 1 with cost 0.046360875194957074 because of step counter
# Final cost : 0.046360875194957074
# Compute control for a deterministic system
# Cost in iteration 0: 0.046360875194957074
# Converged in iteration 1 with cost 0.046360875194957074 because of step counter
# Final cost : 0.046360875194957074
# Compute control for a deterministic system
# Cost in iteration 0: 0.05233579799999236
# Converged in iteration 9 with cost 0.05050637533315824 because of step counter
# Final cost : 0.05050637533315824
# Compute control for a deterministic system
# Cost in iteration 0: 0.05050637533315824
# Converged in iteration 1 with cost 0.05050637533315824 because of step counter
# Final cost : 0.05050637533315824
# Compute control for a deterministic system
# Cost in iteration 0: 0.05050637533315824
# Converged in iteration 1 with cost 0.05050637533315824 because of step counter
# Final cost : 0.05050637533315824
# Compute control for a deterministic system
# Cost in iteration 0: 0.05050637533315824
# Converged in iteration 1 with cost 0.05050637533315824 because of step counter
# Final cost : 0.05050637533315824
# Compute control for a deterministic system
# Cost in iteration 0: 0.06400676096060434
# Converged in iteration 10 with cost 0.05996078391460029 because of step counter
# Final cost : 0.05996078391460029
# Compute control for a deterministic system
# Cost in iteration 0: 0.05996078391460029
# Converged in iteration 1 with cost 0.05996078391460029 because of step counter
# Final cost : 0.05996078391460029
# Compute control for a deterministic system
# Cost in iteration 0: 0.05996078391460029
# Converged in iteration 1 with cost 0.05996078391460029 because of step counter
# Final cost : 0.05996078391460029
# Compute control for a deterministic system
# Cost in iteration 0: 0.05996078391460029
# Converged in iteration 1 with cost 0.05996078391460029 because of step counter
# Final cost : 0.05996078391460029
# Compute control for a deterministic system
# Cost in iteration 0: 0.06869280040602195
# Converged in iteration 9 with cost 0.06742363050207266 because of step counter
# Final cost : 0.06742363050207266
# Compute control for a deterministic system
# Cost in iteration 0: 0.06742363050207266
# Converged in iteration 1 with cost 0.06742363050207266 because of step counter
# Final cost : 0.06742363050207266
# Compute control for a deterministic system
# Cost in iteration 0: 0.06742363050207266
# Converged in iteration 1 with cost 0.06742363050207266 because of step counter
# Final cost : 0.06742363050207266
# Compute control for a deterministic system
# Cost in iteration 0: 0.06742363050207266
# Converged in iteration 1 with cost 0.06742363050207266 because of step counter
# Final cost : 0.06742363050207266
# -----------------------------------------------
# 1 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.07985695315561114
# Converged in iteration 9 with cost 0.07805156632586775 because of step counter
# Final cost : 0.07805156632586775
# Compute control for a deterministic system
# Cost in iteration 0: 0.07805156632586775
# Converged in iteration 1 with cost 0.07805156632586775 because of step counter
# Final cost : 0.07805156632586775
# Compute control for a deterministic system
# Cost in iteration 0: 0.07805156632586775
# Converged in iteration 1 with cost 0.07805156632586775 because of step counter
# Final cost : 0.07805156632586775
# Compute control for a deterministic system
# Cost in iteration 0: 0.07805156632586775
# Converged in iteration 1 with cost 0.07805156632586775 because of step counter
# Final cost : 0.07805156632586775
# Compute control for a deterministic system
# Cost in iteration 0: 0.08718238162341597
# Converged in iteration 76 with cost 0.0828401821857044 because of step counter
# Final cost : 0.0828401821857044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828401821857044
# Converged in iteration 1 with cost 0.0828401821857044 because of step counter
# Final cost : 0.0828401821857044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828401821857044
# Converged in iteration 1 with cost 0.0828401821857044 because of step counter
# Final cost : 0.0828401821857044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828401821857044
# Converged in iteration 1 with cost 0.0828401821857044 because of step counter
# Final cost : 0.0828401821857044
# Compute control for a deterministic system
# Cost in iteration 0: 0.09319914356082602
# Converged in iteration 55 with cost 0.0910042093331561 because of step counter
# Final cost : 0.0910042093331561
# Compute control for a deterministic system
# Cost in iteration 0: 0.0910042093331561
# Converged in iteration 1 with cost 0.0910042093331561 because of step counter
# Final cost : 0.0910042093331561
# Compute control for a deterministic system
# Cost in iteration 0: 0.0910042093331561
# Converged in iteration 1 with cost 0.0910042093331561 because of step counter
# Final cost : 0.0910042093331561
# Compute control for a deterministic system
# Cost in iteration 0: 0.0910042093331561
# Converged in iteration 1 with cost 0.0910042093331561 because of step counter
# Final cost : 0.0910042093331561
# -----------------------------------------------
# 1 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.10074961735582799
# Converged in iteration 48 with cost 0.10047285156993005 because of step counter
# Final cost : 0.10047285156993005
# Compute control for a deterministic system
# Cost in iteration 0: 0.10047285156993005
# Converged in iteration 1 with cost 0.10047285156993005 because of step counter
# Final cost : 0.10047285156993005
# Compute control for a deterministic system
# Cost in iteration 0: 0.10047285156993005
# Converged in iteration 1 with cost 0.10047285156993005 because of step counter
# Final cost : 0.10047285156993005
# Compute control for a deterministic system
# Cost in iteration 0: 0.10047285156993005
# Converged in iteration 1 with cost 0.10047285156993005 because of step counter
# Final cost : 0.10047285156993005
# Compute control for a deterministic system
# Cost in iteration 0: 0.1272894652295506
# Converged in iteration 113 with cost 0.10563432001971818 because of step counter
# Final cost : 0.10563432001971818
# Compute control for a deterministic system
# Cost in iteration 0: 0.10563432001971818
# Converged in iteration 1 with cost 0.10563432001971818 because of step counter
# Final cost : 0.10563432001971818
# Compute control for a deterministic system
# Cost in iteration 0: 0.10563432001971818
# Converged in iteration 1 with cost 0.10563432001971818 because of step counter
# Final cost : 0.10563432001971818
# Compute control for a deterministic system
# Cost in iteration 0: 0.10563432001971818
# Converged in iteration 1 with cost 0.10563432001971818 because of step counter
# Final cost : 0.10563432001971818
# -----------------------------------------------
# 1 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.11862910333533914
# Converged in iteration 74 with cost 0.11450208703586194 because of step counter
# Final cost : 0.11450208703586194
# Compute control for a deterministic system
# Cost in iteration 0: 0.11450208703586194
# Converged in iteration 1 with cost 0.11450208703586194 because of step counter
# Final cost : 0.11450208703586194
# Compute control for a deterministic system
# Cost in iteration 0: 0.11450208703586194
# Converged in iteration 1 with cost 0.11450208703586194 because of step counter
# Final cost : 0.11450208703586194
# Compute control for a deterministic system
# Cost in iteration 0: 0.11450208703586194
# Converged in iteration 1 with cost 0.11450208703586194 because of step counter
# Final cost : 0.11450208703586194
# Compute control for a deterministic system
# Cost in iteration 0: 0.1428797557398085
# Converged in iteration 88 with cost 0.12141729388135497 because of step counter
# Final cost : 0.12141729388135497
# Compute control for a deterministic system
# Cost in iteration 0: 0.12141729388135497
# Converged in iteration 1 with cost 0.12141729388135497 because of step counter
# Final cost : 0.12141729388135497
# Compute control for a deterministic system
# Cost in iteration 0: 0.12141729388135497
# Converged in iteration 1 with cost 0.12141729388135497 because of step counter
# Final cost : 0.12141729388135497
# ...
# Cost in iteration 0: 0.6087388057977879
# Converged in iteration 1 with cost 0.6087388057977879 because of step counter
# Final cost : 0.6087388057977879
# Compute control for a deterministic system
# Cost in iteration 0: 0.6087388057977879
# Converged in iteration 1 with cost 0.6087388057977879 because of step counter
# Final cost : 0.6087388057977879
# Compute control for a deterministic system
# Cost in iteration 0: 0.6087388057977879
# Converged in iteration 1 with cost 0.6087388057977879 because of step counter
# Final cost : 0.6087388057977879
# Compute control for a deterministic system
# Cost in iteration 0: 0.6087388057977879
# Converged in iteration 1 with cost 0.6087388057977879 because of step counter
# Final cost : 0.6087388057977879
# Compute control for a deterministic system
# Cost in iteration 0: 1.0582336239177927
# Cost in iteration 200: 0.9762875176653302
# Final cost : 0.9762875176653302
# Compute control for a deterministic system
# Cost in iteration 0: 0.9762875176653302
# Cost in iteration 200: 0.7519735664082687
# Final cost : 0.7519735664082687
# Compute control for a deterministic system
# Cost in iteration 0: 0.7519735664082687
# Converged in iteration 56 with cost 0.7509355747565275 because of vanishing difference
# Final cost : 0.7509355747565275
# Compute control for a deterministic system
# Cost in iteration 0: 0.75093557475385
# Converged in iteration 2 with cost 0.750935574734683 because of vanishing difference
# Final cost : 0.750935574734683
# Compute control for a deterministic system
# Cost in iteration 0: 0.7509355747346826
# Converged in iteration 1 with cost 0.7509355747346826 because of step counter
# Final cost : 0.7509355747346826
# Compute control for a deterministic system
# Cost in iteration 0: 1.2513920227221613
# Cost in iteration 200: 1.1566986279993605
# Final cost : 1.1566986279993605
# Compute control for a deterministic system
# Cost in iteration 0: 1.1566986279993605
# Cost in iteration 200: 0.8026674457728381
# Final cost : 0.8026674457728381
# Compute control for a deterministic system
# Cost in iteration 0: 0.8026674457728381
# Converged in iteration 78 with cost 0.7990696986248378 because of vanishing difference
# Final cost : 0.7990696986248378
# Compute control for a deterministic system
# Cost in iteration 0: 0.7990696986226543
# Converged in iteration 2 with cost 0.7990696986057295 because of vanishing difference
# Final cost : 0.7990696986057295
# Compute control for a deterministic system
# Cost in iteration 0: 0.7990696986057292
# Converged in iteration 1 with cost 0.7990696986057292 because of step counter
# Final cost : 0.7990696986057292
# Compute control for a deterministic system
# Cost in iteration 0: 0.47843361276235874
# Converged in iteration 2 with cost 0.47832468281048907 because of step counter
# Final cost : 0.47832468281048907
# Compute control for a deterministic system
# Cost in iteration 0: 0.47832468281048907
# Converged in iteration 1 with cost 0.47832468281048907 because of step counter
# Final cost : 0.47832468281048907
# Compute control for a deterministic system
# Cost in iteration 0: 0.47832468281048907
# Converged in iteration 1 with cost 0.47832468281048907 because of step counter
# Final cost : 0.47832468281048907
# Compute control for a deterministic system
# Cost in iteration 0: 0.47832468281048907
# Converged in iteration 1 with cost 0.47832468281048907 because of step counter
# Final cost : 0.47832468281048907
# Compute control for a deterministic system
# Cost in iteration 0: 0.47832468281048907
# Converged in iteration 1 with cost 0.47832468281048907 because of step counter
# Final cost : 0.47832468281048907
# Compute control for a deterministic system
# Cost in iteration 0: 1.36074146634442
# Cost in iteration 200: 1.268119022795461
# Final cost : 1.268119022795461
# Compute control for a deterministic system
# Cost in iteration 0: 1.268119022795461
# Cost in iteration 200: 0.8976019092675833
# Final cost : 0.8976019092675833
# Compute control for a deterministic system
# Cost in iteration 0: 0.8976019092675833
# Converged in iteration 83 with cost 0.893151293512201 because of vanishing difference
# Final cost : 0.893151293512201
# Compute control for a deterministic system
# Cost in iteration 0: 0.8931512935102439
# Converged in iteration 2 with cost 0.8931512934948718 because of vanishing difference
# Final cost : 0.8931512934948718
# Compute control for a deterministic system
# Cost in iteration 0: 0.8931512934948718
# Converged in iteration 1 with cost 0.8931512934948718 because of vanishing difference
# Final cost : 0.8931512934948718
# Compute control for a deterministic system
# Cost in iteration 0: 1.2019758787039376
# Cost in iteration 200: 1.1189486722405129
# Final cost : 1.1189486722405129
# Compute control for a deterministic system
# Cost in iteration 0: 1.1189486722405129
# Cost in iteration 200: 0.8724931360093713
# Final cost : 0.8724931360093713
# Compute control for a deterministic system
# Cost in iteration 0: 0.8724931360093713
# Converged in iteration 59 with cost 0.8711468403305063 because of vanishing difference
# Final cost : 0.8711468403305063
# Compute control for a deterministic system
# Cost in iteration 0: 0.8711468403279606
# Converged in iteration 2 with cost 0.8711468403096915 because of vanishing difference
# Final cost : 0.8711468403096915
# Compute control for a deterministic system
# Cost in iteration 0: 0.8711468403096913
# Converged in iteration 1 with cost 0.8711468403096913 because of step counter
# Final cost : 0.8711468403096913
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909488967152805
# Converged in iteration 1 with cost 0.4909488967152805 because of step counter
# Final cost : 0.4909488967152805
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909488967152805
# Converged in iteration 1 with cost 0.4909488967152805 because of step counter
# Final cost : 0.4909488967152805
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909488967152805
# Converged in iteration 1 with cost 0.4909488967152805 because of step counter
# Final cost : 0.4909488967152805
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909488967152805
# Converged in iteration 1 with cost 0.4909488967152805 because of step counter
# Final cost : 0.4909488967152805
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909488967152805
# Converged in iteration 1 with cost 0.4909488967152805 because of step counter
# Final cost : 0.4909488967152805
# Compute control for a deterministic system
# Cost in iteration 0: 0.5032754975294529
# Converged in iteration 1 with cost 0.5032754975294529 because of step counter
# Final cost : 0.5032754975294529
# Compute control for a deterministic system
# Cost in iteration 0: 0.5032754975294529
# Converged in iteration 1 with cost 0.5032754975294529 because of step counter
# Final cost : 0.5032754975294529
# Compute control for a deterministic system
# Cost in iteration 0: 0.5032754975294529
# Converged in iteration 1 with cost 0.5032754975294529 because of step counter
# Final cost : 0.5032754975294529
# Compute control for a deterministic system
# Cost in iteration 0: 0.5032754975294529
# Converged in iteration 1 with cost 0.5032754975294529 because of step counter
# Final cost : 0.5032754975294529
# Compute control for a deterministic system
# Cost in iteration 0: 0.5032754975294529
# Converged in iteration 1 with cost 0.5032754975294529 because of step counter
# Final cost : 0.5032754975294529
# Compute control for a deterministic system
# Cost in iteration 0: 0.7039944826762891
# Converged in iteration 1 with cost 0.7039944826762891 because of step counter
# Final cost : 0.7039944826762891
# Compute control for a deterministic system
# Cost in iteration 0: 0.7039944826762891
# Converged in iteration 1 with cost 0.7039944826762891 because of step counter
# Final cost : 0.7039944826762891
# Compute control for a deterministic system
# Cost in iteration 0: 0.7039944826762891
# Converged in iteration 1 with cost 0.7039944826762891 because of step counter
# Final cost : 0.7039944826762891
# Compute control for a deterministic system
# Cost in iteration 0: 0.7039944826762891
# Converged in iteration 1 with cost 0.7039944826762891 because of step counter
# Final cost : 0.7039944826762891
# Compute control for a deterministic system
# Cost in iteration 0: 0.7039944826762891
# Converged in iteration 1 with cost 0.7039944826762891 because of step counter
# Final cost : 0.7039944826762891
# Compute control for a deterministic system
# Cost in iteration 0: 0.5547701923559487
# Converged in iteration 2 with cost 0.5540606965205469 because of step counter
# Final cost : 0.5540606965205469
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540606965205469
# Converged in iteration 1 with cost 0.5540606965205469 because of step counter
# Final cost : 0.5540606965205469
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540606965205469
# Converged in iteration 1 with cost 0.5540606965205469 because of step counter
# Final cost : 0.5540606965205469
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540606965205469
# Converged in iteration 1 with cost 0.5540606965205469 because of step counter
# Final cost : 0.5540606965205469
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540606965205469
# Converged in iteration 1 with cost 0.5540606965205469 because of step counter
# Final cost : 0.5540606965205469
# Compute control for a deterministic system
# Cost in iteration 0: 0.448072854576106
# Converged in iteration 2 with cost 0.44804136235983555 because of step counter
# Final cost : 0.44804136235983555
# Compute control for a deterministic system
# Cost in iteration 0: 0.44804136235983555
# Converged in iteration 1 with cost 0.44804136235983555 because of step counter
# Final cost : 0.44804136235983555
# Compute control for a deterministic system
# Cost in iteration 0: 0.44804136235983555
# Converged in iteration 1 with cost 0.44804136235983555 because of step counter
# Final cost : 0.44804136235983555
# Compute control for a deterministic system
# Cost in iteration 0: 0.44804136235983555
# Converged in iteration 1 with cost 0.44804136235983555 because of step counter
# Final cost : 0.44804136235983555
# Compute control for a deterministic system
# Cost in iteration 0: 0.44804136235983555
# Converged in iteration 1 with cost 0.44804136235983555 because of step counter
# Final cost : 0.44804136235983555
# Compute control for a deterministic system
# Cost in iteration 0: 1.8342848434868595
# Cost in iteration 200: 1.6441547912971928
# Final cost : 1.6441547912971928
# Compute control for a deterministic system
# Cost in iteration 0: 1.6441547912971928
# Cost in iteration 200: 1.2411723920107267
# Final cost : 1.2411723920107267
# Compute control for a deterministic system
# Cost in iteration 0: 1.2411723920107267
# Cost in iteration 200: 1.203592483089674
# Converged in iteration 213 with cost 1.2035924830482327 because of vanishing difference
# Final cost : 1.2035924830482327
# Compute control for a deterministic system
# Cost in iteration 0: 1.2035924830465503
# Converged in iteration 2 with cost 1.2035924830312905 because of vanishing difference
# Final cost : 1.2035924830312905
# Compute control for a deterministic system
# Cost in iteration 0: 1.2035924830307896
# Converged in iteration 2 with cost 1.2035924830271898 because of vanishing difference
# Final cost : 1.2035924830271898
# Compute control for a deterministic system
# Cost in iteration 0: 1.5641576585144048
# Cost in iteration 200: 1.353388063167258
# Final cost : 1.353388063167258
# Compute control for a deterministic system
# Cost in iteration 0: 1.353388063167258
# Cost in iteration 200: 1.0250217351406428
# Final cost : 1.0250217351406428
# Compute control for a deterministic system
# Cost in iteration 0: 1.0250217351406428
# Converged in iteration 138 with cost 1.0135155011919503 because of vanishing difference
# Final cost : 1.0135155011919503
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135155011901902
# Converged in iteration 2 with cost 1.0135155011750987 because of vanishing difference
# Final cost : 1.0135155011750987
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135155011750985
# Converged in iteration 1 with cost 1.0135155011750985 because of vanishing difference
# Final cost : 1.0135155011750985
# Compute control for a deterministic system
# Cost in iteration 0: 1.312434265907152
# Cost in iteration 200: 1.1085277416860437
# Final cost : 1.1085277416860437
# Compute control for a deterministic system
# Cost in iteration 0: 1.1085277416860437
# Cost in iteration 200: 0.8621001598508007
# Final cost : 0.8621001598508007
# Compute control for a deterministic system
# Cost in iteration 0: 0.8621001598508007
# Converged in iteration 91 with cost 0.8593035290814623 because of vanishing difference
# Final cost : 0.8593035290814623
# Compute control for a deterministic system
# Cost in iteration 0: 0.8593035290797606
# Converged in iteration 2 with cost 0.8593035290660944 because of vanishing difference
# Final cost : 0.8593035290660944
# Compute control for a deterministic system
# Cost in iteration 0: 0.859303529066093
# Converged in iteration 1 with cost 0.859303529066093 because of step counter
# Final cost : 0.859303529066093
# Compute control for a deterministic system
# Cost in iteration 0: 0.7334220492576493
# Cost in iteration 200: 0.6520111084191
# Final cost : 0.6520111084191
# Compute control for a deterministic system
# Cost in iteration 0: 0.6520111084191
# Cost in iteration 200: 0.6069837179766926
# Final cost : 0.6069837179766926
# Compute control for a deterministic system
# Cost in iteration 0: 0.6069837179766926
# Converged in iteration 24 with cost 0.6069740038201659 because of vanishing difference
# Final cost : 0.6069740038201659
# Compute control for a deterministic system
# Cost in iteration 0: 0.6069740038201646
# Converged in iteration 1 with cost 0.6069740038201646 because of step counter
# Final cost : 0.6069740038201646
# Compute control for a deterministic system
# Cost in iteration 0: 0.6069740038201646
# Converged in iteration 1 with cost 0.6069740038201646 because of step counter
# Final cost : 0.6069740038201646
# Compute control for a deterministic system
# Cost in iteration 0: 0.6552483671442294
# Cost in iteration 200: 0.5964589275322579
# Final cost : 0.5964589275322579
# Compute control for a deterministic system
# Cost in iteration 0: 0.5964589275322579
# Cost in iteration 200: 0.5591330273300315
# Final cost : 0.5591330273300315
# Compute control for a deterministic system
# Cost in iteration 0: 0.5591330273300315
# Converged in iteration 18 with cost 0.5591299789453406 because of vanishing difference
# Final cost : 0.5591299789453406
# Compute control for a deterministic system
# Cost in iteration 0: 0.5591299789453406
# Converged in iteration 1 with cost 0.5591299789453406 because of step counter
# Final cost : 0.5591299789453406
# Compute control for a deterministic system
# Cost in iteration 0: 0.5591299789453406
# Converged in iteration 1 with cost 0.5591299789453406 because of step counter
# Final cost : 0.5591299789453406
# Compute control for a deterministic system
# Cost in iteration 0: 0.30750023892357886
# Converged in iteration 1 with cost 0.30750023892357886 because of step counter
# Final cost : 0.30750023892357886
# Compute control for a deterministic system
# Cost in iteration 0: 0.30750023892357886
# Converged in iteration 1 with cost 0.30750023892357886 because of step counter
# Final cost : 0.30750023892357886
# Compute control for a deterministic system
# Cost in iteration 0: 0.30750023892357886
# Converged in iteration 1 with cost 0.30750023892357886 because of step counter
# Final cost : 0.30750023892357886
# Compute control for a deterministic system
# Cost in iteration 0: 0.30750023892357886
# Converged in iteration 1 with cost 0.30750023892357886 because of step counter
# Final cost : 0.30750023892357886
# Compute control for a deterministic system
# Cost in iteration 0: 0.30750023892357886
# Converged in iteration 1 with cost 0.30750023892357886 because of step counter
# Final cost : 0.30750023892357886
# Compute control for a deterministic system
# Cost in iteration 0: 0.5007008571917039
# Cost in iteration 200: 0.4875957807509875
# Final cost : 0.4875957807509875
# Compute control for a deterministic system
# Cost in iteration 0: 0.4875957807509875

# %%
save(results_peak)
