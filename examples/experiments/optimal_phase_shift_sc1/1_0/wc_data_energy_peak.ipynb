# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,185], wc.inh[0,185]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# peaks =  [ 111  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2945 3134 3323 3512 3701 3890 4079 4268 4457 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L2_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L2_cost_unweighted"][iw][ish] = results_dict["L2_cost_weighted"][iw][ish] / w2
    wc_controlled.w_1D = w2

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w2.pickle")

# %%
for i in [18,19,20,21,22]:
    results_peak["total_cost"][0][i] = 10.

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
results_min = readfile("results_min_w2.pickle")

ind_list = [8,9,10,11,12]
options = [True, True, False, False, True, False, False, False]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        if i_w != 1:
            continue

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.028273218898965884
# Cost in iteration 200: 0.006470737203833583
# Final cost : 0.006470737203833583
# Compute control for a deterministic system
# Cost in iteration 0: 0.006470737203833583
# Cost in iteration 200: 0.005579883554427744
# Final cost : 0.005579883554427744
# Compute control for a deterministic system
# Cost in iteration 0: 0.005579883554427744
# Cost in iteration 200: 0.0055560390924938256
# Final cost : 0.0055560390924938256
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055560390924938256
# Cost in iteration 200: 0.005552759609928316
# Cost in iteration 400: 0.0055520366661277265
# Final cost : 0.0055520366661277265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055520366661277265
# Cost in iteration 200: 0.005551842636730099
# Cost in iteration 400: 0.005551779180195732
# Cost in iteration 600: 0.005551763250627451
# Cost in iteration 800: 0.00555175709598462
# Cost in iteration 1000: 0.005551754918559327
# Final cost : 0.005551754918559327
# Compute control for a deterministic system
# Cost in iteration 0: 0.08035470998575561
# Cost in iteration 200: 0.007175955471067647
# Final cost : 0.007175955471067647
# Compute control for a deterministic system
# Cost in iteration 0: 0.007175955471067647
# Cost in iteration 200: 0.0070600062862625
# Final cost : 0.0070600062862625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0070600062862625
# Cost in iteration 200: 0.007051765039576553
# Final cost : 0.007051765039576553
# Compute control for a deterministic system
# Cost in iteration 0: 0.007051765039576553
# Cost in iteration 200: 0.007048957687178872
# Cost in iteration 400: 0.007047668135918014
# Final cost : 0.007047668135918014
# Compute control for a deterministic system
# Cost in iteration 0: 0.007047668135918014
# Cost in iteration 200: 0.007047090224027288
# Cost in iteration 400: 0.007046856546872076
# Cost in iteration 600: 0.007046773799954062
# Cost in iteration 800: 0.007046730367135149
# Cost in iteration 1000: 0.00704671356220786
# Final cost : 0.00704671356220786
# Compute control for a deterministic system
# Cost in iteration 0: 0.05975685206335827
# Cost in iteration 200: 0.008460018963465057
# Final cost : 0.008460018963465057
# Compute control for a deterministic system
# Cost in iteration 0: 0.008460018963465057
# Cost in iteration 200: 0.008373874447915122
# Final cost : 0.008373874447915122
# Compute control for a deterministic system
# Cost in iteration 0: 0.008373874447915122
# Cost in iteration 200: 0.008367001947242025
# Final cost : 0.008367001947242025
# Compute control for a deterministic system
# Cost in iteration 0: 0.008367001947242025
# Cost in iteration 200: 0.008364477207257241
# Cost in iteration 400: 0.008363214074583483
# Final cost : 0.008363214074583483
# Compute control for a deterministic system
# Cost in iteration 0: 0.008363214074583483
# Cost in iteration 200: 0.008362664582700156
# Cost in iteration 400: 0.00836240096561081
# Cost in iteration 600: 0.008362263806619181
# Cost in iteration 800: 0.008362193695477513
# Cost in iteration 1000: 0.008362157476909056
# Final cost : 0.008362157476909056
# Compute control for a deterministic system
# Cost in iteration 0: 0.03116505094858089
# Cost in iteration 200: 0.010315213902048145
# Final cost : 0.010315213902048145
# Compute control for a deterministic system
# Cost in iteration 0: 0.010315213902048145
# Cost in iteration 200: 0.010174972515631115
# Final cost : 0.010174972515631115
# Compute control for a deterministic system
# Cost in iteration 0: 0.010174972515631115
# Cost in iteration 200: 0.010163465949003664
# Final cost : 0.010163465949003664
# Compute control for a deterministic system
# Cost in iteration 0: 0.010163465949003664
# Cost in iteration 200: 0.010159156650783692
# Cost in iteration 400: 0.010156726926117124
# Final cost : 0.010156726926117124
# Compute control for a deterministic system
# Cost in iteration 0: 0.010156726926117124
# Cost in iteration 200: 0.010155472998884788
# Cost in iteration 400: 0.010154979765201822
# Cost in iteration 600: 0.010154652181346297
# Cost in iteration 800: 0.010154510724302167
# Cost in iteration 1000: 0.010154444653308033
# Final cost : 0.010154444653308033
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.0941392793743287
# Cost in iteration 200: 0.012311898744346676
# Final cost : 0.012311898744346676
# Compute control for a deterministic system
# Cost in iteration 0: 0.012311898744346676
# Cost in iteration 200: 0.01213832196899304
# Final cost : 0.01213832196899304
# Compute control for a deterministic system
# Cost in iteration 0: 0.01213832196899304
# Cost in iteration 200: 0.012123047956870296
# Final cost : 0.012123047956870296
# Compute control for a deterministic system
# Cost in iteration 0: 0.012123047956870296
# Cost in iteration 200: 0.01211717412687485
# Cost in iteration 400: 0.012113960522130728
# Final cost : 0.012113960522130728
# Compute control for a deterministic system
# Cost in iteration 0: 0.012113960522130728
# Cost in iteration 200: 0.012112032602975562
# Cost in iteration 400: 0.012111043484495782
# Cost in iteration 600: 0.012110546429598712
# Cost in iteration 800: 0.012110251194159146
# Cost in iteration 1000: 0.012110077848653056
# Final cost : 0.012110077848653056
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.06728069886878948
# Cost in iteration 200: 0.017706884718397507
# Final cost : 0.017706884718397507
# Compute control for a deterministic system
# Cost in iteration 0: 0.017706884718397507
# Cost in iteration 200: 0.015485064033873112
# Final cost : 0.015485064033873112
# Compute control for a deterministic system
# Cost in iteration 0: 0.015485064033873112
# Cost in iteration 200: 0.014144991064718171
# Cost in iteration 400: 0.013332755691476897
# Final cost : 0.013332755691476897
# Compute control for a deterministic system
# Cost in iteration 0: 0.013332755691476897
# Cost in iteration 200: 0.012863251105163996
# Cost in iteration 400: 0.012579668897332408
# Cost in iteration 600: 0.01240287384586613
# Cost in iteration 800: 0.012287208203536152
# Cost in iteration 1000: 0.01221607855735007
# Final cost : 0.01221607855735007
# Compute control for a deterministic system
# Cost in iteration 0: 0.020752867424032588
# Cost in iteration 200: 0.010235930287986299
# Final cost : 0.010235930287986299
# Compute control for a deterministic system
# Cost in iteration 0: 0.010235930287986299
# Cost in iteration 200: 0.010185938632235199
# Final cost : 0.010185938632235199
# Compute control for a deterministic system
# Cost in iteration 0: 0.010185938632235199
# Cost in iteration 200: 0.010169808553002119
# Cost in iteration 400: 0.010162432959340075
# Final cost : 0.010162432959340075
# Compute control for a deterministic system
# Cost in iteration 0: 0.010162432959340075
# Cost in iteration 200: 0.010158836126036103
# Cost in iteration 400: 0.010156727062859834
# Cost in iteration 600: 0.010155620910574138
# Cost in iteration 800: 0.010155065489307702
# Cost in iteration 1000: 0.010154748538974235
# Final cost : 0.010154748538974235
# Compute control for a deterministic system
# Cost in iteration 0: 0.08346208970351442
# Cost in iteration 200: 0.008413372001235904
# Final cost : 0.008413372001235904
# Compute control for a deterministic system
# Cost in iteration 0: 0.008413372001235904
# Cost in iteration 200: 0.008383584148997642
# Final cost : 0.008383584148997642
# Compute control for a deterministic system
# Cost in iteration 0: 0.008383584148997642
# Cost in iteration 200: 0.00837228583529759
# Cost in iteration 400: 0.008367139524382866
# Final cost : 0.008367139524382866
# Compute control for a deterministic system
# Cost in iteration 0: 0.008367139524382866
# Cost in iteration 200: 0.008364660707243475
# Cost in iteration 400: 0.008363391951860737
# Cost in iteration 600: 0.00836276000809251
# Cost in iteration 800: 0.008362444658574837
# Cost in iteration 1000: 0.008362285645025246
# Final cost : 0.008362285645025246
# Compute control for a deterministic system
# Cost in iteration 0: 0.04330133714432616
# Cost in iteration 200: 0.007074256855829489
# Final cost : 0.007074256855829489
# Compute control for a deterministic system
# Cost in iteration 0: 0.007074256855829489
# Cost in iteration 200: 0.007057460986870795
# Final cost : 0.007057460986870795
# Compute control for a deterministic system
# Cost in iteration 0: 0.007057460986870795
# Cost in iteration 200: 0.007051475760214628
# Cost in iteration 400: 0.007048984611714614
# Final cost : 0.007048984611714614
# Compute control for a deterministic system
# Cost in iteration 0: 0.007048984611714614
# Cost in iteration 200: 0.007047754312344526
# Cost in iteration 400: 0.007047196264700749
# Cost in iteration 600: 0.007046934886808551
# Cost in iteration 800: 0.007046811422283427
# Cost in iteration 1000: 0.0070467519218947805
# Final cost : 0.0070467519218947805
# Compute control for a deterministic system
# Cost in iteration 0: 0.02165561092619529
# Cost in iteration 200: 0.005596180661492682
# Final cost : 0.005596180661492682
# Compute control for a deterministic system
# Cost in iteration 0: 0.005596180661492682
# Cost in iteration 200: 0.005566130788294135
# Final cost : 0.005566130788294135
# Compute control for a deterministic system
# Cost in iteration 0: 0.005566130788294135
# Cost in iteration 200: 0.005557605376298954
# Cost in iteration 400: 0.005554255392754818
# Final cost : 0.005554255392754818
# Compute control for a deterministic system
# Cost in iteration 0: 0.005554255392754818
# Cost in iteration 200: 0.005552792511748016
# Cost in iteration 400: 0.005552196308523876
# Cost in iteration 600: 0.005551950487240321
# Cost in iteration 800: 0.005551837249388806
# Cost in iteration 1000: 0.005551790426919007
# Final cost : 0.005551790426919007
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.008095508649640433
# Cost in iteration 200: 0.005552290918312823
# Final cost : 0.005552290918312823
# Compute control for a deterministic system
# Cost in iteration 0: 0.005552290918312823
# Cost in iteration 200: 0.005551768893307563
# Final cost : 0.005551768893307563
# Compute control for a deterministic system
# Cost in iteration 0: 0.005551768893307563
# Cost in iteration 200: 0.005551754507950736
# Final cost : 0.005551754507950736
# Compute control for a deterministic system
# Cost in iteration 0: 0.005551754507950736
# Cost in iteration 200: 0.005551753440266391
# Cost in iteration 400: 0.005551753339953078
# Final cost : 0.005551753339953078
# Compute control for a deterministic system
# Cost in iteration 0: 0.005551753339953078
# Cost in iteration 200: 0.0055517533247723926
# Cost in iteration 400: 0.0055517533211435445
# Cost in iteration 600: 0.005551753320025574
# Cost in iteration 800: 0.005551753319638636
# Cost in iteration 1000: 0.005551753319481838
# Final cost : 0.005551753319481838
# -----------------------------------------------
# 4 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.009896764667014004
# Cost in iteration 200: 0.007047569414157461
# Final cost : 0.007047569414157461
# Compute control for a deterministic system
# Cost in iteration 0: 0.007047569414157461
# Cost in iteration 200: 0.007046728358089703
# Final cost : 0.007046728358089703
# Compute control for a deterministic system
# Cost in iteration 0: 0.007046728358089703
# Cost in iteration 200: 0.007046702486834072
# Final cost : 0.007046702486834072
# Compute control for a deterministic system
# Cost in iteration 0: 0.007046702486834072
# Cost in iteration 200: 0.007046699372907788
# Cost in iteration 400: 0.007046698489355208
# Final cost : 0.007046698489355208
# Compute control for a deterministic system
# Cost in iteration 0: 0.007046698489355208
# Cost in iteration 200: 0.007046698102115656
# Cost in iteration 400: 0.007046697912773131
# Cost in iteration 600: 0.00704669782184722
# Cost in iteration 800: 0.0070466977819010285
# Cost in iteration 1000: 0.007046697761614053
# Final cost : 0.007046697761614053
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.01905338042987935
# Cost in iteration 200: 0.008363210545225349
# Final cost : 0.008363210545225349
# Compute control for a deterministic system
# Cost in iteration 0: 0.008363210545225349
# Cost in iteration 200: 0.008362162094808006
# Final cost : 0.008362162094808006
# Compute control for a deterministic system
# Cost in iteration 0: 0.008362162094808006
# Cost in iteration 200: 0.008362126186406398
# Final cost : 0.008362126186406398
# Compute control for a deterministic system
# Cost in iteration 0: 0.008362126186406398
# Cost in iteration 200: 0.008362121524120953
# Cost in iteration 400: 0.008362120230756095
# Final cost : 0.008362120230756095
# Compute control for a deterministic system
# Cost in iteration 0: 0.008362120230756095
# Cost in iteration 200: 0.008362119678993673
# Cost in iteration 400: 0.00836211939233216
# Cost in iteration 600: 0.008362119270817392
# Cost in iteration 800: 0.00836211920694318
# Cost in iteration 1000: 0.00836211917662455
# Final cost : 0.00836211917662455
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.024167838456720547
# Cost in iteration 200: 0.010156024803082841
# Final cost : 0.010156024803082841
# Compute control for a deterministic system
# Cost in iteration 0: 0.010156024803082841
# Cost in iteration 200: 0.010154466565981712
# Final cost : 0.010154466565981712
# Compute control for a deterministic system
# Cost in iteration 0: 0.010154466565981712
# Cost in iteration 200: 0.010154401325016863
# Final cost : 0.010154401325016863
# Compute control for a deterministic system
# Cost in iteration 0: 0.010154401325016863
# Cost in iteration 200: 0.010154384793290958
# Cost in iteration 400: 0.010154377315559515
# Final cost : 0.010154377315559515
# Compute control for a deterministic system
# Cost in iteration 0: 0.010154377315559515
# Cost in iteration 200: 0.010154372723851217
# Cost in iteration 400: 0.010154370745112957
# Cost in iteration 600: 0.010154369648207174
# Cost in iteration 800: 0.010154369209536898
# Cost in iteration 1000: 0.010154368975046301
# Final cost : 0.010154368975046301
# -----------------------------------------------
# 4 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.026632548605652343
# Cost in iteration 200: 0.01211218227518302
# Final cost : 0.01211218227518302
# Compute control for a deterministic system
# Cost in iteration 0: 0.01211218227518302
# Cost in iteration 200: 0.012110019018565496
# Final cost : 0.012110019018565496
# Compute control for a deterministic system
# Cost in iteration 0: 0.012110019018565496
# Cost in iteration 200: 0.012109913325447903
# Final cost : 0.012109913325447903
# Compute control for a deterministic system
# Cost in iteration 0: 0.012109913325447903
# Cost in iteration 200: 0.012109878474590557
# Cost in iteration 400: 0.012109859175609099
# Final cost : 0.012109859175609099
# Compute control for a deterministic system
# Cost in iteration 0: 0.012109859175609099
# Cost in iteration 200: 0.012109848627164167
# Cost in iteration 400: 0.012109843385384053
# Cost in iteration 600: 0.012109840510028504
# Cost in iteration 800: 0.012109838533168663
# Cost in iteration 1000: 0.01210983755375252
# Final cost : 0.01210983755375252
# -----------------------------------------------
# 4 found better solution,  12

# %%
save(results_peak)
