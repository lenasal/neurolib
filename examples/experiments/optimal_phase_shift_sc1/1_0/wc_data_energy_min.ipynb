# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L2_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L2_cost_unweighted"][iw][ish] = results_dict["L2_cost_weighted"][iw][ish] / w2
    wc_controlled.w_1D = w2

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, True, False]
options = [True, True, False, False, True, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.028482583133003368
# Cost in iteration 200: 0.00032948105863023387
# Final cost : 0.00032948105863023387
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032948105863023387
# Cost in iteration 200: 0.0003256299896159215
# Final cost : 0.0003256299896159215
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003256299896159215
# Cost in iteration 200: 0.00032541567135819935
# Final cost : 0.00032541567135819935
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032541567135819935
# Cost in iteration 200: 0.000325387356421294
# Cost in iteration 400: 0.00032538246373842807
# Final cost : 0.00032538246373842807
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032538246373842807
# Cost in iteration 200: 0.00032538167595220065
# Cost in iteration 400: 0.0003253815236609283
# Cost in iteration 600: 0.00032538149314380717
# Cost in iteration 800: 0.0003253814870589392
# Cost in iteration 1000: 0.0003253814858080193
# Final cost : 0.0003253814858080193
# Compute control for a deterministic system
# Cost in iteration 0: 0.03758221244401199
# Cost in iteration 200: 0.0007982824322448467
# Final cost : 0.0007982824322448467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007982824322448467
# Cost in iteration 200: 0.0007848957777524408
# Final cost : 0.0007848957777524408
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007848957777524408
# Cost in iteration 200: 0.0007841794333047154
# Final cost : 0.0007841794333047154
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007841794333047154
# Cost in iteration 200: 0.000784073722854411
# Cost in iteration 400: 0.00078405114334631
# Final cost : 0.00078405114334631
# Compute control for a deterministic system
# Cost in iteration 0: 0.00078405114334631
# Cost in iteration 200: 0.0007840459168479522
# Cost in iteration 400: 0.0007840447214023063
# Cost in iteration 600: 0.0007840444331772161
# Cost in iteration 800: 0.0007840443648613048
# Cost in iteration 1000: 0.0007840443481132238
# Final cost : 0.0007840443481132238
# Compute control for a deterministic system
# Cost in iteration 0: 0.04582694058615196
# Cost in iteration 200: 0.0014658262238841583
# Final cost : 0.0014658262238841583
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014658262238841583
# Cost in iteration 200: 0.001439737909643372
# Final cost : 0.001439737909643372
# Compute control for a deterministic system
# Cost in iteration 0: 0.001439737909643372
# Cost in iteration 200: 0.0014383400420922535
# Final cost : 0.0014383400420922535
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014383400420922535
# Cost in iteration 200: 0.0014380971856179994
# Cost in iteration 400: 0.0014380312180698508
# Final cost : 0.0014380312180698508
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014380312180698508
# Cost in iteration 200: 0.0014380141738083154
# Cost in iteration 400: 0.00143800947449481
# Cost in iteration 600: 0.0014380081359075404
# Cost in iteration 800: 0.0014380077526026692
# Cost in iteration 1000: 0.0014380076414278182
# Final cost : 0.0014380076414278182
# Compute control for a deterministic system
# Cost in iteration 0: 0.037552794837081585
# Cost in iteration 200: 0.002328494268940632
# Final cost : 0.002328494268940632
# Compute control for a deterministic system
# Cost in iteration 0: 0.002328494268940632
# Cost in iteration 200: 0.002287729869725197
# Final cost : 0.002287729869725197
# Compute control for a deterministic system
# Cost in iteration 0: 0.002287729869725197
# Cost in iteration 200: 0.0022854126432393443
# Final cost : 0.0022854126432393443
# Compute control for a deterministic system
# Cost in iteration 0: 0.0022854126432393443
# Cost in iteration 200: 0.0022849280290544336
# Cost in iteration 400: 0.002284777981660472
# Final cost : 0.002284777981660472
# Compute control for a deterministic system
# Cost in iteration 0: 0.002284777981660472
# Cost in iteration 200: 0.002284729391762991
# Cost in iteration 400: 0.002284713374762891
# Cost in iteration 600: 0.002284707986189265
# Cost in iteration 800: 0.0022847062189045183
# Cost in iteration 1000: 0.002284705618959974
# Final cost : 0.002284705618959974
# Compute control for a deterministic system
# Cost in iteration 0: 0.017421167062450827
# Cost in iteration 200: 0.003137972189975908
# Final cost : 0.003137972189975908
# Compute control for a deterministic system
# Cost in iteration 0: 0.003137972189975908
# Cost in iteration 200: 0.003102299842868638
# Final cost : 0.003102299842868638
# Compute control for a deterministic system
# Cost in iteration 0: 0.003102299842868638
# Cost in iteration 200: 0.0030999617163783365
# Final cost : 0.0030999617163783365
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030999617163783365
# Cost in iteration 200: 0.003099369336492194
# Cost in iteration 400: 0.003099152934331306
# Final cost : 0.003099152934331306
# Compute control for a deterministic system
# Cost in iteration 0: 0.003099152934331306
# Cost in iteration 200: 0.0030990917142378147
# Cost in iteration 400: 0.0030990763081201003
# Cost in iteration 600: 0.0030990702022587555
# Cost in iteration 800: 0.003099068568658342
# Cost in iteration 1000: 0.0030990680763975003
# Final cost : 0.0030990680763975003
# Compute control for a deterministic system
# Cost in iteration 0: 0.02874259715669539
# Cost in iteration 200: 0.004366881478507736
# Final cost : 0.004366881478507736
# Compute control for a deterministic system
# Cost in iteration 0: 0.004366881478507736
# Cost in iteration 200: 0.004293521642926444
# Final cost : 0.004293521642926444
# Compute control for a deterministic system
# Cost in iteration 0: 0.004293521642926444
# Cost in iteration 200: 0.0042884385271834856
# Final cost : 0.0042884385271834856
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042884385271834856
# Cost in iteration 200: 0.00428684377779305
# Cost in iteration 400: 0.004286324283338273
# Final cost : 0.004286324283338273
# Compute control for a deterministic system
# Cost in iteration 0: 0.004286324283338273
# Cost in iteration 200: 0.004286133342711703
# Cost in iteration 400: 0.0042860603976331135
# Cost in iteration 600: 0.004286031557828359
# Cost in iteration 800: 0.00428601948621114
# Cost in iteration 1000: 0.004286014530384965
# Final cost : 0.004286014530384965
# Compute control for a deterministic system
# Cost in iteration 0: 0.05581664972825965
# Cost in iteration 200: 0.005766197899879237
# Final cost : 0.005766197899879237
# Compute control for a deterministic system
# Cost in iteration 0: 0.005766197899879237
# Cost in iteration 200: 0.005669395622408932
# Final cost : 0.005669395622408932
# Compute control for a deterministic system
# Cost in iteration 0: 0.005669395622408932
# Cost in iteration 200: 0.0056623398071159745
# Final cost : 0.0056623398071159745
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056623398071159745
# Cost in iteration 200: 0.005659829494822654
# Cost in iteration 400: 0.005658884421673777
# Final cost : 0.005658884421673777
# Compute control for a deterministic system
# Cost in iteration 0: 0.005658884421673777
# Cost in iteration 200: 0.005658468366428794
# Cost in iteration 400: 0.005658283160954166
# Cost in iteration 600: 0.0056582002625139615
# Cost in iteration 800: 0.005658161631241202
# Cost in iteration 1000: 0.005658144069752144
# Final cost : 0.005658144069752144
# Compute control for a deterministic system
# Cost in iteration 0: 0.08063834045582363
# Cost in iteration 200: 0.007351831959023454
# Final cost : 0.007351831959023454
# Compute control for a deterministic system
# Cost in iteration 0: 0.007351831959023454
# Cost in iteration 200: 0.007228950503968953
# Final cost : 0.007228950503968953
# Compute control for a deterministic system
# Cost in iteration 0: 0.007228950503968953
# Cost in iteration 200: 0.007219301867839389
# Final cost : 0.007219301867839389
# Compute control for a deterministic system
# Cost in iteration 0: 0.007219301867839389
# Cost in iteration 200: 0.007215704869721578
# Cost in iteration 400: 0.007214093458033422
# Final cost : 0.007214093458033422
# Compute control for a deterministic system
# Cost in iteration 0: 0.007214093458033422
# Cost in iteration 200: 0.007213293918777429
# Cost in iteration 400: 0.007212913849395598
# Cost in iteration 600: 0.007212741892217258
# Cost in iteration 800: 0.007212658535197604
# Cost in iteration 1000: 0.007212610001463672
# Final cost : 0.007212610001463672
# Compute control for a deterministic system
# Cost in iteration 0: 0.06644287299678961
# Cost in iteration 200: 0.008691780855580698
# Final cost : 0.008691780855580698
# Compute control for a deterministic system
# Cost in iteration 0: 0.008691780855580698
# Cost in iteration 200: 0.008599272233469004
# Final cost : 0.008599272233469004
# Compute control for a deterministic system
# Cost in iteration 0: 0.008599272233469004
# Cost in iteration 200: 0.008591651322032637
# Final cost : 0.008591651322032637
# Compute control for a deterministic system
# Cost in iteration 0: 0.008591651322032637
# Cost in iteration 200: 0.00858860320055608
# Cost in iteration 400: 0.008587083337082656
# Final cost : 0.008587083337082656
# Compute control for a deterministic system
# Cost in iteration 0: 0.008587083337082656
# Cost in iteration 200: 0.008586118082192956
# Cost in iteration 400: 0.008585770880778798
# Cost in iteration 600: 0.008585600791259938
# Cost in iteration 800: 0.008585509557687769
# Cost in iteration 1000: 0.00858546445883795
# Final cost : 0.00858546445883795
# Compute control for a deterministic system
# Cost in iteration 0: 0.08146815618395907
# Cost in iteration 200: 0.010645235840710919
# Final cost : 0.010645235840710919
# Compute control for a deterministic system
# Cost in iteration 0: 0.010645235840710919
# Cost in iteration 200: 0.010486784642506757
# Final cost : 0.010486784642506757
# Compute control for a deterministic system
# Cost in iteration 0: 0.010486784642506757
# Cost in iteration 200: 0.01047309620211595
# Final cost : 0.01047309620211595
# Compute control for a deterministic system
# Cost in iteration 0: 0.01047309620211595
# Cost in iteration 200: 0.010467277243659312
# Cost in iteration 400: 0.010464378456730818
# Final cost : 0.010464378456730818
# Compute control for a deterministic system
# Cost in iteration 0: 0.010464378456730818
# Cost in iteration 200: 0.010462699401687172
# Cost in iteration 400: 0.010461732168493311
# Cost in iteration 600: 0.01046118452521553
# Cost in iteration 800: 0.01046090100642034
# Cost in iteration 1000: 0.010460741819007552
# Final cost : 0.010460741819007552
# Compute control for a deterministic system
# Cost in iteration 0: 0.02915871009794934
# Cost in iteration 200: 0.012706155165291076
# Final cost : 0.012706155165291076
# Compute control for a deterministic system
# Cost in iteration 0: 0.012706155165291076
# Cost in iteration 200: 0.012541750488053904
# Final cost : 0.012541750488053904
# Compute control for a deterministic system
# Cost in iteration 0: 0.012541750488053904
# Cost in iteration 200: 0.012526201411226116
# Final cost : 0.012526201411226116
# Compute control for a deterministic system
# Cost in iteration 0: 0.012526201411226116
# Cost in iteration 200: 0.012519072163572323
# Cost in iteration 400: 0.012515254507010682
# Final cost : 0.012515254507010682
# Compute control for a deterministic system
# Cost in iteration 0: 0.012515254507010682
# Cost in iteration 200: 0.01251261102519093
# Cost in iteration 400: 0.012511270082417049
# Cost in iteration 600: 0.01251049167906225
# Cost in iteration 800: 0.01251007651927902
# Cost in iteration 1000: 0.01250980687571099
# Final cost : 0.01250980687571099
# Compute control for a deterministic system
# Cost in iteration 0: 0.019745329337798056
# Cost in iteration 200: 0.014411927177282792
# Final cost : 0.014411927177282792
# Compute control for a deterministic system
# Cost in iteration 0: 0.014411927177282792
# Cost in iteration 200: 0.014297578265485862
# Final cost : 0.014297578265485862
# Compute control for a deterministic system
# Cost in iteration 0: 0.014297578265485862
# Cost in iteration 200: 0.014285809807713584
# Final cost : 0.014285809807713584
# Compute control for a deterministic system
# Cost in iteration 0: 0.014285809807713584
# Cost in iteration 200: 0.014279991403443765
# Cost in iteration 400: 0.014276794686875224
# Final cost : 0.014276794686875224
# Compute control for a deterministic system
# Cost in iteration 0: 0.014276794686875224
# Cost in iteration 200: 0.01427474489785427
# Cost in iteration 400: 0.014273496231761927
# Cost in iteration 600: 0.014272724885611158
# Cost in iteration 800: 0.0142722435851422
# Cost in iteration 1000: 0.014271940765601586
# Final cost : 0.014271940765601586
# Compute control for a deterministic system
# Cost in iteration 0: 0.05822963292514606
# Cost in iteration 200: 0.01686099467589335
# Final cost : 0.01686099467589335
# Compute control for a deterministic system
# Cost in iteration 0: 0.01686099467589335
# Cost in iteration 200: 0.01667053149952537
# Final cost : 0.01667053149952537
# Compute control for a deterministic system
# Cost in iteration 0: 0.01667053149952537
# Cost in iteration 200: 0.016650710937951403
# Final cost : 0.016650710937951403
# Compute control for a deterministic system
# Cost in iteration 0: 0.016650710937951403
# Cost in iteration 200: 0.016640937554032172
# Cost in iteration 400: 0.01663529618205107
# Final cost : 0.01663529618205107
# Compute control for a deterministic system
# Cost in iteration 0: 0.01663529618205107
# Cost in iteration 200: 0.016631456431218338
# Cost in iteration 400: 0.016628939333541867
# Cost in iteration 600: 0.01662734817318318
# Cost in iteration 800: 0.016626358478713976
# Cost in iteration 1000: 0.016625728394719628
# Final cost : 0.016625728394719628
# Compute control for a deterministic system
# Cost in iteration 0: 0.03677053954293403
# Cost in iteration 200: 0.019391103271925475
# Final cost : 0.019391103271925475
# Compute control for a deterministic system
# Cost in iteration 0: 0.019391103271925475
# Cost in iteration 200: 0.01919493661025559
# Final cost : 0.01919493661025559
# Compute control for a deterministic system
# Cost in iteration 0: 0.01919493661025559
# Cost in iteration 200: 0.01917318022670476
# Final cost : 0.01917318022670476
# Compute control for a deterministic system
# Cost in iteration 0: 0.01917318022670476
# Cost in iteration 200: 0.01916204785111195
# Cost in iteration 400: 0.019155337543310676
# Final cost : 0.019155337543310676
# Compute control for a deterministic system
# Cost in iteration 0: 0.019155337543310676
# Cost in iteration 200: 0.019150670716888536
# Cost in iteration 400: 0.019147573364327312
# Cost in iteration 600: 0.01914548303812696
# Cost in iteration 800: 0.019144036540977894
# Cost in iteration 1000: 0.019143133949434833
# Final cost : 0.019143133949434833
# Compute control for a deterministic system
# Cost in iteration 0: 0.05400069672211301
# Cost in iteration 200: 0.02208131122664855
# Final cost : 0.02208131122664855
# Compute control for a deterministic system
# Cost in iteration 0: 0.02208131122664855
# Cost in iteration 200: 0.021878001520398083
# Final cost : 0.021878001520398083
# Compute control for a deterministic system
# Cost in iteration 0: 0.021878001520398083
# Cost in iteration 200: 0.02185406176588191
# Final cost : 0.02185406176588191
# Compute control for a deterministic system
# Cost in iteration 0: 0.02185406176588191
# Cost in iteration 200: 0.02184156036706184
# Cost in iteration 400: 0.02183378328573351
# Final cost : 0.02183378328573351
# Compute control for a deterministic system
# Cost in iteration 0: 0.02183378328573351
# Cost in iteration 200: 0.021827870105843267
# Cost in iteration 400: 0.021824030431445197
# Cost in iteration 600: 0.021821345583496316
# Cost in iteration 800: 0.02181959063026963
# Cost in iteration 1000: 0.021818424139791428
# Final cost : 0.021818424139791428
# Compute control for a deterministic system
# Cost in iteration 0: 0.029499968523622046
# Cost in iteration 200: 0.024240471059664905
# Final cost : 0.024240471059664905
# Compute control for a deterministic system
# Cost in iteration 0: 0.024240471059664905
# Cost in iteration 200: 0.024108018497108377
# Final cost : 0.024108018497108377
# Compute control for a deterministic system
# Cost in iteration 0: 0.024108018497108377
# Cost in iteration 200: 0.02409142641824503
# Final cost : 0.02409142641824503
# Compute control for a deterministic system
# Cost in iteration 0: 0.02409142641824503
# Cost in iteration 200: 0.024082480374552812
# Cost in iteration 400: 0.02407653424811125
# Final cost : 0.02407653424811125
# Compute control for a deterministic system
# Cost in iteration 0: 0.02407653424811125
# Cost in iteration 200: 0.02407224464290618
# Cost in iteration 400: 0.024069292256849204
# Cost in iteration 600: 0.02406725665454984
# Cost in iteration 800: 0.024065818590700838
# Cost in iteration 1000: 0.024064832072581265
# Final cost : 0.024064832072581265
# Compute control for a deterministic system
# Cost in iteration 0: 0.15676596963971923
# Cost in iteration 200: 0.02730800325356892
# Final cost : 0.02730800325356892
# Compute control for a deterministic system
# Cost in iteration 0: 0.02730800325356892
# Cost in iteration 200: 0.0270606200379111
# Final cost : 0.0270606200379111
# Compute control for a deterministic system
# Cost in iteration 0: 0.0270606200379111
# Cost in iteration 200: 0.027033693732322506
# Final cost : 0.027033693732322506
# Compute control for a deterministic system
# Cost in iteration 0: 0.027033693732322506
# Cost in iteration 200: 0.027019965533730792
# Cost in iteration 400: 0.02701142650771385
# Final cost : 0.02701142650771385
# Compute control for a deterministic system
# Cost in iteration 0: 0.02701142650771385
# Cost in iteration 200: 0.027004064699707054
# Cost in iteration 400: 0.026999750146100846
# Cost in iteration 600: 0.02699659913339382
# Cost in iteration 800: 0.026994319429964015
# Cost in iteration 1000: 0.026992746529545895
# Final cost : 0.026992746529545895
# Compute control for a deterministic system
# Cost in iteration 0: 0.23624746598712246
# Cost in iteration 200: 0.030408453245960785
# Final cost : 0.030408453245960785
# Compute control for a deterministic system
# Cost in iteration 0: 0.030408453245960785
# Cost in iteration 200: 0.030094749948162306
# Final cost : 0.030094749948162306
# Compute control for a deterministic system
# Cost in iteration 0: 0.030094749948162306
# Cost in iteration 200: 0.03006696999640021
# Final cost : 0.03006696999640021
# Compute control for a deterministic system
# Cost in iteration 0: 0.03006696999640021
# Cost in iteration 200: 0.030051437356319946
# Cost in iteration 400: 0.03004138628336207
# Final cost : 0.03004138628336207
# Compute control for a deterministic system
# Cost in iteration 0: 0.03004138628336207
# Cost in iteration 200: 0.030034534619655762
# Cost in iteration 400: 0.03002946427860224
# Cost in iteration 600: 0.030025932415989942
# Cost in iteration 800: 0.03002356472723065
# Cost in iteration 1000: 0.03002180911108461
# Final cost : 0.03002180911108461
# Compute control for a deterministic system
# Cost in iteration 0: 0.19454393749673307
# Cost in iteration 200: 0.03274050918352996
# Final cost : 0.03274050918352996
# Compute control for a deterministic system
# Cost in iteration 0: 0.03274050918352996
# Cost in iteration 200: 0.03253980697673443
# Final cost : 0.03253980697673443
# Compute control for a deterministic system
# Cost in iteration 0: 0.03253980697673443
# Cost in iteration 200: 0.03252305951963073
# Final cost : 0.03252305951963073
# Compute control for a deterministic system
# Cost in iteration 0: 0.03252305951963073
# Cost in iteration 200: 0.03251288285356594
# Cost in iteration 400: 0.03250670214286492
# Final cost : 0.03250670214286492
# Compute control for a deterministic system
# Cost in iteration 0: 0.03250670214286492
# Cost in iteration 200: 0.03250244369184033
# Cost in iteration 400: 0.03249983904417903
# Cost in iteration 600: 0.03249784846232
# Cost in iteration 800: 0.03249625047267487
# Cost in iteration 1000: 0.032495058631581863
# Final cost : 0.032495058631581863
# Compute control for a deterministic system
# Cost in iteration 0: 0.24472554954903608
# Cost in iteration 200: 0.036023158986143035
# Final cost : 0.036023158986143035
# Compute control for a deterministic system
# Cost in iteration 0: 0.036023158986143035
# Cost in iteration 200: 0.03571497277849291
# Final cost : 0.03571497277849291
# Compute control for a deterministic system
# Cost in iteration 0: 0.03571497277849291
# Cost in iteration 200: 0.035688483476959305
# Final cost : 0.035688483476959305
# Compute control for a deterministic system
# Cost in iteration 0: 0.035688483476959305
# Cost in iteration 200: 0.03567496824327129
# Cost in iteration 400: 0.03566488084564414
# Final cost : 0.03566488084564414
# Compute control for a deterministic system
# Cost in iteration 0: 0.03566488084564414
# Cost in iteration 200: 0.03565833444735049
# Cost in iteration 400: 0.03565330956409974
# Cost in iteration 600: 0.03564921767618028
# Cost in iteration 800: 0.03564674998193307
# Cost in iteration 1000: 0.03564478486643569
# Final cost : 0.03564478486643569
# Compute control for a deterministic system
# Cost in iteration 0: 0.16123323635694897
# Cost in iteration 200: 0.03916516037755107
# Final cost : 0.03916516037755107
# Compute control for a deterministic system
# Cost in iteration 0: 0.03916516037755107
# Cost in iteration 200: 0.03894023698013713
# Final cost : 0.03894023698013713
# Compute control for a deterministic system
# Cost in iteration 0: 0.03894023698013713
# Cost in iteration 200: 0.03891426271384287
# Final cost : 0.03891426271384287
# Compute control for a deterministic system
# Cost in iteration 0: 0.03891426271384287
# Cost in iteration 200: 0.03889934114479842
# Cost in iteration 400: 0.038889763609393835
# Final cost : 0.038889763609393835
# Compute control for a deterministic system
# Cost in iteration 0: 0.038889763609393835
# Cost in iteration 200: 0.038883633618974574
# Cost in iteration 400: 0.03887923138299396
# Cost in iteration 600: 0.03887572439784762
# Cost in iteration 800: 0.03887299629691102
# Cost in iteration 1000: 0.0388708580359028
# Final cost : 0.0388708580359028
# Compute control for a deterministic system
# Cost in iteration 0: 0.1542727538478487
# Cost in iteration 200: 0.029214796682015064
# Final cost : 0.029214796682015064
# Compute control for a deterministic system
# Cost in iteration 0: 0.029214796682015064
# Cost in iteration 200: 0.028945768272506115
# Final cost : 0.028945768272506115
# Compute control for a deterministic system
# Cost in iteration 0: 0.028945768272506115
# Cost in iteration 200: 0.028871092679624805
# Final cost : 0.028871092679624805
# Compute control for a deterministic system
# Cost in iteration 0: 0.028871092679624805
# Cost in iteration 200: 0.028835662882413026
# Cost in iteration 400: 0.02881610599036978
# Final cost : 0.02881610599036978
# Compute control for a deterministic system
# Cost in iteration 0: 0.02881610599036978
# Cost in iteration 200: 0.028802461048301725
# Cost in iteration 400: 0.028794748597500523
# Cost in iteration 600: 0.028789527662961285
# Cost in iteration 800: 0.02878642362965739
# Cost in iteration 1000: 0.028784749211159734
# Final cost : 0.028784749211159734
# Compute control for a deterministic system
# Cost in iteration 0: 0.05317508398616737
# Cost in iteration 200: 0.02607012632847709
# Final cost : 0.02607012632847709
# Compute control for a deterministic system
# Cost in iteration 0: 0.02607012632847709
# Cost in iteration 200: 0.025891335784442845
# Final cost : 0.025891335784442845
# Compute control for a deterministic system
# Cost in iteration 0: 0.025891335784442845
# Cost in iteration 200: 0.02585195943692145
# Final cost : 0.02585195943692145
# Compute control for a deterministic system
# Cost in iteration 0: 0.02585195943692145
# Cost in iteration 200: 0.025835093963646395
# Cost in iteration 400: 0.02582576424845685
# Final cost : 0.02582576424845685
# Compute control for a deterministic system
# Cost in iteration 0: 0.02582576424845685
# Cost in iteration 200: 0.025820096340814214
# Cost in iteration 400: 0.025815868453137117
# Cost in iteration 600: 0.025813757280046968
# Cost in iteration 800: 0.02581236665028974
# Cost in iteration 1000: 0.025811462861305114
# Final cost : 0.025811462861305114
# Compute control for a deterministic system
# Cost in iteration 0: 0.09575533689505969
# Cost in iteration 200: 0.022709112446344177
# Final cost : 0.022709112446344177
# Compute control for a deterministic system
# Cost in iteration 0: 0.022709112446344177
# Cost in iteration 200: 0.02247415632000243
# Final cost : 0.02247415632000243
# Compute control for a deterministic system
# Cost in iteration 0: 0.02247415632000243
# Cost in iteration 200: 0.022412412963668346
# Final cost : 0.022412412963668346
# Compute control for a deterministic system
# Cost in iteration 0: 0.022412412963668346
# Cost in iteration 200: 0.02238725537064178
# Cost in iteration 400: 0.022373754802841542
# Final cost : 0.022373754802841542
# Compute control for a deterministic system
# Cost in iteration 0: 0.022373754802841542
# Cost in iteration 200: 0.022365832337774526
# Cost in iteration 400: 0.022360223113816673
# Cost in iteration 600: 0.02235742272987665
# Cost in iteration 800: 0.0223556493217799
# Cost in iteration 1000: 0.022354524109250783
# Final cost : 0.022354524109250783
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195504344470226
# Cost in iteration 200: 0.01948188394365047
# Final cost : 0.01948188394365047
# Compute control for a deterministic system
# Cost in iteration 0: 0.01948188394365047
# Cost in iteration 200: 0.019260858961293276
# Final cost : 0.019260858961293276
# Compute control for a deterministic system
# Cost in iteration 0: 0.019260858961293276
# Cost in iteration 200: 0.019207917248101444
# Final cost : 0.019207917248101444
# Compute control for a deterministic system
# Cost in iteration 0: 0.019207917248101444
# Cost in iteration 200: 0.019186131346699824
# Cost in iteration 400: 0.019174472371663594
# Final cost : 0.019174472371663594
# Compute control for a deterministic system
# Cost in iteration 0: 0.019174472371663594
# Cost in iteration 200: 0.019167039772310573
# Cost in iteration 400: 0.019163499465012904
# Cost in iteration 600: 0.019161167166733408
# Cost in iteration 800: 0.01915975397147211
# Cost in iteration 1000: 0.01915910068057391
# Final cost : 0.01915910068057391
# Compute control for a deterministic system
# Cost in iteration 0: 0.058149803297793415
# Cost in iteration 200: 0.01651083606379937
# Final cost : 0.01651083606379937
# Compute control for a deterministic system
# Cost in iteration 0: 0.01651083606379937
# Cost in iteration 200: 0.016316693808444954
# Final cost : 0.016316693808444954
# Compute control for a deterministic system
# Cost in iteration 0: 0.016316693808444954
# Cost in iteration 200: 0.01626681713141833
# Final cost : 0.01626681713141833
# Compute control for a deterministic system
# Cost in iteration 0: 0.01626681713141833
# Cost in iteration 200: 0.016247425494020997
# Cost in iteration 400: 0.01623719538791838
# Final cost : 0.01623719538791838
# Compute control for a deterministic system
# Cost in iteration 0: 0.01623719538791838
# Cost in iteration 200: 0.016231710200348345
# Cost in iteration 400: 0.01622844106326295
# Cost in iteration 600: 0.016226578181109137
# Cost in iteration 800: 0.01622555060230828
# Cost in iteration 1000: 0.016225060996380474
# Final cost : 0.016225060996380474
# Compute control for a deterministic system
# Cost in iteration 0: 0.08640148917190292
# Cost in iteration 200: 0.014225317975270066
# Final cost : 0.014225317975270066
# Compute control for a deterministic system
# Cost in iteration 0: 0.014225317975270066
# Cost in iteration 200: 0.014109754727698565
# Final cost : 0.014109754727698565
# Compute control for a deterministic system
# Cost in iteration 0: 0.014109754727698565
# Cost in iteration 200: 0.014086512215657527
# Final cost : 0.014086512215657527
# Compute control for a deterministic system
# Cost in iteration 0: 0.014086512215657527
# Cost in iteration 200: 0.01407699677218447
# Cost in iteration 400: 0.014072110755014168
# Final cost : 0.014072110755014168
# Compute control for a deterministic system
# Cost in iteration 0: 0.014072110755014168
# Cost in iteration 200: 0.01406964813124237
# Cost in iteration 400: 0.014068461856416732
# Cost in iteration 600: 0.014067816702626698
# Cost in iteration 800: 0.01406750273231412
# Cost in iteration 1000: 0.014067346933810034
# Final cost : 0.014067346933810034
# Compute control for a deterministic system
# Cost in iteration 0: 0.10539058356641387
# Cost in iteration 200: 0.011816886963234493
# Final cost : 0.011816886963234493
# Compute control for a deterministic system
# Cost in iteration 0: 0.011816886963234493
# Cost in iteration 200: 0.011662366781223482
# Final cost : 0.011662366781223482
# Compute control for a deterministic system
# Cost in iteration 0: 0.011662366781223482
# Cost in iteration 200: 0.01163171696503881
# Final cost : 0.01163171696503881
# Compute control for a deterministic system
# Cost in iteration 0: 0.01163171696503881
# Cost in iteration 200: 0.011618916258742685
# Cost in iteration 400: 0.011612589220586344
# Final cost : 0.011612589220586344
# Compute control for a deterministic system
# Cost in iteration 0: 0.011612589220586344
# Cost in iteration 200: 0.011609392220454871
# Cost in iteration 400: 0.01160789925959052
# Cost in iteration 600: 0.011607160295675692
# Cost in iteration 800: 0.011606817389930534
# Cost in iteration 1000: 0.011606658589878966
# Final cost : 0.011606658589878966
# Compute control for a deterministic system
# Cost in iteration 0: 0.05813542659105428
# Cost in iteration 200: 0.009586564398685493
# Final cost : 0.009586564398685493
# Compute control for a deterministic system
# Cost in iteration 0: 0.009586564398685493
# Cost in iteration 200: 0.009451196122833381
# Final cost : 0.009451196122833381
# Compute control for a deterministic system
# Cost in iteration 0: 0.009451196122833381
# Cost in iteration 200: 0.009422137789471844
# Final cost : 0.009422137789471844
# Compute control for a deterministic system
# Cost in iteration 0: 0.009422137789471844
# Cost in iteration 200: 0.009411976533754259
# Cost in iteration 400: 0.009407331114703127
# Final cost : 0.009407331114703127
# Compute control for a deterministic system
# Cost in iteration 0: 0.009407331114703127
# Cost in iteration 200: 0.009405235564336768
# Cost in iteration 400: 0.00940424918840565
# Cost in iteration 600: 0.009403886492842435
# Cost in iteration 800: 0.009403689587513083
# Cost in iteration 1000: 0.009403606121540104
# Final cost : 0.009403606121540104
# Compute control for a deterministic system
# Cost in iteration 0: 0.028394901932446773
# Cost in iteration 200: 0.007922519389255919
# Final cost : 0.007922519389255919
# Compute control for a deterministic system
# Cost in iteration 0: 0.007922519389255919
# Cost in iteration 200: 0.00784302371887417
# Final cost : 0.00784302371887417
# Compute control for a deterministic system
# Cost in iteration 0: 0.00784302371887417
# Cost in iteration 200: 0.00783026492120557
# Final cost : 0.00783026492120557
# Compute control for a deterministic system
# Cost in iteration 0: 0.00783026492120557
# Cost in iteration 200: 0.007825285090509771
# Cost in iteration 400: 0.007823025966514867
# Final cost : 0.007823025966514867
# Compute control for a deterministic system
# Cost in iteration 0: 0.007823025966514867
# Cost in iteration 200: 0.007822307447559832
# Cost in iteration 400: 0.007822073783818412
# Cost in iteration 600: 0.007821975642662047
# Cost in iteration 800: 0.0078219285273241
# Cost in iteration 1000: 0.007821912028028483
# Final cost : 0.007821912028028483
# Compute control for a deterministic system
# Cost in iteration 0: 0.047669443636501774
# Cost in iteration 200: 0.006191336400950607
# Final cost : 0.006191336400950607
# Compute control for a deterministic system
# Cost in iteration 0: 0.006191336400950607
# Cost in iteration 200: 0.00609079719636233
# Final cost : 0.00609079719636233
# Compute control for a deterministic system
# Cost in iteration 0: 0.00609079719636233
# Cost in iteration 200: 0.0060741144500014105
# Final cost : 0.0060741144500014105
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060741144500014105
# Cost in iteration 200: 0.006067717436695395
# Cost in iteration 400: 0.0060650280372474075
# Final cost : 0.0060650280372474075
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060650280372474075
# Cost in iteration 200: 0.006064376054793088
# Cost in iteration 400: 0.006064179092447074
# Cost in iteration 600: 0.006064094312056702
# Cost in iteration 800: 0.006064057386342904
# Cost in iteration 1000: 0.006064041320943605
# Final cost : 0.006064041320943605
# Compute control for a deterministic system
# Cost in iteration 0: 0.060559265299067036
# Cost in iteration 200: 0.0046414170248542126
# Final cost : 0.0046414170248542126
# Compute control for a deterministic system
# Cost in iteration 0: 0.0046414170248542126
# Cost in iteration 200: 0.0045590615330470185
# Final cost : 0.0045590615330470185
# Compute control for a deterministic system
# Cost in iteration 0: 0.0045590615330470185
# Cost in iteration 200: 0.004548223232537065
# Final cost : 0.004548223232537065
# Compute control for a deterministic system
# Cost in iteration 0: 0.004548223232537065
# Cost in iteration 200: 0.00454437833603665
# Cost in iteration 400: 0.004542969244585525
# Final cost : 0.004542969244585525
# Compute control for a deterministic system
# Cost in iteration 0: 0.004542969244585525
# Cost in iteration 200: 0.004542497898945429
# Cost in iteration 400: 0.004542347223876126
# Cost in iteration 600: 0.0045422864102794384
# Cost in iteration 800: 0.004542261934799941
# Cost in iteration 1000: 0.004542252066875213
# Final cost : 0.004542252066875213
# Compute control for a deterministic system
# Cost in iteration 0: 0.02187670606030688
# Cost in iteration 200: 0.003324285740991501
# Final cost : 0.003324285740991501
# Compute control for a deterministic system
# Cost in iteration 0: 0.003324285740991501
# Cost in iteration 200: 0.0032609890733200325
# Final cost : 0.0032609890733200325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032609890733200325
# Cost in iteration 200: 0.003253024120618761
# Final cost : 0.003253024120618761
# Compute control for a deterministic system
# Cost in iteration 0: 0.003253024120618761
# Cost in iteration 200: 0.0032505367573621847
# Cost in iteration 400: 0.00324969098370115
# Final cost : 0.00324969098370115
# Compute control for a deterministic system
# Cost in iteration 0: 0.00324969098370115
# Cost in iteration 200: 0.0032494572917546806
# Cost in iteration 400: 0.0032493849337047096
# Cost in iteration 600: 0.0032493586662562684
# Cost in iteration 800: 0.003249349204559935
# Cost in iteration 1000: 0.003249345750160305
# Final cost : 0.003249345750160305
# Compute control for a deterministic system
# Cost in iteration 0: 0.046239302373143984
# Cost in iteration 200: 0.002411844257480257
# Final cost : 0.002411844257480257
# Compute control for a deterministic system
# Cost in iteration 0: 0.002411844257480257
# Cost in iteration 200: 0.0023804908840201655
# Final cost : 0.0023804908840201655
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023804908840201655
# Cost in iteration 200: 0.002376946711222124
# Final cost : 0.002376946711222124
# Compute control for a deterministic system
# Cost in iteration 0: 0.002376946711222124
# Cost in iteration 200: 0.002375988060653792
# Cost in iteration 400: 0.002375723555275187
# Final cost : 0.002375723555275187
# Compute control for a deterministic system
# Cost in iteration 0: 0.002375723555275187
# Cost in iteration 200: 0.0023756666290431416
# Cost in iteration 400: 0.002375653513819233
# Cost in iteration 600: 0.0023756492921524815
# Cost in iteration 800: 0.002375647894134174
# Cost in iteration 1000: 0.0023756474303281115
# Final cost : 0.0023756474303281115
# Compute control for a deterministic system
# Cost in iteration 0: 0.04383056388525451
# Cost in iteration 200: 0.0015192058599905215
# Final cost : 0.0015192058599905215
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015192058599905215
# Cost in iteration 200: 0.0014846975656553636
# Final cost : 0.0014846975656553636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014846975656553636
# Cost in iteration 200: 0.0014810750552468035
# Final cost : 0.0014810750552468035
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014810750552468035
# Cost in iteration 200: 0.0014801966516793947
# Cost in iteration 400: 0.001479981063389682
# Final cost : 0.001479981063389682
# Compute control for a deterministic system
# Cost in iteration 0: 0.001479981063389682
# Cost in iteration 200: 0.0014799442253017178
# Cost in iteration 400: 0.0014799354647505526
# Cost in iteration 600: 0.0014799339718827445
# Cost in iteration 800: 0.001479933535938352
# Cost in iteration 1000: 0.0014799334067819052
# Final cost : 0.0014799334067819052
# Compute control for a deterministic system
# Cost in iteration 0: 0.04903392985784852
# Cost in iteration 200: 0.0008221996386398369
# Final cost : 0.0008221996386398369
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008221996386398369
# Cost in iteration 200: 0.0008010325793703906
# Final cost : 0.0008010325793703906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008010325793703906
# Cost in iteration 200: 0.0007989169694241644
# Final cost : 0.0007989169694241644
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007989169694241644
# Cost in iteration 200: 0.0007984739026694012
# Cost in iteration 400: 0.0007984028169818556
# Final cost : 0.0007984028169818556
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007984028169818556
# Cost in iteration 200: 0.0007983934420120043
# Cost in iteration 400: 0.0007983916573557312
# Cost in iteration 600: 0.000798391286850697
# Cost in iteration 800: 0.0007983911916531573
# Cost in iteration 1000: 0.0007983911672575882
# Final cost : 0.0007983911672575882
# Compute control for a deterministic system
# Cost in iteration 0: 0.041214106306506
# Cost in iteration 200: 0.000339494710879551
# Final cost : 0.000339494710879551
# Compute control for a deterministic system
# Cost in iteration 0: 0.000339494710879551
# Cost in iteration 200: 0.00032850934720450993
# Final cost : 0.00032850934720450993
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032850934720450993
# Cost in iteration 200: 0.0003275394282961671
# Final cost : 0.0003275394282961671
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003275394282961671
# Cost in iteration 200: 0.0003273788880894366
# Cost in iteration 400: 0.00032735010115263647
# Final cost : 0.00032735010115263647
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032735010115263647
# Cost in iteration 200: 0.0003273446441308923
# Cost in iteration 400: 0.0003273434847597578
# Cost in iteration 600: 0.0003273432439002225
# Cost in iteration 800: 0.00032734319355038477
# Cost in iteration 1000: 0.0003273431829693014
# Final cost : 0.0003273431829693014
# Compute control for a deterministic system
# Cost in iteration 0: 0.021764251292719583
# Cost in iteration 200: 0.00010319492554088181
# Final cost : 0.00010319492554088181
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010319492554088181
# Cost in iteration 200: 0.00010016174425183154
# Final cost : 0.00010016174425183154
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010016174425183154
# Cost in iteration 200: 9.995524951708473e-05
# Final cost : 9.995524951708473e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.995524951708473e-05
# Cost in iteration 200: 9.992544945396201e-05
# Cost in iteration 400: 9.992040777421288e-05
# Final cost : 9.992040777421288e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.992040777421288e-05
# Cost in iteration 200: 9.991955007725999e-05
# Cost in iteration 400: 9.991939368825676e-05
# Cost in iteration 600: 9.99193648254072e-05
# Cost in iteration 800: 9.991935951317921e-05
# Cost in iteration 1000: 9.991935851011771e-05
# Final cost : 9.991935851011771e-05
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.02490543947516518
# Cost in iteration 200: 0.0003278709823753936
# Final cost : 0.0003278709823753936
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003278709823753936
# Cost in iteration 200: 0.00032741928202432844
# Final cost : 0.00032741928202432844
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032741928202432844
# Cost in iteration 200: 0.00032735488520784867
# Cost in iteration 400: 0.0003273454080236683
# Final cost : 0.0003273454080236683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003273454080236683
# Cost in iteration 200: 0.0003273436382286442
# Cost in iteration 400: 0.00032734327685399254
# Cost in iteration 600: 0.0003273432003930812
# Cost in iteration 800: 0.0003273431843853101
# Cost in iteration 1000: 0.00032734318099064886
# Final cost : 0.00032734318099064886
# Compute control for a deterministic system
# Cost in iteration 0: 0.04736399592816771
# Cost in iteration 200: 0.0008089085372819324
# Final cost : 0.0008089085372819324
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008089085372819324
# Cost in iteration 200: 0.0007994271096784867
# Final cost : 0.0007994271096784867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007994271096784867
# Cost in iteration 200: 0.0007985011014116369
# Cost in iteration 400: 0.000798404756576106
# Final cost : 0.000798404756576106
# Compute control for a deterministic system
# Cost in iteration 0: 0.000798404756576106
# Cost in iteration 200: 0.0007983933661039024
# Cost in iteration 400: 0.0007983914947298777
# Cost in iteration 600: 0.0007983912304897881
# Cost in iteration 800: 0.0007983911770206432
# Cost in iteration 1000: 0.0007983911634768602
# Final cost : 0.0007983911634768602
# Compute control for a deterministic system
# Cost in iteration 0: 0.04729329441454331
# Cost in iteration 200: 0.0014950462216209862
# Final cost : 0.0014950462216209862
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014950462216209862
# Cost in iteration 200: 0.001481281102090436
# Final cost : 0.001481281102090436
# Compute control for a deterministic system
# Cost in iteration 0: 0.001481281102090436
# Cost in iteration 200: 0.0014801250459825959
# Cost in iteration 400: 0.0014799529503217326
# Final cost : 0.0014799529503217326
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014799529503217326
# Cost in iteration 200: 0.0014799378901089893
# Cost in iteration 400: 0.0014799342573557585
# Cost in iteration 600: 0.0014799336160884545
# Cost in iteration 800: 0.001479933430471999
# Cost in iteration 1000: 0.0014799333753846135
# Final cost : 0.0014799333753846135
# Compute control for a deterministic system
# Cost in iteration 0: 0.04082979469905909
# Cost in iteration 200: 0.002394126862977452
# Final cost : 0.002394126862977452
# Compute control for a deterministic system
# Cost in iteration 0: 0.002394126862977452
# Cost in iteration 200: 0.0023781457392025485
# Final cost : 0.0023781457392025485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023781457392025485
# Cost in iteration 200: 0.0023762638008492836
# Cost in iteration 400: 0.002375745313950733
# Final cost : 0.002375745313950733
# Compute control for a deterministic system
# Cost in iteration 0: 0.002375745313950733
# Cost in iteration 200: 0.002375671695510451
# Cost in iteration 400: 0.00237565450647856
# Cost in iteration 600: 0.0023756496026115523
# Cost in iteration 800: 0.002375647992493771
# Cost in iteration 1000: 0.002375647460443976
# Final cost : 0.002375647460443976
# Compute control for a deterministic system
# Cost in iteration 0: 0.03472052617853104
# Cost in iteration 200: 0.0032665781201009487
# Final cost : 0.0032665781201009487
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032665781201009487
# Cost in iteration 200: 0.0032525610058140313
# Final cost : 0.0032525610058140313
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032525610058140313
# Cost in iteration 200: 0.003250241293072677
# Cost in iteration 400: 0.003249598521759866
# Final cost : 0.003249598521759866
# Compute control for a deterministic system
# Cost in iteration 0: 0.003249598521759866
# Cost in iteration 200: 0.0032494324806142164
# Cost in iteration 400: 0.003249375031877805
# Cost in iteration 600: 0.003249354976427647
# Cost in iteration 800: 0.0032493478173887536
# Cost in iteration 1000: 0.0032493452218750373
# Final cost : 0.0032493452218750373
# Compute control for a deterministic system
# Cost in iteration 0: 0.05953310391762006
# Cost in iteration 200: 0.004567370690678926
# Final cost : 0.004567370690678926
# Compute control for a deterministic system
# Cost in iteration 0: 0.004567370690678926
# Cost in iteration 200: 0.004547484177277856
# Final cost : 0.004547484177277856
# Compute control for a deterministic system
# Cost in iteration 0: 0.004547484177277856
# Cost in iteration 200: 0.004543800700689395
# Cost in iteration 400: 0.004542578907498547
# Final cost : 0.004542578907498547
# Compute control for a deterministic system
# Cost in iteration 0: 0.004542578907498547
# Cost in iteration 200: 0.004542345889814381
# Cost in iteration 400: 0.004542284142331505
# Cost in iteration 600: 0.004542260910130135
# Cost in iteration 800: 0.004542251671203369
# Cost in iteration 1000: 0.004542247933308047
# Final cost : 0.004542247933308047
# Compute control for a deterministic system
# Cost in iteration 0: 0.033038372318527846
# Cost in iteration 200: 0.006085004489109568
# Final cost : 0.006085004489109568
# Compute control for a deterministic system
# Cost in iteration 0: 0.006085004489109568
# Cost in iteration 200: 0.006070214449363821
# Final cost : 0.006070214449363821
# Compute control for a deterministic system
# Cost in iteration 0: 0.006070214449363821
# Cost in iteration 200: 0.006066236923686473
# Cost in iteration 400: 0.006064825038124628
# Final cost : 0.006064825038124628
# Compute control for a deterministic system
# Cost in iteration 0: 0.006064825038124628
# Cost in iteration 200: 0.006064361301748644
# Cost in iteration 400: 0.0060641712939187645
# Cost in iteration 600: 0.006064090468703917
# Cost in iteration 800: 0.006064055759806657
# Cost in iteration 1000: 0.006064040596340008
# Final cost : 0.006064040596340008
# Compute control for a deterministic system
# Cost in iteration 0: 0.04803573957501335
# Cost in iteration 200: 0.007851079355629993
# Final cost : 0.007851079355629993
# Compute control for a deterministic system
# Cost in iteration 0: 0.007851079355629993
# Cost in iteration 200: 0.007831423250106962
# Final cost : 0.007831423250106962
# Compute control for a deterministic system
# Cost in iteration 0: 0.007831423250106962
# Cost in iteration 200: 0.007825545114031779
# Cost in iteration 400: 0.007823367408490782
# Final cost : 0.007823367408490782
# Compute control for a deterministic system
# Cost in iteration 0: 0.007823367408490782
# Cost in iteration 200: 0.007822559908103668
# Cost in iteration 400: 0.007822201962131651
# Cost in iteration 600: 0.007822039248468877
# Cost in iteration 800: 0.007821963842230743
# Cost in iteration 1000: 0.007821928646610415
# Final cost : 0.007821928646610415
# Compute control for a deterministic system
# Cost in iteration 0: 0.04074386515277649
# Cost in iteration 200: 0.009427798215225873
# Final cost : 0.009427798215225873
# Compute control for a deterministic system
# Cost in iteration 0: 0.009427798215225873
# Cost in iteration 200: 0.009411104549755795
# Final cost : 0.009411104549755795
# Compute control for a deterministic system
# Cost in iteration 0: 0.009411104549755795
# Cost in iteration 200: 0.00940667281964155
# Cost in iteration 400: 0.009404827408429675
# Final cost : 0.009404827408429675
# Compute control for a deterministic system
# Cost in iteration 0: 0.009404827408429675
# Cost in iteration 200: 0.009404148103614651
# Cost in iteration 400: 0.00940382535724185
# Cost in iteration 600: 0.009403670475291894
# Cost in iteration 800: 0.009403595360081191
# Cost in iteration 1000: 0.009403558875621209
# Final cost : 0.009403558875621209
# Compute control for a deterministic system
# Cost in iteration 0: 0.03618593719614145
# Cost in iteration 200: 0.011652897674962236
# Final cost : 0.011652897674962236
# Compute control for a deterministic system
# Cost in iteration 0: 0.011652897674962236
# Cost in iteration 200: 0.01162204518444575
# Final cost : 0.01162204518444575
# Compute control for a deterministic system
# Cost in iteration 0: 0.01162204518444575
# Cost in iteration 200: 0.011613125524520063
# Cost in iteration 400: 0.011609432616078497
# Final cost : 0.011609432616078497
# Compute control for a deterministic system
# Cost in iteration 0: 0.011609432616078497
# Cost in iteration 200: 0.011607990363478402
# ...
# Cost in iteration 400: 0.025809709941808083
# Final cost : 0.025809709941808083
# Compute control for a deterministic system
# Cost in iteration 0: 0.025809709941808083
# Cost in iteration 200: 0.02580970993284054
# Cost in iteration 400: 0.025809709929123473
# Cost in iteration 600: 0.025809709926979885
# Cost in iteration 800: 0.025809709925898382
# Cost in iteration 1000: 0.02580970992515361
# Final cost : 0.02580970992515361
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.022906107314435306
# Cost in iteration 200: 0.022354426676699506
# Final cost : 0.022354426676699506
# Compute control for a deterministic system
# Cost in iteration 0: 0.022354426676699506
# Cost in iteration 200: 0.022352583507872902
# Final cost : 0.022352583507872902
# Compute control for a deterministic system
# Cost in iteration 0: 0.022352583507872902
# Cost in iteration 200: 0.02235255577210498
# Final cost : 0.02235255577210498
# Compute control for a deterministic system
# Cost in iteration 0: 0.02235255577210498
# Cost in iteration 200: 0.022352554554289084
# Cost in iteration 400: 0.022352554458839782
# Final cost : 0.022352554458839782
# Compute control for a deterministic system
# Cost in iteration 0: 0.022352554458839782
# Cost in iteration 200: 0.022352554441317025
# Cost in iteration 400: 0.022352554436212427
# Cost in iteration 600: 0.022352554433742323
# Cost in iteration 800: 0.022352554432497142
# Cost in iteration 1000: 0.02235255443175565
# Final cost : 0.02235255443175565
# Compute control for a deterministic system
# Cost in iteration 0: 0.019594654151228616
# Cost in iteration 200: 0.019160247792009845
# Final cost : 0.019160247792009845
# Compute control for a deterministic system
# Cost in iteration 0: 0.019160247792009845
# Cost in iteration 200: 0.019158114621646582
# Final cost : 0.019158114621646582
# Compute control for a deterministic system
# Cost in iteration 0: 0.019158114621646582
# Cost in iteration 200: 0.019158077828270968
# Final cost : 0.019158077828270968
# Compute control for a deterministic system
# Cost in iteration 0: 0.019158077828270968
# Cost in iteration 200: 0.019158076079012848
# Cost in iteration 400: 0.019158075954481924
# Final cost : 0.019158075954481924
# Compute control for a deterministic system
# Cost in iteration 0: 0.019158075954481924
# Cost in iteration 200: 0.01915807593712844
# Cost in iteration 400: 0.01915807593151461
# Cost in iteration 600: 0.01915807592921074
# Cost in iteration 800: 0.019158075927967155
# Cost in iteration 1000: 0.01915807592726974
# Final cost : 0.01915807592726974
# Compute control for a deterministic system
# Cost in iteration 0: 0.01656200929006432
# Cost in iteration 200: 0.016226987023952325
# Final cost : 0.016226987023952325
# Compute control for a deterministic system
# Cost in iteration 0: 0.016226987023952325
# Cost in iteration 200: 0.01622457548597867
# Final cost : 0.01622457548597867
# Compute control for a deterministic system
# Cost in iteration 0: 0.01622457548597867
# Cost in iteration 200: 0.01622452950389336
# Final cost : 0.01622452950389336
# Compute control for a deterministic system
# Cost in iteration 0: 0.01622452950389336
# Cost in iteration 200: 0.0162245274585463
# Cost in iteration 400: 0.016224527320292115
# Final cost : 0.016224527320292115
# Compute control for a deterministic system
# Cost in iteration 0: 0.016224527320292115
# Cost in iteration 200: 0.01622452729676854
# Cost in iteration 400: 0.016224527290561577
# Cost in iteration 600: 0.016224527287463993
# Cost in iteration 800: 0.016224527285776138
# Cost in iteration 1000: 0.016224527284834755
# Final cost : 0.016224527284834755
# Compute control for a deterministic system
# Cost in iteration 0: 0.014339044288563923
# Cost in iteration 200: 0.014069820417791881
# Final cost : 0.014069820417791881
# Compute control for a deterministic system
# Cost in iteration 0: 0.014069820417791881
# Cost in iteration 200: 0.014067243085880449
# Final cost : 0.014067243085880449
# Compute control for a deterministic system
# Cost in iteration 0: 0.014067243085880449
# Cost in iteration 200: 0.014067195452806183
# Final cost : 0.014067195452806183
# Compute control for a deterministic system
# Cost in iteration 0: 0.014067195452806183
# Cost in iteration 200: 0.014067193295551622
# Cost in iteration 400: 0.014067193149197781
# Final cost : 0.014067193149197781
# Compute control for a deterministic system
# Cost in iteration 0: 0.014067193149197781
# Cost in iteration 200: 0.01406719312682534
# Cost in iteration 400: 0.014067193120475488
# Cost in iteration 600: 0.014067193117715369
# Cost in iteration 800: 0.014067193116359672
# Cost in iteration 1000: 0.014067193115775194
# Final cost : 0.014067193115775194
# Compute control for a deterministic system
# Cost in iteration 0: 0.011812114953762628
# Cost in iteration 200: 0.01160922061515436
# Final cost : 0.01160922061515436
# Compute control for a deterministic system
# Cost in iteration 0: 0.01160922061515436
# Cost in iteration 200: 0.011606562697596171
# Final cost : 0.011606562697596171
# Compute control for a deterministic system
# Cost in iteration 0: 0.011606562697596171
# Cost in iteration 200: 0.01160651255701541
# Final cost : 0.01160651255701541
# Compute control for a deterministic system
# Cost in iteration 0: 0.01160651255701541
# Cost in iteration 200: 0.011606510294794845
# Cost in iteration 400: 0.011606510148774308
# Final cost : 0.011606510148774308
# Compute control for a deterministic system
# Cost in iteration 0: 0.011606510148774308
# Cost in iteration 200: 0.011606510128282795
# Cost in iteration 400: 0.011606510122951465
# Cost in iteration 600: 0.011606510120865854
# Cost in iteration 800: 0.011606510120004607
# Cost in iteration 1000: 0.011606510119561313
# Final cost : 0.011606510119561313
# Compute control for a deterministic system
# Cost in iteration 0: 0.009557749143321135
# Cost in iteration 200: 0.009406156069514336
# Final cost : 0.009406156069514336
# Compute control for a deterministic system
# Cost in iteration 0: 0.009406156069514336
# Cost in iteration 200: 0.009403570033364013
# Final cost : 0.009403570033364013
# Compute control for a deterministic system
# Cost in iteration 0: 0.009403570033364013
# Cost in iteration 200: 0.009403524701957315
# Final cost : 0.009403524701957315
# Compute control for a deterministic system
# Cost in iteration 0: 0.009403524701957315
# Cost in iteration 200: 0.009403522952286162
# Cost in iteration 400: 0.009403522853788078
# Final cost : 0.009403522853788078
# Compute control for a deterministic system
# Cost in iteration 0: 0.009403522853788078
# Cost in iteration 200: 0.009403522840795016
# Cost in iteration 400: 0.009403522838255747
# Cost in iteration 600: 0.009403522837165931
# Cost in iteration 800: 0.009403522836658358
# Cost in iteration 1000: 0.009403522836413648
# Final cost : 0.009403522836413648
# Compute control for a deterministic system
# Cost in iteration 0: 0.007943602630623194
# Cost in iteration 200: 0.00782436054103902
# Final cost : 0.00782436054103902
# Compute control for a deterministic system
# Cost in iteration 0: 0.00782436054103902
# Cost in iteration 200: 0.007821945862448249
# Final cost : 0.007821945862448249
# Compute control for a deterministic system
# Cost in iteration 0: 0.007821945862448249
# Cost in iteration 200: 0.007821899631136747
# Final cost : 0.007821899631136747
# Compute control for a deterministic system
# Cost in iteration 0: 0.007821899631136747
# Cost in iteration 200: 0.00782189757382755
# Cost in iteration 400: 0.007821897437864024
# Final cost : 0.007821897437864024
# Compute control for a deterministic system
# Cost in iteration 0: 0.007821897437864024
# Cost in iteration 200: 0.007821897425268703
# Cost in iteration 400: 0.007821897423220063
# Cost in iteration 600: 0.007821897422423667
# Cost in iteration 800: 0.007821897422077045
# Cost in iteration 1000: 0.007821897421917808
# Final cost : 0.007821897421917808
# Compute control for a deterministic system
# Cost in iteration 0: 0.006153426241766026
# Cost in iteration 200: 0.006066173672087008
# Final cost : 0.006066173672087008
# Compute control for a deterministic system
# Cost in iteration 0: 0.006066173672087008
# Cost in iteration 200: 0.006064065298937425
# Final cost : 0.006064065298937425
# Compute control for a deterministic system
# Cost in iteration 0: 0.006064065298937425
# Cost in iteration 200: 0.0060640300321831925
# Final cost : 0.0060640300321831925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0060640300321831925
# Cost in iteration 200: 0.00606402890655517
# Cost in iteration 400: 0.006064028847810639
# Final cost : 0.006064028847810639
# Compute control for a deterministic system
# Cost in iteration 0: 0.006064028847810639
# Cost in iteration 200: 0.006064028841805187
# Cost in iteration 400: 0.006064028840828333
# Cost in iteration 600: 0.0060640288405146665
# Cost in iteration 800: 0.006064028840391491
# Cost in iteration 1000: 0.006064028840334302
# Final cost : 0.006064028840334302
# Compute control for a deterministic system
# Cost in iteration 0: 0.004606494828461164
# Cost in iteration 200: 0.00454399872759579
# Final cost : 0.00454399872759579
# Compute control for a deterministic system
# Cost in iteration 0: 0.00454399872759579
# Cost in iteration 200: 0.004542274024748133
# Final cost : 0.004542274024748133
# Compute control for a deterministic system
# Cost in iteration 0: 0.004542274024748133
# Cost in iteration 200: 0.0045422467241446485
# Final cost : 0.0045422467241446485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0045422467241446485
# Cost in iteration 200: 0.004542245476383494
# Cost in iteration 400: 0.00454224541636221
# Final cost : 0.00454224541636221
# Compute control for a deterministic system
# Cost in iteration 0: 0.00454224541636221
# Cost in iteration 200: 0.0045422454137430705
# Cost in iteration 400: 0.004542245413373752
# Cost in iteration 600: 0.004542245413266607
# Cost in iteration 800: 0.004542245413214982
# Converged in iteration 826 with cost 0.004542245413205797 because of step counter
# Final cost : 0.004542245413205797
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032939395240902673
# Cost in iteration 200: 0.003250680614576448
# Final cost : 0.003250680614576448
# Compute control for a deterministic system
# Cost in iteration 0: 0.003250680614576448
# Cost in iteration 200: 0.0032493670898606462
# Final cost : 0.0032493670898606462
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032493670898606462
# Cost in iteration 200: 0.0032493447384516747
# Final cost : 0.0032493447384516747
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032493447384516747
# Cost in iteration 200: 0.003249343789368033
# Cost in iteration 400: 0.003249343746672448
# Final cost : 0.003249343746672448
# Compute control for a deterministic system
# Cost in iteration 0: 0.003249343746672448
# Cost in iteration 200: 0.0032493437416085467
# Cost in iteration 400: 0.0032493437411070425
# Cost in iteration 600: 0.0032493437410091486
# Converged in iteration 769 with cost 0.003249343740968802 because of step counter
# Final cost : 0.003249343740968802
# Compute control for a deterministic system
# Cost in iteration 0: 0.002407696599019165
# Cost in iteration 200: 0.0023766615535848043
# Final cost : 0.0023766615535848043
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023766615535848043
# Cost in iteration 200: 0.002375665278559172
# Final cost : 0.002375665278559172
# Compute control for a deterministic system
# Cost in iteration 0: 0.002375665278559172
# Cost in iteration 200: 0.0023756479842743164
# Final cost : 0.0023756479842743164
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023756479842743164
# Cost in iteration 200: 0.0023756472367799123
# Cost in iteration 400: 0.002375647198501871
# Final cost : 0.002375647198501871
# Compute control for a deterministic system
# Cost in iteration 0: 0.002375647198501871
# Cost in iteration 200: 0.0023756471960163453
# Cost in iteration 400: 0.002375647195695211
# Cost in iteration 600: 0.0023756471956556937
# Converged in iteration 609 with cost 0.0023756471956549318 because of step counter
# Final cost : 0.0023756471956549318
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014996185160060503
# Cost in iteration 200: 0.0014805859051558914
# Final cost : 0.0014805859051558914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014805859051558914
# Cost in iteration 200: 0.001479944261241016
# Final cost : 0.001479944261241016
# Compute control for a deterministic system
# Cost in iteration 0: 0.001479944261241016
# Cost in iteration 200: 0.0014799338339765628
# Final cost : 0.0014799338339765628
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014799338339765628
# Cost in iteration 200: 0.0014799333747466743
# Cost in iteration 400: 0.0014799333537233942
# Final cost : 0.0014799333537233942
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014799333537233942
# Cost in iteration 200: 0.0014799333522102173
# Cost in iteration 400: 0.0014799333520052436
# Converged in iteration 581 with cost 0.0014799333519679948 because of step counter
# Final cost : 0.0014799333519679948
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008089345473207388
# Cost in iteration 200: 0.0007987500154835116
# Final cost : 0.0007987500154835116
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007987500154835116
# Cost in iteration 200: 0.0007983978820725489
# Final cost : 0.0007983978820725489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007983978820725489
# Cost in iteration 200: 0.0007983914485647184
# Final cost : 0.0007983914485647184
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007983914485647184
# Cost in iteration 200: 0.0007983911737071077
# Cost in iteration 400: 0.000798391159379741
# Final cost : 0.000798391159379741
# Compute control for a deterministic system
# Cost in iteration 0: 0.000798391159379741
# Cost in iteration 200: 0.0007983911588737021
# Cost in iteration 400: 0.0007983911588194147
# Converged in iteration 451 with cost 0.0007983911588152395 because of step counter
# Final cost : 0.0007983911588152395
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033166082512880036
# Cost in iteration 200: 0.0003274915707908467
# Final cost : 0.0003274915707908467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003274915707908467
# Cost in iteration 200: 0.00032734587889972095
# Final cost : 0.00032734587889972095
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032734587889972095
# Cost in iteration 200: 0.00032734329961842725
# Final cost : 0.00032734329961842725
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032734329961842725
# Cost in iteration 200: 0.00032734318764392396
# Cost in iteration 400: 0.00032734318074758976
# Final cost : 0.00032734318074758976
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032734318074758976
# Cost in iteration 200: 0.0003273431801515755
# Cost in iteration 400: 0.00032734318007471074
# Cost in iteration 600: 0.0003273431800615847
# Converged in iteration 604 with cost 0.00032734318006155157 because of step counter
# Final cost : 0.00032734318006155157
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010124130244282892
# Cost in iteration 200: 9.996466201700925e-05
# Final cost : 9.996466201700925e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.996466201700925e-05
# Cost in iteration 200: 9.992020435869771e-05
# Final cost : 9.992020435869771e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.992020435869771e-05
# Cost in iteration 200: 9.991939735649655e-05
# Final cost : 9.991939735649655e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.991939735649655e-05
# Cost in iteration 200: 9.991936121962874e-05
# Cost in iteration 400: 9.991935855824291e-05
# Final cost : 9.991935855824291e-05
# Compute control for a deterministic system
# Cost in iteration 0: 9.991935855824291e-05
# Cost in iteration 200: 9.991935831690144e-05
# Cost in iteration 400: 9.991935828372856e-05
# Converged in iteration 567 with cost 9.991935827839419e-05 because of step counter
# Final cost : 9.991935827839419e-05

# %%
save(results_min)
