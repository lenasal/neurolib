# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
#options = [True, False, False, False, False, False, True, False]
options = [True, True, True, True, True, True, True, True]

for k in range(9):

    for i_w in range(len(results_min["w1"])):

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["models"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 1.1
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.02950294801196605
# Converged in iteration 103 with cost 0.01820345630779175 because of step counter
# Final cost : 0.01820345630779175
# Compute control for a deterministic system
# Cost in iteration 0: 0.01820345630779175
# Converged in iteration 1 with cost 0.01820345630779175 because of step counter
# Final cost : 0.01820345630779175
# Compute control for a deterministic system
# Cost in iteration 0: 0.01820345630779175
# Converged in iteration 1 with cost 0.01820345630779175 because of step counter
# Final cost : 0.01820345630779175
# Compute control for a deterministic system
# Cost in iteration 0: 0.01820345630779175
# Converged in iteration 1 with cost 0.01820345630779175 because of step counter
# Final cost : 0.01820345630779175
# Compute control for a deterministic system
# Cost in iteration 0: 0.01820345630779175
# Converged in iteration 1 with cost 0.01820345630779175 because of step counter
# Final cost : 0.01820345630779175
# Compute control for a deterministic system
# Cost in iteration 0: 0.041605937718283914
# Converged in iteration 104 with cost 0.02504928113002481 because of step counter
# Final cost : 0.02504928113002481
# Compute control for a deterministic system
# Cost in iteration 0: 0.02504928113002481
# Converged in iteration 1 with cost 0.02504928113002481 because of step counter
# Final cost : 0.02504928113002481
# Compute control for a deterministic system
# Cost in iteration 0: 0.02504928113002481
# Converged in iteration 1 with cost 0.02504928113002481 because of step counter
# Final cost : 0.02504928113002481
# Compute control for a deterministic system
# Cost in iteration 0: 0.02504928113002481
# Converged in iteration 1 with cost 0.02504928113002481 because of step counter
# Final cost : 0.02504928113002481
# Compute control for a deterministic system
# Cost in iteration 0: 0.02504928113002481
# Converged in iteration 1 with cost 0.02504928113002481 because of step counter
# Final cost : 0.02504928113002481
# Compute control for a deterministic system
# Cost in iteration 0: 0.03945287032533122
# Converged in iteration 104 with cost 0.027874431576847755 because of step counter
# Final cost : 0.027874431576847755
# Compute control for a deterministic system
# Cost in iteration 0: 0.027874431576847755
# Converged in iteration 1 with cost 0.027874431576847755 because of step counter
# Final cost : 0.027874431576847755
# Compute control for a deterministic system
# Cost in iteration 0: 0.027874431576847755
# Converged in iteration 1 with cost 0.027874431576847755 because of step counter
# Final cost : 0.027874431576847755
# Compute control for a deterministic system
# Cost in iteration 0: 0.027874431576847755
# Converged in iteration 1 with cost 0.027874431576847755 because of step counter
# Final cost : 0.027874431576847755
# Compute control for a deterministic system
# Cost in iteration 0: 0.027874431576847755
# Converged in iteration 1 with cost 0.027874431576847755 because of step counter
# Final cost : 0.027874431576847755
# Compute control for a deterministic system
# Cost in iteration 0: 0.03860519551400006
# Converged in iteration 101 with cost 0.031515954340236615 because of step counter
# Final cost : 0.031515954340236615
# Compute control for a deterministic system
# Cost in iteration 0: 0.031515954340236615
# Converged in iteration 1 with cost 0.031515954340236615 because of step counter
# Final cost : 0.031515954340236615
# Compute control for a deterministic system
# Cost in iteration 0: 0.031515954340236615
# Converged in iteration 1 with cost 0.031515954340236615 because of step counter
# Final cost : 0.031515954340236615
# Compute control for a deterministic system
# Cost in iteration 0: 0.031515954340236615
# Converged in iteration 1 with cost 0.031515954340236615 because of step counter
# Final cost : 0.031515954340236615
# Compute control for a deterministic system
# Cost in iteration 0: 0.031515954340236615
# Converged in iteration 1 with cost 0.031515954340236615 because of step counter
# Final cost : 0.031515954340236615
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243335097825526
# Converged in iteration 82 with cost 0.03235454033246319 because of step counter
# Final cost : 0.03235454033246319
# Compute control for a deterministic system
# Cost in iteration 0: 0.03235454033246319
# Converged in iteration 1 with cost 0.03235454033246319 because of step counter
# Final cost : 0.03235454033246319
# Compute control for a deterministic system
# Cost in iteration 0: 0.03235454033246319
# Converged in iteration 1 with cost 0.03235454033246319 because of step counter
# Final cost : 0.03235454033246319
# Compute control for a deterministic system
# Cost in iteration 0: 0.03235454033246319
# Converged in iteration 1 with cost 0.03235454033246319 because of step counter
# Final cost : 0.03235454033246319
# Compute control for a deterministic system
# Cost in iteration 0: 0.03235454033246319
# Converged in iteration 1 with cost 0.03235454033246319 because of step counter
# Final cost : 0.03235454033246319
# Compute control for a deterministic system
# Cost in iteration 0: 0.04138870657728788
# Converged in iteration 87 with cost 0.03892257624651477 because of step counter
# Final cost : 0.03892257624651477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03892257624651477
# Converged in iteration 1 with cost 0.03892257624651477 because of step counter
# Final cost : 0.03892257624651477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03892257624651477
# Converged in iteration 1 with cost 0.03892257624651477 because of step counter
# Final cost : 0.03892257624651477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03892257624651477
# Converged in iteration 1 with cost 0.03892257624651477 because of step counter
# Final cost : 0.03892257624651477
# Compute control for a deterministic system
# Cost in iteration 0: 0.03892257624651477
# Converged in iteration 1 with cost 0.03892257624651477 because of step counter
# Final cost : 0.03892257624651477
# Compute control for a deterministic system
# Cost in iteration 0: 0.045928602538807754
# Converged in iteration 62 with cost 0.044022470279456834 because of step counter
# Final cost : 0.044022470279456834
# Compute control for a deterministic system
# Cost in iteration 0: 0.044022470279456834
# Converged in iteration 1 with cost 0.044022470279456834 because of step counter
# Final cost : 0.044022470279456834
# Compute control for a deterministic system
# Cost in iteration 0: 0.044022470279456834
# Converged in iteration 1 with cost 0.044022470279456834 because of step counter
# Final cost : 0.044022470279456834
# Compute control for a deterministic system
# Cost in iteration 0: 0.044022470279456834
# Converged in iteration 1 with cost 0.044022470279456834 because of step counter
# Final cost : 0.044022470279456834
# Compute control for a deterministic system
# Cost in iteration 0: 0.044022470279456834
# Converged in iteration 1 with cost 0.044022470279456834 because of step counter
# Final cost : 0.044022470279456834
# Compute control for a deterministic system
# Cost in iteration 0: 0.054022822845516696
# Converged in iteration 76 with cost 0.051540357598468485 because of step counter
# Final cost : 0.051540357598468485
# Compute control for a deterministic system
# Cost in iteration 0: 0.051540357598468485
# Converged in iteration 1 with cost 0.051540357598468485 because of step counter
# Final cost : 0.051540357598468485
# Compute control for a deterministic system
# Cost in iteration 0: 0.051540357598468485
# Converged in iteration 1 with cost 0.051540357598468485 because of step counter
# Final cost : 0.051540357598468485
# Compute control for a deterministic system
# Cost in iteration 0: 0.051540357598468485
# Converged in iteration 1 with cost 0.051540357598468485 because of step counter
# Final cost : 0.051540357598468485
# Compute control for a deterministic system
# Cost in iteration 0: 0.051540357598468485
# Converged in iteration 1 with cost 0.051540357598468485 because of step counter
# Final cost : 0.051540357598468485
# Compute control for a deterministic system
# Cost in iteration 0: 0.0527185686408395
# Converged in iteration 63 with cost 0.05243446044891487 because of step counter
# Final cost : 0.05243446044891487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05243446044891487
# Converged in iteration 1 with cost 0.05243446044891487 because of step counter
# Final cost : 0.05243446044891487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05243446044891487
# Converged in iteration 1 with cost 0.05243446044891487 because of step counter
# Final cost : 0.05243446044891487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05243446044891487
# Converged in iteration 1 with cost 0.05243446044891487 because of step counter
# Final cost : 0.05243446044891487
# Compute control for a deterministic system
# Cost in iteration 0: 0.05243446044891487
# Converged in iteration 1 with cost 0.05243446044891487 because of step counter
# Final cost : 0.05243446044891487
# Compute control for a deterministic system
# Cost in iteration 0: 0.06100048944093566
# Converged in iteration 117 with cost 0.05937521782066669 because of step counter
# Final cost : 0.05937521782066669
# Compute control for a deterministic system
# Cost in iteration 0: 0.05937521782066669
# Converged in iteration 1 with cost 0.05937521782066669 because of step counter
# Final cost : 0.05937521782066669
# Compute control for a deterministic system
# Cost in iteration 0: 0.05937521782066669
# Converged in iteration 1 with cost 0.05937521782066669 because of step counter
# Final cost : 0.05937521782066669
# Compute control for a deterministic system
# Cost in iteration 0: 0.05937521782066669
# Converged in iteration 1 with cost 0.05937521782066669 because of step counter
# Final cost : 0.05937521782066669
# Compute control for a deterministic system
# Cost in iteration 0: 0.05937521782066669
# Converged in iteration 1 with cost 0.05937521782066669 because of step counter
# Final cost : 0.05937521782066669
# Compute control for a deterministic system
# Cost in iteration 0: 0.06357564913273812
# Converged in iteration 123 with cost 0.06266174938919482 because of step counter
# Final cost : 0.06266174938919482
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266174938919482
# Converged in iteration 1 with cost 0.06266174938919482 because of step counter
# Final cost : 0.06266174938919482
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266174938919482
# Converged in iteration 1 with cost 0.06266174938919482 because of step counter
# Final cost : 0.06266174938919482
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266174938919482
# Converged in iteration 1 with cost 0.06266174938919482 because of step counter
# Final cost : 0.06266174938919482
# Compute control for a deterministic system
# Cost in iteration 0: 0.06266174938919482
# Converged in iteration 1 with cost 0.06266174938919482 because of step counter
# Final cost : 0.06266174938919482
# Compute control for a deterministic system
# Cost in iteration 0: 0.06850829696829225
# Converged in iteration 161 with cost 0.0679227887744614 because of step counter
# Final cost : 0.0679227887744614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679227887744614
# Converged in iteration 1 with cost 0.0679227887744614 because of step counter
# Final cost : 0.0679227887744614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679227887744614
# Converged in iteration 1 with cost 0.0679227887744614 because of step counter
# Final cost : 0.0679227887744614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679227887744614
# Converged in iteration 1 with cost 0.0679227887744614 because of step counter
# Final cost : 0.0679227887744614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679227887744614
# Converged in iteration 1 with cost 0.0679227887744614 because of step counter
# Final cost : 0.0679227887744614
# Compute control for a deterministic system
# Cost in iteration 0: 0.08150732174475836
# Cost in iteration 200: 0.06967881230463358
# Final cost : 0.06967881230463358
# Compute control for a deterministic system
# Cost in iteration 0: 0.06967881230463358
# Converged in iteration 29 with cost 0.0696700586377743 because of step counter
# Final cost : 0.0696700586377743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0696700586377743
# Converged in iteration 1 with cost 0.0696700586377743 because of step counter
# Final cost : 0.0696700586377743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0696700586377743
# Converged in iteration 1 with cost 0.0696700586377743 because of step counter
# Final cost : 0.0696700586377743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0696700586377743
# Converged in iteration 1 with cost 0.0696700586377743 because of step counter
# Final cost : 0.0696700586377743
# Compute control for a deterministic system
# Cost in iteration 0: 0.07583596221918479
# Converged in iteration 188 with cost 0.0734309452265987 because of vanishing difference
# Final cost : 0.0734309452265987
# Compute control for a deterministic system
# Cost in iteration 0: 0.0734309452265987
# Converged in iteration 10 with cost 0.07343094522209824 because of step counter
# Final cost : 0.07343094522209824
# Compute control for a deterministic system
# Cost in iteration 0: 0.07343094522209824
# Converged in iteration 1 with cost 0.07343094522209824 because of step counter
# Final cost : 0.07343094522209824
# Compute control for a deterministic system
# Cost in iteration 0: 0.07343094522209824
# Converged in iteration 1 with cost 0.07343094522209824 because of step counter
# Final cost : 0.07343094522209824
# Compute control for a deterministic system
# Cost in iteration 0: 0.07343094522209824
# Converged in iteration 1 with cost 0.07343094522209824 because of step counter
# Final cost : 0.07343094522209824
# Compute control for a deterministic system
# Cost in iteration 0: 0.07952299585059858
# Converged in iteration 165 with cost 0.07881565832350432 because of step counter
# Final cost : 0.07881565832350432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881565832350432
# Converged in iteration 1 with cost 0.07881565832350432 because of step counter
# Final cost : 0.07881565832350432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881565832350432
# Converged in iteration 1 with cost 0.07881565832350432 because of step counter
# Final cost : 0.07881565832350432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881565832350432
# Converged in iteration 1 with cost 0.07881565832350432 because of step counter
# Final cost : 0.07881565832350432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881565832350432
# Converged in iteration 1 with cost 0.07881565832350432 because of step counter
# Final cost : 0.07881565832350432
# Compute control for a deterministic system
# Cost in iteration 0: 0.08635706405007398
# Cost in iteration 200: 0.08488099384573035
# Final cost : 0.08488099384573035
# Compute control for a deterministic system
# Cost in iteration 0: 0.08488099384573035
# Converged in iteration 11 with cost 0.0847413068779044 because of step counter
# Final cost : 0.0847413068779044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847413068779044
# Converged in iteration 1 with cost 0.0847413068779044 because of step counter
# Final cost : 0.0847413068779044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847413068779044
# Converged in iteration 1 with cost 0.0847413068779044 because of step counter
# Final cost : 0.0847413068779044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0847413068779044
# Converged in iteration 1 with cost 0.0847413068779044 because of step counter
# Final cost : 0.0847413068779044
# Compute control for a deterministic system
# Cost in iteration 0: 0.09749497448853678
# Cost in iteration 200: 0.09428077664510262
# Final cost : 0.09428077664510262
# Compute control for a deterministic system
# Cost in iteration 0: 0.09428077664510262
# Converged in iteration 26 with cost 0.09426518737487459 because of step counter
# Final cost : 0.09426518737487459
# Compute control for a deterministic system
# Cost in iteration 0: 0.09426518737487459
# Converged in iteration 1 with cost 0.09426518737487459 because of step counter
# Final cost : 0.09426518737487459
# Compute control for a deterministic system
# Cost in iteration 0: 0.09426518737487459
# Converged in iteration 1 with cost 0.09426518737487459 because of step counter
# Final cost : 0.09426518737487459
# Compute control for a deterministic system
# Cost in iteration 0: 0.09426518737487459
# Converged in iteration 1 with cost 0.09426518737487459 because of step counter
# Final cost : 0.09426518737487459
# Compute control for a deterministic system
# Cost in iteration 0: 0.11461293723476408
# Cost in iteration 200: 0.10025270294204458
# Final cost : 0.10025270294204458
# Compute control for a deterministic system
# Cost in iteration 0: 0.10025270294204458
# Converged in iteration 31 with cost 0.09815310645168514 because of step counter
# Final cost : 0.09815310645168514
# Compute control for a deterministic system
# Cost in iteration 0: 0.09815310645168514
# Converged in iteration 1 with cost 0.09815310645168514 because of step counter
# Final cost : 0.09815310645168514
# Compute control for a deterministic system
# Cost in iteration 0: 0.09815310645168514
# Converged in iteration 1 with cost 0.09815310645168514 because of step counter
# Final cost : 0.09815310645168514
# Compute control for a deterministic system
# Cost in iteration 0: 0.09815310645168514
# Converged in iteration 1 with cost 0.09815310645168514 because of step counter
# Final cost : 0.09815310645168514
# Compute control for a deterministic system
# Cost in iteration 0: 0.10785570727367251
# Cost in iteration 200: 0.10195870322606332
# Final cost : 0.10195870322606332
# Compute control for a deterministic system
# Cost in iteration 0: 0.10195870322606332
# Converged in iteration 28 with cost 0.09978810731745165 because of step counter
# Final cost : 0.09978810731745165
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978810731745165
# Converged in iteration 1 with cost 0.09978810731745165 because of step counter
# Final cost : 0.09978810731745165
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978810731745165
# Converged in iteration 1 with cost 0.09978810731745165 because of step counter
# Final cost : 0.09978810731745165
# Compute control for a deterministic system
# Cost in iteration 0: 0.09978810731745165
# Converged in iteration 1 with cost 0.09978810731745165 because of step counter
# Final cost : 0.09978810731745165
# Compute control for a deterministic system
# Cost in iteration 0: 0.14693022121866287
# Converged in iteration 153 with cost 0.1171633695918648 because of step counter
# Final cost : 0.1171633695918648
# Compute control for a deterministic system
# Cost in iteration 0: 0.1171633695918648
# Converged in iteration 1 with cost 0.1171633695918648 because of step counter
# Final cost : 0.1171633695918648
# Compute control for a deterministic system
# Cost in iteration 0: 0.1171633695918648
# Converged in iteration 1 with cost 0.1171633695918648 because of step counter
# Final cost : 0.1171633695918648
# Compute control for a deterministic system
# Cost in iteration 0: 0.1171633695918648
# Converged in iteration 1 with cost 0.1171633695918648 because of step counter
# Final cost : 0.1171633695918648
# Compute control for a deterministic system
# Cost in iteration 0: 0.1171633695918648
# Converged in iteration 1 with cost 0.1171633695918648 because of step counter
# Final cost : 0.1171633695918648
# Compute control for a deterministic system
# Cost in iteration 0: 0.12529428400594814
# Cost in iteration 200: 0.08869736177057226
# Final cost : 0.08869736177057226
# Compute control for a deterministic system
# Cost in iteration 0: 0.08869736177057226
# Cost in iteration 200: 0.08745067138096754
# Final cost : 0.08745067138096754
# Compute control for a deterministic system
# Cost in iteration 0: 0.08745067138096754
# Cost in iteration 200: 0.08721707272645972
# Final cost : 0.08721707272645972
# Compute control for a deterministic system
# Cost in iteration 0: 0.08721707272645972
# Converged in iteration 6 with cost 0.08721496055691716 because of step counter
# Final cost : 0.08721496055691716
# Compute control for a deterministic system
# Cost in iteration 0: 0.08721496055691716
# Converged in iteration 1 with cost 0.08721496055691716 because of step counter
# Final cost : 0.08721496055691716
# Compute control for a deterministic system
# Cost in iteration 0: 0.12306305674369201
# Cost in iteration 200: 0.08381793099183261
# Final cost : 0.08381793099183261
# Compute control for a deterministic system
# Cost in iteration 0: 0.08381793099183261
# Cost in iteration 200: 0.08316125837917632
# Final cost : 0.08316125837917632
# Compute control for a deterministic system
# Cost in iteration 0: 0.08316125837917632
# Cost in iteration 200: 0.08295608619172301
# Final cost : 0.08295608619172301
# Compute control for a deterministic system
# Cost in iteration 0: 0.08295608619172301
# Converged in iteration 6 with cost 0.08294511539105826 because of step counter
# Final cost : 0.08294511539105826
# Compute control for a deterministic system
# Cost in iteration 0: 0.08294511539105826
# Converged in iteration 1 with cost 0.08294511539105826 because of step counter
# Final cost : 0.08294511539105826
# Compute control for a deterministic system
# Cost in iteration 0: 0.1013422661737742
# Cost in iteration 200: 0.07610850291872089
# Final cost : 0.07610850291872089
# Compute control for a deterministic system
# Cost in iteration 0: 0.07610850291872089
# Converged in iteration 42 with cost 0.07503294297271194 because of vanishing difference
# Final cost : 0.07503294297271194
# Compute control for a deterministic system
# Cost in iteration 0: 0.07503294297271194
# Converged in iteration 6 with cost 0.07503294297097728 because of step counter
# Final cost : 0.07503294297097728
# Compute control for a deterministic system
# Cost in iteration 0: 0.07503294297097728
# Converged in iteration 1 with cost 0.07503294297097728 because of step counter
# Final cost : 0.07503294297097728
# Compute control for a deterministic system
# Cost in iteration 0: 0.07503294297097728
# Converged in iteration 1 with cost 0.07503294297097728 because of step counter
# Final cost : 0.07503294297097728
# Compute control for a deterministic system
# Cost in iteration 0: 0.11111211027348045
# Cost in iteration 200: 0.07374334893664086
# Final cost : 0.07374334893664086
# Compute control for a deterministic system
# Cost in iteration 0: 0.07374334893664086
# Cost in iteration 200: 0.07107323148718384
# Final cost : 0.07107323148718384
# Compute control for a deterministic system
# Cost in iteration 0: 0.07107323148718384
# Converged in iteration 20 with cost 0.07104917939545066 because of step counter
# Final cost : 0.07104917939545066
# Compute control for a deterministic system
# Cost in iteration 0: 0.07104917939545066
# Converged in iteration 1 with cost 0.07104917939545066 because of step counter
# Final cost : 0.07104917939545066
# Compute control for a deterministic system
# Cost in iteration 0: 0.07104917939545066
# Converged in iteration 1 with cost 0.07104917939545066 because of step counter
# Final cost : 0.07104917939545066
# Compute control for a deterministic system
# Cost in iteration 0: 0.10840828740505291
# Cost in iteration 200: 0.06949367788740737
# Final cost : 0.06949367788740737
# Compute control for a deterministic system
# Cost in iteration 0: 0.06949367788740737
# Cost in iteration 200: 0.06823109265487629
# Final cost : 0.06823109265487629
# Compute control for a deterministic system
# Cost in iteration 0: 0.06823109265487629
# Converged in iteration 161 with cost 0.06808152867138882 because of vanishing difference
# Final cost : 0.06808152867138882
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808152867100765
# Converged in iteration 2 with cost 0.06808152866781887 because of step counter
# Final cost : 0.06808152866781887
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808152866781887
# Converged in iteration 1 with cost 0.06808152866781887 because of step counter
# Final cost : 0.06808152866781887
# Compute control for a deterministic system
# Cost in iteration 0: 0.10246086454706899
# Cost in iteration 200: 0.06720768026168178
# Final cost : 0.06720768026168178
# Compute control for a deterministic system
# Cost in iteration 0: 0.06720768026168178
# Cost in iteration 200: 0.06596130874371296
# Final cost : 0.06596130874371296
# Compute control for a deterministic system
# Cost in iteration 0: 0.06596130874371296
# Cost in iteration 200: 0.06574253144157029
# Final cost : 0.06574253144157029
# Compute control for a deterministic system
# Cost in iteration 0: 0.06574253144157029
# Converged in iteration 31 with cost 0.06559854833658853 because of step counter
# Final cost : 0.06559854833658853
# Compute control for a deterministic system
# Cost in iteration 0: 0.06559854833658853
# Converged in iteration 1 with cost 0.06559854833658853 because of step counter
# Final cost : 0.06559854833658853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0824121041400629
# Cost in iteration 200: 0.0576711286960107
# Final cost : 0.0576711286960107
# Compute control for a deterministic system
# Cost in iteration 0: 0.0576711286960107
# Converged in iteration 40 with cost 0.056736706829153584 because of step counter
# Final cost : 0.056736706829153584
# Compute control for a deterministic system
# Cost in iteration 0: 0.056736706829153584
# Converged in iteration 1 with cost 0.056736706829153584 because of step counter
# Final cost : 0.056736706829153584
# Compute control for a deterministic system
# Cost in iteration 0: 0.056736706829153584
# Converged in iteration 1 with cost 0.056736706829153584 because of step counter
# Final cost : 0.056736706829153584
# Compute control for a deterministic system
# Cost in iteration 0: 0.056736706829153584
# Converged in iteration 1 with cost 0.056736706829153584 because of step counter
# Final cost : 0.056736706829153584
# Compute control for a deterministic system
# Cost in iteration 0: 0.09343719513568713
# Cost in iteration 200: 0.05577984752652416
# Final cost : 0.05577984752652416
# Compute control for a deterministic system
# Cost in iteration 0: 0.05577984752652416
# Converged in iteration 183 with cost 0.05346559324446069 because of step counter
# Final cost : 0.05346559324446069
# Compute control for a deterministic system
# Cost in iteration 0: 0.05346559324446069
# Converged in iteration 1 with cost 0.05346559324446069 because of step counter
# Final cost : 0.05346559324446069
# Compute control for a deterministic system
# Cost in iteration 0: 0.05346559324446069
# Converged in iteration 1 with cost 0.05346559324446069 because of step counter
# Final cost : 0.05346559324446069
# Compute control for a deterministic system
# Cost in iteration 0: 0.05346559324446069
# Converged in iteration 1 with cost 0.05346559324446069 because of step counter
# Final cost : 0.05346559324446069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08712111356595864
# Cost in iteration 200: 0.04870560696040903
# Final cost : 0.04870560696040903
# Compute control for a deterministic system
# Cost in iteration 0: 0.04870560696040903
# Cost in iteration 200: 0.04590629568182091
# Final cost : 0.04590629568182091
# Compute control for a deterministic system
# Cost in iteration 0: 0.04590629568182091
# Converged in iteration 11 with cost 0.045879601373535785 because of step counter
# Final cost : 0.045879601373535785
# Compute control for a deterministic system
# Cost in iteration 0: 0.045879601373535785
# Converged in iteration 1 with cost 0.045879601373535785 because of step counter
# Final cost : 0.045879601373535785
# Compute control for a deterministic system
# Cost in iteration 0: 0.045879601373535785
# Converged in iteration 1 with cost 0.045879601373535785 because of step counter
# Final cost : 0.045879601373535785
# Compute control for a deterministic system
# Cost in iteration 0: 0.06685302686708186
# Cost in iteration 200: 0.04296565341577031
# Final cost : 0.04296565341577031
# Compute control for a deterministic system
# Cost in iteration 0: 0.04296565341577031
# Converged in iteration 41 with cost 0.04199777773241209 because of step counter
# Final cost : 0.04199777773241209
# Compute control for a deterministic system
# Cost in iteration 0: 0.04199777773241209
# Converged in iteration 1 with cost 0.04199777773241209 because of step counter
# Final cost : 0.04199777773241209
# Compute control for a deterministic system
# Cost in iteration 0: 0.04199777773241209
# Converged in iteration 1 with cost 0.04199777773241209 because of step counter
# Final cost : 0.04199777773241209
# Compute control for a deterministic system
# Cost in iteration 0: 0.04199777773241209
# Converged in iteration 1 with cost 0.04199777773241209 because of step counter
# Final cost : 0.04199777773241209
# Compute control for a deterministic system
# Cost in iteration 0: 0.07790265429867635
# Cost in iteration 200: 0.041945937416876175
# Final cost : 0.041945937416876175
# Compute control for a deterministic system
# Cost in iteration 0: 0.041945937416876175
# Cost in iteration 200: 0.04050478393398195
# Final cost : 0.04050478393398195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04050478393398195
# Converged in iteration 195 with cost 0.04039317475217655 because of vanishing difference
# Final cost : 0.04039317475217655
# Compute control for a deterministic system
# Cost in iteration 0: 0.040393174751811964
# Converged in iteration 2 with cost 0.04039317474882176 because of step counter
# Final cost : 0.04039317474882176
# Compute control for a deterministic system
# Cost in iteration 0: 0.04039317474882176
# Converged in iteration 1 with cost 0.04039317474882176 because of step counter
# Final cost : 0.04039317474882176
# Compute control for a deterministic system
# Cost in iteration 0: 0.07476593786020566
# Cost in iteration 200: 0.039179952242752315
# Final cost : 0.039179952242752315
# Compute control for a deterministic system
# Cost in iteration 0: 0.039179952242752315
# Cost in iteration 200: 0.038619897285748016
# Final cost : 0.038619897285748016
# Compute control for a deterministic system
# Cost in iteration 0: 0.038619897285748016
# Cost in iteration 200: 0.03842458301103752
# Final cost : 0.03842458301103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.03842458301103752
# Converged in iteration 20 with cost 0.038218931414349275 because of step counter
# Final cost : 0.038218931414349275
# Compute control for a deterministic system
# Cost in iteration 0: 0.038218931414349275
# Converged in iteration 1 with cost 0.038218931414349275 because of step counter
# Final cost : 0.038218931414349275
# Compute control for a deterministic system
# Cost in iteration 0: 0.07168586365039917
# Cost in iteration 200: 0.035656040070384115
# Final cost : 0.035656040070384115
# Compute control for a deterministic system
# Cost in iteration 0: 0.035656040070384115
# Cost in iteration 200: 0.03475854351682376
# Final cost : 0.03475854351682376
# Compute control for a deterministic system
# Cost in iteration 0: 0.03475854351682376
# Cost in iteration 200: 0.03458231810753045
# Final cost : 0.03458231810753045
# Compute control for a deterministic system
# Cost in iteration 0: 0.03458231810753045
# Converged in iteration 6 with cost 0.03457988524458642 because of step counter
# Final cost : 0.03457988524458642
# Compute control for a deterministic system
# Cost in iteration 0: 0.03457988524458642
# Converged in iteration 1 with cost 0.03457988524458642 because of step counter
# Final cost : 0.03457988524458642
# Compute control for a deterministic system
# Cost in iteration 0: 0.05155345474902159
# Cost in iteration 200: 0.027063330670299725
# Final cost : 0.027063330670299725
# Compute control for a deterministic system
# Cost in iteration 0: 0.027063330670299725
# Converged in iteration 47 with cost 0.026418391668397462 because of step counter
# Final cost : 0.026418391668397462
# Compute control for a deterministic system
# Cost in iteration 0: 0.026418391668397462
# Converged in iteration 1 with cost 0.026418391668397462 because of step counter
# Final cost : 0.026418391668397462
# Compute control for a deterministic system
# Cost in iteration 0: 0.026418391668397462
# Converged in iteration 1 with cost 0.026418391668397462 because of step counter
# Final cost : 0.026418391668397462
# Compute control for a deterministic system
# Cost in iteration 0: 0.026418391668397462
# Converged in iteration 1 with cost 0.026418391668397462 because of step counter
# Final cost : 0.026418391668397462
# Compute control for a deterministic system
# Cost in iteration 0: 0.062216853124590785
# Cost in iteration 200: 0.025516849737073806
# Final cost : 0.025516849737073806
# Compute control for a deterministic system
# Cost in iteration 0: 0.025516849737073806
# Converged in iteration 197 with cost 0.02317716073717513 because of step counter
# Final cost : 0.02317716073717513
# Compute control for a deterministic system
# Cost in iteration 0: 0.02317716073717513
# Converged in iteration 1 with cost 0.02317716073717513 because of step counter
# Final cost : 0.02317716073717513
# Compute control for a deterministic system
# Cost in iteration 0: 0.02317716073717513
# Converged in iteration 1 with cost 0.02317716073717513 because of step counter
# Final cost : 0.02317716073717513
# Compute control for a deterministic system
# Cost in iteration 0: 0.02317716073717513
# Converged in iteration 1 with cost 0.02317716073717513 because of step counter
# Final cost : 0.02317716073717513
# Compute control for a deterministic system
# Cost in iteration 0: 0.05630571901921406
# Cost in iteration 200: 0.01859809076353408
# Final cost : 0.01859809076353408
# Compute control for a deterministic system
# Cost in iteration 0: 0.01859809076353408
# Converged in iteration 83 with cost 0.016495859697548215 because of step counter
# Final cost : 0.016495859697548215
# Compute control for a deterministic system
# Cost in iteration 0: 0.016495859697548215
# Converged in iteration 1 with cost 0.016495859697548215 because of step counter
# Final cost : 0.016495859697548215
# Compute control for a deterministic system
# Cost in iteration 0: 0.016495859697548215
# Converged in iteration 1 with cost 0.016495859697548215 because of step counter
# Final cost : 0.016495859697548215
# Compute control for a deterministic system
# Cost in iteration 0: 0.016495859697548215
# Converged in iteration 1 with cost 0.016495859697548215 because of step counter
# Final cost : 0.016495859697548215
# Compute control for a deterministic system
# Cost in iteration 0: 0.050179757016970625
# Cost in iteration 200: 0.012141723162886454
# Final cost : 0.012141723162886454
# Compute control for a deterministic system
# Cost in iteration 0: 0.012141723162886454
# Converged in iteration 57 with cost 0.010340265613678552 because of step counter
# Final cost : 0.010340265613678552
# Compute control for a deterministic system
# Cost in iteration 0: 0.010340265613678552
# Converged in iteration 1 with cost 0.010340265613678552 because of step counter
# Final cost : 0.010340265613678552
# Compute control for a deterministic system
# Cost in iteration 0: 0.010340265613678552
# Converged in iteration 1 with cost 0.010340265613678552 because of step counter
# Final cost : 0.010340265613678552
# Compute control for a deterministic system
# Cost in iteration 0: 0.010340265613678552
# Converged in iteration 1 with cost 0.010340265613678552 because of step counter
# Final cost : 0.010340265613678552
# Compute control for a deterministic system
# Cost in iteration 0: 0.03138272862922988
# Cost in iteration 200: 0.006147920399793746
# Final cost : 0.006147920399793746
# Compute control for a deterministic system
# Cost in iteration 0: 0.006147920399793746
# Converged in iteration 43 with cost 0.005872322443883697 because of step counter
# Final cost : 0.005872322443883697
# Compute control for a deterministic system
# Cost in iteration 0: 0.005872322443883697
# Converged in iteration 1 with cost 0.005872322443883697 because of step counter
# Final cost : 0.005872322443883697
# Compute control for a deterministic system
# Cost in iteration 0: 0.005872322443883697
# Converged in iteration 1 with cost 0.005872322443883697 because of step counter
# Final cost : 0.005872322443883697
# Compute control for a deterministic system
# Cost in iteration 0: 0.005872322443883697
# Converged in iteration 1 with cost 0.005872322443883697 because of step counter
# Final cost : 0.005872322443883697
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.029478784071137097
# Converged in iteration 14 with cost 0.01831283194188123 because of step counter
# Final cost : 0.01831283194188123
# Compute control for a deterministic system
# Cost in iteration 0: 0.01831283194188123
# Converged in iteration 1 with cost 0.01831283194188123 because of step counter
# Final cost : 0.01831283194188123
# Compute control for a deterministic system
# Cost in iteration 0: 0.01831283194188123
# Converged in iteration 1 with cost 0.01831283194188123 because of step counter
# Final cost : 0.01831283194188123
# Compute control for a deterministic system
# Cost in iteration 0: 0.01831283194188123
# Converged in iteration 1 with cost 0.01831283194188123 because of step counter
# Final cost : 0.01831283194188123
# Compute control for a deterministic system
# Cost in iteration 0: 0.042109602499349134
# Converged in iteration 13 with cost 0.02513049811522195 because of step counter
# Final cost : 0.02513049811522195
# Compute control for a deterministic system
# Cost in iteration 0: 0.02513049811522195
# Converged in iteration 1 with cost 0.02513049811522195 because of step counter
# Final cost : 0.02513049811522195
# Compute control for a deterministic system
# Cost in iteration 0: 0.02513049811522195
# Converged in iteration 1 with cost 0.02513049811522195 because of step counter
# Final cost : 0.02513049811522195
# Compute control for a deterministic system
# Cost in iteration 0: 0.02513049811522195
# Converged in iteration 1 with cost 0.02513049811522195 because of step counter
# Final cost : 0.02513049811522195
# Compute control for a deterministic system
# Cost in iteration 0: 0.039617910593013894
# Converged in iteration 11 with cost 0.027827629274316867 because of step counter
# Final cost : 0.027827629274316867
# Compute control for a deterministic system
# Cost in iteration 0: 0.027827629274316867
# Converged in iteration 1 with cost 0.027827629274316867 because of step counter
# Final cost : 0.027827629274316867
# Compute control for a deterministic system
# Cost in iteration 0: 0.027827629274316867
# Converged in iteration 1 with cost 0.027827629274316867 because of step counter
# Final cost : 0.027827629274316867
# Compute control for a deterministic system
# Cost in iteration 0: 0.027827629274316867
# Converged in iteration 1 with cost 0.027827629274316867 because of step counter
# Final cost : 0.027827629274316867
# Compute control for a deterministic system
# Cost in iteration 0: 0.03909060783343296
# Converged in iteration 9 with cost 0.031726505392832824 because of step counter
# Final cost : 0.031726505392832824
# Compute control for a deterministic system
# Cost in iteration 0: 0.031726505392832824
# Converged in iteration 1 with cost 0.031726505392832824 because of step counter
# Final cost : 0.031726505392832824
# Compute control for a deterministic system
# Cost in iteration 0: 0.031726505392832824
# Converged in iteration 1 with cost 0.031726505392832824 because of step counter
# Final cost : 0.031726505392832824
# Compute control for a deterministic system
# Cost in iteration 0: 0.031726505392832824
# Converged in iteration 1 with cost 0.031726505392832824 because of step counter
# Final cost : 0.031726505392832824
# Compute control for a deterministic system
# Cost in iteration 0: 0.030615279322905968
# Converged in iteration 6 with cost 0.03056913515438885 because of step counter
# Final cost : 0.03056913515438885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03056913515438885
# Converged in iteration 1 with cost 0.03056913515438885 because of step counter
# Final cost : 0.03056913515438885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03056913515438885
# Converged in iteration 1 with cost 0.03056913515438885 because of step counter
# Final cost : 0.03056913515438885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03056913515438885
# Converged in iteration 1 with cost 0.03056913515438885 because of step counter
# Final cost : 0.03056913515438885
# Compute control for a deterministic system
# Cost in iteration 0: 0.03890244120507644
# Converged in iteration 8 with cost 0.036956340022930675 because of step counter
# Final cost : 0.036956340022930675
# Compute control for a deterministic system
# Cost in iteration 0: 0.036956340022930675
# Converged in iteration 1 with cost 0.036956340022930675 because of step counter
# Final cost : 0.036956340022930675
# Compute control for a deterministic system
# Cost in iteration 0: 0.036956340022930675
# Converged in iteration 1 with cost 0.036956340022930675 because of step counter
# Final cost : 0.036956340022930675
# Compute control for a deterministic system
# Cost in iteration 0: 0.036956340022930675
# Converged in iteration 1 with cost 0.036956340022930675 because of step counter
# Final cost : 0.036956340022930675
# Compute control for a deterministic system
# Cost in iteration 0: 0.03699816129519282
# Converged in iteration 2 with cost 0.036998151379786105 because of step counter
# Final cost : 0.036998151379786105
# Compute control for a deterministic system
# Cost in iteration 0: 0.036998151379786105
# Converged in iteration 1 with cost 0.036998151379786105 because of step counter
# Final cost : 0.036998151379786105
# Compute control for a deterministic system
# Cost in iteration 0: 0.036998151379786105
# Converged in iteration 1 with cost 0.036998151379786105 because of step counter
# Final cost : 0.036998151379786105
# Compute control for a deterministic system
# Cost in iteration 0: 0.036998151379786105
# Converged in iteration 1 with cost 0.036998151379786105 because of step counter
# Final cost : 0.036998151379786105
# Compute control for a deterministic system
# Cost in iteration 0: 0.04074307716087899
# Converged in iteration 1 with cost 0.04074307716087899 because of step counter
# Final cost : 0.04074307716087899
# Compute control for a deterministic system
# Cost in iteration 0: 0.04074307716087899
# Converged in iteration 1 with cost 0.04074307716087899 because of step counter
# Final cost : 0.04074307716087899
# Compute control for a deterministic system
# Cost in iteration 0: 0.04074307716087899
# Converged in iteration 1 with cost 0.04074307716087899 because of step counter
# Final cost : 0.04074307716087899
# Compute control for a deterministic system
# Cost in iteration 0: 0.04074307716087899
# Converged in iteration 1 with cost 0.04074307716087899 because of step counter
# Final cost : 0.04074307716087899
# Compute control for a deterministic system
# Cost in iteration 0: 0.04471921041971115
# Converged in iteration 5 with cost 0.04427149265222169 because of step counter
# Final cost : 0.04427149265222169
# Compute control for a deterministic system
# Cost in iteration 0: 0.04427149265222169
# Converged in iteration 1 with cost 0.04427149265222169 because of step counter
# Final cost : 0.04427149265222169
# Compute control for a deterministic system
# Cost in iteration 0: 0.04427149265222169
# Converged in iteration 1 with cost 0.04427149265222169 because of step counter
# Final cost : 0.04427149265222169
# Compute control for a deterministic system
# Cost in iteration 0: 0.04427149265222169
# Converged in iteration 1 with cost 0.04427149265222169 because of step counter
# Final cost : 0.04427149265222169
# Compute control for a deterministic system
# Cost in iteration 0: 0.05133920965515378
# Converged in iteration 11 with cost 0.050724343666460205 because of step counter
# Final cost : 0.050724343666460205
# Compute control for a deterministic system
# Cost in iteration 0: 0.050724343666460205
# Converged in iteration 1 with cost 0.050724343666460205 because of step counter
# Final cost : 0.050724343666460205
# Compute control for a deterministic system
# Cost in iteration 0: 0.050724343666460205
# Converged in iteration 1 with cost 0.050724343666460205 because of step counter
# Final cost : 0.050724343666460205
# Compute control for a deterministic system
# Cost in iteration 0: 0.050724343666460205
# Converged in iteration 1 with cost 0.050724343666460205 because of step counter
# Final cost : 0.050724343666460205
# Compute control for a deterministic system
# Cost in iteration 0: 0.059791232623921324
# Converged in iteration 9 with cost 0.05898109708757144 because of step counter
# Final cost : 0.05898109708757144
# Compute control for a deterministic system
# Cost in iteration 0: 0.05898109708757144
# Converged in iteration 1 with cost 0.05898109708757144 because of step counter
# Final cost : 0.05898109708757144
# Compute control for a deterministic system
# Cost in iteration 0: 0.05898109708757144
# Converged in iteration 1 with cost 0.05898109708757144 because of step counter
# Final cost : 0.05898109708757144
# Compute control for a deterministic system
# Cost in iteration 0: 0.05898109708757144
# Converged in iteration 1 with cost 0.05898109708757144 because of step counter
# Final cost : 0.05898109708757144
# Compute control for a deterministic system
# Cost in iteration 0: 0.06518052678208158
# Converged in iteration 11 with cost 0.05967471618806162 because of step counter
# Final cost : 0.05967471618806162
# Compute control for a deterministic system
# Cost in iteration 0: 0.05967471618806162
# Converged in iteration 1 with cost 0.05967471618806162 because of step counter
# Final cost : 0.05967471618806162
# Compute control for a deterministic system
# Cost in iteration 0: 0.05967471618806162
# Converged in iteration 1 with cost 0.05967471618806162 because of step counter
# Final cost : 0.05967471618806162
# Compute control for a deterministic system
# Cost in iteration 0: 0.05967471618806162
# Converged in iteration 1 with cost 0.05967471618806162 because of step counter
# Final cost : 0.05967471618806162
# Compute control for a deterministic system
# Cost in iteration 0: 0.06571893792099937
# Converged in iteration 5 with cost 0.06567999453202857 because of step counter
# Final cost : 0.06567999453202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.06567999453202857
# Converged in iteration 1 with cost 0.06567999453202857 because of step counter
# Final cost : 0.06567999453202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.06567999453202857
# Converged in iteration 1 with cost 0.06567999453202857 because of step counter
# Final cost : 0.06567999453202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.06567999453202857
# Converged in iteration 1 with cost 0.06567999453202857 because of step counter
# Final cost : 0.06567999453202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0715314646428381
# Converged in iteration 39 with cost 0.07006192019622916 because of step counter
# Final cost : 0.07006192019622916
# Compute control for a deterministic system
# Cost in iteration 0: 0.07006192019622916
# Converged in iteration 1 with cost 0.07006192019622916 because of step counter
# Final cost : 0.07006192019622916
# Compute control for a deterministic system
# Cost in iteration 0: 0.07006192019622916
# Converged in iteration 1 with cost 0.07006192019622916 because of step counter
# Final cost : 0.07006192019622916
# Compute control for a deterministic system
# Cost in iteration 0: 0.07006192019622916
# Converged in iteration 1 with cost 0.07006192019622916 because of step counter
# Final cost : 0.07006192019622916
# Compute control for a deterministic system
# Cost in iteration 0: 0.08192119535589537
# Converged in iteration 31 with cost 0.07456420505587832 because of step counter
# Final cost : 0.07456420505587832
# Compute control for a deterministic system
# Cost in iteration 0: 0.07456420505587832
# Converged in iteration 1 with cost 0.07456420505587832 because of step counter
# Final cost : 0.07456420505587832
# Compute control for a deterministic system
# Cost in iteration 0: 0.07456420505587832
# Converged in iteration 1 with cost 0.07456420505587832 because of step counter
# Final cost : 0.07456420505587832
# Compute control for a deterministic system
# Cost in iteration 0: 0.07456420505587832
# Converged in iteration 1 with cost 0.07456420505587832 because of step counter
# ...
# Cost in iteration 0: 0.017035278445242205
# Converged in iteration 1 with cost 0.017035278445242205 because of step counter
# Final cost : 0.017035278445242205
# ----------------------------------------------- 7
# Compute control for a deterministic system
# Cost in iteration 0: 0.01791003926169481
# Converged in iteration 1 with cost 0.01791003926169481 because of step counter
# Final cost : 0.01791003926169481
# Compute control for a deterministic system
# Cost in iteration 0: 0.01791003926169481
# Converged in iteration 1 with cost 0.01791003926169481 because of step counter
# Final cost : 0.01791003926169481
# Compute control for a deterministic system
# Cost in iteration 0: 0.01791003926169481
# Converged in iteration 1 with cost 0.01791003926169481 because of step counter
# Final cost : 0.01791003926169481
# Compute control for a deterministic system
# Cost in iteration 0: 0.01791003926169481
# Converged in iteration 1 with cost 0.01791003926169481 because of step counter
# Final cost : 0.01791003926169481
# Compute control for a deterministic system
# Cost in iteration 0: 0.01791003926169481
# Converged in iteration 1 with cost 0.01791003926169481 because of step counter
# Final cost : 0.01791003926169481
# Compute control for a deterministic system
# Cost in iteration 0: 0.03410095925461638
# Converged in iteration 1 with cost 0.03410095925461638 because of step counter
# Final cost : 0.03410095925461638
# Compute control for a deterministic system
# Cost in iteration 0: 0.03410095925461638
# Converged in iteration 1 with cost 0.03410095925461638 because of step counter
# Final cost : 0.03410095925461638
# Compute control for a deterministic system
# Cost in iteration 0: 0.03410095925461638
# Converged in iteration 1 with cost 0.03410095925461638 because of step counter
# Final cost : 0.03410095925461638
# Compute control for a deterministic system
# Cost in iteration 0: 0.03410095925461638
# Converged in iteration 1 with cost 0.03410095925461638 because of step counter
# Final cost : 0.03410095925461638
# Compute control for a deterministic system
# Cost in iteration 0: 0.03410095925461638
# Converged in iteration 1 with cost 0.03410095925461638 because of step counter
# Final cost : 0.03410095925461638
# Compute control for a deterministic system
# Cost in iteration 0: 0.0543145657671486
# Converged in iteration 2 with cost 0.05424700103729365 because of step counter
# Final cost : 0.05424700103729365
# Compute control for a deterministic system
# Cost in iteration 0: 0.05424700103729365
# Converged in iteration 1 with cost 0.05424700103729365 because of step counter
# Final cost : 0.05424700103729365
# Compute control for a deterministic system
# Cost in iteration 0: 0.05424700103729365
# Converged in iteration 1 with cost 0.05424700103729365 because of step counter
# Final cost : 0.05424700103729365
# Compute control for a deterministic system
# Cost in iteration 0: 0.05424700103729365
# Converged in iteration 1 with cost 0.05424700103729365 because of step counter
# Final cost : 0.05424700103729365
# Compute control for a deterministic system
# Cost in iteration 0: 0.05424700103729365
# Converged in iteration 1 with cost 0.05424700103729365 because of step counter
# Final cost : 0.05424700103729365
# Compute control for a deterministic system
# Cost in iteration 0: 0.07850909069446195
# Converged in iteration 2 with cost 0.07844485471572928 because of step counter
# Final cost : 0.07844485471572928
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844485471572928
# Converged in iteration 1 with cost 0.07844485471572928 because of step counter
# Final cost : 0.07844485471572928
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844485471572928
# Converged in iteration 1 with cost 0.07844485471572928 because of step counter
# Final cost : 0.07844485471572928
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844485471572928
# Converged in iteration 1 with cost 0.07844485471572928 because of step counter
# Final cost : 0.07844485471572928
# Compute control for a deterministic system
# Cost in iteration 0: 0.07844485471572928
# Converged in iteration 1 with cost 0.07844485471572928 because of step counter
# Final cost : 0.07844485471572928
# Compute control for a deterministic system
# Cost in iteration 0: 0.10550948895884987
# Converged in iteration 3 with cost 0.10529608879058291 because of step counter
# Final cost : 0.10529608879058291
# Compute control for a deterministic system
# Cost in iteration 0: 0.10529608879058291
# Converged in iteration 1 with cost 0.10529608879058291 because of step counter
# Final cost : 0.10529608879058291
# Compute control for a deterministic system
# Cost in iteration 0: 0.10529608879058291
# Converged in iteration 1 with cost 0.10529608879058291 because of step counter
# Final cost : 0.10529608879058291
# Compute control for a deterministic system
# Cost in iteration 0: 0.10529608879058291
# Converged in iteration 1 with cost 0.10529608879058291 because of step counter
# Final cost : 0.10529608879058291
# Compute control for a deterministic system
# Cost in iteration 0: 0.10529608879058291
# Converged in iteration 1 with cost 0.10529608879058291 because of step counter
# Final cost : 0.10529608879058291
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382026080868082
# Converged in iteration 1 with cost 0.14382026080868082 because of step counter
# Final cost : 0.14382026080868082
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382026080868082
# Converged in iteration 1 with cost 0.14382026080868082 because of step counter
# Final cost : 0.14382026080868082
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382026080868082
# Converged in iteration 1 with cost 0.14382026080868082 because of step counter
# Final cost : 0.14382026080868082
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382026080868082
# Converged in iteration 1 with cost 0.14382026080868082 because of step counter
# Final cost : 0.14382026080868082
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382026080868082
# Converged in iteration 1 with cost 0.14382026080868082 because of step counter
# Final cost : 0.14382026080868082
# Compute control for a deterministic system
# Cost in iteration 0: 0.162488785927079
# Converged in iteration 1 with cost 0.162488785927079 because of step counter
# Final cost : 0.162488785927079
# Compute control for a deterministic system
# Cost in iteration 0: 0.162488785927079
# Converged in iteration 1 with cost 0.162488785927079 because of step counter
# Final cost : 0.162488785927079
# Compute control for a deterministic system
# Cost in iteration 0: 0.162488785927079
# Converged in iteration 1 with cost 0.162488785927079 because of step counter
# Final cost : 0.162488785927079
# Compute control for a deterministic system
# Cost in iteration 0: 0.162488785927079
# Converged in iteration 1 with cost 0.162488785927079 because of step counter
# Final cost : 0.162488785927079
# Compute control for a deterministic system
# Cost in iteration 0: 0.162488785927079
# Converged in iteration 1 with cost 0.162488785927079 because of step counter
# Final cost : 0.162488785927079
# Compute control for a deterministic system
# Cost in iteration 0: 0.1763854292663275
# Converged in iteration 1 with cost 0.1763854292663275 because of step counter
# Final cost : 0.1763854292663275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1763854292663275
# Converged in iteration 1 with cost 0.1763854292663275 because of step counter
# Final cost : 0.1763854292663275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1763854292663275
# Converged in iteration 1 with cost 0.1763854292663275 because of step counter
# Final cost : 0.1763854292663275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1763854292663275
# Converged in iteration 1 with cost 0.1763854292663275 because of step counter
# Final cost : 0.1763854292663275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1763854292663275
# Converged in iteration 1 with cost 0.1763854292663275 because of step counter
# Final cost : 0.1763854292663275
# Compute control for a deterministic system
# Cost in iteration 0: 0.1932142147220371
# Converged in iteration 1 with cost 0.1932142147220371 because of step counter
# Final cost : 0.1932142147220371
# Compute control for a deterministic system
# Cost in iteration 0: 0.1932142147220371
# Converged in iteration 1 with cost 0.1932142147220371 because of step counter
# Final cost : 0.1932142147220371
# Compute control for a deterministic system
# Cost in iteration 0: 0.1932142147220371
# Converged in iteration 1 with cost 0.1932142147220371 because of step counter
# Final cost : 0.1932142147220371
# Compute control for a deterministic system
# Cost in iteration 0: 0.1932142147220371
# Converged in iteration 1 with cost 0.1932142147220371 because of step counter
# Final cost : 0.1932142147220371
# Compute control for a deterministic system
# Cost in iteration 0: 0.1932142147220371
# Converged in iteration 1 with cost 0.1932142147220371 because of step counter
# Final cost : 0.1932142147220371
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810654061794467
# Converged in iteration 1 with cost 0.20810654061794467 because of step counter
# Final cost : 0.20810654061794467
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810654061794467
# Converged in iteration 1 with cost 0.20810654061794467 because of step counter
# Final cost : 0.20810654061794467
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810654061794467
# Converged in iteration 1 with cost 0.20810654061794467 because of step counter
# Final cost : 0.20810654061794467
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810654061794467
# Converged in iteration 1 with cost 0.20810654061794467 because of step counter
# Final cost : 0.20810654061794467
# Compute control for a deterministic system
# Cost in iteration 0: 0.20810654061794467
# Converged in iteration 1 with cost 0.20810654061794467 because of step counter
# Final cost : 0.20810654061794467
# Compute control for a deterministic system
# Cost in iteration 0: 0.22319024298842907
# Converged in iteration 1 with cost 0.22319024298842907 because of step counter
# Final cost : 0.22319024298842907
# Compute control for a deterministic system
# Cost in iteration 0: 0.22319024298842907
# Converged in iteration 1 with cost 0.22319024298842907 because of step counter
# Final cost : 0.22319024298842907
# Compute control for a deterministic system
# Cost in iteration 0: 0.22319024298842907
# Converged in iteration 1 with cost 0.22319024298842907 because of step counter
# Final cost : 0.22319024298842907
# Compute control for a deterministic system
# Cost in iteration 0: 0.22319024298842907
# Converged in iteration 1 with cost 0.22319024298842907 because of step counter
# Final cost : 0.22319024298842907
# Compute control for a deterministic system
# Cost in iteration 0: 0.22319024298842907
# Converged in iteration 1 with cost 0.22319024298842907 because of step counter
# Final cost : 0.22319024298842907
# Compute control for a deterministic system
# Cost in iteration 0: 0.24382290951751073
# Converged in iteration 1 with cost 0.24382290951751073 because of step counter
# Final cost : 0.24382290951751073
# Compute control for a deterministic system
# Cost in iteration 0: 0.24382290951751073
# Converged in iteration 1 with cost 0.24382290951751073 because of step counter
# Final cost : 0.24382290951751073
# Compute control for a deterministic system
# Cost in iteration 0: 0.24382290951751073
# Converged in iteration 1 with cost 0.24382290951751073 because of step counter
# Final cost : 0.24382290951751073
# Compute control for a deterministic system
# Cost in iteration 0: 0.24382290951751073
# Converged in iteration 1 with cost 0.24382290951751073 because of step counter
# Final cost : 0.24382290951751073
# Compute control for a deterministic system
# Cost in iteration 0: 0.24382290951751073
# Converged in iteration 1 with cost 0.24382290951751073 because of step counter
# Final cost : 0.24382290951751073
# Compute control for a deterministic system
# Cost in iteration 0: 0.2620024904407406
# Converged in iteration 11 with cost 0.25819414676695207 because of step counter
# Final cost : 0.25819414676695207
# Compute control for a deterministic system
# Cost in iteration 0: 0.25819414676695207
# Converged in iteration 1 with cost 0.25819414676695207 because of step counter
# Final cost : 0.25819414676695207
# Compute control for a deterministic system
# Cost in iteration 0: 0.25819414676695207
# Converged in iteration 1 with cost 0.25819414676695207 because of step counter
# Final cost : 0.25819414676695207
# Compute control for a deterministic system
# Cost in iteration 0: 0.25819414676695207
# Converged in iteration 1 with cost 0.25819414676695207 because of step counter
# Final cost : 0.25819414676695207
# Compute control for a deterministic system
# Cost in iteration 0: 0.25819414676695207
# Converged in iteration 1 with cost 0.25819414676695207 because of step counter
# Final cost : 0.25819414676695207
# Compute control for a deterministic system
# Cost in iteration 0: 0.2735193667860154
# Converged in iteration 5 with cost 0.27157934215333257 because of step counter
# Final cost : 0.27157934215333257
# Compute control for a deterministic system
# Cost in iteration 0: 0.27157934215333257
# Converged in iteration 1 with cost 0.27157934215333257 because of step counter
# Final cost : 0.27157934215333257
# Compute control for a deterministic system
# Cost in iteration 0: 0.27157934215333257
# Converged in iteration 1 with cost 0.27157934215333257 because of step counter
# Final cost : 0.27157934215333257
# Compute control for a deterministic system
# Cost in iteration 0: 0.27157934215333257
# Converged in iteration 1 with cost 0.27157934215333257 because of step counter
# Final cost : 0.27157934215333257
# Compute control for a deterministic system
# Cost in iteration 0: 0.27157934215333257
# Converged in iteration 1 with cost 0.27157934215333257 because of step counter
# Final cost : 0.27157934215333257
# Compute control for a deterministic system
# Cost in iteration 0: 0.289559921933649
# Converged in iteration 4 with cost 0.28872377061285975 because of step counter
# Final cost : 0.28872377061285975
# Compute control for a deterministic system
# Cost in iteration 0: 0.28872377061285975
# Converged in iteration 1 with cost 0.28872377061285975 because of step counter
# Final cost : 0.28872377061285975
# Compute control for a deterministic system
# Cost in iteration 0: 0.28872377061285975
# Converged in iteration 1 with cost 0.28872377061285975 because of step counter
# Final cost : 0.28872377061285975
# Compute control for a deterministic system
# Cost in iteration 0: 0.28872377061285975
# Converged in iteration 1 with cost 0.28872377061285975 because of step counter
# Final cost : 0.28872377061285975
# Compute control for a deterministic system
# Cost in iteration 0: 0.28872377061285975
# Converged in iteration 1 with cost 0.28872377061285975 because of step counter
# Final cost : 0.28872377061285975
# Compute control for a deterministic system
# Cost in iteration 0: 1.1727710519069334
# Cost in iteration 200: 0.9873028018463348
# Final cost : 0.9873028018463348
# Compute control for a deterministic system
# Cost in iteration 0: 0.9873028018463348
# Cost in iteration 200: 0.6895385756907364
# Final cost : 0.6895385756907364
# Compute control for a deterministic system
# Cost in iteration 0: 0.6895385756907364
# Converged in iteration 3 with cost 0.6895325232102821 because of step counter
# Final cost : 0.6895325232102821
# Compute control for a deterministic system
# Cost in iteration 0: 0.6895325232102821
# Converged in iteration 1 with cost 0.6895325232102821 because of step counter
# Final cost : 0.6895325232102821
# Compute control for a deterministic system
# Cost in iteration 0: 0.6895325232102821
# Converged in iteration 1 with cost 0.6895325232102821 because of step counter
# Final cost : 0.6895325232102821
# Compute control for a deterministic system
# Cost in iteration 0: 0.951205185961939
# Cost in iteration 200: 0.813161190484184
# Final cost : 0.813161190484184
# Compute control for a deterministic system
# Cost in iteration 0: 0.813161190484184

# %%
save(results_min)
