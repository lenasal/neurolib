# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
results_peak = readfile("results_peak_w1.pickle")

ind_list = []
#options = [True, False, False, False, False, False, True, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["models"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05200000646323468
# Converged in iteration 195 with cost 0.02707494977792208 because of vanishing difference
# Final cost : 0.02707494977792208
# Compute control for a deterministic system
# Cost in iteration 0: 0.02707494977792208
# Converged in iteration 25 with cost 0.02707494949273081 because of step counter
# Final cost : 0.02707494949273081
# Compute control for a deterministic system
# Cost in iteration 0: 0.02707494949273081
# Converged in iteration 2 with cost 0.027074949492730455 because of step counter
# Final cost : 0.027074949492730455
# Compute control for a deterministic system
# Cost in iteration 0: 0.027074949492730455
# Converged in iteration 1 with cost 0.027074949492730455 because of step counter
# Final cost : 0.027074949492730455
# Compute control for a deterministic system
# Cost in iteration 0: 0.027074949492730455
# Converged in iteration 1 with cost 0.027074949492730455 because of step counter
# Final cost : 0.027074949492730455
# Compute control for a deterministic system
# Cost in iteration 0: 0.08960771212558526
# Cost in iteration 200: 0.04311511632174106
# Final cost : 0.04311511632174106
# Compute control for a deterministic system
# Cost in iteration 0: 0.04311511632174106
# Converged in iteration 16 with cost 0.04311499803021225 because of vanishing difference
# Final cost : 0.04311499803021225
# Compute control for a deterministic system
# Cost in iteration 0: 0.04311499803021225
# Converged in iteration 37 with cost 0.043114997183840736 because of step counter
# Final cost : 0.043114997183840736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043114997183840736
# Converged in iteration 1 with cost 0.043114997183840736 because of step counter
# Final cost : 0.043114997183840736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043114997183840736
# Converged in iteration 1 with cost 0.043114997183840736 because of step counter
# Final cost : 0.043114997183840736
# Compute control for a deterministic system
# Cost in iteration 0: 0.10013532274638012
# Cost in iteration 200: 0.059218201060122475
# Final cost : 0.059218201060122475
# Compute control for a deterministic system
# Cost in iteration 0: 0.059218201060122475
# Converged in iteration 129 with cost 0.059216442703291294 because of step counter
# Final cost : 0.059216442703291294
# Compute control for a deterministic system
# Cost in iteration 0: 0.059216442703291294
# Converged in iteration 2 with cost 0.05921644270329129 because of step counter
# Final cost : 0.05921644270329129
# Compute control for a deterministic system
# Cost in iteration 0: 0.05921644270329129
# Converged in iteration 1 with cost 0.05921644270329129 because of step counter
# Final cost : 0.05921644270329129
# Compute control for a deterministic system
# Cost in iteration 0: 0.05921644270329129
# Converged in iteration 1 with cost 0.05921644270329129 because of step counter
# Final cost : 0.05921644270329129
# Compute control for a deterministic system
# Cost in iteration 0: 0.11247871923019435
# Cost in iteration 200: 0.07536065691676383
# Final cost : 0.07536065691676383
# Compute control for a deterministic system
# Cost in iteration 0: 0.07536065691676383
# Converged in iteration 20 with cost 0.07535216852358836 because of vanishing difference
# Final cost : 0.07535216852358836
# Compute control for a deterministic system
# Cost in iteration 0: 0.07535216852358836
# Converged in iteration 80 with cost 0.07535098897463575 because of step counter
# Final cost : 0.07535098897463575
# Compute control for a deterministic system
# Cost in iteration 0: 0.07535098897463575
# Converged in iteration 7 with cost 0.07535098897463367 because of step counter
# Final cost : 0.07535098897463367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07535098897463367
# Converged in iteration 1 with cost 0.07535098897463367 because of step counter
# Final cost : 0.07535098897463367
# Compute control for a deterministic system
# Cost in iteration 0: 0.1323422526339157
# Cost in iteration 200: 0.08828692555808702
# Final cost : 0.08828692555808702
# Compute control for a deterministic system
# Cost in iteration 0: 0.08828692555808702
# Converged in iteration 54 with cost 0.08826987717841982 because of vanishing difference
# Final cost : 0.08826987717841982
# Compute control for a deterministic system
# Cost in iteration 0: 0.08826987717841982
# Converged in iteration 122 with cost 0.08826968988625053 because of step counter
# Final cost : 0.08826968988625053
# Compute control for a deterministic system
# Cost in iteration 0: 0.08826968988625053
# Converged in iteration 4 with cost 0.08826968988624957 because of step counter
# Final cost : 0.08826968988624957
# Compute control for a deterministic system
# Cost in iteration 0: 0.08826968988624957
# Converged in iteration 1 with cost 0.08826968988624957 because of step counter
# Final cost : 0.08826968988624957
# Compute control for a deterministic system
# Cost in iteration 0: 0.1489305902648656
# Cost in iteration 200: 0.10447218277565566
# Final cost : 0.10447218277565566
# Compute control for a deterministic system
# Cost in iteration 0: 0.10447218277565566
# Converged in iteration 116 with cost 0.10442020444280561 because of vanishing difference
# Final cost : 0.10442020444280561
# Compute control for a deterministic system
# Cost in iteration 0: 0.10442020444280561
# Converged in iteration 153 with cost 0.10442016992112696 because of step counter
# Final cost : 0.10442016992112696
# Compute control for a deterministic system
# Cost in iteration 0: 0.10442016992112696
# Converged in iteration 2 with cost 0.10442016992112683 because of step counter
# Final cost : 0.10442016992112683
# Compute control for a deterministic system
# Cost in iteration 0: 0.10442016992112683
# Converged in iteration 2 with cost 0.1044201699211266 because of vanishing difference
# Final cost : 0.1044201699211266
# Compute control for a deterministic system
# Cost in iteration 0: 0.19308016324053895
# Cost in iteration 200: 0.12066095381388167
# Final cost : 0.12066095381388167
# Compute control for a deterministic system
# Cost in iteration 0: 0.12066095381388167
# Cost in iteration 200: 0.12056333031316592
# Final cost : 0.12056333031316592
# Compute control for a deterministic system
# Cost in iteration 0: 0.12056333031316592
# Converged in iteration 176 with cost 0.12056332316683839 because of step counter
# Final cost : 0.12056332316683839
# Compute control for a deterministic system
# Cost in iteration 0: 0.12056332316683839
# Converged in iteration 1 with cost 0.12056332316683839 because of step counter
# Final cost : 0.12056332316683839
# Compute control for a deterministic system
# Cost in iteration 0: 0.12056332316683839
# Converged in iteration 1 with cost 0.12056332316683839 because of step counter
# Final cost : 0.12056332316683839
# Compute control for a deterministic system
# Cost in iteration 0: 0.16546404141893994
# Cost in iteration 200: 0.13683922113865352
# Final cost : 0.13683922113865352
# Compute control for a deterministic system
# Cost in iteration 0: 0.13683922113865352
# Converged in iteration 185 with cost 0.13669157863027684 because of vanishing difference
# Final cost : 0.13669157863027684
# Compute control for a deterministic system
# Cost in iteration 0: 0.13669157863027684
# Cost in iteration 200: 0.1366914317792839
# Final cost : 0.1366914317792839
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366914317792839
# Converged in iteration 159 with cost 0.13669143177620427 because of step counter
# Final cost : 0.13669143177620427
# Compute control for a deterministic system
# Cost in iteration 0: 0.13669143177620427
# Converged in iteration 1 with cost 0.13669143177620427 because of step counter
# Final cost : 0.13669143177620427
# Compute control for a deterministic system
# Cost in iteration 0: 0.20378073099309985
# Cost in iteration 200: 0.1497110794273763
# Final cost : 0.1497110794273763
# Compute control for a deterministic system
# Cost in iteration 0: 0.1497110794273763
# Converged in iteration 144 with cost 0.14957988489600177 because of vanishing difference
# Final cost : 0.14957988489600177
# Compute control for a deterministic system
# Cost in iteration 0: 0.14957988489600177
# Cost in iteration 200: 0.14957873901484497
# Final cost : 0.14957873901484497
# Compute control for a deterministic system
# Cost in iteration 0: 0.14957873901484497
# Cost in iteration 200: 0.1495787389099656
# Converged in iteration 256 with cost 0.14957873890983805 because of vanishing difference
# Final cost : 0.14957873890983805
# Compute control for a deterministic system
# Cost in iteration 0: 0.14957873890983805
# Converged in iteration 31 with cost 0.14957873890981416 because of step counter
# Final cost : 0.14957873890981416
# Compute control for a deterministic system
# Cost in iteration 0: 0.19431873013947312
# Cost in iteration 200: 0.16592056713295786
# Final cost : 0.16592056713295786
# Compute control for a deterministic system
# Cost in iteration 0: 0.16592056713295786
# Converged in iteration 191 with cost 0.16566551064679613 because of vanishing difference
# Final cost : 0.16566551064679613
# Compute control for a deterministic system
# Cost in iteration 0: 0.16566551064679613
# Cost in iteration 200: 0.16566388664202306
# Final cost : 0.16566388664202306
# Compute control for a deterministic system
# Cost in iteration 0: 0.16566388664202306
# Cost in iteration 200: 0.16566388565119947
# Converged in iteration 242 with cost 0.16566388564790616 because of vanishing difference
# Final cost : 0.16566388564790616
# Compute control for a deterministic system
# Cost in iteration 0: 0.16566388564790616
# Converged in iteration 96 with cost 0.16566388564639709 because of vanishing difference
# Final cost : 0.16566388564639709
# Compute control for a deterministic system
# Cost in iteration 0: 0.21256426469889814
# Cost in iteration 200: 0.18203913349509407
# Final cost : 0.18203913349509407
# Compute control for a deterministic system
# Cost in iteration 0: 0.18203913349509407
# Cost in iteration 200: 0.18172049524003167
# Final cost : 0.18172049524003167
# Compute control for a deterministic system
# Cost in iteration 0: 0.18172049524003167
# Cost in iteration 200: 0.181716885391336
# Final cost : 0.181716885391336
# Compute control for a deterministic system
# Cost in iteration 0: 0.181716885391336
# Cost in iteration 200: 0.18171687656722166
# Cost in iteration 400: 0.18171687644916304
# Final cost : 0.18171687644916304
# Compute control for a deterministic system
# Cost in iteration 0: 0.18171687644916304
# Cost in iteration 200: 0.18171687644755538
# Converged in iteration 215 with cost 0.18171687644754 because of step counter
# Final cost : 0.18171687644754
# Compute control for a deterministic system
# Cost in iteration 0: 0.22460216983491446
# Cost in iteration 200: 0.1947763189966186
# Final cost : 0.1947763189966186
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947763189966186
# Cost in iteration 200: 0.1945363090708071
# Final cost : 0.1945363090708071
# Compute control for a deterministic system
# Cost in iteration 0: 0.1945363090708071
# Cost in iteration 200: 0.19453186063650624
# Final cost : 0.19453186063650624
# Compute control for a deterministic system
# Cost in iteration 0: 0.19453186063650624
# Cost in iteration 200: 0.19453182340618638
# Cost in iteration 400: 0.19453182249954737
# Final cost : 0.19453182249954737
# Compute control for a deterministic system
# Cost in iteration 0: 0.19453182249954737
# Cost in iteration 200: 0.19453182247720266
# Converged in iteration 362 with cost 0.19453182247637105 because of step counter
# Final cost : 0.19453182247637105
# Compute control for a deterministic system
# Cost in iteration 0: 0.2733146162874489
# Cost in iteration 200: 0.21095523225802215
# Final cost : 0.21095523225802215
# Compute control for a deterministic system
# Cost in iteration 0: 0.21095523225802215
# Cost in iteration 200: 0.21052266717485407
# Final cost : 0.21052266717485407
# Compute control for a deterministic system
# Cost in iteration 0: 0.21052266717485407
# Cost in iteration 200: 0.2105095317156897
# Final cost : 0.2105095317156897
# Compute control for a deterministic system
# Cost in iteration 0: 0.2105095317156897
# Cost in iteration 200: 0.21050930410173
# Cost in iteration 400: 0.21050929347295683
# Final cost : 0.21050929347295683
# Compute control for a deterministic system
# Cost in iteration 0: 0.21050929347295683
# Cost in iteration 200: 0.21050929298715146
# Cost in iteration 400: 0.21050929295604928
# Converged in iteration 595 with cost 0.21050929295405776 because of vanishing difference
# Final cost : 0.21050929295405776
# Compute control for a deterministic system
# Cost in iteration 0: 0.26878837037865744
# Cost in iteration 200: 0.22692490371548077
# Final cost : 0.22692490371548077
# Compute control for a deterministic system
# Cost in iteration 0: 0.22692490371548077
# Cost in iteration 200: 0.22645133116512697
# Final cost : 0.22645133116512697
# Compute control for a deterministic system
# Cost in iteration 0: 0.22645133116512697
# Cost in iteration 200: 0.22642932441657107
# Final cost : 0.22642932441657107
# Compute control for a deterministic system
# Cost in iteration 0: 0.22642932441657107
# Cost in iteration 200: 0.22642858728308407
# Cost in iteration 400: 0.2264285317934158
# Final cost : 0.2264285317934158
# Compute control for a deterministic system
# Cost in iteration 0: 0.2264285317934158
# Cost in iteration 200: 0.22642852721740006
# Converged in iteration 304 with cost 0.2264285271720047 because of step counter
# Final cost : 0.2264285271720047
# Compute control for a deterministic system
# Cost in iteration 0: 0.25702430819356814
# Cost in iteration 200: 0.24279927531656564
# Final cost : 0.24279927531656564
# Compute control for a deterministic system
# Cost in iteration 0: 0.24279927531656564
# Cost in iteration 200: 0.24229698811149938
# Final cost : 0.24229698811149938
# Compute control for a deterministic system
# Cost in iteration 0: 0.24229698811149938
# Converged in iteration 43 with cost 0.24228150662765713 because of vanishing difference
# Final cost : 0.24228150662765713
# Compute control for a deterministic system
# Cost in iteration 0: 0.24228150662765713
# Cost in iteration 200: 0.24226408548666958
# Cost in iteration 400: 0.24226221456372202
# Final cost : 0.24226221456372202
# Compute control for a deterministic system
# Cost in iteration 0: 0.24226221456372202
# Cost in iteration 200: 0.2422619753006061
# Converged in iteration 348 with cost 0.24226197526409748 because of vanishing difference
# Final cost : 0.24226197526409748
# Compute control for a deterministic system
# Cost in iteration 0: 0.2832010516649567
# Cost in iteration 200: 0.25519664006031895
# Final cost : 0.25519664006031895
# Compute control for a deterministic system
# Cost in iteration 0: 0.25519664006031895
# Cost in iteration 200: 0.25485560764583665
# Final cost : 0.25485560764583665
# Compute control for a deterministic system
# Cost in iteration 0: 0.25485560764583665
# Converged in iteration 114 with cost 0.2548316202384392 because of vanishing difference
# Final cost : 0.2548316202384392
# Compute control for a deterministic system
# Cost in iteration 0: 0.2548316202384392
# Cost in iteration 200: 0.25482517654865744
# Cost in iteration 400: 0.25482425142462717
# Final cost : 0.25482425142462717
# Compute control for a deterministic system
# Cost in iteration 0: 0.25482425142462717
# Cost in iteration 200: 0.2548240914588292
# Converged in iteration 240 with cost 0.254824091343468 because of vanishing difference
# Final cost : 0.254824091343468
# Compute control for a deterministic system
# Cost in iteration 0: 0.3362981420578157
# Cost in iteration 200: 0.2708837922617862
# Final cost : 0.2708837922617862
# Compute control for a deterministic system
# Cost in iteration 0: 0.2708837922617862
# Cost in iteration 200: 0.2703407692436937
# Final cost : 0.2703407692436937
# Compute control for a deterministic system
# Cost in iteration 0: 0.2703407692436937
# Converged in iteration 126 with cost 0.27029534673252825 because of vanishing difference
# Final cost : 0.27029534673252825
# Compute control for a deterministic system
# Cost in iteration 0: 0.27029534673252825
# Cost in iteration 200: 0.270283337740731
# Cost in iteration 400: 0.27028111060223453
# Final cost : 0.27028111060223453
# Compute control for a deterministic system
# Cost in iteration 0: 0.27028111060223453
# Cost in iteration 200: 0.27028058511393527
# Cost in iteration 400: 0.2702805835275719
# Converged in iteration 456 with cost 0.27028058352562334 because of vanishing difference
# Final cost : 0.27028058352562334
# Compute control for a deterministic system
# Cost in iteration 0: 0.31467903421458465
# Cost in iteration 200: 0.2858665900040209
# Final cost : 0.2858665900040209
# Compute control for a deterministic system
# Cost in iteration 0: 0.2858665900040209
# Cost in iteration 200: 0.2853629865709286
# Final cost : 0.2853629865709286
# Compute control for a deterministic system
# Cost in iteration 0: 0.2853629865709286
# Cost in iteration 200: 0.2853005762724021
# Final cost : 0.2853005762724021
# Compute control for a deterministic system
# Cost in iteration 0: 0.2853005762724021
# Cost in iteration 200: 0.2852930838464016
# Cost in iteration 400: 0.2852913369132254
# Final cost : 0.2852913369132254
# Compute control for a deterministic system
# Cost in iteration 0: 0.2852913369132254
# Cost in iteration 200: 0.28529079652866646
# Cost in iteration 400: 0.2852907936680367
# Converged in iteration 491 with cost 0.2852907936576472 because of vanishing difference
# Final cost : 0.2852907936576472
# Compute control for a deterministic system
# Cost in iteration 0: 0.30134009961524727
# Cost in iteration 200: 0.29728098185631546
# Final cost : 0.29728098185631546
# Compute control for a deterministic system
# Cost in iteration 0: 0.29728098185631546
# Cost in iteration 200: 0.29698794177230753
# Final cost : 0.29698794177230753
# Compute control for a deterministic system
# Cost in iteration 0: 0.29698794177230753
# Cost in iteration 200: 0.29694826182384537
# Final cost : 0.29694826182384537
# Compute control for a deterministic system
# Cost in iteration 0: 0.29694826182384537
# Cost in iteration 200: 0.2969422209056721
# Cost in iteration 400: 0.2969405982234824
# Final cost : 0.2969405982234824
# Compute control for a deterministic system
# Cost in iteration 0: 0.2969405982234824
# Cost in iteration 200: 0.29693998928472937
# Cost in iteration 400: 0.29693998321935866
# Converged in iteration 559 with cost 0.2969399831822928 because of vanishing difference
# Final cost : 0.2969399831822928
# Compute control for a deterministic system
# Cost in iteration 0: 0.324596519924922
# Cost in iteration 200: 0.31174867407968226
# Final cost : 0.31174867407968226
# Compute control for a deterministic system
# Cost in iteration 0: 0.31174867407968226
# Cost in iteration 200: 0.31129949138293717
# Final cost : 0.31129949138293717
# Compute control for a deterministic system
# Cost in iteration 0: 0.31129949138293717
# Converged in iteration 26 with cost 0.3112821405022473 because of vanishing difference
# Final cost : 0.3112821405022473
# Compute control for a deterministic system
# Cost in iteration 0: 0.3112821405022473
# Cost in iteration 200: 0.3112346510416447
# Cost in iteration 400: 0.3112211129006725
# Final cost : 0.3112211129006725
# Compute control for a deterministic system
# Cost in iteration 0: 0.3112211129006725
# Cost in iteration 200: 0.31121522644847643
# Cost in iteration 400: 0.3112149382978007
# Cost in iteration 600: 0.31121493507728604
# Converged in iteration 775 with cost 0.31121493505251674 because of vanishing difference
# Final cost : 0.31121493505251674
# Compute control for a deterministic system
# Cost in iteration 0: 0.3117412859709702
# Cost in iteration 200: 0.28575012794014104
# Final cost : 0.28575012794014104
# Compute control for a deterministic system
# Cost in iteration 0: 0.28575012794014104
# Cost in iteration 200: 0.28492174175485335
# Final cost : 0.28492174175485335
# Compute control for a deterministic system
# Cost in iteration 0: 0.28492174175485335
# Cost in iteration 200: 0.2848604820106912
# Final cost : 0.2848604820106912
# Compute control for a deterministic system
# Cost in iteration 0: 0.2848604820106912
# Cost in iteration 200: 0.284855074864987
# Cost in iteration 400: 0.2848542662725376
# Final cost : 0.2848542662725376
# Compute control for a deterministic system
# Cost in iteration 0: 0.2848542662725376
# Cost in iteration 200: 0.28485415169634476
# Cost in iteration 400: 0.2848541313718467
# Cost in iteration 600: 0.2848541278176407
# Cost in iteration 800: 0.28485412719518727
# Cost in iteration 1000: 0.2848541270851854
# Final cost : 0.2848541270851854
# Compute control for a deterministic system
# Cost in iteration 0: 0.3860904425519607
# Cost in iteration 200: 0.26785738473228027
# Final cost : 0.26785738473228027
# Compute control for a deterministic system
# Cost in iteration 0: 0.26785738473228027
# Cost in iteration 200: 0.2670717568747652
# Final cost : 0.2670717568747652
# Compute control for a deterministic system
# Cost in iteration 0: 0.2670717568747652
# Converged in iteration 105 with cost 0.2670286614084547 because of vanishing difference
# Final cost : 0.2670286614084547
# Compute control for a deterministic system
# Cost in iteration 0: 0.2670286614084547
# Cost in iteration 200: 0.2670171214310853
# Cost in iteration 400: 0.26701586203482264
# Final cost : 0.26701586203482264
# Compute control for a deterministic system
# Cost in iteration 0: 0.26701586203482264
# Cost in iteration 200: 0.2670157301920774
# Cost in iteration 400: 0.2670157130298726
# Cost in iteration 600: 0.2670157108036822
# Cost in iteration 800: 0.26701571051300793
# Cost in iteration 1000: 0.2670157104755498
# Final cost : 0.2670157104755498
# Compute control for a deterministic system
# Cost in iteration 0: 0.34963746627581027
# Cost in iteration 200: 0.2533109625541921
# Final cost : 0.2533109625541921
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533109625541921
# Cost in iteration 200: 0.25282830802486983
# Final cost : 0.25282830802486983
# Compute control for a deterministic system
# Cost in iteration 0: 0.25282830802486983
# Cost in iteration 200: 0.25280225523498917
# Final cost : 0.25280225523498917
# Compute control for a deterministic system
# Cost in iteration 0: 0.25280225523498917
# Cost in iteration 200: 0.25280149368096
# Cost in iteration 400: 0.2528014328246243
# Final cost : 0.2528014328246243
# Compute control for a deterministic system
# Cost in iteration 0: 0.2528014328246243
# Cost in iteration 200: 0.25280142809333983
# Cost in iteration 400: 0.2528014276285544
# Cost in iteration 600: 0.25280142758293445
# Cost in iteration 800: 0.25280142757845697
# Converged in iteration 994 with cost 0.25280142757798507 because of step counter
# Final cost : 0.25280142757798507
# Compute control for a deterministic system
# Cost in iteration 0: 0.24425254037491897
# Cost in iteration 200: 0.23575096869098103
# Final cost : 0.23575096869098103
# Compute control for a deterministic system
# Cost in iteration 0: 0.23575096869098103
# Cost in iteration 200: 0.23511492522515082
# Final cost : 0.23511492522515082
# Compute control for a deterministic system
# Cost in iteration 0: 0.23511492522515082
# Cost in iteration 200: 0.23508768668920688
# Final cost : 0.23508768668920688
# Compute control for a deterministic system
# Cost in iteration 0: 0.23508768668920688
# Cost in iteration 200: 0.23508727624669704
# Cost in iteration 400: 0.2350872551277504
# Final cost : 0.2350872551277504
# Compute control for a deterministic system
# Cost in iteration 0: 0.2350872551277504
# Cost in iteration 200: 0.23508725405321634
# Cost in iteration 400: 0.23508725398383956
# Cost in iteration 600: 0.23508725397936087
# Converged in iteration 719 with cost 0.2350872539790762 because of vanishing difference
# Final cost : 0.2350872539790762
# Compute control for a deterministic system
# Cost in iteration 0: 0.3315278351176757
# Cost in iteration 200: 0.2181018170268208
# Final cost : 0.2181018170268208
# Compute control for a deterministic system
# Cost in iteration 0: 0.2181018170268208
# Cost in iteration 200: 0.21750272696795384
# Final cost : 0.21750272696795384
# Compute control for a deterministic system
# Cost in iteration 0: 0.21750272696795384
# Converged in iteration 9 with cost 0.21750049727819587 because of vanishing difference
# Final cost : 0.21750049727819587
# Compute control for a deterministic system
# Cost in iteration 0: 0.21750049727819587
# Cost in iteration 200: 0.21748601722306907
# Cost in iteration 400: 0.21748557672967483
# Final cost : 0.21748557672967483
# Compute control for a deterministic system
# Cost in iteration 0: 0.21748557672967483
# Cost in iteration 200: 0.21748556348162634
# Cost in iteration 400: 0.21748556296786742
# Cost in iteration 600: 0.21748556294771865
# Converged in iteration 751 with cost 0.21748556294698634 because of vanishing difference
# Final cost : 0.21748556294698634
# Compute control for a deterministic system
# Cost in iteration 0: 0.24834344317376525
# Cost in iteration 200: 0.20057535752808855
# Final cost : 0.20057535752808855
# Compute control for a deterministic system
# Cost in iteration 0: 0.20057535752808855
# Cost in iteration 200: 0.20006708375745785
# Final cost : 0.20006708375745785
# Compute control for a deterministic system
# Cost in iteration 0: 0.20006708375745785
# Cost in iteration 200: 0.2000577248414792
# Final cost : 0.2000577248414792
# Compute control for a deterministic system
# Cost in iteration 0: 0.2000577248414792
# Cost in iteration 200: 0.2000576950646302
# Cost in iteration 400: 0.20005769466522125
# Final cost : 0.20005769466522125
# Compute control for a deterministic system
# Cost in iteration 0: 0.20005769466522125
# Cost in iteration 200: 0.2000576946591211
# Converged in iteration 280 with cost 0.20005769465900738 because of vanishing difference
# Final cost : 0.20005769465900738
# Compute control for a deterministic system
# Cost in iteration 0: 0.1916170603966423
# Cost in iteration 200: 0.18651186974517445
# Final cost : 0.18651186974517445
# Compute control for a deterministic system
# Cost in iteration 0: 0.18651186974517445
# Cost in iteration 200: 0.1862568804576019
# Final cost : 0.1862568804576019
# Compute control for a deterministic system
# Cost in iteration 0: 0.1862568804576019
# Cost in iteration 200: 0.1862546767784112
# Final cost : 0.1862546767784112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1862546767784112
# Converged in iteration 193 with cost 0.18625467575542168 because of vanishing difference
# Final cost : 0.18625467575542168
# Compute control for a deterministic system
# Cost in iteration 0: 0.18625467575542168
# Cost in iteration 200: 0.1862546757469163
# Converged in iteration 230 with cost 0.18625467574686944 because of step counter
# Final cost : 0.18625467574686944
# Compute control for a deterministic system
# Cost in iteration 0: 0.18880299944290774
# Cost in iteration 200: 0.169492403546269
# Final cost : 0.169492403546269
# Compute control for a deterministic system
# Cost in iteration 0: 0.169492403546269
# Cost in iteration 200: 0.16916697829281827
# Final cost : 0.16916697829281827
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916697829281827
# Cost in iteration 200: 0.16916585885698557
# Final cost : 0.16916585885698557
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916585885698557
# Cost in iteration 200: 0.16916585878711615
# Converged in iteration 246 with cost 0.1691658587870073 because of vanishing difference
# Final cost : 0.1691658587870073
# Compute control for a deterministic system
# Cost in iteration 0: 0.1691658587870073
# Converged in iteration 18 with cost 0.16916585878698145 because of step counter
# Final cost : 0.16916585878698145
# Compute control for a deterministic system
# Cost in iteration 0: 0.17395361707759244
# Cost in iteration 200: 0.15248418457922738
# Final cost : 0.15248418457922738
# Compute control for a deterministic system
# Cost in iteration 0: 0.15248418457922738
# Cost in iteration 200: 0.15223759895816702
# Final cost : 0.15223759895816702
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223759895816702
# Cost in iteration 200: 0.15223735915626554
# Final cost : 0.15223735915626554
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223735915626554
# Converged in iteration 129 with cost 0.1522373591545965 because of vanishing difference
# Final cost : 0.1522373591545965
# Compute control for a deterministic system
# Cost in iteration 0: 0.1522373591545965
# Converged in iteration 11 with cost 0.15223735915458586 because of step counter
# Final cost : 0.15223735915458586
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.18563914026970207
# Cost in iteration 200: 0.1389244853445465
# Final cost : 0.1389244853445465
# Compute control for a deterministic system
# Cost in iteration 0: 0.1389244853445465
# Cost in iteration 200: 0.13879203467355658
# Final cost : 0.13879203467355658
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879203467355658
# Cost in iteration 200: 0.1387919908167177
# Final cost : 0.1387919908167177
# Compute control for a deterministic system
# Cost in iteration 0: 0.1387919908167177
# Converged in iteration 22 with cost 0.13879199081670346 because of step counter
# Final cost : 0.13879199081670346
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879199081670346
# Converged in iteration 2 with cost 0.13879199081670288 because of step counter
# Final cost : 0.13879199081670288
# Compute control for a deterministic system
# Cost in iteration 0: 0.16348693660826424
# Cost in iteration 200: 0.12222899500826012
# Final cost : 0.12222899500826012
# Compute control for a deterministic system
# Cost in iteration 0: 0.12222899500826012
# Converged in iteration 145 with cost 0.12208760219842058 because of vanishing difference
# Final cost : 0.12208760219842058
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208760219842058
# Converged in iteration 191 with cost 0.1220874928568534 because of step counter
# Final cost : 0.1220874928568534
# Compute control for a deterministic system
# Cost in iteration 0: 0.1220874928568534
# Converged in iteration 2 with cost 0.12208749285685318 because of step counter
# Final cost : 0.12208749285685318
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208749285685318
# Converged in iteration 1 with cost 0.12208749285685318 because of step counter
# Final cost : 0.12208749285685318
# Compute control for a deterministic system
# Cost in iteration 0: 0.12623900664703813
# Cost in iteration 200: 0.10555235971874477
# Final cost : 0.10555235971874477
# Compute control for a deterministic system
# Cost in iteration 0: 0.10555235971874477
# Cost in iteration 200: 0.10548036319133097
# Final cost : 0.10548036319133097
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036319133097
# Converged in iteration 72 with cost 0.10548036307078086 because of step counter
# Final cost : 0.10548036307078086
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036307078086
# Converged in iteration 5 with cost 0.10548036307077761 because of step counter
# Final cost : 0.10548036307077761
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036307077761
# Converged in iteration 12 with cost 0.10548036307077031 because of step counter
# Final cost : 0.10548036307077031
# Compute control for a deterministic system
# Cost in iteration 0: 0.1539090648699452
# Cost in iteration 200: 0.08899976933166978
# Final cost : 0.08899976933166978
# Compute control for a deterministic system
# Cost in iteration 0: 0.08899976933166978
# Converged in iteration 60 with cost 0.08896012265165529 because of vanishing difference
# Final cost : 0.08896012265165529
# Compute control for a deterministic system
# Cost in iteration 0: 0.08896012265165529
# Converged in iteration 89 with cost 0.0889598834636774 because of vanishing difference
# Final cost : 0.0889598834636774
# Compute control for a deterministic system
# Cost in iteration 0: 0.0889598834636774
# Converged in iteration 23 with cost 0.08895988346365141 because of step counter
# Final cost : 0.08895988346365141
# Compute control for a deterministic system
# Cost in iteration 0: 0.08895988346365141
# Converged in iteration 1 with cost 0.08895988346365141 because of step counter
# Final cost : 0.08895988346365141
# Compute control for a deterministic system
# Cost in iteration 0: 0.11180690081787895
# Cost in iteration 200: 0.075814291183204
# Final cost : 0.075814291183204
# Compute control for a deterministic system
# Cost in iteration 0: 0.075814291183204
# Cost in iteration 200: 0.0758031947146987
# Final cost : 0.0758031947146987
# Compute control for a deterministic system
# Cost in iteration 0: 0.0758031947146987
# Converged in iteration 6 with cost 0.07580319471469216 because of step counter
# Final cost : 0.07580319471469216
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319471469216
# Converged in iteration 1 with cost 0.07580319471469216 because of step counter
# Final cost : 0.07580319471469216
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319471469216
# Converged in iteration 1 with cost 0.07580319471469216 because of step counter
# Final cost : 0.07580319471469216
# Compute control for a deterministic system
# Cost in iteration 0: 0.1115912449540582
# Cost in iteration 200: 0.059439047087216694
# Final cost : 0.059439047087216694
# Compute control for a deterministic system
# Cost in iteration 0: 0.059439047087216694
# Converged in iteration 141 with cost 0.0594345436606401 because of step counter
# Final cost : 0.0594345436606401
# Compute control for a deterministic system
# Cost in iteration 0: 0.0594345436606401
# Converged in iteration 6 with cost 0.05943454366063763 because of step counter
# Final cost : 0.05943454366063763
# Compute control for a deterministic system
# Cost in iteration 0: 0.05943454366063763
# Converged in iteration 2 with cost 0.059434543660637364 because of step counter
# Final cost : 0.059434543660637364
# Compute control for a deterministic system
# Cost in iteration 0: 0.059434543660637364
# Converged in iteration 1 with cost 0.059434543660637364 because of step counter
# Final cost : 0.059434543660637364
# Compute control for a deterministic system
# Cost in iteration 0: 0.0777788610921147
# Cost in iteration 200: 0.043162705407393566
# Final cost : 0.043162705407393566
# Compute control for a deterministic system
# Cost in iteration 0: 0.043162705407393566
# Converged in iteration 79 with cost 0.04316236693774146 because of step counter
# Final cost : 0.04316236693774146
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236693774146
# Converged in iteration 1 with cost 0.04316236693774146 because of vanishing difference
# Final cost : 0.04316236693774146
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236693774146
# Converged in iteration 3 with cost 0.043162366937740906 because of step counter
# Final cost : 0.043162366937740906
# Compute control for a deterministic system
# Cost in iteration 0: 0.043162366937740906
# Converged in iteration 1 with cost 0.043162366937740906 because of step counter
# Final cost : 0.043162366937740906
# Compute control for a deterministic system
# Cost in iteration 0: 0.06553672680317596
# Cost in iteration 200: 0.027009785316785453
# Final cost : 0.027009785316785453
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009785316785453
# Converged in iteration 30 with cost 0.027009784406376768 because of step counter
# Final cost : 0.027009784406376768
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009784406376768
# Converged in iteration 1 with cost 0.027009784406376768 because of step counter
# Final cost : 0.027009784406376768
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009784406376768
# Converged in iteration 1 with cost 0.027009784406376768 because of step counter
# Final cost : 0.027009784406376768
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009784406376768
# Converged in iteration 1 with cost 0.027009784406376768 because of step counter
# Final cost : 0.027009784406376768
# Compute control for a deterministic system
# Cost in iteration 0: 0.03616571089099476
# Converged in iteration 167 with cost 0.014202039953720757 because of step counter
# Final cost : 0.014202039953720757
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202039953720757
# Converged in iteration 12 with cost 0.014202039953717908 because of vanishing difference
# Final cost : 0.014202039953717908
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202039953717908
# Converged in iteration 2 with cost 0.01420203995371732 because of vanishing difference
# Final cost : 0.01420203995371732
# Compute control for a deterministic system
# Cost in iteration 0: 0.01420203995371732
# Converged in iteration 1 with cost 0.01420203995371732 because of step counter
# Final cost : 0.01420203995371732
# Compute control for a deterministic system
# Cost in iteration 0: 0.01420203995371732
# Converged in iteration 1 with cost 0.01420203995371732 because of step counter
# Final cost : 0.01420203995371732
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.05550032461337488
# Converged in iteration 80 with cost 0.027009786530847322 because of step counter
# Final cost : 0.027009786530847322
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009786530847322
# Converged in iteration 2 with cost 0.02700978653084732 because of step counter
# Final cost : 0.02700978653084732
# Compute control for a deterministic system
# Cost in iteration 0: 0.02700978653084732
# Converged in iteration 2 with cost 0.02700978653084667 because of step counter
# Final cost : 0.02700978653084667
# Compute control for a deterministic system
# Cost in iteration 0: 0.02700978653084667
# Converged in iteration 1 with cost 0.02700978653084667 because of step counter
# Final cost : 0.02700978653084667
# Compute control for a deterministic system
# Cost in iteration 0: 0.08828978635647947
# Converged in iteration 133 with cost 0.04316236565008854 because of step counter
# Final cost : 0.04316236565008854
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236565008854
# Converged in iteration 7 with cost 0.04316236565008789 because of step counter
# Final cost : 0.04316236565008789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236565008789
# Converged in iteration 2 with cost 0.04316236565008782 because of step counter
# Final cost : 0.04316236565008782
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236565008782
# Converged in iteration 1 with cost 0.04316236565008782 because of step counter
# Final cost : 0.04316236565008782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0942577079515119
# Converged in iteration 89 with cost 0.059434551076063984 because of vanishing difference
# Final cost : 0.059434551076063984
# Compute control for a deterministic system
# Cost in iteration 0: 0.059434551076063984
# Converged in iteration 49 with cost 0.05943454596426798 because of step counter
# Final cost : 0.05943454596426798
# Compute control for a deterministic system
# Cost in iteration 0: 0.05943454596426798
# Converged in iteration 1 with cost 0.05943454596426798 because of step counter
# Final cost : 0.05943454596426798
# Compute control for a deterministic system
# Cost in iteration 0: 0.05943454596426798
# Converged in iteration 1 with cost 0.05943454596426798 because of step counter
# Final cost : 0.05943454596426798
# Compute control for a deterministic system
# Cost in iteration 0: 0.1289529234141737
# Cost in iteration 200: 0.07580319492150299
# Final cost : 0.07580319492150299
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319492150299
# Converged in iteration 25 with cost 0.07580319492084296 because of step counter
# Final cost : 0.07580319492084296
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319492084296
# Converged in iteration 2 with cost 0.0758031949208429 because of step counter
# Final cost : 0.0758031949208429
# Compute control for a deterministic system
# Cost in iteration 0: 0.0758031949208429
# Converged in iteration 7 with cost 0.0758031949208412 because of step counter
# Final cost : 0.0758031949208412
# Compute control for a deterministic system
# Cost in iteration 0: 0.10940589598652875
# Converged in iteration 82 with cost 0.08896101157199135 because of vanishing difference
# Final cost : 0.08896101157199135
# Compute control for a deterministic system
# Cost in iteration 0: 0.08896101157199135
# Converged in iteration 99 with cost 0.08895988548905365 because of step counter
# Final cost : 0.08895988548905365
# Compute control for a deterministic system
# Cost in iteration 0: 0.08895988548905365
# Converged in iteration 5 with cost 0.08895988548905029 because of step counter
# Final cost : 0.08895988548905029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08895988548905029
# Converged in iteration 14 with cost 0.0889598854890449 because of vanishing difference
# Final cost : 0.0889598854890449
# Compute control for a deterministic system
# Cost in iteration 0: 0.13626393256204117
# Cost in iteration 200: 0.10548036694433893
# Final cost : 0.10548036694433893
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036694433893
# Converged in iteration 108 with cost 0.10548036482201957 because of step counter
# Final cost : 0.10548036482201957
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036482201957
# Converged in iteration 1 with cost 0.10548036482201957 because of step counter
# Final cost : 0.10548036482201957
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036482201957
# Converged in iteration 2 with cost 0.10548036482201874 because of step counter
# Final cost : 0.10548036482201874
# Compute control for a deterministic system
# Cost in iteration 0: 0.14867475063719815
# Converged in iteration 124 with cost 0.12208899043585864 because of vanishing difference
# Final cost : 0.12208899043585864
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208899043585864
# Cost in iteration 200: 0.1220874945575881
# Final cost : 0.1220874945575881
# Compute control for a deterministic system
# Cost in iteration 0: 0.1220874945575881
# Converged in iteration 4 with cost 0.12208749455758519 because of step counter
# Final cost : 0.12208749455758519
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208749455758519
# Converged in iteration 3 with cost 0.12208749455758491 because of step counter
# Final cost : 0.12208749455758491
# Compute control for a deterministic system
# Cost in iteration 0: 0.16291300518290608
# Converged in iteration 123 with cost 0.1387965569866035 because of vanishing difference
# Final cost : 0.1387965569866035
# Compute control for a deterministic system
# Cost in iteration 0: 0.1387965569866035
# Cost in iteration 200: 0.13879199702673772
# Final cost : 0.13879199702673772
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879199702673772
# Converged in iteration 128 with cost 0.1387919970242793 because of step counter
# Final cost : 0.1387919970242793
# Compute control for a deterministic system
# Cost in iteration 0: 0.1387919970242793
# Converged in iteration 3 with cost 0.1387919970242789 because of step counter
# Final cost : 0.1387919970242789
# Compute control for a deterministic system
# Cost in iteration 0: 0.16522230899845658
# Cost in iteration 200: 0.1522377879482416
# Final cost : 0.1522377879482416
# Compute control for a deterministic system
# Cost in iteration 0: 0.1522377879482416
# Cost in iteration 200: 0.15223736628063964
# Final cost : 0.15223736628063964
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223736628063964
# Converged in iteration 133 with cost 0.15223736627767967 because of step counter
# Final cost : 0.15223736627767967
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223736627767967
# Converged in iteration 1 with cost 0.15223736627767967 because of step counter
# Final cost : 0.15223736627767967
# Compute control for a deterministic system
# Cost in iteration 0: 0.22727555102933175
# Cost in iteration 200: 0.16916795331837442
# Final cost : 0.16916795331837442
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916795331837442
# Cost in iteration 200: 0.16916588320326997
# Final cost : 0.16916588320326997
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916588320326997
# Cost in iteration 200: 0.1691658829876482
# Converged in iteration 317 with cost 0.16916588298717014 because of vanishing difference
# Final cost : 0.16916588298717014
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916588298717014
# Converged in iteration 1 with cost 0.16916588298717014 because of step counter
# Final cost : 0.16916588298717014
# Compute control for a deterministic system
# Cost in iteration 0: 0.19918298419150712
# Cost in iteration 200: 0.1862582975916666
# Final cost : 0.1862582975916666
# Compute control for a deterministic system
# Cost in iteration 0: 0.1862582975916666
# Cost in iteration 200: 0.1862546765789142
# Final cost : 0.1862546765789142
# Compute control for a deterministic system
# Cost in iteration 0: 0.1862546765789142
# Cost in iteration 200: 0.18625467575241222
# Converged in iteration 359 with cost 0.18625467574693136 because of vanishing difference
# Final cost : 0.18625467574693136
# Compute control for a deterministic system
# Cost in iteration 0: 0.18625467574693136
# Converged in iteration 32 with cost 0.18625467574687574 because of vanishing difference
# Final cost : 0.18625467574687574
# Compute control for a deterministic system
# Cost in iteration 0: 0.23156121395972012
# Cost in iteration 200: 0.2000645211587907
# Final cost : 0.2000645211587907
# Compute control for a deterministic system
# Cost in iteration 0: 0.2000645211587907
# Cost in iteration 200: 0.2000577133235694
# Final cost : 0.2000577133235694
# Compute control for a deterministic system
# Cost in iteration 0: 0.2000577133235694
# Cost in iteration 200: 0.2000576984209942
# Cost in iteration 400: 0.20005769821157487
# Final cost : 0.20005769821157487
# Compute control for a deterministic system
# Cost in iteration 0: 0.20005769821157487
# Converged in iteration 199 with cost 0.20005769820844976 because of step counter
# Final cost : 0.20005769820844976
# Compute control for a deterministic system
# Cost in iteration 0: 0.2363067079501738
# Cost in iteration 200: 0.21749976933577816
# Final cost : 0.21749976933577816
# Compute control for a deterministic system
# Cost in iteration 0: 0.21749976933577816
# Cost in iteration 200: 0.21748557351220274
# Final cost : 0.21748557351220274
# Compute control for a deterministic system
# Cost in iteration 0: 0.21748557351220274
# Cost in iteration 200: 0.21748550733026625
# Cost in iteration 400: 0.21748550533335437
# Final cost : 0.21748550533335437
# Compute control for a deterministic system
# Cost in iteration 0: 0.21748550533335437
# Cost in iteration 200: 0.21748550527367005
# Cost in iteration 400: 0.21748550527136204
# Converged in iteration 441 with cost 0.21748550527127766 because of step counter
# Final cost : 0.21748550527127766
# Compute control for a deterministic system
# Cost in iteration 0: 0.34402331810925424
# Cost in iteration 200: 0.23512551788632863
# Final cost : 0.23512551788632863
# Compute control for a deterministic system
# Cost in iteration 0: 0.23512551788632863
# Cost in iteration 200: 0.2350877555905627
# Final cost : 0.2350877555905627
# Compute control for a deterministic system
# Cost in iteration 0: 0.2350877555905627
# Cost in iteration 200: 0.23508729782833435
# Cost in iteration 400: 0.23508727456730089
# Final cost : 0.23508727456730089
# Compute control for a deterministic system
# Cost in iteration 0: 0.23508727456730089
# Cost in iteration 200: 0.23508727338725494
# Cost in iteration 400: 0.23508727331029503
# Cost in iteration 600: 0.2350872733053804
# Converged in iteration 735 with cost 0.23508727330505894 because of vanishing difference
# Final cost : 0.23508727330505894
# Compute control for a deterministic system
# Cost in iteration 0: 0.2786479480193719
# Cost in iteration 200: 0.25285147431184984
# Final cost : 0.25285147431184984
# Compute control for a deterministic system
# Cost in iteration 0: 0.25285147431184984
# Cost in iteration 200: 0.2528026871772394
# Final cost : 0.2528026871772394
# Compute control for a deterministic system
# Cost in iteration 0: 0.2528026871772394
# Cost in iteration 200: 0.25280153644461645
# Cost in iteration 400: 0.2528014471546131
# Final cost : 0.2528014471546131
# ...
# Cost in iteration 0: 0.04316268549839094
# Converged in iteration 12 with cost 0.04316237453767598 because of vanishing difference
# Final cost : 0.04316237453767598
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316237453767598
# Converged in iteration 40 with cost 0.043162367439653626 because of step counter
# Final cost : 0.043162367439653626
# Compute control for a deterministic system
# Cost in iteration 0: 0.043162367439653626
# Converged in iteration 3 with cost 0.0431623674396531 because of step counter
# Final cost : 0.0431623674396531
# Compute control for a deterministic system
# Cost in iteration 0: 0.0431623674396531
# Converged in iteration 1 with cost 0.0431623674396531 because of step counter
# Final cost : 0.0431623674396531
# Compute control for a deterministic system
# Cost in iteration 0: 0.07726150833944814
# Cost in iteration 200: 0.027009785475237802
# Final cost : 0.027009785475237802
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009785475237802
# Converged in iteration 32 with cost 0.02700978407509838 because of step counter
# Final cost : 0.02700978407509838
# Compute control for a deterministic system
# Cost in iteration 0: 0.02700978407509838
# Converged in iteration 1 with cost 0.02700978407509838 because of step counter
# Final cost : 0.02700978407509838
# Compute control for a deterministic system
# Cost in iteration 0: 0.02700978407509838
# Converged in iteration 1 with cost 0.02700978407509838 because of step counter
# Final cost : 0.02700978407509838
# Compute control for a deterministic system
# Cost in iteration 0: 0.02700978407509838
# Converged in iteration 1 with cost 0.02700978407509838 because of step counter
# Final cost : 0.02700978407509838
# Compute control for a deterministic system
# Cost in iteration 0: 0.0451264030227919
# Converged in iteration 190 with cost 0.014202040155570946 because of step counter
# Final cost : 0.014202040155570946
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202040155570946
# Converged in iteration 4 with cost 0.014202040155569954 because of step counter
# Final cost : 0.014202040155569954
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202040155569954
# Converged in iteration 2 with cost 0.014202040155569832 because of step counter
# Final cost : 0.014202040155569832
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202040155569832
# Converged in iteration 1 with cost 0.014202040155569832 because of step counter
# Final cost : 0.014202040155569832
# Compute control for a deterministic system
# Cost in iteration 0: 0.014202040155569832
# Converged in iteration 1 with cost 0.014202040155569832 because of step counter
# Final cost : 0.014202040155569832
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.051139968549778085
# Converged in iteration 84 with cost 0.027009785246605522 because of step counter
# Final cost : 0.027009785246605522
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009785246605522
# Converged in iteration 1 with cost 0.027009785246605522 because of step counter
# Final cost : 0.027009785246605522
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009785246605522
# Converged in iteration 5 with cost 0.027009785246604523 because of step counter
# Final cost : 0.027009785246604523
# Compute control for a deterministic system
# Cost in iteration 0: 0.027009785246604523
# Converged in iteration 1 with cost 0.027009785246604523 because of step counter
# Final cost : 0.027009785246604523
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881941087819726
# Converged in iteration 59 with cost 0.043162416523587294 because of vanishing difference
# Final cost : 0.043162416523587294
# Compute control for a deterministic system
# Cost in iteration 0: 0.043162416523587294
# Converged in iteration 40 with cost 0.043162367650614854 because of step counter
# Final cost : 0.043162367650614854
# Compute control for a deterministic system
# Cost in iteration 0: 0.043162367650614854
# Converged in iteration 2 with cost 0.04316236765061467 because of step counter
# Final cost : 0.04316236765061467
# Compute control for a deterministic system
# Cost in iteration 0: 0.04316236765061467
# Converged in iteration 1 with cost 0.04316236765061467 because of step counter
# Final cost : 0.04316236765061467
# Compute control for a deterministic system
# Cost in iteration 0: 0.09197659378152179
# Converged in iteration 182 with cost 0.05943454398195989 because of step counter
# Final cost : 0.05943454398195989
# Compute control for a deterministic system
# Cost in iteration 0: 0.05943454398195989
# Converged in iteration 4 with cost 0.059434543981957334 because of step counter
# Final cost : 0.059434543981957334
# Compute control for a deterministic system
# Cost in iteration 0: 0.059434543981957334
# Converged in iteration 2 with cost 0.05943454398195717 because of step counter
# Final cost : 0.05943454398195717
# Compute control for a deterministic system
# Cost in iteration 0: 0.05943454398195717
# Converged in iteration 1 with cost 0.05943454398195717 because of step counter
# Final cost : 0.05943454398195717
# Compute control for a deterministic system
# Cost in iteration 0: 0.1201647100588574
# Converged in iteration 98 with cost 0.07580327131339994 because of vanishing difference
# Final cost : 0.07580327131339994
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580327131339994
# Converged in iteration 67 with cost 0.07580319694704048 because of step counter
# Final cost : 0.07580319694704048
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319694704048
# Converged in iteration 3 with cost 0.07580319694703982 because of vanishing difference
# Final cost : 0.07580319694703982
# Compute control for a deterministic system
# Cost in iteration 0: 0.07580319694703982
# Converged in iteration 7 with cost 0.07580319694703692 because of step counter
# Final cost : 0.07580319694703692
# Compute control for a deterministic system
# Cost in iteration 0: 0.10318055782361829
# Converged in iteration 116 with cost 0.0889599247926115 because of vanishing difference
# Final cost : 0.0889599247926115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0889599247926115
# Converged in iteration 94 with cost 0.08895988358157922 because of vanishing difference
# Final cost : 0.08895988358157922
# Compute control for a deterministic system
# Cost in iteration 0: 0.08895988358157922
# Converged in iteration 6 with cost 0.088959883581577 because of step counter
# Final cost : 0.088959883581577
# Compute control for a deterministic system
# Cost in iteration 0: 0.088959883581577
# Converged in iteration 2 with cost 0.08895988358157696 because of step counter
# Final cost : 0.08895988358157696
# Compute control for a deterministic system
# Cost in iteration 0: 0.14111603985204263
# Converged in iteration 102 with cost 0.10548146091500847 because of vanishing difference
# Final cost : 0.10548146091500847
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548146091500847
# Converged in iteration 161 with cost 0.10548036619201262 because of step counter
# Final cost : 0.10548036619201262
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036619201262
# Converged in iteration 1 with cost 0.10548036619201262 because of step counter
# Final cost : 0.10548036619201262
# Compute control for a deterministic system
# Cost in iteration 0: 0.10548036619201262
# Converged in iteration 2 with cost 0.10548036619201254 because of step counter
# Final cost : 0.10548036619201254
# Compute control for a deterministic system
# Cost in iteration 0: 0.16275489309596955
# Cost in iteration 200: 0.12208752031666723
# Final cost : 0.12208752031666723
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208752031666723
# Converged in iteration 179 with cost 0.12208748985418388 because of vanishing difference
# Final cost : 0.12208748985418388
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208748985418388
# Converged in iteration 6 with cost 0.12208748985418301 because of step counter
# Final cost : 0.12208748985418301
# Compute control for a deterministic system
# Cost in iteration 0: 0.12208748985418301
# Converged in iteration 2 with cost 0.12208748985418295 because of step counter
# Final cost : 0.12208748985418295
# Compute control for a deterministic system
# Cost in iteration 0: 0.16728556586133994
# Cost in iteration 200: 0.13879222124629811
# Final cost : 0.13879222124629811
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879222124629811
# Cost in iteration 200: 0.13879199991062408
# Final cost : 0.13879199991062408
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879199991062408
# Converged in iteration 59 with cost 0.13879199991051294 because of vanishing difference
# Final cost : 0.13879199991051294
# Compute control for a deterministic system
# Cost in iteration 0: 0.13879199991051294
# Converged in iteration 1 with cost 0.13879199991051294 because of vanishing difference
# Final cost : 0.13879199991051294
# Compute control for a deterministic system
# Cost in iteration 0: 0.18623538570675835
# Cost in iteration 200: 0.15223780487359762
# Final cost : 0.15223780487359762
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223780487359762
# Cost in iteration 200: 0.15223736106412142
# Final cost : 0.15223736106412142
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223736106412142
# Converged in iteration 147 with cost 0.15223736106135136 because of vanishing difference
# Final cost : 0.15223736106135136
# Compute control for a deterministic system
# Cost in iteration 0: 0.15223736106135136
# Converged in iteration 3 with cost 0.15223736106135083 because of step counter
# Final cost : 0.15223736106135083
# Compute control for a deterministic system
# Cost in iteration 0: 0.25832207810560254
# Cost in iteration 200: 0.16916801878119628
# Final cost : 0.16916801878119628
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916801878119628
# Cost in iteration 200: 0.16916586712041437
# Final cost : 0.16916586712041437
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916586712041437
# Cost in iteration 200: 0.16916586696127395
# Converged in iteration 212 with cost 0.16916586696117503 because of vanishing difference
# Final cost : 0.16916586696117503
# Compute control for a deterministic system
# Cost in iteration 0: 0.16916586696117503
# Converged in iteration 33 with cost 0.16916586696102423 because of vanishing difference
# Final cost : 0.16916586696102423
# Compute control for a deterministic system
# Cost in iteration 0: 0.21329542468863258
# Cost in iteration 200: 0.18625982291187734
# Final cost : 0.18625982291187734
# Compute control for a deterministic system
# Cost in iteration 0: 0.18625982291187734
# Cost in iteration 200: 0.18625470215029055
# Final cost : 0.18625470215029055
# Compute control for a deterministic system
# Cost in iteration 0: 0.18625470215029055
# Cost in iteration 200: 0.1862547008240491
# Cost in iteration 400: 0.1862547008148022
# Final cost : 0.1862547008148022
# Compute control for a deterministic system
# Cost in iteration 0: 0.1862547008148022
# Converged in iteration 23 with cost 0.18625470081477613 because of vanishing difference
# Final cost : 0.18625470081477613
# Compute control for a deterministic system
# Cost in iteration 0: 0.22572686708999634
# Cost in iteration 200: 0.20006445794327038
# Final cost : 0.20006445794327038
# Compute control for a deterministic system
# Cost in iteration 0: 0.20006445794327038
# Converged in iteration 32 with cost 0.2000599526628046 because of vanishing difference
# Final cost : 0.2000599526628046
# Compute control for a deterministic system
# Cost in iteration 0: 0.2000599526628046
# Cost in iteration 200: 0.20005774151106492
# Cost in iteration 400: 0.20005771434218336
# Final cost : 0.20005771434218336
# Compute control for a deterministic system
# Cost in iteration 0: 0.20005771434218336
# Cost in iteration 200: 0.200057713938299
# Cost in iteration 400: 0.2000577139298878
# Converged in iteration 471 with cost 0.2000577139297566 because of step counter
# Final cost : 0.2000577139297566
# Compute control for a deterministic system
# Cost in iteration 0: 0.23481352137098305
# Cost in iteration 200: 0.21749975913789546
# Final cost : 0.21749975913789546
# Compute control for a deterministic system
# Cost in iteration 0: 0.21749975913789546
# Cost in iteration 200: 0.21748556957792545
# Final cost : 0.21748556957792545
# Compute control for a deterministic system
# Cost in iteration 0: 0.21748556957792545
# Cost in iteration 200: 0.21748550711898465
# Cost in iteration 400: 0.2174855053267511
# Final cost : 0.2174855053267511
# Compute control for a deterministic system
# Cost in iteration 0: 0.2174855053267511
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [18], line 76
#      73 wc_controlled.update_input()
#      74 wc_controlled.simulate_forward()
# ---> 76 increase_step_compute()
#      78 if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
#      79     print("-----------------------------------------------")
#
# Cell In [13], line 16, in increase_step_compute()
#      14 wc_controlled.step = 1e1
#      15 wc_controlled.zero_step_encountered = False
# ---> 16 wc_controlled.optimize(1000)
#      18 return
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:556, in OC.optimize(self, n_max_iterations)
#     554 if self.M == 1:
#     555     print("Compute control for a deterministic system")
# --> 556     return self.optimize_deterministic(n_max_iterations)
#     557 else:
#     558     print("Compute control for a noisy system")
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:585, in OC.optimize_deterministic(self, n_max_iterations)
#     582     break
#     584 c0 = self.control.copy()
# --> 585 self.step_size(-self.grad)
#     587 if self.zero_step_encountered:
#     588     print(f"Converged in iteration %s with cost %s because of step counter" % (i, cost))
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:502, in OC.step_size(self, cost_gradient)
#     498 self.control = update_control_with_limit(
#     499     control0, step_node[n, v], gradient_node, self.maximum_control_strength
#     500 )
#     501 self.update_input()
# --> 502 self.simulate_forward()
#     503 cost_node[n, v] = self.compute_total_cost()
#     505 if counter == self.count_step:
#
# File ~/Promotion/neurolib/neurolib/optimal_control/oc.py:341, in OC.simulate_forward(self)
#     337 def simulate_forward(self):
#     338     """Updates self.xs in accordance to the current self.control.
#     339     Results can be accessed with self.get_xs()
#     340     """
# --> 341     self.model.run()
#
# File ~/Promotion/neurolib/neurolib/models/model.py:247, in Model.run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run)
#     244 chunkwise = chunkwise if chunksize is None else True
#     246 if chunkwise is False:
# --> 247     self.integrate(append_outputs=append, simulate_bold=bold)
#     248     if continue_run:
#     249         self.setInitialValuesToLastState()
#
# File ~/Promotion/neurolib/neurolib/models/model.py:291, in Model.integrate(self, append_outputs, simulate_bold)
#     285 """Calls each models `integration` function and saves the state and the outputs of the model.
#     286
#     287 :param append: append the chunkwise outputs to the outputs attribute, defaults to False, defaults to False
#     288 :type append: bool, optional
#     289 """
#     290 # run integration
# --> 291 t, *variables = self.integration(self.params)
#     292 self.storeOutputsAndStates(t, variables, append=append_outputs)
#     294 # force bold if params['bold'] == True
#
# File ~/Promotion/neurolib/neurolib/models/wc/timeIntegration.py:112, in timeIntegration(params)
#     109 excs[:, :startind] = exc_init
#     110 inhs[:, :startind] = inh_init
# --> 112 noise_exc = np.zeros((N,))
#     113 noise_inh = np.zeros((N,))
#     115 # ------------------------------------------------------------------------
#
# KeyboardInterrupt:

# %%
save(results_min)
