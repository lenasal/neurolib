# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
def plot_single(time, state, control, target, filename=None):

    fig, ax = plt.subplots(2,1)

    ax[0].plot(time, state[0,0,1:], color="red")
    ax[0].plot(time, state[0,1,1:], color="blue")
    ax[0].plot(time, target[0,0,1:], color="red", linestyle=':')
    ax[0].plot(time, target[0,1,1:], color="blue", linestyle=':')
    #ax[0].set_xlim(0,300)

    ax[1].plot(time, control[0,0,1:], color="red")
    ax[1].plot(time, control[0,1,1:], color="blue")
    #ax[1].set_xlim(0,300)

    if type(filename) != type(None):
        plt.savefig(filename)
    plt.show()

savepath =  '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + 'writing' + os.sep + 'paper2_chaos' + os.sep + 'exploration' + os.sep + 'images_ops' + os.sep

def plot(c_array, filename):

    fig, ax = plt.subplots(len(c_array),1, figsize=(10,2.*len(c_array)))

    for i in range(len(c_array)):
        ax[i].plot(wc_controlled.model.t, c_array[i][0,0,1:], color="red")
        ax[i].plot(wc_controlled.model.t, c_array[i][0,1,1:], color="blue")
        ax[i].set_ylim([-0.4,0.4])
        ax[i].set_title(str(np.round(i*2./(len(c_array)-1), 2))+ " * pi")
        if i != len(c_array)-1:
            ax[i].set_xticklabels([])

    plt.savefig(os.path.join(savepath, filename))
    plt.show()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_peak = [wc.exc[0,185], wc.inh[0,185]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# peaks =  [ 111  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2945 3134 3323 3512 3701 3890 4079 4268 4457 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

ind_list = []
options = [True, True, True, True, True, True, True, True]
#options = [False, False, False, False, False, False, True, False]

for k in range(9):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["models"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.1
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.1
                if i_shift < n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.031014454211455586
# Converged in iteration 109 with cost 0.01927504071668243 because of step counter
# Final cost : 0.01927504071668243
# Compute control for a deterministic system
# Cost in iteration 0: 0.01927504071668243
# Converged in iteration 1 with cost 0.01927504071668243 because of step counter
# Final cost : 0.01927504071668243
# Compute control for a deterministic system
# Cost in iteration 0: 0.01927504071668243
# Converged in iteration 1 with cost 0.01927504071668243 because of step counter
# Final cost : 0.01927504071668243
# Compute control for a deterministic system
# Cost in iteration 0: 0.01927504071668243
# Converged in iteration 1 with cost 0.01927504071668243 because of step counter
# Final cost : 0.01927504071668243
# Compute control for a deterministic system
# Cost in iteration 0: 0.01927504071668243
# Converged in iteration 1 with cost 0.01927504071668243 because of step counter
# Final cost : 0.01927504071668243
# Compute control for a deterministic system
# Cost in iteration 0: 0.04318588436551683
# Converged in iteration 117 with cost 0.026518027088029042 because of step counter
# Final cost : 0.026518027088029042
# Compute control for a deterministic system
# Cost in iteration 0: 0.026518027088029042
# Converged in iteration 1 with cost 0.026518027088029042 because of step counter
# Final cost : 0.026518027088029042
# Compute control for a deterministic system
# Cost in iteration 0: 0.026518027088029042
# Converged in iteration 1 with cost 0.026518027088029042 because of step counter
# Final cost : 0.026518027088029042
# Compute control for a deterministic system
# Cost in iteration 0: 0.026518027088029042
# Converged in iteration 1 with cost 0.026518027088029042 because of step counter
# Final cost : 0.026518027088029042
# Compute control for a deterministic system
# Cost in iteration 0: 0.026518027088029042
# Converged in iteration 1 with cost 0.026518027088029042 because of step counter
# Final cost : 0.026518027088029042
# Compute control for a deterministic system
# Cost in iteration 0: 0.04104409073440952
# Converged in iteration 104 with cost 0.029476021145247305 because of step counter
# Final cost : 0.029476021145247305
# Compute control for a deterministic system
# Cost in iteration 0: 0.029476021145247305
# Converged in iteration 1 with cost 0.029476021145247305 because of step counter
# Final cost : 0.029476021145247305
# Compute control for a deterministic system
# Cost in iteration 0: 0.029476021145247305
# Converged in iteration 1 with cost 0.029476021145247305 because of step counter
# Final cost : 0.029476021145247305
# Compute control for a deterministic system
# Cost in iteration 0: 0.029476021145247305
# Converged in iteration 1 with cost 0.029476021145247305 because of step counter
# Final cost : 0.029476021145247305
# Compute control for a deterministic system
# Cost in iteration 0: 0.029476021145247305
# Converged in iteration 1 with cost 0.029476021145247305 because of step counter
# Final cost : 0.029476021145247305
# Compute control for a deterministic system
# Cost in iteration 0: 0.039668247342744545
# Converged in iteration 98 with cost 0.032900678907792316 because of step counter
# Final cost : 0.032900678907792316
# Compute control for a deterministic system
# Cost in iteration 0: 0.032900678907792316
# Converged in iteration 1 with cost 0.032900678907792316 because of step counter
# Final cost : 0.032900678907792316
# Compute control for a deterministic system
# Cost in iteration 0: 0.032900678907792316
# Converged in iteration 1 with cost 0.032900678907792316 because of step counter
# Final cost : 0.032900678907792316
# Compute control for a deterministic system
# Cost in iteration 0: 0.032900678907792316
# Converged in iteration 1 with cost 0.032900678907792316 because of step counter
# Final cost : 0.032900678907792316
# Compute control for a deterministic system
# Cost in iteration 0: 0.032900678907792316
# Converged in iteration 1 with cost 0.032900678907792316 because of step counter
# Final cost : 0.032900678907792316
# Compute control for a deterministic system
# Cost in iteration 0: 0.03321122886287433
# Converged in iteration 56 with cost 0.033162165495416666 because of step counter
# Final cost : 0.033162165495416666
# Compute control for a deterministic system
# Cost in iteration 0: 0.033162165495416666
# Converged in iteration 2 with cost 0.033162165495416236 because of step counter
# Final cost : 0.033162165495416236
# Compute control for a deterministic system
# Cost in iteration 0: 0.033162165495416236
# Converged in iteration 1 with cost 0.033162165495416236 because of step counter
# Final cost : 0.033162165495416236
# Compute control for a deterministic system
# Cost in iteration 0: 0.033162165495416236
# Converged in iteration 1 with cost 0.033162165495416236 because of step counter
# Final cost : 0.033162165495416236
# Compute control for a deterministic system
# Cost in iteration 0: 0.033162165495416236
# Converged in iteration 1 with cost 0.033162165495416236 because of step counter
# Final cost : 0.033162165495416236
# Compute control for a deterministic system
# Cost in iteration 0: 0.04257550885449937
# Converged in iteration 85 with cost 0.04008318913398987 because of step counter
# Final cost : 0.04008318913398987
# Compute control for a deterministic system
# Cost in iteration 0: 0.04008318913398987
# Converged in iteration 1 with cost 0.04008318913398987 because of step counter
# Final cost : 0.04008318913398987
# Compute control for a deterministic system
# Cost in iteration 0: 0.04008318913398987
# Converged in iteration 1 with cost 0.04008318913398987 because of step counter
# Final cost : 0.04008318913398987
# Compute control for a deterministic system
# Cost in iteration 0: 0.04008318913398987
# Converged in iteration 1 with cost 0.04008318913398987 because of step counter
# Final cost : 0.04008318913398987
# Compute control for a deterministic system
# Cost in iteration 0: 0.04008318913398987
# Converged in iteration 1 with cost 0.04008318913398987 because of step counter
# Final cost : 0.04008318913398987
# Compute control for a deterministic system
# Cost in iteration 0: 0.044124348143924824
# Converged in iteration 74 with cost 0.043155376080974736 because of step counter
# Final cost : 0.043155376080974736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043155376080974736
# Converged in iteration 1 with cost 0.043155376080974736 because of step counter
# Final cost : 0.043155376080974736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043155376080974736
# Converged in iteration 1 with cost 0.043155376080974736 because of step counter
# Final cost : 0.043155376080974736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043155376080974736
# Converged in iteration 1 with cost 0.043155376080974736 because of step counter
# Final cost : 0.043155376080974736
# Compute control for a deterministic system
# Cost in iteration 0: 0.043155376080974736
# Converged in iteration 1 with cost 0.043155376080974736 because of step counter
# Final cost : 0.043155376080974736
# Compute control for a deterministic system
# Cost in iteration 0: 0.04990664296806531
# Converged in iteration 73 with cost 0.04857494304054977 because of step counter
# Final cost : 0.04857494304054977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04857494304054977
# Converged in iteration 1 with cost 0.04857494304054977 because of step counter
# Final cost : 0.04857494304054977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04857494304054977
# Converged in iteration 1 with cost 0.04857494304054977 because of step counter
# Final cost : 0.04857494304054977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04857494304054977
# Converged in iteration 1 with cost 0.04857494304054977 because of step counter
# Final cost : 0.04857494304054977
# Compute control for a deterministic system
# Cost in iteration 0: 0.04857494304054977
# Converged in iteration 1 with cost 0.04857494304054977 because of step counter
# Final cost : 0.04857494304054977
# Compute control for a deterministic system
# Cost in iteration 0: 0.053110779012236424
# Converged in iteration 108 with cost 0.052131085347150004 because of step counter
# Final cost : 0.052131085347150004
# Compute control for a deterministic system
# Cost in iteration 0: 0.052131085347150004
# Converged in iteration 1 with cost 0.052131085347150004 because of step counter
# Final cost : 0.052131085347150004
# Compute control for a deterministic system
# Cost in iteration 0: 0.052131085347150004
# Converged in iteration 1 with cost 0.052131085347150004 because of step counter
# Final cost : 0.052131085347150004
# Compute control for a deterministic system
# Cost in iteration 0: 0.052131085347150004
# Converged in iteration 1 with cost 0.052131085347150004 because of step counter
# Final cost : 0.052131085347150004
# Compute control for a deterministic system
# Cost in iteration 0: 0.052131085347150004
# Converged in iteration 1 with cost 0.052131085347150004 because of step counter
# Final cost : 0.052131085347150004
# Compute control for a deterministic system
# Cost in iteration 0: 0.06574614503784916
# Converged in iteration 112 with cost 0.06207945849403189 because of step counter
# Final cost : 0.06207945849403189
# Compute control for a deterministic system
# Cost in iteration 0: 0.06207945849403189
# Converged in iteration 1 with cost 0.06207945849403189 because of step counter
# Final cost : 0.06207945849403189
# Compute control for a deterministic system
# Cost in iteration 0: 0.06207945849403189
# Converged in iteration 1 with cost 0.06207945849403189 because of step counter
# Final cost : 0.06207945849403189
# Compute control for a deterministic system
# Cost in iteration 0: 0.06207945849403189
# Converged in iteration 1 with cost 0.06207945849403189 because of step counter
# Final cost : 0.06207945849403189
# Compute control for a deterministic system
# Cost in iteration 0: 0.06207945849403189
# Converged in iteration 1 with cost 0.06207945849403189 because of step counter
# Final cost : 0.06207945849403189
# Compute control for a deterministic system
# Cost in iteration 0: 0.06486735975501673
# Converged in iteration 117 with cost 0.0640382782660729 because of step counter
# Final cost : 0.0640382782660729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0640382782660729
# Converged in iteration 1 with cost 0.0640382782660729 because of step counter
# Final cost : 0.0640382782660729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0640382782660729
# Converged in iteration 1 with cost 0.0640382782660729 because of step counter
# Final cost : 0.0640382782660729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0640382782660729
# Converged in iteration 1 with cost 0.0640382782660729 because of step counter
# Final cost : 0.0640382782660729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0640382782660729
# Converged in iteration 1 with cost 0.0640382782660729 because of step counter
# Final cost : 0.0640382782660729
# Compute control for a deterministic system
# Cost in iteration 0: 0.06990773996378552
# Converged in iteration 126 with cost 0.06961070261672506 because of step counter
# Final cost : 0.06961070261672506
# Compute control for a deterministic system
# Cost in iteration 0: 0.06961070261672506
# Converged in iteration 1 with cost 0.06961070261672506 because of step counter
# Final cost : 0.06961070261672506
# Compute control for a deterministic system
# Cost in iteration 0: 0.06961070261672506
# Converged in iteration 1 with cost 0.06961070261672506 because of step counter
# Final cost : 0.06961070261672506
# Compute control for a deterministic system
# Cost in iteration 0: 0.06961070261672506
# Converged in iteration 1 with cost 0.06961070261672506 because of step counter
# Final cost : 0.06961070261672506
# Compute control for a deterministic system
# Cost in iteration 0: 0.06961070261672506
# Converged in iteration 1 with cost 0.06961070261672506 because of step counter
# Final cost : 0.06961070261672506
# Compute control for a deterministic system
# Cost in iteration 0: 0.08344891843377061
# Cost in iteration 200: 0.07084140785497504
# Final cost : 0.07084140785497504
# Compute control for a deterministic system
# Cost in iteration 0: 0.07084140785497504
# Converged in iteration 14 with cost 0.07083625467549877 because of step counter
# Final cost : 0.07083625467549877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083625467549877
# Converged in iteration 1 with cost 0.07083625467549877 because of step counter
# Final cost : 0.07083625467549877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083625467549877
# Converged in iteration 1 with cost 0.07083625467549877 because of step counter
# Final cost : 0.07083625467549877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07083625467549877
# Converged in iteration 1 with cost 0.07083625467549877 because of step counter
# Final cost : 0.07083625467549877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07727065066528255
# Converged in iteration 190 with cost 0.07477183875838742 because of step counter
# Final cost : 0.07477183875838742
# Compute control for a deterministic system
# Cost in iteration 0: 0.07477183875838742
# Converged in iteration 1 with cost 0.07477183875838742 because of step counter
# Final cost : 0.07477183875838742
# Compute control for a deterministic system
# Cost in iteration 0: 0.07477183875838742
# Converged in iteration 1 with cost 0.07477183875838742 because of step counter
# Final cost : 0.07477183875838742
# Compute control for a deterministic system
# Cost in iteration 0: 0.07477183875838742
# Converged in iteration 1 with cost 0.07477183875838742 because of step counter
# Final cost : 0.07477183875838742
# Compute control for a deterministic system
# Cost in iteration 0: 0.07477183875838742
# Converged in iteration 1 with cost 0.07477183875838742 because of step counter
# Final cost : 0.07477183875838742
# Compute control for a deterministic system
# Cost in iteration 0: 0.08145982441753669
# Cost in iteration 200: 0.08045096246530298
# Final cost : 0.08045096246530298
# Compute control for a deterministic system
# Cost in iteration 0: 0.08045096246530298
# Converged in iteration 3 with cost 0.08044859504335823 because of step counter
# Final cost : 0.08044859504335823
# Compute control for a deterministic system
# Cost in iteration 0: 0.08044859504335823
# Converged in iteration 1 with cost 0.08044859504335823 because of step counter
# Final cost : 0.08044859504335823
# Compute control for a deterministic system
# Cost in iteration 0: 0.08044859504335823
# Converged in iteration 1 with cost 0.08044859504335823 because of step counter
# Final cost : 0.08044859504335823
# Compute control for a deterministic system
# Cost in iteration 0: 0.08044859504335823
# Converged in iteration 1 with cost 0.08044859504335823 because of step counter
# Final cost : 0.08044859504335823
# Compute control for a deterministic system
# Cost in iteration 0: 0.09337897285433354
# Cost in iteration 200: 0.0846329627330627
# Final cost : 0.0846329627330627
# Compute control for a deterministic system
# Cost in iteration 0: 0.0846329627330627
# Converged in iteration 29 with cost 0.08391688049982951 because of step counter
# Final cost : 0.08391688049982951
# Compute control for a deterministic system
# Cost in iteration 0: 0.08391688049982951
# Converged in iteration 1 with cost 0.08391688049982951 because of step counter
# Final cost : 0.08391688049982951
# Compute control for a deterministic system
# Cost in iteration 0: 0.08391688049982951
# Converged in iteration 1 with cost 0.08391688049982951 because of step counter
# Final cost : 0.08391688049982951
# Compute control for a deterministic system
# Cost in iteration 0: 0.08391688049982951
# Converged in iteration 1 with cost 0.08391688049982951 because of step counter
# Final cost : 0.08391688049982951
# Compute control for a deterministic system
# Cost in iteration 0: 0.08960570545464305
# Cost in iteration 200: 0.08732266316671379
# Final cost : 0.08732266316671379
# Compute control for a deterministic system
# Cost in iteration 0: 0.08732266316671379
# Converged in iteration 19 with cost 0.08697548306724147 because of step counter
# Final cost : 0.08697548306724147
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697548306724147
# Converged in iteration 1 with cost 0.08697548306724147 because of step counter
# Final cost : 0.08697548306724147
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697548306724147
# Converged in iteration 1 with cost 0.08697548306724147 because of step counter
# Final cost : 0.08697548306724147
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697548306724147
# Converged in iteration 1 with cost 0.08697548306724147 because of step counter
# Final cost : 0.08697548306724147
# Compute control for a deterministic system
# Cost in iteration 0: 0.09464156770382086
# Cost in iteration 200: 0.09287352718933067
# Final cost : 0.09287352718933067
# Compute control for a deterministic system
# Cost in iteration 0: 0.09287352718933067
# Converged in iteration 10 with cost 0.09272042481740779 because of step counter
# Final cost : 0.09272042481740779
# Compute control for a deterministic system
# Cost in iteration 0: 0.09272042481740779
# Converged in iteration 1 with cost 0.09272042481740779 because of step counter
# Final cost : 0.09272042481740779
# Compute control for a deterministic system
# Cost in iteration 0: 0.09272042481740779
# Converged in iteration 1 with cost 0.09272042481740779 because of step counter
# Final cost : 0.09272042481740779
# Compute control for a deterministic system
# Cost in iteration 0: 0.09272042481740779
# Converged in iteration 1 with cost 0.09272042481740779 because of step counter
# Final cost : 0.09272042481740779
# Compute control for a deterministic system
# Cost in iteration 0: 0.10044068203341737
# Cost in iteration 200: 0.09904113204372603
# Final cost : 0.09904113204372603
# Compute control for a deterministic system
# Cost in iteration 0: 0.09904113204372603
# Converged in iteration 13 with cost 0.0987944889125781 because of step counter
# Final cost : 0.0987944889125781
# Compute control for a deterministic system
# Cost in iteration 0: 0.0987944889125781
# Converged in iteration 1 with cost 0.0987944889125781 because of step counter
# Final cost : 0.0987944889125781
# Compute control for a deterministic system
# Cost in iteration 0: 0.0987944889125781
# Converged in iteration 1 with cost 0.0987944889125781 because of step counter
# Final cost : 0.0987944889125781
# Compute control for a deterministic system
# Cost in iteration 0: 0.0987944889125781
# Converged in iteration 1 with cost 0.0987944889125781 because of step counter
# Final cost : 0.0987944889125781
# Compute control for a deterministic system
# Cost in iteration 0: 0.14345780337017686
# Converged in iteration 129 with cost 0.11650237252846504 because of step counter
# Final cost : 0.11650237252846504
# Compute control for a deterministic system
# Cost in iteration 0: 0.11650237252846504
# Converged in iteration 1 with cost 0.11650237252846504 because of step counter
# Final cost : 0.11650237252846504
# Compute control for a deterministic system
# Cost in iteration 0: 0.11650237252846504
# Converged in iteration 1 with cost 0.11650237252846504 because of step counter
# Final cost : 0.11650237252846504
# Compute control for a deterministic system
# Cost in iteration 0: 0.11650237252846504
# Converged in iteration 1 with cost 0.11650237252846504 because of step counter
# Final cost : 0.11650237252846504
# Compute control for a deterministic system
# Cost in iteration 0: 0.11650237252846504
# Converged in iteration 1 with cost 0.11650237252846504 because of step counter
# Final cost : 0.11650237252846504
# Compute control for a deterministic system
# Cost in iteration 0: 0.12440899151085402
# Cost in iteration 200: 0.08741600632697069
# Final cost : 0.08741600632697069
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741600632697069
# Converged in iteration 81 with cost 0.08463233825209585 because of step counter
# Final cost : 0.08463233825209585
# Compute control for a deterministic system
# Cost in iteration 0: 0.08463233825209585
# Converged in iteration 1 with cost 0.08463233825209585 because of step counter
# Final cost : 0.08463233825209585
# Compute control for a deterministic system
# Cost in iteration 0: 0.08463233825209585
# Converged in iteration 1 with cost 0.08463233825209585 because of step counter
# Final cost : 0.08463233825209585
# Compute control for a deterministic system
# Cost in iteration 0: 0.08463233825209585
# Converged in iteration 1 with cost 0.08463233825209585 because of step counter
# Final cost : 0.08463233825209585
# Compute control for a deterministic system
# Cost in iteration 0: 0.11877348733104148
# Cost in iteration 200: 0.08135639471267589
# Final cost : 0.08135639471267589
# Compute control for a deterministic system
# Cost in iteration 0: 0.08135639471267589
# Converged in iteration 91 with cost 0.07886679906183744 because of step counter
# Final cost : 0.07886679906183744
# Compute control for a deterministic system
# Cost in iteration 0: 0.07886679906183744
# Converged in iteration 1 with cost 0.07886679906183744 because of step counter
# Final cost : 0.07886679906183744
# Compute control for a deterministic system
# Cost in iteration 0: 0.07886679906183744
# Converged in iteration 1 with cost 0.07886679906183744 because of step counter
# Final cost : 0.07886679906183744
# Compute control for a deterministic system
# Cost in iteration 0: 0.07886679906183744
# Converged in iteration 1 with cost 0.07886679906183744 because of step counter
# Final cost : 0.07886679906183744
# Compute control for a deterministic system
# Cost in iteration 0: 0.09946784868311483
# Cost in iteration 200: 0.07544667636880018
# Final cost : 0.07544667636880018
# Compute control for a deterministic system
# Cost in iteration 0: 0.07544667636880018
# Converged in iteration 68 with cost 0.0748978430582986 because of step counter
# Final cost : 0.0748978430582986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0748978430582986
# Converged in iteration 1 with cost 0.0748978430582986 because of step counter
# Final cost : 0.0748978430582986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0748978430582986
# Converged in iteration 1 with cost 0.0748978430582986 because of step counter
# Final cost : 0.0748978430582986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0748978430582986
# Converged in iteration 1 with cost 0.0748978430582986 because of step counter
# Final cost : 0.0748978430582986
# Compute control for a deterministic system
# Cost in iteration 0: 0.11139220305468737
# Cost in iteration 200: 0.07410879368880263
# Final cost : 0.07410879368880263
# Compute control for a deterministic system
# Cost in iteration 0: 0.07410879368880263
# Cost in iteration 200: 0.07206996451070094
# Final cost : 0.07206996451070094
# Compute control for a deterministic system
# Cost in iteration 0: 0.07206996451070094
# Converged in iteration 11 with cost 0.07203029160719962 because of step counter
# Final cost : 0.07203029160719962
# Compute control for a deterministic system
# Cost in iteration 0: 0.07203029160719962
# Converged in iteration 1 with cost 0.07203029160719962 because of step counter
# Final cost : 0.07203029160719962
# Compute control for a deterministic system
# Cost in iteration 0: 0.07203029160719962
# Converged in iteration 1 with cost 0.07203029160719962 because of step counter
# Final cost : 0.07203029160719962
# Compute control for a deterministic system
# Cost in iteration 0: 0.11002857308429306
# Cost in iteration 200: 0.07112363956005331
# Final cost : 0.07112363956005331
# Compute control for a deterministic system
# Cost in iteration 0: 0.07112363956005331
# Cost in iteration 200: 0.07020726733445021
# Final cost : 0.07020726733445021
# Compute control for a deterministic system
# Cost in iteration 0: 0.07020726733445021
# Cost in iteration 200: 0.07003630229272277
# Final cost : 0.07003630229272277
# Compute control for a deterministic system
# Cost in iteration 0: 0.07003630229272277
# Converged in iteration 2 with cost 0.07003630227572176 because of vanishing difference
# Final cost : 0.07003630227572176
# Compute control for a deterministic system
# Cost in iteration 0: 0.07003630227572166
# Converged in iteration 1 with cost 0.07003630227572166 because of step counter
# Final cost : 0.07003630227572166
# Compute control for a deterministic system
# Cost in iteration 0: 0.10530277577741762
# Cost in iteration 200: 0.06620869193724202
# Final cost : 0.06620869193724202
# Compute control for a deterministic system
# Cost in iteration 0: 0.06620869193724202
# Cost in iteration 200: 0.06418411833486472
# Final cost : 0.06418411833486472
# Compute control for a deterministic system
# Cost in iteration 0: 0.06418411833486472
# Converged in iteration 8 with cost 0.06415118995090947 because of step counter
# Final cost : 0.06415118995090947
# Compute control for a deterministic system
# Cost in iteration 0: 0.06415118995090947
# Converged in iteration 1 with cost 0.06415118995090947 because of step counter
# Final cost : 0.06415118995090947
# Compute control for a deterministic system
# Cost in iteration 0: 0.06415118995090947
# Converged in iteration 1 with cost 0.06415118995090947 because of step counter
# Final cost : 0.06415118995090947
# Compute control for a deterministic system
# Cost in iteration 0: 0.08389706764614034
# Cost in iteration 200: 0.05772291265022564
# Final cost : 0.05772291265022564
# Compute control for a deterministic system
# Cost in iteration 0: 0.05772291265022564
# Converged in iteration 60 with cost 0.05661178439578786 because of vanishing difference
# Final cost : 0.05661178439578786
# Compute control for a deterministic system
# Cost in iteration 0: 0.05661178439578786
# Converged in iteration 6 with cost 0.056611784394220564 because of step counter
# Final cost : 0.056611784394220564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056611784394220564
# Converged in iteration 1 with cost 0.056611784394220564 because of step counter
# Final cost : 0.056611784394220564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056611784394220564
# Converged in iteration 1 with cost 0.056611784394220564 because of step counter
# Final cost : 0.056611784394220564
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408271911569754
# Cost in iteration 200: 0.054340597109215995
# Final cost : 0.054340597109215995
# Compute control for a deterministic system
# Cost in iteration 0: 0.054340597109215995
# Converged in iteration 181 with cost 0.05184298422532655 because of step counter
# Final cost : 0.05184298422532655
# Compute control for a deterministic system
# Cost in iteration 0: 0.05184298422532655
# Converged in iteration 1 with cost 0.05184298422532655 because of step counter
# Final cost : 0.05184298422532655
# Compute control for a deterministic system
# Cost in iteration 0: 0.05184298422532655
# Converged in iteration 1 with cost 0.05184298422532655 because of step counter
# Final cost : 0.05184298422532655
# Compute control for a deterministic system
# Cost in iteration 0: 0.05184298422532655
# Converged in iteration 1 with cost 0.05184298422532655 because of step counter
# Final cost : 0.05184298422532655
# Compute control for a deterministic system
# Cost in iteration 0: 0.09107022206946983
# Cost in iteration 200: 0.051107113841269425
# Final cost : 0.051107113841269425
# Compute control for a deterministic system
# Cost in iteration 0: 0.051107113841269425
# Cost in iteration 200: 0.04933223779350435
# Final cost : 0.04933223779350435
# Compute control for a deterministic system
# Cost in iteration 0: 0.04933223779350435
# Converged in iteration 176 with cost 0.049278019092418704 because of vanishing difference
# Final cost : 0.049278019092418704
# Compute control for a deterministic system
# Cost in iteration 0: 0.04927801909203266
# Converged in iteration 2 with cost 0.04927801908913111 because of vanishing difference
# Final cost : 0.04927801908913111
# Compute control for a deterministic system
# Cost in iteration 0: 0.049278019089131056
# Converged in iteration 1 with cost 0.049278019089131056 because of step counter
# Final cost : 0.049278019089131056
# Compute control for a deterministic system
# Cost in iteration 0: 0.07068937032185973
# Cost in iteration 200: 0.043908306494325595
# Final cost : 0.043908306494325595
# Compute control for a deterministic system
# Cost in iteration 0: 0.043908306494325595
# Converged in iteration 64 with cost 0.04279955561667732 because of step counter
# Final cost : 0.04279955561667732
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279955561667732
# Converged in iteration 1 with cost 0.04279955561667732 because of step counter
# Final cost : 0.04279955561667732
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279955561667732
# Converged in iteration 1 with cost 0.04279955561667732 because of step counter
# Final cost : 0.04279955561667732
# Compute control for a deterministic system
# Cost in iteration 0: 0.04279955561667732
# Converged in iteration 1 with cost 0.04279955561667732 because of step counter
# Final cost : 0.04279955561667732
# Compute control for a deterministic system
# Cost in iteration 0: 0.08424798799458236
# Cost in iteration 200: 0.04258709057821687
# Final cost : 0.04258709057821687
# Compute control for a deterministic system
# Cost in iteration 0: 0.04258709057821687
# Cost in iteration 200: 0.04125557793153543
# Final cost : 0.04125557793153543
# Compute control for a deterministic system
# Cost in iteration 0: 0.04125557793153543
# Cost in iteration 200: 0.04113562135716897
# Final cost : 0.04113562135716897
# Compute control for a deterministic system
# Cost in iteration 0: 0.04113562135716897
# Converged in iteration 7 with cost 0.041134925650921236 because of step counter
# Final cost : 0.041134925650921236
# Compute control for a deterministic system
# Cost in iteration 0: 0.041134925650921236
# Converged in iteration 1 with cost 0.041134925650921236 because of step counter
# Final cost : 0.041134925650921236
# Compute control for a deterministic system
# Cost in iteration 0: 0.08129241090085267
# Cost in iteration 200: 0.03961338912043609
# Final cost : 0.03961338912043609
# Compute control for a deterministic system
# Cost in iteration 0: 0.03961338912043609
# Cost in iteration 200: 0.038635919841897244
# Final cost : 0.038635919841897244
# Compute control for a deterministic system
# Cost in iteration 0: 0.038635919841897244
# Cost in iteration 200: 0.038447961694511014
# Final cost : 0.038447961694511014
# Compute control for a deterministic system
# Cost in iteration 0: 0.038447961694511014
# Converged in iteration 21 with cost 0.03836331696514942 because of step counter
# Final cost : 0.03836331696514942
# Compute control for a deterministic system
# Cost in iteration 0: 0.03836331696514942
# Converged in iteration 1 with cost 0.03836331696514942 because of step counter
# Final cost : 0.03836331696514942
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881605363359726
# Cost in iteration 200: 0.03719116622253335
# Final cost : 0.03719116622253335
# Compute control for a deterministic system
# Cost in iteration 0: 0.03719116622253335
# Converged in iteration 37 with cost 0.03716813332864226 because of step counter
# Final cost : 0.03716813332864226
# Compute control for a deterministic system
# Cost in iteration 0: 0.03716813332864226
# Converged in iteration 1 with cost 0.03716813332864226 because of step counter
# Final cost : 0.03716813332864226
# Compute control for a deterministic system
# Cost in iteration 0: 0.03716813332864226
# Converged in iteration 1 with cost 0.03716813332864226 because of step counter
# Final cost : 0.03716813332864226
# Compute control for a deterministic system
# Cost in iteration 0: 0.03716813332864226
# Converged in iteration 1 with cost 0.03716813332864226 because of step counter
# Final cost : 0.03716813332864226
# Compute control for a deterministic system
# Cost in iteration 0: 0.05704946991730479
# Cost in iteration 200: 0.028784264308721996
# Final cost : 0.028784264308721996
# Compute control for a deterministic system
# Cost in iteration 0: 0.028784264308721996
# Converged in iteration 48 with cost 0.02770056179485662 because of step counter
# Final cost : 0.02770056179485662
# Compute control for a deterministic system
# Cost in iteration 0: 0.02770056179485662
# Converged in iteration 1 with cost 0.02770056179485662 because of step counter
# Final cost : 0.02770056179485662
# Compute control for a deterministic system
# Cost in iteration 0: 0.02770056179485662
# Converged in iteration 1 with cost 0.02770056179485662 because of step counter
# Final cost : 0.02770056179485662
# Compute control for a deterministic system
# Cost in iteration 0: 0.02770056179485662
# Converged in iteration 1 with cost 0.02770056179485662 because of step counter
# Final cost : 0.02770056179485662
# Compute control for a deterministic system
# Cost in iteration 0: 0.06970344082099805
# Cost in iteration 200: 0.027208946706730536
# Final cost : 0.027208946706730536
# Compute control for a deterministic system
# Cost in iteration 0: 0.027208946706730536
# Cost in iteration 200: 0.025064624164694703
# Final cost : 0.025064624164694703
# Compute control for a deterministic system
# Cost in iteration 0: 0.025064624164694703
# Converged in iteration 15 with cost 0.02499425703355597 because of step counter
# Final cost : 0.02499425703355597
# Compute control for a deterministic system
# Cost in iteration 0: 0.02499425703355597
# Converged in iteration 1 with cost 0.02499425703355597 because of step counter
# Final cost : 0.02499425703355597
# Compute control for a deterministic system
# Cost in iteration 0: 0.02499425703355597
# Converged in iteration 1 with cost 0.02499425703355597 because of step counter
# Final cost : 0.02499425703355597
# Compute control for a deterministic system
# Cost in iteration 0: 0.0623987764708124
# Cost in iteration 200: 0.019532607296794804
# Final cost : 0.019532607296794804
# Compute control for a deterministic system
# Cost in iteration 0: 0.019532607296794804
# Converged in iteration 110 with cost 0.01703593382244797 because of step counter
# Final cost : 0.01703593382244797
# Compute control for a deterministic system
# Cost in iteration 0: 0.01703593382244797
# Converged in iteration 1 with cost 0.01703593382244797 because of step counter
# Final cost : 0.01703593382244797
# Compute control for a deterministic system
# Cost in iteration 0: 0.01703593382244797
# Converged in iteration 1 with cost 0.01703593382244797 because of step counter
# Final cost : 0.01703593382244797
# Compute control for a deterministic system
# Cost in iteration 0: 0.01703593382244797
# Converged in iteration 1 with cost 0.01703593382244797 because of step counter
# Final cost : 0.01703593382244797
# Compute control for a deterministic system
# Cost in iteration 0: 0.055633967396659725
# Cost in iteration 200: 0.012496233070707541
# Final cost : 0.012496233070707541
# Compute control for a deterministic system
# Cost in iteration 0: 0.012496233070707541
# Converged in iteration 70 with cost 0.010374484104174823 because of step counter
# Final cost : 0.010374484104174823
# Compute control for a deterministic system
# Cost in iteration 0: 0.010374484104174823
# Converged in iteration 1 with cost 0.010374484104174823 because of step counter
# Final cost : 0.010374484104174823
# Compute control for a deterministic system
# Cost in iteration 0: 0.010374484104174823
# Converged in iteration 1 with cost 0.010374484104174823 because of step counter
# Final cost : 0.010374484104174823
# Compute control for a deterministic system
# Cost in iteration 0: 0.010374484104174823
# Converged in iteration 1 with cost 0.010374484104174823 because of step counter
# Final cost : 0.010374484104174823
# Compute control for a deterministic system
# Cost in iteration 0: 0.03437516403980372
# Cost in iteration 200: 0.006275715684367995
# Final cost : 0.006275715684367995
# Compute control for a deterministic system
# Cost in iteration 0: 0.006275715684367995
# Converged in iteration 70 with cost 0.0058321145755127896 because of step counter
# Final cost : 0.0058321145755127896
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058321145755127896
# Converged in iteration 1 with cost 0.0058321145755127896 because of step counter
# Final cost : 0.0058321145755127896
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058321145755127896
# Converged in iteration 1 with cost 0.0058321145755127896 because of step counter
# Final cost : 0.0058321145755127896
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058321145755127896
# Converged in iteration 1 with cost 0.0058321145755127896 because of step counter
# Final cost : 0.0058321145755127896
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.031881686025679465
# Converged in iteration 13 with cost 0.019008032885461774 because of step counter
# Final cost : 0.019008032885461774
# Compute control for a deterministic system
# Cost in iteration 0: 0.019008032885461774
# Converged in iteration 1 with cost 0.019008032885461774 because of step counter
# Final cost : 0.019008032885461774
# Compute control for a deterministic system
# Cost in iteration 0: 0.019008032885461774
# Converged in iteration 1 with cost 0.019008032885461774 because of step counter
# Final cost : 0.019008032885461774
# Compute control for a deterministic system
# Cost in iteration 0: 0.019008032885461774
# Converged in iteration 1 with cost 0.019008032885461774 because of step counter
# Final cost : 0.019008032885461774
# Compute control for a deterministic system
# Cost in iteration 0: 0.04654535111697753
# Converged in iteration 11 with cost 0.026992618801482213 because of step counter
# Final cost : 0.026992618801482213
# Compute control for a deterministic system
# Cost in iteration 0: 0.026992618801482213
# Converged in iteration 1 with cost 0.026992618801482213 because of step counter
# Final cost : 0.026992618801482213
# Compute control for a deterministic system
# Cost in iteration 0: 0.026992618801482213
# Converged in iteration 1 with cost 0.026992618801482213 because of step counter
# Final cost : 0.026992618801482213
# Compute control for a deterministic system
# Cost in iteration 0: 0.026992618801482213
# Converged in iteration 1 with cost 0.026992618801482213 because of step counter
# Final cost : 0.026992618801482213
# Compute control for a deterministic system
# Cost in iteration 0: 0.04307135043968961
# Converged in iteration 11 with cost 0.02831967434319465 because of step counter
# Final cost : 0.02831967434319465
# Compute control for a deterministic system
# Cost in iteration 0: 0.02831967434319465
# Converged in iteration 1 with cost 0.02831967434319465 because of step counter
# Final cost : 0.02831967434319465
# Compute control for a deterministic system
# Cost in iteration 0: 0.02831967434319465
# Converged in iteration 1 with cost 0.02831967434319465 because of step counter
# Final cost : 0.02831967434319465
# Compute control for a deterministic system
# Cost in iteration 0: 0.02831967434319465
# Converged in iteration 1 with cost 0.02831967434319465 because of step counter
# Final cost : 0.02831967434319465
# Compute control for a deterministic system
# Cost in iteration 0: 0.04084492655026754
# Converged in iteration 10 with cost 0.0313248940791705 because of step counter
# Final cost : 0.0313248940791705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0313248940791705
# Converged in iteration 1 with cost 0.0313248940791705 because of step counter
# Final cost : 0.0313248940791705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0313248940791705
# Converged in iteration 1 with cost 0.0313248940791705 because of step counter
# Final cost : 0.0313248940791705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0313248940791705
# Converged in iteration 1 with cost 0.0313248940791705 because of step counter
# Final cost : 0.0313248940791705
# Compute control for a deterministic system
# Cost in iteration 0: 0.032561284055471484
# Converged in iteration 7 with cost 0.0322176216093243 because of step counter
# Final cost : 0.0322176216093243
# Compute control for a deterministic system
# Cost in iteration 0: 0.0322176216093243
# Converged in iteration 1 with cost 0.0322176216093243 because of step counter
# Final cost : 0.0322176216093243
# Compute control for a deterministic system
# Cost in iteration 0: 0.0322176216093243
# Converged in iteration 1 with cost 0.0322176216093243 because of step counter
# Final cost : 0.0322176216093243
# Compute control for a deterministic system
# Cost in iteration 0: 0.0322176216093243
# Converged in iteration 1 with cost 0.0322176216093243 because of step counter
# Final cost : 0.0322176216093243
# Compute control for a deterministic system
# Cost in iteration 0: 0.042664863165300784
# Converged in iteration 10 with cost 0.039173066035273346 because of step counter
# Final cost : 0.039173066035273346
# Compute control for a deterministic system
# Cost in iteration 0: 0.039173066035273346
# Converged in iteration 1 with cost 0.039173066035273346 because of step counter
# Final cost : 0.039173066035273346
# Compute control for a deterministic system
# Cost in iteration 0: 0.039173066035273346
# Converged in iteration 1 with cost 0.039173066035273346 because of step counter
# Final cost : 0.039173066035273346
# Compute control for a deterministic system
# Cost in iteration 0: 0.039173066035273346
# Converged in iteration 1 with cost 0.039173066035273346 because of step counter
# Final cost : 0.039173066035273346
# Compute control for a deterministic system
# Cost in iteration 0: 0.0377946195302053
# Converged in iteration 3 with cost 0.03768110968957326 because of step counter
# Final cost : 0.03768110968957326
# Compute control for a deterministic system
# Cost in iteration 0: 0.03768110968957326
# Converged in iteration 1 with cost 0.03768110968957326 because of step counter
# Final cost : 0.03768110968957326
# Compute control for a deterministic system
# Cost in iteration 0: 0.03768110968957326
# Converged in iteration 1 with cost 0.03768110968957326 because of step counter
# Final cost : 0.03768110968957326
# Compute control for a deterministic system
# Cost in iteration 0: 0.03768110968957326
# Converged in iteration 1 with cost 0.03768110968957326 because of step counter
# Final cost : 0.03768110968957326
# Compute control for a deterministic system
# Cost in iteration 0: 0.04126740040984212
# Converged in iteration 2 with cost 0.04123335736423303 because of step counter
# Final cost : 0.04123335736423303
# Compute control for a deterministic system
# Cost in iteration 0: 0.04123335736423303
# Converged in iteration 1 with cost 0.04123335736423303 because of step counter
# Final cost : 0.04123335736423303
# Compute control for a deterministic system
# Cost in iteration 0: 0.04123335736423303
# Converged in iteration 1 with cost 0.04123335736423303 because of step counter
# Final cost : 0.04123335736423303
# Compute control for a deterministic system
# Cost in iteration 0: 0.04123335736423303
# Converged in iteration 1 with cost 0.04123335736423303 because of step counter
# Final cost : 0.04123335736423303
# Compute control for a deterministic system
# Cost in iteration 0: 0.04605237219065068
# Converged in iteration 8 with cost 0.04452906236758685 because of step counter
# Final cost : 0.04452906236758685
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452906236758685
# Converged in iteration 1 with cost 0.04452906236758685 because of step counter
# Final cost : 0.04452906236758685
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452906236758685
# Converged in iteration 1 with cost 0.04452906236758685 because of step counter
# Final cost : 0.04452906236758685
# Compute control for a deterministic system
# Cost in iteration 0: 0.04452906236758685
# Converged in iteration 1 with cost 0.04452906236758685 because of step counter
# Final cost : 0.04452906236758685
# Compute control for a deterministic system
# Cost in iteration 0: 0.05058434108117412
# Converged in iteration 11 with cost 0.05036091752701613 because of step counter
# Final cost : 0.05036091752701613
# Compute control for a deterministic system
# Cost in iteration 0: 0.05036091752701613
# Converged in iteration 1 with cost 0.05036091752701613 because of step counter
# Final cost : 0.05036091752701613
# Compute control for a deterministic system
# Cost in iteration 0: 0.05036091752701613
# Converged in iteration 1 with cost 0.05036091752701613 because of step counter
# Final cost : 0.05036091752701613
# Compute control for a deterministic system
# Cost in iteration 0: 0.05036091752701613
# Converged in iteration 1 with cost 0.05036091752701613 because of step counter
# Final cost : 0.05036091752701613
# Compute control for a deterministic system
# Cost in iteration 0: 0.05602353494484437
# Converged in iteration 20 with cost 0.0556985265578453 because of step counter
# Final cost : 0.0556985265578453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0556985265578453
# Converged in iteration 1 with cost 0.0556985265578453 because of step counter
# Final cost : 0.0556985265578453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0556985265578453
# Converged in iteration 1 with cost 0.0556985265578453 because of step counter
# Final cost : 0.0556985265578453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0556985265578453
# Converged in iteration 1 with cost 0.0556985265578453 because of step counter
# Final cost : 0.0556985265578453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0608858516420409
# Converged in iteration 13 with cost 0.06062559074396167 because of step counter
# Final cost : 0.06062559074396167
# Compute control for a deterministic system
# Cost in iteration 0: 0.06062559074396167
# Converged in iteration 1 with cost 0.06062559074396167 because of step counter
# Final cost : 0.06062559074396167
# Compute control for a deterministic system
# Cost in iteration 0: 0.06062559074396167
# Converged in iteration 1 with cost 0.06062559074396167 because of step counter
# Final cost : 0.06062559074396167
# Compute control for a deterministic system
# Cost in iteration 0: 0.06062559074396167
# Converged in iteration 1 with cost 0.06062559074396167 because of step counter
# Final cost : 0.06062559074396167
# Compute control for a deterministic system
# Cost in iteration 0: 0.07138411411849996
# Converged in iteration 37 with cost 0.06922211943409795 because of vanishing difference
# Final cost : 0.06922211943409795
# Compute control for a deterministic system
# Cost in iteration 0: 0.06922211943409795
# Converged in iteration 1 with cost 0.06922211943409795 because of step counter
# Final cost : 0.06922211943409795
# Compute control for a deterministic system
# Cost in iteration 0: 0.06922211943409795
# Converged in iteration 1 with cost 0.06922211943409795 because of step counter
# Final cost : 0.06922211943409795
# Compute control for a deterministic system
# Cost in iteration 0: 0.06922211943409795
# Converged in iteration 1 with cost 0.06922211943409795 because of step counter
# Final cost : 0.06922211943409795
# Compute control for a deterministic system
# Cost in iteration 0: 0.07255556910980361
# Converged in iteration 45 with cost 0.0712773932540605 because of step counter
# Final cost : 0.0712773932540605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712773932540605
# Converged in iteration 1 with cost 0.0712773932540605 because of step counter
# Final cost : 0.0712773932540605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712773932540605
# Converged in iteration 1 with cost 0.0712773932540605 because of step counter
# Final cost : 0.0712773932540605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712773932540605
# Converged in iteration 1 with cost 0.0712773932540605 because of step counter
# Final cost : 0.0712773932540605
# Compute control for a deterministic system
# Cost in iteration 0: 0.09389695464311502
# Converged in iteration 40 with cost 0.07508071203272328 because of step counter
# Final cost : 0.07508071203272328
# Compute control for a deterministic system
# Cost in iteration 0: 0.07508071203272328
# Converged in iteration 1 with cost 0.07508071203272328 because of step counter
# Final cost : 0.07508071203272328
# Compute control for a deterministic system
# Cost in iteration 0: 0.07508071203272328
# Converged in iteration 1 with cost 0.07508071203272328 because of step counter
# Final cost : 0.07508071203272328
# Compute control for a deterministic system
# Cost in iteration 0: 0.07508071203272328
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.056015507477415384
# Converged in iteration 1 with cost 0.056015507477415384 because of step counter
# Final cost : 0.056015507477415384
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837657200753669
# Converged in iteration 1 with cost 0.0837657200753669 because of step counter
# Final cost : 0.0837657200753669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837657200753669
# Converged in iteration 1 with cost 0.0837657200753669 because of step counter
# Final cost : 0.0837657200753669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837657200753669
# Converged in iteration 1 with cost 0.0837657200753669 because of step counter
# Final cost : 0.0837657200753669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837657200753669
# Converged in iteration 1 with cost 0.0837657200753669 because of step counter
# Final cost : 0.0837657200753669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0837657200753669
# Converged in iteration 1 with cost 0.0837657200753669 because of step counter
# Final cost : 0.0837657200753669
# Compute control for a deterministic system
# Cost in iteration 0: 0.11654326728535187
# Converged in iteration 1 with cost 0.11654326728535187 because of step counter
# Final cost : 0.11654326728535187
# Compute control for a deterministic system
# Cost in iteration 0: 0.11654326728535187
# Converged in iteration 1 with cost 0.11654326728535187 because of step counter
# Final cost : 0.11654326728535187
# Compute control for a deterministic system
# Cost in iteration 0: 0.11654326728535187
# Converged in iteration 1 with cost 0.11654326728535187 because of step counter
# Final cost : 0.11654326728535187
# Compute control for a deterministic system
# Cost in iteration 0: 0.11654326728535187
# Converged in iteration 1 with cost 0.11654326728535187 because of step counter
# Final cost : 0.11654326728535187
# Compute control for a deterministic system
# Cost in iteration 0: 0.11654326728535187
# Converged in iteration 1 with cost 0.11654326728535187 because of step counter
# Final cost : 0.11654326728535187
# Compute control for a deterministic system
# Cost in iteration 0: 0.13324227978859424
# Converged in iteration 1 with cost 0.13324227978859424 because of step counter
# Final cost : 0.13324227978859424
# Compute control for a deterministic system
# Cost in iteration 0: 0.13324227978859424
# Converged in iteration 1 with cost 0.13324227978859424 because of step counter
# Final cost : 0.13324227978859424
# Compute control for a deterministic system
# Cost in iteration 0: 0.13324227978859424
# Converged in iteration 1 with cost 0.13324227978859424 because of step counter
# Final cost : 0.13324227978859424
# Compute control for a deterministic system
# Cost in iteration 0: 0.13324227978859424
# Converged in iteration 1 with cost 0.13324227978859424 because of step counter
# Final cost : 0.13324227978859424
# Compute control for a deterministic system
# Cost in iteration 0: 0.13324227978859424
# Converged in iteration 1 with cost 0.13324227978859424 because of step counter
# Final cost : 0.13324227978859424
# Compute control for a deterministic system
# Cost in iteration 0: 0.14559450686733666
# Converged in iteration 1 with cost 0.14559450686733666 because of step counter
# Final cost : 0.14559450686733666
# Compute control for a deterministic system
# Cost in iteration 0: 0.14559450686733666
# Converged in iteration 1 with cost 0.14559450686733666 because of step counter
# Final cost : 0.14559450686733666
# Compute control for a deterministic system
# Cost in iteration 0: 0.14559450686733666
# Converged in iteration 1 with cost 0.14559450686733666 because of step counter
# Final cost : 0.14559450686733666
# Compute control for a deterministic system
# Cost in iteration 0: 0.14559450686733666
# Converged in iteration 1 with cost 0.14559450686733666 because of step counter
# Final cost : 0.14559450686733666
# Compute control for a deterministic system
# Cost in iteration 0: 0.14559450686733666
# Converged in iteration 1 with cost 0.14559450686733666 because of step counter
# Final cost : 0.14559450686733666
# Compute control for a deterministic system
# Cost in iteration 0: 0.16288020737864747
# Converged in iteration 1 with cost 0.16288020737864747 because of step counter
# Final cost : 0.16288020737864747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16288020737864747
# Converged in iteration 1 with cost 0.16288020737864747 because of step counter
# Final cost : 0.16288020737864747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16288020737864747
# Converged in iteration 1 with cost 0.16288020737864747 because of step counter
# Final cost : 0.16288020737864747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16288020737864747
# Converged in iteration 1 with cost 0.16288020737864747 because of step counter
# Final cost : 0.16288020737864747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16288020737864747
# Converged in iteration 1 with cost 0.16288020737864747 because of step counter
# Final cost : 0.16288020737864747
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420337618503518
# Converged in iteration 1 with cost 0.18420337618503518 because of step counter
# Final cost : 0.18420337618503518
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420337618503518
# Converged in iteration 1 with cost 0.18420337618503518 because of step counter
# Final cost : 0.18420337618503518
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420337618503518
# Converged in iteration 1 with cost 0.18420337618503518 because of step counter
# Final cost : 0.18420337618503518
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420337618503518
# Converged in iteration 1 with cost 0.18420337618503518 because of step counter
# Final cost : 0.18420337618503518
# Compute control for a deterministic system
# Cost in iteration 0: 0.18420337618503518
# Converged in iteration 1 with cost 0.18420337618503518 because of step counter
# Final cost : 0.18420337618503518
# Compute control for a deterministic system
# Cost in iteration 0: 0.22332049681015678
# Converged in iteration 1 with cost 0.22332049681015678 because of step counter
# Final cost : 0.22332049681015678
# Compute control for a deterministic system
# Cost in iteration 0: 0.22332049681015678
# Converged in iteration 1 with cost 0.22332049681015678 because of step counter
# Final cost : 0.22332049681015678
# Compute control for a deterministic system
# Cost in iteration 0: 0.22332049681015678
# Converged in iteration 1 with cost 0.22332049681015678 because of step counter
# Final cost : 0.22332049681015678
# Compute control for a deterministic system
# Cost in iteration 0: 0.22332049681015678
# Converged in iteration 1 with cost 0.22332049681015678 because of step counter
# Final cost : 0.22332049681015678
# Compute control for a deterministic system
# Cost in iteration 0: 0.22332049681015678
# Converged in iteration 1 with cost 0.22332049681015678 because of step counter
# Final cost : 0.22332049681015678
# Compute control for a deterministic system
# Cost in iteration 0: 1.4255714456322457
# Cost in iteration 200: 1.3050466207095297
# Final cost : 1.3050466207095297
# Compute control for a deterministic system
# Cost in iteration 0: 1.3050466207095297
# Cost in iteration 200: 0.6756879573178782
# Final cost : 0.6756879573178782
# Compute control for a deterministic system
# Cost in iteration 0: 0.6756879573178782
# Converged in iteration 122 with cost 0.660103477181285 because of vanishing difference
# Final cost : 0.660103477181285
# Compute control for a deterministic system
# Cost in iteration 0: 0.6601034771804614
# Converged in iteration 2 with cost 0.6601034771734575 because of vanishing difference
# Final cost : 0.6601034771734575
# Compute control for a deterministic system
# Cost in iteration 0: 0.6601034771734575
# Converged in iteration 1 with cost 0.6601034771734575 because of vanishing difference
# Final cost : 0.6601034771734575
# Compute control for a deterministic system
# Cost in iteration 0: 1.4704412722615106
# Cost in iteration 200: 1.359340833975404
# Final cost : 1.359340833975404
# Compute control for a deterministic system
# Cost in iteration 0: 1.359340833975404
# Cost in iteration 200: 0.6995425122289214
# Final cost : 0.6995425122289214
# Compute control for a deterministic system
# Cost in iteration 0: 0.6995425122289214
# Converged in iteration 124 with cost 0.6793891937576363 because of vanishing difference
# Final cost : 0.6793891937576363
# Compute control for a deterministic system
# Cost in iteration 0: 0.6793891937568636
# Converged in iteration 2 with cost 0.6793891937505311 because of vanishing difference
# Final cost : 0.6793891937505311
# Compute control for a deterministic system
# Cost in iteration 0: 0.6793891937505311
# Converged in iteration 1 with cost 0.6793891937505311 because of vanishing difference
# Final cost : 0.6793891937505311
# Compute control for a deterministic system
# Cost in iteration 0: 0.43338105880566646
# Converged in iteration 2 with cost 0.4317273099730141 because of step counter
# Final cost : 0.4317273099730141
# Compute control for a deterministic system
# Cost in iteration 0: 0.4317273099730141
# Converged in iteration 1 with cost 0.4317273099730141 because of step counter
# Final cost : 0.4317273099730141
# Compute control for a deterministic system
# Cost in iteration 0: 0.4317273099730141
# Converged in iteration 1 with cost 0.4317273099730141 because of step counter
# Final cost : 0.4317273099730141
# Compute control for a deterministic system
# Cost in iteration 0: 0.4317273099730141
# Converged in iteration 1 with cost 0.4317273099730141 because of step counter
# Final cost : 0.4317273099730141
# Compute control for a deterministic system
# Cost in iteration 0: 0.4317273099730141
# Converged in iteration 1 with cost 0.4317273099730141 because of step counter
# Final cost : 0.4317273099730141
# Compute control for a deterministic system
# Cost in iteration 0: 0.37790407543349935
# Converged in iteration 2 with cost 0.37662094679446056 because of step counter
# Final cost : 0.37662094679446056
# Compute control for a deterministic system
# Cost in iteration 0: 0.37662094679446056
# Converged in iteration 1 with cost 0.37662094679446056 because of step counter
# Final cost : 0.37662094679446056
# Compute control for a deterministic system
# Cost in iteration 0: 0.37662094679446056
# Converged in iteration 1 with cost 0.37662094679446056 because of step counter
# Final cost : 0.37662094679446056
# Compute control for a deterministic system
# Cost in iteration 0: 0.37662094679446056
# Converged in iteration 1 with cost 0.37662094679446056 because of step counter
# Final cost : 0.37662094679446056
# Compute control for a deterministic system
# Cost in iteration 0: 0.37662094679446056
# Converged in iteration 1 with cost 0.37662094679446056 because of step counter
# Final cost : 0.37662094679446056
# Compute control for a deterministic system
# Cost in iteration 0: 0.35799848949224844
# Converged in iteration 2 with cost 0.3578128856003787 because of step counter
# Final cost : 0.3578128856003787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3578128856003787
# Converged in iteration 1 with cost 0.3578128856003787 because of step counter
# Final cost : 0.3578128856003787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3578128856003787
# Converged in iteration 1 with cost 0.3578128856003787 because of step counter
# Final cost : 0.3578128856003787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3578128856003787
# Converged in iteration 1 with cost 0.3578128856003787 because of step counter
# Final cost : 0.3578128856003787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3578128856003787
# Converged in iteration 1 with cost 0.3578128856003787 because of step counter
# Final cost : 0.3578128856003787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3334581167073297
# Converged in iteration 1 with cost 0.3334581167073297 because of step counter
# Final cost : 0.3334581167073297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3334581167073297
# Converged in iteration 1 with cost 0.3334581167073297 because of step counter
# Final cost : 0.3334581167073297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3334581167073297
# Converged in iteration 1 with cost 0.3334581167073297 because of step counter
# Final cost : 0.3334581167073297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3334581167073297
# Converged in iteration 1 with cost 0.3334581167073297 because of step counter
# Final cost : 0.3334581167073297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3334581167073297
# Converged in iteration 1 with cost 0.3334581167073297 because of step counter
# Final cost : 0.3334581167073297
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526208246495953
# Converged in iteration 1 with cost 0.3526208246495953 because of step counter
# Final cost : 0.3526208246495953
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526208246495953
# Converged in iteration 1 with cost 0.3526208246495953 because of step counter
# Final cost : 0.3526208246495953
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526208246495953
# Converged in iteration 1 with cost 0.3526208246495953 because of step counter
# Final cost : 0.3526208246495953
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526208246495953
# Converged in iteration 1 with cost 0.3526208246495953 because of step counter
# Final cost : 0.3526208246495953
# Compute control for a deterministic system
# Cost in iteration 0: 0.3526208246495953
# Converged in iteration 1 with cost 0.3526208246495953 because of step counter
# Final cost : 0.3526208246495953
# Compute control for a deterministic system
# Cost in iteration 0: 0.3606527185206984
# Converged in iteration 1 with cost 0.3606527185206984 because of step counter
# Final cost : 0.3606527185206984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3606527185206984
# Converged in iteration 1 with cost 0.3606527185206984 because of step counter
# Final cost : 0.3606527185206984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3606527185206984
# Converged in iteration 1 with cost 0.3606527185206984 because of step counter
# Final cost : 0.3606527185206984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3606527185206984
# Converged in iteration 1 with cost 0.3606527185206984 because of step counter
# Final cost : 0.3606527185206984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3606527185206984
# Converged in iteration 1 with cost 0.3606527185206984 because of step counter
# Final cost : 0.3606527185206984
# Compute control for a deterministic system
# Cost in iteration 0: 1.0041115649879093
# Cost in iteration 200: 0.9402959004829883
# Final cost : 0.9402959004829883
# Compute control for a deterministic system
# Cost in iteration 0: 0.9402959004829883
# Cost in iteration 200: 0.7896762840829281
# Final cost : 0.7896762840829281
# Compute control for a deterministic system
# Cost in iteration 0: 0.7896762840829281
# Converged in iteration 52 with cost 0.7890307384858768 because of vanishing difference
# Final cost : 0.7890307384858768
# Compute control for a deterministic system
# Cost in iteration 0: 0.789030738482343
# Converged in iteration 2 with cost 0.7890307384571864 because of vanishing difference
# Final cost : 0.7890307384571864
# Compute control for a deterministic system
# Cost in iteration 0: 0.7890307384571863
# Converged in iteration 1 with cost 0.7890307384571863 because of step counter
# Final cost : 0.7890307384571863
# Compute control for a deterministic system
# Cost in iteration 0: 1.0918036853467958
# Cost in iteration 200: 1.0180248573718815
# Final cost : 1.0180248573718815
# Compute control for a deterministic system
# Cost in iteration 0: 1.0180248573718815
# Cost in iteration 200: 0.8222923896957613
# Final cost : 0.8222923896957613
# Compute control for a deterministic system
# Cost in iteration 0: 0.8222923896957613

# %%
save(results_peak)
