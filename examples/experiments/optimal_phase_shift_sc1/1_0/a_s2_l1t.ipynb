# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,188+87], wc.inh[0,188+87]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 18.895652173913046
# minima =  [ 110  299  488  677  866 1055 1244 1433 1622 1811 2000 2189 2378 2567
#  2756 2944 3133 3322 3511 3700 3889 4078 4267 4456 4645 4834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, ish, w1):
    results_dict["control"][ish] = wc_controlled.control.copy()
    results_dict["state"][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1T = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][ish] = ( results_dict["total_cost"][ish] - results_dict["precision_cost"][ish]) 
    results_dict["L1_cost_unweighted"][ish] = results_dict["L1_cost_weighted"][ish] / w1
    wc_controlled.w_1T = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1T=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][ish]) != type(None):
        wc_controlled.control = results_dict["control"][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [1.]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L1_cost_unweighted", [None] * n_points),
    ("L1_cost_weighted", [None] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ])

# %%
import IPython
filename = IPython.extract_module_locals()[1]['__vsc_ipynb_file__'].split("/")[-1][:-6]
print(filename)

def save(results_dict):
    filehandler = open((filename + ".pickle"),"wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open((filename + ".pickle"),"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict
# Out:
# a_s2_l1t

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 results_min = read()
#
# Cell In [23], line 11, in read()
#      10 def read():
# ---> 11     filehandler = open((filename + ".pickle"),"rb")
#      12     results_dict = pickle.load(filehandler)
#      13     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_s2_l1t.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
options = [True, True, True]

for k in range(10):

    w1 = results_min['w1'][0]

    for i_shift in range(n_points):
        
        if type(results_min["control"][i_shift]) != type(None):
            continue

        period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

        wc_controlled = getmodel(target_shift, w1, results_min, i_shift)

        wc_controlled.step = 1e-3
        wc_controlled.optimize(100)

        if i_shift in [0, n_points-1]:
            get_values(results_min, i_shift, w1)
            continue

        increase_step_compute()
        get_values(results_min, i_shift, w1)

    save(results_min)

    if options[0]:
        print("----------------------------------------------- 0")
        for i_shift in range(2, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_shift)
            
            factor = (0.95+np.random.random()*0.1)
            
            wc_controlled.control = results_min["control"][i_shift-1].copy() * factor
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("0 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    if options[1]:
        print("----------------------------------------------- 1")
        for i_shift in range(n_points-3, 0, -1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_shift)

            factor = (0.95+np.random.random()*0.1)
            
            wc_controlled.control = results_min["control"][i_shift+1].copy() * factor
            wc_controlled.update_input()
            wc_controlled.simulate_forward()

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("1 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    if options[2]:
        print("----------------------------------------------- 4")
        for i_shift in range(1, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_shift)
            
            wc_controlled.control = results_min["control"][i_shift].copy() * (0.95+np.random.random()*0.1)
            wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
            wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_shift]:
                print("-----------------------------------------------")
                print("4 found better solution, ", i_shift)

                get_values(results_min, i_shift, w1)

        save(results_min)

    save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05471635276765263
# Converged in iteration 124 with cost 0.02597550767152698 because of vanishing difference
# Final cost : 0.02597550767152698
# Compute control for a deterministic system
# Cost in iteration 0: 0.02597550767152698
# Converged in iteration 1 with cost 0.02597550767152698 because of step counter
# Final cost : 0.02597550767152698
# Compute control for a deterministic system
# Cost in iteration 0: 0.02597550767152698
# Converged in iteration 1 with cost 0.02597550767152698 because of step counter
# Final cost : 0.02597550767152698
# Compute control for a deterministic system
# Cost in iteration 0: 0.02597550767152698
# Converged in iteration 1 with cost 0.02597550767152698 because of step counter
# Final cost : 0.02597550767152698
# Compute control for a deterministic system
# Cost in iteration 0: 0.02597550767152698
# Converged in iteration 1 with cost 0.02597550767152698 because of step counter
# Final cost : 0.02597550767152698
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873736618571577
# Converged in iteration 140 with cost 0.04154038926992734 because of vanishing difference
# Final cost : 0.04154038926992734
# Compute control for a deterministic system
# Cost in iteration 0: 0.04154038926992734
# Converged in iteration 1 with cost 0.04154038926992734 because of step counter
# Final cost : 0.04154038926992734
# Compute control for a deterministic system
# Cost in iteration 0: 0.04154038926992734
# Converged in iteration 1 with cost 0.04154038926992734 because of step counter
# Final cost : 0.04154038926992734
# Compute control for a deterministic system
# Cost in iteration 0: 0.04154038926992734
# Converged in iteration 1 with cost 0.04154038926992734 because of step counter
# Final cost : 0.04154038926992734
# Compute control for a deterministic system
# Cost in iteration 0: 0.04154038926992734
# Converged in iteration 1 with cost 0.04154038926992734 because of step counter
# Final cost : 0.04154038926992734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09059022109686972
# Converged in iteration 122 with cost 0.056517373185228564 because of vanishing difference
# Final cost : 0.056517373185228564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056517373185228564
# Converged in iteration 1 with cost 0.056517373185228564 because of step counter
# Final cost : 0.056517373185228564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056517373185228564
# Converged in iteration 1 with cost 0.056517373185228564 because of step counter
# Final cost : 0.056517373185228564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056517373185228564
# Converged in iteration 1 with cost 0.056517373185228564 because of step counter
# Final cost : 0.056517373185228564
# Compute control for a deterministic system
# Cost in iteration 0: 0.056517373185228564
# Converged in iteration 1 with cost 0.056517373185228564 because of step counter
# Final cost : 0.056517373185228564
# Compute control for a deterministic system
# Cost in iteration 0: 0.1231700645782283
# Converged in iteration 154 with cost 0.0725250133221073 because of vanishing difference
# Final cost : 0.0725250133221073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0725250133221073
# Converged in iteration 1 with cost 0.0725250133221073 because of step counter
# Final cost : 0.0725250133221073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0725250133221073
# Converged in iteration 1 with cost 0.0725250133221073 because of step counter
# Final cost : 0.0725250133221073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0725250133221073
# Converged in iteration 1 with cost 0.0725250133221073 because of step counter
# Final cost : 0.0725250133221073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0725250133221073
# Converged in iteration 1 with cost 0.0725250133221073 because of step counter
# Final cost : 0.0725250133221073
# Compute control for a deterministic system
# Cost in iteration 0: 0.10468327056109208
# Converged in iteration 123 with cost 0.08427655719748221 because of vanishing difference
# Final cost : 0.08427655719748221
# Compute control for a deterministic system
# Cost in iteration 0: 0.08427655719748221
# Converged in iteration 1 with cost 0.08427655719748221 because of step counter
# Final cost : 0.08427655719748221
# Compute control for a deterministic system
# Cost in iteration 0: 0.08427655719748221
# Converged in iteration 1 with cost 0.08427655719748221 because of step counter
# Final cost : 0.08427655719748221
# Compute control for a deterministic system
# Cost in iteration 0: 0.08427655719748221
# Converged in iteration 1 with cost 0.08427655719748221 because of step counter
# Final cost : 0.08427655719748221
# Compute control for a deterministic system
# Cost in iteration 0: 0.08427655719748221
# Converged in iteration 1 with cost 0.08427655719748221 because of step counter
# Final cost : 0.08427655719748221
# Compute control for a deterministic system
# Cost in iteration 0: 0.1406185077055462
# Converged in iteration 199 with cost 0.1008319783632347 because of vanishing difference
# Final cost : 0.1008319783632347
# Compute control for a deterministic system
# Cost in iteration 0: 0.1008319783632347
# Converged in iteration 1 with cost 0.1008319783632347 because of step counter
# Final cost : 0.1008319783632347
# Compute control for a deterministic system
# Cost in iteration 0: 0.1008319783632347
# Converged in iteration 1 with cost 0.1008319783632347 because of step counter
# Final cost : 0.1008319783632347
# Compute control for a deterministic system
# Cost in iteration 0: 0.1008319783632347
# Converged in iteration 1 with cost 0.1008319783632347 because of step counter
# Final cost : 0.1008319783632347
# Compute control for a deterministic system
# Cost in iteration 0: 0.1008319783632347
# Converged in iteration 1 with cost 0.1008319783632347 because of step counter
# Final cost : 0.1008319783632347
# Compute control for a deterministic system
# Cost in iteration 0: 0.14588917180425742
# Converged in iteration 122 with cost 0.11572047558306675 because of vanishing difference
# Final cost : 0.11572047558306675
# Compute control for a deterministic system
# Cost in iteration 0: 0.11572047558306675
# Converged in iteration 1 with cost 0.11572047558306675 because of step counter
# Final cost : 0.11572047558306675
# Compute control for a deterministic system
# Cost in iteration 0: 0.11572047558306675
# Converged in iteration 1 with cost 0.11572047558306675 because of step counter
# Final cost : 0.11572047558306675
# Compute control for a deterministic system
# Cost in iteration 0: 0.11572047558306675
# Converged in iteration 1 with cost 0.11572047558306675 because of step counter
# Final cost : 0.11572047558306675
# Compute control for a deterministic system
# Cost in iteration 0: 0.11572047558306675
# Converged in iteration 1 with cost 0.11572047558306675 because of step counter
# Final cost : 0.11572047558306675
# Compute control for a deterministic system
# Cost in iteration 0: 0.206007019219339
# Converged in iteration 179 with cost 0.13174319741458168 because of vanishing difference
# Final cost : 0.13174319741458168
# Compute control for a deterministic system
# Cost in iteration 0: 0.13174319741458168
# Converged in iteration 1 with cost 0.13174319741458168 because of step counter
# Final cost : 0.13174319741458168
# Compute control for a deterministic system
# Cost in iteration 0: 0.13174319741458168
# Converged in iteration 1 with cost 0.13174319741458168 because of step counter
# Final cost : 0.13174319741458168
# Compute control for a deterministic system
# Cost in iteration 0: 0.13174319741458168
# Converged in iteration 1 with cost 0.13174319741458168 because of step counter
# Final cost : 0.13174319741458168
# Compute control for a deterministic system
# Cost in iteration 0: 0.13174319741458168
# Converged in iteration 1 with cost 0.13174319741458168 because of step counter
# Final cost : 0.13174319741458168
# Compute control for a deterministic system
# Cost in iteration 0: 0.1498754897319738
# Converged in iteration 112 with cost 0.14239425224724195 because of vanishing difference
# Final cost : 0.14239425224724195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14239425224724195
# Converged in iteration 1 with cost 0.14239425224724195 because of step counter
# Final cost : 0.14239425224724195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14239425224724195
# Converged in iteration 1 with cost 0.14239425224724195 because of step counter
# Final cost : 0.14239425224724195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14239425224724195
# Converged in iteration 1 with cost 0.14239425224724195 because of step counter
# Final cost : 0.14239425224724195
# Compute control for a deterministic system
# Cost in iteration 0: 0.14239425224724195
# Converged in iteration 1 with cost 0.14239425224724195 because of step counter
# Final cost : 0.14239425224724195
# Compute control for a deterministic system
# Cost in iteration 0: 0.18377836347049992
# Converged in iteration 158 with cost 0.1585595959755908 because of vanishing difference
# Final cost : 0.1585595959755908
# Compute control for a deterministic system
# Cost in iteration 0: 0.1585595959755908
# Converged in iteration 1 with cost 0.1585595959755908 because of step counter
# Final cost : 0.1585595959755908
# Compute control for a deterministic system
# Cost in iteration 0: 0.1585595959755908
# Converged in iteration 1 with cost 0.1585595959755908 because of step counter
# Final cost : 0.1585595959755908
# Compute control for a deterministic system
# Cost in iteration 0: 0.1585595959755908
# Converged in iteration 1 with cost 0.1585595959755908 because of step counter
# Final cost : 0.1585595959755908
# Compute control for a deterministic system
# Cost in iteration 0: 0.1585595959755908
# Converged in iteration 1 with cost 0.1585595959755908 because of step counter
# Final cost : 0.1585595959755908
# Compute control for a deterministic system
# Cost in iteration 0: 0.19696228779344901
# Cost in iteration 200: 0.17644939595145148
# Final cost : 0.17644939595145148
# Compute control for a deterministic system
# Cost in iteration 0: 0.17644939595145148
# Cost in iteration 200: 0.17595891607126987
# Final cost : 0.17595891607126987
# Compute control for a deterministic system
# Cost in iteration 0: 0.17595891607126987
# Cost in iteration 200: 0.17595382236861334
# Final cost : 0.17595382236861334
# Compute control for a deterministic system
# Cost in iteration 0: 0.17595382236861334
# Converged in iteration 1 with cost 0.17595382236861334 because of step counter
# Final cost : 0.17595382236861334
# Compute control for a deterministic system
# Cost in iteration 0: 0.17595382236861334
# Converged in iteration 1 with cost 0.17595382236861334 because of step counter
# Final cost : 0.17595382236861334
# Compute control for a deterministic system
# Cost in iteration 0: 0.2771113960950678
# Converged in iteration 113 with cost 0.18473564243185978 because of vanishing difference
# Final cost : 0.18473564243185978
# Compute control for a deterministic system
# Cost in iteration 0: 0.18473564243185978
# Converged in iteration 1 with cost 0.18473564243185978 because of step counter
# Final cost : 0.18473564243185978
# Compute control for a deterministic system
# Cost in iteration 0: 0.18473564243185978
# Converged in iteration 1 with cost 0.18473564243185978 because of step counter
# Final cost : 0.18473564243185978
# Compute control for a deterministic system
# Cost in iteration 0: 0.18473564243185978
# Converged in iteration 1 with cost 0.18473564243185978 because of step counter
# Final cost : 0.18473564243185978
# Compute control for a deterministic system
# Cost in iteration 0: 0.18473564243185978
# Converged in iteration 1 with cost 0.18473564243185978 because of step counter
# Final cost : 0.18473564243185978
# Compute control for a deterministic system
# Cost in iteration 0: 0.21560288791902987
# Converged in iteration 145 with cost 0.20050084848192337 because of vanishing difference
# Final cost : 0.20050084848192337
# Compute control for a deterministic system
# Cost in iteration 0: 0.20050084848192337
# Converged in iteration 1 with cost 0.20050084848192337 because of step counter
# Final cost : 0.20050084848192337
# Compute control for a deterministic system
# Cost in iteration 0: 0.20050084848192337
# Converged in iteration 1 with cost 0.20050084848192337 because of step counter
# Final cost : 0.20050084848192337
# Compute control for a deterministic system
# Cost in iteration 0: 0.20050084848192337
# Converged in iteration 1 with cost 0.20050084848192337 because of step counter
# Final cost : 0.20050084848192337
# Compute control for a deterministic system
# Cost in iteration 0: 0.20050084848192337
# Converged in iteration 1 with cost 0.20050084848192337 because of step counter
# Final cost : 0.20050084848192337
# Compute control for a deterministic system
# Cost in iteration 0: 0.2747080210140805
# Converged in iteration 175 with cost 0.2173928554107126 because of vanishing difference
# Final cost : 0.2173928554107126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2173928554107126
# Converged in iteration 1 with cost 0.2173928554107126 because of step counter
# Final cost : 0.2173928554107126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2173928554107126
# Converged in iteration 1 with cost 0.2173928554107126 because of step counter
# Final cost : 0.2173928554107126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2173928554107126
# Converged in iteration 1 with cost 0.2173928554107126 because of step counter
# Final cost : 0.2173928554107126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2173928554107126
# Converged in iteration 1 with cost 0.2173928554107126 because of step counter
# Final cost : 0.2173928554107126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2478149438886996
# Converged in iteration 165 with cost 0.2347136844022001 because of vanishing difference
# Final cost : 0.2347136844022001
# Compute control for a deterministic system
# Cost in iteration 0: 0.2347136844022001
# Converged in iteration 1 with cost 0.2347136844022001 because of step counter
# Final cost : 0.2347136844022001
# Compute control for a deterministic system
# Cost in iteration 0: 0.2347136844022001
# Converged in iteration 1 with cost 0.2347136844022001 because of step counter
# Final cost : 0.2347136844022001
# Compute control for a deterministic system
# Cost in iteration 0: 0.2347136844022001
# Converged in iteration 1 with cost 0.2347136844022001 because of step counter
# Final cost : 0.2347136844022001
# Compute control for a deterministic system
# Cost in iteration 0: 0.2347136844022001
# Converged in iteration 1 with cost 0.2347136844022001 because of step counter
# Final cost : 0.2347136844022001
# Compute control for a deterministic system
# Cost in iteration 0: 0.2551279115511537
# Converged in iteration 105 with cost 0.2443913936025905 because of vanishing difference
# Final cost : 0.2443913936025905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2443913936025905
# Converged in iteration 1 with cost 0.2443913936025905 because of step counter
# Final cost : 0.2443913936025905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2443913936025905
# Converged in iteration 1 with cost 0.2443913936025905 because of step counter
# Final cost : 0.2443913936025905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2443913936025905
# Converged in iteration 1 with cost 0.2443913936025905 because of step counter
# Final cost : 0.2443913936025905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2443913936025905
# Converged in iteration 1 with cost 0.2443913936025905 because of step counter
# Final cost : 0.2443913936025905
# Compute control for a deterministic system
# Cost in iteration 0: 0.4233797250722138
# Converged in iteration 170 with cost 0.2615231194679122 because of vanishing difference
# Final cost : 0.2615231194679122
# Compute control for a deterministic system
# Cost in iteration 0: 0.2615231194679122
# Converged in iteration 1 with cost 0.2615231194679122 because of step counter
# Final cost : 0.2615231194679122
# Compute control for a deterministic system
# Cost in iteration 0: 0.2615231194679122
# Converged in iteration 1 with cost 0.2615231194679122 because of step counter
# Final cost : 0.2615231194679122
# Compute control for a deterministic system
# Cost in iteration 0: 0.2615231194679122
# Converged in iteration 1 with cost 0.2615231194679122 because of step counter
# Final cost : 0.2615231194679122
# Compute control for a deterministic system
# Cost in iteration 0: 0.2615231194679122
# Converged in iteration 1 with cost 0.2615231194679122 because of step counter
# Final cost : 0.2615231194679122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3384349201853069
# Converged in iteration 189 with cost 0.2782465659346706 because of vanishing difference
# Final cost : 0.2782465659346706
# Compute control for a deterministic system
# Cost in iteration 0: 0.2782465659346706
# Converged in iteration 1 with cost 0.2782465659346706 because of step counter
# Final cost : 0.2782465659346706
# Compute control for a deterministic system
# Cost in iteration 0: 0.2782465659346706
# Converged in iteration 1 with cost 0.2782465659346706 because of step counter
# Final cost : 0.2782465659346706
# Compute control for a deterministic system
# Cost in iteration 0: 0.2782465659346706
# Converged in iteration 1 with cost 0.2782465659346706 because of step counter
# Final cost : 0.2782465659346706
# Compute control for a deterministic system
# Cost in iteration 0: 0.2782465659346706
# Converged in iteration 1 with cost 0.2782465659346706 because of step counter
# Final cost : 0.2782465659346706
# Compute control for a deterministic system
# Cost in iteration 0: 0.4009698228070224
# Converged in iteration 164 with cost 0.2925248637364045 because of vanishing difference
# Final cost : 0.2925248637364045
# Compute control for a deterministic system
# Cost in iteration 0: 0.2925248637364045
# Converged in iteration 1 with cost 0.2925248637364045 because of step counter
# Final cost : 0.2925248637364045
# Compute control for a deterministic system
# Cost in iteration 0: 0.2925248637364045
# Converged in iteration 1 with cost 0.2925248637364045 because of step counter
# Final cost : 0.2925248637364045
# Compute control for a deterministic system
# Cost in iteration 0: 0.2925248637364045
# Converged in iteration 1 with cost 0.2925248637364045 because of step counter
# Final cost : 0.2925248637364045
# Compute control for a deterministic system
# Cost in iteration 0: 0.2925248637364045
# Converged in iteration 1 with cost 0.2925248637364045 because of step counter
# Final cost : 0.2925248637364045
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.4065209652485311
# Cost in iteration 200: 0.3119448461583261
# Final cost : 0.3119448461583261
# Compute control for a deterministic system
# Cost in iteration 0: 0.3119448461583261
# Converged in iteration 77 with cost 0.3119444333858122 because of vanishing difference
# Final cost : 0.3119444333858122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3119444333858122
# Converged in iteration 1 with cost 0.3119444333858122 because of step counter
# Final cost : 0.3119444333858122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3119444333858122
# Converged in iteration 1 with cost 0.3119444333858122 because of step counter
# Final cost : 0.3119444333858122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3119444333858122
# Converged in iteration 1 with cost 0.3119444333858122 because of step counter
# Final cost : 0.3119444333858122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3775531527963967
# Converged in iteration 179 with cost 0.2745329428496385 because of vanishing difference
# Final cost : 0.2745329428496385
# Compute control for a deterministic system
# Cost in iteration 0: 0.2745329428496385
# Converged in iteration 1 with cost 0.2745329428496385 because of step counter
# Final cost : 0.2745329428496385
# Compute control for a deterministic system
# Cost in iteration 0: 0.2745329428496385
# Converged in iteration 1 with cost 0.2745329428496385 because of step counter
# Final cost : 0.2745329428496385
# Compute control for a deterministic system
# Cost in iteration 0: 0.2745329428496385
# Converged in iteration 1 with cost 0.2745329428496385 because of step counter
# Final cost : 0.2745329428496385
# Compute control for a deterministic system
# Cost in iteration 0: 0.2745329428496385
# Converged in iteration 1 with cost 0.2745329428496385 because of step counter
# Final cost : 0.2745329428496385
# Compute control for a deterministic system
# Cost in iteration 0: 0.3201613941362768
# Converged in iteration 181 with cost 0.2571146376868939 because of vanishing difference
# Final cost : 0.2571146376868939
# Compute control for a deterministic system
# Cost in iteration 0: 0.2571146376868939
# Converged in iteration 1 with cost 0.2571146376868939 because of step counter
# Final cost : 0.2571146376868939
# Compute control for a deterministic system
# Cost in iteration 0: 0.2571146376868939
# Converged in iteration 1 with cost 0.2571146376868939 because of step counter
# Final cost : 0.2571146376868939
# Compute control for a deterministic system
# Cost in iteration 0: 0.2571146376868939
# Converged in iteration 1 with cost 0.2571146376868939 because of step counter
# Final cost : 0.2571146376868939
# Compute control for a deterministic system
# Cost in iteration 0: 0.2571146376868939
# Converged in iteration 1 with cost 0.2571146376868939 because of step counter
# Final cost : 0.2571146376868939
# Compute control for a deterministic system
# Cost in iteration 0: 0.30687206484012064
# Converged in iteration 198 with cost 0.24448562455256836 because of vanishing difference
# Final cost : 0.24448562455256836
# Compute control for a deterministic system
# Cost in iteration 0: 0.24448562455256836
# Converged in iteration 1 with cost 0.24448562455256836 because of step counter
# Final cost : 0.24448562455256836
# Compute control for a deterministic system
# Cost in iteration 0: 0.24448562455256836
# Converged in iteration 1 with cost 0.24448562455256836 because of step counter
# Final cost : 0.24448562455256836
# Compute control for a deterministic system
# Cost in iteration 0: 0.24448562455256836
# Converged in iteration 1 with cost 0.24448562455256836 because of step counter
# Final cost : 0.24448562455256836
# Compute control for a deterministic system
# Cost in iteration 0: 0.24448562455256836
# Converged in iteration 1 with cost 0.24448562455256836 because of step counter
# Final cost : 0.24448562455256836
# Compute control for a deterministic system
# Cost in iteration 0: 0.22917571156521352
# Cost in iteration 200: 0.22717860533592021
# Final cost : 0.22717860533592021
# Compute control for a deterministic system
# Cost in iteration 0: 0.22717860533592021
# Converged in iteration 178 with cost 0.22717188936525753 because of step counter
# Final cost : 0.22717188936525753
# Compute control for a deterministic system
# Cost in iteration 0: 0.22717188936525753
# Converged in iteration 1 with cost 0.22717188936525753 because of step counter
# Final cost : 0.22717188936525753
# Compute control for a deterministic system
# Cost in iteration 0: 0.22717188936525753
# Converged in iteration 1 with cost 0.22717188936525753 because of step counter
# Final cost : 0.22717188936525753
# Compute control for a deterministic system
# Cost in iteration 0: 0.22717188936525753
# Converged in iteration 1 with cost 0.22717188936525753 because of step counter
# Final cost : 0.22717188936525753
# Compute control for a deterministic system
# Cost in iteration 0: 0.23344606479653474
# Converged in iteration 179 with cost 0.20948446959558215 because of vanishing difference
# Final cost : 0.20948446959558215
# Compute control for a deterministic system
# Cost in iteration 0: 0.20948446959558215
# Converged in iteration 1 with cost 0.20948446959558215 because of step counter
# Final cost : 0.20948446959558215
# Compute control for a deterministic system
# Cost in iteration 0: 0.20948446959558215
# Converged in iteration 1 with cost 0.20948446959558215 because of step counter
# Final cost : 0.20948446959558215
# Compute control for a deterministic system
# Cost in iteration 0: 0.20948446959558215
# Converged in iteration 1 with cost 0.20948446959558215 because of step counter
# Final cost : 0.20948446959558215
# Compute control for a deterministic system
# Cost in iteration 0: 0.20948446959558215
# Converged in iteration 1 with cost 0.20948446959558215 because of step counter
# Final cost : 0.20948446959558215
# Compute control for a deterministic system
# Cost in iteration 0: 0.21234987628616334
# Cost in iteration 200: 0.19474255870782253
# Final cost : 0.19474255870782253
# Compute control for a deterministic system
# Cost in iteration 0: 0.19474255870782253
# Converged in iteration 5 with cost 0.1947425504325227 because of vanishing difference
# Final cost : 0.1947425504325227
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947425504325227
# Converged in iteration 1 with cost 0.1947425504325227 because of step counter
# Final cost : 0.1947425504325227
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947425504325227
# Converged in iteration 1 with cost 0.1947425504325227 because of step counter
# Final cost : 0.1947425504325227
# Compute control for a deterministic system
# Cost in iteration 0: 0.1947425504325227
# Converged in iteration 1 with cost 0.1947425504325227 because of step counter
# Final cost : 0.1947425504325227
# Compute control for a deterministic system
# Cost in iteration 0: 0.26460796788417196
# Cost in iteration 200: 0.18222301319920423
# Final cost : 0.18222301319920423
# Compute control for a deterministic system
# Cost in iteration 0: 0.18222301319920423
# Converged in iteration 22 with cost 0.18222292751456315 because of vanishing difference
# Final cost : 0.18222292751456315
# Compute control for a deterministic system
# Cost in iteration 0: 0.18222292751456315
# Converged in iteration 1 with cost 0.18222292751456315 because of step counter
# Final cost : 0.18222292751456315
# Compute control for a deterministic system
# Cost in iteration 0: 0.18222292751456315
# Converged in iteration 1 with cost 0.18222292751456315 because of step counter
# Final cost : 0.18222292751456315
# Compute control for a deterministic system
# Cost in iteration 0: 0.18222292751456315
# Converged in iteration 1 with cost 0.18222292751456315 because of step counter
# Final cost : 0.18222292751456315
# Compute control for a deterministic system
# Cost in iteration 0: 0.19336371062047356
# Converged in iteration 117 with cost 0.16193450529274747 because of vanishing difference
# Final cost : 0.16193450529274747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16193450529274747
# Converged in iteration 1 with cost 0.16193450529274747 because of step counter
# Final cost : 0.16193450529274747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16193450529274747
# Converged in iteration 1 with cost 0.16193450529274747 because of step counter
# Final cost : 0.16193450529274747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16193450529274747
# Converged in iteration 1 with cost 0.16193450529274747 because of step counter
# Final cost : 0.16193450529274747
# Compute control for a deterministic system
# Cost in iteration 0: 0.16193450529274747
# Converged in iteration 1 with cost 0.16193450529274747 because of step counter
# Final cost : 0.16193450529274747
# Compute control for a deterministic system
# Cost in iteration 0: 0.21971661503470402
# Converged in iteration 156 with cost 0.14706160390284856 because of vanishing difference
# Final cost : 0.14706160390284856
# Compute control for a deterministic system
# Cost in iteration 0: 0.14706160390284856
# Converged in iteration 1 with cost 0.14706160390284856 because of step counter
# Final cost : 0.14706160390284856
# Compute control for a deterministic system
# Cost in iteration 0: 0.14706160390284856
# Converged in iteration 1 with cost 0.14706160390284856 because of step counter
# Final cost : 0.14706160390284856
# Compute control for a deterministic system
# Cost in iteration 0: 0.14706160390284856
# Converged in iteration 1 with cost 0.14706160390284856 because of step counter
# Final cost : 0.14706160390284856
# Compute control for a deterministic system
# Cost in iteration 0: 0.14706160390284856
# Converged in iteration 1 with cost 0.14706160390284856 because of step counter
# Final cost : 0.14706160390284856
# Compute control for a deterministic system
# Cost in iteration 0: 0.17679375343737636
# Converged in iteration 128 with cost 0.13342158994660397 because of vanishing difference
# Final cost : 0.13342158994660397
# Compute control for a deterministic system
# Cost in iteration 0: 0.13342158994660397
# Converged in iteration 1 with cost 0.13342158994660397 because of step counter
# Final cost : 0.13342158994660397
# Compute control for a deterministic system
# Cost in iteration 0: 0.13342158994660397
# Converged in iteration 1 with cost 0.13342158994660397 because of step counter
# Final cost : 0.13342158994660397
# Compute control for a deterministic system
# Cost in iteration 0: 0.13342158994660397
# Converged in iteration 1 with cost 0.13342158994660397 because of step counter
# Final cost : 0.13342158994660397
# Compute control for a deterministic system
# Cost in iteration 0: 0.13342158994660397
# Converged in iteration 1 with cost 0.13342158994660397 because of step counter
# Final cost : 0.13342158994660397
# Compute control for a deterministic system
# Cost in iteration 0: 0.18369824111274144
# Cost in iteration 200: 0.11922196259729713
# Final cost : 0.11922196259729713
# Compute control for a deterministic system
# Cost in iteration 0: 0.11922196259729713
# Converged in iteration 51 with cost 0.11922187455853707 because of vanishing difference
# Final cost : 0.11922187455853707
# Compute control for a deterministic system
# Cost in iteration 0: 0.11922187455853707
# Converged in iteration 1 with cost 0.11922187455853707 because of step counter
# Final cost : 0.11922187455853707
# Compute control for a deterministic system
# Cost in iteration 0: 0.11922187455853707
# Converged in iteration 1 with cost 0.11922187455853707 because of step counter
# Final cost : 0.11922187455853707
# Compute control for a deterministic system
# Cost in iteration 0: 0.11922187455853707
# Converged in iteration 1 with cost 0.11922187455853707 because of step counter
# Final cost : 0.11922187455853707
# Compute control for a deterministic system
# Cost in iteration 0: 0.14525362846922818
# Converged in iteration 90 with cost 0.10094180370597888 because of vanishing difference
# Final cost : 0.10094180370597888
# Compute control for a deterministic system
# Cost in iteration 0: 0.10094180370597888
# Converged in iteration 1 with cost 0.10094180370597888 because of step counter
# Final cost : 0.10094180370597888
# Compute control for a deterministic system
# Cost in iteration 0: 0.10094180370597888
# Converged in iteration 1 with cost 0.10094180370597888 because of step counter
# Final cost : 0.10094180370597888
# Compute control for a deterministic system
# Cost in iteration 0: 0.10094180370597888
# Converged in iteration 1 with cost 0.10094180370597888 because of step counter
# Final cost : 0.10094180370597888
# Compute control for a deterministic system
# Cost in iteration 0: 0.10094180370597888
# Converged in iteration 1 with cost 0.10094180370597888 because of step counter
# Final cost : 0.10094180370597888
# Compute control for a deterministic system
# Cost in iteration 0: 0.1177796637665143
# Converged in iteration 144 with cost 0.08585041279492768 because of vanishing difference
# Final cost : 0.08585041279492768
# Compute control for a deterministic system
# Cost in iteration 0: 0.08585041279492768
# Converged in iteration 1 with cost 0.08585041279492768 because of step counter
# Final cost : 0.08585041279492768
# Compute control for a deterministic system
# Cost in iteration 0: 0.08585041279492768
# Converged in iteration 1 with cost 0.08585041279492768 because of step counter
# Final cost : 0.08585041279492768
# Compute control for a deterministic system
# Cost in iteration 0: 0.08585041279492768
# Converged in iteration 1 with cost 0.08585041279492768 because of step counter
# Final cost : 0.08585041279492768
# Compute control for a deterministic system
# Cost in iteration 0: 0.08585041279492768
# Converged in iteration 1 with cost 0.08585041279492768 because of step counter
# Final cost : 0.08585041279492768
# Compute control for a deterministic system
# Cost in iteration 0: 0.10533133418086205
# Converged in iteration 196 with cost 0.07347369145119932 because of vanishing difference
# Final cost : 0.07347369145119932
# Compute control for a deterministic system
# Cost in iteration 0: 0.07347369145119932
# Converged in iteration 1 with cost 0.07347369145119932 because of step counter
# Final cost : 0.07347369145119932
# Compute control for a deterministic system
# Cost in iteration 0: 0.07347369145119932
# Converged in iteration 1 with cost 0.07347369145119932 because of step counter
# Final cost : 0.07347369145119932
# Compute control for a deterministic system
# Cost in iteration 0: 0.07347369145119932
# Converged in iteration 1 with cost 0.07347369145119932 because of step counter
# Final cost : 0.07347369145119932
# Compute control for a deterministic system
# Cost in iteration 0: 0.07347369145119932
# Converged in iteration 1 with cost 0.07347369145119932 because of step counter
# Final cost : 0.07347369145119932
# Compute control for a deterministic system
# Cost in iteration 0: 0.10302816841626733
# Converged in iteration 169 with cost 0.056710759175469 because of vanishing difference
# Final cost : 0.056710759175469
# Compute control for a deterministic system
# Cost in iteration 0: 0.056710759175469
# Converged in iteration 1 with cost 0.056710759175469 because of step counter
# Final cost : 0.056710759175469
# Compute control for a deterministic system
# Cost in iteration 0: 0.056710759175469
# Converged in iteration 1 with cost 0.056710759175469 because of step counter
# Final cost : 0.056710759175469
# Compute control for a deterministic system
# Cost in iteration 0: 0.056710759175469
# Converged in iteration 1 with cost 0.056710759175469 because of step counter
# Final cost : 0.056710759175469
# Compute control for a deterministic system
# Cost in iteration 0: 0.056710759175469
# Converged in iteration 1 with cost 0.056710759175469 because of step counter
# Final cost : 0.056710759175469
# -----------------------------------------------
# 0 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0774827450827114
# Cost in iteration 200: 0.04188933597649136
# Final cost : 0.04188933597649136
# Compute control for a deterministic system
# Cost in iteration 0: 0.04188933597649136
# Converged in iteration 48 with cost 0.04188915640433601 because of vanishing difference
# Final cost : 0.04188915640433601
# Compute control for a deterministic system
# Cost in iteration 0: 0.04188915640433601
# Converged in iteration 1 with cost 0.04188915640433601 because of step counter
# Final cost : 0.04188915640433601
# Compute control for a deterministic system
# Cost in iteration 0: 0.04188915640433601
# Converged in iteration 1 with cost 0.04188915640433601 because of step counter
# Final cost : 0.04188915640433601
# Compute control for a deterministic system
# Cost in iteration 0: 0.04188915640433601
# Converged in iteration 1 with cost 0.04188915640433601 because of step counter
# Final cost : 0.04188915640433601
# Compute control for a deterministic system
# Cost in iteration 0: 0.07166427815009258
# Cost in iteration 200: 0.025926390214642138
# Final cost : 0.025926390214642138
# Compute control for a deterministic system
# Cost in iteration 0: 0.025926390214642138
# Converged in iteration 8 with cost 0.02592637954929119 because of vanishing difference
# Final cost : 0.02592637954929119
# Compute control for a deterministic system
# Cost in iteration 0: 0.02592637954929119
# Converged in iteration 1 with cost 0.02592637954929119 because of step counter
# Final cost : 0.02592637954929119
# Compute control for a deterministic system
# Cost in iteration 0: 0.02592637954929119
# Converged in iteration 1 with cost 0.02592637954929119 because of step counter
# Final cost : 0.02592637954929119
# Compute control for a deterministic system
# Cost in iteration 0: 0.02592637954929119
# Converged in iteration 1 with cost 0.02592637954929119 because of step counter
# Final cost : 0.02592637954929119
# Compute control for a deterministic system
# Cost in iteration 0: 0.041709435962058505
# Cost in iteration 200: 0.013709363028003844
# Final cost : 0.013709363028003844
# Compute control for a deterministic system
# Cost in iteration 0: 0.013709363028003844
# Converged in iteration 1 with cost 0.013709363028003844 because of step counter
# Final cost : 0.013709363028003844
# Compute control for a deterministic system
# Cost in iteration 0: 0.013709363028003844
# Converged in iteration 1 with cost 0.013709363028003844 because of step counter
# Final cost : 0.013709363028003844
# Compute control for a deterministic system
# Cost in iteration 0: 0.013709363028003844
# Converged in iteration 1 with cost 0.013709363028003844 because of step counter
# Final cost : 0.013709363028003844
# Compute control for a deterministic system
# Cost in iteration 0: 0.013709363028003844
# Converged in iteration 1 with cost 0.013709363028003844 because of step counter
# Final cost : 0.013709363028003844
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.051009341236860704
# Converged in iteration 125 with cost 0.025941569507829613 because of vanishing difference
# Final cost : 0.025941569507829613
# Compute control for a deterministic system
# Cost in iteration 0: 0.025941569507829613
# Converged in iteration 1 with cost 0.025941569507829613 because of step counter
# Final cost : 0.025941569507829613
# Compute control for a deterministic system
# Cost in iteration 0: 0.025941569507829613
# Converged in iteration 1 with cost 0.025941569507829613 because of step counter
# Final cost : 0.025941569507829613
# Compute control for a deterministic system
# Cost in iteration 0: 0.025941569507829613
# Converged in iteration 1 with cost 0.025941569507829613 because of step counter
# Final cost : 0.025941569507829613
# Compute control for a deterministic system
# Cost in iteration 0: 0.0775676692328826
# Converged in iteration 90 with cost 0.0414927087198294 because of vanishing difference
# Final cost : 0.0414927087198294
# Compute control for a deterministic system
# Cost in iteration 0: 0.0414927087198294
# Converged in iteration 1 with cost 0.0414927087198294 because of step counter
# Final cost : 0.0414927087198294
# Compute control for a deterministic system
# Cost in iteration 0: 0.0414927087198294
# Converged in iteration 1 with cost 0.0414927087198294 because of step counter
# Final cost : 0.0414927087198294
# Compute control for a deterministic system
# Cost in iteration 0: 0.0414927087198294
# Converged in iteration 1 with cost 0.0414927087198294 because of step counter
# Final cost : 0.0414927087198294
# Compute control for a deterministic system
# Cost in iteration 0: 0.09063693295701103
# Converged in iteration 105 with cost 0.05753827313970299 because of step counter
# Final cost : 0.05753827313970299
# Compute control for a deterministic system
# Cost in iteration 0: 0.05753827313970299
# Converged in iteration 1 with cost 0.05753827313970299 because of step counter
# Final cost : 0.05753827313970299
# Compute control for a deterministic system
# Cost in iteration 0: 0.05753827313970299
# Converged in iteration 1 with cost 0.05753827313970299 because of step counter
# Final cost : 0.05753827313970299
# Compute control for a deterministic system
# Cost in iteration 0: 0.05753827313970299
# Converged in iteration 1 with cost 0.05753827313970299 because of step counter
# Final cost : 0.05753827313970299
# Compute control for a deterministic system
# Cost in iteration 0: 0.10161853476440119
# Converged in iteration 71 with cost 0.07243933659437422 because of vanishing difference
# Final cost : 0.07243933659437422
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243933659437422
# Converged in iteration 1 with cost 0.07243933659437422 because of step counter
# Final cost : 0.07243933659437422
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243933659437422
# Converged in iteration 1 with cost 0.07243933659437422 because of step counter
# Final cost : 0.07243933659437422
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243933659437422
# Converged in iteration 1 with cost 0.07243933659437422 because of step counter
# Final cost : 0.07243933659437422
# Compute control for a deterministic system
# Cost in iteration 0: 0.10674778880534053
# Converged in iteration 113 with cost 0.08563091477129671 because of step counter
# Final cost : 0.08563091477129671
# Compute control for a deterministic system
# Cost in iteration 0: 0.08563091477129671
# Converged in iteration 1 with cost 0.08563091477129671 because of step counter
# Final cost : 0.08563091477129671
# Compute control for a deterministic system
# Cost in iteration 0: 0.08563091477129671
# Converged in iteration 1 with cost 0.08563091477129671 because of step counter
# Final cost : 0.08563091477129671
# Compute control for a deterministic system
# Cost in iteration 0: 0.08563091477129671
# Converged in iteration 1 with cost 0.08563091477129671 because of step counter
# Final cost : 0.08563091477129671
# Compute control for a deterministic system
# Cost in iteration 0: 0.16691347541929713
# Converged in iteration 87 with cost 0.10149185948288311 because of vanishing difference
# Final cost : 0.10149185948288311
# Compute control for a deterministic system
# Cost in iteration 0: 0.10149185948288311
# Converged in iteration 1 with cost 0.10149185948288311 because of step counter
# Final cost : 0.10149185948288311
# Compute control for a deterministic system
# Cost in iteration 0: 0.10149185948288311
# Converged in iteration 1 with cost 0.10149185948288311 because of step counter
# Final cost : 0.10149185948288311
# Compute control for a deterministic system
# Cost in iteration 0: 0.10149185948288311
# Converged in iteration 1 with cost 0.10149185948288311 because of step counter
# Final cost : 0.10149185948288311
# Compute control for a deterministic system
# Cost in iteration 0: 0.1404118359082463
# Converged in iteration 136 with cost 0.11805417593479926 because of step counter
# Final cost : 0.11805417593479926
# Compute control for a deterministic system
# Cost in iteration 0: 0.11805417593479926
# Converged in iteration 1 with cost 0.11805417593479926 because of step counter
# Final cost : 0.11805417593479926
# Compute control for a deterministic system
# Cost in iteration 0: 0.11805417593479926
# Converged in iteration 1 with cost 0.11805417593479926 because of step counter
# Final cost : 0.11805417593479926
# Compute control for a deterministic system
# Cost in iteration 0: 0.11805417593479926
# Converged in iteration 1 with cost 0.11805417593479926 because of step counter
# Final cost : 0.11805417593479926
# Compute control for a deterministic system
# Cost in iteration 0: 0.19280151700984316
# Converged in iteration 78 with cost 0.1351464309561666 because of vanishing difference
# Final cost : 0.1351464309561666
# Compute control for a deterministic system
# Cost in iteration 0: 0.1351464309561666
# Converged in iteration 23 with cost 0.13514629186983257 because of step counter
# Final cost : 0.13514629186983257
# Compute control for a deterministic system
# Cost in iteration 0: 0.13514629186983257
# Converged in iteration 1 with cost 0.13514629186983257 because of step counter
# Final cost : 0.13514629186983257
# Compute control for a deterministic system
# Cost in iteration 0: 0.13514629186983257
# Converged in iteration 1 with cost 0.13514629186983257 because of step counter
# Final cost : 0.13514629186983257
# Compute control for a deterministic system
# Cost in iteration 0: 0.21106858071738238
# Converged in iteration 93 with cost 0.14574009593786524 because of vanishing difference
# Final cost : 0.14574009593786524
# Compute control for a deterministic system
# Cost in iteration 0: 0.14574009593786524
# Converged in iteration 1 with cost 0.14574009593786524 because of step counter
# Final cost : 0.14574009593786524
# Compute control for a deterministic system
# Cost in iteration 0: 0.14574009593786524
# Converged in iteration 1 with cost 0.14574009593786524 because of step counter
# Final cost : 0.14574009593786524
# Compute control for a deterministic system
# Cost in iteration 0: 0.14574009593786524
# Converged in iteration 1 with cost 0.14574009593786524 because of step counter
# Final cost : 0.14574009593786524
# Compute control for a deterministic system
# Cost in iteration 0: 0.20000632036098576
# Converged in iteration 156 with cost 0.16286349244484666 because of step counter
# Final cost : 0.16286349244484666
# Compute control for a deterministic system
# Cost in iteration 0: 0.16286349244484666
# Converged in iteration 1 with cost 0.16286349244484666 because of step counter
# Final cost : 0.16286349244484666
# Compute control for a deterministic system
# Cost in iteration 0: 0.16286349244484666
# Converged in iteration 1 with cost 0.16286349244484666 because of step counter
# Final cost : 0.16286349244484666
# Compute control for a deterministic system
# Cost in iteration 0: 0.16286349244484666
# Converged in iteration 1 with cost 0.16286349244484666 because of step counter
# Final cost : 0.16286349244484666
# Compute control for a deterministic system
# Cost in iteration 0: 0.21749303841785683
# Converged in iteration 77 with cost 0.17951383677212995 because of vanishing difference
# Final cost : 0.17951383677212995
# Compute control for a deterministic system
# Cost in iteration 0: 0.17951383677212995
# Converged in iteration 1 with cost 0.17951383677212995 because of step counter
# Final cost : 0.17951383677212995
# Compute control for a deterministic system
# Cost in iteration 0: 0.17951383677212995
# Converged in iteration 1 with cost 0.17951383677212995 because of step counter
# Final cost : 0.17951383677212995
# Compute control for a deterministic system
# Cost in iteration 0: 0.17951383677212995
# Converged in iteration 1 with cost 0.17951383677212995 because of step counter
# Final cost : 0.17951383677212995
# Compute control for a deterministic system
# Cost in iteration 0: 0.24150485138748257
# Converged in iteration 157 with cost 0.19528755855566707 because of step counter
# Final cost : 0.19528755855566707
# Compute control for a deterministic system
# Cost in iteration 0: 0.19528755855566707
# Converged in iteration 1 with cost 0.19528755855566707 because of step counter
# Final cost : 0.19528755855566707
# Compute control for a deterministic system
# Cost in iteration 0: 0.19528755855566707
# Converged in iteration 1 with cost 0.19528755855566707 because of step counter
# Final cost : 0.19528755855566707
# Compute control for a deterministic system
# Cost in iteration 0: 0.19528755855566707
# Converged in iteration 1 with cost 0.19528755855566707 because of step counter
# Final cost : 0.19528755855566707
# Compute control for a deterministic system
# Cost in iteration 0: 0.22200892895129162
# Converged in iteration 90 with cost 0.20925080987163883 because of vanishing difference
# Final cost : 0.20925080987163883
# Compute control for a deterministic system
# Cost in iteration 0: 0.20925080987163883
# Converged in iteration 1 with cost 0.20925080987163883 because of step counter
# Final cost : 0.20925080987163883
# Compute control for a deterministic system
# Cost in iteration 0: 0.20925080987163883
# Converged in iteration 1 with cost 0.20925080987163883 because of step counter
# Final cost : 0.20925080987163883
# Compute control for a deterministic system
# Cost in iteration 0: 0.20925080987163883
# Converged in iteration 1 with cost 0.20925080987163883 because of step counter
# Final cost : 0.20925080987163883
# Compute control for a deterministic system
# Cost in iteration 0: 0.3033631649776099
# Converged in iteration 94 with cost 0.225669460048317 because of vanishing difference
# Final cost : 0.225669460048317
# Compute control for a deterministic system
# Cost in iteration 0: 0.225669460048317
# Converged in iteration 1 with cost 0.225669460048317 because of step counter
# Final cost : 0.225669460048317
# Compute control for a deterministic system
# Cost in iteration 0: 0.225669460048317
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.2560658717049381
# Converged in iteration 1 with cost 0.2560658717049381 because of step counter
# Final cost : 0.2560658717049381
# Compute control for a deterministic system
# Cost in iteration 0: 0.24738627104623245
# Cost in iteration 200: 0.24213867660603033
# Final cost : 0.24213867660603033
# Compute control for a deterministic system
# Cost in iteration 0: 0.24213867660603033
# Converged in iteration 113 with cost 0.242138192771114 because of step counter
# Final cost : 0.242138192771114
# Compute control for a deterministic system
# Cost in iteration 0: 0.242138192771114
# Converged in iteration 1 with cost 0.242138192771114 because of step counter
# Final cost : 0.242138192771114
# Compute control for a deterministic system
# Cost in iteration 0: 0.242138192771114
# Converged in iteration 1 with cost 0.242138192771114 because of step counter
# Final cost : 0.242138192771114
# Compute control for a deterministic system
# Cost in iteration 0: 0.242138192771114
# Converged in iteration 1 with cost 0.242138192771114 because of step counter
# Final cost : 0.242138192771114
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.22655064228662528
# Cost in iteration 200: 0.22545694427893495
# Final cost : 0.22545694427893495
# Compute control for a deterministic system
# Cost in iteration 0: 0.22545694427893495
# Converged in iteration 18 with cost 0.22545693518038695 because of step counter
# Final cost : 0.22545693518038695
# Compute control for a deterministic system
# Cost in iteration 0: 0.22545693518038695
# Converged in iteration 1 with cost 0.22545693518038695 because of step counter
# Final cost : 0.22545693518038695
# Compute control for a deterministic system
# Cost in iteration 0: 0.22545693518038695
# Converged in iteration 1 with cost 0.22545693518038695 because of step counter
# Final cost : 0.22545693518038695
# Compute control for a deterministic system
# Cost in iteration 0: 0.22545693518038695
# Converged in iteration 1 with cost 0.22545693518038695 because of step counter
# Final cost : 0.22545693518038695
# Compute control for a deterministic system
# Cost in iteration 0: 0.21920722343189922
# Converged in iteration 127 with cost 0.20809946128421342 because of vanishing difference
# Final cost : 0.20809946128421342
# Compute control for a deterministic system
# Cost in iteration 0: 0.20809946128421342
# Converged in iteration 1 with cost 0.20809946128421342 because of step counter
# Final cost : 0.20809946128421342
# Compute control for a deterministic system
# Cost in iteration 0: 0.20809946128421342
# Converged in iteration 1 with cost 0.20809946128421342 because of step counter
# Final cost : 0.20809946128421342
# Compute control for a deterministic system
# Cost in iteration 0: 0.20809946128421342
# Converged in iteration 1 with cost 0.20809946128421342 because of step counter
# Final cost : 0.20809946128421342
# Compute control for a deterministic system
# Cost in iteration 0: 0.20809946128421342
# Converged in iteration 1 with cost 0.20809946128421342 because of step counter
# Final cost : 0.20809946128421342
# Compute control for a deterministic system
# Cost in iteration 0: 0.19937999252865332
# Converged in iteration 126 with cost 0.19232389123102978 because of vanishing difference
# Final cost : 0.19232389123102978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19232389123102978
# Converged in iteration 1 with cost 0.19232389123102978 because of step counter
# Final cost : 0.19232389123102978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19232389123102978
# Converged in iteration 1 with cost 0.19232389123102978 because of step counter
# Final cost : 0.19232389123102978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19232389123102978
# Converged in iteration 1 with cost 0.19232389123102978 because of step counter
# Final cost : 0.19232389123102978
# Compute control for a deterministic system
# Cost in iteration 0: 0.19232389123102978
# Converged in iteration 1 with cost 0.19232389123102978 because of step counter
# Final cost : 0.19232389123102978
# Compute control for a deterministic system
# Cost in iteration 0: 0.1849751427553282
# Cost in iteration 200: 0.17895987805291583
# Final cost : 0.17895987805291583
# Compute control for a deterministic system
# Cost in iteration 0: 0.17895987805291583
# Converged in iteration 77 with cost 0.17895981886452822 because of step counter
# Final cost : 0.17895981886452822
# Compute control for a deterministic system
# Cost in iteration 0: 0.17895981886452822
# Converged in iteration 1 with cost 0.17895981886452822 because of step counter
# Final cost : 0.17895981886452822
# Compute control for a deterministic system
# Cost in iteration 0: 0.17895981886452822
# Converged in iteration 1 with cost 0.17895981886452822 because of step counter
# Final cost : 0.17895981886452822
# Compute control for a deterministic system
# Cost in iteration 0: 0.17895981886452822
# Converged in iteration 1 with cost 0.17895981886452822 because of step counter
# Final cost : 0.17895981886452822
# Compute control for a deterministic system
# Cost in iteration 0: 0.18248881248032842
# Converged in iteration 103 with cost 0.1616505174931966 because of vanishing difference
# Final cost : 0.1616505174931966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1616505174931966
# Converged in iteration 1 with cost 0.1616505174931966 because of step counter
# Final cost : 0.1616505174931966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1616505174931966
# Converged in iteration 1 with cost 0.1616505174931966 because of step counter
# Final cost : 0.1616505174931966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1616505174931966
# Converged in iteration 1 with cost 0.1616505174931966 because of step counter
# Final cost : 0.1616505174931966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1616505174931966
# Converged in iteration 1 with cost 0.1616505174931966 because of step counter
# Final cost : 0.1616505174931966
# Compute control for a deterministic system
# Cost in iteration 0: 0.15798319486222895
# Converged in iteration 119 with cost 0.1460320688924366 because of vanishing difference
# Final cost : 0.1460320688924366
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460320688924366
# Converged in iteration 1 with cost 0.1460320688924366 because of step counter
# Final cost : 0.1460320688924366
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460320688924366
# Converged in iteration 1 with cost 0.1460320688924366 because of step counter
# Final cost : 0.1460320688924366
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460320688924366
# Converged in iteration 1 with cost 0.1460320688924366 because of step counter
# Final cost : 0.1460320688924366
# Compute control for a deterministic system
# Cost in iteration 0: 0.1460320688924366
# Converged in iteration 1 with cost 0.1460320688924366 because of step counter
# Final cost : 0.1460320688924366
# Compute control for a deterministic system
# Cost in iteration 0: 0.1368439703960578
# Cost in iteration 200: 0.13292675885702593
# Final cost : 0.13292675885702593
# Compute control for a deterministic system
# Cost in iteration 0: 0.13292675885702593
# Converged in iteration 114 with cost 0.1329258072783828 because of step counter
# Final cost : 0.1329258072783828
# Compute control for a deterministic system
# Cost in iteration 0: 0.1329258072783828
# Converged in iteration 1 with cost 0.1329258072783828 because of step counter
# Final cost : 0.1329258072783828
# Compute control for a deterministic system
# Cost in iteration 0: 0.1329258072783828
# Converged in iteration 1 with cost 0.1329258072783828 because of step counter
# Final cost : 0.1329258072783828
# Compute control for a deterministic system
# Cost in iteration 0: 0.1329258072783828
# Converged in iteration 1 with cost 0.1329258072783828 because of step counter
# Final cost : 0.1329258072783828
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.123556547937837
# Converged in iteration 147 with cost 0.11695247432008317 because of vanishing difference
# Final cost : 0.11695247432008317
# Compute control for a deterministic system
# Cost in iteration 0: 0.11695247432008317
# Converged in iteration 1 with cost 0.11695247432008317 because of step counter
# Final cost : 0.11695247432008317
# Compute control for a deterministic system
# Cost in iteration 0: 0.11695247432008317
# Converged in iteration 1 with cost 0.11695247432008317 because of step counter
# Final cost : 0.11695247432008317
# Compute control for a deterministic system
# Cost in iteration 0: 0.11695247432008317
# Converged in iteration 1 with cost 0.11695247432008317 because of step counter
# Final cost : 0.11695247432008317
# Compute control for a deterministic system
# Cost in iteration 0: 0.11695247432008317
# Converged in iteration 1 with cost 0.11695247432008317 because of step counter
# Final cost : 0.11695247432008317
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.1021286889191027
# Converged in iteration 158 with cost 0.10050390005176224 because of vanishing difference
# Final cost : 0.10050390005176224
# Compute control for a deterministic system
# Cost in iteration 0: 0.10050390005176224
# Converged in iteration 76 with cost 0.1005036648973903 because of step counter
# Final cost : 0.1005036648973903
# Compute control for a deterministic system
# Cost in iteration 0: 0.1005036648973903
# Converged in iteration 1 with cost 0.1005036648973903 because of step counter
# Final cost : 0.1005036648973903
# Compute control for a deterministic system
# Cost in iteration 0: 0.1005036648973903
# Converged in iteration 1 with cost 0.1005036648973903 because of step counter
# Final cost : 0.1005036648973903
# Compute control for a deterministic system
# Cost in iteration 0: 0.1005036648973903
# Converged in iteration 1 with cost 0.1005036648973903 because of step counter
# Final cost : 0.1005036648973903
# Compute control for a deterministic system
# Cost in iteration 0: 0.08659238083466406
# Cost in iteration 200: 0.08509165325692192
# Final cost : 0.08509165325692192
# Compute control for a deterministic system
# Cost in iteration 0: 0.08509165325692192
# Converged in iteration 42 with cost 0.08509164181999625 because of step counter
# Final cost : 0.08509164181999625
# Compute control for a deterministic system
# Cost in iteration 0: 0.08509164181999625
# Converged in iteration 1 with cost 0.08509164181999625 because of step counter
# Final cost : 0.08509164181999625
# Compute control for a deterministic system
# Cost in iteration 0: 0.08509164181999625
# Converged in iteration 1 with cost 0.08509164181999625 because of step counter
# Final cost : 0.08509164181999625
# Compute control for a deterministic system
# Cost in iteration 0: 0.08509164181999625
# Converged in iteration 1 with cost 0.08509164181999625 because of step counter
# Final cost : 0.08509164181999625
# Compute control for a deterministic system
# Cost in iteration 0: 0.07372043829724001
# Cost in iteration 200: 0.07234708924368048
# Final cost : 0.07234708924368048
# Compute control for a deterministic system
# Cost in iteration 0: 0.07234708924368048
# Converged in iteration 47 with cost 0.0723470777758848 because of step counter
# Final cost : 0.0723470777758848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0723470777758848
# Converged in iteration 1 with cost 0.0723470777758848 because of step counter
# Final cost : 0.0723470777758848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0723470777758848
# Converged in iteration 1 with cost 0.0723470777758848 because of step counter
# Final cost : 0.0723470777758848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0723470777758848
# Converged in iteration 1 with cost 0.0723470777758848 because of step counter
# Final cost : 0.0723470777758848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0579054142418687
# Cost in iteration 200: 0.056697845611064175
# Final cost : 0.056697845611064175
# Compute control for a deterministic system
# Cost in iteration 0: 0.056697845611064175
# Converged in iteration 51 with cost 0.056697822116128206 because of step counter
# Final cost : 0.056697822116128206
# Compute control for a deterministic system
# Cost in iteration 0: 0.056697822116128206
# Converged in iteration 1 with cost 0.056697822116128206 because of step counter
# Final cost : 0.056697822116128206
# Compute control for a deterministic system
# Cost in iteration 0: 0.056697822116128206
# Converged in iteration 1 with cost 0.056697822116128206 because of step counter
# Final cost : 0.056697822116128206
# Compute control for a deterministic system
# Cost in iteration 0: 0.056697822116128206
# Converged in iteration 1 with cost 0.056697822116128206 because of step counter
# Final cost : 0.056697822116128206
# Compute control for a deterministic system
# Cost in iteration 0: 0.04302522194836323
# Converged in iteration 128 with cost 0.04125397237920111 because of vanishing difference
# Final cost : 0.04125397237920111
# Compute control for a deterministic system
# Cost in iteration 0: 0.04125397237920111
# Converged in iteration 21 with cost 0.0412539603084798 because of step counter
# Final cost : 0.0412539603084798
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412539603084798
# Converged in iteration 1 with cost 0.0412539603084798 because of step counter
# Final cost : 0.0412539603084798
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412539603084798
# Converged in iteration 1 with cost 0.0412539603084798 because of step counter
# Final cost : 0.0412539603084798
# Compute control for a deterministic system
# Cost in iteration 0: 0.0412539603084798
# Converged in iteration 1 with cost 0.0412539603084798 because of step counter
# Final cost : 0.0412539603084798
# Compute control for a deterministic system
# Cost in iteration 0: 0.026534092715150344
# Converged in iteration 116 with cost 0.02576360069271139 because of vanishing difference
# Final cost : 0.02576360069271139
# Compute control for a deterministic system
# Cost in iteration 0: 0.02576360069271139
# Converged in iteration 13 with cost 0.025763597979747893 because of step counter
# Final cost : 0.025763597979747893
# Compute control for a deterministic system
# Cost in iteration 0: 0.025763597979747893
# Converged in iteration 1 with cost 0.025763597979747893 because of step counter
# Final cost : 0.025763597979747893
# Compute control for a deterministic system
# Cost in iteration 0: 0.025763597979747893
# Converged in iteration 1 with cost 0.025763597979747893 because of step counter
# Final cost : 0.025763597979747893
# Compute control for a deterministic system
# Cost in iteration 0: 0.025763597979747893
# Converged in iteration 1 with cost 0.025763597979747893 because of step counter
# Final cost : 0.025763597979747893
# -----------------------------------------------
# 4 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.01405990591415701
# Converged in iteration 117 with cost 0.013637287624762882 because of vanishing difference
# Final cost : 0.013637287624762882
# Compute control for a deterministic system
# Cost in iteration 0: 0.013637287624762882
# Converged in iteration 1 with cost 0.013637287624762882 because of step counter
# Final cost : 0.013637287624762882
# Compute control for a deterministic system
# Cost in iteration 0: 0.013637287624762882
# Converged in iteration 1 with cost 0.013637287624762882 because of step counter
# Final cost : 0.013637287624762882
# Compute control for a deterministic system
# Cost in iteration 0: 0.013637287624762882
# Converged in iteration 1 with cost 0.013637287624762882 because of step counter
# Final cost : 0.013637287624762882
# Compute control for a deterministic system
# Cost in iteration 0: 0.013637287624762882
# Converged in iteration 1 with cost 0.013637287624762882 because of step counter
# Final cost : 0.013637287624762882

# %%
save(results_min)

# %%
plt.plot(results_min["control"][20][0,0,:], color="red")
plt.plot(results_min["control"][20][0,1,:], color="blue")

plt.ylim(-0.01, 0.01)
plt.xlim(1500,1800)
plt.show()

# %%
from neurolib.optimal_control.oc_utils.plot_oc import ops_plotall

ops_plotall(results_min["control"], 0.05, 300, dt, 200, "")
