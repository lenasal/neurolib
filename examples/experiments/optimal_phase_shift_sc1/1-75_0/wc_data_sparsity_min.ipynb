# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.390687755422495 
y_init = 0.46070476656497017
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,55], wc.inh[0,55]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(200,-1,1)
plt.show()
# Out:
# 0.17547204248052564 0.3559503873165702
# minima =  [  12  165  317  470  623  776  929 1082 1235 1388 1541 1694 1847 2000
#  2153 2306 2459 2612 2764 2917 3070 3223 3376 3529 3682 3835 3988]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 2000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0664171996113641
# Final cost : 0.046323249972202156
# Compute control for a deterministic system
# Cost in iteration 0: 0.046323249972202156
# Cost in iteration 200: 0.022981616516164535
# Final cost : 0.022981616516164535
# Compute control for a deterministic system
# Cost in iteration 0: 0.022981616516164535
# Converged in iteration 11 with cost 0.022981616515585664 because of step counter
# Final cost : 0.022981616515585664
# Compute control for a deterministic system
# Cost in iteration 0: 0.022981616515585664
# Converged in iteration 2 with cost 0.022981616515584405 because of step counter
# Final cost : 0.022981616515584405
# Compute control for a deterministic system
# Cost in iteration 0: 0.022981616515584405
# Converged in iteration 1 with cost 0.022981616515584405 because of step counter
# Final cost : 0.022981616515584405
# Compute control for a deterministic system
# Cost in iteration 0: 0.022981616515584405
# Converged in iteration 1 with cost 0.022981616515584405 because of step counter
# Final cost : 0.022981616515584405
# Compute control for a deterministic system
# Cost in iteration 0: 0.2612259916795139
# Final cost : 0.17266556831115337
# Compute control for a deterministic system
# Cost in iteration 0: 0.17266556831115337
# Cost in iteration 200: 0.04867417342244812
# Final cost : 0.04867417342244812
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867417342244812
# Converged in iteration 8 with cost 0.048673981518149424 because of vanishing difference
# Final cost : 0.048673981518149424
# Compute control for a deterministic system
# Cost in iteration 0: 0.048673981518149424
# Converged in iteration 19 with cost 0.04867397292980152 because of vanishing difference
# Final cost : 0.04867397292980152
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867397292980152
# Converged in iteration 2 with cost 0.04867397292980132 because of step counter
# Final cost : 0.04867397292980132
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867397292980132
# Converged in iteration 4 with cost 0.04867397292980037 because of step counter
# Final cost : 0.04867397292980037
# Compute control for a deterministic system
# Cost in iteration 0: 0.484651021701524
# Final cost : 0.32201231766138794
# Compute control for a deterministic system
# Cost in iteration 0: 0.32201231766138794
# Cost in iteration 200: 0.06808896827636972
# Final cost : 0.06808896827636972
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808896827636972
# Converged in iteration 22 with cost 0.0680836088470083 because of vanishing difference
# Final cost : 0.0680836088470083
# Compute control for a deterministic system
# Cost in iteration 0: 0.0680836088470083
# Converged in iteration 48 with cost 0.06808358783481175 because of step counter
# Final cost : 0.06808358783481175
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808358783481175
# Converged in iteration 1 with cost 0.06808358783481175 because of step counter
# Final cost : 0.06808358783481175
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808358783481175
# Converged in iteration 1 with cost 0.06808358783481175 because of step counter
# Final cost : 0.06808358783481175
# Compute control for a deterministic system
# Cost in iteration 0: 0.873084426665246
# Final cost : 0.5957567688621573
# Compute control for a deterministic system
# Cost in iteration 0: 0.5957567688621573
# Cost in iteration 200: 0.09415437278413104
# Final cost : 0.09415437278413104
# Compute control for a deterministic system
# Cost in iteration 0: 0.09415437278413104
# Converged in iteration 135 with cost 0.09408808969304987 because of step counter
# Final cost : 0.09408808969304987
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408808969304987
# Converged in iteration 12 with cost 0.09408808969303592 because of step counter
# Final cost : 0.09408808969303592
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408808969303592
# Converged in iteration 1 with cost 0.09408808969303592 because of step counter
# Final cost : 0.09408808969303592
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408808969303592
# Converged in iteration 1 with cost 0.09408808969303592 because of step counter
# Final cost : 0.09408808969303592
# Compute control for a deterministic system
# Cost in iteration 0: 1.3491544619270095
# Final cost : 0.954077424964944
# Compute control for a deterministic system
# Cost in iteration 0: 0.954077424964944
# Cost in iteration 200: 0.12049779308345593
# Final cost : 0.12049779308345593
# Compute control for a deterministic system
# Cost in iteration 0: 0.12049779308345593
# Cost in iteration 200: 0.12019070798652344
# Final cost : 0.12019070798652344
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019070798652344
# Converged in iteration 5 with cost 0.12019070798651736 because of step counter
# Final cost : 0.12019070798651736
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019070798651736
# Converged in iteration 1 with cost 0.12019070798651736 because of step counter
# Final cost : 0.12019070798651736
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019070798651736
# Converged in iteration 2 with cost 0.120190707986517 because of step counter
# Final cost : 0.120190707986517
# Compute control for a deterministic system
# Cost in iteration 0: 1.895374624784031
# Final cost : 1.3928498702600662
# Compute control for a deterministic system
# Cost in iteration 0: 1.3928498702600662
# Cost in iteration 200: 0.1472873646777825
# Final cost : 0.1472873646777825
# Compute control for a deterministic system
# Cost in iteration 0: 0.1472873646777825
# Converged in iteration 101 with cost 0.14635520932108081 because of vanishing difference
# Final cost : 0.14635520932108081
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635520932108081
# Converged in iteration 151 with cost 0.14635511954914907 because of vanishing difference
# Final cost : 0.14635511954914907
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635511954914907
# Converged in iteration 2 with cost 0.14635511954914507 because of step counter
# Final cost : 0.14635511954914507
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635511954914507
# Converged in iteration 1 with cost 0.14635511954914507 because of step counter
# Final cost : 0.14635511954914507
# Compute control for a deterministic system
# Cost in iteration 0: 2.4945438649055682
# Final cost : 1.9047132256575672
# Compute control for a deterministic system
# Cost in iteration 0: 1.9047132256575672
# Cost in iteration 200: 0.1746130316997607
# Final cost : 0.1746130316997607
# Compute control for a deterministic system
# Cost in iteration 0: 0.1746130316997607
# Converged in iteration 98 with cost 0.17254496003402264 because of vanishing difference
# Final cost : 0.17254496003402264
# Compute control for a deterministic system
# Cost in iteration 0: 0.17254496003402264
# Cost in iteration 200: 0.17254304186472236
# Final cost : 0.17254304186472236
# Compute control for a deterministic system
# Cost in iteration 0: 0.17254304186472236
# Converged in iteration 44 with cost 0.17254304186444497 because of vanishing difference
# Final cost : 0.17254304186444497
# Compute control for a deterministic system
# Cost in iteration 0: 0.17254304186444497
# Converged in iteration 6 with cost 0.17254304186443306 because of step counter
# Final cost : 0.17254304186443306
# Compute control for a deterministic system
# Cost in iteration 0: 3.1296284999161577
# Final cost : 2.4794369286185893
# Compute control for a deterministic system
# Cost in iteration 0: 2.4794369286185893
# Cost in iteration 200: 0.20272149171137996
# Final cost : 0.20272149171137996
# Compute control for a deterministic system
# Cost in iteration 0: 0.20272149171137996
# Cost in iteration 200: 0.19867875180527295
# Final cost : 0.19867875180527295
# Compute control for a deterministic system
# Cost in iteration 0: 0.19867875180527295
# Cost in iteration 200: 0.19867871151631755
# Final cost : 0.19867871151631755
# Compute control for a deterministic system
# Cost in iteration 0: 0.19867871151631755
# Converged in iteration 29 with cost 0.19867871151605815 because of vanishing difference
# Final cost : 0.19867871151605815
# Compute control for a deterministic system
# Cost in iteration 0: 0.19867871151605815
# Converged in iteration 23 with cost 0.19867871151598948 because of step counter
# Final cost : 0.19867871151598948
# Compute control for a deterministic system
# Cost in iteration 0: 3.6190433414921546
# Final cost : 2.9439346465223397
# Compute control for a deterministic system
# Cost in iteration 0: 2.9439346465223397
# Cost in iteration 200: 0.2242139005273784
# Final cost : 0.2242139005273784
# Compute control for a deterministic system
# Cost in iteration 0: 0.2242139005273784
# Cost in iteration 200: 0.21814451954185335
# Final cost : 0.21814451954185335
# Compute control for a deterministic system
# Cost in iteration 0: 0.21814451954185335
# Cost in iteration 200: 0.2181442538108571
# Final cost : 0.2181442538108571
# Compute control for a deterministic system
# Cost in iteration 0: 0.2181442538108571
# Converged in iteration 153 with cost 0.21814425379419541 because of vanishing difference
# Final cost : 0.21814425379419541
# Compute control for a deterministic system
# Cost in iteration 0: 0.21814425379419541
# Converged in iteration 2 with cost 0.21814425379419375 because of step counter
# Final cost : 0.21814425379419375
# Compute control for a deterministic system
# Cost in iteration 0: 4.274676209550104
# Final cost : 3.5953787932727863
# Compute control for a deterministic system
# Cost in iteration 0: 3.5953787932727863
# Cost in iteration 200: 0.25355708668865
# Final cost : 0.25355708668865
# Compute control for a deterministic system
# Cost in iteration 0: 0.25355708668865
# Cost in iteration 200: 0.24376979231620607
# Final cost : 0.24376979231620607
# Compute control for a deterministic system
# Cost in iteration 0: 0.24376979231620607
# Cost in iteration 200: 0.24376796033787565
# Final cost : 0.24376796033787565
# Compute control for a deterministic system
# Cost in iteration 0: 0.24376796033787565
# Cost in iteration 200: 0.24376795983720836
# Converged in iteration 213 with cost 0.24376795983710878 because of vanishing difference
# Final cost : 0.24376795983710878
# Compute control for a deterministic system
# Cost in iteration 0: 0.24376795983710878
# Converged in iteration 39 with cost 0.24376795983693753 because of step counter
# Final cost : 0.24376795983693753
# Compute control for a deterministic system
# Cost in iteration 0: 4.917636149156884
# Final cost : 4.267737665874235
# Compute control for a deterministic system
# Cost in iteration 0: 4.267737665874235
# Cost in iteration 200: 0.2834868782156924
# Final cost : 0.2834868782156924
# Compute control for a deterministic system
# Cost in iteration 0: 0.2834868782156924
# Cost in iteration 200: 0.2690420783973535
# Final cost : 0.2690420783973535
# Compute control for a deterministic system
# Cost in iteration 0: 0.2690420783973535
# Converged in iteration 28 with cost 0.2690380998341074 because of vanishing difference
# Final cost : 0.2690380998341074
# Compute control for a deterministic system
# Cost in iteration 0: 0.2690380998341074
# Cost in iteration 200: 0.2690356465586369
# Cost in iteration 400: 0.26903564220446297
# Final cost : 0.26903564220446297
# Compute control for a deterministic system
# Cost in iteration 0: 0.26903564220446297
# Converged in iteration 38 with cost 0.26903564219737636 because of vanishing difference
# Final cost : 0.26903564219737636
# Compute control for a deterministic system
# Cost in iteration 0: 5.5310650601195395
# Final cost : 4.942519787681243
# Compute control for a deterministic system
# Cost in iteration 0: 4.942519787681243
# Cost in iteration 200: 0.3148531873463259
# Final cost : 0.3148531873463259
# Compute control for a deterministic system
# Cost in iteration 0: 0.3148531873463259
# Cost in iteration 200: 0.29417847441577094
# Final cost : 0.29417847441577094
# Compute control for a deterministic system
# Cost in iteration 0: 0.29417847441577094
# Converged in iteration 32 with cost 0.2941615197023169 because of vanishing difference
# Final cost : 0.2941615197023169
# Compute control for a deterministic system
# Cost in iteration 0: 0.2941615197023169
# Cost in iteration 200: 0.29415122158349105
# Cost in iteration 400: 0.29415117572563065
# Final cost : 0.29415117572563065
# Compute control for a deterministic system
# Cost in iteration 0: 0.29415117572563065
# Converged in iteration 144 with cost 0.29415117551867154 because of step counter
# Final cost : 0.29415117551867154
# Compute control for a deterministic system
# Cost in iteration 0: 6.099211022083016
# Final cost : 5.599358301053032
# Compute control for a deterministic system
# Cost in iteration 0: 5.599358301053032
# Cost in iteration 200: 0.34783651890100875
# Final cost : 0.34783651890100875
# Compute control for a deterministic system
# Cost in iteration 0: 0.34783651890100875
# Cost in iteration 200: 0.31936881504593767
# Final cost : 0.31936881504593767
# Compute control for a deterministic system
# Cost in iteration 0: 0.31936881504593767
# Cost in iteration 200: 0.31929321152619905
# Final cost : 0.31929321152619905
# Compute control for a deterministic system
# Cost in iteration 0: 0.31929321152619905
# Cost in iteration 200: 0.31929281987439473
# Cost in iteration 400: 0.3192928159943087
# Final cost : 0.3192928159943087
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192928159943087
# Converged in iteration 151 with cost 0.31929281595521664 because of step counter
# Final cost : 0.31929281595521664
# Compute control for a deterministic system
# Cost in iteration 0: 6.607667857947998
# Final cost : 6.2153380359603
# Compute control for a deterministic system
# Cost in iteration 0: 6.2153380359603
# Cost in iteration 200: 0.3831437714423621
# Final cost : 0.3831437714423621
# Compute control for a deterministic system
# Cost in iteration 0: 0.3831437714423621
# Cost in iteration 200: 0.3447185826968854
# Final cost : 0.3447185826968854
# Compute control for a deterministic system
# Cost in iteration 0: 0.3447185826968854
# Converged in iteration 72 with cost 0.34457258831008364 because of vanishing difference
# Final cost : 0.34457258831008364
# Compute control for a deterministic system
# Cost in iteration 0: 0.34457258831008364
# Cost in iteration 200: 0.3445377506765372
# Cost in iteration 400: 0.34453712495974326
# Final cost : 0.34453712495974326
# Compute control for a deterministic system
# Cost in iteration 0: 0.34453712495974326
# Cost in iteration 200: 0.34453711287908806
# Converged in iteration 252 with cost 0.34453711287693556 because of vanishing difference
# Final cost : 0.34453711287693556
# Compute control for a deterministic system
# Cost in iteration 0: 6.942263308678207
# Final cost : 6.635582751509083
# Compute control for a deterministic system
# Cost in iteration 0: 6.635582751509083
# Cost in iteration 200: 0.4121446384216854
# Final cost : 0.4121446384216854
# Compute control for a deterministic system
# Cost in iteration 0: 0.4121446384216854
# Cost in iteration 200: 0.3639027996776035
# Final cost : 0.3639027996776035
# Compute control for a deterministic system
# Cost in iteration 0: 0.3639027996776035
# Converged in iteration 112 with cost 0.3635787089706496 because of vanishing difference
# Final cost : 0.3635787089706496
# Compute control for a deterministic system
# Cost in iteration 0: 0.3635787089706496
# Cost in iteration 200: 0.3635486169966744
# Cost in iteration 400: 0.3635477885592471
# Final cost : 0.3635477885592471
# Compute control for a deterministic system
# Cost in iteration 0: 0.3635477885592471
# Cost in iteration 200: 0.36354776404898265
# Converged in iteration 339 with cost 0.36354776403813427 because of vanishing difference
# Final cost : 0.36354776403813427
# Compute control for a deterministic system
# Cost in iteration 0: 7.318061879178962
# Final cost : 7.120842378150688
# Compute control for a deterministic system
# Cost in iteration 0: 7.120842378150688
# Cost in iteration 200: 0.4596196234986055
# Final cost : 0.4596196234986055
# Compute control for a deterministic system
# Cost in iteration 0: 0.4596196234986055
# Cost in iteration 200: 0.38968831601958726
# Final cost : 0.38968831601958726
# Compute control for a deterministic system
# Cost in iteration 0: 0.38968831601958726
# Converged in iteration 157 with cost 0.38901839791010673 because of vanishing difference
# Final cost : 0.38901839791010673
# Compute control for a deterministic system
# Cost in iteration 0: 0.38901839791010673
# Cost in iteration 200: 0.3889907290817999
# Cost in iteration 400: 0.38898949178277614
# Final cost : 0.38898949178277614
# Compute control for a deterministic system
# Cost in iteration 0: 0.38898949178277614
# Cost in iteration 200: 0.3889894313708087
# Converged in iteration 389 with cost 0.3889894312341684 because of vanishing difference
# Final cost : 0.3889894312341684
# Compute control for a deterministic system
# Cost in iteration 0: 7.60723086466484
# Final cost : 7.502135861697078
# Compute control for a deterministic system
# Cost in iteration 0: 7.502135861697078
# Cost in iteration 200: 0.5117395378796158
# Final cost : 0.5117395378796158
# Compute control for a deterministic system
# Cost in iteration 0: 0.5117395378796158
# Cost in iteration 200: 0.41588182199561113
# Final cost : 0.41588182199561113
# Compute control for a deterministic system
# Cost in iteration 0: 0.41588182199561113
# Converged in iteration 172 with cost 0.4145731169554702 because of vanishing difference
# Final cost : 0.4145731169554702
# Compute control for a deterministic system
# Cost in iteration 0: 0.4145731169554702
# Cost in iteration 200: 0.4145218070165153
# Cost in iteration 400: 0.4145184159950447
# Final cost : 0.4145184159950447
# Compute control for a deterministic system
# Cost in iteration 0: 0.4145184159950447
# Cost in iteration 200: 0.4145181603375946
# Cost in iteration 400: 0.41451815916899476
# Converged in iteration 544 with cost 0.4145181591628545 because of step counter
# Final cost : 0.4145181591628545
# Compute control for a deterministic system
# Cost in iteration 0: 7.805940856859571
# Final cost : 7.766485440668853
# Compute control for a deterministic system
# Cost in iteration 0: 7.766485440668853
# Cost in iteration 200: 0.5699259764048082
# Final cost : 0.5699259764048082
# Compute control for a deterministic system
# Cost in iteration 0: 0.5699259764048082
# Cost in iteration 200: 0.44256093044480993
# Final cost : 0.44256093044480993
# Compute control for a deterministic system
# Cost in iteration 0: 0.44256093044480993
# Cost in iteration 200: 0.44019908486903303
# Final cost : 0.44019908486903303
# Compute control for a deterministic system
# Cost in iteration 0: 0.44019908486903303
# Cost in iteration 200: 0.4401171343512404
# Cost in iteration 400: 0.4401095745379275
# Final cost : 0.4401095745379275
# Compute control for a deterministic system
# Cost in iteration 0: 0.4401095745379275
# Cost in iteration 200: 0.44010875862588283
# Cost in iteration 400: 0.44010875310306774
# Converged in iteration 578 with cost 0.44010875306625336 because of vanishing difference
# Final cost : 0.44010875306625336
# Compute control for a deterministic system
# Cost in iteration 0: 7.912818471932278
# Final cost : 7.907907827873491
# Compute control for a deterministic system
# Cost in iteration 0: 7.907907827873491
# Cost in iteration 200: 0.638311997461414
# Final cost : 0.638311997461414
# Compute control for a deterministic system
# Cost in iteration 0: 0.638311997461414
# Cost in iteration 200: 0.4697939165628521
# Final cost : 0.4697939165628521
# Compute control for a deterministic system
# Cost in iteration 0: 0.4697939165628521
# Cost in iteration 200: 0.46590033660385954
# Final cost : 0.46590033660385954
# Compute control for a deterministic system
# Cost in iteration 0: 0.46590033660385954
# Cost in iteration 200: 0.4657567308457411
# Cost in iteration 400: 0.46573944497041586
# Final cost : 0.46573944497041586
# Compute control for a deterministic system
# Cost in iteration 0: 0.46573944497041586
# Cost in iteration 200: 0.4657368993814777
# Cost in iteration 400: 0.46573686559726996
# Cost in iteration 600: 0.46573686518684293
# Converged in iteration 781 with cost 0.4657368651817003 because of step counter
# Final cost : 0.4657368651817003
# Compute control for a deterministic system
# Cost in iteration 0: 7.932806113959339
# Converged in iteration 1 with cost 7.932806113959339 because of step counter
# Final cost : 7.932806113959339
# Compute control for a deterministic system
# Cost in iteration 0: 7.932806113959339
# Converged in iteration 1 with cost 7.932806113959339 because of step counter
# Final cost : 7.932806113959339
# Compute control for a deterministic system
# Cost in iteration 0: 7.932806113959339
# Converged in iteration 1 with cost 7.932806113959339 because of step counter
# Final cost : 7.932806113959339
# Compute control for a deterministic system
# Cost in iteration 0: 7.932806113959339
# Converged in iteration 1 with cost 7.932806113959339 because of step counter
# Final cost : 7.932806113959339
# Compute control for a deterministic system
# Cost in iteration 0: 7.932806113959339
# Converged in iteration 111 with cost 0.5214334004825512 because of vanishing difference
# Final cost : 0.5214334004825512
# Compute control for a deterministic system
# Cost in iteration 0: 0.5214334004825512
# Cost in iteration 200: 0.5154063642302965
# Cost in iteration 400: 0.5149649930896075
# Cost in iteration 600: 0.5149128368056977
# Cost in iteration 800: 0.5149041675759822
# Converged in iteration 993 with cost 0.5149041659587241 because of vanishing difference
# Final cost : 0.5149041659587241
# Compute control for a deterministic system
# Cost in iteration 0: 7.880160896098381
# Final cost : 7.867733615288827
# Compute control for a deterministic system
# Cost in iteration 0: 7.867733615288827
# Cost in iteration 200: 0.6651583817401382
# Final cost : 0.6651583817401382
# Compute control for a deterministic system
# Cost in iteration 0: 0.6651583817401382
# Cost in iteration 200: 0.49096554570123346
# Final cost : 0.49096554570123346
# Compute control for a deterministic system
# Cost in iteration 0: 0.49096554570123346
# Converged in iteration 97 with cost 0.487777551728085 because of vanishing difference
# Final cost : 0.487777551728085
# Compute control for a deterministic system
# Cost in iteration 0: 0.487777551728085
# Cost in iteration 200: 0.48746168135825463
# Cost in iteration 400: 0.48743835340423913
# Final cost : 0.48743835340423913
# Compute control for a deterministic system
# Cost in iteration 0: 0.48743835340423913
# Cost in iteration 200: 0.48743623892112203
# Converged in iteration 385 with cost 0.48743623824687116 because of vanishing difference
# Final cost : 0.48743623824687116
# Compute control for a deterministic system
# Cost in iteration 0: 7.738721569014512
# Final cost : 7.682952191844721
# Compute control for a deterministic system
# Cost in iteration 0: 7.682952191844721
# Cost in iteration 200: 0.5955007761112462
# Final cost : 0.5955007761112462
# Compute control for a deterministic system
# Cost in iteration 0: 0.5955007761112462
# Cost in iteration 200: 0.46208092070783885
# Final cost : 0.46208092070783885
# Compute control for a deterministic system
# Cost in iteration 0: 0.46208092070783885
# Converged in iteration 184 with cost 0.45993686289844943 because of vanishing difference
# Final cost : 0.45993686289844943
# Compute control for a deterministic system
# Cost in iteration 0: 0.45993686289844943
# Cost in iteration 200: 0.4599090057876452
# Cost in iteration 400: 0.45990736292598444
# Final cost : 0.45990736292598444
# Compute control for a deterministic system
# Cost in iteration 0: 0.45990736292598444
# Cost in iteration 200: 0.45990725505591096
# Converged in iteration 289 with cost 0.45990725499012186 because of vanishing difference
# Final cost : 0.45990725499012186
# Compute control for a deterministic system
# Cost in iteration 0: 7.511409691205765
# Final cost : 7.384443237915008
# Compute control for a deterministic system
# Cost in iteration 0: 7.384443237915008
# Cost in iteration 200: 0.5339145061345133
# Final cost : 0.5339145061345133
# Compute control for a deterministic system
# Cost in iteration 0: 0.5339145061345133
# Cost in iteration 200: 0.43349418068836454
# Final cost : 0.43349418068836454
# Compute control for a deterministic system
# Cost in iteration 0: 0.43349418068836454
# Converged in iteration 162 with cost 0.4323001313906708 because of vanishing difference
# Final cost : 0.4323001313906708
# Compute control for a deterministic system
# Cost in iteration 0: 0.4323001313906708
# Cost in iteration 200: 0.4322747923778601
# Cost in iteration 400: 0.43227379434180413
# Final cost : 0.43227379434180413
# Compute control for a deterministic system
# Cost in iteration 0: 0.43227379434180413
# Cost in iteration 200: 0.43227375456224104
# Cost in iteration 400: 0.4322737521388111
# Cost in iteration 600: 0.4322737519116328
# Cost in iteration 800: 0.4322737518425372
# Cost in iteration 1000: 0.4322737518026857
# Final cost : 0.4322737518026857
# Compute control for a deterministic system
# Cost in iteration 0: 7.202261296927138
# Final cost : 6.9818816980028
# Compute control for a deterministic system
# Cost in iteration 0: 6.9818816980028
# Cost in iteration 200: 0.4780023252681461
# Final cost : 0.4780023252681461
# Compute control for a deterministic system
# Cost in iteration 0: 0.4780023252681461
# Cost in iteration 200: 0.40524029131162703
# Final cost : 0.40524029131162703
# Compute control for a deterministic system
# Cost in iteration 0: 0.40524029131162703
# Cost in iteration 200: 0.4045859285231717
# Final cost : 0.4045859285231717
# Compute control for a deterministic system
# Cost in iteration 0: 0.4045859285231717
# Cost in iteration 200: 0.40458271371556864
# Cost in iteration 400: 0.40458263281627455
# Final cost : 0.40458263281627455
# Compute control for a deterministic system
# Cost in iteration 0: 0.40458263281627455
# Cost in iteration 200: 0.4045826308180492
# Cost in iteration 400: 0.4045826307431342
# Converged in iteration 597 with cost 0.4045826307402592 because of step counter
# Final cost : 0.4045826307402592
# Compute control for a deterministic system
# Cost in iteration 0: 6.816562665959592
# Final cost : 6.489637360429917
# Compute control for a deterministic system
# Cost in iteration 0: 6.489637360429917
# Cost in iteration 200: 0.4291135975077491
# Final cost : 0.4291135975077491
# Compute control for a deterministic system
# Cost in iteration 0: 0.4291135975077491
# Cost in iteration 200: 0.37722141659869174
# Final cost : 0.37722141659869174
# Compute control for a deterministic system
# Cost in iteration 0: 0.37722141659869174
# Converged in iteration 50 with cost 0.3769697938497567 because of vanishing difference
# Final cost : 0.3769697938497567
# Compute control for a deterministic system
# Cost in iteration 0: 0.3769697938497567
# Cost in iteration 200: 0.37691381116958894
# Cost in iteration 400: 0.37691304969663547
# Final cost : 0.37691304969663547
# Compute control for a deterministic system
# Cost in iteration 0: 0.37691304969663547
# Cost in iteration 200: 0.37691303905004797
# Cost in iteration 400: 0.3769130388161009
# Cost in iteration 600: 0.3769130388108559
# Converged in iteration 610 with cost 0.376913038810838 because of step counter
# Final cost : 0.376913038810838
# Compute control for a deterministic system
# Cost in iteration 0: 6.481039283192557
# Final cost : 6.072670802024016
# Compute control for a deterministic system
# Cost in iteration 0: 6.072670802024016
# Cost in iteration 200: 0.39819863492652574
# Final cost : 0.39819863492652574
# Compute control for a deterministic system
# Cost in iteration 0: 0.39819863492652574
# Cost in iteration 200: 0.3563635589094225
# Final cost : 0.3563635589094225
# Compute control for a deterministic system
# Cost in iteration 0: 0.3563635589094225
# Cost in iteration 200: 0.35620213426928354
# Final cost : 0.35620213426928354
# Compute control for a deterministic system
# Cost in iteration 0: 0.35620213426928354
# Cost in iteration 200: 0.3562019172118873
# Cost in iteration 400: 0.3562019152858569
# Final cost : 0.3562019152858569
# Compute control for a deterministic system
# Cost in iteration 0: 0.3562019152858569
# Cost in iteration 200: 0.3562019152692616
# Converged in iteration 242 with cost 0.35620191526911976 because of vanishing difference
# Final cost : 0.35620191526911976
# Compute control for a deterministic system
# Cost in iteration 0: 5.978159234344492
# Final cost : 5.468982945723587
# Compute control for a deterministic system
# Cost in iteration 0: 5.468982945723587
# Cost in iteration 200: 0.3592743156318676
# Final cost : 0.3592743156318676
# Compute control for a deterministic system
# Cost in iteration 0: 0.3592743156318676
# Cost in iteration 200: 0.3287416650592562
# Final cost : 0.3287416650592562
# Compute control for a deterministic system
# Cost in iteration 0: 0.3287416650592562
# Converged in iteration 43 with cost 0.32868716901168216 because of vanishing difference
# Final cost : 0.32868716901168216
# Compute control for a deterministic system
# Cost in iteration 0: 0.32868716901168216
# Cost in iteration 200: 0.3286763309230684
# Cost in iteration 400: 0.32867628624749484
# Final cost : 0.32867628624749484
# Compute control for a deterministic system
# Cost in iteration 0: 0.32867628624749484
# Cost in iteration 200: 0.3286762860606116
# Converged in iteration 335 with cost 0.32867628605920896 because of step counter
# Final cost : 0.32867628605920896
# Compute control for a deterministic system
# Cost in iteration 0: 5.419925296243863
# Final cost : 4.8283995230590895
# Compute control for a deterministic system
# Cost in iteration 0: 4.8283995230590895
# Cost in iteration 200: 0.3231019189231388
# Final cost : 0.3231019189231388
# Compute control for a deterministic system
# Cost in iteration 0: 0.3231019189231388
# Cost in iteration 200: 0.30130911817689904
# Final cost : 0.30130911817689904
# Compute control for a deterministic system
# Cost in iteration 0: 0.30130911817689904
# Converged in iteration 20 with cost 0.30129285432257574 because of vanishing difference
# Final cost : 0.30129285432257574
# Compute control for a deterministic system
# Cost in iteration 0: 0.30129285432257574
# Cost in iteration 200: 0.30128779847697595
# Cost in iteration 400: 0.3012877891885779
# Final cost : 0.3012877891885779
# Compute control for a deterministic system
# Cost in iteration 0: 0.3012877891885779
# Converged in iteration 108 with cost 0.30128778917147037 because of step counter
# Final cost : 0.30128778917147037
# Compute control for a deterministic system
# Cost in iteration 0: 4.818238643608247
# Final cost : 4.170469110979621
# Compute control for a deterministic system
# Cost in iteration 0: 4.170469110979621
# Cost in iteration 200: 0.2888830736270959
# Final cost : 0.2888830736270959
# Compute control for a deterministic system
# Cost in iteration 0: 0.2888830736270959
# Converged in iteration 198 with cost 0.2740637193167351 because of vanishing difference
# Final cost : 0.2740637193167351
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740637193167351
# Cost in iteration 200: 0.2740553114545892
# Final cost : 0.2740553114545892
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740553114545892
# Cost in iteration 200: 0.27405530966923286
# Converged in iteration 299 with cost 0.27405530966802744 because of step counter
# Final cost : 0.27405530966802744
# Compute control for a deterministic system
# Cost in iteration 0: 0.27405530966802744
# Converged in iteration 1 with cost 0.27405530966802744 because of step counter
# Final cost : 0.27405530966802744
# Compute control for a deterministic system
# Cost in iteration 0: 4.1887553350999776
# Final cost : 3.5153044797416175
# Compute control for a deterministic system
# Cost in iteration 0: 3.5153044797416175
# Cost in iteration 200: 0.25660320158268757
# Final cost : 0.25660320158268757
# Compute control for a deterministic system
# Cost in iteration 0: 0.25660320158268757
# Cost in iteration 200: 0.24698052396762862
# Final cost : 0.24698052396762862
# Compute control for a deterministic system
# Cost in iteration 0: 0.24698052396762862
# Cost in iteration 200: 0.24697943759488136
# Final cost : 0.24697943759488136
# Compute control for a deterministic system
# Cost in iteration 0: 0.24697943759488136
# Converged in iteration 164 with cost 0.24697943754593005 because of vanishing difference
# Final cost : 0.24697943754593005
# Compute control for a deterministic system
# Cost in iteration 0: 0.24697943754593005
# Converged in iteration 8 with cost 0.24697943754588458 because of step counter
# Final cost : 0.24697943754588458
# Compute control for a deterministic system
# Cost in iteration 0: 3.5482804583176506
# Final cost : 2.8813660989130025
# Compute control for a deterministic system
# Cost in iteration 0: 2.8813660989130025
# Cost in iteration 200: 0.22596213557877404
# Final cost : 0.22596213557877404
# Compute control for a deterministic system
# Cost in iteration 0: 0.22596213557877404
# Converged in iteration 159 with cost 0.22005263553803897 because of vanishing difference
# Final cost : 0.22005263553803897
# Compute control for a deterministic system
# Cost in iteration 0: 0.22005263553803897
# Cost in iteration 200: 0.22005138428167312
# Final cost : 0.22005138428167312
# Compute control for a deterministic system
# Cost in iteration 0: 0.22005138428167312
# Converged in iteration 136 with cost 0.22005138426280338 because of step counter
# Final cost : 0.22005138426280338
# Compute control for a deterministic system
# Cost in iteration 0: 0.22005138426280338
# Converged in iteration 1 with cost 0.22005138426280338 because of step counter
# Final cost : 0.22005138426280338
# Compute control for a deterministic system
# Cost in iteration 0: 3.07064530754771
# Final cost : 2.4295105423040337
# Compute control for a deterministic system
# Cost in iteration 0: 2.4295105423040337
# Cost in iteration 200: 0.2038165474989396
# Final cost : 0.2038165474989396
# Compute control for a deterministic system
# Cost in iteration 0: 0.2038165474989396
# Cost in iteration 200: 0.19994579215323027
# Final cost : 0.19994579215323027
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994579215323027
# Cost in iteration 200: 0.19994576816003137
# Final cost : 0.19994576816003137
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994576816003137
# Converged in iteration 17 with cost 0.19994576816000054 because of vanishing difference
# Final cost : 0.19994576816000054
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994576816000054
# Converged in iteration 9 with cost 0.19994576815998813 because of step counter
# Final cost : 0.19994576815998813
# Compute control for a deterministic system
# Cost in iteration 0: 2.4504102624702364
# Final cost : 1.869669630013046
# Compute control for a deterministic system
# Cost in iteration 0: 1.869669630013046
# Cost in iteration 200: 0.17528848318014278
# Final cost : 0.17528848318014278
# Compute control for a deterministic system
# Cost in iteration 0: 0.17528848318014278
# Cost in iteration 200: 0.17325162500038768
# Final cost : 0.17325162500038768
# Compute control for a deterministic system
# Cost in iteration 0: 0.17325162500038768
# Converged in iteration 100 with cost 0.17325162422114002 because of vanishing difference
# Final cost : 0.17325162422114002
# Compute control for a deterministic system
# Cost in iteration 0: 0.17325162422114002
# Converged in iteration 15 with cost 0.17325162422107127 because of vanishing difference
# Final cost : 0.17325162422107127
# Compute control for a deterministic system
# Cost in iteration 0: 0.17325162422107127
# Converged in iteration 8 with cost 0.17325162422103088 because of step counter
# Final cost : 0.17325162422103088
# Compute control for a deterministic system
# Cost in iteration 0: 1.8640133991912315
# Final cost : 1.3695985601924205
# Compute control for a deterministic system
# Cost in iteration 0: 1.3695985601924205
# Cost in iteration 200: 0.14754961221386745
# Final cost : 0.14754961221386745
# Compute control for a deterministic system
# Cost in iteration 0: 0.14754961221386745
# Converged in iteration 84 with cost 0.14668300898048206 because of vanishing difference
# Final cost : 0.14668300898048206
# Compute control for a deterministic system
# Cost in iteration 0: 0.14668300898048206
# Converged in iteration 154 with cost 0.1466826642645767 because of step counter
# Final cost : 0.1466826642645767
# Compute control for a deterministic system
# Cost in iteration 0: 0.1466826642645767
# Converged in iteration 1 with cost 0.1466826642645767 because of step counter
# Final cost : 0.1466826642645767
# Compute control for a deterministic system
# Cost in iteration 0: 0.1466826642645767
# Converged in iteration 1 with cost 0.1466826642645767 because of step counter
# Final cost : 0.1466826642645767
# Compute control for a deterministic system
# Cost in iteration 0: 1.3280247131808045
# Final cost : 0.9394518220602278
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394518220602278
# Cost in iteration 200: 0.12066288243245238
# Final cost : 0.12066288243245238
# Compute control for a deterministic system
# Cost in iteration 0: 0.12066288243245238
# Converged in iteration 70 with cost 0.1202404331057592 because of vanishing difference
# Final cost : 0.1202404331057592
# Compute control for a deterministic system
# Cost in iteration 0: 0.1202404331057592
# Converged in iteration 123 with cost 0.12024028451071277 because of step counter
# Final cost : 0.12024028451071277
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024028451071277
# Converged in iteration 1 with cost 0.12024028451071277 because of step counter
# Final cost : 0.12024028451071277
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024028451071277
# Converged in iteration 1 with cost 0.12024028451071277 because of step counter
# Final cost : 0.12024028451071277
# Compute control for a deterministic system
# Cost in iteration 0: 0.8596418978915248
# Final cost : 0.5869973115865771
# Compute control for a deterministic system
# Cost in iteration 0: 0.5869973115865771
# Cost in iteration 200: 0.09399314826697452
# Final cost : 0.09399314826697452
# Compute control for a deterministic system
# Cost in iteration 0: 0.09399314826697452
# Converged in iteration 48 with cost 0.09393470025451596 because of vanishing difference
# Final cost : 0.09393470025451596
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393470025451596
# Converged in iteration 83 with cost 0.09393466670054734 because of step counter
# Final cost : 0.09393466670054734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393466670054734
# Converged in iteration 1 with cost 0.09393466670054734 because of step counter
# Final cost : 0.09393466670054734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393466670054734
# Converged in iteration 1 with cost 0.09393466670054734 because of step counter
# Final cost : 0.09393466670054734
# Compute control for a deterministic system
# Cost in iteration 0: 0.5634052848898298
# Final cost : 0.3766375836637273
# Compute control for a deterministic system
# Cost in iteration 0: 0.3766375836637273
# Cost in iteration 200: 0.07431839841040652
# Final cost : 0.07431839841040652
# Compute control for a deterministic system
# Cost in iteration 0: 0.07431839841040652
# Converged in iteration 30 with cost 0.07430829656438585 because of vanishing difference
# Final cost : 0.07430829656438585
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430829656438585
# Converged in iteration 61 with cost 0.07430827895009944 because of step counter
# Final cost : 0.07430827895009944
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827895009944
# Converged in iteration 1 with cost 0.07430827895009944 because of step counter
# Final cost : 0.07430827895009944
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827895009944
# Converged in iteration 1 with cost 0.07430827895009944 because of step counter
# Final cost : 0.07430827895009944
# Compute control for a deterministic system
# Cost in iteration 0: 0.25611106670503886
# Final cost : 0.16949454924732432
# Compute control for a deterministic system
# Cost in iteration 0: 0.16949454924732432
# Cost in iteration 200: 0.04830873376544724
# Final cost : 0.04830873376544724
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830873376544724
# Converged in iteration 46 with cost 0.048308575437375885 because of step counter
# Final cost : 0.048308575437375885
# Compute control for a deterministic system
# Cost in iteration 0: 0.048308575437375885
# Converged in iteration 1 with cost 0.048308575437375885 because of step counter
# Final cost : 0.048308575437375885
# Compute control for a deterministic system
# Cost in iteration 0: 0.048308575437375885
# Converged in iteration 1 with cost 0.048308575437375885 because of step counter
# Final cost : 0.048308575437375885
# Compute control for a deterministic system
# Cost in iteration 0: 0.048308575437375885
# Converged in iteration 1 with cost 0.048308575437375885 because of step counter
# Final cost : 0.048308575437375885
# Compute control for a deterministic system
# Cost in iteration 0: 0.06413809888128998
# Final cost : 0.04486458002606082
# Compute control for a deterministic system
# Cost in iteration 0: 0.04486458002606082
# Converged in iteration 115 with cost 0.022566395533874878 because of vanishing difference
# Final cost : 0.022566395533874878
# Compute control for a deterministic system
# Cost in iteration 0: 0.022566395533874878
# Converged in iteration 17 with cost 0.02256639343413265 because of step counter
# Final cost : 0.02256639343413265
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256639343413265
# Converged in iteration 1 with cost 0.02256639343413265 because of step counter
# Final cost : 0.02256639343413265
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256639343413265
# Converged in iteration 2 with cost 0.022566393434131866 because of step counter
# Final cost : 0.022566393434131866
# Compute control for a deterministic system
# Cost in iteration 0: 0.022566393434131866
# Converged in iteration 1 with cost 0.022566393434131866 because of step counter
# Final cost : 0.022566393434131866
# Compute control for a deterministic system
# Cost in iteration 0: 1.8440936720456213e-05
# Converged in iteration 1 with cost 1.8440936720456213e-05 because of step counter
# Final cost : 1.8440936720456213e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8440936720456213e-05
# Converged in iteration 1 with cost 1.8440936720456213e-05 because of step counter
# Final cost : 1.8440936720456213e-05
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.13400691368096415
# Cost in iteration 200: 0.04867409910855703
# Final cost : 0.04867409910855703
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867409910855703
# Converged in iteration 7 with cost 0.04867397828044525 because of vanishing difference
# Final cost : 0.04867397828044525
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867397828044525
# Converged in iteration 10 with cost 0.04867396956480344 because of step counter
# Final cost : 0.04867396956480344
# Compute control for a deterministic system
# Cost in iteration 0: 0.04867396956480344
# Converged in iteration 3 with cost 0.048673969564803174 because of vanishing difference
# Final cost : 0.048673969564803174
# Compute control for a deterministic system
# Cost in iteration 0: 0.048673969564803174
# Converged in iteration 3 with cost 0.04867396956480219 because of step counter
# Final cost : 0.04867396956480219
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.08651473398064068
# Cost in iteration 200: 0.0680846783244423
# Final cost : 0.0680846783244423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0680846783244423
# Converged in iteration 16 with cost 0.06808359844222639 because of vanishing difference
# Final cost : 0.06808359844222639
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808359844222639
# Converged in iteration 38 with cost 0.06808358415419864 because of step counter
# Final cost : 0.06808358415419864
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808358415419864
# Converged in iteration 3 with cost 0.06808358415419777 because of vanishing difference
# Final cost : 0.06808358415419777
# Compute control for a deterministic system
# Cost in iteration 0: 0.06808358415419777
# Converged in iteration 1 with cost 0.06808358415419777 because of step counter
# Final cost : 0.06808358415419777
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.1310388155385048
# Cost in iteration 200: 0.09410385710427903
# Final cost : 0.09410385710427903
# Compute control for a deterministic system
# Cost in iteration 0: 0.09410385710427903
# Converged in iteration 138 with cost 0.09408809186011378 because of step counter
# Final cost : 0.09408809186011378
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408809186011378
# Converged in iteration 2 with cost 0.09408809186011198 because of step counter
# Final cost : 0.09408809186011198
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408809186011198
# Converged in iteration 1 with cost 0.09408809186011198 because of step counter
# Final cost : 0.09408809186011198
# Compute control for a deterministic system
# Cost in iteration 0: 0.09408809186011198
# Converged in iteration 2 with cost 0.09408809186011194 because of step counter
# Final cost : 0.09408809186011194
# Compute control for a deterministic system
# Cost in iteration 0: 0.2123352111149306
# Cost in iteration 200: 0.12024545602138886
# Final cost : 0.12024545602138886
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024545602138886
# Converged in iteration 79 with cost 0.12019071845034543 because of vanishing difference
# Final cost : 0.12019071845034543
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019071845034543
# Converged in iteration 116 with cost 0.12019070997231342 because of step counter
# Final cost : 0.12019070997231342
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019070997231342
# Converged in iteration 1 with cost 0.12019070997231342 because of step counter
# Final cost : 0.12019070997231342
# Compute control for a deterministic system
# Cost in iteration 0: 0.12019070997231342
# Converged in iteration 1 with cost 0.12019070997231342 because of step counter
# Final cost : 0.12019070997231342
# Compute control for a deterministic system
# Cost in iteration 0: 0.15079963062025611
# Cost in iteration 200: 0.1464607171788206
# Final cost : 0.1464607171788206
# Compute control for a deterministic system
# Cost in iteration 0: 0.1464607171788206
# Cost in iteration 200: 0.14635511563089806
# Final cost : 0.14635511563089806
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635511563089806
# Converged in iteration 54 with cost 0.14635511562969822 because of step counter
# Final cost : 0.14635511562969822
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635511562969822
# Converged in iteration 2 with cost 0.14635511562969772 because of step counter
# Final cost : 0.14635511562969772
# Compute control for a deterministic system
# Cost in iteration 0: 0.14635511562969772
# Converged in iteration 2 with cost 0.14635511562969747 because of step counter
# Final cost : 0.14635511562969747
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.18753187864883597
# Cost in iteration 200: 0.1727487182045379
# Final cost : 0.1727487182045379
# Compute control for a deterministic system
# Cost in iteration 0: 0.1727487182045379
# Cost in iteration 200: 0.17254303927117806
# Final cost : 0.17254303927117806
# Compute control for a deterministic system
# Cost in iteration 0: 0.17254303927117806
# Converged in iteration 116 with cost 0.17254303915459396 because of step counter
# Final cost : 0.17254303915459396
# Compute control for a deterministic system
# Cost in iteration 0: 0.17254303915459396
# Converged in iteration 1 with cost 0.17254303915459396 because of step counter
# ...
# Cost in iteration 0: 0.4060276975462492
# Cost in iteration 200: 0.40458269585760404
# Final cost : 0.40458269585760404
# Compute control for a deterministic system
# Cost in iteration 0: 0.40458269585760404
# Cost in iteration 200: 0.4045825879895621
# Final cost : 0.4045825879895621
# Compute control for a deterministic system
# Cost in iteration 0: 0.4045825879895621
# Cost in iteration 200: 0.4045825879079054
# Final cost : 0.4045825879079054
# Compute control for a deterministic system
# Cost in iteration 0: 0.4045825879079054
# Converged in iteration 82 with cost 0.404582587907438 because of vanishing difference
# Final cost : 0.404582587907438
# Compute control for a deterministic system
# Cost in iteration 0: 0.404582587907438
# Converged in iteration 8 with cost 0.40458258790742074 because of vanishing difference
# Final cost : 0.40458258790742074
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.37816816108338563
# Cost in iteration 200: 0.37691306370417893
# Final cost : 0.37691306370417893
# Compute control for a deterministic system
# Cost in iteration 0: 0.37691306370417893
# Cost in iteration 200: 0.3769129759573802
# Final cost : 0.3769129759573802
# Compute control for a deterministic system
# Cost in iteration 0: 0.3769129759573802
# Cost in iteration 200: 0.3769129759078103
# Final cost : 0.3769129759078103
# Compute control for a deterministic system
# Cost in iteration 0: 0.3769129759078103
# Converged in iteration 29 with cost 0.3769129759077353 because of vanishing difference
# Final cost : 0.3769129759077353
# Compute control for a deterministic system
# Cost in iteration 0: 0.3769129759077353
# Converged in iteration 15 with cost 0.37691297590764794 because of step counter
# Final cost : 0.37691297590764794
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.3573257204263826
# Cost in iteration 200: 0.35620194313330866
# Final cost : 0.35620194313330866
# Compute control for a deterministic system
# Cost in iteration 0: 0.35620194313330866
# Cost in iteration 200: 0.3562018692345608
# Final cost : 0.3562018692345608
# Compute control for a deterministic system
# Cost in iteration 0: 0.3562018692345608
# Converged in iteration 190 with cost 0.35620186920349967 because of step counter
# Final cost : 0.35620186920349967
# Compute control for a deterministic system
# Cost in iteration 0: 0.35620186920349967
# Converged in iteration 1 with cost 0.35620186920349967 because of step counter
# Final cost : 0.35620186920349967
# Compute control for a deterministic system
# Cost in iteration 0: 0.35620186920349967
# Converged in iteration 1 with cost 0.35620186920349967 because of step counter
# Final cost : 0.35620186920349967
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.3296424581573614
# Cost in iteration 200: 0.3286762732994236
# Final cost : 0.3286762732994236
# Compute control for a deterministic system
# Cost in iteration 0: 0.3286762732994236
# Cost in iteration 200: 0.3286762160515469
# Final cost : 0.3286762160515469
# Compute control for a deterministic system
# Cost in iteration 0: 0.3286762160515469
# Converged in iteration 162 with cost 0.328676216036586 because of vanishing difference
# Final cost : 0.328676216036586
# Compute control for a deterministic system
# Cost in iteration 0: 0.328676216036586
# Converged in iteration 2 with cost 0.32867621603658587 because of vanishing difference
# Final cost : 0.32867621603658587
# Compute control for a deterministic system
# Cost in iteration 0: 0.32867621603658587
# Converged in iteration 7 with cost 0.32867621603654834 because of step counter
# Final cost : 0.32867621603654834
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.30211451728189503
# Cost in iteration 200: 0.3012877749395372
# Final cost : 0.3012877749395372
# Compute control for a deterministic system
# Cost in iteration 0: 0.3012877749395372
# Cost in iteration 200: 0.30128773210453996
# Final cost : 0.30128773210453996
# Compute control for a deterministic system
# Cost in iteration 0: 0.30128773210453996
# Converged in iteration 136 with cost 0.3012877320985768 because of step counter
# Final cost : 0.3012877320985768
# Compute control for a deterministic system
# Cost in iteration 0: 0.3012877320985768
# Converged in iteration 10 with cost 0.3012877320985646 because of step counter
# Final cost : 0.3012877320985646
# Compute control for a deterministic system
# Cost in iteration 0: 0.3012877320985646
# Converged in iteration 2 with cost 0.30128773209856374 because of step counter
# Final cost : 0.30128773209856374
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.2747530929380067
# Cost in iteration 200: 0.2740553354025894
# Final cost : 0.2740553354025894
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740553354025894
# Cost in iteration 200: 0.27405530445006204
# Final cost : 0.27405530445006204
# Compute control for a deterministic system
# Cost in iteration 0: 0.27405530445006204
# Converged in iteration 110 with cost 0.27405530444791226 because of vanishing difference
# Final cost : 0.27405530444791226
# Compute control for a deterministic system
# Cost in iteration 0: 0.27405530444791226
# Converged in iteration 5 with cost 0.2740553044479084 because of step counter
# Final cost : 0.2740553044479084
# Compute control for a deterministic system
# Cost in iteration 0: 0.2740553044479084
# Converged in iteration 1 with cost 0.2740553044479084 because of step counter
# Final cost : 0.2740553044479084
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.24755496883452704
# Cost in iteration 200: 0.24697945684655423
# Final cost : 0.24697945684655423
# Compute control for a deterministic system
# Cost in iteration 0: 0.24697945684655423
# Cost in iteration 200: 0.24697943534539674
# Final cost : 0.24697943534539674
# Compute control for a deterministic system
# Cost in iteration 0: 0.24697943534539674
# Converged in iteration 15 with cost 0.2469794353451345 because of vanishing difference
# Final cost : 0.2469794353451345
# Compute control for a deterministic system
# Cost in iteration 0: 0.2469794353451345
# Converged in iteration 54 with cost 0.24697943534490746 because of step counter
# Final cost : 0.24697943534490746
# Compute control for a deterministic system
# Cost in iteration 0: 0.24697943534490746
# Converged in iteration 2 with cost 0.24697943534490743 because of step counter
# Final cost : 0.24697943534490743
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.22051293369895214
# Cost in iteration 200: 0.22005138919148043
# Final cost : 0.22005138919148043
# Compute control for a deterministic system
# Cost in iteration 0: 0.22005138919148043
# Cost in iteration 200: 0.22005137503531655
# Final cost : 0.22005137503531655
# Compute control for a deterministic system
# Cost in iteration 0: 0.22005137503531655
# Converged in iteration 30 with cost 0.2200513750352591 because of step counter
# Final cost : 0.2200513750352591
# Compute control for a deterministic system
# Cost in iteration 0: 0.2200513750352591
# Converged in iteration 1 with cost 0.2200513750352591 because of step counter
# Final cost : 0.2200513750352591
# Compute control for a deterministic system
# Cost in iteration 0: 0.2200513750352591
# Converged in iteration 3 with cost 0.22005137503525846 because of step counter
# Final cost : 0.22005137503525846
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.20032870709479766
# Cost in iteration 200: 0.199945777612958
# Final cost : 0.199945777612958
# Compute control for a deterministic system
# Cost in iteration 0: 0.199945777612958
# Converged in iteration 197 with cost 0.19994576775296247 because of step counter
# Final cost : 0.19994576775296247
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994576775296247
# Converged in iteration 1 with cost 0.19994576775296247 because of step counter
# Final cost : 0.19994576775296247
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994576775296247
# Converged in iteration 1 with cost 0.19994576775296247 because of step counter
# Final cost : 0.19994576775296247
# Compute control for a deterministic system
# Cost in iteration 0: 0.19994576775296247
# Converged in iteration 7 with cost 0.19994576775294792 because of step counter
# Final cost : 0.19994576775294792
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.17354020370246048
# Cost in iteration 200: 0.17325162882818762
# Final cost : 0.17325162882818762
# Compute control for a deterministic system
# Cost in iteration 0: 0.17325162882818762
# Converged in iteration 158 with cost 0.17325162324535806 because of step counter
# Final cost : 0.17325162324535806
# Compute control for a deterministic system
# Cost in iteration 0: 0.17325162324535806
# Converged in iteration 6 with cost 0.1732516232453516 because of step counter
# Final cost : 0.1732516232453516
# Compute control for a deterministic system
# Cost in iteration 0: 0.1732516232453516
# Converged in iteration 1 with cost 0.1732516232453516 because of step counter
# Final cost : 0.1732516232453516
# Compute control for a deterministic system
# Cost in iteration 0: 0.1732516232453516
# Converged in iteration 2 with cost 0.17325162324535098 because of step counter
# Final cost : 0.17325162324535098
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.1468897310077289
# Cost in iteration 200: 0.1466826630327104
# Final cost : 0.1466826630327104
# Compute control for a deterministic system
# Cost in iteration 0: 0.1466826630327104
# Converged in iteration 109 with cost 0.14668266031059357 because of step counter
# Final cost : 0.14668266031059357
# Compute control for a deterministic system
# Cost in iteration 0: 0.14668266031059357
# Converged in iteration 1 with cost 0.14668266031059357 because of step counter
# Final cost : 0.14668266031059357
# Compute control for a deterministic system
# Cost in iteration 0: 0.14668266031059357
# Converged in iteration 1 with cost 0.14668266031059357 because of step counter
# Final cost : 0.14668266031059357
# Compute control for a deterministic system
# Cost in iteration 0: 0.14668266031059357
# Converged in iteration 14 with cost 0.1466826603105713 because of step counter
# Final cost : 0.1466826603105713
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.12037918715769691
# Cost in iteration 200: 0.1202402797605671
# Final cost : 0.1202402797605671
# Compute control for a deterministic system
# Cost in iteration 0: 0.1202402797605671
# Converged in iteration 80 with cost 0.12024027871314336 because of step counter
# Final cost : 0.12024027871314336
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024027871314336
# Converged in iteration 7 with cost 0.12024027871313372 because of step counter
# Final cost : 0.12024027871313372
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024027871313372
# Converged in iteration 1 with cost 0.12024027871313372 because of step counter
# Final cost : 0.12024027871313372
# Compute control for a deterministic system
# Cost in iteration 0: 0.12024027871313372
# Converged in iteration 3 with cost 0.12024027871313255 because of step counter
# Final cost : 0.12024027871313255
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.09401897211425249
# Cost in iteration 200: 0.09393466171590847
# Final cost : 0.09393466171590847
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393466171590847
# Converged in iteration 54 with cost 0.0939346614532011 because of step counter
# Final cost : 0.0939346614532011
# Compute control for a deterministic system
# Cost in iteration 0: 0.0939346614532011
# Converged in iteration 7 with cost 0.09393466145319349 because of step counter
# Final cost : 0.09393466145319349
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393466145319349
# Converged in iteration 2 with cost 0.09393466145319287 because of step counter
# Final cost : 0.09393466145319287
# Compute control for a deterministic system
# Cost in iteration 0: 0.09393466145319287
# Converged in iteration 1 with cost 0.09393466145319287 because of step counter
# Final cost : 0.09393466145319287
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.07436057001759902
# Cost in iteration 200: 0.07430827293956531
# Final cost : 0.07430827293956531
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827293956531
# Converged in iteration 40 with cost 0.07430827288498273 because of step counter
# Final cost : 0.07430827288498273
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827288498273
# Converged in iteration 3 with cost 0.07430827288498053 because of step counter
# Final cost : 0.07430827288498053
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827288498053
# Converged in iteration 1 with cost 0.07430827288498053 because of step counter
# Final cost : 0.07430827288498053
# Compute control for a deterministic system
# Cost in iteration 0: 0.07430827288498053
# Converged in iteration 2 with cost 0.07430827288497995 because of step counter
# Final cost : 0.07430827288497995
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.04833007172922679
# Cost in iteration 200: 0.048308573579677994
# Final cost : 0.048308573579677994
# Compute control for a deterministic system
# Cost in iteration 0: 0.048308573579677994
# Converged in iteration 22 with cost 0.04830857357850663 because of step counter
# Final cost : 0.04830857357850663
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830857357850663
# Converged in iteration 1 with cost 0.04830857357850663 because of step counter
# Final cost : 0.04830857357850663
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830857357850663
# Converged in iteration 2 with cost 0.04830857357850661 because of step counter
# Final cost : 0.04830857357850661
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830857357850661
# Converged in iteration 1 with cost 0.04830857357850661 because of step counter
# Final cost : 0.04830857357850661
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.022570592717088188
# Converged in iteration 132 with cost 0.02256639246288413 because of step counter
# Final cost : 0.02256639246288413
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256639246288413
# Converged in iteration 5 with cost 0.022566392462879108 because of step counter
# Final cost : 0.022566392462879108
# Compute control for a deterministic system
# Cost in iteration 0: 0.022566392462879108
# Converged in iteration 1 with cost 0.022566392462879108 because of vanishing difference
# Final cost : 0.022566392462879108
# Compute control for a deterministic system
# Cost in iteration 0: 0.022566392462879108
# Converged in iteration 5 with cost 0.02256639246287713 because of step counter
# Final cost : 0.02256639246287713
# Compute control for a deterministic system
# Cost in iteration 0: 0.02256639246287713
# Converged in iteration 1 with cost 0.02256639246287713 because of step counter
# Final cost : 0.02256639246287713
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
