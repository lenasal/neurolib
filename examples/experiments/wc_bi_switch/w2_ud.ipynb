# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 1, 2, 3, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w2_ud = dict([
    ('cost_type', 'w2'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("l2_ud.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w2_ud['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w2_ud['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w2_ud['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
with open('l2_ud.pickle', 'rb') as f:
    results_w2_ud = pickle.load(f)

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 220.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    if i in [2]:
        continue

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w2_ud['d'][i] )
    setinit( results_w2_ud['u'][i] )

    #if type(results_w2_ud["control"][i]) != type(None):
    #    continue

    results_w2_ud["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w2_ud, i)

    if True:
        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w2_ud["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-300:-200] = -5.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()
        get_values(results_w2_ud, i, w1)

    for k in range(200):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)


        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)
            save(results_w2_ud)
        else: break

    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)
            save(results_w2_ud)
        else: break

    save(results_w2_ud)
# Out:
# POINT  1
# Compute control for a deterministic system
# Cost in iteration 0: 4.943715144508187
# Final cost : 4.943673112398054
# Compute control for a deterministic system
# Cost in iteration 0: 126.48981968307989
# Final cost : 18.266404017908503
# Compute control for a deterministic system
# Cost in iteration 0: 18.266404017908503
# Final cost : 2.2037343239322467
# Compute control for a deterministic system
# Cost in iteration 0: 2.2037343239322467
# Final cost : 0.16569162960837586
# Compute control for a deterministic system
# Cost in iteration 0: 0.16569162960837586
# Final cost : 0.16024834946693814
# Compute control for a deterministic system
# Cost in iteration 0: 0.16024834946693814
# Final cost : 0.15793750699014752
# Compute control for a deterministic system
# Cost in iteration 0: 0.15793750699014752
# Final cost : 0.15662014342376263
# Compute control for a deterministic system
# Cost in iteration 0: 0.15662014342376263
# Final cost : 0.15600455102784394
# Compute control for a deterministic system
# Cost in iteration 0: 0.15600455102784394
# Converged in iteration 9 with cost 0.15600451568624688 because of step counter
# Final cost : 0.15600451568624688
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.15539291351366832
# Final cost : 0.15539291351366832
# Compute control for a deterministic system
# Cost in iteration 0: 0.15539291351366832
# Final cost : 0.15512132436134266
# Compute control for a deterministic system
# Cost in iteration 0: 0.15512132436134266
# Final cost : 0.15512115426272258
# Compute control for a deterministic system
# Cost in iteration 0: 0.15512115426272258
# Converged in iteration 6 with cost 0.15512115426272088 because of vanishing difference
# Final cost : 0.15512115426272088
# Compute control for a deterministic system
# Cost in iteration 0: 0.15512115426272088
# Final cost : 0.15512115426272088
# Compute control for a deterministic system
# Cost in iteration 0: 0.15512115426272088
# Final cost : 0.15512115426272088
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.1546214287291153
# Final cost : 0.1546214287291153
# Compute control for a deterministic system
# Cost in iteration 0: 0.1546214287291153
# Final cost : 0.15447778292360903
# Compute control for a deterministic system
# Cost in iteration 0: 0.15447778292360903
# Final cost : 0.15447751849024022
# Compute control for a deterministic system
# Cost in iteration 0: 0.15447751849024022
# Converged in iteration 2 with cost 0.1544775184902398 because of vanishing difference
# Final cost : 0.1544775184902398
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544775184902398
# Final cost : 0.1544775184902398
# Compute control for a deterministic system
# Cost in iteration 0: 0.1544775184902398
# Final cost : 0.1544775184902398
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.1540493381981278
# Final cost : 0.1540493381981278
# Compute control for a deterministic system
# Cost in iteration 0: 0.1540493381981278
# Final cost : 0.1539976898760193
# Compute control for a deterministic system
# Cost in iteration 0: 0.1539976898760193
# Final cost : 0.1539973024628829
# Compute control for a deterministic system
# Cost in iteration 0: 0.1539973024628829
# Converged in iteration 21 with cost 0.15399730246288082 because of vanishing difference
# Final cost : 0.15399730246288082
# Compute control for a deterministic system
# Cost in iteration 0: 0.15399730246288082
# Final cost : 0.15399730246288068
# Compute control for a deterministic system
# Cost in iteration 0: 0.15399730246288068
# Final cost : 0.15399730246288068
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.15358530718355282
# Final cost : 0.15358530718355282
# Compute control for a deterministic system
# Cost in iteration 0: 0.15358530718355282
# Final cost : 0.1535721740410411
# Compute control for a deterministic system
# Cost in iteration 0: 0.1535721740410411
# Final cost : 0.15357183289662313
# Compute control for a deterministic system
# Cost in iteration 0: 0.15357183289662313
# Converged in iteration 18 with cost 0.15357183289662016 because of vanishing difference
# Final cost : 0.15357183289662016
# Compute control for a deterministic system
# Cost in iteration 0: 0.15357183289662016
# Final cost : 0.15357183289662016
# Compute control for a deterministic system
# Cost in iteration 0: 0.15357183289662016
# Final cost : 0.15357183289662016
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.1530280334815866
# Final cost : 0.1530280334815866
# Compute control for a deterministic system
# Cost in iteration 0: 0.1530280334815866
# Final cost : 0.1530237703935827
# Compute control for a deterministic system
# Cost in iteration 0: 0.1530237703935827
# Final cost : 0.15302349303844087
# Compute control for a deterministic system
# Cost in iteration 0: 0.15302349303844087
# Converged in iteration 6 with cost 0.1530234930384385 because of vanishing difference
# Final cost : 0.1530234930384385
# Compute control for a deterministic system
# Cost in iteration 0: 0.1530234930384385
# Converged in iteration 42 with cost 0.1530234930384385 because of vanishing difference
# Final cost : 0.1530234930384385
# Compute control for a deterministic system
# Cost in iteration 0: 0.1530234930384385
# Final cost : 0.1530234930384385
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.15256866585830248
# Final cost : 0.15256866585830248
# Compute control for a deterministic system
# Cost in iteration 0: 0.15256866585830248
# Final cost : 0.15252750050520558
# Compute control for a deterministic system
# Cost in iteration 0: 0.15252750050520558
# Final cost : 0.1525271566033528
# Compute control for a deterministic system
# Cost in iteration 0: 0.1525271566033528
# Converged in iteration 24 with cost 0.15252715660335087 because of vanishing difference
# Final cost : 0.15252715660335087
# Compute control for a deterministic system
# Cost in iteration 0: 0.15252715660335087
# Final cost : 0.15252715660335087
# Compute control for a deterministic system
# Cost in iteration 0: 0.15252715660335087
# Final cost : 0.15252715660335087
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 0.15218813688737876
# Final cost : 0.15218813688737876
# Compute control for a deterministic system
# Cost in iteration 0: 0.15218813688737876
# Final cost : 0.15211941258741463
# Compute control for a deterministic system
# Cost in iteration 0: 0.15211941258741463
# Final cost : 0.15211899326635933
# Compute control for a deterministic system
# Cost in iteration 0: 0.15211899326635933
# Converged in iteration 80 with cost 0.15211899326635125 because of vanishing difference
# Final cost : 0.15211899326635125
# Compute control for a deterministic system
# Cost in iteration 0: 0.15211899326635125
# Final cost : 0.1521189932663512
# Compute control for a deterministic system
# Cost in iteration 0: 0.1521189932663512
# Final cost : 0.1521189932663512
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 0.15187205628070052
# Final cost : 0.15187205628070052
# Compute control for a deterministic system
# Cost in iteration 0: 0.15187205628070052
# Final cost : 0.15179451995788484
# Compute control for a deterministic system
# Cost in iteration 0: 0.15179451995788484
# Final cost : 0.15179403524606824
# Compute control for a deterministic system
# Cost in iteration 0: 0.15179403524606824
# Final cost : 0.15179403524605892
# Compute control for a deterministic system
# Cost in iteration 0: 0.15179403524605892
# Final cost : 0.1517940352460588
# Compute control for a deterministic system
# Cost in iteration 0: 0.1517940352460588
# Final cost : 0.1517940352460588
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 0.15161480700461397
# Final cost : 0.15161480700461397
# Compute control for a deterministic system
# Cost in iteration 0: 0.15161480700461397
# Final cost : 0.15153996368253178
# Compute control for a deterministic system
# Cost in iteration 0: 0.15153996368253178
# Final cost : 0.1515394316988669
# Compute control for a deterministic system
# Cost in iteration 0: 0.1515394316988669
# Final cost : 0.15153943169885678
# Compute control for a deterministic system
# Cost in iteration 0: 0.15153943169885678
# Converged in iteration 11 with cost 0.15153943169885675 because of vanishing difference
# Final cost : 0.15153943169885675
# Compute control for a deterministic system
# Cost in iteration 0: 0.15153943169885675
# Final cost : 0.15153943169885675
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 0.15140784467735596
# Final cost : 0.15140784467735596
# Compute control for a deterministic system
# Cost in iteration 0: 0.15140784467735596
# Final cost : 0.15134219844032326
# Compute control for a deterministic system
# Cost in iteration 0: 0.15134219844032326
# Final cost : 0.15134163987304922
# Compute control for a deterministic system
# Cost in iteration 0: 0.15134163987304922
# Final cost : 0.15134163987303803
# Compute control for a deterministic system
# Cost in iteration 0: 0.15134163987303803
# Final cost : 0.15134163987303798
# Compute control for a deterministic system
# Cost in iteration 0: 0.15134163987303798
# Final cost : 0.15134163987303798
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 0.15124216532090964
# Final cost : 0.15124216532090964
# Compute control for a deterministic system
# Cost in iteration 0: 0.15124216532090964
# Final cost : 0.15118901955423603
# Compute control for a deterministic system
# Cost in iteration 0: 0.15118901955423603
# Final cost : 0.1511884546208332
# Compute control for a deterministic system
# Cost in iteration 0: 0.1511884546208332
# Final cost : 0.15118845462082217
# Compute control for a deterministic system
# Cost in iteration 0: 0.15118845462082217
# Converged in iteration 15 with cost 0.15118845462082217 because of vanishing difference
# Final cost : 0.15118845462082217
# Compute control for a deterministic system
# Cost in iteration 0: 0.15118845462082217
# Final cost : 0.15118845462082217
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 0.15110958599445873
# Final cost : 0.15110958599445873
# Compute control for a deterministic system
# Cost in iteration 0: 0.15110958599445873
# Final cost : 0.15107025943123928
# Compute control for a deterministic system
# Cost in iteration 0: 0.15107025943123928
# Final cost : 0.15106970521935828
# Compute control for a deterministic system
# Cost in iteration 0: 0.15106970521935828
# Converged in iteration 8 with cost 0.15106970521935614 because of vanishing difference
# Final cost : 0.15106970521935614
# Compute control for a deterministic system
# Cost in iteration 0: 0.15106970521935614
# Final cost : 0.15106970521935612
# Compute control for a deterministic system
# Cost in iteration 0: 0.15106970521935612
# Final cost : 0.15106970521935612
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 0.15100308529821874
# Final cost : 0.15100308529821874
# Compute control for a deterministic system
# Cost in iteration 0: 0.15100308529821874
# Final cost : 0.15097782026770384
# Compute control for a deterministic system
# Cost in iteration 0: 0.15097782026770384
# Final cost : 0.15097728887272932
# Compute control for a deterministic system
# Cost in iteration 0: 0.15097728887272932
# Final cost : 0.15097728887271833
# Compute control for a deterministic system
# Cost in iteration 0: 0.15097728887271833
# Converged in iteration 3 with cost 0.15097728887271833 because of vanishing difference
# Final cost : 0.15097728887271833
# Compute control for a deterministic system
# Cost in iteration 0: 0.15097728887271833
# Final cost : 0.15097728887271833
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 0.15091649241539468
# Final cost : 0.15091649241539468
# Compute control for a deterministic system
# Cost in iteration 0: 0.15091649241539468
# Final cost : 0.15090517230326936
# Compute control for a deterministic system
# Cost in iteration 0: 0.15090517230326936
# Final cost : 0.15090467080235595
# Compute control for a deterministic system
# Cost in iteration 0: 0.15090467080235595
# Final cost : 0.15090467080234818
# Compute control for a deterministic system
# Cost in iteration 0: 0.15090467080234818
# Final cost : 0.15090467080234815
# Compute control for a deterministic system
# Cost in iteration 0: 0.15090467080234815
# Final cost : 0.15090467080234815
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 0.15084288810997515
# Final cost : 0.15084288810997515
# Compute control for a deterministic system
# Cost in iteration 0: 0.15084288810997515
# Final cost : 0.15080106506016022
# Compute control for a deterministic system
# Cost in iteration 0: 0.15080106506016022
# Final cost : 0.15080069795341192
# Compute control for a deterministic system
# Cost in iteration 0: 0.15080069795341192
# Converged in iteration 23 with cost 0.1508006979534102 because of vanishing difference
# Final cost : 0.1508006979534102
# Compute control for a deterministic system
# Cost in iteration 0: 0.1508006979534102
# Final cost : 0.1508006979534102
# Compute control for a deterministic system
# Cost in iteration 0: 0.1508006979534102
# Final cost : 0.1508006979534102
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 0.15071255896958322
# Final cost : 0.15071255896958322
# Compute control for a deterministic system
# Cost in iteration 0: 0.15071255896958322
# Final cost : 0.15069974564512348
# Compute control for a deterministic system
# Cost in iteration 0: 0.15069974564512348
# Final cost : 0.15069940553335345
# Compute control for a deterministic system
# Cost in iteration 0: 0.15069940553335345
# Converged in iteration 3 with cost 0.15069940553335334 because of vanishing difference
# Final cost : 0.15069940553335334
# Compute control for a deterministic system
# Cost in iteration 0: 0.15069940553335334
# Final cost : 0.15069940553335334
# Compute control for a deterministic system
# Cost in iteration 0: 0.15069940553335334
# Final cost : 0.15069940553335334
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 0.1506334698106689
# Final cost : 0.1506334698106689
# Compute control for a deterministic system
# Cost in iteration 0: 0.1506334698106689
# Final cost : 0.15061703463366258
# Compute control for a deterministic system
# Cost in iteration 0: 0.15061703463366258
# Final cost : 0.15061671184264572
# Compute control for a deterministic system
# Cost in iteration 0: 0.15061671184264572
# Converged in iteration 12 with cost 0.15061671184264439 because of vanishing difference
# Final cost : 0.15061671184264439
# Compute control for a deterministic system
# Cost in iteration 0: 0.15061671184264439
# Converged in iteration 4 with cost 0.15061671184264439 because of vanishing difference
# Final cost : 0.15061671184264439
# Compute control for a deterministic system
# Cost in iteration 0: 0.15061671184264439
# Final cost : 0.15061671184264439
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 0.15056834944007186
# Final cost : 0.15056834944007186
# Compute control for a deterministic system
# Cost in iteration 0: 0.15056834944007186
# Final cost : 0.15055152757175078
# Compute control for a deterministic system
# Cost in iteration 0: 0.15055152757175078
# Final cost : 0.1505512171117268
# Compute control for a deterministic system
# Cost in iteration 0: 0.1505512171117268
# Converged in iteration 12 with cost 0.150551217111725 because of vanishing difference
# Final cost : 0.150551217111725
# Compute control for a deterministic system
# Cost in iteration 0: 0.150551217111725
# Final cost : 0.15055121711172498
# Compute control for a deterministic system
# Cost in iteration 0: 0.15055121711172498
# Final cost : 0.15055121711172498
# 18
# Compute control for a deterministic system
# Cost in iteration 0: 0.15051612466270115
# Final cost : 0.15051612466270115
# Compute control for a deterministic system
# Cost in iteration 0: 0.15051612466270115
# Final cost : 0.1505004879902863
# Compute control for a deterministic system
# Cost in iteration 0: 0.1505004879902863
# Final cost : 0.15050018711622792
# Compute control for a deterministic system
# Cost in iteration 0: 0.15050018711622792
# Converged in iteration 7 with cost 0.15050018711622745 because of vanishing difference
# Final cost : 0.15050018711622745
# Compute control for a deterministic system
# Cost in iteration 0: 0.15050018711622745
# Final cost : 0.15050018711622745
# Compute control for a deterministic system
# Cost in iteration 0: 0.15050018711622745
# Final cost : 0.15050018711622745
# 19
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504748168208678
# Final cost : 0.1504748168208678
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504748168208678
# Final cost : 0.1504610753788312
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504610753788312
# Final cost : 0.15046078267305915
# Compute control for a deterministic system
# Cost in iteration 0: 0.15046078267305915
# Converged in iteration 3 with cost 0.15046078267305837 because of vanishing difference
# Final cost : 0.15046078267305837
# Compute control for a deterministic system
# Cost in iteration 0: 0.15046078267305837
# Final cost : 0.15046078267305835
# Compute control for a deterministic system
# Cost in iteration 0: 0.15046078267305835
# Final cost : 0.15046078267305835
# 20
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504423557379125
# Final cost : 0.1504423557379125
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504423557379125
# Final cost : 0.15043078293448578
# Compute control for a deterministic system
# Cost in iteration 0: 0.15043078293448578
# Final cost : 0.1504304968191865
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504304968191865
# Converged in iteration 4 with cost 0.15043049681918572 because of vanishing difference
# Final cost : 0.15043049681918572
# Compute control for a deterministic system
# Cost in iteration 0: 0.15043049681918572
# Final cost : 0.15043049681918572
# Compute control for a deterministic system
# Cost in iteration 0: 0.15043049681918572
# Final cost : 0.15043049681918572
# 21
# Compute control for a deterministic system
# Cost in iteration 0: 0.15041689658256957
# Final cost : 0.15041689658256957
# Compute control for a deterministic system
# Cost in iteration 0: 0.15041689658256957
# Final cost : 0.1504080333802884
# Compute control for a deterministic system
# Cost in iteration 0: 0.1504080333802884
# Final cost : 0.15040775177676977
# Compute control for a deterministic system
# Cost in iteration 0: 0.15040775177676977
# Converged in iteration 7 with cost 0.15040775177676954 because of vanishing difference
# Final cost : 0.15040775177676954
# Compute control for a deterministic system
# Cost in iteration 0: 0.15040775177676954
# Final cost : 0.15040775177676954
# Compute control for a deterministic system
# Cost in iteration 0: 0.15040775177676954
# Final cost : 0.15040775177676954
# 22
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039738813350442
# Final cost : 0.15039738813350442
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039738813350442
# Final cost : 0.15039114449575222
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039114449575222
# Final cost : 0.15039086202633875
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039086202633875
# Converged in iteration 15 with cost 0.15039086202633742 because of vanishing difference
# Final cost : 0.15039086202633742
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039086202633742
# Final cost : 0.15039086202633742
# Compute control for a deterministic system
# Cost in iteration 0: 0.15039086202633742
# Final cost : 0.15039086202633742
# 23
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503825332526256
# Final cost : 0.1503825332526256
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503825332526256
# Final cost : 0.15037894116925393
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037894116925393
# Final cost : 0.15037865711404808
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037865711404808
# Converged in iteration 5 with cost 0.15037865711404727 because of vanishing difference
# Final cost : 0.15037865711404727
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037865711404727
# Final cost : 0.15037865711404727
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037865711404727
# Final cost : 0.15037865711404727
# 24
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037142083050853
# Final cost : 0.15037142083050853
# Compute control for a deterministic system
# Cost in iteration 0: 0.15037142083050853
# Final cost : 0.15036978903304624
# Compute control for a deterministic system
# Cost in iteration 0: 0.15036978903304624
# Final cost : 0.15036949477174955
# Compute control for a deterministic system
# Cost in iteration 0: 0.15036949477174955
# Converged in iteration 5 with cost 0.15036949477174824 because of vanishing difference
# Final cost : 0.15036949477174824
# Compute control for a deterministic system
# Cost in iteration 0: 0.15036949477174824
# Final cost : 0.15036949477174813
# Compute control for a deterministic system
# Cost in iteration 0: 0.15036949477174813
# Final cost : 0.15036949477174813
# 25
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503624751185691
# Final cost : 0.1503624751185691
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503624751185691
# Final cost : 0.15035897681821908
# Compute control for a deterministic system
# Cost in iteration 0: 0.15035897681821908
# Final cost : 0.15035871913852764
# Compute control for a deterministic system
# Cost in iteration 0: 0.15035871913852764
# Converged in iteration 11 with cost 0.1503587191385256 because of vanishing difference
# Final cost : 0.1503587191385256
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503587191385256
# Final cost : 0.15035871913852533
# Compute control for a deterministic system
# Cost in iteration 0: 0.15035871913852533
# Final cost : 0.15035871913852533
# 26
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034790334242643
# Final cost : 0.15034790334242643
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034790334242643
# Final cost : 0.15034519303485405
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034519303485405
# Final cost : 0.15034494531197395
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034494531197395
# Converged in iteration 5 with cost 0.15034494531197296 because of vanishing difference
# Final cost : 0.15034494531197296
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034494531197296
# Converged in iteration 42 with cost 0.15034494531197296 because of vanishing difference
# Final cost : 0.15034494531197296
# Compute control for a deterministic system
# Cost in iteration 0: 0.15034494531197296
# Final cost : 0.15034494531197296
# 27
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503365562584687
# Final cost : 0.1503365562584687
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503365562584687
# Final cost : 0.15033375651659467
# Compute control for a deterministic system
# Cost in iteration 0: 0.15033375651659467
# Final cost : 0.15033351049435237
# Compute control for a deterministic system
# Cost in iteration 0: 0.15033351049435237
# Converged in iteration 5 with cost 0.15033351049435198 because of vanishing difference
# Final cost : 0.15033351049435198
# Compute control for a deterministic system
# Cost in iteration 0: 0.15033351049435198
# Final cost : 0.15033351049435198
# Compute control for a deterministic system
# Cost in iteration 0: 0.15033351049435198
# Final cost : 0.15033351049435198
# 28
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032728472437984
# Final cost : 0.15032728472437984
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032728472437984
# Final cost : 0.15032544934181175
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032544934181175
# Final cost : 0.1503252042218196
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503252042218196
# Converged in iteration 15 with cost 0.15032520422181747 because of vanishing difference
# Final cost : 0.15032520422181747
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032520422181747
# Final cost : 0.15032520422181747
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032520422181747
# Final cost : 0.15032520422181747
# 29
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032065933390307
# Final cost : 0.15032065933390307
# Compute control for a deterministic system
# Cost in iteration 0: 0.15032065933390307
# Final cost : 0.1503187180227767
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503187180227767
# Final cost : 0.1503184785499232
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503184785499232
# Converged in iteration 5 with cost 0.15031847854992306 because of vanishing difference
# Final cost : 0.15031847854992306
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031847854992306
# Final cost : 0.150318478549923
# Compute control for a deterministic system
# Cost in iteration 0: 0.150318478549923
# Final cost : 0.150318478549923
# 30
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031518012650366
# Final cost : 0.15031518012650366
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031518012650366
# Final cost : 0.15031351965348175
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031351965348175
# Final cost : 0.15031328139342373
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031328139342373
# Converged in iteration 8 with cost 0.1503132813934226 because of vanishing difference
# Final cost : 0.1503132813934226
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503132813934226
# Final cost : 0.1503132813934226
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503132813934226
# Final cost : 0.1503132813934226
# 31
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031087953281666
# Final cost : 0.15031087953281666
# Compute control for a deterministic system
# Cost in iteration 0: 0.15031087953281666
# Final cost : 0.15030944105411986
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030944105411986
# Final cost : 0.15030920529882988
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030920529882988
# Converged in iteration 5 with cost 0.15030920529882913 because of vanishing difference
# Final cost : 0.15030920529882913
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030920529882913
# Final cost : 0.15030920529882907
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030920529882907
# Final cost : 0.15030920529882907
# 32
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030742864259924
# Final cost : 0.15030742864259924
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030742864259924
# Final cost : 0.15030623926351513
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030623926351513
# Final cost : 0.15030600720121262
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030600720121262
# Converged in iteration 2 with cost 0.15030600720121262 because of vanishing difference
# Final cost : 0.15030600720121262
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030600720121262
# Final cost : 0.15030600720121262
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030600720121262
# Final cost : 0.15030600720121262
# 33
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030464435922555
# Final cost : 0.15030464435922555
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030464435922555
# Final cost : 0.15030371540648427
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030371540648427
# Final cost : 0.15030352658969948
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030352658969948
# Converged in iteration 24 with cost 0.1503035265896831 because of vanishing difference
# Final cost : 0.1503035265896831
# Compute control for a deterministic system
# Cost in iteration 0: 0.1503035265896831
# Final cost : 0.15030352658968302
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030352658968302
# Final cost : 0.15030352658968302
# 34
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030245990566674
# Final cost : 0.15030245990566674
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030245990566674
# Final cost : 0.15030173775050287
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030173775050287
# Final cost : 0.15030159435181695
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030159435181695
# Converged in iteration 17 with cost 0.15030159435180795 because of vanishing difference
# Final cost : 0.15030159435180795
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030159435180795
# Final cost : 0.15030159435180776
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030159435180776
# Final cost : 0.15030159435180776
# 35
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030066137520146
# Final cost : 0.15030066137520146
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030066137520146
# Final cost : 0.15030018076100352
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030018076100352
# Final cost : 0.15030004181911757
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030004181911757
# Converged in iteration 6 with cost 0.15030004181911555 because of vanishing difference
# Final cost : 0.15030004181911555
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030004181911555
# Final cost : 0.15030004181911463
# Compute control for a deterministic system
# Cost in iteration 0: 0.15030004181911463
# Final cost : 0.15030004181911463
# 36
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029914308341155
# Final cost : 0.15029914308341155
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029914308341155
# Final cost : 0.15029840886129972
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029840886129972
# Final cost : 0.15029818198893763
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029818198893763
# Converged in iteration 6 with cost 0.15029818198893655 because of vanishing difference
# Final cost : 0.15029818198893655
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029818198893655
# Final cost : 0.15029818198893655
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029818198893655
# Final cost : 0.15029818198893655
# 37
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029672686390924
# Final cost : 0.15029672686390924
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029672686390924
# Final cost : 0.1502964365517417
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502964365517417
# Final cost : 0.15029621306029822
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029621306029822
# Converged in iteration 7 with cost 0.15029621306029625 because of vanishing difference
# Final cost : 0.15029621306029625
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029621306029625
# Final cost : 0.15029621306029625
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029621306029625
# Final cost : 0.15029621306029625
# 38
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029508886939388
# Final cost : 0.15029508886939388
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029508886939388
# Final cost : 0.15029469363253944
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029469363253944
# Final cost : 0.15029449007926016
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029449007926016
# Converged in iteration 5 with cost 0.15029449007925974 because of vanishing difference
# Final cost : 0.15029449007925974
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029449007925974
# Final cost : 0.15029449007925974
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029449007925974
# Final cost : 0.15029449007925974
# 39
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029364646902016
# Final cost : 0.15029364646902016
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029364646902016
# Final cost : 0.15029322228429473
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029322228429473
# Final cost : 0.15029309128773702
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029309128773702
# Converged in iteration 7 with cost 0.15029309128773322 because of vanishing difference
# Final cost : 0.15029309128773322
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029309128773322
# Converged in iteration 68 with cost 0.15029309128773313 because of vanishing difference
# Final cost : 0.15029309128773313
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029309128773313
# Final cost : 0.15029309128773313
# 40
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029249818468937
# Final cost : 0.15029249818468937
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029249818468937
# Final cost : 0.15029206276700902
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029206276700902
# Final cost : 0.15029201507549908
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029201507549908
# Converged in iteration 4 with cost 0.15029201507549753 because of vanishing difference
# Final cost : 0.15029201507549753
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029201507549753
# Converged in iteration 35 with cost 0.15029201507549753 because of vanishing difference
# Final cost : 0.15029201507549753
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029201507549753
# Final cost : 0.15029201507549753
# 41
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029156329407184
# Final cost : 0.15029156329407184
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029156329407184
# Final cost : 0.15029118282688547
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029118282688547
# Final cost : 0.1502911498684367
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502911498684367
# Converged in iteration 3 with cost 0.15029114986843656 because of vanishing difference
# Final cost : 0.15029114986843656
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029114986843656
# Final cost : 0.15029114986843645
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029114986843645
# Final cost : 0.15029114986843645
# 42
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502908346017806
# Final cost : 0.1502908346017806
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502908346017806
# Final cost : 0.1502904746666469
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502904746666469
# Final cost : 0.15029045313202063
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029045313202063
# Converged in iteration 8 with cost 0.15029045313201697 because of vanishing difference
# Final cost : 0.15029045313201697
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029045313201697
# Final cost : 0.15029045313201675
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029045313201675
# Final cost : 0.15029045313201675
# 43
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029022260595615
# Final cost : 0.15029022260595615
# Compute control for a deterministic system
# Cost in iteration 0: 0.15029022260595615
# Final cost : 0.15028990160261144
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028990160261144
# Final cost : 0.15028988053403805
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028988053403805
# Converged in iteration 15 with cost 0.15028988053403386 because of vanishing difference
# Final cost : 0.15028988053403386
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028988053403386
# Final cost : 0.1502898805340336
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502898805340336
# Final cost : 0.1502898805340336
# 44
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028970522529958
# Final cost : 0.15028970522529958
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028970522529958
# Final cost : 0.1502894267329614
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502894267329614
# Final cost : 0.1502894074879976
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502894074879976
# Converged in iteration 7 with cost 0.1502894074879966 because of vanishing difference
# Final cost : 0.1502894074879966
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502894074879966
# Final cost : 0.1502894074879964
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502894074879964
# Final cost : 0.1502894074879964
# 45
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502892689786436
# Final cost : 0.1502892689786436
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502892689786436
# Final cost : 0.1502890272139588
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502890272139588
# Final cost : 0.15028900870251016
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028900870251016
# Converged in iteration 5 with cost 0.1502890087025098 because of vanishing difference
# Final cost : 0.1502890087025098
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502890087025098
# Final cost : 0.1502890087025098
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502890087025098
# Final cost : 0.1502890087025098
# 46
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028888919786987
# Final cost : 0.15028888919786987
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028888919786987
# Final cost : 0.15028868495918027
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028868495918027
# Final cost : 0.15028866726839257
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028866726839257
# Converged in iteration 5 with cost 0.15028866726839243 because of vanishing difference
# Final cost : 0.15028866726839243
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028866726839243
# Final cost : 0.15028866726839243
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028866726839243
# Final cost : 0.15028866726839243
# 47
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028855657057716
# Final cost : 0.15028855657057716
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028855657057716
# Final cost : 0.15028838294199923
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028838294199923
# Final cost : 0.15028836611885324
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028836611885324
# Converged in iteration 4 with cost 0.15028836611885116 because of vanishing difference
# Final cost : 0.15028836611885116
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028836611885116
# Final cost : 0.1502883661188509
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502883661188509
# Final cost : 0.1502883661188509
# 48
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502882395971612
# Final cost : 0.1502882395971612
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502882395971612
# Final cost : 0.15028802651976123
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028802651976123
# Final cost : 0.15028798309851824
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028798309851824
# Converged in iteration 4 with cost 0.15028798309851632 because of vanishing difference
# Final cost : 0.15028798309851632
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028798309851632
# Final cost : 0.15028798309851626
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028798309851626
# Final cost : 0.15028798309851626
# 49
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502878353359828
# Final cost : 0.1502878353359828
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502878353359828
# Final cost : 0.1502876657652128
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502876657652128
# Final cost : 0.15028765026742713
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028765026742713
# Converged in iteration 34 with cost 0.15028765026739033 because of vanishing difference
# Final cost : 0.15028765026739033
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028765026739033
# Final cost : 0.15028765026739022
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028765026739022
# Final cost : 0.15028765026739022
# 50
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028754597743493
# Final cost : 0.15028754597743493
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028754597743493
# Final cost : 0.15028737059915964
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028737059915964
# Final cost : 0.15028735589515027
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028735589515027
# Converged in iteration 4 with cost 0.15028735589514863 because of vanishing difference
# Final cost : 0.15028735589514863
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028735589514863
# Final cost : 0.15028735589514847
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028735589514847
# Final cost : 0.15028735589514847
# 51
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028727718528395
# Final cost : 0.15028727718528395
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028727718528395
# Final cost : 0.15028710738356116
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028710738356116
# Final cost : 0.15028709330018342
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028709330018342
# Converged in iteration 5 with cost 0.1502870933001805 because of vanishing difference
# Final cost : 0.1502870933001805
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502870933001805
# Final cost : 0.1502870933001803
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502870933001803
# Final cost : 0.1502870933001803
# 52
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028703610691507
# Final cost : 0.15028703610691507
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028703610691507
# Final cost : 0.15028687789487008
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028687789487008
# Final cost : 0.15028686445235775
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028686445235775
# Converged in iteration 5 with cost 0.15028686445235506 because of vanishing difference
# Final cost : 0.15028686445235506
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028686445235506
# Final cost : 0.15028686445235467
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028686445235467
# Final cost : 0.15028686445235467
# 53
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028682333249888
# Final cost : 0.15028682333249888
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028682333249888
# Final cost : 0.15028667321764072
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028667321764072
# Final cost : 0.1502866603517632
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502866603517632
# Converged in iteration 4 with cost 0.1502866603517601 because of vanishing difference
# Final cost : 0.1502866603517601
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502866603517601
# Final cost : 0.15028666035175983
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028666035175983
# Final cost : 0.15028666035175983
# 54
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028663012903268
# Final cost : 0.15028663012903268
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028663012903268
# Final cost : 0.15028648089977403
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028648089977403
# Final cost : 0.15028646858034397
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028646858034397
# Converged in iteration 8 with cost 0.15028646858034275 because of vanishing difference
# Final cost : 0.15028646858034275
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028646858034275
# Converged in iteration 38 with cost 0.1502864685803427 because of vanishing difference
# Final cost : 0.1502864685803427
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502864685803427
# Final cost : 0.1502864685803427
# 55
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502864458359841
# Final cost : 0.1502864458359841
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502864458359841
# Final cost : 0.15028631511203308
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028631511203308
# Final cost : 0.15028630331819628
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028630331819628
# Converged in iteration 2 with cost 0.15028630331819517 because of vanishing difference
# Final cost : 0.15028630331819517
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028630331819517
# Final cost : 0.15028630331819515
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028630331819515
# Final cost : 0.15028630331819515
# 56
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028628540440334
# Final cost : 0.15028628540440334
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028628540440334
# Final cost : 0.15028616303791834
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028616303791834
# Final cost : 0.15028615174952376
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028615174952376
# Converged in iteration 10 with cost 0.15028615174952173 because of vanishing difference
# Final cost : 0.15028615174952173
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028615174952173
# Final cost : 0.1502861517495214
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502861517495214
# Final cost : 0.1502861517495214
# 57
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028613667927546
# Final cost : 0.15028613667927546
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028613667927546
# Final cost : 0.1502860227432061
# Compute control for a deterministic system
# Cost in iteration 0: 0.1502860227432061
# Final cost : 0.15028601193874222
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028601193874222
# Converged in iteration 5 with cost 0.15028601193874028 because of vanishing difference
# Final cost : 0.15028601193874028
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028601193874028
# Final cost : 0.15028601193874014
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028601193874014
# Final cost : 0.15028601193874014
# 58
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028599805529477
# Final cost : 0.15028599805529477
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028599805529477
# Final cost : 0.15028587866144696
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028587866144696
# Final cost : 0.15028586827432905
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028586827432905
# Converged in iteration 1 with cost 0.15028586827432905 because of vanishing difference
# Final cost : 0.15028586827432905
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028586827432905
# Final cost : 0.15028586827432847
# Compute control for a deterministic system
# Cost in iteration 0: 0.15028586827432847
# Final cost : 0.15028586827432847
# 59
# ...
# Cost in iteration 0: 4.904004141761017
# Converged in iteration 1 with cost 4.904004141761017 because of vanishing difference
# Final cost : 4.904004141761017
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004141761017
# Final cost : 4.904004141760981
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004141760981
# Final cost : 4.904004141760981
# 85
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414176094
# Final cost : 4.90400414176094
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414176094
# Converged in iteration 27 with cost 4.904004141757991 because of vanishing difference
# Final cost : 4.904004141757991
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004141757991
# Converged in iteration 31 with cost 4.904004140883837 because of vanishing difference
# Final cost : 4.904004140883837
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883837
# Converged in iteration 1 with cost 4.904004140883837 because of vanishing difference
# Final cost : 4.904004140883837
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883837
# Final cost : 4.904004140883832
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883832
# Final cost : 4.904004140883832
# 86
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414088381
# Final cost : 4.90400414088381
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414088381
# Converged in iteration 10 with cost 4.904004140883603 because of step counter
# Final cost : 4.904004140883603
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883603
# Converged in iteration 1 with cost 4.904004140883603 because of vanishing difference
# Final cost : 4.904004140883603
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883603
# Converged in iteration 1 with cost 4.904004140883603 because of vanishing difference
# Final cost : 4.904004140883603
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883603
# Final cost : 4.904004140883603
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004140883603
# Final cost : 4.904004140883603
# 87
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414088359
# Final cost : 4.90400414088359
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400414088359
# Converged in iteration 16 with cost 4.9040041375213494 because of step counter
# Final cost : 4.9040041375213494
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040041375213494
# Converged in iteration 10 with cost 4.904004137520463 because of vanishing difference
# Final cost : 4.904004137520463
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004137520463
# Converged in iteration 1 with cost 4.904004137520463 because of vanishing difference
# Final cost : 4.904004137520463
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004137520463
# Final cost : 4.9040041375204595
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040041375204595
# Final cost : 4.9040041375204595
# 88
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004137520449
# Final cost : 4.904004137520449
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004137520449
# Converged in iteration 11 with cost 4.904004134717765 because of step counter
# Final cost : 4.904004134717765
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004134717765
# Converged in iteration 4 with cost 4.904004134566665 because of vanishing difference
# Final cost : 4.904004134566665
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004134566665
# Converged in iteration 13 with cost 4.904004134467365 because of vanishing difference
# Final cost : 4.904004134467365
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004134467365
# Final cost : 4.904004134467361
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004134467361
# Final cost : 4.904004134467361
# 89
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400413446735
# Final cost : 4.90400413446735
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400413446735
# Converged in iteration 30 with cost 4.904004127459634 because of step counter
# Final cost : 4.904004127459634
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459634
# Converged in iteration 3 with cost 4.904004127459598 because of vanishing difference
# Final cost : 4.904004127459598
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459598
# Converged in iteration 2 with cost 4.904004127459584 because of vanishing difference
# Final cost : 4.904004127459584
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459584
# Final cost : 4.9040041274595705
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040041274595705
# Final cost : 4.9040041274595705
# 90
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459558
# Final cost : 4.904004127459558
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459558
# Converged in iteration 11 with cost 4.904004127459434 because of step counter
# Final cost : 4.904004127459434
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004127459434
# Converged in iteration 36 with cost 4.904004126835927 because of vanishing difference
# Final cost : 4.904004126835927
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004126835927
# Converged in iteration 1 with cost 4.904004126835927 because of vanishing difference
# Final cost : 4.904004126835927
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004126835927
# Final cost : 4.904004126835921
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004126835921
# Final cost : 4.904004126835921
# 91
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004126835912
# Final cost : 4.904004126835912
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004126835912
# Converged in iteration 19 with cost 4.904004118845785 because of vanishing difference
# Final cost : 4.904004118845785
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004118845785
# Converged in iteration 182 with cost 4.904004115151001 because of vanishing difference
# Final cost : 4.904004115151001
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004115151001
# Converged in iteration 1 with cost 4.904004115151001 because of vanishing difference
# Final cost : 4.904004115151001
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004115151001
# Converged in iteration 4 with cost 4.904004115150999 because of vanishing difference
# Final cost : 4.904004115150999
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004115150999
# Final cost : 4.904004115150999
# 92
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004115150991
# Final cost : 4.904004115150991
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004115150991
# Converged in iteration 13 with cost 4.9040041123473515 because of vanishing difference
# Final cost : 4.9040041123473515
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040041123473515
# Converged in iteration 15 with cost 4.904004112099507 because of vanishing difference
# Final cost : 4.904004112099507
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099507
# Converged in iteration 1 with cost 4.904004112099507 because of vanishing difference
# Final cost : 4.904004112099507
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099507
# Final cost : 4.904004112099502
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099502
# Final cost : 4.904004112099502
# 93
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Final cost : 4.904004112099498
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Converged in iteration 1 with cost 4.904004112099498 because of step counter
# Final cost : 4.904004112099498
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Converged in iteration 1 with cost 4.904004112099498 because of vanishing difference
# Final cost : 4.904004112099498
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Converged in iteration 1 with cost 4.904004112099498 because of vanishing difference
# Final cost : 4.904004112099498
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Converged in iteration 1 with cost 4.904004112099498 because of vanishing difference
# Final cost : 4.904004112099498
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099498
# Final cost : 4.904004112099498
# 94
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099497
# Final cost : 4.904004112099497
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099497
# Converged in iteration 1 with cost 4.904004112099497 because of step counter
# Final cost : 4.904004112099497
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099497
# Converged in iteration 2 with cost 4.904004112099496 because of vanishing difference
# Final cost : 4.904004112099496
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099496
# Converged in iteration 1 with cost 4.904004112099496 because of vanishing difference
# Final cost : 4.904004112099496
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099496
# Converged in iteration 9 with cost 4.9040041120994955 because of vanishing difference
# Final cost : 4.9040041120994955
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040041120994955
# Final cost : 4.904004112099495
# 95
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099495
# Final cost : 4.904004112099495
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099495
# Converged in iteration 1 with cost 4.904004112099495 because of step counter
# Final cost : 4.904004112099495
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004112099495
# Converged in iteration 14 with cost 4.904004111824553 because of step counter
# Final cost : 4.904004111824553
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824553
# Converged in iteration 1 with cost 4.904004111824553 because of vanishing difference
# Final cost : 4.904004111824553
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824553
# Converged in iteration 1 with cost 4.904004111824553 because of vanishing difference
# Final cost : 4.904004111824553
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824553
# Final cost : 4.90400411182455
# 96
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Final cost : 4.90400411182455
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Converged in iteration 1 with cost 4.90400411182455 because of step counter
# Final cost : 4.90400411182455
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Converged in iteration 1 with cost 4.90400411182455 because of step counter
# Final cost : 4.90400411182455
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Converged in iteration 1 with cost 4.90400411182455 because of vanishing difference
# Final cost : 4.90400411182455
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Converged in iteration 1 with cost 4.90400411182455 because of vanishing difference
# Final cost : 4.90400411182455
# Compute control for a deterministic system
# Cost in iteration 0: 4.90400411182455
# Final cost : 4.904004111824547
# 97
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Final cost : 4.904004111824547
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Converged in iteration 1 with cost 4.904004111824547 because of step counter
# Final cost : 4.904004111824547
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Converged in iteration 1 with cost 4.904004111824547 because of step counter
# Final cost : 4.904004111824547
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Converged in iteration 1 with cost 4.904004111824547 because of vanishing difference
# Final cost : 4.904004111824547
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Converged in iteration 1 with cost 4.904004111824547 because of vanishing difference
# Final cost : 4.904004111824547
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824547
# Final cost : 4.9040041118245465
# 98
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546
# 99
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of step counter
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Converged in iteration 1 with cost 4.904004111824546 because of vanishing difference
# Final cost : 4.904004111824546
# Compute control for a deterministic system
# Cost in iteration 0: 4.904004111824546
# Final cost : 4.904004111824546

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)
    if i not in [3]:
        continue
    print(results_w2_ud["cost"][i], results_w2_ud["initial_cost"][i])
    plt.plot(results_w2_ud["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w2_ud["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w2_ud["control"][i][0,0,:], color="red")
    plt.plot(results_w2_ud["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# POINT  2
# POINT  3
# POINT  4
# 0.14353439987751276 2.7329776604176903
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# POINT  9
# POINT  10
