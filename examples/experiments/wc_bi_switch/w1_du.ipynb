# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc


# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w1_du = dict([
    ('cost_type', 'w1'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("w1_du.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("w1_du.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], 
    [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w1_du['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w1_du['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
results_w1_du = read()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 results_w1_du = read()
#
# Cell In [11], line 29, in read()
#      27 def read():
#      28     filehandler = open("w1_du.pickle","rb")
# ---> 29     results_dict = pickle.load(filehandler)
#      30     filehandler.close()
#      32     return results_dict
#
# EOFError: Ran out of input

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 200.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    #if results_w1_du["cost"][i] < 2.:
    #    continue

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    if type(results_w1_du["control"][i]) != type(None):
        continue

    #results_w1_du["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    wc_controlled.step = 1e-3
    wc_controlled.optimize(1)

    results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

    wc_controlled.control[0,0,-300:-200] = 5.
    wc_controlled.update_input()

    wc_controlled.step = 1e-2
    wc_controlled.optimize(100)

    increase_step_compute()

    ce = wc_controlled.cost_history[-1]
    control_e = wc_controlled.control.copy()

    wc_controlled.control[0,0,:] = 0.
    wc_controlled.control[0,1,-300:-200] = -5.
    wc_controlled.update_input()

    wc_controlled.step = 1e-2
    wc_controlled.optimize(100)

    increase_step_compute()

    ci = wc_controlled.cost_history[-1]

    if ce <= ci:
        wc_controlled.control = control_e.copy()
        wc_controlled.update_input()

    wc_controlled.optimize(0)    
    get_values(results_w1_du, i, w1)    

    for k in range(10):
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-100] = wc_controlled.control[0,:,100:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()

        wc_controlled.step = 10**(-(k))
        wc_controlled.step_factor *= 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)

    wc_controlled.step = 10**(-10)

    if i == 2:
        for k in range(3):
            c0 = np.zeros((wc_controlled.control.shape))
            c0[0,:,:-10] = wc_controlled.control[0,:,10:]
            wc_controlled.control = c0.copy()
            wc_controlled.update_input()

            wc_controlled.optimize(100)

            decrease_step_compute()

            if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
                print("--------")
                get_values(results_w1_du, i, w1)

    save(results_w1_du)
# Out:
# POINT  1
# Compute control for a deterministic system
# Cost in iteration 0: 2.4780218055998215
# Converged in iteration 1 with cost 2.4780218055998215 because of step counter
# Final cost : 2.4780218055998215
# Compute control for a deterministic system
# Cost in iteration 0: 15.811815347937504
# Final cost : 14.811814645313165
# Compute control for a deterministic system
# Cost in iteration 0: 14.811814645313165
# Final cost : 12.811812802220631
# Compute control for a deterministic system
# Cost in iteration 0: 12.811812802220631
# Final cost : 1.3154772546187101
# Compute control for a deterministic system
# Cost in iteration 0: 1.3154772546187101
# Final cost : 1.0032094831098088
# Compute control for a deterministic system
# Cost in iteration 0: 1.0032094831098088
# Final cost : 1.0003603416119973
# Compute control for a deterministic system
# Cost in iteration 0: 1.0003603416119973
# Converged in iteration 1 with cost 1.0003603416119973 because of step counter
# Final cost : 1.0003603416119973
# Compute control for a deterministic system
# Cost in iteration 0: 15.81957187191601
# Final cost : 14.81352053507812
# Compute control for a deterministic system
# Cost in iteration 0: 14.81352053507812
# Final cost : 12.807122799449548
# Compute control for a deterministic system
# Cost in iteration 0: 12.807122799449548
# Final cost : 1.1159444887191117
# Compute control for a deterministic system
# Cost in iteration 0: 1.1159444887191117
# Final cost : 1.0772527353870955
# Compute control for a deterministic system
# Cost in iteration 0: 1.0772527353870955
# Final cost : 1.0589590464036598
# Compute control for a deterministic system
# Cost in iteration 0: 1.0589590464036598
# Converged in iteration 1 with cost 1.0589590464036598 because of step counter
# Final cost : 1.0589590464036598
# Compute control for a deterministic system
# Cost in iteration 0: 1.0003603416119973
# Final cost : 1.0003603416119973
# Compute control for a deterministic system
# Cost in iteration 0: 0.9986352293279435
# Final cost : 0.9972245235379291
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972245235379291
# Final cost : 0.9972243375312554
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972243375312554
# Final cost : 0.9972243170519649
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970653321037277
# Final cost : 0.9968580723398526
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968580723398526
# Final cost : 0.9968579464080303
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968579464080303
# Final cost : 0.9968579213895303
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968436445193877
# Final cost : 0.996822680533162
# Compute control for a deterministic system
# Cost in iteration 0: 0.996822680533162
# Final cost : 0.9968226762835781
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968226762835781
# Final cost : 0.996822667960324
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968214075460198
# Final cost : 0.996819509604028
# Compute control for a deterministic system
# Cost in iteration 0: 0.996819509604028
# Final cost : 0.9968195092740137
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968195092740137
# Final cost : 0.9968195082848558
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968193987930719
# Final cost : 0.9968192308363053
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192308363053
# Final cost : 0.9968192308010942
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192308010942
# Final cost : 0.996819230692912
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192211773887
# Final cost : 0.9968192064501392
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192064501392
# Final cost : 0.9968192064033099
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192064033099
# Final cost : 0.996819206399242
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192055662758
# Converged in iteration 55 with cost 0.9968192042847547 because of vanishing difference
# Final cost : 0.9968192042847547
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192042847547
# Converged in iteration 1 with cost 0.9968192042847547 because of vanishing difference
# Final cost : 0.9968192042847547
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192042847547
# Converged in iteration 1 with cost 0.9968192042847547 because of vanishing difference
# Final cost : 0.9968192042847547
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192042127021
# Converged in iteration 52 with cost 0.9968192041004045 because of vanishing difference
# Final cost : 0.9968192041004045
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192041004045
# Converged in iteration 1 with cost 0.9968192041004045 because of vanishing difference
# Final cost : 0.9968192041004045
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192041004045
# Converged in iteration 1 with cost 0.9968192041004045 because of vanishing difference
# Final cost : 0.9968192041004045
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192040940188
# Final cost : 0.9968192040843458
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192040843458
# Converged in iteration 1 with cost 0.9968192040843458 because of vanishing difference
# Final cost : 0.9968192040843458
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968192040843458
# Converged in iteration 1 with cost 0.9968192040843458 because of vanishing difference
# Final cost : 0.9968192040843458
# Compute control for a deterministic system
# Cost in iteration 0: 3.474898380425319
# Final cost : 3.347070961106973
# Compute control for a deterministic system
# Cost in iteration 0: 3.347070961106973
# Final cost : 3.3258842837591955
# Compute control for a deterministic system
# Cost in iteration 0: 3.3258842837591955
# Final cost : 3.3237686608488284
# POINT  2
# Compute control for a deterministic system
# Cost in iteration 0: 2.7238804909935936
# Converged in iteration 1 with cost 2.7238804909935936 because of step counter
# Final cost : 2.7238804909935936
# Compute control for a deterministic system
# Cost in iteration 0: 15.811819991567575
# Final cost : 14.811819277800442
# Compute control for a deterministic system
# Cost in iteration 0: 14.811819277800442
# Final cost : 12.81181741535339
# Compute control for a deterministic system
# Cost in iteration 0: 12.81181741535339
# Final cost : 1.7318908591632678
# Compute control for a deterministic system
# Cost in iteration 0: 1.7318908591632678
# Final cost : 1.5150561672330767
# Compute control for a deterministic system
# Cost in iteration 0: 1.5150561672330767
# Final cost : 1.5125813244665856
# Compute control for a deterministic system
# Cost in iteration 0: 1.5125813244665856
# Converged in iteration 1 with cost 1.5125813244665856 because of step counter
# Final cost : 1.5125813244665856
# Compute control for a deterministic system
# Cost in iteration 0: 15.816264618944956
# Final cost : 14.812597671105443
# Compute control for a deterministic system
# Cost in iteration 0: 14.812597671105443
# Final cost : 12.808912004287434
# Compute control for a deterministic system
# Cost in iteration 0: 12.808912004287434
# Final cost : 1.7758907492934173
# Compute control for a deterministic system
# Cost in iteration 0: 1.7758907492934173
# Final cost : 1.693614710218601
# Compute control for a deterministic system
# Cost in iteration 0: 1.693614710218601
# Final cost : 1.6636011168669647
# Compute control for a deterministic system
# Cost in iteration 0: 1.6636011168669647
# Converged in iteration 1 with cost 1.6636011168669647 because of step counter
# Final cost : 1.6636011168669647
# Compute control for a deterministic system
# Cost in iteration 0: 1.5125813244665856
# Final cost : 1.5125813244665856
# Compute control for a deterministic system
# Cost in iteration 0: 1.510958516008046
# Final cost : 1.5091637914755087
# Compute control for a deterministic system
# Cost in iteration 0: 1.5091637914755087
# Final cost : 1.5091605023752934
# Compute control for a deterministic system
# Cost in iteration 0: 1.5091605023752934
# Final cost : 1.5091600497472528
# Compute control for a deterministic system
# Cost in iteration 0: 1.509000593197181
# Final cost : 1.508792667072376
# Compute control for a deterministic system
# Cost in iteration 0: 1.508792667072376
# Final cost : 1.5087911564989593
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087911564989593
# Final cost : 1.5087908342729675
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087761595245863
# Final cost : 1.508754637263542
# Compute control for a deterministic system
# Cost in iteration 0: 1.508754637263542
# Final cost : 1.5087545828780962
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087545828780962
# Final cost : 1.508754496942024
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087531254372022
# Final cost : 1.5087501882380487
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087501882380487
# Final cost : 1.5087501829959584
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087501829959584
# Final cost : 1.508750161071167
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087500451938138
# Final cost : 1.5087498623335698
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498623335698
# Final cost : 1.5087498617472472
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498617472472
# Final cost : 1.5087498572405529
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498466966873
# Final cost : 1.5087498305142273
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498305142273
# Final cost : 1.5087498303629563
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498303629563
# Final cost : 1.5087498303143525
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498293916104
# Final cost : 1.5087498279281921
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498279281921
# Final cost : 1.508749827926174
# Compute control for a deterministic system
# Cost in iteration 0: 1.508749827926174
# Final cost : 1.5087498279240779
# Compute control for a deterministic system
# Cost in iteration 0: 1.508749827838671
# Final cost : 1.5087498276525315
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498276525315
# Converged in iteration 89 with cost 1.5087498276524793 because of vanishing difference
# Final cost : 1.5087498276524793
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498276524793
# Converged in iteration 8 with cost 1.5087498276524793 because of vanishing difference
# Final cost : 1.5087498276524793
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498276450328
# Final cost : 1.5087498276334743
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498276334743
# Converged in iteration 3 with cost 1.5087498276334743 because of vanishing difference
# Final cost : 1.5087498276334743
# Compute control for a deterministic system
# Cost in iteration 0: 1.5087498276334743
# Converged in iteration 3 with cost 1.5087498276334743 because of vanishing difference
# Final cost : 1.5087498276334743
# Compute control for a deterministic system
# Cost in iteration 0: 1.508749827632825
# Final cost : 1.508749827631778
# Compute control for a deterministic system
# Cost in iteration 0: 1.508749827631778
# Converged in iteration 9 with cost 1.508749827631778 because of vanishing difference
# Final cost : 1.508749827631778
# Compute control for a deterministic system
# Cost in iteration 0: 1.508749827631778
# Converged in iteration 5 with cost 1.508749827631778 because of vanishing difference
# Final cost : 1.508749827631778
# POINT  3
# POINT  4
# Compute control for a deterministic system
# Cost in iteration 0: 2.7329776604176903
# Converged in iteration 1 with cost 2.7329776604176903 because of step counter
# Final cost : 2.7329776604176903
# Compute control for a deterministic system
# Cost in iteration 0: 15.811821790248596
# Final cost : 14.81182105955769
# Compute control for a deterministic system
# Cost in iteration 0: 14.81182105955769
# Final cost : 12.811819142896933
# Compute control for a deterministic system
# Cost in iteration 0: 12.811819142896933
# Final cost : 3.0931697585063374
# Compute control for a deterministic system
# Cost in iteration 0: 3.0931697585063374
# Final cost : 2.6840604076994232
# Compute control for a deterministic system
# Cost in iteration 0: 2.6840604076994232
# Final cost : 2.653317101364117
# Compute control for a deterministic system
# Cost in iteration 0: 2.653317101364117
# Converged in iteration 1 with cost 2.653317101364117 because of step counter
# Final cost : 2.653317101364117
# Compute control for a deterministic system
# Cost in iteration 0: 15.813487910405126
# Final cost : 14.812143146741723
# Compute control for a deterministic system
# Cost in iteration 0: 14.812143146741723
# Final cost : 12.810777208189124
# Compute control for a deterministic system
# Cost in iteration 0: 12.810777208189124
# Final cost : 3.4335490460871987
# Compute control for a deterministic system
# Cost in iteration 0: 3.4335490460871987
# Final cost : 3.194237660225981
# Compute control for a deterministic system
# Cost in iteration 0: 3.194237660225981
# Final cost : 3.059917041001435
# Compute control for a deterministic system
# Cost in iteration 0: 3.059917041001435
# Converged in iteration 1 with cost 3.059917041001435 because of step counter
# Final cost : 3.059917041001435
# Compute control for a deterministic system
# Cost in iteration 0: 2.653317101364117
# Final cost : 2.653317101364117
# Compute control for a deterministic system
# Cost in iteration 0: 2.6514285734816307
# Final cost : 2.648587068597897
# Compute control for a deterministic system
# Cost in iteration 0: 2.648587068597897
# Final cost : 2.6485780091823528
# Compute control for a deterministic system
# Cost in iteration 0: 2.6485780091823528
# Final cost : 2.6485771223992294
# Compute control for a deterministic system
# Cost in iteration 0: 2.648397294439462
# Final cost : 2.6481327025220187
# Compute control for a deterministic system
# Cost in iteration 0: 2.6481327025220187
# Final cost : 2.648127357253516
# Compute control for a deterministic system
# Cost in iteration 0: 2.648127357253516
# Final cost : 2.648126561878104
# Compute control for a deterministic system
# Cost in iteration 0: 2.6481096582195156
# Final cost : 2.6480850717987057
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480850717987057
# Final cost : 2.6480848739553866
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480848739553866
# Final cost : 2.6480847158942082
# Compute control for a deterministic system
# Cost in iteration 0: 2.648083203080125
# Final cost : 2.6480808104480014
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480808104480014
# Final cost : 2.648080794816979
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080794816979
# Final cost : 2.6480805843510167
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080444010879
# Final cost : 2.648080225949726
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080225949726
# Final cost : 2.648080223616071
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080223616071
# Final cost : 2.648080217132006
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080204179478
# Final cost : 2.6480801844538795
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801844538795
# Final cost : 2.6480801842998285
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801842998285
# Final cost : 2.6480801841892427
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801830568392
# Final cost : 2.64808018120675
# Compute control for a deterministic system
# Cost in iteration 0: 2.64808018120675
# Final cost : 2.64808018119436
# Compute control for a deterministic system
# Cost in iteration 0: 2.64808018119436
# Final cost : 2.6480801811793055
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801810771544
# Final cost : 2.648080180905241
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080180905241
# Final cost : 2.6480801809051533
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801809051533
# Final cost : 2.6480801809051533
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801808955228
# Final cost : 2.648080180880479
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080180880479
# Converged in iteration 1 with cost 2.648080180880479 because of vanishing difference
# Final cost : 2.648080180880479
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080180880479
# Converged in iteration 1 with cost 2.648080180880479 because of vanishing difference
# Final cost : 2.648080180880479
# Compute control for a deterministic system
# Cost in iteration 0: 2.648080180879604
# Final cost : 2.6480801808782304
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801808782304
# Converged in iteration 85 with cost 2.6480801808782304 because of vanishing difference
# Final cost : 2.6480801808782304
# Compute control for a deterministic system
# Cost in iteration 0: 2.6480801808782304
# Converged in iteration 5 with cost 2.6480801808782304 because of vanishing difference
# Final cost : 2.6480801808782304
# POINT  5
# Compute control for a deterministic system
# Cost in iteration 0: 2.5246808324957213
# Converged in iteration 1 with cost 2.5246808324957213 because of step counter
# Final cost : 2.5246808324957213
# Compute control for a deterministic system
# Cost in iteration 0: 15.811434245622545
# Final cost : 14.811434194993009
# Compute control for a deterministic system
# Cost in iteration 0: 14.811434194993009
# Final cost : 12.81143399449845
# Compute control for a deterministic system
# Cost in iteration 0: 12.81143399449845
# Final cost : 1.2154720479165095
# Compute control for a deterministic system
# Cost in iteration 0: 1.2154720479165095
# Final cost : 1.0686193089337566
# Compute control for a deterministic system
# Cost in iteration 0: 1.0686193089337566
# Final cost : 1.0665473872450835
# Compute control for a deterministic system
# Cost in iteration 0: 1.0665473872450835
# Converged in iteration 1 with cost 1.0665473872450835 because of step counter
# Final cost : 1.0665473872450835
# Compute control for a deterministic system
# Cost in iteration 0: 15.81510726578556
# Final cost : 14.811875604278999
# Compute control for a deterministic system
# Cost in iteration 0: 14.811875604278999
# Final cost : 12.808918892584465
# Compute control for a deterministic system
# Cost in iteration 0: 12.808918892584465
# Final cost : 1.1804419595227935
# Compute control for a deterministic system
# Cost in iteration 0: 1.1804419595227935
# Final cost : 1.1521254441001105
# Compute control for a deterministic system
# Cost in iteration 0: 1.1521254441001105
# Final cost : 1.1448124489850504
# Compute control for a deterministic system
# Cost in iteration 0: 1.1448124489850504
# Converged in iteration 1 with cost 1.1448124489850504 because of step counter
# Final cost : 1.1448124489850504
# Compute control for a deterministic system
# Cost in iteration 0: 1.0665473872450835
# Final cost : 1.0665473872450835
# Compute control for a deterministic system
# Cost in iteration 0: 1.0656717278549466
# Final cost : 1.0645303238939128
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645303238939128
# Final cost : 1.0645292447456896
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645292447456896
# Final cost : 1.0645282427683134
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645214021499494
# Final cost : 1.064510773515147
# Compute control for a deterministic system
# Cost in iteration 0: 1.064510773515147
# Final cost : 1.064510501073662
# Compute control for a deterministic system
# Cost in iteration 0: 1.064510501073662
# Final cost : 1.0645103664313529
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645103037084223
# Final cost : 1.0645102250016327
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102250016327
# Final cost : 1.0645102249336145
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102249336145
# Final cost : 1.0645102248759115
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102244574223
# Converged in iteration 30 with cost 1.0645102237586193 because of vanishing difference
# Final cost : 1.0645102237586193
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237586193
# Converged in iteration 72 with cost 1.0645102237582986 because of vanishing difference
# Final cost : 1.0645102237582986
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237582986
# Converged in iteration 114 with cost 1.0645102237580872 because of vanishing difference
# Final cost : 1.0645102237580872
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237547408
# Converged in iteration 49 with cost 1.0645102237492845 because of vanishing difference
# Final cost : 1.0645102237492845
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492845
# Converged in iteration 1 with cost 1.0645102237492845 because of vanishing difference
# Final cost : 1.0645102237492845
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492845
# Converged in iteration 19 with cost 1.0645102237492838 because of vanishing difference
# Final cost : 1.0645102237492838
# Compute control for a deterministic system
# Cost in iteration 0: 1.064510223749258
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492146
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492146
# Final cost : 1.0645102237492141
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492141
# Final cost : 1.0645102237492141
# Compute control for a deterministic system
# Cost in iteration 0: 1.0645102237492141
# Final cost : 1.0645102237492141
# Compute control for a deterministic system
# Cost in iteration 0: 3.589191387579354
# Final cost : 3.2429661858168353
# Compute control for a deterministic system
# Cost in iteration 0: 3.2429661858168353
# Final cost : 3.222110267101413
# Compute control for a deterministic system
# Cost in iteration 0: 3.222110267101413
# Final cost : 3.220027376876646
# Compute control for a deterministic system
# Cost in iteration 0: 3.2205337225074793
# Final cost : 3.2205336182338486
# Compute control for a deterministic system
# Cost in iteration 0: 3.2205336182338486
# Final cost : 3.199703869880146
# Compute control for a deterministic system
# Cost in iteration 0: 3.199703869880146
# Final cost : 3.1976236876038704
# POINT  6
# Compute control for a deterministic system
# Cost in iteration 0: 2.7269764265375467
# Converged in iteration 1 with cost 2.7269764265375467 because of step counter
# Final cost : 2.7269764265375467
# Compute control for a deterministic system
# Cost in iteration 0: 15.81143423190352
# Final cost : 14.811434180829277
# Compute control for a deterministic system
# Cost in iteration 0: 14.811434180829277
# Final cost : 12.811433978470715
# Compute control for a deterministic system
# Cost in iteration 0: 12.811433978470715
# Final cost : 1.9274706792423606
# Compute control for a deterministic system
# Cost in iteration 0: 1.9274706792423606
# Final cost : 1.6128172760798476
# Compute control for a deterministic system
# Cost in iteration 0: 1.6128172760798476
# Final cost : 1.5863579165834294
# Compute control for a deterministic system
# Cost in iteration 0: 1.5863579165834294
# Converged in iteration 1 with cost 1.5863579165834294 because of step counter
# Final cost : 1.5863579165834294
# Compute control for a deterministic system
# Cost in iteration 0: 15.813365689502612
# Final cost : 14.811625506693309
# Compute control for a deterministic system
# Cost in iteration 0: 14.811625506693309
# Final cost : 12.810111007023307
# Compute control for a deterministic system
# Cost in iteration 0: 12.810111007023307
# Final cost : 1.8605046891652053
# Compute control for a deterministic system
# Cost in iteration 0: 1.8605046891652053
# Final cost : 1.76327745114534
# Compute control for a deterministic system
# Cost in iteration 0: 1.76327745114534
# Final cost : 1.7392677938237577
# Compute control for a deterministic system
# Cost in iteration 0: 1.7392677938237577
# Converged in iteration 1 with cost 1.7392677938237577 because of step counter
# Final cost : 1.7392677938237577
# Compute control for a deterministic system
# Cost in iteration 0: 1.5863579165834294
# Final cost : 1.5863579165834294
# Compute control for a deterministic system
# Cost in iteration 0: 1.5855100783139608
# Final cost : 1.5832674312928232
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832674312928232
# Final cost : 1.5832659499006958
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832659499006958
# Final cost : 1.5832645215379801
# Compute control for a deterministic system
# Cost in iteration 0: 1.58325789261271
# Final cost : 1.5832474102682887
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832474102682887
# Final cost : 1.583246645938088
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246645938088
# Final cost : 1.5832464260048726
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832463700381794
# Final cost : 1.5832462901149764
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462901149764
# Final cost : 1.5832462900205762
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462900205762
# Final cost : 1.583246289909734
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462894846806
# Converged in iteration 47 with cost 1.583246288827335 because of vanishing difference
# Final cost : 1.583246288827335
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288827335
# Final cost : 1.583246288825319
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288825319
# Final cost : 1.5832462888249714
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288821548
# Converged in iteration 32 with cost 1.5832462888163739 because of vanishing difference
# Final cost : 1.5832462888163739
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163739
# Converged in iteration 1 with cost 1.5832462888163739 because of vanishing difference
# Final cost : 1.5832462888163739
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163739
# Converged in iteration 1 with cost 1.5832462888163739 because of vanishing difference
# Final cost : 1.5832462888163739
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163465
# Final cost : 1.5832462888163072
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163072
# Final cost : 1.5832462888163072
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163072
# Final cost : 1.5832462888163072
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163072
# Final cost : 1.583246288816307
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288816307
# Final cost : 1.583246288816307
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288816307
# Final cost : 1.583246288816307
# Compute control for a deterministic system
# Cost in iteration 0: 1.583246288816307
# Converged in iteration 54 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 24 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# Compute control for a deterministic system
# Cost in iteration 0: 1.5832462888163061
# Converged in iteration 1 with cost 1.5832462888163061 because of vanishing difference
# Final cost : 1.5832462888163061
# POINT  7
# Compute control for a deterministic system
# Cost in iteration 0: 2.769577460088557
# Converged in iteration 1 with cost 2.769577460088557 because of step counter
# Final cost : 2.769577460088557
# Compute control for a deterministic system
# Cost in iteration 0: 15.811434026069843
# Final cost : 14.811433973070216
# Compute control for a deterministic system
# Cost in iteration 0: 14.811433973070216
# Final cost : 12.811433762570468
# Compute control for a deterministic system
# Cost in iteration 0: 12.811433762570468
# Final cost : 2.867689183043693
# Compute control for a deterministic system
# Cost in iteration 0: 2.867689183043693
# Final cost : 2.373046283893871
# Compute control for a deterministic system
# Cost in iteration 0: 2.373046283893871
# Converged in iteration 189 with cost 2.1694716842699644 because of vanishing difference
# Final cost : 2.1694716842699644
# Compute control for a deterministic system
# Cost in iteration 0: 2.1694716842699644
# Converged in iteration 1 with cost 2.1694716842699644 because of step counter
# Final cost : 2.1694716842699644
# Compute control for a deterministic system
# Cost in iteration 0: 15.812511250906656
# Final cost : 14.811575256282064
# Compute control for a deterministic system
# Cost in iteration 0: 14.811575256282064
# Final cost : 12.810757001704662
# Compute control for a deterministic system
# Cost in iteration 0: 12.810757001704662
# Final cost : 2.6308969208759523
# Compute control for a deterministic system
# Cost in iteration 0: 2.6308969208759523
# Final cost : 2.5223430795909905
# Compute control for a deterministic system
# Cost in iteration 0: 2.5223430795909905
# Final cost : 2.459232921301519
# Compute control for a deterministic system
# Cost in iteration 0: 2.459232921301519
# Converged in iteration 1 with cost 2.459232921301519 because of step counter
# Final cost : 2.459232921301519
# Compute control for a deterministic system
# Cost in iteration 0: 2.1694716842699644
# Final cost : 2.1694716842699644
# Compute control for a deterministic system
# Cost in iteration 0: 2.1682070094141204
# Final cost : 2.153239734558025
# Compute control for a deterministic system
# Cost in iteration 0: 2.153239734558025
# Final cost : 2.153178317060751
# Compute control for a deterministic system
# Cost in iteration 0: 2.153178317060751
# Final cost : 2.153155769500017
# Compute control for a deterministic system
# Cost in iteration 0: 2.1531490435904113
# Final cost : 2.1531348536662183
# Compute control for a deterministic system
# Cost in iteration 0: 2.1531348536662183
# Final cost : 2.153128561574279
# Compute control for a deterministic system
# Cost in iteration 0: 2.153128561574279
# Final cost : 2.1531269122698546
# Compute control for a deterministic system
# Cost in iteration 0: 2.153126844980908
# Final cost : 2.1531267398213023
# Compute control for a deterministic system
# Cost in iteration 0: 2.1531267398213023
# Final cost : 2.153126737217141
# Compute control for a deterministic system
# Cost in iteration 0: 2.153126737217141
# Final cost : 2.153126735855689
# Compute control for a deterministic system
# Cost in iteration 0: 2.1531267354008214
# Final cost : 2.1530831582001406
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530831582001406
# Final cost : 2.153077039088719
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039088719
# Final cost : 2.1530770390779908
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039073424
# Converged in iteration 59 with cost 2.1530770390674725 because of vanishing difference
# Final cost : 2.1530770390674725
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390674725
# Converged in iteration 1 with cost 2.1530770390674725 because of vanishing difference
# Final cost : 2.1530770390674725
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390674725
# Converged in iteration 38 with cost 2.15307703906741 because of vanishing difference
# Final cost : 2.15307703906741
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390673757
# Converged in iteration 31 with cost 2.1530770390673277 because of vanishing difference
# Final cost : 2.1530770390673277
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390673277
# Converged in iteration 1 with cost 2.1530770390673277 because of vanishing difference
# Final cost : 2.1530770390673277
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390673277
# Converged in iteration 1 with cost 2.1530770390673277 because of vanishing difference
# Final cost : 2.1530770390673277
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390673277
# Converged in iteration 36 with cost 2.1530770390673273 because of vanishing difference
# Final cost : 2.1530770390673273
# Compute control for a deterministic system
# Cost in iteration 0: 2.1530770390673273
# Converged in iteration 2 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 15 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 14 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 2 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# Compute control for a deterministic system
# Cost in iteration 0: 2.153077039067327
# Converged in iteration 1 with cost 2.153077039067327 because of vanishing difference
# Final cost : 2.153077039067327
# POINT  8
# Compute control for a deterministic system
# Cost in iteration 0: 2.493992239059809
# Converged in iteration 1 with cost 2.493992239059809 because of step counter
# Final cost : 2.493992239059809
# Compute control for a deterministic system
# Cost in iteration 0: 15.811398395503215
# Final cost : 14.811398384279917
# Compute control for a deterministic system
# Cost in iteration 0: 14.811398384279917
# Final cost : 12.811398337820048
# Compute control for a deterministic system
# Cost in iteration 0: 12.811398337820048
# Final cost : 1.3397705970290077
# Compute control for a deterministic system
# Cost in iteration 0: 1.3397705970290077
# Final cost : 1.1836679996999873
# Compute control for a deterministic system
# Cost in iteration 0: 1.1836679996999873
# Converged in iteration 555 with cost 1.1487270916048569 because of vanishing difference
# Final cost : 1.1487270916048569
# Compute control for a deterministic system
# Cost in iteration 0: 1.1487270916048569
# Converged in iteration 1 with cost 1.1487270916048569 because of step counter
# Final cost : 1.1487270916048569
# Compute control for a deterministic system
# Cost in iteration 0: 15.813093399238205
# Final cost : 14.81150612302522
# Compute control for a deterministic system
# Cost in iteration 0: 14.81150612302522
# Final cost : 12.810192865657987
# Compute control for a deterministic system
# Cost in iteration 0: 12.810192865657987
# Final cost : 1.272604928291145
# Compute control for a deterministic system
# Cost in iteration 0: 1.272604928291145
# Final cost : 1.242519193012181
# Compute control for a deterministic system
# Cost in iteration 0: 1.242519193012181
# Final cost : 1.2355058601024878
# Compute control for a deterministic system
# Cost in iteration 0: 1.2355058601024878
# Converged in iteration 1 with cost 1.2355058601024878 because of step counter
# Final cost : 1.2355058601024878
# Compute control for a deterministic system
# Cost in iteration 0: 1.1487270916048569
# Final cost : 1.1487270916048569
# Compute control for a deterministic system
# Cost in iteration 0: 1.1480355089122214
# Final cost : 1.1472050448184432
# Compute control for a deterministic system
# Cost in iteration 0: 1.1472050448184432
# Final cost : 1.147194062433869
# Compute control for a deterministic system
# Cost in iteration 0: 1.147194062433869
# Final cost : 1.1471920937343674
# Compute control for a deterministic system
# Cost in iteration 0: 1.1471902741316509
# Final cost : 1.146934618088074
# Compute control for a deterministic system
# Cost in iteration 0: 1.146934618088074
# Final cost : 1.1469345079662845
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469345079662845
# Final cost : 1.1469343462581985
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469343403192114
# Final cost : 1.1469343312328142
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469343312328142
# Final cost : 1.1469338838411214
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469338838411214
# Final cost : 1.1469337490593412
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490400504
# Converged in iteration 9 with cost 1.1469337490126525 because of vanishing difference
# Final cost : 1.1469337490126525
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490126525
# Converged in iteration 5 with cost 1.1469337490126517 because of vanishing difference
# Final cost : 1.1469337490126517
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490126517
# Converged in iteration 4 with cost 1.1469337490126517 because of vanishing difference
# Final cost : 1.1469337490126517
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125942
# Converged in iteration 17 with cost 1.1469337490125027 because of vanishing difference
# Final cost : 1.1469337490125027
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125027
# Converged in iteration 1 with cost 1.1469337490125027 because of vanishing difference
# Final cost : 1.1469337490125027
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125027
# Converged in iteration 4 with cost 1.1469337490125027 because of vanishing difference
# Final cost : 1.1469337490125027
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125024
# Converged in iteration 24 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 16 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 13 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469337490125022
# Converged in iteration 1 with cost 1.1469337490125022 because of vanishing difference
# Final cost : 1.1469337490125022
# Compute control for a deterministic system
# Cost in iteration 0: 3.6409259849572155
# Final cost : 1.1474573250100986
# Compute control for a deterministic system
# Cost in iteration 0: 1.1474573250100986
# Converged in iteration 46 with cost 1.1469514491462884 because of vanishing difference
# Final cost : 1.1469514491462884
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469514491462884
# Converged in iteration 1 with cost 1.1469514491462884 because of vanishing difference
# Final cost : 1.1469514491462884
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469514491462884
# Final cost : 1.1469514491462884
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469514491462884
# Final cost : 1.1469514491462884
# Compute control for a deterministic system
# Cost in iteration 0: 1.1469514491462884
# Final cost : 1.1469514491462884
# POINT  9
# Compute control for a deterministic system
# Cost in iteration 0: 2.653249494318241
# Converged in iteration 1 with cost 2.653249494318241 because of step counter
# Final cost : 2.653249494318241
# Compute control for a deterministic system
# Cost in iteration 0: 15.811398316153381
# Final cost : 14.811398304744708
# Compute control for a deterministic system
# Cost in iteration 0: 14.811398304744708
# Final cost : 12.811398257490508
# Compute control for a deterministic system
# Cost in iteration 0: 12.811398257490508
# Final cost : 1.83623199663689
# Compute control for a deterministic system
# Cost in iteration 0: 1.83623199663689
# Final cost : 1.6779379081649068
# Compute control for a deterministic system
# Cost in iteration 0: 1.6779379081649068
# Final cost : 1.6739363127224944
# Compute control for a deterministic system
# Cost in iteration 0: 1.6739363127224944
# Converged in iteration 1 with cost 1.6739363127224944 because of step counter
# Final cost : 1.6739363127224944
# Compute control for a deterministic system
# Cost in iteration 0: 15.812259481063155
# Final cost : 14.811468670781574
# Compute control for a deterministic system
# Cost in iteration 0: 14.811468670781574
# Final cost : 12.810823863693544
# Compute control for a deterministic system
# Cost in iteration 0: 12.810823863693544
# Final cost : 1.9264910681293366
# Compute control for a deterministic system
# Cost in iteration 0: 1.9264910681293366
# Final cost : 1.891074182047689
# Compute control for a deterministic system
# Cost in iteration 0: 1.891074182047689
# Final cost : 1.8644961083284914
# Compute control for a deterministic system
# Cost in iteration 0: 1.8644961083284914
# Converged in iteration 1 with cost 1.8644961083284914 because of step counter
# Final cost : 1.8644961083284914
# Compute control for a deterministic system
# Cost in iteration 0: 1.6739363127224944
# Final cost : 1.6739363127224944
# Compute control for a deterministic system
# Cost in iteration 0: 1.673317576014181
# Final cost : 1.6725490160902556
# Compute control for a deterministic system
# Cost in iteration 0: 1.6725490160902556
# Final cost : 1.6725436225200998
# Compute control for a deterministic system
# Cost in iteration 0: 1.6725436225200998
# Final cost : 1.6725416054321174
# Compute control for a deterministic system
# Cost in iteration 0: 1.672539828759202
# Final cost : 1.6721925689470103
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721925689470103
# Final cost : 1.672187154734307
# Compute control for a deterministic system
# Cost in iteration 0: 1.672187154734307
# Final cost : 1.672187020739929
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721870154678624
# Final cost : 1.6721870072686174
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721870072686174
# Final cost : 1.6721870072287417
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721870072287417
# Final cost : 1.672186973603146
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735891541
# Converged in iteration 9 with cost 1.672186973561482 because of vanishing difference
# Final cost : 1.672186973561482
# Compute control for a deterministic system
# Cost in iteration 0: 1.672186973561482
# Converged in iteration 15 with cost 1.6721869735614714 because of vanishing difference
# Final cost : 1.6721869735614714
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735614714
# Converged in iteration 2 with cost 1.6721869735614714 because of vanishing difference
# Final cost : 1.6721869735614714
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735614197
# Converged in iteration 22 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 4 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 9 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 19 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 10 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 24 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# Compute control for a deterministic system
# Cost in iteration 0: 1.6721869735613468
# Converged in iteration 1 with cost 1.6721869735613468 because of vanishing difference
# Final cost : 1.6721869735613468
# POINT  10
# Compute control for a deterministic system
# Cost in iteration 0: 2.4446766927506416
# Converged in iteration 1 with cost 2.4446766927506416 because of step counter
# Final cost : 2.4446766927506416
# Compute control for a deterministic system
# Cost in iteration 0: 15.811391051020395
# Final cost : 14.811391048282152
# Compute control for a deterministic system
# Cost in iteration 0: 14.811391048282152
# Final cost : 12.811391036848187
# Compute control for a deterministic system
# Cost in iteration 0: 12.811391036848187
# Final cost : 1.3896015156040373
# Compute control for a deterministic system
# Cost in iteration 0: 1.3896015156040373
# Final cost : 1.2251862686014259
# Compute control for a deterministic system
# Cost in iteration 0: 1.2251862686014259
# Final cost : 1.2234015930078606
# Compute control for a deterministic system
# Cost in iteration 0: 1.2234015930078606
# Converged in iteration 1 with cost 1.2234015930078606 because of step counter
# Final cost : 1.2234015930078606
# Compute control for a deterministic system
# Cost in iteration 0: 15.812132945329363
# Final cost : 14.811420907895908
# Compute control for a deterministic system
# Cost in iteration 0: 14.811420907895908
# Final cost : 12.810867116311192
# Compute control for a deterministic system
# Cost in iteration 0: 12.810867116311192
# Final cost : 1.3655181547439
# Compute control for a deterministic system
# Cost in iteration 0: 1.3655181547439
# Final cost : 1.333385944886666
# Compute control for a deterministic system
# Cost in iteration 0: 1.333385944886666
# Final cost : 1.3273672171839812
# Compute control for a deterministic system
# Cost in iteration 0: 1.3273672171839812
# Converged in iteration 3 with cost 1.3273415015368775 because of step counter
# Final cost : 1.3273415015368775
# Compute control for a deterministic system
# Cost in iteration 0: 1.2234015930078606
# Final cost : 1.2234015930078606
# Compute control for a deterministic system
# Cost in iteration 0: 1.2227946693139373
# Final cost : 1.221903236036712
# Compute control for a deterministic system
# Cost in iteration 0: 1.221903236036712
# Final cost : 1.221902781947659
# Compute control for a deterministic system
# Cost in iteration 0: 1.221902781947659
# Final cost : 1.2219021512600927
# Compute control for a deterministic system
# Cost in iteration 0: 1.2219007615308197
# Converged in iteration 50 with cost 1.2218988937034398 because of vanishing difference
# Final cost : 1.2218988937034398
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988937034398
# Final cost : 1.2218988931400179
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988931400179
# Final cost : 1.2218988926483942
# Compute control for a deterministic system
# Cost in iteration 0: 1.221898889671169
# Converged in iteration 66 with cost 1.2218988855527488 because of vanishing difference
# Final cost : 1.2218988855527488
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855527488
# Final cost : 1.2218988855516129
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855516129
# Converged in iteration 39 with cost 1.2218988855508284 because of vanishing difference
# Final cost : 1.2218988855508284
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855445523
# Converged in iteration 14 with cost 1.2218988855353197 because of vanishing difference
# Final cost : 1.2218988855353197
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855353197
# Converged in iteration 6 with cost 1.2218988855353197 because of vanishing difference
# Final cost : 1.2218988855353197
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855353197
# Converged in iteration 3 with cost 1.2218988855353197 because of vanishing difference
# Final cost : 1.2218988855353197
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855353043
# Converged in iteration 12 with cost 1.2218988855352837 because of vanishing difference
# Final cost : 1.2218988855352837
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352837
# Converged in iteration 1 with cost 1.2218988855352837 because of vanishing difference
# Final cost : 1.2218988855352837
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352837
# Converged in iteration 3 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 10 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 19 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 18 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 24 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835
# Compute control for a deterministic system
# Cost in iteration 0: 1.2218988855352835
# Converged in iteration 1 with cost 1.2218988855352835 because of vanishing difference
# Final cost : 1.2218988855352835

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)
    if i not in [2]:
        continue
    
    print(results_w1_du["cost"][i], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# POINT  2
# POINT  3
# 2.07050118772301 2.794785708126736
# POINT  4
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# POINT  9
# POINT  10
