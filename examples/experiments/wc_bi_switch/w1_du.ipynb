# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc


# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w1_du = dict([
    ('cost_type', 'w1'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("l1_du.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("l1_du.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_w1_du = read()

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], 
    [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w1_du['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w1_du['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 200.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    if i in [2]:
        continue

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    #if type(results_w2_du["control"][i]) != type(None):
    #    continue

    results_w1_du["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    if True:
        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-300:-200] = 6.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()

        ce = wc_controlled.cost_history[-1]
        control_e = wc_controlled.control.copy()

        wc_controlled.control[0,0,:] = 0.
        wc_controlled.control[0,1,-300:-200] = -6.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()

        ci = wc_controlled.cost_history[-1]

        if ce <= ci:
            wc_controlled.control = control_e.copy()
            wc_controlled.update_input()

        wc_controlled.optimize(0)    
        get_values(results_w1_du, i, w1)    


    for k in range(200):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)


        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
            save(results_w1_du)
        else: break

    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
            save(results_w1_du)
        else: break

    save(results_w1_du)
# Out:
# POINT  1
# Compute control for a deterministic system
# Cost in iteration 0: 2.4780218055998215
# Converged in iteration 1 with cost 2.4780218055998215 because of step counter
# Final cost : 2.4780218055998215
# Compute control for a deterministic system
# Cost in iteration 0: 18.974093191146505
# Final cost : 17.97409270547043
# Compute control for a deterministic system
# Cost in iteration 0: 17.97409270547043
# Final cost : 15.974091748639056
# Compute control for a deterministic system
# Cost in iteration 0: 15.974091748639056
# Final cost : 1.0078996211104738
# Compute control for a deterministic system
# Cost in iteration 0: 1.0078996211104738
# Final cost : 1.0009170992988312
# Compute control for a deterministic system
# Cost in iteration 0: 1.0009170992988312
# Final cost : 1.000331606405243
# Compute control for a deterministic system
# Cost in iteration 0: 1.000331606405243
# Converged in iteration 1 with cost 1.000331606405243 because of step counter
# Final cost : 1.000331606405243
# Compute control for a deterministic system
# Cost in iteration 0: 19.001511399234975
# Final cost : 17.98512055877922
# Compute control for a deterministic system
# Cost in iteration 0: 17.98512055877922
# Final cost : 15.963346583380513
# Compute control for a deterministic system
# Cost in iteration 0: 15.963346583380513
# Final cost : 1.106300565964488
# Compute control for a deterministic system
# Cost in iteration 0: 1.106300565964488
# Final cost : 1.0773896669126903
# Compute control for a deterministic system
# Cost in iteration 0: 1.0773896669126903
# Final cost : 1.0594492109271627
# Compute control for a deterministic system
# Cost in iteration 0: 1.0594492109271627
# Converged in iteration 1 with cost 1.0594492109271627 because of step counter
# Final cost : 1.0594492109271627
# Compute control for a deterministic system
# Cost in iteration 0: 1.000331606405243
# Final cost : 1.000331606405243
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.9997077204575647
# Final cost : 0.9997077204575647
# Compute control for a deterministic system
# Cost in iteration 0: 0.9997077204575647
# Final cost : 0.9996654986532383
# Compute control for a deterministic system
# Cost in iteration 0: 0.9996654986532383
# Final cost : 0.9996654560959857
# Compute control for a deterministic system
# Cost in iteration 0: 0.9996654560959857
# Final cost : 0.9996654560910125
# Compute control for a deterministic system
# Cost in iteration 0: 0.9996654560910125
# Converged in iteration 7 with cost 0.9996654560910079 because of vanishing difference
# Final cost : 0.9996654560910079
# Compute control for a deterministic system
# Cost in iteration 0: 0.9996654560910079
# Converged in iteration 2 with cost 0.9996654560910079 because of vanishing difference
# Final cost : 0.9996654560910079
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.9991700791749475
# Final cost : 0.9991700791749475
# Compute control for a deterministic system
# Cost in iteration 0: 0.9991700791749475
# Final cost : 0.9991323712453902
# Compute control for a deterministic system
# Cost in iteration 0: 0.9991323712453902
# Final cost : 0.999132332490719
# Compute control for a deterministic system
# Cost in iteration 0: 0.999132332490719
# Final cost : 0.9991323324857816
# Compute control for a deterministic system
# Cost in iteration 0: 0.9991323324857816
# Converged in iteration 3 with cost 0.999132332485781 because of vanishing difference
# Final cost : 0.999132332485781
# Compute control for a deterministic system
# Cost in iteration 0: 0.999132332485781
# Converged in iteration 3 with cost 0.999132332485781 because of vanishing difference
# Final cost : 0.999132332485781
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.99873431310421
# Final cost : 0.99873431310421
# Compute control for a deterministic system
# Cost in iteration 0: 0.99873431310421
# Final cost : 0.9986989972199488
# Compute control for a deterministic system
# Cost in iteration 0: 0.9986989972199488
# Final cost : 0.9986989499836485
# Compute control for a deterministic system
# Cost in iteration 0: 0.9986989499836485
# Final cost : 0.9986989499787504
# Compute control for a deterministic system
# Cost in iteration 0: 0.9986989499787504
# Converged in iteration 5 with cost 0.9986989499787495 because of vanishing difference
# Final cost : 0.9986989499787495
# Compute control for a deterministic system
# Cost in iteration 0: 0.9986989499787495
# Converged in iteration 2 with cost 0.9986989499787495 because of vanishing difference
# Final cost : 0.9986989499787495
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983769789233518
# Final cost : 0.9983769789233518
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983769789233518
# Final cost : 0.9983444780494983
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983444780494983
# Final cost : 0.9983444245627004
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983444245627004
# Final cost : 0.9983444245578411
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983444245578411
# Converged in iteration 9 with cost 0.9983444245578372 because of vanishing difference
# Final cost : 0.9983444245578372
# Compute control for a deterministic system
# Cost in iteration 0: 0.9983444245578372
# Converged in iteration 3 with cost 0.9983444245578372 because of vanishing difference
# Final cost : 0.9983444245578372
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.9980834509584496
# Final cost : 0.9980834509584496
# Compute control for a deterministic system
# Cost in iteration 0: 0.9980834509584496
# Final cost : 0.9980540500464284
# Compute control for a deterministic system
# Cost in iteration 0: 0.9980540500464284
# Final cost : 0.9980539923349637
# Compute control for a deterministic system
# Cost in iteration 0: 0.9980539923349637
# Final cost : 0.9980539923301432
# Compute control for a deterministic system
# Cost in iteration 0: 0.9980539923301432
# Converged in iteration 3 with cost 0.998053992330143 because of vanishing difference
# Final cost : 0.998053992330143
# Compute control for a deterministic system
# Cost in iteration 0: 0.998053992330143
# Converged in iteration 3 with cost 0.998053992330143 because of vanishing difference
# Final cost : 0.998053992330143
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978426073760103
# Final cost : 0.9978426073760103
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978426073760103
# Final cost : 0.9978164353420165
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978164353420165
# Final cost : 0.9978163749590206
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978163749590206
# Final cost : 0.9978163749542376
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978163749542376
# Converged in iteration 3 with cost 0.9978163749542368 because of vanishing difference
# Final cost : 0.9978163749542368
# Compute control for a deterministic system
# Cost in iteration 0: 0.9978163749542368
# Converged in iteration 3 with cost 0.9978163749542368 because of vanishing difference
# Final cost : 0.9978163749542368
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976455170904153
# Final cost : 0.9976455170904153
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976455170904153
# Final cost : 0.9976225563203682
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976225563203682
# Final cost : 0.9976224943788825
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976224943788825
# Final cost : 0.9976224943741387
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976224943741387
# Converged in iteration 3 with cost 0.9976224943741373 because of vanishing difference
# Final cost : 0.9976224943741373
# Compute control for a deterministic system
# Cost in iteration 0: 0.9976224943741373
# Converged in iteration 3 with cost 0.9976224943741373 because of vanishing difference
# Final cost : 0.9976224943741373
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 0.9974847740749895
# Final cost : 0.9974847740749895
# Compute control for a deterministic system
# Cost in iteration 0: 0.9974847740749895
# Final cost : 0.9974648881515072
# Compute control for a deterministic system
# Cost in iteration 0: 0.9974648881515072
# Final cost : 0.9974648254397688
# Compute control for a deterministic system
# Cost in iteration 0: 0.9974648254397688
# Final cost : 0.9974648254350647
# Compute control for a deterministic system
# Cost in iteration 0: 0.9974648254350647
# Converged in iteration 8 with cost 0.997464825435061 because of vanishing difference
# Final cost : 0.997464825435061
# Compute control for a deterministic system
# Cost in iteration 0: 0.997464825435061
# Converged in iteration 2 with cost 0.997464825435061 because of vanishing difference
# Final cost : 0.997464825435061
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 0.9973541436170222
# Final cost : 0.9973541436170222
# Compute control for a deterministic system
# Cost in iteration 0: 0.9973541436170222
# Final cost : 0.9973371117077201
# Compute control for a deterministic system
# Cost in iteration 0: 0.9973371117077201
# Final cost : 0.997337048799219
# Compute control for a deterministic system
# Cost in iteration 0: 0.997337048799219
# Final cost : 0.9973370487945538
# Compute control for a deterministic system
# Cost in iteration 0: 0.9973370487945538
# Converged in iteration 7 with cost 0.9973370487945508 because of vanishing difference
# Final cost : 0.9973370487945508
# Compute control for a deterministic system
# Cost in iteration 0: 0.9973370487945508
# Converged in iteration 3 with cost 0.9973370487945508 because of vanishing difference
# Final cost : 0.9973370487945508
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972483551285081
# Final cost : 0.9972483551285081
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972483551285081
# Final cost : 0.9972339053331286
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972339053331286
# Final cost : 0.9972338426656975
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972338426656975
# Final cost : 0.9972338426610696
# Compute control for a deterministic system
# Cost in iteration 0: 0.9972338426610696
# Converged in iteration 8 with cost 0.997233842661067 because of vanishing difference
# Final cost : 0.997233842661067
# Compute control for a deterministic system
# Cost in iteration 0: 0.997233842661067
# Converged in iteration 3 with cost 0.997233842661067 because of vanishing difference
# Final cost : 0.997233842661067
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971629620919261
# Final cost : 0.9971629620919261
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971629620919261
# Final cost : 0.9971507996060024
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971507996060024
# Final cost : 0.9971507375302959
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971507375302959
# Final cost : 0.9971507375257076
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971507375257076
# Converged in iteration 9 with cost 0.9971507375257034 because of vanishing difference
# Final cost : 0.9971507375257034
# Compute control for a deterministic system
# Cost in iteration 0: 0.9971507375257034
# Converged in iteration 2 with cost 0.9971507375257034 because of vanishing difference
# Final cost : 0.9971507375257034
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970942325191275
# Final cost : 0.9970942325191275
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970942325191275
# Final cost : 0.99708406109454
# Compute control for a deterministic system
# Cost in iteration 0: 0.99708406109454
# Final cost : 0.9970839999003507
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970839999003507
# Final cost : 0.9970839998957992
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970839998957992
# Converged in iteration 58 with cost 0.9970839998957776 because of vanishing difference
# Final cost : 0.9970839998957776
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970839998957776
# Converged in iteration 2 with cost 0.9970839998957776 because of vanishing difference
# Final cost : 0.9970839998957776
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970390543023658
# Final cost : 0.9970390543023658
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970390543023658
# Final cost : 0.9970305987621715
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970305987621715
# Final cost : 0.9970305340401566
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970305340401566
# Final cost : 0.9970305340356436
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970305340356436
# Converged in iteration 25 with cost 0.9970305340356344 because of vanishing difference
# Final cost : 0.9970305340356344
# Compute control for a deterministic system
# Cost in iteration 0: 0.9970305340356344
# Converged in iteration 3 with cost 0.9970305340356344 because of vanishing difference
# Final cost : 0.9970305340356344
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 0.996994852711089
# Final cost : 0.996994852711089
# Compute control for a deterministic system
# Cost in iteration 0: 0.996994852711089
# Final cost : 0.996987923815496
# Compute control for a deterministic system
# Cost in iteration 0: 0.996987923815496
# Final cost : 0.9969878616697154
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969878616697154
# Final cost : 0.9969878616668806
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969878616668806
# Converged in iteration 5 with cost 0.9969878616668792 because of vanishing difference
# Final cost : 0.9969878616668792
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969878616668792
# Converged in iteration 3 with cost 0.9969878616668792 because of vanishing difference
# Final cost : 0.9969878616668792
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969595837918451
# Final cost : 0.9969595837918451
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969595837918451
# Final cost : 0.9969539833938607
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969539833938607
# Final cost : 0.9969539235064929
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969539235064929
# Final cost : 0.9969539235055153
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969539235055153
# Converged in iteration 3 with cost 0.9969539235055149 because of vanishing difference
# Final cost : 0.9969539235055149
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969539235055149
# Converged in iteration 3 with cost 0.9969539235055149 because of vanishing difference
# Final cost : 0.9969539235055149
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 0.996931546744248
# Final cost : 0.996931546744248
# Compute control for a deterministic system
# Cost in iteration 0: 0.996931546744248
# Converged in iteration 12 with cost 0.9969273804940886 because of vanishing difference
# Final cost : 0.9969273804940886
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969273804940886
# Final cost : 0.9969272663293739
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969272663293739
# Final cost : 0.9969272663135227
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969272663135227
# Converged in iteration 20 with cost 0.9969272663135142 because of vanishing difference
# Final cost : 0.9969272663135142
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969272663135142
# Converged in iteration 2 with cost 0.9969272663135142 because of vanishing difference
# Final cost : 0.9969272663135142
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 0.996909583627688
# Final cost : 0.996909583627688
# Compute control for a deterministic system
# Cost in iteration 0: 0.996909583627688
# Final cost : 0.9969059080435957
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969059080435957
# Final cost : 0.9969058489006137
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969058489006137
# Final cost : 0.9969058488986052
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969058488986052
# Converged in iteration 2 with cost 0.9969058488986052 because of vanishing difference
# Final cost : 0.9969058488986052
# Compute control for a deterministic system
# Cost in iteration 0: 0.9969058488986052
# Converged in iteration 3 with cost 0.9969058488986052 because of vanishing difference
# Final cost : 0.9969058488986052
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968918898387009
# Final cost : 0.9968918898387009
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968918898387009
# Final cost : 0.9968889711439468
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968889711439468
# Final cost : 0.9968889118223963
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968889118223963
# Final cost : 0.996888911821726
# Compute control for a deterministic system
# Cost in iteration 0: 0.996888911821726
# Converged in iteration 7 with cost 0.9968889118217249 because of vanishing difference
# Final cost : 0.9968889118217249
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968889118217249
# Converged in iteration 3 with cost 0.9968889118217249 because of vanishing difference
# Final cost : 0.9968889118217249
# 18
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968779031142811
# Final cost : 0.9968779031142811
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968779031142811
# Final cost : 0.9968755026306436
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968755026306436
# Final cost : 0.9968754423548144
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968754423548144
# Final cost : 0.996875442353893
# Compute control for a deterministic system
# Cost in iteration 0: 0.996875442353893
# Converged in iteration 4 with cost 0.9968754423538921 because of vanishing difference
# Final cost : 0.9968754423538921
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968754423538921
# Converged in iteration 4 with cost 0.9968754423538921 because of vanishing difference
# Final cost : 0.9968754423538921
# 19
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968667675039653
# Final cost : 0.9968667675039653
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968667675039653
# Final cost : 0.9968648948206077
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968648948206077
# Final cost : 0.9968648375587233
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968648375587233
# Converged in iteration 23 with cost 0.9968648375582437 because of vanishing difference
# Final cost : 0.9968648375582437
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968648375582437
# Converged in iteration 3 with cost 0.9968648375582437 because of vanishing difference
# Final cost : 0.9968648375582437
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968648375582437
# Converged in iteration 3 with cost 0.9968648375582437 because of vanishing difference
# Final cost : 0.9968648375582437
# 20
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968580068475946
# Final cost : 0.9968580068475946
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968580068475946
# Final cost : 0.9968565345783912
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968565345783912
# Final cost : 0.9968564772876572
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968564772876572
# Final cost : 0.9968564772766757
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968564772766757
# Converged in iteration 11 with cost 0.9968564772766694 because of vanishing difference
# Final cost : 0.9968564772766694
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968564772766694
# Converged in iteration 3 with cost 0.9968564772766694 because of vanishing difference
# Final cost : 0.9968564772766694
# 21
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968511020960049
# Final cost : 0.9968511020960049
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968511020960049
# Final cost : 0.9968498371983504
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968498371983504
# Final cost : 0.9968497808102352
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968497808102352
# Final cost : 0.9968497808057797
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968497808057797
# Converged in iteration 9 with cost 0.9968497808057771 because of vanishing difference
# Final cost : 0.9968497808057771
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968497808057771
# Converged in iteration 2 with cost 0.9968497808057771 because of vanishing difference
# Final cost : 0.9968497808057771
# 22
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968455531893748
# Final cost : 0.9968455531893748
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968455531893748
# Final cost : 0.9968446152398388
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968446152398388
# Final cost : 0.9968445624946026
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968445624946026
# Final cost : 0.9968445624938977
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968445624938977
# Converged in iteration 4 with cost 0.9968445624938966 because of vanishing difference
# Final cost : 0.9968445624938966
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968445624938966
# Converged in iteration 3 with cost 0.9968445624938966 because of vanishing difference
# Final cost : 0.9968445624938966
# 23
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968412464406547
# Final cost : 0.9968412464406547
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968412464406547
# Final cost : 0.9968405066072268
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968405066072268
# Final cost : 0.9968404645161506
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968404645161506
# Final cost : 0.9968404645139123
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968404645139123
# Converged in iteration 3 with cost 0.9968404645139117 because of vanishing difference
# Final cost : 0.9968404645139117
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968404645139117
# Converged in iteration 3 with cost 0.9968404645139117 because of vanishing difference
# Final cost : 0.9968404645139117
# 24
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968378461458487
# Final cost : 0.9968378461458487
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968378461458487
# Converged in iteration 83 with cost 0.9968372794298922 because of vanishing difference
# Final cost : 0.9968372794298922
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968372794298922
# Final cost : 0.9968372474358604
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968372474358604
# Final cost : 0.9968372474349109
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968372474349109
# Converged in iteration 6 with cost 0.9968372474349099 because of vanishing difference
# Final cost : 0.9968372474349099
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968372474349099
# Converged in iteration 2 with cost 0.9968372474349099 because of vanishing difference
# Final cost : 0.9968372474349099
# 25
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968351876188677
# Final cost : 0.9968351876188677
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968351876188677
# Final cost : 0.9968347329546278
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968347329546278
# Final cost : 0.9968347009057
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968347009057
# Final cost : 0.996834700903871
# Compute control for a deterministic system
# Cost in iteration 0: 0.996834700903871
# Converged in iteration 9 with cost 0.9968347009038699 because of vanishing difference
# Final cost : 0.9968347009038699
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968347009038699
# Converged in iteration 2 with cost 0.9968347009038699 because of vanishing difference
# Final cost : 0.9968347009038699
# 26
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968330997704353
# Final cost : 0.9968330997704353
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968330997704353
# Final cost : 0.9968327273700789
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968327273700789
# Final cost : 0.9968327063340774
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968327063340774
# Final cost : 0.9968327063336231
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968327063336231
# Converged in iteration 4 with cost 0.9968327063336229 because of vanishing difference
# Final cost : 0.9968327063336229
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968327063336229
# Converged in iteration 2 with cost 0.9968327063336229 because of vanishing difference
# Final cost : 0.9968327063336229
# 27
# Compute control for a deterministic system
# Cost in iteration 0: 0.996831432299053
# Final cost : 0.996831432299053
# Compute control for a deterministic system
# Cost in iteration 0: 0.996831432299053
# Final cost : 0.9968311479961035
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968311479961035
# Final cost : 0.9968311331099218
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968311331099218
# Converged in iteration 7 with cost 0.9968311331098743 because of step counter
# Final cost : 0.9968311331098743
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968311331098743
# Converged in iteration 1 with cost 0.9968311331098743 because of vanishing difference
# Final cost : 0.9968311331098743
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968311331098743
# Final cost : 0.9968311331098743
# 28
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968301488148134
# Final cost : 0.9968301488148134
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968301488148134
# Final cost : 0.9968299143235572
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968299143235572
# Final cost : 0.996829896357931
# Compute control for a deterministic system
# Cost in iteration 0: 0.996829896357931
# Converged in iteration 4 with cost 0.9968298963579291 because of step counter
# Final cost : 0.9968298963579291
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968298963579291
# Converged in iteration 1 with cost 0.9968298963579291 because of vanishing difference
# Final cost : 0.9968298963579291
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968298963579291
# Final cost : 0.9968298963579291
# 29
# Compute control for a deterministic system
# Cost in iteration 0: 0.996829110817017
# Final cost : 0.996829110817017
# Compute control for a deterministic system
# Cost in iteration 0: 0.996829110817017
# Final cost : 0.9968289403200737
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968289403200737
# Final cost : 0.9968289304020708
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968289304020708
# Converged in iteration 6 with cost 0.9968289304020678 because of vanishing difference
# Final cost : 0.9968289304020678
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968289304020678
# Converged in iteration 2 with cost 0.9968289304020678 because of vanishing difference
# Final cost : 0.9968289304020678
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968289304020678
# Final cost : 0.9968289304020678
# 30
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968283239081848
# Final cost : 0.9968283239081848
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968283239081848
# Final cost : 0.9968281757063554
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968281757063554
# Final cost : 0.9968281687079745
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968281687079745
# Converged in iteration 5 with cost 0.9968281687079726 because of step counter
# Final cost : 0.9968281687079726
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968281687079726
# Converged in iteration 1 with cost 0.9968281687079726 because of vanishing difference
# Final cost : 0.9968281687079726
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968281687079726
# Final cost : 0.9968281687079726
# 31
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968276862522244
# Final cost : 0.9968276862522244
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968276862522244
# Final cost : 0.9968275791871261
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968275791871261
# Final cost : 0.9968275711833512
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968275711833512
# Converged in iteration 3 with cost 0.9968275711833493 because of step counter
# Final cost : 0.9968275711833493
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968275711833493
# Converged in iteration 3 with cost 0.9968275711833492 because of vanishing difference
# Final cost : 0.9968275711833492
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968275711833492
# Final cost : 0.9968275711833492
# 32
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968271989980302
# Final cost : 0.9968271989980302
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968271989980302
# Final cost : 0.9968271039680164
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968271039680164
# Final cost : 0.996827099144325
# Compute control for a deterministic system
# Cost in iteration 0: 0.996827099144325
# Converged in iteration 2 with cost 0.9968270991443241 because of vanishing difference
# Final cost : 0.9968270991443241
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968270991443241
# Converged in iteration 1 with cost 0.9968270991443241 because of vanishing difference
# Final cost : 0.9968270991443241
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968270991443241
# Final cost : 0.9968270991443241
# 33
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968268054353178
# Final cost : 0.9968268054353178
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968268054353178
# Final cost : 0.9968267354663581
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968267354663581
# Final cost : 0.9968267266348131
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968267266348131
# Converged in iteration 3 with cost 0.9968267266348119 because of vanishing difference
# Final cost : 0.9968267266348119
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968267266348119
# Converged in iteration 1 with cost 0.9968267266348119 because of vanishing difference
# Final cost : 0.9968267266348119
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968267266348119
# Final cost : 0.9968267266348119
# 34
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264926055171
# Final cost : 0.9968264926055171
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264926055171
# Final cost : 0.9968264419517933
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264419517933
# Final cost : 0.9968264386879839
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264386879839
# Converged in iteration 2 with cost 0.9968264386879836 because of vanishing difference
# Final cost : 0.9968264386879836
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264386879836
# Converged in iteration 2 with cost 0.9968264386879834 because of vanishing difference
# Final cost : 0.9968264386879834
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968264386879834
# Final cost : 0.9968264386879834
# 35
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968262592094708
# Final cost : 0.9968262592094708
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968262592094708
# Final cost : 0.9968262097030883
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968262097030883
# Final cost : 0.996826207425304
# Compute control for a deterministic system
# Cost in iteration 0: 0.996826207425304
# Converged in iteration 3 with cost 0.9968262074253021 because of vanishing difference
# Final cost : 0.9968262074253021
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968262074253021
# Converged in iteration 1 with cost 0.9968262074253021 because of vanishing difference
# Final cost : 0.9968262074253021
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968262074253021
# Final cost : 0.9968262074253021
# 36
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260646499005
# Final cost : 0.9968260646499005
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260646499005
# Converged in iteration 171 with cost 0.9968260328781389 because of vanishing difference
# Final cost : 0.9968260328781389
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260328781389
# Final cost : 0.9968260297992843
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260297992843
# Final cost : 0.9968260297981685
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260297981685
# Converged in iteration 3 with cost 0.9968260297981674 because of vanishing difference
# Final cost : 0.9968260297981674
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968260297981674
# Converged in iteration 4 with cost 0.9968260297981674 because of vanishing difference
# Final cost : 0.9968260297981674
# 37
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968259198342487
# Final cost : 0.9968259198342487
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968259198342487
# Converged in iteration 35 with cost 0.99682589365163 because of vanishing difference
# Final cost : 0.99682589365163
# Compute control for a deterministic system
# Cost in iteration 0: 0.99682589365163
# Final cost : 0.9968258921002672
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968258921002672
# Converged in iteration 20 with cost 0.9968258921002395 because of vanishing difference
# Final cost : 0.9968258921002395
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968258921002395
# Converged in iteration 5 with cost 0.9968258921002381 because of vanishing difference
# Final cost : 0.9968258921002381
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968258921002381
# Converged in iteration 4 with cost 0.996825892100238 because of vanishing difference
# Final cost : 0.996825892100238
# 38
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968258053769407
# Final cost : 0.9968258053769407
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968258053769407
# Final cost : 0.9968257830920926
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968257830920926
# Final cost : 0.9968257820212658
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968257820212658
# Converged in iteration 3 with cost 0.9968257820212647 because of step counter
# Final cost : 0.9968257820212647
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968257820212647
# Converged in iteration 1 with cost 0.9968257820212647 because of vanishing difference
# Final cost : 0.9968257820212647
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968257820212647
# Converged in iteration 4 with cost 0.9968257820212647 because of vanishing difference
# Final cost : 0.9968257820212647
# 39
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825713916128
# Final cost : 0.996825713916128
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825713916128
# Final cost : 0.9968256975523739
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256975523739
# Final cost : 0.9968256957869999
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256957869999
# Converged in iteration 2 with cost 0.9968256957869992 because of vanishing difference
# Final cost : 0.9968256957869992
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256957869992
# Converged in iteration 6 with cost 0.9968256957869984 because of vanishing difference
# Final cost : 0.9968256957869984
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256957869984
# Converged in iteration 2 with cost 0.9968256957869984 because of vanishing difference
# Final cost : 0.9968256957869984
# 40
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256416114684
# Final cost : 0.9968256416114684
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256416114684
# Final cost : 0.9968256296501887
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256296501887
# Final cost : 0.9968256289410062
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256289410062
# Converged in iteration 2 with cost 0.9968256289410058 because of vanishing difference
# Final cost : 0.9968256289410058
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968256289410058
# Converged in iteration 4 with cost 0.996825628941005 because of vanishing difference
# Final cost : 0.996825628941005
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825628941005
# Converged in iteration 3 with cost 0.996825628941005 because of vanishing difference
# Final cost : 0.996825628941005
# 41
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255872676429
# Final cost : 0.9968255872676429
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255872676429
# Final cost : 0.996825576421681
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825576421681
# Final cost : 0.9968255759140856
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255759140856
# Converged in iteration 2 with cost 0.9968255759140853 because of step counter
# Final cost : 0.9968255759140853
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255759140853
# Converged in iteration 6 with cost 0.996825575914084 because of vanishing difference
# Final cost : 0.996825575914084
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825575914084
# Converged in iteration 3 with cost 0.996825575914084 because of vanishing difference
# Final cost : 0.996825575914084
# 42
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825543159474
# Final cost : 0.996825543159474
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825543159474
# Final cost : 0.9968255352338495
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255352338495
# Final cost : 0.9968255345276075
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255345276075
# Converged in iteration 3 with cost 0.9968255345276072 because of vanishing difference
# Final cost : 0.9968255345276072
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255345276072
# Converged in iteration 59 with cost 0.9968255345276066 because of vanishing difference
# Final cost : 0.9968255345276066
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255345276066
# Converged in iteration 3 with cost 0.9968255345276066 because of vanishing difference
# Final cost : 0.9968255345276066
# 43
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825508469677
# Final cost : 0.996825508469677
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825508469677
# Final cost : 0.9968255026825736
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255026825736
# Final cost : 0.9968255023466264
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255023466264
# Converged in iteration 3 with cost 0.996825502346625 because of vanishing difference
# Final cost : 0.996825502346625
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825502346625
# Converged in iteration 2 with cost 0.9968255023466249 because of vanishing difference
# Final cost : 0.9968255023466249
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968255023466249
# Converged in iteration 1 with cost 0.9968255023466249 because of vanishing difference
# Final cost : 0.9968255023466249
# 44
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254821568607
# Final cost : 0.9968254821568607
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254821568607
# Final cost : 0.9968254772116605
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254772116605
# Final cost : 0.9968254769748235
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254769748235
# Converged in iteration 4 with cost 0.9968254769748215 because of step counter
# Final cost : 0.9968254769748215
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254769748215
# Converged in iteration 16 with cost 0.9968254769748213 because of vanishing difference
# Final cost : 0.9968254769748213
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254769748213
# Converged in iteration 4 with cost 0.9968254769748213 because of vanishing difference
# Final cost : 0.9968254769748213
# 45
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254612563094
# Final cost : 0.9968254612563094
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254612563094
# Final cost : 0.9968254573988472
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254573988472
# Final cost : 0.9968254571100753
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254571100753
# Converged in iteration 3 with cost 0.9968254571100751 because of step counter
# Final cost : 0.9968254571100751
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254571100751
# Converged in iteration 6 with cost 0.9968254571100749 because of vanishing difference
# Final cost : 0.9968254571100749
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254571100749
# Converged in iteration 3 with cost 0.9968254571100749 because of vanishing difference
# Final cost : 0.9968254571100749
# 46
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254445939156
# Final cost : 0.9968254445939156
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254445939156
# Final cost : 0.9968254417829359
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254417829359
# Final cost : 0.9968254416259849
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254416259849
# Converged in iteration 3 with cost 0.9968254416259842 because of step counter
# Final cost : 0.9968254416259842
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254416259842
# Converged in iteration 3 with cost 0.9968254416259841 because of vanishing difference
# Final cost : 0.9968254416259841
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254416259841
# Converged in iteration 3 with cost 0.9968254416259841 because of vanishing difference
# Final cost : 0.9968254416259841
# 47
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254319351949
# Final cost : 0.9968254319351949
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254319351949
# Final cost : 0.9968254295544929
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254295544929
# Final cost : 0.9968254294436294
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254294436294
# Converged in iteration 2 with cost 0.9968254294436293 because of vanishing difference
# Final cost : 0.9968254294436293
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254294436293
# Converged in iteration 17 with cost 0.9968254294436283 because of vanishing difference
# Final cost : 0.9968254294436283
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254294436283
# Converged in iteration 2 with cost 0.9968254294436283 because of vanishing difference
# Final cost : 0.9968254294436283
# 48
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254218447857
# Final cost : 0.9968254218447857
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254218447857
# Final cost : 0.996825420020838
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825420020838
# Final cost : 0.9968254199055079
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254199055079
# Converged in iteration 5 with cost 0.9968254199055065 because of vanishing difference
# Final cost : 0.9968254199055065
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254199055065
# Converged in iteration 4 with cost 0.9968254199055059 because of vanishing difference
# Final cost : 0.9968254199055059
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254199055059
# Converged in iteration 3 with cost 0.9968254199055059 because of vanishing difference
# Final cost : 0.9968254199055059
# 49
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254139419863
# Final cost : 0.9968254139419863
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254139419863
# Final cost : 0.9968254125245837
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254125245837
# Final cost : 0.9968254124465669
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254124465669
# Converged in iteration 2 with cost 0.9968254124465662 because of step counter
# Final cost : 0.9968254124465662
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254124465662
# Converged in iteration 3 with cost 0.9968254124465661 because of vanishing difference
# Final cost : 0.9968254124465661
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254124465661
# Converged in iteration 3 with cost 0.9968254124465661 because of vanishing difference
# Final cost : 0.9968254124465661
# 50
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254077835176
# Final cost : 0.9968254077835176
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254077835176
# Converged in iteration 27 with cost 0.9968254067045238 because of vanishing difference
# Final cost : 0.9968254067045238
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254067045238
# Converged in iteration 31 with cost 0.9968254066935366 because of vanishing difference
# Final cost : 0.9968254066935366
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254066935366
# Final cost : 0.9968254066930725
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254066930725
# Converged in iteration 7 with cost 0.9968254066930715 because of vanishing difference
# Final cost : 0.9968254066930715
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254066930715
# Converged in iteration 2 with cost 0.9968254066930715 because of vanishing difference
# Final cost : 0.9968254066930715
# 51
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254029565804
# Final cost : 0.9968254029565804
# Compute control for a deterministic system
# Cost in iteration 0: 0.9968254029565804
# Final cost : 0.996825402158576
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825402158576
# Final cost : 0.996825402105183
# Compute control for a deterministic system
# Cost in iteration 0: 0.996825402105183
# ...
# Final cost : 1.2220508481268382
# 35
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481266095
# Final cost : 1.2220508481266095
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481266095
# Converged in iteration 1 with cost 1.2220508481266095 because of step counter
# Final cost : 1.2220508481266095
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481266095
# Converged in iteration 1 with cost 1.2220508481266095 because of step counter
# Final cost : 1.2220508481266095
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481266095
# Converged in iteration 8 with cost 1.2220508481265018 because of vanishing difference
# Final cost : 1.2220508481265018
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481265018
# Converged in iteration 5 with cost 1.2220508481265009 because of vanishing difference
# Final cost : 1.2220508481265009
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481265009
# Converged in iteration 3 with cost 1.2220508481265009 because of vanishing difference
# Final cost : 1.2220508481265009
# 36
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263734
# Final cost : 1.2220508481263734
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263734
# Converged in iteration 1 with cost 1.2220508481263734 because of step counter
# Final cost : 1.2220508481263734
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263734
# Converged in iteration 1 with cost 1.2220508481263734 because of step counter
# Final cost : 1.2220508481263734
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263734
# Converged in iteration 9 with cost 1.2220508481263328 because of vanishing difference
# Final cost : 1.2220508481263328
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263328
# Converged in iteration 2 with cost 1.2220508481263324 because of vanishing difference
# Final cost : 1.2220508481263324
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481263324
# Converged in iteration 2 with cost 1.2220508481263324 because of vanishing difference
# Final cost : 1.2220508481263324
# 37
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262615
# Final cost : 1.2220508481262615
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262615
# Converged in iteration 1 with cost 1.2220508481262615 because of step counter
# Final cost : 1.2220508481262615
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262615
# Converged in iteration 1 with cost 1.2220508481262615 because of step counter
# Final cost : 1.2220508481262615
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262615
# Converged in iteration 9 with cost 1.2220508481262196 because of vanishing difference
# Final cost : 1.2220508481262196
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262196
# Converged in iteration 3 with cost 1.2220508481262196 because of vanishing difference
# Final cost : 1.2220508481262196
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481262196
# Converged in iteration 3 with cost 1.2220508481262196 because of vanishing difference
# Final cost : 1.2220508481262196
# 38
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261823
# Final cost : 1.2220508481261823
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261823
# Converged in iteration 1 with cost 1.2220508481261823 because of step counter
# Final cost : 1.2220508481261823
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261823
# Converged in iteration 1 with cost 1.2220508481261823 because of step counter
# Final cost : 1.2220508481261823
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261823
# Converged in iteration 7 with cost 1.2220508481261645 because of vanishing difference
# Final cost : 1.2220508481261645
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261645
# Converged in iteration 3 with cost 1.222050848126164 because of vanishing difference
# Final cost : 1.222050848126164
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126164
# Converged in iteration 3 with cost 1.222050848126164 because of vanishing difference
# Final cost : 1.222050848126164
# 39
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261434
# Final cost : 1.2220508481261434
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261434
# Converged in iteration 1 with cost 1.2220508481261434 because of step counter
# Final cost : 1.2220508481261434
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261434
# Converged in iteration 1 with cost 1.2220508481261434 because of step counter
# Final cost : 1.2220508481261434
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261434
# Converged in iteration 5 with cost 1.2220508481261343 because of vanishing difference
# Final cost : 1.2220508481261343
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261343
# Converged in iteration 3 with cost 1.2220508481261338 because of vanishing difference
# Final cost : 1.2220508481261338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261338
# Converged in iteration 4 with cost 1.2220508481261338 because of vanishing difference
# Final cost : 1.2220508481261338
# 40
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126124
# Final cost : 1.222050848126124
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126124
# Converged in iteration 1 with cost 1.222050848126124 because of step counter
# Final cost : 1.222050848126124
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126124
# Converged in iteration 1 with cost 1.222050848126124 because of step counter
# Final cost : 1.222050848126124
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126124
# Converged in iteration 2 with cost 1.222050848126115 because of vanishing difference
# Final cost : 1.222050848126115
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126115
# Converged in iteration 6 with cost 1.2220508481261148 because of vanishing difference
# Final cost : 1.2220508481261148
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261148
# Final cost : 1.2220508481261148
# 41
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261085
# Final cost : 1.2220508481261085
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261085
# Converged in iteration 1 with cost 1.2220508481261085 because of step counter
# Final cost : 1.2220508481261085
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261085
# Converged in iteration 1 with cost 1.2220508481261085 because of step counter
# Final cost : 1.2220508481261085
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261085
# Converged in iteration 1 with cost 1.2220508481261085 because of step counter
# Final cost : 1.2220508481261085
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261085
# Converged in iteration 4 with cost 1.2220508481261056 because of vanishing difference
# Final cost : 1.2220508481261056
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261056
# Converged in iteration 3 with cost 1.2220508481261056 because of vanishing difference
# Final cost : 1.2220508481261056
# 42
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261014
# Final cost : 1.2220508481261014
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261014
# Converged in iteration 1 with cost 1.2220508481261014 because of step counter
# Final cost : 1.2220508481261014
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261014
# Converged in iteration 1 with cost 1.2220508481261014 because of step counter
# Final cost : 1.2220508481261014
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261014
# Converged in iteration 1 with cost 1.2220508481261014 because of step counter
# Final cost : 1.2220508481261014
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261014
# Converged in iteration 5 with cost 1.2220508481261008 because of vanishing difference
# Final cost : 1.2220508481261008
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481261008
# Final cost : 1.2220508481261008
# 43
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260988
# Final cost : 1.2220508481260988
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260988
# Converged in iteration 1 with cost 1.2220508481260988 because of step counter
# Final cost : 1.2220508481260988
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260988
# Converged in iteration 1 with cost 1.2220508481260988 because of step counter
# Final cost : 1.2220508481260988
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260988
# Converged in iteration 1 with cost 1.2220508481260988 because of step counter
# Final cost : 1.2220508481260988
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260988
# Converged in iteration 8 with cost 1.2220508481260979 because of vanishing difference
# Final cost : 1.2220508481260979
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260979
# Converged in iteration 3 with cost 1.2220508481260979 because of vanishing difference
# Final cost : 1.2220508481260979
# 44
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260968
# Final cost : 1.2220508481260968
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260968
# Converged in iteration 1 with cost 1.2220508481260968 because of step counter
# Final cost : 1.2220508481260968
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260968
# Converged in iteration 1 with cost 1.2220508481260968 because of step counter
# Final cost : 1.2220508481260968
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260968
# Converged in iteration 1 with cost 1.2220508481260968 because of step counter
# Final cost : 1.2220508481260968
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260968
# Converged in iteration 3 with cost 1.222050848126096 because of vanishing difference
# Final cost : 1.222050848126096
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126096
# Converged in iteration 4 with cost 1.222050848126096 because of vanishing difference
# Final cost : 1.222050848126096
# 45
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260952
# Final cost : 1.2220508481260952
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260952
# Converged in iteration 1 with cost 1.2220508481260952 because of step counter
# Final cost : 1.2220508481260952
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260952
# Converged in iteration 1 with cost 1.2220508481260952 because of step counter
# Final cost : 1.2220508481260952
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260952
# Converged in iteration 1 with cost 1.2220508481260952 because of step counter
# Final cost : 1.2220508481260952
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260952
# Converged in iteration 4 with cost 1.222050848126095 because of step counter
# Final cost : 1.222050848126095
# Compute control for a deterministic system
# Cost in iteration 0: 1.222050848126095
# Final cost : 1.222050848126095
# 46
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of vanishing difference
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Final cost : 1.2220508481260948
# 47
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Final cost : 1.2220508481260948
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 1 with cost 1.2220508481260948 because of step counter
# Final cost : 1.2220508481260948
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260948
# Converged in iteration 3 with cost 1.2220508481260945 because of vanishing difference
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Final cost : 1.2220508481260945
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Converged in iteration 1 with cost 1.2220508481260945 because of step counter
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Converged in iteration 1 with cost 1.2220508481260945 because of step counter
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Converged in iteration 1 with cost 1.2220508481260945 because of step counter
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Converged in iteration 2 with cost 1.2220508481260945 because of vanishing difference
# Final cost : 1.2220508481260945
# Compute control for a deterministic system
# Cost in iteration 0: 1.2220508481260945
# Final cost : 1.2220508481260945

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)

    if i not in [2]:
        continue
    
    print(results_w1_du["cost"][i], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# POINT  2
# POINT  3
# 2.0693821694826298 2.794785708126736
# POINT  4
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# POINT  9
# POINT  10
