# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
duration_array = np.array( [22, 25, 28, 36, 60, 100])
n_times = len(duration_array)
fname = 'w1_du_T_tau'

results_w1_du = dict([
    ('cost_type', 'w1'),
    ('d', [None] * n_times),
    ('u', [None] * n_times),
    ("cost", [None] * n_times),
    ("initial_cost", [None] * n_times),
    ("precision_cost", [None] * n_times),
    ("L_cost", [np.zeros((2))] * n_times),
    ("control", [None] * n_times),
    ("state", [None] * n_times),
    ])

def save(res, file):
    filehandler = open( (file + ".pickle"),"wb")
    pickle.dump(res,filehandler)
    filehandler.close()

# %%
with open('w1_du_T_tau.pickle', 'rb') as f:
    results_w1_du = pickle.load(f)

# %%
points_bi = [ [2.9, 2.9]]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 5000.
wc.params["duration"] = duration

wc.params.tau_exc = 12.

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:5000] = -5.
bi_control[0,25000:30000] = +5.

p = points_bi[0]

wc.params["exc_ext"] = bi_control + p[0]
wc.params["inh_ext"] = zero_input + p[1]
wc.run()

plt.plot(wc.exc[0,:])
plt.show()

for i in range(len(duration_array)):
    results_w1_du['d'][i] = [wc.exc[0,20000], wc.inh[0,20000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

# %%
w1 = 0.1
duration_array[-1] = 80.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

for i in range(len(duration_array)):

    duration = duration_array[i]
    wc.params["duration"] = duration
    zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

    int0 = np.around(duration/dt).astype(int) - 200

    print("DURATION ", duration_array[i], int0)

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    #if type(results_w1_du["control"][i]) != type(None):
    #    continue

    #results_w1_du["control"][i] = None
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    #wc_controlled.control[0,0,:200] = results_w1_du["control"][i-1][0,0,:200]

    if False:

        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-400:-200] = 5.
        wc_controlled.update_input()

        plt.plot(wc_controlled.get_xs()[0,0,:])
        plt.show()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        plt.plot(wc_controlled.get_xs()[0,0,:])
        plt.show()

        increase_step_compute()

        wc_controlled.optimize(0)    
        get_values(results_w1_du, i, w1)

        plt.plot(wc_controlled.get_xs()[0,0,:])
        plt.show()

        continue

    wc_controlled.step =  10**(4)
    wc_controlled.step_factor = 0.8
    wc_controlled.optimize(100)

    decrease_step_compute()

    wc_controlled.step =  10**(0)
    wc_controlled.step_factor = 0.8
    wc_controlled.optimize(100)

    decrease_step_compute()
    
    if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
        get_values(results_w1_du, i, w1)

    itmax = int(duration)

    for k in range(itmax):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-20] = wc_controlled.control[0,:,20:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-20)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break
    
    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-22)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break

    save(results_w1_du, fname)
# Out:
# DURATION  22 20
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# Compute control for a deterministic system
# Cost in iteration 0: 1.2109591404693338
# Converged in iteration 1 with cost 1.2109591404693338 because of step counter
# Final cost : 1.2109591404693338
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.6282447403181077
# Final cost : 1.6282447403181077
# Compute control for a deterministic system
# Cost in iteration 0: 1.6282447403181077
# Final cost : 1.6282447403040674
# Compute control for a deterministic system
# Cost in iteration 0: 1.6282447403040674
# Final cost : 1.6254337444563283
# Compute control for a deterministic system
# Cost in iteration 0: 1.6254337444563283
# Final cost : 1.625152305177588
# Compute control for a deterministic system
# Cost in iteration 0: 1.625152305177588
# Final cost : 1.6251523051775876
# Compute control for a deterministic system
# Cost in iteration 0: 1.6251523051775876
# Final cost : 1.6223345021922853
# Compute control for a deterministic system
# Cost in iteration 0: 1.6223345021922853
# Final cost : 1.6220523776650269
# Compute control for a deterministic system
# Cost in iteration 0: 1.6220523776650269
# Converged in iteration 1 with cost 1.6220523776650269 because of vanishing difference
# Final cost : 1.6220523776650269
# Compute control for a deterministic system
# Cost in iteration 0: 1.6220523776650269
# Final cost : 1.6192276766374891
# Compute control for a deterministic system
# Cost in iteration 0: 1.6192276766374891
# Final cost : 1.6189448577094416
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.6485444725015723
# Final cost : 1.6485444725015723
# Compute control for a deterministic system
# Cost in iteration 0: 1.6485444725015723
# Final cost : 1.6485444724877327
# Compute control for a deterministic system
# Cost in iteration 0: 1.6485444724877327
# Final cost : 1.6457751479027134
# Compute control for a deterministic system
# Cost in iteration 0: 1.6457751479027134
# Final cost : 1.645497966320051
# Compute control for a deterministic system
# Cost in iteration 0: 1.645497966320051
# Converged in iteration 1 with cost 1.645497966320051 because of vanishing difference
# Final cost : 1.645497966320051
# Compute control for a deterministic system
# Cost in iteration 0: 1.645497966320051
# Final cost : 1.642723620543037
# Compute control for a deterministic system
# Cost in iteration 0: 1.642723620543037
# Final cost : 1.6424459294289502
# DURATION  25 50
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# Compute control for a deterministic system
# Cost in iteration 0: 0.9358973889688555
# Converged in iteration 1 with cost 0.9358973889688555 because of step counter
# Final cost : 0.9358973889688555
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.8398103164518815
# Final cost : 1.8398103164518815
# Compute control for a deterministic system
# Cost in iteration 0: 1.8398103164518815
# Final cost : 1.8398103164125001
# Compute control for a deterministic system
# Cost in iteration 0: 1.8398103164125001
# Final cost : 1.831948271174138
# Compute control for a deterministic system
# Cost in iteration 0: 1.831948271174138
# Final cost : 1.831160454724417
# Compute control for a deterministic system
# Cost in iteration 0: 1.831160454724417
# Final cost : 1.8311604547244167
# Compute control for a deterministic system
# Cost in iteration 0: 1.8311604547244167
# Final cost : 1.8232543801115964
# Compute control for a deterministic system
# Cost in iteration 0: 1.8232543801115964
# Final cost : 1.8224608397352902
# Compute control for a deterministic system
# Cost in iteration 0: 1.8224608397352902
# Converged in iteration 1 with cost 1.8224608397352902 because of vanishing difference
# Final cost : 1.8224608397352902
# Compute control for a deterministic system
# Cost in iteration 0: 1.8224608397352902
# Final cost : 1.8144951954543027
# Compute control for a deterministic system
# Cost in iteration 0: 1.8144951954543027
# Final cost : 1.8136955639493364
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.8512221765185783
# Final cost : 1.8512221765185783
# Compute control for a deterministic system
# Cost in iteration 0: 1.8512221765185783
# Final cost : 1.8512221764806487
# Compute control for a deterministic system
# Cost in iteration 0: 1.8512221764806487
# Final cost : 1.8436128566303585
# Compute control for a deterministic system
# Cost in iteration 0: 1.8436128566303585
# Final cost : 1.8428492648162333
# Compute control for a deterministic system
# Cost in iteration 0: 1.8428492648162333
# Converged in iteration 1 with cost 1.8428492648162333 because of vanishing difference
# Final cost : 1.8428492648162333
# Compute control for a deterministic system
# Cost in iteration 0: 1.8428492648162333
# Final cost : 1.8351865432580086
# Compute control for a deterministic system
# Cost in iteration 0: 1.8351865432580086
# Final cost : 1.8344175660170348
# DURATION  28 80
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# Compute control for a deterministic system
# Cost in iteration 0: 0.9394847000275219
# Converged in iteration 1 with cost 0.9394847000275219 because of step counter
# Final cost : 0.9394847000275219
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.9514948485794157
# Final cost : 0.9514948485794157
# Compute control for a deterministic system
# Cost in iteration 0: 0.9514948485794157
# Final cost : 0.9514948484475377
# Compute control for a deterministic system
# Cost in iteration 0: 0.9514948484475377
# Final cost : 0.9295255781817306
# Compute control for a deterministic system
# Cost in iteration 0: 0.9295255781817306
# Final cost : 0.9277722510122577
# Compute control for a deterministic system
# Cost in iteration 0: 0.9277722510122577
# Converged in iteration 19 with cost 0.9277722510122577 because of vanishing difference
# Final cost : 0.9277722510122577
# Compute control for a deterministic system
# Cost in iteration 0: 0.9277722510122577
# Final cost : 0.9137211492005797
# Compute control for a deterministic system
# Cost in iteration 0: 0.9137211492005797
# Final cost : 0.9126122503277256
# Compute control for a deterministic system
# Cost in iteration 0: 0.9126122503277256
# Converged in iteration 1 with cost 0.9126122503277256 because of vanishing difference
# Final cost : 0.9126122503277256
# Compute control for a deterministic system
# Cost in iteration 0: 0.9126122503277256
# Final cost : 0.9036685689344598
# Compute control for a deterministic system
# Cost in iteration 0: 0.9036685689344598
# Final cost : 0.9029521075572713
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 2.117464598785446
# Final cost : 2.117464598785446
# Compute control for a deterministic system
# Cost in iteration 0: 2.117464598785446
# Final cost : 2.1174645987390934
# Compute control for a deterministic system
# Cost in iteration 0: 2.1174645987390934
# Final cost : 2.108169936065342
# Compute control for a deterministic system
# Cost in iteration 0: 2.108169936065342
# Final cost : 2.1072360419330374
# Compute control for a deterministic system
# Cost in iteration 0: 2.1072360419330374
# Final cost : 2.1072360419330365
# Compute control for a deterministic system
# Cost in iteration 0: 2.1072360419330365
# Final cost : 2.0978390877452897
# Compute control for a deterministic system
# Cost in iteration 0: 2.0978390877452897
# Final cost : 2.096893226216789
# Compute control for a deterministic system
# Cost in iteration 0: 2.096893226216789
# Converged in iteration 1 with cost 2.096893226216789 because of vanishing difference
# Final cost : 2.096893226216789
# Compute control for a deterministic system
# Cost in iteration 0: 2.096893226216789
# Final cost : 2.087369736173139
# Compute control for a deterministic system
# Cost in iteration 0: 2.087369736173139
# Final cost : 2.086410748294504
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.1188226408102557
# Final cost : 2.1188226408102557
# Compute control for a deterministic system
# Cost in iteration 0: 2.1188226408102557
# Final cost : 2.118822640765889
# Compute control for a deterministic system
# Cost in iteration 0: 2.118822640765889
# Final cost : 2.109897894482951
# Compute control for a deterministic system
# Cost in iteration 0: 2.109897894482951
# Final cost : 2.1089996275544425
# Compute control for a deterministic system
# Cost in iteration 0: 2.1089996275544425
# Converged in iteration 1 with cost 2.1089996275544425 because of vanishing difference
# Final cost : 2.1089996275544425
# Compute control for a deterministic system
# Cost in iteration 0: 2.1089996275544425
# Final cost : 2.0999581451601825
# Compute control for a deterministic system
# Cost in iteration 0: 2.0999581451601825
# Final cost : 2.0990480377086405
# DURATION  36 160
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# Compute control for a deterministic system
# Cost in iteration 0: 0.8556692529882357
# Converged in iteration 1 with cost 0.8556692529882357 because of step counter
# Final cost : 0.8556692529882357
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.2782948927245132
# Final cost : 2.2782948927245132
# Compute control for a deterministic system
# Cost in iteration 0: 2.2782948927245132
# Final cost : 2.2782948921427715
# Compute control for a deterministic system
# Cost in iteration 0: 2.2782948921427715
# Final cost : 2.1267662098553366
# Compute control for a deterministic system
# Cost in iteration 0: 2.1267662098553366
# Final cost : 2.106722911931412
# Compute control for a deterministic system
# Cost in iteration 0: 2.106722911931412
# Converged in iteration 4 with cost 2.106722911931412 because of vanishing difference
# Final cost : 2.106722911931412
# Compute control for a deterministic system
# Cost in iteration 0: 2.106722911931412
# Final cost : 1.833123313424085
# Compute control for a deterministic system
# Cost in iteration 0: 1.833123313424085
# Final cost : 1.7962181265345953
# Compute control for a deterministic system
# Cost in iteration 0: 1.7962181265345953
# Converged in iteration 1 with cost 1.7962181265345953 because of vanishing difference
# Final cost : 1.7962181265345953
# Compute control for a deterministic system
# Cost in iteration 0: 1.7962181265345953
# Final cost : 1.2506673367119612
# Compute control for a deterministic system
# Cost in iteration 0: 1.2506673367119612
# Final cost : 1.1733479948031718
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.378774375920254
# Final cost : 1.378774375920254
# Compute control for a deterministic system
# Cost in iteration 0: 1.378774375920254
# Final cost : 1.378774372675777
# Compute control for a deterministic system
# Cost in iteration 0: 1.378774372675777
# Final cost : 0.8779941217499654
# Compute control for a deterministic system
# Cost in iteration 0: 0.8779941217499654
# Final cost : 0.8726134861661019
# Compute control for a deterministic system
# Cost in iteration 0: 0.8726134861661019
# Converged in iteration 1 with cost 0.8726134861661019 because of vanishing difference
# Final cost : 0.8726134861661019
# Compute control for a deterministic system
# Cost in iteration 0: 0.8726134861661019
# Final cost : 0.8550143108064834
# Compute control for a deterministic system
# Cost in iteration 0: 0.8550143108064834
# Final cost : 0.8543118052773571
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.9120649280085493
# Final cost : 0.9120649280085493
# Compute control for a deterministic system
# Cost in iteration 0: 0.9120649280085493
# Final cost : 0.9120649268356071
# Compute control for a deterministic system
# Cost in iteration 0: 0.9120649268356071
# Final cost : 0.8587985504087602
# Compute control for a deterministic system
# Cost in iteration 0: 0.8587985504087602
# Final cost : 0.8577099971751331
# Compute control for a deterministic system
# Cost in iteration 0: 0.8577099971751331
# Converged in iteration 1 with cost 0.8577099971751331 because of vanishing difference
# Final cost : 0.8577099971751331
# Compute control for a deterministic system
# Cost in iteration 0: 0.8577099971751331
# Final cost : 0.8514303067142859
# Compute control for a deterministic system
# Cost in iteration 0: 0.8514303067142859
# Final cost : 0.8510497740232048
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.8919447298156167
# Final cost : 0.8919447298156167
# Compute control for a deterministic system
# Cost in iteration 0: 0.8919447298156167
# Final cost : 0.8919447292095243
# Compute control for a deterministic system
# Cost in iteration 0: 0.8919447292095243
# Final cost : 0.8579941756257071
# Compute control for a deterministic system
# Cost in iteration 0: 0.8579941756257071
# Final cost : 0.8570497889356946
# Compute control for a deterministic system
# Cost in iteration 0: 0.8570497889356946
# Converged in iteration 1 with cost 0.8570497889356946 because of vanishing difference
# Final cost : 0.8570497889356946
# Compute control for a deterministic system
# Cost in iteration 0: 0.8570497889356946
# Final cost : 0.8513798559339345
# Compute control for a deterministic system
# Cost in iteration 0: 0.8513798559339345
# Final cost : 0.8510250999233362
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.8922337589614839
# Final cost : 0.8922337589614839
# Compute control for a deterministic system
# Cost in iteration 0: 0.8922337589614839
# Final cost : 0.8922337583718926
# Compute control for a deterministic system
# Cost in iteration 0: 0.8922337583718926
# Final cost : 0.8584839554882907
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584839554882907
# Final cost : 0.8575309493241594
# Compute control for a deterministic system
# Cost in iteration 0: 0.8575309493241594
# Converged in iteration 1 with cost 0.8575309493241594 because of vanishing difference
# Final cost : 0.8575309493241594
# Compute control for a deterministic system
# Cost in iteration 0: 0.8575309493241594
# Final cost : 0.8518052521642371
# Compute control for a deterministic system
# Cost in iteration 0: 0.8518052521642371
# Final cost : 0.8514468263874111
# DURATION  60 400
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094168923007698
# Converged in iteration 1 with cost 1.0094168923007698 because of step counter
# Final cost : 1.0094168923007698
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 2 with cost 1.0087608051001247 because of vanishing difference
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 89 with cost 1.0087608051001247 because of vanishing difference
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 51 with cost 1.0087608051001247 because of vanishing difference
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087608051001247
# Converged in iteration 1 with cost 1.0087608051001247 because of step counter
# Final cost : 1.0087608051001247
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081961807521145
# Final cost : 1.0081961807521145
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081961807521145
# Converged in iteration 4 with cost 1.0081961807521138 because of vanishing difference
# Final cost : 1.0081961807521138
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081961807521138
# Final cost : 1.008195800858579
# Compute control for a deterministic system
# Cost in iteration 0: 1.008195800858579
# Final cost : 1.0081957616598436
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081957616598436
# Converged in iteration 2 with cost 1.0081957616598436 because of vanishing difference
# Final cost : 1.0081957616598436
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081957616598436
# Final cost : 1.0081953577295153
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081953577295153
# Final cost : 1.0081953161316886
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081953161316886
# Final cost : 1.0081953161316886
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081953161316886
# Final cost : 1.0081948882556215
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081948882556215
# Final cost : 1.0081948442677844
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077219950127327
# Final cost : 1.0077219950127327
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077219950127327
# Converged in iteration 5 with cost 1.0077219950127319 because of vanishing difference
# Final cost : 1.0077219950127319
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077219950127319
# Final cost : 1.0077190132855949
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077190132855949
# Final cost : 1.0077187142522714
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077187142522714
# Converged in iteration 2 with cost 1.0077187142522714 because of vanishing difference
# Final cost : 1.0077187142522714
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077187142522714
# Final cost : 1.0077157154140082
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077157154140082
# Final cost : 1.0077154146725666
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077154146725666
# Converged in iteration 12 with cost 1.0077154146725666 because of vanishing difference
# Final cost : 1.0077154146725666
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077154146725666
# Final cost : 1.0077123987826495
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077123987826495
# Final cost : 1.007712096339022
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073245520764431
# Final cost : 1.0073245520764431
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073245520764431
# Converged in iteration 17 with cost 1.0073245520764404 because of vanishing difference
# Final cost : 1.0073245520764404
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073245520764404
# Final cost : 1.0073190944414285
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073190944414285
# Final cost : 1.0073185481343712
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073185481343712
# Converged in iteration 29 with cost 1.0073185481343712 because of vanishing difference
# Final cost : 1.0073185481343712
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073185481343712
# Final cost : 1.0073130796885204
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073130796885204
# Final cost : 1.0073125323020269
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073125323020269
# Final cost : 1.0073125323020269
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073125323020269
# Final cost : 1.0073070530780974
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073070530780974
# Final cost : 1.0073065046154364
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069940243507873
# Final cost : 1.0069940243507873
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069940243507873
# Final cost : 1.0069940243507476
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069940243507476
# Final cost : 1.0069862890635821
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069862890635821
# Final cost : 1.0069855152508145
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069855152508145
# Final cost : 1.0069855152508145
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069855152508145
# Final cost : 1.0069777743127704
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069777743127704
# Final cost : 1.0069769999356453
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069769999356453
# Final cost : 1.0069769999356453
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069769999356453
# Final cost : 1.0069692533612136
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069692533612136
# Final cost : 1.0069684784211754
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067194685539902
# Final cost : 1.0067194685539902
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067194685539902
# Final cost : 1.0067194685539407
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067194685539407
# Final cost : 1.0067096977217271
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067096977217271
# Final cost : 1.0067087205481713
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067087205481713
# Final cost : 1.0067087205481713
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067087205481713
# Final cost : 1.0066989479190187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0066989479190187
# Final cost : 1.006697970565986
# Compute control for a deterministic system
# Cost in iteration 0: 1.006697970565986
# Final cost : 1.006697970565986
# Compute control for a deterministic system
# Cost in iteration 0: 1.006697970565986
# Final cost : 1.0066881961442053
# Compute control for a deterministic system
# Cost in iteration 0: 1.0066881961442053
# Final cost : 1.0066872186121252
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 1.006490283467883
# Final cost : 1.006490283467883
# Compute control for a deterministic system
# Cost in iteration 0: 1.006490283467883
# Final cost : 1.0064902834678238
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064902834678238
# Final cost : 1.0064787359912433
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064787359912433
# Final cost : 1.0064775812853588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064775812853588
# Final cost : 1.0064775812853588
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064775812853588
# Final cost : 1.0064660346414853
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064660346414853
# Final cost : 1.006464880018872
# Compute control for a deterministic system
# Cost in iteration 0: 1.006464880018872
# Final cost : 1.006464880018872
# Compute control for a deterministic system
# Cost in iteration 0: 1.006464880018872
# Final cost : 1.0064533342077389
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064533342077389
# Final cost : 1.006452179668402
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 1.006296978325387
# Final cost : 1.006296978325387
# Compute control for a deterministic system
# Cost in iteration 0: 1.006296978325387
# Final cost : 1.0062969783253202
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062969783253202
# Final cost : 1.0062839083612234
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062839083612234
# Final cost : 1.0062826014877366
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062826014877366
# Final cost : 1.0062826014877366
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062826014877366
# Final cost : 1.0062695339724899
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062695339724899
# Final cost : 1.0062682273438504
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062682273438504
# Final cost : 1.0062682273438504
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062682273438504
# Final cost : 1.0062551622767177
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062551622767177
# Final cost : 1.0062538558928538
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061314852650893
# Final cost : 1.0061314852650893
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061314852650893
# Final cost : 1.0061314852650158
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061314852650158
# Final cost : 1.0061171274271234
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061171274271234
# Final cost : 1.0061156918088898
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061156918088898
# Final cost : 1.0061156918088898
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061156918088898
# Final cost : 1.0061013372694187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061013372694187
# Final cost : 1.0060999019810344
# Compute control for a deterministic system
# Cost in iteration 0: 1.0060999019810344
# Final cost : 1.0060999019810344
# Compute control for a deterministic system
# Cost in iteration 0: 1.0060999019810344
# Final cost : 1.0060855507401314
# Compute control for a deterministic system
# Cost in iteration 0: 1.0060855507401314
# Final cost : 1.0060841157816107
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059872817927253
# Final cost : 1.0059872817927253
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059872817927253
# Final cost : 1.005987281792647
# Compute control for a deterministic system
# Cost in iteration 0: 1.005987281792647
# Final cost : 1.0059718443511387
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059718443511387
# Final cost : 1.0059703007881047
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059703007881047
# Final cost : 1.0059703007881047
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059703007881047
# Final cost : 1.0059548669555278
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059548669555278
# Final cost : 1.0059533237534621
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059533237534621
# Final cost : 1.0059533237534621
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059533237534621
# Final cost : 1.0059378935313155
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059378935313155
# Final cost : 1.0059363506903676
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 0.9647771944134134
# Final cost : 0.9647771944134134
# Compute control for a deterministic system
# Cost in iteration 0: 0.9647771944134134
# Final cost : 0.9647771944025489
# Compute control for a deterministic system
# Cost in iteration 0: 0.9647771944025489
# Final cost : 0.9634442991013382
# Compute control for a deterministic system
# Cost in iteration 0: 0.9634442991013382
# Final cost : 0.963366693482668
# Compute control for a deterministic system
# Cost in iteration 0: 0.963366693482668
# Final cost : 0.963366693482668
# Compute control for a deterministic system
# Cost in iteration 0: 0.963366693482668
# Final cost : 0.9628388347712448
# Compute control for a deterministic system
# Cost in iteration 0: 0.9628388347712448
# Final cost : 0.9628033594854913
# Compute control for a deterministic system
# Cost in iteration 0: 0.9628033594854913
# Converged in iteration 1 with cost 0.9628033594854913 because of vanishing difference
# Final cost : 0.9628033594854913
# Compute control for a deterministic system
# Cost in iteration 0: 0.9628033594854913
# Final cost : 0.9625479311975126
# Compute control for a deterministic system
# Cost in iteration 0: 0.9625479311975126
# Final cost : 0.9625299677370057
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 3.068884116482838
# Final cost : 3.068884116482838
# Compute control for a deterministic system
# Cost in iteration 0: 3.068884116482838
# Final cost : 3.068884115766823
# Compute control for a deterministic system
# Cost in iteration 0: 3.068884115766823
# Final cost : 2.7821292688039185
# Compute control for a deterministic system
# Cost in iteration 0: 2.7821292688039185
# Final cost : 2.710944601945852
# Compute control for a deterministic system
# Cost in iteration 0: 2.710944601945852
# Converged in iteration 21 with cost 2.710944601945819 because of vanishing difference
# Final cost : 2.710944601945819
# Compute control for a deterministic system
# Cost in iteration 0: 2.710944601945819
# Final cost : 0.9426968947952575
# Compute control for a deterministic system
# Cost in iteration 0: 0.9426968947952575
# Final cost : 0.9418583942502071
# Compute control for a deterministic system
# Cost in iteration 0: 0.9418583942502071
# Converged in iteration 1 with cost 0.9418583942502071 because of vanishing difference
# Final cost : 0.9418583942502071
# Compute control for a deterministic system
# Cost in iteration 0: 0.9418583942502071
# Final cost : 0.938253794361572
# Compute control for a deterministic system
# Cost in iteration 0: 0.938253794361572
# Final cost : 0.9380842706268454
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 3.218798346067814
# Final cost : 3.218798346067814
# Compute control for a deterministic system
# Cost in iteration 0: 3.218798346067814
# Final cost : 3.2187983459363085
# Compute control for a deterministic system
# Cost in iteration 0: 3.2187983459363085
# Final cost : 3.1890043027363855
# Compute control for a deterministic system
# Cost in iteration 0: 3.1890043027363855
# Final cost : 3.1855706755620234
# Compute control for a deterministic system
# Cost in iteration 0: 3.1855706755620234
# Final cost : 3.18557067556202
# Compute control for a deterministic system
# Cost in iteration 0: 3.18557067556202
# Final cost : 3.144854721061976
# Compute control for a deterministic system
# Cost in iteration 0: 3.144854721061976
# Final cost : 3.139986416817358
# Compute control for a deterministic system
# Cost in iteration 0: 3.139986416817358
# Converged in iteration 1 with cost 3.139986416817358 because of vanishing difference
# Final cost : 3.139986416817358
# Compute control for a deterministic system
# Cost in iteration 0: 3.139986416817358
# Final cost : 3.0789814182353785
# Compute control for a deterministic system
# Cost in iteration 0: 3.0789814182353785
# Final cost : 3.0712300933724084
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 3.1086892030725513
# Final cost : 3.1086892030725513
# Compute control for a deterministic system
# Cost in iteration 0: 3.1086892030725513
# Final cost : 3.1086892027740975
# Compute control for a deterministic system
# Cost in iteration 0: 3.1086892027740975
# Final cost : 3.032907153876122
# Compute control for a deterministic system
# Cost in iteration 0: 3.032907153876122
# Final cost : 3.0229090600183928
# Compute control for a deterministic system
# Cost in iteration 0: 3.0229090600183928
# Converged in iteration 1 with cost 3.0229090600183928 because of vanishing difference
# Final cost : 3.0229090600183928
# Compute control for a deterministic system
# Cost in iteration 0: 3.0229090600183928
# Final cost : 2.8722431066731753
# Compute control for a deterministic system
# Cost in iteration 0: 2.8722431066731753
# Final cost : 2.8484659659908784
# DURATION  80 600
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# Compute control for a deterministic system
# Cost in iteration 0: 1.0094167045358244
# Converged in iteration 1 with cost 1.0094167045358244 because of step counter
# Final cost : 1.0094167045358244
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 4 with cost 1.0087605738601915 because of vanishing difference
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 13 with cost 1.0087605738601915 because of vanishing difference
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 81 with cost 1.0087605738601915 because of vanishing difference
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# Compute control for a deterministic system
# Cost in iteration 0: 1.0087605738601915
# Converged in iteration 1 with cost 1.0087605738601915 because of step counter
# Final cost : 1.0087605738601915
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081958970037381
# Final cost : 1.0081958970037381
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081958970037381
# Converged in iteration 1 with cost 1.0081958970037381 because of vanishing difference
# Final cost : 1.0081958970037381
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081958970037381
# Final cost : 1.0081955153196307
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081955153196307
# Final cost : 1.0081954759420553
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081954759420553
# Converged in iteration 1 with cost 1.0081954759420553 because of vanishing difference
# Final cost : 1.0081954759420553
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081954759420553
# Final cost : 1.0081950702254623
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081950702254623
# Final cost : 1.0081950284492243
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081950284492243
# Final cost : 1.0081950284492243
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081950284492243
# Final cost : 1.0081945987911776
# Compute control for a deterministic system
# Cost in iteration 0: 1.0081945987911776
# Final cost : 1.0081945546253568
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 1.007721643364357
# Final cost : 1.007721643364357
# Compute control for a deterministic system
# Cost in iteration 0: 1.007721643364357
# Converged in iteration 4 with cost 1.0077216433643563 because of vanishing difference
# Final cost : 1.0077216433643563
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077216433643563
# Final cost : 1.0077186589699763
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077186589699763
# Final cost : 1.0077183596702302
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077183596702302
# Final cost : 1.0077183596702302
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077183596702302
# Final cost : 1.007715358170712
# Compute control for a deterministic system
# Cost in iteration 0: 1.007715358170712
# Final cost : 1.0077150571634441
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077150571634441
# Final cost : 1.0077150571634441
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077150571634441
# Final cost : 1.0077120386182326
# Compute control for a deterministic system
# Cost in iteration 0: 1.0077120386182326
# Final cost : 1.007711735909374
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073241203410002
# Final cost : 1.0073241203410002
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073241203410002
# Converged in iteration 40 with cost 1.0073241203409917 because of vanishing difference
# Final cost : 1.0073241203409917
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073241203409917
# Final cost : 1.0073186588646599
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073186588646599
# Final cost : 1.0073181121738457
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073181121738457
# Converged in iteration 30 with cost 1.0073181121738457 because of vanishing difference
# Final cost : 1.0073181121738457
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073181121738457
# Final cost : 1.0073126398941428
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073126398941428
# Final cost : 1.0073120921246383
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073120921246383
# Converged in iteration 17 with cost 1.0073120921246383 because of vanishing difference
# Final cost : 1.0073120921246383
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073120921246383
# Final cost : 1.0073066090742908
# Compute control for a deterministic system
# Cost in iteration 0: 1.0073066090742908
# Final cost : 1.0073060602293609
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069935012769953
# Final cost : 1.0069935012769953
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069935012769953
# Final cost : 1.0069935012769569
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069935012769569
# Final cost : 1.0069857606381676
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069857606381676
# Final cost : 1.0069849862906568
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069849862906568
# Final cost : 1.0069849862906568
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069849862906568
# Final cost : 1.0069772400093049
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069772400093049
# Final cost : 1.0069764650982653
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069764650982653
# Final cost : 1.0069764650982653
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069764650982653
# Final cost : 1.0069687131888165
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069687131888165
# Final cost : 1.006967937715691
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067188478030868
# Final cost : 1.0067188478030868
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067188478030868
# Final cost : 1.006718847803037
# Compute control for a deterministic system
# Cost in iteration 0: 1.006718847803037
# Final cost : 1.0067090697837013
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067090697837013
# Final cost : 1.0067080918918367
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067080918918367
# Final cost : 1.0067080918918367
# Compute control for a deterministic system
# Cost in iteration 0: 1.0067080918918367
# Final cost : 1.0066983120836273
# Compute control for a deterministic system
# Cost in iteration 0: 1.0066983120836273
# Final cost : 1.006697334013092
# Compute control for a deterministic system
# Cost in iteration 0: 1.006697334013092
# Final cost : 1.006697334013092
# Compute control for a deterministic system
# Cost in iteration 0: 1.006697334013092
# Final cost : 1.0066875524202992
# Compute control for a deterministic system
# Cost in iteration 0: 1.0066875524202992
# Final cost : 1.0066865741715207
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064895726616683
# Final cost : 1.0064895726616683
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064895726616683
# Final cost : 1.0064895726616092
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064895726616092
# Final cost : 1.006478015998367
# Compute control for a deterministic system
# Cost in iteration 0: 1.006478015998367
# Final cost : 1.0064768603741314
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064768603741314
# Final cost : 1.0064768603741314
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064768603741314
# Final cost : 1.0064653045498744
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064653045498744
# Final cost : 1.0064641490095376
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064641490095376
# Final cost : 1.0064641490095376
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064641490095376
# Final cost : 1.0064525940242892
# Compute control for a deterministic system
# Cost in iteration 0: 1.0064525940242892
# Final cost : 1.0064514385678562
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062962162891358
# Final cost : 1.0062962162891358
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062962162891358
# Final cost : 1.0062962162890685
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062962162890685
# Final cost : 1.0062831355093262
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062831355093262
# Final cost : 1.0062818275544159
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062818275544159
# Final cost : 1.0062818275544159
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062818275544159
# Final cost : 1.0062687492263391
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062687492263391
# Final cost : 1.0062674415165591
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062674415165591
# Final cost : 1.0062674415165591
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062674415165591
# Final cost : 1.0062543656394176
# Compute control for a deterministic system
# Cost in iteration 0: 1.0062543656394176
# Final cost : 1.0062530581746945
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061307591921396
# Final cost : 1.0061307591921396
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061307591921396
# Final cost : 1.0061307591920656
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061307591920656
# Final cost : 1.0061163904310717
# Compute control for a deterministic system
# Cost in iteration 0: 1.0061163904310717
# ...
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 1.005986653208793
# Final cost : 1.005986653208793
# Compute control for a deterministic system
# Cost in iteration 0: 1.005986653208793
# Final cost : 1.005986653208715
# Compute control for a deterministic system
# Cost in iteration 0: 1.005986653208715
# Final cost : 1.0059712064037882
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059712064037882
# Final cost : 1.0059696619041811
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059696619041811
# Final cost : 1.0059696619041811
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059696619041811
# Final cost : 1.00595421870358
# Compute control for a deterministic system
# Cost in iteration 0: 1.00595421870358
# Final cost : 1.0059526745644818
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059526745644818
# Final cost : 1.0059526745644818
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059526745644818
# Final cost : 1.0059372349697107
# Compute control for a deterministic system
# Cost in iteration 0: 1.0059372349697107
# Final cost : 1.0059356911912702
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058588509539965
# Final cost : 1.0058588509539965
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058588509539965
# Final cost : 1.005858850953914
# Compute control for a deterministic system
# Cost in iteration 0: 1.005858850953914
# Final cost : 1.0058425080227271
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058425080227271
# Final cost : 1.0058408739082574
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058408739082574
# Final cost : 1.0058408739082574
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058408739082574
# Final cost : 1.0058245345372852
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058245345372852
# Final cost : 1.0058229007789734
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058229007789734
# Final cost : 1.0058229007789734
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058229007789734
# Final cost : 1.0058065649709225
# Compute control for a deterministic system
# Cost in iteration 0: 1.0058065649709225
# Final cost : 1.0058049315690376
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057440080707405
# Final cost : 1.0057440080707405
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057440080707405
# Final cost : 1.0057440080706541
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057440080706541
# Final cost : 1.0057269273794518
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057269273794518
# Final cost : 1.005725219476162
# Compute control for a deterministic system
# Cost in iteration 0: 1.005725219476162
# Final cost : 1.005725219476162
# Compute control for a deterministic system
# Cost in iteration 0: 1.005725219476162
# Final cost : 1.0057081420900944
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057081420900944
# Final cost : 1.0057064345174953
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057064345174953
# Final cost : 1.0057064345174953
# Compute control for a deterministic system
# Cost in iteration 0: 1.0057064345174953
# Final cost : 1.005689360440077
# Compute control for a deterministic system
# Cost in iteration 0: 1.005689360440077
# Final cost : 1.0056876531985188
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056395587600195
# Final cost : 1.0056395587600195
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056395587600195
# Final cost : 1.0056395587599292
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056395587599292
# Final cost : 1.0056218765796316
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056218765796316
# Final cost : 1.0056201085091647
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056201085091647
# Final cost : 1.0056201085091647
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056201085091647
# Final cost : 1.005602429270195
# Compute control for a deterministic system
# Cost in iteration 0: 1.005602429270195
# Final cost : 1.0056006614940567
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056006614940567
# Final cost : 1.0056006614940567
# Compute control for a deterministic system
# Cost in iteration 0: 1.0056006614940567
# Final cost : 1.0055829852003144
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055829852003144
# Final cost : 1.005581217718894
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055433959716433
# Final cost : 1.0055433959716433
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055433959716433
# Final cost : 1.005543395971552
# Compute control for a deterministic system
# Cost in iteration 0: 1.005543395971552
# Final cost : 1.0055252275515276
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055252275515276
# Final cost : 1.0055234108368754
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055234108368754
# Final cost : 1.0055234108368754
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055234108368754
# Final cost : 1.0055052449554702
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055052449554702
# Final cost : 1.0055034284948758
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055034284948758
# Final cost : 1.0055034284948758
# Compute control for a deterministic system
# Cost in iteration 0: 1.0055034284948758
# Final cost : 1.0054852651560227
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054852651560227
# Final cost : 1.0054834489498794
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054538043758994
# Final cost : 1.0054538043758994
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054538043758994
# Final cost : 1.0054538043758061
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054538043758061
# Final cost : 1.005435245780236
# Compute control for a deterministic system
# Cost in iteration 0: 1.005435245780236
# Final cost : 1.0054333900280803
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054333900280803
# Final cost : 1.0054333900280803
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054333900280803
# Final cost : 1.0054148335736413
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054148335736413
# Final cost : 1.0054129780357846
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054129780357846
# Final cost : 1.0054129780357846
# Compute control for a deterministic system
# Cost in iteration 0: 1.0054129780357846
# Final cost : 1.0053944237261978
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053944237261978
# Final cost : 1.0053925684030132
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 1.005369397835565
# Final cost : 1.005369397835565
# Compute control for a deterministic system
# Cost in iteration 0: 1.005369397835565
# Final cost : 1.0053693978354685
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053693978354685
# Final cost : 1.0053505281541277
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053505281541277
# Final cost : 1.005348641274978
# Compute control for a deterministic system
# Cost in iteration 0: 1.005348641274978
# Final cost : 1.005348641274978
# Compute control for a deterministic system
# Cost in iteration 0: 1.005348641274978
# Final cost : 1.0053297733677145
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053297733677145
# Final cost : 1.0053278866661397
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053278866661397
# Final cost : 1.0053278866661397
# Compute control for a deterministic system
# Cost in iteration 0: 1.0053278866661397
# Final cost : 1.005309020536314
# Compute control for a deterministic system
# Cost in iteration 0: 1.005309020536314
# Final cost : 1.0053071340126538
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052890643115817
# Final cost : 1.0052890643115817
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052890643115817
# Final cost : 1.005289064311483
# Compute control for a deterministic system
# Cost in iteration 0: 1.005289064311483
# Final cost : 1.0052699479656773
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052699479656773
# Final cost : 1.0052680364038022
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052680364038022
# Final cost : 1.0052680364038022
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052680364038022
# Final cost : 1.0052489215075993
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052489215075993
# Final cost : 1.0052470100908328
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052470100908328
# Final cost : 1.0052470100908328
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052470100908328
# Final cost : 1.0052278966471717
# Compute control for a deterministic system
# Cost in iteration 0: 1.0052278966471717
# Final cost : 1.0052259853758068
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 1.005211921420663
# Final cost : 1.005211921420663
# Compute control for a deterministic system
# Cost in iteration 0: 1.005211921420663
# Final cost : 1.005211921420564
# Compute control for a deterministic system
# Cost in iteration 0: 1.005211921420564
# Final cost : 1.0051926103742572
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051926103742572
# Final cost : 1.0051906793283751
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051906793283751
# Final cost : 1.0051906793283751
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051906793283751
# Final cost : 1.0051713694534372
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051713694534372
# Final cost : 1.005169438524818
# Compute control for a deterministic system
# Cost in iteration 0: 1.005169438524818
# Final cost : 1.005169438524818
# Compute control for a deterministic system
# Cost in iteration 0: 1.005169438524818
# Final cost : 1.0051501298237495
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051501298237495
# Final cost : 1.0051481990126425
# 18
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051372860971073
# Final cost : 1.0051372860971073
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051372860971073
# Final cost : 1.0051372860970083
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051372860970083
# Final cost : 1.0051178218723693
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051178218723693
# Final cost : 1.0051158754969407
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051158754969407
# Final cost : 1.0051158754969407
# Compute control for a deterministic system
# Cost in iteration 0: 1.0051158754969407
# Final cost : 1.0050964122101627
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050964122101627
# Final cost : 1.0050944659286258
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050944659286258
# Final cost : 1.0050944659286258
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050944659286258
# Final cost : 1.0050750035817968
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050750035817968
# Final cost : 1.0050730573943583
# 19
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050646259306584
# Final cost : 1.0050646259306584
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050646259306584
# Final cost : 1.0050646259305593
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050646259305593
# Final cost : 1.0050450415762275
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050450415762275
# Final cost : 1.0050430831781623
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050430831781623
# Final cost : 1.0050430831781623
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050430831781623
# Final cost : 1.0050234995689502
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050234995689502
# Final cost : 1.0050215412454833
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050215412454833
# Final cost : 1.0050215412454833
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050215412454833
# Final cost : 1.0050019583831042
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050019583831042
# Final cost : 1.0050000001344088
# 20
# Compute control for a deterministic system
# Cost in iteration 0: 0.9569090349765087
# Final cost : 0.9569090349765087
# Compute control for a deterministic system
# Cost in iteration 0: 0.9569090349765087
# Final cost : 0.9569090349746112
# Compute control for a deterministic system
# Cost in iteration 0: 0.9569090349746112
# Final cost : 0.9567223860374691
# Compute control for a deterministic system
# Cost in iteration 0: 0.9567223860374691
# Final cost : 0.9567141899040561
# Compute control for a deterministic system
# Cost in iteration 0: 0.9567141899040561
# Final cost : 0.9567141899040561
# Compute control for a deterministic system
# Cost in iteration 0: 0.9567141899040561
# Final cost : 0.9566546394692016
# Compute control for a deterministic system
# Cost in iteration 0: 0.9566546394692016
# Final cost : 0.9566504339309271
# Compute control for a deterministic system
# Cost in iteration 0: 0.9566504339309271
# Converged in iteration 1 with cost 0.9566504339309271 because of vanishing difference
# Final cost : 0.9566504339309271
# Compute control for a deterministic system
# Cost in iteration 0: 0.9566504339309271
# Final cost : 0.9566200612777199
# Compute control for a deterministic system
# Cost in iteration 0: 0.9566200612777199
# Final cost : 0.9566179710861978
# 21
# Compute control for a deterministic system
# Cost in iteration 0: 3.608743274958983
# Final cost : 3.608743274958983
# Compute control for a deterministic system
# Cost in iteration 0: 3.608743274958983
# Final cost : 3.608743274944098
# Compute control for a deterministic system
# Cost in iteration 0: 3.608743274944098
# Final cost : 3.605510891094405
# Compute control for a deterministic system
# Cost in iteration 0: 3.605510891094405
# Final cost : 3.6051491041865154
# Compute control for a deterministic system
# Cost in iteration 0: 3.6051491041865154
# Final cost : 3.6051491041865154
# Compute control for a deterministic system
# Cost in iteration 0: 3.6051491041865154
# Final cost : 3.601022629853695
# Compute control for a deterministic system
# Cost in iteration 0: 3.601022629853695
# Final cost : 3.6005501554451493
# Compute control for a deterministic system
# Cost in iteration 0: 3.6005501554451493
# Converged in iteration 1 with cost 3.6005501554451493 because of vanishing difference
# Final cost : 3.6005501554451493
# Compute control for a deterministic system
# Cost in iteration 0: 3.6005501554451493
# Final cost : 3.5950175335229475
# Compute control for a deterministic system
# Cost in iteration 0: 3.5950175335229475
# Final cost : 3.594366195829071
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 3.598751223049498
# Final cost : 3.598751223049498
# Compute control for a deterministic system
# Cost in iteration 0: 3.598751223049498
# Final cost : 3.598751223025733
# Compute control for a deterministic system
# Cost in iteration 0: 3.598751223025733
# Final cost : 3.593269247673092
# Compute control for a deterministic system
# Cost in iteration 0: 3.593269247673092
# Final cost : 3.592625334084811
# Compute control for a deterministic system
# Cost in iteration 0: 3.592625334084811
# Converged in iteration 1 with cost 3.592625334084811 because of vanishing difference
# Final cost : 3.592625334084811
# Compute control for a deterministic system
# Cost in iteration 0: 3.592625334084811
# Final cost : 3.584807622766704
# Compute control for a deterministic system
# Cost in iteration 0: 3.584807622766704
# Final cost : 3.5838507170116443

# %%
for i in range(len(duration_array)):
    print("duration ", duration_array[i])
    print("amplitude = ", np.amax(results_w1_du["control"][i]))
    
    print(results_w1_du["cost"][i], results_w1_du["L_cost"][i][0], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# duration  22
# amplitude =  5.264732399418205
# 1.2109591404693338 45.58108536518756 2.794785708126779
# duration  25
# amplitude =  3.5735598511367077
# 0.9358973889688555 45.58108536518756 2.794785708126779
# duration  28
# amplitude =  3.195891676348417
# 0.9029521075572713 45.58108536518756 2.794785708126779
# duration  36
# amplitude =  2.7588793436686383
# 0.8510250999233362 45.58108536518756 2.794785708126779
# duration  60
# amplitude =  2.3413445525984
# 0.9380842706268454 45.58108536518756 2.794785708126779
# duration  80
# amplitude =  2.3049887247010896
# 0.9566179710861978 45.58108536518756 2.794785708126779

# %%
save(results_w1_du, fname)

# %%
fname = 'w1_du_T'
