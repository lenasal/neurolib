# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc


# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 1, 2, 3, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w1_ud = dict([
    ('cost_type', 'w1'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("l1_ud.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

# %%
def save(results_dict):
    filehandler = open("l1_ud.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

# %%
with open('l1_ud.pickle', 'rb') as f:
    results_w1_ud = pickle.load(f)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w1_ud['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w1_ud['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_ud['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 200.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    if i not in [9]:
        continue

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_ud['d'][i] )
    setinit( results_w1_ud['u'][i] )

    #if type(results_w2_du["control"][i]) != type(None):
    #    continue

    #results_w1_ud["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w1_ud, i)

    if False:

        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w1_ud["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-300:-200] = -6.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()
        control_e = wc_controlled.control.copy()

        wc_controlled.control = control_e.copy()
        wc_controlled.update_input()

        wc_controlled.optimize(0)    
        get_values(results_w1_ud, i, w1)
        save(results_w1_ud)

        plt.plot(wc_controlled.get_xs()[0,0,:])
        plt.show()

        break
    
    for k in range(200):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)


        if results_w1_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_ud, i, w1)
            save(results_w1_ud)
        elif wc_controlled.cost_history[-1] < 2.9:
            break
        else: break

    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)
        wc_controlled.step_factor = 0.5

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        if results_w1_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_ud, i, w1)
            save(results_w1_ud)
        elif wc_controlled.cost_history[-1] < 2.9:
            break
        else: break

    save(results_w1_ud)
# Out:
# POINT  1
# POINT  2
# POINT  3
# POINT  4
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# POINT  9
# POINT  10
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 3.1520858249236885
# Final cost : 3.1520858249236885
# Compute control for a deterministic system
# Cost in iteration 0: 3.1520858249236885
# Final cost : 3.1509629946259956
# Compute control for a deterministic system
# Cost in iteration 0: 3.1509629946259956
# Final cost : 3.150961745392987
# Compute control for a deterministic system
# Cost in iteration 0: 3.150961745392987
# Final cost : 3.1509617452913257
# Compute control for a deterministic system
# Cost in iteration 0: 3.1509617452913257
# Final cost : 3.150961745290309
# Compute control for a deterministic system
# Cost in iteration 0: 3.150961745290309
# Final cost : 3.150961745290299
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 3.144620681933868
# Final cost : 3.144620681933868
# Compute control for a deterministic system
# Cost in iteration 0: 3.144620681933868
# Final cost : 3.1437395816353435
# Compute control for a deterministic system
# Cost in iteration 0: 3.1437395816353435
# Final cost : 3.14373955800335
# Compute control for a deterministic system
# Cost in iteration 0: 3.14373955800335
# Converged in iteration 76 with cost 3.143739557949255 because of vanishing difference
# Final cost : 3.143739557949255
# Compute control for a deterministic system
# Cost in iteration 0: 3.143739557949255
# Final cost : 3.1437395579492486
# Compute control for a deterministic system
# Cost in iteration 0: 3.1437395579492486
# Final cost : 3.1437395579492478
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 3.1397016451123485
# Final cost : 3.1397016451123485
# Compute control for a deterministic system
# Cost in iteration 0: 3.1397016451123485
# Final cost : 3.139022592461121
# Compute control for a deterministic system
# Cost in iteration 0: 3.139022592461121
# Final cost : 3.139022583392987
# Compute control for a deterministic system
# Cost in iteration 0: 3.139022583392987
# Converged in iteration 1 with cost 3.139022583392987 because of vanishing difference
# Final cost : 3.139022583392987
# Compute control for a deterministic system
# Cost in iteration 0: 3.139022583392987
# Final cost : 3.139022583392987
# Compute control for a deterministic system
# Cost in iteration 0: 3.139022583392987
# Final cost : 3.139022583392987
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 3.1365644622031175
# Final cost : 3.1365644622031175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1365644622031175
# Final cost : 3.136048114041676
# Compute control for a deterministic system
# Cost in iteration 0: 3.136048114041676
# Final cost : 3.1360481025561526
# Compute control for a deterministic system
# Cost in iteration 0: 3.1360481025561526
# Converged in iteration 1 with cost 3.1360481025561526 because of vanishing difference
# Final cost : 3.1360481025561526
# Compute control for a deterministic system
# Cost in iteration 0: 3.1360481025561526
# Final cost : 3.1360481025561526
# Compute control for a deterministic system
# Cost in iteration 0: 3.1360481025561526
# Final cost : 3.1360481025561526
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 3.134606939998921
# Final cost : 3.134606939998921
# Compute control for a deterministic system
# Cost in iteration 0: 3.134606939998921
# Final cost : 3.1342329041867183
# Compute control for a deterministic system
# Cost in iteration 0: 3.1342329041867183
# Final cost : 3.1342328909241037
# Compute control for a deterministic system
# Cost in iteration 0: 3.1342328909241037
# Converged in iteration 1 with cost 3.1342328909241037 because of vanishing difference
# Final cost : 3.1342328909241037
# Compute control for a deterministic system
# Cost in iteration 0: 3.1342328909241037
# Final cost : 3.1342328909241037
# Compute control for a deterministic system
# Cost in iteration 0: 3.1342328909241037
# Final cost : 3.1342328909241037
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 3.1334177566521846
# Final cost : 3.1334177566521846
# Compute control for a deterministic system
# Cost in iteration 0: 3.1334177566521846
# Final cost : 3.1331593394848007
# Compute control for a deterministic system
# Cost in iteration 0: 3.1331593394848007
# Final cost : 3.133159325082348
# Compute control for a deterministic system
# Cost in iteration 0: 3.133159325082348
# Converged in iteration 1 with cost 3.133159325082348 because of vanishing difference
# Final cost : 3.133159325082348
# Compute control for a deterministic system
# Cost in iteration 0: 3.133159325082348
# Final cost : 3.133159325082348
# Compute control for a deterministic system
# Cost in iteration 0: 3.133159325082348
# Final cost : 3.133159325082348
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 3.1327137237738727
# Final cost : 3.1327137237738727
# Compute control for a deterministic system
# Cost in iteration 0: 3.1327137237738727
# Final cost : 3.1325433652215033
# Compute control for a deterministic system
# Cost in iteration 0: 3.1325433652215033
# Final cost : 3.132543350154199
# Compute control for a deterministic system
# Cost in iteration 0: 3.132543350154199
# Converged in iteration 5 with cost 3.1325433501541964 because of vanishing difference
# Final cost : 3.1325433501541964
# Compute control for a deterministic system
# Cost in iteration 0: 3.1325433501541964
# Final cost : 3.1325433501541964
# Compute control for a deterministic system
# Cost in iteration 0: 3.1325433501541964
# Final cost : 3.1325433501541964
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 3.132306320067427
# Final cost : 3.132306320067427
# Compute control for a deterministic system
# Cost in iteration 0: 3.132306320067427
# Final cost : 3.132199930533892
# Compute control for a deterministic system
# Cost in iteration 0: 3.132199930533892
# Final cost : 3.132199915087933
# Compute control for a deterministic system
# Cost in iteration 0: 3.132199915087933
# Converged in iteration 1 with cost 3.132199915087933 because of vanishing difference
# Final cost : 3.132199915087933
# Compute control for a deterministic system
# Cost in iteration 0: 3.132199915087933
# Final cost : 3.132199915087933
# Compute control for a deterministic system
# Cost in iteration 0: 3.132199915087933
# Final cost : 3.132199915087933
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320746652171176
# Final cost : 3.1320746652171176
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320746652171176
# Final cost : 3.1320130934506687
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320130934506687
# Final cost : 3.1320130777956225
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320130777956225
# Converged in iteration 1 with cost 3.1320130777956225 because of vanishing difference
# Final cost : 3.1320130777956225
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320130777956225
# Final cost : 3.1320130777956225
# Compute control for a deterministic system
# Cost in iteration 0: 3.1320130777956225
# Final cost : 3.1320130777956225
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 3.13194383514801
# Final cost : 3.13194383514801
# Compute control for a deterministic system
# Cost in iteration 0: 3.13194383514801
# Final cost : 3.131912867119438
# Compute control for a deterministic system
# Cost in iteration 0: 3.131912867119438
# Final cost : 3.131912851153608
# Compute control for a deterministic system
# Cost in iteration 0: 3.131912851153608
# Converged in iteration 1 with cost 3.131912851153608 because of vanishing difference
# Final cost : 3.131912851153608
# Compute control for a deterministic system
# Cost in iteration 0: 3.131912851153608
# Final cost : 3.131912851153608
# Compute control for a deterministic system
# Cost in iteration 0: 3.131912851153608
# Final cost : 3.131912851153608
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318687034682506
# Final cost : 3.1318687034682506
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318687034682506
# Final cost : 3.1318580012453294
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318580012453294
# Final cost : 3.131857984988522
# Compute control for a deterministic system
# Cost in iteration 0: 3.131857984988522
# Converged in iteration 1 with cost 3.131857984988522 because of vanishing difference
# Final cost : 3.131857984988522
# Compute control for a deterministic system
# Cost in iteration 0: 3.131857984988522
# Final cost : 3.131857984988522
# Compute control for a deterministic system
# Cost in iteration 0: 3.131857984988522
# Final cost : 3.131857984988522
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318216790917397
# Final cost : 3.1318216790917397
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318216790917397
# Final cost : 3.1318214048512183
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318214048512183
# Final cost : 3.1318213896738833
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318213896738833
# Converged in iteration 1 with cost 3.1318213896738833 because of vanishing difference
# Final cost : 3.1318213896738833
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318213896738833
# Final cost : 3.1318213896738833
# Compute control for a deterministic system
# Cost in iteration 0: 3.1318213896738833
# Final cost : 3.1318213896738833
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 3.131779281426482
# Final cost : 3.131779281426482
# Compute control for a deterministic system
# Cost in iteration 0: 3.131779281426482
# Final cost : 3.131778676233829
# Compute control for a deterministic system
# Cost in iteration 0: 3.131778676233829
# Final cost : 3.1317786609652565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317786609652565
# Converged in iteration 1 with cost 3.1317786609652565 because of vanishing difference
# Final cost : 3.1317786609652565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317786609652565
# Final cost : 3.1317786609652565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317786609652565
# Final cost : 3.1317786609652565
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 3.131739670609246
# Final cost : 3.131739670609246
# Compute control for a deterministic system
# Cost in iteration 0: 3.131739670609246
# Final cost : 3.1317384348560022
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317384348560022
# Final cost : 3.131738421300815
# Compute control for a deterministic system
# Cost in iteration 0: 3.131738421300815
# Converged in iteration 2 with cost 3.1317384213008146 because of vanishing difference
# Final cost : 3.1317384213008146
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317384213008146
# Final cost : 3.1317384213008146
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317384213008146
# Final cost : 3.1317384213008146
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 3.131710979738777
# Final cost : 3.131710979738777
# Compute control for a deterministic system
# Cost in iteration 0: 3.131710979738777
# Final cost : 3.131708205280142
# Compute control for a deterministic system
# Cost in iteration 0: 3.131708205280142
# Final cost : 3.1317081921242784
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317081921242784
# Converged in iteration 1 with cost 3.1317081921242784 because of vanishing difference
# Final cost : 3.1317081921242784
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317081921242784
# Final cost : 3.1317081921242784
# Compute control for a deterministic system
# Cost in iteration 0: 3.1317081921242784
# Final cost : 3.1317081921242784
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 3.13169086556085
# Final cost : 3.13169086556085
# Compute control for a deterministic system
# Cost in iteration 0: 3.13169086556085
# Final cost : 3.1316878402156876
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316878402156876
# Final cost : 3.131687827578177
# Compute control for a deterministic system
# Cost in iteration 0: 3.131687827578177
# Converged in iteration 1 with cost 3.131687827578177 because of vanishing difference
# Final cost : 3.131687827578177
# Compute control for a deterministic system
# Cost in iteration 0: 3.131687827578177
# Final cost : 3.131687827578177
# Compute control for a deterministic system
# Cost in iteration 0: 3.131687827578177
# Final cost : 3.131687827578177
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 3.131677631826896
# Final cost : 3.131677631826896
# Compute control for a deterministic system
# Cost in iteration 0: 3.131677631826896
# Final cost : 3.131675060449836
# Compute control for a deterministic system
# Cost in iteration 0: 3.131675060449836
# Final cost : 3.1316750482937565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316750482937565
# Converged in iteration 1 with cost 3.1316750482937565 because of vanishing difference
# Final cost : 3.1316750482937565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316750482937565
# Final cost : 3.1316750482937565
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316750482937565
# Final cost : 3.1316750482937565
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316693640892574
# Final cost : 3.1316693640892574
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316693640892574
# Final cost : 3.131667458225577
# Compute control for a deterministic system
# Cost in iteration 0: 3.131667458225577
# Final cost : 3.1316674519838363
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316674519838363
# Converged in iteration 1 with cost 3.1316674519838363 because of vanishing difference
# Final cost : 3.1316674519838363
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316674519838363
# Final cost : 3.1316674519838363
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316674519838363
# Final cost : 3.1316674519838363
# 18
# Compute control for a deterministic system
# Cost in iteration 0: 3.13166440829464
# Final cost : 3.13166440829464
# Compute control for a deterministic system
# Cost in iteration 0: 3.13166440829464
# Final cost : 3.131663130517767
# Compute control for a deterministic system
# Cost in iteration 0: 3.131663130517767
# Final cost : 3.1316631272970015
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316631272970015
# Converged in iteration 3 with cost 3.131663127297 because of vanishing difference
# Final cost : 3.131663127297
# Compute control for a deterministic system
# Cost in iteration 0: 3.131663127297
# Final cost : 3.131663127297
# Compute control for a deterministic system
# Cost in iteration 0: 3.131663127297
# Final cost : 3.131663127297
# 19
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316615027516477
# Final cost : 3.1316615027516477
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316615027516477
# Final cost : 3.1316607473623956
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316607473623956
# Final cost : 3.131660745666455
# Compute control for a deterministic system
# Cost in iteration 0: 3.131660745666455
# Converged in iteration 2 with cost 3.131660745666454 because of vanishing difference
# Final cost : 3.131660745666454
# Compute control for a deterministic system
# Cost in iteration 0: 3.131660745666454
# Final cost : 3.131660745666454
# Compute control for a deterministic system
# Cost in iteration 0: 3.131660745666454
# Final cost : 3.131660745666454
# 20
# Compute control for a deterministic system
# Cost in iteration 0: 3.131659849340055
# Final cost : 3.131659849340055
# Compute control for a deterministic system
# Cost in iteration 0: 3.131659849340055
# Final cost : 3.1316594567385243
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316594567385243
# Final cost : 3.131659455685819
# Compute control for a deterministic system
# Cost in iteration 0: 3.131659455685819
# Converged in iteration 3 with cost 3.1316594556858175 because of vanishing difference
# Final cost : 3.1316594556858175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316594556858175
# Final cost : 3.1316594556858175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316594556858175
# Final cost : 3.1316594556858175
# 21
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316588761197646
# Final cost : 3.1316588761197646
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316588761197646
# Final cost : 3.1316587465865924
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316587465865924
# Final cost : 3.1316587436583716
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316587436583716
# Converged in iteration 2 with cost 3.1316587436583703 because of vanishing difference
# Final cost : 3.1316587436583703
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316587436583703
# Final cost : 3.1316587436583703
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316587436583703
# Final cost : 3.1316587436583703
# 22
# Compute control for a deterministic system
# Cost in iteration 0: 3.131658256225718
# Final cost : 3.131658256225718
# Compute control for a deterministic system
# Cost in iteration 0: 3.131658256225718
# Final cost : 3.131658250590771
# Compute control for a deterministic system
# Cost in iteration 0: 3.131658250590771
# Final cost : 3.1316582485528803
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316582485528803
# Converged in iteration 1 with cost 3.1316582485528803 because of vanishing difference
# Final cost : 3.1316582485528803
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316582485528803
# Final cost : 3.1316582485528803
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316582485528803
# Final cost : 3.1316582485528803
# 23
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576652302697
# Final cost : 3.1316576652302697
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576652302697
# Final cost : 3.1316576594578702
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576594578702
# Final cost : 3.1316576575719033
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576575719033
# Converged in iteration 2 with cost 3.1316576575719015 because of vanishing difference
# Final cost : 3.1316576575719015
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576575719015
# Final cost : 3.1316576575719015
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316576575719015
# Final cost : 3.1316576575719015
# 24
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316571313669566
# Final cost : 3.1316571313669566
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316571313669566
# Final cost : 3.1316571127318245
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316571127318245
# Final cost : 3.131657111884924
# Compute control for a deterministic system
# Cost in iteration 0: 3.131657111884924
# Converged in iteration 1 with cost 3.131657111884924 because of vanishing difference
# Final cost : 3.131657111884924
# Compute control for a deterministic system
# Cost in iteration 0: 3.131657111884924
# Final cost : 3.131657111884924
# Compute control for a deterministic system
# Cost in iteration 0: 3.131657111884924
# Final cost : 3.131657111884924
# 25
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316567423722574
# Final cost : 3.1316567423722574
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316567423722574
# Final cost : 3.131656705706171
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656705706171
# Final cost : 3.1316567051615976
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316567051615976
# Converged in iteration 1 with cost 3.1316567051615976 because of vanishing difference
# Final cost : 3.1316567051615976
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316567051615976
# Final cost : 3.1316567051615976
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316567051615976
# Final cost : 3.1316567051615976
# 26
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316564725821383
# Final cost : 3.1316564725821383
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316564725821383
# Final cost : 3.131656431717064
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656431717064
# Final cost : 3.1316564313630377
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316564313630377
# Converged in iteration 2 with cost 3.131656431363037 because of vanishing difference
# Final cost : 3.131656431363037
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656431363037
# Final cost : 3.131656431363037
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656431363037
# Final cost : 3.131656431363037
# 27
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656293116523
# Final cost : 3.131656293116523
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656293116523
# Final cost : 3.131656259393548
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656259393548
# Final cost : 3.1316562591495196
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316562591495196
# Converged in iteration 1 with cost 3.1316562591495196 because of vanishing difference
# Final cost : 3.1316562591495196
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316562591495196
# Final cost : 3.1316562591495196
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316562591495196
# Final cost : 3.1316562591495196
# 28
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561817905155
# Final cost : 3.1316561817905155
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561817905155
# Final cost : 3.1316561564784013
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561564784013
# Final cost : 3.1316561563237353
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561563237353
# Converged in iteration 2 with cost 3.131656156323735 because of vanishing difference
# Final cost : 3.131656156323735
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656156323735
# Final cost : 3.131656156323735
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656156323735
# Final cost : 3.131656156323735
# 29
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561147764266
# Final cost : 3.1316561147764266
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316561147764266
# Converged in iteration 122 with cost 3.1316560975993046 because of vanishing difference
# Final cost : 3.1316560975993046
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560975993046
# Final cost : 3.1316560975039445
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560975039445
# Converged in iteration 1 with cost 3.1316560975039445 because of vanishing difference
# Final cost : 3.1316560975039445
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560975039445
# Final cost : 3.1316560975039445
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560975039445
# Final cost : 3.1316560975039445
# 30
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560751725104
# Final cost : 3.1316560751725104
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560751725104
# Final cost : 3.1316560650179928
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560650179928
# Final cost : 3.1316560649423777
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560649423777
# Converged in iteration 3 with cost 3.1316560649423764 because of vanishing difference
# Final cost : 3.1316560649423764
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560649423764
# Final cost : 3.1316560649423764
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560649423764
# Final cost : 3.1316560649423764
# 31
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165605282633
# Final cost : 3.13165605282633
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165605282633
# Converged in iteration 93 with cost 3.1316560473670996 because of vanishing difference
# Final cost : 3.1316560473670996
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560473670996
# Final cost : 3.1316560473548143
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560473548143
# Converged in iteration 2 with cost 3.1316560473548134 because of vanishing difference
# Final cost : 3.1316560473548134
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560473548134
# Final cost : 3.1316560473548134
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560473548134
# Final cost : 3.1316560473548134
# 32
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560398476194
# Final cost : 3.1316560398476194
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560398476194
# Converged in iteration 164 with cost 3.131656037761599 because of vanishing difference
# Final cost : 3.131656037761599
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656037761599
# Final cost : 3.1316560377509033
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560377509033
# Converged in iteration 3 with cost 3.1316560377509024 because of vanishing difference
# Final cost : 3.1316560377509024
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560377509024
# Final cost : 3.1316560377509024
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560377509024
# Final cost : 3.1316560377509024
# 33
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560318014437
# Final cost : 3.1316560318014437
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560318014437
# Final cost : 3.1316560316901234
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560316901234
# Converged in iteration 97 with cost 3.131656031677508 because of vanishing difference
# Final cost : 3.131656031677508
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656031677508
# Converged in iteration 2 with cost 3.1316560316775064 because of vanishing difference
# Final cost : 3.1316560316775064
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560316775064
# Final cost : 3.1316560316775064
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560316775064
# Final cost : 3.1316560316775064
# 34
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560249811047
# Final cost : 3.1316560249811047
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560249811047
# Final cost : 3.1316560247986684
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560247986684
# Converged in iteration 165 with cost 3.131656024782235 because of vanishing difference
# Final cost : 3.131656024782235
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656024782235
# Converged in iteration 2 with cost 3.131656024782233 because of vanishing difference
# Final cost : 3.131656024782233
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656024782233
# Final cost : 3.131656024782233
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656024782233
# Final cost : 3.131656024782233
# 35
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656018103145
# Final cost : 3.131656018103145
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656018103145
# Converged in iteration 63 with cost 3.1316560179645667 because of vanishing difference
# Final cost : 3.1316560179645667
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560179645667
# Converged in iteration 28 with cost 3.1316560179614052 because of vanishing difference
# Final cost : 3.1316560179614052
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560179614052
# Converged in iteration 4 with cost 3.1316560179614035 because of vanishing difference
# Final cost : 3.1316560179614035
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560179614035
# Final cost : 3.1316560179614035
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560179614035
# Final cost : 3.1316560179614035
# 36
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560131351445
# Final cost : 3.1316560131351445
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560131351445
# Converged in iteration 122 with cost 3.1316560127199753 because of vanishing difference
# Final cost : 3.1316560127199753
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560127199753
# Converged in iteration 174 with cost 3.1316560127139486 because of vanishing difference
# Final cost : 3.1316560127139486
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560127139486
# Converged in iteration 3 with cost 3.1316560127139472 because of vanishing difference
# Final cost : 3.1316560127139472
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560127139472
# Final cost : 3.1316560127139472
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560127139472
# Final cost : 3.1316560127139472
# 37
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656009625789
# Final cost : 3.131656009625789
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656009625789
# Final cost : 3.1316560091297903
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560091297903
# Final cost : 3.13165600912558
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600912558
# Converged in iteration 1 with cost 3.13165600912558 because of vanishing difference
# Final cost : 3.13165600912558
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600912558
# Final cost : 3.13165600912558
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600912558
# Final cost : 3.13165600912558
# 38
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656007282431
# Final cost : 3.131656007282431
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656007282431
# Converged in iteration 74 with cost 3.1316560068476136 because of vanishing difference
# Final cost : 3.1316560068476136
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560068476136
# Converged in iteration 94 with cost 3.1316560068464403 because of vanishing difference
# Final cost : 3.1316560068464403
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560068464403
# Converged in iteration 1 with cost 3.1316560068464403 because of vanishing difference
# Final cost : 3.1316560068464403
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560068464403
# Final cost : 3.1316560068464403
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560068464403
# Final cost : 3.1316560068464403
# 39
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656005797825
# Final cost : 3.131656005797825
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656005797825
# Converged in iteration 13 with cost 3.1316560054750173 because of vanishing difference
# Final cost : 3.1316560054750173
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560054750173
# Converged in iteration 23 with cost 3.1316560054748646 because of vanishing difference
# Final cost : 3.1316560054748646
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560054748646
# Converged in iteration 2 with cost 3.131656005474863 because of vanishing difference
# Final cost : 3.131656005474863
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656005474863
# Final cost : 3.131656005474863
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656005474863
# Final cost : 3.131656005474863
# 40
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560049079367
# Final cost : 3.1316560049079367
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560049079367
# Converged in iteration 19 with cost 3.1316560046846496 because of vanishing difference
# Final cost : 3.1316560046846496
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560046846496
# Converged in iteration 74 with cost 3.1316560046843516 because of vanishing difference
# Final cost : 3.1316560046843516
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560046843516
# Converged in iteration 3 with cost 3.13165600468435 because of vanishing difference
# Final cost : 3.13165600468435
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600468435
# Final cost : 3.13165600468435
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600468435
# Final cost : 3.13165600468435
# 41
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656004382635
# Final cost : 3.131656004382635
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656004382635
# Converged in iteration 12 with cost 3.1316560042450505 because of step counter
# Final cost : 3.1316560042450505
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560042450505
# Converged in iteration 1 with cost 3.1316560042450505 because of vanishing difference
# Final cost : 3.1316560042450505
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560042450505
# Converged in iteration 2 with cost 3.131656004245049 because of vanishing difference
# Final cost : 3.131656004245049
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656004245049
# Final cost : 3.131656004245049
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656004245049
# Final cost : 3.131656004245049
# 42
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560040818278
# Final cost : 3.1316560040818278
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560040818278
# Converged in iteration 2 with cost 3.13165600400675 because of step counter
# Final cost : 3.13165600400675
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600400675
# Converged in iteration 2 with cost 3.131656004006722 because of vanishing difference
# Final cost : 3.131656004006722
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656004006722
# Converged in iteration 2 with cost 3.1316560040067216 because of vanishing difference
# Final cost : 3.1316560040067216
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560040067216
# Final cost : 3.1316560040067216
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560040067216
# Final cost : 3.1316560040067216
# 43
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003908343
# Final cost : 3.131656003908343
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003908343
# Converged in iteration 1 with cost 3.131656003908343 because of step counter
# Final cost : 3.131656003908343
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003908343
# Converged in iteration 12 with cost 3.131656003877344 because of step counter
# Final cost : 3.131656003877344
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003877344
# Converged in iteration 1 with cost 3.131656003877344 because of vanishing difference
# Final cost : 3.131656003877344
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003877344
# Final cost : 3.131656003877344
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003877344
# Final cost : 3.131656003877344
# 44
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003803232
# Final cost : 3.131656003803232
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003803232
# Converged in iteration 2 with cost 3.1316560038022674 because of step counter
# Final cost : 3.1316560038022674
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560038022674
# Converged in iteration 11 with cost 3.1316560037998253 because of vanishing difference
# Final cost : 3.1316560037998253
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037998253
# Converged in iteration 1 with cost 3.1316560037998253 because of vanishing difference
# Final cost : 3.1316560037998253
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037998253
# Final cost : 3.1316560037998253
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037998253
# Final cost : 3.1316560037998253
# 45
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003721958
# Final cost : 3.131656003721958
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003721958
# Converged in iteration 1 with cost 3.131656003721958 because of step counter
# Final cost : 3.131656003721958
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003721958
# Converged in iteration 10 with cost 3.1316560037190984 because of vanishing difference
# Final cost : 3.1316560037190984
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037190984
# Converged in iteration 1 with cost 3.1316560037190984 because of vanishing difference
# Final cost : 3.1316560037190984
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037190984
# Final cost : 3.1316560037190984
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560037190984
# Final cost : 3.1316560037190984
# 46
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560036346015
# Final cost : 3.1316560036346015
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560036346015
# Converged in iteration 1 with cost 3.1316560036346015 because of step counter
# Final cost : 3.1316560036346015
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560036346015
# Converged in iteration 4 with cost 3.131656003633481 because of step counter
# Final cost : 3.131656003633481
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003633481
# Converged in iteration 1 with cost 3.131656003633481 because of vanishing difference
# Final cost : 3.131656003633481
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003633481
# Final cost : 3.131656003633481
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003633481
# Final cost : 3.131656003633481
# 47
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003570558
# Final cost : 3.131656003570558
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003570558
# Converged in iteration 1 with cost 3.131656003570558 because of step counter
# Final cost : 3.131656003570558
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003570558
# Converged in iteration 8 with cost 3.1316560035649004 because of vanishing difference
# Final cost : 3.1316560035649004
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560035649004
# Converged in iteration 1 with cost 3.1316560035649004 because of vanishing difference
# Final cost : 3.1316560035649004
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560035649004
# Final cost : 3.1316560035649004
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560035649004
# Final cost : 3.1316560035649004
# 48
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600352399
# Final cost : 3.13165600352399
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600352399
# Converged in iteration 1 with cost 3.13165600352399 because of step counter
# Final cost : 3.13165600352399
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600352399
# Converged in iteration 16 with cost 3.131656003517916 because of step counter
# Final cost : 3.131656003517916
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003517916
# Converged in iteration 1 with cost 3.131656003517916 because of vanishing difference
# Final cost : 3.131656003517916
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003517916
# Final cost : 3.131656003517916
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003517916
# Final cost : 3.131656003517916
# 49
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034932577
# Final cost : 3.1316560034932577
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034932577
# Converged in iteration 1 with cost 3.1316560034932577 because of step counter
# Final cost : 3.1316560034932577
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034932577
# Converged in iteration 8 with cost 3.131656003487716 because of vanishing difference
# Final cost : 3.131656003487716
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003487716
# Converged in iteration 4 with cost 3.131656003487714 because of vanishing difference
# Final cost : 3.131656003487714
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003487714
# Final cost : 3.131656003487714
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003487714
# Final cost : 3.131656003487714
# 50
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003473632
# Final cost : 3.131656003473632
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003473632
# Converged in iteration 1 with cost 3.131656003473632 because of step counter
# Final cost : 3.131656003473632
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003473632
# Converged in iteration 2 with cost 3.1316560034709706 because of step counter
# Final cost : 3.1316560034709706
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034709706
# Converged in iteration 18 with cost 3.1316560034693772 because of vanishing difference
# Final cost : 3.1316560034693772
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034693772
# Final cost : 3.1316560034693772
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034693772
# Final cost : 3.1316560034693772
# 51
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034615586
# Final cost : 3.1316560034615586
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034615586
# Converged in iteration 1 with cost 3.1316560034615586 because of step counter
# Final cost : 3.1316560034615586
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034615586
# Converged in iteration 1 with cost 3.1316560034615586 because of step counter
# Final cost : 3.1316560034615586
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034615586
# Converged in iteration 18 with cost 3.131656003458737 because of vanishing difference
# Final cost : 3.131656003458737
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003458737
# Final cost : 3.131656003458737
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003458737
# Final cost : 3.131656003458737
# 52
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003454688
# Final cost : 3.131656003454688
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003454688
# Converged in iteration 1 with cost 3.131656003454688 because of step counter
# Final cost : 3.131656003454688
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003454688
# Converged in iteration 1 with cost 3.131656003454688 because of step counter
# Final cost : 3.131656003454688
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003454688
# Converged in iteration 11 with cost 3.1316560034527874 because of vanishing difference
# Final cost : 3.1316560034527874
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034527874
# Final cost : 3.1316560034527874
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034527874
# Final cost : 3.1316560034527874
# 53
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034505927
# Final cost : 3.1316560034505927
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034505927
# Converged in iteration 1 with cost 3.1316560034505927 because of step counter
# Final cost : 3.1316560034505927
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034505927
# Converged in iteration 1 with cost 3.1316560034505927 because of step counter
# Final cost : 3.1316560034505927
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034505927
# Converged in iteration 6 with cost 3.131656003449549 because of vanishing difference
# Final cost : 3.131656003449549
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003449549
# Final cost : 3.131656003449549
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003449549
# Final cost : 3.131656003449549
# 54
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034482563
# Final cost : 3.1316560034482563
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034482563
# Converged in iteration 1 with cost 3.1316560034482563 because of step counter
# Final cost : 3.1316560034482563
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034482563
# Converged in iteration 1 with cost 3.1316560034482563 because of step counter
# Final cost : 3.1316560034482563
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034482563
# Converged in iteration 5 with cost 3.131656003447799 because of vanishing difference
# Final cost : 3.131656003447799
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003447799
# Final cost : 3.131656003447799
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003447799
# Final cost : 3.131656003447799
# 55
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446866
# Final cost : 3.131656003446866
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446866
# Converged in iteration 1 with cost 3.131656003446866 because of step counter
# Final cost : 3.131656003446866
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446866
# Converged in iteration 1 with cost 3.131656003446866 because of step counter
# Final cost : 3.131656003446866
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446866
# Converged in iteration 4 with cost 3.131656003446787 because of vanishing difference
# Final cost : 3.131656003446787
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446787
# Final cost : 3.131656003446787
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003446787
# Final cost : 3.131656003446787
# 56
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034458685
# Final cost : 3.1316560034458685
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034458685
# Converged in iteration 1 with cost 3.1316560034458685 because of step counter
# Final cost : 3.1316560034458685
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034458685
# Converged in iteration 1 with cost 3.1316560034458685 because of step counter
# Final cost : 3.1316560034458685
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034458685
# Converged in iteration 2 with cost 3.131656003445843 because of vanishing difference
# Final cost : 3.131656003445843
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003445843
# Final cost : 3.131656003445843
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003445843
# Final cost : 3.131656003445843
# 57
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003444781
# Final cost : 3.131656003444781
# ...
# Final cost : 3.131656003442893
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442893
# Final cost : 3.1316560034428917
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034428917
# Final cost : 3.1316560034428917
# 61
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034426906
# Final cost : 3.1316560034426906
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034426906
# Converged in iteration 1 with cost 3.1316560034426906 because of step counter
# Final cost : 3.1316560034426906
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034426906
# Converged in iteration 1 with cost 3.1316560034426906 because of step counter
# Final cost : 3.1316560034426906
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034426906
# Converged in iteration 9 with cost 3.131656003442648 because of vanishing difference
# Final cost : 3.131656003442648
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442648
# Final cost : 3.131656003442648
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442648
# Final cost : 3.131656003442648
# 62
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442553
# Final cost : 3.131656003442553
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442553
# Converged in iteration 1 with cost 3.131656003442553 because of step counter
# Final cost : 3.131656003442553
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442553
# Converged in iteration 1 with cost 3.131656003442553 because of step counter
# Final cost : 3.131656003442553
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442553
# Converged in iteration 8 with cost 3.1316560034425085 because of vanishing difference
# Final cost : 3.1316560034425085
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034425085
# Final cost : 3.1316560034425036
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034425036
# Final cost : 3.1316560034425027
# 63
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424463
# Final cost : 3.1316560034424463
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424463
# Converged in iteration 1 with cost 3.1316560034424463 because of step counter
# Final cost : 3.1316560034424463
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424463
# Converged in iteration 1 with cost 3.1316560034424463 because of step counter
# Final cost : 3.1316560034424463
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424463
# Converged in iteration 8 with cost 3.1316560034424237 because of vanishing difference
# Final cost : 3.1316560034424237
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424237
# Final cost : 3.1316560034424237
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034424237
# Final cost : 3.1316560034424237
# 64
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442388
# Final cost : 3.131656003442388
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442388
# Converged in iteration 1 with cost 3.131656003442388 because of step counter
# Final cost : 3.131656003442388
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442388
# Converged in iteration 1 with cost 3.131656003442388 because of step counter
# Final cost : 3.131656003442388
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442388
# Converged in iteration 5 with cost 3.13165600344238 because of vanishing difference
# Final cost : 3.13165600344238
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344238
# Final cost : 3.131656003442377
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442377
# Final cost : 3.131656003442377
# 65
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442361
# Final cost : 3.131656003442361
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442361
# Converged in iteration 1 with cost 3.131656003442361 because of step counter
# Final cost : 3.131656003442361
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442361
# Converged in iteration 1 with cost 3.131656003442361 because of step counter
# Final cost : 3.131656003442361
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442361
# Converged in iteration 2 with cost 3.1316560034423597 because of step counter
# Final cost : 3.1316560034423597
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423597
# Final cost : 3.1316560034423557
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423557
# Final cost : 3.131656003442355
# 66
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442343
# Final cost : 3.131656003442343
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442343
# Converged in iteration 1 with cost 3.131656003442343 because of step counter
# Final cost : 3.131656003442343
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442343
# Converged in iteration 1 with cost 3.131656003442343 because of step counter
# Final cost : 3.131656003442343
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442343
# Converged in iteration 2 with cost 3.131656003442341 because of step counter
# Final cost : 3.131656003442341
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442341
# Final cost : 3.131656003442341
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442341
# Final cost : 3.131656003442341
# 67
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Final cost : 3.1316560034423304
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Converged in iteration 1 with cost 3.1316560034423304 because of step counter
# Final cost : 3.1316560034423304
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Converged in iteration 1 with cost 3.1316560034423304 because of step counter
# Final cost : 3.1316560034423304
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Converged in iteration 1 with cost 3.1316560034423304 because of vanishing difference
# Final cost : 3.1316560034423304
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Final cost : 3.1316560034423304
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423304
# Final cost : 3.1316560034423304
# 68
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423175
# Final cost : 3.1316560034423175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423175
# Converged in iteration 1 with cost 3.1316560034423175 because of step counter
# Final cost : 3.1316560034423175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423175
# Converged in iteration 1 with cost 3.1316560034423175 because of step counter
# Final cost : 3.1316560034423175
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423175
# Converged in iteration 2 with cost 3.131656003442317 because of step counter
# Final cost : 3.131656003442317
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442317
# Final cost : 3.131656003442317
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442317
# Final cost : 3.131656003442317
# 69
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423078
# Final cost : 3.1316560034423078
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423078
# Converged in iteration 1 with cost 3.1316560034423078 because of step counter
# Final cost : 3.1316560034423078
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423078
# Converged in iteration 1 with cost 3.1316560034423078 because of step counter
# Final cost : 3.1316560034423078
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423078
# Converged in iteration 2 with cost 3.1316560034423064 because of step counter
# Final cost : 3.1316560034423064
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423064
# Final cost : 3.1316560034423055
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034423055
# Final cost : 3.131656003442305
# 70
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Final cost : 3.131656003442298
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Converged in iteration 1 with cost 3.131656003442298 because of step counter
# Final cost : 3.131656003442298
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Converged in iteration 1 with cost 3.131656003442298 because of step counter
# Final cost : 3.131656003442298
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Converged in iteration 1 with cost 3.131656003442298 because of step counter
# Final cost : 3.131656003442298
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Final cost : 3.131656003442298
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442298
# Final cost : 3.131656003442298
# 71
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422944
# Final cost : 3.1316560034422944
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422944
# Converged in iteration 1 with cost 3.1316560034422944 because of step counter
# Final cost : 3.1316560034422944
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422944
# Converged in iteration 1 with cost 3.1316560034422944 because of step counter
# Final cost : 3.1316560034422944
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422944
# Converged in iteration 1 with cost 3.1316560034422944 because of step counter
# Final cost : 3.1316560034422944
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422944
# Final cost : 3.131656003442293
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442293
# Final cost : 3.131656003442293
# 72
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344229
# Final cost : 3.13165600344229
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344229
# Converged in iteration 1 with cost 3.13165600344229 because of step counter
# Final cost : 3.13165600344229
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344229
# Converged in iteration 1 with cost 3.13165600344229 because of step counter
# Final cost : 3.13165600344229
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344229
# Converged in iteration 1 with cost 3.13165600344229 because of step counter
# Final cost : 3.13165600344229
# Compute control for a deterministic system
# Cost in iteration 0: 3.13165600344229
# Final cost : 3.1316560034422896
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422896
# Final cost : 3.131656003442289
# 73
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442288
# Final cost : 3.131656003442288
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442288
# Converged in iteration 1 with cost 3.131656003442288 because of step counter
# Final cost : 3.131656003442288
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442288
# Converged in iteration 1 with cost 3.131656003442288 because of step counter
# Final cost : 3.131656003442288
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442288
# Converged in iteration 1 with cost 3.131656003442288 because of step counter
# Final cost : 3.131656003442288
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442288
# Final cost : 3.1316560034422873
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422873
# Final cost : 3.1316560034422873
# 74
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422865
# Final cost : 3.1316560034422865
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422865
# Converged in iteration 1 with cost 3.1316560034422865 because of step counter
# Final cost : 3.1316560034422865
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422865
# Converged in iteration 1 with cost 3.1316560034422865 because of step counter
# Final cost : 3.1316560034422865
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422865
# Converged in iteration 1 with cost 3.1316560034422865 because of step counter
# Final cost : 3.1316560034422865
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422865
# Final cost : 3.131656003442286
# Compute control for a deterministic system
# Cost in iteration 0: 3.131656003442286
# Final cost : 3.131656003442286
# 75
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# 76
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Converged in iteration 1 with cost 3.1316560034422856 because of step counter
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856
# Compute control for a deterministic system
# Cost in iteration 0: 3.1316560034422856
# Final cost : 3.1316560034422856

# %%
save(results_w1_ud)

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)

    print(results_w1_ud["cost"][i], results_w1_ud["initial_cost"][i])
    plt.plot(results_w1_ud["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_ud["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_ud["control"][i][0,0,:], color="red")
    plt.plot(results_w1_ud["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# 0.5481967136224032 2.4780218056012924
# POINT  2
# 0.5414654444432064 2.7238804909935936
# POINT  3
# 0.5376942350214352 2.794785708126736
# POINT  4
# 0.5357216939376114 2.7329776604176903
# POINT  5
# 1.6710767481250473 2.5246808324957213
# POINT  6
# 1.6688879918031034 2.7269764265375467
# POINT  7
# 1.6676692542597846 2.769577460088557
# POINT  8
# 2.4397726062472587 2.493992239059809
# POINT  9
# 2.438250328967757 2.653249494318241
# POINT  10
# 2.4446766927506416 2.4446766927506416
