# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
duration_array = np.array( [22, 25, 28, 36, 60, 100])
n_times = len(duration_array)
fname = 'l1_du_T'

results_w1_du = dict([
    ('cost_type', 'w1'),
    ('d', [None] * n_times),
    ('u', [None] * n_times),
    ("cost", [None] * n_times),
    ("initial_cost", [None] * n_times),
    ("precision_cost", [None] * n_times),
    ("L_cost", [np.zeros((2))] * n_times),
    ("control", [None] * n_times),
    ("state", [None] * n_times),
    ])

def save(res, file):
    filehandler = open( (file + ".pickle"),"wb")
    pickle.dump(res,filehandler)
    filehandler.close()

# %%
with open('l1_du_T.pickle', 'rb') as f:
    results_w1_du = pickle.load(f)

# %%
points_bi = [ [2.9, 2.9]]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

p = points_bi[0]

wc.params["exc_ext"] = bi_control + p[0]
wc.params["inh_ext"] = zero_input + p[1]
wc.run()

for i in range(len(duration_array)):
    results_w1_du['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

# %%
w1 = 1.
duration_array[-1] = 80.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

for i in range(len(duration_array)):

    if i not in [5]:
        continue

    duration = duration_array[i]
    wc.params["duration"] = duration
    zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

    int0 = np.around(duration/dt).astype(int) - 200

    print("DURATION ", duration_array[i], int0)

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    #if type(results_w1_du["control"][i]) != type(None):
    #    continue

    results_w1_du["control"][i] = None
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    #wc_controlled.control[0,0,:200] = results_w1_du["control"][i-1][0,0,:200]

    if True:

        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-300:-200] = 5.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()

        wc_controlled.optimize(0)    
        get_values(results_w1_du, i, w1)

    wc_controlled.step =  10**(-4)
    wc_controlled.step_factor = 0.8
    wc_controlled.optimize(100)

    decrease_step_compute()

    wc_controlled.step =  10**(-14)
    wc_controlled.step_factor = 0.8
    wc_controlled.optimize(100)

    decrease_step_compute()
    
    if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
        get_values(results_w1_du, i, w1)

    itmax = int(duration)

    for k in range(itmax):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-20] = wc_controlled.control[0,:,20:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-20)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break
    
    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-22)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break

    save(results_w1_du, fname)
# Out:
# DURATION  80 600
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 15.81182176347629
# Final cost : 14.811821042757247
# Compute control for a deterministic system
# Cost in iteration 0: 14.811821042757247
# Final cost : 12.811819164347064
# Compute control for a deterministic system
# Cost in iteration 0: 12.811819164347064
# Final cost : 2.3020503154541756
# Compute control for a deterministic system
# Cost in iteration 0: 2.3020503154541756
# Final cost : 2.08679350345651
# Compute control for a deterministic system
# Cost in iteration 0: 2.08679350345651
# Final cost : 2.0759221165972397
# Compute control for a deterministic system
# Cost in iteration 0: 2.0759221165972397
# Converged in iteration 1 with cost 2.0759221165972397 because of step counter
# Final cost : 2.0759221165972397
# Compute control for a deterministic system
# Cost in iteration 0: 2.0759221165972397
# Final cost : 2.0759221165972397
# Compute control for a deterministic system
# Cost in iteration 0: 2.0759221165972397
# Final cost : 2.0758956817825376
# Compute control for a deterministic system
# Cost in iteration 0: 2.0758956817825376
# Final cost : 2.0758572894598255
# Compute control for a deterministic system
# Cost in iteration 0: 2.0758572894598255
# Final cost : 2.075852556856421
# Compute control for a deterministic system
# Cost in iteration 0: 2.075852556856421
# Converged in iteration 49 with cost 2.0758525568563564 because of vanishing difference
# Final cost : 2.0758525568563564
# Compute control for a deterministic system
# Cost in iteration 0: 2.0758525568563564
# Final cost : 2.075814593848341
# Compute control for a deterministic system
# Cost in iteration 0: 2.075814593848341
# Final cost : 2.0758108189779145
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.0747865906550285
# Final cost : 2.0747865906550285
# Compute control for a deterministic system
# Cost in iteration 0: 2.0747865906550285
# Final cost : 2.074786590595951
# Compute control for a deterministic system
# Cost in iteration 0: 2.074786590595951
# Final cost : 2.0746097419837266
# Compute control for a deterministic system
# Cost in iteration 0: 2.0746097419837266
# Final cost : 2.07460594095163
# Compute control for a deterministic system
# Cost in iteration 0: 2.07460594095163
# Converged in iteration 77 with cost 2.0746059409516278 because of vanishing difference
# Final cost : 2.0746059409516278
# Compute control for a deterministic system
# Cost in iteration 0: 2.0746059409516278
# Final cost : 2.074568147746882
# Compute control for a deterministic system
# Cost in iteration 0: 2.074568147746882
# Final cost : 2.074564390138547
# Compute control for a deterministic system
# Cost in iteration 0: 2.074564390138547
# Final cost : 2.074564390138547
# Compute control for a deterministic system
# Cost in iteration 0: 2.074564390138547
# Final cost : 2.0745270287557154
# Compute control for a deterministic system
# Cost in iteration 0: 2.0745270287557154
# Final cost : 2.0745233140879016
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 2.0738701210245067
# Final cost : 2.0738701210245067
# Compute control for a deterministic system
# Cost in iteration 0: 2.0738701210245067
# Final cost : 2.0738701209545214
# Compute control for a deterministic system
# Cost in iteration 0: 2.0738701209545214
# Final cost : 2.073712803213642
# Compute control for a deterministic system
# Cost in iteration 0: 2.073712803213642
# Final cost : 2.0737090810116827
# Compute control for a deterministic system
# Cost in iteration 0: 2.0737090810116827
# Converged in iteration 48 with cost 2.073709081011682 because of vanishing difference
# Final cost : 2.073709081011682
# Compute control for a deterministic system
# Cost in iteration 0: 2.073709081011682
# Final cost : 2.073672074714215
# Compute control for a deterministic system
# Cost in iteration 0: 2.073672074714215
# Final cost : 2.0736683956542095
# Compute control for a deterministic system
# Cost in iteration 0: 2.0736683956542095
# Final cost : 2.0736683956542095
# Compute control for a deterministic system
# Cost in iteration 0: 2.0736683956542095
# Final cost : 2.073631818295192
# Compute control for a deterministic system
# Cost in iteration 0: 2.073631818295192
# Final cost : 2.0736281818808897
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 2.073202769335847
# Final cost : 2.073202769335847
# Compute control for a deterministic system
# Cost in iteration 0: 2.073202769335847
# Final cost : 2.0732027692561084
# Compute control for a deterministic system
# Cost in iteration 0: 2.0732027692561084
# Final cost : 2.0730694804634866
# Compute control for a deterministic system
# Cost in iteration 0: 2.0730694804634866
# Final cost : 2.073065853548317
# Compute control for a deterministic system
# Cost in iteration 0: 2.073065853548317
# Converged in iteration 10 with cost 2.0730658535483166 because of vanishing difference
# Final cost : 2.0730658535483166
# Compute control for a deterministic system
# Cost in iteration 0: 2.0730658535483166
# Final cost : 2.073029796655484
# Compute control for a deterministic system
# Cost in iteration 0: 2.073029796655484
# Final cost : 2.0730262121875938
# Compute control for a deterministic system
# Cost in iteration 0: 2.0730262121875938
# Final cost : 2.0730262121875938
# Compute control for a deterministic system
# Cost in iteration 0: 2.0730262121875938
# Final cost : 2.072990577270422
# Compute control for a deterministic system
# Cost in iteration 0: 2.072990577270422
# Final cost : 2.072987034750394
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 2.0727105726627846
# Final cost : 2.0727105726627846
# Compute control for a deterministic system
# Cost in iteration 0: 2.0727105726627846
# Final cost : 2.0727105725749233
# Compute control for a deterministic system
# Cost in iteration 0: 2.0727105725749233
# Final cost : 2.072601560686183
# Compute control for a deterministic system
# Cost in iteration 0: 2.072601560686183
# Final cost : 2.072598038110203
# Compute control for a deterministic system
# Cost in iteration 0: 2.072598038110203
# Converged in iteration 31 with cost 2.0725980381102027 because of vanishing difference
# Final cost : 2.0725980381102027
# Compute control for a deterministic system
# Cost in iteration 0: 2.0725980381102027
# Final cost : 2.072563019826816
# Compute control for a deterministic system
# Cost in iteration 0: 2.072563019826816
# Final cost : 2.0725595387403137
# Compute control for a deterministic system
# Cost in iteration 0: 2.0725595387403137
# Final cost : 2.0725595387403137
# Compute control for a deterministic system
# Cost in iteration 0: 2.0725595387403137
# Final cost : 2.072524932872632
# Compute control for a deterministic system
# Cost in iteration 0: 2.072524932872632
# Final cost : 2.072521492779833
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 2.07234334277113
# Final cost : 2.07234334277113
# Compute control for a deterministic system
# Cost in iteration 0: 2.07234334277113
# Final cost : 2.072343342676764
# Compute control for a deterministic system
# Cost in iteration 0: 2.072343342676764
# Final cost : 2.072255735073148
# Compute control for a deterministic system
# Cost in iteration 0: 2.072255735073148
# Final cost : 2.0722523209632
# Compute control for a deterministic system
# Cost in iteration 0: 2.0722523209632
# Converged in iteration 39 with cost 2.072252320963199 because of vanishing difference
# Final cost : 2.072252320963199
# Compute control for a deterministic system
# Cost in iteration 0: 2.072252320963199
# Final cost : 2.0722183817752033
# Compute control for a deterministic system
# Cost in iteration 0: 2.0722183817752033
# Final cost : 2.072215008040944
# Compute control for a deterministic system
# Cost in iteration 0: 2.072215008040944
# Final cost : 2.072215008040944
# Compute control for a deterministic system
# Cost in iteration 0: 2.072215008040944
# Final cost : 2.07218147017121
# Compute control for a deterministic system
# Cost in iteration 0: 2.07218147017121
# Final cost : 2.0721781363249696
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 2.072064350335999
# Final cost : 2.072064350335999
# Compute control for a deterministic system
# Cost in iteration 0: 2.072064350335999
# Final cost : 2.0720643502365186
# Compute control for a deterministic system
# Cost in iteration 0: 2.0720643502365186
# Final cost : 2.0719939728203984
# Compute control for a deterministic system
# Cost in iteration 0: 2.0719939728203984
# Final cost : 2.071990668502298
# Compute control for a deterministic system
# Cost in iteration 0: 2.071990668502298
# Converged in iteration 10 with cost 2.071990668502298 because of vanishing difference
# Final cost : 2.071990668502298
# Compute control for a deterministic system
# Cost in iteration 0: 2.071990668502298
# Final cost : 2.071957821216052
# Compute control for a deterministic system
# Cost in iteration 0: 2.071957821216052
# Final cost : 2.0719545560698354
# Compute control for a deterministic system
# Cost in iteration 0: 2.0719545560698354
# Final cost : 2.0719545560698354
# Compute control for a deterministic system
# Cost in iteration 0: 2.0719545560698354
# Final cost : 2.071922098118755
# Compute control for a deterministic system
# Cost in iteration 0: 2.071922098118755
# Final cost : 2.0719188716677537
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718467387772717
# Final cost : 2.0718467387772717
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718467387772717
# Final cost : 2.0718467386738295
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718467386738295
# Converged in iteration 18 with cost 2.0718197731315455 because of vanishing difference
# Final cost : 2.0718197731315455
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718197731315455
# Final cost : 2.0718163695588885
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718163695588885
# Converged in iteration 7 with cost 2.071816369558888 because of vanishing difference
# Final cost : 2.071816369558888
# Compute control for a deterministic system
# Cost in iteration 0: 2.071816369558888
# Converged in iteration 44 with cost 2.0718095881611163 because of vanishing difference
# Final cost : 2.0718095881611163
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718095881611163
# Final cost : 2.0718062248159845
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718062248159845
# Final cost : 2.0718062248159845
# Compute control for a deterministic system
# Cost in iteration 0: 2.0718062248159845
# Converged in iteration 44 with cost 2.0717994637119346 because of vanishing difference
# Final cost : 2.0717994637119346
# Compute control for a deterministic system
# Cost in iteration 0: 2.0717994637119346
# Final cost : 2.0717961147141293
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 2.0717506906900334
# Final cost : 2.0717506906900334
# Compute control for a deterministic system
# Cost in iteration 0: 2.0717506906900334
# Final cost : 2.071750690580498
# Compute control for a deterministic system
# Cost in iteration 0: 2.071750690580498
# Converged in iteration 100 with cost 2.071727591783863 because of vanishing difference
# Final cost : 2.071727591783863
# Compute control for a deterministic system
# Cost in iteration 0: 2.071727591783863
# Final cost : 2.071724330861807
# Compute control for a deterministic system
# Cost in iteration 0: 2.071724330861807
# Converged in iteration 34 with cost 2.071724330861806 because of vanishing difference
# Final cost : 2.071724330861806
# Compute control for a deterministic system
# Cost in iteration 0: 2.071724330861806
# Converged in iteration 88 with cost 2.0717161781836 because of vanishing difference
# Final cost : 2.0717161781836
# Compute control for a deterministic system
# Cost in iteration 0: 2.0717161781836
# Final cost : 2.071712893280682
# Compute control for a deterministic system
# Cost in iteration 0: 2.071712893280682
# Final cost : 2.071712893280682
# Compute control for a deterministic system
# Cost in iteration 0: 2.071712893280682
# Converged in iteration 82 with cost 2.0717052600778736 because of vanishing difference
# Final cost : 2.0717052600778736
# Compute control for a deterministic system
# Cost in iteration 0: 2.0717052600778736
# Final cost : 2.0717019876437717
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716735061456735
# Final cost : 2.0716735061456735
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716735061456735
# Final cost : 2.0716735060370843
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716735060370843
# Converged in iteration 52 with cost 2.071661268642474 because of vanishing difference
# Final cost : 2.071661268642474
# Compute control for a deterministic system
# Cost in iteration 0: 2.071661268642474
# Final cost : 2.0716579695791846
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716579695791846
# Converged in iteration 33 with cost 2.071657969579183 because of vanishing difference
# Final cost : 2.071657969579183
# Compute control for a deterministic system
# Cost in iteration 0: 2.071657969579183
# Converged in iteration 29 with cost 2.0716556714899204 because of vanishing difference
# Final cost : 2.0716556714899204
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716556714899204
# Final cost : 2.0716523798785618
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716523798785618
# Final cost : 2.0716523798785618
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716523798785618
# Converged in iteration 29 with cost 2.071650085215682 because of vanishing difference
# Final cost : 2.071650085215682
# Compute control for a deterministic system
# Cost in iteration 0: 2.071650085215682
# Final cost : 2.0716468008950986
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716290047730546
# Final cost : 2.0716290047730546
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716290047730546
# Final cost : 2.0716290046597936
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716290046597936
# Final cost : 2.0716161888639664
# Compute control for a deterministic system
# Cost in iteration 0: 2.0716161888639664
# Final cost : 2.071612963921106
# Compute control for a deterministic system
# Cost in iteration 0: 2.071612963921106
# Converged in iteration 49 with cost 2.071612963921105 because of vanishing difference
# Final cost : 2.071612963921105
# Compute control for a deterministic system
# Cost in iteration 0: 2.071612963921105
# Final cost : 2.071605943197414
# Compute control for a deterministic system
# Cost in iteration 0: 2.071605943197414
# Final cost : 2.071602705232484
# Compute control for a deterministic system
# Cost in iteration 0: 2.071602705232484
# Final cost : 2.071602705232484
# Compute control for a deterministic system
# Cost in iteration 0: 2.071602705232484
# Final cost : 2.071595703187025
# Compute control for a deterministic system
# Cost in iteration 0: 2.071595703187025
# Final cost : 2.0715924828831844
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 2.07158138863766
# Final cost : 2.07158138863766
# Compute control for a deterministic system
# Cost in iteration 0: 2.07158138863766
# Final cost : 2.0715813885249283
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715813885249283
# Final cost : 2.071573178935651
# Compute control for a deterministic system
# Cost in iteration 0: 2.071573178935651
# Final cost : 2.0715700246316127
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715700246316127
# Converged in iteration 9 with cost 2.071570024631612 because of vanishing difference
# Final cost : 2.071570024631612
# Compute control for a deterministic system
# Cost in iteration 0: 2.071570024631612
# Final cost : 2.0715654396112932
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715654396112932
# Final cost : 2.0715622813341703
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715622813341703
# Final cost : 2.0715622813341703
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715622813341703
# Final cost : 2.071557706863804
# Compute control for a deterministic system
# Cost in iteration 0: 2.071557706863804
# Final cost : 2.071554558931545
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715476563379402
# Final cost : 2.0715476563379402
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715476563379402
# Final cost : 2.0715476562217545
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715476562217545
# Converged in iteration 11 with cost 2.071544805478379 because of vanishing difference
# Final cost : 2.071544805478379
# Compute control for a deterministic system
# Cost in iteration 0: 2.071544805478379
# Final cost : 2.071542522666896
# Compute control for a deterministic system
# Cost in iteration 0: 2.071542522666896
# Converged in iteration 19 with cost 2.0715425226668955 because of vanishing difference
# Final cost : 2.0715425226668955
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715425226668955
# Final cost : 2.071540194243598
# Compute control for a deterministic system
# Cost in iteration 0: 2.071540194243598
# Final cost : 2.071537934725197
# Compute control for a deterministic system
# Cost in iteration 0: 2.071537934725197
# Final cost : 2.071537934725197
# Compute control for a deterministic system
# Cost in iteration 0: 2.071537934725197
# Final cost : 2.0715356100600215
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715356100600215
# Final cost : 2.071533311674925
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715293035012627
# Final cost : 2.0715293035012627
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715293035012627
# Final cost : 2.071529303380847
# Compute control for a deterministic system
# Cost in iteration 0: 2.071529303380847
# Final cost : 2.071525783345264
# Compute control for a deterministic system
# Cost in iteration 0: 2.071525783345264
# Converged in iteration 11 with cost 2.071525705624022 because of vanishing difference
# Final cost : 2.071525705624022
# Compute control for a deterministic system
# Cost in iteration 0: 2.071525705624022
# Converged in iteration 49 with cost 2.07152570562402 because of vanishing difference
# Final cost : 2.07152570562402
# Compute control for a deterministic system
# Cost in iteration 0: 2.07152570562402
# Final cost : 2.071524260492173
# Compute control for a deterministic system
# Cost in iteration 0: 2.071524260492173
# Converged in iteration 13 with cost 2.0715241634889394 because of vanishing difference
# Final cost : 2.0715241634889394
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715241634889394
# Final cost : 2.0715241634889394
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715241634889394
# Final cost : 2.071522706355544
# Compute control for a deterministic system
# Cost in iteration 0: 2.071522706355544
# Converged in iteration 11 with cost 2.0715226355167444 because of vanishing difference
# Final cost : 2.0715226355167444
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 2.071519801772472
# Final cost : 2.071519801772472
# Compute control for a deterministic system
# Cost in iteration 0: 2.071519801772472
# Final cost : 2.071519801659188
# Compute control for a deterministic system
# Cost in iteration 0: 2.071519801659188
# Final cost : 2.0715179538653454
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715179538653454
# Converged in iteration 7 with cost 2.071517932386907 because of vanishing difference
# Final cost : 2.071517932386907
# Compute control for a deterministic system
# Cost in iteration 0: 2.071517932386907
# Converged in iteration 18 with cost 2.071517932386906 because of vanishing difference
# Final cost : 2.071517932386906
# Compute control for a deterministic system
# Cost in iteration 0: 2.071517932386906
# Final cost : 2.07151702494933
# Compute control for a deterministic system
# Cost in iteration 0: 2.07151702494933
# Converged in iteration 13 with cost 2.0715169810658502 because of vanishing difference
# Final cost : 2.0715169810658502
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715169810658502
# Final cost : 2.0715169810658502
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715169810658502
# Final cost : 2.071516072427111
# Compute control for a deterministic system
# Cost in iteration 0: 2.071516072427111
# Converged in iteration 11 with cost 2.0715160360162765 because of vanishing difference
# Final cost : 2.0715160360162765
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715145384250087
# Final cost : 2.0715145384250087
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715145384250087
# Final cost : 2.07151453829468
# Compute control for a deterministic system
# Cost in iteration 0: 2.07151453829468
# Converged in iteration 2 with cost 2.0715138071603048 because of step counter
# Final cost : 2.0715138071603048
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715138071603048
# Final cost : 2.071513124225899
# Compute control for a deterministic system
# Cost in iteration 0: 2.071513124225899
# Converged in iteration 30 with cost 2.0715131242258975 because of vanishing difference
# Final cost : 2.0715131242258975
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715131242258975
# Final cost : 2.0715125669629897
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715125669629897
# Final cost : 2.0715120088418795
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715120088418795
# Final cost : 2.0715120088418795
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715120088418795
# Final cost : 2.071511455067434
# Compute control for a deterministic system
# Cost in iteration 0: 2.071511455067434
# Final cost : 2.071510897095827
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509812694406
# Final cost : 2.071509812694406
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509812694406
# Final cost : 2.071509812583668
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509812583668
# Converged in iteration 2 with cost 2.071509677847127 because of step counter
# Final cost : 2.071509677847127
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509677847127
# Final cost : 2.071509092278129
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509092278129
# Converged in iteration 11 with cost 2.071509092278128 because of vanishing difference
# Final cost : 2.071509092278128
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509092278128
# Converged in iteration 1 with cost 2.071509092278128 because of step counter
# Final cost : 2.071509092278128
# Compute control for a deterministic system
# Cost in iteration 0: 2.071509092278128
# Final cost : 2.0715087484913837
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715087484913837
# Final cost : 2.0715087484913837
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715087484913837
# Converged in iteration 1 with cost 2.0715087484913837 because of step counter
# Final cost : 2.0715087484913837
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715087484913837
# Final cost : 2.0715084047372088
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 2.071507704425405
# Final cost : 2.071507704425405
# Compute control for a deterministic system
# Cost in iteration 0: 2.071507704425405
# Final cost : 2.0715077043462546
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715077043462546
# Converged in iteration 1 with cost 2.0715077043462546 because of step counter
# Final cost : 2.0715077043462546
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715077043462546
# Final cost : 2.0715073711844747
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715073711844747
# Final cost : 2.0715073711844725
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715073711844725
# Converged in iteration 1 with cost 2.0715073711844725 because of step counter
# Final cost : 2.0715073711844725
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715073711844725
# Final cost : 2.0715071592656513
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715071592656513
# Final cost : 2.0715071592656513
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715071592656513
# Converged in iteration 1 with cost 2.0715071592656513 because of step counter
# Final cost : 2.0715071592656513
# Compute control for a deterministic system
# Cost in iteration 0: 2.0715071592656513
# Final cost : 2.0715069473778382
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 4.8686097401275745
# Final cost : 4.8686097401275745
# Compute control for a deterministic system
# Cost in iteration 0: 4.8686097401275745
# Final cost : 4.867407571696358
# Compute control for a deterministic system
# Cost in iteration 0: 4.867407571696358
# Final cost : 4.67448695357716
# Compute control for a deterministic system
# Cost in iteration 0: 4.67448695357716
# Final cost : 4.672470212847267
# Compute control for a deterministic system
# Cost in iteration 0: 4.672470212847267
# Final cost : 4.672470212847256
# Compute control for a deterministic system
# Cost in iteration 0: 4.672470212847256
# Final cost : 4.652304733755477
# Compute control for a deterministic system
# Cost in iteration 0: 4.652304733755477
# Final cost : 4.650288380462281
# Compute control for a deterministic system
# Cost in iteration 0: 4.650288380462281
# Final cost : 4.650288380462281
# Compute control for a deterministic system
# Cost in iteration 0: 4.650288380462281
# Final cost : 4.630126803435422
# Compute control for a deterministic system
# Cost in iteration 0: 4.630126803435422
# Final cost : 4.628110843150493
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 4.628110829023549
# Final cost : 4.628110829023549
# Compute control for a deterministic system
# Cost in iteration 0: 4.628110829023549
# Final cost : 4.628110828822598
# Compute control for a deterministic system
# Cost in iteration 0: 4.628110828822598
# Final cost : 4.60795320914577
# Compute control for a deterministic system
# Cost in iteration 0: 4.60795320914577
# Final cost : 4.6059376474560665
# Compute control for a deterministic system
# Cost in iteration 0: 4.6059376474560665
# Final cost : 4.6059376474560665
# Compute control for a deterministic system
# Cost in iteration 0: 4.6059376474560665
# Final cost : 4.585784043607809
# Compute control for a deterministic system
# Cost in iteration 0: 4.585784043607809
# Final cost : 4.583768886422842

# %%
save(results_w1_du, fname)

# %%
for i in range(len(duration_array)):
    print("duration ", duration_array[i])
    print("amplitude = ", np.amax(results_w1_du["control"][i]))
    
    print(results_w1_du["cost"][i], results_w1_du["L_cost"][i][0], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# duration  22
# amplitude =  2.671870244489831
# 2.1142254562992333 2.145569227846176 2.794785708126736
# duration  25
# amplitude =  2.6157096639129684
# 2.0877249458975924 2.145569227846176 2.794785708126736
# duration  28
# amplitude =  2.4890088467431664
# 2.0886447384718667 2.145569227846176 2.794785708126736
# duration  36
# amplitude =  2.4606061324131963
# 2.0739734037487443 2.145569227846176 2.794785708126736
# duration  50
# amplitude =  2.4136217717066035
# 2.0713912552873617 2.145569227846176 2.794785708126736
# duration  80
# amplitude =  2.3960731676023492
# 2.0715069473778382 2.145569227846176 2.794785708126736

# %%
save(results_w1_du, fname)

# %%
fname = 'w1_du_T'
