# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [ [2.9, 2.9] ]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
duration_array = np.array( [30, 40, 50, 100, 200])
n_times = len(duration_array)
fname = 'w1_du_T'


results_w1_du = dict([
    ('cost_type', 'w1'),
    ('d', [None] * n_times),
    ('u', [None] * n_times),
    ("cost", [None] * n_times),
    ("initial_cost", [None] * n_times),
    ("precision_cost", [None] * n_times),
    ("L_cost", [np.zeros((2))] * n_times),
    ("control", [None] * n_times),
    ("state", [None] * n_times),
    ])

def save(res, file):
    filehandler = open( (file + ".pickle"),"wb")
    pickle.dump(res,filehandler)
    filehandler.close()

# %%
points_bi = [ [2.9, 2.9]]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

p = points_bi[0]

wc.params["exc_ext"] = bi_control + p[0]
wc.params["inh_ext"] = zero_input + p[1]
wc.run()

for i in range(len(duration_array)):
    results_w1_du['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

# %%
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

for i in range(len(duration_array)):

    duration = duration_array[i]
    wc.params["duration"] = duration
    zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

    int0 = np.around(duration/dt).astype(int) - 200

    print("DURATION ", duration_array[i], int0)

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    if type(results_w1_du["control"][i]) != type(None):
        continue

    #results_w1_du["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    wc_controlled.step = 1e-3
    wc_controlled.optimize(1)

    results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

    wc_controlled.control[0,0,-300:-200] = 5.
    wc_controlled.update_input()

    wc_controlled.step = 1e-2
    wc_controlled.optimize(100)

    increase_step_compute()

    ce = wc_controlled.cost_history[-1]
    control_e = wc_controlled.control.copy()

    wc_controlled.control[0,0,:] = 0.
    wc_controlled.control[0,1,-300:-200] = -5.
    wc_controlled.update_input()

    wc_controlled.step = 1e-2
    wc_controlled.optimize(100)

    increase_step_compute()

    ci = wc_controlled.cost_history[-1]

    if ce <= ci:
        wc_controlled.control = control_e.copy()
        wc_controlled.update_input()

    wc_controlled.optimize(0)    
    get_values(results_w1_du, i, w1)

    itmax = duration/10.

    for k in range(25):
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-100] = wc_controlled.control[0,:,100:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()

        if k%4 == 0:
            wc_controlled.step = 10**(-(k))
            wc_controlled.step_factor *= 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)

    for k in range(30):
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()

        if k%4 == 0:
            wc_controlled.step = 10**(-(k))
            wc_controlled.step_factor *= 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)

    for k in range(40):
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()

        if k%4 == 0:
            wc_controlled.step = 10**(-(k))
            wc_controlled.step_factor *= 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)

    save(results_w1_du, fname)
# Out:
# DURATION  30 100
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 15.81182176347629
# Final cost : 14.811821042757684
# Compute control for a deterministic system
# Cost in iteration 0: 14.811821042757684
# Final cost : 12.811819164348199
# Compute control for a deterministic system
# Cost in iteration 0: 12.811819164348199
# Final cost : 2.4665820611612124
# Compute control for a deterministic system
# Cost in iteration 0: 2.4665820611612124
# Final cost : 2.101474858203762
# Compute control for a deterministic system
# Cost in iteration 0: 2.101474858203762
# Converged in iteration 242 with cost 2.096719885843144 because of vanishing difference
# Final cost : 2.096719885843144
# Compute control for a deterministic system
# Cost in iteration 0: 2.096719885843144
# Converged in iteration 1 with cost 2.096719885843144 because of step counter
# Final cost : 2.096719885843144
# Compute control for a deterministic system
# Cost in iteration 0: 15.814418888380004
# Final cost : 14.812235688947109
# Compute control for a deterministic system
# Cost in iteration 0: 14.812235688947109
# Final cost : 12.810073529839874
# Compute control for a deterministic system
# Cost in iteration 0: 12.810073529839874
# Final cost : 2.569883826551485
# Compute control for a deterministic system
# Cost in iteration 0: 2.569883826551485
# Final cost : 2.4497718453495314
# Compute control for a deterministic system
# Cost in iteration 0: 2.4497718453495314
# Final cost : 2.3638264703615914
# Compute control for a deterministic system
# Cost in iteration 0: 2.3638264703615914
# Converged in iteration 2 with cost 2.363792435820948 because of step counter
# Final cost : 2.363792435820948
# Compute control for a deterministic system
# Cost in iteration 0: 2.096719885843144
# Final cost : 2.096719885843144
# Compute control for a deterministic system
# Cost in iteration 0: 2.8120695385553263
# Converged in iteration 11 with cost 2.7947857121955226 because of step counter
# Final cost : 2.7947857121955226
# Compute control for a deterministic system
# Cost in iteration 0: 2.7947857121955226
# Converged in iteration 8 with cost 2.794785708127056 because of step counter
# Final cost : 2.794785708127056
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708127056
# Converged in iteration 2 with cost 2.794785708126886 because of step counter
# Final cost : 2.794785708126886
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126836
# Converged in iteration 1 with cost 2.794785708126836 because of step counter
# Final cost : 2.794785708126836
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126836
# Converged in iteration 1 with cost 2.794785708126836 because of step counter
# Final cost : 2.794785708126836
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126836
# Converged in iteration 1 with cost 2.794785708126836 because of step counter
# Final cost : 2.794785708126836
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126816
# Converged in iteration 1 with cost 2.794785708126816 because of step counter
# Final cost : 2.794785708126816
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126816
# Converged in iteration 1 with cost 2.794785708126816 because of step counter
# Final cost : 2.794785708126816
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126816
# Converged in iteration 1 with cost 2.794785708126816 because of step counter
# Final cost : 2.794785708126816
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# DURATION  40 200
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 15.81182176347629
# Final cost : 14.811821042757247
# Compute control for a deterministic system
# Cost in iteration 0: 14.811821042757247
# Final cost : 12.811819164347064
# Compute control for a deterministic system
# Cost in iteration 0: 12.811819164347064
# Final cost : 2.2396179365774986
# Compute control for a deterministic system
# Cost in iteration 0: 2.2396179365774986
# Final cost : 2.0869314613581627
# Compute control for a deterministic system
# Cost in iteration 0: 2.0869314613581627
# Converged in iteration 981 with cost 2.0760809393254784 because of vanishing difference
# Final cost : 2.0760809393254784
# Compute control for a deterministic system
# Cost in iteration 0: 2.0760809393254784
# Converged in iteration 1 with cost 2.0760809393254784 because of step counter
# Final cost : 2.0760809393254784
# Compute control for a deterministic system
# Cost in iteration 0: 15.814418882755959
# Final cost : 14.812235454051354
# Compute control for a deterministic system
# Cost in iteration 0: 14.812235454051354
# Final cost : 12.810073437595026
# Compute control for a deterministic system
# Cost in iteration 0: 12.810073437595026
# Final cost : 2.5663430466773156
# Compute control for a deterministic system
# Cost in iteration 0: 2.5663430466773156
# Final cost : 2.437509406373487
# Compute control for a deterministic system
# Cost in iteration 0: 2.437509406373487
# Final cost : 2.349914576827002
# Compute control for a deterministic system
# Cost in iteration 0: 2.349914576827002
# Converged in iteration 1 with cost 2.349914576827002 because of step counter
# Final cost : 2.349914576827002
# Compute control for a deterministic system
# Cost in iteration 0: 2.0760809393254784
# Final cost : 2.0760809393254784
# Compute control for a deterministic system
# Cost in iteration 0: 4.859614088837935
# Converged in iteration 18 with cost 2.7947857346293485 because of vanishing difference
# Final cost : 2.7947857346293485
# Compute control for a deterministic system
# Cost in iteration 0: 2.7947857346293485
# Converged in iteration 11 with cost 2.7947857081290968 because of vanishing difference
# Final cost : 2.7947857081290968
# Compute control for a deterministic system
# Cost in iteration 0: 2.7947857081290968
# Converged in iteration 3 with cost 2.7947857081269443 because of vanishing difference
# Final cost : 2.7947857081269443
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126934
# Converged in iteration 1 with cost 2.794785708126934 because of step counter
# Final cost : 2.794785708126934
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126934
# Converged in iteration 1 with cost 2.794785708126934 because of step counter
# Final cost : 2.794785708126934
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126934
# Converged in iteration 1 with cost 2.794785708126934 because of step counter
# Final cost : 2.794785708126934
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126916
# Converged in iteration 1 with cost 2.794785708126916 because of step counter
# Final cost : 2.794785708126916
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126916
# Converged in iteration 1 with cost 2.794785708126916 because of step counter
# Final cost : 2.794785708126916
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126916
# Converged in iteration 1 with cost 2.794785708126916 because of step counter
# Final cost : 2.794785708126916
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126873
# Converged in iteration 1 with cost 2.794785708126873 because of step counter
# Final cost : 2.794785708126873
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126873
# Converged in iteration 1 with cost 2.794785708126873 because of step counter
# Final cost : 2.794785708126873
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126873
# Converged in iteration 1 with cost 2.794785708126873 because of step counter
# Final cost : 2.794785708126873
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of vanishing difference
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Converged in iteration 1 with cost 2.794785708126736 because of step counter
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# Compute control for a deterministic system
# Cost in iteration 0: 2.794785708126736
# Final cost : 2.794785708126736
# DURATION  50 300
# DURATION  100 800
# DURATION  200 1800

# %%
for i in range(len(duration_array)):
    print("duratoin ", duration_array[i])
    
    print(results_w1_du["cost"][i], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# duratoin  50
# 2.0719173612169763 2.794785708126736
# duratoin  100
# 2.070525114696031 2.794785708126736
# duratoin  150
# None None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [17], line 5
#       2 print("duratoin ", duration_array[i])
#       4 print(results_w1_du["cost"][i], results_w1_du["initial_cost"][i])
# ----> 5 plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
#       6 plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
#       7 plt.plot(results_w1_du["control"][i][0,0,:], color="red")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
save(results_w1_du, fname)

# %%
fname = 'w1_du_T'
