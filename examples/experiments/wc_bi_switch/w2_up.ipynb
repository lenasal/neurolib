# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [
    [2.9, 2.1], [2.9, 2.5], [2.9, 2.9], [2.9, 3.3],
    [3.3, 2.5], [3.3, 2.9], [3.3, 3.3],
    [3.7, 2.9], [3.7, 3.3],
    [4.1, 3.3],
]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 1, 2, 3, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w2_ud = dict([
    ('cost_type', 'w2'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("w2_ud.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w2_ud['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w2_ud['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w2_ud['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 220.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w2_ud['d'][i] )
    setinit( results_w2_ud['u'][i] )

    if i < 7:
        continue

    #if type(results_w2_ud["control"][i]) != type(None):
    #    continue

    results_w2_ud["control"][i] = None
        
    wc_controlled = getmodel(target, w1, results_w2_ud, i)

    wc_controlled.step = 1e-3
    wc_controlled.optimize(1)

    results_w2_ud["initial_cost"][i] = wc_controlled.cost_history[0]

    wc_controlled.control[0,0,-300:-200] = -5.
    wc_controlled.update_input()

    wc_controlled.step = 1e-2
    wc_controlled.optimize(100)

    increase_step_compute()
    get_values(results_w2_ud, i, w1)

    for k in range(10):
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-100] = wc_controlled.control[0,:,100:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()

        wc_controlled.step = 10**(-(k))
        wc_controlled.step_factor *= 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)

    save(results_w2_ud)
# Out:
# POINT  1
# POINT  2
# POINT  3
# POINT  4
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# Compute control for a deterministic system
# Cost in iteration 0: 4.975576556532234
# Final cost : 4.975576039501629
# Compute control for a deterministic system
# Cost in iteration 0: 126.46845668270318
# Final cost : 18.410463392249365
# Compute control for a deterministic system
# Cost in iteration 0: 18.410463392249365
# Final cost : 5.630614052100012
# Compute control for a deterministic system
# Cost in iteration 0: 5.630614052100012
# Final cost : 4.960733141736858
# Compute control for a deterministic system
# Cost in iteration 0: 4.960733141736858
# Final cost : 4.960090562178723
# Compute control for a deterministic system
# Cost in iteration 0: 4.960090562178723
# Converged in iteration 444 with cost 4.96009055952784 because of vanishing difference
# Final cost : 4.96009055952784
# Compute control for a deterministic system
# Cost in iteration 0: 4.96009055952784
# Converged in iteration 3 with cost 4.960090559527837 because of vanishing difference
# Final cost : 4.960090559527837
# Compute control for a deterministic system
# Cost in iteration 0: 4.960090559527837
# Converged in iteration 1 with cost 4.960090559527837 because of step counter
# Final cost : 4.960090559527837
# Compute control for a deterministic system
# Cost in iteration 0: 4.960090559527837
# Converged in iteration 1 with cost 4.960090559527837 because of step counter
# Final cost : 4.960090559527837
# Compute control for a deterministic system
# Cost in iteration 0: 3.719564981786859
# Converged in iteration 42 with cost 3.7195055969388586 because of vanishing difference
# Final cost : 3.7195055969388586
# Compute control for a deterministic system
# Cost in iteration 0: 3.7195055969388586
# Final cost : 3.719505596938858
# Compute control for a deterministic system
# Cost in iteration 0: 3.719505596938858
# Final cost : 3.719505596938858
# Compute control for a deterministic system
# Cost in iteration 0: 3.0515920370705802
# Final cost : 3.022776650241983
# Compute control for a deterministic system
# Cost in iteration 0: 3.022776650241983
# Final cost : 3.022746100855291
# Compute control for a deterministic system
# Cost in iteration 0: 3.022746100855291
# Final cost : 3.0227431545082815
# Compute control for a deterministic system
# Cost in iteration 0: 2.9964494077668524
# Final cost : 2.977742129401222
# Compute control for a deterministic system
# Cost in iteration 0: 2.977742129401222
# Final cost : 2.9777381041432913
# Compute control for a deterministic system
# Cost in iteration 0: 2.9777381041432913
# Final cost : 2.977734006663055
# Compute control for a deterministic system
# Cost in iteration 0: 2.9772730656393667
# Final cost : 2.977150048516197
# Compute control for a deterministic system
# Cost in iteration 0: 2.977150048516197
# Final cost : 2.977149618509724
# Compute control for a deterministic system
# Cost in iteration 0: 2.977149618509724
# Final cost : 2.9771490252267427
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771336149230607
# Final cost : 2.9771299645187232
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771299645187232
# Final cost : 2.977129563422859
# Compute control for a deterministic system
# Cost in iteration 0: 2.977129563422859
# Final cost : 2.9771295249312737
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771290795546803
# Final cost : 2.977128969396268
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128969396268
# Final cost : 2.977128593755834
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128593755834
# Final cost : 2.977128557013325
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128544043521
# Final cost : 2.977128539648705
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128539648705
# Final cost : 2.9771284898333543
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771284898333543
# Final cost : 2.977128471737285
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128471378203
# Final cost : 2.9771284711028545
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771284711028545
# Final cost : 2.977128446361698
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128446361698
# Final cost : 2.977128442484951
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128442476276
# Final cost : 2.97712844246339
# Compute control for a deterministic system
# Cost in iteration 0: 2.97712844246339
# Final cost : 2.9771284142440497
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771284142440497
# Final cost : 2.9771284104341063
# Compute control for a deterministic system
# Cost in iteration 0: 2.977128410433776
# Final cost : 2.9771284104337195
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771284104337195
# Final cost : 2.9771284104337195
# Compute control for a deterministic system
# Cost in iteration 0: 2.9771284104337195
# Final cost : 2.9771284104337195
# POINT  9
# Compute control for a deterministic system
# Cost in iteration 0: 5.293298742395957
# Final cost : 5.2932981746318095
# Compute control for a deterministic system
# Cost in iteration 0: 126.56659332768011
# Final cost : 18.524639343291536
# Compute control for a deterministic system
# Cost in iteration 0: 18.524639343291536
# Final cost : 5.729218345572441
# Compute control for a deterministic system
# Cost in iteration 0: 5.729218345572441
# Final cost : 5.062644001967639
# Compute control for a deterministic system
# Cost in iteration 0: 5.062644001967639
# Final cost : 5.062632561462097
# Compute control for a deterministic system
# Cost in iteration 0: 5.062632561462097
# Converged in iteration 174 with cost 5.062632561448592 because of vanishing difference
# Final cost : 5.062632561448592
# Compute control for a deterministic system
# Cost in iteration 0: 5.062632561448592
# Converged in iteration 2 with cost 5.062632561448591 because of vanishing difference
# Final cost : 5.062632561448591
# Compute control for a deterministic system
# Cost in iteration 0: 5.062632561448591
# Converged in iteration 1 with cost 5.062632561448591 because of step counter
# Final cost : 5.062632561448591
# Compute control for a deterministic system
# Cost in iteration 0: 5.062632561448591
# Converged in iteration 1 with cost 5.062632561448591 because of step counter
# Final cost : 5.062632561448591
# Compute control for a deterministic system
# Cost in iteration 0: 3.742918638206508
# Converged in iteration 55 with cost 3.742853192770156 because of vanishing difference
# Final cost : 3.742853192770156
# Compute control for a deterministic system
# Cost in iteration 0: 3.742853192770156
# Final cost : 3.7428531927701556
# Compute control for a deterministic system
# Cost in iteration 0: 3.7428531927701556
# Final cost : 3.7428531927701556
# Compute control for a deterministic system
# Cost in iteration 0: 3.055762830493928
# Final cost : 3.024320667108229
# Compute control for a deterministic system
# Cost in iteration 0: 3.024320667108229
# Final cost : 3.0242960053007275
# Compute control for a deterministic system
# Cost in iteration 0: 3.0242960053007275
# Final cost : 3.0242936484287535
# Compute control for a deterministic system
# Cost in iteration 0: 2.9929790007631003
# Final cost : 2.973664440206001
# Compute control for a deterministic system
# Cost in iteration 0: 2.973664440206001
# Final cost : 2.9736492722106744
# Compute control for a deterministic system
# Cost in iteration 0: 2.9736492722106744
# Final cost : 2.973645890563067
# Compute control for a deterministic system
# Cost in iteration 0: 2.973474347359336
# Final cost : 2.973245786487437
# Compute control for a deterministic system
# Cost in iteration 0: 2.973245786487437
# Final cost : 2.9732453303840756
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732453303840756
# Final cost : 2.9732451921710257
# Compute control for a deterministic system
# Cost in iteration 0: 2.973240589251654
# Final cost : 2.9732363430541264
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732363430541264
# Final cost : 2.9732359215383752
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732359215383752
# Final cost : 2.9732358803086423
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732358240946635
# Final cost : 2.973235785776775
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235785776775
# Final cost : 2.9732353833361214
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732353833361214
# Final cost : 2.97323534383943
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235343380116
# Final cost : 2.9732353409798025
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732353409798025
# Final cost : 2.9732352729243545
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732352729243545
# Final cost : 2.9732352579482413
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235257938149
# Final cost : 2.973235257856106
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235257856106
# Final cost : 2.973235233056495
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235233056495
# Final cost : 2.9732352293091187
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235229309118
# Final cost : 2.973235229224582
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235229224582
# Final cost : 2.9732352292245805
# Compute control for a deterministic system
# Cost in iteration 0: 2.9732352292245805
# Final cost : 2.97323522922458
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235229224579
# Final cost : 2.973235229224579
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235229224579
# Final cost : 2.973235229224579
# Compute control for a deterministic system
# Cost in iteration 0: 2.973235229224579
# Final cost : 2.973235229224579
# POINT  10
# Compute control for a deterministic system
# Cost in iteration 0: 4.877190814890577
# Final cost : 4.877190683294592
# Compute control for a deterministic system
# Cost in iteration 0: 126.42551626810679
# Final cost : 18.60785711857201
# Compute control for a deterministic system
# Cost in iteration 0: 18.60785711857201
# Final cost : 7.761182706304625
# Compute control for a deterministic system
# Cost in iteration 0: 7.761182706304625
# Final cost : 6.876613462871252
# Compute control for a deterministic system
# Cost in iteration 0: 6.876613462871252
# Final cost : 6.872966166550841
# Compute control for a deterministic system
# Cost in iteration 0: 6.872966166550841
# Converged in iteration 247 with cost 6.872965343533915 because of vanishing difference
# Final cost : 6.872965343533915
# Compute control for a deterministic system
# Cost in iteration 0: 6.872965343533915
# Converged in iteration 1 with cost 6.872965343533915 because of step counter
# Final cost : 6.872965343533915
# Compute control for a deterministic system
# Cost in iteration 0: 6.872965343533915
# Converged in iteration 8 with cost 6.872965343533866 because of step counter
# Final cost : 6.872965343533866
# Compute control for a deterministic system
# Cost in iteration 0: 6.872965343533866
# Converged in iteration 1 with cost 6.872965343533866 because of step counter
# Final cost : 6.872965343533866
# Compute control for a deterministic system
# Cost in iteration 0: 5.6567639972377615
# Final cost : 5.656749050758253
# Compute control for a deterministic system
# Cost in iteration 0: 5.656749050758253
# Converged in iteration 96 with cost 5.656749050758242 because of vanishing difference
# Final cost : 5.656749050758242
# Compute control for a deterministic system
# Cost in iteration 0: 5.656749050758242
# Final cost : 5.656749050758242
# Compute control for a deterministic system
# Cost in iteration 0: 4.971247507573319
# Final cost : 4.9582891151706034
# Compute control for a deterministic system
# Cost in iteration 0: 4.9582891151706034
# Final cost : 4.958258965402064
# Compute control for a deterministic system
# Cost in iteration 0: 4.958258965402064
# Final cost : 4.95825656528727
# Compute control for a deterministic system
# Cost in iteration 0: 4.92360587797179
# Final cost : 4.904485219240559
# Compute control for a deterministic system
# Cost in iteration 0: 4.904485219240559
# Final cost : 4.904476086694867
# Compute control for a deterministic system
# Cost in iteration 0: 4.904476086694867
# Final cost : 4.904473927343158
# Compute control for a deterministic system
# Cost in iteration 0: 4.904219826958947
# Final cost : 4.904040523676275
# Compute control for a deterministic system
# Cost in iteration 0: 4.904040523676275
# Final cost : 4.904040158731342
# Compute control for a deterministic system
# Cost in iteration 0: 4.904040158731342
# Final cost : 4.904040125447791
# Compute control for a deterministic system
# Cost in iteration 0: 4.904035301768005
# Final cost : 4.904031080844129
# Compute control for a deterministic system
# Cost in iteration 0: 4.904031080844129
# Final cost : 4.904030777831316
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030777831316
# Final cost : 4.9040307481927305
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030647855292
# Final cost : 4.904030537998773
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030537998773
# Final cost : 4.904030348473487
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030348473487
# Final cost : 4.904030319760953
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040303175009745
# Final cost : 4.904030314072694
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030314072694
# Final cost : 4.9040302573076815
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040302573076815
# Final cost : 4.904030245338221
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030245295751
# Final cost : 4.904030245194866
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030245194866
# Final cost : 4.904030230356712
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030230356712
# Final cost : 4.904030229032363
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030229032282
# Final cost : 4.904030229013955
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030229013955
# Final cost : 4.904030227296179
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030227296179
# Final cost : 4.904030227296179
# Compute control for a deterministic system
# Cost in iteration 0: 4.904030227296154
# Final cost : 4.9040302272961425
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040302272961425
# Final cost : 4.9040302272961425
# Compute control for a deterministic system
# Cost in iteration 0: 4.9040302272961425
# Final cost : 4.9040302272961425

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)
    if i < 7:
        continue
    print(results_w2_ud["cost"][i], results_w2_ud["initial_cost"][i])
    plt.plot(results_w2_ud["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w2_ud["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w2_ud["control"][i][0,0,:], color="red")
    plt.plot(results_w2_ud["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# POINT  2
# POINT  3
# POINT  4
# POINT  5
# POINT  6
# POINT  7
# POINT  8
# 2.9771284104337195 4.975576556532234
# POINT  9
# 2.973235229224579 5.293298742395957
# POINT  10
# 4.9040302272961425 4.877190814890577
