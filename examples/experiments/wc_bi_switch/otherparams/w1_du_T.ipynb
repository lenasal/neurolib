# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 2, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_1D = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=0., w_1D=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
duration_array = np.array( [22, 25, 28, 36, 60, 100])
n_times = len(duration_array)
fname = 'w1_du_T'

results_w1_du = dict([
    ('cost_type', 'w1'),
    ('d', [None] * n_times),
    ('u', [None] * n_times),
    ("cost", [None] * n_times),
    ("initial_cost", [None] * n_times),
    ("precision_cost", [None] * n_times),
    ("L_cost", [np.zeros((2))] * n_times),
    ("control", [None] * n_times),
    ("state", [None] * n_times),
    ])

def save(res, file):
    filehandler = open( (file + ".pickle"),"wb")
    pickle.dump(res,filehandler)
    filehandler.close()

# %%
with open('w1_du_T.pickle', 'rb') as f:
    results_w1_du = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/lena/Promotion/neurolib/examples/experiments/wc_bi_switch/otherparams/w1_du_T.ipynb Cell 4 in 1
# ----> <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/examples/experiments/wc_bi_switch/otherparams/w1_du_T.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> with open('w1_du_T.pickle', 'rb') as f:
#       <a href='vscode-notebook-cell:/home/lena/Promotion/neurolib/examples/experiments/wc_bi_switch/otherparams/w1_du_T.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     results_w1_du = pickle.load(f)
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'w1_du_T.pickle'

# %%
points_bi = [ [4.2, 3.5]]

wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

wc.params.c_excinh = 2.
wc.params.c_inhexc = 16.
wc.params.c_inhinh = 1.

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

p = points_bi[0]

wc.params["exc_ext"] = bi_control + p[0]
wc.params["inh_ext"] = zero_input + p[1]
wc.run()

plt.plot(wc.exc[0,:])
plt.show()

for i in range(len(duration_array)):
    results_w1_du['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w1_du['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

# %%
w1 = 1.
duration_array[-1] = 80.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

for i in range(len(duration_array)):

    if i in []:
        continue

    duration = duration_array[i]
    wc.params["duration"] = duration
    zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

    int0 = np.around(duration/dt).astype(int) - 200

    print("DURATION ", duration_array[i], int0)

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w1_du['u'][i] )
    setinit( results_w1_du['d'][i] )

    #if type(results_w1_du["control"][i]) != type(None):
    #    continue

    #results_w1_du["control"][i] = None
    wc_controlled = getmodel(target, w1, results_w1_du, i)

    #wc_controlled.control[0,0,:200] = results_w1_du["control"][i-1][0,0,:200]

    if False:

        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w1_du["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,1,-300:-100] = -6.
        wc_controlled.update_input()

        wc_controlled.optimize(0)

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()

        wc_controlled.optimize(0)    
        get_values(results_w1_du, i, w1)

        continue

    itmax = int(duration)

    for k in range(itmax):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-16)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-20)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break
    
    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        wc_controlled.step =  10**(-12)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        wc_controlled.step =  10**(-22)
        wc_controlled.step_factor = 0.8
        wc_controlled.optimize(100)

        decrease_step_compute()

        if results_w1_du["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w1_du, i, w1)
        else: break

    save(results_w1_du, fname)
# Out:
# DURATION  22 20
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.283921794862206
# Final cost : 5.283921794862206
# Compute control for a deterministic system
# Cost in iteration 0: 5.283921794862206
# Final cost : 5.283921794814825
# Compute control for a deterministic system
# Cost in iteration 0: 5.283921794814825
# Final cost : 5.274192481208395
# Compute control for a deterministic system
# Cost in iteration 0: 5.274192481208395
# Final cost : 5.2731919109483805
# Compute control for a deterministic system
# Cost in iteration 0: 5.2731919109483805
# Final cost : 5.2731919109483805
# Compute control for a deterministic system
# Cost in iteration 0: 5.2731919109483805
# Final cost : 5.262918273832781
# Compute control for a deterministic system
# Cost in iteration 0: 5.262918273832781
# Final cost : 5.26186443752279
# Compute control for a deterministic system
# Cost in iteration 0: 5.26186443752279
# Final cost : 5.26186443752279
# Compute control for a deterministic system
# Cost in iteration 0: 5.26186443752279
# Final cost : 5.25107005161676
# Compute control for a deterministic system
# Cost in iteration 0: 5.25107005161676
# Final cost : 5.249965347531212
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.239986881274877
# Final cost : 5.239986881274877
# Compute control for a deterministic system
# Cost in iteration 0: 5.239986881274877
# Final cost : 5.239986881213503
# Compute control for a deterministic system
# Cost in iteration 0: 5.239986881213503
# Final cost : 5.227522574023321
# Compute control for a deterministic system
# Cost in iteration 0: 5.227522574023321
# Final cost : 5.226255605176224
# Compute control for a deterministic system
# Cost in iteration 0: 5.226255605176224
# Final cost : 5.226255605176224
# Compute control for a deterministic system
# Cost in iteration 0: 5.226255605176224
# Final cost : 5.213388214541521
# Compute control for a deterministic system
# Cost in iteration 0: 5.213388214541521
# Final cost : 5.21208200877547
# DURATION  25 50
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.2421970353235965
# Final cost : 5.2421970353235965
# Compute control for a deterministic system
# Cost in iteration 0: 5.2421970353235965
# Final cost : 5.242197035275044
# Compute control for a deterministic system
# Cost in iteration 0: 5.242197035275044
# Final cost : 5.232238449602377
# Compute control for a deterministic system
# Cost in iteration 0: 5.232238449602377
# Final cost : 5.23121567306628
# Compute control for a deterministic system
# Cost in iteration 0: 5.23121567306628
# Final cost : 5.23121567306628
# Compute control for a deterministic system
# Cost in iteration 0: 5.23121567306628
# Final cost : 5.220727827770697
# Compute control for a deterministic system
# Cost in iteration 0: 5.220727827770697
# Final cost : 5.219653395207915
# Compute control for a deterministic system
# Cost in iteration 0: 5.219653395207915
# Final cost : 5.219653395207915
# Compute control for a deterministic system
# Cost in iteration 0: 5.219653395207915
# Final cost : 5.208661836224783
# Compute control for a deterministic system
# Cost in iteration 0: 5.208661836224783
# Final cost : 5.20753832781825
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.198037861595905
# Final cost : 5.198037861595905
# Compute control for a deterministic system
# Cost in iteration 0: 5.198037861595905
# Final cost : 5.1980378615334875
# Compute control for a deterministic system
# Cost in iteration 0: 5.1980378615334875
# Final cost : 5.185375767477417
# Compute control for a deterministic system
# Cost in iteration 0: 5.185375767477417
# Final cost : 5.184090146114274
# Compute control for a deterministic system
# Cost in iteration 0: 5.184090146114274
# Final cost : 5.184090146114274
# Compute control for a deterministic system
# Cost in iteration 0: 5.184090146114274
# Final cost : 5.171047730967011
# Compute control for a deterministic system
# Cost in iteration 0: 5.171047730967011
# Final cost : 5.169725192008071
# DURATION  28 80
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.216195296868632
# Final cost : 5.216195296868632
# Compute control for a deterministic system
# Cost in iteration 0: 5.216195296868632
# Final cost : 5.216195296845525
# Compute control for a deterministic system
# Cost in iteration 0: 5.216195296845525
# Final cost : 5.211083836005113
# Compute control for a deterministic system
# Cost in iteration 0: 5.211083836005113
# Final cost : 5.210517729338667
# Compute control for a deterministic system
# Cost in iteration 0: 5.210517729338667
# Final cost : 5.210517729338667
# Compute control for a deterministic system
# Cost in iteration 0: 5.210517729338667
# Final cost : 5.204301692004921
# Compute control for a deterministic system
# Cost in iteration 0: 5.204301692004921
# Final cost : 5.203624365676145
# Compute control for a deterministic system
# Cost in iteration 0: 5.203624365676145
# Final cost : 5.203624365676145
# Compute control for a deterministic system
# Cost in iteration 0: 5.203624365676145
# Final cost : 5.196302755381851
# Compute control for a deterministic system
# Cost in iteration 0: 5.196302755381851
# Final cost : 5.195516242172662
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.194487364245035
# Final cost : 5.194487364245035
# Compute control for a deterministic system
# Cost in iteration 0: 5.194487364245035
# Final cost : 5.1944873641966804
# Compute control for a deterministic system
# Cost in iteration 0: 5.1944873641966804
# Final cost : 5.184392464346349
# Compute control for a deterministic system
# Cost in iteration 0: 5.184392464346349
# Final cost : 5.183337600808949
# Compute control for a deterministic system
# Cost in iteration 0: 5.183337600808949
# Final cost : 5.183337600808949
# Compute control for a deterministic system
# Cost in iteration 0: 5.183337600808949
# Final cost : 5.172364344656096
# Compute control for a deterministic system
# Cost in iteration 0: 5.172364344656096
# Final cost : 5.171225940485296
# DURATION  36 160
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.9182141954936305
# Final cost : 2.9182141954936305
# Compute control for a deterministic system
# Cost in iteration 0: 2.9182141954936305
# Final cost : 2.918214189619373
# Compute control for a deterministic system
# Cost in iteration 0: 2.918214189619373
# Final cost : 2.9160049343803074
# Compute control for a deterministic system
# Cost in iteration 0: 2.9160049343803074
# Final cost : 2.9160046079436066
# Compute control for a deterministic system
# Cost in iteration 0: 2.9160046079436066
# Converged in iteration 8 with cost 2.916004607943606 because of vanishing difference
# Final cost : 2.916004607943606
# Compute control for a deterministic system
# Cost in iteration 0: 2.916004607943606
# Final cost : 2.916001367238718
# Compute control for a deterministic system
# Cost in iteration 0: 2.916001367238718
# Final cost : 2.916001045531509
# Compute control for a deterministic system
# Cost in iteration 0: 2.916001045531509
# Final cost : 2.916001045531509
# Compute control for a deterministic system
# Cost in iteration 0: 2.916001045531509
# Final cost : 2.9159978517772
# Compute control for a deterministic system
# Cost in iteration 0: 2.9159978517772
# Final cost : 2.915997534730657
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 5.205146951106733
# Final cost : 5.205146951106733
# Compute control for a deterministic system
# Cost in iteration 0: 5.205146951106733
# Final cost : 5.205146935967342
# Compute control for a deterministic system
# Cost in iteration 0: 5.205146935967342
# Final cost : 2.9227090131386793
# Compute control for a deterministic system
# Cost in iteration 0: 2.9227090131386793
# Final cost : 2.922514833278646
# Compute control for a deterministic system
# Cost in iteration 0: 2.922514833278646
# Final cost : 2.922514833278646
# Compute control for a deterministic system
# Cost in iteration 0: 2.922514833278646
# Final cost : 2.9205740626767653
# Compute control for a deterministic system
# Cost in iteration 0: 2.9205740626767653
# Final cost : 2.9203800833525837
# Compute control for a deterministic system
# Cost in iteration 0: 2.9203800833525837
# Converged in iteration 1 with cost 2.9203800833525837 because of vanishing difference
# Final cost : 2.9203800833525837
# Compute control for a deterministic system
# Cost in iteration 0: 2.9203800833525837
# Final cost : 2.9184412197793854
# Compute control for a deterministic system
# Cost in iteration 0: 2.9184412197793854
# Final cost : 2.918247425495841
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.935393853691083
# Final cost : 2.935393853691083
# Compute control for a deterministic system
# Cost in iteration 0: 2.935393853691083
# Final cost : 2.9353835011681397
# Compute control for a deterministic system
# Cost in iteration 0: 2.9353835011681397
# Final cost : 2.9214070975547854
# Compute control for a deterministic system
# Cost in iteration 0: 2.9214070975547854
# Final cost : 2.9212136021119703
# Compute control for a deterministic system
# Cost in iteration 0: 2.9212136021119703
# Converged in iteration 1 with cost 2.9212136021119703 because of vanishing difference
# Final cost : 2.9212136021119703
# Compute control for a deterministic system
# Cost in iteration 0: 2.9212136021119703
# Final cost : 2.9192796056067367
# Compute control for a deterministic system
# Cost in iteration 0: 2.9192796056067367
# Final cost : 2.91908629995751
# DURATION  60 400
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.303987221083477
# Final cost : 5.303987221083477
# Compute control for a deterministic system
# Cost in iteration 0: 5.303987221083477
# Final cost : 5.303895538255718
# Compute control for a deterministic system
# Cost in iteration 0: 5.303895538255718
# Final cost : 2.9225280995057883
# Compute control for a deterministic system
# Cost in iteration 0: 2.9225280995057883
# Final cost : 2.92239063735871
# Compute control for a deterministic system
# Cost in iteration 0: 2.92239063735871
# Final cost : 2.92239063735871
# Compute control for a deterministic system
# Cost in iteration 0: 2.92239063735871
# Converged in iteration 1 with cost 2.92239063735871 because of step counter
# Final cost : 2.92239063735871
# Compute control for a deterministic system
# Cost in iteration 0: 2.92239063735871
# Final cost : 2.922376927195325
# Compute control for a deterministic system
# Cost in iteration 0: 2.922376927195325
# Final cost : 2.922376927195325
# Compute control for a deterministic system
# Cost in iteration 0: 2.922376927195325
# Converged in iteration 1 with cost 2.922376927195325 because of step counter
# Final cost : 2.922376927195325
# Compute control for a deterministic system
# Cost in iteration 0: 2.922376927195325
# Final cost : 2.9223632171153175
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 2.922412004664551
# Final cost : 2.922412004664551
# Compute control for a deterministic system
# Cost in iteration 0: 2.922412004664551
# Final cost : 2.9223794448092746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9223794448092746
# Converged in iteration 1 with cost 2.9223794448092746 because of step counter
# Final cost : 2.9223794448092746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9223794448092746
# Converged in iteration 1 with cost 2.9223794448092746 because of step counter
# Final cost : 2.9223794448092746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9223794448092746
# Final cost : 2.9223794448092746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9223794448092746
# Converged in iteration 1 with cost 2.9223794448092746 because of step counter
# Final cost : 2.9223794448092746
# Compute control for a deterministic system
# Cost in iteration 0: 2.9223794448092746
# Converged in iteration 1 with cost 2.9223794448092746 because of step counter
# Final cost : 2.9223794448092746
# DURATION  80 600
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.310247540030759
# Final cost : 5.310247540030759
# Compute control for a deterministic system
# Cost in iteration 0: 5.310247540030759
# Final cost : 2.9105210041129914
# Compute control for a deterministic system
# Cost in iteration 0: 2.9105210041129914
# Converged in iteration 1 with cost 2.9105210041129914 because of step counter
# Final cost : 2.9105210041129914
# Compute control for a deterministic system
# Cost in iteration 0: 2.9105210041129914
# Converged in iteration 1 with cost 2.9105210041129914 because of step counter
# Final cost : 2.9105210041129914
# Compute control for a deterministic system
# Cost in iteration 0: 2.9105210041129914
# Final cost : 2.910521004112981
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521004112981
# Converged in iteration 1 with cost 2.910521004112981 because of step counter
# Final cost : 2.910521004112981
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521004112981
# Converged in iteration 1 with cost 2.910521004112981 because of step counter
# Final cost : 2.910521004112981
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521004112981
# Final cost : 2.910521004112981
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521004112981
# Converged in iteration 1 with cost 2.910521004112981 because of step counter
# Final cost : 2.910521004112981
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521004112981
# Converged in iteration 1 with cost 2.910521004112981 because of step counter
# Final cost : 2.910521004112981
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 5.3096130668993045
# Final cost : 5.3096130668993045
# Compute control for a deterministic system
# Cost in iteration 0: 5.3096130668993045
# Final cost : 2.910521060317186
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521060317186
# Converged in iteration 1 with cost 2.910521060317186 because of step counter
# Final cost : 2.910521060317186
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521060317186
# Converged in iteration 1 with cost 2.910521060317186 because of step counter
# Final cost : 2.910521060317186
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521060317186
# Final cost : 2.910521060317186
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521060317186
# Converged in iteration 1 with cost 2.910521060317186 because of step counter
# Final cost : 2.910521060317186
# Compute control for a deterministic system
# Cost in iteration 0: 2.910521060317186
# Converged in iteration 1 with cost 2.910521060317186 because of step counter
# Final cost : 2.910521060317186

# %%
for i in range(len(duration_array)):
    print("duration ", duration_array[i])
    print("amplitude = ", np.amax(results_w1_du["control"][i]))
    
    print(results_w1_du["cost"][i], results_w1_du["L_cost"][i][0], results_w1_du["initial_cost"][i])
    plt.plot(results_w1_du["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w1_du["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w1_du["control"][i][0,0,:], color="red")
    plt.plot(results_w1_du["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# duration  22
# amplitude =  0.00962327419192535
# 3.7146881605818485 4.687127209838622e-16 2.3998648494961143
# duration  25
# amplitude =  0.009630860249764337
# 3.310934891842467 4.687127209838622e-16 2.3998648494961143
# duration  28
# amplitude =  0.00855549334103013
# 3.036986053704229 4.687127209838622e-16 2.3998648494961143
# duration  36
# amplitude =  0.005348861394338438
# 2.915997534730657 4.687127209838622e-16 2.3998648494961143
# duration  60
# amplitude =  0.00415169615500033
# 2.910519585799458 4.687127209838622e-16 2.3998648494961143
# duration  80
# amplitude =  0.004250266424593147
# 2.9105209487834145 4.687127209838622e-16 2.3998648494961143

# %%
save(results_w1_du, fname)

# %%
fname = 'w1_du_T'
