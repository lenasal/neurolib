# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control import oc_wc

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
points_bi = [[4.2, 3.5], [5.4, 3.5] ]

# %%
def gettarget(targetstate):
    target = np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
    target[0,0,:] = targetstate[0]
    target[0,1,:] = targetstate[1]

    return target

def setinit(initstate):
    wc.params["exc_init"] = np.array([[ initstate[0] ]])
    wc.params["inh_init"] = np.array([[ initstate[1] ]])

def decrease_step_compute():

    for pow in [-4, -5]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

def increase_step_compute():

    for pow in [-2, -1, 0, 1, 2, 3, 4]:

        wc_controlled.step = 10**pow
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200*(3 + pow))

    return

def get_values(results_dict, ip, w):
    results_dict["control"][ip] = wc_controlled.control.copy()
    results_dict["state"][ip] = wc_controlled.get_xs().copy()
    results_dict["cost"][ip] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][ip] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w

    ce = np.zeros((results_dict["control"][ip].shape))
    ce[0,0,:] = results_dict["control"][ip][0,0,:]
    results_dict["L_cost"][ip][0] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][ip].shape))
    ci[0,1,:] = results_dict["control"][ip][0,1,:]
    results_dict["L_cost"][ip][1] = cost_functions.energy_cost(ci, 1., dt)

    return

def getmodel(t, w, results_dict, i):
    wc_controlled = oc_wc.OcWc(wc, target=t, w_p=1, w_2=w, print_array=[], precision_cost_interval=(int0,None), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][i]) != type(None):
        wc_controlled.control = results_dict["control"][i].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = len(points_bi)
file_array = []
for i in range(len(points_bi)):
    file_array.append('w1_' + str(i+1) + '.png')

results_w2_ud = dict([
    ('cost_type', 'w2'),
    ('point', [None] * n_points),
    ('d', [None] * n_points),
    ('u', [None] * n_points),
    ("cost", [None] * n_points),
    ("initial_cost", [None] * n_points),
    ("precision_cost", [None] * n_points),
    ("L_cost", [np.zeros((2))] * n_points),
    ("control", [None] * n_points),
    ("state", [None] * n_points),
    ("filename", file_array)
    ])

def save(results_dict):
    filehandler = open("w2_ud.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.
dt = 0.1
wc.params.dt = dt
duration = 500.
wc.params["duration"] = duration

wc.params.c_excinh = 2.
wc.params.c_inhexc = 16.
wc.params.c_inhinh = 1.

zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
bi_control = zero_input.copy()
bi_control[0,:500] = -5.
bi_control[0,2500:3000] = +5.

for i in range(len(points_bi)):

    p = points_bi[i]
    results_w2_ud['point'][i] = p

    wc.params["exc_ext"] = bi_control + p[0]
    wc.params["inh_ext"] = zero_input + p[1]
    wc.run()

    results_w2_ud['d'][i] = [wc.exc[0,2000], wc.inh[0,2000]]
    results_w2_ud['u'][i] = [wc.exc[0,-1], wc.inh[0,-1]]

    #plt.plot(wc.exc[0,:])
    #plt.show()

# %%
filehandler = open("w2_ud.pickle","rb")
results_w2_ud = pickle.load(filehandler)
filehandler.close()

# %%
int0 = 1800
w1 = 1.

control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)

for i in range(len(points_bi)):

    print("POINT ", i+1)

    p = points_bi[i]

    wc.params["exc_ext"] = zero_input + p[0]
    wc.params["inh_ext"] = zero_input + p[1]

    target = gettarget( results_w2_ud['d'][i] )
    setinit( results_w2_ud['u'][i] )

    if type(results_w2_ud["control"][i]) != type(None):
        continue
        
    wc_controlled = getmodel(target, w1, results_w2_ud, i)

    if True:

        wc_controlled.step = 1e-3
        wc_controlled.optimize(1)

        results_w2_ud["initial_cost"][i] = wc_controlled.cost_history[0]

        wc_controlled.control[0,0,-300:-200] = -5.
        wc_controlled.update_input()

        wc_controlled.step = 1e-2
        wc_controlled.optimize(100)

        increase_step_compute()
        get_values(results_w2_ud, i, w1)

    if False:
        wc_controlled.step = 10**(-17)
        wc_controlled.step_factor = 0.9
        wc_controlled.optimize(200)

        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)
            save(results_w2_ud)
            print("get values")

        continue

    wc_controlled.step_factor = 0.5

    for k in range(200):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-10] = wc_controlled.control[0,:,10:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.optimize(100)

        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)
            save(results_w2_ud)
        else: break

    for k in range(100):
        print(k)
        c0 = np.zeros((wc_controlled.control.shape))
        c0[0,:,:-1] = 1.05 * wc_controlled.control[0,:,1:]
        wc_controlled.control = c0.copy()
        wc_controlled.update_input()
        wc_controlled.optimize(0)

        decrease_step_compute()

        wc_controlled.step = 10**(-12)
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-14)
        wc_controlled.optimize(100)

        wc_controlled.step = 10**(-16)
        wc_controlled.optimize(100)

        if results_w2_ud["cost"][i] > wc_controlled.cost_history[-1]:
            get_values(results_w2_ud, i, w1)
            save(results_w2_ud)
        else: break

    save(results_w2_ud)
# Out:
# POINT  1
# Compute control for a deterministic system
# Cost in iteration 0: 14.339490966391995
# Final cost : 14.339400253479512
# Compute control for a deterministic system
# Cost in iteration 0: 135.91790797572165
# Final cost : 27.678011185606305
# Compute control for a deterministic system
# Cost in iteration 0: 27.678011185606305
# Final cost : 11.731823733413343
# Compute control for a deterministic system
# Cost in iteration 0: 11.731823733413343
# Final cost : 0.4087158567060267
# Compute control for a deterministic system
# Cost in iteration 0: 0.4087158567060267
# Final cost : 0.2932099952129903
# Compute control for a deterministic system
# Cost in iteration 0: 0.2932099952129903
# Final cost : 0.28524938917290016
# Compute control for a deterministic system
# Cost in iteration 0: 0.28524938917290016
# Final cost : 0.28380669842505507
# Compute control for a deterministic system
# Cost in iteration 0: 0.28380669842505507
# Final cost : 0.28272662175458213
# Compute control for a deterministic system
# Cost in iteration 0: 0.28272662175458213
# Converged in iteration 2 with cost 0.2827261005690153 because of vanishing difference
# Final cost : 0.2827261005690153
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.28123720603892816
# Final cost : 0.28123720603892816
# Compute control for a deterministic system
# Cost in iteration 0: 0.28123720603892816
# Final cost : 0.2809205785090905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2809205785090905
# Final cost : 0.28092044779972997
# Compute control for a deterministic system
# Cost in iteration 0: 0.28092044779972997
# Final cost : 0.2809204477997282
# Compute control for a deterministic system
# Cost in iteration 0: 0.2809204477997282
# Final cost : 0.2809204477997282
# Compute control for a deterministic system
# Cost in iteration 0: 0.2809204477997282
# Final cost : 0.2809204477997282
# 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.2798512540472939
# Final cost : 0.2798512540472939
# Compute control for a deterministic system
# Cost in iteration 0: 0.2798512540472939
# Final cost : 0.2796345377158502
# Compute control for a deterministic system
# Cost in iteration 0: 0.2796345377158502
# Final cost : 0.27963442072850486
# Compute control for a deterministic system
# Cost in iteration 0: 0.27963442072850486
# Final cost : 0.27963442072850453
# Compute control for a deterministic system
# Cost in iteration 0: 0.27963442072850453
# Final cost : 0.27963442072850453
# Compute control for a deterministic system
# Cost in iteration 0: 0.27963442072850453
# Final cost : 0.27963442072850453
# 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.2788735516513689
# Final cost : 0.2788735516513689
# Compute control for a deterministic system
# Cost in iteration 0: 0.2788735516513689
# Final cost : 0.2787186619562331
# Compute control for a deterministic system
# Cost in iteration 0: 0.2787186619562331
# Final cost : 0.2787185307002738
# Compute control for a deterministic system
# Cost in iteration 0: 0.2787185307002738
# Final cost : 0.2787185307002707
# Compute control for a deterministic system
# Cost in iteration 0: 0.2787185307002707
# Final cost : 0.2787185307002707
# Compute control for a deterministic system
# Cost in iteration 0: 0.2787185307002707
# Final cost : 0.2787185307002707
# 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.2781774364577236
# Final cost : 0.2781774364577236
# Compute control for a deterministic system
# Cost in iteration 0: 0.2781774364577236
# Final cost : 0.2780665083606852
# Compute control for a deterministic system
# Cost in iteration 0: 0.2780665083606852
# Final cost : 0.2780663553463576
# Compute control for a deterministic system
# Cost in iteration 0: 0.2780663553463576
# Final cost : 0.2780663553463562
# Compute control for a deterministic system
# Cost in iteration 0: 0.2780663553463562
# Final cost : 0.2780663553463562
# Compute control for a deterministic system
# Cost in iteration 0: 0.2780663553463562
# Final cost : 0.2780663553463562
# 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.2776818315117994
# Final cost : 0.2776818315117994
# Compute control for a deterministic system
# Cost in iteration 0: 0.2776818315117994
# Final cost : 0.27760219576496176
# Compute control for a deterministic system
# Cost in iteration 0: 0.27760219576496176
# Final cost : 0.27760202238922543
# Compute control for a deterministic system
# Cost in iteration 0: 0.27760202238922543
# Final cost : 0.27760202238922527
# Compute control for a deterministic system
# Cost in iteration 0: 0.27760202238922527
# Final cost : 0.27760202238922527
# Compute control for a deterministic system
# Cost in iteration 0: 0.27760202238922527
# Final cost : 0.27760202238922527
# 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.2773289728108655
# Final cost : 0.2773289728108655
# Compute control for a deterministic system
# Cost in iteration 0: 0.2773289728108655
# Final cost : 0.27727162763602087
# Compute control for a deterministic system
# Cost in iteration 0: 0.27727162763602087
# Final cost : 0.2772714384464581
# Compute control for a deterministic system
# Cost in iteration 0: 0.2772714384464581
# Final cost : 0.27727143844645724
# Compute control for a deterministic system
# Cost in iteration 0: 0.27727143844645724
# Final cost : 0.27727143844645724
# Compute control for a deterministic system
# Cost in iteration 0: 0.27727143844645724
# Final cost : 0.27727143844645724
# 6
# Compute control for a deterministic system
# Cost in iteration 0: 0.27707769989015557
# Final cost : 0.27707769989015557
# Compute control for a deterministic system
# Cost in iteration 0: 0.27707769989015557
# Final cost : 0.2770362427791133
# Compute control for a deterministic system
# Cost in iteration 0: 0.2770362427791133
# Final cost : 0.27703604283499345
# Compute control for a deterministic system
# Cost in iteration 0: 0.27703604283499345
# Final cost : 0.277036042834991
# Compute control for a deterministic system
# Cost in iteration 0: 0.277036042834991
# Final cost : 0.277036042834991
# Compute control for a deterministic system
# Cost in iteration 0: 0.277036042834991
# Final cost : 0.277036042834991
# 7
# Compute control for a deterministic system
# Cost in iteration 0: 0.27689868834363124
# Final cost : 0.27689868834363124
# Compute control for a deterministic system
# Cost in iteration 0: 0.27689868834363124
# Final cost : 0.27686856185366754
# Compute control for a deterministic system
# Cost in iteration 0: 0.27686856185366754
# Final cost : 0.2768683556548048
# Compute control for a deterministic system
# Cost in iteration 0: 0.2768683556548048
# Final cost : 0.2768683556548038
# Compute control for a deterministic system
# Cost in iteration 0: 0.2768683556548038
# Final cost : 0.2768683556548038
# Compute control for a deterministic system
# Cost in iteration 0: 0.2768683556548038
# Final cost : 0.2768683556548038
# 8
# Compute control for a deterministic system
# Cost in iteration 0: 0.2767710527597031
# Final cost : 0.2767710527597031
# Compute control for a deterministic system
# Cost in iteration 0: 0.2767710527597031
# Final cost : 0.2767490109477937
# Compute control for a deterministic system
# Cost in iteration 0: 0.2767490109477937
# Final cost : 0.27674880211473474
# Compute control for a deterministic system
# Cost in iteration 0: 0.27674880211473474
# Final cost : 0.27674880211473357
# Compute control for a deterministic system
# Cost in iteration 0: 0.27674880211473357
# Final cost : 0.27674880211473357
# Compute control for a deterministic system
# Cost in iteration 0: 0.27674880211473357
# Final cost : 0.27674880211473357
# 9
# Compute control for a deterministic system
# Cost in iteration 0: 0.27667992457301
# Final cost : 0.27667992457301
# Compute control for a deterministic system
# Cost in iteration 0: 0.27667992457301
# Final cost : 0.27666365512310553
# Compute control for a deterministic system
# Cost in iteration 0: 0.27666365512310553
# Final cost : 0.2766634464059197
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766634464059197
# Final cost : 0.2766634464059176
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766634464059176
# Final cost : 0.2766634464059176
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766634464059176
# Final cost : 0.2766634464059176
# 10
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766147250940751
# Final cost : 0.2766147250940751
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766147250940751
# Final cost : 0.2766025847949286
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766025847949286
# Final cost : 0.2766023781838929
# Compute control for a deterministic system
# Cost in iteration 0: 0.2766023781838929
# Final cost : 0.27660237818389044
# Compute control for a deterministic system
# Cost in iteration 0: 0.27660237818389044
# Final cost : 0.27660237818389044
# Compute control for a deterministic system
# Cost in iteration 0: 0.27660237818389044
# Final cost : 0.27660237818389044
# 11
# Compute control for a deterministic system
# Cost in iteration 0: 0.276567937438189
# Final cost : 0.276567937438189
# Compute control for a deterministic system
# Cost in iteration 0: 0.276567937438189
# Final cost : 0.27655885468602004
# Compute control for a deterministic system
# Cost in iteration 0: 0.27655885468602004
# Final cost : 0.27655865025566995
# Compute control for a deterministic system
# Cost in iteration 0: 0.27655865025566995
# Final cost : 0.2765586502556696
# Compute control for a deterministic system
# Cost in iteration 0: 0.2765586502556696
# Final cost : 0.2765586502556696
# Compute control for a deterministic system
# Cost in iteration 0: 0.2765586502556696
# Final cost : 0.2765586502556696
# 12
# Compute control for a deterministic system
# Cost in iteration 0: 0.2765343196818694
# Final cost : 0.2765343196818694
# Compute control for a deterministic system
# Cost in iteration 0: 0.2765343196818694
# Final cost : 0.27652760310455754
# Compute control for a deterministic system
# Cost in iteration 0: 0.27652760310455754
# Final cost : 0.27652740035607104
# Compute control for a deterministic system
# Cost in iteration 0: 0.27652740035607104
# Final cost : 0.27652740035606943
# Compute control for a deterministic system
# Cost in iteration 0: 0.27652740035606943
# Final cost : 0.27652740035606943
# Compute control for a deterministic system
# Cost in iteration 0: 0.27652740035606943
# Final cost : 0.27652740035606943
# 13
# Compute control for a deterministic system
# Cost in iteration 0: 0.27651022277365145
# Final cost : 0.27651022277365145
# Compute control for a deterministic system
# Cost in iteration 0: 0.27651022277365145
# Final cost : 0.27650547647495793
# Compute control for a deterministic system
# Cost in iteration 0: 0.27650547647495793
# Final cost : 0.27650527524485086
# Compute control for a deterministic system
# Cost in iteration 0: 0.27650527524485086
# Final cost : 0.27650527524484847
# Compute control for a deterministic system
# Cost in iteration 0: 0.27650527524484847
# Final cost : 0.27650527524484847
# Compute control for a deterministic system
# Cost in iteration 0: 0.27650527524484847
# Final cost : 0.27650527524484847
# 14
# Compute control for a deterministic system
# Cost in iteration 0: 0.27649315539412833
# Final cost : 0.27649315539412833
# Compute control for a deterministic system
# Cost in iteration 0: 0.27649315539412833
# Final cost : 0.276489875822446
# Compute control for a deterministic system
# Cost in iteration 0: 0.276489875822446
# Final cost : 0.27648967980385414
# Compute control for a deterministic system
# Cost in iteration 0: 0.27648967980385414
# Final cost : 0.2764896798038524
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764896798038524
# Final cost : 0.27648967980385236
# Compute control for a deterministic system
# Cost in iteration 0: 0.27648967980385236
# Final cost : 0.27648967980385236
# 15
# Compute control for a deterministic system
# Cost in iteration 0: 0.276481133471217
# Final cost : 0.276481133471217
# Compute control for a deterministic system
# Cost in iteration 0: 0.276481133471217
# Final cost : 0.2764788347437466
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764788347437466
# Final cost : 0.2764786395758047
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764786395758047
# Final cost : 0.27647863957580404
# Compute control for a deterministic system
# Cost in iteration 0: 0.27647863957580404
# Final cost : 0.27647863957580404
# Compute control for a deterministic system
# Cost in iteration 0: 0.27647863957580404
# Final cost : 0.27647863957580404
# 16
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764726162074005
# Final cost : 0.2764726162074005
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764726162074005
# Final cost : 0.27647098740172027
# Compute control for a deterministic system
# Cost in iteration 0: 0.27647098740172027
# Final cost : 0.27647079399751306
# Compute control for a deterministic system
# Cost in iteration 0: 0.27647079399751306
# Final cost : 0.2764707939975114
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764707939975114
# Final cost : 0.2764707939975114
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764707939975114
# Final cost : 0.2764707939975114
# 17
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764665507290168
# Final cost : 0.2764665507290168
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764665507290168
# Final cost : 0.27646541306945077
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646541306945077
# Final cost : 0.2764652203510812
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764652203510812
# Final cost : 0.27646522035107884
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646522035107884
# Final cost : 0.27646522035107884
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646522035107884
# Final cost : 0.27646522035107884
# 18
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646223241171974
# Final cost : 0.27646223241171974
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646223241171974
# Final cost : 0.27646142048678946
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646142048678946
# Final cost : 0.27646126989994624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27646126989994624
# Final cost : 0.2764612698999453
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764612698999453
# Final cost : 0.2764612698999453
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764612698999453
# Final cost : 0.2764612698999453
# 19
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645915606012694
# Final cost : 0.27645915606012694
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645915606012694
# Final cost : 0.27645859833863784
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645859833863784
# Final cost : 0.27645845821649867
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645845821649867
# Final cost : 0.2764584582164973
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764584582164973
# Final cost : 0.27645845821649717
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645845821649717
# Final cost : 0.27645845821649717
# 20
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645698910711786
# Final cost : 0.27645698910711786
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645698910711786
# Final cost : 0.27645657678310714
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645657678310714
# Final cost : 0.2764564909272899
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764564909272899
# Final cost : 0.2764564909272875
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764564909272875
# Final cost : 0.2764564909272875
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764564909272875
# Final cost : 0.2764564909272875
# 21
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645543934355926
# Final cost : 0.27645543934355926
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645543934355926
# Final cost : 0.27645517102716993
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645517102716993
# Final cost : 0.27645510821773056
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645510821773056
# Final cost : 0.27645510821772895
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645510821772895
# Final cost : 0.27645510821772895
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645510821772895
# Final cost : 0.27645510821772895
# 22
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764543836255798
# Final cost : 0.2764543836255798
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764543836255798
# Final cost : 0.2764541776009878
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764541776009878
# Final cost : 0.27645412929793517
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645412929793517
# Final cost : 0.2764541292979343
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764541292979343
# Final cost : 0.2764541292979343
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764541292979343
# Final cost : 0.2764541292979343
# 23
# Compute control for a deterministic system
# Cost in iteration 0: 0.2
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896077
# Converged in iteration 1 with cost 0.2764518202896077 because of step counter
# Final cost : 0.2764518202896077
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896077
# Converged in iteration 1 with cost 0.2764518202896077 because of step counter
# Final cost : 0.2764518202896077
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896077
# Final cost : 0.27645182028960713
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960713
# Final cost : 0.27645182028960713
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960713
# Final cost : 0.27645182028960713
# 83
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960696
# Final cost : 0.27645182028960696
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960696
# Converged in iteration 1 with cost 0.27645182028960696 because of step counter
# Final cost : 0.27645182028960696
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960696
# Converged in iteration 1 with cost 0.27645182028960696 because of step counter
# Final cost : 0.27645182028960696
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960696
# Final cost : 0.27645182028960696
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960696
# Final cost : 0.27645182028960685
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960685
# Final cost : 0.27645182028960685
# 84
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896066
# Final cost : 0.2764518202896066
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896066
# Converged in iteration 1 with cost 0.2764518202896066 because of step counter
# Final cost : 0.2764518202896066
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896066
# Converged in iteration 1 with cost 0.2764518202896066 because of step counter
# Final cost : 0.2764518202896066
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896066
# Final cost : 0.2764518202896064
# Compute control for a deterministic system
# Cost in iteration 0: 0.2764518202896064
# Final cost : 0.27645182028960635
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960635
# Final cost : 0.27645182028960635
# 85
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Converged in iteration 1 with cost 0.27645182028960624 because of step counter
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Converged in iteration 1 with cost 0.27645182028960624 because of step counter
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# 86
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Converged in iteration 1 with cost 0.27645182028960624 because of step counter
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Converged in iteration 1 with cost 0.27645182028960624 because of step counter
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# Compute control for a deterministic system
# Cost in iteration 0: 0.27645182028960624
# Final cost : 0.27645182028960624
# 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.30478813186929093
# Final cost : 0.30478813186929093
# Compute control for a deterministic system
# Cost in iteration 0: 0.30478813186929093
# Final cost : 0.2928366325660811
# Compute control for a deterministic system
# Cost in iteration 0: 0.2928366325660811
# Final cost : 0.29166761977501643
# Compute control for a deterministic system
# Cost in iteration 0: 0.29166761977501643
# Final cost : 0.2916676197166829
# Compute control for a deterministic system
# Cost in iteration 0: 0.2916676197166829
# Final cost : 0.2916676197160991
# Compute control for a deterministic system
# Cost in iteration 0: 0.2916676197160991
# Final cost : 0.2916676197160915
# POINT  2

# %%
for i in range(len(points_bi)):
    print("POINT ", i+1)
    print(results_w2_ud["cost"][i], results_w2_ud["initial_cost"][i])
    plt.plot(results_w2_ud["state"][i][0,0,:], color="red", linestyle='-')
    plt.plot(results_w2_ud["state"][i][0,1,:], color="blue", linestyle='-')
    plt.plot(results_w2_ud["control"][i][0,0,:], color="red")
    plt.plot(results_w2_ud["control"][i][0,1,:], color="blue")
    plt.show()
# Out:
# POINT  1
# 0.27645182028960624 14.339490966391995
# POINT  2
# 4.471541213975442 14.93201621915232
