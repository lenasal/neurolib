# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot_single(time, state, control, target, filename=None):

    fig, ax = plt.subplots(2,1)

    ax[0].plot(time, state[0,0,1:], color="red")
    ax[0].plot(time, state[0,1,1:], color="blue")
    ax[0].plot(time, target[0,0,1:], color="red", linestyle=':')
    ax[0].plot(time, target[0,1,1:], color="blue", linestyle=':')
    #ax[0].set_xlim(0,300)

    ax[1].plot(time, control[0,0,1:], color="red")
    ax[1].plot(time, control[0,1,1:], color="blue")
    #ax[1].set_xlim(0,300)

    if type(filename) != type(None):
        plt.savefig(filename)
    plt.show()

savepath =  '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + '..' + os.sep + 'writing' + os.sep + 'paper2_chaos' + os.sep + 'exploration' + os.sep + 'images_ops' + os.sep

def plot(c_array, filename):

    fig, ax = plt.subplots(len(c_array),1, figsize=(10,2.*len(c_array)))

    for i in range(len(c_array)):
        ax[i].plot(wc_controlled.model.t, c_array[i][0,0,1:], color="red")
        ax[i].plot(wc_controlled.model.t, c_array[i][0,1,1:], color="blue")
        ax[i].set_ylim([-0.4,0.4])
        ax[i].set_title(str(np.round(i*2./(len(c_array)-1), 2))+ " * pi")
        if i != len(c_array)-1:
            ax[i].set_xticklabels([])

    plt.savefig(os.path.join(savepath, filename))
    plt.show()

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 400.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
period = (peaks[-1] - peaks[-2])*dt
print("period = ", period)

wc.run()
peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)
init_peak = [wc.exc[0,51], wc.inh[0,51]]

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)
init_min = [wc.exc[0,141], wc.inh[0,141]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(100,-1,1)
plt.show()
# Out:
# period =  18.900000000000002
# peaks =  [ 109  297  485  674  863 1052 1241 1430 1619 1808 1997 2186 2375 2564
#  2753 2942 3131 3320 3509 3698 3887]
# minima =  [  17  198  386  575  764  953 1142 1331 1520 1709 1898 2087 2276 2465
#  2654 2843 3032 3220 3409 3598 3787 3976]
# peaks =  [  57  245  433  622  811 1000 1189 1378 1567 1756 1945 2134 2323 2512
#  2701 2890 3079 3268 3457 3646 3835]
# minima =  [  56  244  433  622  811 1000 1189 1378 1567 1756 1945 2134 2323 2512
#  2701 2890 3078 3267 3456 3645 3834]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 1000, None

duration = 300.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history.copy()

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L2_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish][-1] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L2_cost_unweighted"][iw][ish] = results_dict["L2_cost_weighted"][iw][ish] / w2
    wc_controlled.w_2 = w2

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]
    return p, index, target

# %%
n_points = 41
w_array = [0.125, .25, 0.5, 1., 2., 4., 8.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-125_min.png", "0-25_min.png", "0-5_min.png", "1_min.png", "2_min.png", "4_min.png", "8_min.png"]

results_min = dict([
    ('w2', w_array),
    ('models', [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

for i_w in range(len(results_min["w2"])):

    if i_w not in [1]:
        continue

    w2 = results_min['w2'][i_w]

    for i_shift in range(n_points):

        break
    
        period_shift, index_shift, target_shift = get_period_index_target(i_shift, n_points, target_min)

        wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)
        results_min["models"][i_w][i_shift] = wc_controlled

        wc_controlled.step = 1e-3
        wc_controlled.optimize(100)

        if i_shift in [0, n_points-1]:
            get_values(results_min, i_w, i_shift, w1)
            continue

        increase_step_compute()
        get_values(results_min, i_w, i_shift, w1)

    for i_shift in range(2, n_points-1):

        if i_shift not in []:
            continue

        period_shift, index_shift, target_shift = get_period_index_target(i_shift, n_points, target_min)
        wc_controlled = results_min["models"][i_w][i_shift]
        
        factor = 1.2
        if i_shift > n_points/2:
            factor = 1.
        
        wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
        wc_controlled.update_input()

        wc_controlled.step = 1e-3
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        increase_step_compute()

        if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
            print("-----------------------------------------------")
            print("0 found better solution, ", i_shift)

            get_values(results_min, i_w, i_shift, w2)
            #plot_single(wc_controlled.model.t, results_min["state"][i_w][i_shift], results_min["control"][i_w][i_shift], target_shift, filename=None)

    for i_shift in range(n_points-3, 0, -1):

        if i_shift not in []:
            continue

        print("---------------------")
        print(results_min["total_cost"][i_w][i_shift][-1])

        period_shift, index_shift, target_shift = get_period_index_target(i_shift, n_points, target_min)
        wc_controlled = results_min["models"][i_w][i_shift]

        factor = 1.2
        if i_shift < n_points/2:
            factor = 0.9
        
        wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
        wc_controlled.update_input()
        wc_controlled.simulate_forward()

        increase_step_compute()

        if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
            print("-----------------------------------------------")
            print("1 found better solution, ", i_shift)

            get_values(results_min, i_w, i_shift, w2)
            #plot_single(wc_controlled.model.t, results_min["state"][i_w][i_shift], results_min["control"][i_w][i_shift], target_shift, filename=None)


    if i_w > 0:
        for i_shift in range(1, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(i_shift, n_points, target_min)
            wc_controlled = results_min["models"][i_w][i_shift]
                        
            wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * 1.1
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                print("-----------------------------------------------")
                print("2 found better solution, ", i_shift)

                get_values(results_min, i_w, i_shift, w2)
                #plot_single(wc_controlled.model.t, results_min["state"][i_w][i_shift], results_min["control"][i_w][i_shift], target_shift, filename=None)

    if i_w != len(results_min["w2"]) - 1:
        for i_shift in range(1, n_points-1):

            period_shift, index_shift, target_shift = get_period_index_target(i_shift, n_points, target_min)
            wc_controlled = results_min["models"][i_w][i_shift]
            
            wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * 1.1
            wc_controlled.update_input()

            wc_controlled.step = 1e-3
            wc_controlled.zero_step_encountered = False
            wc_controlled.optimize(200)

            increase_step_compute()

            if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift][-1]:
                print("-----------------------------------------------")
                print("3 found better solution, ", i_shift)

                get_values(results_min, i_w, i_shift, w2)
                #plot_single(wc_controlled.model.t, results_min["state"][i_w][i_shift], results_min["control"][i_w][i_shift], target_shift, filename=None)
            
    #plot(results_min["control"][i_w], results_min["filename"][i_w])
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010581790384104213
# Final cost : 0.0002753964968702034
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002753964968702034
# Converged in iteration 167 with cost 0.00023521882861657651
# Final cost : 0.00023521882861657651
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023521882861657651
# Converged in iteration 1 with cost 0.00023521882861657651
# Final cost : 0.00023521882861657651
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023521882861657651
# Converged in iteration 1 with cost 0.00023521882861657651
# Final cost : 0.00023521882861657651
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023521882861657651
# Converged in iteration 1 with cost 0.00023521882861657651
# Final cost : 0.00023521882861657651
# -----------------------------------------------
# 2 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031837969706285055
# Final cost : 0.0008774347382025132
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008774347382025132
# Converged in iteration 166 with cost 0.0007488597653504419
# Final cost : 0.0007488597653504419
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007488597653504419
# Converged in iteration 1 with cost 0.0007488597653504419
# Final cost : 0.0007488597653504419
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007488597653504419
# Converged in iteration 1 with cost 0.0007488597653504419
# Final cost : 0.0007488597653504419
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007488597653504419
# Converged in iteration 1 with cost 0.0007488597653504419
# Final cost : 0.0007488597653504419
# -----------------------------------------------
# 2 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.006961221249541301
# Final cost : 0.001983890776832622
# Compute control for a deterministic system
# Cost in iteration 0: 0.001983890776832622
# Final cost : 0.0017067108056322523
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017067108056322523
# Converged in iteration 5 with cost 0.0017067108056321029
# Final cost : 0.0017067108056321029
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017067108056321029
# Converged in iteration 1 with cost 0.0017067108056321029
# Final cost : 0.0017067108056321029
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017067108056321029
# Converged in iteration 1 with cost 0.0017067108056321029
# Final cost : 0.0017067108056321029
# -----------------------------------------------
# 2 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.011499024355418977
# Final cost : 0.0034627592798402293
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034627592798402293
# Converged in iteration 169 with cost 0.003096253360346862
# Final cost : 0.003096253360346862
# Compute control for a deterministic system
# Cost in iteration 0: 0.003096253360346862
# Converged in iteration 1 with cost 0.003096253360346862
# Final cost : 0.003096253360346862
# Compute control for a deterministic system
# Cost in iteration 0: 0.003096253360346862
# Converged in iteration 1 with cost 0.003096253360346862
# Final cost : 0.003096253360346862
# Compute control for a deterministic system
# Cost in iteration 0: 0.003096253360346862
# Converged in iteration 1 with cost 0.003096253360346862
# Final cost : 0.003096253360346862
# -----------------------------------------------
# 2 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.014975090317070113
# Final cost : 0.0053117086626868
# Compute control for a deterministic system
# Cost in iteration 0: 0.0053117086626868
# Converged in iteration 149 with cost 0.004654699549722106
# Final cost : 0.004654699549722106
# Compute control for a deterministic system
# Cost in iteration 0: 0.004654699549722106
# Converged in iteration 1 with cost 0.004654699549722106
# Final cost : 0.004654699549722106
# Compute control for a deterministic system
# Cost in iteration 0: 0.004654699549722106
# Converged in iteration 1 with cost 0.004654699549722106
# Final cost : 0.004654699549722106
# Compute control for a deterministic system
# Cost in iteration 0: 0.004654699549722106
# Converged in iteration 1 with cost 0.004654699549722106
# Final cost : 0.004654699549722106
# -----------------------------------------------
# 2 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.019005493804792432
# Final cost : 0.006770659986822109
# Compute control for a deterministic system
# Cost in iteration 0: 0.006770659986822109
# Converged in iteration 140 with cost 0.006006568113217209
# Final cost : 0.006006568113217209
# Compute control for a deterministic system
# Cost in iteration 0: 0.006006568113217209
# Converged in iteration 1 with cost 0.006006568113217209
# Final cost : 0.006006568113217209
# Compute control for a deterministic system
# Cost in iteration 0: 0.006006568113217209
# Converged in iteration 1 with cost 0.006006568113217209
# Final cost : 0.006006568113217209
# Compute control for a deterministic system
# Cost in iteration 0: 0.006006568113217209
# Converged in iteration 1 with cost 0.006006568113217209
# Final cost : 0.006006568113217209
# -----------------------------------------------
# 2 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.024769840841245803
# Final cost : 0.009152738000676291
# Compute control for a deterministic system
# Cost in iteration 0: 0.009152738000676291
# Converged in iteration 123 with cost 0.008105048146222678
# Final cost : 0.008105048146222678
# Compute control for a deterministic system
# Cost in iteration 0: 0.008105048146222678
# Converged in iteration 1 with cost 0.008105048146222678
# Final cost : 0.008105048146222678
# Compute control for a deterministic system
# Cost in iteration 0: 0.008105048146222678
# Converged in iteration 1 with cost 0.008105048146222678
# Final cost : 0.008105048146222678
# Compute control for a deterministic system
# Cost in iteration 0: 0.008105048146222678
# Converged in iteration 1 with cost 0.008105048146222678
# Final cost : 0.008105048146222678
# -----------------------------------------------
# 2 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.03626357363706613
# Final cost : 0.011817914007084639
# Compute control for a deterministic system
# Cost in iteration 0: 0.011817914007084639
# Converged in iteration 142 with cost 0.010475384959933451
# Final cost : 0.010475384959933451
# Compute control for a deterministic system
# Cost in iteration 0: 0.010475384959933451
# Converged in iteration 1 with cost 0.010475384959933451
# Final cost : 0.010475384959933451
# Compute control for a deterministic system
# Cost in iteration 0: 0.010475384959933451
# Converged in iteration 1 with cost 0.010475384959933451
# Final cost : 0.010475384959933451
# Compute control for a deterministic system
# Cost in iteration 0: 0.010475384959933451
# Converged in iteration 1 with cost 0.010475384959933451
# Final cost : 0.010475384959933451
# -----------------------------------------------
# 2 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.07875441511040995
# Converged in iteration 49 with cost 0.021030285638728722
# Final cost : 0.021030285638728722
# Compute control for a deterministic system
# Cost in iteration 0: 0.021030285638728722
# Converged in iteration 2 with cost 0.02103028563872861
# Final cost : 0.02103028563872861
# Compute control for a deterministic system
# Cost in iteration 0: 0.02103028563872861
# Converged in iteration 1 with cost 0.02103028563872861
# Final cost : 0.02103028563872861
# Compute control for a deterministic system
# Cost in iteration 0: 0.02103028563872861
# Converged in iteration 1 with cost 0.02103028563872861
# Final cost : 0.02103028563872861
# Compute control for a deterministic system
# Cost in iteration 0: 0.02103028563872861
# Converged in iteration 1 with cost 0.02103028563872861
# Final cost : 0.02103028563872861
# Compute control for a deterministic system
# Cost in iteration 0: 0.09256568829450973
# Converged in iteration 36 with cost 0.023057835982676272
# Final cost : 0.023057835982676272
# Compute control for a deterministic system
# Cost in iteration 0: 0.023057835982676272
# Converged in iteration 1 with cost 0.023057835982676272
# Final cost : 0.023057835982676272
# Compute control for a deterministic system
# Cost in iteration 0: 0.023057835982676272
# Converged in iteration 1 with cost 0.023057835982676272
# Final cost : 0.023057835982676272
# Compute control for a deterministic system
# Cost in iteration 0: 0.023057835982676272
# Converged in iteration 1 with cost 0.023057835982676272
# Final cost : 0.023057835982676272
# Compute control for a deterministic system
# Cost in iteration 0: 0.023057835982676272
# Converged in iteration 1 with cost 0.023057835982676272
# Final cost : 0.023057835982676272
# Compute control for a deterministic system
# Cost in iteration 0: 0.12901155538239084
# Converged in iteration 22 with cost 0.025238471064818364
# Final cost : 0.025238471064818364
# Compute control for a deterministic system
# Cost in iteration 0: 0.025238471064818364
# Converged in iteration 1 with cost 0.025238471064818364
# Final cost : 0.025238471064818364
# Compute control for a deterministic system
# Cost in iteration 0: 0.025238471064818364
# Converged in iteration 1 with cost 0.025238471064818364
# Final cost : 0.025238471064818364
# Compute control for a deterministic system
# Cost in iteration 0: 0.025238471064818364
# Converged in iteration 1 with cost 0.025238471064818364
# Final cost : 0.025238471064818364
# Compute control for a deterministic system
# Cost in iteration 0: 0.025238471064818364
# Converged in iteration 1 with cost 0.025238471064818364
# Final cost : 0.025238471064818364
# Compute control for a deterministic system
# Cost in iteration 0: 0.1606213644088378
# Converged in iteration 11 with cost 0.03204404734364169
# Final cost : 0.03204404734364169
# Compute control for a deterministic system
# Cost in iteration 0: 0.03204404734364169
# Converged in iteration 1 with cost 0.03204404734364169
# Final cost : 0.03204404734364169
# Compute control for a deterministic system
# Cost in iteration 0: 0.03204404734364169
# Converged in iteration 1 with cost 0.03204404734364169
# Final cost : 0.03204404734364169
# Compute control for a deterministic system
# Cost in iteration 0: 0.03204404734364169
# Converged in iteration 1 with cost 0.03204404734364169
# Final cost : 0.03204404734364169
# Compute control for a deterministic system
# Cost in iteration 0: 0.03204404734364169
# Converged in iteration 1 with cost 0.03204404734364169
# Final cost : 0.03204404734364169
# Compute control for a deterministic system
# Cost in iteration 0: 0.15443336073158162
# Converged in iteration 6 with cost 0.04185712361695237
# Final cost : 0.04185712361695237
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185712361695237
# Converged in iteration 1 with cost 0.04185712361695237
# Final cost : 0.04185712361695237
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185712361695237
# Converged in iteration 1 with cost 0.04185712361695237
# Final cost : 0.04185712361695237
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185712361695237
# Converged in iteration 1 with cost 0.04185712361695237
# Final cost : 0.04185712361695237
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185712361695237
# Converged in iteration 1 with cost 0.04185712361695237
# Final cost : 0.04185712361695237
# Compute control for a deterministic system
# Cost in iteration 0: 0.14890325205927007
# Converged in iteration 4 with cost 0.051600691386574235
# Final cost : 0.051600691386574235
# Compute control for a deterministic system
# Cost in iteration 0: 0.051600691386574235
# Converged in iteration 1 with cost 0.051600691386574235
# Final cost : 0.051600691386574235
# Compute control for a deterministic system
# Cost in iteration 0: 0.051600691386574235
# Converged in iteration 1 with cost 0.051600691386574235
# Final cost : 0.051600691386574235
# Compute control for a deterministic system
# Cost in iteration 0: 0.051600691386574235
# Converged in iteration 1 with cost 0.051600691386574235
# Final cost : 0.051600691386574235
# Compute control for a deterministic system
# Cost in iteration 0: 0.051600691386574235
# Converged in iteration 1 with cost 0.051600691386574235
# Final cost : 0.051600691386574235
# Compute control for a deterministic system
# Cost in iteration 0: 0.13056037648885094
# Converged in iteration 3 with cost 0.0618083893979489
# Final cost : 0.0618083893979489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0618083893979489
# Converged in iteration 1 with cost 0.0618083893979489
# Final cost : 0.0618083893979489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0618083893979489
# Converged in iteration 1 with cost 0.0618083893979489
# Final cost : 0.0618083893979489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0618083893979489
# Converged in iteration 1 with cost 0.0618083893979489
# Final cost : 0.0618083893979489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0618083893979489
# Converged in iteration 1 with cost 0.0618083893979489
# Final cost : 0.0618083893979489
# Compute control for a deterministic system
# Cost in iteration 0: 0.11888157151216397
# Converged in iteration 8 with cost 0.07756397072328594
# Final cost : 0.07756397072328594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07756397072328594
# Converged in iteration 1 with cost 0.07756397072328594
# Final cost : 0.07756397072328594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07756397072328594
# Converged in iteration 1 with cost 0.07756397072328594
# Final cost : 0.07756397072328594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07756397072328594
# Converged in iteration 1 with cost 0.07756397072328594
# Final cost : 0.07756397072328594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07756397072328594
# Converged in iteration 1 with cost 0.07756397072328594
# Final cost : 0.07756397072328594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07462812882090825
# Final cost : 0.06927715046015433
# Compute control for a deterministic system
# Cost in iteration 0: 0.06927715046015433
# Final cost : 0.050783491711440025
# Compute control for a deterministic system
# Cost in iteration 0: 0.050783491711440025
# Converged in iteration 42 with cost 0.04712974724518532
# Final cost : 0.04712974724518532
# Compute control for a deterministic system
# Cost in iteration 0: 0.04712974724518532
# Converged in iteration 1 with cost 0.04712974724518532
# Final cost : 0.04712974724518532
# Compute control for a deterministic system
# Cost in iteration 0: 0.04712974724518532
# Converged in iteration 1 with cost 0.04712974724518532
# Final cost : 0.04712974724518532
# -----------------------------------------------
# 2 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.07419463114671482
# Final cost : 0.06083033543999681
# Compute control for a deterministic system
# Cost in iteration 0: 0.06083033543999681
# Final cost : 0.04802153993713838
# Compute control for a deterministic system
# Cost in iteration 0: 0.04802153993713838
# Converged in iteration 19 with cost 0.04611679834513413
# Final cost : 0.04611679834513413
# Compute control for a deterministic system
# Cost in iteration 0: 0.04611679834513413
# Converged in iteration 1 with cost 0.04611679834513413
# Final cost : 0.04611679834513413
# Compute control for a deterministic system
# Cost in iteration 0: 0.04611679834513413
# Converged in iteration 1 with cost 0.04611679834513413
# Final cost : 0.04611679834513413
# -----------------------------------------------
# 2 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.07382687644611893
# Final cost : 0.05279177891883271
# Compute control for a deterministic system
# Cost in iteration 0: 0.05279177891883271
# Final cost : 0.04634586428645819
# Compute control for a deterministic system
# Cost in iteration 0: 0.04634586428645819
# Converged in iteration 10 with cost 0.04577439087488097
# Final cost : 0.04577439087488097
# Compute control for a deterministic system
# Cost in iteration 0: 0.04577439087488097
# Converged in iteration 1 with cost 0.04577439087488097
# Final cost : 0.04577439087488097
# Compute control for a deterministic system
# Cost in iteration 0: 0.04577439087488097
# Converged in iteration 1 with cost 0.04577439087488097
# Final cost : 0.04577439087488097
# -----------------------------------------------
# 2 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.059991125459984626
# Final cost : 0.0517038216903228
# Compute control for a deterministic system
# Cost in iteration 0: 0.0517038216903228
# Final cost : 0.04410770404677996
# Compute control for a deterministic system
# Cost in iteration 0: 0.04410770404677996
# Converged in iteration 51 with cost 0.04382762663544353
# Final cost : 0.04382762663544353
# Compute control for a deterministic system
# Cost in iteration 0: 0.04382762663544353
# Converged in iteration 1 with cost 0.04382762663544353
# Final cost : 0.04382762663544353
# Compute control for a deterministic system
# Cost in iteration 0: 0.04382762663544353
# Converged in iteration 1 with cost 0.04382762663544353
# Final cost : 0.04382762663544353
# -----------------------------------------------
# 2 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.1025937314227866
# Converged in iteration 196 with cost 0.049494225267165494
# Final cost : 0.049494225267165494
# Compute control for a deterministic system
# Cost in iteration 0: 0.049494225267165494
# Converged in iteration 1 with cost 0.049494225267165494
# Final cost : 0.049494225267165494
# Compute control for a deterministic system
# Cost in iteration 0: 0.049494225267165494
# Converged in iteration 1 with cost 0.049494225267165494
# Final cost : 0.049494225267165494
# Compute control for a deterministic system
# Cost in iteration 0: 0.049494225267165494
# Converged in iteration 1 with cost 0.049494225267165494
# Final cost : 0.049494225267165494
# Compute control for a deterministic system
# Cost in iteration 0: 0.049494225267165494
# Converged in iteration 1 with cost 0.049494225267165494
# Final cost : 0.049494225267165494
# -----------------------------------------------
# 2 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.19205329054587122
# Final cost : 0.05168221811419882
# Compute control for a deterministic system
# Cost in iteration 0: 0.05168221811419882
# Converged in iteration 145 with cost 0.04600281663075523
# Final cost : 0.04600281663075523
# Compute control for a deterministic system
# Cost in iteration 0: 0.04600281663075523
# Converged in iteration 1 with cost 0.04600281663075523
# Final cost : 0.04600281663075523
# Compute control for a deterministic system
# Cost in iteration 0: 0.04600281663075523
# Converged in iteration 1 with cost 0.04600281663075523
# Final cost : 0.04600281663075523
# Compute control for a deterministic system
# Cost in iteration 0: 0.04600281663075523
# Converged in iteration 1 with cost 0.04600281663075523
# Final cost : 0.04600281663075523
# -----------------------------------------------
# 2 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.10805607840487752
# Converged in iteration 20 with cost 0.06316174276607463
# Final cost : 0.06316174276607463
# Compute control for a deterministic system
# Cost in iteration 0: 0.06316174276607463
# Converged in iteration 1 with cost 0.06316174276607463
# Final cost : 0.06316174276607463
# Compute control for a deterministic system
# Cost in iteration 0: 0.06316174276607463
# Converged in iteration 1 with cost 0.06316174276607463
# Final cost : 0.06316174276607463
# Compute control for a deterministic system
# Cost in iteration 0: 0.06316174276607463
# Converged in iteration 1 with cost 0.06316174276607463
# Final cost : 0.06316174276607463
# Compute control for a deterministic system
# Cost in iteration 0: 0.06316174276607463
# Converged in iteration 1 with cost 0.06316174276607463
# Final cost : 0.06316174276607463
# Compute control for a deterministic system
# Cost in iteration 0: 0.13694784578733105
# Final cost : 0.062118909954514516
# Compute control for a deterministic system
# Cost in iteration 0: 0.062118909954514516
# Final cost : 0.05670067379973922
# Compute control for a deterministic system
# Cost in iteration 0: 0.05670067379973922
# Converged in iteration 11 with cost 0.05668963323794556
# Final cost : 0.05668963323794556
# Compute control for a deterministic system
# Cost in iteration 0: 0.05668963323794556
# Converged in iteration 1 with cost 0.05668963323794556
# Final cost : 0.05668963323794556
# Compute control for a deterministic system
# Cost in iteration 0: 0.05668963323794556
# Converged in iteration 1 with cost 0.05668963323794556
# Final cost : 0.05668963323794556
# -----------------------------------------------
# 2 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.1277486954879885
# Final cost : 0.05689827145116404
# Compute control for a deterministic system
# Cost in iteration 0: 0.05689827145116404
# Final cost : 0.051689935725055126
# Compute control for a deterministic system
# Cost in iteration 0: 0.051689935725055126
# Converged in iteration 15 with cost 0.05166108564082626
# Final cost : 0.05166108564082626
# Compute control for a deterministic system
# Cost in iteration 0: 0.05166108564082626
# Converged in iteration 1 with cost 0.05166108564082626
# Final cost : 0.05166108564082626
# Compute control for a deterministic system
# Cost in iteration 0: 0.05166108564082626
# Converged in iteration 1 with cost 0.05166108564082626
# Final cost : 0.05166108564082626
# -----------------------------------------------
# 2 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.11964125824012975
# Final cost : 0.049460748155273244
# Compute control for a deterministic system
# Cost in iteration 0: 0.049460748155273244
# Final cost : 0.044259326081778426
# Compute control for a deterministic system
# Cost in iteration 0: 0.044259326081778426
# Converged in iteration 13 with cost 0.04423606959246096
# Final cost : 0.04423606959246096
# Compute control for a deterministic system
# Cost in iteration 0: 0.04423606959246096
# Converged in iteration 1 with cost 0.04423606959246096
# Final cost : 0.04423606959246096
# Compute control for a deterministic system
# Cost in iteration 0: 0.04423606959246096
# Converged in iteration 1 with cost 0.04423606959246096
# Final cost : 0.04423606959246096
# -----------------------------------------------
# 2 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.10303781855217076
# Final cost : 0.039994100911519774
# Compute control for a deterministic system
# Cost in iteration 0: 0.039994100911519774
# Final cost : 0.035467341163337295
# Compute control for a deterministic system
# Cost in iteration 0: 0.035467341163337295
# Converged in iteration 5 with cost 0.035464121261140485
# Final cost : 0.035464121261140485
# Compute control for a deterministic system
# Cost in iteration 0: 0.035464121261140485
# Converged in iteration 1 with cost 0.035464121261140485
# Final cost : 0.035464121261140485
# Compute control for a deterministic system
# Cost in iteration 0: 0.035464121261140485
# Converged in iteration 1 with cost 0.035464121261140485
# Final cost : 0.035464121261140485
# -----------------------------------------------
# 2 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.12052753154062162
# Final cost : 0.034803512379733906
# Compute control for a deterministic system
# Cost in iteration 0: 0.034803512379733906
# Final cost : 0.029675375873168756
# Compute control for a deterministic system
# Cost in iteration 0: 0.029675375873168756
# Converged in iteration 10 with cost 0.029657668187159755
# Final cost : 0.029657668187159755
# Compute control for a deterministic system
# Cost in iteration 0: 0.029657668187159755
# Converged in iteration 1 with cost 0.029657668187159755
# Final cost : 0.029657668187159755
# Compute control for a deterministic system
# Cost in iteration 0: 0.029657668187159755
# Converged in iteration 1 with cost 0.029657668187159755
# Final cost : 0.029657668187159755
# -----------------------------------------------
# 2 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.12069129841509163
# Final cost : 0.02919258780518632
# Compute control for a deterministic system
# Cost in iteration 0: 0.02919258780518632
# Final cost : 0.023948167731479186
# Compute control for a deterministic system
# Cost in iteration 0: 0.023948167731479186
# Converged in iteration 12 with cost 0.02393364956568996
# Final cost : 0.02393364956568996
# Compute control for a deterministic system
# Cost in iteration 0: 0.02393364956568996
# Converged in iteration 1 with cost 0.02393364956568996
# Final cost : 0.02393364956568996
# Compute control for a deterministic system
# Cost in iteration 0: 0.02393364956568996
# Converged in iteration 1 with cost 0.02393364956568996
# Final cost : 0.02393364956568996
# -----------------------------------------------
# 2 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.11156224017083051
# Final cost : 0.02407765813851749
# Compute control for a deterministic system
# Cost in iteration 0: 0.02407765813851749
# Final cost : 0.01921451392606026
# Compute control for a deterministic system
# Cost in iteration 0: 0.01921451392606026
# Converged in iteration 78 with cost 0.01921326057877889
# Final cost : 0.01921326057877889
# Compute control for a deterministic system
# Cost in iteration 0: 0.01921326057877889
# Converged in iteration 1 with cost 0.01921326057877889
# Final cost : 0.01921326057877889
# Compute control for a deterministic system
# Cost in iteration 0: 0.01921326057877889
# Converged in iteration 1 with cost 0.01921326057877889
# Final cost : 0.01921326057877889
# -----------------------------------------------
# 2 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.0763575385490787
# Final cost : 0.01997829498475143
# Compute control for a deterministic system
# Cost in iteration 0: 0.01997829498475143
# Converged in iteration 195 with cost 0.016204691217850245
# Final cost : 0.016204691217850245
# Compute control for a deterministic system
# Cost in iteration 0: 0.016204691217850245
# Converged in iteration 2 with cost 0.016204691217850224
# Final cost : 0.016204691217850224
# Compute control for a deterministic system
# Cost in iteration 0: 0.016204691217850224
# Converged in iteration 1 with cost 0.016204691217850224
# Final cost : 0.016204691217850224
# Compute control for a deterministic system
# Cost in iteration 0: 0.016204691217850224
# Converged in iteration 1 with cost 0.016204691217850224
# Final cost : 0.016204691217850224
# -----------------------------------------------
# 2 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.07978654429889086
# Final cost : 0.016564859162502107
# Compute control for a deterministic system
# Cost in iteration 0: 0.016564859162502107
# Final cost : 0.012429870130776788
# Compute control for a deterministic system
# Cost in iteration 0: 0.012429870130776788
# Converged in iteration 44 with cost 0.012363523203257905
# Final cost : 0.012363523203257905
# Compute control for a deterministic system
# Cost in iteration 0: 0.012363523203257905
# Converged in iteration 1 with cost 0.012363523203257905
# Final cost : 0.012363523203257905
# Compute control for a deterministic system
# Cost in iteration 0: 0.012363523203257905
# Converged in iteration 1 with cost 0.012363523203257905
# Final cost : 0.012363523203257905
# -----------------------------------------------
# 2 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.057193953350473135
# Final cost : 0.016473917098109497
# Compute control for a deterministic system
# Cost in iteration 0: 0.016473917098109497
# Final cost : 0.014486282216354828
# Compute control for a deterministic system
# Cost in iteration 0: 0.014486282216354828
# Converged in iteration 40 with cost 0.014461412230342011
# Final cost : 0.014461412230342011
# Compute control for a deterministic system
# Cost in iteration 0: 0.014461412230342011
# Converged in iteration 1 with cost 0.014461412230342011
# Final cost : 0.014461412230342011
# Compute control for a deterministic system
# Cost in iteration 0: 0.014461412230342011
# Converged in iteration 1 with cost 0.014461412230342011
# Final cost : 0.014461412230342011
# Compute control for a deterministic system
# Cost in iteration 0: 0.03824023484957414
# Final cost : 0.011387321851123795
# Compute control for a deterministic system
# Cost in iteration 0: 0.011387321851123795
# Converged in iteration 116 with cost 0.010163486817659769
# Final cost : 0.010163486817659769
# Compute control for a deterministic system
# Cost in iteration 0: 0.010163486817659769
# Converged in iteration 1 with cost 0.010163486817659769
# Final cost : 0.010163486817659769
# Compute control for a deterministic system
# Cost in iteration 0: 0.010163486817659769
# Converged in iteration 1 with cost 0.010163486817659769
# Final cost : 0.010163486817659769
# Compute control for a deterministic system
# Cost in iteration 0: 0.010163486817659769
# Converged in iteration 1 with cost 0.010163486817659769
# Final cost : 0.010163486817659769
# -----------------------------------------------
# 2 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.028179405664982164
# Final cost : 0.008211850006960552
# Compute control for a deterministic system
# Cost in iteration 0: 0.008211850006960552
# Converged in iteration 128 with cost 0.007317524238468909
# Final cost : 0.007317524238468909
# Compute control for a deterministic system
# Cost in iteration 0: 0.007317524238468909
# Converged in iteration 1 with cost 0.007317524238468909
# Final cost : 0.007317524238468909
# Compute control for a deterministic system
# Cost in iteration 0: 0.007317524238468909
# Converged in iteration 1 with cost 0.007317524238468909
# Final cost : 0.007317524238468909
# Compute control for a deterministic system
# Cost in iteration 0: 0.007317524238468909
# Converged in iteration 1 with cost 0.007317524238468909
# Final cost : 0.007317524238468909
# -----------------------------------------------
# 2 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.016970565205026305
# Final cost : 0.004998127495987461
# Compute control for a deterministic system
# Cost in iteration 0: 0.004998127495987461
# Converged in iteration 111 with cost 0.004495522735167488
# Final cost : 0.004495522735167488
# Compute control for a deterministic system
# Cost in iteration 0: 0.004495522735167488
# Converged in iteration 1 with cost 0.004495522735167488
# Final cost : 0.004495522735167488
# Compute control for a deterministic system
# Cost in iteration 0: 0.004495522735167488
# Converged in iteration 1 with cost 0.004495522735167488
# Final cost : 0.004495522735167488
# Compute control for a deterministic system
# Cost in iteration 0: 0.004495522735167488
# Converged in iteration 1 with cost 0.004495522735167488
# Final cost : 0.004495522735167488
# -----------------------------------------------
# 2 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.008689482550207784
# Final cost : 0.002646119377505637
# Compute control for a deterministic system
# Cost in iteration 0: 0.002646119377505637
# Converged in iteration 92 with cost 0.0023962969421007403
# Final cost : 0.0023962969421007403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023962969421007403
# Converged in iteration 1 with cost 0.0023962969421007403
# Final cost : 0.0023962969421007403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023962969421007403
# Converged in iteration 1 with cost 0.0023962969421007403
# Final cost : 0.0023962969421007403
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023962969421007403
# Converged in iteration 1 with cost 0.0023962969421007403
# Final cost : 0.0023962969421007403
# -----------------------------------------------
# 2 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034151297906060835
# Final cost : 0.001089161689700932
# Compute control for a deterministic system
# Cost in iteration 0: 0.001089161689700932
# Converged in iteration 80 with cost 0.0009709065475352688
# Final cost : 0.0009709065475352688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009709065475352688
# Converged in iteration 1 with cost 0.0009709065475352688
# Final cost : 0.0009709065475352688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009709065475352688
# Converged in iteration 1 with cost 0.0009709065475352688
# Final cost : 0.0009709065475352688
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009709065475352688
# Converged in iteration 1 with cost 0.0009709065475352688
# Final cost : 0.0009709065475352688
# -----------------------------------------------
# 2 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010843125561964167
# Final cost : 0.0003381450503434965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003381450503434965
# Converged in iteration 127 with cost 0.0003006810376577515
# Final cost : 0.0003006810376577515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003006810376577515
# Converged in iteration 1 with cost 0.0003006810376577515
# Final cost : 0.0003006810376577515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003006810376577515
# Converged in iteration 1 with cost 0.0003006810376577515
# Final cost : 0.0003006810376577515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003006810376577515
# Converged in iteration 1 with cost 0.0003006810376577515
# Final cost : 0.0003006810376577515
# -----------------------------------------------
# 2 found better solution,  39
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010155944714026954
# Final cost : 0.00031301436923001036
# Compute control for a deterministic system
# Cost in iteration 0: 0.00031301436923001036
# Converged in iteration 200 with cost 0.0002684896831583925
# Final cost : 0.0002684896831583925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002684896831583925
# Converged in iteration 1 with cost 0.0002684896831583925
# Final cost : 0.0002684896831583925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002684896831583925
# Converged in iteration 1 with cost 0.0002684896831583925
# Final cost : 0.0002684896831583925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002684896831583925
# Converged in iteration 1 with cost 0.0002684896831583925
# Final cost : 0.0002684896831583925
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029317156329738
# Final cost : 0.0008662074153629289
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008662074153629289
# Converged in iteration 156 with cost 0.0007955210384157251
# Final cost : 0.0007955210384157251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007955210384157251
# Converged in iteration 1 with cost 0.0007955210384157251
# Final cost : 0.0007955210384157251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007955210384157251
# Converged in iteration 1 with cost 0.0007955210384157251
# Final cost : 0.0007955210384157251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007955210384157251
# Converged in iteration 1 with cost 0.0007955210384157251
# Final cost : 0.0007955210384157251
# Compute control for a deterministic system
# Cost in iteration 0: 0.006797932350340222
# Final cost : 0.002192420256415818
# Compute control for a deterministic system
# Cost in iteration 0: 0.002192420256415818
# Final cost : 0.0018905941533685952
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018905941533685952
# Converged in iteration 118 with cost 0.0018676811018814002
# Final cost : 0.0018676811018814002
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018676811018814002
# Converged in iteration 1 with cost 0.0018676811018814002
# Final cost : 0.0018676811018814002
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018676811018814002
# Converged in iteration 1 with cost 0.0018676811018814002
# Final cost : 0.0018676811018814002
# Compute control for a deterministic system
# Cost in iteration 0: 0.012071662937158677
# Final cost : 0.00368029515099923
# Compute control for a deterministic system
# Cost in iteration 0: 0.00368029515099923
# Final cost : 0.0033963351522019454
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033963351522019454
# Final cost : 0.0033740432179385467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033740432179385467
# Converged in iteration 13 with cost 0.003373997283208091
# Final cost : 0.003373997283208091
# Compute control for a deterministic system
# Cost in iteration 0: 0.003373997283208091
# Converged in iteration 1 with cost 0.003373997283208091
# Final cost : 0.003373997283208091
# Compute control for a deterministic system
# Cost in iteration 0: 0.01838249848372977
# Final cost : 0.005745795998596611
# Compute control for a deterministic system
# Cost in iteration 0: 0.005745795998596611
# Final cost : 0.005092850052702108
# Compute control for a deterministic system
# Cost in iteration 0: 0.005092850052702108
# Converged in iteration 67 with cost 0.00506578245869789
# Final cost : 0.00506578245869789
# Compute control for a deterministic system
# Cost in iteration 0: 0.00506578245869789
# Converged in iteration 1 with cost 0.00506578245869789
# Final cost : 0.00506578245869789
# Compute control for a deterministic system
# Cost in iteration 0: 0.00506578245869789
# Converged in iteration 1 with cost 0.00506578245869789
# Final cost : 0.00506578245869789
# Compute control for a deterministic system
# Cost in iteration 0: 0.025311565127027844
# Final cost : 0.007098597271615138
# Compute control for a deterministic system
# Cost in iteration 0: 0.007098597271615138
# Converged in iteration 38 with cost 0.006677392347861791
# Final cost : 0.006677392347861791
# Compute control for a deterministic system
# Cost in iteration 0: 0.006677392347861791
# Converged in iteration 1 with cost 0.006677392347861791
# Final cost : 0.006677392347861791
# Compute control for a deterministic system
# Cost in iteration 0: 0.006677392347861791
# Converged in iteration 1 with cost 0.006677392347861791
# Final cost : 0.006677392347861791
# Compute control for a deterministic system
# Cost in iteration 0: 0.006677392347861791
# Converged in iteration 1 with cost 0.006677392347861791
# Final cost : 0.006677392347861791
# Compute control for a deterministic system
# Cost in iteration 0: 0.050882295946249476
# Final cost : 0.010225119559308982
# Compute control for a deterministic system
# Cost in iteration 0: 0.010225119559308982
# Converged in iteration 183 with cost 0.0085646207052321
# Final cost : 0.0085646207052321
# Compute control for a deterministic system
# Cost in iteration 0: 0.0085646207052321
# Converged in iteration 1 with cost 0.0085646207052321
# Final cost : 0.0085646207052321
# Compute control for a deterministic system
# Cost in iteration 0: 0.0085646207052321
# Converged in iteration 1 with cost 0.0085646207052321
# Final cost : 0.0085646207052321
# Compute control for a deterministic system
# Cost in iteration 0: 0.0085646207052321
# Converged in iteration 1 with cost 0.0085646207052321
# Final cost : 0.0085646207052321
# Compute control for a deterministic system
# Cost in iteration 0: 0.07060968523180507
# Final cost : 0.013243874074226837
# Compute control for a deterministic system
# Cost in iteration 0: 0.013243874074226837
# Converged in iteration 174 with cost 0.01058004423282183
# Final cost : 0.01058004423282183
# Compute control for a deterministic system
# Cost in iteration 0: 0.01058004423282183
# Converged in iteration 1 with cost 0.01058004423282183
# Final cost : 0.01058004423282183
# Compute control for a deterministic system
# Cost in iteration 0: 0.01058004423282183
# Converged in iteration 1 with cost 0.01058004423282183
# Final cost : 0.01058004423282183
# Compute control for a deterministic system
# Cost in iteration 0: 0.01058004423282183
# Converged in iteration 1 with cost 0.01058004423282183
# Final cost : 0.01058004423282183
# Compute control for a deterministic system
# Cost in iteration 0: 0.08608134066880094
# Converged in iteration 64 with cost 0.017840024783143046
# Final cost : 0.017840024783143046
# Compute control for a deterministic system
# Cost in iteration 0: 0.017840024783143046
# Converged in iteration 1 with cost 0.017840024783143046
# Final cost : 0.017840024783143046
# Compute control for a deterministic system
# Cost in iteration 0: 0.017840024783143046
# Converged in iteration 1 with cost 0.017840024783143046
# Final cost : 0.017840024783143046
# Compute control for a deterministic system
# Cost in iteration 0: 0.017840024783143046
# Converged in iteration 1 with cost 0.017840024783143046
# Final cost : 0.017840024783143046
# Compute control for a deterministic system
# Cost in iteration 0: 0.017840024783143046
# Converged in iteration 1 with cost 0.017840024783143046
# Final cost : 0.017840024783143046
# Compute control for a deterministic system
# Cost in iteration 0: 0.11727550212341685
# Converged in iteration 36 with cost 0.022224314958658266
# Final cost : 0.022224314958658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.022224314958658266
# Converged in iteration 1 with cost 0.022224314958658266
# Final cost : 0.022224314958658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.022224314958658266
# Converged in iteration 1 with cost 0.022224314958658266
# Final cost : 0.022224314958658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.022224314958658266
# Converged in iteration 1 with cost 0.022224314958658266
# Final cost : 0.022224314958658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.022224314958658266
# Converged in iteration 1 with cost 0.022224314958658266
# Final cost : 0.022224314958658266
# Compute control for a deterministic system
# Cost in iteration 0: 0.16073314397361976
# Converged in iteration 24 with cost 0.025893744305261104
# Final cost : 0.025893744305261104
# Compute control for a deterministic system
# Cost in iteration 0: 0.025893744305261104
# Converged in iteration 1 with cost 0.025893744305261104
# Final cost : 0.025893744305261104
# Compute control for a deterministic system
# Cost in iteration 0: 0.025893744305261104
# Converged in iteration 1 with cost 0.025893744305261104
# Final cost : 0.025893744305261104
# Compute control for a deterministic system
# Cost in iteration 0: 0.025893744305261104
# Converged in iteration 1 with cost 0.025893744305261104
# Final cost : 0.025893744305261104
# Compute control for a deterministic system
# Cost in iteration 0: 0.025893744305261104
# Converged in iteration 1 with cost 0.025893744305261104
# Final cost : 0.025893744305261104
# Compute control for a deterministic system
# Cost in iteration 0: 0.23863979999703783
# Converged in iteration 15 with cost 0.02854213998577661
# Final cost : 0.02854213998577661
# Compute control for a deterministic system
# Cost in iteration 0: 0.02854213998577661
# Converged in iteration 1 with cost 0.02854213998577661
# Final cost : 0.02854213998577661
# Compute control for a deterministic system
# Cost in iteration 0: 0.02854213998577661
# Converged in iteration 1 with cost 0.02854213998577661
# Final cost : 0.02854213998577661
# Compute control for a deterministic system
# Cost in iteration 0: 0.02854213998577661
# Converged in iteration 1 with cost 0.02854213998577661
# Final cost : 0.02854213998577661
# Compute control for a deterministic system
# Cost in iteration 0: 0.02854213998577661
# Converged in iteration 1 with cost 0.02854213998577661
# Final cost : 0.02854213998577661
# Compute control for a deterministic system
# Cost in iteration 0: 0.19765404510594253
# Converged in iteration 7 with cost 0.036507998114268934
# Final cost : 0.036507998114268934
# Compute control for a deterministic system
# Cost in iteration 0: 0.036507998114268934
# Converged in iteration 1 with cost 0.036507998114268934
# Final cost : 0.036507998114268934
# Compute control for a deterministic system
# Cost in iteration 0: 0.036507998114268934
# Converged in iteration 1 with cost 0.036507998114268934
# Final cost : 0.036507998114268934
# Compute control for a deterministic system
# Cost in iteration 0: 0.036507998114268934
# Converged in iteration 1 with cost 0.036507998114268934
# Final cost : 0.036507998114268934
# Compute control for a deterministic system
# Cost in iteration 0: 0.036507998114268934
# Converged in iteration 1 with cost 0.036507998114268934
# Final cost : 0.036507998114268934
# Compute control for a deterministic system
# Cost in iteration 0: 0.18317791144051776
# Converged in iteration 3 with cost 0.04447337590457716
# Final cost : 0.04447337590457716
# Compute control for a deterministic system
# Cost in iteration 0: 0.04447337590457716
# Converged in iteration 1 with cost 0.04447337590457716
# Final cost : 0.04447337590457716
# Compute control for a deterministic system
# Cost in iteration 0: 0.04447337590457716
# Converged in iteration 1 with cost 0.04447337590457716
# Final cost : 0.04447337590457716
# Compute control for a deterministic system
# Cost in iteration 0: 0.04447337590457716
# Converged in iteration 1 with cost 0.04447337590457716
# Final cost : 0.04447337590457716
# Compute control for a deterministic system
# Cost in iteration 0: 0.04447337590457716
# Converged in iteration 1 with cost 0.04447337590457716
# Final cost : 0.04447337590457716
# Compute control for a deterministic system
# Cost in iteration 0: 0.15355679280470477
# Converged in iteration 2 with cost 0.05354054922787273
# Final cost : 0.05354054922787273
# Compute control for a deterministic system
# Cost in iteration 0: 0.05354054922787273
# Converged in iteration 1 with cost 0.05354054922787273
# Final cost : 0.05354054922787273
# Compute control for a deterministic system
# Cost in iteration 0: 0.05354054922787273
# Converged in iteration 1 with cost 0.05354054922787273
# Final cost : 0.05354054922787273
# Compute control for a deterministic system
# Cost in iteration 0: 0.05354054922787273
# Converged in iteration 1 with cost 0.05354054922787273
# Final cost : 0.05354054922787273
# Compute control for a deterministic system
# Cost in iteration 0: 0.05354054922787273
# Converged in iteration 1 with cost 0.05354054922787273
# Final cost : 0.05354054922787273
# Compute control for a deterministic system
# Cost in iteration 0: 0.13591244441555606
# Converged in iteration 2 with cost 0.061872580365081656
# Final cost : 0.061872580365081656
# Compute control for a deterministic system
# Cost in iteration 0: 0.061872580365081656
# Converged in iteration 1 with cost 0.061872580365081656
# Final cost : 0.061872580365081656
# Compute control for a deterministic system
# Cost in iteration 0: 0.061872580365081656
# Converged in iteration 1 with cost 0.061872580365081656
# Final cost : 0.061872580365081656
# Compute control for a deterministic system
# Cost in iteration 0: 0.061872580365081656
# Converged in iteration 1 with cost 0.061872580365081656
# Final cost : 0.061872580365081656
# Compute control for a deterministic system
# Cost in iteration 0: 0.061872580365081656
# Converged in iteration 1 with cost 0.061872580365081656
# Final cost : 0.061872580365081656
# Compute control for a deterministic system
# Cost in iteration 0: 0.1269279028965058
# Converged in iteration 2 with cost 0.07681466051492367
# Final cost : 0.07681466051492367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07681466051492367
# Converged in iteration 1 with cost 0.07681466051492367
# Final cost : 0.07681466051492367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07681466051492367
# Converged in iteration 1 with cost 0.07681466051492367
# Final cost : 0.07681466051492367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07681466051492367
# Converged in iteration 1 with cost 0.07681466051492367
# Final cost : 0.07681466051492367
# Compute control for a deterministic system
# Cost in iteration 0: 0.07681466051492367
# Converged in iteration 1 with cost 0.07681466051492367
# Final cost : 0.07681466051492367
# Compute control for a deterministic system
# Cost in iteration 0: 0.5624488319592381
# Final cost : 0.3040342677588292
# Compute control for a deterministic system
# Cost in iteration 0: 0.3040342677588292
# Final cost : 0.2924823070541302
# Compute control for a deterministic system
# Cost in iteration 0: 0.2924823070541302
# Final cost : 0.2566069461892319
# Compute control for a deterministic system
# Cost in iteration 0: 0.2566069461892319
# Final cost : 0.21639520837520582
# Compute control for a deterministic system
# Cost in iteration 0: 0.21639520837520582
# Converged in iteration 738 with cost 0.05239806348486626
# Final cost : 0.05239806348486626
# Compute control for a deterministic system
# Cost in iteration 0: 0.5491706394671501
# Final cost : 0.27734846949373404
# Compute control for a deterministic system
# Cost in iteration 0: 0.27734846949373404
# Final cost : 0.26481201529913106
# Compute control for a deterministic system
# Cost in iteration 0: 0.26481201529913106
# Final cost : 0.21757491961254513
# Compute control for a deterministic system
# Cost in iteration 0: 0.21757491961254513
# Final cost : 0.16986946480002613
# Compute control for a deterministic system
# Cost in iteration 0: 0.16986946480002613
# Converged in iteration 865 with cost 0.04760385805950162
# Final cost : 0.04760385805950162
# Compute control for a deterministic system
# Cost in iteration 0: 0.46983540090726883
# Final cost : 0.25290297742762163
# Compute control for a deterministic system
# Cost in iteration 0: 0.25290297742762163
# Final cost : 0.24100414171189427
# Compute control for a deterministic system
# Cost in iteration 0: 0.24100414171189427
# Final cost : 0.19116958270776369
# Compute control for a deterministic system
# Cost in iteration 0: 0.19116958270776369
# Final cost : 0.14458159746705074
# Compute control for a deterministic system
# Cost in iteration 0: 0.14458159746705074
# Cost in iteration 1000: 0.08894709434597786
# Final cost : 0.08894709434597786
# Compute control for a deterministic system
# Cost in iteration 0: 0.42809459633011404
# Final cost : 0.21913070274805263
# Compute control for a deterministic system
# Cost in iteration 0: 0.21913070274805263
# Final cost : 0.2079002713428761
# Compute control for a deterministic system
# Cost in iteration 0: 0.2079002713428761
# Final cost : 0.163851401421942
# Compute control for a deterministic system
# Cost in iteration 0: 0.163851401421942
# Final cost : 0.12601872591198693
# Compute control for a deterministic system
# Cost in iteration 0: 0.12601872591198693
# Cost in iteration 1000: 0.08608620903199547
# Final cost : 0.08608620903199547
# Compute control for a deterministic system
# Cost in iteration 0: 0.43086562574881354
# Final cost : 0.18371161721840512
# Compute control for a deterministic system
# Cost in iteration 0: 0.18371161721840512
# Final cost : 0.17283981061319714
# Compute control for a deterministic system
# Cost in iteration 0: 0.17283981061319714
# Final cost : 0.14029258141316797
# Compute control for a deterministic system
# Cost in iteration 0: 0.14029258141316797
# Final cost : 0.11344978948990969
# Compute control for a deterministic system
# Cost in iteration 0: 0.11344978948990969
# Cost in iteration 1000: 0.0798314220805359
# Final cost : 0.0798314220805359
# Compute control for a deterministic system
# Cost in iteration 0: 0.5542567371449468
# Final cost : 0.18392215094102538
# Compute control for a deterministic system
# Cost in iteration 0: 0.18392215094102538
# Final cost : 0.13917577657719107
# Compute control for a deterministic system
# Cost in iteration 0: 0.13917577657719107
# Final cost : 0.12002405661148788
# Compute control for a deterministic system
# Cost in iteration 0: 0.12002405661148788
# Final cost : 0.1034541893940239
# Compute control for a deterministic system
# Cost in iteration 0: 0.1034541893940239
# Cost in iteration 1000: 0.07637902570492162
# Final cost : 0.07637902570492162
# Compute control for a deterministic system
# Cost in iteration 0: 0.34272982773895977
# Final cost : 0.14046968716190006
# Compute control for a deterministic system
# Cost in iteration 0: 0.14046968716190006
# Final cost : 0.13277114311228186
# Compute control for a deterministic system
# Cost in iteration 0: 0.13277114311228186
# Final cost : 0.11807801436765496
# Compute control for a deterministic system
# Cost in iteration 0: 0.11807801436765496
# Final cost : 0.10624960918264033
# Compute control for a deterministic system
# Cost in iteration 0: 0.10624960918264033
# Cost in iteration 1000: 0.07788537474882276
# Final cost : 0.07788537474882276
# Compute control for a deterministic system
# Cost in iteration 0: 0.373110792867676
# Final cost : 0.1299641028183457
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299641028183457
# Final cost : 0.10352882711959477
# Compute control for a deterministic system
# Cost in iteration 0: 0.10352882711959477
# Final cost : 0.0955250477720062
# Compute control for a deterministic system
# Cost in iteration 0: 0.0955250477720062
# Final cost : 0.08958745180402922
# Compute control for a deterministic system
# Cost in iteration 0: 0.08958745180402922
# Cost in iteration 1000: 0.07627797587495769
# Final cost : 0.07627797587495769
# Compute control for a deterministic system
# Cost in iteration 0: 0.25873571983006904
# Final cost : 0.09079734800706218
# Compute control for a deterministic system
# Cost in iteration 0: 0.09079734800706218
# Final cost : 0.08503609529832011
# Compute control for a deterministic system
# Cost in iteration 0: 0.08503609529832011
# Final cost : 0.07899835802263311
# Compute control for a deterministic system
# Cost in iteration 0: 0.07899835802263311
# Final cost : 0.07542849124068518
# Compute control for a deterministic system
# Cost in iteration 0: 0.07542849124068518
# Cost in iteration 1000: 0.06934871216996281
# Final cost : 0.06934871216996281
# Compute control for a deterministic system
# Cost in iteration 0: 0.22020122683472185
# Final cost : 0.07209626948281467
# Compute control for a deterministic system
# Cost in iteration 0: 0.07209626948281467
# Final cost : 0.06712948519849771
# Compute control for a deterministic system
# Cost in iteration 0: 0.06712948519849771
# Final cost : 0.06316985415207817
# Compute control for a deterministic system
# Cost in iteration 0: 0.06316985415207817
# Final cost : 0.06116746581763072
# Compute control for a deterministic system
# Cost in iteration 0: 0.06116746581763072
# Cost in iteration 1000: 0.05871006280505622
# Final cost : 0.05871006280505622
# Compute control for a deterministic system
# Cost in iteration 0: 0.19159177105727282
# Final cost : 0.05979470324818095
# Compute control for a deterministic system
# Cost in iteration 0: 0.05979470324818095
# Final cost : 0.0554150553724826
# Compute control for a deterministic system
# Cost in iteration 0: 0.0554150553724826
# Final cost : 0.05255259020775678
# Compute control for a deterministic system
# Cost in iteration 0: 0.05255259020775678
# Final cost : 0.05126812197318345
# Compute control for a deterministic system
# Cost in iteration 0: 0.05126812197318345
# Cost in iteration 1000: 0.050041964734476176
# Final cost : 0.050041964734476176
# Compute control for a deterministic system
# Cost in iteration 0: 0.1585949616971542
# Final cost : 0.047178418623395495
# Compute control for a deterministic system
# Cost in iteration 0: 0.047178418623395495
# Final cost : 0.04348139636192706
# Compute control for a deterministic system
# Cost in iteration 0: 0.04348139636192706
# Final cost : 0.041554296527909866
# Compute control for a deterministic system
# Cost in iteration 0: 0.041554296527909866
# Final cost : 0.040802066303571166
# Compute control for a deterministic system
# Cost in iteration 0: 0.040802066303571166
# Cost in iteration 1000: 0.040256600275158566
# Final cost : 0.040256600275158566
# Compute control for a deterministic system
# Cost in iteration 0: 0.14761525285427415
# Final cost : 0.03985794705999574
# Compute control for a deterministic system
# Cost in iteration 0: 0.03985794705999574
# Final cost : 0.033348363167459386
# Compute control for a deterministic system
# Cost in iteration 0: 0.033348363167459386
# Final cost : 0.03245052758684484
# Compute control for a deterministic system
# Cost in iteration 0: 0.03245052758684484
# Final cost : 0.03212676238062693
# Compute control for a deterministic system
# Cost in iteration 0: 0.03212676238062693
# Cost in iteration 1000: 0.03194838147026548
# Final cost : 0.03194838147026548
# Compute control for a deterministic system
# Cost in iteration 0: 0.10703248625466774
# Final cost : 0.030465317173570143
# Compute control for a deterministic system
# Cost in iteration 0: 0.030465317173570143
# Final cost : 0.027725917201632453
# Compute control for a deterministic system
# Cost in iteration 0: 0.027725917201632453
# Final cost : 0.026763485288561883
# Compute control for a deterministic system
# Cost in iteration 0: 0.026763485288561883
# Final cost : 0.026462348648021796
# Compute control for a deterministic system
# Cost in iteration 0: 0.026462348648021796
# Cost in iteration 1000: 0.026316763555117546
# Final cost : 0.026316763555117546
# Compute control for a deterministic system
# Cost in iteration 0: 0.09286790203005355
# Final cost : 0.02389835660812116
# Compute control for a deterministic system
# Cost in iteration 0: 0.02389835660812116
# Final cost : 0.020871030449808335
# Compute control for a deterministic system
# Cost in iteration 0: 0.020871030449808335
# Final cost : 0.020824270371280887
# Compute control for a deterministic system
# Cost in iteration 0: 0.020824270371280887
# Converged in iteration 14 with cost 0.020823084640242368
# Final cost : 0.020823084640242368
# Compute control for a deterministic system
# Cost in iteration 0: 0.020823084640242368
# Converged in iteration 1 with cost 0.020823084640242368
# Final cost : 0.020823084640242368
# Compute control for a deterministic system
# Cost in iteration 0: 0.061797474140510816
# Final cost : 0.017685307284480128
# Compute control for a deterministic system
# Cost in iteration 0: 0.017685307284480128
# Final cost : 0.016030931066667635
# Compute control for a deterministic system
# Cost in iteration 0: 0.016030931066667635
# Final cost : 0.0155982856750584
# Compute control for a deterministic system
# Cost in iteration 0: 0.0155982856750584
# Final cost : 0.015488816596503944
# Compute control for a deterministic system
# Cost in iteration 0: 0.015488816596503944
# Converged in iteration 977 with cost 0.015455966893444043
# Final cost : 0.015455966893444043
# Compute control for a deterministic system
# Cost in iteration 0: 0.0472980936236221
# Final cost : 0.01257116915737241
# Compute control for a deterministic system
# Cost in iteration 0: 0.01257116915737241
# Final cost : 0.011416503317341705
# Compute control for a deterministic system
# Cost in iteration 0: 0.011416503317341705
# Final cost : 0.01140971864430745
# Compute control for a deterministic system
# Cost in iteration 0: 0.01140971864430745
# Converged in iteration 17 with cost 0.011409584995576184
# Final cost : 0.011409584995576184
# Compute control for a deterministic system
# Cost in iteration 0: 0.011409584995576184
# Converged in iteration 1 with cost 0.011409584995576184
# Final cost : 0.011409584995576184
# Compute control for a deterministic system
# Cost in iteration 0: 0.03223886752429132
# Final cost : 0.00971798866046519
# Compute control for a deterministic system
# Cost in iteration 0: 0.00971798866046519
# Final cost : 0.008837663104253917
# Compute control for a deterministic system
# Cost in iteration 0: 0.008837663104253917
# Final cost : 0.008656696352326528
# Compute control for a deterministic system
# Cost in iteration 0: 0.008656696352326528
# Final cost : 0.00862185243161688
# Compute control for a deterministic system
# Cost in iteration 0: 0.00862185243161688
# Converged in iteration 622 with cost 0.008614436603262063
# Final cost : 0.008614436603262063
# Compute control for a deterministic system
# Cost in iteration 0: 0.02017255278507315
# Final cost : 0.005973885442547229
# Compute control for a deterministic system
# Cost in iteration 0: 0.005973885442547229
# Converged in iteration 177 with cost 0.005564405391131931
# Final cost : 0.005564405391131931
# Compute control for a deterministic system
# Cost in iteration 0: 0.005564405391131931
# Converged in iteration 1 with cost 0.005564405391131931
# Final cost : 0.005564405391131931
# Compute control for a deterministic system
# Cost in iteration 0: 0.005564405391131931
# Converged in iteration 1 with cost 0.005564405391131931
# Final cost : 0.005564405391131931
# Compute control for a deterministic system
# Cost in iteration 0: 0.005564405391131931
# Converged in iteration 1 with cost 0.005564405391131931
# Final cost : 0.005564405391131931
# Compute control for a deterministic system
# Cost in iteration 0: 0.010371422631887676
# Final cost : 0.0033598686655061786
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033598686655061786
# Converged in iteration 144 with cost 0.0030825992021185065
# Final cost : 0.0030825992021185065
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030825992021185065
# Converged in iteration 1 with cost 0.0030825992021185065
# Final cost : 0.0030825992021185065
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030825992021185065
# Converged in iteration 1 with cost 0.0030825992021185065
# Final cost : 0.0030825992021185065
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030825992021185065
# Converged in iteration 1 with cost 0.0030825992021185065
# Final cost : 0.0030825992021185065
# Compute control for a deterministic system
# Cost in iteration 0: 0.004085625904000639
# Final cost : 0.001432424808566828
# Compute control for a deterministic system
# Cost in iteration 0: 0.001432424808566828
# Converged in iteration 138 with cost 0.0013097781962913859
# Final cost : 0.0013097781962913859
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013097781962913859
# Converged in iteration 2 with cost 0.0013097781962913817
# Final cost : 0.0013097781962913817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013097781962913817
# Converged in iteration 1 with cost 0.0013097781962913817
# Final cost : 0.0013097781962913817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013097781962913817
# Converged in iteration 1 with cost 0.0013097781962913817
# Final cost : 0.0013097781962913817
# Compute control for a deterministic system
# Cost in iteration 0: 0.001239154373557458
# Final cost : 0.00044178272253295566
# Compute control for a deterministic system
# Cost in iteration 0: 0.00044178272253295566
# Converged in iteration 154 with cost 0.0004108420830908914
# Final cost : 0.0004108420830908914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004108420830908914
# Converged in iteration 1 with cost 0.0004108420830908914
# Final cost : 0.0004108420830908914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004108420830908914
# Converged in iteration 1 with cost 0.0004108420830908914
# Final cost : 0.0004108420830908914
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004108420830908914
# Converged in iteration 1 with cost 0.0004108420830908914
# Final cost : 0.0004108420830908914

# %%
filehandler = open("results_min_w2.pickle","wb")
pickle.dump(results_min,filehandler)
filehandler.close()

# %%
filehandler = open("results_min_w2.pickle","rb")
results_min = pickle.load(filehandler)
filehandler.close()

# %%
n_points = 41
w_array = [0.125, .25, 0.5, 1., 2., 4., 8.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-125.png", "0-25.png", "0-5.png", "1.png", "2.png", "4.png", "8.png"]

results_peak = dict([
    ('w2', w_array),
    ('models', [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

for i_w in range(len(results_peak["w2"])):

    w2 = results_peak['w2'][i_w]

    for i_shift in range(n_points):
    
        period_shift = i_shift* 2.* np.pi / (n_points-1)
        index_shift = np.round(period * period_shift/ ( 2. * np.pi)/ dt).astype(int)
        target_shift = target_peak[:,:,index_shift:index_shift+np.round(1+duration/dt,1).astype(int)]

        wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=np.arange(0,1001,1001), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)
        results_peak["models"][i_w][i_shift] = wc_controlled

        wc_controlled.step = 1e-3
        wc_controlled.optimize(100)

        if i_shift in [0, n_points-1]:
            state = wc_controlled.get_xs()
            results_peak["control"][i_w][i_shift] = wc_controlled.control.copy()
            results_peak["state"][i_w][i_shift] = wc_controlled.get_xs().copy()
            results_peak["total_cost"][i_w][i_shift] = wc_controlled.cost_history.copy()

            wc_controlled.w_2 = 0.
            wc_controlled.simulate_forward()
            results_peak["precision_cost"][i_w][i_shift] = wc_controlled.compute_total_cost()
            results_peak["L2_cost_weighted"][i_w][i_shift] = ( results_peak["total_cost"][i_w][i_shift][-1] - results_peak["precision_cost"][i_w][i_shift]) 
            results_peak["L2_cost_unweighted"][i_w][i_shift] = results_peak["L2_cost_weighted"][i_w][i_shift] / w2
            wc_controlled.w_2 = w2
            continue

        wc_controlled.step = 1e-2
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e-1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e0
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(1000)
        
        results_peak["control"][i_w][i_shift] = wc_controlled.control.copy()
        results_peak["state"][i_w][i_shift] = wc_controlled.get_xs().copy()
        results_peak["total_cost"][i_w][i_shift] = wc_controlled.cost_history.copy()

        wc_controlled.w_2 = 0.
        wc_controlled.simulate_forward()
        results_peak["precision_cost"][i_w][i_shift] = wc_controlled.compute_total_cost()
        results_peak["L2_cost_weighted"][i_w][i_shift] = ( results_peak["total_cost"][i_w][i_shift][-1] - results_peak["precision_cost"][i_w][i_shift]) 
        results_peak["L2_cost_unweighted"][i_w][i_shift] = results_peak["L2_cost_weighted"][i_w][i_shift] / w2
        wc_controlled.w_2 = w2

    for i_shift in range(2, n_points-1):

        period_shift = i_shift* 2.* np.pi / (n_points-1)
        index_shift = np.round(period * period_shift/ ( 2. * np.pi)/ dt).astype(int)
        target_shift = target_peak[:,:,index_shift:index_shift+np.round(1+duration/dt,1).astype(int)]

        wc_controlled = results_peak["models"][i_w][i_shift]

        factor = 1.1
        if i_shift > n_points/2:
            factor = 1.
        
        wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
        wc_controlled.update_input()

        wc_controlled.step = 1e-3
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e-2
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e-1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e0
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(1000)

        if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
            print("-----------------------------------------------")
            print("0 found better solution")

            results_peak["control"][i_w][i_shift] = wc_controlled.control.copy()
            results_peak["state"][i_w][i_shift] = wc_controlled.get_xs().copy()
            results_peak["total_cost"][i_w][i_shift] = wc_controlled.cost_history.copy()

            wc_controlled.w_2 = 0.
            wc_controlled.simulate_forward()
            results_peak["precision_cost"][i_w][i_shift] = wc_controlled.compute_total_cost()
            results_peak["L2_cost_weighted"][i_w][i_shift] = ( results_peak["total_cost"][i_w][i_shift][-1] - results_peak["precision_cost"][i_w][i_shift]) 
            results_peak["L2_cost_unweighted"][i_w][i_shift] = results_peak["L2_cost_weighted"][i_w][i_shift] / w2
            wc_controlled.w_2 = w2

    for i_shift in range(n_points-3, 0, -1):

        if i_shift not in []:
            continue

        period_shift = i_shift* 2.* np.pi / (n_points-1)
        index_shift = np.round(period * period_shift/ ( 2. * np.pi)/ dt).astype(int)
        target_shift = target_peak[:,:,index_shift:index_shift+np.round(1+duration/dt,1).astype(int)]

        wc_controlled = results_peak["models"][i_w][i_shift]

        factor = 1.1
        if i_shift < n_points/2:
            factor = 1.

        wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
        wc_controlled.update_input()
        wc_controlled.simulate_forward()

        wc_controlled.step = 1e-3
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e-2
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e-1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e0
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(200)

        wc_controlled.step = 1e1
        wc_controlled.zero_step_encountered = False
        wc_controlled.optimize(1000)

        if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift][-1]:
            print("-----------------------------------------------")
            print("1 found better solution")

            results_peak["control"][i_w][i_shift] = wc_controlled.control.copy()
            results_peak["state"][i_w][i_shift] = wc_controlled.get_xs().copy()
            results_peak["total_cost"][i_w][i_shift] = wc_controlled.cost_history.copy()

            wc_controlled.w_2 = 0.
            wc_controlled.simulate_forward()
            results_peak["precision_cost"][i_w][i_shift] = wc_controlled.compute_total_cost()
            results_peak["L2_cost_weighted"][i_w][i_shift] = ( results_peak["total_cost"][i_w][i_shift][-1] - results_peak["precision_cost"][i_w][i_shift]) 
            results_peak["L2_cost_unweighted"][i_w][i_shift] = results_peak["L2_cost_weighted"][i_w][i_shift] / w2
            wc_controlled.w_2 = w2
            
    #plot(results_peak["control"][i_w], results_peak["filename"][i_w])
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.08629225867191966
# Final cost : 0.01088014184998174
# Compute control for a deterministic system
# Cost in iteration 0: 0.01088014184998174
# Final cost : 0.00019426687827058474
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019426687827058474
# Final cost : 0.00018213443853762752
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018213443853762752
# Converged in iteration 4 with cost 0.00018213206261067882
# Final cost : 0.00018213206261067882
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018213206261067882
# Converged in iteration 1 with cost 0.00018213206261067882
# Final cost : 0.00018213206261067882
# Compute control for a deterministic system
# Cost in iteration 0: 0.2722600487971873
# Final cost : 0.033052468013753916
# Compute control for a deterministic system
# Cost in iteration 0: 0.033052468013753916
# Final cost : 0.0006355711956590306
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006355711956590306
# Final cost : 0.00052614492317593
# Compute control for a deterministic system
# Cost in iteration 0: 0.00052614492317593
# Converged in iteration 160 with cost 0.0005250919879894148
# Final cost : 0.0005250919879894148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005250919879894148
# Converged in iteration 1 with cost 0.0005250919879894148
# Final cost : 0.0005250919879894148
# Compute control for a deterministic system
# Cost in iteration 0: 0.6262393329611331
# Final cost : 0.07237575758426916
# Compute control for a deterministic system
# Cost in iteration 0: 0.07237575758426916
# Final cost : 0.0016860324375789465
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016860324375789465
# Final cost : 0.0011261884482005784
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011261884482005784
# Final cost : 0.00111353921107214
# Compute control for a deterministic system
# Cost in iteration 0: 0.00111353921107214
# Converged in iteration 683 with cost 0.0011115450337657602
# Final cost : 0.0011115450337657602
# Compute control for a deterministic system
# Cost in iteration 0: 1.0780229641405126
# Final cost : 0.12325936573028541
# Compute control for a deterministic system
# Cost in iteration 0: 0.12325936573028541
# Final cost : 0.0034748608168191737
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034748608168191737
# Final cost : 0.0018892062339158201
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018892062339158201
# Final cost : 0.001843961162957615
# Compute control for a deterministic system
# Cost in iteration 0: 0.001843961162957615
# Converged in iteration 655 with cost 0.001835043141293408
# Final cost : 0.001835043141293408
# Compute control for a deterministic system
# Cost in iteration 0: 1.5853379256454698
# Final cost : 0.19280803495144688
# Compute control for a deterministic system
# Cost in iteration 0: 0.19280803495144688
# Final cost : 0.005999516842457819
# Compute control for a deterministic system
# Cost in iteration 0: 0.005999516842457819
# Final cost : 0.002784170314726039
# Compute control for a deterministic system
# Cost in iteration 0: 0.002784170314726039
# Final cost : 0.002675611477956813
# Compute control for a deterministic system
# Cost in iteration 0: 0.002675611477956813
# Converged in iteration 732 with cost 0.00265140149301534
# Final cost : 0.00265140149301534
# Compute control for a deterministic system
# Cost in iteration 0: 2.005541804376424
# Final cost : 0.2722335230498497
# Compute control for a deterministic system
# Cost in iteration 0: 0.2722335230498497
# Final cost : 0.008563641140866472
# Compute control for a deterministic system
# Cost in iteration 0: 0.008563641140866472
# Final cost : 0.0035777701989444717
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035777701989444717
# Final cost : 0.0033878580669990904
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033878580669990904
# Converged in iteration 684 with cost 0.0033419264499579327
# Final cost : 0.0033419264499579327
# Compute control for a deterministic system
# Cost in iteration 0: 2.52386798479567
# Final cost : 0.42130936698034105
# Compute control for a deterministic system
# Cost in iteration 0: 0.42130936698034105
# Final cost : 0.012489968197260006
# Compute control for a deterministic system
# Cost in iteration 0: 0.012489968197260006
# Final cost : 0.004660075464172273
# Compute control for a deterministic system
# Cost in iteration 0: 0.004660075464172273
# Converged in iteration 122 with cost 0.004373353885579741
# Final cost : 0.004373353885579741
# Compute control for a deterministic system
# Cost in iteration 0: 0.004373353885579741
# Converged in iteration 1 with cost 0.004373353885579741
# Final cost : 0.004373353885579741
# Compute control for a deterministic system
# Cost in iteration 0: 3.0158261757743783
# Final cost : 0.6616616133287618
# Compute control for a deterministic system
# Cost in iteration 0: 0.6616616133287618
# Final cost : 0.017294376776617756
# Compute control for a deterministic system
# Cost in iteration 0: 0.017294376776617756
# Final cost : 0.005866200307726993
# Compute control for a deterministic system
# Cost in iteration 0: 0.005866200307726993
# Converged in iteration 8 with cost 0.005758066010773334
# Final cost : 0.005758066010773334
# Compute control for a deterministic system
# Cost in iteration 0: 0.005758066010773334
# Converged in iteration 1 with cost 0.005758066010773334
# Final cost : 0.005758066010773334
# Compute control for a deterministic system
# Cost in iteration 0: 3.469542705395145
# Final cost : 1.0664503540446522
# Compute control for a deterministic system
# Cost in iteration 0: 1.0664503540446522
# Final cost : 0.02312218313629142
# Compute control for a deterministic system
# Cost in iteration 0: 0.02312218313629142
# Final cost : 0.007266285329852967
# Compute control for a deterministic system
# Cost in iteration 0: 0.007266285329852967
# Converged in iteration 16 with cost 0.0071122420565108545
# Final cost : 0.0071122420565108545
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071122420565108545
# Converged in iteration 1 with cost 0.0071122420565108545
# Final cost : 0.0071122420565108545
# Compute control for a deterministic system
# Cost in iteration 0: 3.8009706124650458
# Final cost : 1.6144489597560032
# Compute control for a deterministic system
# Cost in iteration 0: 1.6144489597560032
# Final cost : 0.028729826030667538
# Compute control for a deterministic system
# Cost in iteration 0: 0.028729826030667538
# Final cost : 0.008207940291508939
# Compute control for a deterministic system
# Cost in iteration 0: 0.008207940291508939
# Converged in iteration 12 with cost 0.008024864620891279
# Final cost : 0.008024864620891279
# Compute control for a deterministic system
# Cost in iteration 0: 0.008024864620891279
# Converged in iteration 1 with cost 0.008024864620891279
# Final cost : 0.008024864620891279
# Compute control for a deterministic system
# Cost in iteration 0: 4.174052821861433
# Final cost : 2.8635720346125386
# Compute control for a deterministic system
# Cost in iteration 0: 2.8635720346125386
# Final cost : 0.03776782723692279
# Compute control for a deterministic system
# Cost in iteration 0: 0.03776782723692279
# Final cost : 0.01043281119067606
# Compute control for a deterministic system
# Cost in iteration 0: 0.01043281119067606
# Converged in iteration 103 with cost 0.009110811491743698
# Final cost : 0.009110811491743698
# Compute control for a deterministic system
# Cost in iteration 0: 0.009110811491743698
# Converged in iteration 1 with cost 0.009110811491743698
# Final cost : 0.009110811491743698
# Compute control for a deterministic system
# Cost in iteration 0: 4.501725299316877
# Final cost : 3.8911664319583137
# Compute control for a deterministic system
# Cost in iteration 0: 3.8911664319583137
# Final cost : 0.045888049372622856
# Compute control for a deterministic system
# Cost in iteration 0: 0.045888049372622856
# Final cost : 0.01649614008618933
# Compute control for a deterministic system
# Cost in iteration 0: 0.01649614008618933
# Converged in iteration 107 with cost 0.010612772929787944
# Final cost : 0.010612772929787944
# Compute control for a deterministic system
# Cost in iteration 0: 0.010612772929787944
# Converged in iteration 1 with cost 0.010612772929787944
# Final cost : 0.010612772929787944
# Compute control for a deterministic system
# Cost in iteration 0: 4.732613877129772
# Final cost : 4.278575336525562
# Compute control for a deterministic system
# Cost in iteration 0: 4.278575336525562
# Converged in iteration 49 with cost 0.3773848634644002
# Final cost : 0.3773848634644002
# Compute control for a deterministic system
# Cost in iteration 0: 0.3773848634644002
# Converged in iteration 1 with cost 0.3773848634644002
# Final cost : 0.3773848634644002
# Compute control for a deterministic system
# Cost in iteration 0: 0.3773848634644002
# Converged in iteration 1 with cost 0.3773848634644002
# Final cost : 0.3773848634644002
# Compute control for a deterministic system
# Cost in iteration 0: 0.3773848634644002
# Converged in iteration 1 with cost 0.3773848634644002
# Final cost : 0.3773848634644002
# Compute control for a deterministic system
# Cost in iteration 0: 4.985248284313345
# Final cost : 4.68780442839288
# Compute control for a deterministic system
# Cost in iteration 0: 4.68780442839288
# Converged in iteration 58 with cost 0.8660220511807374
# Final cost : 0.8660220511807374
# Compute control for a deterministic system
# Cost in iteration 0: 0.8660220511807374
# Converged in iteration 1 with cost 0.8660220511807374
# Final cost : 0.8660220511807374
# Compute control for a deterministic system
# Cost in iteration 0: 0.8660220511807374
# Converged in iteration 1 with cost 0.8660220511807374
# Final cost : 0.8660220511807374
# Compute control for a deterministic system
# Cost in iteration 0: 0.8660220511807374
# Converged in iteration 1 with cost 0.8660220511807374
# Final cost : 0.8660220511807374
# Compute control for a deterministic system
# Cost in iteration 0: 5.20187641649966
# Final cost : 5.021182482071703
# Compute control for a deterministic system
# Cost in iteration 0: 5.021182482071703
# Converged in iteration 90 with cost 0.9222191552910944
# Final cost : 0.9222191552910944
# Compute control for a deterministic system
# Cost in iteration 0: 0.9222191552910944
# Converged in iteration 1 with cost 0.9222191552910944
# Final cost : 0.9222191552910944
# Compute control for a deterministic system
# Cost in iteration 0: 0.9222191552910944
# Converged in iteration 1 with cost 0.9222191552910944
# Final cost : 0.9222191552910944
# Compute control for a deterministic system
# Cost in iteration 0: 0.9222191552910944
# Converged in iteration 1 with cost 0.9222191552910944
# Final cost : 0.9222191552910944
# Compute control for a deterministic system
# Cost in iteration 0: 5.385439464475896
# Final cost : 5.286283209702472
# Compute control for a deterministic system
# Cost in iteration 0: 5.286283209702472
# Converged in iteration 42 with cost 5.097495151150473
# Final cost : 5.097495151150473
# Compute control for a deterministic system
# Cost in iteration 0: 5.097495151150473
# Final cost : 0.04646905954189718
# Compute control for a deterministic system
# Cost in iteration 0: 0.04646905954189718
# Final cost : 0.04547931862047914
# Compute control for a deterministic system
# Cost in iteration 0: 0.04547931862047914
# Converged in iteration 970 with cost 0.039666043481196234
# Final cost : 0.039666043481196234
# Compute control for a deterministic system
# Cost in iteration 0: 5.508692895542554
# Final cost : 5.452799216879133
# Compute control for a deterministic system
# Cost in iteration 0: 5.452799216879133
# Converged in iteration 16 with cost 5.418245989142264
# Final cost : 5.418245989142264
# Compute control for a deterministic system
# Cost in iteration 0: 5.418245989142264
# Final cost : 0.0446826730676514
# Compute control for a deterministic system
# Cost in iteration 0: 0.0446826730676514
# Final cost : 0.04399610265468531
# Compute control for a deterministic system
# Cost in iteration 0: 0.04399610265468531
# Converged in iteration 294 with cost 0.043918126551888585
# Final cost : 0.043918126551888585
# Compute control for a deterministic system
# Cost in iteration 0: 5.631217389751276
# Final cost : 5.605568041842663
# Compute control for a deterministic system
# Cost in iteration 0: 5.605568041842663
# Converged in iteration 29 with cost 5.60052883213559
# Final cost : 5.60052883213559
# Compute control for a deterministic system
# Cost in iteration 0: 5.60052883213559
# Final cost : 0.04217148211820272
# Compute control for a deterministic system
# Cost in iteration 0: 0.04217148211820272
# Final cost : 0.04157664859150377
# Compute control for a deterministic system
# Cost in iteration 0: 0.04157664859150377
# Final cost : 0.04146405717270628
# Compute control for a deterministic system
# Cost in iteration 0: 5.714996904980548
# Final cost : 5.696125887039454
# Compute control for a deterministic system
# Cost in iteration 0: 5.696125887039454
# Final cost : 0.08083953687856711
# Compute control for a deterministic system
# Cost in iteration 0: 0.08083953687856711
# Final cost : 0.03925279191927603
# Compute control for a deterministic system
# Cost in iteration 0: 0.03925279191927603
# Final cost : 0.03891641081644247
# Compute control for a deterministic system
# Cost in iteration 0: 0.03891641081644247
# Final cost : 0.038707406239823175
# Compute control for a deterministic system
# Cost in iteration 0: 5.75183764693526
# Final cost : 4.4866652600156876
# Compute control for a deterministic system
# Cost in iteration 0: 4.4866652600156876
# Final cost : 0.07425706563819083
# Compute control for a deterministic system
# Cost in iteration 0: 0.07425706563819083
# Final cost : 0.03711825423943649
# Compute control for a deterministic system
# Cost in iteration 0: 0.03711825423943649
# Final cost : 0.036754806842480586
# Compute control for a deterministic system
# Cost in iteration 0: 0.036754806842480586
# Final cost : 0.036438401112719385
# Compute control for a deterministic system
# Cost in iteration 0: 5.758661450964794
# Final cost : 4.13909890037853
# Compute control for a deterministic system
# Cost in iteration 0: 4.13909890037853
# Final cost : 0.0679598700426866
# Compute control for a deterministic system
# Cost in iteration 0: 0.0679598700426866
# Final cost : 0.034338905807612875
# Compute control for a deterministic system
# Cost in iteration 0: 0.034338905807612875
# Final cost : 0.03395988810086708
# Compute control for a deterministic system
# Cost in iteration 0: 0.03395988810086708
# Final cost : 0.03357360903801079
# Compute control for a deterministic system
# Cost in iteration 0: 5.721467216529369
# Final cost : 3.756352424555025
# Compute control for a deterministic system
# Cost in iteration 0: 3.756352424555025
# Final cost : 0.06186976141911871
# Compute control for a deterministic system
# Cost in iteration 0: 0.06186976141911871
# Final cost : 0.03154035046004171
# Compute control for a deterministic system
# Cost in iteration 0: 0.03154035046004171
# Final cost : 0.0311578079136547
# Compute control for a deterministic system
# Cost in iteration 0: 0.0311578079136547
# Final cost : 0.030719879273666373
# Compute control for a deterministic system
# Cost in iteration 0: 5.640284642207092
# Final cost : 3.350736981030747
# Compute control for a deterministic system
# Cost in iteration 0: 3.350736981030747
# Final cost : 0.055981044865039534
# Compute control for a deterministic system
# Cost in iteration 0: 0.055981044865039534
# Final cost : 0.02875083871130141
# Compute control for a deterministic system
# Cost in iteration 0: 0.02875083871130141
# Final cost : 0.028363645803284654
# Compute control for a deterministic system
# Cost in iteration 0: 0.028363645803284654
# Final cost : 0.027904922213810877
# Compute control for a deterministic system
# Cost in iteration 0: 5.5436112110087805
# Final cost : 3.018807351248471
# Compute control for a deterministic system
# Cost in iteration 0: 3.018807351248471
# Final cost : 0.05141289495527435
# Compute control for a deterministic system
# Cost in iteration 0: 0.05141289495527435
# Final cost : 0.026549297456938105
# Compute control for a deterministic system
# Cost in iteration 0: 0.026549297456938105
# Final cost : 0.026163230064543765
# Compute control for a deterministic system
# Cost in iteration 0: 0.026163230064543765
# Final cost : 0.025693543589905925
# Compute control for a deterministic system
# Cost in iteration 0: 5.382717971947239
# Final cost : 2.605994482102257
# Compute control for a deterministic system
# Cost in iteration 0: 2.605994482102257
# Final cost : 0.0458829047204163
# Compute control for a deterministic system
# Cost in iteration 0: 0.0458829047204163
# Final cost : 0.0238434786714631
# Compute control for a deterministic system
# Cost in iteration 0: 0.0238434786714631
# Final cost : 0.023457736697949934
# Compute control for a deterministic system
# Cost in iteration 0: 0.023457736697949934
# Final cost : 0.022997627533450585
# Compute control for a deterministic system
# Cost in iteration 0: 5.176492281614859
# Final cost : 2.2072522320453847
# Compute control for a deterministic system
# Cost in iteration 0: 2.2072522320453847
# Final cost : 0.04055921049325363
# Compute control for a deterministic system
# Cost in iteration 0: 0.04055921049325363
# Final cost : 0.021218045144205118
# Compute control for a deterministic system
# Cost in iteration 0: 0.021218045144205118
# Final cost : 0.02083344330267114
# Compute control for a deterministic system
# Cost in iteration 0: 0.02083344330267114
# Final cost : 0.020393175302274986
# Compute control for a deterministic system
# Cost in iteration 0: 4.923706158516537
# Final cost : 1.8331981766840242
# Compute control for a deterministic system
# Cost in iteration 0: 1.8331981766840242
# Final cost : 0.03545224833126924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03545224833126924
# Final cost : 0.018659314270676925
# Compute control for a deterministic system
# Cost in iteration 0: 0.018659314270676925
# Final cost : 0.018295614509418672
# Compute control for a deterministic system
# Cost in iteration 0: 0.018295614509418672
# Final cost : 0.0178915436242671
# Compute control for a deterministic system
# Cost in iteration 0: 4.6870149124579035
# Final cost : 1.5571660359211594
# Compute control for a deterministic system
# Cost in iteration 0: 1.5571660359211594
# Final cost : 0.0315321525227116
# Compute control for a deterministic system
# Cost in iteration 0: 0.0315321525227116
# Final cost : 0.016692155169815974
# Compute control for a deterministic system
# Cost in iteration 0: 0.016692155169815974
# Final cost : 0.016340830742476227
# Compute control for a deterministic system
# Cost in iteration 0: 0.016340830742476227
# Final cost : 0.015976361831456638
# Compute control for a deterministic system
# Cost in iteration 0: 4.346995635459488
# Final cost : 1.2456714875035604
# Compute control for a deterministic system
# Cost in iteration 0: 1.2456714875035604
# Final cost : 0.026853346074125158
# Compute control for a deterministic system
# Cost in iteration 0: 0.026853346074125158
# Final cost : 0.014354509634888718
# Compute control for a deterministic system
# Cost in iteration 0: 0.014354509634888718
# Final cost : 0.014011461856026603
# Compute control for a deterministic system
# Cost in iteration 0: 0.014011461856026603
# Final cost : 0.013697807633243285
# Compute control for a deterministic system
# Cost in iteration 0: 3.9572463933025612
# Final cost : 0.974138868821905
# Compute control for a deterministic system
# Cost in iteration 0: 0.974138868821905
# Final cost : 0.022439167826896117
# Compute control for a deterministic system
# Cost in iteration 0: 0.022439167826896117
# Final cost : 0.012116050248191897
# Compute control for a deterministic system
# Cost in iteration 0: 0.012116050248191897
# Final cost : 0.01180823043659212
# Compute control for a deterministic system
# Cost in iteration 0: 0.01180823043659212
# Final cost : 0.011560120361178558
# Compute control for a deterministic system
# Cost in iteration 0: 3.6099525000077266
# Final cost : 0.786236043293223
# Compute control for a deterministic system
# Cost in iteration 0: 0.786236043293223
# Final cost : 0.0191137620055588
# Compute control for a deterministic system
# Cost in iteration 0: 0.0191137620055588
# Final cost : 0.01037751759551424
# Compute control for a deterministic system
# Cost in iteration 0: 0.01037751759551424
# Final cost : 0.010143742684079107
# Compute control for a deterministic system
# Cost in iteration 0: 0.010143742684079107
# Final cost : 0.009955389799406203
# Compute control for a deterministic system
# Cost in iteration 0: 3.133792636948824
# Final cost : 0.5871783411416092
# Compute control for a deterministic system
# Cost in iteration 0: 0.5871783411416092
# Final cost : 0.015237262302536338
# Compute control for a deterministic system
# Cost in iteration 0: 0.015237262302536338
# Final cost : 0.008424567825538803
# Compute control for a deterministic system
# Cost in iteration 0: 0.008424567825538803
# Final cost : 0.008228728099045226
# Compute control for a deterministic system
# Cost in iteration 0: 0.008228728099045226
# Final cost : 0.008092339279830517
# Compute control for a deterministic system
# Cost in iteration 0: 2.617217316522213
# Final cost : 0.4256023562735948
# Compute control for a deterministic system
# Cost in iteration 0: 0.4256023562735948
# Final cost : 0.01170326031550285
# Compute control for a deterministic system
# Cost in iteration 0: 0.01170326031550285
# Final cost : 0.006607597384827054
# Compute control for a deterministic system
# Cost in iteration 0: 0.006607597384827054
# Final cost : 0.006472934029439075
# Compute control for a deterministic system
# Cost in iteration 0: 0.006472934029439075
# Final cost : 0.006390414542615319
# Compute control for a deterministic system
# Cost in iteration 0: 2.0732814836660345
# Final cost : 0.2977587880170346
# Compute control for a deterministic system
# Cost in iteration 0: 0.2977587880170346
# Final cost : 0.008551345444036261
# Compute control for a deterministic system
# Cost in iteration 0: 0.008551345444036261
# Final cost : 0.004992086769750817
# Compute control for a deterministic system
# Cost in iteration 0: 0.004992086769750817
# Final cost : 0.004901782056134042
# Compute control for a deterministic system
# Cost in iteration 0: 0.004901782056134042
# Final cost : 0.0048554408211595994
# Compute control for a deterministic system
# Cost in iteration 0: 1.6331104749464214
# Final cost : 0.21654698389527338
# Compute control for a deterministic system
# Cost in iteration 0: 0.21654698389527338
# Final cost : 0.006333429916138936
# Compute control for a deterministic system
# Cost in iteration 0: 0.006333429916138936
# Final cost : 0.003833116641850022
# Compute control for a deterministic system
# Cost in iteration 0: 0.003833116641850022
# Final cost : 0.003772464445423611
# Compute control for a deterministic system
# Cost in iteration 0: 0.003772464445423611
# Final cost : 0.0037499812543772422
# Compute control for a deterministic system
# Cost in iteration 0: 1.1036849446419539
# Final cost : 0.13685772430729698
# Compute control for a deterministic system
# Cost in iteration 0: 0.13685772430729698
# Final cost : 0.00397545287596811
# Compute control for a deterministic system
# Cost in iteration 0: 0.00397545287596811
# Final cost : 0.0025719862596612895
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025719862596612895
# Final cost : 0.002534212621543968
# Compute control for a deterministic system
# Cost in iteration 0: 0.002534212621543968
# Final cost : 0.002524905685844645
# Compute control for a deterministic system
# Cost in iteration 0: 0.635732566993363
# Final cost : 0.0768562938040689
# Compute control for a deterministic system
# Cost in iteration 0: 0.0768562938040689
# Final cost : 0.002121244499073884
# Compute control for a deterministic system
# Cost in iteration 0: 0.002121244499073884
# Final cost : 0.001500929050799312
# Compute control for a deterministic system
# Cost in iteration 0: 0.001500929050799312
# Final cost : 0.0014867027236004436
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014867027236004436
# Final cost : 0.0014845744101935126
# Compute control for a deterministic system
# Cost in iteration 0: 0.2733249966026175
# Final cost : 0.03347993547616949
# Compute control for a deterministic system
# Cost in iteration 0: 0.03347993547616949
# Final cost : 0.000830038454186239
# Compute control for a deterministic system
# Cost in iteration 0: 0.000830038454186239
# Final cost : 0.0006656228110251642
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006656228110251642
# Final cost : 0.0006611528661975603
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006611528661975603
# Converged in iteration 880 with cost 0.0006607532373772876
# Final cost : 0.0006607532373772876
# Compute control for a deterministic system
# Cost in iteration 0: 0.08545603811993757
# Final cost : 0.010736601058479445
# Compute control for a deterministic system
# Cost in iteration 0: 0.010736601058479445
# Final cost : 0.0002347927586431025
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002347927586431025
# Final cost : 0.000210773291677262
# Compute control for a deterministic system
# Cost in iteration 0: 0.000210773291677262
# Final cost : 0.0002097456570844989
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002097456570844989
# Converged in iteration 530 with cost 0.00020966058653684635
# Final cost : 0.00020966058653684635
# Compute control for a deterministic system
# Cost in iteration 0: 6.219977717425858e-06
# Final cost : 7.976465079148514e-07
# Compute control for a deterministic system
# Cost in iteration 0: 0.04340158925760882
# Final cost : 0.003627168097487847
# Compute control for a deterministic system
# Cost in iteration 0: 0.003627168097487847
# Final cost : 0.0005494282547708311
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005494282547708311
# Final cost : 0.0005253930146998442
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005253930146998442
# Converged in iteration 107 with cost 0.0005252401158845708
# Final cost : 0.0005252401158845708
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005252401158845708
# Converged in iteration 1 with cost 0.0005252401158845708
# Final cost : 0.0005252401158845708
# Compute control for a deterministic system
# Cost in iteration 0: 0.060001550357561044
# Final cost : 0.005747530515410217
# Compute control for a deterministic system
# Cost in iteration 0: 0.005747530515410217
# Final cost : 0.0011757459695670347
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011757459695670347
# Final cost : 0.0011156040423115467
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011156040423115467
# Final cost : 0.0011124274664823532
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011124274664823532
# Converged in iteration 497 with cost 0.0011115530934823984
# Final cost : 0.0011115530934823984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0474541216111724
# Final cost : 0.006017913428560522
# Compute control for a deterministic system
# Cost in iteration 0: 0.006017913428560522
# Final cost : 0.00193291167616603
# Compute control for a deterministic system
# Cost in iteration 0: 0.00193291167616603
# Converged in iteration 116 with cost 0.0018608726509796252
# Final cost : 0.0018608726509796252
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018608726509796252
# Converged in iteration 1 with cost 0.0018608726509796252
# Final cost : 0.0018608726509796252
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018608726509796252
# Converged in iteration 1 with cost 0.0018608726509796252
# Final cost : 0.0018608726509796252
# Compute control for a deterministic system
# Cost in iteration 0: 0.0366056933970602
# Final cost : 0.006466291730514349
# Compute control for a deterministic system
# Cost in iteration 0: 0.006466291730514349
# Converged in iteration 138 with cost 0.002805460863605577
# Final cost : 0.002805460863605577
# Compute control for a deterministic system
# Cost in iteration 0: 0.002805460863605577
# Converged in iteration 1 with cost 0.002805460863605577
# Final cost : 0.002805460863605577
# Compute control for a deterministic system
# Cost in iteration 0: 0.002805460863605577
# Converged in iteration 1 with cost 0.002805460863605577
# Final cost : 0.002805460863605577
# Compute control for a deterministic system
# Cost in iteration 0: 0.002805460863605577
# Converged in iteration 1 with cost 0.002805460863605577
# Final cost : 0.002805460863605577
# Compute control for a deterministic system
# Cost in iteration 0: 0.012660371032482203
# Final cost : 0.004938520153180928
# Compute control for a deterministic system
# Cost in iteration 0: 0.004938520153180928
# Converged in iteration 124 with cost 0.003428598329231547
# Final cost : 0.003428598329231547
# Compute control for a deterministic system
# Cost in iteration 0: 0.003428598329231547
# Converged in iteration 1 with cost 0.003428598329231547
# Final cost : 0.003428598329231547
# Compute control for a deterministic system
# Cost in iteration 0: 0.003428598329231547
# Converged in iteration 1 with cost 0.003428598329231547
# Final cost : 0.003428598329231547
# Compute control for a deterministic system
# Cost in iteration 0: 0.003428598329231547
# Converged in iteration 1 with cost 0.003428598329231547
# Final cost : 0.003428598329231547
# Compute control for a deterministic system
# Cost in iteration 0: 0.021313947117821412
# Converged in iteration 100 with cost 0.008090086046806576
# Final cost : 0.008090086046806576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008090086046806576
# Converged in iteration 1 with cost 0.008090086046806576
# Final cost : 0.008090086046806576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008090086046806576
# Converged in iteration 1 with cost 0.008090086046806576
# Final cost : 0.008090086046806576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008090086046806576
# Converged in iteration 1 with cost 0.008090086046806576
# Final cost : 0.008090086046806576
# Compute control for a deterministic system
# Cost in iteration 0: 0.008090086046806576
# Converged in iteration 1 with cost 0.008090086046806576
# Final cost : 0.008090086046806576
# Compute control for a deterministic system
# Cost in iteration 0: 0.019484655056928323
# Converged in iteration 69 with cost 0.008592197525144236
# Final cost : 0.008592197525144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.008592197525144236
# Converged in iteration 1 with cost 0.008592197525144236
# Final cost : 0.008592197525144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.008592197525144236
# Converged in iteration 1 with cost 0.008592197525144236
# Final cost : 0.008592197525144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.008592197525144236
# Converged in iteration 1 with cost 0.008592197525144236
# Final cost : 0.008592197525144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.008592197525144236
# Converged in iteration 1 with cost 0.008592197525144236
# Final cost : 0.008592197525144236
# Compute control for a deterministic system
# Cost in iteration 0: 0.025398564854216404
# Converged in iteration 56 with cost 0.010470903546522803
# Final cost : 0.010470903546522803
# Compute control for a deterministic system
# Cost in iteration 0: 0.010470903546522803
# Converged in iteration 1 with cost 0.010470903546522803
# Final cost : 0.010470903546522803
# Compute control for a deterministic system
# Cost in iteration 0: 0.010470903546522803
# Converged in iteration 1 with cost 0.010470903546522803
# Final cost : 0.010470903546522803
# Compute control for a deterministic system
# Cost in iteration 0: 0.010470903546522803
# Converged in iteration 1 with cost 0.010470903546522803
# Final cost : 0.010470903546522803
# Compute control for a deterministic system
# Cost in iteration 0: 0.010470903546522803
# Converged in iteration 1 with cost 0.010470903546522803
# Final cost : 0.010470903546522803
# Compute control for a deterministic system
# Cost in iteration 0: 0.014550466436887718
# Converged in iteration 56 with cost 0.009039182352724526
# Final cost : 0.009039182352724526
# Compute control for a deterministic system
# Cost in iteration 0: 0.009039182352724526
# Converged in iteration 1 with cost 0.009039182352724526
# Final cost : 0.009039182352724526
# Compute control for a deterministic system
# Cost in iteration 0: 0.009039182352724526
# Converged in iteration 1 with cost 0.009039182352724526
# Final cost : 0.009039182352724526
# Compute control for a deterministic system
# Cost in iteration 0: 0.009039182352724526
# Converged in iteration 1 with cost 0.009039182352724526
# Final cost : 0.009039182352724526
# Compute control for a deterministic system
# Cost in iteration 0: 0.009039182352724526
# Converged in iteration 1 with cost 0.009039182352724526
# Final cost : 0.009039182352724526
# Compute control for a deterministic system
# Cost in iteration 0: 0.024965981417673103
# Converged in iteration 49 with cost 0.010958223940201389
# Final cost : 0.010958223940201389
# Compute control for a deterministic system
# Cost in iteration 0: 0.010958223940201389
# Converged in iteration 1 with cost 0.010958223940201389
# Final cost : 0.010958223940201389
# Compute control for a deterministic system
# Cost in iteration 0: 0.010958223940201389
# Converged in iteration 1 with cost 0.010958223940201389
# Final cost : 0.010958223940201389
# Compute control for a deterministic system
# Cost in iteration 0: 0.010958223940201389
# Converged in iteration 1 with cost 0.010958223940201389
# Final cost : 0.010958223940201389
# Compute control for a deterministic system
# Cost in iteration 0: 0.010958223940201389
# Converged in iteration 1 with cost 0.010958223940201389
# Final cost : 0.010958223940201389
# Compute control for a deterministic system
# Cost in iteration 0: 0.017979888510474336
# Converged in iteration 53 with cost 0.010882486074637227
# Final cost : 0.010882486074637227
# Compute control for a deterministic system
# Cost in iteration 0: 0.010882486074637227
# Converged in iteration 1 with cost 0.010882486074637227
# Final cost : 0.010882486074637227
# Compute control for a deterministic system
# Cost in iteration 0: 0.010882486074637227
# Converged in iteration 1 with cost 0.010882486074637227
# Final cost : 0.010882486074637227
# Compute control for a deterministic system
# Cost in iteration 0: 0.010882486074637227
# Converged in iteration 1 with cost 0.010882486074637227
# Final cost : 0.010882486074637227
# Compute control for a deterministic system
# Cost in iteration 0: 0.010882486074637227
# Converged in iteration 1 with cost 0.010882486074637227
# Final cost : 0.010882486074637227
# Compute control for a deterministic system
# Cost in iteration 0: 0.012012287604652054
# Converged in iteration 5 with cost 0.01195916710697486
# Final cost : 0.01195916710697486
# Compute control for a deterministic system
# Cost in iteration 0: 0.01195916710697486
# Converged in iteration 1 with cost 0.01195916710697486
# Final cost : 0.01195916710697486
# Compute control for a deterministic system
# Cost in iteration 0: 0.01195916710697486
# Converged in iteration 1 with cost 0.01195916710697486
# Final cost : 0.01195916710697486
# Compute control for a deterministic system
# Cost in iteration 0: 0.01195916710697486
# Converged in iteration 1 with cost 0.01195916710697486
# Final cost : 0.01195916710697486
# Compute control for a deterministic system
# Cost in iteration 0: 0.01195916710697486
# Converged in iteration 1 with cost 0.01195916710697486
# Final cost : 0.01195916710697486
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.01606977694326833
# Converged in iteration 6 with cost 0.014820241694949478
# Final cost : 0.014820241694949478
# Compute control for a deterministic system
# Cost in iteration 0: 0.014820241694949478
# Converged in iteration 1 with cost 0.014820241694949478
# Final cost : 0.014820241694949478
# Compute control for a deterministic system
# Cost in iteration 0: 0.014820241694949478
# Converged in iteration 1 with cost 0.014820241694949478
# Final cost : 0.014820241694949478
# Compute control for a deterministic system
# Cost in iteration 0: 0.014820241694949478
# Converged in iteration 1 with cost 0.014820241694949478
# Final cost : 0.014820241694949478
# Compute control for a deterministic system
# Cost in iteration 0: 0.014820241694949478
# Converged in iteration 1 with cost 0.014820241694949478
# Final cost : 0.014820241694949478
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.13913420521181197
# Converged in iteration 6 with cost 0.019846147895521672
# Final cost : 0.019846147895521672
# Compute control for a deterministic system
# Cost in iteration 0: 0.019846147895521672
# Converged in iteration 1 with cost 0.019846147895521672
# Final cost : 0.019846147895521672
# Compute control for a deterministic system
# Cost in iteration 0: 0.019846147895521672
# Converged in iteration 1 with cost 0.019846147895521672
# Final cost : 0.019846147895521672
# Compute control for a deterministic system
# Cost in iteration 0: 0.019846147895521672
# Converged in iteration 1 with cost 0.019846147895521672
# Final cost : 0.019846147895521672
# Compute control for a deterministic system
# Cost in iteration 0: 0.019846147895521672
# Converged in iteration 1 with cost 0.019846147895521672
# Final cost : 0.019846147895521672
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.43721244860058067
# Converged in iteration 4 with cost 0.02673289726085013
# Final cost : 0.02673289726085013
# Compute control for a deterministic system
# Cost in iteration 0: 0.02673289726085013
# Converged in iteration 1 with cost 0.02673289726085013
# Final cost : 0.02673289726085013
# Compute control for a deterministic system
# Cost in iteration 0: 0.02673289726085013
# Converged in iteration 1 with cost 0.02673289726085013
# Final cost : 0.02673289726085013
# Compute control for a deterministic system
# Cost in iteration 0: 0.02673289726085013
# Converged in iteration 1 with cost 0.02673289726085013
# Final cost : 0.02673289726085013
# Compute control for a deterministic system
# Cost in iteration 0: 0.02673289726085013
# Converged in iteration 1 with cost 0.02673289726085013
# Final cost : 0.02673289726085013
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.36787280365324615
# Converged in iteration 3 with cost 0.03487980403491699
# Final cost : 0.03487980403491699
# Compute control for a deterministic system
# Cost in iteration 0: 0.03487980403491699
# Converged in iteration 1 with cost 0.03487980403491699
# Final cost : 0.03487980403491699
# Compute control for a deterministic system
# Cost in iteration 0: 0.03487980403491699
# Converged in iteration 1 with cost 0.03487980403491699
# Final cost : 0.03487980403491699
# Compute control for a deterministic system
# Cost in iteration 0: 0.03487980403491699
# Converged in iteration 1 with cost 0.03487980403491699
# Final cost : 0.03487980403491699
# Compute control for a deterministic system
# Cost in iteration 0: 0.03487980403491699
# Converged in iteration 1 with cost 0.03487980403491699
# Final cost : 0.03487980403491699
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.09020788051688741
# Converged in iteration 3 with cost 0.04322278867179969
# Final cost : 0.04322278867179969
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322278867179969
# Converged in iteration 1 with cost 0.04322278867179969
# Final cost : 0.04322278867179969
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322278867179969
# Converged in iteration 1 with cost 0.04322278867179969
# Final cost : 0.04322278867179969
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322278867179969
# Converged in iteration 1 with cost 0.04322278867179969
# Final cost : 0.04322278867179969
# Compute control for a deterministic system
# Cost in iteration 0: 0.04322278867179969
# Converged in iteration 1 with cost 0.04322278867179969
# Final cost : 0.04322278867179969
# Compute control for a deterministic system
# Cost in iteration 0: 0.5263760228722709
# Final cost : 0.05871344399917304
# Compute control for a deterministic system
# Cost in iteration 0: 0.05871344399917304
# Final cost : 0.03912000685708242
# Compute control for a deterministic system
# Cost in iteration 0: 0.03912000685708242
# Final cost : 0.0388015915951285
# Compute control for a deterministic system
# Cost in iteration 0: 0.0388015915951285
# Final cost : 0.038763150126534286
# Compute control for a deterministic system
# Cost in iteration 0: 0.038763150126534286
# Final cost : 0.0386933450112644
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.4817778386365244
# Final cost : 0.05462633918585105
# Compute control for a deterministic system
# Cost in iteration 0: 0.05462633918585105
# Final cost : 0.036719171555960106
# Compute control for a deterministic system
# Cost in iteration 0: 0.036719171555960106
# Final cost : 0.03647207182534483
# Compute control for a deterministic system
# Cost in iteration 0: 0.03647207182534483
# Final cost : 0.03644675382058965
# Compute control for a deterministic system
# Cost in iteration 0: 0.03644675382058965
# Final cost : 0.036404704351008774
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.12104556254920804
# Converged in iteration 62 with cost 0.04256350180696747
# Final cost : 0.04256350180696747
# Compute control for a deterministic system
# Cost in iteration 0: 0.04256350180696747
# Converged in iteration 1 with cost 0.04256350180696747
# Final cost : 0.04256350180696747
# Compute control for a deterministic system
# Cost in iteration 0: 0.04256350180696747
# Converged in iteration 1 with cost 0.04256350180696747
# Final cost : 0.04256350180696747
# Compute control for a deterministic system
# Cost in iteration 0: 0.04256350180696747
# Converged in iteration 1 with cost 0.04256350180696747
# Final cost : 0.04256350180696747
# Compute control for a deterministic system
# Cost in iteration 0: 0.04256350180696747
# Converged in iteration 1 with cost 0.04256350180696747
# Final cost : 0.04256350180696747
# Compute control for a deterministic system
# Cost in iteration 0: 0.11871721363327842
# Converged in iteration 64 with cost 0.03962286225824206
# Final cost : 0.03962286225824206
# Compute control for a deterministic system
# Cost in iteration 0: 0.03962286225824206
# Converged in iteration 1 with cost 0.03962286225824206
# Final cost : 0.03962286225824206
# Compute control for a deterministic system
# Cost in iteration 0: 0.03962286225824206
# Converged in iteration 1 with cost 0.03962286225824206
# Final cost : 0.03962286225824206
# Compute control for a deterministic system
# Cost in iteration 0: 0.03962286225824206
# Converged in iteration 1 with cost 0.03962286225824206
# Final cost : 0.03962286225824206
# Compute control for a deterministic system
# Cost in iteration 0: 0.03962286225824206
# Converged in iteration 1 with cost 0.03962286225824206
# Final cost : 0.03962286225824206
# Compute control for a deterministic system
# Cost in iteration 0: 0.11631740636089481
# Converged in iteration 67 with cost 0.03665785677406993
# Final cost : 0.03665785677406993
# Compute control for a deterministic system
# Cost in iteration 0: 0.03665785677406993
# Converged in iteration 1 with cost 0.03665785677406993
# Final cost : 0.03665785677406993
# Compute control for a deterministic system
# Cost in iteration 0: 0.03665785677406993
# Converged in iteration 1 with cost 0.03665785677406993
# Final cost : 0.03665785677406993
# Compute control for a deterministic system
# Cost in iteration 0: 0.03665785677406993
# Converged in iteration 1 with cost 0.03665785677406993
# Final cost : 0.03665785677406993
# Compute control for a deterministic system
# Cost in iteration 0: 0.03665785677406993
# Converged in iteration 1 with cost 0.03665785677406993
# Final cost : 0.03665785677406993
# Compute control for a deterministic system
# Cost in iteration 0: 0.08257573655869108
# Converged in iteration 74 with cost 0.031211924102932127
# Final cost : 0.031211924102932127
# Compute control for a deterministic system
# Cost in iteration 0: 0.031211924102932127
# Converged in iteration 2 with cost 0.031211924102931818
# Final cost : 0.031211924102931818
# Compute control for a deterministic system
# Cost in iteration 0: 0.031211924102931818
# Converged in iteration 1 with cost 0.031211924102931818
# Final cost : 0.031211924102931818
# Compute control for a deterministic system
# Cost in iteration 0: 0.031211924102931818
# Converged in iteration 1 with cost 0.031211924102931818
# Final cost : 0.031211924102931818
# Compute control for a deterministic system
# Cost in iteration 0: 0.031211924102931818
# Converged in iteration 1 with cost 0.031211924102931818
# Final cost : 0.031211924102931818
# Compute control for a deterministic system
# Cost in iteration 0: 0.11195945104768522
# Converged in iteration 76 with cost 0.0316600280911275
# Final cost : 0.0316600280911275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0316600280911275
# Converged in iteration 1 with cost 0.0316600280911275
# Final cost : 0.0316600280911275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0316600280911275
# Converged in iteration 1 with cost 0.0316600280911275
# Final cost : 0.0316600280911275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0316600280911275
# Converged in iteration 1 with cost 0.0316600280911275
# Final cost : 0.0316600280911275
# Compute control for a deterministic system
# Cost in iteration 0: 0.0316600280911275
# Converged in iteration 1 with cost 0.0316600280911275
# Final cost : 0.0316600280911275
# Compute control for a deterministic system
# Cost in iteration 0: 0.10951227254559512
# Converged in iteration 80 with cost 0.02910118202599983
# Final cost : 0.02910118202599983
# Compute control for a deterministic system
# Cost in iteration 0: 0.02910118202599983
# Converged in iteration 1 with cost 0.02910118202599983
# Final cost : 0.02910118202599983
# Compute control for a deterministic system
# Cost in iteration 0: 0.02910118202599983
# Converged in iteration 1 with cost 0.02910118202599983
# Final cost : 0.02910118202599983
# Compute control for a deterministic system
# Cost in iteration 0: 0.02910118202599983
# Converged in iteration 1 with cost 0.02910118202599983
# Final cost : 0.02910118202599983
# Compute control for a deterministic system
# Cost in iteration 0: 0.02910118202599983
# Converged in iteration 1 with cost 0.02910118202599983
# Final cost : 0.02910118202599983
# Compute control for a deterministic system
# Cost in iteration 0: 0.10726931113932217
# Converged in iteration 103 with cost 0.026650654508349615
# Final cost : 0.026650654508349615
# Compute control for a deterministic system
# Cost in iteration 0: 0.026650654508349615
# Converged in iteration 1 with cost 0.026650654508349615
# Final cost : 0.026650654508349615
# Compute control for a deterministic system
# Cost in iteration 0: 0.026650654508349615
# Converged in iteration 1 with cost 0.026650654508349615
# Final cost : 0.026650654508349615
# Compute control for a deterministic system
# Cost in iteration 0: 0.026650654508349615
# Converged in iteration 1 with cost 0.026650654508349615
# Final cost : 0.026650654508349615
# Compute control for a deterministic system
# Cost in iteration 0: 0.026650654508349615
# Converged in iteration 1 with cost 0.026650654508349615
# Final cost : 0.026650654508349615
# Compute control for a deterministic system
# Cost in iteration 0: 0.07329595226849614
# Final cost : 0.020144022015135012
# Compute control for a deterministic system
# Cost in iteration 0: 0.020144022015135012
# Final cost : 0.015926578459919176
# Compute control for a deterministic system
# Cost in iteration 0: 0.015926578459919176
# Converged in iteration 18 with cost 0.015923476302799097
# Final cost : 0.015923476302799097
# Compute control for a deterministic system
# Cost in iteration 0: 0.015923476302799097
# Converged in iteration 1 with cost 0.015923476302799097
# Final cost : 0.015923476302799097
# Compute control for a deterministic system
# Cost in iteration 0: 0.015923476302799097
# Converged in iteration 1 with cost 0.015923476302799097
# ...
# Final cost : 2.5037320330964428
# Compute control for a deterministic system
# Cost in iteration 0: 2.5037320330964428
# Final cost : 2.5037320308093216
# Compute control for a deterministic system
# Cost in iteration 0: 2.5037320308093216
# Final cost : 2.5037320308093176
# Compute control for a deterministic system
# Cost in iteration 0: 2.5037320308093176
# Final cost : 2.5037320308093176
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 2.3043504764447063
# Final cost : 2.2544592180986456
# Compute control for a deterministic system
# Cost in iteration 0: 2.2544592180986456
# Final cost : 2.253131022655268
# Compute control for a deterministic system
# Cost in iteration 0: 2.253131022655268
# Converged in iteration 6 with cost 2.2531306670091977
# Final cost : 2.2531306670091977
# Compute control for a deterministic system
# Cost in iteration 0: 2.2531306670091977
# Converged in iteration 1 with cost 2.2531306670091977
# Final cost : 2.2531306670091977
# Compute control for a deterministic system
# Cost in iteration 0: 2.2531306670091977
# Converged in iteration 1 with cost 2.2531306670091977
# Final cost : 2.2531306670091977
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 2.057408791419455
# Final cost : 2.00827158179435
# Compute control for a deterministic system
# Cost in iteration 0: 2.00827158179435
# Final cost : 2.0072587423229247
# Compute control for a deterministic system
# Cost in iteration 0: 2.0072587423229247
# Converged in iteration 7 with cost 2.007257358939611
# Final cost : 2.007257358939611
# Compute control for a deterministic system
# Cost in iteration 0: 2.007257358939611
# Converged in iteration 1 with cost 2.007257358939611
# Final cost : 2.007257358939611
# Compute control for a deterministic system
# Cost in iteration 0: 2.007257358939611
# Converged in iteration 1 with cost 2.007257358939611
# Final cost : 2.007257358939611
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 1.8471015759444176
# Final cost : 1.8163499304708655
# Compute control for a deterministic system
# Cost in iteration 0: 1.8163499304708655
# Final cost : 1.815847878764538
# Compute control for a deterministic system
# Cost in iteration 0: 1.815847878764538
# Final cost : 1.8158478777959841
# Compute control for a deterministic system
# Cost in iteration 0: 1.8158478777959841
# Final cost : 1.8158478777959841
# Compute control for a deterministic system
# Cost in iteration 0: 1.8158478777959841
# Final cost : 1.815847877795816
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 1.6303206051050425
# Final cost : 1.5865199437457786
# Compute control for a deterministic system
# Cost in iteration 0: 1.5865199437457786
# Final cost : 1.5861692407600803
# Compute control for a deterministic system
# Cost in iteration 0: 1.5861692407600803
# Final cost : 1.5861692401399836
# Compute control for a deterministic system
# Cost in iteration 0: 1.5861692401399836
# Final cost : 1.5861692401399836
# Compute control for a deterministic system
# Cost in iteration 0: 1.5861692401399836
# Final cost : 1.5861692401399836
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 1.4104934387473331
# Final cost : 1.3688124662993177
# Compute control for a deterministic system
# Cost in iteration 0: 1.3688124662993177
# Final cost : 1.3687047253619615
# Compute control for a deterministic system
# Cost in iteration 0: 1.3687047253619615
# Final cost : 1.3687047252452502
# Compute control for a deterministic system
# Cost in iteration 0: 1.3687047252452502
# Converged in iteration 1 with cost 1.3687047252452502
# Final cost : 1.3687047252452502
# Compute control for a deterministic system
# Cost in iteration 0: 1.3687047252452502
# Converged in iteration 1 with cost 1.3687047252452502
# Final cost : 1.3687047252452502
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 1.2051758281091685
# Converged in iteration 26 with cost 1.1640546797525002
# Final cost : 1.1640546797525002
# Compute control for a deterministic system
# Cost in iteration 0: 1.1640546797525002
# Converged in iteration 1 with cost 1.1640546797525002
# Final cost : 1.1640546797525002
# Compute control for a deterministic system
# Cost in iteration 0: 1.1640546797525002
# Converged in iteration 1 with cost 1.1640546797525002
# Final cost : 1.1640546797525002
# Compute control for a deterministic system
# Cost in iteration 0: 1.1640546797525002
# Converged in iteration 1 with cost 1.1640546797525002
# Final cost : 1.1640546797525002
# Compute control for a deterministic system
# Cost in iteration 0: 1.1640546797525002
# Converged in iteration 1 with cost 1.1640546797525002
# Final cost : 1.1640546797525002
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 1.0415534111039828
# Converged in iteration 22 with cost 1.0111903394590187
# Final cost : 1.0111903394590187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0111903394590187
# Converged in iteration 1 with cost 1.0111903394590187
# Final cost : 1.0111903394590187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0111903394590187
# Converged in iteration 1 with cost 1.0111903394590187
# Final cost : 1.0111903394590187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0111903394590187
# Converged in iteration 1 with cost 1.0111903394590187
# Final cost : 1.0111903394590187
# Compute control for a deterministic system
# Cost in iteration 0: 1.0111903394590187
# Converged in iteration 1 with cost 1.0111903394590187
# Final cost : 1.0111903394590187
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.8864263011265485
# Converged in iteration 24 with cost 0.8356522142223091
# Final cost : 0.8356522142223091
# Compute control for a deterministic system
# Cost in iteration 0: 0.8356522142223091
# Converged in iteration 1 with cost 0.8356522142223091
# Final cost : 0.8356522142223091
# Compute control for a deterministic system
# Cost in iteration 0: 0.8356522142223091
# Converged in iteration 1 with cost 0.8356522142223091
# Final cost : 0.8356522142223091
# Compute control for a deterministic system
# Cost in iteration 0: 0.8356522142223091
# Converged in iteration 1 with cost 0.8356522142223091
# Final cost : 0.8356522142223091
# Compute control for a deterministic system
# Cost in iteration 0: 0.8356522142223091
# Converged in iteration 1 with cost 0.8356522142223091
# Final cost : 0.8356522142223091
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.7309836339498426
# Converged in iteration 26 with cost 0.677324717789211
# Final cost : 0.677324717789211
# Compute control for a deterministic system
# Cost in iteration 0: 0.677324717789211
# Converged in iteration 1 with cost 0.677324717789211
# Final cost : 0.677324717789211
# Compute control for a deterministic system
# Cost in iteration 0: 0.677324717789211
# Converged in iteration 1 with cost 0.677324717789211
# Final cost : 0.677324717789211
# Compute control for a deterministic system
# Cost in iteration 0: 0.677324717789211
# Converged in iteration 1 with cost 0.677324717789211
# Final cost : 0.677324717789211
# Compute control for a deterministic system
# Cost in iteration 0: 0.677324717789211
# Converged in iteration 1 with cost 0.677324717789211
# Final cost : 0.677324717789211
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.5970647733939758
# Converged in iteration 24 with cost 0.5626229585866258
# Final cost : 0.5626229585866258
# Compute control for a deterministic system
# Cost in iteration 0: 0.5626229585866258
# Converged in iteration 1 with cost 0.5626229585866258
# Final cost : 0.5626229585866258
# Compute control for a deterministic system
# Cost in iteration 0: 0.5626229585866258
# Converged in iteration 1 with cost 0.5626229585866258
# Final cost : 0.5626229585866258
# Compute control for a deterministic system
# Cost in iteration 0: 0.5626229585866258
# Converged in iteration 1 with cost 0.5626229585866258
# Final cost : 0.5626229585866258
# Compute control for a deterministic system
# Cost in iteration 0: 0.5626229585866258
# Converged in iteration 1 with cost 0.5626229585866258
# Final cost : 0.5626229585866258
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.4950020926649358
# Converged in iteration 22 with cost 0.43715003731811874
# Final cost : 0.43715003731811874
# Compute control for a deterministic system
# Cost in iteration 0: 0.43715003731811874
# Converged in iteration 1 with cost 0.43715003731811874
# Final cost : 0.43715003731811874
# Compute control for a deterministic system
# Cost in iteration 0: 0.43715003731811874
# Converged in iteration 1 with cost 0.43715003731811874
# Final cost : 0.43715003731811874
# Compute control for a deterministic system
# Cost in iteration 0: 0.43715003731811874
# Converged in iteration 1 with cost 0.43715003731811874
# Final cost : 0.43715003731811874
# Compute control for a deterministic system
# Cost in iteration 0: 0.43715003731811874
# Converged in iteration 1 with cost 0.43715003731811874
# Final cost : 0.43715003731811874
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.3911079027380314
# Converged in iteration 28 with cost 0.3307992410818114
# Final cost : 0.3307992410818114
# Compute control for a deterministic system
# Cost in iteration 0: 0.3307992410818114
# Converged in iteration 2 with cost 0.33079924108181014
# Final cost : 0.33079924108181014
# Compute control for a deterministic system
# Cost in iteration 0: 0.33079924108181014
# Converged in iteration 1 with cost 0.33079924108181014
# Final cost : 0.33079924108181014
# Compute control for a deterministic system
# Cost in iteration 0: 0.33079924108181014
# Converged in iteration 1 with cost 0.33079924108181014
# Final cost : 0.33079924108181014
# Compute control for a deterministic system
# Cost in iteration 0: 0.33079924108181014
# Converged in iteration 1 with cost 0.33079924108181014
# Final cost : 0.33079924108181014
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.3056898503431294
# Converged in iteration 23 with cost 0.24353498356631775
# Final cost : 0.24353498356631775
# Compute control for a deterministic system
# Cost in iteration 0: 0.24353498356631775
# Converged in iteration 1 with cost 0.24353498356631775
# Final cost : 0.24353498356631775
# Compute control for a deterministic system
# Cost in iteration 0: 0.24353498356631775
# Converged in iteration 1 with cost 0.24353498356631775
# Final cost : 0.24353498356631775
# Compute control for a deterministic system
# Cost in iteration 0: 0.24353498356631775
# Converged in iteration 1 with cost 0.24353498356631775
# Final cost : 0.24353498356631775
# Compute control for a deterministic system
# Cost in iteration 0: 0.24353498356631775
# Converged in iteration 1 with cost 0.24353498356631775
# Final cost : 0.24353498356631775
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.2252857642891046
# Converged in iteration 21 with cost 0.18575443361250055
# Final cost : 0.18575443361250055
# Compute control for a deterministic system
# Cost in iteration 0: 0.18575443361250055
# Converged in iteration 1 with cost 0.18575443361250055
# Final cost : 0.18575443361250055
# Compute control for a deterministic system
# Cost in iteration 0: 0.18575443361250055
# Converged in iteration 1 with cost 0.18575443361250055
# Final cost : 0.18575443361250055
# Compute control for a deterministic system
# Cost in iteration 0: 0.18575443361250055
# Converged in iteration 1 with cost 0.18575443361250055
# Final cost : 0.18575443361250055
# Compute control for a deterministic system
# Cost in iteration 0: 0.18575443361250055
# Converged in iteration 1 with cost 0.18575443361250055
# Final cost : 0.18575443361250055
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.19422474878485296
# Converged in iteration 46 with cost 0.13032411259135324
# Final cost : 0.13032411259135324
# Compute control for a deterministic system
# Cost in iteration 0: 0.13032411259135324
# Converged in iteration 1 with cost 0.13032411259135324
# Final cost : 0.13032411259135324
# Compute control for a deterministic system
# Cost in iteration 0: 0.13032411259135324
# Converged in iteration 1 with cost 0.13032411259135324
# Final cost : 0.13032411259135324
# Compute control for a deterministic system
# Cost in iteration 0: 0.13032411259135324
# Converged in iteration 1 with cost 0.13032411259135324
# Final cost : 0.13032411259135324
# Compute control for a deterministic system
# Cost in iteration 0: 0.13032411259135324
# Converged in iteration 1 with cost 0.13032411259135324
# Final cost : 0.13032411259135324
# Compute control for a deterministic system
# Cost in iteration 0: 0.11303932283462134
# Converged in iteration 51 with cost 0.057677459336104034
# Final cost : 0.057677459336104034
# Compute control for a deterministic system
# Cost in iteration 0: 0.057677459336104034
# Converged in iteration 1 with cost 0.057677459336104034
# Final cost : 0.057677459336104034
# Compute control for a deterministic system
# Cost in iteration 0: 0.057677459336104034
# Converged in iteration 1 with cost 0.057677459336104034
# Final cost : 0.057677459336104034
# Compute control for a deterministic system
# Cost in iteration 0: 0.057677459336104034
# Converged in iteration 1 with cost 0.057677459336104034
# Final cost : 0.057677459336104034
# Compute control for a deterministic system
# Cost in iteration 0: 0.057677459336104034
# Converged in iteration 1 with cost 0.057677459336104034
# Final cost : 0.057677459336104034
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.09623663142332714
# Final cost : 0.02433466322405192
# Compute control for a deterministic system
# Cost in iteration 0: 0.02433466322405192
# Converged in iteration 37 with cost 0.023865611369900515
# Final cost : 0.023865611369900515
# Compute control for a deterministic system
# Cost in iteration 0: 0.023865611369900515
# Converged in iteration 1 with cost 0.023865611369900515
# Final cost : 0.023865611369900515
# Compute control for a deterministic system
# Cost in iteration 0: 0.023865611369900515
# Converged in iteration 1 with cost 0.023865611369900515
# Final cost : 0.023865611369900515
# Compute control for a deterministic system
# Cost in iteration 0: 0.023865611369900515
# Converged in iteration 1 with cost 0.023865611369900515
# Final cost : 0.023865611369900515
# -----------------------------------------------
# 0 found better solution
# Compute control for a deterministic system
# Cost in iteration 0: 0.044040018551808106
# Final cost : 0.00718208323464144
# Compute control for a deterministic system
# Cost in iteration 0: 0.00718208323464144
# Converged in iteration 19 with cost 0.0071026207440262725
# Final cost : 0.0071026207440262725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071026207440262725
# Converged in iteration 1 with cost 0.0071026207440262725
# Final cost : 0.0071026207440262725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071026207440262725
# Converged in iteration 1 with cost 0.0071026207440262725
# Final cost : 0.0071026207440262725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0071026207440262725
# Converged in iteration 1 with cost 0.0071026207440262725
# Final cost : 0.0071026207440262725
# -----------------------------------------------
# 0 found better solution

# %%
filehandler = open("results_peaks_w2.pickle","wb")
pickle.dump(results_peak,filehandler)
filehandler.close()

# %%
filehandler = open("results_peaks_w2.pickle","rb")
results_peak = pickle.load(filehandler)
filehandler.close()
