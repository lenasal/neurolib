# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,174], wc.inh[0,174]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  23  211  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                #wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.025599734227773282
# Final cost : 0.0013770429518323965
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013770429518323965
# Final cost : 0.0013557141076271917
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013557141076271917
# Final cost : 0.0013555390407952454
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555390407952454
# Final cost : 0.0013555388827296028
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555388827296028
# Converged in iteration 43 with cost 0.0013555388827256052 because of step counter
# Final cost : 0.0013555388827256052
# Compute control for a deterministic system
# Cost in iteration 0: 0.0508459928657093
# Final cost : 0.0033007129169571334
# Compute control for a deterministic system
# Cost in iteration 0: 0.0033007129169571334
# Final cost : 0.0032396463498813297
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032396463498813297
# Final cost : 0.0032388667310615216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032388667310615216
# Final cost : 0.003238866206175381
# Compute control for a deterministic system
# Cost in iteration 0: 0.003238866206175381
# Converged in iteration 105 with cost 0.003238866206144065 because of vanishing difference
# Final cost : 0.003238866206144065
# Compute control for a deterministic system
# Cost in iteration 0: 0.04246146535186332
# Final cost : 0.005973473643886142
# Compute control for a deterministic system
# Cost in iteration 0: 0.005973473643886142
# Final cost : 0.005886171643597541
# Compute control for a deterministic system
# Cost in iteration 0: 0.005886171643597541
# Final cost : 0.005884525915499193
# Compute control for a deterministic system
# Cost in iteration 0: 0.005884525915499193
# Final cost : 0.005884519849530904
# Compute control for a deterministic system
# Cost in iteration 0: 0.005884519849530904
# Converged in iteration 242 with cost 0.00588451984871607 because of step counter
# Final cost : 0.00588451984871607
# Compute control for a deterministic system
# Cost in iteration 0: 0.037416350813974264
# Final cost : 0.009379583746467895
# Compute control for a deterministic system
# Cost in iteration 0: 0.009379583746467895
# Final cost : 0.009254839845724267
# Compute control for a deterministic system
# Cost in iteration 0: 0.009254839845724267
# Final cost : 0.009251684450035116
# Compute control for a deterministic system
# Cost in iteration 0: 0.009251684450035116
# Final cost : 0.009251655871300063
# Compute control for a deterministic system
# Cost in iteration 0: 0.009251655871300063
# Converged in iteration 260 with cost 0.009251655870353504 because of step counter
# Final cost : 0.009251655870353504
# Compute control for a deterministic system
# Cost in iteration 0: 0.029833651332172674
# Final cost : 0.01254383614674623
# Compute control for a deterministic system
# Cost in iteration 0: 0.01254383614674623
# Final cost : 0.012437840858197812
# Compute control for a deterministic system
# Cost in iteration 0: 0.012437840858197812
# Final cost : 0.012434454807153892
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434454807153892
# Final cost : 0.012434437079706382
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434437079706382
# Converged in iteration 471 with cost 0.012434437062287449 because of vanishing difference
# Final cost : 0.012434437062287449
# Compute control for a deterministic system
# Cost in iteration 0: 0.056949301430835625
# Final cost : 0.017206622173824602
# Compute control for a deterministic system
# Cost in iteration 0: 0.017206622173824602
# Final cost : 0.016991062198911774
# Compute control for a deterministic system
# Cost in iteration 0: 0.016991062198911774
# Final cost : 0.01698268493367714
# Compute control for a deterministic system
# Cost in iteration 0: 0.01698268493367714
# Final cost : 0.016982309656604966
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982309656604966
# Converged in iteration 807 with cost 0.0169823090942125 because of step counter
# Final cost : 0.0169823090942125
# Compute control for a deterministic system
# Cost in iteration 0: 0.09283421359984165
# Final cost : 0.02241177851477107
# Compute control for a deterministic system
# Cost in iteration 0: 0.02241177851477107
# Final cost : 0.022125392699342487
# Compute control for a deterministic system
# Cost in iteration 0: 0.022125392699342487
# Final cost : 0.022111914091724458
# Compute control for a deterministic system
# Cost in iteration 0: 0.022111914091724458
# Final cost : 0.02211114236801345
# Compute control for a deterministic system
# Cost in iteration 0: 0.02211114236801345
# Final cost : 0.02211113875384879
# Compute control for a deterministic system
# Cost in iteration 0: 0.050075098599374895
# Final cost : 0.028055370874287867
# Compute control for a deterministic system
# Cost in iteration 0: 0.028055370874287867
# Final cost : 0.02777838510372871
# Compute control for a deterministic system
# Cost in iteration 0: 0.02777838510372871
# Final cost : 0.027760134528685247
# Compute control for a deterministic system
# Cost in iteration 0: 0.027760134528685247
# Final cost : 0.027758558055289553
# Compute control for a deterministic system
# Cost in iteration 0: 0.027758558055289553
# Final cost : 0.027758537271117257
# Compute control for a deterministic system
# Cost in iteration 0: 0.05840035471642797
# Final cost : 0.03281899796321509
# Compute control for a deterministic system
# Cost in iteration 0: 0.03281899796321509
# Final cost : 0.0326188165344436
# Compute control for a deterministic system
# Cost in iteration 0: 0.0326188165344436
# Final cost : 0.032603698548195545
# Compute control for a deterministic system
# Cost in iteration 0: 0.032603698548195545
# Final cost : 0.03260149383695753
# Compute control for a deterministic system
# Cost in iteration 0: 0.03260149383695753
# Final cost : 0.03260143991441677
# Compute control for a deterministic system
# Cost in iteration 0: 0.08126913264243446
# Final cost : 0.039350041437682226
# Compute control for a deterministic system
# Cost in iteration 0: 0.039350041437682226
# Final cost : 0.0390259419989967
# Compute control for a deterministic system
# Cost in iteration 0: 0.0390259419989967
# Final cost : 0.03899459348051183
# Compute control for a deterministic system
# Cost in iteration 0: 0.03899459348051183
# Final cost : 0.03898891179384957
# Compute control for a deterministic system
# Cost in iteration 0: 0.03898891179384957
# Final cost : 0.03898865549740756
# Compute control for a deterministic system
# Cost in iteration 0: 0.07617341518372787
# Final cost : 0.04601185356306474
# Compute control for a deterministic system
# Cost in iteration 0: 0.04601185356306474
# Final cost : 0.04569519588141958
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569519588141958
# Final cost : 0.04565451148162728
# Compute control for a deterministic system
# Cost in iteration 0: 0.04565451148162728
# Final cost : 0.0456443737598643
# Compute control for a deterministic system
# Cost in iteration 0: 0.0456443737598643
# Final cost : 0.045643500052983246
# Compute control for a deterministic system
# Cost in iteration 0: 0.09888106279320866
# Final cost : 0.051339161208816125
# Compute control for a deterministic system
# Cost in iteration 0: 0.051339161208816125
# Final cost : 0.05110536781402988
# Compute control for a deterministic system
# Cost in iteration 0: 0.05110536781402988
# Final cost : 0.05107223191129473
# Compute control for a deterministic system
# Cost in iteration 0: 0.05107223191129473
# Final cost : 0.05106006951268757
# Compute control for a deterministic system
# Cost in iteration 0: 0.05106006951268757
# Final cost : 0.051058315485674736
# Compute control for a deterministic system
# Cost in iteration 0: 0.07445151327463066
# Final cost : 0.05817394855927044
# Compute control for a deterministic system
# Cost in iteration 0: 0.05817394855927044
# Final cost : 0.0578516640728208
# Compute control for a deterministic system
# Cost in iteration 0: 0.0578516640728208
# Final cost : 0.05778011716912834
# Compute control for a deterministic system
# Cost in iteration 0: 0.05778011716912834
# Final cost : 0.057744800350350206
# Compute control for a deterministic system
# Cost in iteration 0: 0.057744800350350206
# Final cost : 0.0577351683554745
# Compute control for a deterministic system
# Cost in iteration 0: 0.08149054425702204
# Final cost : 0.06447875334748947
# Compute control for a deterministic system
# Cost in iteration 0: 0.06447875334748947
# Final cost : 0.06411475873414227
# Compute control for a deterministic system
# Cost in iteration 0: 0.06411475873414227
# Final cost : 0.06400015274315471
# Compute control for a deterministic system
# Cost in iteration 0: 0.06400015274315471
# Final cost : 0.06391351167417823
# Compute control for a deterministic system
# Cost in iteration 0: 0.06391351167417823
# Final cost : 0.06387742391256127
# Compute control for a deterministic system
# Cost in iteration 0: 0.09964408489785205
# Final cost : 0.06956101050370103
# Compute control for a deterministic system
# Cost in iteration 0: 0.06956101050370103
# Final cost : 0.06919326415329338
# Compute control for a deterministic system
# Cost in iteration 0: 0.06919326415329338
# Final cost : 0.06908342191466327
# Compute control for a deterministic system
# Cost in iteration 0: 0.06908342191466327
# Final cost : 0.06897994313774973
# Compute control for a deterministic system
# Cost in iteration 0: 0.06897994313774973
# Final cost : 0.06892482063521878
# Compute control for a deterministic system
# Cost in iteration 0: 0.09253102155110568
# Final cost : 0.07243520471659753
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243520471659753
# Final cost : 0.07232654938275544
# Compute control for a deterministic system
# Cost in iteration 0: 0.07232654938275544
# Final cost : 0.07228338604100931
# Compute control for a deterministic system
# Cost in iteration 0: 0.07228338604100931
# Final cost : 0.07224643678758955
# Compute control for a deterministic system
# Cost in iteration 0: 0.07224643678758955
# Final cost : 0.07222439583757101
# Compute control for a deterministic system
# Cost in iteration 0: 0.07952657131757719
# Final cost : 0.07590331966083856
# Compute control for a deterministic system
# Cost in iteration 0: 0.07590331966083856
# Final cost : 0.07582277533729584
# Compute control for a deterministic system
# Cost in iteration 0: 0.07582277533729584
# Final cost : 0.07579228126077646
# Compute control for a deterministic system
# Cost in iteration 0: 0.07579228126077646
# Final cost : 0.0757609254673838
# Compute control for a deterministic system
# Cost in iteration 0: 0.0757609254673838
# Final cost : 0.07573874330605497
# Compute control for a deterministic system
# Cost in iteration 0: 0.29836837059948296
# Final cost : 0.07882821158000552
# Compute control for a deterministic system
# Cost in iteration 0: 0.07882821158000552
# Final cost : 0.0787844616642468
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787844616642468
# Final cost : 0.07876520946599488
# Compute control for a deterministic system
# Cost in iteration 0: 0.07876520946599488
# Final cost : 0.07874812041319318
# Compute control for a deterministic system
# Cost in iteration 0: 0.07874812041319318
# Final cost : 0.07873280518697615
# Compute control for a deterministic system
# Cost in iteration 0: 0.3081678619634184
# Final cost : 0.08085523619246801
# Compute control for a deterministic system
# Cost in iteration 0: 0.08085523619246801
# Final cost : 0.08082091823145994
# Compute control for a deterministic system
# Cost in iteration 0: 0.08082091823145994
# Final cost : 0.08080013445824388
# Compute control for a deterministic system
# Cost in iteration 0: 0.08080013445824388
# Final cost : 0.0807810283544227
# Compute control for a deterministic system
# Cost in iteration 0: 0.0807810283544227
# Final cost : 0.08076695360988269
# Compute control for a deterministic system
# Cost in iteration 0: 0.09727449217549478
# Final cost : 0.08291651912446339
# Compute control for a deterministic system
# Cost in iteration 0: 0.08291651912446339
# Final cost : 0.0828894953139323
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828894953139323
# Final cost : 0.08287300583018051
# Compute control for a deterministic system
# Cost in iteration 0: 0.08287300583018051
# Final cost : 0.08285440572333824
# Compute control for a deterministic system
# Cost in iteration 0: 0.08285440572333824
# Final cost : 0.08283664397561001
# Compute control for a deterministic system
# Cost in iteration 0: 0.09067309605751922
# Final cost : 0.08443939892299873
# Compute control for a deterministic system
# Cost in iteration 0: 0.08443939892299873
# Final cost : 0.08442205587430647
# Compute control for a deterministic system
# Cost in iteration 0: 0.08442205587430647
# Final cost : 0.08440942381580298
# Compute control for a deterministic system
# Cost in iteration 0: 0.08440942381580298
# Final cost : 0.08439058058766638
# Compute control for a deterministic system
# Cost in iteration 0: 0.08439058058766638
# Final cost : 0.08436909501427044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0988725423622173
# Final cost : 0.08554198080228533
# Compute control for a deterministic system
# Cost in iteration 0: 0.08554198080228533
# Final cost : 0.0855243033273573
# Compute control for a deterministic system
# Cost in iteration 0: 0.0855243033273573
# Final cost : 0.08551394009581874
# Compute control for a deterministic system
# Cost in iteration 0: 0.08551394009581874
# Final cost : 0.08549768376227676
# Compute control for a deterministic system
# Cost in iteration 0: 0.08549768376227676
# Final cost : 0.08547086753108336
# Compute control for a deterministic system
# Cost in iteration 0: 0.08735319083198756
# Final cost : 0.08619602911514603
# Compute control for a deterministic system
# Cost in iteration 0: 0.08619602911514603
# Final cost : 0.08618718134296326
# Compute control for a deterministic system
# Cost in iteration 0: 0.08618718134296326
# Final cost : 0.08618165015778431
# Compute control for a deterministic system
# Cost in iteration 0: 0.08618165015778431
# Final cost : 0.0861726288294767
# Compute control for a deterministic system
# Cost in iteration 0: 0.0861726288294767
# Final cost : 0.08615822226362714
# Compute control for a deterministic system
# Cost in iteration 0: 0.25743051488897767
# Final cost : 0.08727243557853318
# Compute control for a deterministic system
# Cost in iteration 0: 0.08727243557853318
# Final cost : 0.08711923958622494
# Compute control for a deterministic system
# Cost in iteration 0: 0.08711923958622494
# Final cost : 0.08710203779316045
# Compute control for a deterministic system
# Cost in iteration 0: 0.08710203779316045
# Final cost : 0.08707671245136248
# Compute control for a deterministic system
# Cost in iteration 0: 0.08707671245136248
# Final cost : 0.0869944713886935
# Compute control for a deterministic system
# Cost in iteration 0: 0.8027142872400164
# Final cost : 0.08791700019838564
# Compute control for a deterministic system
# Cost in iteration 0: 0.08791700019838564
# Final cost : 0.08788458517231436
# Compute control for a deterministic system
# Cost in iteration 0: 0.08788458517231436
# Final cost : 0.08787882047237125
# Compute control for a deterministic system
# Cost in iteration 0: 0.08787882047237125
# Final cost : 0.08786571246432123
# Compute control for a deterministic system
# Cost in iteration 0: 0.08786571246432123
# Final cost : 0.08784930830056868
# Compute control for a deterministic system
# Cost in iteration 0: 0.08908086836356596
# Final cost : 0.088825061602525
# Compute control for a deterministic system
# Cost in iteration 0: 0.088825061602525
# Final cost : 0.08880914939101404
# Compute control for a deterministic system
# Cost in iteration 0: 0.08880914939101404
# Final cost : 0.08880167863351437
# Compute control for a deterministic system
# Cost in iteration 0: 0.08880167863351437
# Final cost : 0.0887918107066685
# Compute control for a deterministic system
# Cost in iteration 0: 0.0887918107066685
# Final cost : 0.08877642267076438
# Compute control for a deterministic system
# Cost in iteration 0: 0.1205748972710149
# Final cost : 0.06457013614803882
# Compute control for a deterministic system
# Cost in iteration 0: 0.06457013614803882
# Final cost : 0.06401123842176741
# Compute control for a deterministic system
# Cost in iteration 0: 0.06401123842176741
# Final cost : 0.06391416641542844
# Compute control for a deterministic system
# Cost in iteration 0: 0.06391416641542844
# Final cost : 0.06388213564884608
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388213564884608
# Final cost : 0.06388090175772371
# Compute control for a deterministic system
# Cost in iteration 0: 0.12321650700697195
# Final cost : 0.05300325202649187
# Compute control for a deterministic system
# Cost in iteration 0: 0.05300325202649187
# Final cost : 0.05226157388553827
# Compute control for a deterministic system
# Cost in iteration 0: 0.05226157388553827
# Final cost : 0.052151804974422025
# Compute control for a deterministic system
# Cost in iteration 0: 0.052151804974422025
# Final cost : 0.05212396125422913
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212396125422913
# Final cost : 0.05212330345266756
# Compute control for a deterministic system
# Cost in iteration 0: 0.11076538086160985
# Final cost : 0.042550736691124434
# Compute control for a deterministic system
# Cost in iteration 0: 0.042550736691124434
# Final cost : 0.0419112293229577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0419112293229577
# Final cost : 0.041839186148591404
# Compute control for a deterministic system
# Cost in iteration 0: 0.041839186148591404
# Final cost : 0.04182574844982589
# Compute control for a deterministic system
# Cost in iteration 0: 0.04182574844982589
# Final cost : 0.04182561572379241
# Compute control for a deterministic system
# Cost in iteration 0: 0.09807327435832025
# Final cost : 0.03497267933519078
# Compute control for a deterministic system
# Cost in iteration 0: 0.03497267933519078
# Final cost : 0.03460066047155879
# Compute control for a deterministic system
# Cost in iteration 0: 0.03460066047155879
# Final cost : 0.03456758889560989
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456758889560989
# Final cost : 0.03456309475130222
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456309475130222
# Final cost : 0.03456305984704616
# Compute control for a deterministic system
# Cost in iteration 0: 0.107026845190723
# Final cost : 0.02712758329376203
# Compute control for a deterministic system
# Cost in iteration 0: 0.02712758329376203
# Final cost : 0.026647610745784606
# Compute control for a deterministic system
# Cost in iteration 0: 0.026647610745784606
# Final cost : 0.026613180149285296
# Compute control for a deterministic system
# Cost in iteration 0: 0.026613180149285296
# Final cost : 0.02660982825783299
# Compute control for a deterministic system
# Cost in iteration 0: 0.02660982825783299
# Final cost : 0.02660981720712522
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453384477984225
# Final cost : 0.02018991016726623
# Compute control for a deterministic system
# Cost in iteration 0: 0.02018991016726623
# Final cost : 0.019838138157560584
# Compute control for a deterministic system
# Cost in iteration 0: 0.019838138157560584
# Final cost : 0.01981719866328037
# Compute control for a deterministic system
# Cost in iteration 0: 0.01981719866328037
# Final cost : 0.019815866459530707
# Compute control for a deterministic system
# Cost in iteration 0: 0.019815866459530707
# Converged in iteration 838 with cost 0.01981586518327852 because of vanishing difference
# Final cost : 0.01981586518327852
# Compute control for a deterministic system
# Cost in iteration 0: 0.030920063193482634
# Final cost : 0.014381221344647357
# Compute control for a deterministic system
# Cost in iteration 0: 0.014381221344647357
# Final cost : 0.01411666694325952
# Compute control for a deterministic system
# Cost in iteration 0: 0.01411666694325952
# Final cost : 0.014104199808491695
# Compute control for a deterministic system
# Cost in iteration 0: 0.014104199808491695
# Final cost : 0.014103656239222108
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103656239222108
# Converged in iteration 695 with cost 0.014103655885608888 because of step counter
# Final cost : 0.014103655885608888
# Compute control for a deterministic system
# Cost in iteration 0: 0.028821090108807193
# Final cost : 0.01041836081527765
# Compute control for a deterministic system
# Cost in iteration 0: 0.01041836081527765
# Final cost : 0.010278137793095348
# Compute control for a deterministic system
# Cost in iteration 0: 0.010278137793095348
# Final cost : 0.010273059936921996
# Compute control for a deterministic system
# Cost in iteration 0: 0.010273059936921996
# Final cost : 0.010272898592823826
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272898592823826
# Converged in iteration 591 with cost 0.010272898465230284 because of step counter
# Final cost : 0.010272898465230284
# Compute control for a deterministic system
# Cost in iteration 0: 0.03409383454208226
# Final cost : 0.006533467576646688
# Compute control for a deterministic system
# Cost in iteration 0: 0.006533467576646688
# Final cost : 0.006375057918737226
# Compute control for a deterministic system
# Cost in iteration 0: 0.006375057918737226
# Final cost : 0.006370736864098115
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370736864098115
# Final cost : 0.00637064883041237
# Compute control for a deterministic system
# Cost in iteration 0: 0.00637064883041237
# Converged in iteration 451 with cost 0.006370648806611836 because of step counter
# Final cost : 0.006370648806611836
# Compute control for a deterministic system
# Cost in iteration 0: 0.06199176483201406
# Final cost : 0.0035533067562449065
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035533067562449065
# Final cost : 0.0034230381244635282
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034230381244635282
# Final cost : 0.0034209390253109387
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034209390253109387
# Final cost : 0.0034209338726750196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034209338726750196
# Converged in iteration 237 with cost 0.003420933872051709 because of step counter
# Final cost : 0.003420933872051709
# Compute control for a deterministic system
# Cost in iteration 0: 0.03582301735099001
# Final cost : 0.0014653893295134182
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014653893295134182
# Final cost : 0.001396420428350159
# Compute control for a deterministic system
# Cost in iteration 0: 0.001396420428350159
# Final cost : 0.0013956416715548863
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956416715548863
# Final cost : 0.0013956381365705021
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956381365705021
# Converged in iteration 179 with cost 0.0013956381364748664 because of step counter
# Final cost : 0.0013956381364748664
# Compute control for a deterministic system
# Cost in iteration 0: 0.023556458660435067
# Final cost : 0.0004522801901376952
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004522801901376952
# Final cost : 0.0004243071887043175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004243071887043175
# Final cost : 0.00042415316145410175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042415316145410175
# Converged in iteration 252 with cost 0.00042415301430728607 because of step counter
# Final cost : 0.00042415301430728607
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042415301430728607
# Converged in iteration 4 with cost 0.00042415301430727393 because of vanishing difference
# Final cost : 0.00042415301430727393
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.02932895511992517
# Final cost : 0.0013970671564121433
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013970671564121433
# Final cost : 0.0013956391897098342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956391897098342
# Final cost : 0.0013956381365000379
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956381365000379
# Converged in iteration 123 with cost 0.0013956381364742681 because of step counter
# Final cost : 0.0013956381364742681
# Compute control for a deterministic system
# Cost in iteration 0: 0.04648576988440377
# Final cost : 0.0034246152239394445
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034246152239394445
# Final cost : 0.003420945265130246
# Compute control for a deterministic system
# Cost in iteration 0: 0.003420945265130246
# Final cost : 0.0034209338742607867
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034209338742607867
# Converged in iteration 321 with cost 0.003420933872052591 because of step counter
# Final cost : 0.003420933872052591
# Compute control for a deterministic system
# Cost in iteration 0: 0.05308258986976222
# Final cost : 0.0063767506830274484
# Compute control for a deterministic system
# Cost in iteration 0: 0.0063767506830274484
# Final cost : 0.006370664878781761
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370664878781761
# Final cost : 0.006370648809816802
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370648809816802
# Converged in iteration 328 with cost 0.006370648806612798 because of step counter
# Final cost : 0.006370648806612798
# Compute control for a deterministic system
# Cost in iteration 0: 0.04405333601638292
# Final cost : 0.010281688980212643
# Compute control for a deterministic system
# Cost in iteration 0: 0.010281688980212643
# Final cost : 0.010273112279089603
# Compute control for a deterministic system
# Cost in iteration 0: 0.010273112279089603
# Final cost : 0.010272898580361643
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272898580361643
# Converged in iteration 573 with cost 0.01027289846523071 because of vanishing difference
# Final cost : 0.01027289846523071
# Compute control for a deterministic system
# Cost in iteration 0: 0.028856626851272604
# Final cost : 0.014112123361328645
# Compute control for a deterministic system
# Cost in iteration 0: 0.014112123361328645
# Final cost : 0.014103968929509152
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103968929509152
# Final cost : 0.014103656107859616
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103656107859616
# Converged in iteration 691 with cost 0.01410365588560832 because of step counter
# Final cost : 0.01410365588560832
# Compute control for a deterministic system
# Cost in iteration 0: 0.04507710085352584
# Final cost : 0.019837020517258948
# Compute control for a deterministic system
# Cost in iteration 0: 0.019837020517258948
# Final cost : 0.01981694466813316
# Compute control for a deterministic system
# Cost in iteration 0: 0.01981694466813316
# Final cost : 0.019815866746530325
# Compute control for a deterministic system
# Cost in iteration 0: 0.019815866746530325
# Converged in iteration 863 with cost 0.019815865183279064 because of step counter
# Final cost : 0.019815865183279064
# Compute control for a deterministic system
# Cost in iteration 0: 0.09159154167125487
# Final cost : 0.026645822212314926
# Compute control for a deterministic system
# Cost in iteration 0: 0.026645822212314926
# Final cost : 0.026612387830363814
# Compute control for a deterministic system
# Cost in iteration 0: 0.026612387830363814
# Final cost : 0.02660982450318808
# Compute control for a deterministic system
# Cost in iteration 0: 0.02660982450318808
# Final cost : 0.026609817207115683
# Compute control for a deterministic system
# Cost in iteration 0: 0.10820209994698349
# Final cost : 0.034618287072070084
# Compute control for a deterministic system
# Cost in iteration 0: 0.034618287072070084
# Final cost : 0.034567768431285915
# Compute control for a deterministic system
# Cost in iteration 0: 0.034567768431285915
# Final cost : 0.03456308072041604
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456308072041604
# Final cost : 0.034563059846773235
# Compute control for a deterministic system
# Cost in iteration 0: 0.049379889463178214
# Final cost : 0.04187276521154918
# Compute control for a deterministic system
# Cost in iteration 0: 0.04187276521154918
# Final cost : 0.041830788495645206
# Compute control for a deterministic system
# Cost in iteration 0: 0.041830788495645206
# Final cost : 0.04182567193427844
# Compute control for a deterministic system
# Cost in iteration 0: 0.04182567193427844
# Final cost : 0.04182561571827035
# Compute control for a deterministic system
# Cost in iteration 0: 0.08775542399423762
# Final cost : 0.052234024884707866
# Compute control for a deterministic system
# Cost in iteration 0: 0.052234024884707866
# Final cost : 0.05214123025694276
# Compute control for a deterministic system
# Cost in iteration 0: 0.05214123025694276
# Final cost : 0.05212366810157085
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212366810157085
# Final cost : 0.052123303375539456
# Compute control for a deterministic system
# Cost in iteration 0: 0.0995535855829747
# Final cost : 0.06404737844016017
# Compute control for a deterministic system
# Cost in iteration 0: 0.06404737844016017
# Final cost : 0.06391329196136787
# Compute control for a deterministic system
# Cost in iteration 0: 0.06391329196136787
# Final cost : 0.06388183322782542
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388183322782542
# Final cost : 0.06388090151788513
# Compute control for a deterministic system
# Cost in iteration 0: 0.08244553118565236
# Final cost : 0.07454120193598908
# Compute control for a deterministic system
# Cost in iteration 0: 0.07454120193598908
# Final cost : 0.07442601435916603
# Compute control for a deterministic system
# Cost in iteration 0: 0.07442601435916603
# Final cost : 0.07439435768466778
# Compute control for a deterministic system
# Cost in iteration 0: 0.07439435768466778
# Final cost : 0.07439292836742298
# Compute control for a deterministic system
# Cost in iteration 0: 0.09984687381986108
# Final cost : 0.08923698520733123
# Compute control for a deterministic system
# Cost in iteration 0: 0.08923698520733123
# Final cost : 0.08899091588259014
# Compute control for a deterministic system
# Cost in iteration 0: 0.08899091588259014
# Final cost : 0.0889155880020461
# Compute control for a deterministic system
# Cost in iteration 0: 0.0889155880020461
# Final cost : 0.08891055288125913
# Compute control for a deterministic system
# Cost in iteration 0: 0.08935699222718023
# Final cost : 0.08700176431767633
# Compute control for a deterministic system
# Cost in iteration 0: 0.08700176431767633
# Final cost : 0.08698818413126858
# Compute control for a deterministic system
# Cost in iteration 0: 0.08698818413126858
# Final cost : 0.08697713195214755
# Compute control for a deterministic system
# Cost in iteration 0: 0.08697713195214755
# Final cost : 0.08696397058896801
# Compute control for a deterministic system
# Cost in iteration 0: 0.2954198025073548
# Final cost : 0.08634646250148365
# Compute control for a deterministic system
# Cost in iteration 0: 0.08634646250148365
# Final cost : 0.08629945689937125
# Compute control for a deterministic system
# Cost in iteration 0: 0.08629945689937125
# Final cost : 0.08624987584030903
# Compute control for a deterministic system
# Cost in iteration 0: 0.08624987584030903
# Final cost : 0.086197178288289
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514842040262827
# Final cost : 0.08569594959737546
# Compute control for a deterministic system
# Cost in iteration 0: 0.08569594959737546
# Final cost : 0.08564604074297702
# Compute control for a deterministic system
# Cost in iteration 0: 0.08564604074297702
# Final cost : 0.08559623492099831
# Compute control for a deterministic system
# Cost in iteration 0: 0.08559623492099831
# Final cost : 0.08549119251489727
# Compute control for a deterministic system
# Cost in iteration 0: 0.1454735800712015
# Final cost : 0.08446631930202762
# Compute control for a deterministic system
# Cost in iteration 0: 0.08446631930202762
# Final cost : 0.08443909499349246
# Compute control for a deterministic system
# Cost in iteration 0: 0.08443909499349246
# Final cost : 0.08440194998950067
# Compute control for a deterministic system
# Cost in iteration 0: 0.08440194998950067
# Final cost : 0.0843675638192937
# Compute control for a deterministic system
# Cost in iteration 0: 0.34980031279393836
# Final cost : 0.08326987527998932
# Compute control for a deterministic system
# Cost in iteration 0: 0.08326987527998932
# Final cost : 0.08313637777577677
# Compute control for a deterministic system
# Cost in iteration 0: 0.08313637777577677
# Final cost : 0.08292149645385138
# Compute control for a deterministic system
# Cost in iteration 0: 0.08292149645385138
# Final cost : 0.08284598629526226
# Compute control for a deterministic system
# Cost in iteration 0: 0.1189920396084958
# Final cost : 0.08083505301290932
# Compute control for a deterministic system
# Cost in iteration 0: 0.08083505301290932
# Final cost : 0.08081096120677167
# Compute control for a deterministic system
# Cost in iteration 0: 0.08081096120677167
# Final cost : 0.08078298883855235
# Compute control for a deterministic system
# Cost in iteration 0: 0.08078298883855235
# Final cost : 0.08076817436619628
# Compute control for a deterministic system
# Cost in iteration 0: 0.1467659290443415
# Final cost : 0.07876388580291332
# Compute control for a deterministic system
# Cost in iteration 0: 0.07876388580291332
# Final cost : 0.07874953232869417
# Compute control for a deterministic system
# Cost in iteration 0: 0.07874953232869417
# Final cost : 0.0787377089637221
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787377089637221
# Final cost : 0.07872934371544626
# Compute control for a deterministic system
# Cost in iteration 0: 0.47983356156257134
# Final cost : 0.0758210039970489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0758210039970489
# Final cost : 0.07577305374491698
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577305374491698
# Final cost : 0.07574535203772541
# Compute control for a deterministic system
# Cost in iteration 0: 0.07574535203772541
# Final cost : 0.07573410884562583
# Compute control for a deterministic system
# Cost in iteration 0: 0.0820914435160775
# Final cost : 0.072312841355452
# Compute control for a deterministic system
# Cost in iteration 0: 0.072312841355452
# Final cost : 0.0722716679543416
# Compute control for a deterministic system
# Cost in iteration 0: 0.0722716679543416
# Final cost : 0.07224057438282212
# Compute control for a deterministic system
# Cost in iteration 0: 0.07224057438282212
# Final cost : 0.07222317550841155
# Compute control for a deterministic system
# Cost in iteration 0: 0.08948778381574944
# Final cost : 0.06903566701391321
# Compute control for a deterministic system
# Cost in iteration 0: 0.06903566701391321
# Final cost : 0.06898979357861812
# Compute control for a deterministic system
# Cost in iteration 0: 0.06898979357861812
# Final cost : 0.068949568846869
# Compute control for a deterministic system
# Cost in iteration 0: 0.068949568846869
# Final cost : 0.06892222509075954
# Compute control for a deterministic system
# Cost in iteration 0: 0.08522016894110299
# Final cost : 0.06419588923664449
# Compute control for a deterministic system
# Cost in iteration 0: 0.06419588923664449
# Final cost : 0.06406825639267594
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406825639267594
# Final cost : 0.0639509432304457
# Compute control for a deterministic system
# Cost in iteration 0: 0.0639509432304457
# Final cost : 0.06388128206375078
# Compute control for a deterministic system
# Cost in iteration 0: 0.06413356530584018
# Final cost : 0.05801902910415996
# Compute control for a deterministic system
# Cost in iteration 0: 0.05801902910415996
# Final cost : 0.057874248532711815
# Compute control for a deterministic system
# Cost in iteration 0: 0.057874248532711815
# Final cost : 0.05776345440072796
# Compute control for a deterministic system
# Cost in iteration 0: 0.05776345440072796
# Final cost : 0.05773561431449403
# Compute control for a deterministic system
# Cost in iteration 0: 0.08133033766072914
# Final cost : 0.05119262507364203
# Compute control for a deterministic system
# Cost in iteration 0: 0.05119262507364203
# Final cost : 0.051101026763801266
# Compute control for a deterministic system
# Cost in iteration 0: 0.051101026763801266
# Final cost : 0.05106393027111759
# Compute control for a deterministic system
# Cost in iteration 0: 0.05106393027111759
# Final cost : 0.05105832250724025
# Compute control for a deterministic system
# Cost in iteration 0: 0.10609221333574995
# Final cost : 0.04569240375101745
# Compute control for a deterministic system
# Cost in iteration 0: 0.04569240375101745
# Final cost : 0.04565567699888744
# Compute control for a deterministic system
# Cost in iteration 0: 0.04565567699888744
# Final cost : 0.045644537314147283
# Compute control for a deterministic system
# Cost in iteration 0: 0.045644537314147283
# Final cost : 0.04564349989131684
# Compute control for a deterministic system
# Cost in iteration 0: 0.07917154205779262
# Final cost : 0.03904391979353601
# Compute control for a deterministic system
# Cost in iteration 0: 0.03904391979353601
# Final cost : 0.038998237606631334
# Compute control for a deterministic system
# Cost in iteration 0: 0.038998237606631334
# Final cost : 0.038989129923807805
# Compute control for a deterministic system
# Cost in iteration 0: 0.038989129923807805
# Final cost : 0.0389886556748185
# Compute control for a deterministic system
# Cost in iteration 0: 0.09340394024073143
# Final cost : 0.03263980190953535
# Compute control for a deterministic system
# Cost in iteration 0: 0.03263980190953535
# Final cost : 0.032605526810653
# Compute control for a deterministic system
# Cost in iteration 0: 0.032605526810653
# Final cost : 0.03260153527657731
# Compute control for a deterministic system
# Cost in iteration 0: 0.03260153527657731
# Final cost : 0.032601439921336156
# Compute control for a deterministic system
# Cost in iteration 0: 0.035542811220600705
# Final cost : 0.027776946861939832
# Compute control for a deterministic system
# Cost in iteration 0: 0.027776946861939832
# Final cost : 0.02776021788274068
# Compute control for a deterministic system
# Cost in iteration 0: 0.02776021788274068
# Final cost : 0.027758558318919314
# Compute control for a deterministic system
# Cost in iteration 0: 0.027758558318919314
# Final cost : 0.02775853727116025
# Compute control for a deterministic system
# Cost in iteration 0: 0.03720760126924345
# Final cost : 0.022132268814367178
# Compute control for a deterministic system
# Cost in iteration 0: 0.022132268814367178
# Final cost : 0.022112479409470146
# Compute control for a deterministic system
# Cost in iteration 0: 0.022112479409470146
# Final cost : 0.02211114518830348
# Compute control for a deterministic system
# Cost in iteration 0: 0.02211114518830348
# Final cost : 0.022111138753873022
# Compute control for a deterministic system
# Cost in iteration 0: 0.04276111578328361
# Final cost : 0.016997047542637214
# Compute control for a deterministic system
# Cost in iteration 0: 0.016997047542637214
# Final cost : 0.016982946969507674
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982946969507674
# Final cost : 0.016982310349689566
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982310349689566
# Converged in iteration 865 with cost 0.0169823090942168 because of vanishing difference
# Final cost : 0.0169823090942168
# Compute control for a deterministic system
# Cost in iteration 0: 0.03700977797915422
# Final cost : 0.012444066420732999
# Compute control for a deterministic system
# Cost in iteration 0: 0.012444066420732999
# Final cost : 0.012434620677584851
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434620677584851
# Final cost : 0.012434437143508862
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434437143508862
# Converged in iteration 527 with cost 0.012434437062289605 because of step counter
# Final cost : 0.012434437062289605
# Compute control for a deterministic system
# Cost in iteration 0: 0.030447147459642415
# Final cost : 0.009256022038109518
# Compute control for a deterministic system
# Cost in iteration 0: 0.009256022038109518
# Final cost : 0.009251662245524407
# Compute control for a deterministic system
# Cost in iteration 0: 0.009251662245524407
# Final cost : 0.00925165587122986
# Compute control for a deterministic system
# Cost in iteration 0: 0.00925165587122986
# Converged in iteration 233 with cost 0.009251655870356515 because of step counter
# Final cost : 0.009251655870356515
# Compute control for a deterministic system
# Cost in iteration 0: 0.06770622281138251
# Final cost : 0.005890208023796133
# Compute control for a deterministic system
# Cost in iteration 0: 0.005890208023796133
# Final cost : 0.005884522494724228
# Compute control for a deterministic system
# Cost in iteration 0: 0.005884522494724228
# Final cost : 0.005884519848922175
# Compute control for a deterministic system
# Cost in iteration 0: 0.005884519848922175
# Converged in iteration 184 with cost 0.005884519848715225 because of step counter
# Final cost : 0.005884519848715225
# Compute control for a deterministic system
# Cost in iteration 0: 0.059321668715132364
# Final cost : 0.0032428377295725037
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032428377295725037
# Final cost : 0.003238867995340205
# Compute control for a deterministic system
# Cost in iteration 0: 0.003238867995340205
# Final cost : 0.0032388662062942494
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032388662062942494
# Converged in iteration 178 with cost 0.0032388662061446057 because of step counter
# Final cost : 0.0032388662061446057
# Compute control for a deterministic system
# Cost in iteration 0: 0.052174947849806766
# Final cost : 0.0013584436996402858
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013584436996402858
# Final cost : 0.0013555390909698887
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555390909698887
# Final cost : 0.0013555388827282432
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555388827282432
# Converged in iteration 15 with cost 0.0013555388827263873 because of step counter
# Final cost : 0.0013555388827263873
# Compute control for a deterministic system
# Cost in iteration 0: 0.0327255443218936
# Final cost : 0.00042393913127214823
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042393913127214823
# Final cost : 0.0004223422115621806
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004223422115621806
# Converged in iteration 370 with cost 0.00042234213301609025 because of step counter
# Final cost : 0.00042234213301609025
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042234213301609025
# Converged in iteration 1 with cost 0.00042234213301609025 because of step counter
# Final cost : 0.00042234213301609025
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004288671335126292
# Final cost : 0.00042314906707548324
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042314906707548324
# Final cost : 0.0004223430867023765
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004223430867023765
# Final cost : 0.0004223421331197982
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004223421331197982
# Converged in iteration 135 with cost 0.00042234213301618013 because of step counter
# Final cost : 0.00042234213301618013
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042234213301618013
# Converged in iteration 1 with cost 0.00042234213301618013 because of step counter
# Final cost : 0.00042234213301618013
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015971322344715995
# Final cost : 0.0013573134685843972
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013573134685843972
# Final cost : 0.0013555419077063645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555419077063645
# Final cost : 0.0013555388832226425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555388832226425
# Converged in iteration 139 with cost 0.0013555388827263476 because of step counter
# Final cost : 0.0013555388827263476
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013555388827263476
# Converged in iteration 1 with cost 0.0013555388827263476 because of step counter
# Final cost : 0.0013555388827263476
# Compute control for a deterministic system
# Cost in iteration 0: 0.003339593730580125
# Final cost : 0.0032437330993487744
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032437330993487744
# Final cost : 0.0032388748913200027
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032388748913200027
# Final cost : 0.003238866206719238
# Compute control for a deterministic system
# Cost in iteration 0: 0.003238866206719238
# Converged in iteration 91 with cost 0.0032388662061446005 because of step counter
# Final cost : 0.0032388662061446005
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032388662061446005
# Converged in iteration 1 with cost 0.0032388662061446005 because of step counter
# Final cost : 0.0032388662061446005
# Compute control for a deterministic system
# Cost in iteration 0: 0.008280232186162521
# Final cost : 0.005889928573460923
# Compute control for a deterministic system
# Cost in iteration 0: 0.005889928573460923
# Final cost : 0.005884535772283596
# Compute control for a deterministic system
# Cost in iteration 0: 0.005884535772283596
# Final cost : 0.0058845198492420295
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058845198492420295
# Converged in iteration 171 with cost 0.0058845198487159425 because of step counter
# Final cost : 0.0058845198487159425
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058845198487159425
# Converged in iteration 4 with cost 0.005884519848715773 because of step counter
# Final cost : 0.005884519848715773
# Compute control for a deterministic system
# Cost in iteration 0: 0.009631186468780258
# Final cost : 0.009266083255513447
# Compute control for a deterministic system
# Cost in iteration 0: 0.009266083255513447
# Final cost : 0.0092516903697493
# Compute control for a deterministic system
# Cost in iteration 0: 0.0092516903697493
# Final cost : 0.009251655874673774
# Compute control for a deterministic system
# Cost in iteration 0: 0.009251655874673774
# Converged in iteration 288 with cost 0.009251655870355023 because of vanishing difference
# Final cost : 0.009251655870355023
# Compute control for a deterministic system
# Cost in iteration 0: 0.009251655870355023
# Converged in iteration 12 with cost 0.009251655870353719 because of step counter
# Final cost : 0.009251655870353719
# Compute control for a deterministic system
# Cost in iteration 0: 0.013091708895617716
# Final cost : 0.01244665514460627
# Compute control for a deterministic system
# Cost in iteration 0: 0.01244665514460627
# Final cost : 0.012434482928312679
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434482928312679
# Final cost : 0.012434437087464343
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434437087464343
# Converged in iteration 294 with cost 0.012434437062286719 because of vanishing difference
# Final cost : 0.012434437062286719
# Compute control for a deterministic system
# Cost in iteration 0: 0.012434437062286719
# Converged in iteration 7 with cost 0.012434437062286438 because of step counter
# Final cost : 0.012434437062286438
# Compute control for a deterministic system
# Cost in iteration 0: 0.01792404241441018
# Final cost : 0.017002502534268767
# Compute control for a deterministic system
# Cost in iteration 0: 0.017002502534268767
# Final cost : 0.016982384277771195
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982384277771195
# Final cost : 0.016982309239843812
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982309239843812
# Final cost : 0.016982309094265464
# Compute control for a deterministic system
# Cost in iteration 0: 0.016982309094265464
# ...
# Cost in iteration 0: 0.06892277397812585
# Final cost : 0.06891835588900713
# Compute control for a deterministic system
# Cost in iteration 0: 0.06891835588900713
# Final cost : 0.06891815482859505
# Compute control for a deterministic system
# Cost in iteration 0: 0.06891815482859505
# Final cost : 0.06891809145426236
# Compute control for a deterministic system
# Cost in iteration 0: 0.06891809145426236
# Final cost : 0.06891807574890345
# Compute control for a deterministic system
# Cost in iteration 0: 0.12444001224629106
# Final cost : 0.0722207627109157
# Compute control for a deterministic system
# Cost in iteration 0: 0.0722207627109157
# Final cost : 0.07222022237716925
# Compute control for a deterministic system
# Cost in iteration 0: 0.07222022237716925
# Final cost : 0.07222013589736209
# Compute control for a deterministic system
# Cost in iteration 0: 0.07222013589736209
# Final cost : 0.07222009312687697
# Compute control for a deterministic system
# Cost in iteration 0: 0.07222009312687697
# Final cost : 0.07222007984857927
# Compute control for a deterministic system
# Cost in iteration 0: 0.09191043691016443
# Final cost : 0.07573567817610402
# Compute control for a deterministic system
# Cost in iteration 0: 0.07573567817610402
# Final cost : 0.07573390950032532
# Compute control for a deterministic system
# Cost in iteration 0: 0.07573390950032532
# Final cost : 0.07573298887999409
# Compute control for a deterministic system
# Cost in iteration 0: 0.07573298887999409
# Final cost : 0.0757327005039577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0757327005039577
# Final cost : 0.07573264033217539
# Compute control for a deterministic system
# Cost in iteration 0: 0.2048580385783873
# Final cost : 0.0787290291754062
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787290291754062
# Final cost : 0.07872753297475991
# Compute control for a deterministic system
# Cost in iteration 0: 0.07872753297475991
# Final cost : 0.07872719474183845
# Compute control for a deterministic system
# Cost in iteration 0: 0.07872719474183845
# Final cost : 0.07872699482203323
# Compute control for a deterministic system
# Cost in iteration 0: 0.07872699482203323
# Final cost : 0.07872690391234773
# Compute control for a deterministic system
# Cost in iteration 0: 0.18388464121810288
# Final cost : 0.08076647425987576
# Compute control for a deterministic system
# Cost in iteration 0: 0.08076647425987576
# Final cost : 0.08076534326740532
# Compute control for a deterministic system
# Cost in iteration 0: 0.08076534326740532
# Final cost : 0.08076478117839511
# Compute control for a deterministic system
# Cost in iteration 0: 0.08076478117839511
# Final cost : 0.08076446988771543
# Compute control for a deterministic system
# Cost in iteration 0: 0.08076446988771543
# Final cost : 0.08076429912241086
# Compute control for a deterministic system
# Cost in iteration 0: 0.1676504876911038
# Final cost : 0.08288812716855057
# Compute control for a deterministic system
# Cost in iteration 0: 0.08288812716855057
# Final cost : 0.08286789781175224
# Compute control for a deterministic system
# Cost in iteration 0: 0.08286789781175224
# Final cost : 0.0828540804048601
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828540804048601
# Final cost : 0.0828422666389945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0828422666389945
# Final cost : 0.08283048645851807
# Compute control for a deterministic system
# Cost in iteration 0: 0.09738924981767758
# Final cost : 0.08435440039730904
# Compute control for a deterministic system
# Cost in iteration 0: 0.08435440039730904
# Final cost : 0.08435428797826329
# Compute control for a deterministic system
# Cost in iteration 0: 0.08435428797826329
# Final cost : 0.08435420496601455
# Compute control for a deterministic system
# Cost in iteration 0: 0.08435420496601455
# Final cost : 0.08435412297004752
# Compute control for a deterministic system
# Cost in iteration 0: 0.08435412297004752
# Final cost : 0.08435402580550905
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.09214855121049698
# Final cost : 0.08545139066885647
# Compute control for a deterministic system
# Cost in iteration 0: 0.08545139066885647
# Final cost : 0.08545091250310535
# Compute control for a deterministic system
# Cost in iteration 0: 0.08545091250310535
# Final cost : 0.08545063332778165
# Compute control for a deterministic system
# Cost in iteration 0: 0.08545063332778165
# Final cost : 0.08544988708438998
# Compute control for a deterministic system
# Cost in iteration 0: 0.08544988708438998
# Final cost : 0.08544957222318791
# Compute control for a deterministic system
# Cost in iteration 0: 0.14690024942219046
# Final cost : 0.08618551085375473
# Compute control for a deterministic system
# Cost in iteration 0: 0.08618551085375473
# Final cost : 0.08617813611566544
# Compute control for a deterministic system
# Cost in iteration 0: 0.08617813611566544
# Final cost : 0.0861703532295618
# Compute control for a deterministic system
# Cost in iteration 0: 0.0861703532295618
# Final cost : 0.08616427199042351
# Compute control for a deterministic system
# Cost in iteration 0: 0.08616427199042351
# Final cost : 0.08615060642215626
# Compute control for a deterministic system
# Cost in iteration 0: 0.2551714727179333
# Final cost : 0.08696104972849675
# Compute control for a deterministic system
# Cost in iteration 0: 0.08696104972849675
# Final cost : 0.086957700978572
# Compute control for a deterministic system
# Cost in iteration 0: 0.086957700978572
# Final cost : 0.08695647399425938
# Compute control for a deterministic system
# Cost in iteration 0: 0.08695647399425938
# Final cost : 0.0869546334798945
# Compute control for a deterministic system
# Cost in iteration 0: 0.0869546334798945
# Final cost : 0.08694841044327024
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.08782943459663506
# Final cost : 0.08782015463576176
# Compute control for a deterministic system
# Cost in iteration 0: 0.08782015463576176
# Final cost : 0.08781927530377842
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781927530377842
# Final cost : 0.08781851823263899
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781851823263899
# Final cost : 0.08781665759218153
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781665759218153
# Final cost : 0.08781292940019873
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.08485648923592333
# Final cost : 0.07439692343954335
# Compute control for a deterministic system
# Cost in iteration 0: 0.07439692343954335
# Final cost : 0.07439298163440138
# Compute control for a deterministic system
# Cost in iteration 0: 0.07439298163440138
# Final cost : 0.0743929365080516
# Compute control for a deterministic system
# Cost in iteration 0: 0.0743929365080516
# Final cost : 0.07439292678550465
# Compute control for a deterministic system
# Cost in iteration 0: 0.07439292678550465
# Final cost : 0.07439292632102015
# Compute control for a deterministic system
# Cost in iteration 0: 0.07561510247260457
# Final cost : 0.06388546367884354
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388546367884354
# Final cost : 0.06388095407981163
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388095407981163
# Final cost : 0.06388090975946019
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388090975946019
# Final cost : 0.06388090098825089
# Compute control for a deterministic system
# Cost in iteration 0: 0.06388090098825089
# Final cost : 0.0638809008265568
# Compute control for a deterministic system
# Cost in iteration 0: 0.05260559020429856
# Final cost : 0.052123529901543356
# Compute control for a deterministic system
# Cost in iteration 0: 0.052123529901543356
# Final cost : 0.05212330478401568
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212330478401568
# Final cost : 0.05212330347121424
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212330347121424
# Final cost : 0.05212330326803491
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212330326803491
# Converged in iteration 606 with cost 0.052123303263673176 because of step counter
# Final cost : 0.052123303263673176
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.04212644270057951
# Final cost : 0.04182577369293393
# Compute control for a deterministic system
# Cost in iteration 0: 0.04182577369293393
# Final cost : 0.041825616365972165
# Compute control for a deterministic system
# Cost in iteration 0: 0.041825616365972165
# Final cost : 0.041825615785358296
# Compute control for a deterministic system
# Cost in iteration 0: 0.041825615785358296
# Final cost : 0.04182561571422063
# Compute control for a deterministic system
# Cost in iteration 0: 0.04182561571422063
# Converged in iteration 303 with cost 0.04182561571375816 because of vanishing difference
# Final cost : 0.04182561571375816
# Compute control for a deterministic system
# Cost in iteration 0: 0.045430312622062326
# Final cost : 0.03456803927817
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456803927817
# Final cost : 0.03456308590897261
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456308590897261
# Final cost : 0.034563062170621155
# Compute control for a deterministic system
# Cost in iteration 0: 0.034563062170621155
# Final cost : 0.03456305985316392
# Compute control for a deterministic system
# Cost in iteration 0: 0.03456305985316392
# Converged in iteration 502 with cost 0.0345630598464083 because of vanishing difference
# Final cost : 0.0345630598464083
# Compute control for a deterministic system
# Cost in iteration 0: 0.026615768527169983
# Final cost : 0.026609820432742425
# Compute control for a deterministic system
# Cost in iteration 0: 0.026609820432742425
# Final cost : 0.02660981721453018
# Compute control for a deterministic system
# Cost in iteration 0: 0.02660981721453018
# Final cost : 0.02660981720757097
# Compute control for a deterministic system
# Cost in iteration 0: 0.02660981720757097
# Converged in iteration 221 with cost 0.02660981720709691 because of step counter
# Final cost : 0.02660981720709691
# Compute control for a deterministic system
# Cost in iteration 0: 0.02660981720709691
# Converged in iteration 1 with cost 0.02660981720709691 because of step counter
# Final cost : 0.02660981720709691
# Compute control for a deterministic system
# Cost in iteration 0: 0.01981609883452165
# Final cost : 0.019815865315742268
# Compute control for a deterministic system
# Cost in iteration 0: 0.019815865315742268
# Final cost : 0.019815865183460887
# Compute control for a deterministic system
# Cost in iteration 0: 0.019815865183460887
# Converged in iteration 184 with cost 0.01981586518327304 because of step counter
# Final cost : 0.01981586518327304
# Compute control for a deterministic system
# Cost in iteration 0: 0.01981586518327304
# Converged in iteration 1 with cost 0.01981586518327304 because of step counter
# Final cost : 0.01981586518327304
# Compute control for a deterministic system
# Cost in iteration 0: 0.01981586518327304
# Converged in iteration 1 with cost 0.01981586518327304 because of step counter
# Final cost : 0.01981586518327304
# Compute control for a deterministic system
# Cost in iteration 0: 0.0145020429768158
# Final cost : 0.01410389576232866
# Compute control for a deterministic system
# Cost in iteration 0: 0.01410389576232866
# Final cost : 0.014103656089202348
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103656089202348
# Final cost : 0.014103655892195064
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103655892195064
# Converged in iteration 364 with cost 0.014103655885609174 because of step counter
# Final cost : 0.014103655885609174
# Compute control for a deterministic system
# Cost in iteration 0: 0.014103655885609174
# Converged in iteration 1 with cost 0.014103655885609174 because of step counter
# Final cost : 0.014103655885609174
# Compute control for a deterministic system
# Cost in iteration 0: 0.01031719492623669
# Final cost : 0.010272925440302807
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272925440302807
# Final cost : 0.010272898482457427
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272898482457427
# Final cost : 0.010272898465642052
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272898465642052
# Converged in iteration 184 with cost 0.010272898465235065 because of step counter
# Final cost : 0.010272898465235065
# Compute control for a deterministic system
# Cost in iteration 0: 0.010272898465235065
# Converged in iteration 1 with cost 0.010272898465235065 because of step counter
# Final cost : 0.010272898465235065
# Compute control for a deterministic system
# Cost in iteration 0: 0.006810041059163639
# Final cost : 0.006370919829538536
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370919829538536
# Final cost : 0.0063706489500960015
# Compute control for a deterministic system
# Cost in iteration 0: 0.0063706489500960015
# Final cost : 0.006370648808710124
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370648808710124
# Converged in iteration 293 with cost 0.006370648806611121 because of step counter
# Final cost : 0.006370648806611121
# Compute control for a deterministic system
# Cost in iteration 0: 0.006370648806611121
# Converged in iteration 1 with cost 0.006370648806611121 because of step counter
# Final cost : 0.006370648806611121
# Compute control for a deterministic system
# Cost in iteration 0: 0.003532587809155492
# Final cost : 0.003421004585647703
# Compute control for a deterministic system
# Cost in iteration 0: 0.003421004585647703
# Final cost : 0.0034209338905452874
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034209338905452874
# Final cost : 0.0034209338721262195
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034209338721262195
# Converged in iteration 118 with cost 0.003420933872051761 because of step counter
# Final cost : 0.003420933872051761
# Compute control for a deterministic system
# Cost in iteration 0: 0.003420933872051761
# Converged in iteration 1 with cost 0.003420933872051761 because of step counter
# Final cost : 0.003420933872051761
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014493389294111605
# Final cost : 0.0013956725550287811
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956725550287811
# Final cost : 0.0013956381406947898
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956381406947898
# Final cost : 0.001395638136487875
# Compute control for a deterministic system
# Cost in iteration 0: 0.001395638136487875
# Converged in iteration 73 with cost 0.0013956381364741495 because of step counter
# Final cost : 0.0013956381364741495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013956381364741495
# Converged in iteration 1 with cost 0.0013956381364741495 because of step counter
# Final cost : 0.0013956381364741495
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043743146565826006
# Final cost : 0.00042416151408000404
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042416151408000404
# Final cost : 0.0004241530147550049
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004241530147550049
# Converged in iteration 197 with cost 0.0004241530143076875 because of step counter
# Final cost : 0.0004241530143076875
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004241530143076875
# Converged in iteration 16 with cost 0.0004241530143072385 because of step counter
# Final cost : 0.0004241530143072385
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004241530143072385
# Converged in iteration 1 with cost 0.0004241530143072385 because of step counter
# Final cost : 0.0004241530143072385

# %%
save(results_min)
