# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,174], wc.inh[0,174]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  23  211  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor =  (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor =  (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.07393247766740253
# Cost in iteration 200: 0.04770642000336445
# Final cost : 0.04770642000336445
# Compute control for a deterministic system
# Cost in iteration 0: 0.04770642000336445
# Converged in iteration 9 with cost 0.04770635029365166 because of vanishing difference
# Final cost : 0.04770635029365166
# Compute control for a deterministic system
# Cost in iteration 0: 0.04770635029365166
# Converged in iteration 11 with cost 0.04770634760591452 because of step counter
# Final cost : 0.04770634760591452
# Compute control for a deterministic system
# Cost in iteration 0: 0.04770634760591452
# Converged in iteration 1 with cost 0.04770634760591452 because of step counter
# Final cost : 0.04770634760591452
# Compute control for a deterministic system
# Cost in iteration 0: 0.04770634760591452
# Converged in iteration 1 with cost 0.04770634760591452 because of step counter
# Final cost : 0.04770634760591452
# Compute control for a deterministic system
# Cost in iteration 0: 0.11948733298165246
# Cost in iteration 200: 0.07850183006810957
# Final cost : 0.07850183006810957
# Compute control for a deterministic system
# Cost in iteration 0: 0.07850183006810957
# Converged in iteration 31 with cost 0.07849560907844634 because of vanishing difference
# Final cost : 0.07849560907844634
# Compute control for a deterministic system
# Cost in iteration 0: 0.07849560907844634
# Converged in iteration 23 with cost 0.07849560163439001 because of step counter
# Final cost : 0.07849560163439001
# Compute control for a deterministic system
# Cost in iteration 0: 0.07849560163439001
# Converged in iteration 1 with cost 0.07849560163439001 because of step counter
# Final cost : 0.07849560163439001
# Compute control for a deterministic system
# Cost in iteration 0: 0.07849560163439001
# Converged in iteration 1 with cost 0.07849560163439001 because of step counter
# Final cost : 0.07849560163439001
# Compute control for a deterministic system
# Cost in iteration 0: 0.15129192103041894
# Cost in iteration 200: 0.10985890747918324
# Final cost : 0.10985890747918324
# Compute control for a deterministic system
# Cost in iteration 0: 0.10985890747918324
# Converged in iteration 154 with cost 0.10981598874165652 because of step counter
# Final cost : 0.10981598874165652
# Compute control for a deterministic system
# Cost in iteration 0: 0.10981598874165652
# Converged in iteration 7 with cost 0.10981598874165527 because of step counter
# Final cost : 0.10981598874165527
# Compute control for a deterministic system
# Cost in iteration 0: 0.10981598874165527
# Converged in iteration 3 with cost 0.10981598874165507 because of step counter
# Final cost : 0.10981598874165507
# Compute control for a deterministic system
# Cost in iteration 0: 0.10981598874165507
# Converged in iteration 2 with cost 0.10981598874165477 because of step counter
# Final cost : 0.10981598874165477
# Compute control for a deterministic system
# Cost in iteration 0: 0.19136272234836849
# Cost in iteration 200: 0.14152695654030334
# Final cost : 0.14152695654030334
# Compute control for a deterministic system
# Cost in iteration 0: 0.14152695654030334
# Converged in iteration 89 with cost 0.14139201793886697 because of vanishing difference
# Final cost : 0.14139201793886697
# Compute control for a deterministic system
# Cost in iteration 0: 0.14139201793886697
# Converged in iteration 52 with cost 0.14139200093675341 because of step counter
# Final cost : 0.14139200093675341
# Compute control for a deterministic system
# Cost in iteration 0: 0.14139200093675341
# Converged in iteration 2 with cost 0.14139200093675325 because of step counter
# Final cost : 0.14139200093675325
# Compute control for a deterministic system
# Cost in iteration 0: 0.14139200093675325
# Converged in iteration 1 with cost 0.14139200093675325 because of step counter
# Final cost : 0.14139200093675325
# Compute control for a deterministic system
# Cost in iteration 0: 0.20179004933881212
# Cost in iteration 200: 0.16687231421599938
# Final cost : 0.16687231421599938
# Compute control for a deterministic system
# Cost in iteration 0: 0.16687231421599938
# Cost in iteration 200: 0.16671376439671848
# Final cost : 0.16671376439671848
# Compute control for a deterministic system
# Cost in iteration 0: 0.16671376439671848
# Converged in iteration 23 with cost 0.16671376438939267 because of step counter
# Final cost : 0.16671376438939267
# Compute control for a deterministic system
# Cost in iteration 0: 0.16671376438939267
# Converged in iteration 3 with cost 0.16671376438939214 because of step counter
# Final cost : 0.16671376438939214
# Compute control for a deterministic system
# Cost in iteration 0: 0.16671376438939214
# Converged in iteration 1 with cost 0.16671376438939214 because of step counter
# Final cost : 0.16671376438939214
# Compute control for a deterministic system
# Cost in iteration 0: 0.24690495977391091
# Cost in iteration 200: 0.1987092124346066
# Final cost : 0.1987092124346066
# Compute control for a deterministic system
# Cost in iteration 0: 0.1987092124346066
# Cost in iteration 200: 0.1983262371136477
# Final cost : 0.1983262371136477
# Compute control for a deterministic system
# Cost in iteration 0: 0.1983262371136477
# Converged in iteration 87 with cost 0.19832623609257571 because of vanishing difference
# Final cost : 0.19832623609257571
# Compute control for a deterministic system
# Cost in iteration 0: 0.19832623609257571
# Converged in iteration 8 with cost 0.1983262360925736 because of step counter
# Final cost : 0.1983262360925736
# Compute control for a deterministic system
# Cost in iteration 0: 0.1983262360925736
# Converged in iteration 1 with cost 0.1983262360925736 because of step counter
# Final cost : 0.1983262360925736
# Compute control for a deterministic system
# Cost in iteration 0: 0.2981568465999277
# Cost in iteration 200: 0.23036918412715646
# Final cost : 0.23036918412715646
# Compute control for a deterministic system
# Cost in iteration 0: 0.23036918412715646
# Cost in iteration 200: 0.2297874930278988
# Final cost : 0.2297874930278988
# Compute control for a deterministic system
# Cost in iteration 0: 0.2297874930278988
# Converged in iteration 146 with cost 0.22978747030355812 because of vanishing difference
# Final cost : 0.22978747030355812
# Compute control for a deterministic system
# Cost in iteration 0: 0.22978747030355812
# Converged in iteration 7 with cost 0.22978747030355579 because of step counter
# Final cost : 0.22978747030355579
# Compute control for a deterministic system
# Cost in iteration 0: 0.22978747030355579
# Converged in iteration 1 with cost 0.22978747030355579 because of step counter
# Final cost : 0.22978747030355579
# Compute control for a deterministic system
# Cost in iteration 0: 0.3061197552840055
# Cost in iteration 200: 0.26171131747708853
# Final cost : 0.26171131747708853
# Compute control for a deterministic system
# Cost in iteration 0: 0.26171131747708853
# Cost in iteration 200: 0.2609938728605798
# Final cost : 0.2609938728605798
# Compute control for a deterministic system
# Cost in iteration 0: 0.2609938728605798
# Cost in iteration 200: 0.26099365633183375
# Final cost : 0.26099365633183375
# Compute control for a deterministic system
# Cost in iteration 0: 0.26099365633183375
# Converged in iteration 33 with cost 0.2609936563317825 because of step counter
# Final cost : 0.2609936563317825
# Compute control for a deterministic system
# Cost in iteration 0: 0.2609936563317825
# Converged in iteration 1 with cost 0.2609936563317825 because of vanishing difference
# Final cost : 0.2609936563317825
# Compute control for a deterministic system
# Cost in iteration 0: 0.3238821215074415
# Cost in iteration 200: 0.28626510342723654
# Final cost : 0.28626510342723654
# Compute control for a deterministic system
# Cost in iteration 0: 0.28626510342723654
# Cost in iteration 200: 0.28570751821067686
# Final cost : 0.28570751821067686
# Compute control for a deterministic system
# Cost in iteration 0: 0.28570751821067686
# Cost in iteration 200: 0.28570701092692147
# Final cost : 0.28570701092692147
# Compute control for a deterministic system
# Cost in iteration 0: 0.28570701092692147
# Converged in iteration 102 with cost 0.2857070109251064 because of step counter
# Final cost : 0.2857070109251064
# Compute control for a deterministic system
# Cost in iteration 0: 0.2857070109251064
# Converged in iteration 1 with cost 0.2857070109251064 because of step counter
# Final cost : 0.2857070109251064
# Compute control for a deterministic system
# Cost in iteration 0: 0.35143052361102967
# Cost in iteration 200: 0.31715048212117697
# Final cost : 0.31715048212117697
# Compute control for a deterministic system
# Cost in iteration 0: 0.31715048212117697
# Cost in iteration 200: 0.31619859887381047
# Final cost : 0.31619859887381047
# Compute control for a deterministic system
# Cost in iteration 0: 0.31619859887381047
# Converged in iteration 28 with cost 0.3161961458112805 because of vanishing difference
# Final cost : 0.3161961458112805
# Compute control for a deterministic system
# Cost in iteration 0: 0.3161961458112805
# Cost in iteration 200: 0.3161957278280126
# Cost in iteration 400: 0.3161957276997352
# Final cost : 0.3161957276997352
# Compute control for a deterministic system
# Cost in iteration 0: 0.3161957276997352
# Converged in iteration 7 with cost 0.31619572769972304 because of step counter
# Final cost : 0.31619572769972304
# Compute control for a deterministic system
# Cost in iteration 0: 0.37246626379954256
# Cost in iteration 200: 0.3471807156726253
# Final cost : 0.3471807156726253
# Compute control for a deterministic system
# Cost in iteration 0: 0.3471807156726253
# Cost in iteration 200: 0.3461350412147008
# Final cost : 0.3461350412147008
# Compute control for a deterministic system
# Cost in iteration 0: 0.3461350412147008
# Converged in iteration 13 with cost 0.3461299372873373 because of vanishing difference
# Final cost : 0.3461299372873373
# Compute control for a deterministic system
# Cost in iteration 0: 0.3461299372873373
# Converged in iteration 190 with cost 0.34612666972388156 because of vanishing difference
# Final cost : 0.34612666972388156
# Compute control for a deterministic system
# Cost in iteration 0: 0.34612666972388156
# Converged in iteration 3 with cost 0.34612666972387957 because of vanishing difference
# Final cost : 0.34612666972387957
# Compute control for a deterministic system
# Cost in iteration 0: 0.3811553849328292
# Cost in iteration 200: 0.37028305274153556
# Final cost : 0.37028305274153556
# Compute control for a deterministic system
# Cost in iteration 0: 0.37028305274153556
# Cost in iteration 200: 0.3695854464461221
# Final cost : 0.3695854464461221
# Compute control for a deterministic system
# Cost in iteration 0: 0.3695854464461221
# Cost in iteration 200: 0.3695752042915249
# Final cost : 0.3695752042915249
# Compute control for a deterministic system
# Cost in iteration 0: 0.3695752042915249
# Converged in iteration 149 with cost 0.36957518587266924 because of vanishing difference
# Final cost : 0.36957518587266924
# Compute control for a deterministic system
# Cost in iteration 0: 0.36957518587266924
# Converged in iteration 6 with cost 0.36957518587266774 because of step counter
# Final cost : 0.36957518587266774
# Compute control for a deterministic system
# Cost in iteration 0: 0.4603294641496911
# Cost in iteration 200: 0.3994241297344906
# Final cost : 0.3994241297344906
# Compute control for a deterministic system
# Cost in iteration 0: 0.3994241297344906
# Cost in iteration 200: 0.3981438642769166
# Final cost : 0.3981438642769166
# Compute control for a deterministic system
# Cost in iteration 0: 0.3981438642769166
# Cost in iteration 200: 0.39810964237412366
# Final cost : 0.39810964237412366
# Compute control for a deterministic system
# Cost in iteration 0: 0.39810964237412366
# Converged in iteration 191 with cost 0.39810938632025605 because of vanishing difference
# Final cost : 0.39810938632025605
# Compute control for a deterministic system
# Cost in iteration 0: 0.39810938632025605
# Converged in iteration 86 with cost 0.3981093863192149 because of vanishing difference
# Final cost : 0.3981093863192149
# Compute control for a deterministic system
# Cost in iteration 0: 0.45536163743391256
# Cost in iteration 200: 0.42683706075972155
# Final cost : 0.42683706075972155
# Compute control for a deterministic system
# Cost in iteration 0: 0.42683706075972155
# Cost in iteration 200: 0.4255853078994037
# Final cost : 0.4255853078994037
# Compute control for a deterministic system
# Cost in iteration 0: 0.4255853078994037
# Converged in iteration 73 with cost 0.42553582819771496 because of vanishing difference
# Final cost : 0.42553582819771496
# Compute control for a deterministic system
# Cost in iteration 0: 0.42553582819771496
# Cost in iteration 200: 0.4255213530214674
# Cost in iteration 400: 0.42552134860502827
# Final cost : 0.42552134860502827
# Compute control for a deterministic system
# Cost in iteration 0: 0.42552134860502827
# Converged in iteration 134 with cost 0.42552134860400537 because of vanishing difference
# Final cost : 0.42552134860400537
# Compute control for a deterministic system
# Cost in iteration 0: 0.46986118986674374
# Cost in iteration 200: 0.4527454704905525
# Final cost : 0.4527454704905525
# Compute control for a deterministic system
# Cost in iteration 0: 0.4527454704905525
# Cost in iteration 200: 0.45144467619254447
# Final cost : 0.45144467619254447
# Compute control for a deterministic system
# Cost in iteration 0: 0.45144467619254447
# Converged in iteration 126 with cost 0.45133293915834133 because of vanishing difference
# Final cost : 0.45133293915834133
# Compute control for a deterministic system
# Cost in iteration 0: 0.45133293915834133
# Cost in iteration 200: 0.45130726602872256
# Cost in iteration 400: 0.45130655885656773
# Final cost : 0.45130655885656773
# Compute control for a deterministic system
# Cost in iteration 0: 0.45130655885656773
# Cost in iteration 200: 0.4513065381516359
# Cost in iteration 400: 0.45130653649019375
# Cost in iteration 600: 0.4513065363592222
# Cost in iteration 800: 0.451306536348673
# Converged in iteration 889 with cost 0.4513065363480663 because of vanishing difference
# Final cost : 0.4513065363480663
# Compute control for a deterministic system
# Cost in iteration 0: 0.5104993524831509
# Cost in iteration 200: 0.4712100990605987
# Final cost : 0.4712100990605987
# Compute control for a deterministic system
# Cost in iteration 0: 0.4712100990605987
# Cost in iteration 200: 0.470174520066216
# Final cost : 0.470174520066216
# Compute control for a deterministic system
# Cost in iteration 0: 0.470174520066216
# Converged in iteration 48 with cost 0.47001672194736166 because of vanishing difference
# Final cost : 0.47001672194736166
# Compute control for a deterministic system
# Cost in iteration 0: 0.47001672194736166
# Cost in iteration 200: 0.4699125876558944
# Cost in iteration 400: 0.4698897763013178
# Final cost : 0.4698897763013178
# Compute control for a deterministic system
# Cost in iteration 0: 0.4698897763013178
# Cost in iteration 200: 0.46988424387229955
# Cost in iteration 400: 0.46988244800376233
# Cost in iteration 600: 0.46988185042196234
# Cost in iteration 800: 0.46988164845061803
# Cost in iteration 1000: 0.469881578831693
# Final cost : 0.469881578831693
# Compute control for a deterministic system
# Cost in iteration 0: 0.5156491074004108
# Cost in iteration 200: 0.4906302251763977
# Final cost : 0.4906302251763977
# Compute control for a deterministic system
# Cost in iteration 0: 0.4906302251763977
# Cost in iteration 200: 0.4879306823765789
# Final cost : 0.4879306823765789
# Compute control for a deterministic system
# Cost in iteration 0: 0.4879306823765789
# Cost in iteration 200: 0.4868574765004532
# Final cost : 0.4868574765004532
# Compute control for a deterministic system
# Cost in iteration 0: 0.4868574765004532
# Converged in iteration 110 with cost 0.4864794666714107 because of vanishing difference
# Final cost : 0.4864794666714107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4864794666714107
# Cost in iteration 200: 0.48617936274190743
# Cost in iteration 400: 0.4859683898046756
# Cost in iteration 600: 0.48591939500073095
# Cost in iteration 800: 0.4859046857540765
# Cost in iteration 1000: 0.4858991708465001
# Final cost : 0.4858991708465001
# Compute control for a deterministic system
# Cost in iteration 0: 0.5649750771965082
# Cost in iteration 200: 0.4967691699024978
# Final cost : 0.4967691699024978
# Compute control for a deterministic system
# Cost in iteration 0: 0.4967691699024978
# Cost in iteration 200: 0.49627107570038503
# Final cost : 0.49627107570038503
# Compute control for a deterministic system
# Cost in iteration 0: 0.49627107570038503
# Cost in iteration 200: 0.4961088596149409
# Final cost : 0.4961088596149409
# Compute control for a deterministic system
# Cost in iteration 0: 0.4961088596149409
# Cost in iteration 200: 0.4960469115839965
# Cost in iteration 400: 0.4960149465737498
# Final cost : 0.4960149465737498
# Compute control for a deterministic system
# Cost in iteration 0: 0.4960149465737498
# Cost in iteration 200: 0.4959902303969691
# Cost in iteration 400: 0.49597829296007073
# Cost in iteration 600: 0.4959727119272479
# Cost in iteration 800: 0.49596960658317707
# Cost in iteration 1000: 0.49596788077478243
# Final cost : 0.49596788077478243
# Compute control for a deterministic system
# Cost in iteration 0: 0.5129537114659359
# Cost in iteration 200: 0.5021890271598417
# Final cost : 0.5021890271598417
# Compute control for a deterministic system
# Cost in iteration 0: 0.5021890271598417
# Cost in iteration 200: 0.5021018488613908
# Final cost : 0.5021018488613908
# Compute control for a deterministic system
# Cost in iteration 0: 0.5021018488613908
# Cost in iteration 200: 0.5020641404276559
# Final cost : 0.5020641404276559
# Compute control for a deterministic system
# Cost in iteration 0: 0.5020641404276559
# Cost in iteration 200: 0.5020516192596051
# Cost in iteration 400: 0.5020438987877106
# Final cost : 0.5020438987877106
# Compute control for a deterministic system
# Cost in iteration 0: 0.5020438987877106
# Cost in iteration 200: 0.5020394033557963
# Cost in iteration 400: 0.5020316137694162
# Cost in iteration 600: 0.5020283225179368
# Cost in iteration 800: 0.5020275129511085
# Cost in iteration 1000: 0.5020273289429487
# Final cost : 0.5020273289429487
# Compute control for a deterministic system
# Cost in iteration 0: 0.7962234120125893
# Cost in iteration 200: 0.5079035144747797
# Final cost : 0.5079035144747797
# Compute control for a deterministic system
# Cost in iteration 0: 0.5079035144747797
# Cost in iteration 200: 0.5078321233216807
# Final cost : 0.5078321233216807
# Compute control for a deterministic system
# Cost in iteration 0: 0.5078321233216807
# Cost in iteration 200: 0.5077700517785492
# Final cost : 0.5077700517785492
# Compute control for a deterministic system
# Cost in iteration 0: 0.5077700517785492
# Cost in iteration 200: 0.5077619908858144
# Cost in iteration 400: 0.5077567650648481
# Final cost : 0.5077567650648481
# Compute control for a deterministic system
# Cost in iteration 0: 0.5077567650648481
# Cost in iteration 200: 0.5077534494550984
# Cost in iteration 400: 0.5077509106858451
# Cost in iteration 600: 0.5077489488799826
# Cost in iteration 800: 0.5077473978572914
# Cost in iteration 1000: 0.5077461629735313
# Final cost : 0.5077461629735313
# Compute control for a deterministic system
# Cost in iteration 0: 0.5796929740658935
# Cost in iteration 200: 0.5119711659253637
# Final cost : 0.5119711659253637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119711659253637
# Cost in iteration 200: 0.5118988278705069
# Final cost : 0.5118988278705069
# Compute control for a deterministic system
# Cost in iteration 0: 0.5118988278705069
# Cost in iteration 200: 0.5118656017791617
# Final cost : 0.5118656017791617
# Compute control for a deterministic system
# Cost in iteration 0: 0.5118656017791617
# Cost in iteration 200: 0.5118367439556485
# Cost in iteration 400: 0.5118234299266395
# Final cost : 0.5118234299266395
# Compute control for a deterministic system
# Cost in iteration 0: 0.5118234299266395
# Cost in iteration 200: 0.5118184905036283
# Cost in iteration 400: 0.511814905824224
# Cost in iteration 600: 0.5118122437500633
# Cost in iteration 800: 0.5118101814955129
# Cost in iteration 1000: 0.511808524893898
# Final cost : 0.511808524893898
# Compute control for a deterministic system
# Cost in iteration 0: 0.6598317947697137
# Cost in iteration 200: 0.5149096668585276
# Final cost : 0.5149096668585276
# Compute control for a deterministic system
# Cost in iteration 0: 0.5149096668585276
# Cost in iteration 200: 0.5148451694278035
# Final cost : 0.5148451694278035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5148451694278035
# Cost in iteration 200: 0.5148130782817696
# Final cost : 0.5148130782817696
# Compute control for a deterministic system
# Cost in iteration 0: 0.5148130782817696
# Cost in iteration 200: 0.5147921761818158
# Cost in iteration 400: 0.5147769004468734
# Final cost : 0.5147769004468734
# Compute control for a deterministic system
# Cost in iteration 0: 0.5147769004468734
# Cost in iteration 200: 0.5147606946552185
# Cost in iteration 400: 0.5147505769589784
# Cost in iteration 600: 0.5147436360687956
# Cost in iteration 800: 0.5147387638977378
# Cost in iteration 1000: 0.514735214833955
# Final cost : 0.514735214833955
# Compute control for a deterministic system
# Cost in iteration 0: 0.6715610906484193
# Cost in iteration 200: 0.5167079152005731
# Final cost : 0.5167079152005731
# Compute control for a deterministic system
# Cost in iteration 0: 0.5167079152005731
# Cost in iteration 200: 0.516690109071913
# Final cost : 0.516690109071913
# Compute control for a deterministic system
# Cost in iteration 0: 0.516690109071913
# Cost in iteration 200: 0.5166628498655755
# Final cost : 0.5166628498655755
# Compute control for a deterministic system
# Cost in iteration 0: 0.5166628498655755
# Cost in iteration 200: 0.5166538827151972
# Cost in iteration 400: 0.5166472723987052
# Final cost : 0.5166472723987052
# Compute control for a deterministic system
# Cost in iteration 0: 0.5166472723987052
# Cost in iteration 200: 0.5166421824189998
# Cost in iteration 400: 0.5166379733629043
# Cost in iteration 600: 0.5166344724639311
# Cost in iteration 800: 0.5166315458255143
# Cost in iteration 1000: 0.5166290697829129
# Final cost : 0.5166290697829129
# Compute control for a deterministic system
# Cost in iteration 0: 0.6056661275219144
# Cost in iteration 200: 0.4747972950886703
# Final cost : 0.4747972950886703
# Compute control for a deterministic system
# Cost in iteration 0: 0.4747972950886703
# Cost in iteration 200: 0.47217756849558307
# Final cost : 0.47217756849558307
# Compute control for a deterministic system
# Cost in iteration 0: 0.47217756849558307
# Converged in iteration 20 with cost 0.47205465071454245 because of vanishing difference
# Final cost : 0.47205465071454245
# Compute control for a deterministic system
# Cost in iteration 0: 0.47205465071454245
# Cost in iteration 200: 0.4719812036774326
# Cost in iteration 400: 0.471979133021838
# Final cost : 0.471979133021838
# Compute control for a deterministic system
# Cost in iteration 0: 0.471979133021838
# Cost in iteration 200: 0.47197908052106086
# Cost in iteration 400: 0.4719790780411314
# Cost in iteration 600: 0.4719790779253437
# Cost in iteration 800: 0.4719790779199418
# Converged in iteration 859 with cost 0.4719790779197838 because of step counter
# Final cost : 0.4719790779197838
# Compute control for a deterministic system
# Cost in iteration 0: 0.43754325112572057
# Cost in iteration 200: 0.4350061234653308
# Final cost : 0.4350061234653308
# Compute control for a deterministic system
# Cost in iteration 0: 0.4350061234653308
# Cost in iteration 200: 0.43300755712548267
# Final cost : 0.43300755712548267
# Compute control for a deterministic system
# Cost in iteration 0: 0.43300755712548267
# Cost in iteration 200: 0.4329252283745099
# Final cost : 0.4329252283745099
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329252283745099
# Cost in iteration 200: 0.4329239273534924
# Cost in iteration 400: 0.4329239205845523
# Final cost : 0.4329239205845523
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329239205845523
# Cost in iteration 200: 0.4329239205382158
# Converged in iteration 336 with cost 0.43292392053728096 because of vanishing difference
# Final cost : 0.43292392053728096
# Compute control for a deterministic system
# Cost in iteration 0: 0.46209451796522105
# Cost in iteration 200: 0.39717222949997755
# Final cost : 0.39717222949997755
# Compute control for a deterministic system
# Cost in iteration 0: 0.39717222949997755
# Cost in iteration 200: 0.3952663704516315
# Final cost : 0.3952663704516315
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952663704516315
# Converged in iteration 73 with cost 0.3952315491604285 because of vanishing difference
# Final cost : 0.3952315491604285
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952315491604285
# Cost in iteration 200: 0.39522548487408343
# Cost in iteration 400: 0.3952254784058443
# Final cost : 0.3952254784058443
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952254784058443
# Cost in iteration 200: 0.3952254783976106
# Converged in iteration 202 with cost 0.3952254783976084 because of vanishing difference
# Final cost : 0.3952254783976084
# Compute control for a deterministic system
# Cost in iteration 0: 0.4099744324286678
# Cost in iteration 200: 0.36711104796477667
# Final cost : 0.36711104796477667
# Compute control for a deterministic system
# Cost in iteration 0: 0.36711104796477667
# Cost in iteration 200: 0.36603412806032937
# Final cost : 0.36603412806032937
# Compute control for a deterministic system
# Cost in iteration 0: 0.36603412806032937
# Converged in iteration 28 with cost 0.3660254869691932 because of vanishing difference
# Final cost : 0.3660254869691932
# Compute control for a deterministic system
# Cost in iteration 0: 0.3660254869691932
# Cost in iteration 200: 0.36602195767336543
# Cost in iteration 400: 0.3660219566997376
# Final cost : 0.3660219566997376
# Compute control for a deterministic system
# Cost in iteration 0: 0.3660219566997376
# Converged in iteration 65 with cost 0.3660219566995149 because of step counter
# Final cost : 0.3660219566995149
# Compute control for a deterministic system
# Cost in iteration 0: 0.3882997286671453
# Cost in iteration 200: 0.33194315366497706
# Final cost : 0.33194315366497706
# Compute control for a deterministic system
# Cost in iteration 0: 0.33194315366497706
# Cost in iteration 200: 0.3305315214313039
# Final cost : 0.3305315214313039
# Compute control for a deterministic system
# Cost in iteration 0: 0.3305315214313039
# Cost in iteration 200: 0.33052516158068435
# Final cost : 0.33052516158068435
# Compute control for a deterministic system
# Cost in iteration 0: 0.33052516158068435
# Converged in iteration 195 with cost 0.3305251579200479 because of step counter
# Final cost : 0.3305251579200479
# Compute control for a deterministic system
# Cost in iteration 0: 0.3305251579200479
# Converged in iteration 7 with cost 0.33052515792004267 because of vanishing difference
# Final cost : 0.33052515792004267
# Compute control for a deterministic system
# Cost in iteration 0: 0.34603716717824784
# Cost in iteration 200: 0.29708312812594667
# Final cost : 0.29708312812594667
# Compute control for a deterministic system
# Cost in iteration 0: 0.29708312812594667
# Cost in iteration 200: 0.29590741495120854
# Final cost : 0.29590741495120854
# Compute control for a deterministic system
# Cost in iteration 0: 0.29590741495120854
# Cost in iteration 200: 0.29590558669127204
# Final cost : 0.29590558669127204
# Compute control for a deterministic system
# Cost in iteration 0: 0.29590558669127204
# Converged in iteration 99 with cost 0.2959055865801696 because of vanishing difference
# Final cost : 0.2959055865801696
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959055865801696
# Converged in iteration 2 with cost 0.29590558658016874 because of vanishing difference
# Final cost : 0.29590558658016874
# Compute control for a deterministic system
# Cost in iteration 0: 0.2765958154096155
# Cost in iteration 200: 0.2692431357573492
# Final cost : 0.2692431357573492
# Compute control for a deterministic system
# Cost in iteration 0: 0.2692431357573492
# Cost in iteration 200: 0.2686855368633296
# Final cost : 0.2686855368633296
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686855368633296
# Cost in iteration 200: 0.2686853259404758
# Final cost : 0.2686853259404758
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853259404758
# Converged in iteration 42 with cost 0.2686853259395496 because of step counter
# Final cost : 0.2686853259395496
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853259395496
# Converged in iteration 4 with cost 0.2686853259395483 because of vanishing difference
# Final cost : 0.2686853259395483
# Compute control for a deterministic system
# Cost in iteration 0: 0.29712289381953244
# Cost in iteration 200: 0.23591158180183758
# Final cost : 0.23591158180183758
# Compute control for a deterministic system
# Cost in iteration 0: 0.23591158180183758
# Cost in iteration 200: 0.2351037123701183
# Final cost : 0.2351037123701183
# Compute control for a deterministic system
# Cost in iteration 0: 0.2351037123701183
# Converged in iteration 195 with cost 0.23510364088473443 because of vanishing difference
# Final cost : 0.23510364088473443
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510364088473443
# Converged in iteration 2 with cost 0.23510364088473437 because of step counter
# Final cost : 0.23510364088473437
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510364088473437
# Converged in iteration 1 with cost 0.23510364088473437 because of step counter
# Final cost : 0.23510364088473437
# Compute control for a deterministic system
# Cost in iteration 0: 0.22366089531236996
# Cost in iteration 200: 0.2024109398227985
# Final cost : 0.2024109398227985
# Compute control for a deterministic system
# Cost in iteration 0: 0.2024109398227985
# Cost in iteration 200: 0.2019016065715024
# Final cost : 0.2019016065715024
# Compute control for a deterministic system
# Cost in iteration 0: 0.2019016065715024
# Converged in iteration 111 with cost 0.201901604600142 because of vanishing difference
# Final cost : 0.201901604600142
# Compute control for a deterministic system
# Cost in iteration 0: 0.201901604600142
# Converged in iteration 2 with cost 0.2019016046001417 because of step counter
# Final cost : 0.2019016046001417
# Compute control for a deterministic system
# Cost in iteration 0: 0.2019016046001417
# Converged in iteration 1 with cost 0.2019016046001417 because of step counter
# Final cost : 0.2019016046001417
# Compute control for a deterministic system
# Cost in iteration 0: 0.23176106735749064
# Cost in iteration 200: 0.16939766467025685
# Final cost : 0.16939766467025685
# Compute control for a deterministic system
# Cost in iteration 0: 0.16939766467025685
# Converged in iteration 124 with cost 0.16901424234216247 because of vanishing difference
# Final cost : 0.16901424234216247
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901424234216247
# Converged in iteration 99 with cost 0.16901421718515142 because of step counter
# Final cost : 0.16901421718515142
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421718515142
# Converged in iteration 1 with cost 0.16901421718515142 because of step counter
# Final cost : 0.16901421718515142
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421718515142
# Converged in iteration 2 with cost 0.16901421718515133 because of step counter
# Final cost : 0.16901421718515133
# Compute control for a deterministic system
# Cost in iteration 0: 0.1662179085230005
# Cost in iteration 200: 0.14305438146051347
# Final cost : 0.14305438146051347
# Compute control for a deterministic system
# Cost in iteration 0: 0.14305438146051347
# Cost in iteration 200: 0.14292401252834475
# Final cost : 0.14292401252834475
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252834475
# Converged in iteration 10 with cost 0.14292401252825154 because of step counter
# Final cost : 0.14292401252825154
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825154
# Converged in iteration 4 with cost 0.14292401252825082 because of step counter
# Final cost : 0.14292401252825082
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825082
# Converged in iteration 1 with cost 0.14292401252825082 because of step counter
# Final cost : 0.14292401252825082
# -----------------------------------------------
# 0 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.14717552691898272
# Cost in iteration 200: 0.11070942308401312
# Final cost : 0.11070942308401312
# Compute control for a deterministic system
# Cost in iteration 0: 0.11070942308401312
# Converged in iteration 164 with cost 0.11062657824897576 because of step counter
# Final cost : 0.11062657824897576
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897576
# Converged in iteration 5 with cost 0.11062657824897323 because of step counter
# Final cost : 0.11062657824897323
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897323
# Converged in iteration 1 with cost 0.11062657824897323 because of step counter
# Final cost : 0.11062657824897323
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897323
# Converged in iteration 1 with cost 0.11062657824897323 because of step counter
# Final cost : 0.11062657824897323
# Compute control for a deterministic system
# Cost in iteration 0: 0.10724955599925656
# Cost in iteration 200: 0.0788084910489623
# Final cost : 0.0788084910489623
# Compute control for a deterministic system
# Cost in iteration 0: 0.0788084910489623
# Converged in iteration 93 with cost 0.07879423039867814 because of step counter
# Final cost : 0.07879423039867814
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867814
# Converged in iteration 2 with cost 0.07879423039867652 because of vanishing difference
# Final cost : 0.07879423039867652
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867652
# Converged in iteration 4 with cost 0.07879423039867617 because of vanishing difference
# Final cost : 0.07879423039867617
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867617
# Converged in iteration 1 with cost 0.07879423039867617 because of vanishing difference
# Final cost : 0.07879423039867617
# Compute control for a deterministic system
# Cost in iteration 0: 0.09005038249846185
# Cost in iteration 200: 0.04766757113921376
# Final cost : 0.04766757113921376
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766757113921376
# Converged in iteration 39 with cost 0.04766728066807998 because of step counter
# Final cost : 0.04766728066807998
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807998
# Converged in iteration 5 with cost 0.04766728066807775 because of step counter
# Final cost : 0.04766728066807775
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807775
# Converged in iteration 1 with cost 0.04766728066807775 because of step counter
# Final cost : 0.04766728066807775
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807775
# Converged in iteration 1 with cost 0.04766728066807775 because of step counter
# Final cost : 0.04766728066807775
# -----------------------------------------------
# 0 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.05190032644468499
# Cost in iteration 200: 0.023581876011306818
# Final cost : 0.023581876011306818
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876011306818
# Converged in iteration 13 with cost 0.023581876010026082 because of step counter
# Final cost : 0.023581876010026082
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010026082
# Converged in iteration 1 with cost 0.023581876010026082 because of step counter
# Final cost : 0.023581876010026082
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010026082
# Converged in iteration 1 with cost 0.023581876010026082 because of step counter
# Final cost : 0.023581876010026082
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010026082
# Converged in iteration 1 with cost 0.023581876010026082 because of step counter
# Final cost : 0.023581876010026082
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.07421875148318141
# Converged in iteration 60 with cost 0.04766728066807892 because of step counter
# Final cost : 0.04766728066807892
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807892
# Converged in iteration 1 with cost 0.04766728066807892 because of step counter
# Final cost : 0.04766728066807892
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807892
# Converged in iteration 3 with cost 0.04766728066807835 because of step counter
# Final cost : 0.04766728066807835
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807835
# Converged in iteration 1 with cost 0.04766728066807835 because of step counter
# Final cost : 0.04766728066807835
# Compute control for a deterministic system
# Cost in iteration 0: 0.12440575049794082
# Converged in iteration 117 with cost 0.07879423039867627 because of step counter
# Final cost : 0.07879423039867627
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867627
# Converged in iteration 3 with cost 0.07879423039867547 because of step counter
# Final cost : 0.07879423039867547
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867547
# Converged in iteration 1 with cost 0.07879423039867547 because of step counter
# Final cost : 0.07879423039867547
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867547
# Converged in iteration 1 with cost 0.07879423039867547 because of step counter
# Final cost : 0.07879423039867547
# Compute control for a deterministic system
# Cost in iteration 0: 0.15080450550922397
# Converged in iteration 180 with cost 0.11062657824897523 because of step counter
# Final cost : 0.11062657824897523
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897523
# Converged in iteration 7 with cost 0.11062657824897348 because of step counter
# Final cost : 0.11062657824897348
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897348
# Converged in iteration 1 with cost 0.11062657824897348 because of step counter
# Final cost : 0.11062657824897348
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897348
# Converged in iteration 1 with cost 0.11062657824897348 because of step counter
# Final cost : 0.11062657824897348
# Compute control for a deterministic system
# Cost in iteration 0: 0.1758806487012829
# Cost in iteration 200: 0.1429240125289022
# Final cost : 0.1429240125289022
# Compute control for a deterministic system
# Cost in iteration 0: 0.1429240125289022
# Converged in iteration 8 with cost 0.14292401252825254 because of vanishing difference
# Final cost : 0.14292401252825254
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825254
# Converged in iteration 3 with cost 0.14292401252825232 because of vanishing difference
# Final cost : 0.14292401252825232
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825232
# Converged in iteration 4 with cost 0.14292401252825176 because of step counter
# Final cost : 0.14292401252825176
# Compute control for a deterministic system
# Cost in iteration 0: 0.18325911546763757
# Cost in iteration 200: 0.16901421411128772
# Final cost : 0.16901421411128772
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421411128772
# Converged in iteration 40 with cost 0.16901421406248432 because of vanishing difference
# Final cost : 0.16901421406248432
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421406248432
# Converged in iteration 13 with cost 0.16901421406247957 because of vanishing difference
# Final cost : 0.16901421406247957
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421406247957
# Converged in iteration 1 with cost 0.16901421406247957 because of step counter
# Final cost : 0.16901421406247957
# Compute control for a deterministic system
# Cost in iteration 0: 0.2236849232932404
# Cost in iteration 200: 0.2019016087244338
# Final cost : 0.2019016087244338
# Compute control for a deterministic system
# Cost in iteration 0: 0.2019016087244338
# Converged in iteration 130 with cost 0.201901604600141 because of vanishing difference
# Final cost : 0.201901604600141
# Compute control for a deterministic system
# Cost in iteration 0: 0.201901604600141
# Converged in iteration 3 with cost 0.20190160460014042 because of step counter
# Final cost : 0.20190160460014042
# Compute control for a deterministic system
# Cost in iteration 0: 0.20190160460014042
# Converged in iteration 1 with cost 0.20190160460014042 because of step counter
# Final cost : 0.20190160460014042
# Compute control for a deterministic system
# Cost in iteration 0: 0.2613570685667318
# Cost in iteration 200: 0.23510370512258572
# Final cost : 0.23510370512258572
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510370512258572
# Cost in iteration 200: 0.23510363786088884
# Final cost : 0.23510363786088884
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510363786088884
# Converged in iteration 2 with cost 0.23510363786088823 because of vanishing difference
# Final cost : 0.23510363786088823
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510363786088823
# Converged in iteration 3 with cost 0.23510363786088767 because of step counter
# Final cost : 0.23510363786088767
# Compute control for a deterministic system
# Cost in iteration 0: 0.3148144862890844
# Cost in iteration 200: 0.2686858506841652
# Final cost : 0.2686858506841652
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686858506841652
# Cost in iteration 200: 0.2686853259423184
# Final cost : 0.2686853259423184
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853259423184
# Converged in iteration 47 with cost 0.2686853259395651 because of vanishing difference
# Final cost : 0.2686853259395651
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853259395651
# Converged in iteration 19 with cost 0.26868532593954936 because of step counter
# Final cost : 0.26868532593954936
# Compute control for a deterministic system
# Cost in iteration 0: 0.32990238114725656
# Cost in iteration 200: 0.2959067649674734
# Final cost : 0.2959067649674734
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959067649674734
# Cost in iteration 200: 0.2959055489427506
# Final cost : 0.2959055489427506
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959055489427506
# Converged in iteration 99 with cost 0.29590554887188775 because of vanishing difference
# Final cost : 0.29590554887188775
# Compute control for a deterministic system
# Cost in iteration 0: 0.29590554887188775
# Converged in iteration 3 with cost 0.29590554887188675 because of step counter
# Final cost : 0.29590554887188675
# Compute control for a deterministic system
# Cost in iteration 0: 0.4053841797666582
# Cost in iteration 200: 0.33053174002700436
# Final cost : 0.33053174002700436
# Compute control for a deterministic system
# Cost in iteration 0: 0.33053174002700436
# Cost in iteration 200: 0.3305251378559979
# Final cost : 0.3305251378559979
# Compute control for a deterministic system
# Cost in iteration 0: 0.3305251378559979
# Converged in iteration 175 with cost 0.33052513432126657 because of vanishing difference
# Final cost : 0.33052513432126657
# Compute control for a deterministic system
# Cost in iteration 0: 0.33052513432126657
# Converged in iteration 10 with cost 0.33052513432124964 because of vanishing difference
# Final cost : 0.33052513432124964
# Compute control for a deterministic system
# Cost in iteration 0: 0.3833210886060044
# Cost in iteration 200: 0.3660387804477575
# Final cost : 0.3660387804477575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3660387804477575
# Cost in iteration 200: 0.36602195455338643
# Final cost : 0.36602195455338643
# Compute control for a deterministic system
# Cost in iteration 0: 0.36602195455338643
# Cost in iteration 200: 0.3660219079836654
# Converged in iteration 351 with cost 0.3660219079717911 because of step counter
# Final cost : 0.3660219079717911
# Compute control for a deterministic system
# Cost in iteration 0: 0.3660219079717911
# Converged in iteration 1 with cost 0.3660219079717911 because of step counter
# Final cost : 0.3660219079717911
# Compute control for a deterministic system
# Cost in iteration 0: 0.42777994094037014
# Cost in iteration 200: 0.395249253634658
# Final cost : 0.395249253634658
# Compute control for a deterministic system
# Cost in iteration 0: 0.395249253634658
# Cost in iteration 200: 0.39522562716219317
# Final cost : 0.39522562716219317
# Compute control for a deterministic system
# Cost in iteration 0: 0.39522562716219317
# Cost in iteration 200: 0.395225441561351
# Cost in iteration 400: 0.39522544134702775
# Final cost : 0.39522544134702775
# Compute control for a deterministic system
# Cost in iteration 0: 0.39522544134702775
# Converged in iteration 42 with cost 0.39522544134686766 because of vanishing difference
# Final cost : 0.39522544134686766
# Compute control for a deterministic system
# Cost in iteration 0: 0.4822221425917588
# Cost in iteration 200: 0.4330027169869494
# Final cost : 0.4330027169869494
# Compute control for a deterministic system
# Cost in iteration 0: 0.4330027169869494
# Cost in iteration 200: 0.4329254652799201
# Final cost : 0.4329254652799201
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329254652799201
# Cost in iteration 200: 0.432923930613346
# Cost in iteration 400: 0.4329239206036828
# Final cost : 0.4329239206036828
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329239206036828
# Cost in iteration 200: 0.4329239205386041
# Converged in iteration 396 with cost 0.4329239205372289 because of step counter
# Final cost : 0.4329239205372289
# Compute control for a deterministic system
# Cost in iteration 0: 0.480456514544237
# Cost in iteration 200: 0.47213201700283774
# Final cost : 0.47213201700283774
# Compute control for a deterministic system
# Cost in iteration 0: 0.47213201700283774
# Cost in iteration 200: 0.47198113997474334
# Final cost : 0.47198113997474334
# Compute control for a deterministic system
# Cost in iteration 0: 0.47198113997474334
# Cost in iteration 200: 0.4719790869480054
# Cost in iteration 400: 0.4719790401315371
# Final cost : 0.4719790401315371
# Compute control for a deterministic system
# Cost in iteration 0: 0.4719790401315371
# Cost in iteration 200: 0.4719790389698077
# Cost in iteration 400: 0.4719790389155606
# Converged in iteration 501 with cost 0.4719790389134779 because of vanishing difference
# Final cost : 0.4719790389134779
# Compute control for a deterministic system
# Cost in iteration 0: 0.5315576341375039
# Cost in iteration 200: 0.5122747187882645
# Final cost : 0.5122747187882645
# Compute control for a deterministic system
# Cost in iteration 0: 0.5122747187882645
# Cost in iteration 200: 0.5119873940004561
# Final cost : 0.5119873940004561
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119873940004561
# Cost in iteration 200: 0.5119869356354254
# Cost in iteration 400: 0.5119869091004737
# Final cost : 0.5119869091004737
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119869091004737
# Cost in iteration 200: 0.5119869074892198
# Cost in iteration 400: 0.5119869073526198
# Cost in iteration 600: 0.5119869073410258
# Converged in iteration 683 with cost 0.5119869073403392 because of vanishing difference
# Final cost : 0.5119869073403392
# Compute control for a deterministic system
# Cost in iteration 0: 0.547624733751365
# Cost in iteration 200: 0.544291235795985
# Final cost : 0.544291235795985
# Compute control for a deterministic system
# Cost in iteration 0: 0.544291235795985
# Cost in iteration 200: 0.5440209358454579
# Final cost : 0.5440209358454579
# Compute control for a deterministic system
# Cost in iteration 0: 0.5440209358454579
# Cost in iteration 200: 0.5440206208794646
# ...
# Cost in iteration 200: 0.5147324744755941
# Final cost : 0.5147324744755941
# Compute control for a deterministic system
# Cost in iteration 0: 0.5147324744755941
# Converged in iteration 69 with cost 0.5147302257259501 because of vanishing difference
# Final cost : 0.5147302257259501
# Compute control for a deterministic system
# Cost in iteration 0: 0.5147302257259501
# Cost in iteration 200: 0.514727136808287
# Final cost : 0.514727136808287
# Compute control for a deterministic system
# Cost in iteration 0: 0.514727136808287
# Cost in iteration 200: 0.5147253774650768
# Cost in iteration 400: 0.5147240782416075
# Final cost : 0.5147240782416075
# Compute control for a deterministic system
# Cost in iteration 0: 0.5147240782416075
# Cost in iteration 200: 0.5147226398777554
# Cost in iteration 400: 0.5147216332041856
# Cost in iteration 600: 0.5147209357698957
# Cost in iteration 800: 0.5147204336203498
# Cost in iteration 1000: 0.514720072276016
# Final cost : 0.514720072276016
# Compute control for a deterministic system
# Cost in iteration 0: 0.5234569699672487
# Cost in iteration 200: 0.5119910184458447
# Final cost : 0.5119910184458447
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119910184458447
# Cost in iteration 200: 0.5119869543167236
# Final cost : 0.5119869543167236
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119869543167236
# Converged in iteration 191 with cost 0.511986907348055 because of vanishing difference
# Final cost : 0.511986907348055
# Compute control for a deterministic system
# Cost in iteration 0: 0.511986907348055
# Cost in iteration 200: 0.5119869073404394
# Converged in iteration 297 with cost 0.5119869073400757 because of vanishing difference
# Final cost : 0.5119869073400757
# Compute control for a deterministic system
# Cost in iteration 0: 0.5119869073400757
# Converged in iteration 6 with cost 0.5119869073400681 because of vanishing difference
# Final cost : 0.5119869073400681
# Compute control for a deterministic system
# Cost in iteration 0: 0.4763548130476807
# Cost in iteration 200: 0.4719802598214544
# Final cost : 0.4719802598214544
# Compute control for a deterministic system
# Cost in iteration 0: 0.4719802598214544
# Cost in iteration 200: 0.4719790505106612
# Final cost : 0.4719790505106612
# Compute control for a deterministic system
# Cost in iteration 0: 0.4719790505106612
# Cost in iteration 200: 0.4719790389790149
# Final cost : 0.4719790389790149
# Compute control for a deterministic system
# Cost in iteration 0: 0.4719790389790149
# Cost in iteration 200: 0.47197903891448884
# Converged in iteration 340 with cost 0.47197903891302384 because of vanishing difference
# Final cost : 0.47197903891302384
# Compute control for a deterministic system
# Cost in iteration 0: 0.47197903891302384
# Converged in iteration 6 with cost 0.47197903891301435 because of vanishing difference
# Final cost : 0.47197903891301435
# Compute control for a deterministic system
# Cost in iteration 0: 0.44629342692880125
# Cost in iteration 200: 0.43292810160557715
# Final cost : 0.43292810160557715
# Compute control for a deterministic system
# Cost in iteration 0: 0.43292810160557715
# Converged in iteration 98 with cost 0.43292404396372003 because of vanishing difference
# Final cost : 0.43292404396372003
# Compute control for a deterministic system
# Cost in iteration 0: 0.43292404396372003
# Cost in iteration 200: 0.4329239257426067
# Final cost : 0.4329239257426067
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329239257426067
# Cost in iteration 200: 0.4329239240110979
# Cost in iteration 400: 0.4329239240024895
# Final cost : 0.4329239240024895
# Compute control for a deterministic system
# Cost in iteration 0: 0.4329239240024895
# Converged in iteration 11 with cost 0.43292392400247864 because of vanishing difference
# Final cost : 0.43292392400247864
# Compute control for a deterministic system
# Cost in iteration 0: 0.402399343071694
# Cost in iteration 200: 0.3952277589543997
# Final cost : 0.3952277589543997
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952277589543997
# Cost in iteration 200: 0.39522544682959904
# Final cost : 0.39522544682959904
# Compute control for a deterministic system
# Cost in iteration 0: 0.39522544682959904
# Cost in iteration 200: 0.3952254413814616
# Final cost : 0.3952254413814616
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952254413814616
# Converged in iteration 100 with cost 0.3952254413480799 because of vanishing difference
# Final cost : 0.3952254413480799
# Compute control for a deterministic system
# Cost in iteration 0: 0.3952254413480799
# Converged in iteration 113 with cost 0.395225441346863 because of vanishing difference
# Final cost : 0.395225441346863
# Compute control for a deterministic system
# Cost in iteration 0: 0.36616899499776234
# Cost in iteration 200: 0.3660219537173557
# Final cost : 0.3660219537173557
# Compute control for a deterministic system
# Cost in iteration 0: 0.3660219537173557
# Cost in iteration 200: 0.36602190804123913
# Final cost : 0.36602190804123913
# Compute control for a deterministic system
# Cost in iteration 0: 0.36602190804123913
# Cost in iteration 200: 0.36602190797190415
# Final cost : 0.36602190797190415
# Compute control for a deterministic system
# Cost in iteration 0: 0.36602190797190415
# Converged in iteration 56 with cost 0.366021907971777 because of vanishing difference
# Final cost : 0.366021907971777
# Compute control for a deterministic system
# Cost in iteration 0: 0.366021907971777
# Converged in iteration 3 with cost 0.36602190797177575 because of step counter
# Final cost : 0.36602190797177575
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.33057065529859747
# Cost in iteration 200: 0.33052514853756715
# Final cost : 0.33052514853756715
# Compute control for a deterministic system
# Cost in iteration 0: 0.33052514853756715
# Cost in iteration 200: 0.3305251343301664
# Final cost : 0.3305251343301664
# Compute control for a deterministic system
# Cost in iteration 0: 0.3305251343301664
# Converged in iteration 142 with cost 0.33052513432122677 because of vanishing difference
# Final cost : 0.33052513432122677
# Compute control for a deterministic system
# Cost in iteration 0: 0.33052513432122677
# Converged in iteration 7 with cost 0.3305251343212207 because of vanishing difference
# Final cost : 0.3305251343212207
# Compute control for a deterministic system
# Cost in iteration 0: 0.3305251343212207
# Converged in iteration 2 with cost 0.33052513432122 because of step counter
# Final cost : 0.33052513432122
# Compute control for a deterministic system
# Cost in iteration 0: 0.3010737162188143
# Cost in iteration 200: 0.2959072529096025
# Final cost : 0.2959072529096025
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959072529096025
# Cost in iteration 200: 0.2959055492788922
# Final cost : 0.2959055492788922
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959055492788922
# Converged in iteration 175 with cost 0.2959055488719248 because of vanishing difference
# Final cost : 0.2959055488719248
# Compute control for a deterministic system
# Cost in iteration 0: 0.2959055488719248
# Converged in iteration 25 with cost 0.29590554887188264 because of step counter
# Final cost : 0.29590554887188264
# Compute control for a deterministic system
# Cost in iteration 0: 0.29590554887188264
# Converged in iteration 2 with cost 0.2959055488718825 because of step counter
# Final cost : 0.2959055488718825
# Compute control for a deterministic system
# Cost in iteration 0: 0.273351870496642
# Cost in iteration 200: 0.26868683803493904
# Final cost : 0.26868683803493904
# Compute control for a deterministic system
# Cost in iteration 0: 0.26868683803493904
# Cost in iteration 200: 0.2686853260648167
# Final cost : 0.2686853260648167
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853260648167
# Converged in iteration 90 with cost 0.268685325939718 because of vanishing difference
# Final cost : 0.268685325939718
# Compute control for a deterministic system
# Cost in iteration 0: 0.268685325939718
# Converged in iteration 31 with cost 0.2686853259395499 because of vanishing difference
# Final cost : 0.2686853259395499
# Compute control for a deterministic system
# Cost in iteration 0: 0.2686853259395499
# Converged in iteration 2 with cost 0.26868532593954947 because of vanishing difference
# Final cost : 0.26868532593954947
# Compute control for a deterministic system
# Cost in iteration 0: 0.2358068160505059
# Cost in iteration 200: 0.2351038259523501
# Final cost : 0.2351038259523501
# Compute control for a deterministic system
# Cost in iteration 0: 0.2351038259523501
# Cost in iteration 200: 0.23510363786334265
# Final cost : 0.23510363786334265
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510363786334265
# Converged in iteration 42 with cost 0.23510363786089486 because of vanishing difference
# Final cost : 0.23510363786089486
# Compute control for a deterministic system
# Cost in iteration 0: 0.23510363786089486
# Converged in iteration 8 with cost 0.2351036378608849 because of step counter
# Final cost : 0.2351036378608849
# Compute control for a deterministic system
# Cost in iteration 0: 0.2351036378608849
# Converged in iteration 1 with cost 0.2351036378608849 because of step counter
# Final cost : 0.2351036378608849
# Compute control for a deterministic system
# Cost in iteration 0: 0.20294437079931427
# Cost in iteration 200: 0.20190184179131693
# Final cost : 0.20190184179131693
# Compute control for a deterministic system
# Cost in iteration 0: 0.20190184179131693
# Cost in iteration 200: 0.2019016046003984
# Final cost : 0.2019016046003984
# Compute control for a deterministic system
# Cost in iteration 0: 0.2019016046003984
# Converged in iteration 12 with cost 0.20190160460014106 because of step counter
# Final cost : 0.20190160460014106
# Compute control for a deterministic system
# Cost in iteration 0: 0.20190160460014106
# Converged in iteration 1 with cost 0.20190160460014106 because of step counter
# Final cost : 0.20190160460014106
# Compute control for a deterministic system
# Cost in iteration 0: 0.20190160460014106
# Converged in iteration 1 with cost 0.20190160460014106 because of vanishing difference
# Final cost : 0.20190160460014106
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901531285654176
# Cost in iteration 200: 0.1690142142701681
# Final cost : 0.1690142142701681
# Compute control for a deterministic system
# Cost in iteration 0: 0.1690142142701681
# Converged in iteration 125 with cost 0.16901421406248274 because of step counter
# Final cost : 0.16901421406248274
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421406248274
# Converged in iteration 6 with cost 0.16901421406248007 because of vanishing difference
# Final cost : 0.16901421406248007
# Compute control for a deterministic system
# Cost in iteration 0: 0.16901421406248007
# Converged in iteration 3 with cost 0.1690142140624797 because of step counter
# Final cost : 0.1690142140624797
# Compute control for a deterministic system
# Cost in iteration 0: 0.1690142140624797
# Converged in iteration 3 with cost 0.16901421406247952 because of step counter
# Final cost : 0.16901421406247952
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.14393623264265742
# Cost in iteration 200: 0.14292414018987804
# Final cost : 0.14292414018987804
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292414018987804
# Converged in iteration 154 with cost 0.14292401252825773 because of step counter
# Final cost : 0.14292401252825773
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825773
# Converged in iteration 5 with cost 0.14292401252825182 because of vanishing difference
# Final cost : 0.14292401252825182
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825182
# Converged in iteration 2 with cost 0.14292401252825174 because of step counter
# Final cost : 0.14292401252825174
# Compute control for a deterministic system
# Cost in iteration 0: 0.14292401252825174
# Converged in iteration 1 with cost 0.14292401252825174 because of step counter
# Final cost : 0.14292401252825174
# Compute control for a deterministic system
# Cost in iteration 0: 0.11121720526604903
# Cost in iteration 200: 0.11062662247663224
# Final cost : 0.11062662247663224
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062662247663224
# Converged in iteration 117 with cost 0.11062657824897401 because of step counter
# Final cost : 0.11062657824897401
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897401
# Converged in iteration 4 with cost 0.11062657824897343 because of step counter
# Final cost : 0.11062657824897343
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897343
# Converged in iteration 1 with cost 0.11062657824897343 because of step counter
# Final cost : 0.11062657824897343
# Compute control for a deterministic system
# Cost in iteration 0: 0.11062657824897343
# Converged in iteration 1 with cost 0.11062657824897343 because of step counter
# Final cost : 0.11062657824897343
# Compute control for a deterministic system
# Cost in iteration 0: 0.0788218965484683
# Cost in iteration 200: 0.07879423085916688
# Final cost : 0.07879423085916688
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423085916688
# Converged in iteration 48 with cost 0.07879423039867808 because of step counter
# Final cost : 0.07879423039867808
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867808
# Converged in iteration 3 with cost 0.07879423039867607 because of step counter
# Final cost : 0.07879423039867607
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867607
# Converged in iteration 1 with cost 0.07879423039867607 because of step counter
# Final cost : 0.07879423039867607
# Compute control for a deterministic system
# Cost in iteration 0: 0.07879423039867607
# Converged in iteration 4 with cost 0.0787942303986757 because of step counter
# Final cost : 0.0787942303986757
# Compute control for a deterministic system
# Cost in iteration 0: 0.0476673117766991
# Cost in iteration 200: 0.047667280668092865
# Final cost : 0.047667280668092865
# Compute control for a deterministic system
# Cost in iteration 0: 0.047667280668092865
# Converged in iteration 9 with cost 0.047667280668078724 because of step counter
# Final cost : 0.047667280668078724
# Compute control for a deterministic system
# Cost in iteration 0: 0.047667280668078724
# Converged in iteration 1 with cost 0.047667280668078724 because of vanishing difference
# Final cost : 0.047667280668078724
# Compute control for a deterministic system
# Cost in iteration 0: 0.047667280668078724
# Converged in iteration 6 with cost 0.04766728066807814 because of step counter
# Final cost : 0.04766728066807814
# Compute control for a deterministic system
# Cost in iteration 0: 0.04766728066807814
# Converged in iteration 1 with cost 0.04766728066807814 because of step counter
# Final cost : 0.04766728066807814
# Compute control for a deterministic system
# Cost in iteration 0: 0.023584533894336537
# Converged in iteration 160 with cost 0.02358187601002857 because of step counter
# Final cost : 0.02358187601002857
# Compute control for a deterministic system
# Cost in iteration 0: 0.02358187601002857
# Converged in iteration 7 with cost 0.023581876010025878 because of step counter
# Final cost : 0.023581876010025878
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010025878
# Converged in iteration 1 with cost 0.023581876010025878 because of step counter
# Final cost : 0.023581876010025878
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010025878
# Converged in iteration 1 with cost 0.023581876010025878 because of step counter
# Final cost : 0.023581876010025878
# Compute control for a deterministic system
# Cost in iteration 0: 0.023581876010025878
# Converged in iteration 1 with cost 0.023581876010025878 because of step counter
# Final cost : 0.023581876010025878

# %%
save(results_min)
