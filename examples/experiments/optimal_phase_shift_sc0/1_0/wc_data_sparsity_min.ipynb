# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
period = (peaks[-1] - peaks[-2])*dt
print("period = ", period)

wc.run()
init_min = [wc.exc[0,174], wc.inh[0,174]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  18.900000000000002
# minima =  [  23  211  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 80.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w in [0,2]:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95*np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.052387436508805875
# Converged in iteration 1 with cost 0.052387436508805875 because of step counter
# Final cost : 0.052387436508805875
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496401903954418
# Converged in iteration 1 with cost 0.09496401903954418 because of step counter
# Final cost : 0.09496401903954418
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496401903954418
# Converged in iteration 1 with cost 0.09496401903954418 because of step counter
# Final cost : 0.09496401903954418
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496401903954418
# Converged in iteration 1 with cost 0.09496401903954418 because of step counter
# Final cost : 0.09496401903954418
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496401903954418
# Converged in iteration 1 with cost 0.09496401903954418 because of step counter
# Final cost : 0.09496401903954418
# Compute control for a deterministic system
# Cost in iteration 0: 0.09496401903954418
# Converged in iteration 1 with cost 0.09496401903954418 because of step counter
# Final cost : 0.09496401903954418
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332348426023634
# Converged in iteration 1 with cost 0.1332348426023634 because of step counter
# Final cost : 0.1332348426023634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332348426023634
# Converged in iteration 1 with cost 0.1332348426023634 because of step counter
# Final cost : 0.1332348426023634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332348426023634
# Converged in iteration 1 with cost 0.1332348426023634 because of step counter
# Final cost : 0.1332348426023634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332348426023634
# Converged in iteration 1 with cost 0.1332348426023634 because of step counter
# Final cost : 0.1332348426023634
# Compute control for a deterministic system
# Cost in iteration 0: 0.1332348426023634
# Converged in iteration 1 with cost 0.1332348426023634 because of step counter
# Final cost : 0.1332348426023634
# Compute control for a deterministic system
# Cost in iteration 0: 0.18737640714685122
# Converged in iteration 1 with cost 0.18737640714685122 because of step counter
# Final cost : 0.18737640714685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.18737640714685122
# Converged in iteration 1 with cost 0.18737640714685122 because of step counter
# Final cost : 0.18737640714685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.18737640714685122
# Converged in iteration 1 with cost 0.18737640714685122 because of step counter
# Final cost : 0.18737640714685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.18737640714685122
# Converged in iteration 1 with cost 0.18737640714685122 because of step counter
# Final cost : 0.18737640714685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.18737640714685122
# Converged in iteration 1 with cost 0.18737640714685122 because of step counter
# Final cost : 0.18737640714685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.20510294625777808
# Converged in iteration 1 with cost 0.20510294625777808 because of step counter
# Final cost : 0.20510294625777808
# Compute control for a deterministic system
# Cost in iteration 0: 0.20510294625777808
# Converged in iteration 1 with cost 0.20510294625777808 because of step counter
# Final cost : 0.20510294625777808
# Compute control for a deterministic system
# Cost in iteration 0: 0.20510294625777808
# Converged in iteration 1 with cost 0.20510294625777808 because of step counter
# Final cost : 0.20510294625777808
# Compute control for a deterministic system
# Cost in iteration 0: 0.20510294625777808
# Converged in iteration 1 with cost 0.20510294625777808 because of step counter
# Final cost : 0.20510294625777808
# Compute control for a deterministic system
# Cost in iteration 0: 0.20510294625777808
# Converged in iteration 1 with cost 0.20510294625777808 because of step counter
# Final cost : 0.20510294625777808
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336530765786773
# Converged in iteration 1 with cost 0.2336530765786773 because of step counter
# Final cost : 0.2336530765786773
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336530765786773
# Converged in iteration 1 with cost 0.2336530765786773 because of step counter
# Final cost : 0.2336530765786773
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336530765786773
# Converged in iteration 1 with cost 0.2336530765786773 because of step counter
# Final cost : 0.2336530765786773
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336530765786773
# Converged in iteration 1 with cost 0.2336530765786773 because of step counter
# Final cost : 0.2336530765786773
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336530765786773
# Converged in iteration 1 with cost 0.2336530765786773 because of step counter
# Final cost : 0.2336530765786773
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192059767482127
# Converged in iteration 1 with cost 0.3192059767482127 because of step counter
# Final cost : 0.3192059767482127
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192059767482127
# Converged in iteration 1 with cost 0.3192059767482127 because of step counter
# Final cost : 0.3192059767482127
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192059767482127
# Converged in iteration 1 with cost 0.3192059767482127 because of step counter
# Final cost : 0.3192059767482127
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192059767482127
# Converged in iteration 1 with cost 0.3192059767482127 because of step counter
# Final cost : 0.3192059767482127
# Compute control for a deterministic system
# Cost in iteration 0: 0.3192059767482127
# Converged in iteration 1 with cost 0.3192059767482127 because of step counter
# Final cost : 0.3192059767482127
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214311035910808
# Converged in iteration 1 with cost 0.3214311035910808 because of step counter
# Final cost : 0.3214311035910808
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214311035910808
# Converged in iteration 1 with cost 0.3214311035910808 because of step counter
# Final cost : 0.3214311035910808
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214311035910808
# Converged in iteration 1 with cost 0.3214311035910808 because of step counter
# Final cost : 0.3214311035910808
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214311035910808
# Converged in iteration 1 with cost 0.3214311035910808 because of step counter
# Final cost : 0.3214311035910808
# Compute control for a deterministic system
# Cost in iteration 0: 0.3214311035910808
# Converged in iteration 1 with cost 0.3214311035910808 because of step counter
# Final cost : 0.3214311035910808
# Compute control for a deterministic system
# Cost in iteration 0: 0.33608708216303873
# Converged in iteration 1 with cost 0.33608708216303873 because of step counter
# Final cost : 0.33608708216303873
# Compute control for a deterministic system
# Cost in iteration 0: 0.33608708216303873
# Converged in iteration 1 with cost 0.33608708216303873 because of step counter
# Final cost : 0.33608708216303873
# Compute control for a deterministic system
# Cost in iteration 0: 0.33608708216303873
# Converged in iteration 1 with cost 0.33608708216303873 because of step counter
# Final cost : 0.33608708216303873
# Compute control for a deterministic system
# Cost in iteration 0: 0.33608708216303873
# Converged in iteration 1 with cost 0.33608708216303873 because of step counter
# Final cost : 0.33608708216303873
# Compute control for a deterministic system
# Cost in iteration 0: 0.33608708216303873
# Converged in iteration 1 with cost 0.33608708216303873 because of step counter
# Final cost : 0.33608708216303873
# Compute control for a deterministic system
# Cost in iteration 0: 0.4546508965207773
# Converged in iteration 1 with cost 0.4546508965207773 because of step counter
# Final cost : 0.4546508965207773
# Compute control for a deterministic system
# Cost in iteration 0: 0.4546508965207773
# Converged in iteration 1 with cost 0.4546508965207773 because of step counter
# Final cost : 0.4546508965207773
# Compute control for a deterministic system
# Cost in iteration 0: 0.4546508965207773
# Converged in iteration 1 with cost 0.4546508965207773 because of step counter
# Final cost : 0.4546508965207773
# Compute control for a deterministic system
# Cost in iteration 0: 0.4546508965207773
# Converged in iteration 1 with cost 0.4546508965207773 because of step counter
# Final cost : 0.4546508965207773
# Compute control for a deterministic system
# Cost in iteration 0: 0.4546508965207773
# Converged in iteration 1 with cost 0.4546508965207773 because of step counter
# Final cost : 0.4546508965207773
# Compute control for a deterministic system
# Cost in iteration 0: 0.419645233511286
# Converged in iteration 31 with cost 0.4091052289666311 because of step counter
# Final cost : 0.4091052289666311
# Compute control for a deterministic system
# Cost in iteration 0: 0.4091052289666311
# Converged in iteration 1 with cost 0.4091052289666311 because of step counter
# Final cost : 0.4091052289666311
# Compute control for a deterministic system
# Cost in iteration 0: 0.4091052289666311
# Converged in iteration 1 with cost 0.4091052289666311 because of step counter
# Final cost : 0.4091052289666311
# Compute control for a deterministic system
# Cost in iteration 0: 0.4091052289666311
# Converged in iteration 1 with cost 0.4091052289666311 because of step counter
# Final cost : 0.4091052289666311
# Compute control for a deterministic system
# Cost in iteration 0: 0.4091052289666311
# Converged in iteration 1 with cost 0.4091052289666311 because of step counter
# Final cost : 0.4091052289666311
# Compute control for a deterministic system
# Cost in iteration 0: 0.6371328445085576
# Converged in iteration 2 with cost 0.6354347364054193 because of step counter
# Final cost : 0.6354347364054193
# Compute control for a deterministic system
# Cost in iteration 0: 0.6354347364054193
# Converged in iteration 1 with cost 0.6354347364054193 because of step counter
# Final cost : 0.6354347364054193
# Compute control for a deterministic system
# Cost in iteration 0: 0.6354347364054193
# Converged in iteration 1 with cost 0.6354347364054193 because of step counter
# Final cost : 0.6354347364054193
# Compute control for a deterministic system
# Cost in iteration 0: 0.6354347364054193
# Converged in iteration 1 with cost 0.6354347364054193 because of step counter
# Final cost : 0.6354347364054193
# Compute control for a deterministic system
# Cost in iteration 0: 0.6354347364054193
# Converged in iteration 1 with cost 0.6354347364054193 because of step counter
# Final cost : 0.6354347364054193
# Compute control for a deterministic system
# Cost in iteration 0: 0.5151182706672136
# Converged in iteration 70 with cost 0.460566587448045 because of step counter
# Final cost : 0.460566587448045
# Compute control for a deterministic system
# Cost in iteration 0: 0.460566587448045
# Converged in iteration 1 with cost 0.460566587448045 because of step counter
# Final cost : 0.460566587448045
# Compute control for a deterministic system
# Cost in iteration 0: 0.460566587448045
# Converged in iteration 1 with cost 0.460566587448045 because of step counter
# Final cost : 0.460566587448045
# Compute control for a deterministic system
# Cost in iteration 0: 0.460566587448045
# Converged in iteration 1 with cost 0.460566587448045 because of step counter
# Final cost : 0.460566587448045
# Compute control for a deterministic system
# Cost in iteration 0: 0.460566587448045
# Converged in iteration 1 with cost 0.460566587448045 because of step counter
# Final cost : 0.460566587448045
# Compute control for a deterministic system
# Cost in iteration 0: 0.6941284142474634
# Converged in iteration 2 with cost 0.6929658047181491 because of step counter
# Final cost : 0.6929658047181491
# Compute control for a deterministic system
# Cost in iteration 0: 0.6929658047181491
# Converged in iteration 1 with cost 0.6929658047181491 because of step counter
# Final cost : 0.6929658047181491
# Compute control for a deterministic system
# Cost in iteration 0: 0.6929658047181491
# Converged in iteration 1 with cost 0.6929658047181491 because of step counter
# Final cost : 0.6929658047181491
# Compute control for a deterministic system
# Cost in iteration 0: 0.6929658047181491
# Converged in iteration 1 with cost 0.6929658047181491 because of step counter
# Final cost : 0.6929658047181491
# Compute control for a deterministic system
# Cost in iteration 0: 0.6929658047181491
# Converged in iteration 1 with cost 0.6929658047181491 because of step counter
# Final cost : 0.6929658047181491
# Compute control for a deterministic system
# Cost in iteration 0: 0.6087888811171617
# Converged in iteration 2 with cost 0.6082153191982251 because of step counter
# Final cost : 0.6082153191982251
# Compute control for a deterministic system
# Cost in iteration 0: 0.6082153191982251
# Converged in iteration 1 with cost 0.6082153191982251 because of step counter
# Final cost : 0.6082153191982251
# Compute control for a deterministic system
# Cost in iteration 0: 0.6082153191982251
# Converged in iteration 1 with cost 0.6082153191982251 because of step counter
# Final cost : 0.6082153191982251
# Compute control for a deterministic system
# Cost in iteration 0: 0.6082153191982251
# Converged in iteration 1 with cost 0.6082153191982251 because of step counter
# Final cost : 0.6082153191982251
# Compute control for a deterministic system
# Cost in iteration 0: 0.6082153191982251
# Converged in iteration 1 with cost 0.6082153191982251 because of step counter
# Final cost : 0.6082153191982251
# Compute control for a deterministic system
# Cost in iteration 0: 1.5049616115196303
# Cost in iteration 200: 0.5025220438367035
# Final cost : 0.5025220438367035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5025220438367035
# Converged in iteration 1 with cost 0.5025220438367035 because of step counter
# Final cost : 0.5025220438367035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5025220438367035
# Converged in iteration 1 with cost 0.5025220438367035 because of step counter
# Final cost : 0.5025220438367035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5025220438367035
# Converged in iteration 1 with cost 0.5025220438367035 because of step counter
# Final cost : 0.5025220438367035
# Compute control for a deterministic system
# Cost in iteration 0: 0.5025220438367035
# Converged in iteration 1 with cost 0.5025220438367035 because of step counter
# Final cost : 0.5025220438367035
# Compute control for a deterministic system
# Cost in iteration 0: 1.1696659428686587
# Converged in iteration 1 with cost 1.1696659428686587 because of step counter
# Final cost : 1.1696659428686587
# Compute control for a deterministic system
# Cost in iteration 0: 1.1696659428686587
# Converged in iteration 1 with cost 1.1696659428686587 because of step counter
# Final cost : 1.1696659428686587
# Compute control for a deterministic system
# Cost in iteration 0: 1.1696659428686587
# Converged in iteration 1 with cost 1.1696659428686587 because of step counter
# Final cost : 1.1696659428686587
# Compute control for a deterministic system
# Cost in iteration 0: 1.1696659428686587
# Converged in iteration 1 with cost 1.1696659428686587 because of step counter
# Final cost : 1.1696659428686587
# Compute control for a deterministic system
# Cost in iteration 0: 1.1696659428686587
# Converged in iteration 1 with cost 1.1696659428686587 because of step counter
# Final cost : 1.1696659428686587
# Compute control for a deterministic system
# Cost in iteration 0: 0.7873450289535412
# Converged in iteration 46 with cost 0.5343339490506162 because of step counter
# Final cost : 0.5343339490506162
# Compute control for a deterministic system
# Cost in iteration 0: 0.5343339490506162
# Converged in iteration 1 with cost 0.5343339490506162 because of step counter
# Final cost : 0.5343339490506162
# Compute control for a deterministic system
# Cost in iteration 0: 0.5343339490506162
# Converged in iteration 1 with cost 0.5343339490506162 because of step counter
# Final cost : 0.5343339490506162
# Compute control for a deterministic system
# Cost in iteration 0: 0.5343339490506162
# Converged in iteration 1 with cost 0.5343339490506162 because of step counter
# Final cost : 0.5343339490506162
# Compute control for a deterministic system
# Cost in iteration 0: 0.5343339490506162
# Converged in iteration 1 with cost 0.5343339490506162 because of step counter
# Final cost : 0.5343339490506162
# Compute control for a deterministic system
# Cost in iteration 0: 1.3057181207212287
# Cost in iteration 200: 1.2687298445103288
# Final cost : 1.2687298445103288
# Compute control for a deterministic system
# Cost in iteration 0: 1.2687298445103288
# Cost in iteration 200: 1.243964916181381
# Final cost : 1.243964916181381
# Compute control for a deterministic system
# Cost in iteration 0: 1.243964916181381
# Converged in iteration 18 with cost 0.8960164150333583 because of step counter
# Final cost : 0.8960164150333583
# Compute control for a deterministic system
# Cost in iteration 0: 0.8960164150333583
# Converged in iteration 1 with cost 0.8960164150333583 because of step counter
# Final cost : 0.8960164150333583
# Compute control for a deterministic system
# Cost in iteration 0: 0.8960164150333583
# Converged in iteration 1 with cost 0.8960164150333583 because of step counter
# Final cost : 0.8960164150333583
# Compute control for a deterministic system
# Cost in iteration 0: 1.0626770906692085
# Converged in iteration 56 with cost 0.5464812194694224 because of step counter
# Final cost : 0.5464812194694224
# Compute control for a deterministic system
# Cost in iteration 0: 0.5464812194694224
# Converged in iteration 1 with cost 0.5464812194694224 because of step counter
# Final cost : 0.5464812194694224
# Compute control for a deterministic system
# Cost in iteration 0: 0.5464812194694224
# Converged in iteration 1 with cost 0.5464812194694224 because of step counter
# Final cost : 0.5464812194694224
# Compute control for a deterministic system
# Cost in iteration 0: 0.5464812194694224
# Converged in iteration 1 with cost 0.5464812194694224 because of step counter
# Final cost : 0.5464812194694224
# Compute control for a deterministic system
# Cost in iteration 0: 0.5464812194694224
# Converged in iteration 1 with cost 0.5464812194694224 because of step counter
# Final cost : 0.5464812194694224
# Compute control for a deterministic system
# Cost in iteration 0: 0.9014950823648875
# Cost in iteration 200: 0.5371723590548242
# Final cost : 0.5371723590548242
# Compute control for a deterministic system
# Cost in iteration 0: 0.5371723590548242
# Converged in iteration 15 with cost 0.5366220087974807 because of step counter
# Final cost : 0.5366220087974807
# Compute control for a deterministic system
# Cost in iteration 0: 0.5366220087974807
# Converged in iteration 1 with cost 0.5366220087974807 because of step counter
# Final cost : 0.5366220087974807
# Compute control for a deterministic system
# Cost in iteration 0: 0.5366220087974807
# Converged in iteration 1 with cost 0.5366220087974807 because of step counter
# Final cost : 0.5366220087974807
# Compute control for a deterministic system
# Cost in iteration 0: 0.5366220087974807
# Converged in iteration 1 with cost 0.5366220087974807 because of step counter
# Final cost : 0.5366220087974807
# Compute control for a deterministic system
# Cost in iteration 0: 1.0582315644996199
# Cost in iteration 200: 1.0069196432999543
# Final cost : 1.0069196432999543
# Compute control for a deterministic system
# Cost in iteration 0: 1.0069196432999543
# Cost in iteration 200: 0.9947984674203457
# Final cost : 0.9947984674203457
# Compute control for a deterministic system
# Cost in iteration 0: 0.9947984674203457
# Converged in iteration 2 with cost 0.8765798715404948 because of step counter
# Final cost : 0.8765798715404948
# Compute control for a deterministic system
# Cost in iteration 0: 0.8765798715404948
# Converged in iteration 22 with cost 0.6728764691558533 because of step counter
# Final cost : 0.6728764691558533
# Compute control for a deterministic system
# Cost in iteration 0: 0.6728764691558533
# Converged in iteration 1 with cost 0.6728764691558533 because of step counter
# Final cost : 0.6728764691558533
# Compute control for a deterministic system
# Cost in iteration 0: 0.7927683505606667
# Converged in iteration 41 with cost 0.5301974832664201 because of step counter
# Final cost : 0.5301974832664201
# Compute control for a deterministic system
# Cost in iteration 0: 0.5301974832664201
# Converged in iteration 1 with cost 0.5301974832664201 because of step counter
# Final cost : 0.5301974832664201
# Compute control for a deterministic system
# Cost in iteration 0: 0.5301974832664201
# Converged in iteration 1 with cost 0.5301974832664201 because of step counter
# Final cost : 0.5301974832664201
# Compute control for a deterministic system
# Cost in iteration 0: 0.5301974832664201
# Converged in iteration 1 with cost 0.5301974832664201 because of step counter
# Final cost : 0.5301974832664201
# Compute control for a deterministic system
# Cost in iteration 0: 0.5301974832664201
# Converged in iteration 1 with cost 0.5301974832664201 because of step counter
# Final cost : 0.5301974832664201
# Compute control for a deterministic system
# Cost in iteration 0: 0.6190167744200926
# Converged in iteration 3 with cost 0.5483894759071637 because of step counter
# Final cost : 0.5483894759071637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5483894759071637
# Converged in iteration 1 with cost 0.5483894759071637 because of step counter
# Final cost : 0.5483894759071637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5483894759071637
# Converged in iteration 1 with cost 0.5483894759071637 because of step counter
# Final cost : 0.5483894759071637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5483894759071637
# Converged in iteration 1 with cost 0.5483894759071637 because of step counter
# Final cost : 0.5483894759071637
# Compute control for a deterministic system
# Cost in iteration 0: 0.5483894759071637
# Converged in iteration 1 with cost 0.5483894759071637 because of step counter
# Final cost : 0.5483894759071637
# Compute control for a deterministic system
# Cost in iteration 0: 0.472872788914045
# Converged in iteration 22 with cost 0.46875723614111675 because of step counter
# Final cost : 0.46875723614111675
# Compute control for a deterministic system
# Cost in iteration 0: 0.46875723614111675
# Converged in iteration 1 with cost 0.46875723614111675 because of step counter
# Final cost : 0.46875723614111675
# Compute control for a deterministic system
# Cost in iteration 0: 0.46875723614111675
# Converged in iteration 1 with cost 0.46875723614111675 because of step counter
# Final cost : 0.46875723614111675
# Compute control for a deterministic system
# Cost in iteration 0: 0.46875723614111675
# Converged in iteration 1 with cost 0.46875723614111675 because of step counter
# Final cost : 0.46875723614111675
# Compute control for a deterministic system
# Cost in iteration 0: 0.46875723614111675
# Converged in iteration 1 with cost 0.46875723614111675 because of step counter
# Final cost : 0.46875723614111675
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463617586315992
# Converged in iteration 1 with cost 0.4463617586315992 because of step counter
# Final cost : 0.4463617586315992
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463617586315992
# Converged in iteration 1 with cost 0.4463617586315992 because of step counter
# Final cost : 0.4463617586315992
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463617586315992
# Converged in iteration 1 with cost 0.4463617586315992 because of step counter
# Final cost : 0.4463617586315992
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463617586315992
# Converged in iteration 1 with cost 0.4463617586315992 because of step counter
# Final cost : 0.4463617586315992
# Compute control for a deterministic system
# Cost in iteration 0: 0.4463617586315992
# Converged in iteration 1 with cost 0.4463617586315992 because of step counter
# Final cost : 0.4463617586315992
# Compute control for a deterministic system
# Cost in iteration 0: 0.5372136834834925
# Converged in iteration 76 with cost 0.41367853662613685 because of step counter
# Final cost : 0.41367853662613685
# Compute control for a deterministic system
# Cost in iteration 0: 0.41367853662613685
# Converged in iteration 1 with cost 0.41367853662613685 because of step counter
# Final cost : 0.41367853662613685
# Compute control for a deterministic system
# Cost in iteration 0: 0.41367853662613685
# Converged in iteration 1 with cost 0.41367853662613685 because of step counter
# Final cost : 0.41367853662613685
# Compute control for a deterministic system
# Cost in iteration 0: 0.41367853662613685
# Converged in iteration 1 with cost 0.41367853662613685 because of step counter
# Final cost : 0.41367853662613685
# Compute control for a deterministic system
# Cost in iteration 0: 0.41367853662613685
# Converged in iteration 1 with cost 0.41367853662613685 because of step counter
# Final cost : 0.41367853662613685
# Compute control for a deterministic system
# Cost in iteration 0: 0.46020709135137217
# Converged in iteration 112 with cost 0.3584268909748843 because of step counter
# Final cost : 0.3584268909748843
# Compute control for a deterministic system
# Cost in iteration 0: 0.3584268909748843
# Converged in iteration 1 with cost 0.3584268909748843 because of step counter
# Final cost : 0.3584268909748843
# Compute control for a deterministic system
# Cost in iteration 0: 0.3584268909748843
# Converged in iteration 1 with cost 0.3584268909748843 because of step counter
# Final cost : 0.3584268909748843
# Compute control for a deterministic system
# Cost in iteration 0: 0.3584268909748843
# Converged in iteration 1 with cost 0.3584268909748843 because of step counter
# Final cost : 0.3584268909748843
# Compute control for a deterministic system
# Cost in iteration 0: 0.3584268909748843
# Converged in iteration 1 with cost 0.3584268909748843 because of step counter
# Final cost : 0.3584268909748843
# Compute control for a deterministic system
# Cost in iteration 0: 0.4501523722066046
# Converged in iteration 108 with cost 0.3210693577232185 because of step counter
# Final cost : 0.3210693577232185
# Compute control for a deterministic system
# Cost in iteration 0: 0.3210693577232185
# Converged in iteration 1 with cost 0.3210693577232185 because of step counter
# Final cost : 0.3210693577232185
# Compute control for a deterministic system
# Cost in iteration 0: 0.3210693577232185
# Converged in iteration 1 with cost 0.3210693577232185 because of step counter
# Final cost : 0.3210693577232185
# Compute control for a deterministic system
# Cost in iteration 0: 0.3210693577232185
# Converged in iteration 1 with cost 0.3210693577232185 because of step counter
# Final cost : 0.3210693577232185
# Compute control for a deterministic system
# Cost in iteration 0: 0.3210693577232185
# Converged in iteration 1 with cost 0.3210693577232185 because of step counter
# Final cost : 0.3210693577232185
# Compute control for a deterministic system
# Cost in iteration 0: 0.32323281221218453
# Converged in iteration 48 with cost 0.2929435797239996 because of step counter
# Final cost : 0.2929435797239996
# Compute control for a deterministic system
# Cost in iteration 0: 0.2929435797239996
# Converged in iteration 1 with cost 0.2929435797239996 because of step counter
# Final cost : 0.2929435797239996
# Compute control for a deterministic system
# Cost in iteration 0: 0.2929435797239996
# Converged in iteration 1 with cost 0.2929435797239996 because of step counter
# Final cost : 0.2929435797239996
# Compute control for a deterministic system
# Cost in iteration 0: 0.2929435797239996
# Converged in iteration 1 with cost 0.2929435797239996 because of step counter
# Final cost : 0.2929435797239996
# Compute control for a deterministic system
# Cost in iteration 0: 0.2929435797239996
# Converged in iteration 1 with cost 0.2929435797239996 because of step counter
# Final cost : 0.2929435797239996
# Compute control for a deterministic system
# Cost in iteration 0: 0.2719257375340605
# Converged in iteration 40 with cost 0.25432506745702244 because of step counter
# Final cost : 0.25432506745702244
# Compute control for a deterministic system
# Cost in iteration 0: 0.25432506745702244
# Converged in iteration 1 with cost 0.25432506745702244 because of step counter
# Final cost : 0.25432506745702244
# Compute control for a deterministic system
# Cost in iteration 0: 0.25432506745702244
# Converged in iteration 1 with cost 0.25432506745702244 because of step counter
# Final cost : 0.25432506745702244
# Compute control for a deterministic system
# Cost in iteration 0: 0.25432506745702244
# Converged in iteration 1 with cost 0.25432506745702244 because of step counter
# Final cost : 0.25432506745702244
# Compute control for a deterministic system
# Cost in iteration 0: 0.25432506745702244
# Converged in iteration 1 with cost 0.25432506745702244 because of step counter
# Final cost : 0.25432506745702244
# Compute control for a deterministic system
# Cost in iteration 0: 0.22325400605429727
# Converged in iteration 5 with cost 0.22314289683817848 because of step counter
# Final cost : 0.22314289683817848
# Compute control for a deterministic system
# Cost in iteration 0: 0.22314289683817848
# Converged in iteration 1 with cost 0.22314289683817848 because of step counter
# Final cost : 0.22314289683817848
# Compute control for a deterministic system
# Cost in iteration 0: 0.22314289683817848
# Converged in iteration 1 with cost 0.22314289683817848 because of step counter
# Final cost : 0.22314289683817848
# Compute control for a deterministic system
# Cost in iteration 0: 0.22314289683817848
# Converged in iteration 1 with cost 0.22314289683817848 because of step counter
# Final cost : 0.22314289683817848
# Compute control for a deterministic system
# Cost in iteration 0: 0.22314289683817848
# Converged in iteration 1 with cost 0.22314289683817848 because of step counter
# Final cost : 0.22314289683817848
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933174496470753
# Converged in iteration 1 with cost 0.1933174496470753 because of step counter
# Final cost : 0.1933174496470753
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933174496470753
# Converged in iteration 1 with cost 0.1933174496470753 because of step counter
# Final cost : 0.1933174496470753
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933174496470753
# Converged in iteration 1 with cost 0.1933174496470753 because of step counter
# Final cost : 0.1933174496470753
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933174496470753
# Converged in iteration 1 with cost 0.1933174496470753 because of step counter
# Final cost : 0.1933174496470753
# Compute control for a deterministic system
# Cost in iteration 0: 0.1933174496470753
# Converged in iteration 1 with cost 0.1933174496470753 because of step counter
# Final cost : 0.1933174496470753
# Compute control for a deterministic system
# Cost in iteration 0: 0.16745332201138355
# Converged in iteration 36 with cost 0.15608598239299426 because of step counter
# Final cost : 0.15608598239299426
# Compute control for a deterministic system
# Cost in iteration 0: 0.15608598239299426
# Converged in iteration 1 with cost 0.15608598239299426 because of step counter
# Final cost : 0.15608598239299426
# Compute control for a deterministic system
# Cost in iteration 0: 0.15608598239299426
# Converged in iteration 1 with cost 0.15608598239299426 because of step counter
# Final cost : 0.15608598239299426
# Compute control for a deterministic system
# Cost in iteration 0: 0.15608598239299426
# Converged in iteration 1 with cost 0.15608598239299426 because of step counter
# Final cost : 0.15608598239299426
# Compute control for a deterministic system
# Cost in iteration 0: 0.15608598239299426
# Converged in iteration 1 with cost 0.15608598239299426 because of step counter
# Final cost : 0.15608598239299426
# Compute control for a deterministic system
# Cost in iteration 0: 0.1561555384278191
# Converged in iteration 63 with cost 0.11733551032573074 because of step counter
# Final cost : 0.11733551032573074
# Compute control for a deterministic system
# Cost in iteration 0: 0.11733551032573074
# Converged in iteration 1 with cost 0.11733551032573074 because of step counter
# Final cost : 0.11733551032573074
# Compute control for a deterministic system
# Cost in iteration 0: 0.11733551032573074
# Converged in iteration 1 with cost 0.11733551032573074 because of step counter
# Final cost : 0.11733551032573074
# Compute control for a deterministic system
# Cost in iteration 0: 0.11733551032573074
# Converged in iteration 1 with cost 0.11733551032573074 because of step counter
# Final cost : 0.11733551032573074
# Compute control for a deterministic system
# Cost in iteration 0: 0.11733551032573074
# Converged in iteration 1 with cost 0.11733551032573074 because of step counter
# Final cost : 0.11733551032573074
# Compute control for a deterministic system
# Cost in iteration 0: 0.13297897513091972
# Converged in iteration 68 with cost 0.08175814964485029 because of step counter
# Final cost : 0.08175814964485029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08175814964485029
# Converged in iteration 1 with cost 0.08175814964485029 because of step counter
# Final cost : 0.08175814964485029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08175814964485029
# Converged in iteration 1 with cost 0.08175814964485029 because of step counter
# Final cost : 0.08175814964485029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08175814964485029
# Converged in iteration 1 with cost 0.08175814964485029 because of step counter
# Final cost : 0.08175814964485029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08175814964485029
# Converged in iteration 1 with cost 0.08175814964485029 because of step counter
# Final cost : 0.08175814964485029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08011532201944854
# Converged in iteration 56 with cost 0.04519383892908616 because of step counter
# Final cost : 0.04519383892908616
# Compute control for a deterministic system
# Cost in iteration 0: 0.04519383892908616
# Converged in iteration 1 with cost 0.04519383892908616 because of step counter
# Final cost : 0.04519383892908616
# Compute control for a deterministic system
# Cost in iteration 0: 0.04519383892908616
# Converged in iteration 1 with cost 0.04519383892908616 because of step counter
# Final cost : 0.04519383892908616
# Compute control for a deterministic system
# Cost in iteration 0: 0.04519383892908616
# Converged in iteration 1 with cost 0.04519383892908616 because of step counter
# Final cost : 0.04519383892908616
# Compute control for a deterministic system
# Cost in iteration 0: 0.04519383892908616
# Converged in iteration 1 with cost 0.04519383892908616 because of step counter
# Final cost : 0.04519383892908616
# Compute control for a deterministic system
# Cost in iteration 0: 0.03325141901793046
# Converged in iteration 48 with cost 0.01630779269382767 because of step counter
# Final cost : 0.01630779269382767
# Compute control for a deterministic system
# Cost in iteration 0: 0.01630779269382767
# Converged in iteration 1 with cost 0.01630779269382767 because of step counter
# Final cost : 0.01630779269382767
# Compute control for a deterministic system
# Cost in iteration 0: 0.01630779269382767
# Converged in iteration 1 with cost 0.01630779269382767 because of step counter
# Final cost : 0.01630779269382767
# Compute control for a deterministic system
# Cost in iteration 0: 0.01630779269382767
# Converged in iteration 1 with cost 0.01630779269382767 because of step counter
# Final cost : 0.01630779269382767
# Compute control for a deterministic system
# Cost in iteration 0: 0.01630779269382767
# Converged in iteration 1 with cost 0.01630779269382767 because of step counter
# Final cost : 0.01630779269382767
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195651209843073
# Converged in iteration 1 with cost 0.05195651209843073 because of step counter
# Final cost : 0.05195651209843073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0965780021929496
# Converged in iteration 1 with cost 0.0965780021929496 because of step counter
# Final cost : 0.0965780021929496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0965780021929496
# Converged in iteration 1 with cost 0.0965780021929496 because of step counter
# Final cost : 0.0965780021929496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0965780021929496
# Converged in iteration 1 with cost 0.0965780021929496 because of step counter
# Final cost : 0.0965780021929496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0965780021929496
# Converged in iteration 1 with cost 0.0965780021929496 because of step counter
# Final cost : 0.0965780021929496
# Compute control for a deterministic system
# Cost in iteration 0: 0.1268792191876047
# Converged in iteration 1 with cost 0.1268792191876047 because of step counter
# Final cost : 0.1268792191876047
# Compute control for a deterministic system
# Cost in iteration 0: 0.1268792191876047
# Converged in iteration 1 with cost 0.1268792191876047 because of step counter
# Final cost : 0.1268792191876047
# Compute control for a deterministic system
# Cost in iteration 0: 0.1268792191876047
# Converged in iteration 1 with cost 0.1268792191876047 because of step counter
# Final cost : 0.1268792191876047
# Compute control for a deterministic system
# Cost in iteration 0: 0.1268792191876047
# Converged in iteration 1 with cost 0.1268792191876047 because of step counter
# Final cost : 0.1268792191876047
# Compute control for a deterministic system
# Cost in iteration 0: 0.16827540410658942
# Converged in iteration 1 with cost 0.16827540410658942 because of step counter
# Final cost : 0.16827540410658942
# Compute control for a deterministic system
# Cost in iteration 0: 0.16827540410658942
# Converged in iteration 1 with cost 0.16827540410658942 because of step counter
# Final cost : 0.16827540410658942
# Compute control for a deterministic system
# Cost in iteration 0: 0.16827540410658942
# Converged in iteration 1 with cost 0.16827540410658942 because of step counter
# Final cost : 0.16827540410658942
# Compute control for a deterministic system
# Cost in iteration 0: 0.16827540410658942
# Converged in iteration 1 with cost 0.16827540410658942 because of step counter
# Final cost : 0.16827540410658942
# Compute control for a deterministic system
# Cost in iteration 0: 0.20241685953487804
# Converged in iteration 1 with cost 0.20241685953487804 because of step counter
# Final cost : 0.20241685953487804
# Compute control for a deterministic system
# Cost in iteration 0: 0.20241685953487804
# Converged in iteration 1 with cost 0.20241685953487804 because of step counter
# Final cost : 0.20241685953487804
# Compute control for a deterministic system
# Cost in iteration 0: 0.20241685953487804
# Converged in iteration 1 with cost 0.20241685953487804 because of step counter
# Final cost : 0.20241685953487804
# Compute control for a deterministic system
# Cost in iteration 0: 0.20241685953487804
# Converged in iteration 1 with cost 0.20241685953487804 because of step counter
# Final cost : 0.20241685953487804
# Compute control for a deterministic system
# Cost in iteration 0: 0.22941430407184543
# Converged in iteration 1 with cost 0.22941430407184543 because of step counter
# Final cost : 0.22941430407184543
# Compute control for a deterministic system
# Cost in iteration 0: 0.22941430407184543
# Converged in iteration 1 with cost 0.22941430407184543 because of step counter
# Final cost : 0.22941430407184543
# Compute control for a deterministic system
# Cost in iteration 0: 0.22941430407184543
# Converged in iteration 1 with cost 0.22941430407184543 because of step counter
# Final cost : 0.22941430407184543
# Compute control for a deterministic system
# Cost in iteration 0: 0.22941430407184543
# Converged in iteration 1 with cost 0.22941430407184543 because of step counter
# Final cost : 0.22941430407184543
# Compute control for a deterministic system
# Cost in iteration 0: 0.3086607121708975
# Converged in iteration 2 with cost 0.30813881673232635 because of step counter
# Final cost : 0.30813881673232635
# Compute control for a deterministic system
# Cost in iteration 0: 0.30813881673232635
# Converged in iteration 1 with cost 0.30813881673232635 because of step counter
# Final cost : 0.30813881673232635
# Compute control for a deterministic system
# Cost in iteration 0: 0.30813881673232635
# Converged in iteration 1 with cost 0.30813881673232635 because of step counter
# Final cost : 0.30813881673232635
# Compute control for a deterministic system
# Cost in iteration 0: 0.30813881673232635
# Converged in iteration 1 with cost 0.30813881673232635 because of step counter
# Final cost : 0.30813881673232635
# Compute control for a deterministic system
# Cost in iteration 0: 0.38040160461579453
# Converged in iteration 2 with cost 0.37846592065913465 because of step counter
# Final cost : 0.37846592065913465
# Compute control for a deterministic system
# Cost in iteration 0: 0.37846592065913465
# Converged in iteration 1 with cost 0.37846592065913465 because of step counter
# Final cost : 0.37846592065913465
# Compute control for a deterministic system
# Cost in iteration 0: 0.37846592065913465
# Converged in iteration 1 with cost 0.37846592065913465 because of step counter
# Final cost : 0.37846592065913465
# Compute control for a deterministic system
# Cost in iteration 0: 0.37846592065913465
# Converged in iteration 1 with cost 0.37846592065913465 because of step counter
# Final cost : 0.37846592065913465
# Compute control for a deterministic system
# Cost in iteration 0: 0.37529113378490375
# Converged in iteration 3 with cost 0.3752688624439654 because of step counter
# Final cost : 0.3752688624439654
# Compute control for a deterministic system
# Cost in iteration 0: 0.3752688624439654
# Converged in iteration 1 with cost 0.3752688624439654 because of step counter
# Final cost : 0.3752688624439654
# Compute control for a deterministic system
# Cost in iteration 0: 0.3752688624439654
# Converged in iteration 1 with cost 0.3752688624439654 because of step counter
# Final cost : 0.3752688624439654
# Compute control for a deterministic system
# Cost in iteration 0: 0.3752688624439654
# Converged in iteration 1 with cost 0.3752688624439654 because of step counter
# Final cost : 0.3752688624439654
# Compute control for a deterministic system
# Cost in iteration 0: 0.4301850380025344
# Converged in iteration 2 with cost 0.42864415626774366 because of step counter
# Final cost : 0.42864415626774366
# Compute control for a deterministic system
# Cost in iteration 0: 0.42864415626774366
# Converged in iteration 1 with cost 0.42864415626774366 because of step counter
# Final cost : 0.42864415626774366
# Compute control for a deterministic system
# Cost in iteration 0: 0.42864415626774366
# Converged in iteration 1 with cost 0.42864415626774366 because of step counter
# Final cost : 0.42864415626774366
# Compute control for a deterministic system
# Cost in iteration 0: 0.42864415626774366
# Converged in iteration 1 with cost 0.42864415626774366 because of step counter
# Final cost : 0.42864415626774366
# Compute control for a deterministic system
# Cost in iteration 0: 0.41808561764320984
# Converged in iteration 1 with cost 0.41808561764320984 because of step counter
# Final cost : 0.41808561764320984
# Compute control for a deterministic system
# Cost in iteration 0: 0.41808561764320984
# Converged in iteration 1 with cost 0.41808561764320984 because of step counter
# Final cost : 0.41808561764320984
# Compute control for a deterministic system
# Cost in iteration 0: 0.41808561764320984
# Converged in iteration 1 with cost 0.41808561764320984 because of step counter
# Final cost : 0.41808561764320984
# Compute control for a deterministic system
# Cost in iteration 0: 0.41808561764320984
# Converged in iteration 1 with cost 0.41808561764320984 because of step counter
# Final cost : 0.41808561764320984
# Compute control for a deterministic system
# Cost in iteration 0: 0.49716966953678743
# Converged in iteration 3 with cost 0.49716928476052824 because of step counter
# Final cost : 0.49716928476052824
# Compute control for a deterministic system
# Cost in iteration 0: 0.49716928476052824
# Converged in iteration 1 with cost 0.49716928476052824 because of step counter
# Final cost : 0.49716928476052824
# Compute control for a deterministic system
# Cost in iteration 0: 0.49716928476052824
# Converged in iteration 1 with cost 0.49716928476052824 because of step counter
# Final cost : 0.49716928476052824
# Compute control for a deterministic system
# Cost in iteration 0: 0.49716928476052824
# Converged in iteration 1 with cost 0.49716928476052824 because of step counter
# Final cost : 0.49716928476052824
# Compute control for a deterministic system
# Cost in iteration 0: 0.49022313985998284
# Converged in iteration 1 with cost 0.49022313985998284 because of step counter
# Final cost : 0.49022313985998284
# Compute control for a deterministic system
# Cost in iteration 0: 0.49022313985998284
# Converged in iteration 1 with cost 0.49022313985998284 because of step counter
# Final cost : 0.49022313985998284
# Compute control for a deterministic system
# Cost in iteration 0: 0.49022313985998284
# Converged in iteration 1 with cost 0.49022313985998284 because of step counter
# Final cost : 0.49022313985998284
# Compute control for a deterministic system
# Cost in iteration 0: 0.49022313985998284
# Converged in iteration 1 with cost 0.49022313985998284 because of step counter
# Final cost : 0.49022313985998284
# Compute control for a deterministic system
# Cost in iteration 0: 0.5132522329154667
# Converged in iteration 4 with cost 0.510006424336107 because of step counter
# Final cost : 0.510006424336107
# Compute control for a deterministic system
# Cost in iteration 0: 0.510006424336107
# Converged in iteration 1 with cost 0.510006424336107 because of step counter
# Final cost : 0.510006424336107
# Compute control for a deterministic system
# Cost in iteration 0: 0.510006424336107
# Converged in iteration 1 with cost 0.510006424336107 because of step counter
# Final cost : 0.510006424336107
# Compute control for a deterministic system
# Cost in iteration 0: 0.510006424336107
# Converged in iteration 1 with cost 0.510006424336107 because of step counter
# Final cost : 0.510006424336107
# Compute control for a deterministic system
# Cost in iteration 0: 0.5920008848734746
# Converged in iteration 1 with cost 0.5920008848734746 because of step counter
# Final cost : 0.5920008848734746
# Compute control for a deterministic system
# Cost in iteration 0: 0.5920008848734746
# ...
# Converged in iteration 1 with cost 0.5324134529429829 because of step counter
# Final cost : 0.5324134529429829
# Compute control for a deterministic system
# Cost in iteration 0: 0.5324134529429829
# Converged in iteration 1 with cost 0.5324134529429829 because of step counter
# Final cost : 0.5324134529429829
# Compute control for a deterministic system
# Cost in iteration 0: 0.5324134529429829
# Converged in iteration 1 with cost 0.5324134529429829 because of step counter
# Final cost : 0.5324134529429829
# Compute control for a deterministic system
# Cost in iteration 0: 0.8022191363934306
# Converged in iteration 30 with cost 0.5416702167096518 because of step counter
# Final cost : 0.5416702167096518
# Compute control for a deterministic system
# Cost in iteration 0: 0.5416702167096518
# Converged in iteration 1 with cost 0.5416702167096518 because of step counter
# Final cost : 0.5416702167096518
# Compute control for a deterministic system
# Cost in iteration 0: 0.5416702167096518
# Converged in iteration 1 with cost 0.5416702167096518 because of step counter
# Final cost : 0.5416702167096518
# Compute control for a deterministic system
# Cost in iteration 0: 0.5416702167096518
# Converged in iteration 1 with cost 0.5416702167096518 because of step counter
# Final cost : 0.5416702167096518
# Compute control for a deterministic system
# Cost in iteration 0: 0.5416702167096518
# Converged in iteration 1 with cost 0.5416702167096518 because of step counter
# Final cost : 0.5416702167096518
# Compute control for a deterministic system
# Cost in iteration 0: 0.6441897670340556
# Cost in iteration 200: 0.5522584383286884
# Final cost : 0.5522584383286884
# Compute control for a deterministic system
# Cost in iteration 0: 0.5522584383286884
# Converged in iteration 11 with cost 0.5494169463611361 because of step counter
# Final cost : 0.5494169463611361
# Compute control for a deterministic system
# Cost in iteration 0: 0.5494169463611361
# Converged in iteration 3 with cost 0.546124415416553 because of step counter
# Final cost : 0.546124415416553
# Compute control for a deterministic system
# Cost in iteration 0: 0.546124415416553
# Converged in iteration 1 with cost 0.546124415416553 because of step counter
# Final cost : 0.546124415416553
# Compute control for a deterministic system
# Cost in iteration 0: 0.546124415416553
# Converged in iteration 1 with cost 0.546124415416553 because of step counter
# Final cost : 0.546124415416553
# Compute control for a deterministic system
# Cost in iteration 0: 0.649898603197377
# Cost in iteration 200: 0.5233995289905597
# Final cost : 0.5233995289905597
# Compute control for a deterministic system
# Cost in iteration 0: 0.5233995289905597
# Converged in iteration 10 with cost 0.5204482222200968 because of step counter
# Final cost : 0.5204482222200968
# Compute control for a deterministic system
# Cost in iteration 0: 0.5204482222200968
# Converged in iteration 3 with cost 0.5156249799385831 because of step counter
# Final cost : 0.5156249799385831
# Compute control for a deterministic system
# Cost in iteration 0: 0.5156249799385831
# Converged in iteration 1 with cost 0.5156249799385831 because of step counter
# Final cost : 0.5156249799385831
# Compute control for a deterministic system
# Cost in iteration 0: 0.5156249799385831
# Converged in iteration 1 with cost 0.5156249799385831 because of step counter
# Final cost : 0.5156249799385831
# Compute control for a deterministic system
# Cost in iteration 0: 0.6511681226290569
# Cost in iteration 200: 0.49829399950176734
# Final cost : 0.49829399950176734
# Compute control for a deterministic system
# Cost in iteration 0: 0.49829399950176734
# Converged in iteration 8 with cost 0.4957649222953483 because of step counter
# Final cost : 0.4957649222953483
# Compute control for a deterministic system
# Cost in iteration 0: 0.4957649222953483
# Converged in iteration 3 with cost 0.4899866453945203 because of step counter
# Final cost : 0.4899866453945203
# Compute control for a deterministic system
# Cost in iteration 0: 0.4899866453945203
# Converged in iteration 1 with cost 0.4899866453945203 because of step counter
# Final cost : 0.4899866453945203
# Compute control for a deterministic system
# Cost in iteration 0: 0.4899866453945203
# Converged in iteration 1 with cost 0.4899866453945203 because of step counter
# Final cost : 0.4899866453945203
# Compute control for a deterministic system
# Cost in iteration 0: 0.5128844968349944
# Converged in iteration 170 with cost 0.47995990859388044 because of step counter
# Final cost : 0.47995990859388044
# Compute control for a deterministic system
# Cost in iteration 0: 0.47995990859388044
# Converged in iteration 2 with cost 0.4797943067887897 because of step counter
# Final cost : 0.4797943067887897
# Compute control for a deterministic system
# Cost in iteration 0: 0.4797943067887897
# Converged in iteration 3 with cost 0.47107446444481166 because of step counter
# Final cost : 0.47107446444481166
# Compute control for a deterministic system
# Cost in iteration 0: 0.47107446444481166
# Converged in iteration 1 with cost 0.47107446444481166 because of step counter
# Final cost : 0.47107446444481166
# Compute control for a deterministic system
# Cost in iteration 0: 0.47107446444481166
# Converged in iteration 1 with cost 0.47107446444481166 because of step counter
# Final cost : 0.47107446444481166
# Compute control for a deterministic system
# Cost in iteration 0: 0.4638729109032698
# Converged in iteration 138 with cost 0.4497142846562029 because of step counter
# Final cost : 0.4497142846562029
# Compute control for a deterministic system
# Cost in iteration 0: 0.4497142846562029
# Converged in iteration 2 with cost 0.4495139176432788 because of step counter
# Final cost : 0.4495139176432788
# Compute control for a deterministic system
# Cost in iteration 0: 0.4495139176432788
# Converged in iteration 3 with cost 0.44068849744457333 because of step counter
# Final cost : 0.44068849744457333
# Compute control for a deterministic system
# Cost in iteration 0: 0.44068849744457333
# Converged in iteration 1 with cost 0.44068849744457333 because of step counter
# Final cost : 0.44068849744457333
# Compute control for a deterministic system
# Cost in iteration 0: 0.44068849744457333
# Converged in iteration 1 with cost 0.44068849744457333 because of step counter
# Final cost : 0.44068849744457333
# Compute control for a deterministic system
# Cost in iteration 0: 0.37536745865953813
# Converged in iteration 1 with cost 0.37536745865953813 because of step counter
# Final cost : 0.37536745865953813
# Compute control for a deterministic system
# Cost in iteration 0: 0.37536745865953813
# Converged in iteration 1 with cost 0.37536745865953813 because of step counter
# Final cost : 0.37536745865953813
# Compute control for a deterministic system
# Cost in iteration 0: 0.37536745865953813
# Converged in iteration 1 with cost 0.37536745865953813 because of step counter
# Final cost : 0.37536745865953813
# Compute control for a deterministic system
# Cost in iteration 0: 0.37536745865953813
# Converged in iteration 1 with cost 0.37536745865953813 because of step counter
# Final cost : 0.37536745865953813
# Compute control for a deterministic system
# Cost in iteration 0: 0.37536745865953813
# Converged in iteration 1 with cost 0.37536745865953813 because of step counter
# Final cost : 0.37536745865953813
# Compute control for a deterministic system
# Cost in iteration 0: 0.3501041038935917
# Converged in iteration 1 with cost 0.3501041038935917 because of step counter
# Final cost : 0.3501041038935917
# Compute control for a deterministic system
# Cost in iteration 0: 0.3501041038935917
# Converged in iteration 1 with cost 0.3501041038935917 because of step counter
# Final cost : 0.3501041038935917
# Compute control for a deterministic system
# Cost in iteration 0: 0.3501041038935917
# Converged in iteration 1 with cost 0.3501041038935917 because of step counter
# Final cost : 0.3501041038935917
# Compute control for a deterministic system
# Cost in iteration 0: 0.3501041038935917
# Converged in iteration 1 with cost 0.3501041038935917 because of step counter
# Final cost : 0.3501041038935917
# Compute control for a deterministic system
# Cost in iteration 0: 0.3501041038935917
# Converged in iteration 1 with cost 0.3501041038935917 because of step counter
# Final cost : 0.3501041038935917
# Compute control for a deterministic system
# Cost in iteration 0: 0.31300465824020096
# Converged in iteration 1 with cost 0.31300465824020096 because of step counter
# Final cost : 0.31300465824020096
# Compute control for a deterministic system
# Cost in iteration 0: 0.31300465824020096
# Converged in iteration 1 with cost 0.31300465824020096 because of step counter
# Final cost : 0.31300465824020096
# Compute control for a deterministic system
# Cost in iteration 0: 0.31300465824020096
# Converged in iteration 1 with cost 0.31300465824020096 because of step counter
# Final cost : 0.31300465824020096
# Compute control for a deterministic system
# Cost in iteration 0: 0.31300465824020096
# Converged in iteration 1 with cost 0.31300465824020096 because of step counter
# Final cost : 0.31300465824020096
# Compute control for a deterministic system
# Cost in iteration 0: 0.31300465824020096
# Converged in iteration 1 with cost 0.31300465824020096 because of step counter
# Final cost : 0.31300465824020096
# Compute control for a deterministic system
# Cost in iteration 0: 0.2760283403312544
# Converged in iteration 1 with cost 0.2760283403312544 because of step counter
# Final cost : 0.2760283403312544
# Compute control for a deterministic system
# Cost in iteration 0: 0.2760283403312544
# Converged in iteration 1 with cost 0.2760283403312544 because of step counter
# Final cost : 0.2760283403312544
# Compute control for a deterministic system
# Cost in iteration 0: 0.2760283403312544
# Converged in iteration 1 with cost 0.2760283403312544 because of step counter
# Final cost : 0.2760283403312544
# Compute control for a deterministic system
# Cost in iteration 0: 0.2760283403312544
# Converged in iteration 1 with cost 0.2760283403312544 because of step counter
# Final cost : 0.2760283403312544
# Compute control for a deterministic system
# Cost in iteration 0: 0.2760283403312544
# Converged in iteration 1 with cost 0.2760283403312544 because of step counter
# Final cost : 0.2760283403312544
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164544528094375
# Converged in iteration 1 with cost 0.2164544528094375 because of step counter
# Final cost : 0.2164544528094375
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164544528094375
# Converged in iteration 1 with cost 0.2164544528094375 because of step counter
# Final cost : 0.2164544528094375
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164544528094375
# Converged in iteration 1 with cost 0.2164544528094375 because of step counter
# Final cost : 0.2164544528094375
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164544528094375
# Converged in iteration 1 with cost 0.2164544528094375 because of step counter
# Final cost : 0.2164544528094375
# Compute control for a deterministic system
# Cost in iteration 0: 0.2164544528094375
# Converged in iteration 1 with cost 0.2164544528094375 because of step counter
# Final cost : 0.2164544528094375
# Compute control for a deterministic system
# Cost in iteration 0: 0.1766485256032831
# Converged in iteration 14 with cost 0.1760802937257553 because of step counter
# Final cost : 0.1760802937257553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1760802937257553
# Converged in iteration 1 with cost 0.1760802937257553 because of step counter
# Final cost : 0.1760802937257553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1760802937257553
# Converged in iteration 1 with cost 0.1760802937257553 because of step counter
# Final cost : 0.1760802937257553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1760802937257553
# Converged in iteration 1 with cost 0.1760802937257553 because of step counter
# Final cost : 0.1760802937257553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1760802937257553
# Converged in iteration 1 with cost 0.1760802937257553 because of step counter
# Final cost : 0.1760802937257553
# Compute control for a deterministic system
# Cost in iteration 0: 0.13176989190805555
# Converged in iteration 23 with cost 0.13018270902728646 because of step counter
# Final cost : 0.13018270902728646
# Compute control for a deterministic system
# Cost in iteration 0: 0.13018270902728646
# Converged in iteration 1 with cost 0.13018270902728646 because of step counter
# Final cost : 0.13018270902728646
# Compute control for a deterministic system
# Cost in iteration 0: 0.13018270902728646
# Converged in iteration 1 with cost 0.13018270902728646 because of step counter
# Final cost : 0.13018270902728646
# Compute control for a deterministic system
# Cost in iteration 0: 0.13018270902728646
# Converged in iteration 1 with cost 0.13018270902728646 because of step counter
# Final cost : 0.13018270902728646
# Compute control for a deterministic system
# Cost in iteration 0: 0.13018270902728646
# Converged in iteration 1 with cost 0.13018270902728646 because of step counter
# Final cost : 0.13018270902728646
# Compute control for a deterministic system
# Cost in iteration 0: 0.08464602128430679
# Converged in iteration 10 with cost 0.08417737684103752 because of step counter
# Final cost : 0.08417737684103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.08417737684103752
# Converged in iteration 1 with cost 0.08417737684103752 because of step counter
# Final cost : 0.08417737684103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.08417737684103752
# Converged in iteration 1 with cost 0.08417737684103752 because of step counter
# Final cost : 0.08417737684103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.08417737684103752
# Converged in iteration 1 with cost 0.08417737684103752 because of step counter
# Final cost : 0.08417737684103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.08417737684103752
# Converged in iteration 1 with cost 0.08417737684103752 because of step counter
# Final cost : 0.08417737684103752
# Compute control for a deterministic system
# Cost in iteration 0: 0.04535995880004115
# Converged in iteration 7 with cost 0.045031935916487895 because of step counter
# Final cost : 0.045031935916487895
# Compute control for a deterministic system
# Cost in iteration 0: 0.045031935916487895
# Converged in iteration 1 with cost 0.045031935916487895 because of step counter
# Final cost : 0.045031935916487895
# Compute control for a deterministic system
# Cost in iteration 0: 0.045031935916487895
# Converged in iteration 1 with cost 0.045031935916487895 because of step counter
# Final cost : 0.045031935916487895
# Compute control for a deterministic system
# Cost in iteration 0: 0.045031935916487895
# Converged in iteration 1 with cost 0.045031935916487895 because of step counter
# Final cost : 0.045031935916487895
# Compute control for a deterministic system
# Cost in iteration 0: 0.045031935916487895
# Converged in iteration 1 with cost 0.045031935916487895 because of step counter
# Final cost : 0.045031935916487895
# Compute control for a deterministic system
# Cost in iteration 0: 0.016311368387419315
# Converged in iteration 4 with cost 0.01630979615130085 because of vanishing difference
# Final cost : 0.01630979615130085
# Compute control for a deterministic system
# Cost in iteration 0: 0.01630979615130085
# Converged in iteration 3 with cost 0.016309796146881685 because of step counter
# Final cost : 0.016309796146881685
# Compute control for a deterministic system
# Cost in iteration 0: 0.016309796146881685
# Converged in iteration 1 with cost 0.016309796146881685 because of step counter
# Final cost : 0.016309796146881685
# Compute control for a deterministic system
# Cost in iteration 0: 0.016309796146881685
# Converged in iteration 1 with cost 0.016309796146881685 because of step counter
# Final cost : 0.016309796146881685
# Compute control for a deterministic system
# Cost in iteration 0: 0.016309796146881685
# Converged in iteration 1 with cost 0.016309796146881685 because of step counter
# Final cost : 0.016309796146881685

# %%
save(results_min)
