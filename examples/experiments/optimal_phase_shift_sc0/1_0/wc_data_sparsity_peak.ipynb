# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.045135938287846025
y_init = 0.08586538415443892
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
period = (peaks[-1] - peaks[-2])*dt
print("period = ", period)

wc.run()
init_peak = [wc.exc[0,84], wc.inh[0,84]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  18.900000000000002
# peaks =  [  24  212  400  589  778  967 1156 1345 1534 1723 1912 2101 2290 2479
#  2668 2857]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 80.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])

ind_list = range(41)
options = [True, True, True, True, True, True, True, True]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        if i_w in [2]:
            break

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.02561800435684128
# Converged in iteration 94 with cost 0.023106333577141612 because of step counter
# Final cost : 0.023106333577141612
# Compute control for a deterministic system
# Cost in iteration 0: 0.023106333577141612
# Converged in iteration 1 with cost 0.023106333577141612 because of step counter
# Final cost : 0.023106333577141612
# Compute control for a deterministic system
# Cost in iteration 0: 0.023106333577141612
# Converged in iteration 1 with cost 0.023106333577141612 because of step counter
# Final cost : 0.023106333577141612
# Compute control for a deterministic system
# Cost in iteration 0: 0.023106333577141612
# Converged in iteration 1 with cost 0.023106333577141612 because of step counter
# Final cost : 0.023106333577141612
# Compute control for a deterministic system
# Cost in iteration 0: 0.023106333577141612
# Converged in iteration 1 with cost 0.023106333577141612 because of step counter
# Final cost : 0.023106333577141612
# Compute control for a deterministic system
# Cost in iteration 0: 0.03992051064708857
# Converged in iteration 120 with cost 0.034409569486276 because of step counter
# Final cost : 0.034409569486276
# Compute control for a deterministic system
# Cost in iteration 0: 0.034409569486276
# Converged in iteration 1 with cost 0.034409569486276 because of step counter
# Final cost : 0.034409569486276
# Compute control for a deterministic system
# Cost in iteration 0: 0.034409569486276
# Converged in iteration 1 with cost 0.034409569486276 because of step counter
# Final cost : 0.034409569486276
# Compute control for a deterministic system
# Cost in iteration 0: 0.034409569486276
# Converged in iteration 1 with cost 0.034409569486276 because of step counter
# Final cost : 0.034409569486276
# Compute control for a deterministic system
# Cost in iteration 0: 0.034409569486276
# Converged in iteration 1 with cost 0.034409569486276 because of step counter
# Final cost : 0.034409569486276
# Compute control for a deterministic system
# Cost in iteration 0: 0.04775077201679448
# Converged in iteration 128 with cost 0.042729413683386924 because of step counter
# Final cost : 0.042729413683386924
# Compute control for a deterministic system
# Cost in iteration 0: 0.042729413683386924
# Converged in iteration 1 with cost 0.042729413683386924 because of step counter
# Final cost : 0.042729413683386924
# Compute control for a deterministic system
# Cost in iteration 0: 0.042729413683386924
# Converged in iteration 1 with cost 0.042729413683386924 because of step counter
# Final cost : 0.042729413683386924
# Compute control for a deterministic system
# Cost in iteration 0: 0.042729413683386924
# Converged in iteration 1 with cost 0.042729413683386924 because of step counter
# Final cost : 0.042729413683386924
# Compute control for a deterministic system
# Cost in iteration 0: 0.042729413683386924
# Converged in iteration 1 with cost 0.042729413683386924 because of step counter
# Final cost : 0.042729413683386924
# Compute control for a deterministic system
# Cost in iteration 0: 0.05517550583914464
# Converged in iteration 138 with cost 0.050819302987642895 because of step counter
# Final cost : 0.050819302987642895
# Compute control for a deterministic system
# Cost in iteration 0: 0.050819302987642895
# Converged in iteration 1 with cost 0.050819302987642895 because of step counter
# Final cost : 0.050819302987642895
# Compute control for a deterministic system
# Cost in iteration 0: 0.050819302987642895
# Converged in iteration 1 with cost 0.050819302987642895 because of step counter
# Final cost : 0.050819302987642895
# Compute control for a deterministic system
# Cost in iteration 0: 0.050819302987642895
# Converged in iteration 1 with cost 0.050819302987642895 because of step counter
# Final cost : 0.050819302987642895
# Compute control for a deterministic system
# Cost in iteration 0: 0.050819302987642895
# Converged in iteration 1 with cost 0.050819302987642895 because of step counter
# Final cost : 0.050819302987642895
# Compute control for a deterministic system
# Cost in iteration 0: 0.05580205716018317
# Converged in iteration 113 with cost 0.05488709200177308 because of step counter
# Final cost : 0.05488709200177308
# Compute control for a deterministic system
# Cost in iteration 0: 0.05488709200177308
# Converged in iteration 1 with cost 0.05488709200177308 because of step counter
# Final cost : 0.05488709200177308
# Compute control for a deterministic system
# Cost in iteration 0: 0.05488709200177308
# Converged in iteration 1 with cost 0.05488709200177308 because of step counter
# Final cost : 0.05488709200177308
# Compute control for a deterministic system
# Cost in iteration 0: 0.05488709200177308
# Converged in iteration 1 with cost 0.05488709200177308 because of step counter
# Final cost : 0.05488709200177308
# Compute control for a deterministic system
# Cost in iteration 0: 0.05488709200177308
# Converged in iteration 1 with cost 0.05488709200177308 because of step counter
# Final cost : 0.05488709200177308
# Compute control for a deterministic system
# Cost in iteration 0: 0.06613622580485165
# Converged in iteration 152 with cost 0.06417409386314056 because of step counter
# Final cost : 0.06417409386314056
# Compute control for a deterministic system
# Cost in iteration 0: 0.06417409386314056
# Converged in iteration 1 with cost 0.06417409386314056 because of step counter
# Final cost : 0.06417409386314056
# Compute control for a deterministic system
# Cost in iteration 0: 0.06417409386314056
# Converged in iteration 1 with cost 0.06417409386314056 because of step counter
# Final cost : 0.06417409386314056
# Compute control for a deterministic system
# Cost in iteration 0: 0.06417409386314056
# Converged in iteration 1 with cost 0.06417409386314056 because of step counter
# Final cost : 0.06417409386314056
# Compute control for a deterministic system
# Cost in iteration 0: 0.06417409386314056
# Converged in iteration 1 with cost 0.06417409386314056 because of step counter
# Final cost : 0.06417409386314056
# Compute control for a deterministic system
# Cost in iteration 0: 0.07261909946160577
# Converged in iteration 115 with cost 0.07165685736874498 because of step counter
# Final cost : 0.07165685736874498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07165685736874498
# Converged in iteration 1 with cost 0.07165685736874498 because of step counter
# Final cost : 0.07165685736874498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07165685736874498
# Converged in iteration 1 with cost 0.07165685736874498 because of step counter
# Final cost : 0.07165685736874498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07165685736874498
# Converged in iteration 1 with cost 0.07165685736874498 because of step counter
# Final cost : 0.07165685736874498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07165685736874498
# Converged in iteration 1 with cost 0.07165685736874498 because of step counter
# Final cost : 0.07165685736874498
# Compute control for a deterministic system
# Cost in iteration 0: 0.08069022921886267
# Converged in iteration 136 with cost 0.07905095810475553 because of step counter
# Final cost : 0.07905095810475553
# Compute control for a deterministic system
# Cost in iteration 0: 0.07905095810475553
# Converged in iteration 2 with cost 0.0790509581047554 because of step counter
# Final cost : 0.0790509581047554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0790509581047554
# Converged in iteration 1 with cost 0.0790509581047554 because of step counter
# Final cost : 0.0790509581047554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0790509581047554
# Converged in iteration 1 with cost 0.0790509581047554 because of step counter
# Final cost : 0.0790509581047554
# Compute control for a deterministic system
# Cost in iteration 0: 0.0790509581047554
# Converged in iteration 1 with cost 0.0790509581047554 because of step counter
# Final cost : 0.0790509581047554
# Compute control for a deterministic system
# Cost in iteration 0: 0.08560672424363888
# Converged in iteration 119 with cost 0.08434094580222815 because of vanishing difference
# Final cost : 0.08434094580222815
# Compute control for a deterministic system
# Cost in iteration 0: 0.08434094580222815
# Converged in iteration 1 with cost 0.08434094580222815 because of step counter
# Final cost : 0.08434094580222815
# Compute control for a deterministic system
# Cost in iteration 0: 0.08434094580222815
# Converged in iteration 1 with cost 0.08434094580222815 because of step counter
# Final cost : 0.08434094580222815
# Compute control for a deterministic system
# Cost in iteration 0: 0.08434094580222815
# Converged in iteration 1 with cost 0.08434094580222815 because of step counter
# Final cost : 0.08434094580222815
# Compute control for a deterministic system
# Cost in iteration 0: 0.08434094580222815
# Converged in iteration 1 with cost 0.08434094580222815 because of step counter
# Final cost : 0.08434094580222815
# Compute control for a deterministic system
# Cost in iteration 0: 0.0921328015576
# Converged in iteration 64 with cost 0.091680706030656 because of step counter
# Final cost : 0.091680706030656
# Compute control for a deterministic system
# Cost in iteration 0: 0.091680706030656
# Converged in iteration 1 with cost 0.091680706030656 because of step counter
# Final cost : 0.091680706030656
# Compute control for a deterministic system
# Cost in iteration 0: 0.091680706030656
# Converged in iteration 1 with cost 0.091680706030656 because of step counter
# Final cost : 0.091680706030656
# Compute control for a deterministic system
# Cost in iteration 0: 0.091680706030656
# Converged in iteration 1 with cost 0.091680706030656 because of step counter
# Final cost : 0.091680706030656
# Compute control for a deterministic system
# Cost in iteration 0: 0.091680706030656
# Converged in iteration 1 with cost 0.091680706030656 because of step counter
# Final cost : 0.091680706030656
# Compute control for a deterministic system
# Cost in iteration 0: 0.10304696251358231
# Converged in iteration 182 with cost 0.10009831537764123 because of step counter
# Final cost : 0.10009831537764123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10009831537764123
# Converged in iteration 1 with cost 0.10009831537764123 because of step counter
# Final cost : 0.10009831537764123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10009831537764123
# Converged in iteration 1 with cost 0.10009831537764123 because of step counter
# Final cost : 0.10009831537764123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10009831537764123
# Converged in iteration 1 with cost 0.10009831537764123 because of step counter
# Final cost : 0.10009831537764123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10009831537764123
# Converged in iteration 1 with cost 0.10009831537764123 because of step counter
# Final cost : 0.10009831537764123
# Compute control for a deterministic system
# Cost in iteration 0: 0.10683837910823407
# Converged in iteration 179 with cost 0.10508968143978525 because of step counter
# Final cost : 0.10508968143978525
# Compute control for a deterministic system
# Cost in iteration 0: 0.10508968143978525
# Converged in iteration 2 with cost 0.10508968143978503 because of step counter
# Final cost : 0.10508968143978503
# Compute control for a deterministic system
# Cost in iteration 0: 0.10508968143978503
# Converged in iteration 1 with cost 0.10508968143978503 because of step counter
# Final cost : 0.10508968143978503
# Compute control for a deterministic system
# Cost in iteration 0: 0.10508968143978503
# Converged in iteration 1 with cost 0.10508968143978503 because of step counter
# Final cost : 0.10508968143978503
# Compute control for a deterministic system
# Cost in iteration 0: 0.10508968143978503
# Converged in iteration 1 with cost 0.10508968143978503 because of step counter
# Final cost : 0.10508968143978503
# Compute control for a deterministic system
# Cost in iteration 0: 0.12313367283641223
# Cost in iteration 200: 0.11753131785352444
# Final cost : 0.11753131785352444
# Compute control for a deterministic system
# Cost in iteration 0: 0.11753131785352444
# Converged in iteration 20 with cost 0.11742364325289775 because of step counter
# Final cost : 0.11742364325289775
# Compute control for a deterministic system
# Cost in iteration 0: 0.11742364325289775
# Converged in iteration 1 with cost 0.11742364325289775 because of step counter
# Final cost : 0.11742364325289775
# Compute control for a deterministic system
# Cost in iteration 0: 0.11742364325289775
# Converged in iteration 1 with cost 0.11742364325289775 because of step counter
# Final cost : 0.11742364325289775
# Compute control for a deterministic system
# Cost in iteration 0: 0.11742364325289775
# Converged in iteration 1 with cost 0.11742364325289775 because of step counter
# Final cost : 0.11742364325289775
# Compute control for a deterministic system
# Cost in iteration 0: 0.12551638944146584
# Converged in iteration 167 with cost 0.1253746535282923 because of vanishing difference
# Final cost : 0.1253746535282923
# Compute control for a deterministic system
# Cost in iteration 0: 0.1253746535282923
# Converged in iteration 1 with cost 0.1253746535282923 because of step counter
# Final cost : 0.1253746535282923
# Compute control for a deterministic system
# Cost in iteration 0: 0.1253746535282923
# Converged in iteration 1 with cost 0.1253746535282923 because of step counter
# Final cost : 0.1253746535282923
# Compute control for a deterministic system
# Cost in iteration 0: 0.1253746535282923
# Converged in iteration 1 with cost 0.1253746535282923 because of step counter
# Final cost : 0.1253746535282923
# Compute control for a deterministic system
# Cost in iteration 0: 0.1253746535282923
# Converged in iteration 1 with cost 0.1253746535282923 because of step counter
# Final cost : 0.1253746535282923
# Compute control for a deterministic system
# Cost in iteration 0: 0.13853466151560626
# Cost in iteration 200: 0.13516660886672263
# Final cost : 0.13516660886672263
# Compute control for a deterministic system
# Cost in iteration 0: 0.13516660886672263
# Converged in iteration 31 with cost 0.13163974120806798 because of step counter
# Final cost : 0.13163974120806798
# Compute control for a deterministic system
# Cost in iteration 0: 0.13163974120806798
# Converged in iteration 1 with cost 0.13163974120806798 because of step counter
# Final cost : 0.13163974120806798
# Compute control for a deterministic system
# Cost in iteration 0: 0.13163974120806798
# Converged in iteration 1 with cost 0.13163974120806798 because of step counter
# Final cost : 0.13163974120806798
# Compute control for a deterministic system
# Cost in iteration 0: 0.13163974120806798
# Converged in iteration 1 with cost 0.13163974120806798 because of step counter
# Final cost : 0.13163974120806798
# Compute control for a deterministic system
# Cost in iteration 0: 0.12345260244042253
# Converged in iteration 124 with cost 0.1219142935457421 because of step counter
# Final cost : 0.1219142935457421
# Compute control for a deterministic system
# Cost in iteration 0: 0.1219142935457421
# Converged in iteration 1 with cost 0.1219142935457421 because of step counter
# Final cost : 0.1219142935457421
# Compute control for a deterministic system
# Cost in iteration 0: 0.1219142935457421
# Converged in iteration 1 with cost 0.1219142935457421 because of step counter
# Final cost : 0.1219142935457421
# Compute control for a deterministic system
# Cost in iteration 0: 0.1219142935457421
# Converged in iteration 1 with cost 0.1219142935457421 because of step counter
# Final cost : 0.1219142935457421
# Compute control for a deterministic system
# Cost in iteration 0: 0.1219142935457421
# Converged in iteration 1 with cost 0.1219142935457421 because of step counter
# Final cost : 0.1219142935457421
# Compute control for a deterministic system
# Cost in iteration 0: 0.128431207576114
# Converged in iteration 80 with cost 0.12654334227165395 because of step counter
# Final cost : 0.12654334227165395
# Compute control for a deterministic system
# Cost in iteration 0: 0.12654334227165395
# Converged in iteration 1 with cost 0.12654334227165395 because of step counter
# Final cost : 0.12654334227165395
# Compute control for a deterministic system
# Cost in iteration 0: 0.12654334227165395
# Converged in iteration 1 with cost 0.12654334227165395 because of step counter
# Final cost : 0.12654334227165395
# Compute control for a deterministic system
# Cost in iteration 0: 0.12654334227165395
# Converged in iteration 1 with cost 0.12654334227165395 because of step counter
# Final cost : 0.12654334227165395
# Compute control for a deterministic system
# Cost in iteration 0: 0.12654334227165395
# Converged in iteration 1 with cost 0.12654334227165395 because of step counter
# Final cost : 0.12654334227165395
# Compute control for a deterministic system
# Cost in iteration 0: 0.132849040180236
# Converged in iteration 1 with cost 0.132849040180236 because of step counter
# Final cost : 0.132849040180236
# Compute control for a deterministic system
# Cost in iteration 0: 0.132849040180236
# Converged in iteration 1 with cost 0.132849040180236 because of step counter
# Final cost : 0.132849040180236
# Compute control for a deterministic system
# Cost in iteration 0: 0.132849040180236
# Converged in iteration 1 with cost 0.132849040180236 because of step counter
# Final cost : 0.132849040180236
# Compute control for a deterministic system
# Cost in iteration 0: 0.132849040180236
# Converged in iteration 1 with cost 0.132849040180236 because of step counter
# Final cost : 0.132849040180236
# Compute control for a deterministic system
# Cost in iteration 0: 0.132849040180236
# Converged in iteration 1 with cost 0.132849040180236 because of step counter
# Final cost : 0.132849040180236
# Compute control for a deterministic system
# Cost in iteration 0: 0.13698368193054647
# Converged in iteration 5 with cost 0.1368445330682281 because of step counter
# Final cost : 0.1368445330682281
# Compute control for a deterministic system
# Cost in iteration 0: 0.1368445330682281
# Converged in iteration 1 with cost 0.1368445330682281 because of step counter
# Final cost : 0.1368445330682281
# Compute control for a deterministic system
# Cost in iteration 0: 0.1368445330682281
# Converged in iteration 1 with cost 0.1368445330682281 because of step counter
# Final cost : 0.1368445330682281
# Compute control for a deterministic system
# Cost in iteration 0: 0.1368445330682281
# Converged in iteration 1 with cost 0.1368445330682281 because of step counter
# Final cost : 0.1368445330682281
# Compute control for a deterministic system
# Cost in iteration 0: 0.1368445330682281
# Converged in iteration 1 with cost 0.1368445330682281 because of step counter
# Final cost : 0.1368445330682281
# Compute control for a deterministic system
# Cost in iteration 0: 0.14950665540233044
# Converged in iteration 2 with cost 0.13755948830779569 because of step counter
# Final cost : 0.13755948830779569
# Compute control for a deterministic system
# Cost in iteration 0: 0.13755948830779569
# Converged in iteration 1 with cost 0.13755948830779569 because of step counter
# Final cost : 0.13755948830779569
# Compute control for a deterministic system
# Cost in iteration 0: 0.13755948830779569
# Converged in iteration 1 with cost 0.13755948830779569 because of step counter
# Final cost : 0.13755948830779569
# Compute control for a deterministic system
# Cost in iteration 0: 0.13755948830779569
# Converged in iteration 1 with cost 0.13755948830779569 because of step counter
# Final cost : 0.13755948830779569
# Compute control for a deterministic system
# Cost in iteration 0: 0.13755948830779569
# Converged in iteration 1 with cost 0.13755948830779569 because of step counter
# Final cost : 0.13755948830779569
# Compute control for a deterministic system
# Cost in iteration 0: 0.15366989798131217
# Converged in iteration 3 with cost 0.14009631573995537 because of step counter
# Final cost : 0.14009631573995537
# Compute control for a deterministic system
# Cost in iteration 0: 0.14009631573995537
# Converged in iteration 1 with cost 0.14009631573995537 because of step counter
# Final cost : 0.14009631573995537
# Compute control for a deterministic system
# Cost in iteration 0: 0.14009631573995537
# Converged in iteration 1 with cost 0.14009631573995537 because of step counter
# Final cost : 0.14009631573995537
# Compute control for a deterministic system
# Cost in iteration 0: 0.14009631573995537
# Converged in iteration 1 with cost 0.14009631573995537 because of step counter
# Final cost : 0.14009631573995537
# Compute control for a deterministic system
# Cost in iteration 0: 0.14009631573995537
# Converged in iteration 1 with cost 0.14009631573995537 because of step counter
# Final cost : 0.14009631573995537
# Compute control for a deterministic system
# Cost in iteration 0: 0.1562171871163616
# Converged in iteration 2 with cost 0.14249389347754746 because of step counter
# Final cost : 0.14249389347754746
# Compute control for a deterministic system
# Cost in iteration 0: 0.14249389347754746
# Converged in iteration 1 with cost 0.14249389347754746 because of step counter
# Final cost : 0.14249389347754746
# Compute control for a deterministic system
# Cost in iteration 0: 0.14249389347754746
# Converged in iteration 1 with cost 0.14249389347754746 because of step counter
# Final cost : 0.14249389347754746
# Compute control for a deterministic system
# Cost in iteration 0: 0.14249389347754746
# Converged in iteration 1 with cost 0.14249389347754746 because of step counter
# Final cost : 0.14249389347754746
# Compute control for a deterministic system
# Cost in iteration 0: 0.14249389347754746
# Converged in iteration 1 with cost 0.14249389347754746 because of step counter
# Final cost : 0.14249389347754746
# Compute control for a deterministic system
# Cost in iteration 0: 0.152157055013023
# Converged in iteration 3 with cost 0.1437936735460254 because of step counter
# Final cost : 0.1437936735460254
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437936735460254
# Converged in iteration 1 with cost 0.1437936735460254 because of step counter
# Final cost : 0.1437936735460254
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437936735460254
# Converged in iteration 1 with cost 0.1437936735460254 because of step counter
# Final cost : 0.1437936735460254
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437936735460254
# Converged in iteration 1 with cost 0.1437936735460254 because of step counter
# Final cost : 0.1437936735460254
# Compute control for a deterministic system
# Cost in iteration 0: 0.1437936735460254
# Converged in iteration 1 with cost 0.1437936735460254 because of step counter
# Final cost : 0.1437936735460254
# Compute control for a deterministic system
# Cost in iteration 0: 0.1594154098340589
# Converged in iteration 3 with cost 0.14519095024340892 because of step counter
# Final cost : 0.14519095024340892
# Compute control for a deterministic system
# Cost in iteration 0: 0.14519095024340892
# Converged in iteration 1 with cost 0.14519095024340892 because of step counter
# Final cost : 0.14519095024340892
# Compute control for a deterministic system
# Cost in iteration 0: 0.14519095024340892
# Converged in iteration 1 with cost 0.14519095024340892 because of step counter
# Final cost : 0.14519095024340892
# Compute control for a deterministic system
# Cost in iteration 0: 0.14519095024340892
# Converged in iteration 1 with cost 0.14519095024340892 because of step counter
# Final cost : 0.14519095024340892
# Compute control for a deterministic system
# Cost in iteration 0: 0.14519095024340892
# Converged in iteration 1 with cost 0.14519095024340892 because of step counter
# Final cost : 0.14519095024340892
# Compute control for a deterministic system
# Cost in iteration 0: 0.1487887078944043
# Cost in iteration 200: 0.12933372059326562
# Final cost : 0.12933372059326562
# Compute control for a deterministic system
# Cost in iteration 0: 0.12933372059326562
# Cost in iteration 200: 0.1272392399116133
# Final cost : 0.1272392399116133
# Compute control for a deterministic system
# Cost in iteration 0: 0.1272392399116133
# Converged in iteration 1 with cost 0.1272392399116133 because of vanishing difference
# Final cost : 0.1272392399116133
# Compute control for a deterministic system
# Cost in iteration 0: 0.1272392399116133
# Converged in iteration 4 with cost 0.12723923991004613 because of step counter
# Final cost : 0.12723923991004613
# Compute control for a deterministic system
# Cost in iteration 0: 0.12723923991004613
# Converged in iteration 1 with cost 0.12723923991004613 because of step counter
# Final cost : 0.12723923991004613
# Compute control for a deterministic system
# Cost in iteration 0: 0.13968043785431566
# Cost in iteration 200: 0.12020765622363705
# Final cost : 0.12020765622363705
# Compute control for a deterministic system
# Cost in iteration 0: 0.12020765622363705
# Converged in iteration 196 with cost 0.11814479701373755 because of vanishing difference
# Final cost : 0.11814479701373755
# Compute control for a deterministic system
# Cost in iteration 0: 0.11814479701373755
# Converged in iteration 5 with cost 0.11814479698238207 because of step counter
# Final cost : 0.11814479698238207
# Compute control for a deterministic system
# Cost in iteration 0: 0.11814479698238207
# Converged in iteration 1 with cost 0.11814479698238207 because of step counter
# Final cost : 0.11814479698238207
# Compute control for a deterministic system
# Cost in iteration 0: 0.11814479698238207
# Converged in iteration 1 with cost 0.11814479698238207 because of step counter
# Final cost : 0.11814479698238207
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074885128621335
# Cost in iteration 200: 0.11163938280071625
# Final cost : 0.11163938280071625
# Compute control for a deterministic system
# Cost in iteration 0: 0.11163938280071625
# Converged in iteration 62 with cost 0.1113167094300414 because of step counter
# Final cost : 0.1113167094300414
# Compute control for a deterministic system
# Cost in iteration 0: 0.1113167094300414
# Converged in iteration 1 with cost 0.1113167094300414 because of step counter
# Final cost : 0.1113167094300414
# Compute control for a deterministic system
# Cost in iteration 0: 0.1113167094300414
# Converged in iteration 1 with cost 0.1113167094300414 because of step counter
# Final cost : 0.1113167094300414
# Compute control for a deterministic system
# Cost in iteration 0: 0.1113167094300414
# Converged in iteration 1 with cost 0.1113167094300414 because of step counter
# Final cost : 0.1113167094300414
# Compute control for a deterministic system
# Cost in iteration 0: 0.12041316401073614
# Cost in iteration 200: 0.10469307364458269
# Final cost : 0.10469307364458269
# Compute control for a deterministic system
# Cost in iteration 0: 0.10469307364458269
# Converged in iteration 155 with cost 0.10261363740429315 because of step counter
# Final cost : 0.10261363740429315
# Compute control for a deterministic system
# Cost in iteration 0: 0.10261363740429315
# Converged in iteration 1 with cost 0.10261363740429315 because of step counter
# Final cost : 0.10261363740429315
# Compute control for a deterministic system
# Cost in iteration 0: 0.10261363740429315
# Converged in iteration 1 with cost 0.10261363740429315 because of step counter
# Final cost : 0.10261363740429315
# Compute control for a deterministic system
# Cost in iteration 0: 0.10261363740429315
# Converged in iteration 1 with cost 0.10261363740429315 because of step counter
# Final cost : 0.10261363740429315
# Compute control for a deterministic system
# Cost in iteration 0: 0.1086750223667366
# Cost in iteration 200: 0.09399848354163227
# Final cost : 0.09399848354163227
# Compute control for a deterministic system
# Cost in iteration 0: 0.09399848354163227
# Converged in iteration 65 with cost 0.0932549936272906 because of step counter
# Final cost : 0.0932549936272906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0932549936272906
# Converged in iteration 1 with cost 0.0932549936272906 because of step counter
# Final cost : 0.0932549936272906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0932549936272906
# Converged in iteration 1 with cost 0.0932549936272906 because of step counter
# Final cost : 0.0932549936272906
# Compute control for a deterministic system
# Cost in iteration 0: 0.0932549936272906
# Converged in iteration 1 with cost 0.0932549936272906 because of step counter
# Final cost : 0.0932549936272906
# Compute control for a deterministic system
# Cost in iteration 0: 0.10097450941280933
# Cost in iteration 200: 0.08741465585451101
# Final cost : 0.08741465585451101
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741465585451101
# Converged in iteration 132 with cost 0.0860046180345679 because of step counter
# Final cost : 0.0860046180345679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0860046180345679
# Converged in iteration 1 with cost 0.0860046180345679 because of step counter
# Final cost : 0.0860046180345679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0860046180345679
# Converged in iteration 1 with cost 0.0860046180345679 because of step counter
# Final cost : 0.0860046180345679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0860046180345679
# Converged in iteration 1 with cost 0.0860046180345679 because of step counter
# Final cost : 0.0860046180345679
# Compute control for a deterministic system
# Cost in iteration 0: 0.09231074373039859
# Cost in iteration 200: 0.0773005456075645
# Final cost : 0.0773005456075645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0773005456075645
# Converged in iteration 54 with cost 0.07505751384109327 because of step counter
# Final cost : 0.07505751384109327
# Compute control for a deterministic system
# Cost in iteration 0: 0.07505751384109327
# Converged in iteration 1 with cost 0.07505751384109327 because of step counter
# Final cost : 0.07505751384109327
# Compute control for a deterministic system
# Cost in iteration 0: 0.07505751384109327
# Converged in iteration 1 with cost 0.07505751384109327 because of step counter
# Final cost : 0.07505751384109327
# Compute control for a deterministic system
# Cost in iteration 0: 0.07505751384109327
# Converged in iteration 1 with cost 0.07505751384109327 because of step counter
# Final cost : 0.07505751384109327
# Compute control for a deterministic system
# Cost in iteration 0: 0.08209848946078331
# Cost in iteration 200: 0.06636132658675496
# Final cost : 0.06636132658675496
# Compute control for a deterministic system
# Cost in iteration 0: 0.06636132658675496
# Converged in iteration 68 with cost 0.06502107614608711 because of step counter
# Final cost : 0.06502107614608711
# Compute control for a deterministic system
# Cost in iteration 0: 0.06502107614608711
# Converged in iteration 1 with cost 0.06502107614608711 because of step counter
# Final cost : 0.06502107614608711
# Compute control for a deterministic system
# Cost in iteration 0: 0.06502107614608711
# Converged in iteration 1 with cost 0.06502107614608711 because of step counter
# Final cost : 0.06502107614608711
# Compute control for a deterministic system
# Cost in iteration 0: 0.06502107614608711
# Converged in iteration 1 with cost 0.06502107614608711 because of step counter
# Final cost : 0.06502107614608711
# Compute control for a deterministic system
# Cost in iteration 0: 0.07993678860745335
# Cost in iteration 200: 0.058246191662859
# Final cost : 0.058246191662859
# Compute control for a deterministic system
# Cost in iteration 0: 0.058246191662859
# Converged in iteration 113 with cost 0.05565830486644823 because of step counter
# Final cost : 0.05565830486644823
# Compute control for a deterministic system
# Cost in iteration 0: 0.05565830486644823
# Converged in iteration 1 with cost 0.05565830486644823 because of step counter
# Final cost : 0.05565830486644823
# Compute control for a deterministic system
# Cost in iteration 0: 0.05565830486644823
# Converged in iteration 1 with cost 0.05565830486644823 because of step counter
# Final cost : 0.05565830486644823
# Compute control for a deterministic system
# Cost in iteration 0: 0.05565830486644823
# Converged in iteration 1 with cost 0.05565830486644823 because of step counter
# Final cost : 0.05565830486644823
# Compute control for a deterministic system
# Cost in iteration 0: 0.060170186272996765
# Cost in iteration 200: 0.049045666376912586
# Final cost : 0.049045666376912586
# Compute control for a deterministic system
# Cost in iteration 0: 0.049045666376912586
# Converged in iteration 35 with cost 0.048210991384773444 because of step counter
# Final cost : 0.048210991384773444
# Compute control for a deterministic system
# Cost in iteration 0: 0.048210991384773444
# Converged in iteration 1 with cost 0.048210991384773444 because of step counter
# Final cost : 0.048210991384773444
# Compute control for a deterministic system
# Cost in iteration 0: 0.048210991384773444
# Converged in iteration 1 with cost 0.048210991384773444 because of step counter
# Final cost : 0.048210991384773444
# Compute control for a deterministic system
# Cost in iteration 0: 0.048210991384773444
# Converged in iteration 1 with cost 0.048210991384773444 because of step counter
# Final cost : 0.048210991384773444
# Compute control for a deterministic system
# Cost in iteration 0: 0.06390031622032137
# Cost in iteration 200: 0.04170647880444375
# Final cost : 0.04170647880444375
# Compute control for a deterministic system
# Cost in iteration 0: 0.04170647880444375
# Converged in iteration 133 with cost 0.03833864825843399 because of step counter
# Final cost : 0.03833864825843399
# Compute control for a deterministic system
# Cost in iteration 0: 0.03833864825843399
# Converged in iteration 1 with cost 0.03833864825843399 because of step counter
# Final cost : 0.03833864825843399
# Compute control for a deterministic system
# Cost in iteration 0: 0.03833864825843399
# Converged in iteration 1 with cost 0.03833864825843399 because of step counter
# Final cost : 0.03833864825843399
# Compute control for a deterministic system
# Cost in iteration 0: 0.03833864825843399
# Converged in iteration 1 with cost 0.03833864825843399 because of step counter
# Final cost : 0.03833864825843399
# Compute control for a deterministic system
# Cost in iteration 0: 0.05333236642171236
# Cost in iteration 200: 0.032193130436443514
# Final cost : 0.032193130436443514
# Compute control for a deterministic system
# Cost in iteration 0: 0.032193130436443514
# Converged in iteration 160 with cost 0.02806591731753344 because of step counter
# Final cost : 0.02806591731753344
# Compute control for a deterministic system
# Cost in iteration 0: 0.02806591731753344
# Converged in iteration 1 with cost 0.02806591731753344 because of step counter
# Final cost : 0.02806591731753344
# Compute control for a deterministic system
# Cost in iteration 0: 0.02806591731753344
# Converged in iteration 1 with cost 0.02806591731753344 because of step counter
# Final cost : 0.02806591731753344
# Compute control for a deterministic system
# Cost in iteration 0: 0.02806591731753344
# Converged in iteration 1 with cost 0.02806591731753344 because of step counter
# Final cost : 0.02806591731753344
# Compute control for a deterministic system
# Cost in iteration 0: 0.03824651407567012
# Cost in iteration 200: 0.0210945630045733
# Final cost : 0.0210945630045733
# Compute control for a deterministic system
# Cost in iteration 0: 0.0210945630045733
# Converged in iteration 52 with cost 0.016251159539379407 because of step counter
# Final cost : 0.016251159539379407
# Compute control for a deterministic system
# Cost in iteration 0: 0.016251159539379407
# Converged in iteration 1 with cost 0.016251159539379407 because of step counter
# Final cost : 0.016251159539379407
# Compute control for a deterministic system
# Cost in iteration 0: 0.016251159539379407
# Converged in iteration 1 with cost 0.016251159539379407 because of step counter
# Final cost : 0.016251159539379407
# Compute control for a deterministic system
# Cost in iteration 0: 0.016251159539379407
# Converged in iteration 1 with cost 0.016251159539379407 because of step counter
# Final cost : 0.016251159539379407
# Compute control for a deterministic system
# Cost in iteration 0: 0.0217758471084109
# Cost in iteration 200: 0.010974096970295322
# Final cost : 0.010974096970295322
# Compute control for a deterministic system
# Cost in iteration 0: 0.010974096970295322
# Converged in iteration 36 with cost 0.008255786726157559 because of step counter
# Final cost : 0.008255786726157559
# Compute control for a deterministic system
# Cost in iteration 0: 0.008255786726157559
# Converged in iteration 1 with cost 0.008255786726157559 because of step counter
# Final cost : 0.008255786726157559
# Compute control for a deterministic system
# Cost in iteration 0: 0.008255786726157559
# Converged in iteration 1 with cost 0.008255786726157559 because of step counter
# Final cost : 0.008255786726157559
# Compute control for a deterministic system
# Cost in iteration 0: 0.008255786726157559
# Converged in iteration 1 with cost 0.008255786726157559 because of step counter
# Final cost : 0.008255786726157559
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.028158629236714323
# Converged in iteration 53 with cost 0.023376761778172713 because of step counter
# Final cost : 0.023376761778172713
# Compute control for a deterministic system
# Cost in iteration 0: 0.023376761778172713
# Converged in iteration 1 with cost 0.023376761778172713 because of step counter
# Final cost : 0.023376761778172713
# Compute control for a deterministic system
# Cost in iteration 0: 0.023376761778172713
# Converged in iteration 1 with cost 0.023376761778172713 because of step counter
# Final cost : 0.023376761778172713
# Compute control for a deterministic system
# Cost in iteration 0: 0.023376761778172713
# Converged in iteration 1 with cost 0.023376761778172713 because of step counter
# Final cost : 0.023376761778172713
# Compute control for a deterministic system
# Cost in iteration 0: 0.044480275609368736
# Converged in iteration 34 with cost 0.03411583643224354 because of step counter
# Final cost : 0.03411583643224354
# Compute control for a deterministic system
# Cost in iteration 0: 0.03411583643224354
# Converged in iteration 1 with cost 0.03411583643224354 because of step counter
# Final cost : 0.03411583643224354
# Compute control for a deterministic system
# Cost in iteration 0: 0.03411583643224354
# Converged in iteration 1 with cost 0.03411583643224354 because of step counter
# Final cost : 0.03411583643224354
# Compute control for a deterministic system
# Cost in iteration 0: 0.03411583643224354
# Converged in iteration 1 with cost 0.03411583643224354 because of step counter
# Final cost : 0.03411583643224354
# Compute control for a deterministic system
# Cost in iteration 0: 0.054504584308886814
# Converged in iteration 30 with cost 0.04240359839195005 because of step counter
# Final cost : 0.04240359839195005
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240359839195005
# Converged in iteration 1 with cost 0.04240359839195005 because of step counter
# Final cost : 0.04240359839195005
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240359839195005
# Converged in iteration 1 with cost 0.04240359839195005 because of step counter
# Final cost : 0.04240359839195005
# Compute control for a deterministic system
# Cost in iteration 0: 0.04240359839195005
# Converged in iteration 1 with cost 0.04240359839195005 because of step counter
# Final cost : 0.04240359839195005
# Compute control for a deterministic system
# Cost in iteration 0: 0.06291456282641551
# Converged in iteration 15 with cost 0.05140329864257723 because of step counter
# Final cost : 0.05140329864257723
# Compute control for a deterministic system
# Cost in iteration 0: 0.05140329864257723
# Converged in iteration 1 with cost 0.05140329864257723 because of step counter
# Final cost : 0.05140329864257723
# Compute control for a deterministic system
# Cost in iteration 0: 0.05140329864257723
# Converged in iteration 1 with cost 0.05140329864257723 because of step counter
# Final cost : 0.05140329864257723
# Compute control for a deterministic system
# Cost in iteration 0: 0.05140329864257723
# Converged in iteration 1 with cost 0.05140329864257723 because of step counter
# Final cost : 0.05140329864257723
# Compute control for a deterministic system
# Cost in iteration 0: 0.06342460132096202
# Converged in iteration 12 with cost 0.05724470820758547 because of step counter
# Final cost : 0.05724470820758547
# Compute control for a deterministic system
# Cost in iteration 0: 0.05724470820758547
# Converged in iteration 1 with cost 0.05724470820758547 because of step counter
# Final cost : 0.05724470820758547
# Compute control for a deterministic system
# Cost in iteration 0: 0.05724470820758547
# Converged in iteration 1 with cost 0.05724470820758547 because of step counter
# Final cost : 0.05724470820758547
# Compute control for a deterministic system
# Cost in iteration 0: 0.05724470820758547
# Converged in iteration 1 with cost 0.05724470820758547 because of step counter
# Final cost : 0.05724470820758547
# Compute control for a deterministic system
# Cost in iteration 0: 0.08288573346891548
# Converged in iteration 15 with cost 0.069656411719261 because of step counter
# Final cost : 0.069656411719261
# Compute control for a deterministic system
# Cost in iteration 0: 0.069656411719261
# Converged in iteration 1 with cost 0.069656411719261 because of step counter
# Final cost : 0.069656411719261
# Compute control for a deterministic system
# Cost in iteration 0: 0.069656411719261
# Converged in iteration 1 with cost 0.069656411719261 because of step counter
# Final cost : 0.069656411719261
# Compute control for a deterministic system
# Cost in iteration 0: 0.069656411719261
# Converged in iteration 1 with cost 0.069656411719261 because of step counter
# Final cost : 0.069656411719261
# Compute control for a deterministic system
# Cost in iteration 0: 0.08527197986844479
# Converged in iteration 14 with cost 0.07609852458659447 because of step counter
# Final cost : 0.07609852458659447
# Compute control for a deterministic system
# Cost in iteration 0: 0.07609852458659447
# Converged in iteration 1 with cost 0.07609852458659447 because of step counter
# Final cost : 0.07609852458659447
# Compute control for a deterministic system
# Cost in iteration 0: 0.07609852458659447
# Converged in iteration 1 with cost 0.07609852458659447 because of step counter
# Final cost : 0.07609852458659447
# Compute control for a deterministic system
# Cost in iteration 0: 0.07609852458659447
# Converged in iteration 1 with cost 0.07609852458659447 because of step counter
# Final cost : 0.07609852458659447
# Compute control for a deterministic system
# Cost in iteration 0: 0.09971752797979948
# Converged in iteration 20 with cost 0.08808907057353015 because of step counter
# Final cost : 0.08808907057353015
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808907057353015
# Converged in iteration 1 with cost 0.08808907057353015 because of step counter
# Final cost : 0.08808907057353015
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808907057353015
# Converged in iteration 1 with cost 0.08808907057353015 because of step counter
# Final cost : 0.08808907057353015
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808907057353015
# Converged in iteration 1 with cost 0.08808907057353015 because of step counter
# Final cost : 0.08808907057353015
# Compute control for a deterministic system
# Cost in iteration 0: 0.10401642086749525
# Converged in iteration 21 with cost 0.09720175254151057 because of step counter
# Final cost : 0.09720175254151057
# Compute control for a deterministic system
# Cost in iteration 0: 0.09720175254151057
# Converged in iteration 1 with cost 0.09720175254151057 because of step counter
# Final cost : 0.09720175254151057
# Compute control for a deterministic system
# Cost in iteration 0: 0.09720175254151057
# Converged in iteration 1 with cost 0.09720175254151057 because of step counter
# Final cost : 0.09720175254151057
# Compute control for a deterministic system
# Cost in iteration 0: 0.09720175254151057
# Converged in iteration 1 with cost 0.09720175254151057 because of step counter
# Final cost : 0.09720175254151057
# Compute control for a deterministic system
# Cost in iteration 0: 0.11050349648382274
# Converged in iteration 11 with cost 0.10345207491941093 because of step counter
# Final cost : 0.10345207491941093
# Compute control for a deterministic system
# Cost in iteration 0: 0.10345207491941093
# Converged in iteration 1 with cost 0.10345207491941093 because of step counter
# Final cost : 0.10345207491941093
# Compute control for a deterministic system
# Cost in iteration 0: 0.10345207491941093
# Converged in iteration 1 with cost 0.10345207491941093 because of step counter
# Final cost : 0.10345207491941093
# Compute control for a deterministic system
# Cost in iteration 0: 0.10345207491941093
# Converged in iteration 1 with cost 0.10345207491941093 because of step counter
# Final cost : 0.10345207491941093
# Compute control for a deterministic system
# Cost in iteration 0: 0.1260497140735977
# Converged in iteration 17 with cost 0.11570507314621326 because of step counter
# Final cost : 0.11570507314621326
# Compute control for a deterministic system
# Cost in iteration 0: 0.11570507314621326
# Converged in iteration 1 with cost 0.11570507314621326 because of step counter
# Final cost : 0.11570507314621326
# Compute control for a deterministic system
# Cost in iteration 0: 0.11570507314621326
# Converged in iteration 1 with cost 0.11570507314621326 because of step counter
# Final cost : 0.11570507314621326
# Compute control for a deterministic system
# Cost in iteration 0: 0.11570507314621326
# Converged in iteration 1 with cost 0.11570507314621326 because of step counter
# Final cost : 0.11570507314621326
# Compute control for a deterministic system
# Cost in iteration 0: 0.1236438311546754
# Converged in iteration 9 with cost 0.11881634285352079 because of step counter
# Final cost : 0.11881634285352079
# Compute control for a deterministic system
# Cost in iteration 0: 0.11881634285352079
# Converged in iteration 1 with cost 0.11881634285352079 because of step counter
# Final cost : 0.11881634285352079
# Compute control for a deterministic system
# Cost in iteration 0: 0.11881634285352079
# Converged in iteration 1 with cost 0.11881634285352079 because of step counter
# Final cost : 0.11881634285352079
# Compute control for a deterministic system
# Cost in iteration 0: 0.11881634285352079
# Converged in iteration 1 with cost 0.11881634285352079 because of step counter
# Final cost : 0.11881634285352079
# Compute control for a deterministic system
# Cost in iteration 0: 0.14022853370695987
# Converged in iteration 14 with cost 0.13086762453826659 because of step counter
# Final cost : 0.13086762453826659
# Compute control for a deterministic system
# Cost in iteration 0: 0.13086762453826659
# Converged in iteration 1 with cost 0.13086762453826659 because of step counter
# Final cost : 0.13086762453826659
# Compute control for a deterministic system
# Cost in iteration 0: 0.13086762453826659
# Converged in iteration 1 with cost 0.13086762453826659 because of step counter
# Final cost : 0.13086762453826659
# Compute control for a deterministic system
# Cost in iteration 0: 0.13086762453826659
# Converged in iteration 1 with cost 0.13086762453826659 because of step counter
# Final cost : 0.13086762453826659
# Compute control for a deterministic system
# Cost in iteration 0: 0.1430908807589827
# Converged in iteration 11 with cost 0.13693841530398687 because of step counter
# Final cost : 0.13693841530398687
# Compute control for a deterministic system
# Cost in iteration 0: 0.13693841530398687
# Converged in iteration 1 with cost 0.13693841530398687 because of step counter
# Final cost : 0.13693841530398687
# Compute control for a deterministic system
# Cost in iteration 0: 0.13693841530398687
# Converged in iteration 1 with cost 0.13693841530398687 because of step counter
# Final cost : 0.13693841530398687
# Compute control for a deterministic system
# Cost in iteration 0: 0.13693841530398687
# Converged in iteration 1 with cost 0.13693841530398687 because of step counter
# Final cost : 0.13693841530398687
# Compute control for a deterministic system
# Cost in iteration 0: 0.15186836035238288
# Converged in iteration 13 with cost 0.14609610870062917 because of step counter
# Final cost : 0.14609610870062917
# Compute control for a deterministic system
# Cost in iteration 0: 0.14609610870062917
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 1.0518282319536976
# Converged in iteration 1 with cost 1.0518282319536976 because of step counter
# Final cost : 1.0518282319536976
# Compute control for a deterministic system
# Cost in iteration 0: 1.0518282319536976
# Converged in iteration 1 with cost 1.0518282319536976 because of step counter
# Final cost : 1.0518282319536976
# Compute control for a deterministic system
# Cost in iteration 0: 1.1140008836929747
# Converged in iteration 1 with cost 1.1140008836929747 because of step counter
# Final cost : 1.1140008836929747
# Compute control for a deterministic system
# Cost in iteration 0: 1.1140008836929747
# Converged in iteration 1 with cost 1.1140008836929747 because of step counter
# Final cost : 1.1140008836929747
# Compute control for a deterministic system
# Cost in iteration 0: 1.1140008836929747
# Converged in iteration 1 with cost 1.1140008836929747 because of step counter
# Final cost : 1.1140008836929747
# Compute control for a deterministic system
# Cost in iteration 0: 1.1140008836929747
# Converged in iteration 1 with cost 1.1140008836929747 because of step counter
# Final cost : 1.1140008836929747
# Compute control for a deterministic system
# Cost in iteration 0: 1.1140008836929747
# Converged in iteration 1 with cost 1.1140008836929747 because of step counter
# Final cost : 1.1140008836929747
# Compute control for a deterministic system
# Cost in iteration 0: 0.5324738298804754
# Converged in iteration 14 with cost 0.5320797156912227 because of step counter
# Final cost : 0.5320797156912227
# Compute control for a deterministic system
# Cost in iteration 0: 0.5320797156912227
# Converged in iteration 1 with cost 0.5320797156912227 because of step counter
# Final cost : 0.5320797156912227
# Compute control for a deterministic system
# Cost in iteration 0: 0.5320797156912227
# Converged in iteration 1 with cost 0.5320797156912227 because of step counter
# Final cost : 0.5320797156912227
# Compute control for a deterministic system
# Cost in iteration 0: 0.5320797156912227
# Converged in iteration 1 with cost 0.5320797156912227 because of step counter
# Final cost : 0.5320797156912227
# Compute control for a deterministic system
# Cost in iteration 0: 0.5320797156912227
# Converged in iteration 1 with cost 0.5320797156912227 because of step counter
# Final cost : 0.5320797156912227
# Compute control for a deterministic system
# Cost in iteration 0: 0.49384730109520075
# Converged in iteration 8 with cost 0.4936555860591462 because of step counter
# Final cost : 0.4936555860591462
# Compute control for a deterministic system
# Cost in iteration 0: 0.4936555860591462
# Converged in iteration 1 with cost 0.4936555860591462 because of step counter
# Final cost : 0.4936555860591462
# Compute control for a deterministic system
# Cost in iteration 0: 0.4936555860591462
# Converged in iteration 1 with cost 0.4936555860591462 because of step counter
# Final cost : 0.4936555860591462
# Compute control for a deterministic system
# Cost in iteration 0: 0.4936555860591462
# Converged in iteration 1 with cost 0.4936555860591462 because of step counter
# Final cost : 0.4936555860591462
# Compute control for a deterministic system
# Cost in iteration 0: 0.4936555860591462
# Converged in iteration 1 with cost 0.4936555860591462 because of step counter
# Final cost : 0.4936555860591462
# Compute control for a deterministic system
# Cost in iteration 0: 0.4552313370729527
# Converged in iteration 8 with cost 0.45502485618176836 because of step counter
# Final cost : 0.45502485618176836
# Compute control for a deterministic system
# Cost in iteration 0: 0.45502485618176836
# Converged in iteration 1 with cost 0.45502485618176836 because of step counter
# Final cost : 0.45502485618176836
# Compute control for a deterministic system
# Cost in iteration 0: 0.45502485618176836
# Converged in iteration 1 with cost 0.45502485618176836 because of step counter
# Final cost : 0.45502485618176836
# Compute control for a deterministic system
# Cost in iteration 0: 0.45502485618176836
# Converged in iteration 1 with cost 0.45502485618176836 because of step counter
# Final cost : 0.45502485618176836
# Compute control for a deterministic system
# Cost in iteration 0: 0.45502485618176836
# Converged in iteration 1 with cost 0.45502485618176836 because of step counter
# Final cost : 0.45502485618176836
# Compute control for a deterministic system
# Cost in iteration 0: 0.42563352408015365
# Converged in iteration 11 with cost 0.42529923113669343 because of step counter
# Final cost : 0.42529923113669343
# Compute control for a deterministic system
# Cost in iteration 0: 0.42529923113669343
# Converged in iteration 1 with cost 0.42529923113669343 because of step counter
# Final cost : 0.42529923113669343
# Compute control for a deterministic system
# Cost in iteration 0: 0.42529923113669343
# Converged in iteration 1 with cost 0.42529923113669343 because of step counter
# Final cost : 0.42529923113669343
# Compute control for a deterministic system
# Cost in iteration 0: 0.42529923113669343
# Converged in iteration 1 with cost 0.42529923113669343 because of step counter
# Final cost : 0.42529923113669343
# Compute control for a deterministic system
# Cost in iteration 0: 0.42529923113669343
# Converged in iteration 1 with cost 0.42529923113669343 because of step counter
# Final cost : 0.42529923113669343
# Compute control for a deterministic system
# Cost in iteration 0: 0.3871292329261883
# Converged in iteration 9 with cost 0.38683246565641827 because of step counter
# Final cost : 0.38683246565641827
# Compute control for a deterministic system
# Cost in iteration 0: 0.38683246565641827
# Converged in iteration 1 with cost 0.38683246565641827 because of step counter
# Final cost : 0.38683246565641827
# Compute control for a deterministic system
# Cost in iteration 0: 0.38683246565641827
# Converged in iteration 1 with cost 0.38683246565641827 because of step counter
# Final cost : 0.38683246565641827
# Compute control for a deterministic system
# Cost in iteration 0: 0.38683246565641827
# Converged in iteration 1 with cost 0.38683246565641827 because of step counter
# Final cost : 0.38683246565641827
# Compute control for a deterministic system
# Cost in iteration 0: 0.38683246565641827
# Converged in iteration 1 with cost 0.38683246565641827 because of step counter
# Final cost : 0.38683246565641827
# Compute control for a deterministic system
# Cost in iteration 0: 0.35037354644883856
# Converged in iteration 10 with cost 0.35006744451872024 because of step counter
# Final cost : 0.35006744451872024
# Compute control for a deterministic system
# Cost in iteration 0: 0.35006744451872024
# Converged in iteration 1 with cost 0.35006744451872024 because of step counter
# Final cost : 0.35006744451872024
# Compute control for a deterministic system
# Cost in iteration 0: 0.35006744451872024
# Converged in iteration 1 with cost 0.35006744451872024 because of step counter
# Final cost : 0.35006744451872024
# Compute control for a deterministic system
# Cost in iteration 0: 0.35006744451872024
# Converged in iteration 1 with cost 0.35006744451872024 because of step counter
# Final cost : 0.35006744451872024
# Compute control for a deterministic system
# Cost in iteration 0: 0.35006744451872024
# Converged in iteration 1 with cost 0.35006744451872024 because of step counter
# Final cost : 0.35006744451872024
# Compute control for a deterministic system
# Cost in iteration 0: 0.32259843436432295
# Converged in iteration 7 with cost 0.3223901302894865 because of step counter
# Final cost : 0.3223901302894865
# Compute control for a deterministic system
# Cost in iteration 0: 0.3223901302894865
# Converged in iteration 1 with cost 0.3223901302894865 because of step counter
# Final cost : 0.3223901302894865
# Compute control for a deterministic system
# Cost in iteration 0: 0.3223901302894865
# Converged in iteration 1 with cost 0.3223901302894865 because of step counter
# Final cost : 0.3223901302894865
# Compute control for a deterministic system
# Cost in iteration 0: 0.3223901302894865
# Converged in iteration 1 with cost 0.3223901302894865 because of step counter
# Final cost : 0.3223901302894865
# Compute control for a deterministic system
# Cost in iteration 0: 0.3223901302894865
# Converged in iteration 1 with cost 0.3223901302894865 because of step counter
# Final cost : 0.3223901302894865
# Compute control for a deterministic system
# Cost in iteration 0: 0.2851546836515735
# Converged in iteration 5 with cost 0.2850857437934159 because of step counter
# Final cost : 0.2850857437934159
# Compute control for a deterministic system
# Cost in iteration 0: 0.2850857437934159
# Converged in iteration 1 with cost 0.2850857437934159 because of step counter
# Final cost : 0.2850857437934159
# Compute control for a deterministic system
# Cost in iteration 0: 0.2850857437934159
# Converged in iteration 1 with cost 0.2850857437934159 because of step counter
# Final cost : 0.2850857437934159
# Compute control for a deterministic system
# Cost in iteration 0: 0.2850857437934159
# Converged in iteration 1 with cost 0.2850857437934159 because of step counter
# Final cost : 0.2850857437934159
# Compute control for a deterministic system
# Cost in iteration 0: 0.2850857437934159
# Converged in iteration 1 with cost 0.2850857437934159 because of step counter
# Final cost : 0.2850857437934159
# Compute control for a deterministic system
# Cost in iteration 0: 0.24716995445661794
# Converged in iteration 2 with cost 0.24716991227075003 because of step counter
# Final cost : 0.24716991227075003
# Compute control for a deterministic system
# Cost in iteration 0: 0.24716991227075003
# Converged in iteration 1 with cost 0.24716991227075003 because of step counter
# Final cost : 0.24716991227075003
# Compute control for a deterministic system
# Cost in iteration 0: 0.24716991227075003
# Converged in iteration 1 with cost 0.24716991227075003 because of step counter
# Final cost : 0.24716991227075003
# Compute control for a deterministic system
# Cost in iteration 0: 0.24716991227075003
# Converged in iteration 1 with cost 0.24716991227075003 because of step counter
# Final cost : 0.24716991227075003
# Compute control for a deterministic system
# Cost in iteration 0: 0.24716991227075003
# Converged in iteration 1 with cost 0.24716991227075003 because of step counter
# Final cost : 0.24716991227075003
# Compute control for a deterministic system
# Cost in iteration 0: 0.20874441047136347
# Converged in iteration 1 with cost 0.20874441047136347 because of step counter
# Final cost : 0.20874441047136347
# Compute control for a deterministic system
# Cost in iteration 0: 0.20874441047136347
# Converged in iteration 1 with cost 0.20874441047136347 because of step counter
# Final cost : 0.20874441047136347
# Compute control for a deterministic system
# Cost in iteration 0: 0.20874441047136347
# Converged in iteration 1 with cost 0.20874441047136347 because of step counter
# Final cost : 0.20874441047136347
# Compute control for a deterministic system
# Cost in iteration 0: 0.20874441047136347
# Converged in iteration 1 with cost 0.20874441047136347 because of step counter
# Final cost : 0.20874441047136347
# Compute control for a deterministic system
# Cost in iteration 0: 0.20874441047136347
# Converged in iteration 1 with cost 0.20874441047136347 because of step counter
# Final cost : 0.20874441047136347
# Compute control for a deterministic system
# Cost in iteration 0: 0.17746736142800212
# Converged in iteration 1 with cost 0.17746736142800212 because of step counter
# Final cost : 0.17746736142800212
# Compute control for a deterministic system
# Cost in iteration 0: 0.17746736142800212
# Converged in iteration 1 with cost 0.17746736142800212 because of step counter
# Final cost : 0.17746736142800212
# Compute control for a deterministic system
# Cost in iteration 0: 0.17746736142800212
# Converged in iteration 1 with cost 0.17746736142800212 because of step counter
# Final cost : 0.17746736142800212
# Compute control for a deterministic system
# Cost in iteration 0: 0.17746736142800212
# Converged in iteration 1 with cost 0.17746736142800212 because of step counter
# Final cost : 0.17746736142800212
# Compute control for a deterministic system
# Cost in iteration 0: 0.17746736142800212
# Converged in iteration 1 with cost 0.17746736142800212 because of step counter
# Final cost : 0.17746736142800212
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366496038196596
# Converged in iteration 1 with cost 0.1366496038196596 because of step counter
# Final cost : 0.1366496038196596
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366496038196596
# Converged in iteration 1 with cost 0.1366496038196596 because of step counter
# Final cost : 0.1366496038196596
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366496038196596
# Converged in iteration 1 with cost 0.1366496038196596 because of step counter
# Final cost : 0.1366496038196596
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366496038196596
# Converged in iteration 1 with cost 0.1366496038196596 because of step counter
# Final cost : 0.1366496038196596
# Compute control for a deterministic system
# Cost in iteration 0: 0.1366496038196596
# Converged in iteration 1 with cost 0.1366496038196596 because of step counter
# Final cost : 0.1366496038196596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950096852425158
# Converged in iteration 1 with cost 0.0950096852425158 because of step counter
# Final cost : 0.0950096852425158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950096852425158
# Converged in iteration 1 with cost 0.0950096852425158 because of step counter
# Final cost : 0.0950096852425158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950096852425158
# Converged in iteration 1 with cost 0.0950096852425158 because of step counter
# Final cost : 0.0950096852425158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950096852425158
# Converged in iteration 1 with cost 0.0950096852425158 because of step counter
# Final cost : 0.0950096852425158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950096852425158
# Converged in iteration 1 with cost 0.0950096852425158 because of step counter
# Final cost : 0.0950096852425158
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212271363891095
# Converged in iteration 2 with cost 0.05212252844573419 because of step counter
# Final cost : 0.05212252844573419
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212252844573419
# Converged in iteration 1 with cost 0.05212252844573419 because of step counter
# Final cost : 0.05212252844573419
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212252844573419
# Converged in iteration 1 with cost 0.05212252844573419 because of step counter
# Final cost : 0.05212252844573419
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212252844573419
# Converged in iteration 1 with cost 0.05212252844573419 because of step counter
# Final cost : 0.05212252844573419
# Compute control for a deterministic system
# Cost in iteration 0: 0.05212252844573419
# Converged in iteration 1 with cost 0.05212252844573419 because of step counter
# Final cost : 0.05212252844573419
# Compute control for a deterministic system
# Cost in iteration 0: 0.018337431663357103
# Converged in iteration 1 with cost 0.018337431663357103 because of step counter
# Final cost : 0.018337431663357103
# Compute control for a deterministic system
# Cost in iteration 0: 0.018337431663357103
# Converged in iteration 1 with cost 0.018337431663357103 because of step counter
# Final cost : 0.018337431663357103
# Compute control for a deterministic system
# Cost in iteration 0: 0.018337431663357103
# Converged in iteration 1 with cost 0.018337431663357103 because of step counter
# Final cost : 0.018337431663357103
# Compute control for a deterministic system
# Cost in iteration 0: 0.018337431663357103
# Converged in iteration 1 with cost 0.018337431663357103 because of step counter
# Final cost : 0.018337431663357103
# Compute control for a deterministic system
# Cost in iteration 0: 0.018337431663357103
# Converged in iteration 1 with cost 0.018337431663357103 because of step counter
# Final cost : 0.018337431663357103

# %%
save(results_peak)
