# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

wc.params.c_inhexc = 16
wc.params.c_excinh = 10
wc.params.c_inhinh = 1

duration = 200.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.04201540010391125
y_init = 0.1354067401509556
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

print(period)

init_min = [wc.exc[0,4], wc.inh[0,4]]
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# 13.908333333333335
# minima =  [ 122  261  400  539  678  817  956 1095 1234 1373 1512 1651 1790 1929]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.8
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("e_s1_l2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("e_s1_l2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 results_min = read()
#
# Cell In [7], line 7, in read()
#       6 def read():
# ----> 7     filehandler = open("s1_l2_otherparams.pickle","rb")
#       8     results_dict = pickle.load(filehandler)
#       9     filehandler.close()
#
# File ~/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 's1_l2_otherparams.pickle'

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])

ind_list = []
options = [True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)

            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        save(results_min)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = (0.95+np.random.random()*0.1)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

            save(results_min)

        if options[2]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)
                
            save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.024609993103107897
# Final cost : 0.017400681292670833
# Compute control for a deterministic system
# Cost in iteration 0: 0.017400681292670833
# Converged in iteration 20 with cost 0.01739868489528963 because of vanishing difference
# Final cost : 0.01739868489528963
# Compute control for a deterministic system
# Cost in iteration 0: 0.01739868489528963
# Converged in iteration 9 with cost 0.017398684838844387 because of step counter
# Final cost : 0.017398684838844387
# Compute control for a deterministic system
# Cost in iteration 0: 0.017398684838844387
# Converged in iteration 3 with cost 0.01739868483884404 because of step counter
# Final cost : 0.01739868483884404
# Compute control for a deterministic system
# Cost in iteration 0: 0.01739868483884404
# Converged in iteration 2 with cost 0.017398684838844033 because of step counter
# Final cost : 0.017398684838844033
# Compute control for a deterministic system
# Cost in iteration 0: 0.13192734907423795
# Final cost : 0.049718439818006215
# Compute control for a deterministic system
# Cost in iteration 0: 0.049718439818006215
# Converged in iteration 72 with cost 0.04805499797698781 because of vanishing difference
# Final cost : 0.04805499797698781
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499797698781
# Converged in iteration 19 with cost 0.04805499746432924 because of step counter
# Final cost : 0.04805499746432924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499746432924
# Converged in iteration 1 with cost 0.04805499746432924 because of step counter
# Final cost : 0.04805499746432924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499746432924
# Converged in iteration 1 with cost 0.04805499746432924 because of step counter
# Final cost : 0.04805499746432924
# Compute control for a deterministic system
# Cost in iteration 0: 0.26408668028094134
# Final cost : 0.07401735115743215
# Compute control for a deterministic system
# Cost in iteration 0: 0.07401735115743215
# Converged in iteration 117 with cost 0.07080054480344537 because of vanishing difference
# Final cost : 0.07080054480344537
# Compute control for a deterministic system
# Cost in iteration 0: 0.07080054480344537
# Converged in iteration 29 with cost 0.0708005447742605 because of step counter
# Final cost : 0.0708005447742605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0708005447742605
# Converged in iteration 1 with cost 0.0708005447742605 because of step counter
# Final cost : 0.0708005447742605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0708005447742605
# Converged in iteration 2 with cost 0.0708005447742603 because of step counter
# Final cost : 0.0708005447742603
# Compute control for a deterministic system
# Cost in iteration 0: 0.49983528966731283
# Final cost : 0.10583531775745682
# Compute control for a deterministic system
# Cost in iteration 0: 0.10583531775745682
# Converged in iteration 142 with cost 0.10004225112105533 because of vanishing difference
# Final cost : 0.10004225112105533
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004225112105533
# Converged in iteration 65 with cost 0.10004224982202922 because of step counter
# Final cost : 0.10004224982202922
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004224982202922
# Converged in iteration 2 with cost 0.10004224982202857 because of step counter
# Final cost : 0.10004224982202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004224982202857
# Converged in iteration 1 with cost 0.10004224982202857 because of step counter
# Final cost : 0.10004224982202857
# Compute control for a deterministic system
# Cost in iteration 0: 0.7135901274853022
# Final cost : 0.1292296817370093
# Compute control for a deterministic system
# Cost in iteration 0: 0.1292296817370093
# Converged in iteration 145 with cost 0.12090907840354716 because of vanishing difference
# Final cost : 0.12090907840354716
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907840354716
# Cost in iteration 200: 0.12090907400398589
# Final cost : 0.12090907400398589
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907400398589
# Converged in iteration 8 with cost 0.12090907400348522 because of step counter
# Final cost : 0.12090907400348522
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907400348522
# Converged in iteration 2 with cost 0.12090907400348484 because of step counter
# Final cost : 0.12090907400348484
# Compute control for a deterministic system
# Cost in iteration 0: 1.0356361273923607
# Final cost : 0.16003778135072644
# Compute control for a deterministic system
# Cost in iteration 0: 0.16003778135072644
# Cost in iteration 200: 0.14717039441155286
# Final cost : 0.14717039441155286
# Compute control for a deterministic system
# Cost in iteration 0: 0.14717039441155286
# Converged in iteration 77 with cost 0.1471703841431301 because of step counter
# Final cost : 0.1471703841431301
# Compute control for a deterministic system
# Cost in iteration 0: 0.1471703841431301
# Converged in iteration 1 with cost 0.1471703841431301 because of step counter
# Final cost : 0.1471703841431301
# Compute control for a deterministic system
# Cost in iteration 0: 0.1471703841431301
# Converged in iteration 1 with cost 0.1471703841431301 because of step counter
# Final cost : 0.1471703841431301
# Compute control for a deterministic system
# Cost in iteration 0: 1.2963560838704185
# Final cost : 0.18309042257968675
# Compute control for a deterministic system
# Cost in iteration 0: 0.18309042257968675
# Cost in iteration 200: 0.1656918807205347
# Final cost : 0.1656918807205347
# Compute control for a deterministic system
# Cost in iteration 0: 0.1656918807205347
# Cost in iteration 200: 0.1656917638037251
# Final cost : 0.1656917638037251
# Compute control for a deterministic system
# Cost in iteration 0: 0.1656917638037251
# Converged in iteration 3 with cost 0.1656917638037225 because of step counter
# Final cost : 0.1656917638037225
# Compute control for a deterministic system
# Cost in iteration 0: 0.1656917638037225
# Converged in iteration 2 with cost 0.16569176380372228 because of step counter
# Final cost : 0.16569176380372228
# Compute control for a deterministic system
# Cost in iteration 0: 1.6570365908526377
# Final cost : 0.2141143209947994
# Compute control for a deterministic system
# Cost in iteration 0: 0.2141143209947994
# Cost in iteration 200: 0.18889380243469805
# Final cost : 0.18889380243469805
# Compute control for a deterministic system
# Cost in iteration 0: 0.18889380243469805
# Converged in iteration 49 with cost 0.188890697552549 because of vanishing difference
# Final cost : 0.188890697552549
# Compute control for a deterministic system
# Cost in iteration 0: 0.188890697552549
# Cost in iteration 200: 0.18889015002863532
# Cost in iteration 400: 0.18889014988644842
# Final cost : 0.18889014988644842
# Compute control for a deterministic system
# Cost in iteration 0: 0.18889014988644842
# Converged in iteration 14 with cost 0.18889014988642044 because of step counter
# Final cost : 0.18889014988642044
# Compute control for a deterministic system
# Cost in iteration 0: 1.92924548614514
# Final cost : 0.2378367707423715
# Compute control for a deterministic system
# Cost in iteration 0: 0.2378367707423715
# Cost in iteration 200: 0.20525622902053176
# Final cost : 0.20525622902053176
# Compute control for a deterministic system
# Cost in iteration 0: 0.20525622902053176
# Converged in iteration 54 with cost 0.2052412228960594 because of vanishing difference
# Final cost : 0.2052412228960594
# Compute control for a deterministic system
# Cost in iteration 0: 0.2052412228960594
# Cost in iteration 200: 0.2052369001048357
# Cost in iteration 400: 0.20523688866112075
# Final cost : 0.20523688866112075
# Compute control for a deterministic system
# Cost in iteration 0: 0.20523688866112075
# Converged in iteration 161 with cost 0.20523688863128092 because of step counter
# Final cost : 0.20523688863128092
# Compute control for a deterministic system
# Cost in iteration 0: 2.2837615791922388
# Final cost : 0.27042471854373196
# Compute control for a deterministic system
# Cost in iteration 0: 0.27042471854373196
# Cost in iteration 200: 0.2258176066193999
# Final cost : 0.2258176066193999
# Compute control for a deterministic system
# Cost in iteration 0: 0.2258176066193999
# Converged in iteration 131 with cost 0.22573940853368402 because of vanishing difference
# Final cost : 0.22573940853368402
# Compute control for a deterministic system
# Cost in iteration 0: 0.22573940853368402
# Cost in iteration 200: 0.22573399826262752
# Converged in iteration 299 with cost 0.22573399824004114 because of vanishing difference
# Final cost : 0.22573399824004114
# Compute control for a deterministic system
# Cost in iteration 0: 0.22573399824004114
# Converged in iteration 3 with cost 0.22573399824003446 because of step counter
# Final cost : 0.22573399824003446
# Compute control for a deterministic system
# Cost in iteration 0: 2.5369298860929104
# Final cost : 0.2958371356229431
# Compute control for a deterministic system
# Cost in iteration 0: 0.2958371356229431
# Cost in iteration 200: 0.24036888467835005
# Final cost : 0.24036888467835005
# Compute control for a deterministic system
# Cost in iteration 0: 0.24036888467835005
# Cost in iteration 200: 0.2401896874728665
# Final cost : 0.2401896874728665
# Compute control for a deterministic system
# Cost in iteration 0: 0.2401896874728665
# Converged in iteration 1 with cost 0.2401896874728665 because of vanishing difference
# Final cost : 0.2401896874728665
# Compute control for a deterministic system
# Cost in iteration 0: 0.2401896874728665
# Cost in iteration 200: 0.24018413635672692
# Cost in iteration 400: 0.2401840334212638
# Cost in iteration 600: 0.24018403226219856
# Cost in iteration 800: 0.24018403225095727
# Converged in iteration 887 with cost 0.24018403225082474 because of step counter
# Final cost : 0.24018403225082474
# Compute control for a deterministic system
# Cost in iteration 0: 2.8492814793090684
# Final cost : 0.3314293227758079
# Compute control for a deterministic system
# Cost in iteration 0: 0.3314293227758079
# Cost in iteration 200: 0.2587326736272777
# Final cost : 0.2587326736272777
# Compute control for a deterministic system
# Cost in iteration 0: 0.2587326736272777
# Cost in iteration 200: 0.2582679432696849
# Final cost : 0.2582679432696849
# Compute control for a deterministic system
# Cost in iteration 0: 0.2582679432696849
# Cost in iteration 200: 0.25823326597915164
# Cost in iteration 400: 0.2582324343279202
# Final cost : 0.2582324343279202
# Compute control for a deterministic system
# Cost in iteration 0: 0.2582324343279202
# Cost in iteration 200: 0.2582324130321807
# Cost in iteration 400: 0.25823241184431717
# Cost in iteration 600: 0.25823241177660783
# Cost in iteration 800: 0.2582324117727832
# Converged in iteration 854 with cost 0.25823241177266154 because of vanishing difference
# Final cost : 0.25823241177266154
# Compute control for a deterministic system
# Cost in iteration 0: 3.0597816555520736
# Final cost : 0.3597741801555112
# Compute control for a deterministic system
# Cost in iteration 0: 0.3597741801555112
# Cost in iteration 200: 0.27164600475512574
# Final cost : 0.27164600475512574
# Compute control for a deterministic system
# Cost in iteration 0: 0.27164600475512574
# Converged in iteration 141 with cost 0.27086401672852917 because of vanishing difference
# Final cost : 0.27086401672852917
# Compute control for a deterministic system
# Cost in iteration 0: 0.27086401672852917
# Cost in iteration 200: 0.2708202733781026
# Cost in iteration 400: 0.2708174752558121
# Final cost : 0.2708174752558121
# Compute control for a deterministic system
# Cost in iteration 0: 0.2708174752558121
# Cost in iteration 200: 0.2708173029082465
# Cost in iteration 400: 0.2708172869455814
# Cost in iteration 600: 0.2708172854513153
# Cost in iteration 800: 0.27081728531306515
# Cost in iteration 1000: 0.2708172853002433
# Final cost : 0.2708172853002433
# Compute control for a deterministic system
# Cost in iteration 0: 3.303294856427288
# Final cost : 0.40078877996638457
# Compute control for a deterministic system
# Cost in iteration 0: 0.40078877996638457
# Cost in iteration 200: 0.2878085547147679
# Final cost : 0.2878085547147679
# Compute control for a deterministic system
# Cost in iteration 0: 0.2878085547147679
# Cost in iteration 200: 0.286322519463035
# Final cost : 0.286322519463035
# Compute control for a deterministic system
# Cost in iteration 0: 0.286322519463035
# Cost in iteration 200: 0.2862855172764007
# Cost in iteration 400: 0.28628086748606657
# Final cost : 0.28628086748606657
# Compute control for a deterministic system
# Cost in iteration 0: 0.28628086748606657
# Cost in iteration 200: 0.28628025885855657
# Cost in iteration 400: 0.2862801647780743
# Cost in iteration 600: 0.286280150180213
# Cost in iteration 800: 0.2862801479200003
# Cost in iteration 1000: 0.28628014756970865
# Final cost : 0.28628014756970865
# Compute control for a deterministic system
# Cost in iteration 0: 3.455673491700305
# Final cost : 0.43545817555705124
# Compute control for a deterministic system
# Cost in iteration 0: 0.43545817555705124
# Cost in iteration 200: 0.2991582133477292
# Final cost : 0.2991582133477292
# Compute control for a deterministic system
# Cost in iteration 0: 0.2991582133477292
# Cost in iteration 200: 0.29705583792388934
# Final cost : 0.29705583792388934
# Compute control for a deterministic system
# Cost in iteration 0: 0.29705583792388934
# Converged in iteration 152 with cost 0.29696021939381817 because of vanishing difference
# Final cost : 0.29696021939381817
# Compute control for a deterministic system
# Cost in iteration 0: 0.29696021939381817
# Cost in iteration 200: 0.29693263930852626
# Cost in iteration 400: 0.29692692594890824
# Cost in iteration 600: 0.2969257301065618
# Cost in iteration 800: 0.29692548009749414
# Cost in iteration 1000: 0.29692543644077823
# Final cost : 0.29692543644077823
# Compute control for a deterministic system
# Cost in iteration 0: 3.6166589248798404
# Final cost : 0.4909744959334989
# Compute control for a deterministic system
# Cost in iteration 0: 0.4909744959334989
# Cost in iteration 200: 0.3137290196929495
# Final cost : 0.3137290196929495
# Compute control for a deterministic system
# Cost in iteration 0: 0.3137290196929495
# Cost in iteration 200: 0.31040011314684113
# Final cost : 0.31040011314684113
# Compute control for a deterministic system
# Cost in iteration 0: 0.31040011314684113
# Cost in iteration 200: 0.31009024218772974
# Cost in iteration 400: 0.31001839497036743
# Final cost : 0.31001839497036743
# Compute control for a deterministic system
# Cost in iteration 0: 0.31001839497036743
# Cost in iteration 200: 0.30999608906690074
# Cost in iteration 400: 0.3099957397207009
# Cost in iteration 600: 0.3099957279733161
# Cost in iteration 800: 0.3099957275284754
# Cost in iteration 1000: 0.30999572751164467
# Final cost : 0.30999572751164467
# Compute control for a deterministic system
# Cost in iteration 0: 3.7053975873840708
# Final cost : 0.542859938718001
# Compute control for a deterministic system
# Cost in iteration 0: 0.542859938718001
# Cost in iteration 200: 0.32424439088976076
# Final cost : 0.32424439088976076
# Compute control for a deterministic system
# Cost in iteration 0: 0.32424439088976076
# Cost in iteration 200: 0.31989925599267305
# Final cost : 0.31989925599267305
# Compute control for a deterministic system
# Cost in iteration 0: 0.31989925599267305
# Converged in iteration 101 with cost 0.3195211097499982 because of vanishing difference
# Final cost : 0.3195211097499982
# Compute control for a deterministic system
# Cost in iteration 0: 0.3195211097499982
# Cost in iteration 200: 0.31911038009094955
# Cost in iteration 400: 0.3190822165976746
# Cost in iteration 600: 0.3190788140669855
# Cost in iteration 800: 0.31907841514870494
# Cost in iteration 1000: 0.31907835996068346
# Final cost : 0.31907835996068346
# Compute control for a deterministic system
# Cost in iteration 0: 3.78157517872759
# Final cost : 0.627994934924219
# Compute control for a deterministic system
# Cost in iteration 0: 0.627994934924219
# Cost in iteration 200: 0.3396037985637773
# Final cost : 0.3396037985637773
# Compute control for a deterministic system
# Cost in iteration 0: 0.3396037985637773
# Cost in iteration 200: 0.33235122552529384
# Final cost : 0.33235122552529384
# Compute control for a deterministic system
# Cost in iteration 0: 0.33235122552529384
# Cost in iteration 200: 0.33112661290425616
# Converged in iteration 294 with cost 0.33086602768148615 because of vanishing difference
# Final cost : 0.33086602768148615
# Compute control for a deterministic system
# Cost in iteration 0: 0.33086602768148615
# Cost in iteration 200: 0.33050999191870645
# Cost in iteration 400: 0.330437293412035
# Cost in iteration 600: 0.3304204586542003
# Cost in iteration 800: 0.33041615735581353
# Cost in iteration 1000: 0.33041502720950167
# Final cost : 0.33041502720950167
# Compute control for a deterministic system
# Cost in iteration 0: 3.8080601254189257
# Final cost : 0.7107472837696698
# Compute control for a deterministic system
# Cost in iteration 0: 0.7107472837696698
# Cost in iteration 200: 0.35377049218229895
# Final cost : 0.35377049218229895
# Compute control for a deterministic system
# Cost in iteration 0: 0.35377049218229895
# Cost in iteration 200: 0.34206121549437524
# Final cost : 0.34206121549437524
# Compute control for a deterministic system
# Cost in iteration 0: 0.34206121549437524
# Cost in iteration 200: 0.3399792666408118
# Cost in iteration 400: 0.3391308351573857
# Final cost : 0.3391308351573857
# Compute control for a deterministic system
# Cost in iteration 0: 0.3391308351573857
# Cost in iteration 200: 0.33867820409886856
# Cost in iteration 400: 0.338548698884925
# Cost in iteration 600: 0.3385033328413951
# Cost in iteration 800: 0.3384851045406433
# Cost in iteration 1000: 0.3384786240536158
# Final cost : 0.3384786240536158
# Compute control for a deterministic system
# Cost in iteration 0: 3.804573947971724
# Final cost : 0.9820104230425969
# Compute control for a deterministic system
# Cost in iteration 0: 0.9820104230425969
# Cost in iteration 200: 0.40510770376096816
# Final cost : 0.40510770376096816
# Compute control for a deterministic system
# Cost in iteration 0: 0.40510770376096816
# Cost in iteration 200: 0.35974806498998396
# Final cost : 0.35974806498998396
# Compute control for a deterministic system
# Cost in iteration 0: 0.35974806498998396
# Cost in iteration 200: 0.3534992109479122
# Cost in iteration 400: 0.351203542762266
# Final cost : 0.351203542762266
# Compute control for a deterministic system
# Cost in iteration 0: 0.351203542762266
# Cost in iteration 200: 0.3497627300117283
# Cost in iteration 400: 0.3492570797161914
# Cost in iteration 600: 0.3490267450417299
# Cost in iteration 800: 0.34892161834956004
# Cost in iteration 1000: 0.34887675266156765
# Final cost : 0.34887675266156765
# Compute control for a deterministic system
# Cost in iteration 0: 3.7743668336161345
# Final cost : 2.156375947908594
# Compute control for a deterministic system
# Cost in iteration 0: 2.156375947908594
# Cost in iteration 200: 0.8221749469819608
# Final cost : 0.8221749469819608
# Compute control for a deterministic system
# Cost in iteration 0: 0.8221749469819608
# Cost in iteration 200: 0.807246376427616
# Final cost : 0.807246376427616
# Compute control for a deterministic system
# Cost in iteration 0: 0.807246376427616
# Cost in iteration 200: 0.8001495541700138
# Cost in iteration 400: 0.7953250319662255
# Final cost : 0.7953250319662255
# Compute control for a deterministic system
# Cost in iteration 0: 0.7953250319662255
# Cost in iteration 200: 0.7951642072887694
# Converged in iteration 210 with cost 0.7951628792420786 because of vanishing difference
# Final cost : 0.7951628792420786
# Compute control for a deterministic system
# Cost in iteration 0: 3.721460276635831
# Final cost : 1.5392483718455225
# Compute control for a deterministic system
# Cost in iteration 0: 1.5392483718455225
# Cost in iteration 200: 0.7725435328465732
# Final cost : 0.7725435328465732
# Compute control for a deterministic system
# Cost in iteration 0: 0.7725435328465732
# Cost in iteration 200: 0.7620348881605665
# Final cost : 0.7620348881605665
# Compute control for a deterministic system
# Cost in iteration 0: 0.7620348881605665
# Cost in iteration 200: 0.7556245754890962
# Cost in iteration 400: 0.7511768949505995
# Final cost : 0.7511768949505995
# Compute control for a deterministic system
# Cost in iteration 0: 0.7511768949505995
# Converged in iteration 153 with cost 0.7510644884502005 because of vanishing difference
# Final cost : 0.7510644884502005
# Compute control for a deterministic system
# Cost in iteration 0: 3.616409184326839
# Final cost : 1.236045312501047
# Compute control for a deterministic system
# Cost in iteration 0: 1.236045312501047
# Cost in iteration 200: 0.7095793903163532
# Final cost : 0.7095793903163532
# Compute control for a deterministic system
# Cost in iteration 0: 0.7095793903163532
# Cost in iteration 200: 0.7013383716780466
# Final cost : 0.7013383716780466
# Compute control for a deterministic system
# Cost in iteration 0: 0.7013383716780466
# Cost in iteration 200: 0.6962385011710462
# Cost in iteration 400: 0.6933350597321574
# Final cost : 0.6933350597321574
# Compute control for a deterministic system
# Cost in iteration 0: 0.6933350597321574
# Converged in iteration 121 with cost 0.6933055152526604 because of vanishing difference
# Final cost : 0.6933055152526604
# Compute control for a deterministic system
# Cost in iteration 0: 3.5121674986553106
# Final cost : 1.0728265651197346
# Compute control for a deterministic system
# Cost in iteration 0: 1.0728265651197346
# Cost in iteration 200: 0.6640377857988508
# Final cost : 0.6640377857988508
# Compute control for a deterministic system
# Cost in iteration 0: 0.6640377857988508
# Cost in iteration 200: 0.6577193215971064
# Final cost : 0.6577193215971064
# Compute control for a deterministic system
# Cost in iteration 0: 0.6577193215971064
# Cost in iteration 200: 0.6533772010447227
# Cost in iteration 400: 0.6507732255622573
# Final cost : 0.6507732255622573
# Compute control for a deterministic system
# Cost in iteration 0: 0.6507732255622573
# Converged in iteration 109 with cost 0.6507439264610513 because of vanishing difference
# Final cost : 0.6507439264610513
# Compute control for a deterministic system
# Cost in iteration 0: 3.339916684525563
# Final cost : 0.896602142033241
# Compute control for a deterministic system
# Cost in iteration 0: 0.896602142033241
# Cost in iteration 200: 0.6050890231897575
# Final cost : 0.6050890231897575
# Compute control for a deterministic system
# Cost in iteration 0: 0.6050890231897575
# Cost in iteration 200: 0.6003336135810576
# Final cost : 0.6003336135810576
# Compute control for a deterministic system
# Cost in iteration 0: 0.6003336135810576
# Cost in iteration 200: 0.5970997797078352
# Cost in iteration 400: 0.5950021040289921
# Final cost : 0.5950021040289921
# Compute control for a deterministic system
# Cost in iteration 0: 0.5950021040289921
# Converged in iteration 103 with cost 0.5949726072171568 because of vanishing difference
# Final cost : 0.5949726072171568
# Compute control for a deterministic system
# Cost in iteration 0: 3.1863779748607395
# Final cost : 0.786176083875346
# Compute control for a deterministic system
# Cost in iteration 0: 0.786176083875346
# Cost in iteration 200: 0.5620147056386008
# Final cost : 0.5620147056386008
# Compute control for a deterministic system
# Cost in iteration 0: 0.5620147056386008
# Cost in iteration 200: 0.5581464862709108
# Final cost : 0.5581464862709108
# Compute control for a deterministic system
# Cost in iteration 0: 0.5581464862709108
# Cost in iteration 200: 0.5556846569612404
# Cost in iteration 400: 0.5540758343867707
# Final cost : 0.5540758343867707
# Compute control for a deterministic system
# Cost in iteration 0: 0.5540758343867707
# Converged in iteration 114 with cost 0.5538862812239732 because of vanishing difference
# Final cost : 0.5538862812239732
# Compute control for a deterministic system
# Cost in iteration 0: 2.9504299029740193
# Final cost : 0.6606080523668849
# Compute control for a deterministic system
# Cost in iteration 0: 0.6606080523668849
# Cost in iteration 200: 0.5059273955490797
# Final cost : 0.5059273955490797
# Compute control for a deterministic system
# Cost in iteration 0: 0.5059273955490797
# Cost in iteration 200: 0.5029876195331034
# Final cost : 0.5029876195331034
# Compute control for a deterministic system
# Cost in iteration 0: 0.5029876195331034
# Cost in iteration 200: 0.5014662150527588
# Cost in iteration 400: 0.500511811241823
# Final cost : 0.500511811241823
# Compute control for a deterministic system
# Cost in iteration 0: 0.500511811241823
# Cost in iteration 200: 0.5001187158154231
# Converged in iteration 219 with cost 0.5001186042655552 because of vanishing difference
# Final cost : 0.5001186042655552
# Compute control for a deterministic system
# Cost in iteration 0: 2.751287431114256
# Final cost : 0.5794278194981792
# Compute control for a deterministic system
# Cost in iteration 0: 0.5794278194981792
# Cost in iteration 200: 0.46480543390358287
# Final cost : 0.46480543390358287
# Compute control for a deterministic system
# Cost in iteration 0: 0.46480543390358287
# Cost in iteration 200: 0.4626385191619228
# Final cost : 0.4626385191619228
# Compute control for a deterministic system
# Cost in iteration 0: 0.4626385191619228
# Cost in iteration 200: 0.46165282240516625
# Cost in iteration 400: 0.4610510104891695
# Final cost : 0.4610510104891695
# Compute control for a deterministic system
# Cost in iteration 0: 0.4610510104891695
# Cost in iteration 200: 0.460574872255426
# Converged in iteration 393 with cost 0.4605655649706382 because of vanishing difference
# Final cost : 0.4605655649706382
# Compute control for a deterministic system
# Cost in iteration 0: 2.458885883466965
# Final cost : 0.4850970237703842
# Compute control for a deterministic system
# Cost in iteration 0: 0.4850970237703842
# Cost in iteration 200: 0.4111881979019439
# Final cost : 0.4111881979019439
# Compute control for a deterministic system
# Cost in iteration 0: 0.4111881979019439
# Cost in iteration 200: 0.41003240021693443
# Final cost : 0.41003240021693443
# Compute control for a deterministic system
# Cost in iteration 0: 0.41003240021693443
# Cost in iteration 200: 0.409517363522719
# Cost in iteration 400: 0.4092161949605808
# Final cost : 0.4092161949605808
# Compute control for a deterministic system
# Cost in iteration 0: 0.4092161949605808
# Cost in iteration 200: 0.40900517764881195
# Cost in iteration 400: 0.40892214046129044
# Cost in iteration 600: 0.408891228139987
# Cost in iteration 800: 0.40888245218393393
# Cost in iteration 1000: 0.4088797768244433
# Final cost : 0.4088797768244433
# Compute control for a deterministic system
# Cost in iteration 0: 2.2220856569695906
# Final cost : 0.4230444204677223
# Compute control for a deterministic system
# Cost in iteration 0: 0.4230444204677223
# Cost in iteration 200: 0.3718744967967593
# Final cost : 0.3718744967967593
# Compute control for a deterministic system
# Cost in iteration 0: 0.3718744967967593
# Cost in iteration 200: 0.3713522474108571
# Final cost : 0.3713522474108571
# Compute control for a deterministic system
# Cost in iteration 0: 0.3713522474108571
# Cost in iteration 200: 0.371090859466048
# Cost in iteration 400: 0.3709444574422494
# Final cost : 0.3709444574422494
# Compute control for a deterministic system
# Cost in iteration 0: 0.3709444574422494
# Cost in iteration 200: 0.3708414881941463
# Cost in iteration 400: 0.37080077136399114
# Cost in iteration 600: 0.3707852379931631
# Cost in iteration 800: 0.3707794182942765
# Cost in iteration 1000: 0.3707772627356643
# Final cost : 0.3707772627356643
# Compute control for a deterministic system
# Cost in iteration 0: 1.8884959913064667
# Final cost : 0.3499229502977698
# Compute control for a deterministic system
# Cost in iteration 0: 0.3499229502977698
# Cost in iteration 200: 0.3206602377688024
# Final cost : 0.3206602377688024
# Compute control for a deterministic system
# Cost in iteration 0: 0.3206602377688024
# Cost in iteration 200: 0.320583046876711
# Final cost : 0.320583046876711
# Compute control for a deterministic system
# Cost in iteration 0: 0.320583046876711
# Cost in iteration 200: 0.32054021690638385
# Cost in iteration 400: 0.3205177441711634
# Final cost : 0.3205177441711634
# Compute control for a deterministic system
# Cost in iteration 0: 0.3205177441711634
# Cost in iteration 200: 0.32050452112897415
# Cost in iteration 400: 0.3204992546143471
# Cost in iteration 600: 0.3204971865932039
# Cost in iteration 800: 0.3204963793830092
# Cost in iteration 1000: 0.32049606549327075
# Final cost : 0.32049606549327075
# Compute control for a deterministic system
# Cost in iteration 0: 1.62993444236805
# Final cost : 0.30120203725005573
# Compute control for a deterministic system
# Cost in iteration 0: 0.30120203725005573
# Cost in iteration 200: 0.2831667743258075
# Final cost : 0.2831667743258075
# Compute control for a deterministic system
# Cost in iteration 0: 0.2831667743258075
# Cost in iteration 200: 0.28316336198224185
# Final cost : 0.28316336198224185
# Compute control for a deterministic system
# Cost in iteration 0: 0.28316336198224185
# Cost in iteration 200: 0.28316141400961753
# Cost in iteration 400: 0.2831604243390708
# Final cost : 0.2831604243390708
# Compute control for a deterministic system
# Cost in iteration 0: 0.2831604243390708
# Cost in iteration 200: 0.28315982404826523
# Cost in iteration 400: 0.28315958229203564
# Cost in iteration 600: 0.28315948521773004
# Cost in iteration 800: 0.283159446191737
# Cost in iteration 1000: 0.2831594304904691
# Final cost : 0.2831594304904691
# Compute control for a deterministic system
# Cost in iteration 0: 1.2834582029623927
# Final cost : 0.24304525412919764
# Compute control for a deterministic system
# Cost in iteration 0: 0.24304525412919764
# Cost in iteration 200: 0.23443762379871644
# Final cost : 0.23443762379871644
# Compute control for a deterministic system
# Cost in iteration 0: 0.23443762379871644
# Cost in iteration 200: 0.23418313730306886
# Final cost : 0.23418313730306886
# Compute control for a deterministic system
# Cost in iteration 0: 0.23418313730306886
# Cost in iteration 200: 0.23402816678704008
# Cost in iteration 400: 0.23395109235722034
# Final cost : 0.23395109235722034
# Compute control for a deterministic system
# Cost in iteration 0: 0.23395109235722034
# Cost in iteration 200: 0.23390299638238465
# Cost in iteration 400: 0.23388345857216422
# Cost in iteration 600: 0.23387540614771887
# Cost in iteration 800: 0.23387210473957062
# Cost in iteration 1000: 0.23387111519723527
# Final cost : 0.23387111519723527
# Compute control for a deterministic system
# Cost in iteration 0: 1.030066309023397
# Final cost : 0.20372014573530256
# Compute control for a deterministic system
# Cost in iteration 0: 0.20372014573530256
# Cost in iteration 200: 0.1988803061717601
# Final cost : 0.1988803061717601
# Compute control for a deterministic system
# Cost in iteration 0: 0.1988803061717601
# Cost in iteration 200: 0.1980572230290395
# Final cost : 0.1980572230290395
# Compute control for a deterministic system
# Cost in iteration 0: 0.1980572230290395
# Cost in iteration 200: 0.19784650880968913
# Converged in iteration 346 with cost 0.19784511839096156 because of vanishing difference
# Final cost : 0.19784511839096156
# Compute control for a deterministic system
# Cost in iteration 0: 0.19784511839096156
# Converged in iteration 32 with cost 0.19784511830935933 because of step counter
# Final cost : 0.19784511830935933
# Compute control for a deterministic system
# Cost in iteration 0: 0.713689696777952
# Final cost : 0.1559440992203016
# Compute control for a deterministic system
# Cost in iteration 0: 0.1559440992203016
# Cost in iteration 200: 0.15288529108461218
# Final cost : 0.15288529108461218
# Compute control for a deterministic system
# Cost in iteration 0: 0.15288529108461218
# Converged in iteration 154 with cost 0.15228138362195118 because of vanishing difference
# Final cost : 0.15228138362195118
# Compute control for a deterministic system
# Cost in iteration 0: 0.15228138362195118
# Converged in iteration 28 with cost 0.15228138361189528 because of step counter
# Final cost : 0.15228138361189528
# Compute control for a deterministic system
# Cost in iteration 0: 0.15228138361189528
# Converged in iteration 1 with cost 0.15228138361189528 because of step counter
# Final cost : 0.15228138361189528
# Compute control for a deterministic system
# Cost in iteration 0: 0.5017998633725173
# Final cost : 0.1229641332581107
# Compute control for a deterministic system
# Cost in iteration 0: 0.1229641332581107
# Cost in iteration 200: 0.12007584259474273
# Final cost : 0.12007584259474273
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007584259474273
# Converged in iteration 47 with cost 0.12007534021507277 because of vanishing difference
# Final cost : 0.12007534021507277
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007534021507277
# Converged in iteration 31 with cost 0.12007534018464151 because of step counter
# Final cost : 0.12007534018464151
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007534018464151
# Converged in iteration 1 with cost 0.12007534018464151 because of step counter
# Final cost : 0.12007534018464151
# Compute control for a deterministic system
# Cost in iteration 0: 0.2665744679154942
# Final cost : 0.08205602072252051
# Compute control for a deterministic system
# Cost in iteration 0: 0.08205602072252051
# Converged in iteration 154 with cost 0.07992223777482993 because of vanishing difference
# Final cost : 0.07992223777482993
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223777482993
# Converged in iteration 13 with cost 0.07992223773994966 because of step counter
# Final cost : 0.07992223773994966
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223773994966
# Converged in iteration 1 with cost 0.07992223773994966 because of step counter
# Final cost : 0.07992223773994966
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223773994966
# Converged in iteration 1 with cost 0.07992223773994966 because of step counter
# Final cost : 0.07992223773994966
# Compute control for a deterministic system
# Cost in iteration 0: 0.13398922675492322
# Final cost : 0.05342413794768021
# Compute control for a deterministic system
# Cost in iteration 0: 0.05342413794768021
# Converged in iteration 92 with cost 0.05203452397998361 because of vanishing difference
# Final cost : 0.05203452397998361
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452397998361
# Converged in iteration 13 with cost 0.05203452384980363 because of step counter
# Final cost : 0.05203452384980363
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452384980363
# Converged in iteration 1 with cost 0.05203452384980363 because of step counter
# Final cost : 0.05203452384980363
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452384980363
# Converged in iteration 1 with cost 0.05203452384980363 because of step counter
# Final cost : 0.05203452384980363
# Compute control for a deterministic system
# Cost in iteration 0: 0.025590870486266112
# Final cost : 0.018171039131948376
# Compute control for a deterministic system
# Cost in iteration 0: 0.018171039131948376
# Converged in iteration 44 with cost 0.018151591547219473 because of vanishing difference
# Final cost : 0.018151591547219473
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151591547219473
# Converged in iteration 14 with cost 0.018151591453343913 because of step counter
# Final cost : 0.018151591453343913
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151591453343913
# Converged in iteration 2 with cost 0.018151591453343538 because of step counter
# Final cost : 0.018151591453343538
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151591453343538
# Converged in iteration 1 with cost 0.018151591453343538 because of step counter
# Final cost : 0.018151591453343538
# Compute control for a deterministic system
# Cost in iteration 0: 9.927844359648362e-06
# Converged in iteration 1 with cost 9.927844359648362e-06 because of step counter
# Final cost : 9.927844359648362e-06
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09088443346063949
# Cost in iteration 200: 0.048073818019172085
# Final cost : 0.048073818019172085
# Compute control for a deterministic system
# Cost in iteration 0: 0.048073818019172085
# Converged in iteration 43 with cost 0.04805499755020315 because of vanishing difference
# Final cost : 0.04805499755020315
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499755020315
# Converged in iteration 11 with cost 0.04805499748434046 because of step counter
# Final cost : 0.04805499748434046
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499748434046
# Converged in iteration 1 with cost 0.04805499748434046 because of step counter
# Final cost : 0.04805499748434046
# Compute control for a deterministic system
# Cost in iteration 0: 0.04805499748434046
# Converged in iteration 1 with cost 0.04805499748434046 because of step counter
# Final cost : 0.04805499748434046
# Compute control for a deterministic system
# Cost in iteration 0: 0.09992324034180233
# Cost in iteration 200: 0.07080591467534145
# Final cost : 0.07080591467534145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07080591467534145
# Converged in iteration 46 with cost 0.07080054752593823 because of vanishing difference
# Final cost : 0.07080054752593823
# Compute control for a deterministic system
# Cost in iteration 0: 0.07080054752593823
# Converged in iteration 32 with cost 0.07080054609134386 because of step counter
# Final cost : 0.07080054609134386
# Compute control for a deterministic system
# Cost in iteration 0: 0.07080054609134386
# Converged in iteration 1 with cost 0.07080054609134386 because of step counter
# Final cost : 0.07080054609134386
# Compute control for a deterministic system
# Cost in iteration 0: 0.07080054609134386
# Converged in iteration 1 with cost 0.07080054609134386 because of step counter
# Final cost : 0.07080054609134386
# Compute control for a deterministic system
# Cost in iteration 0: 0.1472378994950821
# Cost in iteration 200: 0.10008426811122301
# Final cost : 0.10008426811122301
# Compute control for a deterministic system
# Cost in iteration 0: 0.10008426811122301
# Converged in iteration 161 with cost 0.10004224950175201 because of step counter
# Final cost : 0.10004224950175201
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004224950175201
# Converged in iteration 6 with cost 0.10004224950174469 because of step counter
# Final cost : 0.10004224950174469
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004224950174469
# Converged in iteration 1 with cost 0.10004224950174469 because of step counter
# Final cost : 0.10004224950174469
# Compute control for a deterministic system
# Cost in iteration 0: 0.10004224950174469
# Converged in iteration 3 with cost 0.1000422495017443 because of step counter
# Final cost : 0.1000422495017443
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.1521297634339795
# Cost in iteration 200: 0.12096560002064008
# Final cost : 0.12096560002064008
# Compute control for a deterministic system
# Cost in iteration 0: 0.12096560002064008
# Cost in iteration 200: 0.12090907287189351
# Final cost : 0.12090907287189351
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907287189351
# Converged in iteration 10 with cost 0.12090907287182415 because of vanishing difference
# Final cost : 0.12090907287182415
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907287182415
# Converged in iteration 4 with cost 0.12090907287182351 because of step counter
# Final cost : 0.12090907287182351
# Compute control for a deterministic system
# Cost in iteration 0: 0.12090907287182351
# Converged in iteration 2 with cost 0.1209090728718232 because of step counter
# Final cost : 0.1209090728718232
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.2039818133063348
# Cost in iteration 200: 0.1473486229910733
# Final cost : 0.1473486229910733
# Compute control for a deterministic system
# Cost in iteration 0: 0.1473486229910733
# Cost in iteration 200: 0.1471703790614447
# Final cost : 0.1471703790614447
# Compute control for a deterministic system
# Cost in iteration 0: 0.1471703790614447
# Converged in iteration 48 with cost 0.14717037898642665 because of step counter
# Final cost : 0.14717037898642665
# Compute control for a deterministic system
# Cost in iteration 0: 0.14717037898642665
# Converged in iteration 6 with cost 0.14717037898642296 because of step counter
# Final cost : 0.14717037898642296
# Compute control for a deterministic system
# Cost in iteration 0: 0.14717037898642296
# Converged in iteration 1 with cost 0.14717037898642296 because of step counter
# Final cost : 0.14717037898642296
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.20124906284609023
# Cost in iteration 200: 0.16583445333915028
# Final cost : 0.16583445333915028
# Compute control for a deterministic system
# Cost in iteration 0: 0.16583445333915028
# Cost in iteration 200: 0.16569175625238208
# Final cost : 0.16569175625238208
# Compute control for a deterministic system
# Cost in iteration 0: 0.16569175625238208
# Converged in iteration 148 with cost 0.16569175411829354 because of step counter
# Final cost : 0.16569175411829354
# Compute control for a deterministic system
# Cost in iteration 0: 0.16569175411829354
# Converged in iteration 14 with cost 0.1656917541182903 because of step counter
# Final cost : 0.1656917541182903
# Compute control for a deterministic system
# Cost in iteration 0: 0.1656917541182903
# Converged in iteration 1 with cost 0.1656917541182903 because of step counter
# Final cost : 0.1656917541182903
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.22715822634338528
# Cost in iteration 200: 0.18918288379320736
# Final cost : 0.18918288379320736
# Compute control for a deterministic system
# Cost in iteration 0: 0.18918288379320736
# Converged in iteration 187 with cost 0.18889025220686556 because of vanishing difference
# Final cost : 0.18889025220686556
# Compute control for a deterministic system
# Cost in iteration 0: 0.18889025220686556
# Cost in iteration 200: 0.18889012759586865
# Final cost : 0.18889012759586865
# Compute control for a deterministic system
# Cost in iteration 0: 0.18889012759586865
# Converged in iteration 151 with cost 0.18889012758575185 because of vanishing difference
# Final cost : 0.18889012758575185
# Compute control for a deterministic system
# Cost in iteration 0: 0.18889012758575185
# Converged in iteration 8 with cost 0.18889012758574228 because of step counter
# Final cost : 0.18889012758574228
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.23646283121022954
# Cost in iteration 200: 0.20543417029148917
# Final cost : 0.20543417029148917
# Compute control for a deterministic system
# Cost in iteration 0: 0.20543417029148917
# Cost in iteration 200: 0.20523711123972158
# Final cost : 0.20523711123972158
# Compute control for a deterministic system
# Cost in iteration 0: 0.20523711123972158
# Cost in iteration 200: 0.20523687590296
# Final cost : 0.20523687590296
# Compute control for a deterministic system
# Cost in iteration 0: 0.20523687590296
# Cost in iteration 200: 0.2052368755475362
# Converged in iteration 325 with cost 0.20523687554657605 because of step counter
# Final cost : 0.20523687554657605
# Compute control for a deterministic system
# Cost in iteration 0: 0.20523687554657605
# Converged in iteration 1 with cost 0.20523687554657605 because of step counter
# Final cost : 0.20523687554657605
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.2594227954367969
# Cost in iteration 200: 0.22608881777175677
# Final cost : 0.22608881777175677
# Compute control for a deterministic system
# Cost in iteration 0: 0.22608881777175677
# Cost in iteration 200: 0.22573581900989867
# Final cost : 0.22573581900989867
# Compute control for a deterministic system
# Cost in iteration 0: 0.22573581900989867
# Converged in iteration 4 with cost 0.22573569693709034 because of vanishing difference
# Final cost : 0.22573569693709034
# Compute control for a deterministic system
# Cost in iteration 0: 0.22573569693709034
# Cost in iteration 200: 0.2257339987778494
# Converged in iteration 319 with cost 0.22573399876880226 because of step counter
# Final cost : 0.22573399876880226
# Compute control for a deterministic system
# Cost in iteration 0: 0.22573399876880226
# Converged in iteration 1 with cost 0.22573399876880226 because of vanishing difference
# Final cost : 0.22573399876880226
# Compute control for a deterministic system
# Cost in iteration 0: 0.2898118931795093
# Cost in iteration 200: 0.2404052267530725
# Final cost : 0.2404052267530725
# Compute control for a deterministic system
# Cost in iteration 0: 0.2404052267530725
# Cost in iteration 200: 0.24018661082938572
# Final cost : 0.24018661082938572
# Compute control for a deterministic system
# Cost in iteration 0: 0.24018661082938572
# Converged in iteration 2 with cost 0.24018656331200225 because of vanishing difference
# Final cost : 0.24018656331200225
# Compute control for a deterministic system
# Cost in iteration 0: 0.24018656331200225
# Cost in iteration 200: 0.24018387296900665
# Cost in iteration 400: 0.24018386745722986
# Final cost : 0.24018386745722986
# Compute control for a deterministic system
# Cost in iteration 0: 0.24018386745722986
# Cost in iteration 200: 0.24018386744686923
# Converged in iteration 214 with cost 0.24018386744684078 because of vanishing difference
# Final cost : 0.24018386744684078
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.2796344089087433
# Cost in iteration 200: 0.2585842114908111
# Final cost : 0.2585842114908111
# Compute control for a deterministic system
# Cost in iteration 0: 0.2585842114908111
# Cost in iteration 200: 0.25824346869453163
# Final cost : 0.25824346869453163
# Compute control for a deterministic system
# Cost in iteration 0: 0.25824346869453163
# Cost in iteration 200: 0.25823247792190485
# Final cost : 0.25823247792190485
# Compute control for a deterministic system
# Cost in iteration 0: 0.25823247792190485
# Cost in iteration 200: 0.25823237680262057
# Cost in iteration 400: 0.2582323744661837
# Final cost : 0.2582323744661837
# Compute control for a deterministic system
# Cost in iteration 0: 0.2582323744661837
# Cost in iteration 200: 0.2582323744064843
# Converged in iteration 299 with cost 0.2582323744037548 because of vanishing difference
# Final cost : 0.2582323744037548
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.359938701386303
# Cost in iteration 200: 0.2710281138761322
# Final cost : 0.2710281138761322
# Compute control for a deterministic system
# Cost in iteration 0: 0.2710281138761322
# Cost in iteration 200: 0.27082749051015903
# Final cost : 0.27082749051015903
# Compute control for a deterministic system
# Cost in iteration 0: 0.27082749051015903
# Converged in iteration 15 with cost 0.27082539164846187 because of vanishing difference
# Final cost : 0.27082539164846187
# Compute control for a deterministic system
# Cost in iteration 0: 0.27082539164846187
# Cost in iteration 200: 0.27081775152533827
# Cost in iteration 400: 0.27081730705599966
# Final cost : 0.27081730705599966
# Compute control for a deterministic system
# Cost in iteration 0: 0.27081730705599966
# Cost in iteration 200: 0.27081727859219923
# Cost in iteration 400: 0.27081727595793414
# Cost in iteration 600: 0.27081727571329356
# Cost in iteration 800: 0.27081727569057124
# Cost in iteration 1000: 0.27081727568843705
# Final cost : 0.27081727568843705
# -----------------------------------------------
# 0 found better solution,  13
# ...
# Cost in iteration 200: 0.3797016228569563
# Cost in iteration 400: 0.37970161254963597
# Cost in iteration 600: 0.3797016081919758
# Cost in iteration 800: 0.3797016063637807
# Cost in iteration 1000: 0.3797016055696748
# Final cost : 0.3797016055696748
# -----------------------------------------------
# 4 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.45561573474378864
# Cost in iteration 200: 0.38825657053991575
# Final cost : 0.38825657053991575
# Compute control for a deterministic system
# Cost in iteration 0: 0.38825657053991575
# Converged in iteration 105 with cost 0.3882532312276216 because of vanishing difference
# Final cost : 0.3882532312276216
# Compute control for a deterministic system
# Cost in iteration 0: 0.3882532312276216
# Cost in iteration 200: 0.3882524085799975
# Final cost : 0.3882524085799975
# Compute control for a deterministic system
# Cost in iteration 0: 0.3882524085799975
# Cost in iteration 200: 0.3882522083519519
# Cost in iteration 400: 0.38825219585031223
# Final cost : 0.38825219585031223
# Compute control for a deterministic system
# Cost in iteration 0: 0.38825219585031223
# Cost in iteration 200: 0.38825219495685115
# Cost in iteration 400: 0.38825219439714265
# Cost in iteration 600: 0.38825219402994643
# Cost in iteration 800: 0.38825219378708126
# Cost in iteration 1000: 0.3882521936273356
# Final cost : 0.3882521936273356
# -----------------------------------------------
# 4 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.39527731059186166
# Cost in iteration 200: 0.3944186871825315
# Final cost : 0.3944186871825315
# Compute control for a deterministic system
# Cost in iteration 0: 0.3944186871825315
# Converged in iteration 13 with cost 0.39441768797840243 because of vanishing difference
# Final cost : 0.39441768797840243
# Compute control for a deterministic system
# Cost in iteration 0: 0.39441768797840243
# Cost in iteration 200: 0.3944157082674563
# Final cost : 0.3944157082674563
# Compute control for a deterministic system
# Cost in iteration 0: 0.3944157082674563
# Cost in iteration 200: 0.39441488651699674
# Cost in iteration 400: 0.3944145727913452
# Final cost : 0.3944145727913452
# Compute control for a deterministic system
# Cost in iteration 0: 0.3944145727913452
# Cost in iteration 200: 0.39441447808547453
# Cost in iteration 400: 0.3944144104313467
# Cost in iteration 600: 0.39441436114820977
# Cost in iteration 800: 0.39441432618912103
# Cost in iteration 1000: 0.39441430180709225
# Final cost : 0.39441430180709225
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.41488763279858804
# Cost in iteration 200: 0.40229263604218973
# Final cost : 0.40229263604218973
# Compute control for a deterministic system
# Cost in iteration 0: 0.40229263604218973
# Converged in iteration 53 with cost 0.40229148981727997 because of vanishing difference
# Final cost : 0.40229148981727997
# Compute control for a deterministic system
# Cost in iteration 0: 0.40229148981727997
# Cost in iteration 200: 0.40228893222310297
# Final cost : 0.40228893222310297
# Compute control for a deterministic system
# Cost in iteration 0: 0.40228893222310297
# Cost in iteration 200: 0.4022885459491338
# Cost in iteration 400: 0.40228827064563855
# Final cost : 0.40228827064563855
# Compute control for a deterministic system
# Cost in iteration 0: 0.40228827064563855
# Cost in iteration 200: 0.4022880899831374
# Cost in iteration 400: 0.4022879511364062
# Cost in iteration 600: 0.4022878440961376
# Cost in iteration 800: 0.4022877616951117
# Cost in iteration 1000: 0.40228769795847746
# Final cost : 0.40228769795847746
# -----------------------------------------------
# 4 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.41176993251929117
# Cost in iteration 200: 0.4079341988539058
# Final cost : 0.4079341988539058
# Compute control for a deterministic system
# Cost in iteration 0: 0.4079341988539058
# Converged in iteration 14 with cost 0.4079335683309653 because of vanishing difference
# Final cost : 0.4079335683309653
# Compute control for a deterministic system
# Cost in iteration 0: 0.4079335683309653
# Cost in iteration 200: 0.40793011437666366
# Final cost : 0.40793011437666366
# Compute control for a deterministic system
# Cost in iteration 0: 0.40793011437666366
# Cost in iteration 200: 0.40792893358375376
# Cost in iteration 400: 0.40792806560653605
# Final cost : 0.40792806560653605
# Compute control for a deterministic system
# Cost in iteration 0: 0.40792806560653605
# Cost in iteration 200: 0.4079274637023317
# Cost in iteration 400: 0.4079269907939846
# Cost in iteration 600: 0.4079266153050148
# Cost in iteration 800: 0.40792631979860705
# Cost in iteration 1000: 0.40792608586706536
# Final cost : 0.40792608586706536
# -----------------------------------------------
# 4 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.46672548270214564
# Cost in iteration 200: 0.4106838237293429
# Final cost : 0.4106838237293429
# Compute control for a deterministic system
# Cost in iteration 0: 0.4106838237293429
# Cost in iteration 200: 0.4088853601852082
# Final cost : 0.4088853601852082
# Compute control for a deterministic system
# Cost in iteration 0: 0.4088853601852082
# Cost in iteration 200: 0.40888192127328554
# Final cost : 0.40888192127328554
# Compute control for a deterministic system
# Cost in iteration 0: 0.40888192127328554
# Cost in iteration 200: 0.40887956935862646
# Cost in iteration 400: 0.4088784320664524
# Final cost : 0.4088784320664524
# Compute control for a deterministic system
# Cost in iteration 0: 0.4088784320664524
# Cost in iteration 200: 0.40887768716921785
# Cost in iteration 400: 0.4088772503417701
# Cost in iteration 600: 0.4088769482333523
# Cost in iteration 800: 0.4088767942253592
# Cost in iteration 1000: 0.40887668055185933
# Final cost : 0.40887668055185933
# -----------------------------------------------
# 4 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.4136722430237127
# Cost in iteration 200: 0.37207558057985246
# Final cost : 0.37207558057985246
# Compute control for a deterministic system
# Cost in iteration 0: 0.37207558057985246
# Cost in iteration 200: 0.37077606613780323
# Final cost : 0.37077606613780323
# Compute control for a deterministic system
# Cost in iteration 0: 0.37077606613780323
# Cost in iteration 200: 0.37077601337526644
# Final cost : 0.37077601337526644
# Compute control for a deterministic system
# Cost in iteration 0: 0.37077601337526644
# Cost in iteration 200: 0.37077601319790066
# Cost in iteration 400: 0.37077601309869745
# Final cost : 0.37077601309869745
# Compute control for a deterministic system
# Cost in iteration 0: 0.37077601309869745
# Cost in iteration 200: 0.37077601302828744
# Cost in iteration 400: 0.3707760129973393
# Cost in iteration 600: 0.37077601298609575
# Cost in iteration 800: 0.3707760129820526
# Cost in iteration 1000: 0.37077601298065305
# Final cost : 0.37077601298065305
# -----------------------------------------------
# 4 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.38102932825025143
# Cost in iteration 200: 0.32084262484508164
# Final cost : 0.32084262484508164
# Compute control for a deterministic system
# Cost in iteration 0: 0.32084262484508164
# Cost in iteration 200: 0.32049703490451853
# Final cost : 0.32049703490451853
# Compute control for a deterministic system
# Cost in iteration 0: 0.32049703490451853
# Cost in iteration 200: 0.3204964121508787
# Final cost : 0.3204964121508787
# Compute control for a deterministic system
# Cost in iteration 0: 0.3204964121508787
# Cost in iteration 200: 0.3204961446288797
# Cost in iteration 400: 0.3204959994365283
# Final cost : 0.3204959994365283
# Compute control for a deterministic system
# Cost in iteration 0: 0.3204959994365283
# Cost in iteration 200: 0.32049591829079643
# Cost in iteration 400: 0.3204958867110561
# Cost in iteration 600: 0.3204958744930155
# Cost in iteration 800: 0.32049586976814604
# Cost in iteration 1000: 0.3204958679415185
# Final cost : 0.3204958679415185
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.34489866372412525
# Cost in iteration 200: 0.28328498574570316
# Final cost : 0.28328498574570316
# Compute control for a deterministic system
# Cost in iteration 0: 0.28328498574570316
# Cost in iteration 200: 0.28315951325279565
# Final cost : 0.28315951325279565
# Compute control for a deterministic system
# Cost in iteration 0: 0.28315951325279565
# Cost in iteration 200: 0.28315947209649583
# Final cost : 0.28315947209649583
# Compute control for a deterministic system
# Cost in iteration 0: 0.28315947209649583
# Cost in iteration 200: 0.28315944664039433
# Cost in iteration 400: 0.2831594334443836
# Final cost : 0.2831594334443836
# Compute control for a deterministic system
# Cost in iteration 0: 0.2831594334443836
# Cost in iteration 200: 0.28315942537529654
# Cost in iteration 400: 0.28315942211079587
# Cost in iteration 600: 0.28315942079616196
# Cost in iteration 800: 0.28315942026667457
# Cost in iteration 1000: 0.28315942005340067
# Final cost : 0.28315942005340067
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.2707470421745774
# Cost in iteration 200: 0.234311798174255
# Final cost : 0.234311798174255
# Compute control for a deterministic system
# Cost in iteration 0: 0.234311798174255
# Cost in iteration 200: 0.2338707297833205
# Final cost : 0.2338707297833205
# Compute control for a deterministic system
# Cost in iteration 0: 0.2338707297833205
# Cost in iteration 200: 0.23387035778547619
# Final cost : 0.23387035778547619
# Compute control for a deterministic system
# Cost in iteration 0: 0.23387035778547619
# Cost in iteration 200: 0.23387014920593935
# Cost in iteration 400: 0.23386997346579796
# Final cost : 0.23386997346579796
# Compute control for a deterministic system
# Cost in iteration 0: 0.23386997346579796
# Cost in iteration 200: 0.23386986476643123
# Cost in iteration 400: 0.23386979631066648
# Cost in iteration 600: 0.2338697512546402
# Cost in iteration 800: 0.2338697195582566
# Cost in iteration 1000: 0.23386969675119304
# Final cost : 0.23386969675119304
# -----------------------------------------------
# 4 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.22635277640588472
# Cost in iteration 200: 0.1981554160539459
# Final cost : 0.1981554160539459
# Compute control for a deterministic system
# Cost in iteration 0: 0.1981554160539459
# Cost in iteration 200: 0.1978457471981781
# Final cost : 0.1978457471981781
# Compute control for a deterministic system
# Cost in iteration 0: 0.1978457471981781
# Converged in iteration 198 with cost 0.19784510720829485 because of vanishing difference
# Final cost : 0.19784510720829485
# Compute control for a deterministic system
# Cost in iteration 0: 0.19784510720829485
# Converged in iteration 32 with cost 0.1978451069229708 because of step counter
# Final cost : 0.1978451069229708
# Compute control for a deterministic system
# Cost in iteration 0: 0.1978451069229708
# Converged in iteration 3 with cost 0.19784510692296942 because of vanishing difference
# Final cost : 0.19784510692296942
# Compute control for a deterministic system
# Cost in iteration 0: 0.1808071258542503
# Cost in iteration 200: 0.1524718680260057
# Final cost : 0.1524718680260057
# Compute control for a deterministic system
# Cost in iteration 0: 0.1524718680260057
# Cost in iteration 200: 0.15228138311256323
# Final cost : 0.15228138311256323
# Compute control for a deterministic system
# Cost in iteration 0: 0.15228138311256323
# Converged in iteration 3 with cost 0.1522813827052369 because of vanishing difference
# Final cost : 0.1522813827052369
# Compute control for a deterministic system
# Cost in iteration 0: 0.1522813827052369
# Converged in iteration 28 with cost 0.15228138267248417 because of step counter
# Final cost : 0.15228138267248417
# Compute control for a deterministic system
# Cost in iteration 0: 0.15228138267248417
# Converged in iteration 2 with cost 0.1522813826724837 because of step counter
# Final cost : 0.1522813826724837
# Compute control for a deterministic system
# Cost in iteration 0: 0.1408780015317608
# Cost in iteration 200: 0.12010182571968674
# Final cost : 0.12010182571968674
# Compute control for a deterministic system
# Cost in iteration 0: 0.12010182571968674
# Converged in iteration 113 with cost 0.12007533534868418 because of vanishing difference
# Final cost : 0.12007533534868418
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007533534868418
# Converged in iteration 17 with cost 0.12007533532976838 because of vanishing difference
# Final cost : 0.12007533532976838
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007533532976838
# Converged in iteration 2 with cost 0.12007533532976726 because of step counter
# Final cost : 0.12007533532976726
# Compute control for a deterministic system
# Cost in iteration 0: 0.12007533532976726
# Converged in iteration 1 with cost 0.12007533532976726 because of step counter
# Final cost : 0.12007533532976726
# Compute control for a deterministic system
# Cost in iteration 0: 0.09294750349527334
# Cost in iteration 200: 0.07992509127746973
# Final cost : 0.07992509127746973
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992509127746973
# Converged in iteration 71 with cost 0.07992223787582134 because of vanishing difference
# Final cost : 0.07992223787582134
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223787582134
# Converged in iteration 19 with cost 0.07992223777241922 because of step counter
# Final cost : 0.07992223777241922
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223777241922
# Converged in iteration 3 with cost 0.07992223777241911 because of step counter
# Final cost : 0.07992223777241911
# Compute control for a deterministic system
# Cost in iteration 0: 0.07992223777241911
# Converged in iteration 2 with cost 0.07992223777241886 because of step counter
# Final cost : 0.07992223777241886
# Compute control for a deterministic system
# Cost in iteration 0: 0.05908183786954811
# Cost in iteration 200: 0.052034690886934847
# Final cost : 0.052034690886934847
# Compute control for a deterministic system
# Cost in iteration 0: 0.052034690886934847
# Converged in iteration 33 with cost 0.05203452416308255 because of vanishing difference
# Final cost : 0.05203452416308255
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452416308255
# Converged in iteration 11 with cost 0.05203452395482879 because of step counter
# Final cost : 0.05203452395482879
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452395482879
# Converged in iteration 1 with cost 0.05203452395482879 because of step counter
# Final cost : 0.05203452395482879
# Compute control for a deterministic system
# Cost in iteration 0: 0.05203452395482879
# Converged in iteration 2 with cost 0.05203452395482873 because of step counter
# Final cost : 0.05203452395482873
# Compute control for a deterministic system
# Cost in iteration 0: 0.019829471247605573
# Converged in iteration 86 with cost 0.018151590914278065 because of vanishing difference
# Final cost : 0.018151590914278065
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151590914278065
# Converged in iteration 9 with cost 0.018151590737887652 because of step counter
# Final cost : 0.018151590737887652
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151590737887652
# Converged in iteration 1 with cost 0.018151590737887652 because of step counter
# Final cost : 0.018151590737887652
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151590737887652
# Converged in iteration 2 with cost 0.018151590737887316 because of step counter
# Final cost : 0.018151590737887316
# Compute control for a deterministic system
# Cost in iteration 0: 0.018151590737887316
# Converged in iteration 1 with cost 0.018151590737887316 because of step counter
# Final cost : 0.018151590737887316

# %%
save(results_min)
