# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,192], wc.inh[0,192]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [  18  209  400  590  781  972 1163 1353 1544 1735 1925 2116 2307 2497
#  2688 2879]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
results_min = readfile("results_min_w2.pickle")

ind_list = [16,17,18,19]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_peak["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()

                if i_w != len(results_peak["w2"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * factor
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# cost =  0.023863661835784037
# Compute control for a deterministic system
# Cost in iteration 0: 0.06360048683898478
# Final cost : 0.024082413412966193
# Compute control for a deterministic system
# Cost in iteration 0: 0.024082413412966193
# Final cost : 0.023874924209128186
# Compute control for a deterministic system
# Cost in iteration 0: 0.023874924209128186
# Final cost : 0.023863665799222174
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863665799222174
# Final cost : 0.02386366187897849
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386366187897849
# Final cost : 0.0238636618365056
# cost =  0.027556878229217055
# Compute control for a deterministic system
# Cost in iteration 0: 0.07569063841724917
# Final cost : 0.027943860598067125
# Compute control for a deterministic system
# Cost in iteration 0: 0.027943860598067125
# Final cost : 0.02757779274504295
# Compute control for a deterministic system
# Cost in iteration 0: 0.02757779274504295
# Final cost : 0.027556896349676886
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556896349676886
# Final cost : 0.027556878430590875
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556878430590875
# Final cost : 0.027556878233464675
# cost =  0.03005257177565496
# Compute control for a deterministic system
# Cost in iteration 0: 0.08440023735569278
# Final cost : 0.03200893391296561
# Compute control for a deterministic system
# Cost in iteration 0: 0.03200893391296561
# Final cost : 0.03158381314595997
# Compute control for a deterministic system
# Cost in iteration 0: 0.03158381314595997
# Final cost : 0.03155799059430538
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155799059430538
# Final cost : 0.03155795934722642
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155795934722642
# Final cost : 0.03155795883660136
# cost =  0.027854969428627762
# Compute control for a deterministic system
# Cost in iteration 0: 0.09325591853893357
# Final cost : 0.02801656284812741
# Compute control for a deterministic system
# Cost in iteration 0: 0.02801656284812741
# Final cost : 0.027869873600892884
# Compute control for a deterministic system
# Cost in iteration 0: 0.027869873600892884
# Final cost : 0.027857656288126587
# Compute control for a deterministic system
# Cost in iteration 0: 0.027857656288126587
# Final cost : 0.02785569839869037
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785569839869037
# Final cost : 0.027855056644464523
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.047367721183302
# Final cost : 0.02786989806855092
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786989806855092
# Final cost : 0.02785601922403315
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785601922403315
# Final cost : 0.027855241105190134
# Compute control for a deterministic system
# Cost in iteration 0: 0.027855241105190134
# Final cost : 0.027855000655781535
# Compute control for a deterministic system
# Cost in iteration 0: 0.06629250270831412
# Final cost : 0.030075070120224968
# Compute control for a deterministic system
# Cost in iteration 0: 0.030075070120224968
# Final cost : 0.030055580133264075
# Compute control for a deterministic system
# Cost in iteration 0: 0.030055580133264075
# Final cost : 0.030053480207456483
# Compute control for a deterministic system
# Cost in iteration 0: 0.030053480207456483
# Final cost : 0.03005277414739717
# Compute control for a deterministic system
# Cost in iteration 0: 0.08849415645302139
# Final cost : 0.03229973288793624
# Compute control for a deterministic system
# Cost in iteration 0: 0.03229973288793624
# Final cost : 0.03228331264877732
# Compute control for a deterministic system
# Cost in iteration 0: 0.03228331264877732
# Final cost : 0.03228127488687725
# Compute control for a deterministic system
# Cost in iteration 0: 0.03228127488687725
# Final cost : 0.03228079484150198
# Compute control for a deterministic system
# Cost in iteration 0: 0.08763374952064537
# Final cost : 0.0238960698127735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0238960698127735
# Final cost : 0.023863672516268312
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863672516268312
# Final cost : 0.02386366191485308
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386366191485308
# Final cost : 0.023863661837132275
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.051286095764147506
# Final cost : 0.0261300507924773
# Compute control for a deterministic system
# Cost in iteration 0: 0.0261300507924773
# Final cost : 0.02391275815631995
# Compute control for a deterministic system
# Cost in iteration 0: 0.02391275815631995
# Final cost : 0.02386367786526695
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386367786526695
# Final cost : 0.023863661968501884
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863661968501884
# Final cost : 0.02386366183810416
# Compute control for a deterministic system
# Cost in iteration 0: 0.06214582509374842
# Final cost : 0.03054138587889688
# Compute control for a deterministic system
# Cost in iteration 0: 0.03054138587889688
# Final cost : 0.027629668794636054
# Compute control for a deterministic system
# Cost in iteration 0: 0.027629668794636054
# Final cost : 0.027556944882997078
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556944882997078
# Final cost : 0.02755687911377326
# Compute control for a deterministic system
# Cost in iteration 0: 0.02755687911377326
# Final cost : 0.027556878247847204
# Compute control for a deterministic system
# Cost in iteration 0: 0.06943699010254174
# Final cost : 0.03542774218909715
# Compute control for a deterministic system
# Cost in iteration 0: 0.03542774218909715
# Final cost : 0.031664267187847206
# Compute control for a deterministic system
# Cost in iteration 0: 0.031664267187847206
# Final cost : 0.031558061788683416
# Compute control for a deterministic system
# Cost in iteration 0: 0.031558061788683416
# Final cost : 0.03155796052533286
# Compute control for a deterministic system
# Cost in iteration 0: 0.03155796052533286
# Final cost : 0.031557958866662864
# Compute control for a deterministic system
# Cost in iteration 0: 0.04762779727146597
# Final cost : 0.028704779104833225
# Compute control for a deterministic system
# Cost in iteration 0: 0.028704779104833225
# Final cost : 0.027884291840652217
# Compute control for a deterministic system
# Cost in iteration 0: 0.027884291840652217
# Final cost : 0.02785742546298122
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785742546298122
# Final cost : 0.02785540093571203
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785540093571203
# Final cost : 0.02785498179118063
# ----------------------------------------------- 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.025789506453014477
# Final cost : 0.02405902158833583
# Compute control for a deterministic system
# Cost in iteration 0: 0.02405902158833583
# Final cost : 0.02387015999092422
# Compute control for a deterministic system
# Cost in iteration 0: 0.02387015999092422
# Final cost : 0.023863663514647457
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863663514647457
# Final cost : 0.023863661853847095
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863661853847095
# Final cost : 0.023863661836036883
# Compute control for a deterministic system
# Cost in iteration 0: 0.02951208661028064
# Final cost : 0.027791512191493464
# Compute control for a deterministic system
# Cost in iteration 0: 0.027791512191493464
# Final cost : 0.027564304034092327
# Compute control for a deterministic system
# Cost in iteration 0: 0.027564304034092327
# Final cost : 0.0275568831406787
# Compute control for a deterministic system
# Cost in iteration 0: 0.0275568831406787
# Final cost : 0.0275568782962362
# Compute control for a deterministic system
# Cost in iteration 0: 0.0275568782962362
# Final cost : 0.027556878230623857
# Compute control for a deterministic system
# Cost in iteration 0: 0.03276506563236251
# Final cost : 0.030110139985117707
# Compute control for a deterministic system
# Cost in iteration 0: 0.030110139985117707
# Final cost : 0.03005479056900741
# Compute control for a deterministic system
# Cost in iteration 0: 0.03005479056900741
# Final cost : 0.03005289708712992
# Compute control for a deterministic system
# Cost in iteration 0: 0.03005289708712992
# Final cost : 0.030052665301478945
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052665301478945
# Final cost : 0.030052593002466023
# Compute control for a deterministic system
# Cost in iteration 0: 0.030614976855955708
# Final cost : 0.02791655707823237
# Compute control for a deterministic system
# Cost in iteration 0: 0.02791655707823237
# Final cost : 0.02785858251207253
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785858251207253
# Final cost : 0.027855157879569693
# Compute control for a deterministic system
# Cost in iteration 0: 0.027855157879569693
# Final cost : 0.027855039205990518
# Compute control for a deterministic system
# Cost in iteration 0: 0.027855039205990518
# Final cost : 0.027854969877095247
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.023891712424894098
# Final cost : 0.023863681731742824
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863681731742824
# Final cost : 0.02386366183992694
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386366183992694
# Converged in iteration 347 with cost 0.02386366183581711 because of step counter
# Final cost : 0.02386366183581711
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386366183581711
# Converged in iteration 34 with cost 0.023863661835806623 because of step counter
# Final cost : 0.023863661835806623
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863661835806623
# Converged in iteration 1 with cost 0.023863661835806623 because of step counter
# Final cost : 0.023863661835806623
# Compute control for a deterministic system
# Cost in iteration 0: 0.02851726597788242
# Final cost : 0.027557567902025782
# Compute control for a deterministic system
# Cost in iteration 0: 0.027557567902025782
# Final cost : 0.0275568784000428
# Compute control for a deterministic system
# Cost in iteration 0: 0.0275568784000428
# Converged in iteration 805 with cost 0.027556878229366474 because of step counter
# Final cost : 0.027556878229366474
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556878229366474
# Converged in iteration 1 with cost 0.027556878229366474 because of step counter
# Final cost : 0.027556878229366474
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556878229366474
# Converged in iteration 17 with cost 0.0275568782292175 because of step counter
# Final cost : 0.0275568782292175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0349509300716309
# Final cost : 0.030052801047312814
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052801047312814
# Final cost : 0.030052571996516855
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052571996516855
# Final cost : 0.030052571779211033
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052571779211033
# Converged in iteration 1288 with cost 0.030052571775275073 because of step counter
# Final cost : 0.030052571775275073
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052571775275073
# Converged in iteration 142 with cost 0.03005257177504275 because of step counter
# Final cost : 0.03005257177504275
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.028263032413468978
# Final cost : 0.027854994383803434
# Compute control for a deterministic system
# Cost in iteration 0: 0.027854994383803434
# Final cost : 0.027854969447417926
# Compute control for a deterministic system
# Cost in iteration 0: 0.027854969447417926
# Final cost : 0.02785496942224068
# Compute control for a deterministic system
# Cost in iteration 0: 0.02785496942224068
# Converged in iteration 1823 with cost 0.027854969420355778 because of vanishing difference
# Final cost : 0.027854969420355778
# Compute control for a deterministic system
# Cost in iteration 0: 0.027854969420355778
# Converged in iteration 141 with cost 0.02785496941983524 because of step counter
# Final cost : 0.02785496941983524
# -----------------------------------------------
# 4 found better solution,  19
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.06436789171474697
# Final cost : 0.024910881543435397
# Compute control for a deterministic system
# Cost in iteration 0: 0.024910881543435397
# Final cost : 0.023884456071344016
# Compute control for a deterministic system
# Cost in iteration 0: 0.023884456071344016
# Final cost : 0.02386366185759482
# Compute control for a deterministic system
# Cost in iteration 0: 0.02386366185759482
# Converged in iteration 1498 with cost 0.023863661835838063 because of step counter
# Final cost : 0.023863661835838063
# Compute control for a deterministic system
# Cost in iteration 0: 0.023863661835838063
# Converged in iteration 41 with cost 0.02386366183575408 because of step counter
# Final cost : 0.02386366183575408
# -----------------------------------------------
# 5 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.0843645031955248
# Final cost : 0.028816945849892656
# Compute control for a deterministic system
# Cost in iteration 0: 0.028816945849892656
# Final cost : 0.027582221275811343
# Compute control for a deterministic system
# Cost in iteration 0: 0.027582221275811343
# Final cost : 0.027556878278462392
# Compute control for a deterministic system
# Cost in iteration 0: 0.027556878278462392
# Converged in iteration 1673 with cost 0.02755687822929854 because of step counter
# Final cost : 0.02755687822929854
# Compute control for a deterministic system
# Cost in iteration 0: 0.02755687822929854
# Converged in iteration 1 with cost 0.02755687822929854 because of step counter
# Final cost : 0.02755687822929854
# Compute control for a deterministic system
# Cost in iteration 0: 0.059911379409063964
# Final cost : 0.03060736331981137
# Compute control for a deterministic system
# Cost in iteration 0: 0.03060736331981137
# Final cost : 0.030069579770461336
# Compute control for a deterministic system
# Cost in iteration 0: 0.030069579770461336
# Final cost : 0.030052572623091377
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052572623091377
# Final cost : 0.030052571776609464
# Compute control for a deterministic system
# Cost in iteration 0: 0.030052571776609464
# Converged in iteration 433 with cost 0.030052571775427705 because of step counter
# Final cost : 0.030052571775427705
# Compute control for a deterministic system
# Cost in iteration 0: 0.042740106059451076
# Final cost : 0.028379780608438442
# Compute control for a deterministic system
# Cost in iteration 0: 0.028379780608438442
# Final cost : 0.02786985021583396
# Compute control for a deterministic system
# Cost in iteration 0: 0.02786985021583396
# Final cost : 0.027854969546054775
# Compute control for a deterministic system
# Cost in iteration 0: 0.027854969546054775
# Final cost : 0.027854969419664
# Compute control for a deterministic system
# Cost in iteration 0: 0.027854969419664
# Converged in iteration 4 with cost 0.027854969419661816 because of step counter
# Final cost : 0.027854969419661816
# -----------------------------------------------
# 5 found better solution,  19
# ----------------------------------------------- 0
# cost =  0.09209706302308192
# Compute control for a deterministic system
# Cost in iteration 0: 0.141216067437962
# Final cost : 0.09259891402633755
# Compute control for a deterministic system
# Cost in iteration 0: 0.09259891402633755
# Final cost : 0.09209831430796035
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209831430796035
# Converged in iteration 627 with cost 0.09209706302314741 because of step counter
# Final cost : 0.09209706302314741
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314741
# Converged in iteration 1 with cost 0.09209706302314741 because of step counter
# Final cost : 0.09209706302314741
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314741
# Converged in iteration 1 with cost 0.09209706302314741 because of step counter
# Final cost : 0.09209706302314741
# cost =  0.10621989030399584
# Compute control for a deterministic system
# Cost in iteration 0: 0.153140413110954
# Final cost : 0.10707830921603281
# Compute control for a deterministic system
# Cost in iteration 0: 0.10707830921603281
# Final cost : 0.1062214720153343
# Compute control for a deterministic system
# Cost in iteration 0: 0.1062214720153343
# Converged in iteration 657 with cost 0.10621989030410466 because of step counter
# Final cost : 0.10621989030410466
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030410466
# Converged in iteration 19 with cost 0.10621989030406864 because of vanishing difference
# Final cost : 0.10621989030406864
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030406864
# Converged in iteration 1 with cost 0.10621989030406864 because of vanishing difference
# Final cost : 0.10621989030406864
# cost =  0.11886533945063253
# Compute control for a deterministic system
# Cost in iteration 0: 0.16711508712843604
# Final cost : 0.12240923909126851
# Compute control for a deterministic system
# Cost in iteration 0: 0.12240923909126851
# Final cost : 0.12145319465657613
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145319465657613
# Converged in iteration 699 with cost 0.12145172705743737 because of step counter
# Final cost : 0.12145172705743737
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145172705743737
# Converged in iteration 2 with cost 0.12145172705743704 because of step counter
# Final cost : 0.12145172705743704
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145172705743704
# Converged in iteration 1 with cost 0.12145172705743704 because of step counter
# Final cost : 0.12145172705743704
# cost =  0.11006308959968394
# Compute control for a deterministic system
# Cost in iteration 0: 0.18364072324022168
# Final cost : 0.11046221005869271
# Compute control for a deterministic system
# Cost in iteration 0: 0.11046221005869271
# Final cost : 0.11006887923550365
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006887923550365
# Final cost : 0.11006310473839853
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006310473839853
# Final cost : 0.11006308974619214
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308974619214
# Converged in iteration 756 with cost 0.11006308959999651 because of step counter
# Final cost : 0.11006308959999651
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.1424552309852253
# Final cost : 0.11006953392606872
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006953392606872
# Final cost : 0.11006310513147716
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006310513147716
# Final cost : 0.11006308967720961
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308967720961
# Converged in iteration 750 with cost 0.11006308960016134 because of vanishing difference
# Final cost : 0.11006308960016134
# Compute control for a deterministic system
# Cost in iteration 0: 0.1726547633743928
# Final cost : 0.11887476281349704
# Compute control for a deterministic system
# Cost in iteration 0: 0.11887476281349704
# Final cost : 0.11886618579814502
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886618579814502
# Final cost : 0.1188653579883326
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188653579883326
# Converged in iteration 324 with cost 0.11886533945066181 because of step counter
# Final cost : 0.11886533945066181
# Compute control for a deterministic system
# Cost in iteration 0: 0.22312358813463268
# Final cost : 0.127778385182767
# Compute control for a deterministic system
# Cost in iteration 0: 0.127778385182767
# Final cost : 0.12777076647693839
# Compute control for a deterministic system
# Cost in iteration 0: 0.12777076647693839
# Final cost : 0.1277702337454427
# Compute control for a deterministic system
# Cost in iteration 0: 0.1277702337454427
# Converged in iteration 912 with cost 0.12777022583586525 because of step counter
# Final cost : 0.12777022583586525
# Compute control for a deterministic system
# Cost in iteration 0: 0.16275907288665442
# Final cost : 0.09210223853082493
# Compute control for a deterministic system
# Cost in iteration 0: 0.09210223853082493
# Converged in iteration 616 with cost 0.09209706302319712 because of step counter
# Final cost : 0.09209706302319712
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302319712
# Converged in iteration 44 with cost 0.09209706302315043 because of step counter
# Final cost : 0.09209706302315043
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302315043
# Converged in iteration 3 with cost 0.0920970630231501 because of vanishing difference
# Final cost : 0.0920970630231501
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.09411012999223649
# Final cost : 0.0924007128140609
# Compute control for a deterministic system
# Cost in iteration 0: 0.0924007128140609
# Final cost : 0.0920987381537672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0920987381537672
# Converged in iteration 629 with cost 0.09209706302314183 because of step counter
# Final cost : 0.09209706302314183
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314183
# Converged in iteration 3 with cost 0.09209706302314082 because of step counter
# Final cost : 0.09209706302314082
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314082
# Converged in iteration 1 with cost 0.09209706302314082 because of step counter
# Final cost : 0.09209706302314082
# Compute control for a deterministic system
# Cost in iteration 0: 0.11139311555627254
# Final cost : 0.10663010670768414
# Compute control for a deterministic system
# Cost in iteration 0: 0.10663010670768414
# Final cost : 0.10622268622882658
# Compute control for a deterministic system
# Cost in iteration 0: 0.10622268622882658
# Converged in iteration 649 with cost 0.10621989030410205 because of vanishing difference
# Final cost : 0.10621989030410205
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030410205
# Converged in iteration 12 with cost 0.10621989030406 because of step counter
# Final cost : 0.10621989030406
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030406
# Converged in iteration 1 with cost 0.10621989030406 because of step counter
# Final cost : 0.10621989030406
# Compute control for a deterministic system
# Cost in iteration 0: 0.11966084491380836
# Final cost : 0.11895453079272099
# Compute control for a deterministic system
# Cost in iteration 0: 0.11895453079272099
# Final cost : 0.1188659009307442
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188659009307442
# Final cost : 0.11886538352195561
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886538352195561
# Final cost : 0.11886533975061318
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886533975061318
# Converged in iteration 766 with cost 0.11886533945064194 because of step counter
# Final cost : 0.11886533945064194
# Compute control for a deterministic system
# Cost in iteration 0: 0.11207521638865107
# Final cost : 0.11016240796321403
# Compute control for a deterministic system
# Cost in iteration 0: 0.11016240796321403
# Final cost : 0.11006373772916803
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006373772916803
# Final cost : 0.11006309129126644
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006309129126644
# Final cost : 0.11006308961960747
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308961960747
# Converged in iteration 465 with cost 0.11006308959999948 because of step counter
# Final cost : 0.11006308959999948
# ----------------------------------------------- 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.10755247746905143
# Final cost : 0.0938821335848386
# Compute control for a deterministic system
# Cost in iteration 0: 0.0938821335848386
# Final cost : 0.09209927114449633
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209927114449633
# Converged in iteration 636 with cost 0.09209706302315247 because of step counter
# Final cost : 0.09209706302315247
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302315247
# Converged in iteration 1 with cost 0.09209706302315247 because of step counter
# Final cost : 0.09209706302315247
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302315247
# Converged in iteration 1 with cost 0.09209706302315247 because of step counter
# Final cost : 0.09209706302315247
# Compute control for a deterministic system
# Cost in iteration 0: 0.1281867932617807
# Final cost : 0.1086282465040708
# Compute control for a deterministic system
# Cost in iteration 0: 0.1086282465040708
# Final cost : 0.10622233727477962
# Compute control for a deterministic system
# Cost in iteration 0: 0.10622233727477962
# Converged in iteration 670 with cost 0.10621989030405808 because of step counter
# Final cost : 0.10621989030405808
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030405808
# Converged in iteration 2 with cost 0.1062198903040576 because of step counter
# Final cost : 0.1062198903040576
# Compute control for a deterministic system
# Cost in iteration 0: 0.1062198903040576
# Converged in iteration 1 with cost 0.1062198903040576 because of step counter
# Final cost : 0.1062198903040576
# Compute control for a deterministic system
# Cost in iteration 0: 0.1431540955495305
# Final cost : 0.12459104409927299
# Compute control for a deterministic system
# Cost in iteration 0: 0.12459104409927299
# Final cost : 0.12145467968755681
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145467968755681
# Converged in iteration 743 with cost 0.12145172705743083 because of step counter
# Final cost : 0.12145172705743083
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145172705743083
# Converged in iteration 1 with cost 0.12145172705743083 because of step counter
# Final cost : 0.12145172705743083
# Compute control for a deterministic system
# Cost in iteration 0: 0.12145172705743083
# Converged in iteration 19 with cost 0.12145172705737838 because of step counter
# Final cost : 0.12145172705737838
# Compute control for a deterministic system
# Cost in iteration 0: 0.11852897132803401
# Final cost : 0.11075792591090595
# Compute control for a deterministic system
# Cost in iteration 0: 0.11075792591090595
# Final cost : 0.11007209135667519
# Compute control for a deterministic system
# Cost in iteration 0: 0.11007209135667519
# Final cost : 0.11006310629110674
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006310629110674
# Final cost : 0.11006308972066431
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308972066431
# Converged in iteration 714 with cost 0.11006308960020092 because of step counter
# Final cost : 0.11006308960020092
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.09345326082904384
# Final cost : 0.09209777312271474
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209777312271474
# Final cost : 0.09209706306912471
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706306912471
# Converged in iteration 237 with cost 0.09209706302313136 because of step counter
# Final cost : 0.09209706302313136
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302313136
# Converged in iteration 1 with cost 0.09209706302313136 because of step counter
# Final cost : 0.09209706302313136
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302313136
# Converged in iteration 1 with cost 0.09209706302313136 because of step counter
# Final cost : 0.09209706302313136
# Compute control for a deterministic system
# Cost in iteration 0: 0.10646771210341358
# Final cost : 0.1062202186901384
# Compute control for a deterministic system
# Cost in iteration 0: 0.1062202186901384
# Final cost : 0.10621989031661977
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989031661977
# Converged in iteration 207 with cost 0.1062198903040762 because of step counter
# Final cost : 0.1062198903040762
# Compute control for a deterministic system
# Cost in iteration 0: 0.1062198903040762
# Converged in iteration 3 with cost 0.10621989030407387 because of step counter
# Final cost : 0.10621989030407387
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030407387
# Converged in iteration 1 with cost 0.10621989030407387 because of step counter
# Final cost : 0.10621989030407387
# Compute control for a deterministic system
# Cost in iteration 0: 0.11905032891141766
# Final cost : 0.1188654544428884
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188654544428884
# Final cost : 0.1188653394522113
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188653394522113
# Converged in iteration 144 with cost 0.11886533945082418 because of step counter
# Final cost : 0.11886533945082418
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886533945082418
# Converged in iteration 10 with cost 0.11886533945081271 because of step counter
# Final cost : 0.11886533945081271
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886533945081271
# Converged in iteration 4 with cost 0.11886533945080568 because of step counter
# Final cost : 0.11886533945080568
# Compute control for a deterministic system
# Cost in iteration 0: 0.11015469684963414
# Final cost : 0.11006318882450479
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006318882450479
# Final cost : 0.11006308960358097
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308960358097
# Converged in iteration 167 with cost 0.11006308959982226 because of step counter
# Final cost : 0.11006308959982226
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308959982226
# Converged in iteration 1 with cost 0.11006308959982226 because of step counter
# Final cost : 0.11006308959982226
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308959982226
# Converged in iteration 1 with cost 0.11006308959982226 because of step counter
# Final cost : 0.11006308959982226
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.13917243590845815
# Final cost : 0.0950107715535109
# Compute control for a deterministic system
# Cost in iteration 0: 0.0950107715535109
# Final cost : 0.09209706716758564
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706716758564
# Converged in iteration 315 with cost 0.09209706302314095 because of step counter
# Final cost : 0.09209706302314095
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314095
# Converged in iteration 1 with cost 0.09209706302314095 because of step counter
# Final cost : 0.09209706302314095
# Compute control for a deterministic system
# Cost in iteration 0: 0.09209706302314095
# Converged in iteration 13 with cost 0.09209706302310015 because of step counter
# Final cost : 0.09209706302310015
# Compute control for a deterministic system
# Cost in iteration 0: 0.16011715476904698
# Final cost : 0.10973770535631346
# Compute control for a deterministic system
# Cost in iteration 0: 0.10973770535631346
# Final cost : 0.10621989646523672
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989646523672
# Converged in iteration 316 with cost 0.10621989030404369 because of step counter
# Final cost : 0.10621989030404369
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030404369
# Converged in iteration 2 with cost 0.10621989030404368 because of step counter
# Final cost : 0.10621989030404368
# Compute control for a deterministic system
# Cost in iteration 0: 0.10621989030404368
# Converged in iteration 12 with cost 0.1062198903040035 because of step counter
# Final cost : 0.1062198903040035
# Compute control for a deterministic system
# Cost in iteration 0: 0.16989287644596618
# Final cost : 0.12049137149764126
# Compute control for a deterministic system
# Cost in iteration 0: 0.12049137149764126
# Final cost : 0.11886534249347099
# Compute control for a deterministic system
# Cost in iteration 0: 0.11886534249347099
# Final cost : 0.1188653394527578
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188653394527578
# Converged in iteration 375 with cost 0.1188653394508644 because of step counter
# Final cost : 0.1188653394508644
# Compute control for a deterministic system
# Cost in iteration 0: 0.1188653394508644
# Converged in iteration 1 with cost 0.1188653394508644 because of step counter
# Final cost : 0.1188653394508644
# Compute control for a deterministic system
# Cost in iteration 0: 0.14332093685446906
# Final cost : 0.11159634090161305
# Compute control for a deterministic system
# Cost in iteration 0: 0.11159634090161305
# Final cost : 0.11006309489459733
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006309489459733
# Converged in iteration 564 with cost 0.11006308959974467 because of step counter
# Final cost : 0.11006308959974467
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308959974467
# Converged in iteration 1 with cost 0.11006308959974467 because of step counter
# Final cost : 0.11006308959974467
# Compute control for a deterministic system
# Cost in iteration 0: 0.11006308959974467
# Converged in iteration 1 with cost 0.11006308959974467 because of step counter
# Final cost : 0.11006308959974467
# ----------------------------------------------- 0
# cost =  0.33379680388683586
# Compute control for a deterministic system
# Cost in iteration 0: 0.3704527274958769
# Final cost : 0.33434738522752017
# Compute control for a deterministic system
# Cost in iteration 0: 0.33434738522752017
# Final cost : 0.333796803888157
# Compute control for a deterministic system
# Cost in iteration 0: 0.333796803888157
# Converged in iteration 44 with cost 0.3337968038868756 because of step counter
# Final cost : 0.3337968038868756
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868756
# Converged in iteration 1 with cost 0.3337968038868756 because of step counter
# Final cost : 0.3337968038868756
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868756
# Converged in iteration 1 with cost 0.3337968038868756 because of step counter
# Final cost : 0.3337968038868756
# cost =  0.3837872624689542
# Compute control for a deterministic system
# Cost in iteration 0: 0.43208729002701396
# Final cost : 0.38474054791586937
# Compute control for a deterministic system
# Cost in iteration 0: 0.38474054791586937
# Final cost : 0.3837872625565211
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872625565211
# Converged in iteration 125 with cost 0.38378726246900174 because of step counter
# Final cost : 0.38378726246900174
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246900174
# Converged in iteration 1 with cost 0.38378726246900174 because of step counter
# Final cost : 0.38378726246900174
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246900174
# Converged in iteration 1 with cost 0.38378726246900174 because of step counter
# Final cost : 0.38378726246900174
# cost =  0.4373646787280548
# Compute control for a deterministic system
# Cost in iteration 0: 0.48599397790180976
# Final cost : 0.43841955896160223
# Compute control for a deterministic system
# Cost in iteration 0: 0.43841955896160223
# Final cost : 0.43736467910816834
# Compute control for a deterministic system
# Cost in iteration 0: 0.43736467910816834
# Converged in iteration 174 with cost 0.4373646787281133 because of vanishing difference
# Final cost : 0.4373646787281133
# Compute control for a deterministic system
# Cost in iteration 0: 0.4373646787281133
# Converged in iteration 1 with cost 0.4373646787281133 because of step counter
# Final cost : 0.4373646787281133
# Compute control for a deterministic system
# Cost in iteration 0: 0.4373646787281133
# Converged in iteration 1 with cost 0.4373646787281133 because of step counter
# Final cost : 0.4373646787281133
# cost =  0.42329424942287913
# Compute control for a deterministic system
# Cost in iteration 0: 0.5587999549140881
# Final cost : 0.49531975674899525
# Compute control for a deterministic system
# Cost in iteration 0: 0.49531975674899525
# Final cost : 0.4941577030966271
# Compute control for a deterministic system
# Cost in iteration 0: 0.4941577030966271
# Converged in iteration 160 with cost 0.4941577025936806 because of vanishing difference
# Final cost : 0.4941577025936806
# Compute control for a deterministic system
# Cost in iteration 0: 0.4941577025936806
# Converged in iteration 15 with cost 0.4941577025935934 because of step counter
# Final cost : 0.4941577025935934
# Compute control for a deterministic system
# Cost in iteration 0: 0.4941577025935934
# Converged in iteration 2 with cost 0.49415770259359326 because of step counter
# Final cost : 0.49415770259359326
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.4678318436589506
# Final cost : 0.42329457539350107
# Compute control for a deterministic system
# Cost in iteration 0: 0.42329457539350107
# Converged in iteration 857 with cost 0.4232942494233247 because of step counter
# Final cost : 0.4232942494233247
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494233247
# Converged in iteration 26 with cost 0.4232942494230963 because of step counter
# Final cost : 0.4232942494230963
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494230963
# Converged in iteration 1 with cost 0.4232942494230963 because of step counter
# Final cost : 0.4232942494230963
# Compute control for a deterministic system
# Cost in iteration 0: 0.4983236411057457
# Final cost : 0.458630516407711
# Compute control for a deterministic system
# Cost in iteration 0: 0.458630516407711
# Final cost : 0.4586301705131202
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586301705131202
# Converged in iteration 59 with cost 0.4586301705125046 because of step counter
# Final cost : 0.4586301705125046
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586301705125046
# Converged in iteration 1 with cost 0.4586301705125046 because of step counter
# Final cost : 0.4586301705125046
# Compute control for a deterministic system
# Cost in iteration 0: 0.44525473823574324
# Final cost : 0.3837872625772272
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872625772272
# Converged in iteration 99 with cost 0.38378726246913875 because of step counter
# Final cost : 0.38378726246913875
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246913875
# Converged in iteration 26 with cost 0.3837872624689875 because of step counter
# Final cost : 0.3837872624689875
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624689875
# Converged in iteration 2 with cost 0.3837872624689851 because of step counter
# Final cost : 0.3837872624689851
# Compute control for a deterministic system
# Cost in iteration 0: 0.3782523070304778
# Final cost : 0.3337968038914546
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038914546
# Converged in iteration 72 with cost 0.3337968038869282 because of step counter
# Final cost : 0.3337968038869282
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038869282
# Converged in iteration 17 with cost 0.33379680388684885 because of step counter
# Final cost : 0.33379680388684885
# Compute control for a deterministic system
# Cost in iteration 0: 0.33379680388684885
# Converged in iteration 1 with cost 0.33379680388684885 because of step counter
# Final cost : 0.33379680388684885
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.3528470263311403
# Final cost : 0.33617915489715905
# Compute control for a deterministic system
# Cost in iteration 0: 0.33617915489715905
# Final cost : 0.3337968038934032
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038934032
# Converged in iteration 91 with cost 0.33379680388685173 because of step counter
# Final cost : 0.33379680388685173
# Compute control for a deterministic system
# Cost in iteration 0: 0.33379680388685173
# Converged in iteration 1 with cost 0.33379680388685173 because of step counter
# Final cost : 0.33379680388685173
# Compute control for a deterministic system
# Cost in iteration 0: 0.33379680388685173
# Converged in iteration 2 with cost 0.3337968038868511 because of step counter
# Final cost : 0.3337968038868511
# Compute control for a deterministic system
# Cost in iteration 0: 0.4117262401485352
# Final cost : 0.3870611600190054
# Compute control for a deterministic system
# Cost in iteration 0: 0.3870611600190054
# Final cost : 0.3837872626248071
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872626248071
# Converged in iteration 122 with cost 0.38378726246903405 because of step counter
# Final cost : 0.38378726246903405
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246903405
# Converged in iteration 1 with cost 0.38378726246903405 because of step counter
# Final cost : 0.38378726246903405
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246903405
# Converged in iteration 12 with cost 0.3837872624689575 because of step counter
# Final cost : 0.3837872624689575
# Compute control for a deterministic system
# Cost in iteration 0: 0.4791606051966837
# Final cost : 0.4593568779306875
# Compute control for a deterministic system
# Cost in iteration 0: 0.4593568779306875
# Final cost : 0.45863033869717695
# Compute control for a deterministic system
# Cost in iteration 0: 0.45863033869717695
# Final cost : 0.4586301705136228
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586301705136228
# Converged in iteration 53 with cost 0.458630170512523 because of step counter
# Final cost : 0.458630170512523
# Compute control for a deterministic system
# Cost in iteration 0: 0.458630170512523
# Converged in iteration 1 with cost 0.458630170512523 because of step counter
# Final cost : 0.458630170512523
# Compute control for a deterministic system
# Cost in iteration 0: 0.4334611962632975
# Final cost : 0.42406600141467216
# Compute control for a deterministic system
# Cost in iteration 0: 0.42406600141467216
# Final cost : 0.4232944342187998
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232944342187998
# Converged in iteration 844 with cost 0.42329424942313576 because of step counter
# Final cost : 0.42329424942313576
# Compute control for a deterministic system
# Cost in iteration 0: 0.42329424942313576
# Converged in iteration 1 with cost 0.42329424942313576 because of step counter
# Final cost : 0.42329424942313576
# Compute control for a deterministic system
# Cost in iteration 0: 0.42329424942313576
# Converged in iteration 1 with cost 0.42329424942313576 because of step counter
# Final cost : 0.42329424942313576
# ----------------------------------------------- 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.37783860464433977
# Final cost : 0.3384345149750211
# Compute control for a deterministic system
# Cost in iteration 0: 0.3384345149750211
# Final cost : 0.3337968039007409
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968039007409
# Converged in iteration 80 with cost 0.3337968038869109 because of step counter
# Final cost : 0.3337968038869109
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038869109
# Converged in iteration 3 with cost 0.3337968038869081 because of step counter
# Final cost : 0.3337968038869081
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038869081
# Converged in iteration 10 with cost 0.3337968038868313 because of step counter
# Final cost : 0.3337968038868313
# -----------------------------------------------
# 3 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.43182483870980537
# Final cost : 0.3899441427022384
# Compute control for a deterministic system
# Cost in iteration 0: 0.3899441427022384
# Final cost : 0.3837872628122058
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872628122058
# Converged in iteration 134 with cost 0.3837872624690375 because of step counter
# Final cost : 0.3837872624690375
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624690375
# Converged in iteration 15 with cost 0.3837872624689577 because of step counter
# Final cost : 0.3837872624689577
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624689577
# Converged in iteration 1 with cost 0.3837872624689577 because of step counter
# Final cost : 0.3837872624689577
# Compute control for a deterministic system
# Cost in iteration 0: 0.48302827039565815
# Final cost : 0.45991409203522066
# Compute control for a deterministic system
# Cost in iteration 0: 0.45991409203522066
# Final cost : 0.4586304677752261
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586304677752261
# Final cost : 0.4586301705135789
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586301705135789
# Converged in iteration 23 with cost 0.4586301705128373 because of step counter
# Final cost : 0.4586301705128373
# Compute control for a deterministic system
# Cost in iteration 0: 0.4586301705128373
# Converged in iteration 2 with cost 0.4586301705128356 because of step counter
# Final cost : 0.4586301705128356
# Compute control for a deterministic system
# Cost in iteration 0: 0.4421040124130896
# Final cost : 0.42468137286162
# Compute control for a deterministic system
# Cost in iteration 0: 0.42468137286162
# Final cost : 0.4232945177477675
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232945177477675
# Converged in iteration 810 with cost 0.4232942494234629 because of vanishing difference
# Final cost : 0.4232942494234629
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494234629
# Converged in iteration 55 with cost 0.4232942494229884 because of step counter
# Final cost : 0.4232942494229884
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494229884
# Converged in iteration 1 with cost 0.4232942494229884 because of step counter
# Final cost : 0.4232942494229884
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.3358955224610127
# Final cost : 0.33380972644395623
# Compute control for a deterministic system
# Cost in iteration 0: 0.33380972644395623
# Converged in iteration 538 with cost 0.33379680388695526 because of vanishing difference
# Final cost : 0.33379680388695526
# Compute control for a deterministic system
# Cost in iteration 0: 0.33379680388695526
# Converged in iteration 11 with cost 0.3337968038868665 because of step counter
# Final cost : 0.3337968038868665
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868665
# Converged in iteration 2 with cost 0.3337968038868659 because of step counter
# Final cost : 0.3337968038868659
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868659
# Converged in iteration 2 with cost 0.333796803886865 because of step counter
# Final cost : 0.333796803886865
# Compute control for a deterministic system
# Cost in iteration 0: 0.3907025305333477
# Final cost : 0.3838025800829249
# Compute control for a deterministic system
# Cost in iteration 0: 0.3838025800829249
# Converged in iteration 432 with cost 0.38378726246912637 because of step counter
# Final cost : 0.38378726246912637
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246912637
# Converged in iteration 13 with cost 0.3837872624690407 because of step counter
# Final cost : 0.3837872624690407
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624690407
# Converged in iteration 2 with cost 0.38378726246903927 because of vanishing difference
# Final cost : 0.38378726246903927
# Compute control for a deterministic system
# Cost in iteration 0: 0.38378726246903927
# Converged in iteration 1 with cost 0.38378726246903927 because of step counter
# Final cost : 0.38378726246903927
# Compute control for a deterministic system
# Cost in iteration 0: 0.44112518103325293
# Final cost : 0.43738415085672433
# Compute control for a deterministic system
# Cost in iteration 0: 0.43738415085672433
# Converged in iteration 742 with cost 0.4373646787281659 because of step counter
# Final cost : 0.4373646787281659
# Compute control for a deterministic system
# Cost in iteration 0: 0.4373646787281659
# Converged in iteration 6 with cost 0.43736467872811213 because of vanishing difference
# Final cost : 0.43736467872811213
# Compute control for a deterministic system
# Cost in iteration 0: 0.43736467872811213
# Converged in iteration 10 with cost 0.43736467872809365 because of step counter
# Final cost : 0.43736467872809365
# Compute control for a deterministic system
# Cost in iteration 0: 0.43736467872809365
# Converged in iteration 1 with cost 0.43736467872809365 because of step counter
# Final cost : 0.43736467872809365
# Compute control for a deterministic system
# Cost in iteration 0: 0.42810784898111
# Final cost : 0.4233005418383236
# Compute control for a deterministic system
# Cost in iteration 0: 0.4233005418383236
# Converged in iteration 428 with cost 0.42329424942307786 because of step counter
# Final cost : 0.42329424942307786
# Compute control for a deterministic system
# Cost in iteration 0: 0.42329424942307786
# Converged in iteration 4 with cost 0.4232942494230224 because of step counter
# Final cost : 0.4232942494230224
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494230224
# Converged in iteration 1 with cost 0.4232942494230224 because of step counter
# Final cost : 0.4232942494230224
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494230224
# Converged in iteration 5 with cost 0.4232942494229933 because of step counter
# Final cost : 0.4232942494229933
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.39113091018067325
# Final cost : 0.33672858913503884
# Compute control for a deterministic system
# Cost in iteration 0: 0.33672858913503884
# Converged in iteration 588 with cost 0.3337968038869543 because of step counter
# Final cost : 0.3337968038869543
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038869543
# Converged in iteration 17 with cost 0.3337968038868695 because of step counter
# Final cost : 0.3337968038868695
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868695
# Converged in iteration 1 with cost 0.3337968038868695 because of step counter
# Final cost : 0.3337968038868695
# Compute control for a deterministic system
# Cost in iteration 0: 0.3337968038868695
# Converged in iteration 1 with cost 0.3337968038868695 because of step counter
# Final cost : 0.3337968038868695
# Compute control for a deterministic system
# Cost in iteration 0: 0.43284751034177954
# Final cost : 0.3873583774328176
# Compute control for a deterministic system
# Cost in iteration 0: 0.3873583774328176
# Converged in iteration 674 with cost 0.3837872624690584 because of step counter
# Final cost : 0.3837872624690584
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624690584
# Converged in iteration 12 with cost 0.3837872624689911 because of step counter
# Final cost : 0.3837872624689911
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624689911
# Converged in iteration 1 with cost 0.3837872624689911 because of step counter
# Final cost : 0.3837872624689911
# Compute control for a deterministic system
# Cost in iteration 0: 0.3837872624689911
# Converged in iteration 1 with cost 0.3837872624689911 because of step counter
# Final cost : 0.3837872624689911
# Compute control for a deterministic system
# Cost in iteration 0: 0.5184411576431304
# Final cost : 0.4414894408325242
# Compute control for a deterministic system
# Cost in iteration 0: 0.4414894408325242
# Final cost : 0.4373646787286472
# Compute control for a deterministic system
# Cost in iteration 0: 0.4373646787286472
# Converged in iteration 35 with cost 0.43736467872812146 because of step counter
# Final cost : 0.43736467872812146
# Compute control for a deterministic system
# Cost in iteration 0: 0.43736467872812146
# Converged in iteration 1 with cost 0.43736467872812146 because of step counter
# Final cost : 0.43736467872812146
# Compute control for a deterministic system
# Cost in iteration 0: 0.43736467872812146
# Converged in iteration 1 with cost 0.43736467872812146 because of step counter
# Final cost : 0.43736467872812146
# Compute control for a deterministic system
# Cost in iteration 0: 0.44488751709669316
# Final cost : 0.42510402050794466
# Compute control for a deterministic system
# Cost in iteration 0: 0.42510402050794466
# Final cost : 0.4232942494264906
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494264906
# Converged in iteration 154 with cost 0.4232942494235376 because of step counter
# Final cost : 0.4232942494235376
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494235376
# Converged in iteration 6 with cost 0.4232942494235158 because of step counter
# Final cost : 0.4232942494235158
# Compute control for a deterministic system
# Cost in iteration 0: 0.4232942494235158
# Converged in iteration 1 with cost 0.4232942494235158 because of step counter
# Final cost : 0.4232942494235158

# %%
save(results_peak)
