# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 00.3811417843321322
y_init = 0.48364147610113273
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,94], wc.inh[0,94]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [  19  209  400  591  781  972 1163 1354 1544 1735 1926 2116 2307 2498
#  2688 2879]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
results_min = readfile("results_min_w1.pickle")

ind_list = range(41)
options = [True, True, True, True, True, True, False, False]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy()
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy()
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy()
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06183363511657163
# Converged in iteration 95 with cost 0.01240142379173216 because of step counter
# Final cost : 0.01240142379173216
# Compute control for a deterministic system
# Cost in iteration 0: 0.01240142379173216
# Converged in iteration 1 with cost 0.01240142379173216 because of step counter
# Final cost : 0.01240142379173216
# Compute control for a deterministic system
# Cost in iteration 0: 0.01240142379173216
# Converged in iteration 1 with cost 0.01240142379173216 because of step counter
# Final cost : 0.01240142379173216
# Compute control for a deterministic system
# Cost in iteration 0: 0.01240142379173216
# Converged in iteration 1 with cost 0.01240142379173216 because of step counter
# Final cost : 0.01240142379173216
# Compute control for a deterministic system
# Cost in iteration 0: 0.01240142379173216
# Converged in iteration 1 with cost 0.01240142379173216 because of step counter
# Final cost : 0.01240142379173216
# Compute control for a deterministic system
# Cost in iteration 0: 0.04591933635854318
# Converged in iteration 75 with cost 0.01771358653201141 because of step counter
# Final cost : 0.01771358653201141
# Compute control for a deterministic system
# Cost in iteration 0: 0.01771358653201141
# Converged in iteration 1 with cost 0.01771358653201141 because of step counter
# Final cost : 0.01771358653201141
# Compute control for a deterministic system
# Cost in iteration 0: 0.01771358653201141
# Converged in iteration 1 with cost 0.01771358653201141 because of step counter
# Final cost : 0.01771358653201141
# Compute control for a deterministic system
# Cost in iteration 0: 0.01771358653201141
# Converged in iteration 1 with cost 0.01771358653201141 because of step counter
# Final cost : 0.01771358653201141
# Compute control for a deterministic system
# Cost in iteration 0: 0.01771358653201141
# Converged in iteration 1 with cost 0.01771358653201141 because of step counter
# Final cost : 0.01771358653201141
# Compute control for a deterministic system
# Cost in iteration 0: 0.06507688168060671
# Converged in iteration 93 with cost 0.024531248116486964 because of step counter
# Final cost : 0.024531248116486964
# Compute control for a deterministic system
# Cost in iteration 0: 0.024531248116486964
# Converged in iteration 1 with cost 0.024531248116486964 because of step counter
# Final cost : 0.024531248116486964
# Compute control for a deterministic system
# Cost in iteration 0: 0.024531248116486964
# Converged in iteration 1 with cost 0.024531248116486964 because of step counter
# Final cost : 0.024531248116486964
# Compute control for a deterministic system
# Cost in iteration 0: 0.024531248116486964
# Converged in iteration 1 with cost 0.024531248116486964 because of step counter
# Final cost : 0.024531248116486964
# Compute control for a deterministic system
# Cost in iteration 0: 0.024531248116486964
# Converged in iteration 1 with cost 0.024531248116486964 because of step counter
# Final cost : 0.024531248116486964
# Compute control for a deterministic system
# Cost in iteration 0: 0.06696107955706741
# Converged in iteration 92 with cost 0.03149598621281971 because of step counter
# Final cost : 0.03149598621281971
# Compute control for a deterministic system
# Cost in iteration 0: 0.03149598621281971
# Converged in iteration 1 with cost 0.03149598621281971 because of step counter
# Final cost : 0.03149598621281971
# Compute control for a deterministic system
# Cost in iteration 0: 0.03149598621281971
# Converged in iteration 1 with cost 0.03149598621281971 because of step counter
# Final cost : 0.03149598621281971
# Compute control for a deterministic system
# Cost in iteration 0: 0.03149598621281971
# Converged in iteration 1 with cost 0.03149598621281971 because of step counter
# Final cost : 0.03149598621281971
# Compute control for a deterministic system
# Cost in iteration 0: 0.03149598621281971
# Converged in iteration 1 with cost 0.03149598621281971 because of step counter
# Final cost : 0.03149598621281971
# Compute control for a deterministic system
# Cost in iteration 0: 0.07032716237777739
# Converged in iteration 94 with cost 0.03861851012696684 because of step counter
# Final cost : 0.03861851012696684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03861851012696684
# Converged in iteration 1 with cost 0.03861851012696684 because of step counter
# Final cost : 0.03861851012696684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03861851012696684
# Converged in iteration 1 with cost 0.03861851012696684 because of step counter
# Final cost : 0.03861851012696684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03861851012696684
# Converged in iteration 1 with cost 0.03861851012696684 because of step counter
# Final cost : 0.03861851012696684
# Compute control for a deterministic system
# Cost in iteration 0: 0.03861851012696684
# Converged in iteration 1 with cost 0.03861851012696684 because of step counter
# Final cost : 0.03861851012696684
# Compute control for a deterministic system
# Cost in iteration 0: 0.05888845229704766
# Converged in iteration 63 with cost 0.04433575069661924 because of step counter
# Final cost : 0.04433575069661924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04433575069661924
# Converged in iteration 1 with cost 0.04433575069661924 because of step counter
# Final cost : 0.04433575069661924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04433575069661924
# Converged in iteration 1 with cost 0.04433575069661924 because of step counter
# Final cost : 0.04433575069661924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04433575069661924
# Converged in iteration 1 with cost 0.04433575069661924 because of step counter
# Final cost : 0.04433575069661924
# Compute control for a deterministic system
# Cost in iteration 0: 0.04433575069661924
# Converged in iteration 1 with cost 0.04433575069661924 because of step counter
# Final cost : 0.04433575069661924
# Compute control for a deterministic system
# Cost in iteration 0: 0.07783180323839904
# Converged in iteration 94 with cost 0.051837384024832754 because of step counter
# Final cost : 0.051837384024832754
# Compute control for a deterministic system
# Cost in iteration 0: 0.051837384024832754
# Converged in iteration 1 with cost 0.051837384024832754 because of step counter
# Final cost : 0.051837384024832754
# Compute control for a deterministic system
# Cost in iteration 0: 0.051837384024832754
# Converged in iteration 1 with cost 0.051837384024832754 because of step counter
# Final cost : 0.051837384024832754
# Compute control for a deterministic system
# Cost in iteration 0: 0.051837384024832754
# Converged in iteration 1 with cost 0.051837384024832754 because of step counter
# Final cost : 0.051837384024832754
# Compute control for a deterministic system
# Cost in iteration 0: 0.051837384024832754
# Converged in iteration 1 with cost 0.051837384024832754 because of step counter
# Final cost : 0.051837384024832754
# Compute control for a deterministic system
# Cost in iteration 0: 0.08278956593716427
# Converged in iteration 100 with cost 0.05940752940179332 because of step counter
# Final cost : 0.05940752940179332
# Compute control for a deterministic system
# Cost in iteration 0: 0.05940752940179332
# Converged in iteration 1 with cost 0.05940752940179332 because of step counter
# Final cost : 0.05940752940179332
# Compute control for a deterministic system
# Cost in iteration 0: 0.05940752940179332
# Converged in iteration 1 with cost 0.05940752940179332 because of step counter
# Final cost : 0.05940752940179332
# Compute control for a deterministic system
# Cost in iteration 0: 0.05940752940179332
# Converged in iteration 1 with cost 0.05940752940179332 because of step counter
# Final cost : 0.05940752940179332
# Compute control for a deterministic system
# Cost in iteration 0: 0.05940752940179332
# Converged in iteration 1 with cost 0.05940752940179332 because of step counter
# Final cost : 0.05940752940179332
# Compute control for a deterministic system
# Cost in iteration 0: 0.08832420065123994
# Converged in iteration 95 with cost 0.06714294230126935 because of step counter
# Final cost : 0.06714294230126935
# Compute control for a deterministic system
# Cost in iteration 0: 0.06714294230126935
# Converged in iteration 1 with cost 0.06714294230126935 because of step counter
# Final cost : 0.06714294230126935
# Compute control for a deterministic system
# Cost in iteration 0: 0.06714294230126935
# Converged in iteration 1 with cost 0.06714294230126935 because of step counter
# Final cost : 0.06714294230126935
# Compute control for a deterministic system
# Cost in iteration 0: 0.06714294230126935
# Converged in iteration 1 with cost 0.06714294230126935 because of step counter
# Final cost : 0.06714294230126935
# Compute control for a deterministic system
# Cost in iteration 0: 0.06714294230126935
# Converged in iteration 1 with cost 0.06714294230126935 because of step counter
# Final cost : 0.06714294230126935
# Compute control for a deterministic system
# Cost in iteration 0: 0.08138607217877306
# Converged in iteration 60 with cost 0.07324745604880169 because of step counter
# Final cost : 0.07324745604880169
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324745604880169
# Converged in iteration 1 with cost 0.07324745604880169 because of step counter
# Final cost : 0.07324745604880169
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324745604880169
# Converged in iteration 1 with cost 0.07324745604880169 because of step counter
# Final cost : 0.07324745604880169
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324745604880169
# Converged in iteration 1 with cost 0.07324745604880169 because of step counter
# Final cost : 0.07324745604880169
# Compute control for a deterministic system
# Cost in iteration 0: 0.07324745604880169
# Converged in iteration 1 with cost 0.07324745604880169 because of step counter
# Final cost : 0.07324745604880169
# Compute control for a deterministic system
# Cost in iteration 0: 0.09935430769846497
# Converged in iteration 101 with cost 0.0814927991534191 because of step counter
# Final cost : 0.0814927991534191
# Compute control for a deterministic system
# Cost in iteration 0: 0.0814927991534191
# Converged in iteration 1 with cost 0.0814927991534191 because of step counter
# Final cost : 0.0814927991534191
# Compute control for a deterministic system
# Cost in iteration 0: 0.0814927991534191
# Converged in iteration 1 with cost 0.0814927991534191 because of step counter
# Final cost : 0.0814927991534191
# Compute control for a deterministic system
# Cost in iteration 0: 0.0814927991534191
# Converged in iteration 1 with cost 0.0814927991534191 because of step counter
# Final cost : 0.0814927991534191
# Compute control for a deterministic system
# Cost in iteration 0: 0.0814927991534191
# Converged in iteration 1 with cost 0.0814927991534191 because of step counter
# Final cost : 0.0814927991534191
# Compute control for a deterministic system
# Cost in iteration 0: 0.10627354509866142
# Converged in iteration 104 with cost 0.0897596393376488 because of step counter
# Final cost : 0.0897596393376488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897596393376488
# Converged in iteration 1 with cost 0.0897596393376488 because of step counter
# Final cost : 0.0897596393376488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897596393376488
# Converged in iteration 1 with cost 0.0897596393376488 because of step counter
# Final cost : 0.0897596393376488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897596393376488
# Converged in iteration 1 with cost 0.0897596393376488 because of step counter
# Final cost : 0.0897596393376488
# Compute control for a deterministic system
# Cost in iteration 0: 0.0897596393376488
# Converged in iteration 1 with cost 0.0897596393376488 because of step counter
# Final cost : 0.0897596393376488
# Compute control for a deterministic system
# Cost in iteration 0: 0.11327008392738258
# Converged in iteration 112 with cost 0.09814495676067907 because of step counter
# Final cost : 0.09814495676067907
# Compute control for a deterministic system
# Cost in iteration 0: 0.09814495676067907
# Converged in iteration 1 with cost 0.09814495676067907 because of step counter
# Final cost : 0.09814495676067907
# Compute control for a deterministic system
# Cost in iteration 0: 0.09814495676067907
# Converged in iteration 1 with cost 0.09814495676067907 because of step counter
# Final cost : 0.09814495676067907
# Compute control for a deterministic system
# Cost in iteration 0: 0.09814495676067907
# Converged in iteration 1 with cost 0.09814495676067907 because of step counter
# Final cost : 0.09814495676067907
# Compute control for a deterministic system
# Cost in iteration 0: 0.09814495676067907
# Converged in iteration 1 with cost 0.09814495676067907 because of step counter
# Final cost : 0.09814495676067907
# Compute control for a deterministic system
# Cost in iteration 0: 0.11593401422912664
# Converged in iteration 147 with cost 0.10518585153852392 because of step counter
# Final cost : 0.10518585153852392
# Compute control for a deterministic system
# Cost in iteration 0: 0.10518585153852392
# Converged in iteration 1 with cost 0.10518585153852392 because of step counter
# Final cost : 0.10518585153852392
# Compute control for a deterministic system
# Cost in iteration 0: 0.10518585153852392
# Converged in iteration 1 with cost 0.10518585153852392 because of step counter
# Final cost : 0.10518585153852392
# Compute control for a deterministic system
# Cost in iteration 0: 0.10518585153852392
# Converged in iteration 1 with cost 0.10518585153852392 because of step counter
# Final cost : 0.10518585153852392
# Compute control for a deterministic system
# Cost in iteration 0: 0.10518585153852392
# Converged in iteration 1 with cost 0.10518585153852392 because of step counter
# Final cost : 0.10518585153852392
# Compute control for a deterministic system
# Cost in iteration 0: 0.11915713571076658
# Converged in iteration 53 with cost 0.11341458754877412 because of vanishing difference
# Final cost : 0.11341458754877412
# Compute control for a deterministic system
# Cost in iteration 0: 0.11341458754877412
# Converged in iteration 9 with cost 0.11341458754300866 because of step counter
# Final cost : 0.11341458754300866
# Compute control for a deterministic system
# Cost in iteration 0: 0.11341458754300866
# Converged in iteration 1 with cost 0.11341458754300866 because of step counter
# Final cost : 0.11341458754300866
# Compute control for a deterministic system
# Cost in iteration 0: 0.11341458754300866
# Converged in iteration 1 with cost 0.11341458754300866 because of step counter
# Final cost : 0.11341458754300866
# Compute control for a deterministic system
# Cost in iteration 0: 0.11341458754300866
# Converged in iteration 1 with cost 0.11341458754300866 because of step counter
# Final cost : 0.11341458754300866
# Compute control for a deterministic system
# Cost in iteration 0: 0.1296829969387646
# Converged in iteration 137 with cost 0.12074990035703964 because of step counter
# Final cost : 0.12074990035703964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074990035703964
# Converged in iteration 1 with cost 0.12074990035703964 because of step counter
# Final cost : 0.12074990035703964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074990035703964
# Converged in iteration 1 with cost 0.12074990035703964 because of step counter
# Final cost : 0.12074990035703964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074990035703964
# Converged in iteration 1 with cost 0.12074990035703964 because of step counter
# Final cost : 0.12074990035703964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12074990035703964
# Converged in iteration 1 with cost 0.12074990035703964 because of step counter
# Final cost : 0.12074990035703964
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.14596241190257095
# Converged in iteration 137 with cost 0.13186036705700158 because of step counter
# Final cost : 0.13186036705700158
# Compute control for a deterministic system
# Cost in iteration 0: 0.13186036705700158
# Converged in iteration 1 with cost 0.13186036705700158 because of step counter
# Final cost : 0.13186036705700158
# Compute control for a deterministic system
# Cost in iteration 0: 0.13186036705700158
# Converged in iteration 1 with cost 0.13186036705700158 because of step counter
# Final cost : 0.13186036705700158
# Compute control for a deterministic system
# Cost in iteration 0: 0.13186036705700158
# Converged in iteration 1 with cost 0.13186036705700158 because of step counter
# Final cost : 0.13186036705700158
# Compute control for a deterministic system
# Cost in iteration 0: 0.13186036705700158
# Converged in iteration 1 with cost 0.13186036705700158 because of step counter
# Final cost : 0.13186036705700158
# Compute control for a deterministic system
# Cost in iteration 0: 0.38895820956232224
# Cost in iteration 200: 0.11936112169364686
# Final cost : 0.11936112169364686
# Compute control for a deterministic system
# Cost in iteration 0: 0.11936112169364686
# Converged in iteration 16 with cost 0.11932041984347698 because of step counter
# Final cost : 0.11932041984347698
# Compute control for a deterministic system
# Cost in iteration 0: 0.11932041984347698
# Converged in iteration 1 with cost 0.11932041984347698 because of step counter
# Final cost : 0.11932041984347698
# Compute control for a deterministic system
# Cost in iteration 0: 0.11932041984347698
# Converged in iteration 1 with cost 0.11932041984347698 because of step counter
# Final cost : 0.11932041984347698
# Compute control for a deterministic system
# Cost in iteration 0: 0.11932041984347698
# Converged in iteration 1 with cost 0.11932041984347698 because of step counter
# Final cost : 0.11932041984347698
# Compute control for a deterministic system
# Cost in iteration 0: 0.30981412461227836
# Cost in iteration 200: 0.11565945395226014
# Final cost : 0.11565945395226014
# Compute control for a deterministic system
# Cost in iteration 0: 0.11565945395226014
# Converged in iteration 15 with cost 0.1155944114593445 because of step counter
# Final cost : 0.1155944114593445
# Compute control for a deterministic system
# Cost in iteration 0: 0.1155944114593445
# Converged in iteration 1 with cost 0.1155944114593445 because of step counter
# Final cost : 0.1155944114593445
# Compute control for a deterministic system
# Cost in iteration 0: 0.1155944114593445
# Converged in iteration 1 with cost 0.1155944114593445 because of step counter
# Final cost : 0.1155944114593445
# Compute control for a deterministic system
# Cost in iteration 0: 0.1155944114593445
# Converged in iteration 1 with cost 0.1155944114593445 because of step counter
# Final cost : 0.1155944114593445
# Compute control for a deterministic system
# Cost in iteration 0: 0.17535916065180324
# Cost in iteration 200: 0.11109892164325198
# Final cost : 0.11109892164325198
# Compute control for a deterministic system
# Cost in iteration 0: 0.11109892164325198
# Converged in iteration 14 with cost 0.11106948023311936 because of step counter
# Final cost : 0.11106948023311936
# Compute control for a deterministic system
# Cost in iteration 0: 0.11106948023311936
# Converged in iteration 1 with cost 0.11106948023311936 because of step counter
# Final cost : 0.11106948023311936
# Compute control for a deterministic system
# Cost in iteration 0: 0.11106948023311936
# Converged in iteration 1 with cost 0.11106948023311936 because of step counter
# Final cost : 0.11106948023311936
# Compute control for a deterministic system
# Cost in iteration 0: 0.11106948023311936
# Converged in iteration 1 with cost 0.11106948023311936 because of step counter
# Final cost : 0.11106948023311936
# Compute control for a deterministic system
# Cost in iteration 0: 0.16774657917141966
# Cost in iteration 200: 0.1057694422280714
# Final cost : 0.1057694422280714
# Compute control for a deterministic system
# Cost in iteration 0: 0.1057694422280714
# Converged in iteration 16 with cost 0.10576722975269294 because of step counter
# Final cost : 0.10576722975269294
# Compute control for a deterministic system
# Cost in iteration 0: 0.10576722975269294
# Converged in iteration 1 with cost 0.10576722975269294 because of step counter
# Final cost : 0.10576722975269294
# Compute control for a deterministic system
# Cost in iteration 0: 0.10576722975269294
# Converged in iteration 1 with cost 0.10576722975269294 because of step counter
# Final cost : 0.10576722975269294
# Compute control for a deterministic system
# Cost in iteration 0: 0.10576722975269294
# Converged in iteration 1 with cost 0.10576722975269294 because of step counter
# Final cost : 0.10576722975269294
# Compute control for a deterministic system
# Cost in iteration 0: 0.16775482530576877
# Cost in iteration 200: 0.10128142309888416
# Final cost : 0.10128142309888416
# Compute control for a deterministic system
# Cost in iteration 0: 0.10128142309888416
# Converged in iteration 15 with cost 0.1012308851335117 because of step counter
# Final cost : 0.1012308851335117
# Compute control for a deterministic system
# Cost in iteration 0: 0.1012308851335117
# Converged in iteration 1 with cost 0.1012308851335117 because of step counter
# Final cost : 0.1012308851335117
# Compute control for a deterministic system
# Cost in iteration 0: 0.1012308851335117
# Converged in iteration 1 with cost 0.1012308851335117 because of step counter
# Final cost : 0.1012308851335117
# Compute control for a deterministic system
# Cost in iteration 0: 0.1012308851335117
# Converged in iteration 1 with cost 0.1012308851335117 because of step counter
# Final cost : 0.1012308851335117
# Compute control for a deterministic system
# Cost in iteration 0: 0.13745934800549015
# Converged in iteration 187 with cost 0.09656131309740232 because of step counter
# Final cost : 0.09656131309740232
# Compute control for a deterministic system
# Cost in iteration 0: 0.09656131309740232
# Converged in iteration 1 with cost 0.09656131309740232 because of step counter
# Final cost : 0.09656131309740232
# Compute control for a deterministic system
# Cost in iteration 0: 0.09656131309740232
# Converged in iteration 1 with cost 0.09656131309740232 because of step counter
# Final cost : 0.09656131309740232
# Compute control for a deterministic system
# Cost in iteration 0: 0.09656131309740232
# Converged in iteration 1 with cost 0.09656131309740232 because of step counter
# Final cost : 0.09656131309740232
# Compute control for a deterministic system
# Cost in iteration 0: 0.09656131309740232
# Converged in iteration 1 with cost 0.09656131309740232 because of step counter
# Final cost : 0.09656131309740232
# Compute control for a deterministic system
# Cost in iteration 0: 0.15916190962071108
# Cost in iteration 200: 0.09167814374945375
# Final cost : 0.09167814374945375
# Compute control for a deterministic system
# Cost in iteration 0: 0.09167814374945375
# Converged in iteration 17 with cost 0.09163992611421734 because of step counter
# Final cost : 0.09163992611421734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09163992611421734
# Converged in iteration 1 with cost 0.09163992611421734 because of step counter
# Final cost : 0.09163992611421734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09163992611421734
# Converged in iteration 1 with cost 0.09163992611421734 because of step counter
# Final cost : 0.09163992611421734
# Compute control for a deterministic system
# Cost in iteration 0: 0.09163992611421734
# Converged in iteration 1 with cost 0.09163992611421734 because of step counter
# Final cost : 0.09163992611421734
# Compute control for a deterministic system
# Cost in iteration 0: 0.1498827618730011
# Cost in iteration 200: 0.08595928326656169
# Final cost : 0.08595928326656169
# Compute control for a deterministic system
# Cost in iteration 0: 0.08595928326656169
# Converged in iteration 17 with cost 0.0859499134503178 because of step counter
# Final cost : 0.0859499134503178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859499134503178
# Converged in iteration 1 with cost 0.0859499134503178 because of step counter
# Final cost : 0.0859499134503178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859499134503178
# Converged in iteration 1 with cost 0.0859499134503178 because of step counter
# Final cost : 0.0859499134503178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859499134503178
# Converged in iteration 1 with cost 0.0859499134503178 because of step counter
# Final cost : 0.0859499134503178
# Compute control for a deterministic system
# Cost in iteration 0: 0.14865550362378546
# Cost in iteration 200: 0.08087408156801737
# Final cost : 0.08087408156801737
# Compute control for a deterministic system
# Cost in iteration 0: 0.08087408156801737
# Converged in iteration 18 with cost 0.08082440117699642 because of step counter
# Final cost : 0.08082440117699642
# Compute control for a deterministic system
# Cost in iteration 0: 0.08082440117699642
# Converged in iteration 1 with cost 0.08082440117699642 because of step counter
# Final cost : 0.08082440117699642
# Compute control for a deterministic system
# Cost in iteration 0: 0.08082440117699642
# Converged in iteration 1 with cost 0.08082440117699642 because of step counter
# Final cost : 0.08082440117699642
# Compute control for a deterministic system
# Cost in iteration 0: 0.08082440117699642
# Converged in iteration 1 with cost 0.08082440117699642 because of step counter
# Final cost : 0.08082440117699642
# Compute control for a deterministic system
# Cost in iteration 0: 0.11707920084333694
# Cost in iteration 200: 0.07591656445589923
# Final cost : 0.07591656445589923
# Compute control for a deterministic system
# Cost in iteration 0: 0.07591656445589923
# Converged in iteration 11 with cost 0.07591648788474575 because of step counter
# Final cost : 0.07591648788474575
# Compute control for a deterministic system
# Cost in iteration 0: 0.07591648788474575
# Converged in iteration 1 with cost 0.07591648788474575 because of step counter
# Final cost : 0.07591648788474575
# Compute control for a deterministic system
# Cost in iteration 0: 0.07591648788474575
# Converged in iteration 1 with cost 0.07591648788474575 because of step counter
# Final cost : 0.07591648788474575
# Compute control for a deterministic system
# Cost in iteration 0: 0.07591648788474575
# Converged in iteration 1 with cost 0.07591648788474575 because of step counter
# Final cost : 0.07591648788474575
# Compute control for a deterministic system
# Cost in iteration 0: 0.1383817018281544
# Cost in iteration 200: 0.07046239744517127
# Final cost : 0.07046239744517127
# Compute control for a deterministic system
# Cost in iteration 0: 0.07046239744517127
# Converged in iteration 21 with cost 0.07041450619537896 because of step counter
# Final cost : 0.07041450619537896
# Compute control for a deterministic system
# Cost in iteration 0: 0.07041450619537896
# Converged in iteration 1 with cost 0.07041450619537896 because of step counter
# Final cost : 0.07041450619537896
# Compute control for a deterministic system
# Cost in iteration 0: 0.07041450619537896
# Converged in iteration 1 with cost 0.07041450619537896 because of step counter
# Final cost : 0.07041450619537896
# Compute control for a deterministic system
# Cost in iteration 0: 0.07041450619537896
# Converged in iteration 1 with cost 0.07041450619537896 because of step counter
# Final cost : 0.07041450619537896
# Compute control for a deterministic system
# Cost in iteration 0: 0.12788455194843684
# Cost in iteration 200: 0.06423760357212392
# Final cost : 0.06423760357212392
# Compute control for a deterministic system
# Cost in iteration 0: 0.06423760357212392
# Converged in iteration 21 with cost 0.06422591020945193 because of step counter
# Final cost : 0.06422591020945193
# Compute control for a deterministic system
# Cost in iteration 0: 0.06422591020945193
# Converged in iteration 1 with cost 0.06422591020945193 because of step counter
# Final cost : 0.06422591020945193
# Compute control for a deterministic system
# Cost in iteration 0: 0.06422591020945193
# Converged in iteration 1 with cost 0.06422591020945193 because of step counter
# Final cost : 0.06422591020945193
# Compute control for a deterministic system
# Cost in iteration 0: 0.06422591020945193
# Converged in iteration 1 with cost 0.06422591020945193 because of step counter
# Final cost : 0.06422591020945193
# Compute control for a deterministic system
# Cost in iteration 0: 0.12535335625765515
# Cost in iteration 200: 0.058531597125833806
# Final cost : 0.058531597125833806
# Compute control for a deterministic system
# Cost in iteration 0: 0.058531597125833806
# Converged in iteration 18 with cost 0.05839185984813089 because of step counter
# Final cost : 0.05839185984813089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05839185984813089
# Converged in iteration 1 with cost 0.05839185984813089 because of step counter
# Final cost : 0.05839185984813089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05839185984813089
# Converged in iteration 1 with cost 0.05839185984813089 because of step counter
# Final cost : 0.05839185984813089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05839185984813089
# Converged in iteration 1 with cost 0.05839185984813089 because of step counter
# Final cost : 0.05839185984813089
# Compute control for a deterministic system
# Cost in iteration 0: 0.11578770080103735
# Cost in iteration 200: 0.0509575426477679
# Final cost : 0.0509575426477679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0509575426477679
# Converged in iteration 18 with cost 0.05093083982103621 because of step counter
# Final cost : 0.05093083982103621
# Compute control for a deterministic system
# Cost in iteration 0: 0.05093083982103621
# Converged in iteration 1 with cost 0.05093083982103621 because of step counter
# Final cost : 0.05093083982103621
# Compute control for a deterministic system
# Cost in iteration 0: 0.05093083982103621
# Converged in iteration 1 with cost 0.05093083982103621 because of step counter
# Final cost : 0.05093083982103621
# Compute control for a deterministic system
# Cost in iteration 0: 0.05093083982103621
# Converged in iteration 1 with cost 0.05093083982103621 because of step counter
# Final cost : 0.05093083982103621
# Compute control for a deterministic system
# Cost in iteration 0: 0.08602025451347271
# Cost in iteration 200: 0.044643916432538185
# Final cost : 0.044643916432538185
# Compute control for a deterministic system
# Cost in iteration 0: 0.044643916432538185
# Converged in iteration 12 with cost 0.04463643827851255 because of step counter
# Final cost : 0.04463643827851255
# Compute control for a deterministic system
# Cost in iteration 0: 0.04463643827851255
# Converged in iteration 1 with cost 0.04463643827851255 because of step counter
# Final cost : 0.04463643827851255
# Compute control for a deterministic system
# Cost in iteration 0: 0.04463643827851255
# Converged in iteration 1 with cost 0.04463643827851255 because of step counter
# Final cost : 0.04463643827851255
# Compute control for a deterministic system
# Cost in iteration 0: 0.04463643827851255
# Converged in iteration 1 with cost 0.04463643827851255 because of step counter
# Final cost : 0.04463643827851255
# Compute control for a deterministic system
# Cost in iteration 0: 0.09837642685416322
# Cost in iteration 200: 0.03647201575930181
# Final cost : 0.03647201575930181
# Compute control for a deterministic system
# Cost in iteration 0: 0.03647201575930181
# Converged in iteration 9 with cost 0.03646848004900658 because of step counter
# Final cost : 0.03646848004900658
# Compute control for a deterministic system
# Cost in iteration 0: 0.03646848004900658
# Converged in iteration 1 with cost 0.03646848004900658 because of step counter
# Final cost : 0.03646848004900658
# Compute control for a deterministic system
# Cost in iteration 0: 0.03646848004900658
# Converged in iteration 1 with cost 0.03646848004900658 because of step counter
# Final cost : 0.03646848004900658
# Compute control for a deterministic system
# Cost in iteration 0: 0.03646848004900658
# Converged in iteration 1 with cost 0.03646848004900658 because of step counter
# Final cost : 0.03646848004900658
# Compute control for a deterministic system
# Cost in iteration 0: 0.09074505525522408
# Cost in iteration 200: 0.02946755444821381
# Final cost : 0.02946755444821381
# Compute control for a deterministic system
# Cost in iteration 0: 0.02946755444821381
# Converged in iteration 13 with cost 0.02945856651145075 because of step counter
# Final cost : 0.02945856651145075
# Compute control for a deterministic system
# Cost in iteration 0: 0.02945856651145075
# Converged in iteration 1 with cost 0.02945856651145075 because of step counter
# Final cost : 0.02945856651145075
# Compute control for a deterministic system
# Cost in iteration 0: 0.02945856651145075
# Converged in iteration 1 with cost 0.02945856651145075 because of step counter
# Final cost : 0.02945856651145075
# Compute control for a deterministic system
# Cost in iteration 0: 0.02945856651145075
# Converged in iteration 1 with cost 0.02945856651145075 because of step counter
# Final cost : 0.02945856651145075
# Compute control for a deterministic system
# Cost in iteration 0: 0.08379421935052113
# Cost in iteration 200: 0.02303209807117713
# Final cost : 0.02303209807117713
# Compute control for a deterministic system
# Cost in iteration 0: 0.02303209807117713
# Converged in iteration 15 with cost 0.023026952038971246 because of step counter
# Final cost : 0.023026952038971246
# Compute control for a deterministic system
# Cost in iteration 0: 0.023026952038971246
# Converged in iteration 1 with cost 0.023026952038971246 because of step counter
# Final cost : 0.023026952038971246
# Compute control for a deterministic system
# Cost in iteration 0: 0.023026952038971246
# Converged in iteration 1 with cost 0.023026952038971246 because of step counter
# Final cost : 0.023026952038971246
# Compute control for a deterministic system
# Cost in iteration 0: 0.023026952038971246
# Converged in iteration 1 with cost 0.023026952038971246 because of step counter
# Final cost : 0.023026952038971246
# Compute control for a deterministic system
# Cost in iteration 0: 0.057465021331832844
# Cost in iteration 200: 0.01801890387456455
# Final cost : 0.01801890387456455
# Compute control for a deterministic system
# Cost in iteration 0: 0.01801890387456455
# Converged in iteration 14 with cost 0.018018511154005632 because of step counter
# Final cost : 0.018018511154005632
# Compute control for a deterministic system
# Cost in iteration 0: 0.018018511154005632
# Converged in iteration 1 with cost 0.018018511154005632 because of step counter
# Final cost : 0.018018511154005632
# Compute control for a deterministic system
# Cost in iteration 0: 0.018018511154005632
# Converged in iteration 1 with cost 0.018018511154005632 because of step counter
# Final cost : 0.018018511154005632
# Compute control for a deterministic system
# Cost in iteration 0: 0.018018511154005632
# Converged in iteration 1 with cost 0.018018511154005632 because of step counter
# Final cost : 0.018018511154005632
# Compute control for a deterministic system
# Cost in iteration 0: 0.0720295057565346
# Cost in iteration 200: 0.011861966780310425
# Final cost : 0.011861966780310425
# Compute control for a deterministic system
# Cost in iteration 0: 0.011861966780310425
# Converged in iteration 20 with cost 0.011849077026502682 because of step counter
# Final cost : 0.011849077026502682
# Compute control for a deterministic system
# Cost in iteration 0: 0.011849077026502682
# Converged in iteration 1 with cost 0.011849077026502682 because of step counter
# Final cost : 0.011849077026502682
# Compute control for a deterministic system
# Cost in iteration 0: 0.011849077026502682
# Converged in iteration 1 with cost 0.011849077026502682 because of step counter
# Final cost : 0.011849077026502682
# Compute control for a deterministic system
# Cost in iteration 0: 0.011849077026502682
# Converged in iteration 1 with cost 0.011849077026502682 because of step counter
# Final cost : 0.011849077026502682
# Compute control for a deterministic system
# Cost in iteration 0: 0.06399480161116626
# Cost in iteration 200: 0.005662054590888601
# Final cost : 0.005662054590888601
# Compute control for a deterministic system
# Cost in iteration 0: 0.005662054590888601
# Converged in iteration 22 with cost 0.005639606165582958 because of step counter
# Final cost : 0.005639606165582958
# Compute control for a deterministic system
# Cost in iteration 0: 0.005639606165582958
# Converged in iteration 1 with cost 0.005639606165582958 because of step counter
# Final cost : 0.005639606165582958
# Compute control for a deterministic system
# Cost in iteration 0: 0.005639606165582958
# Converged in iteration 1 with cost 0.005639606165582958 because of step counter
# Final cost : 0.005639606165582958
# Compute control for a deterministic system
# Cost in iteration 0: 0.005639606165582958
# Converged in iteration 1 with cost 0.005639606165582958 because of step counter
# Final cost : 0.005639606165582958
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.06535489172950011
# Converged in iteration 12 with cost 0.011706131051504625 because of step counter
# Final cost : 0.011706131051504625
# Compute control for a deterministic system
# Cost in iteration 0: 0.011706131051504625
# Converged in iteration 1 with cost 0.011706131051504625 because of step counter
# Final cost : 0.011706131051504625
# Compute control for a deterministic system
# Cost in iteration 0: 0.011706131051504625
# Converged in iteration 1 with cost 0.011706131051504625 because of step counter
# Final cost : 0.011706131051504625
# Compute control for a deterministic system
# Cost in iteration 0: 0.011706131051504625
# Converged in iteration 1 with cost 0.011706131051504625 because of step counter
# Final cost : 0.011706131051504625
# Compute control for a deterministic system
# Cost in iteration 0: 0.07159905683461709
# Converged in iteration 13 with cost 0.01793043362449879 because of step counter
# Final cost : 0.01793043362449879
# Compute control for a deterministic system
# Cost in iteration 0: 0.01793043362449879
# Converged in iteration 1 with cost 0.01793043362449879 because of step counter
# Final cost : 0.01793043362449879
# Compute control for a deterministic system
# Cost in iteration 0: 0.01793043362449879
# Converged in iteration 1 with cost 0.01793043362449879 because of step counter
# Final cost : 0.01793043362449879
# Compute control for a deterministic system
# Cost in iteration 0: 0.01793043362449879
# Converged in iteration 1 with cost 0.01793043362449879 because of step counter
# Final cost : 0.01793043362449879
# Compute control for a deterministic system
# Cost in iteration 0: 0.05460692019781198
# Converged in iteration 9 with cost 0.02287666002542338 because of step counter
# Final cost : 0.02287666002542338
# Compute control for a deterministic system
# Cost in iteration 0: 0.02287666002542338
# Converged in iteration 1 with cost 0.02287666002542338 because of step counter
# Final cost : 0.02287666002542338
# Compute control for a deterministic system
# Cost in iteration 0: 0.02287666002542338
# Converged in iteration 1 with cost 0.02287666002542338 because of step counter
# Final cost : 0.02287666002542338
# Compute control for a deterministic system
# Cost in iteration 0: 0.02287666002542338
# Converged in iteration 1 with cost 0.02287666002542338 because of step counter
# Final cost : 0.02287666002542338
# Compute control for a deterministic system
# Cost in iteration 0: 0.07915129751316974
# Converged in iteration 8 with cost 0.029479689631608 because of step counter
# Final cost : 0.029479689631608
# Compute control for a deterministic system
# Cost in iteration 0: 0.029479689631608
# Converged in iteration 1 with cost 0.029479689631608 because of step counter
# Final cost : 0.029479689631608
# Compute control for a deterministic system
# Cost in iteration 0: 0.029479689631608
# Converged in iteration 1 with cost 0.029479689631608 because of step counter
# Final cost : 0.029479689631608
# Compute control for a deterministic system
# Cost in iteration 0: 0.029479689631608
# Converged in iteration 1 with cost 0.029479689631608 because of step counter
# Final cost : 0.029479689631608
# Compute control for a deterministic system
# Cost in iteration 0: 0.08532951361560107
# Converged in iteration 27 with cost 0.03651931368867729 because of step counter
# Final cost : 0.03651931368867729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03651931368867729
# Converged in iteration 1 with cost 0.03651931368867729 because of step counter
# Final cost : 0.03651931368867729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03651931368867729
# Converged in iteration 1 with cost 0.03651931368867729 because of step counter
# Final cost : 0.03651931368867729
# Compute control for a deterministic system
# Cost in iteration 0: 0.03651931368867729
# Converged in iteration 1 with cost 0.03651931368867729 because of step counter
# Final cost : 0.03651931368867729
# Compute control for a deterministic system
# Cost in iteration 0: 0.0925357907127583
# Converged in iteration 26 with cost 0.0445106633950725 because of step counter
# Final cost : 0.0445106633950725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0445106633950725
# Converged in iteration 1 with cost 0.0445106633950725 because of step counter
# Final cost : 0.0445106633950725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0445106633950725
# Converged in iteration 1 with cost 0.0445106633950725 because of step counter
# Final cost : 0.0445106633950725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0445106633950725
# Converged in iteration 1 with cost 0.0445106633950725 because of step counter
# Final cost : 0.0445106633950725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0800079804931887
# Converged in iteration 26 with cost 0.050964619404167806 because of step counter
# Final cost : 0.050964619404167806
# Compute control for a deterministic system
# Cost in iteration 0: 0.050964619404167806
# Converged in iteration 1 with cost 0.050964619404167806 because of step counter
# Final cost : 0.050964619404167806
# Compute control for a deterministic system
# Cost in iteration 0: 0.050964619404167806
# Converged in iteration 1 with cost 0.050964619404167806 because of step counter
# Final cost : 0.050964619404167806
# Compute control for a deterministic system
# Cost in iteration 0: 0.050964619404167806
# Converged in iteration 1 with cost 0.050964619404167806 because of step counter
# Final cost : 0.050964619404167806
# Compute control for a deterministic system
# Cost in iteration 0: 0.10755907442884202
# Converged in iteration 25 with cost 0.058988376954257085 because of step counter
# Final cost : 0.058988376954257085
# Compute control for a deterministic system
# Cost in iteration 0: 0.058988376954257085
# Converged in iteration 1 with cost 0.058988376954257085 because of step counter
# Final cost : 0.058988376954257085
# Compute control for a deterministic system
# Cost in iteration 0: 0.058988376954257085
# Converged in iteration 1 with cost 0.058988376954257085 because of step counter
# Final cost : 0.058988376954257085
# Compute control for a deterministic system
# Cost in iteration 0: 0.058988376954257085
# Converged in iteration 1 with cost 0.058988376954257085 because of step counter
# Final cost : 0.058988376954257085
# Compute control for a deterministic system
# Cost in iteration 0: 0.11489910601103817
# Converged in iteration 32 with cost 0.06550414584356554 because of step counter
# Final cost : 0.06550414584356554
# Compute control for a deterministic system
# Cost in iteration 0: 0.06550414584356554
# Converged in iteration 1 with cost 0.06550414584356554 because of step counter
# Final cost : 0.06550414584356554
# Compute control for a deterministic system
# Cost in iteration 0: 0.06550414584356554
# Converged in iteration 1 with cost 0.06550414584356554 because of step counter
# Final cost : 0.06550414584356554
# Compute control for a deterministic system
# Cost in iteration 0: 0.06550414584356554
# Converged in iteration 1 with cost 0.06550414584356554 because of step counter
# Final cost : 0.06550414584356554
# Compute control for a deterministic system
# Cost in iteration 0: 0.11724998203930491
# Converged in iteration 27 with cost 0.06995748209543244 because of step counter
# Final cost : 0.06995748209543244
# Compute control for a deterministic system
# Cost in iteration 0: 0.06995748209543244
# Converged in iteration 1 with cost 0.06995748209543244 because of step counter
# Final cost : 0.06995748209543244
# Compute control for a deterministic system
# Cost in iteration 0: 0.06995748209543244
# Converged in iteration 1 with cost 0.06995748209543244 because of step counter
# Final cost : 0.06995748209543244
# Compute control for a deterministic system
# Cost in iteration 0: 0.06995748209543244
# Converged in iteration 1 with cost 0.06995748209543244 because of step counter
# Final cost : 0.06995748209543244
# Compute control for a deterministic system
# Cost in iteration 0: 0.127203115876883
# Converged in iteration 23 with cost 0.07662074362390073 because of step counter
# Final cost : 0.07662074362390073
# Compute control for a deterministic system
# Cost in iteration 0: 0.07662074362390073
# Converged in iteration 1 with cost 0.07662074362390073 because of step counter
# Final cost : 0.07662074362390073
# Compute control for a deterministic system
# Cost in iteration 0: 0.07662074362390073
# Converged in iteration 1 with cost 0.07662074362390073 because of step counter
# Final cost : 0.07662074362390073
# Compute control for a deterministic system
# Cost in iteration 0: 0.07662074362390073
# Converged in iteration 1 with cost 0.07662074362390073 because of step counter
# Final cost : 0.07662074362390073
# Compute control for a deterministic system
# Cost in iteration 0: 0.10645957215510952
# Converged in iteration 23 with cost 0.08022182054585811 because of step counter
# Final cost : 0.08022182054585811
# Compute control for a deterministic system
# Cost in iteration 0: 0.08022182054585811
# Converged in iteration 1 with cost 0.08022182054585811 because of step counter
# Final cost : 0.08022182054585811
# Compute control for a deterministic system
# Cost in iteration 0: 0.08022182054585811
# Converged in iteration 1 with cost 0.08022182054585811 because of step counter
# Final cost : 0.08022182054585811
# Compute control for a deterministic system
# Cost in iteration 0: 0.08022182054585811
# Converged in iteration 1 with cost 0.08022182054585811 because of step counter
# Final cost : 0.08022182054585811
# -----------------------------------------------
# 1 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.13525649148520819
# Converged in iteration 8 with cost 0.08670464326287798 because of step counter
# Final cost : 0.08670464326287798
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670464326287798
# Converged in iteration 1 with cost 0.08670464326287798 because of step counter
# Final cost : 0.08670464326287798
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670464326287798
# Converged in iteration 1 with cost 0.08670464326287798 because of step counter
# Final cost : 0.08670464326287798
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670464326287798
# Converged in iteration 1 with cost 0.08670464326287798 because of step counter
# Final cost : 0.08670464326287798
# Compute control for a deterministic system
# Cost in iteration 0: 0.13342446912710915
# Converged in iteration 27 with cost 0.091232489744222 because of step counter
# Final cost : 0.091232489744222
# Compute control for a deterministic system
# Cost in iteration 0: 0.091232489744222
# Converged in iteration 1 with cost 0.091232489744222 because of step counter
# Final cost : 0.091232489744222
# Compute control for a deterministic system
# Cost in iteration 0: 0.091232489744222
# Converged in iteration 1 with cost 0.091232489744222 because of step counter
# Final cost : 0.091232489744222
# Compute control for a deterministic system
# Cost in iteration 0: 0.091232489744222
# Converged in iteration 1 with cost 0.091232489744222 because of step counter
# Final cost : 0.091232489744222
# Compute control for a deterministic system
# Cost in iteration 0: 0.14361607458795161
# Converged in iteration 8 with cost 0.09755618902429924 because of step counter
# Final cost : 0.09755618902429924
# ...
# Cost in iteration 0: 1.5387528750718964
# Converged in iteration 1 with cost 1.5387528750718964 because of step counter
# Final cost : 1.5387528750718964
# Compute control for a deterministic system
# Cost in iteration 0: 1.5387528750718964
# Converged in iteration 1 with cost 1.5387528750718964 because of step counter
# Final cost : 1.5387528750718964
# Compute control for a deterministic system
# Cost in iteration 0: 1.5387528750718964
# Converged in iteration 1 with cost 1.5387528750718964 because of step counter
# Final cost : 1.5387528750718964
# Compute control for a deterministic system
# Cost in iteration 0: 1.468566128866665
# Converged in iteration 1 with cost 1.468566128866665 because of step counter
# Final cost : 1.468566128866665
# Compute control for a deterministic system
# Cost in iteration 0: 1.468566128866665
# Converged in iteration 1 with cost 1.468566128866665 because of step counter
# Final cost : 1.468566128866665
# Compute control for a deterministic system
# Cost in iteration 0: 1.468566128866665
# Converged in iteration 1 with cost 1.468566128866665 because of step counter
# Final cost : 1.468566128866665
# Compute control for a deterministic system
# Cost in iteration 0: 1.468566128866665
# Converged in iteration 1 with cost 1.468566128866665 because of step counter
# Final cost : 1.468566128866665
# Compute control for a deterministic system
# Cost in iteration 0: 1.468566128866665
# Converged in iteration 1 with cost 1.468566128866665 because of step counter
# Final cost : 1.468566128866665
# Compute control for a deterministic system
# Cost in iteration 0: 1.37949149948566
# Converged in iteration 1 with cost 1.37949149948566 because of step counter
# Final cost : 1.37949149948566
# Compute control for a deterministic system
# Cost in iteration 0: 1.37949149948566
# Converged in iteration 1 with cost 1.37949149948566 because of step counter
# Final cost : 1.37949149948566
# Compute control for a deterministic system
# Cost in iteration 0: 1.37949149948566
# Converged in iteration 1 with cost 1.37949149948566 because of step counter
# Final cost : 1.37949149948566
# Compute control for a deterministic system
# Cost in iteration 0: 1.37949149948566
# Converged in iteration 1 with cost 1.37949149948566 because of step counter
# Final cost : 1.37949149948566
# Compute control for a deterministic system
# Cost in iteration 0: 1.37949149948566
# Converged in iteration 1 with cost 1.37949149948566 because of step counter
# Final cost : 1.37949149948566
# Compute control for a deterministic system
# Cost in iteration 0: 1.2889380258525984
# Converged in iteration 1 with cost 1.2889380258525984 because of step counter
# Final cost : 1.2889380258525984
# Compute control for a deterministic system
# Cost in iteration 0: 1.2889380258525984
# Converged in iteration 1 with cost 1.2889380258525984 because of step counter
# Final cost : 1.2889380258525984
# Compute control for a deterministic system
# Cost in iteration 0: 1.2889380258525984
# Converged in iteration 1 with cost 1.2889380258525984 because of step counter
# Final cost : 1.2889380258525984
# Compute control for a deterministic system
# Cost in iteration 0: 1.2889380258525984
# Converged in iteration 1 with cost 1.2889380258525984 because of step counter
# Final cost : 1.2889380258525984
# Compute control for a deterministic system
# Cost in iteration 0: 1.2889380258525984
# Converged in iteration 1 with cost 1.2889380258525984 because of step counter
# Final cost : 1.2889380258525984
# Compute control for a deterministic system
# Cost in iteration 0: 1.1966891767653671
# Converged in iteration 1 with cost 1.1966891767653671 because of step counter
# Final cost : 1.1966891767653671
# Compute control for a deterministic system
# Cost in iteration 0: 1.1966891767653671
# Converged in iteration 1 with cost 1.1966891767653671 because of step counter
# Final cost : 1.1966891767653671
# Compute control for a deterministic system
# Cost in iteration 0: 1.1966891767653671
# Converged in iteration 1 with cost 1.1966891767653671 because of step counter
# Final cost : 1.1966891767653671
# Compute control for a deterministic system
# Cost in iteration 0: 1.1966891767653671
# Converged in iteration 1 with cost 1.1966891767653671 because of step counter
# Final cost : 1.1966891767653671
# Compute control for a deterministic system
# Cost in iteration 0: 1.1966891767653671
# Converged in iteration 1 with cost 1.1966891767653671 because of step counter
# Final cost : 1.1966891767653671
# Compute control for a deterministic system
# Cost in iteration 0: 1.11063645255759
# Converged in iteration 1 with cost 1.11063645255759 because of step counter
# Final cost : 1.11063645255759
# Compute control for a deterministic system
# Cost in iteration 0: 1.11063645255759
# Converged in iteration 1 with cost 1.11063645255759 because of step counter
# Final cost : 1.11063645255759
# Compute control for a deterministic system
# Cost in iteration 0: 1.11063645255759
# Converged in iteration 1 with cost 1.11063645255759 because of step counter
# Final cost : 1.11063645255759
# Compute control for a deterministic system
# Cost in iteration 0: 1.11063645255759
# Converged in iteration 1 with cost 1.11063645255759 because of step counter
# Final cost : 1.11063645255759
# Compute control for a deterministic system
# Cost in iteration 0: 1.11063645255759
# Converged in iteration 1 with cost 1.11063645255759 because of step counter
# Final cost : 1.11063645255759
# Compute control for a deterministic system
# Cost in iteration 0: 0.9994113453398714
# Converged in iteration 1 with cost 0.9994113453398714 because of step counter
# Final cost : 0.9994113453398714
# Compute control for a deterministic system
# Cost in iteration 0: 0.9994113453398714
# Converged in iteration 1 with cost 0.9994113453398714 because of step counter
# Final cost : 0.9994113453398714
# Compute control for a deterministic system
# Cost in iteration 0: 0.9994113453398714
# Converged in iteration 1 with cost 0.9994113453398714 because of step counter
# Final cost : 0.9994113453398714
# Compute control for a deterministic system
# Cost in iteration 0: 0.9994113453398714
# Converged in iteration 1 with cost 0.9994113453398714 because of step counter
# Final cost : 0.9994113453398714
# Compute control for a deterministic system
# Cost in iteration 0: 0.9994113453398714
# Converged in iteration 1 with cost 0.9994113453398714 because of step counter
# Final cost : 0.9994113453398714
# Compute control for a deterministic system
# Cost in iteration 0: 0.8925013009699488
# Converged in iteration 1 with cost 0.8925013009699488 because of step counter
# Final cost : 0.8925013009699488
# Compute control for a deterministic system
# Cost in iteration 0: 0.8925013009699488
# Converged in iteration 1 with cost 0.8925013009699488 because of step counter
# Final cost : 0.8925013009699488
# Compute control for a deterministic system
# Cost in iteration 0: 0.8925013009699488
# Converged in iteration 1 with cost 0.8925013009699488 because of step counter
# Final cost : 0.8925013009699488
# Compute control for a deterministic system
# Cost in iteration 0: 0.8925013009699488
# Converged in iteration 1 with cost 0.8925013009699488 because of step counter
# Final cost : 0.8925013009699488
# Compute control for a deterministic system
# Cost in iteration 0: 0.8925013009699488
# Converged in iteration 1 with cost 0.8925013009699488 because of step counter
# Final cost : 0.8925013009699488
# Compute control for a deterministic system
# Cost in iteration 0: 0.7521146441653572
# Converged in iteration 1 with cost 0.7521146441653572 because of step counter
# Final cost : 0.7521146441653572
# Compute control for a deterministic system
# Cost in iteration 0: 0.7521146441653572
# Converged in iteration 1 with cost 0.7521146441653572 because of step counter
# Final cost : 0.7521146441653572
# Compute control for a deterministic system
# Cost in iteration 0: 0.7521146441653572
# Converged in iteration 1 with cost 0.7521146441653572 because of step counter
# Final cost : 0.7521146441653572
# Compute control for a deterministic system
# Cost in iteration 0: 0.7521146441653572
# Converged in iteration 1 with cost 0.7521146441653572 because of step counter
# Final cost : 0.7521146441653572
# Compute control for a deterministic system
# Cost in iteration 0: 0.7521146441653572
# Converged in iteration 1 with cost 0.7521146441653572 because of step counter
# Final cost : 0.7521146441653572
# Compute control for a deterministic system
# Cost in iteration 0: 0.6502286597527099
# Converged in iteration 1 with cost 0.6502286597527099 because of step counter
# Final cost : 0.6502286597527099
# Compute control for a deterministic system
# Cost in iteration 0: 0.6502286597527099
# Converged in iteration 1 with cost 0.6502286597527099 because of step counter
# Final cost : 0.6502286597527099
# Compute control for a deterministic system
# Cost in iteration 0: 0.6502286597527099
# Converged in iteration 1 with cost 0.6502286597527099 because of step counter
# Final cost : 0.6502286597527099
# Compute control for a deterministic system
# Cost in iteration 0: 0.6502286597527099
# Converged in iteration 1 with cost 0.6502286597527099 because of step counter
# Final cost : 0.6502286597527099
# Compute control for a deterministic system
# Cost in iteration 0: 0.6502286597527099
# Converged in iteration 1 with cost 0.6502286597527099 because of step counter
# Final cost : 0.6502286597527099
# Compute control for a deterministic system
# Cost in iteration 0: 0.5775523922268244
# Converged in iteration 1 with cost 0.5775523922268244 because of step counter
# Final cost : 0.5775523922268244
# Compute control for a deterministic system
# Cost in iteration 0: 0.5775523922268244
# Converged in iteration 1 with cost 0.5775523922268244 because of step counter
# Final cost : 0.5775523922268244
# Compute control for a deterministic system
# Cost in iteration 0: 0.5775523922268244
# Converged in iteration 1 with cost 0.5775523922268244 because of step counter
# Final cost : 0.5775523922268244
# Compute control for a deterministic system
# Cost in iteration 0: 0.5775523922268244
# Converged in iteration 1 with cost 0.5775523922268244 because of step counter
# Final cost : 0.5775523922268244
# Compute control for a deterministic system
# Cost in iteration 0: 0.5775523922268244
# Converged in iteration 1 with cost 0.5775523922268244 because of step counter
# Final cost : 0.5775523922268244
# Compute control for a deterministic system
# Cost in iteration 0: 0.4907810601126533
# Converged in iteration 1 with cost 0.4907810601126533 because of step counter
# Final cost : 0.4907810601126533
# Compute control for a deterministic system
# Cost in iteration 0: 0.4907810601126533
# Converged in iteration 1 with cost 0.4907810601126533 because of step counter
# Final cost : 0.4907810601126533
# Compute control for a deterministic system
# Cost in iteration 0: 0.4907810601126533
# Converged in iteration 1 with cost 0.4907810601126533 because of step counter
# Final cost : 0.4907810601126533
# Compute control for a deterministic system
# Cost in iteration 0: 0.4907810601126533
# Converged in iteration 1 with cost 0.4907810601126533 because of step counter
# Final cost : 0.4907810601126533
# Compute control for a deterministic system
# Cost in iteration 0: 0.4907810601126533
# Converged in iteration 1 with cost 0.4907810601126533 because of step counter
# Final cost : 0.4907810601126533
# Compute control for a deterministic system
# Cost in iteration 0: 0.39606521892315977
# Converged in iteration 1 with cost 0.39606521892315977 because of step counter
# Final cost : 0.39606521892315977
# Compute control for a deterministic system
# Cost in iteration 0: 0.39606521892315977
# Converged in iteration 1 with cost 0.39606521892315977 because of step counter
# Final cost : 0.39606521892315977
# Compute control for a deterministic system
# Cost in iteration 0: 0.39606521892315977
# Converged in iteration 1 with cost 0.39606521892315977 because of step counter
# Final cost : 0.39606521892315977
# Compute control for a deterministic system
# Cost in iteration 0: 0.39606521892315977
# Converged in iteration 1 with cost 0.39606521892315977 because of step counter
# Final cost : 0.39606521892315977
# Compute control for a deterministic system
# Cost in iteration 0: 0.39606521892315977
# Converged in iteration 1 with cost 0.39606521892315977 because of step counter
# Final cost : 0.39606521892315977
# Compute control for a deterministic system
# Cost in iteration 0: 0.30317176047759065
# Converged in iteration 1 with cost 0.30317176047759065 because of step counter
# Final cost : 0.30317176047759065
# Compute control for a deterministic system
# Cost in iteration 0: 0.30317176047759065
# Converged in iteration 1 with cost 0.30317176047759065 because of step counter
# Final cost : 0.30317176047759065
# Compute control for a deterministic system
# Cost in iteration 0: 0.30317176047759065
# Converged in iteration 1 with cost 0.30317176047759065 because of step counter
# Final cost : 0.30317176047759065
# Compute control for a deterministic system
# Cost in iteration 0: 0.30317176047759065
# Converged in iteration 1 with cost 0.30317176047759065 because of step counter
# Final cost : 0.30317176047759065
# Compute control for a deterministic system
# Cost in iteration 0: 0.30317176047759065
# Converged in iteration 1 with cost 0.30317176047759065 because of step counter
# Final cost : 0.30317176047759065
# Compute control for a deterministic system
# Cost in iteration 0: 0.22936271261028573
# Converged in iteration 1 with cost 0.22936271261028573 because of step counter
# Final cost : 0.22936271261028573
# Compute control for a deterministic system
# Cost in iteration 0: 0.22936271261028573
# Converged in iteration 1 with cost 0.22936271261028573 because of step counter
# Final cost : 0.22936271261028573
# Compute control for a deterministic system
# Cost in iteration 0: 0.22936271261028573
# Converged in iteration 1 with cost 0.22936271261028573 because of step counter
# Final cost : 0.22936271261028573
# Compute control for a deterministic system
# Cost in iteration 0: 0.22936271261028573
# Converged in iteration 1 with cost 0.22936271261028573 because of step counter
# Final cost : 0.22936271261028573
# Compute control for a deterministic system
# Cost in iteration 0: 0.22936271261028573
# Converged in iteration 1 with cost 0.22936271261028573 because of step counter
# Final cost : 0.22936271261028573
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792869706110888
# Converged in iteration 1 with cost 0.13792869706110888 because of step counter
# Final cost : 0.13792869706110888
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792869706110888
# Converged in iteration 1 with cost 0.13792869706110888 because of step counter
# Final cost : 0.13792869706110888
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792869706110888
# Converged in iteration 1 with cost 0.13792869706110888 because of step counter
# Final cost : 0.13792869706110888
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792869706110888
# Converged in iteration 1 with cost 0.13792869706110888 because of step counter
# Final cost : 0.13792869706110888
# Compute control for a deterministic system
# Cost in iteration 0: 0.13792869706110888
# Converged in iteration 1 with cost 0.13792869706110888 because of step counter
# Final cost : 0.13792869706110888
# Compute control for a deterministic system
# Cost in iteration 0: 0.04860029873427914
# Converged in iteration 1 with cost 0.04860029873427914 because of step counter
# Final cost : 0.04860029873427914
# Compute control for a deterministic system
# Cost in iteration 0: 0.04860029873427914
# Converged in iteration 1 with cost 0.04860029873427914 because of step counter
# Final cost : 0.04860029873427914
# Compute control for a deterministic system
# Cost in iteration 0: 0.04860029873427914
# Converged in iteration 1 with cost 0.04860029873427914 because of step counter
# Final cost : 0.04860029873427914
# Compute control for a deterministic system
# Cost in iteration 0: 0.04860029873427914
# Converged in iteration 1 with cost 0.04860029873427914 because of step counter
# Final cost : 0.04860029873427914
# Compute control for a deterministic system
# Cost in iteration 0: 0.04860029873427914
# Converged in iteration 1 with cost 0.04860029873427914 because of step counter
# Final cost : 0.04860029873427914

# %%
save(results_peak)
