# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,127], wc.inh[0,127]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  19  210  400  591  782  972 1163 1354 1545 1735 1926 2117 2307 2498
#  2689 2879]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(800)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [True, True, False, False, True, False, False, False]
#options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                print("cost = ", results_min["total_cost"][i_w][i_shift])

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * factor
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.99 + 0.02*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * factor
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# cost =  0.0017842620105849019
# Compute control for a deterministic system
# Cost in iteration 0: 0.06559999675966646
# Final cost : 0.0018359230903328178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018359230903328178
# Final cost : 0.0017842620464498535
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017842620464498535
# Converged in iteration 228 with cost 0.001784262010591113 because of vanishing difference
# Final cost : 0.001784262010591113
# Compute control for a deterministic system
# Cost in iteration 0: 0.001784262010591113
# Converged in iteration 1 with cost 0.001784262010591113 because of step counter
# Final cost : 0.001784262010591113
# Compute control for a deterministic system
# Cost in iteration 0: 0.001784262010591113
# Converged in iteration 2 with cost 0.00178426201059111 because of step counter
# Final cost : 0.00178426201059111
# cost =  0.0035543159202759953
# Compute control for a deterministic system
# Cost in iteration 0: 0.04368165034830503
# Final cost : 0.0035976502842802196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035976502842802196
# Final cost : 0.0035543160453520104
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035543160453520104
# Converged in iteration 283 with cost 0.0035543159202852735 because of step counter
# Final cost : 0.0035543159202852735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035543159202852735
# Converged in iteration 3 with cost 0.0035543159202850966 because of step counter
# Final cost : 0.0035543159202850966
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035543159202850966
# Converged in iteration 1 with cost 0.0035543159202850966 because of step counter
# Final cost : 0.0035543159202850966
# cost =  0.006639058601213252
# Compute control for a deterministic system
# Cost in iteration 0: 0.07026263747491002
# Final cost : 0.006727067247810093
# Compute control for a deterministic system
# Cost in iteration 0: 0.006727067247810093
# Final cost : 0.006639059032162323
# Compute control for a deterministic system
# Cost in iteration 0: 0.006639059032162323
# Converged in iteration 268 with cost 0.006639058601234552 because of step counter
# Final cost : 0.006639058601234552
# Compute control for a deterministic system
# Cost in iteration 0: 0.006639058601234552
# Converged in iteration 14 with cost 0.0066390586012133055 because of step counter
# Final cost : 0.0066390586012133055
# Compute control for a deterministic system
# Cost in iteration 0: 0.0066390586012133055
# Converged in iteration 1 with cost 0.0066390586012133055 because of step counter
# Final cost : 0.0066390586012133055
# cost =  0.010577372310529642
# Compute control for a deterministic system
# Cost in iteration 0: 0.06779025393115697
# Final cost : 0.01066786375769545
# Compute control for a deterministic system
# Cost in iteration 0: 0.01066786375769545
# Final cost : 0.010577373151002626
# Compute control for a deterministic system
# Cost in iteration 0: 0.010577373151002626
# Converged in iteration 309 with cost 0.010577372310545338 because of step counter
# Final cost : 0.010577372310545338
# Compute control for a deterministic system
# Cost in iteration 0: 0.010577372310545338
# Converged in iteration 1 with cost 0.010577372310545338 because of step counter
# Final cost : 0.010577372310545338
# Compute control for a deterministic system
# Cost in iteration 0: 0.010577372310545338
# Converged in iteration 1 with cost 0.010577372310545338 because of step counter
# Final cost : 0.010577372310545338
# cost =  0.01515420440285245
# Compute control for a deterministic system
# Cost in iteration 0: 0.07846048623672222
# Final cost : 0.015244245840352671
# Compute control for a deterministic system
# Cost in iteration 0: 0.015244245840352671
# Final cost : 0.015154205720008926
# Compute control for a deterministic system
# Cost in iteration 0: 0.015154205720008926
# Converged in iteration 415 with cost 0.015154204402859774 because of step counter
# Final cost : 0.015154204402859774
# Compute control for a deterministic system
# Cost in iteration 0: 0.015154204402859774
# Converged in iteration 1 with cost 0.015154204402859774 because of step counter
# Final cost : 0.015154204402859774
# Compute control for a deterministic system
# Cost in iteration 0: 0.015154204402859774
# Converged in iteration 1 with cost 0.015154204402859774 because of step counter
# Final cost : 0.015154204402859774
# cost =  0.01915350409550469
# Compute control for a deterministic system
# Cost in iteration 0: 0.06151916590876091
# Final cost : 0.0192130333422725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0192130333422725
# Final cost : 0.019153505167842207
# Compute control for a deterministic system
# Cost in iteration 0: 0.019153505167842207
# Converged in iteration 448 with cost 0.019153504095527497 because of step counter
# Final cost : 0.019153504095527497
# Compute control for a deterministic system
# Cost in iteration 0: 0.019153504095527497
# Converged in iteration 3 with cost 0.019153504095527372 because of step counter
# Final cost : 0.019153504095527372
# Compute control for a deterministic system
# Cost in iteration 0: 0.019153504095527372
# Converged in iteration 1 with cost 0.019153504095527372 because of step counter
# Final cost : 0.019153504095527372
# cost =  0.024518172923229282
# Compute control for a deterministic system
# Cost in iteration 0: 0.07756029749325791
# Final cost : 0.024630876119869957
# Compute control for a deterministic system
# Cost in iteration 0: 0.024630876119869957
# Final cost : 0.024518176884214073
# Compute control for a deterministic system
# Cost in iteration 0: 0.024518176884214073
# Converged in iteration 285 with cost 0.024518172923252753 because of step counter
# Final cost : 0.024518172923252753
# Compute control for a deterministic system
# Cost in iteration 0: 0.024518172923252753
# Converged in iteration 1 with cost 0.024518172923252753 because of step counter
# Final cost : 0.024518172923252753
# Compute control for a deterministic system
# Cost in iteration 0: 0.024518172923252753
# Converged in iteration 1 with cost 0.024518172923252753 because of step counter
# Final cost : 0.024518172923252753
# cost =  0.030338025893694616
# Compute control for a deterministic system
# Cost in iteration 0: 0.08537702048372181
# Final cost : 0.030487388444914137
# Compute control for a deterministic system
# Cost in iteration 0: 0.030487388444914137
# Final cost : 0.03033803536679838
# Compute control for a deterministic system
# Cost in iteration 0: 0.03033803536679838
# Converged in iteration 331 with cost 0.03033802589372086 because of step counter
# Final cost : 0.03033802589372086
# Compute control for a deterministic system
# Cost in iteration 0: 0.03033802589372086
# Converged in iteration 6 with cost 0.03033802589371967 because of step counter
# Final cost : 0.03033802589371967
# Compute control for a deterministic system
# Cost in iteration 0: 0.03033802589371967
# Converged in iteration 1 with cost 0.03033802589371967 because of step counter
# Final cost : 0.03033802589371967
# cost =  0.03674863787112312
# Compute control for a deterministic system
# Cost in iteration 0: 0.08564624357505811
# Final cost : 0.03694545533625225
# Compute control for a deterministic system
# Cost in iteration 0: 0.03694545533625225
# Final cost : 0.03674867323009026
# Compute control for a deterministic system
# Cost in iteration 0: 0.03674867323009026
# Converged in iteration 397 with cost 0.03674863787115177 because of step counter
# Final cost : 0.03674863787115177
# Compute control for a deterministic system
# Cost in iteration 0: 0.03674863787115177
# Converged in iteration 1 with cost 0.03674863787115177 because of step counter
# Final cost : 0.03674863787115177
# Compute control for a deterministic system
# Cost in iteration 0: 0.03674863787115177
# Converged in iteration 2 with cost 0.03674863787115144 because of step counter
# Final cost : 0.03674863787115144
# cost =  0.04241635528553523
# Compute control for a deterministic system
# Cost in iteration 0: 0.08254025930640549
# Final cost : 0.04257368612705088
# Compute control for a deterministic system
# Cost in iteration 0: 0.04257368612705088
# Final cost : 0.04241646560013229
# Compute control for a deterministic system
# Cost in iteration 0: 0.04241646560013229
# Converged in iteration 378 with cost 0.04241635528556467 because of step counter
# Final cost : 0.04241635528556467
# Compute control for a deterministic system
# Cost in iteration 0: 0.04241635528556467
# Converged in iteration 11 with cost 0.04241635528556012 because of step counter
# Final cost : 0.04241635528556012
# Compute control for a deterministic system
# Cost in iteration 0: 0.04241635528556012
# Converged in iteration 2 with cost 0.0424163552855598 because of vanishing difference
# Final cost : 0.0424163552855598
# cost =  0.050310753518714765
# Compute control for a deterministic system
# Cost in iteration 0: 0.10781474024020021
# Final cost : 0.05061616225780546
# Compute control for a deterministic system
# Cost in iteration 0: 0.05061616225780546
# Final cost : 0.05031087263544036
# Compute control for a deterministic system
# Cost in iteration 0: 0.05031087263544036
# Converged in iteration 401 with cost 0.050310753518745914 because of step counter
# Final cost : 0.050310753518745914
# Compute control for a deterministic system
# Cost in iteration 0: 0.050310753518745914
# Converged in iteration 1 with cost 0.050310753518745914 because of step counter
# Final cost : 0.050310753518745914
# Compute control for a deterministic system
# Cost in iteration 0: 0.050310753518745914
# Converged in iteration 8 with cost 0.05031075351872544 because of step counter
# Final cost : 0.05031075351872544
# cost =  0.059226335856204695
# Compute control for a deterministic system
# Cost in iteration 0: 0.1085004537136155
# Final cost : 0.05960789164417305
# Compute control for a deterministic system
# Cost in iteration 0: 0.05960789164417305
# Final cost : 0.0592264397539865
# Compute control for a deterministic system
# Cost in iteration 0: 0.0592264397539865
# Converged in iteration 439 with cost 0.05922633585624862 because of step counter
# Final cost : 0.05922633585624862
# Compute control for a deterministic system
# Cost in iteration 0: 0.05922633585624862
# Converged in iteration 1 with cost 0.05922633585624862 because of step counter
# Final cost : 0.05922633585624862
# Compute control for a deterministic system
# Cost in iteration 0: 0.05922633585624862
# Converged in iteration 2 with cost 0.05922633585624817 because of step counter
# Final cost : 0.05922633585624817
# cost =  0.06925497525311285
# Compute control for a deterministic system
# Cost in iteration 0: 0.1326974564638276
# Final cost : 0.0697367912814281
# Compute control for a deterministic system
# Cost in iteration 0: 0.0697367912814281
# Final cost : 0.06925506628213673
# Compute control for a deterministic system
# Cost in iteration 0: 0.06925506628213673
# Converged in iteration 494 with cost 0.06925497525317037 because of step counter
# Final cost : 0.06925497525317037
# Compute control for a deterministic system
# Cost in iteration 0: 0.06925497525317037
# Converged in iteration 1 with cost 0.06925497525317037 because of step counter
# Final cost : 0.06925497525317037
# Compute control for a deterministic system
# Cost in iteration 0: 0.06925497525317037
# Converged in iteration 1 with cost 0.06925497525317037 because of step counter
# Final cost : 0.06925497525317037
# cost =  0.08045279236394574
# Compute control for a deterministic system
# Cost in iteration 0: 0.13661732915416785
# Final cost : 0.08103769121355768
# Compute control for a deterministic system
# Cost in iteration 0: 0.08103769121355768
# Final cost : 0.08045288638237685
# Compute control for a deterministic system
# Cost in iteration 0: 0.08045288638237685
# Converged in iteration 507 with cost 0.0804527923640115 because of step counter
# Final cost : 0.0804527923640115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0804527923640115
# Converged in iteration 1 with cost 0.0804527923640115 because of step counter
# Final cost : 0.0804527923640115
# Compute control for a deterministic system
# Cost in iteration 0: 0.0804527923640115
# Converged in iteration 1 with cost 0.0804527923640115 because of step counter
# Final cost : 0.0804527923640115
# cost =  0.09027395623260055
# Compute control for a deterministic system
# Cost in iteration 0: 0.12323566630974041
# Final cost : 0.0907110151463273
# Compute control for a deterministic system
# Cost in iteration 0: 0.0907110151463273
# Final cost : 0.09027406964185071
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027406964185071
# Converged in iteration 516 with cost 0.09027395623265971 because of step counter
# Final cost : 0.09027395623265971
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027395623265971
# Converged in iteration 11 with cost 0.09027395623265093 because of step counter
# Final cost : 0.09027395623265093
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027395623265093
# Converged in iteration 1 with cost 0.09027395623265093 because of step counter
# Final cost : 0.09027395623265093
# cost =  0.1036427345639259
# Compute control for a deterministic system
# Cost in iteration 0: 0.17365850028362106
# Final cost : 0.10445943579887151
# Compute control for a deterministic system
# Cost in iteration 0: 0.10445943579887151
# Final cost : 0.10364307803112953
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364307803112953
# Converged in iteration 670 with cost 0.10364273456400531 because of step counter
# Final cost : 0.10364273456400531
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364273456400531
# Converged in iteration 1 with cost 0.10364273456400531 because of step counter
# Final cost : 0.10364273456400531
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364273456400531
# Converged in iteration 16 with cost 0.10364273456392825 because of step counter
# Final cost : 0.10364273456392825
# cost =  0.11823308603738239
# Compute control for a deterministic system
# Cost in iteration 0: 0.16124328494106516
# Final cost : 0.11915417094983266
# Compute control for a deterministic system
# Cost in iteration 0: 0.11915417094983266
# Final cost : 0.11823371762939767
# Compute control for a deterministic system
# Cost in iteration 0: 0.11823371762939767
# Converged in iteration 635 with cost 0.11823308603743886 because of step counter
# Final cost : 0.11823308603743886
# Compute control for a deterministic system
# Cost in iteration 0: 0.11823308603743886
# Converged in iteration 3 with cost 0.11823308603743722 because of step counter
# Final cost : 0.11823308603743722
# Compute control for a deterministic system
# Cost in iteration 0: 0.11823308603743722
# Converged in iteration 1 with cost 0.11823308603743722 because of step counter
# Final cost : 0.11823308603743722
# cost =  0.10957830736523574
# Compute control for a deterministic system
# Cost in iteration 0: 0.20045642922671952
# Final cost : 0.1351323549306095
# Compute control for a deterministic system
# Cost in iteration 0: 0.1351323549306095
# Final cost : 0.13405098102261637
# Compute control for a deterministic system
# Cost in iteration 0: 0.13405098102261637
# Converged in iteration 655 with cost 0.13404985946439604 because of step counter
# Final cost : 0.13404985946439604
# Compute control for a deterministic system
# Cost in iteration 0: 0.13404985946439604
# Converged in iteration 13 with cost 0.13404985946437806 because of step counter
# Final cost : 0.13404985946437806
# Compute control for a deterministic system
# Cost in iteration 0: 0.13404985946437806
# Converged in iteration 28 with cost 0.13404985946429493 because of step counter
# Final cost : 0.13404985946429493
# cost =  0.10268074611992023
# Compute control for a deterministic system
# Cost in iteration 0: 0.12168599913105377
# Final cost : 0.10290529293873917
# Compute control for a deterministic system
# Cost in iteration 0: 0.10290529293873917
# Final cost : 0.10268740784265386
# Compute control for a deterministic system
# Cost in iteration 0: 0.10268740784265386
# Final cost : 0.10268074651803245
# Compute control for a deterministic system
# Cost in iteration 0: 0.10268074651803245
# Final cost : 0.1026807461037922
# Compute control for a deterministic system
# Cost in iteration 0: 0.1026807461037922
# Converged in iteration 1134 with cost 0.10268074608957158 because of step counter
# Final cost : 0.10268074608957158
# -----------------------------------------------
# 0 found better solution,  20
# cost =  0.09422737681329665
# Compute control for a deterministic system
# Cost in iteration 0: 0.18057623853285207
# Final cost : 0.0945678340656473
# Compute control for a deterministic system
# Cost in iteration 0: 0.0945678340656473
# Final cost : 0.09423492809799476
# Compute control for a deterministic system
# Cost in iteration 0: 0.09423492809799476
# Final cost : 0.09422737706856542
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422737706856542
# Final cost : 0.09422737681610038
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422737681610038
# Converged in iteration 546 with cost 0.09422737681339212 because of step counter
# Final cost : 0.09422737681339212
# cost =  0.08597393591001175
# Compute control for a deterministic system
# Cost in iteration 0: 0.12265345171769124
# Final cost : 0.08629896717188017
# Compute control for a deterministic system
# Cost in iteration 0: 0.08629896717188017
# Final cost : 0.08597902921577993
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597902921577993
# Final cost : 0.08597393591438797
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597393591438797
# Converged in iteration 680 with cost 0.08597393590844864 because of step counter
# Final cost : 0.08597393590844864
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597393590844864
# Converged in iteration 36 with cost 0.08597393590821134 because of step counter
# Final cost : 0.08597393590821134
# -----------------------------------------------
# 0 found better solution,  22
# cost =  0.07793559560720814
# Compute control for a deterministic system
# Cost in iteration 0: 0.1259888895349313
# Final cost : 0.07824674694526777
# Compute control for a deterministic system
# Cost in iteration 0: 0.07824674694526777
# Final cost : 0.07793914134252691
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793914134252691
# Final cost : 0.07793559561062936
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559561062936
# Converged in iteration 298 with cost 0.07793559560726859 because of vanishing difference
# Final cost : 0.07793559560726859
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559560726859
# Converged in iteration 5 with cost 0.0779355956072649 because of step counter
# Final cost : 0.0779355956072649
# cost =  0.07167113086397624
# Compute control for a deterministic system
# Cost in iteration 0: 0.12298573294842313
# Final cost : 0.07186314926108694
# Compute control for a deterministic system
# Cost in iteration 0: 0.07186314926108694
# Final cost : 0.0716727118079596
# Compute control for a deterministic system
# Cost in iteration 0: 0.0716727118079596
# Final cost : 0.07167113086447113
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113086447113
# Converged in iteration 160 with cost 0.07167113086421814 because of step counter
# Final cost : 0.07167113086421814
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113086421814
# Converged in iteration 72 with cost 0.07167113086404117 because of step counter
# Final cost : 0.07167113086404117
# cost =  0.06406400051864199
# Compute control for a deterministic system
# Cost in iteration 0: 0.13247802618464805
# Final cost : 0.06434581647455553
# Compute control for a deterministic system
# Cost in iteration 0: 0.06434581647455553
# Final cost : 0.06406578848767731
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406578848767731
# Final cost : 0.06406400051876694
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400051876694
# Converged in iteration 8 with cost 0.06406400051875834 because of vanishing difference
# Final cost : 0.06406400051875834
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400051875834
# Converged in iteration 2 with cost 0.06406400051875796 because of step counter
# Final cost : 0.06406400051875796
# cost =  0.05672441056868391
# Compute control for a deterministic system
# Cost in iteration 0: 0.13543093539204848
# Final cost : 0.05698789047651474
# Compute control for a deterministic system
# Cost in iteration 0: 0.05698789047651474
# Final cost : 0.05672558566421089
# Compute control for a deterministic system
# Cost in iteration 0: 0.05672558566421089
# Converged in iteration 920 with cost 0.056724410568762394 because of step counter
# Final cost : 0.056724410568762394
# Compute control for a deterministic system
# Cost in iteration 0: 0.056724410568762394
# Converged in iteration 1 with cost 0.056724410568762394 because of step counter
# Final cost : 0.056724410568762394
# Compute control for a deterministic system
# Cost in iteration 0: 0.056724410568762394
# Converged in iteration 1 with cost 0.056724410568762394 because of step counter
# Final cost : 0.056724410568762394
# cost =  0.049675090850985176
# Compute control for a deterministic system
# Cost in iteration 0: 0.10437221722977877
# Final cost : 0.049917253906227234
# Compute control for a deterministic system
# Cost in iteration 0: 0.049917253906227234
# Final cost : 0.04967582476880258
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967582476880258
# Converged in iteration 774 with cost 0.04967509085106301 because of step counter
# Final cost : 0.04967509085106301
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967509085106301
# Converged in iteration 7 with cost 0.04967509085106189 because of step counter
# Final cost : 0.04967509085106189
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967509085106189
# Converged in iteration 1 with cost 0.04967509085106189 because of step counter
# Final cost : 0.04967509085106189
# cost =  0.04426136225902635
# Compute control for a deterministic system
# Cost in iteration 0: 0.09689560864216318
# Final cost : 0.04440678183266839
# Compute control for a deterministic system
# Cost in iteration 0: 0.04440678183266839
# Final cost : 0.044261652879329774
# Compute control for a deterministic system
# Cost in iteration 0: 0.044261652879329774
# Converged in iteration 572 with cost 0.044261362259097485 because of step counter
# Final cost : 0.044261362259097485
# Compute control for a deterministic system
# Cost in iteration 0: 0.044261362259097485
# Converged in iteration 1 with cost 0.044261362259097485 because of step counter
# Final cost : 0.044261362259097485
# Compute control for a deterministic system
# Cost in iteration 0: 0.044261362259097485
# Converged in iteration 1 with cost 0.044261362259097485 because of step counter
# Final cost : 0.044261362259097485
# cost =  0.037799077645742175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0850256782345114
# Final cost : 0.038002131124986654
# Compute control for a deterministic system
# Cost in iteration 0: 0.038002131124986654
# Final cost : 0.03779939246454828
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779939246454828
# Converged in iteration 508 with cost 0.03779907764578023 because of step counter
# Final cost : 0.03779907764578023
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764578023
# Converged in iteration 16 with cost 0.03779907764577017 because of step counter
# Final cost : 0.03779907764577017
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764577017
# Converged in iteration 1 with cost 0.03779907764577017 because of step counter
# Final cost : 0.03779907764577017
# cost =  0.03170267577312094
# Compute control for a deterministic system
# Cost in iteration 0: 0.09883985582615468
# Final cost : 0.03188656204438891
# Compute control for a deterministic system
# Cost in iteration 0: 0.03188656204438891
# Final cost : 0.031702814586169865
# Compute control for a deterministic system
# Cost in iteration 0: 0.031702814586169865
# Converged in iteration 616 with cost 0.03170267577316007 because of step counter
# Final cost : 0.03170267577316007
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577316007
# Converged in iteration 1 with cost 0.03170267577316007 because of step counter
# Final cost : 0.03170267577316007
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577316007
# Converged in iteration 1 with cost 0.03170267577316007 because of step counter
# Final cost : 0.03170267577316007
# cost =  0.026003625930791238
# Compute control for a deterministic system
# Cost in iteration 0: 0.09928238433090364
# Final cost : 0.02616746331116252
# Compute control for a deterministic system
# Cost in iteration 0: 0.02616746331116252
# Final cost : 0.026003697268692796
# Compute control for a deterministic system
# Cost in iteration 0: 0.026003697268692796
# Converged in iteration 441 with cost 0.026003625930803922 because of step counter
# Final cost : 0.026003625930803922
# Compute control for a deterministic system
# Cost in iteration 0: 0.026003625930803922
# Converged in iteration 1 with cost 0.026003625930803922 because of step counter
# Final cost : 0.026003625930803922
# Compute control for a deterministic system
# Cost in iteration 0: 0.026003625930803922
# Converged in iteration 1 with cost 0.026003625930803922 because of step counter
# Final cost : 0.026003625930803922
# cost =  0.020738418999674844
# Compute control for a deterministic system
# Cost in iteration 0: 0.09300692046650591
# Final cost : 0.02088265270967829
# Compute control for a deterministic system
# Cost in iteration 0: 0.02088265270967829
# Final cost : 0.020738467469946224
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738467469946224
# Converged in iteration 380 with cost 0.020738418999671583 because of step counter
# Final cost : 0.020738418999671583
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738418999671583
# Converged in iteration 1 with cost 0.020738418999671583 because of step counter
# Final cost : 0.020738418999671583
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738418999671583
# Converged in iteration 1 with cost 0.020738418999671583 because of step counter
# Final cost : 0.020738418999671583
# -----------------------------------------------
# 0 found better solution,  32
# cost =  0.016868274518559476
# Compute control for a deterministic system
# Cost in iteration 0: 0.04983285089028565
# Final cost : 0.01694780064481142
# Compute control for a deterministic system
# Cost in iteration 0: 0.01694780064481142
# Final cost : 0.016868283013437423
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868283013437423
# Converged in iteration 303 with cost 0.016868274518579925 because of step counter
# Final cost : 0.016868274518579925
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518579925
# Converged in iteration 1 with cost 0.016868274518579925 because of step counter
# Final cost : 0.016868274518579925
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518579925
# Converged in iteration 1 with cost 0.016868274518579925 because of step counter
# Final cost : 0.016868274518579925
# cost =  0.012500516141300936
# Compute control for a deterministic system
# Cost in iteration 0: 0.07452055659781917
# Final cost : 0.012608815676010257
# Compute control for a deterministic system
# Cost in iteration 0: 0.012608815676010257
# Final cost : 0.012500521800477109
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500521800477109
# Converged in iteration 291 with cost 0.012500516141313017 because of step counter
# Final cost : 0.012500516141313017
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500516141313017
# Converged in iteration 2 with cost 0.012500516141312895 because of step counter
# Final cost : 0.012500516141312895
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500516141312895
# Converged in iteration 2 with cost 0.012500516141312843 because of step counter
# Final cost : 0.012500516141312843
# cost =  0.008704314221382882
# Compute control for a deterministic system
# Cost in iteration 0: 0.0639271037323243
# Final cost : 0.008791601942443453
# Compute control for a deterministic system
# Cost in iteration 0: 0.008791601942443453
# Final cost : 0.008704316676261174
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704316676261174
# Converged in iteration 295 with cost 0.008704314221394213 because of step counter
# Final cost : 0.008704314221394213
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704314221394213
# Converged in iteration 4 with cost 0.008704314221393976 because of step counter
# Final cost : 0.008704314221393976
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704314221393976
# Converged in iteration 1 with cost 0.008704314221393976 because of step counter
# Final cost : 0.008704314221393976
# cost =  0.005531164804487129
# Compute control for a deterministic system
# Cost in iteration 0: 0.07442483915883638
# Final cost : 0.00560424144863542
# Compute control for a deterministic system
# Cost in iteration 0: 0.00560424144863542
# Final cost : 0.005531165783446269
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531165783446269
# Converged in iteration 294 with cost 0.00553116480450588 because of step counter
# Final cost : 0.00553116480450588
# Compute control for a deterministic system
# Cost in iteration 0: 0.00553116480450588
# Converged in iteration 1 with cost 0.00553116480450588 because of step counter
# Final cost : 0.00553116480450588
# Compute control for a deterministic system
# Cost in iteration 0: 0.00553116480450588
# Converged in iteration 1 with cost 0.00553116480450588 because of step counter
# Final cost : 0.00553116480450588
# cost =  0.0034739442876881447
# Compute control for a deterministic system
# Cost in iteration 0: 0.04482979135263686
# Final cost : 0.003510834245301779
# Compute control for a deterministic system
# Cost in iteration 0: 0.003510834245301779
# Final cost : 0.0034739445328084407
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034739445328084407
# Converged in iteration 276 with cost 0.0034739442876936754 because of step counter
# Final cost : 0.0034739442876936754
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034739442876936754
# Converged in iteration 1 with cost 0.0034739442876936754 because of step counter
# Final cost : 0.0034739442876936754
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034739442876936754
# Converged in iteration 2 with cost 0.0034739442876936403 because of step counter
# Final cost : 0.0034739442876936403
# cost =  0.0015435284181083513
# Compute control for a deterministic system
# Cost in iteration 0: 0.06601804015689926
# Final cost : 0.0015890869361051905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015890869361051905
# Final cost : 0.001543528607207422
# Compute control for a deterministic system
# Cost in iteration 0: 0.001543528607207422
# Converged in iteration 306 with cost 0.0015435284181155677 because of step counter
# Final cost : 0.0015435284181155677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284181155677
# Converged in iteration 1 with cost 0.0015435284181155677 because of step counter
# Final cost : 0.0015435284181155677
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284181155677
# Converged in iteration 1 with cost 0.0015435284181155677 because of step counter
# Final cost : 0.0015435284181155677
# cost =  0.00036962779384611957
# Compute control for a deterministic system
# Cost in iteration 0: 0.06579062222752623
# Final cost : 0.00040736823317547466
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040736823317547466
# Final cost : 0.0003696278293716648
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003696278293716648
# Converged in iteration 383 with cost 0.0003696277938493395 because of vanishing difference
# Final cost : 0.0003696277938493395
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003696277938493395
# Converged in iteration 3 with cost 0.00036962779384906426 because of step counter
# Final cost : 0.00036962779384906426
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036962779384906426
# Converged in iteration 21 with cost 0.00036962779384822915 because of step counter
# Final cost : 0.00036962779384822915
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.06430686883114664
# Final cost : 0.0015435286894944342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435286894944342
# Converged in iteration 287 with cost 0.0015435284181231045 because of step counter
# Final cost : 0.0015435284181231045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284181231045
# Converged in iteration 1 with cost 0.0015435284181231045 because of step counter
# Final cost : 0.0015435284181231045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284181231045
# Converged in iteration 1 with cost 0.0015435284181231045 because of step counter
# Final cost : 0.0015435284181231045
# Compute control for a deterministic system
# Cost in iteration 0: 0.0682591898398312
# Final cost : 0.003473944701932286
# Compute control for a deterministic system
# Cost in iteration 0: 0.003473944701932286
# Converged in iteration 282 with cost 0.003473944287699761 because of step counter
# Final cost : 0.003473944287699761
# Compute control for a deterministic system
# Cost in iteration 0: 0.003473944287699761
# Converged in iteration 1 with cost 0.003473944287699761 because of step counter
# Final cost : 0.003473944287699761
# Compute control for a deterministic system
# Cost in iteration 0: 0.003473944287699761
# Converged in iteration 1 with cost 0.003473944287699761 because of step counter
# Final cost : 0.003473944287699761
# Compute control for a deterministic system
# Cost in iteration 0: 0.04892723442516572
# Final cost : 0.0055311653467490385
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055311653467490385
# Converged in iteration 315 with cost 0.005531164804491202 because of step counter
# Final cost : 0.005531164804491202
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531164804491202
# Converged in iteration 1 with cost 0.005531164804491202 because of step counter
# Final cost : 0.005531164804491202
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531164804491202
# Converged in iteration 1 with cost 0.005531164804491202 because of step counter
# Final cost : 0.005531164804491202
# Compute control for a deterministic system
# Cost in iteration 0: 0.07275155144626487
# Final cost : 0.008704316404728992
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704316404728992
# Converged in iteration 299 with cost 0.008704314221395785 because of step counter
# Final cost : 0.008704314221395785
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704314221395785
# Converged in iteration 1 with cost 0.008704314221395785 because of step counter
# Final cost : 0.008704314221395785
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704314221395785
# Converged in iteration 1 with cost 0.008704314221395785 because of step counter
# Final cost : 0.008704314221395785
# Compute control for a deterministic system
# Cost in iteration 0: 0.06951939023564671
# Final cost : 0.012500521035716233
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500521035716233
# Converged in iteration 274 with cost 0.01250051614130221 because of step counter
# Final cost : 0.01250051614130221
# Compute control for a deterministic system
# Cost in iteration 0: 0.01250051614130221
# Converged in iteration 1 with cost 0.01250051614130221 because of step counter
# Final cost : 0.01250051614130221
# Compute control for a deterministic system
# Cost in iteration 0: 0.01250051614130221
# Converged in iteration 1 with cost 0.01250051614130221 because of step counter
# Final cost : 0.01250051614130221
# Compute control for a deterministic system
# Cost in iteration 0: 0.07933575645012662
# Final cost : 0.016868284463510335
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868284463510335
# Converged in iteration 313 with cost 0.016868274518567598 because of step counter
# Final cost : 0.016868274518567598
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518567598
# Converged in iteration 1 with cost 0.016868274518567598 because of step counter
# Final cost : 0.016868274518567598
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518567598
# Converged in iteration 1 with cost 0.016868274518567598 because of step counter
# Final cost : 0.016868274518567598
# Compute control for a deterministic system
# Cost in iteration 0: 0.059694982695523764
# Final cost : 0.020738442938138594
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738442938138594
# Converged in iteration 375 with cost 0.02073841899967887 because of step counter
# Final cost : 0.02073841899967887
# Compute control for a deterministic system
# Cost in iteration 0: 0.02073841899967887
# Converged in iteration 1 with cost 0.02073841899967887 because of step counter
# Final cost : 0.02073841899967887
# Compute control for a deterministic system
# Cost in iteration 0: 0.02073841899967887
# Converged in iteration 1 with cost 0.02073841899967887 because of step counter
# Final cost : 0.02073841899967887
# Compute control for a deterministic system
# Cost in iteration 0: 0.09355004951854194
# Final cost : 0.02600373248645859
# Compute control for a deterministic system
# Cost in iteration 0: 0.02600373248645859
# Converged in iteration 489 with cost 0.02600362593080015 because of step counter
# Final cost : 0.02600362593080015
# Compute control for a deterministic system
# Cost in iteration 0: 0.02600362593080015
# Converged in iteration 1 with cost 0.02600362593080015 because of step counter
# Final cost : 0.02600362593080015
# Compute control for a deterministic system
# Cost in iteration 0: 0.02600362593080015
# Converged in iteration 1 with cost 0.02600362593080015 because of step counter
# Final cost : 0.02600362593080015
# Compute control for a deterministic system
# Cost in iteration 0: 0.10250470343508687
# Final cost : 0.03170282415055332
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170282415055332
# Converged in iteration 620 with cost 0.03170267577318543 because of step counter
# Final cost : 0.03170267577318543
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577318543
# Converged in iteration 2 with cost 0.03170267577318536 because of step counter
# Final cost : 0.03170267577318536
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577318536
# Converged in iteration 33 with cost 0.031702675773172165 because of step counter
# Final cost : 0.031702675773172165
# Compute control for a deterministic system
# Cost in iteration 0: 0.0942557063071414
# Final cost : 0.03779932772124432
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779932772124432
# Converged in iteration 485 with cost 0.03779907764580369 because of step counter
# Final cost : 0.03779907764580369
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764580369
# Converged in iteration 1 with cost 0.03779907764580369 because of step counter
# Final cost : 0.03779907764580369
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764580369
# Converged in iteration 1 with cost 0.03779907764580369 because of step counter
# Final cost : 0.03779907764580369
# Compute control for a deterministic system
# Cost in iteration 0: 0.10321646569970357
# Final cost : 0.04426182638615689
# Compute control for a deterministic system
# Cost in iteration 0: 0.04426182638615689
# Converged in iteration 634 with cost 0.044261362259053055 because of step counter
# Final cost : 0.044261362259053055
# Compute control for a deterministic system
# Cost in iteration 0: 0.044261362259053055
# Converged in iteration 11 with cost 0.04426136225904318 because of step counter
# Final cost : 0.04426136225904318
# Compute control for a deterministic system
# Cost in iteration 0: 0.04426136225904318
# Converged in iteration 1 with cost 0.04426136225904318 because of step counter
# Final cost : 0.04426136225904318
# Compute control for a deterministic system
# Cost in iteration 0: 0.10220405275614676
# Final cost : 0.04967554398340224
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967554398340224
# Converged in iteration 743 with cost 0.04967509085107676 because of step counter
# Final cost : 0.04967509085107676
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967509085107676
# Converged in iteration 1 with cost 0.04967509085107676 because of step counter
# Final cost : 0.04967509085107676
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967509085107676
# Converged in iteration 1 with cost 0.04967509085107676 because of step counter
# Final cost : 0.04967509085107676
# Compute control for a deterministic system
# Cost in iteration 0: 0.10394368705306141
# Final cost : 0.056725478092021664
# Compute control for a deterministic system
# Cost in iteration 0: 0.056725478092021664
# Converged in iteration 928 with cost 0.05672441056874915 because of step counter
# Final cost : 0.05672441056874915
# Compute control for a deterministic system
# Cost in iteration 0: 0.05672441056874915
# Converged in iteration 1 with cost 0.05672441056874915 because of step counter
# Final cost : 0.05672441056874915
# Compute control for a deterministic system
# Cost in iteration 0: 0.05672441056874915
# Converged in iteration 1 with cost 0.05672441056874915 because of step counter
# Final cost : 0.05672441056874915
# Compute control for a deterministic system
# Cost in iteration 0: 0.1114544054067639
# Final cost : 0.06406555510874429
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406555510874429
# Final cost : 0.06406400051877946
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400051877946
# Converged in iteration 26 with cost 0.0640640005187606 because of step counter
# Final cost : 0.0640640005187606
# Compute control for a deterministic system
# Cost in iteration 0: 0.0640640005187606
# Converged in iteration 3 with cost 0.06406400051875967 because of step counter
# Final cost : 0.06406400051875967
# Compute control for a deterministic system
# Cost in iteration 0: 0.12184644684619737
# Final cost : 0.07167333559817433
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167333559817433
# Final cost : 0.071671130864343
# Compute control for a deterministic system
# Cost in iteration 0: 0.071671130864343
# Converged in iteration 70 with cost 0.07167113086420247 because of vanishing difference
# Final cost : 0.07167113086420247
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113086420247
# Converged in iteration 92 with cost 0.07167113086399494 because of vanishing difference
# Final cost : 0.07167113086399494
# Compute control for a deterministic system
# Cost in iteration 0: 0.10546445906980434
# Final cost : 0.07793740985032262
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793740985032262
# Final cost : 0.07793559560818725
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559560818725
# Converged in iteration 342 with cost 0.07793559560717687 because of step counter
# Final cost : 0.07793559560717687
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559560717687
# Converged in iteration 52 with cost 0.07793559560702053 because of step counter
# Final cost : 0.07793559560702053
# -----------------------------------------------
# 1 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.14688490107171143
# Final cost : 0.0859774725702774
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859774725702774
# Final cost : 0.08597393591085893
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597393591085893
# Converged in iteration 506 with cost 0.08597393590839415 because of step counter
# Final cost : 0.08597393590839415
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597393590839415
# Converged in iteration 40 with cost 0.08597393590815473 because of step counter
# Final cost : 0.08597393590815473
# -----------------------------------------------
# 1 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.15712053842238966
# Final cost : 0.09423193284305302
# Compute control for a deterministic system
# Cost in iteration 0: 0.09423193284305302
# Final cost : 0.09422737707785456
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422737707785456
# Final cost : 0.09422737681741462
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422737681741462
# Converged in iteration 638 with cost 0.09422737681330522 because of step counter
# Final cost : 0.09422737681330522
# Compute control for a deterministic system
# Cost in iteration 0: 0.1798010702985176
# Final cost : 0.10268727747397632
# Compute control for a deterministic system
# Cost in iteration 0: 0.10268727747397632
# Final cost : 0.10268074640436213
# Compute control for a deterministic system
# Cost in iteration 0: 0.10268074640436213
# Final cost : 0.10268074609490609
# Compute control for a deterministic system
# Cost in iteration 0: 0.10268074609490609
# Converged in iteration 732 with cost 0.10268074608957016 because of step counter
# Final cost : 0.10268074608957016
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.14576921258441694
# Final cost : 0.10958424804344186
# Compute control for a deterministic system
# Cost in iteration 0: 0.10958424804344186
# Final cost : 0.10957830874527417
# Compute control for a deterministic system
# Cost in iteration 0: 0.10957830874527417
# Final cost : 0.10957830741096944
# Compute control for a deterministic system
# Cost in iteration 0: 0.10957830741096944
# Converged in iteration 1496 with cost 0.1095783073652519 because of step counter
# Final cost : 0.1095783073652519
# Compute control for a deterministic system
# Cost in iteration 0: 0.2044249072439291
# Final cost : 0.11837063987671097
# Compute control for a deterministic system
# Cost in iteration 0: 0.11837063987671097
# Final cost : 0.11835899718486384
# Compute control for a deterministic system
# Cost in iteration 0: 0.11835899718486384
# Final cost : 0.11835897980199167
# Compute control for a deterministic system
# Cost in iteration 0: 0.11835897980199167
# Converged in iteration 941 with cost 0.11835897802883105 because of step counter
# Final cost : 0.11835897802883105
# Compute control for a deterministic system
# Cost in iteration 0: 0.15594508169507654
# Final cost : 0.10364447102723807
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364447102723807
# Converged in iteration 693 with cost 0.10364273456397058 because of step counter
# Final cost : 0.10364273456397058
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364273456397058
# Converged in iteration 1 with cost 0.10364273456397058 because of step counter
# Final cost : 0.10364273456397058
# Compute control for a deterministic system
# Cost in iteration 0: 0.10364273456397058
# Converged in iteration 2 with cost 0.10364273456397002 because of step counter
# Final cost : 0.10364273456397002
# Compute control for a deterministic system
# Cost in iteration 0: 0.1330158256886816
# Final cost : 0.09027554271218853
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027554271218853
# Converged in iteration 594 with cost 0.09027395623262768 because of step counter
# Final cost : 0.09027395623262768
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027395623262768
# Converged in iteration 1 with cost 0.09027395623262768 because of step counter
# Final cost : 0.09027395623262768
# Compute control for a deterministic system
# Cost in iteration 0: 0.09027395623262768
# Converged in iteration 1 with cost 0.09027395623262768 because of step counter
# Final cost : 0.09027395623262768
# ...
# Converged in iteration 1 with cost 0.10268074608972833 because of step counter
# Final cost : 0.10268074608972833
# Compute control for a deterministic system
# Cost in iteration 0: 0.1007980157828515
# Final cost : 0.09424410199812923
# Compute control for a deterministic system
# Cost in iteration 0: 0.09424410199812923
# Final cost : 0.09422738129630474
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422738129630474
# Converged in iteration 488 with cost 0.09422737681362671 because of step counter
# Final cost : 0.09422737681362671
# Compute control for a deterministic system
# Cost in iteration 0: 0.09422737681362671
# Converged in iteration 15 with cost 0.0942273768136089 because of vanishing difference
# Final cost : 0.0942273768136089
# Compute control for a deterministic system
# Cost in iteration 0: 0.0942273768136089
# Converged in iteration 20 with cost 0.09422737681331048 because of step counter
# Final cost : 0.09422737681331048
# Compute control for a deterministic system
# Cost in iteration 0: 0.0893195739349267
# Final cost : 0.08598884715636539
# Compute control for a deterministic system
# Cost in iteration 0: 0.08598884715636539
# Final cost : 0.08597393834198601
# Compute control for a deterministic system
# Cost in iteration 0: 0.08597393834198601
# Converged in iteration 321 with cost 0.0859739359083748 because of vanishing difference
# Final cost : 0.0859739359083748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859739359083748
# Converged in iteration 1 with cost 0.0859739359083748 because of step counter
# Final cost : 0.0859739359083748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859739359083748
# Converged in iteration 75 with cost 0.08597393590818292 because of step counter
# Final cost : 0.08597393590818292
# Compute control for a deterministic system
# Cost in iteration 0: 0.0783185588281456
# Final cost : 0.07794875319489689
# Compute control for a deterministic system
# Cost in iteration 0: 0.07794875319489689
# Final cost : 0.07793559736386423
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559736386423
# Converged in iteration 417 with cost 0.07793559560719876 because of step counter
# Final cost : 0.07793559560719876
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559560719876
# Converged in iteration 1 with cost 0.07793559560719876 because of step counter
# Final cost : 0.07793559560719876
# Compute control for a deterministic system
# Cost in iteration 0: 0.07793559560719876
# Converged in iteration 1 with cost 0.07793559560719876 because of step counter
# Final cost : 0.07793559560719876
# Compute control for a deterministic system
# Cost in iteration 0: 0.07188504629921148
# Final cost : 0.07168237939658523
# Compute control for a deterministic system
# Cost in iteration 0: 0.07168237939658523
# Final cost : 0.07167113204607783
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113204607783
# Converged in iteration 380 with cost 0.07167113086411457 because of vanishing difference
# Final cost : 0.07167113086411457
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113086411457
# Converged in iteration 6 with cost 0.07167113086411164 because of step counter
# Final cost : 0.07167113086411164
# Compute control for a deterministic system
# Cost in iteration 0: 0.07167113086411164
# Converged in iteration 1 with cost 0.07167113086411164 because of step counter
# Final cost : 0.07167113086411164
# Compute control for a deterministic system
# Cost in iteration 0: 0.06429033493861556
# Final cost : 0.06407207097489409
# Compute control for a deterministic system
# Cost in iteration 0: 0.06407207097489409
# Final cost : 0.06406400133013145
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400133013145
# Converged in iteration 318 with cost 0.06406400051872277 because of step counter
# Final cost : 0.06406400051872277
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400051872277
# Converged in iteration 1 with cost 0.06406400051872277 because of step counter
# Final cost : 0.06406400051872277
# Compute control for a deterministic system
# Cost in iteration 0: 0.06406400051872277
# Converged in iteration 1 with cost 0.06406400051872277 because of step counter
# Final cost : 0.06406400051872277
# Compute control for a deterministic system
# Cost in iteration 0: 0.056810136293703885
# Final cost : 0.05672959823049504
# Compute control for a deterministic system
# Cost in iteration 0: 0.05672959823049504
# Final cost : 0.056724410987633096
# Compute control for a deterministic system
# Cost in iteration 0: 0.056724410987633096
# Converged in iteration 259 with cost 0.056724410568737296 because of step counter
# Final cost : 0.056724410568737296
# Compute control for a deterministic system
# Cost in iteration 0: 0.056724410568737296
# Converged in iteration 5 with cost 0.05672441056873653 because of step counter
# Final cost : 0.05672441056873653
# Compute control for a deterministic system
# Cost in iteration 0: 0.05672441056873653
# Converged in iteration 1 with cost 0.05672441056873653 because of step counter
# Final cost : 0.05672441056873653
# Compute control for a deterministic system
# Cost in iteration 0: 0.049894237419540646
# Final cost : 0.04967800383045282
# Compute control for a deterministic system
# Cost in iteration 0: 0.04967800383045282
# Final cost : 0.0496750910514592
# Compute control for a deterministic system
# Cost in iteration 0: 0.0496750910514592
# Converged in iteration 189 with cost 0.049675090851009636 because of step counter
# Final cost : 0.049675090851009636
# Compute control for a deterministic system
# Cost in iteration 0: 0.049675090851009636
# Converged in iteration 2 with cost 0.049675090851009227 because of step counter
# Final cost : 0.049675090851009227
# Compute control for a deterministic system
# Cost in iteration 0: 0.049675090851009227
# Converged in iteration 1 with cost 0.049675090851009227 because of step counter
# Final cost : 0.049675090851009227
# Compute control for a deterministic system
# Cost in iteration 0: 0.04427978448079148
# Final cost : 0.044263205052954994
# Compute control for a deterministic system
# Cost in iteration 0: 0.044263205052954994
# Final cost : 0.04426136232538992
# Compute control for a deterministic system
# Cost in iteration 0: 0.04426136232538992
# Converged in iteration 156 with cost 0.04426136225903139 because of step counter
# Final cost : 0.04426136225903139
# Compute control for a deterministic system
# Cost in iteration 0: 0.04426136225903139
# Converged in iteration 4 with cost 0.044261362259030816 because of step counter
# Final cost : 0.044261362259030816
# Compute control for a deterministic system
# Cost in iteration 0: 0.044261362259030816
# Converged in iteration 1 with cost 0.044261362259030816 because of vanishing difference
# Final cost : 0.044261362259030816
# Compute control for a deterministic system
# Cost in iteration 0: 0.03781998028743839
# Final cost : 0.03780002580857768
# Compute control for a deterministic system
# Cost in iteration 0: 0.03780002580857768
# Final cost : 0.037799077683455716
# Compute control for a deterministic system
# Cost in iteration 0: 0.037799077683455716
# Converged in iteration 115 with cost 0.03779907764575924 because of step counter
# Final cost : 0.03779907764575924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764575924
# Converged in iteration 1 with cost 0.03779907764575924 because of step counter
# Final cost : 0.03779907764575924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03779907764575924
# Converged in iteration 3 with cost 0.03779907764575883 because of step counter
# Final cost : 0.03779907764575883
# Compute control for a deterministic system
# Cost in iteration 0: 0.03172219439527748
# Final cost : 0.031703193793468476
# Compute control for a deterministic system
# Cost in iteration 0: 0.031703193793468476
# Final cost : 0.03170267578287246
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267578287246
# Converged in iteration 137 with cost 0.03170267577315575 because of step counter
# Final cost : 0.03170267577315575
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577315575
# Converged in iteration 3 with cost 0.03170267577315544 because of step counter
# Final cost : 0.03170267577315544
# Compute control for a deterministic system
# Cost in iteration 0: 0.03170267577315544
# Converged in iteration 1 with cost 0.03170267577315544 because of step counter
# Final cost : 0.03170267577315544
# Compute control for a deterministic system
# Cost in iteration 0: 0.026276595994146796
# Final cost : 0.02600400607179246
# Compute control for a deterministic system
# Cost in iteration 0: 0.02600400607179246
# Final cost : 0.02600362593515715
# Compute control for a deterministic system
# Cost in iteration 0: 0.02600362593515715
# Converged in iteration 101 with cost 0.026003625930797435 because of step counter
# Final cost : 0.026003625930797435
# Compute control for a deterministic system
# Cost in iteration 0: 0.026003625930797435
# Converged in iteration 1 with cost 0.026003625930797435 because of step counter
# Final cost : 0.026003625930797435
# Compute control for a deterministic system
# Cost in iteration 0: 0.026003625930797435
# Converged in iteration 1 with cost 0.026003625930797435 because of step counter
# Final cost : 0.026003625930797435
# Compute control for a deterministic system
# Cost in iteration 0: 0.020875394838798692
# Final cost : 0.02073870364002958
# Compute control for a deterministic system
# Cost in iteration 0: 0.02073870364002958
# Final cost : 0.020738419002566587
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738419002566587
# Converged in iteration 70 with cost 0.020738418999672742 because of step counter
# Final cost : 0.020738418999672742
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738418999672742
# Converged in iteration 2 with cost 0.020738418999672235 because of step counter
# Final cost : 0.020738418999672235
# Compute control for a deterministic system
# Cost in iteration 0: 0.020738418999672235
# Converged in iteration 1 with cost 0.020738418999672235 because of step counter
# Final cost : 0.020738418999672235
# Compute control for a deterministic system
# Cost in iteration 0: 0.016872420143911448
# Final cost : 0.016868526638177315
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868526638177315
# Final cost : 0.0168682745190725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0168682745190725
# Converged in iteration 61 with cost 0.016868274518570685 because of step counter
# Final cost : 0.016868274518570685
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518570685
# Converged in iteration 1 with cost 0.016868274518570685 because of step counter
# Final cost : 0.016868274518570685
# Compute control for a deterministic system
# Cost in iteration 0: 0.016868274518570685
# Converged in iteration 2 with cost 0.016868274518570626 because of step counter
# Final cost : 0.016868274518570626
# Compute control for a deterministic system
# Cost in iteration 0: 0.012507285039684504
# Final cost : 0.012500738362510018
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500738362510018
# Final cost : 0.012500516141763899
# Compute control for a deterministic system
# Cost in iteration 0: 0.012500516141763899
# Converged in iteration 69 with cost 0.01250051614130187 because of step counter
# Final cost : 0.01250051614130187
# Compute control for a deterministic system
# Cost in iteration 0: 0.01250051614130187
# Converged in iteration 1 with cost 0.01250051614130187 because of step counter
# Final cost : 0.01250051614130187
# Compute control for a deterministic system
# Cost in iteration 0: 0.01250051614130187
# Converged in iteration 8 with cost 0.0125005161413009 because of step counter
# Final cost : 0.0125005161413009
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.00874290571135799
# Final cost : 0.008704502783662083
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704502783662083
# Final cost : 0.008704314221802616
# Compute control for a deterministic system
# Cost in iteration 0: 0.008704314221802616
# Converged in iteration 75 with cost 0.00870431422139181 because of step counter
# Final cost : 0.00870431422139181
# Compute control for a deterministic system
# Cost in iteration 0: 0.00870431422139181
# Converged in iteration 1 with cost 0.00870431422139181 because of step counter
# Final cost : 0.00870431422139181
# Compute control for a deterministic system
# Cost in iteration 0: 0.00870431422139181
# Converged in iteration 1 with cost 0.00870431422139181 because of step counter
# Final cost : 0.00870431422139181
# Compute control for a deterministic system
# Cost in iteration 0: 0.005536617905322722
# Final cost : 0.005531312581329843
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531312581329843
# Final cost : 0.005531164804794067
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531164804794067
# Converged in iteration 89 with cost 0.005531164804496087 because of step counter
# Final cost : 0.005531164804496087
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531164804496087
# Converged in iteration 1 with cost 0.005531164804496087 because of step counter
# Final cost : 0.005531164804496087
# Compute control for a deterministic system
# Cost in iteration 0: 0.005531164804496087
# Converged in iteration 1 with cost 0.005531164804496087 because of step counter
# Final cost : 0.005531164804496087
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035377599811837455
# Final cost : 0.003474052472598914
# Compute control for a deterministic system
# Cost in iteration 0: 0.003474052472598914
# Final cost : 0.0034739442879207216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034739442879207216
# Converged in iteration 91 with cost 0.00347394428769175 because of step counter
# Final cost : 0.00347394428769175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00347394428769175
# Converged in iteration 1 with cost 0.00347394428769175 because of step counter
# Final cost : 0.00347394428769175
# Compute control for a deterministic system
# Cost in iteration 0: 0.00347394428769175
# Converged in iteration 1 with cost 0.00347394428769175 because of step counter
# Final cost : 0.00347394428769175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015785279601237795
# Final cost : 0.0015435826630180846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435826630180846
# Final cost : 0.0015435284182476396
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284182476396
# Converged in iteration 85 with cost 0.0015435284181179569 because of step counter
# Final cost : 0.0015435284181179569
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015435284181179569
# Converged in iteration 18 with cost 0.00154352841811019 because of step counter
# Final cost : 0.00154352841811019
# Compute control for a deterministic system
# Cost in iteration 0: 0.00154352841811019
# Converged in iteration 2 with cost 0.001543528418110184 because of vanishing difference
# Final cost : 0.001543528418110184
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003711266497393779
# Final cost : 0.00036963923527685106
# Compute control for a deterministic system
# Cost in iteration 0: 0.00036963923527685106
# Final cost : 0.0003696277938813991
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003696277938813991
# Converged in iteration 73 with cost 0.0003696277938480242 because of step counter
# Final cost : 0.0003696277938480242
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003696277938480242
# Converged in iteration 2 with cost 0.0003696277938479834 because of step counter
# Final cost : 0.0003696277938479834
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003696277938479834
# Converged in iteration 1 with cost 0.0003696277938479834 because of step counter
# Final cost : 0.0003696277938479834

# %%
save(results_min)
