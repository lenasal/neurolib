# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 00.3811417843321322
y_init = 0.48364147610113273
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period) # 19.069230769230767

wc.run()
init_min = [wc.exc[0,30], wc.inh[0,30]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t[300:500], wc.exc[0,300:500])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  19.069565217391304
# minima =  [  18  209  400  590  781  972 1163 1353 1544 1735 1925 2116 2307 2497
#  2688 2879 3069 3260 3451 3642 3832 4023 4214 4404 4595 4786 4976]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.5
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy()
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy()
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy()
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.09170664662791786
# Converged in iteration 160 with cost 0.01438359161707599 because of step counter
# Final cost : 0.01438359161707599
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438359161707599
# Converged in iteration 1 with cost 0.01438359161707599 because of step counter
# Final cost : 0.01438359161707599
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438359161707599
# Converged in iteration 1 with cost 0.01438359161707599 because of step counter
# Final cost : 0.01438359161707599
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438359161707599
# Converged in iteration 1 with cost 0.01438359161707599 because of step counter
# Final cost : 0.01438359161707599
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438359161707599
# Converged in iteration 1 with cost 0.01438359161707599 because of step counter
# Final cost : 0.01438359161707599
# Compute control for a deterministic system
# Cost in iteration 0: 0.07643388744914668
# Converged in iteration 140 with cost 0.02079651378171469 because of step counter
# Final cost : 0.02079651378171469
# Compute control for a deterministic system
# Cost in iteration 0: 0.02079651378171469
# Converged in iteration 1 with cost 0.02079651378171469 because of step counter
# Final cost : 0.02079651378171469
# Compute control for a deterministic system
# Cost in iteration 0: 0.02079651378171469
# Converged in iteration 1 with cost 0.02079651378171469 because of step counter
# Final cost : 0.02079651378171469
# Compute control for a deterministic system
# Cost in iteration 0: 0.02079651378171469
# Converged in iteration 1 with cost 0.02079651378171469 because of step counter
# Final cost : 0.02079651378171469
# Compute control for a deterministic system
# Cost in iteration 0: 0.02079651378171469
# Converged in iteration 1 with cost 0.02079651378171469 because of step counter
# Final cost : 0.02079651378171469
# Compute control for a deterministic system
# Cost in iteration 0: 0.043640505048291756
# Converged in iteration 98 with cost 0.029079865402537226 because of step counter
# Final cost : 0.029079865402537226
# Compute control for a deterministic system
# Cost in iteration 0: 0.029079865402537226
# Converged in iteration 1 with cost 0.029079865402537226 because of step counter
# Final cost : 0.029079865402537226
# Compute control for a deterministic system
# Cost in iteration 0: 0.029079865402537226
# Converged in iteration 1 with cost 0.029079865402537226 because of step counter
# Final cost : 0.029079865402537226
# Compute control for a deterministic system
# Cost in iteration 0: 0.029079865402537226
# Converged in iteration 1 with cost 0.029079865402537226 because of step counter
# Final cost : 0.029079865402537226
# Compute control for a deterministic system
# Cost in iteration 0: 0.029079865402537226
# Converged in iteration 1 with cost 0.029079865402537226 because of step counter
# Final cost : 0.029079865402537226
# Compute control for a deterministic system
# Cost in iteration 0: 0.10581821788739044
# Converged in iteration 192 with cost 0.03703176843669789 because of step counter
# Final cost : 0.03703176843669789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03703176843669789
# Converged in iteration 1 with cost 0.03703176843669789 because of step counter
# Final cost : 0.03703176843669789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03703176843669789
# Converged in iteration 1 with cost 0.03703176843669789 because of step counter
# Final cost : 0.03703176843669789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03703176843669789
# Converged in iteration 1 with cost 0.03703176843669789 because of step counter
# Final cost : 0.03703176843669789
# Compute control for a deterministic system
# Cost in iteration 0: 0.03703176843669789
# Converged in iteration 1 with cost 0.03703176843669789 because of step counter
# Final cost : 0.03703176843669789
# Compute control for a deterministic system
# Cost in iteration 0: 0.16510158099587743
# Final cost : 0.044625641545396735
# Compute control for a deterministic system
# Cost in iteration 0: 0.044625641545396735
# Converged in iteration 47 with cost 0.044248143613656386 because of step counter
# Final cost : 0.044248143613656386
# Compute control for a deterministic system
# Cost in iteration 0: 0.044248143613656386
# Converged in iteration 1 with cost 0.044248143613656386 because of step counter
# Final cost : 0.044248143613656386
# Compute control for a deterministic system
# Cost in iteration 0: 0.044248143613656386
# Converged in iteration 1 with cost 0.044248143613656386 because of step counter
# Final cost : 0.044248143613656386
# Compute control for a deterministic system
# Cost in iteration 0: 0.044248143613656386
# Converged in iteration 1 with cost 0.044248143613656386 because of step counter
# Final cost : 0.044248143613656386
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.05817165850287864
# Converged in iteration 172 with cost 0.05181360874936731 because of step counter
# Final cost : 0.05181360874936731
# Compute control for a deterministic system
# Cost in iteration 0: 0.05181360874936731
# Converged in iteration 1 with cost 0.05181360874936731 because of step counter
# Final cost : 0.05181360874936731
# Compute control for a deterministic system
# Cost in iteration 0: 0.05181360874936731
# Converged in iteration 1 with cost 0.05181360874936731 because of step counter
# Final cost : 0.05181360874936731
# Compute control for a deterministic system
# Cost in iteration 0: 0.05181360874936731
# Converged in iteration 1 with cost 0.05181360874936731 because of step counter
# Final cost : 0.05181360874936731
# Compute control for a deterministic system
# Cost in iteration 0: 0.05181360874936731
# Converged in iteration 1 with cost 0.05181360874936731 because of step counter
# Final cost : 0.05181360874936731
# Compute control for a deterministic system
# Cost in iteration 0: 0.0675965604378786
# Converged in iteration 65 with cost 0.0596284802678582 because of step counter
# Final cost : 0.0596284802678582
# Compute control for a deterministic system
# Cost in iteration 0: 0.0596284802678582
# Converged in iteration 1 with cost 0.0596284802678582 because of step counter
# Final cost : 0.0596284802678582
# Compute control for a deterministic system
# Cost in iteration 0: 0.0596284802678582
# Converged in iteration 1 with cost 0.0596284802678582 because of step counter
# Final cost : 0.0596284802678582
# Compute control for a deterministic system
# Cost in iteration 0: 0.0596284802678582
# Converged in iteration 1 with cost 0.0596284802678582 because of step counter
# Final cost : 0.0596284802678582
# Compute control for a deterministic system
# Cost in iteration 0: 0.0596284802678582
# Converged in iteration 1 with cost 0.0596284802678582 because of step counter
# Final cost : 0.0596284802678582
# Compute control for a deterministic system
# Cost in iteration 0: 0.12052032342810733
# Final cost : 0.06409879987327399
# Compute control for a deterministic system
# Cost in iteration 0: 0.06409879987327399
# Converged in iteration 9 with cost 0.06409878122219008 because of step counter
# Final cost : 0.06409878122219008
# Compute control for a deterministic system
# Cost in iteration 0: 0.06409878122219008
# Converged in iteration 1 with cost 0.06409878122219008 because of step counter
# Final cost : 0.06409878122219008
# Compute control for a deterministic system
# Cost in iteration 0: 0.06409878122219008
# Converged in iteration 1 with cost 0.06409878122219008 because of step counter
# Final cost : 0.06409878122219008
# Compute control for a deterministic system
# Cost in iteration 0: 0.06409878122219008
# Converged in iteration 1 with cost 0.06409878122219008 because of step counter
# Final cost : 0.06409878122219008
# Compute control for a deterministic system
# Cost in iteration 0: 0.1711697677260902
# Final cost : 0.0701185239075279
# Compute control for a deterministic system
# Cost in iteration 0: 0.0701185239075279
# Converged in iteration 34 with cost 0.0698890613671699 because of step counter
# Final cost : 0.0698890613671699
# Compute control for a deterministic system
# Cost in iteration 0: 0.0698890613671699
# Converged in iteration 1 with cost 0.0698890613671699 because of step counter
# Final cost : 0.0698890613671699
# Compute control for a deterministic system
# Cost in iteration 0: 0.0698890613671699
# Converged in iteration 1 with cost 0.0698890613671699 because of step counter
# Final cost : 0.0698890613671699
# Compute control for a deterministic system
# Cost in iteration 0: 0.0698890613671699
# Converged in iteration 1 with cost 0.0698890613671699 because of step counter
# Final cost : 0.0698890613671699
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.1096126978786147
# Final cost : 0.07685549680345098
# Compute control for a deterministic system
# Cost in iteration 0: 0.07685549680345098
# Final cost : 0.07678751874620313
# Compute control for a deterministic system
# Cost in iteration 0: 0.07678751874620313
# Converged in iteration 4 with cost 0.07678403980155066 because of step counter
# Final cost : 0.07678403980155066
# Compute control for a deterministic system
# Cost in iteration 0: 0.07678403980155066
# Converged in iteration 1 with cost 0.07678403980155066 because of step counter
# Final cost : 0.07678403980155066
# Compute control for a deterministic system
# Cost in iteration 0: 0.07678403980155066
# Converged in iteration 1 with cost 0.07678403980155066 because of step counter
# Final cost : 0.07678403980155066
# Compute control for a deterministic system
# Cost in iteration 0: 0.33492204794269564
# Final cost : 0.08453827207332697
# Compute control for a deterministic system
# Cost in iteration 0: 0.08453827207332697
# Converged in iteration 95 with cost 0.08324242103670326 because of step counter
# Final cost : 0.08324242103670326
# Compute control for a deterministic system
# Cost in iteration 0: 0.08324242103670326
# Converged in iteration 1 with cost 0.08324242103670326 because of step counter
# Final cost : 0.08324242103670326
# Compute control for a deterministic system
# Cost in iteration 0: 0.08324242103670326
# Converged in iteration 1 with cost 0.08324242103670326 because of step counter
# Final cost : 0.08324242103670326
# Compute control for a deterministic system
# Cost in iteration 0: 0.08324242103670326
# Converged in iteration 1 with cost 0.08324242103670326 because of step counter
# Final cost : 0.08324242103670326
# -----------------------------------------------
# 0 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.12633800917028448
# Converged in iteration 172 with cost 0.09173045966140858 because of step counter
# Final cost : 0.09173045966140858
# Compute control for a deterministic system
# Cost in iteration 0: 0.09173045966140858
# Converged in iteration 1 with cost 0.09173045966140858 because of step counter
# Final cost : 0.09173045966140858
# Compute control for a deterministic system
# Cost in iteration 0: 0.09173045966140858
# Converged in iteration 1 with cost 0.09173045966140858 because of step counter
# Final cost : 0.09173045966140858
# Compute control for a deterministic system
# Cost in iteration 0: 0.09173045966140858
# Converged in iteration 1 with cost 0.09173045966140858 because of step counter
# Final cost : 0.09173045966140858
# Compute control for a deterministic system
# Cost in iteration 0: 0.09173045966140858
# Converged in iteration 1 with cost 0.09173045966140858 because of step counter
# Final cost : 0.09173045966140858
# Compute control for a deterministic system
# Cost in iteration 0: 0.11844660783125065
# Final cost : 0.10006483145953596
# Compute control for a deterministic system
# Cost in iteration 0: 0.10006483145953596
# Final cost : 0.09860761322809045
# Compute control for a deterministic system
# Cost in iteration 0: 0.09860761322809045
# Converged in iteration 14 with cost 0.09846188601494717 because of step counter
# Final cost : 0.09846188601494717
# Compute control for a deterministic system
# Cost in iteration 0: 0.09846188601494717
# Converged in iteration 1 with cost 0.09846188601494717 because of step counter
# Final cost : 0.09846188601494717
# Compute control for a deterministic system
# Cost in iteration 0: 0.09846188601494717
# Converged in iteration 1 with cost 0.09846188601494717 because of step counter
# Final cost : 0.09846188601494717
# Compute control for a deterministic system
# Cost in iteration 0: 0.6609779178854532
# Final cost : 0.10844560014757235
# Compute control for a deterministic system
# Cost in iteration 0: 0.10844560014757235
# Final cost : 0.10580500625471978
# Compute control for a deterministic system
# Cost in iteration 0: 0.10580500625471978
# Converged in iteration 44 with cost 0.10560253267490505 because of step counter
# Final cost : 0.10560253267490505
# Compute control for a deterministic system
# Cost in iteration 0: 0.10560253267490505
# Converged in iteration 1 with cost 0.10560253267490505 because of step counter
# Final cost : 0.10560253267490505
# Compute control for a deterministic system
# Cost in iteration 0: 0.10560253267490505
# Converged in iteration 1 with cost 0.10560253267490505 because of step counter
# Final cost : 0.10560253267490505
# Compute control for a deterministic system
# Cost in iteration 0: 0.16948890170146758
# Final cost : 0.11309278970951613
# Compute control for a deterministic system
# Cost in iteration 0: 0.11309278970951613
# Converged in iteration 31 with cost 0.11273859562475674 because of step counter
# Final cost : 0.11273859562475674
# Compute control for a deterministic system
# Cost in iteration 0: 0.11273859562475674
# Converged in iteration 1 with cost 0.11273859562475674 because of step counter
# Final cost : 0.11273859562475674
# Compute control for a deterministic system
# Cost in iteration 0: 0.11273859562475674
# Converged in iteration 1 with cost 0.11273859562475674 because of step counter
# Final cost : 0.11273859562475674
# Compute control for a deterministic system
# Cost in iteration 0: 0.11273859562475674
# Converged in iteration 1 with cost 0.11273859562475674 because of step counter
# Final cost : 0.11273859562475674
# Compute control for a deterministic system
# Cost in iteration 0: 0.37436585696387764
# Final cost : 0.12515236291160295
# Compute control for a deterministic system
# Cost in iteration 0: 0.12515236291160295
# Converged in iteration 147 with cost 0.12269403631465141 because of step counter
# Final cost : 0.12269403631465141
# Compute control for a deterministic system
# Cost in iteration 0: 0.12269403631465141
# Converged in iteration 1 with cost 0.12269403631465141 because of step counter
# Final cost : 0.12269403631465141
# Compute control for a deterministic system
# Cost in iteration 0: 0.12269403631465141
# Converged in iteration 1 with cost 0.12269403631465141 because of step counter
# Final cost : 0.12269403631465141
# Compute control for a deterministic system
# Cost in iteration 0: 0.12269403631465141
# Converged in iteration 1 with cost 0.12269403631465141 because of step counter
# Final cost : 0.12269403631465141
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.33646717305949325
# Final cost : 0.1359461847001773
# Compute control for a deterministic system
# Cost in iteration 0: 0.1359461847001773
# Converged in iteration 117 with cost 0.13344649633154906 because of step counter
# Final cost : 0.13344649633154906
# Compute control for a deterministic system
# Cost in iteration 0: 0.13344649633154906
# Converged in iteration 1 with cost 0.13344649633154906 because of step counter
# Final cost : 0.13344649633154906
# Compute control for a deterministic system
# Cost in iteration 0: 0.13344649633154906
# Converged in iteration 1 with cost 0.13344649633154906 because of step counter
# Final cost : 0.13344649633154906
# Compute control for a deterministic system
# Cost in iteration 0: 0.13344649633154906
# Converged in iteration 1 with cost 0.13344649633154906 because of step counter
# Final cost : 0.13344649633154906
# Compute control for a deterministic system
# Cost in iteration 0: 0.6812303327922706
# Final cost : 0.14958596820557163
# Compute control for a deterministic system
# Cost in iteration 0: 0.14958596820557163
# Final cost : 0.1282424114371593
# Compute control for a deterministic system
# Cost in iteration 0: 0.1282424114371593
# Converged in iteration 28 with cost 0.12666822304083555 because of vanishing difference
# Final cost : 0.12666822304083555
# Compute control for a deterministic system
# Cost in iteration 0: 0.12666822304083555
# Converged in iteration 8 with cost 0.12666822229602975 because of step counter
# Final cost : 0.12666822229602975
# Compute control for a deterministic system
# Cost in iteration 0: 0.12666822229602975
# Converged in iteration 1 with cost 0.12666822229602975 because of step counter
# Final cost : 0.12666822229602975
# Compute control for a deterministic system
# Cost in iteration 0: 0.33014082755848984
# Final cost : 0.11880620511403851
# Compute control for a deterministic system
# Cost in iteration 0: 0.11880620511403851
# Final cost : 0.1169820195281633
# Compute control for a deterministic system
# Cost in iteration 0: 0.1169820195281633
# Converged in iteration 8 with cost 0.11683971843878331 because of step counter
# Final cost : 0.11683971843878331
# Compute control for a deterministic system
# Cost in iteration 0: 0.11683971843878331
# Converged in iteration 1 with cost 0.11683971843878331 because of step counter
# Final cost : 0.11683971843878331
# Compute control for a deterministic system
# Cost in iteration 0: 0.11683971843878331
# Converged in iteration 1 with cost 0.11683971843878331 because of step counter
# Final cost : 0.11683971843878331
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.7555235154440519
# Final cost : 0.11121298247293993
# Compute control for a deterministic system
# Cost in iteration 0: 0.11121298247293993
# Converged in iteration 18 with cost 0.11097718014874874 because of step counter
# Final cost : 0.11097718014874874
# Compute control for a deterministic system
# Cost in iteration 0: 0.11097718014874874
# Converged in iteration 1 with cost 0.11097718014874874 because of step counter
# Final cost : 0.11097718014874874
# Compute control for a deterministic system
# Cost in iteration 0: 0.11097718014874874
# Converged in iteration 1 with cost 0.11097718014874874 because of step counter
# Final cost : 0.11097718014874874
# Compute control for a deterministic system
# Cost in iteration 0: 0.11097718014874874
# Converged in iteration 1 with cost 0.11097718014874874 because of step counter
# Final cost : 0.11097718014874874
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.5008681917615226
# Converged in iteration 172 with cost 0.1057991826134131 because of step counter
# Final cost : 0.1057991826134131
# Compute control for a deterministic system
# Cost in iteration 0: 0.1057991826134131
# Converged in iteration 1 with cost 0.1057991826134131 because of step counter
# Final cost : 0.1057991826134131
# Compute control for a deterministic system
# Cost in iteration 0: 0.1057991826134131
# Converged in iteration 1 with cost 0.1057991826134131 because of step counter
# Final cost : 0.1057991826134131
# Compute control for a deterministic system
# Cost in iteration 0: 0.1057991826134131
# Converged in iteration 1 with cost 0.1057991826134131 because of step counter
# Final cost : 0.1057991826134131
# Compute control for a deterministic system
# Cost in iteration 0: 0.1057991826134131
# Converged in iteration 1 with cost 0.1057991826134131 because of step counter
# Final cost : 0.1057991826134131
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.11443859415314674
# Converged in iteration 48 with cost 0.10105793854940322 because of vanishing difference
# Final cost : 0.10105793854940322
# Compute control for a deterministic system
# Cost in iteration 0: 0.10105793854940322
# Converged in iteration 10 with cost 0.10105793851632078 because of step counter
# Final cost : 0.10105793851632078
# Compute control for a deterministic system
# Cost in iteration 0: 0.10105793851632078
# Converged in iteration 1 with cost 0.10105793851632078 because of step counter
# Final cost : 0.10105793851632078
# Compute control for a deterministic system
# Cost in iteration 0: 0.10105793851632078
# Converged in iteration 1 with cost 0.10105793851632078 because of step counter
# Final cost : 0.10105793851632078
# Compute control for a deterministic system
# Cost in iteration 0: 0.10105793851632078
# Converged in iteration 1 with cost 0.10105793851632078 because of step counter
# Final cost : 0.10105793851632078
# Compute control for a deterministic system
# Cost in iteration 0: 0.2859315560272647
# Converged in iteration 115 with cost 0.09678307922049176 because of step counter
# Final cost : 0.09678307922049176
# Compute control for a deterministic system
# Cost in iteration 0: 0.09678307922049176
# Converged in iteration 1 with cost 0.09678307922049176 because of step counter
# Final cost : 0.09678307922049176
# Compute control for a deterministic system
# Cost in iteration 0: 0.09678307922049176
# Converged in iteration 1 with cost 0.09678307922049176 because of step counter
# Final cost : 0.09678307922049176
# Compute control for a deterministic system
# Cost in iteration 0: 0.09678307922049176
# Converged in iteration 1 with cost 0.09678307922049176 because of step counter
# Final cost : 0.09678307922049176
# Compute control for a deterministic system
# Cost in iteration 0: 0.09678307922049176
# Converged in iteration 1 with cost 0.09678307922049176 because of step counter
# Final cost : 0.09678307922049176
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.37843735281698654
# Final cost : 0.0924514983290751
# Compute control for a deterministic system
# Cost in iteration 0: 0.0924514983290751
# Converged in iteration 21 with cost 0.09239077961092747 because of step counter
# Final cost : 0.09239077961092747
# Compute control for a deterministic system
# Cost in iteration 0: 0.09239077961092747
# Converged in iteration 1 with cost 0.09239077961092747 because of step counter
# Final cost : 0.09239077961092747
# Compute control for a deterministic system
# Cost in iteration 0: 0.09239077961092747
# Converged in iteration 1 with cost 0.09239077961092747 because of step counter
# Final cost : 0.09239077961092747
# Compute control for a deterministic system
# Cost in iteration 0: 0.09239077961092747
# Converged in iteration 1 with cost 0.09239077961092747 because of step counter
# Final cost : 0.09239077961092747
# Compute control for a deterministic system
# Cost in iteration 0: 0.39475148180802117
# Final cost : 0.08710538753061653
# Compute control for a deterministic system
# Cost in iteration 0: 0.08710538753061653
# Converged in iteration 49 with cost 0.08671186528070954 because of step counter
# Final cost : 0.08671186528070954
# Compute control for a deterministic system
# Cost in iteration 0: 0.08671186528070954
# Converged in iteration 1 with cost 0.08671186528070954 because of step counter
# Final cost : 0.08671186528070954
# Compute control for a deterministic system
# Cost in iteration 0: 0.08671186528070954
# Converged in iteration 1 with cost 0.08671186528070954 because of step counter
# Final cost : 0.08671186528070954
# Compute control for a deterministic system
# Cost in iteration 0: 0.08671186528070954
# Converged in iteration 1 with cost 0.08671186528070954 because of step counter
# Final cost : 0.08671186528070954
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.0813780696818814
# Converged in iteration 35 with cost 0.08088182274979329 because of step counter
# Final cost : 0.08088182274979329
# Compute control for a deterministic system
# Cost in iteration 0: 0.08088182274979329
# Converged in iteration 1 with cost 0.08088182274979329 because of step counter
# Final cost : 0.08088182274979329
# Compute control for a deterministic system
# Cost in iteration 0: 0.08088182274979329
# Converged in iteration 1 with cost 0.08088182274979329 because of step counter
# Final cost : 0.08088182274979329
# Compute control for a deterministic system
# Cost in iteration 0: 0.08088182274979329
# Converged in iteration 1 with cost 0.08088182274979329 because of step counter
# Final cost : 0.08088182274979329
# Compute control for a deterministic system
# Cost in iteration 0: 0.08088182274979329
# Converged in iteration 1 with cost 0.08088182274979329 because of step counter
# Final cost : 0.08088182274979329
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.1346601056780488
# Final cost : 0.07698696010147904
# Compute control for a deterministic system
# Cost in iteration 0: 0.07698696010147904
# Converged in iteration 18 with cost 0.07690861032410432 because of step counter
# Final cost : 0.07690861032410432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07690861032410432
# Converged in iteration 1 with cost 0.07690861032410432 because of step counter
# Final cost : 0.07690861032410432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07690861032410432
# Converged in iteration 1 with cost 0.07690861032410432 because of step counter
# Final cost : 0.07690861032410432
# Compute control for a deterministic system
# Cost in iteration 0: 0.07690861032410432
# Converged in iteration 1 with cost 0.07690861032410432 because of step counter
# Final cost : 0.07690861032410432
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.08836256556041423
# Converged in iteration 60 with cost 0.07146436596979287 because of step counter
# Final cost : 0.07146436596979287
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146436596979287
# Converged in iteration 1 with cost 0.07146436596979287 because of step counter
# Final cost : 0.07146436596979287
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146436596979287
# Converged in iteration 1 with cost 0.07146436596979287 because of step counter
# Final cost : 0.07146436596979287
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146436596979287
# Converged in iteration 1 with cost 0.07146436596979287 because of step counter
# Final cost : 0.07146436596979287
# Compute control for a deterministic system
# Cost in iteration 0: 0.07146436596979287
# Converged in iteration 1 with cost 0.07146436596979287 because of step counter
# Final cost : 0.07146436596979287
# Compute control for a deterministic system
# Cost in iteration 0: 0.15677385464310137
# Final cost : 0.0649624614813188
# Compute control for a deterministic system
# Cost in iteration 0: 0.0649624614813188
# Converged in iteration 39 with cost 0.06477051090789797 because of step counter
# Final cost : 0.06477051090789797
# Compute control for a deterministic system
# Cost in iteration 0: 0.06477051090789797
# Converged in iteration 1 with cost 0.06477051090789797 because of step counter
# Final cost : 0.06477051090789797
# Compute control for a deterministic system
# Cost in iteration 0: 0.06477051090789797
# Converged in iteration 1 with cost 0.06477051090789797 because of step counter
# Final cost : 0.06477051090789797
# Compute control for a deterministic system
# Cost in iteration 0: 0.06477051090789797
# Converged in iteration 1 with cost 0.06477051090789797 because of step counter
# Final cost : 0.06477051090789797
# Compute control for a deterministic system
# Cost in iteration 0: 0.07611328425224596
# Converged in iteration 69 with cost 0.058346444029152754 because of step counter
# Final cost : 0.058346444029152754
# Compute control for a deterministic system
# Cost in iteration 0: 0.058346444029152754
# Converged in iteration 1 with cost 0.058346444029152754 because of step counter
# Final cost : 0.058346444029152754
# Compute control for a deterministic system
# Cost in iteration 0: 0.058346444029152754
# Converged in iteration 1 with cost 0.058346444029152754 because of step counter
# Final cost : 0.058346444029152754
# Compute control for a deterministic system
# Cost in iteration 0: 0.058346444029152754
# Converged in iteration 1 with cost 0.058346444029152754 because of step counter
# Final cost : 0.058346444029152754
# Compute control for a deterministic system
# Cost in iteration 0: 0.058346444029152754
# Converged in iteration 1 with cost 0.058346444029152754 because of step counter
# Final cost : 0.058346444029152754
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.46648371525515075
# Final cost : 0.053462925294753806
# Compute control for a deterministic system
# Cost in iteration 0: 0.053462925294753806
# Converged in iteration 34 with cost 0.0531564098674265 because of step counter
# Final cost : 0.0531564098674265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0531564098674265
# Converged in iteration 1 with cost 0.0531564098674265 because of step counter
# Final cost : 0.0531564098674265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0531564098674265
# Converged in iteration 1 with cost 0.0531564098674265 because of step counter
# Final cost : 0.0531564098674265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0531564098674265
# Converged in iteration 1 with cost 0.0531564098674265 because of step counter
# Final cost : 0.0531564098674265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0476449221867957
# Converged in iteration 18 with cost 0.04692630588056791 because of step counter
# Final cost : 0.04692630588056791
# Compute control for a deterministic system
# Cost in iteration 0: 0.04692630588056791
# Converged in iteration 1 with cost 0.04692630588056791 because of step counter
# Final cost : 0.04692630588056791
# Compute control for a deterministic system
# Cost in iteration 0: 0.04692630588056791
# Converged in iteration 1 with cost 0.04692630588056791 because of step counter
# Final cost : 0.04692630588056791
# Compute control for a deterministic system
# Cost in iteration 0: 0.04692630588056791
# Converged in iteration 1 with cost 0.04692630588056791 because of step counter
# Final cost : 0.04692630588056791
# Compute control for a deterministic system
# Cost in iteration 0: 0.04692630588056791
# Converged in iteration 1 with cost 0.04692630588056791 because of step counter
# Final cost : 0.04692630588056791
# -----------------------------------------------
# 0 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.04056956479413492
# Converged in iteration 8 with cost 0.03994091690168645 because of step counter
# Final cost : 0.03994091690168645
# Compute control for a deterministic system
# Cost in iteration 0: 0.03994091690168645
# Converged in iteration 1 with cost 0.03994091690168645 because of step counter
# Final cost : 0.03994091690168645
# Compute control for a deterministic system
# Cost in iteration 0: 0.03994091690168645
# Converged in iteration 1 with cost 0.03994091690168645 because of step counter
# Final cost : 0.03994091690168645
# Compute control for a deterministic system
# Cost in iteration 0: 0.03994091690168645
# Converged in iteration 1 with cost 0.03994091690168645 because of step counter
# Final cost : 0.03994091690168645
# Compute control for a deterministic system
# Cost in iteration 0: 0.03994091690168645
# Converged in iteration 1 with cost 0.03994091690168645 because of step counter
# Final cost : 0.03994091690168645
# -----------------------------------------------
# 0 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.056969524810058715
# Converged in iteration 121 with cost 0.03371692069076924 because of step counter
# Final cost : 0.03371692069076924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03371692069076924
# Converged in iteration 1 with cost 0.03371692069076924 because of step counter
# Final cost : 0.03371692069076924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03371692069076924
# Converged in iteration 1 with cost 0.03371692069076924 because of step counter
# Final cost : 0.03371692069076924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03371692069076924
# Converged in iteration 1 with cost 0.03371692069076924 because of step counter
# Final cost : 0.03371692069076924
# Compute control for a deterministic system
# Cost in iteration 0: 0.03371692069076924
# Converged in iteration 1 with cost 0.03371692069076924 because of step counter
# Final cost : 0.03371692069076924
# Compute control for a deterministic system
# Cost in iteration 0: 0.043239112069872694
# Final cost : 0.02712889379688767
# Compute control for a deterministic system
# Cost in iteration 0: 0.02712889379688767
# Converged in iteration 29 with cost 0.02701315996835237 because of step counter
# Final cost : 0.02701315996835237
# Compute control for a deterministic system
# Cost in iteration 0: 0.02701315996835237
# Converged in iteration 1 with cost 0.02701315996835237 because of step counter
# Final cost : 0.02701315996835237
# Compute control for a deterministic system
# Cost in iteration 0: 0.02701315996835237
# Converged in iteration 1 with cost 0.02701315996835237 because of step counter
# Final cost : 0.02701315996835237
# Compute control for a deterministic system
# Cost in iteration 0: 0.02701315996835237
# Converged in iteration 1 with cost 0.02701315996835237 because of step counter
# Final cost : 0.02701315996835237
# Compute control for a deterministic system
# Cost in iteration 0: 0.0634951198381933
# Final cost : 0.021239200275662146
# Compute control for a deterministic system
# Cost in iteration 0: 0.021239200275662146
# Converged in iteration 20 with cost 0.02120281107756122 because of step counter
# Final cost : 0.02120281107756122
# Compute control for a deterministic system
# Cost in iteration 0: 0.02120281107756122
# Converged in iteration 1 with cost 0.02120281107756122 because of step counter
# Final cost : 0.02120281107756122
# Compute control for a deterministic system
# Cost in iteration 0: 0.02120281107756122
# Converged in iteration 1 with cost 0.02120281107756122 because of step counter
# Final cost : 0.02120281107756122
# Compute control for a deterministic system
# Cost in iteration 0: 0.02120281107756122
# Converged in iteration 1 with cost 0.02120281107756122 because of step counter
# Final cost : 0.02120281107756122
# Compute control for a deterministic system
# Cost in iteration 0: 0.03208561352834388
# Converged in iteration 168 with cost 0.013805431335258696 because of step counter
# Final cost : 0.013805431335258696
# Compute control for a deterministic system
# Cost in iteration 0: 0.013805431335258696
# Converged in iteration 1 with cost 0.013805431335258696 because of step counter
# Final cost : 0.013805431335258696
# Compute control for a deterministic system
# Cost in iteration 0: 0.013805431335258696
# Converged in iteration 1 with cost 0.013805431335258696 because of step counter
# Final cost : 0.013805431335258696
# Compute control for a deterministic system
# Cost in iteration 0: 0.013805431335258696
# Converged in iteration 1 with cost 0.013805431335258696 because of step counter
# Final cost : 0.013805431335258696
# Compute control for a deterministic system
# Cost in iteration 0: 0.013805431335258696
# Converged in iteration 1 with cost 0.013805431335258696 because of step counter
# Final cost : 0.013805431335258696
# Compute control for a deterministic system
# Cost in iteration 0: 0.04565427309351394
# Final cost : 0.006536539026094359
# Compute control for a deterministic system
# Cost in iteration 0: 0.006536539026094359
# Converged in iteration 26 with cost 0.006513460451862047 because of step counter
# Final cost : 0.006513460451862047
# Compute control for a deterministic system
# Cost in iteration 0: 0.006513460451862047
# Converged in iteration 1 with cost 0.006513460451862047 because of step counter
# Final cost : 0.006513460451862047
# Compute control for a deterministic system
# Cost in iteration 0: 0.006513460451862047
# Converged in iteration 1 with cost 0.006513460451862047 because of step counter
# Final cost : 0.006513460451862047
# Compute control for a deterministic system
# Cost in iteration 0: 0.006513460451862047
# Converged in iteration 1 with cost 0.006513460451862047 because of step counter
# Final cost : 0.006513460451862047
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.09135043508713861
# Converged in iteration 14 with cost 0.013549992104935522 because of step counter
# Final cost : 0.013549992104935522
# Compute control for a deterministic system
# Cost in iteration 0: 0.013549992104935522
# Converged in iteration 1 with cost 0.013549992104935522 because of step counter
# Final cost : 0.013549992104935522
# Compute control for a deterministic system
# Cost in iteration 0: 0.013549992104935522
# Converged in iteration 1 with cost 0.013549992104935522 because of step counter
# Final cost : 0.013549992104935522
# Compute control for a deterministic system
# Cost in iteration 0: 0.013549992104935522
# Converged in iteration 1 with cost 0.013549992104935522 because of step counter
# Final cost : 0.013549992104935522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0737004258166806
# Converged in iteration 18 with cost 0.020890559327213846 because of step counter
# Final cost : 0.020890559327213846
# Compute control for a deterministic system
# Cost in iteration 0: 0.020890559327213846
# Converged in iteration 1 with cost 0.020890559327213846 because of step counter
# Final cost : 0.020890559327213846
# Compute control for a deterministic system
# Cost in iteration 0: 0.020890559327213846
# Converged in iteration 1 with cost 0.020890559327213846 because of step counter
# Final cost : 0.020890559327213846
# Compute control for a deterministic system
# Cost in iteration 0: 0.020890559327213846
# Converged in iteration 1 with cost 0.020890559327213846 because of step counter
# Final cost : 0.020890559327213846
# Compute control for a deterministic system
# Cost in iteration 0: 0.03863439702372272
# Converged in iteration 24 with cost 0.026717688663815145 because of step counter
# Final cost : 0.026717688663815145
# Compute control for a deterministic system
# Cost in iteration 0: 0.026717688663815145
# Converged in iteration 1 with cost 0.026717688663815145 because of step counter
# Final cost : 0.026717688663815145
# Compute control for a deterministic system
# Cost in iteration 0: 0.026717688663815145
# Converged in iteration 1 with cost 0.026717688663815145 because of step counter
# Final cost : 0.026717688663815145
# Compute control for a deterministic system
# Cost in iteration 0: 0.026717688663815145
# Converged in iteration 1 with cost 0.026717688663815145 because of step counter
# Final cost : 0.026717688663815145
# Compute control for a deterministic system
# Cost in iteration 0: 0.20858731719060986
# Converged in iteration 16 with cost 0.034210996376822025 because of vanishing difference
# Final cost : 0.034210996376822025
# Compute control for a deterministic system
# Cost in iteration 0: 0.034210996376822025
# Converged in iteration 9 with cost 0.034210996334006614 because of step counter
# Final cost : 0.034210996334006614
# Compute control for a deterministic system
# Cost in iteration 0: 0.034210996334006614
# Converged in iteration 1 with cost 0.034210996334006614 because of step counter
# Final cost : 0.034210996334006614
# Compute control for a deterministic system
# Cost in iteration 0: 0.034210996334006614
# Converged in iteration 1 with cost 0.034210996334006614 because of step counter
# Final cost : 0.034210996334006614
# Compute control for a deterministic system
# Cost in iteration 0: 0.0714626961888867
# Converged in iteration 6 with cost 0.040037282860793645 because of step counter
# Final cost : 0.040037282860793645
# Compute control for a deterministic system
# Cost in iteration 0: 0.040037282860793645
# Converged in iteration 1 with cost 0.040037282860793645 because of step counter
# Final cost : 0.040037282860793645
# Compute control for a deterministic system
# Cost in iteration 0: 0.040037282860793645
# Converged in iteration 1 with cost 0.040037282860793645 because of step counter
# Final cost : 0.040037282860793645
# Compute control for a deterministic system
# Cost in iteration 0: 0.040037282860793645
# Converged in iteration 1 with cost 0.040037282860793645 because of step counter
# Final cost : 0.040037282860793645
# Compute control for a deterministic system
# Cost in iteration 0: 0.07551116325145851
# Converged in iteration 10 with cost 0.046821700405195045 because of step counter
# Final cost : 0.046821700405195045
# Compute control for a deterministic system
# Cost in iteration 0: 0.046821700405195045
# Converged in iteration 1 with cost 0.046821700405195045 because of step counter
# Final cost : 0.046821700405195045
# Compute control for a deterministic system
# Cost in iteration 0: 0.046821700405195045
# Converged in iteration 1 with cost 0.046821700405195045 because of step counter
# Final cost : 0.046821700405195045
# Compute control for a deterministic system
# Cost in iteration 0: 0.046821700405195045
# Converged in iteration 1 with cost 0.046821700405195045 because of step counter
# Final cost : 0.046821700405195045
# -----------------------------------------------
# 1 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.12261194813201992
# Converged in iteration 31 with cost 0.052451994725637385 because of step counter
# Final cost : 0.052451994725637385
# Compute control for a deterministic system
# Cost in iteration 0: 0.052451994725637385
# Converged in iteration 1 with cost 0.052451994725637385 because of step counter
# Final cost : 0.052451994725637385
# Compute control for a deterministic system
# Cost in iteration 0: 0.052451994725637385
# Converged in iteration 1 with cost 0.052451994725637385 because of step counter
# Final cost : 0.052451994725637385
# Compute control for a deterministic system
# Cost in iteration 0: 0.052451994725637385
# Converged in iteration 1 with cost 0.052451994725637385 because of step counter
# Final cost : 0.052451994725637385
# -----------------------------------------------
# 1 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.12677528546867178
# Converged in iteration 9 with cost 0.059560947159415796 because of step counter
# Final cost : 0.059560947159415796
# Compute control for a deterministic system
# Cost in iteration 0: 0.059560947159415796
# Converged in iteration 1 with cost 0.059560947159415796 because of step counter
# Final cost : 0.059560947159415796
# Compute control for a deterministic system
# Cost in iteration 0: 0.059560947159415796
# Converged in iteration 1 with cost 0.059560947159415796 because of step counter
# Final cost : 0.059560947159415796
# Compute control for a deterministic system
# Cost in iteration 0: 0.059560947159415796
# Converged in iteration 1 with cost 0.059560947159415796 because of step counter
# Final cost : 0.059560947159415796
# Compute control for a deterministic system
# Cost in iteration 0: 0.09595024236294812
# Converged in iteration 39 with cost 0.06489962305639665 because of step counter
# Final cost : 0.06489962305639665
# Compute control for a deterministic system
# Cost in iteration 0: 0.06489962305639665
# Converged in iteration 1 with cost 0.06489962305639665 because of step counter
# Final cost : 0.06489962305639665
# Compute control for a deterministic system
# Cost in iteration 0: 0.06489962305639665
# Converged in iteration 1 with cost 0.06489962305639665 because of step counter
# Final cost : 0.06489962305639665
# Compute control for a deterministic system
# Cost in iteration 0: 0.06489962305639665
# Converged in iteration 1 with cost 0.06489962305639665 because of step counter
# Final cost : 0.06489962305639665
# Compute control for a deterministic system
# Cost in iteration 0: 0.46299142434655527
# Converged in iteration 22 with cost 0.07500732702725221 because of vanishing difference
# Final cost : 0.07500732702725221
# Compute control for a deterministic system
# Cost in iteration 0: 0.07500732702725221
# Converged in iteration 38 with cost 0.07500732668752652 because of step counter
# Final cost : 0.07500732668752652
# Compute control for a deterministic system
# Cost in iteration 0: 0.07500732668752652
# Converged in iteration 1 with cost 0.07500732668752652 because of step counter
# Final cost : 0.07500732668752652
# Compute control for a deterministic system
# Cost in iteration 0: 0.07500732668752652
# Converged in iteration 1 with cost 0.07500732668752652 because of step counter
# Final cost : 0.07500732668752652
# Compute control for a deterministic system
# Cost in iteration 0: 0.29811887823236805
# Converged in iteration 9 with cost 0.07719326350034808 because of step counter
# Final cost : 0.07719326350034808
# Compute control for a deterministic system
# Cost in iteration 0: 0.07719326350034808
# Converged in iteration 1 with cost 0.07719326350034808 because of step counter
# Final cost : 0.07719326350034808
# Compute control for a deterministic system
# Cost in iteration 0: 0.07719326350034808
# Converged in iteration 1 with cost 0.07719326350034808 because of step counter
# Final cost : 0.07719326350034808
# Compute control for a deterministic system
# Cost in iteration 0: 0.07719326350034808
# Converged in iteration 1 with cost 0.07719326350034808 because of step counter
# Final cost : 0.07719326350034808
# Compute control for a deterministic system
# Cost in iteration 0: 0.264801906452206
# Converged in iteration 36 with cost 0.08202933161968082 because of step counter
# Final cost : 0.08202933161968082
# Compute control for a deterministic system
# Cost in iteration 0: 0.08202933161968082
# Converged in iteration 1 with cost 0.08202933161968082 because of step counter
# Final cost : 0.08202933161968082
# Compute control for a deterministic system
# Cost in iteration 0: 0.08202933161968082
# Converged in iteration 1 with cost 0.08202933161968082 because of step counter
# Final cost : 0.08202933161968082
# Compute control for a deterministic system
# Cost in iteration 0: 0.08202933161968082
# Converged in iteration 1 with cost 0.08202933161968082 because of step counter
# Final cost : 0.08202933161968082
# Compute control for a deterministic system
# Cost in iteration 0: 0.09685087377498694
# Converged in iteration 17 with cost 0.0863794594708782 because of step counter
# Final cost : 0.0863794594708782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0863794594708782
# Converged in iteration 1 with cost 0.0863794594708782 because of step counter
# Final cost : 0.0863794594708782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0863794594708782
# Converged in iteration 1 with cost 0.0863794594708782 because of step counter
# Final cost : 0.0863794594708782
# Compute control for a deterministic system
# Cost in iteration 0: 0.0863794594708782
# Converged in iteration 1 with cost 0.0863794594708782 because of step counter
# Final cost : 0.0863794594708782
# -----------------------------------------------
# 1 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.1707787749567555
# Converged in iteration 5 with cost 0.09230797536948127 because of step counter
# Final cost : 0.09230797536948127
# Compute control for a deterministic system
# Cost in iteration 0: 0.09230797536948127
# Converged in iteration 1 with cost 0.09230797536948127 because of step counter
# Final cost : 0.09230797536948127
# Compute control for a deterministic system
# Cost in iteration 0: 0.09230797536948127
# Converged in iteration 1 with cost 0.09230797536948127 because of step counter
# Final cost : 0.09230797536948127
# Compute control for a deterministic system
# Cost in iteration 0: 0.09230797536948127
# Converged in iteration 1 with cost 0.09230797536948127 because of step counter
# Final cost : 0.09230797536948127
# Compute control for a deterministic system
# Cost in iteration 0: 0.11825185903675642
# Converged in iteration 3 with cost 0.09833941100490759 because of step counter
# Final cost : 0.09833941100490759
# Compute control for a deterministic system
# ...
# Final cost : 1.5500170190689475
# Compute control for a deterministic system
# Cost in iteration 0: 1.4819569842299478
# Converged in iteration 1 with cost 1.4819569842299478 because of step counter
# Final cost : 1.4819569842299478
# Compute control for a deterministic system
# Cost in iteration 0: 1.4819569842299478
# Converged in iteration 1 with cost 1.4819569842299478 because of step counter
# Final cost : 1.4819569842299478
# Compute control for a deterministic system
# Cost in iteration 0: 1.4819569842299478
# Converged in iteration 1 with cost 1.4819569842299478 because of step counter
# Final cost : 1.4819569842299478
# Compute control for a deterministic system
# Cost in iteration 0: 1.4819569842299478
# Converged in iteration 1 with cost 1.4819569842299478 because of step counter
# Final cost : 1.4819569842299478
# Compute control for a deterministic system
# Cost in iteration 0: 1.4819569842299478
# Converged in iteration 1 with cost 1.4819569842299478 because of step counter
# Final cost : 1.4819569842299478
# Compute control for a deterministic system
# Cost in iteration 0: 1.3951009780948125
# Converged in iteration 1 with cost 1.3951009780948125 because of step counter
# Final cost : 1.3951009780948125
# Compute control for a deterministic system
# Cost in iteration 0: 1.3951009780948125
# Converged in iteration 1 with cost 1.3951009780948125 because of step counter
# Final cost : 1.3951009780948125
# Compute control for a deterministic system
# Cost in iteration 0: 1.3951009780948125
# Converged in iteration 1 with cost 1.3951009780948125 because of step counter
# Final cost : 1.3951009780948125
# Compute control for a deterministic system
# Cost in iteration 0: 1.3951009780948125
# Converged in iteration 1 with cost 1.3951009780948125 because of step counter
# Final cost : 1.3951009780948125
# Compute control for a deterministic system
# Cost in iteration 0: 1.3951009780948125
# Converged in iteration 1 with cost 1.3951009780948125 because of step counter
# Final cost : 1.3951009780948125
# Compute control for a deterministic system
# Cost in iteration 0: 1.3061670238034913
# Converged in iteration 1 with cost 1.3061670238034913 because of step counter
# Final cost : 1.3061670238034913
# Compute control for a deterministic system
# Cost in iteration 0: 1.3061670238034913
# Converged in iteration 1 with cost 1.3061670238034913 because of step counter
# Final cost : 1.3061670238034913
# Compute control for a deterministic system
# Cost in iteration 0: 1.3061670238034913
# Converged in iteration 1 with cost 1.3061670238034913 because of step counter
# Final cost : 1.3061670238034913
# Compute control for a deterministic system
# Cost in iteration 0: 1.3061670238034913
# Converged in iteration 1 with cost 1.3061670238034913 because of step counter
# Final cost : 1.3061670238034913
# Compute control for a deterministic system
# Cost in iteration 0: 1.3061670238034913
# Converged in iteration 1 with cost 1.3061670238034913 because of step counter
# Final cost : 1.3061670238034913
# Compute control for a deterministic system
# Cost in iteration 0: 1.199823262875232
# Converged in iteration 1 with cost 1.199823262875232 because of step counter
# Final cost : 1.199823262875232
# Compute control for a deterministic system
# Cost in iteration 0: 1.199823262875232
# Converged in iteration 1 with cost 1.199823262875232 because of step counter
# Final cost : 1.199823262875232
# Compute control for a deterministic system
# Cost in iteration 0: 1.199823262875232
# Converged in iteration 1 with cost 1.199823262875232 because of step counter
# Final cost : 1.199823262875232
# Compute control for a deterministic system
# Cost in iteration 0: 1.199823262875232
# Converged in iteration 1 with cost 1.199823262875232 because of step counter
# Final cost : 1.199823262875232
# Compute control for a deterministic system
# Cost in iteration 0: 1.199823262875232
# Converged in iteration 1 with cost 1.199823262875232 because of step counter
# Final cost : 1.199823262875232
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 1.1126082157896007
# Converged in iteration 1 with cost 1.1126082157896007 because of step counter
# Final cost : 1.1126082157896007
# Compute control for a deterministic system
# Cost in iteration 0: 1.1126082157896007
# Converged in iteration 1 with cost 1.1126082157896007 because of step counter
# Final cost : 1.1126082157896007
# Compute control for a deterministic system
# Cost in iteration 0: 1.1126082157896007
# Converged in iteration 1 with cost 1.1126082157896007 because of step counter
# Final cost : 1.1126082157896007
# Compute control for a deterministic system
# Cost in iteration 0: 1.1126082157896007
# Converged in iteration 1 with cost 1.1126082157896007 because of step counter
# Final cost : 1.1126082157896007
# Compute control for a deterministic system
# Cost in iteration 0: 1.1126082157896007
# Converged in iteration 1 with cost 1.1126082157896007 because of step counter
# Final cost : 1.1126082157896007
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135065450287468
# Converged in iteration 1 with cost 1.0135065450287468 because of step counter
# Final cost : 1.0135065450287468
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135065450287468
# Converged in iteration 1 with cost 1.0135065450287468 because of step counter
# Final cost : 1.0135065450287468
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135065450287468
# Converged in iteration 1 with cost 1.0135065450287468 because of step counter
# Final cost : 1.0135065450287468
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135065450287468
# Converged in iteration 1 with cost 1.0135065450287468 because of step counter
# Final cost : 1.0135065450287468
# Compute control for a deterministic system
# Cost in iteration 0: 1.0135065450287468
# Converged in iteration 1 with cost 1.0135065450287468 because of step counter
# Final cost : 1.0135065450287468
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.9188290808279108
# Converged in iteration 1 with cost 0.9188290808279108 because of step counter
# Final cost : 0.9188290808279108
# Compute control for a deterministic system
# Cost in iteration 0: 0.9188290808279108
# Converged in iteration 1 with cost 0.9188290808279108 because of step counter
# Final cost : 0.9188290808279108
# Compute control for a deterministic system
# Cost in iteration 0: 0.9188290808279108
# Converged in iteration 1 with cost 0.9188290808279108 because of step counter
# Final cost : 0.9188290808279108
# Compute control for a deterministic system
# Cost in iteration 0: 0.9188290808279108
# Converged in iteration 1 with cost 0.9188290808279108 because of step counter
# Final cost : 0.9188290808279108
# Compute control for a deterministic system
# Cost in iteration 0: 0.9188290808279108
# Converged in iteration 1 with cost 0.9188290808279108 because of step counter
# Final cost : 0.9188290808279108
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.8267437860906732
# Converged in iteration 1 with cost 0.8267437860906732 because of step counter
# Final cost : 0.8267437860906732
# Compute control for a deterministic system
# Cost in iteration 0: 0.8267437860906732
# Converged in iteration 1 with cost 0.8267437860906732 because of step counter
# Final cost : 0.8267437860906732
# Compute control for a deterministic system
# Cost in iteration 0: 0.8267437860906732
# Converged in iteration 1 with cost 0.8267437860906732 because of step counter
# Final cost : 0.8267437860906732
# Compute control for a deterministic system
# Cost in iteration 0: 0.8267437860906732
# Converged in iteration 1 with cost 0.8267437860906732 because of step counter
# Final cost : 0.8267437860906732
# Compute control for a deterministic system
# Cost in iteration 0: 0.8267437860906732
# Converged in iteration 1 with cost 0.8267437860906732 because of step counter
# Final cost : 0.8267437860906732
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348168557307349
# Converged in iteration 1 with cost 0.7348168557307349 because of step counter
# Final cost : 0.7348168557307349
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348168557307349
# Converged in iteration 1 with cost 0.7348168557307349 because of step counter
# Final cost : 0.7348168557307349
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348168557307349
# Converged in iteration 1 with cost 0.7348168557307349 because of step counter
# Final cost : 0.7348168557307349
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348168557307349
# Converged in iteration 1 with cost 0.7348168557307349 because of step counter
# Final cost : 0.7348168557307349
# Compute control for a deterministic system
# Cost in iteration 0: 0.7348168557307349
# Converged in iteration 1 with cost 0.7348168557307349 because of step counter
# Final cost : 0.7348168557307349
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.658110517441715
# Converged in iteration 1 with cost 0.658110517441715 because of step counter
# Final cost : 0.658110517441715
# Compute control for a deterministic system
# Cost in iteration 0: 0.658110517441715
# Converged in iteration 1 with cost 0.658110517441715 because of step counter
# Final cost : 0.658110517441715
# Compute control for a deterministic system
# Cost in iteration 0: 0.658110517441715
# Converged in iteration 1 with cost 0.658110517441715 because of step counter
# Final cost : 0.658110517441715
# Compute control for a deterministic system
# Cost in iteration 0: 0.658110517441715
# Converged in iteration 1 with cost 0.658110517441715 because of step counter
# Final cost : 0.658110517441715
# Compute control for a deterministic system
# Cost in iteration 0: 0.658110517441715
# Converged in iteration 1 with cost 0.658110517441715 because of step counter
# Final cost : 0.658110517441715
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514871947227981
# Converged in iteration 1 with cost 0.5514871947227981 because of step counter
# Final cost : 0.5514871947227981
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514871947227981
# Converged in iteration 1 with cost 0.5514871947227981 because of step counter
# Final cost : 0.5514871947227981
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514871947227981
# Converged in iteration 1 with cost 0.5514871947227981 because of step counter
# Final cost : 0.5514871947227981
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514871947227981
# Converged in iteration 1 with cost 0.5514871947227981 because of step counter
# Final cost : 0.5514871947227981
# Compute control for a deterministic system
# Cost in iteration 0: 0.5514871947227981
# Converged in iteration 1 with cost 0.5514871947227981 because of step counter
# Final cost : 0.5514871947227981
# Compute control for a deterministic system
# Cost in iteration 0: 0.4446341950699107
# Converged in iteration 1 with cost 0.4446341950699107 because of step counter
# Final cost : 0.4446341950699107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4446341950699107
# Converged in iteration 1 with cost 0.4446341950699107 because of step counter
# Final cost : 0.4446341950699107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4446341950699107
# Converged in iteration 1 with cost 0.4446341950699107 because of step counter
# Final cost : 0.4446341950699107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4446341950699107
# Converged in iteration 1 with cost 0.4446341950699107 because of step counter
# Final cost : 0.4446341950699107
# Compute control for a deterministic system
# Cost in iteration 0: 0.4446341950699107
# Converged in iteration 1 with cost 0.4446341950699107 because of step counter
# Final cost : 0.4446341950699107
# Compute control for a deterministic system
# Cost in iteration 0: 0.33827918196476725
# Converged in iteration 1 with cost 0.33827918196476725 because of step counter
# Final cost : 0.33827918196476725
# Compute control for a deterministic system
# Cost in iteration 0: 0.33827918196476725
# Converged in iteration 1 with cost 0.33827918196476725 because of step counter
# Final cost : 0.33827918196476725
# Compute control for a deterministic system
# Cost in iteration 0: 0.33827918196476725
# Converged in iteration 1 with cost 0.33827918196476725 because of step counter
# Final cost : 0.33827918196476725
# Compute control for a deterministic system
# Cost in iteration 0: 0.33827918196476725
# Converged in iteration 1 with cost 0.33827918196476725 because of step counter
# Final cost : 0.33827918196476725
# Compute control for a deterministic system
# Cost in iteration 0: 0.33827918196476725
# Converged in iteration 1 with cost 0.33827918196476725 because of step counter
# Final cost : 0.33827918196476725
# Compute control for a deterministic system
# Cost in iteration 0: 0.25425382485168585
# Converged in iteration 1 with cost 0.25425382485168585 because of step counter
# Final cost : 0.25425382485168585
# Compute control for a deterministic system
# Cost in iteration 0: 0.25425382485168585
# Converged in iteration 1 with cost 0.25425382485168585 because of step counter
# Final cost : 0.25425382485168585
# Compute control for a deterministic system
# Cost in iteration 0: 0.25425382485168585
# Converged in iteration 1 with cost 0.25425382485168585 because of step counter
# Final cost : 0.25425382485168585
# Compute control for a deterministic system
# Cost in iteration 0: 0.25425382485168585
# Converged in iteration 1 with cost 0.25425382485168585 because of step counter
# Final cost : 0.25425382485168585
# Compute control for a deterministic system
# Cost in iteration 0: 0.25425382485168585
# Converged in iteration 1 with cost 0.25425382485168585 because of step counter
# Final cost : 0.25425382485168585
# Compute control for a deterministic system
# Cost in iteration 0: 0.15184121545762483
# Converged in iteration 1 with cost 0.15184121545762483 because of step counter
# Final cost : 0.15184121545762483
# Compute control for a deterministic system
# Cost in iteration 0: 0.15184121545762483
# Converged in iteration 1 with cost 0.15184121545762483 because of step counter
# Final cost : 0.15184121545762483
# Compute control for a deterministic system
# Cost in iteration 0: 0.15184121545762483
# Converged in iteration 1 with cost 0.15184121545762483 because of step counter
# Final cost : 0.15184121545762483
# Compute control for a deterministic system
# Cost in iteration 0: 0.15184121545762483
# Converged in iteration 1 with cost 0.15184121545762483 because of step counter
# Final cost : 0.15184121545762483
# Compute control for a deterministic system
# Cost in iteration 0: 0.15184121545762483
# Converged in iteration 1 with cost 0.15184121545762483 because of step counter
# Final cost : 0.15184121545762483
# Compute control for a deterministic system
# Cost in iteration 0: 0.05339048271033624
# Converged in iteration 1 with cost 0.05339048271033624 because of step counter
# Final cost : 0.05339048271033624
# Compute control for a deterministic system
# Cost in iteration 0: 0.05339048271033624
# Converged in iteration 1 with cost 0.05339048271033624 because of step counter
# Final cost : 0.05339048271033624
# Compute control for a deterministic system
# Cost in iteration 0: 0.05339048271033624
# Converged in iteration 1 with cost 0.05339048271033624 because of step counter
# Final cost : 0.05339048271033624
# Compute control for a deterministic system
# Cost in iteration 0: 0.05339048271033624
# Converged in iteration 1 with cost 0.05339048271033624 because of step counter
# Final cost : 0.05339048271033624
# Compute control for a deterministic system
# Cost in iteration 0: 0.05339048271033624
# Converged in iteration 1 with cost 0.05339048271033624 because of step counter
# Final cost : 0.05339048271033624

# %%
save(results_min)
