# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,77], wc.inh[0,77]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [ 191  400  608  816 1024 1232 1441 1649 1857 2065 2273 2482 2690 2898]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
#results_min = readfile("results_min_w1.pickle")

ind_list = range(41)
#options = [True, True, True, True, True, True, True, False]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.01
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05557455076426303
# Cost in iteration 200: 0.0053173098454471135
# Final cost : 0.0053173098454471135
# Compute control for a deterministic system
# Cost in iteration 0: 0.0053173098454471135
# Converged in iteration 6 with cost 0.005310136654462337 because of step counter
# Final cost : 0.005310136654462337
# Compute control for a deterministic system
# Cost in iteration 0: 0.005310136654462337
# Converged in iteration 1 with cost 0.005310136654462337 because of step counter
# Final cost : 0.005310136654462337
# Compute control for a deterministic system
# Cost in iteration 0: 0.005310136654462337
# Converged in iteration 1 with cost 0.005310136654462337 because of step counter
# Final cost : 0.005310136654462337
# Compute control for a deterministic system
# Cost in iteration 0: 0.005310136654462337
# Converged in iteration 1 with cost 0.005310136654462337 because of step counter
# Final cost : 0.005310136654462337
# Compute control for a deterministic system
# Cost in iteration 0: 0.07633557646708732
# Converged in iteration 51 with cost 0.008166397304396163 because of step counter
# Final cost : 0.008166397304396163
# Compute control for a deterministic system
# Cost in iteration 0: 0.008166397304396163
# Converged in iteration 1 with cost 0.008166397304396163 because of step counter
# Final cost : 0.008166397304396163
# Compute control for a deterministic system
# Cost in iteration 0: 0.008166397304396163
# Converged in iteration 1 with cost 0.008166397304396163 because of step counter
# Final cost : 0.008166397304396163
# Compute control for a deterministic system
# Cost in iteration 0: 0.008166397304396163
# Converged in iteration 1 with cost 0.008166397304396163 because of step counter
# Final cost : 0.008166397304396163
# Compute control for a deterministic system
# Cost in iteration 0: 0.008166397304396163
# Converged in iteration 1 with cost 0.008166397304396163 because of step counter
# Final cost : 0.008166397304396163
# Compute control for a deterministic system
# Cost in iteration 0: 0.05004807221293246
# Converged in iteration 8 with cost 0.01021842868778655 because of step counter
# Final cost : 0.01021842868778655
# Compute control for a deterministic system
# Cost in iteration 0: 0.01021842868778655
# Converged in iteration 1 with cost 0.01021842868778655 because of step counter
# Final cost : 0.01021842868778655
# Compute control for a deterministic system
# Cost in iteration 0: 0.01021842868778655
# Converged in iteration 1 with cost 0.01021842868778655 because of step counter
# Final cost : 0.01021842868778655
# Compute control for a deterministic system
# Cost in iteration 0: 0.01021842868778655
# Converged in iteration 1 with cost 0.01021842868778655 because of step counter
# Final cost : 0.01021842868778655
# Compute control for a deterministic system
# Cost in iteration 0: 0.01021842868778655
# Converged in iteration 1 with cost 0.01021842868778655 because of step counter
# Final cost : 0.01021842868778655
# Compute control for a deterministic system
# Cost in iteration 0: 0.043145530281319566
# Converged in iteration 4 with cost 0.011840854247965367 because of step counter
# Final cost : 0.011840854247965367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011840854247965367
# Converged in iteration 1 with cost 0.011840854247965367 because of step counter
# Final cost : 0.011840854247965367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011840854247965367
# Converged in iteration 1 with cost 0.011840854247965367 because of step counter
# Final cost : 0.011840854247965367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011840854247965367
# Converged in iteration 1 with cost 0.011840854247965367 because of step counter
# Final cost : 0.011840854247965367
# Compute control for a deterministic system
# Cost in iteration 0: 0.011840854247965367
# Converged in iteration 1 with cost 0.011840854247965367 because of step counter
# Final cost : 0.011840854247965367
# Compute control for a deterministic system
# Cost in iteration 0: 0.038660732721503166
# Converged in iteration 7 with cost 0.013357869792531325 because of step counter
# Final cost : 0.013357869792531325
# Compute control for a deterministic system
# Cost in iteration 0: 0.013357869792531325
# Converged in iteration 1 with cost 0.013357869792531325 because of step counter
# Final cost : 0.013357869792531325
# Compute control for a deterministic system
# Cost in iteration 0: 0.013357869792531325
# Converged in iteration 1 with cost 0.013357869792531325 because of step counter
# Final cost : 0.013357869792531325
# Compute control for a deterministic system
# Cost in iteration 0: 0.013357869792531325
# Converged in iteration 1 with cost 0.013357869792531325 because of step counter
# Final cost : 0.013357869792531325
# Compute control for a deterministic system
# Cost in iteration 0: 0.013357869792531325
# Converged in iteration 1 with cost 0.013357869792531325 because of step counter
# Final cost : 0.013357869792531325
# Compute control for a deterministic system
# Cost in iteration 0: 0.03724379536043685
# Converged in iteration 10 with cost 0.014996475979244663 because of step counter
# Final cost : 0.014996475979244663
# Compute control for a deterministic system
# Cost in iteration 0: 0.014996475979244663
# Converged in iteration 1 with cost 0.014996475979244663 because of step counter
# Final cost : 0.014996475979244663
# Compute control for a deterministic system
# Cost in iteration 0: 0.014996475979244663
# Converged in iteration 1 with cost 0.014996475979244663 because of step counter
# Final cost : 0.014996475979244663
# Compute control for a deterministic system
# Cost in iteration 0: 0.014996475979244663
# Converged in iteration 1 with cost 0.014996475979244663 because of step counter
# Final cost : 0.014996475979244663
# Compute control for a deterministic system
# Cost in iteration 0: 0.014996475979244663
# Converged in iteration 1 with cost 0.014996475979244663 because of step counter
# Final cost : 0.014996475979244663
# Compute control for a deterministic system
# Cost in iteration 0: 0.05586176699333843
# Converged in iteration 72 with cost 0.017052476968030174 because of step counter
# Final cost : 0.017052476968030174
# Compute control for a deterministic system
# Cost in iteration 0: 0.017052476968030174
# Converged in iteration 1 with cost 0.017052476968030174 because of step counter
# Final cost : 0.017052476968030174
# Compute control for a deterministic system
# Cost in iteration 0: 0.017052476968030174
# Converged in iteration 1 with cost 0.017052476968030174 because of step counter
# Final cost : 0.017052476968030174
# Compute control for a deterministic system
# Cost in iteration 0: 0.017052476968030174
# Converged in iteration 1 with cost 0.017052476968030174 because of step counter
# Final cost : 0.017052476968030174
# Compute control for a deterministic system
# Cost in iteration 0: 0.017052476968030174
# Converged in iteration 1 with cost 0.017052476968030174 because of step counter
# Final cost : 0.017052476968030174
# Compute control for a deterministic system
# Cost in iteration 0: 0.04180543730220235
# Converged in iteration 113 with cost 0.01833528846286212 because of step counter
# Final cost : 0.01833528846286212
# Compute control for a deterministic system
# Cost in iteration 0: 0.01833528846286212
# Converged in iteration 1 with cost 0.01833528846286212 because of step counter
# Final cost : 0.01833528846286212
# Compute control for a deterministic system
# Cost in iteration 0: 0.01833528846286212
# Converged in iteration 1 with cost 0.01833528846286212 because of step counter
# Final cost : 0.01833528846286212
# Compute control for a deterministic system
# Cost in iteration 0: 0.01833528846286212
# Converged in iteration 1 with cost 0.01833528846286212 because of step counter
# Final cost : 0.01833528846286212
# Compute control for a deterministic system
# Cost in iteration 0: 0.01833528846286212
# Converged in iteration 1 with cost 0.01833528846286212 because of step counter
# Final cost : 0.01833528846286212
# Compute control for a deterministic system
# Cost in iteration 0: 0.04050170177335445
# Converged in iteration 133 with cost 0.019435877189815695 because of step counter
# Final cost : 0.019435877189815695
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435877189815695
# Converged in iteration 1 with cost 0.019435877189815695 because of step counter
# Final cost : 0.019435877189815695
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435877189815695
# Converged in iteration 1 with cost 0.019435877189815695 because of step counter
# Final cost : 0.019435877189815695
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435877189815695
# Converged in iteration 1 with cost 0.019435877189815695 because of step counter
# Final cost : 0.019435877189815695
# Compute control for a deterministic system
# Cost in iteration 0: 0.019435877189815695
# Converged in iteration 1 with cost 0.019435877189815695 because of step counter
# Final cost : 0.019435877189815695
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.03785339591904165
# Converged in iteration 95 with cost 0.02102109229349746 because of step counter
# Final cost : 0.02102109229349746
# Compute control for a deterministic system
# Cost in iteration 0: 0.02102109229349746
# Converged in iteration 1 with cost 0.02102109229349746 because of step counter
# Final cost : 0.02102109229349746
# Compute control for a deterministic system
# Cost in iteration 0: 0.02102109229349746
# Converged in iteration 1 with cost 0.02102109229349746 because of step counter
# Final cost : 0.02102109229349746
# Compute control for a deterministic system
# Cost in iteration 0: 0.02102109229349746
# Converged in iteration 1 with cost 0.02102109229349746 because of step counter
# Final cost : 0.02102109229349746
# Compute control for a deterministic system
# Cost in iteration 0: 0.02102109229349746
# Converged in iteration 1 with cost 0.02102109229349746 because of step counter
# Final cost : 0.02102109229349746
# Compute control for a deterministic system
# Cost in iteration 0: 0.03850960187167473
# Converged in iteration 2 with cost 0.02084430350183183 because of step counter
# Final cost : 0.02084430350183183
# Compute control for a deterministic system
# Cost in iteration 0: 0.02084430350183183
# Converged in iteration 1 with cost 0.02084430350183183 because of step counter
# Final cost : 0.02084430350183183
# Compute control for a deterministic system
# Cost in iteration 0: 0.02084430350183183
# Converged in iteration 1 with cost 0.02084430350183183 because of step counter
# Final cost : 0.02084430350183183
# Compute control for a deterministic system
# Cost in iteration 0: 0.02084430350183183
# Converged in iteration 1 with cost 0.02084430350183183 because of step counter
# Final cost : 0.02084430350183183
# Compute control for a deterministic system
# Cost in iteration 0: 0.02084430350183183
# Converged in iteration 1 with cost 0.02084430350183183 because of step counter
# Final cost : 0.02084430350183183
# Compute control for a deterministic system
# Cost in iteration 0: 0.026126136069723555
# Converged in iteration 5 with cost 0.0216274148259359 because of step counter
# Final cost : 0.0216274148259359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0216274148259359
# Converged in iteration 1 with cost 0.0216274148259359 because of step counter
# Final cost : 0.0216274148259359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0216274148259359
# Converged in iteration 1 with cost 0.0216274148259359 because of step counter
# Final cost : 0.0216274148259359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0216274148259359
# Converged in iteration 1 with cost 0.0216274148259359 because of step counter
# Final cost : 0.0216274148259359
# Compute control for a deterministic system
# Cost in iteration 0: 0.0216274148259359
# Converged in iteration 1 with cost 0.0216274148259359 because of step counter
# Final cost : 0.0216274148259359
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.027045168608718053
# Converged in iteration 6 with cost 0.02244494316336148 because of step counter
# Final cost : 0.02244494316336148
# Compute control for a deterministic system
# Cost in iteration 0: 0.02244494316336148
# Converged in iteration 1 with cost 0.02244494316336148 because of step counter
# Final cost : 0.02244494316336148
# Compute control for a deterministic system
# Cost in iteration 0: 0.02244494316336148
# Converged in iteration 1 with cost 0.02244494316336148 because of step counter
# Final cost : 0.02244494316336148
# Compute control for a deterministic system
# Cost in iteration 0: 0.02244494316336148
# Converged in iteration 1 with cost 0.02244494316336148 because of step counter
# Final cost : 0.02244494316336148
# Compute control for a deterministic system
# Cost in iteration 0: 0.02244494316336148
# Converged in iteration 1 with cost 0.02244494316336148 because of step counter
# Final cost : 0.02244494316336148
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.023653588266675726
# Converged in iteration 32 with cost 0.023540669432855973 because of vanishing difference
# Final cost : 0.023540669432855973
# Compute control for a deterministic system
# Cost in iteration 0: 0.023540669432855973
# Converged in iteration 1 with cost 0.023540669432855973 because of step counter
# Final cost : 0.023540669432855973
# Compute control for a deterministic system
# Cost in iteration 0: 0.023540669432855973
# Converged in iteration 1 with cost 0.023540669432855973 because of step counter
# Final cost : 0.023540669432855973
# Compute control for a deterministic system
# Cost in iteration 0: 0.023540669432855973
# Converged in iteration 1 with cost 0.023540669432855973 because of step counter
# Final cost : 0.023540669432855973
# Compute control for a deterministic system
# Cost in iteration 0: 0.023540669432855973
# Converged in iteration 1 with cost 0.023540669432855973 because of step counter
# Final cost : 0.023540669432855973
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.0382683392562414
# Converged in iteration 129 with cost 0.024624377432714267 because of step counter
# Final cost : 0.024624377432714267
# Compute control for a deterministic system
# Cost in iteration 0: 0.024624377432714267
# Converged in iteration 1 with cost 0.024624377432714267 because of step counter
# Final cost : 0.024624377432714267
# Compute control for a deterministic system
# Cost in iteration 0: 0.024624377432714267
# Converged in iteration 1 with cost 0.024624377432714267 because of step counter
# Final cost : 0.024624377432714267
# Compute control for a deterministic system
# Cost in iteration 0: 0.024624377432714267
# Converged in iteration 1 with cost 0.024624377432714267 because of step counter
# Final cost : 0.024624377432714267
# Compute control for a deterministic system
# Cost in iteration 0: 0.024624377432714267
# Converged in iteration 1 with cost 0.024624377432714267 because of step counter
# Final cost : 0.024624377432714267
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.047769330450757555
# Cost in iteration 200: 0.025578419137543253
# Final cost : 0.025578419137543253
# Compute control for a deterministic system
# Cost in iteration 0: 0.025578419137543253
# Converged in iteration 2 with cost 0.025578419137542673 because of step counter
# Final cost : 0.025578419137542673
# Compute control for a deterministic system
# Cost in iteration 0: 0.025578419137542673
# Converged in iteration 1 with cost 0.025578419137542673 because of step counter
# Final cost : 0.025578419137542673
# Compute control for a deterministic system
# Cost in iteration 0: 0.025578419137542673
# Converged in iteration 1 with cost 0.025578419137542673 because of step counter
# Final cost : 0.025578419137542673
# Compute control for a deterministic system
# Cost in iteration 0: 0.025578419137542673
# Converged in iteration 1 with cost 0.025578419137542673 because of step counter
# Final cost : 0.025578419137542673
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.06737453929618353
# Cost in iteration 200: 0.027031288371976454
# Final cost : 0.027031288371976454
# Compute control for a deterministic system
# Cost in iteration 0: 0.027031288371976454
# Converged in iteration 27 with cost 0.02681478832618217 because of step counter
# Final cost : 0.02681478832618217
# Compute control for a deterministic system
# Cost in iteration 0: 0.02681478832618217
# Converged in iteration 1 with cost 0.02681478832618217 because of step counter
# Final cost : 0.02681478832618217
# Compute control for a deterministic system
# Cost in iteration 0: 0.02681478832618217
# Converged in iteration 1 with cost 0.02681478832618217 because of step counter
# Final cost : 0.02681478832618217
# Compute control for a deterministic system
# Cost in iteration 0: 0.02681478832618217
# Converged in iteration 1 with cost 0.02681478832618217 because of step counter
# Final cost : 0.02681478832618217
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.05315700422228792
# Converged in iteration 162 with cost 0.028416194475378822 because of step counter
# Final cost : 0.028416194475378822
# Compute control for a deterministic system
# Cost in iteration 0: 0.028416194475378822
# Converged in iteration 1 with cost 0.028416194475378822 because of step counter
# Final cost : 0.028416194475378822
# Compute control for a deterministic system
# Cost in iteration 0: 0.028416194475378822
# Converged in iteration 1 with cost 0.028416194475378822 because of step counter
# Final cost : 0.028416194475378822
# Compute control for a deterministic system
# Cost in iteration 0: 0.028416194475378822
# Converged in iteration 1 with cost 0.028416194475378822 because of step counter
# Final cost : 0.028416194475378822
# Compute control for a deterministic system
# Cost in iteration 0: 0.028416194475378822
# Converged in iteration 1 with cost 0.028416194475378822 because of step counter
# Final cost : 0.028416194475378822
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.0449534987008621
# Converged in iteration 109 with cost 0.02927367434651936 because of step counter
# Final cost : 0.02927367434651936
# Compute control for a deterministic system
# Cost in iteration 0: 0.02927367434651936
# Converged in iteration 1 with cost 0.02927367434651936 because of step counter
# Final cost : 0.02927367434651936
# Compute control for a deterministic system
# Cost in iteration 0: 0.02927367434651936
# Converged in iteration 1 with cost 0.02927367434651936 because of step counter
# Final cost : 0.02927367434651936
# Compute control for a deterministic system
# Cost in iteration 0: 0.02927367434651936
# Converged in iteration 1 with cost 0.02927367434651936 because of step counter
# Final cost : 0.02927367434651936
# Compute control for a deterministic system
# Cost in iteration 0: 0.02927367434651936
# Converged in iteration 1 with cost 0.02927367434651936 because of step counter
# Final cost : 0.02927367434651936
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.08394777238785919
# Converged in iteration 160 with cost 0.03085482672141014 because of step counter
# Final cost : 0.03085482672141014
# Compute control for a deterministic system
# Cost in iteration 0: 0.03085482672141014
# Converged in iteration 1 with cost 0.03085482672141014 because of step counter
# Final cost : 0.03085482672141014
# Compute control for a deterministic system
# Cost in iteration 0: 0.03085482672141014
# Converged in iteration 1 with cost 0.03085482672141014 because of step counter
# Final cost : 0.03085482672141014
# Compute control for a deterministic system
# Cost in iteration 0: 0.03085482672141014
# Converged in iteration 1 with cost 0.03085482672141014 because of step counter
# Final cost : 0.03085482672141014
# Compute control for a deterministic system
# Cost in iteration 0: 0.03085482672141014
# Converged in iteration 1 with cost 0.03085482672141014 because of step counter
# Final cost : 0.03085482672141014
# Compute control for a deterministic system
# Cost in iteration 0: 0.08586760571064225
# Converged in iteration 86 with cost 0.03197480534652781 because of step counter
# Final cost : 0.03197480534652781
# Compute control for a deterministic system
# Cost in iteration 0: 0.03197480534652781
# Converged in iteration 1 with cost 0.03197480534652781 because of step counter
# Final cost : 0.03197480534652781
# Compute control for a deterministic system
# Cost in iteration 0: 0.03197480534652781
# Converged in iteration 1 with cost 0.03197480534652781 because of step counter
# Final cost : 0.03197480534652781
# Compute control for a deterministic system
# Cost in iteration 0: 0.03197480534652781
# Converged in iteration 1 with cost 0.03197480534652781 because of step counter
# Final cost : 0.03197480534652781
# Compute control for a deterministic system
# Cost in iteration 0: 0.03197480534652781
# Converged in iteration 1 with cost 0.03197480534652781 because of step counter
# Final cost : 0.03197480534652781
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.11189252689877374
# Converged in iteration 97 with cost 0.03445568150620912 because of step counter
# Final cost : 0.03445568150620912
# Compute control for a deterministic system
# Cost in iteration 0: 0.03445568150620912
# Converged in iteration 1 with cost 0.03445568150620912 because of step counter
# Final cost : 0.03445568150620912
# Compute control for a deterministic system
# Cost in iteration 0: 0.03445568150620912
# Converged in iteration 1 with cost 0.03445568150620912 because of step counter
# Final cost : 0.03445568150620912
# Compute control for a deterministic system
# Cost in iteration 0: 0.03445568150620912
# Converged in iteration 1 with cost 0.03445568150620912 because of step counter
# Final cost : 0.03445568150620912
# Compute control for a deterministic system
# Cost in iteration 0: 0.03445568150620912
# Converged in iteration 1 with cost 0.03445568150620912 because of step counter
# Final cost : 0.03445568150620912
# Compute control for a deterministic system
# Cost in iteration 0: 0.08965076816642506
# Converged in iteration 150 with cost 0.03572191713763268 because of step counter
# Final cost : 0.03572191713763268
# Compute control for a deterministic system
# Cost in iteration 0: 0.03572191713763268
# Converged in iteration 1 with cost 0.03572191713763268 because of step counter
# Final cost : 0.03572191713763268
# Compute control for a deterministic system
# Cost in iteration 0: 0.03572191713763268
# Converged in iteration 1 with cost 0.03572191713763268 because of step counter
# Final cost : 0.03572191713763268
# Compute control for a deterministic system
# Cost in iteration 0: 0.03572191713763268
# Converged in iteration 1 with cost 0.03572191713763268 because of step counter
# Final cost : 0.03572191713763268
# Compute control for a deterministic system
# Cost in iteration 0: 0.03572191713763268
# Converged in iteration 1 with cost 0.03572191713763268 because of step counter
# Final cost : 0.03572191713763268
# Compute control for a deterministic system
# Cost in iteration 0: 0.09261810850651048
# Converged in iteration 13 with cost 0.0382998875808022 because of step counter
# Final cost : 0.0382998875808022
# Compute control for a deterministic system
# Cost in iteration 0: 0.0382998875808022
# Converged in iteration 1 with cost 0.0382998875808022 because of step counter
# Final cost : 0.0382998875808022
# Compute control for a deterministic system
# Cost in iteration 0: 0.0382998875808022
# Converged in iteration 1 with cost 0.0382998875808022 because of step counter
# Final cost : 0.0382998875808022
# Compute control for a deterministic system
# Cost in iteration 0: 0.0382998875808022
# Converged in iteration 1 with cost 0.0382998875808022 because of step counter
# Final cost : 0.0382998875808022
# Compute control for a deterministic system
# Cost in iteration 0: 0.0382998875808022
# Converged in iteration 1 with cost 0.0382998875808022 because of step counter
# Final cost : 0.0382998875808022
# Compute control for a deterministic system
# Cost in iteration 0: 0.09531476167908963
# Converged in iteration 14 with cost 0.040968465232285096 because of step counter
# Final cost : 0.040968465232285096
# Compute control for a deterministic system
# Cost in iteration 0: 0.040968465232285096
# Converged in iteration 1 with cost 0.040968465232285096 because of step counter
# Final cost : 0.040968465232285096
# Compute control for a deterministic system
# Cost in iteration 0: 0.040968465232285096
# Converged in iteration 1 with cost 0.040968465232285096 because of step counter
# Final cost : 0.040968465232285096
# Compute control for a deterministic system
# Cost in iteration 0: 0.040968465232285096
# Converged in iteration 1 with cost 0.040968465232285096 because of step counter
# Final cost : 0.040968465232285096
# Compute control for a deterministic system
# Cost in iteration 0: 0.040968465232285096
# Converged in iteration 1 with cost 0.040968465232285096 because of step counter
# Final cost : 0.040968465232285096
# Compute control for a deterministic system
# Cost in iteration 0: 0.1252253233225793
# Converged in iteration 79 with cost 0.04560989179165646 because of step counter
# Final cost : 0.04560989179165646
# Compute control for a deterministic system
# Cost in iteration 0: 0.04560989179165646
# Converged in iteration 1 with cost 0.04560989179165646 because of step counter
# Final cost : 0.04560989179165646
# Compute control for a deterministic system
# Cost in iteration 0: 0.04560989179165646
# Converged in iteration 1 with cost 0.04560989179165646 because of step counter
# Final cost : 0.04560989179165646
# Compute control for a deterministic system
# Cost in iteration 0: 0.04560989179165646
# Converged in iteration 1 with cost 0.04560989179165646 because of step counter
# Final cost : 0.04560989179165646
# Compute control for a deterministic system
# Cost in iteration 0: 0.04560989179165646
# Converged in iteration 1 with cost 0.04560989179165646 because of step counter
# Final cost : 0.04560989179165646
# Compute control for a deterministic system
# Cost in iteration 0: 0.10181704387728896
# Converged in iteration 10 with cost 0.04579713019019405 because of step counter
# Final cost : 0.04579713019019405
# Compute control for a deterministic system
# Cost in iteration 0: 0.04579713019019405
# Converged in iteration 1 with cost 0.04579713019019405 because of step counter
# Final cost : 0.04579713019019405
# Compute control for a deterministic system
# Cost in iteration 0: 0.04579713019019405
# Converged in iteration 1 with cost 0.04579713019019405 because of step counter
# Final cost : 0.04579713019019405
# Compute control for a deterministic system
# Cost in iteration 0: 0.04579713019019405
# Converged in iteration 1 with cost 0.04579713019019405 because of step counter
# Final cost : 0.04579713019019405
# Compute control for a deterministic system
# Cost in iteration 0: 0.04579713019019405
# Converged in iteration 1 with cost 0.04579713019019405 because of step counter
# Final cost : 0.04579713019019405
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.10272378768305909
# Converged in iteration 29 with cost 0.04717944541425195 because of step counter
# Final cost : 0.04717944541425195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04717944541425195
# Converged in iteration 1 with cost 0.04717944541425195 because of step counter
# Final cost : 0.04717944541425195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04717944541425195
# Converged in iteration 1 with cost 0.04717944541425195 because of step counter
# Final cost : 0.04717944541425195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04717944541425195
# Converged in iteration 1 with cost 0.04717944541425195 because of step counter
# Final cost : 0.04717944541425195
# Compute control for a deterministic system
# Cost in iteration 0: 0.04717944541425195
# Converged in iteration 1 with cost 0.04717944541425195 because of step counter
# Final cost : 0.04717944541425195
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.10338751013646008
# Converged in iteration 40 with cost 0.04868220826114789 because of step counter
# Final cost : 0.04868220826114789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04868220826114789
# Converged in iteration 1 with cost 0.04868220826114789 because of step counter
# Final cost : 0.04868220826114789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04868220826114789
# Converged in iteration 1 with cost 0.04868220826114789 because of step counter
# Final cost : 0.04868220826114789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04868220826114789
# Converged in iteration 1 with cost 0.04868220826114789 because of step counter
# Final cost : 0.04868220826114789
# Compute control for a deterministic system
# Cost in iteration 0: 0.04868220826114789
# Converged in iteration 1 with cost 0.04868220826114789 because of step counter
# Final cost : 0.04868220826114789
# -----------------------------------------------
# 0 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.1037077265911494
# Converged in iteration 52 with cost 0.05053269396061735 because of vanishing difference
# Final cost : 0.05053269396061735
# Compute control for a deterministic system
# Cost in iteration 0: 0.05053269396061735
# Converged in iteration 1 with cost 0.05053269396061735 because of step counter
# Final cost : 0.05053269396061735
# Compute control for a deterministic system
# Cost in iteration 0: 0.05053269396061735
# Converged in iteration 1 with cost 0.05053269396061735 because of step counter
# Final cost : 0.05053269396061735
# Compute control for a deterministic system
# Cost in iteration 0: 0.05053269396061735
# Converged in iteration 1 with cost 0.05053269396061735 because of step counter
# Final cost : 0.05053269396061735
# Compute control for a deterministic system
# Cost in iteration 0: 0.05053269396061735
# Converged in iteration 1 with cost 0.05053269396061735 because of step counter
# Final cost : 0.05053269396061735
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.12764255896050755
# Converged in iteration 54 with cost 0.05293469249267794 because of step counter
# Final cost : 0.05293469249267794
# Compute control for a deterministic system
# Cost in iteration 0: 0.05293469249267794
# Converged in iteration 1 with cost 0.05293469249267794 because of step counter
# Final cost : 0.05293469249267794
# Compute control for a deterministic system
# Cost in iteration 0: 0.05293469249267794
# Converged in iteration 1 with cost 0.05293469249267794 because of step counter
# Final cost : 0.05293469249267794
# Compute control for a deterministic system
# Cost in iteration 0: 0.05293469249267794
# Converged in iteration 1 with cost 0.05293469249267794 because of step counter
# Final cost : 0.05293469249267794
# Compute control for a deterministic system
# Cost in iteration 0: 0.05293469249267794
# Converged in iteration 1 with cost 0.05293469249267794 because of step counter
# Final cost : 0.05293469249267794
# Compute control for a deterministic system
# Cost in iteration 0: 0.08270255638646312
# Converged in iteration 144 with cost 0.03049024820504435 because of step counter
# Final cost : 0.03049024820504435
# Compute control for a deterministic system
# Cost in iteration 0: 0.03049024820504435
# Converged in iteration 1 with cost 0.03049024820504435 because of step counter
# Final cost : 0.03049024820504435
# Compute control for a deterministic system
# Cost in iteration 0: 0.03049024820504435
# Converged in iteration 1 with cost 0.03049024820504435 because of step counter
# Final cost : 0.03049024820504435
# Compute control for a deterministic system
# Cost in iteration 0: 0.03049024820504435
# Converged in iteration 1 with cost 0.03049024820504435 because of step counter
# Final cost : 0.03049024820504435
# Compute control for a deterministic system
# Cost in iteration 0: 0.03049024820504435
# Converged in iteration 1 with cost 0.03049024820504435 because of step counter
# Final cost : 0.03049024820504435
# Compute control for a deterministic system
# Cost in iteration 0: 0.07663124341807137
# Cost in iteration 200: 0.024404234126951835
# Final cost : 0.024404234126951835
# Compute control for a deterministic system
# Cost in iteration 0: 0.024404234126951835
# Converged in iteration 21 with cost 0.024396690002058137 because of step counter
# Final cost : 0.024396690002058137
# Compute control for a deterministic system
# Cost in iteration 0: 0.024396690002058137
# Converged in iteration 1 with cost 0.024396690002058137 because of step counter
# Final cost : 0.024396690002058137
# Compute control for a deterministic system
# Cost in iteration 0: 0.024396690002058137
# Converged in iteration 1 with cost 0.024396690002058137 because of step counter
# Final cost : 0.024396690002058137
# Compute control for a deterministic system
# Cost in iteration 0: 0.024396690002058137
# Converged in iteration 1 with cost 0.024396690002058137 because of step counter
# Final cost : 0.024396690002058137
# Compute control for a deterministic system
# Cost in iteration 0: 0.07195302629025897
# Cost in iteration 200: 0.0196136164105019
# Final cost : 0.0196136164105019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0196136164105019
# Converged in iteration 25 with cost 0.019516614045932378 because of step counter
# Final cost : 0.019516614045932378
# Compute control for a deterministic system
# Cost in iteration 0: 0.019516614045932378
# Converged in iteration 1 with cost 0.019516614045932378 because of step counter
# Final cost : 0.019516614045932378
# Compute control for a deterministic system
# Cost in iteration 0: 0.019516614045932378
# Converged in iteration 1 with cost 0.019516614045932378 because of step counter
# Final cost : 0.019516614045932378
# Compute control for a deterministic system
# Cost in iteration 0: 0.019516614045932378
# Converged in iteration 1 with cost 0.019516614045932378 because of step counter
# Final cost : 0.019516614045932378
# -----------------------------------------------
# 0 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.0687036980344648
# Cost in iteration 200: 0.015597387545938455
# Final cost : 0.015597387545938455
# Compute control for a deterministic system
# Cost in iteration 0: 0.015597387545938455
# Converged in iteration 11 with cost 0.01546265743157685 because of step counter
# Final cost : 0.01546265743157685
# Compute control for a deterministic system
# Cost in iteration 0: 0.01546265743157685
# Converged in iteration 1 with cost 0.01546265743157685 because of step counter
# Final cost : 0.01546265743157685
# Compute control for a deterministic system
# Cost in iteration 0: 0.01546265743157685
# Converged in iteration 1 with cost 0.01546265743157685 because of step counter
# Final cost : 0.01546265743157685
# Compute control for a deterministic system
# Cost in iteration 0: 0.01546265743157685
# Converged in iteration 1 with cost 0.01546265743157685 because of step counter
# Final cost : 0.01546265743157685
# -----------------------------------------------
# 0 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.08878806885162141
# Cost in iteration 200: 0.011243212164407925
# Final cost : 0.011243212164407925
# Compute control for a deterministic system
# Cost in iteration 0: 0.011243212164407925
# Converged in iteration 51 with cost 0.010852908858567038 because of step counter
# Final cost : 0.010852908858567038
# Compute control for a deterministic system
# Cost in iteration 0: 0.010852908858567038
# Converged in iteration 1 with cost 0.010852908858567038 because of step counter
# Final cost : 0.010852908858567038
# Compute control for a deterministic system
# Cost in iteration 0: 0.010852908858567038
# Converged in iteration 1 with cost 0.010852908858567038 because of step counter
# Final cost : 0.010852908858567038
# Compute control for a deterministic system
# Cost in iteration 0: 0.010852908858567038
# Converged in iteration 1 with cost 0.010852908858567038 because of step counter
# Final cost : 0.010852908858567038
# Compute control for a deterministic system
# Cost in iteration 0: 0.06169251020870721
# Cost in iteration 200: 0.006483807930164015
# Final cost : 0.006483807930164015
# Compute control for a deterministic system
# Cost in iteration 0: 0.006483807930164015
# Converged in iteration 9 with cost 0.006366385095696761 because of step counter
# Final cost : 0.006366385095696761
# Compute control for a deterministic system
# Cost in iteration 0: 0.006366385095696761
# Converged in iteration 1 with cost 0.006366385095696761 because of step counter
# Final cost : 0.006366385095696761
# Compute control for a deterministic system
# Cost in iteration 0: 0.006366385095696761
# Converged in iteration 1 with cost 0.006366385095696761 because of step counter
# Final cost : 0.006366385095696761
# Compute control for a deterministic system
# Cost in iteration 0: 0.006366385095696761
# Converged in iteration 1 with cost 0.006366385095696761 because of step counter
# Final cost : 0.006366385095696761
# Compute control for a deterministic system
# Cost in iteration 0: 0.059916933700616314
# Cost in iteration 200: 0.0029178603596492873
# Final cost : 0.0029178603596492873
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029178603596492873
# Converged in iteration 6 with cost 0.002887828260619612 because of step counter
# Final cost : 0.002887828260619612
# Compute control for a deterministic system
# Cost in iteration 0: 0.002887828260619612
# Converged in iteration 1 with cost 0.002887828260619612 because of step counter
# Final cost : 0.002887828260619612
# Compute control for a deterministic system
# Cost in iteration 0: 0.002887828260619612
# Converged in iteration 1 with cost 0.002887828260619612 because of step counter
# Final cost : 0.002887828260619612
# Compute control for a deterministic system
# Cost in iteration 0: 0.002887828260619612
# Converged in iteration 1 with cost 0.002887828260619612 because of step counter
# Final cost : 0.002887828260619612
# -----------------------------------------------
# 0 found better solution,  39
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.05798424367689846
# Converged in iteration 16 with cost 0.006377423028171645 because of step counter
# Final cost : 0.006377423028171645
# Compute control for a deterministic system
# Cost in iteration 0: 0.006377423028171645
# Converged in iteration 1 with cost 0.006377423028171645 because of step counter
# Final cost : 0.006377423028171645
# Compute control for a deterministic system
# Cost in iteration 0: 0.006377423028171645
# Converged in iteration 1 with cost 0.006377423028171645 because of step counter
# Final cost : 0.006377423028171645
# Compute control for a deterministic system
# Cost in iteration 0: 0.006377423028171645
# Converged in iteration 1 with cost 0.006377423028171645 because of step counter
# Final cost : 0.006377423028171645
# Compute control for a deterministic system
# Cost in iteration 0: 0.05887476205730116
# Converged in iteration 15 with cost 0.009811121124806439 because of step counter
# Final cost : 0.009811121124806439
# Compute control for a deterministic system
# Cost in iteration 0: 0.009811121124806439
# Converged in iteration 1 with cost 0.009811121124806439 because of step counter
# Final cost : 0.009811121124806439
# Compute control for a deterministic system
# Cost in iteration 0: 0.009811121124806439
# Converged in iteration 1 with cost 0.009811121124806439 because of step counter
# Final cost : 0.009811121124806439
# Compute control for a deterministic system
# Cost in iteration 0: 0.009811121124806439
# Converged in iteration 1 with cost 0.009811121124806439 because of step counter
# Final cost : 0.009811121124806439
# -----------------------------------------------
# 1 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.08448716444073776
# Converged in iteration 14 with cost 0.015774402959985615 because of step counter
# Final cost : 0.015774402959985615
# Compute control for a deterministic system
# Cost in iteration 0: 0.015774402959985615
# Converged in iteration 1 with cost 0.015774402959985615 because of step counter
# Final cost : 0.015774402959985615
# Compute control for a deterministic system
# Cost in iteration 0: 0.015774402959985615
# Converged in iteration 1 with cost 0.015774402959985615 because of step counter
# Final cost : 0.015774402959985615
# Compute control for a deterministic system
# Cost in iteration 0: 0.015774402959985615
# Converged in iteration 1 with cost 0.015774402959985615 because of step counter
# Final cost : 0.015774402959985615
# Compute control for a deterministic system
# Cost in iteration 0: 0.0649104007802541
# Converged in iteration 10 with cost 0.01987650527951927 because of step counter
# Final cost : 0.01987650527951927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01987650527951927
# Converged in iteration 1 with cost 0.01987650527951927 because of step counter
# Final cost : 0.01987650527951927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01987650527951927
# Converged in iteration 1 with cost 0.01987650527951927 because of step counter
# Final cost : 0.01987650527951927
# Compute control for a deterministic system
# Cost in iteration 0: 0.01987650527951927
# Converged in iteration 1 with cost 0.01987650527951927 because of step counter
# Final cost : 0.01987650527951927
# Compute control for a deterministic system
# Cost in iteration 0: 0.06951612493487738
# Converged in iteration 10 with cost 0.024786687097112462 because of step counter
# Final cost : 0.024786687097112462
# Compute control for a deterministic system
# Cost in iteration 0: 0.024786687097112462
# Converged in iteration 1 with cost 0.024786687097112462 because of step counter
# Final cost : 0.024786687097112462
# Compute control for a deterministic system
# Cost in iteration 0: 0.024786687097112462
# Converged in iteration 1 with cost 0.024786687097112462 because of step counter
# Final cost : 0.024786687097112462
# Compute control for a deterministic system
# Cost in iteration 0: 0.024786687097112462
# Converged in iteration 1 with cost 0.024786687097112462 because of step counter
# Final cost : 0.024786687097112462
# Compute control for a deterministic system
# Cost in iteration 0: 0.07534760892775483
# Converged in iteration 14 with cost 0.030875307972666063 because of step counter
# Final cost : 0.030875307972666063
# Compute control for a deterministic system
# Cost in iteration 0: 0.030875307972666063
# Converged in iteration 1 with cost 0.030875307972666063 because of step counter
# Final cost : 0.030875307972666063
# Compute control for a deterministic system
# Cost in iteration 0: 0.030875307972666063
# Converged in iteration 1 with cost 0.030875307972666063 because of step counter
# Final cost : 0.030875307972666063
# Compute control for a deterministic system
# Cost in iteration 0: 0.030875307972666063
# Converged in iteration 1 with cost 0.030875307972666063 because of step counter
# Final cost : 0.030875307972666063
# Compute control for a deterministic system
# Cost in iteration 0: 0.08337751153872722
# Converged in iteration 14 with cost 0.039226755582625596 because of step counter
# Final cost : 0.039226755582625596
# Compute control for a deterministic system
# Cost in iteration 0: 0.039226755582625596
# Converged in iteration 1 with cost 0.039226755582625596 because of step counter
# Final cost : 0.039226755582625596
# Compute control for a deterministic system
# Cost in iteration 0: 0.039226755582625596
# Converged in iteration 1 with cost 0.039226755582625596 because of step counter
# Final cost : 0.039226755582625596
# Compute control for a deterministic system
# Cost in iteration 0: 0.039226755582625596
# Converged in iteration 1 with cost 0.039226755582625596 because of step counter
# Final cost : 0.039226755582625596
# Compute control for a deterministic system
# Cost in iteration 0: 0.11968148363337533
# Converged in iteration 102 with cost 0.05233976774471152 because of step counter
# Final cost : 0.05233976774471152
# Compute control for a deterministic system
# Cost in iteration 0: 0.05233976774471152
# Converged in iteration 1 with cost 0.05233976774471152 because of step counter
# Final cost : 0.05233976774471152
# Compute control for a deterministic system
# Cost in iteration 0: 0.05233976774471152
# Converged in iteration 1 with cost 0.05233976774471152 because of step counter
# Final cost : 0.05233976774471152
# Compute control for a deterministic system
# Cost in iteration 0: 0.05233976774471152
# Converged in iteration 1 with cost 0.05233976774471152 because of step counter
# Final cost : 0.05233976774471152
# Compute control for a deterministic system
# Cost in iteration 0: 0.13060692268872992
# Converged in iteration 23 with cost 0.04876406011449278 because of step counter
# Final cost : 0.04876406011449278
# Compute control for a deterministic system
# Cost in iteration 0: 0.04876406011449278
# Converged in iteration 1 with cost 0.04876406011449278 because of step counter
# Final cost : 0.04876406011449278
# Compute control for a deterministic system
# Cost in iteration 0: 0.04876406011449278
# Converged in iteration 1 with cost 0.04876406011449278 because of step counter
# Final cost : 0.04876406011449278
# Compute control for a deterministic system
# Cost in iteration 0: 0.04876406011449278
# Converged in iteration 1 with cost 0.04876406011449278 because of step counter
# Final cost : 0.04876406011449278
# Compute control for a deterministic system
# Cost in iteration 0: 0.1341386502023167
# Converged in iteration 9 with cost 0.047277515459643434 because of step counter
# Final cost : 0.047277515459643434
# Compute control for a deterministic system
# Cost in iteration 0: 0.047277515459643434
# Converged in iteration 1 with cost 0.047277515459643434 because of step counter
# Final cost : 0.047277515459643434
# Compute control for a deterministic system
# Cost in iteration 0: 0.047277515459643434
# Converged in iteration 1 with cost 0.047277515459643434 because of step counter
# Final cost : 0.047277515459643434
# Compute control for a deterministic system
# Cost in iteration 0: 0.047277515459643434
# Converged in iteration 1 with cost 0.047277515459643434 because of step counter
# Final cost : 0.047277515459643434
# Compute control for a deterministic system
# Cost in iteration 0: 0.13763173347051605
# Converged in iteration 9 with cost 0.04589194923205829 because of step counter
# Final cost : 0.04589194923205829
# Compute control for a deterministic system
# Cost in iteration 0: 0.04589194923205829
# Converged in iteration 1 with cost 0.04589194923205829 because of step counter
# Final cost : 0.04589194923205829
# Compute control for a deterministic system
# Cost in iteration 0: 0.04589194923205829
# Converged in iteration 1 with cost 0.04589194923205829 because of step counter
# Final cost : 0.04589194923205829
# Compute control for a deterministic system
# Cost in iteration 0: 0.04589194923205829
# Converged in iteration 1 with cost 0.04589194923205829 because of step counter
# Final cost : 0.04589194923205829
# Compute control for a deterministic system
# Cost in iteration 0: 0.13959828089320772
# Converged in iteration 19 with cost 0.04453606929483803 because of step counter
# Final cost : 0.04453606929483803
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453606929483803
# Converged in iteration 1 with cost 0.04453606929483803 because of step counter
# Final cost : 0.04453606929483803
# Compute control for a deterministic system
# Cost in iteration 0: 0.04453606929483803
# Converged in iteration 1 with cost 0.04453606929483803 because of step counter
# Final cost : 0.04453606929483803
# ...
# Final cost : 0.5195894772002
# Compute control for a deterministic system
# Cost in iteration 0: 0.5195894772002
# Converged in iteration 1 with cost 0.5195894772002 because of step counter
# Final cost : 0.5195894772002
# Compute control for a deterministic system
# Cost in iteration 0: 0.5195894772002
# Converged in iteration 1 with cost 0.5195894772002 because of step counter
# Final cost : 0.5195894772002
# Compute control for a deterministic system
# Cost in iteration 0: 0.5195894772002
# Converged in iteration 1 with cost 0.5195894772002 because of step counter
# Final cost : 0.5195894772002
# Compute control for a deterministic system
# Cost in iteration 0: 0.540471131870611
# Converged in iteration 4 with cost 0.5382721896245577 because of step counter
# Final cost : 0.5382721896245577
# Compute control for a deterministic system
# Cost in iteration 0: 0.5382721896245577
# Converged in iteration 1 with cost 0.5382721896245577 because of step counter
# Final cost : 0.5382721896245577
# Compute control for a deterministic system
# Cost in iteration 0: 0.5382721896245577
# Converged in iteration 1 with cost 0.5382721896245577 because of step counter
# Final cost : 0.5382721896245577
# Compute control for a deterministic system
# Cost in iteration 0: 0.5382721896245577
# Converged in iteration 1 with cost 0.5382721896245577 because of step counter
# Final cost : 0.5382721896245577
# Compute control for a deterministic system
# Cost in iteration 0: 0.5382721896245577
# Converged in iteration 1 with cost 0.5382721896245577 because of step counter
# Final cost : 0.5382721896245577
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.5616514739436532
# Converged in iteration 4 with cost 0.5584077489659958 because of step counter
# Final cost : 0.5584077489659958
# Compute control for a deterministic system
# Cost in iteration 0: 0.5584077489659958
# Converged in iteration 1 with cost 0.5584077489659958 because of step counter
# Final cost : 0.5584077489659958
# Compute control for a deterministic system
# Cost in iteration 0: 0.5584077489659958
# Converged in iteration 1 with cost 0.5584077489659958 because of step counter
# Final cost : 0.5584077489659958
# Compute control for a deterministic system
# Cost in iteration 0: 0.5584077489659958
# Converged in iteration 1 with cost 0.5584077489659958 because of step counter
# Final cost : 0.5584077489659958
# Compute control for a deterministic system
# Cost in iteration 0: 0.5584077489659958
# Converged in iteration 1 with cost 0.5584077489659958 because of step counter
# Final cost : 0.5584077489659958
# Compute control for a deterministic system
# Cost in iteration 0: 0.5859527581228384
# Converged in iteration 4 with cost 0.5838851157835693 because of step counter
# Final cost : 0.5838851157835693
# Compute control for a deterministic system
# Cost in iteration 0: 0.5838851157835693
# Converged in iteration 1 with cost 0.5838851157835693 because of step counter
# Final cost : 0.5838851157835693
# Compute control for a deterministic system
# Cost in iteration 0: 0.5838851157835693
# Converged in iteration 1 with cost 0.5838851157835693 because of step counter
# Final cost : 0.5838851157835693
# Compute control for a deterministic system
# Cost in iteration 0: 0.5838851157835693
# Converged in iteration 1 with cost 0.5838851157835693 because of step counter
# Final cost : 0.5838851157835693
# Compute control for a deterministic system
# Cost in iteration 0: 0.5838851157835693
# Converged in iteration 1 with cost 0.5838851157835693 because of step counter
# Final cost : 0.5838851157835693
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.6083724894433657
# Converged in iteration 4 with cost 0.6065707465306482 because of step counter
# Final cost : 0.6065707465306482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6065707465306482
# Converged in iteration 1 with cost 0.6065707465306482 because of step counter
# Final cost : 0.6065707465306482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6065707465306482
# Converged in iteration 1 with cost 0.6065707465306482 because of step counter
# Final cost : 0.6065707465306482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6065707465306482
# Converged in iteration 1 with cost 0.6065707465306482 because of step counter
# Final cost : 0.6065707465306482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6065707465306482
# Converged in iteration 1 with cost 0.6065707465306482 because of step counter
# Final cost : 0.6065707465306482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6325608936866554
# Converged in iteration 5 with cost 0.6297233473494702 because of step counter
# Final cost : 0.6297233473494702
# Compute control for a deterministic system
# Cost in iteration 0: 0.6297233473494702
# Converged in iteration 1 with cost 0.6297233473494702 because of step counter
# Final cost : 0.6297233473494702
# Compute control for a deterministic system
# Cost in iteration 0: 0.6297233473494702
# Converged in iteration 1 with cost 0.6297233473494702 because of step counter
# Final cost : 0.6297233473494702
# Compute control for a deterministic system
# Cost in iteration 0: 0.6297233473494702
# Converged in iteration 1 with cost 0.6297233473494702 because of step counter
# Final cost : 0.6297233473494702
# Compute control for a deterministic system
# Cost in iteration 0: 0.6297233473494702
# Converged in iteration 1 with cost 0.6297233473494702 because of step counter
# Final cost : 0.6297233473494702
# Compute control for a deterministic system
# Cost in iteration 0: 0.6549890626696513
# Converged in iteration 4 with cost 0.6523698006036485 because of step counter
# Final cost : 0.6523698006036485
# Compute control for a deterministic system
# Cost in iteration 0: 0.6523698006036485
# Converged in iteration 1 with cost 0.6523698006036485 because of step counter
# Final cost : 0.6523698006036485
# Compute control for a deterministic system
# Cost in iteration 0: 0.6523698006036485
# Converged in iteration 1 with cost 0.6523698006036485 because of step counter
# Final cost : 0.6523698006036485
# Compute control for a deterministic system
# Cost in iteration 0: 0.6523698006036485
# Converged in iteration 1 with cost 0.6523698006036485 because of step counter
# Final cost : 0.6523698006036485
# Compute control for a deterministic system
# Cost in iteration 0: 0.6523698006036485
# Converged in iteration 1 with cost 0.6523698006036485 because of step counter
# Final cost : 0.6523698006036485
# Compute control for a deterministic system
# Cost in iteration 0: 0.5427780011775567
# Converged in iteration 2 with cost 0.5427025322834553 because of step counter
# Final cost : 0.5427025322834553
# Compute control for a deterministic system
# Cost in iteration 0: 0.5427025322834553
# Converged in iteration 1 with cost 0.5427025322834553 because of step counter
# Final cost : 0.5427025322834553
# Compute control for a deterministic system
# Cost in iteration 0: 0.5427025322834553
# Converged in iteration 1 with cost 0.5427025322834553 because of step counter
# Final cost : 0.5427025322834553
# Compute control for a deterministic system
# Cost in iteration 0: 0.5427025322834553
# Converged in iteration 1 with cost 0.5427025322834553 because of step counter
# Final cost : 0.5427025322834553
# Compute control for a deterministic system
# Cost in iteration 0: 0.5427025322834553
# Converged in iteration 1 with cost 0.5427025322834553 because of step counter
# Final cost : 0.5427025322834553
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.44768223667816665
# Converged in iteration 3 with cost 0.44758817641173254 because of step counter
# Final cost : 0.44758817641173254
# Compute control for a deterministic system
# Cost in iteration 0: 0.44758817641173254
# Converged in iteration 1 with cost 0.44758817641173254 because of step counter
# Final cost : 0.44758817641173254
# Compute control for a deterministic system
# Cost in iteration 0: 0.44758817641173254
# Converged in iteration 1 with cost 0.44758817641173254 because of step counter
# Final cost : 0.44758817641173254
# Compute control for a deterministic system
# Cost in iteration 0: 0.44758817641173254
# Converged in iteration 1 with cost 0.44758817641173254 because of step counter
# Final cost : 0.44758817641173254
# Compute control for a deterministic system
# Cost in iteration 0: 0.44758817641173254
# Converged in iteration 1 with cost 0.44758817641173254 because of step counter
# Final cost : 0.44758817641173254
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.37643198156703445
# Converged in iteration 6 with cost 0.3763459157193575 because of step counter
# Final cost : 0.3763459157193575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3763459157193575
# Converged in iteration 1 with cost 0.3763459157193575 because of step counter
# Final cost : 0.3763459157193575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3763459157193575
# Converged in iteration 1 with cost 0.3763459157193575 because of step counter
# Final cost : 0.3763459157193575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3763459157193575
# Converged in iteration 1 with cost 0.3763459157193575 because of step counter
# Final cost : 0.3763459157193575
# Compute control for a deterministic system
# Cost in iteration 0: 0.3763459157193575
# Converged in iteration 1 with cost 0.3763459157193575 because of step counter
# Final cost : 0.3763459157193575
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.2967339437230787
# Converged in iteration 2 with cost 0.29671988085862566 because of step counter
# Final cost : 0.29671988085862566
# Compute control for a deterministic system
# Cost in iteration 0: 0.29671988085862566
# Converged in iteration 1 with cost 0.29671988085862566 because of step counter
# Final cost : 0.29671988085862566
# Compute control for a deterministic system
# Cost in iteration 0: 0.29671988085862566
# Converged in iteration 1 with cost 0.29671988085862566 because of step counter
# Final cost : 0.29671988085862566
# Compute control for a deterministic system
# Cost in iteration 0: 0.29671988085862566
# Converged in iteration 1 with cost 0.29671988085862566 because of step counter
# Final cost : 0.29671988085862566
# Compute control for a deterministic system
# Cost in iteration 0: 0.29671988085862566
# Converged in iteration 1 with cost 0.29671988085862566 because of step counter
# Final cost : 0.29671988085862566
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.23845876136490562
# Converged in iteration 1 with cost 0.23845876136490562 because of step counter
# Final cost : 0.23845876136490562
# Compute control for a deterministic system
# Cost in iteration 0: 0.23845876136490562
# Converged in iteration 1 with cost 0.23845876136490562 because of step counter
# Final cost : 0.23845876136490562
# Compute control for a deterministic system
# Cost in iteration 0: 0.23845876136490562
# Converged in iteration 1 with cost 0.23845876136490562 because of step counter
# Final cost : 0.23845876136490562
# Compute control for a deterministic system
# Cost in iteration 0: 0.23845876136490562
# Converged in iteration 1 with cost 0.23845876136490562 because of step counter
# Final cost : 0.23845876136490562
# Compute control for a deterministic system
# Cost in iteration 0: 0.23845876136490562
# Converged in iteration 1 with cost 0.23845876136490562 because of step counter
# Final cost : 0.23845876136490562
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.1912306830513921
# Converged in iteration 3 with cost 0.19080983728275216 because of step counter
# Final cost : 0.19080983728275216
# Compute control for a deterministic system
# Cost in iteration 0: 0.19080983728275216
# Converged in iteration 1 with cost 0.19080983728275216 because of step counter
# Final cost : 0.19080983728275216
# Compute control for a deterministic system
# Cost in iteration 0: 0.19080983728275216
# Converged in iteration 1 with cost 0.19080983728275216 because of step counter
# Final cost : 0.19080983728275216
# Compute control for a deterministic system
# Cost in iteration 0: 0.19080983728275216
# Converged in iteration 1 with cost 0.19080983728275216 because of step counter
# Final cost : 0.19080983728275216
# Compute control for a deterministic system
# Cost in iteration 0: 0.19080983728275216
# Converged in iteration 1 with cost 0.19080983728275216 because of step counter
# Final cost : 0.19080983728275216
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.1299855132642526
# Converged in iteration 3 with cost 0.12757878110047996 because of step counter
# Final cost : 0.12757878110047996
# Compute control for a deterministic system
# Cost in iteration 0: 0.12757878110047996
# Converged in iteration 1 with cost 0.12757878110047996 because of step counter
# Final cost : 0.12757878110047996
# Compute control for a deterministic system
# Cost in iteration 0: 0.12757878110047996
# Converged in iteration 1 with cost 0.12757878110047996 because of step counter
# Final cost : 0.12757878110047996
# Compute control for a deterministic system
# Cost in iteration 0: 0.12757878110047996
# Converged in iteration 1 with cost 0.12757878110047996 because of step counter
# Final cost : 0.12757878110047996
# Compute control for a deterministic system
# Cost in iteration 0: 0.12757878110047996
# Converged in iteration 1 with cost 0.12757878110047996 because of step counter
# Final cost : 0.12757878110047996
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.0765886684928905
# Converged in iteration 1 with cost 0.0765886684928905 because of step counter
# Final cost : 0.0765886684928905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0765886684928905
# Converged in iteration 1 with cost 0.0765886684928905 because of step counter
# Final cost : 0.0765886684928905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0765886684928905
# Converged in iteration 1 with cost 0.0765886684928905 because of step counter
# Final cost : 0.0765886684928905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0765886684928905
# Converged in iteration 1 with cost 0.0765886684928905 because of step counter
# Final cost : 0.0765886684928905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0765886684928905
# Converged in iteration 1 with cost 0.0765886684928905 because of step counter
# Final cost : 0.0765886684928905
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243199218993236
# Converged in iteration 2 with cost 0.03243116330721918 because of step counter
# Final cost : 0.03243116330721918
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243116330721918
# Converged in iteration 1 with cost 0.03243116330721918 because of step counter
# Final cost : 0.03243116330721918
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243116330721918
# Converged in iteration 1 with cost 0.03243116330721918 because of step counter
# Final cost : 0.03243116330721918
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243116330721918
# Converged in iteration 1 with cost 0.03243116330721918 because of step counter
# Final cost : 0.03243116330721918
# Compute control for a deterministic system
# Cost in iteration 0: 0.03243116330721918
# Converged in iteration 1 with cost 0.03243116330721918 because of step counter
# Final cost : 0.03243116330721918
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_peak)
