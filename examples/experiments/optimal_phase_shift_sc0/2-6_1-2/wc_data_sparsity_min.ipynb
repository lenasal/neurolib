# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 500.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period) # 19.069230769230767

wc.run()
init_min = [wc.exc[0,194], wc.inh[0,194]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t[:500], wc.exc[0,:500])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  20.819047619047623
# minima =  [ 191  400  608  816 1024 1232 1441 1649 1857 2065 2273 2481 2690 2898
#  3106 3314 3522 3731 3939 4147 4355 4563 4772 4980]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
options = [True, True, False, False, True, True, False, False]
#options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        if i_w != 1:
            continue

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):

            break
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.07852187533086695
# Final cost : 0.018321973611645195
# Compute control for a deterministic system
# Cost in iteration 0: 0.018321973611645195
# Converged in iteration 6 with cost 0.018321964523808368 because of vanishing difference
# Final cost : 0.018321964523808368
# Compute control for a deterministic system
# Cost in iteration 0: 0.018321964523808368
# Converged in iteration 151 with cost 0.0183219546523949 because of step counter
# Final cost : 0.0183219546523949
# Compute control for a deterministic system
# Cost in iteration 0: 0.0183219546523949
# Converged in iteration 2 with cost 0.018321954652394248 because of step counter
# Final cost : 0.018321954652394248
# Compute control for a deterministic system
# Cost in iteration 0: 0.018321954652394248
# Converged in iteration 1 with cost 0.018321954652394248 because of step counter
# Final cost : 0.018321954652394248
# Compute control for a deterministic system
# Cost in iteration 0: 0.10142020493057036
# Final cost : 0.028667737563143038
# Compute control for a deterministic system
# Cost in iteration 0: 0.028667737563143038
# Converged in iteration 153 with cost 0.02866643593230847 because of vanishing difference
# Final cost : 0.02866643593230847
# Compute control for a deterministic system
# Cost in iteration 0: 0.02866643593230847
# Final cost : 0.028666425166757884
# Compute control for a deterministic system
# Cost in iteration 0: 0.028666425166757884
# Converged in iteration 167 with cost 0.028666425125137715 because of step counter
# Final cost : 0.028666425125137715
# Compute control for a deterministic system
# Cost in iteration 0: 0.028666425125137715
# Converged in iteration 1 with cost 0.028666425125137715 because of step counter
# Final cost : 0.028666425125137715
# Compute control for a deterministic system
# Cost in iteration 0: 0.07747713676700942
# Final cost : 0.036420600684595
# Compute control for a deterministic system
# Cost in iteration 0: 0.036420600684595
# Final cost : 0.036418770354860755
# Compute control for a deterministic system
# Cost in iteration 0: 0.036418770354860755
# Converged in iteration 1 with cost 0.036418770354860755 because of vanishing difference
# Final cost : 0.036418770354860755
# Compute control for a deterministic system
# Cost in iteration 0: 0.036418770354860755
# Final cost : 0.036418652936970344
# Compute control for a deterministic system
# Cost in iteration 0: 0.036418652936970344
# Converged in iteration 547 with cost 0.03641865273617338 because of step counter
# Final cost : 0.03641865273617338
# Compute control for a deterministic system
# Cost in iteration 0: 0.10690726634910425
# Final cost : 0.04345382297251668
# Compute control for a deterministic system
# Cost in iteration 0: 0.04345382297251668
# Converged in iteration 109 with cost 0.04345008084997573 because of vanishing difference
# Final cost : 0.04345008084997573
# Compute control for a deterministic system
# Cost in iteration 0: 0.04345008084997573
# Final cost : 0.043447162395290125
# Compute control for a deterministic system
# Cost in iteration 0: 0.043447162395290125
# Final cost : 0.043446705928626435
# Compute control for a deterministic system
# Cost in iteration 0: 0.043446705928626435
# Final cost : 0.04344667980459405
# Compute control for a deterministic system
# Cost in iteration 0: 0.07944617035518817
# Final cost : 0.04984963244055374
# Compute control for a deterministic system
# Cost in iteration 0: 0.04984963244055374
# Converged in iteration 131 with cost 0.049839539823432165 because of vanishing difference
# Final cost : 0.049839539823432165
# Compute control for a deterministic system
# Cost in iteration 0: 0.049839539823432165
# Final cost : 0.04983658512219059
# Compute control for a deterministic system
# Cost in iteration 0: 0.04983658512219059
# Final cost : 0.04983493749379825
# Compute control for a deterministic system
# Cost in iteration 0: 0.04983493749379825
# Final cost : 0.049834472830528685
# Compute control for a deterministic system
# Cost in iteration 0: 0.14337321151046045
# Final cost : 0.05599486309177863
# Compute control for a deterministic system
# Cost in iteration 0: 0.05599486309177863
# Final cost : 0.055656995866709094
# Compute control for a deterministic system
# Cost in iteration 0: 0.055656995866709094
# Converged in iteration 72 with cost 0.05565512386589468 because of vanishing difference
# Final cost : 0.05565512386589468
# Compute control for a deterministic system
# Cost in iteration 0: 0.05565512386589468
# Final cost : 0.055650342623214395
# Compute control for a deterministic system
# Cost in iteration 0: 0.055650342623214395
# Final cost : 0.055646574548710075
# Compute control for a deterministic system
# Cost in iteration 0: 0.12216883552902713
# Final cost : 0.062001753976131085
# Compute control for a deterministic system
# Cost in iteration 0: 0.062001753976131085
# Final cost : 0.061967065499209974
# Compute control for a deterministic system
# Cost in iteration 0: 0.061967065499209974
# Final cost : 0.061961756835891196
# Compute control for a deterministic system
# Cost in iteration 0: 0.061961756835891196
# Final cost : 0.061951400826747556
# Compute control for a deterministic system
# Cost in iteration 0: 0.061951400826747556
# Final cost : 0.061947624129171985
# Compute control for a deterministic system
# Cost in iteration 0: 0.17373526774032944
# Final cost : 0.06765210575737775
# Compute control for a deterministic system
# Cost in iteration 0: 0.06765210575737775
# Final cost : 0.06697032182870989
# Compute control for a deterministic system
# Cost in iteration 0: 0.06697032182870989
# Final cost : 0.0667507575206743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0667507575206743
# Final cost : 0.06674165992076055
# Compute control for a deterministic system
# Cost in iteration 0: 0.06674165992076055
# Final cost : 0.06673625374545934
# Compute control for a deterministic system
# Cost in iteration 0: 0.08857567382255109
# Final cost : 0.07121171017351405
# Compute control for a deterministic system
# Cost in iteration 0: 0.07121171017351405
# Final cost : 0.07120412021619775
# Compute control for a deterministic system
# Cost in iteration 0: 0.07120412021619775
# Final cost : 0.07120075037560498
# Compute control for a deterministic system
# Cost in iteration 0: 0.07120075037560498
# Final cost : 0.0711938515556044
# Compute control for a deterministic system
# Cost in iteration 0: 0.0711938515556044
# Final cost : 0.07118703271277611
# Compute control for a deterministic system
# Cost in iteration 0: 0.08605239498197068
# Final cost : 0.07538486237315313
# Compute control for a deterministic system
# Cost in iteration 0: 0.07538486237315313
# Final cost : 0.07537744560993848
# Compute control for a deterministic system
# Cost in iteration 0: 0.07537744560993848
# Final cost : 0.075368475055762
# Compute control for a deterministic system
# Cost in iteration 0: 0.075368475055762
# Final cost : 0.07536425948087191
# Compute control for a deterministic system
# Cost in iteration 0: 0.07536425948087191
# Final cost : 0.07535862812028812
# Compute control for a deterministic system
# Cost in iteration 0: 0.08934260086771158
# Final cost : 0.07933465921689783
# Compute control for a deterministic system
# Cost in iteration 0: 0.07933465921689783
# Final cost : 0.07932460311070415
# Compute control for a deterministic system
# Cost in iteration 0: 0.07932460311070415
# Final cost : 0.07931827068912212
# Compute control for a deterministic system
# Cost in iteration 0: 0.07931827068912212
# Final cost : 0.07931399784857272
# Compute control for a deterministic system
# Cost in iteration 0: 0.07931399784857272
# Final cost : 0.07930763365589194
# Compute control for a deterministic system
# Cost in iteration 0: 0.25995376126465947
# Final cost : 0.08402253825434942
# Compute control for a deterministic system
# Cost in iteration 0: 0.08402253825434942
# Final cost : 0.08385408503798146
# Compute control for a deterministic system
# Cost in iteration 0: 0.08385408503798146
# Final cost : 0.0838150058362682
# Compute control for a deterministic system
# Cost in iteration 0: 0.0838150058362682
# Final cost : 0.083810017333158
# Compute control for a deterministic system
# Cost in iteration 0: 0.083810017333158
# Final cost : 0.08380620314778657
# Compute control for a deterministic system
# Cost in iteration 0: 0.32553937746638983
# Final cost : 0.0931233093667036
# Compute control for a deterministic system
# Cost in iteration 0: 0.0931233093667036
# Final cost : 0.09096521885577354
# Compute control for a deterministic system
# Cost in iteration 0: 0.09096521885577354
# Final cost : 0.09048513274950327
# Compute control for a deterministic system
# Cost in iteration 0: 0.09048513274950327
# Final cost : 0.08966701741565956
# Compute control for a deterministic system
# Cost in iteration 0: 0.08966701741565956
# Final cost : 0.08809246724418647
# Compute control for a deterministic system
# Cost in iteration 0: 0.30281515505425927
# Final cost : 0.0954156525149165
# Compute control for a deterministic system
# Cost in iteration 0: 0.0954156525149165
# Final cost : 0.09327688648692825
# Compute control for a deterministic system
# Cost in iteration 0: 0.09327688648692825
# Final cost : 0.09250292897935508
# Compute control for a deterministic system
# Cost in iteration 0: 0.09250292897935508
# Final cost : 0.091445183128276
# Compute control for a deterministic system
# Cost in iteration 0: 0.091445183128276
# Converged in iteration 185 with cost 0.09098149857585577 because of vanishing difference
# Final cost : 0.09098149857585577
# Compute control for a deterministic system
# Cost in iteration 0: 0.10839950840881218
# Final cost : 0.09429032661089912
# Compute control for a deterministic system
# Cost in iteration 0: 0.09429032661089912
# Final cost : 0.09427418554636216
# Compute control for a deterministic system
# Cost in iteration 0: 0.09427418554636216
# Final cost : 0.09427094813867816
# Compute control for a deterministic system
# Cost in iteration 0: 0.09427094813867816
# Final cost : 0.09426774271161267
# Compute control for a deterministic system
# Cost in iteration 0: 0.09426774271161267
# Final cost : 0.09426320034209748
# Compute control for a deterministic system
# Cost in iteration 0: 0.1921959416525469
# Final cost : 0.09819975713763407
# Compute control for a deterministic system
# Cost in iteration 0: 0.09819975713763407
# Final cost : 0.09794153192779413
# Compute control for a deterministic system
# Cost in iteration 0: 0.09794153192779413
# Final cost : 0.0976394772098313
# Compute control for a deterministic system
# Cost in iteration 0: 0.0976394772098313
# Converged in iteration 135 with cost 0.09756780263181171 because of vanishing difference
# Final cost : 0.09756780263181171
# Compute control for a deterministic system
# Cost in iteration 0: 0.09756780263181171
# Final cost : 0.09755692291759442
# Compute control for a deterministic system
# Cost in iteration 0: 0.1284417581113156
# Final cost : 0.10144235733219696
# Compute control for a deterministic system
# Cost in iteration 0: 0.10144235733219696
# Final cost : 0.1014288106591986
# Compute control for a deterministic system
# Cost in iteration 0: 0.1014288106591986
# Converged in iteration 144 with cost 0.10142494330335314 because of vanishing difference
# Final cost : 0.10142494330335314
# Compute control for a deterministic system
# Cost in iteration 0: 0.10142494330335314
# Final cost : 0.10141285155531068
# Compute control for a deterministic system
# Cost in iteration 0: 0.10141285155531068
# Final cost : 0.10140880525524854
# Compute control for a deterministic system
# Cost in iteration 0: 0.22851944882001324
# Final cost : 0.10546494472477429
# Compute control for a deterministic system
# Cost in iteration 0: 0.10546494472477429
# Final cost : 0.1051702181589974
# Compute control for a deterministic system
# Cost in iteration 0: 0.1051702181589974
# Final cost : 0.10495369852528351
# Compute control for a deterministic system
# Cost in iteration 0: 0.10495369852528351
# Final cost : 0.10459833387636114
# Compute control for a deterministic system
# Cost in iteration 0: 0.10459833387636114
# Converged in iteration 39 with cost 0.10456719759799227 because of vanishing difference
# Final cost : 0.10456719759799227
# Compute control for a deterministic system
# Cost in iteration 0: 0.12930673819814464
# Final cost : 0.10770972380067333
# Compute control for a deterministic system
# Cost in iteration 0: 0.10770972380067333
# Final cost : 0.10767815847729191
# Compute control for a deterministic system
# Cost in iteration 0: 0.10767815847729191
# Final cost : 0.10767436019738572
# Compute control for a deterministic system
# Cost in iteration 0: 0.10767436019738572
# Final cost : 0.10766748519797852
# Compute control for a deterministic system
# Cost in iteration 0: 0.10766748519797852
# Final cost : 0.10766137378669366
# Compute control for a deterministic system
# Cost in iteration 0: 0.12948651430817765
# Final cost : 0.11077263263645383
# Compute control for a deterministic system
# Cost in iteration 0: 0.11077263263645383
# Final cost : 0.11076715946845546
# Compute control for a deterministic system
# Cost in iteration 0: 0.11076715946845546
# Final cost : 0.11076373407417602
# Compute control for a deterministic system
# Cost in iteration 0: 0.11076373407417602
# Final cost : 0.11075674320907954
# Compute control for a deterministic system
# Cost in iteration 0: 0.11075674320907954
# Final cost : 0.11074945117016506
# Compute control for a deterministic system
# Cost in iteration 0: 0.14298419721435368
# Final cost : 0.11452688418222791
# Compute control for a deterministic system
# Cost in iteration 0: 0.11452688418222791
# Final cost : 0.11451876622835816
# Compute control for a deterministic system
# Cost in iteration 0: 0.11451876622835816
# Final cost : 0.1145128872002033
# Compute control for a deterministic system
# Cost in iteration 0: 0.1145128872002033
# Final cost : 0.1144992572571892
# Compute control for a deterministic system
# Cost in iteration 0: 0.1144992572571892
# Final cost : 0.11448353742408138
# Compute control for a deterministic system
# Cost in iteration 0: 0.14738818347241345
# Final cost : 0.11766902083947042
# Compute control for a deterministic system
# Cost in iteration 0: 0.11766902083947042
# Final cost : 0.1175377295361791
# Compute control for a deterministic system
# Cost in iteration 0: 0.1175377295361791
# Converged in iteration 18 with cost 0.11753753905707726 because of vanishing difference
# Final cost : 0.11753753905707726
# Compute control for a deterministic system
# Cost in iteration 0: 0.11753753905707726
# Final cost : 0.11753216148422636
# Compute control for a deterministic system
# Cost in iteration 0: 0.11753216148422636
# Final cost : 0.11752615529991634
# Compute control for a deterministic system
# Cost in iteration 0: 0.13340879319835788
# Final cost : 0.12070817877326287
# Compute control for a deterministic system
# Cost in iteration 0: 0.12070817877326287
# Final cost : 0.1207007550315824
# Compute control for a deterministic system
# Cost in iteration 0: 0.1207007550315824
# Final cost : 0.12068931392080127
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068931392080127
# Final cost : 0.12067936262481053
# Compute control for a deterministic system
# Cost in iteration 0: 0.12067936262481053
# Final cost : 0.12066623115881288
# Compute control for a deterministic system
# Cost in iteration 0: 0.25014900646098936
# Final cost : 0.12385342453436259
# Compute control for a deterministic system
# Cost in iteration 0: 0.12385342453436259
# Final cost : 0.1238461627717607
# Compute control for a deterministic system
# Cost in iteration 0: 0.1238461627717607
# Converged in iteration 109 with cost 0.12384322581084846 because of vanishing difference
# Final cost : 0.12384322581084846
# Compute control for a deterministic system
# Cost in iteration 0: 0.12384322581084846
# Final cost : 0.12383093892462516
# Compute control for a deterministic system
# Cost in iteration 0: 0.12383093892462516
# Final cost : 0.12381544184709742
# Compute control for a deterministic system
# Cost in iteration 0: 1.6396194533364759
# Final cost : 0.22558711460390976
# Compute control for a deterministic system
# Cost in iteration 0: 0.22558711460390976
# Final cost : 0.195874647373306
# Compute control for a deterministic system
# Cost in iteration 0: 0.195874647373306
# Final cost : 0.18130920922977362
# Compute control for a deterministic system
# Cost in iteration 0: 0.18130920922977362
# Final cost : 0.16509381475873044
# Compute control for a deterministic system
# Cost in iteration 0: 0.16509381475873044
# Final cost : 0.1490683542210147
# Compute control for a deterministic system
# Cost in iteration 0: 0.6757029028767192
# Final cost : 0.13146024906188292
# Compute control for a deterministic system
# Cost in iteration 0: 0.13146024906188292
# Final cost : 0.13115700829137653
# Compute control for a deterministic system
# Cost in iteration 0: 0.13115700829137653
# Final cost : 0.13091480249758794
# Compute control for a deterministic system
# Cost in iteration 0: 0.13091480249758794
# Converged in iteration 34 with cost 0.13090408776690868 because of vanishing difference
# Final cost : 0.13090408776690868
# Compute control for a deterministic system
# Cost in iteration 0: 0.13090408776690868
# Final cost : 0.1308604881907038
# Compute control for a deterministic system
# Cost in iteration 0: 0.1481716631621594
# Final cost : 0.1341577893177536
# Compute control for a deterministic system
# Cost in iteration 0: 0.1341577893177536
# Final cost : 0.13414745160861602
# Compute control for a deterministic system
# Cost in iteration 0: 0.13414745160861602
# Final cost : 0.13413929376747089
# Compute control for a deterministic system
# Cost in iteration 0: 0.13413929376747089
# Final cost : 0.13411870819900637
# Compute control for a deterministic system
# Cost in iteration 0: 0.13411870819900637
# Final cost : 0.1340930084640737
# Compute control for a deterministic system
# Cost in iteration 0: 2.198965497256298
# Final cost : 0.27487392283737205
# Compute control for a deterministic system
# Cost in iteration 0: 0.27487392283737205
# Final cost : 0.2313721609618116
# Compute control for a deterministic system
# Cost in iteration 0: 0.2313721609618116
# Final cost : 0.20861828712232822
# Compute control for a deterministic system
# Cost in iteration 0: 0.20861828712232822
# Final cost : 0.18776727017237427
# Compute control for a deterministic system
# Cost in iteration 0: 0.18776727017237427
# Final cost : 0.17007981041027112
# Compute control for a deterministic system
# Cost in iteration 0: 0.1683745041451862
# Final cost : 0.14077065164458177
# Compute control for a deterministic system
# Cost in iteration 0: 0.14077065164458177
# Final cost : 0.14071738963373787
# Compute control for a deterministic system
# Cost in iteration 0: 0.14071738963373787
# Converged in iteration 109 with cost 0.1407110363854926 because of vanishing difference
# Final cost : 0.1407110363854926
# Compute control for a deterministic system
# Cost in iteration 0: 0.1407110363854926
# Final cost : 0.14067712133275842
# Compute control for a deterministic system
# Cost in iteration 0: 0.14067712133275842
# Final cost : 0.14064349869559625
# Compute control for a deterministic system
# Cost in iteration 0: 0.1650773212932547
# Final cost : 0.14419421286844303
# Compute control for a deterministic system
# Cost in iteration 0: 0.14419421286844303
# Final cost : 0.1441663453063367
# Compute control for a deterministic system
# Cost in iteration 0: 0.1441663453063367
# Final cost : 0.1441482663366138
# Compute control for a deterministic system
# Cost in iteration 0: 0.1441482663366138
# Final cost : 0.14406669401195057
# Compute control for a deterministic system
# Cost in iteration 0: 0.14406669401195057
# Final cost : 0.14402250896600358
# Compute control for a deterministic system
# Cost in iteration 0: 0.1525587297258443
# Final cost : 0.12128899245863863
# Compute control for a deterministic system
# Cost in iteration 0: 0.12128899245863863
# Final cost : 0.1211876996551719
# Compute control for a deterministic system
# Cost in iteration 0: 0.1211876996551719
# Final cost : 0.12118678075693941
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118678075693941
# Converged in iteration 222 with cost 0.12118675978400066 because of step counter
# Final cost : 0.12118675978400066
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118675978400066
# Converged in iteration 13 with cost 0.12118675978398415 because of step counter
# Final cost : 0.12118675978398415
# Compute control for a deterministic system
# Cost in iteration 0: 0.18648364182065605
# Final cost : 0.10286544400731633
# Compute control for a deterministic system
# Cost in iteration 0: 0.10286544400731633
# Final cost : 0.10282073836035659
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282073836035659
# Final cost : 0.10282063329707082
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282063329707082
# Converged in iteration 122 with cost 0.10282063246998958 because of step counter
# Final cost : 0.10282063246998958
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282063246998958
# Converged in iteration 4 with cost 0.1028206324699895 because of step counter
# Final cost : 0.1028206324699895
# Compute control for a deterministic system
# Cost in iteration 0: 0.1269797586549003
# Final cost : 0.08513606797195637
# Compute control for a deterministic system
# Cost in iteration 0: 0.08513606797195637
# Final cost : 0.0851165482829005
# Compute control for a deterministic system
# Cost in iteration 0: 0.0851165482829005
# Final cost : 0.08511654043062654
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654043062654
# Converged in iteration 80 with cost 0.08511654041560172 because of step counter
# Final cost : 0.08511654041560172
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654041560172
# Converged in iteration 1 with cost 0.08511654041560172 because of step counter
# Final cost : 0.08511654041560172
# Compute control for a deterministic system
# Cost in iteration 0: 0.12605495940606487
# Final cost : 0.06826781718896784
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826781718896784
# Final cost : 0.06826156213882434
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156213882434
# Final cost : 0.06826156179693202
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156179693202
# Converged in iteration 19 with cost 0.06826156179684235 because of step counter
# Final cost : 0.06826156179684235
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156179684235
# Converged in iteration 1 with cost 0.06826156179684235 because of step counter
# Final cost : 0.06826156179684235
# Compute control for a deterministic system
# Cost in iteration 0: 0.11647237222269154
# Final cost : 0.05241828230137594
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241828230137594
# Final cost : 0.052417283632740015
# Compute control for a deterministic system
# Cost in iteration 0: 0.052417283632740015
# Converged in iteration 90 with cost 0.052417283629803586 because of step counter
# Final cost : 0.052417283629803586
# Compute control for a deterministic system
# Cost in iteration 0: 0.052417283629803586
# Converged in iteration 1 with cost 0.052417283629803586 because of step counter
# Final cost : 0.052417283629803586
# Compute control for a deterministic system
# Cost in iteration 0: 0.052417283629803586
# Converged in iteration 1 with cost 0.052417283629803586 because of step counter
# Final cost : 0.052417283629803586
# Compute control for a deterministic system
# Cost in iteration 0: 0.13561935025228256
# Final cost : 0.034922256775301905
# Compute control for a deterministic system
# Cost in iteration 0: 0.034922256775301905
# Converged in iteration 154 with cost 0.034922232423004754 because of step counter
# Final cost : 0.034922232423004754
# Compute control for a deterministic system
# Cost in iteration 0: 0.034922232423004754
# Converged in iteration 1 with cost 0.034922232423004754 because of step counter
# Final cost : 0.034922232423004754
# Compute control for a deterministic system
# Cost in iteration 0: 0.034922232423004754
# Converged in iteration 1 with cost 0.034922232423004754 because of step counter
# Final cost : 0.034922232423004754
# Compute control for a deterministic system
# Cost in iteration 0: 0.034922232423004754
# Converged in iteration 2 with cost 0.03492223242300469 because of step counter
# Final cost : 0.03492223242300469
# Compute control for a deterministic system
# Cost in iteration 0: 0.08217026726708099
# Final cost : 0.021729052421204768
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729052421204768
# Converged in iteration 12 with cost 0.021729052415873928 because of step counter
# Final cost : 0.021729052415873928
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729052415873928
# Converged in iteration 2 with cost 0.021729052415873605 because of step counter
# Final cost : 0.021729052415873605
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729052415873605
# Converged in iteration 12 with cost 0.02172905241586607 because of step counter
# Final cost : 0.02172905241586607
# Compute control for a deterministic system
# Cost in iteration 0: 0.02172905241586607
# Converged in iteration 1 with cost 0.02172905241586607 because of step counter
# Final cost : 0.02172905241586607
# Compute control for a deterministic system
# Cost in iteration 0: 0.0637110690312296
# Converged in iteration 152 with cost 0.009921279163202259 because of step counter
# Final cost : 0.009921279163202259
# Compute control for a deterministic system
# Cost in iteration 0: 0.009921279163202259
# Converged in iteration 5 with cost 0.00992127916319812 because of step counter
# Final cost : 0.00992127916319812
# Compute control for a deterministic system
# Cost in iteration 0: 0.00992127916319812
# Converged in iteration 1 with cost 0.00992127916319812 because of step counter
# Final cost : 0.00992127916319812
# Compute control for a deterministic system
# Cost in iteration 0: 0.00992127916319812
# Converged in iteration 1 with cost 0.00992127916319812 because of step counter
# Final cost : 0.00992127916319812
# Compute control for a deterministic system
# Cost in iteration 0: 0.00992127916319812
# Converged in iteration 1 with cost 0.00992127916319812 because of step counter
# Final cost : 0.00992127916319812
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.07471758350750503
# Converged in iteration 126 with cost 0.02172905690599934 because of vanishing difference
# Final cost : 0.02172905690599934
# Compute control for a deterministic system
# Cost in iteration 0: 0.02172905690599934
# Converged in iteration 47 with cost 0.021729054332887146 because of step counter
# Final cost : 0.021729054332887146
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729054332887146
# Converged in iteration 1 with cost 0.021729054332887146 because of step counter
# Final cost : 0.021729054332887146
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729054332887146
# Converged in iteration 1 with cost 0.021729054332887146 because of step counter
# Final cost : 0.021729054332887146
# Compute control for a deterministic system
# Cost in iteration 0: 0.08582079699914959
# Final cost : 0.034922234063987874
# Compute control for a deterministic system
# Cost in iteration 0: 0.034922234063987874
# Converged in iteration 138 with cost 0.03492223402621824 because of step counter
# Final cost : 0.03492223402621824
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223402621824
# Converged in iteration 1 with cost 0.03492223402621824 because of step counter
# Final cost : 0.03492223402621824
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223402621824
# Converged in iteration 2 with cost 0.03492223402621817 because of step counter
# Final cost : 0.03492223402621817
# Compute control for a deterministic system
# Cost in iteration 0: 0.13795758921700899
# Converged in iteration 122 with cost 0.05241760336028112 because of vanishing difference
# Final cost : 0.05241760336028112
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241760336028112
# Final cost : 0.05241728906288942
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728906288942
# Converged in iteration 66 with cost 0.05241728905698204 because of step counter
# Final cost : 0.05241728905698204
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728905698204
# Converged in iteration 1 with cost 0.05241728905698204 because of step counter
# Final cost : 0.05241728905698204
# Compute control for a deterministic system
# Cost in iteration 0: 0.12042885089347327
# Converged in iteration 177 with cost 0.0682616413559384 because of vanishing difference
# Final cost : 0.0682616413559384
# Compute control for a deterministic system
# Cost in iteration 0: 0.0682616413559384
# Final cost : 0.06826156407604914
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156407604914
# Converged in iteration 81 with cost 0.06826156405360786 because of step counter
# Final cost : 0.06826156405360786
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156405360786
# Converged in iteration 1 with cost 0.06826156405360786 because of step counter
# Final cost : 0.06826156405360786
# Compute control for a deterministic system
# Cost in iteration 0: 0.12915046536947528
# Final cost : 0.08511680572374139
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511680572374139
# Final cost : 0.08511654580209282
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654580209282
# Converged in iteration 108 with cost 0.08511654531396406 because of step counter
# Final cost : 0.08511654531396406
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654531396406
# Converged in iteration 1 with cost 0.08511654531396406 because of step counter
# Final cost : 0.08511654531396406
# Compute control for a deterministic system
# Cost in iteration 0: 0.15972313097108548
# Final cost : 0.10282163432066958
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282163432066958
# Final cost : 0.10282064310794906
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282064310794906
# Converged in iteration 126 with cost 0.10282063549026471 because of vanishing difference
# Final cost : 0.10282063549026471
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282063549026471
# Converged in iteration 42 with cost 0.10282063549010786 because of step counter
# Final cost : 0.10282063549010786
# Compute control for a deterministic system
# Cost in iteration 0: 0.1512427736013365
# Final cost : 0.12118960515113272
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118960515113272
# Final cost : 0.12118682723841745
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118682723841745
# Converged in iteration 270 with cost 0.12118676686996929 because of step counter
# Final cost : 0.12118676686996929
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118676686996929
# Converged in iteration 3 with cost 0.1211867668699684 because of step counter
# Final cost : 0.1211867668699684
# Compute control for a deterministic system
# Cost in iteration 0: 0.20150037066811322
# Final cost : 0.1438263034654137
# Compute control for a deterministic system
# Cost in iteration 0: 0.1438263034654137
# Final cost : 0.14381627465846697
# Compute control for a deterministic system
# Cost in iteration 0: 0.14381627465846697
# Converged in iteration 360 with cost 0.14381572236660248 because of step counter
# Final cost : 0.14381572236660248
# Compute control for a deterministic system
# Cost in iteration 0: 0.14381572236660248
# Converged in iteration 1 with cost 0.14381572236660248 because of step counter
# Final cost : 0.14381572236660248
# Compute control for a deterministic system
# Cost in iteration 0: 0.21544032389446255
# Final cost : 0.1629652109508326
# Compute control for a deterministic system
# Cost in iteration 0: 0.1629652109508326
# Final cost : 0.1629515940931846
# Compute control for a deterministic system
# Cost in iteration 0: 0.1629515940931846
# Final cost : 0.16295021932709516
# Compute control for a deterministic system
# Cost in iteration 0: 0.16295021932709516
# Converged in iteration 4 with cost 0.16295021932708909 because of step counter
# Final cost : 0.16295021932708909
# Compute control for a deterministic system
# Cost in iteration 0: 0.21082401459022113
# Final cost : 0.13770340566542355
# Compute control for a deterministic system
# Cost in iteration 0: 0.13770340566542355
# Final cost : 0.13731149044354027
# Compute control for a deterministic system
# Cost in iteration 0: 0.13731149044354027
# Final cost : 0.13729895678528398
# Compute control for a deterministic system
# Cost in iteration 0: 0.13729895678528398
# Final cost : 0.13728199261946866
# Compute control for a deterministic system
# Cost in iteration 0: 0.25314929293618504
# Final cost : 0.13410019264126805
# Compute control for a deterministic system
# Cost in iteration 0: 0.13410019264126805
# Final cost : 0.13408752618841102
# Compute control for a deterministic system
# Cost in iteration 0: 0.13408752618841102
# Final cost : 0.13407562323299485
# Compute control for a deterministic system
# Cost in iteration 0: 0.13407562323299485
# Final cost : 0.13405757816042593
# Compute control for a deterministic system
# Cost in iteration 0: 0.24297436679920792
# Final cost : 0.13097270156676605
# Compute control for a deterministic system
# Cost in iteration 0: 0.13097270156676605
# Final cost : 0.13093924073123211
# Compute control for a deterministic system
# Cost in iteration 0: 0.13093924073123211
# Final cost : 0.13092362849087605
# Compute control for a deterministic system
# Cost in iteration 0: 0.13092362849087605
# Final cost : 0.13085186613850935
# Compute control for a deterministic system
# Cost in iteration 0: 0.3045225029620007
# Final cost : 0.12706551667489385
# Compute control for a deterministic system
# Cost in iteration 0: 0.12706551667489385
# Converged in iteration 137 with cost 0.12705593179621696 because of vanishing difference
# Final cost : 0.12705593179621696
# Compute control for a deterministic system
# Cost in iteration 0: 0.12705593179621696
# Final cost : 0.12703945636158767
# Compute control for a deterministic system
# Cost in iteration 0: 0.12703945636158767
# Final cost : 0.12700302069966982
# Compute control for a deterministic system
# Cost in iteration 0: 0.26063379126503916
# Final cost : 0.12441932460043331
# Compute control for a deterministic system
# Cost in iteration 0: 0.12441932460043331
# Final cost : 0.12410197426225335
# Compute control for a deterministic system
# Cost in iteration 0: 0.12410197426225335
# Converged in iteration 292 with cost 0.12389279796456998 because of vanishing difference
# Final cost : 0.12389279796456998
# Compute control for a deterministic system
# Cost in iteration 0: 0.12389279796456998
# Final cost : 0.12384706973502962
# Compute control for a deterministic system
# Cost in iteration 0: 0.16932948411944404
# Final cost : 0.12069184272682999
# Compute control for a deterministic system
# Cost in iteration 0: 0.12069184272682999
# Final cost : 0.12068501473915856
# Compute control for a deterministic system
# Cost in iteration 0: 0.12068501473915856
# Final cost : 0.12067835771248425
# Compute control for a deterministic system
# Cost in iteration 0: 0.12067835771248425
# Final cost : 0.1206676240329899
# Compute control for a deterministic system
# Cost in iteration 0: 0.14942940043433564
# Final cost : 0.11758791220157307
# Compute control for a deterministic system
# Cost in iteration 0: 0.11758791220157307
# Converged in iteration 55 with cost 0.11758516048049372 because of vanishing difference
# Final cost : 0.11758516048049372
# Compute control for a deterministic system
# Cost in iteration 0: 0.11758516048049372
# Final cost : 0.11757712631808345
# Compute control for a deterministic system
# Cost in iteration 0: 0.11757712631808345
# Final cost : 0.11756456557399339
# Compute control for a deterministic system
# Cost in iteration 0: 0.20590590989082452
# Final cost : 0.11448427608964881
# Compute control for a deterministic system
# Cost in iteration 0: 0.11448427608964881
# Converged in iteration 23 with cost 0.11448304485418603 because of vanishing difference
# Final cost : 0.11448304485418603
# Compute control for a deterministic system
# Cost in iteration 0: 0.11448304485418603
# Final cost : 0.1144744317559987
# Compute control for a deterministic system
# Cost in iteration 0: 0.1144744317559987
# Final cost : 0.11446368128683486
# Compute control for a deterministic system
# Cost in iteration 0: 0.13135544421425555
# Final cost : 0.11090620576680878
# Compute control for a deterministic system
# Cost in iteration 0: 0.11090620576680878
# Final cost : 0.1108694161758053
# Compute control for a deterministic system
# Cost in iteration 0: 0.1108694161758053
# Final cost : 0.11085284988069896
# Compute control for a deterministic system
# Cost in iteration 0: 0.11085284988069896
# Final cost : 0.11082760749166311
# Compute control for a deterministic system
# Cost in iteration 0: 0.13734621135432332
# Final cost : 0.10767239732922256
# Compute control for a deterministic system
# Cost in iteration 0: 0.10767239732922256
# Converged in iteration 61 with cost 0.10766847258209365 because of vanishing difference
# Final cost : 0.10766847258209365
# Compute control for a deterministic system
# Cost in iteration 0: 0.10766847258209365
# Final cost : 0.10766179015455069
# Compute control for a deterministic system
# Cost in iteration 0: 0.10766179015455069
# Final cost : 0.10765461980586341
# Compute control for a deterministic system
# Cost in iteration 0: 0.2624364392853467
# Final cost : 0.10457620373787312
# Compute control for a deterministic system
# Cost in iteration 0: 0.10457620373787312
# Converged in iteration 51 with cost 0.10456984318161665 because of vanishing difference
# Final cost : 0.10456984318161665
# Compute control for a deterministic system
# Cost in iteration 0: 0.10456984318161665
# Final cost : 0.10455989264396856
# Compute control for a deterministic system
# Cost in iteration 0: 0.10455989264396856
# Final cost : 0.10455272114772929
# Compute control for a deterministic system
# Cost in iteration 0: 0.18240522559247718
# Final cost : 0.10145706879705818
# Compute control for a deterministic system
# Cost in iteration 0: 0.10145706879705818
# Final cost : 0.10141890643466786
# Compute control for a deterministic system
# Cost in iteration 0: 0.10141890643466786
# Final cost : 0.10141162080037082
# Compute control for a deterministic system
# Cost in iteration 0: 0.10141162080037082
# Final cost : 0.10140639923598235
# Compute control for a deterministic system
# Cost in iteration 0: 0.2944872938460098
# Final cost : 0.10139605311658581
# Compute control for a deterministic system
# Cost in iteration 0: 0.10139605311658581
# Final cost : 0.09883026427743803
# Compute control for a deterministic system
# Cost in iteration 0: 0.09883026427743803
# Converged in iteration 211 with cost 0.09759227995084785 because of vanishing difference
# Final cost : 0.09759227995084785
# Compute control for a deterministic system
# Cost in iteration 0: 0.09759227995084785
# Final cost : 0.09756243824356348
# Compute control for a deterministic system
# Cost in iteration 0: 0.13628152988110392
# Final cost : 0.0943443377358873
# Compute control for a deterministic system
# Cost in iteration 0: 0.0943443377358873
# Final cost : 0.09428791081732532
# Compute control for a deterministic system
# Cost in iteration 0: 0.09428791081732532
# Converged in iteration 13 with cost 0.09428609932510994 because of vanishing difference
# Final cost : 0.09428609932510994
# Compute control for a deterministic system
# Cost in iteration 0: 0.09428609932510994
# Final cost : 0.09426484167225693
# Compute control for a deterministic system
# Cost in iteration 0: 0.11308040872620218
# Final cost : 0.09099654260143138
# Compute control for a deterministic system
# Cost in iteration 0: 0.09099654260143138
# Final cost : 0.09091181448829451
# Compute control for a deterministic system
# Cost in iteration 0: 0.09091181448829451
# Final cost : 0.09089058116598656
# Compute control for a deterministic system
# Cost in iteration 0: 0.09089058116598656
# Final cost : 0.0908822121933219
# Compute control for a deterministic system
# Cost in iteration 0: 0.09084490897633836
# Final cost : 0.08744509732933807
# Compute control for a deterministic system
# Cost in iteration 0: 0.08744509732933807
# Final cost : 0.08742136500853644
# Compute control for a deterministic system
# Cost in iteration 0: 0.08742136500853644
# Final cost : 0.08741057552117797
# Compute control for a deterministic system
# Cost in iteration 0: 0.08741057552117797
# Final cost : 0.0873989638710586
# Compute control for a deterministic system
# Cost in iteration 0: 0.09983929638967505
# Final cost : 0.08385812386357747
# Compute control for a deterministic system
# Cost in iteration 0: 0.08385812386357747
# Converged in iteration 70 with cost 0.08384167090052412 because of vanishing difference
# Final cost : 0.08384167090052412
# Compute control for a deterministic system
# Cost in iteration 0: 0.08384167090052412
# Final cost : 0.08381869873554952
# Compute control for a deterministic system
# Cost in iteration 0: 0.08381869873554952
# Final cost : 0.08380852807674183
# Compute control for a deterministic system
# Cost in iteration 0: 0.09029963244664344
# Final cost : 0.07937236323647204
# Compute control for a deterministic system
# Cost in iteration 0: 0.07937236323647204
# Final cost : 0.07933794793670015
# Compute control for a deterministic system
# Cost in iteration 0: 0.07933794793670015
# Final cost : 0.07932568885502693
# Compute control for a deterministic system
# Cost in iteration 0: 0.07932568885502693
# Final cost : 0.07931486388181476
# Compute control for a deterministic system
# Cost in iteration 0: 0.19717905138397893
# Final cost : 0.07540325055890897
# Compute control for a deterministic system
# Cost in iteration 0: 0.07540325055890897
# Converged in iteration 136 with cost 0.0753810911802216 because of vanishing difference
# Final cost : 0.0753810911802216
# Compute control for a deterministic system
# Cost in iteration 0: 0.0753810911802216
# Final cost : 0.07537179797010979
# Compute control for a deterministic system
# Cost in iteration 0: 0.07537179797010979
# Final cost : 0.07536289052778535
# Compute control for a deterministic system
# Cost in iteration 0: 0.1471155768390861
# Final cost : 0.07122928448968902
# Compute control for a deterministic system
# Cost in iteration 0: 0.07122928448968902
# Converged in iteration 45 with cost 0.07121799949166444 because of vanishing difference
# Final cost : 0.07121799949166444
# Compute control for a deterministic system
# Cost in iteration 0: 0.07121799949166444
# Final cost : 0.0712013014688077
# Compute control for a deterministic system
# Cost in iteration 0: 0.0712013014688077
# Final cost : 0.0711906680505915
# Compute control for a deterministic system
# Cost in iteration 0: 0.19612863436964123
# Final cost : 0.0667663571224924
# Compute control for a deterministic system
# Cost in iteration 0: 0.0667663571224924
# Final cost : 0.06675653512766219
# Compute control for a deterministic system
# Cost in iteration 0: 0.06675653512766219
# Converged in iteration 2 with cost 0.06675651545844975 because of vanishing difference
# Final cost : 0.06675651545844975
# Compute control for a deterministic system
# Cost in iteration 0: 0.06675651545844975
# Final cost : 0.06674165206107496
# Compute control for a deterministic system
# Cost in iteration 0: 0.1124211396322815
# Final cost : 0.06197474222302036
# Compute control for a deterministic system
# Cost in iteration 0: 0.06197474222302036
# Final cost : 0.06196449452809475
# Compute control for a deterministic system
# Cost in iteration 0: 0.06196449452809475
# Final cost : 0.06195240411650871
# Compute control for a deterministic system
# Cost in iteration 0: 0.06195240411650871
# Final cost : 0.06194785780141977
# Compute control for a deterministic system
# Cost in iteration 0: 0.1678971577116233
# Final cost : 0.055672289462149485
# Compute control for a deterministic system
# Cost in iteration 0: 0.055672289462149485
# Final cost : 0.05566156797251171
# Compute control for a deterministic system
# Cost in iteration 0: 0.05566156797251171
# Final cost : 0.05564660783350426
# Compute control for a deterministic system
# Cost in iteration 0: 0.05564660783350426
# Final cost : 0.05564637662347856
# Compute control for a deterministic system
# Cost in iteration 0: 0.07691654244269322
# Final cost : 0.0498435964158147
# Compute control for a deterministic system
# Cost in iteration 0: 0.0498435964158147
# Converged in iteration 33 with cost 0.049842494146126896 because of vanishing difference
# Final cost : 0.049842494146126896
# Compute control for a deterministic system
# Cost in iteration 0: 0.049842494146126896
# Final cost : 0.049836262705756064
# Compute control for a deterministic system
# Cost in iteration 0: 0.049836262705756064
# Final cost : 0.049834482778588554
# Compute control for a deterministic system
# Cost in iteration 0: 0.10625544129161248
# Final cost : 0.04344682918328854
# Compute control for a deterministic system
# Cost in iteration 0: 0.04344682918328854
# Final cost : 0.04344670169564588
# Compute control for a deterministic system
# Cost in iteration 0: 0.04344670169564588
# Final cost : 0.04344667996917083
# Compute control for a deterministic system
# Cost in iteration 0: 0.04344667996917083
# Final cost : 0.04344667871323884
# Compute control for a deterministic system
# Cost in iteration 0: 0.071478090472792
# Final cost : 0.03642063419033827
# Compute control for a deterministic system
# Cost in iteration 0: 0.03642063419033827
# Converged in iteration 37 with cost 0.03641930719717606 because of vanishing difference
# Final cost : 0.03641930719717606
# Compute control for a deterministic system
# Cost in iteration 0: 0.03641930719717606
# Final cost : 0.03641864848550302
# Compute control for a deterministic system
# Cost in iteration 0: 0.03641864848550302
# Converged in iteration 682 with cost 0.036418647424701675 because of step counter
# Final cost : 0.036418647424701675
# Compute control for a deterministic system
# Cost in iteration 0: 0.07259754927297712
# Converged in iteration 190 with cost 0.02866662652198787 because of vanishing difference
# Final cost : 0.02866662652198787
# Compute control for a deterministic system
# Cost in iteration 0: 0.02866662652198787
# Final cost : 0.028666427622870486
# Compute control for a deterministic system
# Cost in iteration 0: 0.028666427622870486
# Converged in iteration 235 with cost 0.028666426848231653 because of step counter
# Final cost : 0.028666426848231653
# Compute control for a deterministic system
# Cost in iteration 0: 0.028666426848231653
# Converged in iteration 1 with cost 0.028666426848231653 because of step counter
# Final cost : 0.028666426848231653
# Compute control for a deterministic system
# Cost in iteration 0: 0.08547831961228053
# Converged in iteration 102 with cost 0.018322103008454445 because of vanishing difference
# Final cost : 0.018322103008454445
# Compute control for a deterministic system
# Cost in iteration 0: 0.018322103008454445
# Converged in iteration 200 with cost 0.01832195474989035 because of step counter
# Final cost : 0.01832195474989035
# Compute control for a deterministic system
# Cost in iteration 0: 0.01832195474989035
# Converged in iteration 11 with cost 0.018321954749878317 because of step counter
# Final cost : 0.018321954749878317
# Compute control for a deterministic system
# Cost in iteration 0: 0.018321954749878317
# Converged in iteration 1 with cost 0.018321954749878317 because of step counter
# Final cost : 0.018321954749878317
# Compute control for a deterministic system
# Cost in iteration 0: 0.06984715266067336
# Converged in iteration 55 with cost 0.008926983105659711 because of vanishing difference
# Final cost : 0.008926983105659711
# Compute control for a deterministic system
# Cost in iteration 0: 0.008926983105659711
# Converged in iteration 56 with cost 0.008926981701884246 because of step counter
# Final cost : 0.008926981701884246
# Compute control for a deterministic system
# Cost in iteration 0: 0.008926981701884246
# Converged in iteration 1 with cost 0.008926981701884246 because of step counter
# Final cost : 0.008926981701884246
# Compute control for a deterministic system
# Cost in iteration 0: 0.008926981701884246
# Converged in iteration 1 with cost 0.008926981701884246 because of step counter
# Final cost : 0.008926981701884246
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.009265635437307459
# Converged in iteration 68 with cost 0.008926980785790403 because of vanishing difference
# ...
# Final cost : 0.10454529277729196
# Compute control for a deterministic system
# Cost in iteration 0: 0.10454529277729196
# Final cost : 0.10454521370526912
# -----------------------------------------------
# 5 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.11025976959257072
# Final cost : 0.10764883719146905
# Compute control for a deterministic system
# Cost in iteration 0: 0.10764883719146905
# Converged in iteration 2 with cost 0.10764883704639049 because of vanishing difference
# Final cost : 0.10764883704639049
# Compute control for a deterministic system
# Cost in iteration 0: 0.10764883704639049
# Final cost : 0.10764878112475082
# Compute control for a deterministic system
# Cost in iteration 0: 0.10764878112475082
# Final cost : 0.10764875613632917
# Compute control for a deterministic system
# Cost in iteration 0: 0.10764875613632917
# Final cost : 0.10764871309536693
# -----------------------------------------------
# 5 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.5309294982325764
# Final cost : 0.14702458359337198
# Compute control for a deterministic system
# Cost in iteration 0: 0.14702458359337198
# Final cost : 0.12783348211156442
# Compute control for a deterministic system
# Cost in iteration 0: 0.12783348211156442
# Final cost : 0.12013301014351942
# Compute control for a deterministic system
# Cost in iteration 0: 0.12013301014351942
# Converged in iteration 305 with cost 0.11465388705783859 because of vanishing difference
# Final cost : 0.11465388705783859
# Compute control for a deterministic system
# Cost in iteration 0: 0.11465388705783859
# Final cost : 0.11271269814197489
# Compute control for a deterministic system
# Cost in iteration 0: 0.13101223372426746
# Final cost : 0.11444410352235102
# Compute control for a deterministic system
# Cost in iteration 0: 0.11444410352235102
# Final cost : 0.11444351955743384
# Compute control for a deterministic system
# Cost in iteration 0: 0.11444351955743384
# Final cost : 0.1144426234124452
# Compute control for a deterministic system
# Cost in iteration 0: 0.1144426234124452
# Final cost : 0.11444170600816189
# Compute control for a deterministic system
# Cost in iteration 0: 0.11444170600816189
# Final cost : 0.11443990886650654
# -----------------------------------------------
# 5 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.13098591896179274
# Final cost : 0.11751882886023468
# Compute control for a deterministic system
# Cost in iteration 0: 0.11751882886023468
# Final cost : 0.11751874267226986
# Compute control for a deterministic system
# Cost in iteration 0: 0.11751874267226986
# Final cost : 0.1175186570254073
# Compute control for a deterministic system
# Cost in iteration 0: 0.1175186570254073
# Final cost : 0.11751859946141614
# Compute control for a deterministic system
# Cost in iteration 0: 0.11751859946141614
# Final cost : 0.1175185120282462
# -----------------------------------------------
# 5 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.13988732495674555
# Final cost : 0.12063056031070822
# Compute control for a deterministic system
# Cost in iteration 0: 0.12063056031070822
# Converged in iteration 58 with cost 0.12063045424956055 because of vanishing difference
# Final cost : 0.12063045424956055
# Compute control for a deterministic system
# Cost in iteration 0: 0.12063045424956055
# Final cost : 0.12063031846971255
# Compute control for a deterministic system
# Cost in iteration 0: 0.12063031846971255
# Final cost : 0.12063028747477587
# Compute control for a deterministic system
# Cost in iteration 0: 0.12063028747477587
# Final cost : 0.12063026740223186
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.23402171556899407
# Final cost : 0.12442582670738939
# Compute control for a deterministic system
# Cost in iteration 0: 0.12442582670738939
# Final cost : 0.12422882826918993
# Compute control for a deterministic system
# Cost in iteration 0: 0.12422882826918993
# Final cost : 0.12408777286830702
# Compute control for a deterministic system
# Cost in iteration 0: 0.12408777286830702
# Final cost : 0.12376934648019114
# Compute control for a deterministic system
# Cost in iteration 0: 0.12376934648019114
# Final cost : 0.12376856849632734
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.13638315643343804
# Final cost : 0.12693350857361796
# Compute control for a deterministic system
# Cost in iteration 0: 0.12693350857361796
# Final cost : 0.12693340061131167
# Compute control for a deterministic system
# Cost in iteration 0: 0.12693340061131167
# Final cost : 0.12693328182965624
# Compute control for a deterministic system
# Cost in iteration 0: 0.12693328182965624
# Final cost : 0.1269331347971463
# Compute control for a deterministic system
# Cost in iteration 0: 0.1269331347971463
# Final cost : 0.12693287900659006
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.14850961206413127
# Final cost : 0.13076816736017738
# Compute control for a deterministic system
# Cost in iteration 0: 0.13076816736017738
# Converged in iteration 190 with cost 0.13076800441937625 because of vanishing difference
# Final cost : 0.13076800441937625
# Compute control for a deterministic system
# Cost in iteration 0: 0.13076800441937625
# Final cost : 0.13076786659483716
# Compute control for a deterministic system
# Cost in iteration 0: 0.13076786659483716
# Final cost : 0.130767774162328
# Compute control for a deterministic system
# Cost in iteration 0: 0.130767774162328
# Final cost : 0.1307676075755587
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.18649108883088794
# Final cost : 0.1340010292245656
# Compute control for a deterministic system
# Cost in iteration 0: 0.1340010292245656
# Converged in iteration 116 with cost 0.1340008166854012 because of vanishing difference
# Final cost : 0.1340008166854012
# Compute control for a deterministic system
# Cost in iteration 0: 0.1340008166854012
# Final cost : 0.13400051810409128
# Compute control for a deterministic system
# Cost in iteration 0: 0.13400051810409128
# Final cost : 0.13400021381975052
# Compute control for a deterministic system
# Cost in iteration 0: 0.13400021381975052
# Final cost : 0.13399964454738722
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.1524156958553029
# Final cost : 0.137443108378619
# Compute control for a deterministic system
# Cost in iteration 0: 0.137443108378619
# Final cost : 0.13728650754306856
# Compute control for a deterministic system
# Cost in iteration 0: 0.13728650754306856
# Converged in iteration 75 with cost 0.13725355070942213 because of vanishing difference
# Final cost : 0.13725355070942213
# Compute control for a deterministic system
# Cost in iteration 0: 0.13725355070942213
# Final cost : 0.1372528666606784
# Compute control for a deterministic system
# Cost in iteration 0: 0.1372528666606784
# Final cost : 0.13725248839176063
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.3105039851209481
# Final cost : 0.1409924811115284
# Compute control for a deterministic system
# Cost in iteration 0: 0.1409924811115284
# Final cost : 0.14081473624322705
# Compute control for a deterministic system
# Cost in iteration 0: 0.14081473624322705
# Final cost : 0.1405921840012015
# Compute control for a deterministic system
# Cost in iteration 0: 0.1405921840012015
# Converged in iteration 44 with cost 0.14056032078333625 because of vanishing difference
# Final cost : 0.14056032078333625
# Compute control for a deterministic system
# Cost in iteration 0: 0.14056032078333625
# Final cost : 0.14055576363878972
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.14391492507044762
# Final cost : 0.14381568995127758
# Compute control for a deterministic system
# Cost in iteration 0: 0.14381568995127758
# Final cost : 0.14381568891712987
# Compute control for a deterministic system
# Cost in iteration 0: 0.14381568891712987
# Final cost : 0.1438156889081877
# Compute control for a deterministic system
# Cost in iteration 0: 0.1438156889081877
# Converged in iteration 34 with cost 0.14381568890768892 because of step counter
# Final cost : 0.14381568890768892
# Compute control for a deterministic system
# Cost in iteration 0: 0.14381568890768892
# Converged in iteration 1 with cost 0.14381568890768892 because of step counter
# Final cost : 0.14381568890768892
# Compute control for a deterministic system
# Cost in iteration 0: 0.12121199800859102
# Final cost : 0.12118676001796161
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118676001796161
# Final cost : 0.12118675978482428
# Compute control for a deterministic system
# Cost in iteration 0: 0.12118675978482428
# Converged in iteration 103 with cost 0.1211867597840785 because of step counter
# Final cost : 0.1211867597840785
# Compute control for a deterministic system
# Cost in iteration 0: 0.1211867597840785
# Converged in iteration 13 with cost 0.1211867597839623 because of step counter
# Final cost : 0.1211867597839623
# Compute control for a deterministic system
# Cost in iteration 0: 0.1211867597839623
# Converged in iteration 1 with cost 0.1211867597839623 because of step counter
# Final cost : 0.1211867597839623
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.1036054144151659
# Final cost : 0.1028206369328016
# Compute control for a deterministic system
# Cost in iteration 0: 0.1028206369328016
# Final cost : 0.10282063247587717
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282063247587717
# Final cost : 0.1028206324700036
# Compute control for a deterministic system
# Cost in iteration 0: 0.1028206324700036
# Converged in iteration 2 with cost 0.10282063247000245 because of step counter
# Final cost : 0.10282063247000245
# Compute control for a deterministic system
# Cost in iteration 0: 0.10282063247000245
# Converged in iteration 1 with cost 0.10282063247000245 because of step counter
# Final cost : 0.10282063247000245
# Compute control for a deterministic system
# Cost in iteration 0: 0.08620147527405816
# Final cost : 0.08511654376234337
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654376234337
# Final cost : 0.08511654041635287
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654041635287
# Converged in iteration 65 with cost 0.0851165404156922 because of step counter
# Final cost : 0.0851165404156922
# Compute control for a deterministic system
# Cost in iteration 0: 0.0851165404156922
# Converged in iteration 17 with cost 0.08511654041560761 because of step counter
# Final cost : 0.08511654041560761
# Compute control for a deterministic system
# Cost in iteration 0: 0.08511654041560761
# Converged in iteration 3 with cost 0.08511654041560596 because of step counter
# Final cost : 0.08511654041560596
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826247300018021
# Final cost : 0.0682615617980823
# Compute control for a deterministic system
# Cost in iteration 0: 0.0682615617980823
# Converged in iteration 68 with cost 0.06826156179684262 because of step counter
# Final cost : 0.06826156179684262
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156179684262
# Converged in iteration 7 with cost 0.06826156179683768 because of step counter
# Final cost : 0.06826156179683768
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156179683768
# Converged in iteration 2 with cost 0.06826156179683712 because of step counter
# Final cost : 0.06826156179683712
# Compute control for a deterministic system
# Cost in iteration 0: 0.06826156179683712
# Converged in iteration 1 with cost 0.06826156179683712 because of step counter
# Final cost : 0.06826156179683712
# Compute control for a deterministic system
# Cost in iteration 0: 0.05290076753648784
# Final cost : 0.05241728378184978
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728378184978
# Converged in iteration 124 with cost 0.05241728362982479 because of step counter
# Final cost : 0.05241728362982479
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728362982479
# Converged in iteration 1 with cost 0.05241728362982479 because of step counter
# Final cost : 0.05241728362982479
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728362982479
# Converged in iteration 1 with cost 0.05241728362982479 because of step counter
# Final cost : 0.05241728362982479
# Compute control for a deterministic system
# Cost in iteration 0: 0.05241728362982479
# Converged in iteration 1 with cost 0.05241728362982479 because of step counter
# Final cost : 0.05241728362982479
# Compute control for a deterministic system
# Cost in iteration 0: 0.035633500574502604
# Final cost : 0.03492223242618835
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223242618835
# Converged in iteration 28 with cost 0.03492223242302248 because of step counter
# Final cost : 0.03492223242302248
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223242302248
# Converged in iteration 11 with cost 0.03492223242300005 because of step counter
# Final cost : 0.03492223242300005
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223242300005
# Converged in iteration 1 with cost 0.03492223242300005 because of step counter
# Final cost : 0.03492223242300005
# Compute control for a deterministic system
# Cost in iteration 0: 0.03492223242300005
# Converged in iteration 1 with cost 0.03492223242300005 because of step counter
# Final cost : 0.03492223242300005
# Compute control for a deterministic system
# Cost in iteration 0: 0.022054651719987415
# Converged in iteration 178 with cost 0.02172905241587615 because of step counter
# Final cost : 0.02172905241587615
# Compute control for a deterministic system
# Cost in iteration 0: 0.02172905241587615
# Converged in iteration 6 with cost 0.02172905241586509 because of step counter
# Final cost : 0.02172905241586509
# Compute control for a deterministic system
# Cost in iteration 0: 0.02172905241586509
# Converged in iteration 2 with cost 0.021729052415864696 because of step counter
# Final cost : 0.021729052415864696
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729052415864696
# Converged in iteration 1 with cost 0.021729052415864696 because of step counter
# Final cost : 0.021729052415864696
# Compute control for a deterministic system
# Cost in iteration 0: 0.021729052415864696
# Converged in iteration 1 with cost 0.021729052415864696 because of step counter
# Final cost : 0.021729052415864696
# Compute control for a deterministic system
# Cost in iteration 0: 0.009942063211344354
# Converged in iteration 66 with cost 0.009921278885632481 because of step counter
# Final cost : 0.009921278885632481
# Compute control for a deterministic system
# Cost in iteration 0: 0.009921278885632481
# Converged in iteration 3 with cost 0.009921278885627181 because of step counter
# Final cost : 0.009921278885627181
# Compute control for a deterministic system
# Cost in iteration 0: 0.009921278885627181
# Converged in iteration 1 with cost 0.009921278885627181 because of step counter
# Final cost : 0.009921278885627181
# Compute control for a deterministic system
# Cost in iteration 0: 0.009921278885627181
# Converged in iteration 1 with cost 0.009921278885627181 because of step counter
# Final cost : 0.009921278885627181
# Compute control for a deterministic system
# Cost in iteration 0: 0.009921278885627181
# Converged in iteration 1 with cost 0.009921278885627181 because of step counter
# Final cost : 0.009921278885627181
# -----------------------------------------------
# 5 found better solution,  39

# %%
save(results_min)
