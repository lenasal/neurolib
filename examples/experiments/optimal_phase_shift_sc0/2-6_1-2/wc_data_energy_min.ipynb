# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period = ", period)

wc.run()
init_min = [wc.exc[0,194], wc.inh[0,194]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period =  20.816666666666666
# minima =  [ 191  400  608  816 1024 1232 1441 1649 1857 2065 2273 2481 2690 2898]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(41)
options = [True, True, False, False, True, False, False, False]
#options = [True, True, True, True, True, True, True, True]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

                factor = 0.95 + 0.1*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95 + 0.1*np.random.random())
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95 + 0.1*np.random.random())
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.control[0,1,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)


        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.05168574582430806
# Final cost : 0.0001391330583073651
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001391330583073651
# Final cost : 0.00012688495225498468
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012688495225498468
# Final cost : 0.00012046013482451908
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012046013482451908
# Final cost : 0.00011904839603849795
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011904839603849795
# Final cost : 0.0001186836600149852
# Compute control for a deterministic system
# Cost in iteration 0: 0.0951274987902088
# Final cost : 0.0003079951969096522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003079951969096522
# Final cost : 0.0002830029185929224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002830029185929224
# Final cost : 0.00026766630724116297
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026766630724116297
# Final cost : 0.00026562734740727704
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026562734740727704
# Final cost : 0.00026490409673817395
# Compute control for a deterministic system
# Cost in iteration 0: 0.07997249992264013
# Final cost : 0.000423508745613764
# Compute control for a deterministic system
# Cost in iteration 0: 0.000423508745613764
# Final cost : 0.0004157559190157268
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004157559190157268
# Final cost : 0.0004122936917863171
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004122936917863171
# Final cost : 0.0004106606433438344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004106606433438344
# Final cost : 0.0004101566863513595
# Compute control for a deterministic system
# Cost in iteration 0: 0.03153518290230863
# Final cost : 0.000576802445728229
# Compute control for a deterministic system
# Cost in iteration 0: 0.000576802445728229
# Final cost : 0.0005723959436674245
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005723959436674245
# Final cost : 0.000570372089608342
# Compute control for a deterministic system
# Cost in iteration 0: 0.000570372089608342
# Final cost : 0.0005693553721865943
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005693553721865943
# Final cost : 0.0005690294697718989
# Compute control for a deterministic system
# Cost in iteration 0: 0.03051871144772925
# Final cost : 0.0007500401602488628
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007500401602488628
# Final cost : 0.0007436807503659322
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007436807503659322
# Final cost : 0.0007394450453333921
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007394450453333921
# Final cost : 0.0007378533560783828
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007378533560783828
# Final cost : 0.0007373574462025792
# Compute control for a deterministic system
# Cost in iteration 0: 0.03301353733516838
# Final cost : 0.0009268595878608683
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009268595878608683
# Final cost : 0.0009180513191369681
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009180513191369681
# Final cost : 0.0009148275410856857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009148275410856857
# Final cost : 0.0009136210200039739
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009136210200039739
# Final cost : 0.0009129033123602603
# Compute control for a deterministic system
# Cost in iteration 0: 0.10858597245221933
# Final cost : 0.0014542572375330287
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014542572375330287
# Final cost : 0.0012286163569375757
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012286163569375757
# Final cost : 0.0011814063029157095
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011814063029157095
# Final cost : 0.0011532535612281672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011532535612281672
# Final cost : 0.0011338717838289129
# Compute control for a deterministic system
# Cost in iteration 0: 0.0898958806932672
# Final cost : 0.0017843008318054515
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017843008318054515
# Final cost : 0.0013656101128711527
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013656101128711527
# Final cost : 0.0013363777237643151
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013363777237643151
# Final cost : 0.0013254398992841247
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013254398992841247
# Final cost : 0.0013172535876172374
# Compute control for a deterministic system
# Cost in iteration 0: 0.035793671224721796
# Final cost : 0.0015234799725476202
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015234799725476202
# Final cost : 0.0015113670529372713
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015113670529372713
# Final cost : 0.0015089589144816117
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015089589144816117
# Final cost : 0.0015075970584796541
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015075970584796541
# Final cost : 0.0015060716364938584
# Compute control for a deterministic system
# Cost in iteration 0: 0.13470778229926383
# Final cost : 0.0029329372279988286
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029329372279988286
# Final cost : 0.0023144372647435495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023144372647435495
# Final cost : 0.0017866069791683049
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017866069791683049
# Final cost : 0.0017384274274899311
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017384274274899311
# Final cost : 0.0017066961248420607
# Compute control for a deterministic system
# Cost in iteration 0: 0.18215628732279235
# Final cost : 0.003755201076501792
# Compute control for a deterministic system
# Cost in iteration 0: 0.003755201076501792
# Final cost : 0.0029309317540492682
# Compute control for a deterministic system
# Cost in iteration 0: 0.0029309317540492682
# Final cost : 0.002291388404126634
# Compute control for a deterministic system
# Cost in iteration 0: 0.002291388404126634
# Final cost : 0.00203432003240648
# Compute control for a deterministic system
# Cost in iteration 0: 0.00203432003240648
# Final cost : 0.0019435278201749187
# Compute control for a deterministic system
# Cost in iteration 0: 0.087035587730565
# Final cost : 0.003029255706584697
# Compute control for a deterministic system
# Cost in iteration 0: 0.003029255706584697
# Final cost : 0.002429455689823444
# Compute control for a deterministic system
# Cost in iteration 0: 0.002429455689823444
# Final cost : 0.0021711592563324915
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021711592563324915
# Final cost : 0.0021560163689117217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021560163689117217
# Final cost : 0.0021417369002489713
# Compute control for a deterministic system
# Cost in iteration 0: 0.008782316587429766
# Final cost : 0.0023141495398876937
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023141495398876937
# Final cost : 0.002305019444238195
# Compute control for a deterministic system
# Cost in iteration 0: 0.002305019444238195
# Final cost : 0.0023036133492262984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023036133492262984
# Final cost : 0.002303186027105133
# Compute control for a deterministic system
# Cost in iteration 0: 0.002303186027105133
# Final cost : 0.0023028182340089874
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.03202668648969953
# Final cost : 0.0039248177206220565
# Compute control for a deterministic system
# Cost in iteration 0: 0.0039248177206220565
# Final cost : 0.003440009686645158
# Compute control for a deterministic system
# Cost in iteration 0: 0.003440009686645158
# Final cost : 0.0025203792264550553
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025203792264550553
# Final cost : 0.002497704880636004
# Compute control for a deterministic system
# Cost in iteration 0: 0.002497704880636004
# Final cost : 0.0024920024374400153
# Compute control for a deterministic system
# Cost in iteration 0: 0.01841068694899665
# Final cost : 0.0026885862184135856
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026885862184135856
# Final cost : 0.002680144898777501
# Compute control for a deterministic system
# Cost in iteration 0: 0.002680144898777501
# Final cost : 0.0026767920836536893
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026767920836536893
# Final cost : 0.002675266557058691
# Compute control for a deterministic system
# Cost in iteration 0: 0.002675266557058691
# Final cost : 0.0026741475166381493
# Compute control for a deterministic system
# Cost in iteration 0: 0.013873796264850557
# Final cost : 0.0028761826467097805
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028761826467097805
# Final cost : 0.0028665847578534984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028665847578534984
# Final cost : 0.0028630366972045985
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028630366972045985
# Final cost : 0.002860549896410341
# Compute control for a deterministic system
# Cost in iteration 0: 0.002860549896410341
# Final cost : 0.0028591966949323864
# Compute control for a deterministic system
# Cost in iteration 0: 0.03626369807938162
# Final cost : 0.0031109356451887336
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031109356451887336
# Final cost : 0.0030955561256001845
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030955561256001845
# Final cost : 0.00308845323430953
# Compute control for a deterministic system
# Cost in iteration 0: 0.00308845323430953
# Final cost : 0.003083766192720304
# Compute control for a deterministic system
# Cost in iteration 0: 0.003083766192720304
# Final cost : 0.0030810216346898343
# Compute control for a deterministic system
# Cost in iteration 0: 0.02713114794037596
# Final cost : 0.0032904946190536184
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032904946190536184
# Final cost : 0.003277201772616483
# Compute control for a deterministic system
# Cost in iteration 0: 0.003277201772616483
# Final cost : 0.003271108768054053
# Compute control for a deterministic system
# Cost in iteration 0: 0.003271108768054053
# Final cost : 0.003267205954612429
# Compute control for a deterministic system
# Cost in iteration 0: 0.003267205954612429
# Final cost : 0.0032652898265511546
# Compute control for a deterministic system
# Cost in iteration 0: 0.14494032597459983
# Final cost : 0.003510393156190007
# Compute control for a deterministic system
# Cost in iteration 0: 0.003510393156190007
# Final cost : 0.0034650063877263893
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034650063877263893
# Final cost : 0.003456502451023521
# Compute control for a deterministic system
# Cost in iteration 0: 0.003456502451023521
# Final cost : 0.00345024362251744
# Compute control for a deterministic system
# Cost in iteration 0: 0.00345024362251744
# Final cost : 0.003445515626432567
# Compute control for a deterministic system
# Cost in iteration 0: 0.007963774946194425
# Final cost : 0.0036430104741418455
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036430104741418455
# Final cost : 0.003630810136762833
# Compute control for a deterministic system
# Cost in iteration 0: 0.003630810136762833
# Final cost : 0.0036261157651292096
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036261157651292096
# Final cost : 0.0036242125215052027
# Compute control for a deterministic system
# Cost in iteration 0: 0.0036242125215052027
# Final cost : 0.00362316273652487
# Compute control for a deterministic system
# Cost in iteration 0: 0.5246177403482569
# Final cost : 0.009784135967597711
# Compute control for a deterministic system
# Cost in iteration 0: 0.009784135967597711
# Final cost : 0.008282940142711711
# Compute control for a deterministic system
# Cost in iteration 0: 0.008282940142711711
# Final cost : 0.007129943072205106
# Compute control for a deterministic system
# Cost in iteration 0: 0.007129943072205106
# Final cost : 0.005633338330043775
# Compute control for a deterministic system
# Cost in iteration 0: 0.005633338330043775
# Final cost : 0.004326786083642626
# Compute control for a deterministic system
# Cost in iteration 0: 0.021201983951263326
# Final cost : 0.004038674640748676
# Compute control for a deterministic system
# Cost in iteration 0: 0.004038674640748676
# Final cost : 0.00403017252519613
# Compute control for a deterministic system
# Cost in iteration 0: 0.00403017252519613
# Final cost : 0.004026207470195513
# Compute control for a deterministic system
# Cost in iteration 0: 0.004026207470195513
# Final cost : 0.004024406871031019
# Compute control for a deterministic system
# Cost in iteration 0: 0.004024406871031019
# Final cost : 0.004023130641903944
# Compute control for a deterministic system
# Cost in iteration 0: 0.09585043523444216
# Final cost : 0.0042715247782495
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042715247782495
# Final cost : 0.004224038583860812
# Compute control for a deterministic system
# Cost in iteration 0: 0.004224038583860812
# Final cost : 0.004218427009533337
# Compute control for a deterministic system
# Cost in iteration 0: 0.004218427009533337
# Final cost : 0.004213198336218815
# Compute control for a deterministic system
# Cost in iteration 0: 0.004213198336218815
# Final cost : 0.004209692391333989
# Compute control for a deterministic system
# Cost in iteration 0: 0.02264022720584047
# Final cost : 0.004408008841113514
# Compute control for a deterministic system
# Cost in iteration 0: 0.004408008841113514
# Final cost : 0.004402656710333532
# Compute control for a deterministic system
# Cost in iteration 0: 0.004402656710333532
# Final cost : 0.004400211324226269
# Compute control for a deterministic system
# Cost in iteration 0: 0.004400211324226269
# Final cost : 0.004398776345835675
# Compute control for a deterministic system
# Cost in iteration 0: 0.004398776345835675
# Final cost : 0.004397098779165091
# Compute control for a deterministic system
# Cost in iteration 0: 0.01842274963210392
# Final cost : 0.004596140209935703
# Compute control for a deterministic system
# Cost in iteration 0: 0.004596140209935703
# Final cost : 0.0045917247765658005
# Compute control for a deterministic system
# Cost in iteration 0: 0.0045917247765658005
# Final cost : 0.004590500011437589
# Compute control for a deterministic system
# Cost in iteration 0: 0.004590500011437589
# Final cost : 0.0045896222222422435
# Compute control for a deterministic system
# Cost in iteration 0: 0.0045896222222422435
# Final cost : 0.0045888345366666295
# Compute control for a deterministic system
# Cost in iteration 0: 0.9210928062097217
# Final cost : 0.012948888036910303
# Compute control for a deterministic system
# Cost in iteration 0: 0.012948888036910303
# Final cost : 0.011836631587933934
# Compute control for a deterministic system
# Cost in iteration 0: 0.011836631587933934
# Final cost : 0.01049106848360989
# Compute control for a deterministic system
# Cost in iteration 0: 0.01049106848360989
# Final cost : 0.008950173093993078
# Compute control for a deterministic system
# Cost in iteration 0: 0.008950173093993078
# Final cost : 0.00648521491245692
# Compute control for a deterministic system
# Cost in iteration 0: 0.029167595520805046
# Final cost : 0.0050721514571782506
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050721514571782506
# Final cost : 0.0050628930580282555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0050628930580282555
# Final cost : 0.005059684330930301
# Compute control for a deterministic system
# Cost in iteration 0: 0.005059684330930301
# Final cost : 0.005057155431706693
# Compute control for a deterministic system
# Cost in iteration 0: 0.005057155431706693
# Final cost : 0.005054326796487222
# Compute control for a deterministic system
# Cost in iteration 0: 0.2069282718312324
# Final cost : 0.005763932602057639
# Compute control for a deterministic system
# Cost in iteration 0: 0.005763932602057639
# Final cost : 0.005345771089803807
# Compute control for a deterministic system
# Cost in iteration 0: 0.005345771089803807
# Final cost : 0.005318158249248965
# Compute control for a deterministic system
# Cost in iteration 0: 0.005318158249248965
# Final cost : 0.005309440118124715
# Compute control for a deterministic system
# Cost in iteration 0: 0.005309440118124715
# Final cost : 0.005300943388010187
# Compute control for a deterministic system
# Cost in iteration 0: 0.05981477365161448
# Final cost : 0.0059006595276797835
# Compute control for a deterministic system
# Cost in iteration 0: 0.0059006595276797835
# Final cost : 0.005561167854562034
# Compute control for a deterministic system
# Cost in iteration 0: 0.005561167854562034
# Final cost : 0.005559037914796464
# Compute control for a deterministic system
# Cost in iteration 0: 0.005559037914796464
# Final cost : 0.0055569390479130645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0055569390479130645
# Final cost : 0.0055536964989102615
# Compute control for a deterministic system
# Cost in iteration 0: 0.01589212108336938
# Final cost : 0.005814796867565247
# Compute control for a deterministic system
# Cost in iteration 0: 0.005814796867565247
# Final cost : 0.005810054420539723
# Compute control for a deterministic system
# Cost in iteration 0: 0.005810054420539723
# Final cost : 0.005808713813190965
# Compute control for a deterministic system
# Cost in iteration 0: 0.005808713813190965
# Final cost : 0.005807883325055128
# Compute control for a deterministic system
# Cost in iteration 0: 0.005807883325055128
# Final cost : 0.005806331906058017
# Compute control for a deterministic system
# Cost in iteration 0: 0.22900316176772642
# Final cost : 0.006225465814943816
# Compute control for a deterministic system
# Cost in iteration 0: 0.006225465814943816
# Final cost : 0.006191122359072514
# Compute control for a deterministic system
# Cost in iteration 0: 0.006191122359072514
# Final cost : 0.006179074440299123
# Compute control for a deterministic system
# Cost in iteration 0: 0.006179074440299123
# Final cost : 0.006168690614950377
# Compute control for a deterministic system
# Cost in iteration 0: 0.006168690614950377
# Final cost : 0.006158339903749989
# -----------------------------------------------
# 0 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 1.8356043855249824
# Final cost : 0.40497555405513974
# Compute control for a deterministic system
# Cost in iteration 0: 0.40497555405513974
# Final cost : 0.36895252739178974
# Compute control for a deterministic system
# Cost in iteration 0: 0.36895252739178974
# Final cost : 0.17322575053369915
# Compute control for a deterministic system
# Cost in iteration 0: 0.17322575053369915
# Final cost : 0.10579322111947016
# Compute control for a deterministic system
# Cost in iteration 0: 0.10579322111947016
# Final cost : 0.045562997635600413
# Compute control for a deterministic system
# Cost in iteration 0: 0.09282307461578135
# Final cost : 0.003241879155855114
# Compute control for a deterministic system
# Cost in iteration 0: 0.003241879155855114
# Final cost : 0.0031962975260334224
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031962975260334224
# Final cost : 0.003178145201563353
# Compute control for a deterministic system
# Cost in iteration 0: 0.003178145201563353
# Final cost : 0.003173634339759851
# Compute control for a deterministic system
# Cost in iteration 0: 0.003173634339759851
# Final cost : 0.0031727122470342345
# Compute control for a deterministic system
# Cost in iteration 0: 0.06140378367076848
# Final cost : 0.0020675953151954186
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020675953151954186
# Final cost : 0.0020371276512727364
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020371276512727364
# Final cost : 0.0020247035860925856
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020247035860925856
# Final cost : 0.0020220092420444725
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020220092420444725
# Final cost : 0.002021768505318802
# Compute control for a deterministic system
# Cost in iteration 0: 0.043671360217199966
# Final cost : 0.0012124350343140826
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012124350343140826
# Final cost : 0.0011924392007321473
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011924392007321473
# Final cost : 0.001184414777610879
# Compute control for a deterministic system
# Cost in iteration 0: 0.001184414777610879
# Final cost : 0.001182678778700775
# Compute control for a deterministic system
# Cost in iteration 0: 0.001182678778700775
# Final cost : 0.0011824892623525846
# Compute control for a deterministic system
# Cost in iteration 0: 0.0700492623402638
# Final cost : 0.0005539512151587477
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005539512151587477
# Final cost : 0.0005346378997093679
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005346378997093679
# Final cost : 0.000527124813793957
# Compute control for a deterministic system
# Cost in iteration 0: 0.000527124813793957
# Final cost : 0.000524686367720032
# Compute control for a deterministic system
# Cost in iteration 0: 0.000524686367720032
# Final cost : 0.0005242287225910394
# Compute control for a deterministic system
# Cost in iteration 0: 0.04139980301520858
# Final cost : 0.00022122871962974952
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022122871962974952
# Final cost : 0.0002107175189141141
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002107175189141141
# Final cost : 0.00020823685523509397
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020823685523509397
# Final cost : 0.00020734627693690217
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020734627693690217
# Final cost : 0.00020720616573046907
# Compute control for a deterministic system
# Cost in iteration 0: 0.0481277590538039
# Final cost : 5.068901700136158e-05
# Compute control for a deterministic system
# Cost in iteration 0: 5.068901700136158e-05
# Final cost : 4.851872069339984e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.851872069339984e-05
# Final cost : 4.758066635140705e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.758066635140705e-05
# Final cost : 4.719673895959342e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.719673895959342e-05
# Final cost : 4.714383643982309e-05
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.052630413390638967
# Final cost : 0.0002129502413470979
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002129502413470979
# Final cost : 0.00020873461287673132
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020873461287673132
# Final cost : 0.00020736661490049096
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020736661490049096
# Final cost : 0.00020720770307749935
# Compute control for a deterministic system
# Cost in iteration 0: 0.04721928648066993
# Final cost : 0.0005297031257818579
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005297031257818579
# Final cost : 0.0005256266920064854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005256266920064854
# Final cost : 0.0005244091388300521
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005244091388300521
# Final cost : 0.0005242232170469997
# Compute control for a deterministic system
# Cost in iteration 0: 0.08605555797832072
# Final cost : 0.001237957482042515
# Compute control for a deterministic system
# Cost in iteration 0: 0.001237957482042515
# Final cost : 0.0011837623507095865
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011837623507095865
# Final cost : 0.0011825849594226342
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011825849594226342
# Final cost : 0.001182485738107608
# Compute control for a deterministic system
# Cost in iteration 0: 0.04441967472460141
# Final cost : 0.0020475163460862175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020475163460862175
# Final cost : 0.002025017554530908
# Compute control for a deterministic system
# Cost in iteration 0: 0.002025017554530908
# Final cost : 0.0020221309708727494
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020221309708727494
# Final cost : 0.0020217713279382437
# Compute control for a deterministic system
# Cost in iteration 0: 0.039010286742350415
# Final cost : 0.003200468007462057
# Compute control for a deterministic system
# Cost in iteration 0: 0.003200468007462057
# Final cost : 0.0031773717495747304
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031773717495747304
# Final cost : 0.0031732334100408265
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031732334100408265
# Final cost : 0.0031727002767806857
# Compute control for a deterministic system
# Cost in iteration 0: 0.06610868614400142
# Final cost : 0.004697368751891063
# Compute control for a deterministic system
# Cost in iteration 0: 0.004697368751891063
# Final cost : 0.004675666874617328
# Compute control for a deterministic system
# Cost in iteration 0: 0.004675666874617328
# Final cost : 0.004670479076834611
# Compute control for a deterministic system
# Cost in iteration 0: 0.004670479076834611
# Final cost : 0.004669270809165313
# Compute control for a deterministic system
# Cost in iteration 0: 0.04953381380080799
# Final cost : 0.006588667961573252
# Compute control for a deterministic system
# Cost in iteration 0: 0.006588667961573252
# Final cost : 0.006540654941846758
# Compute control for a deterministic system
# Cost in iteration 0: 0.006540654941846758
# Final cost : 0.006534667423462022
# Compute control for a deterministic system
# Cost in iteration 0: 0.006534667423462022
# Final cost : 0.006533735212438264
# Compute control for a deterministic system
# Cost in iteration 0: 0.14933212672080132
# Final cost : 0.005817911215041909
# Compute control for a deterministic system
# Cost in iteration 0: 0.005817911215041909
# Final cost : 0.0058073768592575735
# Compute control for a deterministic system
# Cost in iteration 0: 0.0058073768592575735
# Final cost : 0.005802244821457333
# Compute control for a deterministic system
# Cost in iteration 0: 0.005802244821457333
# Final cost : 0.005795140535662866
# Compute control for a deterministic system
# Cost in iteration 0: 0.6302086203336124
# Final cost : 0.020056701938713478
# Compute control for a deterministic system
# Cost in iteration 0: 0.020056701938713478
# Final cost : 0.013606471676009438
# Compute control for a deterministic system
# Cost in iteration 0: 0.013606471676009438
# Final cost : 0.011287620173210233
# Compute control for a deterministic system
# Cost in iteration 0: 0.011287620173210233
# Final cost : 0.009407259172742535
# Compute control for a deterministic system
# Cost in iteration 0: 0.008386021759458857
# Final cost : 0.005336580387997232
# Compute control for a deterministic system
# Cost in iteration 0: 0.005336580387997232
# Final cost : 0.005314096145143587
# Compute control for a deterministic system
# Cost in iteration 0: 0.005314096145143587
# Final cost : 0.005297948794359079
# Compute control for a deterministic system
# Cost in iteration 0: 0.005297948794359079
# Final cost : 0.00529062235659487
# Compute control for a deterministic system
# Cost in iteration 0: 0.8023347178103271
# Final cost : 0.019406692349664027
# Compute control for a deterministic system
# Cost in iteration 0: 0.019406692349664027
# Final cost : 0.015935571309059694
# Compute control for a deterministic system
# Cost in iteration 0: 0.015935571309059694
# Final cost : 0.012535831335188026
# Compute control for a deterministic system
# Cost in iteration 0: 0.012535831335188026
# Final cost : 0.00977815485633241
# Compute control for a deterministic system
# Cost in iteration 0: 0.13819085406306153
# Final cost : 0.004838466860886587
# Compute control for a deterministic system
# Cost in iteration 0: 0.004838466860886587
# Final cost : 0.004835575339213834
# Compute control for a deterministic system
# Cost in iteration 0: 0.004835575339213834
# Final cost : 0.004834525046352243
# Compute control for a deterministic system
# Cost in iteration 0: 0.004834525046352243
# Final cost : 0.004833624671980869
# Compute control for a deterministic system
# Cost in iteration 0: 0.18369258252660386
# Final cost : 0.004601370833573165
# Compute control for a deterministic system
# Cost in iteration 0: 0.004601370833573165
# Final cost : 0.004598152061058285
# Compute control for a deterministic system
# Cost in iteration 0: 0.004598152061058285
# Final cost : 0.00459656898484611
# Compute control for a deterministic system
# Cost in iteration 0: 0.00459656898484611
# Final cost : 0.004594993465291337
# Compute control for a deterministic system
# Cost in iteration 0: 0.1256505310482977
# Final cost : 0.00439796992062432
# Compute control for a deterministic system
# Cost in iteration 0: 0.00439796992062432
# Final cost : 0.004396420545836838
# Compute control for a deterministic system
# Cost in iteration 0: 0.004396420545836838
# Final cost : 0.004395784937538048
# Compute control for a deterministic system
# Cost in iteration 0: 0.004395784937538048
# Final cost : 0.00439507940642585
# -----------------------------------------------
# 1 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.1528178676316681
# Final cost : 0.004247543740601138
# Compute control for a deterministic system
# Cost in iteration 0: 0.004247543740601138
# Final cost : 0.0042351706355681805
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042351706355681805
# Final cost : 0.0042285225980421325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0042285225980421325
# Final cost : 0.004220440043211171
# Compute control for a deterministic system
# Cost in iteration 0: 0.1121333586914252
# Final cost : 0.004037046703770442
# Compute control for a deterministic system
# Cost in iteration 0: 0.004037046703770442
# Final cost : 0.0040336245125702245
# Compute control for a deterministic system
# Cost in iteration 0: 0.0040336245125702245
# Final cost : 0.004028798094415619
# Compute control for a deterministic system
# Cost in iteration 0: 0.004028798094415619
# Final cost : 0.004025240011074448
# Compute control for a deterministic system
# Cost in iteration 0: 0.07838337258338914
# Final cost : 0.0038720170027385175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038720170027385175
# Final cost : 0.0038534252808302026
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038534252808302026
# Final cost : 0.003829105087997858
# Compute control for a deterministic system
# Cost in iteration 0: 0.003829105087997858
# Final cost : 0.0038109010046088465
# Compute control for a deterministic system
# Cost in iteration 0: 0.16630565262987787
# Final cost : 0.003643440030530227
# Compute control for a deterministic system
# Cost in iteration 0: 0.003643440030530227
# Final cost : 0.00363656539963883
# Compute control for a deterministic system
# Cost in iteration 0: 0.00363656539963883
# Final cost : 0.003633126084660759
# Compute control for a deterministic system
# Cost in iteration 0: 0.003633126084660759
# Final cost : 0.003628570570733693
# Compute control for a deterministic system
# Cost in iteration 0: 0.0688540398401177
# Final cost : 0.003968543117941965
# Compute control for a deterministic system
# Cost in iteration 0: 0.003968543117941965
# Final cost : 0.0034549014135951497
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034549014135951497
# Final cost : 0.0034478791940509607
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034478791940509607
# Final cost : 0.0034415037292538668
# Compute control for a deterministic system
# Cost in iteration 0: 0.16986942224327475
# Final cost : 0.0032809354533938325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032809354533938325
# Final cost : 0.0032729117384449322
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032729117384449322
# Final cost : 0.003269378595165797
# Compute control for a deterministic system
# Cost in iteration 0: 0.003269378595165797
# Final cost : 0.0032651572335103962
# Compute control for a deterministic system
# Cost in iteration 0: 0.03726908043448611
# Final cost : 0.0031182910569363806
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031182910569363806
# Final cost : 0.0031052259989231288
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031052259989231288
# Final cost : 0.0030924152989951848
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030924152989951848
# Final cost : 0.00308475848943721
# Compute control for a deterministic system
# Cost in iteration 0: 0.004904429036721667
# Final cost : 0.002909831985006424
# Compute control for a deterministic system
# Cost in iteration 0: 0.002909831985006424
# Final cost : 0.0028909332163722557
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028909332163722557
# Final cost : 0.0028721192185368204
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028721192185368204
# Final cost : 0.0028624403784935333
# Compute control for a deterministic system
# Cost in iteration 0: 0.13779966982542646
# Final cost : 0.002701848499851292
# Compute control for a deterministic system
# Cost in iteration 0: 0.002701848499851292
# Final cost : 0.00269499228951363
# Compute control for a deterministic system
# Cost in iteration 0: 0.00269499228951363
# Final cost : 0.0026876060011642305
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026876060011642305
# Final cost : 0.0026811549184260065
# Compute control for a deterministic system
# Cost in iteration 0: 0.11451035299567387
# Final cost : 0.002504456938958874
# Compute control for a deterministic system
# Cost in iteration 0: 0.002504456938958874
# Final cost : 0.0025011924160765905
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025011924160765905
# Final cost : 0.0024977818451615793
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024977818451615793
# Final cost : 0.0024941512799446807
# Compute control for a deterministic system
# Cost in iteration 0: 0.013928858598543169
# Final cost : 0.0023301104213162816
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023301104213162816
# Final cost : 0.002318937769020257
# Compute control for a deterministic system
# Cost in iteration 0: 0.002318937769020257
# Final cost : 0.0023121148752810023
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023121148752810023
# Final cost : 0.0023099716672387235
# Compute control for a deterministic system
# Cost in iteration 0: 0.08139961962391086
# Final cost : 0.002130948060877593
# Compute control for a deterministic system
# Cost in iteration 0: 0.002130948060877593
# Final cost : 0.0021232794388906357
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021232794388906357
# Final cost : 0.0021209327806308857
# Compute control for a deterministic system
# Cost in iteration 0: 0.0021209327806308857
# Final cost : 0.0021193573559820365
# -----------------------------------------------
# 1 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.14554219805725915
# Final cost : 0.0019161943260156728
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019161943260156728
# Final cost : 0.0019121851699572194
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019121851699572194
# Final cost : 0.001907111759698109
# Compute control for a deterministic system
# Cost in iteration 0: 0.001907111759698109
# Final cost : 0.0019032320773569396
# Compute control for a deterministic system
# Cost in iteration 0: 0.031187123220701392
# Final cost : 0.001704969227938085
# Compute control for a deterministic system
# Cost in iteration 0: 0.001704969227938085
# Final cost : 0.001697007821746923
# Compute control for a deterministic system
# Cost in iteration 0: 0.001697007821746923
# Final cost : 0.0016947729073888286
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016947729073888286
# Final cost : 0.0016937893487569754
# Compute control for a deterministic system
# Cost in iteration 0: 0.10643548653550873
# Final cost : 0.0015169474121221529
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015169474121221529
# Final cost : 0.00151109513253169
# Compute control for a deterministic system
# Cost in iteration 0: 0.00151109513253169
# Final cost : 0.0015074731599158645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015074731599158645
# Final cost : 0.0015041763472264465
# Compute control for a deterministic system
# Cost in iteration 0: 0.11321511303659115
# Final cost : 0.0013305194869131984
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013305194869131984
# Final cost : 0.0013239715459180503
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013239715459180503
# Final cost : 0.0013200103050836302
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013200103050836302
# Final cost : 0.0013168664041200134
# Compute control for a deterministic system
# Cost in iteration 0: 0.013077158011162226
# Final cost : 0.001143193231474842
# Compute control for a deterministic system
# Cost in iteration 0: 0.001143193231474842
# Final cost : 0.001135538789340709
# Compute control for a deterministic system
# Cost in iteration 0: 0.001135538789340709
# Final cost : 0.0011316306525403059
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011316306525403059
# Final cost : 0.0011301418033382075
# Compute control for a deterministic system
# Cost in iteration 0: 0.024062673687898568
# Final cost : 0.0009280712798267699
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009280712798267699
# Final cost : 0.0009201645005308528
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009201645005308528
# Final cost : 0.0009144704039597351
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009144704039597351
# Final cost : 0.0009130957711896673
# Compute control for a deterministic system
# Cost in iteration 0: 0.11281573826269643
# Final cost : 0.0007599435571612577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007599435571612577
# Final cost : 0.0007492744977480042
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007492744977480042
# Final cost : 0.0007429121432227247
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007429121432227247
# Final cost : 0.0007391629609779341
# Compute control for a deterministic system
# Cost in iteration 0: 0.021420813057169214
# Final cost : 0.0005757282690454476
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005757282690454476
# Final cost : 0.0005716651838804809
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005716651838804809
# Final cost : 0.0005696300199392496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005696300199392496
# Final cost : 0.0005689684218239724
# Compute control for a deterministic system
# Cost in iteration 0: 0.09097013350944526
# Final cost : 0.0004289322011448273
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004289322011448273
# Final cost : 0.00041968994609507235
# Compute control for a deterministic system
# Cost in iteration 0: 0.00041968994609507235
# Final cost : 0.0004117324481118086
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004117324481118086
# Final cost : 0.0004102750196978226
# Compute control for a deterministic system
# Cost in iteration 0: 0.043658964605993944
# Final cost : 0.00027507186583060724
# Compute control for a deterministic system
# Cost in iteration 0: 0.00027507186583060724
# Final cost : 0.00026984332933885466
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026984332933885466
# Final cost : 0.0002664629636499363
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002664629636499363
# Final cost : 0.00026498229063260585
# Compute control for a deterministic system
# Cost in iteration 0: 0.08506955603672242
# Final cost : 0.0001222485317924911
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001222485317924911
# Final cost : 0.00012013393372178321
# Compute control for a deterministic system
# Cost in iteration 0: 0.00012013393372178321
# Final cost : 0.00011908197178247737
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011908197178247737
# Final cost : 0.00011870101466015817
# Compute control for a deterministic system
# Cost in iteration 0: 0.06089839315998496
# Final cost : 4.0944890772836115e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.0944890772836115e-05
# Final cost : 3.3508673017716696e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3508673017716696e-05
# Final cost : 3.3505734014597e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3505734014597e-05
# Final cost : 3.350495365867719e-05
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 8.543678102563085e-05
# Final cost : 3.351957282049357e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.351957282049357e-05
# Final cost : 3.3509769222704265e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3509769222704265e-05
# Final cost : 3.350670615601308e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.350670615601308e-05
# Final cost : 3.3505334567297435e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3505334567297435e-05
# Final cost : 3.350495380223084e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002490060315370288
# Final cost : 0.00011866890085347062
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011866890085347062
# Final cost : 0.00011865913125175995
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011865913125175995
# Final cost : 0.00011865606744498495
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011865606744498495
# Final cost : 0.00011865338756186063
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011865338756186063
# Final cost : 0.00011865285782336001
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010500728923153746
# Final cost : 0.0002647642009107616
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002647642009107616
# Final cost : 0.0002647578443247037
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002647578443247037
# Final cost : 0.00026475318339665485
# Compute control for a deterministic system
# Cost in iteration 0: 0.00026475318339665485
# Final cost : 0.0002647502292989861
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002647502292989861
# Final cost : 0.00026474905089353954
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012601156076144353
# Final cost : 0.000410090277701522
# Compute control for a deterministic system
# Cost in iteration 0: 0.000410090277701522
# Final cost : 0.00041000980405275474
# Compute control for a deterministic system
# Cost in iteration 0: 0.00041000980405275474
# Final cost : 0.00040995195740545996
# Compute control for a deterministic system
# Cost in iteration 0: 0.00040995195740545996
# Final cost : 0.0004098841220642777
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004098841220642777
# Final cost : 0.0004098605019939185
# Compute control for a deterministic system
# Cost in iteration 0: 0.0066433043891863785
# Final cost : 0.0005695791419590996
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005695791419590996
# Final cost : 0.0005692113033302312
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005692113033302312
# Final cost : 0.0005689275170660727
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005689275170660727
# Final cost : 0.0005687255228181941
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005687255228181941
# Final cost : 0.0005686095225040336
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031744599167807686
# Final cost : 0.0007372998656051116
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007372998656051116
# Final cost : 0.000737159557546961
# Compute control for a deterministic system
# Cost in iteration 0: 0.000737159557546961
# Final cost : 0.0007369496234547795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007369496234547795
# Final cost : 0.0007368112236202695
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007368112236202695
# Final cost : 0.0007367239524443249
# Compute control for a deterministic system
# Cost in iteration 0: 0.006852334944401664
# Final cost : 0.0009122413876702363
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009122413876702363
# Final cost : 0.0009120584227157711
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009120584227157711
# Final cost : 0.0009119470231470116
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009119470231470116
# Final cost : 0.0009117879760010977
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009117879760010977
# Final cost : 0.0009116914525001452
# -----------------------------------------------
# 4 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031296617845247964
# Final cost : 0.0011285871693988972
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011285871693988972
# Final cost : 0.0011285413765159654
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011285413765159654
# Final cost : 0.0011285231882090963
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011285231882090963
# Final cost : 0.0011285071130143322
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011285071130143322
# Final cost : 0.001128488698078291
# Compute control for a deterministic system
# Cost in iteration 0: 0.003791220030442725
# Final cost : 0.001313944067768679
# Compute control for a deterministic system
# Cost in iteration 0: 0.001313944067768679
# Final cost : 0.001313887616702054
# Compute control for a deterministic system
# Cost in iteration 0: 0.001313887616702054
# Final cost : 0.0013138839650407175
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013138839650407175
# Final cost : 0.0013138798355131344
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013138798355131344
# Final cost : 0.0013138744753155506
# -----------------------------------------------
# 4 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015105789941110448
# Final cost : 0.0015023703071482763
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015023703071482763
# Final cost : 0.0015023686052290104
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015023686052290104
# Final cost : 0.0015023668803668953
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015023668803668953
# Final cost : 0.0015023642931177891
# Compute control for a deterministic system
# Cost in iteration 0: 0.0015023642931177891
# Final cost : 0.0015023604357395728
# -----------------------------------------------
# 4 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.032182652532705004
# Final cost : 0.0028401008995396063
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028401008995396063
# Final cost : 0.002208565962948127
# Compute control for a deterministic system
# ...
# Final cost : 0.0023030440886372674
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023030440886372674
# Final cost : 0.0023029071588194935
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023029071588194935
# Final cost : 0.0023027271655816062
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023027271655816062
# Final cost : 0.0023025310402869557
# -----------------------------------------------
# 4 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.11797675025994873
# Final cost : 0.005169203869591247
# Compute control for a deterministic system
# Cost in iteration 0: 0.005169203869591247
# Final cost : 0.0028009440001998606
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028009440001998606
# Final cost : 0.0025979639065411998
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025979639065411998
# Final cost : 0.0025440772693275694
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025440772693275694
# Final cost : 0.002513716974784303
# Compute control for a deterministic system
# Cost in iteration 0: 0.09329586883551044
# Final cost : 0.00551123019869216
# Compute control for a deterministic system
# Cost in iteration 0: 0.00551123019869216
# Final cost : 0.004055026082588694
# Compute control for a deterministic system
# Cost in iteration 0: 0.004055026082588694
# Final cost : 0.0028359199694506553
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028359199694506553
# Final cost : 0.0027438619208928114
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027438619208928114
# Final cost : 0.0027071450185688424
# Compute control for a deterministic system
# Cost in iteration 0: 0.009727990974781461
# Final cost : 0.0028585940270951077
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028585940270951077
# Final cost : 0.002858427922865972
# Compute control for a deterministic system
# Cost in iteration 0: 0.002858427922865972
# Final cost : 0.002858139372652696
# Compute control for a deterministic system
# Cost in iteration 0: 0.002858139372652696
# Final cost : 0.0028578711611141577
# Compute control for a deterministic system
# Cost in iteration 0: 0.0028578711611141577
# Final cost : 0.002857638184558716
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032399364793996863
# Final cost : 0.003078770979240733
# Compute control for a deterministic system
# Cost in iteration 0: 0.003078770979240733
# Final cost : 0.00307873630764987
# Compute control for a deterministic system
# Cost in iteration 0: 0.00307873630764987
# Final cost : 0.0030786944614276802
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030786944614276802
# Final cost : 0.003078637183420851
# Compute control for a deterministic system
# Cost in iteration 0: 0.003078637183420851
# Final cost : 0.003078497081676286
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.27251942344818125
# Final cost : 0.007274761921119151
# Compute control for a deterministic system
# Cost in iteration 0: 0.007274761921119151
# Final cost : 0.00625225756232464
# Compute control for a deterministic system
# Cost in iteration 0: 0.00625225756232464
# Final cost : 0.004878093015341397
# Compute control for a deterministic system
# Cost in iteration 0: 0.004878093015341397
# Final cost : 0.0035016948318452976
# Compute control for a deterministic system
# Cost in iteration 0: 0.0035016948318452976
# Final cost : 0.003357752953249567
# Compute control for a deterministic system
# Cost in iteration 0: 0.005782862404389841
# Final cost : 0.0034417928216176003
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034417928216176003
# Final cost : 0.003441603866066774
# Compute control for a deterministic system
# Cost in iteration 0: 0.003441603866066774
# Final cost : 0.0034415125342670615
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034415125342670615
# Final cost : 0.003441350213722177
# Compute control for a deterministic system
# Cost in iteration 0: 0.003441350213722177
# Final cost : 0.0034412037999905633
# Compute control for a deterministic system
# Cost in iteration 0: 0.30680711860078
# Final cost : 0.00995434647348747
# Compute control for a deterministic system
# Cost in iteration 0: 0.00995434647348747
# Final cost : 0.007868165471216692
# Compute control for a deterministic system
# Cost in iteration 0: 0.007868165471216692
# Final cost : 0.006077249340983018
# Compute control for a deterministic system
# Cost in iteration 0: 0.006077249340983018
# Final cost : 0.004053763370503044
# Compute control for a deterministic system
# Cost in iteration 0: 0.004053763370503044
# Final cost : 0.0038002216139490083
# Compute control for a deterministic system
# Cost in iteration 0: 0.019218242367687644
# Final cost : 0.0038052675132420138
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038052675132420138
# Final cost : 0.0038037878467397017
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038037878467397017
# Final cost : 0.0038036586388680562
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038036586388680562
# Final cost : 0.0038035546349872726
# Compute control for a deterministic system
# Cost in iteration 0: 0.0038035546349872726
# Final cost : 0.0038033601614142266
# Compute control for a deterministic system
# Cost in iteration 0: 0.029179408006201082
# Final cost : 0.004036905469768852
# Compute control for a deterministic system
# Cost in iteration 0: 0.004036905469768852
# Final cost : 0.004024529021233577
# Compute control for a deterministic system
# Cost in iteration 0: 0.004024529021233577
# Final cost : 0.004022133849876877
# Compute control for a deterministic system
# Cost in iteration 0: 0.004022133849876877
# Final cost : 0.004021593327333069
# Compute control for a deterministic system
# Cost in iteration 0: 0.004021593327333069
# Final cost : 0.00402111672049804
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.18443718715097404
# Final cost : 0.01571641164599354
# Compute control for a deterministic system
# Cost in iteration 0: 0.01571641164599354
# Final cost : 0.010219792057612706
# Compute control for a deterministic system
# Cost in iteration 0: 0.010219792057612706
# Final cost : 0.008320727592487503
# Compute control for a deterministic system
# Cost in iteration 0: 0.008320727592487503
# Final cost : 0.007122848916502085
# Compute control for a deterministic system
# Cost in iteration 0: 0.007122848916502085
# Final cost : 0.005772186927990096
# Compute control for a deterministic system
# Cost in iteration 0: 0.07831541387141602
# Final cost : 0.005239878049349781
# Compute control for a deterministic system
# Cost in iteration 0: 0.005239878049349781
# Final cost : 0.004426435178782161
# Compute control for a deterministic system
# Cost in iteration 0: 0.004426435178782161
# Final cost : 0.0044129894134005325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044129894134005325
# Final cost : 0.0044080855709297964
# Compute control for a deterministic system
# Cost in iteration 0: 0.0044080855709297964
# Final cost : 0.0044027007147853705
# Compute control for a deterministic system
# Cost in iteration 0: 0.0046036048033546535
# Final cost : 0.004587567112700892
# Compute control for a deterministic system
# Cost in iteration 0: 0.004587567112700892
# Final cost : 0.004587502572216478
# Compute control for a deterministic system
# Cost in iteration 0: 0.004587502572216478
# Final cost : 0.004587421151273807
# Compute control for a deterministic system
# Cost in iteration 0: 0.004587421151273807
# Final cost : 0.004587179993342551
# Compute control for a deterministic system
# Cost in iteration 0: 0.004587179993342551
# Final cost : 0.004586962491898869
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.027179195798312197
# Final cost : 0.004848253035064511
# Compute control for a deterministic system
# Cost in iteration 0: 0.004848253035064511
# Final cost : 0.004836868712202995
# Compute control for a deterministic system
# Cost in iteration 0: 0.004836868712202995
# Final cost : 0.004835446545098442
# Compute control for a deterministic system
# Cost in iteration 0: 0.004835446545098442
# Final cost : 0.0048344545679205675
# Compute control for a deterministic system
# Cost in iteration 0: 0.0048344545679205675
# Final cost : 0.004833525292405548
# Compute control for a deterministic system
# Cost in iteration 0: 0.021869841951160585
# Final cost : 0.005060013999685122
# Compute control for a deterministic system
# Cost in iteration 0: 0.005060013999685122
# Final cost : 0.005052457852053411
# Compute control for a deterministic system
# Cost in iteration 0: 0.005052457852053411
# Final cost : 0.005051732296718858
# Compute control for a deterministic system
# Cost in iteration 0: 0.005051732296718858
# Final cost : 0.005051378851982059
# Compute control for a deterministic system
# Cost in iteration 0: 0.005051378851982059
# Final cost : 0.005051136407151291
# Compute control for a deterministic system
# Cost in iteration 0: 0.6846883391291646
# Final cost : 0.014644460249634478
# Compute control for a deterministic system
# Cost in iteration 0: 0.014644460249634478
# Final cost : 0.013939648886137876
# Compute control for a deterministic system
# Cost in iteration 0: 0.013939648886137876
# Final cost : 0.012932636397138347
# Compute control for a deterministic system
# Cost in iteration 0: 0.012932636397138347
# Final cost : 0.01135110437685052
# Compute control for a deterministic system
# Cost in iteration 0: 0.01135110437685052
# Final cost : 0.00872226404858507
# Compute control for a deterministic system
# Cost in iteration 0: 0.017874851805954647
# Final cost : 0.005536889271847789
# Compute control for a deterministic system
# Cost in iteration 0: 0.005536889271847789
# Final cost : 0.005534416343782886
# Compute control for a deterministic system
# Cost in iteration 0: 0.005534416343782886
# Final cost : 0.005533854856816471
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533854856816471
# Final cost : 0.005533195456032426
# Compute control for a deterministic system
# Cost in iteration 0: 0.005533195456032426
# Final cost : 0.005532321935759741
# Compute control for a deterministic system
# Cost in iteration 0: 0.007712284517055148
# Final cost : 0.005793143537106611
# Compute control for a deterministic system
# Cost in iteration 0: 0.005793143537106611
# Final cost : 0.0057930141697761645
# Compute control for a deterministic system
# Cost in iteration 0: 0.0057930141697761645
# Final cost : 0.005792893760708381
# Compute control for a deterministic system
# Cost in iteration 0: 0.005792893760708381
# Final cost : 0.005792725563990627
# Compute control for a deterministic system
# Cost in iteration 0: 0.005792725563990627
# Final cost : 0.005792389301060816
# -----------------------------------------------
# 4 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.012272399512356999
# Final cost : 0.006159799293809606
# Compute control for a deterministic system
# Cost in iteration 0: 0.006159799293809606
# Final cost : 0.0061574777645597625
# Compute control for a deterministic system
# Cost in iteration 0: 0.0061574777645597625
# Final cost : 0.006155185037443114
# Compute control for a deterministic system
# Cost in iteration 0: 0.006155185037443114
# Final cost : 0.00615291926469334
# Compute control for a deterministic system
# Cost in iteration 0: 0.00615291926469334
# Final cost : 0.006149424331536559
# -----------------------------------------------
# 4 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 0.008982780230207056
# Final cost : 0.0046702218757226415
# Compute control for a deterministic system
# Cost in iteration 0: 0.0046702218757226415
# Final cost : 0.004669314503972983
# Compute control for a deterministic system
# Cost in iteration 0: 0.004669314503972983
# Final cost : 0.004669228383544107
# Compute control for a deterministic system
# Cost in iteration 0: 0.004669228383544107
# Final cost : 0.004669220505033789
# Compute control for a deterministic system
# Cost in iteration 0: 0.004669220505033789
# Final cost : 0.004669220095105186
# Compute control for a deterministic system
# Cost in iteration 0: 0.003508041976452769
# Final cost : 0.0031727470435478993
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031727470435478993
# Final cost : 0.0031726901641632938
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031726901641632938
# Final cost : 0.0031726823590220742
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031726823590220742
# Final cost : 0.0031726818071246194
# Compute control for a deterministic system
# Cost in iteration 0: 0.0031726818071246194
# Final cost : 0.003172681769112409
# -----------------------------------------------
# 4 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034228462771922668
# Final cost : 0.002022008081212849
# Compute control for a deterministic system
# Cost in iteration 0: 0.002022008081212849
# Final cost : 0.0020217811869270423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020217811869270423
# Final cost : 0.002021760668467982
# Compute control for a deterministic system
# Cost in iteration 0: 0.002021760668467982
# Final cost : 0.002021760658561066
# Compute control for a deterministic system
# Cost in iteration 0: 0.002021760658561066
# Converged in iteration 819 with cost 0.002021760657746106 because of step counter
# Final cost : 0.002021760657746106
# Compute control for a deterministic system
# Cost in iteration 0: 0.00215004389569198
# Final cost : 0.0011826626596037793
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011826626596037793
# Final cost : 0.0011825119412995605
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011825119412995605
# Final cost : 0.001182484263453206
# Compute control for a deterministic system
# Cost in iteration 0: 0.001182484263453206
# Final cost : 0.001182483714094849
# Compute control for a deterministic system
# Cost in iteration 0: 0.001182483714094849
# Final cost : 0.001182483681693989
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011094997878975756
# Final cost : 0.000524302719949753
# Compute control for a deterministic system
# Cost in iteration 0: 0.000524302719949753
# Final cost : 0.0005242405178812251
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005242405178812251
# Final cost : 0.0005242246007724496
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005242246007724496
# Final cost : 0.0005242197134638098
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005242197134638098
# Final cost : 0.0005242193510420775
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037623343138709023
# Final cost : 0.00020720796531395745
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020720796531395745
# Final cost : 0.00020720584875818943
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020720584875818943
# Final cost : 0.00020720493147446218
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020720493147446218
# Final cost : 0.00020720479063236714
# Compute control for a deterministic system
# Cost in iteration 0: 0.00020720479063236714
# Final cost : 0.00020720477745430723
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015332516276919566
# Final cost : 4.716610488126886e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.716610488126886e-05
# Final cost : 4.71538503760907e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.71538503760907e-05
# Final cost : 4.71448554522974e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.71448554522974e-05
# Final cost : 4.7143140896136994e-05
# Compute control for a deterministic system
# Cost in iteration 0: 4.7143140896136994e-05
# Final cost : 4.714306324319945e-05

# %%
save(results_min)
