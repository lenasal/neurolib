# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.4543040513180053 
y_init = 0.3987237035596491
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_peak = [wc.exc[0,77], wc.inh[0,77]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# peaks =  [ 191  400  608  816 1024 1232 1441 1649 1857 2065 2273 2482 2690 2898]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 2.6
wc.params["inh_ext"] = zero_input + 1.2

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
#results_min = readfile("results_min_w2.pickle")

ind_list = range(41)
#options = [True, True, True, True, True, True, True, True]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            break

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w2"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.050803615948032226
# Final cost : 3.814086717315632e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.814086717315632e-05
# Final cost : 3.755678414292867e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.755678414292867e-05
# Final cost : 3.657332694789834e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.657332694789834e-05
# Final cost : 3.577763095703515e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.577763095703515e-05
# Final cost : 3.375042170292999e-05
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.06793042677905559
# Final cost : 8.684095630661261e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.684095630661261e-05
# Final cost : 8.496710236158907e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.496710236158907e-05
# Final cost : 8.106465686320445e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.106465686320445e-05
# Final cost : 7.881974859643905e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.881974859643905e-05
# Final cost : 7.227847075509588e-05
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.03924679100256595
# Final cost : 0.00011054024763648637
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011054024763648637
# Final cost : 0.00010976749439880154
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010976749439880154
# Final cost : 0.00010890317856516623
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010890317856516623
# Final cost : 0.00010777617978419618
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010777617978419618
# Final cost : 0.0001064408847752989
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0341169142966081
# Final cost : 0.00015239875509804156
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015239875509804156
# Final cost : 0.00015153551721760965
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015153551721760965
# Final cost : 0.00015017989270890402
# Compute control for a deterministic system
# Cost in iteration 0: 0.00015017989270890402
# Final cost : 0.00014860841287865233
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014860841287865233
# Final cost : 0.00014535825751421736
# Compute control for a deterministic system
# Cost in iteration 0: 0.027665988409387648
# Final cost : 0.00019019973200598247
# Compute control for a deterministic system
# Cost in iteration 0: 0.00019019973200598247
# Final cost : 0.00018932253620727635
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018932253620727635
# Final cost : 0.00018828213310099194
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018828213310099194
# Final cost : 0.00018715122867515543
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018715122867515543
# Final cost : 0.00018541432088653602
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.02558486986455709
# Final cost : 0.00023612590447059955
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023612590447059955
# Final cost : 0.0002343335198600636
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002343335198600636
# Final cost : 0.00023213748084631883
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023213748084631883
# Final cost : 0.00023004855097816712
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023004855097816712
# Final cost : 0.00022801102140410881
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.03798540349476513
# Final cost : 0.00029244151921580387
# Compute control for a deterministic system
# Cost in iteration 0: 0.00029244151921580387
# Final cost : 0.00028947074388475897
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028947074388475897
# Final cost : 0.0002861819870526553
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002861819870526553
# Final cost : 0.0002838014852102352
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002838014852102352
# Final cost : 0.0002815939056488006
# -----------------------------------------------
# 0 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.017271452622665946
# Final cost : 0.0003350135252026073
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003350135252026073
# Final cost : 0.00033312377015787633
# Compute control for a deterministic system
# Cost in iteration 0: 0.00033312377015787633
# Final cost : 0.000331047437169229
# Compute control for a deterministic system
# Cost in iteration 0: 0.000331047437169229
# Final cost : 0.00032943872010216083
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032943872010216083
# Final cost : 0.0003276852307942187
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.013251127432538605
# Final cost : 0.0003829959599934046
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003829959599934046
# Final cost : 0.00038127313483777263
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038127313483777263
# Final cost : 0.0003788985759889552
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003788985759889552
# Final cost : 0.00037762168153965774
# Compute control for a deterministic system
# Cost in iteration 0: 0.00037762168153965774
# Final cost : 0.000376033938209953
# -----------------------------------------------
# 0 found better solution,  10
# Compute control for a deterministic system
# Cost in iteration 0: 0.010502282001338315
# Final cost : 0.00043442149232695144
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043442149232695144
# Final cost : 0.0004324825340261302
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004324825340261302
# Final cost : 0.00043070211460863555
# Compute control for a deterministic system
# Cost in iteration 0: 0.00043070211460863555
# Final cost : 0.00042964798045803693
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042964798045803693
# Final cost : 0.0004276821686073021
# -----------------------------------------------
# 0 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.008676044924618903
# Final cost : 0.0004899394996256319
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004899394996256319
# Final cost : 0.00048796067933226385
# Compute control for a deterministic system
# Cost in iteration 0: 0.00048796067933226385
# Final cost : 0.0004863544198657405
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004863544198657405
# Final cost : 0.00048516268707083846
# Compute control for a deterministic system
# Cost in iteration 0: 0.00048516268707083846
# Final cost : 0.0004829122385539743
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005562690024757221
# Final cost : 0.0005175444347205788
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005175444347205788
# Final cost : 0.0005172660118884882
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005172660118884882
# Final cost : 0.0005166090450440492
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005166090450440492
# Final cost : 0.0005159351010955821
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005159351010955821
# Final cost : 0.0005146832503596981
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.005185893106601918
# Final cost : 0.0005742036755504263
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005742036755504263
# Final cost : 0.0005722393510005733
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005722393510005733
# Final cost : 0.000570539425307813
# Compute control for a deterministic system
# Cost in iteration 0: 0.000570539425307813
# Final cost : 0.0005698163799715171
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005698163799715171
# Final cost : 0.0005688484198246076
# -----------------------------------------------
# 0 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.006826124776912501
# Final cost : 0.0006350581722893082
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006350581722893082
# Final cost : 0.0006331800199141028
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006331800199141028
# Final cost : 0.000631614683512532
# Compute control for a deterministic system
# Cost in iteration 0: 0.000631614683512532
# Final cost : 0.0006310232894840865
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006310232894840865
# Final cost : 0.0006300255510961834
# -----------------------------------------------
# 0 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.007722829108559798
# Final cost : 0.0007045531813259123
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007045531813259123
# Final cost : 0.0007029190535412029
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007029190535412029
# Final cost : 0.0007015509800216468
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007015509800216468
# Final cost : 0.0007009381817848528
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007009381817848528
# Final cost : 0.0006994223700214592
# -----------------------------------------------
# 0 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.009750553367351762
# Final cost : 0.0007860267958530243
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007860267958530243
# Final cost : 0.0007844357345308223
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007844357345308223
# Final cost : 0.0007830252070574068
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007830252070574068
# Final cost : 0.0007820804386634779
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007820804386634779
# Final cost : 0.0007789615123493902
# -----------------------------------------------
# 0 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.02418350051486567
# Final cost : 0.0008988793769244523
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008988793769244523
# Final cost : 0.0008981043636529591
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008981043636529591
# Final cost : 0.0008970679875958297
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008970679875958297
# Final cost : 0.0008952037365208199
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008952037365208199
# Final cost : 0.0008901301265042041
# -----------------------------------------------
# 0 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.017452227694876105
# Final cost : 0.001012270889781553
# Compute control for a deterministic system
# Cost in iteration 0: 0.001012270889781553
# Final cost : 0.0010111532492239007
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010111532492239007
# Final cost : 0.001009353248732651
# Compute control for a deterministic system
# Cost in iteration 0: 0.001009353248732651
# Final cost : 0.0010052018985483098
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010052018985483098
# Final cost : 0.0009961319147983594
# -----------------------------------------------
# 0 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.02331472075200296
# Final cost : 0.001148718817583012
# Compute control for a deterministic system
# Cost in iteration 0: 0.001148718817583012
# Final cost : 0.001145129578786051
# Compute control for a deterministic system
# Cost in iteration 0: 0.001145129578786051
# Final cost : 0.0011415256268824119
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011415256268824119
# Final cost : 0.0011362517002101672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011362517002101672
# Final cost : 0.0011198579154062444
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.055422396402554995
# Final cost : 0.0013244921534069933
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013244921534069933
# Final cost : 0.0013026109639280741
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013026109639280741
# Final cost : 0.0012923201957356755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012923201957356755
# Final cost : 0.0012848268688488741
# Compute control for a deterministic system
# Cost in iteration 0: 0.0012848268688488741
# Final cost : 0.0012540114549493147
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.05609386520293834
# Final cost : 0.0014999185381439522
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014999185381439522
# Final cost : 0.0014763460495061916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014763460495061916
# Final cost : 0.0014616589572883103
# Compute control for a deterministic system
# Cost in iteration 0: 0.0014616589572883103
# Final cost : 0.001450642478516175
# Compute control for a deterministic system
# Cost in iteration 0: 0.001450642478516175
# Final cost : 0.001412610365712671
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.08082138088012664
# Final cost : 0.0018030604304492466
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018030604304492466
# Final cost : 0.0017637801163102836
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017637801163102836
# Final cost : 0.001739154400752107
# Compute control for a deterministic system
# Cost in iteration 0: 0.001739154400752107
# Final cost : 0.001714971698774165
# Compute control for a deterministic system
# Cost in iteration 0: 0.001714971698774165
# Final cost : 0.0016422059403108664
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.057497287017304305
# Final cost : 0.0020939482766761746
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020939482766761746
# Final cost : 0.0020294314475586303
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020294314475586303
# Final cost : 0.001999873023897526
# Compute control for a deterministic system
# Cost in iteration 0: 0.001999873023897526
# Final cost : 0.0019736381170760396
# Compute control for a deterministic system
# Cost in iteration 0: 0.0019736381170760396
# Final cost : 0.0019025436548484956
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.0581049932198546
# Final cost : 0.002662701317801312
# Compute control for a deterministic system
# Cost in iteration 0: 0.002662701317801312
# Final cost : 0.002427299340263857
# Compute control for a deterministic system
# Cost in iteration 0: 0.002427299340263857
# Final cost : 0.0023557018504626395
# Compute control for a deterministic system
# Cost in iteration 0: 0.0023557018504626395
# Final cost : 0.002323317865105798
# Compute control for a deterministic system
# Cost in iteration 0: 0.002323317865105798
# Final cost : 0.002244465671517537
# -----------------------------------------------
# 0 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.058956464288252027
# Final cost : 0.003394792785529597
# Compute control for a deterministic system
# Cost in iteration 0: 0.003394792785529597
# Final cost : 0.0030390598480257423
# Compute control for a deterministic system
# Cost in iteration 0: 0.0030390598480257423
# Final cost : 0.002859734671951252
# Compute control for a deterministic system
# Cost in iteration 0: 0.002859734671951252
# Final cost : 0.002782386785392876
# Compute control for a deterministic system
# Cost in iteration 0: 0.002782386785392876
# Final cost : 0.00269722102658656
# -----------------------------------------------
# 0 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.08456546833157531
# Final cost : 0.005521144099392866
# Compute control for a deterministic system
# Cost in iteration 0: 0.005521144099392866
# Final cost : 0.004579165768772673
# Compute control for a deterministic system
# Cost in iteration 0: 0.004579165768772673
# Final cost : 0.003971296897459747
# Compute control for a deterministic system
# Cost in iteration 0: 0.003971296897459747
# Final cost : 0.003688766880619837
# Compute control for a deterministic system
# Cost in iteration 0: 0.003688766880619837
# Final cost : 0.0034834390742464897
# -----------------------------------------------
# 0 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 0.060903352896091764
# Final cost : 0.006953554625057965
# Compute control for a deterministic system
# Cost in iteration 0: 0.006953554625057965
# Final cost : 0.006085548667227424
# Compute control for a deterministic system
# Cost in iteration 0: 0.006085548667227424
# Final cost : 0.005404960947954293
# Compute control for a deterministic system
# Cost in iteration 0: 0.005404960947954293
# Final cost : 0.0047870918617398325
# Compute control for a deterministic system
# Cost in iteration 0: 0.0047870918617398325
# Final cost : 0.0043885843994955825
# -----------------------------------------------
# 0 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 0.062121761842817355
# Final cost : 0.009308963557019725
# Compute control for a deterministic system
# Cost in iteration 0: 0.009308963557019725
# Final cost : 0.008622144705559193
# Compute control for a deterministic system
# Cost in iteration 0: 0.008622144705559193
# Final cost : 0.007540348145547375
# Compute control for a deterministic system
# Cost in iteration 0: 0.007540348145547375
# Final cost : 0.00684625006923229
# Compute control for a deterministic system
# Cost in iteration 0: 0.00684625006923229
# Final cost : 0.0057312982028953855
# -----------------------------------------------
# 0 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 0.0641782028949758
# Final cost : 0.012233841871070857
# Compute control for a deterministic system
# Cost in iteration 0: 0.012233841871070857
# Final cost : 0.011629999441440896
# Compute control for a deterministic system
# Cost in iteration 0: 0.011629999441440896
# Final cost : 0.0108230485722219
# Compute control for a deterministic system
# Cost in iteration 0: 0.0108230485722219
# Final cost : 0.00984404348715142
# Compute control for a deterministic system
# Cost in iteration 0: 0.00984404348715142
# Final cost : 0.008266891577661506
# Compute control for a deterministic system
# Cost in iteration 0: 0.05856087913857157
# Final cost : 0.004846169309589566
# Compute control for a deterministic system
# Cost in iteration 0: 0.004846169309589566
# Final cost : 0.004733176137759193
# Compute control for a deterministic system
# Cost in iteration 0: 0.004733176137759193
# Final cost : 0.004719025977430234
# Compute control for a deterministic system
# Cost in iteration 0: 0.004719025977430234
# Final cost : 0.004711565857439957
# Compute control for a deterministic system
# Cost in iteration 0: 0.004711565857439957
# Final cost : 0.004704434307914637
# -----------------------------------------------
# 0 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 0.07922181022541754
# Final cost : 0.0037473342515131594
# Compute control for a deterministic system
# Cost in iteration 0: 0.0037473342515131594
# Final cost : 0.003499767266148815
# Compute control for a deterministic system
# Cost in iteration 0: 0.003499767266148815
# Final cost : 0.0034524405495198526
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034524405495198526
# Final cost : 0.00342859889292275
# Compute control for a deterministic system
# Cost in iteration 0: 0.00342859889292275
# Final cost : 0.0034055225248696454
# Compute control for a deterministic system
# Cost in iteration 0: 0.05446977092794678
# Final cost : 0.0027181562571943047
# Compute control for a deterministic system
# Cost in iteration 0: 0.0027181562571943047
# Final cost : 0.0025673737053051064
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025673737053051064
# Final cost : 0.002497162196147812
# Compute control for a deterministic system
# Cost in iteration 0: 0.002497162196147812
# Final cost : 0.002472673024415654
# Compute control for a deterministic system
# Cost in iteration 0: 0.002472673024415654
# Final cost : 0.002447278078815922
# Compute control for a deterministic system
# Cost in iteration 0: 0.053134345084401416
# Final cost : 0.001855096072420593
# Compute control for a deterministic system
# Cost in iteration 0: 0.001855096072420593
# Final cost : 0.0017274517248304611
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017274517248304611
# Final cost : 0.0016540473214452286
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016540473214452286
# Final cost : 0.0016263332373199222
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016263332373199222
# Final cost : 0.0016195992890292946
# -----------------------------------------------
# 0 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.05237878577365209
# Final cost : 0.0011592087781973287
# Compute control for a deterministic system
# Cost in iteration 0: 0.0011592087781973287
# Final cost : 0.0010937164662685119
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010937164662685119
# Final cost : 0.001038057125677064
# Compute control for a deterministic system
# Cost in iteration 0: 0.001038057125677064
# Final cost : 0.0010009043357804748
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010009043357804748
# Final cost : 0.000980143243325423
# Compute control for a deterministic system
# Cost in iteration 0: 0.05195818317119014
# Final cost : 0.000600901770376123
# Compute control for a deterministic system
# Cost in iteration 0: 0.000600901770376123
# Final cost : 0.0005776779461864622
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005776779461864622
# Final cost : 0.0005522492336968669
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005522492336968669
# Final cost : 0.0005288464288210477
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005288464288210477
# Final cost : 0.0005244180369687737
# -----------------------------------------------
# 0 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.0751521497563827
# Final cost : 0.00027434322652349877
# Compute control for a deterministic system
# Cost in iteration 0: 0.00027434322652349877
# Final cost : 0.00025678511042430207
# Compute control for a deterministic system
# Cost in iteration 0: 0.00025678511042430207
# Final cost : 0.00023906242155850065
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023906242155850065
# Final cost : 0.00022300434764730738
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022300434764730738
# Final cost : 0.0002098134435331286
# Compute control for a deterministic system
# Cost in iteration 0: 0.05353607409315099
# Final cost : 8.555693863320124e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.555693863320124e-05
# Final cost : 8.223594066039378e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.223594066039378e-05
# Final cost : 7.943445932278697e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.943445932278697e-05
# Final cost : 7.69489132025003e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.69489132025003e-05
# Final cost : 7.479933446325458e-05
# -----------------------------------------------
# 0 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.05480495258429852
# Final cost : 3.266610626089899e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.266610626089899e-05
# Final cost : 2.8915731910442657e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.8915731910442657e-05
# Final cost : 2.543236208385807e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.543236208385807e-05
# Final cost : 2.178956358164443e-05
# Compute control for a deterministic system
# Cost in iteration 0: 2.178956358164443e-05
# Final cost : 1.6377395596556946e-05
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.05381340853705322
# Final cost : 8.47299012023791e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.47299012023791e-05
# Final cost : 8.103066230619738e-05
# Compute control for a deterministic system
# Cost in iteration 0: 8.103066230619738e-05
# Final cost : 7.805190788996659e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.805190788996659e-05
# Final cost : 7.504567238632859e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.05173256706434764
# Final cost : 0.0002310991749231019
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002310991749231019
# Final cost : 0.00022140763354192703
# Compute control for a deterministic system
# Cost in iteration 0: 0.00022140763354192703
# Final cost : 0.00021496360953396817
# Compute control for a deterministic system
# Cost in iteration 0: 0.00021496360953396817
# Final cost : 0.0002084363349919425
# -----------------------------------------------
# 1 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.07231420059170021
# Final cost : 0.0005959768671550993
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005959768671550993
# Final cost : 0.0005717779906251586
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005717779906251586
# Final cost : 0.0005494666622780386
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005494666622780386
# Final cost : 0.0005279683949922115
# Compute control for a deterministic system
# Cost in iteration 0: 0.048455069129012346
# Final cost : 0.0010602368958172364
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010602368958172364
# Final cost : 0.001024512460939462
# Compute control for a deterministic system
# Cost in iteration 0: 0.001024512460939462
# Final cost : 0.0009979660212940866
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009979660212940866
# Final cost : 0.00097807290996838
# -----------------------------------------------
# 1 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.04830207995737391
# Final cost : 0.0017806240879178477
# Compute control for a deterministic system
# Cost in iteration 0: 0.0017806240879178477
# Final cost : 0.0016938806629251738
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016938806629251738
# Final cost : 0.001655127315777178
# Compute control for a deterministic system
# Cost in iteration 0: 0.001655127315777178
# Final cost : 0.0016252153163611993
# Compute control for a deterministic system
# Cost in iteration 0: 0.0471739396915626
# Final cost : 0.0026015331898261483
# Compute control for a deterministic system
# Cost in iteration 0: 0.0026015331898261483
# Final cost : 0.002488170469562011
# Compute control for a deterministic system
# Cost in iteration 0: 0.002488170469562011
# Final cost : 0.0024577205040883527
# Compute control for a deterministic system
# Cost in iteration 0: 0.0024577205040883527
# Final cost : 0.0024410315454964477
# -----------------------------------------------
# 1 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 0.047347251287936064
# Final cost : 0.003682760340151068
# Compute control for a deterministic system
# Cost in iteration 0: 0.003682760340151068
# Final cost : 0.0034710662119649648
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034710662119649648
# Final cost : 0.0034345733050379626
# Compute control for a deterministic system
# Cost in iteration 0: 0.0034345733050379626
# Final cost : 0.003407223266772409
# Compute control for a deterministic system
# Cost in iteration 0: 0.06747399480769992
# Final cost : 0.004882675032967279
# Compute control for a deterministic system
# Cost in iteration 0: 0.004882675032967279
# Final cost : 0.00474576176136332
# Compute control for a deterministic system
# Cost in iteration 0: 0.00474576176136332
# Final cost : 0.0047278126295316235
# Compute control for a deterministic system
# Cost in iteration 0: 0.0047278126295316235
# Final cost : 0.004708702737478752
# Compute control for a deterministic system
# Cost in iteration 0: 0.0459416793075611
# Final cost : 0.005993553330038332
# Compute control for a deterministic system
# Cost in iteration 0: 0.005993553330038332
# Final cost : 0.005943453723342036
# Compute control for a deterministic system
# Cost in iteration 0: 0.005943453723342036
# Final cost : 0.005929208729981381
# Compute control for a deterministic system
# Cost in iteration 0: 0.005929208729981381
# Final cost : 0.005908318044408935
# -----------------------------------------------
# 1 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 0.04614277818514392
# Final cost : 0.007299950739230637
# Compute control for a deterministic system
# Cost in iteration 0: 0.007299950739230637
# Final cost : 0.007263621291429036
# Compute control for a deterministic system
# Cost in iteration 0: 0.007263621291429036
# Final cost : 0.0072366485759212534
# Compute control for a deterministic system
# Cost in iteration 0: 0.0072366485759212534
# Final cost : 0.007209546531698883
# Compute control for a deterministic system
# Cost in iteration 0: 0.02904369691533895
# Final cost : 0.006414536493604682
# Compute control for a deterministic system
# Cost in iteration 0: 0.006414536493604682
# Final cost : 0.0057781932296532565
# Compute control for a deterministic system
# Cost in iteration 0: 0.0057781932296532565
# Final cost : 0.005234336115376896
# Compute control for a deterministic system
# Cost in iteration 0: 0.005234336115376896
# Final cost : 0.004489480251057896
# Compute control for a deterministic system
# Cost in iteration 0: 0.036220063290477514
# Final cost : 0.006256612560720591
# Compute control for a deterministic system
# Cost in iteration 0: 0.006256612560720591
# Final cost : 0.005259786405196578
# Compute control for a deterministic system
# Cost in iteration 0: 0.005259786405196578
# Final cost : 0.004176258132938766
# Compute control for a deterministic system
# Cost in iteration 0: 0.004176258132938766
# Final cost : 0.003529801792925112
# Compute control for a deterministic system
# Cost in iteration 0: 0.0635268090996915
# Final cost : 0.0056803698888026125
# Compute control for a deterministic system
# Cost in iteration 0: 0.0056803698888026125
# Final cost : 0.004094574128271502
# Compute control for a deterministic system
# Cost in iteration 0: 0.004094574128271502
# Final cost : 0.0032556546595461956
# Compute control for a deterministic system
# Cost in iteration 0: 0.0032556546595461956
# Final cost : 0.002852763624755756
# Compute control for a deterministic system
# Cost in iteration 0: 0.05244998035008669
# Final cost : 0.003935323932074099
# Compute control for a deterministic system
# Cost in iteration 0: 0.003935323932074099
# Final cost : 0.002583832870996733
# Compute control for a deterministic system
# Cost in iteration 0: 0.002583832870996733
# Final cost : 0.002358134205793918
# Compute control for a deterministic system
# Cost in iteration 0: 0.002358134205793918
# Final cost : 0.002169383789136817
# -----------------------------------------------
# 1 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 0.05054142271169469
# Final cost : 0.0025026743574796196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0025026743574796196
# Final cost : 0.002077542316484449
# Compute control for a deterministic system
# Cost in iteration 0: 0.002077542316484449
# Final cost : 0.001998988840388978
# Compute control for a deterministic system
# Cost in iteration 0: 0.001998988840388978
# Final cost : 0.0017872604091828711
# -----------------------------------------------
# 1 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.05310678278073389
# Final cost : 0.0018047288286265225
# Compute control for a deterministic system
# Cost in iteration 0: 0.0018047288286265225
# Final cost : 0.001735524189266244
# Compute control for a deterministic system
# Cost in iteration 0: 0.001735524189266244
# Final cost : 0.0016831050389418548
# Compute control for a deterministic system
# Cost in iteration 0: 0.0016831050389418548
# Final cost : 0.001458683754374023
# -----------------------------------------------
# 1 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.08874490820753043
# Final cost : 0.001400987490880491
# Compute control for a deterministic system
# Cost in iteration 0: 0.001400987490880491
# Final cost : 0.0013414477908808937
# Compute control for a deterministic system
# Cost in iteration 0: 0.0013414477908808937
# Final cost : 0.001251899556542771
# Compute control for a deterministic system
# Cost in iteration 0: 0.001251899556542771
# Final cost : 0.0012153936081911187
# -----------------------------------------------
# 1 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.06711422482881102
# Final cost : 0.001090952626055651
# Compute control for a deterministic system
# Cost in iteration 0: 0.001090952626055651
# Final cost : 0.0010851036347123307
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010851036347123307
# Final cost : 0.0010800137557666213
# Compute control for a deterministic system
# Cost in iteration 0: 0.0010800137557666213
# Final cost : 0.0010651734233954292
# -----------------------------------------------
# 1 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.039088553013866274
# Final cost : 0.000983457656408309
# Compute control for a deterministic system
# Cost in iteration 0: 0.000983457656408309
# Final cost : 0.0009766762443554817
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009766762443554817
# Final cost : 0.0009683147875183087
# Compute control for a deterministic system
# Cost in iteration 0: 0.0009683147875183087
# Final cost : 0.0009579010191830876
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.03611465697184569
# Final cost : 0.0008891490899132158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008891490899132158
# Final cost : 0.0008846964196672566
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008846964196672566
# Final cost : 0.0008794789767008788
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008794789767008788
# Final cost : 0.0008709641258002485
# -----------------------------------------------
# 1 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.0333648614833499
# Final cost : 0.0008155795794319052
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008155795794319052
# Final cost : 0.0008120910639087007
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008120910639087007
# Final cost : 0.0008090792471567842
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008090792471567842
# Final cost : 0.0008000679689695657
# -----------------------------------------------
# 1 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.04668559852825563
# Final cost : 0.0007496454308380635
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007496454308380635
# Final cost : 0.0007465828179844323
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007465828179844323
# Final cost : 0.0007437186584849453
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007437186584849453
# Final cost : 0.0007353366198756187
# -----------------------------------------------
# 1 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.023912752224351
# Final cost : 0.0007036683741334257
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007036683741334257
# Final cost : 0.0007007264957953428
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007007264957953428
# Final cost : 0.0006981261014397631
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006981261014397631
# Final cost : 0.0006898424453193085
# -----------------------------------------------
# 1 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.021069305750483165
# Final cost : 0.0006629020853940061
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006629020853940061
# Final cost : 0.0006603125346191207
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006603125346191207
# Final cost : 0.0006579993303105345
# Compute control for a deterministic system
# Cost in iteration 0: 0.0006579993303105345
# Final cost : 0.0006516304083721977
# Compute control for a deterministic system
# Cost in iteration 0: 0.03588023545074269
# Final cost : 0.000579187150758686
# Compute control for a deterministic system
# Cost in iteration 0: 0.000579187150758686
# Final cost : 0.0005774120678037005
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005774120678037005
# Final cost : 0.0005749027910028236
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005749027910028236
# Final cost : 0.0005687563230387555
# -----------------------------------------------
# 1 found better solution,  14
# Compute control for a deterministic system
# Cost in iteration 0: 0.03407006966422978
# Final cost : 0.0005284313333598986
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005284313333598986
# Final cost : 0.0005267439675954598
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005267439675954598
# Final cost : 0.0005239792851924187
# Compute control for a deterministic system
# Cost in iteration 0: 0.0005239792851924187
# Final cost : 0.0005172412468944489
# Compute control for a deterministic system
# Cost in iteration 0: 0.05655013877861743
# Final cost : 0.0004678096165828366
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004678096165828366
# Final cost : 0.0004666061795674756
# Compute control for a deterministic system
# Cost in iteration 0: 0.0004666061795674756
# Final cost : 0.00046458108544518027
# Compute control for a deterministic system
# Cost in iteration 0: 0.00046458108544518027
# Final cost : 0.00045928071435351277
# -----------------------------------------------
# 1 found better solution,  12
# Compute control for a deterministic system
# Cost in iteration 0: 0.03382017954379624
# Final cost : 0.00042656136676195967
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042656136676195967
# Final cost : 0.00042532976144754516
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042532976144754516
# Final cost : 0.00042355089643623847
# Compute control for a deterministic system
# Cost in iteration 0: 0.00042355089643623847
# Final cost : 0.0004184995644678803
# -----------------------------------------------
# 1 found better solution,  11
# Compute control for a deterministic system
# Cost in iteration 0: 0.03280364692873852
# Final cost : 0.000390496279515745
# Compute control for a deterministic system
# Cost in iteration 0: 0.000390496279515745
# Final cost : 0.00038930078689035125
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038930078689035125
# Final cost : 0.00038767987681201263
# Compute control for a deterministic system
# Cost in iteration 0: 0.00038767987681201263
# Final cost : 0.00038316925475133975
# Compute control for a deterministic system
# Cost in iteration 0: 0.04308274458868609
# Final cost : 0.0003303391294388196
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003303391294388196
# Final cost : 0.00032946373178621794
# Compute control for a deterministic system
# Cost in iteration 0: 0.00032946373178621794
# Final cost : 0.0003281899633763356
# Compute control for a deterministic system
# Cost in iteration 0: 0.0003281899633763356
# Final cost : 0.0003260654407242073
# -----------------------------------------------
# 1 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.04366466843427505
# Final cost : 0.00028982635437106756
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028982635437106756
# Final cost : 0.000288349157792771
# Compute control for a deterministic system
# Cost in iteration 0: 0.000288349157792771
# Final cost : 0.00028536611439515975
# Compute control for a deterministic system
# Cost in iteration 0: 0.00028536611439515975
# Final cost : 0.0002808892797219833
# -----------------------------------------------
# 1 found better solution,  8
# Compute control for a deterministic system
# Cost in iteration 0: 0.06776410238862458
# Final cost : 0.00024062787819276039
# Compute control for a deterministic system
# Cost in iteration 0: 0.00024062787819276039
# Final cost : 0.00023896240172825597
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023896240172825597
# Final cost : 0.00023717513427812568
# Compute control for a deterministic system
# Cost in iteration 0: 0.00023717513427812568
# Final cost : 0.00023261404157070016
# Compute control for a deterministic system
# Cost in iteration 0: 0.04813749264065107
# Final cost : 0.0001867790587103882
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001867790587103882
# Final cost : 0.00018634457388355403
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018634457388355403
# Final cost : 0.00018583647547258238
# Compute control for a deterministic system
# Cost in iteration 0: 0.00018583647547258238
# Final cost : 0.00018443482803016267
# -----------------------------------------------
# 1 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.04850074789458521
# Final cost : 0.0001473690543671989
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001473690543671989
# Final cost : 0.00014641108301497848
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014641108301497848
# Final cost : 0.0001455979561705101
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001455979561705101
# Final cost : 0.0001440376143924908
# -----------------------------------------------
# 1 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.049461334166416834
# Final cost : 0.00011258154320594747
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011258154320594747
# Final cost : 0.00011003788193113506
# Compute control for a deterministic system
# Cost in iteration 0: 0.00011003788193113506
# Final cost : 0.00010920540946472589
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010920540946472589
# Final cost : 0.00010739057780176024
# Compute control for a deterministic system
# Cost in iteration 0: 0.052027339265238864
# Final cost : 7.055471006689656e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.055471006689656e-05
# Final cost : 7.036817387731007e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.036817387731007e-05
# Final cost : 7.017564603538437e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.017564603538437e-05
# Final cost : 6.982954119360437e-05
# -----------------------------------------------
# 1 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.07705357210527672
# Final cost : 3.443112723721294e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.443112723721294e-05
# Final cost : 3.411017019664172e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.411017019664172e-05
# Final cost : 3.376425395765876e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.376425395765876e-05
# Final cost : 3.31143271228303e-05
# -----------------------------------------------
# 1 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.054307484459660806
# Final cost : 1.3385548232914223e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.3385548232914223e-05
# Final cost : 1.2487934411017509e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.2487934411017509e-05
# Final cost : 1.1814311073748216e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.1814311073748216e-05
# Final cost : 1.0563376160840439e-05
# -----------------------------------------------
# 1 found better solution,  1
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 1.5474703694555556e-05
# Final cost : 1.0364853143315841e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0364853143315841e-05
# Final cost : 1.0299755994059286e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0299755994059286e-05
# Final cost : 1.0186574750519656e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0186574750519656e-05
# Final cost : 1.0050744204459807e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.0050744204459807e-05
# Final cost : 9.799357022322214e-06
# -----------------------------------------------
# 2 found better solution,  1
# Compute control for a deterministic system
# Cost in iteration 0: 5.7998502636607536e-05
# Final cost : 3.460057880916991e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.460057880916991e-05
# Final cost : 3.445298792353993e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.445298792353993e-05
# Final cost : 3.4183353719979937e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.4183353719979937e-05
# Final cost : 3.3825512001111574e-05
# Compute control for a deterministic system
# Cost in iteration 0: 3.3825512001111574e-05
# Final cost : 3.31874453017994e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.00014328173579166673
# Final cost : 7.300462173151872e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.300462173151872e-05
# Final cost : 7.281511570777846e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.281511570777846e-05
# Final cost : 7.247908722001446e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.247908722001446e-05
# Final cost : 7.201550948803746e-05
# Compute control for a deterministic system
# Cost in iteration 0: 7.201550948803746e-05
# Final cost : 7.098499823562362e-05
# Compute control for a deterministic system
# Cost in iteration 0: 0.0002456493082191391
# Final cost : 0.00010847369195294702
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010847369195294702
# Final cost : 0.00010831088702534322
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010831088702534322
# Final cost : 0.00010803419493642685
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010803419493642685
# Final cost : 0.00010753052985305608
# Compute control for a deterministic system
# Cost in iteration 0: 0.00010753052985305608
# Final cost : 0.00010666506091810832
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 0.0117358786734896
# Final cost : 0.010007257847436977
# Compute control for a deterministic system
# Cost in iteration 0: 0.010007257847436977
# Final cost : 0.009406152816019095
# Compute control for a deterministic system
# Cost in iteration 0: 0.009406152816019095
# Final cost : 0.00917613566962331
# Compute control for a deterministic system
# Cost in iteration 0: 0.00917613566962331
# Final cost : 0.008976750500562741
# Compute control for a deterministic system
# Cost in iteration 0: 4.516046307058093
# Final cost : 0.01438425812033506
# Compute control for a deterministic system
# Cost in iteration 0: 0.01438425812033506
# Final cost : 0.010961744320222466
# Compute control for a deterministic system
# Cost in iteration 0: 0.010961744320222466
# Final cost : 0.010146477820585543
# Compute control for a deterministic system
# Cost in iteration 0: 0.010146477820585543
# Final cost : 0.009868643239235716
# Compute control for a deterministic system
# Cost in iteration 0: 0.009868643239235716
# Final cost : 0.009730335104661689
# Compute control for a deterministic system
# Cost in iteration 0: 4.978944535605012
# Final cost : 0.01669178021418277
# Compute control for a deterministic system
# Cost in iteration 0: 0.01669178021418277
# Final cost : 0.012814688846735759
# Compute control for a deterministic system
# Cost in iteration 0: 0.012814688846735759
# Final cost : 0.011200448096927744
# Compute control for a deterministic system
# Cost in iteration 0: 0.011200448096927744
# Final cost : 0.010821169195132858
# Compute control for a deterministic system
# Cost in iteration 0: 0.010821169195132858
# Final cost : 0.010572823784266494
# Compute control for a deterministic system
# Cost in iteration 0: 5.443931803215399
# Final cost : 0.018322322277295112
# Compute control for a deterministic system
# Cost in iteration 0: 0.018322322277295112
# Final cost : 0.01465717198042528
# Compute control for a deterministic system
# Cost in iteration 0: 0.01465717198042528
# Final cost : 0.012415462985600794
# Compute control for a deterministic system
# Cost in iteration 0: 0.012415462985600794
# Final cost : 0.011839845105190839
# Compute control for a deterministic system
# Cost in iteration 0: 0.011839845105190839
# Final cost : 0.011459038148183422
# Compute control for a deterministic system
# Cost in iteration 0: 5.852746106291008
# Final cost : 0.025725160607115733
# Compute control for a deterministic system
# Cost in iteration 0: 0.025725160607115733
# Final cost : 0.01955770859756272
# Compute control for a deterministic system
# Cost in iteration 0: 0.01955770859756272
# Final cost : 0.016344794378095866
# Compute control for a deterministic system
# Cost in iteration 0: 0.016344794378095866
# Final cost : 0.014672481332373163
# Compute control for a deterministic system
# Cost in iteration 0: 0.014672481332373163
# Final cost : 0.013183314062232717
# Compute control for a deterministic system
# Cost in iteration 0: 6.21421126421921
# Final cost : 0.02788983555743669
# Compute control for a deterministic system
# Cost in iteration 0: 0.02788983555743669
# Final cost : 0.02213586044356281
# Compute control for a deterministic system
# Cost in iteration 0: 0.02213586044356281
# Final cost : 0.017683872910457938
# Compute control for a deterministic system
# Cost in iteration 0: 0.017683872910457938
# Final cost : 0.01567281245267423
# Compute control for a deterministic system
# Cost in iteration 0: 0.01567281245267423
# Final cost : 0.0141487285038959
# Compute control for a deterministic system
# Cost in iteration 0: 6.350467596927626
# Final cost : 0.024719116302827013
# Compute control for a deterministic system
# Cost in iteration 0: 0.024719116302827013
# Final cost : 0.020836615080812176
# Compute control for a deterministic system
# Cost in iteration 0: 0.020836615080812176
# Final cost : 0.016932250709364285
# Compute control for a deterministic system
# Cost in iteration 0: 0.016932250709364285
# Final cost : 0.015942191522729625
# Compute control for a deterministic system
# Cost in iteration 0: 0.015942191522729625
# Final cost : 0.014878174025826016
# Compute control for a deterministic system
# Cost in iteration 0: 6.5901990945047775
# Final cost : 0.028440352469863095
# Compute control for a deterministic system
# Cost in iteration 0: 0.028440352469863095
# Final cost : 0.0223017794843131
# Compute control for a deterministic system
# Cost in iteration 0: 0.0223017794843131
# Final cost : 0.01901408885884819
# Compute control for a deterministic system
# Cost in iteration 0: 0.01901408885884819
# Final cost : 0.017633211419750758
# Compute control for a deterministic system
# Cost in iteration 0: 0.017633211419750758
# Final cost : 0.016337783778378537
# Compute control for a deterministic system
# Cost in iteration 0: 6.787470695626097
# Final cost : 0.030072478601779386
# Compute control for a deterministic system
# Cost in iteration 0: 0.030072478601779386
# Final cost : 0.023926559675373237
# Compute control for a deterministic system
# Cost in iteration 0: 0.023926559675373237
# Final cost : 0.020565994885514315
# Compute control for a deterministic system
# Cost in iteration 0: 0.020565994885514315
# Final cost : 0.018889881385115503
# Compute control for a deterministic system
# Cost in iteration 0: 0.018889881385115503
# Final cost : 0.01741957679173941
# Compute control for a deterministic system
# Cost in iteration 0: 6.992318393354223
# Final cost : 0.02625688119485968
# Compute control for a deterministic system
# Cost in iteration 0: 0.02625688119485968
# Final cost : 0.02235826296465058
# Compute control for a deterministic system
# Cost in iteration 0: 0.02235826296465058
# Final cost : 0.019936260615356777
# Compute control for a deterministic system
# Cost in iteration 0: 0.019936260615356777
# Final cost : 0.01929393930743587
# Compute control for a deterministic system
# Cost in iteration 0: 0.01929393930743587
# Final cost : 0.018606223302315133
# Compute control for a deterministic system
# Cost in iteration 0: 7.1070610486156625
# Final cost : 0.025378063473345498
# Compute control for a deterministic system
# Cost in iteration 0: 0.025378063473345498
# Final cost : 0.02289146878304061
# Compute control for a deterministic system
# Cost in iteration 0: 0.02289146878304061
# Final cost : 0.02119346821412211
# Compute control for a deterministic system
# Cost in iteration 0: 0.02119346821412211
# Final cost : 0.02043118958821343
# Compute control for a deterministic system
# Cost in iteration 0: 0.02043118958821343
# Final cost : 0.019816246797276903
# Compute control for a deterministic system
# Cost in iteration 0: 7.181963463661685
# Final cost : 0.025639271777780418
# Compute control for a deterministic system
# Cost in iteration 0: 0.025639271777780418
# Final cost : 0.023538568970305537
# Compute control for a deterministic system
# Cost in iteration 0: 0.023538568970305537
# Final cost : 0.022184196507018403
# Compute control for a deterministic system
# Cost in iteration 0: 0.022184196507018403
# Final cost : 0.02143095506877676
# Compute control for a deterministic system
# Cost in iteration 0: 0.02143095506877676
# Final cost : 0.021135983864817375
# Compute control for a deterministic system
# Cost in iteration 0: 7.243290521826391
# Final cost : 0.027253643253062895
# Compute control for a deterministic system
# Cost in iteration 0: 0.027253643253062895
# Final cost : 0.025390520477512203
# Compute control for a deterministic system
# Cost in iteration 0: 0.025390520477512203
# Final cost : 0.023672428421905783
# Compute control for a deterministic system
# Cost in iteration 0: 0.023672428421905783
# Final cost : 0.023000241871630658
# Compute control for a deterministic system
# Cost in iteration 0: 0.023000241871630658
# Final cost : 0.02275067661398881
# Compute control for a deterministic system
# Cost in iteration 0: 7.290214637617669
# Final cost : 0.028843788562864486
# Compute control for a deterministic system
# Cost in iteration 0: 0.028843788562864486
# Final cost : 0.02544861480154374
# Compute control for a deterministic system
# Cost in iteration 0: 0.02544861480154374
# Final cost : 0.025100984248300102
# Compute control for a deterministic system
# Cost in iteration 0: 0.025100984248300102
# Final cost : 0.025018772263162205
# Compute control for a deterministic system
# Cost in iteration 0: 0.025018772263162205
# Final cost : 0.02498573630580688
# Compute control for a deterministic system
# Cost in iteration 0: 7.325826968254685
# Final cost : 0.19469411720103721
# Compute control for a deterministic system
# Cost in iteration 0: 0.19469411720103721
# Final cost : 0.10933030906802808
# Compute control for a deterministic system
# Cost in iteration 0: 0.10933030906802808
# Final cost : 0.0377293518454158
# Compute control for a deterministic system
# Cost in iteration 0: 0.0377293518454158
# Final cost : 0.028568274220634075
# Compute control for a deterministic system
# Cost in iteration 0: 0.028568274220634075
# Final cost : 0.027189534995820726
# Compute control for a deterministic system
# Cost in iteration 0: 7.363723101096644
# Final cost : 0.03504268135957298
# Compute control for a deterministic system
# Cost in iteration 0: 0.03504268135957298
# Final cost : 0.03042886596889558
# Compute control for a deterministic system
# Cost in iteration 0: 0.03042886596889558
# Final cost : 0.0295997463082437
# Compute control for a deterministic system
# Cost in iteration 0: 0.0295997463082437
# Final cost : 0.029473418193168704
# Compute control for a deterministic system
# Cost in iteration 0: 0.029473418193168704
# Final cost : 0.029443287567793058
# Compute control for a deterministic system
# Cost in iteration 0: 7.408376042110148
# Final cost : 0.03474500308131986
# Compute control for a deterministic system
# Cost in iteration 0: 0.03474500308131986
# Final cost : 0.03307085276378186
# Compute control for a deterministic system
# Cost in iteration 0: 0.03307085276378186
# Final cost : 0.03233101235108809
# Compute control for a deterministic system
# Cost in iteration 0: 0.03233101235108809
# Final cost : 0.03206643702626577
# Compute control for a deterministic system
# Cost in iteration 0: 0.03206643702626577
# Final cost : 0.03200697591990196
# Compute control for a deterministic system
# Cost in iteration 0: 7.457701843048493
# Final cost : 0.05859456407925076
# Compute control for a deterministic system
# Cost in iteration 0: 0.05859456407925076
# Final cost : 0.050048227210962096
# Compute control for a deterministic system
# Cost in iteration 0: 0.050048227210962096
# Final cost : 0.04906234270508515
# Compute control for a deterministic system
# Cost in iteration 0: 0.04906234270508515
# Final cost : 0.048995113397663506
# Compute control for a deterministic system
# Cost in iteration 0: 0.048995113397663506
# Final cost : 0.04899293460175108
# Compute control for a deterministic system
# Cost in iteration 0: 0.08310216675290573
# Final cost : 0.031545677959592094
# Compute control for a deterministic system
# Cost in iteration 0: 0.031545677959592094
# Final cost : 0.030735018726139058
# Compute control for a deterministic system
# Cost in iteration 0: 0.030735018726139058
# Final cost : 0.03072647208557202
# Compute control for a deterministic system
# Cost in iteration 0: 0.03072647208557202
# Final cost : 0.03072644394161032
# Compute control for a deterministic system
# Cost in iteration 0: 0.03072644394161032
# Converged in iteration 933 with cost 0.030726443870348116 because of step counter
# Final cost : 0.030726443870348116
# Compute control for a deterministic system
# Cost in iteration 0: 0.07452786802607428
# Final cost : 0.021066530967246304
# Compute control for a deterministic system
# Cost in iteration 0: 0.021066530967246304
# Final cost : 0.020394194201054795
# Compute control for a deterministic system
# Cost in iteration 0: 0.020394194201054795
# Final cost : 0.02038657075296514
# Compute control for a deterministic system
# Cost in iteration 0: 0.02038657075296514
# Final cost : 0.020386543455773738
# Compute control for a deterministic system
# Cost in iteration 0: 0.020386543455773738
# Converged in iteration 414 with cost 0.02038654344437617 because of step counter
# Final cost : 0.02038654344437617
# Compute control for a deterministic system
# Cost in iteration 0: 0.06570560889670685
# Final cost : 0.013671700385074707
# Compute control for a deterministic system
# Cost in iteration 0: 0.013671700385074707
# Final cost : 0.013144426426717903
# Compute control for a deterministic system
# Cost in iteration 0: 0.013144426426717903
# Final cost : 0.013134026239337931
# Compute control for a deterministic system
# Cost in iteration 0: 0.013134026239337931
# Final cost : 0.013133980451199723
# Compute control for a deterministic system
# Cost in iteration 0: 0.013133980451199723
# Converged in iteration 497 with cost 0.013133980438246535 because of step counter
# Final cost : 0.013133980438246535
# Compute control for a deterministic system
# Cost in iteration 0: 0.05592847982127897
# Final cost : 0.0084746825667854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0084746825667854
# Final cost : 0.008078699624263582
# Compute control for a deterministic system
# Cost in iteration 0: 0.008078699624263582
# Final cost : 0.008074855521916863
# Compute control for a deterministic system
# Cost in iteration 0: 0.008074855521916863
# Final cost : 0.008074834065028133
# Compute control for a deterministic system
# Cost in iteration 0: 0.008074834065028133
# Converged in iteration 502 with cost 0.008074834050786503 because of step counter
# Final cost : 0.008074834050786503
# Compute control for a deterministic system
# Cost in iteration 0: 0.04482041628662282
# Final cost : 0.00489052074238648
# Compute control for a deterministic system
# Cost in iteration 0: 0.00489052074238648
# Final cost : 0.004620900694893175
# Compute control for a deterministic system
# Cost in iteration 0: 0.004620900694893175
# Final cost : 0.00461654406417918
# Compute control for a deterministic system
# Cost in iteration 0: 0.00461654406417918
# Converged in iteration 573 with cost 0.0046165434315870125 because of vanishing difference
# Final cost : 0.0046165434315870125
# Compute control for a deterministic system
# Cost in iteration 0: 0.00461654343158701
# Converged in iteration 3 with cost 0.004616543431586644 because of step counter
# Final cost : 0.004616543431586644
# Compute control for a deterministic system
# Cost in iteration 0: 0.02970343578514802
# Final cost : 0.002155261173877899
# Compute control for a deterministic system
# Cost in iteration 0: 0.002155261173877899
# Final cost : 0.0020227310159751264
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020227310159751264
# Final cost : 0.002014963084079168
# Compute control for a deterministic system
# Cost in iteration 0: 0.002014963084079168
# Final cost : 0.0020148845132111916
# Compute control for a deterministic system
# Cost in iteration 0: 0.0020148845132111916
# Converged in iteration 816 with cost 0.0020148844262879253 because of step counter
# Final cost : 0.0020148844262879253
# Compute control for a deterministic system
# Cost in iteration 0: 0.016453413042568314
# Final cost : 0.0008301563725201321
# Compute control for a deterministic system
# Cost in iteration 0: 0.0008301563725201321
# Final cost : 0.0007921047535242691
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007921047535242691
# Final cost : 0.0007908287719616786
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007908287719616786
# Final cost : 0.0007908251291666795
# Compute control for a deterministic system
# Cost in iteration 0: 0.0007908251291666795
# Converged in iteration 560 with cost 0.0007908251241679864 because of vanishing difference
# Final cost : 0.0007908251241679864
# Compute control for a deterministic system
# Cost in iteration 0: 0.005177734836472226
# Final cost : 0.0001850977349677489
# Compute control for a deterministic system
# Cost in iteration 0: 0.0001850977349677489
# Final cost : 0.00017961649770400167
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017961649770400167
# Final cost : 0.00017921418370959294
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017921418370959294
# Final cost : 0.00017920547554228723
# Compute control for a deterministic system
# Cost in iteration 0: 0.00017920547554228723
# Converged in iteration 768 with cost 0.00017920543616083538 because of step counter
# Final cost : 0.00017920543616083538

# %%
save(results_peak)
