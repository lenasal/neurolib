# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period =", period)

wc.run()
init_peak = [wc.exc[0,57], wc.inh[0,57]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period = 15.293750000000001
# peaks =  [  94  247  400  553  706  858 1011 1164 1317 1470 1623 1776 1929 2082
#  2235 2388 2541 2694 2847]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w2.png", "1_peak_w2.png", "4_peak_w2.png"]

results_peak = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w2.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
#results_min = readfile("results_min_w2.pickle")

ind_list = range(14,29,1)
#options = [True, True, True, True, True, True, True, True]
options = [True, True, True, True, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w2"])):

        w2 = results_peak['w2'][i_w]

        for i_shift in range(n_points):

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w2"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w2, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w2)
                
        save(results_peak)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06551779731059619
# Final cost : 0.05432551632310565
# Compute control for a deterministic system
# Cost in iteration 0: 0.05432551632310565
# Final cost : 0.05356012532206335
# Compute control for a deterministic system
# Cost in iteration 0: 0.05356012532206335
# Final cost : 0.05332730296387367
# Compute control for a deterministic system
# Cost in iteration 0: 0.05332730296387367
# Final cost : 0.053313434091691134
# Compute control for a deterministic system
# Cost in iteration 0: 0.053313434091691134
# Final cost : 0.053310562187689134
# Compute control for a deterministic system
# Cost in iteration 0: 0.06035556197765568
# Final cost : 0.05908624522370194
# Compute control for a deterministic system
# Cost in iteration 0: 0.05908624522370194
# Final cost : 0.05855865204688207
# Compute control for a deterministic system
# Cost in iteration 0: 0.05855865204688207
# Final cost : 0.05842290602265718
# Compute control for a deterministic system
# Cost in iteration 0: 0.05842290602265718
# Final cost : 0.05840957414707158
# Compute control for a deterministic system
# Cost in iteration 0: 0.05840957414707158
# Final cost : 0.05840749340533952
# Compute control for a deterministic system
# Cost in iteration 0: 0.07470075427172032
# Final cost : 0.06662120596206089
# Compute control for a deterministic system
# Cost in iteration 0: 0.06662120596206089
# Final cost : 0.06565386155074324
# Compute control for a deterministic system
# Cost in iteration 0: 0.06565386155074324
# Final cost : 0.0654037752696255
# Compute control for a deterministic system
# Cost in iteration 0: 0.0654037752696255
# Final cost : 0.06537348564890237
# Compute control for a deterministic system
# Cost in iteration 0: 0.06537348564890237
# Final cost : 0.0653588749398536
# Compute control for a deterministic system
# Cost in iteration 0: 0.08047896655860635
# Final cost : 0.07383275739918131
# Compute control for a deterministic system
# Cost in iteration 0: 0.07383275739918131
# Final cost : 0.07274709732010376
# Compute control for a deterministic system
# Cost in iteration 0: 0.07274709732010376
# Final cost : 0.07249340291420515
# Compute control for a deterministic system
# Cost in iteration 0: 0.07249340291420515
# Final cost : 0.07243285630368938
# Compute control for a deterministic system
# Cost in iteration 0: 0.07243285630368938
# Final cost : 0.07238241864980142
# Compute control for a deterministic system
# Cost in iteration 0: 0.07840194728353952
# Final cost : 0.07483925709311494
# Compute control for a deterministic system
# Cost in iteration 0: 0.07483925709311494
# Final cost : 0.07442721543324583
# Compute control for a deterministic system
# Cost in iteration 0: 0.07442721543324583
# Final cost : 0.07425988767048773
# Compute control for a deterministic system
# Cost in iteration 0: 0.07425988767048773
# Final cost : 0.07418346221227588
# Compute control for a deterministic system
# Cost in iteration 0: 0.07418346221227588
# Final cost : 0.07412852400885014
# Compute control for a deterministic system
# Cost in iteration 0: 0.09220708869877445
# Final cost : 0.07786941126869185
# Compute control for a deterministic system
# Cost in iteration 0: 0.07786941126869185
# Final cost : 0.07761116555735942
# Compute control for a deterministic system
# Cost in iteration 0: 0.07761116555735942
# Final cost : 0.07748831190890966
# Compute control for a deterministic system
# Cost in iteration 0: 0.07748831190890966
# Final cost : 0.07743507741074648
# Compute control for a deterministic system
# Cost in iteration 0: 0.07743507741074648
# Final cost : 0.07740355114016809
# Compute control for a deterministic system
# Cost in iteration 0: 0.13412246012802084
# Final cost : 0.07991702580655739
# Compute control for a deterministic system
# Cost in iteration 0: 0.07991702580655739
# Final cost : 0.07973686482642685
# Compute control for a deterministic system
# Cost in iteration 0: 0.07973686482642685
# Final cost : 0.07967527943197669
# Compute control for a deterministic system
# Cost in iteration 0: 0.07967527943197669
# Final cost : 0.07963725955889846
# Compute control for a deterministic system
# Cost in iteration 0: 0.07963725955889846
# Final cost : 0.07960945726666106
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.14855628832663384
# Final cost : 0.08252546144613651
# Compute control for a deterministic system
# Cost in iteration 0: 0.08252546144613651
# Final cost : 0.08242502190213834
# Compute control for a deterministic system
# Cost in iteration 0: 0.08242502190213834
# Final cost : 0.08231526197802004
# Compute control for a deterministic system
# Cost in iteration 0: 0.08231526197802004
# Final cost : 0.08224284753871
# Compute control for a deterministic system
# Cost in iteration 0: 0.08224284753871
# Final cost : 0.08217081349994522
# -----------------------------------------------
# 0 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.15073105972405923
# Final cost : 0.08461839785097383
# Compute control for a deterministic system
# Cost in iteration 0: 0.08461839785097383
# Final cost : 0.08454840281260716
# Compute control for a deterministic system
# Cost in iteration 0: 0.08454840281260716
# Final cost : 0.08446204237361184
# Compute control for a deterministic system
# Cost in iteration 0: 0.08446204237361184
# Final cost : 0.08438286050845112
# Compute control for a deterministic system
# Cost in iteration 0: 0.08438286050845112
# Final cost : 0.0842881300121613
# -----------------------------------------------
# 0 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.15251218902989297
# Final cost : 0.08629877104355628
# Compute control for a deterministic system
# Cost in iteration 0: 0.08629877104355628
# Final cost : 0.08625076850454118
# Compute control for a deterministic system
# Cost in iteration 0: 0.08625076850454118
# Final cost : 0.08616720592746058
# Compute control for a deterministic system
# Cost in iteration 0: 0.08616720592746058
# Final cost : 0.08611075101918048
# Compute control for a deterministic system
# Cost in iteration 0: 0.08611075101918048
# Final cost : 0.08601028348483751
# -----------------------------------------------
# 0 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.15400293832800432
# Final cost : 0.0876701887241876
# Compute control for a deterministic system
# Cost in iteration 0: 0.0876701887241876
# Final cost : 0.0876291094588281
# Compute control for a deterministic system
# Cost in iteration 0: 0.0876291094588281
# Final cost : 0.0875809860431981
# Compute control for a deterministic system
# Cost in iteration 0: 0.0875809860431981
# Final cost : 0.08752133239571172
# Compute control for a deterministic system
# Cost in iteration 0: 0.08752133239571172
# Final cost : 0.087420083889309
# -----------------------------------------------
# 0 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.15550252423518893
# Final cost : 0.08879607148499581
# Compute control for a deterministic system
# Cost in iteration 0: 0.08879607148499581
# Final cost : 0.0887793827119762
# Compute control for a deterministic system
# Cost in iteration 0: 0.0887793827119762
# Final cost : 0.08874298766089302
# Compute control for a deterministic system
# Cost in iteration 0: 0.08874298766089302
# Final cost : 0.08870364793292437
# Compute control for a deterministic system
# Cost in iteration 0: 0.08870364793292437
# Final cost : 0.08861786771817029
# Compute control for a deterministic system
# Cost in iteration 0: 0.11634484068912987
# Final cost : 0.0794890194072672
# Compute control for a deterministic system
# Cost in iteration 0: 0.0794890194072672
# Final cost : 0.0789782788386755
# Compute control for a deterministic system
# Cost in iteration 0: 0.0789782788386755
# Final cost : 0.0787379790886772
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787379790886772
# Final cost : 0.07873035528876088
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873035528876088
# Final cost : 0.0787301363234901
# Compute control for a deterministic system
# Cost in iteration 0: 0.13446818210493108
# Final cost : 0.06861887143433819
# Compute control for a deterministic system
# Cost in iteration 0: 0.06861887143433819
# Final cost : 0.06779911819762151
# Compute control for a deterministic system
# Cost in iteration 0: 0.06779911819762151
# Final cost : 0.06741366873870186
# Compute control for a deterministic system
# Cost in iteration 0: 0.06741366873870186
# Final cost : 0.0674046350922983
# Compute control for a deterministic system
# Cost in iteration 0: 0.0674046350922983
# Converged in iteration 1866 with cost 0.06740448887067504 because of step counter
# Final cost : 0.06740448887067504
# Compute control for a deterministic system
# Cost in iteration 0: 0.12441174769430449
# Final cost : 0.05806728047881045
# Compute control for a deterministic system
# Cost in iteration 0: 0.05806728047881045
# Final cost : 0.057309242117987096
# Compute control for a deterministic system
# Cost in iteration 0: 0.057309242117987096
# Final cost : 0.056969062564050536
# Compute control for a deterministic system
# Cost in iteration 0: 0.056969062564050536
# Final cost : 0.056960882072776074
# Compute control for a deterministic system
# Cost in iteration 0: 0.056960882072776074
# Converged in iteration 1755 with cost 0.05696085198541473 because of step counter
# Final cost : 0.05696085198541473
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 0.11088691712760201
# Final cost : 0.057309195132824634
# Compute control for a deterministic system
# Cost in iteration 0: 0.057309195132824634
# Final cost : 0.05696587777846694
# Compute control for a deterministic system
# Cost in iteration 0: 0.05696587777846694
# Final cost : 0.05696091986243157
# Compute control for a deterministic system
# Cost in iteration 0: 0.05696091986243157
# Converged in iteration 1766 with cost 0.056960851985442935 because of step counter
# Final cost : 0.056960851985442935
# Compute control for a deterministic system
# Cost in iteration 0: 0.11979845694915135
# Final cost : 0.06780098129225529
# Compute control for a deterministic system
# Cost in iteration 0: 0.06780098129225529
# Final cost : 0.06741159129700089
# Compute control for a deterministic system
# Cost in iteration 0: 0.06741159129700089
# Final cost : 0.06740464266818585
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740464266818585
# Converged in iteration 1941 with cost 0.06740448887068498 because of vanishing difference
# Final cost : 0.06740448887068498
# Compute control for a deterministic system
# Cost in iteration 0: 0.12960074956551632
# Final cost : 0.07917735760724917
# Compute control for a deterministic system
# Cost in iteration 0: 0.07917735760724917
# Final cost : 0.0787398408402038
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787398408402038
# Final cost : 0.07873048709814859
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873048709814859
# Final cost : 0.07873013632349006
# Compute control for a deterministic system
# Cost in iteration 0: 0.11280134580971321
# Final cost : 0.08808392240393884
# Compute control for a deterministic system
# Cost in iteration 0: 0.08808392240393884
# Final cost : 0.08781556766289689
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781556766289689
# Final cost : 0.08780874852924302
# Compute control for a deterministic system
# Cost in iteration 0: 0.08780874852924302
# Converged in iteration 1667 with cost 0.08780843172843887 because of step counter
# Final cost : 0.08780843172843887
# Compute control for a deterministic system
# Cost in iteration 0: 0.14899793263917666
# Final cost : 0.10124057655790016
# Compute control for a deterministic system
# Cost in iteration 0: 0.10124057655790016
# Final cost : 0.1007156949753555
# Compute control for a deterministic system
# Cost in iteration 0: 0.1007156949753555
# Final cost : 0.10070134588499811
# Compute control for a deterministic system
# Cost in iteration 0: 0.10070134588499811
# Converged in iteration 1760 with cost 0.10070045910133937 because of vanishing difference
# Final cost : 0.10070045910133937
# Compute control for a deterministic system
# Cost in iteration 0: 0.35571843294409256
# Final cost : 0.0859668182017371
# Compute control for a deterministic system
# Cost in iteration 0: 0.0859668182017371
# Final cost : 0.08595293419844006
# Compute control for a deterministic system
# Cost in iteration 0: 0.08595293419844006
# Final cost : 0.08593629524106587
# Compute control for a deterministic system
# Cost in iteration 0: 0.08593629524106587
# Final cost : 0.0858950743268399
# -----------------------------------------------
# 1 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.33602811189350934
# Final cost : 0.08428530069214779
# Compute control for a deterministic system
# Cost in iteration 0: 0.08428530069214779
# Final cost : 0.08425714710803947
# Compute control for a deterministic system
# Cost in iteration 0: 0.08425714710803947
# Final cost : 0.08422596079539629
# Compute control for a deterministic system
# Cost in iteration 0: 0.08422596079539629
# Final cost : 0.0841679101797671
# -----------------------------------------------
# 1 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.3047052941453058
# Final cost : 0.08234804349385874
# Compute control for a deterministic system
# Cost in iteration 0: 0.08234804349385874
# Final cost : 0.08227051023391185
# Compute control for a deterministic system
# Cost in iteration 0: 0.08227051023391185
# Final cost : 0.0821909117440946
# Compute control for a deterministic system
# Cost in iteration 0: 0.0821909117440946
# Final cost : 0.082084409951442
# -----------------------------------------------
# 1 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.08226784905521635
# Final cost : 0.07989151010251101
# Compute control for a deterministic system
# Cost in iteration 0: 0.07989151010251101
# Final cost : 0.07980755044491733
# Compute control for a deterministic system
# Cost in iteration 0: 0.07980755044491733
# Final cost : 0.07971547635607519
# Compute control for a deterministic system
# Cost in iteration 0: 0.07971547635607519
# Final cost : 0.07959350940790923
# -----------------------------------------------
# 1 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.07842462204213586
# Final cost : 0.07764579533478043
# Compute control for a deterministic system
# Cost in iteration 0: 0.07764579533478043
# Final cost : 0.07757510429301545
# Compute control for a deterministic system
# Cost in iteration 0: 0.07757510429301545
# Final cost : 0.07751106929253358
# Compute control for a deterministic system
# Cost in iteration 0: 0.07751106929253358
# Final cost : 0.07743889673866931
# Compute control for a deterministic system
# Cost in iteration 0: 0.08963381787187477
# Final cost : 0.07434242565776615
# Compute control for a deterministic system
# Cost in iteration 0: 0.07434242565776615
# Final cost : 0.07423147491439767
# Compute control for a deterministic system
# Cost in iteration 0: 0.07423147491439767
# Final cost : 0.07414104980523466
# Compute control for a deterministic system
# Cost in iteration 0: 0.07414104980523466
# Final cost : 0.07408442703836758
# Compute control for a deterministic system
# Cost in iteration 0: 0.09183395196627459
# Final cost : 0.07064939695648528
# Compute control for a deterministic system
# Cost in iteration 0: 0.07064939695648528
# Final cost : 0.0704947544441854
# Compute control for a deterministic system
# Cost in iteration 0: 0.0704947544441854
# Final cost : 0.07040033538007068
# Compute control for a deterministic system
# Cost in iteration 0: 0.07040033538007068
# Final cost : 0.07033683932116747
# Compute control for a deterministic system
# Cost in iteration 0: 0.09449401576384896
# Final cost : 0.06631357060117363
# Compute control for a deterministic system
# Cost in iteration 0: 0.06631357060117363
# Final cost : 0.0661487572750555
# Compute control for a deterministic system
# Cost in iteration 0: 0.0661487572750555
# Final cost : 0.06605386553451692
# Compute control for a deterministic system
# Cost in iteration 0: 0.06605386553451692
# Final cost : 0.06599918912008021
# Compute control for a deterministic system
# Cost in iteration 0: 0.10317338105280849
# Final cost : 0.05874228406974135
# Compute control for a deterministic system
# Cost in iteration 0: 0.05874228406974135
# Final cost : 0.0584461033859374
# Compute control for a deterministic system
# Cost in iteration 0: 0.0584461033859374
# Final cost : 0.058417230046489264
# Compute control for a deterministic system
# Cost in iteration 0: 0.058417230046489264
# Final cost : 0.0584076612779604
# Compute control for a deterministic system
# Cost in iteration 0: 0.0762671329749476
# Final cost : 0.05348215953366777
# Compute control for a deterministic system
# Cost in iteration 0: 0.05348215953366777
# Final cost : 0.05332442410382996
# Compute control for a deterministic system
# Cost in iteration 0: 0.05332442410382996
# Final cost : 0.053311481213117934
# Compute control for a deterministic system
# Cost in iteration 0: 0.053311481213117934
# Final cost : 0.0533105610118112
# ----------------------------------------------- 2
# Compute control for a deterministic system
# Cost in iteration 0: 0.11958004533601058
# Final cost : 0.06893826958752848
# Compute control for a deterministic system
# Cost in iteration 0: 0.06893826958752848
# Final cost : 0.05669679288853719
# Compute control for a deterministic system
# Cost in iteration 0: 0.05669679288853719
# Final cost : 0.0534483173784869
# Compute control for a deterministic system
# Cost in iteration 0: 0.0534483173784869
# Final cost : 0.053328472195315835
# Compute control for a deterministic system
# Cost in iteration 0: 0.053328472195315835
# Final cost : 0.05331057853387277
# Compute control for a deterministic system
# Cost in iteration 0: 0.13049038377747174
# Final cost : 0.07605728435447794
# Compute control for a deterministic system
# Cost in iteration 0: 0.07605728435447794
# Final cost : 0.06236111161266702
# Compute control for a deterministic system
# Cost in iteration 0: 0.06236111161266702
# Final cost : 0.05860801870798858
# Compute control for a deterministic system
# Cost in iteration 0: 0.05860801870798858
# Final cost : 0.05842480611171591
# Compute control for a deterministic system
# Cost in iteration 0: 0.05842480611171591
# Final cost : 0.05840766483882226
# Compute control for a deterministic system
# Cost in iteration 0: 0.14528506299611874
# Final cost : 0.08598705551390216
# Compute control for a deterministic system
# Cost in iteration 0: 0.08598705551390216
# Final cost : 0.07014882067003594
# Compute control for a deterministic system
# Cost in iteration 0: 0.07014882067003594
# Final cost : 0.06574726575528628
# Compute control for a deterministic system
# Cost in iteration 0: 0.06574726575528628
# Final cost : 0.0654505587781646
# Compute control for a deterministic system
# Cost in iteration 0: 0.0654505587781646
# Final cost : 0.06536075838066197
# Compute control for a deterministic system
# Cost in iteration 0: 0.16017414104254657
# Final cost : 0.09634381839091954
# Compute control for a deterministic system
# Cost in iteration 0: 0.09634381839091954
# Final cost : 0.07814286338885212
# Compute control for a deterministic system
# Cost in iteration 0: 0.07814286338885212
# Final cost : 0.07306041386655161
# Compute control for a deterministic system
# Cost in iteration 0: 0.07306041386655161
# Final cost : 0.07267532355586877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07267532355586877
# Final cost : 0.07241632656248079
# Compute control for a deterministic system
# Cost in iteration 0: 0.17486441639313988
# Final cost : 0.1069915686145553
# Compute control for a deterministic system
# Cost in iteration 0: 0.1069915686145553
# Final cost : 0.08623949879786189
# Compute control for a deterministic system
# Cost in iteration 0: 0.08623949879786189
# Final cost : 0.08045837077633931
# Compute control for a deterministic system
# Cost in iteration 0: 0.08045837077633931
# Final cost : 0.08014534920317215
# Compute control for a deterministic system
# Cost in iteration 0: 0.08014534920317215
# Final cost : 0.07979935889538803
# Compute control for a deterministic system
# Cost in iteration 0: 0.18890647437663774
# Final cost : 0.11769489949662301
# Compute control for a deterministic system
# Cost in iteration 0: 0.11769489949662301
# Final cost : 0.09426604045814689
# Compute control for a deterministic system
# Cost in iteration 0: 0.09426604045814689
# Final cost : 0.08718765804634783
# Compute control for a deterministic system
# Cost in iteration 0: 0.08718765804634783
# Final cost : 0.08670756501546881
# Compute control for a deterministic system
# Cost in iteration 0: 0.08670756501546881
# Final cost : 0.08626439866446114
# Compute control for a deterministic system
# Cost in iteration 0: 0.09659796165583585
# Final cost : 0.0827541922799209
# Compute control for a deterministic system
# Cost in iteration 0: 0.0827541922799209
# Final cost : 0.080376986640052
# Compute control for a deterministic system
# Cost in iteration 0: 0.080376986640052
# Final cost : 0.07995416186401859
# Compute control for a deterministic system
# Cost in iteration 0: 0.07995416186401859
# Final cost : 0.07977760503350913
# Compute control for a deterministic system
# Cost in iteration 0: 0.07977760503350913
# Final cost : 0.07966309183468356
# Compute control for a deterministic system
# Cost in iteration 0: 0.09469814336990484
# Final cost : 0.08393499975818633
# Compute control for a deterministic system
# Cost in iteration 0: 0.08393499975818633
# Final cost : 0.08256184544316032
# Compute control for a deterministic system
# Cost in iteration 0: 0.08256184544316032
# Final cost : 0.08233368940856357
# Compute control for a deterministic system
# Cost in iteration 0: 0.08233368940856357
# Final cost : 0.08220695599509929
# Compute control for a deterministic system
# Cost in iteration 0: 0.08220695599509929
# Final cost : 0.0821070436950086
# Compute control for a deterministic system
# Cost in iteration 0: 0.10117818823907085
# Final cost : 0.0850551310409217
# Compute control for a deterministic system
# Cost in iteration 0: 0.0850551310409217
# Final cost : 0.08432896229511774
# Compute control for a deterministic system
# Cost in iteration 0: 0.08432896229511774
# Final cost : 0.08420170011705815
# Compute control for a deterministic system
# Cost in iteration 0: 0.08420170011705815
# Final cost : 0.08412057367960446
# Compute control for a deterministic system
# Cost in iteration 0: 0.08412057367960446
# Final cost : 0.08406181913001559
# -----------------------------------------------
# 2 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.3202149681557748
# Final cost : 0.18544042490838913
# Compute control for a deterministic system
# Cost in iteration 0: 0.18544042490838913
# Final cost : 0.12674819676802607
# Compute control for a deterministic system
# Cost in iteration 0: 0.12674819676802607
# Final cost : 0.11475116255069573
# Compute control for a deterministic system
# Cost in iteration 0: 0.11475116255069573
# Final cost : 0.11452537625370791
# Compute control for a deterministic system
# Cost in iteration 0: 0.11452537625370791
# Converged in iteration 1967 with cost 0.11450699956411757 because of step counter
# Final cost : 0.11450699956411757
# Compute control for a deterministic system
# Cost in iteration 0: 0.2804588081920173
# Final cost : 0.15975483664739992
# Compute control for a deterministic system
# Cost in iteration 0: 0.15975483664739992
# Final cost : 0.11034453615740021
# Compute control for a deterministic system
# Cost in iteration 0: 0.11034453615740021
# Final cost : 0.10087483512718326
# Compute control for a deterministic system
# Cost in iteration 0: 0.10087483512718326
# Final cost : 0.10071126127180005
# Compute control for a deterministic system
# Cost in iteration 0: 0.10071126127180005
# Final cost : 0.1007004591012799
# Compute control for a deterministic system
# Cost in iteration 0: 0.24373863838711748
# Final cost : 0.13664120686983028
# Compute control for a deterministic system
# Cost in iteration 0: 0.13664120686983028
# Final cost : 0.09532232238062031
# Compute control for a deterministic system
# Cost in iteration 0: 0.09532232238062031
# Final cost : 0.08791616839695064
# Compute control for a deterministic system
# Cost in iteration 0: 0.08791616839695064
# Final cost : 0.08781390210301289
# Compute control for a deterministic system
# Cost in iteration 0: 0.08781390210301289
# Final cost : 0.08780843173431045
# Compute control for a deterministic system
# Cost in iteration 0: 0.2182343176523956
# Final cost : 0.12095261643896839
# Compute control for a deterministic system
# Cost in iteration 0: 0.12095261643896839
# Final cost : 0.08491758156372463
# Compute control for a deterministic system
# Cost in iteration 0: 0.08491758156372463
# Final cost : 0.07881152329904267
# Compute control for a deterministic system
# Cost in iteration 0: 0.07881152329904267
# Final cost : 0.07873331500743486
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873331500743486
# Final cost : 0.07873013632495533
# Compute control for a deterministic system
# Cost in iteration 0: 0.18704732482239755
# Final cost : 0.1022299625715064
# Compute control for a deterministic system
# Cost in iteration 0: 0.1022299625715064
# Final cost : 0.07214911184992577
# Compute control for a deterministic system
# Cost in iteration 0: 0.07214911184992577
# Final cost : 0.06745636735241498
# Compute control for a deterministic system
# Cost in iteration 0: 0.06745636735241498
# Final cost : 0.06740582470432525
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740582470432525
# Converged in iteration 1665 with cost 0.06740448887070918 because of step counter
# Final cost : 0.06740448887070918
# Compute control for a deterministic system
# Cost in iteration 0: 0.15891150745729699
# Final cost : 0.08598635549688095
# Compute control for a deterministic system
# Cost in iteration 0: 0.08598635549688095
# Final cost : 0.06059629605507951
# Compute control for a deterministic system
# Cost in iteration 0: 0.06059629605507951
# Final cost : 0.056990754611134516
# Compute control for a deterministic system
# Cost in iteration 0: 0.056990754611134516
# Final cost : 0.05696125291864513
# Compute control for a deterministic system
# Cost in iteration 0: 0.05696125291864513
# Converged in iteration 1955 with cost 0.056960851985407956 because of vanishing difference
# Final cost : 0.056960851985407956
# ----------------------------------------------- 3
# Compute control for a deterministic system
# Cost in iteration 0: 0.05872667163812838
# Final cost : 0.05551697274304009
# Compute control for a deterministic system
# Cost in iteration 0: 0.05551697274304009
# Final cost : 0.05388268018274358
# Compute control for a deterministic system
# Cost in iteration 0: 0.05388268018274358
# Final cost : 0.053339398111049215
# Compute control for a deterministic system
# Cost in iteration 0: 0.053339398111049215
# Final cost : 0.05331570913509505
# Compute control for a deterministic system
# Cost in iteration 0: 0.05331570913509505
# Final cost : 0.053310578663335675
# Compute control for a deterministic system
# Cost in iteration 0: 0.06419341400889322
# Final cost : 0.060789108624405015
# Compute control for a deterministic system
# Cost in iteration 0: 0.060789108624405015
# Final cost : 0.059049039852118394
# Compute control for a deterministic system
# Cost in iteration 0: 0.059049039852118394
# Final cost : 0.05846346040769368
# Compute control for a deterministic system
# Cost in iteration 0: 0.05846346040769368
# Final cost : 0.058414247097104736
# Compute control for a deterministic system
# Cost in iteration 0: 0.058414247097104736
# Final cost : 0.05840752281569877
# Compute control for a deterministic system
# Cost in iteration 0: 0.07160910071983985
# Final cost : 0.06797511141404974
# Compute control for a deterministic system
# Cost in iteration 0: 0.06797511141404974
# Final cost : 0.06609408646714245
# Compute control for a deterministic system
# Cost in iteration 0: 0.06609408646714245
# Final cost : 0.06544713485142588
# Compute control for a deterministic system
# Cost in iteration 0: 0.06544713485142588
# Final cost : 0.06538468442074216
# Compute control for a deterministic system
# Cost in iteration 0: 0.06538468442074216
# Final cost : 0.06535892206873212
# Compute control for a deterministic system
# Cost in iteration 0: 0.07908271749245972
# Final cost : 0.07526551566846672
# Compute control for a deterministic system
# Cost in iteration 0: 0.07526551566846672
# Final cost : 0.07325091547573635
# Compute control for a deterministic system
# Cost in iteration 0: 0.07325091547573635
# Final cost : 0.07253306799438106
# Compute control for a deterministic system
# Cost in iteration 0: 0.07253306799438106
# Final cost : 0.07245412479935492
# Compute control for a deterministic system
# Cost in iteration 0: 0.07245412479935492
# Final cost : 0.07238602035628199
# Compute control for a deterministic system
# Cost in iteration 0: 0.08018036345676863
# Final cost : 0.07465422804146361
# Compute control for a deterministic system
# Cost in iteration 0: 0.07465422804146361
# Final cost : 0.07420703947111464
# Compute control for a deterministic system
# Cost in iteration 0: 0.07420703947111464
# Final cost : 0.07412643621170704
# Compute control for a deterministic system
# Cost in iteration 0: 0.07412643621170704
# Final cost : 0.0740915737982148
# Compute control for a deterministic system
# Cost in iteration 0: 0.0740915737982148
# Final cost : 0.07407429766125956
# -----------------------------------------------
# 3 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.0863137333297199
# Final cost : 0.07779334893022555
# Compute control for a deterministic system
# Cost in iteration 0: 0.07779334893022555
# Final cost : 0.07748722196620011
# Compute control for a deterministic system
# Cost in iteration 0: 0.07748722196620011
# Final cost : 0.0774327267398853
# Compute control for a deterministic system
# Cost in iteration 0: 0.0774327267398853
# Final cost : 0.07740909345073702
# Compute control for a deterministic system
# Cost in iteration 0: 0.07740909345073702
# Final cost : 0.07739372178636508
# -----------------------------------------------
# 3 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.09150733262018278
# Final cost : 0.07991551959445145
# Compute control for a deterministic system
# Cost in iteration 0: 0.07991551959445145
# Final cost : 0.07967722023713424
# Compute control for a deterministic system
# Cost in iteration 0: 0.07967722023713424
# Final cost : 0.0796272073638919
# Compute control for a deterministic system
# Cost in iteration 0: 0.0796272073638919
# Final cost : 0.07960914236928833
# Compute control for a deterministic system
# Cost in iteration 0: 0.07960914236928833
# Final cost : 0.07959376121332196
# Compute control for a deterministic system
# Cost in iteration 0: 0.10431566686215572
# Final cost : 0.08220878926832995
# Compute control for a deterministic system
# Cost in iteration 0: 0.08220878926832995
# Final cost : 0.08206774572021766
# Compute control for a deterministic system
# Cost in iteration 0: 0.08206774572021766
# Final cost : 0.08204494850895146
# Compute control for a deterministic system
# Cost in iteration 0: 0.08204494850895146
# Final cost : 0.0820337419895332
# Compute control for a deterministic system
# Cost in iteration 0: 0.0820337419895332
# Final cost : 0.08202341107617048
# -----------------------------------------------
# 3 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.12233225600421399
# Final cost : 0.08411319709742204
# Compute control for a deterministic system
# Cost in iteration 0: 0.08411319709742204
# Final cost : 0.08404517670931039
# Compute control for a deterministic system
# Cost in iteration 0: 0.08404517670931039
# Final cost : 0.08401002426804476
# Compute control for a deterministic system
# Cost in iteration 0: 0.08401002426804476
# Final cost : 0.0840003367235178
# Compute control for a deterministic system
# Cost in iteration 0: 0.0840003367235178
# Final cost : 0.08399192382518676
# -----------------------------------------------
# 3 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.14676881008273052
# Final cost : 0.08571465666428629
# Compute control for a deterministic system
# Cost in iteration 0: 0.08571465666428629
# Final cost : 0.08566842336206007
# Compute control for a deterministic system
# Cost in iteration 0: 0.08566842336206007
# Final cost : 0.08564063794332576
# Compute control for a deterministic system
# Cost in iteration 0: 0.08564063794332576
# Final cost : 0.08562555817324252
# Compute control for a deterministic system
# Cost in iteration 0: 0.08562555817324252
# Final cost : 0.08561339272320029
# -----------------------------------------------
# 3 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.17659638826924845
# Final cost : 0.08711632857875913
# Compute control for a deterministic system
# Cost in iteration 0: 0.08711632857875913
# Final cost : 0.08708149636481456
# Compute control for a deterministic system
# Cost in iteration 0: 0.08708149636481456
# Final cost : 0.08705224519157029
# Compute control for a deterministic system
# Cost in iteration 0: 0.08705224519157029
# Final cost : 0.08703838100256323
# Compute control for a deterministic system
# Cost in iteration 0: 0.08703838100256323
# Final cost : 0.08700677714079444
# -----------------------------------------------
# 3 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 0.10218916750845246
# Final cost : 0.09438136637641023
# Compute control for a deterministic system
# Cost in iteration 0: 0.09438136637641023
# Final cost : 0.08902316519313394
# Compute control for a deterministic system
# Cost in iteration 0: 0.08902316519313394
# Final cost : 0.08783303436460191
# Compute control for a deterministic system
# Cost in iteration 0: 0.08783303436460191
# Final cost : 0.08780953398009556
# Compute control for a deterministic system
# Cost in iteration 0: 0.08780953398009556
# Final cost : 0.0878084317288457
# Compute control for a deterministic system
# Cost in iteration 0: 0.09159687160764252
# Final cost : 0.08450345591848415
# Compute control for a deterministic system
# Cost in iteration 0: 0.08450345591848415
# Final cost : 0.07973481023207334
# Compute control for a deterministic system
# Cost in iteration 0: 0.07973481023207334
# Final cost : 0.07874812102973597
# Compute control for a deterministic system
# Cost in iteration 0: 0.07874812102973597
# Final cost : 0.07873074625042809
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873074625042809
# Final cost : 0.07873013632361756
# Compute control for a deterministic system
# Cost in iteration 0: 0.07840745288512496
# Final cost : 0.07222968278035855
# Compute control for a deterministic system
# Cost in iteration 0: 0.07222968278035855
# Final cost : 0.06817447328579657
# Compute control for a deterministic system
# Cost in iteration 0: 0.06817447328579657
# Final cost : 0.06741633725625068
# Compute control for a deterministic system
# Cost in iteration 0: 0.06741633725625068
# Final cost : 0.06740476094095814
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740476094095814
# Final cost : 0.06740448887078625
# Compute control for a deterministic system
# Cost in iteration 0: 0.066292611641741
# Final cost : 0.06097885375338007
# Compute control for a deterministic system
# Cost in iteration 0: 0.06097885375338007
# Final cost : 0.05754415104148283
# Compute control for a deterministic system
# Cost in iteration 0: 0.05754415104148283
# Final cost : 0.056967998571833864
# Compute control for a deterministic system
# Cost in iteration 0: 0.056967998571833864
# Final cost : 0.05696094245119498
# Compute control for a deterministic system
# Cost in iteration 0: 0.05696094245119498
# Converged in iteration 1827 with cost 0.05696085198548303 because of step counter
# Final cost : 0.05696085198548303
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.13199523435201785
# Final cost : 0.05404626586327023
# Compute control for a deterministic system
# Cost in iteration 0: 0.05404626586327023
# Final cost : 0.05331381934115539
# Compute control for a deterministic system
# Cost in iteration 0: 0.05331381934115539
# Final cost : 0.05331055944778601
# Compute control for a deterministic system
# Cost in iteration 0: 0.05331055944778601
# Final cost : 0.05331055648506026
# Compute control for a deterministic system
# Cost in iteration 0: 0.05331055648506026
# Final cost : 0.05331055645324256
# Compute control for a deterministic system
# Cost in iteration 0: 0.14231432834646374
# Final cost : 0.05927366699866336
# Compute control for a deterministic system
# Cost in iteration 0: 0.05927366699866336
# Final cost : 0.05841103078093761
# Compute control for a deterministic system
# Cost in iteration 0: 0.05841103078093761
# Final cost : 0.0584074735037102
# Compute control for a deterministic system
# Cost in iteration 0: 0.0584074735037102
# Final cost : 0.05840746862762168
# Compute control for a deterministic system
# Cost in iteration 0: 0.05840746862762168
# Converged in iteration 1147 with cost 0.0584074686190759 because of step counter
# Final cost : 0.0584074686190759
# -----------------------------------------------
# 4 found better solution,  15
# Compute control for a deterministic system
# Cost in iteration 0: 0.15592657625474826
# Final cost : 0.066439645884517
# Compute control for a deterministic system
# Cost in iteration 0: 0.066439645884517
# Final cost : 0.06536279152271787
# Compute control for a deterministic system
# Cost in iteration 0: 0.06536279152271787
# Final cost : 0.06535878129915994
# Compute control for a deterministic system
# Cost in iteration 0: 0.06535878129915994
# Final cost : 0.06535878003988109
# Compute control for a deterministic system
# Cost in iteration 0: 0.06535878003988109
# Converged in iteration 998 with cost 0.06535878003579088 because of vanishing difference
# Final cost : 0.06535878003579088
# -----------------------------------------------
# 4 found better solution,  16
# Compute control for a deterministic system
# Cost in iteration 0: 0.28279549317746977
# Final cost : 0.07459706684072681
# Compute control for a deterministic system
# Cost in iteration 0: 0.07459706684072681
# Final cost : 0.07032105291992911
# Compute control for a deterministic system
# Cost in iteration 0: 0.07032105291992911
# Final cost : 0.07031562397475741
# Compute control for a deterministic system
# Cost in iteration 0: 0.07031562397475741
# Final cost : 0.07031204944923261
# Compute control for a deterministic system
# Cost in iteration 0: 0.07031204944923261
# Final cost : 0.070306047398699
# -----------------------------------------------
# 4 found better solution,  17
# Compute control for a deterministic system
# Cost in iteration 0: 0.3529364981117201
# Final cost : 0.07952670318322844
# Compute control for a deterministic system
# Cost in iteration 0: 0.07952670318322844
# Final cost : 0.07407967956448071
# Compute control for a deterministic system
# Cost in iteration 0: 0.07407967956448071
# Final cost : 0.07407462441739801
# Compute control for a deterministic system
# Cost in iteration 0: 0.07407462441739801
# Final cost : 0.07407291772381294
# Compute control for a deterministic system
# Cost in iteration 0: 0.07407291772381294
# Final cost : 0.0740714851507907
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.440854452722834
# Final cost : 0.08367076394353998
# Compute control for a deterministic system
# Cost in iteration 0: 0.08367076394353998
# Final cost : 0.07742609994727602
# Compute control for a deterministic system
# Cost in iteration 0: 0.07742609994727602
# Final cost : 0.07740298393132418
# Compute control for a deterministic system
# Cost in iteration 0: 0.07740298393132418
# Final cost : 0.07739507264205482
# Compute control for a deterministic system
# Cost in iteration 0: 0.07739507264205482
# Final cost : 0.07739217823731312
# -----------------------------------------------
# 4 found better solution,  19
# Compute control for a deterministic system
# Cost in iteration 0: 0.6124608001525587
# Final cost : 0.08647299409717502
# Compute control for a deterministic system
# Cost in iteration 0: 0.08647299409717502
# Final cost : 0.0796048196107203
# Compute control for a deterministic system
# Cost in iteration 0: 0.0796048196107203
# Final cost : 0.07959026629287658
# Compute control for a deterministic system
# Cost in iteration 0: 0.07959026629287658
# Final cost : 0.07958020253305802
# Compute control for a deterministic system
# Cost in iteration 0: 0.07958020253305802
# Final cost : 0.079572114988447
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.7229205227929574
# Final cost : 0.0903760952989955
# Compute control for a deterministic system
# Cost in iteration 0: 0.0903760952989955
# Final cost : 0.08204988012658382
# Compute control for a deterministic system
# Cost in iteration 0: 0.08204988012658382
# Final cost : 0.08203710209090316
# Compute control for a deterministic system
# Cost in iteration 0: 0.08203710209090316
# Final cost : 0.0820291568633441
# Compute control for a deterministic system
# Cost in iteration 0: 0.0820291568633441
# Final cost : 0.08202202817411318
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.8963297677274076
# Final cost : 0.09186666327483498
# Compute control for a deterministic system
# Cost in iteration 0: 0.09186666327483498
# Final cost : 0.08403881530924551
# Compute control for a deterministic system
# Cost in iteration 0: 0.08403881530924551
# Final cost : 0.08401340400122903
# Compute control for a deterministic system
# Cost in iteration 0: 0.08401340400122903
# Final cost : 0.08400458353268403
# Compute control for a deterministic system
# Cost in iteration 0: 0.08400458353268403
# Final cost : 0.08399141600623738
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.9793420055633394
# Final cost : 0.0951033823478538
# Compute control for a deterministic system
# Cost in iteration 0: 0.0951033823478538
# Final cost : 0.08572482890585409
# Compute control for a deterministic system
# Cost in iteration 0: 0.08572482890585409
# Final cost : 0.08568648430225538
# Compute control for a deterministic system
# Cost in iteration 0: 0.08568648430225538
# Final cost : 0.08563977454541284
# Compute control for a deterministic system
# Cost in iteration 0: 0.08563977454541284
# Final cost : 0.08561218956500209
# -----------------------------------------------
# 4 found better solution,  23
# Compute control for a deterministic system
# Cost in iteration 0: 0.9537636209247988
# Final cost : 0.09769972694878132
# Compute control for a deterministic system
# Cost in iteration 0: 0.09769972694878132
# Final cost : 0.08748199212837511
# Compute control for a deterministic system
# Cost in iteration 0: 0.08748199212837511
# Final cost : 0.08715519566650108
# Compute control for a deterministic system
# Cost in iteration 0: 0.08715519566650108
# Final cost : 0.08711960788235454
# Compute control for a deterministic system
# Cost in iteration 0: 0.08711960788235454
# Final cost : 0.08706049804492923
# Compute control for a deterministic system
# Cost in iteration 0: 0.18537711545075808
# Final cost : 0.08912723147811885
# Compute control for a deterministic system
# Cost in iteration 0: 0.08912723147811885
# Final cost : 0.0878139885135797
# Compute control for a deterministic system
# Cost in iteration 0: 0.0878139885135797
# Final cost : 0.08780843448181223
# Compute control for a deterministic system
# Cost in iteration 0: 0.08780843448181223
# Final cost : 0.08780843174958543
# Compute control for a deterministic system
# Cost in iteration 0: 0.08780843174958543
# Converged in iteration 752 with cost 0.08780843172848632 because of step counter
# Final cost : 0.08780843172848632
# Compute control for a deterministic system
# Cost in iteration 0: 0.16925448904409177
# Final cost : 0.07986603689825875
# Compute control for a deterministic system
# Cost in iteration 0: 0.07986603689825875
# Final cost : 0.0787349277261437
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787349277261437
# Final cost : 0.0787301382659802
# Compute control for a deterministic system
# Cost in iteration 0: 0.0787301382659802
# Final cost : 0.07873013633382141
# Compute control for a deterministic system
# Cost in iteration 0: 0.07873013633382141
# Converged in iteration 679 with cost 0.07873013632327819 because of step counter
# Final cost : 0.07873013632327819
# -----------------------------------------------
# 4 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 0.14843931064100235
# Final cost : 0.06832811466378846
# Compute control for a deterministic system
# Cost in iteration 0: 0.06832811466378846
# Final cost : 0.06740841020480158
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740841020480158
# Final cost : 0.06740449042764864
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740449042764864
# Final cost : 0.06740448887540344
# Compute control for a deterministic system
# Cost in iteration 0: 0.06740448887540344
# Converged in iteration 507 with cost 0.06740448887070585 because of step counter
# Final cost : 0.06740448887070585
# Compute control for a deterministic system
# Cost in iteration 0: 0.12849090393457227
# Final cost : 0.057703495294231834
# Compute control for a deterministic system
# Cost in iteration 0: 0.057703495294231834
# Final cost : 0.056964047072142504
# Compute control for a deterministic system
# Cost in iteration 0: 0.056964047072142504
# Final cost : 0.05696085300700755
# Compute control for a deterministic system
# Cost in iteration 0: 0.05696085300700755
# Final cost : 0.056960851986125355
# Compute control for a deterministic system
# Cost in iteration 0: 0.056960851986125355
# Converged in iteration 288 with cost 0.056960851985421834 because of step counter
# Final cost : 0.056960851985421834
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.1384368472881164
# Final cost : 0.06044225509874576
# Compute control for a deterministic system
# Cost in iteration 0: 0.06044225509874576
# Final cost : 0.05602109733667133
# Compute control for a deterministic system
# Cost in iteration 0: 0.05602109733667133
# Final cost : 0.05331164029327579
# Compute control for a deterministic system
# Cost in iteration 0: 0.05331164029327579
# Final cost : 0.053310580634281096
# Compute control for a deterministic system
# Cost in iteration 0: 0.053310580634281096
# Converged in iteration 1707 with cost 0.053310556453238074 because of vanishing difference
# Final cost : 0.053310556453238074
# Compute control for a deterministic system
# Cost in iteration 0: 0.1801388225822398
# Final cost : 0.06645905143130168
# Compute control for a deterministic system
# Cost in iteration 0: 0.06645905143130168
# Final cost : 0.0614805442093491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0614805442093491
# Final cost : 0.058410038371725266
# Compute control for a deterministic system
# Cost in iteration 0: 0.058410038371725266
# Final cost : 0.058407532002195776
# Compute control for a deterministic system
# Cost in iteration 0: 0.058407532002195776
# Final cost : 0.05840746866714701
# Compute control for a deterministic system
# Cost in iteration 0: 0.2735999713477623
# Final cost : 0.07479145789443853
# Compute control for a deterministic system
# Cost in iteration 0: 0.07479145789443853
# Final cost : 0.06898065520755868
# Compute control for a deterministic system
# Cost in iteration 0: 0.06898065520755868
# Final cost : 0.06536251950715852
# Compute control for a deterministic system
# Cost in iteration 0: 0.06536251950715852
# Final cost : 0.06535891161975309
# Compute control for a deterministic system
# Cost in iteration 0: 0.06535891161975309
# Final cost : 0.06535878022889274
# Compute control for a deterministic system
# Cost in iteration 0: 3.5065390133665195
# Final cost : 0.0920088251879137
# Compute control for a deterministic system
# Cost in iteration 0: 0.0920088251879137
# Final cost : 0.0779026131733538
# Compute control for a deterministic system
# Cost in iteration 0: 0.0779026131733538
# Final cost : 0.07100086387352736
# Compute control for a deterministic system
# Cost in iteration 0: 0.07100086387352736
# Final cost : 0.0705390258389482
# ...
# Final cost : 1.3223771153136739
# Compute control for a deterministic system
# Cost in iteration 0: 1.3223771153136739
# Converged in iteration 136 with cost 1.3223764753586154 because of step counter
# Final cost : 1.3223764753586154
# Compute control for a deterministic system
# Cost in iteration 0: 1.3223764753586154
# Converged in iteration 11 with cost 1.3223764753585718 because of vanishing difference
# Final cost : 1.3223764753585718
# Compute control for a deterministic system
# Cost in iteration 0: 1.322376475358567
# Converged in iteration 1 with cost 1.322376475358567 because of step counter
# Final cost : 1.322376475358567
# Compute control for a deterministic system
# Cost in iteration 0: 1.2417558376633446
# Final cost : 1.1681252656895271
# Compute control for a deterministic system
# Cost in iteration 0: 1.1681252656895271
# Final cost : 1.1658045547208997
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658045547208997
# Converged in iteration 131 with cost 1.1658041575272968 because of vanishing difference
# Final cost : 1.1658041575272968
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658041575272948
# Converged in iteration 4 with cost 1.1658041575272775 because of step counter
# Final cost : 1.1658041575272775
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658041575272775
# Converged in iteration 1 with cost 1.1658041575272775 because of step counter
# Final cost : 1.1658041575272775
# Compute control for a deterministic system
# Cost in iteration 0: 1.082637846218642
# Final cost : 1.02061040694344
# Compute control for a deterministic system
# Cost in iteration 0: 1.02061040694344
# Final cost : 1.0185924916692182
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185924916692182
# Converged in iteration 116 with cost 1.018592253159655 because of vanishing difference
# Final cost : 1.018592253159655
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185922531596523
# Converged in iteration 3 with cost 1.0185922531596465 because of vanishing difference
# Final cost : 1.0185922531596465
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185922531596452
# Converged in iteration 3 with cost 1.0185922531596412 because of vanishing difference
# Final cost : 1.0185922531596412
# Compute control for a deterministic system
# Cost in iteration 0: 0.9704576428690875
# Final cost : 0.9161078441945625
# Compute control for a deterministic system
# Cost in iteration 0: 0.9161078441945625
# Final cost : 0.9143008683305929
# Compute control for a deterministic system
# Cost in iteration 0: 0.9143008683305929
# Converged in iteration 104 with cost 0.9143007074586758 because of step counter
# Final cost : 0.9143007074586758
# Compute control for a deterministic system
# Cost in iteration 0: 0.9143007074586758
# Converged in iteration 10 with cost 0.9143007074586502 because of vanishing difference
# Final cost : 0.9143007074586502
# Compute control for a deterministic system
# Cost in iteration 0: 0.9143007074586474
# Converged in iteration 1 with cost 0.9143007074586474 because of step counter
# Final cost : 0.9143007074586474
# Compute control for a deterministic system
# Cost in iteration 0: 0.8299139246098766
# Final cost : 0.7848230604566961
# Compute control for a deterministic system
# Cost in iteration 0: 0.7848230604566961
# Final cost : 0.7832669664959384
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832669664959384
# Converged in iteration 109 with cost 0.7832668697917229 because of step counter
# Final cost : 0.7832668697917229
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832668697917229
# Converged in iteration 1 with cost 0.7832668697917229 because of vanishing difference
# Final cost : 0.7832668697917229
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832668697917229
# Converged in iteration 2 with cost 0.7832668697917194 because of step counter
# Final cost : 0.7832668697917194
# Compute control for a deterministic system
# Cost in iteration 0: 0.699250550315256
# Final cost : 0.6624255375768513
# Compute control for a deterministic system
# Cost in iteration 0: 0.6624255375768513
# Final cost : 0.6610801097169074
# Compute control for a deterministic system
# Cost in iteration 0: 0.6610801097169074
# Converged in iteration 118 with cost 0.6610800511104096 because of step counter
# Final cost : 0.6610800511104096
# Compute control for a deterministic system
# Cost in iteration 0: 0.6610800511104096
# Converged in iteration 1 with cost 0.6610800511104096 because of step counter
# Final cost : 0.6610800511104096
# Compute control for a deterministic system
# Cost in iteration 0: 0.6610800511104096
# Converged in iteration 1 with cost 0.6610800511104096 because of step counter
# Final cost : 0.6610800511104096
# ----------------------------------------------- 5
# Compute control for a deterministic system
# Cost in iteration 0: 0.7958801955847181
# Final cost : 0.7012317707118869
# Compute control for a deterministic system
# Cost in iteration 0: 0.7012317707118869
# Final cost : 0.6841246011491606
# Compute control for a deterministic system
# Cost in iteration 0: 0.6841246011491606
# Converged in iteration 211 with cost 0.6841244845365694 because of vanishing difference
# Final cost : 0.6841244845365694
# Compute control for a deterministic system
# Cost in iteration 0: 0.6841244845365693
# Converged in iteration 2 with cost 0.6841244845365663 because of step counter
# Final cost : 0.6841244845365663
# Compute control for a deterministic system
# Cost in iteration 0: 0.6841244845365663
# Converged in iteration 1 with cost 0.6841244845365663 because of step counter
# Final cost : 0.6841244845365663
# Compute control for a deterministic system
# Cost in iteration 0: 0.8866346537290317
# Final cost : 0.7737505194497085
# Compute control for a deterministic system
# Cost in iteration 0: 0.7737505194497085
# Final cost : 0.7544501302648807
# Compute control for a deterministic system
# Cost in iteration 0: 0.7544501302648807
# Converged in iteration 239 with cost 0.7544499118660934 because of vanishing difference
# Final cost : 0.7544499118660934
# Compute control for a deterministic system
# Cost in iteration 0: 0.7544499118660891
# Converged in iteration 1 with cost 0.7544499118660891 because of step counter
# Final cost : 0.7544499118660891
# Compute control for a deterministic system
# Cost in iteration 0: 0.7544499118660891
# Converged in iteration 2 with cost 0.7544499118660876 because of step counter
# Final cost : 0.7544499118660876
# Compute control for a deterministic system
# Cost in iteration 0: 1.0189393046801425
# Final cost : 0.8748964083514305
# Compute control for a deterministic system
# Cost in iteration 0: 0.8748964083514305
# Final cost : 0.8523811785318491
# Compute control for a deterministic system
# Cost in iteration 0: 0.8523811785318491
# Converged in iteration 320 with cost 0.8523806913050394 because of step counter
# Final cost : 0.8523806913050394
# Compute control for a deterministic system
# Cost in iteration 0: 0.8523806913050394
# Converged in iteration 9 with cost 0.8523806913050131 because of vanishing difference
# Final cost : 0.8523806913050131
# Compute control for a deterministic system
# Cost in iteration 0: 0.8523806913050131
# Converged in iteration 1 with cost 0.8523806913050131 because of step counter
# Final cost : 0.8523806913050131
# Compute control for a deterministic system
# Cost in iteration 0: 1.1679634761343083
# Final cost : 0.9809292694048578
# Compute control for a deterministic system
# Cost in iteration 0: 0.9809292694048578
# Final cost : 0.9548236959503602
# Compute control for a deterministic system
# Cost in iteration 0: 0.9548236959503602
# Final cost : 0.9548226397656852
# Compute control for a deterministic system
# Cost in iteration 0: 0.9548226397656852
# Converged in iteration 49 with cost 0.9548226397650493 because of step counter
# Final cost : 0.9548226397650493
# Compute control for a deterministic system
# Cost in iteration 0: 0.9548226397650493
# Converged in iteration 1 with cost 0.9548226397650493 because of step counter
# Final cost : 0.9548226397650493
# Compute control for a deterministic system
# Cost in iteration 0: 1.3413233664666449
# Final cost : 1.0915739091466303
# Compute control for a deterministic system
# Cost in iteration 0: 1.0915739091466303
# Final cost : 1.0614382414580554
# Compute control for a deterministic system
# Cost in iteration 0: 1.0614382414580554
# Final cost : 1.0614359556386006
# Compute control for a deterministic system
# Cost in iteration 0: 1.0614359556386006
# Converged in iteration 107 with cost 1.0614359556193569 because of step counter
# Final cost : 1.0614359556193569
# Compute control for a deterministic system
# Cost in iteration 0: 1.0614359556193569
# Converged in iteration 2 with cost 1.061435955619356 because of vanishing difference
# Final cost : 1.061435955619356
# Compute control for a deterministic system
# Cost in iteration 0: 1.5547600625369942
# Final cost : 1.2064826049063502
# Compute control for a deterministic system
# Cost in iteration 0: 1.2064826049063502
# Final cost : 1.1717815063980173
# Compute control for a deterministic system
# Cost in iteration 0: 1.1717815063980173
# Final cost : 1.1717762741894968
# Compute control for a deterministic system
# Cost in iteration 0: 1.1717762741894968
# Converged in iteration 188 with cost 1.1717762741367816 because of step counter
# Final cost : 1.1717762741367816
# Compute control for a deterministic system
# Cost in iteration 0: 1.1717762741367816
# Converged in iteration 1 with cost 1.1717762741367816 because of step counter
# Final cost : 1.1717762741367816
# Compute control for a deterministic system
# Cost in iteration 0: 6.968013287577491
# Final cost : 1.3257466968899438
# Compute control for a deterministic system
# Cost in iteration 0: 1.3257466968899438
# Final cost : 1.237871555329124
# Compute control for a deterministic system
# Cost in iteration 0: 1.237871555329124
# Final cost : 1.2365507242364941
# Compute control for a deterministic system
# Cost in iteration 0: 1.2365507242364941
# Final cost : 1.2362116608447682
# Compute control for a deterministic system
# Cost in iteration 0: 1.2362116608447682
# Final cost : 1.23612295322358
# Compute control for a deterministic system
# Cost in iteration 0: 7.897861383133079
# Final cost : 1.3856950610427148
# Compute control for a deterministic system
# Cost in iteration 0: 1.3856950610427148
# Final cost : 1.2897346818517699
# Compute control for a deterministic system
# Cost in iteration 0: 1.2897346818517699
# Final cost : 1.2886341431099702
# Compute control for a deterministic system
# Cost in iteration 0: 1.2886341431099702
# Final cost : 1.2883193092874632
# Compute control for a deterministic system
# Cost in iteration 0: 1.2883193092874632
# Final cost : 1.2880987763066174
# Compute control for a deterministic system
# Cost in iteration 0: 8.444845399843564
# Final cost : 1.4341798780702306
# Compute control for a deterministic system
# Cost in iteration 0: 1.4341798780702306
# Final cost : 1.330713471744163
# Compute control for a deterministic system
# Cost in iteration 0: 1.330713471744163
# Final cost : 1.3293968017454423
# Compute control for a deterministic system
# Cost in iteration 0: 1.3293968017454423
# Final cost : 1.3291264778497887
# Compute control for a deterministic system
# Cost in iteration 0: 1.3291264778497887
# Final cost : 1.3288126390610093
# Compute control for a deterministic system
# Cost in iteration 0: 1.4179659678078116
# Final cost : 1.3410639680245877
# Compute control for a deterministic system
# Cost in iteration 0: 1.3410639680245877
# Final cost : 1.3223765008386092
# Compute control for a deterministic system
# Cost in iteration 0: 1.3223765008386092
# Converged in iteration 116 with cost 1.3223764753585534 because of step counter
# Final cost : 1.3223764753585534
# Compute control for a deterministic system
# Cost in iteration 0: 1.3223764753585534
# Converged in iteration 1 with cost 1.3223764753585534 because of step counter
# Final cost : 1.3223764753585534
# Compute control for a deterministic system
# Cost in iteration 0: 1.3223764753585534
# Converged in iteration 1 with cost 1.3223764753585534 because of step counter
# Final cost : 1.3223764753585534
# Compute control for a deterministic system
# Cost in iteration 0: 1.2505968888227175
# Final cost : 1.1824300205375904
# Compute control for a deterministic system
# Cost in iteration 0: 1.1824300205375904
# Final cost : 1.1658041744943624
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658041744943624
# Converged in iteration 92 with cost 1.1658041575273197 because of vanishing difference
# Final cost : 1.1658041575273197
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658041575273161
# Converged in iteration 5 with cost 1.1658041575272775 because of step counter
# Final cost : 1.1658041575272775
# Compute control for a deterministic system
# Cost in iteration 0: 1.1658041575272775
# Converged in iteration 1 with cost 1.1658041575272775 because of step counter
# Final cost : 1.1658041575272775
# Compute control for a deterministic system
# Cost in iteration 0: 1.0931561762662554
# Final cost : 1.033254277087512
# Compute control for a deterministic system
# Cost in iteration 0: 1.033254277087512
# Final cost : 1.0185922642432563
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185922642432563
# Converged in iteration 102 with cost 1.0185922531596487 because of step counter
# Final cost : 1.0185922531596487
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185922531596487
# Converged in iteration 1 with cost 1.0185922531596487 because of step counter
# Final cost : 1.0185922531596487
# Compute control for a deterministic system
# Cost in iteration 0: 1.0185922531596487
# Converged in iteration 1 with cost 1.0185922531596487 because of step counter
# Final cost : 1.0185922531596487
# Compute control for a deterministic system
# Cost in iteration 0: 0.9815569498930957
# Final cost : 0.9275535334631174
# Compute control for a deterministic system
# Cost in iteration 0: 0.9275535334631174
# Final cost : 0.9143007155040482
# Compute control for a deterministic system
# Cost in iteration 0: 0.9143007155040482
# Converged in iteration 87 with cost 0.9143007074586718 because of step counter
# Final cost : 0.9143007074586718
# Compute control for a deterministic system
# Cost in iteration 0: 0.9143007074586718
# Converged in iteration 2 with cost 0.914300707458671 because of step counter
# Final cost : 0.914300707458671
# Compute control for a deterministic system
# Cost in iteration 0: 0.914300707458671
# Converged in iteration 2 with cost 0.9143007074586708 because of step counter
# Final cost : 0.9143007074586708
# Compute control for a deterministic system
# Cost in iteration 0: 0.8412442955858526
# Final cost : 0.7947229423656035
# Compute control for a deterministic system
# Cost in iteration 0: 0.7947229423656035
# Final cost : 0.7832668751261056
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832668751261056
# Converged in iteration 89 with cost 0.7832668697917071 because of step counter
# Final cost : 0.7832668697917071
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832668697917071
# Converged in iteration 1 with cost 0.7832668697917071 because of step counter
# Final cost : 0.7832668697917071
# Compute control for a deterministic system
# Cost in iteration 0: 0.7832668697917071
# Converged in iteration 3 with cost 0.7832668697917057 because of step counter
# Final cost : 0.7832668697917057
# Compute control for a deterministic system
# Cost in iteration 0: 0.7103001352036066
# Final cost : 0.6708318322570054
# Compute control for a deterministic system
# Cost in iteration 0: 0.6708318322570054
# Final cost : 0.6610800546214486
# Compute control for a deterministic system
# Cost in iteration 0: 0.6610800546214486
# Converged in iteration 77 with cost 0.661080051110428 because of step counter
# Final cost : 0.661080051110428
# Compute control for a deterministic system
# Cost in iteration 0: 0.661080051110428
# Converged in iteration 1 with cost 0.661080051110428 because of step counter
# Final cost : 0.661080051110428
# Compute control for a deterministic system
# Cost in iteration 0: 0.661080051110428
# Converged in iteration 1 with cost 0.661080051110428 because of step counter
# Final cost : 0.661080051110428

# %%
save(results_peak)
