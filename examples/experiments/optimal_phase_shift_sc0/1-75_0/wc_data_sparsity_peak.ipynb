# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt
print("period =", period)

wc.run()
init_peak = [wc.exc[0,57], wc.inh[0,57]]

wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
wc.run()
target_peak = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
print("peaks = ", peaks)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# period = 15.293750000000001
# peaks =  [  94  247  400  553  706  858 1011 1164 1317 1470 1623 1776 1929 2082
#  2235 2388 2541 2694 2847]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=np.arange(0,2001,200), precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_peak_w1.png", "1_peak_w1.png", "4_peak_w1.png"]

results_peak = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_peak_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_peak_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_peak = read()
results_min = readfile("results_min_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_peak[0]]])
wc.params["inh_init"] = np.array([[init_peak[1]]])
#results_min = readfile("results_min_w1.pickle")

ind_list = range(41)
#options = [True, True, True, True, True, True, True, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_peak["w1"])):

        w1 = results_peak['w1'][i_w]

        for i_shift in range(n_points):

            if type(results_peak["control"][i_w][i_shift]) != type(None):
                continue
        
            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)

            wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_peak["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(100)

            if i_shift in [0, n_points-1]:
                get_values(results_peak, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_peak, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                factor = 1.05
                if i_shift > n_points/2:
                    factor = 1.
                
                wc_controlled.control = results_peak["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                factor = 1.01
                if i_shift < n_points/2:
                    factor = 0.99
                
                wc_controlled.control = results_peak["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                            
                wc_controlled.control = results_peak["control"][i_w-1][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)

                if i_w != len(results_peak["w1"]) - 1:
                    wc_controlled.control = results_peak["control"][i_w+1][i_shift].copy() * 1.01
                else:
                    wc_controlled.control = results_peak["control"][0][i_shift].copy() * 1.01
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,0,int0+np.around(1.5*period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                wc_controlled.control = results_peak["control"][i_w][i_shift].copy() * 1.1
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_peak["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_peak)
                wc_controlled = getmodel(target_shift, w1, results_peak, i_w, i_shift)
                
                control0 = np.zeros((results_peak["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-99] = results_min["control"][i_w][i_shift].copy()[:,:,99:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_peak["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_peak, i_w, i_shift, w1)
                
        save(results_peak)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06383238349245347
# Final cost : 0.05606482127518366
# Compute control for a deterministic system
# Cost in iteration 0: 0.05606482127518366
# Final cost : 0.013240608139228657
# Compute control for a deterministic system
# Cost in iteration 0: 0.013240608139228657
# Cost in iteration 200: 0.012585385478533585
# Final cost : 0.012585385478533585
# Compute control for a deterministic system
# Cost in iteration 0: 0.012585385478533585
# Converged in iteration 18 with cost 0.01258535335425644 because of vanishing difference
# Final cost : 0.01258535335425644
# Compute control for a deterministic system
# Cost in iteration 0: 0.012585353353880308
# Converged in iteration 2 with cost 0.012585353351868592 because of step counter
# Final cost : 0.012585353351868592
# Compute control for a deterministic system
# Cost in iteration 0: 0.012585353351868592
# Converged in iteration 1 with cost 0.012585353351868592 because of step counter
# Final cost : 0.012585353351868592
# Compute control for a deterministic system
# Cost in iteration 0: 0.2508644665887645
# Final cost : 0.22000195229603686
# Compute control for a deterministic system
# Cost in iteration 0: 0.22000195229603686
# Final cost : 0.029741827429037165
# Compute control for a deterministic system
# Cost in iteration 0: 0.029741827429037165
# Converged in iteration 49 with cost 0.028187503202960096 because of step counter
# Final cost : 0.028187503202960096
# Compute control for a deterministic system
# Cost in iteration 0: 0.028187503202960096
# Converged in iteration 1 with cost 0.028187503202960096 because of step counter
# Final cost : 0.028187503202960096
# Compute control for a deterministic system
# Cost in iteration 0: 0.028187503202960096
# Converged in iteration 1 with cost 0.028187503202960096 because of step counter
# Final cost : 0.028187503202960096
# Compute control for a deterministic system
# Cost in iteration 0: 0.028187503202960096
# Converged in iteration 1 with cost 0.028187503202960096 because of step counter
# Final cost : 0.028187503202960096
# Compute control for a deterministic system
# Cost in iteration 0: 0.46516133965151285
# Final cost : 0.4099724716855859
# Compute control for a deterministic system
# Cost in iteration 0: 0.4099724716855859
# Final cost : 0.04364578490070486
# Compute control for a deterministic system
# Cost in iteration 0: 0.04364578490070486
# Converged in iteration 82 with cost 0.04050420267763066 because of step counter
# Final cost : 0.04050420267763066
# Compute control for a deterministic system
# Cost in iteration 0: 0.04050420267763066
# Converged in iteration 1 with cost 0.04050420267763066 because of step counter
# Final cost : 0.04050420267763066
# Compute control for a deterministic system
# Cost in iteration 0: 0.04050420267763066
# Converged in iteration 1 with cost 0.04050420267763066 because of step counter
# Final cost : 0.04050420267763066
# Compute control for a deterministic system
# Cost in iteration 0: 0.04050420267763066
# Converged in iteration 1 with cost 0.04050420267763066 because of step counter
# Final cost : 0.04050420267763066
# Compute control for a deterministic system
# Cost in iteration 0: 0.8373344438438877
# Final cost : 0.7450518389546226
# Compute control for a deterministic system
# Cost in iteration 0: 0.7450518389546226
# Final cost : 0.06390753892740249
# Compute control for a deterministic system
# Cost in iteration 0: 0.06390753892740249
# Converged in iteration 165 with cost 0.057305425934070175 because of step counter
# Final cost : 0.057305425934070175
# Compute control for a deterministic system
# Cost in iteration 0: 0.057305425934070175
# Converged in iteration 1 with cost 0.057305425934070175 because of step counter
# Final cost : 0.057305425934070175
# Compute control for a deterministic system
# Cost in iteration 0: 0.057305425934070175
# Converged in iteration 1 with cost 0.057305425934070175 because of step counter
# Final cost : 0.057305425934070175
# Compute control for a deterministic system
# Cost in iteration 0: 0.057305425934070175
# Converged in iteration 1 with cost 0.057305425934070175 because of step counter
# Final cost : 0.057305425934070175
# Compute control for a deterministic system
# Cost in iteration 0: 1.292863241891248
# Final cost : 1.162910710257422
# Compute control for a deterministic system
# Cost in iteration 0: 1.162910710257422
# Final cost : 0.08653994394865626
# Compute control for a deterministic system
# Cost in iteration 0: 0.08653994394865626
# Cost in iteration 200: 0.07447753089953092
# Final cost : 0.07447753089953092
# Compute control for a deterministic system
# Cost in iteration 0: 0.07447753089953092
# Converged in iteration 14 with cost 0.07443030429499324 because of step counter
# Final cost : 0.07443030429499324
# Compute control for a deterministic system
# Cost in iteration 0: 0.07443030429499324
# Converged in iteration 1 with cost 0.07443030429499324 because of step counter
# Final cost : 0.07443030429499324
# Compute control for a deterministic system
# Cost in iteration 0: 0.07443030429499324
# Converged in iteration 1 with cost 0.07443030429499324 because of step counter
# Final cost : 0.07443030429499324
# Compute control for a deterministic system
# Cost in iteration 0: 1.8145889797659915
# Final cost : 1.6504596819892725
# Compute control for a deterministic system
# Cost in iteration 0: 1.6504596819892725
# Final cost : 0.11180216770384097
# Compute control for a deterministic system
# Cost in iteration 0: 0.11180216770384097
# Cost in iteration 200: 0.09117792798609459
# Final cost : 0.09117792798609459
# Compute control for a deterministic system
# Cost in iteration 0: 0.09117792798609459
# Converged in iteration 199 with cost 0.09063370655490548 because of vanishing difference
# Final cost : 0.09063370655490548
# Compute control for a deterministic system
# Cost in iteration 0: 0.09063370655466708
# Converged in iteration 3 with cost 0.09063370655221475 because of vanishing difference
# Final cost : 0.09063370655221475
# Compute control for a deterministic system
# Cost in iteration 0: 0.09063370655217882
# Converged in iteration 1 with cost 0.09063370655217882 because of vanishing difference
# Final cost : 0.09063370655217882
# Compute control for a deterministic system
# Cost in iteration 0: 2.3856106899367897
# Final cost : 2.1937166692987264
# Compute control for a deterministic system
# Cost in iteration 0: 2.1937166692987264
# Final cost : 0.14005801755929653
# Compute control for a deterministic system
# Cost in iteration 0: 0.14005801755929653
# Cost in iteration 200: 0.10363610031964403
# Final cost : 0.10363610031964403
# Compute control for a deterministic system
# Cost in iteration 0: 0.10363610031964403
# Converged in iteration 122 with cost 0.10096276401048869 because of vanishing difference
# Final cost : 0.10096276401048869
# Compute control for a deterministic system
# Cost in iteration 0: 0.10096276401029457
# Converged in iteration 2 with cost 0.10096276400866694 because of vanishing difference
# Final cost : 0.10096276400866694
# Compute control for a deterministic system
# Cost in iteration 0: 0.10096276400866694
# Converged in iteration 1 with cost 0.10096276400866694 because of step counter
# Final cost : 0.10096276400866694
# Compute control for a deterministic system
# Cost in iteration 0: 2.989742888917694
# Final cost : 2.778469812063494
# Compute control for a deterministic system
# Cost in iteration 0: 2.778469812063494
# Final cost : 0.17205332157412873
# Compute control for a deterministic system
# Cost in iteration 0: 0.17205332157412873
# Cost in iteration 200: 0.12232649129047964
# Final cost : 0.12232649129047964
# Compute control for a deterministic system
# Cost in iteration 0: 0.12232649129047964
# Converged in iteration 85 with cost 0.1128712124075578 because of vanishing difference
# Final cost : 0.1128712124075578
# Compute control for a deterministic system
# Cost in iteration 0: 0.11287121240731345
# Converged in iteration 2 with cost 0.11287121240549547 because of vanishing difference
# Final cost : 0.11287121240549547
# Compute control for a deterministic system
# Cost in iteration 0: 0.11287121240549544
# Converged in iteration 1 with cost 0.11287121240549544 because of step counter
# Final cost : 0.11287121240549544
# Compute control for a deterministic system
# Cost in iteration 0: 3.455422671390094
# Final cost : 3.235889063594402
# Compute control for a deterministic system
# Cost in iteration 0: 3.235889063594402
# Final cost : 0.1993317666901635
# Compute control for a deterministic system
# Cost in iteration 0: 0.1993317666901635
# Cost in iteration 200: 0.1378264749986656
# Final cost : 0.1378264749986656
# Compute control for a deterministic system
# Cost in iteration 0: 0.1378264749986656
# Converged in iteration 106 with cost 0.12554817437899563 because of vanishing difference
# Final cost : 0.12554817437899563
# Compute control for a deterministic system
# Cost in iteration 0: 0.1255481743787598
# Converged in iteration 2 with cost 0.1255481743768927 because of vanishing difference
# Final cost : 0.1255481743768927
# Compute control for a deterministic system
# Cost in iteration 0: 0.1255481743768927
# Converged in iteration 1 with cost 0.1255481743768927 because of step counter
# Final cost : 0.1255481743768927
# Compute control for a deterministic system
# Cost in iteration 0: 4.081826609646816
# Final cost : 3.8602339259912126
# Compute control for a deterministic system
# Cost in iteration 0: 3.8602339259912126
# Final cost : 0.24179753959020006
# Compute control for a deterministic system
# Cost in iteration 0: 0.24179753959020006
# Cost in iteration 200: 0.15933638928758045
# Final cost : 0.15933638928758045
# Compute control for a deterministic system
# Cost in iteration 0: 0.15933638928758045
# Converged in iteration 139 with cost 0.14296169258758432 because of vanishing difference
# Final cost : 0.14296169258758432
# Compute control for a deterministic system
# Cost in iteration 0: 0.14296169258737587
# Converged in iteration 2 with cost 0.14296169258563365 because of vanishing difference
# Final cost : 0.14296169258563365
# Compute control for a deterministic system
# Cost in iteration 0: 0.14296169258563365
# Converged in iteration 1 with cost 0.14296169258563365 because of step counter
# Final cost : 0.14296169258563365
# Compute control for a deterministic system
# Cost in iteration 0: 4.702350839477034
# Final cost : 4.489142003549133
# Compute control for a deterministic system
# Cost in iteration 0: 4.489142003549133
# Final cost : 0.293927449099076
# Compute control for a deterministic system
# Cost in iteration 0: 0.293927449099076
# Cost in iteration 200: 0.181865472758118
# Final cost : 0.181865472758118
# Compute control for a deterministic system
# Cost in iteration 0: 0.181865472758118
# Cost in iteration 200: 0.15936100037583592
# Final cost : 0.15936100037583592
# Compute control for a deterministic system
# Cost in iteration 0: 0.15936100037583592
# Converged in iteration 14 with cost 0.15683173100823952 because of step counter
# Final cost : 0.15683173100823952
# Compute control for a deterministic system
# Cost in iteration 0: 0.15683173100823952
# Converged in iteration 1 with cost 0.15683173100823952 because of step counter
# Final cost : 0.15683173100823952
# Compute control for a deterministic system
# Cost in iteration 0: 5.303522488408817
# Final cost : 5.108685860950178
# Compute control for a deterministic system
# Cost in iteration 0: 5.108685860950178
# Final cost : 0.3597836023510421
# Compute control for a deterministic system
# Cost in iteration 0: 0.3597836023510421
# Cost in iteration 200: 0.20550962709203122
# Final cost : 0.20550962709203122
# Compute control for a deterministic system
# Cost in iteration 0: 0.20550962709203122
# Cost in iteration 200: 0.17473620656975417
# Final cost : 0.17473620656975417
# Compute control for a deterministic system
# Cost in iteration 0: 0.17473620656975417
# Converged in iteration 36 with cost 0.17008873792385054 because of step counter
# Final cost : 0.17008873792385054
# Compute control for a deterministic system
# Cost in iteration 0: 0.17008873792385054
# Converged in iteration 1 with cost 0.17008873792385054 because of step counter
# Final cost : 0.17008873792385054
# Compute control for a deterministic system
# Cost in iteration 0: 5.871266568600853
# Final cost : 5.703340457704724
# Compute control for a deterministic system
# Cost in iteration 0: 5.703340457704724
# Final cost : 0.4452593609782764
# Compute control for a deterministic system
# Cost in iteration 0: 0.4452593609782764
# Cost in iteration 200: 0.23038629873042313
# Final cost : 0.23038629873042313
# Compute control for a deterministic system
# Cost in iteration 0: 0.23038629873042313
# Cost in iteration 200: 0.18603645474608407
# Final cost : 0.18603645474608407
# Compute control for a deterministic system
# Cost in iteration 0: 0.18603645474608407
# Converged in iteration 35 with cost 0.18508576445024635 because of step counter
# Final cost : 0.18508576445024635
# Compute control for a deterministic system
# Cost in iteration 0: 0.18508576445024635
# Converged in iteration 1 with cost 0.18508576445024635 because of step counter
# Final cost : 0.18508576445024635
# Compute control for a deterministic system
# Cost in iteration 0: 6.391280668593294
# Final cost : 6.2562167322987206
# Compute control for a deterministic system
# Cost in iteration 0: 6.2562167322987206
# Final cost : 0.558827559496507
# Compute control for a deterministic system
# Cost in iteration 0: 0.558827559496507
# Cost in iteration 200: 0.25661768419165537
# Final cost : 0.25661768419165537
# Compute control for a deterministic system
# Cost in iteration 0: 0.25661768419165537
# Converged in iteration 92 with cost 0.19860589593019853 because of step counter
# Final cost : 0.19860589593019853
# Compute control for a deterministic system
# Cost in iteration 0: 0.19860589593019853
# Converged in iteration 1 with cost 0.19860589593019853 because of step counter
# Final cost : 0.19860589593019853
# Compute control for a deterministic system
# Cost in iteration 0: 0.19860589593019853
# Converged in iteration 1 with cost 0.19860589593019853 because of step counter
# Final cost : 0.19860589593019853
# Compute control for a deterministic system
# Cost in iteration 0: 6.741833135873174
# Final cost : 6.633190368018981
# Compute control for a deterministic system
# Cost in iteration 0: 6.633190368018981
# Final cost : 0.6695865558791687
# Compute control for a deterministic system
# Cost in iteration 0: 0.6695865558791687
# Cost in iteration 200: 0.2772552272976893
# Final cost : 0.2772552272976893
# Compute control for a deterministic system
# Cost in iteration 0: 0.2772552272976893
# Converged in iteration 132 with cost 0.19966439047575057 because of step counter
# Final cost : 0.19966439047575057
# Compute control for a deterministic system
# Cost in iteration 0: 0.19966439047575057
# Converged in iteration 1 with cost 0.19966439047575057 because of step counter
# Final cost : 0.19966439047575057
# Compute control for a deterministic system
# Cost in iteration 0: 0.19966439047575057
# Converged in iteration 1 with cost 0.19966439047575057 because of step counter
# Final cost : 0.19966439047575057
# Compute control for a deterministic system
# Cost in iteration 0: 7.147323267524825
# Final cost : 7.073090454186783
# Compute control for a deterministic system
# Cost in iteration 0: 7.073090454186783
# Final cost : 0.8652766607400632
# Compute control for a deterministic system
# Cost in iteration 0: 0.8652766607400632
# Cost in iteration 200: 0.3061726866335172
# Final cost : 0.3061726866335172
# Compute control for a deterministic system
# Cost in iteration 0: 0.3061726866335172
# Converged in iteration 157 with cost 0.21259431821862956 because of step counter
# Final cost : 0.21259431821862956
# Compute control for a deterministic system
# Cost in iteration 0: 0.21259431821862956
# Converged in iteration 1 with cost 0.21259431821862956 because of step counter
# Final cost : 0.21259431821862956
# Compute control for a deterministic system
# Cost in iteration 0: 0.21259431821862956
# Converged in iteration 1 with cost 0.21259431821862956 because of step counter
# Final cost : 0.21259431821862956
# Compute control for a deterministic system
# Cost in iteration 0: 7.473843759693352
# Final cost : 7.429799214443279
# Compute control for a deterministic system
# Cost in iteration 0: 7.429799214443279
# Final cost : 1.1413164638191884
# Compute control for a deterministic system
# Cost in iteration 0: 1.1413164638191884
# Cost in iteration 200: 0.33688291682124866
# Final cost : 0.33688291682124866
# Compute control for a deterministic system
# Cost in iteration 0: 0.33688291682124866
# Converged in iteration 187 with cost 0.22441060255558296 because of step counter
# Final cost : 0.22441060255558296
# Compute control for a deterministic system
# Cost in iteration 0: 0.22441060255558296
# Converged in iteration 1 with cost 0.22441060255558296 because of step counter
# Final cost : 0.22441060255558296
# Compute control for a deterministic system
# Cost in iteration 0: 0.22441060255558296
# Converged in iteration 1 with cost 0.22441060255558296 because of step counter
# Final cost : 0.22441060255558296
# Compute control for a deterministic system
# Cost in iteration 0: 7.715055283049967
# Final cost : 7.69434397718021
# Compute control for a deterministic system
# Cost in iteration 0: 7.69434397718021
# Final cost : 1.5513273200000819
# Compute control for a deterministic system
# Cost in iteration 0: 1.5513273200000819
# Cost in iteration 200: 0.36975778629981326
# Final cost : 0.36975778629981326
# Compute control for a deterministic system
# Cost in iteration 0: 0.36975778629981326
# Cost in iteration 200: 0.23773592865514637
# Final cost : 0.23773592865514637
# Compute control for a deterministic system
# Cost in iteration 0: 0.23773592865514637
# Converged in iteration 3 with cost 0.23773591245529968 because of step counter
# Final cost : 0.23773591245529968
# Compute control for a deterministic system
# Cost in iteration 0: 0.23773591245529968
# Converged in iteration 1 with cost 0.23773591245529968 because of step counter
# Final cost : 0.23773591245529968
# Compute control for a deterministic system
# Cost in iteration 0: 7.866808314825294
# Final cost : 7.860993455633491
# Compute control for a deterministic system
# Cost in iteration 0: 7.860993455633491
# Final cost : 2.2529162178688895
# Compute control for a deterministic system
# Cost in iteration 0: 2.2529162178688895
# Cost in iteration 200: 0.4056155638384704
# Final cost : 0.4056155638384704
# Compute control for a deterministic system
# Cost in iteration 0: 0.4056155638384704
# Cost in iteration 200: 0.2517193663380004
# Final cost : 0.2517193663380004
# Compute control for a deterministic system
# Cost in iteration 0: 0.2517193663380004
# Converged in iteration 27 with cost 0.24846094107160718 because of step counter
# Final cost : 0.24846094107160718
# Compute control for a deterministic system
# Cost in iteration 0: 0.24846094107160718
# Converged in iteration 1 with cost 0.24846094107160718 because of step counter
# Final cost : 0.24846094107160718
# Compute control for a deterministic system
# Cost in iteration 0: 7.920241450906928
# Final cost : 7.919550520483817
# Compute control for a deterministic system
# Cost in iteration 0: 7.919550520483817
# Final cost : 3.5508015056648587
# Compute control for a deterministic system
# Cost in iteration 0: 3.5508015056648587
# Cost in iteration 200: 0.43620236459975475
# Final cost : 0.43620236459975475
# Compute control for a deterministic system
# Cost in iteration 0: 0.43620236459975475
# Cost in iteration 200: 0.2657414957375273
# Final cost : 0.2657414957375273
# Compute control for a deterministic system
# Cost in iteration 0: 0.2657414957375273
# Converged in iteration 20 with cost 0.25866052665290784 because of step counter
# Final cost : 0.25866052665290784
# Compute control for a deterministic system
# Cost in iteration 0: 0.25866052665290784
# Converged in iteration 1 with cost 0.25866052665290784 because of step counter
# Final cost : 0.25866052665290784
# Compute control for a deterministic system
# Cost in iteration 0: 7.9094321574687045
# Final cost : 7.907886681660643
# Compute control for a deterministic system
# Cost in iteration 0: 7.907886681660643
# Final cost : 3.3056113110110203
# Compute control for a deterministic system
# Cost in iteration 0: 3.3056113110110203
# Cost in iteration 200: 0.4792617994973174
# Final cost : 0.4792617994973174
# Compute control for a deterministic system
# Cost in iteration 0: 0.4792617994973174
# Cost in iteration 200: 0.3022810482952033
# Final cost : 0.3022810482952033
# Compute control for a deterministic system
# Cost in iteration 0: 0.3022810482952033
# Converged in iteration 17 with cost 0.2975303472584542 because of step counter
# Final cost : 0.2975303472584542
# Compute control for a deterministic system
# Cost in iteration 0: 0.2975303472584542
# Converged in iteration 1 with cost 0.2975303472584542 because of step counter
# Final cost : 0.2975303472584542
# Compute control for a deterministic system
# Cost in iteration 0: 7.803679788652346
# Final cost : 7.79206577174871
# Compute control for a deterministic system
# Cost in iteration 0: 7.79206577174871
# Final cost : 2.2194284106775446
# Compute control for a deterministic system
# Cost in iteration 0: 2.2194284106775446
# Cost in iteration 200: 0.434515028244798
# Final cost : 0.434515028244798
# Compute control for a deterministic system
# Cost in iteration 0: 0.434515028244798
# Cost in iteration 200: 0.28132907774569926
# Final cost : 0.28132907774569926
# Compute control for a deterministic system
# Cost in iteration 0: 0.28132907774569926
# Converged in iteration 16 with cost 0.27769440012429714 because of step counter
# Final cost : 0.27769440012429714
# Compute control for a deterministic system
# Cost in iteration 0: 0.27769440012429714
# Converged in iteration 1 with cost 0.27769440012429714 because of step counter
# Final cost : 0.27769440012429714
# Compute control for a deterministic system
# Cost in iteration 0: 7.602505215070927
# Final cost : 7.571403297777723
# Compute control for a deterministic system
# Cost in iteration 0: 7.571403297777723
# Final cost : 1.6563140132843195
# Compute control for a deterministic system
# Cost in iteration 0: 1.6563140132843195
# Cost in iteration 200: 0.39442051191530714
# Final cost : 0.39442051191530714
# Compute control for a deterministic system
# Cost in iteration 0: 0.39442051191530714
# Converged in iteration 174 with cost 0.26717459053257514 because of step counter
# Final cost : 0.26717459053257514
# Compute control for a deterministic system
# Cost in iteration 0: 0.26717459053257514
# Converged in iteration 1 with cost 0.26717459053257514 because of step counter
# Final cost : 0.26717459053257514
# Compute control for a deterministic system
# Cost in iteration 0: 0.26717459053257514
# Converged in iteration 1 with cost 0.26717459053257514 because of step counter
# Final cost : 0.26717459053257514
# Compute control for a deterministic system
# Cost in iteration 0: 7.306902880360733
# Final cost : 7.248076418682446
# Compute control for a deterministic system
# Cost in iteration 0: 7.248076418682446
# Final cost : 1.2727893410603301
# Compute control for a deterministic system
# Cost in iteration 0: 1.2727893410603301
# Cost in iteration 200: 0.3574751755008853
# Final cost : 0.3574751755008853
# Compute control for a deterministic system
# Cost in iteration 0: 0.3574751755008853
# Converged in iteration 162 with cost 0.24821627050578363 because of step counter
# Final cost : 0.24821627050578363
# Compute control for a deterministic system
# Cost in iteration 0: 0.24821627050578363
# Converged in iteration 1 with cost 0.24821627050578363 because of step counter
# Final cost : 0.24821627050578363
# Compute control for a deterministic system
# Cost in iteration 0: 0.24821627050578363
# Converged in iteration 1 with cost 0.24821627050578363 because of step counter
# Final cost : 0.24821627050578363
# Compute control for a deterministic system
# Cost in iteration 0: 6.920564404206482
# Final cost : 6.828245925360775
# Compute control for a deterministic system
# Cost in iteration 0: 6.828245925360775
# Final cost : 0.9915946227817359
# Compute control for a deterministic system
# Cost in iteration 0: 0.9915946227817359
# Cost in iteration 200: 0.32292963752283066
# Final cost : 0.32292963752283066
# Compute control for a deterministic system
# Cost in iteration 0: 0.32292963752283066
# Converged in iteration 137 with cost 0.23325377837102387 because of step counter
# Final cost : 0.23325377837102387
# Compute control for a deterministic system
# Cost in iteration 0: 0.23325377837102387
# Converged in iteration 1 with cost 0.23325377837102387 because of step counter
# Final cost : 0.23325377837102387
# Compute control for a deterministic system
# Cost in iteration 0: 0.23325377837102387
# Converged in iteration 1 with cost 0.23325377837102387 because of step counter
# Final cost : 0.23325377837102387
# Compute control for a deterministic system
# Cost in iteration 0: 6.57565563090093
# Final cost : 6.456656464566872
# Compute control for a deterministic system
# Cost in iteration 0: 6.456656464566872
# Final cost : 0.8268519678100799
# Compute control for a deterministic system
# Cost in iteration 0: 0.8268519678100799
# Cost in iteration 200: 0.29831527219029286
# Final cost : 0.29831527219029286
# Compute control for a deterministic system
# Cost in iteration 0: 0.29831527219029286
# Converged in iteration 130 with cost 0.21950405703947024 because of step counter
# Final cost : 0.21950405703947024
# Compute control for a deterministic system
# Cost in iteration 0: 0.21950405703947024
# Converged in iteration 1 with cost 0.21950405703947024 because of step counter
# Final cost : 0.21950405703947024
# Compute control for a deterministic system
# Cost in iteration 0: 0.21950405703947024
# Converged in iteration 1 with cost 0.21950405703947024 because of step counter
# Final cost : 0.21950405703947024
# Compute control for a deterministic system
# Cost in iteration 0: 6.0511472696181094
# Final cost : 5.897952157660519
# Compute control for a deterministic system
# Cost in iteration 0: 5.897952157660519
# Final cost : 0.6521361264981311
# Compute control for a deterministic system
# Cost in iteration 0: 0.6521361264981311
# Cost in iteration 200: 0.26699116191702754
# Final cost : 0.26699116191702754
# Compute control for a deterministic system
# Cost in iteration 0: 0.26699116191702754
# Converged in iteration 120 with cost 0.20453824759373923 because of vanishing difference
# Final cost : 0.20453824759373923
# Compute control for a deterministic system
# Cost in iteration 0: 0.20453824759373923
# Converged in iteration 9 with cost 0.20453824587036964 because of step counter
# Final cost : 0.20453824587036964
# Compute control for a deterministic system
# Cost in iteration 0: 0.20453824587036964
# Converged in iteration 1 with cost 0.20453824587036964 because of step counter
# Final cost : 0.20453824587036964
# Compute control for a deterministic system
# Cost in iteration 0: 5.465935248916306
# Final cost : 5.283770956609612
# Compute control for a deterministic system
# Cost in iteration 0: 5.283770956609612
# Final cost : 0.515841413131684
# Compute control for a deterministic system
# Cost in iteration 0: 0.515841413131684
# Cost in iteration 200: 0.23720562056731972
# Final cost : 0.23720562056731972
# Compute control for a deterministic system
# Cost in iteration 0: 0.23720562056731972
# Converged in iteration 127 with cost 0.18754298104065098 because of step counter
# Final cost : 0.18754298104065098
# Compute control for a deterministic system
# Cost in iteration 0: 0.18754298104065098
# Converged in iteration 1 with cost 0.18754298104065098 because of step counter
# Final cost : 0.18754298104065098
# Compute control for a deterministic system
# Cost in iteration 0: 0.18754298104065098
# Converged in iteration 1 with cost 0.18754298104065098 because of step counter
# Final cost : 0.18754298104065098
# Compute control for a deterministic system
# Cost in iteration 0: 4.836661641850295
# Final cost : 4.633751913944581
# Compute control for a deterministic system
# Cost in iteration 0: 4.633751913944581
# Final cost : 0.40770690886190425
# Compute control for a deterministic system
# Cost in iteration 0: 0.40770690886190425
# Cost in iteration 200: 0.20879556465391674
# Final cost : 0.20879556465391674
# Compute control for a deterministic system
# Cost in iteration 0: 0.20879556465391674
# Converged in iteration 45 with cost 0.1785817152122425 because of step counter
# Final cost : 0.1785817152122425
# Compute control for a deterministic system
# Cost in iteration 0: 0.1785817152122425
# Converged in iteration 1 with cost 0.1785817152122425 because of step counter
# Final cost : 0.1785817152122425
# Compute control for a deterministic system
# Cost in iteration 0: 0.1785817152122425
# Converged in iteration 1 with cost 0.1785817152122425 because of step counter
# Final cost : 0.1785817152122425
# Compute control for a deterministic system
# Cost in iteration 0: 4.181465547996508
# Final cost : 3.9678250316111483
# Compute control for a deterministic system
# Cost in iteration 0: 3.9678250316111483
# Final cost : 0.3205091072730808
# Compute control for a deterministic system
# Cost in iteration 0: 0.3205091072730808
# Cost in iteration 200: 0.18148147780620413
# Final cost : 0.18148147780620413
# Compute control for a deterministic system
# Cost in iteration 0: 0.18148147780620413
# Converged in iteration 51 with cost 0.15848669659062092 because of step counter
# Final cost : 0.15848669659062092
# Compute control for a deterministic system
# Cost in iteration 0: 0.15848669659062092
# Converged in iteration 1 with cost 0.15848669659062092 because of step counter
# Final cost : 0.15848669659062092
# Compute control for a deterministic system
# Cost in iteration 0: 0.15848669659062092
# Converged in iteration 1 with cost 0.15848669659062092 because of step counter
# Final cost : 0.15848669659062092
# Compute control for a deterministic system
# Cost in iteration 0: 3.5195741433284504
# Final cost : 3.305957922540955
# Compute control for a deterministic system
# Cost in iteration 0: 3.305957922540955
# Final cost : 0.24972959768203642
# Compute control for a deterministic system
# Cost in iteration 0: 0.24972959768203642
# Cost in iteration 200: 0.1547954079727414
# Final cost : 0.1547954079727414
# Compute control for a deterministic system
# Cost in iteration 0: 0.1547954079727414
# Converged in iteration 53 with cost 0.13842261854910032 because of step counter
# Final cost : 0.13842261854910032
# Compute control for a deterministic system
# Cost in iteration 0: 0.13842261854910032
# Converged in iteration 1 with cost 0.13842261854910032 because of step counter
# Final cost : 0.13842261854910032
# Compute control for a deterministic system
# Cost in iteration 0: 0.13842261854910032
# Converged in iteration 1 with cost 0.13842261854910032 because of step counter
# Final cost : 0.13842261854910032
# Compute control for a deterministic system
# Cost in iteration 0: 3.030709486955123
# Final cost : 2.8241271290963077
# Compute control for a deterministic system
# Cost in iteration 0: 2.8241271290963077
# Final cost : 0.2059662415573433
# Compute control for a deterministic system
# Cost in iteration 0: 0.2059662415573433
# Cost in iteration 200: 0.13513304293783027
# Final cost : 0.13513304293783027
# Compute control for a deterministic system
# Cost in iteration 0: 0.13513304293783027
# Converged in iteration 41 with cost 0.12313126406707255 because of step counter
# Final cost : 0.12313126406707255
# Compute control for a deterministic system
# Cost in iteration 0: 0.12313126406707255
# Converged in iteration 1 with cost 0.12313126406707255 because of step counter
# Final cost : 0.12313126406707255
# Compute control for a deterministic system
# Cost in iteration 0: 0.12313126406707255
# Converged in iteration 1 with cost 0.12313126406707255 because of step counter
# Final cost : 0.12313126406707255
# Compute control for a deterministic system
# Cost in iteration 0: 2.403818617021368
# Final cost : 2.2153523211662516
# Compute control for a deterministic system
# Cost in iteration 0: 2.2153523211662516
# Final cost : 0.15853141520828679
# Compute control for a deterministic system
# Cost in iteration 0: 0.15853141520828679
# Cost in iteration 200: 0.11089317604914078
# Final cost : 0.11089317604914078
# Compute control for a deterministic system
# Cost in iteration 0: 0.11089317604914078
# Cost in iteration 200: 0.10379015440742259
# Final cost : 0.10379015440742259
# Compute control for a deterministic system
# Cost in iteration 0: 0.10379015440742259
# Converged in iteration 12 with cost 0.10378953362984654 because of step counter
# Final cost : 0.10378953362984654
# Compute control for a deterministic system
# Cost in iteration 0: 0.10378953362984654
# Converged in iteration 1 with cost 0.10378953362984654 because of step counter
# Final cost : 0.10378953362984654
# Compute control for a deterministic system
# Cost in iteration 0: 1.8193838693354145
# Final cost : 1.6577446988312663
# Compute control for a deterministic system
# Cost in iteration 0: 1.6577446988312663
# Final cost : 0.12111022810143875
# Compute control for a deterministic system
# Cost in iteration 0: 0.12111022810143875
# Cost in iteration 200: 0.09327569339288393
# Final cost : 0.09327569339288393
# Compute control for a deterministic system
# Cost in iteration 0: 0.09327569339288393
# Converged in iteration 169 with cost 0.09199589583845853 because of vanishing difference
# Final cost : 0.09199589583845853
# Compute control for a deterministic system
# Cost in iteration 0: 0.09199589583813067
# Converged in iteration 2 with cost 0.09199589583521708 because of vanishing difference
# Final cost : 0.09199589583521708
# Compute control for a deterministic system
# Cost in iteration 0: 0.09199589583521708
# Converged in iteration 1 with cost 0.09199589583521708 because of step counter
# Final cost : 0.09199589583521708
# Compute control for a deterministic system
# Cost in iteration 0: 1.2910225299175855
# Final cost : 1.1628573793915178
# Compute control for a deterministic system
# Cost in iteration 0: 1.1628573793915178
# Final cost : 0.09085047459825515
# Compute control for a deterministic system
# Cost in iteration 0: 0.09085047459825515
# Cost in iteration 200: 0.07566569165289974
# Final cost : 0.07566569165289974
# Compute control for a deterministic system
# Cost in iteration 0: 0.07566569165289974
# Converged in iteration 178 with cost 0.07536554743157242 because of vanishing difference
# Final cost : 0.07536554743157242
# Compute control for a deterministic system
# Cost in iteration 0: 0.07536554743122428
# Converged in iteration 2 with cost 0.07536554742808646 because of vanishing difference
# Final cost : 0.07536554742808646
# Compute control for a deterministic system
# Cost in iteration 0: 0.07536554742796177
# Converged in iteration 1 with cost 0.07536554742796177 because of vanishing difference
# Final cost : 0.07536554742796177
# Compute control for a deterministic system
# Cost in iteration 0: 0.832981158559424
# Final cost : 0.7419542387769865
# Compute control for a deterministic system
# Cost in iteration 0: 0.7419542387769865
# Final cost : 0.06562956091304843
# Compute control for a deterministic system
# Cost in iteration 0: 0.06562956091304843
# Cost in iteration 200: 0.05778443617483821
# Final cost : 0.05778443617483821
# Compute control for a deterministic system
# Cost in iteration 0: 0.05778443617483821
# Converged in iteration 127 with cost 0.05775358364851695 because of vanishing difference
# Final cost : 0.05775358364851695
# Compute control for a deterministic system
# Cost in iteration 0: 0.05775358364814825
# Converged in iteration 2 with cost 0.05775358364487498 because of vanishing difference
# Final cost : 0.05775358364487498
# Compute control for a deterministic system
# Cost in iteration 0: 0.05775358364487498
# Converged in iteration 1 with cost 0.05775358364487498 because of step counter
# Final cost : 0.05775358364487498
# Compute control for a deterministic system
# Cost in iteration 0: 0.5448214287128382
# Final cost : 0.48162040907003306
# Compute control for a deterministic system
# Cost in iteration 0: 0.48162040907003306
# Final cost : 0.049203542731348415
# Compute control for a deterministic system
# Cost in iteration 0: 0.049203542731348415
# Converged in iteration 179 with cost 0.04482204064418836 because of step counter
# Final cost : 0.04482204064418836
# Compute control for a deterministic system
# Cost in iteration 0: 0.04482204064418836
# Converged in iteration 1 with cost 0.04482204064418836 because of step counter
# Final cost : 0.04482204064418836
# Compute control for a deterministic system
# Cost in iteration 0: 0.04482204064418836
# Converged in iteration 1 with cost 0.04482204064418836 because of step counter
# Final cost : 0.04482204064418836
# Compute control for a deterministic system
# Cost in iteration 0: 0.04482204064418836
# Converged in iteration 1 with cost 0.04482204064418836 because of step counter
# Final cost : 0.04482204064418836
# Compute control for a deterministic system
# Cost in iteration 0: 0.24710529221770525
# Final cost : 0.21683019471278148
# Compute control for a deterministic system
# Cost in iteration 0: 0.21683019471278148
# Final cost : 0.02972722489292863
# Compute control for a deterministic system
# Cost in iteration 0: 0.02972722489292863
# Cost in iteration 200: 0.027843551280699742
# Final cost : 0.027843551280699742
# Compute control for a deterministic system
# Cost in iteration 0: 0.027843551280699742
# Converged in iteration 52 with cost 0.027842329658185085 because of vanishing difference
# Final cost : 0.027842329658185085
# Compute control for a deterministic system
# Cost in iteration 0: 0.02784232965778498
# Converged in iteration 2 with cost 0.027842329654709883 because of step counter
# Final cost : 0.027842329654709883
# Compute control for a deterministic system
# Cost in iteration 0: 0.027842329654709883
# Converged in iteration 1 with cost 0.027842329654709883 because of step counter
# Final cost : 0.027842329654709883
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Final cost : 0.054285906053752345
# Compute control for a deterministic system
# Cost in iteration 0: 0.054285906053752345
# Final cost : 0.012997733967767943
# Compute control for a deterministic system
# Cost in iteration 0: 0.012997733967767943
# Cost in iteration 200: 0.012292150752650744
# Final cost : 0.012292150752650744
# Compute control for a deterministic system
# Cost in iteration 0: 0.012292150752650744
# Converged in iteration 18 with cost 0.012292117486264137 because of vanishing difference
# Final cost : 0.012292117486264137
# Compute control for a deterministic system
# Cost in iteration 0: 0.01229211748595079
# Converged in iteration 2 with cost 0.012292117484454456 because of step counter
# Final cost : 0.012292117484454456
# Compute control for a deterministic system
# Cost in iteration 0: 0.012292117484454456
# Converged in iteration 1 with cost 0.012292117484454456 because of step counter
# Final cost : 0.012292117484454456
# Compute control for a deterministic system
# Cost in iteration 0: 1.7739098699115488e-05
# Converged in iteration 1 with cost 1.7739098699115488e-05 because of step counter
# Final cost : 1.7739098699115488e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.7739098699115488e-05
# Converged in iteration 1 with cost 1.7739098699115488e-05 because of step counter
# Final cost : 1.7739098699115488e-05
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0808421383648825
# Cost in iteration 200: 0.027168287607129915
# Final cost : 0.027168287607129915
# Compute control for a deterministic system
# Cost in iteration 0: 0.027168287607129915
# Cost in iteration 200: 0.02667047539748006
# Final cost : 0.02667047539748006
# Compute control for a deterministic system
# Cost in iteration 0: 0.02667047539748006
# Converged in iteration 41 with cost 0.02666941397207524 because of vanishing difference
# Final cost : 0.02666941397207524
# Compute control for a deterministic system
# Cost in iteration 0: 0.02666941397167792
# Converged in iteration 2 with cost 0.02666941396885161 because of step counter
# Final cost : 0.02666941396885161
# Compute control for a deterministic system
# Cost in iteration 0: 0.02666941396885161
# Converged in iteration 1 with cost 0.02666941396885161 because of step counter
# Final cost : 0.02666941396885161
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.06255834136170688
# Cost in iteration 200: 0.037759996686995395
# Final cost : 0.037759996686995395
# Compute control for a deterministic system
# Cost in iteration 0: 0.037759996686995395
# Cost in iteration 200: 0.037322106010575035
# Final cost : 0.037322106010575035
# Compute control for a deterministic system
# Cost in iteration 0: 0.037322106010575035
# Converged in iteration 55 with cost 0.037319066051777566 because of vanishing difference
# Final cost : 0.037319066051777566
# Compute control for a deterministic system
# Cost in iteration 0: 0.037319066051378455
# Converged in iteration 2 with cost 0.03731906604832474 because of vanishing difference
# Final cost : 0.03731906604832474
# Compute control for a deterministic system
# Cost in iteration 0: 0.037319066048324606
# Converged in iteration 1 with cost 0.037319066048324606 because of step counter
# Final cost : 0.037319066048324606
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.0975483087133856
# Cost in iteration 200: 0.052972550168001904
# Final cost : 0.052972550168001904
# Compute control for a deterministic system
# Cost in iteration 0: 0.052972550168001904
# Cost in iteration 200: 0.05254566008485535
# Final cost : 0.05254566008485535
# Compute control for a deterministic system
# Cost in iteration 0: 0.05254566008485535
# Converged in iteration 78 with cost 0.05254047844310418 because of vanishing difference
# Final cost : 0.05254047844310418
# Compute control for a deterministic system
# Cost in iteration 0: 0.05254047844274201
# Converged in iteration 2 with cost 0.05254047843974917 because of step counter
# Final cost : 0.05254047843974917
# Compute control for a deterministic system
# Cost in iteration 0: 0.05254047843974917
# Converged in iteration 1 with cost 0.05254047843974917 because of step counter
# Final cost : 0.05254047843974917
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.10959210522592983
# Cost in iteration 200: 0.06880228454626239
# Final cost : 0.06880228454626239
# Compute control for a deterministic system
# Cost in iteration 0: 0.06880228454626239
# Cost in iteration 200: 0.06836273657669142
# Final cost : 0.06836273657669142
# Compute control for a deterministic system
# Cost in iteration 0: 0.06836273657669142
# Converged in iteration 100 with cost 0.06835637111094076 because of vanishing difference
# Final cost : 0.06835637111094076
# Compute control for a deterministic system
# Cost in iteration 0: 0.06835637111059047
# Converged in iteration 2 with cost 0.06835637110757103 because of vanishing difference
# Final cost : 0.06835637110757103
# Compute control for a deterministic system
# Cost in iteration 0: 0.06835637110757103
# Converged in iteration 1 with cost 0.06835637110757103 because of step counter
# Final cost : 0.06835637110757103
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.1231787776606592
# Cost in iteration 200: 0.08525376678305567
# Final cost : 0.08525376678305567
# Compute control for a deterministic system
# Cost in iteration 0: 0.08525376678305567
# Cost in iteration 200: 0.08465732206027789
# Final cost : 0.08465732206027789
# Compute control for a deterministic system
# Cost in iteration 0: 0.08465732206027789
# Converged in iteration 126 with cost 0.08463984559295491 because of vanishing difference
# Final cost : 0.08463984559295491
# Compute control for a deterministic system
# Cost in iteration 0: 0.0846398455926135
# Converged in iteration 2 with cost 0.08463984558960039 because of vanishing difference
# Final cost : 0.08463984558960039
# Compute control for a deterministic system
# Cost in iteration 0: 0.08463984558960039
# Converged in iteration 1 with cost 0.08463984558960039 because of step counter
# Final cost : 0.08463984558960039
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.13805456173109057
# Cost in iteration 200: 0.10220479419604288
# Final cost : 0.10220479419604288
# Compute control for a deterministic system
# Cost in iteration 0: 0.10220479419604288
# Cost in iteration 200: 0.1012788169071154
# Final cost : 0.1012788169071154
# Compute control for a deterministic system
# Cost in iteration 0: 0.1012788169071154
# Converged in iteration 149 with cost 0.10122401868538557 because of vanishing difference
# Final cost : 0.10122401868538557
# Compute control for a deterministic system
# Cost in iteration 0: 0.1012240186850562
# Converged in iteration 2 with cost 0.10122401868210976 because of vanishing difference
# Final cost : 0.10122401868210976
# Compute control for a deterministic system
# Cost in iteration 0: 0.10122401868210969
# Converged in iteration 1 with cost 0.10122401868210969 because of step counter
# Final cost : 0.10122401868210969
# Compute control for a deterministic system
# Cost in iteration 0: 0.15458056148117605
# Converged in iteration 160 with cost 0.11869339001615013 because of step counter
# Final cost : 0.11869339001615013
# Compute control for a deterministic system
# Cost in iteration 0: 0.11869339001615013
# Converged in iteration 1 with cost 0.11869339001615013 because of step counter
# Final cost : 0.11869339001615013
# Compute control for a deterministic system
# Cost in iteration 0: 0.11869339001615013
# Converged in iteration 1 with cost 0.11869339001615013 because of step counter
# Final cost : 0.11869339001615013
# Compute control for a deterministic system
# Cost in iteration 0: 0.11869339001615013
# Converged in iteration 1 with cost 0.11869339001615013 because of step counter
# Final cost : 0.11869339001615013
# Compute control for a deterministic system
# Cost in iteration 0: 0.11869339001615013
# Converged in iteration 1 with cost 0.11869339001615013 because of step counter
# Final cost : 0.11869339001615013
# Compute control for a deterministic system
# Cost in iteration 0: 0.1417243932189564
# Converged in iteration 67 with cost 0.12602352723889518 because of step counter
# Final cost : 0.12602352723889518
# Compute control for a deterministic system
# Cost in iteration 0: 0.12602352723889518
# Converged in iteration 1 with cost 0.12602352723889518 because of step counter
# Final cost : 0.12602352723889518
# Compute control for a deterministic system
# Cost in iteration 0: 0.12602352723889518
# Converged in iteration 1 with cost 0.12602352723889518 because of step counter
# Final cost : 0.12602352723889518
# Compute control for a deterministic system
# Cost in iteration 0: 0.12602352723889518
# Converged in iteration 1 with cost 0.12602352723889518 because of step counter
# Final cost : 0.12602352723889518
# Compute control for a deterministic system
# Cost in iteration 0: 0.12602352723889518
# Converged in iteration 1 with cost 0.12602352723889518 because of step counter
# Final cost : 0.12602352723889518
# Compute control for a deterministic system
# Cost in iteration 0: 0.17856185250879036
# Cost in iteration 200: 0.14383103953158927
# Final cost : 0.14383103953158927
# Compute control for a deterministic system
# Cost in iteration 0: 0.14383103953158927
# Converged in iteration 7 with cost 0.14382742056304157 because of step counter
# Final cost : 0.14382742056304157
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382742056304157
# Converged in iteration 1 with cost 0.14382742056304157 because of step counter
# Final cost : 0.14382742056304157
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382742056304157
# Converged in iteration 1 with cost 0.14382742056304157 because of step counter
# Final cost : 0.14382742056304157
# Compute control for a deterministic system
# Cost in iteration 0: 0.14382742056304157
# Converged in iteration 1 with cost 0.14382742056304157 because of step counter
# Final cost : 0.14382742056304157
# Compute control for a deterministic system
# Cost in iteration 0: 0.1979036105638693
# Cost in iteration 200: 0.1620575424585526
# Final cost : 0.1620575424585526
# Compute control for a deterministic system
# Cost in iteration 0: 0.1620575424585526
# ...
# Compute control for a deterministic system
# Cost in iteration 0: 4.462338687066147
# Converged in iteration 1 with cost 4.462338687066147 because of step counter
# Final cost : 4.462338687066147
# Compute control for a deterministic system
# Cost in iteration 0: 4.462338687066147
# Converged in iteration 1 with cost 4.462338687066147 because of step counter
# Final cost : 4.462338687066147
# -----------------------------------------------
# 5 found better solution,  24
# Compute control for a deterministic system
# Cost in iteration 0: 3.904388894174473
# Converged in iteration 1 with cost 3.904388894174473 because of step counter
# Final cost : 3.904388894174473
# Compute control for a deterministic system
# Cost in iteration 0: 3.904388894174473
# Converged in iteration 1 with cost 3.904388894174473 because of step counter
# Final cost : 3.904388894174473
# Compute control for a deterministic system
# Cost in iteration 0: 3.904388894174473
# Converged in iteration 1 with cost 3.904388894174473 because of step counter
# Final cost : 3.904388894174473
# Compute control for a deterministic system
# Cost in iteration 0: 3.904388894174473
# Converged in iteration 1 with cost 3.904388894174473 because of step counter
# Final cost : 3.904388894174473
# Compute control for a deterministic system
# Cost in iteration 0: 3.904388894174473
# Converged in iteration 1 with cost 3.904388894174473 because of step counter
# Final cost : 3.904388894174473
# -----------------------------------------------
# 5 found better solution,  25
# Compute control for a deterministic system
# Cost in iteration 0: 3.512454759543072
# Converged in iteration 1 with cost 3.512454759543072 because of step counter
# Final cost : 3.512454759543072
# Compute control for a deterministic system
# Cost in iteration 0: 3.512454759543072
# Converged in iteration 1 with cost 3.512454759543072 because of step counter
# Final cost : 3.512454759543072
# Compute control for a deterministic system
# Cost in iteration 0: 3.512454759543072
# Converged in iteration 1 with cost 3.512454759543072 because of step counter
# Final cost : 3.512454759543072
# Compute control for a deterministic system
# Cost in iteration 0: 3.512454759543072
# Converged in iteration 1 with cost 3.512454759543072 because of step counter
# Final cost : 3.512454759543072
# Compute control for a deterministic system
# Cost in iteration 0: 3.512454759543072
# Converged in iteration 1 with cost 3.512454759543072 because of step counter
# Final cost : 3.512454759543072
# -----------------------------------------------
# 5 found better solution,  26
# Compute control for a deterministic system
# Cost in iteration 0: 3.021453424496542
# Converged in iteration 1 with cost 3.021453424496542 because of step counter
# Final cost : 3.021453424496542
# Compute control for a deterministic system
# Cost in iteration 0: 3.021453424496542
# Converged in iteration 1 with cost 3.021453424496542 because of step counter
# Final cost : 3.021453424496542
# Compute control for a deterministic system
# Cost in iteration 0: 3.021453424496542
# Converged in iteration 1 with cost 3.021453424496542 because of step counter
# Final cost : 3.021453424496542
# Compute control for a deterministic system
# Cost in iteration 0: 3.021453424496542
# Converged in iteration 1 with cost 3.021453424496542 because of step counter
# Final cost : 3.021453424496542
# Compute control for a deterministic system
# Cost in iteration 0: 3.021453424496542
# Converged in iteration 1 with cost 3.021453424496542 because of step counter
# Final cost : 3.021453424496542
# -----------------------------------------------
# 5 found better solution,  27
# Compute control for a deterministic system
# Cost in iteration 0: 2.588973294436326
# Converged in iteration 1 with cost 2.588973294436326 because of step counter
# Final cost : 2.588973294436326
# Compute control for a deterministic system
# Cost in iteration 0: 2.588973294436326
# Converged in iteration 1 with cost 2.588973294436326 because of step counter
# Final cost : 2.588973294436326
# Compute control for a deterministic system
# Cost in iteration 0: 2.588973294436326
# Converged in iteration 1 with cost 2.588973294436326 because of step counter
# Final cost : 2.588973294436326
# Compute control for a deterministic system
# Cost in iteration 0: 2.588973294436326
# Converged in iteration 1 with cost 2.588973294436326 because of step counter
# Final cost : 2.588973294436326
# Compute control for a deterministic system
# Cost in iteration 0: 2.588973294436326
# Converged in iteration 1 with cost 2.588973294436326 because of step counter
# Final cost : 2.588973294436326
# -----------------------------------------------
# 5 found better solution,  28
# Compute control for a deterministic system
# Cost in iteration 0: 2.2294377085128767
# Converged in iteration 1 with cost 2.2294377085128767 because of step counter
# Final cost : 2.2294377085128767
# Compute control for a deterministic system
# Cost in iteration 0: 2.2294377085128767
# Converged in iteration 1 with cost 2.2294377085128767 because of step counter
# Final cost : 2.2294377085128767
# Compute control for a deterministic system
# Cost in iteration 0: 2.2294377085128767
# Converged in iteration 1 with cost 2.2294377085128767 because of step counter
# Final cost : 2.2294377085128767
# Compute control for a deterministic system
# Cost in iteration 0: 2.2294377085128767
# Converged in iteration 1 with cost 2.2294377085128767 because of step counter
# Final cost : 2.2294377085128767
# Compute control for a deterministic system
# Cost in iteration 0: 2.2294377085128767
# Converged in iteration 1 with cost 2.2294377085128767 because of step counter
# Final cost : 2.2294377085128767
# -----------------------------------------------
# 5 found better solution,  29
# Compute control for a deterministic system
# Cost in iteration 0: 1.956210765420595
# Converged in iteration 4 with cost 1.9367140402387868 because of step counter
# Final cost : 1.9367140402387868
# Compute control for a deterministic system
# Cost in iteration 0: 1.9367140402387868
# Converged in iteration 1 with cost 1.9367140402387868 because of step counter
# Final cost : 1.9367140402387868
# Compute control for a deterministic system
# Cost in iteration 0: 1.9367140402387868
# Converged in iteration 1 with cost 1.9367140402387868 because of step counter
# Final cost : 1.9367140402387868
# Compute control for a deterministic system
# Cost in iteration 0: 1.9367140402387868
# Converged in iteration 1 with cost 1.9367140402387868 because of step counter
# Final cost : 1.9367140402387868
# Compute control for a deterministic system
# Cost in iteration 0: 1.9367140402387868
# Converged in iteration 1 with cost 1.9367140402387868 because of step counter
# Final cost : 1.9367140402387868
# -----------------------------------------------
# 5 found better solution,  30
# Compute control for a deterministic system
# Cost in iteration 0: 1.6986102771205491
# Converged in iteration 4 with cost 1.6691911612101187 because of step counter
# Final cost : 1.6691911612101187
# Compute control for a deterministic system
# Cost in iteration 0: 1.6691911612101187
# Converged in iteration 1 with cost 1.6691911612101187 because of step counter
# Final cost : 1.6691911612101187
# Compute control for a deterministic system
# Cost in iteration 0: 1.6691911612101187
# Converged in iteration 1 with cost 1.6691911612101187 because of step counter
# Final cost : 1.6691911612101187
# Compute control for a deterministic system
# Cost in iteration 0: 1.6691911612101187
# Converged in iteration 1 with cost 1.6691911612101187 because of step counter
# Final cost : 1.6691911612101187
# Compute control for a deterministic system
# Cost in iteration 0: 1.6691911612101187
# Converged in iteration 1 with cost 1.6691911612101187 because of step counter
# Final cost : 1.6691911612101187
# -----------------------------------------------
# 5 found better solution,  31
# Compute control for a deterministic system
# Cost in iteration 0: 1.5091170831102623
# Converged in iteration 4 with cost 1.4830256000544588 because of step counter
# Final cost : 1.4830256000544588
# Compute control for a deterministic system
# Cost in iteration 0: 1.4830256000544588
# Converged in iteration 1 with cost 1.4830256000544588 because of step counter
# Final cost : 1.4830256000544588
# Compute control for a deterministic system
# Cost in iteration 0: 1.4830256000544588
# Converged in iteration 1 with cost 1.4830256000544588 because of step counter
# Final cost : 1.4830256000544588
# Compute control for a deterministic system
# Cost in iteration 0: 1.4830256000544588
# Converged in iteration 1 with cost 1.4830256000544588 because of step counter
# Final cost : 1.4830256000544588
# Compute control for a deterministic system
# Cost in iteration 0: 1.4830256000544588
# Converged in iteration 1 with cost 1.4830256000544588 because of step counter
# Final cost : 1.4830256000544588
# -----------------------------------------------
# 5 found better solution,  32
# Compute control for a deterministic system
# Cost in iteration 0: 1.268100694563877
# Converged in iteration 3 with cost 1.2536072264488762 because of step counter
# Final cost : 1.2536072264488762
# Compute control for a deterministic system
# Cost in iteration 0: 1.2536072264488762
# Converged in iteration 1 with cost 1.2536072264488762 because of step counter
# Final cost : 1.2536072264488762
# Compute control for a deterministic system
# Cost in iteration 0: 1.2536072264488762
# Converged in iteration 1 with cost 1.2536072264488762 because of step counter
# Final cost : 1.2536072264488762
# Compute control for a deterministic system
# Cost in iteration 0: 1.2536072264488762
# Converged in iteration 1 with cost 1.2536072264488762 because of step counter
# Final cost : 1.2536072264488762
# Compute control for a deterministic system
# Cost in iteration 0: 1.2536072264488762
# Converged in iteration 1 with cost 1.2536072264488762 because of step counter
# Final cost : 1.2536072264488762
# -----------------------------------------------
# 5 found better solution,  33
# Compute control for a deterministic system
# Cost in iteration 0: 1.047074686760228
# Converged in iteration 3 with cost 1.0380682202186853 because of step counter
# Final cost : 1.0380682202186853
# Compute control for a deterministic system
# Cost in iteration 0: 1.0380682202186853
# Converged in iteration 1 with cost 1.0380682202186853 because of step counter
# Final cost : 1.0380682202186853
# Compute control for a deterministic system
# Cost in iteration 0: 1.0380682202186853
# Converged in iteration 1 with cost 1.0380682202186853 because of step counter
# Final cost : 1.0380682202186853
# Compute control for a deterministic system
# Cost in iteration 0: 1.0380682202186853
# Converged in iteration 1 with cost 1.0380682202186853 because of step counter
# Final cost : 1.0380682202186853
# Compute control for a deterministic system
# Cost in iteration 0: 1.0380682202186853
# Converged in iteration 1 with cost 1.0380682202186853 because of step counter
# Final cost : 1.0380682202186853
# -----------------------------------------------
# 5 found better solution,  34
# Compute control for a deterministic system
# Cost in iteration 0: 0.8279107142024822
# Converged in iteration 2 with cost 0.8258211270954785 because of step counter
# Final cost : 0.8258211270954785
# Compute control for a deterministic system
# Cost in iteration 0: 0.8258211270954785
# Converged in iteration 1 with cost 0.8258211270954785 because of step counter
# Final cost : 0.8258211270954785
# Compute control for a deterministic system
# Cost in iteration 0: 0.8258211270954785
# Converged in iteration 1 with cost 0.8258211270954785 because of step counter
# Final cost : 0.8258211270954785
# Compute control for a deterministic system
# Cost in iteration 0: 0.8258211270954785
# Converged in iteration 1 with cost 0.8258211270954785 because of step counter
# Final cost : 0.8258211270954785
# Compute control for a deterministic system
# Cost in iteration 0: 0.8258211270954785
# Converged in iteration 1 with cost 0.8258211270954785 because of step counter
# Final cost : 0.8258211270954785
# -----------------------------------------------
# 5 found better solution,  35
# Compute control for a deterministic system
# Cost in iteration 0: 0.6127783189655774
# Converged in iteration 2 with cost 0.6121216674406889 because of step counter
# Final cost : 0.6121216674406889
# Compute control for a deterministic system
# Cost in iteration 0: 0.6121216674406889
# Converged in iteration 1 with cost 0.6121216674406889 because of step counter
# Final cost : 0.6121216674406889
# Compute control for a deterministic system
# Cost in iteration 0: 0.6121216674406889
# Converged in iteration 1 with cost 0.6121216674406889 because of step counter
# Final cost : 0.6121216674406889
# Compute control for a deterministic system
# Cost in iteration 0: 0.6121216674406889
# Converged in iteration 1 with cost 0.6121216674406889 because of step counter
# Final cost : 0.6121216674406889
# Compute control for a deterministic system
# Cost in iteration 0: 0.6121216674406889
# Converged in iteration 1 with cost 0.6121216674406889 because of step counter
# Final cost : 0.6121216674406889
# -----------------------------------------------
# 5 found better solution,  36
# Compute control for a deterministic system
# Cost in iteration 0: 0.44868248622176776
# Converged in iteration 2 with cost 0.4484230421252801 because of step counter
# Final cost : 0.4484230421252801
# Compute control for a deterministic system
# Cost in iteration 0: 0.4484230421252801
# Converged in iteration 1 with cost 0.4484230421252801 because of step counter
# Final cost : 0.4484230421252801
# Compute control for a deterministic system
# Cost in iteration 0: 0.4484230421252801
# Converged in iteration 1 with cost 0.4484230421252801 because of step counter
# Final cost : 0.4484230421252801
# Compute control for a deterministic system
# Cost in iteration 0: 0.4484230421252801
# Converged in iteration 1 with cost 0.4484230421252801 because of step counter
# Final cost : 0.4484230421252801
# Compute control for a deterministic system
# Cost in iteration 0: 0.4484230421252801
# Converged in iteration 1 with cost 0.4484230421252801 because of step counter
# Final cost : 0.4484230421252801
# -----------------------------------------------
# 5 found better solution,  37
# Compute control for a deterministic system
# Cost in iteration 0: 0.22971539839175636
# Converged in iteration 1 with cost 0.22971539839175636 because of step counter
# Final cost : 0.22971539839175636
# Compute control for a deterministic system
# Cost in iteration 0: 0.22971539839175636
# Converged in iteration 1 with cost 0.22971539839175636 because of step counter
# Final cost : 0.22971539839175636
# Compute control for a deterministic system
# Cost in iteration 0: 0.22971539839175636
# Converged in iteration 1 with cost 0.22971539839175636 because of step counter
# Final cost : 0.22971539839175636
# Compute control for a deterministic system
# Cost in iteration 0: 0.22971539839175636
# Converged in iteration 1 with cost 0.22971539839175636 because of step counter
# Final cost : 0.22971539839175636
# Compute control for a deterministic system
# Cost in iteration 0: 0.22971539839175636
# Converged in iteration 1 with cost 0.22971539839175636 because of step counter
# Final cost : 0.22971539839175636
# -----------------------------------------------
# 5 found better solution,  38
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Converged in iteration 1 with cost 0.06177479817444679 because of step counter
# Final cost : 0.06177479817444679
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Converged in iteration 1 with cost 0.06177479817444679 because of step counter
# Final cost : 0.06177479817444679
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Converged in iteration 1 with cost 0.06177479817444679 because of step counter
# Final cost : 0.06177479817444679
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Converged in iteration 1 with cost 0.06177479817444679 because of step counter
# Final cost : 0.06177479817444679
# Compute control for a deterministic system
# Cost in iteration 0: 0.06177479817444679
# Converged in iteration 1 with cost 0.06177479817444679 because of step counter
# Final cost : 0.06177479817444679

# %%
save(results_peak)
