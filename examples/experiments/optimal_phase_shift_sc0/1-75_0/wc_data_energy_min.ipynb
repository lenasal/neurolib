# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()
print(wc.exc[0,-1], wc.inh[0,-1])

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,144], wc.inh[0,144]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# 0.05741828140599091 0.1036970090184363
# minima =  [  94  247  400  553  706  858 1011 1164 1317 1470 1623 1776 1929 2082
#  2235 2388 2541 2694 2847]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(600)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(2000)

    return

def get_values(results_dict, iw, ish, w2):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_2 = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    wc_controlled.w_2 = w2

    ce = np.zeros((results_dict["control"][iw][ish].shape))
    ce[0,0,:] = results_dict["control"][iw][ish][0,0,:]
    results_dict["L2_cost_e_unweighted"][iw][ish] = cost_functions.energy_cost(ce, 1., dt)
    ci = np.zeros((results_dict["control"][iw][ish].shape))
    ci[0,1,:] = results_dict["control"][iw][ish][0,1,:]
    results_dict["L2_cost_i_unweighted"][iw][ish] = cost_functions.energy_cost(ci, 1., dt)

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w2, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=w2, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w2.png", "1_min_w2.png", "4_min_w2.png"]

results_min = dict([
    ('w2', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_e_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L2_cost_i_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w2.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w2.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w2.pickle")

# %%
for j in [20]:
    results_min["control"][1][j] = None

# %%
plt.plot(results_min["control"][1][19][0,0,:])
plt.plot(results_min["control"][1][20][0,0,:])
plt.plot(results_min["control"][1][21][0,0,:])
plt.show()

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w2.pickle")

ind_list = range(14,24)
options = [True, True, False, False, True, False, False, False]
#options = [False, False, False, False, False, False, False, False]

for k in range(1):

    for i_w in range(len(results_min["w2"])):

        if i_w != 1:
            continue

        w2 = results_min['w2'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w2)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w2)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w2"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95+np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95+np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w2, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w2)

        save(results_min)
# Out:
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.33393734921201934
# Final cost : 0.20337504080692576
# Compute control for a deterministic system
# Cost in iteration 0: 0.20337504080692576
# Final cost : 0.20164812083166125
# Compute control for a deterministic system
# Cost in iteration 0: 0.20164812083166125
# Final cost : 0.2016029232844208
# Compute control for a deterministic system
# Cost in iteration 0: 0.2016029232844208
# Converged in iteration 574 with cost 0.20160292311005948 because of step counter
# Final cost : 0.20160292311005948
# Compute control for a deterministic system
# Cost in iteration 0: 0.20160292311005948
# Converged in iteration 4 with cost 0.20160292311005726 because of step counter
# Final cost : 0.20160292311005726
# Compute control for a deterministic system
# Cost in iteration 0: 0.3450708752196814
# Final cost : 0.22141595151970853
# Compute control for a deterministic system
# Cost in iteration 0: 0.22141595151970853
# Final cost : 0.22028325878942098
# Compute control for a deterministic system
# Cost in iteration 0: 0.22028325878942098
# Final cost : 0.22024822732004162
# Compute control for a deterministic system
# Cost in iteration 0: 0.22024822732004162
# Converged in iteration 731 with cost 0.2202482242089522 because of step counter
# Final cost : 0.2202482242089522
# Compute control for a deterministic system
# Cost in iteration 0: 0.2202482242089522
# Converged in iteration 1 with cost 0.2202482242089522 because of step counter
# Final cost : 0.2202482242089522
# Compute control for a deterministic system
# Cost in iteration 0: 0.26241334252837334
# Final cost : 0.2481003203963731
# Compute control for a deterministic system
# Cost in iteration 0: 0.2481003203963731
# Final cost : 0.24626091998408794
# Compute control for a deterministic system
# Cost in iteration 0: 0.24626091998408794
# Final cost : 0.24618102847458323
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618102847458323
# Final cost : 0.24618099046024097
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618099046024097
# Converged in iteration 134 with cost 0.24618099045940128 because of vanishing difference
# Final cost : 0.24618099045940128
# Compute control for a deterministic system
# Cost in iteration 0: 0.3996582087281618
# Final cost : 0.2756256181191316
# Compute control for a deterministic system
# Cost in iteration 0: 0.2756256181191316
# Final cost : 0.2733712767961244
# Compute control for a deterministic system
# Cost in iteration 0: 0.2733712767961244
# Final cost : 0.2732486033728177
# Compute control for a deterministic system
# Cost in iteration 0: 0.2732486033728177
# Final cost : 0.2732479687786223
# Compute control for a deterministic system
# Cost in iteration 0: 0.2732479687786223
# Converged in iteration 488 with cost 0.27324796877054436 because of vanishing difference
# Final cost : 0.27324796877054436
# Compute control for a deterministic system
# Cost in iteration 0: 0.3168118775274465
# Final cost : 0.30357225906163676
# Compute control for a deterministic system
# Cost in iteration 0: 0.30357225906163676
# Final cost : 0.3013619959843106
# Compute control for a deterministic system
# Cost in iteration 0: 0.3013619959843106
# Final cost : 0.3011888647384578
# Compute control for a deterministic system
# Cost in iteration 0: 0.3011888647384578
# Final cost : 0.3011863969626202
# Compute control for a deterministic system
# Cost in iteration 0: 0.3011863969626202
# Final cost : 0.30118621600763956
# Compute control for a deterministic system
# Cost in iteration 0: 0.31875133892142055
# Final cost : 0.30850458735187986
# Compute control for a deterministic system
# Cost in iteration 0: 0.30850458735187986
# Final cost : 0.3073035599098882
# Compute control for a deterministic system
# Cost in iteration 0: 0.3073035599098882
# Final cost : 0.30723051160115195
# Compute control for a deterministic system
# Cost in iteration 0: 0.30723051160115195
# Final cost : 0.30717743023450866
# Compute control for a deterministic system
# Cost in iteration 0: 0.30717743023450866
# Final cost : 0.3071218333154002
# Compute control for a deterministic system
# Cost in iteration 0: 0.3791079281040995
# Final cost : 0.31738399737837925
# Compute control for a deterministic system
# Cost in iteration 0: 0.31738399737837925
# Final cost : 0.3168503491753079
# Compute control for a deterministic system
# Cost in iteration 0: 0.3168503491753079
# Final cost : 0.31679806216467465
# Compute control for a deterministic system
# Cost in iteration 0: 0.31679806216467465
# Final cost : 0.31676506334876925
# Compute control for a deterministic system
# Cost in iteration 0: 0.31676506334876925
# Final cost : 0.3167308431239191
# -----------------------------------------------
# 0 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.3352011839961332
# Final cost : 0.3289538137401634
# Compute control for a deterministic system
# Cost in iteration 0: 0.3289538137401634
# Final cost : 0.3281605987656193
# Compute control for a deterministic system
# Cost in iteration 0: 0.3281605987656193
# Final cost : 0.32802442651735764
# Compute control for a deterministic system
# Cost in iteration 0: 0.32802442651735764
# Final cost : 0.32793338452354576
# Compute control for a deterministic system
# Cost in iteration 0: 0.32793338452354576
# Final cost : 0.32782117794544774
# Compute control for a deterministic system
# Cost in iteration 0: 0.3700349780571455
# Final cost : 0.33719929184777714
# Compute control for a deterministic system
# Cost in iteration 0: 0.33719929184777714
# Final cost : 0.3367067735776868
# Compute control for a deterministic system
# Cost in iteration 0: 0.3367067735776868
# Final cost : 0.3365964854088955
# Compute control for a deterministic system
# Cost in iteration 0: 0.3365964854088955
# Final cost : 0.3365434522132689
# Compute control for a deterministic system
# Cost in iteration 0: 0.3365434522132689
# Final cost : 0.3364971287234553
# Compute control for a deterministic system
# Cost in iteration 0: 0.4677790628955585
# Final cost : 0.3438218991568775
# Compute control for a deterministic system
# Cost in iteration 0: 0.3438218991568775
# Final cost : 0.3435693572209694
# Compute control for a deterministic system
# Cost in iteration 0: 0.3435693572209694
# Final cost : 0.3434672624456752
# Compute control for a deterministic system
# Cost in iteration 0: 0.3434672624456752
# Final cost : 0.3434334566936603
# Compute control for a deterministic system
# Cost in iteration 0: 0.3434334566936603
# Final cost : 0.3434076633375619
# ----------------------------------------------- 1
# Compute control for a deterministic system
# Cost in iteration 0: 1.5482064004752831
# Final cost : 0.34888394174310744
# Compute control for a deterministic system
# Cost in iteration 0: 0.34888394174310744
# Final cost : 0.34367129362325055
# Compute control for a deterministic system
# Cost in iteration 0: 0.34367129362325055
# Final cost : 0.3434198022008189
# Compute control for a deterministic system
# Cost in iteration 0: 0.3434198022008189
# Final cost : 0.3433889447840842
# Compute control for a deterministic system
# Cost in iteration 0: 0.7476511927268545
# Final cost : 0.3366301518216512
# Compute control for a deterministic system
# Cost in iteration 0: 0.3366301518216512
# Final cost : 0.3365132987402796
# Compute control for a deterministic system
# Cost in iteration 0: 0.3365132987402796
# Final cost : 0.3364715949602923
# Compute control for a deterministic system
# Cost in iteration 0: 0.3364715949602923
# Final cost : 0.33644584715000947
# Compute control for a deterministic system
# Cost in iteration 0: 0.5199987134472787
# Final cost : 0.32806934414174543
# Compute control for a deterministic system
# Cost in iteration 0: 0.32806934414174543
# Final cost : 0.32787840017762176
# Compute control for a deterministic system
# Cost in iteration 0: 0.32787840017762176
# Final cost : 0.3278128644700978
# Compute control for a deterministic system
# Cost in iteration 0: 0.3278128644700978
# Final cost : 0.3277373095423828
# Compute control for a deterministic system
# Cost in iteration 0: 0.40198677643516617
# Final cost : 0.3171590707637741
# Compute control for a deterministic system
# Cost in iteration 0: 0.3171590707637741
# Final cost : 0.3169481045295693
# Compute control for a deterministic system
# Cost in iteration 0: 0.3169481045295693
# Final cost : 0.3168746904068067
# Compute control for a deterministic system
# Cost in iteration 0: 0.3168746904068067
# Final cost : 0.3167792896301199
# Compute control for a deterministic system
# Cost in iteration 0: 0.31744950351877843
# Final cost : 0.30718392084398444
# Compute control for a deterministic system
# Cost in iteration 0: 0.30718392084398444
# Final cost : 0.30712047906616646
# Compute control for a deterministic system
# Cost in iteration 0: 0.30712047906616646
# Final cost : 0.3071093467460577
# Compute control for a deterministic system
# Cost in iteration 0: 0.3071093467460577
# Final cost : 0.3070982099344758
# Compute control for a deterministic system
# Cost in iteration 0: 0.49189424818299693
# Final cost : 0.29285289404983084
# Compute control for a deterministic system
# Cost in iteration 0: 0.29285289404983084
# Final cost : 0.29270337546453595
# Compute control for a deterministic system
# Cost in iteration 0: 0.29270337546453595
# Final cost : 0.29263554053687024
# Compute control for a deterministic system
# Cost in iteration 0: 0.29263554053687024
# Final cost : 0.29258460389627367
# Compute control for a deterministic system
# Cost in iteration 0: 0.4966755103262257
# Final cost : 0.27631569271760503
# Compute control for a deterministic system
# Cost in iteration 0: 0.27631569271760503
# Final cost : 0.2761509377447226
# Compute control for a deterministic system
# Cost in iteration 0: 0.2761509377447226
# Final cost : 0.27602676080393235
# Compute control for a deterministic system
# Cost in iteration 0: 0.27602676080393235
# Final cost : 0.27596807855487065
# Compute control for a deterministic system
# Cost in iteration 0: 0.306517000798402
# Final cost : 0.24629411700611215
# Compute control for a deterministic system
# Cost in iteration 0: 0.24629411700611215
# Final cost : 0.2461810668662949
# Compute control for a deterministic system
# Cost in iteration 0: 0.2461810668662949
# Final cost : 0.24618099047093941
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618099047093941
# Converged in iteration 90 with cost 0.2461809904593723 because of step counter
# Final cost : 0.2461809904593723
# Compute control for a deterministic system
# Cost in iteration 0: 0.30710244952386856
# Final cost : 0.22032400438303826
# Compute control for a deterministic system
# Cost in iteration 0: 0.22032400438303826
# Final cost : 0.22024822805510275
# Compute control for a deterministic system
# Cost in iteration 0: 0.22024822805510275
# Converged in iteration 835 with cost 0.22024822420898524 because of step counter
# Final cost : 0.22024822420898524
# Compute control for a deterministic system
# Cost in iteration 0: 0.22024822420898524
# Converged in iteration 33 with cost 0.2202482242089053 because of step counter
# Final cost : 0.2202482242089053
# Compute control for a deterministic system
# Cost in iteration 0: 0.22054745340149737
# Final cost : 0.2016344872826751
# Compute control for a deterministic system
# Cost in iteration 0: 0.2016344872826751
# Final cost : 0.20160292329822802
# Compute control for a deterministic system
# Cost in iteration 0: 0.20160292329822802
# Converged in iteration 512 with cost 0.2016029231100354 because of step counter
# Final cost : 0.2016029231100354
# Compute control for a deterministic system
# Cost in iteration 0: 0.2016029231100354
# Converged in iteration 19 with cost 0.20160292311000108 because of step counter
# Final cost : 0.20160292311000108
# ----------------------------------------------- 4
# Compute control for a deterministic system
# Cost in iteration 0: 0.2050234826407102
# Final cost : 0.20199265066603034
# Compute control for a deterministic system
# Cost in iteration 0: 0.20199265066603034
# Final cost : 0.20160297068496452
# Compute control for a deterministic system
# Cost in iteration 0: 0.20160297068496452
# Final cost : 0.20160292311008562
# Compute control for a deterministic system
# Cost in iteration 0: 0.20160292311008562
# Converged in iteration 32 with cost 0.2016029231100476 because of vanishing difference
# Final cost : 0.2016029231100476
# Compute control for a deterministic system
# Cost in iteration 0: 0.2016029231100476
# Converged in iteration 5 with cost 0.2016029231100461 because of step counter
# Final cost : 0.2016029231100461
# Compute control for a deterministic system
# Cost in iteration 0: 0.22353262582931385
# Final cost : 0.22074738060399188
# Compute control for a deterministic system
# Cost in iteration 0: 0.22074738060399188
# Final cost : 0.22024830227756895
# Compute control for a deterministic system
# Cost in iteration 0: 0.22024830227756895
# Final cost : 0.2202482242107229
# Compute control for a deterministic system
# Cost in iteration 0: 0.2202482242107229
# Converged in iteration 227 with cost 0.2202482242089682 because of vanishing difference
# Final cost : 0.2202482242089682
# Compute control for a deterministic system
# Cost in iteration 0: 0.2202482242089682
# Converged in iteration 1 with cost 0.2202482242089682 because of step counter
# Final cost : 0.2202482242089682
# Compute control for a deterministic system
# Cost in iteration 0: 0.2639505210493924
# Final cost : 0.24663306841754612
# Compute control for a deterministic system
# Cost in iteration 0: 0.24663306841754612
# Final cost : 0.24618105138630242
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618105138630242
# Final cost : 0.24618099046119776
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618099046119776
# Converged in iteration 315 with cost 0.24618099045945321 because of step counter
# Final cost : 0.24618099045945321
# Compute control for a deterministic system
# Cost in iteration 0: 0.24618099045945321
# Converged in iteration 18 with cost 0.24618099045937905 because of step counter
# Final cost : 0.24618099045937905
# Compute control for a deterministic system
# Cost in iteration 0: 0.2773035762437196
# Final cost : 0.27384813307940115
# Compute control for a deterministic system
# Cost in iteration 0: 0.27384813307940115
# Final cost : 0.27324810718824705
# Compute control for a deterministic system
# Cost in iteration 0: 0.27324810718824705
# Final cost : 0.27324796882111585
# Compute control for a deterministic system
# Cost in iteration 0: 0.27324796882111585
# Converged in iteration 741 with cost 0.273247968770591 because of step counter
# Final cost : 0.273247968770591
# Compute control for a deterministic system
# Cost in iteration 0: 0.273247968770591
# Converged in iteration 1 with cost 0.273247968770591 because of step counter
# Final cost : 0.273247968770591
# Compute control for a deterministic system
# Cost in iteration 0: 0.3445995707677212
# Final cost : 0.2927891453441243
# Compute control for a deterministic system
# Cost in iteration 0: 0.2927891453441243
# Final cost : 0.29256494667774596
# Compute control for a deterministic system
# Cost in iteration 0: 0.29256494667774596
# Final cost : 0.29256483178701775
# Compute control for a deterministic system
# Cost in iteration 0: 0.29256483178701775
# Final cost : 0.29256483171433534
# Compute control for a deterministic system
# Cost in iteration 0: 0.29256483171433534
# Converged in iteration 1389 with cost 0.29256483170755776 because of step counter
# Final cost : 0.29256483170755776
# -----------------------------------------------
# 4 found better solution,  18
# Compute control for a deterministic system
# Cost in iteration 0: 0.3586177559740523
# Final cost : 0.30722479729951396
# Compute control for a deterministic system
# Cost in iteration 0: 0.30722479729951396
# Final cost : 0.30709180556246274
# Compute control for a deterministic system
# Cost in iteration 0: 0.30709180556246274
# Final cost : 0.30709136446572854
# Compute control for a deterministic system
# Cost in iteration 0: 0.30709136446572854
# Final cost : 0.3070913635623629
# Compute control for a deterministic system
# Cost in iteration 0: 0.3070913635623629
# Converged in iteration 538 with cost 0.3070913635596266 because of step counter
# Final cost : 0.3070913635596266
# Compute control for a deterministic system
# Cost in iteration 0: 0.3567004635881146
# Final cost : 0.31678913043036483
# Compute control for a deterministic system
# Cost in iteration 0: 0.31678913043036483
# Final cost : 0.31672651288087295
# Compute control for a deterministic system
# Cost in iteration 0: 0.31672651288087295
# Final cost : 0.31672050335614665
# Compute control for a deterministic system
# Cost in iteration 0: 0.31672050335614665
# Final cost : 0.3167131710006303
# Compute control for a deterministic system
# Cost in iteration 0: 0.3167131710006303
# Final cost : 0.316701167965992
# -----------------------------------------------
# 4 found better solution,  20
# Compute control for a deterministic system
# Cost in iteration 0: 0.3528774962826297
# Final cost : 0.32764963571888345
# Compute control for a deterministic system
# Cost in iteration 0: 0.32764963571888345
# Final cost : 0.3276177346559681
# Compute control for a deterministic system
# Cost in iteration 0: 0.3276177346559681
# Final cost : 0.327617078406206
# Compute control for a deterministic system
# Cost in iteration 0: 0.327617078406206
# Final cost : 0.3276170459124549
# Compute control for a deterministic system
# Cost in iteration 0: 0.3276170459124549
# Final cost : 0.32761703960111926
# -----------------------------------------------
# 4 found better solution,  21
# Compute control for a deterministic system
# Cost in iteration 0: 0.38502752515892297
# Final cost : 0.33638599660422097
# Compute control for a deterministic system
# Cost in iteration 0: 0.33638599660422097
# Final cost : 0.33636689250533286
# Compute control for a deterministic system
# Cost in iteration 0: 0.33636689250533286
# Final cost : 0.33636435136627296
# Compute control for a deterministic system
# Cost in iteration 0: 0.33636435136627296
# Final cost : 0.3363640056671338
# Compute control for a deterministic system
# Cost in iteration 0: 0.3363640056671338
# Final cost : 0.33636395870438063
# -----------------------------------------------
# 4 found better solution,  22
# Compute control for a deterministic system
# Cost in iteration 0: 0.34334049507825326
# Final cost : 0.34332892304590307
# Compute control for a deterministic system
# Cost in iteration 0: 0.34332892304590307
# Final cost : 0.3433266001066318
# Compute control for a deterministic system
# Cost in iteration 0: 0.3433266001066318
# Final cost : 0.3433264846332534
# Compute control for a deterministic system
# Cost in iteration 0: 0.3433264846332534
# Final cost : 0.3433264516153815
# Compute control for a deterministic system
# Cost in iteration 0: 0.3433264516153815
# Final cost : 0.343326446695888
# -----------------------------------------------
# 4 found better solution,  23

# %%
save(results_min)
