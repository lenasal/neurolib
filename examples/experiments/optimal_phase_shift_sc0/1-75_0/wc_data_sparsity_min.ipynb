# %%
import matplotlib.pyplot as plt
import numpy as np
import os, scipy, pickle
import matplotlib

if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')

# We import the model, stimuli, and the optimal control package
from neurolib.models.wc import WCModel
from neurolib.utils.stimulus import ZeroInput
from neurolib.optimal_control import oc_wc
from neurolib.optimal_control import cost_functions as cost_functions
from neurolib.optimal_control.oc_utils.plot_oc import plot_oc_singlenode
import scipy

# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# We define colors for later convenience
color_x = 'red'
color_y = 'blue'
fs_=16
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["axes.titlesize"] = fs_
plt.rcParams["axes.labelsize"] = fs_
matplotlib.rc('xtick', labelsize=fs_) 
matplotlib.rc('ytick', labelsize=fs_) 
plt.rc('legend',fontsize=fs_)

# %%
wc = WCModel()
wc.params.sigma_ou = 0.

dt = 0.1
wc.params.dt = dt

duration = 300.
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]
input = zero_control.copy()

wc.params["duration"] = duration
x_init = 0.44837171357165306
y_init = 0.414803863020717
wc.params["exc_init"] = np.array([[x_init]])
wc.params["inh_init"] = np.array([[y_init]])

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

wc.run()

peaks = scipy.signal.find_peaks(wc.exc[0,:])[0]
p_list = []
for i in range(3,len(peaks)):
    p_list.append(peaks[i]- peaks[i-1])
period = np.mean(p_list)*dt

wc.run()
init_min = [wc.exc[0,144], wc.inh[0,144]]

wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
wc.run()
target_min = np.concatenate((np.concatenate( (wc.params["exc_init"], wc.params["inh_init"]), axis=1)[:,:, np.newaxis], np.stack( (wc.exc, wc.inh), axis=1)), axis=2)

mins = scipy.signal.find_peaks(-wc.exc[0,:])[0]
print("minima = ", mins)

plt.plot(wc.t, wc.exc[0,:])
plt.vlines(40,-1,1)
plt.show()
# Out:
# minima =  [  94  247  400  553  706  858 1011 1164 1317 1470 1623 1776 1929 2082
#  2235 2388 2541 2694 2847]

# %%
control_mat = np.zeros( (wc.params.N, len(wc.state_vars)) )
control_mat[0,0] = 1.
control_mat[0,1] = 1.

prec_mat = np.zeros( (wc.params.N, len(wc.output_vars)) )
prec_mat[0,0] = 1.
prec_mat[0,1] = 1.

int0, int1 = 400, None

duration = 140.
wc.params["duration"] = duration
zero_input = ZeroInput().generate_input(duration=duration+dt, dt=dt)
zero_control =np.vstack( [zero_input, zero_input] )[np.newaxis,:,:]

wc.params["exc_ext"] = zero_input + 1.75
wc.params["inh_ext"] = zero_input

# %%
def increase_step_compute():
    wc_controlled.step = 1e-2
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e-1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(200)

    wc_controlled.step = 1e0
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(400)
    
    wc_controlled.step = 1e1
    wc_controlled.zero_step_encountered = False
    wc_controlled.optimize(1000)

    return

def get_values(results_dict, iw, ish, w1):
    results_dict["control"][iw][ish] = wc_controlled.control.copy()
    results_dict["state"][iw][ish] = wc_controlled.get_xs().copy()
    results_dict["total_cost"][iw][ish] = wc_controlled.cost_history[-1]

    wc_controlled.w_1D = 0.
    wc_controlled.simulate_forward()
    results_dict["precision_cost"][iw][ish] = wc_controlled.compute_total_cost()
    results_dict["L1_cost_weighted"][iw][ish] = ( results_dict["total_cost"][iw][ish] - results_dict["precision_cost"][iw][ish]) 
    results_dict["L1_cost_unweighted"][iw][ish] = results_dict["L1_cost_weighted"][iw][ish] / w1
    wc_controlled.w_1D = w1

    return

def get_period_index_target(period, i_sh, n_points, target_in):
    p = i_sh* 2.* np.pi / (n_points-1)
    index = np.round(p * period/ ( 2. * np.pi)/ dt).astype(int)
    target = target_in[:,:,index:index+np.round(1+duration/dt,1).astype(int)]

    return p, index, target

def getmodel(target_shift, w1, results_dict, iw, ish):
    wc_controlled = oc_wc.OcWc(wc, target=target_shift, w_p=1, w_2=0., w_1D=w1, print_array=[], precision_cost_interval=(int0,int1), control_matrix=control_mat, precision_matrix=prec_mat)

    if type(results_dict["control"][iw][ish]) != type(None):
        wc_controlled.control = results_dict["control"][iw][ish].copy()
        wc_controlled.update_input()
    wc_controlled.model.run()    

    return wc_controlled

# %%
n_points = 41
w_array = [0.25, 1., 4.]
none_array = [[None] * n_points, [None] * n_points, [None] * n_points ]
file_array = ["0-25_min_w1.png", "1_min_w1.png", "4_min_w1.png"]

results_min = dict([
    ('w1', w_array),
    ("total_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("initial_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("precision_cost", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_unweighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("L1_cost_weighted", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("control", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("state", [[None] * n_points, [None] * n_points, [None] * n_points ]),
    ("filename", file_array)
    ])

# %%
def save(results_dict):
    filehandler = open("results_min_w1.pickle","wb")
    pickle.dump(results_dict,filehandler)
    filehandler.close()

def read():
    filehandler = open("results_min_w1.pickle","rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

def readfile(file):
    filehandler = open(file,"rb")
    results_dict = pickle.load(filehandler)
    filehandler.close()

    return results_dict

# %%
results_min = read()
results_peak = readfile("results_peak_w1.pickle")

# %%
wc.params["exc_init"] = np.array([[init_min[0]]])
wc.params["inh_init"] = np.array([[init_min[1]]])
#results_peak = readfile("results_peak_w1.pickle")

ind_list = range(41)
#options = [False, False, False, False, False, False, False, False]
options = [True, True, False, False, True, True, False, False]

for k in range(1):

    for i_w in range(len(results_min["w1"])):

        w1 = results_min['w1'][i_w]

        for i_shift in range(n_points):
            
            if type(results_min["control"][i_w][i_shift]) != type(None):
                continue

            period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
            wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

            wc_controlled.step = 1e-3
            wc_controlled.optimize(1)

            results_min["initial_cost"][i_w][i_shift] = wc_controlled.cost_history[0]

            wc_controlled.step = 1e-3
            wc_controlled.optimize(200)

            if i_shift in [0, n_points-1]:
                get_values(results_min, i_w, i_shift, w1)
                continue

            increase_step_compute()
            get_values(results_min, i_w, i_shift, w1)

        if options[0]:
            print("----------------------------------------------- 0")
            for i_shift in range(2, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift-1].copy() * factor
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("0 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[1]:
            print("----------------------------------------------- 1")
            for i_shift in range(n_points-3, 0, -1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)

                factor = 0.8 + 0.5*np.random.random()
                
                wc_controlled.control = results_min["control"][i_w][i_shift+1].copy() * factor
                wc_controlled.update_input()
                wc_controlled.simulate_forward()

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("1 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[2]:
            print("----------------------------------------------- 2")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                            
                wc_controlled.control = results_min["control"][i_w-1][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("2 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[3]:
            print("----------------------------------------------- 3")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                if i_w != len(results_min["w1"]) - 1:
                    wc_controlled.control = results_min["control"][i_w+1][i_shift].copy() * (0.95*np.random.random()*0.1)
                else:
                    wc_controlled.control = results_min["control"][0][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("3 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[4]:
            print("----------------------------------------------- 4")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,0,int0+np.around(period/dt).astype(int):] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("4 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[5]:
            print("----------------------------------------------- 5")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                wc_controlled.control = results_min["control"][i_w][i_shift].copy() * (0.95*np.random.random()*0.1)
                wc_controlled.control[0,1,:] = 0.
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("5 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[6]:
            print("----------------------------------------------- 6")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-np.around(period/dt).astype(int)] = results_min["control"][i_w][i_shift].copy()[:,:,np.around(period/dt).astype(int):]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("6 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        if options[7]:
            print("----------------------------------------------- 7")
            for i_shift in range(1, n_points-1):

                if i_shift not in ind_list:
                    continue

                period_shift, index_shift, target_shift = get_period_index_target(period, i_shift, n_points, target_min)
                wc_controlled = getmodel(target_shift, w1, results_min, i_w, i_shift)
                
                control0 = np.zeros((results_min["control"][i_w][i_shift].copy().shape))
                control0[:,:,:-90] = results_peak["control"][i_w][i_shift].copy()[:,:,90:]
                wc_controlled.control = control0.copy()
                wc_controlled.update_input()

                wc_controlled.step = 1e-3
                wc_controlled.zero_step_encountered = False
                wc_controlled.optimize(200)

                increase_step_compute()

                if wc_controlled.cost_history[-1] < results_min["total_cost"][i_w][i_shift]:
                    print("-----------------------------------------------")
                    print("7 found better solution, ", i_shift)

                    get_values(results_min, i_w, i_shift, w1)

        save(results_min)
# Out:
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.0
# converged with vanishing gradient in iteration 1 with cost 0.0
# Final cost : 0.0
# Compute control for a deterministic system
# Cost in iteration 0: 0.06642231544552826
# Final cost : 0.05824534487153745
# Compute control for a deterministic system
# Cost in iteration 0: 0.05824534487153745
# Final cost : 0.013206219846982645
# Compute control for a deterministic system
# Cost in iteration 0: 0.013206219846982645
# Final cost : 0.012891426665836902
# Compute control for a deterministic system
# Cost in iteration 0: 0.012891426665836902
# Converged in iteration 19 with cost 0.012891394125127771 because of vanishing difference
# Final cost : 0.012891394125127771
# Compute control for a deterministic system
# Cost in iteration 0: 0.012891394124765795
# Converged in iteration 2 with cost 0.012891394122763985 because of vanishing difference
# Final cost : 0.012891394122763985
# Compute control for a deterministic system
# Cost in iteration 0: 0.012891394122763838
# Converged in iteration 1 with cost 0.012891394122763838 because of step counter
# Final cost : 0.012891394122763838
# Compute control for a deterministic system
# Cost in iteration 0: 0.261253597035157
# Final cost : 0.22886207054523147
# Compute control for a deterministic system
# Cost in iteration 0: 0.22886207054523147
# Final cost : 0.02947978452073146
# Compute control for a deterministic system
# Cost in iteration 0: 0.02947978452073146
# Converged in iteration 44 with cost 0.02899901053687337 because of step counter
# Final cost : 0.02899901053687337
# Compute control for a deterministic system
# Cost in iteration 0: 0.02899901053687337
# Converged in iteration 1 with cost 0.02899901053687337 because of step counter
# Final cost : 0.02899901053687337
# Compute control for a deterministic system
# Cost in iteration 0: 0.02899901053687337
# Converged in iteration 1 with cost 0.02899901053687337 because of step counter
# Final cost : 0.02899901053687337
# Compute control for a deterministic system
# Cost in iteration 0: 0.02899901053687337
# Converged in iteration 1 with cost 0.02899901053687337 because of step counter
# Final cost : 0.02899901053687337
# Compute control for a deterministic system
# Cost in iteration 0: 0.4847105258694425
# Final cost : 0.42692160863099216
# Compute control for a deterministic system
# Cost in iteration 0: 0.42692160863099216
# Final cost : 0.0428006724100598
# Compute control for a deterministic system
# Cost in iteration 0: 0.0428006724100598
# Converged in iteration 61 with cost 0.04185958796005751 because of step counter
# Final cost : 0.04185958796005751
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185958796005751
# Converged in iteration 1 with cost 0.04185958796005751 because of step counter
# Final cost : 0.04185958796005751
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185958796005751
# Converged in iteration 1 with cost 0.04185958796005751 because of step counter
# Final cost : 0.04185958796005751
# Compute control for a deterministic system
# Cost in iteration 0: 0.04185958796005751
# Converged in iteration 1 with cost 0.04185958796005751 because of step counter
# Final cost : 0.04185958796005751
# Compute control for a deterministic system
# Cost in iteration 0: 0.8732054858452513
# Final cost : 0.776935496340775
# Compute control for a deterministic system
# Cost in iteration 0: 0.776935496340775
# Final cost : 0.061543990165860096
# Compute control for a deterministic system
# Cost in iteration 0: 0.061543990165860096
# Converged in iteration 141 with cost 0.05923179385654166 because of step counter
# Final cost : 0.05923179385654166
# Compute control for a deterministic system
# Cost in iteration 0: 0.05923179385654166
# Converged in iteration 1 with cost 0.05923179385654166 because of step counter
# Final cost : 0.05923179385654166
# Compute control for a deterministic system
# Cost in iteration 0: 0.05923179385654166
# Converged in iteration 1 with cost 0.05923179385654166 because of step counter
# Final cost : 0.05923179385654166
# Compute control for a deterministic system
# Cost in iteration 0: 0.05923179385654166
# Converged in iteration 1 with cost 0.05923179385654166 because of step counter
# Final cost : 0.05923179385654166
# Compute control for a deterministic system
# Cost in iteration 0: 1.34935572118781
# Final cost : 1.2144024458942144
# Compute control for a deterministic system
# Cost in iteration 0: 1.2144024458942144
# Final cost : 0.08193757198740623
# Compute control for a deterministic system
# Cost in iteration 0: 0.08193757198740623
# Final cost : 0.07664297340939916
# Compute control for a deterministic system
# Cost in iteration 0: 0.07664297340939916
# Converged in iteration 102 with cost 0.07654093192376629 because of step counter
# Final cost : 0.07654093192376629
# Compute control for a deterministic system
# Cost in iteration 0: 0.07654093192376629
# Converged in iteration 1 with cost 0.07654093192376629 because of vanishing difference
# Final cost : 0.07654093192376629
# Compute control for a deterministic system
# Cost in iteration 0: 0.07654093192376625
# Converged in iteration 1 with cost 0.07654093192376625 because of step counter
# Final cost : 0.07654093192376625
# Compute control for a deterministic system
# Cost in iteration 0: 1.8956693568890082
# Final cost : 1.7261459479181749
# Compute control for a deterministic system
# Cost in iteration 0: 1.7261459479181749
# Final cost : 0.10422158182564761
# Compute control for a deterministic system
# Cost in iteration 0: 0.10422158182564761
# Final cost : 0.09371111908342487
# Compute control for a deterministic system
# Cost in iteration 0: 0.09371111908342487
# Final cost : 0.09296372639040165
# Compute control for a deterministic system
# Cost in iteration 0: 0.09296372639040165
# Converged in iteration 3 with cost 0.0929637263846919 because of vanishing difference
# Final cost : 0.0929637263846919
# Compute control for a deterministic system
# Cost in iteration 0: 0.09296372638459935
# Converged in iteration 1 with cost 0.09296372638459935 because of vanishing difference
# Final cost : 0.09296372638459935
# Compute control for a deterministic system
# Cost in iteration 0: 2.4949347607707626
# Final cost : 2.298012913496935
# Compute control for a deterministic system
# Cost in iteration 0: 2.298012913496935
# Final cost : 0.12871880647385658
# Compute control for a deterministic system
# Cost in iteration 0: 0.12871880647385658
# Final cost : 0.10752786136625231
# Compute control for a deterministic system
# Cost in iteration 0: 0.10752786136625231
# Converged in iteration 130 with cost 0.10463539430309256 because of vanishing difference
# Final cost : 0.10463539430309256
# Compute control for a deterministic system
# Cost in iteration 0: 0.10463539430288361
# Converged in iteration 2 with cost 0.10463539430111223 because of vanishing difference
# Final cost : 0.10463539430111223
# Compute control for a deterministic system
# Cost in iteration 0: 0.1046353943011121
# Converged in iteration 1 with cost 0.1046353943011121 because of step counter
# Final cost : 0.1046353943011121
# Compute control for a deterministic system
# Cost in iteration 0: 3.130095826657774
# Final cost : 2.9149739794306777
# Compute control for a deterministic system
# Cost in iteration 0: 2.9149739794306777
# Final cost : 0.15574947853634447
# Compute control for a deterministic system
# Cost in iteration 0: 0.15574947853634447
# Final cost : 0.126956279522847
# Compute control for a deterministic system
# Cost in iteration 0: 0.126956279522847
# Converged in iteration 84 with cost 0.11686287474126454 because of vanishing difference
# Final cost : 0.11686287474126454
# Compute control for a deterministic system
# Cost in iteration 0: 0.11686287474097855
# Converged in iteration 2 with cost 0.11686287473885994 because of vanishing difference
# Final cost : 0.11686287473885994
# Compute control for a deterministic system
# Cost in iteration 0: 0.11686287473885994
# Converged in iteration 1 with cost 0.11686287473885994 because of step counter
# Final cost : 0.11686287473885994
# Compute control for a deterministic system
# Cost in iteration 0: 3.619533046122486
# Final cost : 3.397546645265917
# Compute control for a deterministic system
# Cost in iteration 0: 3.397546645265917
# Final cost : 0.17771332293187564
# Compute control for a deterministic system
# Cost in iteration 0: 0.17771332293187564
# Final cost : 0.14318868847855856
# Compute control for a deterministic system
# Cost in iteration 0: 0.14318868847855856
# Converged in iteration 106 with cost 0.130054138964581 because of vanishing difference
# Final cost : 0.130054138964581
# Compute control for a deterministic system
# Cost in iteration 0: 0.1300541389643275
# Converged in iteration 2 with cost 0.13005413896232831 because of vanishing difference
# Final cost : 0.13005413896232831
# Compute control for a deterministic system
# Cost in iteration 0: 0.1300541389623283
# Converged in iteration 1 with cost 0.1300541389623283 because of step counter
# Final cost : 0.1300541389623283
# Compute control for a deterministic system
# Cost in iteration 0: 4.275136435831843
# Final cost : 4.053498966543703
# Compute control for a deterministic system
# Cost in iteration 0: 4.053498966543703
# Final cost : 0.20898282202925614
# Compute control for a deterministic system
# Cost in iteration 0: 0.20898282202925614
# Final cost : 0.1651890694755545
# Compute control for a deterministic system
# Cost in iteration 0: 0.1651890694755545
# Final cost : 0.14758189385148388
# Compute control for a deterministic system
# Cost in iteration 0: 0.14758189385148388
# Converged in iteration 55 with cost 0.14281304961225735 because of step counter
# Final cost : 0.14281304961225735
# Compute control for a deterministic system
# Cost in iteration 0: 0.14281304961225735
# Converged in iteration 1 with cost 0.14281304961225735 because of step counter
# Final cost : 0.14281304961225735
# Compute control for a deterministic system
# Cost in iteration 0: 4.918013713528368
# Final cost : 4.707511111729258
# Compute control for a deterministic system
# Cost in iteration 0: 4.707511111729258
# Final cost : 0.2425148095773646
# Compute control for a deterministic system
# Cost in iteration 0: 0.2425148095773646
# Final cost : 0.18743680861174594
# Compute control for a deterministic system
# Cost in iteration 0: 0.18743680861174594
# Final cost : 0.16237780556422127
# Compute control for a deterministic system
# Cost in iteration 0: 0.16237780556422127
# Converged in iteration 40 with cost 0.15874322466682253 because of step counter
# Final cost : 0.15874322466682253
# Compute control for a deterministic system
# Cost in iteration 0: 0.15874322466682253
# Converged in iteration 1 with cost 0.15874322466682253 because of step counter
# Final cost : 0.15874322466682253
# Compute control for a deterministic system
# Cost in iteration 0: 5.531335535221029
# Final cost : 5.3419573342751425
# Compute control for a deterministic system
# Cost in iteration 0: 5.3419573342751425
# Final cost : 0.27937924932007985
# Compute control for a deterministic system
# Cost in iteration 0: 0.27937924932007985
# Final cost : 0.21011435335315312
# Compute control for a deterministic system
# Cost in iteration 0: 0.21011435335315312
# Final cost : 0.17497494776526734
# Compute control for a deterministic system
# Cost in iteration 0: 0.17497494776526734
# Converged in iteration 46 with cost 0.17397485765543477 because of step counter
# Final cost : 0.17397485765543477
# Compute control for a deterministic system
# Cost in iteration 0: 0.17397485765543477
# Converged in iteration 1 with cost 0.17397485765543477 because of step counter
# Final cost : 0.17397485765543477
# Compute control for a deterministic system
# Cost in iteration 0: 6.099376063494085
# Final cost : 5.939344188576248
# Compute control for a deterministic system
# Cost in iteration 0: 5.939344188576248
# Final cost : 0.32190697172825833
# Compute control for a deterministic system
# Cost in iteration 0: 0.32190697172825833
# Final cost : 0.2336417433003946
# Compute control for a deterministic system
# Cost in iteration 0: 0.2336417433003946
# Converged in iteration 117 with cost 0.18774723355892967 because of step counter
# Final cost : 0.18774723355892967
# Compute control for a deterministic system
# Cost in iteration 0: 0.18774723355892967
# Converged in iteration 1 with cost 0.18774723355892967 because of step counter
# Final cost : 0.18774723355892967
# Compute control for a deterministic system
# Cost in iteration 0: 0.18774723355892967
# Converged in iteration 1 with cost 0.18774723355892967 because of step counter
# Final cost : 0.18774723355892967
# Compute control for a deterministic system
# Cost in iteration 0: 6.607743733501704
# Final cost : 6.48235750042462
# Compute control for a deterministic system
# Cost in iteration 0: 6.48235750042462
# Final cost : 0.3735248547265605
# Compute control for a deterministic system
# Cost in iteration 0: 0.3735248547265605
# Final cost : 0.2584699816911706
# Compute control for a deterministic system
# Cost in iteration 0: 0.2584699816911706
# Converged in iteration 119 with cost 0.19285535522199831 because of step counter
# Final cost : 0.19285535522199831
# Compute control for a deterministic system
# Cost in iteration 0: 0.19285535522199831
# Converged in iteration 1 with cost 0.19285535522199831 because of step counter
# Final cost : 0.19285535522199831
# Compute control for a deterministic system
# Cost in iteration 0: 0.19285535522199831
# Converged in iteration 1 with cost 0.19285535522199831 because of step counter
# Final cost : 0.19285535522199831
# Compute control for a deterministic system
# Cost in iteration 0: 6.942286684454658
# Final cost : 6.844023559691904
# Compute control for a deterministic system
# Cost in iteration 0: 6.844023559691904
# Final cost : 0.4209623885281884
# Compute control for a deterministic system
# Cost in iteration 0: 0.4209623885281884
# Final cost : 0.27819979278400925
# Compute control for a deterministic system
# Cost in iteration 0: 0.27819979278400925
# Converged in iteration 127 with cost 0.20169352044729147 because of step counter
# Final cost : 0.20169352044729147
# Compute control for a deterministic system
# Cost in iteration 0: 0.20169352044729147
# Converged in iteration 1 with cost 0.20169352044729147 because of step counter
# Final cost : 0.20169352044729147
# Compute control for a deterministic system
# Cost in iteration 0: 0.20169352044729147
# Converged in iteration 1 with cost 0.20169352044729147 because of step counter
# Final cost : 0.20169352044729147
# Compute control for a deterministic system
# Cost in iteration 0: 7.318035513223855
# Final cost : 7.254061414959642
# Compute control for a deterministic system
# Cost in iteration 0: 7.254061414959642
# Final cost : 0.5009388107703321
# Compute control for a deterministic system
# Cost in iteration 0: 0.5009388107703321
# Final cost : 0.3063058226856528
# Compute control for a deterministic system
# Cost in iteration 0: 0.3063058226856528
# Converged in iteration 164 with cost 0.21276252590497 because of step counter
# Final cost : 0.21276252590497
# Compute control for a deterministic system
# Cost in iteration 0: 0.21276252590497
# Converged in iteration 1 with cost 0.21276252590497 because of step counter
# Final cost : 0.21276252590497
# Compute control for a deterministic system
# Cost in iteration 0: 0.21276252590497
# Converged in iteration 1 with cost 0.21276252590497 because of step counter
# Final cost : 0.21276252590497
# Compute control for a deterministic system
# Cost in iteration 0: 7.607177157124875
# Final cost : 7.572003523619647
# Compute control for a deterministic system
# Cost in iteration 0: 7.572003523619647
# Final cost : 0.6088502070303148
# Compute control for a deterministic system
# Cost in iteration 0: 0.6088502070303148
# Final cost : 0.3368572749800858
# Compute control for a deterministic system
# Cost in iteration 0: 0.3368572749800858
# Converged in iteration 196 with cost 0.22493905040828768 because of step counter
# Final cost : 0.22493905040828768
# Compute control for a deterministic system
# Cost in iteration 0: 0.22493905040828768
# Converged in iteration 1 with cost 0.22493905040828768 because of step counter
# Final cost : 0.22493905040828768
# Compute control for a deterministic system
# Cost in iteration 0: 0.22493905040828768
# Converged in iteration 1 with cost 0.22493905040828768 because of step counter
# Final cost : 0.22493905040828768
# Compute control for a deterministic system
# Cost in iteration 0: 7.805880856532423
# Final cost : 7.7915563630857
# Compute control for a deterministic system
# Cost in iteration 0: 7.7915563630857
# Final cost : 0.7620879679803643
# Compute control for a deterministic system
# Cost in iteration 0: 0.7620879679803643
# Final cost : 0.37041617553012807
# Compute control for a deterministic system
# Cost in iteration 0: 0.37041617553012807
# Converged in iteration 193 with cost 0.23853733381344555 because of step counter
# Final cost : 0.23853733381344555
# Compute control for a deterministic system
# Cost in iteration 0: 0.23853733381344555
# Converged in iteration 1 with cost 0.23853733381344555 because of step counter
# Final cost : 0.23853733381344555
# Compute control for a deterministic system
# Cost in iteration 0: 0.23853733381344555
# Converged in iteration 1 with cost 0.23853733381344555 because of step counter
# Final cost : 0.23853733381344555
# Compute control for a deterministic system
# Cost in iteration 0: 7.912772516099077
# Final cost : 7.9101337996558065
# Compute control for a deterministic system
# Cost in iteration 0: 7.9101337996558065
# Final cost : 1.011483873131969
# Compute control for a deterministic system
# Cost in iteration 0: 1.011483873131969
# Final cost : 0.4080957894046248
# Compute control for a deterministic system
# Cost in iteration 0: 0.4080957894046248
# Final cost : 0.25307655121913025
# Compute control for a deterministic system
# Cost in iteration 0: 0.25307655121913025
# Converged in iteration 19 with cost 0.24855604723924327 because of step counter
# Final cost : 0.24855604723924327
# Compute control for a deterministic system
# Cost in iteration 0: 0.24855604723924327
# Converged in iteration 1 with cost 0.24855604723924327 because of step counter
# Final cost : 0.24855604723924327
# Compute control for a deterministic system
# Cost in iteration 0: 7.932784542804441
# Final cost : 7.932726781299846
# Compute control for a deterministic system
# Cost in iteration 0: 7.932726781299846
# Final cost : 1.8250019076350046
# Compute control for a deterministic system
# Cost in iteration 0: 1.8250019076350046
# Final cost : 0.4442015498406469
# Compute control for a deterministic system
# Cost in iteration 0: 0.4442015498406469
# Final cost : 0.26720876351229594
# Compute control for a deterministic system
# Cost in iteration 0: 0.26720876351229594
# Converged in iteration 22 with cost 0.260339348840969 because of step counter
# Final cost : 0.260339348840969
# Compute control for a deterministic system
# Cost in iteration 0: 0.260339348840969
# Converged in iteration 1 with cost 0.260339348840969 because of step counter
# Final cost : 0.260339348840969
# Compute control for a deterministic system
# Cost in iteration 0: 7.8801928538324395
# Final cost : 7.876339518303218
# Compute control for a deterministic system
# Cost in iteration 0: 7.876339518303218
# Final cost : 1.379020153004623
# Compute control for a deterministic system
# Cost in iteration 0: 1.379020153004623
# Final cost : 0.47548504865960106
# Compute control for a deterministic system
# Cost in iteration 0: 0.47548504865960106
# Final cost : 0.3104469658711338
# Compute control for a deterministic system
# Cost in iteration 0: 0.3104469658711338
# Converged in iteration 20 with cost 0.30524211215736696 because of vanishing difference
# Final cost : 0.30524211215736696
# Compute control for a deterministic system
# Cost in iteration 0: 0.30524211215736696
# Converged in iteration 4 with cost 0.3052421119590517 because of step counter
# Final cost : 0.3052421119590517
# Compute control for a deterministic system
# Cost in iteration 0: 7.73883555721649
# Final cost : 7.722164952732918
# Compute control for a deterministic system
# Cost in iteration 0: 7.722164952732918
# Final cost : 1.0695054216232878
# Compute control for a deterministic system
# Cost in iteration 0: 1.0695054216232878
# Final cost : 0.43242246176273924
# Compute control for a deterministic system
# Cost in iteration 0: 0.43242246176273924
# Final cost : 0.2881607726015005
# Compute control for a deterministic system
# Cost in iteration 0: 0.2881607726015005
# Converged in iteration 13 with cost 0.28423720532696617 because of step counter
# Final cost : 0.28423720532696617
# Compute control for a deterministic system
# Cost in iteration 0: 0.28423720532696617
# Converged in iteration 1 with cost 0.28423720532696617 because of step counter
# Final cost : 0.28423720532696617
# Compute control for a deterministic system
# Cost in iteration 0: 7.5116345217276805
# Final cost : 7.473724846643162
# Compute control for a deterministic system
# Cost in iteration 0: 7.473724846643162
# Final cost : 0.8530928147348095
# Compute control for a deterministic system
# Cost in iteration 0: 0.8530928147348095
# Final cost : 0.3918898448764518
# Compute control for a deterministic system
# Cost in iteration 0: 0.3918898448764518
# Final cost : 0.266904971540112
# Compute control for a deterministic system
# Cost in iteration 0: 0.266904971540112
# Converged in iteration 13 with cost 0.2638461735096085 because of step counter
# Final cost : 0.2638461735096085
# Compute control for a deterministic system
# Cost in iteration 0: 0.2638461735096085
# Converged in iteration 1 with cost 0.2638461735096085 because of step counter
# Final cost : 0.2638461735096085
# Compute control for a deterministic system
# Cost in iteration 0: 7.202609025587866
# Final cost : 7.136466742908958
# Compute control for a deterministic system
# Cost in iteration 0: 7.136466742908958
# Final cost : 0.6890049107598482
# Compute control for a deterministic system
# Cost in iteration 0: 0.6890049107598482
# Final cost : 0.3534902294159744
# Compute control for a deterministic system
# Cost in iteration 0: 0.3534902294159744
# Final cost : 0.2468745989542231
# Compute control for a deterministic system
# Cost in iteration 0: 0.2468745989542231
# Converged in iteration 2 with cost 0.24687458399288706 because of step counter
# Final cost : 0.24687458399288706
# Compute control for a deterministic system
# Cost in iteration 0: 0.24687458399288706
# Converged in iteration 1 with cost 0.24687458399288706 because of step counter
# Final cost : 0.24687458399288706
# Compute control for a deterministic system
# Cost in iteration 0: 6.817012540676686
# Final cost : 6.718057271196905
# Compute control for a deterministic system
# Cost in iteration 0: 6.718057271196905
# Final cost : 0.5613892116914292
# Compute control for a deterministic system
# Cost in iteration 0: 0.5613892116914292
# Final cost : 0.31703391884006393
# Compute control for a deterministic system
# Cost in iteration 0: 0.31703391884006393
# Converged in iteration 151 with cost 0.23164193882067483 because of step counter
# Final cost : 0.23164193882067483
# Compute control for a deterministic system
# Cost in iteration 0: 0.23164193882067483
# Converged in iteration 1 with cost 0.23164193882067483 because of step counter
# Final cost : 0.23164193882067483
# Compute control for a deterministic system
# Cost in iteration 0: 0.23164193882067483
# Converged in iteration 1 with cost 0.23164193882067483 because of step counter
# Final cost : 0.23164193882067483
# Compute control for a deterministic system
# Cost in iteration 0: 6.481525165656783
# Final cost : 6.356941995249633
# Compute control for a deterministic system
# Cost in iteration 0: 6.356941995249633
# Final cost : 0.483863176312217
# Compute control for a deterministic system
# Cost in iteration 0: 0.483863176312217
# Final cost : 0.29093394444157905
# Compute control for a deterministic system
# Cost in iteration 0: 0.29093394444157905
# Converged in iteration 117 with cost 0.22004742535499075 because of step counter
# Final cost : 0.22004742535499075
# Compute control for a deterministic system
# Cost in iteration 0: 0.22004742535499075
# Converged in iteration 1 with cost 0.22004742535499075 because of step counter
# Final cost : 0.22004742535499075
# Compute control for a deterministic system
# Cost in iteration 0: 0.22004742535499075
# Converged in iteration 1 with cost 0.22004742535499075 because of step counter
# Final cost : 0.22004742535499075
# Compute control for a deterministic system
# Cost in iteration 0: 5.978598409211414
# Final cost : 5.821433748568508
# Compute control for a deterministic system
# Cost in iteration 0: 5.821433748568508
# Final cost : 0.39924490614648167
# Compute control for a deterministic system
# Cost in iteration 0: 0.39924490614648167
# Final cost : 0.25784912001979743
# Compute control for a deterministic system
# Cost in iteration 0: 0.25784912001979743
# Converged in iteration 98 with cost 0.20234036096520658 because of step counter
# Final cost : 0.20234036096520658
# Compute control for a deterministic system
# Cost in iteration 0: 0.20234036096520658
# Converged in iteration 1 with cost 0.20234036096520658 because of step counter
# Final cost : 0.20234036096520658
# Compute control for a deterministic system
# Cost in iteration 0: 0.20234036096520658
# Converged in iteration 1 with cost 0.20234036096520658 because of step counter
# Final cost : 0.20234036096520658
# Compute control for a deterministic system
# Cost in iteration 0: 5.42021631640853
# Final cost : 5.235385675725622
# Compute control for a deterministic system
# Cost in iteration 0: 5.235385675725622
# Final cost : 0.33106113206631316
# Compute control for a deterministic system
# Cost in iteration 0: 0.33106113206631316
# Final cost : 0.2268050671759397
# Compute control for a deterministic system
# Cost in iteration 0: 0.2268050671759397
# Converged in iteration 86 with cost 0.18352720233746223 because of step counter
# Final cost : 0.18352720233746223
# Compute control for a deterministic system
# Cost in iteration 0: 0.18352720233746223
# Converged in iteration 1 with cost 0.18352720233746223 because of step counter
# Final cost : 0.18352720233746223
# Compute control for a deterministic system
# Cost in iteration 0: 0.18352720233746223
# Converged in iteration 1 with cost 0.18352720233746223 because of step counter
# Final cost : 0.18352720233746223
# Compute control for a deterministic system
# Cost in iteration 0: 4.818376428358929
# Final cost : 4.613504850797491
# Compute control for a deterministic system
# Cost in iteration 0: 4.613504850797491
# Final cost : 0.27502979419072443
# Compute control for a deterministic system
# Cost in iteration 0: 0.27502979419072443
# Final cost : 0.19783405782660002
# Compute control for a deterministic system
# Cost in iteration 0: 0.19783405782660002
# Converged in iteration 41 with cost 0.17157031774654025 because of step counter
# Final cost : 0.17157031774654025
# Compute control for a deterministic system
# Cost in iteration 0: 0.17157031774654025
# Converged in iteration 1 with cost 0.17157031774654025 because of step counter
# Final cost : 0.17157031774654025
# Compute control for a deterministic system
# Cost in iteration 0: 0.17157031774654025
# Converged in iteration 1 with cost 0.17157031774654025 because of step counter
# Final cost : 0.17157031774654025
# Compute control for a deterministic system
# Cost in iteration 0: 4.188797172822715
# Final cost : 3.9732907540996103
# Compute control for a deterministic system
# Cost in iteration 0: 3.9732907540996103
# Final cost : 0.22832337000385652
# Compute control for a deterministic system
# Cost in iteration 0: 0.22832337000385652
# Final cost : 0.17088851672105942
# Compute control for a deterministic system
# Cost in iteration 0: 0.17088851672105942
# Converged in iteration 51 with cost 0.15162895919373054 because of step counter
# Final cost : 0.15162895919373054
# Compute control for a deterministic system
# Cost in iteration 0: 0.15162895919373054
# Converged in iteration 1 with cost 0.15162895919373054 because of step counter
# Final cost : 0.15162895919373054
# Compute control for a deterministic system
# Cost in iteration 0: 0.15162895919373054
# Converged in iteration 1 with cost 0.15162895919373054 because of step counter
# Final cost : 0.15162895919373054
# Compute control for a deterministic system
# Cost in iteration 0: 3.5482774563853443
# Final cost : 3.332413909414766
# Compute control for a deterministic system
# Cost in iteration 0: 3.332413909414766
# Final cost : 0.18897676352420384
# Compute control for a deterministic system
# Cost in iteration 0: 0.18897676352420384
# Final cost : 0.14585494275501854
# Compute control for a deterministic system
# Cost in iteration 0: 0.14585494275501854
# Converged in iteration 41 with cost 0.13207531460773164 because of step counter
# Final cost : 0.13207531460773164
# Compute control for a deterministic system
# Cost in iteration 0: 0.13207531460773164
# Converged in iteration 1 with cost 0.13207531460773164 because of step counter
# Final cost : 0.13207531460773164
# Compute control for a deterministic system
# Cost in iteration 0: 0.13207531460773164
# Converged in iteration 1 with cost 0.13207531460773164 because of step counter
# Final cost : 0.13207531460773164
# Compute control for a deterministic system
# Cost in iteration 0: 3.070629805637319
# Final cost : 2.8613354079125655
# Compute control for a deterministic system
# Cost in iteration 0: 2.8613354079125655
# Final cost : 0.1633174936079
# Compute control for a deterministic system
# Cost in iteration 0: 0.1633174936079
# Final cost : 0.12824484571748068
# Compute control for a deterministic system
# Cost in iteration 0: 0.12824484571748068
# Converged in iteration 50 with cost 0.11821192454670548 because of step counter
# Final cost : 0.11821192454670548
# Compute control for a deterministic system
# Cost in iteration 0: 0.11821192454670548
# Converged in iteration 1 with cost 0.11821192454670548 because of step counter
# Final cost : 0.11821192454670548
# Compute control for a deterministic system
# Cost in iteration 0: 0.11821192454670548
# Converged in iteration 1 with cost 0.11821192454670548 because of step counter
# Final cost : 0.11821192454670548
# Compute control for a deterministic system
# Cost in iteration 0: 2.4503931036209057
# Final cost : 2.258590534294724
# Compute control for a deterministic system
# Cost in iteration 0: 2.258590534294724
# Final cost : 0.1331693559687444
# Compute control for a deterministic system
# Cost in iteration 0: 0.1331693559687444
# Final cost : 0.1070085493946757
# Compute control for a deterministic system
# Cost in iteration 0: 0.1070085493946757
# Converged in iteration 155 with cost 0.10121703839659175 because of step counter
# Final cost : 0.10121703839659175
# Compute control for a deterministic system
# Cost in iteration 0: 0.10121703839659175
# Converged in iteration 1 with cost 0.10121703839659175 because of step counter
# Final cost : 0.10121703839659175
# Compute control for a deterministic system
# Cost in iteration 0: 0.10121703839659175
# Converged in iteration 1 with cost 0.10121703839659175 because of step counter
# Final cost : 0.10121703839659175
# Compute control for a deterministic system
# Cost in iteration 0: 1.864002125400752
# Final cost : 1.6986437754121586
# Compute control for a deterministic system
# Cost in iteration 0: 1.6986437754121586
# Final cost : 0.10671168382126289
# Compute control for a deterministic system
# Cost in iteration 0: 0.10671168382126289
# Final cost : 0.09285595505807964
# Compute control for a deterministic system
# Cost in iteration 0: 0.09285595505807964
# Converged in iteration 170 with cost 0.09172828404566175 because of vanishing difference
# Final cost : 0.09172828404566175
# Compute control for a deterministic system
# Cost in iteration 0: 0.09172828404535603
# Converged in iteration 2 with cost 0.09172828404263857 because of vanishing difference
# Final cost : 0.09172828404263857
# Compute control for a deterministic system
# Cost in iteration 0: 0.09172828404263857
# Converged in iteration 1 with cost 0.09172828404263857 because of vanishing difference
# Final cost : 0.09172828404263857
# Compute control for a deterministic system
# Cost in iteration 0: 1.3280207533979287
# Final cost : 1.1961755699957166
# Compute control for a deterministic system
# Cost in iteration 0: 1.1961755699957166
# Final cost : 0.08316581812003564
# Compute control for a deterministic system
# Cost in iteration 0: 0.08316581812003564
# Final cost : 0.0760908439283898
# Compute control for a deterministic system
# Cost in iteration 0: 0.0760908439283898
# Converged in iteration 178 with cost 0.07577201208434071 because of vanishing difference
# Final cost : 0.07577201208434071
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577201208400247
# Converged in iteration 2 with cost 0.07577201208094685 because of vanishing difference
# Final cost : 0.07577201208094685
# Compute control for a deterministic system
# Cost in iteration 0: 0.07577201208088025
# Converged in iteration 2 with cost 0.07577201208035085 because of step counter
# Final cost : 0.07577201208035085
# Compute control for a deterministic system
# Cost in iteration 0: 0.8596435648612739
# Final cost : 0.7654683100891603
# Compute control for a deterministic system
# Cost in iteration 0: 0.7654683100891603
# Final cost : 0.061985390835175264
# Compute control for a deterministic system
# Cost in iteration 0: 0.061985390835175264
# Final cost : 0.05865899707990619
# Compute control for a deterministic system
# Cost in iteration 0: 0.05865899707990619
# Converged in iteration 137 with cost 0.05861394436703433 because of vanishing difference
# Final cost : 0.05861394436703433
# Compute control for a deterministic system
# Cost in iteration 0: 0.0586139443666779
# Converged in iteration 2 with cost 0.058613944363514595 because of vanishing difference
# Final cost : 0.058613944363514595
# Compute control for a deterministic system
# Cost in iteration 0: 0.058613944363514595
# Converged in iteration 1 with cost 0.058613944363514595 because of step counter
# Final cost : 0.058613944363514595
# Compute control for a deterministic system
# Cost in iteration 0: 0.5634092239571163
# Final cost : 0.4977456899933885
# Compute control for a deterministic system
# Cost in iteration 0: 0.4977456899933885
# Final cost : 0.0474222342860299
# Compute control for a deterministic system
# Cost in iteration 0: 0.0474222342860299
# Final cost : 0.04568851878349194
# Compute control for a deterministic system
# Cost in iteration 0: 0.04568851878349194
# Converged in iteration 49 with cost 0.04568582592547547 because of vanishing difference
# Final cost : 0.04568582592547547
# Compute control for a deterministic system
# Cost in iteration 0: 0.04568582592547536
# Converged in iteration 1 with cost 0.04568582592547536 because of vanishing difference
# Final cost : 0.04568582592547536
# Compute control for a deterministic system
# Cost in iteration 0: 0.04568582592547536
# Converged in iteration 1 with cost 0.04568582592547536 because of step counter
# Final cost : 0.04568582592547536
# Compute control for a deterministic system
# Cost in iteration 0: 0.2561152218553716
# Final cost : 0.2244910216952515
# Compute control for a deterministic system
# Cost in iteration 0: 0.2244910216952515
# Final cost : 0.029302604717945314
# Compute control for a deterministic system
# Cost in iteration 0: 0.029302604717945314
# Final cost : 0.028656585790082522
# Compute control for a deterministic system
# Cost in iteration 0: 0.028656585790082522
# Converged in iteration 53 with cost 0.028656163081120054 because of vanishing difference
# Final cost : 0.028656163081120054
# Compute control for a deterministic system
# Cost in iteration 0: 0.02865616308075407
# Converged in iteration 2 with cost 0.028656163077867353 because of step counter
# Final cost : 0.028656163077867353
# Compute control for a deterministic system
# Cost in iteration 0: 0.028656163077867353
# Converged in iteration 1 with cost 0.028656163077867353 because of step counter
# Final cost : 0.028656163077867353
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Final cost : 0.05627510273863542
# Compute control for a deterministic system
# Cost in iteration 0: 0.05627510273863542
# Final cost : 0.012928575621289051
# Compute control for a deterministic system
# Cost in iteration 0: 0.012928575621289051
# Final cost : 0.012563925711837991
# Compute control for a deterministic system
# Cost in iteration 0: 0.012563925711837991
# Converged in iteration 19 with cost 0.012563893533744687 because of vanishing difference
# Final cost : 0.012563893533744687
# Compute control for a deterministic system
# Cost in iteration 0: 0.012563893533514359
# Converged in iteration 2 with cost 0.012563893531867858 because of step counter
# Final cost : 0.012563893531867858
# Compute control for a deterministic system
# Cost in iteration 0: 0.012563893531867858
# Converged in iteration 1 with cost 0.012563893531867858 because of step counter
# Final cost : 0.012563893531867858
# Compute control for a deterministic system
# Cost in iteration 0: 1.8441860053179796e-05
# Converged in iteration 1 with cost 1.8441860053179796e-05 because of step counter
# Final cost : 1.8441860053179796e-05
# Compute control for a deterministic system
# Cost in iteration 0: 1.8441860053179796e-05
# Converged in iteration 1 with cost 1.8441860053179796e-05 because of step counter
# Final cost : 1.8441860053179796e-05
# ----------------------------------------------- 0
# Compute control for a deterministic system
# Cost in iteration 0: 0.07157752928633351
# Final cost : 0.02783931959704454
# Compute control for a deterministic system
# Cost in iteration 0: 0.02783931959704454
# Final cost : 0.02734083717697785
# Compute control for a deterministic system
# Cost in iteration 0: 0.02734083717697785
# Converged in iteration 45 with cost 0.0273392181648046 because of vanishing difference
# Final cost : 0.0273392181648046
# Compute control for a deterministic system
# Cost in iteration 0: 0.027339218164438947
# Converged in iteration 2 with cost 0.02733921816177831 because of step counter
# Final cost : 0.02733921816177831
# Compute control for a deterministic system
# Cost in iteration 0: 0.02733921816177831
# Converged in iteration 1 with cost 0.02733921816177831 because of step counter
# Final cost : 0.02733921816177831
# -----------------------------------------------
# 0 found better solution,  2
# Compute control for a deterministic system
# Cost in iteration 0: 0.10719037573051593
# Final cost : 0.039252787762341784
# Compute control for a deterministic system
# Cost in iteration 0: 0.039252787762341784
# Final cost : 0.038935779918062526
# Compute control for a deterministic system
# Cost in iteration 0: 0.038935779918062526
# Converged in iteration 64 with cost 0.03893427307617822 because of vanishing difference
# Final cost : 0.03893427307617822
# Compute control for a deterministic system
# Cost in iteration 0: 0.038934273075834414
# Converged in iteration 2 with cost 0.038934273073059536 because of step counter
# Final cost : 0.038934273073059536
# Compute control for a deterministic system
# Cost in iteration 0: 0.038934273073059536
# Converged in iteration 1 with cost 0.038934273073059536 because of step counter
# Final cost : 0.038934273073059536
# -----------------------------------------------
# 0 found better solution,  3
# Compute control for a deterministic system
# Cost in iteration 0: 0.07259766349320046
# Final cost : 0.054914815579275855
# Compute control for a deterministic system
# Cost in iteration 0: 0.054914815579275855
# Final cost : 0.05449197317844397
# Compute control for a deterministic system
# Cost in iteration 0: 0.05449197317844397
# Converged in iteration 95 with cost 0.05447941207884454 because of vanishing difference
# Final cost : 0.05447941207884454
# Compute control for a deterministic system
# Cost in iteration 0: 0.05447941207849625
# Converged in iteration 2 with cost 0.05447941207554129 because of vanishing difference
# Final cost : 0.05447941207554129
# Compute control for a deterministic system
# Cost in iteration 0: 0.05447941207554127
# Converged in iteration 1 with cost 0.05447941207554127 because of step counter
# Final cost : 0.05447941207554127
# -----------------------------------------------
# 0 found better solution,  4
# Compute control for a deterministic system
# Cost in iteration 0: 0.0747690467008534
# Converged in iteration 65 with cost 0.07217041884280483 because of step counter
# Final cost : 0.07217041884280483
# Compute control for a deterministic system
# Cost in iteration 0: 0.07217041884280483
# Converged in iteration 1 with cost 0.07217041884280483 because of step counter
# Final cost : 0.07217041884280483
# Compute control for a deterministic system
# Cost in iteration 0: 0.07217041884280483
# Converged in iteration 1 with cost 0.07217041884280483 because of step counter
# Final cost : 0.07217041884280483
# Compute control for a deterministic system
# Cost in iteration 0: 0.07217041884280483
# Converged in iteration 1 with cost 0.07217041884280483 because of step counter
# Final cost : 0.07217041884280483
# Compute control for a deterministic system
# Cost in iteration 0: 0.07217041884280483
# Converged in iteration 1 with cost 0.07217041884280483 because of step counter
# Final cost : 0.07217041884280483
# -----------------------------------------------
# 0 found better solution,  5
# Compute control for a deterministic system
# Cost in iteration 0: 0.09346913118991715
# Final cost : 0.09216672751758744
# Compute control for a deterministic system
# Cost in iteration 0: 0.09216672751758744
# Final cost : 0.08464564448880013
# Compute control for a deterministic system
# Cost in iteration 0: 0.08464564448880013
# Converged in iteration 14 with cost 0.08348327968568216 because of step counter
# Final cost : 0.08348327968568216
# Compute control for a deterministic system
# Cost in iteration 0: 0.08348327968568216
# Converged in iteration 1 with cost 0.08348327968568216 because of step counter
# Final cost : 0.08348327968568216
# Compute control for a deterministic system
# Cost in iteration 0: 0.08348327968568216
# Converged in iteration 1 with cost 0.08348327968568216 because of step counter
# Final cost : 0.08348327968568216
# -----------------------------------------------
# 0 found better solution,  6
# Compute control for a deterministic system
# Cost in iteration 0: 0.30897694951765453
# Final cost : 0.10036951396435274
# Compute control for a deterministic system
# Cost in iteration 0: 0.10036951396435274
# Converged in iteration 17 with cost 0.10014335787886205 because of step counter
# Final cost : 0.10014335787886205
# Compute control for a deterministic system
# Cost in iteration 0: 0.10014335787886205
# Converged in iteration 1 with cost 0.10014335787886205 because of step counter
# Final cost : 0.10014335787886205
# Compute control for a deterministic system
# Cost in iteration 0: 0.10014335787886205
# Converged in iteration 1 with cost 0.10014335787886205 because of step counter
# Final cost : 0.10014335787886205
# Compute control for a deterministic system
# Cost in iteration 0: 0.10014335787886205
# Converged in iteration 1 with cost 0.10014335787886205 because of step counter
# Final cost : 0.10014335787886205
# -----------------------------------------------
# 0 found better solution,  7
# Compute control for a deterministic system
# Cost in iteration 0: 0.18629647619717235
# Final cost : 0.11863418166169694
# Compute control for a deterministic system
# Cost in iteration 0: 0.11863418166169694
# Converged in iteration 22 with cost 0.1183989870729043 because of step counter
# Final cost : 0.1183989870729043
# Compute control for a deterministic system
# Cost in iteration 0: 0.1183989870729043
# Converged in iteration 1 with cost 0.1183989870729043 because of step counter
# Final cost : 0.1183989870729043
# Compute control for a deterministic system
# Cost in iteration 0: 0.1183989870729043
# Converged in iteration 1 with cost 0.1183989870729043 because of step counter
# Final cost : 0.1183989870729043
# Compute control for a deterministic system
# Cost in iteration 0: 0.1183989870729043
# Converged in iteration 1 with cost 0.1183989870729043 because of step counter
# Final cost : 0.1183989870729043
# Compute control for a deterministic system
# Cost in iteration 0: 0.2895696773297627
# Final cost : 0.12950975982508678
# Compute control for a deterministic system
# Cost in iteration 0: 0.12950975982508678
# Converged in iteration 20 with cost 0.12919916614394425 because of step counter
# Final cost : 0.12919916614394425
# Compute control for a deterministic system
# Cost in iteration 0: 0.12919916614394425
# Converged in iteration 1 with cost 0.12919916614394425 because of step counter
# Final cost : 0.12919916614394425
# Compute control for a deterministic system
# Cost in iteration 0: 0.12919916614394425
# Converged in iteration 1 with cost 0.12919916614394425 because of step counter
# Final cost : 0.12919916614394425
# Compute control for a deterministic system
# Cost in iteration 0: 0.12919916614394425
# Converged in iteration 1 with cost 0.12919916614394425 because of step counter
# Final cost : 0.12919916614394425
# -----------------------------------------------
# 0 found better solution,  9
# Compute control for a deterministic system
# Cost in iteration 0: 0.2688635976531418
# Final cost : 0.1478824221738221
# Compute control for a deterministic system
# Cost in iteration 0: 0.1478824221738221
# Converged in iteration 29 with cost 0.14743508172467065 because of step counter
# Final cost : 0.14743508172467065
# Compute control for a deterministic system
# Cost in iteration 0: 0.14743508172467065
# Converged in iteration 1 with cost 0.14743508172467065 because of step counter
# Final cost : 0.14743508172467065
# Compute control for a deterministic system
# Cost in iteration 0: 0.14743508172467065
# Converged in iteration 1 with cost 0.14743508172467065 because of step counter
# Final cost : 0.14743508172467065
# Compute control for a deterministic system
# Cost in iteration 0: 0.14743508172467065
# Converged in iteration 1 with cost 0.14743508172467065 because of step counter
# Final cost : 0.14743508172467065
# Compute control for a deterministic system
# Cost in iteration 0: 0.21146835508869355
# Final cost : 0.16110460727105544
# Compute control for a deterministic system
# Cost in iteration 0: 0.16110460727105544
# Converged in iteration 35 with cost 0.1608943966004984 because of step counter
# Final cost : 0.1608943966004984
# Compute control for a deterministic system
# Cost in iteration 0: 0.1608943966004984
# Converged in iteration 1 with cost 0.1608943966004984 because of step counter
# Final cost : 0.1608943966004984
# Compute control for a deterministic system
# Cost in iteration 0: 0.1608943966004984
# Converged in iteration 1 with cost 0.1608943966004984 because of step counter
# Final cost : 0.1608943966004984
# Compute control for a deterministic system
# Cost in iteration 0: 0.1608943966004984
# Converged in iteration 1 with cost 0.1608943966004984 because of step counter
# Final cost : 0.1608943966004984
# Compute control for a deterministic system
# Cost in iteration 0: 0.3634806730723603
# Final cost : 0.17590072579781446
# Compute control for a deterministic system
# Cost in iteration 0: 0.17590072579781446
# Converged in iteration 30 with cost 0.1752134760178642 because of step counter
# Final cost : 0.1752134760178642
# Compute control for a deterministic system
# Cost in iteration 0: 0.1752134760178642
# Converged in iteration 1 with cost 0.1752134760178642 because of step counter
# Final cost : 0.1752134760178642
# Compute control for a deterministic system
# Cost in iteration 0: 0.1752134760178642
# Converged in iteration 1 with cost 0.1752134760178642 because of step counter
# Final cost : 0.1752134760178642
# Compute control for a deterministic system
# Cost in iteration 0: 0.1752134760178642
# Converged in iteration 1 with cost 0.1752134760178642 because of step counter
# Final cost : 0.1752134760178642
# Compute control for a deterministic system
# Cost in iteration 0: 0.2189478600643415
# Final cost : 0.19756456395243377
# Compute control for a deterministic system
# Cost in iteration 0: 0.19756456395243377
# Final cost : 0.19038840494901113
# Compute control for a deterministic system
# Cost in iteration 0: 0.19038840494901113
# Converged in iteration 133 with cost 0.1802167551713812 because of step counter
# Final cost : 0.1802167551713812
# Compute control for a deterministic system
# Cost in iteration 0: 0.1802167551713812
# Converged in iteration 1 with cost 0.1802167551713812 because of step counter
# Final cost : 0.1802167551713812
# Compute control for a deterministic system
# Cost in iteration 0: 0.1802167551713812
# Converged in iteration 1 with cost 0.1802167551713812 because of step counter
# Final cost : 0.1802167551713812
# -----------------------------------------------
# 0 found better solution,  13
# Compute control for a deterministic system
# Cost in iteration 0: 0.2803830461204472
# ...
# Converged in iteration 1 with cost 7.499409285917454 because of step counter
# Final cost : 7.499409285917454
# Compute control for a deterministic system
# Cost in iteration 0: 7.499409285917454
# Converged in iteration 1 with cost 7.499409285917454 because of step counter
# Final cost : 7.499409285917454
# Compute control for a deterministic system
# Cost in iteration 0: 7.499409285917454
# Converged in iteration 1 with cost 7.499409285917454 because of step counter
# Final cost : 7.499409285917454
# Compute control for a deterministic system
# Cost in iteration 0: 7.499409285917454
# Converged in iteration 1 with cost 7.499409285917454 because of step counter
# Final cost : 7.499409285917454
# Compute control for a deterministic system
# Cost in iteration 0: 7.16854909483796
# Converged in iteration 1 with cost 7.16854909483796 because of step counter
# Final cost : 7.16854909483796
# Compute control for a deterministic system
# Cost in iteration 0: 7.16854909483796
# Converged in iteration 1 with cost 7.16854909483796 because of step counter
# Final cost : 7.16854909483796
# Compute control for a deterministic system
# Cost in iteration 0: 7.16854909483796
# Converged in iteration 1 with cost 7.16854909483796 because of step counter
# Final cost : 7.16854909483796
# Compute control for a deterministic system
# Cost in iteration 0: 7.16854909483796
# Converged in iteration 1 with cost 7.16854909483796 because of step counter
# Final cost : 7.16854909483796
# Compute control for a deterministic system
# Cost in iteration 0: 7.16854909483796
# Converged in iteration 1 with cost 7.16854909483796 because of step counter
# Final cost : 7.16854909483796
# Compute control for a deterministic system
# Cost in iteration 0: 6.814610402296282
# Converged in iteration 1 with cost 6.814610402296282 because of step counter
# Final cost : 6.814610402296282
# Compute control for a deterministic system
# Cost in iteration 0: 6.814610402296282
# Converged in iteration 1 with cost 6.814610402296282 because of step counter
# Final cost : 6.814610402296282
# Compute control for a deterministic system
# Cost in iteration 0: 6.814610402296282
# Converged in iteration 1 with cost 6.814610402296282 because of step counter
# Final cost : 6.814610402296282
# Compute control for a deterministic system
# Cost in iteration 0: 6.814610402296282
# Converged in iteration 1 with cost 6.814610402296282 because of step counter
# Final cost : 6.814610402296282
# Compute control for a deterministic system
# Cost in iteration 0: 6.814610402296282
# Converged in iteration 1 with cost 6.814610402296282 because of step counter
# Final cost : 6.814610402296282
# Compute control for a deterministic system
# Cost in iteration 0: 6.416641176077037
# Converged in iteration 1 with cost 6.416641176077037 because of step counter
# Final cost : 6.416641176077037
# Compute control for a deterministic system
# Cost in iteration 0: 6.416641176077037
# Converged in iteration 1 with cost 6.416641176077037 because of step counter
# Final cost : 6.416641176077037
# Compute control for a deterministic system
# Cost in iteration 0: 6.416641176077037
# Converged in iteration 1 with cost 6.416641176077037 because of step counter
# Final cost : 6.416641176077037
# Compute control for a deterministic system
# Cost in iteration 0: 6.416641176077037
# Converged in iteration 1 with cost 6.416641176077037 because of step counter
# Final cost : 6.416641176077037
# Compute control for a deterministic system
# Cost in iteration 0: 6.416641176077037
# Converged in iteration 1 with cost 6.416641176077037 because of step counter
# Final cost : 6.416641176077037
# Compute control for a deterministic system
# Cost in iteration 0: 5.859943873947752
# Converged in iteration 2 with cost 5.859280688470345 because of step counter
# Final cost : 5.859280688470345
# Compute control for a deterministic system
# Cost in iteration 0: 5.859280688470345
# Converged in iteration 1 with cost 5.859280688470345 because of step counter
# Final cost : 5.859280688470345
# Compute control for a deterministic system
# Cost in iteration 0: 5.859280688470345
# Converged in iteration 1 with cost 5.859280688470345 because of step counter
# Final cost : 5.859280688470345
# Compute control for a deterministic system
# Cost in iteration 0: 5.859280688470345
# Converged in iteration 1 with cost 5.859280688470345 because of step counter
# Final cost : 5.859280688470345
# Compute control for a deterministic system
# Cost in iteration 0: 5.859280688470345
# Converged in iteration 1 with cost 5.859280688470345 because of step counter
# Final cost : 5.859280688470345
# Compute control for a deterministic system
# Cost in iteration 0: 5.355179958841924
# Converged in iteration 2 with cost 5.353377616681771 because of step counter
# Final cost : 5.353377616681771
# Compute control for a deterministic system
# Cost in iteration 0: 5.353377616681771
# Converged in iteration 1 with cost 5.353377616681771 because of step counter
# Final cost : 5.353377616681771
# Compute control for a deterministic system
# Cost in iteration 0: 5.353377616681771
# Converged in iteration 1 with cost 5.353377616681771 because of step counter
# Final cost : 5.353377616681771
# Compute control for a deterministic system
# Cost in iteration 0: 5.353377616681771
# Converged in iteration 1 with cost 5.353377616681771 because of step counter
# Final cost : 5.353377616681771
# Compute control for a deterministic system
# Cost in iteration 0: 5.353377616681771
# Converged in iteration 1 with cost 5.353377616681771 because of step counter
# Final cost : 5.353377616681771
# Compute control for a deterministic system
# Cost in iteration 0: 4.634348700992573
# Converged in iteration 2 with cost 4.631107244451826 because of step counter
# Final cost : 4.631107244451826
# Compute control for a deterministic system
# Cost in iteration 0: 4.631107244451826
# Converged in iteration 1 with cost 4.631107244451826 because of step counter
# Final cost : 4.631107244451826
# Compute control for a deterministic system
# Cost in iteration 0: 4.631107244451826
# Converged in iteration 1 with cost 4.631107244451826 because of step counter
# Final cost : 4.631107244451826
# Compute control for a deterministic system
# Cost in iteration 0: 4.631107244451826
# Converged in iteration 1 with cost 4.631107244451826 because of step counter
# Final cost : 4.631107244451826
# Compute control for a deterministic system
# Cost in iteration 0: 4.631107244451826
# Converged in iteration 1 with cost 4.631107244451826 because of step counter
# Final cost : 4.631107244451826
# Compute control for a deterministic system
# Cost in iteration 0: 4.154164903923072
# Converged in iteration 2 with cost 4.150748755109497 because of step counter
# Final cost : 4.150748755109497
# Compute control for a deterministic system
# Cost in iteration 0: 4.150748755109497
# Converged in iteration 1 with cost 4.150748755109497 because of step counter
# Final cost : 4.150748755109497
# Compute control for a deterministic system
# Cost in iteration 0: 4.150748755109497
# Converged in iteration 1 with cost 4.150748755109497 because of step counter
# Final cost : 4.150748755109497
# Compute control for a deterministic system
# Cost in iteration 0: 4.150748755109497
# Converged in iteration 1 with cost 4.150748755109497 because of step counter
# Final cost : 4.150748755109497
# Compute control for a deterministic system
# Cost in iteration 0: 4.150748755109497
# Converged in iteration 1 with cost 4.150748755109497 because of step counter
# Final cost : 4.150748755109497
# Compute control for a deterministic system
# Cost in iteration 0: 3.2935747884133995
# Converged in iteration 2 with cost 3.29015387497956 because of step counter
# Final cost : 3.29015387497956
# Compute control for a deterministic system
# Cost in iteration 0: 3.29015387497956
# Converged in iteration 1 with cost 3.29015387497956 because of step counter
# Final cost : 3.29015387497956
# Compute control for a deterministic system
# Cost in iteration 0: 3.29015387497956
# Converged in iteration 1 with cost 3.29015387497956 because of step counter
# Final cost : 3.29015387497956
# Compute control for a deterministic system
# Cost in iteration 0: 3.29015387497956
# Converged in iteration 1 with cost 3.29015387497956 because of step counter
# Final cost : 3.29015387497956
# Compute control for a deterministic system
# Cost in iteration 0: 3.29015387497956
# Converged in iteration 1 with cost 3.29015387497956 because of step counter
# Final cost : 3.29015387497956
# Compute control for a deterministic system
# Cost in iteration 0: 2.908349829262826
# Converged in iteration 2 with cost 2.9054183350178024 because of step counter
# Final cost : 2.9054183350178024
# Compute control for a deterministic system
# Cost in iteration 0: 2.9054183350178024
# Converged in iteration 1 with cost 2.9054183350178024 because of step counter
# Final cost : 2.9054183350178024
# Compute control for a deterministic system
# Cost in iteration 0: 2.9054183350178024
# Converged in iteration 1 with cost 2.9054183350178024 because of step counter
# Final cost : 2.9054183350178024
# Compute control for a deterministic system
# Cost in iteration 0: 2.9054183350178024
# Converged in iteration 1 with cost 2.9054183350178024 because of step counter
# Final cost : 2.9054183350178024
# Compute control for a deterministic system
# Cost in iteration 0: 2.9054183350178024
# Converged in iteration 1 with cost 2.9054183350178024 because of step counter
# Final cost : 2.9054183350178024
# Compute control for a deterministic system
# Cost in iteration 0: 2.410229220634268
# Converged in iteration 2 with cost 2.4081851658593854 because of step counter
# Final cost : 2.4081851658593854
# Compute control for a deterministic system
# Cost in iteration 0: 2.4081851658593854
# Converged in iteration 1 with cost 2.4081851658593854 because of step counter
# Final cost : 2.4081851658593854
# Compute control for a deterministic system
# Cost in iteration 0: 2.4081851658593854
# Converged in iteration 1 with cost 2.4081851658593854 because of step counter
# Final cost : 2.4081851658593854
# Compute control for a deterministic system
# Cost in iteration 0: 2.4081851658593854
# Converged in iteration 1 with cost 2.4081851658593854 because of step counter
# Final cost : 2.4081851658593854
# Compute control for a deterministic system
# Cost in iteration 0: 2.4081851658593854
# Converged in iteration 1 with cost 2.4081851658593854 because of step counter
# Final cost : 2.4081851658593854
# Compute control for a deterministic system
# Cost in iteration 0: 1.7981903642122459
# Converged in iteration 2 with cost 1.7977198698501335 because of step counter
# Final cost : 1.7977198698501335
# Compute control for a deterministic system
# Cost in iteration 0: 1.7977198698501335
# Converged in iteration 1 with cost 1.7977198698501335 because of step counter
# Final cost : 1.7977198698501335
# Compute control for a deterministic system
# Cost in iteration 0: 1.7977198698501335
# Converged in iteration 1 with cost 1.7977198698501335 because of step counter
# Final cost : 1.7977198698501335
# Compute control for a deterministic system
# Cost in iteration 0: 1.7977198698501335
# Converged in iteration 1 with cost 1.7977198698501335 because of step counter
# Final cost : 1.7977198698501335
# Compute control for a deterministic system
# Cost in iteration 0: 1.7977198698501335
# Converged in iteration 1 with cost 1.7977198698501335 because of step counter
# Final cost : 1.7977198698501335
# Compute control for a deterministic system
# Cost in iteration 0: 1.3151798624529731
# Converged in iteration 1 with cost 1.3151798624529731 because of step counter
# Final cost : 1.3151798624529731
# Compute control for a deterministic system
# Cost in iteration 0: 1.3151798624529731
# Converged in iteration 1 with cost 1.3151798624529731 because of step counter
# Final cost : 1.3151798624529731
# Compute control for a deterministic system
# Cost in iteration 0: 1.3151798624529731
# Converged in iteration 1 with cost 1.3151798624529731 because of step counter
# Final cost : 1.3151798624529731
# Compute control for a deterministic system
# Cost in iteration 0: 1.3151798624529731
# Converged in iteration 1 with cost 1.3151798624529731 because of step counter
# Final cost : 1.3151798624529731
# Compute control for a deterministic system
# Cost in iteration 0: 1.3151798624529731
# Converged in iteration 1 with cost 1.3151798624529731 because of step counter
# Final cost : 1.3151798624529731
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584935672996552
# Converged in iteration 1 with cost 0.8584935672996552 because of step counter
# Final cost : 0.8584935672996552
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584935672996552
# Converged in iteration 1 with cost 0.8584935672996552 because of step counter
# Final cost : 0.8584935672996552
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584935672996552
# Converged in iteration 1 with cost 0.8584935672996552 because of step counter
# Final cost : 0.8584935672996552
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584935672996552
# Converged in iteration 1 with cost 0.8584935672996552 because of step counter
# Final cost : 0.8584935672996552
# Compute control for a deterministic system
# Cost in iteration 0: 0.8584935672996552
# Converged in iteration 1 with cost 0.8584935672996552 because of step counter
# Final cost : 0.8584935672996552
# Compute control for a deterministic system
# Cost in iteration 0: 0.5568795489245197
# Converged in iteration 1 with cost 0.5568795489245197 because of step counter
# Final cost : 0.5568795489245197
# Compute control for a deterministic system
# Cost in iteration 0: 0.5568795489245197
# Converged in iteration 1 with cost 0.5568795489245197 because of step counter
# Final cost : 0.5568795489245197
# Compute control for a deterministic system
# Cost in iteration 0: 0.5568795489245197
# Converged in iteration 1 with cost 0.5568795489245197 because of step counter
# Final cost : 0.5568795489245197
# Compute control for a deterministic system
# Cost in iteration 0: 0.5568795489245197
# Converged in iteration 1 with cost 0.5568795489245197 because of step counter
# Final cost : 0.5568795489245197
# Compute control for a deterministic system
# Cost in iteration 0: 0.5568795489245197
# Converged in iteration 1 with cost 0.5568795489245197 because of step counter
# Final cost : 0.5568795489245197
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533339988289812
# Converged in iteration 1 with cost 0.2533339988289812 because of step counter
# Final cost : 0.2533339988289812
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533339988289812
# Converged in iteration 1 with cost 0.2533339988289812 because of step counter
# Final cost : 0.2533339988289812
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533339988289812
# Converged in iteration 1 with cost 0.2533339988289812 because of step counter
# Final cost : 0.2533339988289812
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533339988289812
# Converged in iteration 1 with cost 0.2533339988289812 because of step counter
# Final cost : 0.2533339988289812
# Compute control for a deterministic system
# Cost in iteration 0: 0.2533339988289812
# Converged in iteration 1 with cost 0.2533339988289812 because of step counter
# Final cost : 0.2533339988289812
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Converged in iteration 1 with cost 0.06414001162569853 because of step counter
# Final cost : 0.06414001162569853
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Converged in iteration 1 with cost 0.06414001162569853 because of step counter
# Final cost : 0.06414001162569853
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Converged in iteration 1 with cost 0.06414001162569853 because of step counter
# Final cost : 0.06414001162569853
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Converged in iteration 1 with cost 0.06414001162569853 because of step counter
# Final cost : 0.06414001162569853
# Compute control for a deterministic system
# Cost in iteration 0: 0.06414001162569853
# Converged in iteration 1 with cost 0.06414001162569853 because of step counter
# Final cost : 0.06414001162569853

# %%
save(results_min)
