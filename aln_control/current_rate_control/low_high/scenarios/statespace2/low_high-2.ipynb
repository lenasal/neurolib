# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy
import pickle
import random
import seaborn as sns
import matplotlib.ticker as ticker


from neurolib.models.aln import ALNModel
import neurolib.utils.functions as func
from neurolib.utils import costFunctions as cost
from neurolib.utils import plotFunctions as plotFunc

np.set_printoptions(precision=4)

font = {
    'family' : 'sans',
    'weight' : 'normal',
    'size'   : 14
       }

matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 
matplotlib.rc('grid', c='0.5', ls='-', lw=0.5)  # solid gray grid lines
matplotlib.rc('savefig', dpi=300)       # higher res outputs
#print (matplotlib.rcParams)
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

aln.params.mufe_init = 0 * np.random.uniform(0, 1, (N,))  # mV/ms
aln.params.mufi_init = 0 * np.random.uniform(0, 1, (N,))  # mV/ms
aln.params.seem_init = 0. * np.random.uniform(0, 1, (N,))
aln.params.seim_init = 0. * np.random.uniform(0, 1, (N,))
aln.params.seev_init = 0.0 * np.random.uniform(0, 1, (N,))
aln.params.seiv_init = 0.0 * np.random.uniform(0, 1, (N,))
aln.params.siim_init = 0. * np.random.uniform(0, 1, (N,))
aln.params.siem_init = 0. * np.random.uniform(0, 1, (N,))
aln.params.siiv_init = 0.0 * np.random.uniform(0, 1, (N,))
aln.params.siev_init = 0.0 * np.random.uniform(0, 1, (N,))
aln.params.rates_exc_init = 0.0 * np.random.uniform(0, 1, (N, 1))
aln.params.rates_inh_init = 0.0 * np.random.uniform(0, 1, (N, 1))
aln.params.IA_init = 0.0 * np.random.uniform(0, 1, (N, 1))  # pA

aln.params.sigma_ou = 0.
aln.params.mue_ou = np.array( [0.] )
aln.params.mui_ou = np.array( [0.] )

state_vars = aln.state_vars
init_vars = aln.init_vars
##############################################################

def step_control(maxI_ = 1.):
    control_ = aln.getZeroControl()
    for i_time in range(control_.shape[2]):
        if ( float(i_time/control_.shape[2]) < 0.1):
            control_[:,:1,i_time] = - maxI_
        elif ( float(i_time/control_.shape[2]) > 0.5 and float(i_time/control_.shape[2]) < 0.6 ):
            control_[:,:1,i_time] = maxI_
    return control_
##############################################################

def setinit(init_vars_):
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if aln.params[init_vars[iv]].ndim == 2:
                    aln.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    aln.params[init_vars[iv]][0] = init_vars_[sv]
##############################################################
                    
def setrandomcontrol(control_, max_cntrl_, min_cntrl_, cntrl_vars_):
    for n in range(control_.shape[0]):
        for v in range(control_.shape[1]):
            if v in cntrl_vars_:
                mean_cntrl = np.mean( [max_cntrl_[v], min_cntrl_[v]] )
                mean_abs_cntrl = np.mean( [max_cntrl_[v], np.abs(min_cntrl_[v])] )
                control_[n,v,1] = mean_cntrl
                for t in range(2, control_.shape[2]-1):
                    control_[n,v,t] = control_[n,v,t-1] + 0.01 * mean_abs_cntrl * random.uniform(-1, 1)
                    
    return control_
##############################################################
                    
max_c_c = 5.
min_c_c = - 5.
max_c_r = 0.18
min_c_r = 0.

def setmaxmincontrol(cntrl_vars):
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl    

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

# %%
aln.params['duration'] = 3000.

control0 = aln.getZeroControl()
target = aln.getZeroTarget()
control0 = step_control(maxI_ = 1.)

aln.params.ext_exc_current = 0.5 * 5.
aln.params.ext_inh_current = 0.55 * 5.

aln.params.mue_ext_mean = 0.
aln.params.mui_ext_mean = 0.

aln.params.sigmae_ext = 0.5
aln.params.sigmai_ext = 0.5

# NO ADAPTATION
aln.params.a = 0.
aln.params.b = 0.

plotFunc.plot_traces(aln, control0)
    
steady_rates = np.zeros((2, 2))
steady_rates[0,0] = aln.rates_exc[0,-1] # high state exc
steady_rates[0,1] = aln.rates_inh[0,-1] # high state inh
steady_rates[1,0] = aln.rates_exc[0,14500] # low state exc
steady_rates[1,1] = aln.rates_inh[0,14500] # low state inh

print(steady_rates)

high_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    if aln.state[state_vars[i]].size == 1:
        high_state_vars[i] = aln.state[state_vars[i]][0] 
    else:
        high_state_vars[i] = aln.state[state_vars[i]][0,-1]
        
control0 = step_control(maxI_ = -3.)
plotFunc.plot_traces(aln, control0)

low_state_vars = np.zeros(( len(state_vars) ))
for i in range(len(state_vars)):
    if aln.state[state_vars[i]].size == 1:
        low_state_vars[i] = aln.state[state_vars[i]][0]
    else:
        low_state_vars[i] = aln.state[state_vars[i]][0,-1]
# Out:
# [[4.5661e+01 1.0253e+02]
#  [1.0766e-33 3.3672e+01]]

# %%
# 8 cases
# ee, ei, ie, ii
c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

bestControla = [ [], [], []]
bestStatea = [ [], [], []]
costa = [ [], [], []]
runtimea = [ [], [], []]
grada = [ [], [], []]
phia = [ [], [], []]
costnodea = [ [], [], []]
weightsa = [ [], [], [], [], [], [], [], [] ]

bestControlb = [ [], [], [], [], [], [], [], [] ]
bestStateb = [ [], [], [], [], [], [], [], [] ]
costb = [ [], [], [], [], [], [], [], [] ]
runtimeb = [ [], [], [], [], [], [], [], [] ]
gradb = [ [], [], [], [], [], [], [], [] ]
phib = [ [], [], [], [], [], [], [], [] ]
costnodeb = [ [], [], [], [], [], [], [], [] ]
weightsb = [ [], [], [], [], [], [], [], [] ]

bestControlc = [ [], [], [], [], [], [], [], [] ]
bestStatec = [ [], [], [], [], [], [], [], [] ]
costc = [ [], [], [], [], [], [], [], [] ]
runtimec = [ [], [], [], [], [], [], [], [] ]
gradc = [ [], [], [], [], [], [], [], [] ]
phic = [ [], [], [], [], [], [], [], [] ]
costnodec = [ [], [], [], [], [], [], [], [] ]
weightsc = [ [], [], [], [], [], [], [], [] ]

bestControld = [ [], [], [], [], [], [], [], [] ]
bestStated = [ [], [], [], [], [], [], [], [] ]
costd = [ [], [], [], [], [], [], [], [] ]
runtimed = [ [], [], [], [], [], [], [], [] ]
gradd = [ [], [], [], [], [], [], [], [] ]
phid = [ [], [], [], [], [], [], [], [] ]
costnoded = [ [], [], [], [], [], [], [], [] ]
weightsd = [ [], [], [], [], [], [], [], [] ]

bestControle = [ [], [], [], [], [], [], [], [] ]
bestStatee = [ [], [], [], [], [], [], [], [] ]
coste = [ [], [], [], [], [], [], [], [] ]
runtimee = [ [], [], [], [], [], [], [], [] ]
grade = [ [], [], [], [], [], [], [], [] ]
phie = [ [], [], [], [], [], [], [], [] ]
costnodee = [ [], [], [], [], [], [], [], [] ]
weightse = [ [], [], [], [], [], [], [], [] ]

# %%
cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

trans_time_array = np.zeros(( len(c_var) ))
trans_time_array[:] = 0.8

target_rates = np.array( [steady_rates[0,0], steady_rates[0,1]])
initVars = low_state_vars

dur = 100
dur_pre = 10
dur_post = 10
aln.params.duration = dur

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

# set low state rates as target
target = aln.getZeroTarget()
target[:,0,:] = target_rates[0]
target[:,1,:] = target_rates[1]

sheet = "state_switching"
max_it = 2000

# %% [markdown]
# ### Cases
#
# Numer | Input | Input label | Result
# ---------|--------------|-----------|-----------
# 1 | E current | 0 | 0
# 2 | I current | 1 | 0
# 3 | E + I current | 0,1 | 0
# 4 | EE rate | 2 | 0
# 5 | EI rate | 3 | 0
# 6 | IE rate | 4 | 0
# 7 | II rate | 5 | 0
# 8 | EE + EI + IE + II rate | 2,3,4,5 | 0
#
# - a) precision cost only
# - b) precision + energy just below maximum
# - c) precision + energy just beyond zero control for one/ both inputs
# - d) precision + sparsity just below maximum
# - e) precision + sparsity just beyond zero control for one/ both inputs

# %% [markdown]
# ## 3

# %%
c_ = 2
case = sheet + str(c_) + "a"
cost.setParams(1.0, 0.0, 0.0)
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]

trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)
aln.params.duration = dur

setinit(initVars)
control0 = aln.getZeroControl()
control0 = setrandomcontrol(control0, max_cntrl, min_cntrl, cntrl_vars)
#control1 = bestControla[c_][:,:,n_pre-1:-n_post+1]

# "HS", "FR", "PR", "HZ"
cgv = None
max_it = 100

weightsa = [ [], [], [], [], [], [], [], [] ]
weightsa[c_] = cost.getParams()

print("control input: ", cntrl_vars, ", precision measure: ", prec_vars)

bestControla[c_], bestStatea[c_], costa[c_], runtimea[c_], grada[c_], phia[c_], costnodea[c_] = aln.A1(
    control0, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,prec_variables_ = prec_vars, transition_time_ = trans_time)

#plotFunc.plot_control(aln, [bestControla[c_]], [costnodea[c_]], [weightsa[c_]], dur, dur_pre, dur_post, initVars, target,
 #                     path, filename_ = case, transition_time_ = trans_time, labels_ = ["a"])
#plotFunc.plot_gradient(grada[c_], dur, aln.params.dt, path, plot_vars = cntrl_vars)
# Out:
# set cost params:  1.0 0.0 0.0
# control input:  [0, 1] , precision measure:  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29734.404868148406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  410.88692263073284
# RUN  2 , total integrated cost =  72.27252457459016
# RUN  3 , total integrated cost =  30.203885218910333
# RUN  4 , total integrated cost =  20.921842023161652
# RUN  5 , total integrated cost =  14.831299310806
# RUN  6 , total integrated cost =  14.470826156819049
# RUN  7 , total integrated cost =  10.48363430031758
# RUN  8 , total integrated cost =  8.231085370541287
# RUN  9 , total integrated cost =  6.669357574901564
# RUN  10 , total integrated cost =  5.5869569010473334
# RUN  11 , total integrated cost =  4.7358912253067045
# RUN  12 , total integrated cost =  3.981620108441896
# RUN  13 , total integrated cost =  3.468608743161768
# RUN  14 , total integrated cost =  3.0810179756194547
# RUN  15 , total integrated cost =  2.731444046206029
# RUN  16 , total integrated cost =  2.4396444188565765
# RUN  17 , total integrated cost =  2.1991175986519758
# RUN  18 , total integrated cost =  1.9769809204652968
# RUN  19 , total integrated cost =  1.7795450031437363
# RUN  20 , total integrated cost =  1.6230091746877482
# RUN  30 , total integrated cost =  0.7616163545073257
# RUN  40 , total integrated cost =  0.4474581835222683
# RUN  50 , total integrated cost =  0.2935247804152379
# RUN  60 , total integrated cost =  0.20914201969333832
# RUN  70 , total integrated cost =  0.156684024868577
# RUN  80 , total integrated cost =  0.12212651169555926
# RUN  90 , total integrated cost =  0.0970877354620078
# ERROR:root:Problem in initial value trasfer
# RUN  100 , total integrated cost =  0.07783770106901171
# RUN  100 , total integrated cost =  0.07783770106901171
# Improved over  100  iterations in  6.7013042000003225  seconds by  99.9997382234438  percent.
# Problem in initial value trasfer:  Vmean_exc -56.1542186508253 -56.15139568809018

# %%
c_ = 2
case = sheet + str(c_) + "c"
cost.setParams(1.0, 1.8 * 1e3, 0.)
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]

trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)
aln.params.duration = dur

setinit(initVars)
control0 = aln.getZeroControl()
#control0 = setrandomcontrol(control0, max_cntrl, min_cntrl, cntrl_vars)
control1 = bestControla[c_][:,:,n_pre-1:-n_post+1]
control2 = bestControlc[c_][:,:,n_pre-1:-n_post+1]
#control3 = bestControlc[c_][:,:,n_pre-1:-n_post+1]

weightsc = [ [], [], [] ]

weightsc[c_] = cost.getParams()

# cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]
cgv = None
max_it = 100

bestControlc[c_], bestStatec[c_], costc[c_], runtimec[c_], gradc[c_], phic[c_], costnodec[c_] = aln.A1(
    control2, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
    prec_variables_ = prec_vars, transition_time_ = trans_time)

print( "max, min in exc array = ", np.amax(bestControlc[c_][0,0,:]), np.amin(bestControlc[c_][0,0,:]) )
print( "max, min in inh array = ", np.amax(bestControlc[c_][0,1,:]), np.amin(bestControlc[c_][0,1,:]) )

plotFunc.plot_control_current(aln, [bestControlc[c_]], [costnodec[c_]], [weightsc[c_]], dur, dur_pre, dur_post, initVars, target,
                      path, filename_ = case, transition_time_ = trans_time, labels_ = ["A"],
                      precision_variables_ = prec_vars)

# max, min in exc array =  0.04823888298757358 -0.0055330301560280746
# max, min in inh array =  0.010659181124614673 -0.10290701929006114
# Out:
# set cost params:  1.0 1800.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18935.22376474897
# Gradient descend method:  FR
# RUN  1 , total integrated cost =  18929.68105181118
# RUN  2 , total integrated cost =  18929.660729174797
# RUN  3 , total integrated cost =  18928.89664400847
# RUN  4 , total integrated cost =  18928.676108421037
# RUN  5 , total integrated cost =  18928.633859349604
# RUN  6 , total integrated cost =  18928.072669853256
# RUN  7 , total integrated cost =  18927.67333967058
# RUN  8 , total integrated cost =  18927.58926517417
# RUN  9 , total integrated cost =  18927.556967895824
# RUN  10 , total integrated cost =  18927.43375579651
# RUN  11 , total integrated cost =  18926.787856190545
# RUN  12 , total integrated cost =  18925.9780975457
# RUN  13 , total integrated cost =  18925.296818948118
# RUN  14 , total integrated cost =  18924.68327610809
# RUN  15 , total integrated cost =  18924.617779919532
# RUN  16 , total integrated cost =  18922.953071630734
# RUN  17 , total integrated cost =  18922.32366732216
# RUN  18 , total integrated cost =  18922.28931373873
# RUN  19 , total integrated cost =  18922.240059621185
# RUN  20 , total integrated cost =  18921.67238187787
# RUN  30 , total integrated cost =  18919.151313365972
# RUN  40 , total integrated cost =  18917.05077026371
# RUN  50 , total integrated cost =  18911.26315637198
# RUN  60 , total integrated cost =  18908.62863276473
# RUN  70 , total integrated cost =  18905.408727209793
# RUN  80 , total integrated cost =  18902.719922963453
# RUN  90 , total integrated cost =  18897.771140415927
# ERROR:root:Problem in initial value trasfer
# RUN  100 , total integrated cost =  18894.935371964515
# RUN  100 , total integrated cost =  18894.935371964515
# Improved over  100  iterations in  6.857124399999975  seconds by  0.21276956261515068  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14646662944671 -56.14646676066336
# max, min in exc array =  0.5891032045494327 0.0
# max, min in inh array =  1.9910155823165605e-11 -1.128373077165523

# %%
c_ = 2
case = sheet + str(c_) + "a"
cost.setParams(1.0, 0.8 * 1e5, 3.8 * 1e4)
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]

trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)
aln.params.duration = dur

setinit(initVars)
#control0 = aln.getZeroControl()
#control0 = setrandomcontrol(control0, max_cntrl, min_cntrl, cntrl_vars)
#control1 = bestControla[c_][:,:,n_pre-1:-n_post+1]
control3 = bestControle[c_][:,:,n_pre-1:-n_post+1] # no input in exc node
control5 = bestControla[c_][:,:,n_pre-1:-n_post+1] # no input in exc node

weightsa = [ [], [], [] ]
weightsa[c_] = cost.getParams()

# "HS", "FR", "PR", "HZ"
cgv = None
max_it = 20

bestControla[c_], bestStatea[c_], costa[c_], runtimea[c_], grada[c_], phia[c_], costnodea[c_] = aln.A1(
        control5, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

print( "max, min in exc array = ", np.amax(bestControla[c_][0,0,:]), np.amin(bestControla[c_][0,0,:]) )
print( "max, min in inh array = ", np.amax(bestControla[c_][0,1,:]), np.amin(bestControla[c_][0,1,:]) )
    
print("final value exc rate: ", bestStatea[c_][0,0,-1])
# Out:
# set cost params:  1.0 80000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22108.220390189916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22108.220390189916
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  22108.220390189916
# Improved over  1  iterations in  0.18082579999463633  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.17454881394804 -56.17455046012667
# max, min in exc array =  2.252147843261711e-16 -2.890436966899526e-17
# max, min in inh array =  0.014325147081678744 -0.1265135467641148
# final value exc rate:  47.50971664567229

# %%
c_ = 2
case = sheet + str(c_) + "d"
cost.setParams(1.0, 0.9 * 1e5, 3.7 * 1e4)
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]

trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)
aln.params.duration = dur

setinit(initVars)
#control0 = aln.getZeroControl()
#control0 = setrandomcontrol(control0, max_cntrl, min_cntrl, cntrl_vars)
#control1 = bestControla[c_][:,:,n_pre-1:-n_post+1]
control2 = bestControlc[c_][:,:,n_pre-1:-n_post+1] # input in exc node
#control4 = bestControld[c_][:,:,n_pre-1:-n_post+1] # input in exc node
control6 = bestControld[c_][:,:,n_pre-1:-n_post+1] # input in exc node

weightsd = [ [], [], [] ]
weightsd[c_] = cost.getParams()

# "HS", "FR", "PR", "HZ"
cgv = None
max_it = 3000

bestControld[c_], bestStated[c_], costd[c_], runtimed[c_], gradd[c_], phid[c_], costnoded[c_] = aln.A1(
        control6, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

print( "max, min in exc array = ", np.amax(bestControld[c_][0,0,:]), np.amin(bestControld[c_][0,0,:]) )
print( "max, min in inh array = ", np.amax(bestControld[c_][0,1,:]), np.amin(bestControld[c_][0,1,:]) )
    
print("final value exc rate: ", bestStated[c_][0,0,-1])
# Out:
# set cost params:  1.0 90000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22509.338795988682
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22509.338795988682
# Control only changes marginally.
# RUN  1 , total integrated cost =  22509.338795988682
# Improved over  1  iterations in  0.17345190000196453  seconds by  0.0  percent.
# ERROR:root:Problem in initial value trasfer
# Problem in initial value trasfer:  Vmean_exc -56.17455322848051 -56.174554702942956
# max, min in exc array =  0.004424898616144747 -0.0005451838680931867
# max, min in inh array =  0.01423775889030629 -0.12403995955169236
# final value exc rate:  47.509722769747995

# %%
c_ = 2
case = sheet + str(c_) + "e"
cost.setParams(1.0, 0., 2.7 * 1e3)
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]

trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)
aln.params.duration = dur

setinit(initVars)
control0 = aln.getZeroControl()
control0 = setrandomcontrol(control0, max_cntrl, min_cntrl, cntrl_vars)
control1 = bestControla[c_][:,:,n_pre-1:-n_post+1]
#control2 = bestControle[c_][:,:,n_pre-1:-n_post+1] # 22442


# "HS", "FR", "PR", "HZ"
cgv = None
max_it = 100
weightse[c_] = cost.getParams()

bestControle[c_], bestStatee[c_], coste[c_], runtimee[c_], grade[c_], phie[c_], costnodee[c_] =  aln.A1(
    control2, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
    prec_variables_ = prec_vars, transition_time_ = trans_time)

print( "max, min in exc array = ", np.amax(bestControle[c_][0,0,:]), np.amin(bestControle[c_][0,0,:]) )
print( "max, min in inh array = ", np.amax(bestControle[c_][0,1,:]), np.amin(bestControle[c_][0,1,:]) )

#plotFunc.plot_control_current(aln, [bestControle[c_]], [costnodee[c_]], [weightse[c_]], dur, dur_pre, dur_post, initVars, target,
#                      path, filename_ = case, transition_time_ = trans_time, labels_ = ["B"],
#                      precision_variables_ = prec_vars)
# Out:
# set cost params:  1.0 0.0 2700.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19317.321627122106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19313.4307238864
# RUN  2 , total integrated cost =  19313.418139684407
# RUN  3 , total integrated cost =  19313.40571161655
# RUN  4 , total integrated cost =  19313.39805127988
# RUN  5 , total integrated cost =  19313.390376713323
# RUN  6 , total integrated cost =  19313.383648167503
# RUN  7 , total integrated cost =  19313.376545820593
# RUN  8 , total integrated cost =  19313.372510593545
# RUN  9 , total integrated cost =  19313.36741860341
# RUN  10 , total integrated cost =  19313.36341271595
# RUN  11 , total integrated cost =  19313.358600014464
# RUN  12 , total integrated cost =  19313.354585798963
# RUN  13 , total integrated cost =  19313.34970627308
# RUN  14 , total integrated cost =  19313.345667523376
# RUN  15 , total integrated cost =  19313.341076771358
# RUN  16 , total integrated cost =  19313.33700839848
# RUN  17 , total integrated cost =  19313.332026999236
# RUN  18 , total integrated cost =  19313.327781256838
# RUN  19 , total integrated cost =  19313.322677809483
# RUN  20 , total integrated cost =  19313.318425781537
# RUN  30 , total integrated cost =  19313.260568158406
# RUN  40 , total integrated cost =  19313.045852024665
# RUN  50 , total integrated cost =  19312.372528951968
# ERROR:root:Problem in initial value trasfer
# RUN  60 , total integrated cost =  19312.301326269426
# Control only changes marginally.
# RUN  60 , total integrated cost =  19312.301326269426
# Improved over  60  iterations in  10.267116100000749  seconds by  0.02598859691620703  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14644752187587 -56.146448274887454
# max, min in exc array =  1.5105047885018328 -0.0003992003374786573
# max, min in inh array =  1.6084196080223142e-16 -2.4019541040435726e-16

# %%
c_ = 2
case = sheet + str(c_) + "_all"
plotFunc.plot_control_current(aln, [bestControlc[c_], bestControld[c_], bestControla[c_], bestControle[c_]],
        [costnodec[c_], costnoded[c_], costnodea[c_], costnodee[c_]],
        [weightsc[c_], weightsd[c_], weightsa[c_], weightse[c_]], dur, dur_pre, dur_post, initVars, target,
        path, filename_ = case, transition_time_ = trans_time, labels_ = ["A", "B", "C", "D"],
        precision_variables_ = prec_vars)

# %%
###### HEATMAP for cost depending on weights

N_e = 6
e_max = 2.1 * 1e3
e_weights = np.linspace(0, e_max, num=N_e, endpoint=False)

N_s = 6
s_max = 4. * 1e3
s_weights = np.linspace(0, s_max, num=N_s, endpoint=False)

weights_array = np.zeros(( N_e,N_s,2 ))
for ind_e in range(N_e):
    for ind_s in range(N_s):
        weights_array[ind_e,ind_s,0] = e_weights[ind_e]
        weights_array[ind_e,ind_s,1] = s_weights[ind_s]

c_ = 2
cntrl_vars = c_var[c_]
prec_vars = p_var[c_]
trans_time = trans_time_array[c_]
max_cntrl, min_cntrl = setmaxmincontrol(cntrl_vars)

#control5 = bestControla[c_][:,:,n_pre-1:-n_post+1]
#control4 = bestControlc[c_][:,:,n_pre-1:-n_post+1]
#control5 = bestControle[c_][:,:,n_pre-1:-n_post+1]

# %%
# zero control : 22493.494361608944
start_cntrl = aln.getZeroControl()

control_ = np.zeros((N_e, N_s, start_cntrl.shape[0], start_cntrl.shape[1], start_cntrl.shape[2]))
cost_nodewise_ = np.zeros(( N_e, N_s, 1, 3, 6 ))
cost_total_ = np.zeros(( N_e, N_s ))
#cost_exc_node_node1zero = np.zeros((N_e, N_s))
#cost_2d_2_node1input = np.zeros((N_e, N_s))
#cost_exc_node_node1input = np.zeros((N_e, N_s))


start_cntrl[0,0,:10] = 0.
start_cntrl[0,0,10:200] = 5.
start_cntrl[0,0,200:] = 0.
start_cntrl[0,1,:10] = 0.
start_cntrl[0,1,10:200] = -5.
start_cntrl[0,1,200:] = 0.

for ind_e in range(len(e_weights)):
    for ind_s in range(len(s_weights)):
        control_[ind_e, ind_s] = start_cntrl
            
            
t_ = np.arange(0, control_.shape[4]*aln.params.dt, aln.params.dt)
plt.plot(t_, control_[0,0,0,0,:])

# %%
cgv_list = [None]#, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]
cgv = None
max_it = 4000
tol = 1e-20

first_it = True

for cgv in cgv_list:

    for ind_e in range(len(e_weights)):
        for ind_s in range(len(s_weights)):

            print("-------------", ind_e, ind_s)

            c_e = e_weights[ind_e]
            c_s = s_weights[ind_s]


            control5 = control_[ind_e,ind_s,:,:,n_pre-1:-n_post+1]
            
            #if ind_s not in [0,1,2]:
            #    control5 = control_[ind_e,ind_s-1,:,:,n_pre-1:-n_post+1]

            cost.setParams(1.0, c_e, c_s)
            aln.params.duration = dur
            setinit(initVars)

            bc, bs, cost_, rt, gr, ph, cost_node = aln.A1(control5,
                target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
                prec_variables_ = prec_vars, transition_time_ = trans_time)

            j = 1
            while cost_[-j] == 0.:
                j += 1
            cost_total_[ind_e,ind_s] = cost_[-j]
            cost_nodewise_[ind_e,ind_s,0,0,0] = cost_node[0][0,0]
            cost_nodewise_[ind_e,ind_s,0,0,1] = cost_node[0][0,1]
            cost_nodewise_[ind_e,ind_s,0,1,0] = cost_node[1][0,0]
            cost_nodewise_[ind_e,ind_s,0,1,1] = cost_node[1][0,1]
            cost_nodewise_[ind_e,ind_s,0,2,0] = cost_node[2][0,0]
            cost_nodewise_[ind_e,ind_s,0,2,1] = cost_node[2][0,1]

            control_[ind_e,ind_s,:,:,:] = bc[:,:,:]

            # 0,1 : 3567
# Out:
# ------------- 0 0
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.799444527824514e-21
# Gradient descend method:  None
# Cost negligibly small.
# RUN  0 , total integrated cost =  9.799444527824514e-21
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# ------------- 0 1
# set cost params:  1.0 0.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3567.487895970325
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  3567.487895970325
# Control only changes marginally.
# RUN  1 , total integrated cost =  3567.487895970325
# Improved over  1  iterations in  0.1786573999997927  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647215417955 -56.1464725144882
# ------------- 0 2
# set cost params:  1.0 0.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7134.518468470541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7134.518468470541
# Control only changes marginally.
# RUN  1 , total integrated cost =  7134.518468470541
# Improved over  1  iterations in  0.1674761999893235  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.1464681606482 -56.146468656135326
# -------------
# ERROR:root:Problem in initial value trasfer
#  0 3
# set cost params:  1.0 0.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10701.4124880478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10701.4124880478
# Control only changes marginally.
# RUN  1 , total integrated cost =  10701.4124880478
# Improved over  1  iterations in  0.16863689999445342  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146465305934605 -56.14646589803419
# ------------- 0 4
# set cost params:  1.0 0.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14267.707840135488
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  14267.707840135488
# Control only changes marginally.
# RUN  1 , total integrated cost =  14267.707840135488
# Improved over  1  iterations in  0.1777116000012029  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146462254758944 -56.14646295208346
# ------------- 0 5
# set cost params:  1.0 0.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17834.326510283012
# Gradient descend method:  None
# RUN
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
#  1 , total integrated cost =  17834.326510283012
# Control only changes marginally.
# RUN  1 , total integrated cost =  17834.326510283012
# Improved over  1  iterations in  0.18092509999405593  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14646009927792 -56.14646086987287
# ------------- 1 0
# set cost params:  1.0 350.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3667.653006907447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3667.653006907447
# Control only changes marginally.
# RUN  1 , total integrated cost =  3667.653006907447
# Improved over  1  iterations in  0.16363140000612475  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14650033446483 -56.14649928964408
# ------------- 1 1
# set cost params:  1.0 350.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7774.222543811426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7774.222543811426
# Control only changes marginally.
# RUN  1 , total integrated cost =  7774.222543811426
# Improved over  1  iterations in  0.1688339999964228  seconds by  0.0  percent.
# ------------- 1 2
# set cost params:  1.0 350.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11735.34411923031
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  11735.34411923031
# Control only changes marginally.
# RUN  1 , total integrated cost =  11735.34411923031
# Improved over  1  iterations in  0.17059720000543166  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647714590014 -56.146477214905495
# ------------- 1 3
# set cost params:  1.0 350.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15556.353385140832
# Gradient descend method:  None
# RUN
# ERROR:root:Problem in initial value trasfer
#  1 , total integrated cost =  15556.353385140832
# Control only changes marginally.
# RUN  1 , total integrated cost =  15556.353385140832
# Improved over  1  iterations in  0.18857749999733642  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14646275026907 -56.14646320944962
# ------------- 1 4
# set cost params:  1.0 350.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19243.936779115924
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  19243.936779115924
# Control only changes marginally.
# RUN  1 , total integrated cost =  19243.936779115924
# Improved over  1  iterations in  0.20198610000079498  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146428579200204 -56.146430235713176
# ------------- 1 5
# set cost params:  1.0 350.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.18869780001114123  seconds by  0.0  percent.
# ------------- 2 0
# set cost params:  1.0 700.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7337.431577872881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7337.431577872881
# Control only changes marginally.
# RUN  1 , total integrated cost =  7337.431577872881
# Improved over  1  iterations in  0.1638169000070775  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647217089954 -56.146472613924956
# ------------- 2 1
# set cost params:  1.0 700.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11478.292284452153
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  11478.292284452153
# Control only changes marginally.
# RUN  1 , total integrated cost =  11478.292284452153
# Improved over  1  iterations in  0.16067359999578912  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647937510383 -56.146479400342464
# ------------- 2 2
# set cost params:  1.0 700.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15547.357518211425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15547.357518211425
# ERROR:root:Problem in initial value trasfer
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  15547.357518211425
# Improved over  1  iterations in  0.16383269999641925  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647515660909 -56.14647525827646
# ------------- 2 3
# set cost params:  1.0 700.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19543.564456665987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19543.564456665987
# Control only changes marginally.
# RUN  1 , total integrated cost =  19543.564456665987
# Improved over  1  iterations in  0.1602990000101272  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146468067746405 -56.146468340711074
# ------------- 2 4
# set cost params:  1.0 700.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.20599750000110362  seconds by  0.0  percent.
# ------------- 2 5
# set cost params:  1.0 700.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.18230849999235943  seconds by  0.0  percent.
# ------------- 3 0
# set cost params:  1.0 1050.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10999.074392897295
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10999.074392897295
# Control only changes marginally.
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  10999.074392897295
# Improved over  1  iterations in  0.17854219999571797  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647802668428 -56.14647809999113
# ------------- 3 1
# set cost params:  1.0 1050.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15151.791108726615
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  15151.791108726615
# Control only changes marginally.
# RUN  1 , total integrated cost =  15151.791108726615
# Improved over  1  iterations in  0.2086051999940537  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647804541367 -56.14647799383119
# ------------- 3 2
# set cost params:  1.0 1050.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19257.63979118948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19257.63979118948
# ERROR:root:Problem in initial value trasfer
# Control only changes marginally.
# RUN  1 , total integrated cost =  19257.63979118948
# Improved over  1  iterations in  0.18161859999236185  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.14647055698323 -56.14647075758114
# ------------- 3 3
# set cost params:  1.0 1050.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.22123689998988993  seconds by  0.0  percent.
# ------------- 3 4
# set cost params:  1.0 1050.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.1819487000029767  seconds by  0.0  percent.
# ------------- 3 5
# set cost params:  1.0 1050.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.21599040000000969  seconds by  0.0  percent.
# ------------- 4 0
# set cost params:  1.0 1400.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14664.715582717366
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  14664.715582717366
# Control only changes marginally.
# RUN  1 , total integrated cost =  14664.715582717366
# Improved over  1  iterations in  0.19067349999386352  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146473863914125 -56.14647398227498
# ------------- 4 1
# set cost params:  1.0 1400.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18827.853327864672
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer
# RUN  1 , total integrated cost =  18827.853327864672
# Control only changes marginally.
# RUN  1 , total integrated cost =  18827.853327864672
# Improved over  1  iterations in  0.19261179999739397  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.146469221631584 -56.146469445694635
# ------------- 4 2
# set cost params:  1.0 1400.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.20361360000970308  seconds by  0.0  percent.
# ------------- 4 3
# set cost params:  1.0 1400.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.18475760000001173  seconds by  0.0  percent.
# ------------- 4 4
# set cost params:  1.0 1400.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.18534699999145232  seconds by  0.0  percent.
# ------------- 4 5
# set cost params:  1.0 1400.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.18037800000456627  seconds by  0.0  percent.
# ------------- 5 0
# set cost params:  1.0 1750.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18326.223798317387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18326.223798317387
# Control only changes marginally.
# RUN  1 , total integrated cost =  18326.223798317387
# Improved over  1  iterations in  0.16878379999252502  seconds by  0.0  percent.
# ERROR:root:Problem in initial value trasfer
# Problem in initial value trasfer:  Vmean_exc -56.14646832977555 -56.14646855749373
# ------------- 5 1
# set cost params:  1.0 1750.0 666.6666666666666
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.2210882999934256  seconds by  0.0  percent.
# ------------- 5 2
# set cost params:  1.0 1750.0 1333.3333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.20807150000473484  seconds by  0.0  percent.
# ------------- 5 3
# set cost params:  1.0 1750.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.20446029999584425  seconds by  0.0  percent.
# ------------- 5 4
# set cost params:  1.0 1750.0 2666.6666666666665
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.23087279999163002  seconds by  0.0  percent.
# ------------- 5 5
# set cost params:  1.0 1750.0 3333.333333333333
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20848.940211946312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20848.940211946312
# Control only changes marginally.
# RUN  1 , total integrated cost =  20848.940211946312
# Improved over  1  iterations in  0.20933030000014696  seconds by  0.0  percent.

# %%
# safe results 
with open('sc2_2_0_control.pickle','wb') as f:
    pickle.dump(control_, f)
    
with open('sc2_2_0_control.pickle','rb') as f:
    arrayname1 = pickle.load(f)

print(arrayname1.shape)

with open('sc2_2_0_cost_nodewise.pickle','wb') as f:
    pickle.dump(cost_nodewise_, f)
    
with open('sc2_2_0_cost_nodewise.pickle','rb') as f:
    arrayname1 = pickle.load(f)

print(arrayname1.shape)

with open('sc2_2_0_cost_total.pickle','wb') as f:
    pickle.dump(cost_total_, f)
    
with open('sc2_2_0_cost_total.pickle','rb') as f:
    arrayname1 = pickle.load(f)

print(arrayname1.shape)

print(cost_total_)
# Out:
# (6, 6, 1, 6, 1201)
# (6, 6, 1, 3, 6)
# (6, 6)
# [[9.7994e-21 3.5675e+03 7.1345e+03 1.0701e+04 1.4268e+04 1.7834e+04]
#  [3.6677e+03 7.7742e+03 1.1735e+04 1.5556e+04 1.9244e+04 2.0849e+04]
#  [7.3374e+03 1.1478e+04 1.5547e+04 1.9544e+04 2.0849e+04 2.0849e+04]
#  [1.0999e+04 1.5152e+04 1.9258e+04 2.0849e+04 2.0849e+04 2.0849e+04]
#  [1.4665e+04 1.8828e+04 2.0849e+04 2.0849e+04 2.0849e+04 2.0849e+04]
#  [1.8326e+04 2.0849e+04 2.0849e+04 2.0849e+04 2.0849e+04 2.0849e+04]]

# %%
ylim = [-0.28, 0.15]

plotFunc.plot_control_array(aln, control_, cost_total_, weights_array, dur, dur_pre,
            dur_post, initVars, target, ylim, path, filename_ = 'control_array_plot_sc2_2_0',
            transition_time_ = trans_time, precision_variables_=prec_vars)

# %%
# load results


with open('sc2_2_0_control.pickle','rb') as f:
    control_ = pickle.load(f)
print(control_.shape)
    
with open('sc2_2_0_cost_nodewise.pickle','rb') as f:
    cost_nodewise_ = pickle.load(f)
print(cost_nodewise_.shape)
    
with open('sc2_2_0_cost_total.pickle','rb') as f:
    cost_total_ = pickle.load(f)
print(cost_total_.shape)
# Out:
# (6, 6, 1, 6, 1201)
# (6, 6, 1, 3, 6)
# (6, 6)

# %%
test_cost = cost_2d_2_node1input
too_high_cost = []
local_min = []

c_ = 2

xd, yd = 0, weightse[c_][2]
yd_arrow = N_s * yd/s_max

xa, ya = weightsc[c_][1], 0
xa_arrow = N_e * xa/e_max

xc, yc = weightsa[c_][1], weightsa[c_][2]
xc_arrow = N_e * xc/e_max
yc_arrow = N_s * yc/s_max

xb, yb = weightsd[c_][1], weightsd[c_][2]
xb_arrow = N_e * xb/e_max
yb_arrow = N_s * yb/s_max

0.8 * 1e5, 3.8 * 1e4

arrow_xlength = 4
arrow_ylength = 2

max_it = 100

for c1_ in range(N_e):
    for c2_ in range(N_s):
        if test_cost[c1_,c2_] > 22492 and test_cost[c1_,c2_] < 22495:
            #print("presumably local minimum for ", c1_, c2_)
            local_min.append([c1_,c2_])
        if test_cost[c1_,c2_] > 22500:
            #print("too high cost for ", c1_, c2_)
            too_high_cost.append([c1_,c2_])
            #test_cost[c1_,c2_] = 22500
        if test_cost[c1_,c2_] == 0.:
            print("zero cost for ", c1_, c2_)
            #test_cost[c1_,c2_] = 22500

n_xticks = 19
e_ticklabels = ["{:.1e}".format(x) for x in e_weights[::int(N_e / (n_xticks-1))  ]]
n_yticks = 15
s_ticklabels = ["{:.1e}".format(x) for x in s_weights[::int(N_s / (n_yticks-1))  ]]

fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, cmap="viridis")
ax.set(xlabel='energy weight', ylabel='sparsity weight', title='cost after {} iterations'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_' + str(c_) ) )
plt.show()

# %%
cgv = None
max_it = 100
control3 = bc[:,:,n_pre-1:-n_post+1]
aln.params.duration = dur

cost_2d_2_node1input_maxcost = cost_2d_2_node1input.copy()

# too_high_cost, local_min

for indices in too_high_cost:
    
    ind_e = indices[0]
    ind_s = indices[1]
        
    print("-------------", ind_e, ind_s)

    c_e = e_weights[ind_e]
    c_s = s_weights[ind_s]

    cost.setParams(1.0, c_e, c_s)
    aln.params.duration = dur
    setinit(initVars)
    
    start_cntrl = control0

    bc, bs, cost_, rt, gr, ph, cn_ = aln.A1(
        start_cntrl, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

    j = 1
    while cost_[-j] == 0.:
        j += 1
    cost_2d_2_node1input_maxcost[ind_e,ind_s] = cost_[-j]
# Out:
# ------------- 0 48
# set cost params:  1.0 0.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.168333800000255  seconds by  0.0  percent.
# ------------- 0 49
# set cost params:  1.0 0.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16961469998932444  seconds by  0.0  percent.
# ------------- 0 50
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18251600000075996  seconds by  0.0  percent.
# ------------- 0 51
# set cost params:  1.0 0.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16404160000092816  seconds by  0.0  percent.
# ------------- 0 52
# set cost params:  1.0 0.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17184480000287294  seconds by  0.0  percent.
# ------------- 0 53
# set cost params:  1.0 0.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16208779999578837  seconds by  0.0  percent.
# ------------- 0 54
# set cost params:  1.0 0.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17322159999457654  seconds by  0.0  percent.
# ------------- 0 55
# set cost params:  1.0 0.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17624880000948906  seconds by  0.0  percent.
# ------------- 1 47
# set cost params:  1.0 5000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17048240000440273  seconds by  0.0  percent.
# ------------- 1 48
# set cost params:  1.0 5000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1736451000033412  seconds by  0.0  percent.
# ------------- 1 49
# set cost params:  1.0 5000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.176405899997917  seconds by  0.0  percent.
# ------------- 1 50
# set cost params:  1.0 5000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17536669998662546  seconds by  0.0  percent.
# ------------- 1 51
# set cost params:  1.0 5000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17557249999663327  seconds by  0.0  percent.
# ------------- 1 52
# set cost params:  1.0 5000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17478039998968598  seconds by  0.0  percent.
# ------------- 1 53
# set cost params:  1.0 5000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17572959999961313  seconds by  0.0  percent.
# ------------- 1 54
# set cost params:  1.0 5000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1762114000011934  seconds by  0.0  percent.
# ------------- 1 55
# set cost params:  1.0 5000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1738790999952471  seconds by  0.0  percent.
# ------------- 2 46
# set cost params:  1.0 10000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1748675999988336  seconds by  0.0  percent.
# ------------- 2 47
# set cost params:  1.0 10000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18032479999237694  seconds by  0.0  percent.
# ------------- 2 48
# set cost params:  1.0 10000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20903470000484958  seconds by  0.0  percent.
# ------------- 2 49
# set cost params:  1.0 10000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20159500000590924  seconds by  0.0  percent.
# ------------- 2 50
# set cost params:  1.0 10000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1743690000002971  seconds by  0.0  percent.
# ------------- 2 51
# set cost params:  1.0 10000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1839314000098966  seconds by  0.0  percent.
# ------------- 2 52
# set cost params:  1.0 10000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17592200000945013  seconds by  0.0  percent.
# ------------- 2 53
# set cost params:  1.0 10000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17504610000469256  seconds by  0.0  percent.
# ------------- 2 54
# set cost params:  1.0 10000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17504690001078416  seconds by  0.0  percent.
# ------------- 2 55
# set cost params:  1.0 10000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1794445999985328  seconds by  0.0  percent.
# ------------- 3 45
# set cost params:  1.0 15000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17099790000065695  seconds by  0.0  percent.
# ------------- 3 46
# set cost params:  1.0 15000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17811340000480413  seconds by  0.0  percent.
# ------------- 3 47
# set cost params:  1.0 15000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18261860001075547  seconds by  0.0  percent.
# ------------- 3 48
# set cost params:  1.0 15000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17654689999471884  seconds by  0.0  percent.
# ------------- 3 49
# set cost params:  1.0 15000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18162149999989197  seconds by  0.0  percent.
# ------------- 3 50
# set cost params:  1.0 15000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17473349999636412  seconds by  0.0  percent.
# ------------- 3 51
# set cost params:  1.0 15000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17521950000082143  seconds by  0.0  percent.
# ------------- 3 52
# set cost params:  1.0 15000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1739199000003282  seconds by  0.0  percent.
# ------------- 3 53
# set cost params:  1.0 15000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17938519999734126  seconds by  0.0  percent.
# ------------- 3 54
# set cost params:  1.0 15000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17588080000132322  seconds by  0.0  percent.
# ------------- 3 55
# set cost params:  1.0 15000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17669330000353511  seconds by  0.0  percent.
# ------------- 4 45
# set cost params:  1.0 20000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18578660000639502  seconds by  0.0  percent.
# ------------- 4 46
# set cost params:  1.0 20000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1728856999980053  seconds by  0.0  percent.
# ------------- 4 47
# set cost params:  1.0 20000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17304280000098515  seconds by  0.0  percent.
# ------------- 4 48
# set cost params:  1.0 20000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17604960000608116  seconds by  0.0  percent.
# ------------- 4 49
# set cost params:  1.0 20000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1758321000088472  seconds by  0.0  percent.
# ------------- 4 50
# set cost params:  1.0 20000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17886230000294745  seconds by  0.0  percent.
# ------------- 4 51
# set cost params:  1.0 20000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17701929999748245  seconds by  0.0  percent.
# ------------- 4 52
# set cost params:  1.0 20000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18935259999125265  seconds by  0.0  percent.
# ------------- 4 53
# set cost params:  1.0 20000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.23277889999735635  seconds by  0.0  percent.
# ------------- 4 54
# set cost params:  1.0 20000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18497829999250825  seconds by  0.0  percent.
# ------------- 4 55
# set cost params:  1.0 20000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18647380000038538  seconds by  0.0  percent.
# ------------- 5 44
# set cost params:  1.0 25000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17726300000504125  seconds by  0.0  percent.
# ------------- 5 45
# set cost params:  1.0 25000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1771731000044383  seconds by  0.0  percent.
# ------------- 5 46
# set cost params:  1.0 25000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1775505000114208  seconds by  0.0  percent.
# ------------- 5 47
# set cost params:  1.0 25000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1796526999969501  seconds by  0.0  percent.
# ------------- 5 48
# set cost params:  1.0 25000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17454939999151975  seconds by  0.0  percent.
# ------------- 5 49
# set cost params:  1.0 25000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17536970000946894  seconds by  0.0  percent.
# ------------- 5 50
# set cost params:  1.0 25000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17630069999722764  seconds by  0.0  percent.
# ------------- 5 51
# set cost params:  1.0 25000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17297919999691658  seconds by  0.0  percent.
# ------------- 5 52
# set cost params:  1.0 25000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17498239999986254  seconds by  0.0  percent.
# ------------- 5 53
# set cost params:  1.0 25000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18588740000268444  seconds by  0.0  percent.
# ------------- 5 54
# set cost params:  1.0 25000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17811220001021866  seconds by  0.0  percent.
# ------------- 5 55
# set cost params:  1.0 25000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17976389999967068  seconds by  0.0  percent.
# ------------- 6 43
# set cost params:  1.0 30000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17574120000062976  seconds by  0.0  percent.
# ------------- 6 44
# set cost params:  1.0 30000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17433940000773873  seconds by  0.0  percent.
# ------------- 6 45
# set cost params:  1.0 30000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19217619999835733  seconds by  0.0  percent.
# ------------- 6 46
# set cost params:  1.0 30000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2017288000060944  seconds by  0.0  percent.
# ------------- 6 47
# set cost params:  1.0 30000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21208159999514464  seconds by  0.0  percent.
# ------------- 6 48
# set cost params:  1.0 30000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.25369789999967907  seconds by  0.0  percent.
# ------------- 6 49
# set cost params:  1.0 30000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2401053000066895  seconds by  0.0  percent.
# ------------- 6 50
# set cost params:  1.0 30000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.3537981000117725  seconds by  0.0  percent.
# ------------- 6 51
# set cost params:  1.0 30000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.27308309999352787  seconds by  0.0  percent.
# ------------- 6 52
# set cost params:  1.0 30000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.24255260000063572  seconds by  0.0  percent.
# ------------- 6 53
# set cost params:  1.0 30000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.22820510000747163  seconds by  0.0  percent.
# ------------- 6 54
# set cost params:  1.0 30000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2112704000028316  seconds by  0.0  percent.
# ------------- 6 55
# set cost params:  1.0 30000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.206960599985905  seconds by  0.0  percent.
# ------------- 7 43
# set cost params:  1.0 35000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18854940000164788  seconds by  0.0  percent.
# ------------- 7 44
# set cost params:  1.0 35000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18640930000401568  seconds by  0.0  percent.
# ------------- 7 45
# set cost params:  1.0 35000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2228264000004856  seconds by  0.0  percent.
# ------------- 7 46
# set cost params:  1.0 35000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.23656029999256134  seconds by  0.0  percent.
# ------------- 7 47
# set cost params:  1.0 35000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20823709999967832  seconds by  0.0  percent.
# ------------- 7 48
# set cost params:  1.0 35000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19689060001110192  seconds by  0.0  percent.
# ------------- 7 49
# set cost params:  1.0 35000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18654680000327062  seconds by  0.0  percent.
# ------------- 7 50
# set cost params:  1.0 35000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19666689999576192  seconds by  0.0  percent.
# ------------- 7 51
# set cost params:  1.0 35000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2076999999990221  seconds by  0.0  percent.
# ------------- 7 52
# set cost params:  1.0 35000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.219078800000716  seconds by  0.0  percent.
# ------------- 7 53
# set cost params:  1.0 35000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21861369999533053  seconds by  0.0  percent.
# ------------- 7 54
# set cost params:  1.0 35000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2348958000075072  seconds by  0.0  percent.
# ------------- 7 55
# set cost params:  1.0 35000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.219685500007472  seconds by  0.0  percent.
# ------------- 8 42
# set cost params:  1.0 40000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19534769999154378  seconds by  0.0  percent.
# ------------- 8 43
# set cost params:  1.0 40000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1900000000023283  seconds by  0.0  percent.
# ------------- 8 44
# set cost params:  1.0 40000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.3165807999903336  seconds by  0.0  percent.
# ------------- 8 45
# set cost params:  1.0 40000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21669680000923108  seconds by  0.0  percent.
# ------------- 8 46
# set cost params:  1.0 40000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2186024999973597  seconds by  0.0  percent.
# ------------- 8 47
# set cost params:  1.0 40000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21869359999254812  seconds by  0.0  percent.
# ------------- 8 48
# set cost params:  1.0 40000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2361623999895528  seconds by  0.0  percent.
# ------------- 8 49
# set cost params:  1.0 40000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.22648830000252929  seconds by  0.0  percent.
# ------------- 8 50
# set cost params:  1.0 40000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21155199999338947  seconds by  0.0  percent.
# ------------- 8 51
# set cost params:  1.0 40000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19674789998680353  seconds by  0.0  percent.
# ------------- 8 52
# set cost params:  1.0 40000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1926990000065416  seconds by  0.0  percent.
# ------------- 8 53
# set cost params:  1.0 40000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20417789999919478  seconds by  0.0  percent.
# ------------- 8 54
# set cost params:  1.0 40000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19451020000269637  seconds by  0.0  percent.
# ------------- 8 55
# set cost params:  1.0 40000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19273080000129994  seconds by  0.0  percent.
# ------------- 9 41
# set cost params:  1.0 45000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18543670000508428  seconds by  0.0  percent.
# ------------- 9 42
# set cost params:  1.0 45000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19744519999949262  seconds by  0.0  percent.
# ------------- 9 43
# set cost params:  1.0 45000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2197236000065459  seconds by  0.0  percent.
# ------------- 9 44
# set cost params:  1.0 45000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.23847379999642726  seconds by  0.0  percent.
# ------------- 9 45
# set cost params:  1.0 45000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19784610001079272  seconds by  0.0  percent.
# ------------- 9 46
# set cost params:  1.0 45000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1867151000042213  seconds by  0.0  percent.
# ------------- 9 47
# set cost params:  1.0 45000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18446489999769256  seconds by  0.0  percent.
# ------------- 9 48
# set cost params:  1.0 45000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1787562999961665  seconds by  0.0  percent.
# ------------- 9 49
# set cost params:  1.0 45000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18456639999931213  seconds by  0.0  percent.
# ------------- 9 50
# set cost params:  1.0 45000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18081799999345094  seconds by  0.0  percent.
# ------------- 9 51
# set cost params:  1.0 45000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18562560000282247  seconds by  0.0  percent.
# ------------- 9 52
# set cost params:  1.0 45000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18433340000046883  seconds by  0.0  percent.
# ------------- 9 53
# set cost params:  1.0 45000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18920039999647997  seconds by  0.0  percent.
# ------------- 9 54
# set cost params:  1.0 45000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20385499999974854  seconds by  0.0  percent.
# ------------- 9 55
# set cost params:  1.0 45000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.21733790000143927  seconds by  0.0  percent.
# ------------- 10 41
# set cost params:  1.0 50000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.22760050000215415  seconds by  0.0  percent.
# ------------- 10 42
# set cost params:  1.0 50000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2114292999904137  seconds by  0.0  percent.
# ------------- 10 43
# set cost params:  1.0 50000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19173510000109673  seconds by  0.0  percent.
# ------------- 10 44
# set cost params:  1.0 50000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18894239999644924  seconds by  0.0  percent.
# ------------- 10 45
# set cost params:  1.0 50000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# ...
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18330150000110734  seconds by  0.0  percent.
# ------------- 65 14
# set cost params:  1.0 325000.0 14000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.204532299991115  seconds by  0.0  percent.
# ------------- 65 15
# set cost params:  1.0 325000.0 15000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20580189999600407  seconds by  0.0  percent.
# ------------- 66 3
# set cost params:  1.0 330000.0 3000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18912100000306964  seconds by  0.0  percent.
# ------------- 66 4
# set cost params:  1.0 330000.0 4000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18113850000372622  seconds by  0.0  percent.
# ------------- 66 5
# set cost params:  1.0 330000.0 5000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17857990000629798  seconds by  0.0  percent.
# ------------- 66 6
# set cost params:  1.0 330000.0 6000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17775689999689348  seconds by  0.0  percent.
# ------------- 66 7
# set cost params:  1.0 330000.0 7000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17175300000235438  seconds by  0.0  percent.
# ------------- 66 8
# set cost params:  1.0 330000.0 8000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1760740000026999  seconds by  0.0  percent.
# ------------- 66 9
# set cost params:  1.0 330000.0 9000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.169560399997863  seconds by  0.0  percent.
# ------------- 66 10
# set cost params:  1.0 330000.0 10000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17305309999210294  seconds by  0.0  percent.
# ------------- 66 11
# set cost params:  1.0 330000.0 11000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17572929999732878  seconds by  0.0  percent.
# ------------- 66 12
# set cost params:  1.0 330000.0 12000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17396569999982603  seconds by  0.0  percent.
# ------------- 66 13
# set cost params:  1.0 330000.0 13000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17369729999336414  seconds by  0.0  percent.
# ------------- 67 2
# set cost params:  1.0 335000.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1761838000093121  seconds by  0.0  percent.
# ------------- 67 3
# set cost params:  1.0 335000.0 3000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17412929999409243  seconds by  0.0  percent.
# ------------- 67 4
# set cost params:  1.0 335000.0 4000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17637709999689832  seconds by  0.0  percent.
# ------------- 67 5
# set cost params:  1.0 335000.0 5000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17622740000660997  seconds by  0.0  percent.
# ------------- 67 6
# set cost params:  1.0 335000.0 6000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17703580000670627  seconds by  0.0  percent.
# ------------- 67 7
# set cost params:  1.0 335000.0 7000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1726226000027964  seconds by  0.0  percent.
# ------------- 67 8
# set cost params:  1.0 335000.0 8000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17337599999154918  seconds by  0.0  percent.
# ------------- 67 9
# set cost params:  1.0 335000.0 9000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1751627999910852  seconds by  0.0  percent.
# ------------- 67 10
# set cost params:  1.0 335000.0 10000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1735291000077268  seconds by  0.0  percent.
# ------------- 67 11
# set cost params:  1.0 335000.0 11000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17534650000743568  seconds by  0.0  percent.
# ------------- 68 2
# set cost params:  1.0 340000.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18766469998809043  seconds by  0.0  percent.
# ------------- 68 3
# set cost params:  1.0 340000.0 3000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17356079998717178  seconds by  0.0  percent.
# ------------- 68 4
# set cost params:  1.0 340000.0 4000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17350039999291766  seconds by  0.0  percent.
# ------------- 68 5
# set cost params:  1.0 340000.0 5000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1865202000044519  seconds by  0.0  percent.
# ------------- 68 8
# set cost params:  1.0 340000.0 8000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2031171999988146  seconds by  0.0  percent.
# ------------- 68 9
# set cost params:  1.0 340000.0 9000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20703960000537336  seconds by  0.0  percent.
# ------------- 69 1
# set cost params:  1.0 345000.0 1000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19016230000124779  seconds by  0.0  percent.
# ------------- 69 3
# set cost params:  1.0 345000.0 3000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1815288999932818  seconds by  0.0  percent.
# ------------- 69 4
# set cost params:  1.0 345000.0 4000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1793794999975944  seconds by  0.0  percent.
# ------------- 69 7
# set cost params:  1.0 345000.0 7000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17660619999514893  seconds by  0.0  percent.
# ------------- 69 8
# set cost params:  1.0 345000.0 8000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18215990001044702  seconds by  0.0  percent.
# ------------- 70 0
# set cost params:  1.0 350000.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22492.994016984765
# RUN  2 , total integrated cost =  22492.994012105642
# ERROR:root:Problem in initial value trasfer
# RUN  3 , total integrated cost =  22492.994012105573
# RUN  4 , total integrated cost =  22492.994012105573
# Control only changes marginally.
# RUN  4 , total integrated cost =  22492.994012105573
# Improved over  4  iterations in  0.30927349999547005  seconds by  0.0022244187378106517  percent.
# Problem in initial value trasfer:  Vmean_exc -56.29219302541232 -56.29223988069473
# ------------- 70 2
# set cost params:  1.0 350000.0 2000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17734130000462756  seconds by  0.0  percent.
# ------------- 70 6
# set cost params:  1.0 350000.0 6000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17546080000465736  seconds by  0.0  percent.
# ------------- 71 1
# set cost params:  1.0 355000.0 1000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1777328000025591  seconds by  0.0  percent.
# ------------- 71 5
# set cost params:  1.0 355000.0 5000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17512679999344982  seconds by  0.0  percent.

# %%
test_cost = cost_2d_2_node1input_maxcost

jumps_input_to_zero = test_cost.copy()
for i_e in range(len(e_weights)):
    for i_s in range(len(s_weights)):
        jumps_input_to_zero[i_e, i_s] = 0
        if np.abs(cost_exc_node_node1input[i_e, i_s]) < 1e-6:
            if np.abs(cost_2d_2_node1input[i_e,i_s] - 22493.49) > 0.5:
                jumps_input_to_zero[i_e, i_s] = 1
            
#print("jumps to zero in exc current control ", jumps_input_to_zero)        
        
fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, mask=jumps_input_to_zero.T == 1, cmap="viridis")
ax.set_facecolor('red')
ax.set(xlabel='energy weight', ylabel='sparsity weight', title='cost after {} iterations, A as initial guess'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_node1input' + str(c_) ) )
plt.show()

# %%
test_cost = cost_2d_2_node1zero
too_high_cost = []
local_min = []

for c1_ in range(N_e):
    for c2_ in range(N_s):
        if test_cost[c1_,c2_] > 22492 and test_cost[c1_,c2_] < 22495:
            #print("presumably local minimum for ", c1_, c2_)
            local_min.append([c1_,c2_])
        if test_cost[c1_,c2_] > 22500:
            #print("too high cost for ", c1_, c2_)
            too_high_cost.append([c1_,c2_])
            #test_cost[c1_,c2_] = 22500
        if test_cost[c1_,c2_] == 0.:
            print("zero cost for ", c1_, c2_)
            #test_cost[c1_,c2_] = 22500

fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, cmap="viridis")
ax.set(xlabel='energy weight', ylabel='sparsity weight', title='cost after {} iterations'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_' + str(c_) ) )
plt.show()

# %%
cgv = None
max_it = 100
control3 = bc[:,:,n_pre-1:-n_post+1]
aln.params.duration = dur

cost_2d_2_node1zero_maxcost = cost_2d_2_node1zero.copy()

# too_high_cost, local_min

for indices in too_high_cost:
    
    ind_e = indices[0]
    ind_s = indices[1]
        
    print("-------------", ind_e, ind_s)

    c_e = e_weights[ind_e]
    c_s = s_weights[ind_s]

    cost.setParams(1.0, c_e, c_s)
    aln.params.duration = dur
    setinit(initVars)
    
    start_cntrl = control0

    bc, bs, cost_, rt, gr, ph, cn_ = aln.A1(
        start_cntrl, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

    j = 1
    while cost_[-j] == 0.:
        j += 1
    cost_2d_2_node1zero_maxcost[ind_e,ind_s] = cost_[-j]
# Out:
# ------------- 1 55
# set cost params:  1.0 5000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1884429000056116  seconds by  0.0  percent.
# ------------- 2 54
# set cost params:  1.0 10000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1816465000010794  seconds by  0.0  percent.
# ------------- 2 55
# set cost params:  1.0 10000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18176479999965522  seconds by  0.0  percent.
# ------------- 3 53
# set cost params:  1.0 15000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1684255000000121  seconds by  0.0  percent.
# ------------- 3 54
# set cost params:  1.0 15000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17232129999320023  seconds by  0.0  percent.
# ------------- 3 55
# set cost params:  1.0 15000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16927999998733867  seconds by  0.0  percent.
# ------------- 4 52
# set cost params:  1.0 20000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16828749999694992  seconds by  0.0  percent.
# ------------- 4 53
# set cost params:  1.0 20000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17112500000803266  seconds by  0.0  percent.
# ------------- 4 54
# set cost params:  1.0 20000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17269340000348166  seconds by  0.0  percent.
# ------------- 4 55
# set cost params:  1.0 20000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17586660000961274  seconds by  0.0  percent.
# ------------- 5 51
# set cost params:  1.0 25000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1727627000072971  seconds by  0.0  percent.
# ------------- 5 52
# set cost params:  1.0 25000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1810986999917077  seconds by  0.0  percent.
# ------------- 5 53
# set cost params:  1.0 25000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17860160001146141  seconds by  0.0  percent.
# ------------- 5 54
# set cost params:  1.0 25000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17456350001157261  seconds by  0.0  percent.
# ------------- 6 50
# set cost params:  1.0 30000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17741230000683572  seconds by  0.0  percent.
# ------------- 6 51
# set cost params:  1.0 30000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1744572000025073  seconds by  0.0  percent.
# ------------- 6 52
# set cost params:  1.0 30000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17432399999233894  seconds by  0.0  percent.
# ------------- 6 55
# set cost params:  1.0 30000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1777311999903759  seconds by  0.0  percent.
# ------------- 7 49
# set cost params:  1.0 35000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1842523999948753  seconds by  0.0  percent.
# ------------- 7 50
# set cost params:  1.0 35000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1735010999982478  seconds by  0.0  percent.
# ------------- 7 53
# set cost params:  1.0 35000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1739570000063395  seconds by  0.0  percent.
# ------------- 7 54
# set cost params:  1.0 35000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17564649999258108  seconds by  0.0  percent.
# ------------- 7 55
# set cost params:  1.0 35000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17140830001153518  seconds by  0.0  percent.
# ------------- 8 48
# set cost params:  1.0 40000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18418290000408888  seconds by  0.0  percent.
# ------------- 8 49
# set cost params:  1.0 40000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20863780000945553  seconds by  0.0  percent.
# ------------- 8 51
# set cost params:  1.0 40000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18693419999908656  seconds by  0.0  percent.
# ------------- 8 52
# set cost params:  1.0 40000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17703350000374485  seconds by  0.0  percent.
# ------------- 8 53
# set cost params:  1.0 40000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1768900000024587  seconds by  0.0  percent.
# ------------- 8 54
# set cost params:  1.0 40000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1786106999934418  seconds by  0.0  percent.
# ------------- 8 55
# set cost params:  1.0 40000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17772659999900497  seconds by  0.0  percent.
# ------------- 9 47
# set cost params:  1.0 45000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17622949999349657  seconds by  0.0  percent.
# ------------- 9 48
# set cost params:  1.0 45000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17539050000777934  seconds by  0.0  percent.
# ------------- 9 50
# set cost params:  1.0 45000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1747830999956932  seconds by  0.0  percent.
# ------------- 9 51
# set cost params:  1.0 45000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17456159999710508  seconds by  0.0  percent.
# ------------- 9 52
# set cost params:  1.0 45000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17823829999542795  seconds by  0.0  percent.
# ------------- 9 53
# set cost params:  1.0 45000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.182270300007076  seconds by  0.0  percent.
# ------------- 9 54
# set cost params:  1.0 45000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1765750000049593  seconds by  0.0  percent.
# ------------- 10 46
# set cost params:  1.0 50000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17567519999283832  seconds by  0.0  percent.
# ------------- 10 47
# set cost params:  1.0 50000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17805240000598133  seconds by  0.0  percent.
# ------------- 10 48
# set cost params:  1.0 50000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1762245999998413  seconds by  0.0  percent.
# ------------- 10 49
# set cost params:  1.0 50000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1898390999995172  seconds by  0.0  percent.
# ------------- 10 50
# set cost params:  1.0 50000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18667129999084864  seconds by  0.0  percent.
# ------------- 10 51
# set cost params:  1.0 50000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19263249999494292  seconds by  0.0  percent.
# ------------- 10 52
# set cost params:  1.0 50000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1899227000103565  seconds by  0.0  percent.
# ------------- 10 53
# set cost params:  1.0 50000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17582050000783056  seconds by  0.0  percent.
# ------------- 11 45
# set cost params:  1.0 55000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17605940000794362  seconds by  0.0  percent.
# ------------- 11 46
# set cost params:  1.0 55000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17572980000113603  seconds by  0.0  percent.
# ------------- 11 47
# set cost params:  1.0 55000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17468169999483507  seconds by  0.0  percent.
# ------------- 11 48
# set cost params:  1.0 55000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17902850000245962  seconds by  0.0  percent.
# ------------- 11 49
# set cost params:  1.0 55000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18934550000994932  seconds by  0.0  percent.
# ------------- 11 50
# set cost params:  1.0 55000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.2261733000050299  seconds by  0.0  percent.
# ------------- 11 51
# set cost params:  1.0 55000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.20504409998829942  seconds by  0.0  percent.
# ------------- 12 44
# set cost params:  1.0 60000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17510639999818522  seconds by  0.0  percent.
# ------------- 12 45
# set cost params:  1.0 60000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17638999999326188  seconds by  0.0  percent.
# ------------- 12 46
# set cost params:  1.0 60000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17509699999936856  seconds by  0.0  percent.
# ------------- 12 47
# set cost params:  1.0 60000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18250489998899866  seconds by  0.0  percent.
# ------------- 12 48
# set cost params:  1.0 60000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18421879998641089  seconds by  0.0  percent.
# ------------- 12 49
# set cost params:  1.0 60000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17620969998824876  seconds by  0.0  percent.
# ------------- 13 43
# set cost params:  1.0 65000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18303509999532253  seconds by  0.0  percent.
# ------------- 13 44
# set cost params:  1.0 65000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17559720001008827  seconds by  0.0  percent.
# ------------- 13 45
# set cost params:  1.0 65000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17663089999405202  seconds by  0.0  percent.
# ------------- 13 46
# set cost params:  1.0 65000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1766792999987956  seconds by  0.0  percent.
# ------------- 13 47
# set cost params:  1.0 65000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17731020000064746  seconds by  0.0  percent.
# ------------- 13 55
# set cost params:  1.0 65000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1755399999965448  seconds by  0.0  percent.
# ------------- 14 41
# set cost params:  1.0 70000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1769225999887567  seconds by  0.0  percent.
# ------------- 14 42
# set cost params:  1.0 70000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17505079999682494  seconds by  0.0  percent.
# ------------- 14 43
# set cost params:  1.0 70000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17632299999240786  seconds by  0.0  percent.
# ------------- 14 44
# set cost params:  1.0 70000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17562850000103936  seconds by  0.0  percent.
# ------------- 14 45
# set cost params:  1.0 70000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17644969999673776  seconds by  0.0  percent.
# ------------- 14 53
# set cost params:  1.0 70000.0 53000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17797439999412745  seconds by  0.0  percent.
# ------------- 14 54
# set cost params:  1.0 70000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18282070000714157  seconds by  0.0  percent.
# ------------- 14 55
# set cost params:  1.0 70000.0 55000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16983570001320913  seconds by  0.0  percent.
# ------------- 15 40
# set cost params:  1.0 75000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17113300001074094  seconds by  0.0  percent.
# ------------- 15 41
# set cost params:  1.0 75000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16616330000397284  seconds by  0.0  percent.
# ------------- 15 42
# set cost params:  1.0 75000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17067809999571182  seconds by  0.0  percent.
# ------------- 15 43
# set cost params:  1.0 75000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16764580000017304  seconds by  0.0  percent.
# ------------- 15 44
# set cost params:  1.0 75000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18432729999767616  seconds by  0.0  percent.
# ------------- 15 51
# set cost params:  1.0 75000.0 51000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19734289999178145  seconds by  0.0  percent.
# ------------- 15 52
# set cost params:  1.0 75000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17643830001179595  seconds by  0.0  percent.
# ------------- 15 54
# set cost params:  1.0 75000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.167603899986716  seconds by  0.0  percent.
# ------------- 16 39
# set cost params:  1.0 80000.0 39000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17297149999649264  seconds by  0.0  percent.
# ------------- 16 40
# set cost params:  1.0 80000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1694363999995403  seconds by  0.0  percent.
# ------------- 16 41
# set cost params:  1.0 80000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1653630999935558  seconds by  0.0  percent.
# ------------- 16 42
# set cost params:  1.0 80000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16905450000194833  seconds by  0.0  percent.
# ------------- 16 48
# set cost params:  1.0 80000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17516100000648294  seconds by  0.0  percent.
# ------------- 16 49
# set cost params:  1.0 80000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1640969000000041  seconds by  0.0  percent.
# ------------- 16 50
# set cost params:  1.0 80000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16848449999815784  seconds by  0.0  percent.
# ------------- 16 52
# set cost params:  1.0 80000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16944950001197867  seconds by  0.0  percent.
# ------------- 16 54
# set cost params:  1.0 80000.0 54000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17007799999555573  seconds by  0.0  percent.
# ------------- 17 38
# set cost params:  1.0 85000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17239880000124685  seconds by  0.0  percent.
# ------------- 17 39
# set cost params:  1.0 85000.0 39000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16510179999750108  seconds by  0.0  percent.
# ------------- 17 40
# set cost params:  1.0 85000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16767569999501575  seconds by  0.0  percent.
# ------------- 17 46
# set cost params:  1.0 85000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16579400000046007  seconds by  0.0  percent.
# ------------- 17 47
# set cost params:  1.0 85000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1683746000053361  seconds by  0.0  percent.
# ------------- 17 48
# set cost params:  1.0 85000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1650686999928439  seconds by  0.0  percent.
# ------------- 17 49
# set cost params:  1.0 85000.0 49000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16935160000866745  seconds by  0.0  percent.
# ------------- 17 50
# set cost params:  1.0 85000.0 50000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1644747000100324  seconds by  0.0  percent.
# ------------- 17 52
# set cost params:  1.0 85000.0 52000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.166949399994337  seconds by  0.0  percent.
# ------------- 18 37
# set cost params:  1.0 90000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16768729999603238  seconds by  0.0  percent.
# ------------- 18 38
# set cost params:  1.0 90000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16410749999340624  seconds by  0.0  percent.
# ------------- 18 43
# set cost params:  1.0 90000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17641439998988062  seconds by  0.0  percent.
# ------------- 18 44
# set cost params:  1.0 90000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16658230000757612  seconds by  0.0  percent.
# ------------- 18 45
# set cost params:  1.0 90000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1660015000088606  seconds by  0.0  percent.
# ------------- 18 46
# set cost params:  1.0 90000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1681922999996459  seconds by  0.0  percent.
# ------------- 18 47
# set cost params:  1.0 90000.0 47000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1860801999864634  seconds by  0.0  percent.
# ------------- 18 48
# set cost params:  1.0 90000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18641219999699388  seconds by  0.0  percent.
# ------------- 19 36
# set cost params:  1.0 95000.0 36000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18798820000665728  seconds by  0.0  percent.
# ------------- 19 37
# set cost params:  1.0 95000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17748630000278354  seconds by  0.0  percent.
# ------------- 19 40
# set cost params:  1.0 95000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16554390000237618  seconds by  0.0  percent.
# ------------- 19 41
# set cost params:  1.0 95000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17116169999644626  seconds by  0.0  percent.
# ------------- 19 42
# set cost params:  1.0 95000.0 42000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18513090000487864  seconds by  0.0  percent.
# ------------- 19 43
# set cost params:  1.0 95000.0 43000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17084240000986028  seconds by  0.0  percent.
# ------------- 19 44
# set cost params:  1.0 95000.0 44000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1700142999907257  seconds by  0.0  percent.
# ------------- 19 45
# set cost params:  1.0 95000.0 45000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1675317999906838  seconds by  0.0  percent.
# ------------- 19 46
# set cost params:  1.0 95000.0 46000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16776820000086445  seconds by  0.0  percent.
# ------------- 19 48
# set cost params:  1.0 95000.0 48000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16464269999414682  seconds by  0.0  percent.
# ------------- 20 35
# set cost params:  1.0 100000.0 35000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16754139999102335  seconds by  0.0  percent.
# ------------- 20 37
# set cost params:  1.0 100000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1667481000040425  seconds by  0.0  percent.
# ------------- 20 38
# set cost params:  1.0 100000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17075769999064505  seconds by  0.0  percent.
# ------------- 20 39
# set cost params:  1.0 100000.0 39000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16676300000108313  seconds by  0.0  percent.
# ------------- 20 40
# set cost params:  1.0 100000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# ...
# ------------- 23 35
# set cost params:  1.0 115000.0 35000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17068389999622013  seconds by  0.0  percent.
# ------------- 23 36
# set cost params:  1.0 115000.0 36000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16761389999010134  seconds by  0.0  percent.
# ------------- 23 37
# set cost params:  1.0 115000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16982029999780934  seconds by  0.0  percent.
# ------------- 23 38
# set cost params:  1.0 115000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16430720000062138  seconds by  0.0  percent.
# ------------- 23 39
# set cost params:  1.0 115000.0 39000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17031859999406151  seconds by  0.0  percent.
# ------------- 23 41
# set cost params:  1.0 115000.0 41000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1681393000035314  seconds by  0.0  percent.
# ------------- 24 32
# set cost params:  1.0 120000.0 32000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16453989999718033  seconds by  0.0  percent.
# ------------- 24 33
# set cost params:  1.0 120000.0 33000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17068779999681283  seconds by  0.0  percent.
# ------------- 24 34
# set cost params:  1.0 120000.0 34000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1632108000048902  seconds by  0.0  percent.
# ------------- 24 35
# set cost params:  1.0 120000.0 35000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1708714999986114  seconds by  0.0  percent.
# ------------- 24 36
# set cost params:  1.0 120000.0 36000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16926159999275114  seconds by  0.0  percent.
# ------------- 24 37
# set cost params:  1.0 120000.0 37000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16883059999963734  seconds by  0.0  percent.
# ------------- 24 38
# set cost params:  1.0 120000.0 38000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1677653999940958  seconds by  0.0  percent.
# ------------- 24 39
# set cost params:  1.0 120000.0 39000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1679539000033401  seconds by  0.0  percent.
# ------------- 24 40
# set cost params:  1.0 120000.0 40000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16989779999130405  seconds by  0.0  percent.
# ------------- 25 36
# set cost params:  1.0 125000.0 36000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.19002339999133255  seconds by  0.0  percent.
# ------------- 26 31
# set cost params:  1.0 130000.0 31000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.18454129999736324  seconds by  0.0  percent.
# ------------- 27 29
# set cost params:  1.0 135000.0 29000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17111309999017976  seconds by  0.0  percent.
# ------------- 27 30
# set cost params:  1.0 135000.0 30000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16870170000765938  seconds by  0.0  percent.
# ------------- 27 31
# set cost params:  1.0 135000.0 31000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16721030000189785  seconds by  0.0  percent.
# ------------- 27 35
# set cost params:  1.0 135000.0 35000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1654867000033846  seconds by  0.0  percent.
# ------------- 28 28
# set cost params:  1.0 140000.0 28000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16866669998853467  seconds by  0.0  percent.
# ------------- 28 29
# set cost params:  1.0 140000.0 29000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16552710000541992  seconds by  0.0  percent.
# ------------- 28 30
# set cost params:  1.0 140000.0 30000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.175520000004326  seconds by  0.0  percent.
# ------------- 28 31
# set cost params:  1.0 140000.0 31000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16800900000089314  seconds by  0.0  percent.
# ------------- 29 27
# set cost params:  1.0 145000.0 27000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16440419999707956  seconds by  0.0  percent.
# ------------- 29 28
# set cost params:  1.0 145000.0 28000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1693297000019811  seconds by  0.0  percent.
# ------------- 29 29
# set cost params:  1.0 145000.0 29000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1668915000045672  seconds by  0.0  percent.
# ------------- 29 30
# set cost params:  1.0 145000.0 30000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16979559999890625  seconds by  0.0  percent.
# ------------- 29 31
# set cost params:  1.0 145000.0 31000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1685445999901276  seconds by  0.0  percent.
# ------------- 30 26
# set cost params:  1.0 150000.0 26000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16659140000410844  seconds by  0.0  percent.
# ------------- 30 27
# set cost params:  1.0 150000.0 27000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.17390829999931157  seconds by  0.0  percent.
# ------------- 30 28
# set cost params:  1.0 150000.0 28000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16788350000570063  seconds by  0.0  percent.
# ------------- 30 29
# set cost params:  1.0 150000.0 29000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1680354999989504  seconds by  0.0  percent.
# ------------- 30 30
# set cost params:  1.0 150000.0 30000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16598859999794513  seconds by  0.0  percent.
# ------------- 31 26
# set cost params:  1.0 155000.0 26000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16730549999920186  seconds by  0.0  percent.
# ------------- 32 24
# set cost params:  1.0 160000.0 24000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16952179999498185  seconds by  0.0  percent.
# ------------- 33 25
# set cost params:  1.0 165000.0 25000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16747790000226814  seconds by  0.0  percent.
# ------------- 35 22
# set cost params:  1.0 175000.0 22000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.1679625999968266  seconds by  0.0  percent.
# ------------- 49 14
# set cost params:  1.0 245000.0 14000.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22493.494361608944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22493.494361608944
# Control only changes marginally.
# RUN  1 , total integrated cost =  22493.494361608944
# Improved over  1  iterations in  0.16657600000326056  seconds by  0.0  percent.

# %%
test_cost = cost_2d_2_node1zero_maxcost

jumps_zero_to_input = test_cost.copy()
for i_e in range(len(e_weights)):
    for i_s in range(len(s_weights)):
        jumps_zero_to_input[i_e, i_s] = 0
        if np.abs(cost_exc_node_node1zero[i_e, i_s]) > 1e-6:
            if np.abs(cost_2d_2_node1zero[i_e,i_s] - 22493.49) > 0.5:
                jumps_zero_to_input[i_e, i_s] = 1
            
#print("jumps to input in exc current control ", jumps_zero_to_input)

fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, mask=jumps_zero_to_input.T == 1, cmap="viridis")
ax.set_facecolor('red')
ax.set(xlabel='energy weight', ylabel='sparsity weight', title='cost after {} iterations, B as initial guess'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_node1zero' + str(c_) ) )
plt.show()

# %%
test_cost = cost_2d_2_node1zero_maxcost - cost_2d_2_node1input_maxcost

fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, cmap="viridis")
ax.set_facecolor('red')
ax.set(xlabel='energy weight', ylabel='sparsity weight',
       title='cost difference after {} iterations, B - A'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_diff' + str(c_) ) )
plt.show()

# %%
test_cost = cost_2d_2_node1zero_maxcost.copy()
for i_e in range(test_cost.shape[0]):
    for i_s in range(test_cost.shape[1]):
        if cost_2d_2_node1input_maxcost[i_e, i_s] < test_cost[i_e, i_s]:
            test_cost[i_e, i_s] = cost_2d_2_node1input_maxcost[i_e, i_s]

fig, ax = plt.subplots(figsize=(12,10)) 
ax = sns.heatmap(test_cost.T, cmap="viridis")
ax.set_facecolor('red')
ax.set(xlabel='energy weight', ylabel='sparsity weight',
       title='minimum cost for A or B as initial guess after {} iterations'.format(max_it))
ax.invert_yaxis()

ax.xaxis.set_major_locator(ticker.LinearLocator(n_xticks))
ax.set_xticklabels(e_ticklabels, rotation=90)

ax.yaxis.set_major_locator(ticker.LinearLocator(n_yticks))
ax.set_yticklabels(s_ticklabels, rotation=0)

ax.annotate('A', xy=(xa_arrow, 0), xytext=(xa_arrow-arrow_xlength, arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('D', xy=(0, yd_arrow), xytext=(arrow_xlength, yd_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('C', xy=(xc_arrow, yc_arrow), xytext=(xc_arrow-arrow_xlength, yc_arrow+arrow_ylength),
            horizontalalignment='right', verticalalignment='bottom',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))
ax.annotate('B', xy=(xb_arrow, yb_arrow), xytext=(xb_arrow+arrow_xlength, yb_arrow-arrow_ylength),
            horizontalalignment='left', verticalalignment='top',
            arrowprops=dict(facecolor='black', width=0.1, headwidth=8., shrink=0.05))

plt.savefig(os.path.join(path, 'heatmap_cost_' + str(c_) ) )
plt.show()
